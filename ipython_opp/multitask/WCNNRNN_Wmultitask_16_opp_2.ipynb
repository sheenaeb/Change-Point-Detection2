# %%
# useing this variable for saving models and summaries
exp_name = "WCNNRNN_Wmultitask_16_opp_2"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.WCNNRNN_model_2 as WCNNRNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 7    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = WCNNRNN_model.Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)
# Out:
# Tensor("Squeeze_24:0", shape=(?, ?, 19), dtype=float32) Tensor("Reshape_8:0", shape=(?, ?, 19), dtype=float32)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.060
# F1 = 0.091 vs. 0.090
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.079 vs. 0.092
# F1 = 0.162 vs. 0.165
# Precision = 0.088 vs. 0.093
# Recall = 1.000 vs. 0.744
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.055 vs. 0.059
# F1 = 0.078 vs. 0.080
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.048 vs. 0.060
# F1 = 0.097 vs. 0.102
# Precision = 0.051 vs. 0.058
# Recall = 0.917 vs. 0.431
# Minibatch Loss= 1.300793
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.800 vs. 0.061
# F1 = 0.772 vs. 0.090
# Accuracy = 0.820 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.082
# F1 = 0.369 vs. 0.163
# Precision = 0.257 vs. 0.089
# Recall = 0.650 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.444 vs. 0.059
# F1 = 0.491 vs. 0.083
# Accuracy = 0.796 vs. 0.056
# CHANGE DETECTION
# AUC = 0.209 vs. 0.054
# F1 = 0.281 vs. 0.103
# Precision = 0.213 vs. 0.057
# Recall = 0.416 vs. 0.556
# Minibatch Loss= 0.208983
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.935 vs. 0.062
# F1 = 0.878 vs. 0.093
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.332 vs. 0.100
# F1 = 0.414 vs. 0.171
# Precision = 0.305 vs. 0.096
# Recall = 0.645 vs. 0.749
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.061
# F1 = 0.534 vs. 0.086
# Accuracy = 0.838 vs. 0.056
# CHANGE DETECTION
# AUC = 0.209 vs. 0.052
# F1 = 0.299 vs. 0.097
# Precision = 0.200 vs. 0.053
# Recall = 0.595 vs. 0.535
# Minibatch Loss= 0.131376
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.964 vs. 0.060
# F1 = 0.919 vs. 0.089
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.084
# F1 = 0.429 vs. 0.156
# Precision = 0.294 vs. 0.086
# Recall = 0.794 vs. 0.889
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.536 vs. 0.059
# F1 = 0.549 vs. 0.079
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.217 vs. 0.054
# F1 = 0.308 vs. 0.100
# Precision = 0.227 vs. 0.053
# Recall = 0.481 vs. 0.826
# Minibatch Loss= 0.096726
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.061
# F1 = 0.953 vs. 0.091
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.421 vs. 0.088
# F1 = 0.499 vs. 0.155
# Precision = 0.369 vs. 0.085
# Recall = 0.771 vs. 0.876
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.532 vs. 0.059
# F1 = 0.549 vs. 0.084
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.230 vs. 0.049
# F1 = 0.328 vs. 0.098
# Precision = 0.228 vs. 0.053
# Recall = 0.587 vs. 0.670
# Minibatch Loss= 0.075209
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.062
# F1 = 0.969 vs. 0.093
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.527 vs. 0.102
# F1 = 0.577 vs. 0.178
# Precision = 0.498 vs. 0.098
# Recall = 0.686 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.533 vs. 0.059
# F1 = 0.549 vs. 0.084
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.238 vs. 0.055
# F1 = 0.330 vs. 0.098
# Precision = 0.227 vs. 0.052
# Recall = 0.603 vs. 0.816
# Minibatch Loss= 0.065439
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.953 vs. 0.062
# F1 = 0.909 vs. 0.093
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.471 vs. 0.093
# F1 = 0.509 vs. 0.171
# Precision = 0.389 vs. 0.094
# Recall = 0.734 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.058
# F1 = 0.597 vs. 0.079
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.252 vs. 0.057
# F1 = 0.358 vs. 0.107
# Precision = 0.258 vs. 0.062
# Recall = 0.584 vs. 0.387
# Minibatch Loss= 0.082816
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.061
# F1 = 0.968 vs. 0.089
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.609 vs. 0.096
# F1 = 0.624 vs. 0.172
# Precision = 0.533 vs. 0.095
# Recall = 0.751 vs. 0.907
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.058
# F1 = 0.600 vs. 0.078
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.054
# F1 = 0.369 vs. 0.098
# Precision = 0.279 vs. 0.053
# Recall = 0.543 vs. 0.683
# Minibatch Loss= 0.056488
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.061
# F1 = 0.950 vs. 0.090
# Accuracy = 0.951 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.094
# F1 = 0.625 vs. 0.172
# Precision = 0.528 vs. 0.094
# Recall = 0.765 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.059
# F1 = 0.617 vs. 0.084
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.053
# F1 = 0.355 vs. 0.103
# Precision = 0.258 vs. 0.057
# Recall = 0.571 vs. 0.540
# Minibatch Loss= 0.058685
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.060
# F1 = 0.984 vs. 0.089
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.720 vs. 0.078
# F1 = 0.722 vs. 0.145
# Precision = 0.595 vs. 0.078
# Recall = 0.918 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.058
# F1 = 0.610 vs. 0.080
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.054
# F1 = 0.369 vs. 0.098
# Precision = 0.276 vs. 0.053
# Recall = 0.558 vs. 0.662
# Minibatch Loss= 0.034339
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.063
# F1 = 0.986 vs. 0.093
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.796 vs. 0.108
# F1 = 0.790 vs. 0.189
# Precision = 0.729 vs. 0.104
# Recall = 0.862 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.058
# F1 = 0.604 vs. 0.080
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.054
# F1 = 0.366 vs. 0.099
# Precision = 0.284 vs. 0.053
# Recall = 0.517 vs. 0.792
# Minibatch Loss= 0.037397
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.989 vs. 0.093
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.859 vs. 0.097
# F1 = 0.832 vs. 0.176
# Precision = 0.783 vs. 0.103
# Recall = 0.887 vs. 0.604
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.060
# F1 = 0.604 vs. 0.082
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.050
# F1 = 0.364 vs. 0.097
# Precision = 0.343 vs. 0.051
# Recall = 0.387 vs. 0.964
# Minibatch Loss= 0.029553
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.061
# F1 = 0.937 vs. 0.091
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.703 vs. 0.093
# F1 = 0.689 vs. 0.166
# Precision = 0.646 vs. 0.091
# Recall = 0.737 vs. 0.946
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.060
# F1 = 0.593 vs. 0.082
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.049
# F1 = 0.389 vs. 0.097
# Precision = 0.319 vs. 0.051
# Recall = 0.496 vs. 0.995
# Minibatch Loss= 0.057514
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.058
# F1 = 0.989 vs. 0.087
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.865 vs. 0.085
# F1 = 0.839 vs. 0.152
# Precision = 0.778 vs. 0.091
# Recall = 0.910 vs. 0.470
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.058
# F1 = 0.621 vs. 0.081
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.049
# F1 = 0.405 vs. 0.097
# Precision = 0.318 vs. 0.051
# Recall = 0.556 vs. 0.951
# Minibatch Loss= 0.023214
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.993 vs. 0.087
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.896 vs. 0.084
# F1 = 0.892 vs. 0.158
# Precision = 0.829 vs. 0.086
# Recall = 0.965 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.059
# F1 = 0.617 vs. 0.079
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.049
# F1 = 0.399 vs. 0.096
# Precision = 0.329 vs. 0.051
# Recall = 0.506 vs. 0.982
# Minibatch Loss= 0.018793
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.092
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.952 vs. 0.080
# F1 = 0.928 vs. 0.155
# Precision = 0.874 vs. 0.084
# Recall = 0.989 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.058
# F1 = 0.619 vs. 0.077
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.052
# F1 = 0.404 vs. 0.099
# Precision = 0.326 vs. 0.052
# Recall = 0.532 vs. 0.919
# Minibatch Loss= 0.015505
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.092
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.083
# F1 = 0.947 vs. 0.161
# Precision = 0.908 vs. 0.088
# Recall = 0.989 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.059
# F1 = 0.609 vs. 0.085
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.051
# F1 = 0.406 vs. 0.098
# Precision = 0.336 vs. 0.053
# Recall = 0.512 vs. 0.722
# Minibatch Loss= 0.013599
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.973 vs. 0.091
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.886 vs. 0.095
# F1 = 0.833 vs. 0.178
# Precision = 0.781 vs. 0.097
# Recall = 0.893 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.059
# F1 = 0.592 vs. 0.082
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.050
# F1 = 0.378 vs. 0.096
# Precision = 0.280 vs. 0.051
# Recall = 0.582 vs. 0.956
# Minibatch Loss= 0.034974
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.063
# F1 = 0.997 vs. 0.096
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.098
# F1 = 0.969 vs. 0.187
# Precision = 0.949 vs. 0.103
# Recall = 0.989 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.059
# F1 = 0.611 vs. 0.079
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.049
# F1 = 0.406 vs. 0.096
# Precision = 0.344 vs. 0.051
# Recall = 0.496 vs. 1.000
# Minibatch Loss= 0.013013
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.093
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.099
# F1 = 0.981 vs. 0.182
# Precision = 0.969 vs. 0.100
# Recall = 0.994 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.058
# F1 = 0.612 vs. 0.080
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.048
# F1 = 0.405 vs. 0.098
# Precision = 0.323 vs. 0.052
# Recall = 0.543 vs. 0.953
# Minibatch Loss= 0.010600
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.093
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.102
# F1 = 0.978 vs. 0.182
# Precision = 0.965 vs. 0.101
# Recall = 0.992 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.058
# F1 = 0.611 vs. 0.081
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.052
# F1 = 0.394 vs. 0.102
# Precision = 0.322 vs. 0.055
# Recall = 0.506 vs. 0.696
# Minibatch Loss= 0.010983
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.098
# F1 = 0.990 vs. 0.181
# Precision = 0.984 vs. 0.100
# Recall = 0.995 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.059
# F1 = 0.612 vs. 0.080
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.049
# F1 = 0.403 vs. 0.097
# Precision = 0.327 vs. 0.051
# Recall = 0.525 vs. 0.956
# Minibatch Loss= 0.008097
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.093
# F1 = 0.994 vs. 0.182
# Precision = 0.988 vs. 0.100
# Recall = 1.000 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.059
# F1 = 0.611 vs. 0.079
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.052
# F1 = 0.401 vs. 0.097
# Precision = 0.329 vs. 0.051
# Recall = 0.514 vs. 0.992
# Minibatch Loss= 0.006568
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.060
# F1 = 0.585 vs. 0.090
# Accuracy = 0.583 vs. 0.056
# CHANGE DETECTION
# AUC = 0.254 vs. 0.086
# F1 = 0.336 vs. 0.160
# Precision = 0.237 vs. 0.088
# Recall = 0.577 vs. 0.897
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.338 vs. 0.058
# F1 = 0.397 vs. 0.080
# Accuracy = 0.570 vs. 0.056
# CHANGE DETECTION
# AUC = 0.118 vs. 0.051
# F1 = 0.198 vs. 0.102
# Precision = 0.123 vs. 0.055
# Recall = 0.509 vs. 0.732
# Minibatch Loss= 0.393226
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.935 vs. 0.063
# F1 = 0.891 vs. 0.093
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.614 vs. 0.087
# F1 = 0.603 vs. 0.176
# Precision = 0.563 vs. 0.096
# Recall = 0.648 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.058
# F1 = 0.614 vs. 0.080
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.053
# F1 = 0.347 vs. 0.098
# Precision = 0.260 vs. 0.058
# Recall = 0.522 vs. 0.322
# Minibatch Loss= 0.107062
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.062
# F1 = 0.946 vs. 0.089
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.725 vs. 0.077
# F1 = 0.721 vs. 0.149
# Precision = 0.650 vs. 0.081
# Recall = 0.810 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.627 vs. 0.058
# F1 = 0.636 vs. 0.079
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.052
# F1 = 0.354 vs. 0.098
# Precision = 0.293 vs. 0.052
# Recall = 0.447 vs. 0.938
# Minibatch Loss= 0.047937
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.062
# F1 = 0.977 vs. 0.091
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.846 vs. 0.086
# F1 = 0.810 vs. 0.157
# Precision = 0.732 vs. 0.086
# Recall = 0.908 vs. 0.926
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.060
# F1 = 0.641 vs. 0.081
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.052
# F1 = 0.357 vs. 0.100
# Precision = 0.262 vs. 0.053
# Recall = 0.561 vs. 0.883
# Minibatch Loss= 0.033341
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.060
# F1 = 0.985 vs. 0.089
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.894 vs. 0.090
# F1 = 0.873 vs. 0.158
# Precision = 0.813 vs. 0.087
# Recall = 0.941 vs. 0.886
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.059
# F1 = 0.644 vs. 0.079
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.051
# F1 = 0.362 vs. 0.097
# Precision = 0.295 vs. 0.051
# Recall = 0.468 vs. 0.987
# Minibatch Loss= 0.024895
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.989 vs. 0.088
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.913 vs. 0.090
# F1 = 0.890 vs. 0.153
# Precision = 0.859 vs. 0.084
# Recall = 0.922 vs. 0.934
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.059
# F1 = 0.643 vs. 0.081
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.052
# F1 = 0.367 vs. 0.097
# Precision = 0.324 vs. 0.051
# Recall = 0.423 vs. 0.987
# Minibatch Loss= 0.022385
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.992 vs. 0.090
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.947 vs. 0.090
# F1 = 0.930 vs. 0.156
# Precision = 0.898 vs. 0.085
# Recall = 0.965 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.060
# F1 = 0.646 vs. 0.084
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.046
# F1 = 0.360 vs. 0.096
# Precision = 0.299 vs. 0.051
# Recall = 0.452 vs. 1.000
# Minibatch Loss= 0.019313
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.994 vs. 0.093
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.114
# F1 = 0.939 vs. 0.187
# Precision = 0.908 vs. 0.103
# Recall = 0.973 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.059
# F1 = 0.650 vs. 0.083
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.051
# F1 = 0.364 vs. 0.102
# Precision = 0.264 vs. 0.056
# Recall = 0.582 vs. 0.636
# Minibatch Loss= 0.019392
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.063
# F1 = 0.989 vs. 0.091
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.952 vs. 0.088
# F1 = 0.916 vs. 0.159
# Precision = 0.888 vs. 0.087
# Recall = 0.946 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.058
# F1 = 0.651 vs. 0.080
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.046
# F1 = 0.368 vs. 0.097
# Precision = 0.284 vs. 0.051
# Recall = 0.522 vs. 0.992
# Minibatch Loss= 0.018483
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.064
# F1 = 0.995 vs. 0.095
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.098
# F1 = 0.970 vs. 0.175
# Precision = 0.950 vs. 0.096
# Recall = 0.990 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.059
# F1 = 0.655 vs. 0.081
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.052
# F1 = 0.376 vs. 0.098
# Precision = 0.306 vs. 0.052
# Recall = 0.488 vs. 0.964
# Minibatch Loss= 0.014281
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.095
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.085
# F1 = 0.976 vs. 0.160
# Precision = 0.957 vs. 0.087
# Recall = 0.996 vs. 0.940
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.627 vs. 0.058
# F1 = 0.653 vs. 0.079
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.057
# F1 = 0.374 vs. 0.098
# Precision = 0.309 vs. 0.052
# Recall = 0.473 vs. 0.852
# Minibatch Loss= 0.010759
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.090
# F1 = 0.982 vs. 0.162
# Precision = 0.971 vs. 0.088
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.625 vs. 0.059
# F1 = 0.654 vs. 0.081
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.048
# F1 = 0.375 vs. 0.097
# Precision = 0.310 vs. 0.051
# Recall = 0.475 vs. 0.935
# Minibatch Loss= 0.009457
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 0.997 vs. 0.165
# Precision = 0.995 vs. 0.092
# Recall = 1.000 vs. 0.828
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.059
# F1 = 0.654 vs. 0.082
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.053
# F1 = 0.373 vs. 0.097
# Precision = 0.280 vs. 0.051
# Recall = 0.558 vs. 0.932
# Minibatch Loss= 0.006911
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.089
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.078
# F1 = 0.996 vs. 0.148
# Precision = 0.992 vs. 0.080
# Recall = 1.000 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.059
# F1 = 0.656 vs. 0.082
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.058
# F1 = 0.378 vs. 0.103
# Precision = 0.287 vs. 0.056
# Recall = 0.553 vs. 0.675
# Minibatch Loss= 0.006061
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 0.998 vs. 0.160
# Precision = 0.996 vs. 0.087
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.058
# F1 = 0.653 vs. 0.077
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.053
# F1 = 0.372 vs. 0.096
# Precision = 0.278 vs. 0.051
# Recall = 0.564 vs. 1.000
# Minibatch Loss= 0.005045
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.089
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.153
# Precision = 0.998 vs. 0.083
# Recall = 1.000 vs. 0.946
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.058
# F1 = 0.653 vs. 0.077
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.048
# F1 = 0.372 vs. 0.098
# Precision = 0.277 vs. 0.052
# Recall = 0.566 vs. 0.925
# Minibatch Loss= 0.005610
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.062
# F1 = 0.970 vs. 0.092
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.913 vs. 0.093
# F1 = 0.848 vs. 0.176
# Precision = 0.825 vs. 0.096
# Recall = 0.873 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.058
# F1 = 0.637 vs. 0.081
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.255 vs. 0.052
# F1 = 0.351 vs. 0.099
# Precision = 0.262 vs. 0.055
# Recall = 0.530 vs. 0.473
# Minibatch Loss= 0.040045
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.060
# F1 = 0.982 vs. 0.089
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.931 vs. 0.082
# F1 = 0.876 vs. 0.164
# Precision = 0.819 vs. 0.090
# Recall = 0.942 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.059
# F1 = 0.680 vs. 0.081
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.050
# F1 = 0.385 vs. 0.096
# Precision = 0.294 vs. 0.051
# Recall = 0.556 vs. 0.997
# Minibatch Loss= 0.023652
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.091
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.994 vs. 0.090
# F1 = 0.978 vs. 0.165
# Precision = 0.968 vs. 0.090
# Recall = 0.988 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.059
# F1 = 0.672 vs. 0.082
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.050
# F1 = 0.381 vs. 0.097
# Precision = 0.297 vs. 0.051
# Recall = 0.532 vs. 0.997
# Minibatch Loss= 0.009443
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.095
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.112
# F1 = 0.992 vs. 0.194
# Precision = 0.985 vs. 0.109
# Recall = 0.999 vs. 0.859
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.059
# F1 = 0.673 vs. 0.083
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.052
# F1 = 0.383 vs. 0.097
# Precision = 0.294 vs. 0.052
# Recall = 0.551 vs. 0.779
# Minibatch Loss= 0.007179
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.998 vs. 0.156
# Precision = 0.996 vs. 0.092
# Recall = 1.000 vs. 0.502
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.059
# F1 = 0.669 vs. 0.083
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.052
# F1 = 0.388 vs. 0.098
# Precision = 0.312 vs. 0.052
# Recall = 0.512 vs. 0.969
# Minibatch Loss= 0.004569
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 0.999 vs. 0.187
# Precision = 0.998 vs. 0.103
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.059
# F1 = 0.666 vs. 0.078
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.050
# F1 = 0.387 vs. 0.096
# Precision = 0.307 vs. 0.051
# Recall = 0.522 vs. 0.995
# Minibatch Loss= 0.005275
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.999 vs. 0.166
# Precision = 0.998 vs. 0.091
# Recall = 1.000 vs. 0.891
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.059
# F1 = 0.667 vs. 0.081
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.051
# F1 = 0.392 vs. 0.097
# Precision = 0.315 vs. 0.051
# Recall = 0.517 vs. 0.992
# Minibatch Loss= 0.003755
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.170
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.960
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.670 vs. 0.083
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.054
# F1 = 0.391 vs. 0.100
# Precision = 0.316 vs. 0.053
# Recall = 0.512 vs. 0.826
# Minibatch Loss= 0.003858
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.186
# Precision = 1.000 vs. 0.108
# Recall = 1.000 vs. 0.701
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.058
# F1 = 0.668 vs. 0.081
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.051
# F1 = 0.393 vs. 0.096
# Precision = 0.316 vs. 0.051
# Recall = 0.519 vs. 0.995
# Minibatch Loss= 0.003083
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.994 vs. 0.092
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.089
# F1 = 0.945 vs. 0.165
# Precision = 0.927 vs. 0.090
# Recall = 0.964 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.058
# F1 = 0.675 vs. 0.081
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.049
# F1 = 0.396 vs. 0.098
# Precision = 0.344 vs. 0.052
# Recall = 0.465 vs. 0.852
# Minibatch Loss= 0.013286
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.159
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.687 vs. 0.060
# F1 = 0.687 vs. 0.082
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.334 vs. 0.051
# F1 = 0.398 vs. 0.097
# Precision = 0.309 vs. 0.051
# Recall = 0.558 vs. 0.891
# Minibatch Loss= 0.003259
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.174
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.948
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.684 vs. 0.058
# F1 = 0.683 vs. 0.077
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.331 vs. 0.053
# F1 = 0.394 vs. 0.098
# Precision = 0.308 vs. 0.053
# Recall = 0.545 vs. 0.665
# Minibatch Loss= 0.002724
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.164
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.938
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.058
# F1 = 0.680 vs. 0.079
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.329 vs. 0.052
# F1 = 0.398 vs. 0.100
# Precision = 0.332 vs. 0.053
# Recall = 0.496 vs. 0.878
# Minibatch Loss= 0.002073
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.157
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.960
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.059
# F1 = 0.677 vs. 0.083
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.051
# F1 = 0.396 vs. 0.098
# Precision = 0.325 vs. 0.051
# Recall = 0.506 vs. 0.953
# Minibatch Loss= 0.001827
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.169
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.678 vs. 0.059
# F1 = 0.676 vs. 0.083
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.050
# F1 = 0.396 vs. 0.097
# Precision = 0.323 vs. 0.053
# Recall = 0.512 vs. 0.577
# Minibatch Loss= 0.001726
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.151
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.937
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.675 vs. 0.059
# F1 = 0.676 vs. 0.078
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.054
# F1 = 0.396 vs. 0.102
# Precision = 0.315 vs. 0.057
# Recall = 0.532 vs. 0.478
# Minibatch Loss= 0.001305
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.852
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.059
# F1 = 0.677 vs. 0.080
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.049
# F1 = 0.394 vs. 0.097
# Precision = 0.338 vs. 0.051
# Recall = 0.473 vs. 0.987
# Minibatch Loss= 0.001264
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.174
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.059
# F1 = 0.676 vs. 0.079
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.049
# F1 = 0.395 vs. 0.097
# Precision = 0.329 vs. 0.051
# Recall = 0.494 vs. 0.935
# Minibatch Loss= 0.001329
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.152
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.811
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.058
# F1 = 0.677 vs. 0.079
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.051
# F1 = 0.399 vs. 0.098
# Precision = 0.338 vs. 0.052
# Recall = 0.488 vs. 0.777
# Minibatch Loss= 0.000997
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.059
# F1 = 0.676 vs. 0.081
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.047
# F1 = 0.401 vs. 0.097
# Precision = 0.341 vs. 0.051
# Recall = 0.486 vs. 0.953
# Minibatch Loss= 0.001043
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.164
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.059
# F1 = 0.677 vs. 0.083
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.049
# F1 = 0.401 vs. 0.097
# Precision = 0.351 vs. 0.051
# Recall = 0.468 vs. 1.000
# Minibatch Loss= 0.000960
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.157
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.058
# F1 = 0.676 vs. 0.081
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.048
# F1 = 0.401 vs. 0.096
# Precision = 0.346 vs. 0.051
# Recall = 0.478 vs. 0.992
# Minibatch Loss= 0.000807
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.174
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.676 vs. 0.081
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.053
# F1 = 0.401 vs. 0.102
# Precision = 0.347 vs. 0.054
# Recall = 0.475 vs. 0.818
# Minibatch Loss= 0.000838
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.154
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.902
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.059
# F1 = 0.675 vs. 0.080
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.051
# F1 = 0.403 vs. 0.098
# Precision = 0.347 vs. 0.052
# Recall = 0.481 vs. 0.906
# Minibatch Loss= 0.000678
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.167
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.965
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.059
# F1 = 0.676 vs. 0.081
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.050
# F1 = 0.403 vs. 0.098
# Precision = 0.346 vs. 0.052
# Recall = 0.483 vs. 0.852
# Minibatch Loss= 0.000668
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.058
# F1 = 0.675 vs. 0.079
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.052
# F1 = 0.402 vs. 0.097
# Precision = 0.344 vs. 0.051
# Recall = 0.483 vs. 0.883
# Minibatch Loss= 0.000601
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.085
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.143
# Precision = 1.000 vs. 0.077
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.060
# F1 = 0.675 vs. 0.083
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.053
# F1 = 0.401 vs. 0.101
# Precision = 0.345 vs. 0.057
# Recall = 0.481 vs. 0.436
# Minibatch Loss= 0.000565
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.146
# Precision = 1.000 vs. 0.079
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.059
# F1 = 0.673 vs. 0.083
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.052
# F1 = 0.402 vs. 0.098
# Precision = 0.346 vs. 0.051
# Recall = 0.481 vs. 0.987
# Minibatch Loss= 0.000434
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.911
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.058
# F1 = 0.674 vs. 0.078
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.053
# F1 = 0.403 vs. 0.098
# Precision = 0.343 vs. 0.052
# Recall = 0.488 vs. 0.919
# Minibatch Loss= 0.000494
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.087
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.143
# Precision = 1.000 vs. 0.077
# Recall = 1.000 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.058
# F1 = 0.675 vs. 0.079
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.051
# F1 = 0.401 vs. 0.097
# Precision = 0.325 vs. 0.051
# Recall = 0.522 vs. 0.943
# Minibatch Loss= 0.000377
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.154
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.835
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.059
# F1 = 0.673 vs. 0.081
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.050
# F1 = 0.401 vs. 0.096
# Precision = 0.343 vs. 0.051
# Recall = 0.483 vs. 1.000
# Minibatch Loss= 0.000400
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.058
# F1 = 0.674 vs. 0.076
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.052
# F1 = 0.402 vs. 0.097
# Precision = 0.350 vs. 0.051
# Recall = 0.473 vs. 1.000
# Minibatch Loss= 0.000432
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.923 vs. 0.062
# F1 = 0.873 vs. 0.092
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.093
# F1 = 0.600 vs. 0.171
# Precision = 0.513 vs. 0.094
# Recall = 0.723 vs. 0.966
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.059
# F1 = 0.584 vs. 0.080
# Accuracy = 0.833 vs. 0.056
# CHANGE DETECTION
# AUC = 0.231 vs. 0.053
# F1 = 0.322 vs. 0.103
# Precision = 0.242 vs. 0.059
# Recall = 0.481 vs. 0.423
# Minibatch Loss= 0.102391
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.062
# F1 = 0.957 vs. 0.093
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.830 vs. 0.105
# F1 = 0.790 vs. 0.181
# Precision = 0.706 vs. 0.101
# Recall = 0.898 vs. 0.818
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.060
# F1 = 0.651 vs. 0.081
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.049
# F1 = 0.358 vs. 0.098
# Precision = 0.272 vs. 0.053
# Recall = 0.525 vs. 0.668
# Minibatch Loss= 0.043275
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.061
# F1 = 0.975 vs. 0.088
# Accuracy = 0.961 vs. 0.056
# CHANGE DETECTION
# AUC = 0.914 vs. 0.082
# F1 = 0.883 vs. 0.160
# Precision = 0.855 vs. 0.087
# Recall = 0.912 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.059
# F1 = 0.653 vs. 0.082
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.050
# F1 = 0.365 vs. 0.097
# Precision = 0.283 vs. 0.051
# Recall = 0.514 vs. 0.951
# Minibatch Loss= 0.028986
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.060
# F1 = 0.981 vs. 0.086
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.929 vs. 0.074
# F1 = 0.895 vs. 0.139
# Precision = 0.848 vs. 0.075
# Recall = 0.947 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.059
# F1 = 0.649 vs. 0.079
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.057
# F1 = 0.363 vs. 0.101
# Precision = 0.288 vs. 0.059
# Recall = 0.491 vs. 0.345
# Minibatch Loss= 0.025324
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.062
# F1 = 0.992 vs. 0.093
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.085
# F1 = 0.947 vs. 0.152
# Precision = 0.916 vs. 0.082
# Recall = 0.979 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.059
# F1 = 0.656 vs. 0.081
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.052
# F1 = 0.363 vs. 0.097
# Precision = 0.296 vs. 0.051
# Recall = 0.470 vs. 0.992
# Minibatch Loss= 0.014125
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.990 vs. 0.088
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.976 vs. 0.084
# F1 = 0.961 vs. 0.157
# Precision = 0.937 vs. 0.085
# Recall = 0.987 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.659 vs. 0.083
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.054
# F1 = 0.361 vs. 0.099
# Precision = 0.283 vs. 0.055
# Recall = 0.496 vs. 0.551
# Minibatch Loss= 0.013993
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.093
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.081
# F1 = 0.978 vs. 0.155
# Precision = 0.964 vs. 0.086
# Recall = 0.993 vs. 0.738
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.663 vs. 0.079
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.054
# F1 = 0.363 vs. 0.099
# Precision = 0.293 vs. 0.053
# Recall = 0.478 vs. 0.849
# Minibatch Loss= 0.010776
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.991 vs. 0.092
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.088
# F1 = 0.949 vs. 0.166
# Precision = 0.932 vs. 0.091
# Recall = 0.967 vs. 0.929
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.059
# F1 = 0.661 vs. 0.079
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.048
# F1 = 0.368 vs. 0.097
# Precision = 0.293 vs. 0.051
# Recall = 0.494 vs. 0.932
# Minibatch Loss= 0.016345
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.996 vs. 0.093
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.106
# F1 = 0.985 vs. 0.190
# Precision = 0.982 vs. 0.105
# Recall = 0.988 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.661 vs. 0.081
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.052
# F1 = 0.367 vs. 0.097
# Precision = 0.346 vs. 0.051
# Recall = 0.392 vs. 0.982
# Minibatch Loss= 0.010070
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 0.996 vs. 0.167
# Precision = 0.992 vs. 0.091
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.058
# F1 = 0.661 vs. 0.081
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.052
# F1 = 0.373 vs. 0.097
# Precision = 0.314 vs. 0.051
# Recall = 0.460 vs. 0.977
# Minibatch Loss= 0.007543
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.998 vs. 0.093
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 0.995 vs. 0.175
# Precision = 0.997 vs. 0.097
# Recall = 0.993 vs. 0.900
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.058
# F1 = 0.659 vs. 0.078
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.054
# F1 = 0.379 vs. 0.098
# Precision = 0.316 vs. 0.051
# Recall = 0.473 vs. 0.979
# Minibatch Loss= 0.006518
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.097
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 0.997 vs. 0.178
# Precision = 0.994 vs. 0.098
# Recall = 1.000 vs. 0.942
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.058
# F1 = 0.658 vs. 0.079
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.047
# F1 = 0.381 vs. 0.097
# Precision = 0.334 vs. 0.051
# Recall = 0.444 vs. 0.836
# Minibatch Loss= 0.005543
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 0.998 vs. 0.153
# Precision = 0.996 vs. 0.083
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.061
# F1 = 0.657 vs. 0.084
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.053
# F1 = 0.380 vs. 0.099
# Precision = 0.337 vs. 0.052
# Recall = 0.436 vs. 0.894
# Minibatch Loss= 0.004884
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.087
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.149
# Precision = 0.998 vs. 0.081
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.059
# F1 = 0.656 vs. 0.081
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.055
# F1 = 0.381 vs. 0.101
# Precision = 0.331 vs. 0.058
# Recall = 0.449 vs. 0.369
# Minibatch Loss= 0.004026
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.999 vs. 0.088
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.999 vs. 0.151
# Precision = 0.998 vs. 0.082
# Recall = 1.000 vs. 0.953
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.058
# F1 = 0.657 vs. 0.081
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.052
# F1 = 0.383 vs. 0.099
# Precision = 0.364 vs. 0.057
# Recall = 0.405 vs. 0.371
# Minibatch Loss= 0.003138
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 0.999 vs. 0.171
# Precision = 1.000 vs. 0.094
# Recall = 0.998 vs. 0.968
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.062
# F1 = 0.657 vs. 0.084
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.048
# F1 = 0.379 vs. 0.098
# Precision = 0.307 vs. 0.052
# Recall = 0.496 vs. 0.953
# Minibatch Loss= 0.003372
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.096
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.190
# Precision = 1.000 vs. 0.105
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.663 vs. 0.059
# F1 = 0.655 vs. 0.082
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.052
# F1 = 0.380 vs. 0.101
# Precision = 0.339 vs. 0.054
# Recall = 0.431 vs. 0.725
# Minibatch Loss= 0.003684
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.060
# F1 = 0.656 vs. 0.082
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.057
# F1 = 0.384 vs. 0.102
# Precision = 0.348 vs. 0.054
# Recall = 0.429 vs. 0.756
# Minibatch Loss= 0.002525
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.177
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.058
# F1 = 0.655 vs. 0.079
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.051
# F1 = 0.386 vs. 0.099
# Precision = 0.353 vs. 0.054
# Recall = 0.426 vs. 0.621
# Minibatch Loss= 0.002716
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.058
# F1 = 0.654 vs. 0.080
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.052
# F1 = 0.384 vs. 0.099
# Precision = 0.355 vs. 0.054
# Recall = 0.418 vs. 0.644
# Minibatch Loss= 0.002446
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.947
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.058
# F1 = 0.654 vs. 0.081
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.051
# F1 = 0.386 vs. 0.098
# Precision = 0.347 vs. 0.052
# Recall = 0.434 vs. 0.971
# Minibatch Loss= 0.001995
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.147
# Precision = 1.000 vs. 0.079
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.060
# F1 = 0.656 vs. 0.083
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.051
# F1 = 0.383 vs. 0.100
# Precision = 0.357 vs. 0.054
# Recall = 0.413 vs. 0.758
# Minibatch Loss= 0.001848
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.174
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.962
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.659 vs. 0.059
# F1 = 0.654 vs. 0.081
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.051
# F1 = 0.384 vs. 0.097
# Precision = 0.344 vs. 0.051
# Recall = 0.434 vs. 0.857
# Minibatch Loss= 0.001495
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.953 vs. 0.061
# F1 = 0.902 vs. 0.090
# Accuracy = 0.835 vs. 0.056
# CHANGE DETECTION
# AUC = 0.699 vs. 0.084
# F1 = 0.661 vs. 0.157
# Precision = 0.628 vs. 0.085
# Recall = 0.697 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.060
# F1 = 0.581 vs. 0.085
# Accuracy = 0.761 vs. 0.056
# CHANGE DETECTION
# AUC = 0.199 vs. 0.054
# F1 = 0.268 vs. 0.098
# Precision = 0.235 vs. 0.052
# Recall = 0.312 vs. 0.917
# Minibatch Loss= 0.149998
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.888 vs. 0.062
# F1 = 0.837 vs. 0.092
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.531 vs. 0.094
# F1 = 0.569 vs. 0.167
# Precision = 0.506 vs. 0.092
# Recall = 0.649 vs. 0.903
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.059
# F1 = 0.568 vs. 0.078
# Accuracy = 0.822 vs. 0.056
# CHANGE DETECTION
# AUC = 0.211 vs. 0.053
# F1 = 0.292 vs. 0.100
# Precision = 0.210 vs. 0.057
# Recall = 0.478 vs. 0.444
# Minibatch Loss= 0.135068
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.060
# F1 = 0.107 vs. 0.092
# Accuracy = 0.048 vs. 0.056
# CHANGE DETECTION
# AUC = 0.091 vs. 0.110
# F1 = 0.177 vs. 0.178
# Precision = 0.097 vs. 0.106
# Recall = 1.000 vs. 0.561
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.059
# F1 = 0.095 vs. 0.079
# Accuracy = 0.018 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.056
# F1 = 0.100 vs. 0.101
# Precision = 0.065 vs. 0.056
# Recall = 0.218 vs. 0.525
# Minibatch Loss= 1.379610
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.060
# F1 = 0.099 vs. 0.089
# Accuracy = 0.083 vs. 0.056
# CHANGE DETECTION
# AUC = 0.089 vs. 0.086
# F1 = 0.176 vs. 0.157
# Precision = 0.097 vs. 0.085
# Recall = 0.958 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.091 vs. 0.084
# Accuracy = 0.139 vs. 0.056
# CHANGE DETECTION
# AUC = 0.047 vs. 0.048
# F1 = 0.105 vs. 0.098
# Precision = 0.055 vs. 0.052
# Recall = 0.984 vs. 0.800
# Minibatch Loss= 1.315519
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.061
# F1 = 0.114 vs. 0.090
# Accuracy = 0.248 vs. 0.056
# CHANGE DETECTION
# AUC = 0.105 vs. 0.098
# F1 = 0.198 vs. 0.179
# Precision = 0.111 vs. 0.099
# Recall = 0.949 vs. 0.950
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.060
# F1 = 0.084 vs. 0.082
# Accuracy = 0.276 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.053
# F1 = 0.107 vs. 0.099
# Precision = 0.057 vs. 0.056
# Recall = 0.943 vs. 0.457
# Minibatch Loss= 1.387271
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.060
# F1 = 0.107 vs. 0.093
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.106 vs. 0.106
# F1 = 0.200 vs. 0.176
# Precision = 0.117 vs. 0.098
# Recall = 0.664 vs. 0.868
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.104 vs. 0.079
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.053
# F1 = 0.100 vs. 0.097
# Precision = 0.055 vs. 0.053
# Recall = 0.571 vs. 0.616
# Minibatch Loss= 1.349871
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.061
# F1 = 0.112 vs. 0.093
# Accuracy = 0.045 vs. 0.056
# CHANGE DETECTION
# AUC = 0.114 vs. 0.103
# F1 = 0.195 vs. 0.178
# Precision = 0.109 vs. 0.100
# Recall = 0.918 vs. 0.810
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.104 vs. 0.079
# Accuracy = 0.056 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.054
# F1 = 0.100 vs. 0.100
# Precision = 0.055 vs. 0.058
# Recall = 0.569 vs. 0.364
# Minibatch Loss= 1.359433
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.060
# F1 = 0.118 vs. 0.092
# Accuracy = 0.015 vs. 0.056
# CHANGE DETECTION
# AUC = 0.103 vs. 0.090
# F1 = 0.194 vs. 0.170
# Precision = 0.113 vs. 0.095
# Recall = 0.700 vs. 0.812
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.106 vs. 0.084
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.048
# F1 = 0.099 vs. 0.097
# Precision = 0.052 vs. 0.051
# Recall = 1.000 vs. 0.979
# Minibatch Loss= 1.308986
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.060
# F1 = 0.103 vs. 0.088
# Accuracy = 0.021 vs. 0.056
# CHANGE DETECTION
# AUC = 0.084 vs. 0.078
# F1 = 0.159 vs. 0.149
# Precision = 0.087 vs. 0.081
# Recall = 0.969 vs. 0.888
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.104 vs. 0.081
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.057 vs. 0.051
# Recall = 0.527 vs. 0.992
# Minibatch Loss= 1.183190
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.061
# F1 = 0.133 vs. 0.093
# Accuracy = 0.072 vs. 0.056
# CHANGE DETECTION
# AUC = 0.133 vs. 0.109
# F1 = 0.221 vs. 0.191
# Precision = 0.140 vs. 0.107
# Recall = 0.525 vs. 0.928
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.058
# F1 = 0.117 vs. 0.080
# Accuracy = 0.042 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.049
# F1 = 0.102 vs. 0.097
# Precision = 0.056 vs. 0.051
# Recall = 0.535 vs. 0.964
# Minibatch Loss= 1.256998
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.060
# F1 = 0.131 vs. 0.091
# Accuracy = 0.071 vs. 0.056
# CHANGE DETECTION
# AUC = 0.102 vs. 0.092
# F1 = 0.181 vs. 0.172
# Precision = 0.102 vs. 0.094
# Recall = 0.792 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.059
# F1 = 0.118 vs. 0.080
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.045
# F1 = 0.101 vs. 0.096
# Precision = 0.056 vs. 0.051
# Recall = 0.519 vs. 1.000
# Minibatch Loss= 1.251817
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.076 vs. 0.062
# F1 = 0.134 vs. 0.092
# Accuracy = 0.129 vs. 0.056
# CHANGE DETECTION
# AUC = 0.108 vs. 0.085
# F1 = 0.190 vs. 0.163
# Precision = 0.105 vs. 0.089
# Recall = 0.977 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.058
# F1 = 0.109 vs. 0.081
# Accuracy = 0.041 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.055
# F1 = 0.104 vs. 0.099
# Precision = 0.058 vs. 0.052
# Recall = 0.535 vs. 0.951
# Minibatch Loss= 1.212244
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.062
# F1 = 0.128 vs. 0.093
# Accuracy = 0.118 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.090
# F1 = 0.182 vs. 0.171
# Precision = 0.101 vs. 0.094
# Recall = 0.975 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.060
# F1 = 0.127 vs. 0.085
# Accuracy = 0.073 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.103 vs. 0.097
# Precision = 0.057 vs. 0.051
# Recall = 0.577 vs. 0.995
# Minibatch Loss= 1.264631
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.060
# F1 = 0.117 vs. 0.087
# Accuracy = 0.108 vs. 0.056
# CHANGE DETECTION
# AUC = 0.104 vs. 0.085
# F1 = 0.185 vs. 0.164
# Precision = 0.106 vs. 0.090
# Recall = 0.738 vs. 0.946
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.060
# F1 = 0.121 vs. 0.083
# Accuracy = 0.074 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.054
# F1 = 0.102 vs. 0.097
# Precision = 0.056 vs. 0.051
# Recall = 0.535 vs. 0.862
# Minibatch Loss= 1.211836
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.062
# F1 = 0.120 vs. 0.092
# Accuracy = 0.041 vs. 0.056
# CHANGE DETECTION
# AUC = 0.107 vs. 0.098
# F1 = 0.187 vs. 0.170
# Precision = 0.111 vs. 0.093
# Recall = 0.603 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.058
# F1 = 0.119 vs. 0.082
# Accuracy = 0.035 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.049
# F1 = 0.101 vs. 0.101
# Precision = 0.056 vs. 0.054
# Recall = 0.519 vs. 0.878
# Minibatch Loss= 1.305809
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.062
# F1 = 0.132 vs. 0.093
# Accuracy = 0.064 vs. 0.056
# CHANGE DETECTION
# AUC = 0.096 vs. 0.086
# F1 = 0.178 vs. 0.161
# Precision = 0.098 vs. 0.087
# Recall = 0.928 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.059
# F1 = 0.124 vs. 0.083
# Accuracy = 0.035 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.104 vs. 0.096
# Precision = 0.058 vs. 0.051
# Recall = 0.535 vs. 1.000
# Minibatch Loss= 1.229956
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.062
# F1 = 0.126 vs. 0.091
# Accuracy = 0.076 vs. 0.056
# CHANGE DETECTION
# AUC = 0.104 vs. 0.103
# F1 = 0.182 vs. 0.175
# Precision = 0.101 vs. 0.104
# Recall = 0.946 vs. 0.562
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.059
# F1 = 0.114 vs. 0.083
# Accuracy = 0.055 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.104 vs. 0.096
# Precision = 0.058 vs. 0.051
# Recall = 0.535 vs. 0.997
# Minibatch Loss= 1.295382
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.060
# F1 = 0.124 vs. 0.091
# Accuracy = 0.156 vs. 0.056
# CHANGE DETECTION
# AUC = 0.096 vs. 0.084
# F1 = 0.178 vs. 0.161
# Precision = 0.098 vs. 0.087
# Recall = 0.975 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.113 vs. 0.079
# Accuracy = 0.083 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.052
# F1 = 0.105 vs. 0.101
# Precision = 0.058 vs. 0.054
# Recall = 0.532 vs. 0.800
# Minibatch Loss= 1.263515
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.078 vs. 0.063
# F1 = 0.136 vs. 0.092
# Accuracy = 0.135 vs. 0.056
# CHANGE DETECTION
# AUC = 0.098 vs. 0.099
# F1 = 0.186 vs. 0.176
# Precision = 0.103 vs. 0.097
# Recall = 0.972 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.113 vs. 0.080
# Accuracy = 0.083 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.052
# F1 = 0.101 vs. 0.097
# Precision = 0.056 vs. 0.051
# Recall = 0.519 vs. 0.992
# Minibatch Loss= 1.263563
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.061
# F1 = 0.121 vs. 0.088
# Accuracy = 0.099 vs. 0.056
# CHANGE DETECTION
# AUC = 0.101 vs. 0.089
# F1 = 0.182 vs. 0.166
# Precision = 0.106 vs. 0.091
# Recall = 0.637 vs. 0.884
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.058
# F1 = 0.116 vs. 0.078
# Accuracy = 0.043 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.052
# F1 = 0.104 vs. 0.097
# Precision = 0.057 vs. 0.051
# Recall = 0.538 vs. 0.951
# Minibatch Loss= 1.239107
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.062
# F1 = 0.122 vs. 0.092
# Accuracy = 0.104 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.097
# F1 = 0.194 vs. 0.178
# Precision = 0.108 vs. 0.098
# Recall = 0.914 vs. 0.969
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.059
# F1 = 0.124 vs. 0.082
# Accuracy = 0.053 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.101 vs. 0.099
# Precision = 0.056 vs. 0.052
# Recall = 0.571 vs. 0.945
# Minibatch Loss= 1.333579
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.062
# F1 = 0.128 vs. 0.090
# Accuracy = 0.167 vs. 0.056
# CHANGE DETECTION
# AUC = 0.098 vs. 0.084
# F1 = 0.183 vs. 0.163
# Precision = 0.102 vs. 0.089
# Recall = 0.889 vs. 0.940
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.059
# F1 = 0.116 vs. 0.079
# Accuracy = 0.081 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.047
# F1 = 0.101 vs. 0.097
# Precision = 0.056 vs. 0.051
# Recall = 0.571 vs. 0.990
# Minibatch Loss= 1.226708
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.061
# F1 = 0.129 vs. 0.091
# Accuracy = 0.080 vs. 0.056
# CHANGE DETECTION
# AUC = 0.110 vs. 0.076
# F1 = 0.177 vs. 0.149
# Precision = 0.107 vs. 0.080
# Recall = 0.520 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.109 vs. 0.082
# Accuracy = 0.048 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.050
# F1 = 0.102 vs. 0.097
# Precision = 0.056 vs. 0.052
# Recall = 0.532 vs. 0.829
# Minibatch Loss= 1.220204
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.083 vs. 0.061
# F1 = 0.155 vs. 0.087
# Accuracy = 0.126 vs. 0.056
# CHANGE DETECTION
# AUC = 0.093 vs. 0.083
# F1 = 0.162 vs. 0.154
# Precision = 0.093 vs. 0.085
# Recall = 0.634 vs. 0.825
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.106 vs. 0.080
# Accuracy = 0.073 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.052
# F1 = 0.104 vs. 0.099
# Precision = 0.057 vs. 0.053
# Recall = 0.538 vs. 0.873
# Minibatch Loss= 1.142680
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.063
# F1 = 0.119 vs. 0.091
# Accuracy = 0.087 vs. 0.056
# CHANGE DETECTION
# AUC = 0.105 vs. 0.094
# F1 = 0.185 vs. 0.171
# Precision = 0.102 vs. 0.094
# Recall = 0.973 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.059
# F1 = 0.126 vs. 0.082
# Accuracy = 0.048 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.055
# F1 = 0.104 vs. 0.098
# Precision = 0.058 vs. 0.055
# Recall = 0.538 vs. 0.473
# Minibatch Loss= 1.280242
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.059
# F1 = 0.128 vs. 0.088
# Accuracy = 0.146 vs. 0.056
# CHANGE DETECTION
# AUC = 0.111 vs. 0.093
# F1 = 0.189 vs. 0.161
# Precision = 0.111 vs. 0.088
# Recall = 0.627 vs. 0.966
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.058
# F1 = 0.112 vs. 0.077
# Accuracy = 0.043 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.054
# F1 = 0.103 vs. 0.102
# Precision = 0.057 vs. 0.055
# Recall = 0.527 vs. 0.740
# Minibatch Loss= 1.170113
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.062
# F1 = 0.129 vs. 0.091
# Accuracy = 0.119 vs. 0.056
# CHANGE DETECTION
# AUC = 0.103 vs. 0.093
# F1 = 0.185 vs. 0.165
# Precision = 0.118 vs. 0.090
# Recall = 0.418 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.059
# F1 = 0.124 vs. 0.081
# Accuracy = 0.081 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.052
# F1 = 0.104 vs. 0.097
# Precision = 0.058 vs. 0.051
# Recall = 0.535 vs. 0.992
# Minibatch Loss= 1.193212
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.063
# F1 = 0.122 vs. 0.098
# Accuracy = 0.063 vs. 0.056
# CHANGE DETECTION
# AUC = 0.118 vs. 0.105
# F1 = 0.204 vs. 0.198
# Precision = 0.114 vs. 0.110
# Recall = 0.983 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.059
# F1 = 0.118 vs. 0.081
# Accuracy = 0.050 vs. 0.056
# CHANGE DETECTION
# AUC = 0.052 vs. 0.052
# F1 = 0.104 vs. 0.099
# Precision = 0.058 vs. 0.053
# Recall = 0.532 vs. 0.894
# Minibatch Loss= 1.384956
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.061
# F1 = 0.134 vs. 0.092
# Accuracy = 0.109 vs. 0.056
# CHANGE DETECTION
# AUC = 0.112 vs. 0.102
# F1 = 0.200 vs. 0.177
# Precision = 0.114 vs. 0.097
# Recall = 0.853 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.058
# F1 = 0.118 vs. 0.081
# Accuracy = 0.043 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.057
# F1 = 0.104 vs. 0.099
# Precision = 0.057 vs. 0.052
# Recall = 0.538 vs. 0.917
# Minibatch Loss= 1.285912
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.062
# F1 = 0.112 vs. 0.093
# Accuracy = 0.097 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.104
# F1 = 0.197 vs. 0.190
# Precision = 0.112 vs. 0.105
# Recall = 0.824 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.058
# F1 = 0.118 vs. 0.077
# Accuracy = 0.082 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.101 vs. 0.097
# Precision = 0.056 vs. 0.051
# Recall = 0.571 vs. 0.992
# Minibatch Loss= 1.354815
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.062
# F1 = 0.119 vs. 0.094
# Accuracy = 0.131 vs. 0.056
# CHANGE DETECTION
# AUC = 0.097 vs. 0.095
# F1 = 0.170 vs. 0.162
# Precision = 0.093 vs. 0.097
# Recall = 0.987 vs. 0.485
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.059
# F1 = 0.113 vs. 0.080
# Accuracy = 0.083 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.050
# F1 = 0.104 vs. 0.098
# Precision = 0.058 vs. 0.052
# Recall = 0.535 vs. 0.945
# Minibatch Loss= 1.197786
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.061
# F1 = 0.102 vs. 0.091
# Accuracy = 0.112 vs. 0.056
# CHANGE DETECTION
# AUC = 0.090 vs. 0.094
# F1 = 0.180 vs. 0.172
# Precision = 0.099 vs. 0.095
# Recall = 0.986 vs. 0.907
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.111 vs. 0.082
# Accuracy = 0.082 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.054
# F1 = 0.102 vs. 0.099
# Precision = 0.056 vs. 0.052
# Recall = 0.532 vs. 0.844
# Minibatch Loss= 1.257621
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.060
# F1 = 0.118 vs. 0.086
# Accuracy = 0.137 vs. 0.056
# CHANGE DETECTION
# AUC = 0.093 vs. 0.074
# F1 = 0.164 vs. 0.143
# Precision = 0.093 vs. 0.077
# Recall = 0.708 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.058
# F1 = 0.125 vs. 0.078
# Accuracy = 0.050 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.103 vs. 0.098
# Precision = 0.057 vs. 0.052
# Recall = 0.527 vs. 0.865
# Minibatch Loss= 1.102810
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.062
# F1 = 0.122 vs. 0.092
# Accuracy = 0.096 vs. 0.056
# CHANGE DETECTION
# AUC = 0.103 vs. 0.087
# F1 = 0.185 vs. 0.168
# Precision = 0.102 vs. 0.091
# Recall = 0.988 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.059
# F1 = 0.116 vs. 0.080
# Accuracy = 0.049 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.060
# F1 = 0.102 vs. 0.099
# Precision = 0.056 vs. 0.052
# Recall = 0.532 vs. 0.904
# Minibatch Loss= 1.235239
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.076 vs. 0.059
# F1 = 0.135 vs. 0.092
# Accuracy = 0.122 vs. 0.056
# CHANGE DETECTION
# AUC = 0.105 vs. 0.092
# F1 = 0.190 vs. 0.170
# Precision = 0.105 vs. 0.093
# Recall = 0.980 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.111 vs. 0.079
# Accuracy = 0.049 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.049
# F1 = 0.102 vs. 0.096
# Precision = 0.056 vs. 0.051
# Recall = 0.532 vs. 1.000
# Minibatch Loss= 1.240917
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.061
# F1 = 0.128 vs. 0.091
# Accuracy = 0.087 vs. 0.056
# CHANGE DETECTION
# AUC = 0.111 vs. 0.089
# F1 = 0.190 vs. 0.171
# Precision = 0.109 vs. 0.094
# Recall = 0.756 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.058
# F1 = 0.123 vs. 0.080
# Accuracy = 0.049 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.049
# F1 = 0.102 vs. 0.099
# Precision = 0.056 vs. 0.052
# Recall = 0.532 vs. 0.977
# Minibatch Loss= 1.262742
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.079 vs. 0.061
# F1 = 0.132 vs. 0.089
# Accuracy = 0.150 vs. 0.056
# CHANGE DETECTION
# AUC = 0.104 vs. 0.092
# F1 = 0.180 vs. 0.164
# Precision = 0.105 vs. 0.090
# Recall = 0.636 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.116 vs. 0.082
# Accuracy = 0.077 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.050
# F1 = 0.102 vs. 0.096
# Precision = 0.056 vs. 0.051
# Recall = 0.571 vs. 1.000
# Minibatch Loss= 1.170274
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.061
# F1 = 0.136 vs. 0.092
# Accuracy = 0.113 vs. 0.056
# CHANGE DETECTION
# AUC = 0.122 vs. 0.090
# F1 = 0.193 vs. 0.168
# Precision = 0.113 vs. 0.092
# Recall = 0.656 vs. 0.911
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.108 vs. 0.079
# Accuracy = 0.049 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.050
# F1 = 0.101 vs. 0.096
# Precision = 0.056 vs. 0.051
# Recall = 0.571 vs. 1.000
# Minibatch Loss= 1.240902
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.062
# F1 = 0.107 vs. 0.094
# Accuracy = 0.096 vs. 0.056
# CHANGE DETECTION
# AUC = 0.090 vs. 0.092
# F1 = 0.180 vs. 0.169
# Precision = 0.099 vs. 0.092
# Recall = 0.985 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.059
# F1 = 0.119 vs. 0.080
# Accuracy = 0.049 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.101 vs. 0.097
# Precision = 0.055 vs. 0.051
# Recall = 0.569 vs. 0.979
# Minibatch Loss= 1.278977
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.062
# F1 = 0.123 vs. 0.092
# Accuracy = 0.073 vs. 0.056
# CHANGE DETECTION
# AUC = 0.096 vs. 0.091
# F1 = 0.187 vs. 0.172
# Precision = 0.105 vs. 0.095
# Recall = 0.855 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.109 vs. 0.083
# Accuracy = 0.049 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.049
# F1 = 0.104 vs. 0.098
# Precision = 0.058 vs. 0.052
# Recall = 0.535 vs. 0.945
# Minibatch Loss= 1.308012
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.060
# F1 = 0.113 vs. 0.090
# Accuracy = 0.067 vs. 0.056
# CHANGE DETECTION
# AUC = 0.080 vs. 0.085
# F1 = 0.159 vs. 0.158
# Precision = 0.087 vs. 0.087
# Recall = 0.989 vs. 0.870
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.059
# F1 = 0.116 vs. 0.081
# Accuracy = 0.045 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.049
# F1 = 0.104 vs. 0.096
# Precision = 0.057 vs. 0.051
# Recall = 0.538 vs. 1.000
# Minibatch Loss= 1.178105
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.084 vs. 0.061
# F1 = 0.148 vs. 0.088
# Accuracy = 0.140 vs. 0.056
# CHANGE DETECTION
# AUC = 0.121 vs. 0.092
# F1 = 0.202 vs. 0.171
# Precision = 0.119 vs. 0.095
# Recall = 0.663 vs. 0.814
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.059
# F1 = 0.119 vs. 0.082
# Accuracy = 0.078 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.104 vs. 0.097
# Precision = 0.058 vs. 0.051
# Recall = 0.532 vs. 0.995
# Minibatch Loss= 1.206032
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.059
# F1 = 0.109 vs. 0.087
# Accuracy = 0.101 vs. 0.056
# CHANGE DETECTION
# AUC = 0.076 vs. 0.067
# F1 = 0.147 vs. 0.127
# Precision = 0.087 vs. 0.068
# Recall = 0.477 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.058
# F1 = 0.112 vs. 0.080
# Accuracy = 0.043 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.102 vs. 0.098
# Precision = 0.056 vs. 0.052
# Recall = 0.571 vs. 0.839
# Minibatch Loss= 1.090690
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/WCNNRNN_Wmultitask_16_opp_new/WCNNRNN_Wmultitask_16_opp_new-20000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.058
# F1 = 0.116 vs. 0.077
# Accuracy = 0.075 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.051
# F1 = 0.104 vs. 0.096
# Precision = 0.058 vs. 0.051
# Recall = 0.535 vs. 1.000

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2
