# %%
# useing this variable for saving models and summaries
exp_name = "DWN_Wmultitask_32_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
train_data.shape
# Out:
# (691, 1024, 77)

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.28595522,  42.44204322,  42.96023857,  45.06666667,
#         44.49794239,  34.32268371,  35.42833608,  50.54312354,
#         54.97974684,  62.17714286,  69.87179487,  66.41463415,
#         71.02605863,  57.96533333,  57.4973545 ,  39.35036496,
#         12.09177028,  47.81236203,   4.77487595])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet = True,
                                 trainable_conv = True,
                                 trainable_last = True,
                                 variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.065
# F1 = 0.106 vs. 0.098
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.160 vs. 0.150
# F1 = 0.267 vs. 0.266
# Precision = 0.154 vs. 0.153
# Recall = 0.986 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.063
# F1 = 0.098 vs. 0.088
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.103 vs. 0.101
# F1 = 0.181 vs. 0.182
# Precision = 0.100 vs. 0.100
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 1.326263
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.540 vs. 0.069
# F1 = 0.580 vs. 0.105
# Accuracy = 0.582 vs. 0.056
# CHANGE DETECTION
# AUC = 0.370 vs. 0.191
# F1 = 0.468 vs. 0.293
# Precision = 0.351 vs. 0.173
# Recall = 0.700 vs. 0.962
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.323 vs. 0.062
# F1 = 0.392 vs. 0.092
# Accuracy = 0.545 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.103
# F1 = 0.357 vs. 0.181
# Precision = 0.262 vs. 0.100
# Recall = 0.557 vs. 1.000
# Minibatch Loss= 0.383970
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.068
# F1 = 0.685 vs. 0.095
# Accuracy = 0.690 vs. 0.056
# CHANGE DETECTION
# AUC = 0.435 vs. 0.175
# F1 = 0.492 vs. 0.288
# Precision = 0.383 vs. 0.168
# Recall = 0.688 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.425 vs. 0.062
# F1 = 0.498 vs. 0.089
# Accuracy = 0.648 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.105
# F1 = 0.354 vs. 0.188
# Precision = 0.297 vs. 0.107
# Recall = 0.438 vs. 0.770
# Minibatch Loss= 0.249246
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.727 vs. 0.068
# F1 = 0.725 vs. 0.102
# Accuracy = 0.739 vs. 0.056
# CHANGE DETECTION
# AUC = 0.466 vs. 0.169
# F1 = 0.522 vs. 0.272
# Precision = 0.402 vs. 0.163
# Recall = 0.744 vs. 0.822
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.430 vs. 0.061
# F1 = 0.501 vs. 0.082
# Accuracy = 0.753 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.099
# F1 = 0.359 vs. 0.182
# Precision = 0.307 vs. 0.101
# Recall = 0.433 vs. 0.942
# Minibatch Loss= 0.180341
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.796 vs. 0.068
# F1 = 0.793 vs. 0.107
# Accuracy = 0.843 vs. 0.056
# CHANGE DETECTION
# AUC = 0.448 vs. 0.163
# F1 = 0.506 vs. 0.278
# Precision = 0.378 vs. 0.161
# Recall = 0.766 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.430 vs. 0.063
# F1 = 0.501 vs. 0.098
# Accuracy = 0.812 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.115
# F1 = 0.364 vs. 0.183
# Precision = 0.250 vs. 0.101
# Recall = 0.668 vs. 0.987
# Minibatch Loss= 0.156838
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.803 vs. 0.067
# F1 = 0.806 vs. 0.103
# Accuracy = 0.821 vs. 0.056
# CHANGE DETECTION
# AUC = 0.526 vs. 0.179
# F1 = 0.576 vs. 0.294
# Precision = 0.457 vs. 0.173
# Recall = 0.779 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.431 vs. 0.063
# F1 = 0.503 vs. 0.088
# Accuracy = 0.799 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.098
# F1 = 0.382 vs. 0.182
# Precision = 0.281 vs. 0.100
# Recall = 0.596 vs. 0.992
# Minibatch Loss= 0.135927
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.838 vs. 0.066
# F1 = 0.839 vs. 0.101
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.499 vs. 0.170
# F1 = 0.562 vs. 0.285
# Precision = 0.428 vs. 0.167
# Recall = 0.815 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.434 vs. 0.064
# F1 = 0.506 vs. 0.091
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.095
# F1 = 0.378 vs. 0.182
# Precision = 0.276 vs. 0.100
# Recall = 0.596 vs. 0.997
# Minibatch Loss= 0.123580
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.874 vs. 0.067
# F1 = 0.864 vs. 0.099
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.468 vs. 0.179
# F1 = 0.548 vs. 0.288
# Precision = 0.406 vs. 0.168
# Recall = 0.846 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.434 vs. 0.064
# F1 = 0.499 vs. 0.090
# Accuracy = 0.841 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.102
# F1 = 0.383 vs. 0.182
# Precision = 0.284 vs. 0.101
# Recall = 0.588 vs. 0.945
# Minibatch Loss= 0.114058
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.841 vs. 0.068
# F1 = 0.824 vs. 0.103
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.504 vs. 0.178
# F1 = 0.577 vs. 0.296
# Precision = 0.440 vs. 0.175
# Recall = 0.838 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.441 vs. 0.061
# F1 = 0.500 vs. 0.085
# Accuracy = 0.837 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.106
# F1 = 0.393 vs. 0.185
# Precision = 0.289 vs. 0.114
# Recall = 0.615 vs. 0.478
# Minibatch Loss= 0.133876
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.893 vs. 0.070
# F1 = 0.883 vs. 0.108
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.533 vs. 0.185
# F1 = 0.579 vs. 0.308
# Precision = 0.496 vs. 0.182
# Recall = 0.695 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.438 vs. 0.063
# F1 = 0.501 vs. 0.094
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.095
# F1 = 0.394 vs. 0.182
# Precision = 0.287 vs. 0.101
# Recall = 0.625 vs. 0.950
# Minibatch Loss= 0.100754
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.911 vs. 0.068
# F1 = 0.895 vs. 0.107
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.565 vs. 0.216
# F1 = 0.625 vs. 0.348
# Precision = 0.513 vs. 0.211
# Recall = 0.799 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.427 vs. 0.062
# F1 = 0.493 vs. 0.088
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.109
# F1 = 0.391 vs. 0.188
# Precision = 0.270 vs. 0.114
# Recall = 0.712 vs. 0.538
# Minibatch Loss= 0.101892
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.885 vs. 0.068
# F1 = 0.883 vs. 0.101
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.583 vs. 0.194
# F1 = 0.619 vs. 0.297
# Precision = 0.498 vs. 0.175
# Recall = 0.815 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.421 vs. 0.062
# F1 = 0.486 vs. 0.088
# Accuracy = 0.839 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.101
# F1 = 0.401 vs. 0.181
# Precision = 0.282 vs. 0.100
# Recall = 0.694 vs. 1.000
# Minibatch Loss= 0.094460
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.849 vs. 0.067
# F1 = 0.831 vs. 0.101
# Accuracy = 0.839 vs. 0.056
# CHANGE DETECTION
# AUC = 0.524 vs. 0.188
# F1 = 0.575 vs. 0.312
# Precision = 0.477 vs. 0.185
# Recall = 0.724 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.428 vs. 0.063
# F1 = 0.491 vs. 0.090
# Accuracy = 0.814 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.100
# F1 = 0.416 vs. 0.181
# Precision = 0.333 vs. 0.100
# Recall = 0.554 vs. 1.000
# Minibatch Loss= 0.158880
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.899 vs. 0.065
# F1 = 0.907 vs. 0.096
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.570 vs. 0.167
# F1 = 0.598 vs. 0.267
# Precision = 0.474 vs. 0.158
# Recall = 0.809 vs. 0.850
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.451 vs. 0.062
# F1 = 0.513 vs. 0.090
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.108
# F1 = 0.415 vs. 0.181
# Precision = 0.314 vs. 0.100
# Recall = 0.615 vs. 1.000
# Minibatch Loss= 0.077509
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.924 vs. 0.068
# F1 = 0.918 vs. 0.106
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.635 vs. 0.187
# F1 = 0.649 vs. 0.322
# Precision = 0.539 vs. 0.192
# Recall = 0.816 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.446 vs. 0.061
# F1 = 0.504 vs. 0.085
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.314 vs. 0.098
# F1 = 0.415 vs. 0.182
# Precision = 0.301 vs. 0.103
# Recall = 0.668 vs. 0.792
# Minibatch Loss= 0.082441
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.933 vs. 0.067
# F1 = 0.935 vs. 0.102
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.674 vs. 0.178
# F1 = 0.672 vs. 0.307
# Precision = 0.545 vs. 0.181
# Recall = 0.877 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.440 vs. 0.062
# F1 = 0.493 vs. 0.089
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.105
# F1 = 0.409 vs. 0.181
# Precision = 0.298 vs. 0.100
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 0.069603
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.925 vs. 0.066
# F1 = 0.919 vs. 0.098
# Accuracy = 0.948 vs. 0.056
# CHANGE DETECTION
# AUC = 0.657 vs. 0.157
# F1 = 0.656 vs. 0.259
# Precision = 0.513 vs. 0.148
# Recall = 0.907 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.437 vs. 0.063
# F1 = 0.487 vs. 0.090
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.104
# F1 = 0.414 vs. 0.184
# Precision = 0.292 vs. 0.101
# Recall = 0.707 vs. 0.979
# Minibatch Loss= 0.064530
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.898 vs. 0.069
# F1 = 0.847 vs. 0.101
# Accuracy = 0.841 vs. 0.056
# CHANGE DETECTION
# AUC = 0.580 vs. 0.182
# F1 = 0.604 vs. 0.298
# Precision = 0.475 vs. 0.177
# Recall = 0.830 vs. 0.943
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.471 vs. 0.061
# F1 = 0.524 vs. 0.083
# Accuracy = 0.820 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.098
# F1 = 0.422 vs. 0.181
# Precision = 0.301 vs. 0.100
# Recall = 0.704 vs. 0.995
# Minibatch Loss= 0.136023
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.922 vs. 0.068
# F1 = 0.926 vs. 0.105
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.186
# F1 = 0.667 vs. 0.329
# Precision = 0.559 vs. 0.197
# Recall = 0.827 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.466 vs. 0.062
# F1 = 0.530 vs. 0.086
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.103
# F1 = 0.428 vs. 0.182
# Precision = 0.325 vs. 0.100
# Recall = 0.625 vs. 0.995
# Minibatch Loss= 0.073049
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.943 vs. 0.066
# F1 = 0.939 vs. 0.100
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.632 vs. 0.186
# F1 = 0.669 vs. 0.302
# Precision = 0.530 vs. 0.178
# Recall = 0.907 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.457 vs. 0.062
# F1 = 0.516 vs. 0.088
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.092
# F1 = 0.420 vs. 0.182
# Precision = 0.321 vs. 0.101
# Recall = 0.607 vs. 0.979
# Minibatch Loss= 0.065850
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.951 vs. 0.065
# F1 = 0.945 vs. 0.096
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.697 vs. 0.161
# F1 = 0.705 vs. 0.287
# Precision = 0.607 vs. 0.168
# Recall = 0.841 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.450 vs. 0.064
# F1 = 0.511 vs. 0.093
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.107
# F1 = 0.420 vs. 0.189
# Precision = 0.328 vs. 0.107
# Recall = 0.583 vs. 0.839
# Minibatch Loss= 0.055092
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.973 vs. 0.067
# F1 = 0.956 vs. 0.102
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.214
# F1 = 0.696 vs. 0.321
# Precision = 0.594 vs. 0.192
# Recall = 0.840 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.448 vs. 0.062
# F1 = 0.510 vs. 0.087
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.105
# F1 = 0.429 vs. 0.183
# Precision = 0.335 vs. 0.101
# Recall = 0.594 vs. 0.918
# Minibatch Loss= 0.058540
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.948 vs. 0.066
# F1 = 0.947 vs. 0.096
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.173
# F1 = 0.688 vs. 0.289
# Precision = 0.568 vs. 0.172
# Recall = 0.872 vs. 0.922
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.443 vs. 0.062
# F1 = 0.507 vs. 0.088
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.101
# F1 = 0.428 vs. 0.184
# Precision = 0.337 vs. 0.102
# Recall = 0.588 vs. 0.966
# Minibatch Loss= 0.056670
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.904 vs. 0.068
# F1 = 0.865 vs. 0.103
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.629 vs. 0.176
# F1 = 0.637 vs. 0.313
# Precision = 0.579 vs. 0.187
# Recall = 0.707 vs. 0.956
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.469 vs. 0.063
# F1 = 0.532 vs. 0.087
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.099
# F1 = 0.411 vs. 0.184
# Precision = 0.308 vs. 0.102
# Recall = 0.617 vs. 0.984
# Minibatch Loss= 0.146416
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.952 vs. 0.068
# F1 = 0.934 vs. 0.102
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.645 vs. 0.187
# F1 = 0.659 vs. 0.309
# Precision = 0.556 vs. 0.183
# Recall = 0.809 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.472 vs. 0.064
# F1 = 0.524 vs. 0.088
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.337 vs. 0.103
# F1 = 0.433 vs. 0.182
# Precision = 0.312 vs. 0.101
# Recall = 0.707 vs. 0.945
# Minibatch Loss= 0.073112
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.971 vs. 0.067
# F1 = 0.953 vs. 0.100
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.697 vs. 0.162
# F1 = 0.690 vs. 0.289
# Precision = 0.603 vs. 0.169
# Recall = 0.806 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.464 vs. 0.062
# F1 = 0.521 vs. 0.089
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.332 vs. 0.102
# F1 = 0.437 vs. 0.183
# Precision = 0.326 vs. 0.101
# Recall = 0.662 vs. 0.984
# Minibatch Loss= 0.053940
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.968 vs. 0.067
# F1 = 0.954 vs. 0.101
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.702 vs. 0.172
# F1 = 0.710 vs. 0.302
# Precision = 0.604 vs. 0.178
# Recall = 0.863 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.462 vs. 0.062
# F1 = 0.519 vs. 0.085
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.111
# F1 = 0.432 vs. 0.185
# Precision = 0.366 vs. 0.103
# Recall = 0.525 vs. 0.953
# Minibatch Loss= 0.051881
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.958 vs. 0.066
# F1 = 0.961 vs. 0.098
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.723 vs. 0.165
# F1 = 0.717 vs. 0.296
# Precision = 0.601 vs. 0.174
# Recall = 0.886 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.455 vs. 0.061
# F1 = 0.513 vs. 0.085
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.094
# F1 = 0.431 vs. 0.181
# Precision = 0.339 vs. 0.100
# Recall = 0.594 vs. 0.987
# Minibatch Loss= 0.051556
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.069
# F1 = 0.973 vs. 0.105
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.753 vs. 0.196
# F1 = 0.755 vs. 0.310
# Precision = 0.657 vs. 0.184
# Recall = 0.888 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.453 vs. 0.063
# F1 = 0.514 vs. 0.092
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.108
# F1 = 0.435 vs. 0.187
# Precision = 0.349 vs. 0.110
# Recall = 0.578 vs. 0.617
# Minibatch Loss= 0.044604
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.924 vs. 0.069
# F1 = 0.884 vs. 0.107
# Accuracy = 0.838 vs. 0.056
# CHANGE DETECTION
# AUC = 0.621 vs. 0.188
# F1 = 0.635 vs. 0.310
# Precision = 0.518 vs. 0.183
# Recall = 0.819 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.450 vs. 0.062
# F1 = 0.505 vs. 0.088
# Accuracy = 0.818 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.102
# F1 = 0.411 vs. 0.181
# Precision = 0.312 vs. 0.100
# Recall = 0.602 vs. 0.992
# Minibatch Loss= 0.169627
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.958 vs. 0.066
# F1 = 0.932 vs. 0.098
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.685 vs. 0.170
# F1 = 0.664 vs. 0.289
# Precision = 0.565 vs. 0.169
# Recall = 0.805 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.512 vs. 0.063
# F1 = 0.548 vs. 0.088
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.360 vs. 0.107
# F1 = 0.460 vs. 0.182
# Precision = 0.344 vs. 0.100
# Recall = 0.691 vs. 0.995
# Minibatch Loss= 0.066800
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.067
# F1 = 0.962 vs. 0.103
# Accuracy = 0.949 vs. 0.056
# CHANGE DETECTION
# AUC = 0.753 vs. 0.196
# F1 = 0.735 vs. 0.319
# Precision = 0.679 vs. 0.190
# Recall = 0.801 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.061
# F1 = 0.555 vs. 0.083
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.365 vs. 0.097
# F1 = 0.462 vs. 0.186
# Precision = 0.351 vs. 0.103
# Recall = 0.673 vs. 0.945
# Minibatch Loss= 0.053283
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.068
# F1 = 0.970 vs. 0.102
# Accuracy = 0.950 vs. 0.056
# CHANGE DETECTION
# AUC = 0.764 vs. 0.170
# F1 = 0.745 vs. 0.293
# Precision = 0.639 vs. 0.172
# Recall = 0.893 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.062
# F1 = 0.547 vs. 0.086
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.363 vs. 0.099
# F1 = 0.459 vs. 0.181
# Precision = 0.353 vs. 0.100
# Recall = 0.657 vs. 0.992
# Minibatch Loss= 0.043416
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.067
# F1 = 0.966 vs. 0.097
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.742 vs. 0.173
# F1 = 0.733 vs. 0.298
# Precision = 0.649 vs. 0.175
# Recall = 0.842 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.492 vs. 0.064
# F1 = 0.542 vs. 0.087
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.361 vs. 0.099
# F1 = 0.454 vs. 0.182
# Precision = 0.350 vs. 0.105
# Recall = 0.646 vs. 0.704
# Minibatch Loss= 0.044677
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.066
# F1 = 0.969 vs. 0.099
# Accuracy = 0.965 vs. 0.056
# CHANGE DETECTION
# AUC = 0.719 vs. 0.190
# F1 = 0.737 vs. 0.295
# Precision = 0.623 vs. 0.191
# Recall = 0.903 vs. 0.656
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.484 vs. 0.063
# F1 = 0.535 vs. 0.088
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.362 vs. 0.106
# F1 = 0.459 vs. 0.183
# Precision = 0.369 vs. 0.102
# Recall = 0.607 vs. 0.889
# Minibatch Loss= 0.044959
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.068
# F1 = 0.972 vs. 0.100
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.787 vs. 0.175
# F1 = 0.791 vs. 0.277
# Precision = 0.690 vs. 0.161
# Recall = 0.928 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.481 vs. 0.062
# F1 = 0.532 vs. 0.087
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.357 vs. 0.103
# F1 = 0.456 vs. 0.181
# Precision = 0.359 vs. 0.100
# Recall = 0.625 vs. 1.000
# Minibatch Loss= 0.035616
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.068
# F1 = 0.969 vs. 0.103
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.811 vs. 0.185
# F1 = 0.784 vs. 0.306
# Precision = 0.684 vs. 0.181
# Recall = 0.918 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.480 vs. 0.064
# F1 = 0.529 vs. 0.092
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.356 vs. 0.103
# F1 = 0.455 vs. 0.182
# Precision = 0.361 vs. 0.100
# Recall = 0.615 vs. 0.997
# Minibatch Loss= 0.039347
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.066
# F1 = 0.948 vs. 0.097
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.732 vs. 0.162
# F1 = 0.712 vs. 0.270
# Precision = 0.619 vs. 0.157
# Recall = 0.838 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.461 vs. 0.061
# F1 = 0.518 vs. 0.084
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.359 vs. 0.100
# F1 = 0.447 vs. 0.190
# Precision = 0.353 vs. 0.108
# Recall = 0.612 vs. 0.784
# Minibatch Loss= 0.066239
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.951 vs. 0.069
# F1 = 0.923 vs. 0.106
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.706 vs. 0.192
# F1 = 0.674 vs. 0.319
# Precision = 0.567 vs. 0.190
# Recall = 0.832 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.528 vs. 0.061
# F1 = 0.559 vs. 0.087
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.108
# F1 = 0.437 vs. 0.190
# Precision = 0.324 vs. 0.112
# Recall = 0.673 vs. 0.617
# Minibatch Loss= 0.078967
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.069
# F1 = 0.961 vs. 0.107
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.737 vs. 0.176
# F1 = 0.714 vs. 0.299
# Precision = 0.678 vs. 0.177
# Recall = 0.754 vs. 0.947
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.514 vs. 0.063
# F1 = 0.555 vs. 0.091
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.092
# F1 = 0.458 vs. 0.182
# Precision = 0.370 vs. 0.100
# Recall = 0.602 vs. 1.000
# Minibatch Loss= 0.054093
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.068
# F1 = 0.978 vs. 0.104
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.827 vs. 0.186
# F1 = 0.790 vs. 0.293
# Precision = 0.668 vs. 0.172
# Recall = 0.967 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.064
# F1 = 0.548 vs. 0.089
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.095
# F1 = 0.454 vs. 0.181
# Precision = 0.369 vs. 0.100
# Recall = 0.588 vs. 0.997
# Minibatch Loss= 0.036306
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.068
# F1 = 0.975 vs. 0.100
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.778 vs. 0.171
# F1 = 0.769 vs. 0.288
# Precision = 0.659 vs. 0.168
# Recall = 0.922 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.504 vs. 0.062
# F1 = 0.537 vs. 0.083
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.096
# F1 = 0.451 vs. 0.181
# Precision = 0.349 vs. 0.100
# Recall = 0.639 vs. 0.955
# Minibatch Loss= 0.037611
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.068
# F1 = 0.976 vs. 0.104
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.760 vs. 0.166
# F1 = 0.752 vs. 0.293
# Precision = 0.652 vs. 0.171
# Recall = 0.886 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.499 vs. 0.063
# F1 = 0.537 vs. 0.089
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.097
# F1 = 0.453 vs. 0.182
# Precision = 0.358 vs. 0.100
# Recall = 0.617 vs. 1.000
# Minibatch Loss= 0.040357
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.067
# F1 = 0.983 vs. 0.098
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.818 vs. 0.185
# F1 = 0.789 vs. 0.290
# Precision = 0.675 vs. 0.169
# Recall = 0.950 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.496 vs. 0.063
# F1 = 0.531 vs. 0.087
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.099
# F1 = 0.449 vs. 0.181
# Precision = 0.365 vs. 0.100
# Recall = 0.586 vs. 1.000
# Minibatch Loss= 0.034773
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.068
# F1 = 0.976 vs. 0.102
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.832 vs. 0.187
# F1 = 0.818 vs. 0.313
# Precision = 0.745 vs. 0.185
# Recall = 0.907 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.492 vs. 0.064
# F1 = 0.524 vs. 0.087
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.370 vs. 0.110
# F1 = 0.445 vs. 0.183
# Precision = 0.363 vs. 0.101
# Recall = 0.575 vs. 0.984
# Minibatch Loss= 0.034984
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.067
# F1 = 0.988 vs. 0.102
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.859 vs. 0.183
# F1 = 0.832 vs. 0.296
# Precision = 0.771 vs. 0.175
# Recall = 0.903 vs. 0.950
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.484 vs. 0.062
# F1 = 0.525 vs. 0.087
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.367 vs. 0.097
# F1 = 0.446 vs. 0.182
# Precision = 0.357 vs. 0.101
# Recall = 0.594 vs. 0.950
# Minibatch Loss= 0.027519
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.066
# F1 = 0.985 vs. 0.097
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.856 vs. 0.177
# F1 = 0.836 vs. 0.299
# Precision = 0.782 vs. 0.180
# Recall = 0.898 vs. 0.873
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.482 vs. 0.064
# F1 = 0.523 vs. 0.093
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.364 vs. 0.107
# F1 = 0.442 vs. 0.182
# Precision = 0.363 vs. 0.100
# Recall = 0.565 vs. 0.987
# Minibatch Loss= 0.028586
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.069
# F1 = 0.986 vs. 0.107
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.840 vs. 0.186
# F1 = 0.833 vs. 0.310
# Precision = 0.764 vs. 0.183
# Recall = 0.916 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.483 vs. 0.063
# F1 = 0.525 vs. 0.088
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.364 vs. 0.109
# F1 = 0.441 vs. 0.187
# Precision = 0.366 vs. 0.108
# Recall = 0.554 vs. 0.689
# Minibatch Loss= 0.031452
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.066
# F1 = 0.983 vs. 0.096
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.853 vs. 0.147
# F1 = 0.807 vs. 0.270
# Precision = 0.746 vs. 0.156
# Recall = 0.880 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.480 vs. 0.063
# F1 = 0.519 vs. 0.089
# Accuracy = 0.840 vs. 0.056
# CHANGE DETECTION
# AUC = 0.354 vs. 0.107
# F1 = 0.435 vs. 0.184
# Precision = 0.378 vs. 0.102
# Recall = 0.512 vs. 0.979
# Minibatch Loss= 0.037336
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.936 vs. 0.069
# F1 = 0.892 vs. 0.105
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.708 vs. 0.184
# F1 = 0.683 vs. 0.315
# Precision = 0.611 vs. 0.190
# Recall = 0.775 vs. 0.926
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.527 vs. 0.063
# F1 = 0.552 vs. 0.085
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.406 vs. 0.111
# F1 = 0.465 vs. 0.184
# Precision = 0.384 vs. 0.110
# Recall = 0.591 vs. 0.573
# Minibatch Loss= 0.095866
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.968 vs. 0.069
# F1 = 0.947 vs. 0.104
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.708 vs. 0.163
# F1 = 0.703 vs. 0.286
# Precision = 0.626 vs. 0.167
# Recall = 0.801 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.539 vs. 0.062
# F1 = 0.560 vs. 0.087
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.420 vs. 0.101
# F1 = 0.494 vs. 0.184
# Precision = 0.389 vs. 0.103
# Recall = 0.675 vs. 0.902
# Minibatch Loss= 0.060934
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.068
# F1 = 0.961 vs. 0.101
# Accuracy = 0.952 vs. 0.056
# CHANGE DETECTION
# AUC = 0.795 vs. 0.199
# F1 = 0.769 vs. 0.313
# Precision = 0.681 vs. 0.186
# Recall = 0.884 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.538 vs. 0.062
# F1 = 0.561 vs. 0.085
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.413 vs. 0.093
# F1 = 0.494 vs. 0.181
# Precision = 0.391 vs. 0.100
# Recall = 0.673 vs. 1.000
# Minibatch Loss= 0.052194
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.973 vs. 0.068
# F1 = 0.968 vs. 0.104
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.818 vs. 0.207
# F1 = 0.773 vs. 0.336
# Precision = 0.731 vs. 0.202
# Recall = 0.821 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.532 vs. 0.062
# F1 = 0.564 vs. 0.090
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.407 vs. 0.105
# F1 = 0.484 vs. 0.182
# Precision = 0.388 vs. 0.100
# Recall = 0.641 vs. 0.997
# Minibatch Loss= 0.051079
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.068
# F1 = 0.972 vs. 0.102
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.805 vs. 0.166
# F1 = 0.767 vs. 0.280
# Precision = 0.658 vs. 0.164
# Recall = 0.919 vs. 0.963
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.530 vs. 0.061
# F1 = 0.556 vs. 0.089
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.403 vs. 0.102
# F1 = 0.478 vs. 0.181
# Precision = 0.383 vs. 0.100
# Recall = 0.633 vs. 0.976
# Minibatch Loss= 0.040991
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.067
# F1 = 0.986 vs. 0.102
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.834 vs. 0.163
# F1 = 0.825 vs. 0.296
# Precision = 0.765 vs. 0.173
# Recall = 0.895 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.527 vs. 0.062
# F1 = 0.554 vs. 0.087
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.400 vs. 0.104
# F1 = 0.471 vs. 0.183
# Precision = 0.367 vs. 0.101
# Recall = 0.660 vs. 0.989
# Minibatch Loss= 0.033031
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.069
# F1 = 0.982 vs. 0.105
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.858 vs. 0.189
# F1 = 0.835 vs. 0.327
# Precision = 0.762 vs. 0.196
# Recall = 0.925 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.522 vs. 0.062
# F1 = 0.553 vs. 0.082
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.104
# F1 = 0.466 vs. 0.184
# Precision = 0.412 vs. 0.101
# Recall = 0.536 vs. 0.976
# Minibatch Loss= 0.035489
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.073
# F1 = 0.982 vs. 0.111
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.877 vs. 0.195
# F1 = 0.843 vs. 0.328
# Precision = 0.760 vs. 0.196
# Recall = 0.946 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.063
# F1 = 0.548 vs. 0.092
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.103
# F1 = 0.474 vs. 0.184
# Precision = 0.414 vs. 0.102
# Recall = 0.554 vs. 0.902
# Minibatch Loss= 0.030887
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.067
# F1 = 0.985 vs. 0.100
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.826 vs. 0.179
# F1 = 0.819 vs. 0.294
# Precision = 0.713 vs. 0.173
# Recall = 0.962 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.063
# F1 = 0.548 vs. 0.089
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.393 vs. 0.100
# F1 = 0.473 vs. 0.183
# Precision = 0.416 vs. 0.104
# Recall = 0.546 vs. 0.731
# Minibatch Loss= 0.031742
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.067
# F1 = 0.983 vs. 0.099
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.867 vs. 0.175
# F1 = 0.851 vs. 0.290
# Precision = 0.802 vs. 0.170
# Recall = 0.907 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.511 vs. 0.064
# F1 = 0.545 vs. 0.095
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.388 vs. 0.108
# F1 = 0.467 vs. 0.184
# Precision = 0.398 vs. 0.107
# Recall = 0.565 vs. 0.646
# Minibatch Loss= 0.027459
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.066
# F1 = 0.990 vs. 0.097
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.873 vs. 0.165
# F1 = 0.855 vs. 0.274
# Precision = 0.777 vs. 0.163
# Recall = 0.950 vs. 0.857
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.063
# F1 = 0.544 vs. 0.090
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.101
# F1 = 0.458 vs. 0.184
# Precision = 0.388 vs. 0.102
# Recall = 0.559 vs. 0.910
# Minibatch Loss= 0.023831
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.071
# F1 = 0.993 vs. 0.106
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.886 vs. 0.169
# F1 = 0.859 vs. 0.287
# Precision = 0.800 vs. 0.170
# Recall = 0.927 vs. 0.915
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.064
# F1 = 0.543 vs. 0.091
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.095
# F1 = 0.458 vs. 0.182
# Precision = 0.390 vs. 0.100
# Recall = 0.554 vs. 0.992
# Minibatch Loss= 0.022851
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.066
# F1 = 0.988 vs. 0.099
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.871 vs. 0.182
# F1 = 0.867 vs. 0.308
# Precision = 0.796 vs. 0.182
# Recall = 0.952 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.061
# F1 = 0.537 vs. 0.088
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.099
# F1 = 0.454 vs. 0.183
# Precision = 0.401 vs. 0.103
# Recall = 0.522 vs. 0.813
# Minibatch Loss= 0.026994
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.065
# F1 = 0.991 vs. 0.100
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.905 vs. 0.164
# F1 = 0.875 vs. 0.277
# Precision = 0.826 vs. 0.161
# Recall = 0.930 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.062
# F1 = 0.536 vs. 0.090
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.102
# F1 = 0.444 vs. 0.181
# Precision = 0.390 vs. 0.100
# Recall = 0.517 vs. 1.000
# Minibatch Loss= 0.021261
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.067
# F1 = 0.993 vs. 0.099
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.178
# F1 = 0.880 vs. 0.300
# Precision = 0.825 vs. 0.177
# Recall = 0.943 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.493 vs. 0.062
# F1 = 0.530 vs. 0.090
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.097
# F1 = 0.447 vs. 0.181
# Precision = 0.363 vs. 0.100
# Recall = 0.580 vs. 1.000
# Minibatch Loss= 0.021095
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.872 vs. 0.064
# F1 = 0.822 vs. 0.097
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.716 vs. 0.170
# F1 = 0.683 vs. 0.292
# Precision = 0.662 vs. 0.171
# Recall = 0.705 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.485 vs. 0.062
# F1 = 0.538 vs. 0.084
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.331 vs. 0.105
# F1 = 0.430 vs. 0.182
# Precision = 0.372 vs. 0.100
# Recall = 0.509 vs. 0.997
# Minibatch Loss= 0.159430
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.067
# F1 = 0.954 vs. 0.102
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.844 vs. 0.187
# F1 = 0.777 vs. 0.321
# Precision = 0.712 vs. 0.192
# Recall = 0.856 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.543 vs. 0.062
# F1 = 0.572 vs. 0.087
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.356 vs. 0.103
# F1 = 0.455 vs. 0.185
# Precision = 0.386 vs. 0.103
# Recall = 0.554 vs. 0.953
# Minibatch Loss= 0.051688
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.070
# F1 = 0.971 vs. 0.105
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.808 vs. 0.166
# F1 = 0.785 vs. 0.297
# Precision = 0.701 vs. 0.175
# Recall = 0.893 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.542 vs. 0.063
# F1 = 0.567 vs. 0.088
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.354 vs. 0.097
# F1 = 0.455 vs. 0.182
# Precision = 0.389 vs. 0.100
# Recall = 0.549 vs. 0.992
# Minibatch Loss= 0.041990
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.068
# F1 = 0.985 vs. 0.103
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.880 vs. 0.176
# F1 = 0.846 vs. 0.306
# Precision = 0.769 vs. 0.182
# Recall = 0.939 vs. 0.953
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.539 vs. 0.062
# F1 = 0.569 vs. 0.089
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.100
# F1 = 0.454 vs. 0.181
# Precision = 0.375 vs. 0.100
# Recall = 0.573 vs. 1.000
# Minibatch Loss= 0.031080
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.067
# F1 = 0.980 vs. 0.103
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.853 vs. 0.169
# F1 = 0.835 vs. 0.287
# Precision = 0.768 vs. 0.168
# Recall = 0.914 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.535 vs. 0.062
# F1 = 0.563 vs. 0.087
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.096
# F1 = 0.454 vs. 0.183
# Precision = 0.404 vs. 0.101
# Recall = 0.517 vs. 0.955
# Minibatch Loss= 0.030981
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.066
# F1 = 0.991 vs. 0.098
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.879 vs. 0.140
# F1 = 0.863 vs. 0.248
# Precision = 0.781 vs. 0.142
# Recall = 0.965 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.531 vs. 0.062
# F1 = 0.562 vs. 0.084
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.099
# F1 = 0.455 vs. 0.182
# Precision = 0.407 vs. 0.100
# Recall = 0.515 vs. 0.989
# Minibatch Loss= 0.022578
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.068
# F1 = 0.992 vs. 0.104
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.200
# F1 = 0.865 vs. 0.331
# Precision = 0.792 vs. 0.203
# Recall = 0.952 vs. 0.894
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.527 vs. 0.063
# F1 = 0.558 vs. 0.096
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.100
# F1 = 0.451 vs. 0.182
# Precision = 0.382 vs. 0.100
# Recall = 0.549 vs. 0.987
# Minibatch Loss= 0.027062
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.070
# F1 = 0.994 vs. 0.107
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.910 vs. 0.202
# F1 = 0.881 vs. 0.343
# Precision = 0.812 vs. 0.207
# Recall = 0.964 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.525 vs. 0.064
# F1 = 0.554 vs. 0.090
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.104
# F1 = 0.446 vs. 0.183
# Precision = 0.381 vs. 0.102
# Recall = 0.538 vs. 0.939
# Minibatch Loss= 0.025861
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.069
# F1 = 0.991 vs. 0.104
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.917 vs. 0.177
# F1 = 0.899 vs. 0.306
# Precision = 0.856 vs. 0.180
# Recall = 0.946 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.067
# F1 = 0.553 vs. 0.094
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.102
# F1 = 0.446 vs. 0.185
# Precision = 0.389 vs. 0.103
# Recall = 0.522 vs. 0.950
# Minibatch Loss= 0.021514
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.066
# F1 = 0.992 vs. 0.098
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.917 vs. 0.159
# F1 = 0.900 vs. 0.284
# Precision = 0.838 vs. 0.166
# Recall = 0.971 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.519 vs. 0.062
# F1 = 0.554 vs. 0.092
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.100
# F1 = 0.445 vs. 0.183
# Precision = 0.385 vs. 0.102
# Recall = 0.528 vs. 0.850
# Minibatch Loss= 0.020289
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.066
# F1 = 0.994 vs. 0.097
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.918 vs. 0.150
# F1 = 0.902 vs. 0.254
# Precision = 0.833 vs. 0.146
# Recall = 0.983 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.520 vs. 0.063
# F1 = 0.555 vs. 0.092
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.096
# F1 = 0.451 vs. 0.185
# Precision = 0.383 vs. 0.103
# Recall = 0.549 vs. 0.908
# Minibatch Loss= 0.016802
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.069
# F1 = 0.995 vs. 0.106
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.910 vs. 0.196
# F1 = 0.908 vs. 0.306
# Precision = 0.853 vs. 0.181
# Recall = 0.971 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.062
# F1 = 0.555 vs. 0.087
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.099
# F1 = 0.448 vs. 0.181
# Precision = 0.384 vs. 0.100
# Recall = 0.538 vs. 1.000
# Minibatch Loss= 0.020024
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.068
# F1 = 0.995 vs. 0.104
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.946 vs. 0.180
# F1 = 0.932 vs. 0.312
# Precision = 0.907 vs. 0.185
# Recall = 0.958 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.062
# F1 = 0.557 vs. 0.087
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.098
# F1 = 0.449 vs. 0.182
# Precision = 0.380 vs. 0.100
# Recall = 0.549 vs. 0.984
# Minibatch Loss= 0.016455
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.069
# F1 = 0.993 vs. 0.106
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.937 vs. 0.196
# F1 = 0.924 vs. 0.333
# Precision = 0.890 vs. 0.202
# Recall = 0.961 vs. 0.934
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.065
# F1 = 0.559 vs. 0.094
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.097
# F1 = 0.449 vs. 0.181
# Precision = 0.370 vs. 0.100
# Recall = 0.570 vs. 1.000
# Minibatch Loss= 0.018447
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.070
# F1 = 0.996 vs. 0.104
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.182
# F1 = 0.947 vs. 0.311
# Precision = 0.917 vs. 0.184
# Recall = 0.978 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.519 vs. 0.063
# F1 = 0.556 vs. 0.088
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.101
# F1 = 0.446 vs. 0.186
# Precision = 0.396 vs. 0.103
# Recall = 0.509 vs. 0.950
# Minibatch Loss= 0.014144
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.069
# F1 = 0.997 vs. 0.104
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.944 vs. 0.205
# F1 = 0.942 vs. 0.306
# Precision = 0.891 vs. 0.181
# Recall = 0.998 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.063
# F1 = 0.555 vs. 0.091
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.104
# F1 = 0.447 vs. 0.181
# Precision = 0.379 vs. 0.100
# Recall = 0.544 vs. 1.000
# Minibatch Loss= 0.014195
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.069
# F1 = 0.993 vs. 0.102
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.199
# F1 = 0.939 vs. 0.322
# Precision = 0.898 vs. 0.193
# Recall = 0.984 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.516 vs. 0.062
# F1 = 0.558 vs. 0.085
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.099
# F1 = 0.448 vs. 0.182
# Precision = 0.394 vs. 0.101
# Recall = 0.520 vs. 0.913
# Minibatch Loss= 0.016461
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.997 vs. 0.102
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.954 vs. 0.188
# F1 = 0.943 vs. 0.311
# Precision = 0.900 vs. 0.184
# Recall = 0.991 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.511 vs. 0.063
# F1 = 0.553 vs. 0.088
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.368 vs. 0.101
# F1 = 0.434 vs. 0.182
# Precision = 0.367 vs. 0.107
# Recall = 0.530 vs. 0.604
# Minibatch Loss= 0.013634
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.535 vs. 0.065
# F1 = 0.579 vs. 0.096
# Accuracy = 0.555 vs. 0.056
# CHANGE DETECTION
# AUC = 0.484 vs. 0.158
# F1 = 0.568 vs. 0.268
# Precision = 0.489 vs. 0.156
# Recall = 0.678 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.365 vs. 0.063
# F1 = 0.436 vs. 0.094
# Accuracy = 0.549 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.099
# F1 = 0.386 vs. 0.185
# Precision = 0.290 vs. 0.105
# Recall = 0.575 vs. 0.810
# Minibatch Loss= 0.402269
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.729 vs. 0.066
# F1 = 0.693 vs. 0.101
# Accuracy = 0.723 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.150
# F1 = 0.595 vs. 0.276
# Precision = 0.575 vs. 0.161
# Recall = 0.616 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.443 vs. 0.065
# F1 = 0.490 vs. 0.098
# Accuracy = 0.687 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.098
# F1 = 0.407 vs. 0.181
# Precision = 0.315 vs. 0.100
# Recall = 0.575 vs. 1.000
# Minibatch Loss= 0.254357
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.753 vs. 0.069
# F1 = 0.735 vs. 0.104
# Accuracy = 0.743 vs. 0.056
# CHANGE DETECTION
# AUC = 0.650 vs. 0.186
# F1 = 0.625 vs. 0.302
# Precision = 0.560 vs. 0.178
# Recall = 0.708 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.475 vs. 0.062
# F1 = 0.521 vs. 0.088
# Accuracy = 0.755 vs. 0.056
# CHANGE DETECTION
# AUC = 0.354 vs. 0.106
# F1 = 0.435 vs. 0.185
# Precision = 0.355 vs. 0.108
# Recall = 0.562 vs. 0.660
# Minibatch Loss= 0.224732
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.818 vs. 0.067
# F1 = 0.767 vs. 0.104
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.694 vs. 0.168
# F1 = 0.665 vs. 0.295
# Precision = 0.605 vs. 0.173
# Recall = 0.738 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.064
# F1 = 0.536 vs. 0.097
# Accuracy = 0.777 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.111
# F1 = 0.448 vs. 0.183
# Precision = 0.347 vs. 0.101
# Recall = 0.631 vs. 0.984
# Minibatch Loss= 0.179028
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.806 vs. 0.065
# F1 = 0.766 vs. 0.095
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.689 vs. 0.156
# F1 = 0.643 vs. 0.278
# Precision = 0.531 vs. 0.163
# Recall = 0.813 vs. 0.949
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.063
# F1 = 0.554 vs. 0.086
# Accuracy = 0.787 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.099
# F1 = 0.458 vs. 0.183
# Precision = 0.366 vs. 0.101
# Recall = 0.612 vs. 0.955
# Minibatch Loss= 0.162547
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.862 vs. 0.066
# F1 = 0.804 vs. 0.101
# Accuracy = 0.843 vs. 0.056
# CHANGE DETECTION
# AUC = 0.701 vs. 0.158
# F1 = 0.649 vs. 0.277
# Precision = 0.632 vs. 0.161
# Recall = 0.668 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.523 vs. 0.063
# F1 = 0.564 vs. 0.088
# Accuracy = 0.795 vs. 0.056
# CHANGE DETECTION
# AUC = 0.399 vs. 0.104
# F1 = 0.461 vs. 0.182
# Precision = 0.397 vs. 0.100
# Recall = 0.551 vs. 1.000
# Minibatch Loss= 0.140972
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.877 vs. 0.067
# F1 = 0.823 vs. 0.101
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.730 vs. 0.156
# F1 = 0.683 vs. 0.273
# Precision = 0.578 vs. 0.159
# Recall = 0.833 vs. 0.956
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.532 vs. 0.065
# F1 = 0.568 vs. 0.091
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.410 vs. 0.106
# F1 = 0.475 vs. 0.183
# Precision = 0.408 vs. 0.101
# Recall = 0.567 vs. 0.958
# Minibatch Loss= 0.114382
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.885 vs. 0.067
# F1 = 0.839 vs. 0.098
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.714 vs. 0.162
# F1 = 0.678 vs. 0.284
# Precision = 0.587 vs. 0.166
# Recall = 0.803 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.540 vs. 0.066
# F1 = 0.578 vs. 0.096
# Accuracy = 0.805 vs. 0.056
# CHANGE DETECTION
# AUC = 0.419 vs. 0.106
# F1 = 0.479 vs. 0.181
# Precision = 0.424 vs. 0.100
# Recall = 0.551 vs. 1.000
# Minibatch Loss= 0.118401
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.879 vs. 0.068
# F1 = 0.844 vs. 0.104
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.743 vs. 0.172
# F1 = 0.701 vs. 0.293
# Precision = 0.656 vs. 0.172
# Recall = 0.752 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.543 vs. 0.062
# F1 = 0.583 vs. 0.087
# Accuracy = 0.824 vs. 0.056
# CHANGE DETECTION
# AUC = 0.428 vs. 0.107
# F1 = 0.482 vs. 0.182
# Precision = 0.412 vs. 0.101
# Recall = 0.580 vs. 0.929
# Minibatch Loss= 0.124267
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.894 vs. 0.069
# F1 = 0.865 vs. 0.104
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.763 vs. 0.168
# F1 = 0.712 vs. 0.289
# Precision = 0.680 vs. 0.171
# Recall = 0.747 vs. 0.950
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.062
# F1 = 0.592 vs. 0.087
# Accuracy = 0.822 vs. 0.056
# CHANGE DETECTION
# AUC = 0.434 vs. 0.106
# F1 = 0.484 vs. 0.185
# Precision = 0.403 vs. 0.108
# Recall = 0.607 vs. 0.657
# Minibatch Loss= 0.093009
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.898 vs. 0.067
# F1 = 0.868 vs. 0.102
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.728 vs. 0.195
# F1 = 0.690 vs. 0.318
# Precision = 0.633 vs. 0.189
# Recall = 0.758 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.552 vs. 0.062
# F1 = 0.596 vs. 0.085
# Accuracy = 0.820 vs. 0.056
# CHANGE DETECTION
# AUC = 0.440 vs. 0.100
# F1 = 0.491 vs. 0.181
# Precision = 0.389 vs. 0.100
# Recall = 0.665 vs. 0.987
# Minibatch Loss= 0.114065
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.919 vs. 0.066
# F1 = 0.883 vs. 0.101
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.763 vs. 0.167
# F1 = 0.714 vs. 0.294
# Precision = 0.630 vs. 0.173
# Recall = 0.823 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.063
# F1 = 0.598 vs. 0.092
# Accuracy = 0.828 vs. 0.056
# CHANGE DETECTION
# AUC = 0.446 vs. 0.101
# F1 = 0.489 vs. 0.187
# Precision = 0.400 vs. 0.104
# Recall = 0.628 vs. 0.916
# Minibatch Loss= 0.095311
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.928 vs. 0.068
# F1 = 0.889 vs. 0.101
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.785 vs. 0.132
# F1 = 0.726 vs. 0.240
# Precision = 0.667 vs. 0.136
# Recall = 0.795 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.061
# F1 = 0.601 vs. 0.085
# Accuracy = 0.831 vs. 0.056
# CHANGE DETECTION
# AUC = 0.447 vs. 0.111
# F1 = 0.497 vs. 0.185
# Precision = 0.397 vs. 0.103
# Recall = 0.665 vs. 0.916
# Minibatch Loss= 0.075420
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.917 vs. 0.069
# F1 = 0.886 vs. 0.104
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.752 vs. 0.167
# F1 = 0.704 vs. 0.291
# Precision = 0.617 vs. 0.171
# Recall = 0.820 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.564 vs. 0.062
# F1 = 0.597 vs. 0.088
# Accuracy = 0.838 vs. 0.056
# CHANGE DETECTION
# AUC = 0.449 vs. 0.106
# F1 = 0.495 vs. 0.185
# Precision = 0.427 vs. 0.105
# Recall = 0.588 vs. 0.749
# Minibatch Loss= 0.095411
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.935 vs. 0.069
# F1 = 0.905 vs. 0.104
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.798 vs. 0.185
# F1 = 0.749 vs. 0.311
# Precision = 0.656 vs. 0.184
# Recall = 0.874 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.062
# F1 = 0.594 vs. 0.086
# Accuracy = 0.839 vs. 0.056
# CHANGE DETECTION
# AUC = 0.453 vs. 0.109
# F1 = 0.497 vs. 0.181
# Precision = 0.408 vs. 0.100
# Recall = 0.636 vs. 1.000
# Minibatch Loss= 0.084037
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.934 vs. 0.067
# F1 = 0.905 vs. 0.102
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.766 vs. 0.161
# F1 = 0.707 vs. 0.269
# Precision = 0.609 vs. 0.155
# Recall = 0.843 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.063
# F1 = 0.594 vs. 0.089
# Accuracy = 0.833 vs. 0.056
# CHANGE DETECTION
# AUC = 0.449 vs. 0.099
# F1 = 0.499 vs. 0.189
# Precision = 0.399 vs. 0.105
# Recall = 0.665 vs. 0.910
# Minibatch Loss= 0.074975
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.944 vs. 0.068
# F1 = 0.920 vs. 0.105
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.808 vs. 0.171
# F1 = 0.758 vs. 0.292
# Precision = 0.693 vs. 0.171
# Recall = 0.838 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.062
# F1 = 0.591 vs. 0.086
# Accuracy = 0.840 vs. 0.056
# CHANGE DETECTION
# AUC = 0.454 vs. 0.104
# F1 = 0.505 vs. 0.182
# Precision = 0.397 vs. 0.100
# Recall = 0.694 vs. 1.000
# Minibatch Loss= 0.071201
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.960 vs. 0.067
# F1 = 0.934 vs. 0.101
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.831 vs. 0.190
# F1 = 0.774 vs. 0.308
# Precision = 0.711 vs. 0.182
# Recall = 0.849 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.061
# F1 = 0.594 vs. 0.089
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.450 vs. 0.106
# F1 = 0.506 vs. 0.184
# Precision = 0.403 vs. 0.103
# Recall = 0.678 vs. 0.894
# Minibatch Loss= 0.067837
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.951 vs. 0.069
# F1 = 0.928 vs. 0.108
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.774 vs. 0.194
# F1 = 0.732 vs. 0.319
# Precision = 0.637 vs. 0.190
# Recall = 0.861 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.064
# F1 = 0.593 vs. 0.091
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.455 vs. 0.103
# F1 = 0.509 vs. 0.182
# Precision = 0.410 vs. 0.100
# Recall = 0.673 vs. 0.992
# Minibatch Loss= 0.077494
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.950 vs. 0.067
# F1 = 0.933 vs. 0.104
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.764 vs. 0.157
# F1 = 0.732 vs. 0.277
# Precision = 0.631 vs. 0.160
# Recall = 0.873 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.062
# F1 = 0.591 vs. 0.087
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.451 vs. 0.102
# F1 = 0.508 vs. 0.184
# Precision = 0.414 vs. 0.102
# Recall = 0.657 vs. 0.960
# Minibatch Loss= 0.062842
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.957 vs. 0.067
# F1 = 0.942 vs. 0.099
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.831 vs. 0.190
# F1 = 0.789 vs. 0.311
# Precision = 0.709 vs. 0.190
# Recall = 0.890 vs. 0.845
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.062
# F1 = 0.594 vs. 0.087
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.448 vs. 0.111
# F1 = 0.500 vs. 0.181
# Precision = 0.407 vs. 0.100
# Recall = 0.649 vs. 1.000
# Minibatch Loss= 0.059544
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.964 vs. 0.065
# F1 = 0.944 vs. 0.098
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.805 vs. 0.163
# F1 = 0.768 vs. 0.277
# Precision = 0.713 vs. 0.162
# Recall = 0.833 vs. 0.963
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.062
# F1 = 0.588 vs. 0.090
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.451 vs. 0.103
# F1 = 0.497 vs. 0.181
# Precision = 0.416 vs. 0.100
# Recall = 0.617 vs. 0.974
# Minibatch Loss= 0.061731
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.068
# F1 = 0.953 vs. 0.103
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.844 vs. 0.170
# F1 = 0.793 vs. 0.288
# Precision = 0.743 vs. 0.168
# Recall = 0.851 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.065
# F1 = 0.587 vs. 0.092
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.447 vs. 0.097
# F1 = 0.504 vs. 0.182
# Precision = 0.414 vs. 0.100
# Recall = 0.644 vs. 0.997
# Minibatch Loss= 0.052954
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.959 vs. 0.065
# F1 = 0.943 vs. 0.094
# Accuracy = 0.952 vs. 0.056
# CHANGE DETECTION
# AUC = 0.809 vs. 0.144
# F1 = 0.767 vs. 0.255
# Precision = 0.680 vs. 0.146
# Recall = 0.878 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.554 vs. 0.062
# F1 = 0.590 vs. 0.090
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.447 vs. 0.107
# F1 = 0.502 vs. 0.182
# Precision = 0.431 vs. 0.100
# Recall = 0.602 vs. 1.000
# Minibatch Loss= 0.049300

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../model/DWN_activity_multitask_64_opp/checkpoint-20000')

# %%
#This is the model evaluation on test dataset
result = nn_eval.evaluate_model (model, sess, test_data, test_gt)

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(out, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
out.shape
# Out:
# (119, 32, 19)
