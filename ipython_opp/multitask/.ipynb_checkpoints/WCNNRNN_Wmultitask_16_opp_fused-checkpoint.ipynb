# %%
# useing this variable for saving models and summaries
exp_name = "WCNNRNN_Wmultitask_32_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.WCNNRNN_model as WCNNRNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 2]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.28595522,  42.44204322,  42.96023857,  45.06666667,
#         44.49794239,  34.32268371,  35.42833608,  50.54312354,
#         54.97974684,  62.17714286,  69.87179487,  66.41463415,
#         71.02605863,  57.96533333,  57.4973545 ,  39.35036496,
#         12.09177028,  47.81236203,   4.77487595])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = WCNNRNN_model.Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)
# Out:
# Tensor("Squeeze_21:0", shape=(?, ?, 19), dtype=float32) Tensor("Reshape_7:0", shape=(?, ?, 19), dtype=float32)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.071
# F1 = 0.114 vs. 0.109
# Accuracy = 0.079 vs. 0.056
# CHANGE DETECTION
# AUC = 0.168 vs. 0.190
# F1 = 0.325 vs. 0.315
# Precision = 0.195 vs. 0.187
# Recall = 0.973 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.062
# F1 = 0.092 vs. 0.087
# Accuracy = 0.030 vs. 0.056
# CHANGE DETECTION
# AUC = 0.085 vs. 0.102
# F1 = 0.192 vs. 0.182
# Precision = 0.107 vs. 0.100
# Recall = 0.974 vs. 1.000
# Minibatch Loss= 1.340526
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.067
# F1 = 0.579 vs. 0.100
# Accuracy = 0.481 vs. 0.056
# CHANGE DETECTION
# AUC = 0.420 vs. 0.176
# F1 = 0.498 vs. 0.291
# Precision = 0.399 vs. 0.171
# Recall = 0.661 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.262 vs. 0.061
# F1 = 0.344 vs. 0.087
# Accuracy = 0.474 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.096
# F1 = 0.406 vs. 0.181
# Precision = 0.293 vs. 0.100
# Recall = 0.660 vs. 1.000
# Minibatch Loss= 0.382650
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.067
# F1 = 0.688 vs. 0.102
# Accuracy = 0.717 vs. 0.056
# CHANGE DETECTION
# AUC = 0.455 vs. 0.186
# F1 = 0.523 vs. 0.308
# Precision = 0.383 vs. 0.182
# Recall = 0.823 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.405 vs. 0.065
# F1 = 0.491 vs. 0.087
# Accuracy = 0.712 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.104
# F1 = 0.438 vs. 0.183
# Precision = 0.369 vs. 0.105
# Recall = 0.538 vs. 0.718
# Minibatch Loss= 0.298354
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.786 vs. 0.067
# F1 = 0.758 vs. 0.101
# Accuracy = 0.833 vs. 0.056
# CHANGE DETECTION
# AUC = 0.495 vs. 0.173
# F1 = 0.538 vs. 0.290
# Precision = 0.424 vs. 0.169
# Recall = 0.737 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.471 vs. 0.061
# F1 = 0.524 vs. 0.086
# Accuracy = 0.788 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.100
# F1 = 0.449 vs. 0.183
# Precision = 0.343 vs. 0.101
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 0.201238
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.853 vs. 0.069
# F1 = 0.809 vs. 0.102
# Accuracy = 0.838 vs. 0.056
# CHANGE DETECTION
# AUC = 0.513 vs. 0.174
# F1 = 0.563 vs. 0.292
# Precision = 0.441 vs. 0.172
# Recall = 0.777 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.492 vs. 0.062
# F1 = 0.537 vs. 0.090
# Accuracy = 0.816 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.092
# F1 = 0.458 vs. 0.181
# Precision = 0.362 vs. 0.100
# Recall = 0.625 vs. 0.987
# Minibatch Loss= 0.165007
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.867 vs. 0.068
# F1 = 0.820 vs. 0.100
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.158
# F1 = 0.570 vs. 0.280
# Precision = 0.448 vs. 0.163
# Recall = 0.784 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.497 vs. 0.065
# F1 = 0.547 vs. 0.091
# Accuracy = 0.813 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.091
# F1 = 0.462 vs. 0.182
# Precision = 0.346 vs. 0.100
# Recall = 0.697 vs. 0.995
# Minibatch Loss= 0.141808
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.901 vs. 0.070
# F1 = 0.850 vs. 0.109
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.502 vs. 0.202
# F1 = 0.587 vs. 0.330
# Precision = 0.445 vs. 0.199
# Recall = 0.866 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.516 vs. 0.063
# F1 = 0.563 vs. 0.092
# Accuracy = 0.826 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.103
# F1 = 0.470 vs. 0.182
# Precision = 0.370 vs. 0.100
# Recall = 0.641 vs. 0.982
# Minibatch Loss= 0.142824
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.918 vs. 0.065
# F1 = 0.877 vs. 0.097
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.559 vs. 0.188
# F1 = 0.619 vs. 0.319
# Precision = 0.518 vs. 0.190
# Recall = 0.770 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.062
# F1 = 0.564 vs. 0.086
# Accuracy = 0.844 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.105
# F1 = 0.472 vs. 0.182
# Precision = 0.373 vs. 0.100
# Recall = 0.644 vs. 0.997
# Minibatch Loss= 0.117548
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.901 vs. 0.067
# F1 = 0.837 vs. 0.106
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.522 vs. 0.181
# F1 = 0.575 vs. 0.290
# Precision = 0.448 vs. 0.171
# Recall = 0.803 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.544 vs. 0.062
# F1 = 0.570 vs. 0.085
# Accuracy = 0.797 vs. 0.056
# CHANGE DETECTION
# AUC = 0.405 vs. 0.104
# F1 = 0.489 vs. 0.182
# Precision = 0.383 vs. 0.100
# Recall = 0.675 vs. 0.974
# Minibatch Loss= 0.133876
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.936 vs. 0.067
# F1 = 0.891 vs. 0.098
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.543 vs. 0.138
# F1 = 0.590 vs. 0.241
# Precision = 0.457 vs. 0.137
# Recall = 0.831 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.544 vs. 0.061
# F1 = 0.572 vs. 0.084
# Accuracy = 0.828 vs. 0.056
# CHANGE DETECTION
# AUC = 0.406 vs. 0.099
# F1 = 0.505 vs. 0.181
# Precision = 0.430 vs. 0.100
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 0.088873
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.959 vs. 0.068
# F1 = 0.910 vs. 0.105
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.556 vs. 0.177
# F1 = 0.631 vs. 0.299
# Precision = 0.486 vs. 0.176
# Recall = 0.900 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.063
# F1 = 0.578 vs. 0.089
# Accuracy = 0.850 vs. 0.056
# CHANGE DETECTION
# AUC = 0.414 vs. 0.101
# F1 = 0.508 vs. 0.182
# Precision = 0.409 vs. 0.103
# Recall = 0.668 vs. 0.768
# Minibatch Loss= 0.097279
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.960 vs. 0.067
# F1 = 0.925 vs. 0.104
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.571 vs. 0.177
# F1 = 0.643 vs. 0.312
# Precision = 0.509 vs. 0.185
# Recall = 0.874 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.062
# F1 = 0.575 vs. 0.086
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.421 vs. 0.101
# F1 = 0.516 vs. 0.184
# Precision = 0.415 vs. 0.101
# Recall = 0.683 vs. 0.984
# Minibatch Loss= 0.089986
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.947 vs. 0.068
# F1 = 0.906 vs. 0.104
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.556 vs. 0.170
# F1 = 0.622 vs. 0.289
# Precision = 0.488 vs. 0.169
# Recall = 0.857 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.511 vs. 0.061
# F1 = 0.555 vs. 0.087
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.101
# F1 = 0.483 vs. 0.187
# Precision = 0.386 vs. 0.104
# Recall = 0.644 vs. 0.913
# Minibatch Loss= 0.094009
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.067
# F1 = 0.949 vs. 0.099
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.616 vs. 0.153
# F1 = 0.673 vs. 0.279
# Precision = 0.573 vs. 0.162
# Recall = 0.815 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.062
# F1 = 0.584 vs. 0.088
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.425 vs. 0.100
# F1 = 0.517 vs. 0.183
# Precision = 0.443 vs. 0.103
# Recall = 0.620 vs. 0.805
# Minibatch Loss= 0.064891
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.065
# F1 = 0.946 vs. 0.093
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.150
# F1 = 0.681 vs. 0.275
# Precision = 0.606 vs. 0.160
# Recall = 0.778 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.063
# F1 = 0.580 vs. 0.091
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.429 vs. 0.097
# F1 = 0.517 vs. 0.183
# Precision = 0.433 vs. 0.101
# Recall = 0.641 vs. 0.926
# Minibatch Loss= 0.062072
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.070
# F1 = 0.967 vs. 0.105
# Accuracy = 0.965 vs. 0.056
# CHANGE DETECTION
# AUC = 0.678 vs. 0.166
# F1 = 0.717 vs. 0.297
# Precision = 0.597 vs. 0.175
# Recall = 0.898 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.063
# F1 = 0.592 vs. 0.092
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.434 vs. 0.101
# F1 = 0.518 vs. 0.182
# Precision = 0.426 vs. 0.101
# Recall = 0.660 vs. 0.947
# Minibatch Loss= 0.060345
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.067
# F1 = 0.968 vs. 0.096
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.681 vs. 0.161
# F1 = 0.708 vs. 0.270
# Precision = 0.602 vs. 0.156
# Recall = 0.860 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.062
# F1 = 0.590 vs. 0.089
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.439 vs. 0.096
# F1 = 0.522 vs. 0.181
# Precision = 0.433 vs. 0.100
# Recall = 0.657 vs. 1.000
# Minibatch Loss= 0.051776
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.065
# F1 = 0.973 vs. 0.101
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.741 vs. 0.180
# F1 = 0.747 vs. 0.289
# Precision = 0.647 vs. 0.169
# Recall = 0.882 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.064
# F1 = 0.586 vs. 0.087
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.437 vs. 0.099
# F1 = 0.519 vs. 0.181
# Precision = 0.432 vs. 0.100
# Recall = 0.652 vs. 0.997
# Minibatch Loss= 0.049595
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.069
# F1 = 0.968 vs. 0.106
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.739 vs. 0.184
# F1 = 0.751 vs. 0.310
# Precision = 0.653 vs. 0.183
# Recall = 0.884 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.064
# F1 = 0.583 vs. 0.092
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.430 vs. 0.093
# F1 = 0.517 vs. 0.182
# Precision = 0.417 vs. 0.101
# Recall = 0.681 vs. 0.963
# Minibatch Loss= 0.055469
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.952 vs. 0.067
# F1 = 0.908 vs. 0.102
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.650 vs. 0.185
# F1 = 0.677 vs. 0.306
# Precision = 0.596 vs. 0.182
# Recall = 0.783 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.062
# F1 = 0.575 vs. 0.092
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.443 vs. 0.102
# F1 = 0.506 vs. 0.184
# Precision = 0.429 vs. 0.103
# Recall = 0.617 vs. 0.894
# Minibatch Loss= 0.083435
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.068
# F1 = 0.964 vs. 0.104
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.728 vs. 0.183
# F1 = 0.730 vs. 0.296
# Precision = 0.612 vs. 0.182
# Recall = 0.905 vs. 0.804
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.064
# F1 = 0.590 vs. 0.094
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.461 vs. 0.096
# F1 = 0.521 vs. 0.182
# Precision = 0.423 vs. 0.100
# Recall = 0.678 vs. 0.992
# Minibatch Loss= 0.053986
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.068
# F1 = 0.978 vs. 0.097
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.811 vs. 0.167
# F1 = 0.793 vs. 0.296
# Precision = 0.702 vs. 0.174
# Recall = 0.911 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.062
# F1 = 0.592 vs. 0.089
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.469 vs. 0.097
# F1 = 0.528 vs. 0.183
# Precision = 0.478 vs. 0.101
# Recall = 0.591 vs. 0.982
# Minibatch Loss= 0.044170
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.067
# F1 = 0.983 vs. 0.102
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.812 vs. 0.173
# F1 = 0.783 vs. 0.312
# Precision = 0.700 vs. 0.185
# Recall = 0.887 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.062
# F1 = 0.599 vs. 0.088
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.467 vs. 0.102
# F1 = 0.539 vs. 0.181
# Precision = 0.448 vs. 0.100
# Recall = 0.678 vs. 0.997
# Minibatch Loss= 0.044973
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.069
# F1 = 0.960 vs. 0.108
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.787 vs. 0.182
# F1 = 0.763 vs. 0.326
# Precision = 0.688 vs. 0.195
# Recall = 0.856 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.064
# F1 = 0.608 vs. 0.096
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.461 vs. 0.094
# F1 = 0.539 vs. 0.181
# Precision = 0.432 vs. 0.100
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.054166
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.072
# F1 = 0.982 vs. 0.108
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.866 vs. 0.214
# F1 = 0.816 vs. 0.337
# Precision = 0.798 vs. 0.202
# Recall = 0.834 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.063
# F1 = 0.604 vs. 0.089
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.458 vs. 0.101
# F1 = 0.542 vs. 0.183
# Precision = 0.449 vs. 0.101
# Recall = 0.683 vs. 0.987
# Minibatch Loss= 0.043358
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.067
# F1 = 0.974 vs. 0.100
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.828 vs. 0.156
# F1 = 0.788 vs. 0.279
# Precision = 0.734 vs. 0.162
# Recall = 0.851 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.063
# F1 = 0.612 vs. 0.088
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.441 vs. 0.104
# F1 = 0.519 vs. 0.182
# Precision = 0.454 vs. 0.101
# Recall = 0.607 vs. 0.926
# Minibatch Loss= 0.043326
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.069
# F1 = 0.980 vs. 0.106
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.876 vs. 0.228
# F1 = 0.817 vs. 0.342
# Precision = 0.762 vs. 0.206
# Recall = 0.882 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.065
# F1 = 0.604 vs. 0.097
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.452 vs. 0.100
# F1 = 0.532 vs. 0.182
# Precision = 0.435 vs. 0.103
# Recall = 0.686 vs. 0.781
# Minibatch Loss= 0.045944
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.994 vs. 0.102
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.941 vs. 0.180
# F1 = 0.890 vs. 0.312
# Precision = 0.859 vs. 0.185
# Recall = 0.922 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.062
# F1 = 0.591 vs. 0.088
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.464 vs. 0.119
# F1 = 0.541 vs. 0.186
# Precision = 0.456 vs. 0.114
# Recall = 0.665 vs. 0.504
# Minibatch Loss= 0.027172
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.065
# F1 = 0.995 vs. 0.093
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.942 vs. 0.135
# F1 = 0.887 vs. 0.253
# Precision = 0.846 vs. 0.145
# Recall = 0.931 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.063
# F1 = 0.591 vs. 0.092
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.459 vs. 0.094
# F1 = 0.525 vs. 0.181
# Precision = 0.489 vs. 0.100
# Recall = 0.567 vs. 1.000
# Minibatch Loss= 0.022390
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.066
# F1 = 0.996 vs. 0.098
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.182
# F1 = 0.906 vs. 0.293
# Precision = 0.892 vs. 0.175
# Recall = 0.921 vs. 0.885
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.062
# F1 = 0.579 vs. 0.089
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.458 vs. 0.101
# F1 = 0.521 vs. 0.184
# Precision = 0.443 vs. 0.103
# Recall = 0.633 vs. 0.894
# Minibatch Loss= 0.022789
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.069
# F1 = 0.996 vs. 0.104
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.191
# F1 = 0.916 vs. 0.321
# Precision = 0.907 vs. 0.194
# Recall = 0.926 vs. 0.943
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.543 vs. 0.061
# F1 = 0.576 vs. 0.086
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.456 vs. 0.100
# F1 = 0.518 vs. 0.182
# Precision = 0.435 vs. 0.100
# Recall = 0.639 vs. 0.997
# Minibatch Loss= 0.024354
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.995 vs. 0.100
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.138
# F1 = 0.928 vs. 0.247
# Precision = 0.910 vs. 0.142
# Recall = 0.946 vs. 0.958
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.541 vs. 0.063
# F1 = 0.579 vs. 0.093
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.450 vs. 0.095
# F1 = 0.508 vs. 0.185
# Precision = 0.432 vs. 0.103
# Recall = 0.617 vs. 0.884
# Minibatch Loss= 0.017650
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.895 vs. 0.069
# F1 = 0.857 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.718 vs. 0.181
# F1 = 0.712 vs. 0.303
# Precision = 0.627 vs. 0.182
# Recall = 0.824 vs. 0.902
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.064
# F1 = 0.584 vs. 0.092
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.416 vs. 0.101
# F1 = 0.495 vs. 0.183
# Precision = 0.393 vs. 0.105
# Recall = 0.668 vs. 0.712
# Minibatch Loss= 0.133759
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.068
# F1 = 0.975 vs. 0.101
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.911 vs. 0.178
# F1 = 0.863 vs. 0.300
# Precision = 0.851 vs. 0.176
# Recall = 0.876 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.578 vs. 0.062
# F1 = 0.603 vs. 0.084
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.479 vs. 0.096
# F1 = 0.522 vs. 0.181
# Precision = 0.405 vs. 0.100
# Recall = 0.734 vs. 0.989
# Minibatch Loss= 0.033382
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.065
# F1 = 0.991 vs. 0.097
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.168
# F1 = 0.924 vs. 0.288
# Precision = 0.905 vs. 0.168
# Recall = 0.944 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.564 vs. 0.062
# F1 = 0.583 vs. 0.086
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.462 vs. 0.101
# F1 = 0.517 vs. 0.181
# Precision = 0.404 vs. 0.100
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.021118
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.069
# F1 = 0.992 vs. 0.101
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.978 vs. 0.217
# F1 = 0.940 vs. 0.347
# Precision = 0.918 vs. 0.210
# Recall = 0.964 vs. 0.999
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.062
# F1 = 0.575 vs. 0.089
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.461 vs. 0.101
# F1 = 0.519 vs. 0.183
# Precision = 0.411 vs. 0.102
# Recall = 0.704 vs. 0.884
# Minibatch Loss= 0.023842
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.068
# F1 = 0.995 vs. 0.102
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.176
# F1 = 0.958 vs. 0.297
# Precision = 0.957 vs. 0.175
# Recall = 0.959 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.554 vs. 0.063
# F1 = 0.575 vs. 0.090
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.457 vs. 0.102
# F1 = 0.515 vs. 0.182
# Precision = 0.447 vs. 0.100
# Recall = 0.607 vs. 0.976
# Minibatch Loss= 0.014874
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.916 vs. 0.069
# F1 = 0.880 vs. 0.102
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.774 vs. 0.171
# F1 = 0.732 vs. 0.301
# Precision = 0.676 vs. 0.177
# Recall = 0.798 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.067
# F1 = 0.596 vs. 0.094
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.465 vs. 0.102
# F1 = 0.527 vs. 0.183
# Precision = 0.449 vs. 0.102
# Recall = 0.639 vs. 0.887
# Minibatch Loss= 0.099797
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.069
# F1 = 0.982 vs. 0.106
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.944 vs. 0.175
# F1 = 0.883 vs. 0.310
# Precision = 0.882 vs. 0.183
# Recall = 0.884 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.061
# F1 = 0.586 vs. 0.084
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.471 vs. 0.104
# F1 = 0.527 vs. 0.183
# Precision = 0.449 vs. 0.101
# Recall = 0.639 vs. 0.937
# Minibatch Loss= 0.031747
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.068
# F1 = 0.986 vs. 0.103
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.171
# F1 = 0.924 vs. 0.299
# Precision = 0.907 vs. 0.176
# Recall = 0.943 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.063
# F1 = 0.583 vs. 0.093
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.465 vs. 0.104
# F1 = 0.523 vs. 0.184
# Precision = 0.448 vs. 0.103
# Recall = 0.628 vs. 0.879
# Minibatch Loss= 0.021062
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.997 vs. 0.103
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.165
# F1 = 0.956 vs. 0.293
# Precision = 0.943 vs. 0.172
# Recall = 0.969 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.540 vs. 0.062
# F1 = 0.571 vs. 0.087
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.468 vs. 0.097
# F1 = 0.531 vs. 0.187
# Precision = 0.441 vs. 0.105
# Recall = 0.668 vs. 0.855
# Minibatch Loss= 0.014850
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.063
# F1 = 0.997 vs. 0.096
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.148
# F1 = 0.966 vs. 0.263
# Precision = 0.956 vs. 0.152
# Recall = 0.977 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.538 vs. 0.067
# F1 = 0.569 vs. 0.095
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.457 vs. 0.104
# F1 = 0.522 vs. 0.185
# Precision = 0.423 vs. 0.102
# Recall = 0.683 vs. 0.953
# Minibatch Loss= 0.012041
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.995 vs. 0.104
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.180
# F1 = 0.978 vs. 0.303
# Precision = 0.974 vs. 0.179
# Recall = 0.982 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.538 vs. 0.062
# F1 = 0.571 vs. 0.085
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.456 vs. 0.097
# F1 = 0.526 vs. 0.184
# Precision = 0.437 vs. 0.102
# Recall = 0.660 vs. 0.976
# Minibatch Loss= 0.012421
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.103
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.161
# F1 = 0.976 vs. 0.280
# Precision = 0.970 vs. 0.163
# Recall = 0.983 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.530 vs. 0.061
# F1 = 0.564 vs. 0.083
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.457 vs. 0.103
# F1 = 0.517 vs. 0.185
# Precision = 0.428 vs. 0.103
# Recall = 0.654 vs. 0.908
# Minibatch Loss= 0.011035
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.071
# F1 = 0.995 vs. 0.103
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.155
# F1 = 0.964 vs. 0.288
# Precision = 0.959 vs. 0.169
# Recall = 0.968 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.062
# F1 = 0.572 vs. 0.085
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.458 vs. 0.099
# F1 = 0.519 vs. 0.181
# Precision = 0.432 vs. 0.100
# Recall = 0.649 vs. 1.000
# Minibatch Loss= 0.014278
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.104
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.174
# F1 = 0.989 vs. 0.300
# Precision = 0.985 vs. 0.177
# Recall = 0.994 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.063
# F1 = 0.575 vs. 0.086
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.457 vs. 0.111
# F1 = 0.521 vs. 0.182
# Precision = 0.423 vs. 0.102
# Recall = 0.678 vs. 0.860
# Minibatch Loss= 0.009362
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 0.999 vs. 0.105
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.179
# F1 = 0.993 vs. 0.303
# Precision = 0.991 vs. 0.179
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.542 vs. 0.061
# F1 = 0.572 vs. 0.084
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.456 vs. 0.100
# F1 = 0.514 vs. 0.184
# Precision = 0.430 vs. 0.102
# Recall = 0.639 vs. 0.942
# Minibatch Loss= 0.007848
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.999 vs. 0.103
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.181
# F1 = 0.993 vs. 0.300
# Precision = 0.988 vs. 0.176
# Recall = 0.998 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.540 vs. 0.064
# F1 = 0.570 vs. 0.096
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.453 vs. 0.102
# F1 = 0.514 vs. 0.183
# Precision = 0.402 vs. 0.101
# Recall = 0.712 vs. 0.955
# Minibatch Loss= 0.008681
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.999 vs. 0.102
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.183
# F1 = 0.994 vs. 0.301
# Precision = 0.989 vs. 0.182
# Recall = 0.998 vs. 0.863
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.538 vs. 0.062
# F1 = 0.568 vs. 0.088
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.453 vs. 0.110
# F1 = 0.517 vs. 0.191
# Precision = 0.406 vs. 0.110
# Recall = 0.710 vs. 0.718
# Minibatch Loss= 0.006971
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.098
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.150
# F1 = 0.996 vs. 0.259
# Precision = 0.994 vs. 0.150
# Recall = 0.998 vs. 0.938
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.537 vs. 0.062
# F1 = 0.570 vs. 0.085
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.451 vs. 0.101
# F1 = 0.518 vs. 0.184
# Precision = 0.420 vs. 0.102
# Recall = 0.675 vs. 0.926
# Minibatch Loss= 0.005696
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.831 vs. 0.067
# F1 = 0.787 vs. 0.104
# Accuracy = 0.846 vs. 0.056
# CHANGE DETECTION
# AUC = 0.651 vs. 0.182
# F1 = 0.642 vs. 0.307
# Precision = 0.553 vs. 0.182
# Recall = 0.764 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.486 vs. 0.062
# F1 = 0.533 vs. 0.088
# Accuracy = 0.799 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.107
# F1 = 0.461 vs. 0.183
# Precision = 0.394 vs. 0.101
# Recall = 0.554 vs. 0.974
# Minibatch Loss= 0.210247
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.065
# F1 = 0.957 vs. 0.093
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.909 vs. 0.156
# F1 = 0.843 vs. 0.261
# Precision = 0.810 vs. 0.150
# Recall = 0.878 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.619 vs. 0.064
# F1 = 0.631 vs. 0.088
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.463 vs. 0.103
# F1 = 0.516 vs. 0.183
# Precision = 0.402 vs. 0.103
# Recall = 0.718 vs. 0.873
# Minibatch Loss= 0.037749
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.067
# F1 = 0.987 vs. 0.100
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.163
# F1 = 0.909 vs. 0.281
# Precision = 0.883 vs. 0.164
# Recall = 0.937 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.063
# F1 = 0.629 vs. 0.093
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.467 vs. 0.094
# F1 = 0.512 vs. 0.181
# Precision = 0.428 vs. 0.100
# Recall = 0.636 vs. 1.000
# Minibatch Loss= 0.023549
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.067
# F1 = 0.990 vs. 0.103
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.159
# F1 = 0.948 vs. 0.277
# Precision = 0.929 vs. 0.161
# Recall = 0.969 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.062
# F1 = 0.625 vs. 0.087
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.470 vs. 0.098
# F1 = 0.499 vs. 0.184
# Precision = 0.427 vs. 0.102
# Recall = 0.599 vs. 0.902
# Minibatch Loss= 0.017701
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.071
# F1 = 0.995 vs. 0.109
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.183
# F1 = 0.973 vs. 0.308
# Precision = 0.963 vs. 0.183
# Recall = 0.983 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.062
# F1 = 0.622 vs. 0.091
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.476 vs. 0.106
# F1 = 0.508 vs. 0.186
# Precision = 0.444 vs. 0.103
# Recall = 0.594 vs. 0.976
# Minibatch Loss= 0.013800
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.997 vs. 0.104
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.179
# F1 = 0.984 vs. 0.314
# Precision = 0.978 vs. 0.186
# Recall = 0.990 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.063
# F1 = 0.621 vs. 0.091
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.471 vs. 0.099
# F1 = 0.509 vs. 0.182
# Precision = 0.410 vs. 0.100
# Recall = 0.670 vs. 0.997
# Minibatch Loss= 0.011586
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.095
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.179
# F1 = 0.994 vs. 0.280
# Precision = 0.992 vs. 0.163
# Recall = 0.996 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.061
# F1 = 0.614 vs. 0.092
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.472 vs. 0.114
# F1 = 0.515 vs. 0.190
# Precision = 0.420 vs. 0.121
# Recall = 0.665 vs. 0.451
# Minibatch Loss= 0.008314
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.921 vs. 0.068
# F1 = 0.883 vs. 0.102
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.851 vs. 0.177
# F1 = 0.775 vs. 0.295
# Precision = 0.792 vs. 0.174
# Recall = 0.759 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.064
# F1 = 0.584 vs. 0.089
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.414 vs. 0.102
# F1 = 0.479 vs. 0.184
# Precision = 0.369 vs. 0.104
# Recall = 0.683 vs. 0.781
# Minibatch Loss= 0.120306
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.068
# F1 = 0.974 vs. 0.103
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.956 vs. 0.175
# F1 = 0.908 vs. 0.295
# Precision = 0.881 vs. 0.175
# Recall = 0.936 vs. 0.933
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.639 vs. 0.063
# F1 = 0.657 vs. 0.091
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.487 vs. 0.104
# F1 = 0.537 vs. 0.185
# Precision = 0.444 vs. 0.103
# Recall = 0.681 vs. 0.881
# Minibatch Loss= 0.028619
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.996 vs. 0.101
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.178
# F1 = 0.971 vs. 0.300
# Precision = 0.959 vs. 0.178
# Recall = 0.984 vs. 0.948
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.062
# F1 = 0.639 vs. 0.085
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.105
# F1 = 0.549 vs. 0.187
# Precision = 0.461 vs. 0.103
# Recall = 0.678 vs. 0.947
# Minibatch Loss= 0.013466
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.069
# F1 = 0.997 vs. 0.102
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.177
# F1 = 0.991 vs. 0.297
# Precision = 0.988 vs. 0.174
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.064
# F1 = 0.637 vs. 0.091
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.498 vs. 0.100
# F1 = 0.542 vs. 0.185
# Precision = 0.450 vs. 0.107
# Recall = 0.683 vs. 0.683
# Minibatch Loss= 0.009606
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 0.998 vs. 0.101
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.193
# F1 = 0.997 vs. 0.302
# Precision = 0.996 vs. 0.178
# Recall = 0.998 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.632 vs. 0.063
# F1 = 0.640 vs. 0.092
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.502 vs. 0.112
# F1 = 0.534 vs. 0.183
# Precision = 0.452 vs. 0.103
# Recall = 0.652 vs. 0.802
# Minibatch Loss= 0.008565
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.999 vs. 0.100
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.167
# F1 = 0.996 vs. 0.283
# Precision = 0.994 vs. 0.165
# Recall = 0.998 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.062
# F1 = 0.636 vs. 0.088
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.504 vs. 0.108
# F1 = 0.534 vs. 0.187
# Precision = 0.452 vs. 0.106
# Recall = 0.654 vs. 0.792
# Minibatch Loss= 0.007156
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.998 vs. 0.103
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.182
# F1 = 0.995 vs. 0.304
# Precision = 0.990 vs. 0.179
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.627 vs. 0.063
# F1 = 0.633 vs. 0.093
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.503 vs. 0.097
# F1 = 0.533 vs. 0.182
# Precision = 0.446 vs. 0.101
# Recall = 0.662 vs. 0.913
# Minibatch Loss= 0.006555
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.999 vs. 0.101
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.180
# F1 = 0.998 vs. 0.283
# Precision = 0.996 vs. 0.165
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.062
# F1 = 0.626 vs. 0.086
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.505 vs. 0.093
# F1 = 0.532 vs. 0.182
# Precision = 0.448 vs. 0.100
# Recall = 0.654 vs. 0.971
# Minibatch Loss= 0.005842
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.102
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.153
# F1 = 0.999 vs. 0.275
# Precision = 0.998 vs. 0.159
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.062
# F1 = 0.625 vs. 0.086
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.503 vs. 0.098
# F1 = 0.527 vs. 0.184
# Precision = 0.443 vs. 0.106
# Recall = 0.649 vs. 0.691
# Minibatch Loss= 0.004719
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.102
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.149
# F1 = 0.998 vs. 0.261
# Precision = 0.995 vs. 0.150
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.061
# F1 = 0.622 vs. 0.087
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.501 vs. 0.097
# F1 = 0.526 vs. 0.182
# Precision = 0.415 vs. 0.101
# Recall = 0.718 vs. 0.987
# Minibatch Loss= 0.004162
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.098
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.153
# F1 = 1.000 vs. 0.272
# Precision = 1.000 vs. 0.157
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.063
# F1 = 0.622 vs. 0.092
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.501 vs. 0.110
# F1 = 0.527 vs. 0.183
# Precision = 0.416 vs. 0.106
# Recall = 0.720 vs. 0.673
# Minibatch Loss= 0.003475
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.102
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.189
# F1 = 0.995 vs. 0.305
# Precision = 0.993 vs. 0.181
# Recall = 0.997 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.063
# F1 = 0.630 vs. 0.092
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.498 vs. 0.097
# F1 = 0.516 vs. 0.181
# Precision = 0.433 vs. 0.100
# Recall = 0.639 vs. 0.997
# Minibatch Loss= 0.004629
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.108
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.173
# F1 = 1.000 vs. 0.306
# Precision = 1.000 vs. 0.180
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.062
# F1 = 0.621 vs. 0.090
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.499 vs. 0.094
# F1 = 0.525 vs. 0.183
# Precision = 0.423 vs. 0.101
# Recall = 0.694 vs. 0.989
# Minibatch Loss= 0.004013
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.178
# F1 = 1.000 vs. 0.314
# Precision = 1.000 vs. 0.187
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.063
# F1 = 0.619 vs. 0.085
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.496 vs. 0.101
# F1 = 0.522 vs. 0.181
# Precision = 0.421 vs. 0.100
# Recall = 0.686 vs. 0.997
# Minibatch Loss= 0.002923
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.178
# F1 = 1.000 vs. 0.288
# Precision = 1.000 vs. 0.168
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.063
# F1 = 0.619 vs. 0.087
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.492 vs. 0.105
# F1 = 0.517 vs. 0.182
# Precision = 0.410 vs. 0.101
# Recall = 0.699 vs. 0.902
# Minibatch Loss= 0.002938
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.107
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.231
# F1 = 1.000 vs. 0.389
# Precision = 1.000 vs. 0.243
# Recall = 1.000 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.061
# F1 = 0.620 vs. 0.087
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.491 vs. 0.110
# F1 = 0.517 vs. 0.183
# Precision = 0.405 vs. 0.101
# Recall = 0.715 vs. 0.979
# Minibatch Loss= 0.003517
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.102
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.161
# F1 = 1.000 vs. 0.292
# Precision = 1.000 vs. 0.174
# Recall = 1.000 vs. 0.923
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.062
# F1 = 0.621 vs. 0.086
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.490 vs. 0.098
# F1 = 0.517 vs. 0.184
# Precision = 0.418 vs. 0.102
# Recall = 0.675 vs. 0.913
# Minibatch Loss= 0.002330
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.100
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.157
# F1 = 1.000 vs. 0.278
# Precision = 1.000 vs. 0.162
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.062
# F1 = 0.619 vs. 0.087
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.101
# F1 = 0.520 vs. 0.183
# Precision = 0.425 vs. 0.101
# Recall = 0.670 vs. 0.968
# Minibatch Loss= 0.001738
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.172
# F1 = 1.000 vs. 0.288
# Precision = 1.000 vs. 0.168
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.061
# F1 = 0.619 vs. 0.085
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.099
# F1 = 0.518 vs. 0.183
# Precision = 0.422 vs. 0.101
# Recall = 0.670 vs. 0.987
# Minibatch Loss= 0.001795
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.162
# F1 = 1.000 vs. 0.283
# Precision = 1.000 vs. 0.165
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.061
# F1 = 0.618 vs. 0.085
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.487 vs. 0.110
# F1 = 0.517 vs. 0.185
# Precision = 0.410 vs. 0.103
# Recall = 0.699 vs. 0.913
# Minibatch Loss= 0.001699
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.849 vs. 0.066
# F1 = 0.807 vs. 0.100
# Accuracy = 0.769 vs. 0.056
# CHANGE DETECTION
# AUC = 0.658 vs. 0.187
# F1 = 0.637 vs. 0.305
# Precision = 0.576 vs. 0.180
# Recall = 0.713 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.454 vs. 0.063
# F1 = 0.512 vs. 0.088
# Accuracy = 0.666 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.102
# F1 = 0.383 vs. 0.182
# Precision = 0.289 vs. 0.100
# Recall = 0.567 vs. 0.992
# Minibatch Loss= 0.304118
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.837 vs. 0.066
# F1 = 0.799 vs. 0.096
# Accuracy = 0.807 vs. 0.056
# CHANGE DETECTION
# AUC = 0.716 vs. 0.183
# F1 = 0.681 vs. 0.293
# Precision = 0.596 vs. 0.172
# Recall = 0.794 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.502 vs. 0.063
# F1 = 0.559 vs. 0.088
# Accuracy = 0.773 vs. 0.056
# CHANGE DETECTION
# AUC = 0.389 vs. 0.105
# F1 = 0.448 vs. 0.181
# Precision = 0.377 vs. 0.100
# Recall = 0.551 vs. 1.000
# Minibatch Loss= 0.151131
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.942 vs. 0.066
# F1 = 0.895 vs. 0.099
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.835 vs. 0.163
# F1 = 0.775 vs. 0.296
# Precision = 0.715 vs. 0.174
# Recall = 0.846 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.063
# F1 = 0.588 vs. 0.088
# Accuracy = 0.823 vs. 0.056
# CHANGE DETECTION
# AUC = 0.438 vs. 0.098
# F1 = 0.477 vs. 0.185
# Precision = 0.455 vs. 0.106
# Recall = 0.501 vs. 0.739
# Minibatch Loss= 0.079931
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.961 vs. 0.068
# F1 = 0.930 vs. 0.105
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.878 vs. 0.182
# F1 = 0.817 vs. 0.308
# Precision = 0.758 vs. 0.182
# Recall = 0.887 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.063
# F1 = 0.594 vs. 0.091
# Accuracy = 0.841 vs. 0.056
# CHANGE DETECTION
# AUC = 0.439 vs. 0.107
# F1 = 0.496 vs. 0.186
# Precision = 0.436 vs. 0.109
# Recall = 0.575 vs. 0.628
# Minibatch Loss= 0.065168
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.069
# F1 = 0.950 vs. 0.100
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.923 vs. 0.180
# F1 = 0.866 vs. 0.298
# Precision = 0.829 vs. 0.175
# Recall = 0.906 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.063
# F1 = 0.585 vs. 0.092
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.443 vs. 0.093
# F1 = 0.489 vs. 0.184
# Precision = 0.422 vs. 0.101
# Recall = 0.580 vs. 0.979
# Minibatch Loss= 0.046204
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.069
# F1 = 0.970 vs. 0.107
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.959 vs. 0.205
# F1 = 0.909 vs. 0.322
# Precision = 0.902 vs. 0.192
# Recall = 0.917 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.539 vs. 0.063
# F1 = 0.588 vs. 0.087
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.446 vs. 0.099
# F1 = 0.495 vs. 0.182
# Precision = 0.435 vs. 0.100
# Recall = 0.575 vs. 0.992
# Minibatch Loss= 0.039222
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.065
# F1 = 0.971 vs. 0.097
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.949 vs. 0.175
# F1 = 0.894 vs. 0.281
# Precision = 0.864 vs. 0.163
# Recall = 0.925 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.064
# F1 = 0.594 vs. 0.095
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.439 vs. 0.096
# F1 = 0.486 vs. 0.181
# Precision = 0.359 vs. 0.100
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.032725
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.066
# F1 = 0.114 vs. 0.101
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.178 vs. 0.176
# F1 = 0.305 vs. 0.303
# Precision = 0.181 vs. 0.179
# Recall = 0.973 vs. 0.966
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.062
# F1 = 0.094 vs. 0.084
# Accuracy = 0.026 vs. 0.056
# CHANGE DETECTION
# AUC = 0.103 vs. 0.099
# F1 = 0.188 vs. 0.183
# Precision = 0.104 vs. 0.102
# Recall = 0.955 vs. 0.908
# Minibatch Loss= 1.878335
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.066
# F1 = 0.108 vs. 0.101
# Accuracy = 0.023 vs. 0.056
# CHANGE DETECTION
# AUC = 0.187 vs. 0.172
# F1 = 0.303 vs. 0.295
# Precision = 0.179 vs. 0.173
# Recall = 0.996 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.063
# F1 = 0.089 vs. 0.089
# Accuracy = 0.016 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.101
# F1 = 0.190 vs. 0.182
# Precision = 0.108 vs. 0.101
# Recall = 0.768 vs. 0.960
# Minibatch Loss= 1.258207
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.065
# F1 = 0.105 vs. 0.096
# Accuracy = 0.018 vs. 0.056
# CHANGE DETECTION
# AUC = 0.152 vs. 0.143
# F1 = 0.256 vs. 0.260
# Precision = 0.147 vs. 0.151
# Recall = 1.000 vs. 0.929
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.088 vs. 0.088
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.102 vs. 0.095
# F1 = 0.187 vs. 0.183
# Precision = 0.105 vs. 0.103
# Recall = 0.847 vs. 0.868
# Minibatch Loss= 1.145764
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.078 vs. 0.068
# F1 = 0.133 vs. 0.104
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.170 vs. 0.162
# F1 = 0.277 vs. 0.277
# Precision = 0.163 vs. 0.160
# Recall = 0.910 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.098 vs. 0.090
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.096
# F1 = 0.184 vs. 0.181
# Precision = 0.111 vs. 0.100
# Recall = 0.538 vs. 0.987
# Minibatch Loss= 1.250162
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.072
# F1 = 0.117 vs. 0.111
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.214 vs. 0.223
# F1 = 0.352 vs. 0.351
# Precision = 0.215 vs. 0.213
# Recall = 0.960 vs. 0.999
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.063
# F1 = 0.098 vs. 0.086
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.102
# F1 = 0.184 vs. 0.186
# Precision = 0.104 vs. 0.104
# Recall = 0.834 vs. 0.842
# Minibatch Loss= 1.410242
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.070
# F1 = 0.109 vs. 0.107
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.179 vs. 0.188
# F1 = 0.317 vs. 0.324
# Precision = 0.188 vs. 0.196
# Recall = 1.000 vs. 0.930
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.097 vs. 0.085
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.106
# F1 = 0.184 vs. 0.182
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 0.987
# Minibatch Loss= 1.326020
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.066
# F1 = 0.107 vs. 0.094
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.170 vs. 0.152
# F1 = 0.263 vs. 0.261
# Precision = 0.152 vs. 0.150
# Recall = 0.996 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.099 vs. 0.090
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.098
# F1 = 0.184 vs. 0.186
# Precision = 0.104 vs. 0.103
# Recall = 0.842 vs. 0.976
# Minibatch Loss= 1.181553
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.067
# F1 = 0.103 vs. 0.101
# Accuracy = 0.094 vs. 0.056
# CHANGE DETECTION
# AUC = 0.158 vs. 0.177
# F1 = 0.295 vs. 0.296
# Precision = 0.173 vs. 0.174
# Recall = 1.000 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.061
# F1 = 0.093 vs. 0.084
# Accuracy = 0.081 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.098
# F1 = 0.184 vs. 0.185
# Precision = 0.104 vs. 0.102
# Recall = 0.834 vs. 0.955
# Minibatch Loss= 1.275455
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.068
# F1 = 0.121 vs. 0.104
# Accuracy = 0.082 vs. 0.056
# CHANGE DETECTION
# AUC = 0.208 vs. 0.193
# F1 = 0.322 vs. 0.321
# Precision = 0.192 vs. 0.191
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.063
# F1 = 0.096 vs. 0.088
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.100
# F1 = 0.184 vs. 0.186
# Precision = 0.104 vs. 0.103
# Recall = 0.834 vs. 0.968
# Minibatch Loss= 1.361667
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.066
# F1 = 0.105 vs. 0.098
# Accuracy = 0.686 vs. 0.056
# CHANGE DETECTION
# AUC = 0.170 vs. 0.173
# F1 = 0.300 vs. 0.299
# Precision = 0.176 vs. 0.176
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.061
# F1 = 0.094 vs. 0.083
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.102
# F1 = 0.185 vs. 0.185
# Precision = 0.103 vs. 0.103
# Recall = 0.879 vs. 0.902
# Minibatch Loss= 1.339992
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.066
# F1 = 0.106 vs. 0.095
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.154 vs. 0.163
# F1 = 0.274 vs. 0.275
# Precision = 0.159 vs. 0.160
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.063
# F1 = 0.095 vs. 0.091
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.111
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 0.984
# Minibatch Loss= 1.225941
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.067
# F1 = 0.108 vs. 0.102
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.180 vs. 0.186
# F1 = 0.295 vs. 0.295
# Precision = 0.173 vs. 0.174
# Recall = 1.000 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.100 vs. 0.086
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.094
# F1 = 0.184 vs. 0.183
# Precision = 0.103 vs. 0.101
# Recall = 0.887 vs. 0.974
# Minibatch Loss= 1.292781
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.067
# F1 = 0.113 vs. 0.104
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.208 vs. 0.169
# F1 = 0.301 vs. 0.296
# Precision = 0.224 vs. 0.174
# Recall = 0.458 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.064
# F1 = 0.095 vs. 0.089
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.110
# F1 = 0.184 vs. 0.182
# Precision = 0.104 vs. 0.101
# Recall = 0.834 vs. 0.950
# Minibatch Loss= 1.263317
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.064
# F1 = 0.115 vs. 0.095
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.176 vs. 0.136
# F1 = 0.269 vs. 0.248
# Precision = 0.197 vs. 0.142
# Recall = 0.427 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.063
# F1 = 0.096 vs. 0.094
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.105
# F1 = 0.184 vs. 0.183
# Precision = 0.104 vs. 0.101
# Recall = 0.834 vs. 0.982
# Minibatch Loss= 1.181451
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.077 vs. 0.068
# F1 = 0.124 vs. 0.102
# Accuracy = 0.047 vs. 0.056
# CHANGE DETECTION
# AUC = 0.186 vs. 0.166
# F1 = 0.283 vs. 0.283
# Precision = 0.165 vs. 0.165
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.063
# F1 = 0.099 vs. 0.084
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.096
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.842 vs. 0.947
# Minibatch Loss= 1.235889
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.066
# F1 = 0.117 vs. 0.095
# Accuracy = 0.030 vs. 0.056
# CHANGE DETECTION
# AUC = 0.192 vs. 0.153
# F1 = 0.282 vs. 0.268
# Precision = 0.238 vs. 0.156
# Recall = 0.345 vs. 0.965
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.099 vs. 0.083
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.098
# F1 = 0.184 vs. 0.182
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 0.982
# Minibatch Loss= 1.226279
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.065
# F1 = 0.107 vs. 0.097
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.170 vs. 0.166
# F1 = 0.291 vs. 0.290
# Precision = 0.170 vs. 0.170
# Recall = 0.998 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.100 vs. 0.090
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.100
# F1 = 0.185 vs. 0.183
# Precision = 0.103 vs. 0.101
# Recall = 0.879 vs. 0.950
# Minibatch Loss= 1.288340
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.068
# F1 = 0.124 vs. 0.102
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.195 vs. 0.180
# F1 = 0.302 vs. 0.300
# Precision = 0.178 vs. 0.177
# Recall = 0.996 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.100 vs. 0.087
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.094
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 1.000
# Minibatch Loss= 1.269218
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.077 vs. 0.067
# F1 = 0.122 vs. 0.100
# Accuracy = 0.673 vs. 0.056
# CHANGE DETECTION
# AUC = 0.172 vs. 0.161
# F1 = 0.285 vs. 0.285
# Precision = 0.166 vs. 0.166
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.061
# F1 = 0.099 vs. 0.086
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.101
# F1 = 0.184 vs. 0.183
# Precision = 0.104 vs. 0.101
# Recall = 0.834 vs. 0.968
# Minibatch Loss= 1.296556
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.069
# F1 = 0.110 vs. 0.102
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.188 vs. 0.174
# F1 = 0.296 vs. 0.295
# Precision = 0.174 vs. 0.173
# Recall = 0.993 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.089 vs. 0.086
# Accuracy = 0.021 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.106
# F1 = 0.184 vs. 0.182
# Precision = 0.103 vs. 0.101
# Recall = 0.887 vs. 0.939
# Minibatch Loss= 1.264104
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.066
# F1 = 0.112 vs. 0.101
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.161 vs. 0.180
# F1 = 0.291 vs. 0.294
# Precision = 0.171 vs. 0.174
# Recall = 0.998 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.063
# F1 = 0.096 vs. 0.089
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.093
# F1 = 0.184 vs. 0.182
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 0.997
# Minibatch Loss= 1.308285
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.069
# F1 = 0.107 vs. 0.106
# Accuracy = 0.068 vs. 0.056
# CHANGE DETECTION
# AUC = 0.170 vs. 0.175
# F1 = 0.305 vs. 0.305
# Precision = 0.180 vs. 0.181
# Recall = 1.000 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.094 vs. 0.086
# Accuracy = 0.054 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.099
# F1 = 0.184 vs. 0.182
# Precision = 0.103 vs. 0.100
# Recall = 0.887 vs. 0.997
# Minibatch Loss= 1.317866
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.066
# F1 = 0.102 vs. 0.100
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.169 vs. 0.161
# F1 = 0.282 vs. 0.285
# Precision = 0.164 vs. 0.167
# Recall = 0.994 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.061
# F1 = 0.096 vs. 0.088
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.095
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 0.937
# Minibatch Loss= 1.253134
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.068
# F1 = 0.117 vs. 0.104
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.193 vs. 0.182
# F1 = 0.302 vs. 0.303
# Precision = 0.178 vs. 0.178
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.097 vs. 0.086
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.108
# F1 = 0.185 vs. 0.182
# Precision = 0.103 vs. 0.100
# Recall = 0.879 vs. 0.992
# Minibatch Loss= 1.283299
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.067
# F1 = 0.125 vs. 0.101
# Accuracy = 0.058 vs. 0.056
# CHANGE DETECTION
# AUC = 0.179 vs. 0.163
# F1 = 0.275 vs. 0.279
# Precision = 0.160 vs. 0.164
# Recall = 1.000 vs. 0.948
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.063
# F1 = 0.092 vs. 0.093
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.096
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 1.000
# Minibatch Loss= 1.217947
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.069
# F1 = 0.108 vs. 0.104
# Accuracy = 0.021 vs. 0.056
# CHANGE DETECTION
# AUC = 0.210 vs. 0.199
# F1 = 0.346 vs. 0.344
# Precision = 0.211 vs. 0.208
# Recall = 0.976 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.065
# F1 = 0.094 vs. 0.090
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.104
# F1 = 0.185 vs. 0.183
# Precision = 0.106 vs. 0.102
# Recall = 0.720 vs. 0.934
# Minibatch Loss= 1.451560
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.077 vs. 0.067
# F1 = 0.125 vs. 0.104
# Accuracy = 0.015 vs. 0.056
# CHANGE DETECTION
# AUC = 0.200 vs. 0.196
# F1 = 0.319 vs. 0.315
# Precision = 0.190 vs. 0.187
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.063
# F1 = 0.098 vs. 0.087
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.101
# F1 = 0.184 vs. 0.183
# Precision = 0.104 vs. 0.101
# Recall = 0.834 vs. 0.984
# Minibatch Loss= 1.311498
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.066
# F1 = 0.109 vs. 0.096
# Accuracy = 0.097 vs. 0.056
# CHANGE DETECTION
# AUC = 0.168 vs. 0.160
# F1 = 0.281 vs. 0.279
# Precision = 0.164 vs. 0.162
# Recall = 0.983 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.099 vs. 0.088
# Accuracy = 0.082 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.098
# F1 = 0.185 vs. 0.182
# Precision = 0.103 vs. 0.100
# Recall = 0.879 vs. 0.984
# Minibatch Loss= 1.240944
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.068
# F1 = 0.108 vs. 0.101
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.178 vs. 0.175
# F1 = 0.306 vs. 0.303
# Precision = 0.181 vs. 0.178
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.061
# F1 = 0.098 vs. 0.083
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.095 vs. 0.099
# F1 = 0.186 vs. 0.184
# Precision = 0.107 vs. 0.104
# Recall = 0.720 vs. 0.807
# Minibatch Loss= 1.312766
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.067
# F1 = 0.116 vs. 0.105
# Accuracy = 0.676 vs. 0.056
# CHANGE DETECTION
# AUC = 0.189 vs. 0.192
# F1 = 0.305 vs. 0.303
# Precision = 0.180 vs. 0.179
# Recall = 0.988 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.063
# F1 = 0.097 vs. 0.090
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.095
# F1 = 0.184 vs. 0.185
# Precision = 0.104 vs. 0.102
# Recall = 0.834 vs. 0.971
# Minibatch Loss= 1.292797
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.070
# F1 = 0.112 vs. 0.105
# Accuracy = 0.019 vs. 0.056
# CHANGE DETECTION
# AUC = 0.168 vs. 0.171
# F1 = 0.285 vs. 0.284
# Precision = 0.167 vs. 0.165
# Recall = 0.968 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.064
# F1 = 0.092 vs. 0.089
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.102
# F1 = 0.184 vs. 0.182
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 0.995
# Minibatch Loss= 1.284998
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.068
# F1 = 0.108 vs. 0.104
# Accuracy = 0.707 vs. 0.056
# CHANGE DETECTION
# AUC = 0.177 vs. 0.186
# F1 = 0.315 vs. 0.314
# Precision = 0.187 vs. 0.187
# Recall = 0.983 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.065
# F1 = 0.095 vs. 0.091
# Accuracy = 0.826 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.102
# F1 = 0.184 vs. 0.183
# Precision = 0.103 vs. 0.103
# Recall = 0.887 vs. 0.868
# Minibatch Loss= 1.329469
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.081 vs. 0.066
# F1 = 0.137 vs. 0.102
# Accuracy = 0.691 vs. 0.056
# CHANGE DETECTION
# AUC = 0.182 vs. 0.184
# F1 = 0.296 vs. 0.297
# Precision = 0.174 vs. 0.176
# Recall = 1.000 vs. 0.960
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.090 vs. 0.084
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.104
# F1 = 0.184 vs. 0.181
# Precision = 0.103 vs. 0.100
# Recall = 0.887 vs. 0.997
# Minibatch Loss= 1.257730
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.064
# F1 = 0.100 vs. 0.093
# Accuracy = 0.013 vs. 0.056
# CHANGE DETECTION
# AUC = 0.131 vs. 0.144
# F1 = 0.258 vs. 0.255
# Precision = 0.148 vs. 0.146
# Recall = 0.987 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.061
# F1 = 0.093 vs. 0.084
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.094
# F1 = 0.184 vs. 0.182
# Precision = 0.104 vs. 0.100
# Recall = 0.842 vs. 0.995
# Minibatch Loss= 1.181301
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.068
# F1 = 0.115 vs. 0.101
# Accuracy = 0.630 vs. 0.056
# CHANGE DETECTION
# AUC = 0.202 vs. 0.196
# F1 = 0.323 vs. 0.318
# Precision = 0.206 vs. 0.189
# Recall = 0.737 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.093 vs. 0.090
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.101 vs. 0.103
# F1 = 0.185 vs. 0.182
# Precision = 0.104 vs. 0.105
# Recall = 0.834 vs. 0.694
# Minibatch Loss= 1.332803
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.066
# F1 = 0.105 vs. 0.099
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.138 vs. 0.163
# F1 = 0.269 vs. 0.270
# Precision = 0.155 vs. 0.156
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.064
# F1 = 0.095 vs. 0.090
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.103
# F1 = 0.185 vs. 0.182
# Precision = 0.103 vs. 0.101
# Recall = 0.879 vs. 0.887
# Minibatch Loss= 1.205429
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.068
# F1 = 0.117 vs. 0.097
# Accuracy = 0.042 vs. 0.056
# CHANGE DETECTION
# AUC = 0.206 vs. 0.158
# F1 = 0.289 vs. 0.277
# Precision = 0.179 vs. 0.161
# Recall = 0.745 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.093 vs. 0.084
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.109
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.842 vs. 1.000
# Minibatch Loss= 1.218790
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.069
# F1 = 0.110 vs. 0.101
# Accuracy = 0.016 vs. 0.056
# CHANGE DETECTION
# AUC = 0.197 vs. 0.198
# F1 = 0.324 vs. 0.328
# Precision = 0.194 vs. 0.197
# Recall = 0.982 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.064
# F1 = 0.094 vs. 0.089
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.098
# F1 = 0.184 vs. 0.183
# Precision = 0.104 vs. 0.101
# Recall = 0.842 vs. 0.997
# Minibatch Loss= 1.349372
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.065
# F1 = 0.104 vs. 0.099
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.143 vs. 0.163
# F1 = 0.276 vs. 0.276
# Precision = 0.162 vs. 0.161
# Recall = 0.954 vs. 0.969
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.061
# F1 = 0.091 vs. 0.085
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.101
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.834 vs. 0.989
# Minibatch Loss= 1.241761
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.068
# F1 = 0.109 vs. 0.105
# Accuracy = 0.689 vs. 0.056
# CHANGE DETECTION
# AUC = 0.175 vs. 0.189
# F1 = 0.307 vs. 0.306
# Precision = 0.181 vs. 0.181
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.060
# F1 = 0.096 vs. 0.082
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.100 vs. 0.100
# F1 = 0.184 vs. 0.181
# Precision = 0.104 vs. 0.100
# Recall = 0.842 vs. 0.987
# Minibatch Loss= 1.341832
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e877f88d5a2e> in <module>()
#       2                 train_eval_step = 100,
#       3                 validation_eval_step = 100,
# ----> 4                 display_step = 100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/RCNN_Wmultitask_8_opp/RCNN_Wmultitask_8_opp-20000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.057
# F1 = 0.646 vs. 0.076
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.144 vs. 0.027
# F1 = 0.247 vs. 0.054
# Precision = 0.176 vs. 0.028
# Recall = 0.418 vs. 0.485

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2
