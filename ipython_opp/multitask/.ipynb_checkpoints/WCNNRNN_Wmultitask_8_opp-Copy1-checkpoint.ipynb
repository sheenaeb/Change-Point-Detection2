# %%
# useing this variable for saving models and summaries
exp_name = "WCNNRNN_Wmultitask_8_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.WCNNRNN_model_2 as WCNNRNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 8    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [2, 2, 2]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.40793684,  51.83632019,  50.54312354,  53.39606396,
#         53.49661121,  43.82919412,  45.64978903,  64.85852569,
#         69.47649402,  84.21001927,  98.26823793,  89.34525026,
#         99.39500568,  75.77777778,  76.17975567,  46.17226667,
#         13.60019809,  65.60240964,  20.4471387 ])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = WCNNRNN_model.Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)
# Out:
# Tensor("Squeeze_27:0", shape=(?, ?, 19), dtype=float32) Tensor("Reshape_9:0", shape=(?, ?, 19), dtype=float32)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.060
# F1 = 0.094 vs. 0.087
# Accuracy = 0.031 vs. 0.056
# CHANGE DETECTION
# AUC = 0.040 vs. 0.046
# F1 = 0.084 vs. 0.088
# Precision = 0.044 vs. 0.049
# Recall = 0.998 vs. 0.437
# Validation: 0
# ACTIVITY RECOGNITION
# AUC = 0.056 vs. 0.057
# F1 = 0.075 vs. 0.077
# Accuracy = 0.014 vs. 0.056
# CHANGE DETECTION
# AUC = 0.019 vs. 0.027
# F1 = 0.050 vs. 0.054
# Precision = 0.025 vs. 0.029
# Recall = 1.000 vs. 0.469
# Minibatch Loss= 1.263349
# Training: 100
# ACTIVITY RECOGNITION
# AUC = 0.769 vs. 0.058
# F1 = 0.728 vs. 0.083
# Accuracy = 0.728 vs. 0.056
# CHANGE DETECTION
# AUC = 0.129 vs. 0.044
# F1 = 0.215 vs. 0.082
# Precision = 0.137 vs. 0.051
# Recall = 0.498 vs. 0.220
# Validation: 100
# ACTIVITY RECOGNITION
# AUC = 0.472 vs. 0.057
# F1 = 0.500 vs. 0.076
# Accuracy = 0.739 vs. 0.056
# CHANGE DETECTION
# AUC = 0.090 vs. 0.027
# F1 = 0.158 vs. 0.052
# Precision = 0.103 vs. 0.027
# Recall = 0.340 vs. 0.961
# Minibatch Loss= 0.217908
# Training: 200
# ACTIVITY RECOGNITION
# AUC = 0.914 vs. 0.059
# F1 = 0.856 vs. 0.088
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.195 vs. 0.053
# F1 = 0.291 vs. 0.099
# Precision = 0.195 vs. 0.054
# Recall = 0.568 vs. 0.573
# Validation: 200
# ACTIVITY RECOGNITION
# AUC = 0.519 vs. 0.057
# F1 = 0.547 vs. 0.075
# Accuracy = 0.846 vs. 0.056
# CHANGE DETECTION
# AUC = 0.110 vs. 0.027
# F1 = 0.188 vs. 0.052
# Precision = 0.114 vs. 0.027
# Recall = 0.531 vs. 0.588
# Minibatch Loss= 0.142962
# Training: 300
# ACTIVITY RECOGNITION
# AUC = 0.958 vs. 0.058
# F1 = 0.908 vs. 0.085
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.237 vs. 0.047
# F1 = 0.330 vs. 0.089
# Precision = 0.240 vs. 0.048
# Recall = 0.527 vs. 0.647
# Validation: 300
# ACTIVITY RECOGNITION
# AUC = 0.539 vs. 0.057
# F1 = 0.568 vs. 0.075
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.112 vs. 0.024
# F1 = 0.197 vs. 0.051
# Precision = 0.122 vs. 0.026
# Recall = 0.508 vs. 0.588
# Minibatch Loss= 0.093840
# Training: 400
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.058
# F1 = 0.934 vs. 0.083
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.343 vs. 0.050
# F1 = 0.411 vs. 0.093
# Precision = 0.317 vs. 0.053
# Recall = 0.584 vs. 0.355
# Validation: 400
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.057
# F1 = 0.558 vs. 0.076
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.125 vs. 0.024
# F1 = 0.202 vs. 0.051
# Precision = 0.132 vs. 0.026
# Recall = 0.423 vs. 0.804
# Minibatch Loss= 0.072535
# Training: 500
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.058
# F1 = 0.929 vs. 0.086
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.045
# F1 = 0.398 vs. 0.095
# Precision = 0.296 vs. 0.050
# Recall = 0.609 vs. 0.965
# Validation: 500
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.057
# F1 = 0.567 vs. 0.078
# Accuracy = 0.787 vs. 0.056
# CHANGE DETECTION
# AUC = 0.119 vs. 0.025
# F1 = 0.204 vs. 0.051
# Precision = 0.133 vs. 0.027
# Recall = 0.443 vs. 0.505
# Minibatch Loss= 0.087027
# Training: 600
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.058
# F1 = 0.958 vs. 0.084
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.442 vs. 0.054
# F1 = 0.491 vs. 0.102
# Precision = 0.416 vs. 0.054
# Recall = 0.600 vs. 0.978
# Validation: 600
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.057
# F1 = 0.587 vs. 0.076
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.134 vs. 0.028
# F1 = 0.220 vs. 0.050
# Precision = 0.147 vs. 0.025
# Recall = 0.433 vs. 1.000
# Minibatch Loss= 0.057270
# Training: 700
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.058
# F1 = 0.979 vs. 0.086
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.506 vs. 0.053
# F1 = 0.577 vs. 0.101
# Precision = 0.450 vs. 0.055
# Recall = 0.803 vs. 0.683
# Validation: 700
# ACTIVITY RECOGNITION
# AUC = 0.575 vs. 0.057
# F1 = 0.579 vs. 0.076
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.133 vs. 0.026
# F1 = 0.224 vs. 0.053
# Precision = 0.154 vs. 0.028
# Recall = 0.412 vs. 0.657
# Minibatch Loss= 0.043437
# Training: 800
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.059
# F1 = 0.940 vs. 0.083
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.040
# F1 = 0.453 vs. 0.078
# Precision = 0.341 vs. 0.041
# Recall = 0.671 vs. 0.931
# Validation: 800
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.057
# F1 = 0.559 vs. 0.075
# Accuracy = 0.844 vs. 0.056
# CHANGE DETECTION
# AUC = 0.126 vs. 0.025
# F1 = 0.206 vs. 0.051
# Precision = 0.146 vs. 0.027
# Recall = 0.345 vs. 0.830
# Minibatch Loss= 0.059530
# Training: 900
# ACTIVITY RECOGNITION
# AUC = 0.966 vs. 0.059
# F1 = 0.913 vs. 0.083
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.441 vs. 0.043
# F1 = 0.475 vs. 0.082
# Precision = 0.387 vs. 0.043
# Recall = 0.613 vs. 0.890
# Validation: 900
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.057
# F1 = 0.612 vs. 0.074
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.147 vs. 0.026
# F1 = 0.233 vs. 0.053
# Precision = 0.173 vs. 0.028
# Recall = 0.356 vs. 0.523
# Minibatch Loss= 0.063303
# Training: 1000
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.059
# F1 = 0.966 vs. 0.086
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.527 vs. 0.055
# F1 = 0.578 vs. 0.101
# Precision = 0.451 vs. 0.056
# Recall = 0.803 vs. 0.497
# Validation: 1000
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.057
# F1 = 0.592 vs. 0.077
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.162 vs. 0.024
# F1 = 0.259 vs. 0.050
# Precision = 0.177 vs. 0.026
# Recall = 0.477 vs. 0.997
# Minibatch Loss= 0.044560
# Training: 1100
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.058
# F1 = 0.977 vs. 0.085
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.598 vs. 0.049
# F1 = 0.645 vs. 0.095
# Precision = 0.538 vs. 0.050
# Recall = 0.804 vs. 0.995
# Validation: 1100
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.058
# F1 = 0.584 vs. 0.077
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.160 vs. 0.028
# F1 = 0.249 vs. 0.056
# Precision = 0.184 vs. 0.030
# Recall = 0.384 vs. 0.314
# Minibatch Loss= 0.036178
# Training: 1200
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.059
# F1 = 0.985 vs. 0.087
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.683 vs. 0.055
# F1 = 0.718 vs. 0.102
# Precision = 0.606 vs. 0.054
# Recall = 0.881 vs. 0.952
# Validation: 1200
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.057
# F1 = 0.578 vs. 0.075
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.157 vs. 0.025
# F1 = 0.257 vs. 0.051
# Precision = 0.199 vs. 0.026
# Recall = 0.363 vs. 0.719
# Minibatch Loss= 0.032517
# Training: 1300
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.057
# F1 = 0.988 vs. 0.084
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.047
# F1 = 0.748 vs. 0.089
# Precision = 0.661 vs. 0.047
# Recall = 0.862 vs. 0.777
# Validation: 1300
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.057
# F1 = 0.580 vs. 0.077
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.159 vs. 0.027
# F1 = 0.265 vs. 0.058
# Precision = 0.200 vs. 0.032
# Recall = 0.392 vs. 0.278
# Minibatch Loss= 0.023316
# Training: 1400
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.058
# F1 = 0.991 vs. 0.086
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.783 vs. 0.052
# F1 = 0.798 vs. 0.096
# Precision = 0.692 vs. 0.051
# Recall = 0.944 vs. 0.916
# Validation: 1400
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.057
# F1 = 0.578 vs. 0.076
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.158 vs. 0.025
# F1 = 0.265 vs. 0.052
# Precision = 0.201 vs. 0.028
# Recall = 0.389 vs. 0.312
# Minibatch Loss= 0.022557
# Training: 1500
# ACTIVITY RECOGNITION
# AUC = 0.692 vs. 0.057
# F1 = 0.671 vs. 0.086
# Accuracy = 0.669 vs. 0.056
# CHANGE DETECTION
# AUC = 0.250 vs. 0.053
# F1 = 0.337 vs. 0.095
# Precision = 0.276 vs. 0.050
# Recall = 0.434 vs. 0.976
# Validation: 1500
# ACTIVITY RECOGNITION
# AUC = 0.392 vs. 0.056
# F1 = 0.423 vs. 0.075
# Accuracy = 0.624 vs. 0.056
# CHANGE DETECTION
# AUC = 0.075 vs. 0.025
# F1 = 0.139 vs. 0.050
# Precision = 0.093 vs. 0.026
# Recall = 0.273 vs. 0.747
# Minibatch Loss= 0.423268
# Training: 1600
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.059
# F1 = 0.949 vs. 0.084
# Accuracy = 0.948 vs. 0.056
# CHANGE DETECTION
# AUC = 0.501 vs. 0.047
# F1 = 0.539 vs. 0.089
# Precision = 0.411 vs. 0.049
# Recall = 0.783 vs. 0.458
# Validation: 1600
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.058
# F1 = 0.632 vs. 0.080
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.176 vs. 0.025
# F1 = 0.267 vs. 0.051
# Precision = 0.222 vs. 0.027
# Recall = 0.332 vs. 0.397
# Minibatch Loss= 0.047124
# Training: 1700
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.058
# F1 = 0.977 vs. 0.085
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.636 vs. 0.045
# F1 = 0.656 vs. 0.083
# Precision = 0.555 vs. 0.045
# Recall = 0.800 vs. 0.496
# Validation: 1700
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.057
# F1 = 0.635 vs. 0.077
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.174 vs. 0.025
# F1 = 0.255 vs. 0.050
# Precision = 0.174 vs. 0.026
# Recall = 0.472 vs. 1.000
# Minibatch Loss= 0.028628
# Training: 1800
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.056
# F1 = 0.947 vs. 0.082
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.613 vs. 0.044
# F1 = 0.611 vs. 0.086
# Precision = 0.512 vs. 0.047
# Recall = 0.757 vs. 0.515
# Validation: 1800
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.057
# F1 = 0.641 vs. 0.076
# Accuracy = 0.794 vs. 0.056
# CHANGE DETECTION
# AUC = 0.166 vs. 0.024
# F1 = 0.254 vs. 0.050
# Precision = 0.198 vs. 0.026
# Recall = 0.356 vs. 0.990
# Minibatch Loss= 0.057162
# Training: 1900
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.059
# F1 = 0.982 vs. 0.089
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.709 vs. 0.052
# F1 = 0.735 vs. 0.099
# Precision = 0.638 vs. 0.052
# Recall = 0.866 vs. 0.941
# Validation: 1900
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.057
# F1 = 0.626 vs. 0.076
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.173 vs. 0.025
# F1 = 0.262 vs. 0.051
# Precision = 0.219 vs. 0.027
# Recall = 0.327 vs. 0.706
# Minibatch Loss= 0.028276
# Training: 2000
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.057
# F1 = 0.989 vs. 0.083
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.815 vs. 0.042
# F1 = 0.817 vs. 0.085
# Precision = 0.741 vs. 0.045
# Recall = 0.910 vs. 0.998
# Validation: 2000
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.057
# F1 = 0.620 vs. 0.076
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.166 vs. 0.026
# F1 = 0.264 vs. 0.053
# Precision = 0.199 vs. 0.028
# Recall = 0.394 vs. 0.459
# Minibatch Loss= 0.017576
# Training: 2100
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.057
# F1 = 0.994 vs. 0.084
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.874 vs. 0.048
# F1 = 0.851 vs. 0.088
# Precision = 0.818 vs. 0.048
# Recall = 0.888 vs. 0.533
# Validation: 2100
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.057
# F1 = 0.612 vs. 0.076
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.160 vs. 0.026
# F1 = 0.258 vs. 0.054
# Precision = 0.199 vs. 0.029
# Recall = 0.366 vs. 0.454
# Minibatch Loss= 0.015462
# Training: 2200
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.059
# F1 = 0.996 vs. 0.088
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.873 vs. 0.047
# F1 = 0.885 vs. 0.092
# Precision = 0.811 vs. 0.048
# Recall = 0.974 vs. 0.971
# Validation: 2200
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.056
# F1 = 0.602 vs. 0.076
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.162 vs. 0.026
# F1 = 0.260 vs. 0.051
# Precision = 0.218 vs. 0.027
# Recall = 0.322 vs. 0.619
# Minibatch Loss= 0.014335
# Training: 2300
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.059
# F1 = 0.997 vs. 0.088
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.937 vs. 0.053
# F1 = 0.930 vs. 0.097
# Precision = 0.882 vs. 0.051
# Recall = 0.984 vs. 0.956
# Validation: 2300
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.057
# F1 = 0.595 vs. 0.076
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.157 vs. 0.026
# F1 = 0.258 vs. 0.051
# Precision = 0.202 vs. 0.026
# Recall = 0.356 vs. 0.905
# Minibatch Loss= 0.012521
# Training: 2400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.995 vs. 0.086
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.917 vs. 0.041
# F1 = 0.891 vs. 0.086
# Precision = 0.824 vs. 0.045
# Recall = 0.969 vs. 0.921
# Validation: 2400
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.057
# F1 = 0.597 vs. 0.076
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.157 vs. 0.024
# F1 = 0.255 vs. 0.050
# Precision = 0.205 vs. 0.026
# Recall = 0.335 vs. 0.936
# Minibatch Loss= 0.012679
# Training: 2500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.058
# F1 = 0.998 vs. 0.085
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.056
# F1 = 0.954 vs. 0.102
# Precision = 0.927 vs. 0.055
# Recall = 0.982 vs. 0.703
# Validation: 2500
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.056
# F1 = 0.587 vs. 0.074
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.152 vs. 0.026
# F1 = 0.262 vs. 0.051
# Precision = 0.211 vs. 0.027
# Recall = 0.345 vs. 0.485
# Minibatch Loss= 0.011061
# Training: 2600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.057
# F1 = 0.999 vs. 0.086
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.981 vs. 0.047
# F1 = 0.960 vs. 0.091
# Precision = 0.936 vs. 0.048
# Recall = 0.985 vs. 0.805
# Validation: 2600
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.056
# F1 = 0.580 vs. 0.074
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.151 vs. 0.027
# F1 = 0.258 vs. 0.050
# Precision = 0.195 vs. 0.026
# Recall = 0.384 vs. 0.997
# Minibatch Loss= 0.008154
# Training: 2700
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.058
# F1 = 0.655 vs. 0.085
# Accuracy = 0.745 vs. 0.056
# CHANGE DETECTION
# AUC = 0.162 vs. 0.045
# F1 = 0.249 vs. 0.089
# Precision = 0.189 vs. 0.046
# Recall = 0.366 vs. 0.995
# Validation: 2700
# ACTIVITY RECOGNITION
# AUC = 0.388 vs. 0.057
# F1 = 0.452 vs. 0.077
# Accuracy = 0.691 vs. 0.056
# CHANGE DETECTION
# AUC = 0.076 vs. 0.024
# F1 = 0.138 vs. 0.051
# Precision = 0.085 vs. 0.026
# Recall = 0.366 vs. 0.722
# Minibatch Loss= 0.355774
# Training: 2800
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.059
# F1 = 0.941 vs. 0.087
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.485 vs. 0.046
# F1 = 0.539 vs. 0.094
# Precision = 0.494 vs. 0.050
# Recall = 0.594 vs. 0.855
# Validation: 2800
# ACTIVITY RECOGNITION
# AUC = 0.636 vs. 0.056
# F1 = 0.627 vs. 0.074
# Accuracy = 0.850 vs. 0.056
# CHANGE DETECTION
# AUC = 0.137 vs. 0.027
# F1 = 0.226 vs. 0.052
# Precision = 0.165 vs. 0.031
# Recall = 0.358 vs. 0.157
# Minibatch Loss= 0.055985
# Training: 2900
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.058
# F1 = 0.971 vs. 0.083
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.656 vs. 0.041
# F1 = 0.678 vs. 0.084
# Precision = 0.571 vs. 0.044
# Recall = 0.834 vs. 0.993
# Validation: 2900
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.057
# F1 = 0.650 vs. 0.079
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.150 vs. 0.028
# F1 = 0.229 vs. 0.052
# Precision = 0.145 vs. 0.028
# Recall = 0.552 vs. 0.428
# Minibatch Loss= 0.030037
# Training: 3000
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.059
# F1 = 0.982 vs. 0.086
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.742 vs. 0.055
# F1 = 0.751 vs. 0.100
# Precision = 0.654 vs. 0.054
# Recall = 0.883 vs. 0.661
# Validation: 3000
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.057
# F1 = 0.640 vs. 0.074
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.148 vs. 0.024
# F1 = 0.234 vs. 0.050
# Precision = 0.157 vs. 0.026
# Recall = 0.461 vs. 1.000
# Minibatch Loss= 0.027750
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.059
# F1 = 0.991 vs. 0.085
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.831 vs. 0.049
# F1 = 0.825 vs. 0.090
# Precision = 0.740 vs. 0.047
# Recall = 0.933 vs. 0.920
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.057
# F1 = 0.639 vs. 0.076
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.148 vs. 0.027
# F1 = 0.233 vs. 0.053
# Precision = 0.178 vs. 0.031
# Recall = 0.340 vs. 0.201
# Minibatch Loss= 0.018787
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 0.866 vs. 0.057
# F1 = 0.813 vs. 0.082
# Accuracy = 0.787 vs. 0.056
# CHANGE DETECTION
# AUC = 0.314 vs. 0.047
# F1 = 0.395 vs. 0.086
# Precision = 0.338 vs. 0.048
# Recall = 0.475 vs. 0.472
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.493 vs. 0.057
# F1 = 0.536 vs. 0.076
# Accuracy = 0.645 vs. 0.056
# CHANGE DETECTION
# AUC = 0.099 vs. 0.027
# F1 = 0.186 vs. 0.054
# Precision = 0.124 vs. 0.033
# Recall = 0.374 vs. 0.147
# Minibatch Loss= 0.170483
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.058
# F1 = 0.958 vs. 0.086
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.622 vs. 0.049
# F1 = 0.632 vs. 0.092
# Precision = 0.543 vs. 0.048
# Recall = 0.756 vs. 0.876
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.057
# F1 = 0.668 vs. 0.074
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.153 vs. 0.026
# F1 = 0.254 vs. 0.051
# Precision = 0.186 vs. 0.026
# Recall = 0.399 vs. 0.838
# Minibatch Loss= 0.040064
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.057
# F1 = 0.971 vs. 0.081
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.721 vs. 0.044
# F1 = 0.725 vs. 0.087
# Precision = 0.615 vs. 0.046
# Recall = 0.881 vs. 1.000
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.057
# F1 = 0.656 vs. 0.076
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.161 vs. 0.025
# F1 = 0.262 vs. 0.050
# Precision = 0.201 vs. 0.026
# Recall = 0.376 vs. 0.781
# Minibatch Loss= 0.029448
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.058
# F1 = 0.985 vs. 0.084
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.798 vs. 0.055
# F1 = 0.793 vs. 0.095
# Precision = 0.702 vs. 0.053
# Recall = 0.913 vs. 0.485
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.056
# F1 = 0.659 vs. 0.074
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.166 vs. 0.028
# F1 = 0.266 vs. 0.053
# Precision = 0.218 vs. 0.030
# Recall = 0.340 vs. 0.245
# Minibatch Loss= 0.021866
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.057
# F1 = 0.991 vs. 0.084
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.871 vs. 0.050
# F1 = 0.855 vs. 0.087
# Precision = 0.812 vs. 0.046
# Recall = 0.903 vs. 0.950
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.057
# F1 = 0.662 vs. 0.079
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.171 vs. 0.029
# F1 = 0.273 vs. 0.052
# Precision = 0.213 vs. 0.027
# Recall = 0.381 vs. 0.830
# Minibatch Loss= 0.016132
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.059
# F1 = 0.993 vs. 0.083
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.043
# F1 = 0.886 vs. 0.081
# Precision = 0.836 vs. 0.043
# Recall = 0.943 vs. 0.568
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.057
# F1 = 0.661 vs. 0.075
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.172 vs. 0.024
# F1 = 0.266 vs. 0.051
# Precision = 0.225 vs. 0.026
# Recall = 0.325 vs. 0.910
# Minibatch Loss= 0.012526
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.058
# F1 = 0.993 vs. 0.083
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.903 vs. 0.042
# F1 = 0.885 vs. 0.084
# Precision = 0.855 vs. 0.052
# Recall = 0.917 vs. 0.229
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.057
# F1 = 0.659 vs. 0.075
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.171 vs. 0.025
# F1 = 0.269 vs. 0.052
# Precision = 0.218 vs. 0.027
# Recall = 0.353 vs. 0.683
# Minibatch Loss= 0.013191
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.058
# F1 = 0.996 vs. 0.083
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.043
# F1 = 0.937 vs. 0.081
# Precision = 0.921 vs. 0.042
# Recall = 0.954 vs. 0.996
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.057
# F1 = 0.657 vs. 0.076
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.174 vs. 0.029
# F1 = 0.270 vs. 0.051
# Precision = 0.222 vs. 0.026
# Recall = 0.345 vs. 0.714
# Minibatch Loss= 0.009911
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.059
# F1 = 0.996 vs. 0.087
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.045
# F1 = 0.960 vs. 0.092
# Precision = 0.930 vs. 0.048
# Recall = 0.992 vs. 0.990
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.663 vs. 0.057
# F1 = 0.658 vs. 0.075
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.172 vs. 0.026
# F1 = 0.270 vs. 0.051
# Precision = 0.207 vs. 0.027
# Recall = 0.387 vs. 0.495
# Minibatch Loss= 0.009116
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.058
# F1 = 0.997 vs. 0.088
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.057
# F1 = 0.972 vs. 0.103
# Precision = 0.959 vs. 0.055
# Recall = 0.987 vs. 0.776
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.056
# F1 = 0.659 vs. 0.073
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.173 vs. 0.026
# F1 = 0.270 vs. 0.050
# Precision = 0.214 vs. 0.026
# Recall = 0.366 vs. 0.997
# Minibatch Loss= 0.008343
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.058
# F1 = 0.994 vs. 0.084
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.046
# F1 = 0.962 vs. 0.090
# Precision = 0.958 vs. 0.048
# Recall = 0.966 vs. 0.681
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.057
# F1 = 0.655 vs. 0.076
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.166 vs. 0.026
# F1 = 0.264 vs. 0.051
# Precision = 0.206 vs. 0.028
# Recall = 0.369 vs. 0.291
# Minibatch Loss= 0.009319
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.058
# F1 = 0.994 vs. 0.087
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.053
# F1 = 0.942 vs. 0.098
# Precision = 0.924 vs. 0.052
# Recall = 0.960 vs. 0.873
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.057
# F1 = 0.658 vs. 0.074
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.172 vs. 0.026
# F1 = 0.282 vs. 0.053
# Precision = 0.230 vs. 0.028
# Recall = 0.363 vs. 0.668
# Minibatch Loss= 0.010448
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 0.926 vs. 0.058
# F1 = 0.871 vs. 0.087
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.417 vs. 0.051
# F1 = 0.441 vs. 0.099
# Precision = 0.393 vs. 0.053
# Recall = 0.503 vs. 0.818
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.057
# F1 = 0.593 vs. 0.074
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.108 vs. 0.026
# F1 = 0.189 vs. 0.053
# Precision = 0.118 vs. 0.029
# Recall = 0.479 vs. 0.379
# Minibatch Loss= 0.145696
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.058
# F1 = 0.948 vs. 0.084
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.579 vs. 0.051
# F1 = 0.596 vs. 0.091
# Precision = 0.474 vs. 0.048
# Recall = 0.803 vs. 0.904
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.056
# F1 = 0.676 vs. 0.073
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.163 vs. 0.027
# F1 = 0.264 vs. 0.054
# Precision = 0.189 vs. 0.032
# Recall = 0.441 vs. 0.186
# Minibatch Loss= 0.048567
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.058
# F1 = 0.978 vs. 0.081
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.817 vs. 0.037
# F1 = 0.804 vs. 0.079
# Precision = 0.701 vs. 0.041
# Recall = 0.943 vs. 0.933
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.057
# F1 = 0.664 vs. 0.077
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.178 vs. 0.027
# F1 = 0.266 vs. 0.054
# Precision = 0.233 vs. 0.029
# Recall = 0.309 vs. 0.469
# Minibatch Loss= 0.019162
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.057
# F1 = 0.991 vs. 0.081
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.911 vs. 0.044
# F1 = 0.882 vs. 0.086
# Precision = 0.841 vs. 0.045
# Recall = 0.927 vs. 0.883
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.057
# F1 = 0.664 vs. 0.076
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.179 vs. 0.026
# F1 = 0.278 vs. 0.052
# Precision = 0.258 vs. 0.027
# Recall = 0.302 vs. 0.665
# Minibatch Loss= 0.013213
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.058
# F1 = 0.995 vs. 0.085
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.953 vs. 0.043
# F1 = 0.923 vs. 0.088
# Precision = 0.876 vs. 0.046
# Recall = 0.976 vs. 0.998
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.057
# F1 = 0.664 vs. 0.078
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.174 vs. 0.026
# F1 = 0.266 vs. 0.052
# Precision = 0.214 vs. 0.027
# Recall = 0.353 vs. 0.683
# Minibatch Loss= 0.010973
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.058
# F1 = 0.997 vs. 0.084
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.976 vs. 0.048
# F1 = 0.966 vs. 0.090
# Precision = 0.940 vs. 0.048
# Recall = 0.995 vs. 0.688
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.057
# F1 = 0.668 vs. 0.075
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.177 vs. 0.026
# F1 = 0.270 vs. 0.053
# Precision = 0.222 vs. 0.027
# Recall = 0.345 vs. 0.879
# Minibatch Loss= 0.008594
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.058
# F1 = 0.996 vs. 0.086
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.056
# F1 = 0.970 vs. 0.104
# Precision = 0.948 vs. 0.056
# Recall = 0.993 vs. 0.721
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.057
# F1 = 0.668 vs. 0.077
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.179 vs. 0.026
# F1 = 0.274 vs. 0.051
# Precision = 0.216 vs. 0.026
# Recall = 0.376 vs. 0.714
# Minibatch Loss= 0.008649
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.998 vs. 0.088
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.046
# F1 = 0.988 vs. 0.092
# Precision = 0.983 vs. 0.049
# Recall = 0.993 vs. 0.865
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.057
# F1 = 0.669 vs. 0.077
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.179 vs. 0.027
# F1 = 0.274 vs. 0.055
# Precision = 0.227 vs. 0.030
# Recall = 0.345 vs. 0.296
# Minibatch Loss= 0.005807
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.999 vs. 0.087
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.051
# F1 = 0.988 vs. 0.094
# Precision = 0.978 vs. 0.050
# Recall = 0.998 vs. 0.972
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.057
# F1 = 0.668 vs. 0.075
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.181 vs. 0.030
# F1 = 0.280 vs. 0.064
# Precision = 0.233 vs. 0.039
# Recall = 0.353 vs. 0.183
# Minibatch Loss= 0.006050
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.058
# F1 = 0.613 vs. 0.083
# Accuracy = 0.642 vs. 0.056
# CHANGE DETECTION
# AUC = 0.182 vs. 0.052
# F1 = 0.250 vs. 0.095
# Precision = 0.185 vs. 0.052
# Recall = 0.388 vs. 0.629
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.341 vs. 0.057
# F1 = 0.390 vs. 0.076
# Accuracy = 0.517 vs. 0.056
# CHANGE DETECTION
# AUC = 0.086 vs. 0.025
# F1 = 0.163 vs. 0.050
# Precision = 0.134 vs. 0.026
# Recall = 0.206 vs. 0.979
# Minibatch Loss= 0.564728
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.058
# F1 = 0.095 vs. 0.085
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.039 vs. 0.045
# F1 = 0.085 vs. 0.085
# Precision = 0.045 vs. 0.044
# Recall = 0.989 vs. 0.998
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.056
# F1 = 0.086 vs. 0.075
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.025
# F1 = 0.056 vs. 0.051
# Precision = 0.029 vs. 0.027
# Recall = 0.686 vs. 0.361
# Minibatch Loss= 1.379263
# Training: 5500
# ACTIVITY RECOGNITION
# AUC = 0.055 vs. 0.058
# F1 = 0.094 vs. 0.083
# Accuracy = 0.014 vs. 0.056
# CHANGE DETECTION
# AUC = 0.042 vs. 0.044
# F1 = 0.084 vs. 0.081
# Precision = 0.054 vs. 0.043
# Recall = 0.189 vs. 0.758
# Validation: 5500
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.089 vs. 0.077
# Accuracy = 0.016 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.024
# F1 = 0.053 vs. 0.051
# Precision = 0.027 vs. 0.026
# Recall = 0.907 vs. 0.912
# Minibatch Loss= 1.272480
# Training: 5600
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.058
# F1 = 0.095 vs. 0.085
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.040 vs. 0.043
# F1 = 0.084 vs. 0.084
# Precision = 0.044 vs. 0.044
# Recall = 0.773 vs. 0.922
# Validation: 5600
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.085 vs. 0.076
# Accuracy = 0.007 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.027
# F1 = 0.055 vs. 0.053
# Precision = 0.030 vs. 0.028
# Recall = 0.379 vs. 0.402
# Minibatch Loss= 1.254266
# Training: 5700
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.058
# F1 = 0.097 vs. 0.087
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.052
# F1 = 0.108 vs. 0.103
# Precision = 0.058 vs. 0.054
# Recall = 0.811 vs. 0.983
# Validation: 5700
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.085 vs. 0.074
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.027 vs. 0.026
# F1 = 0.056 vs. 0.051
# Precision = 0.030 vs. 0.026
# Recall = 0.384 vs. 0.812
# Minibatch Loss= 1.405390
# Training: 5800
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.099 vs. 0.088
# Accuracy = 0.024 vs. 0.056
# CHANGE DETECTION
# AUC = 0.054 vs. 0.052
# F1 = 0.107 vs. 0.102
# Precision = 0.057 vs. 0.054
# Recall = 0.972 vs. 0.867
# Validation: 5800
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.056
# F1 = 0.088 vs. 0.075
# Accuracy = 0.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.027 vs. 0.033
# F1 = 0.056 vs. 0.056
# Precision = 0.030 vs. 0.032
# Recall = 0.384 vs. 0.247
# Minibatch Loss= 1.434554
# Training: 5900
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.057
# F1 = 0.093 vs. 0.082
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.042 vs. 0.037
# F1 = 0.077 vs. 0.074
# Precision = 0.040 vs. 0.039
# Recall = 0.885 vs. 0.807
# Validation: 5900
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.089 vs. 0.077
# Accuracy = 0.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.027 vs. 0.026
# F1 = 0.053 vs. 0.052
# Precision = 0.028 vs. 0.028
# Recall = 0.665 vs. 0.371
# Minibatch Loss= 1.207036
# Training: 6000
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.103 vs. 0.087
# Accuracy = 0.015 vs. 0.056
# CHANGE DETECTION
# AUC = 0.045 vs. 0.046
# F1 = 0.091 vs. 0.091
# Precision = 0.050 vs. 0.048
# Recall = 0.507 vs. 0.848
# Validation: 6000
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.086 vs. 0.077
# Accuracy = 0.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.027 vs. 0.027
# F1 = 0.053 vs. 0.053
# Precision = 0.028 vs. 0.028
# Recall = 0.750 vs. 0.451
# Minibatch Loss= 1.318877
# Training: 6100
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.058
# F1 = 0.091 vs. 0.086
# Accuracy = 0.023 vs. 0.056
# CHANGE DETECTION
# AUC = 0.044 vs. 0.048
# F1 = 0.095 vs. 0.092
# Precision = 0.050 vs. 0.057
# Recall = 0.866 vs. 0.239
# Validation: 6100
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.058
# F1 = 0.089 vs. 0.077
# Accuracy = 0.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.027 vs. 0.027
# F1 = 0.053 vs. 0.051
# Precision = 0.028 vs. 0.027
# Recall = 0.750 vs. 0.366
# Minibatch Loss= 1.284930
# Training: 6200
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.058
# F1 = 0.115 vs. 0.082
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.041
# F1 = 0.089 vs. 0.080
# Precision = 0.056 vs. 0.041
# Recall = 0.221 vs. 0.970
# Validation: 6200
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.086 vs. 0.075
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.027 vs. 0.025
# F1 = 0.053 vs. 0.050
# Precision = 0.028 vs. 0.026
# Recall = 0.750 vs. 0.995
# Minibatch Loss= 1.235822
# Training: 6300
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.103 vs. 0.083
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.044 vs. 0.043
# F1 = 0.086 vs. 0.084
# Precision = 0.045 vs. 0.044
# Recall = 0.954 vs. 0.861
# Validation: 6300
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.090 vs. 0.077
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.025
# F1 = 0.052 vs. 0.052
# Precision = 0.027 vs. 0.027
# Recall = 0.915 vs. 0.923
# Minibatch Loss= 1.232944
# Training: 6400
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.104 vs. 0.085
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.044 vs. 0.050
# F1 = 0.085 vs. 0.086
# Precision = 0.051 vs. 0.047
# Recall = 0.275 vs. 0.488
# Validation: 6400
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.086 vs. 0.077
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.025
# F1 = 0.052 vs. 0.050
# Precision = 0.027 vs. 0.026
# Recall = 0.747 vs. 1.000
# Minibatch Loss= 1.243624
# Training: 6500
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.058
# F1 = 0.101 vs. 0.084
# Accuracy = 0.013 vs. 0.056
# CHANGE DETECTION
# AUC = 0.043 vs. 0.041
# F1 = 0.084 vs. 0.079
# Precision = 0.045 vs. 0.041
# Recall = 0.604 vs. 0.919
# Validation: 6500
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.088 vs. 0.075
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.052 vs. 0.053
# Precision = 0.027 vs. 0.027
# Recall = 0.742 vs. 0.742
# Minibatch Loss= 1.242590
# Training: 6600
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.058
# F1 = 0.103 vs. 0.088
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.049
# F1 = 0.103 vs. 0.097
# Precision = 0.054 vs. 0.051
# Recall = 0.970 vs. 0.997
# Validation: 6600
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.056
# F1 = 0.087 vs. 0.074
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.025
# F1 = 0.053 vs. 0.050
# Precision = 0.028 vs. 0.026
# Recall = 0.637 vs. 0.820
# Minibatch Loss= 1.358099
# Training: 6700
# ACTIVITY RECOGNITION
# AUC = 0.060 vs. 0.058
# F1 = 0.107 vs. 0.085
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.056 vs. 0.052
# F1 = 0.104 vs. 0.099
# Precision = 0.057 vs. 0.052
# Recall = 0.632 vs. 0.886
# Validation: 6700
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.086 vs. 0.075
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.025
# F1 = 0.052 vs. 0.050
# Precision = 0.027 vs. 0.026
# Recall = 0.742 vs. 0.995
# Minibatch Loss= 1.355568
# Training: 6800
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.059
# F1 = 0.098 vs. 0.086
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.048 vs. 0.045
# F1 = 0.095 vs. 0.093
# Precision = 0.050 vs. 0.049
# Recall = 0.926 vs. 0.935
# Validation: 6800
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.087 vs. 0.074
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.024
# F1 = 0.052 vs. 0.051
# Precision = 0.027 vs. 0.026
# Recall = 0.750 vs. 0.758
# Minibatch Loss= 1.362082
# Training: 6900
# ACTIVITY RECOGNITION
# AUC = 0.060 vs. 0.058
# F1 = 0.107 vs. 0.084
# Accuracy = 0.014 vs. 0.056
# CHANGE DETECTION
# AUC = 0.051 vs. 0.046
# F1 = 0.099 vs. 0.088
# Precision = 0.069 vs. 0.046
# Recall = 0.176 vs. 0.962
# Validation: 6900
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.089 vs. 0.075
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.025
# F1 = 0.053 vs. 0.050
# Precision = 0.028 vs. 0.025
# Recall = 0.637 vs. 1.000
# Minibatch Loss= 1.293841
# Training: 7000
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.101 vs. 0.086
# Accuracy = 0.006 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.047
# F1 = 0.094 vs. 0.093
# Precision = 0.050 vs. 0.049
# Recall = 0.896 vs. 1.000
# Validation: 7000
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.056
# F1 = 0.089 vs. 0.074
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.028
# F1 = 0.052 vs. 0.055
# Precision = 0.027 vs. 0.033
# Recall = 0.750 vs. 0.173
# Minibatch Loss= 1.336540
# Training: 7100
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.097 vs. 0.083
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.046 vs. 0.041
# F1 = 0.091 vs. 0.086
# Precision = 0.049 vs. 0.045
# Recall = 0.655 vs. 0.952
# Validation: 7100
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.087 vs. 0.077
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.023
# F1 = 0.052 vs. 0.050
# Precision = 0.027 vs. 0.026
# Recall = 0.742 vs. 0.662
# Minibatch Loss= 1.250013
# Training: 7200
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.105 vs. 0.082
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.046 vs. 0.043
# F1 = 0.088 vs. 0.084
# Precision = 0.047 vs. 0.044
# Recall = 0.785 vs. 0.995
# Validation: 7200
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.087 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.024
# F1 = 0.052 vs. 0.050
# Precision = 0.027 vs. 0.026
# Recall = 0.750 vs. 0.894
# Minibatch Loss= 1.233463
# Training: 7300
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.101 vs. 0.085
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.048 vs. 0.047
# F1 = 0.094 vs. 0.089
# Precision = 0.050 vs. 0.047
# Recall = 0.922 vs. 0.983
# Validation: 7300
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.087 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.024
# F1 = 0.052 vs. 0.051
# Precision = 0.027 vs. 0.026
# Recall = 0.742 vs. 0.899
# Minibatch Loss= 1.291376
# Training: 7400
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.105 vs. 0.085
# Accuracy = 0.017 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.050
# F1 = 0.098 vs. 0.098
# Precision = 0.052 vs. 0.058
# Recall = 0.934 vs. 0.303
# Validation: 7400
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.056
# F1 = 0.087 vs. 0.075
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.027
# F1 = 0.052 vs. 0.054
# Precision = 0.027 vs. 0.031
# Recall = 0.750 vs. 0.222
# Minibatch Loss= 1.327602
# Training: 7500
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.113 vs. 0.083
# Accuracy = 0.041 vs. 0.056
# CHANGE DETECTION
# AUC = 0.039 vs. 0.041
# F1 = 0.082 vs. 0.080
# Precision = 0.043 vs. 0.043
# Recall = 0.822 vs. 0.684
# Validation: 7500
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.084 vs. 0.074
# Accuracy = 0.025 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.024
# F1 = 0.053 vs. 0.050
# Precision = 0.028 vs. 0.026
# Recall = 0.637 vs. 1.000
# Minibatch Loss= 1.250215
# Training: 7600
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.102 vs. 0.088
# Accuracy = 0.570 vs. 0.056
# CHANGE DETECTION
# AUC = 0.054 vs. 0.050
# F1 = 0.102 vs. 0.097
# Precision = 0.054 vs. 0.051
# Recall = 0.856 vs. 0.989
# Validation: 7600
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.056
# F1 = 0.086 vs. 0.074
# Accuracy = 0.744 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.024
# F1 = 0.053 vs. 0.050
# Precision = 0.027 vs. 0.026
# Recall = 0.747 vs. 0.902
# Minibatch Loss= 1.387520
# Training: 7700
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.105 vs. 0.086
# Accuracy = 0.036 vs. 0.056
# CHANGE DETECTION
# AUC = 0.052 vs. 0.051
# F1 = 0.104 vs. 0.095
# Precision = 0.055 vs. 0.050
# Recall = 0.880 vs. 0.833
# Validation: 7700
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.056
# F1 = 0.087 vs. 0.074
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.052 vs. 0.052
# Precision = 0.027 vs. 0.029
# Recall = 0.742 vs. 0.281
# Minibatch Loss= 1.329794
# Training: 7800
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.092 vs. 0.081
# Accuracy = 0.035 vs. 0.056
# CHANGE DETECTION
# AUC = 0.035 vs. 0.034
# F1 = 0.073 vs. 0.066
# Precision = 0.038 vs. 0.035
# Recall = 0.816 vs. 0.809
# Validation: 7800
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.089 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.029
# F1 = 0.053 vs. 0.057
# Precision = 0.028 vs. 0.032
# Recall = 0.637 vs. 0.276
# Minibatch Loss= 1.142281
# Training: 7900
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.057
# F1 = 0.098 vs. 0.082
# Accuracy = 0.019 vs. 0.056
# CHANGE DETECTION
# AUC = 0.044 vs. 0.042
# F1 = 0.087 vs. 0.081
# Precision = 0.046 vs. 0.042
# Recall = 0.764 vs. 0.927
# Validation: 7900
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.027
# F1 = 0.052 vs. 0.053
# Precision = 0.027 vs. 0.029
# Recall = 0.742 vs. 0.268
# Minibatch Loss= 1.241505
# Training: 8000
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.059
# F1 = 0.107 vs. 0.089
# Accuracy = 0.018 vs. 0.056
# CHANGE DETECTION
# AUC = 0.065 vs. 0.060
# F1 = 0.119 vs. 0.115
# Precision = 0.064 vs. 0.061
# Recall = 0.920 vs. 1.000
# Validation: 8000
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.028
# F1 = 0.053 vs. 0.050
# Precision = 0.028 vs. 0.026
# Recall = 0.637 vs. 0.985
# Minibatch Loss= 1.498989
# Training: 8100
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.098 vs. 0.082
# Accuracy = 0.045 vs. 0.056
# CHANGE DETECTION
# AUC = 0.046 vs. 0.045
# F1 = 0.089 vs. 0.083
# Precision = 0.051 vs. 0.044
# Recall = 0.331 vs. 0.996
# Validation: 8100
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.087 vs. 0.077
# Accuracy = 0.026 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.052 vs. 0.051
# Precision = 0.027 vs. 0.026
# Recall = 0.742 vs. 0.737
# Minibatch Loss= 1.228367
# Training: 8200
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.058
# F1 = 0.114 vs. 0.086
# Accuracy = 0.046 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.046
# F1 = 0.097 vs. 0.090
# Precision = 0.052 vs. 0.047
# Recall = 0.705 vs. 1.000
# Validation: 8200
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.056
# F1 = 0.086 vs. 0.075
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.029
# F1 = 0.053 vs. 0.057
# Precision = 0.028 vs. 0.032
# Recall = 0.634 vs. 0.314
# Minibatch Loss= 1.285047
# Training: 8300
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.059
# F1 = 0.102 vs. 0.088
# Accuracy = 0.583 vs. 0.056
# CHANGE DETECTION
# AUC = 0.052 vs. 0.054
# F1 = 0.106 vs. 0.103
# Precision = 0.056 vs. 0.055
# Recall = 0.852 vs. 0.912
# Validation: 8300
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.075
# Accuracy = 0.697 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.025
# F1 = 0.052 vs. 0.052
# Precision = 0.027 vs. 0.027
# Recall = 0.732 vs. 0.711
# Minibatch Loss= 1.393290
# Training: 8400
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.057
# F1 = 0.107 vs. 0.083
# Accuracy = 0.035 vs. 0.056
# CHANGE DETECTION
# AUC = 0.041 vs. 0.039
# F1 = 0.084 vs. 0.079
# Precision = 0.051 vs. 0.042
# Recall = 0.231 vs. 0.750
# Validation: 8400
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.089 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.052 vs. 0.051
# Precision = 0.027 vs. 0.027
# Recall = 0.732 vs. 0.577
# Minibatch Loss= 1.238178
# Training: 8500
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.105 vs. 0.085
# Accuracy = 0.063 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.048
# F1 = 0.098 vs. 0.092
# Precision = 0.074 vs. 0.048
# Recall = 0.146 vs. 0.916
# Validation: 8500
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.086 vs. 0.075
# Accuracy = 0.026 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.052 vs. 0.051
# Precision = 0.027 vs. 0.026
# Recall = 0.732 vs. 0.802
# Minibatch Loss= 1.308558
# Training: 8600
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.098 vs. 0.085
# Accuracy = 0.037 vs. 0.056
# CHANGE DETECTION
# AUC = 0.054 vs. 0.048
# F1 = 0.099 vs. 0.091
# Precision = 0.060 vs. 0.048
# Recall = 0.289 vs. 0.832
# Validation: 8600
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.088 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.028
# F1 = 0.053 vs. 0.054
# Precision = 0.028 vs. 0.029
# Recall = 0.634 vs. 0.482
# Minibatch Loss= 1.273803
# Training: 8700
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.058
# F1 = 0.097 vs. 0.084
# Accuracy = 0.027 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.048
# F1 = 0.093 vs. 0.091
# Precision = 0.049 vs. 0.048
# Recall = 0.998 vs. 0.887
# Validation: 8700
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.083 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.052 vs. 0.051
# Precision = 0.027 vs. 0.027
# Recall = 0.742 vs. 0.791
# Minibatch Loss= 1.290476
# Training: 8800
# ACTIVITY RECOGNITION
# AUC = 0.060 vs. 0.058
# F1 = 0.100 vs. 0.086
# Accuracy = 0.016 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.045
# F1 = 0.090 vs. 0.088
# Precision = 0.048 vs. 0.046
# Recall = 0.605 vs. 0.893
# Validation: 8800
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.056
# F1 = 0.087 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.052 vs. 0.055
# Precision = 0.027 vs. 0.029
# Recall = 0.732 vs. 0.644
# Minibatch Loss= 1.314521
# Training: 8900
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.058
# F1 = 0.096 vs. 0.085
# Accuracy = 0.047 vs. 0.056
# CHANGE DETECTION
# AUC = 0.048 vs. 0.050
# F1 = 0.095 vs. 0.092
# Precision = 0.050 vs. 0.048
# Recall = 0.997 vs. 0.943
# Validation: 8900
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.086 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.026
# F1 = 0.053 vs. 0.050
# Precision = 0.027 vs. 0.026
# Recall = 0.747 vs. 0.876
# Minibatch Loss= 1.321684
# Training: 9000
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.057
# F1 = 0.105 vs. 0.082
# Accuracy = 0.047 vs. 0.056
# CHANGE DETECTION
# AUC = 0.038 vs. 0.038
# F1 = 0.079 vs. 0.076
# Precision = 0.041 vs. 0.040
# Recall = 0.955 vs. 0.687
# Validation: 9000
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.076
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.029
# F1 = 0.052 vs. 0.056
# Precision = 0.027 vs. 0.030
# Recall = 0.732 vs. 0.418
# Minibatch Loss= 1.196503
# Training: 9100
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.106 vs. 0.086
# Accuracy = 0.036 vs. 0.056
# CHANGE DETECTION
# AUC = 0.048 vs. 0.045
# F1 = 0.091 vs. 0.088
# Precision = 0.050 vs. 0.046
# Recall = 0.464 vs. 0.997
# Validation: 9100
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.075
# Accuracy = 0.026 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.030
# F1 = 0.052 vs. 0.055
# Precision = 0.027 vs. 0.028
# Recall = 0.732 vs. 0.729
# Minibatch Loss= 1.334915
# Training: 9200
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.110 vs. 0.085
# Accuracy = 0.016 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.052
# F1 = 0.106 vs. 0.101
# Precision = 0.056 vs. 0.054
# Recall = 0.937 vs. 0.779
# Validation: 9200
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.075
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.028
# F1 = 0.052 vs. 0.054
# Precision = 0.027 vs. 0.030
# Recall = 0.742 vs. 0.271
# Minibatch Loss= 1.340059
# Training: 9300
# ACTIVITY RECOGNITION
# AUC = 0.060 vs. 0.059
# F1 = 0.102 vs. 0.085
# Accuracy = 0.014 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.049
# F1 = 0.100 vs. 0.095
# Precision = 0.053 vs. 0.050
# Recall = 0.893 vs. 0.842
# Validation: 9300
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.088 vs. 0.075
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.026
# F1 = 0.053 vs. 0.052
# Precision = 0.028 vs. 0.029
# Recall = 0.634 vs. 0.222
# Minibatch Loss= 1.354334
# Training: 9400
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.106 vs. 0.087
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.052 vs. 0.048
# F1 = 0.097 vs. 0.099
# Precision = 0.051 vs. 0.052
# Recall = 0.993 vs. 0.812
# Validation: 9400
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.075
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.024
# F1 = 0.052 vs. 0.050
# Precision = 0.027 vs. 0.026
# Recall = 0.742 vs. 0.946
# Minibatch Loss= 1.378132
# Training: 9500
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.058
# F1 = 0.107 vs. 0.084
# Accuracy = 0.037 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.046
# F1 = 0.092 vs. 0.086
# Precision = 0.049 vs. 0.045
# Recall = 0.759 vs. 0.996
# Validation: 9500
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.057
# F1 = 0.087 vs. 0.077
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.025
# F1 = 0.053 vs. 0.050
# Precision = 0.028 vs. 0.026
# Recall = 0.637 vs. 0.992
# Minibatch Loss= 1.288391
# Training: 9600
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.058
# F1 = 0.103 vs. 0.086
# Accuracy = 0.041 vs. 0.056
# CHANGE DETECTION
# AUC = 0.056 vs. 0.054
# F1 = 0.108 vs. 0.101
# Precision = 0.059 vs. 0.055
# Recall = 0.623 vs. 0.712
# Validation: 9600
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.088 vs. 0.077
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.025
# F1 = 0.052 vs. 0.050
# Precision = 0.027 vs. 0.025
# Recall = 0.750 vs. 0.997
# Minibatch Loss= 1.360333
# Training: 9700
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.058
# F1 = 0.096 vs. 0.082
# Accuracy = 0.037 vs. 0.056
# CHANGE DETECTION
# AUC = 0.048 vs. 0.044
# F1 = 0.097 vs. 0.086
# Precision = 0.052 vs. 0.045
# Recall = 0.758 vs. 0.995
# Validation: 9700
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.087 vs. 0.073
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.027
# F1 = 0.053 vs. 0.051
# Precision = 0.028 vs. 0.026
# Recall = 0.634 vs. 0.925
# Minibatch Loss= 1.308653
# Training: 9800
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.103 vs. 0.089
# Accuracy = 0.029 vs. 0.056
# CHANGE DETECTION
# AUC = 0.058 vs. 0.057
# F1 = 0.114 vs. 0.104
# Precision = 0.073 vs. 0.056
# Recall = 0.259 vs. 0.807
# Validation: 9800
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.056
# F1 = 0.086 vs. 0.074
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.026 vs. 0.024
# F1 = 0.053 vs. 0.050
# Precision = 0.028 vs. 0.026
# Recall = 0.637 vs. 1.000
# Minibatch Loss= 1.385829
# Training: 9900
# ACTIVITY RECOGNITION
# AUC = 0.060 vs. 0.058
# F1 = 0.096 vs. 0.086
# Accuracy = 0.049 vs. 0.056
# CHANGE DETECTION
# AUC = 0.049 vs. 0.049
# F1 = 0.093 vs. 0.095
# Precision = 0.049 vs. 0.054
# Recall = 0.806 vs. 0.381
# Validation: 9900
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.057
# F1 = 0.088 vs. 0.074
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.025 vs. 0.027
# F1 = 0.052 vs. 0.051
# Precision = 0.027 vs. 0.027
# Recall = 0.750 vs. 0.629
# Minibatch Loss= 1.277304
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/WCNNRNN_Wmultitask_8_opp/WCNNRNN_Wmultitask_8_opp-10000'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-4495')
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')
# Out:
# INFO:tensorflow:Restoring parameters from ../../model/WCNNRNN_Wmultitask_16_opp_2Adam/WCNNRNN_Wmultitask_16_opp_2Adam-4495

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.060
# F1 = 0.631 vs. 0.082
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.337 vs. 0.053
# F1 = 0.405 vs. 0.101
# Precision = 0.346 vs. 0.054
# Recall = 0.488 vs. 0.766

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2
