# %%
# useing this variable for saving models and summaries
exp_name = "CNN_Wmultitask_64_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)


variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.16329966,  34.21019108,  34.43589744,  37.12413793,
#         36.10067114,  26.70927318,  27.27621483,  39.94814815,
#         42.01945525,  46.65517241,  51.89952153,  48.57847534,
#         51.1509434 ,  43.40160643,  44.68595041,  33.7672956 ,
#         10.65015806,  36.60544218,   2.20649652])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,
                     variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.078 vs. 0.078
# F1 = 0.128 vs. 0.121
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.341
# F1 = 0.505 vs. 0.500
# Precision = 0.338 vs. 0.334
# Recall = 0.996 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.069
# F1 = 0.103 vs. 0.099
# Accuracy = 0.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.136 vs. 0.207
# F1 = 0.317 vs. 0.311
# Precision = 0.190 vs. 0.184
# Recall = 0.966 vs. 1.000
# Minibatch Loss= 1.504769
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.082
# F1 = 0.640 vs. 0.123
# Accuracy = 0.557 vs. 0.056
# CHANGE DETECTION
# AUC = 0.621 vs. 0.320
# F1 = 0.596 vs. 0.490
# Precision = 0.528 vs. 0.325
# Recall = 0.684 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.376 vs. 0.069
# F1 = 0.454 vs. 0.100
# Accuracy = 0.399 vs. 0.056
# CHANGE DETECTION
# AUC = 0.438 vs. 0.174
# F1 = 0.476 vs. 0.311
# Precision = 0.427 vs. 0.184
# Recall = 0.538 vs. 1.000
# Minibatch Loss= 0.395568
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.725 vs. 0.082
# F1 = 0.733 vs. 0.126
# Accuracy = 0.800 vs. 0.056
# CHANGE DETECTION
# AUC = 0.741 vs. 0.345
# F1 = 0.706 vs. 0.505
# Precision = 0.650 vs. 0.338
# Recall = 0.774 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.448 vs. 0.072
# F1 = 0.514 vs. 0.107
# Accuracy = 0.715 vs. 0.056
# CHANGE DETECTION
# AUC = 0.516 vs. 0.191
# F1 = 0.542 vs. 0.318
# Precision = 0.491 vs. 0.199
# Recall = 0.604 vs. 0.789
# Minibatch Loss= 0.300600
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.776 vs. 0.083
# F1 = 0.766 vs. 0.125
# Accuracy = 0.807 vs. 0.056
# CHANGE DETECTION
# AUC = 0.787 vs. 0.388
# F1 = 0.753 vs. 0.532
# Precision = 0.686 vs. 0.363
# Recall = 0.835 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.495 vs. 0.070
# F1 = 0.555 vs. 0.104
# Accuracy = 0.774 vs. 0.056
# CHANGE DETECTION
# AUC = 0.564 vs. 0.197
# F1 = 0.596 vs. 0.314
# Precision = 0.523 vs. 0.187
# Recall = 0.692 vs. 0.986
# Minibatch Loss= 0.250272
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.816 vs. 0.079
# F1 = 0.803 vs. 0.118
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.781 vs. 0.325
# F1 = 0.735 vs. 0.480
# Precision = 0.724 vs. 0.317
# Recall = 0.746 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.502 vs. 0.068
# F1 = 0.573 vs. 0.095
# Accuracy = 0.836 vs. 0.056
# CHANGE DETECTION
# AUC = 0.561 vs. 0.187
# F1 = 0.574 vs. 0.313
# Precision = 0.532 vs. 0.187
# Recall = 0.624 vs. 0.966
# Minibatch Loss= 0.189432
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.856 vs. 0.080
# F1 = 0.826 vs. 0.116
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.813 vs. 0.312
# F1 = 0.773 vs. 0.485
# Precision = 0.703 vs. 0.321
# Recall = 0.858 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.524 vs. 0.071
# F1 = 0.584 vs. 0.102
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.582 vs. 0.186
# F1 = 0.601 vs. 0.311
# Precision = 0.534 vs. 0.184
# Recall = 0.687 vs. 1.000
# Minibatch Loss= 0.155447
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.841 vs. 0.076
# F1 = 0.836 vs. 0.117
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.811 vs. 0.269
# F1 = 0.774 vs. 0.437
# Precision = 0.709 vs. 0.280
# Recall = 0.852 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.535 vs. 0.068
# F1 = 0.591 vs. 0.101
# Accuracy = 0.848 vs. 0.056
# CHANGE DETECTION
# AUC = 0.590 vs. 0.196
# F1 = 0.608 vs. 0.312
# Precision = 0.532 vs. 0.185
# Recall = 0.709 vs. 0.989
# Minibatch Loss= 0.127757
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.893 vs. 0.081
# F1 = 0.869 vs. 0.124
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.850 vs. 0.338
# F1 = 0.809 vs. 0.507
# Precision = 0.774 vs. 0.339
# Recall = 0.847 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.075
# F1 = 0.595 vs. 0.113
# Accuracy = 0.845 vs. 0.056
# CHANGE DETECTION
# AUC = 0.596 vs. 0.188
# F1 = 0.620 vs. 0.312
# Precision = 0.554 vs. 0.185
# Recall = 0.704 vs. 0.994
# Minibatch Loss= 0.118317
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.893 vs. 0.076
# F1 = 0.879 vs. 0.117
# Accuracy = 0.823 vs. 0.056
# CHANGE DETECTION
# AUC = 0.823 vs. 0.245
# F1 = 0.779 vs. 0.418
# Precision = 0.770 vs. 0.265
# Recall = 0.789 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.069
# F1 = 0.590 vs. 0.101
# Accuracy = 0.793 vs. 0.056
# CHANGE DETECTION
# AUC = 0.596 vs. 0.176
# F1 = 0.617 vs. 0.312
# Precision = 0.543 vs. 0.185
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.112010
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.921 vs. 0.081
# F1 = 0.906 vs. 0.124
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.873 vs. 0.371
# F1 = 0.835 vs. 0.518
# Precision = 0.774 vs. 0.350
# Recall = 0.907 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.066
# F1 = 0.592 vs. 0.090
# Accuracy = 0.852 vs. 0.056
# CHANGE DETECTION
# AUC = 0.606 vs. 0.190
# F1 = 0.628 vs. 0.315
# Precision = 0.565 vs. 0.188
# Recall = 0.707 vs. 0.989
# Minibatch Loss= 0.093159
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.934 vs. 0.081
# F1 = 0.923 vs. 0.124
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.855 vs. 0.344
# F1 = 0.825 vs. 0.504
# Precision = 0.774 vs. 0.337
# Recall = 0.883 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.068
# F1 = 0.592 vs. 0.101
# Accuracy = 0.856 vs. 0.056
# CHANGE DETECTION
# AUC = 0.615 vs. 0.187
# F1 = 0.633 vs. 0.320
# Precision = 0.555 vs. 0.193
# Recall = 0.738 vs. 0.940
# Minibatch Loss= 0.084116
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.935 vs. 0.077
# F1 = 0.924 vs. 0.117
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.879 vs. 0.311
# F1 = 0.837 vs. 0.460
# Precision = 0.790 vs. 0.299
# Recall = 0.891 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.069
# F1 = 0.595 vs. 0.101
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.619 vs. 0.194
# F1 = 0.635 vs. 0.314
# Precision = 0.580 vs. 0.187
# Recall = 0.701 vs. 0.986
# Minibatch Loss= 0.069461
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.950 vs. 0.080
# F1 = 0.931 vs. 0.116
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.869 vs. 0.302
# F1 = 0.812 vs. 0.458
# Precision = 0.778 vs. 0.297
# Recall = 0.848 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.068
# F1 = 0.596 vs. 0.101
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.183
# F1 = 0.632 vs. 0.312
# Precision = 0.570 vs. 0.185
# Recall = 0.709 vs. 1.000
# Minibatch Loss= 0.073646
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.958 vs. 0.079
# F1 = 0.944 vs. 0.121
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.882 vs. 0.308
# F1 = 0.834 vs. 0.483
# Precision = 0.777 vs. 0.319
# Recall = 0.901 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.602 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.625 vs. 0.171
# F1 = 0.638 vs. 0.313
# Precision = 0.569 vs. 0.185
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.073279
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.965 vs. 0.079
# F1 = 0.953 vs. 0.124
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.905 vs. 0.304
# F1 = 0.869 vs. 0.485
# Precision = 0.814 vs. 0.320
# Recall = 0.932 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.599 vs. 0.102
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.629 vs. 0.184
# F1 = 0.639 vs. 0.312
# Precision = 0.602 vs. 0.185
# Recall = 0.681 vs. 1.000
# Minibatch Loss= 0.059283
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.961 vs. 0.079
# F1 = 0.944 vs. 0.118
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.898 vs. 0.334
# F1 = 0.855 vs. 0.501
# Precision = 0.801 vs. 0.334
# Recall = 0.917 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.069
# F1 = 0.608 vs. 0.101
# Accuracy = 0.844 vs. 0.056
# CHANGE DETECTION
# AUC = 0.634 vs. 0.191
# F1 = 0.647 vs. 0.313
# Precision = 0.578 vs. 0.185
# Recall = 0.735 vs. 1.000
# Minibatch Loss= 0.077212
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.952 vs. 0.076
# F1 = 0.950 vs. 0.118
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.933 vs. 0.292
# F1 = 0.871 vs. 0.446
# Precision = 0.831 vs. 0.288
# Recall = 0.915 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.067
# F1 = 0.596 vs. 0.098
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.633 vs. 0.175
# F1 = 0.655 vs. 0.315
# Precision = 0.601 vs. 0.188
# Recall = 0.718 vs. 0.969
# Minibatch Loss= 0.049010
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.081
# F1 = 0.973 vs. 0.131
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.930 vs. 0.328
# F1 = 0.882 vs. 0.476
# Precision = 0.844 vs. 0.315
# Recall = 0.924 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.069
# F1 = 0.596 vs. 0.104
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.634 vs. 0.198
# F1 = 0.652 vs. 0.311
# Precision = 0.597 vs. 0.184
# Recall = 0.718 vs. 1.000
# Minibatch Loss= 0.044596
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.081
# F1 = 0.975 vs. 0.124
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.949 vs. 0.317
# F1 = 0.899 vs. 0.475
# Precision = 0.870 vs. 0.311
# Recall = 0.930 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.595 vs. 0.102
# Accuracy = 0.855 vs. 0.056
# CHANGE DETECTION
# AUC = 0.625 vs. 0.200
# F1 = 0.638 vs. 0.314
# Precision = 0.556 vs. 0.187
# Recall = 0.749 vs. 0.983
# Minibatch Loss= 0.039716
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.080
# F1 = 0.978 vs. 0.126
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.965 vs. 0.308
# F1 = 0.912 vs. 0.480
# Precision = 0.872 vs. 0.316
# Recall = 0.956 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.071
# F1 = 0.595 vs. 0.106
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.634 vs. 0.197
# F1 = 0.649 vs. 0.318
# Precision = 0.579 vs. 0.191
# Recall = 0.738 vs. 0.934
# Minibatch Loss= 0.037813
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.078
# F1 = 0.980 vs. 0.122
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.939 vs. 0.289
# F1 = 0.902 vs. 0.453
# Precision = 0.868 vs. 0.294
# Recall = 0.938 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.071
# F1 = 0.594 vs. 0.103
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.634 vs. 0.191
# F1 = 0.646 vs. 0.314
# Precision = 0.589 vs. 0.189
# Recall = 0.715 vs. 0.929
# Minibatch Loss= 0.034647
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.081
# F1 = 0.976 vs. 0.124
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.939 vs. 0.310
# F1 = 0.895 vs. 0.475
# Precision = 0.875 vs. 0.311
# Recall = 0.916 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.070
# F1 = 0.596 vs. 0.108
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.632 vs. 0.189
# F1 = 0.645 vs. 0.318
# Precision = 0.580 vs. 0.192
# Recall = 0.726 vs. 0.937
# Minibatch Loss= 0.034128
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.080
# F1 = 0.983 vs. 0.119
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.944 vs. 0.289
# F1 = 0.908 vs. 0.441
# Precision = 0.888 vs. 0.283
# Recall = 0.929 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.071
# F1 = 0.597 vs. 0.112
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.631 vs. 0.179
# F1 = 0.638 vs. 0.312
# Precision = 0.571 vs. 0.185
# Recall = 0.724 vs. 0.986
# Minibatch Loss= 0.032658
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.081
# F1 = 0.980 vs. 0.124
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.340
# F1 = 0.920 vs. 0.503
# Precision = 0.907 vs. 0.336
# Recall = 0.932 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.072
# F1 = 0.593 vs. 0.107
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.623 vs. 0.188
# F1 = 0.629 vs. 0.314
# Precision = 0.540 vs. 0.187
# Recall = 0.755 vs. 0.986
# Minibatch Loss= 0.037076
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.082
# F1 = 0.966 vs. 0.124
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.934 vs. 0.289
# F1 = 0.889 vs. 0.429
# Precision = 0.869 vs. 0.274
# Recall = 0.911 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.578 vs. 0.070
# F1 = 0.616 vs. 0.103
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.622 vs. 0.185
# F1 = 0.636 vs. 0.313
# Precision = 0.628 vs. 0.186
# Recall = 0.644 vs. 0.994
# Minibatch Loss= 0.040909
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.078
# F1 = 0.985 vs. 0.116
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.327
# F1 = 0.916 vs. 0.492
# Precision = 0.895 vs. 0.326
# Recall = 0.937 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.577 vs. 0.067
# F1 = 0.603 vs. 0.096
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.201
# F1 = 0.635 vs. 0.315
# Precision = 0.578 vs. 0.187
# Recall = 0.704 vs. 0.997
# Minibatch Loss= 0.034954
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.085
# F1 = 0.991 vs. 0.127
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.348
# F1 = 0.923 vs. 0.534
# Precision = 0.903 vs. 0.366
# Recall = 0.943 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.070
# F1 = 0.602 vs. 0.099
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.174
# F1 = 0.640 vs. 0.311
# Precision = 0.606 vs. 0.184
# Recall = 0.678 vs. 1.000
# Minibatch Loss= 0.030221
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.078
# F1 = 0.981 vs. 0.119
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.965 vs. 0.297
# F1 = 0.920 vs. 0.469
# Precision = 0.883 vs. 0.307
# Recall = 0.961 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.069
# F1 = 0.600 vs. 0.100
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.627 vs. 0.187
# F1 = 0.639 vs. 0.312
# Precision = 0.610 vs. 0.185
# Recall = 0.670 vs. 1.000
# Minibatch Loss= 0.029129
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.077
# F1 = 0.984 vs. 0.120
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.318
# F1 = 0.918 vs. 0.494
# Precision = 0.897 vs. 0.328
# Recall = 0.939 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.068
# F1 = 0.596 vs. 0.100
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.625 vs. 0.180
# F1 = 0.634 vs. 0.313
# Precision = 0.607 vs. 0.186
# Recall = 0.664 vs. 0.989
# Minibatch Loss= 0.029449
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.078
# F1 = 0.988 vs. 0.117
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.318
# F1 = 0.938 vs. 0.473
# Precision = 0.927 vs. 0.309
# Recall = 0.949 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.599 vs. 0.099
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.173
# F1 = 0.631 vs. 0.316
# Precision = 0.598 vs. 0.188
# Recall = 0.667 vs. 0.997
# Minibatch Loss= 0.025784
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.079
# F1 = 0.993 vs. 0.119
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.976 vs. 0.312
# F1 = 0.946 vs. 0.459
# Precision = 0.919 vs. 0.298
# Recall = 0.975 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.068
# F1 = 0.594 vs. 0.101
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.629 vs. 0.188
# F1 = 0.638 vs. 0.312
# Precision = 0.613 vs. 0.185
# Recall = 0.667 vs. 1.000
# Minibatch Loss= 0.021341
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.078
# F1 = 0.994 vs. 0.116
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.310
# F1 = 0.926 vs. 0.460
# Precision = 0.900 vs. 0.299
# Recall = 0.954 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.069
# F1 = 0.593 vs. 0.099
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.627 vs. 0.185
# F1 = 0.634 vs. 0.312
# Precision = 0.595 vs. 0.185
# Recall = 0.678 vs. 0.991
# Minibatch Loss= 0.022348
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.075
# F1 = 0.991 vs. 0.117
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.257
# F1 = 0.938 vs. 0.395
# Precision = 0.930 vs. 0.246
# Recall = 0.947 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.069
# F1 = 0.591 vs. 0.100
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.184
# F1 = 0.632 vs. 0.312
# Precision = 0.588 vs. 0.186
# Recall = 0.684 vs. 0.969
# Minibatch Loss= 0.019377
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.077
# F1 = 0.993 vs. 0.118
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.981 vs. 0.298
# F1 = 0.944 vs. 0.461
# Precision = 0.938 vs. 0.301
# Recall = 0.950 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.069
# F1 = 0.593 vs. 0.101
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.623 vs. 0.191
# F1 = 0.625 vs. 0.314
# Precision = 0.584 vs. 0.187
# Recall = 0.672 vs. 0.989
# Minibatch Loss= 0.020874
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.075
# F1 = 0.994 vs. 0.115
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.285
# F1 = 0.957 vs. 0.439
# Precision = 0.951 vs. 0.281
# Recall = 0.962 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.072
# F1 = 0.588 vs. 0.104
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.630 vs. 0.177
# F1 = 0.630 vs. 0.314
# Precision = 0.589 vs. 0.186
# Recall = 0.678 vs. 0.991
# Minibatch Loss= 0.018305
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.080
# F1 = 0.997 vs. 0.120
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.325
# F1 = 0.951 vs. 0.490
# Precision = 0.952 vs. 0.325
# Recall = 0.950 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.070
# F1 = 0.590 vs. 0.101
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.625 vs. 0.174
# F1 = 0.626 vs. 0.313
# Precision = 0.561 vs. 0.186
# Recall = 0.709 vs. 0.966
# Minibatch Loss= 0.018271
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.076
# F1 = 0.995 vs. 0.111
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.282
# F1 = 0.949 vs. 0.439
# Precision = 0.928 vs. 0.281
# Recall = 0.971 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.067
# F1 = 0.587 vs. 0.095
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.624 vs. 0.188
# F1 = 0.626 vs. 0.313
# Precision = 0.601 vs. 0.186
# Recall = 0.652 vs. 0.980
# Minibatch Loss= 0.017449
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.077
# F1 = 0.994 vs. 0.122
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.288
# F1 = 0.951 vs. 0.448
# Precision = 0.950 vs. 0.289
# Recall = 0.952 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.072
# F1 = 0.590 vs. 0.109
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.628 vs. 0.195
# F1 = 0.641 vs. 0.315
# Precision = 0.590 vs. 0.188
# Recall = 0.701 vs. 0.986
# Minibatch Loss= 0.018106
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.074
# F1 = 0.996 vs. 0.109
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.979 vs. 0.265
# F1 = 0.953 vs. 0.419
# Precision = 0.939 vs. 0.265
# Recall = 0.966 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.071
# F1 = 0.590 vs. 0.100
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.625 vs. 0.172
# F1 = 0.633 vs. 0.311
# Precision = 0.569 vs. 0.186
# Recall = 0.712 vs. 0.969
# Minibatch Loss= 0.016734
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.082
# F1 = 0.991 vs. 0.120
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.306
# F1 = 0.964 vs. 0.485
# Precision = 0.956 vs. 0.320
# Recall = 0.973 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.069
# F1 = 0.590 vs. 0.101
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.622 vs. 0.199
# F1 = 0.636 vs. 0.314
# Precision = 0.583 vs. 0.186
# Recall = 0.701 vs. 0.991
# Minibatch Loss= 0.016570
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.078
# F1 = 0.993 vs. 0.122
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.318
# F1 = 0.966 vs. 0.475
# Precision = 0.951 vs. 0.312
# Recall = 0.982 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.070
# F1 = 0.588 vs. 0.105
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.192
# F1 = 0.631 vs. 0.315
# Precision = 0.576 vs. 0.188
# Recall = 0.698 vs. 0.983
# Minibatch Loss= 0.016684
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.081
# F1 = 0.995 vs. 0.126
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.330
# F1 = 0.966 vs. 0.491
# Precision = 0.945 vs. 0.326
# Recall = 0.988 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.070
# F1 = 0.591 vs. 0.102
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.187
# F1 = 0.637 vs. 0.312
# Precision = 0.592 vs. 0.185
# Recall = 0.689 vs. 0.983
# Minibatch Loss= 0.014979
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.997 vs. 0.113
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.270
# F1 = 0.966 vs. 0.435
# Precision = 0.954 vs. 0.278
# Recall = 0.977 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.069
# F1 = 0.589 vs. 0.099
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.197
# F1 = 0.631 vs. 0.315
# Precision = 0.611 vs. 0.189
# Recall = 0.652 vs. 0.952
# Minibatch Loss= 0.013288
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.077
# F1 = 0.996 vs. 0.121
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.313
# F1 = 0.978 vs. 0.479
# Precision = 0.972 vs. 0.315
# Recall = 0.984 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.071
# F1 = 0.592 vs. 0.109
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.614 vs. 0.180
# F1 = 0.630 vs. 0.311
# Precision = 0.599 vs. 0.184
# Recall = 0.664 vs. 1.000
# Minibatch Loss= 0.014103
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.078
# F1 = 0.996 vs. 0.116
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.309
# F1 = 0.972 vs. 0.469
# Precision = 0.958 vs. 0.306
# Recall = 0.986 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.070
# F1 = 0.591 vs. 0.102
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.619 vs. 0.189
# F1 = 0.637 vs. 0.312
# Precision = 0.618 vs. 0.185
# Recall = 0.658 vs. 0.994
# Minibatch Loss= 0.012248
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.077
# F1 = 0.997 vs. 0.119
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.282
# F1 = 0.982 vs. 0.437
# Precision = 0.976 vs. 0.280
# Recall = 0.988 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.073
# F1 = 0.591 vs. 0.111
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.614 vs. 0.177
# F1 = 0.632 vs. 0.311
# Precision = 0.594 vs. 0.184
# Recall = 0.675 vs. 1.000
# Minibatch Loss= 0.010201
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.076
# F1 = 0.997 vs. 0.113
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.278
# F1 = 0.992 vs. 0.459
# Precision = 0.988 vs. 0.298
# Recall = 0.996 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.068
# F1 = 0.590 vs. 0.103
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.623 vs. 0.194
# F1 = 0.636 vs. 0.317
# Precision = 0.583 vs. 0.191
# Recall = 0.701 vs. 0.932
# Minibatch Loss= 0.008471
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.076
# F1 = 0.997 vs. 0.113
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.279
# F1 = 0.987 vs. 0.431
# Precision = 0.986 vs. 0.278
# Recall = 0.988 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.070
# F1 = 0.591 vs. 0.104
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.184
# F1 = 0.632 vs. 0.316
# Precision = 0.588 vs. 0.190
# Recall = 0.684 vs. 0.940
# Minibatch Loss= 0.008764
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.997 vs. 0.114
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.325
# F1 = 0.979 vs. 0.469
# Precision = 0.966 vs. 0.306
# Recall = 0.992 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.068
# F1 = 0.587 vs. 0.097
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.188
# F1 = 0.633 vs. 0.314
# Precision = 0.597 vs. 0.187
# Recall = 0.672 vs. 0.977
# Minibatch Loss= 0.010379
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.117
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.318
# F1 = 0.982 vs. 0.465
# Precision = 0.968 vs. 0.304
# Recall = 0.996 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.070
# F1 = 0.589 vs. 0.106
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.611 vs. 0.187
# F1 = 0.625 vs. 0.314
# Precision = 0.628 vs. 0.187
# Recall = 0.621 vs. 0.983
# Minibatch Loss= 0.009260
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.963 vs. 0.079
# F1 = 0.931 vs. 0.117
# Accuracy = 0.947 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.301
# F1 = 0.890 vs. 0.477
# Precision = 0.843 vs. 0.313
# Recall = 0.942 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.071
# F1 = 0.595 vs. 0.109
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.619 vs. 0.188
# F1 = 0.627 vs. 0.313
# Precision = 0.551 vs. 0.186
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.162682
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.079
# F1 = 0.996 vs. 0.122
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.306
# F1 = 0.967 vs. 0.471
# Precision = 0.954 vs. 0.308
# Recall = 0.980 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.068
# F1 = 0.614 vs. 0.096
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.616 vs. 0.177
# F1 = 0.642 vs. 0.312
# Precision = 0.581 vs. 0.185
# Recall = 0.718 vs. 0.994
# Minibatch Loss= 0.015945
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.080
# F1 = 0.996 vs. 0.118
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.318
# F1 = 0.977 vs. 0.478
# Precision = 0.978 vs. 0.315
# Recall = 0.976 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.069
# F1 = 0.609 vs. 0.103
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.193
# F1 = 0.638 vs. 0.312
# Precision = 0.574 vs. 0.185
# Recall = 0.718 vs. 1.000
# Minibatch Loss= 0.013514
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.118
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.339
# F1 = 0.982 vs. 0.475
# Precision = 0.974 vs. 0.311
# Recall = 0.990 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.069
# F1 = 0.604 vs. 0.098
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.616 vs. 0.187
# F1 = 0.636 vs. 0.315
# Precision = 0.594 vs. 0.187
# Recall = 0.684 vs. 0.991
# Minibatch Loss= 0.009672
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.075
# F1 = 0.997 vs. 0.111
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.271
# F1 = 0.982 vs. 0.433
# Precision = 0.982 vs. 0.276
# Recall = 0.982 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.070
# F1 = 0.606 vs. 0.104
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.616 vs. 0.183
# F1 = 0.635 vs. 0.312
# Precision = 0.587 vs. 0.185
# Recall = 0.692 vs. 0.994
# Minibatch Loss= 0.010001
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.080
# F1 = 0.997 vs. 0.116
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.292
# F1 = 0.992 vs. 0.461
# Precision = 0.988 vs. 0.300
# Recall = 0.996 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.577 vs. 0.073
# F1 = 0.603 vs. 0.113
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.614 vs. 0.180
# F1 = 0.634 vs. 0.316
# Precision = 0.597 vs. 0.188
# Recall = 0.675 vs. 0.989
# Minibatch Loss= 0.007810
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 0.998 vs. 0.127
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.375
# F1 = 0.989 vs. 0.523
# Precision = 0.982 vs. 0.355
# Recall = 0.996 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.070
# F1 = 0.600 vs. 0.099
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.177
# F1 = 0.635 vs. 0.311
# Precision = 0.596 vs. 0.184
# Recall = 0.678 vs. 1.000
# Minibatch Loss= 0.009247
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.119
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.291
# F1 = 0.992 vs. 0.465
# Precision = 0.990 vs. 0.303
# Recall = 0.994 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.070
# F1 = 0.595 vs. 0.098
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.181
# F1 = 0.635 vs. 0.312
# Precision = 0.582 vs. 0.185
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.007484
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.997 vs. 0.119
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.293
# F1 = 0.993 vs. 0.454
# Precision = 0.989 vs. 0.296
# Recall = 0.996 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.070
# F1 = 0.595 vs. 0.102
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.200
# F1 = 0.638 vs. 0.311
# Precision = 0.588 vs. 0.184
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.007053
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.997 vs. 0.114
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.280
# F1 = 0.992 vs. 0.456
# Precision = 0.988 vs. 0.296
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.071
# F1 = 0.594 vs. 0.106
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.191
# F1 = 0.636 vs. 0.313
# Precision = 0.587 vs. 0.186
# Recall = 0.695 vs. 0.991
# Minibatch Loss= 0.006887
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.124
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.349
# F1 = 0.990 vs. 0.511
# Precision = 0.987 vs. 0.343
# Recall = 0.993 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.069
# F1 = 0.592 vs. 0.102
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.615 vs. 0.187
# F1 = 0.633 vs. 0.314
# Precision = 0.576 vs. 0.186
# Recall = 0.704 vs. 0.997
# Minibatch Loss= 0.008245
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.997 vs. 0.120
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.315
# F1 = 0.994 vs. 0.487
# Precision = 0.990 vs. 0.322
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.068
# F1 = 0.591 vs. 0.095
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.612 vs. 0.185
# F1 = 0.628 vs. 0.311
# Precision = 0.560 vs. 0.184
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.007223
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.119
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.294
# F1 = 0.988 vs. 0.444
# Precision = 0.985 vs. 0.291
# Recall = 0.991 vs. 0.936
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.068
# F1 = 0.593 vs. 0.096
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.611 vs. 0.192
# F1 = 0.638 vs. 0.312
# Precision = 0.579 vs. 0.185
# Recall = 0.709 vs. 0.994
# Minibatch Loss= 0.007559
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.117
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.303
# F1 = 0.992 vs. 0.459
# Precision = 0.996 vs. 0.298
# Recall = 0.987 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.069
# F1 = 0.593 vs. 0.105
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.607 vs. 0.182
# F1 = 0.638 vs. 0.314
# Precision = 0.579 vs. 0.186
# Recall = 0.709 vs. 1.000
# Minibatch Loss= 0.007028
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.122
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.370
# F1 = 0.995 vs. 0.509
# Precision = 0.996 vs. 0.341
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.071
# F1 = 0.593 vs. 0.107
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.615 vs. 0.196
# F1 = 0.632 vs. 0.315
# Precision = 0.576 vs. 0.187
# Recall = 0.701 vs. 0.989
# Minibatch Loss= 0.006695
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.119
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.351
# F1 = 0.995 vs. 0.506
# Precision = 0.991 vs. 0.338
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.070
# F1 = 0.590 vs. 0.108
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.612 vs. 0.184
# F1 = 0.631 vs. 0.314
# Precision = 0.566 vs. 0.188
# Recall = 0.712 vs. 0.957
# Minibatch Loss= 0.006680
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.998 vs. 0.118
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.265
# F1 = 0.996 vs. 0.417
# Precision = 0.992 vs. 0.264
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.072
# F1 = 0.590 vs. 0.101
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.610 vs. 0.180
# F1 = 0.634 vs. 0.312
# Precision = 0.568 vs. 0.185
# Recall = 0.718 vs. 1.000
# Minibatch Loss= 0.004975
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.997 vs. 0.114
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.310
# F1 = 0.997 vs. 0.469
# Precision = 0.994 vs. 0.307
# Recall = 1.000 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.069
# F1 = 0.589 vs. 0.097
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.611 vs. 0.195
# F1 = 0.633 vs. 0.315
# Precision = 0.565 vs. 0.187
# Recall = 0.721 vs. 0.994
# Minibatch Loss= 0.005930
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.074
# F1 = 0.998 vs. 0.110
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.273
# F1 = 0.997 vs. 0.430
# Precision = 0.998 vs. 0.274
# Recall = 0.995 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.590 vs. 0.099
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.606 vs. 0.194
# F1 = 0.630 vs. 0.316
# Precision = 0.561 vs. 0.188
# Recall = 0.718 vs. 0.994
# Minibatch Loss= 0.005633
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.117
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.273
# F1 = 0.992 vs. 0.424
# Precision = 0.988 vs. 0.270
# Recall = 0.995 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.068
# F1 = 0.587 vs. 0.099
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.613 vs. 0.185
# F1 = 0.633 vs. 0.312
# Precision = 0.560 vs. 0.185
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.005483
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.120
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 0.999 vs. 0.488
# Precision = 1.000 vs. 0.323
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.072
# F1 = 0.588 vs. 0.108
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.175
# F1 = 0.632 vs. 0.313
# Precision = 0.562 vs. 0.186
# Recall = 0.721 vs. 1.000
# Minibatch Loss= 0.005069
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.117
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.344
# F1 = 0.994 vs. 0.463
# Precision = 0.992 vs. 0.302
# Recall = 0.996 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.068
# F1 = 0.589 vs. 0.099
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.612 vs. 0.185
# F1 = 0.632 vs. 0.313
# Precision = 0.555 vs. 0.187
# Recall = 0.735 vs. 0.966
# Minibatch Loss= 0.005770
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.125
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.301
# F1 = 0.996 vs. 0.468
# Precision = 0.994 vs. 0.305
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.069
# F1 = 0.589 vs. 0.098
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.181
# F1 = 0.632 vs. 0.318
# Precision = 0.564 vs. 0.194
# Recall = 0.718 vs. 0.886
# Minibatch Loss= 0.005754
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.998 vs. 0.126
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 0.998 vs. 0.508
# Precision = 0.998 vs. 0.346
# Recall = 0.998 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.068
# F1 = 0.589 vs. 0.096
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.611 vs. 0.187
# F1 = 0.635 vs. 0.314
# Precision = 0.569 vs. 0.187
# Recall = 0.718 vs. 0.974
# Minibatch Loss= 0.005743
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.074
# F1 = 0.998 vs. 0.112
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.303
# F1 = 0.994 vs. 0.453
# Precision = 0.994 vs. 0.293
# Recall = 0.994 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.068
# F1 = 0.588 vs. 0.096
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.190
# F1 = 0.638 vs. 0.314
# Precision = 0.551 vs. 0.187
# Recall = 0.758 vs. 0.983
# Minibatch Loss= 0.005153
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.118
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.305
# F1 = 0.999 vs. 0.465
# Precision = 0.998 vs. 0.303
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.069
# F1 = 0.587 vs. 0.100
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.604 vs. 0.197
# F1 = 0.633 vs. 0.314
# Precision = 0.566 vs. 0.187
# Recall = 0.718 vs. 0.989
# Minibatch Loss= 0.004201
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.116
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.310
# F1 = 0.998 vs. 0.461
# Precision = 0.996 vs. 0.301
# Recall = 1.000 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.070
# F1 = 0.590 vs. 0.105
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.607 vs. 0.188
# F1 = 0.632 vs. 0.317
# Precision = 0.562 vs. 0.190
# Recall = 0.721 vs. 0.957
# Minibatch Loss= 0.004429
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.119
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.308
# F1 = 0.999 vs. 0.480
# Precision = 0.998 vs. 0.316
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.071
# F1 = 0.588 vs. 0.107
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.615 vs. 0.188
# F1 = 0.635 vs. 0.312
# Precision = 0.567 vs. 0.185
# Recall = 0.721 vs. 1.000
# Minibatch Loss= 0.004418
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.999 vs. 0.123
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.315
# F1 = 0.999 vs. 0.474
# Precision = 1.000 vs. 0.311
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.072
# F1 = 0.588 vs. 0.103
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.606 vs. 0.183
# F1 = 0.630 vs. 0.313
# Precision = 0.564 vs. 0.186
# Recall = 0.712 vs. 0.991
# Minibatch Loss= 0.003636
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.125
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.313
# F1 = 0.998 vs. 0.487
# Precision = 0.996 vs. 0.322
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.068
# F1 = 0.586 vs. 0.100
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.606 vs. 0.192
# F1 = 0.632 vs. 0.313
# Precision = 0.558 vs. 0.187
# Recall = 0.729 vs. 0.954
# Minibatch Loss= 0.004378
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.121
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.310
# F1 = 1.000 vs. 0.466
# Precision = 1.000 vs. 0.305
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.068
# F1 = 0.589 vs. 0.097
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.613 vs. 0.178
# F1 = 0.633 vs. 0.315
# Precision = 0.549 vs. 0.189
# Recall = 0.746 vs. 0.940
# Minibatch Loss= 0.003987
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.117
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.349
# F1 = 0.999 vs. 0.480
# Precision = 1.000 vs. 0.316
# Recall = 0.998 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.067
# F1 = 0.588 vs. 0.094
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.184
# F1 = 0.622 vs. 0.317
# Precision = 0.530 vs. 0.192
# Recall = 0.752 vs. 0.923
# Minibatch Loss= 0.003928
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.999 vs. 0.123
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.351
# F1 = 1.000 vs. 0.509
# Precision = 1.000 vs. 0.343
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.069
# F1 = 0.584 vs. 0.096
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.609 vs. 0.207
# F1 = 0.629 vs. 0.318
# Precision = 0.545 vs. 0.189
# Recall = 0.744 vs. 0.991
# Minibatch Loss= 0.003990
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.118
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.301
# F1 = 1.000 vs. 0.463
# Precision = 1.000 vs. 0.301
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.072
# F1 = 0.587 vs. 0.105
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.610 vs. 0.177
# F1 = 0.635 vs. 0.312
# Precision = 0.556 vs. 0.185
# Recall = 0.741 vs. 1.000
# Minibatch Loss= 0.003331
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.120
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.330
# F1 = 1.000 vs. 0.494
# Precision = 1.000 vs. 0.330
# Recall = 1.000 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.069
# F1 = 0.587 vs. 0.107
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.178
# F1 = 0.638 vs. 0.312
# Precision = 0.562 vs. 0.185
# Recall = 0.738 vs. 1.000
# Minibatch Loss= 0.003968
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.123
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.334
# F1 = 0.998 vs. 0.512
# Precision = 0.996 vs. 0.344
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.068
# F1 = 0.587 vs. 0.100
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.616 vs. 0.173
# F1 = 0.634 vs. 0.314
# Precision = 0.556 vs. 0.189
# Recall = 0.738 vs. 0.926
# Minibatch Loss= 0.003284
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.117
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.278
# F1 = 0.999 vs. 0.459
# Precision = 1.000 vs. 0.298
# Recall = 0.998 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.067
# F1 = 0.590 vs. 0.093
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.184
# F1 = 0.633 vs. 0.316
# Precision = 0.559 vs. 0.189
# Recall = 0.729 vs. 0.966
# Minibatch Loss= 0.003417
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.998 vs. 0.121
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.374
# F1 = 1.000 vs. 0.526
# Precision = 1.000 vs. 0.358
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.070
# F1 = 0.587 vs. 0.098
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.180
# F1 = 0.637 vs. 0.316
# Precision = 0.571 vs. 0.189
# Recall = 0.721 vs. 0.969
# Minibatch Loss= 0.003578
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.999 vs. 0.112
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.291
# F1 = 0.999 vs. 0.435
# Precision = 0.998 vs. 0.278
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.070
# F1 = 0.588 vs. 0.104
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.630 vs. 0.197
# F1 = 0.633 vs. 0.312
# Precision = 0.627 vs. 0.192
# Recall = 0.638 vs. 0.835
# Minibatch Loss= 0.002863
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.119
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.338
# F1 = 1.000 vs. 0.495
# Precision = 1.000 vs. 0.330
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.068
# F1 = 0.586 vs. 0.098
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.634 vs. 0.183
# F1 = 0.636 vs. 0.314
# Precision = 0.623 vs. 0.188
# Recall = 0.650 vs. 0.946
# Minibatch Loss= 0.002998
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.347
# F1 = 0.999 vs. 0.514
# Precision = 1.000 vs. 0.346
# Recall = 0.998 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.068
# F1 = 0.587 vs. 0.099
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.624 vs. 0.177
# F1 = 0.643 vs. 0.311
# Precision = 0.580 vs. 0.184
# Recall = 0.721 vs. 1.000
# Minibatch Loss= 0.003171
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.083
# F1 = 0.966 vs. 0.126
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.970 vs. 0.307
# F1 = 0.905 vs. 0.457
# Precision = 0.887 vs. 0.296
# Recall = 0.924 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.582 vs. 0.070
# F1 = 0.608 vs. 0.105
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.598 vs. 0.199
# F1 = 0.648 vs. 0.321
# Precision = 0.598 vs. 0.199
# Recall = 0.707 vs. 0.823
# Minibatch Loss= 0.038624
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.077
# F1 = 0.993 vs. 0.117
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.288
# F1 = 0.960 vs. 0.456
# Precision = 0.954 vs. 0.296
# Recall = 0.966 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.069
# F1 = 0.610 vs. 0.100
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.198
# F1 = 0.645 vs. 0.312
# Precision = 0.630 vs. 0.185
# Recall = 0.661 vs. 0.994
# Minibatch Loss= 0.014877
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.079
# F1 = 0.990 vs. 0.121
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.329
# F1 = 0.971 vs. 0.511
# Precision = 0.974 vs. 0.344
# Recall = 0.967 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.072
# F1 = 0.613 vs. 0.105
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.609 vs. 0.179
# F1 = 0.641 vs. 0.314
# Precision = 0.576 vs. 0.187
# Recall = 0.721 vs. 0.974
# Minibatch Loss= 0.015739
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.081
# F1 = 0.997 vs. 0.124
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.309
# F1 = 0.971 vs. 0.482
# Precision = 0.956 vs. 0.317
# Recall = 0.987 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.067
# F1 = 0.616 vs. 0.095
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.183
# F1 = 0.639 vs. 0.311
# Precision = 0.563 vs. 0.184
# Recall = 0.738 vs. 1.000
# Minibatch Loss= 0.010502
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.110
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.296
# F1 = 0.984 vs. 0.456
# Precision = 0.977 vs. 0.296
# Recall = 0.991 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.067
# F1 = 0.616 vs. 0.095
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.613 vs. 0.183
# F1 = 0.637 vs. 0.314
# Precision = 0.551 vs. 0.188
# Recall = 0.755 vs. 0.969
# Minibatch Loss= 0.008287
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.118
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.316
# F1 = 0.994 vs. 0.458
# Precision = 0.987 vs. 0.297
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.070
# F1 = 0.614 vs. 0.105
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.615 vs. 0.188
# F1 = 0.638 vs. 0.315
# Precision = 0.582 vs. 0.188
# Recall = 0.707 vs. 0.969
# Minibatch Loss= 0.005967
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.115
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.316
# F1 = 0.996 vs. 0.480
# Precision = 0.998 vs. 0.316
# Recall = 0.994 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.068
# F1 = 0.613 vs. 0.096
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.182
# F1 = 0.644 vs. 0.312
# Precision = 0.585 vs. 0.186
# Recall = 0.715 vs. 0.974
# Minibatch Loss= 0.006602
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.117
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.322
# F1 = 0.995 vs. 0.492
# Precision = 0.992 vs. 0.326
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.070
# F1 = 0.614 vs. 0.105
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.609 vs. 0.187
# F1 = 0.644 vs. 0.324
# Precision = 0.561 vs. 0.196
# Recall = 0.755 vs. 0.923
# Minibatch Loss= 0.006564
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.084
# F1 = 0.998 vs. 0.126
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.393
# F1 = 1.000 vs. 0.534
# Precision = 1.000 vs. 0.365
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.068
# F1 = 0.609 vs. 0.098
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.619 vs. 0.190
# F1 = 0.644 vs. 0.311
# Precision = 0.563 vs. 0.184
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.005886
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 0.999 vs. 0.460
# Precision = 0.998 vs. 0.299
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.070
# F1 = 0.611 vs. 0.106
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.619 vs. 0.181
# F1 = 0.640 vs. 0.312
# Precision = 0.562 vs. 0.185
# Recall = 0.744 vs. 1.000
# Minibatch Loss= 0.004708
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.119
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.311
# F1 = 0.999 vs. 0.484
# Precision = 0.998 vs. 0.320
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.074
# F1 = 0.610 vs. 0.109
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.184
# F1 = 0.642 vs. 0.311
# Precision = 0.561 vs. 0.184
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.004402
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.116
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.333
# F1 = 0.997 vs. 0.477
# Precision = 0.996 vs. 0.313
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.069
# F1 = 0.610 vs. 0.105
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.613 vs. 0.184
# Recall = 0.678 vs. 1.000
# Minibatch Loss= 0.001765
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.267
# F1 = 1.000 vs. 0.419
# Precision = 1.000 vs. 0.265
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.073
# F1 = 0.607 vs. 0.108
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.611 vs. 0.193
# F1 = 0.644 vs. 0.313
# Precision = 0.611 vs. 0.186
# Recall = 0.681 vs. 1.000
# Minibatch Loss= 0.001456
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.114
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.254
# F1 = 1.000 vs. 0.417
# Precision = 1.000 vs. 0.264
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.605 vs. 0.098
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.626 vs. 0.187
# F1 = 0.641 vs. 0.316
# Precision = 0.622 vs. 0.189
# Recall = 0.661 vs. 0.960
# Minibatch Loss= 0.001756
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.118
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.295
# F1 = 1.000 vs. 0.459
# Precision = 1.000 vs. 0.298
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.070
# F1 = 0.605 vs. 0.104
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.185
# F1 = 0.642 vs. 0.312
# Precision = 0.610 vs. 0.185
# Recall = 0.678 vs. 0.997
# Minibatch Loss= 0.001589
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.339
# F1 = 1.000 vs. 0.501
# Precision = 1.000 vs. 0.335
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.071
# F1 = 0.604 vs. 0.104
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.600 vs. 0.176
# F1 = 0.642 vs. 0.314
# Precision = 0.608 vs. 0.187
# Recall = 0.681 vs. 0.986
# Minibatch Loss= 0.001399
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 0.999 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.359
# F1 = 1.000 vs. 0.508
# Precision = 1.000 vs. 0.341
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.564 vs. 0.068
# F1 = 0.605 vs. 0.099
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.624 vs. 0.183
# F1 = 0.644 vs. 0.312
# Precision = 0.606 vs. 0.185
# Recall = 0.687 vs. 1.000
# Minibatch Loss= 0.001748
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.129
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.354
# F1 = 1.000 vs. 0.513
# Precision = 1.000 vs. 0.345
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.071
# F1 = 0.605 vs. 0.104
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.621 vs. 0.185
# F1 = 0.647 vs. 0.311
# Precision = 0.614 vs. 0.184
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.001231
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.298
# F1 = 1.000 vs. 0.453
# Precision = 1.000 vs. 0.293
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.070
# F1 = 0.605 vs. 0.107
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.175
# F1 = 0.647 vs. 0.315
# Precision = 0.614 vs. 0.188
# Recall = 0.684 vs. 0.972
# Minibatch Loss= 0.001237
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.117
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.290
# F1 = 1.000 vs. 0.462
# Precision = 1.000 vs. 0.307
# Recall = 1.000 vs. 0.937
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.068
# F1 = 0.605 vs. 0.095
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.612 vs. 0.183
# F1 = 0.646 vs. 0.312
# Precision = 0.614 vs. 0.185
# Recall = 0.681 vs. 0.994
# Minibatch Loss= 0.001239
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.278
# F1 = 1.000 vs. 0.428
# Precision = 1.000 vs. 0.273
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.559 vs. 0.068
# F1 = 0.605 vs. 0.102
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.198
# F1 = 0.644 vs. 0.312
# Precision = 0.613 vs. 0.186
# Recall = 0.678 vs. 0.969
# Minibatch Loss= 0.001014
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.342
# F1 = 1.000 vs. 0.500
# Precision = 1.000 vs. 0.334
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.069
# F1 = 0.603 vs. 0.102
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.612 vs. 0.182
# F1 = 0.643 vs. 0.312
# Precision = 0.616 vs. 0.185
# Recall = 0.672 vs. 0.991
# Minibatch Loss= 0.001143
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 1.000 vs. 0.458
# Precision = 1.000 vs. 0.297
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.068
# F1 = 0.602 vs. 0.097
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.176
# F1 = 0.643 vs. 0.319
# Precision = 0.614 vs. 0.194
# Recall = 0.675 vs. 0.903
# Minibatch Loss= 0.000981
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.127
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.322
# F1 = 1.000 vs. 0.496
# Precision = 1.000 vs. 0.330
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.069
# F1 = 0.602 vs. 0.100
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.613 vs. 0.187
# F1 = 0.644 vs. 0.314
# Precision = 0.598 vs. 0.187
# Recall = 0.698 vs. 0.966
# Minibatch Loss= 0.001109
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.120
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.314
# F1 = 1.000 vs. 0.486
# Precision = 1.000 vs. 0.321
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.070
# F1 = 0.601 vs. 0.099
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.200
# F1 = 0.645 vs. 0.314
# Precision = 0.615 vs. 0.187
# Recall = 0.678 vs. 0.974
# Minibatch Loss= 0.001143
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.120
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.328
# F1 = 1.000 vs. 0.487
# Precision = 1.000 vs. 0.327
# Recall = 1.000 vs. 0.947
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.069
# F1 = 0.601 vs. 0.105
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.610 vs. 0.185
# F1 = 0.644 vs. 0.311
# Precision = 0.598 vs. 0.184
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.001082
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.120
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.282
# F1 = 1.000 vs. 0.437
# Precision = 1.000 vs. 0.280
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.068
# F1 = 0.602 vs. 0.098
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.181
# F1 = 0.645 vs. 0.311
# Precision = 0.599 vs. 0.184
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.001007
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.114
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 1.000 vs. 0.464
# Precision = 1.000 vs. 0.303
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.069
# F1 = 0.602 vs. 0.097
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.204
# F1 = 0.646 vs. 0.314
# Precision = 0.599 vs. 0.188
# Recall = 0.701 vs. 0.952
# Minibatch Loss= 0.000863
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.298
# F1 = 1.000 vs. 0.445
# Precision = 1.000 vs. 0.288
# Recall = 1.000 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.074
# F1 = 0.602 vs. 0.109
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.627 vs. 0.176
# F1 = 0.645 vs. 0.317
# Precision = 0.597 vs. 0.189
# Recall = 0.701 vs. 0.974
# Minibatch Loss= 0.000717
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.301
# F1 = 1.000 vs. 0.456
# Precision = 1.000 vs. 0.296
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.072
# F1 = 0.600 vs. 0.105
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.177
# F1 = 0.645 vs. 0.314
# Precision = 0.595 vs. 0.186
# Recall = 0.704 vs. 1.000
# Minibatch Loss= 0.000798
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.073
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.248
# F1 = 1.000 vs. 0.400
# Precision = 1.000 vs. 0.251
# Recall = 1.000 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.552 vs. 0.070
# F1 = 0.600 vs. 0.099
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.609 vs. 0.179
# F1 = 0.643 vs. 0.313
# Precision = 0.592 vs. 0.186
# Recall = 0.704 vs. 0.991
# Minibatch Loss= 0.000709
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.286
# F1 = 1.000 vs. 0.440
# Precision = 1.000 vs. 0.282
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.071
# F1 = 0.599 vs. 0.104
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.634 vs. 0.188
# F1 = 0.643 vs. 0.314
# Precision = 0.600 vs. 0.187
# Recall = 0.692 vs. 0.986
# Minibatch Loss= 0.000660
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.343
# F1 = 1.000 vs. 0.507
# Precision = 1.000 vs. 0.340
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.069
# F1 = 0.600 vs. 0.102
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.615 vs. 0.196
# F1 = 0.646 vs. 0.311
# Precision = 0.600 vs. 0.184
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.000851
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.343
# F1 = 1.000 vs. 0.494
# Precision = 1.000 vs. 0.328
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.069
# F1 = 0.599 vs. 0.106
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.614 vs. 0.197
# F1 = 0.646 vs. 0.317
# Precision = 0.600 vs. 0.190
# Recall = 0.698 vs. 0.963
# Minibatch Loss= 0.000618
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.127
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.397
# F1 = 1.000 vs. 0.567
# Precision = 1.000 vs. 0.400
# Recall = 1.000 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.073
# F1 = 0.597 vs. 0.109
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.184
# F1 = 0.641 vs. 0.312
# Precision = 0.593 vs. 0.185
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.000881
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.348
# F1 = 1.000 vs. 0.500
# Precision = 1.000 vs. 0.334
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.068
# F1 = 0.598 vs. 0.100
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.184
# F1 = 0.645 vs. 0.311
# Precision = 0.603 vs. 0.184
# Recall = 0.692 vs. 1.000
# Minibatch Loss= 0.000860
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.124
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.357
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.331
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.070
# F1 = 0.599 vs. 0.109
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.603 vs. 0.173
# F1 = 0.644 vs. 0.311
# Precision = 0.603 vs. 0.184
# Recall = 0.689 vs. 1.000
# Minibatch Loss= 0.000919
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.288
# F1 = 1.000 vs. 0.433
# Precision = 1.000 vs. 0.276
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.073
# F1 = 0.599 vs. 0.104
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.188
# F1 = 0.643 vs. 0.311
# Precision = 0.598 vs. 0.184
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 0.000664
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.123
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.343
# F1 = 1.000 vs. 0.500
# Precision = 1.000 vs. 0.334
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.070
# F1 = 0.599 vs. 0.098
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.191
# F1 = 0.644 vs. 0.312
# Precision = 0.605 vs. 0.185
# Recall = 0.689 vs. 1.000
# Minibatch Loss= 0.000904
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.123
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.333
# F1 = 1.000 vs. 0.490
# Precision = 1.000 vs. 0.324
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.072
# F1 = 0.599 vs. 0.101
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.607 vs. 0.190
# F1 = 0.644 vs. 0.316
# Precision = 0.607 vs. 0.190
# Recall = 0.687 vs. 0.952
# Minibatch Loss= 0.000780
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.330
# F1 = 1.000 vs. 0.501
# Precision = 1.000 vs. 0.334
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.069
# F1 = 0.600 vs. 0.102
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.615 vs. 0.206
# F1 = 0.644 vs. 0.321
# Precision = 0.605 vs. 0.193
# Recall = 0.689 vs. 0.952
# Minibatch Loss= 0.000573
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.320
# F1 = 1.000 vs. 0.469
# Precision = 1.000 vs. 0.307
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.070
# F1 = 0.600 vs. 0.100
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.599 vs. 0.198
# F1 = 0.645 vs. 0.313
# Precision = 0.603 vs. 0.185
# Recall = 0.692 vs. 0.997
# Minibatch Loss= 0.000709
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.111
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.284
# F1 = 1.000 vs. 0.433
# Precision = 1.000 vs. 0.277
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.068
# F1 = 0.599 vs. 0.098
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.181
# F1 = 0.645 vs. 0.312
# Precision = 0.603 vs. 0.185
# Recall = 0.692 vs. 1.000
# Minibatch Loss= 0.000566
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.121
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.321
# F1 = 1.000 vs. 0.487
# Precision = 1.000 vs. 0.322
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.552 vs. 0.067
# F1 = 0.599 vs. 0.096
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.611 vs. 0.194
# F1 = 0.645 vs. 0.311
# Precision = 0.603 vs. 0.184
# Recall = 0.692 vs. 1.000
# Minibatch Loss= 0.000558
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.109
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.266
# F1 = 1.000 vs. 0.421
# Precision = 1.000 vs. 0.266
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.068
# F1 = 0.600 vs. 0.101
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.616 vs. 0.195
# F1 = 0.645 vs. 0.319
# Precision = 0.604 vs. 0.194
# Recall = 0.692 vs. 0.892
# Minibatch Loss= 0.000565
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.336
# F1 = 1.000 vs. 0.498
# Precision = 1.000 vs. 0.335
# Recall = 1.000 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.538 vs. 0.067
# F1 = 0.599 vs. 0.094
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.612 vs. 0.176
# F1 = 0.645 vs. 0.312
# Precision = 0.604 vs. 0.185
# Recall = 0.692 vs. 1.000
# Minibatch Loss= 0.000502
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/CNN_Wmultitask_64_opp/CNN_Wmultitask_64_opp-20000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../../model/CNN_Wmultitask_64_opp/CNN_Wmultitask_64_opp-10093')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.070
# F1 = 0.598 vs. 0.099
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.616 vs. 0.207
# F1 = 0.644 vs. 0.314
# Precision = 0.607 vs. 0.187
# Recall = 0.687 vs. 0.977

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
