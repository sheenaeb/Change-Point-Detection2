# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_Wmultitask_16_opp2"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
from models.HRNN_model import Model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 7    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[9, n_variables, 128],
                 [5, 128, 128],
                 [5, 128, 128]]
bias_shape = [128, 128, 128]
wavelet_weights_shape = [[3, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu

lstm_n_hidden = 256
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)
# Out:
# 7
# Tensor("Squeeze_20:0", shape=(?, ?, 128), dtype=float32)
# Tensor("Squeeze_20:0", shape=(?, ?, 128), dtype=float32) Tensor("zeros:0", shape=(?, ?, 256), dtype=float32) 6
# Tensor("Squeeze_17:0", shape=(?, ?, 128), dtype=float32) Tensor("Reshape:0", shape=(?, ?, ?), dtype=float32) 5
# Tensor("Squeeze_14:0", shape=(?, ?, 128), dtype=float32) Tensor("Reshape_1:0", shape=(?, ?, ?), dtype=float32) 4
# Tensor("Squeeze_11:0", shape=(?, ?, 128), dtype=float32) Tensor("Reshape_2:0", shape=(?, ?, ?), dtype=float32) 3
# Tensor("Squeeze_8:0", shape=(?, ?, 128), dtype=float32) Tensor("Reshape_3:0", shape=(?, ?, ?), dtype=float32) 2
# Tensor("Squeeze_5:0", shape=(?, ?, 128), dtype=float32) Tensor("Reshape_4:0", shape=(?, ?, ?), dtype=float32) 1
# Tensor("Squeeze_2:0", shape=(?, ?, 128), dtype=float32) Tensor("Reshape_5:0", shape=(?, ?, ?), dtype=float32) 0
# Tensor("Squeeze_21:0", shape=(?, ?, 19), dtype=float32) Tensor("Reshape_8:0", shape=(?, ?, 19), dtype=float32)

# %%
3
# Out:
# 3

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.061
# F1 = 0.099 vs. 0.094
# Accuracy = 0.014 vs. 0.056
# CHANGE DETECTION
# AUC = 0.122 vs. 0.098
# F1 = 0.220 vs. 0.181
# Precision = 0.131 vs. 0.100
# Recall = 0.671 vs. 1.000
# Validation: 0
# ACTIVITY RECOGNITION
# AUC = 0.060 vs. 0.059
# F1 = 0.080 vs. 0.080
# Accuracy = 0.008 vs. 0.056
# CHANGE DETECTION
# AUC = 0.061 vs. 0.052
# F1 = 0.142 vs. 0.097
# Precision = 0.079 vs. 0.051
# Recall = 0.704 vs. 0.906
# Minibatch Loss= 1.370328
# Training: 100
# ACTIVITY RECOGNITION
# AUC = 0.804 vs. 0.062
# F1 = 0.767 vs. 0.091
# Accuracy = 0.759 vs. 0.056
# CHANGE DETECTION
# AUC = 0.337 vs. 0.089
# F1 = 0.412 vs. 0.165
# Precision = 0.326 vs. 0.090
# Recall = 0.559 vs. 0.984
# Validation: 100
# ACTIVITY RECOGNITION
# AUC = 0.518 vs. 0.059
# F1 = 0.537 vs. 0.080
# Accuracy = 0.798 vs. 0.056
# CHANGE DETECTION
# AUC = 0.213 vs. 0.050
# F1 = 0.302 vs. 0.097
# Precision = 0.231 vs. 0.051
# Recall = 0.439 vs. 0.990
# Minibatch Loss= 0.211298
# Training: 200
# ACTIVITY RECOGNITION
# AUC = 0.919 vs. 0.063
# F1 = 0.867 vs. 0.095
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.465 vs. 0.095
# F1 = 0.535 vs. 0.179
# Precision = 0.436 vs. 0.099
# Recall = 0.692 vs. 0.982
# Validation: 200
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.058
# F1 = 0.646 vs. 0.080
# Accuracy = 0.850 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.057
# F1 = 0.364 vs. 0.103
# Precision = 0.304 vs. 0.058
# Recall = 0.452 vs. 0.478
# Minibatch Loss= 0.120168
# Training: 300
# ACTIVITY RECOGNITION
# AUC = 0.971 vs. 0.063
# F1 = 0.933 vs. 0.093
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.641 vs. 0.097
# F1 = 0.634 vs. 0.174
# Precision = 0.600 vs. 0.095
# Recall = 0.671 vs. 0.995
# Validation: 300
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.058
# F1 = 0.680 vs. 0.079
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.050
# F1 = 0.393 vs. 0.098
# Precision = 0.318 vs. 0.051
# Recall = 0.514 vs. 0.961
# Minibatch Loss= 0.068880
# Training: 400
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.061
# F1 = 0.949 vs. 0.090
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.714 vs. 0.080
# F1 = 0.700 vs. 0.154
# Precision = 0.629 vs. 0.083
# Recall = 0.788 vs. 0.992
# Validation: 400
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.059
# F1 = 0.694 vs. 0.081
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.053
# F1 = 0.430 vs. 0.097
# Precision = 0.379 vs. 0.051
# Recall = 0.499 vs. 0.847
# Minibatch Loss= 0.047301
# Training: 500
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.061
# F1 = 0.979 vs. 0.089
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.768 vs. 0.078
# F1 = 0.751 vs. 0.148
# Precision = 0.681 vs. 0.081
# Recall = 0.838 vs. 0.863
# Validation: 500
# ACTIVITY RECOGNITION
# AUC = 0.705 vs. 0.059
# F1 = 0.705 vs. 0.082
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.370 vs. 0.049
# F1 = 0.446 vs. 0.097
# Precision = 0.365 vs. 0.051
# Recall = 0.574 vs. 0.917
# Minibatch Loss= 0.033318
# Training: 600
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.062
# F1 = 0.952 vs. 0.092
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.795 vs. 0.092
# F1 = 0.742 vs. 0.170
# Precision = 0.659 vs. 0.093
# Recall = 0.849 vs. 0.995
# Validation: 600
# ACTIVITY RECOGNITION
# AUC = 0.708 vs. 0.058
# F1 = 0.701 vs. 0.081
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.350 vs. 0.050
# F1 = 0.434 vs. 0.099
# Precision = 0.378 vs. 0.054
# Recall = 0.509 vs. 0.631
# Minibatch Loss= 0.045942
# Training: 700
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.985 vs. 0.091
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.098
# F1 = 0.865 vs. 0.178
# Precision = 0.833 vs. 0.099
# Recall = 0.899 vs. 0.858
# Validation: 700
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.058
# F1 = 0.711 vs. 0.080
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.392 vs. 0.052
# F1 = 0.449 vs. 0.100
# Precision = 0.351 vs. 0.054
# Recall = 0.623 vs. 0.717
# Minibatch Loss= 0.024395
# Training: 800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.088
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.077
# F1 = 0.933 vs. 0.147
# Precision = 0.898 vs. 0.079
# Recall = 0.970 vs. 0.998
# Validation: 800
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.059
# F1 = 0.713 vs. 0.082
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.055
# F1 = 0.457 vs. 0.100
# Precision = 0.400 vs. 0.054
# Recall = 0.532 vs. 0.764
# Minibatch Loss= 0.014613
# Training: 900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.997 vs. 0.091
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.104
# F1 = 0.961 vs. 0.172
# Precision = 0.942 vs. 0.095
# Recall = 0.980 vs. 0.973
# Validation: 900
# ACTIVITY RECOGNITION
# AUC = 0.704 vs. 0.058
# F1 = 0.703 vs. 0.080
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.048
# F1 = 0.450 vs. 0.098
# Precision = 0.366 vs. 0.052
# Recall = 0.584 vs. 0.813
# Minibatch Loss= 0.012075
# Training: 1000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.999 vs. 0.097
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.110
# F1 = 0.969 vs. 0.190
# Precision = 0.946 vs. 0.106
# Recall = 0.993 vs. 0.925
# Validation: 1000
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.705 vs. 0.082
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.051
# F1 = 0.459 vs. 0.098
# Precision = 0.380 vs. 0.052
# Recall = 0.582 vs. 0.888
# Minibatch Loss= 0.009566
# Training: 1100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.092
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.093
# F1 = 0.993 vs. 0.169
# Precision = 0.988 vs. 0.093
# Recall = 0.998 vs. 0.921
# Validation: 1100
# ACTIVITY RECOGNITION
# AUC = 0.709 vs. 0.058
# F1 = 0.704 vs. 0.076
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.371 vs. 0.049
# F1 = 0.458 vs. 0.097
# Precision = 0.376 vs. 0.051
# Recall = 0.584 vs. 0.917
# Minibatch Loss= 0.005701
# Training: 1200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.101
# F1 = 0.998 vs. 0.176
# Precision = 0.997 vs. 0.097
# Recall = 1.000 vs. 0.931
# Validation: 1200
# ACTIVITY RECOGNITION
# AUC = 0.706 vs. 0.059
# F1 = 0.705 vs. 0.078
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.365 vs. 0.052
# F1 = 0.447 vs. 0.099
# Precision = 0.387 vs. 0.052
# Recall = 0.527 vs. 0.883
# Minibatch Loss= 0.004342
# Training: 1300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 0.998 vs. 0.165
# Precision = 0.998 vs. 0.091
# Recall = 0.998 vs. 0.878
# Validation: 1300
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.059
# F1 = 0.704 vs. 0.080
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.358 vs. 0.048
# F1 = 0.440 vs. 0.097
# Precision = 0.358 vs. 0.051
# Recall = 0.569 vs. 0.987
# Minibatch Loss= 0.003655
# Training: 1400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 0.999 vs. 0.182
# Precision = 0.998 vs. 0.102
# Recall = 1.000 vs. 0.878
# Validation: 1400
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.058
# F1 = 0.703 vs. 0.078
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.358 vs. 0.051
# F1 = 0.434 vs. 0.099
# Precision = 0.359 vs. 0.052
# Recall = 0.548 vs. 0.906
# Minibatch Loss= 0.002713
# Training: 1500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 1.000
# Validation: 1500
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.057
# F1 = 0.703 vs. 0.077
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.357 vs. 0.048
# F1 = 0.429 vs. 0.096
# Precision = 0.360 vs. 0.051
# Recall = 0.530 vs. 0.992
# Minibatch Loss= 0.001890
# Training: 1600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.167
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.993
# Validation: 1600
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.703 vs. 0.081
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.356 vs. 0.051
# F1 = 0.431 vs. 0.097
# Precision = 0.374 vs. 0.051
# Recall = 0.509 vs. 0.932
# Minibatch Loss= 0.001542
# Training: 1700
# ACTIVITY RECOGNITION
# AUC = 0.768 vs. 0.062
# F1 = 0.734 vs. 0.093
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.462 vs. 0.089
# F1 = 0.487 vs. 0.166
# Precision = 0.400 vs. 0.090
# Recall = 0.620 vs. 1.000
# Validation: 1700
# ACTIVITY RECOGNITION
# AUC = 0.526 vs. 0.059
# F1 = 0.539 vs. 0.083
# Accuracy = 0.772 vs. 0.056
# CHANGE DETECTION
# AUC = 0.217 vs. 0.052
# F1 = 0.302 vs. 0.097
# Precision = 0.231 vs. 0.051
# Recall = 0.436 vs. 0.940
# Minibatch Loss= 0.247774
# Training: 1800
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.061
# F1 = 0.940 vs. 0.092
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.798 vs. 0.104
# F1 = 0.747 vs. 0.185
# Precision = 0.692 vs. 0.103
# Recall = 0.813 vs. 0.892
# Validation: 1800
# ACTIVITY RECOGNITION
# AUC = 0.749 vs. 0.059
# F1 = 0.718 vs. 0.081
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.364 vs. 0.047
# F1 = 0.433 vs. 0.098
# Precision = 0.342 vs. 0.052
# Recall = 0.590 vs. 0.956
# Minibatch Loss= 0.064255
# Training: 1900
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.062
# F1 = 0.976 vs. 0.093
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.904 vs. 0.094
# F1 = 0.874 vs. 0.163
# Precision = 0.797 vs. 0.089
# Recall = 0.968 vs. 0.964
# Validation: 1900
# ACTIVITY RECOGNITION
# AUC = 0.768 vs. 0.058
# F1 = 0.744 vs. 0.079
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.051
# F1 = 0.451 vs. 0.099
# Precision = 0.378 vs. 0.052
# Recall = 0.561 vs. 0.966
# Minibatch Loss= 0.027249
# Training: 2000
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.060
# F1 = 0.979 vs. 0.090
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.947 vs. 0.099
# F1 = 0.902 vs. 0.178
# Precision = 0.886 vs. 0.098
# Recall = 0.918 vs. 0.976
# Validation: 2000
# ACTIVITY RECOGNITION
# AUC = 0.774 vs. 0.059
# F1 = 0.751 vs. 0.082
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.389 vs. 0.050
# F1 = 0.452 vs. 0.097
# Precision = 0.349 vs. 0.051
# Recall = 0.639 vs. 0.990
# Minibatch Loss= 0.024025
# Training: 2100
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.995 vs. 0.093
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.096
# F1 = 0.967 vs. 0.175
# Precision = 0.944 vs. 0.096
# Recall = 0.992 vs. 0.998
# Validation: 2100
# ACTIVITY RECOGNITION
# AUC = 0.768 vs. 0.059
# F1 = 0.746 vs. 0.084
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.049
# F1 = 0.460 vs. 0.097
# Precision = 0.364 vs. 0.051
# Recall = 0.626 vs. 1.000
# Minibatch Loss= 0.013492
# Training: 2200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.997 vs. 0.094
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.994 vs. 0.099
# F1 = 0.979 vs. 0.179
# Precision = 0.973 vs. 0.098
# Recall = 0.986 vs. 0.984
# Validation: 2200
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.058
# F1 = 0.745 vs. 0.081
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.056
# F1 = 0.454 vs. 0.097
# Precision = 0.394 vs. 0.051
# Recall = 0.538 vs. 0.992
# Minibatch Loss= 0.009762
# Training: 2300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.096
# F1 = 0.993 vs. 0.162
# Precision = 0.989 vs. 0.090
# Recall = 0.998 vs. 0.793
# Validation: 2300
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.059
# F1 = 0.746 vs. 0.084
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.047
# F1 = 0.456 vs. 0.097
# Precision = 0.353 vs. 0.051
# Recall = 0.647 vs. 0.992
# Minibatch Loss= 0.005825
# Training: 2400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.086
# F1 = 0.994 vs. 0.164
# Precision = 0.989 vs. 0.089
# Recall = 1.000 vs. 0.998
# Validation: 2400
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.059
# F1 = 0.744 vs. 0.081
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.050
# F1 = 0.455 vs. 0.097
# Precision = 0.373 vs. 0.051
# Recall = 0.582 vs. 0.966
# Minibatch Loss= 0.005427
# Training: 2500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.149
# Precision = 0.998 vs. 0.081
# Recall = 1.000 vs. 0.998
# Validation: 2500
# ACTIVITY RECOGNITION
# AUC = 0.759 vs. 0.058
# F1 = 0.744 vs. 0.077
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.049
# F1 = 0.449 vs. 0.097
# Precision = 0.374 vs. 0.051
# Recall = 0.561 vs. 0.997
# Minibatch Loss= 0.003785
# Training: 2600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.157
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.433
# Validation: 2600
# ACTIVITY RECOGNITION
# AUC = 0.756 vs. 0.058
# F1 = 0.741 vs. 0.080
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.050
# F1 = 0.448 vs. 0.097
# Precision = 0.378 vs. 0.051
# Recall = 0.548 vs. 0.935
# Minibatch Loss= 0.002868
# Training: 2700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.169
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.907
# Validation: 2700
# ACTIVITY RECOGNITION
# AUC = 0.755 vs. 0.059
# F1 = 0.746 vs. 0.080
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.048
# F1 = 0.446 vs. 0.097
# Precision = 0.371 vs. 0.051
# Recall = 0.558 vs. 0.987
# Minibatch Loss= 0.003144
# Training: 2800
# ACTIVITY RECOGNITION
# AUC = 0.945 vs. 0.060
# F1 = 0.898 vs. 0.089
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.798 vs. 0.083
# F1 = 0.746 vs. 0.152
# Precision = 0.742 vs. 0.082
# Recall = 0.750 vs. 1.000
# Validation: 2800
# ACTIVITY RECOGNITION
# AUC = 0.712 vs. 0.058
# F1 = 0.698 vs. 0.079
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.058
# F1 = 0.428 vs. 0.100
# Precision = 0.367 vs. 0.065
# Recall = 0.514 vs. 0.218
# Minibatch Loss= 0.065036
# Training: 2900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.994 vs. 0.091
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.084
# F1 = 0.972 vs. 0.161
# Precision = 0.957 vs. 0.088
# Recall = 0.987 vs. 0.978
# Validation: 2900
# ACTIVITY RECOGNITION
# AUC = 0.779 vs. 0.059
# F1 = 0.758 vs. 0.082
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.057
# F1 = 0.451 vs. 0.106
# Precision = 0.355 vs. 0.060
# Recall = 0.618 vs. 0.460
# Minibatch Loss= 0.011390
# Training: 3000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.087
# F1 = 0.997 vs. 0.166
# Precision = 0.995 vs. 0.091
# Recall = 0.998 vs. 0.970
# Validation: 3000
# ACTIVITY RECOGNITION
# AUC = 0.781 vs. 0.059
# F1 = 0.753 vs. 0.079
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.371 vs. 0.053
# F1 = 0.446 vs. 0.101
# Precision = 0.388 vs. 0.055
# Recall = 0.525 vs. 0.688
# Minibatch Loss= 0.006137
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 0.998 vs. 0.175
# Precision = 0.996 vs. 0.096
# Recall = 1.000 vs. 0.986
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.777 vs. 0.059
# F1 = 0.756 vs. 0.079
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.371 vs. 0.052
# F1 = 0.442 vs. 0.098
# Precision = 0.373 vs. 0.058
# Recall = 0.543 vs. 0.327
# Minibatch Loss= 0.003974
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.999 vs. 0.088
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.695
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.772 vs. 0.058
# F1 = 0.754 vs. 0.077
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.371 vs. 0.050
# F1 = 0.438 vs. 0.097
# Precision = 0.333 vs. 0.051
# Recall = 0.639 vs. 0.982
# Minibatch Loss= 0.003039
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.105
# F1 = 1.000 vs. 0.177
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.997
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.769 vs. 0.059
# F1 = 0.752 vs. 0.079
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.369 vs. 0.052
# F1 = 0.438 vs. 0.097
# Precision = 0.380 vs. 0.051
# Recall = 0.517 vs. 0.997
# Minibatch Loss= 0.002194
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.105
# F1 = 1.000 vs. 0.185
# Precision = 1.000 vs. 0.104
# Recall = 1.000 vs. 0.871
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.766 vs. 0.059
# F1 = 0.752 vs. 0.080
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.370 vs. 0.055
# F1 = 0.439 vs. 0.105
# Precision = 0.390 vs. 0.062
# Recall = 0.504 vs. 0.345
# Minibatch Loss= 0.002233
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.159
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.620
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.765 vs. 0.058
# F1 = 0.752 vs. 0.077
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.053
# F1 = 0.441 vs. 0.098
# Precision = 0.391 vs. 0.052
# Recall = 0.506 vs. 0.803
# Minibatch Loss= 0.001407
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.150
# Precision = 1.000 vs. 0.081
# Recall = 1.000 vs. 1.000
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.058
# F1 = 0.750 vs. 0.078
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.051
# F1 = 0.440 vs. 0.099
# Precision = 0.370 vs. 0.053
# Recall = 0.543 vs. 0.758
# Minibatch Loss= 0.001110
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.183
# Precision = 1.000 vs. 0.101
# Recall = 1.000 vs. 0.995
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.058
# F1 = 0.750 vs. 0.080
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.052
# F1 = 0.442 vs. 0.096
# Precision = 0.378 vs. 0.051
# Recall = 0.532 vs. 1.000
# Minibatch Loss= 0.001142
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.984
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.058
# F1 = 0.750 vs. 0.078
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.054
# F1 = 0.446 vs. 0.101
# Precision = 0.377 vs. 0.055
# Recall = 0.545 vs. 0.699
# Minibatch Loss= 0.001021
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 1.000
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.059
# F1 = 0.750 vs. 0.081
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.048
# F1 = 0.446 vs. 0.097
# Precision = 0.379 vs. 0.051
# Recall = 0.543 vs. 0.995
# Minibatch Loss= 0.000805
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.109
# F1 = 1.000 vs. 0.183
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.911
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.058
# F1 = 0.750 vs. 0.078
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.051
# F1 = 0.444 vs. 0.097
# Precision = 0.377 vs. 0.051
# Recall = 0.540 vs. 0.997
# Minibatch Loss= 0.000797
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.152
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.996
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.059
# F1 = 0.748 vs. 0.080
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.363 vs. 0.049
# F1 = 0.434 vs. 0.097
# Precision = 0.355 vs. 0.051
# Recall = 0.558 vs. 0.984
# Minibatch Loss= 0.000765
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ffeba5e0f2f2> in <module>()
#       2                 train_eval_step = 100,
#       3                 validation_eval_step = 100,
# ----> 4                 display_step = 100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
trainer.train(max_iter = 6000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 1.000
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.759 vs. 0.058
# F1 = 0.746 vs. 0.078
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.371 vs. 0.055
# F1 = 0.435 vs. 0.098
# Precision = 0.380 vs. 0.061
# Recall = 0.509 vs. 0.242
# Minibatch Loss= 0.000665
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.108
# F1 = 1.000 vs. 0.183
# Precision = 1.000 vs. 0.101
# Recall = 1.000 vs. 0.964
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.060
# F1 = 0.748 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.047
# F1 = 0.438 vs. 0.098
# Precision = 0.354 vs. 0.052
# Recall = 0.574 vs. 0.904
# Minibatch Loss= 0.000589
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.164
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.995
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.058
# F1 = 0.748 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.048
# F1 = 0.440 vs. 0.097
# Precision = 0.397 vs. 0.051
# Recall = 0.494 vs. 0.912
# Minibatch Loss= 0.000484
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.109
# F1 = 1.000 vs. 0.185
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.990
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.059
# F1 = 0.748 vs. 0.080
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.050
# F1 = 0.438 vs. 0.097
# Precision = 0.393 vs. 0.051
# Recall = 0.494 vs. 0.990
# Minibatch Loss= 0.000492
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.087
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.150
# Precision = 1.000 vs. 0.081
# Recall = 1.000 vs. 0.967
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.058
# F1 = 0.747 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.052
# F1 = 0.437 vs. 0.100
# Precision = 0.356 vs. 0.053
# Recall = 0.566 vs. 0.935
# Minibatch Loss= 0.000346
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.989
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.059
# F1 = 0.748 vs. 0.080
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.053
# F1 = 0.438 vs. 0.096
# Precision = 0.357 vs. 0.051
# Recall = 0.564 vs. 0.995
# Minibatch Loss= 0.000354
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.182
# Precision = 1.000 vs. 0.101
# Recall = 1.000 vs. 0.939
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.060
# F1 = 0.747 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.052
# F1 = 0.437 vs. 0.096
# Precision = 0.342 vs. 0.051
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 0.000371
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.180
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.994
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.059
# F1 = 0.748 vs. 0.082
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.052
# F1 = 0.440 vs. 0.101
# Precision = 0.346 vs. 0.055
# Recall = 0.603 vs. 0.655
# Minibatch Loss= 0.000296
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.154
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.998
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.058
# F1 = 0.747 vs. 0.079
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.050
# F1 = 0.441 vs. 0.100
# Precision = 0.344 vs. 0.053
# Recall = 0.613 vs. 0.829
# Minibatch Loss= 0.000228
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.112
# F1 = 1.000 vs. 0.195
# Precision = 1.000 vs. 0.109
# Recall = 1.000 vs. 0.907
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.058
# F1 = 0.746 vs. 0.079
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.051
# F1 = 0.441 vs. 0.097
# Precision = 0.347 vs. 0.051
# Recall = 0.603 vs. 0.997
# Minibatch Loss= 0.000296
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 0.952
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.059
# F1 = 0.747 vs. 0.085
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.056
# F1 = 0.444 vs. 0.102
# Precision = 0.349 vs. 0.059
# Recall = 0.608 vs. 0.382
# Minibatch Loss= 0.000246
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.174
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.912
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.059
# F1 = 0.748 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.051
# F1 = 0.444 vs. 0.098
# Precision = 0.349 vs. 0.052
# Recall = 0.610 vs. 0.914
# Minibatch Loss= 0.000217
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.172
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.884
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.059
# F1 = 0.748 vs. 0.084
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.051
# F1 = 0.446 vs. 0.099
# Precision = 0.362 vs. 0.053
# Recall = 0.582 vs. 0.857
# Minibatch Loss= 0.000201
# Training: 5500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.973
# Validation: 5500
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.058
# F1 = 0.748 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.046
# F1 = 0.448 vs. 0.097
# Precision = 0.363 vs. 0.051
# Recall = 0.584 vs. 0.995
# Minibatch Loss= 0.000211
# Training: 5600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.149
# Precision = 1.000 vs. 0.081
# Recall = 1.000 vs. 1.000
# Validation: 5600
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.059
# F1 = 0.748 vs. 0.078
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.051
# F1 = 0.450 vs. 0.097
# Precision = 0.365 vs. 0.052
# Recall = 0.584 vs. 0.719
# Minibatch Loss= 0.000161
# Training: 5700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.187
# Precision = 1.000 vs. 0.103
# Recall = 1.000 vs. 1.000
# Validation: 5700
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.058
# F1 = 0.748 vs. 0.078
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.048
# F1 = 0.450 vs. 0.097
# Precision = 0.366 vs. 0.051
# Recall = 0.584 vs. 0.990
# Minibatch Loss= 0.000168
# Training: 5800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.158
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 1.000
# Validation: 5800
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.060
# F1 = 0.748 vs. 0.082
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.055
# F1 = 0.449 vs. 0.099
# Precision = 0.368 vs. 0.055
# Recall = 0.577 vs. 0.525
# Minibatch Loss= 0.000134
# Training: 5900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.181
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.981
# Validation: 5900
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.060
# F1 = 0.748 vs. 0.083
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.053
# F1 = 0.448 vs. 0.100
# Precision = 0.368 vs. 0.053
# Recall = 0.574 vs. 0.769
# Minibatch Loss= 0.000158
# Training: 6000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.912
# Validation: 6000
# ACTIVITY RECOGNITION
# AUC = 0.761 vs. 0.060
# F1 = 0.748 vs. 0.082
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.053
# F1 = 0.447 vs. 0.099
# Precision = 0.364 vs. 0.056
# Recall = 0.579 vs. 0.439
# Minibatch Loss= 0.000133
# Training: 6100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.996
# Validation: 6100
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.058
# F1 = 0.749 vs. 0.079
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.055
# F1 = 0.447 vs. 0.102
# Precision = 0.360 vs. 0.059
# Recall = 0.592 vs. 0.364
# Minibatch Loss= 0.000125
# Training: 6200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.988
# Validation: 6200
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.750 vs. 0.081
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.050
# F1 = 0.446 vs. 0.097
# Precision = 0.359 vs. 0.051
# Recall = 0.590 vs. 0.919
# Minibatch Loss= 0.000143
# Training: 6300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.809
# Validation: 6300
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.750 vs. 0.084
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.053
# F1 = 0.446 vs. 0.098
# Precision = 0.358 vs. 0.052
# Recall = 0.590 vs. 0.956
# Minibatch Loss= 0.000088
# Training: 6400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.164
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.986
# Validation: 6400
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.058
# F1 = 0.751 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.046
# F1 = 0.442 vs. 0.097
# Precision = 0.356 vs. 0.051
# Recall = 0.584 vs. 0.964
# Minibatch Loss= 0.000112
# Training: 6500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.100
# Recall = 1.000 vs. 0.816
# Validation: 6500
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.057
# F1 = 0.751 vs. 0.076
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.053
# F1 = 0.441 vs. 0.098
# Precision = 0.351 vs. 0.057
# Recall = 0.592 vs. 0.356
# Minibatch Loss= 0.000100
# Training: 6600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.974
# Validation: 6600
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.751 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.054
# F1 = 0.440 vs. 0.098
# Precision = 0.351 vs. 0.053
# Recall = 0.590 vs. 0.577
# Minibatch Loss= 0.000083
# Training: 6700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.931
# Validation: 6700
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.751 vs. 0.078
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.048
# F1 = 0.438 vs. 0.097
# Precision = 0.349 vs. 0.051
# Recall = 0.590 vs. 0.966
# Minibatch Loss= 0.000080
# Training: 6800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.846
# Validation: 6800
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.058
# F1 = 0.751 vs. 0.079
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.051
# F1 = 0.438 vs. 0.098
# Precision = 0.365 vs. 0.054
# Recall = 0.548 vs. 0.478
# Minibatch Loss= 0.000071
# Training: 6900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.996
# Validation: 6900
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.058
# F1 = 0.752 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.054
# F1 = 0.438 vs. 0.100
# Precision = 0.364 vs. 0.063
# Recall = 0.548 vs. 0.249
# Minibatch Loss= 0.000071
# Training: 7000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.152
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.998
# Validation: 7000
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.752 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.048
# F1 = 0.439 vs. 0.099
# Precision = 0.366 vs. 0.052
# Recall = 0.548 vs. 0.982
# Minibatch Loss= 0.000066
# Training: 7100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.982
# Validation: 7100
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.753 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.050
# F1 = 0.437 vs. 0.098
# Precision = 0.351 vs. 0.052
# Recall = 0.579 vs. 0.956
# Minibatch Loss= 0.000056
# Training: 7200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.073
# F1 = 1.000 vs. 0.146
# Precision = 1.000 vs. 0.079
# Recall = 1.000 vs. 0.986
# Validation: 7200
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.060
# F1 = 0.754 vs. 0.082
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.056
# F1 = 0.438 vs. 0.105
# Precision = 0.353 vs. 0.060
# Recall = 0.577 vs. 0.421
# Minibatch Loss= 0.000055
# Training: 7300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.159
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.998
# Validation: 7300
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.753 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.050
# F1 = 0.437 vs. 0.098
# Precision = 0.362 vs. 0.052
# Recall = 0.553 vs. 0.831
# Minibatch Loss= 0.000062
# Training: 7400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.935
# Validation: 7400
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.752 vs. 0.080
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.048
# F1 = 0.439 vs. 0.097
# Precision = 0.353 vs. 0.051
# Recall = 0.579 vs. 0.997
# Minibatch Loss= 0.000052
# Training: 7500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.963
# Validation: 7500
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.753 vs. 0.082
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.056
# F1 = 0.438 vs. 0.097
# Precision = 0.387 vs. 0.051
# Recall = 0.504 vs. 0.883
# Minibatch Loss= 0.000063
# Training: 7600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.180
# Precision = 1.000 vs. 0.103
# Recall = 1.000 vs. 0.697
# Validation: 7600
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.058
# F1 = 0.752 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.052
# F1 = 0.439 vs. 0.100
# Precision = 0.387 vs. 0.054
# Recall = 0.506 vs. 0.766
# Minibatch Loss= 0.000056
# Training: 7700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.950
# Validation: 7700
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.753 vs. 0.080
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.050
# F1 = 0.439 vs. 0.097
# Precision = 0.393 vs. 0.051
# Recall = 0.499 vs. 0.997
# Minibatch Loss= 0.000049
# Training: 7800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.138
# Precision = 1.000 vs. 0.074
# Recall = 1.000 vs. 0.976
# Validation: 7800
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.752 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.048
# F1 = 0.438 vs. 0.097
# Precision = 0.392 vs. 0.052
# Recall = 0.496 vs. 0.834
# Minibatch Loss= 0.000038
# Training: 7900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.166
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.997
# Validation: 7900
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.752 vs. 0.080
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.049
# F1 = 0.438 vs. 0.097
# Precision = 0.392 vs. 0.051
# Recall = 0.496 vs. 0.984
# Minibatch Loss= 0.000041
# Training: 8000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.180
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.972
# Validation: 8000
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.751 vs. 0.078
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.054
# F1 = 0.438 vs. 0.102
# Precision = 0.362 vs. 0.055
# Recall = 0.553 vs. 0.634
# Minibatch Loss= 0.000041
# Training: 8100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.954
# Validation: 8100
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.752 vs. 0.079
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.054
# F1 = 0.438 vs. 0.100
# Precision = 0.362 vs. 0.054
# Recall = 0.553 vs. 0.647
# Minibatch Loss= 0.000033
# Training: 8200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.164
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.982
# Validation: 8200
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.754 vs. 0.079
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.056
# F1 = 0.439 vs. 0.096
# Precision = 0.364 vs. 0.051
# Recall = 0.553 vs. 1.000
# Minibatch Loss= 0.000039
# Training: 8300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.146
# Precision = 1.000 vs. 0.079
# Recall = 1.000 vs. 0.988
# Validation: 8300
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.754 vs. 0.081
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.052
# F1 = 0.438 vs. 0.102
# Precision = 0.370 vs. 0.056
# Recall = 0.538 vs. 0.660
# Minibatch Loss= 0.000032
# Training: 8400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 1.000
# Validation: 8400
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.058
# F1 = 0.754 vs. 0.076
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.052
# F1 = 0.439 vs. 0.098
# Precision = 0.371 vs. 0.052
# Recall = 0.538 vs. 0.860
# Minibatch Loss= 0.000028
# Training: 8500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.966
# Validation: 8500
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.755 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.049
# F1 = 0.437 vs. 0.097
# Precision = 0.370 vs. 0.051
# Recall = 0.535 vs. 0.914
# Minibatch Loss= 0.000027
# Training: 8600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.894
# Validation: 8600
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.755 vs. 0.083
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.059
# F1 = 0.437 vs. 0.108
# Precision = 0.364 vs. 0.065
# Recall = 0.548 vs. 0.322
# Minibatch Loss= 0.000032
# Training: 8700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.175
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.971
# Validation: 8700
# ACTIVITY RECOGNITION
# AUC = 0.764 vs. 0.059
# F1 = 0.755 vs. 0.080
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.048
# F1 = 0.438 vs. 0.102
# Precision = 0.392 vs. 0.055
# Recall = 0.496 vs. 0.735
# Minibatch Loss= 0.000027
# Training: 8800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.153
# Precision = 1.000 vs. 0.083
# Recall = 1.000 vs. 0.988
# Validation: 8800
# ACTIVITY RECOGNITION
# AUC = 0.764 vs. 0.060
# F1 = 0.755 vs. 0.081
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.056
# F1 = 0.438 vs. 0.102
# Precision = 0.392 vs. 0.058
# Recall = 0.496 vs. 0.395
# Minibatch Loss= 0.000021
# Training: 8900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.993
# Validation: 8900
# ACTIVITY RECOGNITION
# AUC = 0.764 vs. 0.059
# F1 = 0.755 vs. 0.079
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.055
# F1 = 0.438 vs. 0.097
# Precision = 0.392 vs. 0.052
# Recall = 0.496 vs. 0.792
# Minibatch Loss= 0.000026
# Training: 9000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.175
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.870
# Validation: 9000
# ACTIVITY RECOGNITION
# AUC = 0.764 vs. 0.058
# F1 = 0.755 vs. 0.079
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.047
# F1 = 0.439 vs. 0.097
# Precision = 0.379 vs. 0.051
# Recall = 0.522 vs. 0.987
# Minibatch Loss= 0.000026
# Training: 9100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.144
# Precision = 1.000 vs. 0.080
# Recall = 1.000 vs. 0.743
# Validation: 9100
# ACTIVITY RECOGNITION
# AUC = 0.764 vs. 0.059
# F1 = 0.755 vs. 0.079
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.051
# F1 = 0.438 vs. 0.096
# Precision = 0.378 vs. 0.051
# Recall = 0.522 vs. 0.992
# Minibatch Loss= 0.000020
# Training: 9200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.087
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.993
# Validation: 9200
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.058
# F1 = 0.755 vs. 0.080
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.050
# F1 = 0.438 vs. 0.099
# Precision = 0.361 vs. 0.052
# Recall = 0.558 vs. 0.834
# Minibatch Loss= 0.000019
# Training: 9300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.155
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.996
# Validation: 9300
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.058
# F1 = 0.755 vs. 0.078
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.050
# F1 = 0.438 vs. 0.096
# Precision = 0.378 vs. 0.051
# Recall = 0.522 vs. 1.000
# Minibatch Loss= 0.000017
# Training: 9400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.838
# Validation: 9400
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.754 vs. 0.080
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.050
# F1 = 0.439 vs. 0.096
# Precision = 0.379 vs. 0.051
# Recall = 0.522 vs. 0.997
# Minibatch Loss= 0.000017
# Training: 9500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.997
# Validation: 9500
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.058
# F1 = 0.755 vs. 0.078
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.051
# F1 = 0.438 vs. 0.099
# Precision = 0.378 vs. 0.052
# Recall = 0.522 vs. 0.868
# Minibatch Loss= 0.000020
# Training: 9600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.864
# Validation: 9600
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.754 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.053
# F1 = 0.439 vs. 0.098
# Precision = 0.365 vs. 0.052
# Recall = 0.551 vs. 0.831
# Minibatch Loss= 0.000018
# Training: 9700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.169
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.932
# Validation: 9700
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.059
# F1 = 0.753 vs. 0.082
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.055
# F1 = 0.440 vs. 0.103
# Precision = 0.382 vs. 0.057
# Recall = 0.519 vs. 0.519
# Minibatch Loss= 0.000015
# Training: 9800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.112
# F1 = 1.000 vs. 0.193
# Precision = 1.000 vs. 0.107
# Recall = 1.000 vs. 0.996
# Validation: 9800
# ACTIVITY RECOGNITION
# AUC = 0.763 vs. 0.058
# F1 = 0.754 vs. 0.079
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.056
# F1 = 0.440 vs. 0.097
# Precision = 0.382 vs. 0.051
# Recall = 0.519 vs. 0.992
# Minibatch Loss= 0.000019
# Training: 9900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.100
# Recall = 1.000 vs. 0.725
# Validation: 9900
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.754 vs. 0.079
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.052
# F1 = 0.440 vs. 0.098
# Precision = 0.381 vs. 0.053
# Recall = 0.519 vs. 0.691
# Minibatch Loss= 0.000014
# Training: 10000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.157
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.909
# Validation: 10000
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.060
# F1 = 0.754 vs. 0.083
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.050
# F1 = 0.439 vs. 0.098
# Precision = 0.380 vs. 0.053
# Recall = 0.519 vs. 0.657
# Minibatch Loss= 0.000012
# Training: 10100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.100
# Recall = 1.000 vs. 0.861
# Validation: 10100
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.059
# F1 = 0.754 vs. 0.081
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.047
# F1 = 0.439 vs. 0.097
# Precision = 0.380 vs. 0.051
# Recall = 0.519 vs. 0.948
# Minibatch Loss= 0.000016
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/HRNN_Wmultitask_16_opp2/HRNN_Wmultitask_16_opp2-10141'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-4495')
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.762 vs. 0.058
# F1 = 0.754 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.052
# F1 = 0.440 vs. 0.096
# Precision = 0.384 vs. 0.051
# Recall = 0.514 vs. 0.992

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2
