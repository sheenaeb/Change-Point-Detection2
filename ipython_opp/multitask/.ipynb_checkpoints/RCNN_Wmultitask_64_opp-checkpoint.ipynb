# %%
# useing this variable for saving models and summaries
exp_name = "RCNN_Wmultitask_64_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.16329966,  34.21019108,  34.43589744,  37.12413793,
#         36.10067114,  26.70927318,  27.27621483,  39.94814815,
#         42.01945525,  46.65517241,  51.89952153,  48.57847534,
#         51.1509434 ,  43.40160643,  44.68595041,  33.7672956 ,
#         10.65015806,  36.60544218,   2.20649652])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables = n_variables,
                        n_classes = n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride = pooling_stride,
                         weights_shape = weights_shape,
                         bias_shape = bias_shape,
                         activation = activation,
                         lstm_n_hidden = lstm_n_hidden,
                         n_classes = n_classes,
                         learning_rate = learning_rate,
                         pos_weight = pos_weight,
                         trainable_conv = True,
                         trainable_last = True,
                         variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.073
# F1 = 0.109 vs. 0.104
# Accuracy = 0.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.213 vs. 0.252
# F1 = 0.418 vs. 0.397
# Precision = 0.265 vs. 0.248
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.070
# F1 = 0.106 vs. 0.105
# Accuracy = 0.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.139 vs. 0.194
# F1 = 0.325 vs. 0.313
# Precision = 0.195 vs. 0.187
# Recall = 0.966 vs. 0.974
# Minibatch Loss= 1.633819
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.689 vs. 0.077
# F1 = 0.691 vs. 0.117
# Accuracy = 0.690 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.349
# F1 = 0.726 vs. 0.485
# Precision = 0.617 vs. 0.320
# Recall = 0.882 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.413 vs. 0.069
# F1 = 0.470 vs. 0.103
# Accuracy = 0.673 vs. 0.056
# CHANGE DETECTION
# AUC = 0.550 vs. 0.189
# F1 = 0.585 vs. 0.311
# Precision = 0.502 vs. 0.184
# Recall = 0.701 vs. 1.000
# Minibatch Loss= 0.316315
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.851 vs. 0.078
# F1 = 0.820 vs. 0.120
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.792 vs. 0.314
# F1 = 0.750 vs. 0.461
# Precision = 0.651 vs. 0.300
# Recall = 0.885 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.506 vs. 0.069
# F1 = 0.563 vs. 0.102
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.595 vs. 0.195
# F1 = 0.597 vs. 0.313
# Precision = 0.471 vs. 0.185
# Recall = 0.815 vs. 1.000
# Minibatch Loss= 0.166790
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.937 vs. 0.080
# F1 = 0.898 vs. 0.127
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.824 vs. 0.286
# F1 = 0.783 vs. 0.433
# Precision = 0.720 vs. 0.276
# Recall = 0.858 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.540 vs. 0.069
# F1 = 0.584 vs. 0.105
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.637 vs. 0.200
# F1 = 0.645 vs. 0.312
# Precision = 0.556 vs. 0.185
# Recall = 0.769 vs. 1.000
# Minibatch Loss= 0.098233
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.957 vs. 0.077
# F1 = 0.914 vs. 0.116
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.820 vs. 0.286
# F1 = 0.790 vs. 0.451
# Precision = 0.764 vs. 0.292
# Recall = 0.819 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.068
# F1 = 0.600 vs. 0.097
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.648 vs. 0.184
# F1 = 0.650 vs. 0.317
# Precision = 0.591 vs. 0.192
# Recall = 0.721 vs. 0.909
# Minibatch Loss= 0.084461
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.078
# F1 = 0.946 vs. 0.115
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.883 vs. 0.324
# F1 = 0.831 vs. 0.481
# Precision = 0.772 vs. 0.316
# Recall = 0.901 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.072
# F1 = 0.598 vs. 0.108
# Accuracy = 0.838 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.197
# F1 = 0.667 vs. 0.313
# Precision = 0.597 vs. 0.186
# Recall = 0.755 vs. 1.000
# Minibatch Loss= 0.065941
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.081
# F1 = 0.956 vs. 0.122
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.905 vs. 0.353
# F1 = 0.869 vs. 0.518
# Precision = 0.799 vs. 0.350
# Recall = 0.953 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.591 vs. 0.069
# F1 = 0.615 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.686 vs. 0.190
# F1 = 0.677 vs. 0.315
# Precision = 0.668 vs. 0.193
# Recall = 0.687 vs. 0.872
# Minibatch Loss= 0.061184
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.076
# F1 = 0.967 vs. 0.115
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.910 vs. 0.299
# F1 = 0.871 vs. 0.449
# Precision = 0.842 vs. 0.289
# Recall = 0.903 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.069
# F1 = 0.602 vs. 0.099
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.693 vs. 0.193
# F1 = 0.676 vs. 0.311
# Precision = 0.650 vs. 0.184
# Recall = 0.704 vs. 1.000
# Minibatch Loss= 0.045726
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.085
# F1 = 0.977 vs. 0.124
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.963 vs. 0.402
# F1 = 0.913 vs. 0.540
# Precision = 0.892 vs. 0.370
# Recall = 0.936 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.070
# F1 = 0.611 vs. 0.098
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.196
# F1 = 0.695 vs. 0.312
# Precision = 0.655 vs. 0.185
# Recall = 0.741 vs. 0.997
# Minibatch Loss= 0.041862
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.081
# F1 = 0.988 vs. 0.117
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.956 vs. 0.339
# F1 = 0.928 vs. 0.522
# Precision = 0.907 vs. 0.353
# Recall = 0.950 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.070
# F1 = 0.607 vs. 0.108
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.716 vs. 0.181
# F1 = 0.700 vs. 0.313
# Precision = 0.677 vs. 0.185
# Recall = 0.724 vs. 0.997
# Minibatch Loss= 0.031671
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.080
# F1 = 0.994 vs. 0.119
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.303
# F1 = 0.944 vs. 0.453
# Precision = 0.920 vs. 0.293
# Recall = 0.969 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.069
# F1 = 0.606 vs. 0.100
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.719 vs. 0.205
# F1 = 0.698 vs. 0.311
# Precision = 0.660 vs. 0.184
# Recall = 0.741 vs. 1.000
# Minibatch Loss= 0.022844
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.083
# F1 = 0.995 vs. 0.120
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.319
# F1 = 0.961 vs. 0.504
# Precision = 0.949 vs. 0.338
# Recall = 0.974 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.069
# F1 = 0.613 vs. 0.101
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.718 vs. 0.186
# F1 = 0.684 vs. 0.312
# Precision = 0.675 vs. 0.186
# Recall = 0.692 vs. 0.969
# Minibatch Loss= 0.020076
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.080
# F1 = 0.994 vs. 0.121
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.251
# F1 = 0.946 vs. 0.417
# Precision = 0.916 vs. 0.264
# Recall = 0.979 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.069
# F1 = 0.617 vs. 0.102
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.720 vs. 0.194
# F1 = 0.687 vs. 0.313
# Precision = 0.671 vs. 0.185
# Recall = 0.704 vs. 0.997
# Minibatch Loss= 0.017600
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.997 vs. 0.116
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.304
# F1 = 0.969 vs. 0.470
# Precision = 0.958 vs. 0.307
# Recall = 0.980 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.071
# F1 = 0.610 vs. 0.108
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.723 vs. 0.187
# F1 = 0.685 vs. 0.313
# Precision = 0.720 vs. 0.186
# Recall = 0.652 vs. 0.997
# Minibatch Loss= 0.014295
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.997 vs. 0.116
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.286
# F1 = 0.975 vs. 0.436
# Precision = 0.971 vs. 0.279
# Recall = 0.980 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.073
# F1 = 0.606 vs. 0.114
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.725 vs. 0.182
# F1 = 0.683 vs. 0.313
# Precision = 0.707 vs. 0.186
# Recall = 0.661 vs. 0.980
# Minibatch Loss= 0.011071
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.999 vs. 0.113
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.267
# F1 = 0.980 vs. 0.429
# Precision = 0.984 vs. 0.273
# Recall = 0.977 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.068
# F1 = 0.609 vs. 0.102
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.722 vs. 0.182
# F1 = 0.684 vs. 0.313
# Precision = 0.653 vs. 0.185
# Recall = 0.718 vs. 1.000
# Minibatch Loss= 0.009017
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.894 vs. 0.075
# F1 = 0.858 vs. 0.114
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.783 vs. 0.263
# F1 = 0.752 vs. 0.414
# Precision = 0.625 vs. 0.262
# Recall = 0.944 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.531 vs. 0.070
# F1 = 0.594 vs. 0.102
# Accuracy = 0.835 vs. 0.056
# CHANGE DETECTION
# AUC = 0.647 vs. 0.189
# F1 = 0.666 vs. 0.313
# Precision = 0.608 vs. 0.186
# Recall = 0.735 vs. 1.000
# Minibatch Loss= 0.124217
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.083
# F1 = 0.939 vs. 0.125
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.325
# F1 = 0.855 vs. 0.502
# Precision = 0.787 vs. 0.336
# Recall = 0.936 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.070
# F1 = 0.627 vs. 0.106
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.190
# F1 = 0.695 vs. 0.315
# Precision = 0.695 vs. 0.189
# Recall = 0.695 vs. 0.949
# Minibatch Loss= 0.066813
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.079
# F1 = 0.974 vs. 0.123
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.282
# F1 = 0.901 vs. 0.436
# Precision = 0.849 vs. 0.279
# Recall = 0.960 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.070
# F1 = 0.641 vs. 0.100
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.714 vs. 0.194
# F1 = 0.694 vs. 0.322
# Precision = 0.649 vs. 0.199
# Recall = 0.746 vs. 0.846
# Minibatch Loss= 0.038967
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.079
# F1 = 0.981 vs. 0.119
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.951 vs. 0.307
# F1 = 0.908 vs. 0.494
# Precision = 0.877 vs. 0.330
# Recall = 0.941 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.068
# F1 = 0.642 vs. 0.093
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.720 vs. 0.173
# F1 = 0.701 vs. 0.315
# Precision = 0.647 vs. 0.192
# Recall = 0.764 vs. 0.889
# Minibatch Loss= 0.039426
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.078
# F1 = 0.989 vs. 0.119
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.975 vs. 0.282
# F1 = 0.926 vs. 0.461
# Precision = 0.914 vs. 0.301
# Recall = 0.939 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.068
# F1 = 0.643 vs. 0.095
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.729 vs. 0.179
# F1 = 0.706 vs. 0.314
# Precision = 0.660 vs. 0.187
# Recall = 0.758 vs. 0.994
# Minibatch Loss= 0.025638
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.080
# F1 = 0.991 vs. 0.117
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.967 vs. 0.322
# F1 = 0.934 vs. 0.467
# Precision = 0.911 vs. 0.305
# Recall = 0.959 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.070
# F1 = 0.640 vs. 0.101
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.177
# F1 = 0.705 vs. 0.313
# Precision = 0.668 vs. 0.186
# Recall = 0.746 vs. 0.989
# Minibatch Loss= 0.024602
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.081
# F1 = 0.991 vs. 0.119
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.297
# F1 = 0.946 vs. 0.449
# Precision = 0.927 vs. 0.289
# Recall = 0.965 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.073
# F1 = 0.642 vs. 0.112
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.732 vs. 0.177
# F1 = 0.709 vs. 0.319
# Precision = 0.678 vs. 0.191
# Recall = 0.744 vs. 0.969
# Minibatch Loss= 0.020674
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.078
# F1 = 0.994 vs. 0.118
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.273
# F1 = 0.957 vs. 0.436
# Precision = 0.949 vs. 0.278
# Recall = 0.964 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.070
# F1 = 0.647 vs. 0.095
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.742 vs. 0.201
# F1 = 0.715 vs. 0.312
# Precision = 0.691 vs. 0.185
# Recall = 0.741 vs. 1.000
# Minibatch Loss= 0.016117
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.072
# F1 = 0.997 vs. 0.110
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.253
# F1 = 0.964 vs. 0.425
# Precision = 0.944 vs. 0.270
# Recall = 0.985 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.632 vs. 0.070
# F1 = 0.643 vs. 0.103
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.740 vs. 0.191
# F1 = 0.708 vs. 0.313
# Precision = 0.665 vs. 0.188
# Recall = 0.758 vs. 0.923
# Minibatch Loss= 0.014095
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.081
# F1 = 0.998 vs. 0.125
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.324
# F1 = 0.977 vs. 0.490
# Precision = 0.968 vs. 0.325
# Recall = 0.987 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.073
# F1 = 0.640 vs. 0.107
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.738 vs. 0.174
# F1 = 0.707 vs. 0.311
# Precision = 0.661 vs. 0.184
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.013136
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.116
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.316
# F1 = 0.976 vs. 0.483
# Precision = 0.964 vs. 0.318
# Recall = 0.988 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.069
# F1 = 0.638 vs. 0.101
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.740 vs. 0.191
# F1 = 0.704 vs. 0.313
# Precision = 0.662 vs. 0.189
# Recall = 0.752 vs. 0.915
# Minibatch Loss= 0.011934
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.308
# F1 = 0.981 vs. 0.459
# Precision = 0.971 vs. 0.307
# Recall = 0.992 vs. 0.907
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.072
# F1 = 0.638 vs. 0.112
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.742 vs. 0.193
# F1 = 0.702 vs. 0.314
# Precision = 0.650 vs. 0.188
# Recall = 0.764 vs. 0.934
# Minibatch Loss= 0.009533
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.118
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.323
# F1 = 0.987 vs. 0.489
# Precision = 0.983 vs. 0.324
# Recall = 0.992 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.068
# F1 = 0.637 vs. 0.098
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.740 vs. 0.177
# F1 = 0.699 vs. 0.316
# Precision = 0.691 vs. 0.188
# Recall = 0.707 vs. 0.983
# Minibatch Loss= 0.009067
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.116
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.265
# F1 = 0.993 vs. 0.441
# Precision = 0.996 vs. 0.283
# Recall = 0.991 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.625 vs. 0.070
# F1 = 0.637 vs. 0.101
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.739 vs. 0.192
# F1 = 0.695 vs. 0.320
# Precision = 0.671 vs. 0.193
# Recall = 0.721 vs. 0.937
# Minibatch Loss= 0.007005
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.113
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.325
# F1 = 0.995 vs. 0.482
# Precision = 0.994 vs. 0.318
# Recall = 0.996 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.068
# F1 = 0.632 vs. 0.097
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.746 vs. 0.175
# F1 = 0.699 vs. 0.313
# Precision = 0.700 vs. 0.185
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.007347
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.999 vs. 0.129
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.356
# F1 = 0.995 vs. 0.526
# Precision = 0.994 vs. 0.357
# Recall = 0.996 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.068
# F1 = 0.632 vs. 0.104
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.742 vs. 0.191
# F1 = 0.695 vs. 0.315
# Precision = 0.703 vs. 0.190
# Recall = 0.687 vs. 0.926
# Minibatch Loss= 0.007347
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.999 vs. 0.119
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.334
# F1 = 0.997 vs. 0.495
# Precision = 0.994 vs. 0.329
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.069
# F1 = 0.631 vs. 0.102
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.739 vs. 0.186
# F1 = 0.691 vs. 0.311
# Precision = 0.654 vs. 0.184
# Recall = 0.732 vs. 1.000
# Minibatch Loss= 0.005784
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.311
# F1 = 0.997 vs. 0.464
# Precision = 0.994 vs. 0.303
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.070
# F1 = 0.632 vs. 0.101
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.740 vs. 0.182
# F1 = 0.691 vs. 0.312
# Precision = 0.652 vs. 0.185
# Recall = 0.735 vs. 0.991
# Minibatch Loss= 0.004722
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.315
# F1 = 0.998 vs. 0.486
# Precision = 0.996 vs. 0.321
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.071
# F1 = 0.634 vs. 0.108
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.741 vs. 0.181
# F1 = 0.692 vs. 0.312
# Precision = 0.706 vs. 0.186
# Recall = 0.678 vs. 0.974
# Minibatch Loss= 0.004466
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.306
# F1 = 0.999 vs. 0.487
# Precision = 0.998 vs. 0.322
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.071
# F1 = 0.634 vs. 0.105
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.738 vs. 0.172
# F1 = 0.691 vs. 0.313
# Precision = 0.641 vs. 0.185
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.003970
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.292
# F1 = 1.000 vs. 0.471
# Precision = 1.000 vs. 0.308
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.068
# F1 = 0.635 vs. 0.097
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.738 vs. 0.200
# F1 = 0.694 vs. 0.313
# Precision = 0.642 vs. 0.190
# Recall = 0.755 vs. 0.886
# Minibatch Loss= 0.004044
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.320
# F1 = 0.999 vs. 0.483
# Precision = 0.998 vs. 0.319
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.074
# F1 = 0.633 vs. 0.109
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.736 vs. 0.175
# F1 = 0.691 vs. 0.313
# Precision = 0.670 vs. 0.186
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.003349
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.123
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.299
# F1 = 1.000 vs. 0.466
# Precision = 1.000 vs. 0.304
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.069
# F1 = 0.635 vs. 0.098
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.736 vs. 0.206
# F1 = 0.688 vs. 0.314
# Precision = 0.670 vs. 0.188
# Recall = 0.707 vs. 0.943
# Minibatch Loss= 0.003114
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.121
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.314
# F1 = 1.000 vs. 0.487
# Precision = 1.000 vs. 0.322
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.069
# F1 = 0.633 vs. 0.097
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.187
# F1 = 0.688 vs. 0.311
# Precision = 0.668 vs. 0.184
# Recall = 0.709 vs. 1.000
# Minibatch Loss= 0.002702
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.341
# F1 = 1.000 vs. 0.514
# Precision = 1.000 vs. 0.348
# Recall = 1.000 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.068
# F1 = 0.634 vs. 0.101
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.184
# F1 = 0.689 vs. 0.313
# Precision = 0.658 vs. 0.186
# Recall = 0.724 vs. 0.994
# Minibatch Loss= 0.002473
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.327
# F1 = 1.000 vs. 0.493
# Precision = 1.000 vs. 0.327
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.070
# F1 = 0.634 vs. 0.101
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.182
# F1 = 0.688 vs. 0.314
# Precision = 0.656 vs. 0.186
# Recall = 0.724 vs. 0.994
# Minibatch Loss= 0.002216
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.298
# F1 = 1.000 vs. 0.457
# Precision = 1.000 vs. 0.296
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.070
# F1 = 0.633 vs. 0.107
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.184
# F1 = 0.686 vs. 0.314
# Precision = 0.659 vs. 0.190
# Recall = 0.715 vs. 0.900
# Minibatch Loss= 0.001857
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.287
# F1 = 1.000 vs. 0.437
# Precision = 1.000 vs. 0.281
# Recall = 1.000 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.069
# F1 = 0.633 vs. 0.102
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.733 vs. 0.180
# F1 = 0.682 vs. 0.311
# Precision = 0.662 vs. 0.184
# Recall = 0.704 vs. 1.000
# Minibatch Loss= 0.001718
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.121
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.343
# F1 = 1.000 vs. 0.505
# Precision = 1.000 vs. 0.338
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.069
# F1 = 0.635 vs. 0.099
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.733 vs. 0.189
# F1 = 0.681 vs. 0.315
# Precision = 0.663 vs. 0.187
# Recall = 0.701 vs. 0.991
# Minibatch Loss= 0.001711
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.264
# F1 = 1.000 vs. 0.423
# Precision = 1.000 vs. 0.279
# Recall = 1.000 vs. 0.874
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.072
# F1 = 0.635 vs. 0.103
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.733 vs. 0.181
# F1 = 0.682 vs. 0.312
# Precision = 0.609 vs. 0.185
# Recall = 0.775 vs. 0.997
# Minibatch Loss= 0.001645
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.334
# F1 = 1.000 vs. 0.514
# Precision = 1.000 vs. 0.346
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.068
# F1 = 0.635 vs. 0.101
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.185
# F1 = 0.682 vs. 0.313
# Precision = 0.612 vs. 0.188
# Recall = 0.769 vs. 0.934
# Minibatch Loss= 0.001369
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.310
# F1 = 1.000 vs. 0.486
# Precision = 1.000 vs. 0.321
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.066
# F1 = 0.632 vs. 0.095
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.209
# F1 = 0.683 vs. 0.319
# Precision = 0.614 vs. 0.195
# Recall = 0.769 vs. 0.889
# Minibatch Loss= 0.001218
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.371
# F1 = 1.000 vs. 0.543
# Precision = 1.000 vs. 0.373
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.070
# F1 = 0.632 vs. 0.104
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.181
# F1 = 0.679 vs. 0.313
# Precision = 0.596 vs. 0.186
# Recall = 0.789 vs. 0.986
# Minibatch Loss= 0.001450
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.128
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.336
# F1 = 1.000 vs. 0.504
# Precision = 1.000 vs. 0.337
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.069
# F1 = 0.632 vs. 0.102
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.730 vs. 0.180
# F1 = 0.680 vs. 0.316
# Precision = 0.597 vs. 0.188
# Recall = 0.789 vs. 0.980
# Minibatch Loss= 0.001042
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.330
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.331
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.069
# F1 = 0.635 vs. 0.099
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.729 vs. 0.193
# F1 = 0.678 vs. 0.318
# Precision = 0.615 vs. 0.197
# Recall = 0.755 vs. 0.812
# Minibatch Loss= 0.001060
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.338
# F1 = 1.000 vs. 0.492
# Precision = 1.000 vs. 0.326
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.070
# F1 = 0.633 vs. 0.103
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.730 vs. 0.184
# F1 = 0.678 vs. 0.313
# Precision = 0.591 vs. 0.186
# Recall = 0.795 vs. 0.991
# Minibatch Loss= 0.001056
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.347
# F1 = 1.000 vs. 0.493
# Precision = 1.000 vs. 0.328
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.069
# F1 = 0.633 vs. 0.098
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.728 vs. 0.178
# F1 = 0.676 vs. 0.312
# Precision = 0.589 vs. 0.185
# Recall = 0.792 vs. 0.997
# Minibatch Loss= 0.000898
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.314
# F1 = 1.000 vs. 0.485
# Precision = 1.000 vs. 0.320
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.070
# F1 = 0.632 vs. 0.100
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.728 vs. 0.206
# F1 = 0.675 vs. 0.320
# Precision = 0.630 vs. 0.192
# Recall = 0.726 vs. 0.963
# Minibatch Loss= 0.000843
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.319
# F1 = 1.000 vs. 0.484
# Precision = 1.000 vs. 0.319
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.069
# F1 = 0.632 vs. 0.104
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.728 vs. 0.173
# F1 = 0.680 vs. 0.313
# Precision = 0.635 vs. 0.186
# Recall = 0.732 vs. 0.989
# Minibatch Loss= 0.000710
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.328
# F1 = 1.000 vs. 0.479
# Precision = 1.000 vs. 0.315
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.075
# F1 = 0.634 vs. 0.109
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.729 vs. 0.193
# F1 = 0.686 vs. 0.312
# Precision = 0.641 vs. 0.187
# Recall = 0.738 vs. 0.937
# Minibatch Loss= 0.000730
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.261
# F1 = 1.000 vs. 0.404
# Precision = 1.000 vs. 0.253
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.069
# F1 = 0.633 vs. 0.107
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.184
# F1 = 0.681 vs. 0.315
# Precision = 0.636 vs. 0.187
# Recall = 0.732 vs. 0.991
# Minibatch Loss= 0.000547
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.136
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.335
# F1 = 1.000 vs. 0.502
# Precision = 1.000 vs. 0.335
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.069
# F1 = 0.631 vs. 0.098
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.192
# F1 = 0.678 vs. 0.312
# Precision = 0.651 vs. 0.186
# Recall = 0.707 vs. 0.983
# Minibatch Loss= 0.000572
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.341
# F1 = 1.000 vs. 0.488
# Precision = 1.000 vs. 0.327
# Recall = 1.000 vs. 0.969
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.069
# F1 = 0.631 vs. 0.103
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.196
# F1 = 0.676 vs. 0.312
# Precision = 0.650 vs. 0.185
# Recall = 0.704 vs. 0.997
# Minibatch Loss= 0.000574
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.128
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.317
# F1 = 1.000 vs. 0.475
# Precision = 1.000 vs. 0.311
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.071
# F1 = 0.634 vs. 0.102
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.192
# F1 = 0.679 vs. 0.315
# Precision = 0.655 vs. 0.189
# Recall = 0.704 vs. 0.952
# Minibatch Loss= 0.000461
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.111
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.268
# F1 = 1.000 vs. 0.412
# Precision = 1.000 vs. 0.260
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.067
# F1 = 0.632 vs. 0.095
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.185
# F1 = 0.680 vs. 0.315
# Precision = 0.661 vs. 0.188
# Recall = 0.701 vs. 0.972
# Minibatch Loss= 0.000402
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.346
# F1 = 1.000 vs. 0.495
# Precision = 1.000 vs. 0.329
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.068
# F1 = 0.633 vs. 0.095
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.182
# F1 = 0.680 vs. 0.313
# Precision = 0.662 vs. 0.189
# Recall = 0.698 vs. 0.923
# Minibatch Loss= 0.000493
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.117
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.305
# F1 = 1.000 vs. 0.481
# Precision = 1.000 vs. 0.317
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.067
# F1 = 0.633 vs. 0.098
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.193
# F1 = 0.679 vs. 0.312
# Precision = 0.654 vs. 0.185
# Recall = 0.707 vs. 0.994
# Minibatch Loss= 0.000401
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.320
# F1 = 1.000 vs. 0.485
# Precision = 1.000 vs. 0.322
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.073
# F1 = 0.630 vs. 0.107
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.183
# F1 = 0.682 vs. 0.312
# Precision = 0.660 vs. 0.185
# Recall = 0.707 vs. 0.997
# Minibatch Loss= 0.000381
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.376
# F1 = 1.000 vs. 0.549
# Precision = 1.000 vs. 0.378
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.070
# F1 = 0.629 vs. 0.098
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.186
# F1 = 0.682 vs. 0.313
# Precision = 0.662 vs. 0.186
# Recall = 0.704 vs. 0.991
# Minibatch Loss= 0.000409
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.282
# F1 = 1.000 vs. 0.434
# Precision = 1.000 vs. 0.277
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.070
# F1 = 0.630 vs. 0.103
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.727 vs. 0.178
# F1 = 0.682 vs. 0.314
# Precision = 0.662 vs. 0.190
# Recall = 0.704 vs. 0.915
# Minibatch Loss= 0.000288
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.359
# F1 = 1.000 vs. 0.508
# Precision = 1.000 vs. 0.342
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.070
# F1 = 0.629 vs. 0.106
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.202
# F1 = 0.680 vs. 0.323
# Precision = 0.661 vs. 0.206
# Recall = 0.701 vs. 0.744
# Minibatch Loss= 0.000320
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.323
# F1 = 1.000 vs. 0.464
# Precision = 1.000 vs. 0.302
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.069
# F1 = 0.627 vs. 0.096
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.725 vs. 0.173
# F1 = 0.680 vs. 0.313
# Precision = 0.661 vs. 0.186
# Recall = 0.701 vs. 0.991
# Minibatch Loss= 0.000288
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.117
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.319
# F1 = 1.000 vs. 0.483
# Precision = 1.000 vs. 0.318
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.070
# F1 = 0.629 vs. 0.104
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.186
# F1 = 0.682 vs. 0.312
# Precision = 0.654 vs. 0.185
# Recall = 0.712 vs. 0.997
# Minibatch Loss= 0.000270
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.127
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.350
# F1 = 1.000 vs. 0.535
# Precision = 1.000 vs. 0.365
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.069
# F1 = 0.628 vs. 0.097
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.199
# F1 = 0.682 vs. 0.316
# Precision = 0.654 vs. 0.189
# Recall = 0.712 vs. 0.946
# Minibatch Loss= 0.000341
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.127
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.347
# F1 = 1.000 vs. 0.530
# Precision = 1.000 vs. 0.361
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.069
# F1 = 0.629 vs. 0.099
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.200
# F1 = 0.683 vs. 0.312
# Precision = 0.656 vs. 0.186
# Recall = 0.712 vs. 0.954
# Minibatch Loss= 0.000270
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.129
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.311
# F1 = 1.000 vs. 0.481
# Precision = 1.000 vs. 0.317
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.075
# F1 = 0.630 vs. 0.115
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.726 vs. 0.194
# F1 = 0.680 vs. 0.315
# Precision = 0.659 vs. 0.190
# Recall = 0.704 vs. 0.917
# Minibatch Loss= 0.000220
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.117
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.319
# F1 = 1.000 vs. 0.498
# Precision = 1.000 vs. 0.332
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.068
# F1 = 0.627 vs. 0.095
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.723 vs. 0.178
# F1 = 0.681 vs. 0.313
# Precision = 0.655 vs. 0.185
# Recall = 0.709 vs. 0.997
# Minibatch Loss= 0.000242
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.310
# F1 = 1.000 vs. 0.461
# Precision = 1.000 vs. 0.300
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.069
# F1 = 0.628 vs. 0.098
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.724 vs. 0.199
# F1 = 0.682 vs. 0.316
# Precision = 0.657 vs. 0.188
# Recall = 0.709 vs. 0.983
# Minibatch Loss= 0.000196
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.114
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.284
# F1 = 1.000 vs. 0.432
# Precision = 1.000 vs. 0.276
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.075
# F1 = 0.628 vs. 0.112
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.724 vs. 0.181
# F1 = 0.682 vs. 0.314
# Precision = 0.657 vs. 0.186
# Recall = 0.709 vs. 0.991
# Minibatch Loss= 0.000164
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.128
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.354
# F1 = 1.000 vs. 0.528
# Precision = 1.000 vs. 0.359
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.074
# F1 = 0.628 vs. 0.108
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.725 vs. 0.195
# F1 = 0.681 vs. 0.311
# Precision = 0.655 vs. 0.184
# Recall = 0.709 vs. 1.000
# Minibatch Loss= 0.000233
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.266
# F1 = 1.000 vs. 0.420
# Precision = 1.000 vs. 0.266
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.067
# F1 = 0.627 vs. 0.093
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.722 vs. 0.195
# F1 = 0.680 vs. 0.313
# Precision = 0.654 vs. 0.186
# Recall = 0.709 vs. 1.000
# Minibatch Loss= 0.000135
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.073
# F1 = 1.000 vs. 0.109
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.242
# F1 = 1.000 vs. 0.409
# Precision = 1.000 vs. 0.257
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.070
# F1 = 0.628 vs. 0.098
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.724 vs. 0.187
# F1 = 0.681 vs. 0.313
# Precision = 0.655 vs. 0.186
# Recall = 0.709 vs. 0.991
# Minibatch Loss= 0.000132
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.114
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.306
# F1 = 1.000 vs. 0.469
# Precision = 1.000 vs. 0.307
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.072
# F1 = 0.629 vs. 0.108
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.724 vs. 0.185
# F1 = 0.681 vs. 0.312
# Precision = 0.653 vs. 0.185
# Recall = 0.712 vs. 0.983
# Minibatch Loss= 0.000151
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.304
# F1 = 1.000 vs. 0.461
# Precision = 1.000 vs. 0.301
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.069
# F1 = 0.629 vs. 0.102
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.723 vs. 0.180
# F1 = 0.685 vs. 0.312
# Precision = 0.655 vs. 0.186
# Recall = 0.718 vs. 0.966
# Minibatch Loss= 0.000127
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.274
# F1 = 1.000 vs. 0.432
# Precision = 1.000 vs. 0.276
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.069
# F1 = 0.628 vs. 0.100
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.724 vs. 0.175
# F1 = 0.683 vs. 0.312
# Precision = 0.651 vs. 0.185
# Recall = 0.718 vs. 0.997
# Minibatch Loss= 0.000109
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.263
# F1 = 1.000 vs. 0.427
# Precision = 1.000 vs. 0.272
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.070
# F1 = 0.628 vs. 0.107
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.722 vs. 0.186
# F1 = 0.683 vs. 0.311
# Precision = 0.651 vs. 0.184
# Recall = 0.718 vs. 1.000
# Minibatch Loss= 0.000110
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.346
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.331
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.067
# F1 = 0.627 vs. 0.098
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.724 vs. 0.195
# F1 = 0.681 vs. 0.313
# Precision = 0.648 vs. 0.186
# Recall = 0.718 vs. 0.989
# Minibatch Loss= 0.000127
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.901 vs. 0.082
# F1 = 0.855 vs. 0.128
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.856 vs. 0.335
# F1 = 0.777 vs. 0.494
# Precision = 0.729 vs. 0.328
# Recall = 0.831 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.069
# F1 = 0.618 vs. 0.100
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.587 vs. 0.181
# F1 = 0.593 vs. 0.312
# Precision = 0.597 vs. 0.185
# Recall = 0.590 vs. 1.000
# Minibatch Loss= 0.132955
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.080
# F1 = 0.973 vs. 0.116
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.965 vs. 0.334
# F1 = 0.914 vs. 0.481
# Precision = 0.903 vs. 0.317
# Recall = 0.925 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.632 vs. 0.069
# F1 = 0.656 vs. 0.100
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.697 vs. 0.198
# F1 = 0.682 vs. 0.314
# Precision = 0.640 vs. 0.187
# Recall = 0.729 vs. 0.974
# Minibatch Loss= 0.042330
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.080
# F1 = 0.987 vs. 0.120
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.979 vs. 0.332
# F1 = 0.945 vs. 0.493
# Precision = 0.931 vs. 0.327
# Recall = 0.960 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.069
# F1 = 0.662 vs. 0.098
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.719 vs. 0.186
# F1 = 0.697 vs. 0.312
# Precision = 0.675 vs. 0.186
# Recall = 0.721 vs. 0.949
# Minibatch Loss= 0.023414
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.075
# F1 = 0.996 vs. 0.112
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.297
# F1 = 0.966 vs. 0.454
# Precision = 0.952 vs. 0.295
# Recall = 0.981 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.069
# F1 = 0.666 vs. 0.095
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.728 vs. 0.182
# F1 = 0.689 vs. 0.312
# Precision = 0.613 vs. 0.185
# Recall = 0.786 vs. 0.980
# Minibatch Loss= 0.014920
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 0.997 vs. 0.129
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.333
# F1 = 0.988 vs. 0.497
# Precision = 0.990 vs. 0.331
# Recall = 0.985 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.071
# F1 = 0.667 vs. 0.105
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.193
# F1 = 0.695 vs. 0.312
# Precision = 0.689 vs. 0.185
# Recall = 0.701 vs. 0.994
# Minibatch Loss= 0.010412
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.080
# F1 = 0.997 vs. 0.126
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.324
# F1 = 0.992 vs. 0.488
# Precision = 0.987 vs. 0.323
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.071
# F1 = 0.668 vs. 0.104
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.183
# F1 = 0.701 vs. 0.312
# Precision = 0.691 vs. 0.185
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.008588
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.117
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.328
# F1 = 0.999 vs. 0.495
# Precision = 0.998 vs. 0.329
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.069
# F1 = 0.667 vs. 0.097
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.182
# F1 = 0.701 vs. 0.312
# Precision = 0.695 vs. 0.185
# Recall = 0.707 vs. 1.000
# Minibatch Loss= 0.005958
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.123
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.324
# F1 = 1.000 vs. 0.474
# Precision = 1.000 vs. 0.314
# Recall = 1.000 vs. 0.963
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.073
# F1 = 0.664 vs. 0.108
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.187
# F1 = 0.702 vs. 0.311
# Precision = 0.651 vs. 0.184
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.005099
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.119
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.301
# F1 = 1.000 vs. 0.462
# Precision = 1.000 vs. 0.300
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.068
# F1 = 0.663 vs. 0.099
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.194
# F1 = 0.705 vs. 0.319
# Precision = 0.653 vs. 0.192
# Recall = 0.766 vs. 0.934
# Minibatch Loss= 0.004378
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.121
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.284
# F1 = 1.000 vs. 0.425
# Precision = 1.000 vs. 0.270
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.069
# F1 = 0.664 vs. 0.098
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.176
# F1 = 0.703 vs. 0.313
# Precision = 0.694 vs. 0.185
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.003118
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.303
# F1 = 1.000 vs. 0.470
# Precision = 1.000 vs. 0.307
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.636 vs. 0.068
# F1 = 0.666 vs. 0.097
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.172
# F1 = 0.704 vs. 0.312
# Precision = 0.678 vs. 0.185
# Recall = 0.732 vs. 0.997
# Minibatch Loss= 0.003146
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.345
# F1 = 1.000 vs. 0.523
# Precision = 1.000 vs. 0.354
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.070
# F1 = 0.666 vs. 0.105
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.168
# F1 = 0.706 vs. 0.311
# Precision = 0.703 vs. 0.184
# Recall = 0.709 vs. 1.000
# Minibatch Loss= 0.002637
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.295
# F1 = 1.000 vs. 0.455
# Precision = 1.000 vs. 0.295
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.636 vs. 0.075
# F1 = 0.665 vs. 0.112
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.190
# F1 = 0.704 vs. 0.312
# Precision = 0.678 vs. 0.185
# Recall = 0.732 vs. 0.991
# Minibatch Loss= 0.002301
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.308
# F1 = 1.000 vs. 0.463
# Precision = 1.000 vs. 0.302
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.072
# F1 = 0.663 vs. 0.109
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.190
# F1 = 0.702 vs. 0.311
# Precision = 0.675 vs. 0.184
# Recall = 0.732 vs. 1.000
# Minibatch Loss= 0.001993
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.112
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.290
# F1 = 1.000 vs. 0.443
# Precision = 1.000 vs. 0.285
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.635 vs. 0.071
# F1 = 0.663 vs. 0.108
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.181
# F1 = 0.706 vs. 0.311
# Precision = 0.729 vs. 0.184
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.001560
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.286
# F1 = 1.000 vs. 0.460
# Precision = 1.000 vs. 0.299
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.067
# F1 = 0.662 vs. 0.094
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.193
# F1 = 0.708 vs. 0.313
# Precision = 0.730 vs. 0.187
# Recall = 0.687 vs. 0.954
# Minibatch Loss= 0.001355
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.111
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.296
# F1 = 1.000 vs. 0.430
# Precision = 1.000 vs. 0.284
# Recall = 1.000 vs. 0.887
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.068
# F1 = 0.662 vs. 0.102
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.180
# F1 = 0.708 vs. 0.313
# Precision = 0.725 vs. 0.187
# Recall = 0.692 vs. 0.972
# Minibatch Loss= 0.000986
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.331
# F1 = 1.000 vs. 0.486
# Precision = 1.000 vs. 0.322
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.632 vs. 0.069
# F1 = 0.660 vs. 0.101
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.177
# F1 = 0.706 vs. 0.316
# Precision = 0.722 vs. 0.191
# Recall = 0.689 vs. 0.917
# Minibatch Loss= 0.001234
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.298
# F1 = 1.000 vs. 0.455
# Precision = 1.000 vs. 0.295
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.071
# F1 = 0.663 vs. 0.101
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.733 vs. 0.190
# F1 = 0.706 vs. 0.313
# Precision = 0.722 vs. 0.187
# Recall = 0.689 vs. 0.974
# Minibatch Loss= 0.001089
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.121
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.332
# F1 = 1.000 vs. 0.503
# Precision = 1.000 vs. 0.336
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.068
# F1 = 0.663 vs. 0.094
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.631 vs. 0.186
# Recall = 0.775 vs. 0.991
# Minibatch Loss= 0.000358
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.128
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.336
# F1 = 1.000 vs. 0.514
# Precision = 1.000 vs. 0.347
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.681 vs. 0.068
# F1 = 0.687 vs. 0.097
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.709 vs. 0.173
# F1 = 0.697 vs. 0.312
# Precision = 0.632 vs. 0.185
# Recall = 0.778 vs. 1.000
# Minibatch Loss= 0.000420
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.277
# F1 = 1.000 vs. 0.442
# Precision = 1.000 vs. 0.284
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.069
# F1 = 0.687 vs. 0.101
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.707 vs. 0.185
# F1 = 0.698 vs. 0.312
# Precision = 0.638 vs. 0.185
# Recall = 0.772 vs. 0.991
# Minibatch Loss= 0.000354
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.128
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.367
# F1 = 1.000 vs. 0.514
# Precision = 1.000 vs. 0.348
# Recall = 1.000 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.069
# F1 = 0.686 vs. 0.102
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.177
# F1 = 0.697 vs. 0.313
# Precision = 0.632 vs. 0.186
# Recall = 0.778 vs. 0.991
# Minibatch Loss= 0.000331
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.306
# F1 = 1.000 vs. 0.456
# Precision = 1.000 vs. 0.296
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.070
# F1 = 0.686 vs. 0.102
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.197
# F1 = 0.698 vs. 0.316
# Precision = 0.643 vs. 0.194
# Recall = 0.764 vs. 0.840
# Minibatch Loss= 0.000272
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.113
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.310
# F1 = 1.000 vs. 0.466
# Precision = 1.000 vs. 0.304
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.069
# F1 = 0.689 vs. 0.097
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.184
# F1 = 0.697 vs. 0.312
# Precision = 0.646 vs. 0.185
# Recall = 0.758 vs. 0.997
# Minibatch Loss= 0.000258
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.372
# F1 = 1.000 vs. 0.534
# Precision = 1.000 vs. 0.364
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.681 vs. 0.068
# F1 = 0.690 vs. 0.100
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.714 vs. 0.182
# F1 = 0.701 vs. 0.313
# Precision = 0.650 vs. 0.186
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.000328
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.330
# F1 = 1.000 vs. 0.483
# Precision = 1.000 vs. 0.319
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.067
# F1 = 0.688 vs. 0.100
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.710 vs. 0.188
# F1 = 0.700 vs. 0.312
# Precision = 0.646 vs. 0.189
# Recall = 0.764 vs. 0.906
# Minibatch Loss= 0.000223
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.349
# F1 = 1.000 vs. 0.498
# Precision = 1.000 vs. 0.340
# Recall = 1.000 vs. 0.930
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.070
# F1 = 0.689 vs. 0.101
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.712 vs. 0.178
# F1 = 0.702 vs. 0.312
# Precision = 0.646 vs. 0.185
# Recall = 0.769 vs. 1.000
# Minibatch Loss= 0.000262
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.341
# F1 = 1.000 vs. 0.510
# Precision = 1.000 vs. 0.343
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.068
# F1 = 0.688 vs. 0.101
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.185
# F1 = 0.702 vs. 0.312
# Precision = 0.646 vs. 0.185
# Recall = 0.769 vs. 1.000
# Minibatch Loss= 0.000211
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.113
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.268
# F1 = 1.000 vs. 0.429
# Precision = 1.000 vs. 0.273
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.068
# F1 = 0.688 vs. 0.096
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.710 vs. 0.172
# F1 = 0.703 vs. 0.313
# Precision = 0.645 vs. 0.186
# Recall = 0.772 vs. 0.986
# Minibatch Loss= 0.000187
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.135
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.304
# F1 = 1.000 vs. 0.474
# Precision = 1.000 vs. 0.310
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.676 vs. 0.068
# F1 = 0.687 vs. 0.103
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.710 vs. 0.188
# F1 = 0.702 vs. 0.319
# Precision = 0.648 vs. 0.193
# Recall = 0.766 vs. 0.926
# Minibatch Loss= 0.000189
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.331
# F1 = 1.000 vs. 0.485
# Precision = 1.000 vs. 0.320
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.677 vs. 0.075
# F1 = 0.686 vs. 0.110
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.712 vs. 0.195
# F1 = 0.703 vs. 0.315
# Precision = 0.647 vs. 0.194
# Recall = 0.769 vs. 0.849
# Minibatch Loss= 0.000174
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.358
# F1 = 1.000 vs. 0.515
# Precision = 1.000 vs. 0.347
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.676 vs. 0.068
# F1 = 0.686 vs. 0.097
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.193
# F1 = 0.703 vs. 0.311
# Precision = 0.647 vs. 0.184
# Recall = 0.769 vs. 1.000
# Minibatch Loss= 0.000199
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.113
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.265
# F1 = 1.000 vs. 0.405
# Precision = 1.000 vs. 0.255
# Recall = 1.000 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.676 vs. 0.072
# F1 = 0.687 vs. 0.106
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.186
# F1 = 0.704 vs. 0.312
# Precision = 0.620 vs. 0.185
# Recall = 0.815 vs. 1.000
# Minibatch Loss= 0.000131
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.119
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.317
# F1 = 1.000 vs. 0.472
# Precision = 1.000 vs. 0.313
# Recall = 1.000 vs. 0.961
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.069
# F1 = 0.683 vs. 0.101
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.184
# F1 = 0.706 vs. 0.312
# Precision = 0.621 vs. 0.185
# Recall = 0.818 vs. 1.000
# Minibatch Loss= 0.000144
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.313
# F1 = 1.000 vs. 0.508
# Precision = 1.000 vs. 0.340
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.069
# F1 = 0.684 vs. 0.098
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.706 vs. 0.182
# F1 = 0.707 vs. 0.316
# Precision = 0.624 vs. 0.189
# Recall = 0.815 vs. 0.972
# Minibatch Loss= 0.000153
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.316
# F1 = 1.000 vs. 0.485
# Precision = 1.000 vs. 0.320
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.071
# F1 = 0.684 vs. 0.097
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.176
# F1 = 0.709 vs. 0.312
# Precision = 0.627 vs. 0.185
# Recall = 0.815 vs. 0.997
# Minibatch Loss= 0.000129
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.125
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 1.000 vs. 0.491
# Precision = 1.000 vs. 0.326
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.071
# F1 = 0.682 vs. 0.101
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.709 vs. 0.181
# F1 = 0.708 vs. 0.312
# Precision = 0.626 vs. 0.185
# Recall = 0.815 vs. 1.000
# Minibatch Loss= 0.000138
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.262
# F1 = 1.000 vs. 0.439
# Precision = 1.000 vs. 0.286
# Recall = 1.000 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.072
# F1 = 0.683 vs. 0.105
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.709 vs. 0.190
# F1 = 0.708 vs. 0.313
# Precision = 0.626 vs. 0.190
# Recall = 0.815 vs. 0.892
# Minibatch Loss= 0.000109
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.334
# F1 = 1.000 vs. 0.504
# Precision = 1.000 vs. 0.337
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.069
# F1 = 0.682 vs. 0.096
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.708 vs. 0.197
# F1 = 0.709 vs. 0.314
# Precision = 0.625 vs. 0.187
# Recall = 0.821 vs. 0.972
# Minibatch Loss= 0.000139
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.111
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.324
# F1 = 1.000 vs. 0.471
# Precision = 1.000 vs. 0.308
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.067
# F1 = 0.681 vs. 0.098
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.709 vs. 0.201
# F1 = 0.709 vs. 0.313
# Precision = 0.635 vs. 0.186
# Recall = 0.803 vs. 0.991
# Minibatch Loss= 0.000111
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 1.000 vs. 0.476
# Precision = 1.000 vs. 0.313
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.068
# F1 = 0.681 vs. 0.100
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.707 vs. 0.192
# F1 = 0.709 vs. 0.317
# Precision = 0.636 vs. 0.192
# Recall = 0.801 vs. 0.912
# Minibatch Loss= 0.000102
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.287
# F1 = 1.000 vs. 0.438
# Precision = 1.000 vs. 0.284
# Recall = 1.000 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.067
# F1 = 0.681 vs. 0.094
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.707 vs. 0.198
# F1 = 0.708 vs. 0.312
# Precision = 0.632 vs. 0.185
# Recall = 0.803 vs. 1.000
# Minibatch Loss= 0.000079
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.329
# F1 = 1.000 vs. 0.474
# Precision = 1.000 vs. 0.311
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.069
# F1 = 0.679 vs. 0.099
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.189
# F1 = 0.708 vs. 0.313
# Precision = 0.632 vs. 0.186
# Recall = 0.806 vs. 0.994
# Minibatch Loss= 0.000100
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.115
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 1.000 vs. 0.481
# Precision = 1.000 vs. 0.317
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.069
# F1 = 0.681 vs. 0.106
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.701 vs. 0.178
# F1 = 0.708 vs. 0.312
# Precision = 0.630 vs. 0.185
# Recall = 0.809 vs. 1.000
# Minibatch Loss= 0.000077
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.305
# F1 = 1.000 vs. 0.480
# Precision = 1.000 vs. 0.316
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.070
# F1 = 0.680 vs. 0.107
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.707 vs. 0.200
# F1 = 0.708 vs. 0.313
# Precision = 0.630 vs. 0.189
# Recall = 0.806 vs. 0.915
# Minibatch Loss= 0.000073
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.117
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.320
# F1 = 1.000 vs. 0.487
# Precision = 1.000 vs. 0.322
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.072
# F1 = 0.679 vs. 0.114
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.708 vs. 0.190
# F1 = 0.707 vs. 0.318
# Precision = 0.626 vs. 0.193
# Recall = 0.812 vs. 0.915
# Minibatch Loss= 0.000076
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.129
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.349
# F1 = 1.000 vs. 0.512
# Precision = 1.000 vs. 0.346
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.070
# F1 = 0.678 vs. 0.103
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.704 vs. 0.192
# F1 = 0.708 vs. 0.313
# Precision = 0.628 vs. 0.187
# Recall = 0.812 vs. 0.954
# Minibatch Loss= 0.000078
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.127
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.350
# F1 = 1.000 vs. 0.517
# Precision = 1.000 vs. 0.349
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.072
# F1 = 0.680 vs. 0.106
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.703 vs. 0.202
# F1 = 0.709 vs. 0.312
# Precision = 0.645 vs. 0.185
# Recall = 0.786 vs. 1.000
# Minibatch Loss= 0.000074
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.316
# F1 = 1.000 vs. 0.482
# Precision = 1.000 vs. 0.318
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.070
# F1 = 0.677 vs. 0.100
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.185
# F1 = 0.708 vs. 0.312
# Precision = 0.643 vs. 0.185
# Recall = 0.786 vs. 1.000
# Minibatch Loss= 0.000068
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.126
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.323
# F1 = 1.000 vs. 0.506
# Precision = 1.000 vs. 0.340
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.070
# F1 = 0.677 vs. 0.102
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.703 vs. 0.178
# F1 = 0.706 vs. 0.317
# Precision = 0.638 vs. 0.189
# Recall = 0.792 vs. 0.983
# Minibatch Loss= 0.000059
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.317
# F1 = 1.000 vs. 0.484
# Precision = 1.000 vs. 0.320
# Recall = 1.000 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.071
# F1 = 0.677 vs. 0.109
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.699 vs. 0.181
# F1 = 0.705 vs. 0.320
# Precision = 0.637 vs. 0.196
# Recall = 0.789 vs. 0.886
# Minibatch Loss= 0.000057
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.117
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.290
# F1 = 1.000 vs. 0.433
# Precision = 1.000 vs. 0.277
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.068
# F1 = 0.676 vs. 0.101
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.707 vs. 0.183
# F1 = 0.706 vs. 0.312
# Precision = 0.638 vs. 0.186
# Recall = 0.789 vs. 0.980
# Minibatch Loss= 0.000058
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.132
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.297
# F1 = 1.000 vs. 0.478
# Precision = 1.000 vs. 0.316
# Recall = 1.000 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.070
# F1 = 0.676 vs. 0.105
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.688 vs. 0.183
# F1 = 0.707 vs. 0.311
# Precision = 0.640 vs. 0.184
# Recall = 0.789 vs. 1.000
# Minibatch Loss= 0.000050
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/RCNN_Wmultitask_64_opp/RCNN_Wmultitask_64_opp-20000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.070
# F1 = 0.676 vs. 0.098
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.707 vs. 0.192
# F1 = 0.706 vs. 0.312
# Precision = 0.643 vs. 0.185
# Recall = 0.783 vs. 1.000

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
