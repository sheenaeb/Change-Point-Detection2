# %%
# useing this variable for saving models and summaries
exp_name = "WCNNRNN_Wmultitask_16_opp_2Adam"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.WCNNRNN_model_2 as WCNNRNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 7    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = WCNNRNN_model.Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)
# Out:
# Tensor("Squeeze_24:0", shape=(?, ?, 19), dtype=float32) Tensor("Reshape_8:0", shape=(?, ?, 19), dtype=float32)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.060
# F1 = 0.097 vs. 0.089
# Accuracy = 0.021 vs. 0.056
# CHANGE DETECTION
# AUC = 0.092 vs. 0.085
# F1 = 0.176 vs. 0.153
# Precision = 0.099 vs. 0.083
# Recall = 0.810 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.059
# F1 = 0.082 vs. 0.078
# Accuracy = 0.005 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.046
# F1 = 0.132 vs. 0.096
# Precision = 0.073 vs. 0.051
# Recall = 0.657 vs. 1.000
# Minibatch Loss= 1.271739
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.732 vs. 0.061
# F1 = 0.709 vs. 0.089
# Accuracy = 0.744 vs. 0.056
# CHANGE DETECTION
# AUC = 0.243 vs. 0.094
# F1 = 0.353 vs. 0.166
# Precision = 0.245 vs. 0.091
# Recall = 0.630 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.447 vs. 0.059
# F1 = 0.503 vs. 0.082
# Accuracy = 0.791 vs. 0.056
# CHANGE DETECTION
# AUC = 0.194 vs. 0.050
# F1 = 0.272 vs. 0.100
# Precision = 0.178 vs. 0.054
# Recall = 0.584 vs. 0.712
# Minibatch Loss= 0.243927
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.913 vs. 0.061
# F1 = 0.859 vs. 0.093
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.092
# F1 = 0.388 vs. 0.175
# Precision = 0.248 vs. 0.096
# Recall = 0.881 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.489 vs. 0.059
# F1 = 0.529 vs. 0.082
# Accuracy = 0.826 vs. 0.056
# CHANGE DETECTION
# AUC = 0.200 vs. 0.051
# F1 = 0.292 vs. 0.097
# Precision = 0.191 vs. 0.052
# Recall = 0.613 vs. 0.756
# Minibatch Loss= 0.148336
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.949 vs. 0.062
# F1 = 0.906 vs. 0.093
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.103
# F1 = 0.474 vs. 0.191
# Precision = 0.340 vs. 0.106
# Recall = 0.783 vs. 0.936
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.499 vs. 0.059
# F1 = 0.534 vs. 0.083
# Accuracy = 0.819 vs. 0.056
# CHANGE DETECTION
# AUC = 0.197 vs. 0.053
# F1 = 0.291 vs. 0.098
# Precision = 0.187 vs. 0.052
# Recall = 0.652 vs. 0.748
# Minibatch Loss= 0.110112
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.937 vs. 0.061
# F1 = 0.889 vs. 0.089
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.359 vs. 0.091
# F1 = 0.434 vs. 0.168
# Precision = 0.305 vs. 0.092
# Recall = 0.749 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.059
# F1 = 0.568 vs. 0.077
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.197 vs. 0.050
# F1 = 0.298 vs. 0.096
# Precision = 0.201 vs. 0.051
# Recall = 0.574 vs. 0.956
# Minibatch Loss= 0.107799
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.062
# F1 = 0.959 vs. 0.091
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.493 vs. 0.099
# F1 = 0.550 vs. 0.180
# Precision = 0.431 vs. 0.099
# Recall = 0.759 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.534 vs. 0.060
# F1 = 0.588 vs. 0.080
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.208 vs. 0.049
# F1 = 0.316 vs. 0.096
# Precision = 0.230 vs. 0.051
# Recall = 0.506 vs. 1.000
# Minibatch Loss= 0.073500
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.063
# F1 = 0.959 vs. 0.095
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.588 vs. 0.107
# F1 = 0.596 vs. 0.199
# Precision = 0.489 vs. 0.111
# Recall = 0.763 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.531 vs. 0.058
# F1 = 0.583 vs. 0.076
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.220 vs. 0.050
# F1 = 0.326 vs. 0.099
# Precision = 0.247 vs. 0.052
# Recall = 0.478 vs. 0.951
# Minibatch Loss= 0.074383
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.061
# F1 = 0.981 vs. 0.091
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.091
# F1 = 0.694 vs. 0.165
# Precision = 0.615 vs. 0.091
# Recall = 0.796 vs. 0.847
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.059
# F1 = 0.602 vs. 0.079
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.247 vs. 0.049
# F1 = 0.356 vs. 0.097
# Precision = 0.256 vs. 0.051
# Recall = 0.582 vs. 0.888
# Minibatch Loss= 0.044919
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.989 vs. 0.089
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.719 vs. 0.085
# F1 = 0.729 vs. 0.145
# Precision = 0.650 vs. 0.082
# Recall = 0.830 vs. 0.605
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.543 vs. 0.059
# F1 = 0.595 vs. 0.080
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.254 vs. 0.052
# F1 = 0.357 vs. 0.099
# Precision = 0.277 vs. 0.053
# Recall = 0.501 vs. 0.761
# Minibatch Loss= 0.034564
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.990 vs. 0.088
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.791 vs. 0.096
# F1 = 0.778 vs. 0.164
# Precision = 0.721 vs. 0.090
# Recall = 0.845 vs. 0.931
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.058
# F1 = 0.592 vs. 0.079
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.048
# F1 = 0.359 vs. 0.097
# Precision = 0.294 vs. 0.051
# Recall = 0.460 vs. 0.953
# Minibatch Loss= 0.034906
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.990 vs. 0.091
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.823 vs. 0.080
# F1 = 0.797 vs. 0.146
# Precision = 0.709 vs. 0.079
# Recall = 0.910 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.538 vs. 0.059
# F1 = 0.591 vs. 0.085
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.051
# F1 = 0.362 vs. 0.100
# Precision = 0.284 vs. 0.055
# Recall = 0.499 vs. 0.561
# Minibatch Loss= 0.027975
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.994 vs. 0.092
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.852 vs. 0.084
# F1 = 0.845 vs. 0.162
# Precision = 0.779 vs. 0.089
# Recall = 0.924 vs. 0.897
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.527 vs. 0.059
# F1 = 0.583 vs. 0.080
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.049
# F1 = 0.367 vs. 0.097
# Precision = 0.293 vs. 0.053
# Recall = 0.491 vs. 0.618
# Minibatch Loss= 0.026024
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.060
# F1 = 0.574 vs. 0.087
# Accuracy = 0.639 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.079
# F1 = 0.345 vs. 0.149
# Precision = 0.288 vs. 0.080
# Recall = 0.432 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.317 vs. 0.058
# F1 = 0.378 vs. 0.078
# Accuracy = 0.567 vs. 0.056
# CHANGE DETECTION
# AUC = 0.178 vs. 0.050
# F1 = 0.247 vs. 0.098
# Precision = 0.191 vs. 0.052
# Recall = 0.348 vs. 0.803
# Minibatch Loss= 0.427062
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.954 vs. 0.062
# F1 = 0.910 vs. 0.092
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.656 vs. 0.091
# F1 = 0.627 vs. 0.163
# Precision = 0.589 vs. 0.093
# Recall = 0.669 vs. 0.669
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.058
# F1 = 0.627 vs. 0.080
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.277 vs. 0.057
# F1 = 0.352 vs. 0.099
# Precision = 0.264 vs. 0.052
# Recall = 0.530 vs. 0.971
# Minibatch Loss= 0.076837
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.060
# F1 = 0.967 vs. 0.090
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.749 vs. 0.086
# F1 = 0.715 vs. 0.164
# Precision = 0.624 vs. 0.090
# Recall = 0.835 vs. 0.945
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.059
# F1 = 0.623 vs. 0.079
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.049
# F1 = 0.380 vs. 0.097
# Precision = 0.278 vs. 0.051
# Recall = 0.600 vs. 0.995
# Minibatch Loss= 0.043655
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.060
# F1 = 0.982 vs. 0.089
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.803 vs. 0.087
# F1 = 0.795 vs. 0.155
# Precision = 0.744 vs. 0.084
# Recall = 0.855 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.059
# F1 = 0.619 vs. 0.081
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.052
# F1 = 0.376 vs. 0.100
# Precision = 0.270 vs. 0.053
# Recall = 0.621 vs. 0.886
# Minibatch Loss= 0.032001
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.988 vs. 0.087
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.869 vs. 0.094
# F1 = 0.833 vs. 0.169
# Precision = 0.751 vs. 0.093
# Recall = 0.935 vs. 0.960
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.059
# F1 = 0.611 vs. 0.082
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.053
# F1 = 0.364 vs. 0.099
# Precision = 0.274 vs. 0.054
# Recall = 0.540 vs. 0.675
# Minibatch Loss= 0.028146
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.993 vs. 0.087
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.887 vs. 0.093
# F1 = 0.877 vs. 0.161
# Precision = 0.806 vs. 0.090
# Recall = 0.962 vs. 0.796
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.059
# F1 = 0.605 vs. 0.081
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.049
# F1 = 0.368 vs. 0.097
# Precision = 0.307 vs. 0.051
# Recall = 0.460 vs. 0.979
# Minibatch Loss= 0.022093
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.960 vs. 0.062
# F1 = 0.912 vs. 0.092
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.678 vs. 0.091
# F1 = 0.680 vs. 0.169
# Precision = 0.583 vs. 0.092
# Recall = 0.815 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.058
# F1 = 0.611 vs. 0.079
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.054
# F1 = 0.367 vs. 0.097
# Precision = 0.279 vs. 0.051
# Recall = 0.538 vs. 0.894
# Minibatch Loss= 0.080392
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.064
# F1 = 0.981 vs. 0.097
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.873 vs. 0.110
# F1 = 0.830 vs. 0.205
# Precision = 0.767 vs. 0.115
# Recall = 0.903 vs. 0.964
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.059
# F1 = 0.619 vs. 0.081
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.052
# F1 = 0.400 vs. 0.102
# Precision = 0.300 vs. 0.054
# Recall = 0.600 vs. 0.932
# Minibatch Loss= 0.033309
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.991 vs. 0.093
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.944 vs. 0.098
# F1 = 0.905 vs. 0.184
# Precision = 0.858 vs. 0.105
# Recall = 0.958 vs. 0.774
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.059
# F1 = 0.608 vs. 0.081
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.055
# F1 = 0.390 vs. 0.099
# Precision = 0.295 vs. 0.056
# Recall = 0.574 vs. 0.434
# Minibatch Loss= 0.020473
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.091
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.953 vs. 0.094
# F1 = 0.931 vs. 0.165
# Precision = 0.911 vs. 0.090
# Recall = 0.953 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.059
# F1 = 0.608 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.052
# F1 = 0.384 vs. 0.099
# Precision = 0.285 vs. 0.056
# Recall = 0.587 vs. 0.429
# Minibatch Loss= 0.015557
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.997 vs. 0.090
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.954 vs. 0.097
# F1 = 0.942 vs. 0.177
# Precision = 0.915 vs. 0.097
# Recall = 0.971 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.059
# F1 = 0.615 vs. 0.083
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.054
# F1 = 0.391 vs. 0.100
# Precision = 0.295 vs. 0.057
# Recall = 0.579 vs. 0.397
# Minibatch Loss= 0.015060
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.088
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.965 vs. 0.074
# F1 = 0.944 vs. 0.141
# Precision = 0.920 vs. 0.076
# Recall = 0.969 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.059
# F1 = 0.610 vs. 0.080
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.052
# F1 = 0.391 vs. 0.097
# Precision = 0.325 vs. 0.052
# Recall = 0.491 vs. 0.758
# Minibatch Loss= 0.012545
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.998 vs. 0.093
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.099
# F1 = 0.979 vs. 0.183
# Precision = 0.970 vs. 0.103
# Recall = 0.990 vs. 0.817
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.059
# F1 = 0.612 vs. 0.079
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.051
# F1 = 0.382 vs. 0.096
# Precision = 0.306 vs. 0.051
# Recall = 0.509 vs. 0.990
# Minibatch Loss= 0.010620
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.090
# F1 = 0.986 vs. 0.166
# Precision = 0.985 vs. 0.091
# Recall = 0.988 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.059
# F1 = 0.608 vs. 0.079
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.060
# F1 = 0.385 vs. 0.103
# Precision = 0.287 vs. 0.056
# Recall = 0.584 vs. 0.621
# Minibatch Loss= 0.007637
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.999 vs. 0.095
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.091
# F1 = 0.987 vs. 0.172
# Precision = 0.977 vs. 0.094
# Recall = 0.997 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.059
# F1 = 0.608 vs. 0.081
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.049
# F1 = 0.390 vs. 0.098
# Precision = 0.304 vs. 0.052
# Recall = 0.545 vs. 0.956
# Minibatch Loss= 0.007134
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.080
# F1 = 0.994 vs. 0.145
# Precision = 0.988 vs. 0.078
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.060
# F1 = 0.605 vs. 0.083
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.059
# F1 = 0.391 vs. 0.107
# Precision = 0.298 vs. 0.060
# Recall = 0.566 vs. 0.462
# Minibatch Loss= 0.005427
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.088
# F1 = 0.991 vs. 0.167
# Precision = 0.985 vs. 0.091
# Recall = 0.998 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.058
# F1 = 0.606 vs. 0.078
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.052
# F1 = 0.386 vs. 0.098
# Precision = 0.299 vs. 0.052
# Recall = 0.545 vs. 0.930
# Minibatch Loss= 0.006205
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.083
# F1 = 0.996 vs. 0.152
# Precision = 0.992 vs. 0.082
# Recall = 1.000 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.059
# F1 = 0.605 vs. 0.080
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.052
# F1 = 0.379 vs. 0.098
# Precision = 0.285 vs. 0.052
# Recall = 0.566 vs. 0.891
# Minibatch Loss= 0.004709
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 0.998 vs. 0.180
# Precision = 0.995 vs. 0.099
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.059
# F1 = 0.605 vs. 0.082
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.053
# F1 = 0.377 vs. 0.098
# Precision = 0.278 vs. 0.055
# Recall = 0.590 vs. 0.483
# Minibatch Loss= 0.004574
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.904 vs. 0.062
# F1 = 0.852 vs. 0.094
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.593 vs. 0.097
# F1 = 0.597 vs. 0.175
# Precision = 0.532 vs. 0.096
# Recall = 0.679 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.554 vs. 0.059
# F1 = 0.586 vs. 0.081
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.250 vs. 0.057
# F1 = 0.316 vs. 0.105
# Precision = 0.226 vs. 0.059
# Recall = 0.525 vs. 0.496
# Minibatch Loss= 0.124265
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.943 vs. 0.062
# F1 = 0.904 vs. 0.095
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.098
# F1 = 0.656 vs. 0.173
# Precision = 0.586 vs. 0.095
# Recall = 0.745 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.058
# F1 = 0.640 vs. 0.079
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.058
# F1 = 0.328 vs. 0.103
# Precision = 0.263 vs. 0.056
# Recall = 0.434 vs. 0.590
# Minibatch Loss= 0.090657
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.981 vs. 0.088
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.925 vs. 0.090
# F1 = 0.895 vs. 0.156
# Precision = 0.846 vs. 0.085
# Recall = 0.950 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.058
# F1 = 0.651 vs. 0.078
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.340 vs. 0.051
# F1 = 0.401 vs. 0.101
# Precision = 0.347 vs. 0.058
# Recall = 0.475 vs. 0.416
# Minibatch Loss= 0.020698
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.990 vs. 0.092
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.088
# F1 = 0.938 vs. 0.169
# Precision = 0.908 vs. 0.092
# Recall = 0.969 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.638 vs. 0.059
# F1 = 0.646 vs. 0.084
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.049
# F1 = 0.403 vs. 0.097
# Precision = 0.336 vs. 0.051
# Recall = 0.501 vs. 0.971
# Minibatch Loss= 0.017387
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.090
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.980 vs. 0.097
# F1 = 0.964 vs. 0.174
# Precision = 0.942 vs. 0.096
# Recall = 0.987 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.058
# F1 = 0.642 vs. 0.078
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.347 vs. 0.054
# F1 = 0.413 vs. 0.099
# Precision = 0.326 vs. 0.052
# Recall = 0.561 vs. 0.855
# Minibatch Loss= 0.012538
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.996 vs. 0.090
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.097
# F1 = 0.975 vs. 0.172
# Precision = 0.957 vs. 0.097
# Recall = 0.993 vs. 0.739
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.059
# F1 = 0.637 vs. 0.079
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.350 vs. 0.046
# F1 = 0.417 vs. 0.097
# Precision = 0.350 vs. 0.051
# Recall = 0.517 vs. 0.971
# Minibatch Loss= 0.009766
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.085
# F1 = 0.991 vs. 0.161
# Precision = 0.982 vs. 0.088
# Recall = 1.000 vs. 0.935
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.059
# F1 = 0.635 vs. 0.083
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.349 vs. 0.057
# F1 = 0.412 vs. 0.097
# Precision = 0.355 vs. 0.051
# Recall = 0.491 vs. 0.990
# Minibatch Loss= 0.007354
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.997 vs. 0.088
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.087
# F1 = 0.962 vs. 0.159
# Precision = 0.962 vs. 0.087
# Recall = 0.962 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.613 vs. 0.058
# F1 = 0.628 vs. 0.076
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.048
# F1 = 0.398 vs. 0.096
# Precision = 0.322 vs. 0.051
# Recall = 0.522 vs. 1.000
# Minibatch Loss= 0.009765
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.087
# F1 = 0.994 vs. 0.161
# Precision = 0.988 vs. 0.088
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.058
# F1 = 0.632 vs. 0.079
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.343 vs. 0.051
# F1 = 0.413 vs. 0.097
# Precision = 0.364 vs. 0.051
# Recall = 0.478 vs. 0.987
# Minibatch Loss= 0.005795
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 0.999 vs. 0.180
# Precision = 0.998 vs. 0.100
# Recall = 1.000 vs. 0.877
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.059
# F1 = 0.630 vs. 0.079
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.052
# F1 = 0.409 vs. 0.096
# Precision = 0.341 vs. 0.051
# Recall = 0.509 vs. 0.990
# Minibatch Loss= 0.004864
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 0.999 vs. 0.147
# Precision = 0.998 vs. 0.080
# Recall = 1.000 vs. 0.933
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.058
# F1 = 0.629 vs. 0.080
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.340 vs. 0.050
# F1 = 0.410 vs. 0.097
# Precision = 0.349 vs. 0.051
# Recall = 0.496 vs. 0.997
# Minibatch Loss= 0.002980
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.087
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.138
# Precision = 1.000 vs. 0.075
# Recall = 1.000 vs. 0.909
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.058
# F1 = 0.628 vs. 0.078
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.339 vs. 0.052
# F1 = 0.406 vs. 0.100
# Precision = 0.347 vs. 0.054
# Recall = 0.488 vs. 0.719
# Minibatch Loss= 0.002981
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.177
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.870
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.058
# F1 = 0.632 vs. 0.080
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.339 vs. 0.051
# F1 = 0.407 vs. 0.097
# Precision = 0.347 vs. 0.051
# Recall = 0.491 vs. 0.951
# Minibatch Loss= 0.002931
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.101
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.842
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.059
# F1 = 0.630 vs. 0.082
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.336 vs. 0.052
# F1 = 0.405 vs. 0.096
# Precision = 0.348 vs. 0.051
# Recall = 0.486 vs. 1.000
# Minibatch Loss= 0.002861
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e877f88d5a2e> in <module>()
#       2                 train_eval_step = 100,
#       3                 validation_eval_step = 100,
# ----> 4                 display_step = 100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/WCNNRNN_Wmultitask_16_opp_2Adam/WCNNRNN_Wmultitask_16_opp_2Adam-4495'

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.087
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.153
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.788
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.058
# F1 = 0.630 vs. 0.078
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.336 vs. 0.053
# F1 = 0.406 vs. 0.098
# Precision = 0.345 vs. 0.058
# Recall = 0.494 vs. 0.299
# Minibatch Loss= 0.002361
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.167
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.931
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.059
# F1 = 0.631 vs. 0.081
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.336 vs. 0.049
# F1 = 0.402 vs. 0.096
# Precision = 0.337 vs. 0.051
# Recall = 0.499 vs. 0.995
# Minibatch Loss= 0.002549
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.061
# F1 = 0.942 vs. 0.091
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.892 vs. 0.098
# F1 = 0.818 vs. 0.178
# Precision = 0.813 vs. 0.098
# Recall = 0.822 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.058
# F1 = 0.634 vs. 0.078
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.049
# F1 = 0.329 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.390 vs. 1.000
# Minibatch Loss= 0.061212
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.062
# F1 = 0.956 vs. 0.092
# Accuracy = 0.952 vs. 0.056
# CHANGE DETECTION
# AUC = 0.842 vs. 0.095
# F1 = 0.776 vs. 0.175
# Precision = 0.753 vs. 0.097
# Recall = 0.800 vs. 0.907
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.058
# F1 = 0.674 vs. 0.080
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.048
# F1 = 0.381 vs. 0.098
# Precision = 0.337 vs. 0.051
# Recall = 0.436 vs. 0.974
# Minibatch Loss= 0.043453
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.989 vs. 0.092
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.102
# F1 = 0.913 vs. 0.182
# Precision = 0.861 vs. 0.101
# Recall = 0.972 vs. 0.934
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.688 vs. 0.059
# F1 = 0.680 vs. 0.082
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.314 vs. 0.054
# F1 = 0.399 vs. 0.098
# Precision = 0.339 vs. 0.057
# Recall = 0.483 vs. 0.343
# Minibatch Loss= 0.020817
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.993 vs. 0.092
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.974 vs. 0.112
# F1 = 0.955 vs. 0.195
# Precision = 0.938 vs. 0.109
# Recall = 0.973 vs. 0.918
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.058
# F1 = 0.676 vs. 0.081
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.052
# F1 = 0.393 vs. 0.098
# Precision = 0.361 vs. 0.051
# Recall = 0.431 vs. 0.953
# Minibatch Loss= 0.015241
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.996 vs. 0.088
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.087
# F1 = 0.978 vs. 0.159
# Precision = 0.966 vs. 0.087
# Recall = 0.991 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.687 vs. 0.059
# F1 = 0.681 vs. 0.083
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.047
# F1 = 0.390 vs. 0.098
# Precision = 0.314 vs. 0.051
# Recall = 0.514 vs. 0.984
# Minibatch Loss= 0.009302
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.997 vs. 0.089
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.095
# F1 = 0.984 vs. 0.159
# Precision = 0.974 vs. 0.091
# Recall = 0.994 vs. 0.606
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.682 vs. 0.079
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.050
# F1 = 0.393 vs. 0.097
# Precision = 0.314 vs. 0.052
# Recall = 0.525 vs. 0.797
# Minibatch Loss= 0.008400
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.095
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.096
# F1 = 0.994 vs. 0.171
# Precision = 0.992 vs. 0.094
# Recall = 0.997 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.687 vs. 0.059
# F1 = 0.685 vs. 0.081
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.055
# F1 = 0.398 vs. 0.101
# Precision = 0.328 vs. 0.055
# Recall = 0.506 vs. 0.590
# Minibatch Loss= 0.006277
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.089
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.085
# F1 = 0.996 vs. 0.155
# Precision = 0.994 vs. 0.084
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.059
# F1 = 0.681 vs. 0.079
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.047
# F1 = 0.404 vs. 0.099
# Precision = 0.342 vs. 0.052
# Recall = 0.494 vs. 0.966
# Minibatch Loss= 0.004808
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.094
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.095
# F1 = 0.996 vs. 0.177
# Precision = 0.994 vs. 0.097
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.684 vs. 0.082
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.050
# F1 = 0.408 vs. 0.096
# Precision = 0.334 vs. 0.051
# Recall = 0.522 vs. 0.938
# Minibatch Loss= 0.004829
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 0.996 vs. 0.152
# Precision = 0.992 vs. 0.083
# Recall = 1.000 vs. 0.958
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.681 vs. 0.060
# F1 = 0.681 vs. 0.083
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.055
# F1 = 0.409 vs. 0.099
# Precision = 0.325 vs. 0.054
# Recall = 0.551 vs. 0.561
# Minibatch Loss= 0.003435
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.105
# F1 = 1.000 vs. 0.185
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.060
# F1 = 0.686 vs. 0.085
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.057
# F1 = 0.408 vs. 0.099
# Precision = 0.334 vs. 0.058
# Recall = 0.525 vs. 0.351
# Minibatch Loss= 0.004103
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.913
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.060
# F1 = 0.684 vs. 0.082
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.052
# F1 = 0.408 vs. 0.098
# Precision = 0.332 vs. 0.052
# Recall = 0.530 vs. 0.761
# Minibatch Loss= 0.002600
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.170
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.684 vs. 0.059
# F1 = 0.687 vs. 0.081
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.051
# F1 = 0.405 vs. 0.097
# Precision = 0.333 vs. 0.051
# Recall = 0.517 vs. 0.966
# Minibatch Loss= 0.002499
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.096
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.166
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.683 vs. 0.058
# F1 = 0.686 vs. 0.083
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.053
# F1 = 0.404 vs. 0.099
# Precision = 0.331 vs. 0.053
# Recall = 0.517 vs. 0.751
# Minibatch Loss= 0.002185
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.158
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.707
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.680 vs. 0.058
# F1 = 0.687 vs. 0.077
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.052
# F1 = 0.401 vs. 0.096
# Precision = 0.320 vs. 0.051
# Recall = 0.535 vs. 1.000
# Minibatch Loss= 0.001852
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.059
# F1 = 0.689 vs. 0.079
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.049
# F1 = 0.399 vs. 0.097
# Precision = 0.324 vs. 0.053
# Recall = 0.519 vs. 0.603
# Minibatch Loss= 0.001744
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.062
# F1 = 0.937 vs. 0.093
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.794 vs. 0.100
# F1 = 0.759 vs. 0.185
# Precision = 0.714 vs. 0.110
# Recall = 0.809 vs. 0.603
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.059
# F1 = 0.694 vs. 0.080
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.055
# F1 = 0.366 vs. 0.099
# Precision = 0.267 vs. 0.056
# Recall = 0.579 vs. 0.429
# Minibatch Loss= 0.056326
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.989 vs. 0.094
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.111
# F1 = 0.918 vs. 0.181
# Precision = 0.880 vs. 0.102
# Recall = 0.960 vs. 0.786
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.059
# F1 = 0.693 vs. 0.079
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.050
# F1 = 0.381 vs. 0.097
# Precision = 0.291 vs. 0.052
# Recall = 0.551 vs. 0.847
# Minibatch Loss= 0.019178
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.993 vs. 0.094
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.097
# F1 = 0.962 vs. 0.173
# Precision = 0.942 vs. 0.095
# Recall = 0.984 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.693 vs. 0.059
# F1 = 0.688 vs. 0.082
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.050
# F1 = 0.395 vs. 0.097
# Precision = 0.322 vs. 0.051
# Recall = 0.512 vs. 0.945
# Minibatch Loss= 0.012402
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.998 vs. 0.087
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.083
# F1 = 0.989 vs. 0.154
# Precision = 0.980 vs. 0.084
# Recall = 0.998 vs. 0.934
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.692 vs. 0.058
# F1 = 0.684 vs. 0.081
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.056
# F1 = 0.395 vs. 0.102
# Precision = 0.299 vs. 0.061
# Recall = 0.582 vs. 0.306
# Minibatch Loss= 0.007387
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.092
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 0.995 vs. 0.171
# Precision = 0.992 vs. 0.094
# Recall = 0.998 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.689 vs. 0.060
# F1 = 0.679 vs. 0.083
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.045
# F1 = 0.391 vs. 0.096
# Precision = 0.313 vs. 0.051
# Recall = 0.519 vs. 0.995
# Minibatch Loss= 0.006773
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.999 vs. 0.087
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 0.996 vs. 0.156
# Precision = 0.996 vs. 0.086
# Recall = 0.996 vs. 0.876
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.688 vs. 0.058
# F1 = 0.677 vs. 0.078
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.052
# F1 = 0.387 vs. 0.098
# Precision = 0.306 vs. 0.054
# Recall = 0.527 vs. 0.548
# Minibatch Loss= 0.005324
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.998 vs. 0.164
# Precision = 0.997 vs. 0.089
# Recall = 1.000 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.689 vs. 0.060
# F1 = 0.682 vs. 0.081
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.050
# F1 = 0.384 vs. 0.097
# Precision = 0.295 vs. 0.053
# Recall = 0.551 vs. 0.636
# Minibatch Loss= 0.004503
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 0.999 vs. 0.160
# Precision = 0.998 vs. 0.087
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.688 vs. 0.058
# F1 = 0.680 vs. 0.081
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.054
# F1 = 0.386 vs. 0.102
# Precision = 0.320 vs. 0.054
# Recall = 0.488 vs. 0.805
# Minibatch Loss= 0.003561
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 0.999 vs. 0.174
# Precision = 0.998 vs. 0.096
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.688 vs. 0.059
# F1 = 0.681 vs. 0.078
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.053
# F1 = 0.382 vs. 0.102
# Precision = 0.317 vs. 0.055
# Recall = 0.481 vs. 0.727
# Minibatch Loss= 0.003161
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.060
# F1 = 0.679 vs. 0.083
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.051
# F1 = 0.382 vs. 0.097
# Precision = 0.308 vs. 0.052
# Recall = 0.501 vs. 0.701
# Minibatch Loss= 0.002741
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.147
# Precision = 1.000 vs. 0.079
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.680 vs. 0.082
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.054
# F1 = 0.382 vs. 0.104
# Precision = 0.308 vs. 0.056
# Recall = 0.501 vs. 0.717
# Minibatch Loss= 0.002292
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.958 vs. 0.061
# F1 = 0.906 vs. 0.087
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.764 vs. 0.089
# F1 = 0.708 vs. 0.153
# Precision = 0.649 vs. 0.083
# Recall = 0.778 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.058
# F1 = 0.658 vs. 0.078
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.056
# F1 = 0.369 vs. 0.100
# Precision = 0.299 vs. 0.054
# Recall = 0.481 vs. 0.670
# Minibatch Loss= 0.086602
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.991 vs. 0.093
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.980 vs. 0.104
# F1 = 0.942 vs. 0.178
# Precision = 0.927 vs. 0.098
# Recall = 0.958 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.059
# F1 = 0.711 vs. 0.081
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.049
# F1 = 0.366 vs. 0.096
# Precision = 0.307 vs. 0.051
# Recall = 0.452 vs. 1.000
# Minibatch Loss= 0.013911
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.094
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.994 vs. 0.095
# F1 = 0.988 vs. 0.172
# Precision = 0.985 vs. 0.094
# Recall = 0.992 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.698 vs. 0.058
# F1 = 0.712 vs. 0.078
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.056
# F1 = 0.378 vs. 0.104
# Precision = 0.290 vs. 0.058
# Recall = 0.543 vs. 0.504
# Minibatch Loss= 0.005811
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.088
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.084
# F1 = 0.997 vs. 0.159
# Precision = 0.994 vs. 0.087
# Recall = 1.000 vs. 0.919
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.059
# F1 = 0.709 vs. 0.085
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.051
# F1 = 0.385 vs. 0.097
# Precision = 0.311 vs. 0.051
# Recall = 0.506 vs. 1.000
# Minibatch Loss= 0.003704
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.097
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.116
# F1 = 0.998 vs. 0.217
# Precision = 0.997 vs. 0.122
# Recall = 0.999 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.698 vs. 0.058
# F1 = 0.708 vs. 0.079
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.050
# F1 = 0.383 vs. 0.097
# Precision = 0.294 vs. 0.052
# Recall = 0.548 vs. 0.696
# Minibatch Loss= 0.004424
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.073
# F1 = 0.999 vs. 0.141
# Precision = 0.998 vs. 0.076
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.059
# F1 = 0.705 vs. 0.078
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.049
# F1 = 0.382 vs. 0.099
# Precision = 0.303 vs. 0.053
# Recall = 0.517 vs. 0.722
# Minibatch Loss= 0.002110
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.181
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.828
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.694 vs. 0.059
# F1 = 0.703 vs. 0.080
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.049
# F1 = 0.378 vs. 0.097
# Precision = 0.295 vs. 0.051
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 0.002308
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.096
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.111
# F1 = 1.000 vs. 0.199
# Precision = 1.000 vs. 0.110
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.059
# F1 = 0.704 vs. 0.081
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.053
# F1 = 0.382 vs. 0.097
# Precision = 0.298 vs. 0.051
# Recall = 0.530 vs. 0.987
# Minibatch Loss= 0.002110
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.689 vs. 0.059
# F1 = 0.705 vs. 0.080
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.055
# F1 = 0.375 vs. 0.097
# Precision = 0.284 vs. 0.051
# Recall = 0.553 vs. 0.984
# Minibatch Loss= 0.001579
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.934
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.688 vs. 0.060
# F1 = 0.704 vs. 0.082
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.054
# F1 = 0.372 vs. 0.100
# Precision = 0.304 vs. 0.054
# Recall = 0.481 vs. 0.600
# Minibatch Loss= 0.001445
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.175
# Precision = 1.000 vs. 0.100
# Recall = 1.000 vs. 0.728
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.687 vs. 0.059
# F1 = 0.704 vs. 0.081
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.051
# F1 = 0.370 vs. 0.097
# Precision = 0.298 vs. 0.051
# Recall = 0.488 vs. 0.995
# Minibatch Loss= 0.001367
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.164
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.939
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.703 vs. 0.083
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.047
# F1 = 0.367 vs. 0.097
# Precision = 0.293 vs. 0.051
# Recall = 0.491 vs. 1.000
# Minibatch Loss= 0.001236
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.894 vs. 0.060
# F1 = 0.845 vs. 0.088
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.526 vs. 0.080
# F1 = 0.522 vs. 0.148
# Precision = 0.487 vs. 0.082
# Recall = 0.562 vs. 0.748
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.544 vs. 0.058
# F1 = 0.579 vs. 0.079
# Accuracy = 0.775 vs. 0.056
# CHANGE DETECTION
# AUC = 0.233 vs. 0.053
# F1 = 0.326 vs. 0.103
# Precision = 0.282 vs. 0.056
# Recall = 0.387 vs. 0.608
# Minibatch Loss= 0.186466
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.982 vs. 0.093
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.959 vs. 0.094
# F1 = 0.908 vs. 0.169
# Precision = 0.862 vs. 0.095
# Recall = 0.958 vs. 0.763
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.059
# F1 = 0.675 vs. 0.079
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.054
# F1 = 0.397 vs. 0.097
# Precision = 0.315 vs. 0.052
# Recall = 0.535 vs. 0.771
# Minibatch Loss= 0.019656
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.088
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.086
# F1 = 0.981 vs. 0.158
# Precision = 0.962 vs. 0.086
# Recall = 1.000 vs. 0.935
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.059
# F1 = 0.671 vs. 0.082
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.052
# F1 = 0.400 vs. 0.098
# Precision = 0.320 vs. 0.053
# Recall = 0.532 vs. 0.712
# Minibatch Loss= 0.009245
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.095
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.102
# F1 = 0.992 vs. 0.175
# Precision = 0.992 vs. 0.097
# Recall = 0.992 vs. 0.949
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.059
# F1 = 0.672 vs. 0.086
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.053
# F1 = 0.401 vs. 0.098
# Precision = 0.341 vs. 0.052
# Recall = 0.486 vs. 0.795
# Minibatch Loss= 0.007214
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.998 vs. 0.090
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 0.998 vs. 0.157
# Precision = 0.996 vs. 0.085
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.058
# F1 = 0.671 vs. 0.078
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.049
# F1 = 0.397 vs. 0.098
# Precision = 0.317 vs. 0.052
# Recall = 0.530 vs. 0.951
# Minibatch Loss= 0.005211
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.095
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 0.998 vs. 0.180
# Precision = 0.995 vs. 0.099
# Recall = 1.000 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.058
# F1 = 0.672 vs. 0.080
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.054
# F1 = 0.394 vs. 0.096
# Precision = 0.325 vs. 0.051
# Recall = 0.499 vs. 0.992
# Minibatch Loss= 0.004302
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.075
# F1 = 0.999 vs. 0.142
# Precision = 0.998 vs. 0.077
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.059
# F1 = 0.673 vs. 0.081
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.057
# F1 = 0.389 vs. 0.107
# Precision = 0.348 vs. 0.064
# Recall = 0.442 vs. 0.338
# Minibatch Loss= 0.003060
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.966
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.059
# F1 = 0.673 vs. 0.082
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.052
# F1 = 0.390 vs. 0.097
# Precision = 0.340 vs. 0.051
# Recall = 0.457 vs. 0.987
# Minibatch Loss= 0.002844
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.058
# F1 = 0.674 vs. 0.079
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.047
# F1 = 0.387 vs. 0.098
# Precision = 0.318 vs. 0.052
# Recall = 0.496 vs. 0.891
# Minibatch Loss= 0.002559
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.690
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.061
# F1 = 0.676 vs. 0.087
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.055
# F1 = 0.390 vs. 0.102
# Precision = 0.319 vs. 0.060
# Recall = 0.501 vs. 0.358
# Minibatch Loss= 0.002092
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.059
# F1 = 0.677 vs. 0.080
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.051
# F1 = 0.386 vs. 0.097
# Precision = 0.317 vs. 0.051
# Recall = 0.494 vs. 0.974
# Minibatch Loss= 0.001991
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.058
# F1 = 0.678 vs. 0.079
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.049
# F1 = 0.389 vs. 0.098
# Precision = 0.319 vs. 0.052
# Recall = 0.499 vs. 0.922
# Minibatch Loss= 0.001636
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.101
# F1 = 1.000 vs. 0.170
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.059
# F1 = 0.678 vs. 0.081
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.315 vs. 0.052
# F1 = 0.384 vs. 0.101
# Precision = 0.316 vs. 0.054
# Recall = 0.488 vs. 0.842
# Minibatch Loss= 0.001581
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.178
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 0.952
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.059
# F1 = 0.678 vs. 0.079
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.314 vs. 0.053
# F1 = 0.382 vs. 0.098
# Precision = 0.306 vs. 0.052
# Recall = 0.506 vs. 0.922
# Minibatch Loss= 0.001350
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.181
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.058
# F1 = 0.679 vs. 0.077
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.053
# F1 = 0.381 vs. 0.101
# Precision = 0.306 vs. 0.054
# Recall = 0.504 vs. 0.810
# Minibatch Loss= 0.001252
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.096
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.187
# Precision = 1.000 vs. 0.103
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.678 vs. 0.081
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.044
# F1 = 0.375 vs. 0.097
# Precision = 0.297 vs. 0.051
# Recall = 0.509 vs. 0.992
# Minibatch Loss= 0.001222
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.097
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.169
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.059
# F1 = 0.679 vs. 0.080
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.049
# F1 = 0.374 vs. 0.097
# Precision = 0.290 vs. 0.051
# Recall = 0.527 vs. 0.995
# Minibatch Loss= 0.001007
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.159
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.733
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.059
# F1 = 0.679 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.051
# F1 = 0.372 vs. 0.100
# Precision = 0.287 vs. 0.054
# Recall = 0.530 vs. 0.647
# Minibatch Loss= 0.000876
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.058
# F1 = 0.678 vs. 0.076
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.056
# F1 = 0.373 vs. 0.101
# Precision = 0.292 vs. 0.058
# Recall = 0.514 vs. 0.390
# Minibatch Loss= 0.000819
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.069
# Recall = 1.000 vs. 0.819
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.058
# F1 = 0.679 vs. 0.082
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.052
# F1 = 0.370 vs. 0.098
# Precision = 0.321 vs. 0.051
# Recall = 0.436 vs. 0.969
# Minibatch Loss= 0.000573
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.153
# Precision = 1.000 vs. 0.083
# Recall = 1.000 vs. 0.935
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.059
# F1 = 0.679 vs. 0.079
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.048
# F1 = 0.370 vs. 0.097
# Precision = 0.287 vs. 0.051
# Recall = 0.519 vs. 1.000
# Minibatch Loss= 0.000593
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.059
# F1 = 0.678 vs. 0.080
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.052
# F1 = 0.369 vs. 0.098
# Precision = 0.288 vs. 0.052
# Recall = 0.514 vs. 0.821
# Minibatch Loss= 0.000649
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.153
# Precision = 1.000 vs. 0.083
# Recall = 1.000 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.060
# F1 = 0.677 vs. 0.084
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.057
# F1 = 0.369 vs. 0.099
# Precision = 0.277 vs. 0.057
# Recall = 0.553 vs. 0.351
# Minibatch Loss= 0.000540
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.858 vs. 0.062
# F1 = 0.819 vs. 0.094
# Accuracy = 0.801 vs. 0.056
# CHANGE DETECTION
# AUC = 0.539 vs. 0.081
# F1 = 0.547 vs. 0.151
# Precision = 0.480 vs. 0.082
# Recall = 0.634 vs. 0.964
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.515 vs. 0.059
# F1 = 0.548 vs. 0.078
# Accuracy = 0.693 vs. 0.056
# CHANGE DETECTION
# AUC = 0.157 vs. 0.045
# F1 = 0.238 vs. 0.096
# Precision = 0.182 vs. 0.051
# Recall = 0.343 vs. 1.000
# Minibatch Loss= 0.243982
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.875 vs. 0.061
# F1 = 0.828 vs. 0.091
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.496 vs. 0.082
# F1 = 0.516 vs. 0.153
# Precision = 0.418 vs. 0.083
# Recall = 0.673 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.528 vs. 0.058
# F1 = 0.566 vs. 0.083
# Accuracy = 0.772 vs. 0.056
# CHANGE DETECTION
# AUC = 0.215 vs. 0.049
# F1 = 0.329 vs. 0.097
# Precision = 0.237 vs. 0.051
# Recall = 0.535 vs. 0.966
# Minibatch Loss= 0.139399
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.961 vs. 0.064
# F1 = 0.928 vs. 0.090
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.087
# F1 = 0.726 vs. 0.161
# Precision = 0.637 vs. 0.092
# Recall = 0.844 vs. 0.645
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.058
# F1 = 0.611 vs. 0.079
# Accuracy = 0.852 vs. 0.056
# CHANGE DETECTION
# AUC = 0.249 vs. 0.055
# F1 = 0.354 vs. 0.099
# Precision = 0.261 vs. 0.055
# Recall = 0.548 vs. 0.496
# Minibatch Loss= 0.058261
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.060
# F1 = 0.953 vs. 0.088
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.829 vs. 0.086
# F1 = 0.799 vs. 0.153
# Precision = 0.749 vs. 0.087
# Recall = 0.855 vs. 0.649
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.058
# F1 = 0.611 vs. 0.079
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.250 vs. 0.048
# F1 = 0.366 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.509 vs. 0.938
# Minibatch Loss= 0.038613
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.062
# F1 = 0.972 vs. 0.093
# Accuracy = 0.962 vs. 0.056
# CHANGE DETECTION
# AUC = 0.899 vs. 0.108
# F1 = 0.876 vs. 0.184
# Precision = 0.843 vs. 0.102
# Recall = 0.912 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.059
# F1 = 0.613 vs. 0.082
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.256 vs. 0.054
# F1 = 0.366 vs. 0.098
# Precision = 0.302 vs. 0.053
# Recall = 0.465 vs. 0.735
# Minibatch Loss= 0.034453
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.063
# F1 = 0.977 vs. 0.095
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.914 vs. 0.098
# F1 = 0.899 vs. 0.184
# Precision = 0.851 vs. 0.101
# Recall = 0.954 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.059
# F1 = 0.614 vs. 0.083
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.255 vs. 0.054
# F1 = 0.363 vs. 0.098
# Precision = 0.288 vs. 0.052
# Recall = 0.491 vs. 0.849
# Minibatch Loss= 0.028365
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.062
# F1 = 0.983 vs. 0.094
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.958 vs. 0.106
# F1 = 0.930 vs. 0.194
# Precision = 0.893 vs. 0.109
# Recall = 0.971 vs. 0.885
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.058
# F1 = 0.615 vs. 0.077
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.053
# F1 = 0.363 vs. 0.102
# Precision = 0.287 vs. 0.056
# Recall = 0.496 vs. 0.509
# Minibatch Loss= 0.025977
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.061
# F1 = 0.986 vs. 0.087
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.084
# F1 = 0.954 vs. 0.157
# Precision = 0.929 vs. 0.085
# Recall = 0.980 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.059
# F1 = 0.617 vs. 0.080
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.047
# F1 = 0.361 vs. 0.096
# Precision = 0.268 vs. 0.051
# Recall = 0.553 vs. 0.995
# Minibatch Loss= 0.019140
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.990 vs. 0.089
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.088
# F1 = 0.968 vs. 0.166
# Precision = 0.951 vs. 0.091
# Recall = 0.984 vs. 0.932
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.059
# F1 = 0.618 vs. 0.082
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.052
# F1 = 0.358 vs. 0.102
# Precision = 0.296 vs. 0.056
# Recall = 0.452 vs. 0.590
# Minibatch Loss= 0.016508
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.995 vs. 0.093
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.093
# F1 = 0.981 vs. 0.181
# Precision = 0.965 vs. 0.100
# Recall = 0.997 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.060
# F1 = 0.618 vs. 0.081
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.052
# F1 = 0.358 vs. 0.098
# Precision = 0.271 vs. 0.052
# Recall = 0.527 vs. 0.901
# Minibatch Loss= 0.014858
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.994 vs. 0.094
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.107
# F1 = 0.985 vs. 0.191
# Precision = 0.971 vs. 0.106
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.059
# F1 = 0.619 vs. 0.082
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.049
# F1 = 0.362 vs. 0.097
# Precision = 0.276 vs. 0.051
# Recall = 0.522 vs. 0.979
# Minibatch Loss= 0.015702
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.997 vs. 0.089
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.089
# F1 = 0.991 vs. 0.161
# Precision = 0.984 vs. 0.088
# Recall = 0.998 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.591 vs. 0.058
# F1 = 0.613 vs. 0.076
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.052
# F1 = 0.367 vs. 0.101
# Precision = 0.287 vs. 0.055
# Recall = 0.509 vs. 0.652
# Minibatch Loss= 0.010205
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.086
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.073
# F1 = 0.989 vs. 0.136
# Precision = 0.987 vs. 0.074
# Recall = 0.991 vs. 0.808
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.059
# F1 = 0.613 vs. 0.081
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.264 vs. 0.053
# F1 = 0.367 vs. 0.102
# Precision = 0.294 vs. 0.054
# Recall = 0.488 vs. 0.886
# Minibatch Loss= 0.009172
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.094
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.099
# F1 = 0.990 vs. 0.175
# Precision = 0.981 vs. 0.098
# Recall = 1.000 vs. 0.808
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.058
# F1 = 0.612 vs. 0.078
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.054
# F1 = 0.366 vs. 0.099
# Precision = 0.301 vs. 0.052
# Recall = 0.468 vs. 0.810
# Minibatch Loss= 0.009845
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.091
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.095
# F1 = 0.992 vs. 0.169
# Precision = 0.988 vs. 0.099
# Recall = 0.997 vs. 0.581
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.058
# F1 = 0.613 vs. 0.077
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.264 vs. 0.052
# F1 = 0.367 vs. 0.097
# Precision = 0.295 vs. 0.052
# Recall = 0.486 vs. 0.696
# Minibatch Loss= 0.009157
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.095
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.107
# F1 = 0.995 vs. 0.185
# Precision = 0.991 vs. 0.105
# Recall = 0.998 vs. 0.762
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.058
# F1 = 0.612 vs. 0.079
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.265 vs. 0.053
# F1 = 0.363 vs. 0.100
# Precision = 0.306 vs. 0.056
# Recall = 0.447 vs. 0.447
# Minibatch Loss= 0.008383
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.999 vs. 0.154
# Precision = 0.998 vs. 0.083
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.058
# F1 = 0.612 vs. 0.083
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.265 vs. 0.051
# F1 = 0.365 vs. 0.098
# Precision = 0.304 vs. 0.054
# Recall = 0.457 vs. 0.504
# Minibatch Loss= 0.005865
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.092
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.105
# F1 = 0.998 vs. 0.187
# Precision = 0.995 vs. 0.104
# Recall = 1.000 vs. 0.968
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.059
# F1 = 0.612 vs. 0.081
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.265 vs. 0.049
# F1 = 0.359 vs. 0.096
# Precision = 0.298 vs. 0.051
# Recall = 0.452 vs. 0.995
# Minibatch Loss= 0.006536
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.089
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.073
# F1 = 0.997 vs. 0.135
# Precision = 0.993 vs. 0.078
# Recall = 1.000 vs. 0.532
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.060
# F1 = 0.611 vs. 0.086
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.051
# F1 = 0.355 vs. 0.098
# Precision = 0.288 vs. 0.052
# Recall = 0.462 vs. 0.927
# Minibatch Loss= 0.004779
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 0.999 vs. 0.169
# Precision = 0.998 vs. 0.093
# Recall = 1.000 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.059
# F1 = 0.611 vs. 0.083
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.053
# F1 = 0.357 vs. 0.097
# Precision = 0.315 vs. 0.051
# Recall = 0.410 vs. 0.919
# Minibatch Loss= 0.005190
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.145
# Precision = 1.000 vs. 0.079
# Recall = 1.000 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.058
# F1 = 0.615 vs. 0.079
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.051
# F1 = 0.357 vs. 0.097
# Precision = 0.305 vs. 0.051
# Recall = 0.431 vs. 0.826
# Minibatch Loss= 0.004551
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.167
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.058
# F1 = 0.611 vs. 0.082
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.055
# F1 = 0.353 vs. 0.101
# Precision = 0.298 vs. 0.063
# Recall = 0.434 vs. 0.252
# Minibatch Loss= 0.004068
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 0.999 vs. 0.177
# Precision = 0.998 vs. 0.100
# Recall = 1.000 vs. 0.778
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.582 vs. 0.059
# F1 = 0.610 vs. 0.083
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.051
# F1 = 0.353 vs. 0.097
# Precision = 0.282 vs. 0.051
# Recall = 0.473 vs. 0.839
# Minibatch Loss= 0.004147
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.446 vs. 0.060
# F1 = 0.526 vs. 0.091
# Accuracy = 0.718 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.090
# F1 = 0.334 vs. 0.172
# Precision = 0.319 vs. 0.095
# Recall = 0.351 vs. 0.915
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.302 vs. 0.058
# F1 = 0.399 vs. 0.080
# Accuracy = 0.825 vs. 0.056
# CHANGE DETECTION
# AUC = 0.108 vs. 0.050
# F1 = 0.196 vs. 0.098
# Precision = 0.157 vs. 0.051
# Recall = 0.260 vs. 0.940
# Minibatch Loss= 3.269531
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.105 vs. 0.093
# Accuracy = 0.020 vs. 0.056
# CHANGE DETECTION
# AUC = 0.102 vs. 0.102
# F1 = 0.186 vs. 0.182
# Precision = 0.103 vs. 0.101
# Recall = 0.972 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.058
# F1 = 0.087 vs. 0.078
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.047 vs. 0.051
# F1 = 0.099 vs. 0.097
# Precision = 0.052 vs. 0.051
# Recall = 0.992 vs. 0.997
# Minibatch Loss= 3.158238
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.061
# F1 = 0.099 vs. 0.093
# Accuracy = 0.264 vs. 0.056
# CHANGE DETECTION
# AUC = 0.076 vs. 0.096
# F1 = 0.169 vs. 0.169
# Precision = 0.092 vs. 0.093
# Recall = 1.000 vs. 0.883
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.058
# F1 = 0.085 vs. 0.079
# Accuracy = 0.379 vs. 0.056
# CHANGE DETECTION
# AUC = 0.050 vs. 0.051
# F1 = 0.108 vs. 0.100
# Precision = 0.058 vs. 0.054
# Recall = 0.678 vs. 0.706
# Minibatch Loss= 1.406767
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.099 vs. 0.095
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.082 vs. 0.096
# F1 = 0.190 vs. 0.174
# Precision = 0.105 vs. 0.097
# Recall = 0.989 vs. 0.857
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.059
# F1 = 0.086 vs. 0.079
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.047 vs. 0.054
# F1 = 0.108 vs. 0.106
# Precision = 0.057 vs. 0.057
# Recall = 0.966 vs. 0.727
# Minibatch Loss= 1.843200
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.062
# F1 = 0.117 vs. 0.093
# Accuracy = 0.004 vs. 0.056
# CHANGE DETECTION
# AUC = 0.130 vs. 0.106
# F1 = 0.203 vs. 0.185
# Precision = 0.118 vs. 0.107
# Recall = 0.721 vs. 0.663
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.059
# F1 = 0.101 vs. 0.080
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.059 vs. 0.052
# F1 = 0.110 vs. 0.098
# Precision = 0.062 vs. 0.051
# Recall = 0.522 vs. 0.956
# Minibatch Loss= 1.405751
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.061
# F1 = 0.109 vs. 0.089
# Accuracy = 0.015 vs. 0.056
# CHANGE DETECTION
# AUC = 0.086 vs. 0.075
# F1 = 0.165 vs. 0.143
# Precision = 0.096 vs. 0.077
# Recall = 0.595 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.060
# F1 = 0.096 vs. 0.084
# Accuracy = 0.036 vs. 0.056
# CHANGE DETECTION
# AUC = 0.053 vs. 0.050
# F1 = 0.116 vs. 0.098
# Precision = 0.063 vs. 0.052
# Recall = 0.662 vs. 0.878
# Minibatch Loss= 1.200996
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.063
# F1 = 0.118 vs. 0.097
# Accuracy = 0.012 vs. 0.056
# CHANGE DETECTION
# AUC = 0.141 vs. 0.112
# F1 = 0.242 vs. 0.211
# Precision = 0.143 vs. 0.118
# Recall = 0.786 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.059
# F1 = 0.096 vs. 0.078
# Accuracy = 0.036 vs. 0.056
# CHANGE DETECTION
# AUC = 0.056 vs. 0.050
# F1 = 0.116 vs. 0.098
# Precision = 0.063 vs. 0.053
# Recall = 0.735 vs. 0.662
# Minibatch Loss= 1.436618
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.062
# F1 = 0.119 vs. 0.094
# Accuracy = 0.028 vs. 0.056
# CHANGE DETECTION
# AUC = 0.115 vs. 0.101
# F1 = 0.201 vs. 0.179
# Precision = 0.115 vs. 0.098
# Recall = 0.785 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.058
# F1 = 0.096 vs. 0.077
# Accuracy = 0.046 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.055
# F1 = 0.116 vs. 0.101
# Precision = 0.063 vs. 0.054
# Recall = 0.662 vs. 0.831
# Minibatch Loss= 1.287950
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.060
# F1 = 0.123 vs. 0.090
# Accuracy = 0.033 vs. 0.056
# CHANGE DETECTION
# AUC = 0.123 vs. 0.089
# F1 = 0.187 vs. 0.163
# Precision = 0.107 vs. 0.089
# Recall = 0.762 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.066 vs. 0.058
# F1 = 0.101 vs. 0.083
# Accuracy = 0.046 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.050
# F1 = 0.116 vs. 0.098
# Precision = 0.063 vs. 0.052
# Recall = 0.735 vs. 0.977
# Minibatch Loss= 1.256234
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.060
# F1 = 0.114 vs. 0.090
# Accuracy = 0.029 vs. 0.056
# CHANGE DETECTION
# AUC = 0.102 vs. 0.081
# F1 = 0.194 vs. 0.157
# Precision = 0.111 vs. 0.085
# Recall = 0.747 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.059
# F1 = 0.103 vs. 0.082
# Accuracy = 0.046 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.058
# F1 = 0.115 vs. 0.098
# Precision = 0.063 vs. 0.058
# Recall = 0.660 vs. 0.322
# Minibatch Loss= 1.192668
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.061
# F1 = 0.122 vs. 0.092
# Accuracy = 0.018 vs. 0.056
# CHANGE DETECTION
# AUC = 0.109 vs. 0.095
# F1 = 0.199 vs. 0.160
# Precision = 0.116 vs. 0.091
# Recall = 0.689 vs. 0.665
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.059
# F1 = 0.096 vs. 0.079
# Accuracy = 0.041 vs. 0.056
# CHANGE DETECTION
# AUC = 0.056 vs. 0.052
# F1 = 0.117 vs. 0.098
# Precision = 0.063 vs. 0.055
# Recall = 0.735 vs. 0.473
# Minibatch Loss= 1.187302
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.061
# F1 = 0.123 vs. 0.093
# Accuracy = 0.034 vs. 0.056
# CHANGE DETECTION
# AUC = 0.105 vs. 0.085
# F1 = 0.180 vs. 0.161
# Precision = 0.103 vs. 0.090
# Recall = 0.694 vs. 0.740
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.058
# F1 = 0.098 vs. 0.081
# Accuracy = 0.040 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.053
# F1 = 0.115 vs. 0.101
# Precision = 0.063 vs. 0.054
# Recall = 0.662 vs. 0.888
# Minibatch Loss= 1.234580
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.070 vs. 0.062
# F1 = 0.121 vs. 0.093
# Accuracy = 0.020 vs. 0.056
# CHANGE DETECTION
# AUC = 0.103 vs. 0.091
# F1 = 0.190 vs. 0.170
# Precision = 0.108 vs. 0.095
# Recall = 0.816 vs. 0.811
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.067 vs. 0.060
# F1 = 0.098 vs. 0.078
# Accuracy = 0.040 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.049
# F1 = 0.118 vs. 0.096
# Precision = 0.065 vs. 0.051
# Recall = 0.647 vs. 0.995
# Minibatch Loss= 1.285756
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.061
# F1 = 0.122 vs. 0.092
# Accuracy = 0.028 vs. 0.056
# CHANGE DETECTION
# AUC = 0.110 vs. 0.102
# F1 = 0.202 vs. 0.178
# Precision = 0.116 vs. 0.098
# Recall = 0.778 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.058
# F1 = 0.102 vs. 0.079
# Accuracy = 0.040 vs. 0.056
# CHANGE DETECTION
# AUC = 0.054 vs. 0.050
# F1 = 0.118 vs. 0.096
# Precision = 0.065 vs. 0.051
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 1.263084
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.061
# F1 = 0.122 vs. 0.088
# Accuracy = 0.022 vs. 0.056
# CHANGE DETECTION
# AUC = 0.088 vs. 0.083
# F1 = 0.178 vs. 0.154
# Precision = 0.101 vs. 0.084
# Recall = 0.745 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.059
# F1 = 0.100 vs. 0.080
# Accuracy = 0.040 vs. 0.056
# CHANGE DETECTION
# AUC = 0.055 vs. 0.054
# F1 = 0.117 vs. 0.100
# Precision = 0.064 vs. 0.054
# Recall = 0.644 vs. 0.670
# Minibatch Loss= 1.188279
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.071 vs. 0.060
# F1 = 0.119 vs. 0.090
# Accuracy = 0.031 vs. 0.056
# CHANGE DETECTION
# AUC = 0.088 vs. 0.092
# F1 = 0.185 vs. 0.168
# Precision = 0.103 vs. 0.092
# Recall = 0.936 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.058
# F1 = 0.100 vs. 0.080
# Accuracy = 0.040 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.088 vs. 0.053
# Recall = 0.309 vs. 0.808
# Minibatch Loss= 1.158075
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.060
# F1 = 0.120 vs. 0.087
# Accuracy = 0.170 vs. 0.056
# CHANGE DETECTION
# AUC = 0.123 vs. 0.082
# F1 = 0.188 vs. 0.156
# Precision = 0.113 vs. 0.085
# Recall = 0.572 vs. 0.953
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.116 vs. 0.083
# Accuracy = 0.202 vs. 0.056
# CHANGE DETECTION
# AUC = 0.073 vs. 0.054
# F1 = 0.142 vs. 0.097
# Precision = 0.092 vs. 0.051
# Recall = 0.312 vs. 0.914
# Minibatch Loss= 1.132988
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.089 vs. 0.061
# F1 = 0.156 vs. 0.090
# Accuracy = 0.156 vs. 0.056
# CHANGE DETECTION
# AUC = 0.127 vs. 0.083
# F1 = 0.208 vs. 0.158
# Precision = 0.125 vs. 0.086
# Recall = 0.624 vs. 0.940
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.118 vs. 0.080
# Accuracy = 0.200 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.052
# F1 = 0.137 vs. 0.098
# Precision = 0.088 vs. 0.053
# Recall = 0.309 vs. 0.738
# Minibatch Loss= 1.164685
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.061
# F1 = 0.118 vs. 0.089
# Accuracy = 0.180 vs. 0.056
# CHANGE DETECTION
# AUC = 0.112 vs. 0.081
# F1 = 0.208 vs. 0.159
# Precision = 0.121 vs. 0.087
# Recall = 0.767 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.076 vs. 0.059
# F1 = 0.125 vs. 0.080
# Accuracy = 0.197 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.051
# F1 = 0.135 vs. 0.099
# Precision = 0.077 vs. 0.053
# Recall = 0.553 vs. 0.743
# Minibatch Loss= 1.150406
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.061
# F1 = 0.121 vs. 0.089
# Accuracy = 0.194 vs. 0.056
# CHANGE DETECTION
# AUC = 0.113 vs. 0.080
# F1 = 0.191 vs. 0.154
# Precision = 0.121 vs. 0.084
# Recall = 0.452 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.058
# F1 = 0.120 vs. 0.079
# Accuracy = 0.192 vs. 0.056
# CHANGE DETECTION
# AUC = 0.073 vs. 0.050
# F1 = 0.140 vs. 0.096
# Precision = 0.090 vs. 0.051
# Recall = 0.314 vs. 1.000
# Minibatch Loss= 1.159053
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.080 vs. 0.060
# F1 = 0.131 vs. 0.089
# Accuracy = 0.197 vs. 0.056
# CHANGE DETECTION
# AUC = 0.119 vs. 0.096
# F1 = 0.200 vs. 0.167
# Precision = 0.114 vs. 0.091
# Recall = 0.797 vs. 0.969
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.118 vs. 0.082
# Accuracy = 0.206 vs. 0.056
# CHANGE DETECTION
# AUC = 0.070 vs. 0.054
# F1 = 0.140 vs. 0.097
# Precision = 0.087 vs. 0.051
# Recall = 0.364 vs. 0.917
# Minibatch Loss= 1.125967
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.085 vs. 0.060
# F1 = 0.138 vs. 0.086
# Accuracy = 0.218 vs. 0.056
# CHANGE DETECTION
# AUC = 0.119 vs. 0.076
# F1 = 0.203 vs. 0.139
# Precision = 0.138 vs. 0.077
# Recall = 0.386 vs. 0.750
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.116 vs. 0.081
# Accuracy = 0.200 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.049
# F1 = 0.138 vs. 0.097
# Precision = 0.088 vs. 0.051
# Recall = 0.314 vs. 0.995
# Minibatch Loss= 1.041668
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.079 vs. 0.061
# F1 = 0.125 vs. 0.085
# Accuracy = 0.087 vs. 0.056
# CHANGE DETECTION
# AUC = 0.106 vs. 0.079
# F1 = 0.174 vs. 0.141
# Precision = 0.109 vs. 0.076
# Recall = 0.423 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.117 vs. 0.080
# Accuracy = 0.184 vs. 0.056
# CHANGE DETECTION
# AUC = 0.067 vs. 0.049
# F1 = 0.134 vs. 0.097
# Precision = 0.080 vs. 0.051
# Recall = 0.408 vs. 0.870
# Minibatch Loss= 1.140984
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.081 vs. 0.061
# F1 = 0.133 vs. 0.092
# Accuracy = 0.177 vs. 0.056
# CHANGE DETECTION
# AUC = 0.135 vs. 0.097
# F1 = 0.219 vs. 0.173
# Precision = 0.128 vs. 0.097
# Recall = 0.762 vs. 0.792
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.059
# F1 = 0.115 vs. 0.082
# Accuracy = 0.201 vs. 0.056
# CHANGE DETECTION
# AUC = 0.070 vs. 0.049
# F1 = 0.137 vs. 0.097
# Precision = 0.084 vs. 0.051
# Recall = 0.369 vs. 0.997
# Minibatch Loss= 1.146427
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.061
# F1 = 0.119 vs. 0.087
# Accuracy = 0.132 vs. 0.056
# CHANGE DETECTION
# AUC = 0.119 vs. 0.081
# F1 = 0.185 vs. 0.151
# Precision = 0.114 vs. 0.082
# Recall = 0.503 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.119 vs. 0.080
# Accuracy = 0.190 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.058
# F1 = 0.134 vs. 0.103
# Precision = 0.081 vs. 0.070
# Recall = 0.384 vs. 0.190
# Minibatch Loss= 1.138262
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.082 vs. 0.063
# F1 = 0.139 vs. 0.095
# Accuracy = 0.151 vs. 0.056
# CHANGE DETECTION
# AUC = 0.138 vs. 0.103
# F1 = 0.226 vs. 0.189
# Precision = 0.138 vs. 0.104
# Recall = 0.640 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.058
# F1 = 0.121 vs. 0.080
# Accuracy = 0.200 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.053
# F1 = 0.143 vs. 0.097
# Precision = 0.089 vs. 0.051
# Recall = 0.369 vs. 0.977
# Minibatch Loss= 1.221722
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.079 vs. 0.063
# F1 = 0.134 vs. 0.094
# Accuracy = 0.151 vs. 0.056
# CHANGE DETECTION
# AUC = 0.145 vs. 0.110
# F1 = 0.229 vs. 0.192
# Precision = 0.134 vs. 0.106
# Recall = 0.793 vs. 0.964
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.120 vs. 0.084
# Accuracy = 0.199 vs. 0.056
# CHANGE DETECTION
# AUC = 0.070 vs. 0.048
# F1 = 0.136 vs. 0.098
# Precision = 0.084 vs. 0.052
# Recall = 0.366 vs. 0.901
# Minibatch Loss= 1.298482
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.060
# F1 = 0.120 vs. 0.087
# Accuracy = 0.146 vs. 0.056
# CHANGE DETECTION
# AUC = 0.145 vs. 0.084
# F1 = 0.208 vs. 0.155
# Precision = 0.162 vs. 0.084
# Recall = 0.291 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.058
# F1 = 0.126 vs. 0.078
# Accuracy = 0.185 vs. 0.056
# CHANGE DETECTION
# AUC = 0.070 vs. 0.051
# F1 = 0.135 vs. 0.097
# Precision = 0.083 vs. 0.051
# Recall = 0.361 vs. 0.984
# Minibatch Loss= 1.127762
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.077 vs. 0.061
# F1 = 0.127 vs. 0.091
# Accuracy = 0.114 vs. 0.056
# CHANGE DETECTION
# AUC = 0.116 vs. 0.093
# F1 = 0.201 vs. 0.175
# Precision = 0.117 vs. 0.097
# Recall = 0.716 vs. 0.902
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.125 vs. 0.083
# Accuracy = 0.209 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.047
# F1 = 0.135 vs. 0.096
# Precision = 0.082 vs. 0.051
# Recall = 0.382 vs. 1.000
# Minibatch Loss= 1.244737
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.079 vs. 0.061
# F1 = 0.133 vs. 0.092
# Accuracy = 0.140 vs. 0.056
# CHANGE DETECTION
# AUC = 0.135 vs. 0.096
# F1 = 0.206 vs. 0.173
# Precision = 0.116 vs. 0.095
# Recall = 0.906 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.117 vs. 0.080
# Accuracy = 0.198 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.048
# F1 = 0.134 vs. 0.098
# Precision = 0.082 vs. 0.052
# Recall = 0.364 vs. 0.979
# Minibatch Loss= 1.246953
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.077 vs. 0.060
# F1 = 0.126 vs. 0.090
# Accuracy = 0.158 vs. 0.056
# CHANGE DETECTION
# AUC = 0.108 vs. 0.088
# F1 = 0.196 vs. 0.164
# Precision = 0.109 vs. 0.089
# Recall = 0.942 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.060
# F1 = 0.128 vs. 0.084
# Accuracy = 0.205 vs. 0.056
# CHANGE DETECTION
# AUC = 0.068 vs. 0.048
# F1 = 0.135 vs. 0.099
# Precision = 0.082 vs. 0.053
# Recall = 0.382 vs. 0.771
# Minibatch Loss= 1.152573
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.080 vs. 0.061
# F1 = 0.133 vs. 0.092
# Accuracy = 0.172 vs. 0.056
# CHANGE DETECTION
# AUC = 0.137 vs. 0.098
# F1 = 0.205 vs. 0.172
# Precision = 0.117 vs. 0.094
# Recall = 0.812 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.059
# F1 = 0.116 vs. 0.081
# Accuracy = 0.197 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.051
# F1 = 0.137 vs. 0.100
# Precision = 0.085 vs. 0.057
# Recall = 0.351 vs. 0.444
# Minibatch Loss= 1.203777
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.082 vs. 0.062
# F1 = 0.139 vs. 0.093
# Accuracy = 0.174 vs. 0.056
# CHANGE DETECTION
# AUC = 0.148 vs. 0.102
# F1 = 0.230 vs. 0.189
# Precision = 0.138 vs. 0.106
# Recall = 0.698 vs. 0.880
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.058
# F1 = 0.119 vs. 0.080
# Accuracy = 0.199 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.050
# F1 = 0.134 vs. 0.099
# Precision = 0.081 vs. 0.053
# Recall = 0.387 vs. 0.805
# Minibatch Loss= 1.267459
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.078 vs. 0.061
# F1 = 0.129 vs. 0.093
# Accuracy = 0.194 vs. 0.056
# CHANGE DETECTION
# AUC = 0.131 vs. 0.098
# F1 = 0.207 vs. 0.176
# Precision = 0.118 vs. 0.096
# Recall = 0.833 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.121 vs. 0.080
# Accuracy = 0.204 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.051
# F1 = 0.137 vs. 0.096
# Precision = 0.084 vs. 0.051
# Recall = 0.374 vs. 1.000
# Minibatch Loss= 1.219070
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.079 vs. 0.061
# F1 = 0.135 vs. 0.090
# Accuracy = 0.161 vs. 0.056
# CHANGE DETECTION
# AUC = 0.137 vs. 0.097
# F1 = 0.219 vs. 0.177
# Precision = 0.129 vs. 0.099
# Recall = 0.735 vs. 0.861
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.058
# F1 = 0.123 vs. 0.080
# Accuracy = 0.210 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.046
# F1 = 0.135 vs. 0.097
# Precision = 0.081 vs. 0.051
# Recall = 0.403 vs. 0.992
# Minibatch Loss= 1.203674
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.062
# F1 = 0.123 vs. 0.093
# Accuracy = 0.132 vs. 0.056
# CHANGE DETECTION
# AUC = 0.120 vs. 0.100
# F1 = 0.207 vs. 0.184
# Precision = 0.118 vs. 0.101
# Recall = 0.835 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.059
# F1 = 0.114 vs. 0.080
# Accuracy = 0.199 vs. 0.056
# CHANGE DETECTION
# AUC = 0.074 vs. 0.050
# F1 = 0.140 vs. 0.098
# Precision = 0.092 vs. 0.052
# Recall = 0.291 vs. 0.906
# Minibatch Loss= 1.218566
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.062
# F1 = 0.122 vs. 0.092
# Accuracy = 0.171 vs. 0.056
# CHANGE DETECTION
# AUC = 0.111 vs. 0.085
# F1 = 0.195 vs. 0.162
# Precision = 0.109 vs. 0.088
# Recall = 0.906 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.058
# F1 = 0.114 vs. 0.078
# Accuracy = 0.186 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.052
# F1 = 0.135 vs. 0.100
# Precision = 0.081 vs. 0.053
# Recall = 0.410 vs. 0.787
# Minibatch Loss= 1.180908
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.082 vs. 0.062
# F1 = 0.135 vs. 0.090
# Accuracy = 0.172 vs. 0.056
# CHANGE DETECTION
# AUC = 0.112 vs. 0.082
# F1 = 0.185 vs. 0.155
# Precision = 0.104 vs. 0.084
# Recall = 0.795 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.118 vs. 0.079
# Accuracy = 0.199 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.055
# F1 = 0.137 vs. 0.097
# Precision = 0.084 vs. 0.051
# Recall = 0.379 vs. 0.836
# Minibatch Loss= 1.105338
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.081 vs. 0.062
# F1 = 0.147 vs. 0.090
# Accuracy = 0.144 vs. 0.056
# CHANGE DETECTION
# AUC = 0.114 vs. 0.097
# F1 = 0.198 vs. 0.169
# Precision = 0.119 vs. 0.092
# Recall = 0.579 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.121 vs. 0.080
# Accuracy = 0.202 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.048
# F1 = 0.136 vs. 0.096
# Precision = 0.078 vs. 0.051
# Recall = 0.509 vs. 0.987
# Minibatch Loss= 1.165981
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.079 vs. 0.061
# F1 = 0.135 vs. 0.095
# Accuracy = 0.192 vs. 0.056
# CHANGE DETECTION
# AUC = 0.139 vs. 0.105
# F1 = 0.217 vs. 0.185
# Precision = 0.123 vs. 0.104
# Recall = 0.942 vs. 0.846
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.076 vs. 0.058
# F1 = 0.122 vs. 0.078
# Accuracy = 0.204 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.053
# F1 = 0.141 vs. 0.098
# Precision = 0.088 vs. 0.052
# Recall = 0.356 vs. 0.849
# Minibatch Loss= 1.240650
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.082 vs. 0.062
# F1 = 0.129 vs. 0.092
# Accuracy = 0.189 vs. 0.056
# CHANGE DETECTION
# AUC = 0.136 vs. 0.092
# F1 = 0.230 vs. 0.166
# Precision = 0.145 vs. 0.092
# Recall = 0.564 vs. 0.847
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.072 vs. 0.058
# F1 = 0.116 vs. 0.081
# Accuracy = 0.205 vs. 0.056
# CHANGE DETECTION
# AUC = 0.069 vs. 0.051
# F1 = 0.136 vs. 0.097
# Precision = 0.082 vs. 0.051
# Recall = 0.384 vs. 0.919
# Minibatch Loss= 1.198686
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.082 vs. 0.062
# F1 = 0.135 vs. 0.094
# Accuracy = 0.139 vs. 0.056
# CHANGE DETECTION
# AUC = 0.118 vs. 0.094
# F1 = 0.194 vs. 0.158
# Precision = 0.112 vs. 0.087
# Recall = 0.750 vs. 0.854
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.075 vs. 0.058
# F1 = 0.125 vs. 0.080
# Accuracy = 0.207 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.052
# F1 = 0.136 vs. 0.097
# Precision = 0.084 vs. 0.051
# Recall = 0.353 vs. 0.992
# Minibatch Loss= 1.130042
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.076 vs. 0.063
# F1 = 0.131 vs. 0.089
# Accuracy = 0.138 vs. 0.056
# CHANGE DETECTION
# AUC = 0.122 vs. 0.081
# F1 = 0.193 vs. 0.160
# Precision = 0.109 vs. 0.089
# Recall = 0.846 vs. 0.848
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.120 vs. 0.079
# Accuracy = 0.189 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.053
# F1 = 0.139 vs. 0.099
# Precision = 0.080 vs. 0.052
# Recall = 0.545 vs. 0.855
# Minibatch Loss= 1.148397
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.083 vs. 0.061
# F1 = 0.135 vs. 0.088
# Accuracy = 0.150 vs. 0.056
# CHANGE DETECTION
# AUC = 0.112 vs. 0.084
# F1 = 0.189 vs. 0.156
# Precision = 0.112 vs. 0.085
# Recall = 0.605 vs. 0.919
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.058
# F1 = 0.118 vs. 0.079
# Accuracy = 0.202 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.050
# F1 = 0.138 vs. 0.098
# Precision = 0.079 vs. 0.052
# Recall = 0.545 vs. 0.919
# Minibatch Loss= 1.160403
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.079 vs. 0.061
# F1 = 0.134 vs. 0.093
# Accuracy = 0.165 vs. 0.056
# CHANGE DETECTION
# AUC = 0.151 vs. 0.103
# F1 = 0.226 vs. 0.179
# Precision = 0.132 vs. 0.099
# Recall = 0.777 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.117 vs. 0.079
# Accuracy = 0.200 vs. 0.056
# CHANGE DETECTION
# AUC = 0.073 vs. 0.048
# F1 = 0.138 vs. 0.097
# Precision = 0.079 vs. 0.051
# Recall = 0.548 vs. 0.969
# Minibatch Loss= 1.212824
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.061
# F1 = 0.111 vs. 0.090
# Accuracy = 0.203 vs. 0.056
# CHANGE DETECTION
# AUC = 0.103 vs. 0.081
# F1 = 0.188 vs. 0.152
# Precision = 0.105 vs. 0.087
# Recall = 0.872 vs. 0.587
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.115 vs. 0.081
# Accuracy = 0.208 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.048
# F1 = 0.138 vs. 0.097
# Precision = 0.079 vs. 0.051
# Recall = 0.545 vs. 0.873
# Minibatch Loss= 1.156916
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.077 vs. 0.062
# F1 = 0.126 vs. 0.095
# Accuracy = 0.156 vs. 0.056
# CHANGE DETECTION
# AUC = 0.123 vs. 0.108
# F1 = 0.226 vs. 0.191
# Precision = 0.135 vs. 0.105
# Recall = 0.690 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.121 vs. 0.081
# Accuracy = 0.200 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.048
# F1 = 0.135 vs. 0.097
# Precision = 0.084 vs. 0.051
# Recall = 0.338 vs. 0.855
# Minibatch Loss= 1.267071
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.078 vs. 0.063
# F1 = 0.136 vs. 0.096
# Accuracy = 0.156 vs. 0.056
# CHANGE DETECTION
# AUC = 0.139 vs. 0.100
# F1 = 0.220 vs. 0.185
# Precision = 0.129 vs. 0.103
# Recall = 0.769 vs. 0.892
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.059
# F1 = 0.121 vs. 0.080
# Accuracy = 0.198 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.051
# F1 = 0.135 vs. 0.097
# Precision = 0.082 vs. 0.051
# Recall = 0.382 vs. 0.992
# Minibatch Loss= 1.263917
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.060
# F1 = 0.119 vs. 0.088
# Accuracy = 0.144 vs. 0.056
# CHANGE DETECTION
# AUC = 0.096 vs. 0.076
# F1 = 0.176 vs. 0.148
# Precision = 0.102 vs. 0.080
# Recall = 0.638 vs. 0.924
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.119 vs. 0.079
# Accuracy = 0.186 vs. 0.056
# CHANGE DETECTION
# AUC = 0.071 vs. 0.049
# F1 = 0.135 vs. 0.096
# Precision = 0.082 vs. 0.051
# Recall = 0.382 vs. 0.927
# Minibatch Loss= 1.124787
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.074 vs. 0.062
# F1 = 0.124 vs. 0.094
# Accuracy = 0.127 vs. 0.056
# CHANGE DETECTION
# AUC = 0.125 vs. 0.087
# F1 = 0.203 vs. 0.169
# Precision = 0.143 vs. 0.092
# Recall = 0.351 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.073 vs. 0.059
# F1 = 0.118 vs. 0.081
# Accuracy = 0.183 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.051
# F1 = 0.138 vs. 0.099
# Precision = 0.084 vs. 0.052
# Recall = 0.382 vs. 0.865
# Minibatch Loss= 1.187251
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/WCNNRNN_Wmultitask_16_opp_2Adam/WCNNRNN_Wmultitask_16_opp_2Adam-24495'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-4495')
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')
# Out:
# INFO:tensorflow:Restoring parameters from ../../model/WCNNRNN_Wmultitask_16_opp_2Adam/WCNNRNN_Wmultitask_16_opp_2Adam-4495

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.060
# F1 = 0.631 vs. 0.082
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.337 vs. 0.053
# F1 = 0.405 vs. 0.101
# Precision = 0.346 vs. 0.054
# Recall = 0.488 vs. 0.766

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2
