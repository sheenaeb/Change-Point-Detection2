# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_NewWavelet_Wmultitask_16_opp_20K_2"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
from models.HRNN_model_new_Wavelet import Model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 7    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[9, n_variables, 128],
                 [5, 128, 128],
                 [5, 128, 128]]
bias_shape = [128, 128, 128]
wavelet_kernel_size = 3    
activation = tf.nn.relu

lstm_n_hidden = 256
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_kernel_size = wavelet_kernel_size,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.061
# F1 = 0.097 vs. 0.092
# Accuracy = 0.021 vs. 0.056
# CHANGE DETECTION
# AUC = 0.118 vs. 0.097
# F1 = 0.207 vs. 0.168
# Precision = 0.123 vs. 0.092
# Recall = 0.643 vs. 1.000
# Validation: 0
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.058
# F1 = 0.079 vs. 0.078
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.059 vs. 0.052
# F1 = 0.122 vs. 0.099
# Precision = 0.070 vs. 0.052
# Recall = 0.504 vs. 0.945
# Minibatch Loss= 1.303529
# Training: 100
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.062
# F1 = 0.602 vs. 0.090
# Accuracy = 0.650 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.095
# F1 = 0.372 vs. 0.173
# Precision = 0.247 vs. 0.095
# Recall = 0.750 vs. 0.990
# Validation: 100
# ACTIVITY RECOGNITION
# AUC = 0.270 vs. 0.058
# F1 = 0.347 vs. 0.079
# Accuracy = 0.660 vs. 0.056
# CHANGE DETECTION
# AUC = 0.219 vs. 0.051
# F1 = 0.291 vs. 0.101
# Precision = 0.215 vs. 0.055
# Recall = 0.452 vs. 0.587
# Minibatch Loss= 0.370378
# Training: 200
# ACTIVITY RECOGNITION
# AUC = 0.751 vs. 0.061
# F1 = 0.718 vs. 0.090
# Accuracy = 0.781 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.088
# F1 = 0.374 vs. 0.157
# Precision = 0.303 vs. 0.085
# Recall = 0.490 vs. 1.000
# Validation: 200
# ACTIVITY RECOGNITION
# AUC = 0.428 vs. 0.059
# F1 = 0.474 vs. 0.081
# Accuracy = 0.752 vs. 0.056
# CHANGE DETECTION
# AUC = 0.220 vs. 0.050
# F1 = 0.313 vs. 0.100
# Precision = 0.209 vs. 0.054
# Recall = 0.621 vs. 0.688
# Minibatch Loss= 0.201558
# Training: 300
# ACTIVITY RECOGNITION
# AUC = 0.840 vs. 0.061
# F1 = 0.799 vs. 0.092
# Accuracy = 0.780 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.096
# F1 = 0.462 vs. 0.170
# Precision = 0.365 vs. 0.095
# Recall = 0.627 vs. 0.806
# Validation: 300
# ACTIVITY RECOGNITION
# AUC = 0.493 vs. 0.059
# F1 = 0.537 vs. 0.082
# Accuracy = 0.803 vs. 0.056
# CHANGE DETECTION
# AUC = 0.239 vs. 0.049
# F1 = 0.327 vs. 0.097
# Precision = 0.216 vs. 0.051
# Recall = 0.670 vs. 0.995
# Minibatch Loss= 0.159384
# Training: 400
# ACTIVITY RECOGNITION
# AUC = 0.920 vs. 0.062
# F1 = 0.859 vs. 0.090
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.412 vs. 0.094
# F1 = 0.482 vs. 0.161
# Precision = 0.380 vs. 0.090
# Recall = 0.662 vs. 0.765
# Validation: 400
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.058
# F1 = 0.571 vs. 0.077
# Accuracy = 0.810 vs. 0.056
# CHANGE DETECTION
# AUC = 0.259 vs. 0.054
# F1 = 0.336 vs. 0.105
# Precision = 0.227 vs. 0.058
# Recall = 0.644 vs. 0.512
# Minibatch Loss= 0.112685
# Training: 500
# ACTIVITY RECOGNITION
# AUC = 0.939 vs. 0.060
# F1 = 0.887 vs. 0.090
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.485 vs. 0.089
# F1 = 0.526 vs. 0.160
# Precision = 0.408 vs. 0.088
# Recall = 0.739 vs. 0.854
# Validation: 500
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.058
# F1 = 0.571 vs. 0.077
# Accuracy = 0.831 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.051
# F1 = 0.347 vs. 0.098
# Precision = 0.262 vs. 0.052
# Recall = 0.514 vs. 0.922
# Minibatch Loss= 0.099074
# Training: 600
# ACTIVITY RECOGNITION
# AUC = 0.923 vs. 0.064
# F1 = 0.874 vs. 0.095
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.477 vs. 0.093
# F1 = 0.509 vs. 0.171
# Precision = 0.414 vs. 0.094
# Recall = 0.660 vs. 0.968
# Validation: 600
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.059
# F1 = 0.608 vs. 0.078
# Accuracy = 0.844 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.053
# F1 = 0.375 vs. 0.097
# Precision = 0.264 vs. 0.051
# Recall = 0.644 vs. 0.953
# Minibatch Loss= 0.109895
# Training: 700
# ACTIVITY RECOGNITION
# AUC = 0.960 vs. 0.062
# F1 = 0.916 vs. 0.091
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.521 vs. 0.096
# F1 = 0.556 vs. 0.171
# Precision = 0.435 vs. 0.094
# Recall = 0.770 vs. 1.000
# Validation: 700
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.059
# F1 = 0.604 vs. 0.082
# Accuracy = 0.852 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.050
# F1 = 0.377 vs. 0.096
# Precision = 0.286 vs. 0.051
# Recall = 0.556 vs. 1.000
# Minibatch Loss= 0.083204
# Training: 800
# ACTIVITY RECOGNITION
# AUC = 0.953 vs. 0.061
# F1 = 0.916 vs. 0.090
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.549 vs. 0.094
# F1 = 0.597 vs. 0.170
# Precision = 0.507 vs. 0.095
# Recall = 0.724 vs. 0.839
# Validation: 800
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.058
# F1 = 0.614 vs. 0.079
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.055
# F1 = 0.386 vs. 0.097
# Precision = 0.283 vs. 0.052
# Recall = 0.608 vs. 0.836
# Minibatch Loss= 0.076423
# Training: 900
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.061
# F1 = 0.933 vs. 0.088
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.636 vs. 0.092
# F1 = 0.646 vs. 0.168
# Precision = 0.582 vs. 0.092
# Recall = 0.727 vs. 1.000
# Validation: 900
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.059
# F1 = 0.625 vs. 0.080
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.053
# F1 = 0.405 vs. 0.099
# Precision = 0.326 vs. 0.054
# Recall = 0.535 vs. 0.621
# Minibatch Loss= 0.061089
# Training: 1000
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.060
# F1 = 0.954 vs. 0.089
# Accuracy = 0.950 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.082
# F1 = 0.665 vs. 0.156
# Precision = 0.544 vs. 0.085
# Recall = 0.855 vs. 0.939
# Validation: 1000
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.059
# F1 = 0.613 vs. 0.081
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.053
# F1 = 0.403 vs. 0.103
# Precision = 0.308 vs. 0.056
# Recall = 0.582 vs. 0.636
# Minibatch Loss= 0.048464
# Training: 1100
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.061
# F1 = 0.940 vs. 0.093
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.102
# F1 = 0.685 vs. 0.182
# Precision = 0.580 vs. 0.100
# Recall = 0.837 vs. 0.959
# Validation: 1100
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.058
# F1 = 0.612 vs. 0.079
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.047
# F1 = 0.397 vs. 0.096
# Precision = 0.324 vs. 0.051
# Recall = 0.514 vs. 1.000
# Minibatch Loss= 0.055792
# Training: 1200
# ACTIVITY RECOGNITION
# AUC = 0.912 vs. 0.062
# F1 = 0.864 vs. 0.092
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.545 vs. 0.099
# F1 = 0.564 vs. 0.178
# Precision = 0.486 vs. 0.098
# Recall = 0.670 vs. 0.997
# Validation: 1200
# ACTIVITY RECOGNITION
# AUC = 0.632 vs. 0.058
# F1 = 0.626 vs. 0.078
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.050
# F1 = 0.385 vs. 0.097
# Precision = 0.310 vs. 0.051
# Recall = 0.506 vs. 0.883
# Minibatch Loss= 0.105243
# Training: 1300
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.061
# F1 = 0.928 vs. 0.090
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.649 vs. 0.101
# F1 = 0.629 vs. 0.173
# Precision = 0.550 vs. 0.095
# Recall = 0.735 vs. 0.940
# Validation: 1300
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.058
# F1 = 0.632 vs. 0.079
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.337 vs. 0.050
# F1 = 0.390 vs. 0.097
# Precision = 0.353 vs. 0.053
# Recall = 0.436 vs. 0.623
# Minibatch Loss= 0.066798
# Training: 1400
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.060
# F1 = 0.943 vs. 0.087
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.075
# F1 = 0.641 vs. 0.146
# Precision = 0.521 vs. 0.079
# Recall = 0.833 vs. 0.980
# Validation: 1400
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.059
# F1 = 0.633 vs. 0.080
# Accuracy = 0.811 vs. 0.056
# CHANGE DETECTION
# AUC = 0.348 vs. 0.050
# F1 = 0.395 vs. 0.097
# Precision = 0.286 vs. 0.053
# Recall = 0.636 vs. 0.597
# Minibatch Loss= 0.060730
# Training: 1500
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.061
# F1 = 0.965 vs. 0.093
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.732 vs. 0.107
# F1 = 0.729 vs. 0.178
# Precision = 0.661 vs. 0.099
# Recall = 0.812 vs. 0.893
# Validation: 1500
# ACTIVITY RECOGNITION
# AUC = 0.632 vs. 0.059
# F1 = 0.636 vs. 0.081
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.056
# F1 = 0.407 vs. 0.109
# Precision = 0.360 vs. 0.063
# Recall = 0.468 vs. 0.431
# Minibatch Loss= 0.043179
# Training: 1600
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.062
# F1 = 0.943 vs. 0.091
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.715 vs. 0.088
# F1 = 0.690 vs. 0.171
# Precision = 0.656 vs. 0.094
# Recall = 0.727 vs. 0.958
# Validation: 1600
# ACTIVITY RECOGNITION
# AUC = 0.636 vs. 0.059
# F1 = 0.642 vs. 0.081
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.368 vs. 0.050
# F1 = 0.422 vs. 0.097
# Precision = 0.329 vs. 0.051
# Recall = 0.590 vs. 0.982
# Minibatch Loss= 0.055567
# Training: 1700
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.060
# F1 = 0.976 vs. 0.090
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.789 vs. 0.090
# F1 = 0.768 vs. 0.161
# Precision = 0.673 vs. 0.087
# Recall = 0.894 vs. 1.000
# Validation: 1700
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.058
# F1 = 0.626 vs. 0.084
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.360 vs. 0.053
# F1 = 0.421 vs. 0.100
# Precision = 0.335 vs. 0.054
# Recall = 0.566 vs. 0.670
# Minibatch Loss= 0.034326
# Training: 1800
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.061
# F1 = 0.980 vs. 0.090
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.826 vs. 0.089
# F1 = 0.815 vs. 0.166
# Precision = 0.742 vs. 0.091
# Recall = 0.905 vs. 0.977
# Validation: 1800
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.059
# F1 = 0.630 vs. 0.081
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.369 vs. 0.059
# F1 = 0.423 vs. 0.104
# Precision = 0.378 vs. 0.061
# Recall = 0.481 vs. 0.351
# Minibatch Loss= 0.029151
# Training: 1900
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.986 vs. 0.094
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.872 vs. 0.101
# F1 = 0.847 vs. 0.182
# Precision = 0.790 vs. 0.100
# Recall = 0.914 vs. 1.000
# Validation: 1900
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.061
# F1 = 0.629 vs. 0.084
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.050
# F1 = 0.428 vs. 0.097
# Precision = 0.330 vs. 0.051
# Recall = 0.610 vs. 0.925
# Minibatch Loss= 0.027074
# Training: 2000
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.063
# F1 = 0.988 vs. 0.094
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.918 vs. 0.104
# F1 = 0.874 vs. 0.181
# Precision = 0.820 vs. 0.100
# Recall = 0.937 vs. 0.984
# Validation: 2000
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.058
# F1 = 0.633 vs. 0.078
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.056
# F1 = 0.431 vs. 0.097
# Precision = 0.350 vs. 0.051
# Recall = 0.561 vs. 0.995
# Minibatch Loss= 0.023597
# Training: 2100
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.991 vs. 0.090
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.091
# F1 = 0.868 vs. 0.160
# Precision = 0.805 vs. 0.087
# Recall = 0.941 vs. 0.974
# Validation: 2100
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.058
# F1 = 0.628 vs. 0.081
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.388 vs. 0.055
# F1 = 0.432 vs. 0.100
# Precision = 0.385 vs. 0.061
# Recall = 0.494 vs. 0.288
# Minibatch Loss= 0.020799
# Training: 2200
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.988 vs. 0.094
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.932 vs. 0.105
# F1 = 0.897 vs. 0.189
# Precision = 0.861 vs. 0.106
# Recall = 0.935 vs. 0.863
# Validation: 2200
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.058
# F1 = 0.625 vs. 0.077
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.052
# F1 = 0.429 vs. 0.097
# Precision = 0.369 vs. 0.052
# Recall = 0.512 vs. 0.642
# Minibatch Loss= 0.021326
# Training: 2300
# ACTIVITY RECOGNITION
# AUC = 0.960 vs. 0.063
# F1 = 0.918 vs. 0.092
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.097
# F1 = 0.687 vs. 0.170
# Precision = 0.681 vs. 0.094
# Recall = 0.693 vs. 0.924
# Validation: 2300
# ACTIVITY RECOGNITION
# AUC = 0.659 vs. 0.059
# F1 = 0.658 vs. 0.083
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.363 vs. 0.054
# F1 = 0.412 vs. 0.099
# Precision = 0.338 vs. 0.058
# Recall = 0.527 vs. 0.345
# Minibatch Loss= 0.067760
# Training: 2400
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.062
# F1 = 0.962 vs. 0.090
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.833 vs. 0.082
# F1 = 0.794 vs. 0.165
# Precision = 0.735 vs. 0.091
# Recall = 0.863 vs. 0.937
# Validation: 2400
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.059
# F1 = 0.674 vs. 0.081
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.051
# F1 = 0.419 vs. 0.099
# Precision = 0.339 vs. 0.053
# Recall = 0.551 vs. 0.873
# Minibatch Loss= 0.037371
# Training: 2500
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.060
# F1 = 0.981 vs. 0.090
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.913 vs. 0.084
# F1 = 0.871 vs. 0.154
# Precision = 0.828 vs. 0.084
# Recall = 0.919 vs. 0.987
# Validation: 2500
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.060
# F1 = 0.670 vs. 0.082
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.048
# F1 = 0.436 vs. 0.096
# Precision = 0.340 vs. 0.051
# Recall = 0.610 vs. 1.000
# Minibatch Loss= 0.022077
# Training: 2600
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.992 vs. 0.086
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.922 vs. 0.079
# F1 = 0.889 vs. 0.139
# Precision = 0.836 vs. 0.075
# Recall = 0.949 vs. 0.977
# Validation: 2600
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.059
# F1 = 0.671 vs. 0.076
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.051
# F1 = 0.439 vs. 0.097
# Precision = 0.374 vs. 0.051
# Recall = 0.530 vs. 0.839
# Minibatch Loss= 0.017380
# Training: 2700
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.983 vs. 0.090
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.923 vs. 0.084
# F1 = 0.896 vs. 0.150
# Precision = 0.868 vs. 0.081
# Recall = 0.926 vs. 0.998
# Validation: 2700
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.059
# F1 = 0.671 vs. 0.081
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.049
# F1 = 0.433 vs. 0.097
# Precision = 0.350 vs. 0.051
# Recall = 0.566 vs. 1.000
# Minibatch Loss= 0.019217
# Training: 2800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.091
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.083
# F1 = 0.929 vs. 0.160
# Precision = 0.879 vs. 0.088
# Recall = 0.984 vs. 0.936
# Validation: 2800
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.059
# F1 = 0.665 vs. 0.083
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.394 vs. 0.055
# F1 = 0.450 vs. 0.102
# Precision = 0.387 vs. 0.055
# Recall = 0.538 vs. 0.730
# Minibatch Loss= 0.013859
# Training: 2900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.064
# F1 = 0.996 vs. 0.099
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.094
# F1 = 0.955 vs. 0.182
# Precision = 0.917 vs. 0.100
# Recall = 0.997 vs. 1.000
# Validation: 2900
# ACTIVITY RECOGNITION
# AUC = 0.659 vs. 0.059
# F1 = 0.662 vs. 0.081
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.057
# F1 = 0.447 vs. 0.103
# Precision = 0.373 vs. 0.061
# Recall = 0.558 vs. 0.325
# Minibatch Loss= 0.012667
# Training: 3000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.997 vs. 0.090
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.083
# F1 = 0.964 vs. 0.158
# Precision = 0.941 vs. 0.086
# Recall = 0.989 vs. 0.960
# Validation: 3000
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.058
# F1 = 0.659 vs. 0.077
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.386 vs. 0.053
# F1 = 0.443 vs. 0.096
# Precision = 0.369 vs. 0.051
# Recall = 0.553 vs. 1.000
# Minibatch Loss= 0.009804
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 0.878 vs. 0.062
# F1 = 0.832 vs. 0.093
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.682 vs. 0.094
# F1 = 0.679 vs. 0.173
# Precision = 0.606 vs. 0.095
# Recall = 0.771 vs. 0.903
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.058
# F1 = 0.573 vs. 0.077
# Accuracy = 0.792 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.053
# F1 = 0.350 vs. 0.101
# Precision = 0.309 vs. 0.058
# Recall = 0.403 vs. 0.400
# Minibatch Loss= 0.161945
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.063
# F1 = 0.975 vs. 0.093
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.914 vs. 0.100
# F1 = 0.861 vs. 0.182
# Precision = 0.795 vs. 0.101
# Recall = 0.938 vs. 0.918
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.058
# F1 = 0.690 vs. 0.082
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.398 vs. 0.047
# F1 = 0.435 vs. 0.097
# Precision = 0.346 vs. 0.051
# Recall = 0.584 vs. 0.982
# Minibatch Loss= 0.028344
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.990 vs. 0.094
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.966 vs. 0.094
# F1 = 0.916 vs. 0.173
# Precision = 0.871 vs. 0.095
# Recall = 0.967 vs. 0.957
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.676 vs. 0.059
# F1 = 0.672 vs. 0.081
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.399 vs. 0.056
# F1 = 0.446 vs. 0.098
# Precision = 0.361 vs. 0.052
# Recall = 0.584 vs. 0.922
# Minibatch Loss= 0.017026
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.994 vs. 0.090
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.082
# F1 = 0.954 vs. 0.155
# Precision = 0.928 vs. 0.084
# Recall = 0.983 vs. 0.943
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.058
# F1 = 0.665 vs. 0.078
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.402 vs. 0.054
# F1 = 0.445 vs. 0.098
# Precision = 0.359 vs. 0.051
# Recall = 0.584 vs. 0.982
# Minibatch Loss= 0.011508
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.093
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.100
# F1 = 0.963 vs. 0.182
# Precision = 0.940 vs. 0.100
# Recall = 0.987 vs. 0.975
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.058
# F1 = 0.664 vs. 0.078
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.051
# F1 = 0.437 vs. 0.097
# Precision = 0.335 vs. 0.051
# Recall = 0.626 vs. 0.987
# Minibatch Loss= 0.010350
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.063
# F1 = 0.995 vs. 0.093
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.092
# F1 = 0.977 vs. 0.176
# Precision = 0.962 vs. 0.097
# Recall = 0.992 vs. 0.974
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.059
# F1 = 0.661 vs. 0.079
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.050
# F1 = 0.438 vs. 0.096
# Precision = 0.366 vs. 0.051
# Recall = 0.545 vs. 1.000
# Minibatch Loss= 0.009279
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.995 vs. 0.086
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.074
# F1 = 0.959 vs. 0.142
# Precision = 0.952 vs. 0.076
# Recall = 0.967 vs. 0.996
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.058
# F1 = 0.663 vs. 0.077
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.050
# F1 = 0.439 vs. 0.101
# Precision = 0.386 vs. 0.054
# Recall = 0.509 vs. 0.769
# Minibatch Loss= 0.009456
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.092
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.091
# F1 = 0.991 vs. 0.166
# Precision = 0.987 vs. 0.091
# Recall = 0.996 vs. 0.992
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.059
# F1 = 0.666 vs. 0.080
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.054
# F1 = 0.441 vs. 0.097
# Precision = 0.345 vs. 0.053
# Recall = 0.613 vs. 0.634
# Minibatch Loss= 0.006150
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.999 vs. 0.095
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.105
# F1 = 0.996 vs. 0.182
# Precision = 0.992 vs. 0.100
# Recall = 1.000 vs. 0.942
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.060
# F1 = 0.669 vs. 0.081
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.394 vs. 0.055
# F1 = 0.445 vs. 0.100
# Precision = 0.353 vs. 0.053
# Recall = 0.600 vs. 0.922
# Minibatch Loss= 0.005034
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 0.997 vs. 0.157
# Precision = 0.994 vs. 0.087
# Recall = 1.000 vs. 0.848
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.058
# F1 = 0.667 vs. 0.079
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.394 vs. 0.049
# F1 = 0.437 vs. 0.097
# Precision = 0.379 vs. 0.051
# Recall = 0.514 vs. 0.974
# Minibatch Loss= 0.003237
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 0.997 vs. 0.167
# Precision = 0.995 vs. 0.091
# Recall = 1.000 vs. 0.962
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.059
# F1 = 0.666 vs. 0.078
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.048
# F1 = 0.443 vs. 0.097
# Precision = 0.353 vs. 0.051
# Recall = 0.592 vs. 0.951
# Minibatch Loss= 0.003401
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.090
# F1 = 0.983 vs. 0.160
# Precision = 0.971 vs. 0.091
# Recall = 0.995 vs. 0.650
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.062
# F1 = 0.675 vs. 0.087
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.049
# F1 = 0.438 vs. 0.097
# Precision = 0.365 vs. 0.053
# Recall = 0.548 vs. 0.616
# Minibatch Loss= 0.005742
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.100
# F1 = 0.998 vs. 0.182
# Precision = 0.997 vs. 0.102
# Recall = 0.998 vs. 0.881
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.061
# F1 = 0.673 vs. 0.086
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.393 vs. 0.053
# F1 = 0.447 vs. 0.101
# Precision = 0.363 vs. 0.054
# Recall = 0.582 vs. 0.808
# Minibatch Loss= 0.003388
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.096
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.186
# Precision = 1.000 vs. 0.103
# Recall = 1.000 vs. 1.000
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.058
# F1 = 0.668 vs. 0.078
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.392 vs. 0.051
# F1 = 0.452 vs. 0.097
# Precision = 0.364 vs. 0.052
# Recall = 0.597 vs. 0.779
# Minibatch Loss= 0.002797
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.169
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.991
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.060
# F1 = 0.668 vs. 0.082
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.054
# F1 = 0.450 vs. 0.101
# Precision = 0.358 vs. 0.062
# Recall = 0.605 vs. 0.273
# Minibatch Loss= 0.001812
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 0.998 vs. 0.164
# Precision = 0.996 vs. 0.090
# Recall = 1.000 vs. 0.894
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.059
# F1 = 0.668 vs. 0.079
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.050
# F1 = 0.446 vs. 0.098
# Precision = 0.379 vs. 0.051
# Recall = 0.543 vs. 0.992
# Minibatch Loss= 0.002149
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.149
# Precision = 1.000 vs. 0.080
# Recall = 1.000 vs. 1.000
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.058
# F1 = 0.668 vs. 0.080
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.051
# F1 = 0.447 vs. 0.096
# Precision = 0.354 vs. 0.051
# Recall = 0.608 vs. 0.997
# Minibatch Loss= 0.001367
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.988
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.058
# F1 = 0.668 vs. 0.079
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.393 vs. 0.053
# F1 = 0.447 vs. 0.102
# Precision = 0.349 vs. 0.057
# Recall = 0.621 vs. 0.504
# Minibatch Loss= 0.001392
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.113
# F1 = 1.000 vs. 0.195
# Precision = 1.000 vs. 0.108
# Recall = 1.000 vs. 1.000
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.060
# F1 = 0.668 vs. 0.083
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.392 vs. 0.051
# F1 = 0.445 vs. 0.097
# Precision = 0.351 vs. 0.052
# Recall = 0.608 vs. 0.727
# Minibatch Loss= 0.001453
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.084
# F1 = 0.982 vs. 0.159
# Precision = 0.984 vs. 0.086
# Recall = 0.980 vs. 1.000
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.675 vs. 0.059
# F1 = 0.678 vs. 0.082
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.401 vs. 0.054
# F1 = 0.451 vs. 0.098
# Precision = 0.371 vs. 0.051
# Recall = 0.574 vs. 0.932
# Minibatch Loss= 0.006303
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 0.961 vs. 0.063
# F1 = 0.918 vs. 0.092
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.739 vs. 0.099
# F1 = 0.690 vs. 0.178
# Precision = 0.620 vs. 0.098
# Recall = 0.777 vs. 1.000
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.058
# F1 = 0.678 vs. 0.080
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.339 vs. 0.048
# F1 = 0.416 vs. 0.097
# Precision = 0.340 vs. 0.051
# Recall = 0.535 vs. 0.971
# Minibatch Loss= 0.071075
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.061
# F1 = 0.965 vs. 0.093
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.854 vs. 0.105
# F1 = 0.802 vs. 0.183
# Precision = 0.763 vs. 0.102
# Recall = 0.845 vs. 0.905
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.706 vs. 0.059
# F1 = 0.700 vs. 0.082
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.057
# F1 = 0.428 vs. 0.102
# Precision = 0.349 vs. 0.056
# Recall = 0.553 vs. 0.564
# Minibatch Loss= 0.041273
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.060
# F1 = 0.983 vs. 0.086
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.945 vs. 0.088
# F1 = 0.903 vs. 0.155
# Precision = 0.873 vs. 0.084
# Recall = 0.935 vs. 1.000
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.706 vs. 0.059
# F1 = 0.704 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.364 vs. 0.059
# F1 = 0.434 vs. 0.108
# Precision = 0.347 vs. 0.068
# Recall = 0.579 vs. 0.268
# Minibatch Loss= 0.022137
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.988 vs. 0.090
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.959 vs. 0.086
# F1 = 0.929 vs. 0.157
# Precision = 0.917 vs. 0.086
# Recall = 0.942 vs. 0.936
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.707 vs. 0.059
# F1 = 0.709 vs. 0.082
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.370 vs. 0.050
# F1 = 0.440 vs. 0.097
# Precision = 0.348 vs. 0.051
# Recall = 0.597 vs. 0.829
# Minibatch Loss= 0.016407
# Training: 5500
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.993 vs. 0.090
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.088
# F1 = 0.962 vs. 0.162
# Precision = 0.950 vs. 0.088
# Recall = 0.975 vs. 0.996
# Validation: 5500
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.058
# F1 = 0.705 vs. 0.083
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.362 vs. 0.055
# F1 = 0.427 vs. 0.099
# Precision = 0.351 vs. 0.053
# Recall = 0.545 vs. 0.657
# Minibatch Loss= 0.012276
# Training: 5600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.095
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.103
# F1 = 0.979 vs. 0.182
# Precision = 0.962 vs. 0.100
# Recall = 0.997 vs. 0.997
# Validation: 5600
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.704 vs. 0.081
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.364 vs. 0.051
# F1 = 0.429 vs. 0.098
# Precision = 0.358 vs. 0.052
# Recall = 0.535 vs. 0.823
# Minibatch Loss= 0.010559
# Training: 5700
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.997 vs. 0.089
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.079
# F1 = 0.988 vs. 0.150
# Precision = 0.979 vs. 0.081
# Recall = 0.998 vs. 0.979
# Validation: 5700
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.059
# F1 = 0.703 vs. 0.082
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.361 vs. 0.053
# F1 = 0.424 vs. 0.097
# Precision = 0.346 vs. 0.051
# Recall = 0.548 vs. 0.997
# Minibatch Loss= 0.007942
# Training: 5800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.999 vs. 0.091
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.082
# F1 = 0.996 vs. 0.157
# Precision = 0.996 vs. 0.086
# Recall = 0.996 vs. 0.928
# Validation: 5800
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.058
# F1 = 0.701 vs. 0.081
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.358 vs. 0.049
# F1 = 0.418 vs. 0.097
# Precision = 0.340 vs. 0.051
# Recall = 0.540 vs. 0.935
# Minibatch Loss= 0.006107
# Training: 5900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.091
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.996 vs. 0.162
# Precision = 0.994 vs. 0.088
# Recall = 0.998 vs. 1.000
# Validation: 5900
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.059
# F1 = 0.699 vs. 0.085
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.359 vs. 0.053
# F1 = 0.420 vs. 0.101
# Precision = 0.323 vs. 0.055
# Recall = 0.597 vs. 0.639
# Minibatch Loss= 0.005124
# Training: 6000
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.061
# F1 = 0.955 vs. 0.090
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.888 vs. 0.090
# F1 = 0.821 vs. 0.169
# Precision = 0.758 vs. 0.093
# Recall = 0.897 vs. 0.988
# Validation: 6000
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.705 vs. 0.081
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.050
# F1 = 0.434 vs. 0.097
# Precision = 0.337 vs. 0.051
# Recall = 0.610 vs. 0.922
# Minibatch Loss= 0.042117
# Training: 6100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.998 vs. 0.089
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.079
# F1 = 0.995 vs. 0.162
# Precision = 0.993 vs. 0.088
# Recall = 0.996 vs. 1.000
# Validation: 6100
# ACTIVITY RECOGNITION
# AUC = 0.706 vs. 0.059
# F1 = 0.713 vs. 0.080
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.049
# F1 = 0.451 vs. 0.098
# Precision = 0.423 vs. 0.051
# Recall = 0.483 vs. 0.971
# Minibatch Loss= 0.006363
# Training: 6200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 0.999 vs. 0.162
# Precision = 0.998 vs. 0.091
# Recall = 1.000 vs. 0.744
# Validation: 6200
# ACTIVITY RECOGNITION
# AUC = 0.703 vs. 0.058
# F1 = 0.712 vs. 0.081
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.054
# F1 = 0.445 vs. 0.102
# Precision = 0.409 vs. 0.059
# Recall = 0.488 vs. 0.379
# Minibatch Loss= 0.004070
# Training: 6300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 0.999 vs. 0.190
# Precision = 0.997 vs. 0.105
# Recall = 1.000 vs. 0.997
# Validation: 6300
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.059
# F1 = 0.710 vs. 0.080
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.386 vs. 0.052
# F1 = 0.441 vs. 0.097
# Precision = 0.429 vs. 0.052
# Recall = 0.455 vs. 0.873
# Minibatch Loss= 0.003805
# Training: 6400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 0.999 vs. 0.173
# Precision = 0.998 vs. 0.095
# Recall = 1.000 vs. 0.957
# Validation: 6400
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.060
# F1 = 0.710 vs. 0.080
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.056
# F1 = 0.436 vs. 0.103
# Precision = 0.354 vs. 0.061
# Recall = 0.569 vs. 0.348
# Minibatch Loss= 0.002770
# Training: 6500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.724
# Validation: 6500
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.711 vs. 0.081
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.048
# F1 = 0.437 vs. 0.097
# Precision = 0.390 vs. 0.051
# Recall = 0.496 vs. 0.995
# Minibatch Loss= 0.002414
# Training: 6600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.172
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.972
# Validation: 6600
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.060
# F1 = 0.711 vs. 0.079
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.051
# F1 = 0.440 vs. 0.099
# Precision = 0.395 vs. 0.053
# Recall = 0.496 vs. 0.725
# Minibatch Loss= 0.002364
# Training: 6700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.999 vs. 0.172
# Precision = 0.998 vs. 0.097
# Recall = 1.000 vs. 0.749
# Validation: 6700
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.713 vs. 0.080
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.055
# F1 = 0.442 vs. 0.097
# Precision = 0.398 vs. 0.051
# Recall = 0.496 vs. 0.966
# Minibatch Loss= 0.002043
# Training: 6800
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.968 vs. 0.093
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.929 vs. 0.104
# F1 = 0.865 vs. 0.180
# Precision = 0.831 vs. 0.105
# Recall = 0.901 vs. 0.627
# Validation: 6800
# ACTIVITY RECOGNITION
# AUC = 0.705 vs. 0.059
# F1 = 0.705 vs. 0.082
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.052
# F1 = 0.455 vs. 0.098
# Precision = 0.434 vs. 0.052
# Recall = 0.478 vs. 0.849
# Minibatch Loss= 0.038038
# Training: 6900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.085
# F1 = 0.999 vs. 0.167
# Precision = 0.998 vs. 0.091
# Recall = 1.000 vs. 0.981
# Validation: 6900
# ACTIVITY RECOGNITION
# AUC = 0.703 vs. 0.059
# F1 = 0.713 vs. 0.081
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.054
# F1 = 0.452 vs. 0.102
# Precision = 0.408 vs. 0.057
# Recall = 0.506 vs. 0.478
# Minibatch Loss= 0.003693
# Training: 7000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.106
# F1 = 1.000 vs. 0.191
# Precision = 1.000 vs. 0.107
# Recall = 1.000 vs. 0.932
# Validation: 7000
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.059
# F1 = 0.709 vs. 0.080
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.049
# F1 = 0.451 vs. 0.098
# Precision = 0.389 vs. 0.051
# Recall = 0.535 vs. 0.997
# Minibatch Loss= 0.002537
# Training: 7100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.181
# Precision = 1.000 vs. 0.100
# Recall = 1.000 vs. 0.906
# Validation: 7100
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.058
# F1 = 0.707 vs. 0.080
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.049
# F1 = 0.446 vs. 0.099
# Precision = 0.379 vs. 0.052
# Recall = 0.543 vs. 0.891
# Minibatch Loss= 0.002323
# Training: 7200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.134
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 1.000
# Validation: 7200
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.058
# F1 = 0.709 vs. 0.081
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.053
# F1 = 0.444 vs. 0.098
# Precision = 0.362 vs. 0.052
# Recall = 0.571 vs. 0.909
# Minibatch Loss= 0.001341
# Training: 7300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.185
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.985
# Validation: 7300
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.060
# F1 = 0.709 vs. 0.081
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.052
# F1 = 0.444 vs. 0.104
# Precision = 0.358 vs. 0.055
# Recall = 0.587 vs. 0.836
# Minibatch Loss= 0.001383
# Training: 7400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.169
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.964
# Validation: 7400
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.058
# F1 = 0.709 vs. 0.081
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.054
# F1 = 0.445 vs. 0.100
# Precision = 0.353 vs. 0.055
# Recall = 0.603 vs. 0.579
# Minibatch Loss= 0.001081
# Training: 7500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.088
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.170
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.913
# Validation: 7500
# ACTIVITY RECOGNITION
# AUC = 0.698 vs. 0.058
# F1 = 0.709 vs. 0.081
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.051
# F1 = 0.442 vs. 0.096
# Precision = 0.348 vs. 0.051
# Recall = 0.605 vs. 0.966
# Minibatch Loss= 0.001160
# Training: 7600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.110
# F1 = 1.000 vs. 0.188
# Precision = 1.000 vs. 0.104
# Recall = 1.000 vs. 0.988
# Validation: 7600
# ACTIVITY RECOGNITION
# AUC = 0.698 vs. 0.059
# F1 = 0.709 vs. 0.081
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.054
# F1 = 0.442 vs. 0.104
# Precision = 0.348 vs. 0.059
# Recall = 0.605 vs. 0.444
# Minibatch Loss= 0.001177
# Training: 7700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.170
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.919
# Validation: 7700
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.058
# F1 = 0.710 vs. 0.080
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.047
# F1 = 0.443 vs. 0.098
# Precision = 0.355 vs. 0.053
# Recall = 0.590 vs. 0.774
# Minibatch Loss= 0.000731
# Training: 7800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.897
# Validation: 7800
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.059
# F1 = 0.709 vs. 0.081
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.054
# F1 = 0.442 vs. 0.104
# Precision = 0.363 vs. 0.056
# Recall = 0.564 vs. 0.730
# Minibatch Loss= 0.000799
# Training: 7900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.117
# F1 = 1.000 vs. 0.191
# Precision = 1.000 vs. 0.105
# Recall = 1.000 vs. 1.000
# Validation: 7900
# ACTIVITY RECOGNITION
# AUC = 0.694 vs. 0.058
# F1 = 0.709 vs. 0.079
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.052
# F1 = 0.442 vs. 0.101
# Precision = 0.363 vs. 0.055
# Recall = 0.566 vs. 0.691
# Minibatch Loss= 0.000732
# Training: 8000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.111
# F1 = 1.000 vs. 0.193
# Precision = 1.000 vs. 0.107
# Recall = 1.000 vs. 0.995
# Validation: 8000
# ACTIVITY RECOGNITION
# AUC = 0.694 vs. 0.058
# F1 = 0.709 vs. 0.077
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.052
# F1 = 0.442 vs. 0.100
# Precision = 0.363 vs. 0.054
# Recall = 0.566 vs. 0.764
# Minibatch Loss= 0.000711
# Training: 8100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.865
# Validation: 8100
# ACTIVITY RECOGNITION
# AUC = 0.693 vs. 0.059
# F1 = 0.709 vs. 0.082
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.049
# F1 = 0.442 vs. 0.098
# Precision = 0.357 vs. 0.052
# Recall = 0.579 vs. 0.906
# Minibatch Loss= 0.000541
# Training: 8200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.175
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.953
# Validation: 8200
# ACTIVITY RECOGNITION
# AUC = 0.692 vs. 0.059
# F1 = 0.710 vs. 0.079
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.049
# F1 = 0.445 vs. 0.098
# Precision = 0.360 vs. 0.052
# Recall = 0.582 vs. 0.977
# Minibatch Loss= 0.000494
# Training: 8300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.998
# Validation: 8300
# ACTIVITY RECOGNITION
# AUC = 0.692 vs. 0.059
# F1 = 0.709 vs. 0.081
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.050
# F1 = 0.444 vs. 0.098
# Precision = 0.362 vs. 0.052
# Recall = 0.574 vs. 0.823
# Minibatch Loss= 0.000462
# Training: 8400
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.063
# F1 = 0.926 vs. 0.095
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.791 vs. 0.100
# F1 = 0.739 vs. 0.183
# Precision = 0.710 vs. 0.100
# Recall = 0.769 vs. 0.998
# Validation: 8400
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.058
# F1 = 0.623 vs. 0.078
# Accuracy = 0.805 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.054
# F1 = 0.377 vs. 0.097
# Precision = 0.303 vs. 0.051
# Recall = 0.499 vs. 1.000
# Minibatch Loss= 0.081655
# Training: 8500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.091
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.091
# F1 = 0.992 vs. 0.162
# Precision = 0.984 vs. 0.088
# Recall = 1.000 vs. 0.984
# Validation: 8500
# ACTIVITY RECOGNITION
# AUC = 0.720 vs. 0.059
# F1 = 0.724 vs. 0.080
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.386 vs. 0.051
# F1 = 0.442 vs. 0.096
# Precision = 0.376 vs. 0.051
# Recall = 0.538 vs. 1.000
# Minibatch Loss= 0.006802
# Training: 8600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 0.998 vs. 0.162
# Precision = 0.996 vs. 0.089
# Recall = 1.000 vs. 0.914
# Validation: 8600
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.059
# F1 = 0.722 vs. 0.083
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.047
# F1 = 0.444 vs. 0.096
# Precision = 0.380 vs. 0.051
# Recall = 0.532 vs. 1.000
# Minibatch Loss= 0.002470
# Training: 8700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.169
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.949
# Validation: 8700
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.058
# F1 = 0.722 vs. 0.079
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.389 vs. 0.048
# F1 = 0.452 vs. 0.096
# Precision = 0.401 vs. 0.051
# Recall = 0.517 vs. 1.000
# Minibatch Loss= 0.001793
# Training: 8800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.105
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.732
# Validation: 8800
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.722 vs. 0.082
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.392 vs. 0.058
# F1 = 0.457 vs. 0.101
# Precision = 0.405 vs. 0.060
# Recall = 0.525 vs. 0.312
# Minibatch Loss= 0.001693
# Training: 8900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.157
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.981
# Validation: 8900
# ACTIVITY RECOGNITION
# AUC = 0.709 vs. 0.058
# F1 = 0.722 vs. 0.079
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.393 vs. 0.050
# F1 = 0.453 vs. 0.099
# Precision = 0.425 vs. 0.053
# Recall = 0.486 vs. 0.826
# Minibatch Loss= 0.001020
# Training: 9000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.991
# Validation: 9000
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.058
# F1 = 0.724 vs. 0.079
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.392 vs. 0.053
# F1 = 0.454 vs. 0.097
# Precision = 0.414 vs. 0.051
# Recall = 0.501 vs. 0.943
# Minibatch Loss= 0.000857
# Training: 9100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.748
# Validation: 9100
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.058
# F1 = 0.725 vs. 0.080
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.050
# F1 = 0.451 vs. 0.098
# Precision = 0.407 vs. 0.051
# Recall = 0.506 vs. 0.971
# Minibatch Loss= 0.000666
# Training: 9200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.678
# Validation: 9200
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.058
# F1 = 0.727 vs. 0.078
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.048
# F1 = 0.450 vs. 0.097
# Precision = 0.418 vs. 0.051
# Recall = 0.488 vs. 0.855
# Minibatch Loss= 0.000578
# Training: 9300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.111
# F1 = 1.000 vs. 0.193
# Precision = 1.000 vs. 0.110
# Recall = 1.000 vs. 0.764
# Validation: 9300
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.059
# F1 = 0.727 vs. 0.080
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.054
# F1 = 0.447 vs. 0.102
# Precision = 0.414 vs. 0.056
# Recall = 0.486 vs. 0.569
# Minibatch Loss= 0.000660
# Training: 9400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.108
# F1 = 1.000 vs. 0.190
# Precision = 1.000 vs. 0.105
# Recall = 1.000 vs. 0.989
# Validation: 9400
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.727 vs. 0.082
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.052
# F1 = 0.445 vs. 0.097
# Precision = 0.435 vs. 0.051
# Recall = 0.455 vs. 0.938
# Minibatch Loss= 0.000542
# Training: 9500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.956
# Validation: 9500
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.058
# F1 = 0.727 vs. 0.081
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.054
# F1 = 0.442 vs. 0.096
# Precision = 0.419 vs. 0.051
# Recall = 0.468 vs. 1.000
# Minibatch Loss= 0.000483
# Training: 9600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.177
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 0.953
# Validation: 9600
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.060
# F1 = 0.728 vs. 0.081
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.051
# F1 = 0.443 vs. 0.096
# Precision = 0.447 vs. 0.051
# Recall = 0.439 vs. 0.995
# Minibatch Loss= 0.000440
# Training: 9700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.107
# F1 = 1.000 vs. 0.197
# Precision = 1.000 vs. 0.109
# Recall = 1.000 vs. 0.994
# Validation: 9700
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.059
# F1 = 0.728 vs. 0.082
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.389 vs. 0.050
# F1 = 0.446 vs. 0.099
# Precision = 0.453 vs. 0.052
# Recall = 0.439 vs. 0.896
# Minibatch Loss= 0.000440
# Training: 9800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.879
# Validation: 9800
# ACTIVITY RECOGNITION
# AUC = 0.712 vs. 0.059
# F1 = 0.728 vs. 0.082
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.053
# F1 = 0.447 vs. 0.098
# Precision = 0.461 vs. 0.052
# Recall = 0.434 vs. 0.844
# Minibatch Loss= 0.000324
# Training: 9900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.188
# Precision = 1.000 vs. 0.104
# Recall = 1.000 vs. 1.000
# Validation: 9900
# ACTIVITY RECOGNITION
# AUC = 0.712 vs. 0.059
# F1 = 0.728 vs. 0.080
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.049
# F1 = 0.447 vs. 0.096
# Precision = 0.460 vs. 0.051
# Recall = 0.434 vs. 1.000
# Minibatch Loss= 0.000321
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/HRNN_NewWavelet_Wmultitask_16_opp_20K_2/HRNN_NewWavelet_Wmultitask_16_opp_20K_2-10000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, checkpoint_path+'-10000')
# Out:
# INFO:tensorflow:Restoring parameters from ../../model/HRNN_NewWavelet_Wmultitask_16_opp/HRNN_NewWavelet_Wmultitask_16_opp-10000

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.059
# F1 = 0.729 vs. 0.083
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.052
# F1 = 0.444 vs. 0.096
# Precision = 0.448 vs. 0.051
# Recall = 0.439 vs. 1.000

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1

# %%
2
