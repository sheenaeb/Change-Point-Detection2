# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_Wmultitask_16_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
from models.HRNN_model import Model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 7    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[3, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu

lstm_n_hidden = 64
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)
# Out:
# 7
# Tensor("Squeeze_20:0", shape=(?, ?, 32), dtype=float32)
# Tensor("Squeeze_20:0", shape=(?, ?, 32), dtype=float32) Tensor("zeros:0", shape=(?, ?, 64), dtype=float32) 6
# Tensor("Squeeze_17:0", shape=(?, ?, 32), dtype=float32) Tensor("Reshape:0", shape=(?, ?, ?), dtype=float32) 5
# Tensor("Squeeze_14:0", shape=(?, ?, 32), dtype=float32) Tensor("Reshape_1:0", shape=(?, ?, ?), dtype=float32) 4
# Tensor("Squeeze_11:0", shape=(?, ?, 32), dtype=float32) Tensor("Reshape_2:0", shape=(?, ?, ?), dtype=float32) 3
# Tensor("Squeeze_8:0", shape=(?, ?, 32), dtype=float32) Tensor("Reshape_3:0", shape=(?, ?, ?), dtype=float32) 2
# Tensor("Squeeze_5:0", shape=(?, ?, 32), dtype=float32) Tensor("Reshape_4:0", shape=(?, ?, ?), dtype=float32) 1
# Tensor("Squeeze_2:0", shape=(?, ?, 32), dtype=float32) Tensor("Reshape_5:0", shape=(?, ?, ?), dtype=float32) 0
# Tensor("Squeeze_21:0", shape=(?, ?, 19), dtype=float32) Tensor("Reshape_8:0", shape=(?, ?, 19), dtype=float32)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.102 vs. 0.093
# Accuracy = 0.019 vs. 0.056
# CHANGE DETECTION
# AUC = 0.075 vs. 0.112
# F1 = 0.186 vs. 0.186
# Precision = 0.103 vs. 0.103
# Recall = 0.995 vs. 1.000
# Validation: 0
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.058
# F1 = 0.083 vs. 0.080
# Accuracy = 0.001 vs. 0.056
# CHANGE DETECTION
# AUC = 0.032 vs. 0.059
# F1 = 0.096 vs. 0.109
# Precision = 0.051 vs. 0.061
# Recall = 1.000 vs. 0.512
# Minibatch Loss= 1.405988
# Training: 100
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.062
# F1 = 0.594 vs. 0.092
# Accuracy = 0.724 vs. 0.056
# CHANGE DETECTION
# AUC = 0.226 vs. 0.094
# F1 = 0.331 vs. 0.169
# Precision = 0.215 vs. 0.093
# Recall = 0.716 vs. 0.950
# Validation: 100
# ACTIVITY RECOGNITION
# AUC = 0.357 vs. 0.058
# F1 = 0.424 vs. 0.079
# Accuracy = 0.753 vs. 0.056
# CHANGE DETECTION
# AUC = 0.149 vs. 0.055
# F1 = 0.245 vs. 0.098
# Precision = 0.167 vs. 0.052
# Recall = 0.457 vs. 0.792
# Minibatch Loss= 0.401942
# Training: 200
# ACTIVITY RECOGNITION
# AUC = 0.723 vs. 0.059
# F1 = 0.709 vs. 0.086
# Accuracy = 0.777 vs. 0.056
# CHANGE DETECTION
# AUC = 0.220 vs. 0.074
# F1 = 0.334 vs. 0.141
# Precision = 0.226 vs. 0.076
# Recall = 0.641 vs. 0.955
# Validation: 200
# ACTIVITY RECOGNITION
# AUC = 0.459 vs. 0.059
# F1 = 0.500 vs. 0.081
# Accuracy = 0.763 vs. 0.056
# CHANGE DETECTION
# AUC = 0.164 vs. 0.049
# F1 = 0.261 vs. 0.096
# Precision = 0.161 vs. 0.051
# Recall = 0.683 vs. 0.997
# Minibatch Loss= 0.240152
# Training: 300
# ACTIVITY RECOGNITION
# AUC = 0.820 vs. 0.061
# F1 = 0.779 vs. 0.092
# Accuracy = 0.829 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.101
# F1 = 0.380 vs. 0.188
# Precision = 0.266 vs. 0.104
# Recall = 0.663 vs. 0.958
# Validation: 300
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.059
# F1 = 0.551 vs. 0.081
# Accuracy = 0.813 vs. 0.056
# CHANGE DETECTION
# AUC = 0.179 vs. 0.051
# F1 = 0.282 vs. 0.097
# Precision = 0.182 vs. 0.051
# Recall = 0.626 vs. 1.000
# Minibatch Loss= 0.217686
# Training: 400
# ACTIVITY RECOGNITION
# AUC = 0.893 vs. 0.062
# F1 = 0.833 vs. 0.092
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.341 vs. 0.090
# F1 = 0.416 vs. 0.174
# Precision = 0.314 vs. 0.095
# Recall = 0.613 vs. 0.967
# Validation: 400
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.059
# F1 = 0.566 vs. 0.082
# Accuracy = 0.823 vs. 0.056
# CHANGE DETECTION
# AUC = 0.197 vs. 0.056
# F1 = 0.298 vs. 0.101
# Precision = 0.201 vs. 0.054
# Recall = 0.571 vs. 0.675
# Minibatch Loss= 0.156226
# Training: 500
# ACTIVITY RECOGNITION
# AUC = 0.889 vs. 0.062
# F1 = 0.840 vs. 0.093
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.367 vs. 0.101
# F1 = 0.420 vs. 0.180
# Precision = 0.322 vs. 0.100
# Recall = 0.601 vs. 0.924
# Validation: 500
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.058
# F1 = 0.598 vs. 0.079
# Accuracy = 0.793 vs. 0.056
# CHANGE DETECTION
# AUC = 0.195 vs. 0.055
# F1 = 0.304 vs. 0.100
# Precision = 0.208 vs. 0.053
# Recall = 0.561 vs. 0.847
# Minibatch Loss= 0.154930
# Training: 600
# ACTIVITY RECOGNITION
# AUC = 0.898 vs. 0.060
# F1 = 0.855 vs. 0.088
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.089
# F1 = 0.470 vs. 0.169
# Precision = 0.357 vs. 0.093
# Recall = 0.685 vs. 0.934
# Validation: 600
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.059
# F1 = 0.617 vs. 0.083
# Accuracy = 0.816 vs. 0.056
# CHANGE DETECTION
# AUC = 0.218 vs. 0.054
# F1 = 0.330 vs. 0.097
# Precision = 0.238 vs. 0.051
# Recall = 0.535 vs. 1.000
# Minibatch Loss= 0.114760
# Training: 700
# ACTIVITY RECOGNITION
# AUC = 0.928 vs. 0.061
# F1 = 0.879 vs. 0.090
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.413 vs. 0.098
# F1 = 0.462 vs. 0.173
# Precision = 0.364 vs. 0.095
# Recall = 0.633 vs. 0.935
# Validation: 700
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.058
# F1 = 0.613 vs. 0.078
# Accuracy = 0.845 vs. 0.056
# CHANGE DETECTION
# AUC = 0.223 vs. 0.050
# F1 = 0.327 vs. 0.100
# Precision = 0.227 vs. 0.053
# Recall = 0.587 vs. 0.740
# Minibatch Loss= 0.119632
# Training: 800
# ACTIVITY RECOGNITION
# AUC = 0.940 vs. 0.061
# F1 = 0.891 vs. 0.089
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.435 vs. 0.090
# F1 = 0.494 vs. 0.163
# Precision = 0.370 vs. 0.089
# Recall = 0.740 vs. 1.000
# Validation: 800
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.058
# F1 = 0.632 vs. 0.078
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.237 vs. 0.046
# F1 = 0.334 vs. 0.097
# Precision = 0.229 vs. 0.051
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 0.099635
# Training: 900
# ACTIVITY RECOGNITION
# AUC = 0.956 vs. 0.064
# F1 = 0.911 vs. 0.095
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.504 vs. 0.098
# F1 = 0.549 vs. 0.181
# Precision = 0.444 vs. 0.100
# Recall = 0.718 vs. 1.000
# Validation: 900
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.059
# F1 = 0.627 vs. 0.082
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.248 vs. 0.048
# F1 = 0.338 vs. 0.100
# Precision = 0.252 vs. 0.053
# Recall = 0.514 vs. 0.800
# Minibatch Loss= 0.096041
# Training: 1000
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.061
# F1 = 0.933 vs. 0.090
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.520 vs. 0.079
# F1 = 0.546 vs. 0.157
# Precision = 0.447 vs. 0.087
# Recall = 0.701 vs. 0.803
# Validation: 1000
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.059
# F1 = 0.640 vs. 0.078
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.261 vs. 0.051
# F1 = 0.352 vs. 0.102
# Precision = 0.243 vs. 0.054
# Recall = 0.642 vs. 0.860
# Minibatch Loss= 0.071765
# Training: 1100
# ACTIVITY RECOGNITION
# AUC = 0.965 vs. 0.061
# F1 = 0.921 vs. 0.087
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.562 vs. 0.087
# F1 = 0.553 vs. 0.156
# Precision = 0.430 vs. 0.092
# Recall = 0.775 vs. 0.509
# Validation: 1100
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.058
# F1 = 0.630 vs. 0.077
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.259 vs. 0.053
# F1 = 0.365 vs. 0.101
# Precision = 0.270 vs. 0.054
# Recall = 0.561 vs. 0.732
# Minibatch Loss= 0.078550
# Training: 1200
# ACTIVITY RECOGNITION
# AUC = 0.965 vs. 0.061
# F1 = 0.933 vs. 0.091
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.614 vs. 0.092
# F1 = 0.605 vs. 0.171
# Precision = 0.512 vs. 0.093
# Recall = 0.739 vs. 0.995
# Validation: 1200
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.059
# F1 = 0.644 vs. 0.079
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.052
# F1 = 0.366 vs. 0.099
# Precision = 0.279 vs. 0.052
# Recall = 0.532 vs. 0.865
# Minibatch Loss= 0.072454
# Training: 1300
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.061
# F1 = 0.940 vs. 0.091
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.625 vs. 0.105
# F1 = 0.637 vs. 0.185
# Precision = 0.543 vs. 0.104
# Recall = 0.771 vs. 0.847
# Validation: 1300
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.058
# F1 = 0.640 vs. 0.080
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.265 vs. 0.053
# F1 = 0.367 vs. 0.101
# Precision = 0.298 vs. 0.055
# Recall = 0.478 vs. 0.587
# Minibatch Loss= 0.073972
# Training: 1400
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.060
# F1 = 0.925 vs. 0.087
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.548 vs. 0.078
# F1 = 0.572 vs. 0.140
# Precision = 0.486 vs. 0.075
# Recall = 0.694 vs. 0.990
# Validation: 1400
# ACTIVITY RECOGNITION
# AUC = 0.645 vs. 0.059
# F1 = 0.657 vs. 0.081
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.053
# F1 = 0.364 vs. 0.101
# Precision = 0.257 vs. 0.055
# Recall = 0.623 vs. 0.647
# Minibatch Loss= 0.067368
# Training: 1500
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.063
# F1 = 0.951 vs. 0.097
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.653 vs. 0.109
# F1 = 0.663 vs. 0.190
# Precision = 0.556 vs. 0.106
# Recall = 0.823 vs. 0.904
# Validation: 1500
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.060
# F1 = 0.641 vs. 0.084
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.052
# F1 = 0.380 vs. 0.097
# Precision = 0.313 vs. 0.051
# Recall = 0.483 vs. 1.000
# Minibatch Loss= 0.065126
# Training: 1600
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.061
# F1 = 0.962 vs. 0.089
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.682 vs. 0.087
# F1 = 0.679 vs. 0.157
# Precision = 0.624 vs. 0.086
# Recall = 0.745 vs. 0.912
# Validation: 1600
# ACTIVITY RECOGNITION
# AUC = 0.638 vs. 0.059
# F1 = 0.637 vs. 0.080
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.050
# F1 = 0.380 vs. 0.098
# Precision = 0.326 vs. 0.052
# Recall = 0.455 vs. 0.870
# Minibatch Loss= 0.049526
# Training: 1700
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.061
# F1 = 0.963 vs. 0.087
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.630 vs. 0.073
# F1 = 0.672 vs. 0.138
# Precision = 0.608 vs. 0.074
# Recall = 0.751 vs. 0.995
# Validation: 1700
# ACTIVITY RECOGNITION
# AUC = 0.638 vs. 0.059
# F1 = 0.635 vs. 0.083
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.050
# F1 = 0.377 vs. 0.097
# Precision = 0.289 vs. 0.051
# Recall = 0.540 vs. 0.974
# Minibatch Loss= 0.041919
# Training: 1800
# ACTIVITY RECOGNITION
# AUC = 0.956 vs. 0.061
# F1 = 0.916 vs. 0.088
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.611 vs. 0.086
# F1 = 0.616 vs. 0.147
# Precision = 0.502 vs. 0.082
# Recall = 0.795 vs. 0.715
# Validation: 1800
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.059
# F1 = 0.643 vs. 0.080
# Accuracy = 0.846 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.054
# F1 = 0.352 vs. 0.097
# Precision = 0.288 vs. 0.051
# Recall = 0.452 vs. 0.953
# Minibatch Loss= 0.067024
# Training: 1900
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.062
# F1 = 0.958 vs. 0.094
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.693 vs. 0.107
# F1 = 0.695 vs. 0.181
# Precision = 0.600 vs. 0.100
# Recall = 0.826 vs. 1.000
# Validation: 1900
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.058
# F1 = 0.660 vs. 0.078
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.049
# F1 = 0.386 vs. 0.097
# Precision = 0.306 vs. 0.051
# Recall = 0.525 vs. 0.971
# Minibatch Loss= 0.055611
# Training: 2000
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.968 vs. 0.094
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.768 vs. 0.103
# F1 = 0.758 vs. 0.188
# Precision = 0.701 vs. 0.104
# Recall = 0.826 vs. 1.000
# Validation: 2000
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.058
# F1 = 0.649 vs. 0.079
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.050
# F1 = 0.382 vs. 0.096
# Precision = 0.306 vs. 0.051
# Recall = 0.506 vs. 0.984
# Minibatch Loss= 0.045942
# Training: 2100
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.061
# F1 = 0.973 vs. 0.092
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.773 vs. 0.104
# F1 = 0.741 vs. 0.182
# Precision = 0.677 vs. 0.100
# Recall = 0.819 vs. 0.989
# Validation: 2100
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.058
# F1 = 0.644 vs. 0.081
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.052
# F1 = 0.379 vs. 0.097
# Precision = 0.316 vs. 0.051
# Recall = 0.475 vs. 1.000
# Minibatch Loss= 0.043360
# Training: 2200
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.061
# F1 = 0.972 vs. 0.092
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.733 vs. 0.081
# F1 = 0.734 vs. 0.153
# Precision = 0.705 vs. 0.083
# Recall = 0.766 vs. 0.940
# Validation: 2200
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.058
# F1 = 0.635 vs. 0.082
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.051
# F1 = 0.378 vs. 0.099
# Precision = 0.281 vs. 0.052
# Recall = 0.577 vs. 0.943
# Minibatch Loss= 0.034475
# Training: 2300
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.060
# F1 = 0.967 vs. 0.089
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.773 vs. 0.087
# F1 = 0.772 vs. 0.160
# Precision = 0.684 vs. 0.088
# Recall = 0.886 vs. 0.870
# Validation: 2300
# ACTIVITY RECOGNITION
# AUC = 0.638 vs. 0.058
# F1 = 0.643 vs. 0.080
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.053
# F1 = 0.373 vs. 0.100
# Precision = 0.301 vs. 0.060
# Recall = 0.491 vs. 0.299
# Minibatch Loss= 0.036294
# Training: 2400
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.061
# F1 = 0.926 vs. 0.093
# Accuracy = 0.947 vs. 0.056
# CHANGE DETECTION
# AUC = 0.668 vs. 0.085
# F1 = 0.649 vs. 0.168
# Precision = 0.608 vs. 0.092
# Recall = 0.695 vs. 0.989
# Validation: 2400
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.058
# F1 = 0.651 vs. 0.077
# Accuracy = 0.852 vs. 0.056
# CHANGE DETECTION
# AUC = 0.250 vs. 0.052
# F1 = 0.341 vs. 0.100
# Precision = 0.254 vs. 0.053
# Recall = 0.517 vs. 0.816
# Minibatch Loss= 0.067415
# Training: 2500
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.972 vs. 0.092
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.717 vs. 0.076
# F1 = 0.711 vs. 0.144
# Precision = 0.610 vs. 0.078
# Recall = 0.853 vs. 1.000
# Validation: 2500
# ACTIVITY RECOGNITION
# AUC = 0.676 vs. 0.059
# F1 = 0.675 vs. 0.079
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.050
# F1 = 0.389 vs. 0.097
# Precision = 0.318 vs. 0.051
# Recall = 0.499 vs. 0.826
# Minibatch Loss= 0.036822
# Training: 2600
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.985 vs. 0.089
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.792 vs. 0.069
# F1 = 0.781 vs. 0.134
# Precision = 0.705 vs. 0.072
# Recall = 0.874 vs. 0.899
# Validation: 2600
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.058
# F1 = 0.657 vs. 0.078
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.048
# F1 = 0.394 vs. 0.098
# Precision = 0.306 vs. 0.052
# Recall = 0.556 vs. 0.912
# Minibatch Loss= 0.025989
# Training: 2700
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.061
# F1 = 0.982 vs. 0.090
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.809 vs. 0.091
# F1 = 0.804 vs. 0.161
# Precision = 0.713 vs. 0.089
# Recall = 0.922 vs. 0.823
# Validation: 2700
# ACTIVITY RECOGNITION
# AUC = 0.659 vs. 0.061
# F1 = 0.651 vs. 0.082
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.051
# F1 = 0.381 vs. 0.097
# Precision = 0.280 vs. 0.052
# Recall = 0.595 vs. 0.769
# Minibatch Loss= 0.028496
# Training: 2800
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.991 vs. 0.089
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.832 vs. 0.091
# F1 = 0.824 vs. 0.154
# Precision = 0.742 vs. 0.088
# Recall = 0.926 vs. 0.623
# Validation: 2800
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.059
# F1 = 0.645 vs. 0.080
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.055
# F1 = 0.383 vs. 0.097
# Precision = 0.287 vs. 0.051
# Recall = 0.577 vs. 0.997
# Minibatch Loss= 0.024428
# Training: 2900
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.982 vs. 0.089
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.843 vs. 0.078
# F1 = 0.808 vs. 0.154
# Precision = 0.741 vs. 0.084
# Recall = 0.889 vs. 0.989
# Validation: 2900
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.059
# F1 = 0.646 vs. 0.081
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.052
# F1 = 0.368 vs. 0.099
# Precision = 0.279 vs. 0.054
# Recall = 0.540 vs. 0.577
# Minibatch Loss= 0.028247
# Training: 3000
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.988 vs. 0.094
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.874 vs. 0.100
# F1 = 0.854 vs. 0.180
# Precision = 0.805 vs. 0.099
# Recall = 0.908 vs. 0.984
# Validation: 3000
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.058
# F1 = 0.634 vs. 0.077
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.052
# F1 = 0.378 vs. 0.097
# Precision = 0.307 vs. 0.052
# Recall = 0.494 vs. 0.795
# Minibatch Loss= 0.026424
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.991 vs. 0.091
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.894 vs. 0.100
# F1 = 0.868 vs. 0.174
# Precision = 0.807 vs. 0.096
# Recall = 0.940 vs. 0.962
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.058
# F1 = 0.632 vs. 0.079
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.050
# F1 = 0.378 vs. 0.096
# Precision = 0.284 vs. 0.051
# Recall = 0.566 vs. 0.974
# Minibatch Loss= 0.022993
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 0.851 vs. 0.061
# F1 = 0.816 vs. 0.091
# Accuracy = 0.845 vs. 0.056
# CHANGE DETECTION
# AUC = 0.533 vs. 0.101
# F1 = 0.548 vs. 0.177
# Precision = 0.451 vs. 0.099
# Recall = 0.700 vs. 0.845
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.059
# F1 = 0.599 vs. 0.082
# Accuracy = 0.799 vs. 0.056
# CHANGE DETECTION
# AUC = 0.219 vs. 0.051
# F1 = 0.305 vs. 0.097
# Precision = 0.214 vs. 0.051
# Recall = 0.532 vs. 0.922
# Minibatch Loss= 0.156721
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 0.974 vs. 0.063
# F1 = 0.941 vs. 0.093
# Accuracy = 0.950 vs. 0.056
# CHANGE DETECTION
# AUC = 0.735 vs. 0.092
# F1 = 0.706 vs. 0.172
# Precision = 0.612 vs. 0.095
# Recall = 0.834 vs. 0.882
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.058
# F1 = 0.656 vs. 0.080
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.046
# F1 = 0.371 vs. 0.097
# Precision = 0.272 vs. 0.051
# Recall = 0.582 vs. 0.964
# Minibatch Loss= 0.054694
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.060
# F1 = 0.964 vs. 0.086
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.777 vs. 0.080
# F1 = 0.743 vs. 0.148
# Precision = 0.627 vs. 0.081
# Recall = 0.911 vs. 0.903
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.060
# F1 = 0.654 vs. 0.083
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.048
# F1 = 0.385 vs. 0.097
# Precision = 0.299 vs. 0.051
# Recall = 0.540 vs. 0.932
# Minibatch Loss= 0.035327
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.969 vs. 0.090
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.833 vs. 0.097
# F1 = 0.788 vs. 0.178
# Precision = 0.719 vs. 0.098
# Recall = 0.872 vs. 0.997
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.058
# F1 = 0.650 vs. 0.081
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.059
# F1 = 0.374 vs. 0.098
# Precision = 0.268 vs. 0.053
# Recall = 0.623 vs. 0.683
# Minibatch Loss= 0.035931
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.060
# F1 = 0.980 vs. 0.089
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.855 vs. 0.093
# F1 = 0.813 vs. 0.167
# Precision = 0.759 vs. 0.092
# Recall = 0.876 vs. 0.925
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.058
# F1 = 0.653 vs. 0.080
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.054
# F1 = 0.364 vs. 0.100
# Precision = 0.327 vs. 0.053
# Recall = 0.410 vs. 0.795
# Minibatch Loss= 0.031445
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.061
# F1 = 0.975 vs. 0.090
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.879 vs. 0.091
# F1 = 0.826 vs. 0.167
# Precision = 0.777 vs. 0.093
# Recall = 0.882 vs. 0.786
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.059
# F1 = 0.646 vs. 0.084
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.053
# F1 = 0.371 vs. 0.099
# Precision = 0.264 vs. 0.053
# Recall = 0.626 vs. 0.805
# Minibatch Loss= 0.027854
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.986 vs. 0.091
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.899 vs. 0.103
# F1 = 0.879 vs. 0.183
# Precision = 0.823 vs. 0.101
# Recall = 0.945 vs. 0.965
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.058
# F1 = 0.634 vs. 0.080
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.051
# F1 = 0.373 vs. 0.097
# Precision = 0.274 vs. 0.051
# Recall = 0.584 vs. 0.906
# Minibatch Loss= 0.024144
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.992 vs. 0.092
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.923 vs. 0.096
# F1 = 0.883 vs. 0.169
# Precision = 0.822 vs. 0.093
# Recall = 0.955 vs. 0.916
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.057
# F1 = 0.635 vs. 0.077
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.053
# F1 = 0.380 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.569 vs. 0.997
# Minibatch Loss= 0.021086
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.993 vs. 0.088
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.952 vs. 0.084
# F1 = 0.889 vs. 0.153
# Precision = 0.870 vs. 0.083
# Recall = 0.909 vs. 0.994
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.059
# F1 = 0.640 vs. 0.081
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.051
# F1 = 0.381 vs. 0.099
# Precision = 0.296 vs. 0.053
# Recall = 0.535 vs. 0.831
# Minibatch Loss= 0.017270
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.993 vs. 0.093
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.098
# F1 = 0.913 vs. 0.181
# Precision = 0.873 vs. 0.099
# Recall = 0.956 vs. 0.998
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.058
# F1 = 0.636 vs. 0.079
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.053
# F1 = 0.376 vs. 0.102
# Precision = 0.291 vs. 0.057
# Recall = 0.530 vs. 0.442
# Minibatch Loss= 0.018000
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.994 vs. 0.092
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.096
# F1 = 0.922 vs. 0.181
# Precision = 0.890 vs. 0.101
# Recall = 0.957 vs. 0.884
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.059
# F1 = 0.632 vs. 0.083
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.058
# F1 = 0.366 vs. 0.102
# Precision = 0.261 vs. 0.055
# Recall = 0.610 vs. 0.681
# Minibatch Loss= 0.015862
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 0.838 vs. 0.062
# F1 = 0.806 vs. 0.091
# Accuracy = 0.835 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.107
# F1 = 0.639 vs. 0.192
# Precision = 0.595 vs. 0.109
# Recall = 0.691 vs. 0.798
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.059
# F1 = 0.580 vs. 0.079
# Accuracy = 0.752 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.050
# F1 = 0.336 vs. 0.097
# Precision = 0.249 vs. 0.051
# Recall = 0.517 vs. 0.925
# Minibatch Loss= 0.206937
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.062
# F1 = 0.968 vs. 0.091
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.862 vs. 0.101
# F1 = 0.808 vs. 0.181
# Precision = 0.749 vs. 0.103
# Recall = 0.877 vs. 0.733
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.059
# F1 = 0.691 vs. 0.081
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.053
# F1 = 0.388 vs. 0.097
# Precision = 0.291 vs. 0.051
# Recall = 0.582 vs. 0.943
# Minibatch Loss= 0.034268
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.986 vs. 0.094
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.912 vs. 0.101
# F1 = 0.860 vs. 0.177
# Precision = 0.786 vs. 0.097
# Recall = 0.948 vs. 0.956
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.059
# F1 = 0.678 vs. 0.082
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.051
# F1 = 0.381 vs. 0.097
# Precision = 0.330 vs. 0.051
# Recall = 0.449 vs. 0.953
# Minibatch Loss= 0.021976
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.988 vs. 0.087
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.945 vs. 0.096
# F1 = 0.899 vs. 0.170
# Precision = 0.855 vs. 0.098
# Recall = 0.947 vs. 0.651
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.059
# F1 = 0.671 vs. 0.082
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.315 vs. 0.054
# F1 = 0.384 vs. 0.097
# Precision = 0.348 vs. 0.051
# Recall = 0.429 vs. 0.995
# Minibatch Loss= 0.018106
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.994 vs. 0.089
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.086
# F1 = 0.920 vs. 0.164
# Precision = 0.882 vs. 0.090
# Recall = 0.961 vs. 0.952
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.059
# F1 = 0.669 vs. 0.080
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.052
# F1 = 0.374 vs. 0.097
# Precision = 0.309 vs. 0.051
# Recall = 0.475 vs. 0.977
# Minibatch Loss= 0.015017
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.996 vs. 0.093
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.950 vs. 0.096
# F1 = 0.923 vs. 0.179
# Precision = 0.868 vs. 0.101
# Recall = 0.985 vs. 0.785
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.649 vs. 0.059
# F1 = 0.655 vs. 0.082
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.052
# F1 = 0.374 vs. 0.097
# Precision = 0.314 vs. 0.051
# Recall = 0.462 vs. 0.992
# Minibatch Loss= 0.015330
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.994 vs. 0.092
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.081
# F1 = 0.938 vs. 0.156
# Precision = 0.903 vs. 0.085
# Recall = 0.976 vs. 0.948
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.058
# F1 = 0.656 vs. 0.081
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.054
# F1 = 0.379 vs. 0.109
# Precision = 0.316 vs. 0.062
# Recall = 0.473 vs. 0.449
# Minibatch Loss= 0.013596
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.996 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.108
# F1 = 0.944 vs. 0.189
# Precision = 0.918 vs. 0.104
# Recall = 0.972 vs. 1.000
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.645 vs. 0.059
# F1 = 0.651 vs. 0.078
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.050
# F1 = 0.370 vs. 0.098
# Precision = 0.281 vs. 0.051
# Recall = 0.540 vs. 0.943
# Minibatch Loss= 0.014398
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.996 vs. 0.091
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.088
# F1 = 0.959 vs. 0.162
# Precision = 0.932 vs. 0.092
# Recall = 0.989 vs. 0.672
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.058
# F1 = 0.650 vs. 0.080
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.050
# F1 = 0.374 vs. 0.097
# Precision = 0.307 vs. 0.051
# Recall = 0.478 vs. 0.997
# Minibatch Loss= 0.010496
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 0.952 vs. 0.064
# F1 = 0.906 vs. 0.097
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.737 vs. 0.111
# F1 = 0.691 vs. 0.197
# Precision = 0.597 vs. 0.109
# Recall = 0.819 vs. 1.000
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.059
# F1 = 0.626 vs. 0.083
# Accuracy = 0.847 vs. 0.056
# CHANGE DETECTION
# AUC = 0.261 vs. 0.053
# F1 = 0.360 vs. 0.099
# Precision = 0.266 vs. 0.056
# Recall = 0.558 vs. 0.397
# Minibatch Loss= 0.106712
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.060
# F1 = 0.977 vs. 0.090
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.888 vs. 0.085
# F1 = 0.840 vs. 0.158
# Precision = 0.777 vs. 0.086
# Recall = 0.913 vs. 0.958
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.059
# F1 = 0.678 vs. 0.077
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.050
# F1 = 0.377 vs. 0.097
# Precision = 0.312 vs. 0.051
# Recall = 0.475 vs. 0.982
# Minibatch Loss= 0.023778
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.062
# F1 = 0.990 vs. 0.095
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.951 vs. 0.111
# F1 = 0.910 vs. 0.201
# Precision = 0.863 vs. 0.113
# Recall = 0.963 vs. 0.953
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.059
# F1 = 0.680 vs. 0.082
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.049
# F1 = 0.381 vs. 0.097
# Precision = 0.300 vs. 0.051
# Recall = 0.522 vs. 0.992
# Minibatch Loss= 0.020249
# Training: 5500
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.994 vs. 0.089
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.962 vs. 0.089
# F1 = 0.943 vs. 0.161
# Precision = 0.906 vs. 0.088
# Recall = 0.982 vs. 1.000
# Validation: 5500
# ACTIVITY RECOGNITION
# AUC = 0.678 vs. 0.059
# F1 = 0.681 vs. 0.080
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.052
# F1 = 0.369 vs. 0.099
# Precision = 0.279 vs. 0.052
# Recall = 0.545 vs. 0.899
# Minibatch Loss= 0.013229
# Training: 5600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.064
# F1 = 0.994 vs. 0.096
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.970 vs. 0.105
# F1 = 0.940 vs. 0.189
# Precision = 0.904 vs. 0.108
# Recall = 0.980 vs. 0.773
# Validation: 5600
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.059
# F1 = 0.681 vs. 0.081
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.053
# F1 = 0.369 vs. 0.104
# Precision = 0.272 vs. 0.056
# Recall = 0.571 vs. 0.675
# Minibatch Loss= 0.014905
# Training: 5700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.091
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.084
# F1 = 0.964 vs. 0.165
# Precision = 0.951 vs. 0.090
# Recall = 0.977 vs. 0.995
# Validation: 5700
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.059
# F1 = 0.681 vs. 0.081
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.051
# F1 = 0.366 vs. 0.096
# Precision = 0.281 vs. 0.051
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 0.009306
# Training: 5800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.996 vs. 0.091
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.979 vs. 0.088
# F1 = 0.958 vs. 0.162
# Precision = 0.934 vs. 0.088
# Recall = 0.984 vs. 1.000
# Validation: 5800
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.058
# F1 = 0.680 vs. 0.079
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.057
# F1 = 0.370 vs. 0.105
# Precision = 0.339 vs. 0.059
# Recall = 0.408 vs. 0.491
# Minibatch Loss= 0.009842
# Training: 5900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.997 vs. 0.096
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.107
# F1 = 0.976 vs. 0.186
# Precision = 0.959 vs. 0.105
# Recall = 0.993 vs. 0.803
# Validation: 5900
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.058
# F1 = 0.677 vs. 0.078
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.049
# F1 = 0.368 vs. 0.097
# Precision = 0.342 vs. 0.051
# Recall = 0.397 vs. 0.997
# Minibatch Loss= 0.009083
# Training: 6000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.092
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.088
# F1 = 0.970 vs. 0.167
# Precision = 0.949 vs. 0.091
# Recall = 0.991 vs. 0.990
# Validation: 6000
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.059
# F1 = 0.677 vs. 0.080
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.051
# F1 = 0.363 vs. 0.100
# Precision = 0.297 vs. 0.054
# Recall = 0.468 vs. 0.717
# Minibatch Loss= 0.008566
# Training: 6100
# ACTIVITY RECOGNITION
# AUC = 0.774 vs. 0.060
# F1 = 0.751 vs. 0.090
# Accuracy = 0.790 vs. 0.056
# CHANGE DETECTION
# AUC = 0.496 vs. 0.091
# F1 = 0.526 vs. 0.162
# Precision = 0.445 vs. 0.088
# Recall = 0.642 vs. 0.982
# Validation: 6100
# ACTIVITY RECOGNITION
# AUC = 0.451 vs. 0.058
# F1 = 0.518 vs. 0.079
# Accuracy = 0.753 vs. 0.056
# CHANGE DETECTION
# AUC = 0.204 vs. 0.050
# F1 = 0.287 vs. 0.097
# Precision = 0.189 vs. 0.051
# Recall = 0.595 vs. 0.925
# Minibatch Loss= 0.259125
# Training: 6200
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.061
# F1 = 0.974 vs. 0.094
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.907 vs. 0.099
# F1 = 0.845 vs. 0.180
# Precision = 0.820 vs. 0.100
# Recall = 0.872 vs. 0.941
# Validation: 6200
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.058
# F1 = 0.651 vs. 0.079
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.054
# F1 = 0.385 vs. 0.103
# Precision = 0.320 vs. 0.057
# Recall = 0.483 vs. 0.579
# Minibatch Loss= 0.026400
# Training: 6300
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.991 vs. 0.085
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.954 vs. 0.076
# F1 = 0.909 vs. 0.144
# Precision = 0.875 vs. 0.078
# Recall = 0.946 vs. 0.940
# Validation: 6300
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.058
# F1 = 0.661 vs. 0.077
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.055
# F1 = 0.373 vs. 0.100
# Precision = 0.319 vs. 0.056
# Recall = 0.449 vs. 0.444
# Minibatch Loss= 0.013377
# Training: 6400
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.995 vs. 0.087
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.065
# F1 = 0.945 vs. 0.132
# Precision = 0.941 vs. 0.071
# Recall = 0.949 vs. 1.000
# Validation: 6400
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.058
# F1 = 0.656 vs. 0.077
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.049
# F1 = 0.371 vs. 0.097
# Precision = 0.308 vs. 0.051
# Recall = 0.465 vs. 0.938
# Minibatch Loss= 0.009592
# Training: 6500
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.991 vs. 0.095
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.970 vs. 0.111
# F1 = 0.930 vs. 0.194
# Precision = 0.885 vs. 0.107
# Recall = 0.979 vs. 0.999
# Validation: 6500
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.059
# F1 = 0.654 vs. 0.079
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.050
# F1 = 0.367 vs. 0.099
# Precision = 0.300 vs. 0.052
# Recall = 0.473 vs. 0.914
# Minibatch Loss= 0.018593
# Training: 6600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.995 vs. 0.094
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.095
# F1 = 0.957 vs. 0.169
# Precision = 0.929 vs. 0.093
# Recall = 0.987 vs. 0.908
# Validation: 6600
# ACTIVITY RECOGNITION
# AUC = 0.669 vs. 0.058
# F1 = 0.672 vs. 0.079
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.055
# F1 = 0.366 vs. 0.101
# Precision = 0.264 vs. 0.055
# Recall = 0.595 vs. 0.595
# Minibatch Loss= 0.010716
# Training: 6700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.998 vs. 0.089
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.084
# F1 = 0.982 vs. 0.150
# Precision = 0.977 vs. 0.081
# Recall = 0.988 vs. 0.951
# Validation: 6700
# ACTIVITY RECOGNITION
# AUC = 0.660 vs. 0.059
# F1 = 0.661 vs. 0.080
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.051
# F1 = 0.367 vs. 0.099
# Precision = 0.353 vs. 0.053
# Recall = 0.382 vs. 0.844
# Minibatch Loss= 0.006994
# Training: 6800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.998 vs. 0.091
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.096
# F1 = 0.978 vs. 0.178
# Precision = 0.960 vs. 0.098
# Recall = 0.997 vs. 0.994
# Validation: 6800
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.058
# F1 = 0.665 vs. 0.079
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.052
# F1 = 0.362 vs. 0.097
# Precision = 0.357 vs. 0.051
# Recall = 0.366 vs. 0.997
# Minibatch Loss= 0.008714
# Training: 6900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.097
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.092
# F1 = 0.987 vs. 0.171
# Precision = 0.977 vs. 0.094
# Recall = 0.997 vs. 1.000
# Validation: 6900
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.058
# F1 = 0.665 vs. 0.078
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.051
# F1 = 0.362 vs. 0.099
# Precision = 0.296 vs. 0.054
# Recall = 0.465 vs. 0.577
# Minibatch Loss= 0.007118
# Training: 7000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.087
# F1 = 0.986 vs. 0.156
# Precision = 0.982 vs. 0.084
# Recall = 0.991 vs. 1.000
# Validation: 7000
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.057
# F1 = 0.663 vs. 0.077
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.052
# F1 = 0.363 vs. 0.098
# Precision = 0.273 vs. 0.053
# Recall = 0.543 vs. 0.579
# Minibatch Loss= 0.005845
# Training: 7100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.086
# F1 = 0.985 vs. 0.161
# Precision = 0.975 vs. 0.088
# Recall = 0.995 vs. 1.000
# Validation: 7100
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.059
# F1 = 0.661 vs. 0.080
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.051
# F1 = 0.364 vs. 0.099
# Precision = 0.273 vs. 0.053
# Recall = 0.545 vs. 0.834
# Minibatch Loss= 0.005876
# Training: 7200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.091
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.084
# F1 = 0.995 vs. 0.161
# Precision = 0.989 vs. 0.088
# Recall = 1.000 vs. 0.968
# Validation: 7200
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.058
# F1 = 0.660 vs. 0.078
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.050
# F1 = 0.367 vs. 0.097
# Precision = 0.279 vs. 0.052
# Recall = 0.535 vs. 0.748
# Minibatch Loss= 0.005317
# Training: 7300
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.060
# F1 = 0.960 vs. 0.091
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.891 vs. 0.099
# F1 = 0.831 vs. 0.177
# Precision = 0.773 vs. 0.102
# Recall = 0.898 vs. 0.661
# Validation: 7300
# ACTIVITY RECOGNITION
# AUC = 0.659 vs. 0.059
# F1 = 0.668 vs. 0.083
# Accuracy = 0.847 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.056
# F1 = 0.381 vs. 0.099
# Precision = 0.349 vs. 0.052
# Recall = 0.418 vs. 0.906
# Minibatch Loss= 0.041119
# Training: 7400
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.997 vs. 0.090
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.094
# F1 = 0.972 vs. 0.165
# Precision = 0.959 vs. 0.091
# Recall = 0.986 vs. 0.881
# Validation: 7400
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.059
# F1 = 0.659 vs. 0.080
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.053
# F1 = 0.369 vs. 0.100
# Precision = 0.338 vs. 0.054
# Recall = 0.405 vs. 0.675
# Minibatch Loss= 0.007733
# Training: 7500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.093
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.111
# F1 = 0.987 vs. 0.187
# Precision = 0.976 vs. 0.103
# Recall = 0.998 vs. 1.000
# Validation: 7500
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.059
# F1 = 0.659 vs. 0.083
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.049
# F1 = 0.373 vs. 0.100
# Precision = 0.324 vs. 0.053
# Recall = 0.439 vs. 0.816
# Minibatch Loss= 0.006674
# Training: 7600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.095
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.105
# F1 = 0.989 vs. 0.177
# Precision = 0.982 vs. 0.097
# Recall = 0.995 vs. 0.995
# Validation: 7600
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.059
# F1 = 0.661 vs. 0.084
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.053
# F1 = 0.373 vs. 0.097
# Precision = 0.335 vs. 0.051
# Recall = 0.421 vs. 0.979
# Minibatch Loss= 0.005546
# Training: 7700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.999 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.079
# F1 = 0.997 vs. 0.157
# Precision = 0.996 vs. 0.085
# Recall = 0.998 vs. 1.000
# Validation: 7700
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.059
# F1 = 0.661 vs. 0.079
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.050
# F1 = 0.378 vs. 0.098
# Precision = 0.324 vs. 0.054
# Recall = 0.455 vs. 0.509
# Minibatch Loss= 0.004382
# Training: 7800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.087
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.088
# F1 = 0.996 vs. 0.158
# Precision = 0.993 vs. 0.087
# Recall = 1.000 vs. 0.934
# Validation: 7800
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.058
# F1 = 0.658 vs. 0.077
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.054
# F1 = 0.376 vs. 0.100
# Precision = 0.295 vs. 0.053
# Recall = 0.519 vs. 0.800
# Minibatch Loss= 0.004083
# Training: 7900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.087
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.075
# F1 = 0.995 vs. 0.149
# Precision = 0.992 vs. 0.081
# Recall = 0.998 vs. 0.939
# Validation: 7900
# ACTIVITY RECOGNITION
# AUC = 0.645 vs. 0.058
# F1 = 0.657 vs. 0.078
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.050
# F1 = 0.380 vs. 0.097
# Precision = 0.303 vs. 0.051
# Recall = 0.509 vs. 0.966
# Minibatch Loss= 0.003328
# Training: 8000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.993 vs. 0.087
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.086
# F1 = 0.958 vs. 0.164
# Precision = 0.946 vs. 0.091
# Recall = 0.970 vs. 0.788
# Validation: 8000
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.058
# F1 = 0.657 vs. 0.079
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.051
# F1 = 0.358 vs. 0.099
# Precision = 0.300 vs. 0.052
# Recall = 0.442 vs. 0.919
# Minibatch Loss= 0.014239
# Training: 8100
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.979 vs. 0.092
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.938 vs. 0.092
# F1 = 0.868 vs. 0.157
# Precision = 0.830 vs. 0.085
# Recall = 0.910 vs. 0.971
# Validation: 8100
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.059
# F1 = 0.661 vs. 0.082
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.048
# F1 = 0.379 vs. 0.096
# Precision = 0.300 vs. 0.051
# Recall = 0.514 vs. 1.000
# Minibatch Loss= 0.021687
# Training: 8200
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.998 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.081
# F1 = 0.985 vs. 0.142
# Precision = 0.976 vs. 0.076
# Recall = 0.994 vs. 0.985
# Validation: 8200
# ACTIVITY RECOGNITION
# AUC = 0.632 vs. 0.060
# F1 = 0.655 vs. 0.083
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.053
# F1 = 0.360 vs. 0.097
# Precision = 0.280 vs. 0.051
# Recall = 0.504 vs. 0.951
# Minibatch Loss= 0.005749
# Training: 8300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.998 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.087
# F1 = 0.996 vs. 0.166
# Precision = 0.995 vs. 0.090
# Recall = 0.997 vs. 1.000
# Validation: 8300
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.058
# F1 = 0.649 vs. 0.080
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.049
# F1 = 0.362 vs. 0.097
# Precision = 0.286 vs. 0.051
# Recall = 0.494 vs. 0.995
# Minibatch Loss= 0.004896
# Training: 8400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.094
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.096
# F1 = 0.995 vs. 0.179
# Precision = 0.991 vs. 0.099
# Recall = 1.000 vs. 0.973
# Validation: 8400
# ACTIVITY RECOGNITION
# AUC = 0.619 vs. 0.059
# F1 = 0.644 vs. 0.082
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.047
# F1 = 0.357 vs. 0.096
# Precision = 0.290 vs. 0.051
# Recall = 0.465 vs. 0.995
# Minibatch Loss= 0.004611
# Training: 8500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.091
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 0.998 vs. 0.159
# Precision = 0.996 vs. 0.087
# Recall = 1.000 vs. 0.904
# Validation: 8500
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.058
# F1 = 0.639 vs. 0.079
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.048
# F1 = 0.356 vs. 0.096
# Precision = 0.303 vs. 0.051
# Recall = 0.431 vs. 1.000
# Minibatch Loss= 0.003888
# Training: 8600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.096
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.100
# F1 = 0.999 vs. 0.191
# Precision = 0.999 vs. 0.106
# Recall = 0.999 vs. 1.000
# Validation: 8600
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.059
# F1 = 0.642 vs. 0.082
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.052
# F1 = 0.357 vs. 0.100
# Precision = 0.302 vs. 0.056
# Recall = 0.436 vs. 0.449
# Minibatch Loss= 0.003815
# Training: 8700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 0.997 vs. 0.158
# Precision = 0.994 vs. 0.089
# Recall = 1.000 vs. 0.683
# Validation: 8700
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.059
# F1 = 0.640 vs. 0.079
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.048
# F1 = 0.355 vs. 0.097
# Precision = 0.270 vs. 0.051
# Recall = 0.514 vs. 0.997
# Minibatch Loss= 0.003448
# Training: 8800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.098
# F1 = 0.997 vs. 0.179
# Precision = 0.993 vs. 0.100
# Recall = 1.000 vs. 0.867
# Validation: 8800
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.059
# F1 = 0.642 vs. 0.084
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.048
# F1 = 0.354 vs. 0.099
# Precision = 0.264 vs. 0.053
# Recall = 0.538 vs. 0.831
# Minibatch Loss= 0.003183
# Training: 8900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 0.999 vs. 0.170
# Precision = 0.998 vs. 0.093
# Recall = 1.000 vs. 0.986
# Validation: 8900
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.058
# F1 = 0.638 vs. 0.079
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.054
# F1 = 0.361 vs. 0.100
# Precision = 0.250 vs. 0.059
# Recall = 0.647 vs. 0.319
# Minibatch Loss= 0.002939
# Training: 9000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 0.998 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.085
# F1 = 0.995 vs. 0.157
# Precision = 0.993 vs. 0.085
# Recall = 0.998 vs. 0.952
# Validation: 9000
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.058
# F1 = 0.631 vs. 0.079
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.048
# F1 = 0.350 vs. 0.096
# Precision = 0.242 vs. 0.051
# Recall = 0.634 vs. 0.997
# Minibatch Loss= 0.003398
# Training: 9100
# ACTIVITY RECOGNITION
# AUC = 0.942 vs. 0.061
# F1 = 0.891 vs. 0.091
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.737 vs. 0.091
# F1 = 0.687 vs. 0.164
# Precision = 0.605 vs. 0.091
# Recall = 0.794 vs. 0.880
# Validation: 9100
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.059
# F1 = 0.638 vs. 0.079
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.051
# F1 = 0.352 vs. 0.097
# Precision = 0.259 vs. 0.051
# Recall = 0.551 vs. 0.997
# Minibatch Loss= 0.077683
# Training: 9200
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.062
# F1 = 0.952 vs. 0.091
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.865 vs. 0.087
# F1 = 0.803 vs. 0.161
# Precision = 0.739 vs. 0.088
# Recall = 0.878 vs. 0.909
# Validation: 9200
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.059
# F1 = 0.647 vs. 0.081
# Accuracy = 0.837 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.051
# F1 = 0.360 vs. 0.099
# Precision = 0.290 vs. 0.055
# Recall = 0.473 vs. 0.517
# Minibatch Loss= 0.039051
# Training: 9300
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.062
# F1 = 0.971 vs. 0.093
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.927 vs. 0.088
# F1 = 0.868 vs. 0.171
# Precision = 0.793 vs. 0.094
# Recall = 0.958 vs. 0.997
# Validation: 9300
# ACTIVITY RECOGNITION
# AUC = 0.646 vs. 0.058
# F1 = 0.652 vs. 0.078
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.049
# F1 = 0.362 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.496 vs. 0.971
# Minibatch Loss= 0.025345
# Training: 9400
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.063
# F1 = 0.990 vs. 0.093
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.083
# F1 = 0.926 vs. 0.152
# Precision = 0.896 vs. 0.082
# Recall = 0.958 vs. 1.000
# Validation: 9400
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.059
# F1 = 0.642 vs. 0.079
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.055
# F1 = 0.362 vs. 0.101
# Precision = 0.267 vs. 0.055
# Recall = 0.561 vs. 0.727
# Minibatch Loss= 0.014252
# Training: 9500
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.060
# F1 = 0.988 vs. 0.087
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.967 vs. 0.099
# F1 = 0.939 vs. 0.169
# Precision = 0.897 vs. 0.093
# Recall = 0.986 vs. 0.924
# Validation: 9500
# ACTIVITY RECOGNITION
# AUC = 0.639 vs. 0.061
# F1 = 0.641 vs. 0.083
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.054
# F1 = 0.364 vs. 0.097
# Precision = 0.271 vs. 0.051
# Recall = 0.553 vs. 0.992
# Minibatch Loss= 0.014790
# Training: 9600
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.989 vs. 0.088
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.967 vs. 0.090
# F1 = 0.949 vs. 0.160
# Precision = 0.924 vs. 0.087
# Recall = 0.975 vs. 0.944
# Validation: 9600
# ACTIVITY RECOGNITION
# AUC = 0.633 vs. 0.059
# F1 = 0.643 vs. 0.081
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.052
# F1 = 0.361 vs. 0.096
# Precision = 0.274 vs. 0.051
# Recall = 0.530 vs. 1.000
# Minibatch Loss= 0.013200
# Training: 9700
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.994 vs. 0.087
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.075
# F1 = 0.964 vs. 0.153
# Precision = 0.945 vs. 0.083
# Recall = 0.983 vs. 0.956
# Validation: 9700
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.059
# F1 = 0.644 vs. 0.080
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.052
# F1 = 0.358 vs. 0.100
# Precision = 0.265 vs. 0.054
# Recall = 0.556 vs. 0.714
# Minibatch Loss= 0.009381
# Training: 9800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.063
# F1 = 0.995 vs. 0.097
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.115
# F1 = 0.974 vs. 0.203
# Precision = 0.957 vs. 0.113
# Recall = 0.992 vs. 0.988
# Validation: 9800
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.058
# F1 = 0.638 vs. 0.081
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.053
# F1 = 0.358 vs. 0.099
# Precision = 0.350 vs. 0.056
# Recall = 0.366 vs. 0.462
# Minibatch Loss= 0.011534
# Training: 9900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.089
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.085
# F1 = 0.988 vs. 0.157
# Precision = 0.983 vs. 0.086
# Recall = 0.993 vs. 0.937
# Validation: 9900
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.059
# F1 = 0.636 vs. 0.082
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.055
# F1 = 0.355 vs. 0.102
# Precision = 0.280 vs. 0.057
# Recall = 0.486 vs. 0.522
# Minibatch Loss= 0.006566
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/HRNN_Wmultitask_16_opp/HRNN_Wmultitask_16_opp-10000'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-4495')
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.634 vs. 0.059
# F1 = 0.641 vs. 0.081
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.057
# F1 = 0.360 vs. 0.100
# Precision = 0.310 vs. 0.053
# Recall = 0.429 vs. 0.756

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2
