# %%
# useing this variable for saving models and summaries
exp_name = "RCNN_Wmultitask_32_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

pooling_stride = [4, 4, 2]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.28595522,  42.44204322,  42.96023857,  45.06666667,
#         44.49794239,  34.32268371,  35.42833608,  50.54312354,
#         54.97974684,  62.17714286,  69.87179487,  66.41463415,
#         71.02605863,  57.96533333,  57.4973545 ,  39.35036496,
#         12.09177028,  47.81236203,   4.77487595])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables = n_variables,
                        n_classes = n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride = pooling_stride,
                         weights_shape = weights_shape,
                         bias_shape = bias_shape,
                         activation = activation,
                         lstm_n_hidden = lstm_n_hidden,
                         n_classes = n_classes,
                         learning_rate = learning_rate,
                         pos_weight = pos_weight,
                         trainable_conv = True,
                         trainable_last = True,
                         variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.065 vs. 0.068
# F1 = 0.100 vs. 0.102
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.189 vs. 0.177
# F1 = 0.312 vs. 0.308
# Precision = 0.187 vs. 0.183
# Recall = 0.945 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.088 vs. 0.092
# Accuracy = 0.002 vs. 0.056
# CHANGE DETECTION
# AUC = 0.106 vs. 0.102
# F1 = 0.194 vs. 0.182
# Precision = 0.122 vs. 0.100
# Recall = 0.475 vs. 0.987
# Minibatch Loss= 1.858710
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.068
# F1 = 0.690 vs. 0.102
# Accuracy = 0.620 vs. 0.056
# CHANGE DETECTION
# AUC = 0.476 vs. 0.192
# F1 = 0.521 vs. 0.319
# Precision = 0.382 vs. 0.190
# Recall = 0.821 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.418 vs. 0.062
# F1 = 0.482 vs. 0.088
# Accuracy = 0.613 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.094
# F1 = 0.383 vs. 0.182
# Precision = 0.274 vs. 0.100
# Recall = 0.636 vs. 1.000
# Minibatch Loss= 0.306922
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.843 vs. 0.067
# F1 = 0.795 vs. 0.103
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.548 vs. 0.158
# F1 = 0.571 vs. 0.256
# Precision = 0.436 vs. 0.149
# Recall = 0.827 vs. 0.889
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.511 vs. 0.062
# F1 = 0.558 vs. 0.093
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.100
# F1 = 0.429 vs. 0.181
# Precision = 0.313 vs. 0.100
# Recall = 0.681 vs. 0.942
# Minibatch Loss= 0.141239
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.913 vs. 0.068
# F1 = 0.873 vs. 0.105
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.643 vs. 0.177
# F1 = 0.651 vs. 0.307
# Precision = 0.589 vs. 0.182
# Recall = 0.729 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.062
# F1 = 0.591 vs. 0.086
# Accuracy = 0.847 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.108
# F1 = 0.481 vs. 0.181
# Precision = 0.370 vs. 0.100
# Recall = 0.686 vs. 1.000
# Minibatch Loss= 0.128080
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.932 vs. 0.069
# F1 = 0.890 vs. 0.105
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.688 vs. 0.174
# F1 = 0.688 vs. 0.309
# Precision = 0.598 vs. 0.183
# Recall = 0.810 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.061
# F1 = 0.605 vs. 0.084
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.420 vs. 0.108
# F1 = 0.502 vs. 0.182
# Precision = 0.381 vs. 0.101
# Recall = 0.734 vs. 0.966
# Minibatch Loss= 0.096673
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.936 vs. 0.066
# F1 = 0.903 vs. 0.099
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.704 vs. 0.176
# F1 = 0.695 vs. 0.282
# Precision = 0.603 vs. 0.164
# Recall = 0.819 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.064
# F1 = 0.602 vs. 0.093
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.444 vs. 0.103
# F1 = 0.519 vs. 0.183
# Precision = 0.409 vs. 0.101
# Recall = 0.710 vs. 1.000
# Minibatch Loss= 0.077984
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.964 vs. 0.066
# F1 = 0.940 vs. 0.100
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.764 vs. 0.191
# F1 = 0.752 vs. 0.311
# Precision = 0.663 vs. 0.184
# Recall = 0.869 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.062
# F1 = 0.606 vs. 0.086
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.443 vs. 0.103
# F1 = 0.515 vs. 0.182
# Precision = 0.415 vs. 0.101
# Recall = 0.678 vs. 0.929
# Minibatch Loss= 0.065646
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.066
# F1 = 0.946 vs. 0.101
# Accuracy = 0.952 vs. 0.056
# CHANGE DETECTION
# AUC = 0.783 vs. 0.191
# F1 = 0.742 vs. 0.317
# Precision = 0.666 vs. 0.189
# Recall = 0.837 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.064
# F1 = 0.600 vs. 0.089
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.444 vs. 0.102
# F1 = 0.496 vs. 0.182
# Precision = 0.424 vs. 0.102
# Recall = 0.599 vs. 0.855
# Minibatch Loss= 0.062697
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.066
# F1 = 0.970 vs. 0.099
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.827 vs. 0.151
# F1 = 0.774 vs. 0.265
# Precision = 0.708 vs. 0.153
# Recall = 0.854 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.062
# F1 = 0.604 vs. 0.088
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.448 vs. 0.099
# F1 = 0.501 vs. 0.181
# Precision = 0.443 vs. 0.100
# Recall = 0.575 vs. 1.000
# Minibatch Loss= 0.043126
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.065
# F1 = 0.984 vs. 0.097
# Accuracy = 0.961 vs. 0.056
# CHANGE DETECTION
# AUC = 0.841 vs. 0.138
# F1 = 0.816 vs. 0.240
# Precision = 0.732 vs. 0.137
# Recall = 0.921 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.063
# F1 = 0.616 vs. 0.088
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.461 vs. 0.101
# F1 = 0.499 vs. 0.182
# Precision = 0.429 vs. 0.100
# Recall = 0.596 vs. 0.987
# Minibatch Loss= 0.034445
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.069
# F1 = 0.983 vs. 0.105
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.201
# F1 = 0.849 vs. 0.311
# Precision = 0.831 vs. 0.184
# Recall = 0.868 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.061
# F1 = 0.603 vs. 0.086
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.458 vs. 0.097
# F1 = 0.494 vs. 0.182
# Precision = 0.423 vs. 0.100
# Recall = 0.594 vs. 1.000
# Minibatch Loss= 0.037117
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.959 vs. 0.067
# F1 = 0.916 vs. 0.100
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.797 vs. 0.164
# F1 = 0.750 vs. 0.280
# Precision = 0.716 vs. 0.163
# Recall = 0.787 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.062
# F1 = 0.630 vs. 0.088
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.477 vs. 0.101
# F1 = 0.526 vs. 0.183
# Precision = 0.460 vs. 0.102
# Recall = 0.615 vs. 0.934
# Minibatch Loss= 0.075869
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.067
# F1 = 0.977 vs. 0.101
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.881 vs. 0.165
# F1 = 0.832 vs. 0.282
# Precision = 0.754 vs. 0.164
# Recall = 0.929 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.062
# F1 = 0.629 vs. 0.086
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.472 vs. 0.098
# F1 = 0.516 vs. 0.181
# Precision = 0.440 vs. 0.100
# Recall = 0.625 vs. 1.000
# Minibatch Loss= 0.037522
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.067
# F1 = 0.985 vs. 0.101
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.926 vs. 0.176
# F1 = 0.866 vs. 0.298
# Precision = 0.798 vs. 0.175
# Recall = 0.946 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.062
# F1 = 0.632 vs. 0.086
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.473 vs. 0.094
# F1 = 0.517 vs. 0.182
# Precision = 0.421 vs. 0.100
# Recall = 0.670 vs. 0.992
# Minibatch Loss= 0.030171
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.992 vs. 0.105
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.922 vs. 0.165
# F1 = 0.878 vs. 0.297
# Precision = 0.837 vs. 0.174
# Recall = 0.923 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.613 vs. 0.063
# F1 = 0.633 vs. 0.092
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.472 vs. 0.120
# F1 = 0.501 vs. 0.183
# Precision = 0.393 vs. 0.101
# Recall = 0.691 vs. 0.942
# Minibatch Loss= 0.025218
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.067
# F1 = 0.991 vs. 0.100
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.953 vs. 0.155
# F1 = 0.910 vs. 0.295
# Precision = 0.855 vs. 0.173
# Recall = 0.973 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.061
# F1 = 0.626 vs. 0.085
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.470 vs. 0.107
# F1 = 0.499 vs. 0.182
# Precision = 0.487 vs. 0.100
# Recall = 0.512 vs. 0.982
# Minibatch Loss= 0.021699
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.068
# F1 = 0.994 vs. 0.104
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.952 vs. 0.179
# F1 = 0.906 vs. 0.307
# Precision = 0.880 vs. 0.182
# Recall = 0.934 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.062
# F1 = 0.635 vs. 0.088
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.479 vs. 0.096
# F1 = 0.509 vs. 0.181
# Precision = 0.508 vs. 0.100
# Recall = 0.509 vs. 1.000
# Minibatch Loss= 0.022710
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.068
# F1 = 0.994 vs. 0.104
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.170
# F1 = 0.933 vs. 0.294
# Precision = 0.908 vs. 0.173
# Recall = 0.960 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.064
# F1 = 0.630 vs. 0.092
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.480 vs. 0.094
# F1 = 0.509 vs. 0.182
# Precision = 0.509 vs. 0.100
# Recall = 0.509 vs. 0.997
# Minibatch Loss= 0.017988
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.065
# F1 = 0.995 vs. 0.096
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.964 vs. 0.180
# F1 = 0.942 vs. 0.304
# Precision = 0.901 vs. 0.179
# Recall = 0.986 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.061
# F1 = 0.631 vs. 0.087
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.095
# F1 = 0.509 vs. 0.182
# Precision = 0.460 vs. 0.101
# Recall = 0.570 vs. 0.950
# Minibatch Loss= 0.017872
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.069
# F1 = 0.951 vs. 0.101
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.162
# F1 = 0.820 vs. 0.273
# Precision = 0.785 vs. 0.160
# Recall = 0.857 vs. 0.944
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.641 vs. 0.063
# F1 = 0.649 vs. 0.091
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.481 vs. 0.098
# F1 = 0.533 vs. 0.183
# Precision = 0.472 vs. 0.102
# Recall = 0.612 vs. 0.892
# Minibatch Loss= 0.047594
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.993 vs. 0.106
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.179
# F1 = 0.938 vs. 0.294
# Precision = 0.926 vs. 0.173
# Recall = 0.951 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.063
# F1 = 0.644 vs. 0.088
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.519 vs. 0.100
# F1 = 0.546 vs. 0.183
# Precision = 0.515 vs. 0.101
# Recall = 0.580 vs. 0.971
# Minibatch Loss= 0.018095
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.066
# F1 = 0.996 vs. 0.099
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.979 vs. 0.188
# F1 = 0.950 vs. 0.312
# Precision = 0.929 vs. 0.185
# Recall = 0.973 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.063
# F1 = 0.628 vs. 0.097
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.511 vs. 0.102
# F1 = 0.530 vs. 0.184
# Precision = 0.489 vs. 0.106
# Recall = 0.578 vs. 0.689
# Minibatch Loss= 0.016130
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 0.998 vs. 0.103
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.172
# F1 = 0.967 vs. 0.296
# Precision = 0.948 vs. 0.173
# Recall = 0.987 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.062
# F1 = 0.628 vs. 0.089
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.507 vs. 0.100
# F1 = 0.521 vs. 0.182
# Precision = 0.468 vs. 0.100
# Recall = 0.588 vs. 1.000
# Minibatch Loss= 0.013112
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.998 vs. 0.104
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.181
# F1 = 0.969 vs. 0.305
# Precision = 0.956 vs. 0.180
# Recall = 0.983 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.062
# F1 = 0.626 vs. 0.084
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.509 vs. 0.111
# F1 = 0.517 vs. 0.181
# Precision = 0.462 vs. 0.100
# Recall = 0.588 vs. 1.000
# Minibatch Loss= 0.011668
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.104
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.178
# F1 = 0.971 vs. 0.309
# Precision = 0.951 vs. 0.184
# Recall = 0.992 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.062
# F1 = 0.626 vs. 0.089
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.503 vs. 0.096
# F1 = 0.509 vs. 0.182
# Precision = 0.486 vs. 0.100
# Recall = 0.536 vs. 0.974
# Minibatch Loss= 0.010544
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.999 vs. 0.099
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.155
# F1 = 0.986 vs. 0.272
# Precision = 0.978 vs. 0.158
# Recall = 0.994 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.063
# F1 = 0.627 vs. 0.097
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.506 vs. 0.096
# F1 = 0.513 vs. 0.182
# Precision = 0.459 vs. 0.100
# Recall = 0.583 vs. 0.992
# Minibatch Loss= 0.007700
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.999 vs. 0.102
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.175
# F1 = 0.991 vs. 0.297
# Precision = 0.986 vs. 0.175
# Recall = 0.996 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.062
# F1 = 0.628 vs. 0.091
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.506 vs. 0.110
# F1 = 0.509 vs. 0.186
# Precision = 0.460 vs. 0.104
# Recall = 0.570 vs. 0.908
# Minibatch Loss= 0.007770
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 0.999 vs. 0.108
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.187
# F1 = 0.989 vs. 0.330
# Precision = 0.990 vs. 0.198
# Recall = 0.987 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.613 vs. 0.063
# F1 = 0.625 vs. 0.087
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.504 vs. 0.096
# F1 = 0.508 vs. 0.182
# Precision = 0.471 vs. 0.100
# Recall = 0.551 vs. 0.995
# Minibatch Loss= 0.007727
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.999 vs. 0.098
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.159
# F1 = 0.985 vs. 0.269
# Precision = 0.974 vs. 0.156
# Recall = 0.996 vs. 0.968
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.063
# F1 = 0.625 vs. 0.089
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.506 vs. 0.096
# F1 = 0.508 vs. 0.181
# Precision = 0.467 vs. 0.100
# Recall = 0.557 vs. 1.000
# Minibatch Loss= 0.005762
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.065
# F1 = 0.948 vs. 0.099
# Accuracy = 0.951 vs. 0.056
# CHANGE DETECTION
# AUC = 0.897 vs. 0.145
# F1 = 0.819 vs. 0.252
# Precision = 0.783 vs. 0.144
# Recall = 0.859 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.646 vs. 0.062
# F1 = 0.644 vs. 0.086
# Accuracy = 0.838 vs. 0.056
# CHANGE DETECTION
# AUC = 0.466 vs. 0.099
# F1 = 0.513 vs. 0.181
# Precision = 0.417 vs. 0.100
# Recall = 0.668 vs. 1.000
# Minibatch Loss= 0.048457
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.068
# F1 = 0.987 vs. 0.099
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.188
# F1 = 0.916 vs. 0.305
# Precision = 0.916 vs. 0.180
# Recall = 0.916 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.063
# F1 = 0.662 vs. 0.095
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.511 vs. 0.094
# F1 = 0.548 vs. 0.182
# Precision = 0.455 vs. 0.100
# Recall = 0.689 vs. 0.976
# Minibatch Loss= 0.023699
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.069
# F1 = 0.996 vs. 0.106
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.192
# F1 = 0.956 vs. 0.317
# Precision = 0.934 vs. 0.188
# Recall = 0.980 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.661 vs. 0.063
# F1 = 0.662 vs. 0.088
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.509 vs. 0.104
# F1 = 0.548 vs. 0.185
# Precision = 0.476 vs. 0.103
# Recall = 0.646 vs. 0.910
# Minibatch Loss= 0.015646
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.066
# F1 = 0.997 vs. 0.099
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.181
# F1 = 0.968 vs. 0.303
# Precision = 0.942 vs. 0.178
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.062
# F1 = 0.667 vs. 0.086
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.508 vs. 0.095
# F1 = 0.536 vs. 0.182
# Precision = 0.451 vs. 0.100
# Recall = 0.662 vs. 0.995
# Minibatch Loss= 0.011926
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.997 vs. 0.102
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.190
# F1 = 0.982 vs. 0.325
# Precision = 0.970 vs. 0.194
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.670 vs. 0.090
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.509 vs. 0.101
# F1 = 0.535 vs. 0.182
# Precision = 0.438 vs. 0.102
# Recall = 0.689 vs. 0.828
# Minibatch Loss= 0.010260
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.999 vs. 0.106
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.181
# F1 = 0.984 vs. 0.309
# Precision = 0.976 vs. 0.183
# Recall = 0.991 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.065
# F1 = 0.663 vs. 0.094
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.508 vs. 0.100
# F1 = 0.533 vs. 0.182
# Precision = 0.437 vs. 0.101
# Recall = 0.681 vs. 0.868
# Minibatch Loss= 0.008517
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.999 vs. 0.100
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.195
# F1 = 0.994 vs. 0.310
# Precision = 0.990 vs. 0.183
# Recall = 0.998 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.062
# F1 = 0.661 vs. 0.087
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.504 vs. 0.102
# F1 = 0.526 vs. 0.183
# Precision = 0.422 vs. 0.101
# Recall = 0.699 vs. 0.971
# Minibatch Loss= 0.006147
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 0.999 vs. 0.105
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.184
# F1 = 0.997 vs. 0.310
# Precision = 0.997 vs. 0.184
# Recall = 0.997 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.644 vs. 0.064
# F1 = 0.656 vs. 0.094
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.503 vs. 0.099
# F1 = 0.533 vs. 0.182
# Precision = 0.461 vs. 0.102
# Recall = 0.633 vs. 0.842
# Minibatch Loss= 0.005483
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.999 vs. 0.098
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.191
# F1 = 0.994 vs. 0.291
# Precision = 0.989 vs. 0.174
# Recall = 1.000 vs. 0.876
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.062
# F1 = 0.652 vs. 0.086
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.498 vs. 0.108
# F1 = 0.527 vs. 0.182
# Precision = 0.446 vs. 0.100
# Recall = 0.644 vs. 0.984
# Minibatch Loss= 0.004751
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.098
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.154
# F1 = 0.997 vs. 0.266
# Precision = 0.993 vs. 0.154
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.064
# F1 = 0.651 vs. 0.091
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.497 vs. 0.101
# F1 = 0.528 vs. 0.182
# Precision = 0.458 vs. 0.100
# Recall = 0.625 vs. 0.995
# Minibatch Loss= 0.004763
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.101
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.174
# F1 = 0.997 vs. 0.295
# Precision = 0.995 vs. 0.173
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.061
# F1 = 0.651 vs. 0.082
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.497 vs. 0.095
# F1 = 0.529 vs. 0.181
# Precision = 0.438 vs. 0.100
# Recall = 0.668 vs. 1.000
# Minibatch Loss= 0.003908
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.162
# F1 = 0.997 vs. 0.283
# Precision = 0.994 vs. 0.165
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.062
# F1 = 0.650 vs. 0.088
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.496 vs. 0.106
# F1 = 0.526 vs. 0.184
# Precision = 0.452 vs. 0.105
# Recall = 0.631 vs. 0.739
# Minibatch Loss= 0.003395
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.104
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.195
# F1 = 0.997 vs. 0.317
# Precision = 0.993 vs. 0.190
# Recall = 1.000 vs. 0.952
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.640 vs. 0.064
# F1 = 0.649 vs. 0.090
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.101
# F1 = 0.527 vs. 0.182
# Precision = 0.461 vs. 0.100
# Recall = 0.615 vs. 0.997
# Minibatch Loss= 0.003362
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.101
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.192
# F1 = 1.000 vs. 0.305
# Precision = 1.000 vs. 0.180
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.639 vs. 0.063
# F1 = 0.648 vs. 0.091
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.493 vs. 0.112
# F1 = 0.527 vs. 0.193
# Precision = 0.448 vs. 0.111
# Recall = 0.639 vs. 0.736
# Minibatch Loss= 0.002754
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.069
# F1 = 0.941 vs. 0.103
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.932 vs. 0.181
# F1 = 0.869 vs. 0.307
# Precision = 0.836 vs. 0.181
# Recall = 0.905 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.062
# F1 = 0.660 vs. 0.086
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.101
# F1 = 0.518 vs. 0.185
# Precision = 0.432 vs. 0.102
# Recall = 0.649 vs. 0.937
# Minibatch Loss= 0.090487
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.999 vs. 0.097
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.171
# F1 = 0.994 vs. 0.269
# Precision = 0.994 vs. 0.156
# Recall = 0.994 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.061
# F1 = 0.679 vs. 0.085
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.492 vs. 0.108
# F1 = 0.526 vs. 0.186
# Precision = 0.477 vs. 0.104
# Recall = 0.586 vs. 0.892
# Minibatch Loss= 0.004597
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.103
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.177
# F1 = 1.000 vs. 0.301
# Precision = 1.000 vs. 0.177
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.665 vs. 0.062
# F1 = 0.674 vs. 0.088
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.099
# F1 = 0.539 vs. 0.183
# Precision = 0.480 vs. 0.101
# Recall = 0.615 vs. 0.976
# Minibatch Loss= 0.003495
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.101
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.176
# F1 = 1.000 vs. 0.292
# Precision = 1.000 vs. 0.173
# Recall = 1.000 vs. 0.936
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.662 vs. 0.063
# F1 = 0.669 vs. 0.093
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.492 vs. 0.109
# F1 = 0.535 vs. 0.185
# Precision = 0.492 vs. 0.111
# Recall = 0.586 vs. 0.559
# Minibatch Loss= 0.002546
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.101
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.154
# F1 = 0.999 vs. 0.269
# Precision = 0.998 vs. 0.155
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.063
# F1 = 0.667 vs. 0.091
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.095
# F1 = 0.533 vs. 0.184
# Precision = 0.473 vs. 0.101
# Recall = 0.612 vs. 0.971
# Minibatch Loss= 0.002116
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.100
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.182
# F1 = 1.000 vs. 0.289
# Precision = 1.000 vs. 0.169
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.063
# F1 = 0.668 vs. 0.090
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.103
# F1 = 0.536 vs. 0.181
# Precision = 0.494 vs. 0.100
# Recall = 0.586 vs. 1.000
# Minibatch Loss= 0.001904
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.172
# F1 = 1.000 vs. 0.277
# Precision = 1.000 vs. 0.162
# Recall = 1.000 vs. 0.939
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.062
# F1 = 0.667 vs. 0.087
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.493 vs. 0.096
# F1 = 0.530 vs. 0.182
# Precision = 0.462 vs. 0.100
# Recall = 0.623 vs. 1.000
# Minibatch Loss= 0.001623
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.110
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.203
# F1 = 1.000 vs. 0.336
# Precision = 1.000 vs. 0.202
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.065
# F1 = 0.667 vs. 0.092
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.493 vs. 0.102
# F1 = 0.533 vs. 0.182
# Precision = 0.490 vs. 0.104
# Recall = 0.583 vs. 0.747
# Minibatch Loss= 0.001793
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.186
# F1 = 1.000 vs. 0.306
# Precision = 1.000 vs. 0.181
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.651 vs. 0.065
# F1 = 0.666 vs. 0.087
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.495 vs. 0.105
# F1 = 0.531 vs. 0.185
# Precision = 0.484 vs. 0.103
# Recall = 0.588 vs. 0.908
# Minibatch Loss= 0.001911
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.152
# F1 = 1.000 vs. 0.262
# Precision = 1.000 vs. 0.151
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.063
# F1 = 0.666 vs. 0.083
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.495 vs. 0.098
# F1 = 0.530 vs. 0.182
# Precision = 0.497 vs. 0.100
# Recall = 0.567 vs. 0.984
# Minibatch Loss= 0.001250
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.178
# F1 = 1.000 vs. 0.296
# Precision = 1.000 vs. 0.174
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.062
# F1 = 0.666 vs. 0.085
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.496 vs. 0.106
# F1 = 0.529 vs. 0.185
# Precision = 0.472 vs. 0.104
# Recall = 0.602 vs. 0.871
# Minibatch Loss= 0.001261
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.165
# F1 = 1.000 vs. 0.279
# Precision = 1.000 vs. 0.162
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.647 vs. 0.062
# F1 = 0.664 vs. 0.089
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.098
# F1 = 0.529 vs. 0.182
# Precision = 0.494 vs. 0.100
# Recall = 0.570 vs. 0.987
# Minibatch Loss= 0.001100
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.101
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.181
# F1 = 1.000 vs. 0.314
# Precision = 1.000 vs. 0.186
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.646 vs. 0.061
# F1 = 0.662 vs. 0.084
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.491 vs. 0.099
# F1 = 0.529 vs. 0.184
# Precision = 0.493 vs. 0.101
# Recall = 0.570 vs. 0.989
# Minibatch Loss= 0.001306
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.154
# F1 = 1.000 vs. 0.272
# Precision = 1.000 vs. 0.158
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.646 vs. 0.062
# F1 = 0.661 vs. 0.085
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.111
# F1 = 0.531 vs. 0.189
# Precision = 0.502 vs. 0.106
# Recall = 0.562 vs. 0.865
# Minibatch Loss= 0.000908
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.173
# F1 = 1.000 vs. 0.291
# Precision = 1.000 vs. 0.170
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.644 vs. 0.062
# F1 = 0.661 vs. 0.086
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.490 vs. 0.097
# F1 = 0.529 vs. 0.181
# Precision = 0.502 vs. 0.100
# Recall = 0.559 vs. 1.000
# Minibatch Loss= 0.000928
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.106
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.186
# F1 = 1.000 vs. 0.317
# Precision = 1.000 vs. 0.188
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.061
# F1 = 0.660 vs. 0.085
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.490 vs. 0.097
# F1 = 0.531 vs. 0.182
# Precision = 0.497 vs. 0.100
# Recall = 0.570 vs. 0.989
# Minibatch Loss= 0.001087
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.184
# F1 = 1.000 vs. 0.307
# Precision = 1.000 vs. 0.181
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.064
# F1 = 0.661 vs. 0.094
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.105
# F1 = 0.532 vs. 0.183
# Precision = 0.499 vs. 0.112
# Recall = 0.570 vs. 0.515
# Minibatch Loss= 0.000837
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.163
# F1 = 1.000 vs. 0.286
# Precision = 1.000 vs. 0.169
# Recall = 1.000 vs. 0.930
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.643 vs. 0.061
# F1 = 0.661 vs. 0.086
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.490 vs. 0.094
# F1 = 0.532 vs. 0.182
# Precision = 0.501 vs. 0.100
# Recall = 0.567 vs. 0.997
# Minibatch Loss= 0.000689
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.911 vs. 0.068
# F1 = 0.883 vs. 0.103
# Accuracy = 0.794 vs. 0.056
# CHANGE DETECTION
# AUC = 0.804 vs. 0.173
# F1 = 0.750 vs. 0.302
# Precision = 0.676 vs. 0.178
# Recall = 0.843 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.063
# F1 = 0.593 vs. 0.088
# Accuracy = 0.725 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.114
# F1 = 0.449 vs. 0.185
# Precision = 0.377 vs. 0.109
# Recall = 0.554 vs. 0.612
# Minibatch Loss= 0.254558
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.994 vs. 0.103
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.181
# F1 = 0.969 vs. 0.311
# Precision = 0.952 vs. 0.185
# Recall = 0.986 vs. 0.962
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.678 vs. 0.062
# F1 = 0.674 vs. 0.085
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.524 vs. 0.106
# F1 = 0.556 vs. 0.182
# Precision = 0.499 vs. 0.100
# Recall = 0.628 vs. 0.955
# Minibatch Loss= 0.014298
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.071
# F1 = 0.998 vs. 0.107
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.200
# F1 = 0.993 vs. 0.328
# Precision = 0.987 vs. 0.196
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.062
# F1 = 0.677 vs. 0.088
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.524 vs. 0.106
# F1 = 0.554 vs. 0.190
# Precision = 0.514 vs. 0.109
# Recall = 0.602 vs. 0.763
# Minibatch Loss= 0.006715
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.103
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.206
# F1 = 1.000 vs. 0.327
# Precision = 1.000 vs. 0.195
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.670 vs. 0.063
# F1 = 0.680 vs. 0.090
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.524 vs. 0.094
# F1 = 0.556 vs. 0.182
# Precision = 0.487 vs. 0.100
# Recall = 0.646 vs. 0.992
# Minibatch Loss= 0.003661
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.103
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.179
# F1 = 1.000 vs. 0.301
# Precision = 1.000 vs. 0.177
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.667 vs. 0.062
# F1 = 0.679 vs. 0.089
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.522 vs. 0.101
# F1 = 0.555 vs. 0.184
# Precision = 0.493 vs. 0.102
# Recall = 0.636 vs. 0.974
# Minibatch Loss= 0.002424
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.197
# F1 = 1.000 vs. 0.332
# Precision = 1.000 vs. 0.199
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.063
# F1 = 0.678 vs. 0.088
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.521 vs. 0.102
# F1 = 0.550 vs. 0.186
# Precision = 0.486 vs. 0.103
# Recall = 0.633 vs. 0.937
# Minibatch Loss= 0.002332
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.107
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.176
# F1 = 1.000 vs. 0.309
# Precision = 1.000 vs. 0.183
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.062
# F1 = 0.674 vs. 0.088
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.518 vs. 0.103
# F1 = 0.545 vs. 0.182
# Precision = 0.472 vs. 0.100
# Recall = 0.644 vs. 0.987
# Minibatch Loss= 0.001551
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.165
# F1 = 1.000 vs. 0.293
# Precision = 1.000 vs. 0.173
# Recall = 1.000 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.659 vs. 0.062
# F1 = 0.672 vs. 0.088
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.516 vs. 0.101
# F1 = 0.543 vs. 0.183
# Precision = 0.462 vs. 0.101
# Recall = 0.660 vs. 0.995
# Minibatch Loss= 0.001350
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.185
# F1 = 1.000 vs. 0.298
# Precision = 1.000 vs. 0.177
# Recall = 1.000 vs. 0.944
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.062
# F1 = 0.673 vs. 0.087
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.516 vs. 0.099
# F1 = 0.541 vs. 0.184
# Precision = 0.458 vs. 0.103
# Recall = 0.660 vs. 0.897
# Minibatch Loss= 0.001171
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.147
# F1 = 1.000 vs. 0.259
# Precision = 1.000 vs. 0.149
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.062
# F1 = 0.673 vs. 0.087
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.518 vs. 0.101
# F1 = 0.542 vs. 0.181
# Precision = 0.465 vs. 0.100
# Recall = 0.649 vs. 1.000
# Minibatch Loss= 0.000886
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.096
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.151
# F1 = 1.000 vs. 0.268
# Precision = 1.000 vs. 0.156
# Recall = 1.000 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.062
# F1 = 0.673 vs. 0.090
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.519 vs. 0.093
# F1 = 0.541 vs. 0.182
# Precision = 0.457 vs. 0.100
# Recall = 0.662 vs. 0.997
# Minibatch Loss= 0.000886
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.198
# F1 = 1.000 vs. 0.325
# Precision = 1.000 vs. 0.194
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.065
# F1 = 0.672 vs. 0.094
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.520 vs. 0.102
# F1 = 0.540 vs. 0.183
# Precision = 0.456 vs. 0.101
# Recall = 0.662 vs. 0.992
# Minibatch Loss= 0.000952
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.164
# F1 = 1.000 vs. 0.295
# Precision = 1.000 vs. 0.173
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.062
# F1 = 0.672 vs. 0.089
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.517 vs. 0.096
# F1 = 0.540 vs. 0.182
# Precision = 0.447 vs. 0.100
# Recall = 0.681 vs. 0.992
# Minibatch Loss= 0.000766
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.158
# F1 = 1.000 vs. 0.281
# Precision = 1.000 vs. 0.164
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.671 vs. 0.088
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.519 vs. 0.102
# F1 = 0.540 vs. 0.182
# Precision = 0.468 vs. 0.100
# Recall = 0.639 vs. 0.968
# Minibatch Loss= 0.000654
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.101
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.180
# F1 = 1.000 vs. 0.291
# Precision = 1.000 vs. 0.170
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.672 vs. 0.086
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.514 vs. 0.096
# F1 = 0.544 vs. 0.182
# Precision = 0.461 vs. 0.100
# Recall = 0.665 vs. 0.987
# Minibatch Loss= 0.000541
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.098
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.161
# F1 = 1.000 vs. 0.271
# Precision = 1.000 vs. 0.157
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.063
# F1 = 0.672 vs. 0.092
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.519 vs. 0.097
# F1 = 0.546 vs. 0.181
# Precision = 0.468 vs. 0.100
# Recall = 0.654 vs. 1.000
# Minibatch Loss= 0.000610
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.176
# F1 = 1.000 vs. 0.302
# Precision = 1.000 vs. 0.181
# Recall = 1.000 vs. 0.908
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.063
# F1 = 0.671 vs. 0.087
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.515 vs. 0.099
# F1 = 0.547 vs. 0.181
# Precision = 0.467 vs. 0.100
# Recall = 0.660 vs. 0.989
# Minibatch Loss= 0.000597
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.171
# F1 = 1.000 vs. 0.288
# Precision = 1.000 vs. 0.169
# Recall = 1.000 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.062
# F1 = 0.671 vs. 0.089
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.517 vs. 0.089
# F1 = 0.547 vs. 0.181
# Precision = 0.457 vs. 0.100
# Recall = 0.681 vs. 1.000
# Minibatch Loss= 0.000512
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.102
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.179
# F1 = 1.000 vs. 0.313
# Precision = 1.000 vs. 0.185
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.064
# F1 = 0.668 vs. 0.091
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.515 vs. 0.110
# F1 = 0.549 vs. 0.188
# Precision = 0.473 vs. 0.106
# Recall = 0.654 vs. 0.807
# Minibatch Loss= 0.000478
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.101
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.199
# F1 = 1.000 vs. 0.321
# Precision = 1.000 vs. 0.191
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.062
# F1 = 0.667 vs. 0.085
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.517 vs. 0.096
# F1 = 0.551 vs. 0.181
# Precision = 0.474 vs. 0.100
# Recall = 0.657 vs. 1.000
# Minibatch Loss= 0.000460
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.135
# F1 = 1.000 vs. 0.252
# Precision = 1.000 vs. 0.144
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.062
# F1 = 0.667 vs. 0.087
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.513 vs. 0.100
# F1 = 0.551 vs. 0.182
# Precision = 0.472 vs. 0.101
# Recall = 0.662 vs. 0.955
# Minibatch Loss= 0.000329
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.188
# F1 = 1.000 vs. 0.322
# Precision = 1.000 vs. 0.192
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.064
# F1 = 0.669 vs. 0.090
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.518 vs. 0.101
# F1 = 0.551 vs. 0.183
# Precision = 0.476 vs. 0.101
# Recall = 0.654 vs. 0.942
# Minibatch Loss= 0.000399
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.101
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.159
# F1 = 1.000 vs. 0.284
# Precision = 1.000 vs. 0.165
# Recall = 1.000 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.061
# F1 = 0.668 vs. 0.087
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.515 vs. 0.103
# F1 = 0.549 vs. 0.184
# Precision = 0.472 vs. 0.101
# Recall = 0.657 vs. 0.982
# Minibatch Loss= 0.000394
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.098
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.165
# F1 = 1.000 vs. 0.283
# Precision = 1.000 vs. 0.165
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.063
# F1 = 0.669 vs. 0.091
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.517 vs. 0.091
# F1 = 0.550 vs. 0.182
# Precision = 0.480 vs. 0.100
# Recall = 0.644 vs. 1.000
# Minibatch Loss= 0.000293
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.142
# F1 = 1.000 vs. 0.260
# Precision = 1.000 vs. 0.150
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.669 vs. 0.087
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.517 vs. 0.098
# F1 = 0.549 vs. 0.182
# Precision = 0.483 vs. 0.100
# Recall = 0.636 vs. 0.992
# Minibatch Loss= 0.000298
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.181
# F1 = 1.000 vs. 0.302
# Precision = 1.000 vs. 0.179
# Recall = 1.000 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.669 vs. 0.084
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.514 vs. 0.096
# F1 = 0.548 vs. 0.182
# Precision = 0.485 vs. 0.100
# Recall = 0.631 vs. 1.000
# Minibatch Loss= 0.000280
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.235
# F1 = 1.000 vs. 0.367
# Precision = 1.000 vs. 0.225
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.062
# F1 = 0.669 vs. 0.083
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.514 vs. 0.102
# F1 = 0.549 vs. 0.181
# Precision = 0.487 vs. 0.100
# Recall = 0.631 vs. 1.000
# Minibatch Loss= 0.000343
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.101
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.172
# F1 = 1.000 vs. 0.293
# Precision = 1.000 vs. 0.172
# Recall = 1.000 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.063
# F1 = 0.669 vs. 0.089
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.510 vs. 0.103
# F1 = 0.552 vs. 0.184
# Precision = 0.491 vs. 0.102
# Recall = 0.631 vs. 0.929
# Minibatch Loss= 0.000262
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.160
# F1 = 1.000 vs. 0.274
# Precision = 1.000 vs. 0.159
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.060
# F1 = 0.667 vs. 0.084
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.515 vs. 0.101
# F1 = 0.552 vs. 0.183
# Precision = 0.489 vs. 0.104
# Recall = 0.633 vs. 0.792
# Minibatch Loss= 0.000231
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.096
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.151
# F1 = 1.000 vs. 0.264
# Precision = 1.000 vs. 0.153
# Recall = 1.000 vs. 0.932
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.062
# F1 = 0.666 vs. 0.085
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.509 vs. 0.099
# F1 = 0.552 vs. 0.184
# Precision = 0.491 vs. 0.105
# Recall = 0.631 vs. 0.747
# Minibatch Loss= 0.000204
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.215
# F1 = 1.000 vs. 0.346
# Precision = 1.000 vs. 0.210
# Recall = 1.000 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.062
# F1 = 0.666 vs. 0.087
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.515 vs. 0.106
# F1 = 0.552 vs. 0.183
# Precision = 0.493 vs. 0.102
# Recall = 0.628 vs. 0.887
# Minibatch Loss= 0.000245
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.163
# F1 = 1.000 vs. 0.285
# Precision = 1.000 vs. 0.166
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.666 vs. 0.091
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.510 vs. 0.100
# F1 = 0.551 vs. 0.185
# Precision = 0.492 vs. 0.103
# Recall = 0.625 vs. 0.902
# Minibatch Loss= 0.000209
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.160
# F1 = 1.000 vs. 0.283
# Precision = 1.000 vs. 0.165
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.065
# F1 = 0.666 vs. 0.092
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.516 vs. 0.102
# F1 = 0.548 vs. 0.184
# Precision = 0.492 vs. 0.108
# Recall = 0.620 vs. 0.625
# Minibatch Loss= 0.000183
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.102
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.169
# F1 = 1.000 vs. 0.286
# Precision = 1.000 vs. 0.168
# Recall = 1.000 vs. 0.963
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.667 vs. 0.088
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.511 vs. 0.097
# F1 = 0.547 vs. 0.181
# Precision = 0.490 vs. 0.100
# Recall = 0.620 vs. 0.953
# Minibatch Loss= 0.000185
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.146
# F1 = 1.000 vs. 0.268
# Precision = 1.000 vs. 0.154
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.062
# F1 = 0.667 vs. 0.086
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.512 vs. 0.102
# F1 = 0.546 vs. 0.184
# Precision = 0.492 vs. 0.104
# Recall = 0.615 vs. 0.797
# Minibatch Loss= 0.000192
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.180
# F1 = 1.000 vs. 0.292
# Precision = 1.000 vs. 0.175
# Recall = 1.000 vs. 0.881
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.061
# F1 = 0.666 vs. 0.085
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.511 vs. 0.102
# F1 = 0.547 vs. 0.182
# Precision = 0.488 vs. 0.101
# Recall = 0.623 vs. 0.979
# Minibatch Loss= 0.000163
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.102
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.150
# F1 = 1.000 vs. 0.274
# Precision = 1.000 vs. 0.159
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.062
# F1 = 0.665 vs. 0.089
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.507 vs. 0.100
# F1 = 0.547 vs. 0.182
# Precision = 0.486 vs. 0.100
# Recall = 0.625 vs. 0.953
# Minibatch Loss= 0.000129
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.187
# F1 = 1.000 vs. 0.318
# Precision = 1.000 vs. 0.189
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.653 vs. 0.064
# F1 = 0.665 vs. 0.087
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.512 vs. 0.094
# F1 = 0.545 vs. 0.183
# Precision = 0.484 vs. 0.101
# Recall = 0.625 vs. 0.958
# Minibatch Loss= 0.000172
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.098
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.169
# F1 = 1.000 vs. 0.282
# Precision = 1.000 vs. 0.167
# Recall = 1.000 vs. 0.915
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.064
# F1 = 0.665 vs. 0.087
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.510 vs. 0.103
# F1 = 0.547 vs. 0.183
# Precision = 0.486 vs. 0.101
# Recall = 0.625 vs. 0.968
# Minibatch Loss= 0.000148
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.159
# F1 = 1.000 vs. 0.288
# Precision = 1.000 vs. 0.168
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.655 vs. 0.063
# F1 = 0.666 vs. 0.089
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.507 vs. 0.098
# F1 = 0.545 vs. 0.182
# Precision = 0.484 vs. 0.100
# Recall = 0.625 vs. 1.000
# Minibatch Loss= 0.000128
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.184
# F1 = 1.000 vs. 0.319
# Precision = 1.000 vs. 0.191
# Recall = 1.000 vs. 0.969
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.062
# F1 = 0.665 vs. 0.085
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.509 vs. 0.107
# F1 = 0.546 vs. 0.182
# Precision = 0.485 vs. 0.107
# Recall = 0.625 vs. 0.628
# Minibatch Loss= 0.000139
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.102
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.191
# F1 = 1.000 vs. 0.296
# Precision = 1.000 vs. 0.174
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.064
# F1 = 0.667 vs. 0.094
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.447 vs. 0.100
# Recall = 0.683 vs. 1.000
# Minibatch Loss= 0.000059
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.175
# F1 = 1.000 vs. 0.303
# Precision = 1.000 vs. 0.178
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.062
# F1 = 0.649 vs. 0.090
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.490 vs. 0.102
# F1 = 0.539 vs. 0.182
# Precision = 0.448 vs. 0.100
# Recall = 0.678 vs. 0.995
# Minibatch Loss= 0.000058
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.204
# F1 = 1.000 vs. 0.334
# Precision = 1.000 vs. 0.200
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.063
# F1 = 0.649 vs. 0.091
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.102
# F1 = 0.540 vs. 0.182
# Precision = 0.449 vs. 0.100
# Recall = 0.678 vs. 0.989
# Minibatch Loss= 0.000070
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.170
# F1 = 1.000 vs. 0.280
# Precision = 1.000 vs. 0.163
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.062
# F1 = 0.650 vs. 0.082
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.491 vs. 0.095
# F1 = 0.541 vs. 0.183
# Precision = 0.451 vs. 0.101
# Recall = 0.675 vs. 1.000
# Minibatch Loss= 0.000048
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.188
# F1 = 1.000 vs. 0.313
# Precision = 1.000 vs. 0.185
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.061
# F1 = 0.651 vs. 0.085
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.096
# F1 = 0.540 vs. 0.183
# Precision = 0.445 vs. 0.101
# Recall = 0.686 vs. 0.979
# Minibatch Loss= 0.000049
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.182
# F1 = 1.000 vs. 0.310
# Precision = 1.000 vs. 0.184
# Recall = 1.000 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.063
# F1 = 0.651 vs. 0.090
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.487 vs. 0.109
# F1 = 0.540 vs. 0.183
# Precision = 0.451 vs. 0.101
# Recall = 0.673 vs. 0.963
# Minibatch Loss= 0.000048
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.173
# F1 = 1.000 vs. 0.294
# Precision = 1.000 vs. 0.176
# Recall = 1.000 vs. 0.894
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.062
# F1 = 0.650 vs. 0.086
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.100
# F1 = 0.540 vs. 0.184
# Precision = 0.444 vs. 0.101
# Recall = 0.689 vs. 0.976
# Minibatch Loss= 0.000048
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.186
# F1 = 1.000 vs. 0.305
# Precision = 1.000 vs. 0.181
# Recall = 1.000 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.062
# F1 = 0.650 vs. 0.090
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.484 vs. 0.095
# F1 = 0.540 vs. 0.184
# Precision = 0.451 vs. 0.103
# Recall = 0.673 vs. 0.828
# Minibatch Loss= 0.000042
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.190
# F1 = 1.000 vs. 0.313
# Precision = 1.000 vs. 0.186
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.062
# F1 = 0.648 vs. 0.089
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.102
# F1 = 0.539 vs. 0.181
# Precision = 0.443 vs. 0.100
# Recall = 0.689 vs. 0.982
# Minibatch Loss= 0.000037
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.102
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.183
# F1 = 1.000 vs. 0.291
# Precision = 1.000 vs. 0.173
# Recall = 1.000 vs. 0.923
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.063
# F1 = 0.649 vs. 0.088
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.098
# F1 = 0.539 vs. 0.182
# Precision = 0.444 vs. 0.101
# Recall = 0.686 vs. 0.889
# Minibatch Loss= 0.000037
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.098
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.170
# F1 = 1.000 vs. 0.290
# Precision = 1.000 vs. 0.170
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.063
# F1 = 0.650 vs. 0.092
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.487 vs. 0.104
# F1 = 0.539 vs. 0.182
# Precision = 0.444 vs. 0.100
# Recall = 0.686 vs. 0.979
# Minibatch Loss= 0.000036
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.101
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.161
# F1 = 1.000 vs. 0.286
# Precision = 1.000 vs. 0.167
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.062
# F1 = 0.648 vs. 0.087
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.483 vs. 0.099
# F1 = 0.539 vs. 0.182
# Precision = 0.444 vs. 0.100
# Recall = 0.686 vs. 0.992
# Minibatch Loss= 0.000032
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.224
# F1 = 1.000 vs. 0.366
# Precision = 1.000 vs. 0.227
# Recall = 1.000 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.064
# F1 = 0.648 vs. 0.092
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.494 vs. 0.098
# F1 = 0.537 vs. 0.183
# Precision = 0.447 vs. 0.105
# Recall = 0.673 vs. 0.715
# Minibatch Loss= 0.000040
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.102
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.167
# F1 = 1.000 vs. 0.292
# Precision = 1.000 vs. 0.171
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.062
# F1 = 0.647 vs. 0.090
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.100
# F1 = 0.537 vs. 0.182
# Precision = 0.447 vs. 0.103
# Recall = 0.673 vs. 0.757
# Minibatch Loss= 0.000025
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.103
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.165
# F1 = 1.000 vs. 0.290
# Precision = 1.000 vs. 0.174
# Recall = 1.000 vs. 0.883
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.062
# F1 = 0.647 vs. 0.087
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.099
# F1 = 0.538 vs. 0.182
# Precision = 0.441 vs. 0.100
# Recall = 0.689 vs. 0.982
# Minibatch Loss= 0.000030
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.184
# F1 = 1.000 vs. 0.314
# Precision = 1.000 vs. 0.186
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.065
# F1 = 0.647 vs. 0.098
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.102
# F1 = 0.536 vs. 0.182
# Precision = 0.456 vs. 0.100
# Recall = 0.652 vs. 0.995
# Minibatch Loss= 0.000028
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.098
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.148
# F1 = 1.000 vs. 0.260
# Precision = 1.000 vs. 0.150
# Recall = 1.000 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.062
# F1 = 0.649 vs. 0.086
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.097
# F1 = 0.536 vs. 0.186
# Precision = 0.443 vs. 0.104
# Recall = 0.681 vs. 0.900
# Minibatch Loss= 0.000022
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.101
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.197
# F1 = 1.000 vs. 0.318
# Precision = 1.000 vs. 0.189
# Recall = 1.000 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.061
# F1 = 0.648 vs. 0.089
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.480 vs. 0.103
# F1 = 0.536 vs. 0.183
# Precision = 0.453 vs. 0.102
# Recall = 0.657 vs. 0.863
# Minibatch Loss= 0.000027
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.162
# F1 = 1.000 vs. 0.287
# Precision = 1.000 vs. 0.168
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.062
# F1 = 0.648 vs. 0.088
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.484 vs. 0.102
# F1 = 0.538 vs. 0.181
# Precision = 0.447 vs. 0.100
# Recall = 0.675 vs. 0.997
# Minibatch Loss= 0.000022
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.186
# F1 = 1.000 vs. 0.326
# Precision = 1.000 vs. 0.194
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.630 vs. 0.065
# F1 = 0.647 vs. 0.087
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.476 vs. 0.101
# F1 = 0.537 vs. 0.182
# Precision = 0.446 vs. 0.100
# Recall = 0.675 vs. 1.000
# Minibatch Loss= 0.000025
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.163
# F1 = 1.000 vs. 0.284
# Precision = 1.000 vs. 0.165
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.062
# F1 = 0.648 vs. 0.086
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.484 vs. 0.091
# F1 = 0.540 vs. 0.181
# Precision = 0.447 vs. 0.100
# Recall = 0.681 vs. 1.000
# Minibatch Loss= 0.000019
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.100
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.174
# F1 = 1.000 vs. 0.290
# Precision = 1.000 vs. 0.169
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.061
# F1 = 0.648 vs. 0.087
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.484 vs. 0.104
# F1 = 0.540 vs. 0.190
# Precision = 0.448 vs. 0.109
# Recall = 0.681 vs. 0.731
# Minibatch Loss= 0.000019
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.173
# F1 = 1.000 vs. 0.298
# Precision = 1.000 vs. 0.175
# Recall = 1.000 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.062
# F1 = 0.647 vs. 0.086
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.483 vs. 0.096
# F1 = 0.539 vs. 0.182
# Precision = 0.447 vs. 0.101
# Recall = 0.678 vs. 0.950
# Minibatch Loss= 0.000018
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.099
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.146
# F1 = 1.000 vs. 0.264
# Precision = 1.000 vs. 0.155
# Recall = 1.000 vs. 0.880
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.064
# F1 = 0.647 vs. 0.093
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.485 vs. 0.091
# F1 = 0.539 vs. 0.184
# Precision = 0.446 vs. 0.101
# Recall = 0.681 vs. 0.974
# Minibatch Loss= 0.000014
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.214
# F1 = 1.000 vs. 0.346
# Precision = 1.000 vs. 0.209
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.064
# F1 = 0.647 vs. 0.091
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.481 vs. 0.093
# F1 = 0.535 vs. 0.185
# Precision = 0.452 vs. 0.103
# Recall = 0.657 vs. 0.865
# Minibatch Loss= 0.000021
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.189
# F1 = 1.000 vs. 0.307
# Precision = 1.000 vs. 0.181
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.062
# F1 = 0.646 vs. 0.086
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.484 vs. 0.100
# F1 = 0.537 vs. 0.181
# Precision = 0.454 vs. 0.100
# Recall = 0.657 vs. 0.950
# Minibatch Loss= 0.000018
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.206
# F1 = 1.000 vs. 0.335
# Precision = 1.000 vs. 0.203
# Recall = 1.000 vs. 0.957
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.063
# F1 = 0.647 vs. 0.093
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.099
# F1 = 0.537 vs. 0.184
# Precision = 0.455 vs. 0.102
# Recall = 0.654 vs. 0.934
# Minibatch Loss= 0.000017
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.102
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.160
# F1 = 1.000 vs. 0.282
# Precision = 1.000 vs. 0.165
# Recall = 1.000 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.062
# F1 = 0.647 vs. 0.084
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.478 vs. 0.096
# F1 = 0.537 vs. 0.182
# Precision = 0.455 vs. 0.100
# Recall = 0.654 vs. 0.976
# Minibatch Loss= 0.000013
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.098
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.160
# F1 = 1.000 vs. 0.265
# Precision = 1.000 vs. 0.153
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.627 vs. 0.063
# F1 = 0.646 vs. 0.091
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.475 vs. 0.108
# F1 = 0.536 vs. 0.184
# Precision = 0.456 vs. 0.103
# Recall = 0.649 vs. 0.834
# Minibatch Loss= 0.000014
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.097
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.157
# F1 = 1.000 vs. 0.257
# Precision = 1.000 vs. 0.147
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.063
# F1 = 0.646 vs. 0.088
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.477 vs. 0.100
# F1 = 0.536 vs. 0.182
# Precision = 0.462 vs. 0.102
# Recall = 0.639 vs. 0.855
# Minibatch Loss= 0.000012
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.958 vs. 0.067
# F1 = 0.903 vs. 0.105
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.828 vs. 0.201
# F1 = 0.764 vs. 0.320
# Precision = 0.784 vs. 0.191
# Recall = 0.745 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.663 vs. 0.064
# F1 = 0.664 vs. 0.093
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.416 vs. 0.101
# F1 = 0.498 vs. 0.182
# Precision = 0.410 vs. 0.104
# Recall = 0.633 vs. 0.726
# Minibatch Loss= 0.142464
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.065
# F1 = 0.989 vs. 0.098
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.156
# F1 = 0.958 vs. 0.279
# Precision = 0.932 vs. 0.164
# Recall = 0.984 vs. 0.940
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.062
# F1 = 0.669 vs. 0.084
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.446 vs. 0.108
# F1 = 0.515 vs. 0.185
# Precision = 0.460 vs. 0.106
# Recall = 0.583 vs. 0.734
# Minibatch Loss= 0.014995
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.064
# F1 = 0.997 vs. 0.095
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.140
# F1 = 0.995 vs. 0.242
# Precision = 0.993 vs. 0.138
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.063
# F1 = 0.667 vs. 0.091
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.451 vs. 0.096
# F1 = 0.503 vs. 0.182
# Precision = 0.426 vs. 0.101
# Recall = 0.612 vs. 0.963
# Minibatch Loss= 0.006099
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 0.999 vs. 0.096
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.135
# F1 = 0.997 vs. 0.247
# Precision = 0.993 vs. 0.141
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.063
# F1 = 0.670 vs. 0.088
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.455 vs. 0.103
# F1 = 0.496 vs. 0.181
# Precision = 0.457 vs. 0.100
# Recall = 0.544 vs. 0.997
# Minibatch Loss= 0.003395
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.999 vs. 0.099
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.167
# F1 = 0.998 vs. 0.286
# Precision = 0.996 vs. 0.174
# Recall = 1.000 vs. 0.807
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.063
# F1 = 0.666 vs. 0.090
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.461 vs. 0.108
# F1 = 0.500 vs. 0.184
# Precision = 0.402 vs. 0.102
# Recall = 0.662 vs. 0.926
# Minibatch Loss= 0.002972
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/RCNN_Wmultitask_32_opp/RCNN_Wmultitask_32_opp-20000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
result = nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.649 vs. 0.065
# F1 = 0.665 vs. 0.092
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.461 vs. 0.110
# F1 = 0.504 vs. 0.182
# Precision = 0.413 vs. 0.100
# Recall = 0.646 vs. 0.997

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
out.shape
# Out:
# (119, 32, 19)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1
