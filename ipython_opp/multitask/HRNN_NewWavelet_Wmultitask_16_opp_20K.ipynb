# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_NewWavelet_Wmultitask_16_opp_20K"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../src')

# %%
from models.HRNN_model_new_Wavelet import Model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 7    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_kernel_size = 3    
activation = tf.nn.relu

lstm_n_hidden = 64
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary/' + exp_name 
checkpoint_path = '../../model/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_kernel_size = wavelet_kernel_size,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights
)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.062
# F1 = 0.104 vs. 0.094
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.094 vs. 0.102
# F1 = 0.189 vs. 0.188
# Precision = 0.106 vs. 0.106
# Recall = 0.904 vs. 0.870
# Validation: 0
# ACTIVITY RECOGNITION
# AUC = 0.062 vs. 0.060
# F1 = 0.088 vs. 0.079
# Accuracy = 0.017 vs. 0.056
# CHANGE DETECTION
# AUC = 0.048 vs. 0.049
# F1 = 0.103 vs. 0.097
# Precision = 0.054 vs. 0.051
# Recall = 0.966 vs. 0.992
# Minibatch Loss= 1.400876
# Training: 100
# ACTIVITY RECOGNITION
# AUC = 0.364 vs. 0.061
# F1 = 0.426 vs. 0.089
# Accuracy = 0.440 vs. 0.056
# CHANGE DETECTION
# AUC = 0.220 vs. 0.094
# F1 = 0.331 vs. 0.157
# Precision = 0.257 vs. 0.087
# Recall = 0.466 vs. 0.845
# Validation: 100
# ACTIVITY RECOGNITION
# AUC = 0.181 vs. 0.060
# F1 = 0.252 vs. 0.080
# Accuracy = 0.426 vs. 0.056
# CHANGE DETECTION
# AUC = 0.175 vs. 0.048
# F1 = 0.265 vs. 0.097
# Precision = 0.184 vs. 0.051
# Recall = 0.475 vs. 0.992
# Minibatch Loss= 0.539392
# Training: 200
# ACTIVITY RECOGNITION
# AUC = 0.554 vs. 0.060
# F1 = 0.566 vs. 0.086
# Accuracy = 0.597 vs. 0.056
# CHANGE DETECTION
# AUC = 0.234 vs. 0.083
# F1 = 0.333 vs. 0.153
# Precision = 0.226 vs. 0.083
# Recall = 0.631 vs. 0.956
# Validation: 200
# ACTIVITY RECOGNITION
# AUC = 0.262 vs. 0.059
# F1 = 0.350 vs. 0.084
# Accuracy = 0.612 vs. 0.056
# CHANGE DETECTION
# AUC = 0.181 vs. 0.062
# F1 = 0.268 vs. 0.107
# Precision = 0.182 vs. 0.078
# Recall = 0.509 vs. 0.169
# Minibatch Loss= 0.386100
# Training: 300
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.062
# F1 = 0.619 vs. 0.093
# Accuracy = 0.588 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.109
# F1 = 0.378 vs. 0.196
# Precision = 0.273 vs. 0.109
# Recall = 0.616 vs. 0.941
# Validation: 300
# ACTIVITY RECOGNITION
# AUC = 0.321 vs. 0.059
# F1 = 0.404 vs. 0.080
# Accuracy = 0.642 vs. 0.056
# CHANGE DETECTION
# AUC = 0.191 vs. 0.050
# F1 = 0.274 vs. 0.101
# Precision = 0.186 vs. 0.054
# Recall = 0.522 vs. 0.836
# Minibatch Loss= 0.394201
# Training: 400
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.061
# F1 = 0.664 vs. 0.091
# Accuracy = 0.682 vs. 0.056
# CHANGE DETECTION
# AUC = 0.245 vs. 0.081
# F1 = 0.334 vs. 0.155
# Precision = 0.232 vs. 0.084
# Recall = 0.598 vs. 0.998
# Validation: 400
# ACTIVITY RECOGNITION
# AUC = 0.369 vs. 0.059
# F1 = 0.441 vs. 0.082
# Accuracy = 0.715 vs. 0.056
# CHANGE DETECTION
# AUC = 0.191 vs. 0.056
# F1 = 0.287 vs. 0.105
# Precision = 0.194 vs. 0.060
# Recall = 0.553 vs. 0.410
# Minibatch Loss= 0.280202
# Training: 500
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.060
# F1 = 0.696 vs. 0.090
# Accuracy = 0.712 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.108
# F1 = 0.366 vs. 0.179
# Precision = 0.247 vs. 0.098
# Recall = 0.702 vs. 0.994
# Validation: 500
# ACTIVITY RECOGNITION
# AUC = 0.401 vs. 0.059
# F1 = 0.462 vs. 0.083
# Accuracy = 0.729 vs. 0.056
# CHANGE DETECTION
# AUC = 0.209 vs. 0.050
# F1 = 0.303 vs. 0.099
# Precision = 0.216 vs. 0.052
# Recall = 0.506 vs. 0.883
# Minibatch Loss= 0.256172
# Training: 600
# ACTIVITY RECOGNITION
# AUC = 0.773 vs. 0.059
# F1 = 0.748 vs. 0.087
# Accuracy = 0.751 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.097
# F1 = 0.399 vs. 0.168
# Precision = 0.272 vs. 0.092
# Recall = 0.747 vs. 0.993
# Validation: 600
# ACTIVITY RECOGNITION
# AUC = 0.420 vs. 0.059
# F1 = 0.475 vs. 0.079
# Accuracy = 0.756 vs. 0.056
# CHANGE DETECTION
# AUC = 0.217 vs. 0.046
# F1 = 0.322 vs. 0.097
# Precision = 0.231 vs. 0.051
# Recall = 0.530 vs. 0.938
# Minibatch Loss= 0.208625
# Training: 700
# ACTIVITY RECOGNITION
# AUC = 0.802 vs. 0.060
# F1 = 0.767 vs. 0.087
# Accuracy = 0.829 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.076
# F1 = 0.391 vs. 0.145
# Precision = 0.268 vs. 0.079
# Recall = 0.724 vs. 0.884
# Validation: 700
# ACTIVITY RECOGNITION
# AUC = 0.429 vs. 0.058
# F1 = 0.485 vs. 0.078
# Accuracy = 0.782 vs. 0.056
# CHANGE DETECTION
# AUC = 0.227 vs. 0.053
# F1 = 0.323 vs. 0.101
# Precision = 0.241 vs. 0.054
# Recall = 0.494 vs. 0.808
# Minibatch Loss= 0.156296
# Training: 800
# ACTIVITY RECOGNITION
# AUC = 0.853 vs. 0.062
# F1 = 0.797 vs. 0.094
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.104
# F1 = 0.409 vs. 0.185
# Precision = 0.294 vs. 0.103
# Recall = 0.669 vs. 0.908
# Validation: 800
# ACTIVITY RECOGNITION
# AUC = 0.444 vs. 0.058
# F1 = 0.493 vs. 0.079
# Accuracy = 0.783 vs. 0.056
# CHANGE DETECTION
# AUC = 0.229 vs. 0.056
# F1 = 0.322 vs. 0.101
# Precision = 0.241 vs. 0.059
# Recall = 0.486 vs. 0.358
# Minibatch Loss= 0.185508
# Training: 900
# ACTIVITY RECOGNITION
# AUC = 0.835 vs. 0.059
# F1 = 0.796 vs. 0.088
# Accuracy = 0.828 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.089
# F1 = 0.396 vs. 0.159
# Precision = 0.276 vs. 0.088
# Recall = 0.705 vs. 0.818
# Validation: 900
# ACTIVITY RECOGNITION
# AUC = 0.451 vs. 0.059
# F1 = 0.499 vs. 0.083
# Accuracy = 0.790 vs. 0.056
# CHANGE DETECTION
# AUC = 0.239 vs. 0.051
# F1 = 0.326 vs. 0.101
# Precision = 0.271 vs. 0.055
# Recall = 0.410 vs. 0.636
# Minibatch Loss= 0.160119
# Training: 1000
# ACTIVITY RECOGNITION
# AUC = 0.853 vs. 0.062
# F1 = 0.818 vs. 0.092
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.352 vs. 0.097
# F1 = 0.456 vs. 0.178
# Precision = 0.327 vs. 0.098
# Recall = 0.756 vs. 0.977
# Validation: 1000
# ACTIVITY RECOGNITION
# AUC = 0.455 vs. 0.058
# F1 = 0.511 vs. 0.081
# Accuracy = 0.795 vs. 0.056
# CHANGE DETECTION
# AUC = 0.238 vs. 0.049
# F1 = 0.336 vs. 0.096
# Precision = 0.248 vs. 0.051
# Recall = 0.522 vs. 1.000
# Minibatch Loss= 0.147861
# Training: 1100
# ACTIVITY RECOGNITION
# AUC = 0.894 vs. 0.060
# F1 = 0.834 vs. 0.088
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.347 vs. 0.081
# F1 = 0.426 vs. 0.138
# Precision = 0.312 vs. 0.074
# Recall = 0.672 vs. 0.991
# Validation: 1100
# ACTIVITY RECOGNITION
# AUC = 0.454 vs. 0.059
# F1 = 0.509 vs. 0.083
# Accuracy = 0.809 vs. 0.056
# CHANGE DETECTION
# AUC = 0.240 vs. 0.052
# F1 = 0.328 vs. 0.098
# Precision = 0.246 vs. 0.055
# Recall = 0.491 vs. 0.465
# Minibatch Loss= 0.120164
# Training: 1200
# ACTIVITY RECOGNITION
# AUC = 0.894 vs. 0.060
# F1 = 0.849 vs. 0.087
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.082
# F1 = 0.438 vs. 0.153
# Precision = 0.319 vs. 0.083
# Recall = 0.697 vs. 0.943
# Validation: 1200
# ACTIVITY RECOGNITION
# AUC = 0.472 vs. 0.059
# F1 = 0.517 vs. 0.082
# Accuracy = 0.806 vs. 0.056
# CHANGE DETECTION
# AUC = 0.248 vs. 0.055
# F1 = 0.326 vs. 0.101
# Precision = 0.232 vs. 0.060
# Recall = 0.543 vs. 0.319
# Minibatch Loss= 0.117679
# Training: 1300
# ACTIVITY RECOGNITION
# AUC = 0.886 vs. 0.061
# F1 = 0.842 vs. 0.088
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.347 vs. 0.084
# F1 = 0.438 vs. 0.155
# Precision = 0.325 vs. 0.084
# Recall = 0.667 vs. 0.994
# Validation: 1300
# ACTIVITY RECOGNITION
# AUC = 0.473 vs. 0.060
# F1 = 0.517 vs. 0.086
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.248 vs. 0.049
# F1 = 0.328 vs. 0.096
# Precision = 0.242 vs. 0.051
# Recall = 0.506 vs. 0.823
# Minibatch Loss= 0.120295
# Training: 1400
# ACTIVITY RECOGNITION
# AUC = 0.837 vs. 0.062
# F1 = 0.802 vs. 0.094
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.355 vs. 0.096
# F1 = 0.443 vs. 0.182
# Precision = 0.307 vs. 0.100
# Recall = 0.795 vs. 0.969
# Validation: 1400
# ACTIVITY RECOGNITION
# AUC = 0.476 vs. 0.059
# F1 = 0.519 vs. 0.079
# Accuracy = 0.817 vs. 0.056
# CHANGE DETECTION
# AUC = 0.241 vs. 0.055
# F1 = 0.322 vs. 0.097
# Precision = 0.241 vs. 0.051
# Recall = 0.486 vs. 0.992
# Minibatch Loss= 0.155719
# Training: 1500
# ACTIVITY RECOGNITION
# AUC = 0.911 vs. 0.061
# F1 = 0.874 vs. 0.091
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.412 vs. 0.088
# F1 = 0.474 vs. 0.162
# Precision = 0.374 vs. 0.088
# Recall = 0.647 vs. 1.000
# Validation: 1500
# ACTIVITY RECOGNITION
# AUC = 0.477 vs. 0.058
# F1 = 0.519 vs. 0.077
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.251 vs. 0.049
# F1 = 0.331 vs. 0.096
# Precision = 0.230 vs. 0.051
# Recall = 0.595 vs. 0.997
# Minibatch Loss= 0.109251
# Training: 1600
# ACTIVITY RECOGNITION
# AUC = 0.914 vs. 0.061
# F1 = 0.863 vs. 0.088
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.464 vs. 0.088
# F1 = 0.498 vs. 0.160
# Precision = 0.404 vs. 0.087
# Recall = 0.648 vs. 0.967
# Validation: 1600
# ACTIVITY RECOGNITION
# AUC = 0.502 vs. 0.058
# F1 = 0.539 vs. 0.079
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.053
# F1 = 0.338 vs. 0.100
# Precision = 0.233 vs. 0.054
# Recall = 0.613 vs. 0.696
# Minibatch Loss= 0.106143
# Training: 1700
# ACTIVITY RECOGNITION
# AUC = 0.917 vs. 0.061
# F1 = 0.875 vs. 0.094
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.425 vs. 0.093
# F1 = 0.496 vs. 0.166
# Precision = 0.401 vs. 0.092
# Recall = 0.649 vs. 0.824
# Validation: 1700
# ACTIVITY RECOGNITION
# AUC = 0.491 vs. 0.059
# F1 = 0.536 vs. 0.082
# Accuracy = 0.823 vs. 0.056
# CHANGE DETECTION
# AUC = 0.257 vs. 0.051
# F1 = 0.337 vs. 0.099
# Precision = 0.244 vs. 0.052
# Recall = 0.543 vs. 0.951
# Minibatch Loss= 0.104094
# Training: 1800
# ACTIVITY RECOGNITION
# AUC = 0.937 vs. 0.064
# F1 = 0.888 vs. 0.093
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.430 vs. 0.094
# F1 = 0.485 vs. 0.174
# Precision = 0.389 vs. 0.097
# Recall = 0.646 vs. 0.844
# Validation: 1800
# ACTIVITY RECOGNITION
# AUC = 0.493 vs. 0.059
# F1 = 0.535 vs. 0.079
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.256 vs. 0.055
# F1 = 0.340 vs. 0.099
# Precision = 0.242 vs. 0.054
# Recall = 0.569 vs. 0.584
# Minibatch Loss= 0.103780
# Training: 1900
# ACTIVITY RECOGNITION
# AUC = 0.932 vs. 0.061
# F1 = 0.894 vs. 0.093
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.457 vs. 0.097
# F1 = 0.511 vs. 0.179
# Precision = 0.403 vs. 0.100
# Recall = 0.697 vs. 0.838
# Validation: 1900
# ACTIVITY RECOGNITION
# AUC = 0.482 vs. 0.059
# F1 = 0.527 vs. 0.080
# Accuracy = 0.814 vs. 0.056
# CHANGE DETECTION
# AUC = 0.257 vs. 0.054
# F1 = 0.322 vs. 0.103
# Precision = 0.225 vs. 0.058
# Recall = 0.566 vs. 0.457
# Minibatch Loss= 0.094113
# Training: 2000
# ACTIVITY RECOGNITION
# AUC = 0.936 vs. 0.061
# F1 = 0.893 vs. 0.092
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.100
# F1 = 0.540 vs. 0.172
# Precision = 0.444 vs. 0.095
# Recall = 0.690 vs. 0.893
# Validation: 2000
# ACTIVITY RECOGNITION
# AUC = 0.504 vs. 0.059
# F1 = 0.540 vs. 0.080
# Accuracy = 0.830 vs. 0.056
# CHANGE DETECTION
# AUC = 0.259 vs. 0.050
# F1 = 0.330 vs. 0.098
# Precision = 0.230 vs. 0.054
# Recall = 0.587 vs. 0.564
# Minibatch Loss= 0.086719
# Training: 2100
# ACTIVITY RECOGNITION
# AUC = 0.965 vs. 0.060
# F1 = 0.918 vs. 0.088
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.485 vs. 0.086
# F1 = 0.537 vs. 0.155
# Precision = 0.449 vs. 0.084
# Recall = 0.669 vs. 1.000
# Validation: 2100
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.060
# F1 = 0.541 vs. 0.088
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.253 vs. 0.058
# F1 = 0.338 vs. 0.100
# Precision = 0.231 vs. 0.055
# Recall = 0.629 vs. 0.579
# Minibatch Loss= 0.076916
# Training: 2200
# ACTIVITY RECOGNITION
# AUC = 0.917 vs. 0.062
# F1 = 0.866 vs. 0.096
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.489 vs. 0.093
# F1 = 0.511 vs. 0.177
# Precision = 0.396 vs. 0.097
# Recall = 0.722 vs. 0.976
# Validation: 2200
# ACTIVITY RECOGNITION
# AUC = 0.518 vs. 0.059
# F1 = 0.550 vs. 0.082
# Accuracy = 0.818 vs. 0.056
# CHANGE DETECTION
# AUC = 0.251 vs. 0.053
# F1 = 0.338 vs. 0.099
# Precision = 0.253 vs. 0.055
# Recall = 0.512 vs. 0.525
# Minibatch Loss= 0.110597
# Training: 2300
# ACTIVITY RECOGNITION
# AUC = 0.964 vs. 0.063
# F1 = 0.925 vs. 0.096
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.486 vs. 0.093
# F1 = 0.529 vs. 0.174
# Precision = 0.418 vs. 0.097
# Recall = 0.720 vs. 0.885
# Validation: 2300
# ACTIVITY RECOGNITION
# AUC = 0.528 vs. 0.059
# F1 = 0.562 vs. 0.079
# Accuracy = 0.836 vs. 0.056
# CHANGE DETECTION
# AUC = 0.259 vs. 0.050
# F1 = 0.342 vs. 0.097
# Precision = 0.242 vs. 0.051
# Recall = 0.587 vs. 0.995
# Minibatch Loss= 0.086798
# Training: 2400
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.061
# F1 = 0.932 vs. 0.088
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.500 vs. 0.079
# F1 = 0.542 vs. 0.152
# Precision = 0.445 vs. 0.083
# Recall = 0.694 vs. 1.000
# Validation: 2400
# ACTIVITY RECOGNITION
# AUC = 0.531 vs. 0.058
# F1 = 0.562 vs. 0.078
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.048
# F1 = 0.348 vs. 0.096
# Precision = 0.248 vs. 0.051
# Recall = 0.582 vs. 0.997
# Minibatch Loss= 0.068033
# Training: 2500
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.061
# F1 = 0.932 vs. 0.089
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.555 vs. 0.077
# F1 = 0.563 vs. 0.145
# Precision = 0.458 vs. 0.078
# Recall = 0.730 vs. 0.988
# Validation: 2500
# ACTIVITY RECOGNITION
# AUC = 0.523 vs. 0.059
# F1 = 0.557 vs. 0.082
# Accuracy = 0.848 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.054
# F1 = 0.343 vs. 0.102
# Precision = 0.241 vs. 0.055
# Recall = 0.600 vs. 0.779
# Minibatch Loss= 0.065987
# Training: 2600
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.060
# F1 = 0.928 vs. 0.090
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.518 vs. 0.084
# F1 = 0.540 vs. 0.154
# Precision = 0.467 vs. 0.084
# Recall = 0.640 vs. 1.000
# Validation: 2600
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.059
# F1 = 0.564 vs. 0.084
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.051
# F1 = 0.335 vs. 0.098
# Precision = 0.249 vs. 0.052
# Recall = 0.512 vs. 0.792
# Minibatch Loss= 0.068442
# Training: 2700
# ACTIVITY RECOGNITION
# AUC = 0.966 vs. 0.061
# F1 = 0.933 vs. 0.091
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.582 vs. 0.094
# F1 = 0.598 vs. 0.170
# Precision = 0.514 vs. 0.093
# Recall = 0.716 vs. 1.000
# Validation: 2700
# ACTIVITY RECOGNITION
# AUC = 0.527 vs. 0.059
# F1 = 0.552 vs. 0.080
# Accuracy = 0.850 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.051
# F1 = 0.346 vs. 0.098
# Precision = 0.268 vs. 0.052
# Recall = 0.486 vs. 0.919
# Minibatch Loss= 0.068104
# Training: 2800
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.062
# F1 = 0.637 vs. 0.095
# Accuracy = 0.709 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.108
# F1 = 0.377 vs. 0.193
# Precision = 0.278 vs. 0.108
# Recall = 0.584 vs. 0.899
# Validation: 2800
# ACTIVITY RECOGNITION
# AUC = 0.381 vs. 0.059
# F1 = 0.436 vs. 0.080
# Accuracy = 0.781 vs. 0.056
# CHANGE DETECTION
# AUC = 0.177 vs. 0.052
# F1 = 0.243 vs. 0.099
# Precision = 0.158 vs. 0.052
# Recall = 0.525 vs. 0.956
# Minibatch Loss= 0.384845
# Training: 2900
# ACTIVITY RECOGNITION
# AUC = 0.904 vs. 0.062
# F1 = 0.857 vs. 0.093
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.500 vs. 0.099
# F1 = 0.525 vs. 0.179
# Precision = 0.436 vs. 0.099
# Recall = 0.660 vs. 1.000
# Validation: 2900
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.058
# F1 = 0.577 vs. 0.079
# Accuracy = 0.844 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.048
# F1 = 0.360 vs. 0.097
# Precision = 0.296 vs. 0.051
# Recall = 0.460 vs. 0.995
# Minibatch Loss= 0.118702
# Training: 3000
# ACTIVITY RECOGNITION
# AUC = 0.943 vs. 0.062
# F1 = 0.900 vs. 0.089
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.535 vs. 0.085
# F1 = 0.529 vs. 0.160
# Precision = 0.442 vs. 0.087
# Recall = 0.658 vs. 0.967
# Validation: 3000
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.059
# F1 = 0.579 vs. 0.080
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.271 vs. 0.051
# F1 = 0.349 vs. 0.098
# Precision = 0.303 vs. 0.051
# Recall = 0.410 vs. 0.982
# Minibatch Loss= 0.086939
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 0.947 vs. 0.061
# F1 = 0.905 vs. 0.094
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.530 vs. 0.097
# F1 = 0.559 vs. 0.182
# Precision = 0.466 vs. 0.100
# Recall = 0.698 vs. 1.000
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.059
# F1 = 0.585 vs. 0.082
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.052
# F1 = 0.347 vs. 0.098
# Precision = 0.247 vs. 0.052
# Recall = 0.582 vs. 0.919
# Minibatch Loss= 0.089221
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 0.955 vs. 0.063
# F1 = 0.917 vs. 0.097
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.553 vs. 0.121
# F1 = 0.578 vs. 0.202
# Precision = 0.483 vs. 0.112
# Recall = 0.721 vs. 1.000
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.059
# F1 = 0.582 vs. 0.082
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.052
# F1 = 0.353 vs. 0.097
# Precision = 0.270 vs. 0.051
# Recall = 0.509 vs. 0.974
# Minibatch Loss= 0.084932
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 0.905 vs. 0.062
# F1 = 0.851 vs. 0.090
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.478 vs. 0.090
# F1 = 0.509 vs. 0.163
# Precision = 0.454 vs. 0.090
# Recall = 0.579 vs. 0.832
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.536 vs. 0.061
# F1 = 0.568 vs. 0.085
# Accuracy = 0.833 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.052
# F1 = 0.343 vs. 0.100
# Precision = 0.250 vs. 0.055
# Recall = 0.545 vs. 0.566
# Minibatch Loss= 0.116268
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 0.966 vs. 0.060
# F1 = 0.925 vs. 0.090
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.547 vs. 0.097
# F1 = 0.573 vs. 0.177
# Precision = 0.455 vs. 0.098
# Recall = 0.776 vs. 0.931
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.060
# F1 = 0.588 vs. 0.089
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.050
# F1 = 0.350 vs. 0.096
# Precision = 0.248 vs. 0.051
# Recall = 0.592 vs. 1.000
# Minibatch Loss= 0.076709
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.060
# F1 = 0.939 vs. 0.088
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.555 vs. 0.079
# F1 = 0.587 vs. 0.157
# Precision = 0.470 vs. 0.085
# Recall = 0.782 vs. 1.000
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.058
# F1 = 0.577 vs. 0.079
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.054
# F1 = 0.348 vs. 0.099
# Precision = 0.240 vs. 0.055
# Recall = 0.639 vs. 0.564
# Minibatch Loss= 0.065229
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.060
# F1 = 0.939 vs. 0.088
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.593 vs. 0.091
# F1 = 0.600 vs. 0.154
# Precision = 0.495 vs. 0.084
# Recall = 0.763 vs. 0.961
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.059
# F1 = 0.568 vs. 0.078
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.054
# F1 = 0.348 vs. 0.099
# Precision = 0.261 vs. 0.052
# Recall = 0.522 vs. 0.896
# Minibatch Loss= 0.057595
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.061
# F1 = 0.946 vs. 0.092
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.094
# F1 = 0.632 vs. 0.168
# Precision = 0.543 vs. 0.092
# Recall = 0.756 vs. 1.000
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.059
# F1 = 0.563 vs. 0.081
# Accuracy = 0.856 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.048
# F1 = 0.340 vs. 0.100
# Precision = 0.244 vs. 0.053
# Recall = 0.558 vs. 0.927
# Minibatch Loss= 0.057927
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 0.942 vs. 0.062
# F1 = 0.897 vs. 0.091
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.540 vs. 0.099
# F1 = 0.557 vs. 0.167
# Precision = 0.463 vs. 0.092
# Recall = 0.698 vs. 0.913
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.058
# F1 = 0.576 vs. 0.079
# Accuracy = 0.843 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.058
# F1 = 0.361 vs. 0.100
# Precision = 0.283 vs. 0.055
# Recall = 0.501 vs. 0.569
# Minibatch Loss= 0.088173
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.061
# F1 = 0.951 vs. 0.089
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.618 vs. 0.093
# F1 = 0.622 vs. 0.168
# Precision = 0.544 vs. 0.092
# Recall = 0.726 vs. 0.941
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.542 vs. 0.059
# F1 = 0.570 vs. 0.079
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.051
# F1 = 0.361 vs. 0.098
# Precision = 0.302 vs. 0.052
# Recall = 0.447 vs. 0.912
# Minibatch Loss= 0.057019
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.061
# F1 = 0.963 vs. 0.091
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.082
# F1 = 0.675 vs. 0.156
# Precision = 0.622 vs. 0.085
# Recall = 0.737 vs. 0.868
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.058
# F1 = 0.569 vs. 0.079
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.056
# F1 = 0.364 vs. 0.097
# Precision = 0.277 vs. 0.051
# Recall = 0.532 vs. 0.995
# Minibatch Loss= 0.047126
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.062
# F1 = 0.957 vs. 0.093
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.645 vs. 0.097
# F1 = 0.658 vs. 0.174
# Precision = 0.546 vs. 0.095
# Recall = 0.829 vs. 0.982
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.539 vs. 0.058
# F1 = 0.567 vs. 0.079
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.053
# F1 = 0.363 vs. 0.097
# Precision = 0.279 vs. 0.051
# Recall = 0.519 vs. 0.997
# Minibatch Loss= 0.051878
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.061
# F1 = 0.963 vs. 0.093
# Accuracy = 0.951 vs. 0.056
# CHANGE DETECTION
# AUC = 0.682 vs. 0.091
# F1 = 0.676 vs. 0.165
# Precision = 0.577 vs. 0.095
# Recall = 0.817 vs. 0.635
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.537 vs. 0.060
# F1 = 0.565 vs. 0.081
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.051
# F1 = 0.364 vs. 0.098
# Precision = 0.272 vs. 0.053
# Recall = 0.551 vs. 0.673
# Minibatch Loss= 0.043036
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.062
# F1 = 0.966 vs. 0.093
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.100
# F1 = 0.676 vs. 0.187
# Precision = 0.580 vs. 0.104
# Recall = 0.808 vs. 0.936
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.059
# F1 = 0.573 vs. 0.082
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.056
# F1 = 0.358 vs. 0.103
# Precision = 0.274 vs. 0.055
# Recall = 0.517 vs. 0.834
# Minibatch Loss= 0.048055
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.061
# F1 = 0.969 vs. 0.090
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.689 vs. 0.093
# F1 = 0.687 vs. 0.162
# Precision = 0.624 vs. 0.088
# Recall = 0.764 vs. 0.998
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.533 vs. 0.059
# F1 = 0.562 vs. 0.079
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.048
# F1 = 0.366 vs. 0.098
# Precision = 0.295 vs. 0.052
# Recall = 0.481 vs. 0.896
# Minibatch Loss= 0.043636
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.061
# F1 = 0.966 vs. 0.090
# Accuracy = 0.949 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.092
# F1 = 0.679 vs. 0.176
# Precision = 0.564 vs. 0.097
# Recall = 0.853 vs. 0.946
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.541 vs. 0.058
# F1 = 0.570 vs. 0.079
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.048
# F1 = 0.365 vs. 0.096
# Precision = 0.297 vs. 0.051
# Recall = 0.473 vs. 1.000
# Minibatch Loss= 0.046295
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 0.947 vs. 0.060
# F1 = 0.893 vs. 0.092
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.606 vs. 0.093
# F1 = 0.593 vs. 0.173
# Precision = 0.485 vs. 0.095
# Recall = 0.764 vs. 0.975
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.530 vs. 0.059
# F1 = 0.547 vs. 0.081
# Accuracy = 0.845 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.054
# F1 = 0.357 vs. 0.097
# Precision = 0.245 vs. 0.052
# Recall = 0.657 vs. 0.629
# Minibatch Loss= 0.101663
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.061
# F1 = 0.936 vs. 0.090
# Accuracy = 0.948 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.085
# F1 = 0.652 vs. 0.153
# Precision = 0.584 vs. 0.083
# Recall = 0.738 vs. 0.966
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.059
# F1 = 0.609 vs. 0.082
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.051
# F1 = 0.363 vs. 0.099
# Precision = 0.273 vs. 0.052
# Recall = 0.540 vs. 0.849
# Minibatch Loss= 0.052780
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.061
# F1 = 0.963 vs. 0.091
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.645 vs. 0.083
# F1 = 0.663 vs. 0.157
# Precision = 0.597 vs. 0.085
# Recall = 0.747 vs. 0.980
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.058
# F1 = 0.586 vs. 0.081
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.051
# F1 = 0.381 vs. 0.096
# Precision = 0.301 vs. 0.051
# Recall = 0.519 vs. 1.000
# Minibatch Loss= 0.043871
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.061
# F1 = 0.967 vs. 0.091
# Accuracy = 0.952 vs. 0.056
# CHANGE DETECTION
# AUC = 0.710 vs. 0.089
# F1 = 0.700 vs. 0.161
# Precision = 0.590 vs. 0.088
# Recall = 0.859 vs. 0.998
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.059
# F1 = 0.592 vs. 0.080
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.052
# F1 = 0.373 vs. 0.096
# Precision = 0.302 vs. 0.051
# Recall = 0.488 vs. 1.000
# Minibatch Loss= 0.041054
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.062
# F1 = 0.945 vs. 0.091
# Accuracy = 0.952 vs. 0.056
# CHANGE DETECTION
# AUC = 0.702 vs. 0.089
# F1 = 0.693 vs. 0.168
# Precision = 0.626 vs. 0.092
# Recall = 0.777 vs. 0.998
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.059
# F1 = 0.600 vs. 0.081
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.053
# F1 = 0.371 vs. 0.100
# Precision = 0.273 vs. 0.053
# Recall = 0.582 vs. 0.831
# Minibatch Loss= 0.049505
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.060
# F1 = 0.964 vs. 0.090
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.696 vs. 0.086
# F1 = 0.706 vs. 0.154
# Precision = 0.620 vs. 0.083
# Recall = 0.822 vs. 1.000
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.060
# F1 = 0.601 vs. 0.082
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.052
# F1 = 0.365 vs. 0.098
# Precision = 0.309 vs. 0.052
# Recall = 0.444 vs. 0.868
# Minibatch Loss= 0.038505
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.063
# F1 = 0.969 vs. 0.094
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.723 vs. 0.101
# F1 = 0.711 vs. 0.173
# Precision = 0.623 vs. 0.095
# Recall = 0.828 vs. 0.996
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.058
# F1 = 0.596 vs. 0.081
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.052
# F1 = 0.362 vs. 0.100
# Precision = 0.297 vs. 0.057
# Recall = 0.465 vs. 0.405
# Minibatch Loss= 0.040474
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.979 vs. 0.092
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.767 vs. 0.095
# F1 = 0.737 vs. 0.168
# Precision = 0.652 vs. 0.092
# Recall = 0.848 vs. 0.978
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.578 vs. 0.059
# F1 = 0.595 vs. 0.080
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.050
# F1 = 0.362 vs. 0.097
# Precision = 0.311 vs. 0.051
# Recall = 0.434 vs. 0.995
# Minibatch Loss= 0.034140
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.983 vs. 0.093
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.793 vs. 0.108
# F1 = 0.755 vs. 0.190
# Precision = 0.681 vs. 0.105
# Recall = 0.847 vs. 0.952
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.058
# F1 = 0.598 vs. 0.081
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.054
# F1 = 0.359 vs. 0.100
# Precision = 0.271 vs. 0.056
# Recall = 0.532 vs. 0.455
# Minibatch Loss= 0.036775
# Training: 5500
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.063
# F1 = 0.979 vs. 0.092
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.781 vs. 0.092
# F1 = 0.755 vs. 0.172
# Precision = 0.662 vs. 0.094
# Recall = 0.879 vs. 0.978
# Validation: 5500
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.059
# F1 = 0.588 vs. 0.080
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.051
# F1 = 0.360 vs. 0.097
# Precision = 0.278 vs. 0.052
# Recall = 0.512 vs. 0.738
# Minibatch Loss= 0.032910
# Training: 5600
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.061
# F1 = 0.983 vs. 0.089
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.812 vs. 0.093
# F1 = 0.785 vs. 0.160
# Precision = 0.707 vs. 0.090
# Recall = 0.883 vs. 0.747
# Validation: 5600
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.058
# F1 = 0.585 vs. 0.079
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.052
# F1 = 0.362 vs. 0.100
# Precision = 0.281 vs. 0.053
# Recall = 0.509 vs. 0.761
# Minibatch Loss= 0.027216
# Training: 5700
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.060
# F1 = 0.979 vs. 0.088
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.822 vs. 0.086
# F1 = 0.793 vs. 0.161
# Precision = 0.702 vs. 0.088
# Recall = 0.912 vs. 0.977
# Validation: 5700
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.059
# F1 = 0.581 vs. 0.082
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.052
# F1 = 0.355 vs. 0.097
# Precision = 0.282 vs. 0.051
# Recall = 0.478 vs. 0.997
# Minibatch Loss= 0.028768
# Training: 5800
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.984 vs. 0.091
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.789 vs. 0.091
# F1 = 0.768 vs. 0.165
# Precision = 0.697 vs. 0.093
# Recall = 0.855 vs. 0.765
# Validation: 5800
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.059
# F1 = 0.589 vs. 0.082
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.052
# F1 = 0.375 vs. 0.099
# Precision = 0.326 vs. 0.052
# Recall = 0.442 vs. 0.849
# Minibatch Loss= 0.029446
# Training: 5900
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.984 vs. 0.091
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.821 vs. 0.082
# F1 = 0.786 vs. 0.154
# Precision = 0.716 vs. 0.083
# Recall = 0.870 vs. 1.000
# Validation: 5900
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.058
# F1 = 0.581 vs. 0.080
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.054
# F1 = 0.360 vs. 0.104
# Precision = 0.304 vs. 0.057
# Recall = 0.442 vs. 0.660
# Minibatch Loss= 0.026925
# Training: 6000
# ACTIVITY RECOGNITION
# AUC = 0.955 vs. 0.061
# F1 = 0.906 vs. 0.092
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.606 vs. 0.082
# F1 = 0.603 vs. 0.150
# Precision = 0.509 vs. 0.082
# Recall = 0.741 vs. 0.886
# Validation: 6000
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.059
# F1 = 0.633 vs. 0.082
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.052
# F1 = 0.370 vs. 0.097
# Precision = 0.282 vs. 0.051
# Recall = 0.535 vs. 0.984
# Minibatch Loss= 0.066976
# Training: 6100
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.062
# F1 = 0.965 vs. 0.093
# Accuracy = 0.962 vs. 0.056
# CHANGE DETECTION
# AUC = 0.766 vs. 0.096
# F1 = 0.728 vs. 0.175
# Precision = 0.653 vs. 0.097
# Recall = 0.824 vs. 0.948
# Validation: 6100
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.058
# F1 = 0.621 vs. 0.080
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.054
# F1 = 0.380 vs. 0.102
# Precision = 0.339 vs. 0.056
# Recall = 0.431 vs. 0.548
# Minibatch Loss= 0.040561
# Training: 6200
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.061
# F1 = 0.972 vs. 0.092
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.755 vs. 0.089
# F1 = 0.755 vs. 0.174
# Precision = 0.679 vs. 0.095
# Recall = 0.850 vs. 0.987
# Validation: 6200
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.058
# F1 = 0.618 vs. 0.079
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.047
# F1 = 0.367 vs. 0.098
# Precision = 0.315 vs. 0.052
# Recall = 0.439 vs. 0.816
# Minibatch Loss= 0.036691
# Training: 6300
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.981 vs. 0.091
# Accuracy = 0.965 vs. 0.056
# CHANGE DETECTION
# AUC = 0.822 vs. 0.101
# F1 = 0.804 vs. 0.185
# Precision = 0.725 vs. 0.105
# Recall = 0.902 vs. 0.755
# Validation: 6300
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.059
# F1 = 0.604 vs. 0.080
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.049
# F1 = 0.360 vs. 0.097
# Precision = 0.303 vs. 0.051
# Recall = 0.444 vs. 1.000
# Minibatch Loss= 0.031493
# Training: 6400
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.983 vs. 0.093
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.835 vs. 0.092
# F1 = 0.807 vs. 0.173
# Precision = 0.714 vs. 0.096
# Recall = 0.928 vs. 0.845
# Validation: 6400
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.059
# F1 = 0.605 vs. 0.078
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.048
# F1 = 0.364 vs. 0.096
# Precision = 0.322 vs. 0.051
# Recall = 0.418 vs. 0.984
# Minibatch Loss= 0.028493
# Training: 6500
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.983 vs. 0.093
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.854 vs. 0.099
# F1 = 0.810 vs. 0.180
# Precision = 0.731 vs. 0.102
# Recall = 0.908 vs. 0.780
# Validation: 6500
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.058
# F1 = 0.597 vs. 0.079
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.050
# F1 = 0.368 vs. 0.099
# Precision = 0.304 vs. 0.053
# Recall = 0.468 vs. 0.821
# Minibatch Loss= 0.029673
# Training: 6600
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.983 vs. 0.090
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.865 vs. 0.087
# F1 = 0.826 vs. 0.162
# Precision = 0.754 vs. 0.089
# Recall = 0.914 vs. 0.922
# Validation: 6600
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.058
# F1 = 0.599 vs. 0.077
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.052
# F1 = 0.377 vs. 0.098
# Precision = 0.296 vs. 0.053
# Recall = 0.519 vs. 0.683
# Minibatch Loss= 0.025273
# Training: 6700
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.989 vs. 0.091
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.840 vs. 0.084
# F1 = 0.811 vs. 0.154
# Precision = 0.737 vs. 0.084
# Recall = 0.901 vs. 0.943
# Validation: 6700
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.059
# F1 = 0.595 vs. 0.082
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.056
# F1 = 0.366 vs. 0.101
# Precision = 0.286 vs. 0.056
# Recall = 0.509 vs. 0.470
# Minibatch Loss= 0.021641
# Training: 6800
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.988 vs. 0.094
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.854 vs. 0.093
# F1 = 0.823 vs. 0.175
# Precision = 0.767 vs. 0.096
# Recall = 0.889 vs. 0.971
# Validation: 6800
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.060
# F1 = 0.588 vs. 0.083
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.052
# F1 = 0.356 vs. 0.100
# Precision = 0.274 vs. 0.054
# Recall = 0.506 vs. 0.626
# Minibatch Loss= 0.024090
# Training: 6900
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.991 vs. 0.094
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.879 vs. 0.108
# F1 = 0.845 vs. 0.184
# Precision = 0.778 vs. 0.102
# Recall = 0.925 vs. 0.967
# Validation: 6900
# ACTIVITY RECOGNITION
# AUC = 0.564 vs. 0.059
# F1 = 0.585 vs. 0.080
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.049
# F1 = 0.360 vs. 0.100
# Precision = 0.314 vs. 0.053
# Recall = 0.421 vs. 0.831
# Minibatch Loss= 0.024523
# Training: 7000
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.989 vs. 0.093
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.092
# F1 = 0.849 vs. 0.173
# Precision = 0.782 vs. 0.095
# Recall = 0.929 vs. 0.990
# Validation: 7000
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.059
# F1 = 0.586 vs. 0.086
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.050
# F1 = 0.359 vs. 0.096
# Precision = 0.320 vs. 0.051
# Recall = 0.410 vs. 0.982
# Minibatch Loss= 0.022212
# Training: 7100
# ACTIVITY RECOGNITION
# AUC = 0.891 vs. 0.061
# F1 = 0.850 vs. 0.092
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.621 vs. 0.093
# F1 = 0.615 vs. 0.177
# Precision = 0.543 vs. 0.099
# Recall = 0.709 vs. 0.864
# Validation: 7100
# ACTIVITY RECOGNITION
# AUC = 0.499 vs. 0.059
# F1 = 0.541 vs. 0.081
# Accuracy = 0.831 vs. 0.056
# CHANGE DETECTION
# AUC = 0.253 vs. 0.054
# F1 = 0.319 vs. 0.097
# Precision = 0.214 vs. 0.051
# Recall = 0.623 vs. 0.969
# Minibatch Loss= 0.165558
# Training: 7200
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.061
# F1 = 0.956 vs. 0.091
# Accuracy = 0.950 vs. 0.056
# CHANGE DETECTION
# AUC = 0.766 vs. 0.092
# F1 = 0.718 vs. 0.168
# Precision = 0.618 vs. 0.093
# Recall = 0.857 vs. 0.848
# Validation: 7200
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.059
# F1 = 0.626 vs. 0.084
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.055
# F1 = 0.376 vs. 0.097
# Precision = 0.270 vs. 0.051
# Recall = 0.623 vs. 0.932
# Minibatch Loss= 0.044617
# Training: 7300
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.981 vs. 0.090
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.880 vs. 0.085
# F1 = 0.841 vs. 0.162
# Precision = 0.769 vs. 0.088
# Recall = 0.927 vs. 1.000
# Validation: 7300
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.058
# F1 = 0.619 vs. 0.081
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.052
# F1 = 0.373 vs. 0.103
# Precision = 0.292 vs. 0.056
# Recall = 0.517 vs. 0.655
# Minibatch Loss= 0.023024
# Training: 7400
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.988 vs. 0.093
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.870 vs. 0.081
# F1 = 0.838 vs. 0.159
# Precision = 0.762 vs. 0.086
# Recall = 0.931 vs. 0.987
# Validation: 7400
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.059
# F1 = 0.606 vs. 0.082
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.056
# F1 = 0.368 vs. 0.100
# Precision = 0.287 vs. 0.053
# Recall = 0.514 vs. 0.818
# Minibatch Loss= 0.021932
# Training: 7500
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.991 vs. 0.095
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.104
# F1 = 0.855 vs. 0.181
# Precision = 0.777 vs. 0.100
# Recall = 0.951 vs. 0.998
# Validation: 7500
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.058
# F1 = 0.600 vs. 0.080
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.056
# F1 = 0.373 vs. 0.101
# Precision = 0.304 vs. 0.060
# Recall = 0.483 vs. 0.317
# Minibatch Loss= 0.022226
# Training: 7600
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.062
# F1 = 0.989 vs. 0.091
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.873 vs. 0.086
# F1 = 0.872 vs. 0.164
# Precision = 0.831 vs. 0.090
# Recall = 0.917 vs. 0.949
# Validation: 7600
# ACTIVITY RECOGNITION
# AUC = 0.575 vs. 0.059
# F1 = 0.591 vs. 0.080
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.047
# F1 = 0.373 vs. 0.100
# Precision = 0.303 vs. 0.053
# Recall = 0.483 vs. 0.896
# Minibatch Loss= 0.020062
# Training: 7700
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.991 vs. 0.093
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.913 vs. 0.111
# F1 = 0.883 vs. 0.195
# Precision = 0.838 vs. 0.108
# Recall = 0.934 vs. 1.000
# Validation: 7700
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.058
# F1 = 0.586 vs. 0.078
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.051
# F1 = 0.368 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.519 vs. 0.984
# Minibatch Loss= 0.022222
# Training: 7800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.995 vs. 0.089
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.912 vs. 0.085
# F1 = 0.884 vs. 0.151
# Precision = 0.820 vs. 0.083
# Recall = 0.959 vs. 0.820
# Validation: 7800
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.059
# F1 = 0.585 vs. 0.082
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.052
# F1 = 0.366 vs. 0.097
# Precision = 0.299 vs. 0.053
# Recall = 0.470 vs. 0.558
# Minibatch Loss= 0.016075
# Training: 7900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.063
# F1 = 0.993 vs. 0.096
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.102
# F1 = 0.899 vs. 0.186
# Precision = 0.836 vs. 0.104
# Recall = 0.972 vs. 0.884
# Validation: 7900
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.058
# F1 = 0.586 vs. 0.078
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.053
# F1 = 0.361 vs. 0.097
# Precision = 0.272 vs. 0.051
# Recall = 0.540 vs. 0.925
# Minibatch Loss= 0.018649
# Training: 8000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.993 vs. 0.092
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.938 vs. 0.090
# F1 = 0.905 vs. 0.158
# Precision = 0.866 vs. 0.086
# Recall = 0.948 vs. 0.982
# Validation: 8000
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.058
# F1 = 0.584 vs. 0.078
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.051
# F1 = 0.354 vs. 0.097
# Precision = 0.259 vs. 0.051
# Recall = 0.558 vs. 0.953
# Minibatch Loss= 0.015287
# Training: 8100
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.993 vs. 0.095
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.925 vs. 0.104
# F1 = 0.898 vs. 0.186
# Precision = 0.836 vs. 0.103
# Recall = 0.970 vs. 0.992
# Validation: 8100
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.058
# F1 = 0.584 vs. 0.080
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.054
# F1 = 0.354 vs. 0.099
# Precision = 0.265 vs. 0.053
# Recall = 0.535 vs. 0.847
# Minibatch Loss= 0.018029
# Training: 8200
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.994 vs. 0.093
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.945 vs. 0.101
# F1 = 0.912 vs. 0.172
# Precision = 0.871 vs. 0.095
# Recall = 0.957 vs. 0.948
# Validation: 8200
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.058
# F1 = 0.585 vs. 0.078
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.054
# F1 = 0.364 vs. 0.099
# Precision = 0.288 vs. 0.053
# Recall = 0.494 vs. 0.769
# Minibatch Loss= 0.015907
# Training: 8300
# ACTIVITY RECOGNITION
# AUC = 0.935 vs. 0.060
# F1 = 0.887 vs. 0.092
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.569 vs. 0.086
# F1 = 0.596 vs. 0.162
# Precision = 0.480 vs. 0.090
# Recall = 0.784 vs. 0.759
# Validation: 8300
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.058
# F1 = 0.622 vs. 0.079
# Accuracy = 0.812 vs. 0.056
# CHANGE DETECTION
# AUC = 0.255 vs. 0.055
# F1 = 0.351 vs. 0.103
# Precision = 0.285 vs. 0.060
# Recall = 0.457 vs. 0.340
# Minibatch Loss= 0.110332
# Training: 8400
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.062
# F1 = 0.968 vs. 0.093
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.825 vs. 0.106
# F1 = 0.770 vs. 0.185
# Precision = 0.699 vs. 0.102
# Recall = 0.857 vs. 0.977
# Validation: 8400
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.058
# F1 = 0.617 vs. 0.084
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.056
# F1 = 0.385 vs. 0.098
# Precision = 0.296 vs. 0.071
# Recall = 0.551 vs. 0.161
# Minibatch Loss= 0.035765
# Training: 8500
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.982 vs. 0.095
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.892 vs. 0.111
# F1 = 0.841 vs. 0.190
# Precision = 0.780 vs. 0.109
# Recall = 0.912 vs. 0.720
# Validation: 8500
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.058
# F1 = 0.611 vs. 0.079
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.053
# F1 = 0.386 vs. 0.097
# Precision = 0.298 vs. 0.051
# Recall = 0.548 vs. 0.984
# Minibatch Loss= 0.025888
# Training: 8600
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.985 vs. 0.090
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.898 vs. 0.093
# F1 = 0.859 vs. 0.166
# Precision = 0.807 vs. 0.091
# Recall = 0.917 vs. 1.000
# Validation: 8600
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.058
# F1 = 0.614 vs. 0.077
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.052
# F1 = 0.386 vs. 0.099
# Precision = 0.301 vs. 0.054
# Recall = 0.538 vs. 0.642
# Minibatch Loss= 0.020078
# Training: 8700
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.992 vs. 0.094
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.918 vs. 0.098
# F1 = 0.889 vs. 0.179
# Precision = 0.850 vs. 0.098
# Recall = 0.932 vs. 0.989
# Validation: 8700
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.059
# F1 = 0.608 vs. 0.081
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.058
# F1 = 0.379 vs. 0.099
# Precision = 0.310 vs. 0.054
# Recall = 0.486 vs. 0.644
# Minibatch Loss= 0.020038
# Training: 8800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.993 vs. 0.093
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.939 vs. 0.100
# F1 = 0.903 vs. 0.177
# Precision = 0.874 vs. 0.097
# Recall = 0.935 vs. 0.989
# Validation: 8800
# ACTIVITY RECOGNITION
# AUC = 0.578 vs. 0.058
# F1 = 0.605 vs. 0.078
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.051
# F1 = 0.372 vs. 0.099
# Precision = 0.298 vs. 0.053
# Recall = 0.496 vs. 0.805
# Minibatch Loss= 0.017791
# Training: 8900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.993 vs. 0.091
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.951 vs. 0.084
# F1 = 0.916 vs. 0.152
# Precision = 0.908 vs. 0.082
# Recall = 0.924 vs. 0.998
# Validation: 8900
# ACTIVITY RECOGNITION
# AUC = 0.575 vs. 0.058
# F1 = 0.605 vs. 0.079
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.052
# F1 = 0.364 vs. 0.097
# Precision = 0.292 vs. 0.051
# Recall = 0.483 vs. 0.974
# Minibatch Loss= 0.014137
# Training: 9000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.993 vs. 0.087
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.914 vs. 0.080
# F1 = 0.893 vs. 0.153
# Precision = 0.839 vs. 0.084
# Recall = 0.954 vs. 0.829
# Validation: 9000
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.058
# F1 = 0.604 vs. 0.077
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.049
# F1 = 0.366 vs. 0.097
# Precision = 0.328 vs. 0.051
# Recall = 0.413 vs. 0.997
# Minibatch Loss= 0.014532
# Training: 9100
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.994 vs. 0.091
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.936 vs. 0.089
# F1 = 0.914 vs. 0.167
# Precision = 0.858 vs. 0.091
# Recall = 0.978 vs. 0.984
# Validation: 9100
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.059
# F1 = 0.600 vs. 0.083
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.056
# F1 = 0.369 vs. 0.103
# Precision = 0.305 vs. 0.057
# Recall = 0.468 vs. 0.569
# Minibatch Loss= 0.015769
# Training: 9200
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.997 vs. 0.088
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.079
# F1 = 0.941 vs. 0.156
# Precision = 0.895 vs. 0.085
# Recall = 0.993 vs. 0.998
# Validation: 9200
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.059
# F1 = 0.599 vs. 0.082
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.050
# F1 = 0.360 vs. 0.099
# Precision = 0.291 vs. 0.052
# Recall = 0.470 vs. 0.868
# Minibatch Loss= 0.011590
# Training: 9300
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.995 vs. 0.095
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.967 vs. 0.105
# F1 = 0.941 vs. 0.188
# Precision = 0.922 vs. 0.104
# Recall = 0.961 vs. 0.956
# Validation: 9300
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.058
# F1 = 0.600 vs. 0.082
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.054
# F1 = 0.354 vs. 0.104
# Precision = 0.290 vs. 0.061
# Recall = 0.455 vs. 0.340
# Minibatch Loss= 0.013360
# Training: 9400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.997 vs. 0.095
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.106
# F1 = 0.949 vs. 0.186
# Precision = 0.922 vs. 0.103
# Recall = 0.978 vs. 0.920
# Validation: 9400
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.058
# F1 = 0.599 vs. 0.079
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.049
# F1 = 0.356 vs. 0.097
# Precision = 0.281 vs. 0.051
# Recall = 0.488 vs. 0.997
# Minibatch Loss= 0.012151
# Training: 9500
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.061
# F1 = 0.962 vs. 0.092
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.851 vs. 0.105
# F1 = 0.789 vs. 0.183
# Precision = 0.756 vs. 0.102
# Recall = 0.825 vs. 0.912
# Validation: 9500
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.058
# F1 = 0.617 vs. 0.080
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.051
# F1 = 0.383 vs. 0.097
# Precision = 0.340 vs. 0.051
# Recall = 0.439 vs. 1.000
# Minibatch Loss= 0.054615
# Training: 9600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.993 vs. 0.092
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.953 vs. 0.095
# F1 = 0.912 vs. 0.169
# Precision = 0.876 vs. 0.096
# Recall = 0.951 vs. 0.729
# Validation: 9600
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.058
# F1 = 0.614 vs. 0.081
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.053
# F1 = 0.377 vs. 0.099
# Precision = 0.296 vs. 0.052
# Recall = 0.517 vs. 0.953
# Minibatch Loss= 0.015410
# Training: 9700
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.996 vs. 0.091
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.091
# F1 = 0.937 vs. 0.173
# Precision = 0.894 vs. 0.095
# Recall = 0.985 vs. 0.945
# Validation: 9700
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.059
# F1 = 0.602 vs. 0.083
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.052
# F1 = 0.377 vs. 0.099
# Precision = 0.361 vs. 0.053
# Recall = 0.395 vs. 0.761
# Minibatch Loss= 0.012828
# Training: 9800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.064
# F1 = 0.995 vs. 0.094
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.963 vs. 0.106
# F1 = 0.939 vs. 0.192
# Precision = 0.897 vs. 0.106
# Recall = 0.985 vs. 1.000
# Validation: 9800
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.058
# F1 = 0.599 vs. 0.078
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.050
# F1 = 0.371 vs. 0.099
# Precision = 0.351 vs. 0.053
# Recall = 0.392 vs. 0.862
# Minibatch Loss= 0.013918
# Training: 9900
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.092
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.959 vs. 0.107
# F1 = 0.950 vs. 0.194
# Precision = 0.921 vs. 0.107
# Recall = 0.982 vs. 0.999
# Validation: 9900
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.058
# F1 = 0.599 vs. 0.078
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.054
# F1 = 0.372 vs. 0.100
# Precision = 0.341 vs. 0.055
# Recall = 0.410 vs. 0.574
# Minibatch Loss= 0.013532
# Training: 10000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.097
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.112
# F1 = 0.953 vs. 0.205
# Precision = 0.920 vs. 0.114
# Recall = 0.989 vs. 1.000
# Validation: 10000
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.058
# F1 = 0.599 vs. 0.078
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.051
# F1 = 0.373 vs. 0.096
# Precision = 0.318 vs. 0.051
# Recall = 0.452 vs. 1.000
# Minibatch Loss= 0.012744
# Training: 10100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.995 vs. 0.097
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.959 vs. 0.099
# F1 = 0.948 vs. 0.174
# Precision = 0.925 vs. 0.096
# Recall = 0.973 vs. 1.000
# Validation: 10100
# ACTIVITY RECOGNITION
# AUC = 0.578 vs. 0.059
# F1 = 0.596 vs. 0.078
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.052
# F1 = 0.363 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.499 vs. 0.956
# Minibatch Loss= 0.012403
# Training: 10200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.998 vs. 0.087
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.978 vs. 0.072
# F1 = 0.956 vs. 0.135
# Precision = 0.926 vs. 0.072
# Recall = 0.987 vs. 1.000
# Validation: 10200
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.059
# F1 = 0.594 vs. 0.082
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.054
# F1 = 0.369 vs. 0.098
# Precision = 0.301 vs. 0.054
# Recall = 0.475 vs. 0.527
# Minibatch Loss= 0.007666
# Training: 10300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.997 vs. 0.094
# Accuracy = 0.993 vs. 0.056
# ...
# Precision = 0.311 vs. 0.053
# Recall = 0.488 vs. 0.595
# Minibatch Loss= 0.005490
# Training: 16600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.103
# F1 = 0.993 vs. 0.176
# Precision = 0.987 vs. 0.100
# Recall = 0.998 vs. 0.744
# Validation: 16600
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.058
# F1 = 0.631 vs. 0.078
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.050
# F1 = 0.387 vs. 0.098
# Precision = 0.307 vs. 0.051
# Recall = 0.525 vs. 0.979
# Minibatch Loss= 0.004636
# Training: 16700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.094
# F1 = 0.997 vs. 0.169
# Precision = 0.993 vs. 0.098
# Recall = 1.000 vs. 0.631
# Validation: 16700
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.058
# F1 = 0.632 vs. 0.077
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.055
# F1 = 0.388 vs. 0.100
# Precision = 0.318 vs. 0.053
# Recall = 0.499 vs. 0.816
# Minibatch Loss= 0.004120
# Training: 16800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.092
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.095
# F1 = 0.995 vs. 0.161
# Precision = 0.991 vs. 0.099
# Recall = 1.000 vs. 0.440
# Validation: 16800
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.061
# F1 = 0.632 vs. 0.082
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.049
# F1 = 0.389 vs. 0.097
# Precision = 0.318 vs. 0.051
# Recall = 0.499 vs. 0.805
# Minibatch Loss= 0.003915
# Training: 16900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.088
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.094
# F1 = 0.997 vs. 0.172
# Precision = 0.997 vs. 0.095
# Recall = 0.998 vs. 0.957
# Validation: 16900
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.058
# F1 = 0.632 vs. 0.080
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.051
# F1 = 0.387 vs. 0.097
# Precision = 0.320 vs. 0.051
# Recall = 0.491 vs. 1.000
# Minibatch Loss= 0.003725
# Training: 17000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.098
# F1 = 0.995 vs. 0.178
# Precision = 0.992 vs. 0.099
# Recall = 0.998 vs. 0.844
# Validation: 17000
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.059
# F1 = 0.631 vs. 0.082
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.061
# F1 = 0.384 vs. 0.104
# Precision = 0.307 vs. 0.060
# Recall = 0.512 vs. 0.403
# Minibatch Loss= 0.003421
# Training: 17100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.999 vs. 0.096
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 0.999 vs. 0.176
# Precision = 0.998 vs. 0.098
# Recall = 1.000 vs. 0.900
# Validation: 17100
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.058
# F1 = 0.631 vs. 0.076
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.049
# F1 = 0.383 vs. 0.098
# Precision = 0.309 vs. 0.052
# Recall = 0.506 vs. 0.938
# Minibatch Loss= 0.003545
# Training: 17200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.152
# Precision = 0.998 vs. 0.083
# Recall = 1.000 vs. 0.888
# Validation: 17200
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.059
# F1 = 0.629 vs. 0.081
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.049
# F1 = 0.384 vs. 0.097
# Precision = 0.307 vs. 0.051
# Recall = 0.514 vs. 0.927
# Minibatch Loss= 0.002656
# Training: 17300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.087
# F1 = 0.999 vs. 0.163
# Precision = 0.998 vs. 0.089
# Recall = 1.000 vs. 0.979
# Validation: 17300
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.058
# F1 = 0.629 vs. 0.078
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.045
# F1 = 0.380 vs. 0.097
# Precision = 0.295 vs. 0.051
# Recall = 0.535 vs. 1.000
# Minibatch Loss= 0.003070
# Training: 17400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 0.999 vs. 0.155
# Precision = 0.998 vs. 0.084
# Recall = 1.000 vs. 0.998
# Validation: 17400
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.060
# F1 = 0.628 vs. 0.082
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.054
# F1 = 0.378 vs. 0.098
# Precision = 0.294 vs. 0.057
# Recall = 0.530 vs. 0.358
# Minibatch Loss= 0.002679
# Training: 17500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.079
# F1 = 0.995 vs. 0.156
# Precision = 0.993 vs. 0.085
# Recall = 0.998 vs. 0.904
# Validation: 17500
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.060
# F1 = 0.629 vs. 0.086
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.056
# F1 = 0.378 vs. 0.099
# Precision = 0.293 vs. 0.053
# Recall = 0.532 vs. 0.831
# Minibatch Loss= 0.002784
# Training: 17600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.085
# F1 = 0.996 vs. 0.154
# Precision = 0.992 vs. 0.083
# Recall = 1.000 vs. 0.996
# Validation: 17600
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.059
# F1 = 0.626 vs. 0.079
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.057
# F1 = 0.380 vs. 0.098
# Precision = 0.296 vs. 0.053
# Recall = 0.532 vs. 0.634
# Minibatch Loss= 0.002479
# Training: 17700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.166
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.828
# Validation: 17700
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.059
# F1 = 0.626 vs. 0.081
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.051
# F1 = 0.380 vs. 0.098
# Precision = 0.293 vs. 0.052
# Recall = 0.540 vs. 0.805
# Minibatch Loss= 0.002399
# Training: 17800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 0.858
# Validation: 17800
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.058
# F1 = 0.626 vs. 0.080
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.048
# F1 = 0.380 vs. 0.096
# Precision = 0.295 vs. 0.051
# Recall = 0.532 vs. 0.987
# Minibatch Loss= 0.002433
# Training: 17900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.086
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 0.999 vs. 0.159
# Precision = 1.000 vs. 0.087
# Recall = 0.998 vs. 0.942
# Validation: 17900
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.058
# F1 = 0.626 vs. 0.078
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.053
# F1 = 0.376 vs. 0.098
# Precision = 0.292 vs. 0.052
# Recall = 0.527 vs. 0.977
# Minibatch Loss= 0.001938
# Training: 18000
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.062
# F1 = 0.933 vs. 0.089
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.759 vs. 0.082
# F1 = 0.713 vs. 0.150
# Precision = 0.641 vs. 0.085
# Recall = 0.804 vs. 0.641
# Validation: 18000
# ACTIVITY RECOGNITION
# AUC = 0.629 vs. 0.059
# F1 = 0.641 vs. 0.079
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.046
# F1 = 0.375 vs. 0.097
# Precision = 0.308 vs. 0.051
# Recall = 0.481 vs. 0.990
# Minibatch Loss= 0.064173
# Training: 18100
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.986 vs. 0.093
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.967 vs. 0.106
# F1 = 0.921 vs. 0.181
# Precision = 0.897 vs. 0.100
# Recall = 0.945 vs. 1.000
# Validation: 18100
# ACTIVITY RECOGNITION
# AUC = 0.645 vs. 0.058
# F1 = 0.659 vs. 0.081
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.051
# F1 = 0.378 vs. 0.101
# Precision = 0.317 vs. 0.055
# Recall = 0.468 vs. 0.683
# Minibatch Loss= 0.015113
# Training: 18200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.995 vs. 0.089
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.071
# F1 = 0.963 vs. 0.136
# Precision = 0.954 vs. 0.073
# Recall = 0.972 vs. 0.996
# Validation: 18200
# ACTIVITY RECOGNITION
# AUC = 0.639 vs. 0.058
# F1 = 0.656 vs. 0.081
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.059
# F1 = 0.379 vs. 0.098
# Precision = 0.314 vs. 0.056
# Recall = 0.481 vs. 0.410
# Minibatch Loss= 0.007608
# Training: 18300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.998 vs. 0.093
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.096
# F1 = 0.989 vs. 0.166
# Precision = 0.981 vs. 0.092
# Recall = 0.997 vs. 0.829
# Validation: 18300
# ACTIVITY RECOGNITION
# AUC = 0.631 vs. 0.059
# F1 = 0.651 vs. 0.078
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.051
# F1 = 0.384 vs. 0.097
# Precision = 0.301 vs. 0.051
# Recall = 0.530 vs. 0.997
# Minibatch Loss= 0.006113
# Training: 18400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.999 vs. 0.092
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.106
# F1 = 0.993 vs. 0.184
# Precision = 0.986 vs. 0.101
# Recall = 1.000 vs. 1.000
# Validation: 18400
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.059
# F1 = 0.643 vs. 0.083
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.050
# F1 = 0.374 vs. 0.098
# Precision = 0.304 vs. 0.052
# Recall = 0.486 vs. 0.995
# Minibatch Loss= 0.004951
# Training: 18500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.087
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 0.997 vs. 0.152
# Precision = 0.994 vs. 0.085
# Recall = 1.000 vs. 0.700
# Validation: 18500
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.060
# F1 = 0.642 vs. 0.086
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.047
# F1 = 0.377 vs. 0.097
# Precision = 0.299 vs. 0.051
# Recall = 0.512 vs. 0.992
# Minibatch Loss= 0.003946
# Training: 18600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.089
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 0.999 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 0.998 vs. 1.000
# Validation: 18600
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.059
# F1 = 0.638 vs. 0.080
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.055
# F1 = 0.379 vs. 0.096
# Precision = 0.305 vs. 0.051
# Recall = 0.501 vs. 0.987
# Minibatch Loss= 0.003089
# Training: 18700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.099
# F1 = 0.999 vs. 0.185
# Precision = 0.998 vs. 0.102
# Recall = 1.000 vs. 0.985
# Validation: 18700
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.059
# F1 = 0.636 vs. 0.079
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.056
# F1 = 0.381 vs. 0.101
# Precision = 0.345 vs. 0.057
# Recall = 0.426 vs. 0.426
# Minibatch Loss= 0.003162
# Training: 18800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.095
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.109
# F1 = 0.999 vs. 0.193
# Precision = 0.999 vs. 0.107
# Recall = 1.000 vs. 1.000
# Validation: 18800
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.059
# F1 = 0.640 vs. 0.081
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.052
# F1 = 0.381 vs. 0.099
# Precision = 0.345 vs. 0.052
# Recall = 0.426 vs. 0.899
# Minibatch Loss= 0.002744
# Training: 18900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.087
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.085
# F1 = 0.996 vs. 0.157
# Precision = 0.993 vs. 0.085
# Recall = 1.000 vs. 0.978
# Validation: 18900
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.059
# F1 = 0.640 vs. 0.086
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.049
# F1 = 0.381 vs. 0.099
# Precision = 0.345 vs. 0.053
# Recall = 0.426 vs. 0.816
# Minibatch Loss= 0.002791
# Training: 19000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.094
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.114
# F1 = 0.998 vs. 0.201
# Precision = 0.999 vs. 0.112
# Recall = 0.997 vs. 0.994
# Validation: 19000
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.059
# F1 = 0.639 vs. 0.088
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.051
# F1 = 0.380 vs. 0.099
# Precision = 0.325 vs. 0.052
# Recall = 0.457 vs. 0.932
# Minibatch Loss= 0.003345
# Training: 19100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.172
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 1.000
# Validation: 19100
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.059
# F1 = 0.638 vs. 0.083
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.050
# F1 = 0.380 vs. 0.100
# Precision = 0.337 vs. 0.054
# Recall = 0.434 vs. 0.709
# Minibatch Loss= 0.002438
# Training: 19200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.101
# F1 = 0.999 vs. 0.172
# Precision = 0.998 vs. 0.094
# Recall = 1.000 vs. 0.996
# Validation: 19200
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.059
# F1 = 0.636 vs. 0.081
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.049
# F1 = 0.378 vs. 0.100
# Precision = 0.326 vs. 0.054
# Recall = 0.449 vs. 0.688
# Minibatch Loss= 0.002295
# Training: 19300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 0.999 vs. 0.169
# Precision = 1.000 vs. 0.092
# Recall = 0.998 vs. 1.000
# Validation: 19300
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.058
# F1 = 0.632 vs. 0.082
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.056
# F1 = 0.379 vs. 0.099
# Precision = 0.299 vs. 0.053
# Recall = 0.519 vs. 0.873
# Minibatch Loss= 0.002374
# Training: 19400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.089
# F1 = 0.999 vs. 0.163
# Precision = 0.998 vs. 0.089
# Recall = 1.000 vs. 0.993
# Validation: 19400
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.059
# F1 = 0.632 vs. 0.082
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.053
# F1 = 0.382 vs. 0.097
# Precision = 0.311 vs. 0.051
# Recall = 0.496 vs. 0.990
# Minibatch Loss= 0.001888
# Training: 19500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.085
# F1 = 0.998 vs. 0.154
# Precision = 0.996 vs. 0.084
# Recall = 1.000 vs. 1.000
# Validation: 19500
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.059
# F1 = 0.630 vs. 0.082
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.048
# F1 = 0.385 vs. 0.098
# Precision = 0.315 vs. 0.052
# Recall = 0.494 vs. 0.948
# Minibatch Loss= 0.001923
# Training: 19600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.111
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.104
# Recall = 1.000 vs. 0.639
# Validation: 19600
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.058
# F1 = 0.630 vs. 0.077
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.054
# F1 = 0.385 vs. 0.097
# Precision = 0.321 vs. 0.053
# Recall = 0.481 vs. 0.616
# Minibatch Loss= 0.001842
# Training: 19700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.080
# F1 = 0.999 vs. 0.148
# Precision = 0.998 vs. 0.087
# Recall = 1.000 vs. 0.482
# Validation: 19700
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.058
# F1 = 0.628 vs. 0.079
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.054
# F1 = 0.387 vs. 0.097
# Precision = 0.319 vs. 0.051
# Recall = 0.491 vs. 1.000
# Minibatch Loss= 0.001583
# Training: 19800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.094
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.096
# F1 = 0.999 vs. 0.173
# Precision = 0.998 vs. 0.096
# Recall = 1.000 vs. 0.883
# Validation: 19800
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.059
# F1 = 0.625 vs. 0.081
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.051
# F1 = 0.382 vs. 0.102
# Precision = 0.335 vs. 0.055
# Recall = 0.444 vs. 0.647
# Minibatch Loss= 0.002297
# Training: 19900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.146
# Precision = 0.998 vs. 0.079
# Recall = 1.000 vs. 0.916
# Validation: 19900
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.059
# F1 = 0.626 vs. 0.082
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.052
# F1 = 0.389 vs. 0.101
# Precision = 0.306 vs. 0.056
# Recall = 0.535 vs. 0.527
# Minibatch Loss= 0.001799
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/HRNN_NewWavelet_Wmultitask_16_opp_20K/HRNN_NewWavelet_Wmultitask_16_opp_20K-20000'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-10000')
# Out:
# INFO:tensorflow:Restoring parameters from ../../model/HRNN_NewWavelet_Wmultitask_16_opp/HRNN_NewWavelet_Wmultitask_16_opp-10000

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.058
# F1 = 0.623 vs. 0.079
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.052
# F1 = 0.373 vs. 0.097
# Precision = 0.329 vs. 0.051
# Recall = 0.431 vs. 0.958

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1

# %%
2
