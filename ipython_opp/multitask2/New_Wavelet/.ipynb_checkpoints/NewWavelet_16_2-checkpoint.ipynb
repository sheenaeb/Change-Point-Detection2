# %%
# useing this variable for saving models and summaries
exp_name = "NewWavelet_16_2"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../../src')

# %%
import models.New_wavelet2 as wavelet_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 7    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[9, n_variables, 128],
                 [5, 128, 128],
                 [5, 128, 128]]
bias_shape = [128, 128, 128]
wavelet_kernel_size = 3    
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
train_data.shape
# Out:
# (691, 1024, 77)

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../../summary/' + exp_name 
checkpoint_path = '../../../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_kernel_size = wavelet_kernel_size,    
                                 activation = activation,
                                 trainable_wavelet = True,
                                 trainable_conv = True,
                                 trainable_last = True,
                                 variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 3000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.061
# F1 = 0.100 vs. 0.091
# Accuracy = 0.038 vs. 0.056
# CHANGE DETECTION
# AUC = 0.081 vs. 0.105
# F1 = 0.188 vs. 0.188
# Precision = 0.105 vs. 0.107
# Recall = 0.915 vs. 0.769
# Validation: 0
# ACTIVITY RECOGNITION
# AUC = 0.060 vs. 0.059
# F1 = 0.084 vs. 0.081
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.037 vs. 0.047
# F1 = 0.100 vs. 0.096
# Precision = 0.053 vs. 0.051
# Recall = 0.974 vs. 0.992
# Minibatch Loss= 1.338492
# Training: 100
# ACTIVITY RECOGNITION
# AUC = 0.465 vs. 0.062
# F1 = 0.492 vs. 0.094
# Accuracy = 0.606 vs. 0.056
# CHANGE DETECTION
# AUC = 0.236 vs. 0.094
# F1 = 0.332 vs. 0.173
# Precision = 0.218 vs. 0.095
# Recall = 0.702 vs. 0.978
# Validation: 100
# ACTIVITY RECOGNITION
# AUC = 0.339 vs. 0.059
# F1 = 0.403 vs. 0.082
# Accuracy = 0.678 vs. 0.056
# CHANGE DETECTION
# AUC = 0.172 vs. 0.052
# F1 = 0.271 vs. 0.100
# Precision = 0.176 vs. 0.053
# Recall = 0.592 vs. 0.938
# Minibatch Loss= 0.475586
# Training: 200
# ACTIVITY RECOGNITION
# AUC = 0.650 vs. 0.061
# F1 = 0.654 vs. 0.091
# Accuracy = 0.777 vs. 0.056
# CHANGE DETECTION
# AUC = 0.248 vs. 0.085
# F1 = 0.352 vs. 0.151
# Precision = 0.238 vs. 0.081
# Recall = 0.674 vs. 0.994
# Validation: 200
# ACTIVITY RECOGNITION
# AUC = 0.442 vs. 0.059
# F1 = 0.506 vs. 0.078
# Accuracy = 0.745 vs. 0.056
# CHANGE DETECTION
# AUC = 0.211 vs. 0.050
# F1 = 0.309 vs. 0.096
# Precision = 0.214 vs. 0.051
# Recall = 0.558 vs. 0.997
# Minibatch Loss= 0.256959
# Training: 300
# ACTIVITY RECOGNITION
# AUC = 0.720 vs. 0.061
# F1 = 0.706 vs. 0.095
# Accuracy = 0.798 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.095
# F1 = 0.373 vs. 0.182
# Precision = 0.272 vs. 0.100
# Recall = 0.597 vs. 1.000
# Validation: 300
# ACTIVITY RECOGNITION
# AUC = 0.489 vs. 0.059
# F1 = 0.543 vs. 0.079
# Accuracy = 0.795 vs. 0.056
# CHANGE DETECTION
# AUC = 0.221 vs. 0.052
# F1 = 0.323 vs. 0.099
# Precision = 0.235 vs. 0.053
# Recall = 0.519 vs. 0.795
# Minibatch Loss= 0.257233
# Training: 400
# ACTIVITY RECOGNITION
# AUC = 0.743 vs. 0.061
# F1 = 0.723 vs. 0.090
# Accuracy = 0.825 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.102
# F1 = 0.414 vs. 0.178
# Precision = 0.285 vs. 0.098
# Recall = 0.759 vs. 0.997
# Validation: 400
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.059
# F1 = 0.568 vs. 0.080
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.237 vs. 0.054
# F1 = 0.341 vs. 0.100
# Precision = 0.228 vs. 0.058
# Recall = 0.678 vs. 0.351
# Minibatch Loss= 0.202259
# Training: 500
# ACTIVITY RECOGNITION
# AUC = 0.766 vs. 0.059
# F1 = 0.750 vs. 0.082
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.360 vs. 0.073
# F1 = 0.436 vs. 0.140
# Precision = 0.350 vs. 0.075
# Recall = 0.578 vs. 0.973
# Validation: 500
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.060
# F1 = 0.581 vs. 0.086
# Accuracy = 0.847 vs. 0.056
# CHANGE DETECTION
# AUC = 0.254 vs. 0.050
# F1 = 0.358 vs. 0.096
# Precision = 0.260 vs. 0.051
# Recall = 0.577 vs. 1.000
# Minibatch Loss= 0.155101
# Training: 600
# ACTIVITY RECOGNITION
# AUC = 0.760 vs. 0.059
# F1 = 0.748 vs. 0.086
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.091
# F1 = 0.431 vs. 0.152
# Precision = 0.325 vs. 0.083
# Recall = 0.643 vs. 0.927
# Validation: 600
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.059
# F1 = 0.597 vs. 0.081
# Accuracy = 0.845 vs. 0.056
# CHANGE DETECTION
# AUC = 0.256 vs. 0.052
# F1 = 0.357 vs. 0.098
# Precision = 0.259 vs. 0.058
# Recall = 0.577 vs. 0.309
# Minibatch Loss= 0.152931
# Training: 700
# ACTIVITY RECOGNITION
# AUC = 0.810 vs. 0.060
# F1 = 0.786 vs. 0.088
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.357 vs. 0.074
# F1 = 0.431 vs. 0.138
# Precision = 0.321 vs. 0.080
# Recall = 0.653 vs. 0.515
# Validation: 700
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.060
# F1 = 0.612 vs. 0.083
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.261 vs. 0.054
# F1 = 0.355 vs. 0.097
# Precision = 0.255 vs. 0.051
# Recall = 0.584 vs. 0.906
# Minibatch Loss= 0.124818
# Training: 800
# ACTIVITY RECOGNITION
# AUC = 0.851 vs. 0.063
# F1 = 0.827 vs. 0.095
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.422 vs. 0.103
# F1 = 0.483 vs. 0.195
# Precision = 0.387 vs. 0.109
# Recall = 0.643 vs. 0.937
# Validation: 800
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.059
# F1 = 0.626 vs. 0.080
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.049
# F1 = 0.359 vs. 0.098
# Precision = 0.302 vs. 0.051
# Recall = 0.442 vs. 0.956
# Minibatch Loss= 0.140098
# Training: 900
# ACTIVITY RECOGNITION
# AUC = 0.852 vs. 0.060
# F1 = 0.835 vs. 0.090
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.439 vs. 0.089
# F1 = 0.503 vs. 0.165
# Precision = 0.387 vs. 0.092
# Recall = 0.719 vs. 0.828
# Validation: 900
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.058
# F1 = 0.637 vs. 0.080
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.270 vs. 0.050
# F1 = 0.351 vs. 0.096
# Precision = 0.288 vs. 0.051
# Recall = 0.449 vs. 0.997
# Minibatch Loss= 0.110677
# Training: 1000
# ACTIVITY RECOGNITION
# AUC = 0.852 vs. 0.061
# F1 = 0.830 vs. 0.088
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.414 vs. 0.089
# F1 = 0.478 vs. 0.167
# Precision = 0.370 vs. 0.091
# Recall = 0.674 vs. 0.960
# Validation: 1000
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.058
# F1 = 0.649 vs. 0.078
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.052
# F1 = 0.363 vs. 0.099
# Precision = 0.276 vs. 0.060
# Recall = 0.532 vs. 0.291
# Minibatch Loss= 0.108218
# Training: 1100
# ACTIVITY RECOGNITION
# AUC = 0.896 vs. 0.061
# F1 = 0.859 vs. 0.089
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.423 vs. 0.077
# F1 = 0.485 vs. 0.145
# Precision = 0.358 vs. 0.079
# Recall = 0.754 vs. 0.927
# Validation: 1100
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.059
# F1 = 0.657 vs. 0.081
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.047
# F1 = 0.375 vs. 0.099
# Precision = 0.263 vs. 0.052
# Recall = 0.652 vs. 0.922
# Minibatch Loss= 0.082953
# Training: 1200
# ACTIVITY RECOGNITION
# AUC = 0.912 vs. 0.062
# F1 = 0.886 vs. 0.089
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.510 vs. 0.089
# F1 = 0.542 vs. 0.165
# Precision = 0.450 vs. 0.090
# Recall = 0.681 vs. 0.990
# Validation: 1200
# ACTIVITY RECOGNITION
# AUC = 0.645 vs. 0.059
# F1 = 0.663 vs. 0.082
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.052
# F1 = 0.378 vs. 0.097
# Precision = 0.269 vs. 0.051
# Recall = 0.636 vs. 0.990
# Minibatch Loss= 0.080764
# Training: 1300
# ACTIVITY RECOGNITION
# AUC = 0.923 vs. 0.061
# F1 = 0.882 vs. 0.089
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.486 vs. 0.075
# F1 = 0.526 vs. 0.140
# Precision = 0.406 vs. 0.075
# Recall = 0.748 vs. 1.000
# Validation: 1300
# ACTIVITY RECOGNITION
# AUC = 0.656 vs. 0.058
# F1 = 0.669 vs. 0.080
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.053
# F1 = 0.383 vs. 0.100
# Precision = 0.266 vs. 0.053
# Recall = 0.688 vs. 0.829
# Minibatch Loss= 0.075644
# Training: 1400
# ACTIVITY RECOGNITION
# AUC = 0.946 vs. 0.062
# F1 = 0.911 vs. 0.094
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.541 vs. 0.097
# F1 = 0.570 vs. 0.169
# Precision = 0.470 vs. 0.092
# Recall = 0.723 vs. 1.000
# Validation: 1400
# ACTIVITY RECOGNITION
# AUC = 0.658 vs. 0.060
# F1 = 0.672 vs. 0.082
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.051
# F1 = 0.383 vs. 0.099
# Precision = 0.268 vs. 0.053
# Recall = 0.673 vs. 0.727
# Minibatch Loss= 0.072979
# Training: 1500
# ACTIVITY RECOGNITION
# AUC = 0.950 vs. 0.061
# F1 = 0.927 vs. 0.088
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.562 vs. 0.087
# F1 = 0.591 vs. 0.160
# Precision = 0.494 vs. 0.087
# Recall = 0.734 vs. 0.919
# Validation: 1500
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.060
# F1 = 0.675 vs. 0.083
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.052
# F1 = 0.383 vs. 0.099
# Precision = 0.278 vs. 0.053
# Recall = 0.618 vs. 0.790
# Minibatch Loss= 0.059663
# Training: 1600
# ACTIVITY RECOGNITION
# AUC = 0.939 vs. 0.062
# F1 = 0.914 vs. 0.095
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.555 vs. 0.104
# F1 = 0.577 vs. 0.185
# Precision = 0.470 vs. 0.102
# Recall = 0.748 vs. 0.986
# Validation: 1600
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.059
# F1 = 0.679 vs. 0.081
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.049
# F1 = 0.389 vs. 0.097
# Precision = 0.282 vs. 0.051
# Recall = 0.626 vs. 0.945
# Minibatch Loss= 0.071967
# Training: 1700
# ACTIVITY RECOGNITION
# AUC = 0.961 vs. 0.062
# F1 = 0.926 vs. 0.094
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.570 vs. 0.097
# F1 = 0.598 vs. 0.171
# Precision = 0.504 vs. 0.093
# Recall = 0.736 vs. 0.998
# Validation: 1700
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.058
# F1 = 0.681 vs. 0.077
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.051
# F1 = 0.392 vs. 0.097
# Precision = 0.285 vs. 0.052
# Recall = 0.626 vs. 0.862
# Minibatch Loss= 0.061378
# Training: 1800
# ACTIVITY RECOGNITION
# AUC = 0.954 vs. 0.060
# F1 = 0.933 vs. 0.088
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.589 vs. 0.089
# F1 = 0.596 vs. 0.152
# Precision = 0.539 vs. 0.082
# Recall = 0.665 vs. 0.998
# Validation: 1800
# ACTIVITY RECOGNITION
# AUC = 0.681 vs. 0.058
# F1 = 0.683 vs. 0.079
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.054
# F1 = 0.394 vs. 0.100
# Precision = 0.286 vs. 0.054
# Recall = 0.631 vs. 0.727
# Minibatch Loss= 0.054960
# Training: 1900
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.061
# F1 = 0.941 vs. 0.090
# Accuracy = 0.950 vs. 0.056
# CHANGE DETECTION
# AUC = 0.581 vs. 0.098
# F1 = 0.620 vs. 0.170
# Precision = 0.553 vs. 0.093
# Recall = 0.705 vs. 0.983
# Validation: 1900
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.682 vs. 0.082
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.049
# F1 = 0.405 vs. 0.097
# Precision = 0.293 vs. 0.053
# Recall = 0.655 vs. 0.660
# Minibatch Loss= 0.055157
# Training: 2000
# ACTIVITY RECOGNITION
# AUC = 0.901 vs. 0.061
# F1 = 0.859 vs. 0.090
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.561 vs. 0.087
# F1 = 0.566 vs. 0.168
# Precision = 0.463 vs. 0.092
# Recall = 0.726 vs. 0.973
# Validation: 2000
# ACTIVITY RECOGNITION
# AUC = 0.619 vs. 0.058
# F1 = 0.647 vs. 0.081
# Accuracy = 0.852 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.052
# F1 = 0.360 vs. 0.098
# Precision = 0.240 vs. 0.052
# Recall = 0.717 vs. 0.958
# Minibatch Loss= 0.108300
# Training: 2100
# ACTIVITY RECOGNITION
# AUC = 0.963 vs. 0.062
# F1 = 0.938 vs. 0.092
# Accuracy = 0.951 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.099
# F1 = 0.639 vs. 0.180
# Precision = 0.583 vs. 0.101
# Recall = 0.708 vs. 0.874
# Validation: 2100
# ACTIVITY RECOGNITION
# AUC = 0.704 vs. 0.059
# F1 = 0.693 vs. 0.082
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.332 vs. 0.049
# F1 = 0.402 vs. 0.097
# Precision = 0.309 vs. 0.051
# Recall = 0.574 vs. 0.964
# Minibatch Loss= 0.054469
# Training: 2200
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.063
# F1 = 0.947 vs. 0.094
# Accuracy = 0.955 vs. 0.056
# CHANGE DETECTION
# AUC = 0.613 vs. 0.087
# F1 = 0.628 vs. 0.167
# Precision = 0.502 vs. 0.091
# Recall = 0.836 vs. 1.000
# Validation: 2200
# ACTIVITY RECOGNITION
# AUC = 0.705 vs. 0.058
# F1 = 0.694 vs. 0.079
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.334 vs. 0.054
# F1 = 0.410 vs. 0.098
# Precision = 0.311 vs. 0.057
# Recall = 0.600 vs. 0.348
# Minibatch Loss= 0.050153
# Training: 2300
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.061
# F1 = 0.961 vs. 0.089
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.634 vs. 0.073
# F1 = 0.655 vs. 0.141
# Precision = 0.548 vs. 0.076
# Recall = 0.814 vs. 0.988
# Validation: 2300
# ACTIVITY RECOGNITION
# AUC = 0.707 vs. 0.058
# F1 = 0.692 vs. 0.081
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.336 vs. 0.053
# F1 = 0.408 vs. 0.098
# Precision = 0.292 vs. 0.052
# Recall = 0.675 vs. 0.932
# Minibatch Loss= 0.037881
# Training: 2400
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.060
# F1 = 0.958 vs. 0.088
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.591 vs. 0.078
# F1 = 0.634 vs. 0.147
# Precision = 0.537 vs. 0.080
# Recall = 0.774 vs. 0.829
# Validation: 2400
# ACTIVITY RECOGNITION
# AUC = 0.708 vs. 0.059
# F1 = 0.694 vs. 0.080
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.329 vs. 0.054
# F1 = 0.404 vs. 0.099
# Precision = 0.310 vs. 0.056
# Recall = 0.577 vs. 0.436
# Minibatch Loss= 0.040362
# Training: 2500
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.062
# F1 = 0.963 vs. 0.093
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.644 vs. 0.082
# F1 = 0.675 vs. 0.156
# Precision = 0.577 vs. 0.085
# Recall = 0.812 vs. 0.982
# Validation: 2500
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.696 vs. 0.080
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.329 vs. 0.050
# F1 = 0.398 vs. 0.096
# Precision = 0.298 vs. 0.051
# Recall = 0.597 vs. 1.000
# Minibatch Loss= 0.040445
# Training: 2600
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.061
# F1 = 0.965 vs. 0.090
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.656 vs. 0.095
# F1 = 0.673 vs. 0.168
# Precision = 0.606 vs. 0.092
# Recall = 0.756 vs. 0.955
# Validation: 2600
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.696 vs. 0.079
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.054
# F1 = 0.408 vs. 0.110
# Precision = 0.294 vs. 0.063
# Recall = 0.662 vs. 0.457
# Minibatch Loss= 0.038643
# Training: 2700
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.063
# F1 = 0.971 vs. 0.094
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.672 vs. 0.105
# F1 = 0.690 vs. 0.198
# Precision = 0.616 vs. 0.110
# Recall = 0.784 vs. 0.980
# Validation: 2700
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.696 vs. 0.079
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.331 vs. 0.056
# F1 = 0.404 vs. 0.097
# Precision = 0.286 vs. 0.051
# Recall = 0.683 vs. 0.969
# Minibatch Loss= 0.045524
# Training: 2800
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.062
# F1 = 0.966 vs. 0.091
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.649 vs. 0.086
# F1 = 0.696 vs. 0.166
# Precision = 0.595 vs. 0.091
# Recall = 0.837 vs. 0.968
# Validation: 2800
# ACTIVITY RECOGNITION
# AUC = 0.712 vs. 0.059
# F1 = 0.696 vs. 0.081
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.054
# F1 = 0.416 vs. 0.098
# Precision = 0.312 vs. 0.051
# Recall = 0.623 vs. 0.961
# Minibatch Loss= 0.037556
# Training: 2900
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.061
# F1 = 0.970 vs. 0.090
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.670 vs. 0.092
# F1 = 0.711 vs. 0.172
# Precision = 0.586 vs. 0.095
# Recall = 0.905 vs. 0.935
# Validation: 2900
# ACTIVITY RECOGNITION
# AUC = 0.712 vs. 0.060
# F1 = 0.695 vs. 0.083
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.050
# F1 = 0.399 vs. 0.096
# Precision = 0.287 vs. 0.051
# Recall = 0.657 vs. 1.000
# Minibatch Loss= 0.036687
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../../model/NewWavelet_16_2/checkpoint-3000'

# %%
trainer.train(max_iter = 3000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 3000
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.061
# F1 = 0.977 vs. 0.091
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.715 vs. 0.089
# F1 = 0.748 vs. 0.161
# Precision = 0.639 vs. 0.088
# Recall = 0.901 vs. 0.995
# Validation: 3000
# ACTIVITY RECOGNITION
# AUC = 0.712 vs. 0.060
# F1 = 0.695 vs. 0.085
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.329 vs. 0.054
# F1 = 0.402 vs. 0.099
# Precision = 0.287 vs. 0.053
# Recall = 0.670 vs. 0.810
# Minibatch Loss= 0.029937
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 0.955 vs. 0.062
# F1 = 0.910 vs. 0.093
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.633 vs. 0.099
# F1 = 0.631 vs. 0.187
# Precision = 0.539 vs. 0.103
# Recall = 0.760 vs. 1.000
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.664 vs. 0.058
# F1 = 0.672 vs. 0.080
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.049
# F1 = 0.394 vs. 0.097
# Precision = 0.317 vs. 0.051
# Recall = 0.522 vs. 0.938
# Minibatch Loss= 0.119070
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.062
# F1 = 0.973 vs. 0.095
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.094
# F1 = 0.703 vs. 0.171
# Precision = 0.653 vs. 0.096
# Recall = 0.762 vs. 0.797
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.719 vs. 0.058
# F1 = 0.708 vs. 0.079
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.048
# F1 = 0.408 vs. 0.097
# Precision = 0.315 vs. 0.051
# Recall = 0.582 vs. 1.000
# Minibatch Loss= 0.035578
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.062
# F1 = 0.971 vs. 0.093
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.730 vs. 0.102
# F1 = 0.749 vs. 0.182
# Precision = 0.640 vs. 0.100
# Recall = 0.904 vs. 0.986
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.719 vs. 0.059
# F1 = 0.706 vs. 0.082
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.336 vs. 0.050
# F1 = 0.400 vs. 0.096
# Precision = 0.310 vs. 0.051
# Recall = 0.564 vs. 0.951
# Minibatch Loss= 0.034322
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.061
# F1 = 0.977 vs. 0.088
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.733 vs. 0.084
# F1 = 0.768 vs. 0.149
# Precision = 0.660 vs. 0.080
# Recall = 0.918 vs. 1.000
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.719 vs. 0.058
# F1 = 0.703 vs. 0.079
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.331 vs. 0.047
# F1 = 0.392 vs. 0.096
# Precision = 0.304 vs. 0.051
# Recall = 0.551 vs. 1.000
# Minibatch Loss= 0.026265
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.060
# F1 = 0.982 vs. 0.090
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.085
# F1 = 0.756 vs. 0.158
# Precision = 0.650 vs. 0.086
# Recall = 0.902 vs. 0.989
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.719 vs. 0.058
# F1 = 0.702 vs. 0.078
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.051
# F1 = 0.388 vs. 0.103
# Precision = 0.285 vs. 0.060
# Recall = 0.608 vs. 0.356
# Minibatch Loss= 0.027316
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.985 vs. 0.089
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.764 vs. 0.078
# F1 = 0.786 vs. 0.148
# Precision = 0.700 vs. 0.080
# Recall = 0.895 vs. 1.000
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.059
# F1 = 0.697 vs. 0.083
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.332 vs. 0.049
# F1 = 0.396 vs. 0.096
# Precision = 0.273 vs. 0.051
# Recall = 0.719 vs. 1.000
# Minibatch Loss= 0.024934
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.062
# F1 = 0.984 vs. 0.091
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.770 vs. 0.089
# F1 = 0.802 vs. 0.169
# Precision = 0.709 vs. 0.093
# Recall = 0.923 vs. 0.932
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.059
# F1 = 0.698 vs. 0.082
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.050
# F1 = 0.387 vs. 0.100
# Precision = 0.279 vs. 0.053
# Recall = 0.634 vs. 0.756
# Minibatch Loss= 0.024493
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.990 vs. 0.090
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.770 vs. 0.090
# F1 = 0.810 vs. 0.159
# Precision = 0.710 vs. 0.087
# Recall = 0.942 vs. 0.998
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.059
# F1 = 0.696 vs. 0.079
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.058
# F1 = 0.387 vs. 0.103
# Precision = 0.272 vs. 0.058
# Recall = 0.668 vs. 0.478
# Minibatch Loss= 0.022486
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.990 vs. 0.089
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.776 vs. 0.079
# F1 = 0.822 vs. 0.153
# Precision = 0.727 vs. 0.083
# Recall = 0.945 vs. 0.962
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.058
# F1 = 0.693 vs. 0.082
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.052
# F1 = 0.385 vs. 0.102
# Precision = 0.274 vs. 0.057
# Recall = 0.644 vs. 0.473
# Minibatch Loss= 0.019899
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 0.897 vs. 0.060
# F1 = 0.837 vs. 0.090
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.513 vs. 0.093
# F1 = 0.548 vs. 0.169
# Precision = 0.478 vs. 0.093
# Recall = 0.643 vs. 0.979
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.059
# F1 = 0.599 vs. 0.080
# Accuracy = 0.841 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.052
# F1 = 0.348 vs. 0.101
# Precision = 0.254 vs. 0.056
# Recall = 0.551 vs. 0.535
# Minibatch Loss= 0.147347
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.061
# F1 = 0.945 vs. 0.090
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.638 vs. 0.088
# F1 = 0.631 vs. 0.155
# Precision = 0.530 vs. 0.084
# Recall = 0.778 vs. 0.981
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.709 vs. 0.059
# F1 = 0.700 vs. 0.082
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.333 vs. 0.049
# F1 = 0.403 vs. 0.097
# Precision = 0.292 vs. 0.051
# Recall = 0.649 vs. 0.992
# Minibatch Loss= 0.052887
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.062
# F1 = 0.967 vs. 0.093
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.698 vs. 0.090
# F1 = 0.697 vs. 0.162
# Precision = 0.592 vs. 0.088
# Recall = 0.847 vs. 0.973
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.059
# F1 = 0.703 vs. 0.081
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.336 vs. 0.051
# F1 = 0.404 vs. 0.103
# Precision = 0.318 vs. 0.057
# Recall = 0.553 vs. 0.494
# Minibatch Loss= 0.036889
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.061
# F1 = 0.978 vs. 0.090
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.767 vs. 0.088
# F1 = 0.759 vs. 0.171
# Precision = 0.649 vs. 0.094
# Recall = 0.914 vs. 0.914
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.060
# F1 = 0.699 vs. 0.082
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.334 vs. 0.049
# F1 = 0.399 vs. 0.097
# Precision = 0.327 vs. 0.052
# Recall = 0.512 vs. 0.652
# Minibatch Loss= 0.030047
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.062
# F1 = 0.978 vs. 0.091
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.759 vs. 0.097
# F1 = 0.783 vs. 0.171
# Precision = 0.684 vs. 0.094
# Recall = 0.915 vs. 0.959
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.058
# F1 = 0.699 vs. 0.080
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.048
# F1 = 0.397 vs. 0.097
# Precision = 0.305 vs. 0.051
# Recall = 0.571 vs. 0.953
# Minibatch Loss= 0.027939
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.984 vs. 0.092
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.795 vs. 0.087
# F1 = 0.788 vs. 0.161
# Precision = 0.678 vs. 0.087
# Recall = 0.943 vs. 1.000
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.060
# F1 = 0.700 vs. 0.082
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.053
# F1 = 0.393 vs. 0.100
# Precision = 0.292 vs. 0.055
# Recall = 0.603 vs. 0.551
# Minibatch Loss= 0.023584
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.063
# F1 = 0.990 vs. 0.094
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.802 vs. 0.099
# F1 = 0.829 vs. 0.171
# Precision = 0.725 vs. 0.100
# Recall = 0.967 vs. 0.588
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.059
# F1 = 0.701 vs. 0.086
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.053
# F1 = 0.389 vs. 0.100
# Precision = 0.306 vs. 0.053
# Recall = 0.535 vs. 0.862
# Minibatch Loss= 0.021640
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.988 vs. 0.094
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.843 vs. 0.103
# F1 = 0.853 vs. 0.176
# Precision = 0.772 vs. 0.097
# Recall = 0.953 vs. 0.997
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.058
# F1 = 0.699 vs. 0.081
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.050
# F1 = 0.385 vs. 0.097
# Precision = 0.315 vs. 0.051
# Recall = 0.496 vs. 0.971
# Minibatch Loss= 0.019867
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.989 vs. 0.088
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.812 vs. 0.088
# F1 = 0.848 vs. 0.157
# Precision = 0.768 vs. 0.085
# Recall = 0.947 vs. 0.993
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.059
# F1 = 0.698 vs. 0.081
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.046
# F1 = 0.380 vs. 0.097
# Precision = 0.307 vs. 0.051
# Recall = 0.499 vs. 0.909
# Minibatch Loss= 0.019497
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.992 vs. 0.089
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.870 vs. 0.086
# F1 = 0.883 vs. 0.169
# Precision = 0.814 vs. 0.092
# Recall = 0.964 vs. 1.000
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.058
# F1 = 0.697 vs. 0.081
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.048
# F1 = 0.381 vs. 0.097
# Precision = 0.297 vs. 0.052
# Recall = 0.530 vs. 0.829
# Minibatch Loss= 0.016493
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.993 vs. 0.088
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.902 vs. 0.079
# F1 = 0.890 vs. 0.150
# Precision = 0.820 vs. 0.081
# Recall = 0.973 vs. 0.977
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.059
# F1 = 0.697 vs. 0.081
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.048
# F1 = 0.384 vs. 0.097
# Precision = 0.304 vs. 0.051
# Recall = 0.522 vs. 0.922
# Minibatch Loss= 0.013906
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.989 vs. 0.092
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.866 vs. 0.094
# F1 = 0.843 vs. 0.175
# Precision = 0.767 vs. 0.099
# Recall = 0.935 vs. 0.798
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.718 vs. 0.058
# F1 = 0.702 vs. 0.080
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.051
# F1 = 0.394 vs. 0.096
# Precision = 0.308 vs. 0.051
# Recall = 0.545 vs. 1.000
# Minibatch Loss= 0.029570
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.063
# F1 = 0.993 vs. 0.093
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.850 vs. 0.088
# F1 = 0.870 vs. 0.165
# Precision = 0.808 vs. 0.090
# Recall = 0.943 vs. 1.000
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.059
# F1 = 0.699 vs. 0.084
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.052
# F1 = 0.385 vs. 0.100
# Precision = 0.303 vs. 0.053
# Recall = 0.530 vs. 0.821
# Minibatch Loss= 0.015738
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.993 vs. 0.095
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.881 vs. 0.100
# F1 = 0.903 vs. 0.186
# Precision = 0.840 vs. 0.103
# Recall = 0.977 vs. 0.948
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.059
# F1 = 0.697 vs. 0.081
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.052
# F1 = 0.380 vs. 0.098
# Precision = 0.300 vs. 0.054
# Recall = 0.519 vs. 0.582
# Minibatch Loss= 0.015092
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.096
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.106
# F1 = 0.929 vs. 0.194
# Precision = 0.886 vs. 0.108
# Recall = 0.975 vs. 0.943
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.057
# F1 = 0.694 vs. 0.078
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.051
# F1 = 0.380 vs. 0.099
# Precision = 0.295 vs. 0.054
# Recall = 0.532 vs. 0.623
# Minibatch Loss= 0.014007
# Training: 5500
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.997 vs. 0.090
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.903 vs. 0.092
# F1 = 0.913 vs. 0.165
# Precision = 0.861 vs. 0.091
# Recall = 0.972 vs. 0.875
# Validation: 5500
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.058
# F1 = 0.691 vs. 0.079
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.047
# F1 = 0.379 vs. 0.096
# Precision = 0.304 vs. 0.051
# Recall = 0.504 vs. 1.000
# Minibatch Loss= 0.011946
# Training: 5600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.996 vs. 0.091
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.936 vs. 0.096
# F1 = 0.932 vs. 0.172
# Precision = 0.879 vs. 0.094
# Recall = 0.992 vs. 0.953
# Validation: 5600
# ACTIVITY RECOGNITION
# AUC = 0.708 vs. 0.058
# F1 = 0.689 vs. 0.078
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.049
# F1 = 0.377 vs. 0.098
# Precision = 0.294 vs. 0.052
# Recall = 0.525 vs. 0.891
# Minibatch Loss= 0.011071
# Training: 5700
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.061
# F1 = 0.988 vs. 0.091
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.865 vs. 0.088
# F1 = 0.858 vs. 0.159
# Precision = 0.785 vs. 0.088
# Recall = 0.944 vs. 0.872
# Validation: 5700
# ACTIVITY RECOGNITION
# AUC = 0.724 vs. 0.058
# F1 = 0.704 vs. 0.080
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.047
# F1 = 0.396 vs. 0.098
# Precision = 0.307 vs. 0.052
# Recall = 0.556 vs. 0.888
# Minibatch Loss= 0.019443
# Training: 5800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.996 vs. 0.090
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.897 vs. 0.075
# F1 = 0.905 vs. 0.135
# Precision = 0.838 vs. 0.075
# Recall = 0.985 vs. 0.644
# Validation: 5800
# ACTIVITY RECOGNITION
# AUC = 0.720 vs. 0.059
# F1 = 0.702 vs. 0.082
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.052
# F1 = 0.381 vs. 0.096
# Precision = 0.316 vs. 0.051
# Recall = 0.478 vs. 1.000
# Minibatch Loss= 0.010708
# Training: 5900
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.996 vs. 0.092
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.912 vs. 0.098
# F1 = 0.923 vs. 0.181
# Precision = 0.869 vs. 0.099
# Recall = 0.984 vs. 1.000
# Validation: 5900
# ACTIVITY RECOGNITION
# AUC = 0.717 vs. 0.058
# F1 = 0.698 vs. 0.081
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.055
# F1 = 0.380 vs. 0.101
# Precision = 0.314 vs. 0.056
# Recall = 0.481 vs. 0.478
# Minibatch Loss= 0.012860
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../../model/NewWavelet_16_2/checkpoint-6000'

# %%
saver = tf.train.Saver()
saver.restore(sess, "../../../model/NewWavelet_16_1/checkpoint-3095")
# Out:
# INFO:tensorflow:Restoring parameters from ../../../model/NewWavelet_16_1/checkpoint-3095

# %%
trainer.train(max_iter = 3000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.061
# F1 = 0.964 vs. 0.087
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.711 vs. 0.086
# F1 = 0.727 vs. 0.152
# Precision = 0.642 vs. 0.083
# Recall = 0.837 vs. 0.943
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.059
# F1 = 0.698 vs. 0.077
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.050
# F1 = 0.388 vs. 0.097
# Precision = 0.298 vs. 0.051
# Recall = 0.556 vs. 0.982
# Minibatch Loss= 0.038012
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.060
# F1 = 0.941 vs. 0.089
# Accuracy = 0.950 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.097
# F1 = 0.694 vs. 0.169
# Precision = 0.609 vs. 0.093
# Recall = 0.806 vs. 0.926
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.059
# F1 = 0.704 vs. 0.079
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.335 vs. 0.049
# F1 = 0.395 vs. 0.097
# Precision = 0.276 vs. 0.051
# Recall = 0.699 vs. 0.956
# Minibatch Loss= 0.051821
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.061
# F1 = 0.961 vs. 0.093
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.724 vs. 0.100
# F1 = 0.730 vs. 0.187
# Precision = 0.635 vs. 0.103
# Recall = 0.859 vs. 0.979
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.059
# F1 = 0.698 vs. 0.082
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.335 vs. 0.053
# F1 = 0.400 vs. 0.103
# Precision = 0.312 vs. 0.058
# Recall = 0.558 vs. 0.444
# Minibatch Loss= 0.041937
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.061
# F1 = 0.968 vs. 0.087
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.704 vs. 0.078
# F1 = 0.725 vs. 0.147
# Precision = 0.654 vs. 0.080
# Recall = 0.812 vs. 0.962
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.059
# F1 = 0.701 vs. 0.081
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.333 vs. 0.050
# F1 = 0.399 vs. 0.097
# Precision = 0.305 vs. 0.051
# Recall = 0.577 vs. 1.000
# Minibatch Loss= 0.030597
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.061
# F1 = 0.975 vs. 0.091
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.800 vs. 0.105
# F1 = 0.794 vs. 0.191
# Precision = 0.716 vs. 0.106
# Recall = 0.891 vs. 0.938
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.058
# F1 = 0.702 vs. 0.078
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.332 vs. 0.053
# F1 = 0.399 vs. 0.101
# Precision = 0.336 vs. 0.057
# Recall = 0.491 vs. 0.439
# Minibatch Loss= 0.031865
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.061
# F1 = 0.975 vs. 0.089
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.734 vs. 0.092
# F1 = 0.761 vs. 0.157
# Precision = 0.664 vs. 0.085
# Recall = 0.890 vs. 1.000
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.059
# F1 = 0.704 vs. 0.083
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.049
# F1 = 0.391 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.623 vs. 0.992
# Minibatch Loss= 0.028292
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.060
# F1 = 0.981 vs. 0.088
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.772 vs. 0.079
# F1 = 0.766 vs. 0.146
# Precision = 0.682 vs. 0.079
# Recall = 0.873 vs. 0.974
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.058
# F1 = 0.704 vs. 0.081
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.060
# F1 = 0.395 vs. 0.100
# Precision = 0.285 vs. 0.055
# Recall = 0.644 vs. 0.600
# Minibatch Loss= 0.025127
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.061
# F1 = 0.978 vs. 0.092
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.789 vs. 0.085
# F1 = 0.771 vs. 0.156
# Precision = 0.651 vs. 0.085
# Recall = 0.943 vs. 1.000
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.718 vs. 0.059
# F1 = 0.704 vs. 0.080
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.332 vs. 0.050
# F1 = 0.402 vs. 0.097
# Precision = 0.344 vs. 0.052
# Recall = 0.483 vs. 0.865
# Minibatch Loss= 0.026804
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.062
# F1 = 0.983 vs. 0.093
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.798 vs. 0.092
# F1 = 0.816 vs. 0.168
# Precision = 0.713 vs. 0.092
# Recall = 0.953 vs. 0.934
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.716 vs. 0.059
# F1 = 0.700 vs. 0.079
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.047
# F1 = 0.397 vs. 0.097
# Precision = 0.284 vs. 0.051
# Recall = 0.655 vs. 0.901
# Minibatch Loss= 0.024123
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.061
# F1 = 0.978 vs. 0.092
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.823 vs. 0.097
# F1 = 0.830 vs. 0.169
# Precision = 0.745 vs. 0.093
# Recall = 0.937 vs. 0.990
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.058
# F1 = 0.702 vs. 0.079
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.052
# F1 = 0.392 vs. 0.098
# Precision = 0.337 vs. 0.051
# Recall = 0.468 vs. 0.958
# Minibatch Loss= 0.025045
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.062
# F1 = 0.979 vs. 0.092
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.797 vs. 0.090
# F1 = 0.832 vs. 0.161
# Precision = 0.757 vs. 0.088
# Recall = 0.923 vs. 0.996
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.059
# F1 = 0.700 vs. 0.079
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.052
# F1 = 0.389 vs. 0.096
# Precision = 0.280 vs. 0.051
# Recall = 0.636 vs. 1.000
# Minibatch Loss= 0.022735
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.060
# F1 = 0.979 vs. 0.092
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.812 vs. 0.103
# F1 = 0.830 vs. 0.184
# Precision = 0.736 vs. 0.102
# Recall = 0.951 vs. 0.992
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.059
# F1 = 0.699 vs. 0.079
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.055
# F1 = 0.390 vs. 0.099
# Precision = 0.284 vs. 0.052
# Recall = 0.618 vs. 0.919
# Minibatch Loss= 0.025240
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.062
# F1 = 0.975 vs. 0.092
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.815 vs. 0.097
# F1 = 0.789 vs. 0.178
# Precision = 0.723 vs. 0.098
# Recall = 0.868 vs. 0.982
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.723 vs. 0.058
# F1 = 0.705 vs. 0.078
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.050
# F1 = 0.399 vs. 0.097
# Precision = 0.295 vs. 0.051
# Recall = 0.616 vs. 0.951
# Minibatch Loss= 0.032421
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.062
# F1 = 0.987 vs. 0.094
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.869 vs. 0.102
# F1 = 0.850 vs. 0.184
# Precision = 0.788 vs. 0.102
# Recall = 0.923 vs. 0.922
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.719 vs. 0.058
# F1 = 0.703 vs. 0.077
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.051
# F1 = 0.395 vs. 0.097
# Precision = 0.294 vs. 0.052
# Recall = 0.603 vs. 0.852
# Minibatch Loss= 0.022161
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.988 vs. 0.090
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.846 vs. 0.089
# F1 = 0.851 vs. 0.159
# Precision = 0.803 vs. 0.087
# Recall = 0.905 vs. 0.917
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.717 vs. 0.059
# F1 = 0.700 vs. 0.083
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.048
# F1 = 0.390 vs. 0.097
# Precision = 0.292 vs. 0.051
# Recall = 0.587 vs. 0.953
# Minibatch Loss= 0.018363
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.987 vs. 0.093
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.838 vs. 0.096
# F1 = 0.862 vs. 0.170
# Precision = 0.774 vs. 0.094
# Recall = 0.971 vs. 0.884
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.058
# F1 = 0.702 vs. 0.081
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.054
# F1 = 0.384 vs. 0.098
# Precision = 0.296 vs. 0.052
# Recall = 0.548 vs. 0.870
# Minibatch Loss= 0.018959
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.990 vs. 0.089
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.894 vs. 0.085
# F1 = 0.883 vs. 0.164
# Precision = 0.801 vs. 0.089
# Recall = 0.982 vs. 0.991
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.058
# F1 = 0.700 vs. 0.078
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.049
# F1 = 0.382 vs. 0.097
# Precision = 0.296 vs. 0.051
# Recall = 0.538 vs. 1.000
# Minibatch Loss= 0.016913
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.992 vs. 0.088
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.873 vs. 0.078
# F1 = 0.884 vs. 0.141
# Precision = 0.824 vs. 0.076
# Recall = 0.952 vs. 0.996
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.059
# F1 = 0.700 vs. 0.081
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.053
# F1 = 0.387 vs. 0.101
# Precision = 0.282 vs. 0.055
# Recall = 0.618 vs. 0.668
# Minibatch Loss= 0.013960
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.989 vs. 0.093
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.839 vs. 0.082
# F1 = 0.847 vs. 0.155
# Precision = 0.769 vs. 0.085
# Recall = 0.944 vs. 0.944
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.709 vs. 0.058
# F1 = 0.697 vs. 0.080
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.053
# F1 = 0.377 vs. 0.097
# Precision = 0.360 vs. 0.052
# Recall = 0.395 vs. 0.865
# Minibatch Loss= 0.018686
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 0.921 vs. 0.061
# F1 = 0.867 vs. 0.091
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.570 vs. 0.096
# F1 = 0.570 vs. 0.171
# Precision = 0.516 vs. 0.093
# Recall = 0.636 vs. 0.997
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.668 vs. 0.058
# F1 = 0.658 vs. 0.080
# Accuracy = 0.856 vs. 0.056
# CHANGE DETECTION
# AUC = 0.275 vs. 0.048
# F1 = 0.357 vs. 0.097
# Precision = 0.284 vs. 0.051
# Recall = 0.481 vs. 0.990
# Minibatch Loss= 0.106321
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 0.963 vs. 0.059
# F1 = 0.923 vs. 0.086
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.623 vs. 0.075
# F1 = 0.634 vs. 0.145
# Precision = 0.548 vs. 0.079
# Recall = 0.753 vs. 0.901
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.058
# F1 = 0.673 vs. 0.078
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.059
# F1 = 0.381 vs. 0.102
# Precision = 0.310 vs. 0.061
# Recall = 0.494 vs. 0.325
# Minibatch Loss= 0.059350
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.063
# F1 = 0.940 vs. 0.092
# Accuracy = 0.947 vs. 0.056
# CHANGE DETECTION
# AUC = 0.695 vs. 0.094
# F1 = 0.681 vs. 0.165
# Precision = 0.580 vs. 0.090
# Recall = 0.824 vs. 0.994
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.059
# F1 = 0.683 vs. 0.083
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.048
# F1 = 0.387 vs. 0.097
# Precision = 0.305 vs. 0.051
# Recall = 0.530 vs. 1.000
# Minibatch Loss= 0.052797
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.064
# F1 = 0.948 vs. 0.097
# Accuracy = 0.965 vs. 0.056
# CHANGE DETECTION
# AUC = 0.741 vs. 0.095
# F1 = 0.726 vs. 0.179
# Precision = 0.634 vs. 0.098
# Recall = 0.848 vs. 0.978
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.058
# F1 = 0.690 vs. 0.079
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.057
# F1 = 0.380 vs. 0.102
# Precision = 0.275 vs. 0.062
# Recall = 0.616 vs. 0.288
# Minibatch Loss= 0.044891
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.062
# F1 = 0.950 vs. 0.091
# Accuracy = 0.955 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.098
# F1 = 0.722 vs. 0.181
# Precision = 0.657 vs. 0.101
# Recall = 0.803 vs. 0.913
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.704 vs. 0.059
# F1 = 0.693 vs. 0.084
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.051
# F1 = 0.384 vs. 0.097
# Precision = 0.306 vs. 0.051
# Recall = 0.517 vs. 0.919
# Minibatch Loss= 0.043666
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-89dc4a0335ac> in <module>()
#       2                 train_eval_step = 100,
#       3                 validation_eval_step = 100,
# ----> 4                 display_step = 100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model/DWN_16_1/checkpoint-6000'

# %%
trainer.train(max_iter = 3000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 6000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.099
# F1 = 0.998 vs. 0.174
# Precision = 0.997 vs. 0.097
# Recall = 1.000 vs. 0.888
# Validation: 6000
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.059
# F1 = 0.665 vs. 0.082
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.051
# F1 = 0.403 vs. 0.098
# Precision = 0.316 vs. 0.052
# Recall = 0.553 vs. 0.860
# Minibatch Loss= 0.001026
# Training: 6100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.180
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.952
# Validation: 6100
# ACTIVITY RECOGNITION
# AUC = 0.673 vs. 0.059
# F1 = 0.663 vs. 0.080
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.052
# F1 = 0.397 vs. 0.100
# Precision = 0.328 vs. 0.053
# Recall = 0.504 vs. 0.797
# Minibatch Loss= 0.001048
# Training: 6200
# ACTIVITY RECOGNITION
# AUC = 0.904 vs. 0.061
# F1 = 0.849 vs. 0.091
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.716 vs. 0.092
# F1 = 0.666 vs. 0.170
# Precision = 0.609 vs. 0.093
# Recall = 0.735 vs. 0.925
# Validation: 6200
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.058
# F1 = 0.612 vs. 0.080
# Accuracy = 0.806 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.050
# F1 = 0.368 vs. 0.098
# Precision = 0.282 vs. 0.051
# Recall = 0.530 vs. 0.971
# Minibatch Loss= 0.149966
# Training: 6300
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.987 vs. 0.090
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.951 vs. 0.076
# F1 = 0.916 vs. 0.150
# Precision = 0.891 vs. 0.081
# Recall = 0.943 vs. 0.949
# Validation: 6300
# ACTIVITY RECOGNITION
# AUC = 0.703 vs. 0.059
# F1 = 0.696 vs. 0.080
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.052
# F1 = 0.393 vs. 0.096
# Precision = 0.313 vs. 0.051
# Recall = 0.530 vs. 1.000
# Minibatch Loss= 0.018074
# Training: 6400
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.994 vs. 0.091
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.086
# F1 = 0.963 vs. 0.167
# Precision = 0.941 vs. 0.091
# Recall = 0.986 vs. 0.995
# Validation: 6400
# ACTIVITY RECOGNITION
# AUC = 0.705 vs. 0.060
# F1 = 0.703 vs. 0.082
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.050
# F1 = 0.406 vs. 0.097
# Precision = 0.348 vs. 0.051
# Recall = 0.488 vs. 0.974
# Minibatch Loss= 0.011827
# Training: 6500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.090
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.082
# F1 = 0.985 vs. 0.147
# Precision = 0.975 vs. 0.079
# Recall = 0.996 vs. 0.992
# Validation: 6500
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.696 vs. 0.080
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.052
# F1 = 0.396 vs. 0.097
# Precision = 0.336 vs. 0.051
# Recall = 0.481 vs. 1.000
# Minibatch Loss= 0.006067
# Training: 6600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.094
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.096
# F1 = 0.986 vs. 0.186
# Precision = 0.974 vs. 0.103
# Recall = 0.998 vs. 0.960
# Validation: 6600
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.059
# F1 = 0.692 vs. 0.081
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.048
# F1 = 0.392 vs. 0.096
# Precision = 0.320 vs. 0.051
# Recall = 0.504 vs. 1.000
# Minibatch Loss= 0.005084
# Training: 6700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.085
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.083
# F1 = 0.993 vs. 0.148
# Precision = 0.986 vs. 0.080
# Recall = 1.000 vs. 0.994
# Validation: 6700
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.058
# F1 = 0.692 vs. 0.079
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.052
# F1 = 0.390 vs. 0.098
# Precision = 0.312 vs. 0.052
# Recall = 0.519 vs. 0.935
# Minibatch Loss= 0.003082
# Training: 6800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.999 vs. 0.089
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.092
# F1 = 0.997 vs. 0.167
# Precision = 0.993 vs. 0.091
# Recall = 1.000 vs. 0.978
# Validation: 6800
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.059
# F1 = 0.693 vs. 0.081
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.053
# F1 = 0.389 vs. 0.097
# Precision = 0.326 vs. 0.051
# Recall = 0.483 vs. 1.000
# Minibatch Loss= 0.002827
# Training: 6900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 0.999 vs. 0.160
# Precision = 0.998 vs. 0.088
# Recall = 1.000 vs. 0.923
# Validation: 6900
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.693 vs. 0.082
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.051
# F1 = 0.388 vs. 0.096
# Precision = 0.308 vs. 0.051
# Recall = 0.525 vs. 0.992
# Minibatch Loss= 0.002037
# Training: 7000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.094
# F1 = 0.999 vs. 0.174
# Precision = 0.998 vs. 0.095
# Recall = 1.000 vs. 0.950
# Validation: 7000
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.059
# F1 = 0.692 vs. 0.080
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.056
# F1 = 0.387 vs. 0.098
# Precision = 0.338 vs. 0.053
# Recall = 0.452 vs. 0.639
# Minibatch Loss= 0.001856
# Training: 7100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.993
# Validation: 7100
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.059
# F1 = 0.693 vs. 0.081
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.057
# F1 = 0.387 vs. 0.103
# Precision = 0.328 vs. 0.057
# Recall = 0.473 vs. 0.512
# Minibatch Loss= 0.001395
# Training: 7200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.978
# Validation: 7200
# ACTIVITY RECOGNITION
# AUC = 0.703 vs. 0.059
# F1 = 0.693 vs. 0.081
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.054
# F1 = 0.385 vs. 0.101
# Precision = 0.330 vs. 0.054
# Recall = 0.462 vs. 0.678
# Minibatch Loss= 0.001211
# Training: 7300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.083
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.131
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.894
# Validation: 7300
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.058
# F1 = 0.693 vs. 0.082
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.051
# F1 = 0.385 vs. 0.097
# Precision = 0.327 vs. 0.051
# Recall = 0.468 vs. 0.984
# Minibatch Loss= 0.000893
# Training: 7400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.915
# Validation: 7400
# ACTIVITY RECOGNITION
# AUC = 0.704 vs. 0.059
# F1 = 0.693 vs. 0.081
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.052
# F1 = 0.384 vs. 0.098
# Precision = 0.313 vs. 0.053
# Recall = 0.496 vs. 0.732
# Minibatch Loss= 0.000890
# Training: 7500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.147
# Precision = 1.000 vs. 0.080
# Recall = 1.000 vs. 0.972
# Validation: 7500
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.693 vs. 0.079
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.049
# F1 = 0.383 vs. 0.097
# Precision = 0.317 vs. 0.051
# Recall = 0.483 vs. 1.000
# Minibatch Loss= 0.000605
# Training: 7600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.988
# Validation: 7600
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.059
# F1 = 0.693 vs. 0.081
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.055
# F1 = 0.382 vs. 0.100
# Precision = 0.317 vs. 0.053
# Recall = 0.481 vs. 0.761
# Minibatch Loss= 0.000587
# Training: 7700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.104
# Recall = 1.000 vs. 0.653
# Validation: 7700
# ACTIVITY RECOGNITION
# AUC = 0.703 vs. 0.060
# F1 = 0.694 vs. 0.083
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.051
# F1 = 0.382 vs. 0.100
# Precision = 0.306 vs. 0.053
# Recall = 0.509 vs. 0.932
# Minibatch Loss= 0.000587
# Training: 7800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.106
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.108
# Recall = 1.000 vs. 0.516
# Validation: 7800
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.060
# F1 = 0.693 vs. 0.085
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.056
# F1 = 0.382 vs. 0.098
# Precision = 0.307 vs. 0.052
# Recall = 0.506 vs. 0.912
# Minibatch Loss= 0.000529
# Training: 7900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.998
# Validation: 7900
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.694 vs. 0.083
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.290 vs. 0.054
# F1 = 0.381 vs. 0.097
# Precision = 0.303 vs. 0.051
# Recall = 0.512 vs. 0.813
# Minibatch Loss= 0.000368
# Training: 8000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.184
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.912
# Validation: 8000
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.058
# F1 = 0.694 vs. 0.079
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.047
# F1 = 0.379 vs. 0.096
# Precision = 0.356 vs. 0.051
# Recall = 0.405 vs. 0.997
# Minibatch Loss= 0.000384
# Training: 8100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.890
# Validation: 8100
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.058
# F1 = 0.694 vs. 0.078
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.053
# F1 = 0.381 vs. 0.100
# Precision = 0.360 vs. 0.054
# Recall = 0.405 vs. 0.709
# Minibatch Loss= 0.000307
# Training: 8200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.996
# Validation: 8200
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.694 vs. 0.078
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.055
# F1 = 0.382 vs. 0.102
# Precision = 0.361 vs. 0.056
# Recall = 0.405 vs. 0.610
# Minibatch Loss= 0.000291
# Training: 8300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.176
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 0.852
# Validation: 8300
# ACTIVITY RECOGNITION
# AUC = 0.704 vs. 0.059
# F1 = 0.695 vs. 0.082
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.050
# F1 = 0.381 vs. 0.097
# Precision = 0.356 vs. 0.051
# Recall = 0.410 vs. 0.896
# Minibatch Loss= 0.000235
# Training: 8400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.106
# F1 = 1.000 vs. 0.189
# Precision = 1.000 vs. 0.105
# Recall = 1.000 vs. 0.995
# Validation: 8400
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.058
# F1 = 0.695 vs. 0.077
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.051
# F1 = 0.383 vs. 0.098
# Precision = 0.355 vs. 0.052
# Recall = 0.416 vs. 0.805
# Minibatch Loss= 0.000193
# Training: 8500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.152
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.671
# Validation: 8500
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.059
# F1 = 0.694 vs. 0.081
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.050
# F1 = 0.385 vs. 0.098
# Precision = 0.358 vs. 0.052
# Recall = 0.416 vs. 0.919
# Minibatch Loss= 0.000180
# Training: 8600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.162
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.923
# Validation: 8600
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.058
# F1 = 0.695 vs. 0.080
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.051
# F1 = 0.380 vs. 0.096
# Precision = 0.354 vs. 0.051
# Recall = 0.410 vs. 0.966
# Minibatch Loss= 0.000162
# Training: 8700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 0.976
# Validation: 8700
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.059
# F1 = 0.694 vs. 0.082
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.293 vs. 0.051
# F1 = 0.378 vs. 0.098
# Precision = 0.355 vs. 0.052
# Recall = 0.405 vs. 0.912
# Minibatch Loss= 0.000152
# Training: 8800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.992
# Validation: 8800
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.060
# F1 = 0.695 vs. 0.082
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.050
# F1 = 0.379 vs. 0.100
# Precision = 0.364 vs. 0.053
# Recall = 0.395 vs. 0.873
# Minibatch Loss= 0.000130
# Training: 8900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.175
# Precision = 1.000 vs. 0.096
# Recall = 1.000 vs. 0.992
# Validation: 8900
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.058
# F1 = 0.695 vs. 0.078
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.050
# F1 = 0.379 vs. 0.098
# Precision = 0.343 vs. 0.052
# Recall = 0.423 vs. 0.875
# Minibatch Loss= 0.000130
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../../model/NewWavelet_16_2/checkpoint-6000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../../model/DWN_Wmultitask_16_opp/checkpoint-20000')

# %%
#load the model
saver = tf.train.Saver()
#'../../model/DWN_16_1/checkpoint-6000'
saver.restore(sess, "../../model/DWN_16_1/checkpoint-6000")

# %%
#This is the model evaluation on test dataset
result = nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.714 vs. 0.059
# F1 = 0.696 vs. 0.079
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.053
# F1 = 0.374 vs. 0.098
# Precision = 0.292 vs. 0.057
# Recall = 0.519 vs. 0.330

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(out, axis = 2)

# %%
savemat('../../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})
