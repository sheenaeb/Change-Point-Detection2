# %%
# useing this variable for saving models and summaries
exp_name = "CNN_16_1"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[9, n_variables, 128],
                 [5, 128, 128],
                 [5, 128, 128]]
bias_shape = [128, 128, 128]
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)


variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../../summary/' + exp_name 
checkpoint_path = '../../../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,
                     variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# ACTIVITY RECOGNITION
# AUC = 0.061 vs. 0.062
# F1 = 0.097 vs. 0.091
# Accuracy = 0.032 vs. 0.056
# CHANGE DETECTION
# AUC = 0.072 vs. 0.088
# F1 = 0.172 vs. 0.167
# Precision = 0.095 vs. 0.091
# Recall = 0.967 vs. 0.997
# Validation: 0
# ACTIVITY RECOGNITION
# AUC = 0.057 vs. 0.059
# F1 = 0.079 vs. 0.081
# Accuracy = 0.011 vs. 0.056
# CHANGE DETECTION
# AUC = 0.042 vs. 0.052
# F1 = 0.102 vs. 0.098
# Precision = 0.054 vs. 0.053
# Recall = 0.919 vs. 0.709
# Minibatch Loss= 1.390713
# Training: 100
# ACTIVITY RECOGNITION
# AUC = 0.720 vs. 0.062
# F1 = 0.710 vs. 0.092
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.500 vs. 0.085
# F1 = 0.500 vs. 0.157
# Precision = 0.475 vs. 0.085
# Recall = 0.529 vs. 0.972
# Validation: 100
# ACTIVITY RECOGNITION
# AUC = 0.494 vs. 0.059
# F1 = 0.537 vs. 0.083
# Accuracy = 0.774 vs. 0.056
# CHANGE DETECTION
# AUC = 0.222 vs. 0.051
# F1 = 0.296 vs. 0.097
# Precision = 0.233 vs. 0.051
# Recall = 0.408 vs. 0.888
# Minibatch Loss= 0.214766
# Training: 200
# ACTIVITY RECOGNITION
# AUC = 0.850 vs. 0.062
# F1 = 0.808 vs. 0.091
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.603 vs. 0.082
# F1 = 0.579 vs. 0.160
# Precision = 0.510 vs. 0.088
# Recall = 0.672 vs. 0.877
# Validation: 200
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.058
# F1 = 0.628 vs. 0.080
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.054
# F1 = 0.356 vs. 0.097
# Precision = 0.271 vs. 0.053
# Recall = 0.519 vs. 0.605
# Minibatch Loss= 0.129194
# Training: 300
# ACTIVITY RECOGNITION
# AUC = 0.928 vs. 0.063
# F1 = 0.889 vs. 0.095
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.105
# F1 = 0.660 vs. 0.185
# Precision = 0.580 vs. 0.102
# Recall = 0.765 vs. 0.951
# Validation: 300
# ACTIVITY RECOGNITION
# AUC = 0.648 vs. 0.058
# F1 = 0.665 vs. 0.079
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.049
# F1 = 0.383 vs. 0.097
# Precision = 0.300 vs. 0.051
# Recall = 0.530 vs. 0.964
# Minibatch Loss= 0.107541
# Training: 400
# ACTIVITY RECOGNITION
# AUC = 0.946 vs. 0.061
# F1 = 0.914 vs. 0.093
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.695 vs. 0.087
# F1 = 0.688 vs. 0.165
# Precision = 0.632 vs. 0.090
# Recall = 0.754 vs. 0.926
# Validation: 400
# ACTIVITY RECOGNITION
# AUC = 0.671 vs. 0.060
# F1 = 0.678 vs. 0.081
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.048
# F1 = 0.395 vs. 0.097
# Precision = 0.303 vs. 0.051
# Recall = 0.566 vs. 1.000
# Minibatch Loss= 0.071704
# Training: 500
# ACTIVITY RECOGNITION
# AUC = 0.965 vs. 0.062
# F1 = 0.944 vs. 0.092
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.788 vs. 0.083
# F1 = 0.752 vs. 0.166
# Precision = 0.665 vs. 0.091
# Recall = 0.865 vs. 1.000
# Validation: 500
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.061
# F1 = 0.694 vs. 0.082
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.048
# F1 = 0.399 vs. 0.097
# Precision = 0.297 vs. 0.051
# Recall = 0.605 vs. 0.992
# Minibatch Loss= 0.053000
# Training: 600
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.059
# F1 = 0.961 vs. 0.085
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.849 vs. 0.082
# F1 = 0.783 vs. 0.150
# Precision = 0.712 vs. 0.086
# Recall = 0.870 vs. 0.592
# Validation: 600
# ACTIVITY RECOGNITION
# AUC = 0.707 vs. 0.060
# F1 = 0.700 vs. 0.086
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.049
# F1 = 0.414 vs. 0.097
# Precision = 0.356 vs. 0.051
# Recall = 0.496 vs. 0.982
# Minibatch Loss= 0.039612
# Training: 700
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.061
# F1 = 0.968 vs. 0.094
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.837 vs. 0.093
# F1 = 0.811 vs. 0.174
# Precision = 0.735 vs. 0.095
# Recall = 0.905 vs. 0.993
# Validation: 700
# ACTIVITY RECOGNITION
# AUC = 0.712 vs. 0.058
# F1 = 0.711 vs. 0.080
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.053
# F1 = 0.387 vs. 0.097
# Precision = 0.332 vs. 0.051
# Recall = 0.465 vs. 0.984
# Minibatch Loss= 0.047810
# Training: 800
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.060
# F1 = 0.974 vs. 0.087
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.075
# F1 = 0.838 vs. 0.135
# Precision = 0.803 vs. 0.073
# Recall = 0.877 vs. 1.000
# Validation: 800
# ACTIVITY RECOGNITION
# AUC = 0.724 vs. 0.058
# F1 = 0.712 vs. 0.077
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.048
# F1 = 0.396 vs. 0.099
# Precision = 0.328 vs. 0.053
# Recall = 0.499 vs. 0.740
# Minibatch Loss= 0.027034
# Training: 900
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.062
# F1 = 0.981 vs. 0.092
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.933 vs. 0.093
# F1 = 0.889 vs. 0.173
# Precision = 0.849 vs. 0.095
# Recall = 0.934 vs. 0.963
# Validation: 900
# ACTIVITY RECOGNITION
# AUC = 0.727 vs. 0.058
# F1 = 0.713 vs. 0.081
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.050
# F1 = 0.396 vs. 0.099
# Precision = 0.337 vs. 0.053
# Recall = 0.481 vs. 0.800
# Minibatch Loss= 0.027635
# Training: 1000
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.062
# F1 = 0.985 vs. 0.093
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.095
# F1 = 0.912 vs. 0.176
# Precision = 0.885 vs. 0.098
# Recall = 0.942 vs. 0.821
# Validation: 1000
# ACTIVITY RECOGNITION
# AUC = 0.726 vs. 0.059
# F1 = 0.713 vs. 0.078
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.049
# F1 = 0.390 vs. 0.098
# Precision = 0.322 vs. 0.052
# Recall = 0.496 vs. 0.888
# Minibatch Loss= 0.020994
# Training: 1100
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.987 vs. 0.093
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.953 vs. 0.095
# F1 = 0.928 vs. 0.175
# Precision = 0.891 vs. 0.096
# Recall = 0.969 vs. 0.998
# Validation: 1100
# ACTIVITY RECOGNITION
# AUC = 0.725 vs. 0.061
# F1 = 0.715 vs. 0.084
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.299 vs. 0.050
# F1 = 0.391 vs. 0.096
# Precision = 0.347 vs. 0.051
# Recall = 0.449 vs. 1.000
# Minibatch Loss= 0.018745
# Training: 1200
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.991 vs. 0.092
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.092
# F1 = 0.928 vs. 0.166
# Precision = 0.898 vs. 0.091
# Recall = 0.960 vs. 0.991
# Validation: 1200
# ACTIVITY RECOGNITION
# AUC = 0.726 vs. 0.059
# F1 = 0.714 vs. 0.080
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.049
# F1 = 0.387 vs. 0.096
# Precision = 0.353 vs. 0.051
# Recall = 0.429 vs. 1.000
# Minibatch Loss= 0.017910
# Training: 1300
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.062
# F1 = 0.992 vs. 0.091
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.970 vs. 0.081
# F1 = 0.937 vs. 0.152
# Precision = 0.896 vs. 0.082
# Recall = 0.983 vs. 0.992
# Validation: 1300
# ACTIVITY RECOGNITION
# AUC = 0.724 vs. 0.058
# F1 = 0.712 vs. 0.080
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.048
# F1 = 0.380 vs. 0.098
# Precision = 0.360 vs. 0.052
# Recall = 0.403 vs. 0.971
# Minibatch Loss= 0.014133
# Training: 1400
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.995 vs. 0.089
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.092
# F1 = 0.959 vs. 0.164
# Precision = 0.943 vs. 0.089
# Recall = 0.975 vs. 0.980
# Validation: 1400
# ACTIVITY RECOGNITION
# AUC = 0.718 vs. 0.058
# F1 = 0.709 vs. 0.079
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.050
# F1 = 0.386 vs. 0.096
# Precision = 0.348 vs. 0.051
# Recall = 0.434 vs. 1.000
# Minibatch Loss= 0.012248
# Training: 1500
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.063
# F1 = 0.994 vs. 0.092
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.109
# F1 = 0.965 vs. 0.190
# Precision = 0.938 vs. 0.105
# Recall = 0.994 vs. 1.000
# Validation: 1500
# ACTIVITY RECOGNITION
# AUC = 0.720 vs. 0.059
# F1 = 0.707 vs. 0.081
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.050
# F1 = 0.377 vs. 0.097
# Precision = 0.360 vs. 0.051
# Recall = 0.395 vs. 0.995
# Minibatch Loss= 0.010466
# Training: 1600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.060
# F1 = 0.995 vs. 0.091
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.100
# F1 = 0.975 vs. 0.177
# Precision = 0.954 vs. 0.097
# Recall = 0.997 vs. 0.995
# Validation: 1600
# ACTIVITY RECOGNITION
# AUC = 0.717 vs. 0.058
# F1 = 0.703 vs. 0.080
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.050
# F1 = 0.382 vs. 0.096
# Precision = 0.327 vs. 0.051
# Recall = 0.460 vs. 1.000
# Minibatch Loss= 0.008592
# Training: 1700
# ACTIVITY RECOGNITION
# AUC = 0.793 vs. 0.061
# F1 = 0.768 vs. 0.089
# Accuracy = 0.745 vs. 0.056
# CHANGE DETECTION
# AUC = 0.425 vs. 0.072
# F1 = 0.464 vs. 0.144
# Precision = 0.398 vs. 0.077
# Recall = 0.556 vs. 0.996
# Validation: 1700
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.059
# F1 = 0.564 vs. 0.083
# Accuracy = 0.685 vs. 0.056
# CHANGE DETECTION
# AUC = 0.207 vs. 0.049
# F1 = 0.292 vs. 0.100
# Precision = 0.255 vs. 0.053
# Recall = 0.340 vs. 0.881
# Minibatch Loss= 0.215778
# Training: 1800
# ACTIVITY RECOGNITION
# AUC = 0.960 vs. 0.061
# F1 = 0.911 vs. 0.091
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.718 vs. 0.097
# F1 = 0.685 vs. 0.175
# Precision = 0.627 vs. 0.097
# Recall = 0.755 vs. 0.854
# Validation: 1800
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.058
# F1 = 0.666 vs. 0.081
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.053
# F1 = 0.377 vs. 0.099
# Precision = 0.329 vs. 0.053
# Recall = 0.442 vs. 0.930
# Minibatch Loss= 0.076498
# Training: 1900
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.062
# F1 = 0.942 vs. 0.091
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.779 vs. 0.091
# F1 = 0.742 vs. 0.160
# Precision = 0.682 vs. 0.089
# Recall = 0.814 vs. 0.801
# Validation: 1900
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.688 vs. 0.082
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.049
# F1 = 0.374 vs. 0.099
# Precision = 0.298 vs. 0.053
# Recall = 0.501 vs. 0.717
# Minibatch Loss= 0.046642
# Training: 2000
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.063
# F1 = 0.959 vs. 0.094
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.845 vs. 0.102
# F1 = 0.795 vs. 0.186
# Precision = 0.742 vs. 0.103
# Recall = 0.856 vs. 0.954
# Validation: 2000
# ACTIVITY RECOGNITION
# AUC = 0.713 vs. 0.058
# F1 = 0.698 vs. 0.078
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.308 vs. 0.052
# F1 = 0.388 vs. 0.105
# Precision = 0.314 vs. 0.057
# Recall = 0.506 vs. 0.621
# Minibatch Loss= 0.043685
# Training: 2100
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.063
# F1 = 0.975 vs. 0.093
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.880 vs. 0.094
# F1 = 0.854 vs. 0.174
# Precision = 0.787 vs. 0.096
# Recall = 0.934 vs. 0.879
# Validation: 2100
# ACTIVITY RECOGNITION
# AUC = 0.719 vs. 0.059
# F1 = 0.699 vs. 0.081
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.050
# F1 = 0.378 vs. 0.097
# Precision = 0.303 vs. 0.051
# Recall = 0.501 vs. 0.992
# Minibatch Loss= 0.030934
# Training: 2200
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.060
# F1 = 0.982 vs. 0.085
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.075
# F1 = 0.854 vs. 0.145
# Precision = 0.777 vs. 0.078
# Recall = 0.948 vs. 0.996
# Validation: 2200
# ACTIVITY RECOGNITION
# AUC = 0.720 vs. 0.059
# F1 = 0.696 vs. 0.078
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.049
# F1 = 0.377 vs. 0.096
# Precision = 0.291 vs. 0.051
# Recall = 0.535 vs. 1.000
# Minibatch Loss= 0.023188
# Training: 2300
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.061
# F1 = 0.985 vs. 0.093
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.930 vs. 0.092
# F1 = 0.882 vs. 0.172
# Precision = 0.820 vs. 0.094
# Recall = 0.953 vs. 0.968
# Validation: 2300
# ACTIVITY RECOGNITION
# AUC = 0.723 vs. 0.058
# F1 = 0.696 vs. 0.079
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.051
# F1 = 0.380 vs. 0.098
# Precision = 0.343 vs. 0.054
# Recall = 0.426 vs. 0.616
# Minibatch Loss= 0.024202
# Training: 2400
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.986 vs. 0.094
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.911 vs. 0.089
# F1 = 0.895 vs. 0.171
# Precision = 0.845 vs. 0.094
# Recall = 0.950 vs. 0.980
# Validation: 2400
# ACTIVITY RECOGNITION
# AUC = 0.723 vs. 0.058
# F1 = 0.693 vs. 0.081
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.300 vs. 0.054
# F1 = 0.369 vs. 0.108
# Precision = 0.345 vs. 0.059
# Recall = 0.397 vs. 0.571
# Minibatch Loss= 0.020649
# Training: 2500
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.992 vs. 0.092
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.952 vs. 0.096
# F1 = 0.926 vs. 0.175
# Precision = 0.896 vs. 0.096
# Recall = 0.957 vs. 0.997
# Validation: 2500
# ACTIVITY RECOGNITION
# AUC = 0.724 vs. 0.057
# F1 = 0.693 vs. 0.078
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.054
# F1 = 0.374 vs. 0.097
# Precision = 0.317 vs. 0.053
# Recall = 0.455 vs. 0.535
# Minibatch Loss= 0.016658
# Training: 2600
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.061
# F1 = 0.990 vs. 0.089
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.954 vs. 0.099
# F1 = 0.937 vs. 0.162
# Precision = 0.886 vs. 0.092
# Recall = 0.995 vs. 0.672
# Validation: 2600
# ACTIVITY RECOGNITION
# AUC = 0.722 vs. 0.059
# F1 = 0.689 vs. 0.078
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.052
# F1 = 0.370 vs. 0.096
# Precision = 0.309 vs. 0.052
# Recall = 0.460 vs. 0.727
# Minibatch Loss= 0.014587
# Training: 2700
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.060
# F1 = 0.992 vs. 0.089
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.083
# F1 = 0.950 vs. 0.158
# Precision = 0.928 vs. 0.086
# Recall = 0.974 vs. 0.989
# Validation: 2700
# ACTIVITY RECOGNITION
# AUC = 0.723 vs. 0.059
# F1 = 0.691 vs. 0.082
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.297 vs. 0.049
# F1 = 0.371 vs. 0.097
# Precision = 0.301 vs. 0.051
# Recall = 0.483 vs. 0.844
# Minibatch Loss= 0.013021
# Training: 2800
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.993 vs. 0.091
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.094
# F1 = 0.944 vs. 0.176
# Precision = 0.922 vs. 0.097
# Recall = 0.967 vs. 0.979
# Validation: 2800
# ACTIVITY RECOGNITION
# AUC = 0.721 vs. 0.059
# F1 = 0.691 vs. 0.080
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.050
# F1 = 0.370 vs. 0.097
# Precision = 0.307 vs. 0.052
# Recall = 0.468 vs. 0.745
# Minibatch Loss= 0.012979
# Training: 2900
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.061
# F1 = 0.995 vs. 0.089
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.089
# F1 = 0.963 vs. 0.162
# Precision = 0.945 vs. 0.090
# Recall = 0.982 vs. 0.853
# Validation: 2900
# ACTIVITY RECOGNITION
# AUC = 0.720 vs. 0.058
# F1 = 0.695 vs. 0.080
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.294 vs. 0.054
# F1 = 0.370 vs. 0.099
# Precision = 0.309 vs. 0.053
# Recall = 0.462 vs. 0.790
# Minibatch Loss= 0.010004
# Training: 3000
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.996 vs. 0.092
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.976 vs. 0.088
# F1 = 0.966 vs. 0.162
# Precision = 0.945 vs. 0.090
# Recall = 0.987 vs. 0.799
# Validation: 3000
# ACTIVITY RECOGNITION
# AUC = 0.718 vs. 0.059
# F1 = 0.692 vs. 0.083
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.052
# F1 = 0.371 vs. 0.099
# Precision = 0.319 vs. 0.054
# Recall = 0.444 vs. 0.652
# Minibatch Loss= 0.009267
# Training: 3100
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.997 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.150
# Precision = 0.971 vs. 0.082
# Recall = 0.989 vs. 0.896
# Validation: 3100
# ACTIVITY RECOGNITION
# AUC = 0.717 vs. 0.059
# F1 = 0.693 vs. 0.084
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.285 vs. 0.053
# F1 = 0.363 vs. 0.099
# Precision = 0.304 vs. 0.053
# Recall = 0.452 vs. 0.699
# Minibatch Loss= 0.007230
# Training: 3200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.997 vs. 0.096
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.092
# F1 = 0.976 vs. 0.167
# Precision = 0.956 vs. 0.091
# Recall = 0.998 vs. 0.998
# Validation: 3200
# ACTIVITY RECOGNITION
# AUC = 0.715 vs. 0.059
# F1 = 0.690 vs. 0.080
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.050
# F1 = 0.368 vs. 0.098
# Precision = 0.305 vs. 0.052
# Recall = 0.462 vs. 0.842
# Minibatch Loss= 0.007936
# Training: 3300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 0.998 vs. 0.091
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.094
# F1 = 0.984 vs. 0.169
# Precision = 0.973 vs. 0.092
# Recall = 0.995 vs. 0.985
# Validation: 3300
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.059
# F1 = 0.689 vs. 0.084
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.048
# F1 = 0.363 vs. 0.097
# Precision = 0.293 vs. 0.051
# Recall = 0.478 vs. 0.992
# Minibatch Loss= 0.006917
# Training: 3400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.998 vs. 0.091
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.091
# F1 = 0.988 vs. 0.167
# Precision = 0.978 vs. 0.091
# Recall = 0.998 vs. 0.962
# Validation: 3400
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.058
# F1 = 0.690 vs. 0.080
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.286 vs. 0.050
# F1 = 0.363 vs. 0.100
# Precision = 0.298 vs. 0.053
# Recall = 0.462 vs. 0.829
# Minibatch Loss= 0.005890
# Training: 3500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.088
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.081
# F1 = 0.988 vs. 0.150
# Precision = 0.977 vs. 0.081
# Recall = 1.000 vs. 0.984
# Validation: 3500
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.059
# F1 = 0.690 vs. 0.083
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.051
# F1 = 0.363 vs. 0.098
# Precision = 0.293 vs. 0.052
# Recall = 0.475 vs. 0.912
# Minibatch Loss= 0.005037
# Training: 3600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.093
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.104
# F1 = 0.995 vs. 0.177
# Precision = 0.997 vs. 0.098
# Recall = 0.993 vs. 0.948
# Validation: 3600
# ACTIVITY RECOGNITION
# AUC = 0.707 vs. 0.059
# F1 = 0.690 vs. 0.081
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.049
# F1 = 0.355 vs. 0.097
# Precision = 0.291 vs. 0.051
# Recall = 0.455 vs. 0.984
# Minibatch Loss= 0.004617
# Training: 3700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 0.999 vs. 0.091
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.094
# F1 = 0.993 vs. 0.173
# Precision = 0.989 vs. 0.095
# Recall = 0.997 vs. 1.000
# Validation: 3700
# ACTIVITY RECOGNITION
# AUC = 0.708 vs. 0.059
# F1 = 0.689 vs. 0.081
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.051
# F1 = 0.356 vs. 0.098
# Precision = 0.320 vs. 0.052
# Recall = 0.400 vs. 0.896
# Minibatch Loss= 0.004307
# Training: 3800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.092
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.084
# F1 = 0.994 vs. 0.167
# Precision = 0.989 vs. 0.091
# Recall = 1.000 vs. 0.979
# Validation: 3800
# ACTIVITY RECOGNITION
# AUC = 0.707 vs. 0.059
# F1 = 0.690 vs. 0.077
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.052
# F1 = 0.358 vs. 0.100
# Precision = 0.327 vs. 0.053
# Recall = 0.395 vs. 0.743
# Minibatch Loss= 0.004166
# Training: 3900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.092
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.106
# F1 = 0.996 vs. 0.186
# Precision = 0.994 vs. 0.106
# Recall = 0.998 vs. 0.772
# Validation: 3900
# ACTIVITY RECOGNITION
# AUC = 0.707 vs. 0.058
# F1 = 0.690 vs. 0.078
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.050
# F1 = 0.356 vs. 0.097
# Precision = 0.314 vs. 0.052
# Recall = 0.410 vs. 0.865
# Minibatch Loss= 0.003547
# Training: 4000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 0.997 vs. 0.162
# Precision = 0.995 vs. 0.088
# Recall = 1.000 vs. 1.000
# Validation: 4000
# ACTIVITY RECOGNITION
# AUC = 0.705 vs. 0.059
# F1 = 0.689 vs. 0.082
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.050
# F1 = 0.363 vs. 0.099
# Precision = 0.326 vs. 0.053
# Recall = 0.410 vs. 0.730
# Minibatch Loss= 0.002781
# Training: 4100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.998
# Validation: 4100
# ACTIVITY RECOGNITION
# AUC = 0.705 vs. 0.059
# F1 = 0.690 vs. 0.079
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.056
# F1 = 0.359 vs. 0.103
# Precision = 0.308 vs. 0.058
# Recall = 0.429 vs. 0.447
# Minibatch Loss= 0.002740
# Training: 4200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.096
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 0.998 vs. 0.175
# Precision = 0.997 vs. 0.097
# Recall = 1.000 vs. 0.925
# Validation: 4200
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.063
# F1 = 0.690 vs. 0.083
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.049
# F1 = 0.360 vs. 0.097
# Precision = 0.292 vs. 0.051
# Recall = 0.468 vs. 1.000
# Minibatch Loss= 0.002666
# Training: 4300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 0.939
# Validation: 4300
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.058
# F1 = 0.689 vs. 0.077
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.049
# F1 = 0.363 vs. 0.101
# Precision = 0.316 vs. 0.054
# Recall = 0.426 vs. 0.891
# Minibatch Loss= 0.002149
# Training: 4400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.185
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.967
# Validation: 4400
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.059
# F1 = 0.689 vs. 0.078
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.053
# F1 = 0.364 vs. 0.102
# Precision = 0.305 vs. 0.056
# Recall = 0.452 vs. 0.566
# Minibatch Loss= 0.002583
# Training: 4500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.095
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.189
# Precision = 1.000 vs. 0.104
# Recall = 1.000 vs. 0.997
# Validation: 4500
# ACTIVITY RECOGNITION
# AUC = 0.702 vs. 0.058
# F1 = 0.687 vs. 0.081
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.052
# F1 = 0.368 vs. 0.098
# Precision = 0.313 vs. 0.052
# Recall = 0.447 vs. 0.787
# Minibatch Loss= 0.002024
# Training: 4600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.159
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 0.905
# Validation: 4600
# ACTIVITY RECOGNITION
# AUC = 0.700 vs. 0.059
# F1 = 0.689 vs. 0.080
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.277 vs. 0.054
# F1 = 0.366 vs. 0.101
# Precision = 0.317 vs. 0.058
# Recall = 0.434 vs. 0.379
# Minibatch Loss= 0.001453
# Training: 4700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.157
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.930
# Validation: 4700
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.059
# F1 = 0.687 vs. 0.081
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.053
# F1 = 0.364 vs. 0.100
# Precision = 0.312 vs. 0.054
# Recall = 0.436 vs. 0.616
# Minibatch Loss= 0.001479
# Training: 4800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.999 vs. 0.093
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.179
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.954
# Validation: 4800
# ACTIVITY RECOGNITION
# AUC = 0.697 vs. 0.059
# F1 = 0.686 vs. 0.081
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.282 vs. 0.051
# F1 = 0.368 vs. 0.099
# Precision = 0.316 vs. 0.052
# Recall = 0.442 vs. 0.974
# Minibatch Loss= 0.001371
# Training: 4900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 1.000
# Validation: 4900
# ACTIVITY RECOGNITION
# AUC = 0.701 vs. 0.059
# F1 = 0.687 vs. 0.083
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.283 vs. 0.049
# F1 = 0.367 vs. 0.098
# Precision = 0.317 vs. 0.052
# Recall = 0.436 vs. 0.935
# Minibatch Loss= 0.000940
# Training: 5000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 1.000 vs. 0.990
# Validation: 5000
# ACTIVITY RECOGNITION
# AUC = 0.692 vs. 0.059
# F1 = 0.688 vs. 0.079
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.049
# F1 = 0.364 vs. 0.097
# Precision = 0.303 vs. 0.052
# Recall = 0.457 vs. 0.842
# Minibatch Loss= 0.001153
# Training: 5100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.097
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.188
# Precision = 1.000 vs. 0.104
# Recall = 1.000 vs. 0.970
# Validation: 5100
# ACTIVITY RECOGNITION
# AUC = 0.698 vs. 0.058
# F1 = 0.688 vs. 0.079
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.277 vs. 0.051
# F1 = 0.368 vs. 0.100
# Precision = 0.312 vs. 0.054
# Recall = 0.449 vs. 0.642
# Minibatch Loss= 0.001044
# Training: 5200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.900
# Validation: 5200
# ACTIVITY RECOGNITION
# AUC = 0.696 vs. 0.059
# F1 = 0.687 vs. 0.083
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.048
# F1 = 0.367 vs. 0.096
# Precision = 0.306 vs. 0.051
# Recall = 0.460 vs. 1.000
# Minibatch Loss= 0.000801
# Training: 5300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.090
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.151
# Precision = 1.000 vs. 0.081
# Recall = 1.000 vs. 0.994
# Validation: 5300
# ACTIVITY RECOGNITION
# AUC = 0.693 vs. 0.058
# F1 = 0.689 vs. 0.079
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.052
# F1 = 0.363 vs. 0.096
# Precision = 0.301 vs. 0.051
# Recall = 0.457 vs. 1.000
# Minibatch Loss= 0.000720
# Training: 5400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.184
# Precision = 1.000 vs. 0.102
# Recall = 1.000 vs. 0.947
# Validation: 5400
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.059
# F1 = 0.688 vs. 0.082
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.048
# F1 = 0.363 vs. 0.096
# Precision = 0.310 vs. 0.051
# Recall = 0.439 vs. 1.000
# Minibatch Loss= 0.000656
# Training: 5500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.167
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.831
# Validation: 5500
# ACTIVITY RECOGNITION
# AUC = 0.698 vs. 0.059
# F1 = 0.689 vs. 0.079
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.277 vs. 0.052
# F1 = 0.364 vs. 0.097
# Precision = 0.299 vs. 0.051
# Recall = 0.465 vs. 1.000
# Minibatch Loss= 0.000733
# Training: 5600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.103
# F1 = 1.000 vs. 0.172
# Precision = 1.000 vs. 0.098
# Recall = 1.000 vs. 0.708
# Validation: 5600
# ACTIVITY RECOGNITION
# AUC = 0.699 vs. 0.059
# F1 = 0.691 vs. 0.080
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.052
# F1 = 0.361 vs. 0.098
# Precision = 0.306 vs. 0.052
# Recall = 0.439 vs. 0.901
# Minibatch Loss= 0.000595
# Training: 5700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.145
# Precision = 1.000 vs. 0.078
# Recall = 1.000 vs. 1.000
# Validation: 5700
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.059
# F1 = 0.690 vs. 0.080
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.275 vs. 0.052
# F1 = 0.363 vs. 0.096
# Precision = 0.300 vs. 0.051
# Recall = 0.457 vs. 1.000
# Minibatch Loss= 0.000373
# Training: 5800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.747
# Validation: 5800
# ACTIVITY RECOGNITION
# AUC = 0.690 vs. 0.059
# F1 = 0.689 vs. 0.078
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.051
# F1 = 0.362 vs. 0.099
# Precision = 0.298 vs. 0.053
# Recall = 0.462 vs. 0.751
# Minibatch Loss= 0.000409
# Training: 5900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.098
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.142
# Precision = 1.000 vs. 0.077
# Recall = 1.000 vs. 0.965
# Validation: 5900
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.059
# F1 = 0.689 vs. 0.081
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.050
# F1 = 0.362 vs. 0.097
# Precision = 0.296 vs. 0.051
# Recall = 0.465 vs. 0.948
# Minibatch Loss= 0.000345
# Training: 6000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.173
# Precision = 1.000 vs. 0.094
# Recall = 1.000 vs. 1.000
# Validation: 6000
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.059
# F1 = 0.689 vs. 0.082
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.051
# F1 = 0.360 vs. 0.101
# Precision = 0.304 vs. 0.055
# Recall = 0.442 vs. 0.603
# Minibatch Loss= 0.000327
# Training: 6100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 0.928
# Validation: 6100
# ACTIVITY RECOGNITION
# AUC = 0.688 vs. 0.058
# F1 = 0.687 vs. 0.080
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.053
# F1 = 0.359 vs. 0.103
# Precision = 0.305 vs. 0.056
# Recall = 0.436 vs. 0.566
# Minibatch Loss= 0.000315
# Training: 6200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.107
# F1 = 1.000 vs. 0.174
# Precision = 1.000 vs. 0.100
# Recall = 1.000 vs. 0.671
# Validation: 6200
# ACTIVITY RECOGNITION
# AUC = 0.692 vs. 0.058
# F1 = 0.690 vs. 0.081
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.050
# F1 = 0.363 vs. 0.098
# Precision = 0.297 vs. 0.052
# Recall = 0.468 vs. 0.860
# Minibatch Loss= 0.000317
# Training: 6300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.089
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.166
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.967
# Validation: 6300
# ACTIVITY RECOGNITION
# AUC = 0.690 vs. 0.059
# F1 = 0.688 vs. 0.080
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.052
# F1 = 0.359 vs. 0.097
# Precision = 0.316 vs. 0.051
# Recall = 0.416 vs. 0.997
# Minibatch Loss= 0.000267
# Training: 6400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.160
# Precision = 1.000 vs. 0.089
# Recall = 1.000 vs. 0.785
# Validation: 6400
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.059
# F1 = 0.688 vs. 0.081
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.052
# F1 = 0.359 vs. 0.099
# Precision = 0.273 vs. 0.052
# Recall = 0.525 vs. 0.839
# Minibatch Loss= 0.000205
# Training: 6500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.088
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.148
# Precision = 1.000 vs. 0.080
# Recall = 1.000 vs. 1.000
# Validation: 6500
# ACTIVITY RECOGNITION
# AUC = 0.689 vs. 0.058
# F1 = 0.687 vs. 0.077
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.270 vs. 0.052
# F1 = 0.361 vs. 0.099
# Precision = 0.312 vs. 0.053
# Recall = 0.429 vs. 0.766
# Minibatch Loss= 0.000178
# Training: 6600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.172
# Precision = 1.000 vs. 0.101
# Recall = 1.000 vs. 0.576
# Validation: 6600
# ACTIVITY RECOGNITION
# AUC = 0.690 vs. 0.059
# F1 = 0.687 vs. 0.082
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.050
# F1 = 0.361 vs. 0.096
# Precision = 0.275 vs. 0.051
# Recall = 0.525 vs. 1.000
# Minibatch Loss= 0.000189
# Training: 6700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.165
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.815
# Validation: 6700
# ACTIVITY RECOGNITION
# AUC = 0.687 vs. 0.059
# F1 = 0.686 vs. 0.083
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.051
# F1 = 0.362 vs. 0.097
# Precision = 0.311 vs. 0.051
# Recall = 0.431 vs. 0.997
# Minibatch Loss= 0.000176
# Training: 6800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.993
# Validation: 6800
# ACTIVITY RECOGNITION
# AUC = 0.694 vs. 0.058
# F1 = 0.686 vs. 0.077
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.050
# F1 = 0.362 vs. 0.097
# Precision = 0.275 vs. 0.051
# Recall = 0.527 vs. 0.984
# Minibatch Loss= 0.000139
# Training: 6900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.090
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.159
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 0.995
# Validation: 6900
# ACTIVITY RECOGNITION
# AUC = 0.688 vs. 0.059
# F1 = 0.686 vs. 0.082
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.055
# F1 = 0.361 vs. 0.098
# Precision = 0.307 vs. 0.055
# Recall = 0.436 vs. 0.496
# Minibatch Loss= 0.000157
# Training: 7000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 1.000
# Validation: 7000
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.058
# F1 = 0.686 vs. 0.079
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.049
# F1 = 0.366 vs. 0.097
# Precision = 0.316 vs. 0.051
# Recall = 0.436 vs. 1.000
# Minibatch Loss= 0.000129
# Training: 7100
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.094
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.163
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.759
# Validation: 7100
# ACTIVITY RECOGNITION
# AUC = 0.691 vs. 0.059
# F1 = 0.686 vs. 0.081
# Accuracy = 0.929 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.052
# F1 = 0.364 vs. 0.098
# Precision = 0.313 vs. 0.052
# Recall = 0.434 vs. 0.914
# Minibatch Loss= 0.000120
# Training: 7200
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.086
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.082
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.998
# Validation: 7200
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.686 vs. 0.080
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.275 vs. 0.048
# F1 = 0.364 vs. 0.097
# Precision = 0.312 vs. 0.052
# Recall = 0.436 vs. 0.899
# Minibatch Loss= 0.000104
# Training: 7300
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.092
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.996
# Validation: 7300
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.059
# F1 = 0.686 vs. 0.077
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.054
# F1 = 0.362 vs. 0.098
# Precision = 0.308 vs. 0.054
# Recall = 0.439 vs. 0.522
# Minibatch Loss= 0.000109
# Training: 7400
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.098
# F1 = 1.000 vs. 0.180
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.997
# Validation: 7400
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.058
# F1 = 0.685 vs. 0.077
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.278 vs. 0.043
# F1 = 0.364 vs. 0.096
# Precision = 0.313 vs. 0.051
# Recall = 0.436 vs. 0.997
# Minibatch Loss= 0.000087
# Training: 7500
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.175
# Precision = 1.000 vs. 0.097
# Recall = 1.000 vs. 0.865
# Validation: 7500
# ACTIVITY RECOGNITION
# AUC = 0.683 vs. 0.059
# F1 = 0.686 vs. 0.079
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.056
# F1 = 0.362 vs. 0.098
# Precision = 0.313 vs. 0.052
# Recall = 0.431 vs. 0.779
# Minibatch Loss= 0.000078
# Training: 7600
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.161
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.956
# Validation: 7600
# ACTIVITY RECOGNITION
# AUC = 0.686 vs. 0.059
# F1 = 0.686 vs. 0.079
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.052
# F1 = 0.365 vs. 0.097
# Precision = 0.314 vs. 0.053
# Recall = 0.436 vs. 0.574
# Minibatch Loss= 0.000073
# Training: 7700
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.093
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.168
# Precision = 1.000 vs. 0.092
# Recall = 1.000 vs. 0.966
# Validation: 7700
# ACTIVITY RECOGNITION
# AUC = 0.687 vs. 0.059
# F1 = 0.686 vs. 0.080
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.051
# F1 = 0.363 vs. 0.100
# Precision = 0.313 vs. 0.054
# Recall = 0.434 vs. 0.678
# Minibatch Loss= 0.000071
# Training: 7800
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.085
# F1 = 1.000 vs. 0.156
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.996
# Validation: 7800
# ACTIVITY RECOGNITION
# AUC = 0.682 vs. 0.059
# F1 = 0.686 vs. 0.084
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.058
# F1 = 0.362 vs. 0.099
# Precision = 0.312 vs. 0.056
# Recall = 0.431 vs. 0.431
# Minibatch Loss= 0.000056
# Training: 7900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.096
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.102
# F1 = 1.000 vs. 0.193
# Precision = 1.000 vs. 0.107
# Recall = 1.000 vs. 0.999
# Validation: 7900
# ACTIVITY RECOGNITION
# AUC = 0.684 vs. 0.059
# F1 = 0.686 vs. 0.083
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.052
# F1 = 0.364 vs. 0.100
# Precision = 0.309 vs. 0.054
# Recall = 0.444 vs. 0.621
# Minibatch Loss= 0.000065
# Training: 8000
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.091
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.087
# F1 = 1.000 vs. 0.171
# Precision = 1.000 vs. 0.093
# Recall = 1.000 vs. 0.993
# Validation: 8000
# ACTIVITY RECOGNITION
# AUC = 0.687 vs. 0.059
# F1 = 0.686 vs. 0.081
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.052
# F1 = 0.364 vs. 0.100
# Precision = 0.311 vs. 0.054
# Recall = 0.439 vs. 0.699
# Minibatch Loss= 0.000056
# Training: 8100
# ACTIVITY RECOGNITION
# AUC = 0.744 vs. 0.061
# F1 = 0.723 vs. 0.091
# Accuracy = 0.775 vs. 0.056
# CHANGE DETECTION
# AUC = 0.473 vs. 0.089
# F1 = 0.499 vs. 0.159
# Precision = 0.424 vs. 0.087
# Recall = 0.608 vs. 0.935
# Validation: 8100
# ACTIVITY RECOGNITION
# AUC = 0.436 vs. 0.059
# F1 = 0.487 vs. 0.080
# Accuracy = 0.737 vs. 0.056
# CHANGE DETECTION
# AUC = 0.197 vs. 0.048
# F1 = 0.281 vs. 0.097
# Precision = 0.214 vs. 0.051
# Recall = 0.410 vs. 0.969
# Minibatch Loss= 0.219593
# Training: 8200
# ACTIVITY RECOGNITION
# AUC = 0.928 vs. 0.061
# F1 = 0.882 vs. 0.092
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.085
# F1 = 0.658 vs. 0.160
# Precision = 0.585 vs. 0.087
# Recall = 0.751 vs. 0.993
# Validation: 8200
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.058
# F1 = 0.597 vs. 0.080
# Accuracy = 0.822 vs. 0.056
# CHANGE DETECTION
# AUC = 0.258 vs. 0.049
# F1 = 0.362 vs. 0.097
# Precision = 0.330 vs. 0.051
# Recall = 0.400 vs. 0.997
# Minibatch Loss= 0.087936
# Training: 8300
# ACTIVITY RECOGNITION
# AUC = 0.961 vs. 0.060
# F1 = 0.919 vs. 0.090
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.769 vs. 0.082
# F1 = 0.714 vs. 0.152
# Precision = 0.639 vs. 0.083
# Recall = 0.809 vs. 0.900
# Validation: 8300
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.059
# F1 = 0.629 vs. 0.078
# Accuracy = 0.848 vs. 0.056
# CHANGE DETECTION
# AUC = 0.272 vs. 0.050
# F1 = 0.360 vs. 0.097
# Precision = 0.285 vs. 0.051
# Recall = 0.491 vs. 0.997
# Minibatch Loss= 0.058878
# Training: 8400
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.061
# F1 = 0.948 vs. 0.089
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.824 vs. 0.099
# F1 = 0.775 vs. 0.172
# Precision = 0.686 vs. 0.094
# Recall = 0.889 vs. 0.995
# Validation: 8400
# ACTIVITY RECOGNITION
# AUC = 0.637 vs. 0.060
# F1 = 0.635 vs. 0.082
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.051
# F1 = 0.370 vs. 0.098
# Precision = 0.319 vs. 0.052
# Recall = 0.442 vs. 0.826
# Minibatch Loss= 0.046818
# Training: 8500
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.061
# F1 = 0.951 vs. 0.091
# Accuracy = 0.944 vs. 0.056
# CHANGE DETECTION
# AUC = 0.827 vs. 0.092
# F1 = 0.792 vs. 0.174
# Precision = 0.735 vs. 0.096
# Recall = 0.858 vs. 0.918
# Validation: 8500
# ACTIVITY RECOGNITION
# AUC = 0.647 vs. 0.058
# F1 = 0.648 vs. 0.081
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.292 vs. 0.052
# F1 = 0.370 vs. 0.098
# Precision = 0.361 vs. 0.055
# Recall = 0.379 vs. 0.496
# Minibatch Loss= 0.044710
# Training: 8600
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.061
# F1 = 0.961 vs. 0.093
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.851 vs. 0.093
# F1 = 0.821 vs. 0.167
# Precision = 0.746 vs. 0.091
# Recall = 0.914 vs. 0.993
# Validation: 8600
# ACTIVITY RECOGNITION
# AUC = 0.652 vs. 0.060
# F1 = 0.650 vs. 0.085
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.050
# F1 = 0.372 vs. 0.098
# Precision = 0.274 vs. 0.052
# Recall = 0.582 vs. 0.927
# Minibatch Loss= 0.034732
# Training: 8700
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.062
# F1 = 0.972 vs. 0.093
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.907 vs. 0.097
# F1 = 0.860 vs. 0.178
# Precision = 0.816 vs. 0.098
# Recall = 0.909 vs. 0.938
# Validation: 8700
# ACTIVITY RECOGNITION
# AUC = 0.657 vs. 0.059
# F1 = 0.652 vs. 0.078
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.301 vs. 0.051
# F1 = 0.378 vs. 0.098
# Precision = 0.323 vs. 0.052
# Recall = 0.455 vs. 0.992
# Minibatch Loss= 0.028242
# Training: 8800
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.063
# F1 = 0.982 vs. 0.094
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.925 vs. 0.089
# F1 = 0.890 vs. 0.169
# Precision = 0.821 vs. 0.092
# Recall = 0.971 vs. 0.967
# Validation: 8800
# ACTIVITY RECOGNITION
# AUC = 0.663 vs. 0.059
# F1 = 0.658 vs. 0.077
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.295 vs. 0.052
# F1 = 0.386 vs. 0.097
# Precision = 0.320 vs. 0.067
# Recall = 0.486 vs. 0.171
# Minibatch Loss= 0.022417
# Training: 8900
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.983 vs. 0.097
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.930 vs. 0.101
# F1 = 0.887 vs. 0.180
# Precision = 0.824 vs. 0.099
# Recall = 0.961 vs. 1.000
# Validation: 8900
# ACTIVITY RECOGNITION
# AUC = 0.666 vs. 0.059
# F1 = 0.662 vs. 0.084
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.289 vs. 0.052
# F1 = 0.379 vs. 0.097
# Precision = 0.320 vs. 0.054
# Recall = 0.465 vs. 0.473
# Minibatch Loss= 0.024571
# Training: 9000
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.062
# F1 = 0.986 vs. 0.094
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.943 vs. 0.094
# F1 = 0.907 vs. 0.180
# Precision = 0.854 vs. 0.099
# Recall = 0.968 vs. 1.000
# Validation: 9000
# ACTIVITY RECOGNITION
# AUC = 0.672 vs. 0.058
# F1 = 0.668 vs. 0.077
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.054
# F1 = 0.380 vs. 0.100
# Precision = 0.331 vs. 0.055
# Recall = 0.444 vs. 0.551
# Minibatch Loss= 0.020346
# Training: 9100
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.061
# F1 = 0.988 vs. 0.090
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.086
# F1 = 0.922 vs. 0.159
# Precision = 0.878 vs. 0.087
# Recall = 0.970 vs. 0.899
# Validation: 9100
# ACTIVITY RECOGNITION
# AUC = 0.674 vs. 0.058
# F1 = 0.672 vs. 0.079
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.048
# F1 = 0.380 vs. 0.096
# Precision = 0.315 vs. 0.051
# Recall = 0.481 vs. 1.000
# Minibatch Loss= 0.016946
# Training: 9200
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.063
# F1 = 0.989 vs. 0.094
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.113
# F1 = 0.947 vs. 0.199
# Precision = 0.910 vs. 0.111
# Recall = 0.986 vs. 0.947
# Validation: 9200
# ACTIVITY RECOGNITION
# AUC = 0.677 vs. 0.059
# F1 = 0.675 vs. 0.082
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.284 vs. 0.050
# F1 = 0.375 vs. 0.097
# Precision = 0.320 vs. 0.051
# Recall = 0.452 vs. 0.969
# Minibatch Loss= 0.016782
# Training: 9300
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.060
# F1 = 0.991 vs. 0.089
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.093
# F1 = 0.952 vs. 0.160
# Precision = 0.929 vs. 0.088
# Recall = 0.976 vs. 0.909
# Validation: 9300
# ACTIVITY RECOGNITION
# AUC = 0.679 vs. 0.060
# F1 = 0.678 vs. 0.085
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.280 vs. 0.050
# F1 = 0.382 vs. 0.097
# Precision = 0.325 vs. 0.051
# Recall = 0.462 vs. 0.984
# Minibatch Loss= 0.013950
# Training: 9400
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.060
# F1 = 0.992 vs. 0.091
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.100
# F1 = 0.956 vs. 0.169
# Precision = 0.920 vs. 0.093
# Recall = 0.994 vs. 0.953
# Validation: 9400
# ACTIVITY RECOGNITION
# AUC = 0.681 vs. 0.059
# F1 = 0.679 vs. 0.079
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.277 vs. 0.057
# F1 = 0.378 vs. 0.097
# Precision = 0.333 vs. 0.052
# Recall = 0.436 vs. 0.862
# Minibatch Loss= 0.012791
# Training: 9500
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.090
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.978 vs. 0.093
# F1 = 0.959 vs. 0.164
# Precision = 0.944 vs. 0.090
# Recall = 0.975 vs. 0.928
# Validation: 9500
# ACTIVITY RECOGNITION
# AUC = 0.684 vs. 0.058
# F1 = 0.680 vs. 0.080
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.274 vs. 0.052
# F1 = 0.374 vs. 0.100
# Precision = 0.318 vs. 0.055
# Recall = 0.455 vs. 0.558
# Minibatch Loss= 0.011130
# Training: 9600
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.061
# F1 = 0.995 vs. 0.090
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.070
# F1 = 0.958 vs. 0.139
# Precision = 0.939 vs. 0.075
# Recall = 0.977 vs. 0.996
# Validation: 9600
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.058
# F1 = 0.683 vs. 0.079
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.275 vs. 0.051
# F1 = 0.374 vs. 0.098
# Precision = 0.299 vs. 0.052
# Recall = 0.499 vs. 0.745
# Minibatch Loss= 0.009867
# Training: 9700
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.062
# F1 = 0.995 vs. 0.096
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.115
# F1 = 0.980 vs. 0.204
# Precision = 0.968 vs. 0.114
# Recall = 0.993 vs. 0.964
# Validation: 9700
# ACTIVITY RECOGNITION
# AUC = 0.684 vs. 0.058
# F1 = 0.682 vs. 0.078
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.270 vs. 0.057
# F1 = 0.369 vs. 0.104
# Precision = 0.307 vs. 0.057
# Recall = 0.462 vs. 0.621
# Minibatch Loss= 0.010823
# Training: 9800
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.095
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.093
# F1 = 0.982 vs. 0.176
# Precision = 0.971 vs. 0.097
# Recall = 0.993 vs. 0.964
# Validation: 9800
# ACTIVITY RECOGNITION
# AUC = 0.684 vs. 0.059
# F1 = 0.682 vs. 0.079
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.049
# F1 = 0.373 vs. 0.096
# Precision = 0.310 vs. 0.051
# Recall = 0.468 vs. 1.000
# Minibatch Loss= 0.008566
# Training: 9900
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.061
# F1 = 0.996 vs. 0.092
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.093
# F1 = 0.980 vs. 0.173
# Precision = 0.968 vs. 0.095
# Recall = 0.993 vs. 0.983
# Validation: 9900
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.059
# F1 = 0.682 vs. 0.082
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.265 vs. 0.051
# F1 = 0.368 vs. 0.102
# Precision = 0.309 vs. 0.056
# Recall = 0.455 vs. 0.613
# Minibatch Loss= 0.007985
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../../model/CNN_16_1/CNN_16_1-10000'

# %%
#load the model
#saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
#saver.restore(sess, '../../model/CNN_Wmultitask_16_opp/CNN_Wmultitask_16_opp-20000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.685 vs. 0.059
# F1 = 0.683 vs. 0.077
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.055
# F1 = 0.368 vs. 0.104
# Precision = 0.299 vs. 0.057
# Recall = 0.478 vs. 0.642

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../../../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
# Out:
# 1
