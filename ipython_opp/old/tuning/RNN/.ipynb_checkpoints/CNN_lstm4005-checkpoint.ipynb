# %%
# useing this variable for saving models and summaries
exp_name = "CNN-LSTM4005"

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../../src')
sys.path.append('../../../src/models')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

pooling_stride = [4, 2, 2, 2, 1, 1]
weights_shape = [[7,n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]

bias_shape = [32, 32, 32, 32, 32, 32, 32]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 1


#positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
pos_weight
# Out:
# 3.186018221237171

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables, n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride,
                         weights_shape,
                         bias_shape,
                         activation,
                         lstm_n_hidden,
                         n_classes,
                         learning_rate,
                         pos_weight)

# %%
train_obj = training.Trainer(model,
                 train_data, train_gt,
                 validation_data, validation_gt,
                 sess,
                 summary_path,
                 batch_size,
                 global_step = 0)

# %%
train_obj.train(max_iter = 10000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Tarin Iter 0, auc= 0.287518, fmeasure_max= 0.403232, precision= 0.271048, recall= 0.787066
# Train Random guess:  , auc= 0.259191fmeasure_max= 0.398574, precision= 0.250816, recall= 0.970032
# Validation Iter 0, auc= 0.183087, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Validation Random guess:  auc= 0.223657, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 1.076743
# Tarin Iter 100, auc= 0.725111, fmeasure_max= 0.738689, precision= 0.775194, recall= 0.705467
# Train Random guess:  , auc= 0.210125fmeasure_max= 0.363105, precision= 0.222532, recall= 0.985891
# Validation Iter 100, auc= 0.727651, fmeasure_max= 0.707775, precision= 0.738806, recall= 0.679245
# Validation Random guess:  auc= 0.227239, fmeasure_max= 0.372695, precision= 0.229665, recall= 0.987993
# Minibatch Loss= 0.772597
# Tarin Iter 200, auc= 0.803521, fmeasure_max= 0.765379, precision= 0.762108, recall= 0.768678
# Train Random guess:  , auc= 0.280548fmeasure_max= 0.428792, precision= 0.273121, recall= 0.997126
# Validation Iter 200, auc= 0.812094, fmeasure_max= 0.762836, precision= 0.726708, recall= 0.802744
# Validation Random guess:  auc= 0.237626, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.793221
# Tarin Iter 300, auc= 0.879088, fmeasure_max= 0.806293, precision= 0.864979, recall= 0.755064
# Train Random guess:  , auc= 0.219039fmeasure_max= 0.351433, precision= 0.215111, recall= 0.959484
# Validation Iter 300, auc= 0.851091, fmeasure_max= 0.781995, precision= 0.805455, recall= 0.759863
# Validation Random guess:  auc= 0.227485, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.629484
# Tarin Iter 400, auc= 0.915826, fmeasure_max= 0.842004, precision= 0.860236, recall= 0.824528
# Train Random guess:  , auc= 0.196726fmeasure_max= 0.345430, precision= 0.210139, recall= 0.969811
# Validation Iter 400, auc= 0.923059, fmeasure_max= 0.857847, precision= 0.823344, recall= 0.895369
# Validation Random guess:  auc= 0.219749, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.478557
# Tarin Iter 500, auc= 0.877916, fmeasure_max= 0.815553, precision= 0.893013, recall= 0.750459
# Train Random guess:  , auc= 0.216324fmeasure_max= 0.353559, precision= 0.215256, recall= 0.988991
# Validation Iter 500, auc= 0.890182, fmeasure_max= 0.823009, precision= 0.850091, recall= 0.797599
# Validation Random guess:  auc= 0.233441, fmeasure_max= 0.373360, precision= 0.230832, recall= 0.975986
# Minibatch Loss= 0.555382
# Tarin Iter 600, auc= 0.884261, fmeasure_max= 0.830159, precision= 0.831479, recall= 0.828843
# Train Random guess:  , auc= 0.250911fmeasure_max= 0.396102, precision= 0.247059, recall= 0.998415
# Validation Iter 600, auc= 0.923904, fmeasure_max= 0.856410, precision= 0.853492, recall= 0.859348
# Validation Random guess:  auc= 0.225435, fmeasure_max= 0.371382, precision= 0.229133, recall= 0.979417
# Minibatch Loss= 0.612223
# Tarin Iter 700, auc= 0.939028, fmeasure_max= 0.872483, precision= 0.895669, recall= 0.850467
# Train Random guess:  , auc= 0.209405fmeasure_max= 0.347919, precision= 0.214851, recall= 0.914019
# Validation Iter 700, auc= 0.911241, fmeasure_max= 0.837489, precision= 0.839655, recall= 0.835334
# Validation Random guess:  auc= 0.235642, fmeasure_max= 0.374626, precision= 0.232290, recall= 0.967410
# Minibatch Loss= 0.443466
# Tarin Iter 800, auc= 0.911459, fmeasure_max= 0.833191, precision= 0.848432, recall= 0.818487
# Train Random guess:  , auc= 0.239351fmeasure_max= 0.377418, precision= 0.232604, recall= 1.000000
# Validation Iter 800, auc= 0.895489, fmeasure_max= 0.840070, precision= 0.861261, recall= 0.819897
# Validation Random guess:  auc= 0.234022, fmeasure_max= 0.371750, precision= 0.228673, recall= 0.993139
# Minibatch Loss= 0.522747
# Tarin Iter 900, auc= 0.924148, fmeasure_max= 0.846435, precision= 0.892100, recall= 0.805217
# Train Random guess:  , auc= 0.237604fmeasure_max= 0.370474, precision= 0.231606, recall= 0.925217
# Validation Iter 900, auc= 0.874077, fmeasure_max= 0.797178, precision= 0.820327, recall= 0.775300
# Validation Random guess:  auc= 0.236941, fmeasure_max= 0.372153, precision= 0.228887, recall= 0.994854
# Minibatch Loss= 0.493744
# Tarin Iter 1000, auc= 0.939102, fmeasure_max= 0.877722, precision= 0.877722, recall= 0.877722
# Train Random guess:  , auc= 0.233507fmeasure_max= 0.379156, precision= 0.234295, recall= 0.993300
# Validation Iter 1000, auc= 0.932964, fmeasure_max= 0.872358, precision= 0.860000, recall= 0.885077
# Validation Random guess:  auc= 0.225044, fmeasure_max= 0.373001, precision= 0.229257, recall= 1.000000
# Minibatch Loss= 0.474546
# Tarin Iter 1100, auc= 0.936059, fmeasure_max= 0.863636, precision= 0.901328, recall= 0.828970
# Train Random guess:  , auc= 0.228462fmeasure_max= 0.367757, precision= 0.225755, recall= 0.991274
# Validation Iter 1100, auc= 0.939866, fmeasure_max= 0.866071, precision= 0.903166, recall= 0.831904
# Validation Random guess:  auc= 0.219694, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.481624
# Tarin Iter 1200, auc= 0.944490, fmeasure_max= 0.871237, precision= 0.895189, recall= 0.848534
# Train Random guess:  , auc= 0.230433fmeasure_max= 0.387983, precision= 0.241352, recall= 0.988599
# Validation Iter 1200, auc= 0.922621, fmeasure_max= 0.850847, precision= 0.840871, recall= 0.861063
# Validation Random guess:  auc= 0.235122, fmeasure_max= 0.374001, precision= 0.234525, recall= 0.922813
# Minibatch Loss= 0.482359
# Tarin Iter 1300, auc= 0.958207, fmeasure_max= 0.896364, precision= 0.872566, recall= 0.921495
# Train Random guess:  , auc= 0.213342fmeasure_max= 0.348112, precision= 0.211155, recall= 0.990654
# Validation Iter 1300, auc= 0.927506, fmeasure_max= 0.858630, precision= 0.868421, recall= 0.849057
# Validation Random guess:  auc= 0.236876, fmeasure_max= 0.371769, precision= 0.230390, recall= 0.962264
# Minibatch Loss= 0.415972
# Tarin Iter 1400, auc= 0.951524, fmeasure_max= 0.885093, precision= 0.879630, recall= 0.890625
# Train Random guess:  , auc= 0.265943fmeasure_max= 0.401634, precision= 0.251377, recall= 0.998437
# Validation Iter 1400, auc= 0.938675, fmeasure_max= 0.862447, precision= 0.848837, recall= 0.876501
# Validation Random guess:  auc= 0.242797, fmeasure_max= 0.371837, precision= 0.236474, recall= 0.869640
# Minibatch Loss= 0.454107
# Tarin Iter 1500, auc= 0.944304, fmeasure_max= 0.874032, precision= 0.828000, recall= 0.925484
# Train Random guess:  , auc= 0.263685fmeasure_max= 0.416408, precision= 0.263055, recall= 0.998510
# Validation Iter 1500, auc= 0.937080, fmeasure_max= 0.871452, precision= 0.848780, recall= 0.895369
# Validation Random guess:  auc= 0.223613, fmeasure_max= 0.372675, precision= 0.229191, recall= 0.996569
# Minibatch Loss= 0.500052
# Tarin Iter 1600, auc= 0.918380, fmeasure_max= 0.829845, precision= 0.842884, recall= 0.817204
# Train Random guess:  , auc= 0.228780fmeasure_max= 0.358037, precision= 0.218054, recall= 1.000000
# Validation Iter 1600, auc= 0.913999, fmeasure_max= 0.853514, precision= 0.842809, recall= 0.864494
# Validation Random guess:  auc= 0.224148, fmeasure_max= 0.372675, precision= 0.229191, recall= 0.996569
# Minibatch Loss= 0.506162
# Tarin Iter 1700, auc= 0.965736, fmeasure_max= 0.900251, precision= 0.896494, recall= 0.904040
# Train Random guess:  , auc= 0.233587fmeasure_max= 0.377600, precision= 0.233109, recall= 0.993266
# Validation Iter 1700, auc= 0.922691, fmeasure_max= 0.858102, precision= 0.840461, recall= 0.876501
# Validation Random guess:  auc= 0.227663, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.453637
# Tarin Iter 1800, auc= 0.965657, fmeasure_max= 0.898894, precision= 0.896063, recall= 0.901743
# Train Random guess:  , auc= 0.236432fmeasure_max= 0.395487, precision= 0.246484, recall= 1.000000
# Validation Iter 1800, auc= 0.933374, fmeasure_max= 0.862511, precision= 0.858844, recall= 0.866209
# Validation Random guess:  auc= 0.223552, fmeasure_max= 0.373777, precision= 0.230769, recall= 0.982847
# Minibatch Loss= 0.410676
# Tarin Iter 1900, auc= 0.912732, fmeasure_max= 0.846878, precision= 0.851979, recall= 0.841837
# Train Random guess:  , auc= 0.228662fmeasure_max= 0.376372, precision= 0.232271, recall= 0.991497
# Validation Iter 1900, auc= 0.938982, fmeasure_max= 0.868755, precision= 0.857860, recall= 0.879931
# Validation Random guess:  auc= 0.212916, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.484900
# Tarin Iter 2000, auc= 0.928307, fmeasure_max= 0.849558, precision= 0.832972, recall= 0.866817
# Train Random guess:  , auc= 0.166508fmeasure_max= 0.298373, precision= 0.176206, recall= 0.972912
# Validation Iter 2000, auc= 0.878815, fmeasure_max= 0.810811, precision= 0.853890, recall= 0.771870
# Validation Random guess:  auc= 0.231521, fmeasure_max= 0.372643, precision= 0.228987, recall= 1.000000
# Minibatch Loss= 0.377479
# Tarin Iter 2100, auc= 0.969384, fmeasure_max= 0.917526, precision= 0.869707, recall= 0.970909
# Train Random guess:  , auc= 0.212414fmeasure_max= 0.355642, precision= 0.216280, recall= 1.000000
# Validation Iter 2100, auc= 0.937471, fmeasure_max= 0.872947, precision= 0.879791, recall= 0.866209
# Validation Random guess:  auc= 0.249316, fmeasure_max= 0.374134, precision= 0.231618, recall= 0.972556
# Minibatch Loss= 0.352316
# Tarin Iter 2200, auc= 0.949626, fmeasure_max= 0.886518, precision= 0.887379, recall= 0.885659
# Train Random guess:  , auc= 0.218605fmeasure_max= 0.336653, precision= 0.203125, recall= 0.982558
# Validation Iter 2200, auc= 0.916554, fmeasure_max= 0.826623, precision= 0.793375, recall= 0.862779
# Validation Random guess:  auc= 0.224504, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.413108
# Tarin Iter 2300, auc= 0.906564, fmeasure_max= 0.818565, precision= 0.862989, recall= 0.778491
# Train Random guess:  , auc= 0.258260fmeasure_max= 0.392070, precision= 0.243836, recall= 1.000000
# Validation Iter 2300, auc= 0.923722, fmeasure_max= 0.853186, precision= 0.924000, recall= 0.792453
# Validation Random guess:  auc= 0.230483, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.576263
# Tarin Iter 2400, auc= 0.955020, fmeasure_max= 0.886010, precision= 0.869492, recall= 0.903169
# Train Random guess:  , auc= 0.210871fmeasure_max= 0.363636, precision= 0.222397, recall= 0.996479
# Validation Iter 2400, auc= 0.946376, fmeasure_max= 0.874126, precision= 0.891266, recall= 0.857633
# Validation Random guess:  auc= 0.245992, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.386169
# Tarin Iter 2500, auc= 0.942284, fmeasure_max= 0.862843, precision= 0.859272, recall= 0.866444
# Train Random guess:  , auc= 0.236273fmeasure_max= 0.382475, precision= 0.236551, recall= 0.998331
# Validation Iter 2500, auc= 0.909440, fmeasure_max= 0.824889, precision= 0.856089, recall= 0.795883
# Validation Random guess:  auc= 0.226170, fmeasure_max= 0.372760, precision= 0.230088, recall= 0.981132
# Minibatch Loss= 0.438369
# Tarin Iter 2600, auc= 0.964165, fmeasure_max= 0.896813, precision= 0.906442, recall= 0.887387
# Train Random guess:  , auc= 0.261018fmeasure_max= 0.413408, precision= 0.260563, recall= 1.000000
# Validation Iter 2600, auc= 0.927236, fmeasure_max= 0.845047, precision= 0.834448, recall= 0.855918
# Validation Random guess:  auc= 0.229221, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.447638
# Tarin Iter 2700, auc= 0.955462, fmeasure_max= 0.884752, precision= 0.881625, recall= 0.887900
# Train Random guess:  , auc= 0.231534fmeasure_max= 0.362035, precision= 0.221645, recall= 0.987544
# Validation Iter 2700, auc= 0.893408, fmeasure_max= 0.803604, precision= 0.846300, recall= 0.765009
# Validation Random guess:  auc= 0.233100, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.456229
# Tarin Iter 2800, auc= 0.942251, fmeasure_max= 0.858988, precision= 0.863636, recall= 0.854390
# Train Random guess:  , auc= 0.180453fmeasure_max= 0.308760, precision= 0.182565, recall= 1.000000
# Validation Iter 2800, auc= 0.915551, fmeasure_max= 0.839529, precision= 0.890385, recall= 0.794168
# Validation Random guess:  auc= 0.209329, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.368162
# Tarin Iter 2900, auc= 0.952020, fmeasure_max= 0.875200, precision= 0.890879, recall= 0.860063
# Train Random guess:  , auc= 0.256140fmeasure_max= 0.398356, precision= 0.249307, recall= 0.990566
# Validation Iter 2900, auc= 0.937546, fmeasure_max= 0.857895, precision= 0.877917, recall= 0.838765
# Validation Random guess:  auc= 0.233786, fmeasure_max= 0.377547, precision= 0.238482, recall= 0.905660
# Minibatch Loss= 0.463639
# Tarin Iter 3000, auc= 0.954896, fmeasure_max= 0.878165, precision= 0.868545, recall= 0.888000
# Train Random guess:  , auc= 0.242030fmeasure_max= 0.393082, precision= 0.244618, recall= 1.000000
# Validation Iter 3000, auc= 0.912405, fmeasure_max= 0.840809, precision= 0.862816, recall= 0.819897
# Validation Random guess:  auc= 0.220770, fmeasure_max= 0.372794, precision= 0.229282, recall= 0.996569
# Minibatch Loss= 0.429345
# Tarin Iter 3100, auc= 0.934603, fmeasure_max= 0.846512, precision= 0.881783, recall= 0.813953
# Train Random guess:  , auc= 0.216969fmeasure_max= 0.359754, precision= 0.219589, recall= 0.994633
# Validation Iter 3100, auc= 0.949336, fmeasure_max= 0.877133, precision= 0.872666, recall= 0.881647
# Validation Random guess:  auc= 0.231340, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.483984
# Tarin Iter 3200, auc= 0.951024, fmeasure_max= 0.891501, precision= 0.891501, recall= 0.891501
# Train Random guess:  , auc= 0.221043fmeasure_max= 0.357166, precision= 0.217494, recall= 0.998192
# Validation Iter 3200, auc= 0.939292, fmeasure_max= 0.859206, precision= 0.906667, recall= 0.816467
# Validation Random guess:  auc= 0.232081, fmeasure_max= 0.373067, precision= 0.229671, recall= 0.993139
# Minibatch Loss= 0.416069
# Tarin Iter 3300, auc= 0.958834, fmeasure_max= 0.902511, precision= 0.885507, recall= 0.920181
# Train Random guess:  , auc= 0.260783fmeasure_max= 0.412060, precision= 0.260317, recall= 0.987952
# Validation Iter 3300, auc= 0.941122, fmeasure_max= 0.863884, precision= 0.917148, recall= 0.816467
# Validation Random guess:  auc= 0.246858, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.433674
# Tarin Iter 3400, auc= 0.941190, fmeasure_max= 0.875465, precision= 0.897143, recall= 0.854809
# Train Random guess:  , auc= 0.222200fmeasure_max= 0.354683, precision= 0.215571, recall= 1.000000
# Validation Iter 3400, auc= 0.956664, fmeasure_max= 0.885077, precision= 0.885077, recall= 0.885077
# Validation Random guess:  auc= 0.233612, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.449955
# Tarin Iter 3500, auc= 0.936385, fmeasure_max= 0.858630, precision= 0.863874, recall= 0.853448
# Train Random guess:  , auc= 0.240028fmeasure_max= 0.372986, precision= 0.232777, recall= 0.937931
# Validation Iter 3500, auc= 0.940101, fmeasure_max= 0.859416, precision= 0.886861, recall= 0.833619
# Validation Random guess:  auc= 0.234284, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.454467
# Tarin Iter 3600, auc= 0.945063, fmeasure_max= 0.871479, precision= 0.903285, recall= 0.841837
# Train Random guess:  , auc= 0.225778fmeasure_max= 0.373571, precision= 0.229687, recall= 1.000000
# Validation Iter 3600, auc= 0.948045, fmeasure_max= 0.878916, precision= 0.867893, recall= 0.890223
# Validation Random guess:  auc= 0.235870, fmeasure_max= 0.372517, precision= 0.229904, recall= 0.981132
# Minibatch Loss= 0.443405
# Tarin Iter 3700, auc= 0.965142, fmeasure_max= 0.907705, precision= 0.930556, recall= 0.885950
# Train Random guess:  , auc= 0.232370fmeasure_max= 0.382548, precision= 0.236513, recall= 1.000000
# Validation Iter 3700, auc= 0.955879, fmeasure_max= 0.889465, precision= 0.895652, recall= 0.883362
# Validation Random guess:  auc= 0.225449, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.426015
# Tarin Iter 3800, auc= 0.977214, fmeasure_max= 0.928196, precision= 0.931459, recall= 0.924956
# Train Random guess:  , auc= 0.226566fmeasure_max= 0.369854, precision= 0.228372, recall= 0.972077
# Validation Iter 3800, auc= 0.958396, fmeasure_max= 0.882545, precision= 0.841369, recall= 0.927959
# Validation Random guess:  auc= 0.212518, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.359984
# Tarin Iter 3900, auc= 0.951939, fmeasure_max= 0.863487, precision= 0.880872, recall= 0.846774
# Train Random guess:  , auc= 0.246142fmeasure_max= 0.390398, precision= 0.242734, recall= 0.996774
# Validation Iter 3900, auc= 0.895856, fmeasure_max= 0.809302, precision= 0.884146, recall= 0.746141
# Validation Random guess:  auc= 0.233504, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.446584
# Tarin Iter 4000, auc= 0.969610, fmeasure_max= 0.913793, precision= 0.931459, recall= 0.896785
# Train Random guess:  , auc= 0.222103fmeasure_max= 0.376074, precision= 0.231583, recall= 1.000000
# Validation Iter 4000, auc= 0.937523, fmeasure_max= 0.860606, precision= 0.868881, recall= 0.852487
# Validation Random guess:  auc= 0.234866, fmeasure_max= 0.372562, precision= 0.229844, recall= 0.982847
# Minibatch Loss= 0.368656
# Tarin Iter 4100, auc= 0.962511, fmeasure_max= 0.893954, precision= 0.887795, recall= 0.900200
# Train Random guess:  , auc= 0.199048fmeasure_max= 0.329737, precision= 0.198377, recall= 0.976048
# Validation Iter 4100, auc= 0.935766, fmeasure_max= 0.846957, precision= 0.858907, recall= 0.835334
# Validation Random guess:  auc= 0.224391, fmeasure_max= 0.373581, precision= 0.233649, recall= 0.931389
# Minibatch Loss= 0.370431
# Tarin Iter 4200, auc= 0.961668, fmeasure_max= 0.903226, precision= 0.900415, recall= 0.906054
# Train Random guess:  , auc= 0.205939fmeasure_max= 0.316628, precision= 0.188240, recall= 0.995825
# Validation Iter 4200, auc= 0.934475, fmeasure_max= 0.866609, precision= 0.881206, recall= 0.852487
# Validation Random guess:  auc= 0.226294, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.336260
# Tarin Iter 4300, auc= 0.964207, fmeasure_max= 0.901408, precision= 0.881239, recall= 0.922523
# Train Random guess:  , auc= 0.236390fmeasure_max= 0.358707, precision= 0.222222, recall= 0.929730
# Validation Iter 4300, auc= 0.902852, fmeasure_max= 0.826007, precision= 0.886051, recall= 0.773585
# Validation Random guess:  auc= 0.246454, fmeasure_max= 0.376471, precision= 0.232539, recall= 0.987993
# Minibatch Loss= 0.349297
# Tarin Iter 4400, auc= 0.971287, fmeasure_max= 0.914573, precision= 0.903974, recall= 0.925424
# Train Random guess:  , auc= 0.231753fmeasure_max= 0.376756, precision= 0.232101, recall= 1.000000
# Validation Iter 4400, auc= 0.944462, fmeasure_max= 0.876174, precision= 0.872449, recall= 0.879931
# Validation Random guess:  auc= 0.242391, fmeasure_max= 0.371879, precision= 0.229988, recall= 0.970840
# Minibatch Loss= 0.408896
# Tarin Iter 4500, auc= 0.963013, fmeasure_max= 0.902148, precision= 0.885938, recall= 0.918963
# Train Random guess:  , auc= 0.251092fmeasure_max= 0.389997, precision= 0.242329, recall= 0.998379
# Validation Iter 4500, auc= 0.935521, fmeasure_max= 0.870403, precision= 0.889088, recall= 0.852487
# Validation Random guess:  auc= 0.240295, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.410161
# Tarin Iter 4600, auc= 0.975114, fmeasure_max= 0.914141, precision= 0.908027, recall= 0.920339
# Train Random guess:  , auc= 0.239047fmeasure_max= 0.375080, precision= 0.231102, recall= 0.994915
# Validation Iter 4600, auc= 0.957623, fmeasure_max= 0.878661, precision= 0.857843, recall= 0.900515
# Validation Random guess:  auc= 0.232819, fmeasure_max= 0.373034, precision= 0.229463, recall= 0.996569
# Minibatch Loss= 0.400615
# Tarin Iter 4700, auc= 0.952208, fmeasure_max= 0.873802, precision= 0.916248, recall= 0.835115
# Train Random guess:  , auc= 0.253389fmeasure_max= 0.407604, precision= 0.256069, recall= 0.998473
# Validation Iter 4700, auc= 0.946904, fmeasure_max= 0.875106, precision= 0.867003, recall= 0.883362
# Validation Random guess:  auc= 0.225644, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.489318
# Tarin Iter 4800, auc= 0.974989, fmeasure_max= 0.913075, precision= 0.886525, recall= 0.941265
# Train Random guess:  , auc= 0.258717fmeasure_max= 0.412858, precision= 0.261060, recall= 0.986446
# Validation Iter 4800, auc= 0.937536, fmeasure_max= 0.863333, precision= 0.839546, recall= 0.888508
# Validation Random guess:  auc= 0.226703, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.443393
# Tarin Iter 4900, auc= 0.964229, fmeasure_max= 0.905550, precision= 0.904669, recall= 0.906433
# Train Random guess:  , auc= 0.210518fmeasure_max= 0.336201, precision= 0.202471, recall= 0.990253
# Validation Iter 4900, auc= 0.944205, fmeasure_max= 0.871441, precision= 0.876736, recall= 0.866209
# Validation Random guess:  auc= 0.241019, fmeasure_max= 0.371863, precision= 0.230266, recall= 0.965695
# Minibatch Loss= 0.360708
# Tarin Iter 5000, auc= 0.964293, fmeasure_max= 0.899051, precision= 0.922124, recall= 0.877104
# Train Random guess:  , auc= 0.226075fmeasure_max= 0.378464, precision= 0.233399, recall= 1.000000
# Validation Iter 5000, auc= 0.905007, fmeasure_max= 0.820106, precision= 0.843920, recall= 0.797599
# Validation Random guess:  auc= 0.229624, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.413306
# Tarin Iter 5100, auc= 0.977229, fmeasure_max= 0.918216, precision= 0.939163, recall= 0.898182
# Train Random guess:  , auc= 0.213347fmeasure_max= 0.355629, precision= 0.217409, recall= 0.976364
# Validation Iter 5100, auc= 0.952266, fmeasure_max= 0.882453, precision= 0.876481, recall= 0.888508
# Validation Random guess:  auc= 0.232501, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.360099
# Tarin Iter 5200, auc= 0.971131, fmeasure_max= 0.917574, precision= 0.893939, recall= 0.942492
# Train Random guess:  , auc= 0.262808fmeasure_max= 0.392969, precision= 0.244531, recall= 1.000000
# Validation Iter 5200, auc= 0.952465, fmeasure_max= 0.877498, precision= 0.889085, recall= 0.866209
# Validation Random guess:  auc= 0.227605, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.414386
# Tarin Iter 5300, auc= 0.966017, fmeasure_max= 0.900084, precision= 0.868720, recall= 0.933798
# Train Random guess:  , auc= 0.228734fmeasure_max= 0.367137, precision= 0.225020, recall= 0.996516
# Validation Iter 5300, auc= 0.953717, fmeasure_max= 0.880407, precision= 0.870805, recall= 0.890223
# Validation Random guess:  auc= 0.233170, fmeasure_max= 0.372229, precision= 0.229779, recall= 0.979417
# Minibatch Loss= 0.384433
# Tarin Iter 5400, auc= 0.969147, fmeasure_max= 0.906801, precision= 0.910624, recall= 0.903010
# Train Random guess:  , auc= 0.231589fmeasure_max= 0.380032, precision= 0.235341, recall= 0.986622
# Validation Iter 5400, auc= 0.939396, fmeasure_max= 0.874138, precision= 0.878683, recall= 0.869640
# Validation Random guess:  auc= 0.236515, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.399551
# Tarin Iter 5500, auc= 0.972787, fmeasure_max= 0.916152, precision= 0.921847, recall= 0.910526
# Train Random guess:  , auc= 0.211497fmeasure_max= 0.364217, precision= 0.222656, recall= 1.000000
# Validation Iter 5500, auc= 0.956883, fmeasure_max= 0.892617, precision= 0.873563, recall= 0.912521
# Validation Random guess:  auc= 0.231594, fmeasure_max= 0.372536, precision= 0.230394, recall= 0.972556
# Minibatch Loss= 0.391969
# Tarin Iter 5600, auc= 0.970678, fmeasure_max= 0.904802, precision= 0.905565, recall= 0.904040
# Train Random guess:  , auc= 0.225189fmeasure_max= 0.376783, precision= 0.233333, recall= 0.978114
# Validation Iter 5600, auc= 0.949315, fmeasure_max= 0.873544, precision= 0.848142, recall= 0.900515
# Validation Random guess:  auc= 0.246425, fmeasure_max= 0.371750, precision= 0.228673, recall= 0.993139
# Minibatch Loss= 0.390232
# Tarin Iter 5700, auc= 0.972307, fmeasure_max= 0.922222, precision= 0.913761, recall= 0.930841
# Train Random guess:  , auc= 0.209516fmeasure_max= 0.345967, precision= 0.209248, recall= 0.998131
# Validation Iter 5700, auc= 0.935055, fmeasure_max= 0.854545, precision= 0.824561, recall= 0.886792
# Validation Random guess:  auc= 0.229147, fmeasure_max= 0.371273, precision= 0.228312, recall= 0.993139
# Minibatch Loss= 0.347594
# Tarin Iter 5800, auc= 0.982412, fmeasure_max= 0.925987, precision= 0.944631, recall= 0.908065
# Train Random guess:  , auc= 0.239262fmeasure_max= 0.394780, precision= 0.247444, recall= 0.975806
# Validation Iter 5800, auc= 0.936956, fmeasure_max= 0.858377, precision= 0.864348, recall= 0.852487
# Validation Random guess:  auc= 0.227629, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.367755
# Tarin Iter 5900, auc= 0.938117, fmeasure_max= 0.864293, precision= 0.890873, recall= 0.839252
# Train Random guess:  , auc= 0.209056fmeasure_max= 0.346278, precision= 0.209393, recall= 1.000000
# Validation Iter 5900, auc= 0.949644, fmeasure_max= 0.861456, precision= 0.893186, recall= 0.831904
# Validation Random guess:  auc= 0.236523, fmeasure_max= 0.373001, precision= 0.229257, recall= 1.000000
# Minibatch Loss= 0.414124
# Tarin Iter 6000, auc= 0.976691, fmeasure_max= 0.911013, precision= 0.928187, recall= 0.894464
# Train Random guess:  , auc= 0.238948fmeasure_max= 0.368388, precision= 0.225781, recall= 1.000000
# Validation Iter 6000, auc= 0.934356, fmeasure_max= 0.844996, precision= 0.873626, recall= 0.818182
# Validation Random guess:  auc= 0.246197, fmeasure_max= 0.375884, precision= 0.233864, recall= 0.957118
# Minibatch Loss= 0.358703
# Tarin Iter 6100, auc= 0.973507, fmeasure_max= 0.912975, precision= 0.898754, recall= 0.927653
# Train Random guess:  , auc= 0.245777fmeasure_max= 0.391072, precision= 0.243064, recall= 1.000000
# Validation Iter 6100, auc= 0.966094, fmeasure_max= 0.892148, precision= 0.897569, recall= 0.886792
# Validation Random guess:  auc= 0.234289, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.440981
# Tarin Iter 6200, auc= 0.968734, fmeasure_max= 0.910053, precision= 0.892734, recall= 0.928058
# Train Random guess:  , auc= 0.220885fmeasure_max= 0.357786, precision= 0.217868, recall= 1.000000
# Validation Iter 6200, auc= 0.960254, fmeasure_max= 0.883876, precision= 0.861564, recall= 0.907376
# Validation Random guess:  auc= 0.253876, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.373345
# Tarin Iter 6300, auc= 0.973576, fmeasure_max= 0.909971, precision= 0.916179, recall= 0.903846
# Train Random guess:  , auc= 0.209287fmeasure_max= 0.337992, precision= 0.203363, recall= 1.000000
# Validation Iter 6300, auc= 0.935225, fmeasure_max= 0.848222, precision= 0.857895, recall= 0.838765
# Validation Random guess:  auc= 0.235214, fmeasure_max= 0.372536, precision= 0.230394, recall= 0.972556
# Minibatch Loss= 0.354399
# Tarin Iter 6400, auc= 0.978233, fmeasure_max= 0.917108, precision= 0.945455, recall= 0.890411
# Train Random guess:  , auc= 0.238802fmeasure_max= 0.372330, precision= 0.228750, recall= 1.000000
# Validation Iter 6400, auc= 0.959538, fmeasure_max= 0.897544, precision= 0.886288, recall= 0.909091
# Validation Random guess:  auc= 0.228181, fmeasure_max= 0.373471, precision= 0.229885, recall= 0.994854
# Minibatch Loss= 0.386337
# Tarin Iter 6500, auc= 0.977819, fmeasure_max= 0.926400, precision= 0.944535, recall= 0.908948
# Train Random guess:  , auc= 0.252923fmeasure_max= 0.400129, precision= 0.251723, recall= 0.974882
# Validation Iter 6500, auc= 0.954689, fmeasure_max= 0.879590, precision= 0.875850, recall= 0.883362
# Validation Random guess:  auc= 0.238363, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.380910
# Tarin Iter 6600, auc= 0.966389, fmeasure_max= 0.902128, precision= 0.907534, recall= 0.896785
# Train Random guess:  , auc= 0.229930fmeasure_max= 0.375882, precision= 0.231896, recall= 0.991540
# Validation Iter 6600, auc= 0.926096, fmeasure_max= 0.839316, precision= 0.836457, recall= 0.842196
# Validation Random guess:  auc= 0.218009, fmeasure_max= 0.373482, precision= 0.230925, recall= 0.975986
# Minibatch Loss= 0.406610
# Tarin Iter 6700, auc= 0.976430, fmeasure_max= 0.911925, precision= 0.911215, recall= 0.912637
# Train Random guess:  , auc= 0.254481fmeasure_max= 0.401629, precision= 0.251274, recall= 1.000000
# Validation Iter 6700, auc= 0.950105, fmeasure_max= 0.870370, precision= 0.854545, recall= 0.886792
# Validation Random guess:  auc= 0.221932, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.368223
# Tarin Iter 6800, auc= 0.970305, fmeasure_max= 0.923567, precision= 0.900621, recall= 0.947712
# Train Random guess:  , auc= 0.236084fmeasure_max= 0.385998, precision= 0.239156, recall= 1.000000
# Validation Iter 6800, auc= 0.958885, fmeasure_max= 0.886383, precision= 0.896491, recall= 0.876501
# Validation Random guess:  auc= 0.233639, fmeasure_max= 0.375084, precision= 0.233042, recall= 0.960549
# Minibatch Loss= 0.393869
# Tarin Iter 6900, auc= 0.982468, fmeasure_max= 0.928857, precision= 0.925159, recall= 0.932584
# Train Random guess:  , auc= 0.241434fmeasure_max= 0.391455, precision= 0.243359, recall= 1.000000
# Validation Iter 6900, auc= 0.962786, fmeasure_max= 0.884682, precision= 0.887737, recall= 0.881647
# Validation Random guess:  auc= 0.226803, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.369623
# Tarin Iter 7000, auc= 0.962711, fmeasure_max= 0.899539, precision= 0.912150, recall= 0.887273
# Train Random guess:  , auc= 0.214525fmeasure_max= 0.353698, precision= 0.214844, recall= 1.000000
# Validation Iter 7000, auc= 0.961725, fmeasure_max= 0.894378, precision= 0.888325, recall= 0.900515
# Validation Random guess:  auc= 0.233894, fmeasure_max= 0.371807, precision= 0.229084, recall= 0.986278
# Minibatch Loss= 0.396892
# Tarin Iter 7100, auc= 0.981869, fmeasure_max= 0.920368, precision= 0.910606, recall= 0.930341
# Train Random guess:  , auc= 0.259833fmeasure_max= 0.402994, precision= 0.252344, recall= 1.000000
# Validation Iter 7100, auc= 0.953976, fmeasure_max= 0.880610, precision= 0.869565, recall= 0.891938
# Validation Random guess:  auc= 0.229909, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.377368
# Tarin Iter 7200, auc= 0.965016, fmeasure_max= 0.894693, precision= 0.896959, recall= 0.892437
# Train Random guess:  , auc= 0.245518fmeasure_max= 0.378049, precision= 0.233637, recall= 0.989916
# Validation Iter 7200, auc= 0.930907, fmeasure_max= 0.842809, precision= 0.822186, recall= 0.864494
# Validation Random guess:  auc= 0.245589, fmeasure_max= 0.374759, precision= 0.230678, recall= 0.998285
# Minibatch Loss= 0.389176
# Tarin Iter 7300, auc= 0.974708, fmeasure_max= 0.911145, precision= 0.889706, recall= 0.933642
# Train Random guess:  , auc= 0.262249fmeasure_max= 0.404635, precision= 0.253831, recall= 0.996914
# Validation Iter 7300, auc= 0.951850, fmeasure_max= 0.864348, precision= 0.876543, recall= 0.852487
# Validation Random guess:  auc= 0.227241, fmeasure_max= 0.373281, precision= 0.230676, recall= 0.977702
# Minibatch Loss= 0.434529
# Tarin Iter 7400, auc= 0.954924, fmeasure_max= 0.884714, precision= 0.859038, recall= 0.911972
# Train Random guess:  , auc= 0.214126fmeasure_max= 0.363171, precision= 0.221875, recall= 1.000000
# Validation Iter 7400, auc= 0.953612, fmeasure_max= 0.872918, precision= 0.892473, recall= 0.854202
# Validation Random guess:  auc= 0.235141, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.400019
# Tarin Iter 7500, auc= 0.974523, fmeasure_max= 0.910798, precision= 0.889908, recall= 0.932692
# Train Random guess:  , auc= 0.212046fmeasure_max= 0.340040, precision= 0.205930, recall= 0.975000
# Validation Iter 7500, auc= 0.955266, fmeasure_max= 0.876254, precision= 0.854812, recall= 0.898799
# Validation Random guess:  auc= 0.227062, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.349326
# Tarin Iter 7600, auc= 0.982570, fmeasure_max= 0.927197, precision= 0.894992, recall= 0.961806
# Train Random guess:  , auc= 0.243245fmeasure_max= 0.368098, precision= 0.226101, recall= 0.989583
# Validation Iter 7600, auc= 0.960553, fmeasure_max= 0.890344, precision= 0.851330, recall= 0.933105
# Validation Random guess:  auc= 0.241731, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.319226
# Tarin Iter 7700, auc= 0.984674, fmeasure_max= 0.942085, precision= 0.956113, recall= 0.928463
# Train Random guess:  , auc= 0.256188fmeasure_max= 0.408455, precision= 0.256641, recall= 1.000000
# Validation Iter 7700, auc= 0.956372, fmeasure_max= 0.890365, precision= 0.863124, recall= 0.919383
# Validation Random guess:  auc= 0.224034, fmeasure_max= 0.372937, precision= 0.230895, recall= 0.969125
# Minibatch Loss= 0.379015
# Tarin Iter 7800, auc= 0.961661, fmeasure_max= 0.894144, precision= 0.936321, recall= 0.855603
# Train Random guess:  , auc= 0.183618fmeasure_max= 0.309548, precision= 0.184243, recall= 0.967672
# Validation Iter 7800, auc= 0.955144, fmeasure_max= 0.874290, precision= 0.829231, recall= 0.924528
# Validation Random guess:  auc= 0.220675, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.374982
# Tarin Iter 7900, auc= 0.972414, fmeasure_max= 0.912577, precision= 0.928237, recall= 0.897436
# Train Random guess:  , auc= 0.258068fmeasure_max= 0.411618, precision= 0.259551, recall= 0.993967
# Validation Iter 7900, auc= 0.946419, fmeasure_max= 0.867365, precision= 0.882771, recall= 0.852487
# Validation Random guess:  auc= 0.214420, fmeasure_max= 0.371973, precision= 0.229117, recall= 0.987993
# Minibatch Loss= 0.421757
# Tarin Iter 8000, auc= 0.981731, fmeasure_max= 0.923985, precision= 0.930163, recall= 0.917889
# Train Random guess:  , auc= 0.259269fmeasure_max= 0.421314, precision= 0.267086, recall= 0.997067
# Validation Iter 8000, auc= 0.940425, fmeasure_max= 0.857877, precision= 0.856410, recall= 0.859348
# Validation Random guess:  auc= 0.235197, fmeasure_max= 0.375302, precision= 0.234888, recall= 0.933105
# Minibatch Loss= 0.383026
# Tarin Iter 8100, auc= 0.976850, fmeasure_max= 0.917031, precision= 0.891341, recall= 0.944245
# Train Random guess:  , auc= 0.226072fmeasure_max= 0.359441, precision= 0.219357, recall= 0.994604
# Validation Iter 8100, auc= 0.955887, fmeasure_max= 0.877722, precision= 0.857610, recall= 0.898799
# Validation Random guess:  auc= 0.241186, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.324409
# Tarin Iter 8200, auc= 0.978494, fmeasure_max= 0.926523, precision= 0.936594, recall= 0.916667
# Train Random guess:  , auc= 0.233188fmeasure_max= 0.366026, precision= 0.225968, recall= 0.962766
# Validation Iter 8200, auc= 0.960341, fmeasure_max= 0.890560, precision= 0.868078, recall= 0.914237
# Validation Random guess:  auc= 0.227926, fmeasure_max= 0.373561, precision= 0.231082, recall= 0.974271
# Minibatch Loss= 0.344643
# Tarin Iter 8300, auc= 0.979225, fmeasure_max= 0.927560, precision= 0.923715, recall= 0.931438
# Train Random guess:  , auc= 0.241730fmeasure_max= 0.379222, precision= 0.234252, recall= 0.994983
# Validation Iter 8300, auc= 0.962817, fmeasure_max= 0.885668, precision= 0.834598, recall= 0.943396
# Validation Random guess:  auc= 0.217984, fmeasure_max= 0.371882, precision= 0.229233, recall= 0.984563
# Minibatch Loss= 0.347991
# Tarin Iter 8400, auc= 0.969877, fmeasure_max= 0.900418, precision= 0.859425, recall= 0.945518
# Train Random guess:  , auc= 0.220994fmeasure_max= 0.364396, precision= 0.222965, recall= 0.996485
# Validation Iter 8400, auc= 0.924473, fmeasure_max= 0.840655, precision= 0.844291, recall= 0.837050
# Validation Random guess:  auc= 0.221573, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.398545
# Tarin Iter 8500, auc= 0.966323, fmeasure_max= 0.910304, precision= 0.896350, recall= 0.924699
# Train Random guess:  , auc= 0.257908fmeasure_max= 0.411911, precision= 0.259375, recall= 1.000000
# Validation Iter 8500, auc= 0.951306, fmeasure_max= 0.877342, precision= 0.871404, recall= 0.883362
# Validation Random guess:  auc= 0.219181, fmeasure_max= 0.372827, precision= 0.229489, recall= 0.993139
# Minibatch Loss= 0.402673
# Tarin Iter 8600, auc= 0.978789, fmeasure_max= 0.921434, precision= 0.924962, recall= 0.917933
# Train Random guess:  , auc= 0.267966fmeasure_max= 0.409459, precision= 0.257433, recall= 1.000000
# Validation Iter 8600, auc= 0.953054, fmeasure_max= 0.870175, precision= 0.890485, recall= 0.850772
# Validation Random guess:  auc= 0.215493, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.407157
# Tarin Iter 8700, auc= 0.978478, fmeasure_max= 0.933692, precision= 0.959484, recall= 0.909250
# Train Random guess:  , auc= 0.223085fmeasure_max= 0.367068, precision= 0.225600, recall= 0.984293
# Validation Iter 8700, auc= 0.932291, fmeasure_max= 0.871340, precision= 0.902574, recall= 0.842196
# Validation Random guess:  auc= 0.218091, fmeasure_max= 0.372892, precision= 0.229908, recall= 0.986278
# Minibatch Loss= 0.345020
# Tarin Iter 8800, auc= 0.979559, fmeasure_max= 0.930672, precision= 0.946581, recall= 0.915289
# Train Random guess:  , auc= 0.201727fmeasure_max= 0.318802, precision= 0.190004, recall= 0.989669
# Validation Iter 8800, auc= 0.942600, fmeasure_max= 0.873603, precision= 0.875862, recall= 0.871355
# Validation Random guess:  auc= 0.229136, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.262515
# Tarin Iter 8900, auc= 0.965904, fmeasure_max= 0.903342, precision= 0.917431, recall= 0.889680
# Train Random guess:  , auc= 0.220484fmeasure_max= 0.362755, precision= 0.221652, recall= 0.998221
# Validation Iter 8900, auc= 0.935365, fmeasure_max= 0.863212, precision= 0.855219, recall= 0.871355
# Validation Random guess:  auc= 0.238197, fmeasure_max= 0.373826, precision= 0.230431, recall= 0.989708
# Minibatch Loss= 0.367734
# Tarin Iter 9000, auc= 0.979717, fmeasure_max= 0.926199, precision= 0.916058, recall= 0.936567
# Train Random guess:  , auc= 0.209960fmeasure_max= 0.350102, precision= 0.214048, recall= 0.960821
# Validation Iter 9000, auc= 0.946825, fmeasure_max= 0.865568, precision= 0.875439, recall= 0.855918
# Validation Random guess:  auc= 0.235812, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.359733
# Tarin Iter 9100, auc= 0.960141, fmeasure_max= 0.889734, precision= 0.924171, recall= 0.857771
# Train Random guess:  , auc= 0.258700fmeasure_max= 0.422606, precision= 0.268877, recall= 0.986804
# Validation Iter 9100, auc= 0.902501, fmeasure_max= 0.829437, precision= 0.837413, recall= 0.821612
# Validation Random guess:  auc= 0.222758, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.464030
# Tarin Iter 9200, auc= 0.957635, fmeasure_max= 0.903117, precision= 0.935428, recall= 0.872964
# Train Random guess:  , auc= 0.228036fmeasure_max= 0.387199, precision= 0.240362, recall= 0.995114
# Validation Iter 9200, auc= 0.939752, fmeasure_max= 0.863676, precision= 0.886282, recall= 0.842196
# Validation Random guess:  auc= 0.226608, fmeasure_max= 0.373273, precision= 0.229644, recall= 0.996569
# Minibatch Loss= 0.452718
# Tarin Iter 9300, auc= 0.989317, fmeasure_max= 0.942424, precision= 0.900145, recall= 0.988871
# Train Random guess:  , auc= 0.256363fmeasure_max= 0.394729, precision= 0.245895, recall= 1.000000
# Validation Iter 9300, auc= 0.951017, fmeasure_max= 0.876307, precision= 0.890265, recall= 0.862779
# Validation Random guess:  auc= 0.246295, fmeasure_max= 0.372549, precision= 0.234052, recall= 0.912521
# Minibatch Loss= 0.321381
# Tarin Iter 9400, auc= 0.969719, fmeasure_max= 0.903974, precision= 0.902479, recall= 0.905473
# Train Random guess:  , auc= 0.244426fmeasure_max= 0.381284, precision= 0.235547, recall= 1.000000
# Validation Iter 9400, auc= 0.954612, fmeasure_max= 0.878887, precision= 0.840376, recall= 0.921098
# Validation Random guess:  auc= 0.239145, fmeasure_max= 0.371914, precision= 0.228707, recall= 0.994854
# Minibatch Loss= 0.424286
# Tarin Iter 9500, auc= 0.979449, fmeasure_max= 0.918688, precision= 0.929293, recall= 0.908322
# Train Random guess:  , auc= 0.272158fmeasure_max= 0.434170, precision= 0.277278, recall= 1.000000
# Validation Iter 9500, auc= 0.948019, fmeasure_max= 0.881154, precision= 0.872269, recall= 0.890223
# Validation Random guess:  auc= 0.250487, fmeasure_max= 0.372504, precision= 0.230178, recall= 0.975986
# Minibatch Loss= 0.427052
# Tarin Iter 9600, auc= 0.982685, fmeasure_max= 0.927152, precision= 0.912052, recall= 0.942761
# Train Random guess:  , auc= 0.224684fmeasure_max= 0.377143, precision= 0.232394, recall= 1.000000
# Validation Iter 9600, auc= 0.940398, fmeasure_max= 0.861436, precision= 0.839024, recall= 0.885077
# Validation Random guess:  auc= 0.227683, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.350443
# Tarin Iter 9700, auc= 0.982066, fmeasure_max= 0.924149, precision= 0.884444, recall= 0.967585
# Train Random guess:  , auc= 0.242029fmeasure_max= 0.389117, precision= 0.241745, recall= 0.996759
# Validation Iter 9700, auc= 0.949446, fmeasure_max= 0.870163, precision= 0.872414, recall= 0.867925
# Validation Random guess:  auc= 0.228852, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.370617
# Tarin Iter 9800, auc= 0.986970, fmeasure_max= 0.940048, precision= 0.939297, recall= 0.940800
# Train Random guess:  , auc= 0.234505fmeasure_max= 0.392711, precision= 0.244332, recall= 1.000000
# Validation Iter 9800, auc= 0.955264, fmeasure_max= 0.874598, precision= 0.822995, recall= 0.933105
# Validation Random guess:  auc= 0.229281, fmeasure_max= 0.373403, precision= 0.230769, recall= 0.977702
# Minibatch Loss= 0.343324

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=train_obj.global_step)

# %%
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-1000')

# %%
probability_of_pos = nn_eval.evaluate_model(model,
                                   sess,
                                   test_data,
                                   test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
