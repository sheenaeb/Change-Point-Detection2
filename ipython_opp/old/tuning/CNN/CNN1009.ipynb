# %%
# useing this variable for saving models and summaries
exp_name = "CNN1009"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [4, 4, 2, 1, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.257942, fmeasure_max= 0.393093, precision= 0.244627, recall= 1.000000
# Train Random guess:  , auc= 0.241191fmeasure_max= 0.395054, precision= 0.248059, recall= 0.969649
# Validation Iter 0, auc= 0.264190, fmeasure_max= 0.393622, precision= 0.277388, recall= 0.677530
# Validation Random guess:  auc= 0.236346, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 1.075578
# Tarin Iter 100, auc= 0.694163, fmeasure_max= 0.755733, precision= 0.779835, recall= 0.733075
# Train Random guess:  , auc= 0.199549fmeasure_max= 0.336595, precision= 0.202432, recall= 0.998066
# Validation Iter 100, auc= 0.753401, fmeasure_max= 0.722873, precision= 0.663324, recall= 0.794168
# Validation Random guess:  auc= 0.229546, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.772762
# Tarin Iter 200, auc= 0.825688, fmeasure_max= 0.761492, precision= 0.772887, recall= 0.750427
# Train Random guess:  , auc= 0.234057fmeasure_max= 0.372374, precision= 0.228784, recall= 1.000000
# Validation Iter 200, auc= 0.805000, fmeasure_max= 0.789223, precision= 0.733432, recall= 0.854202
# Validation Random guess:  auc= 0.226052, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.675936
# Tarin Iter 300, auc= 0.820532, fmeasure_max= 0.764610, precision= 0.850181, recall= 0.694690
# Train Random guess:  , auc= 0.263729fmeasure_max= 0.418777, precision= 0.264844, recall= 1.000000
# Validation Iter 300, auc= 0.816079, fmeasure_max= 0.781893, precision= 0.751582, recall= 0.814751
# Validation Random guess:  auc= 0.229957, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.773852
# Tarin Iter 400, auc= 0.803115, fmeasure_max= 0.782609, precision= 0.788961, recall= 0.776358
# Train Random guess:  , auc= 0.243600fmeasure_max= 0.393319, precision= 0.244994, recall= 0.996805
# Validation Iter 400, auc= 0.837440, fmeasure_max= 0.786885, precision= 0.753532, recall= 0.823328
# Validation Random guess:  auc= 0.219978, fmeasure_max= 0.371392, precision= 0.228402, recall= 0.993139
# Minibatch Loss= 0.686997
# Tarin Iter 500, auc= 0.841417, fmeasure_max= 0.761269, precision= 0.767677, recall= 0.754967
# Train Random guess:  , auc= 0.232414fmeasure_max= 0.382692, precision= 0.237281, recall= 0.988411
# Validation Iter 500, auc= 0.812467, fmeasure_max= 0.766067, precision= 0.765411, recall= 0.766724
# Validation Random guess:  auc= 0.218963, fmeasure_max= 0.374663, precision= 0.233124, recall= 0.953688
# Minibatch Loss= 0.702133
# Tarin Iter 600, auc= 0.862386, fmeasure_max= 0.819469, precision= 0.825312, recall= 0.813708
# Train Random guess:  , auc= 0.227199fmeasure_max= 0.364532, precision= 0.224152, recall= 0.975395
# Validation Iter 600, auc= 0.849782, fmeasure_max= 0.817481, precision= 0.816781, recall= 0.818182
# Validation Random guess:  auc= 0.230898, fmeasure_max= 0.372427, precision= 0.230024, recall= 0.977702
# Minibatch Loss= 0.661210
# Tarin Iter 700, auc= 0.872342, fmeasure_max= 0.817875, precision= 0.822034, recall= 0.813758
# Train Random guess:  , auc= 0.240533fmeasure_max= 0.378173, precision= 0.233177, recall= 1.000000
# Validation Iter 700, auc= 0.857693, fmeasure_max= 0.807554, precision= 0.848771, recall= 0.770154
# Validation Random guess:  auc= 0.227101, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.629294
# Tarin Iter 800, auc= 0.857913, fmeasure_max= 0.792763, precision= 0.794069, recall= 0.791461
# Train Random guess:  , auc= 0.227729fmeasure_max= 0.384763, precision= 0.238966, recall= 0.986864
# Validation Iter 800, auc= 0.855610, fmeasure_max= 0.776145, precision= 0.782230, recall= 0.770154
# Validation Random guess:  auc= 0.242084, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.624945
# Tarin Iter 900, auc= 0.863891, fmeasure_max= 0.799692, precision= 0.825119, recall= 0.775785
# Train Random guess:  , auc= 0.270710fmeasure_max= 0.415166, precision= 0.263221, recall= 0.982063
# Validation Iter 900, auc= 0.870490, fmeasure_max= 0.794401, precision= 0.810714, recall= 0.778731
# Validation Random guess:  auc= 0.226052, fmeasure_max= 0.372881, precision= 0.229167, recall= 1.000000
# Minibatch Loss= 0.704772
# Tarin Iter 1000, auc= 0.837793, fmeasure_max= 0.773333, precision= 0.764706, recall= 0.782158
# Train Random guess:  , auc= 0.194352fmeasure_max= 0.318548, precision= 0.190056, recall= 0.983402
# Validation Iter 1000, auc= 0.866254, fmeasure_max= 0.791851, precision= 0.818681, recall= 0.766724
# Validation Random guess:  auc= 0.212424, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.592199
# Tarin Iter 1100, auc= 0.839909, fmeasure_max= 0.809739, precision= 0.837687, recall= 0.783595
# Train Random guess:  , auc= 0.239267fmeasure_max= 0.367675, precision= 0.225424, recall= 0.996510
# Validation Iter 1100, auc= 0.858170, fmeasure_max= 0.817204, precision= 0.855535, recall= 0.782161
# Validation Random guess:  auc= 0.237007, fmeasure_max= 0.373120, precision= 0.229347, recall= 1.000000
# Minibatch Loss= 0.658421
# Tarin Iter 1200, auc= 0.890226, fmeasure_max= 0.815812, precision= 0.862989, recall= 0.773525
# Train Random guess:  , auc= 0.256632fmeasure_max= 0.393597, precision= 0.245018, recall= 1.000000
# Validation Iter 1200, auc= 0.881769, fmeasure_max= 0.811569, precision= 0.829749, recall= 0.794168
# Validation Random guess:  auc= 0.228930, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.581015
# Tarin Iter 1300, auc= 0.899781, fmeasure_max= 0.840603, precision= 0.874587, recall= 0.809160
# Train Random guess:  , auc= 0.248734fmeasure_max= 0.409020, precision= 0.257289, recall= 0.996947
# Validation Iter 1300, auc= 0.901570, fmeasure_max= 0.819255, precision= 0.870656, recall= 0.773585
# Validation Random guess:  auc= 0.230414, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.670532
# Tarin Iter 1400, auc= 0.957767, fmeasure_max= 0.896980, precision= 0.898577, recall= 0.895390
# Train Random guess:  , auc= 0.215253fmeasure_max= 0.362455, precision= 0.221869, recall= 0.989362
# Validation Iter 1400, auc= 0.890658, fmeasure_max= 0.821747, precision= 0.855288, recall= 0.790738
# Validation Random guess:  auc= 0.229946, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.425059
# Tarin Iter 1500, auc= 0.922715, fmeasure_max= 0.839350, precision= 0.861111, recall= 0.818662
# Train Random guess:  , auc= 0.222893fmeasure_max= 0.363812, precision= 0.222616, recall= 0.994718
# Validation Iter 1500, auc= 0.886801, fmeasure_max= 0.809773, precision= 0.824156, recall= 0.795883
# Validation Random guess:  auc= 0.226116, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.513839
# Tarin Iter 1600, auc= 0.916222, fmeasure_max= 0.849758, precision= 0.896082, recall= 0.807988
# Train Random guess:  , auc= 0.261796fmeasure_max= 0.405481, precision= 0.254297, recall= 1.000000
# Validation Iter 1600, auc= 0.871952, fmeasure_max= 0.819298, precision= 0.838420, recall= 0.801029
# Validation Random guess:  auc= 0.229723, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.577168
# Tarin Iter 1700, auc= 0.904096, fmeasure_max= 0.832781, precision= 0.848229, recall= 0.817886
# Train Random guess:  , auc= 0.256515fmeasure_max= 0.387646, precision= 0.240422, recall= 1.000000
# Validation Iter 1700, auc= 0.888117, fmeasure_max= 0.804702, precision= 0.850860, recall= 0.763293
# Validation Random guess:  auc= 0.235517, fmeasure_max= 0.372719, precision= 0.229134, recall= 0.998285
# Minibatch Loss= 0.600974
# Tarin Iter 1800, auc= 0.936569, fmeasure_max= 0.867470, precision= 0.868966, recall= 0.865979
# Train Random guess:  , auc= 0.239626fmeasure_max= 0.372783, precision= 0.229456, recall= 0.993127
# Validation Iter 1800, auc= 0.884995, fmeasure_max= 0.810857, precision= 0.802013, recall= 0.819897
# Validation Random guess:  auc= 0.237586, fmeasure_max= 0.372382, precision= 0.230085, recall= 0.975986
# Minibatch Loss= 0.498545
# Tarin Iter 1900, auc= 0.899164, fmeasure_max= 0.824477, precision= 0.885813, recall= 0.771084
# Train Random guess:  , auc= 0.275719fmeasure_max= 0.412076, precision= 0.259710, recall= 0.996988
# Validation Iter 1900, auc= 0.869024, fmeasure_max= 0.799666, precision= 0.778862, recall= 0.821612
# Validation Random guess:  auc= 0.235129, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.589998
# Tarin Iter 2000, auc= 0.912065, fmeasure_max= 0.856877, precision= 0.886538, recall= 0.829137
# Train Random guess:  , auc= 0.238019fmeasure_max= 0.358325, precision= 0.218614, recall= 0.992806
# Validation Iter 2000, auc= 0.859178, fmeasure_max= 0.791394, precision= 0.870370, recall= 0.725557
# Validation Random guess:  auc= 0.238779, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.531493
# Tarin Iter 2100, auc= 0.929234, fmeasure_max= 0.866412, precision= 0.939959, recall= 0.803540
# Train Random guess:  , auc= 0.229717fmeasure_max= 0.364545, precision= 0.224548, recall= 0.968142
# Validation Iter 2100, auc= 0.879039, fmeasure_max= 0.801778, precision= 0.832103, recall= 0.773585
# Validation Random guess:  auc= 0.214633, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.513058
# Tarin Iter 2200, auc= 0.909817, fmeasure_max= 0.839749, precision= 0.919608, recall= 0.772652
# Train Random guess:  , auc= 0.240777fmeasure_max= 0.384076, precision= 0.238058, recall= 0.993410
# Validation Iter 2200, auc= 0.876924, fmeasure_max= 0.799270, precision= 0.853801, recall= 0.751286
# Validation Random guess:  auc= 0.223984, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.567328
# Tarin Iter 2300, auc= 0.949926, fmeasure_max= 0.884488, precision= 0.899329, recall= 0.870130
# Train Random guess:  , auc= 0.234929fmeasure_max= 0.389241, precision= 0.241745, recall= 0.998377
# Validation Iter 2300, auc= 0.871232, fmeasure_max= 0.810997, precision= 0.812392, recall= 0.809605
# Validation Random guess:  auc= 0.215052, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.479821
# Tarin Iter 2400, auc= 0.953579, fmeasure_max= 0.893031, precision= 0.888710, recall= 0.897394
# Train Random guess:  , auc= 0.246783fmeasure_max= 0.387260, precision= 0.240125, recall= 1.000000
# Validation Iter 2400, auc= 0.876107, fmeasure_max= 0.812274, precision= 0.857143, recall= 0.771870
# Validation Random guess:  auc= 0.231501, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.472941
# Tarin Iter 2500, auc= 0.943171, fmeasure_max= 0.871252, precision= 0.851724, recall= 0.891697
# Train Random guess:  , auc= 0.221385fmeasure_max= 0.355812, precision= 0.216406, recall= 1.000000
# Validation Iter 2500, auc= 0.880188, fmeasure_max= 0.812044, precision= 0.867446, recall= 0.763293
# Validation Random guess:  auc= 0.247158, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.479500
# Tarin Iter 2600, auc= 0.935622, fmeasure_max= 0.846761, precision= 0.787078, recall= 0.916239
# Train Random guess:  , auc= 0.227721fmeasure_max= 0.374426, precision= 0.231643, recall= 0.976068
# Validation Iter 2600, auc= 0.879397, fmeasure_max= 0.801438, precision= 0.841509, recall= 0.765009
# Validation Random guess:  auc= 0.242302, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.481304
# Tarin Iter 2700, auc= 0.963327, fmeasure_max= 0.901763, precision= 0.919521, recall= 0.884679
# Train Random guess:  , auc= 0.265247fmeasure_max= 0.387403, precision= 0.243819, recall= 0.942339
# Validation Iter 2700, auc= 0.881353, fmeasure_max= 0.813092, precision= 0.816609, recall= 0.809605
# Validation Random guess:  auc= 0.239471, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.402937
# Tarin Iter 2800, auc= 0.957804, fmeasure_max= 0.889783, precision= 0.850769, recall= 0.932546
# Train Random guess:  , auc= 0.233703fmeasure_max= 0.376867, precision= 0.232185, recall= 1.000000
# Validation Iter 2800, auc= 0.880648, fmeasure_max= 0.817851, precision= 0.871845, recall= 0.770154
# Validation Random guess:  auc= 0.219550, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.451035
# Tarin Iter 2900, auc= 0.927162, fmeasure_max= 0.847267, precision= 0.858306, recall= 0.836508
# Train Random guess:  , auc= 0.259113fmeasure_max= 0.396184, precision= 0.247714, recall= 0.988889
# Validation Iter 2900, auc= 0.848581, fmeasure_max= 0.806563, precision= 0.812174, recall= 0.801029
# Validation Random guess:  auc= 0.228180, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.514995
# Tarin Iter 3000, auc= 0.927926, fmeasure_max= 0.847515, precision= 0.885563, recall= 0.812601
# Train Random guess:  , auc= 0.244990fmeasure_max= 0.389921, precision= 0.242175, recall= 1.000000
# Validation Iter 3000, auc= 0.866902, fmeasure_max= 0.808772, precision= 0.827648, recall= 0.790738
# Validation Random guess:  auc= 0.235654, fmeasure_max= 0.371459, precision= 0.233304, recall= 0.910806
# Minibatch Loss= 0.534574
# Tarin Iter 3100, auc= 0.949943, fmeasure_max= 0.880066, precision= 0.895623, recall= 0.865041
# Train Random guess:  , auc= 0.238768fmeasure_max= 0.388325, precision= 0.241230, recall= 0.995122
# Validation Iter 3100, auc= 0.872055, fmeasure_max= 0.817717, precision= 0.812183, recall= 0.823328
# Validation Random guess:  auc= 0.221193, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.456340
# Tarin Iter 3200, auc= 0.953050, fmeasure_max= 0.879421, precision= 0.850700, recall= 0.910150
# Train Random guess:  , auc= 0.241246fmeasure_max= 0.380621, precision= 0.235041, recall= 1.000000
# Validation Iter 3200, auc= 0.873900, fmeasure_max= 0.813530, precision= 0.822807, recall= 0.804460
# Validation Random guess:  auc= 0.241860, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.426215
# Tarin Iter 3300, auc= 0.938118, fmeasure_max= 0.856894, precision= 0.867491, recall= 0.846552
# Train Random guess:  , auc= 0.232736fmeasure_max= 0.372973, precision= 0.231933, recall= 0.951724
# Validation Iter 3300, auc= 0.878505, fmeasure_max= 0.811009, precision= 0.871795, recall= 0.758148
# Validation Random guess:  auc= 0.239295, fmeasure_max= 0.372870, precision= 0.229430, recall= 0.994854
# Minibatch Loss= 0.477204
# Tarin Iter 3400, auc= 0.971787, fmeasure_max= 0.916370, precision= 0.903509, recall= 0.929603
# Train Random guess:  , auc= 0.225766fmeasure_max= 0.357560, precision= 0.217959, recall= 0.994585
# Validation Iter 3400, auc= 0.907061, fmeasure_max= 0.822201, precision= 0.910417, recall= 0.749571
# Validation Random guess:  auc= 0.228456, fmeasure_max= 0.373359, precision= 0.229528, recall= 1.000000
# Minibatch Loss= 0.416152
# Tarin Iter 3500, auc= 0.872846, fmeasure_max= 0.793072, precision= 0.775401, recall= 0.811567
# Train Random guess:  , auc= 0.224480fmeasure_max= 0.346477, precision= 0.209539, recall= 1.000000
# Validation Iter 3500, auc= 0.885015, fmeasure_max= 0.827141, precision= 0.781679, recall= 0.878216
# Validation Random guess:  auc= 0.230018, fmeasure_max= 0.372154, precision= 0.230392, recall= 0.967410
# Minibatch Loss= 0.554396
# Tarin Iter 3600, auc= 0.953563, fmeasure_max= 0.880213, precision= 0.893694, recall= 0.867133
# Train Random guess:  , auc= 0.234020fmeasure_max= 0.366506, precision= 0.224635, recall= 0.994755
# Validation Iter 3600, auc= 0.879676, fmeasure_max= 0.804085, precision= 0.876518, recall= 0.742710
# Validation Random guess:  auc= 0.234351, fmeasure_max= 0.373838, precision= 0.231783, recall= 0.965695
# Minibatch Loss= 0.358395
# Tarin Iter 3700, auc= 0.933949, fmeasure_max= 0.871042, precision= 0.845577, recall= 0.898089
# Train Random guess:  , auc= 0.247336fmeasure_max= 0.394571, precision= 0.246063, recall= 0.995223
# Validation Iter 3700, auc= 0.886253, fmeasure_max= 0.828496, precision= 0.850181, recall= 0.807890
# Validation Random guess:  auc= 0.233057, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.485343
# Tarin Iter 3800, auc= 0.953363, fmeasure_max= 0.875098, precision= 0.889776, recall= 0.860896
# Train Random guess:  , auc= 0.251183fmeasure_max= 0.403870, precision= 0.253031, recall= 1.000000
# Validation Iter 3800, auc= 0.892667, fmeasure_max= 0.830824, precision= 0.858974, recall= 0.804460
# Validation Random guess:  auc= 0.239195, fmeasure_max= 0.373203, precision= 0.230521, recall= 0.979417
# Minibatch Loss= 0.484842
# Tarin Iter 3900, auc= 0.934424, fmeasure_max= 0.860133, precision= 0.851224, recall= 0.869231
# Train Random guess:  , auc= 0.202585fmeasure_max= 0.337882, precision= 0.203284, recall= 1.000000
# Validation Iter 3900, auc= 0.881189, fmeasure_max= 0.816216, precision= 0.859583, recall= 0.777015
# Validation Random guess:  auc= 0.238992, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.438671
# Tarin Iter 4000, auc= 0.946568, fmeasure_max= 0.901575, precision= 0.894531, recall= 0.908730
# Train Random guess:  , auc= 0.215947fmeasure_max= 0.330033, precision= 0.197941, recall= 0.992063
# Validation Iter 4000, auc= 0.881986, fmeasure_max= 0.816473, precision= 0.853933, recall= 0.782161
# Validation Random guess:  auc= 0.230483, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.336590
# Tarin Iter 4100, auc= 0.927888, fmeasure_max= 0.857143, precision= 0.870968, recall= 0.843750
# Train Random guess:  , auc= 0.215660fmeasure_max= 0.351343, precision= 0.213192, recall= 0.998162
# Validation Iter 4100, auc= 0.882623, fmeasure_max= 0.828496, precision= 0.850181, recall= 0.807890
# Validation Random guess:  auc= 0.237424, fmeasure_max= 0.374016, precision= 0.231237, recall= 0.977702
# Minibatch Loss= 0.478618
# Tarin Iter 4200, auc= 0.964862, fmeasure_max= 0.894837, precision= 0.886364, recall= 0.903475
# Train Random guess:  , auc= 0.190654fmeasure_max= 0.338572, precision= 0.203864, recall= 0.998069
# Validation Iter 4200, auc= 0.880337, fmeasure_max= 0.827344, precision= 0.845878, recall= 0.809605
# Validation Random guess:  auc= 0.221555, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.372713
# Tarin Iter 4300, auc= 0.923186, fmeasure_max= 0.840809, precision= 0.862816, recall= 0.819897
# Train Random guess:  , auc= 0.244506fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Validation Iter 4300, auc= 0.870844, fmeasure_max= 0.823428, precision= 0.826990, recall= 0.819897
# Validation Random guess:  auc= 0.237729, fmeasure_max= 0.374300, precision= 0.231648, recall= 0.974271
# Minibatch Loss= 0.517405
# Tarin Iter 4400, auc= 0.952709, fmeasure_max= 0.880315, precision= 0.835575, recall= 0.930116
# Train Random guess:  , auc= 0.232197fmeasure_max= 0.380500, precision= 0.234949, recall= 1.000000
# Validation Iter 4400, auc= 0.903775, fmeasure_max= 0.838654, precision= 0.843750, recall= 0.833619
# Validation Random guess:  auc= 0.216859, fmeasure_max= 0.371853, precision= 0.229026, recall= 0.987993
# Minibatch Loss= 0.468444
# Tarin Iter 4500, auc= 0.968868, fmeasure_max= 0.914757, precision= 0.889483, recall= 0.941509
# Train Random guess:  , auc= 0.205887fmeasure_max= 0.345550, precision= 0.211991, recall= 0.933962
# Validation Iter 4500, auc= 0.901141, fmeasure_max= 0.825571, precision= 0.882812, recall= 0.775300
# Validation Random guess:  auc= 0.235173, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.374781
# Tarin Iter 4600, auc= 0.955045, fmeasure_max= 0.882922, precision= 0.893478, recall= 0.872611
# Train Random guess:  , auc= 0.178165fmeasure_max= 0.311508, precision= 0.184489, recall= 1.000000
# Validation Iter 4600, auc= 0.896796, fmeasure_max= 0.832470, precision= 0.838261, recall= 0.826758
# Validation Random guess:  auc= 0.235493, fmeasure_max= 0.373125, precision= 0.230366, recall= 0.981132
# Minibatch Loss= 0.362850
# Tarin Iter 4700, auc= 0.943011, fmeasure_max= 0.882175, precision= 0.888438, recall= 0.876000
# Train Random guess:  , auc= 0.181407fmeasure_max= 0.329256, precision= 0.199492, recall= 0.942000
# Validation Iter 4700, auc= 0.890107, fmeasure_max= 0.821990, precision= 0.836590, recall= 0.807890
# Validation Random guess:  auc= 0.226693, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.386583
# Tarin Iter 4800, auc= 0.943154, fmeasure_max= 0.882250, precision= 0.882250, recall= 0.882250
# Train Random guess:  , auc= 0.225404fmeasure_max= 0.368345, precision= 0.231569, recall= 0.899824
# Validation Iter 4800, auc= 0.900468, fmeasure_max= 0.841256, precision= 0.881579, recall= 0.804460
# Validation Random guess:  auc= 0.231664, fmeasure_max= 0.373868, precision= 0.230371, recall= 0.991424
# Minibatch Loss= 0.497689
# Tarin Iter 4900, auc= 0.950659, fmeasure_max= 0.885906, precision= 0.881469, recall= 0.890388
# Train Random guess:  , auc= 0.239729fmeasure_max= 0.376682, precision= 0.232503, recall= 0.991568
# Validation Iter 4900, auc= 0.878264, fmeasure_max= 0.826377, precision= 0.804878, recall= 0.849057
# Validation Random guess:  auc= 0.241137, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.465609
# Tarin Iter 5000, auc= 0.973327, fmeasure_max= 0.925659, precision= 0.924920, recall= 0.926400
# Train Random guess:  , auc= 0.252851fmeasure_max= 0.392835, precision= 0.244427, recall= 1.000000
# Validation Iter 5000, auc= 0.889981, fmeasure_max= 0.840708, precision= 0.868373, recall= 0.814751
# Validation Random guess:  auc= 0.233908, fmeasure_max= 0.374110, precision= 0.230554, recall= 0.991424
# Minibatch Loss= 0.409182
# Tarin Iter 5100, auc= 0.972898, fmeasure_max= 0.912903, precision= 0.895570, recall= 0.930921
# Train Random guess:  , auc= 0.235491fmeasure_max= 0.383960, precision= 0.237593, recall= 1.000000
# Validation Iter 5100, auc= 0.892048, fmeasure_max= 0.837044, precision= 0.870370, recall= 0.806175
# Validation Random guess:  auc= 0.249174, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.387133
# Tarin Iter 5200, auc= 0.930500, fmeasure_max= 0.851254, precision= 0.849732, recall= 0.852783
# Train Random guess:  , auc= 0.227681fmeasure_max= 0.358841, precision= 0.219173, recall= 0.989228
# Validation Iter 5200, auc= 0.889212, fmeasure_max= 0.828749, precision= 0.858456, recall= 0.801029
# Validation Random guess:  auc= 0.237355, fmeasure_max= 0.372524, precision= 0.228897, recall= 1.000000
# Minibatch Loss= 0.440597
# Tarin Iter 5300, auc= 0.966554, fmeasure_max= 0.906395, precision= 0.914019, recall= 0.898897
# Train Random guess:  , auc= 0.205647fmeasure_max= 0.350843, precision= 0.212992, recall= 0.994485
# Validation Iter 5300, auc= 0.894353, fmeasure_max= 0.837998, precision= 0.828859, recall= 0.847341
# Validation Random guess:  auc= 0.210572, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.365794
# Tarin Iter 5400, auc= 0.958129, fmeasure_max= 0.888889, precision= 0.876611, recall= 0.901515
# Train Random guess:  , auc= 0.204406fmeasure_max= 0.342857, precision= 0.206897, recall= 1.000000
# Validation Iter 5400, auc= 0.896837, fmeasure_max= 0.842015, precision= 0.838435, recall= 0.845626
# Validation Random guess:  auc= 0.249396, fmeasure_max= 0.377196, precision= 0.233772, recall= 0.975986
# Minibatch Loss= 0.371800
# Tarin Iter 5500, auc= 0.951839, fmeasure_max= 0.880411, precision= 0.852273, recall= 0.910470
# Train Random guess:  , auc= 0.269029fmeasure_max= 0.411374, precision= 0.259777, recall= 0.987860
# Validation Iter 5500, auc= 0.881182, fmeasure_max= 0.840206, precision= 0.841652, recall= 0.838765
# Validation Random guess:  auc= 0.252748, fmeasure_max= 0.373755, precision= 0.233677, recall= 0.933105
# Minibatch Loss= 0.463252
# Tarin Iter 5600, auc= 0.953953, fmeasure_max= 0.875000, precision= 0.860963, recall= 0.889503
# Train Random guess:  , auc= 0.214114fmeasure_max= 0.351828, precision= 0.213804, recall= 0.992634
# Validation Iter 5600, auc= 0.884845, fmeasure_max= 0.832595, precision= 0.860806, recall= 0.806175
# Validation Random guess:  auc= 0.234199, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.395433
# Tarin Iter 5700, auc= 0.957209, fmeasure_max= 0.886747, precision= 0.926174, recall= 0.850539
# Train Random guess:  , auc= 0.266258fmeasure_max= 0.404487, precision= 0.253516, recall= 1.000000
# Validation Iter 5700, auc= 0.898793, fmeasure_max= 0.853021, precision= 0.899240, recall= 0.811321
# Validation Random guess:  auc= 0.235647, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.477738
# Tarin Iter 5800, auc= 0.964716, fmeasure_max= 0.898529, precision= 0.913303, recall= 0.884226
# Train Random guess:  , auc= 0.286111fmeasure_max= 0.426383, precision= 0.271930, recall= 0.986975
# Validation Iter 5800, auc= 0.892472, fmeasure_max= 0.849868, precision= 0.870504, recall= 0.830189
# Validation Random guess:  auc= 0.235270, fmeasure_max= 0.375337, precision= 0.233543, recall= 0.955403
# Minibatch Loss= 0.497093
# Tarin Iter 5900, auc= 0.950273, fmeasure_max= 0.872434, precision= 0.867347, recall= 0.877581
# Train Random guess:  , auc= 0.269714fmeasure_max= 0.419036, precision= 0.265051, recall= 1.000000
# Validation Iter 5900, auc= 0.897040, fmeasure_max= 0.850838, precision= 0.876364, recall= 0.826758
# Validation Random guess:  auc= 0.225672, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.460381
# Tarin Iter 6000, auc= 0.955439, fmeasure_max= 0.895238, precision= 0.905297, recall= 0.885400
# Train Random guess:  , auc= 0.255188fmeasure_max= 0.399749, precision= 0.249902, recall= 0.998430
# Validation Iter 6000, auc= 0.882690, fmeasure_max= 0.834646, precision= 0.851786, recall= 0.818182
# Validation Random guess:  auc= 0.239351, fmeasure_max= 0.371635, precision= 0.229801, recall= 0.970840
# Minibatch Loss= 0.459780
# Tarin Iter 6100, auc= 0.967276, fmeasure_max= 0.895963, precision= 0.902973, recall= 0.889060
# Train Random guess:  , auc= 0.240087fmeasure_max= 0.404487, precision= 0.253516, recall= 1.000000
# Validation Iter 6100, auc= 0.897478, fmeasure_max= 0.839350, precision= 0.885714, recall= 0.797599
# Validation Random guess:  auc= 0.225997, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.431029
# Tarin Iter 6200, auc= 0.971509, fmeasure_max= 0.909238, precision= 0.900482, recall= 0.918167
# Train Random guess:  , auc= 0.250497fmeasure_max= 0.385367, precision= 0.238672, recall= 1.000000
# Validation Iter 6200, auc= 0.879614, fmeasure_max= 0.828248, precision= 0.842199, recall= 0.814751
# Validation Random guess:  auc= 0.247112, fmeasure_max= 0.376478, precision= 0.232832, recall= 0.982847
# Minibatch Loss= 0.441490
# Tarin Iter 6300, auc= 0.971632, fmeasure_max= 0.903752, precision= 0.915702, recall= 0.892110
# Train Random guess:  , auc= 0.244037fmeasure_max= 0.391798, precision= 0.243625, recall= 1.000000
# Validation Iter 6300, auc= 0.881921, fmeasure_max= 0.841089, precision= 0.861511, recall= 0.821612
# Validation Random guess:  auc= 0.241756, fmeasure_max= 0.373669, precision= 0.230127, recall= 0.993139
# Minibatch Loss= 0.397961
# Tarin Iter 6400, auc= 0.965638, fmeasure_max= 0.915055, precision= 0.918919, recall= 0.911223
# Train Random guess:  , auc= 0.239936fmeasure_max= 0.379487, precision= 0.234641, recall= 0.991625
# Validation Iter 6400, auc= 0.897798, fmeasure_max= 0.831276, precision= 0.799051, recall= 0.866209
# Validation Random guess:  auc= 0.224650, fmeasure_max= 0.371567, precision= 0.228901, recall= 0.986278
# Minibatch Loss= 0.419318
# Tarin Iter 6500, auc= 0.955023, fmeasure_max= 0.900285, precision= 0.896030, recall= 0.904580
# Train Random guess:  , auc= 0.208871fmeasure_max= 0.343096, precision= 0.209898, recall= 0.938931
# Validation Iter 6500, auc= 0.898510, fmeasure_max= 0.843972, precision= 0.873394, recall= 0.816467
# Validation Random guess:  auc= 0.220464, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.394443
# Tarin Iter 6600, auc= 0.961349, fmeasure_max= 0.891731, precision= 0.928952, recall= 0.857377
# Train Random guess:  , auc= 0.247748fmeasure_max= 0.391161, precision= 0.244839, recall= 0.972131
# Validation Iter 6600, auc= 0.900575, fmeasure_max= 0.849291, precision= 0.878899, recall= 0.821612
# Validation Random guess:  auc= 0.226607, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.418683
# Tarin Iter 6700, auc= 0.969171, fmeasure_max= 0.905822, precision= 0.908935, recall= 0.902730
# Train Random guess:  , auc= 0.244009fmeasure_max= 0.377641, precision= 0.235945, recall= 0.945392
# Validation Iter 6700, auc= 0.895055, fmeasure_max= 0.838710, precision= 0.878049, recall= 0.802744
# Validation Random guess:  auc= 0.238784, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.411695
# Tarin Iter 6800, auc= 0.965605, fmeasure_max= 0.895664, precision= 0.883690, recall= 0.907967
# Train Random guess:  , auc= 0.281989fmeasure_max= 0.443293, precision= 0.284875, recall= 0.998626
# Validation Iter 6800, auc= 0.888600, fmeasure_max= 0.833028, precision= 0.895464, recall= 0.778731
# Validation Random guess:  auc= 0.240830, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.498061
# Tarin Iter 6900, auc= 0.960631, fmeasure_max= 0.901869, precision= 0.892142, recall= 0.911811
# Train Random guess:  , auc= 0.247540fmeasure_max= 0.400257, precision= 0.251412, recall= 0.981102
# Validation Iter 6900, auc= 0.891375, fmeasure_max= 0.838652, precision= 0.867890, recall= 0.811321
# Validation Random guess:  auc= 0.238833, fmeasure_max= 0.375766, precision= 0.237900, recall= 0.893654
# Minibatch Loss= 0.399943
# Tarin Iter 7000, auc= 0.959148, fmeasure_max= 0.883265, precision= 0.878247, recall= 0.888342
# Train Random guess:  , auc= 0.243496fmeasure_max= 0.388070, precision= 0.245234, recall= 0.929392
# Validation Iter 7000, auc= 0.894656, fmeasure_max= 0.846495, precision= 0.876838, recall= 0.818182
# Validation Random guess:  auc= 0.228431, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.437637
# Tarin Iter 7100, auc= 0.936774, fmeasure_max= 0.850596, precision= 0.854512, recall= 0.846715
# Train Random guess:  , auc= 0.216788fmeasure_max= 0.353702, precision= 0.214931, recall= 0.998175
# Validation Iter 7100, auc= 0.902387, fmeasure_max= 0.849527, precision= 0.851724, recall= 0.847341
# Validation Random guess:  auc= 0.223297, fmeasure_max= 0.373857, precision= 0.232911, recall= 0.946827
# Minibatch Loss= 0.425138
# Tarin Iter 7200, auc= 0.936532, fmeasure_max= 0.872781, precision= 0.836879, recall= 0.911901
# Train Random guess:  , auc= 0.248930fmeasure_max= 0.406020, precision= 0.256058, recall= 0.979907
# Validation Iter 7200, auc= 0.889231, fmeasure_max= 0.849246, precision= 0.829787, recall= 0.869640
# Validation Random guess:  auc= 0.230404, fmeasure_max= 0.371659, precision= 0.228787, recall= 0.989708
# Minibatch Loss= 0.482255
# Tarin Iter 7300, auc= 0.969085, fmeasure_max= 0.905481, precision= 0.878274, recall= 0.934426
# Train Random guess:  , auc= 0.229954fmeasure_max= 0.386415, precision= 0.240143, recall= 0.988525
# Validation Iter 7300, auc= 0.899029, fmeasure_max= 0.853492, precision= 0.847716, recall= 0.859348
# Validation Random guess:  auc= 0.242694, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.432236
# Tarin Iter 7400, auc= 0.978149, fmeasure_max= 0.937182, precision= 0.924623, recall= 0.950086
# Train Random guess:  , auc= 0.223167fmeasure_max= 0.372529, precision= 0.233275, recall= 0.924269
# Validation Iter 7400, auc= 0.898927, fmeasure_max= 0.864583, precision= 0.875220, recall= 0.854202
# Validation Random guess:  auc= 0.226063, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.350960
# Tarin Iter 7500, auc= 0.968176, fmeasure_max= 0.906863, precision= 0.917355, recall= 0.896607
# Train Random guess:  , auc= 0.238307fmeasure_max= 0.389921, precision= 0.242175, recall= 1.000000
# Validation Iter 7500, auc= 0.872481, fmeasure_max= 0.823420, precision= 0.898580, recall= 0.759863
# Validation Random guess:  auc= 0.245594, fmeasure_max= 0.372467, precision= 0.229216, recall= 0.993139
# Minibatch Loss= 0.444319
# Tarin Iter 7600, auc= 0.941259, fmeasure_max= 0.849716, precision= 0.802147, recall= 0.903282
# Train Random guess:  , auc= 0.213401fmeasure_max= 0.370107, precision= 0.227707, recall= 0.987910
# Validation Iter 7600, auc= 0.897618, fmeasure_max= 0.832350, precision= 0.817881, recall= 0.847341
# Validation Random guess:  auc= 0.207705, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.432031
# Tarin Iter 7700, auc= 0.965583, fmeasure_max= 0.900741, precision= 0.917044, recall= 0.885007
# Train Random guess:  , auc= 0.268826fmeasure_max= 0.425345, precision= 0.271092, recall= 0.986900
# Validation Iter 7700, auc= 0.896840, fmeasure_max= 0.832611, precision= 0.842105, recall= 0.823328
# Validation Random guess:  auc= 0.226484, fmeasure_max= 0.374001, precision= 0.234525, recall= 0.922813
# Minibatch Loss= 0.446494
# Tarin Iter 7800, auc= 0.963315, fmeasure_max= 0.885937, precision= 0.833824, recall= 0.945000
# Train Random guess:  , auc= 0.234651fmeasure_max= 0.379867, precision= 0.234467, recall= 1.000000
# Validation Iter 7800, auc= 0.902884, fmeasure_max= 0.855136, precision= 0.875899, recall= 0.835334
# Validation Random guess:  auc= 0.216660, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.377526
# Tarin Iter 7900, auc= 0.963725, fmeasure_max= 0.889465, precision= 0.871404, recall= 0.908289
# Train Random guess:  , auc= 0.214747fmeasure_max= 0.363873, precision= 0.223019, recall= 0.987654
# Validation Iter 7900, auc= 0.903145, fmeasure_max= 0.854715, precision= 0.846801, recall= 0.862779
# Validation Random guess:  auc= 0.220088, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.390734
# Tarin Iter 8000, auc= 0.964269, fmeasure_max= 0.895833, precision= 0.887302, recall= 0.904531
# Train Random guess:  , auc= 0.235252fmeasure_max= 0.390322, precision= 0.242965, recall= 0.991909
# Validation Iter 8000, auc= 0.899184, fmeasure_max= 0.854594, precision= 0.890335, recall= 0.821612
# Validation Random guess:  auc= 0.249531, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.422829
# Tarin Iter 8100, auc= 0.980676, fmeasure_max= 0.922619, precision= 0.924453, recall= 0.920792
# Train Random guess:  , auc= 0.201500fmeasure_max= 0.329742, precision= 0.197420, recall= 1.000000
# Validation Iter 8100, auc= 0.907986, fmeasure_max= 0.852349, precision= 0.834154, recall= 0.871355
# Validation Random guess:  auc= 0.227279, fmeasure_max= 0.371344, precision= 0.229675, recall= 0.969125
# Minibatch Loss= 0.315647
# Tarin Iter 8200, auc= 0.970353, fmeasure_max= 0.908522, precision= 0.928115, recall= 0.889740
# Train Random guess:  , auc= 0.243260fmeasure_max= 0.407895, precision= 0.256400, recall= 0.996937
# Validation Iter 8200, auc= 0.908213, fmeasure_max= 0.849268, precision= 0.852941, recall= 0.845626
# Validation Random guess:  auc= 0.240834, fmeasure_max= 0.373144, precision= 0.232255, recall= 0.948542
# Minibatch Loss= 0.427662
# Tarin Iter 8300, auc= 0.977264, fmeasure_max= 0.915228, precision= 0.923930, recall= 0.906687
# Train Random guess:  , auc= 0.258609fmeasure_max= 0.404884, precision= 0.255164, recall= 0.979782
# Validation Iter 8300, auc= 0.909492, fmeasure_max= 0.844677, precision= 0.859680, recall= 0.830189
# Validation Random guess:  auc= 0.215314, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.457388
# Tarin Iter 8400, auc= 0.974400, fmeasure_max= 0.914286, precision= 0.924188, recall= 0.904594
# Train Random guess:  , auc= 0.224243fmeasure_max= 0.364230, precision= 0.223379, recall= 0.985866
# Validation Iter 8400, auc= 0.908655, fmeasure_max= 0.862191, precision= 0.888889, recall= 0.837050
# Validation Random guess:  auc= 0.232463, fmeasure_max= 0.374510, precision= 0.231328, recall= 0.982847
# Minibatch Loss= 0.379787
# Tarin Iter 8500, auc= 0.978628, fmeasure_max= 0.922213, precision= 0.928918, recall= 0.915605
# Train Random guess:  , auc= 0.249516fmeasure_max= 0.394528, precision= 0.246521, recall= 0.987261
# Validation Iter 8500, auc= 0.906799, fmeasure_max= 0.850368, precision= 0.812500, recall= 0.891938
# Validation Random guess:  auc= 0.226871, fmeasure_max= 0.375288, precision= 0.232114, recall= 0.979417
# Minibatch Loss= 0.373908
# Tarin Iter 8600, auc= 0.955566, fmeasure_max= 0.887480, precision= 0.898876, recall= 0.876369
# Train Random guess:  , auc= 0.251759fmeasure_max= 0.401415, precision= 0.252632, recall= 0.976526
# Validation Iter 8600, auc= 0.905683, fmeasure_max= 0.856628, precision= 0.903042, recall= 0.814751
# Validation Random guess:  auc= 0.237282, fmeasure_max= 0.373316, precision= 0.229586, recall= 0.998285
# Minibatch Loss= 0.469678
# Tarin Iter 8700, auc= 0.970753, fmeasure_max= 0.907907, precision= 0.893773, recall= 0.922495
# Train Random guess:  , auc= 0.209601fmeasure_max= 0.345054, precision= 0.208831, recall= 0.992439
# Validation Iter 8700, auc= 0.913998, fmeasure_max= 0.852843, precision= 0.831974, recall= 0.874786
# Validation Random guess:  auc= 0.227622, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.356618
# Tarin Iter 8800, auc= 0.961573, fmeasure_max= 0.904716, precision= 0.905588, recall= 0.903846
# Train Random guess:  , auc= 0.197732fmeasure_max= 0.338001, precision= 0.203450, recall= 0.998077
# Validation Iter 8800, auc= 0.921266, fmeasure_max= 0.864241, precision= 0.895221, recall= 0.835334
# Validation Random guess:  auc= 0.235326, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.356869
# Tarin Iter 8900, auc= 0.977521, fmeasure_max= 0.928571, precision= 0.933702, recall= 0.923497
# Train Random guess:  , auc= 0.232975fmeasure_max= 0.353396, precision= 0.214621, recall= 1.000000
# Validation Iter 8900, auc= 0.906035, fmeasure_max= 0.856153, precision= 0.865149, recall= 0.847341
# Validation Random guess:  auc= 0.230439, fmeasure_max= 0.374836, precision= 0.231673, recall= 0.981132
# Minibatch Loss= 0.289948
# Tarin Iter 9000, auc= 0.943782, fmeasure_max= 0.882662, precision= 0.890459, recall= 0.875000
# Train Random guess:  , auc= 0.229050fmeasure_max= 0.367786, precision= 0.226415, recall= 0.979167
# Validation Iter 9000, auc= 0.894035, fmeasure_max= 0.826758, precision= 0.826758, recall= 0.826758
# Validation Random guess:  auc= 0.224724, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.471472
# Tarin Iter 9100, auc= 0.973157, fmeasure_max= 0.908373, precision= 0.911252, recall= 0.905512
# Train Random guess:  , auc= 0.243363fmeasure_max= 0.397745, precision= 0.248241, recall= 1.000000
# Validation Iter 9100, auc= 0.915319, fmeasure_max= 0.870668, precision= 0.858333, recall= 0.883362
# Validation Random guess:  auc= 0.238649, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.417964
# Tarin Iter 9200, auc= 0.970231, fmeasure_max= 0.905135, precision= 0.895009, recall= 0.915493
# Train Random guess:  , auc= 0.224716fmeasure_max= 0.366093, precision= 0.226494, recall= 0.954225
# Validation Iter 9200, auc= 0.900567, fmeasure_max= 0.831560, precision= 0.860550, recall= 0.804460
# Validation Random guess:  auc= 0.221720, fmeasure_max= 0.371659, precision= 0.228787, recall= 0.989708
# Minibatch Loss= 0.376586
# Tarin Iter 9300, auc= 0.975298, fmeasure_max= 0.914201, precision= 0.885387, recall= 0.944954
# Train Random guess:  , auc= 0.253981fmeasure_max= 0.407350, precision= 0.255768, recall= 1.000000
# Validation Iter 9300, auc= 0.900679, fmeasure_max= 0.840580, precision= 0.890595, recall= 0.795883
# Validation Random guess:  auc= 0.231105, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.428385
# Tarin Iter 9400, auc= 0.957934, fmeasure_max= 0.887564, precision= 0.896730, recall= 0.878583
# Train Random guess:  , auc= 0.231289fmeasure_max= 0.376867, precision= 0.232185, recall= 1.000000
# Validation Iter 9400, auc= 0.908428, fmeasure_max= 0.854185, precision= 0.859375, recall= 0.849057
# Validation Random guess:  auc= 0.232232, fmeasure_max= 0.371824, precision= 0.228820, recall= 0.991424
# Minibatch Loss= 0.372119
# Tarin Iter 9500, auc= 0.968794, fmeasure_max= 0.903437, precision= 0.929293, recall= 0.878981
# Train Random guess:  , auc= 0.246100fmeasure_max= 0.393977, precision= 0.245312, recall= 1.000000
# Validation Iter 9500, auc= 0.907144, fmeasure_max= 0.856905, precision= 0.831987, recall= 0.883362
# Validation Random guess:  auc= 0.227540, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.411937
# Tarin Iter 9600, auc= 0.972527, fmeasure_max= 0.914331, precision= 0.919485, recall= 0.909236
# Train Random guess:  , auc= 0.239132fmeasure_max= 0.395432, precision= 0.248666, recall= 0.964968
# Validation Iter 9600, auc= 0.915300, fmeasure_max= 0.863519, precision= 0.864261, recall= 0.862779
# Validation Random guess:  auc= 0.225895, fmeasure_max= 0.375333, precision= 0.232933, recall= 0.965695
# Minibatch Loss= 0.397721
# Tarin Iter 9700, auc= 0.965318, fmeasure_max= 0.896321, precision= 0.875817, recall= 0.917808
# Train Random guess:  , auc= 0.215361fmeasure_max= 0.372347, precision= 0.229216, recall= 0.991438
# Validation Iter 9700, auc= 0.901562, fmeasure_max= 0.847694, precision= 0.860424, recall= 0.835334
# Validation Random guess:  auc= 0.228975, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.375023
# Tarin Iter 9800, auc= 0.962357, fmeasure_max= 0.884752, precision= 0.918969, recall= 0.852991
# Train Random guess:  , auc= 0.234717fmeasure_max= 0.372137, precision= 0.228605, recall= 1.000000
# Validation Iter 9800, auc= 0.905722, fmeasure_max= 0.856378, precision= 0.892193, recall= 0.823328
# Validation Random guess:  auc= 0.226872, fmeasure_max= 0.373530, precision= 0.232247, recall= 0.953688
# Minibatch Loss= 0.436556
# Tarin Iter 9900, auc= 0.980539, fmeasure_max= 0.930054, precision= 0.933642, recall= 0.926493
# Train Random guess:  , auc= 0.260484fmeasure_max= 0.406474, precision= 0.255078, recall= 1.000000
# Validation Iter 9900, auc= 0.914102, fmeasure_max= 0.862191, precision= 0.888889, recall= 0.837050
# Validation Random guess:  auc= 0.227005, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.410333
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-cbf22a8a2ba9> in <module>()
#       1 #Save the model
#       2 saver = tf.train.Saver()
# ----> 3 saver.save(sess, checkpoint_path, global_step=trainer.global_step)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/training/saver.pyc in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1592               "Parent directory of {} doesn't exist, can't save.".format(
#    1593                   save_path))
# -> 1594         raise exc
#    1595
#    1596     if write_meta_graph:
#
# ValueError: Parent directory of ../model/CNN1009/CNN1009 doesn't exist, can't save.

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.899933 F1_max = 0.820585 prec = 0.854582 rec = 0.789189
# Test Random guess: auc= 0.233005 fmeasure_max= 0.375670 , precision= 0.231277 , recall= 1.000000

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
