# %%
# useing this variable for saving models and summaries
exp_name = "CNN1010"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [32, 1, 1, 1, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.321622, fmeasure_max= 0.437631, precision= 0.287414, recall= 0.916788
# Train Random guess:  , auc= 0.272589fmeasure_max= 0.422579, precision= 0.267892, recall= 1.000000
# Validation Iter 0, auc= 0.322903, fmeasure_max= 0.373393, precision= 0.229735, recall= 0.996569
# Validation Random guess:  auc= 0.226187, fmeasure_max= 0.373350, precision= 0.229794, recall= 0.994854
# Minibatch Loss= 1.112470
# Tarin Iter 100, auc= 0.704320, fmeasure_max= 0.726570, precision= 0.752000, recall= 0.702804
# Train Random guess:  , auc= 0.206998fmeasure_max= 0.346528, precision= 0.209658, recall= 0.998131
# Validation Iter 100, auc= 0.718982, fmeasure_max= 0.742373, precision= 0.733668, recall= 0.751286
# Validation Random guess:  auc= 0.244979, fmeasure_max= 0.376454, precision= 0.235143, recall= 0.943396
# Minibatch Loss= 0.754075
# Tarin Iter 200, auc= 0.692367, fmeasure_max= 0.704289, precision= 0.703759, recall= 0.704819
# Train Random guess:  , auc= 0.265764fmeasure_max= 0.411911, precision= 0.259375, recall= 1.000000
# Validation Iter 200, auc= 0.751090, fmeasure_max= 0.734198, precision= 0.695853, recall= 0.777015
# Validation Random guess:  auc= 0.248980, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.867595
# Tarin Iter 300, auc= 0.766394, fmeasure_max= 0.750000, precision= 0.759375, recall= 0.740854
# Train Random guess:  , auc= 0.254261fmeasure_max= 0.408214, precision= 0.256450, recall= 1.000000
# Validation Iter 300, auc= 0.811595, fmeasure_max= 0.777161, precision= 0.722714, recall= 0.840480
# Validation Random guess:  auc= 0.224095, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.734932
# Tarin Iter 400, auc= 0.755328, fmeasure_max= 0.743922, precision= 0.707242, recall= 0.784615
# Train Random guess:  , auc= 0.234525fmeasure_max= 0.372137, precision= 0.228605, recall= 1.000000
# Validation Iter 400, auc= 0.814409, fmeasure_max= 0.795349, precision= 0.725601, recall= 0.879931
# Validation Random guess:  auc= 0.241808, fmeasure_max= 0.373230, precision= 0.229703, recall= 0.994854
# Minibatch Loss= 0.663622
# Tarin Iter 500, auc= 0.855592, fmeasure_max= 0.824921, precision= 0.807099, recall= 0.843548
# Train Random guess:  , auc= 0.246565fmeasure_max= 0.390521, precision= 0.242829, recall= 0.996774
# Validation Iter 500, auc= 0.829797, fmeasure_max= 0.797396, precision= 0.758514, recall= 0.840480
# Validation Random guess:  auc= 0.231529, fmeasure_max= 0.373134, precision= 0.230092, recall= 0.986278
# Minibatch Loss= 0.615550
# Tarin Iter 600, auc= 0.860042, fmeasure_max= 0.800317, precision= 0.760542, recall= 0.844482
# Train Random guess:  , auc= 0.228842fmeasure_max= 0.379321, precision= 0.234051, recall= 1.000000
# Validation Iter 600, auc= 0.866803, fmeasure_max= 0.807512, precision= 0.742446, recall= 0.885077
# Validation Random guess:  auc= 0.219614, fmeasure_max= 0.372511, precision= 0.229158, recall= 0.994854
# Minibatch Loss= 0.588751
# Tarin Iter 700, auc= 0.823251, fmeasure_max= 0.763218, precision= 0.786730, recall= 0.741071
# Train Random guess:  , auc= 0.253842fmeasure_max= 0.416253, precision= 0.262931, recall= 0.998512
# Validation Iter 700, auc= 0.859896, fmeasure_max= 0.799676, precision= 0.758462, recall= 0.845626
# Validation Random guess:  auc= 0.227130, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.708473
# Tarin Iter 800, auc= 0.841623, fmeasure_max= 0.785650, precision= 0.787770, recall= 0.783542
# Train Random guess:  , auc= 0.224147fmeasure_max= 0.358776, precision= 0.218775, recall= 0.996422
# Validation Iter 800, auc= 0.883956, fmeasure_max= 0.806122, precision= 0.799325, recall= 0.813036
# Validation Random guess:  auc= 0.237352, fmeasure_max= 0.374790, precision= 0.232917, recall= 0.958834
# Minibatch Loss= 0.620655
# Tarin Iter 900, auc= 0.941338, fmeasure_max= 0.863708, precision= 0.877617, recall= 0.850234
# Train Random guess:  , auc= 0.250964fmeasure_max= 0.403431, precision= 0.253291, recall= 0.990640
# Validation Iter 900, auc= 0.885572, fmeasure_max= 0.804089, precision= 0.798646, recall= 0.809605
# Validation Random guess:  auc= 0.215397, fmeasure_max= 0.373218, precision= 0.231306, recall= 0.965695
# Minibatch Loss= 0.525320
# Tarin Iter 1000, auc= 0.883461, fmeasure_max= 0.815764, precision= 0.811765, recall= 0.819802
# Train Random guess:  , auc= 0.207958fmeasure_max= 0.329634, precision= 0.197343, recall= 1.000000
# Validation Iter 1000, auc= 0.909699, fmeasure_max= 0.832130, precision= 0.878095, recall= 0.790738
# Validation Random guess:  auc= 0.230259, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.468197
# Tarin Iter 1100, auc= 0.910763, fmeasure_max= 0.840060, precision= 0.824047, recall= 0.856707
# Train Random guess:  , auc= 0.243440fmeasure_max= 0.408138, precision= 0.256794, recall= 0.993902
# Validation Iter 1100, auc= 0.887525, fmeasure_max= 0.822496, precision= 0.843243, recall= 0.802744
# Validation Random guess:  auc= 0.234479, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.608696
# Tarin Iter 1200, auc= 0.908833, fmeasure_max= 0.842857, precision= 0.830986, recall= 0.855072
# Train Random guess:  , auc= 0.266181fmeasure_max= 0.425413, precision= 0.270924, recall= 0.989855
# Validation Iter 1200, auc= 0.855245, fmeasure_max= 0.800681, precision= 0.795262, recall= 0.806175
# Validation Random guess:  auc= 0.213915, fmeasure_max= 0.374834, precision= 0.232253, recall= 0.970840
# Minibatch Loss= 0.655498
# Tarin Iter 1300, auc= 0.878920, fmeasure_max= 0.811201, precision= 0.813406, recall= 0.809009
# Train Random guess:  , auc= 0.205257fmeasure_max= 0.358440, precision= 0.220339, recall= 0.960360
# Validation Iter 1300, auc= 0.895092, fmeasure_max= 0.831579, precision= 0.850987, recall= 0.813036
# Validation Random guess:  auc= 0.234032, fmeasure_max= 0.373482, precision= 0.230925, recall= 0.975986
# Minibatch Loss= 0.532489
# Tarin Iter 1400, auc= 0.880687, fmeasure_max= 0.806890, precision= 0.841210, recall= 0.775261
# Train Random guess:  , auc= 0.225089fmeasure_max= 0.368185, precision= 0.225629, recall= 1.000000
# Validation Iter 1400, auc= 0.876824, fmeasure_max= 0.819444, precision= 0.829525, recall= 0.809605
# Validation Random guess:  auc= 0.229822, fmeasure_max= 0.372272, precision= 0.228977, recall= 0.994854
# Minibatch Loss= 0.557137
# Tarin Iter 1500, auc= 0.911858, fmeasure_max= 0.856631, precision= 0.886827, recall= 0.828423
# Train Random guess:  , auc= 0.233044fmeasure_max= 0.368231, precision= 0.227126, recall= 0.972270
# Validation Iter 1500, auc= 0.876378, fmeasure_max= 0.803235, precision= 0.843396, recall= 0.766724
# Validation Random guess:  auc= 0.225822, fmeasure_max= 0.373144, precision= 0.229821, recall= 0.991424
# Minibatch Loss= 0.501419
# Tarin Iter 1600, auc= 0.925301, fmeasure_max= 0.882867, precision= 0.844482, recall= 0.924908
# Train Random guess:  , auc= 0.216113fmeasure_max= 0.353136, precision= 0.215647, recall= 0.974359
# Validation Iter 1600, auc= 0.886779, fmeasure_max= 0.818981, precision= 0.839640, recall= 0.799314
# Validation Random guess:  auc= 0.229711, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.455687
# Tarin Iter 1700, auc= 0.938289, fmeasure_max= 0.859518, precision= 0.833871, recall= 0.886792
# Train Random guess:  , auc= 0.232924fmeasure_max= 0.377698, precision= 0.238962, recall= 0.900515
# Validation Iter 1700, auc= 0.884336, fmeasure_max= 0.820922, precision= 0.849541, recall= 0.794168
# Validation Random guess:  auc= 0.226377, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.484344
# Tarin Iter 1800, auc= 0.913266, fmeasure_max= 0.843416, precision= 0.850987, recall= 0.835979
# Train Random guess:  , auc= 0.232063fmeasure_max= 0.366732, precision= 0.225171, recall= 0.987654
# Validation Iter 1800, auc= 0.889299, fmeasure_max= 0.825672, precision= 0.835088, recall= 0.816467
# Validation Random guess:  auc= 0.235226, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.520095
# Tarin Iter 1900, auc= 0.947581, fmeasure_max= 0.881533, precision= 0.875433, recall= 0.887719
# Train Random guess:  , auc= 0.216472fmeasure_max= 0.364217, precision= 0.222656, recall= 1.000000
# Validation Iter 1900, auc= 0.883068, fmeasure_max= 0.821990, precision= 0.836590, recall= 0.807890
# Validation Random guess:  auc= 0.218940, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.416797
# Tarin Iter 2000, auc= 0.936245, fmeasure_max= 0.865574, precision= 0.888889, recall= 0.843450
# Train Random guess:  , auc= 0.246409fmeasure_max= 0.393835, precision= 0.245202, recall= 1.000000
# Validation Iter 2000, auc= 0.898545, fmeasure_max= 0.827149, precision= 0.875479, recall= 0.783877
# Validation Random guess:  auc= 0.222356, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.496638
# Tarin Iter 2100, auc= 0.948340, fmeasure_max= 0.871956, precision= 0.898058, recall= 0.847328
# Train Random guess:  , auc= 0.258170fmeasure_max= 0.408227, precision= 0.256460, recall= 1.000000
# Validation Iter 2100, auc= 0.892507, fmeasure_max= 0.828319, precision= 0.855576, recall= 0.802744
# Validation Random guess:  auc= 0.228878, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.489999
# Tarin Iter 2200, auc= 0.934658, fmeasure_max= 0.879325, precision= 0.841680, recall= 0.920495
# Train Random guess:  , auc= 0.227880fmeasure_max= 0.362704, precision= 0.221526, recall= 1.000000
# Validation Iter 2200, auc= 0.893993, fmeasure_max= 0.839549, precision= 0.849123, recall= 0.830189
# Validation Random guess:  auc= 0.240091, fmeasure_max= 0.373899, precision= 0.230862, recall= 0.982847
# Minibatch Loss= 0.413367
# Tarin Iter 2300, auc= 0.927292, fmeasure_max= 0.846014, precision= 0.912109, recall= 0.788851
# Train Random guess:  , auc= 0.237738fmeasure_max= 0.376396, precision= 0.232009, recall= 0.996622
# Validation Iter 2300, auc= 0.877467, fmeasure_max= 0.815903, precision= 0.822300, recall= 0.809605
# Validation Random guess:  auc= 0.248812, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.472511
# Tarin Iter 2400, auc= 0.924343, fmeasure_max= 0.855151, precision= 0.872038, recall= 0.838906
# Train Random guess:  , auc= 0.247488fmeasure_max= 0.409404, precision= 0.257899, recall= 0.992401
# Validation Iter 2400, auc= 0.899069, fmeasure_max= 0.820601, precision= 0.821306, recall= 0.819897
# Validation Random guess:  auc= 0.243272, fmeasure_max= 0.372222, precision= 0.233348, recall= 0.919383
# Minibatch Loss= 0.546789
# Tarin Iter 2500, auc= 0.965169, fmeasure_max= 0.896203, precision= 0.857835, recall= 0.938163
# Train Random guess:  , auc= 0.219251fmeasure_max= 0.362934, precision= 0.221873, recall= 0.996466
# Validation Iter 2500, auc= 0.890367, fmeasure_max= 0.825151, precision= 0.828720, recall= 0.821612
# Validation Random guess:  auc= 0.224936, fmeasure_max= 0.371740, precision= 0.230172, recall= 0.965695
# Minibatch Loss= 0.395288
# Tarin Iter 2600, auc= 0.925624, fmeasure_max= 0.840580, precision= 0.777151, recall= 0.915282
# Train Random guess:  , auc= 0.240117fmeasure_max= 0.381529, precision= 0.236013, recall= 0.995017
# Validation Iter 2600, auc= 0.891435, fmeasure_max= 0.821990, precision= 0.836590, recall= 0.807890
# Validation Random guess:  auc= 0.223648, fmeasure_max= 0.373910, precision= 0.230310, recall= 0.993139
# Minibatch Loss= 0.481581
# Tarin Iter 2700, auc= 0.928911, fmeasure_max= 0.849761, precision= 0.844106, recall= 0.855491
# Train Random guess:  , auc= 0.200503fmeasure_max= 0.337232, precision= 0.202814, recall= 1.000000
# Validation Iter 2700, auc= 0.896922, fmeasure_max= 0.829694, precision= 0.845196, recall= 0.814751
# Validation Random guess:  auc= 0.236913, fmeasure_max= 0.371971, precision= 0.229866, recall= 0.974271
# Minibatch Loss= 0.463063
# Tarin Iter 2800, auc= 0.885741, fmeasure_max= 0.839361, precision= 0.876977, recall= 0.804839
# Train Random guess:  , auc= 0.249929fmeasure_max= 0.390944, precision= 0.243641, recall= 0.988710
# Validation Iter 2800, auc= 0.892109, fmeasure_max= 0.816189, precision= 0.802653, recall= 0.830189
# Validation Random guess:  auc= 0.244118, fmeasure_max= 0.374000, precision= 0.232106, recall= 0.962264
# Minibatch Loss= 0.619283
# Tarin Iter 2900, auc= 0.948277, fmeasure_max= 0.897959, precision= 0.897163, recall= 0.898757
# Train Random guess:  , auc= 0.211021fmeasure_max= 0.361066, precision= 0.220392, recall= 0.998224
# Validation Iter 2900, auc= 0.905961, fmeasure_max= 0.842017, precision= 0.825371, recall= 0.859348
# Validation Random guess:  auc= 0.224974, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.390201
# Tarin Iter 3000, auc= 0.944201, fmeasure_max= 0.876177, precision= 0.880640, recall= 0.871758
# Train Random guess:  , auc= 0.266576fmeasure_max= 0.427797, precision= 0.274662, recall= 0.966859
# Validation Iter 3000, auc= 0.892473, fmeasure_max= 0.828700, precision= 0.868421, recall= 0.792453
# Validation Random guess:  auc= 0.239116, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.563033
# Tarin Iter 3100, auc= 0.908628, fmeasure_max= 0.814594, precision= 0.770423, recall= 0.864139
# Train Random guess:  , auc= 0.252371fmeasure_max= 0.397578, precision= 0.252564, recall= 0.933649
# Validation Iter 3100, auc= 0.894010, fmeasure_max= 0.814503, precision= 0.800995, recall= 0.828473
# Validation Random guess:  auc= 0.232904, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.526744
# Tarin Iter 3200, auc= 0.954303, fmeasure_max= 0.885012, precision= 0.913257, recall= 0.858462
# Train Random guess:  , auc= 0.250050fmeasure_max= 0.405183, precision= 0.254972, recall= 0.986154
# Validation Iter 3200, auc= 0.907095, fmeasure_max= 0.841474, precision= 0.840753, recall= 0.842196
# Validation Random guess:  auc= 0.232224, fmeasure_max= 0.371114, precision= 0.228743, recall= 0.982847
# Minibatch Loss= 0.474559
# Tarin Iter 3300, auc= 0.945376, fmeasure_max= 0.894977, precision= 0.892261, recall= 0.897710
# Train Random guess:  , auc= 0.254321fmeasure_max= 0.408227, precision= 0.256460, recall= 1.000000
# Validation Iter 3300, auc= 0.904230, fmeasure_max= 0.839760, precision= 0.839041, recall= 0.840480
# Validation Random guess:  auc= 0.220662, fmeasure_max= 0.371898, precision= 0.228968, recall= 0.989708
# Minibatch Loss= 0.473701
# Tarin Iter 3400, auc= 0.962219, fmeasure_max= 0.901363, precision= 0.897764, recall= 0.904992
# Train Random guess:  , auc= 0.244579fmeasure_max= 0.390812, precision= 0.242863, recall= 1.000000
# Validation Iter 3400, auc= 0.909604, fmeasure_max= 0.830479, precision= 0.829060, recall= 0.831904
# Validation Random guess:  auc= 0.232890, fmeasure_max= 0.372914, precision= 0.229372, recall= 0.996569
# Minibatch Loss= 0.363556
# Tarin Iter 3500, auc= 0.961226, fmeasure_max= 0.900188, precision= 0.907021, recall= 0.893458
# Train Random guess:  , auc= 0.211171fmeasure_max= 0.346054, precision= 0.209230, recall= 1.000000
# Validation Iter 3500, auc= 0.918372, fmeasure_max= 0.834918, precision= 0.841463, recall= 0.828473
# Validation Random guess:  auc= 0.227562, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.373668
# Tarin Iter 3600, auc= 0.941272, fmeasure_max= 0.864434, precision= 0.884176, recall= 0.845554
# Train Random guess:  , auc= 0.277880fmeasure_max= 0.400750, precision= 0.250586, recall= 1.000000
# Validation Iter 3600, auc= 0.903520, fmeasure_max= 0.821300, precision= 0.866667, recall= 0.780446
# Validation Random guess:  auc= 0.226855, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.482553
# Tarin Iter 3700, auc= 0.934339, fmeasure_max= 0.888552, precision= 0.861765, recall= 0.917058
# Train Random guess:  , auc= 0.238951fmeasure_max= 0.400125, precision= 0.250098, recall= 1.000000
# Validation Iter 3700, auc= 0.903183, fmeasure_max= 0.826087, precision= 0.875240, recall= 0.782161
# Validation Random guess:  auc= 0.228185, fmeasure_max= 0.372827, precision= 0.229489, recall= 0.993139
# Minibatch Loss= 0.460941
# Tarin Iter 3800, auc= 0.948653, fmeasure_max= 0.865275, precision= 0.899408, recall= 0.833638
# Train Random guess:  , auc= 0.219940fmeasure_max= 0.353821, precision= 0.215190, recall= 0.994516
# Validation Iter 3800, auc= 0.901958, fmeasure_max= 0.829016, precision= 0.834783, recall= 0.823328
# Validation Random guess:  auc= 0.227600, fmeasure_max= 0.372138, precision= 0.229150, recall= 0.989708
# Minibatch Loss= 0.396618
# Tarin Iter 3900, auc= 0.971115, fmeasure_max= 0.911720, precision= 0.883481, recall= 0.941824
# Train Random guess:  , auc= 0.256913fmeasure_max= 0.398619, precision= 0.249020, recall= 0.998428
# Validation Iter 3900, auc= 0.914694, fmeasure_max= 0.843911, precision= 0.843911, recall= 0.843911
# Validation Random guess:  auc= 0.241274, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.402250
# Tarin Iter 4000, auc= 0.948406, fmeasure_max= 0.879102, precision= 0.899293, recall= 0.859797
# Train Random guess:  , auc= 0.228019fmeasure_max= 0.375992, precision= 0.231521, recall= 1.000000
# Validation Iter 4000, auc= 0.903897, fmeasure_max= 0.828924, precision= 0.852995, recall= 0.806175
# Validation Random guess:  auc= 0.219576, fmeasure_max= 0.371745, precision= 0.229409, recall= 0.979417
# Minibatch Loss= 0.451096
# Tarin Iter 4100, auc= 0.965125, fmeasure_max= 0.901836, precision= 0.899682, recall= 0.904000
# Train Random guess:  , auc= 0.237101fmeasure_max= 0.393082, precision= 0.244618, recall= 1.000000
# Validation Iter 4100, auc= 0.922308, fmeasure_max= 0.861326, precision= 0.865052, recall= 0.857633
# Validation Random guess:  auc= 0.234139, fmeasure_max= 0.372263, precision= 0.230769, recall= 0.962264
# Minibatch Loss= 0.399590
# Tarin Iter 4200, auc= 0.941877, fmeasure_max= 0.866873, precision= 0.842105, recall= 0.893142
# Train Random guess:  , auc= 0.232016fmeasure_max= 0.393473, precision= 0.244922, recall= 1.000000
# Validation Iter 4200, auc= 0.925942, fmeasure_max= 0.852349, precision= 0.834154, recall= 0.871355
# Validation Random guess:  auc= 0.231779, fmeasure_max= 0.372317, precision= 0.228920, recall= 0.996569
# Minibatch Loss= 0.499895
# Tarin Iter 4300, auc= 0.968069, fmeasure_max= 0.900560, precision= 0.878415, recall= 0.923851
# Train Random guess:  , auc= 0.266746fmeasure_max= 0.428083, precision= 0.273088, recall= 0.989943
# Validation Iter 4300, auc= 0.909088, fmeasure_max= 0.837998, precision= 0.828859, recall= 0.847341
# Validation Random guess:  auc= 0.224343, fmeasure_max= 0.373584, precision= 0.230247, recall= 0.989708
# Minibatch Loss= 0.430088
# Tarin Iter 4400, auc= 0.967587, fmeasure_max= 0.895911, precision= 0.941406, recall= 0.854610
# Train Random guess:  , auc= 0.209243fmeasure_max= 0.362812, precision= 0.221958, recall= 0.992908
# Validation Iter 4400, auc= 0.922181, fmeasure_max= 0.834580, precision= 0.809677, recall= 0.861063
# Validation Random guess:  auc= 0.225454, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.364407
# Tarin Iter 4500, auc= 0.948152, fmeasure_max= 0.883485, precision= 0.884381, recall= 0.882591
# Train Random guess:  , auc= 0.189634fmeasure_max= 0.326475, precision= 0.196532, recall= 0.963563
# Validation Iter 4500, auc= 0.909111, fmeasure_max= 0.832298, precision= 0.862132, recall= 0.804460
# Validation Random guess:  auc= 0.241249, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.373953
# Tarin Iter 4600, auc= 0.947091, fmeasure_max= 0.869888, precision= 0.826271, recall= 0.918367
# Train Random guess:  , auc= 0.245637fmeasure_max= 0.398499, precision= 0.248828, recall= 1.000000
# Validation Iter 4600, auc= 0.911894, fmeasure_max= 0.835401, precision= 0.806709, recall= 0.866209
# Validation Random guess:  auc= 0.226040, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.441543
# Tarin Iter 4700, auc= 0.960855, fmeasure_max= 0.893322, precision= 0.895652, recall= 0.891003
# Train Random guess:  , auc= 0.225668fmeasure_max= 0.368740, precision= 0.226046, recall= 1.000000
# Validation Iter 4700, auc= 0.913529, fmeasure_max= 0.843776, precision= 0.822476, recall= 0.866209
# Validation Random guess:  auc= 0.230143, fmeasure_max= 0.372719, precision= 0.229134, recall= 0.998285
# Minibatch Loss= 0.372175
# Tarin Iter 4800, auc= 0.919812, fmeasure_max= 0.843911, precision= 0.839590, recall= 0.848276
# Train Random guess:  , auc= 0.227280fmeasure_max= 0.370844, precision= 0.227630, recall= 1.000000
# Validation Iter 4800, auc= 0.920348, fmeasure_max= 0.841823, precision= 0.878731, recall= 0.807890
# Validation Random guess:  auc= 0.232739, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.492976
# Tarin Iter 4900, auc= 0.979505, fmeasure_max= 0.930954, precision= 0.928793, recall= 0.933126
# Train Random guess:  , auc= 0.258173fmeasure_max= 0.401499, precision= 0.251172, recall= 1.000000
# Validation Iter 4900, auc= 0.916828, fmeasure_max= 0.830420, precision= 0.846702, recall= 0.814751
# Validation Random guess:  auc= 0.221342, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.396402
# Tarin Iter 5000, auc= 0.981707, fmeasure_max= 0.933333, precision= 0.930233, recall= 0.936455
# Train Random guess:  , auc= 0.231383fmeasure_max= 0.378841, precision= 0.233685, recall= 1.000000
# Validation Iter 5000, auc= 0.918519, fmeasure_max= 0.844595, precision= 0.831947, recall= 0.857633
# Validation Random guess:  auc= 0.234694, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.356600
# Tarin Iter 5100, auc= 0.967677, fmeasure_max= 0.914331, precision= 0.939145, recall= 0.890796
# Train Random guess:  , auc= 0.248945fmeasure_max= 0.400750, precision= 0.250586, recall= 1.000000
# Validation Iter 5100, auc= 0.907769, fmeasure_max= 0.823633, precision= 0.847550, recall= 0.801029
# Validation Random guess:  auc= 0.223552, fmeasure_max= 0.373777, precision= 0.230769, recall= 0.982847
# Minibatch Loss= 0.378062
# Tarin Iter 5200, auc= 0.979015, fmeasure_max= 0.925249, precision= 0.914614, recall= 0.936134
# Train Random guess:  , auc= 0.240873fmeasure_max= 0.378396, precision= 0.234281, recall= 0.983193
# Validation Iter 5200, auc= 0.921331, fmeasure_max= 0.851718, precision= 0.900574, recall= 0.807890
# Validation Random guess:  auc= 0.230551, fmeasure_max= 0.371319, precision= 0.228257, recall= 0.994854
# Minibatch Loss= 0.355547
# Tarin Iter 5300, auc= 0.946000, fmeasure_max= 0.889474, precision= 0.857868, recall= 0.923497
# Train Random guess:  , auc= 0.208664fmeasure_max= 0.353434, precision= 0.214734, recall= 0.998179
# Validation Iter 5300, auc= 0.910363, fmeasure_max= 0.832900, precision= 0.840909, recall= 0.825043
# Validation Random guess:  auc= 0.225618, fmeasure_max= 0.371273, precision= 0.228312, recall= 0.993139
# Minibatch Loss= 0.399480
# Tarin Iter 5400, auc= 0.972207, fmeasure_max= 0.909232, precision= 0.898773, recall= 0.919937
# Train Random guess:  , auc= 0.257944fmeasure_max= 0.398748, precision= 0.249023, recall= 1.000000
# Validation Iter 5400, auc= 0.905962, fmeasure_max= 0.827041, precision= 0.847122, recall= 0.807890
# Validation Random guess:  auc= 0.218083, fmeasure_max= 0.372409, precision= 0.229541, recall= 0.986278
# Minibatch Loss= 0.423782
# Tarin Iter 5500, auc= 0.954625, fmeasure_max= 0.876161, precision= 0.829912, recall= 0.927869
# Train Random guess:  , auc= 0.240707fmeasure_max= 0.386313, precision= 0.239968, recall= 0.990164
# Validation Iter 5500, auc= 0.897936, fmeasure_max= 0.824275, precision= 0.873321, recall= 0.780446
# Validation Random guess:  auc= 0.238882, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.424649
# Tarin Iter 5600, auc= 0.957979, fmeasure_max= 0.891975, precision= 0.852507, recall= 0.935275
# Train Random guess:  , auc= 0.247244fmeasure_max= 0.390590, precision= 0.243863, recall= 0.980583
# Validation Iter 5600, auc= 0.902835, fmeasure_max= 0.827832, precision= 0.862454, recall= 0.795883
# Validation Random guess:  auc= 0.225679, fmeasure_max= 0.371087, precision= 0.228537, recall= 0.986278
# Minibatch Loss= 0.441437
# Tarin Iter 5700, auc= 0.961653, fmeasure_max= 0.908203, precision= 0.904669, recall= 0.911765
# Train Random guess:  , auc= 0.196218fmeasure_max= 0.332461, precision= 0.199529, recall= 0.996078
# Validation Iter 5700, auc= 0.915670, fmeasure_max= 0.839397, precision= 0.869485, recall= 0.811321
# Validation Random guess:  auc= 0.226534, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.339272
# Tarin Iter 5800, auc= 0.969873, fmeasure_max= 0.899098, precision= 0.901316, recall= 0.896890
# Train Random guess:  , auc= 0.242605fmeasure_max= 0.385611, precision= 0.238858, recall= 1.000000
# Validation Iter 5800, auc= 0.907623, fmeasure_max= 0.830743, precision= 0.836522, recall= 0.825043
# Validation Random guess:  auc= 0.240677, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.411220
# Tarin Iter 5900, auc= 0.950028, fmeasure_max= 0.885199, precision= 0.880747, recall= 0.889695
# Train Random guess:  , auc= 0.282241fmeasure_max= 0.424467, precision= 0.269623, recall= 0.997097
# Validation Iter 5900, auc= 0.910963, fmeasure_max= 0.835165, precision= 0.823333, recall= 0.847341
# Validation Random guess:  auc= 0.235887, fmeasure_max= 0.371067, precision= 0.228800, recall= 0.981132
# Minibatch Loss= 0.481475
# Tarin Iter 6000, auc= 0.968018, fmeasure_max= 0.907378, precision= 0.918919, recall= 0.896124
# Train Random guess:  , auc= 0.259264fmeasure_max= 0.402622, precision= 0.252052, recall= 1.000000
# Validation Iter 6000, auc= 0.917479, fmeasure_max= 0.843434, precision= 0.828099, recall= 0.859348
# Validation Random guess:  auc= 0.223035, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.401299
# Tarin Iter 6100, auc= 0.971832, fmeasure_max= 0.932355, precision= 0.930081, recall= 0.934641
# Train Random guess:  , auc= 0.246514fmeasure_max= 0.385876, precision= 0.239063, recall= 1.000000
# Validation Iter 6100, auc= 0.919568, fmeasure_max= 0.847458, precision= 0.837521, recall= 0.857633
# Validation Random guess:  auc= 0.240663, fmeasure_max= 0.371721, precision= 0.228470, recall= 0.996569
# Minibatch Loss= 0.365372
# Tarin Iter 6200, auc= 0.952234, fmeasure_max= 0.883140, precision= 0.903285, recall= 0.863874
# Train Random guess:  , auc= 0.218135fmeasure_max= 0.368438, precision= 0.227199, recall= 0.973822
# Validation Iter 6200, auc= 0.904853, fmeasure_max= 0.821990, precision= 0.836590, recall= 0.807890
# Validation Random guess:  auc= 0.234318, fmeasure_max= 0.373850, precision= 0.231207, recall= 0.975986
# Minibatch Loss= 0.419193
# Tarin Iter 6300, auc= 0.959061, fmeasure_max= 0.890388, precision= 0.862745, recall= 0.919861
# Train Random guess:  , auc= 0.227863fmeasure_max= 0.366305, precision= 0.224219, recall= 1.000000
# Validation Iter 6300, auc= 0.899325, fmeasure_max= 0.818815, precision= 0.831858, recall= 0.806175
# Validation Random guess:  auc= 0.227852, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.402875
# Tarin Iter 6400, auc= 0.961969, fmeasure_max= 0.893964, precision= 0.882448, recall= 0.905785
# Train Random guess:  , auc= 0.238339fmeasure_max= 0.384590, precision= 0.240132, recall= 0.965289
# Validation Iter 6400, auc= 0.901564, fmeasure_max= 0.837679, precision= 0.821782, recall= 0.854202
# Validation Random guess:  auc= 0.223451, fmeasure_max= 0.371676, precision= 0.228526, recall= 0.994854
# Minibatch Loss= 0.398675
# Tarin Iter 6500, auc= 0.967407, fmeasure_max= 0.919778, precision= 0.917591, recall= 0.921975
# Train Random guess:  , auc= 0.239254fmeasure_max= 0.395982, precision= 0.248576, recall= 0.972930
# Validation Iter 6500, auc= 0.911388, fmeasure_max= 0.832203, precision= 0.822446, recall= 0.842196
# Validation Random guess:  auc= 0.234751, fmeasure_max= 0.374785, precision= 0.234483, recall= 0.933105
# Minibatch Loss= 0.336237
# Tarin Iter 6600, auc= 0.966869, fmeasure_max= 0.904943, precision= 0.904943, recall= 0.904943
# Train Random guess:  , auc= 0.217067fmeasure_max= 0.341574, precision= 0.206044, recall= 0.998099
# Validation Iter 6600, auc= 0.901869, fmeasure_max= 0.825969, precision= 0.870722, recall= 0.785592
# Validation Random guess:  auc= 0.226971, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.369899
# Tarin Iter 6700, auc= 0.967841, fmeasure_max= 0.906624, precision= 0.895899, recall= 0.917609
# Train Random guess:  , auc= 0.246884fmeasure_max= 0.389676, precision= 0.241986, recall= 1.000000
# Validation Iter 6700, auc= 0.900352, fmeasure_max= 0.821732, precision= 0.813445, recall= 0.830189
# Validation Random guess:  auc= 0.228404, fmeasure_max= 0.373110, precision= 0.229612, recall= 0.994854
# Minibatch Loss= 0.357664
# Tarin Iter 6800, auc= 0.971956, fmeasure_max= 0.908766, precision= 0.930403, recall= 0.888112
# Train Random guess:  , auc= 0.220335fmeasure_max= 0.365612, precision= 0.223700, recall= 1.000000
# Validation Iter 6800, auc= 0.902320, fmeasure_max= 0.828547, precision= 0.840989, recall= 0.816467
# Validation Random guess:  auc= 0.234170, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.361308
# Tarin Iter 6900, auc= 0.967869, fmeasure_max= 0.905804, precision= 0.891386, recall= 0.920696
# Train Random guess:  , auc= 0.199893fmeasure_max= 0.336324, precision= 0.203050, recall= 0.978723
# Validation Iter 6900, auc= 0.902554, fmeasure_max= 0.832781, precision= 0.804800, recall= 0.862779
# Validation Random guess:  auc= 0.251771, fmeasure_max= 0.374445, precision= 0.233788, recall= 0.939966
# Minibatch Loss= 0.353829
# Tarin Iter 7000, auc= 0.967613, fmeasure_max= 0.895105, precision= 0.843493, recall= 0.953445
# Train Random guess:  , auc= 0.213746fmeasure_max= 0.347053, precision= 0.210800, recall= 0.981378
# Validation Iter 7000, auc= 0.911714, fmeasure_max= 0.833871, precision= 0.786910, recall= 0.886792
# Validation Random guess:  auc= 0.228207, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.335705
# Tarin Iter 7100, auc= 0.952641, fmeasure_max= 0.877351, precision= 0.856094, recall= 0.899691
# Train Random guess:  , auc= 0.272942fmeasure_max= 0.404116, precision= 0.253224, recall= 1.000000
# Validation Iter 7100, auc= 0.904246, fmeasure_max= 0.822660, precision= 0.788976, recall= 0.859348
# Validation Random guess:  auc= 0.227779, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.461333
# Tarin Iter 7200, auc= 0.979878, fmeasure_max= 0.919052, precision= 0.900641, recall= 0.938230
# Train Random guess:  , auc= 0.218918fmeasure_max= 0.379234, precision= 0.233984, recall= 1.000000
# Validation Iter 7200, auc= 0.907025, fmeasure_max= 0.834315, precision= 0.818482, recall= 0.850772
# Validation Random guess:  auc= 0.235467, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.314492
# Tarin Iter 7300, auc= 0.975544, fmeasure_max= 0.911877, precision= 0.880178, recall= 0.945946
# Train Random guess:  , auc= 0.242993fmeasure_max= 0.394844, precision= 0.246082, recall= 0.998410
# Validation Iter 7300, auc= 0.915443, fmeasure_max= 0.835069, precision= 0.845343, recall= 0.825043
# Validation Random guess:  auc= 0.219084, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.421092
# Tarin Iter 7400, auc= 0.970810, fmeasure_max= 0.900239, precision= 0.933775, recall= 0.869029
# Train Random guess:  , auc= 0.255234fmeasure_max= 0.405159, precision= 0.254545, recall= 0.992296
# Validation Iter 7400, auc= 0.919900, fmeasure_max= 0.847636, precision= 0.865832, recall= 0.830189
# Validation Random guess:  auc= 0.251138, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.411198
# Tarin Iter 7500, auc= 0.974038, fmeasure_max= 0.919457, precision= 0.910394, recall= 0.928702
# Train Random guess:  , auc= 0.215921fmeasure_max= 0.352941, precision= 0.214370, recall= 0.998172
# Validation Iter 7500, auc= 0.909511, fmeasure_max= 0.829016, precision= 0.834783, recall= 0.823328
# Validation Random guess:  auc= 0.215489, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.365433
# Tarin Iter 7600, auc= 0.962751, fmeasure_max= 0.907251, precision= 0.862179, recall= 0.957295
# Train Random guess:  , auc= 0.220004fmeasure_max= 0.360571, precision= 0.220460, recall= 0.989324
# Validation Iter 7600, auc= 0.918656, fmeasure_max= 0.852570, precision= 0.837748, recall= 0.867925
# Validation Random guess:  auc= 0.223032, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.366384
# Tarin Iter 7700, auc= 0.942442, fmeasure_max= 0.869832, precision= 0.877898, recall= 0.861912
# Train Random guess:  , auc= 0.272140fmeasure_max= 0.410081, precision= 0.257926, recall= 1.000000
# Validation Iter 7700, auc= 0.892611, fmeasure_max= 0.809083, precision= 0.793729, recall= 0.825043
# Validation Random guess:  auc= 0.229737, fmeasure_max= 0.372242, precision= 0.228774, recall= 0.998285
# Minibatch Loss= 0.524800
# Tarin Iter 7800, auc= 0.964320, fmeasure_max= 0.894780, precision= 0.885246, recall= 0.904523
# Train Random guess:  , auc= 0.236922fmeasure_max= 0.378447, precision= 0.233385, recall= 1.000000
# Validation Iter 7800, auc= 0.909476, fmeasure_max= 0.852010, precision= 0.849829, recall= 0.854202
# Validation Random guess:  auc= 0.224939, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.375011
# Tarin Iter 7900, auc= 0.970474, fmeasure_max= 0.911765, precision= 0.888889, recall= 0.935849
# Train Random guess:  , auc= 0.209816fmeasure_max= 0.343153, precision= 0.207112, recall= 1.000000
# Validation Iter 7900, auc= 0.905894, fmeasure_max= 0.833619, precision= 0.833619, recall= 0.833619
# Validation Random guess:  auc= 0.233054, fmeasure_max= 0.373212, precision= 0.230245, recall= 0.984563
# Minibatch Loss= 0.320905
# Tarin Iter 8000, auc= 0.959694, fmeasure_max= 0.902868, precision= 0.877698, recall= 0.929524
# Train Random guess:  , auc= 0.203890fmeasure_max= 0.343554, precision= 0.207735, recall= 0.992381
# Validation Iter 8000, auc= 0.914620, fmeasure_max= 0.831799, precision= 0.812092, recall= 0.852487
# Validation Random guess:  auc= 0.223392, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.367666
# Tarin Iter 8100, auc= 0.960104, fmeasure_max= 0.909091, precision= 0.912698, recall= 0.905512
# Train Random guess:  , auc= 0.197844fmeasure_max= 0.331701, precision= 0.198826, recall= 1.000000
# Validation Iter 8100, auc= 0.918393, fmeasure_max= 0.837291, precision= 0.859206, recall= 0.816467
# Validation Random guess:  auc= 0.231280, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.356998
# Tarin Iter 8200, auc= 0.978658, fmeasure_max= 0.924282, precision= 0.893939, recall= 0.956757
# Train Random guess:  , auc= 0.211370fmeasure_max= 0.357718, precision= 0.217818, recall= 1.000000
# Validation Iter 8200, auc= 0.911189, fmeasure_max= 0.832068, precision= 0.818937, recall= 0.845626
# Validation Random guess:  auc= 0.231352, fmeasure_max= 0.372671, precision= 0.233261, recall= 0.926244
# Minibatch Loss= 0.347252
# Tarin Iter 8300, auc= 0.962505, fmeasure_max= 0.896853, precision= 0.903169, recall= 0.890625
# Train Random guess:  , auc= 0.225825fmeasure_max= 0.367647, precision= 0.225313, recall= 0.998264
# Validation Iter 8300, auc= 0.910664, fmeasure_max= 0.829825, precision= 0.849192, recall= 0.811321
# Validation Random guess:  auc= 0.233023, fmeasure_max= 0.374349, precision= 0.231016, recall= 0.986278
# Minibatch Loss= 0.371438
# Tarin Iter 8400, auc= 0.976737, fmeasure_max= 0.910875, precision= 0.923715, recall= 0.898387
# Train Random guess:  , auc= 0.264598fmeasure_max= 0.390783, precision= 0.242936, recall= 0.998387
# Validation Iter 8400, auc= 0.908316, fmeasure_max= 0.830189, precision= 0.830189, recall= 0.830189
# Validation Random guess:  auc= 0.239776, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.367570
# Tarin Iter 8500, auc= 0.978822, fmeasure_max= 0.923562, precision= 0.901538, recall= 0.946688
# Train Random guess:  , auc= 0.247974fmeasure_max= 0.389553, precision= 0.241891, recall= 1.000000
# Validation Iter 8500, auc= 0.900526, fmeasure_max= 0.818565, precision= 0.805648, recall= 0.831904
# Validation Random guess:  auc= 0.239676, fmeasure_max= 0.373428, precision= 0.229944, recall= 0.993139
# Minibatch Loss= 0.366357
# Tarin Iter 8600, auc= 0.981626, fmeasure_max= 0.926316, precision= 0.921466, recall= 0.931217
# Train Random guess:  , auc= 0.233743fmeasure_max= 0.363112, precision= 0.221831, recall= 1.000000
# Validation Iter 8600, auc= 0.921835, fmeasure_max= 0.842105, precision= 0.833613, recall= 0.850772
# Validation Random guess:  auc= 0.229417, fmeasure_max= 0.374143, precision= 0.231048, recall= 0.982847
# Minibatch Loss= 0.327971
# Tarin Iter 8700, auc= 0.958648, fmeasure_max= 0.903595, precision= 0.889068, recall= 0.918605
# Train Random guess:  , auc= 0.230279fmeasure_max= 0.382465, precision= 0.236449, recall= 1.000000
# Validation Iter 8700, auc= 0.902067, fmeasure_max= 0.817021, precision= 0.810811, recall= 0.823328
# Validation Random guess:  auc= 0.236467, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.407011
# Tarin Iter 8800, auc= 0.964372, fmeasure_max= 0.909944, precision= 0.929119, recall= 0.891544
# Train Random guess:  , auc= 0.198715fmeasure_max= 0.351456, precision= 0.213276, recall= 0.998162
# Validation Iter 8800, auc= 0.907994, fmeasure_max= 0.819237, precision= 0.792937, recall= 0.847341
# Validation Random guess:  auc= 0.230941, fmeasure_max= 0.373478, precision= 0.232617, recall= 0.946827
# Minibatch Loss= 0.363745
# Tarin Iter 8900, auc= 0.972701, fmeasure_max= 0.915094, precision= 0.900929, recall= 0.929712
# Train Random guess:  , auc= 0.259246fmeasure_max= 0.394161, precision= 0.251888, recall= 0.905751
# Validation Iter 8900, auc= 0.909277, fmeasure_max= 0.831034, precision= 0.835355, recall= 0.826758
# Validation Random guess:  auc= 0.242496, fmeasure_max= 0.372556, precision= 0.230896, recall= 0.963979
# Minibatch Loss= 0.380304
# Tarin Iter 9000, auc= 0.979127, fmeasure_max= 0.925687, precision= 0.915335, recall= 0.936275
# Train Random guess:  , auc= 0.232718fmeasure_max= 0.388232, precision= 0.241352, recall= 0.991830
# Validation Iter 9000, auc= 0.927592, fmeasure_max= 0.840321, precision= 0.875465, recall= 0.807890
# Validation Random guess:  auc= 0.229391, fmeasure_max= 0.373273, precision= 0.229644, recall= 0.996569
# Minibatch Loss= 0.323175
# Tarin Iter 9100, auc= 0.957414, fmeasure_max= 0.881384, precision= 0.919244, recall= 0.846519
# Train Random guess:  , auc= 0.245877fmeasure_max= 0.396966, precision= 0.248025, recall= 0.993671
# Validation Iter 9100, auc= 0.908157, fmeasure_max= 0.833043, precision= 0.844797, recall= 0.821612
# Validation Random guess:  auc= 0.245110, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.419033
# Tarin Iter 9200, auc= 0.970899, fmeasure_max= 0.924632, precision= 0.928044, recall= 0.921245
# Train Random guess:  , auc= 0.207964fmeasure_max= 0.357238, precision= 0.218167, recall= 0.985348
# Validation Iter 9200, auc= 0.919202, fmeasure_max= 0.832504, precision= 0.805778, recall= 0.861063
# Validation Random guess:  auc= 0.227679, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.298090
# Tarin Iter 9300, auc= 0.970795, fmeasure_max= 0.915789, precision= 0.917399, recall= 0.914186
# Train Random guess:  , auc= 0.232465fmeasure_max= 0.364856, precision= 0.223134, recall= 1.000000
# Validation Iter 9300, auc= 0.927277, fmeasure_max= 0.847487, precision= 0.856392, recall= 0.838765
# Validation Random guess:  auc= 0.225660, fmeasure_max= 0.372228, precision= 0.229035, recall= 0.993139
# Minibatch Loss= 0.345268
# Tarin Iter 9400, auc= 0.941519, fmeasure_max= 0.862069, precision= 0.865385, recall= 0.858779
# Train Random guess:  , auc= 0.225783fmeasure_max= 0.344000, precision= 0.208401, recall= 0.984733
# Validation Iter 9400, auc= 0.914278, fmeasure_max= 0.840775, precision= 0.826159, recall= 0.855918
# Validation Random guess:  auc= 0.232520, fmeasure_max= 0.372848, precision= 0.229968, recall= 0.984563
# Minibatch Loss= 0.369548
# Tarin Iter 9500, auc= 0.951006, fmeasure_max= 0.889816, precision= 0.888333, recall= 0.891304
# Train Random guess:  , auc= 0.242889fmeasure_max= 0.379409, precision= 0.234209, recall= 0.998328
# Validation Iter 9500, auc= 0.913674, fmeasure_max= 0.845626, precision= 0.845626, recall= 0.845626
# Validation Random guess:  auc= 0.230464, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.408642
# Tarin Iter 9600, auc= 0.970271, fmeasure_max= 0.916868, precision= 0.890282, recall= 0.945092
# Train Random guess:  , auc= 0.223683fmeasure_max= 0.380770, precision= 0.235433, recall= 0.995008
# Validation Iter 9600, auc= 0.919847, fmeasure_max= 0.839733, precision= 0.817886, recall= 0.862779
# Validation Random guess:  auc= 0.230945, fmeasure_max= 0.372643, precision= 0.228987, recall= 1.000000
# Minibatch Loss= 0.379468
# Tarin Iter 9700, auc= 0.971447, fmeasure_max= 0.908946, precision= 0.893250, recall= 0.925203
# Train Random guess:  , auc= 0.242484fmeasure_max= 0.389696, precision= 0.244509, recall= 0.959350
# Validation Iter 9700, auc= 0.918973, fmeasure_max= 0.842196, precision= 0.842196, recall= 0.842196
# Validation Random guess:  auc= 0.240621, fmeasure_max= 0.372272, precision= 0.228977, recall= 0.994854
# Minibatch Loss= 0.386455
# Tarin Iter 9800, auc= 0.975323, fmeasure_max= 0.912253, precision= 0.929147, recall= 0.895963
# Train Random guess:  , auc= 0.262346fmeasure_max= 0.403324, precision= 0.253924, recall= 0.979814
# Validation Iter 9800, auc= 0.915005, fmeasure_max= 0.827768, precision= 0.848649, recall= 0.807890
# Validation Random guess:  auc= 0.247374, fmeasure_max= 0.372018, precision= 0.229059, recall= 0.989708
# Minibatch Loss= 0.370305
# Tarin Iter 9900, auc= 0.983370, fmeasure_max= 0.925483, precision= 0.928044, recall= 0.922936
# Train Random guess:  , auc= 0.214092fmeasure_max= 0.351535, precision= 0.213333, recall= 0.998165
# Validation Iter 9900, auc= 0.912393, fmeasure_max= 0.832930, precision= 0.786585, recall= 0.885077
# Validation Random guess:  auc= 0.223158, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.332687
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.916077 F1_max = 0.842087 prec = 0.853033 rec = 0.831419
# Test Random guess: auc= 0.234764 fmeasure_max= 0.376239 , precision= 0.232390 , recall= 0.987500

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
