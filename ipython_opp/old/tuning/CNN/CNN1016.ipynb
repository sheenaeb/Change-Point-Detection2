# %%
# useing this variable for saving models and summaries
exp_name = "CNN1016"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [4, 8, 1, 1, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.236782, fmeasure_max= 0.362061, precision= 0.242369, recall= 0.715315
# Train Random guess:  , auc= 0.204797fmeasure_max= 0.356569, precision= 0.216966, recall= 1.000000
# Validation Iter 0, auc= 0.239818, fmeasure_max= 0.398708, precision= 0.272727, recall= 0.740995
# Validation Random guess:  auc= 0.216352, fmeasure_max= 0.372495, precision= 0.233232, recall= 0.924528
# Minibatch Loss= 1.026852
# Tarin Iter 100, auc= 0.770915, fmeasure_max= 0.805526, precision= 0.792887, recall= 0.818575
# Train Random guess:  , auc= 0.173998fmeasure_max= 0.306857, precision= 0.182038, recall= 0.976242
# Validation Iter 100, auc= 0.674730, fmeasure_max= 0.683453, precision= 0.718336, recall= 0.651801
# Validation Random guess:  auc= 0.240026, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.610078
# Tarin Iter 200, auc= 0.813771, fmeasure_max= 0.777778, precision= 0.791803, recall= 0.764241
# Train Random guess:  , auc= 0.255534fmeasure_max= 0.399579, precision= 0.256769, recall= 0.900316
# Validation Iter 200, auc= 0.777340, fmeasure_max= 0.737705, precision= 0.706436, recall= 0.771870
# Validation Random guess:  auc= 0.232253, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.771316
# Tarin Iter 300, auc= 0.820908, fmeasure_max= 0.763359, precision= 0.790514, recall= 0.738007
# Train Random guess:  , auc= 0.202860fmeasure_max= 0.349452, precision= 0.211719, recall= 1.000000
# Validation Iter 300, auc= 0.827068, fmeasure_max= 0.755292, precision= 0.745819, recall= 0.765009
# Validation Random guess:  auc= 0.232815, fmeasure_max= 0.376144, precision= 0.234375, recall= 0.951973
# Minibatch Loss= 0.618284
# Tarin Iter 400, auc= 0.823291, fmeasure_max= 0.810552, precision= 0.795918, recall= 0.825733
# Train Random guess:  , auc= 0.239047fmeasure_max= 0.387464, precision= 0.240472, recall= 0.996743
# Validation Iter 400, auc= 0.853109, fmeasure_max= 0.789338, precision= 0.791379, recall= 0.787307
# Validation Random guess:  auc= 0.219278, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.714914
# Tarin Iter 500, auc= 0.829773, fmeasure_max= 0.775986, precision= 0.824762, recall= 0.732657
# Train Random guess:  , auc= 0.227987fmeasure_max= 0.377446, precision= 0.234736, recall= 0.962775
# Validation Iter 500, auc= 0.837042, fmeasure_max= 0.792422, precision= 0.762282, recall= 0.825043
# Validation Random guess:  auc= 0.228516, fmeasure_max= 0.371127, precision= 0.228022, recall= 0.996569
# Minibatch Loss= 0.682944
# Tarin Iter 600, auc= 0.879130, fmeasure_max= 0.818394, precision= 0.784753, recall= 0.855049
# Train Random guess:  , auc= 0.237761fmeasure_max= 0.387852, precision= 0.240675, recall= 0.998371
# Validation Iter 600, auc= 0.864593, fmeasure_max= 0.805042, precision= 0.789127, recall= 0.821612
# Validation Random guess:  auc= 0.232092, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.600403
# Tarin Iter 700, auc= 0.893144, fmeasure_max= 0.850202, precision= 0.830696, recall= 0.870647
# Train Random guess:  , auc= 0.228003fmeasure_max= 0.381345, precision= 0.235779, recall= 0.996683
# Validation Iter 700, auc= 0.868600, fmeasure_max= 0.812141, precision= 0.778302, recall= 0.849057
# Validation Random guess:  auc= 0.229822, fmeasure_max= 0.372454, precision= 0.229482, recall= 0.987993
# Minibatch Loss= 0.638806
# Tarin Iter 800, auc= 0.846869, fmeasure_max= 0.789773, precision= 0.762340, recall= 0.819253
# Train Random guess:  , auc= 0.215828fmeasure_max= 0.332786, precision= 0.199764, recall= 0.996071
# Validation Iter 800, auc= 0.854589, fmeasure_max= 0.806959, precision= 0.780449, recall= 0.835334
# Validation Random guess:  auc= 0.234297, fmeasure_max= 0.375376, precision= 0.233167, recall= 0.962264
# Minibatch Loss= 0.577102
# Tarin Iter 900, auc= 0.896294, fmeasure_max= 0.836735, precision= 0.806557, recall= 0.869258
# Train Random guess:  , auc= 0.222312fmeasure_max= 0.363812, precision= 0.222441, recall= 0.998233
# Validation Iter 900, auc= 0.879917, fmeasure_max= 0.799673, precision= 0.764062, recall= 0.838765
# Validation Random guess:  auc= 0.219732, fmeasure_max= 0.372748, precision= 0.230364, recall= 0.975986
# Minibatch Loss= 0.510019
# Tarin Iter 1000, auc= 0.895701, fmeasure_max= 0.810017, precision= 0.883239, recall= 0.748006
# Train Random guess:  , auc= 0.233352fmeasure_max= 0.395275, precision= 0.247106, recall= 0.987241
# Validation Iter 1000, auc= 0.843098, fmeasure_max= 0.783217, precision= 0.798574, recall= 0.768439
# Validation Random guess:  auc= 0.229618, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.611406
# Tarin Iter 1100, auc= 0.932907, fmeasure_max= 0.868920, precision= 0.905498, recall= 0.835182
# Train Random guess:  , auc= 0.262887fmeasure_max= 0.397221, precision= 0.248028, recall= 0.996830
# Validation Iter 1100, auc= 0.867008, fmeasure_max= 0.796848, precision= 0.813953, recall= 0.780446
# Validation Random guess:  auc= 0.228535, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.537653
# Tarin Iter 1200, auc= 0.930973, fmeasure_max= 0.850671, precision= 0.849246, recall= 0.852101
# Train Random guess:  , auc= 0.227401fmeasure_max= 0.377538, precision= 0.232695, recall= 1.000000
# Validation Iter 1200, auc= 0.855441, fmeasure_max= 0.791342, precision= 0.798951, recall= 0.783877
# Validation Random guess:  auc= 0.221833, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.493827
# Tarin Iter 1300, auc= 0.934088, fmeasure_max= 0.869932, precision= 0.887931, recall= 0.852649
# Train Random guess:  , auc= 0.228770fmeasure_max= 0.384230, precision= 0.240686, recall= 0.951987
# Validation Iter 1300, auc= 0.854980, fmeasure_max= 0.790186, precision= 0.779633, recall= 0.801029
# Validation Random guess:  auc= 0.250686, fmeasure_max= 0.371987, precision= 0.229594, recall= 0.979417
# Minibatch Loss= 0.510393
# Tarin Iter 1400, auc= 0.917952, fmeasure_max= 0.836868, precision= 0.834146, recall= 0.839607
# Train Random guess:  , auc= 0.263058fmeasure_max= 0.386371, precision= 0.240400, recall= 0.983633
# Validation Iter 1400, auc= 0.864470, fmeasure_max= 0.813617, precision= 0.807432, recall= 0.819897
# Validation Random guess:  auc= 0.225283, fmeasure_max= 0.373264, precision= 0.229912, recall= 0.991424
# Minibatch Loss= 0.473512
# Tarin Iter 1500, auc= 0.930114, fmeasure_max= 0.848138, precision= 0.829132, recall= 0.868035
# Train Random guess:  , auc= 0.284917fmeasure_max= 0.420858, precision= 0.266510, recall= 1.000000
# Validation Iter 1500, auc= 0.871664, fmeasure_max= 0.811736, precision= 0.773292, recall= 0.854202
# Validation Random guess:  auc= 0.237942, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.568123
# Tarin Iter 1600, auc= 0.919702, fmeasure_max= 0.831104, precision= 0.900362, recall= 0.771739
# Train Random guess:  , auc= 0.258856fmeasure_max= 0.402382, precision= 0.252061, recall= 0.996894
# Validation Iter 1600, auc= 0.881265, fmeasure_max= 0.837998, precision= 0.828859, recall= 0.847341
# Validation Random guess:  auc= 0.244462, fmeasure_max= 0.372990, precision= 0.229521, recall= 0.994854
# Minibatch Loss= 0.553530
# Tarin Iter 1700, auc= 0.905562, fmeasure_max= 0.830325, precision= 0.853432, recall= 0.808436
# Train Random guess:  , auc= 0.226740fmeasure_max= 0.365577, precision= 0.224029, recall= 0.992970
# Validation Iter 1700, auc= 0.856066, fmeasure_max= 0.783666, precision= 0.794014, recall= 0.773585
# Validation Random guess:  auc= 0.243614, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.528297
# Tarin Iter 1800, auc= 0.902451, fmeasure_max= 0.859130, precision= 0.885305, recall= 0.834459
# Train Random guess:  , auc= 0.250739fmeasure_max= 0.375635, precision= 0.231250, recall= 1.000000
# Validation Iter 1800, auc= 0.879596, fmeasure_max= 0.822742, precision= 0.802610, recall= 0.843911
# Validation Random guess:  auc= 0.223532, fmeasure_max= 0.371721, precision= 0.228470, recall= 0.996569
# Minibatch Loss= 0.479362
# Tarin Iter 1900, auc= 0.943202, fmeasure_max= 0.867791, precision= 0.856392, recall= 0.879496
# Train Random guess:  , auc= 0.222976fmeasure_max= 0.359543, precision= 0.221074, recall= 0.962230
# Validation Iter 1900, auc= 0.879674, fmeasure_max= 0.818182, precision= 0.803306, recall= 0.833619
# Validation Random guess:  auc= 0.233649, fmeasure_max= 0.372771, precision= 0.229816, recall= 0.986278
# Minibatch Loss= 0.418055
# Tarin Iter 2000, auc= 0.908409, fmeasure_max= 0.842615, precision= 0.836538, recall= 0.848780
# Train Random guess:  , auc= 0.234913fmeasure_max= 0.387524, precision= 0.240328, recall= 1.000000
# Validation Iter 2000, auc= 0.900913, fmeasure_max= 0.837793, precision= 0.817292, recall= 0.859348
# Validation Random guess:  auc= 0.238450, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.544615
# Tarin Iter 2100, auc= 0.910691, fmeasure_max= 0.868739, precision= 0.851100, recall= 0.887125
# Train Random guess:  , auc= 0.230212fmeasure_max= 0.367292, precision= 0.226727, recall= 0.966490
# Validation Iter 2100, auc= 0.904800, fmeasure_max= 0.821895, precision= 0.784711, recall= 0.862779
# Validation Random guess:  auc= 0.215774, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.475180
# Tarin Iter 2200, auc= 0.969472, fmeasure_max= 0.905689, precision= 0.893648, recall= 0.918058
# Train Random guess:  , auc= 0.253881fmeasure_max= 0.410916, precision= 0.258996, recall= 0.993930
# Validation Iter 2200, auc= 0.901355, fmeasure_max= 0.840701, precision= 0.818182, recall= 0.864494
# Validation Random guess:  auc= 0.238035, fmeasure_max= 0.374554, precision= 0.230985, recall= 0.989708
# Minibatch Loss= 0.423921
# Tarin Iter 2300, auc= 0.961385, fmeasure_max= 0.897243, precision= 0.930676, recall= 0.866129
# Train Random guess:  , auc= 0.259637fmeasure_max= 0.393369, precision= 0.245133, recall= 0.995161
# Validation Iter 2300, auc= 0.899513, fmeasure_max= 0.824427, precision= 0.815436, recall= 0.833619
# Validation Random guess:  auc= 0.233796, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.444897
# Tarin Iter 2400, auc= 0.931199, fmeasure_max= 0.850575, precision= 0.833333, recall= 0.868545
# Train Random guess:  , auc= 0.247920fmeasure_max= 0.400754, precision= 0.250688, recall= 0.998435
# Validation Iter 2400, auc= 0.907602, fmeasure_max= 0.833183, precision= 0.878327, recall= 0.792453
# Validation Random guess:  auc= 0.231562, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.496795
# Tarin Iter 2500, auc= 0.926398, fmeasure_max= 0.845447, precision= 0.873921, recall= 0.818770
# Train Random guess:  , auc= 0.247645fmeasure_max= 0.391026, precision= 0.243805, recall= 0.987055
# Validation Iter 2500, auc= 0.880821, fmeasure_max= 0.802189, precision= 0.737069, recall= 0.879931
# Validation Random guess:  auc= 0.220768, fmeasure_max= 0.372275, precision= 0.229719, recall= 0.981132
# Minibatch Loss= 0.535482
# Tarin Iter 2600, auc= 0.934762, fmeasure_max= 0.864567, precision= 0.835616, recall= 0.895595
# Train Random guess:  , auc= 0.246015fmeasure_max= 0.389252, precision= 0.246725, recall= 0.921697
# Validation Iter 2600, auc= 0.917560, fmeasure_max= 0.854353, precision= 0.812693, recall= 0.900515
# Validation Random guess:  auc= 0.233871, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.496476
# Tarin Iter 2700, auc= 0.952048, fmeasure_max= 0.867347, precision= 0.864407, recall= 0.870307
# Train Random guess:  , auc= 0.229902fmeasure_max= 0.373011, precision= 0.229264, recall= 1.000000
# Validation Iter 2700, auc= 0.930934, fmeasure_max= 0.855072, precision= 0.805766, recall= 0.910806
# Validation Random guess:  auc= 0.229609, fmeasure_max= 0.372643, precision= 0.228987, recall= 1.000000
# Minibatch Loss= 0.446990
# Tarin Iter 2800, auc= 0.956150, fmeasure_max= 0.883333, precision= 0.894172, recall= 0.872754
# Train Random guess:  , auc= 0.256271fmeasure_max= 0.414179, precision= 0.261381, recall= 0.997006
# Validation Iter 2800, auc= 0.908452, fmeasure_max= 0.826347, precision= 0.824232, recall= 0.828473
# Validation Random guess:  auc= 0.244462, fmeasure_max= 0.371539, precision= 0.228696, recall= 0.989708
# Minibatch Loss= 0.494812
# Tarin Iter 2900, auc= 0.913223, fmeasure_max= 0.830744, precision= 0.856661, recall= 0.806349
# Train Random guess:  , auc= 0.239301fmeasure_max= 0.395604, precision= 0.246575, recall= 1.000000
# Validation Iter 2900, auc= 0.859706, fmeasure_max= 0.787290, precision= 0.810909, recall= 0.765009
# Validation Random guess:  auc= 0.223929, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.574446
# Tarin Iter 3000, auc= 0.957094, fmeasure_max= 0.877351, precision= 0.888720, recall= 0.866270
# Train Random guess:  , auc= 0.261247fmeasure_max= 0.417789, precision= 0.264683, recall= 0.991085
# Validation Iter 3000, auc= 0.906020, fmeasure_max= 0.829616, precision= 0.864312, recall= 0.797599
# Validation Random guess:  auc= 0.248024, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.459287
# Tarin Iter 3100, auc= 0.932347, fmeasure_max= 0.854127, precision= 0.904472, recall= 0.809091
# Train Random guess:  , auc= 0.219259fmeasure_max= 0.354153, precision= 0.215180, recall= 1.000000
# Validation Iter 3100, auc= 0.902120, fmeasure_max= 0.828720, precision= 0.835951, recall= 0.821612
# Validation Random guess:  auc= 0.229948, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.466466
# Tarin Iter 3200, auc= 0.959530, fmeasure_max= 0.889397, precision= 0.851095, recall= 0.931310
# Train Random guess:  , auc= 0.258468fmeasure_max= 0.393411, precision= 0.246559, recall= 0.972843
# Validation Iter 3200, auc= 0.908228, fmeasure_max= 0.823052, precision= 0.781202, recall= 0.869640
# Validation Random guess:  auc= 0.218416, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.427806
# Tarin Iter 3300, auc= 0.948701, fmeasure_max= 0.870256, precision= 0.867958, recall= 0.872566
# Train Random guess:  , auc= 0.230791fmeasure_max= 0.361947, precision= 0.220962, recall= 1.000000
# Validation Iter 3300, auc= 0.896805, fmeasure_max= 0.816901, precision= 0.839060, recall= 0.795883
# Validation Random guess:  auc= 0.222624, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.433966
# Tarin Iter 3400, auc= 0.957976, fmeasure_max= 0.885714, precision= 0.887122, recall= 0.884311
# Train Random guess:  , auc= 0.266867fmeasure_max= 0.396952, precision= 0.253989, recall= 0.908082
# Validation Iter 3400, auc= 0.931311, fmeasure_max= 0.848739, precision= 0.831960, recall= 0.866209
# Validation Random guess:  auc= 0.217103, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.419703
# Tarin Iter 3500, auc= 0.956753, fmeasure_max= 0.901993, precision= 0.897521, recall= 0.906511
# Train Random guess:  , auc= 0.220899fmeasure_max= 0.379234, precision= 0.233984, recall= 1.000000
# Validation Iter 3500, auc= 0.924471, fmeasure_max= 0.834206, precision= 0.849023, recall= 0.819897
# Validation Random guess:  auc= 0.235193, fmeasure_max= 0.372524, precision= 0.228897, recall= 1.000000
# Minibatch Loss= 0.396796
# Tarin Iter 3600, auc= 0.957438, fmeasure_max= 0.884477, precision= 0.912477, recall= 0.858144
# Train Random guess:  , auc= 0.224583fmeasure_max= 0.365440, precision= 0.223571, recall= 1.000000
# Validation Iter 3600, auc= 0.932554, fmeasure_max= 0.857143, precision= 0.854949, recall= 0.859348
# Validation Random guess:  auc= 0.235351, fmeasure_max= 0.372762, precision= 0.229077, recall= 1.000000
# Minibatch Loss= 0.380013
# Tarin Iter 3700, auc= 0.949370, fmeasure_max= 0.863548, precision= 0.919087, recall= 0.814338
# Train Random guess:  , auc= 0.216022fmeasure_max= 0.353327, precision= 0.214998, recall= 0.990809
# Validation Iter 3700, auc= 0.919074, fmeasure_max= 0.836601, precision= 0.798752, recall= 0.878216
# Validation Random guess:  auc= 0.222510, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.426472
# Tarin Iter 3800, auc= 0.942267, fmeasure_max= 0.871499, precision= 0.878738, recall= 0.864379
# Train Random guess:  , auc= 0.244610fmeasure_max= 0.386912, precision= 0.240142, recall= 0.995098
# Validation Iter 3800, auc= 0.925870, fmeasure_max= 0.833760, precision= 0.828814, recall= 0.838765
# Validation Random guess:  auc= 0.234956, fmeasure_max= 0.371920, precision= 0.231513, recall= 0.945111
# Minibatch Loss= 0.485153
# Tarin Iter 3900, auc= 0.953881, fmeasure_max= 0.878123, precision= 0.878788, recall= 0.877458
# Train Random guess:  , auc= 0.246975fmeasure_max= 0.410959, precision= 0.258722, recall= 0.998487
# Validation Iter 3900, auc= 0.933602, fmeasure_max= 0.855390, precision= 0.874552, recall= 0.837050
# Validation Random guess:  auc= 0.238769, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.447923
# Tarin Iter 4000, auc= 0.966081, fmeasure_max= 0.916667, precision= 0.908778, recall= 0.924694
# Train Random guess:  , auc= 0.226582fmeasure_max= 0.364856, precision= 0.223134, recall= 1.000000
# Validation Iter 4000, auc= 0.911729, fmeasure_max= 0.833922, precision= 0.859745, recall= 0.809605
# Validation Random guess:  auc= 0.235073, fmeasure_max= 0.372695, precision= 0.229665, recall= 0.987993
# Minibatch Loss= 0.357309
# Tarin Iter 4100, auc= 0.962823, fmeasure_max= 0.892638, precision= 0.912226, recall= 0.873874
# Train Random guess:  , auc= 0.246453fmeasure_max= 0.413408, precision= 0.260563, recall= 1.000000
# Validation Iter 4100, auc= 0.926716, fmeasure_max= 0.857143, precision= 0.870796, recall= 0.843911
# Validation Random guess:  auc= 0.231950, fmeasure_max= 0.371630, precision= 0.228583, recall= 0.993139
# Minibatch Loss= 0.487431
# Tarin Iter 4200, auc= 0.948746, fmeasure_max= 0.867061, precision= 0.882707, recall= 0.851959
# Train Random guess:  , auc= 0.267236fmeasure_max= 0.424261, precision= 0.269246, recall= 1.000000
# Validation Iter 4200, auc= 0.907253, fmeasure_max= 0.849868, precision= 0.870504, recall= 0.830189
# Validation Random guess:  auc= 0.229113, fmeasure_max= 0.371988, precision= 0.228854, recall= 0.993139
# Minibatch Loss= 0.536627
# Tarin Iter 4300, auc= 0.954456, fmeasure_max= 0.884378, precision= 0.856410, recall= 0.914234
# Train Random guess:  , auc= 0.239699fmeasure_max= 0.355050, precision= 0.218870, recall= 0.939781
# Validation Iter 4300, auc= 0.924503, fmeasure_max= 0.834646, precision= 0.851786, recall= 0.818182
# Validation Random guess:  auc= 0.221475, fmeasure_max= 0.372594, precision= 0.230056, recall= 0.979417
# Minibatch Loss= 0.408002
# Tarin Iter 4400, auc= 0.968994, fmeasure_max= 0.912837, precision= 0.884793, recall= 0.942717
# Train Random guess:  , auc= 0.225551fmeasure_max= 0.385489, precision= 0.238765, recall= 1.000000
# Validation Iter 4400, auc= 0.913634, fmeasure_max= 0.831304, precision= 0.843034, recall= 0.819897
# Validation Random guess:  auc= 0.230608, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.356384
# Tarin Iter 4500, auc= 0.927863, fmeasure_max= 0.853088, precision= 0.854515, recall= 0.851667
# Train Random guess:  , auc= 0.247508fmeasure_max= 0.381134, precision= 0.235619, recall= 0.996667
# Validation Iter 4500, auc= 0.895387, fmeasure_max= 0.804328, precision= 0.847909, recall= 0.765009
# Validation Random guess:  auc= 0.219860, fmeasure_max= 0.372771, precision= 0.229816, recall= 0.986278
# Minibatch Loss= 0.473916
# Tarin Iter 4600, auc= 0.971589, fmeasure_max= 0.902896, precision= 0.880399, recall= 0.926573
# Train Random guess:  , auc= 0.237814fmeasure_max= 0.366458, precision= 0.225885, recall= 0.970280
# Validation Iter 4600, auc= 0.909733, fmeasure_max= 0.845543, precision= 0.870909, recall= 0.821612
# Validation Random guess:  auc= 0.220502, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.392184
# Tarin Iter 4700, auc= 0.962565, fmeasure_max= 0.899377, precision= 0.895390, recall= 0.903399
# Train Random guess:  , auc= 0.217453fmeasure_max= 0.358776, precision= 0.218775, recall= 0.996422
# Validation Iter 4700, auc= 0.935550, fmeasure_max= 0.859504, precision= 0.829346, recall= 0.891938
# Validation Random guess:  auc= 0.240553, fmeasure_max= 0.374056, precision= 0.233805, recall= 0.934820
# Minibatch Loss= 0.421966
# Tarin Iter 4800, auc= 0.972862, fmeasure_max= 0.913518, precision= 0.929915, recall= 0.897690
# Train Random guess:  , auc= 0.235169fmeasure_max= 0.384249, precision= 0.237908, recall= 0.998350
# Validation Iter 4800, auc= 0.927715, fmeasure_max= 0.845290, precision= 0.851916, recall= 0.838765
# Validation Random guess:  auc= 0.237542, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.387232
# Tarin Iter 4900, auc= 0.952241, fmeasure_max= 0.881844, precision= 0.880998, recall= 0.882692
# Train Random guess:  , auc= 0.189987fmeasure_max= 0.340326, precision= 0.205799, recall= 0.982692
# Validation Iter 4900, auc= 0.928533, fmeasure_max= 0.841933, precision= 0.805643, recall= 0.881647
# Validation Random guess:  auc= 0.232344, fmeasure_max= 0.375439, precision= 0.235995, recall= 0.917667
# Minibatch Loss= 0.405271
# Tarin Iter 5000, auc= 0.974932, fmeasure_max= 0.911170, precision= 0.931655, recall= 0.891566
# Train Random guess:  , auc= 0.227419fmeasure_max= 0.373526, precision= 0.230676, recall= 0.981067
# Validation Iter 5000, auc= 0.900668, fmeasure_max= 0.838095, precision= 0.846154, recall= 0.830189
# Validation Random guess:  auc= 0.216527, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.402180
# Tarin Iter 5100, auc= 0.959998, fmeasure_max= 0.900515, precision= 0.877926, recall= 0.924296
# Train Random guess:  , auc= 0.220760fmeasure_max= 0.364104, precision= 0.222747, recall= 0.996479
# Validation Iter 5100, auc= 0.926832, fmeasure_max= 0.842105, precision= 0.833613, recall= 0.850772
# Validation Random guess:  auc= 0.238593, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.390031
# Tarin Iter 5200, auc= 0.969800, fmeasure_max= 0.904110, precision= 0.903285, recall= 0.904936
# Train Random guess:  , auc= 0.229637fmeasure_max= 0.352562, precision= 0.214006, recall= 1.000000
# Validation Iter 5200, auc= 0.934617, fmeasure_max= 0.868309, precision= 0.860269, recall= 0.876501
# Validation Random guess:  auc= 0.237335, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.402115
# Tarin Iter 5300, auc= 0.957717, fmeasure_max= 0.881164, precision= 0.897858, recall= 0.865079
# Train Random guess:  , auc= 0.250378fmeasure_max= 0.395459, precision= 0.246753, recall= 0.995238
# Validation Iter 5300, auc= 0.936563, fmeasure_max= 0.860692, precision= 0.891544, recall= 0.831904
# Validation Random guess:  auc= 0.232131, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.436186
# Tarin Iter 5400, auc= 0.976719, fmeasure_max= 0.924399, precision= 0.918089, recall= 0.930796
# Train Random guess:  , auc= 0.214016fmeasure_max= 0.369044, precision= 0.226363, recall= 0.998270
# Validation Iter 5400, auc= 0.919854, fmeasure_max= 0.843478, precision= 0.855379, recall= 0.831904
# Validation Random guess:  auc= 0.222772, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.364056
# Tarin Iter 5500, auc= 0.968620, fmeasure_max= 0.903759, precision= 0.891691, recall= 0.916159
# Train Random guess:  , auc= 0.267559fmeasure_max= 0.408992, precision= 0.257165, recall= 0.998476
# Validation Iter 5500, auc= 0.929132, fmeasure_max= 0.852843, precision= 0.831974, recall= 0.874786
# Validation Random guess:  auc= 0.228202, fmeasure_max= 0.374212, precision= 0.235139, recall= 0.915952
# Minibatch Loss= 0.394702
# Tarin Iter 5600, auc= 0.966448, fmeasure_max= 0.896437, precision= 0.910774, recall= 0.882545
# Train Random guess:  , auc= 0.247327fmeasure_max= 0.387241, precision= 0.240682, recall= 0.990212
# Validation Iter 5600, auc= 0.929343, fmeasure_max= 0.866782, precision= 0.874346, recall= 0.859348
# Validation Random guess:  auc= 0.233883, fmeasure_max= 0.373290, precision= 0.230398, recall= 0.982847
# Minibatch Loss= 0.398165
# Tarin Iter 5700, auc= 0.964900, fmeasure_max= 0.898723, precision= 0.921466, recall= 0.877076
# Train Random guess:  , auc= 0.238610fmeasure_max= 0.382222, precision= 0.236264, recall= 1.000000
# Validation Iter 5700, auc= 0.904268, fmeasure_max= 0.828402, precision= 0.816667, recall= 0.840480
# Validation Random guess:  auc= 0.225735, fmeasure_max= 0.372783, precision= 0.229547, recall= 0.991424
# Minibatch Loss= 0.436231
# Tarin Iter 5800, auc= 0.970599, fmeasure_max= 0.906500, precision= 0.900885, recall= 0.912186
# Train Random guess:  , auc= 0.212255fmeasure_max= 0.358382, precision= 0.218310, recall= 1.000000
# Validation Iter 5800, auc= 0.932815, fmeasure_max= 0.862325, precision= 0.830159, recall= 0.897084
# Validation Random guess:  auc= 0.228357, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.344691
# Tarin Iter 5900, auc= 0.967764, fmeasure_max= 0.902564, precision= 0.915078, recall= 0.890388
# Train Random guess:  , auc= 0.228692fmeasure_max= 0.377877, precision= 0.233136, recall= 0.996627
# Validation Iter 5900, auc= 0.917111, fmeasure_max= 0.833482, precision= 0.866667, recall= 0.802744
# Validation Random guess:  auc= 0.219291, fmeasure_max= 0.371676, precision= 0.228526, recall= 0.994854
# Minibatch Loss= 0.413213
# Tarin Iter 6000, auc= 0.975168, fmeasure_max= 0.909091, precision= 0.945419, recall= 0.875451
# Train Random guess:  , auc= 0.216710fmeasure_max= 0.356156, precision= 0.216660, recall= 1.000000
# Validation Iter 6000, auc= 0.923397, fmeasure_max= 0.850000, precision= 0.886406, recall= 0.816467
# Validation Random guess:  auc= 0.232396, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.359161
# Tarin Iter 6100, auc= 0.978390, fmeasure_max= 0.922421, precision= 0.926370, recall= 0.918506
# Train Random guess:  , auc= 0.226636fmeasure_max= 0.376309, precision= 0.233077, recall= 0.976231
# Validation Iter 6100, auc= 0.925071, fmeasure_max= 0.845896, precision= 0.826514, recall= 0.866209
# Validation Random guess:  auc= 0.227220, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.371411
# Tarin Iter 6200, auc= 0.955061, fmeasure_max= 0.885057, precision= 0.847484, recall= 0.926117
# Train Random guess:  , auc= 0.223016fmeasure_max= 0.370701, precision= 0.227522, recall= 1.000000
# Validation Iter 6200, auc= 0.928435, fmeasure_max= 0.848837, precision= 0.822866, recall= 0.876501
# Validation Random guess:  auc= 0.226264, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.409235
# Tarin Iter 6300, auc= 0.946919, fmeasure_max= 0.865872, precision= 0.871064, recall= 0.860741
# Train Random guess:  , auc= 0.278667fmeasure_max= 0.417311, precision= 0.263672, recall= 1.000000
# Validation Iter 6300, auc= 0.900420, fmeasure_max= 0.832068, precision= 0.818937, recall= 0.845626
# Validation Random guess:  auc= 0.237220, fmeasure_max= 0.372530, precision= 0.229633, recall= 0.986278
# Minibatch Loss= 0.504656
# Tarin Iter 6400, auc= 0.965744, fmeasure_max= 0.908752, precision= 0.890511, recall= 0.927757
# Train Random guess:  , auc= 0.206362fmeasure_max= 0.341115, precision= 0.205629, recall= 1.000000
# Validation Iter 6400, auc= 0.914576, fmeasure_max= 0.834073, precision= 0.863971, recall= 0.806175
# Validation Random guess:  auc= 0.211279, fmeasure_max= 0.372881, precision= 0.230181, recall= 0.981132
# Minibatch Loss= 0.357653
# Tarin Iter 6500, auc= 0.971786, fmeasure_max= 0.914714, precision= 0.913858, recall= 0.915572
# Train Random guess:  , auc= 0.219540fmeasure_max= 0.346702, precision= 0.210548, recall= 0.981238
# Validation Iter 6500, auc= 0.925053, fmeasure_max= 0.840486, precision= 0.796012, recall= 0.890223
# Validation Random guess:  auc= 0.218340, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.347232
# Tarin Iter 6600, auc= 0.970366, fmeasure_max= 0.894336, precision= 0.956600, recall= 0.839683
# Train Random guess:  , auc= 0.253003fmeasure_max= 0.394984, precision= 0.246094, recall= 1.000000
# Validation Iter 6600, auc= 0.920337, fmeasure_max= 0.822567, precision= 0.785937, recall= 0.862779
# Validation Random guess:  auc= 0.232390, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.427474
# Tarin Iter 6700, auc= 0.972632, fmeasure_max= 0.922395, precision= 0.912281, recall= 0.932735
# Train Random guess:  , auc= 0.250630fmeasure_max= 0.414764, precision= 0.262263, recall= 0.991031
# Validation Iter 6700, auc= 0.937294, fmeasure_max= 0.860781, precision= 0.852101, recall= 0.869640
# Validation Random guess:  auc= 0.243354, fmeasure_max= 0.373455, precision= 0.230430, recall= 0.984563
# Minibatch Loss= 0.400826
# Tarin Iter 6800, auc= 0.948628, fmeasure_max= 0.868988, precision= 0.853420, recall= 0.885135
# Train Random guess:  , auc= 0.226769fmeasure_max= 0.375754, precision= 0.231340, recall= 1.000000
# Validation Iter 6800, auc= 0.917738, fmeasure_max= 0.833333, precision= 0.802862, recall= 0.866209
# Validation Random guess:  auc= 0.235651, fmeasure_max= 0.376399, precision= 0.234573, recall= 0.951973
# Minibatch Loss= 0.420872
# Tarin Iter 6900, auc= 0.959161, fmeasure_max= 0.895470, precision= 0.898601, recall= 0.892361
# Train Random guess:  , auc= 0.214352fmeasure_max= 0.367464, precision= 0.225088, recall= 1.000000
# Validation Iter 6900, auc= 0.933930, fmeasure_max= 0.849673, precision= 0.811232, recall= 0.891938
# Validation Random guess:  auc= 0.235720, fmeasure_max= 0.371799, precision= 0.230611, recall= 0.958834
# Minibatch Loss= 0.368397
# Tarin Iter 7000, auc= 0.981449, fmeasure_max= 0.925208, precision= 0.948864, recall= 0.902703
# Train Random guess:  , auc= 0.233681fmeasure_max= 0.357840, precision= 0.218341, recall= 0.990991
# Validation Iter 7000, auc= 0.916717, fmeasure_max= 0.847863, precision= 0.844974, recall= 0.850772
# Validation Random guess:  auc= 0.232195, fmeasure_max= 0.371319, precision= 0.228257, recall= 0.994854
# Minibatch Loss= 0.357097
# Tarin Iter 7100, auc= 0.968676, fmeasure_max= 0.904682, precision= 0.894215, recall= 0.915398
# Train Random guess:  , auc= 0.218909fmeasure_max= 0.375596, precision= 0.231221, recall= 1.000000
# Validation Iter 7100, auc= 0.920411, fmeasure_max= 0.847845, precision= 0.870036, recall= 0.826758
# Validation Random guess:  auc= 0.227763, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.380376
# Tarin Iter 7200, auc= 0.968289, fmeasure_max= 0.911252, precision= 0.928918, recall= 0.894246
# Train Random guess:  , auc= 0.241256fmeasure_max= 0.402512, precision= 0.252164, recall= 0.996890
# Validation Iter 7200, auc= 0.913462, fmeasure_max= 0.844920, precision= 0.879406, recall= 0.813036
# Validation Random guess:  auc= 0.222970, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.414200
# Tarin Iter 7300, auc= 0.985049, fmeasure_max= 0.938272, precision= 0.940952, recall= 0.935606
# Train Random guess:  , auc= 0.206449fmeasure_max= 0.343864, precision= 0.208552, recall= 0.979167
# Validation Iter 7300, auc= 0.928206, fmeasure_max= 0.849453, precision= 0.833333, recall= 0.866209
# Validation Random guess:  auc= 0.232249, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.279851
# Tarin Iter 7400, auc= 0.961797, fmeasure_max= 0.891089, precision= 0.918367, recall= 0.865385
# Train Random guess:  , auc= 0.262058fmeasure_max= 0.418488, precision= 0.265241, recall= 0.991124
# Validation Iter 7400, auc= 0.914741, fmeasure_max= 0.854352, precision= 0.885820, recall= 0.825043
# Validation Random guess:  auc= 0.224183, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.448522
# Tarin Iter 7500, auc= 0.979965, fmeasure_max= 0.921803, precision= 0.936449, recall= 0.907609
# Train Random guess:  , auc= 0.222559fmeasure_max= 0.355098, precision= 0.215878, recall= 1.000000
# Validation Iter 7500, auc= 0.914295, fmeasure_max= 0.849408, precision= 0.838063, recall= 0.861063
# Validation Random guess:  auc= 0.234476, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.379072
# Tarin Iter 7600, auc= 0.964719, fmeasure_max= 0.893546, precision= 0.872340, recall= 0.915808
# Train Random guess:  , auc= 0.231813fmeasure_max= 0.371923, precision= 0.230611, recall= 0.960481
# Validation Iter 7600, auc= 0.924249, fmeasure_max= 0.861301, precision= 0.859829, recall= 0.862779
# Validation Random guess:  auc= 0.232440, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.349999
# Tarin Iter 7700, auc= 0.922545, fmeasure_max= 0.857143, precision= 0.857805, recall= 0.856481
# Train Random guess:  , auc= 0.259216fmeasure_max= 0.405550, precision= 0.254855, recall= 0.992284
# Validation Iter 7700, auc= 0.901464, fmeasure_max= 0.823105, precision= 0.868571, recall= 0.782161
# Validation Random guess:  auc= 0.229380, fmeasure_max= 0.372707, precision= 0.229398, recall= 0.993139
# Minibatch Loss= 0.577655
# Tarin Iter 7800, auc= 0.966538, fmeasure_max= 0.898156, precision= 0.881890, recall= 0.915033
# Train Random guess:  , auc= 0.250268fmeasure_max= 0.385919, precision= 0.241042, recall= 0.967320
# Validation Iter 7800, auc= 0.914385, fmeasure_max= 0.850671, precision= 0.832512, recall= 0.869640
# Validation Random guess:  auc= 0.233577, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.405145
# Tarin Iter 7900, auc= 0.970392, fmeasure_max= 0.903386, precision= 0.911667, recall= 0.895254
# Train Random guess:  , auc= 0.245685fmeasure_max= 0.386098, precision= 0.239233, recall= 1.000000
# Validation Iter 7900, auc= 0.920283, fmeasure_max= 0.846906, precision= 0.806202, recall= 0.891938
# Validation Random guess:  auc= 0.221744, fmeasure_max= 0.373436, precision= 0.229676, recall= 0.998285
# Minibatch Loss= 0.383770
# Tarin Iter 8000, auc= 0.963907, fmeasure_max= 0.896552, precision= 0.880707, recall= 0.912977
# Train Random guess:  , auc= 0.248030fmeasure_max= 0.408500, precision= 0.257806, recall= 0.983206
# Validation Iter 8000, auc= 0.948283, fmeasure_max= 0.873449, precision= 0.843450, recall= 0.905660
# Validation Random guess:  auc= 0.234369, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.471218
# Tarin Iter 8100, auc= 0.977874, fmeasure_max= 0.925984, precision= 0.934817, recall= 0.917317
# Train Random guess:  , auc= 0.259528fmeasure_max= 0.401274, precision= 0.252101, recall= 0.982839
# Validation Iter 8100, auc= 0.930108, fmeasure_max= 0.844813, precision= 0.818328, recall= 0.873070
# Validation Random guess:  auc= 0.223450, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.396694
# Tarin Iter 8200, auc= 0.975518, fmeasure_max= 0.910062, precision= 0.888696, recall= 0.932482
# Train Random guess:  , auc= 0.203029fmeasure_max= 0.353443, precision= 0.215428, recall= 0.983577
# Validation Iter 8200, auc= 0.919922, fmeasure_max= 0.849268, precision= 0.852941, recall= 0.845626
# Validation Random guess:  auc= 0.216568, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.368741
# Tarin Iter 8300, auc= 0.963216, fmeasure_max= 0.894292, precision= 0.881250, recall= 0.907725
# Train Random guess:  , auc= 0.174858fmeasure_max= 0.308201, precision= 0.182174, recall= 1.000000
# Validation Iter 8300, auc= 0.927618, fmeasure_max= 0.838111, precision= 0.824212, recall= 0.852487
# Validation Random guess:  auc= 0.235114, fmeasure_max= 0.373893, precision= 0.231144, recall= 0.977702
# Minibatch Loss= 0.330617
# Tarin Iter 8400, auc= 0.975701, fmeasure_max= 0.926866, precision= 0.909224, recall= 0.945205
# Train Random guess:  , auc= 0.278619fmeasure_max= 0.408964, precision= 0.257042, recall= 1.000000
# Validation Iter 8400, auc= 0.935372, fmeasure_max= 0.862191, precision= 0.888889, recall= 0.837050
# Validation Random guess:  auc= 0.226843, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.394554
# Tarin Iter 8500, auc= 0.963001, fmeasure_max= 0.893524, precision= 0.908482, recall= 0.879050
# Train Random guess:  , auc= 0.196595fmeasure_max= 0.311610, precision= 0.188491, recall= 0.898488
# Validation Iter 8500, auc= 0.929661, fmeasure_max= 0.862069, precision= 0.866551, recall= 0.857633
# Validation Random guess:  auc= 0.227036, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.298212
# Tarin Iter 8600, auc= 0.969546, fmeasure_max= 0.912671, precision= 0.930192, recall= 0.895798
# Train Random guess:  , auc= 0.238465fmeasure_max= 0.378103, precision= 0.233216, recall= 0.998319
# Validation Iter 8600, auc= 0.948850, fmeasure_max= 0.885000, precision= 0.860616, recall= 0.910806
# Validation Random guess:  auc= 0.226384, fmeasure_max= 0.371778, precision= 0.228877, recall= 0.989708
# Minibatch Loss= 0.376728
# Tarin Iter 8700, auc= 0.975392, fmeasure_max= 0.920792, precision= 0.945122, recall= 0.897683
# Train Random guess:  , auc= 0.209461fmeasure_max= 0.336911, precision= 0.202581, recall= 1.000000
# Validation Iter 8700, auc= 0.922681, fmeasure_max= 0.854484, precision= 0.843072, recall= 0.866209
# Validation Random guess:  auc= 0.223119, fmeasure_max= 0.371319, precision= 0.228257, recall= 0.994854
# Minibatch Loss= 0.312573
# Tarin Iter 8800, auc= 0.921129, fmeasure_max= 0.850629, precision= 0.894215, recall= 0.811094
# Train Random guess:  , auc= 0.257194fmeasure_max= 0.413772, precision= 0.260853, recall= 1.000000
# Validation Iter 8800, auc= 0.902908, fmeasure_max= 0.836243, precision= 0.811290, recall= 0.862779
# Validation Random guess:  auc= 0.244323, fmeasure_max= 0.372093, precision= 0.230738, recall= 0.960549
# Minibatch Loss= 0.570198
# Tarin Iter 8900, auc= 0.965870, fmeasure_max= 0.904087, precision= 0.910924, recall= 0.897351
# Train Random guess:  , auc= 0.229762fmeasure_max= 0.382559, precision= 0.236801, recall= 0.995033
# Validation Iter 8900, auc= 0.903246, fmeasure_max= 0.838710, precision= 0.852837, recall= 0.825043
# Validation Random guess:  auc= 0.234305, fmeasure_max= 0.373351, precision= 0.232519, recall= 0.946827
# Minibatch Loss= 0.411644
# Tarin Iter 9000, auc= 0.980332, fmeasure_max= 0.921457, precision= 0.896063, recall= 0.948333
# Train Random guess:  , auc= 0.229784fmeasure_max= 0.380228, precision= 0.234742, recall= 1.000000
# Validation Iter 9000, auc= 0.912913, fmeasure_max= 0.846561, precision= 0.871143, recall= 0.823328
# Validation Random guess:  auc= 0.223623, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.399452
# Tarin Iter 9100, auc= 0.973658, fmeasure_max= 0.910017, precision= 0.919383, recall= 0.900840
# Train Random guess:  , auc= 0.253398fmeasure_max= 0.378223, precision= 0.233307, recall= 0.998319
# Validation Iter 9100, auc= 0.934706, fmeasure_max= 0.846218, precision= 0.820968, recall= 0.873070
# Validation Random guess:  auc= 0.226407, fmeasure_max= 0.371951, precision= 0.231743, recall= 0.941681
# Minibatch Loss= 0.372249
# Tarin Iter 9200, auc= 0.966365, fmeasure_max= 0.904202, precision= 0.896667, recall= 0.911864
# Train Random guess:  , auc= 0.230794fmeasure_max= 0.376041, precision= 0.231833, recall= 0.994915
# Validation Iter 9200, auc= 0.931920, fmeasure_max= 0.853571, precision= 0.890130, recall= 0.819897
# Validation Random guess:  auc= 0.223840, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.384721
# Tarin Iter 9300, auc= 0.982930, fmeasure_max= 0.938567, precision= 0.941781, recall= 0.935374
# Train Random guess:  , auc= 0.224134fmeasure_max= 0.374165, precision= 0.230137, recall= 1.000000
# Validation Iter 9300, auc= 0.932053, fmeasure_max= 0.862576, precision= 0.869338, recall= 0.855918
# Validation Random guess:  auc= 0.238894, fmeasure_max= 0.372719, precision= 0.229134, recall= 0.998285
# Minibatch Loss= 0.373940
# Tarin Iter 9400, auc= 0.971072, fmeasure_max= 0.915527, precision= 0.893250, recall= 0.938944
# Train Random guess:  , auc= 0.246326fmeasure_max= 0.385386, precision= 0.239646, recall= 0.983498
# Validation Iter 9400, auc= 0.913182, fmeasure_max= 0.846091, precision= 0.813291, recall= 0.881647
# Validation Random guess:  auc= 0.234988, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.362425
# Tarin Iter 9500, auc= 0.958190, fmeasure_max= 0.878247, precision= 0.889803, recall= 0.866987
# Train Random guess:  , auc= 0.244898fmeasure_max= 0.392925, precision= 0.244689, recall= 0.996795
# Validation Iter 9500, auc= 0.932435, fmeasure_max= 0.848908, precision= 0.864769, recall= 0.833619
# Validation Random guess:  auc= 0.226687, fmeasure_max= 0.372957, precision= 0.229314, recall= 0.998285
# Minibatch Loss= 0.402793
# Tarin Iter 9600, auc= 0.972181, fmeasure_max= 0.905405, precision= 0.860353, recall= 0.955437
# Train Random guess:  , auc= 0.228227fmeasure_max= 0.360000, precision= 0.219772, recall= 0.994652
# Validation Iter 9600, auc= 0.923609, fmeasure_max= 0.848222, precision= 0.857895, recall= 0.838765
# Validation Random guess:  auc= 0.235624, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.341132
# Tarin Iter 9700, auc= 0.966329, fmeasure_max= 0.905628, precision= 0.890971, recall= 0.920775
# Train Random guess:  , auc= 0.239077fmeasure_max= 0.364926, precision= 0.223362, recall= 0.996479
# Validation Iter 9700, auc= 0.934451, fmeasure_max= 0.858854, precision= 0.856655, recall= 0.861063
# Validation Random guess:  auc= 0.234709, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.406645
# Tarin Iter 9800, auc= 0.974672, fmeasure_max= 0.912118, precision= 0.891501, recall= 0.933712
# Train Random guess:  , auc= 0.210571fmeasure_max= 0.344262, precision= 0.208168, recall= 0.994318
# Validation Iter 9800, auc= 0.926379, fmeasure_max= 0.849829, precision= 0.845501, recall= 0.854202
# Validation Random guess:  auc= 0.225755, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.371200
# Tarin Iter 9900, auc= 0.988000, fmeasure_max= 0.940075, precision= 0.931354, recall= 0.948960
# Train Random guess:  , auc= 0.195475fmeasure_max= 0.342839, precision= 0.206883, recall= 1.000000
# Validation Iter 9900, auc= 0.937460, fmeasure_max= 0.858917, precision= 0.889706, recall= 0.830189
# Validation Random guess:  auc= 0.241109, fmeasure_max= 0.371227, precision= 0.228368, recall= 0.991424
# Minibatch Loss= 0.323721
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.913418 F1_max = 0.843662 prec = 0.849221 rec = 0.838176
# Test Random guess: auc= 0.232746 fmeasure_max= 0.375762 , precision= 0.231383 , recall= 0.999324

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
