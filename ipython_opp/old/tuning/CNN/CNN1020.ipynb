# %%
# useing this variable for saving models and summaries
exp_name = "CNN1020"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [4, 2, 2, 2, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [1, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.233112, fmeasure_max= 0.359551, precision= 0.222319, recall= 0.939450
# Train Random guess:  , auc= 0.218690fmeasure_max= 0.351386, precision= 0.213140, recall= 1.000000
# Validation Iter 0, auc= 0.191038, fmeasure_max= 0.373061, precision= 0.239320, recall= 0.845626
# Validation Random guess:  auc= 0.242638, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 1.031113
# Tarin Iter 100, auc= 0.795002, fmeasure_max= 0.796875, precision= 0.840659, recall= 0.757426
# Train Random guess:  , auc= 0.242233fmeasure_max= 0.382938, precision= 0.236811, recall= 1.000000
# Validation Iter 100, auc= 0.750071, fmeasure_max= 0.743056, precision= 0.752197, recall= 0.734134
# Validation Random guess:  auc= 0.237180, fmeasure_max= 0.373502, precision= 0.231722, recall= 0.962264
# Minibatch Loss= 0.846548
# Tarin Iter 200, auc= 0.708587, fmeasure_max= 0.679174, precision= 0.754167, recall= 0.617747
# Train Random guess:  , auc= 0.225091fmeasure_max= 0.374016, precision= 0.231519, recall= 0.972696
# Validation Iter 200, auc= 0.740390, fmeasure_max= 0.712014, precision= 0.734062, recall= 0.691252
# Validation Random guess:  auc= 0.217840, fmeasure_max= 0.372272, precision= 0.228977, recall= 0.994854
# Minibatch Loss= 0.872361
# Tarin Iter 300, auc= 0.762993, fmeasure_max= 0.713147, precision= 0.793792, recall= 0.647378
# Train Random guess:  , auc= 0.211121fmeasure_max= 0.356085, precision= 0.216608, recall= 1.000000
# Validation Iter 300, auc= 0.787175, fmeasure_max= 0.748971, precision= 0.719937, recall= 0.780446
# Validation Random guess:  auc= 0.230081, fmeasure_max= 0.372108, precision= 0.229686, recall= 0.979417
# Minibatch Loss= 0.729256
# Tarin Iter 400, auc= 0.805381, fmeasure_max= 0.769658, precision= 0.830339, recall= 0.717241
# Train Random guess:  , auc= 0.227586fmeasure_max= 0.370016, precision= 0.227006, recall= 1.000000
# Validation Iter 400, auc= 0.838767, fmeasure_max= 0.777589, precision= 0.769748, recall= 0.785592
# Validation Random guess:  auc= 0.227640, fmeasure_max= 0.373308, precision= 0.229853, recall= 0.993139
# Minibatch Loss= 0.703730
# Tarin Iter 500, auc= 0.856860, fmeasure_max= 0.796460, precision= 0.826377, recall= 0.768634
# Train Random guess:  , auc= 0.267211fmeasure_max= 0.403261, precision= 0.252652, recall= 0.998447
# Validation Iter 500, auc= 0.850283, fmeasure_max= 0.784000, precision= 0.813653, recall= 0.756432
# Validation Random guess:  auc= 0.217431, fmeasure_max= 0.372816, precision= 0.229757, recall= 0.987993
# Minibatch Loss= 0.652262
# Tarin Iter 600, auc= 0.803035, fmeasure_max= 0.787072, precision= 0.855372, recall= 0.728873
# Train Random guess:  , auc= 0.216032fmeasure_max= 0.364805, precision= 0.225806, recall= 0.948944
# Validation Iter 600, auc= 0.856132, fmeasure_max= 0.790378, precision= 0.791738, recall= 0.789022
# Validation Random guess:  auc= 0.250696, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.804963
# Tarin Iter 700, auc= 0.867433, fmeasure_max= 0.789765, precision= 0.760320, recall= 0.821583
# Train Random guess:  , auc= 0.286615fmeasure_max= 0.427999, precision= 0.272370, recall= 0.998561
# Validation Iter 700, auc= 0.813419, fmeasure_max= 0.767797, precision= 0.758794, recall= 0.777015
# Validation Random guess:  auc= 0.215658, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.710227
# Tarin Iter 800, auc= 0.754587, fmeasure_max= 0.745862, precision= 0.830803, recall= 0.676678
# Train Random guess:  , auc= 0.232746fmeasure_max= 0.366178, precision= 0.225595, recall= 0.971731
# Validation Iter 800, auc= 0.813532, fmeasure_max= 0.763604, precision= 0.795539, recall= 0.734134
# Validation Random guess:  auc= 0.209521, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.724746
# Tarin Iter 900, auc= 0.770391, fmeasure_max= 0.738557, precision= 0.750789, recall= 0.726718
# Train Random guess:  , auc= 0.261252fmeasure_max= 0.407846, precision= 0.256160, recall= 1.000000
# Validation Iter 900, auc= 0.830137, fmeasure_max= 0.754789, precision= 0.854664, recall= 0.675815
# Validation Random guess:  auc= 0.241099, fmeasure_max= 0.376051, precision= 0.233891, recall= 0.958834
# Minibatch Loss= 0.825349
# Tarin Iter 1000, auc= 0.857874, fmeasure_max= 0.787129, precision= 0.808475, recall= 0.766881
# Train Random guess:  , auc= 0.236080fmeasure_max= 0.392665, precision= 0.244392, recall= 0.998392
# Validation Iter 1000, auc= 0.855911, fmeasure_max= 0.766881, precision= 0.721634, recall= 0.818182
# Validation Random guess:  auc= 0.214038, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.676675
# Tarin Iter 1100, auc= 0.888839, fmeasure_max= 0.836938, precision= 0.885563, recall= 0.793375
# Train Random guess:  , auc= 0.256653fmeasure_max= 0.397368, precision= 0.247947, recall= 1.000000
# Validation Iter 1100, auc= 0.820827, fmeasure_max= 0.748784, precision= 0.709677, recall= 0.792453
# Validation Random guess:  auc= 0.213488, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.642781
# Tarin Iter 1200, auc= 0.916569, fmeasure_max= 0.850043, precision= 0.849315, recall= 0.850772
# Train Random guess:  , auc= 0.216649fmeasure_max= 0.372000, precision= 0.230865, recall= 0.957118
# Validation Iter 1200, auc= 0.847284, fmeasure_max= 0.757001, precision= 0.799618, recall= 0.718696
# Validation Random guess:  auc= 0.232317, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.561525
# Tarin Iter 1300, auc= 0.870004, fmeasure_max= 0.804281, precision= 0.841600, recall= 0.770132
# Train Random guess:  , auc= 0.255900fmeasure_max= 0.422264, precision= 0.268062, recall= 0.994143
# Validation Iter 1300, auc= 0.855657, fmeasure_max= 0.771615, precision= 0.735614, recall= 0.811321
# Validation Random guess:  auc= 0.240189, fmeasure_max= 0.372990, precision= 0.229521, recall= 0.994854
# Minibatch Loss= 0.681202
# Tarin Iter 1400, auc= 0.916064, fmeasure_max= 0.835532, precision= 0.846702, recall= 0.824653
# Train Random guess:  , auc= 0.231193fmeasure_max= 0.367581, precision= 0.225176, recall= 1.000000
# Validation Iter 1400, auc= 0.851314, fmeasure_max= 0.766488, precision= 0.797774, recall= 0.737564
# Validation Random guess:  auc= 0.225931, fmeasure_max= 0.372153, precision= 0.228887, recall= 0.994854
# Minibatch Loss= 0.552222
# Tarin Iter 1500, auc= 0.835918, fmeasure_max= 0.785371, precision= 0.827586, recall= 0.747253
# Train Random guess:  , auc= 0.211164fmeasure_max= 0.351691, precision= 0.213365, recall= 1.000000
# Validation Iter 1500, auc= 0.841958, fmeasure_max= 0.755413, precision= 0.709337, recall= 0.807890
# Validation Random guess:  auc= 0.231544, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.627702
# Tarin Iter 1600, auc= 0.855845, fmeasure_max= 0.813258, precision= 0.842546, recall= 0.785937
# Train Random guess:  , auc= 0.258921fmeasure_max= 0.401786, precision= 0.252404, recall= 0.984375
# Validation Iter 1600, auc= 0.855041, fmeasure_max= 0.785592, precision= 0.785592, recall= 0.785592
# Validation Random guess:  auc= 0.247257, fmeasure_max= 0.371300, precision= 0.228515, recall= 0.989708
# Minibatch Loss= 0.650155
# Tarin Iter 1700, auc= 0.849664, fmeasure_max= 0.800327, precision= 0.797716, recall= 0.802956
# Train Random guess:  , auc= 0.230308fmeasure_max= 0.384789, precision= 0.239374, recall= 0.980296
# Validation Iter 1700, auc= 0.854551, fmeasure_max= 0.782334, precision= 0.724088, recall= 0.850772
# Validation Random guess:  auc= 0.231273, fmeasure_max= 0.372123, precision= 0.229416, recall= 0.984563
# Minibatch Loss= 0.640747
# Tarin Iter 1800, auc= 0.884154, fmeasure_max= 0.834401, precision= 0.895874, recall= 0.780822
# Train Random guess:  , auc= 0.230953fmeasure_max= 0.374231, precision= 0.230739, recall= 0.989726
# Validation Iter 1800, auc= 0.856177, fmeasure_max= 0.756235, precision= 0.712121, recall= 0.806175
# Validation Random guess:  auc= 0.220812, fmeasure_max= 0.371227, precision= 0.228368, recall= 0.991424
# Minibatch Loss= 0.658102
# Tarin Iter 1900, auc= 0.912904, fmeasure_max= 0.841943, precision= 0.882068, recall= 0.805310
# Train Random guess:  , auc= 0.261430fmeasure_max= 0.418906, precision= 0.264947, recall= 1.000000
# Validation Iter 1900, auc= 0.850685, fmeasure_max= 0.756195, precision= 0.708084, recall= 0.811321
# Validation Random guess:  auc= 0.226659, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.767380
# Tarin Iter 2000, auc= 0.843476, fmeasure_max= 0.766246, precision= 0.821206, recall= 0.718182
# Train Random guess:  , auc= 0.210737fmeasure_max= 0.355716, precision= 0.216940, recall= 0.987273
# Validation Iter 2000, auc= 0.855709, fmeasure_max= 0.775510, precision= 0.768971, recall= 0.782161
# Validation Random guess:  auc= 0.246820, fmeasure_max= 0.372904, precision= 0.231763, recall= 0.953688
# Minibatch Loss= 0.626152
# Tarin Iter 2100, auc= 0.919476, fmeasure_max= 0.856509, precision= 0.841570, recall= 0.871988
# Train Random guess:  , auc= 0.254405fmeasure_max= 0.412442, precision= 0.259898, recall= 0.998494
# Validation Iter 2100, auc= 0.864409, fmeasure_max= 0.790336, precision= 0.795139, recall= 0.785592
# Validation Random guess:  auc= 0.234142, fmeasure_max= 0.373910, precision= 0.234676, recall= 0.919383
# Minibatch Loss= 0.659859
# Tarin Iter 2200, auc= 0.899325, fmeasure_max= 0.833467, precision= 0.836834, recall= 0.830128
# Train Random guess:  , auc= 0.238609fmeasure_max= 0.393319, precision= 0.244802, recall= 1.000000
# Validation Iter 2200, auc= 0.844839, fmeasure_max= 0.773403, precision= 0.789286, recall= 0.758148
# Validation Random guess:  auc= 0.226004, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.589676
# Tarin Iter 2300, auc= 0.915272, fmeasure_max= 0.858917, precision= 0.872072, recall= 0.846154
# Train Random guess:  , auc= 0.226890fmeasure_max= 0.365440, precision= 0.223658, recall= 0.998252
# Validation Iter 2300, auc= 0.854323, fmeasure_max= 0.786632, precision= 0.785959, recall= 0.787307
# Validation Random guess:  auc= 0.213047, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.568222
# Tarin Iter 2400, auc= 0.906585, fmeasure_max= 0.809192, precision= 0.800275, recall= 0.818310
# Train Random guess:  , auc= 0.277185fmeasure_max= 0.434889, precision= 0.278083, recall= 0.997183
# Validation Iter 2400, auc= 0.866587, fmeasure_max= 0.778662, precision= 0.726597, recall= 0.838765
# Validation Random guess:  auc= 0.220701, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.682873
# Tarin Iter 2500, auc= 0.951573, fmeasure_max= 0.877049, precision= 0.879934, recall= 0.874183
# Train Random guess:  , auc= 0.242348fmeasure_max= 0.385876, precision= 0.239063, recall= 1.000000
# Validation Iter 2500, auc= 0.869618, fmeasure_max= 0.792130, precision= 0.790102, recall= 0.794168
# Validation Random guess:  auc= 0.231821, fmeasure_max= 0.374227, precision= 0.230924, recall= 0.986278
# Minibatch Loss= 0.499338
# Tarin Iter 2600, auc= 0.947896, fmeasure_max= 0.870000, precision= 0.843023, recall= 0.898760
# Train Random guess:  , auc= 0.192626fmeasure_max= 0.320027, precision= 0.191343, recall= 0.977273
# Validation Iter 2600, auc= 0.873002, fmeasure_max= 0.797353, precision= 0.769968, recall= 0.826758
# Validation Random guess:  auc= 0.236180, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.462550
# Tarin Iter 2700, auc= 0.921703, fmeasure_max= 0.855769, precision= 0.838041, recall= 0.874263
# Train Random guess:  , auc= 0.188621fmeasure_max= 0.331704, precision= 0.198828, recall= 1.000000
# Validation Iter 2700, auc= 0.865868, fmeasure_max= 0.787004, precision= 0.830476, recall= 0.747856
# Validation Random guess:  auc= 0.224326, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.507229
# Tarin Iter 2800, auc= 0.912447, fmeasure_max= 0.835616, precision= 0.838900, recall= 0.832359
# Train Random guess:  , auc= 0.195003fmeasure_max= 0.334755, precision= 0.201263, recall= 0.994152
# Validation Iter 2800, auc= 0.888091, fmeasure_max= 0.817276, precision= 0.792271, recall= 0.843911
# Validation Random guess:  auc= 0.232622, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.494545
# Tarin Iter 2900, auc= 0.932899, fmeasure_max= 0.859425, precision= 0.855326, recall= 0.863563
# Train Random guess:  , auc= 0.233570fmeasure_max= 0.391455, precision= 0.243359, recall= 1.000000
# Validation Iter 2900, auc= 0.886286, fmeasure_max= 0.816901, precision= 0.790064, recall= 0.845626
# Validation Random guess:  auc= 0.226960, fmeasure_max= 0.371795, precision= 0.228616, recall= 0.994854
# Minibatch Loss= 0.510431
# Tarin Iter 3000, auc= 0.933338, fmeasure_max= 0.860978, precision= 0.882122, recall= 0.840824
# Train Random guess:  , auc= 0.210696fmeasure_max= 0.346016, precision= 0.209366, recall= 0.996255
# Validation Iter 3000, auc= 0.887907, fmeasure_max= 0.799314, precision= 0.799314, recall= 0.799314
# Validation Random guess:  auc= 0.226815, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.497128
# Tarin Iter 3100, auc= 0.918645, fmeasure_max= 0.828666, precision= 0.800955, recall= 0.858362
# Train Random guess:  , auc= 0.228467fmeasure_max= 0.372537, precision= 0.228906, recall= 1.000000
# Validation Iter 3100, auc= 0.878313, fmeasure_max= 0.818339, precision= 0.825480, recall= 0.811321
# Validation Random guess:  auc= 0.230374, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.532123
# Tarin Iter 3200, auc= 0.931611, fmeasure_max= 0.850044, precision= 0.888683, recall= 0.814626
# Train Random guess:  , auc= 0.232900fmeasure_max= 0.374165, precision= 0.230137, recall= 1.000000
# Validation Iter 3200, auc= 0.879578, fmeasure_max= 0.814450, precision= 0.781102, recall= 0.850772
# Validation Random guess:  auc= 0.217994, fmeasure_max= 0.373569, precision= 0.230800, recall= 0.979417
# Minibatch Loss= 0.492310
# Tarin Iter 3300, auc= 0.951394, fmeasure_max= 0.888696, precision= 0.893357, recall= 0.884083
# Train Random guess:  , auc= 0.226762fmeasure_max= 0.368932, precision= 0.226911, recall= 0.986159
# Validation Iter 3300, auc= 0.872807, fmeasure_max= 0.786765, precision= 0.847525, recall= 0.734134
# Validation Random guess:  auc= 0.215675, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.492605
# Tarin Iter 3400, auc= 0.940540, fmeasure_max= 0.872629, precision= 0.901119, recall= 0.845884
# Train Random guess:  , auc= 0.221709fmeasure_max= 0.367159, precision= 0.225950, recall= 0.978984
# Validation Iter 3400, auc= 0.870723, fmeasure_max= 0.790353, precision= 0.860606, recall= 0.730703
# Validation Random guess:  auc= 0.234923, fmeasure_max= 0.372472, precision= 0.229964, recall= 0.979417
# Minibatch Loss= 0.501660
# Tarin Iter 3500, auc= 0.869543, fmeasure_max= 0.809475, precision= 0.775148, recall= 0.846983
# Train Random guess:  , auc= 0.188174fmeasure_max= 0.306980, precision= 0.181321, recall= 1.000000
# Validation Iter 3500, auc= 0.878485, fmeasure_max= 0.807296, precision= 0.750737, recall= 0.873070
# Validation Random guess:  auc= 0.230928, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.479126
# Tarin Iter 3600, auc= 0.918419, fmeasure_max= 0.851100, precision= 0.839733, recall= 0.862779
# Train Random guess:  , auc= 0.231379fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Validation Iter 3600, auc= 0.868386, fmeasure_max= 0.808163, precision= 0.771028, recall= 0.849057
# Validation Random guess:  auc= 0.236141, fmeasure_max= 0.374539, precision= 0.232723, recall= 0.958834
# Minibatch Loss= 0.496214
# Tarin Iter 3700, auc= 0.906453, fmeasure_max= 0.823806, precision= 0.858075, recall= 0.792169
# Train Random guess:  , auc= 0.258001fmeasure_max= 0.412422, precision= 0.259781, recall= 1.000000
# Validation Iter 3700, auc= 0.878096, fmeasure_max= 0.809098, precision= 0.768519, recall= 0.854202
# Validation Random guess:  auc= 0.229511, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.605554
# Tarin Iter 3800, auc= 0.915486, fmeasure_max= 0.854560, precision= 0.832000, recall= 0.878378
# Train Random guess:  , auc= 0.231655fmeasure_max= 0.378116, precision= 0.233881, recall= 0.986486
# Validation Iter 3800, auc= 0.872169, fmeasure_max= 0.805743, precision= 0.793677, recall= 0.818182
# Validation Random guess:  auc= 0.225086, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.535650
# Tarin Iter 3900, auc= 0.939490, fmeasure_max= 0.860534, precision= 0.880121, recall= 0.841800
# Train Random guess:  , auc= 0.271360fmeasure_max= 0.424392, precision= 0.269351, recall= 1.000000
# Validation Iter 3900, auc= 0.877440, fmeasure_max= 0.807857, precision= 0.804422, recall= 0.811321
# Validation Random guess:  auc= 0.221584, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.578245
# Tarin Iter 4000, auc= 0.938853, fmeasure_max= 0.858553, precision= 0.889267, recall= 0.829889
# Train Random guess:  , auc= 0.241149fmeasure_max= 0.394969, precision= 0.246178, recall= 0.998410
# Validation Iter 4000, auc= 0.873567, fmeasure_max= 0.784615, precision= 0.781942, recall= 0.787307
# Validation Random guess:  auc= 0.227192, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.516743
# Tarin Iter 4100, auc= 0.951855, fmeasure_max= 0.882399, precision= 0.913399, recall= 0.853435
# Train Random guess:  , auc= 0.273591fmeasure_max= 0.408819, precision= 0.257540, recall= 0.990840
# Validation Iter 4100, auc= 0.880156, fmeasure_max= 0.800330, precision= 0.771065, recall= 0.831904
# Validation Random guess:  auc= 0.232479, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.514939
# Tarin Iter 4200, auc= 0.880802, fmeasure_max= 0.802956, precision= 0.746565, recall= 0.868561
# Train Random guess:  , auc= 0.214367fmeasure_max= 0.361812, precision= 0.221211, recall= 0.992895
# Validation Iter 4200, auc= 0.881325, fmeasure_max= 0.793781, precision= 0.758998, recall= 0.831904
# Validation Random guess:  auc= 0.234006, fmeasure_max= 0.373494, precision= 0.235373, recall= 0.903945
# Minibatch Loss= 0.573605
# Tarin Iter 4300, auc= 0.912265, fmeasure_max= 0.826087, precision= 0.809199, recall= 0.843694
# Train Random guess:  , auc= 0.229497fmeasure_max= 0.363880, precision= 0.224145, recall= 0.966252
# Validation Iter 4300, auc= 0.875846, fmeasure_max= 0.801633, precision= 0.764798, recall= 0.842196
# Validation Random guess:  auc= 0.236581, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.566085
# Tarin Iter 4400, auc= 0.928266, fmeasure_max= 0.866079, precision= 0.850394, recall= 0.882353
# Train Random guess:  , auc= 0.237765fmeasure_max= 0.386680, precision= 0.241032, recall= 0.977124
# Validation Iter 4400, auc= 0.899074, fmeasure_max= 0.809441, precision= 0.825312, recall= 0.794168
# Validation Random guess:  auc= 0.224797, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.528761
# Tarin Iter 4500, auc= 0.937993, fmeasure_max= 0.860377, precision= 0.860377, recall= 0.860377
# Train Random guess:  , auc= 0.225678fmeasure_max= 0.343526, precision= 0.207547, recall= 0.996226
# Validation Iter 4500, auc= 0.902994, fmeasure_max= 0.826733, precision= 0.796502, recall= 0.859348
# Validation Random guess:  auc= 0.213154, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.463214
# Tarin Iter 4600, auc= 0.946809, fmeasure_max= 0.895582, precision= 0.921488, recall= 0.871094
# Train Random guess:  , auc= 0.207889fmeasure_max= 0.333333, precision= 0.200000, recall= 1.000000
# Validation Iter 4600, auc= 0.905076, fmeasure_max= 0.827891, precision= 0.852727, recall= 0.804460
# Validation Random guess:  auc= 0.224898, fmeasure_max= 0.371994, precision= 0.234298, recall= 0.902230
# Minibatch Loss= 0.408988
# Tarin Iter 4700, auc= 0.903607, fmeasure_max= 0.842105, precision= 0.826620, recall= 0.858182
# Train Random guess:  , auc= 0.205459fmeasure_max= 0.354702, precision= 0.216013, recall= 0.990909
# Validation Iter 4700, auc= 0.898581, fmeasure_max= 0.814414, precision= 0.857685, recall= 0.775300
# Validation Random guess:  auc= 0.225997, fmeasure_max= 0.372838, precision= 0.229224, recall= 0.998285
# Minibatch Loss= 0.527184
# Tarin Iter 4800, auc= 0.917968, fmeasure_max= 0.851823, precision= 0.831818, recall= 0.872814
# Train Random guess:  , auc= 0.238348fmeasure_max= 0.395590, precision= 0.248473, recall= 0.969793
# Validation Iter 4800, auc= 0.908085, fmeasure_max= 0.836855, precision= 0.825000, recall= 0.849057
# Validation Random guess:  auc= 0.224825, fmeasure_max= 0.372846, precision= 0.233290, recall= 0.927959
# Minibatch Loss= 0.544061
# Tarin Iter 4900, auc= 0.924496, fmeasure_max= 0.857398, precision= 0.835069, recall= 0.880952
# Train Random guess:  , auc= 0.213531fmeasure_max= 0.351954, precision= 0.213642, recall= 0.998168
# Validation Iter 4900, auc= 0.899535, fmeasure_max= 0.825658, precision= 0.793049, recall= 0.861063
# Validation Random guess:  auc= 0.243223, fmeasure_max= 0.375665, precision= 0.232990, recall= 0.969125
# Minibatch Loss= 0.496403
# Tarin Iter 5000, auc= 0.940118, fmeasure_max= 0.853621, precision= 0.903752, recall= 0.808759
# Train Random guess:  , auc= 0.270765fmeasure_max= 0.423808, precision= 0.269414, recall= 0.992701
# Validation Iter 5000, auc= 0.897440, fmeasure_max= 0.813749, precision= 0.761976, recall= 0.873070
# Validation Random guess:  auc= 0.232241, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.575096
# Tarin Iter 5100, auc= 0.945633, fmeasure_max= 0.883642, precision= 0.873333, recall= 0.894198
# Train Random guess:  , auc= 0.229194fmeasure_max= 0.373402, precision= 0.229740, recall= 0.996587
# Validation Iter 5100, auc= 0.896092, fmeasure_max= 0.812030, precision= 0.791531, recall= 0.833619
# Validation Random guess:  auc= 0.235799, fmeasure_max= 0.371291, precision= 0.232397, recall= 0.922813
# Minibatch Loss= 0.481992
# Tarin Iter 5200, auc= 0.933180, fmeasure_max= 0.897803, precision= 0.907336, recall= 0.888469
# Train Random guess:  , auc= 0.211441fmeasure_max= 0.349294, precision= 0.213564, recall= 0.958412
# Validation Iter 5200, auc= 0.895598, fmeasure_max= 0.818713, precision= 0.798046, recall= 0.840480
# Validation Random guess:  auc= 0.233870, fmeasure_max= 0.372745, precision= 0.231439, recall= 0.957118
# Minibatch Loss= 0.393759
# Tarin Iter 5300, auc= 0.922897, fmeasure_max= 0.840753, precision= 0.861404, recall= 0.821070
# Train Random guess:  , auc= 0.228153fmeasure_max= 0.380435, precision= 0.235178, recall= 0.994983
# Validation Iter 5300, auc= 0.875260, fmeasure_max= 0.807432, precision= 0.795341, recall= 0.819897
# Validation Random guess:  auc= 0.242503, fmeasure_max= 0.372123, precision= 0.229416, recall= 0.984563
# Minibatch Loss= 0.588880
# Tarin Iter 5400, auc= 0.918575, fmeasure_max= 0.858639, precision= 0.839590, recall= 0.878571
# Train Random guess:  , auc= 0.217547fmeasure_max= 0.358974, precision= 0.218750, recall= 1.000000
# Validation Iter 5400, auc= 0.910989, fmeasure_max= 0.838223, precision= 0.819672, recall= 0.857633
# Validation Random guess:  auc= 0.226895, fmeasure_max= 0.373150, precision= 0.233419, recall= 0.929674
# Minibatch Loss= 0.475991
# Tarin Iter 5500, auc= 0.955910, fmeasure_max= 0.890071, precision= 0.888496, recall= 0.891652
# Train Random guess:  , auc= 0.222951fmeasure_max= 0.362641, precision= 0.221479, recall= 1.000000
# Validation Iter 5500, auc= 0.891468, fmeasure_max= 0.823938, precision= 0.833333, recall= 0.814751
# Validation Random guess:  auc= 0.238506, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.433304
# Tarin Iter 5600, auc= 0.923788, fmeasure_max= 0.848101, precision= 0.873371, recall= 0.824253
# Train Random guess:  , auc= 0.221944fmeasure_max= 0.364401, precision= 0.223324, recall= 0.989455
# Validation Iter 5600, auc= 0.891889, fmeasure_max= 0.802653, precision= 0.776886, recall= 0.830189
# Validation Random guess:  auc= 0.218272, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.510756
# Tarin Iter 5700, auc= 0.942748, fmeasure_max= 0.869010, precision= 0.900662, recall= 0.839506
# Train Random guess:  , auc= 0.251598fmeasure_max= 0.404621, precision= 0.253620, recall= 1.000000
# Validation Iter 5700, auc= 0.900089, fmeasure_max= 0.824313, precision= 0.800971, recall= 0.849057
# Validation Random guess:  auc= 0.224137, fmeasure_max= 0.371762, precision= 0.229142, recall= 0.984563
# Minibatch Loss= 0.512402
# Tarin Iter 5800, auc= 0.947852, fmeasure_max= 0.884334, precision= 0.848315, recall= 0.923547
# Train Random guess:  , auc= 0.257931fmeasure_max= 0.408548, precision= 0.257120, recall= 0.993884
# Validation Iter 5800, auc= 0.881648, fmeasure_max= 0.804858, precision= 0.762270, recall= 0.852487
# Validation Random guess:  auc= 0.238995, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.435934
# Tarin Iter 5900, auc= 0.960231, fmeasure_max= 0.894500, precision= 0.901818, recall= 0.887299
# Train Random guess:  , auc= 0.222596fmeasure_max= 0.361779, precision= 0.221729, recall= 0.982111
# Validation Iter 5900, auc= 0.893644, fmeasure_max= 0.810985, precision= 0.766412, recall= 0.861063
# Validation Random guess:  auc= 0.226692, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.423473
# Tarin Iter 6000, auc= 0.918220, fmeasure_max= 0.848329, precision= 0.811475, recall= 0.888689
# Train Random guess:  , auc= 0.229568fmeasure_max= 0.357510, precision= 0.217663, recall= 1.000000
# Validation Iter 6000, auc= 0.887313, fmeasure_max= 0.812968, precision= 0.788710, recall= 0.838765
# Validation Random guess:  auc= 0.229172, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.487182
# Tarin Iter 6100, auc= 0.946306, fmeasure_max= 0.876016, precision= 0.851779, recall= 0.901674
# Train Random guess:  , auc= 0.193255fmeasure_max= 0.315685, precision= 0.187500, recall= 0.997908
# Validation Iter 6100, auc= 0.869216, fmeasure_max= 0.798283, precision= 0.798969, recall= 0.797599
# Validation Random guess:  auc= 0.237819, fmeasure_max= 0.372213, precision= 0.229299, recall= 0.987993
# Minibatch Loss= 0.407845
# Tarin Iter 6200, auc= 0.943161, fmeasure_max= 0.868671, precision= 0.867299, recall= 0.870048
# Train Random guess:  , auc= 0.255686fmeasure_max= 0.395859, precision= 0.246774, recall= 1.000000
# Validation Iter 6200, auc= 0.882141, fmeasure_max= 0.800000, precision= 0.790620, recall= 0.809605
# Validation Random guess:  auc= 0.225243, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.553630
# Tarin Iter 6300, auc= 0.894565, fmeasure_max= 0.806394, precision= 0.864762, recall= 0.755408
# Train Random guess:  , auc= 0.229852fmeasure_max= 0.382211, precision= 0.237010, recall= 0.986689
# Validation Iter 6300, auc= 0.900915, fmeasure_max= 0.835052, precision= 0.836489, recall= 0.833619
# Validation Random guess:  auc= 0.238044, fmeasure_max= 0.371055, precision= 0.227878, recall= 0.998285
# Minibatch Loss= 0.558226
# Tarin Iter 6400, auc= 0.951479, fmeasure_max= 0.893546, precision= 0.889816, recall= 0.897306
# Train Random guess:  , auc= 0.231319fmeasure_max= 0.377023, precision= 0.232303, recall= 1.000000
# Validation Iter 6400, auc= 0.892253, fmeasure_max= 0.826623, precision= 0.793375, recall= 0.862779
# Validation Random guess:  auc= 0.223656, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.469858
# Tarin Iter 6500, auc= 0.956105, fmeasure_max= 0.878475, precision= 0.856037, recall= 0.902121
# Train Random guess:  , auc= 0.259909fmeasure_max= 0.386789, precision= 0.240142, recall= 0.993475
# Validation Iter 6500, auc= 0.886208, fmeasure_max= 0.813559, precision= 0.847584, recall= 0.782161
# Validation Random guess:  auc= 0.239472, fmeasure_max= 0.374257, precision= 0.231712, recall= 0.972556
# Minibatch Loss= 0.478731
# Tarin Iter 6600, auc= 0.952550, fmeasure_max= 0.887900, precision= 0.915596, recall= 0.861831
# Train Random guess:  , auc= 0.227849fmeasure_max= 0.372063, precision= 0.228639, recall= 0.998273
# Validation Iter 6600, auc= 0.887654, fmeasure_max= 0.810087, precision= 0.749271, recall= 0.881647
# Validation Random guess:  auc= 0.230890, fmeasure_max= 0.372631, precision= 0.229249, recall= 0.994854
# Minibatch Loss= 0.460128
# Tarin Iter 6700, auc= 0.938601, fmeasure_max= 0.854633, precision= 0.837246, recall= 0.872757
# Train Random guess:  , auc= 0.236459fmeasure_max= 0.387097, precision= 0.241255, recall= 0.978793
# Validation Iter 6700, auc= 0.893267, fmeasure_max= 0.824979, precision= 0.791798, recall= 0.861063
# Validation Random guess:  auc= 0.231483, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.490087
# Tarin Iter 6800, auc= 0.939250, fmeasure_max= 0.865533, precision= 0.886076, recall= 0.845921
# Train Random guess:  , auc= 0.253806fmeasure_max= 0.411308, precision= 0.258897, recall= 1.000000
# Validation Iter 6800, auc= 0.889978, fmeasure_max= 0.815372, precision= 0.794788, recall= 0.837050
# Validation Random guess:  auc= 0.233165, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.537315
# Tarin Iter 6900, auc= 0.930125, fmeasure_max= 0.860063, precision= 0.835115, recall= 0.886548
# Train Random guess:  , auc= 0.244289fmeasure_max= 0.391021, precision= 0.244607, recall= 0.974068
# Validation Iter 6900, auc= 0.888057, fmeasure_max= 0.826712, precision= 0.815000, recall= 0.838765
# Validation Random guess:  auc= 0.234355, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.523577
# Tarin Iter 7000, auc= 0.960265, fmeasure_max= 0.898672, precision= 0.868919, recall= 0.930535
# Train Random guess:  , auc= 0.258993fmeasure_max= 0.426658, precision= 0.271825, recall= 0.991317
# Validation Iter 7000, auc= 0.882571, fmeasure_max= 0.816291, precision= 0.824869, recall= 0.807890
# Validation Random guess:  auc= 0.218915, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.503804
# Tarin Iter 7100, auc= 0.957680, fmeasure_max= 0.887295, precision= 0.896480, recall= 0.878296
# Train Random guess:  , auc= 0.210838fmeasure_max= 0.326909, precision= 0.198354, recall= 0.929006
# Validation Iter 7100, auc= 0.895984, fmeasure_max= 0.825234, precision= 0.820339, recall= 0.830189
# Validation Random guess:  auc= 0.224488, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.408700
# Tarin Iter 7200, auc= 0.940977, fmeasure_max= 0.865306, precision= 0.833333, recall= 0.899830
# Train Random guess:  , auc= 0.231117fmeasure_max= 0.374682, precision= 0.230528, recall= 1.000000
# Validation Iter 7200, auc= 0.881182, fmeasure_max= 0.802316, precision= 0.774760, recall= 0.831904
# Validation Random guess:  auc= 0.239856, fmeasure_max= 0.371733, precision= 0.228935, recall= 0.987993
# Minibatch Loss= 0.455864
# Tarin Iter 7300, auc= 0.927895, fmeasure_max= 0.848885, precision= 0.839869, recall= 0.858097
# Train Random guess:  , auc= 0.234645fmeasure_max= 0.380128, precision= 0.235224, recall= 0.989983
# Validation Iter 7300, auc= 0.893470, fmeasure_max= 0.830093, precision= 0.818333, recall= 0.842196
# Validation Random guess:  auc= 0.229773, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.478572
# Tarin Iter 7400, auc= 0.942569, fmeasure_max= 0.864293, precision= 0.825368, recall= 0.907071
# Train Random guess:  , auc= 0.189509fmeasure_max= 0.327112, precision= 0.196574, recall= 0.973737
# Validation Iter 7400, auc= 0.893302, fmeasure_max= 0.823926, precision= 0.809603, recall= 0.838765
# Validation Random guess:  auc= 0.233051, fmeasure_max= 0.371641, precision= 0.229050, recall= 0.984563
# Minibatch Loss= 0.421685
# Tarin Iter 7500, auc= 0.938079, fmeasure_max= 0.861287, precision= 0.896226, recall= 0.828970
# Train Random guess:  , auc= 0.220020fmeasure_max= 0.367080, precision= 0.225793, recall= 0.980803
# Validation Iter 7500, auc= 0.871819, fmeasure_max= 0.794702, precision= 0.768000, recall= 0.823328
# Validation Random guess:  auc= 0.218260, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.471463
# Tarin Iter 7600, auc= 0.952753, fmeasure_max= 0.881013, precision= 0.859967, recall= 0.903114
# Train Random guess:  , auc= 0.230116fmeasure_max= 0.369635, precision= 0.226808, recall= 0.998270
# Validation Iter 7600, auc= 0.901279, fmeasure_max= 0.829897, precision= 0.831325, recall= 0.828473
# Validation Random guess:  auc= 0.226547, fmeasure_max= 0.371969, precision= 0.230643, recall= 0.960549
# Minibatch Loss= 0.422435
# Tarin Iter 7700, auc= 0.959052, fmeasure_max= 0.889930, precision= 0.861027, recall= 0.920840
# Train Random guess:  , auc= 0.226213fmeasure_max= 0.390892, precision= 0.243020, recall= 0.998384
# Validation Iter 7700, auc= 0.895508, fmeasure_max= 0.829185, precision= 0.829897, recall= 0.828473
# Validation Random guess:  auc= 0.225955, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.475775
# Tarin Iter 7800, auc= 0.937274, fmeasure_max= 0.863787, precision= 0.891938, recall= 0.837359
# Train Random guess:  , auc= 0.252339fmeasure_max= 0.391304, precision= 0.243243, recall= 1.000000
# Validation Iter 7800, auc= 0.895052, fmeasure_max= 0.816901, precision= 0.790064, recall= 0.845626
# Validation Random guess:  auc= 0.242646, fmeasure_max= 0.374225, precision= 0.234153, recall= 0.931389
# Minibatch Loss= 0.482944
# Tarin Iter 7900, auc= 0.973206, fmeasure_max= 0.915942, precision= 0.919942, recall= 0.911977
# Train Random guess:  , auc= 0.257751fmeasure_max= 0.428949, precision= 0.278183, recall= 0.936508
# Validation Iter 7900, auc= 0.891130, fmeasure_max= 0.816853, precision= 0.818966, recall= 0.814751
# Validation Random guess:  auc= 0.234058, fmeasure_max= 0.373218, precision= 0.231306, recall= 0.965695
# Minibatch Loss= 0.500134
# Tarin Iter 8000, auc= 0.937446, fmeasure_max= 0.855196, precision= 0.814935, recall= 0.899642
# Train Random guess:  , auc= 0.231554fmeasure_max= 0.358842, precision= 0.218652, recall= 1.000000
# Validation Iter 8000, auc= 0.867903, fmeasure_max= 0.794168, precision= 0.794168, recall= 0.794168
# Validation Random guess:  auc= 0.223586, fmeasure_max= 0.371740, precision= 0.230172, recall= 0.965695
# Minibatch Loss= 0.465773
# Tarin Iter 8100, auc= 0.956009, fmeasure_max= 0.891271, precision= 0.884498, recall= 0.898148
# Train Random guess:  , auc= 0.244701fmeasure_max= 0.404330, precision= 0.254713, recall= 0.979938
# Validation Iter 8100, auc= 0.883569, fmeasure_max= 0.815961, precision= 0.776744, recall= 0.859348
# Validation Random guess:  auc= 0.243238, fmeasure_max= 0.372793, precision= 0.230303, recall= 0.977702
# Minibatch Loss= 0.473435
# Tarin Iter 8200, auc= 0.957180, fmeasure_max= 0.889394, precision= 0.844604, recall= 0.939200
# Train Random guess:  , auc= 0.251617fmeasure_max= 0.393060, precision= 0.244794, recall= 0.996800
# Validation Iter 8200, auc= 0.887531, fmeasure_max= 0.807018, precision= 0.874000, recall= 0.749571
# Validation Random guess:  auc= 0.237660, fmeasure_max= 0.374381, precision= 0.231807, recall= 0.972556
# Minibatch Loss= 0.459478
# Tarin Iter 8300, auc= 0.972843, fmeasure_max= 0.918530, precision= 0.915605, recall= 0.921474
# Train Random guess:  , auc= 0.249216fmeasure_max= 0.392329, precision= 0.244036, recall= 1.000000
# Validation Iter 8300, auc= 0.889943, fmeasure_max= 0.820771, precision= 0.801964, recall= 0.840480
# Validation Random guess:  auc= 0.232595, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.432389
# Tarin Iter 8400, auc= 0.947502, fmeasure_max= 0.867610, precision= 0.878583, recall= 0.856908
# Train Random guess:  , auc= 0.235453fmeasure_max= 0.384935, precision= 0.238812, recall= 0.991776
# Validation Iter 8400, auc= 0.880614, fmeasure_max= 0.821306, precision= 0.822719, recall= 0.819897
# Validation Random guess:  auc= 0.223242, fmeasure_max= 0.372555, precision= 0.229101, recall= 0.996569
# Minibatch Loss= 0.474994
# Tarin Iter 8500, auc= 0.928123, fmeasure_max= 0.844019, precision= 0.833648, recall= 0.854651
# Train Random guess:  , auc= 0.191043fmeasure_max= 0.336835, precision= 0.202767, recall= 0.994186
# Validation Iter 8500, auc= 0.882278, fmeasure_max= 0.808407, precision= 0.764526, recall= 0.857633
# Validation Random guess:  auc= 0.223193, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.466507
# Tarin Iter 8600, auc= 0.942569, fmeasure_max= 0.865823, precision= 0.823435, recall= 0.912811
# Train Random guess:  , auc= 0.230884fmeasure_max= 0.362164, precision= 0.221386, recall= 0.994662
# Validation Iter 8600, auc= 0.869912, fmeasure_max= 0.801633, precision= 0.764798, recall= 0.842196
# Validation Random guess:  auc= 0.234063, fmeasure_max= 0.374273, precision= 0.233761, recall= 0.938250
# Minibatch Loss= 0.433011
# Tarin Iter 8700, auc= 0.962608, fmeasure_max= 0.909251, precision= 0.903678, recall= 0.914894
# Train Random guess:  , auc= 0.207102fmeasure_max= 0.361120, precision= 0.220606, recall= 0.994681
# Validation Iter 8700, auc= 0.883730, fmeasure_max= 0.826733, precision= 0.796502, recall= 0.859348
# Validation Random guess:  auc= 0.242656, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.434864
# Tarin Iter 8800, auc= 0.946057, fmeasure_max= 0.872381, precision= 0.914172, recall= 0.834244
# Train Random guess:  , auc= 0.220178fmeasure_max= 0.356584, precision= 0.221583, recall= 0.912568
# Validation Iter 8800, auc= 0.886387, fmeasure_max= 0.815721, precision= 0.830961, recall= 0.801029
# Validation Random guess:  auc= 0.233752, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.434439
# Tarin Iter 8900, auc= 0.941061, fmeasure_max= 0.868460, precision= 0.881639, recall= 0.855670
# Train Random guess:  , auc= 0.270837fmeasure_max= 0.419265, precision= 0.265234, recall= 1.000000
# Validation Iter 8900, auc= 0.878179, fmeasure_max= 0.800705, precision= 0.823956, recall= 0.778731
# Validation Random guess:  auc= 0.228730, fmeasure_max= 0.371281, precision= 0.228776, recall= 0.984563
# Minibatch Loss= 0.507118
# Tarin Iter 9000, auc= 0.951190, fmeasure_max= 0.889513, precision= 0.899621, recall= 0.879630
# Train Random guess:  , auc= 0.218787fmeasure_max= 0.349885, precision= 0.212715, recall= 0.985185
# Validation Iter 9000, auc= 0.897476, fmeasure_max= 0.827883, precision= 0.830743, recall= 0.825043
# Validation Random guess:  auc= 0.231097, fmeasure_max= 0.371693, precision= 0.230234, recall= 0.963979
# Minibatch Loss= 0.393826
# Tarin Iter 9100, auc= 0.962414, fmeasure_max= 0.892226, precision= 0.889085, recall= 0.895390
# Train Random guess:  , auc= 0.221097fmeasure_max= 0.361764, precision= 0.220999, recall= 0.996454
# Validation Iter 9100, auc= 0.887526, fmeasure_max= 0.822222, precision= 0.819421, recall= 0.825043
# Validation Random guess:  auc= 0.243252, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.432350
# Tarin Iter 9200, auc= 0.963866, fmeasure_max= 0.899844, precision= 0.873860, recall= 0.927419
# Train Random guess:  , auc= 0.242372fmeasure_max= 0.390398, precision= 0.242734, recall= 0.996774
# Validation Iter 9200, auc= 0.889079, fmeasure_max= 0.822838, precision= 0.805921, recall= 0.840480
# Validation Random guess:  auc= 0.222999, fmeasure_max= 0.372848, precision= 0.231022, recall= 0.965695
# Minibatch Loss= 0.412115
# Tarin Iter 9300, auc= 0.935751, fmeasure_max= 0.864865, precision= 0.858420, recall= 0.871407
# Train Random guess:  , auc= 0.258755fmeasure_max= 0.411191, precision= 0.259524, recall= 0.989410
# Validation Iter 9300, auc= 0.896141, fmeasure_max= 0.828891, precision= 0.831034, recall= 0.826758
# Validation Random guess:  auc= 0.231014, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.561123
# Tarin Iter 9400, auc= 0.960102, fmeasure_max= 0.893309, precision= 0.898182, recall= 0.888489
# Train Random guess:  , auc= 0.222359fmeasure_max= 0.357556, precision= 0.217698, recall= 1.000000
# Validation Iter 9400, auc= 0.882956, fmeasure_max= 0.821918, precision= 0.820513, recall= 0.823328
# Validation Random guess:  auc= 0.248875, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.452784
# Tarin Iter 9500, auc= 0.959167, fmeasure_max= 0.896552, precision= 0.856287, recall= 0.940789
# Train Random guess:  , auc= 0.237977fmeasure_max= 0.385965, precision= 0.239414, recall= 0.995066
# Validation Iter 9500, auc= 0.890069, fmeasure_max= 0.823123, precision= 0.828125, recall= 0.818182
# Validation Random guess:  auc= 0.234345, fmeasure_max= 0.371928, precision= 0.229175, recall= 0.986278
# Minibatch Loss= 0.421941
# Tarin Iter 9600, auc= 0.949796, fmeasure_max= 0.883997, precision= 0.859967, recall= 0.909408
# Train Random guess:  , auc= 0.221058fmeasure_max= 0.366549, precision= 0.224578, recall= 0.996516
# Validation Iter 9600, auc= 0.877584, fmeasure_max= 0.815700, precision= 0.811545, recall= 0.819897
# Validation Random guess:  auc= 0.232177, fmeasure_max= 0.373576, precision= 0.230522, recall= 0.984563
# Minibatch Loss= 0.416994
# Tarin Iter 9700, auc= 0.942841, fmeasure_max= 0.865417, precision= 0.894366, recall= 0.838284
# Train Random guess:  , auc= 0.230157fmeasure_max= 0.382817, precision= 0.236719, recall= 1.000000
# Validation Iter 9700, auc= 0.879831, fmeasure_max= 0.824605, precision= 0.800000, recall= 0.850772
# Validation Random guess:  auc= 0.222644, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.498627
# Tarin Iter 9800, auc= 0.973821, fmeasure_max= 0.921175, precision= 0.937107, recall= 0.905775
# Train Random guess:  , auc= 0.251283fmeasure_max= 0.411707, precision= 0.261895, recall= 0.962006
# Validation Iter 9800, auc= 0.882563, fmeasure_max= 0.823428, precision= 0.826990, recall= 0.819897
# Validation Random guess:  auc= 0.241248, fmeasure_max= 0.374185, precision= 0.230986, recall= 0.984563
# Minibatch Loss= 0.465674
# Tarin Iter 9900, auc= 0.954779, fmeasure_max= 0.899286, precision= 0.866972, recall= 0.934102
# Train Random guess:  , auc= 0.251302fmeasure_max= 0.384421, precision= 0.237946, recall= 1.000000
# Validation Iter 9900, auc= 0.902120, fmeasure_max= 0.835796, precision= 0.801575, recall= 0.873070
# Validation Random guess:  auc= 0.217095, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.457508
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.889948 F1_max = 0.810155 prec = 0.825789 rec = 0.795101
# Test Random guess: auc= 0.233900 fmeasure_max= 0.375840 , precision= 0.231569 , recall= 0.996959

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
