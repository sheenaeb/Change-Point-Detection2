# %%
# useing this variable for saving models and summaries
exp_name = "CNN1013"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [32, 1, 1, 1, 1, 1]
weights_shape = [[9, n_variables, 32],
                 [9, 32, 32],
                 [9, 32, 32],
                 [9, 32, 32],
                 [9, 32, 32],
                 [9, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.206110, fmeasure_max= 0.378971, precision= 0.241562, recall= 0.878947
# Train Random guess:  , auc= 0.224114fmeasure_max= 0.364744, precision= 0.223137, recall= 0.998246
# Validation Iter 0, auc= 0.209592, fmeasure_max= 0.399572, precision= 0.252252, recall= 0.960549
# Validation Random guess:  auc= 0.224980, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 1.048825
# Tarin Iter 100, auc= 0.648143, fmeasure_max= 0.667848, precision= 0.669627, recall= 0.666078
# Train Random guess:  , auc= 0.225825fmeasure_max= 0.362937, precision= 0.221700, recall= 1.000000
# Validation Iter 100, auc= 0.652533, fmeasure_max= 0.680815, precision= 0.673950, recall= 0.687822
# Validation Random guess:  auc= 0.228236, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.847487
# Tarin Iter 200, auc= 0.821246, fmeasure_max= 0.797945, precision= 0.789831, recall= 0.806228
# Train Random guess:  , auc= 0.236451fmeasure_max= 0.369931, precision= 0.228513, recall= 0.970588
# Validation Iter 200, auc= 0.818690, fmeasure_max= 0.792208, precision= 0.751926, recall= 0.837050
# Validation Random guess:  auc= 0.242962, fmeasure_max= 0.372719, precision= 0.229134, recall= 0.998285
# Minibatch Loss= 0.641007
# Tarin Iter 300, auc= 0.913100, fmeasure_max= 0.845290, precision= 0.903882, recall= 0.793831
# Train Random guess:  , auc= 0.244002fmeasure_max= 0.387909, precision= 0.240625, recall= 1.000000
# Validation Iter 300, auc= 0.818183, fmeasure_max= 0.779461, precision= 0.765289, recall= 0.794168
# Validation Random guess:  auc= 0.217470, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.556292
# Tarin Iter 400, auc= 0.845839, fmeasure_max= 0.800000, precision= 0.804382, recall= 0.795666
# Train Random guess:  , auc= 0.240926fmeasure_max= 0.403372, precision= 0.252640, recall= 1.000000
# Validation Iter 400, auc= 0.860791, fmeasure_max= 0.807474, precision= 0.766975, recall= 0.852487
# Validation Random guess:  auc= 0.229125, fmeasure_max= 0.373013, precision= 0.230000, recall= 0.986278
# Minibatch Loss= 0.650865
# Tarin Iter 500, auc= 0.938143, fmeasure_max= 0.872526, precision= 0.901800, recall= 0.845092
# Train Random guess:  , auc= 0.264229fmeasure_max= 0.407396, precision= 0.256006, recall= 0.996933
# Validation Iter 500, auc= 0.874420, fmeasure_max= 0.810587, precision= 0.782748, recall= 0.840480
# Validation Random guess:  auc= 0.223687, fmeasure_max= 0.372543, precision= 0.229365, recall= 0.991424
# Minibatch Loss= 0.599811
# Tarin Iter 600, auc= 0.903815, fmeasure_max= 0.840796, precision= 0.823052, recall= 0.859322
# Train Random guess:  , auc= 0.241024fmeasure_max= 0.376408, precision= 0.233937, recall= 0.962712
# Validation Iter 600, auc= 0.891820, fmeasure_max= 0.816856, precision= 0.774194, recall= 0.864494
# Validation Random guess:  auc= 0.222275, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.526748
# Tarin Iter 700, auc= 0.859048, fmeasure_max= 0.806593, precision= 0.855478, recall= 0.762994
# Train Random guess:  , auc= 0.183307fmeasure_max= 0.317450, precision= 0.189276, recall= 0.983368
# Validation Iter 700, auc= 0.901583, fmeasure_max= 0.824013, precision= 0.791469, recall= 0.859348
# Validation Random guess:  auc= 0.228149, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.504681
# Tarin Iter 800, auc= 0.865970, fmeasure_max= 0.788508, precision= 0.813839, recall= 0.764706
# Train Random guess:  , auc= 0.256854fmeasure_max= 0.403120, precision= 0.252442, recall= 1.000000
# Validation Iter 800, auc= 0.890416, fmeasure_max= 0.810065, precision= 0.768875, recall= 0.855918
# Validation Random guess:  auc= 0.228496, fmeasure_max= 0.373115, precision= 0.230645, recall= 0.975986
# Minibatch Loss= 0.676569
# Tarin Iter 900, auc= 0.930493, fmeasure_max= 0.850644, precision= 0.808357, recall= 0.897600
# Train Random guess:  , auc= 0.233928fmeasure_max= 0.392700, precision= 0.244418, recall= 0.998400
# Validation Iter 900, auc= 0.904609, fmeasure_max= 0.842777, precision= 0.788060, recall= 0.905660
# Validation Random guess:  auc= 0.222017, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.521758
# Tarin Iter 1000, auc= 0.901217, fmeasure_max= 0.827195, precision= 0.814126, recall= 0.840691
# Train Random guess:  , auc= 0.218217fmeasure_max= 0.339204, precision= 0.204322, recall= 0.998081
# Validation Iter 1000, auc= 0.917314, fmeasure_max= 0.836248, precision= 0.779259, recall= 0.902230
# Validation Random guess:  auc= 0.232616, fmeasure_max= 0.373548, precision= 0.230036, recall= 0.993139
# Minibatch Loss= 0.482536
# Tarin Iter 1100, auc= 0.937162, fmeasure_max= 0.853190, precision= 0.829596, recall= 0.878165
# Train Random guess:  , auc= 0.235379fmeasure_max= 0.396114, precision= 0.246971, recall= 1.000000
# Validation Iter 1100, auc= 0.919057, fmeasure_max= 0.846615, precision= 0.845890, recall= 0.847341
# Validation Random guess:  auc= 0.243205, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.489993
# Tarin Iter 1200, auc= 0.902204, fmeasure_max= 0.808149, precision= 0.824957, recall= 0.792013
# Train Random guess:  , auc= 0.238547fmeasure_max= 0.381380, precision= 0.236277, recall= 0.988353
# Validation Iter 1200, auc= 0.892875, fmeasure_max= 0.812656, precision= 0.789644, recall= 0.837050
# Validation Random guess:  auc= 0.226586, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.530838
# Tarin Iter 1300, auc= 0.941040, fmeasure_max= 0.866785, precision= 0.887273, recall= 0.847222
# Train Random guess:  , auc= 0.218287fmeasure_max= 0.368353, precision= 0.226475, recall= 0.986111
# Validation Iter 1300, auc= 0.907998, fmeasure_max= 0.829060, precision= 0.826235, recall= 0.831904
# Validation Random guess:  auc= 0.231095, fmeasure_max= 0.372348, precision= 0.232578, recall= 0.933105
# Minibatch Loss= 0.453537
# Tarin Iter 1400, auc= 0.927753, fmeasure_max= 0.863738, precision= 0.874811, recall= 0.852941
# Train Random guess:  , auc= 0.258666fmeasure_max= 0.420922, precision= 0.266562, recall= 1.000000
# Validation Iter 1400, auc= 0.883758, fmeasure_max= 0.819672, precision= 0.824653, recall= 0.814751
# Validation Random guess:  auc= 0.233422, fmeasure_max= 0.372472, precision= 0.229964, recall= 0.979417
# Minibatch Loss= 0.577199
# Tarin Iter 1500, auc= 0.934241, fmeasure_max= 0.853097, precision= 0.877960, recall= 0.829604
# Train Random guess:  , auc= 0.233630fmeasure_max= 0.370418, precision= 0.227308, recall= 1.000000
# Validation Iter 1500, auc= 0.892697, fmeasure_max= 0.803787, precision= 0.806563, recall= 0.801029
# Validation Random guess:  auc= 0.229698, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.436585
# Tarin Iter 1600, auc= 0.917350, fmeasure_max= 0.835590, precision= 0.887064, recall= 0.789762
# Train Random guess:  , auc= 0.211922fmeasure_max= 0.353936, precision= 0.215275, recall= 0.994516
# Validation Iter 1600, auc= 0.864284, fmeasure_max= 0.796941, precision= 0.789562, recall= 0.804460
# Validation Random guess:  auc= 0.242879, fmeasure_max= 0.373548, precision= 0.230036, recall= 0.993139
# Minibatch Loss= 0.482309
# Tarin Iter 1700, auc= 0.952739, fmeasure_max= 0.880829, precision= 0.850000, recall= 0.913978
# Train Random guess:  , auc= 0.256717fmeasure_max= 0.405734, precision= 0.254496, recall= 1.000000
# Validation Iter 1700, auc= 0.910666, fmeasure_max= 0.835970, precision= 0.812298, recall= 0.861063
# Validation Random guess:  auc= 0.218810, fmeasure_max= 0.372063, precision= 0.229002, recall= 0.991424
# Minibatch Loss= 0.471040
# Tarin Iter 1800, auc= 0.933652, fmeasure_max= 0.844090, precision= 0.847162, recall= 0.841040
# Train Random guess:  , auc= 0.272458fmeasure_max= 0.428288, precision= 0.277635, recall= 0.936416
# Validation Iter 1800, auc= 0.907330, fmeasure_max= 0.829431, precision= 0.809135, recall= 0.850772
# Validation Random guess:  auc= 0.234981, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.571504
# Tarin Iter 1900, auc= 0.924300, fmeasure_max= 0.839735, precision= 0.803549, recall= 0.879334
# Train Random guess:  , auc= 0.276885fmeasure_max= 0.439768, precision= 0.281861, recall= 1.000000
# Validation Iter 1900, auc= 0.896622, fmeasure_max= 0.822096, precision= 0.780864, recall= 0.867925
# Validation Random guess:  auc= 0.235466, fmeasure_max= 0.374058, precision= 0.231174, recall= 0.979417
# Minibatch Loss= 0.539589
# Tarin Iter 2000, auc= 0.965636, fmeasure_max= 0.900850, precision= 0.928016, recall= 0.875229
# Train Random guess:  , auc= 0.217242fmeasure_max= 0.351500, precision= 0.213224, recall= 1.000000
# Validation Iter 2000, auc= 0.923146, fmeasure_max= 0.839869, precision= 0.801872, recall= 0.881647
# Validation Random guess:  auc= 0.239562, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.394885
# Tarin Iter 2100, auc= 0.919992, fmeasure_max= 0.840731, precision= 0.854867, recall= 0.827055
# Train Random guess:  , auc= 0.222279fmeasure_max= 0.372347, precision= 0.229216, recall= 0.991438
# Validation Iter 2100, auc= 0.911042, fmeasure_max= 0.839895, precision= 0.857143, recall= 0.823328
# Validation Random guess:  auc= 0.233532, fmeasure_max= 0.376831, precision= 0.235119, recall= 0.948542
# Minibatch Loss= 0.470187
# Tarin Iter 2200, auc= 0.929538, fmeasure_max= 0.833181, precision= 0.824910, recall= 0.841621
# Train Random guess:  , auc= 0.230544fmeasure_max= 0.351413, precision= 0.213328, recall= 0.996317
# Validation Iter 2200, auc= 0.920037, fmeasure_max= 0.849408, precision= 0.838063, recall= 0.861063
# Validation Random guess:  auc= 0.236163, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.445289
# Tarin Iter 2300, auc= 0.958845, fmeasure_max= 0.882521, precision= 0.893617, recall= 0.871698
# Train Random guess:  , auc= 0.203464fmeasure_max= 0.343618, precision= 0.207532, recall= 0.998113
# Validation Iter 2300, auc= 0.907773, fmeasure_max= 0.853065, precision= 0.835526, recall= 0.871355
# Validation Random guess:  auc= 0.224053, fmeasure_max= 0.372498, precision= 0.229423, recall= 0.989708
# Minibatch Loss= 0.373989
# Tarin Iter 2400, auc= 0.926204, fmeasure_max= 0.869632, precision= 0.868300, recall= 0.870968
# Train Random guess:  , auc= 0.248917fmeasure_max= 0.405860, precision= 0.254595, recall= 1.000000
# Validation Iter 2400, auc= 0.920474, fmeasure_max= 0.843373, precision= 0.793051, recall= 0.900515
# Validation Random guess:  auc= 0.228663, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.502682
# Tarin Iter 2500, auc= 0.939571, fmeasure_max= 0.869728, precision= 0.862454, recall= 0.877127
# Train Random guess:  , auc= 0.208484fmeasure_max= 0.343299, precision= 0.208742, recall= 0.965974
# Validation Iter 2500, auc= 0.931038, fmeasure_max= 0.855939, precision= 0.841060, recall= 0.871355
# Validation Random guess:  auc= 0.217703, fmeasure_max= 0.376198, precision= 0.233006, recall= 0.975986
# Minibatch Loss= 0.399273
# Tarin Iter 2600, auc= 0.956669, fmeasure_max= 0.890037, precision= 0.880292, recall= 0.900000
# Train Random guess:  , auc= 0.263064fmeasure_max= 0.416824, precision= 0.263911, recall= 0.991045
# Validation Iter 2600, auc= 0.916444, fmeasure_max= 0.842105, precision= 0.847222, recall= 0.837050
# Validation Random guess:  auc= 0.237991, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.483799
# Tarin Iter 2700, auc= 0.947352, fmeasure_max= 0.875332, precision= 0.885510, recall= 0.865385
# Train Random guess:  , auc= 0.214956fmeasure_max= 0.366432, precision= 0.224314, recall= 1.000000
# Validation Iter 2700, auc= 0.916550, fmeasure_max= 0.847315, precision= 0.829228, recall= 0.866209
# Validation Random guess:  auc= 0.224919, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.392930
# Tarin Iter 2800, auc= 0.941374, fmeasure_max= 0.853360, precision= 0.893390, recall= 0.816764
# Train Random guess:  , auc= 0.208662fmeasure_max= 0.333876, precision= 0.200391, recall= 1.000000
# Validation Iter 2800, auc= 0.927110, fmeasure_max= 0.857143, precision= 0.840198, recall= 0.874786
# Validation Random guess:  auc= 0.236379, fmeasure_max= 0.372606, precision= 0.229784, recall= 0.984563
# Minibatch Loss= 0.397127
# Tarin Iter 2900, auc= 0.965534, fmeasure_max= 0.904924, precision= 0.917384, recall= 0.892797
# Train Random guess:  , auc= 0.229510fmeasure_max= 0.378687, precision= 0.233568, recall= 1.000000
# Validation Iter 2900, auc= 0.929332, fmeasure_max= 0.852041, precision= 0.844857, recall= 0.859348
# Validation Random guess:  auc= 0.233740, fmeasure_max= 0.373393, precision= 0.229735, recall= 0.996569
# Minibatch Loss= 0.411470
# Tarin Iter 3000, auc= 0.945725, fmeasure_max= 0.872757, precision= 0.853270, recall= 0.893155
# Train Random guess:  , auc= 0.235831fmeasure_max= 0.379354, precision= 0.234076, recall= 1.000000
# Validation Iter 3000, auc= 0.918156, fmeasure_max= 0.845557, precision= 0.850694, recall= 0.840480
# Validation Random guess:  auc= 0.224220, fmeasure_max= 0.371750, precision= 0.228673, recall= 0.993139
# Minibatch Loss= 0.467521
# Tarin Iter 3100, auc= 0.860809, fmeasure_max= 0.800975, precision= 0.757296, recall= 0.850000
# Train Random guess:  , auc= 0.232960fmeasure_max= 0.370942, precision= 0.227973, recall= 0.994828
# Validation Iter 3100, auc= 0.921575, fmeasure_max= 0.837668, precision= 0.877820, recall= 0.801029
# Validation Random guess:  auc= 0.236012, fmeasure_max= 0.372076, precision= 0.235428, recall= 0.886792
# Minibatch Loss= 0.506174
# Tarin Iter 3200, auc= 0.904540, fmeasure_max= 0.866197, precision= 0.880143, recall= 0.852686
# Train Random guess:  , auc= 0.226977fmeasure_max= 0.367985, precision= 0.225479, recall= 1.000000
# Validation Iter 3200, auc= 0.922248, fmeasure_max= 0.849315, precision= 0.847863, recall= 0.850772
# Validation Random guess:  auc= 0.225052, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.431388
# Tarin Iter 3300, auc= 0.965511, fmeasure_max= 0.903226, precision= 0.865293, recall= 0.944637
# Train Random guess:  , auc= 0.231489fmeasure_max= 0.368740, precision= 0.226046, recall= 1.000000
# Validation Iter 3300, auc= 0.917997, fmeasure_max= 0.846678, precision= 0.840948, recall= 0.852487
# Validation Random guess:  auc= 0.221916, fmeasure_max= 0.372574, precision= 0.229574, recall= 0.987993
# Minibatch Loss= 0.396655
# Tarin Iter 3400, auc= 0.952202, fmeasure_max= 0.889673, precision= 0.871972, recall= 0.908108
# Train Random guess:  , auc= 0.216047fmeasure_max= 0.356865, precision= 0.217529, recall= 0.992793
# Validation Iter 3400, auc= 0.917862, fmeasure_max= 0.851502, precision= 0.852234, recall= 0.850772
# Validation Random guess:  auc= 0.228724, fmeasure_max= 0.371154, precision= 0.228222, recall= 0.993139
# Minibatch Loss= 0.380443
# Tarin Iter 3500, auc= 0.950121, fmeasure_max= 0.866776, precision= 0.865353, recall= 0.868204
# Train Random guess:  , auc= 0.249837fmeasure_max= 0.386809, precision= 0.244358, recall= 0.927512
# Validation Iter 3500, auc= 0.925448, fmeasure_max= 0.851385, precision= 0.833882, recall= 0.869640
# Validation Random guess:  auc= 0.228586, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.452579
# Tarin Iter 3600, auc= 0.925719, fmeasure_max= 0.855761, precision= 0.816923, recall= 0.898477
# Train Random guess:  , auc= 0.217956fmeasure_max= 0.375119, precision= 0.230859, recall= 1.000000
# Validation Iter 3600, auc= 0.921627, fmeasure_max= 0.849226, precision= 0.809006, recall= 0.893654
# Validation Random guess:  auc= 0.252476, fmeasure_max= 0.372303, precision= 0.229183, recall= 0.991424
# Minibatch Loss= 0.455339
# Tarin Iter 3700, auc= 0.953500, fmeasure_max= 0.879087, precision= 0.887865, recall= 0.870482
# Train Random guess:  , auc= 0.267095fmeasure_max= 0.411911, precision= 0.259375, recall= 1.000000
# Validation Iter 3700, auc= 0.900572, fmeasure_max= 0.818644, precision= 0.809045, recall= 0.828473
# Validation Random guess:  auc= 0.230239, fmeasure_max= 0.371273, precision= 0.228312, recall= 0.993139
# Minibatch Loss= 0.482479
# Tarin Iter 3800, auc= 0.951284, fmeasure_max= 0.871662, precision= 0.883072, recall= 0.860544
# Train Random guess:  , auc= 0.225099fmeasure_max= 0.374759, precision= 0.231136, recall= 0.989796
# Validation Iter 3800, auc= 0.921680, fmeasure_max= 0.855160, precision= 0.864912, recall= 0.845626
# Validation Random guess:  auc= 0.228864, fmeasure_max= 0.374261, precision= 0.231425, recall= 0.977702
# Minibatch Loss= 0.411622
# Tarin Iter 3900, auc= 0.954588, fmeasure_max= 0.880766, precision= 0.905188, recall= 0.857627
# Train Random guess:  , auc= 0.253422fmeasure_max= 0.375437, precision= 0.231101, recall= 1.000000
# Validation Iter 3900, auc= 0.917219, fmeasure_max= 0.837998, precision= 0.828859, recall= 0.847341
# Validation Random guess:  auc= 0.221567, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.461632
# Tarin Iter 4000, auc= 0.903389, fmeasure_max= 0.828829, precision= 0.812199, recall= 0.846154
# Train Random guess:  , auc= 0.241690fmeasure_max= 0.379706, precision= 0.234621, recall= 0.994983
# Validation Iter 4000, auc= 0.910406, fmeasure_max= 0.844929, precision= 0.826230, recall= 0.864494
# Validation Random guess:  auc= 0.220925, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.569683
# Tarin Iter 4100, auc= 0.955928, fmeasure_max= 0.884770, precision= 0.911960, recall= 0.859155
# Train Random guess:  , auc= 0.253179fmeasure_max= 0.399500, precision= 0.249609, recall= 1.000000
# Validation Iter 4100, auc= 0.899776, fmeasure_max= 0.829185, precision= 0.829897, recall= 0.828473
# Validation Random guess:  auc= 0.224921, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.450702
# Tarin Iter 4200, auc= 0.960790, fmeasure_max= 0.890771, precision= 0.893039, recall= 0.888514
# Train Random guess:  , auc= 0.237218fmeasure_max= 0.378326, precision= 0.233478, recall= 0.996622
# Validation Iter 4200, auc= 0.905070, fmeasure_max= 0.841549, precision= 0.864376, recall= 0.819897
# Validation Random guess:  auc= 0.226155, fmeasure_max= 0.372317, precision= 0.228920, recall= 0.996569
# Minibatch Loss= 0.394862
# Tarin Iter 4300, auc= 0.967646, fmeasure_max= 0.901382, precision= 0.929658, recall= 0.874776
# Train Random guess:  , auc= 0.208146fmeasure_max= 0.360343, precision= 0.220832, recall= 0.978533
# Validation Iter 4300, auc= 0.922386, fmeasure_max= 0.859335, precision= 0.854237, recall= 0.864494
# Validation Random guess:  auc= 0.219468, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.365431
# Tarin Iter 4400, auc= 0.960440, fmeasure_max= 0.901333, precision= 0.921818, recall= 0.881739
# Train Random guess:  , auc= 0.215319fmeasure_max= 0.369410, precision= 0.227001, recall= 0.991304
# Validation Iter 4400, auc= 0.927893, fmeasure_max= 0.865823, precision= 0.852159, recall= 0.879931
# Validation Random guess:  auc= 0.222564, fmeasure_max= 0.371154, precision= 0.228222, recall= 0.993139
# Minibatch Loss= 0.405335
# Tarin Iter 4500, auc= 0.967998, fmeasure_max= 0.896552, precision= 0.927032, recall= 0.868012
# Train Random guess:  , auc= 0.248194fmeasure_max= 0.403004, precision= 0.252351, recall= 1.000000
# Validation Iter 4500, auc= 0.916191, fmeasure_max= 0.841453, precision= 0.869963, recall= 0.814751
# Validation Random guess:  auc= 0.225707, fmeasure_max= 0.372048, precision= 0.229266, recall= 0.986278
# Minibatch Loss= 0.402597
# Tarin Iter 4600, auc= 0.958471, fmeasure_max= 0.885113, precision= 0.860063, recall= 0.911667
# Train Random guess:  , auc= 0.232106fmeasure_max= 0.380435, precision= 0.235364, recall= 0.991667
# Validation Iter 4600, auc= 0.903371, fmeasure_max= 0.825641, precision= 0.822828, recall= 0.828473
# Validation Random guess:  auc= 0.231985, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.382650
# Tarin Iter 4700, auc= 0.964774, fmeasure_max= 0.897213, precision= 0.905097, recall= 0.889465
# Train Random guess:  , auc= 0.227952fmeasure_max= 0.371347, precision= 0.233947, recall= 0.899827
# Validation Iter 4700, auc= 0.898699, fmeasure_max= 0.839442, precision= 0.854352, recall= 0.825043
# Validation Random guess:  auc= 0.217427, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.402639
# Tarin Iter 4800, auc= 0.949069, fmeasure_max= 0.881633, precision= 0.925054, recall= 0.842105
# Train Random guess:  , auc= 0.203826fmeasure_max= 0.336399, precision= 0.202292, recall= 0.998051
# Validation Iter 4800, auc= 0.926075, fmeasure_max= 0.857645, precision= 0.879279, recall= 0.837050
# Validation Random guess:  auc= 0.226705, fmeasure_max= 0.371567, precision= 0.228901, recall= 0.986278
# Minibatch Loss= 0.382877
# Tarin Iter 4900, auc= 0.970449, fmeasure_max= 0.905194, precision= 0.889789, recall= 0.921141
# Train Random guess:  , auc= 0.233904fmeasure_max= 0.378173, precision= 0.233177, recall= 1.000000
# Validation Iter 4900, auc= 0.925373, fmeasure_max= 0.855219, precision= 0.839669, recall= 0.871355
# Validation Random guess:  auc= 0.236243, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.376449
# Tarin Iter 5000, auc= 0.944540, fmeasure_max= 0.866270, precision= 0.826950, recall= 0.909516
# Train Random guess:  , auc= 0.239711fmeasure_max= 0.401769, precision= 0.251881, recall= 0.992200
# Validation Iter 5000, auc= 0.926799, fmeasure_max= 0.842845, precision= 0.863309, recall= 0.823328
# Validation Random guess:  auc= 0.228292, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.476676
# Tarin Iter 5100, auc= 0.958104, fmeasure_max= 0.885809, precision= 0.852605, recall= 0.921703
# Train Random guess:  , auc= 0.279222fmeasure_max= 0.444038, precision= 0.285378, recall= 1.000000
# Validation Iter 5100, auc= 0.916846, fmeasure_max= 0.847973, precision= 0.835275, recall= 0.861063
# Validation Random guess:  auc= 0.230981, fmeasure_max= 0.371200, precision= 0.228167, recall= 0.994854
# Minibatch Loss= 0.444631
# Tarin Iter 5200, auc= 0.963258, fmeasure_max= 0.888889, precision= 0.882353, recall= 0.895522
# Train Random guess:  , auc= 0.236921fmeasure_max= 0.382507, precision= 0.238115, recall= 0.971808
# Validation Iter 5200, auc= 0.906004, fmeasure_max= 0.830638, precision= 0.824324, recall= 0.837050
# Validation Random guess:  auc= 0.245207, fmeasure_max= 0.373170, precision= 0.232795, recall= 0.939966
# Minibatch Loss= 0.393195
# Tarin Iter 5300, auc= 0.962066, fmeasure_max= 0.897890, precision= 0.875000, recall= 0.922010
# Train Random guess:  , auc= 0.247641fmeasure_max= 0.367985, precision= 0.225479, recall= 1.000000
# Validation Iter 5300, auc= 0.894054, fmeasure_max= 0.834934, precision= 0.850534, recall= 0.819897
# Validation Random guess:  auc= 0.242750, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.380715
# Tarin Iter 5400, auc= 0.958039, fmeasure_max= 0.890671, precision= 0.850975, recall= 0.934251
# Train Random guess:  , auc= 0.264933fmeasure_max= 0.407858, precision= 0.256169, recall= 1.000000
# Validation Iter 5400, auc= 0.905258, fmeasure_max= 0.832432, precision= 0.876660, recall= 0.792453
# Validation Random guess:  auc= 0.249244, fmeasure_max= 0.376841, precision= 0.235445, recall= 0.943396
# Minibatch Loss= 0.401238
# Tarin Iter 5500, auc= 0.959344, fmeasure_max= 0.894522, precision= 0.890879, recall= 0.898194
# Train Random guess:  , auc= 0.243779fmeasure_max= 0.385480, precision= 0.239617, recall= 0.985222
# Validation Iter 5500, auc= 0.922473, fmeasure_max= 0.853448, precision= 0.857886, recall= 0.849057
# Validation Random guess:  auc= 0.229142, fmeasure_max= 0.373968, precision= 0.231588, recall= 0.970840
# Minibatch Loss= 0.407395
# Tarin Iter 5600, auc= 0.977477, fmeasure_max= 0.926661, precision= 0.924269, recall= 0.929066
# Train Random guess:  , auc= 0.217577fmeasure_max= 0.370013, precision= 0.227273, recall= 0.994810
# Validation Iter 5600, auc= 0.927486, fmeasure_max= 0.852570, precision= 0.837748, recall= 0.867925
# Validation Random guess:  auc= 0.223820, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.324787
# Tarin Iter 5700, auc= 0.970872, fmeasure_max= 0.906716, precision= 0.886861, recall= 0.927481
# Train Random guess:  , auc= 0.208832fmeasure_max= 0.340039, precision= 0.204848, recall= 1.000000
# Validation Iter 5700, auc= 0.913294, fmeasure_max= 0.852373, precision= 0.873874, recall= 0.831904
# Validation Random guess:  auc= 0.228227, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.348900
# Tarin Iter 5800, auc= 0.963660, fmeasure_max= 0.893130, precision= 0.866667, recall= 0.921260
# Train Random guess:  , auc= 0.253982fmeasure_max= 0.398119, precision= 0.248532, recall= 1.000000
# Validation Iter 5800, auc= 0.915470, fmeasure_max= 0.845745, precision= 0.875229, recall= 0.818182
# Validation Random guess:  auc= 0.223165, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.427232
# Tarin Iter 5900, auc= 0.947578, fmeasure_max= 0.870075, precision= 0.849427, recall= 0.891753
# Train Random guess:  , auc= 0.218780fmeasure_max= 0.372751, precision= 0.229249, recall= 0.996564
# Validation Iter 5900, auc= 0.923192, fmeasure_max= 0.849192, precision= 0.890772, recall= 0.811321
# Validation Random guess:  auc= 0.214675, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.424297
# Tarin Iter 6000, auc= 0.967224, fmeasure_max= 0.895119, precision= 0.896050, recall= 0.894191
# Train Random guess:  , auc= 0.191304fmeasure_max= 0.318725, precision= 0.189723, recall= 0.995851
# Validation Iter 6000, auc= 0.912797, fmeasure_max= 0.842105, precision= 0.861759, recall= 0.823328
# Validation Random guess:  auc= 0.226056, fmeasure_max= 0.372562, precision= 0.229844, recall= 0.982847
# Minibatch Loss= 0.320322
# Tarin Iter 6100, auc= 0.959767, fmeasure_max= 0.882516, precision= 0.886617, recall= 0.878453
# Train Random guess:  , auc= 0.223853fmeasure_max= 0.350582, precision= 0.212632, recall= 0.998158
# Validation Iter 6100, auc= 0.913256, fmeasure_max= 0.840067, precision= 0.824793, recall= 0.855918
# Validation Random guess:  auc= 0.224604, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.370922
# Tarin Iter 6200, auc= 0.962559, fmeasure_max= 0.889341, precision= 0.907202, recall= 0.872170
# Train Random guess:  , auc= 0.285788fmeasure_max= 0.453639, precision= 0.293359, recall= 1.000000
# Validation Iter 6200, auc= 0.895662, fmeasure_max= 0.817133, precision= 0.786054, recall= 0.850772
# Validation Random guess:  auc= 0.226923, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.502888
# Tarin Iter 6300, auc= 0.962068, fmeasure_max= 0.884714, precision= 0.853377, recall= 0.918440
# Train Random guess:  , auc= 0.229422fmeasure_max= 0.361307, precision= 0.220485, recall= 1.000000
# Validation Iter 6300, auc= 0.901542, fmeasure_max= 0.821338, precision= 0.811037, recall= 0.831904
# Validation Random guess:  auc= 0.225189, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.378387
# Tarin Iter 6400, auc= 0.970939, fmeasure_max= 0.907716, precision= 0.883652, recall= 0.933126
# Train Random guess:  , auc= 0.243635fmeasure_max= 0.402126, precision= 0.251663, recall= 1.000000
# Validation Iter 6400, auc= 0.900665, fmeasure_max= 0.829576, precision= 0.874525, recall= 0.789022
# Validation Random guess:  auc= 0.241352, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.360431
# Tarin Iter 6500, auc= 0.967156, fmeasure_max= 0.900585, precision= 0.877493, recall= 0.924925
# Train Random guess:  , auc= 0.243766fmeasure_max= 0.413665, precision= 0.260767, recall= 1.000000
# Validation Iter 6500, auc= 0.879138, fmeasure_max= 0.803604, precision= 0.846300, recall= 0.765009
# Validation Random guess:  auc= 0.220585, fmeasure_max= 0.371447, precision= 0.228810, recall= 0.986278
# Minibatch Loss= 0.419257
# Tarin Iter 6600, auc= 0.946931, fmeasure_max= 0.874138, precision= 0.833882, recall= 0.918478
# Train Random guess:  , auc= 0.219138fmeasure_max= 0.354911, precision= 0.215825, recall= 0.998188
# Validation Iter 6600, auc= 0.909746, fmeasure_max= 0.844996, precision= 0.873626, recall= 0.818182
# Validation Random guess:  auc= 0.238051, fmeasure_max= 0.371898, precision= 0.228968, recall= 0.989708
# Minibatch Loss= 0.416635
# Tarin Iter 6700, auc= 0.953621, fmeasure_max= 0.876604, precision= 0.870588, recall= 0.882704
# Train Random guess:  , auc= 0.194226fmeasure_max= 0.328436, precision= 0.196484, recall= 1.000000
# Validation Iter 6700, auc= 0.888239, fmeasure_max= 0.826549, precision= 0.853748, recall= 0.801029
# Validation Random guess:  auc= 0.219386, fmeasure_max= 0.372838, precision= 0.229224, recall= 0.998285
# Minibatch Loss= 0.356617
# Tarin Iter 6800, auc= 0.969304, fmeasure_max= 0.913323, precision= 0.943615, recall= 0.884914
# Train Random guess:  , auc= 0.250920fmeasure_max= 0.401499, precision= 0.251172, recall= 1.000000
# Validation Iter 6800, auc= 0.909889, fmeasure_max= 0.846939, precision= 0.839798, recall= 0.854202
# Validation Random guess:  auc= 0.228912, fmeasure_max= 0.374499, precision= 0.232491, recall= 0.962264
# Minibatch Loss= 0.424884
# Tarin Iter 6900, auc= 0.969221, fmeasure_max= 0.901743, precision= 0.884914, recall= 0.919225
# Train Random guess:  , auc= 0.240987fmeasure_max= 0.389676, precision= 0.241986, recall= 1.000000
# Validation Iter 6900, auc= 0.894230, fmeasure_max= 0.812386, precision= 0.866019, recall= 0.765009
# Validation Random guess:  auc= 0.225457, fmeasure_max= 0.372213, precision= 0.229299, recall= 0.987993
# Minibatch Loss= 0.424488
# Tarin Iter 7000, auc= 0.950814, fmeasure_max= 0.876190, precision= 0.836364, recall= 0.920000
# Train Random guess:  , auc= 0.223634fmeasure_max= 0.357020, precision= 0.220059, recall= 0.945455
# Validation Iter 7000, auc= 0.911626, fmeasure_max= 0.845217, precision= 0.857143, recall= 0.833619
# Validation Random guess:  auc= 0.214452, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.381282
# Tarin Iter 7100, auc= 0.939257, fmeasure_max= 0.888703, precision= 0.901528, recall= 0.876238
# Train Random guess:  , auc= 0.233510fmeasure_max= 0.384541, precision= 0.238896, recall= 0.985149
# Validation Iter 7100, auc= 0.908265, fmeasure_max= 0.846021, precision= 0.853403, recall= 0.838765
# Validation Random guess:  auc= 0.228101, fmeasure_max= 0.372199, precision= 0.229567, recall= 0.982847
# Minibatch Loss= 0.436869
# Tarin Iter 7200, auc= 0.960174, fmeasure_max= 0.903120, precision= 0.875796, recall= 0.932203
# Train Random guess:  , auc= 0.231253fmeasure_max= 0.374603, precision= 0.230469, recall= 1.000000
# Validation Iter 7200, auc= 0.916748, fmeasure_max= 0.846221, precision= 0.857394, recall= 0.835334
# Validation Random guess:  auc= 0.235420, fmeasure_max= 0.374794, precision= 0.232026, recall= 0.974271
# Minibatch Loss= 0.359698
# Tarin Iter 7300, auc= 0.972130, fmeasure_max= 0.903286, precision= 0.876138, recall= 0.932171
# Train Random guess:  , auc= 0.200892fmeasure_max= 0.335501, precision= 0.201563, recall= 1.000000
# Validation Iter 7300, auc= 0.905689, fmeasure_max= 0.824869, precision= 0.842576, recall= 0.807890
# Validation Random guess:  auc= 0.240625, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.358942
# Tarin Iter 7400, auc= 0.973726, fmeasure_max= 0.917722, precision= 0.907668, recall= 0.928000
# Train Random guess:  , auc= 0.258980fmeasure_max= 0.393082, precision= 0.244618, recall= 1.000000
# Validation Iter 7400, auc= 0.915342, fmeasure_max= 0.838938, precision= 0.866545, recall= 0.813036
# Validation Random guess:  auc= 0.220234, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.388241
# Tarin Iter 7500, auc= 0.965286, fmeasure_max= 0.908205, precision= 0.880315, recall= 0.937919
# Train Random guess:  , auc= 0.225336fmeasure_max= 0.378533, precision= 0.233451, recall= 1.000000
# Validation Iter 7500, auc= 0.911664, fmeasure_max= 0.831904, precision= 0.831904, recall= 0.831904
# Validation Random guess:  auc= 0.224651, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.384825
# Tarin Iter 7600, auc= 0.963585, fmeasure_max= 0.909241, precision= 0.895935, recall= 0.922948
# Train Random guess:  , auc= 0.234436fmeasure_max= 0.378447, precision= 0.233385, recall= 1.000000
# Validation Iter 7600, auc= 0.910775, fmeasure_max= 0.844444, precision= 0.841567, recall= 0.847341
# Validation Random guess:  auc= 0.231234, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.352055
# Tarin Iter 7700, auc= 0.969243, fmeasure_max= 0.909317, precision= 0.901478, recall= 0.917293
# Train Random guess:  , auc= 0.158034fmeasure_max= 0.270933, precision= 0.156755, recall= 0.997494
# Validation Iter 7700, auc= 0.876986, fmeasure_max= 0.820604, precision= 0.850829, recall= 0.792453
# Validation Random guess:  auc= 0.260958, fmeasure_max= 0.371127, precision= 0.228022, recall= 0.996569
# Minibatch Loss= 0.243843
# Tarin Iter 7800, auc= 0.966577, fmeasure_max= 0.892574, precision= 0.838753, recall= 0.953775
# Train Random guess:  , auc= 0.246554fmeasure_max= 0.404613, precision= 0.253615, recall= 1.000000
# Validation Iter 7800, auc= 0.891803, fmeasure_max= 0.830716, precision= 0.845471, recall= 0.816467
# Validation Random guess:  auc= 0.225646, fmeasure_max= 0.374917, precision= 0.232121, recall= 0.974271
# Minibatch Loss= 0.414989
# Tarin Iter 7900, auc= 0.968949, fmeasure_max= 0.901304, precision= 0.889706, recall= 0.913208
# Train Random guess:  , auc= 0.214029fmeasure_max= 0.343933, precision= 0.207680, recall= 1.000000
# Validation Iter 7900, auc= 0.897838, fmeasure_max= 0.828194, precision= 0.851449, recall= 0.806175
# Validation Random guess:  auc= 0.236273, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.356425
# Tarin Iter 8000, auc= 0.970833, fmeasure_max= 0.903692, precision= 0.932119, recall= 0.876947
# Train Random guess:  , auc= 0.267597fmeasure_max= 0.401258, precision= 0.251379, recall= 0.993769
# Validation Iter 8000, auc= 0.916226, fmeasure_max= 0.833333, precision= 0.905433, recall= 0.771870
# Validation Random guess:  auc= 0.219301, fmeasure_max= 0.371392, precision= 0.228402, recall= 0.993139
# Minibatch Loss= 0.418838
# Tarin Iter 8100, auc= 0.983416, fmeasure_max= 0.936909, precision= 0.922360, recall= 0.951923
# Train Random guess:  , auc= 0.253341fmeasure_max= 0.392206, precision= 0.243941, recall= 1.000000
# Validation Iter 8100, auc= 0.918101, fmeasure_max= 0.846831, precision= 0.869801, recall= 0.825043
# Validation Random guess:  auc= 0.214390, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.350310
# Tarin Iter 8200, auc= 0.963084, fmeasure_max= 0.907063, precision= 0.894428, recall= 0.920060
# Train Random guess:  , auc= 0.252157fmeasure_max= 0.411856, precision= 0.259638, recall= 0.995475
# Validation Iter 8200, auc= 0.907264, fmeasure_max= 0.842918, precision= 0.843643, recall= 0.842196
# Validation Random guess:  auc= 0.229739, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.442157
# Tarin Iter 8300, auc= 0.978584, fmeasure_max= 0.926746, precision= 0.905158, recall= 0.949389
# Train Random guess:  , auc= 0.243281fmeasure_max= 0.373582, precision= 0.230928, recall= 0.977312
# Validation Iter 8300, auc= 0.904650, fmeasure_max= 0.839223, precision= 0.865209, recall= 0.814751
# Validation Random guess:  auc= 0.222333, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.316781
# Tarin Iter 8400, auc= 0.955173, fmeasure_max= 0.894689, precision= 0.889088, recall= 0.900362
# Train Random guess:  , auc= 0.215216fmeasure_max= 0.355140, precision= 0.215994, recall= 0.998188
# Validation Iter 8400, auc= 0.905717, fmeasure_max= 0.839733, precision= 0.817886, recall= 0.862779
# Validation Random guess:  auc= 0.223827, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.364746
# Tarin Iter 8500, auc= 0.972160, fmeasure_max= 0.919156, precision= 0.924028, recall= 0.914336
# Train Random guess:  , auc= 0.228488fmeasure_max= 0.369581, precision= 0.231936, recall= 0.909091
# Validation Iter 8500, auc= 0.901085, fmeasure_max= 0.832579, precision= 0.881226, recall= 0.789022
# Validation Random guess:  auc= 0.226385, fmeasure_max= 0.372684, precision= 0.232947, recall= 0.931389
# Minibatch Loss= 0.323147
# Tarin Iter 8600, auc= 0.960486, fmeasure_max= 0.894094, precision= 0.903292, recall= 0.885081
# Train Random guess:  , auc= 0.200685fmeasure_max= 0.325074, precision= 0.194390, recall= 0.991935
# Validation Iter 8600, auc= 0.917742, fmeasure_max= 0.846221, precision= 0.857394, recall= 0.835334
# Validation Random guess:  auc= 0.237137, fmeasure_max= 0.374172, precision= 0.231842, recall= 0.969125
# Minibatch Loss= 0.322905
# Tarin Iter 8700, auc= 0.960685, fmeasure_max= 0.884444, precision= 0.852857, recall= 0.918462
# Train Random guess:  , auc= 0.272777fmeasure_max= 0.405326, precision= 0.256896, recall= 0.960000
# Validation Iter 8700, auc= 0.907312, fmeasure_max= 0.835640, precision= 0.842932, recall= 0.828473
# Validation Random guess:  auc= 0.213874, fmeasure_max= 0.371966, precision= 0.232280, recall= 0.933105
# Minibatch Loss= 0.414170
# Tarin Iter 8800, auc= 0.968934, fmeasure_max= 0.899028, precision= 0.867244, recall= 0.933230
# Train Random guess:  , auc= 0.254116fmeasure_max= 0.402756, precision= 0.252256, recall= 0.998447
# Validation Iter 8800, auc= 0.902555, fmeasure_max= 0.843889, precision= 0.879182, recall= 0.811321
# Validation Random guess:  auc= 0.231482, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.412747
# Tarin Iter 8900, auc= 0.979285, fmeasure_max= 0.924205, precision= 0.918963, recall= 0.929508
# Train Random guess:  , auc= 0.236071fmeasure_max= 0.385374, precision= 0.239053, recall= 0.993443
# Validation Iter 8900, auc= 0.913075, fmeasure_max= 0.841645, precision= 0.858929, recall= 0.825043
# Validation Random guess:  auc= 0.228100, fmeasure_max= 0.373526, precision= 0.230863, recall= 0.977702
# Minibatch Loss= 0.358292
# Tarin Iter 9000, auc= 0.972175, fmeasure_max= 0.907063, precision= 0.898380, recall= 0.915916
# Train Random guess:  , auc= 0.276382fmeasure_max= 0.413408, precision= 0.260563, recall= 1.000000
# Validation Iter 9000, auc= 0.892696, fmeasure_max= 0.827939, precision= 0.822335, recall= 0.833619
# Validation Random guess:  auc= 0.232432, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.439079
# Tarin Iter 9100, auc= 0.963976, fmeasure_max= 0.909438, precision= 0.915547, recall= 0.903409
# Train Random guess:  , auc= 0.201157fmeasure_max= 0.342746, precision= 0.206816, recall= 1.000000
# Validation Iter 9100, auc= 0.899461, fmeasure_max= 0.833333, precision= 0.826307, recall= 0.840480
# Validation Random guess:  auc= 0.233545, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.312054
# Tarin Iter 9200, auc= 0.972674, fmeasure_max= 0.912621, precision= 0.892919, recall= 0.933213
# Train Random guess:  , auc= 0.219822fmeasure_max= 0.356499, precision= 0.216915, recall= 1.000000
# Validation Iter 9200, auc= 0.920236, fmeasure_max= 0.852686, precision= 0.861646, recall= 0.843911
# Validation Random guess:  auc= 0.234208, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.364690
# Tarin Iter 9300, auc= 0.983177, fmeasure_max= 0.934566, precision= 0.937233, recall= 0.931915
# Train Random guess:  , auc= 0.268473fmeasure_max= 0.432383, precision= 0.275822, recall= 1.000000
# Validation Iter 9300, auc= 0.921167, fmeasure_max= 0.855688, precision= 0.847059, recall= 0.864494
# Validation Random guess:  auc= 0.231921, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.390541
# Tarin Iter 9400, auc= 0.920485, fmeasure_max= 0.837959, precision= 0.852459, recall= 0.823944
# Train Random guess:  , auc= 0.233293fmeasure_max= 0.364339, precision= 0.222922, recall= 0.996479
# Validation Iter 9400, auc= 0.890481, fmeasure_max= 0.826855, precision= 0.852459, recall= 0.802744
# Validation Random guess:  auc= 0.234593, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.458785
# Tarin Iter 9500, auc= 0.979874, fmeasure_max= 0.919748, precision= 0.930657, recall= 0.909091
# Train Random guess:  , auc= 0.221078fmeasure_max= 0.359615, precision= 0.219226, recall= 1.000000
# Validation Iter 9500, auc= 0.906405, fmeasure_max= 0.821338, precision= 0.811037, recall= 0.831904
# Validation Random guess:  auc= 0.226723, fmeasure_max= 0.372033, precision= 0.229535, recall= 0.981132
# Minibatch Loss= 0.315398
# Tarin Iter 9600, auc= 0.955224, fmeasure_max= 0.876442, precision= 0.888147, recall= 0.865041
# Train Random guess:  , auc= 0.249301fmeasure_max= 0.391151, precision= 0.243610, recall= 0.991870
# Validation Iter 9600, auc= 0.917885, fmeasure_max= 0.844857, precision= 0.830846, recall= 0.859348
# Validation Random guess:  auc= 0.229464, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.407316
# Tarin Iter 9700, auc= 0.965137, fmeasure_max= 0.903390, precision= 0.891304, recall= 0.915808
# Train Random guess:  , auc= 0.210923fmeasure_max= 0.372423, precision= 0.229183, recall= 0.993127
# Validation Iter 9700, auc= 0.892416, fmeasure_max= 0.812553, precision= 0.803691, recall= 0.821612
# Validation Random guess:  auc= 0.226723, fmeasure_max= 0.371943, precision= 0.228911, recall= 0.991424
# Minibatch Loss= 0.420585
# Tarin Iter 9800, auc= 0.984903, fmeasure_max= 0.934615, precision= 0.910112, recall= 0.960474
# Train Random guess:  , auc= 0.204763fmeasure_max= 0.330179, precision= 0.197733, recall= 1.000000
# Validation Iter 9800, auc= 0.931112, fmeasure_max= 0.861592, precision= 0.869110, recall= 0.854202
# Validation Random guess:  auc= 0.232611, fmeasure_max= 0.374547, precision= 0.231837, recall= 0.974271
# Minibatch Loss= 0.303590
# Tarin Iter 9900, auc= 0.979389, fmeasure_max= 0.925081, precision= 0.911717, recall= 0.938843
# Train Random guess:  , auc= 0.240001fmeasure_max= 0.383154, precision= 0.236976, recall= 1.000000
# Validation Iter 9900, auc= 0.910807, fmeasure_max= 0.832014, precision= 0.853791, recall= 0.811321
# Validation Random guess:  auc= 0.217366, fmeasure_max= 0.372396, precision= 0.229811, recall= 0.981132
# Minibatch Loss= 0.330573
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.916268 F1_max = 0.839965 prec = 0.864758 rec = 0.816554
# Test Random guess: auc= 0.231433 fmeasure_max= 0.375698 , precision= 0.231316 , recall= 0.999662

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
