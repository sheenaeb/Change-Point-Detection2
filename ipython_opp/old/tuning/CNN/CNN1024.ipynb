# %%
# useing this variable for saving models and summaries
exp_name = "CNN1024"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [4, 2, 2, 2, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [3, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.163541, fmeasure_max= 0.323686, precision= 0.196850, recall= 0.910064
# Train Random guess:  , auc= 0.190903fmeasure_max= 0.309943, precision= 0.183465, recall= 0.997859
# Validation Iter 0, auc= 0.233182, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Validation Random guess:  auc= 0.245723, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.977947
# Tarin Iter 100, auc= 0.733306, fmeasure_max= 0.695881, precision= 0.725777, recall= 0.668350
# Train Random guess:  , auc= 0.227191fmeasure_max= 0.378622, precision= 0.234076, recall= 0.989899
# Validation Iter 100, auc= 0.702446, fmeasure_max= 0.683333, precision= 0.742455, recall= 0.632933
# Validation Random guess:  auc= 0.229552, fmeasure_max= 0.374499, precision= 0.232491, recall= 0.962264
# Minibatch Loss= 0.887553
# Tarin Iter 200, auc= 0.790345, fmeasure_max= 0.781173, precision= 0.815517, recall= 0.749604
# Train Random guess:  , auc= 0.252950fmeasure_max= 0.396232, precision= 0.247063, recall= 1.000000
# Validation Iter 200, auc= 0.804195, fmeasure_max= 0.776386, precision= 0.811215, recall= 0.744425
# Validation Random guess:  auc= 0.222937, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.759243
# Tarin Iter 300, auc= 0.746293, fmeasure_max= 0.700000, precision= 0.764454, recall= 0.645570
# Train Random guess:  , auc= 0.208231fmeasure_max= 0.355513, precision= 0.216185, recall= 1.000000
# Validation Iter 300, auc= 0.797998, fmeasure_max= 0.766436, precision= 0.773124, recall= 0.759863
# Validation Random guess:  auc= 0.235720, fmeasure_max= 0.372485, precision= 0.229692, recall= 0.984563
# Minibatch Loss= 0.716831
# Tarin Iter 400, auc= 0.770827, fmeasure_max= 0.770186, precision= 0.805195, recall= 0.738095
# Train Random guess:  , auc= 0.253725fmeasure_max= 0.375800, precision= 0.231467, recall= 0.998299
# Validation Iter 400, auc= 0.833754, fmeasure_max= 0.792982, precision= 0.811490, recall= 0.775300
# Validation Random guess:  auc= 0.241294, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.799128
# Tarin Iter 500, auc= 0.851372, fmeasure_max= 0.783945, precision= 0.743922, recall= 0.828520
# Train Random guess:  , auc= 0.206118fmeasure_max= 0.356729, precision= 0.217085, recall= 1.000000
# Validation Iter 500, auc= 0.802697, fmeasure_max= 0.770421, precision= 0.772414, recall= 0.768439
# Validation Random guess:  auc= 0.235706, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.599414
# Tarin Iter 600, auc= 0.809503, fmeasure_max= 0.787295, precision= 0.779048, recall= 0.795720
# Train Random guess:  , auc= 0.196412fmeasure_max= 0.334966, precision= 0.201255, recall= 0.998054
# Validation Iter 600, auc= 0.821604, fmeasure_max= 0.780446, precision= 0.780446, recall= 0.780446
# Validation Random guess:  auc= 0.223468, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.595479
# Tarin Iter 700, auc= 0.839441, fmeasure_max= 0.807958, precision= 0.820738, recall= 0.795571
# Train Random guess:  , auc= 0.217588fmeasure_max= 0.373316, precision= 0.229949, recall= 0.991482
# Validation Iter 700, auc= 0.829373, fmeasure_max= 0.792553, precision= 0.820183, recall= 0.766724
# Validation Random guess:  auc= 0.233626, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.641842
# Tarin Iter 800, auc= 0.825892, fmeasure_max= 0.803030, precision= 0.839604, recall= 0.769510
# Train Random guess:  , auc= 0.220437fmeasure_max= 0.357143, precision= 0.217477, recall= 0.998185
# Validation Iter 800, auc= 0.841675, fmeasure_max= 0.792988, precision= 0.772358, recall= 0.814751
# Validation Random guess:  auc= 0.220408, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.604802
# Tarin Iter 900, auc= 0.853816, fmeasure_max= 0.786806, precision= 0.783654, recall= 0.789984
# Train Random guess:  , auc= 0.228893fmeasure_max= 0.393108, precision= 0.244930, recall= 0.995153
# Validation Iter 900, auc= 0.834867, fmeasure_max= 0.787215, precision= 0.841797, recall= 0.739280
# Validation Random guess:  auc= 0.227907, fmeasure_max= 0.372903, precision= 0.229638, recall= 0.991424
# Minibatch Loss= 0.658151
# Tarin Iter 1000, auc= 0.902857, fmeasure_max= 0.828767, precision= 0.876812, recall= 0.785714
# Train Random guess:  , auc= 0.238595fmeasure_max= 0.388362, precision= 0.241163, recall= 0.996753
# Validation Iter 1000, auc= 0.852167, fmeasure_max= 0.780749, precision= 0.812616, recall= 0.751286
# Validation Random guess:  auc= 0.232466, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.635193
# Tarin Iter 1100, auc= 0.916464, fmeasure_max= 0.852381, precision= 0.870340, recall= 0.835148
# Train Random guess:  , auc= 0.242283fmeasure_max= 0.402420, precision= 0.253002, recall= 0.982893
# Validation Iter 1100, auc= 0.861723, fmeasure_max= 0.795262, precision= 0.784641, recall= 0.806175
# Validation Random guess:  auc= 0.227544, fmeasure_max= 0.371816, precision= 0.230328, recall= 0.963979
# Minibatch Loss= 0.610471
# Tarin Iter 1200, auc= 0.829482, fmeasure_max= 0.812450, precision= 0.822294, recall= 0.802839
# Train Random guess:  , auc= 0.242101fmeasure_max= 0.398738, precision= 0.249211, recall= 0.996845
# Validation Iter 1200, auc= 0.855146, fmeasure_max= 0.787724, precision= 0.783051, recall= 0.792453
# Validation Random guess:  auc= 0.235272, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.658368
# Tarin Iter 1300, auc= 0.919119, fmeasure_max= 0.862576, precision= 0.851536, recall= 0.873905
# Train Random guess:  , auc= 0.229621fmeasure_max= 0.365323, precision= 0.223483, recall= 1.000000
# Validation Iter 1300, auc= 0.852168, fmeasure_max= 0.781491, precision= 0.780822, recall= 0.782161
# Validation Random guess:  auc= 0.229685, fmeasure_max= 0.374206, precision= 0.232365, recall= 0.960549
# Minibatch Loss= 0.531369
# Tarin Iter 1400, auc= 0.926002, fmeasure_max= 0.870624, precision= 0.899371, recall= 0.843658
# Train Random guess:  , auc= 0.260761fmeasure_max= 0.420720, precision= 0.267685, recall= 0.982301
# Validation Iter 1400, auc= 0.859643, fmeasure_max= 0.787625, precision= 0.768352, recall= 0.807890
# Validation Random guess:  auc= 0.228989, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.589344
# Tarin Iter 1500, auc= 0.907609, fmeasure_max= 0.830479, precision= 0.804312, recall= 0.858407
# Train Random guess:  , auc= 0.230192fmeasure_max= 0.361600, precision= 0.220703, recall= 1.000000
# Validation Iter 1500, auc= 0.876864, fmeasure_max= 0.813993, precision= 0.809847, recall= 0.818182
# Validation Random guess:  auc= 0.221330, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.581227
# Tarin Iter 1600, auc= 0.863851, fmeasure_max= 0.808682, precision= 0.836938, recall= 0.782271
# Train Random guess:  , auc= 0.252263fmeasure_max= 0.401499, precision= 0.251172, recall= 1.000000
# Validation Iter 1600, auc= 0.883248, fmeasure_max= 0.808362, precision= 0.821239, recall= 0.795883
# Validation Random guess:  auc= 0.232292, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.696102
# Tarin Iter 1700, auc= 0.913529, fmeasure_max= 0.830508, precision= 0.839041, recall= 0.822148
# Train Random guess:  , auc= 0.244705fmeasure_max= 0.377933, precision= 0.232995, recall= 1.000000
# Validation Iter 1700, auc= 0.864200, fmeasure_max= 0.788194, precision= 0.797891, recall= 0.778731
# Validation Random guess:  auc= 0.240940, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.552941
# Tarin Iter 1800, auc= 0.939846, fmeasure_max= 0.889302, precision= 0.919231, recall= 0.861261
# Train Random guess:  , auc= 0.216738fmeasure_max= 0.357192, precision= 0.221266, recall= 0.926126
# Validation Iter 1800, auc= 0.871930, fmeasure_max= 0.797468, precision= 0.843212, recall= 0.756432
# Validation Random guess:  auc= 0.235086, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.484329
# Tarin Iter 1900, auc= 0.930890, fmeasure_max= 0.859594, precision= 0.887279, recall= 0.833585
# Train Random guess:  , auc= 0.261784fmeasure_max= 0.411379, precision= 0.259259, recall= 0.995461
# Validation Iter 1900, auc= 0.868838, fmeasure_max= 0.794063, precision= 0.864646, recall= 0.734134
# Validation Random guess:  auc= 0.238513, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.542979
# Tarin Iter 2000, auc= 0.917259, fmeasure_max= 0.864516, precision= 0.888258, recall= 0.842011
# Train Random guess:  , auc= 0.220431fmeasure_max= 0.359754, precision= 0.219416, recall= 0.998205
# Validation Iter 2000, auc= 0.889608, fmeasure_max= 0.793135, precision= 0.837786, recall= 0.753002
# Validation Random guess:  auc= 0.230454, fmeasure_max= 0.374068, precision= 0.230616, recall= 0.989708
# Minibatch Loss= 0.549950
# Tarin Iter 2100, auc= 0.955080, fmeasure_max= 0.884880, precision= 0.916370, recall= 0.855482
# Train Random guess:  , auc= 0.239520fmeasure_max= 0.380772, precision= 0.235156, recall= 1.000000
# Validation Iter 2100, auc= 0.878353, fmeasure_max= 0.802168, precision= 0.847328, recall= 0.761578
# Validation Random guess:  auc= 0.212861, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.485512
# Tarin Iter 2200, auc= 0.899848, fmeasure_max= 0.853821, precision= 0.887737, recall= 0.822400
# Train Random guess:  , auc= 0.248511fmeasure_max= 0.394258, precision= 0.246215, recall= 0.988800
# Validation Iter 2200, auc= 0.863512, fmeasure_max= 0.814424, precision= 0.835740, recall= 0.794168
# Validation Random guess:  auc= 0.214803, fmeasure_max= 0.373479, precision= 0.229618, recall= 1.000000
# Minibatch Loss= 0.619168
# Tarin Iter 2300, auc= 0.940456, fmeasure_max= 0.868571, precision= 0.889632, recall= 0.848485
# Train Random guess:  , auc= 0.240394fmeasure_max= 0.394207, precision= 0.245587, recall= 0.998405
# Validation Iter 2300, auc= 0.865410, fmeasure_max= 0.794393, precision= 0.872690, recall= 0.728988
# Validation Random guess:  auc= 0.241048, fmeasure_max= 0.371750, precision= 0.228673, recall= 0.993139
# Minibatch Loss= 0.522667
# Tarin Iter 2400, auc= 0.932203, fmeasure_max= 0.860697, precision= 0.885666, recall= 0.837097
# Train Random guess:  , auc= 0.250869fmeasure_max= 0.391153, precision= 0.243222, recall= 0.998387
# Validation Iter 2400, auc= 0.872436, fmeasure_max= 0.800702, precision= 0.820144, recall= 0.782161
# Validation Random guess:  auc= 0.232646, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.554706
# Tarin Iter 2500, auc= 0.931404, fmeasure_max= 0.875912, precision= 0.912548, recall= 0.842105
# Train Random guess:  , auc= 0.231623fmeasure_max= 0.365756, precision= 0.225740, recall= 0.963158
# Validation Iter 2500, auc= 0.871965, fmeasure_max= 0.801330, precision= 0.777419, recall= 0.826758
# Validation Random guess:  auc= 0.216745, fmeasure_max= 0.373125, precision= 0.230366, recall= 0.981132
# Minibatch Loss= 0.487820
# Tarin Iter 2600, auc= 0.942873, fmeasure_max= 0.884120, precision= 0.908289, recall= 0.861204
# Train Random guess:  , auc= 0.230088fmeasure_max= 0.379585, precision= 0.234529, recall= 0.994983
# Validation Iter 2600, auc= 0.859977, fmeasure_max= 0.798568, precision= 0.835206, recall= 0.765009
# Validation Random guess:  auc= 0.234236, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.521813
# Tarin Iter 2700, auc= 0.942634, fmeasure_max= 0.862007, precision= 0.871377, recall= 0.852837
# Train Random guess:  , auc= 0.217956fmeasure_max= 0.361985, precision= 0.221516, recall= 0.989362
# Validation Iter 2700, auc= 0.880481, fmeasure_max= 0.818101, precision= 0.847426, recall= 0.790738
# Validation Random guess:  auc= 0.241304, fmeasure_max= 0.371928, precision= 0.229175, recall= 0.986278
# Minibatch Loss= 0.441382
# Tarin Iter 2800, auc= 0.892375, fmeasure_max= 0.823748, precision= 0.840909, recall= 0.807273
# Train Random guess:  , auc= 0.217694fmeasure_max= 0.353812, precision= 0.214928, recall= 1.000000
# Validation Iter 2800, auc= 0.877214, fmeasure_max= 0.815946, precision= 0.807047, recall= 0.825043
# Validation Random guess:  auc= 0.221935, fmeasure_max= 0.373037, precision= 0.230489, recall= 0.977702
# Minibatch Loss= 0.549077
# Tarin Iter 2900, auc= 0.929522, fmeasure_max= 0.863256, precision= 0.875472, recall= 0.851376
# Train Random guess:  , auc= 0.213514fmeasure_max= 0.351150, precision= 0.213218, recall= 0.994495
# Validation Iter 2900, auc= 0.883967, fmeasure_max= 0.824336, precision= 0.823630, recall= 0.825043
# Validation Random guess:  auc= 0.225402, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.476114
# Tarin Iter 3000, auc= 0.955265, fmeasure_max= 0.891667, precision= 0.867099, recall= 0.917667
# Train Random guess:  , auc= 0.228422fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Validation Iter 3000, auc= 0.869353, fmeasure_max= 0.799296, precision= 0.820976, recall= 0.778731
# Validation Random guess:  auc= 0.235206, fmeasure_max= 0.371859, precision= 0.231057, recall= 0.951973
# Minibatch Loss= 0.401865
# Tarin Iter 3100, auc= 0.881146, fmeasure_max= 0.802710, precision= 0.790000, recall= 0.815835
# Train Random guess:  , auc= 0.233873fmeasure_max= 0.369946, precision= 0.226953, recall= 1.000000
# Validation Iter 3100, auc= 0.842289, fmeasure_max= 0.788889, precision= 0.857143, recall= 0.730703
# Validation Random guess:  auc= 0.212641, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.606136
# Tarin Iter 3200, auc= 0.933813, fmeasure_max= 0.861595, precision= 0.878505, recall= 0.845324
# Train Random guess:  , auc= 0.216019fmeasure_max= 0.358791, precision= 0.218961, recall= 0.992806
# Validation Iter 3200, auc= 0.868486, fmeasure_max= 0.808905, precision= 0.880808, recall= 0.747856
# Validation Random guess:  auc= 0.235759, fmeasure_max= 0.372549, precision= 0.230117, recall= 0.977702
# Minibatch Loss= 0.463156
# Tarin Iter 3300, auc= 0.919757, fmeasure_max= 0.845309, precision= 0.843170, recall= 0.847458
# Train Random guess:  , auc= 0.236406fmeasure_max= 0.374722, precision= 0.230559, recall= 1.000000
# Validation Iter 3300, auc= 0.867020, fmeasure_max= 0.800000, precision= 0.859961, recall= 0.747856
# Validation Random guess:  auc= 0.225666, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.533865
# Tarin Iter 3400, auc= 0.913815, fmeasure_max= 0.835740, precision= 0.812281, recall= 0.860595
# Train Random guess:  , auc= 0.213515fmeasure_max= 0.347736, precision= 0.213588, recall= 0.934944
# Validation Iter 3400, auc= 0.877534, fmeasure_max= 0.807520, precision= 0.844569, recall= 0.773585
# Validation Random guess:  auc= 0.216945, fmeasure_max= 0.371943, precision= 0.228911, recall= 0.991424
# Minibatch Loss= 0.499239
# Tarin Iter 3500, auc= 0.925669, fmeasure_max= 0.863704, precision= 0.856094, recall= 0.871450
# Train Random guess:  , auc= 0.257415fmeasure_max= 0.414627, precision= 0.261532, recall= 1.000000
# Validation Iter 3500, auc= 0.848336, fmeasure_max= 0.782274, precision= 0.892308, recall= 0.696398
# Validation Random guess:  auc= 0.234636, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.588306
# Tarin Iter 3600, auc= 0.907198, fmeasure_max= 0.835210, precision= 0.898678, recall= 0.780115
# Train Random guess:  , auc= 0.227493fmeasure_max= 0.339500, precision= 0.204457, recall= 1.000000
# Validation Iter 3600, auc= 0.859595, fmeasure_max= 0.798568, precision= 0.835206, recall= 0.765009
# Validation Random guess:  auc= 0.230371, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.532479
# Tarin Iter 3700, auc= 0.940597, fmeasure_max= 0.864742, precision= 0.886293, recall= 0.844214
# Train Random guess:  , auc= 0.266892fmeasure_max= 0.418069, precision= 0.264590, recall= 0.995549
# Validation Iter 3700, auc= 0.861276, fmeasure_max= 0.795620, precision= 0.849903, recall= 0.747856
# Validation Random guess:  auc= 0.227965, fmeasure_max= 0.372244, precision= 0.229508, recall= 0.984563
# Minibatch Loss= 0.554869
# Tarin Iter 3800, auc= 0.931522, fmeasure_max= 0.864865, precision= 0.866995, recall= 0.862745
# Train Random guess:  , auc= 0.241539fmeasure_max= 0.385876, precision= 0.239063, recall= 1.000000
# Validation Iter 3800, auc= 0.855702, fmeasure_max= 0.801425, precision= 0.833333, recall= 0.771870
# Validation Random guess:  auc= 0.236790, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.520128
# Tarin Iter 3900, auc= 0.930393, fmeasure_max= 0.838710, precision= 0.879865, recall= 0.801233
# Train Random guess:  , auc= 0.254610fmeasure_max= 0.406566, precision= 0.255657, recall= 0.992296
# Validation Iter 3900, auc= 0.873099, fmeasure_max= 0.806678, precision= 0.827027, recall= 0.787307
# Validation Random guess:  auc= 0.230382, fmeasure_max= 0.372562, precision= 0.229844, recall= 0.982847
# Minibatch Loss= 0.513893
# Tarin Iter 4000, auc= 0.948733, fmeasure_max= 0.883287, precision= 0.907869, recall= 0.860000
# Train Random guess:  , auc= 0.219053fmeasure_max= 0.353777, precision= 0.215071, recall= 0.996364
# Validation Iter 4000, auc= 0.849572, fmeasure_max= 0.785847, precision= 0.859470, recall= 0.723842
# Validation Random guess:  auc= 0.232387, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.463418
# Tarin Iter 4100, auc= 0.952797, fmeasure_max= 0.878788, precision= 0.887279, recall= 0.870458
# Train Random guess:  , auc= 0.265859fmeasure_max= 0.397208, precision= 0.248511, recall= 0.988942
# Validation Iter 4100, auc= 0.861910, fmeasure_max= 0.790617, precision= 0.801056, recall= 0.780446
# Validation Random guess:  auc= 0.221895, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.494278
# Tarin Iter 4200, auc= 0.919560, fmeasure_max= 0.868621, precision= 0.915332, recall= 0.826446
# Train Random guess:  , auc= 0.195304fmeasure_max= 0.319493, precision= 0.192536, recall= 0.938017
# Validation Iter 4200, auc= 0.865344, fmeasure_max= 0.796791, precision= 0.829314, recall= 0.766724
# Validation Random guess:  auc= 0.233626, fmeasure_max= 0.372199, precision= 0.229567, recall= 0.982847
# Minibatch Loss= 0.431756
# Tarin Iter 4300, auc= 0.971956, fmeasure_max= 0.917258, precision= 0.932692, recall= 0.902326
# Train Random guess:  , auc= 0.247489fmeasure_max= 0.402999, precision= 0.252347, recall= 1.000000
# Validation Iter 4300, auc= 0.862377, fmeasure_max= 0.789127, precision= 0.759113, recall= 0.821612
# Validation Random guess:  auc= 0.232250, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.460580
# Tarin Iter 4400, auc= 0.939203, fmeasure_max= 0.882769, precision= 0.855183, recall= 0.912195
# Train Random guess:  , auc= 0.228197fmeasure_max= 0.388362, precision= 0.241068, recall= 0.998374
# Validation Iter 4400, auc= 0.870889, fmeasure_max= 0.800681, precision= 0.795262, recall= 0.806175
# Validation Random guess:  auc= 0.225502, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.510090
# Tarin Iter 4500, auc= 0.944742, fmeasure_max= 0.872659, precision= 0.841155, recall= 0.906615
# Train Random guess:  , auc= 0.206209fmeasure_max= 0.338065, precision= 0.203579, recall= 0.996109
# Validation Iter 4500, auc= 0.857658, fmeasure_max= 0.790816, precision= 0.784148, recall= 0.797599
# Validation Random guess:  auc= 0.227660, fmeasure_max= 0.372093, precision= 0.229208, recall= 0.987993
# Minibatch Loss= 0.428017
# Tarin Iter 4600, auc= 0.931683, fmeasure_max= 0.856925, precision= 0.889415, recall= 0.826725
# Train Random guess:  , auc= 0.273506fmeasure_max= 0.420760, precision= 0.266432, recall= 1.000000
# Validation Iter 4600, auc= 0.855468, fmeasure_max= 0.781609, precision= 0.806569, recall= 0.758148
# Validation Random guess:  auc= 0.232507, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.566040
# Tarin Iter 4700, auc= 0.915354, fmeasure_max= 0.831336, precision= 0.877432, recall= 0.789842
# Train Random guess:  , auc= 0.224609fmeasure_max= 0.364740, precision= 0.223047, recall= 1.000000
# Validation Iter 4700, auc= 0.866550, fmeasure_max= 0.800347, precision= 0.810193, recall= 0.790738
# Validation Random guess:  auc= 0.226718, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.512317
# Tarin Iter 4800, auc= 0.950996, fmeasure_max= 0.887446, precision= 0.919283, recall= 0.857741
# Train Random guess:  , auc= 0.288478fmeasure_max= 0.437595, precision= 0.280078, recall= 1.000000
# Validation Iter 4800, auc= 0.857614, fmeasure_max= 0.791019, precision= 0.796522, recall= 0.785592
# Validation Random guess:  auc= 0.237929, fmeasure_max= 0.372530, precision= 0.229633, recall= 0.986278
# Minibatch Loss= 0.537530
# Tarin Iter 4900, auc= 0.914250, fmeasure_max= 0.835081, precision= 0.906832, recall= 0.773852
# Train Random guess:  , auc= 0.250041fmeasure_max= 0.364063, precision= 0.224659, recall= 0.959364
# Validation Iter 4900, auc= 0.864688, fmeasure_max= 0.802502, precision= 0.837687, recall= 0.770154
# Validation Random guess:  auc= 0.221524, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.528748
# Tarin Iter 5000, auc= 0.914447, fmeasure_max= 0.836988, precision= 0.862475, recall= 0.812963
# Train Random guess:  , auc= 0.215065fmeasure_max= 0.349206, precision= 0.211622, recall= 0.998148
# Validation Iter 5000, auc= 0.862759, fmeasure_max= 0.802480, precision= 0.829670, recall= 0.777015
# Validation Random guess:  auc= 0.221980, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.509570
# Tarin Iter 5100, auc= 0.953803, fmeasure_max= 0.882963, precision= 0.868805, recall= 0.897590
# Train Random guess:  , auc= 0.257392fmeasure_max= 0.412166, precision= 0.259578, recall= 1.000000
# Validation Iter 5100, auc= 0.864754, fmeasure_max= 0.799644, precision= 0.831481, recall= 0.770154
# Validation Random guess:  auc= 0.243460, fmeasure_max= 0.371641, precision= 0.229050, recall= 0.984563
# Minibatch Loss= 0.508010
# Tarin Iter 5200, auc= 0.949594, fmeasure_max= 0.883465, precision= 0.889065, recall= 0.877934
# Train Random guess:  , auc= 0.254742fmeasure_max= 0.402923, precision= 0.252791, recall= 0.992175
# Validation Iter 5200, auc= 0.868216, fmeasure_max= 0.802039, precision= 0.794613, recall= 0.809605
# Validation Random guess:  auc= 0.232679, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.481109
# Tarin Iter 5300, auc= 0.951600, fmeasure_max= 0.883567, precision= 0.869919, recall= 0.897651
# Train Random guess:  , auc= 0.235272fmeasure_max= 0.377813, precision= 0.232903, recall= 1.000000
# Validation Iter 5300, auc= 0.861072, fmeasure_max= 0.794092, precision= 0.804577, recall= 0.783877
# Validation Random guess:  auc= 0.221403, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.466939
# Tarin Iter 5400, auc= 0.943397, fmeasure_max= 0.869565, precision= 0.857143, recall= 0.882353
# Train Random guess:  , auc= 0.226605fmeasure_max= 0.368926, precision= 0.226275, recall= 0.998270
# Validation Iter 5400, auc= 0.853279, fmeasure_max= 0.793594, precision= 0.824399, recall= 0.765009
# Validation Random guess:  auc= 0.226919, fmeasure_max= 0.372033, precision= 0.228797, recall= 0.994854
# Minibatch Loss= 0.499771
# Tarin Iter 5500, auc= 0.946944, fmeasure_max= 0.880249, precision= 0.841010, recall= 0.923328
# Train Random guess:  , auc= 0.235639fmeasure_max= 0.386995, precision= 0.239922, recall= 1.000000
# Validation Iter 5500, auc= 0.859754, fmeasure_max= 0.804252, precision= 0.831502, recall= 0.778731
# Validation Random guess:  auc= 0.238148, fmeasure_max= 0.372765, precision= 0.233118, recall= 0.929674
# Minibatch Loss= 0.493507
# Tarin Iter 5600, auc= 0.907421, fmeasure_max= 0.830692, precision= 0.781790, recall= 0.886121
# Train Random guess:  , auc= 0.223487fmeasure_max= 0.360951, precision= 0.220219, recall= 1.000000
# Validation Iter 5600, auc= 0.841848, fmeasure_max= 0.781879, precision= 0.765189, recall= 0.799314
# Validation Random guess:  auc= 0.246054, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.518674
# Tarin Iter 5700, auc= 0.925359, fmeasure_max= 0.836866, precision= 0.900794, recall= 0.781411
# Train Random guess:  , auc= 0.233925fmeasure_max= 0.370489, precision= 0.227451, recall= 0.998279
# Validation Iter 5700, auc= 0.847285, fmeasure_max= 0.809228, precision= 0.838235, recall= 0.782161
# Validation Random guess:  auc= 0.224659, fmeasure_max= 0.371925, precision= 0.229927, recall= 0.972556
# Minibatch Loss= 0.510733
# Tarin Iter 5800, auc= 0.941403, fmeasure_max= 0.877342, precision= 0.871404, recall= 0.883362
# Train Random guess:  , auc= 0.243075fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Validation Iter 5800, auc= 0.860215, fmeasure_max= 0.797178, precision= 0.820327, recall= 0.775300
# Validation Random guess:  auc= 0.238830, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.468150
# Tarin Iter 5900, auc= 0.920977, fmeasure_max= 0.842105, precision= 0.833922, recall= 0.850450
# Train Random guess:  , auc= 0.224044fmeasure_max= 0.357916, precision= 0.220325, recall= 0.953153
# Validation Iter 5900, auc= 0.854691, fmeasure_max= 0.803524, precision= 0.826087, recall= 0.782161
# Validation Random guess:  auc= 0.233708, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.487957
# Tarin Iter 6000, auc= 0.952308, fmeasure_max= 0.886076, precision= 0.834327, recall= 0.944669
# Train Random guess:  , auc= 0.272583fmeasure_max= 0.448955, precision= 0.289453, recall= 1.000000
# Validation Iter 6000, auc= 0.869714, fmeasure_max= 0.803524, precision= 0.826087, recall= 0.782161
# Validation Random guess:  auc= 0.227832, fmeasure_max= 0.373212, precision= 0.230245, recall= 0.984563
# Minibatch Loss= 0.559019
# Tarin Iter 6100, auc= 0.962926, fmeasure_max= 0.902816, precision= 0.898734, recall= 0.906934
# Train Random guess:  , auc= 0.225427fmeasure_max= 0.353891, precision= 0.214986, recall= 1.000000
# Validation Iter 6100, auc= 0.854949, fmeasure_max= 0.799644, precision= 0.831481, recall= 0.770154
# Validation Random guess:  auc= 0.232797, fmeasure_max= 0.373154, precision= 0.229554, recall= 0.996569
# Minibatch Loss= 0.428544
# Tarin Iter 6200, auc= 0.958049, fmeasure_max= 0.895175, precision= 0.914966, recall= 0.876221
# Train Random guess:  , auc= 0.236050fmeasure_max= 0.388126, precision= 0.241366, recall= 0.990228
# Validation Iter 6200, auc= 0.873969, fmeasure_max= 0.797546, precision= 0.815412, recall= 0.780446
# Validation Random guess:  auc= 0.232105, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.487787
# Tarin Iter 6300, auc= 0.910889, fmeasure_max= 0.828383, precision= 0.856655, recall= 0.801917
# Train Random guess:  , auc= 0.263839fmeasure_max= 0.393216, precision= 0.244722, recall= 1.000000
# Validation Iter 6300, auc= 0.861031, fmeasure_max= 0.801826, precision= 0.857422, recall= 0.753002
# Validation Random guess:  auc= 0.231505, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.546662
# Tarin Iter 6400, auc= 0.912801, fmeasure_max= 0.833333, precision= 0.836653, recall= 0.830040
# Train Random guess:  , auc= 0.205758fmeasure_max= 0.330719, precision= 0.198121, recall= 1.000000
# Validation Iter 6400, auc= 0.859851, fmeasure_max= 0.799652, precision= 0.812389, recall= 0.787307
# Validation Random guess:  auc= 0.232556, fmeasure_max= 0.375365, precision= 0.231415, recall= 0.993139
# Minibatch Loss= 0.455875
# Tarin Iter 6500, auc= 0.937827, fmeasure_max= 0.864025, precision= 0.844985, recall= 0.883943
# Train Random guess:  , auc= 0.248408fmeasure_max= 0.394729, precision= 0.245895, recall= 1.000000
# Validation Iter 6500, auc= 0.862881, fmeasure_max= 0.811828, precision= 0.849906, recall= 0.777015
# Validation Random guess:  auc= 0.251041, fmeasure_max= 0.372569, precision= 0.232538, recall= 0.936535
# Minibatch Loss= 0.513728
# Tarin Iter 6600, auc= 0.954261, fmeasure_max= 0.885789, precision= 0.923636, recall= 0.850921
# Train Random guess:  , auc= 0.251462fmeasure_max= 0.378207, precision= 0.233203, recall= 1.000000
# Validation Iter 6600, auc= 0.867655, fmeasure_max= 0.809187, precision= 0.834244, recall= 0.785592
# Validation Random guess:  auc= 0.215426, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.446743
# Tarin Iter 6700, auc= 0.948203, fmeasure_max= 0.880929, precision= 0.906375, recall= 0.856874
# Train Random guess:  , auc= 0.224888fmeasure_max= 0.343689, precision= 0.207503, recall= 1.000000
# Validation Iter 6700, auc= 0.869353, fmeasure_max= 0.810762, precision= 0.849624, recall= 0.775300
# Validation Random guess:  auc= 0.224678, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.436142
# Tarin Iter 6800, auc= 0.946380, fmeasure_max= 0.895470, precision= 0.865320, recall= 0.927798
# Train Random guess:  , auc= 0.222038fmeasure_max= 0.356589, precision= 0.217152, recall= 0.996390
# Validation Iter 6800, auc= 0.858575, fmeasure_max= 0.814947, precision= 0.846580, recall= 0.785592
# Validation Random guess:  auc= 0.242583, fmeasure_max= 0.375826, precision= 0.232720, recall= 0.975986
# Minibatch Loss= 0.437018
# Tarin Iter 6900, auc= 0.955185, fmeasure_max= 0.890809, precision= 0.894322, recall= 0.887324
# Train Random guess:  , auc= 0.247199fmeasure_max= 0.399500, precision= 0.249609, recall= 1.000000
# Validation Iter 6900, auc= 0.864719, fmeasure_max= 0.797127, precision= 0.836158, recall= 0.761578
# Validation Random guess:  auc= 0.232914, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.485015
# Tarin Iter 7000, auc= 0.950109, fmeasure_max= 0.877519, precision= 0.912903, recall= 0.844776
# Train Random guess:  , auc= 0.263445fmeasure_max= 0.415177, precision= 0.262803, recall= 0.988060
# Validation Iter 7000, auc= 0.856726, fmeasure_max= 0.804518, precision= 0.815141, recall= 0.794168
# Validation Random guess:  auc= 0.222247, fmeasure_max= 0.371200, precision= 0.228167, recall= 0.994854
# Minibatch Loss= 0.524816
# Tarin Iter 7100, auc= 0.930920, fmeasure_max= 0.853526, precision= 0.883895, recall= 0.825175
# Train Random guess:  , auc= 0.233455fmeasure_max= 0.366731, precision= 0.224626, recall= 0.998252
# Validation Iter 7100, auc= 0.853950, fmeasure_max= 0.805430, precision= 0.852490, recall= 0.763293
# Validation Random guess:  auc= 0.222011, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.493625
# Tarin Iter 7200, auc= 0.967191, fmeasure_max= 0.904930, precision= 0.926126, recall= 0.884682
# Train Random guess:  , auc= 0.226011fmeasure_max= 0.370489, precision= 0.227451, recall= 0.998279
# Validation Iter 7200, auc= 0.858315, fmeasure_max= 0.822907, precision= 0.846014, recall= 0.801029
# Validation Random guess:  auc= 0.243270, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.411822
# Tarin Iter 7300, auc= 0.932554, fmeasure_max= 0.848972, precision= 0.866788, recall= 0.831874
# Train Random guess:  , auc= 0.220960fmeasure_max= 0.364856, precision= 0.223134, recall= 1.000000
# Validation Iter 7300, auc= 0.881688, fmeasure_max= 0.814685, precision= 0.830660, recall= 0.799314
# Validation Random guess:  auc= 0.235703, fmeasure_max= 0.373741, precision= 0.230553, recall= 0.986278
# Minibatch Loss= 0.462767
# Tarin Iter 7400, auc= 0.958912, fmeasure_max= 0.891667, precision= 0.879934, recall= 0.903716
# Train Random guess:  , auc= 0.237678fmeasure_max= 0.376313, precision= 0.231856, recall= 0.998311
# Validation Iter 7400, auc= 0.864795, fmeasure_max= 0.793403, precision= 0.803163, recall= 0.783877
# Validation Random guess:  auc= 0.233597, fmeasure_max= 0.373281, precision= 0.230676, recall= 0.977702
# Minibatch Loss= 0.450404
# Tarin Iter 7500, auc= 0.955602, fmeasure_max= 0.896364, precision= 0.850000, recall= 0.948077
# Train Random guess:  , auc= 0.204908fmeasure_max= 0.337992, precision= 0.203363, recall= 1.000000
# Validation Iter 7500, auc= 0.864753, fmeasure_max= 0.816071, precision= 0.851024, recall= 0.783877
# Validation Random guess:  auc= 0.214888, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.377484
# Tarin Iter 7600, auc= 0.965349, fmeasure_max= 0.909248, precision= 0.927690, recall= 0.891525
# Train Random guess:  , auc= 0.225286fmeasure_max= 0.374841, precision= 0.230649, recall= 1.000000
# Validation Iter 7600, auc= 0.863597, fmeasure_max= 0.816652, precision= 0.844322, recall= 0.790738
# Validation Random guess:  auc= 0.228948, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.410637
# Tarin Iter 7700, auc= 0.967586, fmeasure_max= 0.913931, precision= 0.938069, recall= 0.891003
# Train Random guess:  , auc= 0.220162fmeasure_max= 0.370984, precision= 0.229414, recall= 0.968858
# Validation Iter 7700, auc= 0.875723, fmeasure_max= 0.810764, precision= 0.820738, recall= 0.801029
# Validation Random guess:  auc= 0.235726, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.448552
# Tarin Iter 7800, auc= 0.940115, fmeasure_max= 0.864567, precision= 0.844615, recall= 0.885484
# Train Random guess:  , auc= 0.237238fmeasure_max= 0.391249, precision= 0.243489, recall= 0.995161
# Validation Iter 7800, auc= 0.874376, fmeasure_max= 0.820690, precision= 0.824957, recall= 0.816467
# Validation Random guess:  auc= 0.224253, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.545038
# Tarin Iter 7900, auc= 0.947117, fmeasure_max= 0.882450, precision= 0.876645, recall= 0.888333
# Train Random guess:  , auc= 0.231327fmeasure_max= 0.379987, precision= 0.234558, recall= 1.000000
# Validation Iter 7900, auc= 0.872769, fmeasure_max= 0.815398, precision= 0.832143, recall= 0.799314
# Validation Random guess:  auc= 0.221061, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.459991
# Tarin Iter 8000, auc= 0.947413, fmeasure_max= 0.898914, precision= 0.895175, recall= 0.902685
# Train Random guess:  , auc= 0.238798fmeasure_max= 0.378793, precision= 0.233925, recall= 0.994966
# Validation Iter 8000, auc= 0.868134, fmeasure_max= 0.813285, precision= 0.853107, recall= 0.777015
# Validation Random guess:  auc= 0.240885, fmeasure_max= 0.373001, precision= 0.229257, recall= 1.000000
# Minibatch Loss= 0.468254
# Tarin Iter 8100, auc= 0.968415, fmeasure_max= 0.912602, precision= 0.927686, recall= 0.898000
# Train Random guess:  , auc= 0.208569fmeasure_max= 0.331361, precision= 0.200590, recall= 0.952000
# Validation Iter 8100, auc= 0.865398, fmeasure_max= 0.819383, precision= 0.842391, recall= 0.797599
# Validation Random guess:  auc= 0.235194, fmeasure_max= 0.372859, precision= 0.229697, recall= 0.989708
# Minibatch Loss= 0.351346
# Tarin Iter 8200, auc= 0.953244, fmeasure_max= 0.885798, precision= 0.884503, recall= 0.887097
# Train Random guess:  , auc= 0.259108fmeasure_max= 0.421183, precision= 0.266981, recall= 0.997067
# Validation Iter 8200, auc= 0.853522, fmeasure_max= 0.803109, precision= 0.808696, recall= 0.797599
# Validation Random guess:  auc= 0.227792, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.478615
# Tarin Iter 8300, auc= 0.957071, fmeasure_max= 0.888655, precision= 0.894292, recall= 0.883090
# Train Random guess:  , auc= 0.172203fmeasure_max= 0.316485, precision= 0.187991, recall= 1.000000
# Validation Iter 8300, auc= 0.869083, fmeasure_max= 0.815013, precision= 0.850746, recall= 0.782161
# Validation Random guess:  auc= 0.244826, fmeasure_max= 0.371127, precision= 0.228022, recall= 0.996569
# Minibatch Loss= 0.382185
# Tarin Iter 8400, auc= 0.961852, fmeasure_max= 0.889552, precision= 0.867540, recall= 0.912711
# Train Random guess:  , auc= 0.253355fmeasure_max= 0.407675, precision= 0.256532, recall= 0.992343
# Validation Iter 8400, auc= 0.870374, fmeasure_max= 0.808171, precision= 0.837937, recall= 0.780446
# Validation Random guess:  auc= 0.224656, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.520117
# Tarin Iter 8500, auc= 0.949946, fmeasure_max= 0.900840, precision= 0.891847, recall= 0.910017
# Train Random guess:  , auc= 0.250575fmeasure_max= 0.374628, precision= 0.232568, recall= 0.962649
# Validation Iter 8500, auc= 0.876203, fmeasure_max= 0.814286, precision= 0.849162, recall= 0.782161
# Validation Random guess:  auc= 0.234615, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.419823
# Tarin Iter 8600, auc= 0.930275, fmeasure_max= 0.854529, precision= 0.869646, recall= 0.839928
# Train Random guess:  , auc= 0.222637fmeasure_max= 0.360313, precision= 0.220096, recall= 0.992806
# Validation Iter 8600, auc= 0.873520, fmeasure_max= 0.814286, precision= 0.849162, recall= 0.782161
# Validation Random guess:  auc= 0.234783, fmeasure_max= 0.372168, precision= 0.229358, recall= 0.986278
# Minibatch Loss= 0.517633
# Tarin Iter 8700, auc= 0.945810, fmeasure_max= 0.870717, precision= 0.891547, recall= 0.850837
# Train Random guess:  , auc= 0.267309fmeasure_max= 0.409616, precision= 0.257659, recall= 0.998478
# Validation Iter 8700, auc= 0.870100, fmeasure_max= 0.823325, precision= 0.835689, recall= 0.811321
# Validation Random guess:  auc= 0.222968, fmeasure_max= 0.373569, precision= 0.230800, recall= 0.979417
# Minibatch Loss= 0.545973
# Tarin Iter 8800, auc= 0.960883, fmeasure_max= 0.904006, precision= 0.895210, recall= 0.912977
# Train Random guess:  , auc= 0.255588fmeasure_max= 0.407592, precision= 0.255959, recall= 1.000000
# Validation Iter 8800, auc= 0.886697, fmeasure_max= 0.829525, precision= 0.850450, recall= 0.809605
# Validation Random guess:  auc= 0.230421, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.431303
# Tarin Iter 8900, auc= 0.954702, fmeasure_max= 0.874693, precision= 0.857143, recall= 0.892977
# Train Random guess:  , auc= 0.227845fmeasure_max= 0.378841, precision= 0.233685, recall= 1.000000
# Validation Iter 8900, auc= 0.875995, fmeasure_max= 0.816221, precision= 0.821181, recall= 0.811321
# Validation Random guess:  auc= 0.221303, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.417253
# Tarin Iter 9000, auc= 0.964225, fmeasure_max= 0.911111, precision= 0.901099, recall= 0.921348
# Train Random guess:  , auc= 0.207424fmeasure_max= 0.346304, precision= 0.209412, recall= 1.000000
# Validation Iter 9000, auc= 0.873052, fmeasure_max= 0.822086, precision= 0.840502, recall= 0.804460
# Validation Random guess:  auc= 0.229328, fmeasure_max= 0.372108, precision= 0.228944, recall= 0.993139
# Minibatch Loss= 0.368732
# Tarin Iter 9100, auc= 0.965446, fmeasure_max= 0.904478, precision= 0.897778, recall= 0.911278
# Train Random guess:  , auc= 0.265311fmeasure_max= 0.413729, precision= 0.261024, recall= 0.996992
# Validation Iter 9100, auc= 0.882304, fmeasure_max= 0.823331, precision= 0.811667, recall= 0.835334
# Validation Random guess:  auc= 0.229177, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.476490
# Tarin Iter 9200, auc= 0.967463, fmeasure_max= 0.904239, precision= 0.909953, recall= 0.898596
# Train Random guess:  , auc= 0.243307fmeasure_max= 0.400500, precision= 0.250391, recall= 1.000000
# Validation Iter 9200, auc= 0.876761, fmeasure_max= 0.815208, precision= 0.841241, recall= 0.790738
# Validation Random guess:  auc= 0.229165, fmeasure_max= 0.372168, precision= 0.229358, recall= 0.986278
# Minibatch Loss= 0.465350
# Tarin Iter 9300, auc= 0.959117, fmeasure_max= 0.892278, precision= 0.960986, recall= 0.832740
# Train Random guess:  , auc= 0.217398fmeasure_max= 0.360141, precision= 0.219617, recall= 1.000000
# Validation Iter 9300, auc= 0.889756, fmeasure_max= 0.820946, precision= 0.808652, recall= 0.833619
# Validation Random guess:  auc= 0.240455, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.410889
# Tarin Iter 9400, auc= 0.930683, fmeasure_max= 0.870912, precision= 0.857627, recall= 0.884615
# Train Random guess:  , auc= 0.225688fmeasure_max= 0.365378, precision= 0.223525, recall= 1.000000
# Validation Iter 9400, auc= 0.869638, fmeasure_max= 0.811569, precision= 0.829749, recall= 0.794168
# Validation Random guess:  auc= 0.224090, fmeasure_max= 0.373576, precision= 0.230522, recall= 0.984563
# Minibatch Loss= 0.481896
# Tarin Iter 9500, auc= 0.951303, fmeasure_max= 0.878347, precision= 0.871017, recall= 0.885802
# Train Random guess:  , auc= 0.258409fmeasure_max= 0.406001, precision= 0.255936, recall= 0.981481
# Validation Iter 9500, auc= 0.875617, fmeasure_max= 0.817282, precision= 0.859848, recall= 0.778731
# Validation Random guess:  auc= 0.234738, fmeasure_max= 0.373711, precision= 0.230067, recall= 0.994854
# Minibatch Loss= 0.485322
# Tarin Iter 9600, auc= 0.959387, fmeasure_max= 0.889353, precision= 0.887500, recall= 0.891213
# Train Random guess:  , auc= 0.184099fmeasure_max= 0.315268, precision= 0.187206, recall= 0.997908
# Validation Iter 9600, auc= 0.879939, fmeasure_max= 0.813036, precision= 0.813036, recall= 0.813036
# Validation Random guess:  auc= 0.223061, fmeasure_max= 0.372275, precision= 0.229719, recall= 0.981132
# Minibatch Loss= 0.356217
# Tarin Iter 9700, auc= 0.973192, fmeasure_max= 0.915819, precision= 0.935728, recall= 0.896739
# Train Random guess:  , auc= 0.217919fmeasure_max= 0.354984, precision= 0.215794, recall= 1.000000
# Validation Iter 9700, auc= 0.881225, fmeasure_max= 0.821678, precision= 0.837790, recall= 0.806175
# Validation Random guess:  auc= 0.228145, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.379097
# Tarin Iter 9800, auc= 0.968563, fmeasure_max= 0.908185, precision= 0.886111, recall= 0.931387
# Train Random guess:  , auc= 0.266153fmeasure_max= 0.422709, precision= 0.267997, recall= 1.000000
# Validation Iter 9800, auc= 0.864475, fmeasure_max= 0.807899, precision= 0.847458, recall= 0.771870
# Validation Random guess:  auc= 0.228354, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.466240
# Tarin Iter 9900, auc= 0.960445, fmeasure_max= 0.898810, precision= 0.889543, recall= 0.908271
# Train Random guess:  , auc= 0.258480fmeasure_max= 0.412403, precision= 0.259766, recall= 1.000000
# Validation Iter 9900, auc= 0.893199, fmeasure_max= 0.819556, precision= 0.850554, recall= 0.790738
# Validation Random guess:  auc= 0.222942, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.485763
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.881329 F1_max = 0.799304 prec = 0.823656 rec = 0.776351
# Test Random guess: auc= 0.234047 fmeasure_max= 0.375798 , precision= 0.231410 , recall= 0.999324

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
