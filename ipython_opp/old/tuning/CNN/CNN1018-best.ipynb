# %%
# useing this variable for saving models and summaries
exp_name = "CNN1018"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10



convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [4, 2, 2, 2, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.257973, fmeasure_max= 0.395244, precision= 0.246493, recall= 0.996759
# Train Random guess:  , auc= 0.252727fmeasure_max= 0.390293, precision= 0.245504, recall= 0.951378
# Validation Iter 0, auc= 0.303718, fmeasure_max= 0.375523, precision= 0.231166, recall= 1.000000
# Validation Random guess:  auc= 0.214286, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 1.070181
# Tarin Iter 100, auc= 0.828412, fmeasure_max= 0.796581, precision= 0.835125, recall= 0.761438
# Train Random guess:  , auc= 0.237514fmeasure_max= 0.386933, precision= 0.240063, recall= 0.996732
# Validation Iter 100, auc= 0.802269, fmeasure_max= 0.786667, precision= 0.764992, recall= 0.809605
# Validation Random guess:  auc= 0.239951, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.865988
# Tarin Iter 200, auc= 0.812959, fmeasure_max= 0.796003, precision= 0.804714, recall= 0.787479
# Train Random guess:  , auc= 0.258481fmeasure_max= 0.385774, precision= 0.239459, recall= 0.991763
# Validation Iter 200, auc= 0.794662, fmeasure_max= 0.765354, precision= 0.707424, recall= 0.833619
# Validation Random guess:  auc= 0.220848, fmeasure_max= 0.371327, precision= 0.228719, recall= 0.986278
# Minibatch Loss= 0.758919
# Tarin Iter 300, auc= 0.838513, fmeasure_max= 0.810662, precision= 0.841603, recall= 0.781915
# Train Random guess:  , auc= 0.228299fmeasure_max= 0.362407, precision= 0.221392, recall= 0.998227
# Validation Iter 300, auc= 0.819415, fmeasure_max= 0.772118, precision= 0.805970, recall= 0.740995
# Validation Random guess:  auc= 0.228444, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.663668
# Tarin Iter 400, auc= 0.883111, fmeasure_max= 0.854839, precision= 0.854839, recall= 0.854839
# Train Random guess:  , auc= 0.257052fmeasure_max= 0.391661, precision= 0.243519, recall= 1.000000
# Validation Iter 400, auc= 0.865828, fmeasure_max= 0.811618, precision= 0.786174, recall= 0.838765
# Validation Random guess:  auc= 0.218526, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.684853
# Tarin Iter 500, auc= 0.859725, fmeasure_max= 0.811808, precision= 0.808824, recall= 0.814815
# Train Random guess:  , auc= 0.255852fmeasure_max= 0.418460, precision= 0.265008, recall= 0.994074
# Validation Iter 500, auc= 0.854805, fmeasure_max= 0.796639, precision= 0.780890, recall= 0.813036
# Validation Random guess:  auc= 0.219883, fmeasure_max= 0.375164, precision= 0.232020, recall= 0.979417
# Minibatch Loss= 0.721761
# Tarin Iter 600, auc= 0.883987, fmeasure_max= 0.816720, precision= 0.865417, recall= 0.773212
# Train Random guess:  , auc= 0.270410fmeasure_max= 0.408663, precision= 0.257414, recall= 0.990868
# Validation Iter 600, auc= 0.867107, fmeasure_max= 0.794408, precision= 0.763033, recall= 0.828473
# Validation Random guess:  auc= 0.220351, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.723352
# Tarin Iter 700, auc= 0.863099, fmeasure_max= 0.783037, precision= 0.884187, recall= 0.702655
# Train Random guess:  , auc= 0.220619fmeasure_max= 0.362524, precision= 0.221566, recall= 0.996460
# Validation Iter 700, auc= 0.885212, fmeasure_max= 0.806370, precision= 0.788525, recall= 0.825043
# Validation Random guess:  auc= 0.237854, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.634206
# Tarin Iter 800, auc= 0.834145, fmeasure_max= 0.775272, precision= 0.754472, recall= 0.797251
# Train Random guess:  , auc= 0.233169fmeasure_max= 0.371410, precision= 0.228056, recall= 1.000000
# Validation Iter 800, auc= 0.884961, fmeasure_max= 0.814638, precision= 0.759644, recall= 0.878216
# Validation Random guess:  auc= 0.234117, fmeasure_max= 0.372320, precision= 0.229659, recall= 0.982847
# Minibatch Loss= 0.637803
# Tarin Iter 900, auc= 0.892677, fmeasure_max= 0.854123, precision= 0.897778, recall= 0.814516
# Train Random guess:  , auc= 0.201480fmeasure_max= 0.324714, precision= 0.193826, recall= 1.000000
# Validation Iter 900, auc= 0.888931, fmeasure_max= 0.810903, precision= 0.805415, recall= 0.816467
# Validation Random guess:  auc= 0.237667, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.514188
# Tarin Iter 1000, auc= 0.864115, fmeasure_max= 0.789116, precision= 0.840580, recall= 0.743590
# Train Random guess:  , auc= 0.219017fmeasure_max= 0.352144, precision= 0.213699, recall= 1.000000
# Validation Iter 1000, auc= 0.855291, fmeasure_max= 0.770563, precision= 0.777972, recall= 0.763293
# Validation Random guess:  auc= 0.223942, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.636013
# Tarin Iter 1100, auc= 0.844688, fmeasure_max= 0.790235, precision= 0.843629, recall= 0.743197
# Train Random guess:  , auc= 0.217969fmeasure_max= 0.374479, precision= 0.230739, recall= 0.993197
# Validation Iter 1100, auc= 0.917280, fmeasure_max= 0.836555, precision= 0.857658, recall= 0.816467
# Validation Random guess:  auc= 0.219114, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.711841
# Tarin Iter 1200, auc= 0.861721, fmeasure_max= 0.821074, precision= 0.826000, recall= 0.816206
# Train Random guess:  , auc= 0.203318fmeasure_max= 0.332084, precision= 0.204903, recall= 0.875494
# Validation Iter 1200, auc= 0.886304, fmeasure_max= 0.839041, precision= 0.837607, recall= 0.840480
# Validation Random guess:  auc= 0.231864, fmeasure_max= 0.371630, precision= 0.228583, recall= 0.993139
# Minibatch Loss= 0.640024
# Tarin Iter 1300, auc= 0.937910, fmeasure_max= 0.876764, precision= 0.901354, recall= 0.853480
# Train Random guess:  , auc= 0.222334fmeasure_max= 0.351691, precision= 0.213365, recall= 1.000000
# Validation Iter 1300, auc= 0.910482, fmeasure_max= 0.836109, precision= 0.854839, recall= 0.818182
# Validation Random guess:  auc= 0.235790, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.512372
# Tarin Iter 1400, auc= 0.906009, fmeasure_max= 0.849823, precision= 0.872958, recall= 0.827883
# Train Random guess:  , auc= 0.226504fmeasure_max= 0.370654, precision= 0.227486, recall= 1.000000
# Validation Iter 1400, auc= 0.919406, fmeasure_max= 0.852018, precision= 0.892857, recall= 0.814751
# Validation Random guess:  auc= 0.235257, fmeasure_max= 0.372562, precision= 0.231702, recall= 0.950257
# Minibatch Loss= 0.561189
# Tarin Iter 1500, auc= 0.906663, fmeasure_max= 0.840474, precision= 0.833635, recall= 0.847426
# Train Random guess:  , auc= 0.226726fmeasure_max= 0.353824, precision= 0.219610, recall= 0.909926
# Validation Iter 1500, auc= 0.910792, fmeasure_max= 0.844407, precision= 0.828383, recall= 0.861063
# Validation Random guess:  auc= 0.223244, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.535334
# Tarin Iter 1600, auc= 0.949310, fmeasure_max= 0.885965, precision= 0.916515, recall= 0.857385
# Train Random guess:  , auc= 0.230526fmeasure_max= 0.374444, precision= 0.230348, recall= 1.000000
# Validation Iter 1600, auc= 0.923122, fmeasure_max= 0.852188, precision= 0.821656, recall= 0.885077
# Validation Random guess:  auc= 0.224877, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.456111
# Tarin Iter 1700, auc= 0.942164, fmeasure_max= 0.886076, precision= 0.873544, recall= 0.898973
# Train Random guess:  , auc= 0.241445fmeasure_max= 0.372197, precision= 0.228920, recall= 0.994863
# Validation Iter 1700, auc= 0.904483, fmeasure_max= 0.843860, precision= 0.863555, recall= 0.825043
# Validation Random guess:  auc= 0.243756, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.458078
# Tarin Iter 1800, auc= 0.927769, fmeasure_max= 0.875451, precision= 0.881818, recall= 0.869176
# Train Random guess:  , auc= 0.217060fmeasure_max= 0.358037, precision= 0.218054, recall= 1.000000
# Validation Iter 1800, auc= 0.918690, fmeasure_max= 0.840966, precision= 0.817152, recall= 0.866209
# Validation Random guess:  auc= 0.222935, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.508088
# Tarin Iter 1900, auc= 0.946126, fmeasure_max= 0.857847, precision= 0.808050, recall= 0.914186
# Train Random guess:  , auc= 0.225465fmeasure_max= 0.365893, precision= 0.224900, recall= 0.980736
# Validation Iter 1900, auc= 0.903304, fmeasure_max= 0.836207, precision= 0.840555, recall= 0.831904
# Validation Random guess:  auc= 0.234008, fmeasure_max= 0.371628, precision= 0.230579, recall= 0.957118
# Minibatch Loss= 0.478058
# Tarin Iter 2000, auc= 0.887265, fmeasure_max= 0.814699, precision= 0.837621, recall= 0.792998
# Train Random guess:  , auc= 0.256766fmeasure_max= 0.408764, precision= 0.260308, recall= 0.951294
# Validation Iter 2000, auc= 0.875735, fmeasure_max= 0.823729, precision= 0.814070, recall= 0.833619
# Validation Random guess:  auc= 0.212960, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.611361
# Tarin Iter 2100, auc= 0.947371, fmeasure_max= 0.870918, precision= 0.854962, recall= 0.887480
# Train Random guess:  , auc= 0.260273fmeasure_max= 0.396961, precision= 0.248022, recall= 0.993661
# Validation Iter 2100, auc= 0.880713, fmeasure_max= 0.828058, precision= 0.825939, recall= 0.830189
# Validation Random guess:  auc= 0.235443, fmeasure_max= 0.372303, precision= 0.229183, recall= 0.991424
# Minibatch Loss= 0.497878
# Tarin Iter 2200, auc= 0.897907, fmeasure_max= 0.836224, precision= 0.842718, recall= 0.829828
# Train Random guess:  , auc= 0.207526fmeasure_max= 0.339934, precision= 0.205425, recall= 0.984704
# Validation Iter 2200, auc= 0.915807, fmeasure_max= 0.863322, precision= 0.870855, recall= 0.855918
# Validation Random guess:  auc= 0.230113, fmeasure_max= 0.374058, precision= 0.231174, recall= 0.979417
# Minibatch Loss= 0.517301
# Tarin Iter 2300, auc= 0.958405, fmeasure_max= 0.900185, precision= 0.898524, recall= 0.901852
# Train Random guess:  , auc= 0.210872fmeasure_max= 0.350973, precision= 0.215153, recall= 0.951852
# Validation Iter 2300, auc= 0.890244, fmeasure_max= 0.835821, precision= 0.856115, recall= 0.816467
# Validation Random guess:  auc= 0.231461, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.433864
# Tarin Iter 2400, auc= 0.942293, fmeasure_max= 0.873725, precision= 0.919142, recall= 0.832586
# Train Random guess:  , auc= 0.270352fmeasure_max= 0.414778, precision= 0.261755, recall= 0.998505
# Validation Iter 2400, auc= 0.914409, fmeasure_max= 0.850991, precision= 0.854671, recall= 0.847341
# Validation Random guess:  auc= 0.229123, fmeasure_max= 0.375940, precision= 0.234742, recall= 0.943396
# Minibatch Loss= 0.514433
# Tarin Iter 2500, auc= 0.951581, fmeasure_max= 0.882096, precision= 0.913201, recall= 0.853041
# Train Random guess:  , auc= 0.259713fmeasure_max= 0.378100, precision= 0.233585, recall= 0.991554
# Validation Iter 2500, auc= 0.895887, fmeasure_max= 0.843722, precision= 0.891221, recall= 0.801029
# Validation Random guess:  auc= 0.219975, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.439610
# Tarin Iter 2600, auc= 0.905149, fmeasure_max= 0.846863, precision= 0.861163, recall= 0.833031
# Train Random guess:  , auc= 0.218932fmeasure_max= 0.355729, precision= 0.216601, recall= 0.994555
# Validation Iter 2600, auc= 0.897847, fmeasure_max= 0.850991, precision= 0.854671, recall= 0.847341
# Validation Random guess:  auc= 0.225954, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.556697
# Tarin Iter 2700, auc= 0.965061, fmeasure_max= 0.905532, precision= 0.904762, recall= 0.906303
# Train Random guess:  , auc= 0.224975fmeasure_max= 0.373647, precision= 0.229746, recall= 1.000000
# Validation Iter 2700, auc= 0.909090, fmeasure_max= 0.834448, precision= 0.814029, recall= 0.855918
# Validation Random guess:  auc= 0.232563, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.424211
# Tarin Iter 2800, auc= 0.942591, fmeasure_max= 0.886887, precision= 0.904082, recall= 0.870334
# Train Random guess:  , auc= 0.203685fmeasure_max= 0.334585, precision= 0.202479, recall= 0.962672
# Validation Iter 2800, auc= 0.904961, fmeasure_max= 0.846422, precision= 0.861456, recall= 0.831904
# Validation Random guess:  auc= 0.239211, fmeasure_max= 0.372153, precision= 0.228887, recall= 0.994854
# Minibatch Loss= 0.405413
# Tarin Iter 2900, auc= 0.943532, fmeasure_max= 0.865997, precision= 0.870370, recall= 0.861667
# Train Random guess:  , auc= 0.229284fmeasure_max= 0.380013, precision= 0.234854, recall= 0.995000
# Validation Iter 2900, auc= 0.922119, fmeasure_max= 0.856652, precision= 0.857388, recall= 0.855918
# Validation Random guess:  auc= 0.232511, fmeasure_max= 0.372108, precision= 0.228944, recall= 0.993139
# Minibatch Loss= 0.446519
# Tarin Iter 3000, auc= 0.955368, fmeasure_max= 0.876689, precision= 0.897924, recall= 0.856436
# Train Random guess:  , auc= 0.232507fmeasure_max= 0.384640, precision= 0.239069, recall= 0.983498
# Validation Iter 3000, auc= 0.922718, fmeasure_max= 0.852130, precision= 0.830619, recall= 0.874786
# Validation Random guess:  auc= 0.230212, fmeasure_max= 0.372562, precision= 0.229844, recall= 0.982847
# Minibatch Loss= 0.450675
# Tarin Iter 3100, auc= 0.946924, fmeasure_max= 0.866438, precision= 0.870912, recall= 0.862010
# Train Random guess:  , auc= 0.228025fmeasure_max= 0.374426, precision= 0.231831, recall= 0.972743
# Validation Iter 3100, auc= 0.913522, fmeasure_max= 0.842291, precision= 0.865942, recall= 0.819897
# Validation Random guess:  auc= 0.234732, fmeasure_max= 0.371898, precision= 0.228968, recall= 0.989708
# Minibatch Loss= 0.477113
# Tarin Iter 3200, auc= 0.954248, fmeasure_max= 0.896832, precision= 0.884615, recall= 0.909390
# Train Random guess:  , auc= 0.251787fmeasure_max= 0.385987, precision= 0.239242, recall= 0.998353
# Validation Iter 3200, auc= 0.899642, fmeasure_max= 0.838302, precision= 0.885496, recall= 0.795883
# Validation Random guess:  auc= 0.235593, fmeasure_max= 0.375631, precision= 0.233668, recall= 0.957118
# Minibatch Loss= 0.461172
# Tarin Iter 3300, auc= 0.929848, fmeasure_max= 0.887786, precision= 0.908537, recall= 0.867961
# Train Random guess:  , auc= 0.199688fmeasure_max= 0.339007, precision= 0.206430, recall= 0.947573
# Validation Iter 3300, auc= 0.930953, fmeasure_max= 0.860825, precision= 0.862306, recall= 0.859348
# Validation Random guess:  auc= 0.229141, fmeasure_max= 0.372762, precision= 0.229077, recall= 1.000000
# Minibatch Loss= 0.407939
# Tarin Iter 3400, auc= 0.956366, fmeasure_max= 0.883365, precision= 0.902344, recall= 0.865169
# Train Random guess:  , auc= 0.207631fmeasure_max= 0.345655, precision= 0.209020, recall= 0.998127
# Validation Iter 3400, auc= 0.909486, fmeasure_max= 0.843723, precision= 0.840136, recall= 0.847341
# Validation Random guess:  auc= 0.240568, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.420300
# Tarin Iter 3500, auc= 0.965808, fmeasure_max= 0.905759, precision= 0.901042, recall= 0.910526
# Train Random guess:  , auc= 0.217490fmeasure_max= 0.366534, precision= 0.226044, recall= 0.968421
# Validation Iter 3500, auc= 0.912678, fmeasure_max= 0.839442, precision= 0.854352, recall= 0.825043
# Validation Random guess:  auc= 0.226230, fmeasure_max= 0.372446, precision= 0.230518, recall= 0.969125
# Minibatch Loss= 0.419905
# Tarin Iter 3600, auc= 0.949824, fmeasure_max= 0.889073, precision= 0.892027, recall= 0.886139
# Train Random guess:  , auc= 0.237489fmeasure_max= 0.384369, precision= 0.238474, recall= 0.990099
# Validation Iter 3600, auc= 0.894572, fmeasure_max= 0.832298, precision= 0.862132, recall= 0.804460
# Validation Random guess:  auc= 0.222971, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.478907
# Tarin Iter 3700, auc= 0.945095, fmeasure_max= 0.871332, precision= 0.830703, recall= 0.916139
# Train Random guess:  , auc= 0.265507fmeasure_max= 0.396810, precision= 0.248502, recall= 0.984177
# Validation Iter 3700, auc= 0.912406, fmeasure_max= 0.845415, precision= 0.861210, recall= 0.830189
# Validation Random guess:  auc= 0.218528, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.472471
# Tarin Iter 3800, auc= 0.938714, fmeasure_max= 0.874062, precision= 0.859016, recall= 0.889643
# Train Random guess:  , auc= 0.232556fmeasure_max= 0.375000, precision= 0.230860, recall= 0.998302
# Validation Iter 3800, auc= 0.923858, fmeasure_max= 0.851582, precision= 0.807692, recall= 0.900515
# Validation Random guess:  auc= 0.220834, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.480394
# Tarin Iter 3900, auc= 0.945301, fmeasure_max= 0.874564, precision= 0.829752, recall= 0.924494
# Train Random guess:  , auc= 0.233458fmeasure_max= 0.350549, precision= 0.212524, recall= 1.000000
# Validation Iter 3900, auc= 0.916607, fmeasure_max= 0.830450, precision= 0.837696, recall= 0.823328
# Validation Random guess:  auc= 0.227918, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.447420
# Tarin Iter 4000, auc= 0.933212, fmeasure_max= 0.870420, precision= 0.860424, recall= 0.880651
# Train Random guess:  , auc= 0.223210fmeasure_max= 0.356905, precision= 0.224395, recall= 0.871609
# Validation Iter 4000, auc= 0.905399, fmeasure_max= 0.838998, precision= 0.876636, recall= 0.804460
# Validation Random guess:  auc= 0.219990, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.482360
# Tarin Iter 4100, auc= 0.962624, fmeasure_max= 0.900662, precision= 0.866856, recall= 0.937213
# Train Random guess:  , auc= 0.258375fmeasure_max= 0.406854, precision= 0.255377, recall= 1.000000
# Validation Iter 4100, auc= 0.912444, fmeasure_max= 0.849785, precision= 0.850515, recall= 0.849057
# Validation Random guess:  auc= 0.225063, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.456573
# Tarin Iter 4200, auc= 0.956165, fmeasure_max= 0.893683, precision= 0.892308, recall= 0.895062
# Train Random guess:  , auc= 0.257158fmeasure_max= 0.404168, precision= 0.254069, recall= 0.987654
# Validation Iter 4200, auc= 0.912061, fmeasure_max= 0.844156, precision= 0.801233, recall= 0.891938
# Validation Random guess:  auc= 0.228253, fmeasure_max= 0.371273, precision= 0.228312, recall= 0.993139
# Minibatch Loss= 0.428242
# Tarin Iter 4300, auc= 0.957433, fmeasure_max= 0.890625, precision= 0.899408, recall= 0.882012
# Train Random guess:  , auc= 0.200781fmeasure_max= 0.337027, precision= 0.202666, recall= 1.000000
# Validation Iter 4300, auc= 0.911094, fmeasure_max= 0.840909, precision= 0.857398, recall= 0.825043
# Validation Random guess:  auc= 0.243604, fmeasure_max= 0.373436, precision= 0.229676, recall= 0.998285
# Minibatch Loss= 0.421407
# Tarin Iter 4400, auc= 0.957377, fmeasure_max= 0.890879, precision= 0.916248, recall= 0.866878
# Train Random guess:  , auc= 0.250520fmeasure_max= 0.395611, precision= 0.246581, recall= 1.000000
# Validation Iter 4400, auc= 0.899604, fmeasure_max= 0.821181, precision= 0.831283, recall= 0.811321
# Validation Random guess:  auc= 0.234084, fmeasure_max= 0.372700, precision= 0.231505, recall= 0.955403
# Minibatch Loss= 0.505639
# Tarin Iter 4500, auc= 0.952676, fmeasure_max= 0.878133, precision= 0.923636, recall= 0.836903
# Train Random guess:  , auc= 0.242265fmeasure_max= 0.383883, precision= 0.237721, recall= 0.996705
# Validation Iter 4500, auc= 0.906869, fmeasure_max= 0.842478, precision= 0.870201, recall= 0.816467
# Validation Random guess:  auc= 0.231993, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.475003
# Tarin Iter 4600, auc= 0.963372, fmeasure_max= 0.903175, precision= 0.870031, recall= 0.938944
# Train Random guess:  , auc= 0.241065fmeasure_max= 0.383728, precision= 0.238076, recall= 0.988449
# Validation Iter 4600, auc= 0.891856, fmeasure_max= 0.832320, precision= 0.843310, recall= 0.821612
# Validation Random guess:  auc= 0.216812, fmeasure_max= 0.371659, precision= 0.228787, recall= 0.989708
# Minibatch Loss= 0.412285
# Tarin Iter 4700, auc= 0.963832, fmeasure_max= 0.902066, precision= 0.931354, recall= 0.874564
# Train Random guess:  , auc= 0.216261fmeasure_max= 0.367360, precision= 0.225010, recall= 1.000000
# Validation Iter 4700, auc= 0.909208, fmeasure_max= 0.833188, precision= 0.848754, recall= 0.818182
# Validation Random guess:  auc= 0.218890, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.431080
# Tarin Iter 4800, auc= 0.965208, fmeasure_max= 0.903442, precision= 0.904202, recall= 0.902685
# Train Random guess:  , auc= 0.241369fmeasure_max= 0.377913, precision= 0.233346, recall= 0.993289
# Validation Iter 4800, auc= 0.904538, fmeasure_max= 0.835714, precision= 0.871508, recall= 0.802744
# Validation Random guess:  auc= 0.234146, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.379422
# Tarin Iter 4900, auc= 0.959474, fmeasure_max= 0.900169, precision= 0.898649, recall= 0.901695
# Train Random guess:  , auc= 0.239970fmeasure_max= 0.376868, precision= 0.233119, recall= 0.983051
# Validation Iter 4900, auc= 0.912076, fmeasure_max= 0.846929, precision= 0.909449, recall= 0.792453
# Validation Random guess:  auc= 0.220115, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.395687
# Tarin Iter 5000, auc= 0.943438, fmeasure_max= 0.866507, precision= 0.812594, recall= 0.928082
# Train Random guess:  , auc= 0.240726fmeasure_max= 0.371738, precision= 0.228303, recall= 1.000000
# Validation Iter 5000, auc= 0.913151, fmeasure_max= 0.836855, precision= 0.825000, recall= 0.849057
# Validation Random guess:  auc= 0.236548, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.434266
# Tarin Iter 5100, auc= 0.965206, fmeasure_max= 0.901695, precision= 0.897133, recall= 0.906303
# Train Random guess:  , auc= 0.236408fmeasure_max= 0.373766, precision= 0.229836, recall= 1.000000
# Validation Iter 5100, auc= 0.905876, fmeasure_max= 0.841540, precision= 0.880150, recall= 0.806175
# Validation Random guess:  auc= 0.214702, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.405219
# Tarin Iter 5200, auc= 0.934793, fmeasure_max= 0.886544, precision= 0.900000, recall= 0.873484
# Train Random guess:  , auc= 0.231820fmeasure_max= 0.368220, precision= 0.225655, recall= 1.000000
# Validation Iter 5200, auc= 0.918196, fmeasure_max= 0.833751, precision= 0.812704, recall= 0.855918
# Validation Random guess:  auc= 0.242959, fmeasure_max= 0.371869, precision= 0.228763, recall= 0.993139
# Minibatch Loss= 0.427535
# Tarin Iter 5300, auc= 0.955229, fmeasure_max= 0.872814, precision= 0.902961, recall= 0.844615
# Train Random guess:  , auc= 0.260106fmeasure_max= 0.405388, precision= 0.254524, recall= 0.995385
# Validation Iter 5300, auc= 0.916693, fmeasure_max= 0.845962, precision= 0.822006, recall= 0.871355
# Validation Random guess:  auc= 0.217594, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.538980
# Tarin Iter 5400, auc= 0.955415, fmeasure_max= 0.888889, precision= 0.886700, recall= 0.891089
# Train Random guess:  , auc= 0.229939fmeasure_max= 0.383423, precision= 0.237182, recall= 1.000000
# Validation Iter 5400, auc= 0.915930, fmeasure_max= 0.841837, precision= 0.834739, recall= 0.849057
# Validation Random guess:  auc= 0.225350, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.446442
# Tarin Iter 5500, auc= 0.951798, fmeasure_max= 0.900976, precision= 0.867114, recall= 0.937591
# Train Random guess:  , auc= 0.259061fmeasure_max= 0.425348, precision= 0.270228, recall= 0.998549
# Validation Iter 5500, auc= 0.923476, fmeasure_max= 0.853762, precision= 0.841667, recall= 0.866209
# Validation Random guess:  auc= 0.216176, fmeasure_max= 0.372881, precision= 0.229167, recall= 1.000000
# Minibatch Loss= 0.442552
# Tarin Iter 5600, auc= 0.946912, fmeasure_max= 0.889764, precision= 0.875969, recall= 0.904000
# Train Random guess:  , auc= 0.250172fmeasure_max= 0.392588, precision= 0.244236, recall= 1.000000
# Validation Iter 5600, auc= 0.926823, fmeasure_max= 0.839707, precision= 0.798762, recall= 0.885077
# Validation Random guess:  auc= 0.223746, fmeasure_max= 0.373316, precision= 0.229586, recall= 0.998285
# Minibatch Loss= 0.476904
# Tarin Iter 5700, auc= 0.952428, fmeasure_max= 0.901961, precision= 0.921536, recall= 0.883200
# Train Random guess:  , auc= 0.248775fmeasure_max= 0.393432, precision= 0.245083, recall= 0.996800
# Validation Iter 5700, auc= 0.915011, fmeasure_max= 0.835093, precision= 0.793210, recall= 0.881647
# Validation Random guess:  auc= 0.211790, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.473629
# Tarin Iter 5800, auc= 0.952784, fmeasure_max= 0.876645, precision= 0.888333, recall= 0.865260
# Train Random guess:  , auc= 0.258425fmeasure_max= 0.390132, precision= 0.244637, recall= 0.962662
# Validation Iter 5800, auc= 0.926305, fmeasure_max= 0.847291, precision= 0.812598, recall= 0.885077
# Validation Random guess:  auc= 0.230991, fmeasure_max= 0.373351, precision= 0.231115, recall= 0.970840
# Minibatch Loss= 0.429034
# Tarin Iter 5900, auc= 0.957242, fmeasure_max= 0.891255, precision= 0.905719, recall= 0.877246
# Train Random guess:  , auc= 0.279679fmeasure_max= 0.414375, precision= 0.261848, recall= 0.992515
# Validation Iter 5900, auc= 0.909438, fmeasure_max= 0.834335, precision= 0.835052, recall= 0.833619
# Validation Random guess:  auc= 0.232118, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.507755
# Tarin Iter 6000, auc= 0.939058, fmeasure_max= 0.864777, precision= 0.864078, recall= 0.865478
# Train Random guess:  , auc= 0.261116fmeasure_max= 0.388608, precision= 0.241447, recall= 0.995138
# Validation Iter 6000, auc= 0.910401, fmeasure_max= 0.840555, precision= 0.849387, recall= 0.831904
# Validation Random guess:  auc= 0.227219, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.492537
# Tarin Iter 6100, auc= 0.943483, fmeasure_max= 0.873462, precision= 0.832496, recall= 0.918669
# Train Random guess:  , auc= 0.227614fmeasure_max= 0.351968, precision= 0.214343, recall= 0.983364
# Validation Iter 6100, auc= 0.934782, fmeasure_max= 0.864331, precision= 0.907547, recall= 0.825043
# Validation Random guess:  auc= 0.233332, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.423999
# Tarin Iter 6200, auc= 0.964327, fmeasure_max= 0.896613, precision= 0.885563, recall= 0.907942
# Train Random guess:  , auc= 0.224157fmeasure_max= 0.358784, precision= 0.220698, recall= 0.958484
# Validation Iter 6200, auc= 0.926843, fmeasure_max= 0.851376, precision= 0.915187, recall= 0.795883
# Validation Random guess:  auc= 0.236104, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.391617
# Tarin Iter 6300, auc= 0.978266, fmeasure_max= 0.919201, precision= 0.899660, recall= 0.939609
# Train Random guess:  , auc= 0.225328fmeasure_max= 0.360551, precision= 0.219922, recall= 1.000000
# Validation Iter 6300, auc= 0.922048, fmeasure_max= 0.856887, precision= 0.895327, recall= 0.821612
# Validation Random guess:  auc= 0.254661, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.388530
# Tarin Iter 6400, auc= 0.966595, fmeasure_max= 0.909548, precision= 0.901993, recall= 0.917230
# Train Random guess:  , auc= 0.227646fmeasure_max= 0.377128, precision= 0.232844, recall= 0.991554
# Validation Iter 6400, auc= 0.919553, fmeasure_max= 0.840889, precision= 0.872694, recall= 0.811321
# Validation Random guess:  auc= 0.222164, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.398284
# Tarin Iter 6500, auc= 0.958984, fmeasure_max= 0.885860, precision= 0.868114, recall= 0.904348
# Train Random guess:  , auc= 0.222213fmeasure_max= 0.366943, precision= 0.224697, recall= 1.000000
# Validation Iter 6500, auc= 0.915217, fmeasure_max= 0.848945, precision= 0.835548, recall= 0.862779
# Validation Random guess:  auc= 0.241062, fmeasure_max= 0.372228, precision= 0.229035, recall= 0.993139
# Minibatch Loss= 0.419037
# Tarin Iter 6600, auc= 0.952500, fmeasure_max= 0.875205, precision= 0.875205, recall= 0.875205
# Train Random guess:  , auc= 0.261876fmeasure_max= 0.384591, precision= 0.238077, recall= 1.000000
# Validation Iter 6600, auc= 0.915688, fmeasure_max= 0.844601, precision= 0.865108, recall= 0.825043
# Validation Random guess:  auc= 0.232776, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.480383
# Tarin Iter 6700, auc= 0.969426, fmeasure_max= 0.917460, precision= 0.923323, recall= 0.911672
# Train Random guess:  , auc= 0.234851fmeasure_max= 0.397119, precision= 0.247753, recall= 1.000000
# Validation Iter 6700, auc= 0.917454, fmeasure_max= 0.844857, precision= 0.830846, recall= 0.859348
# Validation Random guess:  auc= 0.230905, fmeasure_max= 0.372915, precision= 0.230396, recall= 0.977702
# Minibatch Loss= 0.447879
# Tarin Iter 6800, auc= 0.968130, fmeasure_max= 0.906643, precision= 0.918182, recall= 0.895390
# Train Random guess:  , auc= 0.243982fmeasure_max= 0.362504, precision= 0.222356, recall= 0.980496
# Validation Iter 6800, auc= 0.909729, fmeasure_max= 0.841256, precision= 0.881579, recall= 0.804460
# Validation Random guess:  auc= 0.218162, fmeasure_max= 0.371973, precision= 0.229117, recall= 0.987993
# Minibatch Loss= 0.412808
# Tarin Iter 6900, auc= 0.936551, fmeasure_max= 0.865004, precision= 0.876307, recall= 0.853990
# Train Random guess:  , auc= 0.237647fmeasure_max= 0.375442, precision= 0.231562, recall= 0.991511
# Validation Iter 6900, auc= 0.916022, fmeasure_max= 0.848030, precision= 0.935818, recall= 0.775300
# Validation Random guess:  auc= 0.234039, fmeasure_max= 0.371675, precision= 0.235107, recall= 0.886792
# Minibatch Loss= 0.485331
# Tarin Iter 7000, auc= 0.946222, fmeasure_max= 0.881106, precision= 0.908745, recall= 0.855098
# Train Random guess:  , auc= 0.226725fmeasure_max= 0.359327, precision= 0.222364, recall= 0.935599
# Validation Iter 7000, auc= 0.918437, fmeasure_max= 0.859416, precision= 0.886861, recall= 0.833619
# Validation Random guess:  auc= 0.244957, fmeasure_max= 0.373134, precision= 0.230092, recall= 0.986278
# Minibatch Loss= 0.452564
# Tarin Iter 7100, auc= 0.971681, fmeasure_max= 0.906917, precision= 0.920277, recall= 0.893939
# Train Random guess:  , auc= 0.238915fmeasure_max= 0.377023, precision= 0.232303, recall= 1.000000
# Validation Iter 7100, auc= 0.905662, fmeasure_max= 0.844284, precision= 0.888258, recall= 0.804460
# Validation Random guess:  auc= 0.232540, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.381438
# Tarin Iter 7200, auc= 0.955632, fmeasure_max= 0.886667, precision= 0.883721, recall= 0.889632
# Train Random guess:  , auc= 0.236228fmeasure_max= 0.380128, precision= 0.235131, recall= 0.991639
# Validation Iter 7200, auc= 0.915268, fmeasure_max= 0.857881, precision= 0.861592, recall= 0.854202
# Validation Random guess:  auc= 0.244008, fmeasure_max= 0.375466, precision= 0.233953, recall= 0.950257
# Minibatch Loss= 0.421703
# Tarin Iter 7300, auc= 0.956412, fmeasure_max= 0.877971, precision= 0.868339, recall= 0.887821
# Train Random guess:  , auc= 0.235876fmeasure_max= 0.392823, precision= 0.244418, recall= 1.000000
# Validation Iter 7300, auc= 0.903543, fmeasure_max= 0.832470, precision= 0.838261, recall= 0.826758
# Validation Random guess:  auc= 0.225031, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.496216
# Tarin Iter 7400, auc= 0.956865, fmeasure_max= 0.885645, precision= 0.889251, recall= 0.882068
# Train Random guess:  , auc= 0.240568fmeasure_max= 0.391813, precision= 0.245222, recall= 0.974152
# Validation Iter 7400, auc= 0.919947, fmeasure_max= 0.858896, precision= 0.878136, recall= 0.840480
# Validation Random guess:  auc= 0.214913, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.432353
# Tarin Iter 7500, auc= 0.957737, fmeasure_max= 0.896959, precision= 0.906143, recall= 0.887960
# Train Random guess:  , auc= 0.224393fmeasure_max= 0.380044, precision= 0.234602, recall= 1.000000
# Validation Iter 7500, auc= 0.926365, fmeasure_max= 0.852817, precision= 0.836634, recall= 0.869640
# Validation Random guess:  auc= 0.243802, fmeasure_max= 0.371971, precision= 0.229866, recall= 0.974271
# Minibatch Loss= 0.417320
# Tarin Iter 7600, auc= 0.979441, fmeasure_max= 0.922109, precision= 0.931638, recall= 0.912773
# Train Random guess:  , auc= 0.239049fmeasure_max= 0.401125, precision= 0.250879, recall= 1.000000
# Validation Iter 7600, auc= 0.909141, fmeasure_max= 0.843668, precision= 0.859431, recall= 0.828473
# Validation Random guess:  auc= 0.244419, fmeasure_max= 0.372827, precision= 0.229489, recall= 0.993139
# Minibatch Loss= 0.428992
# Tarin Iter 7700, auc= 0.965301, fmeasure_max= 0.908658, precision= 0.892356, recall= 0.925566
# Train Random guess:  , auc= 0.238072fmeasure_max= 0.389905, precision= 0.242163, recall= 1.000000
# Validation Iter 7700, auc= 0.921739, fmeasure_max= 0.850000, precision= 0.854419, recall= 0.845626
# Validation Random guess:  auc= 0.239922, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.428354
# Tarin Iter 7800, auc= 0.964314, fmeasure_max= 0.894334, precision= 0.884848, recall= 0.904025
# Train Random guess:  , auc= 0.273898fmeasure_max= 0.405330, precision= 0.262013, recall= 0.894737
# Validation Iter 7800, auc= 0.915999, fmeasure_max= 0.847943, precision= 0.885981, recall= 0.813036
# Validation Random guess:  auc= 0.236835, fmeasure_max= 0.374048, precision= 0.231747, recall= 0.969125
# Minibatch Loss= 0.429622
# Tarin Iter 7900, auc= 0.970196, fmeasure_max= 0.900804, precision= 0.933333, recall= 0.870466
# Train Random guess:  , auc= 0.222797fmeasure_max= 0.370323, precision= 0.227687, recall= 0.991364
# Validation Iter 7900, auc= 0.937058, fmeasure_max= 0.863176, precision= 0.850250, recall= 0.876501
# Validation Random guess:  auc= 0.237031, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.385972
# Tarin Iter 8000, auc= 0.956826, fmeasure_max= 0.874009, precision= 0.892086, recall= 0.856649
# Train Random guess:  , auc= 0.244278fmeasure_max= 0.372614, precision= 0.230175, recall= 0.977547
# Validation Iter 8000, auc= 0.926936, fmeasure_max= 0.854701, precision= 0.851789, recall= 0.857633
# Validation Random guess:  auc= 0.213666, fmeasure_max= 0.372228, precision= 0.229035, recall= 0.993139
# Minibatch Loss= 0.411526
# Tarin Iter 8100, auc= 0.973252, fmeasure_max= 0.909402, precision= 0.875000, recall= 0.946619
# Train Random guess:  , auc= 0.217404fmeasure_max= 0.360244, precision= 0.219867, recall= 0.996441
# Validation Iter 8100, auc= 0.923873, fmeasure_max= 0.848589, precision= 0.846416, recall= 0.850772
# Validation Random guess:  auc= 0.230426, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.381169
# Tarin Iter 8200, auc= 0.973572, fmeasure_max= 0.917083, precision= 0.910714, recall= 0.923541
# Train Random guess:  , auc= 0.195228fmeasure_max= 0.327657, precision= 0.197212, recall= 0.967807
# Validation Iter 8200, auc= 0.927948, fmeasure_max= 0.857393, precision= 0.875000, recall= 0.840480
# Validation Random guess:  auc= 0.209570, fmeasure_max= 0.373115, precision= 0.230645, recall= 0.975986
# Minibatch Loss= 0.343886
# Tarin Iter 8300, auc= 0.938537, fmeasure_max= 0.859072, precision= 0.882149, recall= 0.837171
# Train Random guess:  , auc= 0.240778fmeasure_max= 0.384766, precision= 0.239854, recall= 0.972039
# Validation Iter 8300, auc= 0.919974, fmeasure_max= 0.852071, precision= 0.840000, recall= 0.864494
# Validation Random guess:  auc= 0.243137, fmeasure_max= 0.371853, precision= 0.229026, recall= 0.987993
# Minibatch Loss= 0.510836
# Tarin Iter 8400, auc= 0.974490, fmeasure_max= 0.912052, precision= 0.893142, recall= 0.931780
# Train Random guess:  , auc= 0.237078fmeasure_max= 0.382419, precision= 0.236884, recall= 0.991681
# Validation Iter 8400, auc= 0.916648, fmeasure_max= 0.842932, precision= 0.857904, recall= 0.828473
# Validation Random guess:  auc= 0.232384, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.414881
# Tarin Iter 8500, auc= 0.967467, fmeasure_max= 0.907359, precision= 0.891156, recall= 0.924162
# Train Random guess:  , auc= 0.216550fmeasure_max= 0.362648, precision= 0.221484, recall= 1.000000
# Validation Iter 8500, auc= 0.923863, fmeasure_max= 0.849057, precision= 0.849057, recall= 0.849057
# Validation Random guess:  auc= 0.222523, fmeasure_max= 0.371382, precision= 0.229133, recall= 0.979417
# Minibatch Loss= 0.385812
# Tarin Iter 8600, auc= 0.960685, fmeasure_max= 0.882416, precision= 0.870213, recall= 0.894967
# Train Random guess:  , auc= 0.189313fmeasure_max= 0.304260, precision= 0.179928, recall= 0.984683
# Validation Iter 8600, auc= 0.905004, fmeasure_max= 0.851852, precision= 0.876588, recall= 0.828473
# Validation Random guess:  auc= 0.213055, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.327267
# Tarin Iter 8700, auc= 0.949971, fmeasure_max= 0.884483, precision= 0.868020, recall= 0.901582
# Train Random guess:  , auc= 0.224499fmeasure_max= 0.366787, precision= 0.225301, recall= 0.985940
# Validation Iter 8700, auc= 0.912838, fmeasure_max= 0.850394, precision= 0.867857, recall= 0.833619
# Validation Random guess:  auc= 0.238910, fmeasure_max= 0.372835, precision= 0.232430, recall= 0.941681
# Minibatch Loss= 0.429373
# Tarin Iter 8800, auc= 0.971740, fmeasure_max= 0.903069, precision= 0.876176, recall= 0.931667
# Train Random guess:  , auc= 0.240775fmeasure_max= 0.380831, precision= 0.235202, recall= 1.000000
# Validation Iter 8800, auc= 0.916876, fmeasure_max= 0.850000, precision= 0.854419, recall= 0.845626
# Validation Random guess:  auc= 0.241626, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.427043
# Tarin Iter 8900, auc= 0.957429, fmeasure_max= 0.895046, precision= 0.880992, recall= 0.909556
# Train Random guess:  , auc= 0.223117fmeasure_max= 0.373077, precision= 0.229676, recall= 0.993174
# Validation Iter 8900, auc= 0.919750, fmeasure_max= 0.854610, precision= 0.884404, recall= 0.826758
# Validation Random guess:  auc= 0.224724, fmeasure_max= 0.373605, precision= 0.231019, recall= 0.975986
# Minibatch Loss= 0.391286
# Tarin Iter 9000, auc= 0.961596, fmeasure_max= 0.905491, precision= 0.934944, recall= 0.877836
# Train Random guess:  , auc= 0.222515fmeasure_max= 0.366151, precision= 0.225649, recall= 0.970332
# Validation Iter 9000, auc= 0.925377, fmeasure_max= 0.849696, precision= 0.860915, recall= 0.838765
# Validation Random guess:  auc= 0.222695, fmeasure_max= 0.371676, precision= 0.228526, recall= 0.994854
# Minibatch Loss= 0.412623
# Tarin Iter 9100, auc= 0.954506, fmeasure_max= 0.878719, precision= 0.872727, recall= 0.884793
# Train Random guess:  , auc= 0.251830fmeasure_max= 0.405607, precision= 0.254396, recall= 1.000000
# Validation Iter 9100, auc= 0.915443, fmeasure_max= 0.855652, precision= 0.867725, recall= 0.843911
# Validation Random guess:  auc= 0.221590, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.491929
# Tarin Iter 9200, auc= 0.961568, fmeasure_max= 0.906149, precision= 0.894569, recall= 0.918033
# Train Random guess:  , auc= 0.233728fmeasure_max= 0.384858, precision= 0.238281, recall= 1.000000
# Validation Iter 9200, auc= 0.921481, fmeasure_max= 0.865004, precision= 0.867241, recall= 0.862779
# Validation Random guess:  auc= 0.230849, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.371883
# Tarin Iter 9300, auc= 0.933689, fmeasure_max= 0.868182, precision= 0.843888, recall= 0.893916
# Train Random guess:  , auc= 0.268881fmeasure_max= 0.403086, precision= 0.253846, recall= 0.978159
# Validation Iter 9300, auc= 0.907760, fmeasure_max= 0.859322, precision= 0.849246, recall= 0.869640
# Validation Random guess:  auc= 0.236213, fmeasure_max= 0.373925, precision= 0.231652, recall= 0.969125
# Minibatch Loss= 0.499014
# Tarin Iter 9400, auc= 0.958668, fmeasure_max= 0.888889, precision= 0.876122, recall= 0.902033
# Train Random guess:  , auc= 0.216024fmeasure_max= 0.351762, precision= 0.216320, recall= 0.940850
# Validation Iter 9400, auc= 0.918719, fmeasure_max= 0.852916, precision= 0.865724, recall= 0.840480
# Validation Random guess:  auc= 0.223937, fmeasure_max= 0.371795, precision= 0.228616, recall= 0.994854
# Minibatch Loss= 0.417525
# Tarin Iter 9500, auc= 0.965616, fmeasure_max= 0.899916, precision= 0.902192, recall= 0.897651
# Train Random guess:  , auc= 0.224687fmeasure_max= 0.377813, precision= 0.232903, recall= 1.000000
# Validation Iter 9500, auc= 0.920065, fmeasure_max= 0.858896, precision= 0.878136, recall= 0.840480
# Validation Random guess:  auc= 0.231057, fmeasure_max= 0.371988, precision= 0.228854, recall= 0.993139
# Minibatch Loss= 0.397148
# Tarin Iter 9600, auc= 0.941480, fmeasure_max= 0.870523, precision= 0.844920, recall= 0.897727
# Train Random guess:  , auc= 0.270593fmeasure_max= 0.431373, precision= 0.275000, recall= 1.000000
# Validation Iter 9600, auc= 0.918600, fmeasure_max= 0.865417, precision= 0.859560, recall= 0.871355
# Validation Random guess:  auc= 0.224284, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.542700
# Tarin Iter 9700, auc= 0.967139, fmeasure_max= 0.906748, precision= 0.906061, recall= 0.907436
# Train Random guess:  , auc= 0.253696fmeasure_max= 0.410709, precision= 0.259141, recall= 0.989378
# Validation Iter 9700, auc= 0.916813, fmeasure_max= 0.852863, precision= 0.876812, recall= 0.830189
# Validation Random guess:  auc= 0.241246, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.466218
# Tarin Iter 9800, auc= 0.954237, fmeasure_max= 0.883436, precision= 0.911392, recall= 0.857143
# Train Random guess:  , auc= 0.219154fmeasure_max= 0.374165, precision= 0.230137, recall= 1.000000
# Validation Iter 9800, auc= 0.914593, fmeasure_max= 0.856134, precision= 0.881818, recall= 0.831904
# Validation Random guess:  auc= 0.244059, fmeasure_max= 0.371973, precision= 0.229117, recall= 0.987993
# Minibatch Loss= 0.411547
# Tarin Iter 9900, auc= 0.961454, fmeasure_max= 0.895760, precision= 0.920145, recall= 0.872633
# Train Random guess:  , auc= 0.232143fmeasure_max= 0.371511, precision= 0.228312, recall= 0.996558
# Validation Iter 9900, auc= 0.915374, fmeasure_max= 0.842291, precision= 0.865942, recall= 0.819897
# Validation Random guess:  auc= 0.220390, fmeasure_max= 0.372109, precision= 0.232075, recall= 0.938250
# Minibatch Loss= 0.421996
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-cbf22a8a2ba9> in <module>()
#       1 #Save the model
#       2 saver = tf.train.Saver()
# ----> 3 saver.save(sess, checkpoint_path, global_step=trainer.global_step)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/training/saver.pyc in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1592               "Parent directory of {} doesn't exist, can't save.".format(
#    1593                   save_path))
# -> 1594         raise exc
#    1595
#    1596     if write_meta_graph:
#
# ValueError: Parent directory of ../model/CNN1018/CNN1018 doesn't exist, can't save.

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.888431 F1_max = 0.804833 prec = 0.835484 rec = 0.776351
# Test Random guess: auc= 0.228613 fmeasure_max= 0.375856 , precision= 0.231600 , recall= 0.996622

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
