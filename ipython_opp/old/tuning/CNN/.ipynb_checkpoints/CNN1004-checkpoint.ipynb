# %%
# useing this variable for saving models and summaries
exp_name = "CNN1005"

# %%
# 6 layers CNN pooling_stride = [2, 2, 2, 2, 2, 1]

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2, 1]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64, 64]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.255575, fmeasure_max= 0.454331, precision= 0.301463, recall= 0.921725
# Train Random guess:  , auc= 0.241220fmeasure_max= 0.394073, precision= 0.245483, recall= 0.998403
# Validation Iter 0, auc= 0.188859, fmeasure_max= 0.379394, precision= 0.237991, recall= 0.934820
# Validation Random guess:  auc= 0.226893, fmeasure_max= 0.371853, precision= 0.229026, recall= 0.987993
# Minibatch Loss= 1.073102
# Tarin Iter 100, auc= 0.806107, fmeasure_max= 0.748950, precision= 0.802158, recall= 0.702362
# Train Random guess:  , auc= 0.240481fmeasure_max= 0.398849, precision= 0.250200, recall= 0.982677
# Validation Iter 100, auc= 0.782047, fmeasure_max= 0.750000, precision= 0.759227, recall= 0.740995
# Validation Random guess:  auc= 0.235267, fmeasure_max= 0.372330, precision= 0.232037, recall= 0.941681
# Minibatch Loss= 0.878933
# Tarin Iter 200, auc= 0.821845, fmeasure_max= 0.772350, precision= 0.813592, recall= 0.735088
# Train Random guess:  , auc= 0.236736fmeasure_max= 0.366753, precision= 0.224822, recall= 0.994737
# Validation Iter 200, auc= 0.810774, fmeasure_max= 0.766467, precision= 0.764505, recall= 0.768439
# Validation Random guess:  auc= 0.220345, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.701087
# Tarin Iter 300, auc= 0.817962, fmeasure_max= 0.781327, precision= 0.815385, recall= 0.750000
# Train Random guess:  , auc= 0.250282fmeasure_max= 0.398995, precision= 0.249313, recall= 0.998428
# Validation Iter 300, auc= 0.835235, fmeasure_max= 0.782842, precision= 0.817164, recall= 0.751286
# Validation Random guess:  auc= 0.224383, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.781345
# Tarin Iter 400, auc= 0.750799, fmeasure_max= 0.711703, precision= 0.871795, recall= 0.601286
# Train Random guess:  , auc= 0.243461fmeasure_max= 0.393173, precision= 0.244689, recall= 1.000000
# Validation Iter 400, auc= 0.829845, fmeasure_max= 0.764805, precision= 0.754591, recall= 0.775300
# Validation Random guess:  auc= 0.234076, fmeasure_max= 0.373698, precision= 0.230615, recall= 0.984563
# Minibatch Loss= 0.841476
# Tarin Iter 500, auc= 0.804779, fmeasure_max= 0.763088, precision= 0.797774, recall= 0.731293
# Train Random guess:  , auc= 0.232156fmeasure_max= 0.376561, precision= 0.231953, recall= 1.000000
# Validation Iter 500, auc= 0.852430, fmeasure_max= 0.795222, precision= 0.791171, recall= 0.799314
# Validation Random guess:  auc= 0.233043, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.786222
# Tarin Iter 600, auc= 0.837210, fmeasure_max= 0.776326, precision= 0.808000, recall= 0.747041
# Train Random guess:  , auc= 0.268833fmeasure_max= 0.418576, precision= 0.264683, recall= 1.000000
# Validation Iter 600, auc= 0.851334, fmeasure_max= 0.785899, precision= 0.787931, recall= 0.783877
# Validation Random guess:  auc= 0.248324, fmeasure_max= 0.371487, precision= 0.232120, recall= 0.929674
# Minibatch Loss= 0.818668
# Tarin Iter 700, auc= 0.778425, fmeasure_max= 0.705434, precision= 0.813187, recall= 0.622896
# Train Random guess:  , auc= 0.239457fmeasure_max= 0.377668, precision= 0.234598, recall= 0.968013
# Validation Iter 700, auc= 0.828598, fmeasure_max= 0.764653, precision= 0.806084, recall= 0.727273
# Validation Random guess:  auc= 0.223395, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.739161
# Tarin Iter 800, auc= 0.862613, fmeasure_max= 0.799302, precision= 0.856075, recall= 0.749591
# Train Random guess:  , auc= 0.233287fmeasure_max= 0.385732, precision= 0.238952, recall= 1.000000
# Validation Iter 800, auc= 0.811922, fmeasure_max= 0.721170, precision= 0.723661, recall= 0.718696
# Validation Random guess:  auc= 0.226965, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.695395
# Tarin Iter 900, auc= 0.817231, fmeasure_max= 0.773698, precision= 0.861217, recall= 0.702326
# Train Random guess:  , auc= 0.262750fmeasure_max= 0.404282, precision= 0.253655, recall= 0.995349
# Validation Iter 900, auc= 0.830007, fmeasure_max= 0.776170, precision= 0.770270, recall= 0.782161
# Validation Random guess:  auc= 0.228325, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.743077
# Tarin Iter 1000, auc= 0.843412, fmeasure_max= 0.795820, precision= 0.831933, recall= 0.762712
# Train Random guess:  , auc= 0.253346fmeasure_max= 0.404613, precision= 0.253615, recall= 1.000000
# Validation Iter 1000, auc= 0.837184, fmeasure_max= 0.776512, precision= 0.793907, recall= 0.759863
# Validation Random guess:  auc= 0.243507, fmeasure_max= 0.375352, precision= 0.236154, recall= 0.914237
# Minibatch Loss= 0.754855
# Tarin Iter 1100, auc= 0.828909, fmeasure_max= 0.781278, precision= 0.842718, recall= 0.728188
# Train Random guess:  , auc= 0.239919fmeasure_max= 0.379253, precision= 0.236117, recall= 0.963087
# Validation Iter 1100, auc= 0.830069, fmeasure_max= 0.761313, precision= 0.788603, recall= 0.735849
# Validation Random guess:  auc= 0.229566, fmeasure_max= 0.373845, precision= 0.235769, recall= 0.902230
# Minibatch Loss= 0.676871
# Tarin Iter 1200, auc= 0.795989, fmeasure_max= 0.751192, precision= 0.856522, recall= 0.668930
# Train Random guess:  , auc= 0.232266fmeasure_max= 0.374087, precision= 0.230078, recall= 1.000000
# Validation Iter 1200, auc= 0.842862, fmeasure_max= 0.767361, precision= 0.776801, recall= 0.758148
# Validation Random guess:  auc= 0.236877, fmeasure_max= 0.373008, precision= 0.232460, recall= 0.943396
# Minibatch Loss= 0.731972
# Tarin Iter 1300, auc= 0.875753, fmeasure_max= 0.826162, precision= 0.821918, recall= 0.830450
# Train Random guess:  , auc= 0.212277fmeasure_max= 0.370776, precision= 0.227758, recall= 0.996540
# Validation Iter 1300, auc= 0.856067, fmeasure_max= 0.787770, precision= 0.827977, recall= 0.751286
# Validation Random guess:  auc= 0.225184, fmeasure_max= 0.371670, precision= 0.229259, recall= 0.981132
# Minibatch Loss= 0.650757
# Tarin Iter 1400, auc= 0.773705, fmeasure_max= 0.709609, precision= 0.848485, recall= 0.609800
# Train Random guess:  , auc= 0.215229fmeasure_max= 0.356979, precision= 0.217703, recall= 0.990926
# Validation Iter 1400, auc= 0.829981, fmeasure_max= 0.767559, precision= 0.748777, recall= 0.787307
# Validation Random guess:  auc= 0.244502, fmeasure_max= 0.372062, precision= 0.230517, recall= 0.963979
# Minibatch Loss= 0.709873
# Tarin Iter 1500, auc= 0.843665, fmeasure_max= 0.801126, precision= 0.816444, recall= 0.786372
# Train Random guess:  , auc= 0.218382fmeasure_max= 0.352864, precision= 0.214830, recall= 0.987109
# Validation Iter 1500, auc= 0.840319, fmeasure_max= 0.762808, precision= 0.853503, recall= 0.689537
# Validation Random guess:  auc= 0.228529, fmeasure_max= 0.373669, precision= 0.230127, recall= 0.993139
# Minibatch Loss= 0.714640
# Tarin Iter 1600, auc= 0.819567, fmeasure_max= 0.768953, precision= 0.777372, recall= 0.760714
# Train Random guess:  , auc= 0.221530fmeasure_max= 0.363034, precision= 0.222855, recall= 0.978571
# Validation Iter 1600, auc= 0.848152, fmeasure_max= 0.747826, precision= 0.856195, recall= 0.663808
# Validation Random guess:  auc= 0.236118, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.733183
# Tarin Iter 1700, auc= 0.861639, fmeasure_max= 0.824782, precision= 0.832031, recall= 0.817658
# Train Random guess:  , auc= 0.207999fmeasure_max= 0.338422, precision= 0.203675, recall= 1.000000
# Validation Iter 1700, auc= 0.837276, fmeasure_max= 0.756808, precision= 0.836100, recall= 0.691252
# Validation Random guess:  auc= 0.225022, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.575193
# Tarin Iter 1800, auc= 0.874070, fmeasure_max= 0.817743, precision= 0.872428, recall= 0.769510
# Train Random guess:  , auc= 0.218510fmeasure_max= 0.354341, precision= 0.215318, recall= 1.000000
# Validation Iter 1800, auc= 0.870807, fmeasure_max= 0.780710, precision= 0.831395, recall= 0.735849
# Validation Random guess:  auc= 0.218192, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.627852
# Tarin Iter 1900, auc= 0.895980, fmeasure_max= 0.830565, precision= 0.869565, recall= 0.794913
# Train Random guess:  , auc= 0.256207fmeasure_max= 0.394729, precision= 0.245895, recall= 1.000000
# Validation Iter 1900, auc= 0.859974, fmeasure_max= 0.773684, precision= 0.791741, recall= 0.756432
# Validation Random guess:  auc= 0.240069, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.656574
# Tarin Iter 2000, auc= 0.822403, fmeasure_max= 0.782258, precision= 0.788618, recall= 0.776000
# Train Random guess:  , auc= 0.253935fmeasure_max= 0.393329, precision= 0.244810, recall= 1.000000
# Validation Iter 2000, auc= 0.834889, fmeasure_max= 0.770421, precision= 0.772414, recall= 0.768439
# Validation Random guess:  auc= 0.231940, fmeasure_max= 0.372626, precision= 0.230271, recall= 0.975986
# Minibatch Loss= 0.738467
# Tarin Iter 2100, auc= 0.888602, fmeasure_max= 0.849699, precision= 0.867076, recall= 0.833006
# Train Random guess:  , auc= 0.193251fmeasure_max= 0.331920, precision= 0.198984, recall= 1.000000
# Validation Iter 2100, auc= 0.861054, fmeasure_max= 0.795181, precision= 0.797927, recall= 0.792453
# Validation Random guess:  auc= 0.218962, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.564784
# Tarin Iter 2200, auc= 0.874647, fmeasure_max= 0.806497, precision= 0.782192, recall= 0.832362
# Train Random guess:  , auc= 0.267299fmeasure_max= 0.423849, precision= 0.268914, recall= 1.000000
# Validation Iter 2200, auc= 0.852761, fmeasure_max= 0.779451, precision= 0.805861, recall= 0.754717
# Validation Random guess:  auc= 0.230929, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.684898
# Tarin Iter 2300, auc= 0.869653, fmeasure_max= 0.809787, precision= 0.804075, recall= 0.815580
# Train Random guess:  , auc= 0.258843fmeasure_max= 0.395827, precision= 0.247040, recall= 0.995231
# Validation Iter 2300, auc= 0.864021, fmeasure_max= 0.775435, precision= 0.832677, recall= 0.725557
# Validation Random guess:  auc= 0.233565, fmeasure_max= 0.372093, precision= 0.229208, recall= 0.987993
# Minibatch Loss= 0.621840
# Tarin Iter 2400, auc= 0.907187, fmeasure_max= 0.826733, precision= 0.840604, recall= 0.813312
# Train Random guess:  , auc= 0.249080fmeasure_max= 0.389012, precision= 0.241474, recall= 1.000000
# Validation Iter 2400, auc= 0.836173, fmeasure_max= 0.751773, precision= 0.777982, recall= 0.727273
# Validation Random guess:  auc= 0.218478, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.684628
# Tarin Iter 2500, auc= 0.863505, fmeasure_max= 0.799629, precision= 0.830443, recall= 0.771020
# Train Random guess:  , auc= 0.237790fmeasure_max= 0.359370, precision= 0.219044, recall= 1.000000
# Validation Iter 2500, auc= 0.859443, fmeasure_max= 0.799639, precision= 0.843810, recall= 0.759863
# Validation Random guess:  auc= 0.225731, fmeasure_max= 0.371745, precision= 0.229409, recall= 0.979417
# Minibatch Loss= 0.680626
# Tarin Iter 2600, auc= 0.918436, fmeasure_max= 0.857732, precision= 0.860690, recall= 0.854795
# Train Random guess:  , auc= 0.281182fmeasure_max= 0.444241, precision= 0.285658, recall= 0.998630
# Validation Iter 2600, auc= 0.862219, fmeasure_max= 0.785779, precision= 0.838521, recall= 0.739280
# Validation Random guess:  auc= 0.231149, fmeasure_max= 0.375330, precision= 0.232340, recall= 0.975986
# Minibatch Loss= 0.661825
# Tarin Iter 2700, auc= 0.829659, fmeasure_max= 0.766082, precision= 0.811983, recall= 0.725092
# Train Random guess:  , auc= 0.205083fmeasure_max= 0.351105, precision= 0.213102, recall= 0.996310
# Validation Iter 2700, auc= 0.865506, fmeasure_max= 0.782965, precision= 0.749216, recall= 0.819897
# Validation Random guess:  auc= 0.227375, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.656050
# Tarin Iter 2800, auc= 0.879305, fmeasure_max= 0.825974, precision= 0.823834, recall= 0.828125
# Train Random guess:  , auc= 0.217482fmeasure_max= 0.368015, precision= 0.225768, recall= 0.994792
# Validation Iter 2800, auc= 0.871132, fmeasure_max= 0.793072, precision= 0.846304, recall= 0.746141
# Validation Random guess:  auc= 0.212126, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.616822
# Tarin Iter 2900, auc= 0.875889, fmeasure_max= 0.808112, precision= 0.817035, recall= 0.799383
# Train Random guess:  , auc= 0.258832fmeasure_max= 0.405882, precision= 0.257463, recall= 0.958333
# Validation Iter 2900, auc= 0.865529, fmeasure_max= 0.778342, precision= 0.767947, recall= 0.789022
# Validation Random guess:  auc= 0.224473, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.674459
# Tarin Iter 3000, auc= 0.907590, fmeasure_max= 0.843779, precision= 0.847744, recall= 0.839851
# Train Random guess:  , auc= 0.212257fmeasure_max= 0.347460, precision= 0.210258, recall= 1.000000
# Validation Iter 3000, auc= 0.874249, fmeasure_max= 0.784926, precision= 0.845545, recall= 0.732419
# Validation Random guess:  auc= 0.238385, fmeasure_max= 0.371757, precision= 0.229894, recall= 0.970840
# Minibatch Loss= 0.538779
# Tarin Iter 3100, auc= 0.895386, fmeasure_max= 0.837989, precision= 0.880872, recall= 0.799087
# Train Random guess:  , auc= 0.248501fmeasure_max= 0.410770, precision= 0.258573, recall= 0.998478
# Validation Iter 3100, auc= 0.859642, fmeasure_max= 0.785223, precision= 0.786575, recall= 0.783877
# Validation Random guess:  auc= 0.233801, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.677439
# Tarin Iter 3200, auc= 0.936054, fmeasure_max= 0.887938, precision= 0.901042, recall= 0.875211
# Train Random guess:  , auc= 0.223790fmeasure_max= 0.376628, precision= 0.232003, recall= 1.000000
# Validation Iter 3200, auc= 0.850077, fmeasure_max= 0.769371, precision= 0.821012, recall= 0.723842
# Validation Random guess:  auc= 0.222267, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.504953
# Tarin Iter 3300, auc= 0.900983, fmeasure_max= 0.834315, precision= 0.836425, recall= 0.832215
# Train Random guess:  , auc= 0.237722fmeasure_max= 0.378179, precision= 0.236204, recall= 0.947987
# Validation Iter 3300, auc= 0.846587, fmeasure_max= 0.779020, precision= 0.781034, recall= 0.777015
# Validation Random guess:  auc= 0.252382, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.623719
# Tarin Iter 3400, auc= 0.878124, fmeasure_max= 0.800000, precision= 0.872093, recall= 0.738916
# Train Random guess:  , auc= 0.240404fmeasure_max= 0.387326, precision= 0.241143, recall= 0.983580
# Validation Iter 3400, auc= 0.872370, fmeasure_max= 0.785649, precision= 0.847222, recall= 0.732419
# Validation Random guess:  auc= 0.224640, fmeasure_max= 0.372823, precision= 0.232737, recall= 0.936535
# Minibatch Loss= 0.654146
# Tarin Iter 3500, auc= 0.929285, fmeasure_max= 0.854317, precision= 0.869963, recall= 0.839223
# Train Random guess:  , auc= 0.221450fmeasure_max= 0.363045, precision= 0.222488, recall= 0.985866
# Validation Iter 3500, auc= 0.857463, fmeasure_max= 0.781086, precision= 0.797853, recall= 0.765009
# Validation Random guess:  auc= 0.223133, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.513152
# Tarin Iter 3600, auc= 0.890690, fmeasure_max= 0.801782, precision= 0.796460, recall= 0.807175
# Train Random guess:  , auc= 0.258696fmeasure_max= 0.414627, precision= 0.261532, recall= 1.000000
# Validation Iter 3600, auc= 0.809015, fmeasure_max= 0.730983, precision= 0.795960, recall= 0.675815
# Validation Random guess:  auc= 0.221263, fmeasure_max= 0.373698, precision= 0.230615, recall= 0.984563
# Minibatch Loss= 0.677081
# Tarin Iter 3700, auc= 0.891573, fmeasure_max= 0.819188, precision= 0.857143, recall= 0.784452
# Train Random guess:  , auc= 0.217858fmeasure_max= 0.362516, precision= 0.222002, recall= 0.987633
# Validation Iter 3700, auc= 0.856983, fmeasure_max= 0.769497, precision= 0.777583, recall= 0.761578
# Validation Random guess:  auc= 0.229057, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.562035
# Tarin Iter 3800, auc= 0.925343, fmeasure_max= 0.848635, precision= 0.814286, recall= 0.886010
# Train Random guess:  , auc= 0.219749fmeasure_max= 0.369260, precision= 0.226437, recall= 1.000000
# Validation Iter 3800, auc= 0.833123, fmeasure_max= 0.759690, precision= 0.762976, recall= 0.756432
# Validation Random guess:  auc= 0.220777, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.504310
# Tarin Iter 3900, auc= 0.890500, fmeasure_max= 0.802013, precision= 0.769726, recall= 0.837128
# Train Random guess:  , auc= 0.219374fmeasure_max= 0.365557, precision= 0.223658, recall= 1.000000
# Validation Iter 3900, auc= 0.847592, fmeasure_max= 0.769658, precision= 0.835341, recall= 0.713551
# Validation Random guess:  auc= 0.226949, fmeasure_max= 0.371704, precision= 0.228730, recall= 0.991424
# Minibatch Loss= 0.565768
# Tarin Iter 4000, auc= 0.895630, fmeasure_max= 0.833814, precision= 0.896694, recall= 0.779174
# Train Random guess:  , auc= 0.216908fmeasure_max= 0.357395, precision= 0.217578, recall= 1.000000
# Validation Iter 4000, auc= 0.856204, fmeasure_max= 0.771899, precision= 0.780702, recall= 0.763293
# Validation Random guess:  auc= 0.219824, fmeasure_max= 0.371646, precision= 0.230296, recall= 0.962264
# Minibatch Loss= 0.568836
# Tarin Iter 4100, auc= 0.934750, fmeasure_max= 0.865625, precision= 0.871069, recall= 0.860248
# Train Random guess:  , auc= 0.244518fmeasure_max= 0.402520, precision= 0.252469, recall= 0.992236
# Validation Iter 4100, auc= 0.850696, fmeasure_max= 0.776316, precision= 0.858628, recall= 0.708405
# Validation Random guess:  auc= 0.229410, fmeasure_max= 0.373264, precision= 0.229912, recall= 0.991424
# Minibatch Loss= 0.520830
# Tarin Iter 4200, auc= 0.948428, fmeasure_max= 0.869176, precision= 0.878623, recall= 0.859929
# Train Random guess:  , auc= 0.220247fmeasure_max= 0.361191, precision= 0.220399, recall= 1.000000
# Validation Iter 4200, auc= 0.851213, fmeasure_max= 0.783595, precision= 0.797513, recall= 0.770154
# Validation Random guess:  auc= 0.230982, fmeasure_max= 0.373221, precision= 0.229972, recall= 0.989708
# Minibatch Loss= 0.440856
# Tarin Iter 4300, auc= 0.921124, fmeasure_max= 0.854545, precision= 0.827200, recall= 0.883761
# Train Random guess:  , auc= 0.231725fmeasure_max= 0.373026, precision= 0.230957, recall= 0.969231
# Validation Iter 4300, auc= 0.860438, fmeasure_max= 0.783956, precision= 0.836576, recall= 0.737564
# Validation Random guess:  auc= 0.227594, fmeasure_max= 0.375082, precision= 0.231575, recall= 0.986278
# Minibatch Loss= 0.531303
# Tarin Iter 4400, auc= 0.919482, fmeasure_max= 0.844402, precision= 0.847619, recall= 0.841210
# Train Random guess:  , auc= 0.219501fmeasure_max= 0.344988, precision= 0.209378, recall= 0.979206
# Validation Iter 4400, auc= 0.833485, fmeasure_max= 0.751704, precision= 0.869369, recall= 0.662093
# Validation Random guess:  auc= 0.220236, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.492251
# Tarin Iter 4500, auc= 0.945754, fmeasure_max= 0.882954, precision= 0.869969, recall= 0.896332
# Train Random guess:  , auc= 0.245996fmeasure_max= 0.393721, precision= 0.245113, recall= 1.000000
# Validation Iter 4500, auc= 0.845173, fmeasure_max= 0.786219, precision= 0.810565, recall= 0.763293
# Validation Random guess:  auc= 0.244303, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.487388
# Tarin Iter 4600, auc= 0.916694, fmeasure_max= 0.842857, precision= 0.856452, recall= 0.829688
# Train Random guess:  , auc= 0.245516fmeasure_max= 0.401134, precision= 0.251183, recall= 0.995313
# Validation Iter 4600, auc= 0.834024, fmeasure_max= 0.765957, precision= 0.831325, recall= 0.710120
# Validation Random guess:  auc= 0.231219, fmeasure_max= 0.373874, precision= 0.230099, recall= 0.996569
# Minibatch Loss= 0.589730
# Tarin Iter 4700, auc= 0.931881, fmeasure_max= 0.865696, precision= 0.874183, recall= 0.857372
# Train Random guess:  , auc= 0.243924fmeasure_max= 0.392393, precision= 0.244567, recall= 0.991987
# Validation Iter 4700, auc= 0.830542, fmeasure_max= 0.758437, precision= 0.786372, recall= 0.732419
# Validation Random guess:  auc= 0.244097, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.492213
# Tarin Iter 4800, auc= 0.943056, fmeasure_max= 0.871889, precision= 0.856884, recall= 0.887430
# Train Random guess:  , auc= 0.207403fmeasure_max= 0.347167, precision= 0.210547, recall= 0.988743
# Validation Iter 4800, auc= 0.836091, fmeasure_max= 0.776408, precision= 0.797468, recall= 0.756432
# Validation Random guess:  auc= 0.231690, fmeasure_max= 0.371869, precision= 0.228763, recall= 0.993139
# Minibatch Loss= 0.455995
# Tarin Iter 4900, auc= 0.916263, fmeasure_max= 0.843493, precision= 0.854758, recall= 0.832520
# Train Random guess:  , auc= 0.261150fmeasure_max= 0.388041, precision= 0.241202, recall= 0.991870
# Validation Iter 4900, auc= 0.825963, fmeasure_max= 0.768439, precision= 0.768439, recall= 0.768439
# Validation Random guess:  auc= 0.228922, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.527426
# Tarin Iter 5000, auc= 0.924701, fmeasure_max= 0.855151, precision= 0.862500, recall= 0.847926
# Train Random guess:  , auc= 0.250890fmeasure_max= 0.406652, precision= 0.255521, recall= 0.995392
# Validation Iter 5000, auc= 0.839634, fmeasure_max= 0.767857, precision= 0.800745, recall= 0.737564
# Validation Random guess:  auc= 0.231110, fmeasure_max= 0.371849, precision= 0.229773, recall= 0.974271
# Minibatch Loss= 0.594016
# Tarin Iter 5100, auc= 0.944646, fmeasure_max= 0.881557, precision= 0.901384, recall= 0.862583
# Train Random guess:  , auc= 0.248538fmeasure_max= 0.382037, precision= 0.236122, recall= 1.000000
# Validation Iter 5100, auc= 0.856236, fmeasure_max= 0.780357, precision= 0.813780, recall= 0.749571
# Validation Random guess:  auc= 0.236491, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.513020
# Tarin Iter 5200, auc= 0.927678, fmeasure_max= 0.864431, precision= 0.843528, recall= 0.886398
# Train Random guess:  , auc= 0.282794fmeasure_max= 0.417633, precision= 0.268313, recall= 0.941704
# Validation Iter 5200, auc= 0.841120, fmeasure_max= 0.784314, precision= 0.779661, recall= 0.789022
# Validation Random guess:  auc= 0.227631, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.610951
# Tarin Iter 5300, auc= 0.951093, fmeasure_max= 0.878140, precision= 0.912959, recall= 0.845878
# Train Random guess:  , auc= 0.213866fmeasure_max= 0.359223, precision= 0.219194, recall= 0.994624
# Validation Iter 5300, auc= 0.842370, fmeasure_max= 0.776119, precision= 0.794964, recall= 0.758148
# Validation Random guess:  auc= 0.233132, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.453648
# Tarin Iter 5400, auc= 0.929760, fmeasure_max= 0.862992, precision= 0.910299, recall= 0.820359
# Train Random guess:  , auc= 0.268291fmeasure_max= 0.414007, precision= 0.261039, recall= 1.000000
# Validation Iter 5400, auc= 0.811466, fmeasure_max= 0.729875, precision= 0.762617, recall= 0.699828
# Validation Random guess:  auc= 0.218221, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.553675
# Tarin Iter 5500, auc= 0.935451, fmeasure_max= 0.851101, precision= 0.828473, recall= 0.875000
# Train Random guess:  , auc= 0.205745fmeasure_max= 0.356262, precision= 0.216996, recall= 0.994565
# Validation Iter 5500, auc= 0.831542, fmeasure_max= 0.755396, precision= 0.793951, recall= 0.720412
# Validation Random guess:  auc= 0.223050, fmeasure_max= 0.373881, precision= 0.231717, recall= 0.967410
# Minibatch Loss= 0.462658
# Tarin Iter 5600, auc= 0.916757, fmeasure_max= 0.848372, precision= 0.865275, recall= 0.832117
# Train Random guess:  , auc= 0.214729fmeasure_max= 0.352865, precision= 0.214230, recall= 1.000000
# Validation Iter 5600, auc= 0.800012, fmeasure_max= 0.733641, precision= 0.792829, recall= 0.682676
# Validation Random guess:  auc= 0.219061, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.471842
# Tarin Iter 5700, auc= 0.945882, fmeasure_max= 0.873319, precision= 0.865358, recall= 0.881429
# Train Random guess:  , auc= 0.263192fmeasure_max= 0.430108, precision= 0.273973, recall= 1.000000
# Validation Iter 5700, auc= 0.825907, fmeasure_max= 0.758242, precision= 0.813360, recall= 0.710120
# Validation Random guess:  auc= 0.227425, fmeasure_max= 0.372441, precision= 0.229751, recall= 0.982847
# Minibatch Loss= 0.578814
# Tarin Iter 5800, auc= 0.906330, fmeasure_max= 0.824687, precision= 0.863296, recall= 0.789384
# Train Random guess:  , auc= 0.232158fmeasure_max= 0.372619, precision= 0.229606, recall= 0.988014
# Validation Iter 5800, auc= 0.819258, fmeasure_max= 0.745167, precision= 0.763964, recall= 0.727273
# Validation Random guess:  auc= 0.225228, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.558812
# Tarin Iter 5900, auc= 0.904509, fmeasure_max= 0.838969, precision= 0.843042, recall= 0.834936
# Train Random guess:  , auc= 0.240030fmeasure_max= 0.392329, precision= 0.244036, recall= 1.000000
# Validation Iter 5900, auc= 0.835775, fmeasure_max= 0.748375, precision= 0.815789, recall= 0.691252
# Validation Random guess:  auc= 0.237233, fmeasure_max= 0.372524, precision= 0.228897, recall= 1.000000
# Minibatch Loss= 0.564375
# Tarin Iter 6000, auc= 0.941916, fmeasure_max= 0.878173, precision= 0.862126, recall= 0.894828
# Train Random guess:  , auc= 0.238644fmeasure_max= 0.370134, precision= 0.227095, recall= 1.000000
# Validation Iter 6000, auc= 0.834630, fmeasure_max= 0.750227, precision= 0.797297, recall= 0.708405
# Validation Random guess:  auc= 0.217809, fmeasure_max= 0.373034, precision= 0.229463, recall= 0.996569
# Minibatch Loss= 0.464290
# Tarin Iter 6100, auc= 0.939996, fmeasure_max= 0.863388, precision= 0.849462, recall= 0.877778
# Train Random guess:  , auc= 0.230788fmeasure_max= 0.395729, precision= 0.246672, recall= 1.000000
# Validation Iter 6100, auc= 0.822798, fmeasure_max= 0.750229, precision= 0.803922, recall= 0.703259
# Validation Random guess:  auc= 0.226889, fmeasure_max= 0.375742, precision= 0.232558, recall= 0.977702
# Minibatch Loss= 0.558555
# Tarin Iter 6200, auc= 0.957068, fmeasure_max= 0.892925, precision= 0.886148, recall= 0.899807
# Train Random guess:  , auc= 0.193154fmeasure_max= 0.341513, precision= 0.207453, recall= 0.965318
# Validation Iter 6200, auc= 0.828172, fmeasure_max= 0.755981, precision= 0.854978, recall= 0.677530
# Validation Random guess:  auc= 0.227589, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.452754
# Tarin Iter 6300, auc= 0.940886, fmeasure_max= 0.865467, precision= 0.853041, recall= 0.878261
# Train Random guess:  , auc= 0.208591fmeasure_max= 0.368799, precision= 0.226999, recall= 0.982609
# Validation Iter 6300, auc= 0.818093, fmeasure_max= 0.751640, precision= 0.828512, recall= 0.687822
# Validation Random guess:  auc= 0.226606, fmeasure_max= 0.373777, precision= 0.230769, recall= 0.982847
# Minibatch Loss= 0.501318
# Tarin Iter 6400, auc= 0.926269, fmeasure_max= 0.847537, precision= 0.871383, recall= 0.824962
# Train Random guess:  , auc= 0.266946fmeasure_max= 0.411269, precision= 0.261209, recall= 0.966514
# Validation Iter 6400, auc= 0.818126, fmeasure_max= 0.753052, precision= 0.831950, recall= 0.687822
# Validation Random guess:  auc= 0.234868, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.585068
# Tarin Iter 6500, auc= 0.962123, fmeasure_max= 0.887684, precision= 0.866868, recall= 0.909524
# Train Random guess:  , auc= 0.244614fmeasure_max= 0.395977, precision= 0.246865, recall= 1.000000
# Validation Iter 6500, auc= 0.830652, fmeasure_max= 0.751342, precision= 0.785047, recall= 0.720412
# Validation Random guess:  auc= 0.237275, fmeasure_max= 0.372033, precision= 0.228797, recall= 0.994854
# Minibatch Loss= 0.455566
# Tarin Iter 6600, auc= 0.975233, fmeasure_max= 0.917058, precision= 0.919937, recall= 0.914197
# Train Random guess:  , auc= 0.260135fmeasure_max= 0.404094, precision= 0.256281, recall= 0.954758
# Validation Iter 6600, auc= 0.825296, fmeasure_max= 0.745946, precision= 0.785579, recall= 0.710120
# Validation Random guess:  auc= 0.227060, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.468387
# Tarin Iter 6700, auc= 0.931625, fmeasure_max= 0.872663, precision= 0.907407, recall= 0.840480
# Train Random guess:  , auc= 0.246593fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Validation Iter 6700, auc= 0.836320, fmeasure_max= 0.757709, precision= 0.778986, recall= 0.737564
# Validation Random guess:  auc= 0.233335, fmeasure_max= 0.374067, precision= 0.233178, recall= 0.945111
# Minibatch Loss= 0.476113
# Tarin Iter 6800, auc= 0.955275, fmeasure_max= 0.892535, precision= 0.915825, recall= 0.870400
# Train Random guess:  , auc= 0.248762fmeasure_max= 0.392465, precision= 0.244141, recall= 1.000000
# Validation Iter 6800, auc= 0.823470, fmeasure_max= 0.738075, precision= 0.720588, recall= 0.756432
# Validation Random guess:  auc= 0.212067, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.465373
# Tarin Iter 6900, auc= 0.942961, fmeasure_max= 0.882068, precision= 0.890701, recall= 0.873600
# Train Random guess:  , auc= 0.236621fmeasure_max= 0.393195, precision= 0.244802, recall= 0.998400
# Validation Iter 6900, auc= 0.821267, fmeasure_max= 0.744144, precision= 0.783681, recall= 0.708405
# Validation Random guess:  auc= 0.238281, fmeasure_max= 0.371943, precision= 0.228911, recall= 0.991424
# Minibatch Loss= 0.475717
# Tarin Iter 7000, auc= 0.943715, fmeasure_max= 0.880407, precision= 0.887179, recall= 0.873737
# Train Random guess:  , auc= 0.240425fmeasure_max= 0.376867, precision= 0.232276, recall= 0.998316
# Validation Iter 7000, auc= 0.791861, fmeasure_max= 0.713420, precision= 0.720280, recall= 0.706690
# Validation Random guess:  auc= 0.219219, fmeasure_max= 0.371521, precision= 0.228959, recall= 0.984563
# Minibatch Loss= 0.467414
# Tarin Iter 7100, auc= 0.937682, fmeasure_max= 0.871750, precision= 0.884007, recall= 0.859829
# Train Random guess:  , auc= 0.227608fmeasure_max= 0.372925, precision= 0.229289, recall= 0.998291
# Validation Iter 7100, auc= 0.799224, fmeasure_max= 0.736842, precision= 0.798000, recall= 0.684391
# Validation Random guess:  auc= 0.233753, fmeasure_max= 0.372260, precision= 0.229992, recall= 0.975986
# Minibatch Loss= 0.534778
# Tarin Iter 7200, auc= 0.957949, fmeasure_max= 0.899275, precision= 0.892800, recall= 0.905844
# Train Random guess:  , auc= 0.237600fmeasure_max= 0.389718, precision= 0.242209, recall= 0.996753
# Validation Iter 7200, auc= 0.818419, fmeasure_max= 0.741614, precision= 0.786538, recall= 0.701544
# Validation Random guess:  auc= 0.215435, fmeasure_max= 0.371055, precision= 0.227878, recall= 0.998285
# Minibatch Loss= 0.468109
# Tarin Iter 7300, auc= 0.948777, fmeasure_max= 0.884547, precision= 0.892473, recall= 0.876761
# Train Random guess:  , auc= 0.218824fmeasure_max= 0.365910, precision= 0.225010, recall= 0.978873
# Validation Iter 7300, auc= 0.774593, fmeasure_max= 0.697717, precision= 0.746094, recall= 0.655232
# Validation Random guess:  auc= 0.237671, fmeasure_max= 0.374096, precision= 0.231395, recall= 0.975986
# Minibatch Loss= 0.496206
# Tarin Iter 7400, auc= 0.927412, fmeasure_max= 0.843290, precision= 0.810316, recall= 0.879061
# Train Random guess:  , auc= 0.224209fmeasure_max= 0.356935, precision= 0.217408, recall= 0.996390
# Validation Iter 7400, auc= 0.813796, fmeasure_max= 0.722936, precision= 0.777120, recall= 0.675815
# Validation Random guess:  auc= 0.218117, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.470760
# Tarin Iter 7500, auc= 0.968263, fmeasure_max= 0.902736, precision= 0.905488, recall= 0.900000
# Train Random guess:  , auc= 0.260651fmeasure_max= 0.410320, precision= 0.258115, recall= 1.000000
# Validation Iter 7500, auc= 0.813761, fmeasure_max= 0.733032, precision= 0.775862, recall= 0.694683
# Validation Random guess:  auc= 0.213959, fmeasure_max= 0.371316, precision= 0.229462, recall= 0.972556
# Minibatch Loss= 0.462068
# Tarin Iter 7600, auc= 0.952314, fmeasure_max= 0.879528, precision= 0.893836, recall= 0.865672
# Train Random guess:  , auc= 0.246551fmeasure_max= 0.381284, precision= 0.235547, recall= 1.000000
# Validation Iter 7600, auc= 0.811057, fmeasure_max= 0.727273, precision= 0.756957, recall= 0.699828
# Validation Random guess:  auc= 0.225990, fmeasure_max= 0.373441, precision= 0.232383, recall= 0.950257
# Minibatch Loss= 0.444483
# Tarin Iter 7700, auc= 0.943951, fmeasure_max= 0.880527, precision= 0.915851, recall= 0.847826
# Train Random guess:  , auc= 0.219508fmeasure_max= 0.357686, precision= 0.218763, recall= 0.980072
# Validation Iter 7700, auc= 0.808062, fmeasure_max= 0.731930, precision= 0.784314, recall= 0.686106
# Validation Random guess:  auc= 0.233230, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.489594
# Tarin Iter 7800, auc= 0.953352, fmeasure_max= 0.875706, precision= 0.869159, recall= 0.882353
# Train Random guess:  , auc= 0.223808fmeasure_max= 0.351741, precision= 0.215889, recall= 0.948767
# Validation Iter 7800, auc= 0.756418, fmeasure_max= 0.684257, precision= 0.702166, recall= 0.667238
# Validation Random guess:  auc= 0.235327, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.414669
# Tarin Iter 7900, auc= 0.940010, fmeasure_max= 0.873999, precision= 0.873362, recall= 0.874636
# Train Random guess:  , auc= 0.271041fmeasure_max= 0.423077, precision= 0.268716, recall= 0.994169
# Validation Iter 7900, auc= 0.800964, fmeasure_max= 0.732394, precision= 0.752260, recall= 0.713551
# Validation Random guess:  auc= 0.224472, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.578128
# Tarin Iter 8000, auc= 0.914464, fmeasure_max= 0.839695, precision= 0.859375, recall= 0.820896
# Train Random guess:  , auc= 0.203693fmeasure_max= 0.348648, precision= 0.211212, recall= 0.998134
# Validation Iter 8000, auc= 0.813255, fmeasure_max= 0.731128, precision= 0.723154, recall= 0.739280
# Validation Random guess:  auc= 0.231311, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.493089
# Tarin Iter 8100, auc= 0.949454, fmeasure_max= 0.857661, precision= 0.906130, recall= 0.814114
# Train Random guess:  , auc= 0.218209fmeasure_max= 0.370064, precision= 0.227042, recall= 1.000000
# Validation Iter 8100, auc= 0.784322, fmeasure_max= 0.710909, precision= 0.756286, recall= 0.670669
# Validation Random guess:  auc= 0.226647, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.458997
# Tarin Iter 8200, auc= 0.937882, fmeasure_max= 0.863967, precision= 0.894624, recall= 0.835341
# Train Random guess:  , auc= 0.200670fmeasure_max= 0.326330, precision= 0.195055, recall= 0.997992
# Validation Iter 8200, auc= 0.810800, fmeasure_max= 0.722175, precision= 0.715488, recall= 0.728988
# Validation Random guess:  auc= 0.231807, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.471063
# Tarin Iter 8300, auc= 0.935461, fmeasure_max= 0.858577, precision= 0.906360, recall= 0.815580
# Train Random guess:  , auc= 0.247621fmeasure_max= 0.395349, precision= 0.246377, recall= 1.000000
# Validation Iter 8300, auc= 0.792159, fmeasure_max= 0.718693, precision= 0.763006, recall= 0.679245
# Validation Random guess:  auc= 0.237523, fmeasure_max= 0.371869, precision= 0.228763, recall= 0.993139
# Minibatch Loss= 0.510094
# Tarin Iter 8400, auc= 0.937989, fmeasure_max= 0.861702, precision= 0.839378, recall= 0.885246
# Train Random guess:  , auc= 0.208053fmeasure_max= 0.353588, precision= 0.214931, recall= 0.996357
# Validation Iter 8400, auc= 0.799695, fmeasure_max= 0.718531, precision= 0.732620, recall= 0.704974
# Validation Random guess:  auc= 0.220950, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.491199
# Tarin Iter 8500, auc= 0.944100, fmeasure_max= 0.855442, precision= 0.877836, recall= 0.834163
# Train Random guess:  , auc= 0.241399fmeasure_max= 0.381447, precision= 0.237097, recall= 0.975124
# Validation Iter 8500, auc= 0.791670, fmeasure_max= 0.718978, precision= 0.768031, recall= 0.675815
# Validation Random guess:  auc= 0.224566, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.523304
# Tarin Iter 8600, auc= 0.949822, fmeasure_max= 0.871395, precision= 0.811321, recall= 0.941077
# Train Random guess:  , auc= 0.236733fmeasure_max= 0.376904, precision= 0.232213, recall= 1.000000
# Validation Iter 8600, auc= 0.775540, fmeasure_max= 0.696824, precision= 0.793860, recall= 0.620926
# Validation Random guess:  auc= 0.243817, fmeasure_max= 0.371721, precision= 0.228470, recall= 0.996569
# Minibatch Loss= 0.455213
# Tarin Iter 8700, auc= 0.949093, fmeasure_max= 0.868472, precision= 0.903421, recall= 0.836127
# Train Random guess:  , auc= 0.232963fmeasure_max= 0.346899, precision= 0.209848, recall= 1.000000
# Validation Iter 8700, auc= 0.796338, fmeasure_max= 0.707996, precision= 0.743396, recall= 0.675815
# Validation Random guess:  auc= 0.241338, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.444276
# Tarin Iter 8800, auc= 0.930724, fmeasure_max= 0.860465, precision= 0.878165, recall= 0.843465
# Train Random guess:  , auc= 0.252522fmeasure_max= 0.408950, precision= 0.257031, recall= 1.000000
# Validation Iter 8800, auc= 0.811638, fmeasure_max= 0.742961, precision= 0.789575, recall= 0.701544
# Validation Random guess:  auc= 0.235906, fmeasure_max= 0.372599, precision= 0.229044, recall= 0.998285
# Minibatch Loss= 0.555294
# Tarin Iter 8900, auc= 0.961452, fmeasure_max= 0.896670, precision= 0.892857, recall= 0.900515
# Train Random guess:  , auc= 0.239375fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Validation Iter 8900, auc= 0.781125, fmeasure_max= 0.704981, precision= 0.798265, recall= 0.631218
# Validation Random guess:  auc= 0.226599, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.461015
# Tarin Iter 9000, auc= 0.973797, fmeasure_max= 0.925347, precision= 0.930192, recall= 0.920553
# Train Random guess:  , auc= 0.226798fmeasure_max= 0.370491, precision= 0.228183, recall= 0.984456
# Validation Iter 9000, auc= 0.783983, fmeasure_max= 0.709964, precision= 0.737523, recall= 0.684391
# Validation Random guess:  auc= 0.249153, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.395143
# Tarin Iter 9100, auc= 0.941692, fmeasure_max= 0.882310, precision= 0.881674, recall= 0.882948
# Train Random guess:  , auc= 0.282311fmeasure_max= 0.425966, precision= 0.270940, recall= 0.995665
# Validation Iter 9100, auc= 0.807102, fmeasure_max= 0.714412, precision= 0.737226, recall= 0.692967
# Validation Random guess:  auc= 0.236217, fmeasure_max= 0.376317, precision= 0.238710, recall= 0.888508
# Minibatch Loss= 0.514955
# Tarin Iter 9200, auc= 0.925489, fmeasure_max= 0.854717, precision= 0.849906, recall= 0.859583
# Train Random guess:  , auc= 0.197723fmeasure_max= 0.341764, precision= 0.206101, recall= 1.000000
# Validation Iter 9200, auc= 0.814127, fmeasure_max= 0.724074, precision= 0.786720, recall= 0.670669
# Validation Random guess:  auc= 0.231447, fmeasure_max= 0.374391, precision= 0.230954, recall= 0.987993
# Minibatch Loss= 0.473121
# Tarin Iter 9300, auc= 0.952953, fmeasure_max= 0.877228, precision= 0.840607, recall= 0.917184
# Train Random guess:  , auc= 0.198180fmeasure_max= 0.321526, precision= 0.197987, recall= 0.855072
# Validation Iter 9300, auc= 0.806722, fmeasure_max= 0.731490, precision= 0.762082, recall= 0.703259
# Validation Random guess:  auc= 0.225556, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.413222
# Tarin Iter 9400, auc= 0.972166, fmeasure_max= 0.908943, precision= 0.900161, recall= 0.917898
# Train Random guess:  , auc= 0.230397fmeasure_max= 0.384348, precision= 0.237891, recall= 1.000000
# Validation Iter 9400, auc= 0.811535, fmeasure_max= 0.714771, precision= 0.707563, recall= 0.722127
# Validation Random guess:  auc= 0.235146, fmeasure_max= 0.371869, precision= 0.228763, recall= 0.993139
# Minibatch Loss= 0.383826
# Tarin Iter 9500, auc= 0.950127, fmeasure_max= 0.878472, precision= 0.905188, recall= 0.853288
# Train Random guess:  , auc= 0.235999fmeasure_max= 0.376636, precision= 0.232283, recall= 0.994941
# Validation Iter 9500, auc= 0.747275, fmeasure_max= 0.661305, precision= 0.690299, recall= 0.634648
# Validation Random guess:  auc= 0.210703, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.461138
# Tarin Iter 9600, auc= 0.966742, fmeasure_max= 0.903323, precision= 0.876833, recall= 0.931464
# Train Random guess:  , auc= 0.258678fmeasure_max= 0.402528, precision= 0.252477, recall= 0.992212
# Validation Iter 9600, auc= 0.780262, fmeasure_max= 0.699364, precision= 0.743243, recall= 0.660377
# Validation Random guess:  auc= 0.232279, fmeasure_max= 0.372695, precision= 0.229665, recall= 0.987993
# Minibatch Loss= 0.458906
# Tarin Iter 9700, auc= 0.953533, fmeasure_max= 0.886018, precision= 0.866270, recall= 0.906687
# Train Random guess:  , auc= 0.250333fmeasure_max= 0.405309, precision= 0.255928, recall= 0.973561
# Validation Iter 9700, auc= 0.793336, fmeasure_max= 0.703097, precision= 0.749515, recall= 0.662093
# Validation Random guess:  auc= 0.236486, fmeasure_max= 0.372317, precision= 0.228920, recall= 0.996569
# Minibatch Loss= 0.445603
# Tarin Iter 9800, auc= 0.965314, fmeasure_max= 0.907975, precision= 0.920071, recall= 0.896194
# Train Random guess:  , auc= 0.214721fmeasure_max= 0.368622, precision= 0.225958, recall= 1.000000
# Validation Iter 9800, auc= 0.793987, fmeasure_max= 0.720627, precision= 0.731449, recall= 0.710120
# Validation Random guess:  auc= 0.232106, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.393991
# Tarin Iter 9900, auc= 0.936581, fmeasure_max= 0.870204, precision= 0.863857, recall= 0.876645
# Train Random guess:  , auc= 0.253616fmeasure_max= 0.383838, precision= 0.237500, recall= 1.000000
# Validation Iter 9900, auc= 0.827646, fmeasure_max= 0.749104, precision= 0.784240, recall= 0.716981
# Validation Random guess:  auc= 0.218463, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.508932
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.831502 F1_max = 0.767640 prec = 0.797777 rec = 0.739696
# Test Random guess: auc= 0.229809 fmeasure_max= 0.375658 , precision= 0.231268 , recall= 1.000000

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
