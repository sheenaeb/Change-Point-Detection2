# %%
# useing this variable for saving models and summaries
exp_name = "CNN1007"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2, 1]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.191365, fmeasure_max= 0.376909, precision= 0.234803, recall= 0.954717
# Train Random guess:  , auc= 0.213517fmeasure_max= 0.343264, precision= 0.207193, recall= 1.000000
# Validation Iter 0, auc= 0.255229, fmeasure_max= 0.392089, precision= 0.245759, recall= 0.969125
# Validation Random guess:  auc= 0.251085, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 1.019440
# Tarin Iter 100, auc= 0.795662, fmeasure_max= 0.729901, precision= 0.826176, recall= 0.653722
# Train Random guess:  , auc= 0.235073fmeasure_max= 0.391123, precision= 0.244079, recall= 0.983819
# Validation Iter 100, auc= 0.715520, fmeasure_max= 0.659829, precision= 0.657581, recall= 0.662093
# Validation Random guess:  auc= 0.226308, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.930961
# Tarin Iter 200, auc= 0.832187, fmeasure_max= 0.780129, precision= 0.868852, recall= 0.707846
# Train Random guess:  , auc= 0.242430fmeasure_max= 0.379594, precision= 0.234259, recall= 1.000000
# Validation Iter 200, auc= 0.785393, fmeasure_max= 0.746903, precision= 0.771481, recall= 0.723842
# Validation Random guess:  auc= 0.235739, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.849426
# Tarin Iter 300, auc= 0.670488, fmeasure_max= 0.630859, precision= 0.681435, recall= 0.587273
# Train Random guess:  , auc= 0.211004fmeasure_max= 0.354849, precision= 0.215949, recall= 0.994545
# Validation Iter 300, auc= 0.772020, fmeasure_max= 0.708747, precision= 0.747148, recall= 0.674099
# Validation Random guess:  auc= 0.226112, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.890840
# Tarin Iter 400, auc= 0.744109, fmeasure_max= 0.678962, precision= 0.629114, recall= 0.737389
# Train Random guess:  , auc= 0.266614fmeasure_max= 0.417212, precision= 0.264114, recall= 0.992582
# Validation Iter 400, auc= 0.776710, fmeasure_max= 0.718360, precision= 0.747681, recall= 0.691252
# Validation Random guess:  auc= 0.244623, fmeasure_max= 0.372303, precision= 0.229183, recall= 0.991424
# Minibatch Loss= 0.853657
# Tarin Iter 500, auc= 0.794588, fmeasure_max= 0.763636, precision= 0.763636, recall= 0.763636
# Train Random guess:  , auc= 0.215362fmeasure_max= 0.353812, precision= 0.214928, recall= 1.000000
# Validation Iter 500, auc= 0.828290, fmeasure_max= 0.766972, precision= 0.824458, recall= 0.716981
# Validation Random guess:  auc= 0.220097, fmeasure_max= 0.372392, precision= 0.229068, recall= 0.994854
# Minibatch Loss= 0.765556
# Tarin Iter 600, auc= 0.795131, fmeasure_max= 0.735922, precision= 0.802966, recall= 0.679211
# Train Random guess:  , auc= 0.233281fmeasure_max= 0.360688, precision= 0.221185, recall= 0.976703
# Validation Iter 600, auc= 0.800939, fmeasure_max= 0.715342, precision= 0.775551, recall= 0.663808
# Validation Random guess:  auc= 0.219804, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.719687
# Tarin Iter 700, auc= 0.866129, fmeasure_max= 0.779661, precision= 0.756353, recall= 0.804452
# Train Random guess:  , auc= 0.252767fmeasure_max= 0.396033, precision= 0.247897, recall= 0.984102
# Validation Iter 700, auc= 0.843474, fmeasure_max= 0.763158, precision= 0.733017, recall= 0.795883
# Validation Random guess:  auc= 0.231185, fmeasure_max= 0.373455, precision= 0.230430, recall= 0.984563
# Minibatch Loss= 0.644107
# Tarin Iter 800, auc= 0.844733, fmeasure_max= 0.776772, precision= 0.807210, recall= 0.748547
# Train Random guess:  , auc= 0.267655fmeasure_max= 0.423906, precision= 0.268960, recall= 1.000000
# Validation Iter 800, auc= 0.855868, fmeasure_max= 0.782609, precision= 0.763458, recall= 0.802744
# Validation Random guess:  auc= 0.221610, fmeasure_max= 0.372063, precision= 0.229002, recall= 0.991424
# Minibatch Loss= 0.757614
# Tarin Iter 900, auc= 0.830266, fmeasure_max= 0.793233, precision= 0.852525, recall= 0.741652
# Train Random guess:  , auc= 0.221378fmeasure_max= 0.365172, precision= 0.223994, recall= 0.987698
# Validation Iter 900, auc= 0.861106, fmeasure_max= 0.792453, precision= 0.759434, recall= 0.828473
# Validation Random guess:  auc= 0.236107, fmeasure_max= 0.371041, precision= 0.228594, recall= 0.984563
# Minibatch Loss= 0.704906
# Tarin Iter 1000, auc= 0.795223, fmeasure_max= 0.728656, precision= 0.785064, recall= 0.679811
# Train Random guess:  , auc= 0.244539fmeasure_max= 0.399484, precision= 0.251116, recall= 0.976341
# Validation Iter 1000, auc= 0.839370, fmeasure_max= 0.774306, precision= 0.783831, recall= 0.765009
# Validation Random guess:  auc= 0.216820, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.819751
# Tarin Iter 1100, auc= 0.869891, fmeasure_max= 0.818695, precision= 0.827362, recall= 0.810207
# Train Random guess:  , auc= 0.250683fmeasure_max= 0.393473, precision= 0.244922, recall= 1.000000
# Validation Iter 1100, auc= 0.849048, fmeasure_max= 0.800341, precision= 0.796265, recall= 0.804460
# Validation Random guess:  auc= 0.238290, fmeasure_max= 0.374837, precision= 0.231388, recall= 0.986278
# Minibatch Loss= 0.670586
# Tarin Iter 1200, auc= 0.790122, fmeasure_max= 0.752669, precision= 0.789179, recall= 0.719388
# Train Random guess:  , auc= 0.230712fmeasure_max= 0.374599, precision= 0.230830, recall= 0.993197
# Validation Iter 1200, auc= 0.840058, fmeasure_max= 0.784383, precision= 0.812500, recall= 0.758148
# Validation Random guess:  auc= 0.229367, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.709218
# Tarin Iter 1300, auc= 0.826094, fmeasure_max= 0.749799, precision= 0.866171, recall= 0.660993
# Train Random guess:  , auc= 0.279625fmeasure_max= 0.435873, precision= 0.279791, recall= 0.985816
# Validation Iter 1300, auc= 0.828329, fmeasure_max= 0.753022, precision= 0.758261, recall= 0.747856
# Validation Random guess:  auc= 0.226404, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.831237
# Tarin Iter 1400, auc= 0.849494, fmeasure_max= 0.827246, precision= 0.818359, recall= 0.836327
# Train Random guess:  , auc= 0.205325fmeasure_max= 0.332985, precision= 0.201688, recall= 0.954092
# Validation Iter 1400, auc= 0.850588, fmeasure_max= 0.796875, precision= 0.806678, recall= 0.787307
# Validation Random guess:  auc= 0.237140, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.572670
# Tarin Iter 1500, auc= 0.859028, fmeasure_max= 0.807864, precision= 0.886275, recall= 0.742200
# Train Random guess:  , auc= 0.240265fmeasure_max= 0.385199, precision= 0.238543, recall= 1.000000
# Validation Iter 1500, auc= 0.862525, fmeasure_max= 0.800360, precision= 0.841210, recall= 0.763293
# Validation Random guess:  auc= 0.219451, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.642802
# Tarin Iter 1600, auc= 0.877222, fmeasure_max= 0.827411, precision= 0.838765, recall= 0.816361
# Train Random guess:  , auc= 0.231931fmeasure_max= 0.379715, precision= 0.234351, recall= 1.000000
# Validation Iter 1600, auc= 0.858967, fmeasure_max= 0.791228, precision= 0.809695, recall= 0.773585
# Validation Random guess:  auc= 0.235207, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.602433
# Tarin Iter 1700, auc= 0.833031, fmeasure_max= 0.775937, precision= 0.830224, recall= 0.728314
# Train Random guess:  , auc= 0.233839fmeasure_max= 0.385854, precision= 0.239045, recall= 1.000000
# Validation Iter 1700, auc= 0.855256, fmeasure_max= 0.792244, precision= 0.858000, recall= 0.735849
# Validation Random guess:  auc= 0.224912, fmeasure_max= 0.373466, precision= 0.231497, recall= 0.965695
# Minibatch Loss= 0.739816
# Tarin Iter 1800, auc= 0.851296, fmeasure_max= 0.780710, precision= 0.859719, recall= 0.715000
# Train Random guess:  , auc= 0.244276fmeasure_max= 0.380469, precision= 0.234926, recall= 1.000000
# Validation Iter 1800, auc= 0.867397, fmeasure_max= 0.808028, precision= 0.822380, recall= 0.794168
# Validation Random guess:  auc= 0.228042, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.680156
# Tarin Iter 1900, auc= 0.900810, fmeasure_max= 0.861111, precision= 0.872420, recall= 0.850091
# Train Random guess:  , auc= 0.222531fmeasure_max= 0.352827, precision= 0.214286, recall= 0.998172
# Validation Iter 1900, auc= 0.855566, fmeasure_max= 0.795031, precision= 0.823529, recall= 0.768439
# Validation Random guess:  auc= 0.229521, fmeasure_max= 0.373941, precision= 0.230800, recall= 0.984563
# Minibatch Loss= 0.539744
# Tarin Iter 2000, auc= 0.845996, fmeasure_max= 0.803975, precision= 0.860735, recall= 0.754237
# Train Random guess:  , auc= 0.225646fmeasure_max= 0.374682, precision= 0.230619, recall= 0.998305
# Validation Iter 2000, auc= 0.856384, fmeasure_max= 0.777880, precision= 0.840637, recall= 0.723842
# Validation Random guess:  auc= 0.224541, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.669689
# Tarin Iter 2100, auc= 0.838988, fmeasure_max= 0.784995, precision= 0.790055, recall= 0.780000
# Train Random guess:  , auc= 0.216522fmeasure_max= 0.354039, precision= 0.215096, recall= 1.000000
# Validation Iter 2100, auc= 0.853073, fmeasure_max= 0.786558, precision= 0.835907, recall= 0.742710
# Validation Random guess:  auc= 0.234297, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.625780
# Tarin Iter 2200, auc= 0.820769, fmeasure_max= 0.788066, precision= 0.866516, recall= 0.722642
# Train Random guess:  , auc= 0.211071fmeasure_max= 0.343395, precision= 0.207370, recall= 0.998113
# Validation Iter 2200, auc= 0.859890, fmeasure_max= 0.805333, precision= 0.835793, recall= 0.777015
# Validation Random guess:  auc= 0.224919, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.608221
# Tarin Iter 2300, auc= 0.876683, fmeasure_max= 0.823626, precision= 0.843697, recall= 0.804487
# Train Random guess:  , auc= 0.240958fmeasure_max= 0.392541, precision= 0.244488, recall= 0.995192
# Validation Iter 2300, auc= 0.830916, fmeasure_max= 0.770197, precision= 0.807910, recall= 0.735849
# Validation Random guess:  auc= 0.223820, fmeasure_max= 0.373463, precision= 0.230156, recall= 0.989708
# Minibatch Loss= 0.670654
# Tarin Iter 2400, auc= 0.876327, fmeasure_max= 0.801587, precision= 0.885965, recall= 0.731884
# Train Random guess:  , auc= 0.283302fmeasure_max= 0.426199, precision= 0.271891, recall= 0.985507
# Validation Iter 2400, auc= 0.854736, fmeasure_max= 0.792808, precision= 0.791453, recall= 0.794168
# Validation Random guess:  auc= 0.223063, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.672573
# Tarin Iter 2500, auc= 0.916605, fmeasure_max= 0.854037, precision= 0.855365, recall= 0.852713
# Train Random guess:  , auc= 0.258847fmeasure_max= 0.403783, precision= 0.255679, recall= 0.959690
# Validation Iter 2500, auc= 0.862333, fmeasure_max= 0.785965, precision= 0.804309, recall= 0.768439
# Validation Random guess:  auc= 0.238073, fmeasure_max= 0.372568, precision= 0.230612, recall= 0.969125
# Minibatch Loss= 0.588516
# Tarin Iter 2600, auc= 0.888387, fmeasure_max= 0.820346, precision= 0.911058, recall= 0.746063
# Train Random guess:  , auc= 0.193825fmeasure_max= 0.332243, precision= 0.199216, recall= 1.000000
# Validation Iter 2600, auc= 0.858961, fmeasure_max= 0.805654, precision= 0.830601, recall= 0.782161
# Validation Random guess:  auc= 0.241738, fmeasure_max= 0.373626, precision= 0.230187, recall= 0.991424
# Minibatch Loss= 0.524940
# Tarin Iter 2700, auc= 0.879241, fmeasure_max= 0.798100, precision= 0.746667, recall= 0.857143
# Train Random guess:  , auc= 0.229283fmeasure_max= 0.373808, precision= 0.229867, recall= 1.000000
# Validation Iter 2700, auc= 0.852066, fmeasure_max= 0.788268, precision= 0.846457, recall= 0.737564
# Validation Random guess:  auc= 0.247709, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.600030
# Tarin Iter 2800, auc= 0.856682, fmeasure_max= 0.811647, precision= 0.800718, recall= 0.822878
# Train Random guess:  , auc= 0.221389fmeasure_max= 0.352862, precision= 0.215815, recall= 0.966790
# Validation Iter 2800, auc= 0.853171, fmeasure_max= 0.775435, precision= 0.832677, recall= 0.725557
# Validation Random guess:  auc= 0.244166, fmeasure_max= 0.372504, precision= 0.230178, recall= 0.975986
# Minibatch Loss= 0.613956
# Tarin Iter 2900, auc= 0.873790, fmeasure_max= 0.800427, precision= 0.829646, recall= 0.773196
# Train Random guess:  , auc= 0.195512fmeasure_max= 0.319394, precision= 0.190047, recall= 1.000000
# Validation Iter 2900, auc= 0.871688, fmeasure_max= 0.785653, precision= 0.782313, recall= 0.789022
# Validation Random guess:  auc= 0.218821, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.540701
# Tarin Iter 3000, auc= 0.864161, fmeasure_max= 0.812274, precision= 0.822669, recall= 0.802139
# Train Random guess:  , auc= 0.216203fmeasure_max= 0.359615, precision= 0.219226, recall= 1.000000
# Validation Iter 3000, auc= 0.861877, fmeasure_max= 0.778681, precision= 0.822519, recall= 0.739280
# Validation Random guess:  auc= 0.235197, fmeasure_max= 0.372936, precision= 0.229848, recall= 0.987993
# Minibatch Loss= 0.595691
# Tarin Iter 3100, auc= 0.857864, fmeasure_max= 0.787490, precision= 0.788122, recall= 0.786859
# Train Random guess:  , auc= 0.245574fmeasure_max= 0.393498, precision= 0.249463, recall= 0.931090
# Validation Iter 3100, auc= 0.874091, fmeasure_max= 0.816754, precision= 0.831261, recall= 0.802744
# Validation Random guess:  auc= 0.223521, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.651334
# Tarin Iter 3200, auc= 0.884112, fmeasure_max= 0.826007, precision= 0.802491, recall= 0.850943
# Train Random guess:  , auc= 0.208082fmeasure_max= 0.344332, precision= 0.208218, recall= 0.994340
# Validation Iter 3200, auc= 0.847655, fmeasure_max= 0.780809, precision= 0.864583, recall= 0.711835
# Validation Random guess:  auc= 0.233274, fmeasure_max= 0.371585, precision= 0.228639, recall= 0.991424
# Minibatch Loss= 0.582142
# Tarin Iter 3300, auc= 0.909101, fmeasure_max= 0.838335, precision= 0.831094, recall= 0.845703
# Train Random guess:  , auc= 0.198486fmeasure_max= 0.333333, precision= 0.200000, recall= 1.000000
# Validation Iter 3300, auc= 0.869507, fmeasure_max= 0.791703, precision= 0.797909, recall= 0.785592
# Validation Random guess:  auc= 0.229346, fmeasure_max= 0.373439, precision= 0.230988, recall= 0.974271
# Minibatch Loss= 0.480191
# Tarin Iter 3400, auc= 0.916309, fmeasure_max= 0.840580, precision= 0.897485, recall= 0.790460
# Train Random guess:  , auc= 0.230320fmeasure_max= 0.373999, precision= 0.230284, recall= 0.994889
# Validation Iter 3400, auc= 0.876181, fmeasure_max= 0.819343, precision= 0.875244, recall= 0.770154
# Validation Random guess:  auc= 0.252078, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.579616
# Tarin Iter 3500, auc= 0.879711, fmeasure_max= 0.803586, precision= 0.871025, recall= 0.745840
# Train Random guess:  , auc= 0.260996fmeasure_max= 0.411156, precision= 0.259289, recall= 0.992436
# Validation Iter 3500, auc= 0.871123, fmeasure_max= 0.807453, precision= 0.836397, recall= 0.780446
# Validation Random guess:  auc= 0.239715, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.644717
# Tarin Iter 3600, auc= 0.893989, fmeasure_max= 0.826043, precision= 0.815261, recall= 0.837113
# Train Random guess:  , auc= 0.192689fmeasure_max= 0.318660, precision= 0.189527, recall= 1.000000
# Validation Iter 3600, auc= 0.859359, fmeasure_max= 0.804899, precision= 0.821429, recall= 0.789022
# Validation Random guess:  auc= 0.228018, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.494848
# Tarin Iter 3700, auc= 0.892028, fmeasure_max= 0.809709, precision= 0.916484, recall= 0.725217
# Train Random guess:  , auc= 0.236454fmeasure_max= 0.366943, precision= 0.224697, recall= 1.000000
# Validation Iter 3700, auc= 0.856411, fmeasure_max= 0.789338, precision= 0.791379, recall= 0.787307
# Validation Random guess:  auc= 0.236649, fmeasure_max= 0.371134, precision= 0.228481, recall= 0.987993
# Minibatch Loss= 0.581773
# Tarin Iter 3800, auc= 0.912964, fmeasure_max= 0.842679, precision= 0.841369, recall= 0.843994
# Train Random guess:  , auc= 0.250409fmeasure_max= 0.402475, precision= 0.254321, recall= 0.964119
# Validation Iter 3800, auc= 0.853620, fmeasure_max= 0.798541, precision= 0.852140, recall= 0.751286
# Validation Random guess:  auc= 0.230358, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.608491
# Tarin Iter 3900, auc= 0.921380, fmeasure_max= 0.855831, precision= 0.874296, recall= 0.838129
# Train Random guess:  , auc= 0.219167fmeasure_max= 0.356868, precision= 0.217188, recall= 1.000000
# Validation Iter 3900, auc= 0.855569, fmeasure_max= 0.801754, precision= 0.820467, recall= 0.783877
# Validation Random guess:  auc= 0.229095, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.518231
# Tarin Iter 4000, auc= 0.884765, fmeasure_max= 0.796098, precision= 0.817635, recall= 0.775665
# Train Random guess:  , auc= 0.206706fmeasure_max= 0.340894, precision= 0.205469, recall= 1.000000
# Validation Iter 4000, auc= 0.838178, fmeasure_max= 0.766151, precision= 0.815891, recall= 0.722127
# Validation Random guess:  auc= 0.235973, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.525541
# Tarin Iter 4100, auc= 0.931743, fmeasure_max= 0.860847, precision= 0.907104, recall= 0.819079
# Train Random guess:  , auc= 0.238980fmeasure_max= 0.384274, precision= 0.238020, recall= 0.996711
# Validation Iter 4100, auc= 0.867368, fmeasure_max= 0.798535, precision= 0.856582, recall= 0.747856
# Validation Random guess:  auc= 0.245514, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.528464
# Tarin Iter 4200, auc= 0.899347, fmeasure_max= 0.811429, precision= 0.908316, recall= 0.733219
# Train Random guess:  , auc= 0.240836fmeasure_max= 0.371853, precision= 0.228844, recall= 0.991394
# Validation Iter 4200, auc= 0.860949, fmeasure_max= 0.804598, precision= 0.830292, recall= 0.780446
# Validation Random guess:  auc= 0.238767, fmeasure_max= 0.373368, precision= 0.230552, recall= 0.981132
# Minibatch Loss= 0.580327
# Tarin Iter 4300, auc= 0.912384, fmeasure_max= 0.830345, precision= 0.797351, recall= 0.866187
# Train Random guess:  , auc= 0.261555fmeasure_max= 0.427764, precision= 0.273604, recall= 0.979856
# Validation Iter 4300, auc= 0.871308, fmeasure_max= 0.813530, precision= 0.822807, recall= 0.804460
# Validation Random guess:  auc= 0.214032, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.625976
# Tarin Iter 4400, auc= 0.923078, fmeasure_max= 0.836052, precision= 0.800987, recall= 0.874327
# Train Random guess:  , auc= 0.226697fmeasure_max= 0.357510, precision= 0.217663, recall= 1.000000
# Validation Iter 4400, auc= 0.858545, fmeasure_max= 0.798535, precision= 0.856582, recall= 0.747856
# Validation Random guess:  auc= 0.223722, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.546439
# Tarin Iter 4500, auc= 0.925736, fmeasure_max= 0.851813, precision= 0.905286, recall= 0.804305
# Train Random guess:  , auc= 0.211367fmeasure_max= 0.332791, precision= 0.199609, recall= 1.000000
# Validation Iter 4500, auc= 0.864647, fmeasure_max= 0.797136, precision= 0.743323, recall= 0.859348
# Validation Random guess:  auc= 0.224383, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.512670
# Tarin Iter 4600, auc= 0.920742, fmeasure_max= 0.833199, precision= 0.814173, recall= 0.853135
# Train Random guess:  , auc= 0.263347fmeasure_max= 0.382817, precision= 0.236719, recall= 1.000000
# Validation Iter 4600, auc= 0.846673, fmeasure_max= 0.787511, precision= 0.796491, recall= 0.778731
# Validation Random guess:  auc= 0.242024, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.544629
# Tarin Iter 4700, auc= 0.968379, fmeasure_max= 0.907087, precision= 0.879389, recall= 0.936585
# Train Random guess:  , auc= 0.243280fmeasure_max= 0.389293, precision= 0.244297, recall= 0.957724
# Validation Iter 4700, auc= 0.848860, fmeasure_max= 0.779692, precision= 0.826923, recall= 0.737564
# Validation Random guess:  auc= 0.235259, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.484259
# Tarin Iter 4800, auc= 0.915852, fmeasure_max= 0.837073, precision= 0.841176, recall= 0.833010
# Train Random guess:  , auc= 0.190273fmeasure_max= 0.334959, precision= 0.201172, recall= 1.000000
# Validation Iter 4800, auc= 0.844752, fmeasure_max= 0.795737, precision= 0.825046, recall= 0.768439
# Validation Random guess:  auc= 0.225476, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.522013
# Tarin Iter 4900, auc= 0.917589, fmeasure_max= 0.856293, precision= 0.853755, recall= 0.858847
# Train Random guess:  , auc= 0.211131fmeasure_max= 0.329004, precision= 0.197600, recall= 0.982107
# Validation Iter 4900, auc= 0.849224, fmeasure_max= 0.803754, precision= 0.799660, recall= 0.807890
# Validation Random guess:  auc= 0.225464, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.492975
# Tarin Iter 5000, auc= 0.920835, fmeasure_max= 0.832814, precision= 0.930394, recall= 0.753759
# Train Random guess:  , auc= 0.211575fmeasure_max= 0.346064, precision= 0.210165, recall= 0.979323
# Validation Iter 5000, auc= 0.849031, fmeasure_max= 0.766667, precision= 0.745543, recall= 0.789022
# Validation Random guess:  auc= 0.239541, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.516245
# Tarin Iter 5100, auc= 0.942891, fmeasure_max= 0.885281, precision= 0.889130, recall= 0.881466
# Train Random guess:  , auc= 0.177799fmeasure_max= 0.308106, precision= 0.182543, recall= 0.987069
# Validation Iter 5100, auc= 0.860635, fmeasure_max= 0.798623, precision= 0.801382, recall= 0.795883
# Validation Random guess:  auc= 0.242140, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.431425
# Tarin Iter 5200, auc= 0.931287, fmeasure_max= 0.865136, precision= 0.872648, recall= 0.857752
# Train Random guess:  , auc= 0.283245fmeasure_max= 0.431543, precision= 0.276013, recall= 0.988620
# Validation Iter 5200, auc= 0.856644, fmeasure_max= 0.803150, precision= 0.819643, recall= 0.787307
# Validation Random guess:  auc= 0.220580, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.585756
# Tarin Iter 5300, auc= 0.951996, fmeasure_max= 0.887583, precision= 0.886931, recall= 0.888235
# Train Random guess:  , auc= 0.269105fmeasure_max= 0.421249, precision= 0.267034, recall= 0.997059
# Validation Iter 5300, auc= 0.851980, fmeasure_max= 0.777975, precision= 0.806630, recall= 0.751286
# Validation Random guess:  auc= 0.230656, fmeasure_max= 0.374227, precision= 0.230924, recall= 0.986278
# Minibatch Loss= 0.536459
# Tarin Iter 5400, auc= 0.940060, fmeasure_max= 0.874788, precision= 0.863105, recall= 0.886792
# Train Random guess:  , auc= 0.237422fmeasure_max= 0.372153, precision= 0.228887, recall= 0.994854
# Validation Iter 5400, auc= 0.848097, fmeasure_max= 0.786713, precision= 0.802139, recall= 0.771870
# Validation Random guess:  auc= 0.231029, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.493359
# Tarin Iter 5500, auc= 0.901757, fmeasure_max= 0.817348, precision= 0.812604, recall= 0.822148
# Train Random guess:  , auc= 0.230145fmeasure_max= 0.379255, precision= 0.234001, recall= 1.000000
# Validation Iter 5500, auc= 0.858209, fmeasure_max= 0.792419, precision= 0.836190, recall= 0.753002
# Validation Random guess:  auc= 0.229920, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.527638
# Tarin Iter 5600, auc= 0.904392, fmeasure_max= 0.826764, precision= 0.857414, recall= 0.798230
# Train Random guess:  , auc= 0.225425fmeasure_max= 0.361947, precision= 0.220962, recall= 1.000000
# Validation Iter 5600, auc= 0.860674, fmeasure_max= 0.787456, precision= 0.800000, recall= 0.775300
# Validation Random guess:  auc= 0.238687, fmeasure_max= 0.372154, precision= 0.229627, recall= 0.981132
# Minibatch Loss= 0.561033
# Tarin Iter 5700, auc= 0.956245, fmeasure_max= 0.889068, precision= 0.889068, recall= 0.889068
# Train Random guess:  , auc= 0.253856fmeasure_max= 0.391195, precision= 0.243159, recall= 1.000000
# Validation Iter 5700, auc= 0.849054, fmeasure_max= 0.802855, precision= 0.836431, recall= 0.771870
# Validation Random guess:  auc= 0.237422, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.516822
# Tarin Iter 5800, auc= 0.927616, fmeasure_max= 0.855713, precision= 0.865093, recall= 0.846535
# Train Random guess:  , auc= 0.234376fmeasure_max= 0.383059, precision= 0.236904, recall= 1.000000
# Validation Iter 5800, auc= 0.843076, fmeasure_max= 0.777285, precision= 0.805147, recall= 0.751286
# Validation Random guess:  auc= 0.227384, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.596635
# Tarin Iter 5900, auc= 0.933180, fmeasure_max= 0.848714, precision= 0.876563, recall= 0.822581
# Train Random guess:  , auc= 0.281958fmeasure_max= 0.421790, precision= 0.269434, recall= 0.970674
# Validation Iter 5900, auc= 0.851916, fmeasure_max= 0.777154, precision= 0.855670, recall= 0.711835
# Validation Random guess:  auc= 0.222717, fmeasure_max= 0.372033, precision= 0.228797, recall= 0.994854
# Minibatch Loss= 0.578337
# Tarin Iter 6000, auc= 0.940334, fmeasure_max= 0.883300, precision= 0.903292, recall= 0.864173
# Train Random guess:  , auc= 0.212065fmeasure_max= 0.334407, precision= 0.204376, recall= 0.919291
# Validation Iter 6000, auc= 0.847110, fmeasure_max= 0.794401, precision= 0.810714, recall= 0.778731
# Validation Random guess:  auc= 0.234845, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.438106
# Tarin Iter 6100, auc= 0.920217, fmeasure_max= 0.834259, precision= 0.844302, recall= 0.824451
# Train Random guess:  , auc= 0.251041fmeasure_max= 0.399249, precision= 0.249414, recall= 1.000000
# Validation Iter 6100, auc= 0.833518, fmeasure_max= 0.771668, precision= 0.844898, recall= 0.710120
# Validation Random guess:  auc= 0.222403, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.542970
# Tarin Iter 6200, auc= 0.935816, fmeasure_max= 0.859766, precision= 0.898778, recall= 0.824000
# Train Random guess:  , auc= 0.253492fmeasure_max= 0.395054, precision= 0.246342, recall= 0.996800
# Validation Iter 6200, auc= 0.860948, fmeasure_max= 0.796491, precision= 0.815081, recall= 0.778731
# Validation Random guess:  auc= 0.230386, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.551833
# Tarin Iter 6300, auc= 0.880943, fmeasure_max= 0.802292, precision= 0.818713, recall= 0.786517
# Train Random guess:  , auc= 0.204691fmeasure_max= 0.345319, precision= 0.208774, recall= 0.998127
# Validation Iter 6300, auc= 0.841568, fmeasure_max= 0.785461, precision= 0.812844, recall= 0.759863
# Validation Random guess:  auc= 0.213694, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.589779
# Tarin Iter 6400, auc= 0.955787, fmeasure_max= 0.877969, precision= 0.885950, recall= 0.870130
# Train Random guess:  , auc= 0.233274fmeasure_max= 0.389206, precision= 0.241910, recall= 0.995130
# Validation Iter 6400, auc= 0.836637, fmeasure_max= 0.764605, precision= 0.765921, recall= 0.763293
# Validation Random guess:  auc= 0.238568, fmeasure_max= 0.372093, precision= 0.229208, recall= 0.987993
# Minibatch Loss= 0.524254
# Tarin Iter 6500, auc= 0.929485, fmeasure_max= 0.850895, precision= 0.878850, recall= 0.824663
# Train Random guess:  , auc= 0.220632fmeasure_max= 0.338580, precision= 0.206838, recall= 0.932563
# Validation Iter 6500, auc= 0.847402, fmeasure_max= 0.779949, precision= 0.772727, recall= 0.787307
# Validation Random guess:  auc= 0.230077, fmeasure_max= 0.371346, precision= 0.228458, recall= 0.991424
# Minibatch Loss= 0.470321
# Tarin Iter 6600, auc= 0.900289, fmeasure_max= 0.821114, precision= 0.812772, recall= 0.829630
# Train Random guess:  , auc= 0.249152fmeasure_max= 0.417311, precision= 0.263672, recall= 1.000000
# Validation Iter 6600, auc= 0.867535, fmeasure_max= 0.787156, precision= 0.846154, recall= 0.735849
# Validation Random guess:  auc= 0.224223, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.627254
# Tarin Iter 6700, auc= 0.909854, fmeasure_max= 0.827706, precision= 0.803361, recall= 0.853571
# Train Random guess:  , auc= 0.228258fmeasure_max= 0.359782, precision= 0.219350, recall= 1.000000
# Validation Iter 6700, auc= 0.829701, fmeasure_max= 0.754682, precision= 0.830928, recall= 0.691252
# Validation Random guess:  auc= 0.234044, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.533063
# Tarin Iter 6800, auc= 0.910831, fmeasure_max= 0.846290, precision= 0.878899, recall= 0.816014
# Train Random guess:  , auc= 0.222704fmeasure_max= 0.374640, precision= 0.230678, recall= 0.996593
# Validation Iter 6800, auc= 0.850700, fmeasure_max= 0.782462, precision= 0.769486, recall= 0.795883
# Validation Random guess:  auc= 0.218381, fmeasure_max= 0.373103, precision= 0.233492, recall= 0.927959
# Minibatch Loss= 0.523293
# Tarin Iter 6900, auc= 0.925352, fmeasure_max= 0.862579, precision= 0.866242, recall= 0.858947
# Train Random guess:  , auc= 0.178878fmeasure_max= 0.313078, precision= 0.185664, recall= 0.997895
# Validation Iter 6900, auc= 0.839064, fmeasure_max= 0.776170, precision= 0.770270, recall= 0.782161
# Validation Random guess:  auc= 0.227972, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.535093
# Tarin Iter 7000, auc= 0.952264, fmeasure_max= 0.887906, precision= 0.887906, recall= 0.887906
# Train Random guess:  , auc= 0.270504fmeasure_max= 0.419948, precision= 0.270042, recall= 0.943953
# Validation Iter 7000, auc= 0.854710, fmeasure_max= 0.811881, precision= 0.854167, recall= 0.773585
# Validation Random guess:  auc= 0.229675, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.508945
# Tarin Iter 7100, auc= 0.927422, fmeasure_max= 0.844291, precision= 0.841379, recall= 0.847222
# Train Random guess:  , auc= 0.225638fmeasure_max= 0.367347, precision= 0.225000, recall= 1.000000
# Validation Iter 7100, auc= 0.860370, fmeasure_max= 0.793460, precision= 0.796200, recall= 0.790738
# Validation Random guess:  auc= 0.244096, fmeasure_max= 0.376050, precision= 0.236252, recall= 0.921098
# Minibatch Loss= 0.526616
# Tarin Iter 7200, auc= 0.920457, fmeasure_max= 0.842706, precision= 0.860233, recall= 0.825879
# Train Random guess:  , auc= 0.249628fmeasure_max= 0.393701, precision= 0.245194, recall= 0.998403
# Validation Iter 7200, auc= 0.861562, fmeasure_max= 0.804965, precision= 0.833028, recall= 0.778731
# Validation Random guess:  auc= 0.232214, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.562550
# Tarin Iter 7300, auc= 0.929900, fmeasure_max= 0.870287, precision= 0.875569, recall= 0.865067
# Train Random guess:  , auc= 0.276711fmeasure_max= 0.413772, precision= 0.260853, recall= 1.000000
# Validation Iter 7300, auc= 0.834063, fmeasure_max= 0.778388, precision= 0.834971, recall= 0.728988
# Validation Random guess:  auc= 0.230532, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.626216
# Tarin Iter 7400, auc= 0.952356, fmeasure_max= 0.880795, precision= 0.875000, recall= 0.886667
# Train Random guess:  , auc= 0.185976fmeasure_max= 0.301950, precision= 0.177892, recall= 0.997778
# Validation Iter 7400, auc= 0.834587, fmeasure_max= 0.776682, precision= 0.813910, recall= 0.742710
# Validation Random guess:  auc= 0.218241, fmeasure_max= 0.373134, precision= 0.230092, recall= 0.986278
# Minibatch Loss= 0.380162
# Tarin Iter 7500, auc= 0.923940, fmeasure_max= 0.851298, precision= 0.888342, recall= 0.817221
# Train Random guess:  , auc= 0.246784fmeasure_max= 0.411471, precision= 0.259230, recall= 0.996979
# Validation Iter 7500, auc= 0.844940, fmeasure_max= 0.790571, precision= 0.838462, recall= 0.747856
# Validation Random guess:  auc= 0.225953, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.544267
# Tarin Iter 7600, auc= 0.945774, fmeasure_max= 0.885216, precision= 0.881170, recall= 0.889299
# Train Random guess:  , auc= 0.226918fmeasure_max= 0.350129, precision= 0.212216, recall= 1.000000
# Validation Iter 7600, auc= 0.847298, fmeasure_max= 0.811828, precision= 0.849906, recall= 0.777015
# Validation Random guess:  auc= 0.235323, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.444680
# Tarin Iter 7700, auc= 0.926185, fmeasure_max= 0.836050, precision= 0.914046, recall= 0.770318
# Train Random guess:  , auc= 0.231317fmeasure_max= 0.363753, precision= 0.222310, recall= 1.000000
# Validation Iter 7700, auc= 0.855396, fmeasure_max= 0.810084, precision= 0.794069, recall= 0.826758
# Validation Random guess:  auc= 0.235294, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.524365
# Tarin Iter 7800, auc= 0.952068, fmeasure_max= 0.883074, precision= 0.891089, recall= 0.875203
# Train Random guess:  , auc= 0.249570fmeasure_max= 0.390071, precision= 0.243461, recall= 0.980551
# Validation Iter 7800, auc= 0.850103, fmeasure_max= 0.810764, precision= 0.820738, recall= 0.801029
# Validation Random guess:  auc= 0.231272, fmeasure_max= 0.373940, precision= 0.233080, recall= 0.945111
# Minibatch Loss= 0.478496
# Tarin Iter 7900, auc= 0.928800, fmeasure_max= 0.846753, precision= 0.868561, recall= 0.826014
# Train Random guess:  , auc= 0.242557fmeasure_max= 0.377044, precision= 0.232687, recall= 0.993243
# Validation Iter 7900, auc= 0.825450, fmeasure_max= 0.772647, precision= 0.801105, recall= 0.746141
# Validation Random guess:  auc= 0.230624, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.525486
# Tarin Iter 8000, auc= 0.898730, fmeasure_max= 0.815745, precision= 0.863475, recall= 0.773016
# Train Random guess:  , auc= 0.268698fmeasure_max= 0.396694, precision= 0.248013, recall= 0.990476
# Validation Iter 8000, auc= 0.823322, fmeasure_max= 0.776699, precision= 0.800000, recall= 0.754717
# Validation Random guess:  auc= 0.221059, fmeasure_max= 0.373110, precision= 0.229612, recall= 0.994854
# Minibatch Loss= 0.585167
# Tarin Iter 8100, auc= 0.936344, fmeasure_max= 0.871637, precision= 0.818182, recall= 0.932566
# Train Random guess:  , auc= 0.255596fmeasure_max= 0.384299, precision= 0.237946, recall= 0.998355
# Validation Iter 8100, auc= 0.820427, fmeasure_max= 0.767502, precision= 0.773519, recall= 0.761578
# Validation Random guess:  auc= 0.217316, fmeasure_max= 0.372483, precision= 0.231539, recall= 0.951973
# Minibatch Loss= 0.473433
# Tarin Iter 8200, auc= 0.907893, fmeasure_max= 0.828036, precision= 0.812800, recall= 0.843854
# Train Random guess:  , auc= 0.236871fmeasure_max= 0.381871, precision= 0.236748, recall= 0.986711
# Validation Iter 8200, auc= 0.839121, fmeasure_max= 0.776903, precision= 0.792857, recall= 0.761578
# Validation Random guess:  auc= 0.218168, fmeasure_max= 0.373105, precision= 0.230926, recall= 0.970840
# Minibatch Loss= 0.537538
# Tarin Iter 8300, auc= 0.961002, fmeasure_max= 0.913160, precision= 0.935780, recall= 0.891608
# Train Random guess:  , auc= 0.222408fmeasure_max= 0.367809, precision= 0.225615, recall= 0.994755
# Validation Iter 8300, auc= 0.841137, fmeasure_max= 0.791993, precision= 0.803887, recall= 0.780446
# Validation Random guess:  auc= 0.240942, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.441939
# Tarin Iter 8400, auc= 0.952262, fmeasure_max= 0.889580, precision= 0.877301, recall= 0.902208
# Train Random guess:  , auc= 0.254929fmeasure_max= 0.398241, precision= 0.248627, recall= 1.000000
# Validation Iter 8400, auc= 0.836902, fmeasure_max= 0.777778, precision= 0.845070, recall= 0.720412
# Validation Random guess:  auc= 0.232174, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.492930
# Tarin Iter 8500, auc= 0.914215, fmeasure_max= 0.842887, precision= 0.866812, recall= 0.820248
# Train Random guess:  , auc= 0.196988fmeasure_max= 0.318736, precision= 0.189581, recall= 1.000000
# Validation Iter 8500, auc= 0.842427, fmeasure_max= 0.788909, precision= 0.824299, recall= 0.756432
# Validation Random guess:  auc= 0.214977, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.453704
# Tarin Iter 8600, auc= 0.951033, fmeasure_max= 0.890017, precision= 0.876667, recall= 0.903780
# Train Random guess:  , auc= 0.233142fmeasure_max= 0.370701, precision= 0.227522, recall= 1.000000
# Validation Iter 8600, auc= 0.845475, fmeasure_max= 0.785649, precision= 0.847222, recall= 0.732419
# Validation Random guess:  auc= 0.225870, fmeasure_max= 0.374261, precision= 0.231425, recall= 0.977702
# Minibatch Loss= 0.438787
# Tarin Iter 8700, auc= 0.938955, fmeasure_max= 0.859259, precision= 0.857143, recall= 0.861386
# Train Random guess:  , auc= 0.255507fmeasure_max= 0.385954, precision= 0.239792, recall= 0.988449
# Validation Iter 8700, auc= 0.825668, fmeasure_max= 0.776801, precision= 0.796396, recall= 0.758148
# Validation Random guess:  auc= 0.222037, fmeasure_max= 0.372199, precision= 0.229567, recall= 0.982847
# Minibatch Loss= 0.501828
# Tarin Iter 8800, auc= 0.952208, fmeasure_max= 0.882673, precision= 0.905901, recall= 0.860606
# Train Random guess:  , auc= 0.260096fmeasure_max= 0.410467, precision= 0.259156, recall= 0.986364
# Validation Iter 8800, auc= 0.841853, fmeasure_max= 0.775300, precision= 0.775300, recall= 0.775300
# Validation Random guess:  auc= 0.228083, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.481716
# Tarin Iter 8900, auc= 0.937958, fmeasure_max= 0.869048, precision= 0.907638, recall= 0.833605
# Train Random guess:  , auc= 0.243760fmeasure_max= 0.386751, precision= 0.239734, recall= 1.000000
# Validation Iter 8900, auc= 0.836791, fmeasure_max= 0.789798, precision= 0.810469, recall= 0.770154
# Validation Random guess:  auc= 0.211967, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.529125
# Tarin Iter 9000, auc= 0.945209, fmeasure_max= 0.882556, precision= 0.914132, recall= 0.853088
# Train Random guess:  , auc= 0.229469fmeasure_max= 0.380680, precision= 0.235086, recall= 1.000000
# Validation Iter 9000, auc= 0.835571, fmeasure_max= 0.778182, precision= 0.827853, recall= 0.734134
# Validation Random guess:  auc= 0.243588, fmeasure_max= 0.373584, precision= 0.230247, recall= 0.989708
# Minibatch Loss= 0.492704
# Tarin Iter 9100, auc= 0.932465, fmeasure_max= 0.861538, precision= 0.888060, recall= 0.836555
# Train Random guess:  , auc= 0.226734fmeasure_max= 0.363869, precision= 0.222483, recall= 0.998243
# Validation Iter 9100, auc= 0.848225, fmeasure_max= 0.772556, precision= 0.854470, recall= 0.704974
# Validation Random guess:  auc= 0.223790, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.506105
# Tarin Iter 9200, auc= 0.942887, fmeasure_max= 0.874172, precision= 0.836767, recall= 0.915078
# Train Random guess:  , auc= 0.217463fmeasure_max= 0.368169, precision= 0.225705, recall= 0.998267
# Validation Iter 9200, auc= 0.827930, fmeasure_max= 0.775435, precision= 0.832677, recall= 0.725557
# Validation Random guess:  auc= 0.228576, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.522690
# Tarin Iter 9300, auc= 0.932220, fmeasure_max= 0.871965, precision= 0.877778, recall= 0.866228
# Train Random guess:  , auc= 0.196918fmeasure_max= 0.304392, precision= 0.179660, recall= 0.995614
# Validation Iter 9300, auc= 0.845510, fmeasure_max= 0.794667, precision= 0.824723, recall= 0.766724
# Validation Random guess:  auc= 0.219933, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.426532
# Tarin Iter 9400, auc= 0.941755, fmeasure_max= 0.878899, precision= 0.897004, recall= 0.861511
# Train Random guess:  , auc= 0.226143fmeasure_max= 0.357929, precision= 0.218232, recall= 0.994604
# Validation Iter 9400, auc= 0.832861, fmeasure_max= 0.780053, precision= 0.811111, recall= 0.751286
# Validation Random guess:  auc= 0.233144, fmeasure_max= 0.372606, precision= 0.229784, recall= 0.984563
# Minibatch Loss= 0.482449
# Tarin Iter 9500, auc= 0.930168, fmeasure_max= 0.860825, precision= 0.849153, recall= 0.872822
# Train Random guess:  , auc= 0.235844fmeasure_max= 0.368250, precision= 0.226400, recall= 0.986063
# Validation Iter 9500, auc= 0.844727, fmeasure_max= 0.796281, precision= 0.785000, recall= 0.807890
# Validation Random guess:  auc= 0.238917, fmeasure_max= 0.373436, precision= 0.229676, recall= 0.998285
# Minibatch Loss= 0.519215
# Tarin Iter 9600, auc= 0.955890, fmeasure_max= 0.892333, precision= 0.876603, recall= 0.908638
# Train Random guess:  , auc= 0.236881fmeasure_max= 0.381013, precision= 0.235340, recall= 1.000000
# Validation Iter 9600, auc= 0.840364, fmeasure_max= 0.783562, precision= 0.837891, recall= 0.735849
# Validation Random guess:  auc= 0.232537, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.450542
# Tarin Iter 9700, auc= 0.911470, fmeasure_max= 0.837438, precision= 0.822581, recall= 0.852843
# Train Random guess:  , auc= 0.243646fmeasure_max= 0.379201, precision= 0.233959, recall= 1.000000
# Validation Iter 9700, auc= 0.830254, fmeasure_max= 0.779152, precision= 0.803279, recall= 0.756432
# Validation Random guess:  auc= 0.230882, fmeasure_max= 0.374448, precision= 0.233475, recall= 0.945111
# Minibatch Loss= 0.541069
# Tarin Iter 9800, auc= 0.937289, fmeasure_max= 0.869427, precision= 0.887805, recall= 0.851794
# Train Random guess:  , auc= 0.256151fmeasure_max= 0.402007, precision= 0.251570, recall= 1.000000
# Validation Iter 9800, auc= 0.827574, fmeasure_max= 0.775801, precision= 0.805915, recall= 0.747856
# Validation Random guess:  auc= 0.227550, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.560273
# Tarin Iter 9900, auc= 0.941247, fmeasure_max= 0.891213, precision= 0.865854, recall= 0.918103
# Train Random guess:  , auc= 0.163415fmeasure_max= 0.306878, precision= 0.181250, recall= 1.000000
# Validation Iter 9900, auc= 0.842653, fmeasure_max= 0.779399, precision= 0.780069, recall= 0.778731
# Validation Random guess:  auc= 0.228111, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.385546
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.849545 F1_max = 0.778399 prec = 0.780115 rec = 0.776689
# Test Random guess: auc= 0.230531 fmeasure_max= 0.375663 , precision= 0.231682 , recall= 0.992399

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
