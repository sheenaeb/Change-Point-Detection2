# %%
# useing this variable for saving models and summaries
exp_name = "CNN1006"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2, 1]
weights_shape = [[3, n_variables, 32],
                 [3, 32, 32],
                 [3, 32, 32],
                 [3, 32, 32],
                 [3, 32, 32],
                 [3, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.226263, fmeasure_max= 0.405568, precision= 0.254466, recall= 0.998442
# Train Random guess:  , auc= 0.262829fmeasure_max= 0.401380, precision= 0.251276, recall= 0.996885
# Validation Iter 0, auc= 0.255683, fmeasure_max= 0.384921, precision= 0.238427, recall= 0.998285
# Validation Random guess:  auc= 0.221780, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 1.094018
# Tarin Iter 100, auc= 0.580012, fmeasure_max= 0.534422, precision= 0.601050, recall= 0.481092
# Train Random guess:  , auc= 0.184678fmeasure_max= 0.315789, precision= 0.189553, recall= 0.945378
# Validation Iter 100, auc= 0.442500, fmeasure_max= 0.444541, precision= 0.297391, recall= 0.879931
# Validation Random guess:  auc= 0.214733, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.906145
# Tarin Iter 200, auc= 0.643521, fmeasure_max= 0.541512, precision= 0.445464, recall= 0.690363
# Train Random guess:  , auc= 0.251902fmeasure_max= 0.397583, precision= 0.248905, recall= 0.987362
# Validation Iter 200, auc= 0.615258, fmeasure_max= 0.520851, precision= 0.516892, recall= 0.524871
# Validation Random guess:  auc= 0.225178, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.937641
# Tarin Iter 300, auc= 0.742520, fmeasure_max= 0.682403, precision= 0.777506, recall= 0.608031
# Train Random guess:  , auc= 0.215459fmeasure_max= 0.339280, precision= 0.204297, recall= 1.000000
# Validation Iter 300, auc= 0.766910, fmeasure_max= 0.700911, precision= 0.677885, recall= 0.725557
# Validation Random guess:  auc= 0.223514, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.858890
# Tarin Iter 400, auc= 0.797734, fmeasure_max= 0.745794, precision= 0.798000, recall= 0.700000
# Train Random guess:  , auc= 0.222495fmeasure_max= 0.364887, precision= 0.224325, recall= 0.977193
# Validation Iter 400, auc= 0.802871, fmeasure_max= 0.731878, precision= 0.745552, recall= 0.718696
# Validation Random guess:  auc= 0.231928, fmeasure_max= 0.373812, precision= 0.235164, recall= 0.910806
# Minibatch Loss= 0.833951
# Tarin Iter 500, auc= 0.775115, fmeasure_max= 0.717904, precision= 0.752747, recall= 0.686144
# Train Random guess:  , auc= 0.220547fmeasure_max= 0.379924, precision= 0.234602, recall= 0.998331
# Validation Iter 500, auc= 0.798901, fmeasure_max= 0.715111, precision= 0.689490, recall= 0.742710
# Validation Random guess:  auc= 0.222854, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.810440
# Tarin Iter 600, auc= 0.800870, fmeasure_max= 0.738648, precision= 0.851163, recall= 0.652406
# Train Random guess:  , auc= 0.214232fmeasure_max= 0.361516, precision= 0.220903, recall= 0.994652
# Validation Iter 600, auc= 0.820259, fmeasure_max= 0.749565, precision= 0.760141, recall= 0.739280
# Validation Random guess:  auc= 0.220215, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.772811
# Tarin Iter 700, auc= 0.764780, fmeasure_max= 0.685437, precision= 0.703187, recall= 0.668561
# Train Random guess:  , auc= 0.200974fmeasure_max= 0.342968, precision= 0.206978, recall= 1.000000
# Validation Iter 700, auc= 0.830582, fmeasure_max= 0.751667, precision= 0.730956, recall= 0.773585
# Validation Random guess:  auc= 0.230833, fmeasure_max= 0.372268, precision= 0.232409, recall= 0.934820
# Minibatch Loss= 0.748898
# Tarin Iter 800, auc= 0.883097, fmeasure_max= 0.802416, precision= 0.846995, recall= 0.762295
# Train Random guess:  , auc= 0.238986fmeasure_max= 0.384979, precision= 0.238374, recall= 1.000000
# Validation Iter 800, auc= 0.833837, fmeasure_max= 0.753873, precision= 0.756477, recall= 0.751286
# Validation Random guess:  auc= 0.238416, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.704996
# Tarin Iter 900, auc= 0.838542, fmeasure_max= 0.770070, precision= 0.816529, recall= 0.728614
# Train Random guess:  , auc= 0.269908fmeasure_max= 0.419415, precision= 0.265773, recall= 0.994100
# Validation Iter 900, auc= 0.820636, fmeasure_max= 0.730570, precision= 0.735652, recall= 0.725557
# Validation Random guess:  auc= 0.246885, fmeasure_max= 0.371987, precision= 0.229594, recall= 0.979417
# Minibatch Loss= 0.756324
# Tarin Iter 1000, auc= 0.799607, fmeasure_max= 0.719651, precision= 0.825651, recall= 0.637771
# Train Random guess:  , auc= 0.248434fmeasure_max= 0.404935, precision= 0.254473, recall= 0.990712
# Validation Iter 1000, auc= 0.824156, fmeasure_max= 0.738382, precision= 0.740933, recall= 0.735849
# Validation Random guess:  auc= 0.220905, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.762552
# Tarin Iter 1100, auc= 0.786945, fmeasure_max= 0.718367, precision= 0.743243, recall= 0.695103
# Train Random guess:  , auc= 0.236149fmeasure_max= 0.396492, precision= 0.247266, recall= 1.000000
# Validation Iter 1100, auc= 0.827850, fmeasure_max= 0.742358, precision= 0.756228, recall= 0.728988
# Validation Random guess:  auc= 0.227594, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.744708
# Tarin Iter 1200, auc= 0.731342, fmeasure_max= 0.649057, precision= 0.769575, recall= 0.561175
# Train Random guess:  , auc= 0.239933fmeasure_max= 0.386933, precision= 0.240157, recall= 0.995106
# Validation Iter 1200, auc= 0.802124, fmeasure_max= 0.715649, precision= 0.806452, recall= 0.643225
# Validation Random guess:  auc= 0.233757, fmeasure_max= 0.371180, precision= 0.228424, recall= 0.989708
# Minibatch Loss= 0.840998
# Tarin Iter 1300, auc= 0.809278, fmeasure_max= 0.750626, precision= 0.799290, recall= 0.707547
# Train Random guess:  , auc= 0.255336fmeasure_max= 0.401835, precision= 0.253830, recall= 0.963836
# Validation Iter 1300, auc= 0.790465, fmeasure_max= 0.711645, precision= 0.771543, recall= 0.660377
# Validation Random guess:  auc= 0.231898, fmeasure_max= 0.373589, precision= 0.233333, recall= 0.936535
# Minibatch Loss= 0.753327
# Tarin Iter 1400, auc= 0.866784, fmeasure_max= 0.786713, precision= 0.825688, recall= 0.751252
# Train Random guess:  , auc= 0.221007fmeasure_max= 0.379234, precision= 0.233984, recall= 1.000000
# Validation Iter 1400, auc= 0.826189, fmeasure_max= 0.748387, precision= 0.808765, recall= 0.696398
# Validation Random guess:  auc= 0.232084, fmeasure_max= 0.374790, precision= 0.232917, recall= 0.958834
# Minibatch Loss= 0.667825
# Tarin Iter 1500, auc= 0.837849, fmeasure_max= 0.786042, precision= 0.880658, recall= 0.709784
# Train Random guess:  , auc= 0.234597fmeasure_max= 0.383710, precision= 0.237402, recall= 1.000000
# Validation Iter 1500, auc= 0.805444, fmeasure_max= 0.727106, precision= 0.779961, recall= 0.680961
# Validation Random guess:  auc= 0.226715, fmeasure_max= 0.374150, precision= 0.233347, recall= 0.943396
# Minibatch Loss= 0.716747
# Tarin Iter 1600, auc= 0.852345, fmeasure_max= 0.784878, precision= 0.828897, recall= 0.745299
# Train Random guess:  , auc= 0.229564fmeasure_max= 0.372730, precision= 0.229052, recall= 1.000000
# Validation Iter 1600, auc= 0.802356, fmeasure_max= 0.715613, precision= 0.780933, recall= 0.660377
# Validation Random guess:  auc= 0.240868, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.774619
# Tarin Iter 1700, auc= 0.832670, fmeasure_max= 0.768103, precision= 0.846465, recall= 0.703020
# Train Random guess:  , auc= 0.226117fmeasure_max= 0.377707, precision= 0.233097, recall= 0.994966
# Validation Iter 1700, auc= 0.816043, fmeasure_max= 0.732270, precision= 0.757798, recall= 0.708405
# Validation Random guess:  auc= 0.219381, fmeasure_max= 0.371273, precision= 0.228312, recall= 0.993139
# Minibatch Loss= 0.732155
# Tarin Iter 1800, auc= 0.799336, fmeasure_max= 0.739130, precision= 0.809524, recall= 0.680000
# Train Random guess:  , auc= 0.227373fmeasure_max= 0.367060, precision= 0.224785, recall= 1.000000
# Validation Iter 1800, auc= 0.814229, fmeasure_max= 0.733617, precision= 0.728041, recall= 0.739280
# Validation Random guess:  auc= 0.225763, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.723784
# Tarin Iter 1900, auc= 0.828630, fmeasure_max= 0.759287, precision= 0.807267, recall= 0.716690
# Train Random guess:  , auc= 0.275621fmeasure_max= 0.437021, precision= 0.279608, recall= 1.000000
# Validation Iter 1900, auc= 0.802163, fmeasure_max= 0.713787, precision= 0.726465, recall= 0.701544
# Validation Random guess:  auc= 0.222975, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.789754
# Tarin Iter 2000, auc= 0.828503, fmeasure_max= 0.766234, precision= 0.882793, recall= 0.676864
# Train Random guess:  , auc= 0.210480fmeasure_max= 0.339954, precision= 0.204867, recall= 0.998088
# Validation Iter 2000, auc= 0.811751, fmeasure_max= 0.729330, precision= 0.740283, recall= 0.718696
# Validation Random guess:  auc= 0.240200, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.716479
# Tarin Iter 2100, auc= 0.793288, fmeasure_max= 0.735910, precision= 0.755372, recall= 0.717425
# Train Random guess:  , auc= 0.237409fmeasure_max= 0.398499, precision= 0.248828, recall= 1.000000
# Validation Iter 2100, auc= 0.815461, fmeasure_max= 0.731621, precision= 0.756410, recall= 0.708405
# Validation Random guess:  auc= 0.223741, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.747638
# Tarin Iter 2200, auc= 0.806698, fmeasure_max= 0.732478, precision= 0.757143, recall= 0.709369
# Train Random guess:  , auc= 0.198304fmeasure_max= 0.339980, precision= 0.205047, recall= 0.994264
# Validation Iter 2200, auc= 0.803692, fmeasure_max= 0.720705, precision= 0.740942, recall= 0.701544
# Validation Random guess:  auc= 0.232331, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.627121
# Tarin Iter 2300, auc= 0.844563, fmeasure_max= 0.760383, precision= 0.800448, recall= 0.724138
# Train Random guess:  , auc= 0.196149fmeasure_max= 0.324022, precision= 0.193333, recall= 1.000000
# Validation Iter 2300, auc= 0.815564, fmeasure_max= 0.741014, precision= 0.800797, recall= 0.689537
# Validation Random guess:  auc= 0.223359, fmeasure_max= 0.372272, precision= 0.228977, recall= 0.994854
# Minibatch Loss= 0.702235
# Tarin Iter 2400, auc= 0.804922, fmeasure_max= 0.723845, precision= 0.803347, recall= 0.658662
# Train Random guess:  , auc= 0.231614fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Validation Iter 2400, auc= 0.822028, fmeasure_max= 0.739090, precision= 0.805668, recall= 0.682676
# Validation Random guess:  auc= 0.235919, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.686551
# Tarin Iter 2500, auc= 0.848182, fmeasure_max= 0.790698, precision= 0.831522, recall= 0.753695
# Train Random guess:  , auc= 0.229849fmeasure_max= 0.384932, precision= 0.238431, recall= 0.998358
# Validation Iter 2500, auc= 0.821003, fmeasure_max= 0.745240, precision= 0.790385, recall= 0.704974
# Validation Random guess:  auc= 0.245340, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.659108
# Tarin Iter 2600, auc= 0.763925, fmeasure_max= 0.733898, precision= 0.797422, recall= 0.679749
# Train Random guess:  , auc= 0.244048fmeasure_max= 0.398998, precision= 0.249218, recall= 1.000000
# Validation Iter 2600, auc= 0.816491, fmeasure_max= 0.742557, precision= 0.758497, recall= 0.727273
# Validation Random guess:  auc= 0.229341, fmeasure_max= 0.373197, precision= 0.229495, recall= 0.998285
# Minibatch Loss= 0.863208
# Tarin Iter 2700, auc= 0.859781, fmeasure_max= 0.796373, precision= 0.807692, recall= 0.785366
# Train Random guess:  , auc= 0.247539fmeasure_max= 0.387524, precision= 0.240328, recall= 1.000000
# Validation Iter 2700, auc= 0.803897, fmeasure_max= 0.720293, precision= 0.771037, recall= 0.675815
# Validation Random guess:  auc= 0.229005, fmeasure_max= 0.372138, precision= 0.229150, recall= 0.989708
# Minibatch Loss= 0.675085
# Tarin Iter 2800, auc= 0.791299, fmeasure_max= 0.746528, precision= 0.784672, recall= 0.711921
# Train Random guess:  , auc= 0.232912fmeasure_max= 0.382158, precision= 0.236214, recall= 1.000000
# Validation Iter 2800, auc= 0.795668, fmeasure_max= 0.716535, precision= 0.840647, recall= 0.624357
# Validation Random guess:  auc= 0.222089, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.739260
# Tarin Iter 2900, auc= 0.852652, fmeasure_max= 0.791150, precision= 0.874755, recall= 0.722132
# Train Random guess:  , auc= 0.248523fmeasure_max= 0.389723, precision= 0.245585, recall= 0.943457
# Validation Iter 2900, auc= 0.817315, fmeasure_max= 0.733706, precision= 0.802444, recall= 0.675815
# Validation Random guess:  auc= 0.203242, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.738825
# Tarin Iter 3000, auc= 0.880442, fmeasure_max= 0.815987, precision= 0.834753, recall= 0.798046
# Train Random guess:  , auc= 0.248384fmeasure_max= 0.387015, precision= 0.239937, recall= 1.000000
# Validation Iter 3000, auc= 0.809836, fmeasure_max= 0.715596, precision= 0.769231, recall= 0.668954
# Validation Random guess:  auc= 0.235557, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.663253
# Tarin Iter 3100, auc= 0.885336, fmeasure_max= 0.813360, precision= 0.843177, recall= 0.785579
# Train Random guess:  , auc= 0.201440fmeasure_max= 0.343750, precision= 0.208384, recall= 0.981025
# Validation Iter 3100, auc= 0.818058, fmeasure_max= 0.739752, precision= 0.832618, recall= 0.665523
# Validation Random guess:  auc= 0.230686, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.584469
# Tarin Iter 3200, auc= 0.862083, fmeasure_max= 0.783307, precision= 0.822934, recall= 0.747320
# Train Random guess:  , auc= 0.244451fmeasure_max= 0.406494, precision= 0.255294, recall= 0.996937
# Validation Iter 3200, auc= 0.792279, fmeasure_max= 0.715750, precision= 0.783673, recall= 0.658662
# Validation Random guess:  auc= 0.231516, fmeasure_max= 0.372351, precision= 0.229871, recall= 0.979417
# Minibatch Loss= 0.730355
# Tarin Iter 3300, auc= 0.840509, fmeasure_max= 0.767764, precision= 0.808394, recall= 0.731023
# Train Random guess:  , auc= 0.259268fmeasure_max= 0.383397, precision= 0.237255, recall= 0.998350
# Validation Iter 3300, auc= 0.814698, fmeasure_max= 0.732955, precision= 0.818182, recall= 0.663808
# Validation Random guess:  auc= 0.241275, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.711121
# Tarin Iter 3400, auc= 0.842216, fmeasure_max= 0.757342, precision= 0.771654, recall= 0.743551
# Train Random guess:  , auc= 0.274360fmeasure_max= 0.413092, precision= 0.261254, recall= 0.986343
# Validation Iter 3400, auc= 0.807062, fmeasure_max= 0.730516, precision= 0.807054, recall= 0.667238
# Validation Random guess:  auc= 0.222990, fmeasure_max= 0.371824, precision= 0.228820, recall= 0.991424
# Minibatch Loss= 0.798525
# Tarin Iter 3500, auc= 0.845609, fmeasure_max= 0.769604, precision= 0.822107, recall= 0.723404
# Train Random guess:  , auc= 0.244283fmeasure_max= 0.408950, precision= 0.257031, recall= 1.000000
# Validation Iter 3500, auc= 0.815043, fmeasure_max= 0.736538, precision= 0.838074, recall= 0.656947
# Validation Random guess:  auc= 0.224401, fmeasure_max= 0.372893, precision= 0.230958, recall= 0.967410
# Minibatch Loss= 0.719024
# Tarin Iter 3600, auc= 0.854924, fmeasure_max= 0.783595, precision= 0.778163, recall= 0.789104
# Train Random guess:  , auc= 0.234911fmeasure_max= 0.365466, precision= 0.224124, recall= 0.989455
# Validation Iter 3600, auc= 0.799588, fmeasure_max= 0.713387, precision= 0.749057, recall= 0.680961
# Validation Random guess:  auc= 0.222464, fmeasure_max= 0.373930, precision= 0.231365, recall= 0.974271
# Minibatch Loss= 0.627865
# Tarin Iter 3700, auc= 0.828290, fmeasure_max= 0.774741, precision= 0.826962, recall= 0.728723
# Train Random guess:  , auc= 0.231160fmeasure_max= 0.362003, precision= 0.221003, recall= 1.000000
# Validation Iter 3700, auc= 0.813046, fmeasure_max= 0.731047, precision= 0.771429, recall= 0.694683
# Validation Random guess:  auc= 0.233897, fmeasure_max= 0.372454, precision= 0.229482, recall= 0.987993
# Minibatch Loss= 0.691577
# Tarin Iter 3800, auc= 0.851443, fmeasure_max= 0.791667, precision= 0.799235, recall= 0.784240
# Train Random guess:  , auc= 0.199138fmeasure_max= 0.344761, precision= 0.208284, recall= 1.000000
# Validation Iter 3800, auc= 0.820540, fmeasure_max= 0.737705, precision= 0.786408, recall= 0.694683
# Validation Random guess:  auc= 0.233681, fmeasure_max= 0.371134, precision= 0.228481, recall= 0.987993
# Minibatch Loss= 0.657739
# Tarin Iter 3900, auc= 0.923020, fmeasure_max= 0.849026, precision= 0.874582, recall= 0.824921
# Train Random guess:  , auc= 0.251353fmeasure_max= 0.397243, precision= 0.247850, recall= 1.000000
# Validation Iter 3900, auc= 0.799214, fmeasure_max= 0.719453, precision= 0.836364, recall= 0.631218
# Validation Random guess:  auc= 0.210010, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.541798
# Tarin Iter 4000, auc= 0.879108, fmeasure_max= 0.805479, precision= 0.882000, recall= 0.741176
# Train Random guess:  , auc= 0.244866fmeasure_max= 0.377299, precision= 0.232513, recall= 1.000000
# Validation Iter 4000, auc= 0.768940, fmeasure_max= 0.687081, precision= 0.777056, recall= 0.615780
# Validation Random guess:  auc= 0.230682, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.662214
# Tarin Iter 4100, auc= 0.876093, fmeasure_max= 0.811828, precision= 0.814748, recall= 0.808929
# Train Random guess:  , auc= 0.219718fmeasure_max= 0.362231, precision= 0.223096, recall= 0.962500
# Validation Iter 4100, auc= 0.765951, fmeasure_max= 0.706943, precision= 0.745247, recall= 0.672384
# Validation Random guess:  auc= 0.239737, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.692986
# Tarin Iter 4200, auc= 0.870130, fmeasure_max= 0.799185, precision= 0.850325, recall= 0.753846
# Train Random guess:  , auc= 0.191813fmeasure_max= 0.339571, precision= 0.206284, recall= 0.959615
# Validation Iter 4200, auc= 0.793959, fmeasure_max= 0.703739, precision= 0.797826, recall= 0.629503
# Validation Random guess:  auc= 0.222844, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.542286
# Tarin Iter 4300, auc= 0.871804, fmeasure_max= 0.820779, precision= 0.861818, recall= 0.783471
# Train Random guess:  , auc= 0.234373fmeasure_max= 0.383806, precision= 0.237757, recall= 0.995041
# Validation Iter 4300, auc= 0.809179, fmeasure_max= 0.726358, precision= 0.878345, recall= 0.619211
# Validation Random guess:  auc= 0.208279, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.643341
# Tarin Iter 4400, auc= 0.802252, fmeasure_max= 0.714761, precision= 0.882192, recall= 0.600746
# Train Random guess:  , auc= 0.215135fmeasure_max= 0.346253, precision= 0.209375, recall= 1.000000
# Validation Iter 4400, auc= 0.795468, fmeasure_max= 0.701787, precision= 0.777083, recall= 0.639794
# Validation Random guess:  auc= 0.232189, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.690700
# Tarin Iter 4500, auc= 0.864833, fmeasure_max= 0.785582, precision= 0.851703, recall= 0.728988
# Train Random guess:  , auc= 0.234547fmeasure_max= 0.372250, precision= 0.231872, recall= 0.943396
# Validation Iter 4500, auc= 0.790483, fmeasure_max= 0.711744, precision= 0.739372, recall= 0.686106
# Validation Random guess:  auc= 0.250129, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.637220
# Tarin Iter 4600, auc= 0.810892, fmeasure_max= 0.751848, precision= 0.827907, recall= 0.688588
# Train Random guess:  , auc= 0.219080fmeasure_max= 0.336042, precision= 0.201953, recall= 1.000000
# Validation Iter 4600, auc= 0.762774, fmeasure_max= 0.692374, precision= 0.691781, recall= 0.692967
# Validation Random guess:  auc= 0.222227, fmeasure_max= 0.371009, precision= 0.227933, recall= 0.996569
# Minibatch Loss= 0.719305
# Tarin Iter 4700, auc= 0.875708, fmeasure_max= 0.797735, precision= 0.813531, recall= 0.782540
# Train Random guess:  , auc= 0.243808fmeasure_max= 0.395473, precision= 0.246570, recall= 0.998413
# Validation Iter 4700, auc= 0.800733, fmeasure_max= 0.719927, precision= 0.774704, recall= 0.672384
# Validation Random guess:  auc= 0.239054, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.672485
# Tarin Iter 4800, auc= 0.885692, fmeasure_max= 0.802130, precision= 0.759664, recall= 0.849624
# Train Random guess:  , auc= 0.216243fmeasure_max= 0.348338, precision= 0.213497, recall= 0.945489
# Validation Iter 4800, auc= 0.799258, fmeasure_max= 0.712946, precision= 0.786749, recall= 0.651801
# Validation Random guess:  auc= 0.231566, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.549199
# Tarin Iter 4900, auc= 0.909108, fmeasure_max= 0.822222, precision= 0.879342, recall= 0.772071
# Train Random guess:  , auc= 0.242398fmeasure_max= 0.391701, precision= 0.243550, recall= 1.000000
# Validation Iter 4900, auc= 0.810768, fmeasure_max= 0.733962, precision= 0.815514, recall= 0.667238
# Validation Random guess:  auc= 0.245019, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.600394
# Tarin Iter 5000, auc= 0.830457, fmeasure_max= 0.761726, precision= 0.791423, recall= 0.734177
# Train Random guess:  , auc= 0.218984fmeasure_max= 0.356464, precision= 0.221347, recall= 0.915009
# Validation Iter 5000, auc= 0.793431, fmeasure_max= 0.719331, precision= 0.784990, recall= 0.663808
# Validation Random guess:  auc= 0.236085, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.638538
# Tarin Iter 5100, auc= 0.833375, fmeasure_max= 0.762976, precision= 0.856311, recall= 0.687988
# Train Random guess:  , auc= 0.253222fmeasure_max= 0.403821, precision= 0.255950, recall= 0.956318
# Validation Iter 5100, auc= 0.790971, fmeasure_max= 0.710280, precision= 0.780287, recall= 0.651801
# Validation Random guess:  auc= 0.238944, fmeasure_max= 0.372018, precision= 0.229059, recall= 0.989708
# Minibatch Loss= 0.730750
# Tarin Iter 5200, auc= 0.907770, fmeasure_max= 0.824675, precision= 0.819355, recall= 0.830065
# Train Random guess:  , auc= 0.234236fmeasure_max= 0.391914, precision= 0.244807, recall= 0.982026
# Validation Iter 5200, auc= 0.809510, fmeasure_max= 0.734619, precision= 0.790514, recall= 0.686106
# Validation Random guess:  auc= 0.227200, fmeasure_max= 0.373913, precision= 0.232239, recall= 0.958834
# Minibatch Loss= 0.600424
# Tarin Iter 5300, auc= 0.843201, fmeasure_max= 0.770971, precision= 0.794175, recall= 0.749084
# Train Random guess:  , auc= 0.232111fmeasure_max= 0.351804, precision= 0.213448, recall= 1.000000
# Validation Iter 5300, auc= 0.809320, fmeasure_max= 0.733132, precision= 0.887805, recall= 0.624357
# Validation Random guess:  auc= 0.240883, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.641093
# Tarin Iter 5400, auc= 0.870391, fmeasure_max= 0.786436, precision= 0.842349, recall= 0.737483
# Train Random guess:  , auc= 0.287938fmeasure_max= 0.449755, precision= 0.290693, recall= 0.993234
# Validation Iter 5400, auc= 0.815699, fmeasure_max= 0.737561, precision= 0.855204, recall= 0.648370
# Validation Random guess:  auc= 0.236295, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.746391
# Tarin Iter 5500, auc= 0.870066, fmeasure_max= 0.777219, precision= 0.795883, recall= 0.759411
# Train Random guess:  , auc= 0.243953fmeasure_max= 0.385864, precision= 0.239526, recall= 0.991817
# Validation Iter 5500, auc= 0.822075, fmeasure_max= 0.739655, precision= 0.743501, recall= 0.735849
# Validation Random guess:  auc= 0.239456, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.623550
# Tarin Iter 5600, auc= 0.851923, fmeasure_max= 0.803220, precision= 0.842402, recall= 0.767521
# Train Random guess:  , auc= 0.216165fmeasure_max= 0.372019, precision= 0.228516, recall= 1.000000
# Validation Iter 5600, auc= 0.779885, fmeasure_max= 0.706096, precision= 0.751938, recall= 0.665523
# Validation Random guess:  auc= 0.222522, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.652919
# Tarin Iter 5700, auc= 0.873924, fmeasure_max= 0.789525, precision= 0.804348, recall= 0.775238
# Train Random guess:  , auc= 0.203866fmeasure_max= 0.341592, precision= 0.206635, recall= 0.984762
# Validation Iter 5700, auc= 0.817347, fmeasure_max= 0.740484, precision= 0.746946, recall= 0.734134
# Validation Random guess:  auc= 0.219725, fmeasure_max= 0.371108, precision= 0.228278, recall= 0.991424
# Minibatch Loss= 0.602807
# Tarin Iter 5800, auc= 0.847328, fmeasure_max= 0.800959, precision= 0.869792, recall= 0.742222
# Train Random guess:  , auc= 0.253534fmeasure_max= 0.419761, precision= 0.266480, recall= 0.988148
# Validation Iter 5800, auc= 0.787383, fmeasure_max= 0.702599, precision= 0.800439, recall= 0.626072
# Validation Random guess:  auc= 0.220746, fmeasure_max= 0.372937, precision= 0.230895, recall= 0.969125
# Minibatch Loss= 0.708827
# Tarin Iter 5900, auc= 0.870044, fmeasure_max= 0.792262, precision= 0.787625, recall= 0.796954
# Train Random guess:  , auc= 0.230399fmeasure_max= 0.376858, precision= 0.232920, recall= 0.986464
# Validation Iter 5900, auc= 0.792436, fmeasure_max= 0.717254, precision= 0.757634, recall= 0.680961
# Validation Random guess:  auc= 0.226512, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.653766
# Tarin Iter 6000, auc= 0.831507, fmeasure_max= 0.786194, precision= 0.877944, recall= 0.711806
# Train Random guess:  , auc= 0.226770fmeasure_max= 0.369916, precision= 0.227201, recall= 0.994792
# Validation Iter 6000, auc= 0.804911, fmeasure_max= 0.715431, precision= 0.860241, recall= 0.612350
# Validation Random guess:  auc= 0.232535, fmeasure_max= 0.378157, precision= 0.236046, recall= 0.950257
# Minibatch Loss= 0.655643
# Tarin Iter 6100, auc= 0.880143, fmeasure_max= 0.822042, precision= 0.875000, recall= 0.775128
# Train Random guess:  , auc= 0.221682fmeasure_max= 0.374515, precision= 0.231138, recall= 0.986371
# Validation Iter 6100, auc= 0.820652, fmeasure_max= 0.750232, precision= 0.817814, recall= 0.692967
# Validation Random guess:  auc= 0.237504, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.629480
# Tarin Iter 6200, auc= 0.823891, fmeasure_max= 0.763828, precision= 0.760490, recall= 0.767196
# Train Random guess:  , auc= 0.215312fmeasure_max= 0.364751, precision= 0.223232, recall= 0.996473
# Validation Iter 6200, auc= 0.818426, fmeasure_max= 0.746544, precision= 0.806773, recall= 0.694683
# Validation Random guess:  auc= 0.243294, fmeasure_max= 0.371762, precision= 0.229142, recall= 0.984563
# Minibatch Loss= 0.672745
# Tarin Iter 6300, auc= 0.867721, fmeasure_max= 0.800352, precision= 0.780446, recall= 0.821300
# Train Random guess:  , auc= 0.220240fmeasure_max= 0.356270, precision= 0.216745, recall= 1.000000
# Validation Iter 6300, auc= 0.826998, fmeasure_max= 0.753131, precision= 0.786916, recall= 0.722127
# Validation Random guess:  auc= 0.223103, fmeasure_max= 0.375169, precision= 0.233515, recall= 0.953688
# Minibatch Loss= 0.595175
# Tarin Iter 6400, auc= 0.921886, fmeasure_max= 0.840580, precision= 0.857391, recall= 0.824415
# Train Random guess:  , auc= 0.244041fmeasure_max= 0.382895, precision= 0.238329, recall= 0.973244
# Validation Iter 6400, auc= 0.817935, fmeasure_max= 0.751640, precision= 0.828512, recall= 0.687822
# Validation Random guess:  auc= 0.228578, fmeasure_max= 0.372587, precision= 0.229307, recall= 0.993139
# Minibatch Loss= 0.514662
# Tarin Iter 6500, auc= 0.900931, fmeasure_max= 0.826291, precision= 0.861057, recall= 0.794224
# Train Random guess:  , auc= 0.224068fmeasure_max= 0.359242, precision= 0.219298, recall= 0.992780
# Validation Iter 6500, auc= 0.788339, fmeasure_max= 0.697628, precision= 0.822844, recall= 0.605489
# Validation Random guess:  auc= 0.237491, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.576746
# Tarin Iter 6600, auc= 0.908721, fmeasure_max= 0.834320, precision= 0.900000, recall= 0.777574
# Train Random guess:  , auc= 0.222405fmeasure_max= 0.351194, precision= 0.212999, recall= 1.000000
# Validation Iter 6600, auc= 0.816131, fmeasure_max= 0.739169, precision= 0.762774, recall= 0.716981
# Validation Random guess:  auc= 0.222686, fmeasure_max= 0.372870, precision= 0.232667, recall= 0.938250
# Minibatch Loss= 0.522542
# Tarin Iter 6700, auc= 0.894263, fmeasure_max= 0.847603, precision= 0.837563, recall= 0.857886
# Train Random guess:  , auc= 0.211184fmeasure_max= 0.368051, precision= 0.225617, recall= 0.998267
# Validation Iter 6700, auc= 0.796875, fmeasure_max= 0.721251, precision= 0.777778, recall= 0.672384
# Validation Random guess:  auc= 0.232248, fmeasure_max= 0.371026, precision= 0.229335, recall= 0.970840
# Minibatch Loss= 0.608871
# Tarin Iter 6800, auc= 0.872163, fmeasure_max= 0.821799, precision= 0.854317, recall= 0.791667
# Train Random guess:  , auc= 0.218025fmeasure_max= 0.380108, precision= 0.234650, recall= 1.000000
# Validation Iter 6800, auc= 0.798233, fmeasure_max= 0.720930, precision= 0.828508, recall= 0.638079
# Validation Random guess:  auc= 0.220643, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.617935
# Tarin Iter 6900, auc= 0.848606, fmeasure_max= 0.753363, precision= 0.831683, recall= 0.688525
# Train Random guess:  , auc= 0.260269fmeasure_max= 0.387841, precision= 0.246448, recall= 0.909836
# Validation Iter 6900, auc= 0.778338, fmeasure_max= 0.687596, precision= 0.621024, recall= 0.770154
# Validation Random guess:  auc= 0.226381, fmeasure_max= 0.371353, precision= 0.230169, recall= 0.960549
# Minibatch Loss= 0.662062
# Tarin Iter 7000, auc= 0.873802, fmeasure_max= 0.779692, precision= 0.809793, recall= 0.751748
# Train Random guess:  , auc= 0.213031fmeasure_max= 0.365495, precision= 0.223612, recall= 1.000000
# Validation Iter 7000, auc= 0.823186, fmeasure_max= 0.735652, precision= 0.746032, recall= 0.725557
# Validation Random guess:  auc= 0.219702, fmeasure_max= 0.371824, precision= 0.228820, recall= 0.991424
# Minibatch Loss= 0.572880
# Tarin Iter 7100, auc= 0.814413, fmeasure_max= 0.748673, precision= 0.798113, recall= 0.705000
# Train Random guess:  , auc= 0.225189fmeasure_max= 0.380228, precision= 0.234742, recall= 1.000000
# Validation Iter 7100, auc= 0.807082, fmeasure_max= 0.709106, precision= 0.668693, recall= 0.754717
# Validation Random guess:  auc= 0.227406, fmeasure_max= 0.374300, precision= 0.231648, recall= 0.974271
# Minibatch Loss= 0.749615
# Tarin Iter 7200, auc= 0.878492, fmeasure_max= 0.797753, precision= 0.793296, recall= 0.802260
# Train Random guess:  , auc= 0.205379fmeasure_max= 0.346925, precision= 0.212442, recall= 0.945386
# Validation Iter 7200, auc= 0.802128, fmeasure_max= 0.704314, precision= 0.648844, recall= 0.770154
# Validation Random guess:  auc= 0.240495, fmeasure_max= 0.373225, precision= 0.232421, recall= 0.946827
# Minibatch Loss= 0.621539
# Tarin Iter 7300, auc= 0.906414, fmeasure_max= 0.823091, precision= 0.864971, recall= 0.785080
# Train Random guess:  , auc= 0.216505fmeasure_max= 0.361640, precision= 0.220994, recall= 0.994671
# Validation Iter 7300, auc= 0.811847, fmeasure_max= 0.722372, precision= 0.758491, recall= 0.689537
# Validation Random guess:  auc= 0.223388, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.563889
# Tarin Iter 7400, auc= 0.836481, fmeasure_max= 0.752667, precision= 0.818565, recall= 0.696589
# Train Random guess:  , auc= 0.197928fmeasure_max= 0.357739, precision= 0.217833, recall= 1.000000
# Validation Iter 7400, auc= 0.806665, fmeasure_max= 0.703629, precision= 0.853301, recall= 0.598628
# Validation Random guess:  auc= 0.217414, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.653973
# Tarin Iter 7500, auc= 0.875705, fmeasure_max= 0.795096, precision= 0.781411, recall= 0.809269
# Train Random guess:  , auc= 0.227420fmeasure_max= 0.360497, precision= 0.223555, recall= 0.930481
# Validation Iter 7500, auc= 0.812492, fmeasure_max= 0.731939, precision= 0.820896, recall= 0.660377
# Validation Random guess:  auc= 0.240843, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.599463
# Tarin Iter 7600, auc= 0.900538, fmeasure_max= 0.812734, precision= 0.826667, recall= 0.799263
# Train Random guess:  , auc= 0.218120fmeasure_max= 0.353923, precision= 0.216150, recall= 0.976059
# Validation Iter 7600, auc= 0.821778, fmeasure_max= 0.732090, precision= 0.855505, recall= 0.639794
# Validation Random guess:  auc= 0.233086, fmeasure_max= 0.372771, precision= 0.229816, recall= 0.986278
# Minibatch Loss= 0.524785
# Tarin Iter 7700, auc= 0.885034, fmeasure_max= 0.791587, precision= 0.828000, recall= 0.758242
# Train Random guess:  , auc= 0.212515fmeasure_max= 0.353055, precision= 0.214370, recall= 1.000000
# Validation Iter 7700, auc= 0.814394, fmeasure_max= 0.727977, precision= 0.835556, recall= 0.644940
# Validation Random guess:  auc= 0.228379, fmeasure_max= 0.372378, precision= 0.229332, recall= 0.989708
# Minibatch Loss= 0.553958
# Tarin Iter 7800, auc= 0.892563, fmeasure_max= 0.809473, precision= 0.876457, recall= 0.752000
# Train Random guess:  , auc= 0.203125fmeasure_max= 0.331010, precision= 0.200422, recall= 0.950000
# Validation Iter 7800, auc= 0.828483, fmeasure_max= 0.745763, precision= 0.776952, recall= 0.716981
# Validation Random guess:  auc= 0.216576, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.537928
# Tarin Iter 7900, auc= 0.828863, fmeasure_max= 0.761404, precision= 0.741880, recall= 0.781982
# Train Random guess:  , auc= 0.217157fmeasure_max= 0.356913, precision= 0.217221, recall= 1.000000
# Validation Iter 7900, auc= 0.816039, fmeasure_max= 0.725417, precision= 0.789899, recall= 0.670669
# Validation Random guess:  auc= 0.225341, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.652845
# Tarin Iter 8000, auc= 0.885248, fmeasure_max= 0.831703, precision= 0.867347, recall= 0.798872
# Train Random guess:  , auc= 0.214988fmeasure_max= 0.345801, precision= 0.212858, recall= 0.921053
# Validation Iter 8000, auc= 0.822049, fmeasure_max= 0.735986, precision= 0.778203, recall= 0.698113
# Validation Random guess:  auc= 0.229134, fmeasure_max= 0.374920, precision= 0.230708, recall= 1.000000
# Minibatch Loss= 0.574894
# Tarin Iter 8100, auc= 0.851699, fmeasure_max= 0.771165, precision= 0.765391, recall= 0.777027
# Train Random guess:  , auc= 0.224659fmeasure_max= 0.376231, precision= 0.231703, recall= 1.000000
# Validation Iter 8100, auc= 0.811752, fmeasure_max= 0.714563, precision= 0.823266, recall= 0.631218
# Validation Random guess:  auc= 0.221728, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.652391
# Tarin Iter 8200, auc= 0.860082, fmeasure_max= 0.779899, precision= 0.798354, recall= 0.762279
# Train Random guess:  , auc= 0.200815fmeasure_max= 0.332462, precision= 0.199373, recall= 1.000000
# Validation Iter 8200, auc= 0.791053, fmeasure_max= 0.714709, precision= 0.841860, recall= 0.620926
# Validation Random guess:  auc= 0.240386, fmeasure_max= 0.372498, precision= 0.229423, recall= 0.989708
# Minibatch Loss= 0.604168
# Tarin Iter 8300, auc= 0.847547, fmeasure_max= 0.787585, precision= 0.789883, recall= 0.785300
# Train Random guess:  , auc= 0.202680fmeasure_max= 0.336042, precision= 0.201953, recall= 1.000000
# Validation Iter 8300, auc= 0.799020, fmeasure_max= 0.697218, precision= 0.666667, recall= 0.730703
# Validation Random guess:  auc= 0.231759, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.577545
# Tarin Iter 8400, auc= 0.901777, fmeasure_max= 0.819549, precision= 0.860979, recall= 0.781923
# Train Random guess:  , auc= 0.274625fmeasure_max= 0.429615, precision= 0.279482, recall= 0.928264
# Validation Iter 8400, auc= 0.838090, fmeasure_max= 0.748214, precision= 0.780261, recall= 0.718696
# Validation Random guess:  auc= 0.231257, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.648000
# Tarin Iter 8500, auc= 0.858981, fmeasure_max= 0.789916, precision= 0.815972, recall= 0.765472
# Train Random guess:  , auc= 0.240171fmeasure_max= 0.387994, precision= 0.240690, recall= 1.000000
# Validation Iter 8500, auc= 0.825869, fmeasure_max= 0.736086, precision= 0.772128, recall= 0.703259
# Validation Random guess:  auc= 0.226077, fmeasure_max= 0.372626, precision= 0.230271, recall= 0.975986
# Minibatch Loss= 0.655717
# Tarin Iter 8600, auc= 0.882403, fmeasure_max= 0.805301, precision= 0.840426, recall= 0.772994
# Train Random guess:  , auc= 0.192969fmeasure_max= 0.333007, precision= 0.199765, recall= 1.000000
# Validation Iter 8600, auc= 0.812490, fmeasure_max= 0.745583, precision= 0.768670, recall= 0.723842
# Validation Random guess:  auc= 0.234123, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.584109
# Tarin Iter 8700, auc= 0.895629, fmeasure_max= 0.825342, precision= 0.838261, recall= 0.812816
# Train Random guess:  , auc= 0.236352fmeasure_max= 0.376867, precision= 0.232185, recall= 1.000000
# Validation Iter 8700, auc= 0.804117, fmeasure_max= 0.725146, precision= 0.706840, recall= 0.744425
# Validation Random guess:  auc= 0.243665, fmeasure_max= 0.374454, precision= 0.232860, recall= 0.955403
# Minibatch Loss= 0.627438
# Tarin Iter 8800, auc= 0.873169, fmeasure_max= 0.818756, precision= 0.884990, recall= 0.761745
# Train Random guess:  , auc= 0.243787fmeasure_max= 0.378361, precision= 0.233782, recall= 0.991611
# Validation Iter 8800, auc= 0.799017, fmeasure_max= 0.707022, precision= 0.667683, recall= 0.751286
# Validation Random guess:  auc= 0.229235, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.619479
# Tarin Iter 8900, auc= 0.903209, fmeasure_max= 0.819320, precision= 0.823741, recall= 0.814947
# Train Random guess:  , auc= 0.211549fmeasure_max= 0.361236, precision= 0.220519, recall= 0.998221
# Validation Iter 8900, auc= 0.816635, fmeasure_max= 0.729335, precision= 0.691244, recall= 0.771870
# Validation Random guess:  auc= 0.224596, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.560322
# Tarin Iter 9000, auc= 0.931225, fmeasure_max= 0.859946, precision= 0.871609, recall= 0.848592
# Train Random guess:  , auc= 0.207438fmeasure_max= 0.363520, precision= 0.222135, recall= 1.000000
# Validation Iter 9000, auc= 0.822566, fmeasure_max= 0.737303, precision= 0.753131, recall= 0.722127
# Validation Random guess:  auc= 0.228917, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.498199
# Tarin Iter 9100, auc= 0.881261, fmeasure_max= 0.808898, precision= 0.862069, recall= 0.761905
# Train Random guess:  , auc= 0.186109fmeasure_max= 0.341431, precision= 0.206267, recall= 0.990476
# Validation Iter 9100, auc= 0.827650, fmeasure_max= 0.745170, precision= 0.803571, recall= 0.694683
# Validation Random guess:  auc= 0.227069, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.536305
# Tarin Iter 9200, auc= 0.920028, fmeasure_max= 0.852377, precision= 0.881034, recall= 0.825525
# Train Random guess:  , auc= 0.250053fmeasure_max= 0.390431, precision= 0.243243, recall= 0.988691
# Validation Iter 9200, auc= 0.838974, fmeasure_max= 0.762332, precision= 0.798872, recall= 0.728988
# Validation Random guess:  auc= 0.231656, fmeasure_max= 0.373178, precision= 0.230032, recall= 0.987993
# Minibatch Loss= 0.561888
# Tarin Iter 9300, auc= 0.893457, fmeasure_max= 0.816960, precision= 0.918605, recall= 0.735568
# Train Random guess:  , auc= 0.200060fmeasure_max= 0.348869, precision= 0.213776, recall= 0.947858
# Validation Iter 9300, auc= 0.775189, fmeasure_max= 0.703297, precision= 0.648336, recall= 0.768439
# Validation Random guess:  auc= 0.210118, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.538019
# Tarin Iter 9400, auc= 0.852021, fmeasure_max= 0.791322, precision= 0.870455, recall= 0.725379
# Train Random guess:  , auc= 0.199076fmeasure_max= 0.343099, precision= 0.207154, recall= 0.998106
# Validation Iter 9400, auc= 0.819135, fmeasure_max= 0.725926, precision= 0.788732, recall= 0.672384
# Validation Random guess:  auc= 0.237296, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.598859
# Tarin Iter 9500, auc= 0.893728, fmeasure_max= 0.814063, precision= 0.810264, recall= 0.817896
# Train Random guess:  , auc= 0.251277fmeasure_max= 0.402801, precision= 0.255715, recall= 0.948195
# Validation Iter 9500, auc= 0.819218, fmeasure_max= 0.739650, precision= 0.797619, recall= 0.689537
# Validation Random guess:  auc= 0.230157, fmeasure_max= 0.372108, precision= 0.229686, recall= 0.979417
# Minibatch Loss= 0.633318
# Tarin Iter 9600, auc= 0.902964, fmeasure_max= 0.820821, precision= 0.879828, recall= 0.769231
# Train Random guess:  , auc= 0.195392fmeasure_max= 0.344872, precision= 0.208366, recall= 1.000000
# Validation Iter 9600, auc= 0.815606, fmeasure_max= 0.726050, precision= 0.711697, recall= 0.740995
# Validation Random guess:  auc= 0.239801, fmeasure_max= 0.371882, precision= 0.229233, recall= 0.984563
# Minibatch Loss= 0.510606
# Tarin Iter 9700, auc= 0.922629, fmeasure_max= 0.866841, precision= 0.912088, recall= 0.825871
# Train Random guess:  , auc= 0.235162fmeasure_max= 0.382259, precision= 0.236665, recall= 0.993367
# Validation Iter 9700, auc= 0.825360, fmeasure_max= 0.742044, precision= 0.725041, recall= 0.759863
# Validation Random guess:  auc= 0.232138, fmeasure_max= 0.372739, precision= 0.229606, recall= 0.989708
# Minibatch Loss= 0.528955
# Tarin Iter 9800, auc= 0.919466, fmeasure_max= 0.840067, precision= 0.883186, recall= 0.800963
# Train Random guess:  , auc= 0.252313fmeasure_max= 0.393016, precision= 0.244954, recall= 0.993579
# Validation Iter 9800, auc= 0.812922, fmeasure_max= 0.716390, precision= 0.773360, recall= 0.667238
# Validation Random guess:  auc= 0.226270, fmeasure_max= 0.374822, precision= 0.236429, recall= 0.903945
# Minibatch Loss= 0.550723
# Tarin Iter 9900, auc= 0.827339, fmeasure_max= 0.727088, precision= 0.802247, recall= 0.664804
# Train Random guess:  , auc= 0.209030fmeasure_max= 0.347150, precision= 0.210114, recall= 0.998138
# Validation Iter 9900, auc= 0.770283, fmeasure_max= 0.690000, precision= 0.827338, recall= 0.591767
# Validation Random guess:  auc= 0.231190, fmeasure_max= 0.372031, precision= 0.231089, recall= 0.953688
# Minibatch Loss= 0.656767
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.793846 F1_max = 0.719880 prec = 0.755053 rec = 0.687838
# Test Random guess: auc= 0.231561 fmeasure_max= 0.375763 , precision= 0.231438 , recall= 0.998311

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
