# %%
# useing this variable for saving models and summaries
exp_name = "CNN1008"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.150185, fmeasure_max= 0.326377, precision= 0.195572, recall= 0.985537
# Train Random guess:  , auc= 0.190576fmeasure_max= 0.318438, precision= 0.189594, recall= 0.993802
# Validation Iter 0, auc= 0.242318, fmeasure_max= 0.405986, precision= 0.261493, recall= 0.907376
# Validation Random guess:  auc= 0.224560, fmeasure_max= 0.371035, precision= 0.228132, recall= 0.993139
# Minibatch Loss= 1.004113
# Tarin Iter 100, auc= 0.765576, fmeasure_max= 0.697789, precision= 0.753982, recall= 0.649390
# Train Random guess:  , auc= 0.248613fmeasure_max= 0.407960, precision= 0.256250, recall= 1.000000
# Validation Iter 100, auc= 0.724138, fmeasure_max= 0.691756, precision= 0.724203, recall= 0.662093
# Validation Random guess:  auc= 0.222041, fmeasure_max= 0.372511, precision= 0.229158, recall= 0.994854
# Minibatch Loss= 0.878469
# Tarin Iter 200, auc= 0.853503, fmeasure_max= 0.789238, precision= 0.846154, recall= 0.739496
# Train Random guess:  , auc= 0.243358fmeasure_max= 0.377622, precision= 0.232850, recall= 0.998319
# Validation Iter 200, auc= 0.829519, fmeasure_max= 0.776831, precision= 0.771574, recall= 0.782161
# Validation Random guess:  auc= 0.234161, fmeasure_max= 0.373237, precision= 0.230738, recall= 0.975986
# Minibatch Loss= 0.681389
# Tarin Iter 300, auc= 0.800804, fmeasure_max= 0.795414, precision= 0.821494, recall= 0.770940
# Train Random guess:  , auc= 0.228042fmeasure_max= 0.373273, precision= 0.229826, recall= 0.993162
# Validation Iter 300, auc= 0.815531, fmeasure_max= 0.783666, precision= 0.794014, recall= 0.773585
# Validation Random guess:  auc= 0.228961, fmeasure_max= 0.372485, precision= 0.229692, recall= 0.984563
# Minibatch Loss= 0.827076
# Tarin Iter 400, auc= 0.834693, fmeasure_max= 0.819731, precision= 0.857411, recall= 0.785223
# Train Random guess:  , auc= 0.226486fmeasure_max= 0.370465, precision= 0.227344, recall= 1.000000
# Validation Iter 400, auc= 0.856641, fmeasure_max= 0.813206, precision= 0.823944, recall= 0.802744
# Validation Random guess:  auc= 0.228099, fmeasure_max= 0.374384, precision= 0.231519, recall= 0.977702
# Minibatch Loss= 0.682862
# Tarin Iter 500, auc= 0.908850, fmeasure_max= 0.867470, precision= 0.887064, recall= 0.848723
# Train Random guess:  , auc= 0.204620fmeasure_max= 0.332560, precision= 0.200000, recall= 0.986248
# Validation Iter 500, auc= 0.875640, fmeasure_max= 0.813644, precision= 0.789984, recall= 0.838765
# Validation Random guess:  auc= 0.219848, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.575873
# Tarin Iter 600, auc= 0.840686, fmeasure_max= 0.789264, precision= 0.855603, recall= 0.732472
# Train Random guess:  , auc= 0.226106fmeasure_max= 0.350394, precision= 0.213089, recall= 0.985240
# Validation Iter 600, auc= 0.802765, fmeasure_max= 0.746690, precision= 0.769091, recall= 0.725557
# Validation Random guess:  auc= 0.219746, fmeasure_max= 0.372340, precision= 0.230928, recall= 0.960549
# Minibatch Loss= 0.665024
# Tarin Iter 700, auc= 0.898306, fmeasure_max= 0.816879, precision= 0.846535, recall= 0.789231
# Train Random guess:  , auc= 0.259883fmeasure_max= 0.405111, precision= 0.254005, recall= 1.000000
# Validation Iter 700, auc= 0.832015, fmeasure_max= 0.787931, precision= 0.792028, recall= 0.783877
# Validation Random guess:  auc= 0.242241, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.683979
# Tarin Iter 800, auc= 0.841724, fmeasure_max= 0.770723, precision= 0.797445, recall= 0.745734
# Train Random guess:  , auc= 0.222830fmeasure_max= 0.373801, precision= 0.231842, recall= 0.964164
# Validation Iter 800, auc= 0.867137, fmeasure_max= 0.803390, precision= 0.793970, recall= 0.813036
# Validation Random guess:  auc= 0.220352, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.629063
# Tarin Iter 900, auc= 0.821810, fmeasure_max= 0.774194, precision= 0.748800, recall= 0.801370
# Train Random guess:  , auc= 0.234749fmeasure_max= 0.371885, precision= 0.228594, recall= 0.996575
# Validation Iter 900, auc= 0.849354, fmeasure_max= 0.771654, precision= 0.787500, recall= 0.756432
# Validation Random guess:  auc= 0.226821, fmeasure_max= 0.371869, precision= 0.228763, recall= 0.993139
# Minibatch Loss= 0.658161
# Tarin Iter 1000, auc= 0.846661, fmeasure_max= 0.800777, precision= 0.834008, recall= 0.770093
# Train Random guess:  , auc= 0.208105fmeasure_max= 0.349983, precision= 0.213235, recall= 0.975701
# Validation Iter 1000, auc= 0.866530, fmeasure_max= 0.815567, precision= 0.804674, recall= 0.826758
# Validation Random guess:  auc= 0.242475, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.615805
# Tarin Iter 1100, auc= 0.861106, fmeasure_max= 0.819588, precision= 0.864130, recall= 0.779412
# Train Random guess:  , auc= 0.255678fmeasure_max= 0.390003, precision= 0.244133, recall= 0.968954
# Validation Iter 1100, auc= 0.895000, fmeasure_max= 0.829150, precision= 0.785276, recall= 0.878216
# Validation Random guess:  auc= 0.226347, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.687423
# Tarin Iter 1200, auc= 0.878162, fmeasure_max= 0.813278, precision= 0.829103, recall= 0.798046
# Train Random guess:  , auc= 0.243231fmeasure_max= 0.387504, precision= 0.240313, recall= 1.000000
# Validation Iter 1200, auc= 0.907966, fmeasure_max= 0.831123, precision= 0.857664, recall= 0.806175
# Validation Random guess:  auc= 0.239517, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.644528
# Tarin Iter 1300, auc= 0.887076, fmeasure_max= 0.794025, precision= 0.799051, recall= 0.789062
# Train Random guess:  , auc= 0.250956fmeasure_max= 0.401010, precision= 0.251286, recall= 0.992188
# Validation Iter 1300, auc= 0.896035, fmeasure_max= 0.822593, precision= 0.767062, recall= 0.886792
# Validation Random guess:  auc= 0.237413, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.639354
# Tarin Iter 1400, auc= 0.896664, fmeasure_max= 0.826753, precision= 0.870968, recall= 0.786810
# Train Random guess:  , auc= 0.259118fmeasure_max= 0.406231, precision= 0.254887, recall= 1.000000
# Validation Iter 1400, auc= 0.891582, fmeasure_max= 0.830718, precision= 0.800955, recall= 0.862779
# Validation Random guess:  auc= 0.242544, fmeasure_max= 0.371419, precision= 0.229829, recall= 0.967410
# Minibatch Loss= 0.626072
# Tarin Iter 1500, auc= 0.879834, fmeasure_max= 0.810573, precision= 0.933063, recall= 0.716511
# Train Random guess:  , auc= 0.243173fmeasure_max= 0.401375, precision= 0.251075, recall= 1.000000
# Validation Iter 1500, auc= 0.898679, fmeasure_max= 0.836024, precision= 0.828283, recall= 0.843911
# Validation Random guess:  auc= 0.231308, fmeasure_max= 0.373989, precision= 0.230463, recall= 0.991424
# Minibatch Loss= 0.605250
# Tarin Iter 1600, auc= 0.894438, fmeasure_max= 0.834915, precision= 0.817844, recall= 0.852713
# Train Random guess:  , auc= 0.207201fmeasure_max= 0.336047, precision= 0.201957, recall= 1.000000
# Validation Iter 1600, auc= 0.884010, fmeasure_max= 0.842735, precision= 0.839864, recall= 0.845626
# Validation Random guess:  auc= 0.249487, fmeasure_max= 0.371697, precision= 0.247306, recall= 0.747856
# Minibatch Loss= 0.548433
# Tarin Iter 1700, auc= 0.941938, fmeasure_max= 0.873141, precision= 0.857388, recall= 0.889483
# Train Random guess:  , auc= 0.223377fmeasure_max= 0.360560, precision= 0.220541, recall= 0.987522
# Validation Iter 1700, auc= 0.903281, fmeasure_max= 0.837905, precision= 0.812903, recall= 0.864494
# Validation Random guess:  auc= 0.225161, fmeasure_max= 0.373826, precision= 0.230431, recall= 0.989708
# Minibatch Loss= 0.508359
# Tarin Iter 1800, auc= 0.917068, fmeasure_max= 0.857886, precision= 0.871479, recall= 0.844710
# Train Random guess:  , auc= 0.225198fmeasure_max= 0.374110, precision= 0.230831, recall= 0.986348
# Validation Iter 1800, auc= 0.901190, fmeasure_max= 0.824156, precision= 0.854512, recall= 0.795883
# Validation Random guess:  auc= 0.226045, fmeasure_max= 0.372569, precision= 0.232538, recall= 0.936535
# Minibatch Loss= 0.552282
# Tarin Iter 1900, auc= 0.813442, fmeasure_max= 0.724832, precision= 0.928367, recall= 0.594495
# Train Random guess:  , auc= 0.230570fmeasure_max= 0.351047, precision= 0.212891, recall= 1.000000
# Validation Iter 1900, auc= 0.907918, fmeasure_max= 0.831354, precision= 0.772059, recall= 0.900515
# Validation Random guess:  auc= 0.232425, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.658062
# Tarin Iter 2000, auc= 0.884388, fmeasure_max= 0.828352, precision= 0.844948, recall= 0.812395
# Train Random guess:  , auc= 0.225690fmeasure_max= 0.378207, precision= 0.233203, recall= 1.000000
# Validation Iter 2000, auc= 0.905417, fmeasure_max= 0.835377, precision= 0.853309, recall= 0.818182
# Validation Random guess:  auc= 0.232238, fmeasure_max= 0.372272, precision= 0.228977, recall= 0.994854
# Minibatch Loss= 0.607194
# Tarin Iter 2100, auc= 0.902505, fmeasure_max= 0.836634, precision= 0.930275, recall= 0.760120
# Train Random guess:  , auc= 0.265744fmeasure_max= 0.413387, precision= 0.260547, recall= 1.000000
# Validation Iter 2100, auc= 0.900665, fmeasure_max= 0.841453, precision= 0.869963, recall= 0.814751
# Validation Random guess:  auc= 0.228641, fmeasure_max= 0.372762, precision= 0.229077, recall= 1.000000
# Minibatch Loss= 0.629149
# Tarin Iter 2200, auc= 0.885527, fmeasure_max= 0.838710, precision= 0.924686, recall= 0.767361
# Train Random guess:  , auc= 0.223001fmeasure_max= 0.367581, precision= 0.225176, recall= 1.000000
# Validation Iter 2200, auc= 0.908695, fmeasure_max= 0.836080, precision= 0.845614, recall= 0.826758
# Validation Random guess:  auc= 0.232203, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.617072
# Tarin Iter 2300, auc= 0.916290, fmeasure_max= 0.847724, precision= 0.882353, recall= 0.815710
# Train Random guess:  , auc= 0.257068fmeasure_max= 0.411396, precision= 0.259479, recall= 0.992447
# Validation Iter 2300, auc= 0.904732, fmeasure_max= 0.846088, precision= 0.848276, recall= 0.843911
# Validation Random guess:  auc= 0.234343, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.614265
# Tarin Iter 2400, auc= 0.882863, fmeasure_max= 0.822142, precision= 0.840445, recall= 0.804618
# Train Random guess:  , auc= 0.222038fmeasure_max= 0.360897, precision= 0.220180, recall= 1.000000
# Validation Iter 2400, auc= 0.909777, fmeasure_max= 0.841558, precision= 0.849650, recall= 0.833619
# Validation Random guess:  auc= 0.223728, fmeasure_max= 0.371274, precision= 0.231321, recall= 0.939966
# Minibatch Loss= 0.586891
# Tarin Iter 2500, auc= 0.903089, fmeasure_max= 0.841667, precision= 0.850526, recall= 0.832990
# Train Random guess:  , auc= 0.194215fmeasure_max= 0.318974, precision= 0.189750, recall= 1.000000
# Validation Iter 2500, auc= 0.917518, fmeasure_max= 0.848000, precision= 0.880074, recall= 0.818182
# Validation Random guess:  auc= 0.219905, fmeasure_max= 0.373436, precision= 0.229676, recall= 0.998285
# Minibatch Loss= 0.554830
# Tarin Iter 2600, auc= 0.904791, fmeasure_max= 0.842686, precision= 0.899804, recall= 0.792388
# Train Random guess:  , auc= 0.227722fmeasure_max= 0.368522, precision= 0.226060, recall= 0.996540
# Validation Iter 2600, auc= 0.901742, fmeasure_max= 0.845309, precision= 0.833333, recall= 0.857633
# Validation Random guess:  auc= 0.242913, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.540800
# Tarin Iter 2700, auc= 0.898074, fmeasure_max= 0.817332, precision= 0.820819, recall= 0.813875
# Train Random guess:  , auc= 0.231491fmeasure_max= 0.376074, precision= 0.231583, recall= 1.000000
# Validation Iter 2700, auc= 0.895388, fmeasure_max= 0.840034, precision= 0.837884, recall= 0.842196
# Validation Random guess:  auc= 0.225206, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.578919
# Tarin Iter 2800, auc= 0.922913, fmeasure_max= 0.864865, precision= 0.870293, recall= 0.859504
# Train Random guess:  , auc= 0.177850fmeasure_max= 0.319339, precision= 0.190083, recall= 0.997934
# Validation Iter 2800, auc= 0.900159, fmeasure_max= 0.806780, precision= 0.797320, recall= 0.816467
# Validation Random guess:  auc= 0.234085, fmeasure_max= 0.371750, precision= 0.228673, recall= 0.993139
# Minibatch Loss= 0.459444
# Tarin Iter 2900, auc= 0.919244, fmeasure_max= 0.861035, precision= 0.879406, recall= 0.843416
# Train Random guess:  , auc= 0.220776fmeasure_max= 0.361454, precision= 0.221032, recall= 0.991103
# Validation Iter 2900, auc= 0.894038, fmeasure_max= 0.849662, precision= 0.836938, recall= 0.862779
# Validation Random guess:  auc= 0.224077, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.525133
# Tarin Iter 3000, auc= 0.871628, fmeasure_max= 0.820195, precision= 0.841818, recall= 0.799655
# Train Random guess:  , auc= 0.228105fmeasure_max= 0.369142, precision= 0.226349, recall= 1.000000
# Validation Iter 3000, auc= 0.884612, fmeasure_max= 0.840775, precision= 0.826159, recall= 0.855918
# Validation Random guess:  auc= 0.224151, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.713758
# Tarin Iter 3100, auc= 0.924923, fmeasure_max= 0.850662, precision= 0.858779, recall= 0.842697
# Train Random guess:  , auc= 0.218938fmeasure_max= 0.350102, precision= 0.213870, recall= 0.964419
# Validation Iter 3100, auc= 0.909518, fmeasure_max= 0.832734, precision= 0.875236, recall= 0.794168
# Validation Random guess:  auc= 0.234507, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.506385
# Tarin Iter 3200, auc= 0.897799, fmeasure_max= 0.820119, precision= 0.851327, recall= 0.791118
# Train Random guess:  , auc= 0.218642fmeasure_max= 0.383960, precision= 0.237593, recall= 1.000000
# Validation Iter 3200, auc= 0.909974, fmeasure_max= 0.831346, precision= 0.825719, recall= 0.837050
# Validation Random guess:  auc= 0.236191, fmeasure_max= 0.373905, precision= 0.230584, recall= 0.987993
# Minibatch Loss= 0.556407
# Tarin Iter 3300, auc= 0.932892, fmeasure_max= 0.845118, precision= 0.831126, recall= 0.859589
# Train Random guess:  , auc= 0.226101fmeasure_max= 0.372004, precision= 0.228684, recall= 0.996575
# Validation Iter 3300, auc= 0.920335, fmeasure_max= 0.852402, precision= 0.868327, recall= 0.837050
# Validation Random guess:  auc= 0.224070, fmeasure_max= 0.373129, precision= 0.231436, recall= 0.962264
# Minibatch Loss= 0.550934
# Tarin Iter 3400, auc= 0.928255, fmeasure_max= 0.850256, precision= 0.849635, recall= 0.850877
# Train Random guess:  , auc= 0.275914fmeasure_max= 0.422658, precision= 0.268486, recall= 0.992690
# Validation Iter 3400, auc= 0.899569, fmeasure_max= 0.826268, precision= 0.801613, recall= 0.852487
# Validation Random guess:  auc= 0.235649, fmeasure_max= 0.373518, precision= 0.231146, recall= 0.972556
# Minibatch Loss= 0.580299
# Tarin Iter 3500, auc= 0.913921, fmeasure_max= 0.843278, precision= 0.857605, recall= 0.829421
# Train Random guess:  , auc= 0.281494fmeasure_max= 0.399625, precision= 0.249707, recall= 1.000000
# Validation Iter 3500, auc= 0.916369, fmeasure_max= 0.842725, precision= 0.826733, recall= 0.859348
# Validation Random guess:  auc= 0.234597, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.612152
# Tarin Iter 3600, auc= 0.881705, fmeasure_max= 0.827988, precision= 0.858871, recall= 0.799250
# Train Random guess:  , auc= 0.212113fmeasure_max= 0.347399, precision= 0.210380, recall= 0.996248
# Validation Iter 3600, auc= 0.895579, fmeasure_max= 0.824957, precision= 0.833625, recall= 0.816467
# Validation Random guess:  auc= 0.221123, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.571806
# Tarin Iter 3700, auc= 0.874616, fmeasure_max= 0.787213, precision= 0.784861, recall= 0.789579
# Train Random guess:  , auc= 0.195377fmeasure_max= 0.328000, precision= 0.196721, recall= 0.985972
# Validation Iter 3700, auc= 0.907379, fmeasure_max= 0.827402, precision= 0.859519, recall= 0.797599
# Validation Random guess:  auc= 0.233676, fmeasure_max= 0.372446, precision= 0.230518, recall= 0.969125
# Minibatch Loss= 0.546561
# Tarin Iter 3800, auc= 0.893192, fmeasure_max= 0.819317, precision= 0.857143, recall= 0.784689
# Train Random guess:  , auc= 0.251345fmeasure_max= 0.394295, precision= 0.246044, recall= 0.992026
# Validation Iter 3800, auc= 0.887652, fmeasure_max= 0.838095, precision= 0.846154, recall= 0.830189
# Validation Random guess:  auc= 0.229695, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.610445
# Tarin Iter 3900, auc= 0.912497, fmeasure_max= 0.820932, precision= 0.849408, recall= 0.794304
# Train Random guess:  , auc= 0.251808fmeasure_max= 0.396238, precision= 0.247068, recall= 1.000000
# Validation Iter 3900, auc= 0.912158, fmeasure_max= 0.860158, precision= 0.882671, recall= 0.838765
# Validation Random guess:  auc= 0.225736, fmeasure_max= 0.374589, precision= 0.231772, recall= 0.975986
# Minibatch Loss= 0.550822
# Tarin Iter 4000, auc= 0.917859, fmeasure_max= 0.852113, precision= 0.850615, recall= 0.853616
# Train Random guess:  , auc= 0.227276fmeasure_max= 0.363636, precision= 0.223387, recall= 0.977072
# Validation Iter 4000, auc= 0.923085, fmeasure_max= 0.868376, precision= 0.865417, recall= 0.871355
# Validation Random guess:  auc= 0.256616, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.523196
# Tarin Iter 4100, auc= 0.937636, fmeasure_max= 0.868839, precision= 0.848287, recall= 0.890411
# Train Random guess:  , auc= 0.237122fmeasure_max= 0.373115, precision= 0.230738, recall= 0.974315
# Validation Iter 4100, auc= 0.898273, fmeasure_max= 0.830850, precision= 0.849462, recall= 0.813036
# Validation Random guess:  auc= 0.243184, fmeasure_max= 0.371127, precision= 0.228022, recall= 0.996569
# Minibatch Loss= 0.491695
# Tarin Iter 4200, auc= 0.953371, fmeasure_max= 0.882303, precision= 0.906087, recall= 0.859736
# Train Random guess:  , auc= 0.260400fmeasure_max= 0.383302, precision= 0.237089, recall= 1.000000
# Validation Iter 4200, auc= 0.898738, fmeasure_max= 0.817937, precision= 0.857143, recall= 0.782161
# Validation Random guess:  auc= 0.230771, fmeasure_max= 0.371820, precision= 0.229561, recall= 0.977702
# Minibatch Loss= 0.453768
# Tarin Iter 4300, auc= 0.905866, fmeasure_max= 0.836625, precision= 0.844203, recall= 0.829181
# Train Random guess:  , auc= 0.218807fmeasure_max= 0.361979, precision= 0.221514, recall= 0.989324
# Validation Iter 4300, auc= 0.916895, fmeasure_max= 0.833333, precision= 0.843585, recall= 0.823328
# Validation Random guess:  auc= 0.218608, fmeasure_max= 0.372695, precision= 0.229665, recall= 0.987993
# Minibatch Loss= 0.516204
# Tarin Iter 4400, auc= 0.925003, fmeasure_max= 0.851390, precision= 0.875740, recall= 0.828358
# Train Random guess:  , auc= 0.221473fmeasure_max= 0.346840, precision= 0.209886, recall= 0.998134
# Validation Iter 4400, auc= 0.903261, fmeasure_max= 0.844974, precision= 0.839255, recall= 0.850772
# Validation Random guess:  auc= 0.237933, fmeasure_max= 0.373405, precision= 0.232150, recall= 0.953688
# Minibatch Loss= 0.504644
# Tarin Iter 4500, auc= 0.957088, fmeasure_max= 0.891980, precision= 0.887622, recall= 0.896382
# Train Random guess:  , auc= 0.239575fmeasure_max= 0.388317, precision= 0.243243, recall= 0.962171
# Validation Iter 4500, auc= 0.923194, fmeasure_max= 0.867893, precision= 0.846656, recall= 0.890223
# Validation Random guess:  auc= 0.223959, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.466203
# Tarin Iter 4600, auc= 0.930365, fmeasure_max= 0.876886, precision= 0.878981, recall= 0.874802
# Train Random guess:  , auc= 0.230768fmeasure_max= 0.398708, precision= 0.250406, recall= 0.977813
# Validation Iter 4600, auc= 0.897572, fmeasure_max= 0.825061, precision= 0.784830, recall= 0.869640
# Validation Random guess:  auc= 0.211572, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.515137
# Tarin Iter 4700, auc= 0.910042, fmeasure_max= 0.834089, precision= 0.812721, recall= 0.856611
# Train Random guess:  , auc= 0.217587fmeasure_max= 0.347067, precision= 0.213580, recall= 0.925512
# Validation Iter 4700, auc= 0.910132, fmeasure_max= 0.826923, precision= 0.843137, recall= 0.811321
# Validation Random guess:  auc= 0.222148, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.493987
# Tarin Iter 4800, auc= 0.943077, fmeasure_max= 0.884726, precision= 0.896350, recall= 0.873400
# Train Random guess:  , auc= 0.282114fmeasure_max= 0.431421, precision= 0.275039, recall= 1.000000
# Validation Iter 4800, auc= 0.918064, fmeasure_max= 0.855872, precision= 0.889094, recall= 0.825043
# Validation Random guess:  auc= 0.219763, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.583865
# Tarin Iter 4900, auc= 0.947331, fmeasure_max= 0.879752, precision= 0.868300, recall= 0.891509
# Train Random guess:  , auc= 0.267243fmeasure_max= 0.398122, precision= 0.248535, recall= 1.000000
# Validation Iter 4900, auc= 0.926357, fmeasure_max= 0.855136, precision= 0.875899, recall= 0.835334
# Validation Random guess:  auc= 0.236449, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.502456
# Tarin Iter 5000, auc= 0.937473, fmeasure_max= 0.884685, precision= 0.884685, recall= 0.884685
# Train Random guess:  , auc= 0.219275fmeasure_max= 0.357306, precision= 0.218030, recall= 0.989189
# Validation Iter 5000, auc= 0.921480, fmeasure_max= 0.864111, precision= 0.877876, recall= 0.850772
# Validation Random guess:  auc= 0.224164, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.507264
# Tarin Iter 5100, auc= 0.938164, fmeasure_max= 0.872420, precision= 0.882353, recall= 0.862709
# Train Random guess:  , auc= 0.210180fmeasure_max= 0.347854, precision= 0.210547, recall= 1.000000
# Validation Iter 5100, auc= 0.921147, fmeasure_max= 0.853952, precision= 0.855422, recall= 0.852487
# Validation Random guess:  auc= 0.230699, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.456731
# Tarin Iter 5200, auc= 0.946388, fmeasure_max= 0.894825, precision= 0.893333, recall= 0.896321
# Train Random guess:  , auc= 0.246116fmeasure_max= 0.378841, precision= 0.233685, recall= 1.000000
# Validation Iter 5200, auc= 0.923371, fmeasure_max= 0.862712, precision= 0.852596, recall= 0.873070
# Validation Random guess:  auc= 0.245120, fmeasure_max= 0.372587, precision= 0.229307, recall= 0.993139
# Minibatch Loss= 0.489866
# Tarin Iter 5300, auc= 0.953960, fmeasure_max= 0.868966, precision= 0.900000, recall= 0.840000
# Train Random guess:  , auc= 0.231973fmeasure_max= 0.379987, precision= 0.234558, recall= 1.000000
# Validation Iter 5300, auc= 0.922319, fmeasure_max= 0.854403, precision= 0.868794, recall= 0.840480
# Validation Random guess:  auc= 0.222770, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.450652
# Tarin Iter 5400, auc= 0.952469, fmeasure_max= 0.887538, precision= 0.901235, recall= 0.874251
# Train Random guess:  , auc= 0.270578fmeasure_max= 0.414264, precision= 0.261244, recall= 1.000000
# Validation Iter 5400, auc= 0.906039, fmeasure_max= 0.839442, precision= 0.854352, recall= 0.825043
# Validation Random guess:  auc= 0.222959, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.465777
# Tarin Iter 5500, auc= 0.899781, fmeasure_max= 0.837489, precision= 0.808970, recall= 0.868093
# Train Random guess:  , auc= 0.203326fmeasure_max= 0.359962, precision= 0.219484, recall= 1.000000
# Validation Iter 5500, auc= 0.924201, fmeasure_max= 0.845872, precision= 0.909270, recall= 0.790738
# Validation Random guess:  auc= 0.230383, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.537878
# Tarin Iter 5600, auc= 0.936926, fmeasure_max= 0.877089, precision= 0.931106, recall= 0.828996
# Train Random guess:  , auc= 0.206268fmeasure_max= 0.347433, precision= 0.210238, recall= 1.000000
# Validation Iter 5600, auc= 0.900556, fmeasure_max= 0.830824, precision= 0.858974, recall= 0.804460
# Validation Random guess:  auc= 0.221339, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.484832
# Tarin Iter 5700, auc= 0.936087, fmeasure_max= 0.870588, precision= 0.815427, recall= 0.933754
# Train Random guess:  , auc= 0.256868fmeasure_max= 0.401267, precision= 0.258269, recall= 0.899054
# Validation Iter 5700, auc= 0.890668, fmeasure_max= 0.826504, precision= 0.840426, recall= 0.813036
# Validation Random guess:  auc= 0.257683, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.490130
# Tarin Iter 5800, auc= 0.940401, fmeasure_max= 0.884858, precision= 0.886256, recall= 0.883465
# Train Random guess:  , auc= 0.253062fmeasure_max= 0.399615, precision= 0.251009, recall= 0.979528
# Validation Iter 5800, auc= 0.913532, fmeasure_max= 0.848057, precision= 0.874317, recall= 0.823328
# Validation Random guess:  auc= 0.240130, fmeasure_max= 0.373506, precision= 0.230096, recall= 0.991424
# Minibatch Loss= 0.516034
# Tarin Iter 5900, auc= 0.931917, fmeasure_max= 0.857827, precision= 0.844340, recall= 0.871753
# Train Random guess:  , auc= 0.255481fmeasure_max= 0.388276, precision= 0.240907, recall= 1.000000
# Validation Iter 5900, auc= 0.927967, fmeasure_max= 0.862245, precision= 0.854975, recall= 0.869640
# Validation Random guess:  auc= 0.235500, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.519714
# Tarin Iter 6000, auc= 0.923087, fmeasure_max= 0.869351, precision= 0.842357, recall= 0.898132
# Train Random guess:  , auc= 0.230863fmeasure_max= 0.374800, precision= 0.230890, recall= 0.994907
# Validation Iter 6000, auc= 0.920415, fmeasure_max= 0.852863, precision= 0.876812, recall= 0.830189
# Validation Random guess:  auc= 0.236753, fmeasure_max= 0.374194, precision= 0.230433, recall= 0.994854
# Minibatch Loss= 0.488049
# Tarin Iter 6100, auc= 0.949695, fmeasure_max= 0.897925, precision= 0.869775, recall= 0.927959
# Train Random guess:  , auc= 0.230955fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Validation Iter 6100, auc= 0.885964, fmeasure_max= 0.807993, precision= 0.818662, recall= 0.797599
# Validation Random guess:  auc= 0.232642, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.460784
# Tarin Iter 6200, auc= 0.941745, fmeasure_max= 0.875568, precision= 0.881170, recall= 0.870036
# Train Random guess:  , auc= 0.214729fmeasure_max= 0.357427, precision= 0.218928, recall= 0.972924
# Validation Iter 6200, auc= 0.918235, fmeasure_max= 0.841026, precision= 0.838160, recall= 0.843911
# Validation Random guess:  auc= 0.225709, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.452381
# Tarin Iter 6300, auc= 0.948859, fmeasure_max= 0.896092, precision= 0.875233, recall= 0.917969
# Train Random guess:  , auc= 0.196737fmeasure_max= 0.333333, precision= 0.200000, recall= 1.000000
# Validation Iter 6300, auc= 0.915809, fmeasure_max= 0.845144, precision= 0.862500, recall= 0.828473
# Validation Random guess:  auc= 0.241495, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.413168
# Tarin Iter 6400, auc= 0.957736, fmeasure_max= 0.891509, precision= 0.885938, recall= 0.897152
# Train Random guess:  , auc= 0.236389fmeasure_max= 0.395990, precision= 0.246875, recall= 1.000000
# Validation Iter 6400, auc= 0.910581, fmeasure_max= 0.843697, precision= 0.827018, recall= 0.861063
# Validation Random guess:  auc= 0.230666, fmeasure_max= 0.371955, precision= 0.230143, recall= 0.969125
# Minibatch Loss= 0.484903
# Tarin Iter 6500, auc= 0.927596, fmeasure_max= 0.838816, precision= 0.851419, recall= 0.826580
# Train Random guess:  , auc= 0.233606fmeasure_max= 0.388889, precision= 0.241474, recall= 0.998379
# Validation Iter 6500, auc= 0.904519, fmeasure_max= 0.830255, precision= 0.851986, recall= 0.809605
# Validation Random guess:  auc= 0.240296, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.554355
# Tarin Iter 6600, auc= 0.971933, fmeasure_max= 0.901679, precision= 0.890995, recall= 0.912621
# Train Random guess:  , auc= 0.237601fmeasure_max= 0.391051, precision= 0.244526, recall= 0.975728
# Validation Iter 6600, auc= 0.903689, fmeasure_max= 0.835689, precision= 0.861566, recall= 0.811321
# Validation Random guess:  auc= 0.227109, fmeasure_max= 0.372334, precision= 0.229391, recall= 0.987993
# Minibatch Loss= 0.435077
# Tarin Iter 6700, auc= 0.941059, fmeasure_max= 0.861742, precision= 0.888672, recall= 0.836397
# Train Random guess:  , auc= 0.219614fmeasure_max= 0.350741, precision= 0.212666, recall= 1.000000
# Validation Iter 6700, auc= 0.898625, fmeasure_max= 0.832618, precision= 0.833333, recall= 0.831904
# Validation Random guess:  auc= 0.223349, fmeasure_max= 0.373129, precision= 0.231436, recall= 0.962264
# Minibatch Loss= 0.436786
# Tarin Iter 6800, auc= 0.914760, fmeasure_max= 0.846366, precision= 0.858209, recall= 0.834846
# Train Random guess:  , auc= 0.217499fmeasure_max= 0.356655, precision= 0.217288, recall= 0.994555
# Validation Iter 6800, auc= 0.894239, fmeasure_max= 0.817376, precision= 0.845872, recall= 0.790738
# Validation Random guess:  auc= 0.223639, fmeasure_max= 0.372562, precision= 0.229844, recall= 0.982847
# Minibatch Loss= 0.532756
# Tarin Iter 6900, auc= 0.956246, fmeasure_max= 0.886154, precision= 0.887064, recall= 0.885246
# Train Random guess:  , auc= 0.185756fmeasure_max= 0.320525, precision= 0.190849, recall= 1.000000
# Validation Iter 6900, auc= 0.900667, fmeasure_max= 0.819130, precision= 0.830688, recall= 0.807890
# Validation Random guess:  auc= 0.236672, fmeasure_max= 0.371721, precision= 0.228470, recall= 0.996569
# Minibatch Loss= 0.402070
# Tarin Iter 7000, auc= 0.954940, fmeasure_max= 0.880972, precision= 0.885993, recall= 0.876006
# Train Random guess:  , auc= 0.233483fmeasure_max= 0.393398, precision= 0.248722, recall= 0.940419
# Validation Iter 7000, auc= 0.907098, fmeasure_max= 0.838488, precision= 0.839931, recall= 0.837050
# Validation Random guess:  auc= 0.249129, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.460425
# Tarin Iter 7100, auc= 0.940383, fmeasure_max= 0.874582, precision= 0.897084, recall= 0.853181
# Train Random guess:  , auc= 0.237646fmeasure_max= 0.386635, precision= 0.244397, recall= 0.924959
# Validation Iter 7100, auc= 0.912087, fmeasure_max= 0.831889, precision= 0.840630, recall= 0.823328
# Validation Random guess:  auc= 0.221949, fmeasure_max= 0.375694, precision= 0.232042, recall= 0.986278
# Minibatch Loss= 0.531997
# Tarin Iter 7200, auc= 0.947259, fmeasure_max= 0.879242, precision= 0.896940, recall= 0.862229
# Train Random guess:  , auc= 0.260932fmeasure_max= 0.405645, precision= 0.257393, recall= 0.956656
# Validation Iter 7200, auc= 0.911439, fmeasure_max= 0.840630, precision= 0.858676, recall= 0.823328
# Validation Random guess:  auc= 0.233495, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.547677
# Tarin Iter 7300, auc= 0.953951, fmeasure_max= 0.876688, precision= 0.880651, recall= 0.872760
# Train Random guess:  , auc= 0.232285fmeasure_max= 0.357922, precision= 0.217969, recall= 1.000000
# Validation Iter 7300, auc= 0.882917, fmeasure_max= 0.806890, precision= 0.855769, recall= 0.763293
# Validation Random guess:  auc= 0.219881, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.430162
# Tarin Iter 7400, auc= 0.939032, fmeasure_max= 0.872889, precision= 0.878354, recall= 0.867491
# Train Random guess:  , auc= 0.223045fmeasure_max= 0.362472, precision= 0.221353, recall= 1.000000
# Validation Iter 7400, auc= 0.914957, fmeasure_max= 0.847845, precision= 0.870036, recall= 0.826758
# Validation Random guess:  auc= 0.228437, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.449042
# Tarin Iter 7500, auc= 0.933369, fmeasure_max= 0.873323, precision= 0.825352, recall= 0.927215
# Train Random guess:  , auc= 0.243616fmeasure_max= 0.396345, precision= 0.247443, recall= 0.995253
# Validation Iter 7500, auc= 0.908223, fmeasure_max= 0.831683, precision= 0.875000, recall= 0.792453
# Validation Random guess:  auc= 0.227211, fmeasure_max= 0.372894, precision= 0.238506, recall= 0.854202
# Minibatch Loss= 0.499265
# Tarin Iter 7600, auc= 0.954788, fmeasure_max= 0.883258, precision= 0.862191, recall= 0.905380
# Train Random guess:  , auc= 0.206498fmeasure_max= 0.349196, precision= 0.213088, recall= 0.966605
# Validation Iter 7600, auc= 0.912493, fmeasure_max= 0.833638, precision= 0.892368, recall= 0.782161
# Validation Random guess:  auc= 0.229755, fmeasure_max= 0.371127, precision= 0.228022, recall= 0.996569
# Minibatch Loss= 0.432043
# Tarin Iter 7700, auc= 0.961912, fmeasure_max= 0.900886, precision= 0.947458, recall= 0.858679
# Train Random guess:  , auc= 0.261631fmeasure_max= 0.406279, precision= 0.255328, recall= 0.993856
# Validation Iter 7700, auc= 0.895202, fmeasure_max= 0.831752, precision= 0.836806, recall= 0.826758
# Validation Random guess:  auc= 0.241804, fmeasure_max= 0.373281, precision= 0.230676, recall= 0.977702
# Minibatch Loss= 0.488553
# Tarin Iter 7800, auc= 0.952602, fmeasure_max= 0.882206, precision= 0.932862, recall= 0.836767
# Train Random guess:  , auc= 0.230082fmeasure_max= 0.396725, precision= 0.247544, recall= 0.998415
# Validation Iter 7800, auc= 0.917326, fmeasure_max= 0.847247, precision= 0.878453, recall= 0.818182
# Validation Random guess:  auc= 0.232716, fmeasure_max= 0.372334, precision= 0.229391, recall= 0.987993
# Minibatch Loss= 0.429682
# Tarin Iter 7900, auc= 0.930677, fmeasure_max= 0.873900, precision= 0.888668, recall= 0.859615
# Train Random guess:  , auc= 0.198891fmeasure_max= 0.338983, precision= 0.204082, recall= 1.000000
# Validation Iter 7900, auc= 0.890090, fmeasure_max= 0.822222, precision= 0.893360, recall= 0.761578
# Validation Random guess:  auc= 0.223246, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.415438
# Tarin Iter 8000, auc= 0.935637, fmeasure_max= 0.868132, precision= 0.913295, recall= 0.827225
# Train Random guess:  , auc= 0.220679fmeasure_max= 0.368612, precision= 0.227236, recall= 0.975567
# Validation Iter 8000, auc= 0.902779, fmeasure_max= 0.819298, precision= 0.838420, recall= 0.801029
# Validation Random guess:  auc= 0.222152, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.503627
# Tarin Iter 8100, auc= 0.965904, fmeasure_max= 0.893728, precision= 0.879931, recall= 0.907965
# Train Random guess:  , auc= 0.222082fmeasure_max= 0.365535, precision= 0.224090, recall= 0.991150
# Validation Iter 8100, auc= 0.892799, fmeasure_max= 0.823430, precision= 0.815126, recall= 0.831904
# Validation Random guess:  auc= 0.224898, fmeasure_max= 0.372258, precision= 0.229241, recall= 0.989708
# Minibatch Loss= 0.472253
# Tarin Iter 8200, auc= 0.957287, fmeasure_max= 0.883139, precision= 0.889076, recall= 0.877280
# Train Random guess:  , auc= 0.247737fmeasure_max= 0.381708, precision= 0.236057, recall= 0.996683
# Validation Iter 8200, auc= 0.908879, fmeasure_max= 0.838651, precision= 0.894942, recall= 0.789022
# Validation Random guess:  auc= 0.239395, fmeasure_max= 0.374486, precision= 0.234033, recall= 0.936535
# Minibatch Loss= 0.452934
# Tarin Iter 8300, auc= 0.962682, fmeasure_max= 0.889069, precision= 0.918060, recall= 0.861852
# Train Random guess:  , auc= 0.254913fmeasure_max= 0.401655, precision= 0.251896, recall= 0.990581
# Validation Iter 8300, auc= 0.915217, fmeasure_max= 0.837668, precision= 0.877820, recall= 0.801029
# Validation Random guess:  auc= 0.236057, fmeasure_max= 0.379174, precision= 0.239782, recall= 0.905660
# Minibatch Loss= 0.458293
# Tarin Iter 8400, auc= 0.959351, fmeasure_max= 0.893061, precision= 0.901153, recall= 0.885113
# Train Random guess:  , auc= 0.242928fmeasure_max= 0.389660, precision= 0.241973, recall= 1.000000
# Validation Iter 8400, auc= 0.905566, fmeasure_max= 0.832461, precision= 0.847247, recall= 0.818182
# Validation Random guess:  auc= 0.218304, fmeasure_max= 0.371914, precision= 0.228707, recall= 0.994854
# Minibatch Loss= 0.469878
# Tarin Iter 8500, auc= 0.962326, fmeasure_max= 0.898955, precision= 0.868102, recall= 0.932081
# Train Random guess:  , auc= 0.254924fmeasure_max= 0.428212, precision= 0.273752, recall= 0.982659
# Validation Iter 8500, auc= 0.886587, fmeasure_max= 0.814750, precision= 0.834532, recall= 0.795883
# Validation Random guess:  auc= 0.227831, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.474006
# Tarin Iter 8600, auc= 0.956574, fmeasure_max= 0.882353, precision= 0.879630, recall= 0.885093
# Train Random guess:  , auc= 0.261176fmeasure_max= 0.402123, precision= 0.251661, recall= 1.000000
# Validation Iter 8600, auc= 0.888446, fmeasure_max= 0.818487, precision= 0.802306, recall= 0.835334
# Validation Random guess:  auc= 0.236107, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.489625
# Tarin Iter 8700, auc= 0.960127, fmeasure_max= 0.895091, precision= 0.875706, recall= 0.915354
# Train Random guess:  , auc= 0.214520fmeasure_max= 0.331160, precision= 0.198437, recall= 1.000000
# Validation Iter 8700, auc= 0.912411, fmeasure_max= 0.834471, precision= 0.830221, recall= 0.838765
# Validation Random guess:  auc= 0.221806, fmeasure_max= 0.372671, precision= 0.230210, recall= 0.977702
# Minibatch Loss= 0.374929
# Tarin Iter 8800, auc= 0.947490, fmeasure_max= 0.882353, precision= 0.918919, recall= 0.848586
# Train Random guess:  , auc= 0.252638fmeasure_max= 0.381630, precision= 0.236853, recall= 0.981697
# Validation Iter 8800, auc= 0.900906, fmeasure_max= 0.828003, precision= 0.834495, recall= 0.821612
# Validation Random guess:  auc= 0.241285, fmeasure_max= 0.372017, precision= 0.229806, recall= 0.975986
# Minibatch Loss= 0.495675
# Tarin Iter 8900, auc= 0.957861, fmeasure_max= 0.892073, precision= 0.930279, recall= 0.856881
# Train Random guess:  , auc= 0.222501fmeasure_max= 0.352825, precision= 0.214886, recall= 0.985321
# Validation Iter 8900, auc= 0.906757, fmeasure_max= 0.838375, precision= 0.844948, recall= 0.831904
# Validation Random guess:  auc= 0.228424, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.390979
# Tarin Iter 9000, auc= 0.935204, fmeasure_max= 0.853270, precision= 0.897651, recall= 0.813070
# Train Random guess:  , auc= 0.256043fmeasure_max= 0.409204, precision= 0.257232, recall= 1.000000
# Validation Iter 9000, auc= 0.902222, fmeasure_max= 0.826389, precision= 0.836555, recall= 0.816467
# Validation Random guess:  auc= 0.241584, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.559021
# Tarin Iter 9100, auc= 0.955075, fmeasure_max= 0.888889, precision= 0.903955, recall= 0.874317
# Train Random guess:  , auc= 0.211707fmeasure_max= 0.354776, precision= 0.215896, recall= 0.994536
# Validation Iter 9100, auc= 0.902190, fmeasure_max= 0.828227, precision= 0.902834, recall= 0.765009
# Validation Random guess:  auc= 0.230174, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.423631
# Tarin Iter 9200, auc= 0.958188, fmeasure_max= 0.894874, precision= 0.874363, recall= 0.916370
# Train Random guess:  , auc= 0.231005fmeasure_max= 0.360603, precision= 0.219961, recall= 1.000000
# Validation Iter 9200, auc= 0.916124, fmeasure_max= 0.844828, precision= 0.849220, recall= 0.840480
# Validation Random guess:  auc= 0.220462, fmeasure_max= 0.371585, precision= 0.228639, recall= 0.991424
# Minibatch Loss= 0.426292
# Tarin Iter 9300, auc= 0.942623, fmeasure_max= 0.872837, precision= 0.872180, recall= 0.873494
# Train Random guess:  , auc= 0.269950fmeasure_max= 0.412550, precision= 0.259883, recall= 1.000000
# Validation Iter 9300, auc= 0.895284, fmeasure_max= 0.822934, precision= 0.809287, recall= 0.837050
# Validation Random guess:  auc= 0.212022, fmeasure_max= 0.372848, precision= 0.229968, recall= 0.984563
# Minibatch Loss= 0.578048
# Tarin Iter 9400, auc= 0.936866, fmeasure_max= 0.871589, precision= 0.847114, recall= 0.897521
# Train Random guess:  , auc= 0.251632fmeasure_max= 0.383169, precision= 0.237362, recall= 0.993388
# Validation Iter 9400, auc= 0.890377, fmeasure_max= 0.802817, precision= 0.824593, recall= 0.782161
# Validation Random guess:  auc= 0.227940, fmeasure_max= 0.371055, precision= 0.227878, recall= 0.998285
# Minibatch Loss= 0.473924
# Tarin Iter 9500, auc= 0.965428, fmeasure_max= 0.899275, precision= 0.900000, recall= 0.898551
# Train Random guess:  , auc= 0.248099fmeasure_max= 0.390566, precision= 0.242673, recall= 1.000000
# Validation Iter 9500, auc= 0.897387, fmeasure_max= 0.808439, precision= 0.795681, recall= 0.821612
# Validation Random guess:  auc= 0.244883, fmeasure_max= 0.372549, precision= 0.232000, recall= 0.945111
# Minibatch Loss= 0.421741
# Tarin Iter 9600, auc= 0.926027, fmeasure_max= 0.851613, precision= 0.831496, recall= 0.872727
# Train Random guess:  , auc= 0.244100fmeasure_max= 0.388460, precision= 0.243687, recall= 0.957025
# Validation Iter 9600, auc= 0.913657, fmeasure_max= 0.835184, precision= 0.831633, recall= 0.838765
# Validation Random guess:  auc= 0.230687, fmeasure_max= 0.372751, precision= 0.229340, recall= 0.994854
# Minibatch Loss= 0.558632
# Tarin Iter 9700, auc= 0.942446, fmeasure_max= 0.873059, precision= 0.898496, recall= 0.849023
# Train Random guess:  , auc= 0.223143fmeasure_max= 0.360551, precision= 0.219922, recall= 1.000000
# Validation Iter 9700, auc= 0.901729, fmeasure_max= 0.819856, precision= 0.768769, recall= 0.878216
# Validation Random guess:  auc= 0.232538, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.451980
# Tarin Iter 9800, auc= 0.973700, fmeasure_max= 0.918668, precision= 0.920807, recall= 0.916538
# Train Random guess:  , auc= 0.255363fmeasure_max= 0.404881, precision= 0.253825, recall= 1.000000
# Validation Iter 9800, auc= 0.913321, fmeasure_max= 0.836457, precision= 0.830795, recall= 0.842196
# Validation Random guess:  auc= 0.236422, fmeasure_max= 0.377111, precision= 0.235979, recall= 0.938250
# Minibatch Loss= 0.422125
# Tarin Iter 9900, auc= 0.972545, fmeasure_max= 0.910095, precision= 0.917329, recall= 0.902973
# Train Random guess:  , auc= 0.242576fmeasure_max= 0.400125, precision= 0.250098, recall= 1.000000
# Validation Iter 9900, auc= 0.896958, fmeasure_max= 0.820384, precision= 0.799674, recall= 0.842196
# Validation Random guess:  auc= 0.219799, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.447215
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.878221 F1_max = 0.806585 prec = 0.842250 rec = 0.773818
# Test Random guess: auc= 0.226149 fmeasure_max= 0.375865 , precision= 0.231670 , recall= 0.995439

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
