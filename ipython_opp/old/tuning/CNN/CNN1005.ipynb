# %%
# useing this variable for saving models and summaries
exp_name = "CNN1004"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2, 1]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 128],
                 [5, 128, 128]]
bias_shape = [32, 64, 64, 64, 128, 128]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.252584, fmeasure_max= 0.429310, precision= 0.291640, recall= 0.813167
# Train Random guess:  , auc= 0.220652fmeasure_max= 0.361702, precision= 0.220866, recall= 0.998221
# Validation Iter 0, auc= 0.224027, fmeasure_max= 0.376793, precision= 0.232596, recall= 0.991424
# Validation Random guess:  auc= 0.222134, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 1.032080
# Tarin Iter 100, auc= 0.687584, fmeasure_max= 0.645944, precision= 0.631111, recall= 0.661491
# Train Random guess:  , auc= 0.256385fmeasure_max= 0.402756, precision= 0.252256, recall= 0.998447
# Validation Iter 100, auc= 0.696267, fmeasure_max= 0.654836, precision= 0.678309, recall= 0.632933
# Validation Random guess:  auc= 0.215824, fmeasure_max= 0.372837, precision= 0.230242, recall= 0.979417
# Minibatch Loss= 1.058234
# Tarin Iter 200, auc= 0.719037, fmeasure_max= 0.692615, precision= 0.818396, recall= 0.600346
# Train Random guess:  , auc= 0.231185fmeasure_max= 0.369270, precision= 0.226984, recall= 0.989619
# Validation Iter 200, auc= 0.774566, fmeasure_max= 0.728251, precision= 0.763158, recall= 0.696398
# Validation Random guess:  auc= 0.227299, fmeasure_max= 0.372608, precision= 0.231636, recall= 0.951973
# Minibatch Loss= 0.839731
# Tarin Iter 300, auc= 0.802164, fmeasure_max= 0.795205, precision= 0.857759, recall= 0.741155
# Train Random guess:  , auc= 0.209648fmeasure_max= 0.346899, precision= 0.209848, recall= 1.000000
# Validation Iter 300, auc= 0.784764, fmeasure_max= 0.735931, precision= 0.743007, recall= 0.728988
# Validation Random guess:  auc= 0.223206, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.834327
# Tarin Iter 400, auc= 0.815454, fmeasure_max= 0.757406, precision= 0.753185, recall= 0.761675
# Train Random guess:  , auc= 0.255076fmeasure_max= 0.397213, precision= 0.253446, recall= 0.917874
# Validation Iter 400, auc= 0.809347, fmeasure_max= 0.765388, precision= 0.797398, recall= 0.735849
# Validation Random guess:  auc= 0.234390, fmeasure_max= 0.371346, precision= 0.228458, recall= 0.991424
# Minibatch Loss= 0.797806
# Tarin Iter 500, auc= 0.729644, fmeasure_max= 0.700180, precision= 0.810811, recall= 0.616114
# Train Random guess:  , auc= 0.237671fmeasure_max= 0.396492, precision= 0.247266, recall= 1.000000
# Validation Iter 500, auc= 0.803540, fmeasure_max= 0.763948, precision= 0.764605, recall= 0.763293
# Validation Random guess:  auc= 0.228933, fmeasure_max= 0.373351, precision= 0.231115, recall= 0.970840
# Minibatch Loss= 0.828688
# Tarin Iter 600, auc= 0.771745, fmeasure_max= 0.744939, precision= 0.834467, recall= 0.672761
# Train Random guess:  , auc= 0.206736fmeasure_max= 0.354278, precision= 0.216769, recall= 0.968921
# Validation Iter 600, auc= 0.828370, fmeasure_max= 0.759965, precision= 0.785714, recall= 0.735849
# Validation Random guess:  auc= 0.224584, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.770257
# Tarin Iter 700, auc= 0.808521, fmeasure_max= 0.764548, precision= 0.827519, recall= 0.710483
# Train Random guess:  , auc= 0.231255fmeasure_max= 0.380380, precision= 0.234857, recall= 1.000000
# Validation Iter 700, auc= 0.881143, fmeasure_max= 0.823024, precision= 0.824441, recall= 0.821612
# Validation Random guess:  auc= 0.230858, fmeasure_max= 0.371346, precision= 0.228458, recall= 0.991424
# Minibatch Loss= 0.681417
# Tarin Iter 800, auc= 0.893341, fmeasure_max= 0.846894, precision= 0.865832, recall= 0.828767
# Train Random guess:  , auc= 0.220526fmeasure_max= 0.371738, precision= 0.228303, recall= 1.000000
# Validation Iter 800, auc= 0.859740, fmeasure_max= 0.797113, precision= 0.748494, recall= 0.852487
# Validation Random guess:  auc= 0.212109, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.632504
# Tarin Iter 900, auc= 0.854486, fmeasure_max= 0.812609, precision= 0.852941, recall= 0.775920
# Train Random guess:  , auc= 0.227555fmeasure_max= 0.378841, precision= 0.233685, recall= 1.000000
# Validation Iter 900, auc= 0.878812, fmeasure_max= 0.819376, precision= 0.785827, recall= 0.855918
# Validation Random guess:  auc= 0.236929, fmeasure_max= 0.373557, precision= 0.234622, recall= 0.915952
# Minibatch Loss= 0.749146
# Tarin Iter 1000, auc= 0.832636, fmeasure_max= 0.757895, precision= 0.748800, recall= 0.767213
# Train Random guess:  , auc= 0.246633fmeasure_max= 0.385406, precision= 0.241580, recall= 0.952459
# Validation Iter 1000, auc= 0.852766, fmeasure_max= 0.784722, precision= 0.794376, recall= 0.775300
# Validation Random guess:  auc= 0.217214, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.760252
# Tarin Iter 1100, auc= 0.846938, fmeasure_max= 0.786636, precision= 0.775449, recall= 0.798151
# Train Random guess:  , auc= 0.245336fmeasure_max= 0.404487, precision= 0.253516, recall= 1.000000
# Validation Iter 1100, auc= 0.858889, fmeasure_max= 0.778073, precision= 0.802920, recall= 0.754717
# Validation Random guess:  auc= 0.237014, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.728872
# Tarin Iter 1200, auc= 0.883227, fmeasure_max= 0.816773, precision= 0.817518, recall= 0.816029
# Train Random guess:  , auc= 0.219269fmeasure_max= 0.353320, precision= 0.214649, recall= 0.998179
# Validation Iter 1200, auc= 0.882504, fmeasure_max= 0.810811, precision= 0.798669, recall= 0.823328
# Validation Random guess:  auc= 0.234185, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.614977
# Tarin Iter 1300, auc= 0.849576, fmeasure_max= 0.798058, precision= 0.863445, recall= 0.741877
# Train Random guess:  , auc= 0.210241fmeasure_max= 0.357096, precision= 0.218051, recall= 0.985560
# Validation Iter 1300, auc= 0.842540, fmeasure_max= 0.772766, precision= 0.766892, recall= 0.778731
# Validation Random guess:  auc= 0.249041, fmeasure_max= 0.372555, precision= 0.229101, recall= 0.996569
# Minibatch Loss= 0.637398
# Tarin Iter 1400, auc= 0.850733, fmeasure_max= 0.800393, precision= 0.864119, recall= 0.745421
# Train Random guess:  , auc= 0.212521fmeasure_max= 0.351762, precision= 0.213585, recall= 0.996337
# Validation Iter 1400, auc= 0.890141, fmeasure_max= 0.815451, precision= 0.816151, recall= 0.814751
# Validation Random guess:  auc= 0.221889, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.659459
# Tarin Iter 1500, auc= 0.918793, fmeasure_max= 0.843725, precision= 0.895189, recall= 0.797856
# Train Random guess:  , auc= 0.258129fmeasure_max= 0.406600, precision= 0.255178, recall= 1.000000
# Validation Iter 1500, auc= 0.886524, fmeasure_max= 0.800676, precision= 0.788686, recall= 0.813036
# Validation Random guess:  auc= 0.219126, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.638753
# Tarin Iter 1600, auc= 0.870690, fmeasure_max= 0.816014, precision= 0.837413, recall= 0.795681
# Train Random guess:  , auc= 0.238047fmeasure_max= 0.380892, precision= 0.235248, recall= 1.000000
# Validation Iter 1600, auc= 0.874722, fmeasure_max= 0.801016, precision= 0.790970, recall= 0.811321
# Validation Random guess:  auc= 0.222087, fmeasure_max= 0.377726, precision= 0.234779, recall= 0.965695
# Minibatch Loss= 0.625766
# Tarin Iter 1700, auc= 0.926831, fmeasure_max= 0.862745, precision= 0.851852, recall= 0.873921
# Train Random guess:  , auc= 0.227564fmeasure_max= 0.369802, precision= 0.226934, recall= 0.998273
# Validation Iter 1700, auc= 0.880659, fmeasure_max= 0.800679, precision= 0.791946, recall= 0.809605
# Validation Random guess:  auc= 0.241562, fmeasure_max= 0.374677, precision= 0.230800, recall= 0.994854
# Minibatch Loss= 0.530241
# Tarin Iter 1800, auc= 0.921401, fmeasure_max= 0.857864, precision= 0.838816, recall= 0.877797
# Train Random guess:  , auc= 0.223549fmeasure_max= 0.369946, precision= 0.226953, recall= 1.000000
# Validation Iter 1800, auc= 0.886360, fmeasure_max= 0.812330, precision= 0.861538, recall= 0.768439
# Validation Random guess:  auc= 0.220416, fmeasure_max= 0.371659, precision= 0.228787, recall= 0.989708
# Minibatch Loss= 0.561207
# Tarin Iter 1900, auc= 0.891127, fmeasure_max= 0.834315, precision= 0.913444, recall= 0.767802
# Train Random guess:  , auc= 0.248720fmeasure_max= 0.403130, precision= 0.252648, recall= 0.996904
# Validation Iter 1900, auc= 0.894789, fmeasure_max= 0.813891, precision= 0.846296, recall= 0.783877
# Validation Random guess:  auc= 0.223461, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.662827
# Tarin Iter 2000, auc= 0.874710, fmeasure_max= 0.807910, precision= 0.852883, recall= 0.767442
# Train Random guess:  , auc= 0.214029fmeasure_max= 0.359007, precision= 0.218947, recall= 0.996422
# Validation Iter 2000, auc= 0.860239, fmeasure_max= 0.788708, precision= 0.786689, recall= 0.790738
# Validation Random guess:  auc= 0.231698, fmeasure_max= 0.372382, precision= 0.230085, recall= 0.975986
# Minibatch Loss= 0.567524
# Tarin Iter 2100, auc= 0.899948, fmeasure_max= 0.842798, precision= 0.835237, recall= 0.850498
# Train Random guess:  , auc= 0.254404fmeasure_max= 0.383562, precision= 0.240067, recall= 0.953488
# Validation Iter 2100, auc= 0.867467, fmeasure_max= 0.811052, precision= 0.844156, recall= 0.780446
# Validation Random guess:  auc= 0.239348, fmeasure_max= 0.373218, precision= 0.231306, recall= 0.965695
# Minibatch Loss= 0.619081
# Tarin Iter 2200, auc= 0.846069, fmeasure_max= 0.786655, precision= 0.780488, recall= 0.792920
# Train Random guess:  , auc= 0.232335fmeasure_max= 0.362788, precision= 0.223500, recall= 0.962832
# Validation Iter 2200, auc= 0.877712, fmeasure_max= 0.804348, precision= 0.784666, recall= 0.825043
# Validation Random guess:  auc= 0.235764, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.679203
# Tarin Iter 2300, auc= 0.818955, fmeasure_max= 0.750745, precision= 0.766734, recall= 0.735409
# Train Random guess:  , auc= 0.216529fmeasure_max= 0.336935, precision= 0.203840, recall= 0.970817
# Validation Iter 2300, auc= 0.856537, fmeasure_max= 0.779221, precision= 0.786713, recall= 0.771870
# Validation Random guess:  auc= 0.240392, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.643820
# Tarin Iter 2400, auc= 0.907048, fmeasure_max= 0.838247, precision= 0.853896, recall= 0.823161
# Train Random guess:  , auc= 0.248623fmeasure_max= 0.399875, precision= 0.249902, recall= 1.000000
# Validation Iter 2400, auc= 0.876840, fmeasure_max= 0.800741, precision= 0.870968, recall= 0.740995
# Validation Random guess:  auc= 0.223290, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.617360
# Tarin Iter 2500, auc= 0.903268, fmeasure_max= 0.830015, precision= 0.831288, recall= 0.828746
# Train Random guess:  , auc= 0.257431fmeasure_max= 0.407361, precision= 0.255878, recall= 0.998471
# Validation Iter 2500, auc= 0.845304, fmeasure_max= 0.762903, precision= 0.719939, recall= 0.811321
# Validation Random guess:  auc= 0.229453, fmeasure_max= 0.374143, precision= 0.231048, recall= 0.982847
# Minibatch Loss= 0.637449
# Tarin Iter 2600, auc= 0.928109, fmeasure_max= 0.852061, precision= 0.865353, recall= 0.839172
# Train Random guess:  , auc= 0.255925fmeasure_max= 0.394545, precision= 0.246337, recall= 0.990446
# Validation Iter 2600, auc= 0.838936, fmeasure_max= 0.777124, precision= 0.762376, recall= 0.792453
# Validation Random guess:  auc= 0.236637, fmeasure_max= 0.373193, precision= 0.230800, recall= 0.974271
# Minibatch Loss= 0.590794
# Tarin Iter 2700, auc= 0.922222, fmeasure_max= 0.866062, precision= 0.911017, recall= 0.825336
# Train Random guess:  , auc= 0.199692fmeasure_max= 0.338202, precision= 0.203516, recall= 1.000000
# Validation Iter 2700, auc= 0.857170, fmeasure_max= 0.770044, precision= 0.791667, recall= 0.749571
# Validation Random guess:  auc= 0.213877, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.491999
# Tarin Iter 2800, auc= 0.902690, fmeasure_max= 0.823339, precision= 0.850921, recall= 0.797488
# Train Random guess:  , auc= 0.259347fmeasure_max= 0.400926, precision= 0.253982, recall= 0.951334
# Validation Iter 2800, auc= 0.850922, fmeasure_max= 0.790349, precision= 0.767367, recall= 0.814751
# Validation Random guess:  auc= 0.226879, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.658783
# Tarin Iter 2900, auc= 0.903825, fmeasure_max= 0.847926, precision= 0.879541, recall= 0.818505
# Train Random guess:  , auc= 0.229524fmeasure_max= 0.362989, precision= 0.221827, recall= 0.998221
# Validation Iter 2900, auc= 0.852529, fmeasure_max= 0.783205, precision= 0.782534, recall= 0.783877
# Validation Random guess:  auc= 0.242815, fmeasure_max= 0.374451, precision= 0.233165, recall= 0.950257
# Minibatch Loss= 0.527589
# Tarin Iter 3000, auc= 0.901058, fmeasure_max= 0.838816, precision= 0.844371, recall= 0.833333
# Train Random guess:  , auc= 0.246710fmeasure_max= 0.386242, precision= 0.239343, recall= 1.000000
# Validation Iter 3000, auc= 0.855979, fmeasure_max= 0.789901, precision= 0.832700, recall= 0.751286
# Validation Random guess:  auc= 0.223376, fmeasure_max= 0.373945, precision= 0.232773, recall= 0.950257
# Minibatch Loss= 0.664867
# Tarin Iter 3100, auc= 0.937588, fmeasure_max= 0.870683, precision= 0.871383, recall= 0.869984
# Train Random guess:  , auc= 0.231389fmeasure_max= 0.391811, precision= 0.243730, recall= 0.998395
# Validation Iter 3100, auc= 0.857879, fmeasure_max= 0.782007, precision= 0.788831, recall= 0.775300
# Validation Random guess:  auc= 0.225502, fmeasure_max= 0.372063, precision= 0.229002, recall= 0.991424
# Minibatch Loss= 0.554544
# Tarin Iter 3200, auc= 0.925042, fmeasure_max= 0.858080, precision= 0.909565, recall= 0.812112
# Train Random guess:  , auc= 0.256757fmeasure_max= 0.404573, precision= 0.254291, recall= 0.989130
# Validation Iter 3200, auc= 0.846332, fmeasure_max= 0.786942, precision= 0.788296, recall= 0.785592
# Validation Random guess:  auc= 0.228049, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.579584
# Tarin Iter 3300, auc= 0.906875, fmeasure_max= 0.849026, precision= 0.850407, recall= 0.847650
# Train Random guess:  , auc= 0.249795fmeasure_max= 0.389381, precision= 0.241853, recall= 0.998379
# Validation Iter 3300, auc= 0.840565, fmeasure_max= 0.773471, precision= 0.776817, recall= 0.770154
# Validation Random guess:  auc= 0.234000, fmeasure_max= 0.373139, precision= 0.231148, recall= 0.967410
# Minibatch Loss= 0.551832
# Tarin Iter 3400, auc= 0.905182, fmeasure_max= 0.832776, precision= 0.835570, recall= 0.830000
# Train Random guess:  , auc= 0.249311fmeasure_max= 0.379892, precision= 0.234762, recall= 0.995000
# Validation Iter 3400, auc= 0.859705, fmeasure_max= 0.767055, precision= 0.744750, recall= 0.790738
# Validation Random guess:  auc= 0.249426, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.585460
# Tarin Iter 3500, auc= 0.943904, fmeasure_max= 0.883937, precision= 0.883117, recall= 0.884758
# Train Random guess:  , auc= 0.201823fmeasure_max= 0.348278, precision= 0.211024, recall= 0.996283
# Validation Iter 3500, auc= 0.849950, fmeasure_max= 0.759340, precision= 0.769366, recall= 0.749571
# Validation Random guess:  auc= 0.225420, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.451862
# Tarin Iter 3600, auc= 0.916550, fmeasure_max= 0.848320, precision= 0.847550, recall= 0.849091
# Train Random guess:  , auc= 0.221292fmeasure_max= 0.354160, precision= 0.215439, recall= 0.994545
# Validation Iter 3600, auc= 0.860055, fmeasure_max= 0.778309, precision= 0.727273, recall= 0.837050
# Validation Random guess:  auc= 0.223248, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.526862
# Tarin Iter 3700, auc= 0.916099, fmeasure_max= 0.846154, precision= 0.815407, recall= 0.879310
# Train Random guess:  , auc= 0.249192fmeasure_max= 0.399873, precision= 0.250696, recall= 0.987461
# Validation Iter 3700, auc= 0.847583, fmeasure_max= 0.768963, precision= 0.781915, recall= 0.756432
# Validation Random guess:  auc= 0.227460, fmeasure_max= 0.375505, precision= 0.233571, recall= 0.957118
# Minibatch Loss= 0.558405
# Tarin Iter 3800, auc= 0.916974, fmeasure_max= 0.840824, precision= 0.850379, recall= 0.831481
# Train Random guess:  , auc= 0.208812fmeasure_max= 0.349320, precision= 0.211705, recall= 0.998148
# Validation Iter 3800, auc= 0.850601, fmeasure_max= 0.764543, precision= 0.828000, recall= 0.710120
# Validation Random guess:  auc= 0.244545, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.519327
# Tarin Iter 3900, auc= 0.940361, fmeasure_max= 0.871589, precision= 0.882927, recall= 0.860539
# Train Random guess:  , auc= 0.254602fmeasure_max= 0.397839, precision= 0.248808, recall= 0.992076
# Validation Iter 3900, auc= 0.873686, fmeasure_max= 0.791958, precision= 0.807487, recall= 0.777015
# Validation Random guess:  auc= 0.225702, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.519451
# Tarin Iter 4000, auc= 0.919769, fmeasure_max= 0.837730, precision= 0.852033, recall= 0.823899
# Train Random guess:  , auc= 0.240797fmeasure_max= 0.398496, precision= 0.248826, recall= 1.000000
# Validation Iter 4000, auc= 0.855346, fmeasure_max= 0.778051, precision= 0.744514, recall= 0.814751
# Validation Random guess:  auc= 0.236050, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.581478
# Tarin Iter 4100, auc= 0.945166, fmeasure_max= 0.878846, precision= 0.855805, recall= 0.903162
# Train Random guess:  , auc= 0.198844fmeasure_max= 0.332891, precision= 0.200000, recall= 0.992095
# Validation Iter 4100, auc= 0.842133, fmeasure_max= 0.766076, precision= 0.838776, recall= 0.704974
# Validation Random guess:  auc= 0.230747, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.394113
# Tarin Iter 4200, auc= 0.870572, fmeasure_max= 0.795752, precision= 0.813022, recall= 0.779200
# Train Random guess:  , auc= 0.246867fmeasure_max= 0.392958, precision= 0.244523, recall= 1.000000
# Validation Iter 4200, auc= 0.851907, fmeasure_max= 0.780209, precision= 0.876068, recall= 0.703259
# Validation Random guess:  auc= 0.216096, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.649871
# Tarin Iter 4300, auc= 0.955408, fmeasure_max= 0.893827, precision= 0.909548, recall= 0.878641
# Train Random guess:  , auc= 0.252136fmeasure_max= 0.389046, precision= 0.241501, recall= 1.000000
# Validation Iter 4300, auc= 0.861721, fmeasure_max= 0.776492, precision= 0.807407, recall= 0.747856
# Validation Random guess:  auc= 0.230033, fmeasure_max= 0.371539, precision= 0.228696, recall= 0.989708
# Minibatch Loss= 0.490173
# Tarin Iter 4400, auc= 0.945883, fmeasure_max= 0.881818, precision= 0.838617, recall= 0.929712
# Train Random guess:  , auc= 0.240283fmeasure_max= 0.393216, precision= 0.244722, recall= 1.000000
# Validation Iter 4400, auc= 0.852047, fmeasure_max= 0.766917, precision= 0.747557, recall= 0.787307
# Validation Random guess:  auc= 0.217747, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.484574
# Tarin Iter 4500, auc= 0.934672, fmeasure_max= 0.868442, precision= 0.890728, recall= 0.847244
# Train Random guess:  , auc= 0.259620fmeasure_max= 0.398369, precision= 0.248727, recall= 1.000000
# Validation Iter 4500, auc= 0.843551, fmeasure_max= 0.762943, precision= 0.810811, recall= 0.720412
# Validation Random guess:  auc= 0.231273, fmeasure_max= 0.371795, precision= 0.228616, recall= 0.994854
# Minibatch Loss= 0.533000
# Tarin Iter 4600, auc= 0.952338, fmeasure_max= 0.881448, precision= 0.871199, recall= 0.891941
# Train Random guess:  , auc= 0.206740fmeasure_max= 0.351578, precision= 0.213281, recall= 1.000000
# Validation Iter 4600, auc= 0.837462, fmeasure_max= 0.775023, precision= 0.833992, recall= 0.723842
# Validation Random guess:  auc= 0.220717, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.460039
# Tarin Iter 4700, auc= 0.954610, fmeasure_max= 0.889078, precision= 0.889078, recall= 0.889078
# Train Random guess:  , auc= 0.234664fmeasure_max= 0.373662, precision= 0.230677, recall= 0.982935
# Validation Iter 4700, auc= 0.859024, fmeasure_max= 0.774139, precision= 0.758224, recall= 0.790738
# Validation Random guess:  auc= 0.234208, fmeasure_max= 0.371716, precision= 0.229200, recall= 0.982847
# Minibatch Loss= 0.469209
# Tarin Iter 4800, auc= 0.932128, fmeasure_max= 0.880297, precision= 0.866764, recall= 0.894260
# Train Random guess:  , auc= 0.270445fmeasure_max= 0.412867, precision= 0.260236, recall= 0.998489
# Validation Iter 4800, auc= 0.820084, fmeasure_max= 0.757180, precision= 0.768551, recall= 0.746141
# Validation Random guess:  auc= 0.231131, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.502222
# Tarin Iter 4900, auc= 0.899316, fmeasure_max= 0.822002, precision= 0.790015, recall= 0.856688
# Train Random guess:  , auc= 0.256647fmeasure_max= 0.397330, precision= 0.248213, recall= 0.995223
# Validation Iter 4900, auc= 0.825105, fmeasure_max= 0.752244, precision= 0.789077, recall= 0.718696
# Validation Random guess:  auc= 0.228449, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.610149
# Tarin Iter 5000, auc= 0.952457, fmeasure_max= 0.889483, precision= 0.902351, recall= 0.876977
# Train Random guess:  , auc= 0.234015fmeasure_max= 0.370032, precision= 0.231310, recall= 0.924429
# Validation Iter 5000, auc= 0.829390, fmeasure_max= 0.756007, precision= 0.819639, recall= 0.701544
# Validation Random guess:  auc= 0.234118, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.437981
# Tarin Iter 5100, auc= 0.951050, fmeasure_max= 0.891437, precision= 0.896923, recall= 0.886018
# Train Random guess:  , auc= 0.251111fmeasure_max= 0.409204, precision= 0.257232, recall= 1.000000
# Validation Iter 5100, auc= 0.840801, fmeasure_max= 0.765122, precision= 0.705797, recall= 0.835334
# Validation Random guess:  auc= 0.216540, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.500722
# Tarin Iter 5200, auc= 0.943971, fmeasure_max= 0.881702, precision= 0.880952, recall= 0.882453
# Train Random guess:  , auc= 0.228393fmeasure_max= 0.373172, precision= 0.229386, recall= 1.000000
# Validation Iter 5200, auc= 0.860573, fmeasure_max= 0.793133, precision= 0.793814, recall= 0.792453
# Validation Random guess:  auc= 0.219405, fmeasure_max= 0.374194, precision= 0.230433, recall= 0.994854
# Minibatch Loss= 0.488342
# Tarin Iter 5300, auc= 0.941539, fmeasure_max= 0.869286, precision= 0.853543, recall= 0.885621
# Train Random guess:  , auc= 0.244488fmeasure_max= 0.385998, precision= 0.239156, recall= 1.000000
# Validation Iter 5300, auc= 0.841458, fmeasure_max= 0.773381, precision= 0.812854, recall= 0.737564
# Validation Random guess:  auc= 0.248635, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.484913
# Tarin Iter 5400, auc= 0.915252, fmeasure_max= 0.847771, precision= 0.851351, recall= 0.844221
# Train Random guess:  , auc= 0.238614fmeasure_max= 0.378567, precision= 0.233477, recall= 1.000000
# Validation Iter 5400, auc= 0.862848, fmeasure_max= 0.791897, precision= 0.854871, recall= 0.737564
# Validation Random guess:  auc= 0.248534, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.536075
# Tarin Iter 5500, auc= 0.937474, fmeasure_max= 0.871560, precision= 0.881262, recall= 0.862069
# Train Random guess:  , auc= 0.218376fmeasure_max= 0.354341, precision= 0.215318, recall= 1.000000
# Validation Iter 5500, auc= 0.839526, fmeasure_max= 0.767442, precision= 0.881960, recall= 0.679245
# Validation Random guess:  auc= 0.220155, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.478373
# Tarin Iter 5600, auc= 0.932662, fmeasure_max= 0.857636, precision= 0.826955, recall= 0.890681
# Train Random guess:  , auc= 0.218342fmeasure_max= 0.360224, precision= 0.220653, recall= 0.980287
# Validation Iter 5600, auc= 0.840258, fmeasure_max= 0.754128, precision= 0.810651, recall= 0.704974
# Validation Random guess:  auc= 0.230914, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.511370
# Tarin Iter 5700, auc= 0.929305, fmeasure_max= 0.865178, precision= 0.857377, recall= 0.873122
# Train Random guess:  , auc= 0.228648fmeasure_max= 0.379474, precision= 0.234167, recall= 1.000000
# Validation Iter 5700, auc= 0.837601, fmeasure_max= 0.763450, precision= 0.760204, recall= 0.766724
# Validation Random guess:  auc= 0.229932, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.527306
# Tarin Iter 5800, auc= 0.936827, fmeasure_max= 0.872902, precision= 0.854460, recall= 0.892157
# Train Random guess:  , auc= 0.238817fmeasure_max= 0.385876, precision= 0.239063, recall= 1.000000
# Validation Iter 5800, auc= 0.851429, fmeasure_max= 0.770538, precision= 0.857143, recall= 0.699828
# Validation Random guess:  auc= 0.233744, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.505984
# Tarin Iter 5900, auc= 0.906019, fmeasure_max= 0.819165, precision= 0.854839, recall= 0.786350
# Train Random guess:  , auc= 0.274250fmeasure_max= 0.419060, precision= 0.266132, recall= 0.985163
# Validation Iter 5900, auc= 0.844544, fmeasure_max= 0.763203, precision= 0.758037, recall= 0.768439
# Validation Random guess:  auc= 0.227857, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.616593
# Tarin Iter 6000, auc= 0.933741, fmeasure_max= 0.852240, precision= 0.818681, recall= 0.888668
# Train Random guess:  , auc= 0.194012fmeasure_max= 0.330640, precision= 0.199027, recall= 0.976143
# Validation Iter 6000, auc= 0.839880, fmeasure_max= 0.780749, precision= 0.812616, recall= 0.751286
# Validation Random guess:  auc= 0.227337, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.449464
# Tarin Iter 6100, auc= 0.916468, fmeasure_max= 0.850233, precision= 0.878846, recall= 0.823423
# Train Random guess:  , auc= 0.221328fmeasure_max= 0.356684, precision= 0.217051, recall= 1.000000
# Validation Iter 6100, auc= 0.846589, fmeasure_max= 0.773403, precision= 0.789286, recall= 0.758148
# Validation Random guess:  auc= 0.232178, fmeasure_max= 0.371578, precision= 0.229376, recall= 0.977702
# Minibatch Loss= 0.482961
# Tarin Iter 6200, auc= 0.939244, fmeasure_max= 0.867176, precision= 0.856712, recall= 0.877898
# Train Random guess:  , auc= 0.259818fmeasure_max= 0.403876, precision= 0.253135, recall= 0.998454
# Validation Iter 6200, auc= 0.844727, fmeasure_max= 0.784173, precision= 0.824197, recall= 0.747856
# Validation Random guess:  auc= 0.238142, fmeasure_max= 0.375451, precision= 0.232143, recall= 0.981132
# Minibatch Loss= 0.499734
# Tarin Iter 6300, auc= 0.956214, fmeasure_max= 0.873156, precision= 0.907975, recall= 0.840909
# Train Random guess:  , auc= 0.214190fmeasure_max= 0.344529, precision= 0.208955, recall= 0.981061
# Validation Iter 6300, auc= 0.853241, fmeasure_max= 0.770814, precision= 0.847737, recall= 0.706690
# Validation Random guess:  auc= 0.221566, fmeasure_max= 0.371429, precision= 0.229075, recall= 0.981132
# Minibatch Loss= 0.449076
# Tarin Iter 6400, auc= 0.937565, fmeasure_max= 0.864821, precision= 0.869067, recall= 0.860616
# Train Random guess:  , auc= 0.235441fmeasure_max= 0.388417, precision= 0.241016, recall= 1.000000
# Validation Iter 6400, auc= 0.839905, fmeasure_max= 0.776786, precision= 0.810056, recall= 0.746141
# Validation Random guess:  auc= 0.230439, fmeasure_max= 0.372386, precision= 0.230864, recall= 0.962264
# Minibatch Loss= 0.535216
# Tarin Iter 6500, auc= 0.966184, fmeasure_max= 0.904321, precision= 0.905719, recall= 0.902928
# Train Random guess:  , auc= 0.265291fmeasure_max= 0.404740, precision= 0.253714, recall= 1.000000
# Validation Iter 6500, auc= 0.841650, fmeasure_max= 0.767018, precision= 0.869565, recall= 0.686106
# Validation Random guess:  auc= 0.227940, fmeasure_max= 0.374797, precision= 0.231170, recall= 0.989708
# Minibatch Loss= 0.472494
# Tarin Iter 6600, auc= 0.952394, fmeasure_max= 0.878002, precision= 0.890838, recall= 0.865530
# Train Random guess:  , auc= 0.217375fmeasure_max= 0.345901, precision= 0.211595, recall= 0.946970
# Validation Iter 6600, auc= 0.842711, fmeasure_max= 0.766187, precision= 0.805293, recall= 0.730703
# Validation Random guess:  auc= 0.240453, fmeasure_max= 0.374916, precision= 0.233319, recall= 0.953688
# Minibatch Loss= 0.450028
# Tarin Iter 6700, auc= 0.940978, fmeasure_max= 0.863777, precision= 0.861111, recall= 0.866460
# Train Random guess:  , auc= 0.245480fmeasure_max= 0.403008, precision= 0.252454, recall= 0.998447
# Validation Iter 6700, auc= 0.840404, fmeasure_max= 0.782307, precision= 0.791228, recall= 0.773585
# Validation Random guess:  auc= 0.217470, fmeasure_max= 0.373120, precision= 0.229347, recall= 1.000000
# Minibatch Loss= 0.496304
# Tarin Iter 6800, auc= 0.927048, fmeasure_max= 0.862944, precision= 0.844371, recall= 0.882353
# Train Random guess:  , auc= 0.215897fmeasure_max= 0.368740, precision= 0.226046, recall= 1.000000
# Validation Iter 6800, auc= 0.835658, fmeasure_max= 0.775401, precision= 0.807050, recall= 0.746141
# Validation Random guess:  auc= 0.227043, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.499596
# Tarin Iter 6900, auc= 0.927845, fmeasure_max= 0.858006, precision= 0.865854, recall= 0.850299
# Train Random guess:  , auc= 0.271473fmeasure_max= 0.414894, precision= 0.262263, recall= 0.992515
# Validation Iter 6900, auc= 0.844125, fmeasure_max= 0.763231, precision= 0.831984, recall= 0.704974
# Validation Random guess:  auc= 0.223374, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.569610
# Tarin Iter 7000, auc= 0.956974, fmeasure_max= 0.899390, precision= 0.895296, recall= 0.903522
# Train Random guess:  , auc= 0.248232fmeasure_max= 0.406474, precision= 0.255078, recall= 1.000000
# Validation Iter 7000, auc= 0.843365, fmeasure_max= 0.768054, precision= 0.760943, recall= 0.775300
# Validation Random guess:  auc= 0.226516, fmeasure_max= 0.373110, precision= 0.229612, recall= 0.994854
# Minibatch Loss= 0.487491
# Tarin Iter 7100, auc= 0.958671, fmeasure_max= 0.898413, precision= 0.912903, recall= 0.884375
# Train Random guess:  , auc= 0.244402fmeasure_max= 0.400251, precision= 0.250392, recall= 0.996875
# Validation Iter 7100, auc= 0.849852, fmeasure_max= 0.770885, precision= 0.744409, recall= 0.799314
# Validation Random guess:  auc= 0.228831, fmeasure_max= 0.372643, precision= 0.228987, recall= 1.000000
# Minibatch Loss= 0.491796
# Tarin Iter 7200, auc= 0.951752, fmeasure_max= 0.885906, precision= 0.908778, recall= 0.864157
# Train Random guess:  , auc= 0.229325fmeasure_max= 0.386688, precision= 0.239780, recall= 0.998363
# Validation Iter 7200, auc= 0.850829, fmeasure_max= 0.763412, precision= 0.783394, recall= 0.744425
# Validation Random guess:  auc= 0.224126, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.487968
# Tarin Iter 7300, auc= 0.962730, fmeasure_max= 0.903279, precision= 0.887279, recall= 0.919866
# Train Random guess:  , auc= 0.224911fmeasure_max= 0.380828, precision= 0.236629, recall= 0.974958
# Validation Iter 7300, auc= 0.851688, fmeasure_max= 0.770999, precision= 0.795620, recall= 0.747856
# Validation Random guess:  auc= 0.226244, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.449092
# Tarin Iter 7400, auc= 0.943841, fmeasure_max= 0.865600, precision= 0.861465, recall= 0.869775
# Train Random guess:  , auc= 0.240559fmeasure_max= 0.391072, precision= 0.243064, recall= 1.000000
# Validation Iter 7400, auc= 0.838746, fmeasure_max= 0.760036, precision= 0.791822, recall= 0.730703
# Validation Random guess:  auc= 0.211142, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.496216
# Tarin Iter 7500, auc= 0.936621, fmeasure_max= 0.860122, precision= 0.885510, recall= 0.836149
# Train Random guess:  , auc= 0.228968fmeasure_max= 0.377515, precision= 0.232769, recall= 0.998311
# Validation Iter 7500, auc= 0.859310, fmeasure_max= 0.784101, precision= 0.828244, recall= 0.744425
# Validation Random guess:  auc= 0.231206, fmeasure_max= 0.372382, precision= 0.230085, recall= 0.975986
# Minibatch Loss= 0.512972
# Tarin Iter 7600, auc= 0.932182, fmeasure_max= 0.861436, precision= 0.850082, recall= 0.873096
# Train Random guess:  , auc= 0.234144fmeasure_max= 0.375238, precision= 0.230950, recall= 1.000000
# Validation Iter 7600, auc= 0.837800, fmeasure_max= 0.754325, precision= 0.760908, recall= 0.747856
# Validation Random guess:  auc= 0.230735, fmeasure_max= 0.372748, precision= 0.230364, recall= 0.975986
# Minibatch Loss= 0.507667
# Tarin Iter 7700, auc= 0.959893, fmeasure_max= 0.885580, precision= 0.929276, recall= 0.845808
# Train Random guess:  , auc= 0.248110fmeasure_max= 0.414007, precision= 0.261039, recall= 1.000000
# Validation Iter 7700, auc= 0.834688, fmeasure_max= 0.766136, precision= 0.749180, recall= 0.783877
# Validation Random guess:  auc= 0.228534, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.465154
# Tarin Iter 7800, auc= 0.945969, fmeasure_max= 0.878887, precision= 0.848341, recall= 0.911715
# Train Random guess:  , auc= 0.240264fmeasure_max= 0.374642, precision= 0.230588, recall= 0.998302
# Validation Iter 7800, auc= 0.833309, fmeasure_max= 0.763134, precision= 0.824701, recall= 0.710120
# Validation Random guess:  auc= 0.241996, fmeasure_max= 0.374958, precision= 0.232945, recall= 0.960549
# Minibatch Loss= 0.422820
# Tarin Iter 7900, auc= 0.924910, fmeasure_max= 0.840033, precision= 0.866328, recall= 0.815287
# Train Random guess:  , auc= 0.251877fmeasure_max= 0.393977, precision= 0.245312, recall= 1.000000
# Validation Iter 7900, auc= 0.849533, fmeasure_max= 0.770627, precision= 0.742448, recall= 0.801029
# Validation Random guess:  auc= 0.223654, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.572815
# Tarin Iter 8000, auc= 0.924409, fmeasure_max= 0.849442, precision= 0.863894, recall= 0.835466
# Train Random guess:  , auc= 0.220617fmeasure_max= 0.353552, precision= 0.214905, recall= 0.996344
# Validation Iter 8000, auc= 0.827900, fmeasure_max= 0.771300, precision= 0.808271, recall= 0.737564
# Validation Random guess:  auc= 0.221770, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.461475
# Tarin Iter 8100, auc= 0.950169, fmeasure_max= 0.881804, precision= 0.883178, recall= 0.880435
# Train Random guess:  , auc= 0.245544fmeasure_max= 0.402626, precision= 0.252055, recall= 1.000000
# Validation Iter 8100, auc= 0.846516, fmeasure_max= 0.771453, precision= 0.764310, recall= 0.778731
# Validation Random guess:  auc= 0.233466, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.508059
# Tarin Iter 8200, auc= 0.947609, fmeasure_max= 0.873355, precision= 0.850962, recall= 0.896959
# Train Random guess:  , auc= 0.228132fmeasure_max= 0.375635, precision= 0.231250, recall= 1.000000
# Validation Iter 8200, auc= 0.847827, fmeasure_max= 0.781588, precision= 0.824762, recall= 0.742710
# Validation Random guess:  auc= 0.231957, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.449063
# Tarin Iter 8300, auc= 0.949100, fmeasure_max= 0.882938, precision= 0.889060, recall= 0.876900
# Train Random guess:  , auc= 0.274160fmeasure_max= 0.409204, precision= 0.257232, recall= 1.000000
# Validation Iter 8300, auc= 0.832631, fmeasure_max= 0.761722, precision= 0.861472, recall= 0.682676
# Validation Random guess:  auc= 0.247653, fmeasure_max= 0.372859, precision= 0.230738, recall= 0.970840
# Minibatch Loss= 0.539464
# Tarin Iter 8400, auc= 0.955987, fmeasure_max= 0.896027, precision= 0.870279, recall= 0.923345
# Train Random guess:  , auc= 0.242294fmeasure_max= 0.367771, precision= 0.226038, recall= 0.986063
# Validation Iter 8400, auc= 0.857640, fmeasure_max= 0.781735, precision= 0.835938, recall= 0.734134
# Validation Random guess:  auc= 0.227039, fmeasure_max= 0.372242, precision= 0.228774, recall= 0.998285
# Minibatch Loss= 0.446073
# Tarin Iter 8500, auc= 0.954766, fmeasure_max= 0.902024, precision= 0.904221, recall= 0.899838
# Train Random guess:  , auc= 0.254186fmeasure_max= 0.390361, precision= 0.248031, recall= 0.915994
# Validation Iter 8500, auc= 0.835345, fmeasure_max= 0.766222, precision= 0.795203, recall= 0.739280
# Validation Random guess:  auc= 0.235213, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.462248
# Tarin Iter 8600, auc= 0.968043, fmeasure_max= 0.913765, precision= 0.926050, recall= 0.901800
# Train Random guess:  , auc= 0.235350fmeasure_max= 0.386378, precision= 0.239826, recall= 0.993453
# Validation Iter 8600, auc= 0.838319, fmeasure_max= 0.769953, precision= 0.850622, recall= 0.703259
# Validation Random guess:  auc= 0.233934, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.469339
# Tarin Iter 8700, auc= 0.948055, fmeasure_max= 0.880143, precision= 0.891304, recall= 0.869258
# Train Random guess:  , auc= 0.209352fmeasure_max= 0.362937, precision= 0.221700, recall= 1.000000
# Validation Iter 8700, auc= 0.822326, fmeasure_max= 0.770383, precision= 0.747981, recall= 0.794168
# Validation Random guess:  auc= 0.228159, fmeasure_max= 0.371791, precision= 0.229350, recall= 0.981132
# Minibatch Loss= 0.447839
# Tarin Iter 8800, auc= 0.958487, fmeasure_max= 0.899153, precision= 0.876877, recall= 0.922591
# Train Random guess:  , auc= 0.243615fmeasure_max= 0.397091, precision= 0.248221, recall= 0.992101
# Validation Iter 8800, auc= 0.818320, fmeasure_max= 0.761905, precision= 0.742671, recall= 0.782161
# Validation Random guess:  auc= 0.227600, fmeasure_max= 0.371624, precision= 0.229317, recall= 0.979417
# Minibatch Loss= 0.471233
# Tarin Iter 8900, auc= 0.967103, fmeasure_max= 0.908088, precision= 0.903108, recall= 0.913124
# Train Random guess:  , auc= 0.198220fmeasure_max= 0.349370, precision= 0.211659, recall= 1.000000
# Validation Iter 8900, auc= 0.835174, fmeasure_max= 0.765388, precision= 0.797398, recall= 0.735849
# Validation Random guess:  auc= 0.225266, fmeasure_max= 0.373159, precision= 0.230583, recall= 0.977702
# Minibatch Loss= 0.374571
# Tarin Iter 9000, auc= 0.971388, fmeasure_max= 0.916006, precision= 0.904538, recall= 0.927769
# Train Random guess:  , auc= 0.238433fmeasure_max= 0.391455, precision= 0.243359, recall= 1.000000
# Validation Iter 9000, auc= 0.831327, fmeasure_max= 0.769919, precision= 0.805243, recall= 0.737564
# Validation Random guess:  auc= 0.229228, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.462510
# Tarin Iter 9100, auc= 0.942774, fmeasure_max= 0.884354, precision= 0.904573, recall= 0.865019
# Train Random guess:  , auc= 0.208869fmeasure_max= 0.341829, precision= 0.212885, recall= 0.866920
# Validation Iter 9100, auc= 0.834055, fmeasure_max= 0.762849, precision= 0.804183, recall= 0.725557
# Validation Random guess:  auc= 0.233161, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.450446
# Tarin Iter 9200, auc= 0.950632, fmeasure_max= 0.873029, precision= 0.853896, recall= 0.893039
# Train Random guess:  , auc= 0.227283fmeasure_max= 0.375200, precision= 0.231102, recall= 0.996604
# Validation Iter 9200, auc= 0.833112, fmeasure_max= 0.776065, precision= 0.823077, recall= 0.734134
# Validation Random guess:  auc= 0.233908, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.501198
# Tarin Iter 9300, auc= 0.958443, fmeasure_max= 0.899017, precision= 0.921245, recall= 0.877836
# Train Random guess:  , auc= 0.218545fmeasure_max= 0.365799, precision= 0.224192, recall= 0.993019
# Validation Iter 9300, auc= 0.828761, fmeasure_max= 0.765475, precision= 0.778369, recall= 0.753002
# Validation Random guess:  auc= 0.259200, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.443043
# Tarin Iter 9400, auc= 0.951163, fmeasure_max= 0.878536, precision= 0.934513, recall= 0.828885
# Train Random guess:  , auc= 0.259408fmeasure_max= 0.399370, precision= 0.249803, recall= 0.995290
# Validation Iter 9400, auc= 0.849309, fmeasure_max= 0.780269, precision= 0.817669, recall= 0.746141
# Validation Random guess:  auc= 0.224892, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.515584
# Tarin Iter 9500, auc= 0.970622, fmeasure_max= 0.913994, precision= 0.937220, recall= 0.891892
# Train Random guess:  , auc= 0.265334fmeasure_max= 0.430892, precision= 0.274609, recall= 1.000000
# Validation Iter 9500, auc= 0.824997, fmeasure_max= 0.774074, precision= 0.841046, recall= 0.716981
# Validation Random guess:  auc= 0.219709, fmeasure_max= 0.373655, precision= 0.230676, recall= 0.982847
# Minibatch Loss= 0.492188
# Tarin Iter 9600, auc= 0.967252, fmeasure_max= 0.918367, precision= 0.932642, recall= 0.904523
# Train Random guess:  , auc= 0.226882fmeasure_max= 0.381770, precision= 0.237762, recall= 0.968174
# Validation Iter 9600, auc= 0.833386, fmeasure_max= 0.773634, precision= 0.782456, recall= 0.765009
# Validation Random guess:  auc= 0.237044, fmeasure_max= 0.371750, precision= 0.228673, recall= 0.993139
# Minibatch Loss= 0.417868
# Tarin Iter 9700, auc= 0.962128, fmeasure_max= 0.903331, precision= 0.901135, recall= 0.905537
# Train Random guess:  , auc= 0.230273fmeasure_max= 0.387994, precision= 0.240690, recall= 1.000000
# Validation Iter 9700, auc= 0.837930, fmeasure_max= 0.765368, precision= 0.772727, recall= 0.758148
# Validation Random guess:  auc= 0.232285, fmeasure_max= 0.372351, precision= 0.229871, recall= 0.979417
# Minibatch Loss= 0.462853
# Tarin Iter 9800, auc= 0.972800, fmeasure_max= 0.924668, precision= 0.913869, recall= 0.935725
# Train Random guess:  , auc= 0.277378fmeasure_max= 0.414498, precision= 0.261430, recall= 1.000000
# Validation Iter 9800, auc= 0.829186, fmeasure_max= 0.769497, precision= 0.777583, recall= 0.761578
# Validation Random guess:  auc= 0.227585, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.447145
# Tarin Iter 9900, auc= 0.952314, fmeasure_max= 0.884583, precision= 0.897436, recall= 0.872093
# Train Random guess:  , auc= 0.250595fmeasure_max= 0.380772, precision= 0.235156, recall= 1.000000
# Validation Iter 9900, auc= 0.829268, fmeasure_max= 0.777778, precision= 0.775128, recall= 0.780446
# Validation Random guess:  auc= 0.234424, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.469195
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.834647 F1_max = 0.780378 prec = 0.801353 rec = 0.760473
# Test Random guess: auc= 0.231034 fmeasure_max= 0.375718 , precision= 0.231313 , recall= 1.000000

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
