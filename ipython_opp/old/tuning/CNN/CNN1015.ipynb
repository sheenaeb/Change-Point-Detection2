# %%
# useing this variable for saving models and summaries
exp_name = "CNN1015"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [8, 4, 1, 1, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.271837, fmeasure_max= 0.432572, precision= 0.289171, recall= 0.858120
# Train Random guess:  , auc= 0.227220fmeasure_max= 0.373350, precision= 0.229976, recall= 0.991453
# Validation Iter 0, auc= 0.245197, fmeasure_max= 0.421561, precision= 0.275355, recall= 0.898799
# Validation Random guess:  auc= 0.224896, fmeasure_max= 0.374420, precision= 0.232033, recall= 0.969125
# Minibatch Loss= 1.044540
# Tarin Iter 100, auc= 0.821445, fmeasure_max= 0.801504, precision= 0.839370, recall= 0.766906
# Train Random guess:  , auc= 0.272912fmeasure_max= 0.427429, precision= 0.271803, recall= 1.000000
# Validation Iter 100, auc= 0.740745, fmeasure_max= 0.728941, precision= 0.709416, recall= 0.749571
# Validation Random guess:  auc= 0.230795, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.847451
# Tarin Iter 200, auc= 0.848390, fmeasure_max= 0.781573, precision= 0.842466, recall= 0.728889
# Train Random guess:  , auc= 0.262250fmeasure_max= 0.418069, precision= 0.264694, recall= 0.994074
# Validation Iter 200, auc= 0.779390, fmeasure_max= 0.746032, precision= 0.694239, recall= 0.806175
# Validation Random guess:  auc= 0.211532, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.704402
# Tarin Iter 300, auc= 0.785997, fmeasure_max= 0.739698, precision= 0.817778, recall= 0.675229
# Train Random guess:  , auc= 0.210391fmeasure_max= 0.353369, precision= 0.215465, recall= 0.981651
# Validation Iter 300, auc= 0.807651, fmeasure_max= 0.749529, precision= 0.830898, recall= 0.682676
# Validation Random guess:  auc= 0.231544, fmeasure_max= 0.374011, precision= 0.231523, recall= 0.972556
# Minibatch Loss= 0.704081
# Tarin Iter 400, auc= 0.876700, fmeasure_max= 0.802752, precision= 0.864909, recall= 0.748930
# Train Random guess:  , auc= 0.280148fmeasure_max= 0.430590, precision= 0.274364, recall= 1.000000
# Validation Iter 400, auc= 0.857078, fmeasure_max= 0.780154, precision= 0.778157, recall= 0.782161
# Validation Random guess:  auc= 0.229280, fmeasure_max= 0.372940, precision= 0.233147, recall= 0.931389
# Minibatch Loss= 0.751030
# Tarin Iter 500, auc= 0.831580, fmeasure_max= 0.760274, precision= 0.770833, recall= 0.750000
# Train Random guess:  , auc= 0.227979fmeasure_max= 0.377070, precision= 0.232339, recall= 1.000000
# Validation Iter 500, auc= 0.867146, fmeasure_max= 0.777219, precision= 0.759411, recall= 0.795883
# Validation Random guess:  auc= 0.227792, fmeasure_max= 0.371762, precision= 0.229142, recall= 0.984563
# Minibatch Loss= 0.686105
# Tarin Iter 600, auc= 0.827270, fmeasure_max= 0.774454, precision= 0.783961, recall= 0.765176
# Train Random guess:  , auc= 0.241485fmeasure_max= 0.393308, precision= 0.245083, recall= 0.995208
# Validation Iter 600, auc= 0.872966, fmeasure_max= 0.802168, precision= 0.847328, recall= 0.761578
# Validation Random guess:  auc= 0.207969, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.730428
# Tarin Iter 700, auc= 0.848799, fmeasure_max= 0.774016, precision= 0.796610, recall= 0.752669
# Train Random guess:  , auc= 0.231783fmeasure_max= 0.361156, precision= 0.220898, recall= 0.989324
# Validation Iter 700, auc= 0.898737, fmeasure_max= 0.828316, precision= 0.787926, recall= 0.873070
# Validation Random guess:  auc= 0.233739, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.618488
# Tarin Iter 800, auc= 0.848645, fmeasure_max= 0.793530, precision= 0.845842, recall= 0.747312
# Train Random guess:  , auc= 0.213824fmeasure_max= 0.357922, precision= 0.217969, recall= 1.000000
# Validation Iter 800, auc= 0.873586, fmeasure_max= 0.814298, precision= 0.828014, recall= 0.801029
# Validation Random guess:  auc= 0.239463, fmeasure_max= 0.375856, precision= 0.232071, recall= 0.987993
# Minibatch Loss= 0.652090
# Tarin Iter 900, auc= 0.900484, fmeasure_max= 0.805704, precision= 0.818841, recall= 0.792982
# Train Random guess:  , auc= 0.220776fmeasure_max= 0.367252, precision= 0.226400, recall= 0.971930
# Validation Iter 900, auc= 0.886641, fmeasure_max= 0.809122, precision= 0.797005, recall= 0.821612
# Validation Random guess:  auc= 0.228898, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.553362
# Tarin Iter 1000, auc= 0.914258, fmeasure_max= 0.837012, precision= 0.820300, recall= 0.854419
# Train Random guess:  , auc= 0.213894fmeasure_max= 0.367867, precision= 0.225391, recall= 1.000000
# Validation Iter 1000, auc= 0.896274, fmeasure_max= 0.823009, precision= 0.850091, recall= 0.797599
# Validation Random guess:  auc= 0.244613, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.542411
# Tarin Iter 1100, auc= 0.922293, fmeasure_max= 0.845679, precision= 0.861635, recall= 0.830303
# Train Random guess:  , auc= 0.187260fmeasure_max= 0.325504, precision= 0.194620, recall= 0.993939
# Validation Iter 1100, auc= 0.902681, fmeasure_max= 0.824253, precision= 0.845045, recall= 0.804460
# Validation Random guess:  auc= 0.222590, fmeasure_max= 0.373775, precision= 0.232744, recall= 0.948542
# Minibatch Loss= 0.448542
# Tarin Iter 1200, auc= 0.914628, fmeasure_max= 0.851952, precision= 0.833992, recall= 0.870702
# Train Random guess:  , auc= 0.281951fmeasure_max= 0.442483, precision= 0.284095, recall= 1.000000
# Validation Iter 1200, auc= 0.869806, fmeasure_max= 0.799663, precision= 0.785124, recall= 0.814751
# Validation Random guess:  auc= 0.231089, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.634374
# Tarin Iter 1300, auc= 0.941086, fmeasure_max= 0.861011, precision= 0.875229, recall= 0.847247
# Train Random guess:  , auc= 0.221155fmeasure_max= 0.361057, precision= 0.220559, recall= 0.994671
# Validation Iter 1300, auc= 0.893796, fmeasure_max= 0.825629, precision= 0.783077, recall= 0.873070
# Validation Random guess:  auc= 0.227767, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.443493
# Tarin Iter 1400, auc= 0.913495, fmeasure_max= 0.845395, precision= 0.874150, recall= 0.818471
# Train Random guess:  , auc= 0.256180fmeasure_max= 0.394225, precision= 0.245504, recall= 1.000000
# Validation Iter 1400, auc= 0.892208, fmeasure_max= 0.816092, precision= 0.782677, recall= 0.852487
# Validation Random guess:  auc= 0.228074, fmeasure_max= 0.372783, precision= 0.229547, recall= 0.991424
# Minibatch Loss= 0.584746
# Tarin Iter 1500, auc= 0.945383, fmeasure_max= 0.874049, precision= 0.873311, recall= 0.874788
# Train Random guess:  , auc= 0.224888fmeasure_max= 0.376079, precision= 0.231861, recall= 0.994924
# Validation Iter 1500, auc= 0.898745, fmeasure_max= 0.819277, precision= 0.822107, recall= 0.816467
# Validation Random guess:  auc= 0.243595, fmeasure_max= 0.372947, precision= 0.229580, recall= 0.993139
# Minibatch Loss= 0.472065
# Tarin Iter 1600, auc= 0.914306, fmeasure_max= 0.854938, precision= 0.839394, recall= 0.871069
# Train Random guess:  , auc= 0.255018fmeasure_max= 0.399621, precision= 0.250000, recall= 0.995283
# Validation Iter 1600, auc= 0.916488, fmeasure_max= 0.838182, precision= 0.891683, recall= 0.790738
# Validation Random guess:  auc= 0.234694, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.571014
# Tarin Iter 1700, auc= 0.918652, fmeasure_max= 0.870031, precision= 0.868702, recall= 0.871363
# Train Random guess:  , auc= 0.242921fmeasure_max= 0.406474, precision= 0.255078, recall= 1.000000
# Validation Iter 1700, auc= 0.908199, fmeasure_max= 0.837209, precision= 0.874766, recall= 0.802744
# Validation Random guess:  auc= 0.227192, fmeasure_max= 0.373342, precision= 0.230064, recall= 0.989708
# Minibatch Loss= 0.525379
# Tarin Iter 1800, auc= 0.908919, fmeasure_max= 0.837838, precision= 0.805195, recall= 0.873239
# Train Random guess:  , auc= 0.233893fmeasure_max= 0.363171, precision= 0.221875, recall= 1.000000
# Validation Iter 1800, auc= 0.897457, fmeasure_max= 0.817360, precision= 0.864245, recall= 0.775300
# Validation Random guess:  auc= 0.239522, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.546253
# Tarin Iter 1900, auc= 0.911749, fmeasure_max= 0.816901, precision= 0.821239, recall= 0.812609
# Train Random guess:  , auc= 0.218724fmeasure_max= 0.365791, precision= 0.223834, recall= 1.000000
# Validation Iter 1900, auc= 0.915800, fmeasure_max= 0.845270, precision= 0.872263, recall= 0.819897
# Validation Random guess:  auc= 0.222475, fmeasure_max= 0.373091, precision= 0.230152, recall= 0.984563
# Minibatch Loss= 0.492228
# Tarin Iter 2000, auc= 0.956294, fmeasure_max= 0.902267, precision= 0.870287, recall= 0.936688
# Train Random guess:  , auc= 0.242804fmeasure_max= 0.390886, precision= 0.243600, recall= 0.988636
# Validation Iter 2000, auc= 0.913078, fmeasure_max= 0.844720, precision= 0.875000, recall= 0.816467
# Validation Random guess:  auc= 0.235611, fmeasure_max= 0.371808, precision= 0.231946, recall= 0.936535
# Minibatch Loss= 0.432925
# Tarin Iter 2100, auc= 0.929575, fmeasure_max= 0.851064, precision= 0.872865, recall= 0.830325
# Train Random guess:  , auc= 0.219987fmeasure_max= 0.358874, precision= 0.219200, recall= 0.989170
# Validation Iter 2100, auc= 0.921089, fmeasure_max= 0.843990, precision= 0.838983, recall= 0.849057
# Validation Random guess:  auc= 0.236681, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.432807
# Tarin Iter 2200, auc= 0.937235, fmeasure_max= 0.856683, precision= 0.802413, recall= 0.918826
# Train Random guess:  , auc= 0.229581fmeasure_max= 0.370323, precision= 0.227237, recall= 1.000000
# Validation Iter 2200, auc= 0.898588, fmeasure_max= 0.824360, precision= 0.849091, recall= 0.801029
# Validation Random guess:  auc= 0.233970, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.450078
# Tarin Iter 2300, auc= 0.906607, fmeasure_max= 0.813592, precision= 0.841365, recall= 0.787594
# Train Random guess:  , auc= 0.196998fmeasure_max= 0.344560, precision= 0.208138, recall= 1.000000
# Validation Iter 2300, auc= 0.904125, fmeasure_max= 0.824670, precision= 0.847826, recall= 0.802744
# Validation Random guess:  auc= 0.236342, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.489113
# Tarin Iter 2400, auc= 0.922248, fmeasure_max= 0.845022, precision= 0.838488, recall= 0.851658
# Train Random guess:  , auc= 0.228016fmeasure_max= 0.366251, precision= 0.224178, recall= 1.000000
# Validation Iter 2400, auc= 0.888808, fmeasure_max= 0.801425, precision= 0.833333, recall= 0.771870
# Validation Random guess:  auc= 0.225096, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.462844
# Tarin Iter 2500, auc= 0.959803, fmeasure_max= 0.899585, precision= 0.901830, recall= 0.897351
# Train Random guess:  , auc= 0.237072fmeasure_max= 0.382642, precision= 0.236584, recall= 1.000000
# Validation Iter 2500, auc= 0.914765, fmeasure_max= 0.840606, precision= 0.874074, recall= 0.809605
# Validation Random guess:  auc= 0.240031, fmeasure_max= 0.372859, precision= 0.229697, recall= 0.989708
# Minibatch Loss= 0.434395
# Tarin Iter 2600, auc= 0.940223, fmeasure_max= 0.891918, precision= 0.899804, recall= 0.884170
# Train Random guess:  , auc= 0.211659fmeasure_max= 0.339735, precision= 0.205036, recall= 0.990347
# Validation Iter 2600, auc= 0.912308, fmeasure_max= 0.827948, precision= 0.843416, recall= 0.813036
# Validation Random guess:  auc= 0.223987, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.441059
# Tarin Iter 2700, auc= 0.934506, fmeasure_max= 0.860300, precision= 0.809807, recall= 0.917508
# Train Random guess:  , auc= 0.238574fmeasure_max= 0.376665, precision= 0.232031, recall= 1.000000
# Validation Iter 2700, auc= 0.918133, fmeasure_max= 0.850258, precision= 0.853195, recall= 0.847341
# Validation Random guess:  auc= 0.237021, fmeasure_max= 0.372925, precision= 0.230120, recall= 0.982847
# Minibatch Loss= 0.452041
# Tarin Iter 2800, auc= 0.898441, fmeasure_max= 0.844444, precision= 0.868571, recall= 0.821622
# Train Random guess:  , auc= 0.216560fmeasure_max= 0.356798, precision= 0.217136, recall= 1.000000
# Validation Iter 2800, auc= 0.900360, fmeasure_max= 0.807323, precision= 0.820922, recall= 0.794168
# Validation Random guess:  auc= 0.239054, fmeasure_max= 0.372661, precision= 0.239686, recall= 0.837050
# Minibatch Loss= 0.469844
# Tarin Iter 2900, auc= 0.943862, fmeasure_max= 0.872668, precision= 0.828968, recall= 0.921233
# Train Random guess:  , auc= 0.229765fmeasure_max= 0.372915, precision= 0.230489, recall= 0.976027
# Validation Iter 2900, auc= 0.913418, fmeasure_max= 0.834934, precision= 0.850534, recall= 0.819897
# Validation Random guess:  auc= 0.239300, fmeasure_max= 0.372454, precision= 0.229482, recall= 0.987993
# Minibatch Loss= 0.457766
# Tarin Iter 3000, auc= 0.947136, fmeasure_max= 0.877922, precision= 0.903743, recall= 0.853535
# Train Random guess:  , auc= 0.233047fmeasure_max= 0.377023, precision= 0.232303, recall= 1.000000
# Validation Iter 3000, auc= 0.911504, fmeasure_max= 0.846086, precision= 0.868231, recall= 0.825043
# Validation Random guess:  auc= 0.229051, fmeasure_max= 0.372258, precision= 0.229241, recall= 0.989708
# Minibatch Loss= 0.461839
# Tarin Iter 3100, auc= 0.962121, fmeasure_max= 0.897995, precision= 0.868465, recall= 0.929603
# Train Random guess:  , auc= 0.223421fmeasure_max= 0.355812, precision= 0.216406, recall= 1.000000
# Validation Iter 3100, auc= 0.912266, fmeasure_max= 0.841751, precision= 0.826446, recall= 0.857633
# Validation Random guess:  auc= 0.228225, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.406384
# Tarin Iter 3200, auc= 0.931496, fmeasure_max= 0.853224, precision= 0.833780, recall= 0.873596
# Train Random guess:  , auc= 0.303897fmeasure_max= 0.435395, precision= 0.278387, recall= 0.998596
# Validation Iter 3200, auc= 0.897855, fmeasure_max= 0.823117, precision= 0.840787, recall= 0.806175
# Validation Random guess:  auc= 0.244951, fmeasure_max= 0.371596, precision= 0.232528, recall= 0.924528
# Minibatch Loss= 0.528269
# Tarin Iter 3300, auc= 0.926059, fmeasure_max= 0.858757, precision= 0.875000, recall= 0.843106
# Train Random guess:  , auc= 0.245880fmeasure_max= 0.396108, precision= 0.246967, recall= 1.000000
# Validation Iter 3300, auc= 0.912407, fmeasure_max= 0.840655, precision= 0.844291, recall= 0.837050
# Validation Random guess:  auc= 0.237955, fmeasure_max= 0.371081, precision= 0.228077, recall= 0.994854
# Minibatch Loss= 0.503260
# Tarin Iter 3400, auc= 0.950042, fmeasure_max= 0.883271, precision= 0.868421, recall= 0.898638
# Train Random guess:  , auc= 0.261171fmeasure_max= 0.411343, precision= 0.259027, recall= 0.998487
# Validation Iter 3400, auc= 0.916707, fmeasure_max= 0.837768, precision= 0.838488, recall= 0.837050
# Validation Random guess:  auc= 0.224412, fmeasure_max= 0.374634, precision= 0.231140, recall= 0.987993
# Minibatch Loss= 0.503043
# Tarin Iter 3500, auc= 0.937574, fmeasure_max= 0.851064, precision= 0.849057, recall= 0.853081
# Train Random guess:  , auc= 0.257594fmeasure_max= 0.398489, precision= 0.248821, recall= 1.000000
# Validation Iter 3500, auc= 0.924127, fmeasure_max= 0.851624, precision= 0.872302, recall= 0.831904
# Validation Random guess:  auc= 0.237536, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.494233
# Tarin Iter 3600, auc= 0.946506, fmeasure_max= 0.867209, precision= 0.879121, recall= 0.855615
# Train Random guess:  , auc= 0.223471fmeasure_max= 0.360129, precision= 0.219694, recall= 0.998217
# Validation Iter 3600, auc= 0.912966, fmeasure_max= 0.823834, precision= 0.829565, recall= 0.818182
# Validation Random guess:  auc= 0.235870, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.422068
# Tarin Iter 3700, auc= 0.956782, fmeasure_max= 0.885219, precision= 0.870130, recall= 0.900840
# Train Random guess:  , auc= 0.223225fmeasure_max= 0.377538, precision= 0.232695, recall= 1.000000
# Validation Iter 3700, auc= 0.907008, fmeasure_max= 0.817726, precision= 0.797716, recall= 0.838765
# Validation Random guess:  auc= 0.216777, fmeasure_max= 0.374918, precision= 0.231831, recall= 0.979417
# Minibatch Loss= 0.399997
# Tarin Iter 3800, auc= 0.927684, fmeasure_max= 0.845238, precision= 0.851027, recall= 0.839527
# Train Random guess:  , auc= 0.248867fmeasure_max= 0.377668, precision= 0.234407, recall= 0.971284
# Validation Iter 3800, auc= 0.905016, fmeasure_max= 0.815074, precision= 0.833333, recall= 0.797599
# Validation Random guess:  auc= 0.241561, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.505637
# Tarin Iter 3900, auc= 0.938748, fmeasure_max= 0.861157, precision= 0.874161, recall= 0.848534
# Train Random guess:  , auc= 0.224475fmeasure_max= 0.386894, precision= 0.239844, recall= 1.000000
# Validation Iter 3900, auc= 0.931364, fmeasure_max= 0.856669, precision= 0.828526, recall= 0.886792
# Validation Random guess:  auc= 0.228269, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.442986
# Tarin Iter 4000, auc= 0.938236, fmeasure_max= 0.846792, precision= 0.826215, recall= 0.868421
# Train Random guess:  , auc= 0.254690fmeasure_max= 0.403865, precision= 0.254982, recall= 0.970588
# Validation Iter 4000, auc= 0.923401, fmeasure_max= 0.844996, precision= 0.873626, recall= 0.818182
# Validation Random guess:  auc= 0.216909, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.453187
# Tarin Iter 4100, auc= 0.959406, fmeasure_max= 0.901387, precision= 0.877061, recall= 0.927100
# Train Random guess:  , auc= 0.242373fmeasure_max= 0.395984, precision= 0.246870, recall= 1.000000
# Validation Iter 4100, auc= 0.890527, fmeasure_max= 0.812057, precision= 0.840367, recall= 0.785592
# Validation Random guess:  auc= 0.227038, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.403000
# Tarin Iter 4200, auc= 0.977608, fmeasure_max= 0.919403, precision= 0.904552, recall= 0.934750
# Train Random guess:  , auc= 0.261038fmeasure_max= 0.409444, precision= 0.257422, recall= 1.000000
# Validation Iter 4200, auc= 0.926462, fmeasure_max= 0.838223, precision= 0.819672, recall= 0.857633
# Validation Random guess:  auc= 0.221328, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.433322
# Tarin Iter 4300, auc= 0.967357, fmeasure_max= 0.909579, precision= 0.918626, recall= 0.900709
# Train Random guess:  , auc= 0.225859fmeasure_max= 0.361477, precision= 0.220698, recall= 0.998227
# Validation Iter 4300, auc= 0.920718, fmeasure_max= 0.838969, precision= 0.790592, recall= 0.893654
# Validation Random guess:  auc= 0.225051, fmeasure_max= 0.372555, precision= 0.229101, recall= 0.996569
# Minibatch Loss= 0.399480
# Tarin Iter 4400, auc= 0.972992, fmeasure_max= 0.897710, precision= 0.868538, recall= 0.928910
# Train Random guess:  , auc= 0.250216fmeasure_max= 0.396990, precision= 0.247653, recall= 1.000000
# Validation Iter 4400, auc= 0.906856, fmeasure_max= 0.816251, precision= 0.884000, recall= 0.758148
# Validation Random guess:  auc= 0.217366, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.377127
# Tarin Iter 4500, auc= 0.951490, fmeasure_max= 0.867610, precision= 0.838969, recall= 0.898276
# Train Random guess:  , auc= 0.227727fmeasure_max= 0.374534, precision= 0.233038, recall= 0.953448
# Validation Iter 4500, auc= 0.919110, fmeasure_max= 0.836547, precision= 0.818033, recall= 0.855918
# Validation Random guess:  auc= 0.230520, fmeasure_max= 0.373057, precision= 0.229940, recall= 0.987993
# Minibatch Loss= 0.406277
# Tarin Iter 4600, auc= 0.964762, fmeasure_max= 0.907577, precision= 0.886179, recall= 0.930034
# Train Random guess:  , auc= 0.234510fmeasure_max= 0.376040, precision= 0.233568, recall= 0.964164
# Validation Iter 4600, auc= 0.917478, fmeasure_max= 0.832496, precision= 0.813421, recall= 0.852487
# Validation Random guess:  auc= 0.234363, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.393364
# Tarin Iter 4700, auc= 0.954611, fmeasure_max= 0.874363, precision= 0.924596, recall= 0.829308
# Train Random guess:  , auc= 0.248733fmeasure_max= 0.390812, precision= 0.242863, recall= 1.000000
# Validation Iter 4700, auc= 0.931214, fmeasure_max= 0.842009, precision= 0.900391, recall= 0.790738
# Validation Random guess:  auc= 0.231909, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.448409
# Tarin Iter 4800, auc= 0.963223, fmeasure_max= 0.906445, precision= 0.902692, recall= 0.910230
# Train Random guess:  , auc= 0.187930fmeasure_max= 0.317324, precision= 0.188583, recall= 1.000000
# Validation Iter 4800, auc= 0.935193, fmeasure_max= 0.853171, precision= 0.864437, recall= 0.842196
# Validation Random guess:  auc= 0.219456, fmeasure_max= 0.375762, precision= 0.234078, recall= 0.951973
# Minibatch Loss= 0.338536
# Tarin Iter 4900, auc= 0.943594, fmeasure_max= 0.884553, precision= 0.846034, recall= 0.926746
# Train Random guess:  , auc= 0.234617fmeasure_max= 0.374638, precision= 0.230952, recall= 0.991482
# Validation Iter 4900, auc= 0.923856, fmeasure_max= 0.838990, precision= 0.851590, recall= 0.826758
# Validation Random guess:  auc= 0.228627, fmeasure_max= 0.372619, precision= 0.229515, recall= 0.989708
# Minibatch Loss= 0.454990
# Tarin Iter 5000, auc= 0.965090, fmeasure_max= 0.901695, precision= 0.880795, recall= 0.923611
# Train Random guess:  , auc= 0.229363fmeasure_max= 0.368592, precision= 0.226656, recall= 0.986111
# Validation Iter 5000, auc= 0.927034, fmeasure_max= 0.863833, precision= 0.873684, recall= 0.854202
# Validation Random guess:  auc= 0.219530, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.404104
# Tarin Iter 5100, auc= 0.964331, fmeasure_max= 0.899166, precision= 0.890390, recall= 0.908116
# Train Random guess:  , auc= 0.265468fmeasure_max= 0.407687, precision= 0.256644, recall= 0.990812
# Validation Iter 5100, auc= 0.920421, fmeasure_max= 0.828231, precision= 0.821248, recall= 0.835334
# Validation Random guess:  auc= 0.212256, fmeasure_max= 0.373212, precision= 0.230245, recall= 0.984563
# Minibatch Loss= 0.446580
# Tarin Iter 5200, auc= 0.955710, fmeasure_max= 0.896808, precision= 0.912387, recall= 0.881752
# Train Random guess:  , auc= 0.271330fmeasure_max= 0.422614, precision= 0.268025, recall= 0.998540
# Validation Iter 5200, auc= 0.893554, fmeasure_max= 0.813206, precision= 0.823944, recall= 0.802744
# Validation Random guess:  auc= 0.234528, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.544166
# Tarin Iter 5300, auc= 0.961915, fmeasure_max= 0.889968, precision= 0.892857, recall= 0.887097
# Train Random guess:  , auc= 0.245029fmeasure_max= 0.390521, precision= 0.242829, recall= 0.996774
# Validation Iter 5300, auc= 0.932200, fmeasure_max= 0.861404, precision= 0.881508, recall= 0.842196
# Validation Random guess:  auc= 0.237870, fmeasure_max= 0.372523, precision= 0.230675, recall= 0.967410
# Minibatch Loss= 0.427293
# Tarin Iter 5400, auc= 0.973473, fmeasure_max= 0.907453, precision= 0.906710, recall= 0.908197
# Train Random guess:  , auc= 0.232854fmeasure_max= 0.385710, precision= 0.238935, recall= 1.000000
# Validation Iter 5400, auc= 0.922119, fmeasure_max= 0.837209, precision= 0.840830, recall= 0.833619
# Validation Random guess:  auc= 0.237741, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.363089
# Tarin Iter 5500, auc= 0.939320, fmeasure_max= 0.862245, precision= 0.811200, recall= 0.920145
# Train Random guess:  , auc= 0.224004fmeasure_max= 0.355323, precision= 0.216647, recall= 0.987296
# Validation Iter 5500, auc= 0.913611, fmeasure_max= 0.818580, precision= 0.836918, recall= 0.801029
# Validation Random guess:  auc= 0.245757, fmeasure_max= 0.376153, precision= 0.232776, recall= 0.979417
# Minibatch Loss= 0.399704
# Tarin Iter 5600, auc= 0.962892, fmeasure_max= 0.891844, precision= 0.891844, recall= 0.891844
# Train Random guess:  , auc= 0.225677fmeasure_max= 0.362989, precision= 0.222002, recall= 0.994681
# Validation Iter 5600, auc= 0.908094, fmeasure_max= 0.837413, precision= 0.853832, recall= 0.821612
# Validation Random guess:  auc= 0.220660, fmeasure_max= 0.371981, precision= 0.232829, recall= 0.924528
# Minibatch Loss= 0.388277
# Tarin Iter 5700, auc= 0.955832, fmeasure_max= 0.893855, precision= 0.877743, recall= 0.910569
# Train Random guess:  , auc= 0.240666fmeasure_max= 0.387749, precision= 0.240596, recall= 0.998374
# Validation Iter 5700, auc= 0.911353, fmeasure_max= 0.825252, precision= 0.884314, recall= 0.773585
# Validation Random guess:  auc= 0.227776, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.444069
# Tarin Iter 5800, auc= 0.945959, fmeasure_max= 0.879032, precision= 0.838462, recall= 0.923729
# Train Random guess:  , auc= 0.185854fmeasure_max= 0.312085, precision= 0.185039, recall= 0.995763
# Validation Iter 5800, auc= 0.907268, fmeasure_max= 0.835640, precision= 0.842932, recall= 0.828473
# Validation Random guess:  auc= 0.239548, fmeasure_max= 0.377079, precision= 0.240339, recall= 0.874786
# Minibatch Loss= 0.341257
# Tarin Iter 5900, auc= 0.966428, fmeasure_max= 0.902232, precision= 0.930159, recall= 0.875934
# Train Random guess:  , auc= 0.270233fmeasure_max= 0.414649, precision= 0.261653, recall= 0.998505
# Validation Iter 5900, auc= 0.920408, fmeasure_max= 0.846957, precision= 0.858907, recall= 0.835334
# Validation Random guess:  auc= 0.214199, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.434018
# Tarin Iter 6000, auc= 0.960434, fmeasure_max= 0.906542, precision= 0.913371, recall= 0.899814
# Train Random guess:  , auc= 0.214918fmeasure_max= 0.348356, precision= 0.213101, recall= 0.953618
# Validation Iter 6000, auc= 0.906755, fmeasure_max= 0.846561, precision= 0.871143, recall= 0.823328
# Validation Random guess:  auc= 0.234130, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.375682
# Tarin Iter 6100, auc= 0.978968, fmeasure_max= 0.921368, precision= 0.922945, recall= 0.919795
# Train Random guess:  , auc= 0.234602fmeasure_max= 0.376495, precision= 0.237145, recall= 0.912969
# Validation Iter 6100, auc= 0.911734, fmeasure_max= 0.834065, precision= 0.854317, recall= 0.814751
# Validation Random guess:  auc= 0.239617, fmeasure_max= 0.372779, precision= 0.231667, recall= 0.953688
# Minibatch Loss= 0.349963
# Tarin Iter 6200, auc= 0.945357, fmeasure_max= 0.858491, precision= 0.865019, recall= 0.852060
# Train Random guess:  , auc= 0.201843fmeasure_max= 0.345631, precision= 0.208920, recall= 1.000000
# Validation Iter 6200, auc= 0.912368, fmeasure_max= 0.839903, precision= 0.790909, recall= 0.895369
# Validation Random guess:  auc= 0.224334, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.404135
# Tarin Iter 6300, auc= 0.957837, fmeasure_max= 0.889971, precision= 0.889105, recall= 0.890838
# Train Random guess:  , auc= 0.202804fmeasure_max= 0.335370, precision= 0.203042, recall= 0.962963
# Validation Iter 6300, auc= 0.915082, fmeasure_max= 0.832882, precision= 0.879771, recall= 0.790738
# Validation Random guess:  auc= 0.220636, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.391605
# Tarin Iter 6400, auc= 0.953362, fmeasure_max= 0.896235, precision= 0.893773, recall= 0.898711
# Train Random guess:  , auc= 0.211117fmeasure_max= 0.350210, precision= 0.212275, recall= 1.000000
# Validation Iter 6400, auc= 0.929244, fmeasure_max= 0.855148, precision= 0.870337, recall= 0.840480
# Validation Random guess:  auc= 0.225315, fmeasure_max= 0.373945, precision= 0.232773, recall= 0.950257
# Minibatch Loss= 0.402467
# Tarin Iter 6500, auc= 0.974610, fmeasure_max= 0.913295, precision= 0.887640, recall= 0.940476
# Train Random guess:  , auc= 0.216503fmeasure_max= 0.373571, precision= 0.229687, recall= 1.000000
# Validation Iter 6500, auc= 0.936353, fmeasure_max= 0.855196, precision= 0.849408, recall= 0.861063
# Validation Random guess:  auc= 0.245148, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.370686
# Tarin Iter 6600, auc= 0.947337, fmeasure_max= 0.869489, precision= 0.851468, recall= 0.888288
# Train Random guess:  , auc= 0.227068fmeasure_max= 0.356569, precision= 0.216966, recall= 1.000000
# Validation Iter 6600, auc= 0.936181, fmeasure_max= 0.862745, precision= 0.857627, recall= 0.867925
# Validation Random guess:  auc= 0.238169, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.397178
# Tarin Iter 6700, auc= 0.970981, fmeasure_max= 0.905628, precision= 0.900172, recall= 0.911150
# Train Random guess:  , auc= 0.238281fmeasure_max= 0.366955, precision= 0.224794, recall= 0.998258
# Validation Iter 6700, auc= 0.908782, fmeasure_max= 0.830221, precision= 0.821849, recall= 0.838765
# Validation Random guess:  auc= 0.245205, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.384808
# Tarin Iter 6800, auc= 0.976153, fmeasure_max= 0.922475, precision= 0.914596, recall= 0.930490
# Train Random guess:  , auc= 0.248303fmeasure_max= 0.398734, precision= 0.249307, recall= 0.995261
# Validation Iter 6800, auc= 0.926561, fmeasure_max= 0.864392, precision= 0.882143, recall= 0.847341
# Validation Random guess:  auc= 0.224999, fmeasure_max= 0.374349, precision= 0.231016, recall= 0.986278
# Minibatch Loss= 0.380614
# Tarin Iter 6900, auc= 0.956355, fmeasure_max= 0.887737, precision= 0.880137, recall= 0.895470
# Train Random guess:  , auc= 0.227914fmeasure_max= 0.366422, precision= 0.224306, recall= 1.000000
# Validation Iter 6900, auc= 0.925977, fmeasure_max= 0.856655, precision= 0.852292, recall= 0.861063
# Validation Random guess:  auc= 0.226640, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.394042
# Tarin Iter 7000, auc= 0.965368, fmeasure_max= 0.903010, precision= 0.913706, recall= 0.892562
# Train Random guess:  , auc= 0.226227fmeasure_max= 0.382790, precision= 0.236698, recall= 1.000000
# Validation Iter 7000, auc= 0.925034, fmeasure_max= 0.852740, precision= 0.851282, recall= 0.854202
# Validation Random guess:  auc= 0.243130, fmeasure_max= 0.371254, precision= 0.228571, recall= 0.987993
# Minibatch Loss= 0.430811
# Tarin Iter 7100, auc= 0.943077, fmeasure_max= 0.866995, precision= 0.859935, recall= 0.874172
# Train Random guess:  , auc= 0.241094fmeasure_max= 0.382493, precision= 0.236563, recall= 0.998344
# Validation Iter 7100, auc= 0.911271, fmeasure_max= 0.826843, precision= 0.799679, recall= 0.855918
# Validation Random guess:  auc= 0.228242, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.460172
# Tarin Iter 7200, auc= 0.956035, fmeasure_max= 0.869037, precision= 0.850594, recall= 0.888298
# Train Random guess:  , auc= 0.223439fmeasure_max= 0.362230, precision= 0.221347, recall= 0.996454
# Validation Iter 7200, auc= 0.936928, fmeasure_max= 0.869718, precision= 0.893309, recall= 0.847341
# Validation Random guess:  auc= 0.223482, fmeasure_max= 0.372757, precision= 0.231150, recall= 0.962264
# Minibatch Loss= 0.371800
# Tarin Iter 7300, auc= 0.961152, fmeasure_max= 0.890566, precision= 0.866373, recall= 0.916149
# Train Random guess:  , auc= 0.257094fmeasure_max= 0.402378, precision= 0.251959, recall= 0.998447
# Validation Iter 7300, auc= 0.920217, fmeasure_max= 0.842011, precision= 0.883239, recall= 0.804460
# Validation Random guess:  auc= 0.224501, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.445730
# Tarin Iter 7400, auc= 0.966605, fmeasure_max= 0.892221, precision= 0.862319, recall= 0.924272
# Train Random guess:  , auc= 0.205393fmeasure_max= 0.335724, precision= 0.201723, recall= 1.000000
# Validation Iter 7400, auc= 0.928416, fmeasure_max= 0.848229, precision= 0.834163, recall= 0.862779
# Validation Random guess:  auc= 0.219429, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.367512
# Tarin Iter 7500, auc= 0.963320, fmeasure_max= 0.895775, precision= 0.896617, recall= 0.894934
# Train Random guess:  , auc= 0.195294fmeasure_max= 0.344649, precision= 0.208203, recall= 1.000000
# Validation Iter 7500, auc= 0.924832, fmeasure_max= 0.858407, precision= 0.886654, recall= 0.831904
# Validation Random guess:  auc= 0.231647, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.361950
# Tarin Iter 7600, auc= 0.959137, fmeasure_max= 0.882398, precision= 0.844118, recall= 0.924316
# Train Random guess:  , auc= 0.244713fmeasure_max= 0.390443, precision= 0.242578, recall= 1.000000
# Validation Iter 7600, auc= 0.935563, fmeasure_max= 0.856378, precision= 0.892193, recall= 0.823328
# Validation Random guess:  auc= 0.232940, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.419521
# Tarin Iter 7700, auc= 0.968211, fmeasure_max= 0.910558, precision= 0.907507, recall= 0.913630
# Train Random guess:  , auc= 0.293998fmeasure_max= 0.448955, precision= 0.289453, recall= 1.000000
# Validation Iter 7700, auc= 0.926751, fmeasure_max= 0.847670, precision= 0.887430, recall= 0.811321
# Validation Random guess:  auc= 0.234797, fmeasure_max= 0.371704, precision= 0.228730, recall= 0.991424
# Minibatch Loss= 0.461796
# Tarin Iter 7800, auc= 0.970164, fmeasure_max= 0.912397, precision= 0.923077, recall= 0.901961
# Train Random guess:  , auc= 0.260018fmeasure_max= 0.387701, precision= 0.243697, recall= 0.947712
# Validation Iter 7800, auc= 0.933995, fmeasure_max= 0.866551, precision= 0.875657, recall= 0.857633
# Validation Random guess:  auc= 0.234013, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.425777
# Tarin Iter 7900, auc= 0.959173, fmeasure_max= 0.885333, precision= 0.886121, recall= 0.884547
# Train Random guess:  , auc= 0.215924fmeasure_max= 0.360734, precision= 0.223016, recall= 0.943162
# Validation Iter 7900, auc= 0.926922, fmeasure_max= 0.845948, precision= 0.879630, recall= 0.814751
# Validation Random guess:  auc= 0.226737, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.426856
# Tarin Iter 8000, auc= 0.946597, fmeasure_max= 0.887651, precision= 0.903592, recall= 0.872263
# Train Random guess:  , auc= 0.216441fmeasure_max= 0.353401, precision= 0.215050, recall= 0.990876
# Validation Iter 8000, auc= 0.928213, fmeasure_max= 0.847791, precision= 0.810642, recall= 0.888508
# Validation Random guess:  auc= 0.240578, fmeasure_max= 0.372365, precision= 0.229600, recall= 0.984563
# Minibatch Loss= 0.404423
# Tarin Iter 8100, auc= 0.980732, fmeasure_max= 0.922504, precision= 0.919762, recall= 0.925262
# Train Random guess:  , auc= 0.270899fmeasure_max= 0.417511, precision= 0.267140, recall= 0.955157
# Validation Iter 8100, auc= 0.938263, fmeasure_max= 0.866264, precision= 0.871528, recall= 0.861063
# Validation Random guess:  auc= 0.222345, fmeasure_max= 0.371273, precision= 0.228312, recall= 0.993139
# Minibatch Loss= 0.357753
# Tarin Iter 8200, auc= 0.971628, fmeasure_max= 0.907502, precision= 0.861687, recall= 0.958462
# Train Random guess:  , auc= 0.266988fmeasure_max= 0.407178, precision= 0.258385, recall= 0.960000
# Validation Iter 8200, auc= 0.921124, fmeasure_max= 0.857399, precision= 0.898496, recall= 0.819897
# Validation Random guess:  auc= 0.240083, fmeasure_max= 0.371227, precision= 0.228368, recall= 0.991424
# Minibatch Loss= 0.410850
# Tarin Iter 8300, auc= 0.961406, fmeasure_max= 0.893222, precision= 0.858929, recall= 0.930368
# Train Random guess:  , auc= 0.200130fmeasure_max= 0.338113, precision= 0.204271, recall= 0.980658
# Validation Iter 8300, auc= 0.922267, fmeasure_max= 0.858844, precision= 0.851602, recall= 0.866209
# Validation Random guess:  auc= 0.229748, fmeasure_max= 0.372881, precision= 0.229167, recall= 1.000000
# Minibatch Loss= 0.359594
# Tarin Iter 8400, auc= 0.974067, fmeasure_max= 0.910739, precision= 0.892077, recall= 0.930199
# Train Random guess:  , auc= 0.280757fmeasure_max= 0.431373, precision= 0.279898, recall= 0.940171
# Validation Iter 8400, auc= 0.944002, fmeasure_max= 0.873288, precision= 0.871795, recall= 0.874786
# Validation Random guess:  auc= 0.245176, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.459465
# Tarin Iter 8500, auc= 0.952090, fmeasure_max= 0.882649, precision= 0.878223, recall= 0.887120
# Train Random guess:  , auc= 0.262819fmeasure_max= 0.425755, precision= 0.270450, recall= 1.000000
# Validation Iter 8500, auc= 0.938663, fmeasure_max= 0.878762, precision= 0.881034, recall= 0.876501
# Validation Random guess:  auc= 0.231131, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.464718
# Tarin Iter 8600, auc= 0.960092, fmeasure_max= 0.905518, precision= 0.879589, recall= 0.933022
# Train Random guess:  , auc= 0.238019fmeasure_max= 0.402010, precision= 0.251770, recall= 0.996885
# Validation Iter 8600, auc= 0.939369, fmeasure_max= 0.867958, precision= 0.891501, recall= 0.845626
# Validation Random guess:  auc= 0.231392, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.434439
# Tarin Iter 8700, auc= 0.963349, fmeasure_max= 0.895296, precision= 0.875371, recall= 0.916149
# Train Random guess:  , auc= 0.249674fmeasure_max= 0.402266, precision= 0.252270, recall= 0.992236
# Validation Iter 8700, auc= 0.930776, fmeasure_max= 0.874676, precision= 0.881533, recall= 0.867925
# Validation Random guess:  auc= 0.233877, fmeasure_max= 0.376841, precision= 0.234096, recall= 0.965695
# Minibatch Loss= 0.405586
# Tarin Iter 8800, auc= 0.956581, fmeasure_max= 0.892532, precision= 0.894161, recall= 0.890909
# Train Random guess:  , auc= 0.220994fmeasure_max= 0.353698, precision= 0.214844, recall= 1.000000
# Validation Iter 8800, auc= 0.901843, fmeasure_max= 0.830850, precision= 0.849462, recall= 0.813036
# Validation Random guess:  auc= 0.227779, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.383399
# Tarin Iter 8900, auc= 0.975378, fmeasure_max= 0.916885, precision= 0.914485, recall= 0.919298
# Train Random guess:  , auc= 0.229230fmeasure_max= 0.364334, precision= 0.222743, recall= 1.000000
# Validation Iter 8900, auc= 0.912926, fmeasure_max= 0.841652, precision= 0.844560, recall= 0.838765
# Validation Random guess:  auc= 0.223025, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.385493
# Tarin Iter 9000, auc= 0.973569, fmeasure_max= 0.914286, precision= 0.882562, recall= 0.948375
# Train Random guess:  , auc= 0.201786fmeasure_max= 0.339536, precision= 0.204724, recall= 0.994264
# Validation Iter 9000, auc= 0.929662, fmeasure_max= 0.858156, precision= 0.888073, recall= 0.830189
# Validation Random guess:  auc= 0.233130, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.313170
# Tarin Iter 9100, auc= 0.979010, fmeasure_max= 0.925771, precision= 0.934343, recall= 0.917355
# Train Random guess:  , auc= 0.229284fmeasure_max= 0.382669, precision= 0.236605, recall= 1.000000
# Validation Iter 9100, auc= 0.932015, fmeasure_max= 0.863359, precision= 0.876325, recall= 0.850772
# Validation Random guess:  auc= 0.236100, fmeasure_max= 0.372826, precision= 0.230519, recall= 0.974271
# Minibatch Loss= 0.371738
# Tarin Iter 9200, auc= 0.980675, fmeasure_max= 0.918249, precision= 0.914474, recall= 0.922056
# Train Random guess:  , auc= 0.249742fmeasure_max= 0.381655, precision= 0.236581, recall= 0.986733
# Validation Iter 9200, auc= 0.914335, fmeasure_max= 0.843911, precision= 0.843911, recall= 0.843911
# Validation Random guess:  auc= 0.244797, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.362204
# Tarin Iter 9300, auc= 0.961985, fmeasure_max= 0.894684, precision= 0.859345, recall= 0.933054
# Train Random guess:  , auc= 0.183520fmeasure_max= 0.315303, precision= 0.187157, recall= 1.000000
# Validation Iter 9300, auc= 0.929046, fmeasure_max= 0.858407, precision= 0.886654, recall= 0.831904
# Validation Random guess:  auc= 0.223940, fmeasure_max= 0.371336, precision= 0.229192, recall= 0.977702
# Minibatch Loss= 0.340637
# Tarin Iter 9400, auc= 0.953664, fmeasure_max= 0.876018, precision= 0.862745, recall= 0.889706
# Train Random guess:  , auc= 0.218134fmeasure_max= 0.351081, precision= 0.212916, recall= 1.000000
# Validation Iter 9400, auc= 0.915394, fmeasure_max= 0.860251, precision= 0.839869, recall= 0.881647
# Validation Random guess:  auc= 0.230994, fmeasure_max= 0.372047, precision= 0.230801, recall= 0.958834
# Minibatch Loss= 0.386476
# Tarin Iter 9500, auc= 0.974680, fmeasure_max= 0.931655, precision= 0.913580, recall= 0.950459
# Train Random guess:  , auc= 0.213648fmeasure_max= 0.351535, precision= 0.213333, recall= 0.998165
# Validation Iter 9500, auc= 0.924798, fmeasure_max= 0.852143, precision= 0.869643, recall= 0.835334
# Validation Random guess:  auc= 0.233336, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.314709
# Tarin Iter 9600, auc= 0.967222, fmeasure_max= 0.912705, precision= 0.904110, recall= 0.921466
# Train Random guess:  , auc= 0.224892fmeasure_max= 0.366288, precision= 0.224920, recall= 0.986038
# Validation Iter 9600, auc= 0.933098, fmeasure_max= 0.868619, precision= 0.848039, recall= 0.890223
# Validation Random guess:  auc= 0.228683, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.376580
# Tarin Iter 9700, auc= 0.974712, fmeasure_max= 0.919403, precision= 0.933333, recall= 0.905882
# Train Random guess:  , auc= 0.212691fmeasure_max= 0.337634, precision= 0.206579, recall= 0.923529
# Validation Iter 9700, auc= 0.931264, fmeasure_max= 0.868056, precision= 0.878735, recall= 0.857633
# Validation Random guess:  auc= 0.221722, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.320803
# Tarin Iter 9800, auc= 0.947081, fmeasure_max= 0.877660, precision= 0.895118, recall= 0.860870
# Train Random guess:  , auc= 0.238971fmeasure_max= 0.367412, precision= 0.225049, recall= 1.000000
# Validation Iter 9800, auc= 0.909323, fmeasure_max= 0.836717, precision= 0.861818, recall= 0.813036
# Validation Random guess:  auc= 0.231962, fmeasure_max= 0.371325, precision= 0.229951, recall= 0.963979
# Minibatch Loss= 0.430138
# Tarin Iter 9900, auc= 0.980030, fmeasure_max= 0.932379, precision= 0.934609, recall= 0.930159
# Train Random guess:  , auc= 0.237001fmeasure_max= 0.395108, precision= 0.246190, recall= 1.000000
# Validation Iter 9900, auc= 0.930493, fmeasure_max= 0.860307, precision= 0.854484, recall= 0.866209
# Validation Random guess:  auc= 0.216252, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.402186
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.922560 F1_max = 0.843106 prec = 0.847059 rec = 0.839189
# Test Random guess: auc= 0.230807 fmeasure_max= 0.375738 , precision= 0.231337 , recall= 0.999831

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
