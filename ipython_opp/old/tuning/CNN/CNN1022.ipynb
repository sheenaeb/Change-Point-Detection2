# %%
# useing this variable for saving models and summaries
exp_name = "CNN1022"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [4, 2, 2, 2, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [9, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.218566, fmeasure_max= 0.361766, precision= 0.220916, recall= 0.998168
# Train Random guess:  , auc= 0.215968fmeasure_max= 0.352485, precision= 0.213950, recall= 1.000000
# Validation Iter 0, auc= 0.208844, fmeasure_max= 0.374476, precision= 0.230556, recall= 0.996569
# Validation Random guess:  auc= 0.228728, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 1.027426
# Tarin Iter 100, auc= 0.685588, fmeasure_max= 0.687273, precision= 0.703911, recall= 0.671403
# Train Random guess:  , auc= 0.231800fmeasure_max= 0.364682, precision= 0.225240, recall= 0.957371
# Validation Iter 100, auc= 0.720643, fmeasure_max= 0.734266, precision= 0.748663, recall= 0.720412
# Validation Random guess:  auc= 0.237062, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.791628
# Tarin Iter 200, auc= 0.732984, fmeasure_max= 0.695320, precision= 0.715128, recall= 0.676580
# Train Random guess:  , auc= 0.218890fmeasure_max= 0.347433, precision= 0.210238, recall= 1.000000
# Validation Iter 200, auc= 0.741453, fmeasure_max= 0.691379, precision= 0.694974, recall= 0.687822
# Validation Random guess:  auc= 0.229286, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.773705
# Tarin Iter 300, auc= 0.842566, fmeasure_max= 0.756573, precision= 0.819853, recall= 0.702362
# Train Random guess:  , auc= 0.240064fmeasure_max= 0.397621, precision= 0.248144, recall= 1.000000
# Validation Iter 300, auc= 0.830593, fmeasure_max= 0.781850, precision= 0.795737, recall= 0.768439
# Validation Random guess:  auc= 0.232984, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.664304
# Tarin Iter 400, auc= 0.821141, fmeasure_max= 0.765090, precision= 0.743265, recall= 0.788235
# Train Random guess:  , auc= 0.223859fmeasure_max= 0.378585, precision= 0.233582, recall= 0.998319
# Validation Iter 400, auc= 0.854252, fmeasure_max= 0.783831, precision= 0.803604, recall= 0.765009
# Validation Random guess:  auc= 0.231937, fmeasure_max= 0.373016, precision= 0.231053, recall= 0.967410
# Minibatch Loss= 0.641211
# Tarin Iter 500, auc= 0.823382, fmeasure_max= 0.760171, precision= 0.853365, recall= 0.685328
# Train Random guess:  , auc= 0.206242fmeasure_max= 0.338158, precision= 0.203807, recall= 0.992278
# Validation Iter 500, auc= 0.903844, fmeasure_max= 0.824468, precision= 0.853211, recall= 0.797599
# Validation Random guess:  auc= 0.233574, fmeasure_max= 0.372695, precision= 0.229665, recall= 0.987993
# Minibatch Loss= 0.598033
# Tarin Iter 600, auc= 0.881265, fmeasure_max= 0.820276, precision= 0.842271, recall= 0.799401
# Train Random guess:  , auc= 0.260037fmeasure_max= 0.415023, precision= 0.262366, recall= 0.992515
# Validation Iter 600, auc= 0.863219, fmeasure_max= 0.803540, precision= 0.829982, recall= 0.778731
# Validation Random guess:  auc= 0.224886, fmeasure_max= 0.372608, precision= 0.231636, recall= 0.951973
# Minibatch Loss= 0.621786
# Tarin Iter 700, auc= 0.907939, fmeasure_max= 0.840604, precision= 0.837793, recall= 0.843434
# Train Random guess:  , auc= 0.238073fmeasure_max= 0.377467, precision= 0.232732, recall= 0.998316
# Validation Iter 700, auc= 0.868776, fmeasure_max= 0.791912, precision= 0.778146, recall= 0.806175
# Validation Random guess:  auc= 0.236341, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.578921
# Tarin Iter 800, auc= 0.862821, fmeasure_max= 0.823718, precision= 0.833063, recall= 0.814580
# Train Random guess:  , auc= 0.245400fmeasure_max= 0.395971, precision= 0.247054, recall= 0.996830
# Validation Iter 800, auc= 0.884211, fmeasure_max= 0.806874, precision= 0.771518, recall= 0.845626
# Validation Random guess:  auc= 0.238069, fmeasure_max= 0.371300, precision= 0.228515, recall= 0.989708
# Minibatch Loss= 0.633029
# Tarin Iter 900, auc= 0.945899, fmeasure_max= 0.877651, precision= 0.845912, recall= 0.911864
# Train Random guess:  , auc= 0.231491fmeasure_max= 0.374841, precision= 0.230649, recall= 1.000000
# Validation Iter 900, auc= 0.896145, fmeasure_max= 0.827526, precision= 0.840708, recall= 0.814751
# Validation Random guess:  auc= 0.232359, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.466043
# Tarin Iter 1000, auc= 0.832050, fmeasure_max= 0.781986, precision= 0.882217, recall= 0.702206
# Train Random guess:  , auc= 0.212602fmeasure_max= 0.350809, precision= 0.212883, recall= 0.996324
# Validation Iter 1000, auc= 0.911206, fmeasure_max= 0.833743, precision= 0.797806, recall= 0.873070
# Validation Random guess:  auc= 0.223867, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.633150
# Tarin Iter 1100, auc= 0.875950, fmeasure_max= 0.810770, precision= 0.835131, recall= 0.787791
# Train Random guess:  , auc= 0.259995fmeasure_max= 0.424822, precision= 0.269698, recall= 1.000000
# Validation Iter 1100, auc= 0.896619, fmeasure_max= 0.824957, precision= 0.833625, recall= 0.816467
# Validation Random guess:  auc= 0.220769, fmeasure_max= 0.371676, precision= 0.228526, recall= 0.994854
# Minibatch Loss= 0.696615
# Tarin Iter 1200, auc= 0.904282, fmeasure_max= 0.826016, precision= 0.835526, recall= 0.816720
# Train Random guess:  , auc= 0.251720fmeasure_max= 0.391883, precision= 0.244076, recall= 0.993569
# Validation Iter 1200, auc= 0.906304, fmeasure_max= 0.832168, precision= 0.848485, recall= 0.816467
# Validation Random guess:  auc= 0.225790, fmeasure_max= 0.372238, precision= 0.233031, recall= 0.924528
# Minibatch Loss= 0.592039
# Tarin Iter 1300, auc= 0.898368, fmeasure_max= 0.848430, precision= 0.879182, recall= 0.819757
# Train Random guess:  , auc= 0.235149fmeasure_max= 0.371752, precision= 0.230103, recall= 0.967071
# Validation Iter 1300, auc= 0.922235, fmeasure_max= 0.848014, precision= 0.853913, recall= 0.842196
# Validation Random guess:  auc= 0.237306, fmeasure_max= 0.372675, precision= 0.229191, recall= 0.996569
# Minibatch Loss= 0.587764
# Tarin Iter 1400, auc= 0.921456, fmeasure_max= 0.866255, precision= 0.864476, recall= 0.868041
# Train Random guess:  , auc= 0.193477fmeasure_max= 0.320767, precision= 0.191020, recall= 1.000000
# Validation Iter 1400, auc= 0.879337, fmeasure_max= 0.819643, precision= 0.854749, recall= 0.787307
# Validation Random guess:  auc= 0.238582, fmeasure_max= 0.374318, precision= 0.230253, recall= 1.000000
# Minibatch Loss= 0.463078
# Tarin Iter 1500, auc= 0.924690, fmeasure_max= 0.867083, precision= 0.922201, recall= 0.818182
# Train Random guess:  , auc= 0.237158fmeasure_max= 0.376665, precision= 0.232031, recall= 1.000000
# Validation Iter 1500, auc= 0.919301, fmeasure_max= 0.837723, precision= 0.829966, recall= 0.845626
# Validation Random guess:  auc= 0.228868, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.497719
# Tarin Iter 1600, auc= 0.870033, fmeasure_max= 0.803456, precision= 0.889952, recall= 0.732283
# Train Random guess:  , auc= 0.199881fmeasure_max= 0.332892, precision= 0.200080, recall= 0.990157
# Validation Iter 1600, auc= 0.904637, fmeasure_max= 0.821894, precision= 0.832746, recall= 0.811321
# Validation Random guess:  auc= 0.225890, fmeasure_max= 0.372549, precision= 0.230117, recall= 0.977702
# Minibatch Loss= 0.551929
# Tarin Iter 1700, auc= 0.932512, fmeasure_max= 0.859389, precision= 0.866197, recall= 0.852686
# Train Random guess:  , auc= 0.234915fmeasure_max= 0.369431, precision= 0.227382, recall= 0.984402
# Validation Iter 1700, auc= 0.920584, fmeasure_max= 0.853333, precision= 0.885609, recall= 0.823328
# Validation Random guess:  auc= 0.251714, fmeasure_max= 0.374171, precision= 0.234882, recall= 0.919383
# Minibatch Loss= 0.477332
# Tarin Iter 1800, auc= 0.883049, fmeasure_max= 0.835381, precision= 0.834697, recall= 0.836066
# Train Random guess:  , auc= 0.251354fmeasure_max= 0.386576, precision= 0.240659, recall= 0.981967
# Validation Iter 1800, auc= 0.911933, fmeasure_max= 0.846290, precision= 0.872495, recall= 0.821612
# Validation Random guess:  auc= 0.217112, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.624052
# Tarin Iter 1900, auc= 0.948665, fmeasure_max= 0.896289, precision= 0.888679, recall= 0.904031
# Train Random guess:  , auc= 0.208263fmeasure_max= 0.340879, precision= 0.206202, recall= 0.982726
# Validation Iter 1900, auc= 0.906709, fmeasure_max= 0.844021, precision= 0.852890, recall= 0.835334
# Validation Random guess:  auc= 0.228452, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.450942
# Tarin Iter 2000, auc= 0.943459, fmeasure_max= 0.877531, precision= 0.892157, recall= 0.863378
# Train Random guess:  , auc= 0.210548fmeasure_max= 0.341432, precision= 0.205859, recall= 1.000000
# Validation Iter 2000, auc= 0.919636, fmeasure_max= 0.847660, precision= 0.841216, recall= 0.854202
# Validation Random guess:  auc= 0.219600, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.477483
# Tarin Iter 2100, auc= 0.943107, fmeasure_max= 0.864516, precision= 0.832298, recall= 0.899329
# Train Random guess:  , auc= 0.242239fmeasure_max= 0.377933, precision= 0.232995, recall= 1.000000
# Validation Iter 2100, auc= 0.912979, fmeasure_max= 0.840655, precision= 0.844291, recall= 0.837050
# Validation Random guess:  auc= 0.223225, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.490794
# Tarin Iter 2200, auc= 0.911729, fmeasure_max= 0.830904, precision= 0.845697, recall= 0.816619
# Train Random guess:  , auc= 0.271941fmeasure_max= 0.429010, precision= 0.273083, recall= 1.000000
# Validation Iter 2200, auc= 0.874705, fmeasure_max= 0.817857, precision= 0.852886, recall= 0.785592
# Validation Random guess:  auc= 0.227483, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.670844
# Tarin Iter 2300, auc= 0.944028, fmeasure_max= 0.866029, precision= 0.845794, recall= 0.887255
# Train Random guess:  , auc= 0.245326fmeasure_max= 0.387973, precision= 0.241838, recall= 0.980392
# Validation Iter 2300, auc= 0.920460, fmeasure_max= 0.863002, precision= 0.827044, recall= 0.902230
# Validation Random guess:  auc= 0.209689, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.499227
# Tarin Iter 2400, auc= 0.945782, fmeasure_max= 0.874881, precision= 0.894531, recall= 0.856075
# Train Random guess:  , auc= 0.217864fmeasure_max= 0.345942, precision= 0.209148, recall= 1.000000
# Validation Iter 2400, auc= 0.925852, fmeasure_max= 0.855918, precision= 0.855918, recall= 0.855918
# Validation Random guess:  auc= 0.227033, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.421582
# Tarin Iter 2500, auc= 0.949832, fmeasure_max= 0.877276, precision= 0.894992, recall= 0.860248
# Train Random guess:  , auc= 0.270770fmeasure_max= 0.402500, precision= 0.251956, recall= 1.000000
# Validation Iter 2500, auc= 0.920800, fmeasure_max= 0.849339, precision= 0.873188, recall= 0.826758
# Validation Random guess:  auc= 0.229021, fmeasure_max= 0.371227, precision= 0.228368, recall= 0.991424
# Minibatch Loss= 0.512413
# Tarin Iter 2600, auc= 0.896568, fmeasure_max= 0.820614, precision= 0.855372, recall= 0.788571
# Train Random guess:  , auc= 0.209645fmeasure_max= 0.341352, precision= 0.205802, recall= 1.000000
# Validation Iter 2600, auc= 0.926285, fmeasure_max= 0.852459, precision= 0.816327, recall= 0.891938
# Validation Random guess:  auc= 0.229102, fmeasure_max= 0.372663, precision= 0.229456, recall= 0.991424
# Minibatch Loss= 0.510882
# Tarin Iter 2700, auc= 0.917721, fmeasure_max= 0.845669, precision= 0.857827, recall= 0.833851
# Train Random guess:  , auc= 0.260585fmeasure_max= 0.403919, precision= 0.253571, recall= 0.992236
# Validation Iter 2700, auc= 0.905443, fmeasure_max= 0.840909, precision= 0.798151, recall= 0.888508
# Validation Random guess:  auc= 0.227074, fmeasure_max= 0.373952, precision= 0.230250, recall= 0.994854
# Minibatch Loss= 0.564528
# Tarin Iter 2800, auc= 0.929216, fmeasure_max= 0.863684, precision= 0.918142, recall= 0.815324
# Train Random guess:  , auc= 0.194274fmeasure_max= 0.333221, precision= 0.201056, recall= 0.972495
# Validation Iter 2800, auc= 0.934142, fmeasure_max= 0.869048, precision= 0.861720, recall= 0.876501
# Validation Random guess:  auc= 0.228305, fmeasure_max= 0.372213, precision= 0.229299, recall= 0.987993
# Minibatch Loss= 0.465935
# Tarin Iter 2900, auc= 0.905853, fmeasure_max= 0.818349, precision= 0.864341, recall= 0.777003
# Train Random guess:  , auc= 0.235948fmeasure_max= 0.374179, precision= 0.236624, recall= 0.893728
# Validation Iter 2900, auc= 0.912434, fmeasure_max= 0.839486, precision= 0.788839, recall= 0.897084
# Validation Random guess:  auc= 0.219190, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.513990
# Tarin Iter 3000, auc= 0.921700, fmeasure_max= 0.843979, precision= 0.844864, recall= 0.843096
# Train Random guess:  , auc= 0.173010fmeasure_max= 0.314851, precision= 0.186912, recall= 0.997908
# Validation Iter 3000, auc= 0.918415, fmeasure_max= 0.858306, precision= 0.817054, recall= 0.903945
# Validation Random guess:  auc= 0.219918, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.442096
# Tarin Iter 3100, auc= 0.943677, fmeasure_max= 0.853974, precision= 0.898833, recall= 0.813380
# Train Random guess:  , auc= 0.222959fmeasure_max= 0.364935, precision= 0.223726, recall= 0.989437
# Validation Iter 3100, auc= 0.915658, fmeasure_max= 0.858080, precision= 0.822327, recall= 0.897084
# Validation Random guess:  auc= 0.215501, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.453046
# Tarin Iter 3200, auc= 0.922800, fmeasure_max= 0.858513, precision= 0.893511, recall= 0.826154
# Train Random guess:  , auc= 0.260907fmeasure_max= 0.405498, precision= 0.254410, recall= 0.998462
# Validation Iter 3200, auc= 0.931815, fmeasure_max= 0.856887, precision= 0.895327, recall= 0.821612
# Validation Random guess:  auc= 0.226923, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.550807
# Tarin Iter 3300, auc= 0.962089, fmeasure_max= 0.893773, precision= 0.902367, recall= 0.885341
# Train Random guess:  , auc= 0.277089fmeasure_max= 0.425177, precision= 0.269984, recall= 1.000000
# Validation Iter 3300, auc= 0.905786, fmeasure_max= 0.842960, precision= 0.889524, recall= 0.801029
# Validation Random guess:  auc= 0.216982, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.505766
# Tarin Iter 3400, auc= 0.944499, fmeasure_max= 0.874598, precision= 0.890344, recall= 0.859400
# Train Random guess:  , auc= 0.261167fmeasure_max= 0.396741, precision= 0.247459, recall= 1.000000
# Validation Iter 3400, auc= 0.918222, fmeasure_max= 0.850289, precision= 0.821086, recall= 0.881647
# Validation Random guess:  auc= 0.228717, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.528451
# Tarin Iter 3500, auc= 0.889157, fmeasure_max= 0.801438, precision= 0.783831, recall= 0.819853
# Train Random guess:  , auc= 0.212431fmeasure_max= 0.350741, precision= 0.212666, recall= 1.000000
# Validation Iter 3500, auc= 0.917326, fmeasure_max= 0.853204, precision= 0.809231, recall= 0.902230
# Validation Random guess:  auc= 0.227434, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.546701
# Tarin Iter 3600, auc= 0.939474, fmeasure_max= 0.865672, precision= 0.876890, recall= 0.854737
# Train Random guess:  , auc= 0.183159fmeasure_max= 0.318614, precision= 0.189955, recall= 0.987368
# Validation Iter 3600, auc= 0.914428, fmeasure_max= 0.854772, precision= 0.827974, recall= 0.883362
# Validation Random guess:  auc= 0.222281, fmeasure_max= 0.373584, precision= 0.230247, recall= 0.989708
# Minibatch Loss= 0.390188
# Tarin Iter 3700, auc= 0.908963, fmeasure_max= 0.821656, precision= 0.834951, recall= 0.808777
# Train Random guess:  , auc= 0.239268fmeasure_max= 0.399124, precision= 0.249316, recall= 1.000000
# Validation Iter 3700, auc= 0.901686, fmeasure_max= 0.840070, precision= 0.861261, recall= 0.819897
# Validation Random guess:  auc= 0.239040, fmeasure_max= 0.372001, precision= 0.230081, recall= 0.970840
# Minibatch Loss= 0.611596
# Tarin Iter 3800, auc= 0.962281, fmeasure_max= 0.902857, precision= 0.881978, recall= 0.924749
# Train Random guess:  , auc= 0.243861fmeasure_max= 0.379530, precision= 0.234301, recall= 0.998328
# Validation Iter 3800, auc= 0.885415, fmeasure_max= 0.815884, precision= 0.860952, recall= 0.775300
# Validation Random guess:  auc= 0.225832, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.423894
# Tarin Iter 3900, auc= 0.942672, fmeasure_max= 0.876385, precision= 0.850993, recall= 0.903339
# Train Random guess:  , auc= 0.225627fmeasure_max= 0.365679, precision= 0.226774, recall= 0.943761
# Validation Iter 3900, auc= 0.898214, fmeasure_max= 0.844555, precision= 0.819355, recall= 0.871355
# Validation Random guess:  auc= 0.230933, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.444027
# Tarin Iter 4000, auc= 0.947354, fmeasure_max= 0.884553, precision= 0.902156, recall= 0.867624
# Train Random guess:  , auc= 0.241000fmeasure_max= 0.394571, precision= 0.245966, recall= 0.996810
# Validation Iter 4000, auc= 0.912052, fmeasure_max= 0.858529, precision= 0.811927, recall= 0.910806
# Validation Random guess:  auc= 0.228509, fmeasure_max= 0.371716, precision= 0.229200, recall= 0.982847
# Minibatch Loss= 0.445641
# Tarin Iter 4100, auc= 0.915120, fmeasure_max= 0.849953, precision= 0.882012, recall= 0.820144
# Train Random guess:  , auc= 0.207495fmeasure_max= 0.357607, precision= 0.218254, recall= 0.989209
# Validation Iter 4100, auc= 0.911982, fmeasure_max= 0.854369, precision= 0.808576, recall= 0.905660
# Validation Random guess:  auc= 0.236113, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.473299
# Tarin Iter 4200, auc= 0.958277, fmeasure_max= 0.904605, precision= 0.885668, recall= 0.924370
# Train Random guess:  , auc= 0.227406fmeasure_max= 0.378431, precision= 0.234213, recall= 0.984874
# Validation Iter 4200, auc= 0.902865, fmeasure_max= 0.826825, precision= 0.818487, recall= 0.835334
# Validation Random guess:  auc= 0.220720, fmeasure_max= 0.373575, precision= 0.232180, recall= 0.955403
# Minibatch Loss= 0.438339
# Tarin Iter 4300, auc= 0.946351, fmeasure_max= 0.869852, precision= 0.855754, recall= 0.884422
# Train Random guess:  , auc= 0.229129fmeasure_max= 0.378927, precision= 0.233751, recall= 1.000000
# Validation Iter 4300, auc= 0.921277, fmeasure_max= 0.861461, precision= 0.843750, recall= 0.879931
# Validation Random guess:  auc= 0.241052, fmeasure_max= 0.372771, precision= 0.229816, recall= 0.986278
# Minibatch Loss= 0.472267
# Tarin Iter 4400, auc= 0.959559, fmeasure_max= 0.897248, precision= 0.895604, recall= 0.898897
# Train Random guess:  , auc= 0.212904fmeasure_max= 0.353019, precision= 0.215119, recall= 0.983456
# Validation Iter 4400, auc= 0.913542, fmeasure_max= 0.846284, precision= 0.833611, recall= 0.859348
# Validation Random guess:  auc= 0.241161, fmeasure_max= 0.372651, precision= 0.229724, recall= 0.986278
# Minibatch Loss= 0.426349
# Tarin Iter 4500, auc= 0.939895, fmeasure_max= 0.859375, precision= 0.856401, recall= 0.862369
# Train Random guess:  , auc= 0.242392fmeasure_max= 0.366305, precision= 0.224219, recall= 1.000000
# Validation Iter 4500, auc= 0.907481, fmeasure_max= 0.855172, precision= 0.859619, recall= 0.850772
# Validation Random guess:  auc= 0.235330, fmeasure_max= 0.371281, precision= 0.228776, recall= 0.984563
# Minibatch Loss= 0.447095
# Tarin Iter 4600, auc= 0.941296, fmeasure_max= 0.857143, precision= 0.843750, recall= 0.870968
# Train Random guess:  , auc= 0.194805fmeasure_max= 0.342208, precision= 0.206424, recall= 1.000000
# Validation Iter 4600, auc= 0.909695, fmeasure_max= 0.837607, precision= 0.834753, recall= 0.840480
# Validation Random guess:  auc= 0.232689, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.402523
# Tarin Iter 4700, auc= 0.933776, fmeasure_max= 0.864048, precision= 0.875510, recall= 0.852883
# Train Random guess:  , auc= 0.203741fmeasure_max= 0.330342, precision= 0.198324, recall= 0.988072
# Validation Iter 4700, auc= 0.915298, fmeasure_max= 0.845754, precision= 0.854641, recall= 0.837050
# Validation Random guess:  auc= 0.212679, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.423083
# Tarin Iter 4800, auc= 0.948298, fmeasure_max= 0.885525, precision= 0.886364, recall= 0.884688
# Train Random guess:  , auc= 0.208635fmeasure_max= 0.342728, precision= 0.206802, recall= 1.000000
# Validation Iter 4800, auc= 0.924889, fmeasure_max= 0.846816, precision= 0.849741, recall= 0.843911
# Validation Random guess:  auc= 0.217477, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.430878
# Tarin Iter 4900, auc= 0.961395, fmeasure_max= 0.918745, precision= 0.907790, recall= 0.929967
# Train Random guess:  , auc= 0.232275fmeasure_max= 0.388022, precision= 0.241188, recall= 0.991857
# Validation Iter 4900, auc= 0.910385, fmeasure_max= 0.842017, precision= 0.825371, recall= 0.859348
# Validation Random guess:  auc= 0.213494, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.431655
# Tarin Iter 5000, auc= 0.963647, fmeasure_max= 0.893220, precision= 0.916522, recall= 0.871074
# Train Random guess:  , auc= 0.230846fmeasure_max= 0.385542, precision= 0.240065, recall= 0.978512
# Validation Iter 5000, auc= 0.912363, fmeasure_max= 0.847958, precision= 0.859155, recall= 0.837050
# Validation Random guess:  auc= 0.247203, fmeasure_max= 0.374081, precision= 0.232269, recall= 0.960549
# Minibatch Loss= 0.464778
# Tarin Iter 5100, auc= 0.960813, fmeasure_max= 0.898119, precision= 0.906646, recall= 0.889752
# Train Random guess:  , auc= 0.239042fmeasure_max= 0.402500, precision= 0.251956, recall= 1.000000
# Validation Iter 5100, auc= 0.922698, fmeasure_max= 0.860034, precision= 0.845771, recall= 0.874786
# Validation Random guess:  auc= 0.228980, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.444642
# Tarin Iter 5200, auc= 0.954681, fmeasure_max= 0.883319, precision= 0.855946, recall= 0.912500
# Train Random guess:  , auc= 0.224806fmeasure_max= 0.360064, precision= 0.219646, recall= 0.998214
# Validation Iter 5200, auc= 0.913054, fmeasure_max= 0.830901, precision= 0.831615, recall= 0.830189
# Validation Random guess:  auc= 0.237826, fmeasure_max= 0.375168, precision= 0.233208, recall= 0.958834
# Minibatch Loss= 0.381809
# Tarin Iter 5300, auc= 0.951206, fmeasure_max= 0.867372, precision= 0.900338, recall= 0.836735
# Train Random guess:  , auc= 0.253366fmeasure_max= 0.399621, precision= 0.250099, recall= 0.993721
# Validation Iter 5300, auc= 0.927598, fmeasure_max= 0.855472, precision= 0.833876, recall= 0.878216
# Validation Random guess:  auc= 0.228069, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.497196
# Tarin Iter 5400, auc= 0.939750, fmeasure_max= 0.859983, precision= 0.888699, recall= 0.833066
# Train Random guess:  , auc= 0.245299fmeasure_max= 0.393038, precision= 0.244777, recall= 0.996790
# Validation Iter 5400, auc= 0.927034, fmeasure_max= 0.857603, precision= 0.807576, recall= 0.914237
# Validation Random guess:  auc= 0.228519, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.495601
# Tarin Iter 5500, auc= 0.936932, fmeasure_max= 0.885024, precision= 0.892788, recall= 0.877395
# Train Random guess:  , auc= 0.194787fmeasure_max= 0.341869, precision= 0.206841, recall= 0.984674
# Validation Iter 5500, auc= 0.910077, fmeasure_max= 0.829097, precision= 0.847670, recall= 0.811321
# Validation Random guess:  auc= 0.224212, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.397644
# Tarin Iter 5600, auc= 0.954972, fmeasure_max= 0.899814, precision= 0.938104, recall= 0.864528
# Train Random guess:  , auc= 0.225738fmeasure_max= 0.363246, precision= 0.227191, recall= 0.905526
# Validation Iter 5600, auc= 0.917753, fmeasure_max= 0.848847, precision= 0.845238, recall= 0.852487
# Validation Random guess:  auc= 0.217305, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.394705
# Tarin Iter 5700, auc= 0.955925, fmeasure_max= 0.880270, precision= 0.870000, recall= 0.890785
# Train Random guess:  , auc= 0.220269fmeasure_max= 0.373011, precision= 0.229264, recall= 1.000000
# Validation Iter 5700, auc= 0.916161, fmeasure_max= 0.841463, precision= 0.854867, recall= 0.828473
# Validation Random guess:  auc= 0.229794, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.427600
# Tarin Iter 5800, auc= 0.948112, fmeasure_max= 0.875828, precision= 0.913644, recall= 0.841017
# Train Random guess:  , auc= 0.252915fmeasure_max= 0.394976, precision= 0.246088, recall= 1.000000
# Validation Iter 5800, auc= 0.919503, fmeasure_max= 0.846975, precision= 0.879852, recall= 0.816467
# Validation Random guess:  auc= 0.215225, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.487195
# Tarin Iter 5900, auc= 0.957791, fmeasure_max= 0.891869, precision= 0.891122, recall= 0.892617
# Train Random guess:  , auc= 0.231942fmeasure_max= 0.378981, precision= 0.233884, recall= 0.998322
# Validation Iter 5900, auc= 0.918880, fmeasure_max= 0.856661, precision= 0.842454, recall= 0.871355
# Validation Random guess:  auc= 0.219088, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.422716
# Tarin Iter 6000, auc= 0.961431, fmeasure_max= 0.892075, precision= 0.888722, recall= 0.895455
# Train Random guess:  , auc= 0.273847fmeasure_max= 0.411410, precision= 0.260120, recall= 0.983333
# Validation Iter 6000, auc= 0.907775, fmeasure_max= 0.828596, precision= 0.832180, recall= 0.825043
# Validation Random guess:  auc= 0.232213, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.451496
# Tarin Iter 6100, auc= 0.951842, fmeasure_max= 0.898966, precision= 0.871914, recall= 0.927750
# Train Random guess:  , auc= 0.232735fmeasure_max= 0.384348, precision= 0.237891, recall= 1.000000
# Validation Iter 6100, auc= 0.911222, fmeasure_max= 0.838605, precision= 0.795385, recall= 0.886792
# Validation Random guess:  auc= 0.216421, fmeasure_max= 0.371162, precision= 0.230419, recall= 0.953688
# Minibatch Loss= 0.459443
# Tarin Iter 6200, auc= 0.961082, fmeasure_max= 0.889831, precision= 0.901288, recall= 0.878661
# Train Random guess:  , auc= 0.173663fmeasure_max= 0.315789, precision= 0.188488, recall= 0.972803
# Validation Iter 6200, auc= 0.910800, fmeasure_max= 0.846527, precision= 0.800000, recall= 0.898799
# Validation Random guess:  auc= 0.245905, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.386842
# Tarin Iter 6300, auc= 0.979997, fmeasure_max= 0.923588, precision= 0.960276, recall= 0.889600
# Train Random guess:  , auc= 0.254194fmeasure_max= 0.398886, precision= 0.254893, recall= 0.916800
# Validation Iter 6300, auc= 0.902038, fmeasure_max= 0.822581, precision= 0.861163, recall= 0.787307
# Validation Random guess:  auc= 0.242399, fmeasure_max= 0.372549, precision= 0.230117, recall= 0.977702
# Minibatch Loss= 0.427958
# Tarin Iter 6400, auc= 0.972707, fmeasure_max= 0.906764, precision= 0.930582, recall= 0.884135
# Train Random guess:  , auc= 0.221218fmeasure_max= 0.359962, precision= 0.219484, recall= 1.000000
# Validation Iter 6400, auc= 0.898948, fmeasure_max= 0.831541, precision= 0.870544, recall= 0.795883
# Validation Random guess:  auc= 0.239023, fmeasure_max= 0.371467, precision= 0.231059, recall= 0.946827
# Minibatch Loss= 0.377242
# Tarin Iter 6500, auc= 0.973229, fmeasure_max= 0.908127, precision= 0.890815, recall= 0.926126
# Train Random guess:  , auc= 0.215674fmeasure_max= 0.359360, precision= 0.219473, recall= 0.990991
# Validation Iter 6500, auc= 0.902616, fmeasure_max= 0.833333, precision= 0.862385, recall= 0.806175
# Validation Random guess:  auc= 0.228440, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.384140
# Tarin Iter 6600, auc= 0.970389, fmeasure_max= 0.889853, precision= 0.924324, recall= 0.857860
# Train Random guess:  , auc= 0.228644fmeasure_max= 0.379892, precision= 0.234578, recall= 0.998328
# Validation Iter 6600, auc= 0.911258, fmeasure_max= 0.835017, precision= 0.819835, recall= 0.850772
# Validation Random guess:  auc= 0.220636, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.427158
# Tarin Iter 6700, auc= 0.936820, fmeasure_max= 0.857914, precision= 0.865699, recall= 0.850267
# Train Random guess:  , auc= 0.223944fmeasure_max= 0.359500, precision= 0.219141, recall= 1.000000
# Validation Iter 6700, auc= 0.896408, fmeasure_max= 0.826460, precision= 0.827883, recall= 0.825043
# Validation Random guess:  auc= 0.223145, fmeasure_max= 0.373308, precision= 0.229853, recall= 0.993139
# Minibatch Loss= 0.440747
# Tarin Iter 6800, auc= 0.952016, fmeasure_max= 0.877737, precision= 0.880952, recall= 0.874545
# Train Random guess:  , auc= 0.219334fmeasure_max= 0.354496, precision= 0.215433, recall= 1.000000
# Validation Iter 6800, auc= 0.916863, fmeasure_max= 0.853135, precision= 0.821940, recall= 0.886792
# Validation Random guess:  auc= 0.220886, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.400896
# Tarin Iter 6900, auc= 0.956638, fmeasure_max= 0.881773, precision= 0.922680, recall= 0.844340
# Train Random guess:  , auc= 0.246310fmeasure_max= 0.399114, precision= 0.249802, recall= 0.992138
# Validation Iter 6900, auc= 0.912946, fmeasure_max= 0.851317, precision= 0.843434, recall= 0.859348
# Validation Random guess:  auc= 0.224950, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.481129
# Tarin Iter 7000, auc= 0.954144, fmeasure_max= 0.897384, precision= 0.923395, recall= 0.872798
# Train Random guess:  , auc= 0.222588fmeasure_max= 0.334105, precision= 0.218788, recall= 0.706458
# Validation Iter 7000, auc= 0.902019, fmeasure_max= 0.834632, precision= 0.842657, recall= 0.826758
# Validation Random guess:  auc= 0.239688, fmeasure_max= 0.374374, precision= 0.232394, recall= 0.962264
# Minibatch Loss= 0.389185
# Tarin Iter 7100, auc= 0.974779, fmeasure_max= 0.922594, precision= 0.932347, recall= 0.913043
# Train Random guess:  , auc= 0.195428fmeasure_max= 0.318590, precision= 0.189778, recall= 0.991718
# Validation Iter 7100, auc= 0.897137, fmeasure_max= 0.824849, precision= 0.829861, recall= 0.819897
# Validation Random guess:  auc= 0.232325, fmeasure_max= 0.378686, precision= 0.235319, recall= 0.969125
# Minibatch Loss= 0.317175
# Tarin Iter 7200, auc= 0.965643, fmeasure_max= 0.903808, precision= 0.918534, recall= 0.889546
# Train Random guess:  , auc= 0.200052fmeasure_max= 0.330827, precision= 0.198276, recall= 0.998028
# Validation Iter 7200, auc= 0.904221, fmeasure_max= 0.818182, precision= 0.818182, recall= 0.818182
# Validation Random guess:  auc= 0.216131, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.363224
# Tarin Iter 7300, auc= 0.977825, fmeasure_max= 0.919311, precision= 0.925182, recall= 0.913514
# Train Random guess:  , auc= 0.230808fmeasure_max= 0.356340, precision= 0.216797, recall= 1.000000
# Validation Iter 7300, auc= 0.913553, fmeasure_max= 0.840065, precision= 0.793893, recall= 0.891938
# Validation Random guess:  auc= 0.219743, fmeasure_max= 0.372272, precision= 0.228977, recall= 0.994854
# Minibatch Loss= 0.377166
# Tarin Iter 7400, auc= 0.962100, fmeasure_max= 0.885459, precision= 0.893443, recall= 0.877617
# Train Random guess:  , auc= 0.251165fmeasure_max= 0.391139, precision= 0.243403, recall= 0.995169
# Validation Iter 7400, auc= 0.900530, fmeasure_max= 0.835401, precision= 0.806709, recall= 0.866209
# Validation Random guess:  auc= 0.242097, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.442695
# Tarin Iter 7500, auc= 0.952848, fmeasure_max= 0.888889, precision= 0.910569, recall= 0.868217
# Train Random guess:  , auc= 0.304892fmeasure_max= 0.464865, precision= 0.302817, recall= 1.000000
# Validation Iter 7500, auc= 0.907336, fmeasure_max= 0.843290, precision= 0.851399, recall= 0.835334
# Validation Random guess:  auc= 0.244824, fmeasure_max= 0.372432, precision= 0.230801, recall= 0.963979
# Minibatch Loss= 0.509813
# Tarin Iter 7600, auc= 0.953716, fmeasure_max= 0.884702, precision= 0.850725, recall= 0.921507
# Train Random guess:  , auc= 0.237806fmeasure_max= 0.398623, precision= 0.248925, recall= 1.000000
# Validation Iter 7600, auc= 0.901493, fmeasure_max= 0.833482, precision= 0.866667, recall= 0.802744
# Validation Random guess:  auc= 0.225723, fmeasure_max= 0.373626, precision= 0.230187, recall= 0.991424
# Minibatch Loss= 0.431775
# Tarin Iter 7700, auc= 0.945695, fmeasure_max= 0.866058, precision= 0.864742, recall= 0.867378
# Train Random guess:  , auc= 0.254062fmeasure_max= 0.408341, precision= 0.256551, recall= 1.000000
# Validation Iter 7700, auc= 0.905407, fmeasure_max= 0.838537, precision= 0.873606, recall= 0.806175
# Validation Random guess:  auc= 0.233339, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.474371
# Tarin Iter 7800, auc= 0.970536, fmeasure_max= 0.912879, precision= 0.882784, recall= 0.945098
# Train Random guess:  , auc= 0.195595fmeasure_max= 0.333333, precision= 0.200397, recall= 0.990196
# Validation Iter 7800, auc= 0.889816, fmeasure_max= 0.821773, precision= 0.841727, recall= 0.802744
# Validation Random guess:  auc= 0.234788, fmeasure_max= 0.374871, precision= 0.234335, recall= 0.936535
# Minibatch Loss= 0.342291
# Tarin Iter 7900, auc= 0.969954, fmeasure_max= 0.906089, precision= 0.944086, recall= 0.871032
# Train Random guess:  , auc= 0.196700fmeasure_max= 0.329627, precision= 0.197338, recall= 1.000000
# Validation Iter 7900, auc= 0.903057, fmeasure_max= 0.839527, precision= 0.826955, recall= 0.852487
# Validation Random guess:  auc= 0.244192, fmeasure_max= 0.371281, precision= 0.228776, recall= 0.984563
# Minibatch Loss= 0.355039
# Tarin Iter 8000, auc= 0.939473, fmeasure_max= 0.865370, precision= 0.820059, recall= 0.915980
# Train Random guess:  , auc= 0.224104fmeasure_max= 0.383449, precision= 0.237202, recall= 1.000000
# Validation Iter 8000, auc= 0.902742, fmeasure_max= 0.822064, precision= 0.853974, recall= 0.792453
# Validation Random guess:  auc= 0.236259, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.521553
# Tarin Iter 8100, auc= 0.960060, fmeasure_max= 0.891816, precision= 0.922179, recall= 0.863388
# Train Random guess:  , auc= 0.212999fmeasure_max= 0.355184, precision= 0.217534, recall= 0.967213
# Validation Iter 8100, auc= 0.916604, fmeasure_max= 0.842809, precision= 0.822186, recall= 0.864494
# Validation Random guess:  auc= 0.236215, fmeasure_max= 0.372033, precision= 0.228797, recall= 0.994854
# Minibatch Loss= 0.419540
# Tarin Iter 8200, auc= 0.958269, fmeasure_max= 0.883019, precision= 0.883019, recall= 0.883019
# Train Random guess:  , auc= 0.198993fmeasure_max= 0.343821, precision= 0.207599, recall= 1.000000
# Validation Iter 8200, auc= 0.909426, fmeasure_max= 0.834934, precision= 0.850534, recall= 0.819897
# Validation Random guess:  auc= 0.231600, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.362856
# Tarin Iter 8300, auc= 0.962101, fmeasure_max= 0.896605, precision= 0.903577, recall= 0.889740
# Train Random guess:  , auc= 0.277638fmeasure_max= 0.407107, precision= 0.255577, recall= 1.000000
# Validation Iter 8300, auc= 0.906025, fmeasure_max= 0.837004, precision= 0.860507, recall= 0.814751
# Validation Random guess:  auc= 0.236964, fmeasure_max= 0.373308, precision= 0.229853, recall= 0.993139
# Minibatch Loss= 0.425821
# Tarin Iter 8400, auc= 0.952824, fmeasure_max= 0.890894, precision= 0.849765, recall= 0.936207
# Train Random guess:  , auc= 0.214600fmeasure_max= 0.369898, precision= 0.226917, recall= 1.000000
# Validation Iter 8400, auc= 0.907868, fmeasure_max= 0.833192, precision= 0.822742, recall= 0.843911
# Validation Random guess:  auc= 0.236687, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.435600
# Tarin Iter 8500, auc= 0.950436, fmeasure_max= 0.882353, precision= 0.890851, recall= 0.874016
# Train Random guess:  , auc= 0.256604fmeasure_max= 0.398487, precision= 0.249113, recall= 0.995276
# Validation Iter 8500, auc= 0.909187, fmeasure_max= 0.835749, precision= 0.787557, recall= 0.890223
# Validation Random guess:  auc= 0.226090, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.460846
# Tarin Iter 8600, auc= 0.964546, fmeasure_max= 0.907136, precision= 0.890595, recall= 0.924303
# Train Random guess:  , auc= 0.195355fmeasure_max= 0.328319, precision= 0.196401, recall= 1.000000
# Validation Iter 8600, auc= 0.913546, fmeasure_max= 0.844053, precision= 0.867754, recall= 0.821612
# Validation Random guess:  auc= 0.219986, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.378902
# Tarin Iter 8700, auc= 0.940498, fmeasure_max= 0.863267, precision= 0.819074, recall= 0.912500
# Train Random guess:  , auc= 0.242666fmeasure_max= 0.400759, precision= 0.251189, recall= 0.990625
# Validation Iter 8700, auc= 0.904796, fmeasure_max= 0.830961, precision= 0.863216, recall= 0.801029
# Validation Random guess:  auc= 0.225079, fmeasure_max= 0.374709, precision= 0.232453, recall= 0.965695
# Minibatch Loss= 0.517449
# Tarin Iter 8800, auc= 0.957974, fmeasure_max= 0.908469, precision= 0.889447, recall= 0.928322
# Train Random guess:  , auc= 0.221437fmeasure_max= 0.367162, precision= 0.225218, recall= 0.993007
# Validation Iter 8800, auc= 0.915088, fmeasure_max= 0.840407, precision= 0.831933, recall= 0.849057
# Validation Random guess:  auc= 0.218612, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.447039
# Tarin Iter 8900, auc= 0.962414, fmeasure_max= 0.893443, precision= 0.877264, recall= 0.910230
# Train Random guess:  , auc= 0.193968fmeasure_max= 0.316208, precision= 0.187943, recall= 0.995825
# Validation Iter 8900, auc= 0.903240, fmeasure_max= 0.830876, precision= 0.840351, recall= 0.821612
# Validation Random guess:  auc= 0.231938, fmeasure_max= 0.371108, precision= 0.228278, recall= 0.991424
# Minibatch Loss= 0.352400
# Tarin Iter 9000, auc= 0.965989, fmeasure_max= 0.908333, precision= 0.884740, recall= 0.933219
# Train Random guess:  , auc= 0.228398fmeasure_max= 0.372286, precision= 0.228807, recall= 0.998288
# Validation Iter 9000, auc= 0.922532, fmeasure_max= 0.850694, precision= 0.861160, recall= 0.840480
# Validation Random guess:  auc= 0.242055, fmeasure_max= 0.372093, precision= 0.229960, recall= 0.974271
# Minibatch Loss= 0.380652
# Tarin Iter 9100, auc= 0.973056, fmeasure_max= 0.919129, precision= 0.903670, recall= 0.935127
# Train Random guess:  , auc= 0.268510fmeasure_max= 0.399231, precision= 0.250301, recall= 0.985759
# Validation Iter 9100, auc= 0.901905, fmeasure_max= 0.832787, precision= 0.797488, recall= 0.871355
# Validation Random guess:  auc= 0.224773, fmeasure_max= 0.373001, precision= 0.229257, recall= 1.000000
# Minibatch Loss= 0.417426
# Tarin Iter 9200, auc= 0.965511, fmeasure_max= 0.900446, precision= 0.865714, recall= 0.938080
# Train Random guess:  , auc= 0.263643fmeasure_max= 0.406098, precision= 0.256873, recall= 0.969040
# Validation Iter 9200, auc= 0.912162, fmeasure_max= 0.832618, precision= 0.833333, recall= 0.831904
# Validation Random guess:  auc= 0.224756, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.446333
# Tarin Iter 9300, auc= 0.967734, fmeasure_max= 0.912026, precision= 0.906902, recall= 0.917208
# Train Random guess:  , auc= 0.237066fmeasure_max= 0.388835, precision= 0.242303, recall= 0.983766
# Validation Iter 9300, auc= 0.912005, fmeasure_max= 0.839209, precision= 0.841379, recall= 0.837050
# Validation Random guess:  auc= 0.231696, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.395008
# Tarin Iter 9400, auc= 0.970265, fmeasure_max= 0.910920, precision= 0.901849, recall= 0.920174
# Train Random guess:  , auc= 0.265065fmeasure_max= 0.424131, precision= 0.269141, recall= 1.000000
# Validation Iter 9400, auc= 0.918551, fmeasure_max= 0.846088, precision= 0.848276, recall= 0.843911
# Validation Random guess:  auc= 0.227371, fmeasure_max= 0.372925, precision= 0.230120, recall= 0.982847
# Minibatch Loss= 0.487792
# Tarin Iter 9500, auc= 0.955326, fmeasure_max= 0.880878, precision= 0.861963, recall= 0.900641
# Train Random guess:  , auc= 0.254889fmeasure_max= 0.395626, precision= 0.247485, recall= 0.985577
# Validation Iter 9500, auc= 0.934545, fmeasure_max= 0.861953, precision= 0.846281, recall= 0.878216
# Validation Random guess:  auc= 0.221989, fmeasure_max= 0.371108, precision= 0.228278, recall= 0.991424
# Minibatch Loss= 0.492173
# Tarin Iter 9600, auc= 0.952651, fmeasure_max= 0.903963, precision= 0.890390, recall= 0.917957
# Train Random guess:  , auc= 0.258982fmeasure_max= 0.405660, precision= 0.254538, recall= 0.998452
# Validation Iter 9600, auc= 0.922444, fmeasure_max= 0.843042, precision= 0.797856, recall= 0.893654
# Validation Random guess:  auc= 0.235883, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.465951
# Tarin Iter 9700, auc= 0.940165, fmeasure_max= 0.860465, precision= 0.930818, recall= 0.800000
# Train Random guess:  , auc= 0.230098fmeasure_max= 0.356614, precision= 0.217085, recall= 0.998198
# Validation Iter 9700, auc= 0.929566, fmeasure_max= 0.857860, precision= 0.836868, recall= 0.879931
# Validation Random guess:  auc= 0.234897, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.474023
# Tarin Iter 9800, auc= 0.953328, fmeasure_max= 0.878049, precision= 0.865979, recall= 0.890459
# Train Random guess:  , auc= 0.220242fmeasure_max= 0.362240, precision= 0.221180, recall= 1.000000
# Validation Iter 9800, auc= 0.920469, fmeasure_max= 0.843137, precision= 0.877551, recall= 0.811321
# Validation Random guess:  auc= 0.243970, fmeasure_max= 0.372362, precision= 0.232272, recall= 0.938250
# Minibatch Loss= 0.413855
# Tarin Iter 9900, auc= 0.964036, fmeasure_max= 0.895028, precision= 0.865649, recall= 0.926471
# Train Random guess:  , auc= 0.242752fmeasure_max= 0.386242, precision= 0.239343, recall= 1.000000
# Validation Iter 9900, auc= 0.910449, fmeasure_max= 0.846690, precision= 0.860177, recall= 0.833619
# Validation Random guess:  auc= 0.231129, fmeasure_max= 0.372160, precision= 0.235616, recall= 0.885077
# Minibatch Loss= 0.428079
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.896503 F1_max = 0.818469 prec = 0.806393 rec = 0.830912
# Test Random guess: auc= 0.231329 fmeasure_max= 0.375914 , precision= 0.231534 , recall= 0.998649

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
