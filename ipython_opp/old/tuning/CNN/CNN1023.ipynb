# %%
# useing this variable for saving models and summaries
exp_name = "CNN1023"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 6    #number of convolution to have in the network
pooling_stride = [4, 2, 2, 2, 1, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.330539, fmeasure_max= 0.424144, precision= 0.287611, recall= 0.807453
# Train Random guess:  , auc= 0.251919fmeasure_max= 0.402985, precision= 0.254717, recall= 0.964286
# Validation Iter 0, auc= 0.246002, fmeasure_max= 0.387829, precision= 0.277286, recall= 0.644940
# Validation Random guess:  auc= 0.225895, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 1.085161
# Tarin Iter 100, auc= 0.827874, fmeasure_max= 0.782080, precision= 0.811024, recall= 0.755132
# Train Random guess:  , auc= 0.259908fmeasure_max= 0.420728, precision= 0.266406, recall= 1.000000
# Validation Iter 100, auc= 0.754171, fmeasure_max= 0.733995, precision= 0.773764, recall= 0.698113
# Validation Random guess:  auc= 0.229024, fmeasure_max= 0.371081, precision= 0.228077, recall= 0.994854
# Minibatch Loss= 0.798304
# Tarin Iter 200, auc= 0.806146, fmeasure_max= 0.774510, precision= 0.784768, recall= 0.764516
# Train Random guess:  , auc= 0.253289fmeasure_max= 0.391174, precision= 0.246731, recall= 0.943548
# Validation Iter 200, auc= 0.795473, fmeasure_max= 0.774697, precision= 0.782837, recall= 0.766724
# Validation Random guess:  auc= 0.229953, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.719555
# Tarin Iter 300, auc= 0.740836, fmeasure_max= 0.697020, precision= 0.727116, recall= 0.669316
# Train Random guess:  , auc= 0.248009fmeasure_max= 0.395814, precision= 0.247227, recall= 0.992051
# Validation Iter 300, auc= 0.795753, fmeasure_max= 0.760770, precision= 0.816929, recall= 0.711835
# Validation Random guess:  auc= 0.218505, fmeasure_max= 0.371840, precision= 0.228560, recall= 0.996569
# Minibatch Loss= 0.877485
# Tarin Iter 400, auc= 0.800875, fmeasure_max= 0.771930, precision= 0.776471, recall= 0.767442
# Train Random guess:  , auc= 0.239575fmeasure_max= 0.381133, precision= 0.235432, recall= 1.000000
# Validation Iter 400, auc= 0.833091, fmeasure_max= 0.801376, precision= 0.803448, recall= 0.799314
# Validation Random guess:  auc= 0.233487, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.718832
# Tarin Iter 500, auc= 0.922600, fmeasure_max= 0.844175, precision= 0.862442, recall= 0.826667
# Train Random guess:  , auc= 0.265713fmeasure_max= 0.418970, precision= 0.265843, recall= 0.988148
# Validation Iter 500, auc= 0.872772, fmeasure_max= 0.816254, precision= 0.841530, recall= 0.792453
# Validation Random guess:  auc= 0.231107, fmeasure_max= 0.373801, precision= 0.231557, recall= 0.969125
# Minibatch Loss= 0.605245
# Tarin Iter 600, auc= 0.834583, fmeasure_max= 0.805921, precision= 0.823529, recall= 0.789050
# Train Random guess:  , auc= 0.237316fmeasure_max= 0.391667, precision= 0.244498, recall= 0.983897
# Validation Iter 600, auc= 0.889472, fmeasure_max= 0.832350, precision= 0.817881, recall= 0.847341
# Validation Random guess:  auc= 0.242843, fmeasure_max= 0.375276, precision= 0.238876, recall= 0.874786
# Minibatch Loss= 0.706677
# Tarin Iter 700, auc= 0.851460, fmeasure_max= 0.801794, precision= 0.823204, recall= 0.781469
# Train Random guess:  , auc= 0.212834fmeasure_max= 0.366516, precision= 0.224822, recall= 0.991259
# Validation Iter 700, auc= 0.877960, fmeasure_max= 0.816999, precision= 0.826316, recall= 0.807890
# Validation Random guess:  auc= 0.239216, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.746889
# Tarin Iter 800, auc= 0.902376, fmeasure_max= 0.846460, precision= 0.832551, recall= 0.860841
# Train Random guess:  , auc= 0.239921fmeasure_max= 0.389766, precision= 0.242151, recall= 0.998382
# Validation Iter 800, auc= 0.886606, fmeasure_max= 0.818792, precision= 0.801314, recall= 0.837050
# Validation Random guess:  auc= 0.229707, fmeasure_max= 0.372638, precision= 0.229996, recall= 0.981132
# Minibatch Loss= 0.617494
# Tarin Iter 900, auc= 0.890618, fmeasure_max= 0.810105, precision= 0.872420, recall= 0.756098
# Train Random guess:  , auc= 0.246873fmeasure_max= 0.387402, precision= 0.240234, recall= 1.000000
# Validation Iter 900, auc= 0.888509, fmeasure_max= 0.814879, precision= 0.821990, recall= 0.807890
# Validation Random guess:  auc= 0.221426, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.610190
# Tarin Iter 1000, auc= 0.880267, fmeasure_max= 0.821869, precision= 0.816112, recall= 0.827709
# Train Random guess:  , auc= 0.208917fmeasure_max= 0.360551, precision= 0.219922, recall= 1.000000
# Validation Iter 1000, auc= 0.892509, fmeasure_max= 0.822526, precision= 0.818336, recall= 0.826758
# Validation Random guess:  auc= 0.246682, fmeasure_max= 0.372794, precision= 0.229282, recall= 0.996569
# Minibatch Loss= 0.568849
# Tarin Iter 1100, auc= 0.928000, fmeasure_max= 0.863014, precision= 0.895735, recall= 0.832599
# Train Random guess:  , auc= 0.260774fmeasure_max= 0.421216, precision= 0.267007, recall= 0.997063
# Validation Iter 1100, auc= 0.903751, fmeasure_max= 0.836718, precision= 0.794753, recall= 0.883362
# Validation Random guess:  auc= 0.243907, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.596062
# Tarin Iter 1200, auc= 0.909066, fmeasure_max= 0.835673, precision= 0.830870, recall= 0.840532
# Train Random guess:  , auc= 0.242382fmeasure_max= 0.382101, precision= 0.236171, recall= 1.000000
# Validation Iter 1200, auc= 0.901252, fmeasure_max= 0.835465, precision= 0.830508, recall= 0.840480
# Validation Random guess:  auc= 0.234311, fmeasure_max= 0.371094, precision= 0.229008, recall= 0.977702
# Minibatch Loss= 0.592084
# Tarin Iter 1300, auc= 0.903535, fmeasure_max= 0.815789, precision= 0.839458, recall= 0.793419
# Train Random guess:  , auc= 0.218269fmeasure_max= 0.353907, precision= 0.219858, recall= 0.906764
# Validation Iter 1300, auc= 0.898818, fmeasure_max= 0.832479, precision= 0.829642, recall= 0.835334
# Validation Random guess:  auc= 0.223525, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.512904
# Tarin Iter 1400, auc= 0.908348, fmeasure_max= 0.829588, precision= 0.900407, recall= 0.769097
# Train Random guess:  , auc= 0.239683fmeasure_max= 0.367464, precision= 0.225088, recall= 1.000000
# Validation Iter 1400, auc= 0.904661, fmeasure_max= 0.817857, precision= 0.852886, recall= 0.785592
# Validation Random guess:  auc= 0.250643, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.532070
# Tarin Iter 1500, auc= 0.894213, fmeasure_max= 0.810078, precision= 0.876310, recall= 0.753153
# Train Random guess:  , auc= 0.213258fmeasure_max= 0.356798, precision= 0.217136, recall= 1.000000
# Validation Iter 1500, auc= 0.891541, fmeasure_max= 0.826855, precision= 0.852459, recall= 0.802744
# Validation Random guess:  auc= 0.229022, fmeasure_max= 0.372093, precision= 0.229208, recall= 0.987993
# Minibatch Loss= 0.520767
# Tarin Iter 1600, auc= 0.871236, fmeasure_max= 0.791058, precision= 0.822898, recall= 0.761589
# Train Random guess:  , auc= 0.235014fmeasure_max= 0.382391, precision= 0.237241, recall= 0.985099
# Validation Iter 1600, auc= 0.909248, fmeasure_max= 0.839549, precision= 0.849123, recall= 0.830189
# Validation Random guess:  auc= 0.222379, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.585939
# Tarin Iter 1700, auc= 0.928664, fmeasure_max= 0.854839, precision= 0.905983, recall= 0.809160
# Train Random guess:  , auc= 0.254514fmeasure_max= 0.409821, precision= 0.258128, recall= 0.993893
# Validation Iter 1700, auc= 0.903951, fmeasure_max= 0.828151, precision= 0.791862, recall= 0.867925
# Validation Random guess:  auc= 0.237769, fmeasure_max= 0.374699, precision= 0.234308, recall= 0.934820
# Minibatch Loss= 0.561821
# Tarin Iter 1800, auc= 0.896370, fmeasure_max= 0.830088, precision= 0.843525, recall= 0.817073
# Train Random guess:  , auc= 0.231528fmeasure_max= 0.368919, precision= 0.226999, recall= 0.984321
# Validation Iter 1800, auc= 0.907754, fmeasure_max= 0.839090, precision= 0.824503, recall= 0.854202
# Validation Random guess:  auc= 0.239989, fmeasure_max= 0.371988, precision= 0.228854, recall= 0.993139
# Minibatch Loss= 0.551471
# Tarin Iter 1900, auc= 0.908079, fmeasure_max= 0.834021, precision= 0.850168, recall= 0.818476
# Train Random guess:  , auc= 0.237256fmeasure_max= 0.388417, precision= 0.241016, recall= 1.000000
# Validation Iter 1900, auc= 0.904440, fmeasure_max= 0.829396, precision= 0.846429, recall= 0.813036
# Validation Random guess:  auc= 0.245148, fmeasure_max= 0.372366, precision= 0.233131, recall= 0.924528
# Minibatch Loss= 0.562293
# Tarin Iter 2000, auc= 0.933711, fmeasure_max= 0.855184, precision= 0.889483, recall= 0.823432
# Train Random guess:  , auc= 0.246903fmeasure_max= 0.384021, precision= 0.238591, recall= 0.983498
# Validation Iter 2000, auc= 0.891391, fmeasure_max= 0.834225, precision= 0.868275, recall= 0.802744
# Validation Random guess:  auc= 0.230328, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.492510
# Tarin Iter 2100, auc= 0.920213, fmeasure_max= 0.850216, precision= 0.842196, recall= 0.858392
# Train Random guess:  , auc= 0.235066fmeasure_max= 0.365378, precision= 0.223525, recall= 1.000000
# Validation Iter 2100, auc= 0.870628, fmeasure_max= 0.801444, precision= 0.845714, recall= 0.761578
# Validation Random guess:  auc= 0.229124, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.520096
# Tarin Iter 2200, auc= 0.927320, fmeasure_max= 0.854288, precision= 0.865093, recall= 0.843750
# Train Random guess:  , auc= 0.227972fmeasure_max= 0.386088, precision= 0.239509, recall= 0.995066
# Validation Iter 2200, auc= 0.883884, fmeasure_max= 0.823529, precision= 0.843525, recall= 0.804460
# Validation Random guess:  auc= 0.230371, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.502250
# Tarin Iter 2300, auc= 0.914314, fmeasure_max= 0.842004, precision= 0.822976, recall= 0.861933
# Train Random guess:  , auc= 0.197578fmeasure_max= 0.332510, precision= 0.202494, recall= 0.928994
# Validation Iter 2300, auc= 0.892777, fmeasure_max= 0.812446, precision= 0.818815, recall= 0.806175
# Validation Random guess:  auc= 0.224166, fmeasure_max= 0.372631, precision= 0.229249, recall= 0.994854
# Minibatch Loss= 0.462028
# Tarin Iter 2400, auc= 0.917658, fmeasure_max= 0.834426, precision= 0.818328, recall= 0.851171
# Train Random guess:  , auc= 0.221619fmeasure_max= 0.378961, precision= 0.233776, recall= 1.000000
# Validation Iter 2400, auc= 0.904003, fmeasure_max= 0.835034, precision= 0.827993, recall= 0.842196
# Validation Random guess:  auc= 0.214252, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.533737
# Tarin Iter 2500, auc= 0.943589, fmeasure_max= 0.870871, precision= 0.849195, recall= 0.893683
# Train Random guess:  , auc= 0.250384fmeasure_max= 0.405732, precision= 0.255721, recall= 0.981510
# Validation Iter 2500, auc= 0.879102, fmeasure_max= 0.814495, precision= 0.819444, recall= 0.809605
# Validation Random guess:  auc= 0.232831, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.516883
# Tarin Iter 2600, auc= 0.915216, fmeasure_max= 0.831579, precision= 0.815835, recall= 0.847943
# Train Random guess:  , auc= 0.243087fmeasure_max= 0.359057, precision= 0.219070, recall= 0.994633
# Validation Iter 2600, auc= 0.873691, fmeasure_max= 0.825175, precision= 0.841355, recall= 0.809605
# Validation Random guess:  auc= 0.242203, fmeasure_max= 0.372242, precision= 0.228774, recall= 0.998285
# Minibatch Loss= 0.531468
# Tarin Iter 2700, auc= 0.874380, fmeasure_max= 0.835366, precision= 0.874468, recall= 0.799611
# Train Random guess:  , auc= 0.190730fmeasure_max= 0.336387, precision= 0.202203, recall= 1.000000
# Validation Iter 2700, auc= 0.879674, fmeasure_max= 0.828452, precision= 0.808824, recall= 0.849057
# Validation Random guess:  auc= 0.221603, fmeasure_max= 0.372594, precision= 0.230056, recall= 0.979417
# Minibatch Loss= 0.637745
# Tarin Iter 2800, auc= 0.947083, fmeasure_max= 0.894040, precision= 0.897010, recall= 0.891089
# Train Random guess:  , auc= 0.250764fmeasure_max= 0.386689, precision= 0.242184, recall= 0.958746
# Validation Iter 2800, auc= 0.884429, fmeasure_max= 0.820119, precision= 0.815254, recall= 0.825043
# Validation Random guess:  auc= 0.240578, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.462109
# Tarin Iter 2900, auc= 0.916648, fmeasure_max= 0.846449, precision= 0.833648, recall= 0.859649
# Train Random guess:  , auc= 0.198593fmeasure_max= 0.334093, precision= 0.200547, recall= 1.000000
# Validation Iter 2900, auc= 0.897740, fmeasure_max= 0.829694, precision= 0.845196, recall= 0.814751
# Validation Random guess:  auc= 0.222175, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.508165
# Tarin Iter 3000, auc= 0.916163, fmeasure_max= 0.859873, precision= 0.873786, recall= 0.846395
# Train Random guess:  , auc= 0.249615fmeasure_max= 0.399249, precision= 0.249414, recall= 1.000000
# Validation Iter 3000, auc= 0.863047, fmeasure_max= 0.811847, precision= 0.824779, recall= 0.799314
# Validation Random guess:  auc= 0.227272, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.538288
# Tarin Iter 3100, auc= 0.924763, fmeasure_max= 0.847097, precision= 0.872054, recall= 0.823529
# Train Random guess:  , auc= 0.238732fmeasure_max= 0.395952, precision= 0.247138, recall= 0.995231
# Validation Iter 3100, auc= 0.887235, fmeasure_max= 0.814626, precision= 0.807757, recall= 0.821612
# Validation Random guess:  auc= 0.243851, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.514622
# Tarin Iter 3200, auc= 0.937406, fmeasure_max= 0.878367, precision= 0.855326, recall= 0.902685
# Train Random guess:  , auc= 0.242545fmeasure_max= 0.377813, precision= 0.232903, recall= 1.000000
# Validation Iter 3200, auc= 0.880180, fmeasure_max= 0.834163, precision= 0.807384, recall= 0.862779
# Validation Random guess:  auc= 0.230454, fmeasure_max= 0.372969, precision= 0.230060, recall= 0.984563
# Minibatch Loss= 0.460674
# Tarin Iter 3300, auc= 0.931004, fmeasure_max= 0.853116, precision= 0.826149, recall= 0.881902
# Train Random guess:  , auc= 0.248646fmeasure_max= 0.406114, precision= 0.254894, recall= 0.998466
# Validation Iter 3300, auc= 0.897123, fmeasure_max= 0.828352, precision= 0.824830, recall= 0.831904
# Validation Random guess:  auc= 0.224287, fmeasure_max= 0.371721, precision= 0.228470, recall= 0.996569
# Minibatch Loss= 0.560994
# Tarin Iter 3400, auc= 0.957405, fmeasure_max= 0.886633, precision= 0.864686, recall= 0.909722
# Train Random guess:  , auc= 0.229350fmeasure_max= 0.367347, precision= 0.225000, recall= 1.000000
# Validation Iter 3400, auc= 0.883050, fmeasure_max= 0.802102, precision= 0.819320, recall= 0.785592
# Validation Random guess:  auc= 0.226595, fmeasure_max= 0.371009, precision= 0.227933, recall= 0.996569
# Minibatch Loss= 0.445388
# Tarin Iter 3500, auc= 0.952431, fmeasure_max= 0.895238, precision= 0.919929, recall= 0.871838
# Train Random guess:  , auc= 0.247055fmeasure_max= 0.378068, precision= 0.233097, recall= 1.000000
# Validation Iter 3500, auc= 0.888736, fmeasure_max= 0.817128, precision= 0.851301, recall= 0.785592
# Validation Random guess:  auc= 0.225969, fmeasure_max= 0.374913, precision= 0.235243, recall= 0.922813
# Minibatch Loss= 0.442216
# Tarin Iter 3600, auc= 0.931817, fmeasure_max= 0.846449, precision= 0.801818, recall= 0.896341
# Train Random guess:  , auc= 0.185846fmeasure_max= 0.324706, precision= 0.194523, recall= 0.981707
# Validation Iter 3600, auc= 0.888480, fmeasure_max= 0.823843, precision= 0.855823, recall= 0.794168
# Validation Random guess:  auc= 0.227164, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.432024
# Tarin Iter 3700, auc= 0.936249, fmeasure_max= 0.862136, precision= 0.891566, recall= 0.834586
# Train Random guess:  , auc= 0.224277fmeasure_max= 0.344225, precision= 0.207894, recall= 1.000000
# Validation Iter 3700, auc= 0.893130, fmeasure_max= 0.802269, precision= 0.760369, recall= 0.849057
# Validation Random guess:  auc= 0.224188, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.465904
# Tarin Iter 3800, auc= 0.916211, fmeasure_max= 0.839738, precision= 0.875000, recall= 0.807207
# Train Random guess:  , auc= 0.221498fmeasure_max= 0.356569, precision= 0.216966, recall= 1.000000
# Validation Iter 3800, auc= 0.894084, fmeasure_max= 0.836646, precision= 0.843206, recall= 0.830189
# Validation Random guess:  auc= 0.232114, fmeasure_max= 0.372001, precision= 0.230081, recall= 0.970840
# Minibatch Loss= 0.507126
# Tarin Iter 3900, auc= 0.958957, fmeasure_max= 0.896861, precision= 0.872093, recall= 0.923077
# Train Random guess:  , auc= 0.257679fmeasure_max= 0.406339, precision= 0.255888, recall= 0.986154
# Validation Iter 3900, auc= 0.894839, fmeasure_max= 0.824818, precision= 0.881092, recall= 0.775300
# Validation Random guess:  auc= 0.238035, fmeasure_max= 0.371721, precision= 0.228470, recall= 0.996569
# Minibatch Loss= 0.475205
# Tarin Iter 4000, auc= 0.912766, fmeasure_max= 0.834783, precision= 0.861759, recall= 0.809444
# Train Random guess:  , auc= 0.225693fmeasure_max= 0.377707, precision= 0.232823, recall= 1.000000
# Validation Iter 4000, auc= 0.875423, fmeasure_max= 0.808007, precision= 0.860465, recall= 0.761578
# Validation Random guess:  auc= 0.245747, fmeasure_max= 0.372427, precision= 0.230024, recall= 0.977702
# Minibatch Loss= 0.560665
# Tarin Iter 4100, auc= 0.968202, fmeasure_max= 0.906621, precision= 0.891486, recall= 0.922280
# Train Random guess:  , auc= 0.228440fmeasure_max= 0.369260, precision= 0.226437, recall= 1.000000
# Validation Iter 4100, auc= 0.898092, fmeasure_max= 0.825023, precision= 0.875000, recall= 0.780446
# Validation Random guess:  auc= 0.237766, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.422114
# Tarin Iter 4200, auc= 0.956376, fmeasure_max= 0.886435, precision= 0.889241, recall= 0.883648
# Train Random guess:  , auc= 0.244908fmeasure_max= 0.398371, precision= 0.248729, recall= 1.000000
# Validation Iter 4200, auc= 0.896347, fmeasure_max= 0.814539, precision= 0.891837, recall= 0.749571
# Validation Random guess:  auc= 0.225426, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.490142
# Tarin Iter 4300, auc= 0.917055, fmeasure_max= 0.830093, precision= 0.856894, recall= 0.804918
# Train Random guess:  , auc= 0.238216fmeasure_max= 0.385819, precision= 0.239587, recall= 0.990164
# Validation Iter 4300, auc= 0.906609, fmeasure_max= 0.827899, precision= 0.877159, recall= 0.783877
# Validation Random guess:  auc= 0.222430, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.532736
# Tarin Iter 4400, auc= 0.966941, fmeasure_max= 0.903553, precision= 0.905523, recall= 0.901592
# Train Random guess:  , auc= 0.271892fmeasure_max= 0.425362, precision= 0.270133, recall= 1.000000
# Validation Iter 4400, auc= 0.903505, fmeasure_max= 0.836842, precision= 0.856373, recall= 0.818182
# Validation Random guess:  auc= 0.214994, fmeasure_max= 0.373178, precision= 0.230032, recall= 0.987993
# Minibatch Loss= 0.461531
# Tarin Iter 4500, auc= 0.938905, fmeasure_max= 0.881967, precision= 0.830247, recall= 0.940559
# Train Random guess:  , auc= 0.220706fmeasure_max= 0.366733, precision= 0.226672, recall= 0.959790
# Validation Iter 4500, auc= 0.885741, fmeasure_max= 0.822926, precision= 0.820819, recall= 0.825043
# Validation Random guess:  auc= 0.241587, fmeasure_max= 0.377979, precision= 0.234975, recall= 0.965695
# Minibatch Loss= 0.460554
# Tarin Iter 4600, auc= 0.964689, fmeasure_max= 0.896279, precision= 0.917342, recall= 0.876161
# Train Random guess:  , auc= 0.242092fmeasure_max= 0.403120, precision= 0.252442, recall= 1.000000
# Validation Iter 4600, auc= 0.910667, fmeasure_max= 0.831986, precision= 0.873585, recall= 0.794168
# Validation Random guess:  auc= 0.240226, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.467561
# Tarin Iter 4700, auc= 0.914978, fmeasure_max= 0.844842, precision= 0.826709, recall= 0.863787
# Train Random guess:  , auc= 0.239344fmeasure_max= 0.383937, precision= 0.238927, recall= 0.976744
# Validation Iter 4700, auc= 0.883359, fmeasure_max= 0.817531, precision= 0.854206, recall= 0.783877
# Validation Random guess:  auc= 0.234247, fmeasure_max= 0.372078, precision= 0.228740, recall= 0.996569
# Minibatch Loss= 0.518070
# Tarin Iter 4800, auc= 0.938794, fmeasure_max= 0.880583, precision= 0.864043, recall= 0.897770
# Train Random guess:  , auc= 0.206398fmeasure_max= 0.349279, precision= 0.212013, recall= 0.990706
# Validation Iter 4800, auc= 0.882579, fmeasure_max= 0.819469, precision= 0.846435, recall= 0.794168
# Validation Random guess:  auc= 0.229716, fmeasure_max= 0.372138, precision= 0.229150, recall= 0.989708
# Minibatch Loss= 0.458609
# Tarin Iter 4900, auc= 0.929207, fmeasure_max= 0.853462, precision= 0.826833, recall= 0.881864
# Train Random guess:  , auc= 0.238675fmeasure_max= 0.380741, precision= 0.235133, recall= 1.000000
# Validation Iter 4900, auc= 0.893121, fmeasure_max= 0.826531, precision= 0.819562, recall= 0.833619
# Validation Random guess:  auc= 0.230386, fmeasure_max= 0.373315, precision= 0.232285, recall= 0.950257
# Minibatch Loss= 0.497041
# Tarin Iter 5000, auc= 0.925500, fmeasure_max= 0.847645, precision= 0.843750, recall= 0.851577
# Train Random guess:  , auc= 0.229010fmeasure_max= 0.348852, precision= 0.211868, recall= 0.987013
# Validation Iter 5000, auc= 0.881517, fmeasure_max= 0.806023, precision= 0.833333, recall= 0.780446
# Validation Random guess:  auc= 0.225818, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.483242
# Tarin Iter 5100, auc= 0.942808, fmeasure_max= 0.874647, precision= 0.848263, recall= 0.902724
# Train Random guess:  , auc= 0.192148fmeasure_max= 0.336058, precision= 0.201965, recall= 1.000000
# Validation Iter 5100, auc= 0.895039, fmeasure_max= 0.838028, precision= 0.860759, recall= 0.816467
# Validation Random guess:  auc= 0.230921, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.416887
# Tarin Iter 5200, auc= 0.929351, fmeasure_max= 0.867365, precision= 0.911927, recall= 0.826955
# Train Random guess:  , auc= 0.242121fmeasure_max= 0.380983, precision= 0.235317, recall= 1.000000
# Validation Iter 5200, auc= 0.883454, fmeasure_max= 0.828598, precision= 0.889764, recall= 0.775300
# Validation Random guess:  auc= 0.236813, fmeasure_max= 0.371578, precision= 0.229376, recall= 0.977702
# Minibatch Loss= 0.495245
# Tarin Iter 5300, auc= 0.964318, fmeasure_max= 0.900709, precision= 0.881944, recall= 0.920290
# Train Random guess:  , auc= 0.237543fmeasure_max= 0.357306, precision= 0.217771, recall= 0.994565
# Validation Iter 5300, auc= 0.897653, fmeasure_max= 0.831213, precision= 0.822148, recall= 0.840480
# Validation Random guess:  auc= 0.219638, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.429338
# Tarin Iter 5400, auc= 0.967760, fmeasure_max= 0.907285, precision= 0.917923, recall= 0.896890
# Train Random guess:  , auc= 0.238483fmeasure_max= 0.385597, precision= 0.240998, recall= 0.963993
# Validation Iter 5400, auc= 0.903980, fmeasure_max= 0.840034, precision= 0.837884, recall= 0.842196
# Validation Random guess:  auc= 0.231751, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.419756
# Tarin Iter 5500, auc= 0.944340, fmeasure_max= 0.866251, precision= 0.828912, recall= 0.907112
# Train Random guess:  , auc= 0.278478fmeasure_max= 0.424784, precision= 0.272318, recall= 0.965167
# Validation Iter 5500, auc= 0.898908, fmeasure_max= 0.817264, precision= 0.879447, recall= 0.763293
# Validation Random guess:  auc= 0.222360, fmeasure_max= 0.372969, precision= 0.230060, recall= 0.984563
# Minibatch Loss= 0.482061
# Tarin Iter 5600, auc= 0.970552, fmeasure_max= 0.908213, precision= 0.947899, recall= 0.871716
# Train Random guess:  , auc= 0.255496fmeasure_max= 0.405524, precision= 0.254431, recall= 0.998454
# Validation Iter 5600, auc= 0.898084, fmeasure_max= 0.838938, precision= 0.866545, recall= 0.813036
# Validation Random guess:  auc= 0.216863, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.471261
# Tarin Iter 5700, auc= 0.960229, fmeasure_max= 0.896853, precision= 0.896853, recall= 0.896853
# Train Random guess:  , auc= 0.224793fmeasure_max= 0.365262, precision= 0.223438, recall= 1.000000
# Validation Iter 5700, auc= 0.879170, fmeasure_max= 0.819876, precision= 0.849265, recall= 0.792453
# Validation Random guess:  auc= 0.226463, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.451543
# Tarin Iter 5800, auc= 0.955992, fmeasure_max= 0.900000, precision= 0.907317, recall= 0.892800
# Train Random guess:  , auc= 0.246581fmeasure_max= 0.392947, precision= 0.244610, recall= 0.998400
# Validation Iter 5800, auc= 0.890503, fmeasure_max= 0.817029, precision= 0.865643, recall= 0.773585
# Validation Random guess:  auc= 0.224551, fmeasure_max= 0.371941, precision= 0.229654, recall= 0.977702
# Minibatch Loss= 0.446144
# Tarin Iter 5900, auc= 0.940669, fmeasure_max= 0.891221, precision= 0.915686, recall= 0.868030
# Train Random guess:  , auc= 0.224044fmeasure_max= 0.351271, precision= 0.213569, recall= 0.988848
# Validation Iter 5900, auc= 0.901396, fmeasure_max= 0.826816, precision= 0.904277, recall= 0.761578
# Validation Random guess:  auc= 0.225221, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.397452
# Tarin Iter 6000, auc= 0.968035, fmeasure_max= 0.914141, precision= 0.925043, recall= 0.903494
# Train Random guess:  , auc= 0.237821fmeasure_max= 0.382080, precision= 0.236529, recall= 0.993344
# Validation Iter 6000, auc= 0.908981, fmeasure_max= 0.846782, precision= 0.898077, recall= 0.801029
# Validation Random guess:  auc= 0.219080, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.407286
# Tarin Iter 6100, auc= 0.961587, fmeasure_max= 0.906225, precision= 0.877863, recall= 0.936482
# Train Random guess:  , auc= 0.247903fmeasure_max= 0.390369, precision= 0.243103, recall= 0.990228
# Validation Iter 6100, auc= 0.904409, fmeasure_max= 0.830255, precision= 0.851986, recall= 0.809605
# Validation Random guess:  auc= 0.230264, fmeasure_max= 0.372524, precision= 0.228897, recall= 1.000000
# Minibatch Loss= 0.482542
# Tarin Iter 6200, auc= 0.971568, fmeasure_max= 0.914729, precision= 0.930599, recall= 0.899390
# Train Random guess:  , auc= 0.268228fmeasure_max= 0.411863, precision= 0.263539, recall= 0.942073
# Validation Iter 6200, auc= 0.909329, fmeasure_max= 0.841530, precision= 0.897087, recall= 0.792453
# Validation Random guess:  auc= 0.235125, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.429707
# Tarin Iter 6300, auc= 0.944277, fmeasure_max= 0.875433, precision= 0.870912, recall= 0.880000
# Train Random guess:  , auc= 0.214258fmeasure_max= 0.367307, precision= 0.225962, recall= 0.980870
# Validation Iter 6300, auc= 0.881793, fmeasure_max= 0.819731, precision= 0.859023, recall= 0.783877
# Validation Random guess:  auc= 0.248512, fmeasure_max= 0.372631, precision= 0.229249, recall= 0.994854
# Minibatch Loss= 0.484828
# Tarin Iter 6400, auc= 0.948258, fmeasure_max= 0.869291, precision= 0.859813, recall= 0.878981
# Train Random guess:  , auc= 0.252785fmeasure_max= 0.393977, precision= 0.245312, recall= 1.000000
# Validation Iter 6400, auc= 0.906688, fmeasure_max= 0.839483, precision= 0.908184, recall= 0.780446
# Validation Random guess:  auc= 0.229724, fmeasure_max= 0.372033, precision= 0.228797, recall= 0.994854
# Minibatch Loss= 0.484114
# Tarin Iter 6500, auc= 0.956811, fmeasure_max= 0.895238, precision= 0.888189, recall= 0.902400
# Train Random guess:  , auc= 0.256313fmeasure_max= 0.395462, precision= 0.247967, recall= 0.976000
# Validation Iter 6500, auc= 0.905166, fmeasure_max= 0.833040, precision= 0.854054, recall= 0.813036
# Validation Random guess:  auc= 0.234852, fmeasure_max= 0.372063, precision= 0.229002, recall= 0.991424
# Minibatch Loss= 0.459986
# Tarin Iter 6600, auc= 0.941960, fmeasure_max= 0.857143, precision= 0.851718, recall= 0.862637
# Train Random guess:  , auc= 0.196846fmeasure_max= 0.353364, precision= 0.215024, recall= 0.990842
# Validation Iter 6600, auc= 0.904986, fmeasure_max= 0.831971, precision= 0.884170, recall= 0.785592
# Validation Random guess:  auc= 0.229361, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.409841
# Tarin Iter 6700, auc= 0.947039, fmeasure_max= 0.861069, precision= 0.881250, recall= 0.841791
# Train Random guess:  , auc= 0.266495fmeasure_max= 0.414861, precision= 0.261719, recall= 1.000000
# Validation Iter 6700, auc= 0.906007, fmeasure_max= 0.820091, precision= 0.876953, recall= 0.770154
# Validation Random guess:  auc= 0.226496, fmeasure_max= 0.372892, precision= 0.229908, recall= 0.986278
# Minibatch Loss= 0.550287
# Tarin Iter 6800, auc= 0.958239, fmeasure_max= 0.894100, precision= 0.890060, recall= 0.898176
# Train Random guess:  , auc= 0.253539fmeasure_max= 0.409459, precision= 0.257433, recall= 1.000000
# Validation Iter 6800, auc= 0.890582, fmeasure_max= 0.826958, precision= 0.881553, recall= 0.778731
# Validation Random guess:  auc= 0.242594, fmeasure_max= 0.373230, precision= 0.229703, recall= 0.994854
# Minibatch Loss= 0.489408
# Tarin Iter 6900, auc= 0.974472, fmeasure_max= 0.915044, precision= 0.919929, recall= 0.910211
# Train Random guess:  , auc= 0.221039fmeasure_max= 0.363171, precision= 0.221875, recall= 1.000000
# Validation Iter 6900, auc= 0.895549, fmeasure_max= 0.837715, precision= 0.888462, recall= 0.792453
# Validation Random guess:  auc= 0.231767, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.354548
# Tarin Iter 7000, auc= 0.947459, fmeasure_max= 0.876688, precision= 0.865009, recall= 0.888686
# Train Random guess:  , auc= 0.221062fmeasure_max= 0.353331, precision= 0.215877, recall= 0.972628
# Validation Iter 7000, auc= 0.883815, fmeasure_max= 0.827462, precision= 0.874046, recall= 0.785592
# Validation Random guess:  auc= 0.237396, fmeasure_max= 0.373581, precision= 0.233649, recall= 0.931389
# Minibatch Loss= 0.444069
# Tarin Iter 7100, auc= 0.929110, fmeasure_max= 0.852727, precision= 0.827160, recall= 0.879925
# Train Random guess:  , auc= 0.216016fmeasure_max= 0.345098, precision= 0.208943, recall= 0.990619
# Validation Iter 7100, auc= 0.859356, fmeasure_max= 0.810238, precision= 0.834545, recall= 0.787307
# Validation Random guess:  auc= 0.235272, fmeasure_max= 0.372153, precision= 0.228887, recall= 0.994854
# Minibatch Loss= 0.466438
# Tarin Iter 7200, auc= 0.961796, fmeasure_max= 0.898655, precision= 0.917582, recall= 0.880492
# Train Random guess:  , auc= 0.237276fmeasure_max= 0.364513, precision= 0.223053, recall= 0.996485
# Validation Iter 7200, auc= 0.880873, fmeasure_max= 0.826165, precision= 0.864916, recall= 0.790738
# Validation Random guess:  auc= 0.232163, fmeasure_max= 0.372751, precision= 0.229340, recall= 0.994854
# Minibatch Loss= 0.426982
# Tarin Iter 7300, auc= 0.968933, fmeasure_max= 0.903117, precision= 0.900840, recall= 0.905405
# Train Random guess:  , auc= 0.233929fmeasure_max= 0.376861, precision= 0.235618, recall= 0.940878
# Validation Iter 7300, auc= 0.903999, fmeasure_max= 0.843243, precision= 0.888046, recall= 0.802744
# Validation Random guess:  auc= 0.245987, fmeasure_max= 0.372908, precision= 0.242865, recall= 0.802744
# Minibatch Loss= 0.403210
# Tarin Iter 7400, auc= 0.977376, fmeasure_max= 0.913121, precision= 0.906690, recall= 0.919643
# Train Random guess:  , auc= 0.217808fmeasure_max= 0.359623, precision= 0.219754, recall= 0.989286
# Validation Iter 7400, auc= 0.891880, fmeasure_max= 0.839709, precision= 0.895146, recall= 0.790738
# Validation Random guess:  auc= 0.213101, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.389233
# Tarin Iter 7500, auc= 0.961607, fmeasure_max= 0.908810, precision= 0.886878, recall= 0.931854
# Train Random guess:  , auc= 0.250444fmeasure_max= 0.396595, precision= 0.247540, recall= 0.996830
# Validation Iter 7500, auc= 0.896581, fmeasure_max= 0.830123, precision= 0.847943, recall= 0.813036
# Validation Random guess:  auc= 0.221643, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.396347
# Tarin Iter 7600, auc= 0.949921, fmeasure_max= 0.875190, precision= 0.877863, recall= 0.872534
# Train Random guess:  , auc= 0.258369fmeasure_max= 0.409444, precision= 0.257422, recall= 1.000000
# Validation Iter 7600, auc= 0.888423, fmeasure_max= 0.822430, precision= 0.903491, recall= 0.754717
# Validation Random guess:  auc= 0.228907, fmeasure_max= 0.372568, precision= 0.230612, recall= 0.969125
# Minibatch Loss= 0.466930
# Tarin Iter 7700, auc= 0.964837, fmeasure_max= 0.899718, precision= 0.894663, recall= 0.904830
# Train Random guess:  , auc= 0.277538fmeasure_max= 0.431922, precision= 0.280220, recall= 0.941761
# Validation Iter 7700, auc= 0.892624, fmeasure_max= 0.833778, precision= 0.865314, recall= 0.804460
# Validation Random guess:  auc= 0.216172, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.503834
# Tarin Iter 7800, auc= 0.953930, fmeasure_max= 0.886957, precision= 0.888502, recall= 0.885417
# Train Random guess:  , auc= 0.215950fmeasure_max= 0.367347, precision= 0.225000, recall= 1.000000
# Validation Iter 7800, auc= 0.898224, fmeasure_max= 0.836879, precision= 0.866055, recall= 0.809605
# Validation Random guess:  auc= 0.223622, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.412331
# Tarin Iter 7900, auc= 0.968189, fmeasure_max= 0.904514, precision= 0.864013, recall= 0.948998
# Train Random guess:  , auc= 0.220833fmeasure_max= 0.353473, precision= 0.214847, recall= 0.996357
# Validation Iter 7900, auc= 0.889333, fmeasure_max= 0.830824, precision= 0.858974, recall= 0.804460
# Validation Random guess:  auc= 0.226326, fmeasure_max= 0.372032, precision= 0.230298, recall= 0.967410
# Minibatch Loss= 0.399254
# Tarin Iter 8000, auc= 0.941812, fmeasure_max= 0.876761, precision= 0.873684, recall= 0.879859
# Train Random guess:  , auc= 0.220261fmeasure_max= 0.362588, precision= 0.221440, recall= 1.000000
# Validation Iter 8000, auc= 0.898577, fmeasure_max= 0.830683, precision= 0.913580, recall= 0.761578
# Validation Random guess:  auc= 0.228325, fmeasure_max= 0.372524, precision= 0.228897, recall= 1.000000
# Minibatch Loss= 0.440836
# Tarin Iter 8100, auc= 0.966013, fmeasure_max= 0.905609, precision= 0.916898, recall= 0.894595
# Train Random guess:  , auc= 0.308380fmeasure_max= 0.449802, precision= 0.290501, recall= 0.995946
# Validation Iter 8100, auc= 0.895826, fmeasure_max= 0.829312, precision= 0.865672, recall= 0.795883
# Validation Random guess:  auc= 0.222990, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.526285
# Tarin Iter 8200, auc= 0.955969, fmeasure_max= 0.887160, precision= 0.892368, recall= 0.882012
# Train Random guess:  , auc= 0.197939fmeasure_max= 0.338682, precision= 0.205638, recall= 0.959381
# Validation Iter 8200, auc= 0.898701, fmeasure_max= 0.834081, precision= 0.874060, recall= 0.797599
# Validation Random guess:  auc= 0.231336, fmeasure_max= 0.372947, precision= 0.229580, recall= 0.993139
# Minibatch Loss= 0.410182
# Tarin Iter 8300, auc= 0.975340, fmeasure_max= 0.928953, precision= 0.922610, recall= 0.935385
# Train Random guess:  , auc= 0.255960fmeasure_max= 0.405397, precision= 0.254631, recall= 0.993846
# Validation Iter 8300, auc= 0.888820, fmeasure_max= 0.815838, precision= 0.880716, recall= 0.759863
# Validation Random guess:  auc= 0.241180, fmeasure_max= 0.375376, precision= 0.233167, recall= 0.962264
# Minibatch Loss= 0.431466
# Tarin Iter 8400, auc= 0.956469, fmeasure_max= 0.888683, precision= 0.841828, recall= 0.941061
# Train Random guess:  , auc= 0.225133fmeasure_max= 0.332957, precision= 0.205965, recall= 0.868369
# Validation Iter 8400, auc= 0.903624, fmeasure_max= 0.849462, precision= 0.889306, recall= 0.813036
# Validation Random guess:  auc= 0.218255, fmeasure_max= 0.371254, precision= 0.228571, recall= 0.987993
# Minibatch Loss= 0.384043
# Tarin Iter 8500, auc= 0.977385, fmeasure_max= 0.914777, precision= 0.914062, recall= 0.915493
# Train Random guess:  , auc= 0.241205fmeasure_max= 0.401395, precision= 0.251690, recall= 0.990610
# Validation Iter 8500, auc= 0.888252, fmeasure_max= 0.827523, precision= 0.889546, recall= 0.773585
# Validation Random guess:  auc= 0.240832, fmeasure_max= 0.373634, precision= 0.231527, recall= 0.967410
# Minibatch Loss= 0.429650
# Tarin Iter 8600, auc= 0.955558, fmeasure_max= 0.898477, precision= 0.877686, recall= 0.920277
# Train Random guess:  , auc= 0.229091fmeasure_max= 0.367985, precision= 0.225479, recall= 1.000000
# Validation Iter 8600, auc= 0.894491, fmeasure_max= 0.833942, precision= 0.890838, recall= 0.783877
# Validation Random guess:  auc= 0.229133, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.396998
# Tarin Iter 8700, auc= 0.947967, fmeasure_max= 0.884083, precision= 0.882556, recall= 0.885615
# Train Random guess:  , auc= 0.241559fmeasure_max= 0.367867, precision= 0.225391, recall= 1.000000
# Validation Iter 8700, auc= 0.893571, fmeasure_max= 0.824336, precision= 0.823630, recall= 0.825043
# Validation Random guess:  auc= 0.224715, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.424418
# Tarin Iter 8800, auc= 0.939240, fmeasure_max= 0.873603, precision= 0.905526, recall= 0.843854
# Train Random guess:  , auc= 0.250976fmeasure_max= 0.383544, precision= 0.238229, recall= 0.983389
# Validation Iter 8800, auc= 0.878065, fmeasure_max= 0.825806, precision= 0.892430, recall= 0.768439
# Validation Random guess:  auc= 0.236207, fmeasure_max= 0.376376, precision= 0.233637, recall= 0.967410
# Minibatch Loss= 0.502931
# Tarin Iter 8900, auc= 0.962572, fmeasure_max= 0.890226, precision= 0.836158, recall= 0.951768
# Train Random guess:  , auc= 0.240864fmeasure_max= 0.390949, precision= 0.242969, recall= 1.000000
# Validation Iter 8900, auc= 0.894406, fmeasure_max= 0.821966, precision= 0.849817, recall= 0.795883
# Validation Random guess:  auc= 0.232016, fmeasure_max= 0.372765, precision= 0.233118, recall= 0.929674
# Minibatch Loss= 0.424300
# Tarin Iter 9000, auc= 0.957850, fmeasure_max= 0.901857, precision= 0.899471, recall= 0.904255
# Train Random guess:  , auc= 0.219918fmeasure_max= 0.361709, precision= 0.220871, recall= 0.998227
# Validation Iter 9000, auc= 0.888749, fmeasure_max= 0.828025, precision= 0.881783, recall= 0.780446
# Validation Random guess:  auc= 0.242529, fmeasure_max= 0.374256, precision= 0.238955, recall= 0.862779
# Minibatch Loss= 0.416637
# Tarin Iter 9100, auc= 0.972811, fmeasure_max= 0.909769, precision= 0.920060, recall= 0.899705
# Train Random guess:  , auc= 0.270340fmeasure_max= 0.419904, precision= 0.268363, recall= 0.964602
# Validation Iter 9100, auc= 0.899219, fmeasure_max= 0.831239, precision= 0.871940, recall= 0.794168
# Validation Random guess:  auc= 0.217341, fmeasure_max= 0.373533, precision= 0.230584, recall= 0.982847
# Minibatch Loss= 0.488134
# Tarin Iter 9200, auc= 0.971109, fmeasure_max= 0.910790, precision= 0.917808, recall= 0.903879
# Train Random guess:  , auc= 0.229231fmeasure_max= 0.376628, precision= 0.232003, recall= 1.000000
# Validation Iter 9200, auc= 0.907807, fmeasure_max= 0.839350, precision= 0.885714, recall= 0.797599
# Validation Random guess:  auc= 0.223639, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.441837
# Tarin Iter 9300, auc= 0.947270, fmeasure_max= 0.879720, precision= 0.887165, recall= 0.872399
# Train Random guess:  , auc= 0.283217fmeasure_max= 0.440909, precision= 0.287834, recall= 0.941748
# Validation Iter 9300, auc= 0.896124, fmeasure_max= 0.845249, precision= 0.894636, recall= 0.801029
# Validation Random guess:  auc= 0.214488, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.566382
# Tarin Iter 9400, auc= 0.974447, fmeasure_max= 0.911463, precision= 0.887477, recall= 0.936782
# Train Random guess:  , auc= 0.196964fmeasure_max= 0.339292, precision= 0.204305, recall= 1.000000
# Validation Iter 9400, auc= 0.894369, fmeasure_max= 0.828025, precision= 0.881783, recall= 0.780446
# Validation Random guess:  auc= 0.243663, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.335337
# Tarin Iter 9500, auc= 0.948444, fmeasure_max= 0.893417, precision= 0.883721, recall= 0.903328
# Train Random guess:  , auc= 0.235803fmeasure_max= 0.395487, precision= 0.246484, recall= 1.000000
# Validation Iter 9500, auc= 0.901128, fmeasure_max= 0.850694, precision= 0.861160, recall= 0.840480
# Validation Random guess:  auc= 0.245134, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.483696
# Tarin Iter 9600, auc= 0.954854, fmeasure_max= 0.888321, precision= 0.910839, recall= 0.866889
# Train Random guess:  , auc= 0.247111fmeasure_max= 0.380259, precision= 0.234766, recall= 1.000000
# Validation Iter 9600, auc= 0.903582, fmeasure_max= 0.840731, precision= 0.853357, recall= 0.828473
# Validation Random guess:  auc= 0.229664, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.412306
# Tarin Iter 9700, auc= 0.963541, fmeasure_max= 0.905597, precision= 0.942609, recall= 0.871383
# Train Random guess:  , auc= 0.245701fmeasure_max= 0.391746, precision= 0.244066, recall= 0.991961
# Validation Iter 9700, auc= 0.897766, fmeasure_max= 0.844004, precision= 0.889734, recall= 0.802744
# Validation Random guess:  auc= 0.225824, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.432320
# Tarin Iter 9800, auc= 0.969063, fmeasure_max= 0.905229, precision= 0.889246, recall= 0.921797
# Train Random guess:  , auc= 0.225015fmeasure_max= 0.380438, precision= 0.235086, recall= 0.996672
# Validation Iter 9800, auc= 0.896264, fmeasure_max= 0.826691, precision= 0.899194, recall= 0.765009
# Validation Random guess:  auc= 0.228745, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.417849
# Tarin Iter 9900, auc= 0.963584, fmeasure_max= 0.894695, precision= 0.874613, recall= 0.915721
# Train Random guess:  , auc= 0.235918fmeasure_max= 0.389841, precision= 0.242400, recall= 0.995138
# Validation Iter 9900, auc= 0.900201, fmeasure_max= 0.844365, precision= 0.882243, recall= 0.809605
# Validation Random guess:  auc= 0.223202, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.454790
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.851383 F1_max = 0.811280 prec = 0.801517 rec = 0.821284
# Test Random guess: auc= 0.234386 fmeasure_max= 0.375715 , precision= 0.231374 , recall= 0.998818

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
