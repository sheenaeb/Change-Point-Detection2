# %%
# useing this variable for saving models and summaries
exp_name = "CNN1021"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [4, 2, 2, 2, 1]
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.193864, fmeasure_max= 0.374677, precision= 0.247300, recall= 0.772647
# Train Random guess:  , auc= 0.233275fmeasure_max= 0.362739, precision= 0.222626, recall= 0.978686
# Validation Iter 0, auc= 0.221294, fmeasure_max= 0.373085, precision= 0.231501, recall= 0.960549
# Validation Random guess:  auc= 0.245933, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 1.039741
# Tarin Iter 100, auc= 0.714494, fmeasure_max= 0.690154, precision= 0.765531, recall= 0.628289
# Train Random guess:  , auc= 0.234320fmeasure_max= 0.383960, precision= 0.237593, recall= 1.000000
# Validation Iter 100, auc= 0.706676, fmeasure_max= 0.677196, precision= 0.797674, recall= 0.588336
# Validation Random guess:  auc= 0.239546, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.973865
# Tarin Iter 200, auc= 0.813734, fmeasure_max= 0.779777, precision= 0.821300, recall= 0.742251
# Train Random guess:  , auc= 0.245424fmeasure_max= 0.386751, precision= 0.239734, recall= 1.000000
# Validation Iter 200, auc= 0.806787, fmeasure_max= 0.773006, precision= 0.790323, recall= 0.756432
# Validation Random guess:  auc= 0.220483, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.748843
# Tarin Iter 300, auc= 0.833298, fmeasure_max= 0.792850, precision= 0.802128, recall= 0.783784
# Train Random guess:  , auc= 0.178723fmeasure_max= 0.317639, precision= 0.188955, recall= 0.995842
# Validation Iter 300, auc= 0.825899, fmeasure_max= 0.767327, precision= 0.739269, recall= 0.797599
# Validation Random guess:  auc= 0.223160, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.574944
# Tarin Iter 400, auc= 0.745600, fmeasure_max= 0.740016, precision= 0.802120, recall= 0.686838
# Train Random guess:  , auc= 0.263297fmeasure_max= 0.410814, precision= 0.258506, recall= 1.000000
# Validation Iter 400, auc= 0.844459, fmeasure_max= 0.790861, precision= 0.810811, recall= 0.771870
# Validation Random guess:  auc= 0.222857, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.869474
# Tarin Iter 500, auc= 0.841143, fmeasure_max= 0.788991, precision= 0.821656, recall= 0.758824
# Train Random guess:  , auc= 0.219944fmeasure_max= 0.337341, precision= 0.203301, recall= 0.990196
# Validation Iter 500, auc= 0.848847, fmeasure_max= 0.783607, precision= 0.750392, recall= 0.819897
# Validation Random guess:  auc= 0.244936, fmeasure_max= 0.371795, precision= 0.228616, recall= 0.994854
# Minibatch Loss= 0.624045
# Tarin Iter 600, auc= 0.819637, fmeasure_max= 0.740501, precision= 0.802102, recall= 0.687688
# Train Random guess:  , auc= 0.259986fmeasure_max= 0.414272, precision= 0.262295, recall= 0.984985
# Validation Iter 600, auc= 0.882526, fmeasure_max= 0.828523, precision= 0.820168, recall= 0.837050
# Validation Random guess:  auc= 0.223874, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.759062
# Tarin Iter 700, auc= 0.862793, fmeasure_max= 0.808140, precision= 0.810496, recall= 0.805797
# Train Random guess:  , auc= 0.262987fmeasure_max= 0.426617, precision= 0.271576, recall= 0.994203
# Validation Iter 700, auc= 0.867859, fmeasure_max= 0.829769, precision= 0.827645, recall= 0.831904
# Validation Random guess:  auc= 0.233236, fmeasure_max= 0.371676, precision= 0.228526, recall= 0.994854
# Minibatch Loss= 0.705564
# Tarin Iter 800, auc= 0.883942, fmeasure_max= 0.835061, precision= 0.842205, recall= 0.828037
# Train Random guess:  , auc= 0.212874fmeasure_max= 0.347086, precision= 0.210401, recall= 0.990654
# Validation Iter 800, auc= 0.878297, fmeasure_max= 0.830438, precision= 0.801917, recall= 0.861063
# Validation Random guess:  auc= 0.234409, fmeasure_max= 0.373034, precision= 0.229463, recall= 0.996569
# Minibatch Loss= 0.583622
# Tarin Iter 900, auc= 0.862902, fmeasure_max= 0.816652, precision= 0.842779, recall= 0.792096
# Train Random guess:  , auc= 0.230128fmeasure_max= 0.370701, precision= 0.227522, recall= 1.000000
# Validation Iter 900, auc= 0.899759, fmeasure_max= 0.845705, precision= 0.823052, recall= 0.869640
# Validation Random guess:  auc= 0.213779, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.638307
# Tarin Iter 1000, auc= 0.889575, fmeasure_max= 0.846422, precision= 0.852373, recall= 0.840555
# Train Random guess:  , auc= 0.224059fmeasure_max= 0.367867, precision= 0.225391, recall= 1.000000
# Validation Iter 1000, auc= 0.885894, fmeasure_max= 0.844974, precision= 0.839255, recall= 0.850772
# Validation Random guess:  auc= 0.224709, fmeasure_max= 0.373212, precision= 0.230245, recall= 0.984563
# Minibatch Loss= 0.655987
# Tarin Iter 1100, auc= 0.849021, fmeasure_max= 0.789427, precision= 0.825046, recall= 0.756757
# Train Random guess:  , auc= 0.226412fmeasure_max= 0.376710, precision= 0.232066, recall= 1.000000
# Validation Iter 1100, auc= 0.895656, fmeasure_max= 0.842546, precision= 0.823241, recall= 0.862779
# Validation Random guess:  auc= 0.231133, fmeasure_max= 0.374534, precision= 0.233333, recall= 0.948542
# Minibatch Loss= 0.662405
# Tarin Iter 1200, auc= 0.889097, fmeasure_max= 0.817844, precision= 0.834915, recall= 0.801457
# Train Random guess:  , auc= 0.214613fmeasure_max= 0.353851, precision= 0.214957, recall= 1.000000
# Validation Iter 1200, auc= 0.906121, fmeasure_max= 0.844955, precision= 0.809748, recall= 0.883362
# Validation Random guess:  auc= 0.228518, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.573852
# Tarin Iter 1300, auc= 0.865221, fmeasure_max= 0.818792, precision= 0.885662, recall= 0.761310
# Train Random guess:  , auc= 0.248574fmeasure_max= 0.400500, precision= 0.250391, recall= 1.000000
# Validation Iter 1300, auc= 0.902910, fmeasure_max= 0.846400, precision= 0.793103, recall= 0.907376
# Validation Random guess:  auc= 0.221252, fmeasure_max= 0.373506, precision= 0.230096, recall= 0.991424
# Minibatch Loss= 0.674870
# Tarin Iter 1400, auc= 0.896462, fmeasure_max= 0.854288, precision= 0.853577, recall= 0.855000
# Train Random guess:  , auc= 0.244961fmeasure_max= 0.384063, precision= 0.238830, recall= 0.980000
# Validation Iter 1400, auc= 0.828935, fmeasure_max= 0.827141, precision= 0.781679, recall= 0.878216
# Validation Random guess:  auc= 0.264617, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.583741
# Tarin Iter 1500, auc= 0.848658, fmeasure_max= 0.802855, precision= 0.819672, recall= 0.786713
# Train Random guess:  , auc= 0.231243fmeasure_max= 0.371134, precision= 0.229158, recall= 0.975524
# Validation Iter 1500, auc= 0.816851, fmeasure_max= 0.801047, precision= 0.815275, recall= 0.787307
# Validation Random guess:  auc= 0.229295, fmeasure_max= 0.371578, precision= 0.229376, recall= 0.977702
# Minibatch Loss= 0.676811
# Tarin Iter 1600, auc= 0.848510, fmeasure_max= 0.820696, precision= 0.842491, recall= 0.800000
# Train Random guess:  , auc= 0.223753fmeasure_max= 0.366943, precision= 0.224697, recall= 1.000000
# Validation Iter 1600, auc= 0.820702, fmeasure_max= 0.798021, precision= 0.768254, recall= 0.830189
# Validation Random guess:  auc= 0.222500, fmeasure_max= 0.372123, precision= 0.229416, recall= 0.984563
# Minibatch Loss= 0.668883
# Tarin Iter 1700, auc= 0.860021, fmeasure_max= 0.834375, precision= 0.862682, recall= 0.807867
# Train Random guess:  , auc= 0.249686fmeasure_max= 0.411122, precision= 0.259055, recall= 0.995461
# Validation Iter 1700, auc= 0.846452, fmeasure_max= 0.791630, precision= 0.804965, recall= 0.778731
# Validation Random guess:  auc= 0.218061, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.663717
# Tarin Iter 1800, auc= 0.879319, fmeasure_max= 0.834906, precision= 0.846890, recall= 0.823256
# Train Random guess:  , auc= 0.247684fmeasure_max= 0.403130, precision= 0.252549, recall= 0.998450
# Validation Iter 1800, auc= 0.869252, fmeasure_max= 0.805873, precision= 0.768274, recall= 0.847341
# Validation Random guess:  auc= 0.231734, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.646628
# Tarin Iter 1900, auc= 0.857229, fmeasure_max= 0.794547, precision= 0.886957, recall= 0.719577
# Train Random guess:  , auc= 0.229071fmeasure_max= 0.363462, precision= 0.222092, recall= 1.000000
# Validation Iter 1900, auc= 0.843571, fmeasure_max= 0.805532, precision= 0.811847, recall= 0.799314
# Validation Random guess:  auc= 0.254572, fmeasure_max= 0.374332, precision= 0.240786, recall= 0.840480
# Minibatch Loss= 0.631380
# Tarin Iter 2000, auc= 0.891337, fmeasure_max= 0.831768, precision= 0.813022, recall= 0.851399
# Train Random guess:  , auc= 0.215509fmeasure_max= 0.366742, precision= 0.224812, recall= 0.994755
# Validation Iter 2000, auc= 0.848178, fmeasure_max= 0.805825, precision= 0.762634, recall= 0.854202
# Validation Random guess:  auc= 0.238519, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.541258
# Tarin Iter 2100, auc= 0.844849, fmeasure_max= 0.761578, precision= 0.826816, recall= 0.705882
# Train Random guess:  , auc= 0.234690fmeasure_max= 0.394976, precision= 0.246088, recall= 1.000000
# Validation Iter 2100, auc= 0.864502, fmeasure_max= 0.795021, precision= 0.770096, recall= 0.821612
# Validation Random guess:  auc= 0.232633, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.695572
# Tarin Iter 2200, auc= 0.893643, fmeasure_max= 0.817863, precision= 0.812174, recall= 0.823633
# Train Random guess:  , auc= 0.222600fmeasure_max= 0.364542, precision= 0.224540, recall= 0.968254
# Validation Iter 2200, auc= 0.854691, fmeasure_max= 0.781646, precision= 0.725404, recall= 0.847341
# Validation Random guess:  auc= 0.223906, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.581759
# Tarin Iter 2300, auc= 0.864085, fmeasure_max= 0.786311, precision= 0.753600, recall= 0.821990
# Train Random guess:  , auc= 0.225964fmeasure_max= 0.367150, precision= 0.225118, recall= 0.994764
# Validation Iter 2300, auc= 0.881818, fmeasure_max= 0.798291, precision= 0.795571, recall= 0.801029
# Validation Random guess:  auc= 0.237619, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.594950
# Tarin Iter 2400, auc= 0.855502, fmeasure_max= 0.813708, precision= 0.803819, recall= 0.823843
# Train Random guess:  , auc= 0.228336fmeasure_max= 0.360141, precision= 0.219617, recall= 1.000000
# Validation Iter 2400, auc= 0.857343, fmeasure_max= 0.782965, precision= 0.749216, recall= 0.819897
# Validation Random guess:  auc= 0.232941, fmeasure_max= 0.373788, precision= 0.232143, recall= 0.958834
# Minibatch Loss= 0.640308
# Tarin Iter 2500, auc= 0.861040, fmeasure_max= 0.809723, precision= 0.847368, recall= 0.775281
# Train Random guess:  , auc= 0.239442fmeasure_max= 0.391578, precision= 0.243454, recall= 1.000000
# Validation Iter 2500, auc= 0.876534, fmeasure_max= 0.792808, precision= 0.791453, recall= 0.794168
# Validation Random guess:  auc= 0.236851, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.705621
# Tarin Iter 2600, auc= 0.815313, fmeasure_max= 0.773408, precision= 0.766234, recall= 0.780718
# Train Random guess:  , auc= 0.201160fmeasure_max= 0.342646, precision= 0.208436, recall= 0.962193
# Validation Iter 2600, auc= 0.862591, fmeasure_max= 0.798982, precision= 0.790268, recall= 0.807890
# Validation Random guess:  auc= 0.226158, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.634023
# Tarin Iter 2700, auc= 0.873534, fmeasure_max= 0.802041, precision= 0.829114, recall= 0.776680
# Train Random guess:  , auc= 0.202924fmeasure_max= 0.330287, precision= 0.197811, recall= 1.000000
# Validation Iter 2700, auc= 0.868972, fmeasure_max= 0.789207, precision= 0.776119, recall= 0.802744
# Validation Random guess:  auc= 0.232127, fmeasure_max= 0.371227, precision= 0.228368, recall= 0.991424
# Minibatch Loss= 0.542269
# Tarin Iter 2800, auc= 0.903594, fmeasure_max= 0.824427, precision= 0.822335, recall= 0.826531
# Train Random guess:  , auc= 0.242546fmeasure_max= 0.374920, precision= 0.231166, recall= 0.991497
# Validation Iter 2800, auc= 0.870030, fmeasure_max= 0.775937, precision= 0.789007, recall= 0.763293
# Validation Random guess:  auc= 0.226890, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.550277
# Tarin Iter 2900, auc= 0.933656, fmeasure_max= 0.883640, precision= 0.857385, recall= 0.911552
# Train Random guess:  , auc= 0.230286fmeasure_max= 0.356200, precision= 0.216778, recall= 0.998195
# Validation Iter 2900, auc= 0.864019, fmeasure_max= 0.781034, precision= 0.785095, recall= 0.777015
# Validation Random guess:  auc= 0.217621, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.469026
# Tarin Iter 3000, auc= 0.899692, fmeasure_max= 0.812245, precision= 0.825726, recall= 0.799197
# Train Random guess:  , auc= 0.195248fmeasure_max= 0.325941, precision= 0.195722, recall= 0.973896
# Validation Iter 3000, auc= 0.876540, fmeasure_max= 0.774089, precision= 0.733129, recall= 0.819897
# Validation Random guess:  auc= 0.235705, fmeasure_max= 0.372870, precision= 0.229430, recall= 0.994854
# Minibatch Loss= 0.470888
# Tarin Iter 3100, auc= 0.939304, fmeasure_max= 0.870886, precision= 0.864322, recall= 0.877551
# Train Random guess:  , auc= 0.220276fmeasure_max= 0.373571, precision= 0.229687, recall= 1.000000
# Validation Iter 3100, auc= 0.884173, fmeasure_max= 0.795161, precision= 0.750381, recall= 0.845626
# Validation Random guess:  auc= 0.226075, fmeasure_max= 0.371127, precision= 0.228022, recall= 0.996569
# Minibatch Loss= 0.506780
# Tarin Iter 3200, auc= 0.875969, fmeasure_max= 0.791189, precision= 0.828413, recall= 0.757167
# Train Random guess:  , auc= 0.242700fmeasure_max= 0.378808, precision= 0.235682, recall= 0.964587
# Validation Iter 3200, auc= 0.864128, fmeasure_max= 0.762324, precision= 0.783002, recall= 0.742710
# Validation Random guess:  auc= 0.215268, fmeasure_max= 0.373978, precision= 0.231018, recall= 0.981132
# Minibatch Loss= 0.633426
# Tarin Iter 3300, auc= 0.921032, fmeasure_max= 0.856287, precision= 0.848665, recall= 0.864048
# Train Random guess:  , auc= 0.274006fmeasure_max= 0.412114, precision= 0.259740, recall= 0.996979
# Validation Iter 3300, auc= 0.876187, fmeasure_max= 0.780529, precision= 0.777211, recall= 0.783877
# Validation Random guess:  auc= 0.233150, fmeasure_max= 0.372523, precision= 0.230675, recall= 0.967410
# Minibatch Loss= 0.545135
# Tarin Iter 3400, auc= 0.933514, fmeasure_max= 0.856083, precision= 0.849779, recall= 0.862481
# Train Random guess:  , auc= 0.261025fmeasure_max= 0.415236, precision= 0.262431, recall= 0.994021
# Validation Iter 3400, auc= 0.880386, fmeasure_max= 0.794250, precision= 0.833962, recall= 0.758148
# Validation Random guess:  auc= 0.226220, fmeasure_max= 0.373597, precision= 0.231304, recall= 0.970840
# Minibatch Loss= 0.541962
# Tarin Iter 3500, auc= 0.966402, fmeasure_max= 0.897356, precision= 0.893189, recall= 0.901563
# Train Random guess:  , auc= 0.258941fmeasure_max= 0.400502, precision= 0.250589, recall= 0.996875
# Validation Iter 3500, auc= 0.874971, fmeasure_max= 0.791155, precision= 0.757053, recall= 0.828473
# Validation Random guess:  auc= 0.215020, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.508436
# Tarin Iter 3600, auc= 0.949169, fmeasure_max= 0.894281, precision= 0.905263, recall= 0.883562
# Train Random guess:  , auc= 0.225734fmeasure_max= 0.373351, precision= 0.231209, recall= 0.969178
# Validation Iter 3600, auc= 0.882223, fmeasure_max= 0.787129, precision= 0.758347, recall= 0.818182
# Validation Random guess:  auc= 0.233390, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.509153
# Tarin Iter 3700, auc= 0.931047, fmeasure_max= 0.860896, precision= 0.864907, recall= 0.856923
# Train Random guess:  , auc= 0.258684fmeasure_max= 0.404984, precision= 0.253906, recall= 1.000000
# Validation Iter 3700, auc= 0.864405, fmeasure_max= 0.789869, precision= 0.871636, recall= 0.722127
# Validation Random guess:  auc= 0.215513, fmeasure_max= 0.372108, precision= 0.228944, recall= 0.993139
# Minibatch Loss= 0.530854
# Tarin Iter 3800, auc= 0.889318, fmeasure_max= 0.821089, precision= 0.858951, recall= 0.786424
# Train Random guess:  , auc= 0.238920fmeasure_max= 0.382158, precision= 0.236214, recall= 1.000000
# Validation Iter 3800, auc= 0.888801, fmeasure_max= 0.797054, precision= 0.762128, recall= 0.835334
# Validation Random guess:  auc= 0.223324, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.620529
# Tarin Iter 3900, auc= 0.908206, fmeasure_max= 0.857143, precision= 0.902542, recall= 0.816092
# Train Random guess:  , auc= 0.214002fmeasure_max= 0.341639, precision= 0.206092, recall= 0.998084
# Validation Iter 3900, auc= 0.894180, fmeasure_max= 0.806310, precision= 0.824373, recall= 0.789022
# Validation Random guess:  auc= 0.225865, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.500053
# Tarin Iter 4000, auc= 0.903096, fmeasure_max= 0.839623, precision= 0.869141, recall= 0.812044
# Train Random guess:  , auc= 0.215046fmeasure_max= 0.353856, precision= 0.215130, recall= 0.996350
# Validation Iter 4000, auc= 0.893378, fmeasure_max= 0.814087, precision= 0.778997, recall= 0.852487
# Validation Random guess:  auc= 0.218970, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.559798
# Tarin Iter 4100, auc= 0.911593, fmeasure_max= 0.832965, precision= 0.878882, recall= 0.791608
# Train Random guess:  , auc= 0.265495fmeasure_max= 0.436908, precision= 0.279515, recall= 1.000000
# Validation Iter 4100, auc= 0.884883, fmeasure_max= 0.786127, precision= 0.896703, recall= 0.699828
# Validation Random guess:  auc= 0.215965, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.687922
# Tarin Iter 4200, auc= 0.944830, fmeasure_max= 0.883309, precision= 0.887240, recall= 0.879412
# Train Random guess:  , auc= 0.271849fmeasure_max= 0.419883, precision= 0.265729, recall= 1.000000
# Validation Iter 4200, auc= 0.842824, fmeasure_max= 0.766798, precision= 0.904429, recall= 0.665523
# Validation Random guess:  auc= 0.231643, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.574885
# Tarin Iter 4300, auc= 0.919456, fmeasure_max= 0.863874, precision= 0.918367, recall= 0.815486
# Train Random guess:  , auc= 0.256810fmeasure_max= 0.384217, precision= 0.239034, recall= 0.978583
# Validation Iter 4300, auc= 0.882789, fmeasure_max= 0.797407, precision= 0.755760, recall= 0.843911
# Validation Random guess:  auc= 0.232602, fmeasure_max= 0.372675, precision= 0.229191, recall= 0.996569
# Minibatch Loss= 0.557580
# Tarin Iter 4400, auc= 0.934649, fmeasure_max= 0.856909, precision= 0.856209, recall= 0.857610
# Train Random guess:  , auc= 0.228026fmeasure_max= 0.385732, precision= 0.238952, recall= 1.000000
# Validation Iter 4400, auc= 0.842978, fmeasure_max= 0.764151, precision= 0.849057, recall= 0.694683
# Validation Random guess:  auc= 0.226903, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.514808
# Tarin Iter 4500, auc= 0.940826, fmeasure_max= 0.872322, precision= 0.867121, recall= 0.877586
# Train Random guess:  , auc= 0.245834fmeasure_max= 0.369920, precision= 0.227112, recall= 0.996552
# Validation Iter 4500, auc= 0.882866, fmeasure_max= 0.793831, precision= 0.753467, recall= 0.838765
# Validation Random guess:  auc= 0.221273, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.506004
# Tarin Iter 4600, auc= 0.937308, fmeasure_max= 0.867925, precision= 0.863039, recall= 0.872865
# Train Random guess:  , auc= 0.191076fmeasure_max= 0.341875, precision= 0.206182, recall= 1.000000
# Validation Iter 4600, auc= 0.873685, fmeasure_max= 0.783270, precision= 0.878465, recall= 0.706690
# Validation Random guess:  auc= 0.227426, fmeasure_max= 0.372762, precision= 0.229077, recall= 1.000000
# Minibatch Loss= 0.456331
# Tarin Iter 4700, auc= 0.943988, fmeasure_max= 0.885837, precision= 0.924731, recall= 0.850082
# Train Random guess:  , auc= 0.232158fmeasure_max= 0.384371, precision= 0.238095, recall= 0.996705
# Validation Iter 4700, auc= 0.882882, fmeasure_max= 0.802855, precision= 0.836431, recall= 0.771870
# Validation Random guess:  auc= 0.235306, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.506295
# Tarin Iter 4800, auc= 0.917656, fmeasure_max= 0.853782, precision= 0.866894, recall= 0.841060
# Train Random guess:  , auc= 0.231314fmeasure_max= 0.382037, precision= 0.236122, recall= 1.000000
# Validation Iter 4800, auc= 0.876377, fmeasure_max= 0.791227, precision= 0.751543, recall= 0.835334
# Validation Random guess:  auc= 0.235698, fmeasure_max= 0.373154, precision= 0.231957, recall= 0.953688
# Minibatch Loss= 0.554457
# Tarin Iter 4900, auc= 0.950828, fmeasure_max= 0.884018, precision= 0.913208, recall= 0.856637
# Train Random guess:  , auc= 0.236804fmeasure_max= 0.363339, precision= 0.222892, recall= 0.982301
# Validation Iter 4900, auc= 0.865278, fmeasure_max= 0.779370, precision= 0.879310, recall= 0.699828
# Validation Random guess:  auc= 0.234497, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.455730
# Tarin Iter 5000, auc= 0.951376, fmeasure_max= 0.874788, precision= 0.899130, recall= 0.851730
# Train Random guess:  , auc= 0.269017fmeasure_max= 0.383328, precision= 0.237109, recall= 1.000000
# Validation Iter 5000, auc= 0.857845, fmeasure_max= 0.766820, precision= 0.828685, recall= 0.713551
# Validation Random guess:  auc= 0.225649, fmeasure_max= 0.372480, precision= 0.228954, recall= 0.998285
# Minibatch Loss= 0.475042
# Tarin Iter 5100, auc= 0.925946, fmeasure_max= 0.844082, precision= 0.894464, recall= 0.799073
# Train Random guess:  , auc= 0.233530fmeasure_max= 0.403882, precision= 0.253239, recall= 0.996909
# Validation Iter 5100, auc= 0.874844, fmeasure_max= 0.803957, precision= 0.844991, recall= 0.766724
# Validation Random guess:  auc= 0.236201, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.550026
# Tarin Iter 5200, auc= 0.928385, fmeasure_max= 0.857383, precision= 0.869048, recall= 0.846026
# Train Random guess:  , auc= 0.228995fmeasure_max= 0.381795, precision= 0.235937, recall= 1.000000
# Validation Iter 5200, auc= 0.872914, fmeasure_max= 0.796718, precision= 0.850195, recall= 0.749571
# Validation Random guess:  auc= 0.223770, fmeasure_max= 0.373783, precision= 0.230492, recall= 0.987993
# Minibatch Loss= 0.526950
# Tarin Iter 5300, auc= 0.955155, fmeasure_max= 0.889577, precision= 0.901674, recall= 0.877800
# Train Random guess:  , auc= 0.196054fmeasure_max= 0.322366, precision= 0.192613, recall= 0.987780
# Validation Iter 5300, auc= 0.866625, fmeasure_max= 0.770874, precision= 0.888143, recall= 0.680961
# Validation Random guess:  auc= 0.227779, fmeasure_max= 0.373187, precision= 0.229762, recall= 0.993139
# Minibatch Loss= 0.388877
# Tarin Iter 5400, auc= 0.902051, fmeasure_max= 0.841687, precision= 0.896610, recall= 0.793103
# Train Random guess:  , auc= 0.269723fmeasure_max= 0.414258, precision= 0.263588, recall= 0.967016
# Validation Iter 5400, auc= 0.883620, fmeasure_max= 0.812770, precision= 0.817708, recall= 0.807890
# Validation Random guess:  auc= 0.239051, fmeasure_max= 0.372154, precision= 0.229627, recall= 0.981132
# Minibatch Loss= 0.593746
# Tarin Iter 5500, auc= 0.954878, fmeasure_max= 0.885417, precision= 0.887265, recall= 0.883576
# Train Random guess:  , auc= 0.182314fmeasure_max= 0.319048, precision= 0.190728, recall= 0.975052
# Validation Iter 5500, auc= 0.885389, fmeasure_max= 0.788530, precision= 0.825516, recall= 0.754717
# Validation Random guess:  auc= 0.244715, fmeasure_max= 0.372154, precision= 0.229627, recall= 0.981132
# Minibatch Loss= 0.399015
# Tarin Iter 5600, auc= 0.924617, fmeasure_max= 0.852665, precision= 0.858044, recall= 0.847352
# Train Random guess:  , auc= 0.262292fmeasure_max= 0.402800, precision= 0.253099, recall= 0.985981
# Validation Iter 5600, auc= 0.885100, fmeasure_max= 0.804434, precision= 0.747059, recall= 0.871355
# Validation Random guess:  auc= 0.231029, fmeasure_max= 0.372794, precision= 0.229282, recall= 0.996569
# Minibatch Loss= 0.561550
# Tarin Iter 5700, auc= 0.932139, fmeasure_max= 0.844332, precision= 0.822076, recall= 0.867826
# Train Random guess:  , auc= 0.238203fmeasure_max= 0.366943, precision= 0.224697, recall= 1.000000
# Validation Iter 5700, auc= 0.882526, fmeasure_max= 0.805263, precision= 0.824057, recall= 0.787307
# Validation Random guess:  auc= 0.228414, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.460188
# Tarin Iter 5800, auc= 0.935793, fmeasure_max= 0.877280, precision= 0.875828, recall= 0.878738
# Train Random guess:  , auc= 0.248433fmeasure_max= 0.380952, precision= 0.235479, recall= 0.996678
# Validation Iter 5800, auc= 0.860785, fmeasure_max= 0.783366, precision= 0.898004, recall= 0.694683
# Validation Random guess:  auc= 0.228354, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.524684
# Tarin Iter 5900, auc= 0.908175, fmeasure_max= 0.860972, precision= 0.898601, recall= 0.826367
# Train Random guess:  , auc= 0.244560fmeasure_max= 0.390949, precision= 0.242969, recall= 1.000000
# Validation Iter 5900, auc= 0.885592, fmeasure_max= 0.813061, precision= 0.775701, recall= 0.854202
# Validation Random guess:  auc= 0.222850, fmeasure_max= 0.375830, precision= 0.233018, recall= 0.970840
# Minibatch Loss= 0.535615
# Tarin Iter 6000, auc= 0.956993, fmeasure_max= 0.884770, precision= 0.895595, recall= 0.874204
# Train Random guess:  , auc= 0.237962fmeasure_max= 0.394472, precision= 0.245696, recall= 1.000000
# Validation Iter 6000, auc= 0.888395, fmeasure_max= 0.806202, precision= 0.809689, recall= 0.802744
# Validation Random guess:  auc= 0.239070, fmeasure_max= 0.371055, precision= 0.227878, recall= 0.998285
# Minibatch Loss= 0.487801
# Tarin Iter 6100, auc= 0.934875, fmeasure_max= 0.853952, precision= 0.885918, recall= 0.824212
# Train Random guess:  , auc= 0.243359fmeasure_max= 0.382517, precision= 0.238525, recall= 0.965174
# Validation Iter 6100, auc= 0.872842, fmeasure_max= 0.798932, precision= 0.829945, recall= 0.770154
# Validation Random guess:  auc= 0.247753, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.469673
# Tarin Iter 6200, auc= 0.929062, fmeasure_max= 0.870130, precision= 0.903371, recall= 0.839248
# Train Random guess:  , auc= 0.194662fmeasure_max= 0.315506, precision= 0.188051, recall= 0.979123
# Validation Iter 6200, auc= 0.860826, fmeasure_max= 0.780533, precision= 0.839921, recall= 0.728988
# Validation Random guess:  auc= 0.216576, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.448695
# Tarin Iter 6300, auc= 0.967648, fmeasure_max= 0.903896, precision= 0.925532, recall= 0.883249
# Train Random guess:  , auc= 0.229739fmeasure_max= 0.375238, precision= 0.230950, recall= 1.000000
# Validation Iter 6300, auc= 0.872591, fmeasure_max= 0.801754, precision= 0.820467, recall= 0.783877
# Validation Random guess:  auc= 0.232411, fmeasure_max= 0.371175, precision= 0.229642, recall= 0.967410
# Minibatch Loss= 0.461803
# Tarin Iter 6400, auc= 0.922964, fmeasure_max= 0.855925, precision= 0.894831, recall= 0.820261
# Train Random guess:  , auc= 0.241598fmeasure_max= 0.387937, precision= 0.240741, recall= 0.998366
# Validation Iter 6400, auc= 0.873859, fmeasure_max= 0.796848, precision= 0.813953, recall= 0.780446
# Validation Random guess:  auc= 0.226639, fmeasure_max= 0.371879, precision= 0.229988, recall= 0.970840
# Minibatch Loss= 0.508237
# Tarin Iter 6500, auc= 0.938597, fmeasure_max= 0.859012, precision= 0.871681, recall= 0.846705
# Train Random guess:  , auc= 0.259791fmeasure_max= 0.428615, precision= 0.272763, recall= 1.000000
# Validation Iter 6500, auc= 0.870470, fmeasure_max= 0.784173, precision= 0.824197, recall= 0.747856
# Validation Random guess:  auc= 0.233222, fmeasure_max= 0.373237, precision= 0.230738, recall= 0.975986
# Minibatch Loss= 0.606601
# Tarin Iter 6600, auc= 0.933003, fmeasure_max= 0.892253, precision= 0.872822, recall= 0.912568
# Train Random guess:  , auc= 0.230380fmeasure_max= 0.354389, precision= 0.215524, recall= 0.996357
# Validation Iter 6600, auc= 0.868244, fmeasure_max= 0.784420, precision= 0.831094, recall= 0.742710
# Validation Random guess:  auc= 0.233536, fmeasure_max= 0.373264, precision= 0.229912, recall= 0.991424
# Minibatch Loss= 0.469882
# Tarin Iter 6700, auc= 0.947275, fmeasure_max= 0.884311, precision= 0.882911, recall= 0.885714
# Train Random guess:  , auc= 0.236699fmeasure_max= 0.395108, precision= 0.246190, recall= 1.000000
# Validation Iter 6700, auc= 0.893810, fmeasure_max= 0.806481, precision= 0.848485, recall= 0.768439
# Validation Random guess:  auc= 0.223370, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.495892
# Tarin Iter 6800, auc= 0.945859, fmeasure_max= 0.871404, precision= 0.862647, recall= 0.880342
# Train Random guess:  , auc= 0.232008fmeasure_max= 0.372137, precision= 0.228605, recall= 1.000000
# Validation Iter 6800, auc= 0.885798, fmeasure_max= 0.808824, precision= 0.871287, recall= 0.754717
# Validation Random guess:  auc= 0.232234, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.440827
# Tarin Iter 6900, auc= 0.943798, fmeasure_max= 0.880000, precision= 0.895349, recall= 0.865169
# Train Random guess:  , auc= 0.208976fmeasure_max= 0.346580, precision= 0.209779, recall= 0.996255
# Validation Iter 6900, auc= 0.861099, fmeasure_max= 0.772118, precision= 0.805970, recall= 0.740995
# Validation Random guess:  auc= 0.227661, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.465709
# Tarin Iter 7000, auc= 0.927644, fmeasure_max= 0.875771, precision= 0.890681, recall= 0.861352
# Train Random guess:  , auc= 0.221303fmeasure_max= 0.369602, precision= 0.229046, recall= 0.956672
# Validation Iter 7000, auc= 0.864416, fmeasure_max= 0.787826, precision= 0.798942, recall= 0.777015
# Validation Random guess:  auc= 0.221221, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.508641
# Tarin Iter 7100, auc= 0.935656, fmeasure_max= 0.862712, precision= 0.883681, recall= 0.842715
# Train Random guess:  , auc= 0.238868fmeasure_max= 0.381916, precision= 0.236030, recall= 1.000000
# Validation Iter 7100, auc= 0.859831, fmeasure_max= 0.785455, precision= 0.835590, recall= 0.740995
# Validation Random guess:  auc= 0.229275, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.491036
# Tarin Iter 7200, auc= 0.958921, fmeasure_max= 0.905967, precision= 0.899461, recall= 0.912568
# Train Random guess:  , auc= 0.212418fmeasure_max= 0.353282, precision= 0.214537, recall= 1.000000
# Validation Iter 7200, auc= 0.844701, fmeasure_max= 0.775814, precision= 0.847561, recall= 0.715266
# Validation Random guess:  auc= 0.223747, fmeasure_max= 0.372892, precision= 0.229908, recall= 0.986278
# Minibatch Loss= 0.410325
# Tarin Iter 7300, auc= 0.940660, fmeasure_max= 0.879573, precision= 0.876900, recall= 0.882263
# Train Random guess:  , auc= 0.253526fmeasure_max= 0.407627, precision= 0.256189, recall= 0.996942
# Validation Iter 7300, auc= 0.889860, fmeasure_max= 0.819338, precision= 0.810403, recall= 0.828473
# Validation Random guess:  auc= 0.228354, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.551846
# Tarin Iter 7400, auc= 0.950345, fmeasure_max= 0.884808, precision= 0.887772, recall= 0.881864
# Train Random guess:  , auc= 0.237138fmeasure_max= 0.381318, precision= 0.236040, recall= 0.991681
# Validation Iter 7400, auc= 0.878682, fmeasure_max= 0.808652, precision= 0.785137, recall= 0.833619
# Validation Random guess:  auc= 0.227723, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.487372
# Tarin Iter 7500, auc= 0.961384, fmeasure_max= 0.906129, precision= 0.905426, recall= 0.906832
# Train Random guess:  , auc= 0.263606fmeasure_max= 0.403447, precision= 0.253917, recall= 0.981366
# Validation Iter 7500, auc= 0.879679, fmeasure_max= 0.818182, precision= 0.870406, recall= 0.771870
# Validation Random guess:  auc= 0.221130, fmeasure_max= 0.371234, precision= 0.228834, recall= 0.982847
# Minibatch Loss= 0.450927
# Tarin Iter 7600, auc= 0.959568, fmeasure_max= 0.891767, precision= 0.892593, recall= 0.890943
# Train Random guess:  , auc= 0.216049fmeasure_max= 0.349063, precision= 0.211516, recall= 0.998152
# Validation Iter 7600, auc= 0.873488, fmeasure_max= 0.803571, precision= 0.837989, recall= 0.771870
# Validation Random guess:  auc= 0.241747, fmeasure_max= 0.374718, precision= 0.230739, recall= 0.996569
# Minibatch Loss= 0.435568
# Tarin Iter 7700, auc= 0.928359, fmeasure_max= 0.861430, precision= 0.882459, recall= 0.841379
# Train Random guess:  , auc= 0.226448fmeasure_max= 0.369662, precision= 0.226740, recall= 1.000000
# Validation Iter 7700, auc= 0.881295, fmeasure_max= 0.806338, precision= 0.828210, recall= 0.785592
# Validation Random guess:  auc= 0.237191, fmeasure_max= 0.372498, precision= 0.229423, recall= 0.989708
# Minibatch Loss= 0.506682
# Tarin Iter 7800, auc= 0.905974, fmeasure_max= 0.828844, precision= 0.844248, recall= 0.813993
# Train Random guess:  , auc= 0.211951fmeasure_max= 0.373248, precision= 0.229444, recall= 1.000000
# Validation Iter 7800, auc= 0.837504, fmeasure_max= 0.747554, precision= 0.870159, recall= 0.655232
# Validation Random guess:  auc= 0.236810, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.592094
# Tarin Iter 7900, auc= 0.936685, fmeasure_max= 0.864407, precision= 0.842975, recall= 0.886957
# Train Random guess:  , auc= 0.221126fmeasure_max= 0.366826, precision= 0.224609, recall= 1.000000
# Validation Iter 7900, auc= 0.858387, fmeasure_max= 0.798561, precision= 0.839319, recall= 0.761578
# Validation Random guess:  auc= 0.217588, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.452278
# Tarin Iter 8000, auc= 0.930495, fmeasure_max= 0.870229, precision= 0.899408, recall= 0.842884
# Train Random guess:  , auc= 0.204320fmeasure_max= 0.349060, precision= 0.212450, recall= 0.977819
# Validation Iter 8000, auc= 0.880830, fmeasure_max= 0.799296, precision= 0.820976, recall= 0.778731
# Validation Random guess:  auc= 0.243711, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.486689
# Tarin Iter 8100, auc= 0.914290, fmeasure_max= 0.855831, precision= 0.861368, recall= 0.850365
# Train Random guess:  , auc= 0.218333fmeasure_max= 0.353286, precision= 0.214964, recall= 0.990876
# Validation Iter 8100, auc= 0.876456, fmeasure_max= 0.813008, precision= 0.858779, recall= 0.771870
# Validation Random guess:  auc= 0.215205, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.484118
# Tarin Iter 8200, auc= 0.926591, fmeasure_max= 0.863240, precision= 0.849237, recall= 0.877712
# Train Random guess:  , auc= 0.217121fmeasure_max= 0.333111, precision= 0.200482, recall= 0.984221
# Validation Iter 8200, auc= 0.889137, fmeasure_max= 0.824147, precision= 0.841071, recall= 0.807890
# Validation Random guess:  auc= 0.229750, fmeasure_max= 0.371733, precision= 0.228935, recall= 0.987993
# Minibatch Loss= 0.439605
# Tarin Iter 8300, auc= 0.956856, fmeasure_max= 0.894309, precision= 0.871479, recall= 0.918367
# Train Random guess:  , auc= 0.207393fmeasure_max= 0.349206, precision= 0.212475, recall= 0.979592
# Validation Iter 8300, auc= 0.882916, fmeasure_max= 0.820559, precision= 0.865019, recall= 0.780446
# Validation Random guess:  auc= 0.238383, fmeasure_max= 0.374053, precision= 0.231459, recall= 0.974271
# Minibatch Loss= 0.402800
# Tarin Iter 8400, auc= 0.954375, fmeasure_max= 0.893654, precision= 0.917254, recall= 0.871237
# Train Random guess:  , auc= 0.245784fmeasure_max= 0.380070, precision= 0.234899, recall= 0.994983
# Validation Iter 8400, auc= 0.887610, fmeasure_max= 0.820144, precision= 0.862004, recall= 0.782161
# Validation Random guess:  auc= 0.222326, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.458808
# Tarin Iter 8500, auc= 0.946986, fmeasure_max= 0.870427, precision= 0.854790, recall= 0.886646
# Train Random guess:  , auc= 0.242576fmeasure_max= 0.404344, precision= 0.254524, recall= 0.982919
# Validation Iter 8500, auc= 0.882662, fmeasure_max= 0.806159, precision= 0.854127, recall= 0.763293
# Validation Random guess:  auc= 0.228220, fmeasure_max= 0.372228, precision= 0.229035, recall= 0.993139
# Minibatch Loss= 0.484613
# Tarin Iter 8600, auc= 0.950048, fmeasure_max= 0.888889, precision= 0.891429, recall= 0.886364
# Train Random guess:  , auc= 0.216905fmeasure_max= 0.343080, precision= 0.207059, recall= 1.000000
# Validation Iter 8600, auc= 0.881597, fmeasure_max= 0.806723, precision= 0.790774, recall= 0.823328
# Validation Random guess:  auc= 0.225651, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.425848
# Tarin Iter 8700, auc= 0.939622, fmeasure_max= 0.872024, precision= 0.838340, recall= 0.908527
# Train Random guess:  , auc= 0.256945fmeasure_max= 0.403125, precision= 0.252446, recall= 1.000000
# Validation Iter 8700, auc= 0.873053, fmeasure_max= 0.809009, precision= 0.851992, recall= 0.770154
# Validation Random guess:  auc= 0.236560, fmeasure_max= 0.377537, precision= 0.235145, recall= 0.957118
# Minibatch Loss= 0.505136
# Tarin Iter 8800, auc= 0.928969, fmeasure_max= 0.848659, precision= 0.875494, recall= 0.823420
# Train Random guess:  , auc= 0.213545fmeasure_max= 0.350208, precision= 0.215260, recall= 0.938662
# Validation Iter 8800, auc= 0.885133, fmeasure_max= 0.822731, precision= 0.813758, recall= 0.831904
# Validation Random guess:  auc= 0.226282, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.459784
# Tarin Iter 8900, auc= 0.928673, fmeasure_max= 0.903785, precision= 0.899529, recall= 0.908082
# Train Random guess:  , auc= 0.253029fmeasure_max= 0.396657, precision= 0.248790, recall= 0.977813
# Validation Iter 8900, auc= 0.887625, fmeasure_max= 0.809806, precision= 0.798333, recall= 0.821612
# Validation Random guess:  auc= 0.229006, fmeasure_max= 0.372242, precision= 0.228774, recall= 0.998285
# Minibatch Loss= 0.472942
# Tarin Iter 9000, auc= 0.927807, fmeasure_max= 0.854185, precision= 0.833333, recall= 0.876106
# Train Random guess:  , auc= 0.229751fmeasure_max= 0.362063, precision= 0.221049, recall= 1.000000
# Validation Iter 9000, auc= 0.876596, fmeasure_max= 0.791355, precision= 0.767742, recall= 0.816467
# Validation Random guess:  auc= 0.234322, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.452697
# Tarin Iter 9100, auc= 0.952585, fmeasure_max= 0.892665, precision= 0.891071, recall= 0.894265
# Train Random guess:  , auc= 0.235520fmeasure_max= 0.358940, precision= 0.220146, recall= 0.971326
# Validation Iter 9100, auc= 0.902281, fmeasure_max= 0.822622, precision= 0.821918, recall= 0.823328
# Validation Random guess:  auc= 0.233574, fmeasure_max= 0.372378, precision= 0.229332, recall= 0.989708
# Minibatch Loss= 0.463737
# Tarin Iter 9200, auc= 0.964681, fmeasure_max= 0.911056, precision= 0.893964, recall= 0.928814
# Train Random guess:  , auc= 0.222113fmeasure_max= 0.375079, precision= 0.230829, recall= 1.000000
# Validation Iter 9200, auc= 0.867412, fmeasure_max= 0.787216, precision= 0.772277, recall= 0.802744
# Validation Random guess:  auc= 0.222576, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.442764
# Tarin Iter 9300, auc= 0.952982, fmeasure_max= 0.899065, precision= 0.890741, recall= 0.907547
# Train Random guess:  , auc= 0.204574fmeasure_max= 0.343264, precision= 0.207193, recall= 1.000000
# Validation Iter 9300, auc= 0.888523, fmeasure_max= 0.818859, precision= 0.790735, recall= 0.849057
# Validation Random guess:  auc= 0.227283, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.447263
# Tarin Iter 9400, auc= 0.965082, fmeasure_max= 0.899408, precision= 0.920415, recall= 0.879339
# Train Random guess:  , auc= 0.247475fmeasure_max= 0.384319, precision= 0.238532, recall= 0.988430
# Validation Iter 9400, auc= 0.883754, fmeasure_max= 0.811037, precision= 0.791191, recall= 0.831904
# Validation Random guess:  auc= 0.223384, fmeasure_max= 0.371762, precision= 0.229142, recall= 0.984563
# Minibatch Loss= 0.444351
# Tarin Iter 9500, auc= 0.968947, fmeasure_max= 0.909380, precision= 0.889580, recall= 0.930081
# Train Random guess:  , auc= 0.240426fmeasure_max= 0.389711, precision= 0.242886, recall= 0.985366
# Validation Iter 9500, auc= 0.875236, fmeasure_max= 0.804943, precision= 0.829091, recall= 0.782161
# Validation Random guess:  auc= 0.212689, fmeasure_max= 0.371898, precision= 0.228968, recall= 0.989708
# Minibatch Loss= 0.436359
# Tarin Iter 9600, auc= 0.941002, fmeasure_max= 0.883026, precision= 0.873043, recall= 0.893238
# Train Random guess:  , auc= 0.211600fmeasure_max= 0.361868, precision= 0.221253, recall= 0.992883
# Validation Iter 9600, auc= 0.872002, fmeasure_max= 0.794941, precision= 0.839695, recall= 0.754717
# Validation Random guess:  auc= 0.216997, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.413320
# Tarin Iter 9700, auc= 0.969151, fmeasure_max= 0.925397, precision= 0.906687, recall= 0.944895
# Train Random guess:  , auc= 0.241661fmeasure_max= 0.391443, precision= 0.243738, recall= 0.993517
# Validation Iter 9700, auc= 0.896418, fmeasure_max= 0.822635, precision= 0.810316, recall= 0.835334
# Validation Random guess:  auc= 0.221122, fmeasure_max= 0.373342, precision= 0.231402, recall= 0.965695
# Minibatch Loss= 0.453733
# Tarin Iter 9800, auc= 0.945855, fmeasure_max= 0.878049, precision= 0.886248, recall= 0.870000
# Train Random guess:  , auc= 0.246675fmeasure_max= 0.379747, precision= 0.234375, recall= 1.000000
# Validation Iter 9800, auc= 0.837044, fmeasure_max= 0.737662, precision= 0.744755, recall= 0.730703
# Validation Random guess:  auc= 0.220722, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.489392
# Tarin Iter 9900, auc= 0.957062, fmeasure_max= 0.900369, precision= 0.876437, recall= 0.925645
# Train Random guess:  , auc= 0.261896fmeasure_max= 0.411209, precision= 0.259436, recall= 0.990895
# Validation Iter 9900, auc= 0.879800, fmeasure_max= 0.803853, precision= 0.821109, recall= 0.787307
# Validation Random guess:  auc= 0.227823, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.509859
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.886678 F1_max = 0.809963 prec = 0.826852 rec = 0.793750
# Test Random guess: auc= 0.232971 fmeasure_max= 0.375702 , precision= 0.231310 , recall= 0.999831

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
