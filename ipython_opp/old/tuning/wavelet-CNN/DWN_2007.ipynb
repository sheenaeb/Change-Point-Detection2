# %%
# useing this variable for saving models and summaries
exp_name = "DWN2007"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10


wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]    #stride of pooling in convolution
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 64]]
bias_shape = [32, 32, 32, 32, 64]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
granularity = np.prod(pooling_stride)
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.239829, fmeasure_max= 0.412770, precision= 0.273540, recall= 0.840659
# Train Random guess:  , auc= 0.212560fmeasure_max= 0.352258, precision= 0.213782, recall= 1.000000
# Validation Iter 0, auc= 0.312084, fmeasure_max= 0.381101, precision= 0.273269, recall= 0.629503
# Validation Random guess:  auc= 0.254875, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 1.027254
# Tarin Iter 100, auc= 0.532894, fmeasure_max= 0.573503, precision= 0.456208, recall= 0.771987
# Train Random guess:  , auc= 0.243106fmeasure_max= 0.389744, precision= 0.242618, recall= 0.990228
# Validation Iter 100, auc= 0.692746, fmeasure_max= 0.657534, precision= 0.590971, recall= 0.740995
# Validation Random guess:  auc= 0.242023, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.902181
# Tarin Iter 200, auc= 0.799126, fmeasure_max= 0.741507, precision= 0.794304, recall= 0.695291
# Train Random guess:  , auc= 0.287144fmeasure_max= 0.440110, precision= 0.282141, recall= 1.000000
# Validation Iter 200, auc= 0.721703, fmeasure_max= 0.691742, precision= 0.660937, recall= 0.725557
# Validation Random guess:  auc= 0.232889, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.754147
# Tarin Iter 300, auc= 0.756402, fmeasure_max= 0.706452, precision= 0.646018, recall= 0.779359
# Train Random guess:  , auc= 0.236913fmeasure_max= 0.360413, precision= 0.220079, recall= 0.994662
# Validation Iter 300, auc= 0.750759, fmeasure_max= 0.745370, precision= 0.677419, recall= 0.828473
# Validation Random guess:  auc= 0.229722, fmeasure_max= 0.371162, precision= 0.230419, recall= 0.953688
# Minibatch Loss= 0.667641
# Tarin Iter 400, auc= 0.808849, fmeasure_max= 0.774336, precision= 0.697211, recall= 0.870647
# Train Random guess:  , auc= 0.236255fmeasure_max= 0.381958, precision= 0.236623, recall= 0.990050
# Validation Iter 400, auc= 0.828428, fmeasure_max= 0.779479, precision= 0.704011, recall= 0.873070
# Validation Random guess:  auc= 0.237915, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.627042
# Tarin Iter 500, auc= 0.808022, fmeasure_max= 0.740989, precision= 0.702703, recall= 0.783688
# Train Random guess:  , auc= 0.223847fmeasure_max= 0.361593, precision= 0.220784, recall= 0.998227
# Validation Iter 500, auc= 0.820749, fmeasure_max= 0.766952, precision= 0.702857, recall= 0.843911
# Validation Random guess:  auc= 0.243394, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.614378
# Tarin Iter 600, auc= 0.837807, fmeasure_max= 0.760588, precision= 0.785714, recall= 0.737018
# Train Random guess:  , auc= 0.244640fmeasure_max= 0.379731, precision= 0.234827, recall= 0.991625
# Validation Iter 600, auc= 0.798391, fmeasure_max= 0.733114, precision= 0.705230, recall= 0.763293
# Validation Random guess:  auc= 0.232586, fmeasure_max= 0.374051, precision= 0.234125, recall= 0.929674
# Minibatch Loss= 0.647975
# Tarin Iter 700, auc= 0.808993, fmeasure_max= 0.767145, precision= 0.706314, recall= 0.839442
# Train Random guess:  , auc= 0.218027fmeasure_max= 0.367085, precision= 0.224980, recall= 0.996510
# Validation Iter 700, auc= 0.786149, fmeasure_max= 0.756137, precision= 0.723005, recall= 0.792453
# Validation Random guess:  auc= 0.217913, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.644717
# Tarin Iter 800, auc= 0.875823, fmeasure_max= 0.813688, precision= 0.788214, recall= 0.840864
# Train Random guess:  , auc= 0.217930fmeasure_max= 0.331704, precision= 0.198828, recall= 1.000000
# Validation Iter 800, auc= 0.862512, fmeasure_max= 0.806649, precision= 0.823214, recall= 0.790738
# Validation Random guess:  auc= 0.223574, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.471128
# Tarin Iter 900, auc= 0.865815, fmeasure_max= 0.838878, precision= 0.800747, recall= 0.880822
# Train Random guess:  , auc= 0.306660fmeasure_max= 0.444241, precision= 0.285658, recall= 0.998630
# Validation Iter 900, auc= 0.804730, fmeasure_max= 0.765101, precision= 0.748768, recall= 0.782161
# Validation Random guess:  auc= 0.210506, fmeasure_max= 0.371419, precision= 0.228605, recall= 0.989708
# Minibatch Loss= 0.662312
# Tarin Iter 1000, auc= 0.851244, fmeasure_max= 0.791227, precision= 0.750385, recall= 0.836770
# Train Random guess:  , auc= 0.229222fmeasure_max= 0.370937, precision= 0.227700, recall= 1.000000
# Validation Iter 1000, auc= 0.899089, fmeasure_max= 0.823723, precision= 0.792393, recall= 0.857633
# Validation Random guess:  auc= 0.236852, fmeasure_max= 0.371346, precision= 0.228458, recall= 0.991424
# Minibatch Loss= 0.530392
# Tarin Iter 1100, auc= 0.919352, fmeasure_max= 0.833572, precision= 0.833572, recall= 0.833572
# Train Random guess:  , auc= 0.261265fmeasure_max= 0.428001, precision= 0.272266, recall= 1.000000
# Validation Iter 1100, auc= 0.877167, fmeasure_max= 0.819672, precision= 0.784929, recall= 0.857633
# Validation Random guess:  auc= 0.236988, fmeasure_max= 0.378035, precision= 0.241643, recall= 0.867925
# Minibatch Loss= 0.522204
# Tarin Iter 1200, auc= 0.878599, fmeasure_max= 0.820388, precision= 0.788491, recall= 0.854975
# Train Random guess:  , auc= 0.233559fmeasure_max= 0.377070, precision= 0.232430, recall= 0.998314
# Validation Iter 1200, auc= 0.887654, fmeasure_max= 0.811067, precision= 0.752199, recall= 0.879931
# Validation Random guess:  auc= 0.245863, fmeasure_max= 0.374699, precision= 0.234308, recall= 0.934820
# Minibatch Loss= 0.564819
# Tarin Iter 1300, auc= 0.853314, fmeasure_max= 0.814638, precision= 0.796267, recall= 0.833876
# Train Random guess:  , auc= 0.242802fmeasure_max= 0.387405, precision= 0.240711, recall= 0.991857
# Validation Iter 1300, auc= 0.876626, fmeasure_max= 0.817133, precision= 0.786054, recall= 0.850772
# Validation Random guess:  auc= 0.219237, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.549787
# Tarin Iter 1400, auc= 0.911532, fmeasure_max= 0.848080, precision= 0.797488, recall= 0.905526
# Train Random guess:  , auc= 0.217323fmeasure_max= 0.361165, precision= 0.220641, recall= 0.994652
# Validation Iter 1400, auc= 0.864055, fmeasure_max= 0.796800, precision= 0.746627, recall= 0.854202
# Validation Random guess:  auc= 0.229101, fmeasure_max= 0.372258, precision= 0.234507, recall= 0.902230
# Minibatch Loss= 0.448263
# Tarin Iter 1500, auc= 0.909289, fmeasure_max= 0.848168, precision= 0.859091, recall= 0.837518
# Train Random guess:  , auc= 0.269221fmeasure_max= 0.418289, precision= 0.264453, recall= 1.000000
# Validation Iter 1500, auc= 0.864447, fmeasure_max= 0.796736, precision= 0.701961, recall= 0.921098
# Validation Random guess:  auc= 0.222569, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.556553
# Tarin Iter 1600, auc= 0.861414, fmeasure_max= 0.784091, precision= 0.791803, recall= 0.776527
# Train Random guess:  , auc= 0.245011fmeasure_max= 0.392295, precision= 0.245086, recall= 0.982315
# Validation Iter 1600, auc= 0.886636, fmeasure_max= 0.804878, precision= 0.724280, recall= 0.905660
# Validation Random guess:  auc= 0.227345, fmeasure_max= 0.374177, precision= 0.231553, recall= 0.974271
# Minibatch Loss= 0.575135
# Tarin Iter 1700, auc= 0.867112, fmeasure_max= 0.813900, precision= 0.747518, recall= 0.893220
# Train Random guess:  , auc= 0.244107fmeasure_max= 0.375437, precision= 0.231101, recall= 1.000000
# Validation Iter 1700, auc= 0.899797, fmeasure_max= 0.835034, precision= 0.827993, recall= 0.842196
# Validation Random guess:  auc= 0.229856, fmeasure_max= 0.372048, precision= 0.229266, recall= 0.986278
# Minibatch Loss= 0.490208
# Tarin Iter 1800, auc= 0.912910, fmeasure_max= 0.829618, precision= 0.779940, recall= 0.886054
# Train Random guess:  , auc= 0.233743fmeasure_max= 0.374522, precision= 0.230408, recall= 1.000000
# Validation Iter 1800, auc= 0.859295, fmeasure_max= 0.813344, precision= 0.757396, recall= 0.878216
# Validation Random guess:  auc= 0.229174, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.499015
# Tarin Iter 1900, auc= 0.910389, fmeasure_max= 0.830666, precision= 0.730370, recall= 0.962891
# Train Random guess:  , auc= 0.187694fmeasure_max= 0.333442, precision= 0.200078, recall= 1.000000
# Validation Iter 1900, auc= 0.900537, fmeasure_max= 0.836039, precision= 0.793529, recall= 0.883362
# Validation Random guess:  auc= 0.225602, fmeasure_max= 0.371493, precision= 0.228753, recall= 0.987993
# Minibatch Loss= 0.420863
# Tarin Iter 2000, auc= 0.922407, fmeasure_max= 0.851406, precision= 0.867076, recall= 0.836292
# Train Random guess:  , auc= 0.201042fmeasure_max= 0.330832, precision= 0.198202, recall= 1.000000
# Validation Iter 2000, auc= 0.908359, fmeasure_max= 0.854216, precision= 0.790087, recall= 0.929674
# Validation Random guess:  auc= 0.216589, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.423856
# Tarin Iter 2100, auc= 0.865266, fmeasure_max= 0.796253, precision= 0.738061, recall= 0.864407
# Train Random guess:  , auc= 0.230041fmeasure_max= 0.375959, precision= 0.231678, recall= 0.996610
# Validation Iter 2100, auc= 0.889026, fmeasure_max= 0.828729, precision= 0.767544, recall= 0.900515
# Validation Random guess:  auc= 0.216475, fmeasure_max= 0.372423, precision= 0.229274, recall= 0.991424
# Minibatch Loss= 0.566758
# Tarin Iter 2200, auc= 0.924571, fmeasure_max= 0.855204, precision= 0.873652, recall= 0.837518
# Train Random guess:  , auc= 0.266145fmeasure_max= 0.418374, precision= 0.264833, recall= 0.995569
# Validation Iter 2200, auc= 0.890145, fmeasure_max= 0.811200, precision= 0.760120, recall= 0.869640
# Validation Random guess:  auc= 0.220771, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.508363
# Tarin Iter 2300, auc= 0.936211, fmeasure_max= 0.866008, precision= 0.811096, recall= 0.928896
# Train Random guess:  , auc= 0.257921fmeasure_max= 0.411156, precision= 0.259289, recall= 0.992436
# Validation Iter 2300, auc= 0.907760, fmeasure_max= 0.832370, precision= 0.802548, recall= 0.864494
# Validation Random guess:  auc= 0.227828, fmeasure_max= 0.371549, precision= 0.229167, recall= 0.981132
# Minibatch Loss= 0.471708
# Tarin Iter 2400, auc= 0.906160, fmeasure_max= 0.844444, precision= 0.838772, recall= 0.850195
# Train Random guess:  , auc= 0.179775fmeasure_max= 0.336647, precision= 0.202875, recall= 0.988327
# Validation Iter 2400, auc= 0.890904, fmeasure_max= 0.812348, precision= 0.771605, recall= 0.857633
# Validation Random guess:  auc= 0.222334, fmeasure_max= 0.372511, precision= 0.229158, recall= 0.994854
# Minibatch Loss= 0.482671
# Tarin Iter 2500, auc= 0.904341, fmeasure_max= 0.819277, precision= 0.777439, recall= 0.865874
# Train Random guess:  , auc= 0.226050fmeasure_max= 0.375584, precision= 0.233707, recall= 0.955857
# Validation Iter 2500, auc= 0.913545, fmeasure_max= 0.820306, precision= 0.773556, recall= 0.873070
# Validation Random guess:  auc= 0.229567, fmeasure_max= 0.371641, precision= 0.229050, recall= 0.984563
# Minibatch Loss= 0.491848
# Tarin Iter 2600, auc= 0.897262, fmeasure_max= 0.835314, precision= 0.798701, recall= 0.875445
# Train Random guess:  , auc= 0.224872fmeasure_max= 0.361204, precision= 0.222405, recall= 0.960854
# Validation Iter 2600, auc= 0.923286, fmeasure_max= 0.857613, precision= 0.824367, recall= 0.893654
# Validation Random guess:  auc= 0.244214, fmeasure_max= 0.371346, precision= 0.228458, recall= 0.991424
# Minibatch Loss= 0.471378
# Tarin Iter 2700, auc= 0.886767, fmeasure_max= 0.842730, precision= 0.765499, recall= 0.937294
# Train Random guess:  , auc= 0.231594fmeasure_max= 0.387472, precision= 0.240867, recall= 0.990099
# Validation Iter 2700, auc= 0.899453, fmeasure_max= 0.823245, precision= 0.777439, recall= 0.874786
# Validation Random guess:  auc= 0.237385, fmeasure_max= 0.372330, precision= 0.232037, recall= 0.941681
# Minibatch Loss= 0.508615
# Tarin Iter 2800, auc= 0.912767, fmeasure_max= 0.846886, precision= 0.796143, recall= 0.904538
# Train Random guess:  , auc= 0.255692fmeasure_max= 0.399625, precision= 0.249707, recall= 1.000000
# Validation Iter 2800, auc= 0.906210, fmeasure_max= 0.819277, precision= 0.770393, recall= 0.874786
# Validation Random guess:  auc= 0.237695, fmeasure_max= 0.371355, precision= 0.228925, recall= 0.982847
# Minibatch Loss= 0.461696
# Tarin Iter 2900, auc= 0.941206, fmeasure_max= 0.858169, precision= 0.822719, recall= 0.896811
# Train Random guess:  , auc= 0.212384fmeasure_max= 0.348229, precision= 0.211415, recall= 0.986867
# Validation Iter 2900, auc= 0.904710, fmeasure_max= 0.831316, precision= 0.785061, recall= 0.883362
# Validation Random guess:  auc= 0.230763, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.407059
# Tarin Iter 3000, auc= 0.907615, fmeasure_max= 0.836753, precision= 0.814236, recall= 0.860550
# Train Random guess:  , auc= 0.196759fmeasure_max= 0.351194, precision= 0.213083, recall= 0.998165
# Validation Iter 3000, auc= 0.888670, fmeasure_max= 0.794193, precision= 0.790816, recall= 0.797599
# Validation Random guess:  auc= 0.234000, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.446004
# Tarin Iter 3100, auc= 0.968563, fmeasure_max= 0.902844, precision= 0.931540, recall= 0.875862
# Train Random guess:  , auc= 0.180007fmeasure_max= 0.291242, precision= 0.170848, recall= 0.986207
# Validation Iter 3100, auc= 0.919066, fmeasure_max= 0.830159, precision= 0.772526, recall= 0.897084
# Validation Random guess:  auc= 0.225850, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.363509
# Tarin Iter 3200, auc= 0.894077, fmeasure_max= 0.819088, precision= 0.768717, recall= 0.876524
# Train Random guess:  , auc= 0.251680fmeasure_max= 0.408864, precision= 0.257064, recall= 0.998476
# Validation Iter 3200, auc= 0.894719, fmeasure_max= 0.807812, precision= 0.741750, recall= 0.886792
# Validation Random guess:  auc= 0.242908, fmeasure_max= 0.375537, precision= 0.232596, recall= 0.974271
# Minibatch Loss= 0.552001
# Tarin Iter 3300, auc= 0.933218, fmeasure_max= 0.852113, precision= 0.843794, recall= 0.860597
# Train Random guess:  , auc= 0.287608fmeasure_max= 0.434557, precision= 0.281566, recall= 0.951636
# Validation Iter 3300, auc= 0.907836, fmeasure_max= 0.849916, precision= 0.835821, recall= 0.864494
# Validation Random guess:  auc= 0.217368, fmeasure_max= 0.371659, precision= 0.228787, recall= 0.989708
# Minibatch Loss= 0.513228
# Tarin Iter 3400, auc= 0.957089, fmeasure_max= 0.891010, precision= 0.852359, recall= 0.933333
# Train Random guess:  , auc= 0.239207fmeasure_max= 0.380952, precision= 0.236821, recall= 0.973333
# Validation Iter 3400, auc= 0.927997, fmeasure_max= 0.834783, precision= 0.774194, recall= 0.905660
# Validation Random guess:  auc= 0.216596, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.365725
# Tarin Iter 3500, auc= 0.946150, fmeasure_max= 0.875186, precision= 0.862372, recall= 0.888386
# Train Random guess:  , auc= 0.260855fmeasure_max= 0.414183, precision= 0.261490, recall= 0.995475
# Validation Iter 3500, auc= 0.891750, fmeasure_max= 0.807626, precision= 0.816112, recall= 0.799314
# Validation Random guess:  auc= 0.232397, fmeasure_max= 0.371602, precision= 0.228381, recall= 0.996569
# Minibatch Loss= 0.504293
# Tarin Iter 3600, auc= 0.898344, fmeasure_max= 0.830821, precision= 0.823920, recall= 0.837838
# Train Random guess:  , auc= 0.216025fmeasure_max= 0.379510, precision= 0.234475, recall= 0.994932
# Validation Iter 3600, auc= 0.888556, fmeasure_max= 0.814145, precision= 0.781991, recall= 0.849057
# Validation Random guess:  auc= 0.237877, fmeasure_max= 0.374595, precision= 0.230923, recall= 0.991424
# Minibatch Loss= 0.505887
# Tarin Iter 3700, auc= 0.928591, fmeasure_max= 0.870939, precision= 0.873239, recall= 0.868651
# Train Random guess:  , auc= 0.219198fmeasure_max= 0.367028, precision= 0.227598, recall= 0.947461
# Validation Iter 3700, auc= 0.919234, fmeasure_max= 0.847097, precision= 0.809375, recall= 0.888508
# Validation Random guess:  auc= 0.227384, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.481801
# Tarin Iter 3800, auc= 0.926616, fmeasure_max= 0.870843, precision= 0.856925, recall= 0.885220
# Train Random guess:  , auc= 0.248999fmeasure_max= 0.398746, precision= 0.249021, recall= 1.000000
# Validation Iter 3800, auc= 0.872375, fmeasure_max= 0.807692, precision= 0.732218, recall= 0.900515
# Validation Random guess:  auc= 0.228838, fmeasure_max= 0.372244, precision= 0.229508, recall= 0.984563
# Minibatch Loss= 0.477991
# Tarin Iter 3900, auc= 0.922826, fmeasure_max= 0.857394, precision= 0.877477, recall= 0.838210
# Train Random guess:  , auc= 0.247842fmeasure_max= 0.370205, precision= 0.227326, recall= 0.996558
# Validation Iter 3900, auc= 0.917631, fmeasure_max= 0.848329, precision= 0.847603, recall= 0.849057
# Validation Random guess:  auc= 0.221111, fmeasure_max= 0.373968, precision= 0.231588, recall= 0.970840
# Minibatch Loss= 0.480554
# Tarin Iter 4000, auc= 0.920934, fmeasure_max= 0.846931, precision= 0.802651, recall= 0.896382
# Train Random guess:  , auc= 0.238216fmeasure_max= 0.384542, precision= 0.238133, recall= 0.998355
# Validation Iter 4000, auc= 0.858802, fmeasure_max= 0.780723, precision= 0.734139, recall= 0.833619
# Validation Random guess:  auc= 0.230086, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.494391
# Tarin Iter 4100, auc= 0.915660, fmeasure_max= 0.866450, precision= 0.871179, recall= 0.861771
# Train Random guess:  , auc= 0.178490fmeasure_max= 0.309023, precision= 0.190937, recall= 0.809935
# Validation Iter 4100, auc= 0.893378, fmeasure_max= 0.830950, precision= 0.815182, recall= 0.847341
# Validation Random guess:  auc= 0.216969, fmeasure_max= 0.371503, precision= 0.229225, recall= 0.979417
# Minibatch Loss= 0.399014
# Tarin Iter 4200, auc= 0.962392, fmeasure_max= 0.903122, precision= 0.874419, recall= 0.933775
# Train Random guess:  , auc= 0.215153fmeasure_max= 0.382952, precision= 0.237008, recall= 0.996689
# Validation Iter 4200, auc= 0.906749, fmeasure_max= 0.830537, precision= 0.812808, recall= 0.849057
# Validation Random guess:  auc= 0.230630, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.414296
# Tarin Iter 4300, auc= 0.919419, fmeasure_max= 0.855730, precision= 0.845277, recall= 0.866444
# Train Random guess:  , auc= 0.222208fmeasure_max= 0.379234, precision= 0.233984, recall= 1.000000
# Validation Iter 4300, auc= 0.919509, fmeasure_max= 0.840555, precision= 0.849387, recall= 0.831904
# Validation Random guess:  auc= 0.231333, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.483558
# Tarin Iter 4400, auc= 0.921133, fmeasure_max= 0.835081, precision= 0.855469, recall= 0.815642
# Train Random guess:  , auc= 0.208239fmeasure_max= 0.347123, precision= 0.210012, recall= 1.000000
# Validation Iter 4400, auc= 0.928747, fmeasure_max= 0.836428, precision= 0.863139, recall= 0.811321
# Validation Random guess:  auc= 0.225839, fmeasure_max= 0.374357, precision= 0.233933, recall= 0.936535
# Minibatch Loss= 0.477628
# Tarin Iter 4500, auc= 0.958843, fmeasure_max= 0.893993, precision= 0.906810, recall= 0.881533
# Train Random guess:  , auc= 0.237104fmeasure_max= 0.368015, precision= 0.225591, recall= 0.998258
# Validation Iter 4500, auc= 0.922354, fmeasure_max= 0.847487, precision= 0.856392, recall= 0.838765
# Validation Random guess:  auc= 0.228239, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.399826
# Tarin Iter 4600, auc= 0.934768, fmeasure_max= 0.852916, precision= 0.826307, recall= 0.881295
# Train Random guess:  , auc= 0.213232fmeasure_max= 0.357786, precision= 0.217868, recall= 1.000000
# Validation Iter 4600, auc= 0.917760, fmeasure_max= 0.852675, precision= 0.819620, recall= 0.888508
# Validation Random guess:  auc= 0.232551, fmeasure_max= 0.372093, precision= 0.229208, recall= 0.987993
# Minibatch Loss= 0.423450
# Tarin Iter 4700, auc= 0.941291, fmeasure_max= 0.878465, precision= 0.911504, recall= 0.847737
# Train Random guess:  , auc= 0.193318fmeasure_max= 0.320238, precision= 0.190720, recall= 0.997942
# Validation Iter 4700, auc= 0.919470, fmeasure_max= 0.849829, precision= 0.845501, recall= 0.854202
# Validation Random guess:  auc= 0.228661, fmeasure_max= 0.371984, precision= 0.231154, recall= 0.951973
# Minibatch Loss= 0.372605
# Tarin Iter 4800, auc= 0.901790, fmeasure_max= 0.821429, precision= 0.780864, recall= 0.866438
# Train Random guess:  , auc= 0.238324fmeasure_max= 0.372801, precision= 0.232293, recall= 0.943493
# Validation Iter 4800, auc= 0.886151, fmeasure_max= 0.827309, precision= 0.777946, recall= 0.883362
# Validation Random guess:  auc= 0.224818, fmeasure_max= 0.371419, precision= 0.228605, recall= 0.989708
# Minibatch Loss= 0.526996
# Tarin Iter 4900, auc= 0.945946, fmeasure_max= 0.873646, precision= 0.876812, recall= 0.870504
# Train Random guess:  , auc= 0.210019fmeasure_max= 0.357212, precision= 0.217442, recall= 1.000000
# Validation Iter 4900, auc= 0.934703, fmeasure_max= 0.855953, precision= 0.831715, recall= 0.881647
# Validation Random guess:  auc= 0.241262, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.412763
# Tarin Iter 5000, auc= 0.953768, fmeasure_max= 0.887500, precision= 0.865854, recall= 0.910256
# Train Random guess:  , auc= 0.205000fmeasure_max= 0.351578, precision= 0.213281, recall= 1.000000
# Validation Iter 5000, auc= 0.917251, fmeasure_max= 0.845754, precision= 0.854641, recall= 0.837050
# Validation Random guess:  auc= 0.237997, fmeasure_max= 0.372813, precision= 0.231896, recall= 0.950257
# Minibatch Loss= 0.371939
# Tarin Iter 5100, auc= 0.947989, fmeasure_max= 0.870550, precision= 0.889256, recall= 0.852615
# Train Random guess:  , auc= 0.244834fmeasure_max= 0.395827, precision= 0.247235, recall= 0.992076
# Validation Iter 5100, auc= 0.920322, fmeasure_max= 0.839669, precision= 0.810207, recall= 0.871355
# Validation Random guess:  auc= 0.233720, fmeasure_max= 0.374756, precision= 0.231232, recall= 0.987993
# Minibatch Loss= 0.417167
# Tarin Iter 5200, auc= 0.952506, fmeasure_max= 0.875887, precision= 0.880570, recall= 0.871252
# Train Random guess:  , auc= 0.221384fmeasure_max= 0.362764, precision= 0.221571, recall= 1.000000
# Validation Iter 5200, auc= 0.936183, fmeasure_max= 0.860251, precision= 0.839869, recall= 0.881647
# Validation Random guess:  auc= 0.236134, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.407780
# Tarin Iter 5300, auc= 0.951017, fmeasure_max= 0.886751, precision= 0.878299, recall= 0.895366
# Train Random guess:  , auc= 0.257995fmeasure_max= 0.415012, precision= 0.261840, recall= 1.000000
# Validation Iter 5300, auc= 0.910755, fmeasure_max= 0.853535, precision= 0.838017, recall= 0.869640
# Validation Random guess:  auc= 0.222721, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.450931
# Tarin Iter 5400, auc= 0.949963, fmeasure_max= 0.880975, precision= 0.843806, recall= 0.921569
# Train Random guess:  , auc= 0.224140fmeasure_max= 0.334410, precision= 0.204655, recall= 0.913725
# Validation Iter 5400, auc= 0.940273, fmeasure_max= 0.860565, precision= 0.858362, recall= 0.862779
# Validation Random guess:  auc= 0.237850, fmeasure_max= 0.371681, precision= 0.229741, recall= 0.972556
# Minibatch Loss= 0.369779
# Tarin Iter 5500, auc= 0.952381, fmeasure_max= 0.874671, precision= 0.833055, recall= 0.920664
# Train Random guess:  , auc= 0.211203fmeasure_max= 0.350447, precision= 0.213565, recall= 0.976015
# Validation Iter 5500, auc= 0.928741, fmeasure_max= 0.853403, precision= 0.868561, recall= 0.838765
# Validation Random guess:  auc= 0.243594, fmeasure_max= 0.372959, precision= 0.230335, recall= 0.979417
# Minibatch Loss= 0.395105
# Tarin Iter 5600, auc= 0.937466, fmeasure_max= 0.875585, precision= 0.906977, recall= 0.846293
# Train Random guess:  , auc= 0.207911fmeasure_max= 0.355970, precision= 0.216523, recall= 1.000000
# Validation Iter 5600, auc= 0.912849, fmeasure_max= 0.833470, precision= 0.798742, recall= 0.871355
# Validation Random guess:  auc= 0.224586, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 0.419253
# Tarin Iter 5700, auc= 0.938242, fmeasure_max= 0.861702, precision= 0.823729, recall= 0.903346
# Train Random guess:  , auc= 0.207960fmeasure_max= 0.350264, precision= 0.212911, recall= 0.986989
# Validation Iter 5700, auc= 0.920879, fmeasure_max= 0.839834, precision= 0.813505, recall= 0.867925
# Validation Random guess:  auc= 0.240240, fmeasure_max= 0.373109, precision= 0.232023, recall= 0.951973
# Minibatch Loss= 0.384470
# Tarin Iter 5800, auc= 0.939652, fmeasure_max= 0.851536, precision= 0.847199, recall= 0.855918
# Train Random guess:  , auc= 0.231625fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Validation Iter 5800, auc= 0.932430, fmeasure_max= 0.862620, precision= 0.807175, recall= 0.926244
# Validation Random guess:  auc= 0.232237, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.398404
# Tarin Iter 5900, auc= 0.945389, fmeasure_max= 0.869176, precision= 0.873874, recall= 0.864528
# Train Random guess:  , auc= 0.219429fmeasure_max= 0.360492, precision= 0.221586, recall= 0.966132
# Validation Iter 5900, auc= 0.894237, fmeasure_max= 0.828235, precision= 0.763006, recall= 0.905660
# Validation Random guess:  auc= 0.238473, fmeasure_max= 0.372340, precision= 0.230928, recall= 0.960549
# Minibatch Loss= 0.416988
# Tarin Iter 6000, auc= 0.953527, fmeasure_max= 0.891182, precision= 0.925926, recall= 0.858951
# Train Random guess:  , auc= 0.218861fmeasure_max= 0.356014, precision= 0.216641, recall= 0.998192
# Validation Iter 6000, auc= 0.931583, fmeasure_max= 0.853333, precision= 0.829822, recall= 0.878216
# Validation Random guess:  auc= 0.221327, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.389223
# Tarin Iter 6100, auc= 0.930919, fmeasure_max= 0.845045, precision= 0.912451, recall= 0.786913
# Train Random guess:  , auc= 0.236383fmeasure_max= 0.379068, precision= 0.234043, recall= 0.996644
# Validation Iter 6100, auc= 0.923848, fmeasure_max= 0.827528, precision= 0.819865, recall= 0.835334
# Validation Random guess:  auc= 0.229940, fmeasure_max= 0.373634, precision= 0.231527, recall= 0.967410
# Minibatch Loss= 0.426634
# Tarin Iter 6200, auc= 0.948134, fmeasure_max= 0.874676, precision= 0.870912, recall= 0.878472
# Train Random guess:  , auc= 0.226705fmeasure_max= 0.368640, precision= 0.225971, recall= 1.000000
# Validation Iter 6200, auc= 0.931047, fmeasure_max= 0.851792, precision= 0.810853, recall= 0.897084
# Validation Random guess:  auc= 0.224346, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.397115
# Tarin Iter 6300, auc= 0.973650, fmeasure_max= 0.913580, precision= 0.904135, recall= 0.923225
# Train Random guess:  , auc= 0.193281fmeasure_max= 0.338202, precision= 0.203516, recall= 1.000000
# Validation Iter 6300, auc= 0.930904, fmeasure_max= 0.856700, precision= 0.781073, recall= 0.948542
# Validation Random guess:  auc= 0.234815, fmeasure_max= 0.373125, precision= 0.230366, recall= 0.981132
# Minibatch Loss= 0.322548
# Tarin Iter 6400, auc= 0.920266, fmeasure_max= 0.831366, precision= 0.842735, recall= 0.820300
# Train Random guess:  , auc= 0.241800fmeasure_max= 0.382949, precision= 0.242371, recall= 0.911814
# Validation Iter 6400, auc= 0.938591, fmeasure_max= 0.873676, precision= 0.832298, recall= 0.919383
# Validation Random guess:  auc= 0.226964, fmeasure_max= 0.372183, precision= 0.229092, recall= 0.991424
# Minibatch Loss= 0.506097
# Tarin Iter 6500, auc= 0.954778, fmeasure_max= 0.876800, precision= 0.879615, recall= 0.874003
# Train Random guess:  , auc= 0.245244fmeasure_max= 0.393473, precision= 0.244922, recall= 1.000000
# Validation Iter 6500, auc= 0.930839, fmeasure_max= 0.850746, precision= 0.823435, recall= 0.879931
# Validation Random guess:  auc= 0.213208, fmeasure_max= 0.371305, precision= 0.230231, recall= 0.958834
# Minibatch Loss= 0.419248
# Tarin Iter 6600, auc= 0.943134, fmeasure_max= 0.865169, precision= 0.830935, recall= 0.902344
# Train Random guess:  , auc= 0.218710fmeasure_max= 0.342835, precision= 0.213532, recall= 0.869141
# Validation Iter 6600, auc= 0.934930, fmeasure_max= 0.846656, precision= 0.807154, recall= 0.890223
# Validation Random guess:  auc= 0.235277, fmeasure_max= 0.373040, precision= 0.231566, recall= 0.958834
# Minibatch Loss= 0.389977
# Tarin Iter 6700, auc= 0.938977, fmeasure_max= 0.870890, precision= 0.861905, recall= 0.880065
# Train Random guess:  , auc= 0.254916fmeasure_max= 0.389397, precision= 0.241771, recall= 1.000000
# Validation Iter 6700, auc= 0.931550, fmeasure_max= 0.856410, precision= 0.853492, recall= 0.859348
# Validation Random guess:  auc= 0.247008, fmeasure_max= 0.371308, precision= 0.228983, recall= 0.981132
# Minibatch Loss= 0.498965
# Tarin Iter 6800, auc= 0.941183, fmeasure_max= 0.881356, precision= 0.868114, recall= 0.895009
# Train Random guess:  , auc= 0.219605fmeasure_max= 0.371154, precision= 0.228043, recall= 0.996558
# Validation Iter 6800, auc= 0.919300, fmeasure_max= 0.856912, precision= 0.810398, recall= 0.909091
# Validation Random guess:  auc= 0.240665, fmeasure_max= 0.374787, precision= 0.233844, recall= 0.943396
# Minibatch Loss= 0.469024
# Tarin Iter 6900, auc= 0.962612, fmeasure_max= 0.908940, precision= 0.928934, recall= 0.889789
# Train Random guess:  , auc= 0.244402fmeasure_max= 0.389454, precision= 0.242197, recall= 0.993517
# Validation Iter 6900, auc= 0.940570, fmeasure_max= 0.865672, precision= 0.837881, recall= 0.895369
# Validation Random guess:  auc= 0.225345, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.367908
# Tarin Iter 7000, auc= 0.955156, fmeasure_max= 0.875000, precision= 0.839623, recall= 0.913490
# Train Random guess:  , auc= 0.271449fmeasure_max= 0.421352, precision= 0.268519, recall= 0.978006
# Validation Iter 7000, auc= 0.939003, fmeasure_max= 0.866319, precision= 0.876977, recall= 0.855918
# Validation Random guess:  auc= 0.231849, fmeasure_max= 0.371885, precision= 0.228504, recall= 0.998285
# Minibatch Loss= 0.442484
# Tarin Iter 7100, auc= 0.940268, fmeasure_max= 0.865140, precision= 0.865874, recall= 0.864407
# Train Random guess:  , auc= 0.232069fmeasure_max= 0.374722, precision= 0.230559, recall= 1.000000
# Validation Iter 7100, auc= 0.944092, fmeasure_max= 0.869128, precision= 0.850575, recall= 0.888508
# Validation Random guess:  auc= 0.231950, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.411359
# Tarin Iter 7200, auc= 0.930380, fmeasure_max= 0.843434, precision= 0.886726, recall= 0.804173
# Train Random guess:  , auc= 0.241694fmeasure_max= 0.391455, precision= 0.243359, recall= 1.000000
# Validation Iter 7200, auc= 0.949365, fmeasure_max= 0.879933, precision= 0.861842, recall= 0.898799
# Validation Random guess:  auc= 0.253215, fmeasure_max= 0.374918, precision= 0.231545, recall= 0.984563
# Minibatch Loss= 0.466022
# Tarin Iter 7300, auc= 0.961982, fmeasure_max= 0.907010, precision= 0.864939, recall= 0.953383
# Train Random guess:  , auc= 0.256810fmeasure_max= 0.412422, precision= 0.259883, recall= 0.998496
# Validation Iter 7300, auc= 0.945121, fmeasure_max= 0.869136, precision= 0.835443, recall= 0.905660
# Validation Random guess:  auc= 0.230051, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.429044
# Tarin Iter 7400, auc= 0.953187, fmeasure_max= 0.888511, precision= 0.867110, recall= 0.910995
# Train Random guess:  , auc= 0.229214fmeasure_max= 0.366388, precision= 0.224635, recall= 0.993019
# Validation Iter 7400, auc= 0.934258, fmeasure_max= 0.852090, precision= 0.801815, recall= 0.909091
# Validation Random guess:  auc= 0.231548, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.382483
# Tarin Iter 7500, auc= 0.944022, fmeasure_max= 0.874437, precision= 0.805457, recall= 0.956338
# Train Random guess:  , auc= 0.281907fmeasure_max= 0.434436, precision= 0.277604, recall= 0.998592
# Validation Iter 7500, auc= 0.927906, fmeasure_max= 0.835938, precision= 0.767575, recall= 0.917667
# Validation Random guess:  auc= 0.228149, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.463260
# Tarin Iter 7600, auc= 0.933072, fmeasure_max= 0.862403, precision= 0.831776, recall= 0.895372
# Train Random guess:  , auc= 0.207347fmeasure_max= 0.326693, precision= 0.195626, recall= 0.989940
# Validation Iter 7600, auc= 0.928151, fmeasure_max= 0.847844, precision= 0.806502, recall= 0.893654
# Validation Random guess:  auc= 0.234587, fmeasure_max= 0.373913, precision= 0.232239, recall= 0.958834
# Minibatch Loss= 0.380405
# Tarin Iter 7700, auc= 0.954527, fmeasure_max= 0.884921, precision= 0.859345, recall= 0.912065
# Train Random guess:  , auc= 0.215221fmeasure_max= 0.321429, precision= 0.192416, recall= 0.975460
# Validation Iter 7700, auc= 0.931397, fmeasure_max= 0.868421, precision= 0.834123, recall= 0.905660
# Validation Random guess:  auc= 0.223320, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.331543
# Tarin Iter 7800, auc= 0.959915, fmeasure_max= 0.876649, precision= 0.875969, recall= 0.877329
# Train Random guess:  , auc= 0.257574fmeasure_max= 0.402374, precision= 0.251858, recall= 1.000000
# Validation Iter 7800, auc= 0.926864, fmeasure_max= 0.855462, precision= 0.838550, recall= 0.873070
# Validation Random guess:  auc= 0.226134, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.419252
# Tarin Iter 7900, auc= 0.965717, fmeasure_max= 0.892116, precision= 0.844241, recall= 0.945748
# Train Random guess:  , auc= 0.269047fmeasure_max= 0.421967, precision= 0.267611, recall= 0.997067
# Validation Iter 7900, auc= 0.926272, fmeasure_max= 0.843548, precision= 0.796043, recall= 0.897084
# Validation Random guess:  auc= 0.230463, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.449579
# Tarin Iter 8000, auc= 0.943837, fmeasure_max= 0.881701, precision= 0.908571, recall= 0.856373
# Train Random guess:  , auc= 0.220962fmeasure_max= 0.358430, precision= 0.218346, recall= 1.000000
# Validation Iter 8000, auc= 0.928142, fmeasure_max= 0.852965, precision= 0.810185, recall= 0.900515
# Validation Random guess:  auc= 0.230391, fmeasure_max= 0.372451, precision= 0.231312, recall= 0.955403
# Minibatch Loss= 0.403238
# Tarin Iter 8100, auc= 0.943655, fmeasure_max= 0.863451, precision= 0.828885, recall= 0.901024
# Train Random guess:  , auc= 0.227580fmeasure_max= 0.372774, precision= 0.229085, recall= 1.000000
# Validation Iter 8100, auc= 0.928966, fmeasure_max= 0.851438, precision= 0.796712, recall= 0.914237
# Validation Random guess:  auc= 0.217297, fmeasure_max= 0.371557, precision= 0.228436, recall= 0.994854
# Minibatch Loss= 0.415622
# Tarin Iter 8200, auc= 0.953834, fmeasure_max= 0.902121, precision= 0.912541, recall= 0.891935
# Train Random guess:  , auc= 0.246230fmeasure_max= 0.390060, precision= 0.242282, recall= 1.000000
# Validation Iter 8200, auc= 0.935366, fmeasure_max= 0.862151, precision= 0.805060, recall= 0.927959
# Validation Random guess:  auc= 0.229634, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.448363
# Tarin Iter 8300, auc= 0.946942, fmeasure_max= 0.871702, precision= 0.852313, recall= 0.891993
# Train Random guess:  , auc= 0.203677fmeasure_max= 0.348168, precision= 0.211195, recall= 0.990689
# Validation Iter 8300, auc= 0.916245, fmeasure_max= 0.830769, precision= 0.753138, recall= 0.926244
# Validation Random guess:  auc= 0.223601, fmeasure_max= 0.372347, precision= 0.229125, recall= 0.993139
# Minibatch Loss= 0.386750
# Tarin Iter 8400, auc= 0.953713, fmeasure_max= 0.902581, precision= 0.894389, recall= 0.910924
# Train Random guess:  , auc= 0.238742fmeasure_max= 0.379172, precision= 0.236568, recall= 0.954622
# Validation Iter 8400, auc= 0.933038, fmeasure_max= 0.848387, precision= 0.800609, recall= 0.902230
# Validation Random guess:  auc= 0.223542, fmeasure_max= 0.371914, precision= 0.228707, recall= 0.994854
# Minibatch Loss= 0.428962
# Tarin Iter 8500, auc= 0.965451, fmeasure_max= 0.902730, precision= 0.913644, recall= 0.892074
# Train Random guess:  , auc= 0.221804fmeasure_max= 0.376508, precision= 0.231912, recall= 1.000000
# Validation Iter 8500, auc= 0.932921, fmeasure_max= 0.841832, precision= 0.848432, recall= 0.835334
# Validation Random guess:  auc= 0.225694, fmeasure_max= 0.371735, precision= 0.230961, recall= 0.951973
# Minibatch Loss= 0.384769
# Tarin Iter 8600, auc= 0.957468, fmeasure_max= 0.890292, precision= 0.898089, recall= 0.882629
# Train Random guess:  , auc= 0.248731fmeasure_max= 0.399625, precision= 0.249707, recall= 1.000000
# Validation Iter 8600, auc= 0.939090, fmeasure_max= 0.866264, precision= 0.871528, recall= 0.861063
# Validation Random guess:  auc= 0.244900, fmeasure_max= 0.373436, precision= 0.229676, recall= 0.998285
# Minibatch Loss= 0.431573
# Tarin Iter 8700, auc= 0.961254, fmeasure_max= 0.880992, precision= 0.848726, recall= 0.915808
# Train Random guess:  , auc= 0.235199fmeasure_max= 0.370819, precision= 0.227610, recall= 1.000000
# Validation Iter 8700, auc= 0.940219, fmeasure_max= 0.864558, precision= 0.820000, recall= 0.914237
# Validation Random guess:  auc= 0.238049, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.392112
# Tarin Iter 8800, auc= 0.968655, fmeasure_max= 0.905505, precision= 0.873217, recall= 0.940273
# Train Random guess:  , auc= 0.241027fmeasure_max= 0.375865, precision= 0.232938, recall= 0.972696
# Validation Iter 8800, auc= 0.933704, fmeasure_max= 0.851550, precision= 0.811820, recall= 0.895369
# Validation Random guess:  auc= 0.237650, fmeasure_max= 0.373548, precision= 0.230036, recall= 0.993139
# Minibatch Loss= 0.346336
# Tarin Iter 8900, auc= 0.975341, fmeasure_max= 0.915391, precision= 0.860606, recall= 0.977625
# Train Random guess:  , auc= 0.231113fmeasure_max= 0.371786, precision= 0.229923, recall= 0.970740
# Validation Iter 8900, auc= 0.928424, fmeasure_max= 0.848222, precision= 0.857895, recall= 0.838765
# Validation Random guess:  auc= 0.223002, fmeasure_max= 0.374147, precision= 0.230769, recall= 0.987993
# Minibatch Loss= 0.355033
# Tarin Iter 9000, auc= 0.964165, fmeasure_max= 0.901763, precision= 0.886139, recall= 0.917949
# Train Random guess:  , auc= 0.253471fmeasure_max= 0.372019, precision= 0.228516, recall= 1.000000
# Validation Iter 9000, auc= 0.940980, fmeasure_max= 0.857143, precision= 0.813559, recall= 0.905660
# Validation Random guess:  auc= 0.223184, fmeasure_max= 0.374053, precision= 0.231459, recall= 0.974271
# Minibatch Loss= 0.376103
# Tarin Iter 9100, auc= 0.967324, fmeasure_max= 0.910140, precision= 0.913907, recall= 0.906404
# Train Random guess:  , auc= 0.242959fmeasure_max= 0.385850, precision= 0.240998, recall= 0.967159
# Validation Iter 9100, auc= 0.925349, fmeasure_max= 0.836066, precision= 0.800628, recall= 0.874786
# Validation Random guess:  auc= 0.222201, fmeasure_max= 0.371925, precision= 0.229927, recall= 0.972556
# Minibatch Loss= 0.377723
# Tarin Iter 9200, auc= 0.949596, fmeasure_max= 0.881919, precision= 0.839578, recall= 0.928756
# Train Random guess:  , auc= 0.295287fmeasure_max= 0.464130, precision= 0.305670, recall= 0.963731
# Validation Iter 9200, auc= 0.930459, fmeasure_max= 0.860616, precision= 0.815668, recall= 0.910806
# Validation Random guess:  auc= 0.235271, fmeasure_max= 0.372498, precision= 0.229423, recall= 0.989708
# Minibatch Loss= 0.484075
# Tarin Iter 9300, auc= 0.968610, fmeasure_max= 0.916923, precision= 0.879056, recall= 0.958199
# Train Random guess:  , auc= 0.250354fmeasure_max= 0.391524, precision= 0.243701, recall= 0.995177
# Validation Iter 9300, auc= 0.932241, fmeasure_max= 0.853377, precision= 0.820919, recall= 0.888508
# Validation Random guess:  auc= 0.232628, fmeasure_max= 0.373342, precision= 0.230064, recall= 0.989708
# Minibatch Loss= 0.371398
# Tarin Iter 9400, auc= 0.940182, fmeasure_max= 0.867925, precision= 0.857374, recall= 0.878738
# Train Random guess:  , auc= 0.247519fmeasure_max= 0.381650, precision= 0.236106, recall= 0.995017
# Validation Iter 9400, auc= 0.929844, fmeasure_max= 0.851883, precision= 0.831699, recall= 0.873070
# Validation Random guess:  auc= 0.237215, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.434077
# Tarin Iter 9500, auc= 0.973249, fmeasure_max= 0.915282, precision= 0.932318, recall= 0.898858
# Train Random guess:  , auc= 0.257186fmeasure_max= 0.389908, precision= 0.243952, recall= 0.970636
# Validation Iter 9500, auc= 0.945310, fmeasure_max= 0.863833, precision= 0.873684, recall= 0.854202
# Validation Random guess:  auc= 0.230805, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.403534
# Tarin Iter 9600, auc= 0.942125, fmeasure_max= 0.877306, precision= 0.880837, recall= 0.873802
# Train Random guess:  , auc= 0.260852fmeasure_max= 0.395241, precision= 0.249167, recall= 0.955272
# Validation Iter 9600, auc= 0.933666, fmeasure_max= 0.861352, precision= 0.870403, recall= 0.852487
# Validation Random guess:  auc= 0.240485, fmeasure_max= 0.371777, precision= 0.231712, recall= 0.939966
# Minibatch Loss= 0.434554
# Tarin Iter 9700, auc= 0.966780, fmeasure_max= 0.909693, precision= 0.907438, recall= 0.911960
# Train Random guess:  , auc= 0.256584fmeasure_max= 0.384641, precision= 0.240702, recall= 0.956811
# Validation Iter 9700, auc= 0.930721, fmeasure_max= 0.851792, precision= 0.810853, recall= 0.897084
# Validation Random guess:  auc= 0.245778, fmeasure_max= 0.371567, precision= 0.228901, recall= 0.986278
# Minibatch Loss= 0.377506
# Tarin Iter 9800, auc= 0.969272, fmeasure_max= 0.899140, precision= 0.879205, recall= 0.920000
# Train Random guess:  , auc= 0.239608fmeasure_max= 0.394545, precision= 0.246044, recall= 0.995200
# Validation Iter 9800, auc= 0.935025, fmeasure_max= 0.854975, precision= 0.840796, recall= 0.869640
# Validation Random guess:  auc= 0.229451, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.419480
# Tarin Iter 9900, auc= 0.969053, fmeasure_max= 0.894118, precision= 0.914815, recall= 0.874336
# Train Random guess:  , auc= 0.232229fmeasure_max= 0.362108, precision= 0.221519, recall= 0.991150
# Validation Iter 9900, auc= 0.927831, fmeasure_max= 0.835242, precision= 0.858696, recall= 0.813036
# Validation Random guess:  auc= 0.226164, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.377000
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.920553 F1_max = 0.848173 prec = 0.821898 rec = 0.876182
# Test Random guess: auc= 0.227888 fmeasure_max= 0.375706 , precision= 0.231304 , recall= 1.000000

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
