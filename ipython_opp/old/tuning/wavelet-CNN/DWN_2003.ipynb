# %%
# useing this variable for saving models and summaries
exp_name = "DWN2003"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10


wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [4, 2, 2, 2, 1]    #stride of pooling in convolution
weights_shape = [[7, n_variables, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32],
                 [7, 32, 32]]
bias_shape = [32, 32, 32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
granularity = np.prod(pooling_stride)
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.205020, fmeasure_max= 0.374479, precision= 0.237064, recall= 0.890873
# Train Random guess:  , auc= 0.190385fmeasure_max= 0.329519, precision= 0.197260, recall= 1.000000
# Validation Iter 0, auc= 0.199839, fmeasure_max= 0.382447, precision= 0.241441, recall= 0.919383
# Validation Random guess:  auc= 0.221980, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.992862
# Tarin Iter 100, auc= 0.752283, fmeasure_max= 0.718978, precision= 0.679310, recall= 0.763566
# Train Random guess:  , auc= 0.210883fmeasure_max= 0.335501, precision= 0.201563, recall= 1.000000
# Validation Iter 100, auc= 0.690273, fmeasure_max= 0.675170, precision= 0.669477, recall= 0.680961
# Validation Random guess:  auc= 0.222205, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.641406
# Tarin Iter 200, auc= 0.774239, fmeasure_max= 0.728798, precision= 0.701975, recall= 0.757752
# Train Random guess:  , auc= 0.207473fmeasure_max= 0.335719, precision= 0.201720, recall= 1.000000
# Validation Iter 200, auc= 0.731299, fmeasure_max= 0.746420, precision= 0.733444, recall= 0.759863
# Validation Random guess:  auc= 0.225075, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.588576
# Tarin Iter 300, auc= 0.802844, fmeasure_max= 0.747440, precision= 0.700800, recall= 0.800731
# Train Random guess:  , auc= 0.217437fmeasure_max= 0.352108, precision= 0.213672, recall= 1.000000
# Validation Iter 300, auc= 0.827645, fmeasure_max= 0.782538, precision= 0.740061, recall= 0.830189
# Validation Random guess:  auc= 0.230847, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.615025
# Tarin Iter 400, auc= 0.802504, fmeasure_max= 0.761828, precision= 0.690407, recall= 0.849732
# Train Random guess:  , auc= 0.240287fmeasure_max= 0.359844, precision= 0.220008, recall= 0.987478
# Validation Iter 400, auc= 0.847593, fmeasure_max= 0.800638, precision= 0.748137, recall= 0.861063
# Validation Random guess:  auc= 0.222988, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.547737
# Tarin Iter 500, auc= 0.824667, fmeasure_max= 0.791531, precision= 0.750000, recall= 0.837931
# Train Random guess:  , auc= 0.234420fmeasure_max= 0.369898, precision= 0.226917, recall= 1.000000
# Validation Iter 500, auc= 0.821205, fmeasure_max= 0.788732, precision= 0.725180, recall= 0.864494
# Validation Random guess:  auc= 0.246020, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.562807
# Tarin Iter 600, auc= 0.899210, fmeasure_max= 0.857988, precision= 0.830153, recall= 0.887755
# Train Random guess:  , auc= 0.196718fmeasure_max= 0.323892, precision= 0.193548, recall= 0.991837
# Validation Iter 600, auc= 0.873012, fmeasure_max= 0.827423, precision= 0.765306, recall= 0.900515
# Validation Random guess:  auc= 0.234958, fmeasure_max= 0.374180, precision= 0.234226, recall= 0.929674
# Minibatch Loss= 0.410079
# Tarin Iter 700, auc= 0.869766, fmeasure_max= 0.794414, precision= 0.712100, recall= 0.898246
# Train Random guess:  , auc= 0.222997fmeasure_max= 0.366623, precision= 0.225546, recall= 0.978947
# Validation Iter 700, auc= 0.871489, fmeasure_max= 0.825342, precision= 0.823932, recall= 0.826758
# Validation Random guess:  auc= 0.240807, fmeasure_max= 0.373168, precision= 0.230305, recall= 0.982847
# Minibatch Loss= 0.554942
# Tarin Iter 800, auc= 0.913480, fmeasure_max= 0.844660, precision= 0.858553, recall= 0.831210
# Train Random guess:  , auc= 0.243821fmeasure_max= 0.394510, precision= 0.246707, recall= 0.984076
# Validation Iter 800, auc= 0.876294, fmeasure_max= 0.818627, precision= 0.781591, recall= 0.859348
# Validation Random guess:  auc= 0.240178, fmeasure_max= 0.371560, precision= 0.229648, recall= 0.972556
# Minibatch Loss= 0.512291
# Tarin Iter 900, auc= 0.922534, fmeasure_max= 0.854340, precision= 0.772169, recall= 0.956081
# Train Random guess:  , auc= 0.228881fmeasure_max= 0.375754, precision= 0.231340, recall= 1.000000
# Validation Iter 900, auc= 0.871291, fmeasure_max= 0.801809, precision= 0.715054, recall= 0.912521
# Validation Random guess:  auc= 0.238882, fmeasure_max= 0.374636, precision= 0.230861, recall= 0.993139
# Minibatch Loss= 0.456507
# Tarin Iter 1000, auc= 0.901836, fmeasure_max= 0.840246, precision= 0.810370, recall= 0.872408
# Train Random guess:  , auc= 0.249819fmeasure_max= 0.395880, precision= 0.247984, recall= 0.980861
# Validation Iter 1000, auc= 0.875780, fmeasure_max= 0.825545, precision= 0.756063, recall= 0.909091
# Validation Random guess:  auc= 0.226405, fmeasure_max= 0.372033, precision= 0.229535, recall= 0.981132
# Minibatch Loss= 0.519379
# Tarin Iter 1100, auc= 0.911561, fmeasure_max= 0.836003, precision= 0.757953, recall= 0.931973
# Train Random guess:  , auc= 0.223050fmeasure_max= 0.373808, precision= 0.229867, recall= 1.000000
# Validation Iter 1100, auc= 0.891892, fmeasure_max= 0.835148, precision= 0.763869, recall= 0.921098
# Validation Random guess:  auc= 0.230957, fmeasure_max= 0.371585, precision= 0.228639, recall= 0.991424
# Minibatch Loss= 0.461458
# Tarin Iter 1200, auc= 0.957037, fmeasure_max= 0.904040, precision= 0.841693, recall= 0.976364
# Train Random guess:  , auc= 0.212835fmeasure_max= 0.354766, precision= 0.215717, recall= 0.998182
# Validation Iter 1200, auc= 0.884702, fmeasure_max= 0.805085, precision= 0.795645, recall= 0.814751
# Validation Random guess:  auc= 0.249115, fmeasure_max= 0.372651, precision= 0.229724, recall= 0.986278
# Minibatch Loss= 0.380249
# Tarin Iter 1300, auc= 0.924552, fmeasure_max= 0.840227, precision= 0.867672, recall= 0.814465
# Train Random guess:  , auc= 0.242226fmeasure_max= 0.399120, precision= 0.249411, recall= 0.998428
# Validation Iter 1300, auc= 0.889111, fmeasure_max= 0.819865, precision= 0.804959, recall= 0.835334
# Validation Random guess:  auc= 0.235654, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.511666
# Tarin Iter 1400, auc= 0.882098, fmeasure_max= 0.806259, precision= 0.824695, recall= 0.788630
# Train Random guess:  , auc= 0.270259fmeasure_max= 0.423196, precision= 0.268388, recall= 1.000000
# Validation Iter 1400, auc= 0.904797, fmeasure_max= 0.853639, precision= 0.815625, recall= 0.895369
# Validation Random guess:  auc= 0.233853, fmeasure_max= 0.374091, precision= 0.231682, recall= 0.970840
# Minibatch Loss= 0.602695
# Tarin Iter 1500, auc= 0.936407, fmeasure_max= 0.853605, precision= 0.798365, recall= 0.917058
# Train Random guess:  , auc= 0.251017fmeasure_max= 0.399625, precision= 0.249707, recall= 1.000000
# Validation Iter 1500, auc= 0.901361, fmeasure_max= 0.829032, precision= 0.782344, recall= 0.881647
# Validation Random guess:  auc= 0.226536, fmeasure_max= 0.373342, precision= 0.230064, recall= 0.989708
# Minibatch Loss= 0.463428
# Tarin Iter 1600, auc= 0.922680, fmeasure_max= 0.865443, precision= 0.860182, recall= 0.870769
# Train Random guess:  , auc= 0.271539fmeasure_max= 0.409179, precision= 0.259002, recall= 0.973846
# Validation Iter 1600, auc= 0.918824, fmeasure_max= 0.827427, precision= 0.751049, recall= 0.921098
# Validation Random guess:  auc= 0.225979, fmeasure_max= 0.372242, precision= 0.228774, recall= 0.998285
# Minibatch Loss= 0.516394
# Tarin Iter 1700, auc= 0.937760, fmeasure_max= 0.872603, precision= 0.820876, recall= 0.931287
# Train Random guess:  , auc= 0.276887fmeasure_max= 0.422167, precision= 0.268196, recall= 0.991228
# Validation Iter 1700, auc= 0.903973, fmeasure_max= 0.827476, precision= 0.774290, recall= 0.888508
# Validation Random guess:  auc= 0.235357, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.470950
# Tarin Iter 1800, auc= 0.936588, fmeasure_max= 0.863254, precision= 0.857360, recall= 0.869231
# Train Random guess:  , auc= 0.247647fmeasure_max= 0.405363, precision= 0.254204, recall= 1.000000
# Validation Iter 1800, auc= 0.918910, fmeasure_max= 0.834556, precision= 0.795031, recall= 0.878216
# Validation Random guess:  auc= 0.219907, fmeasure_max= 0.371273, precision= 0.228312, recall= 0.993139
# Minibatch Loss= 0.473173
# Tarin Iter 1900, auc= 0.942369, fmeasure_max= 0.867271, precision= 0.893039, recall= 0.842949
# Train Random guess:  , auc= 0.258786fmeasure_max= 0.392766, precision= 0.244858, recall= 0.991987
# Validation Iter 1900, auc= 0.922547, fmeasure_max= 0.839149, precision= 0.832770, recall= 0.845626
# Validation Random guess:  auc= 0.229876, fmeasure_max= 0.373899, precision= 0.230862, recall= 0.982847
# Minibatch Loss= 0.435140
# Tarin Iter 2000, auc= 0.960985, fmeasure_max= 0.890411, precision= 0.875421, recall= 0.905923
# Train Random guess:  , auc= 0.211166fmeasure_max= 0.366860, precision= 0.225079, recall= 0.991289
# Validation Iter 2000, auc= 0.929862, fmeasure_max= 0.860656, precision= 0.824176, recall= 0.900515
# Validation Random guess:  auc= 0.225324, fmeasure_max= 0.372063, precision= 0.229002, recall= 0.991424
# Minibatch Loss= 0.387225
# Tarin Iter 2100, auc= 0.908291, fmeasure_max= 0.838519, precision= 0.787204, recall= 0.896989
# Train Random guess:  , auc= 0.246299fmeasure_max= 0.395611, precision= 0.246581, recall= 1.000000
# Validation Iter 2100, auc= 0.934576, fmeasure_max= 0.854671, precision= 0.862129, recall= 0.847341
# Validation Random guess:  auc= 0.228301, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.521192
# Tarin Iter 2200, auc= 0.935526, fmeasure_max= 0.881950, precision= 0.853982, recall= 0.911811
# Train Random guess:  , auc= 0.242044fmeasure_max= 0.398959, precision= 0.251436, recall= 0.965354
# Validation Iter 2200, auc= 0.929712, fmeasure_max= 0.866455, precision= 0.807407, recall= 0.934820
# Validation Random guess:  auc= 0.222580, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.422102
# Tarin Iter 2300, auc= 0.951659, fmeasure_max= 0.870519, precision= 0.869883, recall= 0.871157
# Train Random guess:  , auc= 0.263176fmeasure_max= 0.422719, precision= 0.268216, recall= 0.997072
# Validation Iter 2300, auc= 0.903581, fmeasure_max= 0.835650, precision= 0.798438, recall= 0.876501
# Validation Random guess:  auc= 0.239743, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.454681
# Tarin Iter 2400, auc= 0.894558, fmeasure_max= 0.846034, precision= 0.839506, recall= 0.852665
# Train Random guess:  , auc= 0.261707fmeasure_max= 0.400971, precision= 0.257461, recall= 0.905956
# Validation Iter 2400, auc= 0.913541, fmeasure_max= 0.840555, precision= 0.849387, recall= 0.831904
# Validation Random guess:  auc= 0.225662, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.518615
# Tarin Iter 2500, auc= 0.928698, fmeasure_max= 0.877384, precision= 0.881387, recall= 0.873418
# Train Random guess:  , auc= 0.230179fmeasure_max= 0.359678, precision= 0.220715, recall= 0.971067
# Validation Iter 2500, auc= 0.921808, fmeasure_max= 0.856908, precision= 0.823065, recall= 0.893654
# Validation Random guess:  auc= 0.227689, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.425583
# Tarin Iter 2600, auc= 0.900326, fmeasure_max= 0.837838, precision= 0.811215, recall= 0.866267
# Train Random guess:  , auc= 0.187731fmeasure_max= 0.328309, precision= 0.196394, recall= 1.000000
# Validation Iter 2600, auc= 0.920642, fmeasure_max= 0.841270, precision= 0.782866, recall= 0.909091
# Validation Random guess:  auc= 0.222409, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.425135
# Tarin Iter 2700, auc= 0.943173, fmeasure_max= 0.872502, precision= 0.822078, recall= 0.929515
# Train Random guess:  , auc= 0.262294fmeasure_max= 0.420500, precision= 0.266224, recall= 1.000000
# Validation Iter 2700, auc= 0.935481, fmeasure_max= 0.867121, precision= 0.861252, recall= 0.873070
# Validation Random guess:  auc= 0.232950, fmeasure_max= 0.375798, precision= 0.233696, recall= 0.958834
# Minibatch Loss= 0.464768
# Tarin Iter 2800, auc= 0.953373, fmeasure_max= 0.887500, precision= 0.848123, recall= 0.930712
# Train Random guess:  , auc= 0.211175fmeasure_max= 0.345655, precision= 0.209020, recall= 0.998127
# Validation Iter 2800, auc= 0.922699, fmeasure_max= 0.842282, precision= 0.824302, recall= 0.861063
# Validation Random guess:  auc= 0.228442, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.394923
# Tarin Iter 2900, auc= 0.959662, fmeasure_max= 0.899388, precision= 0.898601, recall= 0.900175
# Train Random guess:  , auc= 0.224537fmeasure_max= 0.365090, precision= 0.223309, recall= 1.000000
# Validation Iter 2900, auc= 0.918956, fmeasure_max= 0.854264, precision= 0.779349, recall= 0.945111
# Validation Random guess:  auc= 0.222243, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.320928
# Tarin Iter 3000, auc= 0.942192, fmeasure_max= 0.859535, precision= 0.847706, recall= 0.871698
# Train Random guess:  , auc= 0.202883fmeasure_max= 0.344065, precision= 0.207859, recall= 0.998113
# Validation Iter 3000, auc= 0.928431, fmeasure_max= 0.863896, precision= 0.822981, recall= 0.909091
# Validation Random guess:  auc= 0.231031, fmeasure_max= 0.371202, precision= 0.229857, recall= 0.963979
# Minibatch Loss= 0.405684
# Tarin Iter 3100, auc= 0.943200, fmeasure_max= 0.866058, precision= 0.817529, recall= 0.920712
# Train Random guess:  , auc= 0.239080fmeasure_max= 0.388924, precision= 0.241406, recall= 1.000000
# Validation Iter 3100, auc= 0.931445, fmeasure_max= 0.870293, precision= 0.849673, recall= 0.891938
# Validation Random guess:  auc= 0.209329, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.450027
# Tarin Iter 3200, auc= 0.930136, fmeasure_max= 0.847426, precision= 0.888247, recall= 0.810193
# Train Random guess:  , auc= 0.239563fmeasure_max= 0.366437, precision= 0.225222, recall= 0.982425
# Validation Iter 3200, auc= 0.913040, fmeasure_max= 0.860215, precision= 0.830671, recall= 0.891938
# Validation Random guess:  auc= 0.234824, fmeasure_max= 0.373101, precision= 0.229880, recall= 0.989708
# Minibatch Loss= 0.446535
# Tarin Iter 3300, auc= 0.943101, fmeasure_max= 0.856693, precision= 0.854003, recall= 0.859400
# Train Random guess:  , auc= 0.251666fmeasure_max= 0.396492, precision= 0.247266, recall= 1.000000
# Validation Iter 3300, auc= 0.913851, fmeasure_max= 0.849250, precision= 0.786550, recall= 0.922813
# Validation Random guess:  auc= 0.228582, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.481912
# Tarin Iter 3400, auc= 0.939764, fmeasure_max= 0.863256, precision= 0.811189, recall= 0.922465
# Train Random guess:  , auc= 0.206878fmeasure_max= 0.333676, precision= 0.201573, recall= 0.968191
# Validation Iter 3400, auc= 0.921229, fmeasure_max= 0.860577, precision= 0.807519, recall= 0.921098
# Validation Random guess:  auc= 0.248548, fmeasure_max= 0.372915, precision= 0.230396, recall= 0.977702
# Minibatch Loss= 0.361727
# Tarin Iter 3500, auc= 0.955213, fmeasure_max= 0.895686, precision= 0.857357, recall= 0.937603
# Train Random guess:  , auc= 0.247565fmeasure_max= 0.385180, precision= 0.239096, recall= 0.990148
# Validation Iter 3500, auc= 0.945252, fmeasure_max= 0.879421, precision= 0.827534, recall= 0.938250
# Validation Random guess:  auc= 0.230046, fmeasure_max= 0.371483, precision= 0.228291, recall= 0.996569
# Minibatch Loss= 0.379424
# Tarin Iter 3600, auc= 0.937528, fmeasure_max= 0.863208, precision= 0.833080, recall= 0.895595
# Train Random guess:  , auc= 0.253947fmeasure_max= 0.386852, precision= 0.239906, recall= 0.998369
# Validation Iter 3600, auc= 0.928612, fmeasure_max= 0.855501, precision= 0.820472, recall= 0.893654
# Validation Random guess:  auc= 0.246064, fmeasure_max= 0.372310, precision= 0.235374, recall= 0.890223
# Minibatch Loss= 0.410582
# Tarin Iter 3700, auc= 0.933753, fmeasure_max= 0.874680, precision= 0.824759, recall= 0.931034
# Train Random guess:  , auc= 0.218974fmeasure_max= 0.355195, precision= 0.216291, recall= 0.992740
# Validation Iter 3700, auc= 0.924106, fmeasure_max= 0.873191, precision= 0.866554, recall= 0.879931
# Validation Random guess:  auc= 0.227812, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.383827
# Tarin Iter 3800, auc= 0.961629, fmeasure_max= 0.896063, precision= 0.916264, recall= 0.876733
# Train Random guess:  , auc= 0.247948fmeasure_max= 0.405507, precision= 0.254417, recall= 0.998459
# Validation Iter 3800, auc= 0.916073, fmeasure_max= 0.845258, precision= 0.820679, recall= 0.871355
# Validation Random guess:  auc= 0.232531, fmeasure_max= 0.373178, precision= 0.230032, recall= 0.987993
# Minibatch Loss= 0.440995
# Tarin Iter 3900, auc= 0.974752, fmeasure_max= 0.921971, precision= 0.929607, recall= 0.914460
# Train Random guess:  , auc= 0.211893fmeasure_max= 0.322602, precision= 0.192323, recall= 1.000000
# Validation Iter 3900, auc= 0.942047, fmeasure_max= 0.883721, precision= 0.856683, recall= 0.912521
# Validation Random guess:  auc= 0.227190, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.316897
# Tarin Iter 4000, auc= 0.940111, fmeasure_max= 0.869421, precision= 0.849758, recall= 0.890017
# Train Random guess:  , auc= 0.248500fmeasure_max= 0.375442, precision= 0.231746, recall= 0.988156
# Validation Iter 4000, auc= 0.946553, fmeasure_max= 0.885459, precision= 0.841049, recall= 0.934820
# Validation Random guess:  auc= 0.225124, fmeasure_max= 0.372489, precision= 0.232370, recall= 0.938250
# Minibatch Loss= 0.439335
# Tarin Iter 4100, auc= 0.954931, fmeasure_max= 0.878367, precision= 0.847244, recall= 0.911864
# Train Random guess:  , auc= 0.221075fmeasure_max= 0.375916, precision= 0.231463, recall= 1.000000
# Validation Iter 4100, auc= 0.944720, fmeasure_max= 0.872668, precision= 0.827692, recall= 0.922813
# Validation Random guess:  auc= 0.215688, fmeasure_max= 0.372751, precision= 0.229340, recall= 0.994854
# Minibatch Loss= 0.373879
# Tarin Iter 4200, auc= 0.967245, fmeasure_max= 0.898678, precision= 0.899471, recall= 0.897887
# Train Random guess:  , auc= 0.228166fmeasure_max= 0.363404, precision= 0.222048, recall= 1.000000
# Validation Iter 4200, auc= 0.917576, fmeasure_max= 0.842373, precision= 0.832496, recall= 0.852487
# Validation Random guess:  auc= 0.220941, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.365436
# Tarin Iter 4300, auc= 0.955595, fmeasure_max= 0.879121, precision= 0.885609, recall= 0.872727
# Train Random guess:  , auc= 0.215528fmeasure_max= 0.354496, precision= 0.215433, recall= 1.000000
# Validation Iter 4300, auc= 0.933768, fmeasure_max= 0.860979, precision= 0.797950, recall= 0.934820
# Validation Random guess:  auc= 0.222280, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.387780
# Tarin Iter 4400, auc= 0.947184, fmeasure_max= 0.877451, precision= 0.832558, recall= 0.927461
# Train Random guess:  , auc= 0.226002fmeasure_max= 0.369211, precision= 0.226489, recall= 0.998273
# Validation Iter 4400, auc= 0.896536, fmeasure_max= 0.824953, precision= 0.902240, recall= 0.759863
# Validation Random guess:  auc= 0.248212, fmeasure_max= 0.375976, precision= 0.234349, recall= 0.950257
# Minibatch Loss= 0.412405
# Tarin Iter 4500, auc= 0.969642, fmeasure_max= 0.896552, precision= 0.902135, recall= 0.891037
# Train Random guess:  , auc= 0.230802fmeasure_max= 0.364226, precision= 0.223282, recall= 0.987698
# Validation Iter 4500, auc= 0.945070, fmeasure_max= 0.860129, precision= 0.809380, recall= 0.917667
# Validation Random guess:  auc= 0.227680, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.357283
# Tarin Iter 4600, auc= 0.974356, fmeasure_max= 0.917616, precision= 0.877081, recall= 0.962079
# Train Random guess:  , auc= 0.276467fmeasure_max= 0.437829, precision= 0.280939, recall= 0.991573
# Validation Iter 4600, auc= 0.925737, fmeasure_max= 0.858065, precision= 0.809741, recall= 0.912521
# Validation Random guess:  auc= 0.219823, fmeasure_max= 0.370994, precision= 0.228651, recall= 0.982847
# Minibatch Loss= 0.363347
# Tarin Iter 4700, auc= 0.955913, fmeasure_max= 0.894193, precision= 0.858015, recall= 0.933555
# Train Random guess:  , auc= 0.230494fmeasure_max= 0.380772, precision= 0.235156, recall= 1.000000
# Validation Iter 4700, auc= 0.934423, fmeasure_max= 0.866116, precision= 0.835726, recall= 0.898799
# Validation Random guess:  auc= 0.242037, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.407656
# Tarin Iter 4800, auc= 0.961362, fmeasure_max= 0.899263, precision= 0.913478, recall= 0.885484
# Train Random guess:  , auc= 0.252573fmeasure_max= 0.391167, precision= 0.243137, recall= 1.000000
# Validation Iter 4800, auc= 0.911259, fmeasure_max= 0.849543, precision= 0.824194, recall= 0.876501
# Validation Random guess:  auc= 0.223599, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.380518
# Tarin Iter 4900, auc= 0.939573, fmeasure_max= 0.863787, precision= 0.841424, recall= 0.887372
# Train Random guess:  , auc= 0.236013fmeasure_max= 0.373760, precision= 0.230012, recall= 0.996587
# Validation Iter 4900, auc= 0.923654, fmeasure_max= 0.841772, precision= 0.781204, recall= 0.912521
# Validation Random guess:  auc= 0.223001, fmeasure_max= 0.372606, precision= 0.229784, recall= 0.984563
# Minibatch Loss= 0.414599
# Tarin Iter 5000, auc= 0.959811, fmeasure_max= 0.901296, precision= 0.898608, recall= 0.904000
# Train Random guess:  , auc= 0.196015fmeasure_max= 0.327404, precision= 0.195978, recall= 0.994000
# Validation Iter 5000, auc= 0.929131, fmeasure_max= 0.849134, precision= 0.817460, recall= 0.883362
# Validation Random guess:  auc= 0.225004, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.331467
# Tarin Iter 5100, auc= 0.969214, fmeasure_max= 0.912680, precision= 0.876093, recall= 0.952456
# Train Random guess:  , auc= 0.254625fmeasure_max= 0.395487, precision= 0.246484, recall= 1.000000
# Validation Iter 5100, auc= 0.940688, fmeasure_max= 0.862400, precision= 0.808096, recall= 0.924528
# Validation Random guess:  auc= 0.214173, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.381108
# Tarin Iter 5200, auc= 0.977652, fmeasure_max= 0.919089, precision= 0.901387, recall= 0.937500
# Train Random guess:  , auc= 0.254051fmeasure_max= 0.393195, precision= 0.244706, recall= 1.000000
# Validation Iter 5200, auc= 0.931586, fmeasure_max= 0.855746, precision= 0.815217, recall= 0.900515
# Validation Random guess:  auc= 0.239806, fmeasure_max= 0.374147, precision= 0.230769, recall= 0.987993
# Minibatch Loss= 0.362946
# Tarin Iter 5300, auc= 0.954318, fmeasure_max= 0.889789, precision= 0.851163, recall= 0.932088
# Train Random guess:  , auc= 0.221472fmeasure_max= 0.375120, precision= 0.230951, recall= 0.998302
# Validation Iter 5300, auc= 0.920384, fmeasure_max= 0.854116, precision= 0.813665, recall= 0.898799
# Validation Random guess:  auc= 0.226433, fmeasure_max= 0.371529, precision= 0.228235, recall= 0.998285
# Minibatch Loss= 0.383618
# Tarin Iter 5400, auc= 0.958655, fmeasure_max= 0.882598, precision= 0.852090, recall= 0.915371
# Train Random guess:  , auc= 0.231057fmeasure_max= 0.369211, precision= 0.226489, recall= 0.998273
# Validation Iter 5400, auc= 0.921094, fmeasure_max= 0.836066, precision= 0.800628, recall= 0.874786
# Validation Random guess:  auc= 0.242103, fmeasure_max= 0.371869, precision= 0.228763, recall= 0.993139
# Minibatch Loss= 0.370076
# Tarin Iter 5500, auc= 0.947353, fmeasure_max= 0.861170, precision= 0.827913, recall= 0.897210
# Train Random guess:  , auc= 0.264202fmeasure_max= 0.420890, precision= 0.266536, recall= 1.000000
# Validation Iter 5500, auc= 0.927671, fmeasure_max= 0.847189, precision= 0.786765, recall= 0.917667
# Validation Random guess:  auc= 0.222627, fmeasure_max= 0.376134, precision= 0.236093, recall= 0.924528
# Minibatch Loss= 0.479005
# Tarin Iter 5600, auc= 0.957764, fmeasure_max= 0.905751, precision= 0.894322, recall= 0.917476
# Train Random guess:  , auc= 0.249367fmeasure_max= 0.389643, precision= 0.242056, recall= 0.998382
# Validation Iter 5600, auc= 0.917343, fmeasure_max= 0.836983, precision= 0.793846, recall= 0.885077
# Validation Random guess:  auc= 0.233859, fmeasure_max= 0.373134, precision= 0.230092, recall= 0.986278
# Minibatch Loss= 0.419678
# Tarin Iter 5700, auc= 0.965433, fmeasure_max= 0.906925, precision= 0.903561, recall= 0.910314
# Train Random guess:  , auc= 0.268394fmeasure_max= 0.415601, precision= 0.264335, recall= 0.971599
# Validation Iter 5700, auc= 0.914473, fmeasure_max= 0.830156, precision= 0.838879, recall= 0.821612
# Validation Random guess:  auc= 0.233047, fmeasure_max= 0.373246, precision= 0.230459, recall= 0.981132
# Minibatch Loss= 0.403467
# Tarin Iter 5800, auc= 0.962831, fmeasure_max= 0.890971, precision= 0.922399, recall= 0.861614
# Train Random guess:  , auc= 0.241360fmeasure_max= 0.383449, precision= 0.237202, recall= 1.000000
# Validation Iter 5800, auc= 0.908333, fmeasure_max= 0.840336, precision= 0.823723, recall= 0.857633
# Validation Random guess:  auc= 0.231430, fmeasure_max= 0.374172, precision= 0.231842, recall= 0.969125
# Minibatch Loss= 0.423614
# Tarin Iter 5900, auc= 0.951988, fmeasure_max= 0.875850, precision= 0.855482, recall= 0.897213
# Train Random guess:  , auc= 0.212799fmeasure_max= 0.366305, precision= 0.224219, recall= 1.000000
# Validation Iter 5900, auc= 0.937970, fmeasure_max= 0.866455, precision= 0.807407, recall= 0.934820
# Validation Random guess:  auc= 0.239299, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.377336
# Tarin Iter 6000, auc= 0.962464, fmeasure_max= 0.890388, precision= 0.907216, recall= 0.874172
# Train Random guess:  , auc= 0.234012fmeasure_max= 0.382037, precision= 0.236122, recall= 1.000000
# Validation Iter 6000, auc= 0.920809, fmeasure_max= 0.856459, precision= 0.800298, recall= 0.921098
# Validation Random guess:  auc= 0.232336, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.393341
# Tarin Iter 6100, auc= 0.956592, fmeasure_max= 0.897482, precision= 0.912249, recall= 0.883186
# Train Random guess:  , auc= 0.208873fmeasure_max= 0.361600, precision= 0.220703, recall= 1.000000
# Validation Iter 6100, auc= 0.925962, fmeasure_max= 0.836879, precision= 0.774052, recall= 0.910806
# Validation Random guess:  auc= 0.217682, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.407371
# Tarin Iter 6200, auc= 0.975012, fmeasure_max= 0.918264, precision= 0.922921, recall= 0.913655
# Train Random guess:  , auc= 0.204627fmeasure_max= 0.327528, precision= 0.196543, recall= 0.981928
# Validation Iter 6200, auc= 0.934777, fmeasure_max= 0.853514, precision= 0.842809, recall= 0.864494
# Validation Random guess:  auc= 0.244033, fmeasure_max= 0.371392, precision= 0.228402, recall= 0.993139
# Minibatch Loss= 0.263556
# Tarin Iter 6300, auc= 0.964205, fmeasure_max= 0.891106, precision= 0.928943, recall= 0.856230
# Train Random guess:  , auc= 0.241583fmeasure_max= 0.392969, precision= 0.244531, recall= 1.000000
# Validation Iter 6300, auc= 0.934858, fmeasure_max= 0.856680, precision= 0.811350, recall= 0.907376
# Validation Random guess:  auc= 0.241711, fmeasure_max= 0.371877, precision= 0.234790, recall= 0.893654
# Minibatch Loss= 0.414174
# Tarin Iter 6400, auc= 0.973493, fmeasure_max= 0.926222, precision= 0.927046, recall= 0.925400
# Train Random guess:  , auc= 0.235062fmeasure_max= 0.361274, precision= 0.221074, recall= 0.987567
# Validation Iter 6400, auc= 0.921572, fmeasure_max= 0.851485, precision= 0.820350, recall= 0.885077
# Validation Random guess:  auc= 0.243503, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.347787
# Tarin Iter 6500, auc= 0.967004, fmeasure_max= 0.905416, precision= 0.860215, recall= 0.955631
# Train Random guess:  , auc= 0.223521fmeasure_max= 0.374147, precision= 0.231047, recall= 0.982935
# Validation Iter 6500, auc= 0.929271, fmeasure_max= 0.854922, precision= 0.860870, recall= 0.849057
# Validation Random guess:  auc= 0.233399, fmeasure_max= 0.373655, precision= 0.230676, recall= 0.982847
# Minibatch Loss= 0.367619
# Tarin Iter 6600, auc= 0.973630, fmeasure_max= 0.930591, precision= 0.906511, recall= 0.955986
# Train Random guess:  , auc= 0.231106fmeasure_max= 0.364590, precision= 0.224013, recall= 0.978873
# Validation Iter 6600, auc= 0.925540, fmeasure_max= 0.854758, precision= 0.832520, recall= 0.878216
# Validation Random guess:  auc= 0.229489, fmeasure_max= 0.375330, precision= 0.232340, recall= 0.975986
# Minibatch Loss= 0.330811
# Tarin Iter 6700, auc= 0.966347, fmeasure_max= 0.901487, precision= 0.922053, recall= 0.881818
# Train Random guess:  , auc= 0.214894fmeasure_max= 0.354039, precision= 0.215096, recall= 1.000000
# Validation Iter 6700, auc= 0.941661, fmeasure_max= 0.877389, precision= 0.818722, recall= 0.945111
# Validation Random guess:  auc= 0.225289, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.381479
# Tarin Iter 6800, auc= 0.973162, fmeasure_max= 0.914035, precision= 0.887564, recall= 0.942134
# Train Random guess:  , auc= 0.224642fmeasure_max= 0.355398, precision= 0.216100, recall= 1.000000
# Validation Iter 6800, auc= 0.927568, fmeasure_max= 0.858630, precision= 0.868421, recall= 0.849057
# Validation Random guess:  auc= 0.227013, fmeasure_max= 0.376401, precision= 0.232966, recall= 0.979417
# Minibatch Loss= 0.376427
# Tarin Iter 6900, auc= 0.973620, fmeasure_max= 0.905325, precision= 0.881844, recall= 0.930091
# Train Random guess:  , auc= 0.257276fmeasure_max= 0.411298, precision= 0.259928, recall= 0.984802
# Validation Iter 6900, auc= 0.917449, fmeasure_max= 0.853514, precision= 0.842809, recall= 0.864494
# Validation Random guess:  auc= 0.231594, fmeasure_max= 0.372631, precision= 0.229249, recall= 0.994854
# Minibatch Loss= 0.383836
# Tarin Iter 7000, auc= 0.982890, fmeasure_max= 0.933649, precision= 0.942584, recall= 0.924883
# Train Random guess:  , auc= 0.244508fmeasure_max= 0.400627, precision= 0.250490, recall= 1.000000
# Validation Iter 7000, auc= 0.929788, fmeasure_max= 0.852407, precision= 0.789474, recall= 0.926244
# Validation Random guess:  auc= 0.239059, fmeasure_max= 0.371613, precision= 0.228844, recall= 0.987993
# Minibatch Loss= 0.390095
# Tarin Iter 7100, auc= 0.972708, fmeasure_max= 0.905386, precision= 0.906706, recall= 0.904070
# Train Random guess:  , auc= 0.277034fmeasure_max= 0.424374, precision= 0.269548, recall= 0.997093
# Validation Iter 7100, auc= 0.926560, fmeasure_max= 0.852405, precision= 0.825040, recall= 0.881647
# Validation Random guess:  auc= 0.220898, fmeasure_max= 0.371523, precision= 0.230201, recall= 0.962264
# Minibatch Loss= 0.410005
# Tarin Iter 7200, auc= 0.963826, fmeasure_max= 0.905085, precision= 0.897479, recall= 0.912821
# Train Random guess:  , auc= 0.242921fmeasure_max= 0.372137, precision= 0.228605, recall= 1.000000
# Validation Iter 7200, auc= 0.924322, fmeasure_max= 0.856675, precision= 0.819749, recall= 0.897084
# Validation Random guess:  auc= 0.238150, fmeasure_max= 0.373071, precision= 0.230707, recall= 0.974271
# Minibatch Loss= 0.370700
# Tarin Iter 7300, auc= 0.958953, fmeasure_max= 0.896607, precision= 0.867188, recall= 0.928094
# Train Random guess:  , auc= 0.237554fmeasure_max= 0.380134, precision= 0.234762, recall= 0.998328
# Validation Iter 7300, auc= 0.922538, fmeasure_max= 0.844178, precision= 0.842735, recall= 0.845626
# Validation Random guess:  auc= 0.229936, fmeasure_max= 0.371292, precision= 0.228056, recall= 0.998285
# Minibatch Loss= 0.406325
# Tarin Iter 7400, auc= 0.966266, fmeasure_max= 0.905498, precision= 0.858306, recall= 0.958182
# Train Random guess:  , auc= 0.215815fmeasure_max= 0.353698, precision= 0.214844, recall= 1.000000
# Validation Iter 7400, auc= 0.921868, fmeasure_max= 0.855932, precision= 0.845896, recall= 0.866209
# Validation Random guess:  auc= 0.222161, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.326196
# Tarin Iter 7500, auc= 0.977961, fmeasure_max= 0.930937, precision= 0.924812, recall= 0.937143
# Train Random guess:  , auc= 0.200087fmeasure_max= 0.340917, precision= 0.206140, recall= 0.984762
# Validation Iter 7500, auc= 0.923493, fmeasure_max= 0.846878, precision= 0.844710, recall= 0.849057
# Validation Random guess:  auc= 0.218862, fmeasure_max= 0.372049, precision= 0.228538, recall= 1.000000
# Minibatch Loss= 0.303470
# Tarin Iter 7600, auc= 0.967955, fmeasure_max= 0.908304, precision= 0.886824, recall= 0.930851
# Train Random guess:  , auc= 0.233679fmeasure_max= 0.362220, precision= 0.221692, recall= 0.989362
# Validation Iter 7600, auc= 0.916528, fmeasure_max= 0.844615, precision= 0.765690, recall= 0.941681
# Validation Random guess:  auc= 0.220409, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.373362
# Tarin Iter 7700, auc= 0.965193, fmeasure_max= 0.907524, precision= 0.883969, recall= 0.932367
# Train Random guess:  , auc= 0.232374fmeasure_max= 0.392421, precision= 0.245086, recall= 0.983897
# Validation Iter 7700, auc= 0.931139, fmeasure_max= 0.858785, precision= 0.823622, recall= 0.897084
# Validation Random guess:  auc= 0.232456, fmeasure_max= 0.372126, precision= 0.234403, recall= 0.902230
# Minibatch Loss= 0.393750
# Tarin Iter 7800, auc= 0.970069, fmeasure_max= 0.908915, precision= 0.914230, recall= 0.903661
# Train Random guess:  , auc= 0.202059fmeasure_max= 0.344828, precision= 0.214053, recall= 0.886320
# Validation Iter 7800, auc= 0.933879, fmeasure_max= 0.859118, precision= 0.865854, recall= 0.852487
# Validation Random guess:  auc= 0.219990, fmeasure_max= 0.372542, precision= 0.237689, recall= 0.861063
# Minibatch Loss= 0.326920
# Tarin Iter 7900, auc= 0.965671, fmeasure_max= 0.894874, precision= 0.854063, recall= 0.939781
# Train Random guess:  , auc= 0.226615fmeasure_max= 0.352638, precision= 0.214062, recall= 1.000000
# Validation Iter 7900, auc= 0.923066, fmeasure_max= 0.844374, precision= 0.789552, recall= 0.907376
# Validation Random guess:  auc= 0.225325, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.342693
# Tarin Iter 8000, auc= 0.981946, fmeasure_max= 0.934211, precision= 0.917609, recall= 0.951424
# Train Random guess:  , auc= 0.234788fmeasure_max= 0.379358, precision= 0.239542, recall= 0.911223
# Validation Iter 8000, auc= 0.922060, fmeasure_max= 0.856901, precision= 0.846154, recall= 0.867925
# Validation Random guess:  auc= 0.232007, fmeasure_max= 0.372242, precision= 0.228774, recall= 0.998285
# Minibatch Loss= 0.338280
# Tarin Iter 8100, auc= 0.973371, fmeasure_max= 0.910805, precision= 0.894587, recall= 0.927622
# Train Random guess:  , auc= 0.265854fmeasure_max= 0.418677, precision= 0.264763, recall= 1.000000
# Validation Iter 8100, auc= 0.930832, fmeasure_max= 0.860485, precision= 0.838762, recall= 0.883362
# Validation Random guess:  auc= 0.220578, fmeasure_max= 0.372914, precision= 0.229372, recall= 0.996569
# Minibatch Loss= 0.412709
# Tarin Iter 8200, auc= 0.971988, fmeasure_max= 0.909894, precision= 0.886403, recall= 0.934664
# Train Random guess:  , auc= 0.214013fmeasure_max= 0.354797, precision= 0.215656, recall= 1.000000
# Validation Iter 8200, auc= 0.919116, fmeasure_max= 0.841494, precision= 0.815113, recall= 0.869640
# Validation Random guess:  auc= 0.237938, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.320638
# Tarin Iter 8300, auc= 0.970214, fmeasure_max= 0.915916, precision= 0.914543, recall= 0.917293
# Train Random guess:  , auc= 0.251868fmeasure_max= 0.412403, precision= 0.259766, recall= 1.000000
# Validation Iter 8300, auc= 0.921682, fmeasure_max= 0.849835, precision= 0.818760, recall= 0.883362
# Validation Random guess:  auc= 0.222570, fmeasure_max= 0.371207, precision= 0.228628, recall= 0.986278
# Minibatch Loss= 0.406330
# Tarin Iter 8400, auc= 0.964812, fmeasure_max= 0.906373, precision= 0.875380, recall= 0.939641
# Train Random guess:  , auc= 0.224584fmeasure_max= 0.388924, precision= 0.241597, recall= 0.996737
# Validation Iter 8400, auc= 0.915813, fmeasure_max= 0.845957, precision= 0.839527, recall= 0.852487
# Validation Random guess:  auc= 0.248705, fmeasure_max= 0.373255, precision= 0.230184, recall= 0.986278
# Minibatch Loss= 0.403633
# Tarin Iter 8500, auc= 0.980353, fmeasure_max= 0.915825, precision= 0.905158, recall= 0.926746
# Train Random guess:  , auc= 0.240128fmeasure_max= 0.374474, precision= 0.231200, recall= 0.984668
# Validation Iter 8500, auc= 0.920395, fmeasure_max= 0.858102, precision= 0.840461, recall= 0.876501
# Validation Random guess:  auc= 0.234422, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.347861
# Tarin Iter 8600, auc= 0.972716, fmeasure_max= 0.905405, precision= 0.880292, recall= 0.931994
# Train Random guess:  , auc= 0.253583fmeasure_max= 0.405262, precision= 0.254124, recall= 1.000000
# Validation Iter 8600, auc= 0.920377, fmeasure_max= 0.852010, precision= 0.849829, recall= 0.854202
# Validation Random guess:  auc= 0.227807, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.398850
# Tarin Iter 8700, auc= 0.983625, fmeasure_max= 0.931087, precision= 0.912913, recall= 0.950000
# Train Random guess:  , auc= 0.247369fmeasure_max= 0.400375, precision= 0.250293, recall= 1.000000
# Validation Iter 8700, auc= 0.921273, fmeasure_max= 0.850555, precision= 0.846939, recall= 0.854202
# Validation Random guess:  auc= 0.240932, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.362288
# Tarin Iter 8800, auc= 0.980798, fmeasure_max= 0.932945, precision= 0.909091, recall= 0.958084
# Train Random guess:  , auc= 0.262478fmeasure_max= 0.416234, precision= 0.265755, recall= 0.959581
# Validation Iter 8800, auc= 0.923835, fmeasure_max= 0.866499, precision= 0.848684, recall= 0.885077
# Validation Random guess:  auc= 0.222544, fmeasure_max= 0.373134, precision= 0.230092, recall= 0.986278
# Minibatch Loss= 0.341240
# Tarin Iter 8900, auc= 0.974627, fmeasure_max= 0.916525, precision= 0.880524, recall= 0.955595
# Train Random guess:  , auc= 0.223073fmeasure_max= 0.360551, precision= 0.219922, recall= 1.000000
# Validation Iter 8900, auc= 0.918185, fmeasure_max= 0.845344, precision= 0.800613, recall= 0.895369
# Validation Random guess:  auc= 0.225055, fmeasure_max= 0.373168, precision= 0.230305, recall= 0.982847
# Minibatch Loss= 0.338594
# Tarin Iter 9000, auc= 0.976993, fmeasure_max= 0.916230, precision= 0.898973, recall= 0.934164
# Train Random guess:  , auc= 0.232191fmeasure_max= 0.362241, precision= 0.222906, recall= 0.966192
# Validation Iter 9000, auc= 0.916941, fmeasure_max= 0.854671, precision= 0.862129, recall= 0.847341
# Validation Random guess:  auc= 0.236993, fmeasure_max= 0.372368, precision= 0.230362, recall= 0.970840
# Minibatch Loss= 0.335914
# Tarin Iter 9100, auc= 0.982943, fmeasure_max= 0.934112, precision= 0.945946, recall= 0.922570
# Train Random guess:  , auc= 0.246148fmeasure_max= 0.384152, precision= 0.237834, recall= 0.998353
# Validation Iter 9100, auc= 0.920476, fmeasure_max= 0.858120, precision= 0.855196, recall= 0.861063
# Validation Random guess:  auc= 0.235340, fmeasure_max= 0.373698, precision= 0.230615, recall= 0.984563
# Minibatch Loss= 0.346095
# Tarin Iter 9200, auc= 0.971066, fmeasure_max= 0.908284, precision= 0.883453, recall= 0.934551
# Train Random guess:  , auc= 0.250282fmeasure_max= 0.410530, precision= 0.258485, recall= 0.996956
# Validation Iter 9200, auc= 0.923690, fmeasure_max= 0.847826, precision= 0.827080, recall= 0.869640
# Validation Random guess:  auc= 0.220300, fmeasure_max= 0.371346, precision= 0.228458, recall= 0.991424
# Minibatch Loss= 0.370631
# Tarin Iter 9300, auc= 0.976335, fmeasure_max= 0.903963, precision= 0.865693, recall= 0.945774
# Train Random guess:  , auc= 0.242936fmeasure_max= 0.397507, precision= 0.250206, recall= 0.966507
# Validation Iter 9300, auc= 0.924271, fmeasure_max= 0.854468, precision= 0.847973, recall= 0.861063
# Validation Random guess:  auc= 0.219598, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.375899
# Tarin Iter 9400, auc= 0.971107, fmeasure_max= 0.914127, precision= 0.893502, recall= 0.935728
# Train Random guess:  , auc= 0.205991fmeasure_max= 0.343750, precision= 0.207629, recall= 0.998110
# Validation Iter 9400, auc= 0.923102, fmeasure_max= 0.850891, precision= 0.806452, recall= 0.900515
# Validation Random guess:  auc= 0.234341, fmeasure_max= 0.371319, precision= 0.228257, recall= 0.994854
# Minibatch Loss= 0.318417
# Tarin Iter 9500, auc= 0.938780, fmeasure_max= 0.892590, precision= 0.868720, recall= 0.917808
# Train Random guess:  , auc= 0.232913fmeasure_max= 0.372727, precision= 0.229968, recall= 0.982877
# Validation Iter 9500, auc= 0.892762, fmeasure_max= 0.825658, precision= 0.793049, recall= 0.861063
# Validation Random guess:  auc= 0.231910, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.376644
# Tarin Iter 9600, auc= 0.962926, fmeasure_max= 0.903654, precision= 0.863492, recall= 0.947735
# Train Random guess:  , auc= 0.237300fmeasure_max= 0.366539, precision= 0.224394, recall= 1.000000
# Validation Iter 9600, auc= 0.927404, fmeasure_max= 0.854909, precision= 0.866197, recall= 0.843911
# Validation Random guess:  auc= 0.222698, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.347418
# Tarin Iter 9700, auc= 0.971750, fmeasure_max= 0.914980, precision= 0.874613, recall= 0.959253
# Train Random guess:  , auc= 0.223831fmeasure_max= 0.374325, precision= 0.230258, recall= 1.000000
# Validation Iter 9700, auc= 0.913465, fmeasure_max= 0.854468, precision= 0.847973, recall= 0.861063
# Validation Random guess:  auc= 0.218347, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.340483
# Tarin Iter 9800, auc= 0.981851, fmeasure_max= 0.930403, precision= 0.903272, recall= 0.959215
# Train Random guess:  , auc= 0.249459fmeasure_max= 0.410925, precision= 0.258594, recall= 1.000000
# Validation Iter 9800, auc= 0.927114, fmeasure_max= 0.856423, precision= 0.838816, recall= 0.874786
# Validation Random guess:  auc= 0.222537, fmeasure_max= 0.371447, precision= 0.228810, recall= 0.986278
# Minibatch Loss= 0.353775
# Tarin Iter 9900, auc= 0.967182, fmeasure_max= 0.895184, precision= 0.879406, recall= 0.911538
# Train Random guess:  , auc= 0.211365fmeasure_max= 0.341805, precision= 0.211390, recall= 0.892308
# Validation Iter 9900, auc= 0.919228, fmeasure_max= 0.854500, precision= 0.838284, recall= 0.871355
# Validation Random guess:  auc= 0.216630, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.327460
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.934270 F1_max = 0.859258 prec = 0.865741 rec = 0.852872
# Test Random guess: auc= 0.231544 fmeasure_max= 0.375635 , precision= 0.231250 , recall= 1.000000

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
