# %%
# useing this variable for saving models and summaries
exp_name = "DWN2006"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10


wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [8, 2, 2, 1, 1]    #stride of pooling in convolution
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
granularity = np.prod(pooling_stride)
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Tarin Iter 0, auc= 0.201630, fmeasure_max= 0.350000, precision= 0.212121, recall= 1.000000
# Train Random guess:  , auc= 0.225397fmeasure_max= 0.348754, precision= 0.211207, recall= 1.000000
# Validation Iter 0, auc= 0.206438, fmeasure_max= 0.374265, precision= 0.234402, recall= 0.927959
# Validation Random guess:  auc= 0.227375, fmeasure_max= 0.371943, precision= 0.228911, recall= 0.991424
# Minibatch Loss= 1.027621
# Tarin Iter 100, auc= 0.535889, fmeasure_max= 0.579838, precision= 0.500000, recall= 0.690018
# Train Random guess:  , auc= 0.221930fmeasure_max= 0.364973, precision= 0.223221, recall= 1.000000
# Validation Iter 100, auc= 0.559274, fmeasure_max= 0.607560, precision= 0.506881, recall= 0.758148
# Validation Random guess:  auc= 0.234812, fmeasure_max= 0.371659, precision= 0.228787, recall= 0.989708
# Minibatch Loss= 0.883478
# Tarin Iter 200, auc= 0.705888, fmeasure_max= 0.683288, precision= 0.605012, recall= 0.784830
# Train Random guess:  , auc= 0.244456fmeasure_max= 0.404129, precision= 0.253234, recall= 1.000000
# Validation Iter 200, auc= 0.688812, fmeasure_max= 0.650888, precision= 0.641667, recall= 0.660377
# Validation Random guess:  auc= 0.213919, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.815409
# Tarin Iter 300, auc= 0.836454, fmeasure_max= 0.747755, precision= 0.688722, recall= 0.817857
# Train Random guess:  , auc= 0.224332fmeasure_max= 0.362107, precision= 0.227691, recall= 0.883929
# Validation Iter 300, auc= 0.742464, fmeasure_max= 0.712808, precision= 0.664688, recall= 0.768439
# Validation Random guess:  auc= 0.220053, fmeasure_max= 0.371795, precision= 0.228616, recall= 0.994854
# Minibatch Loss= 0.552459
# Tarin Iter 400, auc= 0.814826, fmeasure_max= 0.777244, precision= 0.771065, recall= 0.783522
# Train Random guess:  , auc= 0.233552fmeasure_max= 0.389660, precision= 0.242068, recall= 0.998384
# Validation Iter 400, auc= 0.799885, fmeasure_max= 0.738394, precision= 0.647287, recall= 0.859348
# Validation Random guess:  auc= 0.226488, fmeasure_max= 0.374211, precision= 0.232069, recall= 0.965695
# Minibatch Loss= 0.646179
# Tarin Iter 500, auc= 0.858398, fmeasure_max= 0.800667, precision= 0.779221, recall= 0.823328
# Train Random guess:  , auc= 0.219746fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Validation Iter 500, auc= 0.842696, fmeasure_max= 0.774914, precision= 0.776248, recall= 0.773585
# Validation Random guess:  auc= 0.237222, fmeasure_max= 0.373612, precision= 0.230738, recall= 0.981132
# Minibatch Loss= 0.525542
# Tarin Iter 600, auc= 0.888134, fmeasure_max= 0.807722, precision= 0.763504, recall= 0.857377
# Train Random guess:  , auc= 0.245683fmeasure_max= 0.384979, precision= 0.238374, recall= 1.000000
# Validation Iter 600, auc= 0.839341, fmeasure_max= 0.752979, precision= 0.701183, recall= 0.813036
# Validation Random guess:  auc= 0.213696, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.544221
# Tarin Iter 700, auc= 0.904652, fmeasure_max= 0.826546, precision= 0.762170, recall= 0.902801
# Train Random guess:  , auc= 0.246031fmeasure_max= 0.384566, precision= 0.238434, recall= 0.993410
# Validation Iter 700, auc= 0.850180, fmeasure_max= 0.780998, precision= 0.735964, recall= 0.831904
# Validation Random guess:  auc= 0.216933, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.519049
# Tarin Iter 800, auc= 0.887642, fmeasure_max= 0.796130, precision= 0.721805, recall= 0.887519
# Train Random guess:  , auc= 0.257536fmeasure_max= 0.404613, precision= 0.253615, recall= 1.000000
# Validation Iter 800, auc= 0.879261, fmeasure_max= 0.805817, precision= 0.803754, recall= 0.807890
# Validation Random guess:  auc= 0.229176, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.537744
# Tarin Iter 900, auc= 0.857692, fmeasure_max= 0.794376, precision= 0.805704, recall= 0.783362
# Train Random guess:  , auc= 0.230498fmeasure_max= 0.369410, precision= 0.227182, recall= 0.987868
# Validation Iter 900, auc= 0.879498, fmeasure_max= 0.805369, precision= 0.788177, recall= 0.823328
# Validation Random guess:  auc= 0.226642, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.536885
# Tarin Iter 1000, auc= 0.917615, fmeasure_max= 0.852770, precision= 0.775862, recall= 0.946602
# Train Random guess:  , auc= 0.233845fmeasure_max= 0.390028, precision= 0.242258, recall= 1.000000
# Validation Iter 1000, auc= 0.875231, fmeasure_max= 0.805810, precision= 0.726897, recall= 0.903945
# Validation Random guess:  auc= 0.217535, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.439206
# Tarin Iter 1100, auc= 0.919637, fmeasure_max= 0.847262, precision= 0.822378, recall= 0.873700
# Train Random guess:  , auc= 0.253904fmeasure_max= 0.417005, precision= 0.264054, recall= 0.991085
# Validation Iter 1100, auc= 0.895777, fmeasure_max= 0.827356, precision= 0.805195, recall= 0.850772
# Validation Random guess:  auc= 0.246473, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.504796
# Tarin Iter 1200, auc= 0.898735, fmeasure_max= 0.819620, precision= 0.811912, recall= 0.827476
# Train Random guess:  , auc= 0.233683fmeasure_max= 0.393093, precision= 0.244627, recall= 1.000000
# Validation Iter 1200, auc= 0.906987, fmeasure_max= 0.828767, precision= 0.827350, recall= 0.830189
# Validation Random guess:  auc= 0.236332, fmeasure_max= 0.371419, precision= 0.228605, recall= 0.989708
# Minibatch Loss= 0.540944
# Tarin Iter 1300, auc= 0.931734, fmeasure_max= 0.863706, precision= 0.881250, recall= 0.846847
# Train Random guess:  , auc= 0.265068fmeasure_max= 0.413815, precision= 0.260989, recall= 0.998498
# Validation Iter 1300, auc= 0.915180, fmeasure_max= 0.845912, precision= 0.780842, recall= 0.922813
# Validation Random guess:  auc= 0.216862, fmeasure_max= 0.373246, precision= 0.230459, recall= 0.981132
# Minibatch Loss= 0.474519
# Tarin Iter 1400, auc= 0.890695, fmeasure_max= 0.829694, precision= 0.843694, recall= 0.816151
# Train Random guess:  , auc= 0.235282fmeasure_max= 0.371081, precision= 0.227987, recall= 0.996564
# Validation Iter 1400, auc= 0.905209, fmeasure_max= 0.831343, precision= 0.735799, recall= 0.955403
# Validation Random guess:  auc= 0.220418, fmeasure_max= 0.376297, precision= 0.233777, recall= 0.963979
# Minibatch Loss= 0.510517
# Tarin Iter 1500, auc= 0.898021, fmeasure_max= 0.838499, precision= 0.825040, recall= 0.852405
# Train Random guess:  , auc= 0.258204fmeasure_max= 0.381587, precision= 0.235964, recall= 0.996683
# Validation Iter 1500, auc= 0.912610, fmeasure_max= 0.829876, precision= 0.803859, recall= 0.857633
# Validation Random guess:  auc= 0.238497, fmeasure_max= 0.377384, precision= 0.235444, recall= 0.950257
# Minibatch Loss= 0.485948
# Tarin Iter 1600, auc= 0.894512, fmeasure_max= 0.815859, precision= 0.799655, recall= 0.832734
# Train Random guess:  , auc= 0.224397fmeasure_max= 0.358344, precision= 0.218454, recall= 0.996403
# Validation Iter 1600, auc= 0.908071, fmeasure_max= 0.820396, precision= 0.737346, recall= 0.924528
# Validation Random guess:  auc= 0.238546, fmeasure_max= 0.374436, precision= 0.234756, recall= 0.924528
# Minibatch Loss= 0.530844
# Tarin Iter 1700, auc= 0.935628, fmeasure_max= 0.868016, precision= 0.871545, recall= 0.864516
# Train Random guess:  , auc= 0.251088fmeasure_max= 0.391176, precision= 0.245759, recall= 0.958065
# Validation Iter 1700, auc= 0.902301, fmeasure_max= 0.845973, precision= 0.777299, recall= 0.927959
# Validation Random guess:  auc= 0.250463, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.425919
# Tarin Iter 1800, auc= 0.904949, fmeasure_max= 0.819107, precision= 0.803379, recall= 0.835463
# Train Random guess:  , auc= 0.258250fmeasure_max= 0.393587, precision= 0.245010, recall= 1.000000
# Validation Iter 1800, auc= 0.908882, fmeasure_max= 0.833876, precision= 0.793798, recall= 0.878216
# Validation Random guess:  auc= 0.219425, fmeasure_max= 0.372168, precision= 0.229358, recall= 0.986278
# Minibatch Loss= 0.566113
# Tarin Iter 1900, auc= 0.907542, fmeasure_max= 0.835093, precision= 0.788344, recall= 0.887737
# Train Random guess:  , auc= 0.222725fmeasure_max= 0.368907, precision= 0.226172, recall= 1.000000
# Validation Iter 1900, auc= 0.898402, fmeasure_max= 0.839813, precision= 0.768137, recall= 0.926244
# Validation Random guess:  auc= 0.221650, fmeasure_max= 0.372392, precision= 0.229068, recall= 0.994854
# Minibatch Loss= 0.446593
# Tarin Iter 2000, auc= 0.954418, fmeasure_max= 0.881245, precision= 0.826421, recall= 0.943860
# Train Random guess:  , auc= 0.233314fmeasure_max= 0.364800, precision= 0.223092, recall= 1.000000
# Validation Iter 2000, auc= 0.921247, fmeasure_max= 0.842105, precision= 0.820847, recall= 0.864494
# Validation Random guess:  auc= 0.229158, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.421102
# Tarin Iter 2100, auc= 0.930746, fmeasure_max= 0.858500, precision= 0.843284, recall= 0.874275
# Train Random guess:  , auc= 0.205646fmeasure_max= 0.336485, precision= 0.202353, recall= 0.998066
# Validation Iter 2100, auc= 0.905306, fmeasure_max= 0.837607, precision= 0.765625, recall= 0.924528
# Validation Random guess:  auc= 0.212551, fmeasure_max= 0.373533, precision= 0.230584, recall= 0.982847
# Minibatch Loss= 0.407098
# Tarin Iter 2200, auc= 0.948332, fmeasure_max= 0.871795, precision= 0.847079, recall= 0.897996
# Train Random guess:  , auc= 0.211020fmeasure_max= 0.353396, precision= 0.214621, recall= 1.000000
# Validation Iter 2200, auc= 0.930521, fmeasure_max= 0.868944, precision= 0.809172, recall= 0.938250
# Validation Random guess:  auc= 0.239032, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.400426
# Tarin Iter 2300, auc= 0.925774, fmeasure_max= 0.839506, precision= 0.821752, recall= 0.858044
# Train Random guess:  , auc= 0.262157fmeasure_max= 0.396994, precision= 0.247656, recall= 1.000000
# Validation Iter 2300, auc= 0.915713, fmeasure_max= 0.853933, precision= 0.802413, recall= 0.912521
# Validation Random guess:  auc= 0.224191, fmeasure_max= 0.371319, precision= 0.228257, recall= 0.994854
# Minibatch Loss= 0.512957
# Tarin Iter 2400, auc= 0.937168, fmeasure_max= 0.871369, precision= 0.863487, recall= 0.879397
# Train Random guess:  , auc= 0.231730fmeasure_max= 0.378706, precision= 0.233858, recall= 0.994975
# Validation Iter 2400, auc= 0.911679, fmeasure_max= 0.847041, precision= 0.767409, recall= 0.945111
# Validation Random guess:  auc= 0.219227, fmeasure_max= 0.372242, precision= 0.228774, recall= 0.998285
# Minibatch Loss= 0.397152
# Tarin Iter 2500, auc= 0.947144, fmeasure_max= 0.888889, precision= 0.896797, recall= 0.881119
# Train Random guess:  , auc= 0.220490fmeasure_max= 0.366265, precision= 0.228033, recall= 0.930070
# Validation Iter 2500, auc= 0.910192, fmeasure_max= 0.834171, precision= 0.815057, recall= 0.854202
# Validation Random guess:  auc= 0.244638, fmeasure_max= 0.373230, precision= 0.229703, recall= 0.994854
# Minibatch Loss= 0.416452
# Tarin Iter 2600, auc= 0.962729, fmeasure_max= 0.899649, precision= 0.891516, recall= 0.907932
# Train Random guess:  , auc= 0.285641fmeasure_max= 0.433653, precision= 0.277404, recall= 0.992918
# Validation Iter 2600, auc= 0.904395, fmeasure_max= 0.842365, precision= 0.807874, recall= 0.879931
# Validation Random guess:  auc= 0.229925, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.471318
# Tarin Iter 2700, auc= 0.939266, fmeasure_max= 0.870476, precision= 0.903162, recall= 0.840074
# Train Random guess:  , auc= 0.215041fmeasure_max= 0.352140, precision= 0.213780, recall= 0.998162
# Validation Iter 2700, auc= 0.915385, fmeasure_max= 0.849387, precision= 0.867621, recall= 0.831904
# Validation Random guess:  auc= 0.225736, fmeasure_max= 0.373308, precision= 0.229853, recall= 0.993139
# Minibatch Loss= 0.467240
# Tarin Iter 2800, auc= 0.943487, fmeasure_max= 0.873323, precision= 0.854227, recall= 0.893293
# Train Random guess:  , auc= 0.270009fmeasure_max= 0.408468, precision= 0.256651, recall= 1.000000
# Validation Iter 2800, auc= 0.918519, fmeasure_max= 0.862179, precision= 0.809023, recall= 0.922813
# Validation Random guess:  auc= 0.226807, fmeasure_max= 0.372762, precision= 0.229077, recall= 1.000000
# Minibatch Loss= 0.492823
# Tarin Iter 2900, auc= 0.942238, fmeasure_max= 0.872666, precision= 0.834416, recall= 0.914591
# Train Random guess:  , auc= 0.227988fmeasure_max= 0.360487, precision= 0.219875, recall= 1.000000
# Validation Iter 2900, auc= 0.909071, fmeasure_max= 0.834471, precision= 0.830221, recall= 0.838765
# Validation Random guess:  auc= 0.223241, fmeasure_max= 0.371207, precision= 0.228628, recall= 0.986278
# Minibatch Loss= 0.422788
# Tarin Iter 3000, auc= 0.950394, fmeasure_max= 0.873288, precision= 0.904255, recall= 0.844371
# Train Random guess:  , auc= 0.239509fmeasure_max= 0.382437, precision= 0.236707, recall= 0.995033
# Validation Iter 3000, auc= 0.905172, fmeasure_max= 0.834002, precision= 0.783133, recall= 0.891938
# Validation Random guess:  auc= 0.231515, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.421771
# Tarin Iter 3100, auc= 0.923881, fmeasure_max= 0.836399, precision= 0.862275, recall= 0.812030
# Train Random guess:  , auc= 0.197328fmeasure_max= 0.344642, precision= 0.209816, recall= 0.964286
# Validation Iter 3100, auc= 0.912936, fmeasure_max= 0.845732, precision= 0.778098, recall= 0.926244
# Validation Random guess:  auc= 0.223319, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.411077
# Tarin Iter 3200, auc= 0.950196, fmeasure_max= 0.887974, precision= 0.892384, recall= 0.883607
# Train Random guess:  , auc= 0.236643fmeasure_max= 0.386198, precision= 0.239310, recall= 1.000000
# Validation Iter 3200, auc= 0.911663, fmeasure_max= 0.837171, precision= 0.804107, recall= 0.873070
# Validation Random guess:  auc= 0.228260, fmeasure_max= 0.371774, precision= 0.229621, recall= 0.975986
# Minibatch Loss= 0.439637
# Tarin Iter 3300, auc= 0.963750, fmeasure_max= 0.906379, precision= 0.872408, recall= 0.943103
# Train Random guess:  , auc= 0.216528fmeasure_max= 0.370016, precision= 0.227006, recall= 1.000000
# Validation Iter 3300, auc= 0.910299, fmeasure_max= 0.845182, precision= 0.783309, recall= 0.917667
# Validation Random guess:  auc= 0.214184, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.373269
# Tarin Iter 3400, auc= 0.951007, fmeasure_max= 0.886143, precision= 0.852292, recall= 0.922794
# Train Random guess:  , auc= 0.208342fmeasure_max= 0.351989, precision= 0.215524, recall= 0.959559
# Validation Iter 3400, auc= 0.897765, fmeasure_max= 0.812843, precision= 0.747839, recall= 0.890223
# Validation Random guess:  auc= 0.222798, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.366044
# Tarin Iter 3500, auc= 0.917872, fmeasure_max= 0.825889, precision= 0.861217, recall= 0.793345
# Train Random guess:  , auc= 0.248105fmeasure_max= 0.365206, precision= 0.223396, recall= 1.000000
# Validation Iter 3500, auc= 0.922276, fmeasure_max= 0.858091, precision= 0.831190, recall= 0.886792
# Validation Random guess:  auc= 0.225591, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.420580
# Tarin Iter 3600, auc= 0.947609, fmeasure_max= 0.876501, precision= 0.887153, recall= 0.866102
# Train Random guess:  , auc= 0.230216fmeasure_max= 0.375318, precision= 0.231010, recall= 1.000000
# Validation Iter 3600, auc= 0.920033, fmeasure_max= 0.850368, precision= 0.812500, recall= 0.891938
# Validation Random guess:  auc= 0.221801, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.400622
# Tarin Iter 3700, auc= 0.958432, fmeasure_max= 0.890675, precision= 0.879365, recall= 0.902280
# Train Random guess:  , auc= 0.244800fmeasure_max= 0.387015, precision= 0.239937, recall= 1.000000
# Validation Iter 3700, auc= 0.907333, fmeasure_max= 0.839931, precision= 0.842832, recall= 0.837050
# Validation Random guess:  auc= 0.230842, fmeasure_max= 0.371475, precision= 0.229017, recall= 0.982847
# Minibatch Loss= 0.417015
# Tarin Iter 3800, auc= 0.946792, fmeasure_max= 0.889427, precision= 0.890145, recall= 0.888710
# Train Random guess:  , auc= 0.245679fmeasure_max= 0.391733, precision= 0.243960, recall= 0.993548
# Validation Iter 3800, auc= 0.922674, fmeasure_max= 0.877451, precision= 0.837754, recall= 0.921098
# Validation Random guess:  auc= 0.235886, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.469699
# Tarin Iter 3900, auc= 0.948014, fmeasure_max= 0.881188, precision= 0.846276, recall= 0.919105
# Train Random guess:  , auc= 0.221600fmeasure_max= 0.369946, precision= 0.226953, recall= 1.000000
# Validation Iter 3900, auc= 0.921729, fmeasure_max= 0.842962, precision= 0.801858, recall= 0.888508
# Validation Random guess:  auc= 0.235619, fmeasure_max= 0.371200, precision= 0.228167, recall= 0.994854
# Minibatch Loss= 0.389585
# Tarin Iter 4000, auc= 0.959486, fmeasure_max= 0.899377, precision= 0.884413, recall= 0.914855
# Train Random guess:  , auc= 0.221754fmeasure_max= 0.355026, precision= 0.215909, recall= 0.998188
# Validation Iter 4000, auc= 0.902767, fmeasure_max= 0.837593, precision= 0.806349, recall= 0.871355
# Validation Random guess:  auc= 0.220729, fmeasure_max= 0.374028, precision= 0.232940, recall= 0.948542
# Minibatch Loss= 0.333064
# Tarin Iter 4100, auc= 0.962715, fmeasure_max= 0.911924, precision= 0.871762, recall= 0.955966
# Train Random guess:  , auc= 0.280854fmeasure_max= 0.432034, precision= 0.275538, recall= 1.000000
# Validation Iter 4100, auc= 0.921628, fmeasure_max= 0.847021, precision= 0.798179, recall= 0.902230
# Validation Random guess:  auc= 0.220180, fmeasure_max= 0.372228, precision= 0.229035, recall= 0.993139
# Minibatch Loss= 0.409961
# Tarin Iter 4200, auc= 0.964796, fmeasure_max= 0.895430, precision= 0.901716, recall= 0.889231
# Train Random guess:  , auc= 0.265823fmeasure_max= 0.406618, precision= 0.256318, recall= 0.983077
# Validation Iter 4200, auc= 0.910465, fmeasure_max= 0.853441, precision= 0.808282, recall= 0.903945
# Validation Random guess:  auc= 0.240679, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.425220
# Tarin Iter 4300, auc= 0.969145, fmeasure_max= 0.916990, precision= 0.876855, recall= 0.960976
# Train Random guess:  , auc= 0.237927fmeasure_max= 0.389420, precision= 0.242172, recall= 0.993496
# Validation Iter 4300, auc= 0.912870, fmeasure_max= 0.843931, precision= 0.813694, recall= 0.876501
# Validation Random guess:  auc= 0.223734, fmeasure_max= 0.373905, precision= 0.230584, recall= 0.987993
# Minibatch Loss= 0.352629
# Tarin Iter 4400, auc= 0.956282, fmeasure_max= 0.877607, precision= 0.888073, recall= 0.867384
# Train Random guess:  , auc= 0.219503fmeasure_max= 0.358374, precision= 0.218911, recall= 0.987455
# Validation Iter 4400, auc= 0.912890, fmeasure_max= 0.859259, precision= 0.825949, recall= 0.895369
# Validation Random guess:  auc= 0.233642, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.388271
# Tarin Iter 4500, auc= 0.965100, fmeasure_max= 0.889984, precision= 0.912458, recall= 0.868590
# Train Random guess:  , auc= 0.244850fmeasure_max= 0.392565, precision= 0.244314, recall= 0.998397
# Validation Iter 4500, auc= 0.920217, fmeasure_max= 0.859967, precision= 0.827258, recall= 0.895369
# Validation Random guess:  auc= 0.231252, fmeasure_max= 0.375041, precision= 0.231638, recall= 0.984563
# Minibatch Loss= 0.382874
# Tarin Iter 4600, auc= 0.957127, fmeasure_max= 0.891392, precision= 0.844512, recall= 0.943782
# Train Random guess:  , auc= 0.230471fmeasure_max= 0.374115, precision= 0.230647, recall= 0.989779
# Validation Iter 4600, auc= 0.918858, fmeasure_max= 0.847298, precision= 0.779539, recall= 0.927959
# Validation Random guess:  auc= 0.219002, fmeasure_max= 0.374036, precision= 0.230130, recall= 0.998285
# Minibatch Loss= 0.412517
# Tarin Iter 4700, auc= 0.951207, fmeasure_max= 0.892238, precision= 0.857971, recall= 0.929356
# Train Random guess:  , auc= 0.249836fmeasure_max= 0.400785, precision= 0.253097, recall= 0.962323
# Validation Iter 4700, auc= 0.913856, fmeasure_max= 0.844884, precision= 0.813990, recall= 0.878216
# Validation Random guess:  auc= 0.242478, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.417911
# Tarin Iter 4800, auc= 0.969787, fmeasure_max= 0.899408, precision= 0.910959, recall= 0.888147
# Train Random guess:  , auc= 0.240421fmeasure_max= 0.380497, precision= 0.235132, recall= 0.996661
# Validation Iter 4800, auc= 0.915313, fmeasure_max= 0.835000, precision= 0.811994, recall= 0.859348
# Validation Random guess:  auc= 0.221220, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.383004
# Tarin Iter 4900, auc= 0.963241, fmeasure_max= 0.903690, precision= 0.883803, recall= 0.924494
# Train Random guess:  , auc= 0.229846fmeasure_max= 0.353293, precision= 0.215591, recall= 0.977901
# Validation Iter 4900, auc= 0.924777, fmeasure_max= 0.857385, precision= 0.848739, recall= 0.866209
# Validation Random guess:  auc= 0.237446, fmeasure_max= 0.371704, precision= 0.228730, recall= 0.991424
# Minibatch Loss= 0.375010
# Tarin Iter 5000, auc= 0.967616, fmeasure_max= 0.907154, precision= 0.901664, recall= 0.912711
# Train Random guess:  , auc= 0.242835fmeasure_max= 0.406980, precision= 0.255477, recall= 1.000000
# Validation Iter 5000, auc= 0.931770, fmeasure_max= 0.855263, precision= 0.821485, recall= 0.891938
# Validation Random guess:  auc= 0.251977, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.452451
# Tarin Iter 5100, auc= 0.974477, fmeasure_max= 0.920128, precision= 0.927536, recall= 0.912837
# Train Random guess:  , auc= 0.246820fmeasure_max= 0.395965, precision= 0.247147, recall= 0.995246
# Validation Iter 5100, auc= 0.925074, fmeasure_max= 0.862401, precision= 0.881720, recall= 0.843911
# Validation Random guess:  auc= 0.236890, fmeasure_max= 0.373193, precision= 0.230800, recall= 0.974271
# Minibatch Loss= 0.397527
# Tarin Iter 5200, auc= 0.974092, fmeasure_max= 0.917009, precision= 0.916256, recall= 0.917763
# Train Random guess:  , auc= 0.248049fmeasure_max= 0.384908, precision= 0.238413, recall= 0.998355
# Validation Iter 5200, auc= 0.924895, fmeasure_max= 0.859212, precision= 0.809091, recall= 0.915952
# Validation Random guess:  auc= 0.253871, fmeasure_max= 0.371539, precision= 0.228696, recall= 0.989708
# Minibatch Loss= 0.367955
# Tarin Iter 5300, auc= 0.981688, fmeasure_max= 0.925000, precision= 0.884462, recall= 0.969432
# Train Random guess:  , auc= 0.266025fmeasure_max= 0.424374, precision= 0.269442, recall= 0.998544
# Validation Iter 5300, auc= 0.922347, fmeasure_max= 0.857613, precision= 0.824367, recall= 0.893654
# Validation Random guess:  auc= 0.256388, fmeasure_max= 0.373482, precision= 0.230925, recall= 0.975986
# Minibatch Loss= 0.390658
# Tarin Iter 5400, auc= 0.966909, fmeasure_max= 0.908778, precision= 0.897959, recall= 0.919861
# Train Random guess:  , auc= 0.207500fmeasure_max= 0.366422, precision= 0.224306, recall= 1.000000
# Validation Iter 5400, auc= 0.930034, fmeasure_max= 0.860051, precision= 0.850671, recall= 0.869640
# Validation Random guess:  auc= 0.235789, fmeasure_max= 0.375769, precision= 0.231629, recall= 0.994854
# Minibatch Loss= 0.380381
# Tarin Iter 5500, auc= 0.978641, fmeasure_max= 0.921077, precision= 0.916821, recall= 0.925373
# Train Random guess:  , auc= 0.215374fmeasure_max= 0.351648, precision= 0.214025, recall= 0.985075
# Validation Iter 5500, auc= 0.935102, fmeasure_max= 0.868825, precision= 0.862944, recall= 0.874786
# Validation Random guess:  auc= 0.221658, fmeasure_max= 0.372511, precision= 0.229158, recall= 0.994854
# Minibatch Loss= 0.301209
# Tarin Iter 5600, auc= 0.974447, fmeasure_max= 0.911839, precision= 0.944348, recall= 0.881494
# Train Random guess:  , auc= 0.240832fmeasure_max= 0.388626, precision= 0.241271, recall= 0.998377
# Validation Iter 5600, auc= 0.925007, fmeasure_max= 0.858355, precision= 0.848993, recall= 0.867925
# Validation Random guess:  auc= 0.231403, fmeasure_max= 0.374523, precision= 0.240804, recall= 0.842196
# Minibatch Loss= 0.371844
# Tarin Iter 5700, auc= 0.976975, fmeasure_max= 0.919079, precision= 0.917037, recall= 0.921131
# Train Random guess:  , auc= 0.262575fmeasure_max= 0.416483, precision= 0.264061, recall= 0.985119
# Validation Iter 5700, auc= 0.923869, fmeasure_max= 0.854150, precision= 0.805471, recall= 0.909091
# Validation Random guess:  auc= 0.231477, fmeasure_max= 0.372123, precision= 0.228684, recall= 0.998285
# Minibatch Loss= 0.401782
# Tarin Iter 5800, auc= 0.971394, fmeasure_max= 0.903522, precision= 0.900763, recall= 0.906298
# Train Random guess:  , auc= 0.252258fmeasure_max= 0.406631, precision= 0.255302, recall= 0.998464
# Validation Iter 5800, auc= 0.927623, fmeasure_max= 0.847257, precision= 0.833887, recall= 0.861063
# Validation Random guess:  auc= 0.231326, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.416237
# Tarin Iter 5900, auc= 0.964150, fmeasure_max= 0.902184, precision= 0.886194, recall= 0.918762
# Train Random guess:  , auc= 0.196970fmeasure_max= 0.336601, precision= 0.202517, recall= 0.996132
# Validation Iter 5900, auc= 0.938655, fmeasure_max= 0.869058, precision= 0.845779, recall= 0.893654
# Validation Random guess:  auc= 0.217066, fmeasure_max= 0.372168, precision= 0.229358, recall= 0.986278
# Minibatch Loss= 0.354274
# Tarin Iter 6000, auc= 0.966046, fmeasure_max= 0.903282, precision= 0.877517, recall= 0.930605
# Train Random guess:  , auc= 0.228577fmeasure_max= 0.363378, precision= 0.226950, recall= 0.911032
# Validation Iter 6000, auc= 0.933159, fmeasure_max= 0.864819, precision= 0.847039, recall= 0.883362
# Validation Random guess:  auc= 0.226958, fmeasure_max= 0.376302, precision= 0.232222, recall= 0.991424
# Minibatch Loss= 0.374011
# Tarin Iter 6100, auc= 0.972787, fmeasure_max= 0.911215, precision= 0.928571, recall= 0.894495
# Train Random guess:  , auc= 0.256013fmeasure_max= 0.407615, precision= 0.256078, recall= 0.998471
# Validation Iter 6100, auc= 0.931418, fmeasure_max= 0.874086, precision= 0.830247, recall= 0.922813
# Validation Random guess:  auc= 0.249710, fmeasure_max= 0.374143, precision= 0.231048, recall= 0.982847
# Minibatch Loss= 0.424884
# Tarin Iter 6200, auc= 0.973588, fmeasure_max= 0.911215, precision= 0.924171, recall= 0.898618
# Train Random guess:  , auc= 0.247541fmeasure_max= 0.405996, precision= 0.254802, recall= 0.998464
# Validation Iter 6200, auc= 0.938911, fmeasure_max= 0.859532, precision= 0.838499, recall= 0.881647
# Validation Random guess:  auc= 0.233580, fmeasure_max= 0.372286, precision= 0.228717, recall= 1.000000
# Minibatch Loss= 0.409654
# Tarin Iter 6300, auc= 0.972502, fmeasure_max= 0.911667, precision= 0.902640, recall= 0.920875
# Train Random guess:  , auc= 0.233765fmeasure_max= 0.380228, precision= 0.239234, recall= 0.925926
# Validation Iter 6300, auc= 0.922415, fmeasure_max= 0.841787, precision= 0.753388, recall= 0.953688
# Validation Random guess:  auc= 0.236804, fmeasure_max= 0.371246, precision= 0.228112, recall= 0.996569
# Minibatch Loss= 0.357479
# Tarin Iter 6400, auc= 0.968007, fmeasure_max= 0.910909, precision= 0.885159, recall= 0.938202
# Train Random guess:  , auc= 0.200636fmeasure_max= 0.345184, precision= 0.208594, recall= 1.000000
# Validation Iter 6400, auc= 0.935662, fmeasure_max= 0.873377, precision= 0.828968, recall= 0.922813
# Validation Random guess:  auc= 0.245096, fmeasure_max= 0.372498, precision= 0.229423, recall= 0.989708
# Minibatch Loss= 0.335298
# Tarin Iter 6500, auc= 0.975029, fmeasure_max= 0.912587, precision= 0.925532, recall= 0.900000
# Train Random guess:  , auc= 0.224657fmeasure_max= 0.369427, precision= 0.226562, recall= 1.000000
# Validation Iter 6500, auc= 0.933329, fmeasure_max= 0.866723, precision= 0.847541, recall= 0.886792
# Validation Random guess:  auc= 0.245937, fmeasure_max= 0.374749, precision= 0.232684, recall= 0.962264
# Minibatch Loss= 0.354068
# Tarin Iter 6600, auc= 0.962002, fmeasure_max= 0.887737, precision= 0.884682, recall= 0.890815
# Train Random guess:  , auc= 0.228831fmeasure_max= 0.368236, precision= 0.225844, recall= 0.996534
# Validation Iter 6600, auc= 0.928562, fmeasure_max= 0.855932, precision= 0.845896, recall= 0.866209
# Validation Random guess:  auc= 0.223206, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 0.383391
# Tarin Iter 6700, auc= 0.964332, fmeasure_max= 0.892576, precision= 0.885615, recall= 0.899648
# Train Random guess:  , auc= 0.214242fmeasure_max= 0.363520, precision= 0.222310, recall= 0.996479
# Validation Iter 6700, auc= 0.935721, fmeasure_max= 0.870528, precision= 0.864636, recall= 0.876501
# Validation Random guess:  auc= 0.237766, fmeasure_max= 0.371277, precision= 0.230012, recall= 0.962264
# Minibatch Loss= 0.363173
# Tarin Iter 6800, auc= 0.974123, fmeasure_max= 0.903704, precision= 0.908940, recall= 0.898527
# Train Random guess:  , auc= 0.242784fmeasure_max= 0.385854, precision= 0.239045, recall= 1.000000
# Validation Iter 6800, auc= 0.934677, fmeasure_max= 0.854701, precision= 0.781250, recall= 0.943396
# Validation Random guess:  auc= 0.221439, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.374225
# Tarin Iter 6900, auc= 0.977131, fmeasure_max= 0.927288, precision= 0.921769, recall= 0.932874
# Train Random guess:  , auc= 0.231371fmeasure_max= 0.371038, precision= 0.230132, recall= 0.956971
# Validation Iter 6900, auc= 0.936853, fmeasure_max= 0.867956, precision= 0.851485, recall= 0.885077
# Validation Random guess:  auc= 0.235139, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.364885
# Tarin Iter 7000, auc= 0.963484, fmeasure_max= 0.891304, precision= 0.846032, recall= 0.941696
# Train Random guess:  , auc= 0.228735fmeasure_max= 0.368060, precision= 0.228316, recall= 0.948763
# Validation Iter 7000, auc= 0.938710, fmeasure_max= 0.873285, precision= 0.824695, recall= 0.927959
# Validation Random guess:  auc= 0.226694, fmeasure_max= 0.371898, precision= 0.228968, recall= 0.989708
# Minibatch Loss= 0.391390
# Tarin Iter 7100, auc= 0.977591, fmeasure_max= 0.920337, precision= 0.946050, recall= 0.895985
# Train Random guess:  , auc= 0.202256fmeasure_max= 0.353816, precision= 0.215016, recall= 0.998175
# Validation Iter 7100, auc= 0.926365, fmeasure_max= 0.859425, precision= 0.804185, recall= 0.922813
# Validation Random guess:  auc= 0.233707, fmeasure_max= 0.372362, precision= 0.232272, recall= 0.938250
# Minibatch Loss= 0.344667
# Tarin Iter 7200, auc= 0.979437, fmeasure_max= 0.921348, precision= 0.925806, recall= 0.916933
# Train Random guess:  , auc= 0.248687fmeasure_max= 0.393340, precision= 0.244818, recall= 1.000000
# Validation Iter 7200, auc= 0.932489, fmeasure_max= 0.857143, precision= 0.882033, recall= 0.833619
# Validation Random guess:  auc= 0.225404, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.377724
# Tarin Iter 7300, auc= 0.968845, fmeasure_max= 0.904605, precision= 0.878594, recall= 0.932203
# Train Random guess:  , auc= 0.233928fmeasure_max= 0.374603, precision= 0.230469, recall= 1.000000
# Validation Iter 7300, auc= 0.938223, fmeasure_max= 0.882255, precision= 0.853933, recall= 0.912521
# Validation Random guess:  auc= 0.226499, fmeasure_max= 0.372454, precision= 0.229482, recall= 0.987993
# Minibatch Loss= 0.350462
# Tarin Iter 7400, auc= 0.990472, fmeasure_max= 0.950376, precision= 0.925329, recall= 0.976816
# Train Random guess:  , auc= 0.248841fmeasure_max= 0.403492, precision= 0.252734, recall= 1.000000
# Validation Iter 7400, auc= 0.930347, fmeasure_max= 0.860345, precision= 0.864818, recall= 0.855918
# Validation Random guess:  auc= 0.229600, fmeasure_max= 0.371511, precision= 0.228493, recall= 0.993139
# Minibatch Loss= 0.366292
# Tarin Iter 7500, auc= 0.971631, fmeasure_max= 0.908197, precision= 0.897893, recall= 0.918740
# Train Random guess:  , auc= 0.256157fmeasure_max= 0.385884, precision= 0.240840, recall= 0.970149
# Validation Iter 7500, auc= 0.932752, fmeasure_max= 0.874582, precision= 0.853181, recall= 0.897084
# Validation Random guess:  auc= 0.223132, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.379248
# Tarin Iter 7600, auc= 0.985266, fmeasure_max= 0.941176, precision= 0.918768, recall= 0.964706
# Train Random guess:  , auc= 0.276309fmeasure_max= 0.419753, precision= 0.265625, recall= 1.000000
# Validation Iter 7600, auc= 0.932763, fmeasure_max= 0.864912, precision= 0.885099, recall= 0.845626
# Validation Random guess:  auc= 0.236667, fmeasure_max= 0.373134, precision= 0.230092, recall= 0.986278
# Minibatch Loss= 0.336518
# Tarin Iter 7700, auc= 0.972261, fmeasure_max= 0.925346, precision= 0.916058, recall= 0.934823
# Train Random guess:  , auc= 0.198809fmeasure_max= 0.348278, precision= 0.210941, recall= 0.998138
# Validation Iter 7700, auc= 0.936823, fmeasure_max= 0.873239, precision= 0.896926, recall= 0.850772
# Validation Random guess:  auc= 0.232515, fmeasure_max= 0.373026, precision= 0.230769, recall= 0.972556
# Minibatch Loss= 0.339606
# Tarin Iter 7800, auc= 0.973361, fmeasure_max= 0.920325, precision= 0.930921, recall= 0.909968
# Train Random guess:  , auc= 0.249492fmeasure_max= 0.391304, precision= 0.243339, recall= 0.998392
# Validation Iter 7800, auc= 0.943076, fmeasure_max= 0.884388, precision= 0.870432, recall= 0.898799
# Validation Random guess:  auc= 0.230685, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.389725
# Tarin Iter 7900, auc= 0.968095, fmeasure_max= 0.912553, precision= 0.859230, recall= 0.972932
# Train Random guess:  , auc= 0.263457fmeasure_max= 0.413404, precision= 0.261076, recall= 0.992481
# Validation Iter 7900, auc= 0.926109, fmeasure_max= 0.868486, precision= 0.838658, recall= 0.900515
# Validation Random guess:  auc= 0.234020, fmeasure_max= 0.372033, precision= 0.228797, recall= 0.994854
# Minibatch Loss= 0.395003
# Tarin Iter 8000, auc= 0.966331, fmeasure_max= 0.906428, precision= 0.868955, recall= 0.947279
# Train Random guess:  , auc= 0.223681fmeasure_max= 0.374362, precision= 0.230377, recall= 0.998299
# Validation Iter 8000, auc= 0.936357, fmeasure_max= 0.873583, precision= 0.888298, recall= 0.859348
# Validation Random guess:  auc= 0.230789, fmeasure_max= 0.372606, precision= 0.229784, recall= 0.984563
# Minibatch Loss= 0.357675
# Tarin Iter 8100, auc= 0.980433, fmeasure_max= 0.930390, precision= 0.914858, recall= 0.946459
# Train Random guess:  , auc= 0.222375fmeasure_max= 0.369845, precision= 0.227327, recall= 0.991364
# Validation Iter 8100, auc= 0.938091, fmeasure_max= 0.863174, precision= 0.793103, recall= 0.946827
# Validation Random guess:  auc= 0.226163, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.355906
# Tarin Iter 8200, auc= 0.974148, fmeasure_max= 0.903437, precision= 0.915423, recall= 0.891761
# Train Random guess:  , auc= 0.249016fmeasure_max= 0.391179, precision= 0.243825, recall= 0.988691
# Validation Iter 8200, auc= 0.937433, fmeasure_max= 0.871917, precision= 0.813056, recall= 0.939966
# Validation Random guess:  auc= 0.247192, fmeasure_max= 0.373034, precision= 0.229463, recall= 0.996569
# Minibatch Loss= 0.333203
# Tarin Iter 8300, auc= 0.978655, fmeasure_max= 0.919961, precision= 0.906844, recall= 0.933464
# Train Random guess:  , auc= 0.204446fmeasure_max= 0.333116, precision= 0.199844, recall= 1.000000
# Validation Iter 8300, auc= 0.939472, fmeasure_max= 0.875000, precision= 0.873504, recall= 0.876501
# Validation Random guess:  auc= 0.233475, fmeasure_max= 0.371127, precision= 0.228022, recall= 0.996569
# Minibatch Loss= 0.323769
# Tarin Iter 8400, auc= 0.981814, fmeasure_max= 0.926829, precision= 0.940952, recall= 0.913124
# Train Random guess:  , auc= 0.225063fmeasure_max= 0.349932, precision= 0.214555, recall= 0.948244
# Validation Iter 8400, auc= 0.937192, fmeasure_max= 0.875828, precision= 0.846400, recall= 0.907376
# Validation Random guess:  auc= 0.219153, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.313292
# Tarin Iter 8500, auc= 0.975585, fmeasure_max= 0.919854, precision= 0.906643, recall= 0.933457
# Train Random guess:  , auc= 0.222651fmeasure_max= 0.350389, precision= 0.212407, recall= 1.000000
# Validation Iter 8500, auc= 0.933283, fmeasure_max= 0.872340, precision= 0.834116, recall= 0.914237
# Validation Random guess:  auc= 0.232098, fmeasure_max= 0.371676, precision= 0.228526, recall= 0.994854
# Minibatch Loss= 0.337114
# Tarin Iter 8600, auc= 0.960236, fmeasure_max= 0.902364, precision= 0.869307, recall= 0.938034
# Train Random guess:  , auc= 0.176972fmeasure_max= 0.309966, precision= 0.184685, recall= 0.963675
# Validation Iter 8600, auc= 0.929407, fmeasure_max= 0.858362, precision= 0.853990, recall= 0.862779
# Validation Random guess:  auc= 0.230925, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.314117
# Tarin Iter 8700, auc= 0.972051, fmeasure_max= 0.915819, precision= 0.925234, recall= 0.906593
# Train Random guess:  , auc= 0.203571fmeasure_max= 0.352369, precision= 0.214117, recall= 0.994505
# Validation Iter 8700, auc= 0.929618, fmeasure_max= 0.865178, precision= 0.835463, recall= 0.897084
# Validation Random guess:  auc= 0.219849, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.361793
# Tarin Iter 8800, auc= 0.965170, fmeasure_max= 0.908055, precision= 0.881517, recall= 0.936242
# Train Random guess:  , auc= 0.235231fmeasure_max= 0.377994, precision= 0.234162, recall= 0.979866
# Validation Iter 8800, auc= 0.934587, fmeasure_max= 0.870293, precision= 0.849673, recall= 0.891938
# Validation Random guess:  auc= 0.224259, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.385009
# Tarin Iter 8900, auc= 0.979671, fmeasure_max= 0.911814, precision= 0.899836, recall= 0.924115
# Train Random guess:  , auc= 0.229229fmeasure_max= 0.377671, precision= 0.232887, recall= 0.998314
# Validation Iter 8900, auc= 0.934983, fmeasure_max= 0.871582, precision= 0.842949, recall= 0.902230
# Validation Random guess:  auc= 0.227968, fmeasure_max= 0.374021, precision= 0.230955, recall= 0.982847
# Minibatch Loss= 0.338732
# Tarin Iter 9000, auc= 0.970277, fmeasure_max= 0.905263, precision= 0.936479, recall= 0.876061
# Train Random guess:  , auc= 0.236828fmeasure_max= 0.381248, precision= 0.239187, recall= 0.938879
# Validation Iter 9000, auc= 0.928937, fmeasure_max= 0.853380, precision= 0.874101, recall= 0.833619
# Validation Random guess:  auc= 0.226739, fmeasure_max= 0.374493, precision= 0.238498, recall= 0.871355
# Minibatch Loss= 0.361845
# Tarin Iter 9100, auc= 0.961909, fmeasure_max= 0.888718, precision= 0.855244, recall= 0.924920
# Train Random guess:  , auc= 0.236695fmeasure_max= 0.393093, precision= 0.244627, recall= 1.000000
# Validation Iter 9100, auc= 0.933896, fmeasure_max= 0.867769, precision= 0.837321, recall= 0.900515
# Validation Random guess:  auc= 0.227375, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.453913
# Tarin Iter 9200, auc= 0.975597, fmeasure_max= 0.918623, precision= 0.956026, recall= 0.884036
# Train Random guess:  , auc= 0.255804fmeasure_max= 0.412935, precision= 0.260188, recall= 1.000000
# Validation Iter 9200, auc= 0.932471, fmeasure_max= 0.871417, precision= 0.833856, recall= 0.912521
# Validation Random guess:  auc= 0.248019, fmeasure_max= 0.372903, precision= 0.229638, recall= 0.991424
# Minibatch Loss= 0.396876
# Tarin Iter 9300, auc= 0.981052, fmeasure_max= 0.930499, precision= 0.931260, recall= 0.929739
# Train Random guess:  , auc= 0.248274fmeasure_max= 0.387671, precision= 0.240631, recall= 0.996732
# Validation Iter 9300, auc= 0.944734, fmeasure_max= 0.877398, precision= 0.853896, recall= 0.902230
# Validation Random guess:  auc= 0.231954, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.349718
# Tarin Iter 9400, auc= 0.983006, fmeasure_max= 0.932143, precision= 0.923894, recall= 0.940541
# Train Random guess:  , auc= 0.222624fmeasure_max= 0.356913, precision= 0.217221, recall= 1.000000
# Validation Iter 9400, auc= 0.941285, fmeasure_max= 0.875302, precision= 0.824242, recall= 0.933105
# Validation Random guess:  auc= 0.229603, fmeasure_max= 0.371227, precision= 0.228368, recall= 0.991424
# Minibatch Loss= 0.341214
# Tarin Iter 9500, auc= 0.987803, fmeasure_max= 0.941935, precision= 0.906028, recall= 0.980806
# Train Random guess:  , auc= 0.203658fmeasure_max= 0.338873, precision= 0.204082, recall= 0.998081
# Validation Iter 9500, auc= 0.937485, fmeasure_max= 0.874685, precision= 0.858086, recall= 0.891938
# Validation Random guess:  auc= 0.226930, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.265901
# Tarin Iter 9600, auc= 0.967134, fmeasure_max= 0.913151, precision= 0.888889, recall= 0.938776
# Train Random guess:  , auc= 0.218630fmeasure_max= 0.373808, precision= 0.229867, recall= 1.000000
# Validation Iter 9600, auc= 0.944035, fmeasure_max= 0.883645, precision= 0.840557, recall= 0.931389
# Validation Random guess:  auc= 0.226672, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.336414
# Tarin Iter 9700, auc= 0.966590, fmeasure_max= 0.906917, precision= 0.910806, recall= 0.903061
# Train Random guess:  , auc= 0.229615fmeasure_max= 0.374324, precision= 0.233558, recall= 0.942177
# Validation Iter 9700, auc= 0.928112, fmeasure_max= 0.865140, precision= 0.855705, recall= 0.874786
# Validation Random guess:  auc= 0.230124, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.339653
# Tarin Iter 9800, auc= 0.986709, fmeasure_max= 0.936170, precision= 0.936170, recall= 0.936170
# Train Random guess:  , auc= 0.277809fmeasure_max= 0.431985, precision= 0.275498, recall= 1.000000
# Validation Iter 9800, auc= 0.933799, fmeasure_max= 0.867408, precision= 0.865188, recall= 0.869640
# Validation Random guess:  auc= 0.231582, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.389195
# Tarin Iter 9900, auc= 0.976260, fmeasure_max= 0.914878, precision= 0.891775, recall= 0.939210
# Train Random guess:  , auc= 0.261280fmeasure_max= 0.410192, precision= 0.258628, recall= 0.990881
# Validation Iter 9900, auc= 0.942405, fmeasure_max= 0.883759, precision= 0.850794, recall= 0.919383
# Validation Random guess:  auc= 0.234918, fmeasure_max= 0.372984, precision= 0.231926, recall= 0.951973
# Minibatch Loss= 0.367514
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-cbf22a8a2ba9> in <module>()
#       1 #Save the model
#       2 saver = tf.train.Saver()
# ----> 3 saver.save(sess, checkpoint_path, global_step=trainer.global_step)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/training/saver.pyc in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1592               "Parent directory of {} doesn't exist, can't save.".format(
#    1593                   save_path))
# -> 1594         raise exc
#    1595
#    1596     if write_meta_graph:
#
# ValueError: Parent directory of ../model/DWN2006/DWN2006 doesn't exist, can't save.

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# Testing auc = 0.938336 F1_max = 0.858190 prec = 0.828253 rec = 0.890372
# Test Random guess: auc= 0.233631 fmeasure_max= 0.375635 , precision= 0.231277 , recall= 0.999493

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
