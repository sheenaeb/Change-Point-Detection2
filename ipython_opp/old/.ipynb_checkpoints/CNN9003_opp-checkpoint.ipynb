# %%
# useing this variable for saving models and summaries
exp_name = "CNN9003_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.CNN_model_finetune as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp3.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)
    
train_data = data['train_data']
test_data = data['test_data']
validation_data = data['validation_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

#index_of_changes = data['index_of_changes_test']

# %%
train_gt.shape, train_data.shape
# Out:
# ((1, 700165, 1), (1, 700165, 77))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 1

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
''' s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()
'''

s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[0,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)
pos_weight = pos_weight[0]

# %%
print pos_weight
# Out:
# 1.4926

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
#load the model
saver = tf.train.Saver(var_list = [
    model.weights['wc0'],model.weights['wc1'],model.weights['wc2'],
    model.bias['bc0'],model.bias['bc1'],model.bias['bc2']
])
saver.restore(sess, '../model/CNN9001_opp/CNN9001_opp-4000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/CNN9001_opp/CNN9001_opp-4000

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 1, 
                validation_eval_step = 1,
                display_step = 1)
# Out:
# Train Batch Evaluation
# AUC = 0.448 vs. 0.406
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.273 vs. 0.247
# F1 = 0.393 vs. 0.397
# Precision = 0.245 vs. 0.249
# Recall = 1.000 vs. 0.983
# Minibatch Loss= 29.105583
# Train Batch Evaluation
# AUC = 0.450 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.403 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.274 vs. 0.250
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 0.998 vs. 1.000
# Minibatch Loss= 28.605474
# Train Batch Evaluation
# AUC = 0.452 vs. 0.406
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.276 vs. 0.233
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.993
# Minibatch Loss= 28.105400
# Train Batch Evaluation
# AUC = 0.454 vs. 0.401
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.278 vs. 0.247
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 27.605375
# Train Batch Evaluation
# AUC = 0.457 vs. 0.399
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.281 vs. 0.236
# F1 = 0.393 vs. 0.396
# Precision = 0.245 vs. 0.247
# Recall = 1.000 vs. 0.998
# Minibatch Loss= 27.105398
# Train Batch Evaluation
# AUC = 0.459 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.403
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.283 vs. 0.236
# F1 = 0.394 vs. 0.393
# Precision = 0.246 vs. 0.245
# Recall = 0.998 vs. 1.000
# Minibatch Loss= 26.605486
# Train Batch Evaluation
# AUC = 0.461 vs. 0.411
# F1 = 0.574 vs. 0.574
# Precision = 0.403 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.286 vs. 0.240
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 0.998 vs. 0.993
# Minibatch Loss= 26.105652
# Train Batch Evaluation
# AUC = 0.463 vs. 0.400
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.288 vs. 0.262
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 25.605909
# Train Batch Evaluation
# AUC = 0.466 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.291 vs. 0.251
# F1 = 0.393 vs. 0.397
# Precision = 0.245 vs. 0.248
# Recall = 1.000 vs. 0.989
# Minibatch Loss= 25.106279
# Train Batch Evaluation
# AUC = 0.468 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.295 vs. 0.241
# F1 = 0.393 vs. 0.393
# Precision = 0.245 vs. 0.245
# Recall = 0.998 vs. 1.000
# Minibatch Loss= 24.606823
# Train Batch Evaluation
# AUC = 0.470 vs. 0.397
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.298 vs. 0.249
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 24.107620
# Train Batch Evaluation
# AUC = 0.473 vs. 0.408
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.300 vs. 0.262
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 23.608799
# Train Batch Evaluation
# AUC = 0.475 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.302 vs. 0.246
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 23.110464
# Train Batch Evaluation
# AUC = 0.478 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.403 vs. 0.402
# Recall = 0.999 vs. 0.998
# Validation
# AUC = 0.305 vs. 0.261
# F1 = 0.393 vs. 0.395
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.996
# Minibatch Loss= 22.612705
# Train Batch Evaluation
# AUC = 0.480 vs. 0.408
# F1 = 0.574 vs. 0.574
# Precision = 0.403 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.307 vs. 0.239
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 22.115612
# Train Batch Evaluation
# AUC = 0.482 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.310 vs. 0.247
# F1 = 0.393 vs. 0.393
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 21.619274
# Train Batch Evaluation
# AUC = 0.484 vs. 0.399
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.312 vs. 0.237
# F1 = 0.393 vs. 0.393
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 21.123783
# Train Batch Evaluation
# AUC = 0.487 vs. 0.410
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.315 vs. 0.274
# F1 = 0.394 vs. 0.400
# Precision = 0.245 vs. 0.252
# Recall = 1.000 vs. 0.976
# Minibatch Loss= 20.629232
# Train Batch Evaluation
# AUC = 0.489 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.403 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.318 vs. 0.249
# F1 = 0.393 vs. 0.395
# Precision = 0.245 vs. 0.251
# Recall = 1.000 vs. 0.922
# Minibatch Loss= 20.135731
# Train Batch Evaluation
# AUC = 0.491 vs. 0.398
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.321 vs. 0.242
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.989
# Minibatch Loss= 19.643360
# Train Batch Evaluation
# AUC = 0.493 vs. 0.400
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.324 vs. 0.244
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.991
# Minibatch Loss= 19.152231
# Train Batch Evaluation
# AUC = 0.496 vs. 0.408
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.326 vs. 0.247
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.983
# Minibatch Loss= 18.662529
# Train Batch Evaluation
# AUC = 0.498 vs. 0.405
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.327 vs. 0.268
# F1 = 0.393 vs. 0.399
# Precision = 0.245 vs. 0.251
# Recall = 1.000 vs. 0.980
# Minibatch Loss= 18.174532
# Train Batch Evaluation
# AUC = 0.500 vs. 0.389
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.403
# Recall = 1.000 vs. 0.995
# Validation
# AUC = 0.329 vs. 0.253
# F1 = 0.394 vs. 0.393
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 17.688532
# Train Batch Evaluation
# AUC = 0.502 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.331 vs. 0.258
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.996
# Minibatch Loss= 17.204803
# Train Batch Evaluation
# AUC = 0.504 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.403
# Recall = 0.999 vs. 0.999
# Validation
# AUC = 0.332 vs. 0.250
# F1 = 0.394 vs. 0.393
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.985
# Minibatch Loss= 16.723574
# Train Batch Evaluation
# AUC = 0.507 vs. 0.397
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.334 vs. 0.238
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 16.245007
# Train Batch Evaluation
# AUC = 0.509 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.403
# Recall = 1.000 vs. 0.998
# Validation
# AUC = 0.336 vs. 0.253
# F1 = 0.394 vs. 0.395
# Precision = 0.245 vs. 0.247
# Recall = 1.000 vs. 0.996
# Minibatch Loss= 15.769357
# Train Batch Evaluation
# AUC = 0.510 vs. 0.396
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.338 vs. 0.249
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 15.296993
# Train Batch Evaluation
# AUC = 0.512 vs. 0.399
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.340 vs. 0.255
# F1 = 0.394 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 14.828388
# Train Batch Evaluation
# AUC = 0.514 vs. 0.398
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.342 vs. 0.250
# F1 = 0.394 vs. 0.395
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.993
# Minibatch Loss= 14.364026
# Train Batch Evaluation
# AUC = 0.515 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.343 vs. 0.252
# F1 = 0.393 vs. 0.395
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.998
# Minibatch Loss= 13.904408
# Train Batch Evaluation
# AUC = 0.517 vs. 0.401
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.346 vs. 0.243
# F1 = 0.393 vs. 0.393
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 13.450048
# Train Batch Evaluation
# AUC = 0.519 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.346 vs. 0.236
# F1 = 0.393 vs. 0.393
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 13.001453
# Train Batch Evaluation
# AUC = 0.520 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.348 vs. 0.245
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 0.998
# Minibatch Loss= 12.559188
# Train Batch Evaluation
# AUC = 0.522 vs. 0.399
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 0.999 vs. 1.000
# Validation
# AUC = 0.348 vs. 0.249
# F1 = 0.393 vs. 0.395
# Precision = 0.245 vs. 0.247
# Recall = 1.000 vs. 0.993
# Minibatch Loss= 12.123953
# Train Batch Evaluation
# AUC = 0.523 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.350 vs. 0.248
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.991
# Minibatch Loss= 11.696566
# Train Batch Evaluation
# AUC = 0.524 vs. 0.399
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.352 vs. 0.255
# F1 = 0.393 vs. 0.395
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.996
# Minibatch Loss= 11.277966
# Train Batch Evaluation
# AUC = 0.527 vs. 0.401
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.354 vs. 0.248
# F1 = 0.393 vs. 0.395
# Precision = 0.245 vs. 0.251
# Recall = 1.000 vs. 0.935
# Minibatch Loss= 10.869197
# Train Batch Evaluation
# AUC = 0.528 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.357 vs. 0.252
# F1 = 0.393 vs. 0.393
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 10.471277
# Train Batch Evaluation
# AUC = 0.529 vs. 0.395
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.355 vs. 0.257
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.245
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 10.085075
# Train Batch Evaluation
# AUC = 0.531 vs. 0.412
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.354 vs. 0.251
# F1 = 0.393 vs. 0.395
# Precision = 0.245 vs. 0.247
# Recall = 1.000 vs. 0.998
# Minibatch Loss= 9.711432
# Train Batch Evaluation
# AUC = 0.531 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.362 vs. 0.259
# F1 = 0.393 vs. 0.394
# Precision = 0.245 vs. 0.246
# Recall = 1.000 vs. 0.993
# Minibatch Loss= 9.351276
# Train Batch Evaluation
# AUC = 0.532 vs. 0.408
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.356 vs. 0.256
# F1 = 0.394 vs. 0.394
# Precision = 0.311 vs. 0.245
# Recall = 0.538 vs. 0.993
# Minibatch Loss= 9.005494
# Train Batch Evaluation
# AUC = 0.533 vs. 0.408
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.361 vs. 0.247
# F1 = 0.395 vs. 0.395
# Precision = 0.312 vs. 0.247
# Recall = 0.538 vs. 0.996
# Minibatch Loss= 8.674788
# Train Batch Evaluation
# AUC = 0.534 vs. 0.394
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.356 vs. 0.250
# F1 = 0.395 vs. 0.394
# Precision = 0.311 vs. 0.246
# Recall = 0.540 vs. 1.000
# Minibatch Loss= 8.359672
# Train Batch Evaluation
# AUC = 0.535 vs. 0.392
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.353 vs. 0.255
# F1 = 0.396 vs. 0.404
# Precision = 0.315 vs. 0.255
# Recall = 0.534 vs. 0.965
# Minibatch Loss= 8.060521
# Train Batch Evaluation
# AUC = 0.534 vs. 0.408
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.352 vs. 0.244
# F1 = 0.397 vs. 0.394
# Precision = 0.318 vs. 0.245
# Recall = 0.529 vs. 1.000
# Minibatch Loss= 7.777615
# Train Batch Evaluation
# AUC = 0.534 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.359 vs. 0.256
# F1 = 0.398 vs. 0.395
# Precision = 0.328 vs. 0.246
# Recall = 0.505 vs. 0.993
# Minibatch Loss= 7.511220
# Train Batch Evaluation
# AUC = 0.538 vs. 0.405
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.353 vs. 0.259
# F1 = 0.399 vs. 0.394
# Precision = 0.325 vs. 0.245
# Recall = 0.516 vs. 0.998
# Minibatch Loss= 7.261582
# Train Batch Evaluation
# AUC = 0.537 vs. 0.409
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.359 vs. 0.258
# F1 = 0.402 vs. 0.395
# Precision = 0.329 vs. 0.246
# Recall = 0.516 vs. 1.000
# Minibatch Loss= 7.028806
# Train Batch Evaluation
# AUC = 0.538 vs. 0.399
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.353 vs. 0.248
# F1 = 0.402 vs. 0.393
# Precision = 0.332 vs. 0.245
# Recall = 0.508 vs. 1.000
# Minibatch Loss= 6.812778
# Train Batch Evaluation
# AUC = 0.538 vs. 0.407
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.403
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.351 vs. 0.254
# F1 = 0.404 vs. 0.394
# Precision = 0.335 vs. 0.245
# Recall = 0.510 vs. 1.000
# Minibatch Loss= 6.613224
# Train Batch Evaluation
# AUC = 0.535 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.356 vs. 0.253
# F1 = 0.404 vs. 0.394
# Precision = 0.334 vs. 0.246
# Recall = 0.510 vs. 0.991
# Minibatch Loss= 6.429702
# Train Batch Evaluation
# AUC = 0.538 vs. 0.396
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.358 vs. 0.256
# F1 = 0.405 vs. 0.394
# Precision = 0.338 vs. 0.247
# Recall = 0.505 vs. 0.976
# Minibatch Loss= 6.261656
# Train Batch Evaluation
# AUC = 0.539 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.354 vs. 0.246
# F1 = 0.407 vs. 0.395
# Precision = 0.339 vs. 0.247
# Recall = 0.508 vs. 0.980
# Minibatch Loss= 6.108548
# Train Batch Evaluation
# AUC = 0.538 vs. 0.393
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.364 vs. 0.252
# F1 = 0.408 vs. 0.393
# Precision = 0.339 vs. 0.245
# Recall = 0.512 vs. 1.000
# Minibatch Loss= 5.969894
# Train Batch Evaluation
# AUC = 0.538 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.350 vs. 0.247
# F1 = 0.409 vs. 0.397
# Precision = 0.338 vs. 0.254
# Recall = 0.516 vs. 0.913
# Minibatch Loss= 5.845169
# Train Batch Evaluation
# AUC = 0.536 vs. 0.407
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.352 vs. 0.249
# F1 = 0.409 vs. 0.394
# Precision = 0.340 vs. 0.245
# Recall = 0.514 vs. 1.000
# Minibatch Loss= 5.733686
# Train Batch Evaluation
# AUC = 0.540 vs. 0.400
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.364 vs. 0.250
# F1 = 0.411 vs. 0.395
# Precision = 0.338 vs. 0.246
# Recall = 0.523 vs. 0.998
# Minibatch Loss= 5.634600
# Train Batch Evaluation
# AUC = 0.536 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.357 vs. 0.237
# F1 = 0.412 vs. 0.394
# Precision = 0.339 vs. 0.246
# Recall = 0.523 vs. 0.991
# Minibatch Loss= 5.546982
# Train Batch Evaluation
# AUC = 0.534 vs. 0.399
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.351 vs. 0.233
# F1 = 0.413 vs. 0.396
# Precision = 0.334 vs. 0.248
# Recall = 0.540 vs. 0.980
# Minibatch Loss= 5.469896
# Train Batch Evaluation
# AUC = 0.539 vs. 0.398
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.350 vs. 0.242
# F1 = 0.414 vs. 0.394
# Precision = 0.336 vs. 0.246
# Recall = 0.540 vs. 1.000
# Minibatch Loss= 5.402420
# Train Batch Evaluation
# AUC = 0.538 vs. 0.401
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.345 vs. 0.252
# F1 = 0.415 vs. 0.394
# Precision = 0.336 vs. 0.245
# Recall = 0.542 vs. 1.000
# Minibatch Loss= 5.343657
# Train Batch Evaluation
# AUC = 0.531 vs. 0.406
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.356 vs. 0.251
# F1 = 0.416 vs. 0.394
# Precision = 0.339 vs. 0.245
# Recall = 0.538 vs. 1.000
# Minibatch Loss= 5.292742
# Train Batch Evaluation
# AUC = 0.526 vs. 0.408
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.357 vs. 0.238
# F1 = 0.418 vs. 0.394
# Precision = 0.338 vs. 0.245
# Recall = 0.549 vs. 1.000
# Minibatch Loss= 5.248860
# Train Batch Evaluation
# AUC = 0.529 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.403
# Recall = 1.000 vs. 0.994
# Validation
# AUC = 0.362 vs. 0.248
# F1 = 0.420 vs. 0.394
# Precision = 0.342 vs. 0.245
# Recall = 0.544 vs. 1.000
# Minibatch Loss= 5.211239
# Train Batch Evaluation
# AUC = 0.543 vs. 0.404
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.345 vs. 0.239
# F1 = 0.421 vs. 0.394
# Precision = 0.342 vs. 0.246
# Recall = 0.547 vs. 0.998
# Minibatch Loss= 5.179144
# Train Batch Evaluation
# AUC = 0.532 vs. 0.407
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.351 vs. 0.281
# F1 = 0.421 vs. 0.394
# Precision = 0.342 vs. 0.246
# Recall = 0.547 vs. 0.996
# Minibatch Loss= 5.151868
# Train Batch Evaluation
# AUC = 0.527 vs. 0.403
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.347 vs. 0.250
# F1 = 0.422 vs. 0.394
# Precision = 0.344 vs. 0.245
# Recall = 0.544 vs. 1.000
# Minibatch Loss= 5.128748
# Train Batch Evaluation
# AUC = 0.528 vs. 0.407
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 0.999
# Validation
# AUC = 0.344 vs. 0.237
# F1 = 0.422 vs. 0.396
# Precision = 0.346 vs. 0.247
# Recall = 0.540 vs. 0.996
# Minibatch Loss= 5.109158
# Train Batch Evaluation
# AUC = 0.526 vs. 0.406
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.359 vs. 0.235
# F1 = 0.423 vs. 0.394
# Precision = 0.347 vs. 0.245
# Recall = 0.542 vs. 1.000
# Minibatch Loss= 5.092523
# Train Batch Evaluation
# AUC = 0.532 vs. 0.401
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.355 vs. 0.245
# F1 = 0.423 vs. 0.395
# Precision = 0.347 vs. 0.246
# Recall = 0.542 vs. 1.000
# Minibatch Loss= 5.078317
# Train Batch Evaluation
# AUC = 0.543 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.354 vs. 0.242
# F1 = 0.423 vs. 0.394
# Precision = 0.345 vs. 0.246
# Recall = 0.547 vs. 0.991
# Minibatch Loss= 5.066067
# Train Batch Evaluation
# AUC = 0.536 vs. 0.401
# F1 = 0.574 vs. 0.574
# Precision = 0.402 vs. 0.402
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.368 vs. 0.248
# F1 = 0.425 vs. 0.393
# Precision = 0.363 vs. 0.245
# Recall = 0.512 vs. 1.000
# Minibatch Loss= 5.055349
# Train Batch Evaluation
# AUC = 0.543 vs. 0.402
# F1 = 0.574 vs. 0.574
# Precision = 0.501 vs. 0.402
# Recall = 0.672 vs. 1.000
# Validation
# AUC = 0.366 vs. 0.245
# F1 = 0.425 vs. 0.394
# Precision = 0.364 vs. 0.246
# Recall = 0.512 vs. 0.998
# Minibatch Loss= 5.045793
# Train Batch Evaluation
# AUC = 0.527 vs. 0.405
# F1 = 0.575 vs. 0.574
# Precision = 0.505 vs. 0.403
# Recall = 0.667 vs. 0.999
# Validation
# AUC = 0.352 vs. 0.255
# F1 = 0.426 vs. 0.398
# Precision = 0.352 vs. 0.249
# Recall = 0.540 vs. 0.993
# Minibatch Loss= 5.037075
# Train Batch Evaluation
# AUC = 0.533 vs. 0.406
# F1 = 0.575 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.673 vs. 1.000
# Validation
# AUC = 0.355 vs. 0.265
# F1 = 0.428 vs. 0.395
# Precision = 0.361 vs. 0.248
# Recall = 0.527 vs. 0.974
# Minibatch Loss= 5.028918
# Train Batch Evaluation
# AUC = 0.532 vs. 0.402
# F1 = 0.575 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.675 vs. 1.000
# Validation
# AUC = 0.361 vs. 0.265
# F1 = 0.429 vs. 0.394
# Precision = 0.362 vs. 0.245
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 5.021091
# Train Batch Evaluation
# AUC = 0.546 vs. 0.400
# F1 = 0.576 vs. 0.574
# Precision = 0.500 vs. 0.402
# Recall = 0.679 vs. 1.000
# Validation
# AUC = 0.362 vs. 0.255
# F1 = 0.430 vs. 0.395
# Precision = 0.363 vs. 0.248
# Recall = 0.527 vs. 0.970
# Minibatch Loss= 5.013401
# Train Batch Evaluation
# AUC = 0.545 vs. 0.401
# F1 = 0.577 vs. 0.574
# Precision = 0.501 vs. 0.402
# Recall = 0.679 vs. 1.000
# Validation
# AUC = 0.362 vs. 0.258
# F1 = 0.430 vs. 0.394
# Precision = 0.363 vs. 0.245
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 5.005694
# Train Batch Evaluation
# AUC = 0.533 vs. 0.408
# F1 = 0.577 vs. 0.574
# Precision = 0.501 vs. 0.402
# Recall = 0.681 vs. 0.999
# Validation
# AUC = 0.358 vs. 0.255
# F1 = 0.431 vs. 0.395
# Precision = 0.362 vs. 0.248
# Recall = 0.531 vs. 0.976
# Minibatch Loss= 4.997851
# Train Batch Evaluation
# AUC = 0.535 vs. 0.393
# F1 = 0.578 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.682 vs. 0.999
# Validation
# AUC = 0.360 vs. 0.254
# F1 = 0.431 vs. 0.394
# Precision = 0.361 vs. 0.245
# Recall = 0.536 vs. 1.000
# Minibatch Loss= 4.989779
# Train Batch Evaluation
# AUC = 0.533 vs. 0.401
# F1 = 0.578 vs. 0.574
# Precision = 0.501 vs. 0.402
# Recall = 0.684 vs. 0.998
# Validation
# AUC = 0.361 vs. 0.245
# F1 = 0.432 vs. 0.394
# Precision = 0.362 vs. 0.245
# Recall = 0.536 vs. 1.000
# Minibatch Loss= 4.981417
# Train Batch Evaluation
# AUC = 0.541 vs. 0.405
# F1 = 0.579 vs. 0.574
# Precision = 0.502 vs. 0.403
# Recall = 0.684 vs. 0.998
# Validation
# AUC = 0.364 vs. 0.243
# F1 = 0.432 vs. 0.398
# Precision = 0.362 vs. 0.254
# Recall = 0.536 vs. 0.918
# Minibatch Loss= 4.972722
# Train Batch Evaluation
# AUC = 0.526 vs. 0.404
# F1 = 0.579 vs. 0.574
# Precision = 0.503 vs. 0.402
# Recall = 0.683 vs. 1.000
# Validation
# AUC = 0.360 vs. 0.250
# F1 = 0.432 vs. 0.394
# Precision = 0.359 vs. 0.245
# Recall = 0.542 vs. 1.000
# Minibatch Loss= 4.963671
# Train Batch Evaluation
# AUC = 0.532 vs. 0.404
# F1 = 0.580 vs. 0.574
# Precision = 0.503 vs. 0.402
# Recall = 0.684 vs. 1.000
# Validation
# AUC = 0.364 vs. 0.257
# F1 = 0.432 vs. 0.394
# Precision = 0.359 vs. 0.247
# Recall = 0.542 vs. 0.978
# Minibatch Loss= 4.954262
# Train Batch Evaluation
# AUC = 0.539 vs. 0.405
# F1 = 0.580 vs. 0.574
# Precision = 0.503 vs. 0.402
# Recall = 0.684 vs. 1.000
# Validation
# AUC = 0.364 vs. 0.265
# F1 = 0.432 vs. 0.394
# Precision = 0.364 vs. 0.246
# Recall = 0.531 vs. 0.996
# Minibatch Loss= 4.944500
# Train Batch Evaluation
# AUC = 0.536 vs. 0.398
# F1 = 0.580 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.687 vs. 1.000
# Validation
# AUC = 0.365 vs. 0.245
# F1 = 0.433 vs. 0.394
# Precision = 0.363 vs. 0.246
# Recall = 0.536 vs. 0.998
# Minibatch Loss= 4.934406
# Train Batch Evaluation
# AUC = 0.532 vs. 0.399
# F1 = 0.581 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.688 vs. 1.000
# Validation
# AUC = 0.365 vs. 0.247
# F1 = 0.433 vs. 0.393
# Precision = 0.363 vs. 0.245
# Recall = 0.536 vs. 1.000
# Minibatch Loss= 4.924006
# Train Batch Evaluation
# AUC = 0.533 vs. 0.398
# F1 = 0.581 vs. 0.574
# Precision = 0.503 vs. 0.402
# Recall = 0.688 vs. 1.000
# Validation
# AUC = 0.372 vs. 0.234
# F1 = 0.432 vs. 0.393
# Precision = 0.363 vs. 0.245
# Recall = 0.534 vs. 1.000
# Minibatch Loss= 4.913333
# Train Batch Evaluation
# AUC = 0.536 vs. 0.400
# F1 = 0.581 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.691 vs. 1.000
# Validation
# AUC = 0.359 vs. 0.256
# F1 = 0.432 vs. 0.394
# Precision = 0.363 vs. 0.245
# Recall = 0.534 vs. 1.000
# Minibatch Loss= 4.902422
# Train Batch Evaluation
# AUC = 0.533 vs. 0.402
# F1 = 0.582 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.692 vs. 1.000
# Validation
# AUC = 0.366 vs. 0.254
# F1 = 0.432 vs. 0.395
# Precision = 0.365 vs. 0.249
# Recall = 0.527 vs. 0.952
# Minibatch Loss= 4.891312
# Train Batch Evaluation
# AUC = 0.533 vs. 0.403
# F1 = 0.582 vs. 0.574
# Precision = 0.502 vs. 0.402
# Recall = 0.691 vs. 1.000
# Validation
# AUC = 0.358 vs. 0.258
# F1 = 0.432 vs. 0.394
# Precision = 0.365 vs. 0.245
# Recall = 0.529 vs. 1.000
# Minibatch Loss= 4.880042
# Train Batch Evaluation
# AUC = 0.545 vs. 0.400
# F1 = 0.582 vs. 0.574
# Precision = 0.501 vs. 0.402
# Recall = 0.694 vs. 1.000
# Validation
# AUC = 0.356 vs. 0.237
# F1 = 0.432 vs. 0.393
# Precision = 0.367 vs. 0.245
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 4.868649
# Train Batch Evaluation
# AUC = 0.530 vs. 0.397
# F1 = 0.582 vs. 0.574
# Precision = 0.509 vs. 0.402
# Recall = 0.681 vs. 1.000
# Validation
# AUC = 0.353 vs. 0.251
# F1 = 0.432 vs. 0.394
# Precision = 0.366 vs. 0.245
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 4.857171
# Train Batch Evaluation
# AUC = 0.553 vs. 0.402
# F1 = 0.583 vs. 0.574
# Precision = 0.493 vs. 0.402
# Recall = 0.712 vs. 1.000
# Validation
# AUC = 0.365 vs. 0.243
# F1 = 0.432 vs. 0.394
# Precision = 0.353 vs. 0.246
# Recall = 0.555 vs. 0.987
# Minibatch Loss= 4.845641
# Train Batch Evaluation
# AUC = 0.553 vs. 0.400
# F1 = 0.584 vs. 0.574
# Precision = 0.494 vs. 0.402
# Recall = 0.714 vs. 1.000
# Validation
# AUC = 0.355 vs. 0.231
# F1 = 0.432 vs. 0.393
# Precision = 0.354 vs. 0.245
# Recall = 0.553 vs. 0.998
# Minibatch Loss= 4.834090
# Train Batch Evaluation
# AUC = 0.532 vs. 0.398
# F1 = 0.583 vs. 0.574
# Precision = 0.493 vs. 0.402
# Recall = 0.714 vs. 1.000
# Validation
# AUC = 0.368 vs. 0.246
# F1 = 0.431 vs. 0.396
# Precision = 0.354 vs. 0.247
# Recall = 0.553 vs. 0.996
# Minibatch Loss= 4.822546
# Train Batch Evaluation
# AUC = 0.546 vs. 0.406
# F1 = 0.583 vs. 0.574
# Precision = 0.490 vs. 0.402
# Recall = 0.720 vs. 0.999
# Validation
# AUC = 0.369 vs. 0.259
# F1 = 0.431 vs. 0.394
# Precision = 0.354 vs. 0.246
# Recall = 0.551 vs. 0.991
# Minibatch Loss= 4.811031
# Train Batch Evaluation
# AUC = 0.549 vs. 0.401
# F1 = 0.584 vs. 0.574
# Precision = 0.491 vs. 0.402
# Recall = 0.720 vs. 0.999
# Validation
# AUC = 0.352 vs. 0.244
# F1 = 0.431 vs. 0.393
# Precision = 0.364 vs. 0.245
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 4.799569
# Train Batch Evaluation
# AUC = 0.549 vs. 0.407
# F1 = 0.584 vs. 0.574
# Precision = 0.492 vs. 0.402
# Recall = 0.719 vs. 1.000
# Validation
# AUC = 0.369 vs. 0.263
# F1 = 0.431 vs. 0.395
# Precision = 0.364 vs. 0.249
# Recall = 0.527 vs. 0.961
# Minibatch Loss= 4.788174
# Train Batch Evaluation
# AUC = 0.546 vs. 0.402
# F1 = 0.585 vs. 0.574
# Precision = 0.493 vs. 0.402
# Recall = 0.718 vs. 1.000
# Validation
# AUC = 0.368 vs. 0.238
# F1 = 0.432 vs. 0.394
# Precision = 0.349 vs. 0.245
# Recall = 0.564 vs. 1.000
# Minibatch Loss= 4.776858
# Train Batch Evaluation
# AUC = 0.539 vs. 0.408
# F1 = 0.585 vs. 0.574
# Precision = 0.492 vs. 0.403
# Recall = 0.721 vs. 0.998
# Validation
# AUC = 0.371 vs. 0.267
# F1 = 0.432 vs. 0.396
# Precision = 0.350 vs. 0.251
# Recall = 0.564 vs. 0.946
# Minibatch Loss= 4.765633
# Train Batch Evaluation
# AUC = 0.550 vs. 0.410
# F1 = 0.585 vs. 0.574
# Precision = 0.492 vs. 0.403
# Recall = 0.722 vs. 0.998
# Validation
# AUC = 0.368 vs. 0.273
# F1 = 0.432 vs. 0.394
# Precision = 0.349 vs. 0.245
# Recall = 0.564 vs. 1.000
# Minibatch Loss= 4.754504
# Train Batch Evaluation
# AUC = 0.539 vs. 0.407
# F1 = 0.585 vs. 0.574
# Precision = 0.493 vs. 0.402
# Recall = 0.721 vs. 1.000
# Validation
# AUC = 0.364 vs. 0.230
# F1 = 0.431 vs. 0.394
# Precision = 0.350 vs. 0.245
# Recall = 0.562 vs. 1.000
# Minibatch Loss= 4.743476
# Train Batch Evaluation
# AUC = 0.544 vs. 0.402
# F1 = 0.585 vs. 0.574
# Precision = 0.494 vs. 0.403
# Recall = 0.719 vs. 0.999
# Validation
# AUC = 0.370 vs. 0.250
# F1 = 0.432 vs. 0.393
# Precision = 0.350 vs. 0.248
# Recall = 0.562 vs. 0.952
# Minibatch Loss= 4.732550
# Train Batch Evaluation
# AUC = 0.542 vs. 0.401
# F1 = 0.586 vs. 0.574
# Precision = 0.494 vs. 0.402
# Recall = 0.720 vs. 1.000
# Validation
# AUC = 0.388 vs. 0.266
# F1 = 0.433 vs. 0.397
# Precision = 0.349 vs. 0.249
# Recall = 0.570 vs. 0.976
# Minibatch Loss= 4.721723
# Train Batch Evaluation
# AUC = 0.541 vs. 0.401
# F1 = 0.586 vs. 0.574
# Precision = 0.507 vs. 0.402
# Recall = 0.693 vs. 0.999
# Validation
# AUC = 0.388 vs. 0.249
# F1 = 0.434 vs. 0.393
# Precision = 0.350 vs. 0.245
# Recall = 0.570 vs. 1.000
# Minibatch Loss= 4.710995
# Train Batch Evaluation
# AUC = 0.548 vs. 0.403
# F1 = 0.586 vs. 0.574
# Precision = 0.527 vs. 0.402
# Recall = 0.661 vs. 1.000
# Validation
# AUC = 0.363 vs. 0.250
# F1 = 0.433 vs. 0.393
# Precision = 0.349 vs. 0.245
# Recall = 0.570 vs. 1.000
# Minibatch Loss= 4.700359
# Train Batch Evaluation
# AUC = 0.542 vs. 0.399
# F1 = 0.587 vs. 0.574
# Precision = 0.510 vs. 0.402
# Recall = 0.691 vs. 1.000
# Validation
# AUC = 0.364 vs. 0.252
# F1 = 0.433 vs. 0.395
# Precision = 0.349 vs. 0.247
# Recall = 0.570 vs. 0.980
# Minibatch Loss= 4.689813
# Train Batch Evaluation
# AUC = 0.549 vs. 0.398
# F1 = 0.587 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.662 vs. 0.999
# Validation
# AUC = 0.367 vs. 0.245
# F1 = 0.433 vs. 0.396
# Precision = 0.388 vs. 0.247
# Recall = 0.490 vs. 0.993
# Minibatch Loss= 4.679348
# Train Batch Evaluation
# AUC = 0.555 vs. 0.400
# F1 = 0.588 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.659 vs. 0.999
# Validation
# AUC = 0.381 vs. 0.241
# F1 = 0.433 vs. 0.398
# Precision = 0.388 vs. 0.259
# Recall = 0.490 vs. 0.859
# Minibatch Loss= 4.668959
# Train Batch Evaluation
# AUC = 0.543 vs. 0.401
# F1 = 0.588 vs. 0.574
# Precision = 0.529 vs. 0.402
# Recall = 0.662 vs. 1.000
# Validation
# AUC = 0.371 vs. 0.255
# F1 = 0.433 vs. 0.394
# Precision = 0.394 vs. 0.245
# Recall = 0.482 vs. 1.000
# Minibatch Loss= 4.658638
# Train Batch Evaluation
# AUC = 0.554 vs. 0.397
# F1 = 0.588 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.664 vs. 0.998
# Validation
# AUC = 0.377 vs. 0.240
# F1 = 0.434 vs. 0.394
# Precision = 0.337 vs. 0.245
# Recall = 0.607 vs. 0.998
# Minibatch Loss= 4.648378
# Train Batch Evaluation
# AUC = 0.549 vs. 0.404
# F1 = 0.589 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.664 vs. 1.000
# Validation
# AUC = 0.366 vs. 0.256
# F1 = 0.435 vs. 0.394
# Precision = 0.396 vs. 0.246
# Recall = 0.482 vs. 0.987
# Minibatch Loss= 4.638173
# Train Batch Evaluation
# AUC = 0.544 vs. 0.398
# F1 = 0.589 vs. 0.574
# Precision = 0.529 vs. 0.402
# Recall = 0.665 vs. 1.000
# Validation
# AUC = 0.392 vs. 0.254
# F1 = 0.436 vs. 0.394
# Precision = 0.337 vs. 0.246
# Recall = 0.618 vs. 0.983
# Minibatch Loss= 4.628014
# Train Batch Evaluation
# AUC = 0.546 vs. 0.398
# F1 = 0.590 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.665 vs. 1.000
# Validation
# AUC = 0.393 vs. 0.246
# F1 = 0.437 vs. 0.394
# Precision = 0.338 vs. 0.245
# Recall = 0.618 vs. 1.000
# Minibatch Loss= 4.617898
# Train Batch Evaluation
# AUC = 0.550 vs. 0.396
# F1 = 0.590 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.664 vs. 1.000
# Validation
# AUC = 0.382 vs. 0.254
# F1 = 0.438 vs. 0.394
# Precision = 0.400 vs. 0.246
# Recall = 0.484 vs. 0.978
# Minibatch Loss= 4.607815
# Train Batch Evaluation
# AUC = 0.553 vs. 0.406
# F1 = 0.590 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.664 vs. 1.000
# Validation
# AUC = 0.392 vs. 0.249
# F1 = 0.438 vs. 0.395
# Precision = 0.400 vs. 0.247
# Recall = 0.484 vs. 0.991
# Minibatch Loss= 4.597762
# Train Batch Evaluation
# AUC = 0.559 vs. 0.411
# F1 = 0.590 vs. 0.574
# Precision = 0.520 vs. 0.402
# Recall = 0.682 vs. 0.999
# Validation
# AUC = 0.393 vs. 0.261
# F1 = 0.439 vs. 0.397
# Precision = 0.401 vs. 0.255
# Recall = 0.484 vs. 0.892
# Minibatch Loss= 4.587736
# Train Batch Evaluation
# AUC = 0.547 vs. 0.406
# F1 = 0.590 vs. 0.574
# Precision = 0.520 vs. 0.402
# Recall = 0.682 vs. 1.000
# Validation
# AUC = 0.393 vs. 0.245
# F1 = 0.439 vs. 0.393
# Precision = 0.401 vs. 0.245
# Recall = 0.486 vs. 1.000
# Minibatch Loss= 4.577728
# Train Batch Evaluation
# AUC = 0.559 vs. 0.406
# F1 = 0.591 vs. 0.574
# Precision = 0.520 vs. 0.402
# Recall = 0.686 vs. 1.000
# Validation
# AUC = 0.394 vs. 0.244
# F1 = 0.439 vs. 0.395
# Precision = 0.401 vs. 0.247
# Recall = 0.486 vs. 0.985
# Minibatch Loss= 4.567738
# Train Batch Evaluation
# AUC = 0.560 vs. 0.398
# F1 = 0.592 vs. 0.574
# Precision = 0.521 vs. 0.403
# Recall = 0.684 vs. 0.998
# Validation
# AUC = 0.392 vs. 0.242
# F1 = 0.440 vs. 0.393
# Precision = 0.400 vs. 0.245
# Recall = 0.488 vs. 1.000
# Minibatch Loss= 4.557762
# Train Batch Evaluation
# AUC = 0.550 vs. 0.405
# F1 = 0.592 vs. 0.574
# Precision = 0.522 vs. 0.402
# Recall = 0.684 vs. 1.000
# Validation
# AUC = 0.392 vs. 0.253
# F1 = 0.440 vs. 0.394
# Precision = 0.401 vs. 0.245
# Recall = 0.488 vs. 0.996
# Minibatch Loss= 4.547797
# Train Batch Evaluation
# AUC = 0.555 vs. 0.406
# F1 = 0.593 vs. 0.574
# Precision = 0.523 vs. 0.402
# Recall = 0.684 vs. 1.000
# Validation
# AUC = 0.380 vs. 0.254
# F1 = 0.441 vs. 0.393
# Precision = 0.348 vs. 0.245
# Recall = 0.603 vs. 1.000
# Minibatch Loss= 4.537842
# Train Batch Evaluation
# AUC = 0.564 vs. 0.402
# F1 = 0.593 vs. 0.574
# Precision = 0.524 vs. 0.402
# Recall = 0.683 vs. 1.000
# Validation
# AUC = 0.388 vs. 0.239
# F1 = 0.443 vs. 0.395
# Precision = 0.349 vs. 0.246
# Recall = 0.605 vs. 0.998
# Minibatch Loss= 4.527895
# Train Batch Evaluation
# AUC = 0.549 vs. 0.404
# F1 = 0.594 vs. 0.574
# Precision = 0.524 vs. 0.402
# Recall = 0.684 vs. 1.000
# Validation
# AUC = 0.376 vs. 0.238
# F1 = 0.444 vs. 0.394
# Precision = 0.350 vs. 0.246
# Recall = 0.605 vs. 0.998
# Minibatch Loss= 4.517955
# Train Batch Evaluation
# AUC = 0.554 vs. 0.399
# F1 = 0.594 vs. 0.574
# Precision = 0.524 vs. 0.403
# Recall = 0.684 vs. 0.997
# Validation
# AUC = 0.392 vs. 0.256
# F1 = 0.444 vs. 0.397
# Precision = 0.351 vs. 0.248
# Recall = 0.605 vs. 0.985
# Minibatch Loss= 4.508022
# Train Batch Evaluation
# AUC = 0.562 vs. 0.396
# F1 = 0.594 vs. 0.574
# Precision = 0.526 vs. 0.402
# Recall = 0.684 vs. 1.000
# Validation
# AUC = 0.381 vs. 0.251
# F1 = 0.446 vs. 0.395
# Precision = 0.351 vs. 0.246
# Recall = 0.610 vs. 0.998
# Minibatch Loss= 4.498095
# Train Batch Evaluation
# AUC = 0.566 vs. 0.401
# F1 = 0.595 vs. 0.574
# Precision = 0.524 vs. 0.402
# Recall = 0.688 vs. 1.000
# Validation
# AUC = 0.381 vs. 0.236
# F1 = 0.447 vs. 0.393
# Precision = 0.353 vs. 0.245
# Recall = 0.610 vs. 1.000
# Minibatch Loss= 4.488174
# Train Batch Evaluation
# AUC = 0.565 vs. 0.395
# F1 = 0.595 vs. 0.574
# Precision = 0.524 vs. 0.402
# Recall = 0.688 vs. 1.000
# Validation
# AUC = 0.379 vs. 0.258
# F1 = 0.446 vs. 0.394
# Precision = 0.352 vs. 0.245
# Recall = 0.610 vs. 1.000
# Minibatch Loss= 4.478259
# Train Batch Evaluation
# AUC = 0.553 vs. 0.408
# F1 = 0.596 vs. 0.574
# Precision = 0.523 vs. 0.402
# Recall = 0.692 vs. 1.000
# Validation
# AUC = 0.392 vs. 0.256
# F1 = 0.446 vs. 0.395
# Precision = 0.354 vs. 0.248
# Recall = 0.605 vs. 0.983
# Minibatch Loss= 4.468351
# Train Batch Evaluation
# AUC = 0.555 vs. 0.400
# F1 = 0.596 vs. 0.574
# Precision = 0.525 vs. 0.402
# Recall = 0.690 vs. 1.000
# Validation
# AUC = 0.397 vs. 0.250
# F1 = 0.447 vs. 0.394
# Precision = 0.353 vs. 0.245
# Recall = 0.607 vs. 1.000
# Minibatch Loss= 4.458452
# Train Batch Evaluation
# AUC = 0.568 vs. 0.398
# F1 = 0.597 vs. 0.574
# Precision = 0.524 vs. 0.402
# Recall = 0.693 vs. 1.000
# Validation
# AUC = 0.397 vs. 0.244
# F1 = 0.447 vs. 0.397
# Precision = 0.354 vs. 0.248
# Recall = 0.607 vs. 1.000
# Minibatch Loss= 4.448559
# Train Batch Evaluation
# AUC = 0.565 vs. 0.408
# F1 = 0.597 vs. 0.574
# Precision = 0.525 vs. 0.402
# Recall = 0.693 vs. 1.000
# Validation
# AUC = 0.398 vs. 0.262
# F1 = 0.448 vs. 0.394
# Precision = 0.354 vs. 0.245
# Recall = 0.607 vs. 1.000
# Minibatch Loss= 4.438676
# Train Batch Evaluation
# AUC = 0.550 vs. 0.398
# F1 = 0.598 vs. 0.574
# Precision = 0.526 vs. 0.402
# Recall = 0.693 vs. 1.000
# Validation
# AUC = 0.397 vs. 0.236
# F1 = 0.448 vs. 0.394
# Precision = 0.354 vs. 0.245
# Recall = 0.610 vs. 1.000
# Minibatch Loss= 4.428803
# Train Batch Evaluation
# AUC = 0.562 vs. 0.406
# F1 = 0.598 vs. 0.574
# Precision = 0.527 vs. 0.402
# Recall = 0.691 vs. 1.000
# Validation
# AUC = 0.394 vs. 0.229
# F1 = 0.449 vs. 0.393
# Precision = 0.355 vs. 0.246
# Recall = 0.610 vs. 0.987
# Minibatch Loss= 4.418940
# Train Batch Evaluation
# AUC = 0.558 vs. 0.402
# F1 = 0.599 vs. 0.574
# Precision = 0.525 vs. 0.402
# Recall = 0.696 vs. 1.000
# Validation
# AUC = 0.397 vs. 0.254
# F1 = 0.449 vs. 0.394
# Precision = 0.355 vs. 0.246
# Recall = 0.610 vs. 0.996
# Minibatch Loss= 4.409089
# Train Batch Evaluation
# AUC = 0.564 vs. 0.403
# F1 = 0.599 vs. 0.574
# Precision = 0.525 vs. 0.402
# Recall = 0.697 vs. 1.000
# Validation
# AUC = 0.398 vs. 0.265
# F1 = 0.449 vs. 0.398
# Precision = 0.355 vs. 0.251
# Recall = 0.610 vs. 0.967
# Minibatch Loss= 4.399249
# Train Batch Evaluation
# AUC = 0.557 vs. 0.400
# F1 = 0.600 vs. 0.574
# Precision = 0.527 vs. 0.402
# Recall = 0.696 vs. 1.000
# Validation
# AUC = 0.384 vs. 0.255
# F1 = 0.450 vs. 0.394
# Precision = 0.356 vs. 0.247
# Recall = 0.610 vs. 0.983
# Minibatch Loss= 4.389421
# Train Batch Evaluation
# AUC = 0.570 vs. 0.400
# F1 = 0.600 vs. 0.574
# Precision = 0.527 vs. 0.402
# Recall = 0.696 vs. 1.000
# Validation
# AUC = 0.383 vs. 0.250
# F1 = 0.450 vs. 0.395
# Precision = 0.356 vs. 0.246
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.379607
# Train Batch Evaluation
# AUC = 0.570 vs. 0.401
# F1 = 0.600 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.695 vs. 1.000
# Validation
# AUC = 0.407 vs. 0.262
# F1 = 0.450 vs. 0.393
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.369807
# Train Batch Evaluation
# AUC = 0.571 vs. 0.400
# F1 = 0.601 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.694 vs. 1.000
# Validation
# AUC = 0.390 vs. 0.256
# F1 = 0.450 vs. 0.397
# Precision = 0.357 vs. 0.249
# Recall = 0.612 vs. 0.976
# Minibatch Loss= 4.360022
# Train Batch Evaluation
# AUC = 0.570 vs. 0.403
# F1 = 0.601 vs. 0.574
# Precision = 0.531 vs. 0.402
# Recall = 0.694 vs. 1.000
# Validation
# AUC = 0.382 vs. 0.230
# F1 = 0.450 vs. 0.393
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.350250
# Train Batch Evaluation
# AUC = 0.567 vs. 0.403
# F1 = 0.602 vs. 0.574
# Precision = 0.531 vs. 0.402
# Recall = 0.694 vs. 1.000
# Validation
# AUC = 0.381 vs. 0.266
# F1 = 0.450 vs. 0.395
# Precision = 0.357 vs. 0.247
# Recall = 0.612 vs. 0.993
# Minibatch Loss= 4.340495
# Train Batch Evaluation
# AUC = 0.564 vs. 0.400
# F1 = 0.602 vs. 0.574
# Precision = 0.531 vs. 0.402
# Recall = 0.696 vs. 1.000
# Validation
# AUC = 0.398 vs. 0.242
# F1 = 0.450 vs. 0.394
# Precision = 0.357 vs. 0.246
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.330754
# Train Batch Evaluation
# AUC = 0.565 vs. 0.390
# F1 = 0.602 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.701 vs. 1.000
# Validation
# AUC = 0.387 vs. 0.256
# F1 = 0.451 vs. 0.393
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.321029
# Train Batch Evaluation
# AUC = 0.555 vs. 0.409
# F1 = 0.602 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.700 vs. 1.000
# Validation
# AUC = 0.384 vs. 0.234
# F1 = 0.451 vs. 0.396
# Precision = 0.357 vs. 0.251
# Recall = 0.612 vs. 0.944
# Minibatch Loss= 4.311320
# Train Batch Evaluation
# AUC = 0.573 vs. 0.404
# F1 = 0.603 vs. 0.574
# Precision = 0.527 vs. 0.402
# Recall = 0.703 vs. 1.000
# Validation
# AUC = 0.386 vs. 0.243
# F1 = 0.451 vs. 0.393
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.301627
# Train Batch Evaluation
# AUC = 0.567 vs. 0.407
# F1 = 0.603 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.703 vs. 1.000
# Validation
# AUC = 0.390 vs. 0.248
# F1 = 0.451 vs. 0.393
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.291950
# Train Batch Evaluation
# AUC = 0.569 vs. 0.409
# F1 = 0.603 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.701 vs. 0.999
# Validation
# AUC = 0.391 vs. 0.244
# F1 = 0.451 vs. 0.394
# Precision = 0.357 vs. 0.246
# Recall = 0.612 vs. 0.985
# Minibatch Loss= 4.282290
# Train Batch Evaluation
# AUC = 0.574 vs. 0.398
# F1 = 0.604 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.700 vs. 1.000
# Validation
# AUC = 0.388 vs. 0.255
# F1 = 0.451 vs. 0.396
# Precision = 0.357 vs. 0.247
# Recall = 0.612 vs. 0.998
# Minibatch Loss= 4.272645
# Train Batch Evaluation
# AUC = 0.564 vs. 0.402
# F1 = 0.604 vs. 0.574
# Precision = 0.532 vs. 0.402
# Recall = 0.698 vs. 1.000
# Validation
# AUC = 0.389 vs. 0.238
# F1 = 0.451 vs. 0.397
# Precision = 0.357 vs. 0.249
# Recall = 0.612 vs. 0.985
# Minibatch Loss= 4.263017
# Train Batch Evaluation
# AUC = 0.567 vs. 0.408
# F1 = 0.605 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.707 vs. 0.999
# Validation
# AUC = 0.389 vs. 0.246
# F1 = 0.451 vs. 0.397
# Precision = 0.357 vs. 0.248
# Recall = 0.612 vs. 0.998
# Minibatch Loss= 4.253406
# Train Batch Evaluation
# AUC = 0.569 vs. 0.394
# F1 = 0.605 vs. 0.574
# Precision = 0.529 vs. 0.402
# Recall = 0.707 vs. 1.000
# Validation
# AUC = 0.395 vs. 0.249
# F1 = 0.451 vs. 0.393
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.243811
# Train Batch Evaluation
# AUC = 0.562 vs. 0.406
# F1 = 0.605 vs. 0.574
# Precision = 0.529 vs. 0.402
# Recall = 0.707 vs. 0.999
# Validation
# AUC = 0.394 vs. 0.253
# F1 = 0.451 vs. 0.393
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.234233
# Train Batch Evaluation
# AUC = 0.564 vs. 0.401
# F1 = 0.606 vs. 0.574
# Precision = 0.530 vs. 0.402
# Recall = 0.706 vs. 1.000
# Validation
# AUC = 0.394 vs. 0.238
# F1 = 0.451 vs. 0.397
# Precision = 0.357 vs. 0.249
# Recall = 0.612 vs. 0.980
# Minibatch Loss= 4.224671
# Train Batch Evaluation
# AUC = 0.570 vs. 0.402
# F1 = 0.606 vs. 0.574
# Precision = 0.531 vs. 0.402
# Recall = 0.706 vs. 1.000
# Validation
# AUC = 0.393 vs. 0.229
# F1 = 0.451 vs. 0.394
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 4.215127
# Train Batch Evaluation
# AUC = 0.577 vs. 0.403
# F1 = 0.606 vs. 0.574
# Precision = 0.531 vs. 0.403
# Recall = 0.707 vs. 0.997
# Validation
# AUC = 0.399 vs. 0.262
# F1 = 0.451 vs. 0.396
# Precision = 0.357 vs. 0.248
# Recall = 0.612 vs. 0.980
# Minibatch Loss= 4.205598
# Train Batch Evaluation
# AUC = 0.570 vs. 0.398
# F1 = 0.607 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.713 vs. 1.000
# Validation
# AUC = 0.403 vs. 0.238
# F1 = 0.450 vs. 0.394
# Precision = 0.357 vs. 0.245
# Recall = 0.612 vs. 0.998
# Minibatch Loss= 4.196087
# Train Batch Evaluation
# AUC = 0.569 vs. 0.409
# F1 = 0.607 vs. 0.574
# Precision = 0.521 vs. 0.402
# Recall = 0.728 vs. 1.000
# Validation
# AUC = 0.404 vs. 0.243
# F1 = 0.450 vs. 0.393
# Precision = 0.428 vs. 0.245
# Recall = 0.475 vs. 1.000
# Minibatch Loss= 4.186593
# Train Batch Evaluation
# AUC = 0.580 vs. 0.406
# F1 = 0.608 vs. 0.574
# Precision = 0.521 vs. 0.402
# Recall = 0.729 vs. 0.999
# Validation
# AUC = 0.387 vs. 0.238
# F1 = 0.450 vs. 0.393
# Precision = 0.428 vs. 0.245
# Recall = 0.475 vs. 1.000
# Minibatch Loss= 4.177116
# Train Batch Evaluation
# AUC = 0.571 vs. 0.395
# F1 = 0.609 vs. 0.574
# Precision = 0.522 vs. 0.402
# Recall = 0.729 vs. 1.000
# Validation
# AUC = 0.403 vs. 0.257
# F1 = 0.450 vs. 0.393
# Precision = 0.428 vs. 0.245
# Recall = 0.475 vs. 0.998
# Minibatch Loss= 4.167656
# Train Batch Evaluation
# AUC = 0.575 vs. 0.409
# F1 = 0.609 vs. 0.574
# Precision = 0.531 vs. 0.402
# Recall = 0.713 vs. 1.000
# Validation
# AUC = 0.403 vs. 0.250
# F1 = 0.451 vs. 0.397
# Precision = 0.425 vs. 0.248
# Recall = 0.479 vs. 0.987
# Minibatch Loss= 4.158213
# Train Batch Evaluation
# AUC = 0.576 vs. 0.409
# F1 = 0.609 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.720 vs. 0.999
# Validation
# AUC = 0.403 vs. 0.241
# F1 = 0.452 vs. 0.397
# Precision = 0.427 vs. 0.248
# Recall = 0.479 vs. 0.996
# Minibatch Loss= 4.148788
# Train Batch Evaluation
# AUC = 0.576 vs. 0.403
# F1 = 0.610 vs. 0.574
# Precision = 0.528 vs. 0.403
# Recall = 0.721 vs. 0.999
# Validation
# AUC = 0.391 vs. 0.248
# F1 = 0.452 vs. 0.394
# Precision = 0.428 vs. 0.245
# Recall = 0.479 vs. 1.000
# Minibatch Loss= 4.139381
# Train Batch Evaluation
# AUC = 0.572 vs. 0.399
# F1 = 0.610 vs. 0.574
# Precision = 0.528 vs. 0.402
# Recall = 0.722 vs. 1.000
# Validation
# AUC = 0.401 vs. 0.240
# F1 = 0.453 vs. 0.394
# Precision = 0.429 vs. 0.247
# Recall = 0.479 vs. 0.983
# Minibatch Loss= 4.129991
# Train Batch Evaluation
# AUC = 0.583 vs. 0.399
# F1 = 0.611 vs. 0.574
# Precision = 0.528 vs. 0.403
# Recall = 0.724 vs. 0.998
# Validation
# AUC = 0.395 vs. 0.253
# F1 = 0.452 vs. 0.395
# Precision = 0.428 vs. 0.247
# Recall = 0.479 vs. 0.996
# Minibatch Loss= 4.120620
# Train Batch Evaluation
# AUC = 0.585 vs. 0.405
# F1 = 0.611 vs. 0.574
# Precision = 0.529 vs. 0.402
# Recall = 0.724 vs. 0.999
# Validation
# AUC = 0.393 vs. 0.247
# F1 = 0.453 vs. 0.394
# Precision = 0.404 vs. 0.247
# Recall = 0.514 vs. 0.974
# Minibatch Loss= 4.111267
# Train Batch Evaluation
# AUC = 0.577 vs. 0.402
# F1 = 0.612 vs. 0.574
# Precision = 0.534 vs. 0.402
# Recall = 0.717 vs. 1.000
# Validation
# AUC = 0.410 vs. 0.234
# F1 = 0.453 vs. 0.394
# Precision = 0.425 vs. 0.246
# Recall = 0.486 vs. 0.989
# Minibatch Loss= 4.101932
# Train Batch Evaluation
# AUC = 0.569 vs. 0.399
# F1 = 0.612 vs. 0.574
# Precision = 0.534 vs. 0.402
# Recall = 0.717 vs. 1.000
# Validation
# AUC = 0.410 vs. 0.242
# F1 = 0.454 vs. 0.394
# Precision = 0.407 vs. 0.245
# Recall = 0.514 vs. 0.998
# Minibatch Loss= 4.092615
# Train Batch Evaluation
# AUC = 0.570 vs. 0.399
# F1 = 0.612 vs. 0.574
# Precision = 0.534 vs. 0.402
# Recall = 0.718 vs. 1.000
# Validation
# AUC = 0.411 vs. 0.238
# F1 = 0.455 vs. 0.393
# Precision = 0.409 vs. 0.245
# Recall = 0.514 vs. 1.000
# Minibatch Loss= 4.083318
# Train Batch Evaluation
# AUC = 0.570 vs. 0.395
# F1 = 0.613 vs. 0.574
# Precision = 0.535 vs. 0.402
# Recall = 0.717 vs. 1.000
# Validation
# AUC = 0.411 vs. 0.256
# F1 = 0.455 vs. 0.395
# Precision = 0.409 vs. 0.246
# Recall = 0.514 vs. 0.989
# Minibatch Loss= 4.074039
# Train Batch Evaluation
# AUC = 0.571 vs. 0.403
# F1 = 0.613 vs. 0.574
# Precision = 0.535 vs. 0.402
# Recall = 0.718 vs. 1.000
# Validation
# AUC = 0.407 vs. 0.234
# F1 = 0.455 vs. 0.393
# Precision = 0.388 vs. 0.245
# Recall = 0.551 vs. 0.998
# Minibatch Loss= 4.064780
# Train Batch Evaluation
# AUC = 0.587 vs. 0.408
# F1 = 0.613 vs. 0.574
# Precision = 0.536 vs. 0.402
# Recall = 0.716 vs. 1.000
# Validation
# AUC = 0.401 vs. 0.241
# F1 = 0.456 vs. 0.394
# Precision = 0.389 vs. 0.245
# Recall = 0.551 vs. 1.000
# Minibatch Loss= 4.055540
# Train Batch Evaluation
# AUC = 0.575 vs. 0.395
# F1 = 0.613 vs. 0.574
# Precision = 0.537 vs. 0.402
# Recall = 0.716 vs. 1.000
# Validation
# AUC = 0.402 vs. 0.259
# F1 = 0.457 vs. 0.395
# Precision = 0.390 vs. 0.247
# Recall = 0.551 vs. 0.983
# Minibatch Loss= 4.046320
# Train Batch Evaluation
# AUC = 0.580 vs. 0.404
# F1 = 0.614 vs. 0.574
# Precision = 0.537 vs. 0.402
# Recall = 0.716 vs. 0.999
# Validation
# AUC = 0.400 vs. 0.259
# F1 = 0.458 vs. 0.394
# Precision = 0.391 vs. 0.246
# Recall = 0.551 vs. 0.991
# Minibatch Loss= 4.037119
# Train Batch Evaluation
# AUC = 0.576 vs. 0.406
# F1 = 0.614 vs. 0.574
# Precision = 0.538 vs. 0.402
# Recall = 0.715 vs. 1.000
# Validation
# AUC = 0.401 vs. 0.239
# F1 = 0.458 vs. 0.395
# Precision = 0.438 vs. 0.246
# Recall = 0.479 vs. 0.998
# Minibatch Loss= 4.027939
# Train Batch Evaluation
# AUC = 0.577 vs. 0.398
# F1 = 0.614 vs. 0.574
# Precision = 0.533 vs. 0.402
# Recall = 0.724 vs. 1.000
# Validation
# AUC = 0.402 vs. 0.255
# F1 = 0.458 vs. 0.394
# Precision = 0.391 vs. 0.245
# Recall = 0.551 vs. 1.000
# Minibatch Loss= 4.018779
# Train Batch Evaluation
# AUC = 0.577 vs. 0.404
# F1 = 0.615 vs. 0.574
# Precision = 0.539 vs. 0.402
# Recall = 0.715 vs. 1.000
# Validation
# AUC = 0.399 vs. 0.255
# F1 = 0.458 vs. 0.396
# Precision = 0.393 vs. 0.247
# Recall = 0.551 vs. 0.991
# Minibatch Loss= 4.009640
# Train Batch Evaluation
# AUC = 0.589 vs. 0.395
# F1 = 0.615 vs. 0.574
# Precision = 0.537 vs. 0.402
# Recall = 0.720 vs. 1.000
# Validation
# AUC = 0.398 vs. 0.241
# F1 = 0.460 vs. 0.395
# Precision = 0.394 vs. 0.246
# Recall = 0.553 vs. 0.996
# Minibatch Loss= 4.000521
# Train Batch Evaluation
# AUC = 0.580 vs. 0.404
# F1 = 0.615 vs. 0.574
# Precision = 0.537 vs. 0.402
# Recall = 0.721 vs. 0.999
# Validation
# AUC = 0.402 vs. 0.252
# F1 = 0.459 vs. 0.394
# Precision = 0.393 vs. 0.245
# Recall = 0.553 vs. 1.000
# Minibatch Loss= 3.991423
# Train Batch Evaluation
# AUC = 0.591 vs. 0.401
# F1 = 0.615 vs. 0.574
# Precision = 0.540 vs. 0.402
# Recall = 0.715 vs. 1.000
# Validation
# AUC = 0.405 vs. 0.249
# F1 = 0.460 vs. 0.394
# Precision = 0.392 vs. 0.245
# Recall = 0.557 vs. 0.998
# Minibatch Loss= 3.982346
# Train Batch Evaluation
# AUC = 0.586 vs. 0.402
# F1 = 0.616 vs. 0.574
# Precision = 0.539 vs. 0.402
# Recall = 0.717 vs. 1.000
# Validation
# AUC = 0.406 vs. 0.238
# F1 = 0.461 vs. 0.393
# Precision = 0.392 vs. 0.245
# Recall = 0.560 vs. 1.000
# Minibatch Loss= 3.973290
# Train Batch Evaluation
# AUC = 0.587 vs. 0.400
# F1 = 0.616 vs. 0.574
# Precision = 0.540 vs. 0.402
# Recall = 0.717 vs. 1.000
# Validation
# AUC = 0.398 vs. 0.251
# F1 = 0.462 vs. 0.397
# Precision = 0.393 vs. 0.253
# Recall = 0.560 vs. 0.926
# Minibatch Loss= 3.964256
# Train Batch Evaluation
# AUC = 0.586 vs. 0.403
# F1 = 0.616 vs. 0.574
# Precision = 0.541 vs. 0.402
# Recall = 0.717 vs. 1.000
# Validation
# AUC = 0.408 vs. 0.259
# F1 = 0.462 vs. 0.394
# Precision = 0.394 vs. 0.246
# Recall = 0.560 vs. 0.978
# Minibatch Loss= 3.955244
# Train Batch Evaluation
# AUC = 0.589 vs. 0.408
# F1 = 0.617 vs. 0.574
# Precision = 0.541 vs. 0.402
# Recall = 0.718 vs. 1.000
# Validation
# AUC = 0.408 vs. 0.238
# F1 = 0.463 vs. 0.394
# Precision = 0.393 vs. 0.245
# Recall = 0.562 vs. 1.000
# Minibatch Loss= 3.946254
# Train Batch Evaluation
# AUC = 0.578 vs. 0.402
# F1 = 0.617 vs. 0.574
# Precision = 0.541 vs. 0.402
# Recall = 0.718 vs. 1.000
# Validation
# AUC = 0.410 vs. 0.266
# F1 = 0.463 vs. 0.395
# Precision = 0.394 vs. 0.254
# Recall = 0.562 vs. 0.885
# Minibatch Loss= 3.937285
# Train Batch Evaluation
# AUC = 0.586 vs. 0.403
# F1 = 0.618 vs. 0.574
# Precision = 0.542 vs. 0.402
# Recall = 0.718 vs. 1.000
# Validation
# AUC = 0.405 vs. 0.228
# F1 = 0.464 vs. 0.393
# Precision = 0.403 vs. 0.245
# Recall = 0.547 vs. 1.000
# Minibatch Loss= 3.928340
# Train Batch Evaluation
# AUC = 0.584 vs. 0.404
# F1 = 0.618 vs. 0.574
# Precision = 0.542 vs. 0.402
# Recall = 0.718 vs. 1.000
# Validation
# AUC = 0.408 vs. 0.240
# F1 = 0.465 vs. 0.393
# Precision = 0.404 vs. 0.245
# Recall = 0.547 vs. 1.000
# Minibatch Loss= 3.919417
# ...
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.245
# F1 = 0.700 vs. 0.396
# Precision = 0.680 vs. 0.247
# Recall = 0.722 vs. 0.996
# Minibatch Loss= 0.465399
# Train Batch Evaluation
# AUC = 0.832 vs. 0.410
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.252
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.247
# Recall = 0.722 vs. 0.983
# Minibatch Loss= 0.465398
# Train Batch Evaluation
# AUC = 0.832 vs. 0.414
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.241
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465398
# Train Batch Evaluation
# AUC = 0.832 vs. 0.405
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.253
# F1 = 0.700 vs. 0.395
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.996
# Minibatch Loss= 0.465397
# Train Batch Evaluation
# AUC = 0.832 vs. 0.405
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.403
# Recall = 0.875 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.246
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465396
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.249
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465396
# Train Batch Evaluation
# AUC = 0.832 vs. 0.402
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.244
# F1 = 0.700 vs. 0.395
# Precision = 0.680 vs. 0.248
# Recall = 0.722 vs. 0.967
# Minibatch Loss= 0.465395
# Train Batch Evaluation
# AUC = 0.832 vs. 0.403
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.259
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465394
# Train Batch Evaluation
# AUC = 0.832 vs. 0.400
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.238
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465393
# Train Batch Evaluation
# AUC = 0.832 vs. 0.398
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.241
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465393
# Train Batch Evaluation
# AUC = 0.832 vs. 0.400
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.252
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.989
# Minibatch Loss= 0.465392
# Train Batch Evaluation
# AUC = 0.832 vs. 0.403
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.251
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.991
# Minibatch Loss= 0.465391
# Train Batch Evaluation
# AUC = 0.832 vs. 0.399
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.228
# F1 = 0.700 vs. 0.398
# Precision = 0.680 vs. 0.249
# Recall = 0.722 vs. 0.996
# Minibatch Loss= 0.465390
# Train Batch Evaluation
# AUC = 0.832 vs. 0.409
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.403
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.244
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 0.996
# Minibatch Loss= 0.465390
# Train Batch Evaluation
# AUC = 0.832 vs. 0.393
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.241
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 0.998
# Minibatch Loss= 0.465389
# Train Batch Evaluation
# AUC = 0.832 vs. 0.404
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.241
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465388
# Train Batch Evaluation
# AUC = 0.832 vs. 0.396
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.236
# F1 = 0.700 vs. 0.395
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.996
# Minibatch Loss= 0.465387
# Train Batch Evaluation
# AUC = 0.832 vs. 0.402
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.240
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.989
# Minibatch Loss= 0.465387
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.273
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.976
# Minibatch Loss= 0.465386
# Train Batch Evaluation
# AUC = 0.832 vs. 0.399
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.277
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465385
# Train Batch Evaluation
# AUC = 0.832 vs. 0.411
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.246
# F1 = 0.700 vs. 0.396
# Precision = 0.680 vs. 0.252
# Recall = 0.722 vs. 0.922
# Minibatch Loss= 0.465385
# Train Batch Evaluation
# AUC = 0.832 vs. 0.402
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.403
# Recall = 0.875 vs. 0.998
# Validation
# AUC = 0.696 vs. 0.264
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.249
# Recall = 0.722 vs. 0.937
# Minibatch Loss= 0.465384
# Train Batch Evaluation
# AUC = 0.832 vs. 0.411
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.233
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465383
# Train Batch Evaluation
# AUC = 0.832 vs. 0.405
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.240
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465382
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.231
# F1 = 0.700 vs. 0.395
# Precision = 0.680 vs. 0.247
# Recall = 0.722 vs. 0.993
# Minibatch Loss= 0.465382
# Train Batch Evaluation
# AUC = 0.832 vs. 0.400
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.239
# F1 = 0.700 vs. 0.395
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.989
# Minibatch Loss= 0.465381
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.256
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465380
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 0.998
# Validation
# AUC = 0.696 vs. 0.248
# F1 = 0.700 vs. 0.397
# Precision = 0.680 vs. 0.248
# Recall = 0.722 vs. 0.996
# Minibatch Loss= 0.465380
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.255
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465379
# Train Batch Evaluation
# AUC = 0.832 vs. 0.398
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.261
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465378
# Train Batch Evaluation
# AUC = 0.832 vs. 0.407
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.240
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.987
# Minibatch Loss= 0.465377
# Train Batch Evaluation
# AUC = 0.832 vs. 0.403
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.251
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.998
# Minibatch Loss= 0.465377
# Train Batch Evaluation
# AUC = 0.832 vs. 0.405
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.274
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465376
# Train Batch Evaluation
# AUC = 0.832 vs. 0.409
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.242
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 0.991
# Minibatch Loss= 0.465375
# Train Batch Evaluation
# AUC = 0.832 vs. 0.399
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.239
# F1 = 0.700 vs. 0.396
# Precision = 0.680 vs. 0.249
# Recall = 0.722 vs. 0.967
# Minibatch Loss= 0.465375
# Train Batch Evaluation
# AUC = 0.832 vs. 0.398
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.241
# F1 = 0.700 vs. 0.395
# Precision = 0.680 vs. 0.246
# Recall = 0.722 vs. 0.989
# Minibatch Loss= 0.465374
# Train Batch Evaluation
# AUC = 0.832 vs. 0.408
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.233
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465373
# Train Batch Evaluation
# AUC = 0.832 vs. 0.399
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.237
# F1 = 0.700 vs. 0.396
# Precision = 0.680 vs. 0.248
# Recall = 0.722 vs. 0.985
# Minibatch Loss= 0.465372
# Train Batch Evaluation
# AUC = 0.832 vs. 0.400
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.231
# F1 = 0.700 vs. 0.393
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465372
# Train Batch Evaluation
# AUC = 0.832 vs. 0.399
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.253
# F1 = 0.700 vs. 0.397
# Precision = 0.680 vs. 0.248
# Recall = 0.722 vs. 0.991
# Minibatch Loss= 0.465371
# Train Batch Evaluation
# AUC = 0.832 vs. 0.396
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.402
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.255
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 0.998
# Minibatch Loss= 0.465370
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.745 vs. 0.403
# Recall = 0.875 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.238
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465370
# Train Batch Evaluation
# AUC = 0.832 vs. 0.403
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.238
# F1 = 0.700 vs. 0.396
# Precision = 0.680 vs. 0.250
# Recall = 0.722 vs. 0.959
# Minibatch Loss= 0.465369
# Train Batch Evaluation
# AUC = 0.832 vs. 0.408
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.238
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465368
# Train Batch Evaluation
# AUC = 0.832 vs. 0.403
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.247
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465367
# Train Batch Evaluation
# AUC = 0.832 vs. 0.405
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.244
# F1 = 0.700 vs. 0.396
# Precision = 0.680 vs. 0.247
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465367
# Train Batch Evaluation
# AUC = 0.832 vs. 0.404
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.255
# F1 = 0.700 vs. 0.396
# Precision = 0.680 vs. 0.247
# Recall = 0.722 vs. 0.993
# Minibatch Loss= 0.465366
# Train Batch Evaluation
# AUC = 0.832 vs. 0.400
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.239
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.245
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.465365
# Train Batch Evaluation
# AUC = 0.832 vs. 0.400
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.251
# F1 = 0.700 vs. 0.398
# Precision = 0.680 vs. 0.254
# Recall = 0.722 vs. 0.920
# Minibatch Loss= 0.465365
# Train Batch Evaluation
# AUC = 0.832 vs. 0.394
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.232
# F1 = 0.700 vs. 0.394
# Precision = 0.680 vs. 0.249
# Recall = 0.722 vs. 0.948
# Minibatch Loss= 0.465364
# Train Batch Evaluation
# AUC = 0.832 vs. 0.404
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.259
# F1 = 0.700 vs. 0.395
# Precision = 0.675 vs. 0.249
# Recall = 0.727 vs. 0.959
# Minibatch Loss= 0.465363
# Train Batch Evaluation
# AUC = 0.832 vs. 0.403
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.243
# F1 = 0.700 vs. 0.396
# Precision = 0.675 vs. 0.248
# Recall = 0.727 vs. 0.993
# Minibatch Loss= 0.465362
# Train Batch Evaluation
# AUC = 0.832 vs. 0.406
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.227
# F1 = 0.700 vs. 0.396
# Precision = 0.675 vs. 0.247
# Recall = 0.727 vs. 1.000
# Minibatch Loss= 0.465362
# Train Batch Evaluation
# AUC = 0.832 vs. 0.404
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.253
# F1 = 0.700 vs. 0.395
# Precision = 0.675 vs. 0.246
# Recall = 0.727 vs. 1.000
# Minibatch Loss= 0.465361
# Train Batch Evaluation
# AUC = 0.832 vs. 0.409
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.248
# F1 = 0.700 vs. 0.397
# Precision = 0.675 vs. 0.249
# Recall = 0.727 vs. 0.976
# Minibatch Loss= 0.465360
# Train Batch Evaluation
# AUC = 0.832 vs. 0.399
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.253
# F1 = 0.700 vs. 0.395
# Precision = 0.675 vs. 0.247
# Recall = 0.727 vs. 0.976
# Minibatch Loss= 0.465360
# Train Batch Evaluation
# AUC = 0.832 vs. 0.396
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.258
# F1 = 0.700 vs. 0.394
# Precision = 0.675 vs. 0.245
# Recall = 0.727 vs. 1.000
# Minibatch Loss= 0.465359
# Train Batch Evaluation
# AUC = 0.832 vs. 0.400
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 0.999
# Validation
# AUC = 0.696 vs. 0.262
# F1 = 0.700 vs. 0.398
# Precision = 0.675 vs. 0.249
# Recall = 0.727 vs. 0.993
# Minibatch Loss= 0.465358
# Train Batch Evaluation
# AUC = 0.832 vs. 0.399
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.254
# F1 = 0.700 vs. 0.393
# Precision = 0.675 vs. 0.245
# Recall = 0.727 vs. 1.000
# Minibatch Loss= 0.465357
# Train Batch Evaluation
# AUC = 0.832 vs. 0.396
# F1 = 0.805 vs. 0.574
# Precision = 0.746 vs. 0.402
# Recall = 0.874 vs. 1.000
# Validation
# AUC = 0.696 vs. 0.248
# F1 = 0.700 vs. 0.393
# Precision = 0.675 vs. 0.245
# Recall = 0.727 vs. 1.000
# Minibatch Loss= 0.465357
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b36d9b1bc550> in <module>()
#       2                 train_eval_step = 1,
#       3                 validation_eval_step = 1,
# ----> 4                 display_step = 1)
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#      65         for _ in range (max_iter):
#      66             if self.global_step % self.num_batch == 0:
# ---> 67                 self.data_train ,self.ground_truth_train = self.shuffle(self.data_train, self.ground_truth_train)
#      68
#      69             batch_idx = self.global_step % self.num_batch
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.pyc in shuffle(self, data, gt)
#     138         np.random.shuffle(idx)
#     139
# --> 140         data = data[idx]
#     141         gt = gt[idx]
#     142
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/CNN9003_opp/CNN9003_opp-5625'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.696 vs. 0.261
# F1 = 0.700 vs. 0.395
# Precision = 0.675 vs. 0.246
# Recall = 0.727 vs. 0.993

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
