# %%
# useing this variable for saving models and summaries
exp_name = "DWN9006_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model_light as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp4.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)
    
train_data = data['train_data']
test_data = data['test_data']
validation_data = data['validation_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

#index_of_changes = data['index_of_changes_test']

# %%
train_gt.shape, train_data.shape
# Out:
# ((1, 700165, 1), (1, 700165, 77))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 1

wavelet_levels = 5    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_kernel_size = 5    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
''' s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()
'''

s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[0,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)
pos_weight = pos_weight[0]

# %%
train_data = train_data[:,:-(train_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_data = validation_data[:,:-(validation_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_data = test_data[:,:-(test_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

train_gt = train_gt[:,:-(train_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_gt = validation_gt[:,:-(validation_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_gt = test_gt[:,:-(test_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

# %%
print pos_weight
# Out:
# 2.17746

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_kernel_size = wavelet_kernel_size,    
                                 activation = activation,
                                 trainable_wavelet=False,
                                 trainable_conv=False,
                                 trainable_last=True,
                                )

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
#load the model
saver = tf.train.Saver(var_list = [
    model.weights['wc0'],model.weights['wc1'],model.weights['wc2'],
    model.bias['bc0'],model.bias['bc1'],model.bias['bc2'],
    model.weights['high_pass'],model.weights['low_pass']
])
saver.restore(sess, '../model/DWN9005_opp/checkpoint-607')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/DWN9005_opp/checkpoint-607

# %%
trainer.train(max_iter = 4000,
                train_eval_step = 1, 
                validation_eval_step = 1,
                display_step = 1)
# Out:
# Train Batch Evaluation
# AUC = 0.530 vs. 0.319
# F1 = 0.512 vs. 0.479
# Precision = 0.516 vs. 0.315
# Recall = 0.508 vs. 1.000
# Validation
# AUC = 0.316 vs. 0.194
# F1 = 0.447 vs. 0.321
# Precision = 0.357 vs. 0.191
# Recall = 0.597 vs. 0.994
# Minibatch Loss= 25.901600
# Train Batch Evaluation
# AUC = 0.533 vs. 0.311
# F1 = 0.513 vs. 0.479
# Precision = 0.514 vs. 0.315
# Recall = 0.512 vs. 0.999
# Validation
# AUC = 0.319 vs. 0.224
# F1 = 0.450 vs. 0.326
# Precision = 0.353 vs. 0.201
# Recall = 0.619 vs. 0.854
# Minibatch Loss= 25.541018
# Train Batch Evaluation
# AUC = 0.535 vs. 0.314
# F1 = 0.514 vs. 0.479
# Precision = 0.518 vs. 0.315
# Recall = 0.511 vs. 1.000
# Validation
# AUC = 0.321 vs. 0.195
# F1 = 0.452 vs. 0.324
# Precision = 0.355 vs. 0.194
# Recall = 0.622 vs. 0.980
# Minibatch Loss= 25.180523
# Train Batch Evaluation
# AUC = 0.537 vs. 0.317
# F1 = 0.515 vs. 0.479
# Precision = 0.519 vs. 0.315
# Recall = 0.511 vs. 0.998
# Validation
# AUC = 0.324 vs. 0.211
# F1 = 0.454 vs. 0.324
# Precision = 0.357 vs. 0.216
# Recall = 0.622 vs. 0.641
# Minibatch Loss= 24.820135
# Train Batch Evaluation
# AUC = 0.540 vs. 0.318
# F1 = 0.517 vs. 0.479
# Precision = 0.522 vs. 0.315
# Recall = 0.511 vs. 1.000
# Validation
# AUC = 0.327 vs. 0.193
# F1 = 0.455 vs. 0.322
# Precision = 0.359 vs. 0.192
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 24.459906
# Train Batch Evaluation
# AUC = 0.542 vs. 0.313
# F1 = 0.517 vs. 0.479
# Precision = 0.525 vs. 0.315
# Recall = 0.510 vs. 1.000
# Validation
# AUC = 0.331 vs. 0.194
# F1 = 0.456 vs. 0.320
# Precision = 0.360 vs. 0.191
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 24.099873
# Train Batch Evaluation
# AUC = 0.544 vs. 0.318
# F1 = 0.518 vs. 0.479
# Precision = 0.525 vs. 0.315
# Recall = 0.512 vs. 1.000
# Validation
# AUC = 0.334 vs. 0.222
# F1 = 0.458 vs. 0.324
# Precision = 0.362 vs. 0.198
# Recall = 0.622 vs. 0.885
# Minibatch Loss= 23.740107
# Train Batch Evaluation
# AUC = 0.546 vs. 0.321
# F1 = 0.520 vs. 0.479
# Precision = 0.527 vs. 0.315
# Recall = 0.512 vs. 1.000
# Validation
# AUC = 0.336 vs. 0.203
# F1 = 0.459 vs. 0.321
# Precision = 0.363 vs. 0.192
# Recall = 0.622 vs. 0.992
# Minibatch Loss= 23.380692
# Train Batch Evaluation
# AUC = 0.548 vs. 0.324
# F1 = 0.521 vs. 0.479
# Precision = 0.547 vs. 0.315
# Recall = 0.497 vs. 0.999
# Validation
# AUC = 0.338 vs. 0.192
# F1 = 0.459 vs. 0.322
# Precision = 0.363 vs. 0.193
# Recall = 0.622 vs. 0.975
# Minibatch Loss= 23.021744
# Train Batch Evaluation
# AUC = 0.551 vs. 0.316
# F1 = 0.522 vs. 0.479
# Precision = 0.549 vs. 0.316
# Recall = 0.497 vs. 0.997
# Validation
# AUC = 0.341 vs. 0.180
# F1 = 0.460 vs. 0.320
# Precision = 0.365 vs. 0.191
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 22.663408
# Train Batch Evaluation
# AUC = 0.553 vs. 0.315
# F1 = 0.524 vs. 0.481
# Precision = 0.556 vs. 0.317
# Recall = 0.495 vs. 0.991
# Validation
# AUC = 0.343 vs. 0.193
# F1 = 0.460 vs. 0.321
# Precision = 0.365 vs. 0.191
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 22.305866
# Train Batch Evaluation
# AUC = 0.555 vs. 0.320
# F1 = 0.526 vs. 0.479
# Precision = 0.559 vs. 0.315
# Recall = 0.496 vs. 1.000
# Validation
# AUC = 0.346 vs. 0.177
# F1 = 0.461 vs. 0.321
# Precision = 0.366 vs. 0.193
# Recall = 0.622 vs. 0.952
# Minibatch Loss= 21.949339
# Train Batch Evaluation
# AUC = 0.557 vs. 0.316
# F1 = 0.527 vs. 0.480
# Precision = 0.561 vs. 0.315
# Recall = 0.498 vs. 0.999
# Validation
# AUC = 0.349 vs. 0.200
# F1 = 0.462 vs. 0.323
# Precision = 0.368 vs. 0.193
# Recall = 0.622 vs. 0.994
# Minibatch Loss= 21.594093
# Train Batch Evaluation
# AUC = 0.558 vs. 0.317
# F1 = 0.528 vs. 0.480
# Precision = 0.565 vs. 0.316
# Recall = 0.496 vs. 0.997
# Validation
# AUC = 0.352 vs. 0.216
# F1 = 0.464 vs. 0.323
# Precision = 0.370 vs. 0.195
# Recall = 0.622 vs. 0.947
# Minibatch Loss= 21.240454
# Train Batch Evaluation
# AUC = 0.560 vs. 0.312
# F1 = 0.530 vs. 0.479
# Precision = 0.567 vs. 0.316
# Recall = 0.497 vs. 0.998
# Validation
# AUC = 0.354 vs. 0.177
# F1 = 0.465 vs. 0.322
# Precision = 0.371 vs. 0.193
# Recall = 0.622 vs. 0.978
# Minibatch Loss= 20.888750
# Train Batch Evaluation
# AUC = 0.562 vs. 0.314
# F1 = 0.531 vs. 0.479
# Precision = 0.572 vs. 0.315
# Recall = 0.496 vs. 1.000
# Validation
# AUC = 0.357 vs. 0.199
# F1 = 0.465 vs. 0.324
# Precision = 0.372 vs. 0.196
# Recall = 0.622 vs. 0.933
# Minibatch Loss= 20.539343
# Train Batch Evaluation
# AUC = 0.564 vs. 0.302
# F1 = 0.533 vs. 0.479
# Precision = 0.564 vs. 0.315
# Recall = 0.505 vs. 1.000
# Validation
# AUC = 0.361 vs. 0.199
# F1 = 0.466 vs. 0.333
# Precision = 0.372 vs. 0.209
# Recall = 0.622 vs. 0.821
# Minibatch Loss= 20.192574
# Train Batch Evaluation
# AUC = 0.566 vs. 0.319
# F1 = 0.534 vs. 0.479
# Precision = 0.570 vs. 0.315
# Recall = 0.503 vs. 1.000
# Validation
# AUC = 0.364 vs. 0.206
# F1 = 0.467 vs. 0.321
# Precision = 0.375 vs. 0.191
# Recall = 0.619 vs. 1.000
# Minibatch Loss= 19.848768
# Train Batch Evaluation
# AUC = 0.567 vs. 0.311
# F1 = 0.536 vs. 0.479
# Precision = 0.576 vs. 0.315
# Recall = 0.500 vs. 1.000
# Validation
# AUC = 0.366 vs. 0.186
# F1 = 0.468 vs. 0.325
# Precision = 0.374 vs. 0.194
# Recall = 0.625 vs. 0.994
# Minibatch Loss= 19.508253
# Train Batch Evaluation
# AUC = 0.569 vs. 0.309
# F1 = 0.537 vs. 0.480
# Precision = 0.575 vs. 0.316
# Recall = 0.504 vs. 0.999
# Validation
# AUC = 0.369 vs. 0.204
# F1 = 0.469 vs. 0.321
# Precision = 0.376 vs. 0.192
# Recall = 0.622 vs. 0.992
# Minibatch Loss= 19.171329
# Train Batch Evaluation
# AUC = 0.571 vs. 0.314
# F1 = 0.539 vs. 0.479
# Precision = 0.585 vs. 0.315
# Recall = 0.499 vs. 1.000
# Validation
# AUC = 0.372 vs. 0.195
# F1 = 0.470 vs. 0.321
# Precision = 0.378 vs. 0.191
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 18.838299
# Train Batch Evaluation
# AUC = 0.572 vs. 0.308
# F1 = 0.540 vs. 0.479
# Precision = 0.590 vs. 0.316
# Recall = 0.498 vs. 0.996
# Validation
# AUC = 0.375 vs. 0.199
# F1 = 0.471 vs. 0.329
# Precision = 0.406 vs. 0.202
# Recall = 0.560 vs. 0.877
# Minibatch Loss= 18.509457
# Train Batch Evaluation
# AUC = 0.574 vs. 0.317
# F1 = 0.543 vs. 0.480
# Precision = 0.594 vs. 0.317
# Recall = 0.499 vs. 0.992
# Validation
# AUC = 0.377 vs. 0.184
# F1 = 0.472 vs. 0.322
# Precision = 0.408 vs. 0.192
# Recall = 0.560 vs. 0.997
# Minibatch Loss= 18.185064
# Train Batch Evaluation
# AUC = 0.576 vs. 0.317
# F1 = 0.544 vs. 0.480
# Precision = 0.595 vs. 0.316
# Recall = 0.500 vs. 0.997
# Validation
# AUC = 0.380 vs. 0.199
# F1 = 0.476 vs. 0.326
# Precision = 0.417 vs. 0.200
# Recall = 0.555 vs. 0.888
# Minibatch Loss= 17.865347
# Train Batch Evaluation
# AUC = 0.577 vs. 0.317
# F1 = 0.545 vs. 0.479
# Precision = 0.574 vs. 0.315
# Recall = 0.518 vs. 1.000
# Validation
# AUC = 0.384 vs. 0.190
# F1 = 0.478 vs. 0.320
# Precision = 0.418 vs. 0.191
# Recall = 0.557 vs. 1.000
# Minibatch Loss= 17.550489
# Train Batch Evaluation
# AUC = 0.579 vs. 0.313
# F1 = 0.547 vs. 0.479
# Precision = 0.591 vs. 0.315
# Recall = 0.509 vs. 1.000
# Validation
# AUC = 0.387 vs. 0.201
# F1 = 0.480 vs. 0.324
# Precision = 0.420 vs. 0.197
# Recall = 0.560 vs. 0.908
# Minibatch Loss= 17.240614
# Train Batch Evaluation
# AUC = 0.580 vs. 0.322
# F1 = 0.548 vs. 0.480
# Precision = 0.593 vs. 0.316
# Recall = 0.509 vs. 0.998
# Validation
# AUC = 0.390 vs. 0.216
# F1 = 0.481 vs. 0.321
# Precision = 0.420 vs. 0.191
# Recall = 0.563 vs. 1.000
# Minibatch Loss= 16.935822
# Train Batch Evaluation
# AUC = 0.581 vs. 0.322
# F1 = 0.550 vs. 0.480
# Precision = 0.596 vs. 0.315
# Recall = 0.510 vs. 0.999
# Validation
# AUC = 0.393 vs. 0.190
# F1 = 0.484 vs. 0.323
# Precision = 0.420 vs. 0.193
# Recall = 0.571 vs. 0.997
# Minibatch Loss= 16.636192
# Train Batch Evaluation
# AUC = 0.583 vs. 0.318
# F1 = 0.551 vs. 0.479
# Precision = 0.585 vs. 0.315
# Recall = 0.521 vs. 1.000
# Validation
# AUC = 0.396 vs. 0.217
# F1 = 0.486 vs. 0.321
# Precision = 0.422 vs. 0.191
# Recall = 0.571 vs. 1.000
# Minibatch Loss= 16.341820
# Train Batch Evaluation
# AUC = 0.584 vs. 0.315
# F1 = 0.553 vs. 0.479
# Precision = 0.588 vs. 0.315
# Recall = 0.521 vs. 1.000
# Validation
# AUC = 0.399 vs. 0.183
# F1 = 0.486 vs. 0.321
# Precision = 0.423 vs. 0.192
# Recall = 0.571 vs. 0.994
# Minibatch Loss= 16.052807
# Train Batch Evaluation
# AUC = 0.585 vs. 0.322
# F1 = 0.554 vs. 0.479
# Precision = 0.591 vs. 0.315
# Recall = 0.521 vs. 1.000
# Validation
# AUC = 0.401 vs. 0.208
# F1 = 0.487 vs. 0.321
# Precision = 0.424 vs. 0.191
# Recall = 0.571 vs. 1.000
# Minibatch Loss= 15.769259
# Train Batch Evaluation
# AUC = 0.587 vs. 0.316
# F1 = 0.555 vs. 0.480
# Precision = 0.597 vs. 0.316
# Recall = 0.519 vs. 0.997
# Validation
# AUC = 0.405 vs. 0.185
# F1 = 0.489 vs. 0.324
# Precision = 0.428 vs. 0.193
# Recall = 0.571 vs. 0.997
# Minibatch Loss= 15.491288
# Train Batch Evaluation
# AUC = 0.588 vs. 0.312
# F1 = 0.557 vs. 0.479
# Precision = 0.595 vs. 0.315
# Recall = 0.523 vs. 0.999
# Validation
# AUC = 0.407 vs. 0.212
# F1 = 0.491 vs. 0.325
# Precision = 0.436 vs. 0.196
# Recall = 0.563 vs. 0.944
# Minibatch Loss= 15.219005
# Train Batch Evaluation
# AUC = 0.589 vs. 0.314
# F1 = 0.558 vs. 0.479
# Precision = 0.604 vs. 0.315
# Recall = 0.518 vs. 1.000
# Validation
# AUC = 0.409 vs. 0.235
# F1 = 0.495 vs. 0.325
# Precision = 0.437 vs. 0.216
# Recall = 0.571 vs. 0.661
# Minibatch Loss= 14.952521
# Train Batch Evaluation
# AUC = 0.590 vs. 0.314
# F1 = 0.559 vs. 0.479
# Precision = 0.603 vs. 0.315
# Recall = 0.521 vs. 1.000
# Validation
# AUC = 0.412 vs. 0.191
# F1 = 0.496 vs. 0.323
# Precision = 0.437 vs. 0.193
# Recall = 0.574 vs. 1.000
# Minibatch Loss= 14.691973
# Train Batch Evaluation
# AUC = 0.591 vs. 0.312
# F1 = 0.561 vs. 0.479
# Precision = 0.601 vs. 0.315
# Recall = 0.525 vs. 0.998
# Validation
# AUC = 0.414 vs. 0.197
# F1 = 0.499 vs. 0.325
# Precision = 0.442 vs. 0.198
# Recall = 0.574 vs. 0.894
# Minibatch Loss= 14.437493
# Train Batch Evaluation
# AUC = 0.593 vs. 0.316
# F1 = 0.562 vs. 0.479
# Precision = 0.618 vs. 0.315
# Recall = 0.516 vs. 1.000
# Validation
# AUC = 0.416 vs. 0.202
# F1 = 0.499 vs. 0.321
# Precision = 0.443 vs. 0.191
# Recall = 0.571 vs. 1.000
# Minibatch Loss= 14.189218
# Train Batch Evaluation
# AUC = 0.594 vs. 0.315
# F1 = 0.564 vs. 0.479
# Precision = 0.624 vs. 0.315
# Recall = 0.515 vs. 0.998
# Validation
# AUC = 0.419 vs. 0.176
# F1 = 0.501 vs. 0.321
# Precision = 0.478 vs. 0.191
# Recall = 0.527 vs. 0.986
# Minibatch Loss= 13.947263
# Train Batch Evaluation
# AUC = 0.595 vs. 0.317
# F1 = 0.566 vs. 0.479
# Precision = 0.626 vs. 0.316
# Recall = 0.517 vs. 0.994
# Validation
# AUC = 0.421 vs. 0.198
# F1 = 0.503 vs. 0.324
# Precision = 0.481 vs. 0.195
# Recall = 0.527 vs. 0.966
# Minibatch Loss= 13.711707
# Train Batch Evaluation
# AUC = 0.595 vs. 0.317
# F1 = 0.568 vs. 0.479
# Precision = 0.629 vs. 0.315
# Recall = 0.518 vs. 1.000
# Validation
# AUC = 0.424 vs. 0.200
# F1 = 0.503 vs. 0.326
# Precision = 0.481 vs. 0.196
# Recall = 0.527 vs. 0.966
# Minibatch Loss= 13.482591
# Train Batch Evaluation
# AUC = 0.596 vs. 0.320
# F1 = 0.569 vs. 0.480
# Precision = 0.635 vs. 0.316
# Recall = 0.515 vs. 0.999
# Validation
# AUC = 0.426 vs. 0.184
# F1 = 0.504 vs. 0.321
# Precision = 0.454 vs. 0.191
# Recall = 0.566 vs. 1.000
# Minibatch Loss= 13.259907
# Train Batch Evaluation
# AUC = 0.598 vs. 0.315
# F1 = 0.570 vs. 0.479
# Precision = 0.636 vs. 0.315
# Recall = 0.517 vs. 1.000
# Validation
# AUC = 0.428 vs. 0.185
# F1 = 0.506 vs. 0.320
# Precision = 0.475 vs. 0.191
# Recall = 0.541 vs. 1.000
# Minibatch Loss= 13.043613
# Train Batch Evaluation
# AUC = 0.598 vs. 0.321
# F1 = 0.572 vs. 0.479
# Precision = 0.636 vs. 0.315
# Recall = 0.519 vs. 1.000
# Validation
# AUC = 0.431 vs. 0.189
# F1 = 0.508 vs. 0.321
# Precision = 0.476 vs. 0.192
# Recall = 0.546 vs. 0.969
# Minibatch Loss= 12.833627
# Train Batch Evaluation
# AUC = 0.599 vs. 0.319
# F1 = 0.572 vs. 0.479
# Precision = 0.634 vs. 0.315
# Recall = 0.521 vs. 1.000
# Validation
# AUC = 0.434 vs. 0.192
# F1 = 0.510 vs. 0.323
# Precision = 0.475 vs. 0.193
# Recall = 0.552 vs. 0.994
# Minibatch Loss= 12.629837
# Train Batch Evaluation
# AUC = 0.600 vs. 0.314
# F1 = 0.573 vs. 0.479
# Precision = 0.640 vs. 0.315
# Recall = 0.519 vs. 0.999
# Validation
# AUC = 0.436 vs. 0.191
# F1 = 0.512 vs. 0.320
# Precision = 0.477 vs. 0.191
# Recall = 0.552 vs. 0.989
# Minibatch Loss= 12.432093
# Train Batch Evaluation
# AUC = 0.601 vs. 0.312
# F1 = 0.575 vs. 0.479
# Precision = 0.642 vs. 0.315
# Recall = 0.520 vs. 0.997
# Validation
# AUC = 0.435 vs. 0.190
# F1 = 0.512 vs. 0.322
# Precision = 0.478 vs. 0.193
# Recall = 0.552 vs. 0.975
# Minibatch Loss= 12.240235
# Train Batch Evaluation
# AUC = 0.601 vs. 0.319
# F1 = 0.576 vs. 0.479
# Precision = 0.647 vs. 0.315
# Recall = 0.518 vs. 1.000
# Validation
# AUC = 0.440 vs. 0.199
# F1 = 0.514 vs. 0.321
# Precision = 0.479 vs. 0.191
# Recall = 0.555 vs. 1.000
# Minibatch Loss= 12.054087
# Train Batch Evaluation
# AUC = 0.602 vs. 0.307
# F1 = 0.577 vs. 0.479
# Precision = 0.651 vs. 0.315
# Recall = 0.519 vs. 1.000
# Validation
# AUC = 0.438 vs. 0.185
# F1 = 0.516 vs. 0.323
# Precision = 0.484 vs. 0.195
# Recall = 0.552 vs. 0.936
# Minibatch Loss= 11.873470
# Train Batch Evaluation
# AUC = 0.604 vs. 0.315
# F1 = 0.578 vs. 0.479
# Precision = 0.653 vs. 0.315
# Recall = 0.518 vs. 1.000
# Validation
# AUC = 0.439 vs. 0.205
# F1 = 0.517 vs. 0.321
# Precision = 0.447 vs. 0.191
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 11.698199
# Train Batch Evaluation
# AUC = 0.605 vs. 0.309
# F1 = 0.579 vs. 0.479
# Precision = 0.665 vs. 0.315
# Recall = 0.512 vs. 0.999
# Validation
# AUC = 0.446 vs. 0.186
# F1 = 0.517 vs. 0.323
# Precision = 0.494 vs. 0.193
# Recall = 0.543 vs. 0.989
# Minibatch Loss= 11.528091
# Train Batch Evaluation
# AUC = 0.604 vs. 0.315
# F1 = 0.579 vs. 0.479
# Precision = 0.665 vs. 0.315
# Recall = 0.513 vs. 1.000
# Validation
# AUC = 0.444 vs. 0.188
# F1 = 0.518 vs. 0.321
# Precision = 0.447 vs. 0.191
# Recall = 0.616 vs. 0.989
# Minibatch Loss= 11.362969
# Train Batch Evaluation
# AUC = 0.606 vs. 0.310
# F1 = 0.581 vs. 0.479
# Precision = 0.663 vs. 0.315
# Recall = 0.517 vs. 1.000
# Validation
# AUC = 0.446 vs. 0.194
# F1 = 0.521 vs. 0.321
# Precision = 0.458 vs. 0.191
# Recall = 0.602 vs. 1.000
# Minibatch Loss= 11.202658
# Train Batch Evaluation
# AUC = 0.607 vs. 0.321
# F1 = 0.582 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.514 vs. 1.000
# Validation
# AUC = 0.451 vs. 0.189
# F1 = 0.524 vs. 0.320
# Precision = 0.461 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 11.046993
# Train Batch Evaluation
# AUC = 0.608 vs. 0.322
# F1 = 0.583 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.514 vs. 0.997
# Validation
# AUC = 0.453 vs. 0.210
# F1 = 0.525 vs. 0.327
# Precision = 0.463 vs. 0.200
# Recall = 0.608 vs. 0.888
# Minibatch Loss= 10.895823
# Train Batch Evaluation
# AUC = 0.609 vs. 0.310
# F1 = 0.584 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.518 vs. 1.000
# Validation
# AUC = 0.450 vs. 0.193
# F1 = 0.528 vs. 0.323
# Precision = 0.467 vs. 0.194
# Recall = 0.608 vs. 0.952
# Minibatch Loss= 10.748993
# Train Batch Evaluation
# AUC = 0.609 vs. 0.320
# F1 = 0.585 vs. 0.479
# Precision = 0.674 vs. 0.316
# Recall = 0.517 vs. 0.997
# Validation
# AUC = 0.460 vs. 0.202
# F1 = 0.530 vs. 0.323
# Precision = 0.472 vs. 0.194
# Recall = 0.605 vs. 0.972
# Minibatch Loss= 10.606353
# Train Batch Evaluation
# AUC = 0.611 vs. 0.316
# F1 = 0.586 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.518 vs. 1.000
# Validation
# AUC = 0.461 vs. 0.210
# F1 = 0.531 vs. 0.322
# Precision = 0.472 vs. 0.194
# Recall = 0.608 vs. 0.941
# Minibatch Loss= 10.467752
# Train Batch Evaluation
# AUC = 0.610 vs. 0.321
# F1 = 0.586 vs. 0.479
# Precision = 0.667 vs. 0.315
# Recall = 0.523 vs. 1.000
# Validation
# AUC = 0.465 vs. 0.187
# F1 = 0.531 vs. 0.321
# Precision = 0.473 vs. 0.191
# Recall = 0.605 vs. 1.000
# Minibatch Loss= 10.333040
# Train Batch Evaluation
# AUC = 0.612 vs. 0.322
# F1 = 0.588 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.524 vs. 1.000
# Validation
# AUC = 0.457 vs. 0.191
# F1 = 0.532 vs. 0.321
# Precision = 0.472 vs. 0.194
# Recall = 0.611 vs. 0.938
# Minibatch Loss= 10.202072
# Train Batch Evaluation
# AUC = 0.610 vs. 0.316
# F1 = 0.588 vs. 0.479
# Precision = 0.665 vs. 0.315
# Recall = 0.527 vs. 1.000
# Validation
# AUC = 0.468 vs. 0.203
# F1 = 0.533 vs. 0.324
# Precision = 0.473 vs. 0.194
# Recall = 0.611 vs. 0.980
# Minibatch Loss= 10.074706
# Train Batch Evaluation
# AUC = 0.613 vs. 0.317
# F1 = 0.589 vs. 0.479
# Precision = 0.668 vs. 0.315
# Recall = 0.527 vs. 1.000
# Validation
# AUC = 0.461 vs. 0.197
# F1 = 0.533 vs. 0.321
# Precision = 0.470 vs. 0.191
# Recall = 0.616 vs. 0.992
# Minibatch Loss= 9.950814
# Train Batch Evaluation
# AUC = 0.613 vs. 0.311
# F1 = 0.591 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.528 vs. 0.998
# Validation
# AUC = 0.467 vs. 0.188
# F1 = 0.535 vs. 0.322
# Precision = 0.473 vs. 0.193
# Recall = 0.616 vs. 0.969
# Minibatch Loss= 9.830276
# Train Batch Evaluation
# AUC = 0.610 vs. 0.311
# F1 = 0.591 vs. 0.479
# Precision = 0.668 vs. 0.315
# Recall = 0.529 vs. 0.999
# Validation
# AUC = 0.465 vs. 0.188
# F1 = 0.535 vs. 0.325
# Precision = 0.473 vs. 0.197
# Recall = 0.616 vs. 0.944
# Minibatch Loss= 9.712980
# Train Batch Evaluation
# AUC = 0.614 vs. 0.310
# F1 = 0.591 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.529 vs. 1.000
# Validation
# AUC = 0.457 vs. 0.177
# F1 = 0.536 vs. 0.321
# Precision = 0.472 vs. 0.191
# Recall = 0.619 vs. 1.000
# Minibatch Loss= 9.598824
# Train Batch Evaluation
# AUC = 0.615 vs. 0.318
# F1 = 0.592 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.530 vs. 1.000
# Validation
# AUC = 0.466 vs. 0.199
# F1 = 0.538 vs. 0.320
# Precision = 0.473 vs. 0.191
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 9.487712
# Train Batch Evaluation
# AUC = 0.610 vs. 0.317
# F1 = 0.592 vs. 0.479
# Precision = 0.668 vs. 0.315
# Recall = 0.532 vs. 0.998
# Validation
# AUC = 0.465 vs. 0.200
# F1 = 0.538 vs. 0.320
# Precision = 0.475 vs. 0.191
# Recall = 0.619 vs. 1.000
# Minibatch Loss= 9.379556
# Train Batch Evaluation
# AUC = 0.614 vs. 0.314
# F1 = 0.592 vs. 0.479
# Precision = 0.670 vs. 0.316
# Recall = 0.531 vs. 0.997
# Validation
# AUC = 0.472 vs. 0.186
# F1 = 0.538 vs. 0.321
# Precision = 0.475 vs. 0.192
# Recall = 0.619 vs. 1.000
# Minibatch Loss= 9.274265
# Train Batch Evaluation
# AUC = 0.612 vs. 0.310
# F1 = 0.593 vs. 0.480
# Precision = 0.670 vs. 0.316
# Recall = 0.531 vs. 0.998
# Validation
# AUC = 0.482 vs. 0.207
# F1 = 0.538 vs. 0.320
# Precision = 0.474 vs. 0.191
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 9.171757
# Train Batch Evaluation
# AUC = 0.610 vs. 0.312
# F1 = 0.593 vs. 0.479
# Precision = 0.664 vs. 0.315
# Recall = 0.536 vs. 0.999
# Validation
# AUC = 0.470 vs. 0.190
# F1 = 0.538 vs. 0.321
# Precision = 0.476 vs. 0.191
# Recall = 0.619 vs. 1.000
# Minibatch Loss= 9.071942
# Train Batch Evaluation
# AUC = 0.610 vs. 0.316
# F1 = 0.594 vs. 0.479
# Precision = 0.667 vs. 0.315
# Recall = 0.535 vs. 1.000
# Validation
# AUC = 0.469 vs. 0.191
# F1 = 0.538 vs. 0.322
# Precision = 0.476 vs. 0.192
# Recall = 0.619 vs. 0.989
# Minibatch Loss= 8.974736
# Train Batch Evaluation
# AUC = 0.613 vs. 0.321
# F1 = 0.594 vs. 0.479
# Precision = 0.666 vs. 0.316
# Recall = 0.537 vs. 0.994
# Validation
# AUC = 0.479 vs. 0.186
# F1 = 0.540 vs. 0.325
# Precision = 0.480 vs. 0.195
# Recall = 0.616 vs. 0.983
# Minibatch Loss= 8.880052
# Train Batch Evaluation
# AUC = 0.610 vs. 0.316
# F1 = 0.595 vs. 0.479
# Precision = 0.667 vs. 0.315
# Recall = 0.537 vs. 1.000
# Validation
# AUC = 0.481 vs. 0.184
# F1 = 0.543 vs. 0.322
# Precision = 0.486 vs. 0.192
# Recall = 0.616 vs. 0.992
# Minibatch Loss= 8.787804
# Train Batch Evaluation
# AUC = 0.610 vs. 0.306
# F1 = 0.595 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.535 vs. 1.000
# Validation
# AUC = 0.463 vs. 0.188
# F1 = 0.543 vs. 0.322
# Precision = 0.485 vs. 0.192
# Recall = 0.616 vs. 1.000
# Minibatch Loss= 8.697913
# Train Batch Evaluation
# AUC = 0.610 vs. 0.312
# F1 = 0.596 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.537 vs. 0.999
# Validation
# AUC = 0.489 vs. 0.191
# F1 = 0.543 vs. 0.322
# Precision = 0.487 vs. 0.193
# Recall = 0.613 vs. 0.969
# Minibatch Loss= 8.610302
# Train Batch Evaluation
# AUC = 0.608 vs. 0.314
# F1 = 0.596 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.537 vs. 0.998
# Validation
# AUC = 0.490 vs. 0.208
# F1 = 0.544 vs. 0.320
# Precision = 0.489 vs. 0.191
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 8.524896
# Train Batch Evaluation
# AUC = 0.610 vs. 0.308
# F1 = 0.596 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.537 vs. 1.000
# Validation
# AUC = 0.486 vs. 0.187
# F1 = 0.545 vs. 0.322
# Precision = 0.494 vs. 0.192
# Recall = 0.608 vs. 0.994
# Minibatch Loss= 8.441629
# Train Batch Evaluation
# AUC = 0.610 vs. 0.313
# F1 = 0.597 vs. 0.479
# Precision = 0.672 vs. 0.315
# Recall = 0.536 vs. 0.999
# Validation
# AUC = 0.476 vs. 0.213
# F1 = 0.547 vs. 0.333
# Precision = 0.493 vs. 0.209
# Recall = 0.613 vs. 0.818
# Minibatch Loss= 8.360438
# Train Batch Evaluation
# AUC = 0.610 vs. 0.313
# F1 = 0.597 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.535 vs. 1.000
# Validation
# AUC = 0.488 vs. 0.201
# F1 = 0.547 vs. 0.321
# Precision = 0.493 vs. 0.191
# Recall = 0.613 vs. 0.997
# Minibatch Loss= 8.281263
# Train Batch Evaluation
# AUC = 0.605 vs. 0.308
# F1 = 0.597 vs. 0.479
# Precision = 0.679 vs. 0.315
# Recall = 0.532 vs. 1.000
# Validation
# AUC = 0.476 vs. 0.192
# F1 = 0.547 vs. 0.322
# Precision = 0.494 vs. 0.193
# Recall = 0.613 vs. 0.980
# Minibatch Loss= 8.204049
# Train Batch Evaluation
# AUC = 0.604 vs. 0.321
# F1 = 0.597 vs. 0.479
# Precision = 0.676 vs. 0.315
# Recall = 0.534 vs. 0.999
# Validation
# AUC = 0.485 vs. 0.185
# F1 = 0.548 vs. 0.323
# Precision = 0.498 vs. 0.192
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 8.128739
# Train Batch Evaluation
# AUC = 0.609 vs. 0.326
# F1 = 0.597 vs. 0.479
# Precision = 0.677 vs. 0.315
# Recall = 0.534 vs. 1.000
# Validation
# AUC = 0.473 vs. 0.184
# F1 = 0.548 vs. 0.323
# Precision = 0.498 vs. 0.196
# Recall = 0.611 vs. 0.930
# Minibatch Loss= 8.055283
# Train Batch Evaluation
# AUC = 0.605 vs. 0.318
# F1 = 0.597 vs. 0.479
# Precision = 0.678 vs. 0.316
# Recall = 0.534 vs. 0.995
# Validation
# AUC = 0.476 vs. 0.201
# F1 = 0.550 vs. 0.321
# Precision = 0.499 vs. 0.191
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 7.983628
# Train Batch Evaluation
# AUC = 0.607 vs. 0.314
# F1 = 0.597 vs. 0.479
# Precision = 0.680 vs. 0.315
# Recall = 0.533 vs. 1.000
# Validation
# AUC = 0.488 vs. 0.196
# F1 = 0.550 vs. 0.321
# Precision = 0.499 vs. 0.191
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 7.913729
# Train Batch Evaluation
# AUC = 0.606 vs. 0.308
# F1 = 0.598 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.538 vs. 0.999
# Validation
# AUC = 0.483 vs. 0.187
# F1 = 0.551 vs. 0.323
# Precision = 0.502 vs. 0.193
# Recall = 0.611 vs. 0.980
# Minibatch Loss= 7.845540
# Train Batch Evaluation
# AUC = 0.605 vs. 0.310
# F1 = 0.598 vs. 0.479
# Precision = 0.672 vs. 0.315
# Recall = 0.538 vs. 1.000
# Validation
# AUC = 0.490 vs. 0.190
# F1 = 0.551 vs. 0.322
# Precision = 0.500 vs. 0.192
# Recall = 0.613 vs. 0.997
# Minibatch Loss= 7.779016
# Train Batch Evaluation
# AUC = 0.598 vs. 0.318
# F1 = 0.598 vs. 0.479
# Precision = 0.672 vs. 0.316
# Recall = 0.538 vs. 0.997
# Validation
# AUC = 0.495 vs. 0.199
# F1 = 0.551 vs. 0.321
# Precision = 0.502 vs. 0.191
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 7.714122
# Train Batch Evaluation
# AUC = 0.602 vs. 0.317
# F1 = 0.598 vs. 0.479
# Precision = 0.668 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.497 vs. 0.208
# F1 = 0.552 vs. 0.325
# Precision = 0.503 vs. 0.201
# Recall = 0.611 vs. 0.852
# Minibatch Loss= 7.650820
# Train Batch Evaluation
# AUC = 0.595 vs. 0.317
# F1 = 0.598 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.491 vs. 0.190
# F1 = 0.552 vs. 0.321
# Precision = 0.503 vs. 0.192
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 7.589076
# Train Batch Evaluation
# AUC = 0.605 vs. 0.317
# F1 = 0.599 vs. 0.479
# Precision = 0.664 vs. 0.316
# Recall = 0.545 vs. 0.993
# Validation
# AUC = 0.488 vs. 0.184
# F1 = 0.552 vs. 0.321
# Precision = 0.503 vs. 0.192
# Recall = 0.611 vs. 0.997
# Minibatch Loss= 7.528859
# Train Batch Evaluation
# AUC = 0.607 vs. 0.313
# F1 = 0.599 vs. 0.479
# Precision = 0.665 vs. 0.315
# Recall = 0.545 vs. 1.000
# Validation
# AUC = 0.523 vs. 0.192
# F1 = 0.552 vs. 0.322
# Precision = 0.500 vs. 0.192
# Recall = 0.616 vs. 0.997
# Minibatch Loss= 7.470140
# Train Batch Evaluation
# AUC = 0.602 vs. 0.314
# F1 = 0.599 vs. 0.479
# Precision = 0.667 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.487 vs. 0.192
# F1 = 0.553 vs. 0.324
# Precision = 0.503 vs. 0.196
# Recall = 0.613 vs. 0.938
# Minibatch Loss= 7.412889
# Train Batch Evaluation
# AUC = 0.606 vs. 0.312
# F1 = 0.600 vs. 0.480
# Precision = 0.669 vs. 0.316
# Recall = 0.543 vs. 0.998
# Validation
# AUC = 0.502 vs. 0.188
# F1 = 0.552 vs. 0.321
# Precision = 0.502 vs. 0.192
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 7.357080
# Train Batch Evaluation
# AUC = 0.604 vs. 0.309
# F1 = 0.600 vs. 0.479
# Precision = 0.667 vs. 0.315
# Recall = 0.545 vs. 0.999
# Validation
# AUC = 0.519 vs. 0.204
# F1 = 0.552 vs. 0.321
# Precision = 0.500 vs. 0.193
# Recall = 0.616 vs. 0.958
# Minibatch Loss= 7.302684
# Train Batch Evaluation
# AUC = 0.607 vs. 0.319
# F1 = 0.601 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.545 vs. 1.000
# Validation
# AUC = 0.514 vs. 0.210
# F1 = 0.553 vs. 0.323
# Precision = 0.511 vs. 0.193
# Recall = 0.602 vs. 0.980
# Minibatch Loss= 7.249673
# Train Batch Evaluation
# AUC = 0.607 vs. 0.315
# F1 = 0.601 vs. 0.479
# Precision = 0.672 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.492 vs. 0.184
# F1 = 0.553 vs. 0.321
# Precision = 0.511 vs. 0.191
# Recall = 0.602 vs. 0.992
# Minibatch Loss= 7.198020
# Train Batch Evaluation
# AUC = 0.604 vs. 0.328
# F1 = 0.601 vs. 0.479
# Precision = 0.667 vs. 0.315
# Recall = 0.547 vs. 1.000
# Validation
# AUC = 0.510 vs. 0.195
# F1 = 0.553 vs. 0.320
# Precision = 0.513 vs. 0.191
# Recall = 0.599 vs. 0.997
# Minibatch Loss= 7.147697
# Train Batch Evaluation
# AUC = 0.609 vs. 0.312
# F1 = 0.601 vs. 0.479
# Precision = 0.676 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.475 vs. 0.202
# F1 = 0.554 vs. 0.323
# Precision = 0.516 vs. 0.194
# Recall = 0.599 vs. 0.966
# Minibatch Loss= 7.098673
# Train Batch Evaluation
# AUC = 0.607 vs. 0.312
# F1 = 0.601 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.475 vs. 0.182
# F1 = 0.555 vs. 0.322
# Precision = 0.521 vs. 0.193
# Recall = 0.594 vs. 0.975
# Minibatch Loss= 7.050919
# Train Batch Evaluation
# AUC = 0.603 vs. 0.319
# F1 = 0.602 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.513 vs. 0.200
# F1 = 0.558 vs. 0.322
# Precision = 0.525 vs. 0.194
# Recall = 0.597 vs. 0.950
# Minibatch Loss= 7.004403
# Train Batch Evaluation
# AUC = 0.606 vs. 0.310
# F1 = 0.602 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.544 vs. 0.998
# Validation
# AUC = 0.506 vs. 0.186
# F1 = 0.559 vs. 0.321
# Precision = 0.525 vs. 0.191
# Recall = 0.599 vs. 0.997
# Minibatch Loss= 6.959095
# Train Batch Evaluation
# AUC = 0.605 vs. 0.314
# F1 = 0.603 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.545 vs. 0.998
# Validation
# AUC = 0.485 vs. 0.193
# F1 = 0.560 vs. 0.321
# Precision = 0.526 vs. 0.191
# Recall = 0.599 vs. 1.000
# Minibatch Loss= 6.914966
# Train Batch Evaluation
# AUC = 0.605 vs. 0.326
# F1 = 0.602 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.545 vs. 1.000
# Validation
# AUC = 0.488 vs. 0.183
# F1 = 0.560 vs. 0.323
# Precision = 0.526 vs. 0.194
# Recall = 0.599 vs. 0.969
# Minibatch Loss= 6.871981
# Train Batch Evaluation
# AUC = 0.605 vs. 0.313
# F1 = 0.603 vs. 0.480
# Precision = 0.674 vs. 0.316
# Recall = 0.545 vs. 0.998
# Validation
# AUC = 0.508 vs. 0.203
# F1 = 0.561 vs. 0.324
# Precision = 0.520 vs. 0.194
# Recall = 0.608 vs. 0.983
# Minibatch Loss= 6.830110
# Train Batch Evaluation
# AUC = 0.602 vs. 0.321
# F1 = 0.603 vs. 0.479
# Precision = 0.678 vs. 0.315
# Recall = 0.542 vs. 1.000
# Validation
# AUC = 0.498 vs. 0.206
# F1 = 0.561 vs. 0.326
# Precision = 0.529 vs. 0.195
# Recall = 0.597 vs. 0.994
# Minibatch Loss= 6.789321
# Train Batch Evaluation
# AUC = 0.600 vs. 0.308
# F1 = 0.603 vs. 0.479
# Precision = 0.678 vs. 0.316
# Recall = 0.543 vs. 0.998
# Validation
# AUC = 0.510 vs. 0.186
# F1 = 0.561 vs. 0.321
# Precision = 0.530 vs. 0.191
# Recall = 0.597 vs. 0.994
# Minibatch Loss= 6.749585
# Train Batch Evaluation
# AUC = 0.595 vs. 0.317
# F1 = 0.603 vs. 0.479
# Precision = 0.678 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.507 vs. 0.204
# F1 = 0.563 vs. 0.326
# Precision = 0.531 vs. 0.205
# Recall = 0.599 vs. 0.787
# Minibatch Loss= 6.710869
# Train Batch Evaluation
# AUC = 0.597 vs. 0.311
# F1 = 0.603 vs. 0.479
# Precision = 0.678 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.508 vs. 0.201
# F1 = 0.565 vs. 0.324
# Precision = 0.532 vs. 0.194
# Recall = 0.602 vs. 0.983
# Minibatch Loss= 6.673145
# Train Batch Evaluation
# AUC = 0.606 vs. 0.306
# F1 = 0.603 vs. 0.480
# Precision = 0.676 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.522 vs. 0.182
# F1 = 0.566 vs. 0.321
# Precision = 0.533 vs. 0.193
# Recall = 0.602 vs. 0.964
# Minibatch Loss= 6.636387
# Train Batch Evaluation
# AUC = 0.603 vs. 0.311
# F1 = 0.603 vs. 0.480
# Precision = 0.677 vs. 0.316
# Recall = 0.543 vs. 0.998
# Validation
# AUC = 0.518 vs. 0.213
# F1 = 0.567 vs. 0.321
# Precision = 0.536 vs. 0.191
# Recall = 0.602 vs. 0.997
# Minibatch Loss= 6.600567
# Train Batch Evaluation
# AUC = 0.605 vs. 0.315
# F1 = 0.603 vs. 0.479
# Precision = 0.676 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.473 vs. 0.181
# F1 = 0.567 vs. 0.323
# Precision = 0.536 vs. 0.193
# Recall = 0.602 vs. 0.983
# Minibatch Loss= 6.565660
# Train Batch Evaluation
# AUC = 0.597 vs. 0.316
# F1 = 0.602 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.544 vs. 0.999
# Validation
# AUC = 0.534 vs. 0.198
# F1 = 0.568 vs. 0.322
# Precision = 0.539 vs. 0.194
# Recall = 0.599 vs. 0.952
# Minibatch Loss= 6.531643
# Train Batch Evaluation
# AUC = 0.605 vs. 0.312
# F1 = 0.602 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.477 vs. 0.182
# F1 = 0.568 vs. 0.320
# Precision = 0.539 vs. 0.191
# Recall = 0.599 vs. 1.000
# Minibatch Loss= 6.498495
# Train Batch Evaluation
# AUC = 0.599 vs. 0.322
# F1 = 0.602 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.488 vs. 0.198
# F1 = 0.569 vs. 0.323
# Precision = 0.539 vs. 0.194
# Recall = 0.602 vs. 0.950
# Minibatch Loss= 6.466192
# Train Batch Evaluation
# AUC = 0.591 vs. 0.318
# F1 = 0.602 vs. 0.480
# Precision = 0.670 vs. 0.316
# Recall = 0.546 vs. 0.995
# Validation
# AUC = 0.477 vs. 0.186
# F1 = 0.568 vs. 0.321
# Precision = 0.540 vs. 0.191
# Recall = 0.599 vs. 1.000
# Minibatch Loss= 6.434719
# Train Batch Evaluation
# AUC = 0.597 vs. 0.310
# F1 = 0.602 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.546 vs. 1.000
# Validation
# AUC = 0.499 vs. 0.201
# F1 = 0.569 vs. 0.322
# Precision = 0.537 vs. 0.198
# Recall = 0.605 vs. 0.857
# Minibatch Loss= 6.404055
# Train Batch Evaluation
# AUC = 0.593 vs. 0.318
# F1 = 0.602 vs. 0.479
# Precision = 0.670 vs. 0.315
# Recall = 0.546 vs. 1.000
# Validation
# AUC = 0.493 vs. 0.199
# F1 = 0.569 vs. 0.325
# Precision = 0.537 vs. 0.195
# Recall = 0.605 vs. 0.986
# Minibatch Loss= 6.374182
# Train Batch Evaluation
# AUC = 0.598 vs. 0.313
# F1 = 0.602 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.545 vs. 1.000
# Validation
# AUC = 0.477 vs. 0.181
# F1 = 0.569 vs. 0.321
# Precision = 0.537 vs. 0.191
# Recall = 0.605 vs. 1.000
# Minibatch Loss= 6.345083
# Train Batch Evaluation
# AUC = 0.595 vs. 0.314
# F1 = 0.602 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.545 vs. 1.000
# Validation
# AUC = 0.478 vs. 0.200
# F1 = 0.569 vs. 0.321
# Precision = 0.534 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 6.316741
# Train Batch Evaluation
# AUC = 0.594 vs. 0.330
# F1 = 0.602 vs. 0.479
# Precision = 0.672 vs. 0.315
# Recall = 0.545 vs. 1.000
# Validation
# AUC = 0.495 vs. 0.181
# F1 = 0.570 vs. 0.320
# Precision = 0.536 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 6.289137
# Train Batch Evaluation
# AUC = 0.591 vs. 0.318
# F1 = 0.602 vs. 0.479
# Precision = 0.666 vs. 0.315
# Recall = 0.548 vs. 1.000
# Validation
# AUC = 0.496 vs. 0.183
# F1 = 0.570 vs. 0.323
# Precision = 0.546 vs. 0.193
# Recall = 0.597 vs. 0.992
# Minibatch Loss= 6.262256
# Train Batch Evaluation
# AUC = 0.598 vs. 0.306
# F1 = 0.602 vs. 0.479
# Precision = 0.666 vs. 0.315
# Recall = 0.549 vs. 1.000
# Validation
# AUC = 0.484 vs. 0.227
# F1 = 0.571 vs. 0.330
# Precision = 0.548 vs. 0.210
# Recall = 0.597 vs. 0.776
# Minibatch Loss= 6.236079
# Train Batch Evaluation
# AUC = 0.595 vs. 0.312
# F1 = 0.602 vs. 0.479
# Precision = 0.661 vs. 0.315
# Recall = 0.553 vs. 0.999
# Validation
# AUC = 0.515 vs. 0.183
# F1 = 0.571 vs. 0.323
# Precision = 0.548 vs. 0.193
# Recall = 0.597 vs. 0.989
# Minibatch Loss= 6.210588
# Train Batch Evaluation
# AUC = 0.601 vs. 0.320
# F1 = 0.602 vs. 0.479
# Precision = 0.660 vs. 0.315
# Recall = 0.553 vs. 1.000
# Validation
# AUC = 0.510 vs. 0.210
# F1 = 0.570 vs. 0.322
# Precision = 0.546 vs. 0.192
# Recall = 0.597 vs. 0.994
# Minibatch Loss= 6.185766
# Train Batch Evaluation
# AUC = 0.589 vs. 0.326
# F1 = 0.602 vs. 0.479
# Precision = 0.660 vs. 0.315
# Recall = 0.553 vs. 1.000
# Validation
# AUC = 0.490 vs. 0.192
# F1 = 0.571 vs. 0.320
# Precision = 0.548 vs. 0.191
# Recall = 0.597 vs. 1.000
# Minibatch Loss= 6.161593
# Train Batch Evaluation
# AUC = 0.593 vs. 0.323
# F1 = 0.602 vs. 0.479
# Precision = 0.660 vs. 0.315
# Recall = 0.554 vs. 1.000
# Validation
# AUC = 0.493 vs. 0.208
# F1 = 0.571 vs. 0.325
# Precision = 0.551 vs. 0.195
# Recall = 0.594 vs. 0.972
# Minibatch Loss= 6.138050
# Train Batch Evaluation
# AUC = 0.592 vs. 0.313
# F1 = 0.602 vs. 0.479
# Precision = 0.661 vs. 0.315
# Recall = 0.553 vs. 0.999
# Validation
# AUC = 0.512 vs. 0.189
# F1 = 0.573 vs. 0.321
# Precision = 0.550 vs. 0.191
# Recall = 0.597 vs. 1.000
# Minibatch Loss= 6.115118
# Train Batch Evaluation
# AUC = 0.600 vs. 0.316
# F1 = 0.602 vs. 0.479
# Precision = 0.661 vs. 0.315
# Recall = 0.553 vs. 0.999
# Validation
# AUC = 0.508 vs. 0.178
# F1 = 0.573 vs. 0.321
# Precision = 0.550 vs. 0.192
# Recall = 0.597 vs. 0.983
# Minibatch Loss= 6.092777
# Train Batch Evaluation
# AUC = 0.600 vs. 0.310
# F1 = 0.602 vs. 0.479
# Precision = 0.661 vs. 0.315
# Recall = 0.553 vs. 1.000
# Validation
# AUC = 0.494 vs. 0.183
# F1 = 0.573 vs. 0.322
# Precision = 0.549 vs. 0.193
# Recall = 0.599 vs. 0.978
# Minibatch Loss= 6.071008
# Train Batch Evaluation
# AUC = 0.600 vs. 0.311
# F1 = 0.602 vs. 0.480
# Precision = 0.662 vs. 0.316
# Recall = 0.552 vs. 0.999
# Validation
# AUC = 0.473 vs. 0.188
# F1 = 0.573 vs. 0.322
# Precision = 0.552 vs. 0.194
# Recall = 0.597 vs. 0.961
# Minibatch Loss= 6.049790
# Train Batch Evaluation
# AUC = 0.591 vs. 0.315
# F1 = 0.602 vs. 0.479
# Precision = 0.662 vs. 0.315
# Recall = 0.552 vs. 1.000
# Validation
# AUC = 0.496 vs. 0.204
# F1 = 0.573 vs. 0.324
# Precision = 0.552 vs. 0.198
# Recall = 0.597 vs. 0.885
# Minibatch Loss= 6.029105
# Train Batch Evaluation
# AUC = 0.591 vs. 0.319
# F1 = 0.602 vs. 0.479
# Precision = 0.662 vs. 0.315
# Recall = 0.552 vs. 0.999
# Validation
# AUC = 0.495 vs. 0.192
# F1 = 0.573 vs. 0.322
# Precision = 0.552 vs. 0.194
# Recall = 0.597 vs. 0.933
# Minibatch Loss= 6.008929
# Train Batch Evaluation
# AUC = 0.585 vs. 0.315
# F1 = 0.602 vs. 0.479
# Precision = 0.662 vs. 0.315
# Recall = 0.552 vs. 0.999
# Validation
# AUC = 0.509 vs. 0.181
# F1 = 0.574 vs. 0.320
# Precision = 0.550 vs. 0.191
# Recall = 0.599 vs. 1.000
# Minibatch Loss= 5.989247
# Train Batch Evaluation
# AUC = 0.590 vs. 0.320
# F1 = 0.602 vs. 0.479
# Precision = 0.670 vs. 0.315
# Recall = 0.546 vs. 1.000
# Validation
# AUC = 0.518 vs. 0.191
# F1 = 0.574 vs. 0.325
# Precision = 0.548 vs. 0.200
# Recall = 0.602 vs. 0.866
# Minibatch Loss= 5.970036
# Train Batch Evaluation
# AUC = 0.596 vs. 0.314
# F1 = 0.602 vs. 0.479
# Precision = 0.669 vs. 0.315
# Recall = 0.546 vs. 0.999
# Validation
# AUC = 0.520 vs. 0.182
# F1 = 0.574 vs. 0.323
# Precision = 0.548 vs. 0.193
# Recall = 0.602 vs. 0.994
# Minibatch Loss= 5.951277
# Train Batch Evaluation
# AUC = 0.591 vs. 0.315
# F1 = 0.602 vs. 0.479
# Precision = 0.670 vs. 0.315
# Recall = 0.546 vs. 1.000
# Validation
# AUC = 0.497 vs. 0.188
# F1 = 0.575 vs. 0.322
# Precision = 0.545 vs. 0.192
# Recall = 0.608 vs. 0.980
# Minibatch Loss= 5.932951
# Train Batch Evaluation
# AUC = 0.588 vs. 0.316
# F1 = 0.602 vs. 0.479
# Precision = 0.670 vs. 0.315
# Recall = 0.546 vs. 1.000
# Validation
# AUC = 0.492 vs. 0.205
# F1 = 0.575 vs. 0.323
# Precision = 0.545 vs. 0.198
# Recall = 0.608 vs. 0.866
# Minibatch Loss= 5.915040
# Train Batch Evaluation
# AUC = 0.588 vs. 0.314
# F1 = 0.602 vs. 0.479
# Precision = 0.670 vs. 0.315
# Recall = 0.546 vs. 1.000
# Validation
# AUC = 0.492 vs. 0.186
# F1 = 0.575 vs. 0.320
# Precision = 0.545 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 5.897523
# Train Batch Evaluation
# AUC = 0.590 vs. 0.319
# F1 = 0.602 vs. 0.479
# Precision = 0.670 vs. 0.316
# Recall = 0.546 vs. 0.991
# Validation
# AUC = 0.504 vs. 0.201
# F1 = 0.575 vs. 0.320
# Precision = 0.545 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 5.880383
# Train Batch Evaluation
# AUC = 0.588 vs. 0.322
# F1 = 0.601 vs. 0.479
# Precision = 0.681 vs. 0.315
# Recall = 0.538 vs. 1.000
# Validation
# AUC = 0.508 vs. 0.198
# F1 = 0.575 vs. 0.321
# Precision = 0.545 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 5.863602
# Train Batch Evaluation
# AUC = 0.589 vs. 0.311
# F1 = 0.601 vs. 0.480
# Precision = 0.682 vs. 0.315
# Recall = 0.538 vs. 1.000
# Validation
# AUC = 0.504 vs. 0.183
# F1 = 0.575 vs. 0.320
# Precision = 0.544 vs. 0.191
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 5.847162
# Train Batch Evaluation
# AUC = 0.588 vs. 0.319
# F1 = 0.601 vs. 0.480
# Precision = 0.681 vs. 0.316
# Recall = 0.538 vs. 0.999
# Validation
# AUC = 0.497 vs. 0.202
# F1 = 0.575 vs. 0.325
# Precision = 0.544 vs. 0.195
# Recall = 0.611 vs. 0.978
# Minibatch Loss= 5.831044
# Train Batch Evaluation
# AUC = 0.587 vs. 0.314
# F1 = 0.601 vs. 0.479
# Precision = 0.680 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.498 vs. 0.186
# F1 = 0.576 vs. 0.323
# Precision = 0.545 vs. 0.193
# Recall = 0.611 vs. 0.986
# Minibatch Loss= 5.815234
# Train Batch Evaluation
# AUC = 0.590 vs. 0.309
# F1 = 0.601 vs. 0.479
# Precision = 0.679 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.500 vs. 0.193
# F1 = 0.576 vs. 0.320
# Precision = 0.548 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 5.799713
# Train Batch Evaluation
# AUC = 0.581 vs. 0.312
# F1 = 0.601 vs. 0.479
# Precision = 0.679 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.488 vs. 0.206
# F1 = 0.576 vs. 0.323
# Precision = 0.548 vs. 0.194
# Recall = 0.608 vs. 0.966
# Minibatch Loss= 5.784466
# Train Batch Evaluation
# AUC = 0.591 vs. 0.314
# F1 = 0.601 vs. 0.479
# Precision = 0.678 vs. 0.315
# Recall = 0.540 vs. 0.999
# Validation
# AUC = 0.506 vs. 0.204
# F1 = 0.577 vs. 0.321
# Precision = 0.549 vs. 0.192
# Recall = 0.608 vs. 0.989
# Minibatch Loss= 5.769477
# Train Batch Evaluation
# AUC = 0.592 vs. 0.319
# F1 = 0.601 vs. 0.479
# Precision = 0.677 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.506 vs. 0.179
# F1 = 0.577 vs. 0.321
# Precision = 0.549 vs. 0.191
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 5.754732
# Train Batch Evaluation
# AUC = 0.593 vs. 0.320
# F1 = 0.602 vs. 0.479
# Precision = 0.677 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.496 vs. 0.214
# F1 = 0.577 vs. 0.332
# Precision = 0.549 vs. 0.205
# Recall = 0.608 vs. 0.885
# Minibatch Loss= 5.740214
# Train Batch Evaluation
# AUC = 0.593 vs. 0.323
# F1 = 0.602 vs. 0.480
# Precision = 0.678 vs. 0.317
# Recall = 0.541 vs. 0.986
# Validation
# AUC = 0.490 vs. 0.217
# F1 = 0.577 vs. 0.322
# Precision = 0.549 vs. 0.193
# Recall = 0.608 vs. 0.986
# Minibatch Loss= 5.725910
# Train Batch Evaluation
# AUC = 0.588 vs. 0.310
# F1 = 0.602 vs. 0.479
# Precision = 0.679 vs. 0.315
# Recall = 0.540 vs. 0.999
# Validation
# AUC = 0.511 vs. 0.182
# F1 = 0.578 vs. 0.321
# Precision = 0.549 vs. 0.192
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 5.711806
# Train Batch Evaluation
# AUC = 0.593 vs. 0.315
# F1 = 0.601 vs. 0.479
# Precision = 0.678 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.510 vs. 0.206
# F1 = 0.578 vs. 0.323
# Precision = 0.549 vs. 0.199
# Recall = 0.611 vs. 0.846
# Minibatch Loss= 5.697889
# Train Batch Evaluation
# AUC = 0.592 vs. 0.309
# F1 = 0.601 vs. 0.479
# Precision = 0.672 vs. 0.315
# Recall = 0.545 vs. 1.000
# Validation
# AUC = 0.480 vs. 0.198
# F1 = 0.578 vs. 0.324
# Precision = 0.549 vs. 0.196
# Recall = 0.611 vs. 0.950
# Minibatch Loss= 5.684145
# Train Batch Evaluation
# AUC = 0.592 vs. 0.318
# F1 = 0.601 vs. 0.479
# Precision = 0.671 vs. 0.315
# Recall = 0.545 vs. 0.998
# Validation
# AUC = 0.481 vs. 0.192
# F1 = 0.578 vs. 0.321
# Precision = 0.549 vs. 0.193
# Recall = 0.611 vs. 0.958
# Minibatch Loss= 5.670565
# Train Batch Evaluation
# AUC = 0.592 vs. 0.315
# F1 = 0.601 vs. 0.480
# Precision = 0.673 vs. 0.316
# Recall = 0.544 vs. 0.993
# Validation
# AUC = 0.508 vs. 0.186
# F1 = 0.579 vs. 0.322
# Precision = 0.549 vs. 0.193
# Recall = 0.613 vs. 0.966
# Minibatch Loss= 5.657133
# Train Batch Evaluation
# AUC = 0.591 vs. 0.313
# F1 = 0.602 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.508 vs. 0.194
# F1 = 0.579 vs. 0.320
# Precision = 0.549 vs. 0.191
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 5.643839
# Train Batch Evaluation
# AUC = 0.591 vs. 0.317
# F1 = 0.602 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.510 vs. 0.194
# F1 = 0.580 vs. 0.322
# Precision = 0.550 vs. 0.192
# Recall = 0.613 vs. 0.997
# Minibatch Loss= 5.630673
# Train Batch Evaluation
# AUC = 0.592 vs. 0.318
# F1 = 0.602 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.508 vs. 0.185
# F1 = 0.580 vs. 0.320
# Precision = 0.550 vs. 0.191
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 5.617625
# Train Batch Evaluation
# AUC = 0.590 vs. 0.312
# F1 = 0.601 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.510 vs. 0.214
# F1 = 0.579 vs. 0.321
# Precision = 0.547 vs. 0.192
# Recall = 0.613 vs. 0.994
# Minibatch Loss= 5.604684
# Train Batch Evaluation
# AUC = 0.595 vs. 0.314
# F1 = 0.601 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.544 vs. 1.000
# Validation
# AUC = 0.489 vs. 0.190
# F1 = 0.579 vs. 0.320
# Precision = 0.551 vs. 0.191
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 5.591842
# Train Batch Evaluation
# AUC = 0.591 vs. 0.315
# F1 = 0.601 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.504 vs. 0.188
# F1 = 0.579 vs. 0.322
# Precision = 0.551 vs. 0.192
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 5.579088
# Train Batch Evaluation
# AUC = 0.590 vs. 0.319
# F1 = 0.601 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.495 vs. 0.203
# F1 = 0.579 vs. 0.324
# Precision = 0.547 vs. 0.194
# Recall = 0.613 vs. 0.980
# Minibatch Loss= 5.566414
# Train Batch Evaluation
# AUC = 0.590 vs. 0.318
# F1 = 0.601 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.543 vs. 0.997
# Validation
# AUC = 0.498 vs. 0.207
# F1 = 0.579 vs. 0.323
# Precision = 0.549 vs. 0.199
# Recall = 0.613 vs. 0.849
# Minibatch Loss= 5.553814
# Train Batch Evaluation
# AUC = 0.590 vs. 0.315
# F1 = 0.601 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.543 vs. 0.998
# Validation
# AUC = 0.491 vs. 0.189
# F1 = 0.579 vs. 0.322
# Precision = 0.549 vs. 0.192
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 5.541278
# Train Batch Evaluation
# AUC = 0.589 vs. 0.314
# F1 = 0.601 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.491 vs. 0.196
# F1 = 0.578 vs. 0.321
# Precision = 0.549 vs. 0.191
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 5.528802
# Train Batch Evaluation
# AUC = 0.588 vs. 0.318
# F1 = 0.601 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.543 vs. 1.000
# Validation
# AUC = 0.513 vs. 0.194
# F1 = 0.578 vs. 0.321
# Precision = 0.549 vs. 0.192
# Recall = 0.611 vs. 0.980
# Minibatch Loss= 5.516376
# Train Batch Evaluation
# AUC = 0.587 vs. 0.313
# F1 = 0.601 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.542 vs. 1.000
# Validation
# AUC = 0.490 vs. 0.190
# F1 = 0.578 vs. 0.323
# Precision = 0.549 vs. 0.194
# Recall = 0.611 vs. 0.978
# Minibatch Loss= 5.503996
# Train Batch Evaluation
# AUC = 0.586 vs. 0.321
# F1 = 0.601 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.542 vs. 1.000
# Validation
# AUC = 0.491 vs. 0.192
# F1 = 0.578 vs. 0.321
# Precision = 0.549 vs. 0.191
# Recall = 0.611 vs. 0.997
# Minibatch Loss= 5.491656
# Train Batch Evaluation
# AUC = 0.581 vs. 0.318
# F1 = 0.601 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.542 vs. 1.000
# Validation
# AUC = 0.491 vs. 0.203
# F1 = 0.578 vs. 0.325
# Precision = 0.546 vs. 0.202
# Recall = 0.613 vs. 0.832
# Minibatch Loss= 5.479350
# Train Batch Evaluation
# AUC = 0.583 vs. 0.307
# F1 = 0.601 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.541 vs. 0.999
# Validation
# AUC = 0.468 vs. 0.178
# F1 = 0.577 vs. 0.322
# Precision = 0.549 vs. 0.192
# Recall = 0.608 vs. 0.989
# Minibatch Loss= 5.467072
# Train Batch Evaluation
# AUC = 0.585 vs. 0.313
# F1 = 0.601 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.523 vs. 0.193
# F1 = 0.577 vs. 0.321
# Precision = 0.549 vs. 0.192
# Recall = 0.608 vs. 0.997
# Minibatch Loss= 5.454820
# Train Batch Evaluation
# AUC = 0.584 vs. 0.320
# F1 = 0.601 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.541 vs. 0.999
# Validation
# AUC = 0.523 vs. 0.196
# F1 = 0.577 vs. 0.326
# Precision = 0.546 vs. 0.196
# Recall = 0.611 vs. 0.975
# Minibatch Loss= 5.442588
# Train Batch Evaluation
# AUC = 0.584 vs. 0.316
# F1 = 0.601 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.516 vs. 0.186
# F1 = 0.577 vs. 0.321
# Precision = 0.546 vs. 0.191
# Recall = 0.611 vs. 0.994
# Minibatch Loss= 5.430372
# Train Batch Evaluation
# AUC = 0.583 vs. 0.314
# F1 = 0.601 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.541 vs. 1.000
# Validation
# AUC = 0.518 vs. 0.182
# F1 = 0.576 vs. 0.320
# Precision = 0.550 vs. 0.191
# Recall = 0.605 vs. 1.000
# Minibatch Loss= 5.418169
# Train Batch Evaluation
# AUC = 0.585 vs. 0.316
# F1 = 0.600 vs. 0.479
# Precision = 0.676 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.518 vs. 0.193
# F1 = 0.576 vs. 0.332
# Precision = 0.550 vs. 0.200
# Recall = 0.605 vs. 0.972
# Minibatch Loss= 5.405974
# Train Batch Evaluation
# AUC = 0.585 vs. 0.316
# F1 = 0.600 vs. 0.479
# Precision = 0.676 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.474 vs. 0.209
# F1 = 0.576 vs. 0.322
# Precision = 0.543 vs. 0.192
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 5.393786
# Train Batch Evaluation
# AUC = 0.585 vs. 0.310
# F1 = 0.600 vs. 0.479
# Precision = 0.676 vs. 0.316
# Recall = 0.540 vs. 0.996
# Validation
# AUC = 0.474 vs. 0.205
# F1 = 0.576 vs. 0.325
# Precision = 0.550 vs. 0.199
# Recall = 0.605 vs. 0.882
# Minibatch Loss= 5.381602
# Train Batch Evaluation
# AUC = 0.586 vs. 0.315
# F1 = 0.600 vs. 0.479
# Precision = 0.676 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.480 vs. 0.200
# F1 = 0.576 vs. 0.323
# Precision = 0.547 vs. 0.193
# Recall = 0.608 vs. 0.989
# Minibatch Loss= 5.369419
# Train Batch Evaluation
# AUC = 0.585 vs. 0.312
# F1 = 0.600 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.512 vs. 0.193
# F1 = 0.576 vs. 0.325
# Precision = 0.542 vs. 0.200
# Recall = 0.613 vs. 0.866
# Minibatch Loss= 5.357234
# Train Batch Evaluation
# AUC = 0.597 vs. 0.313
# F1 = 0.600 vs. 0.480
# Precision = 0.675 vs. 0.315
# Recall = 0.540 vs. 0.999
# Validation
# AUC = 0.509 vs. 0.204
# F1 = 0.576 vs. 0.325
# Precision = 0.542 vs. 0.196
# Recall = 0.613 vs. 0.944
# Minibatch Loss= 5.345045
# Train Batch Evaluation
# AUC = 0.598 vs. 0.322
# F1 = 0.600 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.509 vs. 0.200
# F1 = 0.575 vs. 0.321
# Precision = 0.541 vs. 0.191
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 5.332851
# Train Batch Evaluation
# AUC = 0.590 vs. 0.316
# F1 = 0.600 vs. 0.479
# Precision = 0.673 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.509 vs. 0.189
# F1 = 0.574 vs. 0.323
# Precision = 0.542 vs. 0.194
# Recall = 0.611 vs. 0.966
# Minibatch Loss= 5.320650
# Train Batch Evaluation
# AUC = 0.594 vs. 0.320
# F1 = 0.599 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.509 vs. 0.186
# F1 = 0.574 vs. 0.321
# Precision = 0.542 vs. 0.191
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 5.308440
# Train Batch Evaluation
# AUC = 0.588 vs. 0.314
# F1 = 0.599 vs. 0.480
# Precision = 0.672 vs. 0.316
# Recall = 0.541 vs. 0.998
# Validation
# AUC = 0.516 vs. 0.187
# F1 = 0.575 vs. 0.322
# Precision = 0.541 vs. 0.192
# Recall = 0.613 vs. 0.997
# Minibatch Loss= 5.296221
# Train Batch Evaluation
# AUC = 0.588 vs. 0.320
# F1 = 0.599 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.513 vs. 0.200
# F1 = 0.574 vs. 0.321
# Precision = 0.544 vs. 0.191
# Recall = 0.608 vs. 0.992
# Minibatch Loss= 5.283990
# Train Batch Evaluation
# AUC = 0.594 vs. 0.320
# F1 = 0.599 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.514 vs. 0.201
# F1 = 0.573 vs. 0.323
# Precision = 0.542 vs. 0.198
# Recall = 0.608 vs. 0.885
# Minibatch Loss= 5.271748
# Train Batch Evaluation
# AUC = 0.592 vs. 0.310
# F1 = 0.599 vs. 0.479
# Precision = 0.675 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.513 vs. 0.202
# F1 = 0.573 vs. 0.322
# Precision = 0.542 vs. 0.193
# Recall = 0.608 vs. 0.972
# Minibatch Loss= 5.259492
# Train Batch Evaluation
# AUC = 0.591 vs. 0.324
# F1 = 0.599 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.513 vs. 0.206
# F1 = 0.573 vs. 0.322
# Precision = 0.538 vs. 0.194
# Recall = 0.613 vs. 0.952
# Minibatch Loss= 5.247222
# Train Batch Evaluation
# AUC = 0.592 vs. 0.325
# F1 = 0.599 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.513 vs. 0.181
# F1 = 0.573 vs. 0.321
# Precision = 0.538 vs. 0.191
# Recall = 0.613 vs. 0.997
# Minibatch Loss= 5.234938
# Train Batch Evaluation
# AUC = 0.592 vs. 0.312
# F1 = 0.599 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.539 vs. 1.000
# Validation
# AUC = 0.522 vs. 0.173
# F1 = 0.572 vs. 0.320
# Precision = 0.538 vs. 0.191
# Recall = 0.611 vs. 1.000
# Minibatch Loss= 5.222640
# Train Batch Evaluation
# AUC = 0.592 vs. 0.311
# F1 = 0.599 vs. 0.479
# Precision = 0.674 vs. 0.315
# Recall = 0.539 vs. 0.999
# Validation
# AUC = 0.511 vs. 0.190
# F1 = 0.572 vs. 0.322
# Precision = 0.538 vs. 0.192
# Recall = 0.611 vs. 0.997
# Minibatch Loss= 5.210325
# Train Batch Evaluation
# AUC = 0.592 vs. 0.318
# F1 = 0.599 vs. 0.479
# Precision = 0.657 vs. 0.315
# Recall = 0.550 vs. 1.000
# Validation
# AUC = 0.511 vs. 0.185
# F1 = 0.572 vs. 0.321
# Precision = 0.534 vs. 0.191
# Recall = 0.616 vs. 0.997
# Minibatch Loss= 5.197994
# Train Batch Evaluation
# AUC = 0.592 vs. 0.311
# F1 = 0.599 vs. 0.479
# Precision = 0.657 vs. 0.315
# Recall = 0.550 vs. 1.000
# Validation
# AUC = 0.509 vs. 0.190
# F1 = 0.572 vs. 0.321
# Precision = 0.534 vs. 0.191
# Recall = 0.616 vs. 1.000
# ...
# Precision = 0.537 vs. 0.315
# Recall = 0.527 vs. 1.000
# Validation
# AUC = 0.393 vs. 0.191
# F1 = 0.429 vs. 0.321
# Precision = 0.323 vs. 0.191
# Recall = 0.636 vs. 1.000
# Minibatch Loss= 2.064548
# Train Batch Evaluation
# AUC = 0.559 vs. 0.313
# F1 = 0.532 vs. 0.479
# Precision = 0.509 vs. 0.315
# Recall = 0.557 vs. 1.000
# Validation
# AUC = 0.392 vs. 0.200
# F1 = 0.427 vs. 0.321
# Precision = 0.322 vs. 0.193
# Recall = 0.636 vs. 0.950
# Minibatch Loss= 2.056762
# Train Batch Evaluation
# AUC = 0.559 vs. 0.328
# F1 = 0.532 vs. 0.479
# Precision = 0.507 vs. 0.315
# Recall = 0.559 vs. 1.000
# Validation
# AUC = 0.392 vs. 0.196
# F1 = 0.427 vs. 0.322
# Precision = 0.319 vs. 0.192
# Recall = 0.647 vs. 1.000
# Minibatch Loss= 2.049036
# Train Batch Evaluation
# AUC = 0.558 vs. 0.313
# F1 = 0.532 vs. 0.479
# Precision = 0.507 vs. 0.315
# Recall = 0.559 vs. 1.000
# Validation
# AUC = 0.391 vs. 0.202
# F1 = 0.427 vs. 0.327
# Precision = 0.319 vs. 0.196
# Recall = 0.647 vs. 0.983
# Minibatch Loss= 2.041371
# Train Batch Evaluation
# AUC = 0.558 vs. 0.319
# F1 = 0.532 vs. 0.479
# Precision = 0.503 vs. 0.315
# Recall = 0.563 vs. 0.999
# Validation
# AUC = 0.391 vs. 0.187
# F1 = 0.427 vs. 0.321
# Precision = 0.319 vs. 0.192
# Recall = 0.644 vs. 0.989
# Minibatch Loss= 2.033766
# Train Batch Evaluation
# AUC = 0.558 vs. 0.315
# F1 = 0.532 vs. 0.479
# Precision = 0.504 vs. 0.315
# Recall = 0.562 vs. 1.000
# Validation
# AUC = 0.390 vs. 0.203
# F1 = 0.427 vs. 0.322
# Precision = 0.319 vs. 0.192
# Recall = 0.644 vs. 1.000
# Minibatch Loss= 2.026221
# Train Batch Evaluation
# AUC = 0.557 vs. 0.322
# F1 = 0.532 vs. 0.479
# Precision = 0.504 vs. 0.315
# Recall = 0.562 vs. 1.000
# Validation
# AUC = 0.389 vs. 0.203
# F1 = 0.426 vs. 0.329
# Precision = 0.319 vs. 0.200
# Recall = 0.644 vs. 0.910
# Minibatch Loss= 2.018735
# Train Batch Evaluation
# AUC = 0.557 vs. 0.313
# F1 = 0.532 vs. 0.479
# Precision = 0.504 vs. 0.315
# Recall = 0.563 vs. 1.000
# Validation
# AUC = 0.390 vs. 0.202
# F1 = 0.426 vs. 0.321
# Precision = 0.318 vs. 0.191
# Recall = 0.644 vs. 0.997
# Minibatch Loss= 2.011309
# Train Batch Evaluation
# AUC = 0.556 vs. 0.323
# F1 = 0.532 vs. 0.479
# Precision = 0.503 vs. 0.316
# Recall = 0.564 vs. 0.996
# Validation
# AUC = 0.389 vs. 0.186
# F1 = 0.426 vs. 0.321
# Precision = 0.318 vs. 0.191
# Recall = 0.644 vs. 1.000
# Minibatch Loss= 2.003942
# Train Batch Evaluation
# AUC = 0.556 vs. 0.319
# F1 = 0.532 vs. 0.479
# Precision = 0.506 vs. 0.315
# Recall = 0.560 vs. 0.999
# Validation
# AUC = 0.388 vs. 0.185
# F1 = 0.425 vs. 0.321
# Precision = 0.317 vs. 0.191
# Recall = 0.644 vs. 0.992
# Minibatch Loss= 1.996633
# Train Batch Evaluation
# AUC = 0.556 vs. 0.316
# F1 = 0.531 vs. 0.479
# Precision = 0.504 vs. 0.315
# Recall = 0.563 vs. 1.000
# Validation
# AUC = 0.387 vs. 0.192
# F1 = 0.424 vs. 0.324
# Precision = 0.316 vs. 0.196
# Recall = 0.647 vs. 0.944
# Minibatch Loss= 1.989383
# Train Batch Evaluation
# AUC = 0.556 vs. 0.320
# F1 = 0.532 vs. 0.480
# Precision = 0.504 vs. 0.316
# Recall = 0.562 vs. 0.997
# Validation
# AUC = 0.387 vs. 0.194
# F1 = 0.424 vs. 0.320
# Precision = 0.316 vs. 0.191
# Recall = 0.647 vs. 1.000
# Minibatch Loss= 1.982190
# Train Batch Evaluation
# AUC = 0.555 vs. 0.314
# F1 = 0.531 vs. 0.479
# Precision = 0.507 vs. 0.315
# Recall = 0.558 vs. 1.000
# Validation
# AUC = 0.387 vs. 0.187
# F1 = 0.424 vs. 0.321
# Precision = 0.315 vs. 0.192
# Recall = 0.647 vs. 1.000
# Minibatch Loss= 1.975056
# Train Batch Evaluation
# AUC = 0.555 vs. 0.310
# F1 = 0.531 vs. 0.479
# Precision = 0.506 vs. 0.315
# Recall = 0.559 vs. 1.000
# Validation
# AUC = 0.387 vs. 0.189
# F1 = 0.423 vs. 0.323
# Precision = 0.328 vs. 0.193
# Recall = 0.597 vs. 0.989
# Minibatch Loss= 1.967978
# Train Batch Evaluation
# AUC = 0.555 vs. 0.317
# F1 = 0.532 vs. 0.480
# Precision = 0.526 vs. 0.316
# Recall = 0.538 vs. 0.999
# Validation
# AUC = 0.386 vs. 0.195
# F1 = 0.423 vs. 0.322
# Precision = 0.328 vs. 0.192
# Recall = 0.597 vs. 1.000
# Minibatch Loss= 1.960958
# Train Batch Evaluation
# AUC = 0.554 vs. 0.313
# F1 = 0.531 vs. 0.479
# Precision = 0.525 vs. 0.315
# Recall = 0.538 vs. 1.000
# Validation
# AUC = 0.386 vs. 0.204
# F1 = 0.421 vs. 0.327
# Precision = 0.326 vs. 0.202
# Recall = 0.597 vs. 0.868
# Minibatch Loss= 1.953994
# Train Batch Evaluation
# AUC = 0.554 vs. 0.318
# F1 = 0.531 vs. 0.479
# Precision = 0.524 vs. 0.315
# Recall = 0.539 vs. 0.999
# Validation
# AUC = 0.385 vs. 0.194
# F1 = 0.421 vs. 0.322
# Precision = 0.323 vs. 0.192
# Recall = 0.602 vs. 1.000
# Minibatch Loss= 1.947086
# Train Batch Evaluation
# AUC = 0.553 vs. 0.316
# F1 = 0.531 vs. 0.480
# Precision = 0.496 vs. 0.316
# Recall = 0.572 vs. 0.999
# Validation
# AUC = 0.385 vs. 0.189
# F1 = 0.421 vs. 0.321
# Precision = 0.333 vs. 0.191
# Recall = 0.574 vs. 0.994
# Minibatch Loss= 1.940233
# Train Batch Evaluation
# AUC = 0.553 vs. 0.312
# F1 = 0.531 vs. 0.479
# Precision = 0.525 vs. 0.315
# Recall = 0.537 vs. 1.000
# Validation
# AUC = 0.384 vs. 0.201
# F1 = 0.421 vs. 0.321
# Precision = 0.333 vs. 0.191
# Recall = 0.574 vs. 0.994
# Minibatch Loss= 1.933437
# Train Batch Evaluation
# AUC = 0.553 vs. 0.316
# F1 = 0.531 vs. 0.479
# Precision = 0.494 vs. 0.315
# Recall = 0.573 vs. 1.000
# Validation
# AUC = 0.384 vs. 0.180
# F1 = 0.422 vs. 0.322
# Precision = 0.336 vs. 0.192
# Recall = 0.566 vs. 1.000
# Minibatch Loss= 1.926694
# Train Batch Evaluation
# AUC = 0.553 vs. 0.311
# F1 = 0.531 vs. 0.479
# Precision = 0.520 vs. 0.315
# Recall = 0.542 vs. 1.000
# Validation
# AUC = 0.383 vs. 0.211
# F1 = 0.422 vs. 0.324
# Precision = 0.337 vs. 0.194
# Recall = 0.566 vs. 0.978
# Minibatch Loss= 1.920007
# Train Batch Evaluation
# AUC = 0.552 vs. 0.308
# F1 = 0.531 vs. 0.479
# Precision = 0.521 vs. 0.315
# Recall = 0.542 vs. 1.000
# Validation
# AUC = 0.383 vs. 0.192
# F1 = 0.422 vs. 0.321
# Precision = 0.337 vs. 0.191
# Recall = 0.566 vs. 1.000
# Minibatch Loss= 1.913373
# Train Batch Evaluation
# AUC = 0.552 vs. 0.311
# F1 = 0.531 vs. 0.479
# Precision = 0.523 vs. 0.315
# Recall = 0.540 vs. 1.000
# Validation
# AUC = 0.382 vs. 0.230
# F1 = 0.422 vs. 0.329
# Precision = 0.336 vs. 0.203
# Recall = 0.566 vs. 0.868
# Minibatch Loss= 1.906793
# Train Batch Evaluation
# AUC = 0.552 vs. 0.318
# F1 = 0.531 vs. 0.479
# Precision = 0.521 vs. 0.316
# Recall = 0.541 vs. 0.993
# Validation
# AUC = 0.382 vs. 0.196
# F1 = 0.422 vs. 0.321
# Precision = 0.337 vs. 0.191
# Recall = 0.563 vs. 0.997
# Minibatch Loss= 1.900266
# Train Batch Evaluation
# AUC = 0.552 vs. 0.320
# F1 = 0.531 vs. 0.479
# Precision = 0.491 vs. 0.315
# Recall = 0.578 vs. 1.000
# Validation
# AUC = 0.382 vs. 0.184
# F1 = 0.422 vs. 0.323
# Precision = 0.337 vs. 0.194
# Recall = 0.563 vs. 0.975
# Minibatch Loss= 1.893792
# Train Batch Evaluation
# AUC = 0.551 vs. 0.315
# F1 = 0.531 vs. 0.480
# Precision = 0.494 vs. 0.316
# Recall = 0.573 vs. 0.997
# Validation
# AUC = 0.381 vs. 0.200
# F1 = 0.422 vs. 0.332
# Precision = 0.335 vs. 0.203
# Recall = 0.569 vs. 0.902
# Minibatch Loss= 1.887370
# Train Batch Evaluation
# AUC = 0.551 vs. 0.316
# F1 = 0.530 vs. 0.479
# Precision = 0.492 vs. 0.315
# Recall = 0.575 vs. 1.000
# Validation
# AUC = 0.381 vs. 0.184
# F1 = 0.422 vs. 0.321
# Precision = 0.335 vs. 0.191
# Recall = 0.569 vs. 1.000
# Minibatch Loss= 1.881001
# Train Batch Evaluation
# AUC = 0.551 vs. 0.314
# F1 = 0.531 vs. 0.479
# Precision = 0.511 vs. 0.315
# Recall = 0.552 vs. 0.999
# Validation
# AUC = 0.380 vs. 0.198
# F1 = 0.420 vs. 0.321
# Precision = 0.334 vs. 0.191
# Recall = 0.566 vs. 1.000
# Minibatch Loss= 1.874682
# Train Batch Evaluation
# AUC = 0.551 vs. 0.303
# F1 = 0.531 vs. 0.479
# Precision = 0.493 vs. 0.315
# Recall = 0.574 vs. 1.000
# Validation
# AUC = 0.379 vs. 0.187
# F1 = 0.421 vs. 0.322
# Precision = 0.335 vs. 0.192
# Recall = 0.566 vs. 0.997
# Minibatch Loss= 1.868415
# Train Batch Evaluation
# AUC = 0.551 vs. 0.313
# F1 = 0.531 vs. 0.480
# Precision = 0.487 vs. 0.316
# Recall = 0.583 vs. 0.996
# Validation
# AUC = 0.379 vs. 0.195
# F1 = 0.420 vs. 0.323
# Precision = 0.334 vs. 0.193
# Recall = 0.566 vs. 0.992
# Minibatch Loss= 1.862198
# Train Batch Evaluation
# AUC = 0.551 vs. 0.318
# F1 = 0.531 vs. 0.479
# Precision = 0.487 vs. 0.315
# Recall = 0.583 vs. 1.000
# Validation
# AUC = 0.379 vs. 0.191
# F1 = 0.420 vs. 0.321
# Precision = 0.334 vs. 0.192
# Recall = 0.566 vs. 0.989
# Minibatch Loss= 1.856031
# Train Batch Evaluation
# AUC = 0.550 vs. 0.320
# F1 = 0.531 vs. 0.480
# Precision = 0.490 vs. 0.316
# Recall = 0.579 vs. 0.994
# Validation
# AUC = 0.378 vs. 0.195
# F1 = 0.420 vs. 0.321
# Precision = 0.334 vs. 0.192
# Recall = 0.566 vs. 0.980
# Minibatch Loss= 1.849914
# Train Batch Evaluation
# AUC = 0.550 vs. 0.315
# F1 = 0.531 vs. 0.479
# Precision = 0.480 vs. 0.316
# Recall = 0.593 vs. 0.997
# Validation
# AUC = 0.378 vs. 0.190
# F1 = 0.419 vs. 0.325
# Precision = 0.305 vs. 0.194
# Recall = 0.669 vs. 0.997
# Minibatch Loss= 1.843847
# Train Batch Evaluation
# AUC = 0.550 vs. 0.311
# F1 = 0.531 vs. 0.479
# Precision = 0.480 vs. 0.315
# Recall = 0.593 vs. 1.000
# Validation
# AUC = 0.377 vs. 0.190
# F1 = 0.419 vs. 0.324
# Precision = 0.305 vs. 0.193
# Recall = 0.669 vs. 1.000
# Minibatch Loss= 1.837828
# Train Batch Evaluation
# AUC = 0.550 vs. 0.315
# F1 = 0.531 vs. 0.479
# Precision = 0.482 vs. 0.315
# Recall = 0.591 vs. 1.000
# Validation
# AUC = 0.377 vs. 0.203
# F1 = 0.419 vs. 0.320
# Precision = 0.304 vs. 0.191
# Recall = 0.669 vs. 1.000
# Minibatch Loss= 1.831857
# Train Batch Evaluation
# AUC = 0.550 vs. 0.317
# F1 = 0.531 vs. 0.479
# Precision = 0.483 vs. 0.315
# Recall = 0.590 vs. 1.000
# Validation
# AUC = 0.377 vs. 0.190
# F1 = 0.418 vs. 0.322
# Precision = 0.304 vs. 0.192
# Recall = 0.669 vs. 0.986
# Minibatch Loss= 1.825935
# Train Batch Evaluation
# AUC = 0.550 vs. 0.316
# F1 = 0.532 vs. 0.479
# Precision = 0.484 vs. 0.315
# Recall = 0.590 vs. 0.998
# Validation
# AUC = 0.376 vs. 0.197
# F1 = 0.418 vs. 0.322
# Precision = 0.304 vs. 0.192
# Recall = 0.669 vs. 0.992
# Minibatch Loss= 1.820059
# Train Batch Evaluation
# AUC = 0.549 vs. 0.319
# F1 = 0.531 vs. 0.479
# Precision = 0.484 vs. 0.315
# Recall = 0.590 vs. 1.000
# Validation
# AUC = 0.376 vs. 0.193
# F1 = 0.419 vs. 0.321
# Precision = 0.307 vs. 0.191
# Recall = 0.658 vs. 1.000
# Minibatch Loss= 1.814232
# Train Batch Evaluation
# AUC = 0.549 vs. 0.314
# F1 = 0.532 vs. 0.479
# Precision = 0.487 vs. 0.315
# Recall = 0.587 vs. 0.999
# Validation
# AUC = 0.376 vs. 0.192
# F1 = 0.419 vs. 0.320
# Precision = 0.337 vs. 0.191
# Recall = 0.555 vs. 1.000
# Minibatch Loss= 1.808450
# Train Batch Evaluation
# AUC = 0.549 vs. 0.318
# F1 = 0.532 vs. 0.479
# Precision = 0.487 vs. 0.315
# Recall = 0.586 vs. 1.000
# Validation
# AUC = 0.375 vs. 0.180
# F1 = 0.419 vs. 0.324
# Precision = 0.337 vs. 0.194
# Recall = 0.555 vs. 0.992
# Minibatch Loss= 1.802715
# Train Batch Evaluation
# AUC = 0.549 vs. 0.311
# F1 = 0.532 vs. 0.480
# Precision = 0.488 vs. 0.316
# Recall = 0.585 vs. 0.997
# Validation
# AUC = 0.375 vs. 0.200
# F1 = 0.419 vs. 0.322
# Precision = 0.337 vs. 0.192
# Recall = 0.555 vs. 0.989
# Minibatch Loss= 1.797026
# Train Batch Evaluation
# AUC = 0.549 vs. 0.316
# F1 = 0.533 vs. 0.479
# Precision = 0.468 vs. 0.315
# Recall = 0.618 vs. 0.999
# Validation
# AUC = 0.375 vs. 0.188
# F1 = 0.418 vs. 0.321
# Precision = 0.335 vs. 0.191
# Recall = 0.555 vs. 1.000
# Minibatch Loss= 1.791382
# Train Batch Evaluation
# AUC = 0.549 vs. 0.310
# F1 = 0.533 vs. 0.479
# Precision = 0.469 vs. 0.315
# Recall = 0.617 vs. 1.000
# Validation
# AUC = 0.375 vs. 0.192
# F1 = 0.418 vs. 0.321
# Precision = 0.336 vs. 0.191
# Recall = 0.555 vs. 1.000
# Minibatch Loss= 1.785782
# Train Batch Evaluation
# AUC = 0.549 vs. 0.314
# F1 = 0.533 vs. 0.479
# Precision = 0.470 vs. 0.315
# Recall = 0.616 vs. 1.000
# Validation
# AUC = 0.374 vs. 0.181
# F1 = 0.418 vs. 0.322
# Precision = 0.324 vs. 0.192
# Recall = 0.588 vs. 0.983
# Minibatch Loss= 1.780228
# Train Batch Evaluation
# AUC = 0.549 vs. 0.311
# F1 = 0.533 vs. 0.479
# Precision = 0.470 vs. 0.315
# Recall = 0.617 vs. 1.000
# Validation
# AUC = 0.374 vs. 0.189
# F1 = 0.417 vs. 0.323
# Precision = 0.323 vs. 0.192
# Recall = 0.588 vs. 1.000
# Minibatch Loss= 1.774718
# Train Batch Evaluation
# AUC = 0.549 vs. 0.315
# F1 = 0.534 vs. 0.479
# Precision = 0.469 vs. 0.315
# Recall = 0.620 vs. 1.000
# Validation
# AUC = 0.374 vs. 0.189
# F1 = 0.416 vs. 0.321
# Precision = 0.323 vs. 0.191
# Recall = 0.585 vs. 1.000
# Minibatch Loss= 1.769251
# Train Batch Evaluation
# AUC = 0.549 vs. 0.310
# F1 = 0.534 vs. 0.479
# Precision = 0.465 vs. 0.315
# Recall = 0.628 vs. 1.000
# Validation
# AUC = 0.374 vs. 0.196
# F1 = 0.417 vs. 0.328
# Precision = 0.304 vs. 0.200
# Recall = 0.664 vs. 0.916
# Minibatch Loss= 1.763827
# Train Batch Evaluation
# AUC = 0.549 vs. 0.317
# F1 = 0.534 vs. 0.479
# Precision = 0.469 vs. 0.315
# Recall = 0.620 vs. 1.000
# Validation
# AUC = 0.374 vs. 0.191
# F1 = 0.416 vs. 0.321
# Precision = 0.324 vs. 0.192
# Recall = 0.583 vs. 0.975
# Minibatch Loss= 1.758447
# Train Batch Evaluation
# AUC = 0.549 vs. 0.316
# F1 = 0.535 vs. 0.479
# Precision = 0.470 vs. 0.315
# Recall = 0.622 vs. 1.000
# Validation
# AUC = 0.373 vs. 0.183
# F1 = 0.416 vs. 0.322
# Precision = 0.324 vs. 0.192
# Recall = 0.583 vs. 0.994
# Minibatch Loss= 1.753108
# Train Batch Evaluation
# AUC = 0.549 vs. 0.315
# F1 = 0.536 vs. 0.479
# Precision = 0.470 vs. 0.315
# Recall = 0.623 vs. 1.000
# Validation
# AUC = 0.373 vs. 0.192
# F1 = 0.416 vs. 0.321
# Precision = 0.325 vs. 0.191
# Recall = 0.577 vs. 1.000
# Minibatch Loss= 1.747812
# Train Batch Evaluation
# AUC = 0.549 vs. 0.319
# F1 = 0.536 vs. 0.480
# Precision = 0.471 vs. 0.316
# Recall = 0.623 vs. 1.000
# Validation
# AUC = 0.373 vs. 0.202
# F1 = 0.418 vs. 0.324
# Precision = 0.326 vs. 0.195
# Recall = 0.580 vs. 0.961
# Minibatch Loss= 1.742558
# Train Batch Evaluation
# AUC = 0.549 vs. 0.323
# F1 = 0.536 vs. 0.479
# Precision = 0.471 vs. 0.315
# Recall = 0.623 vs. 1.000
# Validation
# AUC = 0.373 vs. 0.187
# F1 = 0.418 vs. 0.322
# Precision = 0.327 vs. 0.192
# Recall = 0.580 vs. 0.997
# Minibatch Loss= 1.737345
# Train Batch Evaluation
# AUC = 0.549 vs. 0.316
# F1 = 0.536 vs. 0.479
# Precision = 0.471 vs. 0.315
# Recall = 0.623 vs. 0.999
# Validation
# AUC = 0.373 vs. 0.189
# F1 = 0.417 vs. 0.324
# Precision = 0.326 vs. 0.194
# Recall = 0.580 vs. 0.989
# Minibatch Loss= 1.732172
# Train Batch Evaluation
# AUC = 0.549 vs. 0.313
# F1 = 0.537 vs. 0.479
# Precision = 0.473 vs. 0.315
# Recall = 0.621 vs. 1.000
# Validation
# AUC = 0.373 vs. 0.189
# F1 = 0.417 vs. 0.324
# Precision = 0.325 vs. 0.203
# Recall = 0.580 vs. 0.807
# Minibatch Loss= 1.727040
# Train Batch Evaluation
# AUC = 0.549 vs. 0.323
# F1 = 0.537 vs. 0.479
# Precision = 0.470 vs. 0.315
# Recall = 0.627 vs. 1.000
# Validation
# AUC = 0.372 vs. 0.188
# F1 = 0.416 vs. 0.320
# Precision = 0.297 vs. 0.191
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 1.721949
# Train Batch Evaluation
# AUC = 0.549 vs. 0.314
# F1 = 0.537 vs. 0.479
# Precision = 0.471 vs. 0.315
# Recall = 0.626 vs. 0.999
# Validation
# AUC = 0.372 vs. 0.196
# F1 = 0.417 vs. 0.326
# Precision = 0.302 vs. 0.195
# Recall = 0.675 vs. 0.975
# Minibatch Loss= 1.716897
# Train Batch Evaluation
# AUC = 0.549 vs. 0.320
# F1 = 0.538 vs. 0.480
# Precision = 0.474 vs. 0.316
# Recall = 0.621 vs. 0.998
# Validation
# AUC = 0.372 vs. 0.173
# F1 = 0.417 vs. 0.321
# Precision = 0.301 vs. 0.192
# Recall = 0.678 vs. 0.986
# Minibatch Loss= 1.711884
# Train Batch Evaluation
# AUC = 0.549 vs. 0.325
# F1 = 0.538 vs. 0.479
# Precision = 0.471 vs. 0.315
# Recall = 0.626 vs. 0.998
# Validation
# AUC = 0.372 vs. 0.196
# F1 = 0.417 vs. 0.327
# Precision = 0.302 vs. 0.198
# Recall = 0.675 vs. 0.952
# Minibatch Loss= 1.706911
# Train Batch Evaluation
# AUC = 0.549 vs. 0.306
# F1 = 0.538 vs. 0.479
# Precision = 0.473 vs. 0.316
# Recall = 0.624 vs. 0.992
# Validation
# AUC = 0.371 vs. 0.196
# F1 = 0.417 vs. 0.323
# Precision = 0.302 vs. 0.196
# Recall = 0.675 vs. 0.922
# Minibatch Loss= 1.701976
# Train Batch Evaluation
# AUC = 0.549 vs. 0.307
# F1 = 0.538 vs. 0.480
# Precision = 0.474 vs. 0.315
# Recall = 0.622 vs. 1.000
# Validation
# AUC = 0.371 vs. 0.190
# F1 = 0.417 vs. 0.323
# Precision = 0.324 vs. 0.194
# Recall = 0.585 vs. 0.969
# Minibatch Loss= 1.697080
# Train Batch Evaluation
# AUC = 0.549 vs. 0.309
# F1 = 0.538 vs. 0.479
# Precision = 0.475 vs. 0.315
# Recall = 0.622 vs. 1.000
# Validation
# AUC = 0.371 vs. 0.184
# F1 = 0.417 vs. 0.321
# Precision = 0.324 vs. 0.191
# Recall = 0.585 vs. 1.000
# Minibatch Loss= 1.692221
# Train Batch Evaluation
# AUC = 0.549 vs. 0.312
# F1 = 0.538 vs. 0.479
# Precision = 0.475 vs. 0.315
# Recall = 0.621 vs. 1.000
# Validation
# AUC = 0.371 vs. 0.193
# F1 = 0.418 vs. 0.320
# Precision = 0.298 vs. 0.191
# Recall = 0.697 vs. 1.000
# Minibatch Loss= 1.687400
# Train Batch Evaluation
# AUC = 0.549 vs. 0.310
# F1 = 0.539 vs. 0.479
# Precision = 0.474 vs. 0.315
# Recall = 0.624 vs. 1.000
# Validation
# AUC = 0.371 vs. 0.175
# F1 = 0.418 vs. 0.321
# Precision = 0.301 vs. 0.193
# Recall = 0.681 vs. 0.952
# Minibatch Loss= 1.682616
# Train Batch Evaluation
# AUC = 0.549 vs. 0.313
# F1 = 0.539 vs. 0.479
# Precision = 0.467 vs. 0.315
# Recall = 0.636 vs. 1.000
# Validation
# AUC = 0.371 vs. 0.216
# F1 = 0.419 vs. 0.326
# Precision = 0.302 vs. 0.203
# Recall = 0.681 vs. 0.826
# Minibatch Loss= 1.677869

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
