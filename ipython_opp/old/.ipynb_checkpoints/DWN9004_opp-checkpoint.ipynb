# %%
# useing this variable for saving models and summaries
exp_name = "DWN9004_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp4.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)
    
train_data = data['train_data']
test_data = data['test_data']
validation_data = data['validation_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

#index_of_changes = data['index_of_changes_test']

# %%
train_gt.shape, train_data.shape
# Out:
# ((1, 700165, 1), (1, 700165, 77))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 1

wavelet_levels = 5    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
''' s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()
'''

s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[0,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)
pos_weight = pos_weight[0]

# %%
train_data = train_data[:,:-(train_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_data = validation_data[:,:-(validation_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_data = test_data[:,:-(test_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

train_gt = train_gt[:,:-(train_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_gt = validation_gt[:,:-(validation_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_gt = test_gt[:,:-(test_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

# %%
print pos_weight
# Out:
# 2.17746

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet=False,
                                 trainable_conv=False,
                                 trainable_last=True,
                                )

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
#load the model
saver = tf.train.Saver(var_list = [
    model.weights['wc0'],model.weights['wc1'],model.weights['wc2'],
    model.bias['bc0'],model.bias['bc1'],model.bias['bc2'],
    model.weights['high_pass'],model.weights['low_pass']
])
saver.restore(sess, '../model/DWN9001_opp/checkpoint-4000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/CNN9001_opp/CNN9001_opp-4000

# %%
trainer.train(max_iter = 50000,
                train_eval_step = 1, 
                validation_eval_step = 1,
                display_step = 1)
# Out:
# Train Batch Evaluation
# AUC = 0.596 vs. 0.312
# F1 = 0.600 vs. 0.478
# Precision = 0.643 vs. 0.314
# Recall = 0.562 vs. 0.999
# Validation
# AUC = 0.461 vs. 0.176
# F1 = 0.541 vs. 0.315
# Precision = 0.502 vs. 0.187
# Recall = 0.587 vs. 1.000
# Minibatch Loss= 9.982225
# Train Batch Evaluation
# AUC = 0.595 vs. 0.316
# F1 = 0.600 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.556 vs. 1.000
# Validation
# AUC = 0.466 vs. 0.193
# F1 = 0.541 vs. 0.316
# Precision = 0.502 vs. 0.189
# Recall = 0.587 vs. 0.957
# Minibatch Loss= 9.764697
# Train Batch Evaluation
# AUC = 0.597 vs. 0.313
# F1 = 0.600 vs. 0.478
# Precision = 0.652 vs. 0.314
# Recall = 0.556 vs. 1.000
# Validation
# AUC = 0.466 vs. 0.203
# F1 = 0.542 vs. 0.315
# Precision = 0.506 vs. 0.199
# Recall = 0.584 vs. 0.764
# Minibatch Loss= 9.554661
# Train Batch Evaluation
# AUC = 0.583 vs. 0.306
# F1 = 0.601 vs. 0.478
# Precision = 0.625 vs. 0.314
# Recall = 0.578 vs. 1.000
# Validation
# AUC = 0.463 vs. 0.184
# F1 = 0.545 vs. 0.315
# Precision = 0.509 vs. 0.187
# Recall = 0.587 vs. 0.997
# Minibatch Loss= 9.351956
# Train Batch Evaluation
# AUC = 0.594 vs. 0.319
# F1 = 0.602 vs. 0.478
# Precision = 0.630 vs. 0.314
# Recall = 0.577 vs. 1.000
# Validation
# AUC = 0.473 vs. 0.182
# F1 = 0.547 vs. 0.316
# Precision = 0.515 vs. 0.189
# Recall = 0.584 vs. 0.969
# Minibatch Loss= 9.156743
# Train Batch Evaluation
# AUC = 0.589 vs. 0.317
# F1 = 0.603 vs. 0.478
# Precision = 0.624 vs. 0.314
# Recall = 0.583 vs. 0.998
# Validation
# AUC = 0.477 vs. 0.186
# F1 = 0.547 vs. 0.315
# Precision = 0.515 vs. 0.187
# Recall = 0.584 vs. 1.000
# Minibatch Loss= 8.969249
# Train Batch Evaluation
# AUC = 0.583 vs. 0.321
# F1 = 0.604 vs. 0.478
# Precision = 0.628 vs. 0.314
# Recall = 0.582 vs. 1.000
# Validation
# AUC = 0.459 vs. 0.182
# F1 = 0.548 vs. 0.315
# Precision = 0.516 vs. 0.187
# Recall = 0.584 vs. 1.000
# Minibatch Loss= 8.789654
# Train Batch Evaluation
# AUC = 0.586 vs. 0.316
# F1 = 0.605 vs. 0.478
# Precision = 0.628 vs. 0.314
# Recall = 0.584 vs. 1.000
# Validation
# AUC = 0.451 vs. 0.201
# F1 = 0.551 vs. 0.317
# Precision = 0.516 vs. 0.189
# Recall = 0.590 vs. 0.983
# Minibatch Loss= 8.617985
# Train Batch Evaluation
# AUC = 0.586 vs. 0.316
# F1 = 0.607 vs. 0.478
# Precision = 0.635 vs. 0.314
# Recall = 0.581 vs. 1.000
# Validation
# AUC = 0.495 vs. 0.176
# F1 = 0.553 vs. 0.314
# Precision = 0.520 vs. 0.186
# Recall = 0.590 vs. 1.000
# Minibatch Loss= 8.454244
# Train Batch Evaluation
# AUC = 0.583 vs. 0.314
# F1 = 0.608 vs. 0.478
# Precision = 0.637 vs. 0.314
# Recall = 0.581 vs. 0.999
# Validation
# AUC = 0.472 vs. 0.185
# F1 = 0.556 vs. 0.319
# Precision = 0.525 vs. 0.191
# Recall = 0.590 vs. 0.960
# Minibatch Loss= 8.298482
# Train Batch Evaluation
# AUC = 0.587 vs. 0.310
# F1 = 0.608 vs. 0.478
# Precision = 0.640 vs. 0.314
# Recall = 0.579 vs. 1.000
# Validation
# AUC = 0.459 vs. 0.194
# F1 = 0.558 vs. 0.314
# Precision = 0.522 vs. 0.187
# Recall = 0.598 vs. 1.000
# Minibatch Loss= 8.150759
# Train Batch Evaluation
# AUC = 0.584 vs. 0.306
# F1 = 0.607 vs. 0.478
# Precision = 0.637 vs. 0.314
# Recall = 0.580 vs. 1.000
# Validation
# AUC = 0.459 vs. 0.185
# F1 = 0.559 vs. 0.315
# Precision = 0.525 vs. 0.188
# Recall = 0.598 vs. 0.983
# Minibatch Loss= 8.011096
# Train Batch Evaluation
# AUC = 0.579 vs. 0.316
# F1 = 0.607 vs. 0.478
# Precision = 0.621 vs. 0.314
# Recall = 0.594 vs. 1.000
# Validation
# AUC = 0.469 vs. 0.189
# F1 = 0.559 vs. 0.315
# Precision = 0.541 vs. 0.187
# Recall = 0.578 vs. 0.986
# Minibatch Loss= 7.879418
# Train Batch Evaluation
# AUC = 0.581 vs. 0.309
# F1 = 0.608 vs. 0.478
# Precision = 0.624 vs. 0.315
# Recall = 0.593 vs. 0.993
# Validation
# AUC = 0.493 vs. 0.180
# F1 = 0.562 vs. 0.315
# Precision = 0.542 vs. 0.188
# Recall = 0.584 vs. 0.980
# Minibatch Loss= 7.755608
# Train Batch Evaluation
# AUC = 0.602 vs. 0.315
# F1 = 0.608 vs. 0.478
# Precision = 0.624 vs. 0.314
# Recall = 0.592 vs. 1.000
# Validation
# AUC = 0.481 vs. 0.193
# F1 = 0.565 vs. 0.319
# Precision = 0.552 vs. 0.201
# Recall = 0.578 vs. 0.769
# Minibatch Loss= 7.639591
# Train Batch Evaluation
# AUC = 0.576 vs. 0.313
# F1 = 0.608 vs. 0.478
# Precision = 0.640 vs. 0.314
# Recall = 0.579 vs. 1.000
# Validation
# AUC = 0.472 vs. 0.188
# F1 = 0.567 vs. 0.316
# Precision = 0.554 vs. 0.190
# Recall = 0.581 vs. 0.926
# Minibatch Loss= 7.531311
# Train Batch Evaluation
# AUC = 0.572 vs. 0.315
# F1 = 0.608 vs. 0.478
# Precision = 0.643 vs. 0.314
# Recall = 0.577 vs. 1.000
# Validation
# AUC = 0.463 vs. 0.181
# F1 = 0.569 vs. 0.315
# Precision = 0.557 vs. 0.187
# Recall = 0.581 vs. 0.991
# Minibatch Loss= 7.430622
# Train Batch Evaluation
# AUC = 0.570 vs. 0.311
# F1 = 0.608 vs. 0.478
# Precision = 0.622 vs. 0.314
# Recall = 0.594 vs. 1.000
# Validation
# AUC = 0.469 vs. 0.185
# F1 = 0.572 vs. 0.317
# Precision = 0.560 vs. 0.189
# Recall = 0.584 vs. 0.994
# Minibatch Loss= 7.337302
# Train Batch Evaluation
# AUC = 0.566 vs. 0.324
# F1 = 0.608 vs. 0.478
# Precision = 0.620 vs. 0.314
# Recall = 0.597 vs. 1.000
# Validation
# AUC = 0.488 vs. 0.180
# F1 = 0.571 vs. 0.319
# Precision = 0.557 vs. 0.190
# Recall = 0.587 vs. 0.980
# Minibatch Loss= 7.251072
# Train Batch Evaluation
# AUC = 0.570 vs. 0.325
# F1 = 0.608 vs. 0.478
# Precision = 0.621 vs. 0.314
# Recall = 0.595 vs. 1.000
# Validation
# AUC = 0.477 vs. 0.192
# F1 = 0.572 vs. 0.316
# Precision = 0.555 vs. 0.188
# Recall = 0.590 vs. 0.994
# Minibatch Loss= 7.171597
# Train Batch Evaluation
# AUC = 0.570 vs. 0.317
# F1 = 0.609 vs. 0.478
# Precision = 0.625 vs. 0.314
# Recall = 0.593 vs. 0.999
# Validation
# AUC = 0.472 vs. 0.183
# F1 = 0.572 vs. 0.314
# Precision = 0.555 vs. 0.186
# Recall = 0.590 vs. 1.000
# Minibatch Loss= 7.098486
# Train Batch Evaluation
# AUC = 0.580 vs. 0.315
# F1 = 0.609 vs. 0.478
# Precision = 0.625 vs. 0.314
# Recall = 0.593 vs. 0.998
# Validation
# AUC = 0.472 vs. 0.186
# F1 = 0.571 vs. 0.314
# Precision = 0.553 vs. 0.187
# Recall = 0.590 vs. 1.000
# Minibatch Loss= 7.031336
# Train Batch Evaluation
# AUC = 0.583 vs. 0.312
# F1 = 0.609 vs. 0.478
# Precision = 0.625 vs. 0.314
# Recall = 0.594 vs. 0.999
# Validation
# AUC = 0.464 vs. 0.183
# F1 = 0.569 vs. 0.322
# Precision = 0.549 vs. 0.194
# Recall = 0.590 vs. 0.954
# Minibatch Loss= 6.969726
# Train Batch Evaluation
# AUC = 0.566 vs. 0.314
# F1 = 0.609 vs. 0.478
# Precision = 0.628 vs. 0.314
# Recall = 0.591 vs. 0.999
# Validation
# AUC = 0.468 vs. 0.182
# F1 = 0.570 vs. 0.315
# Precision = 0.549 vs. 0.187
# Recall = 0.593 vs. 1.000
# Minibatch Loss= 6.913203
# Train Batch Evaluation
# AUC = 0.563 vs. 0.307
# F1 = 0.609 vs. 0.478
# Precision = 0.627 vs. 0.314
# Recall = 0.592 vs. 1.000
# Validation
# AUC = 0.464 vs. 0.193
# F1 = 0.571 vs. 0.314
# Precision = 0.552 vs. 0.187
# Recall = 0.593 vs. 1.000
# Minibatch Loss= 6.861248
# Train Batch Evaluation
# AUC = 0.566 vs. 0.304
# F1 = 0.608 vs. 0.478
# Precision = 0.625 vs. 0.314
# Recall = 0.591 vs. 1.000
# Validation
# AUC = 0.478 vs. 0.195
# F1 = 0.571 vs. 0.315
# Precision = 0.552 vs. 0.187
# Recall = 0.593 vs. 1.000
# Minibatch Loss= 6.813273
# Train Batch Evaluation
# AUC = 0.567 vs. 0.312
# F1 = 0.608 vs. 0.478
# Precision = 0.624 vs. 0.314
# Recall = 0.592 vs. 1.000
# Validation
# AUC = 0.455 vs. 0.201
# F1 = 0.571 vs. 0.314
# Precision = 0.552 vs. 0.186
# Recall = 0.593 vs. 1.000
# Minibatch Loss= 6.768664
# Train Batch Evaluation
# AUC = 0.571 vs. 0.309
# F1 = 0.608 vs. 0.478
# Precision = 0.616 vs. 0.314
# Recall = 0.599 vs. 1.000
# Validation
# AUC = 0.477 vs. 0.194
# F1 = 0.572 vs. 0.316
# Precision = 0.550 vs. 0.188
# Recall = 0.595 vs. 0.989
# Minibatch Loss= 6.726833
# Train Batch Evaluation
# AUC = 0.572 vs. 0.309
# F1 = 0.607 vs. 0.478
# Precision = 0.616 vs. 0.314
# Recall = 0.598 vs. 0.999
# Validation
# AUC = 0.481 vs. 0.197
# F1 = 0.571 vs. 0.316
# Precision = 0.549 vs. 0.188
# Recall = 0.595 vs. 1.000
# Minibatch Loss= 6.687230
# Train Batch Evaluation
# AUC = 0.570 vs. 0.316
# F1 = 0.607 vs. 0.478
# Precision = 0.609 vs. 0.314
# Recall = 0.604 vs. 1.000
# Validation
# AUC = 0.470 vs. 0.198
# F1 = 0.569 vs. 0.318
# Precision = 0.551 vs. 0.191
# Recall = 0.590 vs. 0.946
# Minibatch Loss= 6.649339
# Train Batch Evaluation
# AUC = 0.555 vs. 0.317
# F1 = 0.607 vs. 0.478
# Precision = 0.610 vs. 0.314
# Recall = 0.604 vs. 1.000
# Validation
# AUC = 0.447 vs. 0.196
# F1 = 0.569 vs. 0.314
# Precision = 0.549 vs. 0.186
# Recall = 0.590 vs. 1.000
# Minibatch Loss= 6.612679
# Train Batch Evaluation
# AUC = 0.596 vs. 0.312
# F1 = 0.607 vs. 0.478
# Precision = 0.619 vs. 0.314
# Recall = 0.595 vs. 1.000
# Validation
# AUC = 0.454 vs. 0.205
# F1 = 0.570 vs. 0.318
# Precision = 0.539 vs. 0.190
# Recall = 0.604 vs. 0.980
# Minibatch Loss= 6.576800
# Train Batch Evaluation
# AUC = 0.558 vs. 0.322
# F1 = 0.607 vs. 0.478
# Precision = 0.618 vs. 0.314
# Recall = 0.596 vs. 1.000
# Validation
# AUC = 0.464 vs. 0.194
# F1 = 0.570 vs. 0.314
# Precision = 0.539 vs. 0.187
# Recall = 0.604 vs. 0.986
# Minibatch Loss= 6.541288
# Train Batch Evaluation
# AUC = 0.571 vs. 0.322
# F1 = 0.606 vs. 0.478
# Precision = 0.607 vs. 0.314
# Recall = 0.606 vs. 0.996
# Validation
# AUC = 0.476 vs. 0.204
# F1 = 0.569 vs. 0.314
# Precision = 0.540 vs. 0.187
# Recall = 0.601 vs. 0.991
# Minibatch Loss= 6.505787
# Train Batch Evaluation
# AUC = 0.573 vs. 0.310
# F1 = 0.606 vs. 0.478
# Precision = 0.613 vs. 0.314
# Recall = 0.599 vs. 1.000
# Validation
# AUC = 0.486 vs. 0.174
# F1 = 0.569 vs. 0.316
# Precision = 0.547 vs. 0.188
# Recall = 0.593 vs. 0.991
# Minibatch Loss= 6.469997
# Train Batch Evaluation
# AUC = 0.573 vs. 0.311
# F1 = 0.606 vs. 0.478
# Precision = 0.600 vs. 0.314
# Recall = 0.612 vs. 0.999
# Validation
# AUC = 0.486 vs. 0.182
# F1 = 0.569 vs. 0.314
# Precision = 0.540 vs. 0.186
# Recall = 0.601 vs. 1.000
# Minibatch Loss= 6.433698
# Train Batch Evaluation
# AUC = 0.571 vs. 0.315
# F1 = 0.606 vs. 0.478
# Precision = 0.600 vs. 0.314
# Recall = 0.611 vs. 1.000
# Validation
# AUC = 0.489 vs. 0.180
# F1 = 0.568 vs. 0.314
# Precision = 0.535 vs. 0.187
# Recall = 0.604 vs. 0.991
# Minibatch Loss= 6.396746
# Train Batch Evaluation
# AUC = 0.595 vs. 0.314
# F1 = 0.606 vs. 0.478
# Precision = 0.600 vs. 0.314
# Recall = 0.612 vs. 1.000
# Validation
# AUC = 0.492 vs. 0.186
# F1 = 0.568 vs. 0.316
# Precision = 0.535 vs. 0.188
# Recall = 0.604 vs. 0.983
# Minibatch Loss= 6.359076
# Train Batch Evaluation
# AUC = 0.571 vs. 0.313
# F1 = 0.605 vs. 0.478
# Precision = 0.600 vs. 0.314
# Recall = 0.611 vs. 1.000
# Validation
# AUC = 0.468 vs. 0.192
# F1 = 0.566 vs. 0.318
# Precision = 0.536 vs. 0.195
# Recall = 0.601 vs. 0.869
# Minibatch Loss= 6.320699
# Train Batch Evaluation
# AUC = 0.574 vs. 0.315
# F1 = 0.605 vs. 0.478
# Precision = 0.601 vs. 0.314
# Recall = 0.610 vs. 0.999
# Validation
# AUC = 0.501 vs. 0.214
# F1 = 0.568 vs. 0.314
# Precision = 0.530 vs. 0.187
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 6.281691
# Train Batch Evaluation
# AUC = 0.568 vs. 0.313
# F1 = 0.605 vs. 0.478
# Precision = 0.612 vs. 0.314
# Recall = 0.599 vs. 1.000
# Validation
# AUC = 0.467 vs. 0.194
# F1 = 0.566 vs. 0.315
# Precision = 0.531 vs. 0.187
# Recall = 0.607 vs. 1.000
# Minibatch Loss= 6.242186
# Train Batch Evaluation
# AUC = 0.599 vs. 0.322
# F1 = 0.605 vs. 0.478
# Precision = 0.612 vs. 0.314
# Recall = 0.598 vs. 1.000
# Validation
# AUC = 0.470 vs. 0.184
# F1 = 0.566 vs. 0.314
# Precision = 0.528 vs. 0.189
# Recall = 0.610 vs. 0.923
# Minibatch Loss= 6.202357
# Train Batch Evaluation
# AUC = 0.573 vs. 0.309
# F1 = 0.605 vs. 0.478
# Precision = 0.614 vs. 0.314
# Recall = 0.596 vs. 1.000
# Validation
# AUC = 0.448 vs. 0.204
# F1 = 0.566 vs. 0.315
# Precision = 0.522 vs. 0.189
# Recall = 0.618 vs. 0.957
# Minibatch Loss= 6.162402
# Train Batch Evaluation
# AUC = 0.576 vs. 0.307
# F1 = 0.605 vs. 0.478
# Precision = 0.614 vs. 0.314
# Recall = 0.597 vs. 0.999
# Validation
# AUC = 0.453 vs. 0.187
# F1 = 0.566 vs. 0.316
# Precision = 0.522 vs. 0.188
# Recall = 0.618 vs. 0.997
# Minibatch Loss= 6.122532
# Train Batch Evaluation
# AUC = 0.566 vs. 0.308
# F1 = 0.605 vs. 0.478
# Precision = 0.611 vs. 0.314
# Recall = 0.598 vs. 1.000
# Validation
# AUC = 0.443 vs. 0.203
# F1 = 0.566 vs. 0.319
# Precision = 0.526 vs. 0.192
# Recall = 0.613 vs. 0.934
# Minibatch Loss= 6.082946
# Train Batch Evaluation
# AUC = 0.582 vs. 0.320
# F1 = 0.604 vs. 0.478
# Precision = 0.606 vs. 0.314
# Recall = 0.602 vs. 1.000
# Validation
# AUC = 0.480 vs. 0.192
# F1 = 0.565 vs. 0.318
# Precision = 0.526 vs. 0.191
# Recall = 0.610 vs. 0.957
# Minibatch Loss= 6.043830
# Train Batch Evaluation
# AUC = 0.585 vs. 0.311
# F1 = 0.604 vs. 0.478
# Precision = 0.607 vs. 0.314
# Recall = 0.601 vs. 1.000
# Validation
# AUC = 0.438 vs. 0.197
# F1 = 0.565 vs. 0.315
# Precision = 0.526 vs. 0.187
# Recall = 0.610 vs. 1.000
# Minibatch Loss= 6.005338
# Train Batch Evaluation
# AUC = 0.576 vs. 0.311
# F1 = 0.604 vs. 0.478
# Precision = 0.597 vs. 0.314
# Recall = 0.611 vs. 1.000
# Validation
# AUC = 0.478 vs. 0.182
# F1 = 0.563 vs. 0.317
# Precision = 0.519 vs. 0.191
# Recall = 0.615 vs. 0.952
# Minibatch Loss= 5.967590
# Train Batch Evaluation
# AUC = 0.577 vs. 0.311
# F1 = 0.603 vs. 0.478
# Precision = 0.607 vs. 0.314
# Recall = 0.599 vs. 1.000
# Validation
# AUC = 0.460 vs. 0.188
# F1 = 0.563 vs. 0.316
# Precision = 0.523 vs. 0.188
# Recall = 0.610 vs. 0.986
# Minibatch Loss= 5.930663
# Train Batch Evaluation
# AUC = 0.580 vs. 0.311
# F1 = 0.603 vs. 0.478
# Precision = 0.610 vs. 0.314
# Recall = 0.596 vs. 1.000
# Validation
# AUC = 0.469 vs. 0.187
# F1 = 0.561 vs. 0.318
# Precision = 0.514 vs. 0.190
# Recall = 0.618 vs. 0.974
# Minibatch Loss= 5.894599
# Train Batch Evaluation
# AUC = 0.578 vs. 0.316
# F1 = 0.603 vs. 0.478
# Precision = 0.610 vs. 0.314
# Recall = 0.596 vs. 1.000
# Validation
# AUC = 0.456 vs. 0.192
# F1 = 0.561 vs. 0.317
# Precision = 0.512 vs. 0.189
# Recall = 0.621 vs. 0.997
# Minibatch Loss= 5.859404
# Train Batch Evaluation
# AUC = 0.578 vs. 0.312
# F1 = 0.602 vs. 0.478
# Precision = 0.599 vs. 0.314
# Recall = 0.605 vs. 1.000
# Validation
# AUC = 0.455 vs. 0.200
# F1 = 0.562 vs. 0.316
# Precision = 0.513 vs. 0.188
# Recall = 0.621 vs. 0.986
# Minibatch Loss= 5.825047
# Train Batch Evaluation
# AUC = 0.579 vs. 0.313
# F1 = 0.602 vs. 0.478
# Precision = 0.602 vs. 0.314
# Recall = 0.602 vs. 0.999
# Validation
# AUC = 0.458 vs. 0.180
# F1 = 0.560 vs. 0.314
# Precision = 0.511 vs. 0.186
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 5.791480
# Train Batch Evaluation
# AUC = 0.590 vs. 0.313
# F1 = 0.602 vs. 0.478
# Precision = 0.601 vs. 0.314
# Recall = 0.602 vs. 1.000
# Validation
# AUC = 0.482 vs. 0.187
# F1 = 0.559 vs. 0.316
# Precision = 0.508 vs. 0.189
# Recall = 0.621 vs. 0.966
# Minibatch Loss= 5.758633
# Train Batch Evaluation
# AUC = 0.581 vs. 0.317
# F1 = 0.601 vs. 0.478
# Precision = 0.602 vs. 0.314
# Recall = 0.600 vs. 1.000
# Validation
# AUC = 0.461 vs. 0.195
# F1 = 0.558 vs. 0.319
# Precision = 0.507 vs. 0.191
# Recall = 0.621 vs. 0.963
# Minibatch Loss= 5.726426
# Train Batch Evaluation
# AUC = 0.587 vs. 0.313
# F1 = 0.601 vs. 0.478
# Precision = 0.598 vs. 0.314
# Recall = 0.604 vs. 1.000
# Validation
# AUC = 0.459 vs. 0.179
# F1 = 0.556 vs. 0.318
# Precision = 0.503 vs. 0.189
# Recall = 0.621 vs. 0.986
# Minibatch Loss= 5.694776
# Train Batch Evaluation
# AUC = 0.572 vs. 0.313
# F1 = 0.600 vs. 0.478
# Precision = 0.599 vs. 0.314
# Recall = 0.602 vs. 0.999
# Validation
# AUC = 0.472 vs. 0.175
# F1 = 0.555 vs. 0.318
# Precision = 0.502 vs. 0.190
# Recall = 0.621 vs. 0.980
# Minibatch Loss= 5.663604
# Train Batch Evaluation
# AUC = 0.577 vs. 0.311
# F1 = 0.600 vs. 0.478
# Precision = 0.608 vs. 0.314
# Recall = 0.592 vs. 0.999
# Validation
# AUC = 0.484 vs. 0.169
# F1 = 0.554 vs. 0.314
# Precision = 0.499 vs. 0.187
# Recall = 0.624 vs. 1.000
# Minibatch Loss= 5.632835
# Train Batch Evaluation
# AUC = 0.580 vs. 0.317
# F1 = 0.600 vs. 0.478
# Precision = 0.607 vs. 0.314
# Recall = 0.593 vs. 1.000
# Validation
# AUC = 0.465 vs. 0.208
# F1 = 0.553 vs. 0.320
# Precision = 0.495 vs. 0.196
# Recall = 0.627 vs. 0.869
# Minibatch Loss= 5.602404
# Train Batch Evaluation
# AUC = 0.582 vs. 0.313
# F1 = 0.600 vs. 0.478
# Precision = 0.606 vs. 0.314
# Recall = 0.594 vs. 1.000
# Validation
# AUC = 0.458 vs. 0.182
# F1 = 0.554 vs. 0.316
# Precision = 0.494 vs. 0.188
# Recall = 0.630 vs. 1.000
# Minibatch Loss= 5.572262
# Train Batch Evaluation
# AUC = 0.583 vs. 0.308
# F1 = 0.599 vs. 0.478
# Precision = 0.598 vs. 0.314
# Recall = 0.600 vs. 1.000
# Validation
# AUC = 0.437 vs. 0.180
# F1 = 0.554 vs. 0.314
# Precision = 0.494 vs. 0.187
# Recall = 0.630 vs. 0.989
# Minibatch Loss= 5.542371
# Train Batch Evaluation
# AUC = 0.580 vs. 0.310
# F1 = 0.599 vs. 0.478
# Precision = 0.597 vs. 0.315
# Recall = 0.601 vs. 0.995
# Validation
# AUC = 0.465 vs. 0.178
# F1 = 0.554 vs. 0.314
# Precision = 0.494 vs. 0.187
# Recall = 0.630 vs. 0.994
# Minibatch Loss= 5.512710
# Train Batch Evaluation
# AUC = 0.577 vs. 0.321
# F1 = 0.599 vs. 0.478
# Precision = 0.601 vs. 0.314
# Recall = 0.597 vs. 1.000
# Validation
# AUC = 0.472 vs. 0.186
# F1 = 0.554 vs. 0.315
# Precision = 0.494 vs. 0.187
# Recall = 0.630 vs. 1.000
# Minibatch Loss= 5.483270
# Train Batch Evaluation
# AUC = 0.577 vs. 0.322
# F1 = 0.599 vs. 0.478
# Precision = 0.593 vs. 0.314
# Recall = 0.604 vs. 1.000
# Validation
# AUC = 0.484 vs. 0.189
# F1 = 0.553 vs. 0.314
# Precision = 0.491 vs. 0.187
# Recall = 0.632 vs. 0.997
# Minibatch Loss= 5.454057
# Train Batch Evaluation
# AUC = 0.578 vs. 0.312
# F1 = 0.599 vs. 0.478
# Precision = 0.592 vs. 0.315
# Recall = 0.605 vs. 0.999
# Validation
# AUC = 0.481 vs. 0.187
# F1 = 0.554 vs. 0.317
# Precision = 0.492 vs. 0.191
# Recall = 0.632 vs. 0.934
# Minibatch Loss= 5.425083
# Train Batch Evaluation
# AUC = 0.578 vs. 0.318
# F1 = 0.599 vs. 0.478
# Precision = 0.596 vs. 0.314
# Recall = 0.602 vs. 1.000
# Validation
# AUC = 0.449 vs. 0.182
# F1 = 0.553 vs. 0.314
# Precision = 0.491 vs. 0.186
# Recall = 0.632 vs. 1.000
# Minibatch Loss= 5.396369
# Train Batch Evaluation
# AUC = 0.577 vs. 0.316
# F1 = 0.598 vs. 0.478
# Precision = 0.593 vs. 0.314
# Recall = 0.604 vs. 1.000
# Validation
# AUC = 0.465 vs. 0.189
# F1 = 0.553 vs. 0.319
# Precision = 0.491 vs. 0.192
# Recall = 0.632 vs. 0.943
# Minibatch Loss= 5.367938
# Train Batch Evaluation
# AUC = 0.577 vs. 0.312
# F1 = 0.598 vs. 0.479
# Precision = 0.588 vs. 0.316
# Recall = 0.608 vs. 0.991
# Validation
# AUC = 0.460 vs. 0.185
# F1 = 0.552 vs. 0.315
# Precision = 0.489 vs. 0.187
# Recall = 0.632 vs. 1.000
# Minibatch Loss= 5.339814
# Train Batch Evaluation
# AUC = 0.575 vs. 0.312
# F1 = 0.598 vs. 0.478
# Precision = 0.589 vs. 0.314
# Recall = 0.607 vs. 0.999
# Validation
# AUC = 0.441 vs. 0.188
# F1 = 0.550 vs. 0.315
# Precision = 0.489 vs. 0.187
# Recall = 0.630 vs. 1.000
# Minibatch Loss= 5.312019
# Train Batch Evaluation
# AUC = 0.575 vs. 0.314
# F1 = 0.597 vs. 0.478
# Precision = 0.582 vs. 0.314
# Recall = 0.613 vs. 0.999
# Validation
# AUC = 0.477 vs. 0.189
# F1 = 0.550 vs. 0.316
# Precision = 0.489 vs. 0.188
# Recall = 0.630 vs. 0.991
# Minibatch Loss= 5.284568
# Train Batch Evaluation
# AUC = 0.578 vs. 0.315
# F1 = 0.597 vs. 0.478
# Precision = 0.574 vs. 0.314
# Recall = 0.622 vs. 0.998
# Validation
# AUC = 0.469 vs. 0.195
# F1 = 0.550 vs. 0.320
# Precision = 0.492 vs. 0.194
# Recall = 0.624 vs. 0.897
# Minibatch Loss= 5.257472
# Train Batch Evaluation
# AUC = 0.580 vs. 0.314
# F1 = 0.598 vs. 0.478
# Precision = 0.574 vs. 0.314
# Recall = 0.623 vs. 1.000
# Validation
# AUC = 0.461 vs. 0.189
# F1 = 0.550 vs. 0.317
# Precision = 0.493 vs. 0.189
# Recall = 0.621 vs. 0.997
# Minibatch Loss= 5.230733
# Train Batch Evaluation
# AUC = 0.575 vs. 0.317
# F1 = 0.598 vs. 0.478
# Precision = 0.576 vs. 0.314
# Recall = 0.622 vs. 1.000
# Validation
# AUC = 0.467 vs. 0.191
# F1 = 0.550 vs. 0.315
# Precision = 0.493 vs. 0.187
# Recall = 0.621 vs. 0.997
# Minibatch Loss= 5.204347
# Train Batch Evaluation
# AUC = 0.573 vs. 0.318
# F1 = 0.598 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.619 vs. 1.000
# Validation
# AUC = 0.464 vs. 0.207
# F1 = 0.550 vs. 0.317
# Precision = 0.493 vs. 0.189
# Recall = 0.621 vs. 0.974
# Minibatch Loss= 5.178300
# Train Batch Evaluation
# AUC = 0.573 vs. 0.319
# F1 = 0.598 vs. 0.478
# Precision = 0.577 vs. 0.314
# Recall = 0.621 vs. 1.000
# Validation
# AUC = 0.444 vs. 0.185
# F1 = 0.549 vs. 0.315
# Precision = 0.494 vs. 0.188
# Recall = 0.618 vs. 0.974
# Minibatch Loss= 5.152576
# Train Batch Evaluation
# AUC = 0.576 vs. 0.316
# F1 = 0.598 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.619 vs. 0.999
# Validation
# AUC = 0.454 vs. 0.188
# F1 = 0.549 vs. 0.314
# Precision = 0.494 vs. 0.186
# Recall = 0.618 vs. 1.000
# Minibatch Loss= 5.127153
# Train Batch Evaluation
# AUC = 0.573 vs. 0.310
# F1 = 0.598 vs. 0.478
# Precision = 0.579 vs. 0.314
# Recall = 0.617 vs. 0.999
# Validation
# AUC = 0.466 vs. 0.210
# F1 = 0.550 vs. 0.316
# Precision = 0.495 vs. 0.188
# Recall = 0.618 vs. 1.000
# Minibatch Loss= 5.102008
# Train Batch Evaluation
# AUC = 0.579 vs. 0.313
# F1 = 0.598 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.616 vs. 1.000
# Validation
# AUC = 0.470 vs. 0.201
# F1 = 0.548 vs. 0.320
# Precision = 0.492 vs. 0.190
# Recall = 0.618 vs. 0.994
# Minibatch Loss= 5.077118
# Train Batch Evaluation
# AUC = 0.572 vs. 0.310
# F1 = 0.597 vs. 0.478
# Precision = 0.579 vs. 0.314
# Recall = 0.617 vs. 0.995
# Validation
# AUC = 0.469 vs. 0.193
# F1 = 0.547 vs. 0.314
# Precision = 0.491 vs. 0.186
# Recall = 0.618 vs. 1.000
# Minibatch Loss= 5.052460
# Train Batch Evaluation
# AUC = 0.572 vs. 0.311
# F1 = 0.597 vs. 0.478
# Precision = 0.579 vs. 0.314
# Recall = 0.616 vs. 1.000
# Validation
# AUC = 0.449 vs. 0.188
# F1 = 0.546 vs. 0.315
# Precision = 0.494 vs. 0.189
# Recall = 0.610 vs. 0.943
# Minibatch Loss= 5.028017
# Train Batch Evaluation
# AUC = 0.569 vs. 0.316
# F1 = 0.597 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.615 vs. 1.000
# Validation
# AUC = 0.445 vs. 0.190
# F1 = 0.546 vs. 0.315
# Precision = 0.494 vs. 0.187
# Recall = 0.610 vs. 1.000
# Minibatch Loss= 5.003771
# Train Batch Evaluation
# AUC = 0.581 vs. 0.316
# F1 = 0.597 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.615 vs. 1.000
# Validation
# AUC = 0.466 vs. 0.222
# F1 = 0.545 vs. 0.317
# Precision = 0.486 vs. 0.189
# Recall = 0.621 vs. 0.989
# Minibatch Loss= 4.979712
# Train Batch Evaluation
# AUC = 0.568 vs. 0.312
# F1 = 0.597 vs. 0.478
# Precision = 0.579 vs. 0.314
# Recall = 0.616 vs. 0.999
# Validation
# AUC = 0.458 vs. 0.177
# F1 = 0.545 vs. 0.317
# Precision = 0.486 vs. 0.191
# Recall = 0.621 vs. 0.932
# Minibatch Loss= 4.955832
# Train Batch Evaluation
# AUC = 0.578 vs. 0.313
# F1 = 0.597 vs. 0.478
# Precision = 0.576 vs. 0.314
# Recall = 0.619 vs. 1.000
# Validation
# AUC = 0.457 vs. 0.189
# F1 = 0.544 vs. 0.319
# Precision = 0.479 vs. 0.194
# Recall = 0.630 vs. 0.906
# Minibatch Loss= 4.932127
# Train Batch Evaluation
# AUC = 0.575 vs. 0.312
# F1 = 0.596 vs. 0.478
# Precision = 0.577 vs. 0.314
# Recall = 0.618 vs. 1.000
# Validation
# AUC = 0.452 vs. 0.179
# F1 = 0.545 vs. 0.315
# Precision = 0.496 vs. 0.187
# Recall = 0.604 vs. 0.997
# Minibatch Loss= 4.908596
# Train Batch Evaluation
# AUC = 0.579 vs. 0.309
# F1 = 0.596 vs. 0.478
# Precision = 0.576 vs. 0.314
# Recall = 0.618 vs. 0.999
# Validation
# AUC = 0.454 vs. 0.179
# F1 = 0.544 vs. 0.319
# Precision = 0.495 vs. 0.192
# Recall = 0.604 vs. 0.934
# Minibatch Loss= 4.885238
# Train Batch Evaluation
# AUC = 0.569 vs. 0.320
# F1 = 0.596 vs. 0.478
# Precision = 0.568 vs. 0.314
# Recall = 0.626 vs. 0.999
# Validation
# AUC = 0.452 vs. 0.196
# F1 = 0.544 vs. 0.317
# Precision = 0.496 vs. 0.189
# Recall = 0.601 vs. 0.972
# Minibatch Loss= 4.862054
# Train Batch Evaluation
# AUC = 0.566 vs. 0.314
# F1 = 0.596 vs. 0.478
# Precision = 0.568 vs. 0.314
# Recall = 0.627 vs. 1.000
# Validation
# AUC = 0.446 vs. 0.184
# F1 = 0.543 vs. 0.315
# Precision = 0.492 vs. 0.187
# Recall = 0.607 vs. 1.000
# Minibatch Loss= 4.839045
# Train Batch Evaluation
# AUC = 0.567 vs. 0.312
# F1 = 0.596 vs. 0.478
# Precision = 0.568 vs. 0.314
# Recall = 0.627 vs. 0.997
# Validation
# AUC = 0.443 vs. 0.182
# F1 = 0.544 vs. 0.315
# Precision = 0.494 vs. 0.187
# Recall = 0.604 vs. 1.000
# Minibatch Loss= 4.816208
# Train Batch Evaluation
# AUC = 0.566 vs. 0.322
# F1 = 0.596 vs. 0.478
# Precision = 0.567 vs. 0.314
# Recall = 0.629 vs. 0.999
# Validation
# AUC = 0.442 vs. 0.175
# F1 = 0.544 vs. 0.314
# Precision = 0.495 vs. 0.186
# Recall = 0.604 vs. 1.000
# Minibatch Loss= 4.793545
# Train Batch Evaluation
# AUC = 0.565 vs. 0.315
# F1 = 0.596 vs. 0.478
# Precision = 0.568 vs. 0.314
# Recall = 0.627 vs. 1.000
# Validation
# AUC = 0.446 vs. 0.190
# F1 = 0.544 vs. 0.315
# Precision = 0.495 vs. 0.187
# Recall = 0.604 vs. 0.994
# Minibatch Loss= 4.771048
# Train Batch Evaluation
# AUC = 0.566 vs. 0.316
# F1 = 0.596 vs. 0.478
# Precision = 0.568 vs. 0.314
# Recall = 0.627 vs. 0.999
# Validation
# AUC = 0.448 vs. 0.179
# F1 = 0.544 vs. 0.317
# Precision = 0.494 vs. 0.188
# Recall = 0.604 vs. 0.994
# Minibatch Loss= 4.748716
# Train Batch Evaluation
# AUC = 0.566 vs. 0.318
# F1 = 0.595 vs. 0.478
# Precision = 0.567 vs. 0.314
# Recall = 0.627 vs. 1.000
# Validation
# AUC = 0.466 vs. 0.206
# F1 = 0.543 vs. 0.320
# Precision = 0.472 vs. 0.194
# Recall = 0.641 vs. 0.906
# Minibatch Loss= 4.726541
# Train Batch Evaluation
# AUC = 0.574 vs. 0.312
# F1 = 0.595 vs. 0.478
# Precision = 0.569 vs. 0.314
# Recall = 0.624 vs. 1.000
# Validation
# AUC = 0.443 vs. 0.189
# F1 = 0.544 vs. 0.317
# Precision = 0.473 vs. 0.189
# Recall = 0.641 vs. 0.986
# Minibatch Loss= 4.704517
# Train Batch Evaluation
# AUC = 0.568 vs. 0.322
# F1 = 0.595 vs. 0.478
# Precision = 0.566 vs. 0.314
# Recall = 0.627 vs. 1.000
# Validation
# AUC = 0.447 vs. 0.188
# F1 = 0.544 vs. 0.315
# Precision = 0.473 vs. 0.188
# Recall = 0.641 vs. 0.977
# Minibatch Loss= 4.682636
# Train Batch Evaluation
# AUC = 0.569 vs. 0.315
# F1 = 0.595 vs. 0.478
# Precision = 0.567 vs. 0.315
# Recall = 0.625 vs. 0.986
# Validation
# AUC = 0.448 vs. 0.186
# F1 = 0.544 vs. 0.316
# Precision = 0.473 vs. 0.188
# Recall = 0.641 vs. 0.997
# Minibatch Loss= 4.660890
# Train Batch Evaluation
# AUC = 0.568 vs. 0.327
# F1 = 0.594 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.609 vs. 0.996
# Validation
# AUC = 0.437 vs. 0.205
# F1 = 0.542 vs. 0.314
# Precision = 0.472 vs. 0.187
# Recall = 0.638 vs. 1.000
# Minibatch Loss= 4.639274
# Train Batch Evaluation
# AUC = 0.569 vs. 0.320
# F1 = 0.595 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.611 vs. 1.000
# Validation
# AUC = 0.439 vs. 0.196
# F1 = 0.542 vs. 0.317
# Precision = 0.472 vs. 0.188
# Recall = 0.635 vs. 0.991
# Minibatch Loss= 4.617781
# Train Batch Evaluation
# AUC = 0.568 vs. 0.324
# F1 = 0.595 vs. 0.478
# Precision = 0.582 vs. 0.314
# Recall = 0.609 vs. 1.000
# Validation
# AUC = 0.449 vs. 0.190
# F1 = 0.541 vs. 0.314
# Precision = 0.470 vs. 0.186
# Recall = 0.635 vs. 0.997
# Minibatch Loss= 4.596406
# Train Batch Evaluation
# AUC = 0.568 vs. 0.312
# F1 = 0.595 vs. 0.478
# Precision = 0.582 vs. 0.314
# Recall = 0.608 vs. 1.000
# Validation
# AUC = 0.444 vs. 0.182
# F1 = 0.540 vs. 0.317
# Precision = 0.469 vs. 0.189
# Recall = 0.635 vs. 0.966
# Minibatch Loss= 4.575147
# Train Batch Evaluation
# AUC = 0.567 vs. 0.310
# F1 = 0.594 vs. 0.478
# Precision = 0.564 vs. 0.314
# Recall = 0.628 vs. 1.000
# Validation
# AUC = 0.453 vs. 0.179
# F1 = 0.539 vs. 0.316
# Precision = 0.470 vs. 0.189
# Recall = 0.632 vs. 0.983
# Minibatch Loss= 4.553998
# Train Batch Evaluation
# AUC = 0.568 vs. 0.316
# F1 = 0.594 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.612 vs. 1.000
# Validation
# AUC = 0.453 vs. 0.204
# F1 = 0.539 vs. 0.324
# Precision = 0.469 vs. 0.199
# Recall = 0.632 vs. 0.860
# Minibatch Loss= 4.532960
# Train Batch Evaluation
# AUC = 0.568 vs. 0.314
# F1 = 0.595 vs. 0.478
# Precision = 0.588 vs. 0.314
# Recall = 0.601 vs. 1.000
# Validation
# AUC = 0.454 vs. 0.189
# F1 = 0.537 vs. 0.316
# Precision = 0.464 vs. 0.187
# Recall = 0.638 vs. 1.000
# Minibatch Loss= 4.512032
# Train Batch Evaluation
# AUC = 0.568 vs. 0.312
# F1 = 0.595 vs. 0.478
# Precision = 0.581 vs. 0.314
# Recall = 0.608 vs. 1.000
# Validation
# AUC = 0.438 vs. 0.183
# F1 = 0.536 vs. 0.314
# Precision = 0.472 vs. 0.187
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 4.491211
# Train Batch Evaluation
# AUC = 0.568 vs. 0.317
# F1 = 0.594 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.609 vs. 1.000
# Validation
# AUC = 0.459 vs. 0.193
# F1 = 0.538 vs. 0.317
# Precision = 0.474 vs. 0.189
# Recall = 0.621 vs. 0.974
# Minibatch Loss= 4.470500
# Train Batch Evaluation
# AUC = 0.568 vs. 0.303
# F1 = 0.595 vs. 0.478
# Precision = 0.583 vs. 0.314
# Recall = 0.608 vs. 0.999
# Validation
# AUC = 0.456 vs. 0.178
# F1 = 0.538 vs. 0.315
# Precision = 0.474 vs. 0.187
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 4.449896
# Train Batch Evaluation
# AUC = 0.567 vs. 0.313
# F1 = 0.595 vs. 0.478
# Precision = 0.584 vs. 0.314
# Recall = 0.606 vs. 1.000
# Validation
# AUC = 0.455 vs. 0.174
# F1 = 0.536 vs. 0.315
# Precision = 0.471 vs. 0.187
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 4.429399
# Train Batch Evaluation
# AUC = 0.566 vs. 0.316
# F1 = 0.595 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.612 vs. 1.000
# Validation
# AUC = 0.451 vs. 0.187
# F1 = 0.535 vs. 0.316
# Precision = 0.470 vs. 0.187
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 4.409011
# Train Batch Evaluation
# AUC = 0.569 vs. 0.310
# F1 = 0.596 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.612 vs. 1.000
# Validation
# AUC = 0.457 vs. 0.191
# F1 = 0.535 vs. 0.315
# Precision = 0.468 vs. 0.187
# Recall = 0.624 vs. 0.997
# Minibatch Loss= 4.388730
# Train Batch Evaluation
# AUC = 0.567 vs. 0.308
# F1 = 0.595 vs. 0.478
# Precision = 0.582 vs. 0.314
# Recall = 0.609 vs. 0.999
# Validation
# AUC = 0.450 vs. 0.186
# F1 = 0.535 vs. 0.318
# Precision = 0.484 vs. 0.193
# Recall = 0.598 vs. 0.889
# Minibatch Loss= 4.368555
# Train Batch Evaluation
# AUC = 0.570 vs. 0.320
# F1 = 0.595 vs. 0.478
# Precision = 0.578 vs. 0.315
# Recall = 0.613 vs. 0.994
# Validation
# AUC = 0.448 vs. 0.185
# F1 = 0.534 vs. 0.314
# Precision = 0.479 vs. 0.186
# Recall = 0.604 vs. 1.000
# Minibatch Loss= 4.348485
# Train Batch Evaluation
# AUC = 0.570 vs. 0.322
# F1 = 0.595 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.613 vs. 1.000
# Validation
# AUC = 0.446 vs. 0.200
# F1 = 0.535 vs. 0.315
# Precision = 0.480 vs. 0.187
# Recall = 0.604 vs. 1.000
# Minibatch Loss= 4.328521
# Train Batch Evaluation
# AUC = 0.564 vs. 0.318
# F1 = 0.595 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.613 vs. 0.998
# Validation
# AUC = 0.456 vs. 0.202
# F1 = 0.534 vs. 0.316
# Precision = 0.479 vs. 0.194
# Recall = 0.604 vs. 0.855
# Minibatch Loss= 4.308661
# Train Batch Evaluation
# AUC = 0.563 vs. 0.314
# F1 = 0.595 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.613 vs. 1.000
# Validation
# AUC = 0.453 vs. 0.188
# F1 = 0.535 vs. 0.315
# Precision = 0.478 vs. 0.187
# Recall = 0.607 vs. 1.000
# Minibatch Loss= 4.288903
# Train Batch Evaluation
# AUC = 0.564 vs. 0.311
# F1 = 0.596 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.615 vs. 0.999
# Validation
# AUC = 0.441 vs. 0.192
# F1 = 0.535 vs. 0.317
# Precision = 0.478 vs. 0.188
# Recall = 0.607 vs. 0.994
# Minibatch Loss= 4.269249
# Train Batch Evaluation
# AUC = 0.564 vs. 0.314
# F1 = 0.596 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.614 vs. 1.000
# Validation
# AUC = 0.450 vs. 0.206
# F1 = 0.535 vs. 0.318
# Precision = 0.479 vs. 0.189
# Recall = 0.607 vs. 0.991
# Minibatch Loss= 4.249697
# Train Batch Evaluation
# AUC = 0.566 vs. 0.320
# F1 = 0.596 vs. 0.478
# Precision = 0.576 vs. 0.314
# Recall = 0.616 vs. 0.999
# Validation
# AUC = 0.454 vs. 0.178
# F1 = 0.534 vs. 0.318
# Precision = 0.477 vs. 0.190
# Recall = 0.607 vs. 0.957
# Minibatch Loss= 4.230248
# Train Batch Evaluation
# AUC = 0.563 vs. 0.311
# F1 = 0.596 vs. 0.478
# Precision = 0.575 vs. 0.314
# Recall = 0.619 vs. 1.000
# Validation
# AUC = 0.462 vs. 0.188
# F1 = 0.533 vs. 0.320
# Precision = 0.471 vs. 0.193
# Recall = 0.615 vs. 0.932
# Minibatch Loss= 4.210902
# Train Batch Evaluation
# AUC = 0.566 vs. 0.318
# F1 = 0.596 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.615 vs. 1.000
# Validation
# AUC = 0.436 vs. 0.204
# F1 = 0.534 vs. 0.314
# Precision = 0.472 vs. 0.186
# Recall = 0.615 vs. 1.000
# Minibatch Loss= 4.191659
# Train Batch Evaluation
# AUC = 0.566 vs. 0.325
# F1 = 0.596 vs. 0.478
# Precision = 0.577 vs. 0.314
# Recall = 0.616 vs. 0.999
# Validation
# AUC = 0.438 vs. 0.198
# F1 = 0.533 vs. 0.318
# Precision = 0.471 vs. 0.195
# Recall = 0.615 vs. 0.863
# Minibatch Loss= 4.172521
# Train Batch Evaluation
# AUC = 0.566 vs. 0.304
# F1 = 0.595 vs. 0.478
# Precision = 0.576 vs. 0.314
# Recall = 0.616 vs. 1.000
# Validation
# AUC = 0.438 vs. 0.193
# F1 = 0.534 vs. 0.315
# Precision = 0.470 vs. 0.190
# Recall = 0.618 vs. 0.906
# Minibatch Loss= 4.153487
# Train Batch Evaluation
# AUC = 0.565 vs. 0.323
# F1 = 0.595 vs. 0.478
# Precision = 0.576 vs. 0.314
# Recall = 0.616 vs. 1.000
# Validation
# AUC = 0.437 vs. 0.179
# F1 = 0.535 vs. 0.314
# Precision = 0.472 vs. 0.187
# Recall = 0.618 vs. 1.000
# Minibatch Loss= 4.134558
# Train Batch Evaluation
# AUC = 0.565 vs. 0.320
# F1 = 0.596 vs. 0.478
# Precision = 0.572 vs. 0.314
# Recall = 0.623 vs. 0.999
# Validation
# AUC = 0.438 vs. 0.188
# F1 = 0.535 vs. 0.318
# Precision = 0.468 vs. 0.189
# Recall = 0.624 vs. 0.994
# Minibatch Loss= 4.115736
# Train Batch Evaluation
# AUC = 0.561 vs. 0.314
# F1 = 0.596 vs. 0.478
# Precision = 0.571 vs. 0.314
# Recall = 0.625 vs. 1.000
# Validation
# AUC = 0.451 vs. 0.202
# F1 = 0.534 vs. 0.315
# Precision = 0.467 vs. 0.190
# Recall = 0.624 vs. 0.926
# Minibatch Loss= 4.097022
# Train Batch Evaluation
# AUC = 0.561 vs. 0.310
# F1 = 0.597 vs. 0.478
# Precision = 0.571 vs. 0.314
# Recall = 0.625 vs. 1.000
# Validation
# AUC = 0.450 vs. 0.177
# F1 = 0.533 vs. 0.314
# Precision = 0.473 vs. 0.186
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 4.078414
# Train Batch Evaluation
# AUC = 0.563 vs. 0.315
# F1 = 0.597 vs. 0.478
# Precision = 0.572 vs. 0.314
# Recall = 0.626 vs. 1.000
# Validation
# AUC = 0.445 vs. 0.185
# F1 = 0.533 vs. 0.317
# Precision = 0.473 vs. 0.188
# Recall = 0.613 vs. 0.989
# Minibatch Loss= 4.059915
# Train Batch Evaluation
# AUC = 0.563 vs. 0.321
# F1 = 0.597 vs. 0.478
# Precision = 0.572 vs. 0.315
# Recall = 0.625 vs. 0.996
# Validation
# AUC = 0.460 vs. 0.191
# F1 = 0.533 vs. 0.314
# Precision = 0.473 vs. 0.186
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 4.041525
# Train Batch Evaluation
# AUC = 0.563 vs. 0.315
# F1 = 0.597 vs. 0.478
# Precision = 0.573 vs. 0.314
# Recall = 0.623 vs. 1.000
# Validation
# AUC = 0.433 vs. 0.199
# F1 = 0.533 vs. 0.318
# Precision = 0.469 vs. 0.192
# Recall = 0.618 vs. 0.929
# Minibatch Loss= 4.023244
# Train Batch Evaluation
# AUC = 0.568 vs. 0.316
# F1 = 0.597 vs. 0.478
# Precision = 0.575 vs. 0.314
# Recall = 0.621 vs. 0.999
# Validation
# AUC = 0.440 vs. 0.176
# F1 = 0.535 vs. 0.316
# Precision = 0.472 vs. 0.188
# Recall = 0.618 vs. 0.986
# Minibatch Loss= 4.005073
# Train Batch Evaluation
# AUC = 0.566 vs. 0.308
# F1 = 0.597 vs. 0.478
# Precision = 0.576 vs. 0.314
# Recall = 0.620 vs. 1.000
# Validation
# AUC = 0.463 vs. 0.190
# F1 = 0.535 vs. 0.316
# Precision = 0.472 vs. 0.188
# Recall = 0.618 vs. 0.980
# Minibatch Loss= 3.987011
# Train Batch Evaluation
# AUC = 0.567 vs. 0.312
# F1 = 0.597 vs. 0.478
# Precision = 0.575 vs. 0.314
# Recall = 0.620 vs. 1.000
# Validation
# AUC = 0.454 vs. 0.192
# F1 = 0.536 vs. 0.315
# Precision = 0.473 vs. 0.187
# Recall = 0.618 vs. 1.000
# Minibatch Loss= 3.969060
# Train Batch Evaluation
# AUC = 0.568 vs. 0.313
# F1 = 0.597 vs. 0.478
# Precision = 0.577 vs. 0.314
# Recall = 0.618 vs. 0.998
# Validation
# AUC = 0.429 vs. 0.178
# F1 = 0.536 vs. 0.316
# Precision = 0.473 vs. 0.188
# Recall = 0.618 vs. 0.991
# Minibatch Loss= 3.951220
# Train Batch Evaluation
# AUC = 0.568 vs. 0.308
# F1 = 0.597 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.617 vs. 1.000
# Validation
# AUC = 0.450 vs. 0.198
# F1 = 0.534 vs. 0.315
# Precision = 0.471 vs. 0.187
# Recall = 0.618 vs. 1.000
# Minibatch Loss= 3.933491
# Train Batch Evaluation
# AUC = 0.566 vs. 0.311
# F1 = 0.596 vs. 0.478
# Precision = 0.581 vs. 0.314
# Recall = 0.612 vs. 1.000
# Validation
# AUC = 0.443 vs. 0.183
# F1 = 0.534 vs. 0.320
# Precision = 0.471 vs. 0.196
# Recall = 0.618 vs. 0.872
# Minibatch Loss= 3.915874
# Train Batch Evaluation
# AUC = 0.569 vs. 0.317
# F1 = 0.596 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.613 vs. 1.000
# Validation
# AUC = 0.455 vs. 0.184
# F1 = 0.534 vs. 0.316
# Precision = 0.471 vs. 0.189
# Recall = 0.618 vs. 0.974
# Minibatch Loss= 3.898369
# Train Batch Evaluation
# AUC = 0.569 vs. 0.303
# F1 = 0.597 vs. 0.478
# Precision = 0.581 vs. 0.314
# Recall = 0.613 vs. 0.999
# Validation
# AUC = 0.451 vs. 0.199
# F1 = 0.533 vs. 0.316
# Precision = 0.471 vs. 0.188
# Recall = 0.615 vs. 1.000
# Minibatch Loss= 3.880977
# Train Batch Evaluation
# AUC = 0.569 vs. 0.311
# F1 = 0.597 vs. 0.478
# Precision = 0.581 vs. 0.314
# Recall = 0.613 vs. 1.000
# Validation
# AUC = 0.440 vs. 0.181
# F1 = 0.533 vs. 0.315
# Precision = 0.467 vs. 0.187
# Recall = 0.621 vs. 0.997
# Minibatch Loss= 3.863698
# Train Batch Evaluation
# AUC = 0.572 vs. 0.316
# F1 = 0.596 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.613 vs. 1.000
# Validation
# AUC = 0.451 vs. 0.190
# F1 = 0.533 vs. 0.320
# Precision = 0.466 vs. 0.195
# Recall = 0.624 vs. 0.892
# Minibatch Loss= 3.846533
# Train Batch Evaluation
# AUC = 0.567 vs. 0.312
# F1 = 0.596 vs. 0.478
# Precision = 0.564 vs. 0.314
# Recall = 0.632 vs. 1.000
# Validation
# AUC = 0.437 vs. 0.190
# F1 = 0.534 vs. 0.315
# Precision = 0.467 vs. 0.190
# Recall = 0.624 vs. 0.915
# Minibatch Loss= 3.829481
# Train Batch Evaluation
# AUC = 0.572 vs. 0.312
# F1 = 0.596 vs. 0.478
# Precision = 0.565 vs. 0.314
# Recall = 0.631 vs. 1.000
# Validation
# AUC = 0.456 vs. 0.206
# F1 = 0.532 vs. 0.315
# Precision = 0.466 vs. 0.187
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 3.812544
# Train Batch Evaluation
# AUC = 0.574 vs. 0.321
# F1 = 0.597 vs. 0.478
# Precision = 0.561 vs. 0.314
# Recall = 0.636 vs. 0.999
# Validation
# AUC = 0.454 vs. 0.185
# F1 = 0.530 vs. 0.316
# Precision = 0.460 vs. 0.188
# Recall = 0.624 vs. 0.997
# Minibatch Loss= 3.795722
# Train Batch Evaluation
# AUC = 0.568 vs. 0.319
# F1 = 0.596 vs. 0.478
# Precision = 0.560 vs. 0.315
# Recall = 0.638 vs. 0.989
# Validation
# AUC = 0.449 vs. 0.202
# F1 = 0.528 vs. 0.315
# Precision = 0.463 vs. 0.187
# Recall = 0.615 vs. 1.000
# Minibatch Loss= 3.779015
# Train Batch Evaluation
# AUC = 0.570 vs. 0.314
# F1 = 0.597 vs. 0.478
# Precision = 0.559 vs. 0.314
# Recall = 0.641 vs. 0.999
# Validation
# AUC = 0.455 vs. 0.188
# F1 = 0.526 vs. 0.314
# Precision = 0.455 vs. 0.186
# Recall = 0.624 vs. 1.000
# Minibatch Loss= 3.762424
# Train Batch Evaluation
# AUC = 0.566 vs. 0.316
# F1 = 0.597 vs. 0.478
# Precision = 0.563 vs. 0.314
# Recall = 0.635 vs. 1.000
# Validation
# AUC = 0.468 vs. 0.178
# F1 = 0.525 vs. 0.318
# Precision = 0.448 vs. 0.189
# Recall = 0.635 vs. 0.997
# Minibatch Loss= 3.745949
# Train Batch Evaluation
# AUC = 0.569 vs. 0.315
# F1 = 0.598 vs. 0.478
# Precision = 0.562 vs. 0.314
# Recall = 0.638 vs. 1.000
# Validation
# AUC = 0.457 vs. 0.193
# F1 = 0.527 vs. 0.315
# Precision = 0.451 vs. 0.187
# Recall = 0.635 vs. 0.991
# Minibatch Loss= 3.729590
# Train Batch Evaluation
# AUC = 0.571 vs. 0.322
# F1 = 0.598 vs. 0.478
# Precision = 0.568 vs. 0.315
# Recall = 0.631 vs. 0.994
# Validation
# AUC = 0.444 vs. 0.171
# F1 = 0.529 vs. 0.315
# Precision = 0.456 vs. 0.189
# Recall = 0.630 vs. 0.934
# Minibatch Loss= 3.713347
# Train Batch Evaluation
# AUC = 0.570 vs. 0.313
# F1 = 0.598 vs. 0.478
# Precision = 0.561 vs. 0.314
# Recall = 0.640 vs. 1.000
# Validation
# AUC = 0.460 vs. 0.188
# F1 = 0.526 vs. 0.314
# Precision = 0.452 vs. 0.186
# Recall = 0.630 vs. 1.000
# Minibatch Loss= 3.697222
# Train Batch Evaluation
# AUC = 0.569 vs. 0.315
# F1 = 0.598 vs. 0.478
# Precision = 0.561 vs. 0.314
# Recall = 0.641 vs. 1.000
# Validation
# AUC = 0.447 vs. 0.180
# F1 = 0.527 vs. 0.317
# Precision = 0.451 vs. 0.192
# Recall = 0.632 vs. 0.920
# Minibatch Loss= 3.681213
# Train Batch Evaluation
# AUC = 0.566 vs. 0.313
# F1 = 0.598 vs. 0.478
# Precision = 0.563 vs. 0.314
# Recall = 0.638 vs. 0.999
# Validation
# AUC = 0.442 vs. 0.200
# F1 = 0.525 vs. 0.319
# Precision = 0.448 vs. 0.195
# Recall = 0.632 vs. 0.877
# Minibatch Loss= 3.665322
# Train Batch Evaluation
# AUC = 0.570 vs. 0.313
# F1 = 0.598 vs. 0.478
# Precision = 0.569 vs. 0.314
# Recall = 0.630 vs. 1.000
# Validation
# AUC = 0.451 vs. 0.193
# F1 = 0.523 vs. 0.320
# Precision = 0.447 vs. 0.197
# Recall = 0.630 vs. 0.849
# Minibatch Loss= 3.649549
# Train Batch Evaluation
# AUC = 0.577 vs. 0.318
# F1 = 0.598 vs. 0.478
# Precision = 0.569 vs. 0.314
# Recall = 0.630 vs. 0.997
# Validation
# AUC = 0.444 vs. 0.182
# F1 = 0.523 vs. 0.314
# Precision = 0.456 vs. 0.186
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 3.633894
# Train Batch Evaluation
# AUC = 0.576 vs. 0.309
# F1 = 0.598 vs. 0.478
# Precision = 0.569 vs. 0.314
# Recall = 0.629 vs. 1.000
# Validation
# AUC = 0.460 vs. 0.184
# F1 = 0.524 vs. 0.314
# Precision = 0.457 vs. 0.186
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 3.618358
# Train Batch Evaluation
# AUC = 0.568 vs. 0.313
# F1 = 0.597 vs. 0.478
# Precision = 0.567 vs. 0.314
# Recall = 0.631 vs. 1.000
# Validation
# AUC = 0.464 vs. 0.180
# F1 = 0.524 vs. 0.316
# Precision = 0.457 vs. 0.188
# Recall = 0.613 vs. 1.000
# Minibatch Loss= 3.602940
# Train Batch Evaluation
# AUC = 0.579 vs. 0.323
# F1 = 0.597 vs. 0.478
# Precision = 0.561 vs. 0.314
# Recall = 0.639 vs. 0.999
# Validation
# AUC = 0.434 vs. 0.200
# F1 = 0.522 vs. 0.318
# Precision = 0.455 vs. 0.190
# Recall = 0.613 vs. 0.974
# Minibatch Loss= 3.587641
# Train Batch Evaluation
# AUC = 0.571 vs. 0.312
# F1 = 0.597 vs. 0.478
# Precision = 0.556 vs. 0.314
# Recall = 0.645 vs. 0.999
# Validation
# AUC = 0.464 vs. 0.198
# F1 = 0.522 vs. 0.316
# Precision = 0.425 vs. 0.193
# Recall = 0.675 vs. 0.863
# Minibatch Loss= 3.572461
# Train Batch Evaluation
# AUC = 0.576 vs. 0.314
# F1 = 0.597 vs. 0.478
# Precision = 0.561 vs. 0.314
# Recall = 0.639 vs. 0.999
# Validation
# AUC = 0.454 vs. 0.185
# F1 = 0.522 vs. 0.315
# Precision = 0.468 vs. 0.187
# Recall = 0.590 vs. 0.997
# Minibatch Loss= 3.557400
# Train Batch Evaluation
# AUC = 0.574 vs. 0.312
# F1 = 0.598 vs. 0.478
# Precision = 0.561 vs. 0.314
# Recall = 0.640 vs. 1.000
# Validation
# AUC = 0.464 vs. 0.185
# F1 = 0.522 vs. 0.315
# Precision = 0.468 vs. 0.187
# Recall = 0.590 vs. 0.994
# Minibatch Loss= 3.542459
# Train Batch Evaluation
# AUC = 0.572 vs. 0.312
# F1 = 0.597 vs. 0.478
# Precision = 0.559 vs. 0.314
# Recall = 0.640 vs. 1.000
# Validation
# AUC = 0.465 vs. 0.218
# F1 = 0.522 vs. 0.316
# Precision = 0.423 vs. 0.205
# Recall = 0.684 vs. 0.687
# Minibatch Loss= 3.527637
# Train Batch Evaluation
# AUC = 0.575 vs. 0.311
# F1 = 0.597 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.616 vs. 0.999
# Validation
# AUC = 0.462 vs. 0.186
# F1 = 0.522 vs. 0.318
# Precision = 0.423 vs. 0.190
# Recall = 0.684 vs. 0.974
# Minibatch Loss= 3.512934
# Train Batch Evaluation
# AUC = 0.573 vs. 0.317
# F1 = 0.598 vs. 0.478
# Precision = 0.583 vs. 0.314
# Recall = 0.613 vs. 1.000
# Validation
# AUC = 0.456 vs. 0.189
# F1 = 0.523 vs. 0.318
# Precision = 0.421 vs. 0.190
# Recall = 0.689 vs. 0.972
# Minibatch Loss= 3.498349
# Train Batch Evaluation
# AUC = 0.578 vs. 0.313
# F1 = 0.598 vs. 0.478
# Precision = 0.573 vs. 0.314
# Recall = 0.625 vs. 1.000
# Validation
# AUC = 0.468 vs. 0.201
# F1 = 0.522 vs. 0.316
# Precision = 0.420 vs. 0.189
# Recall = 0.689 vs. 0.974
# Minibatch Loss= 3.483884
# Train Batch Evaluation
# AUC = 0.575 vs. 0.321
# F1 = 0.598 vs. 0.478
# Precision = 0.583 vs. 0.315
# Recall = 0.615 vs. 0.996
# Validation
# AUC = 0.458 vs. 0.182
# F1 = 0.522 vs. 0.316
# Precision = 0.420 vs. 0.188
# Recall = 0.689 vs. 0.997
# Minibatch Loss= 3.469538
# Train Batch Evaluation
# AUC = 0.572 vs. 0.310
# F1 = 0.599 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.618 vs. 1.000
# Validation
# AUC = 0.460 vs. 0.195
# F1 = 0.522 vs. 0.314
# Precision = 0.424 vs. 0.187
# Recall = 0.678 vs. 0.991
# Minibatch Loss= 3.455311
# Train Batch Evaluation
# AUC = 0.575 vs. 0.309
# F1 = 0.599 vs. 0.478
# Precision = 0.580 vs. 0.314
# Recall = 0.619 vs. 1.000
# Validation
# AUC = 0.461 vs. 0.183
# F1 = 0.525 vs. 0.316
# Precision = 0.418 vs. 0.190
# Recall = 0.707 vs. 0.943
# Minibatch Loss= 3.441201
# Train Batch Evaluation
# AUC = 0.575 vs. 0.313
# F1 = 0.599 vs. 0.478
# Precision = 0.577 vs. 0.314
# Recall = 0.622 vs. 1.000
# Validation
# AUC = 0.461 vs. 0.170
# F1 = 0.528 vs. 0.315
# Precision = 0.422 vs. 0.187
# Recall = 0.704 vs. 1.000
# Minibatch Loss= 3.427209
# Train Batch Evaluation
# AUC = 0.574 vs. 0.314
# F1 = 0.599 vs. 0.478
# Precision = 0.578 vs. 0.314
# Recall = 0.621 vs. 0.999
# Validation
# AUC = 0.465 vs. 0.187
# F1 = 0.527 vs. 0.318
# Precision = 0.423 vs. 0.196
# Recall = 0.701 vs. 0.849
# Minibatch Loss= 3.413335
# Train Batch Evaluation
# AUC = 0.575 vs. 0.312
# F1 = 0.599 vs. 0.478
# Precision = 0.577 vs. 0.315
# Recall = 0.622 vs. 0.993
# Validation
# AUC = 0.464 vs. 0.197
# F1 = 0.527 vs. 0.315
# Precision = 0.423 vs. 0.187
# Recall = 0.701 vs. 1.000
# Minibatch Loss= 3.399577
# Train Batch Evaluation
# AUC = 0.574 vs. 0.315
# F1 = 0.598 vs. 0.478
# Precision = 0.582 vs. 0.314
# Recall = 0.616 vs. 1.000
# Validation
# AUC = 0.456 vs. 0.192
# F1 = 0.526 vs. 0.316
# Precision = 0.424 vs. 0.191
# Recall = 0.695 vs. 0.915
# Minibatch Loss= 3.385936
# Train Batch Evaluation
# AUC = 0.573 vs. 0.314
# F1 = 0.599 vs. 0.478
# Precision = 0.573 vs. 0.314
# Recall = 0.628 vs. 0.999
# Validation
# AUC = 0.451 vs. 0.202
# F1 = 0.527 vs. 0.320
# Precision = 0.426 vs. 0.197
# Recall = 0.689 vs. 0.863
# Minibatch Loss= 3.372411
# Train Batch Evaluation
# AUC = 0.576 vs. 0.304
# F1 = 0.599 vs. 0.478
# Precision = 0.573 vs. 0.314
# Recall = 0.627 vs. 1.000
# Validation
# AUC = 0.451 vs. 0.186
# F1 = 0.527 vs. 0.317
# Precision = 0.426 vs. 0.189
# Recall = 0.692 vs. 0.989
# Minibatch Loss= 3.359000
# Train Batch Evaluation
# AUC = 0.573 vs. 0.312
# F1 = 0.599 vs. 0.478
# Precision = 0.574 vs. 0.314
# Recall = 0.627 vs. 1.000
# Validation
# AUC = 0.464 vs. 0.201
# F1 = 0.528 vs. 0.314
# Precision = 0.426 vs. 0.186
# Recall = 0.692 vs. 1.000
# Minibatch Loss= 3.345704
# Train Batch Evaluation
# AUC = 0.579 vs. 0.320
# F1 = 0.599 vs. 0.478
# Precision = 0.570 vs. 0.315
# Recall = 0.632 vs. 0.996
# Validation
# AUC = 0.452 vs. 0.183
# F1 = 0.527 vs. 0.316
# Precision = 0.426 vs. 0.188
# Recall = 0.692 vs. 0.989
# Minibatch Loss= 3.332523
# Train Batch Evaluation
# AUC = 0.583 vs. 0.316
# F1 = 0.600 vs. 0.478
# Precision = 0.572 vs. 0.314
# Recall = 0.630 vs. 1.000
# Validation
# AUC = 0.472 vs. 0.178
# F1 = 0.527 vs. 0.315
# Precision = 0.422 vs. 0.187
# Recall = 0.701 vs. 1.000
# Minibatch Loss= 3.319454
# Train Batch Evaluation
# AUC = 0.581 vs. 0.315
# F1 = 0.599 vs. 0.478
# Precision = 0.569 vs. 0.315
# Recall = 0.634 vs. 0.997
# Validation
# AUC = 0.467 vs. 0.198
# F1 = 0.527 vs. 0.314
# Precision = 0.425 vs. 0.189
# Recall = 0.692 vs. 0.946
# Minibatch Loss= 3.306498
# Train Batch Evaluation
# AUC = 0.575 vs. 0.317
# F1 = 0.601 vs. 0.478
# Precision = 0.567 vs. 0.315
# Recall = 0.639 vs. 0.988
# Validation
# AUC = 0.463 vs. 0.196
# F1 = 0.526 vs. 0.316
# Precision = 0.425 vs. 0.188
# Recall = 0.689 vs. 0.994
# Minibatch Loss= 3.293653
# Train Batch Evaluation
# AUC = 0.573 vs. 0.309
# F1 = 0.601 vs. 0.478
# Precision = 0.566 vs. 0.314
# Recall = 0.639 vs. 1.000
# Validation
# AUC = 0.476 vs. 0.183
# F1 = 0.527 vs. 0.318
# Precision = 0.420 vs. 0.192
# Recall = 0.707 vs. 0.915
# Minibatch Loss= 3.280920
# Train Batch Evaluation
# AUC = 0.577 vs. 0.314
# F1 = 0.601 vs. 0.478
# Precision = 0.565 vs. 0.314
# Recall = 0.642 vs. 0.997
# Validation
# AUC = 0.461 vs. 0.187
# F1 = 0.527 vs. 0.314
# Precision = 0.422 vs. 0.189
# Recall = 0.704 vs. 0.920
# Minibatch Loss= 3.268296
# Train Batch Evaluation
# AUC = 0.578 vs. 0.314
# F1 = 0.601 vs. 0.478
# Precision = 0.566 vs. 0.314
# Recall = 0.641 vs. 1.000
# Validation
# AUC = 0.452 vs. 0.201
# F1 = 0.528 vs. 0.314
# Precision = 0.425 vs. 0.187
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 3.255782
# Train Batch Evaluation
# AUC = 0.578 vs. 0.316
# F1 = 0.601 vs. 0.478
# Precision = 0.567 vs. 0.315
# Recall = 0.641 vs. 0.998
# Validation
# AUC = 0.461 vs. 0.202
# F1 = 0.528 vs. 0.317
# Precision = 0.467 vs. 0.202
# Recall = 0.607 vs. 0.735
# Minibatch Loss= 3.243375
# Train Batch Evaluation
# AUC = 0.580 vs. 0.306
# F1 = 0.601 vs. 0.478
# Precision = 0.567 vs. 0.314
# Recall = 0.640 vs. 1.000
# Validation
# AUC = 0.472 vs. 0.196
# F1 = 0.528 vs. 0.316
# Precision = 0.423 vs. 0.190
# Recall = 0.704 vs. 0.940
# Minibatch Loss= 3.231077
# Train Batch Evaluation
# AUC = 0.580 vs. 0.310
# F1 = 0.602 vs. 0.478
# Precision = 0.567 vs. 0.314
# Recall = 0.641 vs. 1.000
# Validation
# AUC = 0.465 vs. 0.184
# F1 = 0.529 vs. 0.314
# Precision = 0.445 vs. 0.186
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 3.218885
# Train Batch Evaluation
# AUC = 0.588 vs. 0.310
# F1 = 0.602 vs. 0.478
# Precision = 0.567 vs. 0.314
# Recall = 0.642 vs. 1.000
# Validation
# AUC = 0.466 vs. 0.210
# F1 = 0.529 vs. 0.316
# Precision = 0.446 vs. 0.188
# Recall = 0.652 vs. 0.997
# Minibatch Loss= 3.206799
# Train Batch Evaluation
# AUC = 0.581 vs. 0.315
# F1 = 0.602 vs. 0.478
# Precision = 0.568 vs. 0.314
# Recall = 0.641 vs. 0.997
# Validation
# AUC = 0.480 vs. 0.196
# F1 = 0.530 vs. 0.315
# Precision = 0.446 vs. 0.187
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 3.194818
# Train Batch Evaluation
# AUC = 0.582 vs. 0.309
# F1 = 0.602 vs. 0.478
# Precision = 0.568 vs. 0.314
# Recall = 0.641 vs. 0.999
# Validation
# AUC = 0.478 vs. 0.186
# F1 = 0.530 vs. 0.316
# Precision = 0.446 vs. 0.189
# Recall = 0.652 vs. 0.974
# Minibatch Loss= 3.182941
# Train Batch Evaluation
# AUC = 0.584 vs. 0.313
# F1 = 0.602 vs. 0.478
# Precision = 0.553 vs. 0.314
# Recall = 0.662 vs. 1.000
# Validation
# AUC = 0.458 vs. 0.181
# F1 = 0.529 vs. 0.314
# Precision = 0.455 vs. 0.186
# Recall = 0.632 vs. 1.000
# Minibatch Loss= 3.171168
# Train Batch Evaluation
# AUC = 0.580 vs. 0.324
# F1 = 0.603 vs. 0.478
# Precision = 0.559 vs. 0.314
# Recall = 0.655 vs. 0.999
# Validation
# AUC = 0.465 vs. 0.178
# F1 = 0.530 vs. 0.314
# Precision = 0.459 vs. 0.187
# Recall = 0.627 vs. 0.997
# Minibatch Loss= 3.159498
# Train Batch Evaluation
# AUC = 0.584 vs. 0.316
# F1 = 0.603 vs. 0.478
# Precision = 0.561 vs. 0.314
# Recall = 0.652 vs. 1.000
# Validation
# AUC = 0.470 vs. 0.197
# F1 = 0.533 vs. 0.314
# Precision = 0.461 vs. 0.187
# Recall = 0.632 vs. 0.983
# Minibatch Loss= 3.147929
# Train Batch Evaluation
# AUC = 0.586 vs. 0.312
# F1 = 0.604 vs. 0.478
# Precision = 0.562 vs. 0.314
# Recall = 0.653 vs. 0.997
# Validation
# AUC = 0.486 vs. 0.194
# F1 = 0.533 vs. 0.317
# Precision = 0.461 vs. 0.190
# Recall = 0.632 vs. 0.952
# Minibatch Loss= 3.136463
# Train Batch Evaluation
# AUC = 0.582 vs. 0.305
# F1 = 0.605 vs. 0.478
# Precision = 0.563 vs. 0.314
# Recall = 0.653 vs. 0.998
# Validation
# AUC = 0.468 vs. 0.181
# F1 = 0.534 vs. 0.314
# Precision = 0.462 vs. 0.186
# Recall = 0.632 vs. 1.000
# Minibatch Loss= 3.125096
# Train Batch Evaluation
# AUC = 0.579 vs. 0.317
# F1 = 0.605 vs. 0.478
# Precision = 0.562 vs. 0.315
# Recall = 0.655 vs. 0.994
# Validation
# AUC = 0.478 vs. 0.178
# F1 = 0.534 vs. 0.315
# Precision = 0.464 vs. 0.187
# Recall = 0.630 vs. 1.000
# Minibatch Loss= 3.113829
# Train Batch Evaluation
# AUC = 0.587 vs. 0.309
# F1 = 0.605 vs. 0.478
# Precision = 0.566 vs. 0.314
# Recall = 0.650 vs. 1.000
# Validation
# AUC = 0.472 vs. 0.193
# F1 = 0.535 vs. 0.320
# Precision = 0.461 vs. 0.194
# Recall = 0.638 vs. 0.903
# Minibatch Loss= 3.102661
# Train Batch Evaluation
# AUC = 0.587 vs. 0.306
# ...
# Precision = 0.651 vs. 0.315
# Recall = 0.849 vs. 0.997
# Validation
# AUC = 0.575 vs. 0.209
# F1 = 0.637 vs. 0.321
# Precision = 0.554 vs. 0.193
# Recall = 0.749 vs. 0.946
# Minibatch Loss= 0.573813
# Train Batch Evaluation
# AUC = 0.736 vs. 0.308
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.203
# F1 = 0.637 vs. 0.322
# Precision = 0.554 vs. 0.198
# Recall = 0.749 vs. 0.858
# Minibatch Loss= 0.573811
# Train Batch Evaluation
# AUC = 0.736 vs. 0.317
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.193
# F1 = 0.637 vs. 0.322
# Precision = 0.554 vs. 0.193
# Recall = 0.749 vs. 0.972
# Minibatch Loss= 0.573809
# Train Batch Evaluation
# AUC = 0.736 vs. 0.310
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.997
# Validation
# AUC = 0.575 vs. 0.183
# F1 = 0.637 vs. 0.317
# Precision = 0.554 vs. 0.189
# Recall = 0.749 vs. 0.983
# Minibatch Loss= 0.573806
# Train Batch Evaluation
# AUC = 0.736 vs. 0.310
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.210
# F1 = 0.637 vs. 0.314
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 0.986
# Minibatch Loss= 0.573804
# Train Batch Evaluation
# AUC = 0.736 vs. 0.314
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.198
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.980
# Minibatch Loss= 0.573802
# Train Batch Evaluation
# AUC = 0.736 vs. 0.315
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.183
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.190
# Recall = 0.749 vs. 0.920
# Minibatch Loss= 0.573800
# Train Batch Evaluation
# AUC = 0.736 vs. 0.318
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.178
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573798
# Train Batch Evaluation
# AUC = 0.736 vs. 0.315
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.199
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.994
# Minibatch Loss= 0.573795
# Train Batch Evaluation
# AUC = 0.736 vs. 0.311
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.180
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.994
# Minibatch Loss= 0.573793
# Train Batch Evaluation
# AUC = 0.736 vs. 0.321
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.180
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.189
# Recall = 0.749 vs. 0.966
# Minibatch Loss= 0.573791
# Train Batch Evaluation
# AUC = 0.736 vs. 0.316
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.315
# Recall = 0.850 vs. 0.997
# Validation
# AUC = 0.575 vs. 0.186
# F1 = 0.637 vs. 0.318
# Precision = 0.554 vs. 0.190
# Recall = 0.749 vs. 0.986
# Minibatch Loss= 0.573789
# Train Batch Evaluation
# AUC = 0.736 vs. 0.313
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.315
# Recall = 0.850 vs. 0.995
# Validation
# AUC = 0.575 vs. 0.188
# F1 = 0.637 vs. 0.317
# Precision = 0.554 vs. 0.189
# Recall = 0.749 vs. 0.989
# Minibatch Loss= 0.573787
# Train Batch Evaluation
# AUC = 0.736 vs. 0.318
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.187
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.991
# Minibatch Loss= 0.573784
# Train Batch Evaluation
# AUC = 0.736 vs. 0.323
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.185
# F1 = 0.637 vs. 0.314
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573782
# Train Batch Evaluation
# AUC = 0.736 vs. 0.317
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.997
# Validation
# AUC = 0.575 vs. 0.189
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573780
# Train Batch Evaluation
# AUC = 0.736 vs. 0.313
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.187
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.986
# Minibatch Loss= 0.573778
# Train Batch Evaluation
# AUC = 0.736 vs. 0.320
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.175
# F1 = 0.637 vs. 0.317
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.573775
# Train Batch Evaluation
# AUC = 0.736 vs. 0.311
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.186
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.573773
# Train Batch Evaluation
# AUC = 0.736 vs. 0.314
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.209
# F1 = 0.637 vs. 0.319
# Precision = 0.554 vs. 0.194
# Recall = 0.749 vs. 0.897
# Minibatch Loss= 0.573771
# Train Batch Evaluation
# AUC = 0.736 vs. 0.315
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.198
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573769
# Train Batch Evaluation
# AUC = 0.736 vs. 0.315
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.998
# Validation
# AUC = 0.575 vs. 0.175
# F1 = 0.637 vs. 0.319
# Precision = 0.554 vs. 0.191
# Recall = 0.749 vs. 0.972
# Minibatch Loss= 0.573767
# Train Batch Evaluation
# AUC = 0.736 vs. 0.313
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.197
# F1 = 0.637 vs. 0.321
# Precision = 0.554 vs. 0.194
# Recall = 0.749 vs. 0.929
# Minibatch Loss= 0.573765
# Train Batch Evaluation
# AUC = 0.736 vs. 0.317
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.200
# F1 = 0.637 vs. 0.321
# Precision = 0.554 vs. 0.196
# Recall = 0.749 vs. 0.883
# Minibatch Loss= 0.573762
# Train Batch Evaluation
# AUC = 0.736 vs. 0.316
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.997
# Validation
# AUC = 0.575 vs. 0.189
# F1 = 0.637 vs. 0.317
# Precision = 0.554 vs. 0.189
# Recall = 0.749 vs. 0.989
# Minibatch Loss= 0.573760
# Train Batch Evaluation
# AUC = 0.736 vs. 0.318
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.189
# F1 = 0.637 vs. 0.314
# Precision = 0.554 vs. 0.186
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573758
# Train Batch Evaluation
# AUC = 0.736 vs. 0.319
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.193
# F1 = 0.637 vs. 0.317
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.573756
# Train Batch Evaluation
# AUC = 0.736 vs. 0.306
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.171
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.994
# Minibatch Loss= 0.573754
# Train Batch Evaluation
# AUC = 0.736 vs. 0.313
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.190
# F1 = 0.637 vs. 0.314
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 0.972
# Minibatch Loss= 0.573751
# Train Batch Evaluation
# AUC = 0.736 vs. 0.307
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.196
# F1 = 0.637 vs. 0.318
# Precision = 0.554 vs. 0.190
# Recall = 0.749 vs. 0.966
# Minibatch Loss= 0.573749
# Train Batch Evaluation
# AUC = 0.736 vs. 0.314
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.190
# F1 = 0.637 vs. 0.319
# Precision = 0.554 vs. 0.191
# Recall = 0.749 vs. 0.969
# Minibatch Loss= 0.573747
# Train Batch Evaluation
# AUC = 0.736 vs. 0.310
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.998
# Validation
# AUC = 0.575 vs. 0.190
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.573745
# Train Batch Evaluation
# AUC = 0.736 vs. 0.311
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.206
# F1 = 0.637 vs. 0.321
# Precision = 0.554 vs. 0.193
# Recall = 0.749 vs. 0.957
# Minibatch Loss= 0.573743
# Train Batch Evaluation
# AUC = 0.736 vs. 0.312
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.191
# F1 = 0.637 vs. 0.317
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.994
# Minibatch Loss= 0.573741
# Train Batch Evaluation
# AUC = 0.736 vs. 0.314
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.191
# F1 = 0.637 vs. 0.318
# Precision = 0.554 vs. 0.189
# Recall = 0.749 vs. 0.991
# Minibatch Loss= 0.573738
# Train Batch Evaluation
# AUC = 0.736 vs. 0.316
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.178
# F1 = 0.637 vs. 0.318
# Precision = 0.554 vs. 0.189
# Recall = 0.749 vs. 0.989
# Minibatch Loss= 0.573736
# Train Batch Evaluation
# AUC = 0.736 vs. 0.314
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.177
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573734
# Train Batch Evaluation
# AUC = 0.736 vs. 0.320
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.994
# Validation
# AUC = 0.575 vs. 0.197
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.991
# Minibatch Loss= 0.573732
# Train Batch Evaluation
# AUC = 0.736 vs. 0.321
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.315
# Recall = 0.849 vs. 0.991
# Validation
# AUC = 0.575 vs. 0.177
# F1 = 0.637 vs. 0.314
# Precision = 0.554 vs. 0.186
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573730
# Train Batch Evaluation
# AUC = 0.736 vs. 0.316
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.187
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 0.989
# Minibatch Loss= 0.573728
# Train Batch Evaluation
# AUC = 0.736 vs. 0.319
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.177
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573725
# Train Batch Evaluation
# AUC = 0.736 vs. 0.315
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.172
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573723
# Train Batch Evaluation
# AUC = 0.736 vs. 0.320
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.182
# F1 = 0.637 vs. 0.314
# Precision = 0.554 vs. 0.186
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573721
# Train Batch Evaluation
# AUC = 0.736 vs. 0.317
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.214
# F1 = 0.637 vs. 0.320
# Precision = 0.554 vs. 0.192
# Recall = 0.749 vs. 0.969
# Minibatch Loss= 0.573719
# Train Batch Evaluation
# AUC = 0.736 vs. 0.307
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.177
# F1 = 0.637 vs. 0.317
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.989
# Minibatch Loss= 0.573717
# Train Batch Evaluation
# AUC = 0.736 vs. 0.315
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.183
# F1 = 0.637 vs. 0.314
# Precision = 0.554 vs. 0.186
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573715
# Train Batch Evaluation
# AUC = 0.736 vs. 0.304
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.194
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573712
# Train Batch Evaluation
# AUC = 0.736 vs. 0.317
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.178
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.573710
# Train Batch Evaluation
# AUC = 0.736 vs. 0.318
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.195
# F1 = 0.637 vs. 0.320
# Precision = 0.554 vs. 0.201
# Recall = 0.749 vs. 0.781
# Minibatch Loss= 0.573708
# Train Batch Evaluation
# AUC = 0.736 vs. 0.312
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.998
# Validation
# AUC = 0.575 vs. 0.191
# F1 = 0.637 vs. 0.316
# Precision = 0.554 vs. 0.188
# Recall = 0.749 vs. 0.986
# Minibatch Loss= 0.573706
# Train Batch Evaluation
# AUC = 0.736 vs. 0.312
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.181
# F1 = 0.637 vs. 0.315
# Precision = 0.554 vs. 0.187
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.573704
# Train Batch Evaluation
# AUC = 0.736 vs. 0.312
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.190
# F1 = 0.637 vs. 0.319
# Precision = 0.554 vs. 0.192
# Recall = 0.749 vs. 0.946
# Minibatch Loss= 0.573702
# Train Batch Evaluation
# AUC = 0.736 vs. 0.312
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.201
# F1 = 0.636 vs. 0.321
# Precision = 0.553 vs. 0.193
# Recall = 0.749 vs. 0.937
# Minibatch Loss= 0.573700
# Train Batch Evaluation
# AUC = 0.736 vs. 0.326
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.171
# F1 = 0.636 vs. 0.314
# Precision = 0.553 vs. 0.186
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573697
# Train Batch Evaluation
# AUC = 0.736 vs. 0.311
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.998
# Validation
# AUC = 0.575 vs. 0.189
# F1 = 0.636 vs. 0.315
# Precision = 0.553 vs. 0.188
# Recall = 0.749 vs. 0.980
# Minibatch Loss= 0.573695
# Train Batch Evaluation
# AUC = 0.736 vs. 0.316
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 0.999
# Validation
# AUC = 0.575 vs. 0.178
# F1 = 0.636 vs. 0.317
# Precision = 0.553 vs. 0.188
# Recall = 0.749 vs. 0.991
# Minibatch Loss= 0.573693
# Train Batch Evaluation
# AUC = 0.736 vs. 0.304
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.182
# F1 = 0.636 vs. 0.318
# Precision = 0.553 vs. 0.190
# Recall = 0.749 vs. 0.957
# Minibatch Loss= 0.573691
# Train Batch Evaluation
# AUC = 0.736 vs. 0.314
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.187
# F1 = 0.636 vs. 0.316
# Precision = 0.553 vs. 0.188
# Recall = 0.749 vs. 0.989
# Minibatch Loss= 0.573689
# Train Batch Evaluation
# AUC = 0.736 vs. 0.312
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.315
# Recall = 0.849 vs. 0.995
# Validation
# AUC = 0.575 vs. 0.190
# F1 = 0.636 vs. 0.315
# Precision = 0.553 vs. 0.187
# Recall = 0.749 vs. 0.994
# Minibatch Loss= 0.573687
# Train Batch Evaluation
# AUC = 0.736 vs. 0.310
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.204
# F1 = 0.636 vs. 0.317
# Precision = 0.553 vs. 0.189
# Recall = 0.749 vs. 0.986
# Minibatch Loss= 0.573685
# Train Batch Evaluation
# AUC = 0.736 vs. 0.314
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.315
# Recall = 0.849 vs. 0.993
# Validation
# AUC = 0.575 vs. 0.199
# F1 = 0.636 vs. 0.322
# Precision = 0.553 vs. 0.195
# Recall = 0.749 vs. 0.923
# Minibatch Loss= 0.573682
# Train Batch Evaluation
# AUC = 0.736 vs. 0.322
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.196
# F1 = 0.636 vs. 0.317
# Precision = 0.553 vs. 0.191
# Recall = 0.749 vs. 0.934
# Minibatch Loss= 0.573680
# Train Batch Evaluation
# AUC = 0.736 vs. 0.309
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.190
# F1 = 0.636 vs. 0.314
# Precision = 0.553 vs. 0.186
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.573678
# Train Batch Evaluation
# AUC = 0.736 vs. 0.320
# F1 = 0.737 vs. 0.478
# Precision = 0.651 vs. 0.314
# Recall = 0.850 vs. 1.000
# Validation
# AUC = 0.575 vs. 0.187
# F1 = 0.636 vs. 0.315
# Precision = 0.553 vs. 0.188
# Recall = 0.749 vs. 0.977
# Minibatch Loss= 0.573676

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
