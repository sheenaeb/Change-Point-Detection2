# %%
# useing this variable for saving models and summaries
exp_name = "CNN9002_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval_activity as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp2.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((1, 639875, 77), (1, 639875, 18))

# %%
test_data.shape, test_gt.shape
# Out:
# ((1, 212698, 77), (1, 212698, 18))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 1

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu
n_classes = 18

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[0,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

# %%
pos_weight.shape
# Out:
# (18,)

# %%
pos_weight
# Out:
# array([  0.13937322,  37.6023166 ,  39.97540984,  38.51778656,
#         39.47773279,  28.57988166,  28.49262537,  41.00840336,
#         43.83408072,  49.49494949,  59.22891566,  52.18085106,
#         58.15976331,  45.71962617,  48.00980392,  34.96402878,
#         11.35846724,  39.15261044])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'activity')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 1, 
                validation_eval_step = 1,
                display_step = 1)
# Out:
# Train Batch Evaluation
# AUC = 0.078 vs. 0.076
# F1 = 0.120 vs. 0.105
# Accuracy = 0.003 vs. 0.056
# Validation
# AUC = 0.077 vs. 0.077
# F1 = 0.122 vs. 0.111
# Accuracy = 0.003 vs. 0.056
# Minibatch Loss= 1.376197
# Train Batch Evaluation
# AUC = 0.085 vs. 0.075
# F1 = 0.127 vs. 0.106
# Accuracy = 0.004 vs. 0.056
# Validation
# AUC = 0.084 vs. 0.077
# F1 = 0.131 vs. 0.111
# Accuracy = 0.004 vs. 0.056
# Minibatch Loss= 1.315915
# Train Batch Evaluation
# AUC = 0.095 vs. 0.074
# F1 = 0.144 vs. 0.104
# Accuracy = 0.005 vs. 0.056
# Validation
# AUC = 0.090 vs. 0.077
# F1 = 0.140 vs. 0.113
# Accuracy = 0.006 vs. 0.056
# Minibatch Loss= 1.282445
# Train Batch Evaluation
# AUC = 0.107 vs. 0.075
# F1 = 0.165 vs. 0.105
# Accuracy = 0.008 vs. 0.056
# Validation
# AUC = 0.098 vs. 0.078
# F1 = 0.147 vs. 0.113
# Accuracy = 0.009 vs. 0.056
# Minibatch Loss= 1.258086
# Train Batch Evaluation
# AUC = 0.126 vs. 0.074
# F1 = 0.189 vs. 0.106
# Accuracy = 0.019 vs. 0.056
# Validation
# AUC = 0.108 vs. 0.078
# F1 = 0.160 vs. 0.112
# Accuracy = 0.022 vs. 0.056
# Minibatch Loss= 1.237858
# Train Batch Evaluation
# AUC = 0.148 vs. 0.074
# F1 = 0.214 vs. 0.104
# Accuracy = 0.047 vs. 0.056
# Validation
# AUC = 0.114 vs. 0.077
# F1 = 0.173 vs. 0.112
# Accuracy = 0.056 vs. 0.056
# Minibatch Loss= 1.219102
# Train Batch Evaluation
# AUC = 0.170 vs. 0.076
# F1 = 0.245 vs. 0.107
# Accuracy = 0.081 vs. 0.056
# Validation
# AUC = 0.121 vs. 0.077
# F1 = 0.188 vs. 0.112
# Accuracy = 0.108 vs. 0.056
# Minibatch Loss= 1.200887
# Train Batch Evaluation
# AUC = 0.192 vs. 0.075
# F1 = 0.272 vs. 0.104
# Accuracy = 0.102 vs. 0.056
# Validation
# AUC = 0.127 vs. 0.078
# F1 = 0.201 vs. 0.113
# Accuracy = 0.144 vs. 0.056
# Minibatch Loss= 1.182477
# Train Batch Evaluation
# AUC = 0.211 vs. 0.076
# F1 = 0.292 vs. 0.105
# Accuracy = 0.116 vs. 0.056
# Validation
# AUC = 0.134 vs. 0.075
# F1 = 0.209 vs. 0.110
# Accuracy = 0.167 vs. 0.056
# Minibatch Loss= 1.162722
# Train Batch Evaluation
# AUC = 0.229 vs. 0.075
# F1 = 0.310 vs. 0.104
# Accuracy = 0.125 vs. 0.056
# Validation
# AUC = 0.139 vs. 0.076
# F1 = 0.218 vs. 0.109
# Accuracy = 0.179 vs. 0.056
# Minibatch Loss= 1.141063
# Train Batch Evaluation
# AUC = 0.244 vs. 0.075
# F1 = 0.325 vs. 0.104
# Accuracy = 0.123 vs. 0.056
# Validation
# AUC = 0.145 vs. 0.078
# F1 = 0.226 vs. 0.111
# Accuracy = 0.178 vs. 0.056
# Minibatch Loss= 1.117352
# Train Batch Evaluation
# AUC = 0.258 vs. 0.075
# F1 = 0.335 vs. 0.105
# Accuracy = 0.118 vs. 0.056
# Validation
# AUC = 0.152 vs. 0.077
# F1 = 0.233 vs. 0.109
# Accuracy = 0.167 vs. 0.056
# Minibatch Loss= 1.091805
# Train Batch Evaluation
# AUC = 0.269 vs. 0.076
# F1 = 0.344 vs. 0.105
# Accuracy = 0.114 vs. 0.056
# Validation
# AUC = 0.157 vs. 0.077
# F1 = 0.239 vs. 0.112
# Accuracy = 0.155 vs. 0.056
# Minibatch Loss= 1.064826
# Train Batch Evaluation
# AUC = 0.278 vs. 0.076
# F1 = 0.353 vs. 0.107
# Accuracy = 0.110 vs. 0.056
# Validation
# AUC = 0.162 vs. 0.077
# F1 = 0.244 vs. 0.111
# Accuracy = 0.145 vs. 0.056
# Minibatch Loss= 1.036637
# Train Batch Evaluation
# AUC = 0.284 vs. 0.075
# F1 = 0.359 vs. 0.105
# Accuracy = 0.108 vs. 0.056
# Validation
# AUC = 0.166 vs. 0.077
# F1 = 0.247 vs. 0.112
# Accuracy = 0.130 vs. 0.056
# Minibatch Loss= 1.007067
# Train Batch Evaluation
# AUC = 0.290 vs. 0.075
# F1 = 0.364 vs. 0.105
# Accuracy = 0.106 vs. 0.056
# Validation
# AUC = 0.171 vs. 0.077
# F1 = 0.251 vs. 0.112
# Accuracy = 0.120 vs. 0.056
# Minibatch Loss= 0.976548
# Train Batch Evaluation
# AUC = 0.295 vs. 0.076
# F1 = 0.367 vs. 0.107
# Accuracy = 0.104 vs. 0.056
# Validation
# AUC = 0.177 vs. 0.075
# F1 = 0.257 vs. 0.111
# Accuracy = 0.116 vs. 0.056
# Minibatch Loss= 0.945600
# Train Batch Evaluation
# AUC = 0.299 vs. 0.075
# F1 = 0.371 vs. 0.105
# Accuracy = 0.102 vs. 0.056
# Validation
# AUC = 0.182 vs. 0.076
# F1 = 0.262 vs. 0.109
# Accuracy = 0.115 vs. 0.056
# Minibatch Loss= 0.915130
# Train Batch Evaluation
# AUC = 0.304 vs. 0.075
# F1 = 0.376 vs. 0.105
# Accuracy = 0.104 vs. 0.056
# Validation
# AUC = 0.188 vs. 0.078
# F1 = 0.267 vs. 0.113
# Accuracy = 0.116 vs. 0.056
# Minibatch Loss= 0.885622
# Train Batch Evaluation
# AUC = 0.308 vs. 0.075
# F1 = 0.382 vs. 0.105
# Accuracy = 0.105 vs. 0.056
# Validation
# AUC = 0.194 vs. 0.077
# F1 = 0.272 vs. 0.113
# Accuracy = 0.114 vs. 0.056
# Minibatch Loss= 0.857522
# Train Batch Evaluation
# AUC = 0.314 vs. 0.076
# F1 = 0.387 vs. 0.106
# Accuracy = 0.110 vs. 0.056
# Validation
# AUC = 0.199 vs. 0.075
# F1 = 0.278 vs. 0.108
# Accuracy = 0.115 vs. 0.056
# Minibatch Loss= 0.830880
# Train Batch Evaluation
# AUC = 0.319 vs. 0.075
# F1 = 0.393 vs. 0.105
# Accuracy = 0.116 vs. 0.056
# Validation
# AUC = 0.203 vs. 0.077
# F1 = 0.285 vs. 0.110
# Accuracy = 0.116 vs. 0.056
# Minibatch Loss= 0.805708
# Train Batch Evaluation
# AUC = 0.325 vs. 0.075
# F1 = 0.398 vs. 0.105
# Accuracy = 0.128 vs. 0.056
# Validation
# AUC = 0.206 vs. 0.077
# F1 = 0.290 vs. 0.109
# Accuracy = 0.119 vs. 0.056
# Minibatch Loss= 0.781602
# Train Batch Evaluation
# AUC = 0.330 vs. 0.077
# F1 = 0.403 vs. 0.106
# Accuracy = 0.141 vs. 0.056
# Validation
# AUC = 0.209 vs. 0.075
# F1 = 0.293 vs. 0.107
# Accuracy = 0.124 vs. 0.056
# Minibatch Loss= 0.758703
# Train Batch Evaluation
# AUC = 0.335 vs. 0.075
# F1 = 0.408 vs. 0.104
# Accuracy = 0.157 vs. 0.056
# Validation
# AUC = 0.211 vs. 0.077
# F1 = 0.297 vs. 0.109
# Accuracy = 0.142 vs. 0.056
# Minibatch Loss= 0.737113
# Train Batch Evaluation
# AUC = 0.340 vs. 0.076
# F1 = 0.412 vs. 0.105
# Accuracy = 0.179 vs. 0.056
# Validation
# AUC = 0.214 vs. 0.076
# F1 = 0.301 vs. 0.113
# Accuracy = 0.161 vs. 0.056
# Minibatch Loss= 0.716716
# Train Batch Evaluation
# AUC = 0.347 vs. 0.075
# F1 = 0.418 vs. 0.105
# Accuracy = 0.219 vs. 0.056
# Validation
# AUC = 0.219 vs. 0.075
# F1 = 0.305 vs. 0.109
# Accuracy = 0.192 vs. 0.056
# Minibatch Loss= 0.697482
# Train Batch Evaluation
# AUC = 0.356 vs. 0.076
# F1 = 0.425 vs. 0.106
# Accuracy = 0.261 vs. 0.056
# Validation
# AUC = 0.223 vs. 0.078
# F1 = 0.310 vs. 0.116
# Accuracy = 0.224 vs. 0.056
# Minibatch Loss= 0.678931
# Train Batch Evaluation
# AUC = 0.365 vs. 0.075
# F1 = 0.433 vs. 0.104
# Accuracy = 0.304 vs. 0.056
# Validation
# AUC = 0.229 vs. 0.075
# F1 = 0.317 vs. 0.107
# Accuracy = 0.247 vs. 0.056
# Minibatch Loss= 0.660766
# Train Batch Evaluation
# AUC = 0.374 vs. 0.076
# F1 = 0.439 vs. 0.106
# Accuracy = 0.344 vs. 0.056
# Validation
# AUC = 0.235 vs. 0.077
# F1 = 0.322 vs. 0.112
# Accuracy = 0.264 vs. 0.056
# Minibatch Loss= 0.643067
# Train Batch Evaluation
# AUC = 0.384 vs. 0.075
# F1 = 0.447 vs. 0.104
# Accuracy = 0.373 vs. 0.056
# Validation
# AUC = 0.241 vs. 0.076
# F1 = 0.329 vs. 0.109
# Accuracy = 0.285 vs. 0.056
# Minibatch Loss= 0.626037
# Train Batch Evaluation
# AUC = 0.395 vs. 0.076
# F1 = 0.454 vs. 0.105
# Accuracy = 0.398 vs. 0.056
# Validation
# AUC = 0.248 vs. 0.078
# F1 = 0.335 vs. 0.114
# Accuracy = 0.299 vs. 0.056
# Minibatch Loss= 0.609512
# Train Batch Evaluation
# AUC = 0.406 vs. 0.075
# F1 = 0.463 vs. 0.105
# Accuracy = 0.414 vs. 0.056
# Validation
# AUC = 0.254 vs. 0.076
# F1 = 0.342 vs. 0.109
# Accuracy = 0.308 vs. 0.056
# Minibatch Loss= 0.593652
# Train Batch Evaluation
# AUC = 0.417 vs. 0.075
# F1 = 0.471 vs. 0.105
# Accuracy = 0.425 vs. 0.056
# Validation
# AUC = 0.259 vs. 0.077
# F1 = 0.347 vs. 0.112
# Accuracy = 0.321 vs. 0.056
# Minibatch Loss= 0.578526
# Train Batch Evaluation
# AUC = 0.427 vs. 0.074
# F1 = 0.479 vs. 0.106
# Accuracy = 0.438 vs. 0.056
# Validation
# AUC = 0.262 vs. 0.077
# F1 = 0.349 vs. 0.113
# Accuracy = 0.331 vs. 0.056
# Minibatch Loss= 0.564189
# Train Batch Evaluation
# AUC = 0.438 vs. 0.076
# F1 = 0.485 vs. 0.107
# Accuracy = 0.459 vs. 0.056
# Validation
# AUC = 0.265 vs. 0.076
# F1 = 0.352 vs. 0.112
# Accuracy = 0.347 vs. 0.056
# Minibatch Loss= 0.550370
# Train Batch Evaluation
# AUC = 0.449 vs. 0.075
# F1 = 0.493 vs. 0.105
# Accuracy = 0.480 vs. 0.056
# Validation
# AUC = 0.269 vs. 0.075
# F1 = 0.354 vs. 0.107
# Accuracy = 0.357 vs. 0.056
# Minibatch Loss= 0.537201
# Train Batch Evaluation
# AUC = 0.459 vs. 0.076
# F1 = 0.502 vs. 0.106
# Accuracy = 0.497 vs. 0.056
# Validation
# AUC = 0.273 vs. 0.077
# F1 = 0.356 vs. 0.111
# Accuracy = 0.377 vs. 0.056
# Minibatch Loss= 0.524841
# Train Batch Evaluation
# AUC = 0.470 vs. 0.075
# F1 = 0.511 vs. 0.104
# Accuracy = 0.505 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.080
# F1 = 0.357 vs. 0.120
# Accuracy = 0.389 vs. 0.056
# Minibatch Loss= 0.513232
# Train Batch Evaluation
# AUC = 0.478 vs. 0.074
# F1 = 0.517 vs. 0.104
# Accuracy = 0.509 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.078
# F1 = 0.359 vs. 0.112
# Accuracy = 0.399 vs. 0.056
# Minibatch Loss= 0.502050
# Train Batch Evaluation
# AUC = 0.488 vs. 0.075
# F1 = 0.524 vs. 0.105
# Accuracy = 0.512 vs. 0.056
# Validation
# AUC = 0.281 vs. 0.077
# F1 = 0.359 vs. 0.110
# Accuracy = 0.406 vs. 0.056
# Minibatch Loss= 0.491175
# Train Batch Evaluation
# AUC = 0.497 vs. 0.075
# F1 = 0.530 vs. 0.105
# Accuracy = 0.516 vs. 0.056
# Validation
# AUC = 0.284 vs. 0.076
# F1 = 0.361 vs. 0.112
# Accuracy = 0.412 vs. 0.056
# Minibatch Loss= 0.480667
# Train Batch Evaluation
# AUC = 0.504 vs. 0.076
# F1 = 0.536 vs. 0.107
# Accuracy = 0.519 vs. 0.056
# Validation
# AUC = 0.286 vs. 0.076
# F1 = 0.362 vs. 0.111
# Accuracy = 0.417 vs. 0.056
# Minibatch Loss= 0.470634
# Train Batch Evaluation
# AUC = 0.512 vs. 0.075
# F1 = 0.542 vs. 0.106
# Accuracy = 0.519 vs. 0.056
# Validation
# AUC = 0.288 vs. 0.078
# F1 = 0.364 vs. 0.113
# Accuracy = 0.418 vs. 0.056
# Minibatch Loss= 0.460953
# Train Batch Evaluation
# AUC = 0.520 vs. 0.075
# F1 = 0.549 vs. 0.106
# Accuracy = 0.527 vs. 0.056
# Validation
# AUC = 0.289 vs. 0.075
# F1 = 0.365 vs. 0.110
# Accuracy = 0.419 vs. 0.056
# Minibatch Loss= 0.451469
# Train Batch Evaluation
# AUC = 0.529 vs. 0.075
# F1 = 0.556 vs. 0.104
# Accuracy = 0.536 vs. 0.056
# Validation
# AUC = 0.292 vs. 0.077
# F1 = 0.367 vs. 0.111
# Accuracy = 0.438 vs. 0.056
# Minibatch Loss= 0.442167
# Train Batch Evaluation
# AUC = 0.537 vs. 0.075
# F1 = 0.563 vs. 0.105
# Accuracy = 0.548 vs. 0.056
# Validation
# AUC = 0.295 vs. 0.078
# F1 = 0.369 vs. 0.112
# Accuracy = 0.454 vs. 0.056
# Minibatch Loss= 0.433059
# Train Batch Evaluation
# AUC = 0.545 vs. 0.075
# F1 = 0.569 vs. 0.105
# Accuracy = 0.563 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.076
# F1 = 0.372 vs. 0.111
# Accuracy = 0.471 vs. 0.056
# Minibatch Loss= 0.424086
# Train Batch Evaluation
# AUC = 0.552 vs. 0.075
# F1 = 0.574 vs. 0.104
# Accuracy = 0.575 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.076
# F1 = 0.374 vs. 0.109
# Accuracy = 0.483 vs. 0.056
# Minibatch Loss= 0.415281
# Train Batch Evaluation
# AUC = 0.559 vs. 0.076
# F1 = 0.582 vs. 0.106
# Accuracy = 0.582 vs. 0.056
# Validation
# AUC = 0.304 vs. 0.074
# F1 = 0.377 vs. 0.106
# Accuracy = 0.489 vs. 0.056
# Minibatch Loss= 0.406760
# Train Batch Evaluation
# AUC = 0.566 vs. 0.074
# F1 = 0.589 vs. 0.104
# Accuracy = 0.587 vs. 0.056
# Validation
# AUC = 0.308 vs. 0.076
# F1 = 0.380 vs. 0.108
# Accuracy = 0.492 vs. 0.056
# Minibatch Loss= 0.398418
# Train Batch Evaluation
# AUC = 0.573 vs. 0.075
# F1 = 0.594 vs. 0.106
# Accuracy = 0.596 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.076
# F1 = 0.382 vs. 0.110
# Accuracy = 0.494 vs. 0.056
# Minibatch Loss= 0.390432
# Train Batch Evaluation
# AUC = 0.580 vs. 0.075
# F1 = 0.599 vs. 0.105
# Accuracy = 0.612 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.076
# F1 = 0.383 vs. 0.109
# Accuracy = 0.504 vs. 0.056
# Minibatch Loss= 0.382729
# Train Batch Evaluation
# AUC = 0.586 vs. 0.075
# F1 = 0.604 vs. 0.105
# Accuracy = 0.633 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.079
# F1 = 0.381 vs. 0.114
# Accuracy = 0.522 vs. 0.056
# Minibatch Loss= 0.375306
# Train Batch Evaluation
# AUC = 0.591 vs. 0.077
# F1 = 0.609 vs. 0.106
# Accuracy = 0.645 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.075
# F1 = 0.382 vs. 0.110
# Accuracy = 0.528 vs. 0.056
# Minibatch Loss= 0.368199
# Train Batch Evaluation
# AUC = 0.596 vs. 0.076
# F1 = 0.614 vs. 0.105
# Accuracy = 0.652 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.075
# F1 = 0.382 vs. 0.110
# Accuracy = 0.535 vs. 0.056
# Minibatch Loss= 0.361439
# Train Batch Evaluation
# AUC = 0.601 vs. 0.076
# F1 = 0.619 vs. 0.105
# Accuracy = 0.653 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.077
# F1 = 0.384 vs. 0.111
# Accuracy = 0.536 vs. 0.056
# Minibatch Loss= 0.354903
# Train Batch Evaluation
# AUC = 0.606 vs. 0.075
# F1 = 0.623 vs. 0.104
# Accuracy = 0.658 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.078
# F1 = 0.384 vs. 0.113
# Accuracy = 0.541 vs. 0.056
# Minibatch Loss= 0.348642
# Train Batch Evaluation
# AUC = 0.610 vs. 0.075
# F1 = 0.628 vs. 0.105
# Accuracy = 0.663 vs. 0.056
# Validation
# AUC = 0.313 vs. 0.077
# F1 = 0.384 vs. 0.111
# Accuracy = 0.541 vs. 0.056
# Minibatch Loss= 0.342639
# Train Batch Evaluation
# AUC = 0.615 vs. 0.075
# F1 = 0.631 vs. 0.105
# Accuracy = 0.668 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.075
# F1 = 0.383 vs. 0.108
# Accuracy = 0.544 vs. 0.056
# Minibatch Loss= 0.336693
# Train Batch Evaluation
# AUC = 0.619 vs. 0.075
# F1 = 0.636 vs. 0.104
# Accuracy = 0.673 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.076
# F1 = 0.382 vs. 0.113
# Accuracy = 0.545 vs. 0.056
# Minibatch Loss= 0.330882
# Train Batch Evaluation
# AUC = 0.624 vs. 0.075
# F1 = 0.640 vs. 0.104
# Accuracy = 0.679 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.076
# F1 = 0.380 vs. 0.110
# Accuracy = 0.545 vs. 0.056
# Minibatch Loss= 0.325250
# Train Batch Evaluation
# AUC = 0.629 vs. 0.075
# F1 = 0.644 vs. 0.105
# Accuracy = 0.682 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.077
# F1 = 0.379 vs. 0.112
# Accuracy = 0.545 vs. 0.056
# Minibatch Loss= 0.319671
# Train Batch Evaluation
# AUC = 0.633 vs. 0.075
# F1 = 0.646 vs. 0.104
# Accuracy = 0.682 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.077
# F1 = 0.379 vs. 0.110
# Accuracy = 0.544 vs. 0.056
# Minibatch Loss= 0.314282
# Train Batch Evaluation
# AUC = 0.637 vs. 0.076
# F1 = 0.649 vs. 0.106
# Accuracy = 0.686 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.078
# F1 = 0.378 vs. 0.116
# Accuracy = 0.546 vs. 0.056
# Minibatch Loss= 0.309113
# Train Batch Evaluation
# AUC = 0.642 vs. 0.075
# F1 = 0.653 vs. 0.105
# Accuracy = 0.692 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.075
# F1 = 0.378 vs. 0.111
# Accuracy = 0.551 vs. 0.056
# Minibatch Loss= 0.304064
# Train Batch Evaluation
# AUC = 0.646 vs. 0.075
# F1 = 0.657 vs. 0.105
# Accuracy = 0.696 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.075
# F1 = 0.379 vs. 0.108
# Accuracy = 0.556 vs. 0.056
# Minibatch Loss= 0.299116
# Train Batch Evaluation
# AUC = 0.650 vs. 0.075
# F1 = 0.660 vs. 0.104
# Accuracy = 0.698 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.077
# F1 = 0.379 vs. 0.110
# Accuracy = 0.557 vs. 0.056
# Minibatch Loss= 0.294322
# Train Batch Evaluation
# AUC = 0.654 vs. 0.075
# F1 = 0.663 vs. 0.104
# Accuracy = 0.704 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.076
# F1 = 0.380 vs. 0.110
# Accuracy = 0.562 vs. 0.056
# Minibatch Loss= 0.289624
# Train Batch Evaluation
# AUC = 0.658 vs. 0.075
# F1 = 0.666 vs. 0.105
# Accuracy = 0.709 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.076
# F1 = 0.380 vs. 0.112
# Accuracy = 0.566 vs. 0.056
# Minibatch Loss= 0.285024
# Train Batch Evaluation
# AUC = 0.662 vs. 0.076
# F1 = 0.668 vs. 0.107
# Accuracy = 0.711 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.077
# F1 = 0.380 vs. 0.109
# Accuracy = 0.565 vs. 0.056
# Minibatch Loss= 0.280545
# Train Batch Evaluation
# AUC = 0.666 vs. 0.075
# F1 = 0.672 vs. 0.105
# Accuracy = 0.713 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.076
# F1 = 0.380 vs. 0.111
# Accuracy = 0.564 vs. 0.056
# Minibatch Loss= 0.276167
# Train Batch Evaluation
# AUC = 0.670 vs. 0.075
# F1 = 0.673 vs. 0.105
# Accuracy = 0.715 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.077
# F1 = 0.380 vs. 0.108
# Accuracy = 0.565 vs. 0.056
# Minibatch Loss= 0.271900
# Train Batch Evaluation
# AUC = 0.674 vs. 0.075
# F1 = 0.675 vs. 0.105
# Accuracy = 0.717 vs. 0.056
# Validation
# AUC = 0.309 vs. 0.077
# F1 = 0.381 vs. 0.110
# Accuracy = 0.565 vs. 0.056
# Minibatch Loss= 0.267761
# Train Batch Evaluation
# AUC = 0.678 vs. 0.075
# F1 = 0.678 vs. 0.104
# Accuracy = 0.722 vs. 0.056
# Validation
# AUC = 0.309 vs. 0.077
# F1 = 0.381 vs. 0.114
# Accuracy = 0.567 vs. 0.056
# Minibatch Loss= 0.263716
# Train Batch Evaluation
# AUC = 0.681 vs. 0.076
# F1 = 0.680 vs. 0.106
# Accuracy = 0.722 vs. 0.056
# Validation
# AUC = 0.309 vs. 0.076
# F1 = 0.383 vs. 0.109
# Accuracy = 0.565 vs. 0.056
# Minibatch Loss= 0.259768
# Train Batch Evaluation
# AUC = 0.685 vs. 0.074
# F1 = 0.682 vs. 0.106
# Accuracy = 0.722 vs. 0.056
# Validation
# AUC = 0.309 vs. 0.077
# F1 = 0.384 vs. 0.113
# Accuracy = 0.565 vs. 0.056
# Minibatch Loss= 0.255934
# Train Batch Evaluation
# AUC = 0.688 vs. 0.076
# F1 = 0.683 vs. 0.106
# Accuracy = 0.726 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.077
# F1 = 0.384 vs. 0.110
# Accuracy = 0.568 vs. 0.056
# Minibatch Loss= 0.252194
# Train Batch Evaluation
# AUC = 0.692 vs. 0.075
# F1 = 0.685 vs. 0.106
# Accuracy = 0.729 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.075
# F1 = 0.385 vs. 0.111
# Accuracy = 0.571 vs. 0.056
# Minibatch Loss= 0.248589
# Train Batch Evaluation
# AUC = 0.695 vs. 0.076
# F1 = 0.688 vs. 0.108
# Accuracy = 0.730 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.076
# F1 = 0.387 vs. 0.108
# Accuracy = 0.568 vs. 0.056
# Minibatch Loss= 0.245050
# Train Batch Evaluation
# AUC = 0.698 vs. 0.075
# F1 = 0.690 vs. 0.107
# Accuracy = 0.734 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.077
# F1 = 0.387 vs. 0.111
# Accuracy = 0.570 vs. 0.056
# Minibatch Loss= 0.241616
# Train Batch Evaluation
# AUC = 0.702 vs. 0.075
# F1 = 0.691 vs. 0.106
# Accuracy = 0.741 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.075
# F1 = 0.386 vs. 0.108
# Accuracy = 0.574 vs. 0.056
# Minibatch Loss= 0.238257
# Train Batch Evaluation
# AUC = 0.705 vs. 0.075
# F1 = 0.694 vs. 0.105
# Accuracy = 0.742 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.078
# F1 = 0.387 vs. 0.112
# Accuracy = 0.574 vs. 0.056
# Minibatch Loss= 0.234973
# Train Batch Evaluation
# AUC = 0.708 vs. 0.075
# F1 = 0.695 vs. 0.104
# Accuracy = 0.744 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.076
# F1 = 0.387 vs. 0.109
# Accuracy = 0.576 vs. 0.056
# Minibatch Loss= 0.231782
# Train Batch Evaluation
# AUC = 0.711 vs. 0.075
# F1 = 0.697 vs. 0.105
# Accuracy = 0.744 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.075
# F1 = 0.387 vs. 0.109
# Accuracy = 0.577 vs. 0.056
# Minibatch Loss= 0.228652
# Train Batch Evaluation
# AUC = 0.714 vs. 0.075
# F1 = 0.699 vs. 0.105
# Accuracy = 0.746 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.077
# F1 = 0.387 vs. 0.115
# Accuracy = 0.577 vs. 0.056
# Minibatch Loss= 0.225617
# Train Batch Evaluation
# AUC = 0.717 vs. 0.076
# F1 = 0.701 vs. 0.104
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.076
# F1 = 0.388 vs. 0.111
# Accuracy = 0.579 vs. 0.056
# Minibatch Loss= 0.222668
# Train Batch Evaluation
# AUC = 0.720 vs. 0.074
# F1 = 0.703 vs. 0.104
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.077
# F1 = 0.388 vs. 0.114
# Accuracy = 0.579 vs. 0.056
# Minibatch Loss= 0.219785
# Train Batch Evaluation
# AUC = 0.723 vs. 0.075
# F1 = 0.706 vs. 0.105
# Accuracy = 0.753 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.077
# F1 = 0.387 vs. 0.109
# Accuracy = 0.582 vs. 0.056
# Minibatch Loss= 0.216974
# Train Batch Evaluation
# AUC = 0.726 vs. 0.076
# F1 = 0.709 vs. 0.105
# Accuracy = 0.753 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.076
# F1 = 0.387 vs. 0.111
# Accuracy = 0.582 vs. 0.056
# Minibatch Loss= 0.214220
# Train Batch Evaluation
# AUC = 0.728 vs. 0.075
# F1 = 0.711 vs. 0.106
# Accuracy = 0.757 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.077
# F1 = 0.386 vs. 0.108
# Accuracy = 0.584 vs. 0.056
# Minibatch Loss= 0.211547
# Train Batch Evaluation
# AUC = 0.731 vs. 0.076
# F1 = 0.713 vs. 0.107
# Accuracy = 0.761 vs. 0.056
# Validation
# AUC = 0.309 vs. 0.077
# F1 = 0.386 vs. 0.112
# Accuracy = 0.586 vs. 0.056
# Minibatch Loss= 0.208935
# Train Batch Evaluation
# AUC = 0.734 vs. 0.075
# F1 = 0.715 vs. 0.105
# Accuracy = 0.763 vs. 0.056
# Validation
# AUC = 0.308 vs. 0.078
# F1 = 0.386 vs. 0.115
# Accuracy = 0.587 vs. 0.056
# Minibatch Loss= 0.206387
# Train Batch Evaluation
# AUC = 0.736 vs. 0.075
# F1 = 0.717 vs. 0.105
# Accuracy = 0.763 vs. 0.056
# Validation
# AUC = 0.308 vs. 0.076
# F1 = 0.386 vs. 0.111
# Accuracy = 0.588 vs. 0.056
# Minibatch Loss= 0.203916
# Train Batch Evaluation
# AUC = 0.739 vs. 0.075
# F1 = 0.719 vs. 0.104
# Accuracy = 0.765 vs. 0.056
# Validation
# AUC = 0.307 vs. 0.076
# F1 = 0.386 vs. 0.111
# Accuracy = 0.587 vs. 0.056
# Minibatch Loss= 0.201510
# Train Batch Evaluation
# AUC = 0.741 vs. 0.075
# F1 = 0.720 vs. 0.105
# Accuracy = 0.775 vs. 0.056
# Validation
# AUC = 0.306 vs. 0.077
# F1 = 0.386 vs. 0.110
# Accuracy = 0.591 vs. 0.056
# Minibatch Loss= 0.199194
# Train Batch Evaluation
# AUC = 0.744 vs. 0.075
# F1 = 0.722 vs. 0.104
# Accuracy = 0.767 vs. 0.056
# Validation
# AUC = 0.308 vs. 0.075
# F1 = 0.386 vs. 0.112
# Accuracy = 0.589 vs. 0.056
# Minibatch Loss= 0.196972
# Train Batch Evaluation
# AUC = 0.746 vs. 0.075
# F1 = 0.724 vs. 0.105
# Accuracy = 0.780 vs. 0.056
# Validation
# AUC = 0.305 vs. 0.077
# F1 = 0.385 vs. 0.111
# Accuracy = 0.591 vs. 0.056
# Minibatch Loss= 0.194763
# Train Batch Evaluation
# AUC = 0.748 vs. 0.076
# F1 = 0.726 vs. 0.105
# Accuracy = 0.773 vs. 0.056
# Validation
# AUC = 0.306 vs. 0.076
# F1 = 0.386 vs. 0.112
# Accuracy = 0.590 vs. 0.056
# Minibatch Loss= 0.192582
# Train Batch Evaluation
# AUC = 0.751 vs. 0.075
# F1 = 0.728 vs. 0.105
# Accuracy = 0.780 vs. 0.056
# Validation
# AUC = 0.305 vs. 0.076
# F1 = 0.386 vs. 0.107
# Accuracy = 0.591 vs. 0.056
# Minibatch Loss= 0.190379
# Train Batch Evaluation
# AUC = 0.753 vs. 0.076
# F1 = 0.729 vs. 0.105
# Accuracy = 0.782 vs. 0.056
# Validation
# AUC = 0.305 vs. 0.078
# F1 = 0.385 vs. 0.111
# Accuracy = 0.591 vs. 0.056
# Minibatch Loss= 0.188209
# Train Batch Evaluation
# AUC = 0.756 vs. 0.075
# F1 = 0.731 vs. 0.104
# Accuracy = 0.782 vs. 0.056
# Validation
# AUC = 0.304 vs. 0.077
# F1 = 0.386 vs. 0.115
# Accuracy = 0.591 vs. 0.056
# Minibatch Loss= 0.186133
# Train Batch Evaluation
# AUC = 0.758 vs. 0.075
# F1 = 0.733 vs. 0.105
# Accuracy = 0.786 vs. 0.056
# Validation
# AUC = 0.303 vs. 0.077
# F1 = 0.386 vs. 0.113
# Accuracy = 0.591 vs. 0.056
# Minibatch Loss= 0.184178
# Train Batch Evaluation
# AUC = 0.760 vs. 0.075
# F1 = 0.735 vs. 0.104
# Accuracy = 0.788 vs. 0.056
# Validation
# AUC = 0.303 vs. 0.076
# F1 = 0.387 vs. 0.111
# Accuracy = 0.594 vs. 0.056
# Minibatch Loss= 0.182285
# Train Batch Evaluation
# AUC = 0.763 vs. 0.075
# F1 = 0.737 vs. 0.106
# Accuracy = 0.793 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.074
# F1 = 0.387 vs. 0.107
# Accuracy = 0.591 vs. 0.056
# Minibatch Loss= 0.180402
# Train Batch Evaluation
# AUC = 0.764 vs. 0.075
# F1 = 0.739 vs. 0.105
# Accuracy = 0.791 vs. 0.056
# Validation
# AUC = 0.302 vs. 0.075
# F1 = 0.386 vs. 0.110
# Accuracy = 0.594 vs. 0.056
# Minibatch Loss= 0.178509
# Train Batch Evaluation
# AUC = 0.767 vs. 0.075
# F1 = 0.741 vs. 0.104
# Accuracy = 0.799 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.386 vs. 0.109
# Accuracy = 0.594 vs. 0.056
# Minibatch Loss= 0.176615
# Train Batch Evaluation
# AUC = 0.769 vs. 0.075
# F1 = 0.743 vs. 0.105
# Accuracy = 0.796 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.077
# F1 = 0.386 vs. 0.112
# Accuracy = 0.595 vs. 0.056
# Minibatch Loss= 0.174778
# Train Batch Evaluation
# AUC = 0.771 vs. 0.076
# F1 = 0.744 vs. 0.104
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.077
# F1 = 0.385 vs. 0.111
# Accuracy = 0.595 vs. 0.056
# Minibatch Loss= 0.172988
# Train Batch Evaluation
# AUC = 0.773 vs. 0.074
# F1 = 0.745 vs. 0.104
# Accuracy = 0.803 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.078
# F1 = 0.385 vs. 0.116
# Accuracy = 0.595 vs. 0.056
# Minibatch Loss= 0.171266
# Train Batch Evaluation
# AUC = 0.774 vs. 0.075
# F1 = 0.747 vs. 0.104
# Accuracy = 0.799 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.077
# F1 = 0.386 vs. 0.116
# Accuracy = 0.595 vs. 0.056
# Minibatch Loss= 0.169612
# Train Batch Evaluation
# AUC = 0.777 vs. 0.075
# F1 = 0.749 vs. 0.105
# Accuracy = 0.807 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.384 vs. 0.107
# Accuracy = 0.598 vs. 0.056
# Minibatch Loss= 0.167980
# Train Batch Evaluation
# AUC = 0.778 vs. 0.075
# F1 = 0.750 vs. 0.105
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.387 vs. 0.108
# Accuracy = 0.596 vs. 0.056
# Minibatch Loss= 0.166349
# Train Batch Evaluation
# AUC = 0.780 vs. 0.075
# F1 = 0.751 vs. 0.105
# Accuracy = 0.809 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.386 vs. 0.111
# Accuracy = 0.601 vs. 0.056
# Minibatch Loss= 0.164735
# Train Batch Evaluation
# AUC = 0.782 vs. 0.076
# F1 = 0.753 vs. 0.106
# Accuracy = 0.806 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.387 vs. 0.109
# Accuracy = 0.597 vs. 0.056
# Minibatch Loss= 0.163169
# Train Batch Evaluation
# AUC = 0.784 vs. 0.075
# F1 = 0.755 vs. 0.105
# Accuracy = 0.808 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.387 vs. 0.109
# Accuracy = 0.604 vs. 0.056
# Minibatch Loss= 0.161705
# Train Batch Evaluation
# AUC = 0.786 vs. 0.076
# F1 = 0.756 vs. 0.106
# Accuracy = 0.813 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.078
# F1 = 0.387 vs. 0.113
# Accuracy = 0.598 vs. 0.056
# Minibatch Loss= 0.160400
# Train Batch Evaluation
# AUC = 0.787 vs. 0.076
# F1 = 0.757 vs. 0.105
# Accuracy = 0.811 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.077
# F1 = 0.389 vs. 0.111
# Accuracy = 0.607 vs. 0.056
# Minibatch Loss= 0.159236
# Train Batch Evaluation
# AUC = 0.790 vs. 0.075
# F1 = 0.759 vs. 0.104
# Accuracy = 0.814 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.075
# F1 = 0.388 vs. 0.111
# Accuracy = 0.599 vs. 0.056
# Minibatch Loss= 0.158152
# Train Batch Evaluation
# AUC = 0.791 vs. 0.074
# F1 = 0.761 vs. 0.104
# Accuracy = 0.816 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.075
# F1 = 0.389 vs. 0.107
# Accuracy = 0.610 vs. 0.056
# Minibatch Loss= 0.156626
# Train Batch Evaluation
# AUC = 0.793 vs. 0.075
# F1 = 0.762 vs. 0.105
# Accuracy = 0.818 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.078
# F1 = 0.389 vs. 0.109
# Accuracy = 0.604 vs. 0.056
# Minibatch Loss= 0.154805
# Train Batch Evaluation
# AUC = 0.794 vs. 0.075
# F1 = 0.764 vs. 0.105
# Accuracy = 0.822 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.389 vs. 0.111
# Accuracy = 0.605 vs. 0.056
# Minibatch Loss= 0.153034
# Train Batch Evaluation
# AUC = 0.796 vs. 0.074
# F1 = 0.765 vs. 0.104
# Accuracy = 0.820 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.078
# F1 = 0.390 vs. 0.112
# Accuracy = 0.610 vs. 0.056
# Minibatch Loss= 0.151858
# Train Batch Evaluation
# AUC = 0.797 vs. 0.075
# F1 = 0.766 vs. 0.106
# Accuracy = 0.823 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.390 vs. 0.113
# Accuracy = 0.604 vs. 0.056
# Minibatch Loss= 0.150948
# Train Batch Evaluation
# AUC = 0.799 vs. 0.075
# F1 = 0.767 vs. 0.105
# Accuracy = 0.821 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.077
# F1 = 0.390 vs. 0.113
# Accuracy = 0.611 vs. 0.056
# Minibatch Loss= 0.149645
# Train Batch Evaluation
# AUC = 0.800 vs. 0.075
# F1 = 0.768 vs. 0.105
# Accuracy = 0.824 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.076
# F1 = 0.390 vs. 0.110
# Accuracy = 0.606 vs. 0.056
# Minibatch Loss= 0.148065
# Train Batch Evaluation
# AUC = 0.802 vs. 0.075
# F1 = 0.769 vs. 0.104
# Accuracy = 0.823 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.391 vs. 0.110
# Accuracy = 0.607 vs. 0.056
# Minibatch Loss= 0.146681
# Train Batch Evaluation
# AUC = 0.803 vs. 0.075
# F1 = 0.771 vs. 0.106
# Accuracy = 0.826 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.075
# F1 = 0.390 vs. 0.110
# Accuracy = 0.613 vs. 0.056
# Minibatch Loss= 0.145669
# Train Batch Evaluation
# AUC = 0.804 vs. 0.075
# F1 = 0.773 vs. 0.105
# Accuracy = 0.829 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.075
# F1 = 0.390 vs. 0.109
# Accuracy = 0.607 vs. 0.056
# Minibatch Loss= 0.144649
# Train Batch Evaluation
# AUC = 0.806 vs. 0.075
# F1 = 0.774 vs. 0.104
# Accuracy = 0.823 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.391 vs. 0.111
# Accuracy = 0.610 vs. 0.056
# Minibatch Loss= 0.143324
# Train Batch Evaluation
# AUC = 0.807 vs. 0.075
# F1 = 0.776 vs. 0.104
# Accuracy = 0.833 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.076
# F1 = 0.390 vs. 0.110
# Accuracy = 0.613 vs. 0.056
# Minibatch Loss= 0.141998
# Train Batch Evaluation
# AUC = 0.809 vs. 0.076
# F1 = 0.777 vs. 0.106
# Accuracy = 0.829 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.391 vs. 0.112
# Accuracy = 0.607 vs. 0.056
# Minibatch Loss= 0.140924
# Train Batch Evaluation
# AUC = 0.810 vs. 0.075
# F1 = 0.778 vs. 0.105
# Accuracy = 0.829 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.391 vs. 0.111
# Accuracy = 0.615 vs. 0.056
# Minibatch Loss= 0.139936
# Train Batch Evaluation
# AUC = 0.811 vs. 0.075
# F1 = 0.779 vs. 0.104
# Accuracy = 0.834 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.077
# F1 = 0.390 vs. 0.110
# Accuracy = 0.610 vs. 0.056
# Minibatch Loss= 0.138824
# Train Batch Evaluation
# AUC = 0.813 vs. 0.076
# F1 = 0.781 vs. 0.106
# Accuracy = 0.829 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.392 vs. 0.112
# Accuracy = 0.612 vs. 0.056
# Minibatch Loss= 0.137632
# Train Batch Evaluation
# AUC = 0.814 vs. 0.075
# F1 = 0.782 vs. 0.106
# Accuracy = 0.837 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.074
# F1 = 0.392 vs. 0.107
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.136547
# Train Batch Evaluation
# AUC = 0.815 vs. 0.075
# F1 = 0.783 vs. 0.105
# Accuracy = 0.833 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.078
# F1 = 0.392 vs. 0.114
# Accuracy = 0.610 vs. 0.056
# Minibatch Loss= 0.135590
# Train Batch Evaluation
# AUC = 0.817 vs. 0.077
# F1 = 0.785 vs. 0.106
# Accuracy = 0.836 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.078
# F1 = 0.391 vs. 0.113
# Accuracy = 0.616 vs. 0.056
# Minibatch Loss= 0.134559
# Train Batch Evaluation
# AUC = 0.818 vs. 0.075
# F1 = 0.785 vs. 0.106
# Accuracy = 0.841 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.075
# F1 = 0.391 vs. 0.110
# Accuracy = 0.616 vs. 0.056
# Minibatch Loss= 0.133465
# Train Batch Evaluation
# AUC = 0.819 vs. 0.075
# F1 = 0.786 vs. 0.105
# Accuracy = 0.836 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.393 vs. 0.111
# Accuracy = 0.612 vs. 0.056
# Minibatch Loss= 0.132453
# Train Batch Evaluation
# AUC = 0.820 vs. 0.075
# F1 = 0.788 vs. 0.104
# Accuracy = 0.842 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.077
# F1 = 0.391 vs. 0.111
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.131509
# Train Batch Evaluation
# AUC = 0.821 vs. 0.075
# F1 = 0.789 vs. 0.105
# Accuracy = 0.838 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.075
# F1 = 0.392 vs. 0.108
# Accuracy = 0.614 vs. 0.056
# Minibatch Loss= 0.130540
# Train Batch Evaluation
# AUC = 0.823 vs. 0.075
# F1 = 0.790 vs. 0.105
# Accuracy = 0.840 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.392 vs. 0.108
# Accuracy = 0.614 vs. 0.056
# Minibatch Loss= 0.129528
# Train Batch Evaluation
# AUC = 0.824 vs. 0.075
# F1 = 0.792 vs. 0.106
# Accuracy = 0.846 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.076
# F1 = 0.391 vs. 0.110
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.128566
# Train Batch Evaluation
# AUC = 0.825 vs. 0.075
# F1 = 0.793 vs. 0.106
# Accuracy = 0.841 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.077
# F1 = 0.391 vs. 0.114
# Accuracy = 0.616 vs. 0.056
# Minibatch Loss= 0.127666
# Train Batch Evaluation
# AUC = 0.826 vs. 0.075
# F1 = 0.794 vs. 0.105
# Accuracy = 0.846 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.391 vs. 0.113
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.126761
# Train Batch Evaluation
# AUC = 0.827 vs. 0.075
# F1 = 0.795 vs. 0.106
# Accuracy = 0.845 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.078
# F1 = 0.391 vs. 0.116
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.125807
# Train Batch Evaluation
# AUC = 0.829 vs. 0.076
# F1 = 0.796 vs. 0.105
# Accuracy = 0.845 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.391 vs. 0.111
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.124870
# Train Batch Evaluation
# AUC = 0.830 vs. 0.075
# F1 = 0.797 vs. 0.104
# Accuracy = 0.849 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.390 vs. 0.112
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.123998
# Train Batch Evaluation
# AUC = 0.831 vs. 0.075
# F1 = 0.798 vs. 0.105
# Accuracy = 0.845 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.076
# F1 = 0.391 vs. 0.114
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.123150
# Train Batch Evaluation
# AUC = 0.832 vs. 0.075
# F1 = 0.799 vs. 0.105
# Accuracy = 0.851 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.390 vs. 0.113
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.122274
# Train Batch Evaluation
# AUC = 0.833 vs. 0.075
# F1 = 0.800 vs. 0.105
# Accuracy = 0.848 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.077
# F1 = 0.391 vs. 0.113
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.121383
# Train Batch Evaluation
# AUC = 0.834 vs. 0.075
# F1 = 0.802 vs. 0.104
# Accuracy = 0.851 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.390 vs. 0.110
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.120513
# Train Batch Evaluation
# AUC = 0.836 vs. 0.075
# F1 = 0.803 vs. 0.104
# Accuracy = 0.852 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.077
# F1 = 0.390 vs. 0.110
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.119680
# Train Batch Evaluation
# AUC = 0.837 vs. 0.076
# F1 = 0.804 vs. 0.105
# Accuracy = 0.853 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.078
# F1 = 0.391 vs. 0.107
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.118863
# Train Batch Evaluation
# AUC = 0.838 vs. 0.075
# F1 = 0.806 vs. 0.106
# Accuracy = 0.852 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.390 vs. 0.109
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.118042
# Train Batch Evaluation
# AUC = 0.839 vs. 0.075
# F1 = 0.807 vs. 0.106
# Accuracy = 0.855 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.079
# F1 = 0.392 vs. 0.115
# Accuracy = 0.621 vs. 0.056
# Minibatch Loss= 0.117223
# Train Batch Evaluation
# AUC = 0.840 vs. 0.075
# F1 = 0.808 vs. 0.105
# Accuracy = 0.854 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.079
# F1 = 0.391 vs. 0.114
# Accuracy = 0.621 vs. 0.056
# Minibatch Loss= 0.116402
# Train Batch Evaluation
# AUC = 0.841 vs. 0.076
# F1 = 0.809 vs. 0.106
# Accuracy = 0.854 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.392 vs. 0.111
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.115602
# Train Batch Evaluation
# AUC = 0.842 vs. 0.076
# F1 = 0.811 vs. 0.105
# Accuracy = 0.855 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.075
# F1 = 0.392 vs. 0.109
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.114832
# Train Batch Evaluation
# AUC = 0.843 vs. 0.075
# F1 = 0.812 vs. 0.104
# Accuracy = 0.856 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.077
# F1 = 0.391 vs. 0.112
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.114071
# Train Batch Evaluation
# AUC = 0.844 vs. 0.075
# F1 = 0.813 vs. 0.105
# Accuracy = 0.856 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.077
# F1 = 0.392 vs. 0.113
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.113317
# Train Batch Evaluation
# AUC = 0.846 vs. 0.075
# F1 = 0.815 vs. 0.104
# Accuracy = 0.861 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.079
# F1 = 0.391 vs. 0.113
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.112563
# Train Batch Evaluation
# AUC = 0.847 vs. 0.075
# F1 = 0.816 vs. 0.105
# Accuracy = 0.856 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.076
# F1 = 0.394 vs. 0.109
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.111816
# Train Batch Evaluation
# AUC = 0.848 vs. 0.075
# F1 = 0.817 vs. 0.105
# Accuracy = 0.863 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.393 vs. 0.109
# Accuracy = 0.622 vs. 0.056
# Minibatch Loss= 0.111082
# Train Batch Evaluation
# AUC = 0.849 vs. 0.075
# F1 = 0.818 vs. 0.104
# Accuracy = 0.855 vs. 0.056
# Validation
# AUC = 0.302 vs. 0.076
# F1 = 0.395 vs. 0.108
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.110374
# Train Batch Evaluation
# AUC = 0.850 vs. 0.075
# F1 = 0.819 vs. 0.105
# Accuracy = 0.867 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.393 vs. 0.108
# Accuracy = 0.622 vs. 0.056
# Minibatch Loss= 0.109687
# Train Batch Evaluation
# AUC = 0.851 vs. 0.076
# F1 = 0.820 vs. 0.106
# Accuracy = 0.854 vs. 0.056
# Validation
# AUC = 0.302 vs. 0.077
# F1 = 0.395 vs. 0.113
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.109059
# Train Batch Evaluation
# AUC = 0.852 vs. 0.075
# F1 = 0.821 vs. 0.104
# Accuracy = 0.872 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.075
# F1 = 0.391 vs. 0.107
# Accuracy = 0.623 vs. 0.056
# Minibatch Loss= 0.108427
# Train Batch Evaluation
# AUC = 0.853 vs. 0.075
# F1 = 0.822 vs. 0.105
# Accuracy = 0.850 vs. 0.056
# Validation
# AUC = 0.303 vs. 0.076
# F1 = 0.395 vs. 0.110
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.107858
# Train Batch Evaluation
# AUC = 0.854 vs. 0.075
# F1 = 0.823 vs. 0.104
# Accuracy = 0.874 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.077
# F1 = 0.392 vs. 0.113
# Accuracy = 0.624 vs. 0.056
# Minibatch Loss= 0.107171
# Train Batch Evaluation
# AUC = 0.855 vs. 0.075
# F1 = 0.823 vs. 0.104
# Accuracy = 0.853 vs. 0.056
# Validation
# AUC = 0.303 vs. 0.076
# F1 = 0.395 vs. 0.111
# Accuracy = 0.623 vs. 0.056
# Minibatch Loss= 0.106531
# Train Batch Evaluation
# AUC = 0.856 vs. 0.075
# F1 = 0.825 vs. 0.105
# Accuracy = 0.872 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.076
# F1 = 0.391 vs. 0.111
# Accuracy = 0.623 vs. 0.056
# Minibatch Loss= 0.105729
# Train Batch Evaluation
# AUC = 0.856 vs. 0.075
# F1 = 0.825 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.077
# F1 = 0.394 vs. 0.115
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.104988
# Train Batch Evaluation
# AUC = 0.858 vs. 0.075
# F1 = 0.827 vs. 0.105
# Accuracy = 0.865 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.076
# F1 = 0.392 vs. 0.111
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.104312
# Train Batch Evaluation
# AUC = 0.858 vs. 0.075
# F1 = 0.828 vs. 0.106
# Accuracy = 0.871 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.076
# F1 = 0.392 vs. 0.112
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.103688
# Train Batch Evaluation
# AUC = 0.860 vs. 0.075
# F1 = 0.829 vs. 0.105
# Accuracy = 0.859 vs. 0.056
# Validation
# AUC = 0.302 vs. 0.077
# F1 = 0.394 vs. 0.112
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.103095
# Train Batch Evaluation
# AUC = 0.860 vs. 0.075
# F1 = 0.829 vs. 0.105
# Accuracy = 0.876 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.078
# F1 = 0.392 vs. 0.116
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.102450
# Train Batch Evaluation
# AUC = 0.861 vs. 0.075
# F1 = 0.830 vs. 0.105
# Accuracy = 0.862 vs. 0.056
# Validation
# AUC = 0.302 vs. 0.078
# F1 = 0.393 vs. 0.111
# Accuracy = 0.623 vs. 0.056
# Minibatch Loss= 0.101827
# Train Batch Evaluation
# AUC = 0.863 vs. 0.075
# F1 = 0.832 vs. 0.105
# Accuracy = 0.874 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.392 vs. 0.111
# Accuracy = 0.623 vs. 0.056
# Minibatch Loss= 0.101205
# Train Batch Evaluation
# AUC = 0.863 vs. 0.074
# F1 = 0.832 vs. 0.104
# Accuracy = 0.868 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.075
# F1 = 0.394 vs. 0.107
# Accuracy = 0.626 vs. 0.056
# Minibatch Loss= 0.100629
# Train Batch Evaluation
# AUC = 0.865 vs. 0.076
# F1 = 0.833 vs. 0.105
# Accuracy = 0.870 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.076
# F1 = 0.393 vs. 0.109
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.100106
# Train Batch Evaluation
# AUC = 0.865 vs. 0.075
# F1 = 0.834 vs. 0.105
# Accuracy = 0.872 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.075
# F1 = 0.394 vs. 0.112
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.099547
# Train Batch Evaluation
# AUC = 0.867 vs. 0.075
# F1 = 0.835 vs. 0.106
# Accuracy = 0.868 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.075
# F1 = 0.394 vs. 0.110
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.098999
# Train Batch Evaluation
# AUC = 0.867 vs. 0.075
# F1 = 0.836 vs. 0.106
# Accuracy = 0.875 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.076
# F1 = 0.394 vs. 0.111
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.098321
# Train Batch Evaluation
# AUC = 0.868 vs. 0.076
# F1 = 0.836 vs. 0.106
# Accuracy = 0.871 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.078
# F1 = 0.394 vs. 0.113
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.097662
# Train Batch Evaluation
# AUC = 0.869 vs. 0.076
# F1 = 0.838 vs. 0.105
# Accuracy = 0.873 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.394 vs. 0.108
# Accuracy = 0.623 vs. 0.056
# Minibatch Loss= 0.097040
# Train Batch Evaluation
# AUC = 0.869 vs. 0.075
# F1 = 0.838 vs. 0.104
# Accuracy = 0.876 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.076
# F1 = 0.393 vs. 0.112
# Accuracy = 0.626 vs. 0.056
# Minibatch Loss= 0.096497
# Train Batch Evaluation
# AUC = 0.871 vs. 0.074
# F1 = 0.839 vs. 0.104
# Accuracy = 0.870 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.078
# F1 = 0.394 vs. 0.117
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.096006
# Train Batch Evaluation
# AUC = 0.871 vs. 0.076
# F1 = 0.840 vs. 0.106
# Accuracy = 0.880 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.076
# F1 = 0.393 vs. 0.109
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.095511
# Train Batch Evaluation
# AUC = 0.872 vs. 0.076
# F1 = 0.841 vs. 0.105
# Accuracy = 0.871 vs. 0.056
# Validation
# AUC = 0.301 vs. 0.077
# F1 = 0.394 vs. 0.111
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.095015
# Train Batch Evaluation
# AUC = 0.872 vs. 0.076
# F1 = 0.842 vs. 0.105
# Accuracy = 0.880 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.075
# F1 = 0.393 vs. 0.107
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.094444
# Train Batch Evaluation
# AUC = 0.874 vs. 0.075
# F1 = 0.843 vs. 0.104
# Accuracy = 0.875 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.394 vs. 0.110
# Accuracy = 0.621 vs. 0.056
# Minibatch Loss= 0.093882
# Train Batch Evaluation
# AUC = 0.874 vs. 0.075
# F1 = 0.844 vs. 0.107
# Accuracy = 0.877 vs. 0.056
# Validation
# AUC = 0.299 vs. 0.077
# F1 = 0.393 vs. 0.112
# Accuracy = 0.629 vs. 0.056
# Minibatch Loss= 0.093314
# Train Batch Evaluation
# AUC = 0.875 vs. 0.075
# F1 = 0.844 vs. 0.104
# Accuracy = 0.881 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.075
# F1 = 0.393 vs. 0.109
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.092791
# Train Batch Evaluation
# AUC = 0.876 vs. 0.075
# F1 = 0.846 vs. 0.105
# Accuracy = 0.872 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.394 vs. 0.109
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.092318
# Train Batch Evaluation
# AUC = 0.877 vs. 0.075
# F1 = 0.846 vs. 0.105
# Accuracy = 0.887 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.076
# F1 = 0.392 vs. 0.108
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.091875
# Train Batch Evaluation
# AUC = 0.878 vs. 0.075
# F1 = 0.847 vs. 0.106
# Accuracy = 0.870 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.076
# F1 = 0.394 vs. 0.110
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.091496
# Train Batch Evaluation
# AUC = 0.878 vs. 0.076
# F1 = 0.848 vs. 0.106
# Accuracy = 0.892 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.391 vs. 0.109
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.091033
# Train Batch Evaluation
# AUC = 0.880 vs. 0.075
# F1 = 0.848 vs. 0.104
# Accuracy = 0.870 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.075
# F1 = 0.395 vs. 0.108
# Accuracy = 0.627 vs. 0.056
# Minibatch Loss= 0.090632
# Train Batch Evaluation
# AUC = 0.880 vs. 0.075
# F1 = 0.850 vs. 0.106
# Accuracy = 0.890 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.076
# F1 = 0.392 vs. 0.110
# Accuracy = 0.631 vs. 0.056
# Minibatch Loss= 0.090023
# Train Batch Evaluation
# AUC = 0.881 vs. 0.075
# F1 = 0.850 vs. 0.104
# Accuracy = 0.878 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.076
# F1 = 0.394 vs. 0.110
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.089458
# Train Batch Evaluation
# AUC = 0.882 vs. 0.075
# F1 = 0.851 vs. 0.104
# Accuracy = 0.884 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.077
# F1 = 0.393 vs. 0.113
# Accuracy = 0.627 vs. 0.056
# Minibatch Loss= 0.088925
# Train Batch Evaluation
# AUC = 0.882 vs. 0.075
# F1 = 0.852 vs. 0.104
# Accuracy = 0.887 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.076
# F1 = 0.392 vs. 0.112
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.088444
# Train Batch Evaluation
# AUC = 0.884 vs. 0.075
# F1 = 0.853 vs. 0.104
# Accuracy = 0.879 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.077
# F1 = 0.395 vs. 0.113
# Accuracy = 0.626 vs. 0.056
# Minibatch Loss= 0.088019
# Train Batch Evaluation
# AUC = 0.883 vs. 0.075
# F1 = 0.853 vs. 0.105
# Accuracy = 0.889 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.076
# F1 = 0.393 vs. 0.111
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.087512
# Train Batch Evaluation
# AUC = 0.885 vs. 0.075
# F1 = 0.854 vs. 0.105
# Accuracy = 0.880 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.076
# F1 = 0.394 vs. 0.108
# Accuracy = 0.628 vs. 0.056
# Minibatch Loss= 0.087002
# Train Batch Evaluation
# AUC = 0.885 vs. 0.075
# F1 = 0.855 vs. 0.104
# Accuracy = 0.887 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.393 vs. 0.109
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.086477
# Train Batch Evaluation
# AUC = 0.886 vs. 0.075
# F1 = 0.855 vs. 0.104
# Accuracy = 0.886 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.077
# F1 = 0.394 vs. 0.115
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.086025
# Train Batch Evaluation
# AUC = 0.887 vs. 0.076
# F1 = 0.856 vs. 0.105
# Accuracy = 0.886 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.076
# F1 = 0.394 vs. 0.109
# Accuracy = 0.629 vs. 0.056
# Minibatch Loss= 0.085642
# Train Batch Evaluation
# AUC = 0.887 vs. 0.076
# F1 = 0.856 vs. 0.106
# Accuracy = 0.888 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.393 vs. 0.110
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.085258
# Train Batch Evaluation
# AUC = 0.889 vs. 0.075
# F1 = 0.858 vs. 0.105
# Accuracy = 0.886 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.076
# F1 = 0.395 vs. 0.112
# Accuracy = 0.628 vs. 0.056
# Minibatch Loss= 0.084880
# Train Batch Evaluation
# AUC = 0.888 vs. 0.075
# F1 = 0.858 vs. 0.104
# Accuracy = 0.888 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.394 vs. 0.112
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.084383
# Train Batch Evaluation
# AUC = 0.890 vs. 0.074
# F1 = 0.859 vs. 0.104
# Accuracy = 0.889 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.076
# F1 = 0.394 vs. 0.109
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.083888
# Train Batch Evaluation
# AUC = 0.890 vs. 0.075
# F1 = 0.860 vs. 0.105
# Accuracy = 0.887 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.076
# F1 = 0.395 vs. 0.110
# Accuracy = 0.633 vs. 0.056
# Minibatch Loss= 0.083394
# Train Batch Evaluation
# AUC = 0.891 vs. 0.074
# F1 = 0.860 vs. 0.105
# Accuracy = 0.893 vs. 0.056
# Validation
# AUC = 0.295 vs. 0.075
# F1 = 0.393 vs. 0.107
# Accuracy = 0.636 vs. 0.056
# Minibatch Loss= 0.082955
# Train Batch Evaluation
# AUC = 0.892 vs. 0.075
# F1 = 0.862 vs. 0.106
# Accuracy = 0.886 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.077
# F1 = 0.395 vs. 0.115
# Accuracy = 0.631 vs. 0.056
# Minibatch Loss= 0.082578
# Train Batch Evaluation
# AUC = 0.892 vs. 0.076
# F1 = 0.861 vs. 0.106
# Accuracy = 0.897 vs. 0.056
# Validation
# AUC = 0.295 vs. 0.077
# F1 = 0.393 vs. 0.114
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.082198
# Train Batch Evaluation
# AUC = 0.893 vs. 0.075
# F1 = 0.864 vs. 0.105
# Accuracy = 0.886 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.077
# F1 = 0.395 vs. 0.114
# Accuracy = 0.629 vs. 0.056
# Minibatch Loss= 0.081816
# Train Batch Evaluation
# AUC = 0.893 vs. 0.075
# F1 = 0.863 vs. 0.106
# Accuracy = 0.895 vs. 0.056
# Validation
# AUC = 0.295 vs. 0.077
# F1 = 0.393 vs. 0.111
# Accuracy = 0.640 vs. 0.056
# Minibatch Loss= 0.081352
# Train Batch Evaluation
# AUC = 0.894 vs. 0.076
# F1 = 0.865 vs. 0.106
# Accuracy = 0.889 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.078
# F1 = 0.395 vs. 0.110
# Accuracy = 0.634 vs. 0.056
# Minibatch Loss= 0.080905
# Train Batch Evaluation
# AUC = 0.894 vs. 0.077
# F1 = 0.865 vs. 0.106
# Accuracy = 0.893 vs. 0.056
# Validation
# AUC = 0.295 vs. 0.076
# F1 = 0.393 vs. 0.110
# Accuracy = 0.639 vs. 0.056
# Minibatch Loss= 0.080457
# Train Batch Evaluation
# AUC = 0.895 vs. 0.075
# F1 = 0.865 vs. 0.106
# Accuracy = 0.894 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.075
# F1 = 0.394 vs. 0.110
# Accuracy = 0.634 vs. 0.056
# Minibatch Loss= 0.080052
# Train Batch Evaluation
# AUC = 0.896 vs. 0.075
# F1 = 0.866 vs. 0.105
# Accuracy = 0.890 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.394 vs. 0.111
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.079681
# Train Batch Evaluation
# AUC = 0.896 vs. 0.075
# F1 = 0.867 vs. 0.106
# Accuracy = 0.900 vs. 0.056
# Validation
# AUC = 0.295 vs. 0.076
# F1 = 0.394 vs. 0.111
# Accuracy = 0.640 vs. 0.056
# Minibatch Loss= 0.079327
# Train Batch Evaluation
# AUC = 0.897 vs. 0.075
# F1 = 0.868 vs. 0.106
# Accuracy = 0.887 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.078
# F1 = 0.395 vs. 0.117
# Accuracy = 0.636 vs. 0.056
# Minibatch Loss= 0.079017
# Train Batch Evaluation
# AUC = 0.897 vs. 0.075
# F1 = 0.868 vs. 0.104
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.294 vs. 0.077
# F1 = 0.393 vs. 0.110
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.078696
# Train Batch Evaluation
# AUC = 0.898 vs. 0.075
# F1 = 0.870 vs. 0.106
# Accuracy = 0.883 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.076
# F1 = 0.395 vs. 0.108
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.078466
# Train Batch Evaluation
# AUC = 0.899 vs. 0.075
# F1 = 0.870 vs. 0.105
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.294 vs. 0.076
# F1 = 0.394 vs. 0.111
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.078162
# Train Batch Evaluation
# AUC = 0.899 vs. 0.076
# F1 = 0.871 vs. 0.105
# Accuracy = 0.883 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.076
# F1 = 0.396 vs. 0.110
# Accuracy = 0.640 vs. 0.056
# Minibatch Loss= 0.077956
# Train Batch Evaluation
# AUC = 0.900 vs. 0.075
# F1 = 0.871 vs. 0.105
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.294 vs. 0.077
# F1 = 0.394 vs. 0.109
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.077426
# Train Batch Evaluation
# AUC = 0.900 vs. 0.075
# F1 = 0.872 vs. 0.107
# Accuracy = 0.892 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.075
# F1 = 0.394 vs. 0.109
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.076879
# Train Batch Evaluation
# AUC = 0.902 vs. 0.075
# F1 = 0.873 vs. 0.105
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.395 vs. 0.108
# Accuracy = 0.637 vs. 0.056
# Minibatch Loss= 0.076339
# Train Batch Evaluation
# AUC = 0.902 vs. 0.075
# F1 = 0.873 vs. 0.105
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.294 vs. 0.075
# F1 = 0.394 vs. 0.111
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.075930
# Train Batch Evaluation
# AUC = 0.903 vs. 0.075
# F1 = 0.875 vs. 0.104
# Accuracy = 0.890 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.075
# F1 = 0.396 vs. 0.110
# Accuracy = 0.637 vs. 0.056
# Minibatch Loss= 0.075678
# Train Batch Evaluation
# AUC = 0.903 vs. 0.075
# F1 = 0.875 vs. 0.106
# Accuracy = 0.909 vs. 0.056
# Validation
# AUC = 0.294 vs. 0.075
# F1 = 0.394 vs. 0.111
# Accuracy = 0.644 vs. 0.056
# Minibatch Loss= 0.075378
# Train Batch Evaluation
# AUC = 0.904 vs. 0.075
# F1 = 0.876 vs. 0.104
# Accuracy = 0.891 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.078
# F1 = 0.395 vs. 0.112
# Accuracy = 0.640 vs. 0.056
# Minibatch Loss= 0.075048
# Train Batch Evaluation
# AUC = 0.904 vs. 0.075
# F1 = 0.877 vs. 0.104
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.295 vs. 0.077
# F1 = 0.393 vs. 0.113
# Accuracy = 0.643 vs. 0.056
# Minibatch Loss= 0.074553
# Train Batch Evaluation
# AUC = 0.905 vs. 0.076
# F1 = 0.877 vs. 0.105
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.395 vs. 0.113
# Accuracy = 0.640 vs. 0.056
# Minibatch Loss= 0.074111
# Train Batch Evaluation
# AUC = 0.905 vs. 0.074
# F1 = 0.878 vs. 0.104
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.296 vs. 0.077
# F1 = 0.395 vs. 0.112
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.073768
# Train Batch Evaluation
# AUC = 0.906 vs. 0.076
# F1 = 0.878 vs. 0.106
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.294 vs. 0.075
# F1 = 0.393 vs. 0.109
# Accuracy = 0.643 vs. 0.056
# Minibatch Loss= 0.073474
# Train Batch Evaluation
# ...
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000603
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.076
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000603
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.075
# F1 = 0.361 vs. 0.109
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000602
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.077
# F1 = 0.361 vs. 0.113
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000602
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.277 vs. 0.076
# F1 = 0.361 vs. 0.108
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000601
# Train Batch Evaluation
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.280 vs. 0.078
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000601
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.077
# F1 = 0.361 vs. 0.115
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000600
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.277 vs. 0.076
# F1 = 0.361 vs. 0.109
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000599
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.076
# F1 = 0.361 vs. 0.111
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000598
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.076
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000597
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.077
# F1 = 0.361 vs. 0.111
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000595
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.273 vs. 0.076
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000594
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.282 vs. 0.076
# F1 = 0.361 vs. 0.108
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000593
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.272 vs. 0.077
# F1 = 0.361 vs. 0.111
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000592
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.282 vs. 0.075
# F1 = 0.361 vs. 0.108
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000591
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.078
# F1 = 0.361 vs. 0.114
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000590
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.078
# F1 = 0.361 vs. 0.111
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000589
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.076
# F1 = 0.361 vs. 0.109
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000589
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.274 vs. 0.077
# F1 = 0.361 vs. 0.111
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000588
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.077
# F1 = 0.361 vs. 0.110
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000587
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.075
# F1 = 0.361 vs. 0.108
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000587
# Train Batch Evaluation
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.273 vs. 0.079
# F1 = 0.361 vs. 0.115
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000587
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.076
# F1 = 0.361 vs. 0.110
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000586
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.077
# F1 = 0.361 vs. 0.113
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000586
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.078
# F1 = 0.361 vs. 0.113
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000585
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.076
# F1 = 0.361 vs. 0.113
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000584
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.077
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000583
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.076
# F1 = 0.361 vs. 0.109
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000582
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.282 vs. 0.078
# F1 = 0.361 vs. 0.115
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000581
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.274 vs. 0.076
# F1 = 0.361 vs. 0.111
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000580
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.076
# F1 = 0.361 vs. 0.110
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000579
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.078
# F1 = 0.361 vs. 0.113
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000577
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.107
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.277 vs. 0.078
# F1 = 0.361 vs. 0.115
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000576
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.076
# F1 = 0.361 vs. 0.111
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000576
# Train Batch Evaluation
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.277 vs. 0.076
# F1 = 0.361 vs. 0.109
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000575
# Train Batch Evaluation
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.076
# F1 = 0.361 vs. 0.109
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.000574
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.077
# F1 = 0.361 vs. 0.110
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000574
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.077
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000573
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.076
# F1 = 0.361 vs. 0.110
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000573
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.077
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000572
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.272 vs. 0.076
# F1 = 0.361 vs. 0.110
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000572
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.076
# F1 = 0.361 vs. 0.108
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000571
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.273 vs. 0.077
# F1 = 0.361 vs. 0.112
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000571
# Train Batch Evaluation
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.077
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000570
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.272 vs. 0.077
# F1 = 0.361 vs. 0.113
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000569
# Train Batch Evaluation
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.078
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000568
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.272 vs. 0.077
# F1 = 0.361 vs. 0.109
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000567
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.277 vs. 0.078
# F1 = 0.361 vs. 0.110
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000566
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.272 vs. 0.077
# F1 = 0.361 vs. 0.113
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000565
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.076
# F1 = 0.361 vs. 0.108
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000564
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.274 vs. 0.077
# F1 = 0.361 vs. 0.115
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000563
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.076
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000562
# Train Batch Evaluation
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.274 vs. 0.077
# F1 = 0.361 vs. 0.111
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000561
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.274 vs. 0.078
# F1 = 0.361 vs. 0.110
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000560
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.274 vs. 0.076
# F1 = 0.361 vs. 0.113
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000559
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.077
# F1 = 0.361 vs. 0.113
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000559
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.078
# F1 = 0.361 vs. 0.114
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000558
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.276 vs. 0.076
# F1 = 0.361 vs. 0.109
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000558
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.106
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.076
# F1 = 0.361 vs. 0.108
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000558
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.079
# F1 = 0.361 vs. 0.116
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000557
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.075
# F1 = 0.361 vs. 0.109
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.000557
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.277 vs. 0.078
# F1 = 0.361 vs. 0.111
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000556
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.077
# F1 = 0.361 vs. 0.110
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.000556
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.080
# F1 = 0.361 vs. 0.113
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000555
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.077
# F1 = 0.361 vs. 0.112
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.000554
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.076
# F1 = 0.361 vs. 0.110
# Accuracy = 0.765 vs. 0.056
# Minibatch Loss= 0.000553
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.075
# F1 = 0.361 vs. 0.108
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.000552
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.104
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.279 vs. 0.077
# F1 = 0.361 vs. 0.110
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.000550
# Train Batch Evaluation
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.282 vs. 0.076
# F1 = 0.361 vs. 0.112
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000549
# Train Batch Evaluation
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.105
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.075
# F1 = 0.361 vs. 0.110
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.000548
# Train Batch Evaluation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-b36d9b1bc550> in <module>()
#       2                 train_eval_step = 1,
#       3                 validation_eval_step = 1,
# ----> 4                 display_step = 1)
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#      78
#      79                 print("Train Batch Evaluation")
# ---> 80                 eval_result = self.evaluate_model(self.model, self.sess, batch_x, batch_y)
#      81
#      82                 #summary np.array
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/evaluation/nn_eval_activity.pyc in evaluate_model(model, sess, data, ground_truth)
#      94
#      95     probability_of_pos, pooled_y, debug_info = sess.run((model.prob_of_pos, model.pooled_y, model.debug_info),
# ---> 96                                   feed_dict={model.x: data, model.y:ground_truth})
#      97
#      98     acc = accuracy(probability_of_pos, pooled_y)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1087             feed_handles[subfeed_t] = subfeed_val
#    1088           else:
# -> 1089             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1090
#    1091           if (not is_tensor_handle_feed and
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.537 vs. 0.069
# F1 = 0.586 vs. 0.103
# Accuracy = 0.919 vs. 0.056

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
# Out:
# 1
