# %%
# useing this variable for saving models and summaries
exp_name = "DWN9005_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model_light as wavelet_conv_model
import training
import evaluation.nn_eval_activity as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp1.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((1, 700165, 77), (1, 700165, 18))

# %%
test_data.shape, test_gt.shape
# Out:
# ((1, 120516, 77), (1, 120516, 18))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 1

wavelet_levels = 5    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_kernel_size = 5    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 18

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[0,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

# %%
train_data = train_data[:,:-(train_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_data = validation_data[:,:-(validation_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_data = test_data[:,:-(test_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

train_gt = train_gt[:,:-(train_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_gt = validation_gt[:,:-(validation_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_gt = test_gt[:,:-(test_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

# %%
pos_weight.shape
# Out:
# (18,)

# %%
pos_weight
# Out:
# array([  0.15400844,  34.75163399,  34.29032258,  35.46666667,
#         35.7114094 ,  26.21393035,  26.69620253,  39.51851852,
#         40.59695817,  45.55319149,  50.12149533,  48.50226244,
#         52.10679612,  43.11290323,  43.11290323,  33.08099688,
#         10.4795383 ,  35.83501684])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_kernel_size = wavelet_kernel_size,    
                                 activation = activation)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-637d12b6927a> in <module>()
#       7                                  bias_shape = bias_shape,
#       8                                  wavelet_kernel_size = wavelet_kernel_size,
# ----> 9                                  activation = activation)
#      10
#
# TypeError: build_neural_wavelet_layer() takes exactly 13 arguments (10 given)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'activity')

# %%
trainer.run_debug_ops()
# Out:
# {'wavelet_out_shape': [array([     1, 699392,     77], dtype=int32), array([     1, 349696,     77], dtype=int32), array([     1, 174848,     77], dtype=int32), array([    1, 87424,    77], dtype=int32), array([    1, 43712,    77], dtype=int32)], 'cnn_out_shape': [array([    1, 10928,    18], dtype=int32), array([   1, 5464,   18], dtype=int32), array([   1, 2732,   18], dtype=int32), array([   1, 1366,   18], dtype=int32), array([  1, 683,  18], dtype=int32)], 'input_shape': array([     1, 699392,     77], dtype=int32), 'label_shape': array([     1, 699392,     18], dtype=int32)}

# %%
trainer.train(max_iter = 4000,
                train_eval_step = 1, 
                validation_eval_step = 1,
                display_step = 1)
# Out:
# Train Batch Evaluation
# AUC = 0.079 vs. 0.077
# F1 = 0.122 vs. 0.108
# Accuracy = 0.003 vs. 0.056
# Validation
# AUC = 0.074 vs. 0.070
# F1 = 0.107 vs. 0.099
# Accuracy = 0.000 vs. 0.056
# Minibatch Loss= 1.281807
# Train Batch Evaluation
# AUC = 0.086 vs. 0.077
# F1 = 0.132 vs. 0.109
# Accuracy = 0.005 vs. 0.056
# Validation
# AUC = 0.079 vs. 0.070
# F1 = 0.117 vs. 0.098
# Accuracy = 0.001 vs. 0.056
# Minibatch Loss= 1.280940
# Train Batch Evaluation
# AUC = 0.091 vs. 0.076
# F1 = 0.140 vs. 0.107
# Accuracy = 0.013 vs. 0.056
# Validation
# AUC = 0.083 vs. 0.073
# F1 = 0.120 vs. 0.108
# Accuracy = 0.006 vs. 0.056
# Minibatch Loss= 1.280178
# Train Batch Evaluation
# AUC = 0.094 vs. 0.077
# F1 = 0.147 vs. 0.108
# Accuracy = 0.032 vs. 0.056
# Validation
# AUC = 0.082 vs. 0.071
# F1 = 0.121 vs. 0.108
# Accuracy = 0.013 vs. 0.056
# Minibatch Loss= 1.279428
# Train Batch Evaluation
# AUC = 0.099 vs. 0.077
# F1 = 0.154 vs. 0.108
# Accuracy = 0.035 vs. 0.056
# Validation
# AUC = 0.083 vs. 0.072
# F1 = 0.123 vs. 0.105
# Accuracy = 0.018 vs. 0.056
# Minibatch Loss= 1.278616
# Train Batch Evaluation
# AUC = 0.106 vs. 0.076
# F1 = 0.166 vs. 0.107
# Accuracy = 0.025 vs. 0.056
# Validation
# AUC = 0.085 vs. 0.068
# F1 = 0.130 vs. 0.096
# Accuracy = 0.013 vs. 0.056
# Minibatch Loss= 1.277680
# Train Batch Evaluation
# AUC = 0.113 vs. 0.077
# F1 = 0.176 vs. 0.109
# Accuracy = 0.023 vs. 0.056
# Validation
# AUC = 0.089 vs. 0.070
# F1 = 0.132 vs. 0.097
# Accuracy = 0.010 vs. 0.056
# Minibatch Loss= 1.276611
# Train Batch Evaluation
# AUC = 0.120 vs. 0.078
# F1 = 0.187 vs. 0.111
# Accuracy = 0.021 vs. 0.056
# Validation
# AUC = 0.096 vs. 0.070
# F1 = 0.142 vs. 0.102
# Accuracy = 0.011 vs. 0.056
# Minibatch Loss= 1.275394
# Train Batch Evaluation
# AUC = 0.126 vs. 0.077
# F1 = 0.199 vs. 0.109
# Accuracy = 0.019 vs. 0.056
# Validation
# AUC = 0.096 vs. 0.069
# F1 = 0.149 vs. 0.097
# Accuracy = 0.011 vs. 0.056
# Minibatch Loss= 1.273984
# Train Batch Evaluation
# AUC = 0.132 vs. 0.076
# F1 = 0.207 vs. 0.108
# Accuracy = 0.018 vs. 0.056
# Validation
# AUC = 0.100 vs. 0.071
# F1 = 0.155 vs. 0.106
# Accuracy = 0.011 vs. 0.056
# Minibatch Loss= 1.272343
# Train Batch Evaluation
# AUC = 0.138 vs. 0.078
# F1 = 0.215 vs. 0.109
# Accuracy = 0.018 vs. 0.056
# Validation
# AUC = 0.099 vs. 0.069
# F1 = 0.159 vs. 0.102
# Accuracy = 0.020 vs. 0.056
# Minibatch Loss= 1.270439
# Train Batch Evaluation
# AUC = 0.142 vs. 0.076
# F1 = 0.221 vs. 0.107
# Accuracy = 0.020 vs. 0.056
# Validation
# AUC = 0.099 vs. 0.073
# F1 = 0.161 vs. 0.106
# Accuracy = 0.022 vs. 0.056
# Minibatch Loss= 1.268223
# Train Batch Evaluation
# AUC = 0.146 vs. 0.078
# F1 = 0.228 vs. 0.109
# Accuracy = 0.023 vs. 0.056
# Validation
# AUC = 0.100 vs. 0.070
# F1 = 0.162 vs. 0.103
# Accuracy = 0.023 vs. 0.056
# Minibatch Loss= 1.265639
# Train Batch Evaluation
# AUC = 0.150 vs. 0.077
# F1 = 0.234 vs. 0.108
# Accuracy = 0.023 vs. 0.056
# Validation
# AUC = 0.102 vs. 0.070
# F1 = 0.167 vs. 0.100
# Accuracy = 0.025 vs. 0.056
# Minibatch Loss= 1.262632
# Train Batch Evaluation
# AUC = 0.154 vs. 0.077
# F1 = 0.239 vs. 0.109
# Accuracy = 0.024 vs. 0.056
# Validation
# AUC = 0.104 vs. 0.069
# F1 = 0.171 vs. 0.098
# Accuracy = 0.025 vs. 0.056
# Minibatch Loss= 1.259153
# Train Batch Evaluation
# AUC = 0.157 vs. 0.077
# F1 = 0.244 vs. 0.109
# Accuracy = 0.025 vs. 0.056
# Validation
# AUC = 0.107 vs. 0.072
# F1 = 0.174 vs. 0.103
# Accuracy = 0.024 vs. 0.056
# Minibatch Loss= 1.255136
# Train Batch Evaluation
# AUC = 0.160 vs. 0.077
# F1 = 0.249 vs. 0.107
# Accuracy = 0.025 vs. 0.056
# Validation
# AUC = 0.111 vs. 0.069
# F1 = 0.178 vs. 0.100
# Accuracy = 0.026 vs. 0.056
# Minibatch Loss= 1.250500
# Train Batch Evaluation
# AUC = 0.163 vs. 0.077
# F1 = 0.253 vs. 0.109
# Accuracy = 0.025 vs. 0.056
# Validation
# AUC = 0.113 vs. 0.070
# F1 = 0.185 vs. 0.104
# Accuracy = 0.022 vs. 0.056
# Minibatch Loss= 1.245171
# Train Batch Evaluation
# AUC = 0.166 vs. 0.076
# F1 = 0.258 vs. 0.107
# Accuracy = 0.026 vs. 0.056
# Validation
# AUC = 0.118 vs. 0.069
# F1 = 0.192 vs. 0.102
# Accuracy = 0.022 vs. 0.056
# Minibatch Loss= 1.239080
# Train Batch Evaluation
# AUC = 0.169 vs. 0.078
# F1 = 0.262 vs. 0.109
# Accuracy = 0.028 vs. 0.056
# Validation
# AUC = 0.121 vs. 0.071
# F1 = 0.195 vs. 0.101
# Accuracy = 0.019 vs. 0.056
# Minibatch Loss= 1.232112
# Train Batch Evaluation
# AUC = 0.172 vs. 0.077
# F1 = 0.266 vs. 0.108
# Accuracy = 0.032 vs. 0.056
# Validation
# AUC = 0.124 vs. 0.073
# F1 = 0.199 vs. 0.107
# Accuracy = 0.013 vs. 0.056
# Minibatch Loss= 1.224133
# Train Batch Evaluation
# AUC = 0.175 vs. 0.078
# F1 = 0.269 vs. 0.111
# Accuracy = 0.036 vs. 0.056
# Validation
# AUC = 0.127 vs. 0.068
# F1 = 0.207 vs. 0.098
# Accuracy = 0.015 vs. 0.056
# Minibatch Loss= 1.215044
# Train Batch Evaluation
# AUC = 0.179 vs. 0.077
# F1 = 0.273 vs. 0.108
# Accuracy = 0.040 vs. 0.056
# Validation
# AUC = 0.131 vs. 0.070
# F1 = 0.217 vs. 0.099
# Accuracy = 0.016 vs. 0.056
# Minibatch Loss= 1.204735
# Train Batch Evaluation
# AUC = 0.184 vs. 0.078
# F1 = 0.277 vs. 0.111
# Accuracy = 0.043 vs. 0.056
# Validation
# AUC = 0.136 vs. 0.068
# F1 = 0.226 vs. 0.095
# Accuracy = 0.021 vs. 0.056
# Minibatch Loss= 1.193114
# Train Batch Evaluation
# AUC = 0.188 vs. 0.077
# F1 = 0.281 vs. 0.109
# Accuracy = 0.045 vs. 0.056
# Validation
# AUC = 0.140 vs. 0.069
# F1 = 0.232 vs. 0.095
# Accuracy = 0.024 vs. 0.056
# Minibatch Loss= 1.180087
# Train Batch Evaluation
# AUC = 0.193 vs. 0.076
# F1 = 0.285 vs. 0.108
# Accuracy = 0.047 vs. 0.056
# Validation
# AUC = 0.153 vs. 0.075
# F1 = 0.236 vs. 0.111
# Accuracy = 0.025 vs. 0.056
# Minibatch Loss= 1.165553
# Train Batch Evaluation
# AUC = 0.198 vs. 0.077
# F1 = 0.291 vs. 0.109
# Accuracy = 0.051 vs. 0.056
# Validation
# AUC = 0.159 vs. 0.070
# F1 = 0.242 vs. 0.105
# Accuracy = 0.027 vs. 0.056
# Minibatch Loss= 1.149421
# Train Batch Evaluation
# AUC = 0.204 vs. 0.078
# F1 = 0.294 vs. 0.110
# Accuracy = 0.055 vs. 0.056
# Validation
# AUC = 0.166 vs. 0.073
# F1 = 0.249 vs. 0.107
# Accuracy = 0.028 vs. 0.056
# Minibatch Loss= 1.131664
# Train Batch Evaluation
# AUC = 0.209 vs. 0.077
# F1 = 0.299 vs. 0.108
# Accuracy = 0.065 vs. 0.056
# Validation
# AUC = 0.167 vs. 0.070
# F1 = 0.248 vs. 0.104
# Accuracy = 0.035 vs. 0.056
# Minibatch Loss= 1.112313
# Train Batch Evaluation
# AUC = 0.214 vs. 0.076
# F1 = 0.302 vs. 0.107
# Accuracy = 0.078 vs. 0.056
# Validation
# AUC = 0.165 vs. 0.069
# F1 = 0.247 vs. 0.102
# Accuracy = 0.045 vs. 0.056
# Minibatch Loss= 1.091510
# Train Batch Evaluation
# AUC = 0.217 vs. 0.077
# F1 = 0.305 vs. 0.109
# Accuracy = 0.094 vs. 0.056
# Validation
# AUC = 0.166 vs. 0.075
# F1 = 0.246 vs. 0.112
# Accuracy = 0.056 vs. 0.056
# Minibatch Loss= 1.069462
# Train Batch Evaluation
# AUC = 0.219 vs. 0.077
# F1 = 0.305 vs. 0.107
# Accuracy = 0.113 vs. 0.056
# Validation
# AUC = 0.164 vs. 0.070
# F1 = 0.248 vs. 0.101
# Accuracy = 0.072 vs. 0.056
# Minibatch Loss= 1.046476
# Train Batch Evaluation
# AUC = 0.219 vs. 0.077
# F1 = 0.304 vs. 0.107
# Accuracy = 0.140 vs. 0.056
# Validation
# AUC = 0.165 vs. 0.070
# F1 = 0.247 vs. 0.100
# Accuracy = 0.102 vs. 0.056
# Minibatch Loss= 1.023000
# Train Batch Evaluation
# AUC = 0.218 vs. 0.077
# F1 = 0.302 vs. 0.108
# Accuracy = 0.166 vs. 0.056
# Validation
# AUC = 0.165 vs. 0.071
# F1 = 0.246 vs. 0.103
# Accuracy = 0.132 vs. 0.056
# Minibatch Loss= 0.999525
# Train Batch Evaluation
# AUC = 0.218 vs. 0.078
# F1 = 0.303 vs. 0.110
# Accuracy = 0.198 vs. 0.056
# Validation
# AUC = 0.163 vs. 0.070
# F1 = 0.244 vs. 0.099
# Accuracy = 0.163 vs. 0.056
# Minibatch Loss= 0.976559
# Train Batch Evaluation
# AUC = 0.219 vs. 0.077
# F1 = 0.303 vs. 0.108
# Accuracy = 0.241 vs. 0.056
# Validation
# AUC = 0.163 vs. 0.074
# F1 = 0.246 vs. 0.112
# Accuracy = 0.200 vs. 0.056
# Minibatch Loss= 0.954530
# Train Batch Evaluation
# AUC = 0.222 vs. 0.077
# F1 = 0.304 vs. 0.108
# Accuracy = 0.278 vs. 0.056
# Validation
# AUC = 0.163 vs. 0.072
# F1 = 0.247 vs. 0.102
# Accuracy = 0.236 vs. 0.056
# Minibatch Loss= 0.933796
# Train Batch Evaluation
# AUC = 0.224 vs. 0.076
# F1 = 0.305 vs. 0.109
# Accuracy = 0.315 vs. 0.056
# Validation
# AUC = 0.163 vs. 0.070
# F1 = 0.247 vs. 0.107
# Accuracy = 0.268 vs. 0.056
# Minibatch Loss= 0.914624
# Train Batch Evaluation
# AUC = 0.229 vs. 0.077
# F1 = 0.306 vs. 0.109
# Accuracy = 0.341 vs. 0.056
# Validation
# AUC = 0.166 vs. 0.070
# F1 = 0.248 vs. 0.100
# Accuracy = 0.290 vs. 0.056
# Minibatch Loss= 0.897105
# Train Batch Evaluation
# AUC = 0.234 vs. 0.077
# F1 = 0.310 vs. 0.109
# Accuracy = 0.348 vs. 0.056
# Validation
# AUC = 0.170 vs. 0.070
# F1 = 0.249 vs. 0.099
# Accuracy = 0.303 vs. 0.056
# Minibatch Loss= 0.881247
# Train Batch Evaluation
# AUC = 0.237 vs. 0.076
# F1 = 0.314 vs. 0.107
# Accuracy = 0.337 vs. 0.056
# Validation
# AUC = 0.173 vs. 0.076
# F1 = 0.253 vs. 0.109
# Accuracy = 0.295 vs. 0.056
# Minibatch Loss= 0.867084
# Train Batch Evaluation
# AUC = 0.241 vs. 0.077
# F1 = 0.319 vs. 0.108
# Accuracy = 0.291 vs. 0.056
# Validation
# AUC = 0.171 vs. 0.073
# F1 = 0.254 vs. 0.109
# Accuracy = 0.246 vs. 0.056
# Minibatch Loss= 0.854586
# Train Batch Evaluation
# AUC = 0.244 vs. 0.077
# F1 = 0.326 vs. 0.108
# Accuracy = 0.259 vs. 0.056
# Validation
# AUC = 0.170 vs. 0.071
# F1 = 0.255 vs. 0.107
# Accuracy = 0.190 vs. 0.056
# Minibatch Loss= 0.843718
# Train Batch Evaluation
# AUC = 0.249 vs. 0.077
# F1 = 0.332 vs. 0.109
# Accuracy = 0.231 vs. 0.056
# Validation
# AUC = 0.167 vs. 0.072
# F1 = 0.258 vs. 0.110
# Accuracy = 0.161 vs. 0.056
# Minibatch Loss= 0.834331
# Train Batch Evaluation
# AUC = 0.254 vs. 0.077
# F1 = 0.340 vs. 0.109
# Accuracy = 0.184 vs. 0.056
# Validation
# AUC = 0.167 vs. 0.070
# F1 = 0.259 vs. 0.098
# Accuracy = 0.116 vs. 0.056
# Minibatch Loss= 0.826059
# Train Batch Evaluation
# AUC = 0.260 vs. 0.077
# F1 = 0.348 vs. 0.108
# Accuracy = 0.150 vs. 0.056
# Validation
# AUC = 0.168 vs. 0.072
# F1 = 0.262 vs. 0.105
# Accuracy = 0.092 vs. 0.056
# Minibatch Loss= 0.817922
# Train Batch Evaluation
# AUC = 0.266 vs. 0.076
# F1 = 0.355 vs. 0.108
# Accuracy = 0.136 vs. 0.056
# Validation
# AUC = 0.170 vs. 0.072
# F1 = 0.262 vs. 0.109
# Accuracy = 0.081 vs. 0.056
# Minibatch Loss= 0.808943
# Train Batch Evaluation
# AUC = 0.272 vs. 0.077
# F1 = 0.360 vs. 0.108
# Accuracy = 0.133 vs. 0.056
# Validation
# AUC = 0.173 vs. 0.070
# F1 = 0.261 vs. 0.105
# Accuracy = 0.076 vs. 0.056
# Minibatch Loss= 0.798800
# Train Batch Evaluation
# AUC = 0.278 vs. 0.077
# F1 = 0.364 vs. 0.107
# Accuracy = 0.139 vs. 0.056
# Validation
# AUC = 0.171 vs. 0.072
# F1 = 0.257 vs. 0.106
# Accuracy = 0.078 vs. 0.056
# Minibatch Loss= 0.787853
# Train Batch Evaluation
# AUC = 0.284 vs. 0.077
# F1 = 0.368 vs. 0.109
# Accuracy = 0.147 vs. 0.056
# Validation
# AUC = 0.172 vs. 0.071
# F1 = 0.259 vs. 0.099
# Accuracy = 0.083 vs. 0.056
# Minibatch Loss= 0.776559
# Train Batch Evaluation
# AUC = 0.290 vs. 0.076
# F1 = 0.373 vs. 0.109
# Accuracy = 0.142 vs. 0.056
# Validation
# AUC = 0.170 vs. 0.070
# F1 = 0.255 vs. 0.104
# Accuracy = 0.092 vs. 0.056
# Minibatch Loss= 0.765175
# Train Batch Evaluation
# AUC = 0.295 vs. 0.077
# F1 = 0.375 vs. 0.109
# Accuracy = 0.139 vs. 0.056
# Validation
# AUC = 0.171 vs. 0.071
# F1 = 0.254 vs. 0.106
# Accuracy = 0.098 vs. 0.056
# Minibatch Loss= 0.753899
# Train Batch Evaluation
# AUC = 0.300 vs. 0.077
# F1 = 0.379 vs. 0.109
# Accuracy = 0.149 vs. 0.056
# Validation
# AUC = 0.173 vs. 0.073
# F1 = 0.252 vs. 0.104
# Accuracy = 0.111 vs. 0.056
# Minibatch Loss= 0.742945
# Train Batch Evaluation
# AUC = 0.305 vs. 0.077
# F1 = 0.385 vs. 0.108
# Accuracy = 0.162 vs. 0.056
# Validation
# AUC = 0.175 vs. 0.074
# F1 = 0.255 vs. 0.107
# Accuracy = 0.126 vs. 0.056
# Minibatch Loss= 0.732418
# Train Batch Evaluation
# AUC = 0.310 vs. 0.077
# F1 = 0.388 vs. 0.110
# Accuracy = 0.177 vs. 0.056
# Validation
# AUC = 0.178 vs. 0.070
# F1 = 0.261 vs. 0.100
# Accuracy = 0.144 vs. 0.056
# Minibatch Loss= 0.722330
# Train Batch Evaluation
# AUC = 0.315 vs. 0.077
# F1 = 0.391 vs. 0.108
# Accuracy = 0.185 vs. 0.056
# Validation
# AUC = 0.182 vs. 0.071
# F1 = 0.260 vs. 0.104
# Accuracy = 0.153 vs. 0.056
# Minibatch Loss= 0.712617
# Train Batch Evaluation
# AUC = 0.320 vs. 0.077
# F1 = 0.395 vs. 0.109
# Accuracy = 0.189 vs. 0.056
# Validation
# AUC = 0.186 vs. 0.070
# F1 = 0.263 vs. 0.100
# Accuracy = 0.162 vs. 0.056
# Minibatch Loss= 0.703213
# Train Batch Evaluation
# AUC = 0.324 vs. 0.077
# F1 = 0.397 vs. 0.108
# Accuracy = 0.188 vs. 0.056
# Validation
# AUC = 0.189 vs. 0.071
# F1 = 0.267 vs. 0.108
# Accuracy = 0.161 vs. 0.056
# Minibatch Loss= 0.694102
# Train Batch Evaluation
# AUC = 0.328 vs. 0.076
# F1 = 0.401 vs. 0.108
# Accuracy = 0.183 vs. 0.056
# Validation
# AUC = 0.192 vs. 0.068
# F1 = 0.271 vs. 0.098
# Accuracy = 0.159 vs. 0.056
# Minibatch Loss= 0.685128
# Train Batch Evaluation
# AUC = 0.332 vs. 0.076
# F1 = 0.403 vs. 0.108
# Accuracy = 0.184 vs. 0.056
# Validation
# AUC = 0.193 vs. 0.074
# F1 = 0.274 vs. 0.109
# Accuracy = 0.157 vs. 0.056
# Minibatch Loss= 0.676190
# Train Batch Evaluation
# AUC = 0.336 vs. 0.078
# F1 = 0.406 vs. 0.109
# Accuracy = 0.190 vs. 0.056
# Validation
# AUC = 0.195 vs. 0.073
# F1 = 0.275 vs. 0.109
# Accuracy = 0.157 vs. 0.056
# Minibatch Loss= 0.667270
# Train Batch Evaluation
# AUC = 0.339 vs. 0.077
# F1 = 0.410 vs. 0.109
# Accuracy = 0.204 vs. 0.056
# Validation
# AUC = 0.196 vs. 0.071
# F1 = 0.278 vs. 0.107
# Accuracy = 0.165 vs. 0.056
# Minibatch Loss= 0.658460
# Train Batch Evaluation
# AUC = 0.343 vs. 0.077
# F1 = 0.412 vs. 0.109
# Accuracy = 0.220 vs. 0.056
# Validation
# AUC = 0.199 vs. 0.074
# F1 = 0.280 vs. 0.101
# Accuracy = 0.169 vs. 0.056
# Minibatch Loss= 0.649884
# Train Batch Evaluation
# AUC = 0.346 vs. 0.077
# F1 = 0.415 vs. 0.108
# Accuracy = 0.233 vs. 0.056
# Validation
# AUC = 0.202 vs. 0.070
# F1 = 0.283 vs. 0.104
# Accuracy = 0.181 vs. 0.056
# Minibatch Loss= 0.641556
# Train Batch Evaluation
# AUC = 0.350 vs. 0.077
# F1 = 0.419 vs. 0.109
# Accuracy = 0.242 vs. 0.056
# Validation
# AUC = 0.205 vs. 0.073
# F1 = 0.287 vs. 0.110
# Accuracy = 0.187 vs. 0.056
# Minibatch Loss= 0.633263
# Train Batch Evaluation
# AUC = 0.354 vs. 0.076
# F1 = 0.422 vs. 0.108
# Accuracy = 0.246 vs. 0.056
# Validation
# AUC = 0.208 vs. 0.073
# F1 = 0.288 vs. 0.110
# Accuracy = 0.188 vs. 0.056
# Minibatch Loss= 0.624769
# Train Batch Evaluation
# AUC = 0.358 vs. 0.077
# F1 = 0.426 vs. 0.108
# Accuracy = 0.247 vs. 0.056
# Validation
# AUC = 0.209 vs. 0.069
# F1 = 0.294 vs. 0.098
# Accuracy = 0.184 vs. 0.056
# Minibatch Loss= 0.615999
# Train Batch Evaluation
# AUC = 0.364 vs. 0.077
# F1 = 0.430 vs. 0.109
# Accuracy = 0.244 vs. 0.056
# Validation
# AUC = 0.213 vs. 0.072
# F1 = 0.299 vs. 0.102
# Accuracy = 0.187 vs. 0.056
# Minibatch Loss= 0.607077
# Train Batch Evaluation
# AUC = 0.370 vs. 0.077
# F1 = 0.435 vs. 0.109
# Accuracy = 0.242 vs. 0.056
# Validation
# AUC = 0.216 vs. 0.075
# F1 = 0.304 vs. 0.107
# Accuracy = 0.187 vs. 0.056
# Minibatch Loss= 0.598170
# Train Batch Evaluation
# AUC = 0.376 vs. 0.077
# F1 = 0.439 vs. 0.109
# Accuracy = 0.242 vs. 0.056
# Validation
# AUC = 0.220 vs. 0.069
# F1 = 0.308 vs. 0.101
# Accuracy = 0.187 vs. 0.056
# Minibatch Loss= 0.589348
# Train Batch Evaluation
# AUC = 0.382 vs. 0.076
# F1 = 0.445 vs. 0.107
# Accuracy = 0.244 vs. 0.056
# Validation
# AUC = 0.225 vs. 0.071
# F1 = 0.311 vs. 0.110
# Accuracy = 0.188 vs. 0.056
# Minibatch Loss= 0.580630
# Train Batch Evaluation
# AUC = 0.387 vs. 0.076
# F1 = 0.449 vs. 0.108
# Accuracy = 0.250 vs. 0.056
# Validation
# AUC = 0.231 vs. 0.072
# F1 = 0.317 vs. 0.107
# Accuracy = 0.204 vs. 0.056
# Minibatch Loss= 0.572052
# Train Batch Evaluation
# AUC = 0.392 vs. 0.077
# F1 = 0.453 vs. 0.109
# Accuracy = 0.258 vs. 0.056
# Validation
# AUC = 0.235 vs. 0.072
# F1 = 0.324 vs. 0.104
# Accuracy = 0.211 vs. 0.056
# Minibatch Loss= 0.563667
# Train Batch Evaluation
# AUC = 0.397 vs. 0.076
# F1 = 0.457 vs. 0.107
# Accuracy = 0.264 vs. 0.056
# Validation
# AUC = 0.243 vs. 0.073
# F1 = 0.330 vs. 0.109
# Accuracy = 0.217 vs. 0.056
# Minibatch Loss= 0.555560
# Train Batch Evaluation
# AUC = 0.402 vs. 0.076
# F1 = 0.462 vs. 0.107
# Accuracy = 0.267 vs. 0.056
# Validation
# AUC = 0.249 vs. 0.068
# F1 = 0.338 vs. 0.098
# Accuracy = 0.218 vs. 0.056
# Minibatch Loss= 0.547623
# Train Batch Evaluation
# AUC = 0.407 vs. 0.077
# F1 = 0.467 vs. 0.108
# Accuracy = 0.266 vs. 0.056
# Validation
# AUC = 0.253 vs. 0.070
# F1 = 0.340 vs. 0.100
# Accuracy = 0.214 vs. 0.056
# Minibatch Loss= 0.539784
# Train Batch Evaluation
# AUC = 0.412 vs. 0.077
# F1 = 0.471 vs. 0.108
# Accuracy = 0.264 vs. 0.056
# Validation
# AUC = 0.257 vs. 0.070
# F1 = 0.343 vs. 0.102
# Accuracy = 0.208 vs. 0.056
# Minibatch Loss= 0.532089
# Train Batch Evaluation
# AUC = 0.417 vs. 0.076
# F1 = 0.474 vs. 0.107
# Accuracy = 0.261 vs. 0.056
# Validation
# AUC = 0.260 vs. 0.073
# F1 = 0.348 vs. 0.110
# Accuracy = 0.199 vs. 0.056
# Minibatch Loss= 0.524643
# Train Batch Evaluation
# AUC = 0.422 vs. 0.076
# F1 = 0.480 vs. 0.108
# Accuracy = 0.259 vs. 0.056
# Validation
# AUC = 0.266 vs. 0.073
# F1 = 0.350 vs. 0.108
# Accuracy = 0.198 vs. 0.056
# Minibatch Loss= 0.517470
# Train Batch Evaluation
# AUC = 0.427 vs. 0.077
# F1 = 0.485 vs. 0.109
# Accuracy = 0.261 vs. 0.056
# Validation
# AUC = 0.272 vs. 0.069
# F1 = 0.354 vs. 0.101
# Accuracy = 0.196 vs. 0.056
# Minibatch Loss= 0.510551
# Train Batch Evaluation
# AUC = 0.432 vs. 0.076
# F1 = 0.491 vs. 0.108
# Accuracy = 0.271 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.071
# F1 = 0.358 vs. 0.107
# Accuracy = 0.212 vs. 0.056
# Minibatch Loss= 0.503810
# Train Batch Evaluation
# AUC = 0.437 vs. 0.077
# F1 = 0.495 vs. 0.109
# Accuracy = 0.287 vs. 0.056
# Validation
# AUC = 0.282 vs. 0.073
# F1 = 0.362 vs. 0.103
# Accuracy = 0.230 vs. 0.056
# Minibatch Loss= 0.497256
# Train Batch Evaluation
# AUC = 0.443 vs. 0.077
# F1 = 0.499 vs. 0.108
# Accuracy = 0.306 vs. 0.056
# Validation
# AUC = 0.286 vs. 0.071
# F1 = 0.366 vs. 0.105
# Accuracy = 0.254 vs. 0.056
# Minibatch Loss= 0.490890
# Train Batch Evaluation
# AUC = 0.448 vs. 0.077
# F1 = 0.505 vs. 0.108
# Accuracy = 0.324 vs. 0.056
# Validation
# AUC = 0.289 vs. 0.073
# F1 = 0.369 vs. 0.104
# Accuracy = 0.285 vs. 0.056
# Minibatch Loss= 0.484690
# Train Batch Evaluation
# AUC = 0.454 vs. 0.077
# F1 = 0.509 vs. 0.109
# Accuracy = 0.337 vs. 0.056
# Validation
# AUC = 0.293 vs. 0.071
# F1 = 0.375 vs. 0.101
# Accuracy = 0.306 vs. 0.056
# Minibatch Loss= 0.478647
# Train Batch Evaluation
# AUC = 0.459 vs. 0.077
# F1 = 0.514 vs. 0.108
# Accuracy = 0.347 vs. 0.056
# Validation
# AUC = 0.300 vs. 0.069
# F1 = 0.379 vs. 0.097
# Accuracy = 0.321 vs. 0.056
# Minibatch Loss= 0.472762
# Train Batch Evaluation
# AUC = 0.464 vs. 0.076
# F1 = 0.519 vs. 0.108
# Accuracy = 0.354 vs. 0.056
# Validation
# AUC = 0.303 vs. 0.074
# F1 = 0.384 vs. 0.104
# Accuracy = 0.327 vs. 0.056
# Minibatch Loss= 0.467004
# Train Batch Evaluation
# AUC = 0.469 vs. 0.077
# F1 = 0.523 vs. 0.108
# Accuracy = 0.358 vs. 0.056
# Validation
# AUC = 0.307 vs. 0.071
# F1 = 0.385 vs. 0.100
# Accuracy = 0.329 vs. 0.056
# Minibatch Loss= 0.461368
# Train Batch Evaluation
# AUC = 0.474 vs. 0.077
# F1 = 0.526 vs. 0.108
# Accuracy = 0.364 vs. 0.056
# Validation
# AUC = 0.312 vs. 0.072
# F1 = 0.389 vs. 0.106
# Accuracy = 0.329 vs. 0.056
# Minibatch Loss= 0.455832
# Train Batch Evaluation
# AUC = 0.478 vs. 0.077
# F1 = 0.530 vs. 0.108
# Accuracy = 0.373 vs. 0.056
# Validation
# AUC = 0.315 vs. 0.069
# F1 = 0.391 vs. 0.094
# Accuracy = 0.334 vs. 0.056
# Minibatch Loss= 0.450405
# Train Batch Evaluation
# AUC = 0.483 vs. 0.077
# F1 = 0.533 vs. 0.109
# Accuracy = 0.385 vs. 0.056
# Validation
# AUC = 0.321 vs. 0.070
# F1 = 0.391 vs. 0.097
# Accuracy = 0.340 vs. 0.056
# Minibatch Loss= 0.445094
# Train Batch Evaluation
# AUC = 0.487 vs. 0.077
# F1 = 0.536 vs. 0.108
# Accuracy = 0.402 vs. 0.056
# Validation
# AUC = 0.325 vs. 0.073
# F1 = 0.397 vs. 0.108
# Accuracy = 0.351 vs. 0.056
# Minibatch Loss= 0.439903
# Train Batch Evaluation
# AUC = 0.491 vs. 0.076
# F1 = 0.539 vs. 0.107
# Accuracy = 0.425 vs. 0.056
# Validation
# AUC = 0.328 vs. 0.075
# F1 = 0.400 vs. 0.117
# Accuracy = 0.369 vs. 0.056
# Minibatch Loss= 0.434796
# Train Batch Evaluation
# AUC = 0.496 vs. 0.077
# F1 = 0.542 vs. 0.110
# Accuracy = 0.452 vs. 0.056
# Validation
# AUC = 0.331 vs. 0.071
# F1 = 0.405 vs. 0.103
# Accuracy = 0.393 vs. 0.056
# Minibatch Loss= 0.429757
# Train Batch Evaluation
# AUC = 0.500 vs. 0.077
# F1 = 0.544 vs. 0.109
# Accuracy = 0.478 vs. 0.056
# Validation
# AUC = 0.335 vs. 0.069
# F1 = 0.408 vs. 0.095
# Accuracy = 0.426 vs. 0.056
# Minibatch Loss= 0.424837
# Train Batch Evaluation
# AUC = 0.504 vs. 0.076
# F1 = 0.546 vs. 0.107
# Accuracy = 0.502 vs. 0.056
# Validation
# AUC = 0.339 vs. 0.070
# F1 = 0.412 vs. 0.103
# Accuracy = 0.465 vs. 0.056
# Minibatch Loss= 0.420020
# Train Batch Evaluation
# AUC = 0.508 vs. 0.076
# F1 = 0.549 vs. 0.108
# Accuracy = 0.523 vs. 0.056
# Validation
# AUC = 0.343 vs. 0.071
# F1 = 0.416 vs. 0.104
# Accuracy = 0.496 vs. 0.056
# Minibatch Loss= 0.415261
# Train Batch Evaluation
# AUC = 0.513 vs. 0.076
# F1 = 0.552 vs. 0.107
# Accuracy = 0.532 vs. 0.056
# Validation
# AUC = 0.346 vs. 0.069
# F1 = 0.421 vs. 0.099
# Accuracy = 0.510 vs. 0.056
# Minibatch Loss= 0.410539
# Train Batch Evaluation
# AUC = 0.517 vs. 0.077
# F1 = 0.555 vs. 0.110
# Accuracy = 0.537 vs. 0.056
# Validation
# AUC = 0.350 vs. 0.069
# F1 = 0.426 vs. 0.095
# Accuracy = 0.516 vs. 0.056
# Minibatch Loss= 0.405868
# Train Batch Evaluation
# AUC = 0.521 vs. 0.076
# F1 = 0.558 vs. 0.108
# Accuracy = 0.533 vs. 0.056
# Validation
# AUC = 0.354 vs. 0.069
# F1 = 0.431 vs. 0.101
# Accuracy = 0.513 vs. 0.056
# Minibatch Loss= 0.401280
# Train Batch Evaluation
# AUC = 0.525 vs. 0.077
# F1 = 0.561 vs. 0.107
# Accuracy = 0.540 vs. 0.056
# Validation
# AUC = 0.358 vs. 0.070
# F1 = 0.432 vs. 0.110
# Accuracy = 0.520 vs. 0.056
# Minibatch Loss= 0.396806
# Train Batch Evaluation
# AUC = 0.529 vs. 0.077
# F1 = 0.564 vs. 0.108
# Accuracy = 0.532 vs. 0.056
# Validation
# AUC = 0.362 vs. 0.071
# F1 = 0.438 vs. 0.100
# Accuracy = 0.511 vs. 0.056
# Minibatch Loss= 0.392608
# Train Batch Evaluation
# AUC = 0.533 vs. 0.077
# F1 = 0.567 vs. 0.107
# Accuracy = 0.560 vs. 0.056
# Validation
# AUC = 0.367 vs. 0.070
# F1 = 0.444 vs. 0.096
# Accuracy = 0.538 vs. 0.056
# Minibatch Loss= 0.389127
# Train Batch Evaluation
# AUC = 0.536 vs. 0.077
# F1 = 0.571 vs. 0.109
# Accuracy = 0.540 vs. 0.056
# Validation
# AUC = 0.369 vs. 0.076
# F1 = 0.448 vs. 0.111
# Accuracy = 0.520 vs. 0.056
# Minibatch Loss= 0.386153
# Train Batch Evaluation
# AUC = 0.541 vs. 0.077
# F1 = 0.573 vs. 0.108
# Accuracy = 0.595 vs. 0.056
# Validation
# AUC = 0.373 vs. 0.074
# F1 = 0.452 vs. 0.105
# Accuracy = 0.562 vs. 0.056
# Minibatch Loss= 0.382004
# Train Batch Evaluation
# AUC = 0.544 vs. 0.076
# F1 = 0.576 vs. 0.108
# Accuracy = 0.590 vs. 0.056
# Validation
# AUC = 0.376 vs. 0.071
# F1 = 0.455 vs. 0.107
# Accuracy = 0.565 vs. 0.056
# Minibatch Loss= 0.376321
# Train Batch Evaluation
# AUC = 0.547 vs. 0.077
# F1 = 0.579 vs. 0.110
# Accuracy = 0.596 vs. 0.056
# Validation
# AUC = 0.377 vs. 0.070
# F1 = 0.456 vs. 0.098
# Accuracy = 0.579 vs. 0.056
# Minibatch Loss= 0.373565
# Train Batch Evaluation
# AUC = 0.551 vs. 0.077
# F1 = 0.582 vs. 0.108
# Accuracy = 0.632 vs. 0.056
# Validation
# AUC = 0.383 vs. 0.069
# F1 = 0.463 vs. 0.105
# Accuracy = 0.610 vs. 0.056
# Minibatch Loss= 0.370683
# Train Batch Evaluation
# AUC = 0.553 vs. 0.077
# F1 = 0.584 vs. 0.108
# Accuracy = 0.621 vs. 0.056
# Validation
# AUC = 0.384 vs. 0.072
# F1 = 0.463 vs. 0.108
# Accuracy = 0.599 vs. 0.056
# Minibatch Loss= 0.365640
# Train Batch Evaluation
# AUC = 0.557 vs. 0.076
# F1 = 0.587 vs. 0.108
# Accuracy = 0.616 vs. 0.056
# Validation
# AUC = 0.386 vs. 0.070
# F1 = 0.462 vs. 0.104
# Accuracy = 0.590 vs. 0.056
# Minibatch Loss= 0.362942
# Train Batch Evaluation
# AUC = 0.560 vs. 0.078
# F1 = 0.589 vs. 0.109
# Accuracy = 0.636 vs. 0.056
# Validation
# AUC = 0.391 vs. 0.069
# F1 = 0.466 vs. 0.097
# Accuracy = 0.612 vs. 0.056
# Minibatch Loss= 0.359829
# Train Batch Evaluation
# AUC = 0.562 vs. 0.078
# F1 = 0.592 vs. 0.109
# Accuracy = 0.627 vs. 0.056
# Validation
# AUC = 0.392 vs. 0.070
# F1 = 0.468 vs. 0.102
# Accuracy = 0.596 vs. 0.056
# Minibatch Loss= 0.355612
# Train Batch Evaluation
# AUC = 0.566 vs. 0.077
# F1 = 0.595 vs. 0.108
# Accuracy = 0.623 vs. 0.056
# Validation
# AUC = 0.392 vs. 0.071
# F1 = 0.464 vs. 0.109
# Accuracy = 0.590 vs. 0.056
# Minibatch Loss= 0.353128
# Train Batch Evaluation
# AUC = 0.569 vs. 0.077
# F1 = 0.597 vs. 0.108
# Accuracy = 0.646 vs. 0.056
# Validation
# AUC = 0.395 vs. 0.069
# F1 = 0.468 vs. 0.096
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.349759
# Train Batch Evaluation
# AUC = 0.571 vs. 0.077
# F1 = 0.599 vs. 0.108
# Accuracy = 0.640 vs. 0.056
# Validation
# AUC = 0.396 vs. 0.071
# F1 = 0.468 vs. 0.102
# Accuracy = 0.611 vs. 0.056
# Minibatch Loss= 0.346434
# Train Batch Evaluation
# AUC = 0.575 vs. 0.077
# F1 = 0.602 vs. 0.109
# Accuracy = 0.640 vs. 0.056
# Validation
# AUC = 0.393 vs. 0.069
# F1 = 0.465 vs. 0.100
# Accuracy = 0.599 vs. 0.056
# Minibatch Loss= 0.343708
# Train Batch Evaluation
# AUC = 0.579 vs. 0.077
# F1 = 0.604 vs. 0.108
# Accuracy = 0.655 vs. 0.056
# Validation
# AUC = 0.397 vs. 0.073
# F1 = 0.465 vs. 0.113
# Accuracy = 0.629 vs. 0.056
# Minibatch Loss= 0.340452
# Train Batch Evaluation
# AUC = 0.581 vs. 0.077
# F1 = 0.605 vs. 0.109
# Accuracy = 0.656 vs. 0.056
# Validation
# AUC = 0.399 vs. 0.070
# F1 = 0.468 vs. 0.100
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.337817
# Train Batch Evaluation
# AUC = 0.584 vs. 0.077
# F1 = 0.609 vs. 0.110
# Accuracy = 0.652 vs. 0.056
# Validation
# AUC = 0.399 vs. 0.071
# F1 = 0.465 vs. 0.105
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.334756
# Train Batch Evaluation
# AUC = 0.587 vs. 0.076
# F1 = 0.610 vs. 0.108
# Accuracy = 0.662 vs. 0.056
# Validation
# AUC = 0.401 vs. 0.071
# F1 = 0.468 vs. 0.104
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.331894
# Train Batch Evaluation
# AUC = 0.589 vs. 0.077
# F1 = 0.612 vs. 0.109
# Accuracy = 0.660 vs. 0.056
# Validation
# AUC = 0.402 vs. 0.070
# F1 = 0.468 vs. 0.102
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.329602
# Train Batch Evaluation
# AUC = 0.592 vs. 0.078
# F1 = 0.615 vs. 0.109
# Accuracy = 0.657 vs. 0.056
# Validation
# AUC = 0.404 vs. 0.073
# F1 = 0.467 vs. 0.109
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.326383
# Train Batch Evaluation
# AUC = 0.595 vs. 0.076
# F1 = 0.618 vs. 0.107
# Accuracy = 0.659 vs. 0.056
# Validation
# AUC = 0.404 vs. 0.068
# F1 = 0.467 vs. 0.092
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.323891
# Train Batch Evaluation
# AUC = 0.597 vs. 0.076
# F1 = 0.620 vs. 0.108
# Accuracy = 0.663 vs. 0.056
# Validation
# AUC = 0.406 vs. 0.072
# F1 = 0.469 vs. 0.107
# Accuracy = 0.619 vs. 0.056
# Minibatch Loss= 0.321683
# Train Batch Evaluation
# AUC = 0.600 vs. 0.077
# F1 = 0.623 vs. 0.109
# Accuracy = 0.670 vs. 0.056
# Validation
# AUC = 0.409 vs. 0.070
# F1 = 0.471 vs. 0.103
# Accuracy = 0.621 vs. 0.056
# Minibatch Loss= 0.318682
# Train Batch Evaluation
# AUC = 0.602 vs. 0.077
# F1 = 0.625 vs. 0.108
# Accuracy = 0.667 vs. 0.056
# Validation
# AUC = 0.409 vs. 0.068
# F1 = 0.473 vs. 0.095
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.316335
# Train Batch Evaluation
# AUC = 0.604 vs. 0.076
# F1 = 0.626 vs. 0.108
# Accuracy = 0.675 vs. 0.056
# Validation
# AUC = 0.410 vs. 0.068
# F1 = 0.471 vs. 0.100
# Accuracy = 0.629 vs. 0.056
# Minibatch Loss= 0.314079
# Train Batch Evaluation
# AUC = 0.606 vs. 0.077
# F1 = 0.628 vs. 0.108
# Accuracy = 0.680 vs. 0.056
# Validation
# AUC = 0.412 vs. 0.070
# F1 = 0.475 vs. 0.100
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.311447
# Train Batch Evaluation
# AUC = 0.609 vs. 0.077
# F1 = 0.630 vs. 0.108
# Accuracy = 0.673 vs. 0.056
# Validation
# AUC = 0.411 vs. 0.069
# F1 = 0.474 vs. 0.104
# Accuracy = 0.620 vs. 0.056
# Minibatch Loss= 0.309325
# Train Batch Evaluation
# AUC = 0.610 vs. 0.078
# F1 = 0.631 vs. 0.110
# Accuracy = 0.684 vs. 0.056
# Validation
# AUC = 0.414 vs. 0.070
# F1 = 0.475 vs. 0.107
# Accuracy = 0.634 vs. 0.056
# Minibatch Loss= 0.307026
# Train Batch Evaluation
# AUC = 0.613 vs. 0.076
# F1 = 0.633 vs. 0.108
# Accuracy = 0.682 vs. 0.056
# Validation
# AUC = 0.414 vs. 0.071
# F1 = 0.474 vs. 0.105
# Accuracy = 0.628 vs. 0.056
# Minibatch Loss= 0.304478
# Train Batch Evaluation
# AUC = 0.615 vs. 0.076
# F1 = 0.634 vs. 0.107
# Accuracy = 0.677 vs. 0.056
# Validation
# AUC = 0.415 vs. 0.069
# F1 = 0.475 vs. 0.105
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.302487
# Train Batch Evaluation
# AUC = 0.617 vs. 0.076
# F1 = 0.636 vs. 0.108
# Accuracy = 0.689 vs. 0.056
# Validation
# AUC = 0.418 vs. 0.073
# F1 = 0.478 vs. 0.106
# Accuracy = 0.639 vs. 0.056
# Minibatch Loss= 0.300397
# Train Batch Evaluation
# AUC = 0.619 vs. 0.077
# F1 = 0.637 vs. 0.107
# Accuracy = 0.683 vs. 0.056
# Validation
# AUC = 0.417 vs. 0.071
# F1 = 0.476 vs. 0.108
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.298032
# Train Batch Evaluation
# AUC = 0.622 vs. 0.077
# F1 = 0.639 vs. 0.109
# Accuracy = 0.687 vs. 0.056
# Validation
# AUC = 0.418 vs. 0.071
# F1 = 0.478 vs. 0.103
# Accuracy = 0.634 vs. 0.056
# Minibatch Loss= 0.296022
# Train Batch Evaluation
# AUC = 0.623 vs. 0.076
# F1 = 0.641 vs. 0.108
# Accuracy = 0.692 vs. 0.056
# Validation
# AUC = 0.419 vs. 0.070
# F1 = 0.477 vs. 0.100
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.293915
# Train Batch Evaluation
# AUC = 0.626 vs. 0.076
# F1 = 0.642 vs. 0.107
# Accuracy = 0.692 vs. 0.056
# Validation
# AUC = 0.422 vs. 0.067
# F1 = 0.481 vs. 0.092
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.291604
# Train Batch Evaluation
# AUC = 0.628 vs. 0.076
# F1 = 0.644 vs. 0.107
# Accuracy = 0.692 vs. 0.056
# Validation
# AUC = 0.422 vs. 0.073
# F1 = 0.480 vs. 0.103
# Accuracy = 0.641 vs. 0.056
# Minibatch Loss= 0.289621
# Train Batch Evaluation
# AUC = 0.630 vs. 0.077
# F1 = 0.645 vs. 0.108
# Accuracy = 0.695 vs. 0.056
# Validation
# AUC = 0.424 vs. 0.071
# F1 = 0.479 vs. 0.105
# Accuracy = 0.645 vs. 0.056
# Minibatch Loss= 0.287684
# Train Batch Evaluation
# AUC = 0.633 vs. 0.077
# F1 = 0.647 vs. 0.107
# Accuracy = 0.696 vs. 0.056
# Validation
# AUC = 0.424 vs. 0.072
# F1 = 0.479 vs. 0.107
# Accuracy = 0.645 vs. 0.056
# Minibatch Loss= 0.285545
# Train Batch Evaluation
# AUC = 0.635 vs. 0.076
# F1 = 0.649 vs. 0.108
# Accuracy = 0.691 vs. 0.056
# Validation
# AUC = 0.424 vs. 0.073
# F1 = 0.479 vs. 0.106
# Accuracy = 0.642 vs. 0.056
# Minibatch Loss= 0.283596
# Train Batch Evaluation
# AUC = 0.637 vs. 0.076
# F1 = 0.650 vs. 0.107
# Accuracy = 0.703 vs. 0.056
# Validation
# AUC = 0.426 vs. 0.072
# F1 = 0.482 vs. 0.108
# Accuracy = 0.653 vs. 0.056
# Minibatch Loss= 0.281828
# Train Batch Evaluation
# AUC = 0.639 vs. 0.076
# F1 = 0.652 vs. 0.107
# Accuracy = 0.690 vs. 0.056
# Validation
# AUC = 0.426 vs. 0.069
# F1 = 0.482 vs. 0.099
# Accuracy = 0.636 vs. 0.056
# Minibatch Loss= 0.279983
# Train Batch Evaluation
# AUC = 0.642 vs. 0.077
# F1 = 0.655 vs. 0.108
# Accuracy = 0.707 vs. 0.056
# Validation
# AUC = 0.428 vs. 0.070
# F1 = 0.485 vs. 0.105
# Accuracy = 0.663 vs. 0.056
# Minibatch Loss= 0.278457
# Train Batch Evaluation
# AUC = 0.642 vs. 0.076
# F1 = 0.656 vs. 0.107
# Accuracy = 0.691 vs. 0.056
# Validation
# AUC = 0.428 vs. 0.075
# F1 = 0.480 vs. 0.111
# Accuracy = 0.646 vs. 0.056
# Minibatch Loss= 0.277442
# Train Batch Evaluation
# AUC = 0.646 vs. 0.077
# F1 = 0.658 vs. 0.109
# Accuracy = 0.717 vs. 0.056
# Validation
# AUC = 0.431 vs. 0.070
# F1 = 0.487 vs. 0.104
# Accuracy = 0.679 vs. 0.056
# Minibatch Loss= 0.276797
# Train Batch Evaluation
# AUC = 0.646 vs. 0.077
# F1 = 0.660 vs. 0.110
# Accuracy = 0.692 vs. 0.056
# Validation
# AUC = 0.430 vs. 0.072
# F1 = 0.482 vs. 0.110
# Accuracy = 0.644 vs. 0.056
# Minibatch Loss= 0.274663
# Train Batch Evaluation
# AUC = 0.650 vs. 0.077
# F1 = 0.662 vs. 0.109
# Accuracy = 0.719 vs. 0.056
# Validation
# AUC = 0.434 vs. 0.068
# F1 = 0.487 vs. 0.097
# Accuracy = 0.682 vs. 0.056
# Minibatch Loss= 0.271815
# Train Batch Evaluation
# AUC = 0.651 vs. 0.077
# F1 = 0.663 vs. 0.108
# Accuracy = 0.708 vs. 0.056
# Validation
# AUC = 0.433 vs. 0.072
# F1 = 0.486 vs. 0.108
# Accuracy = 0.657 vs. 0.056
# Minibatch Loss= 0.269015
# Train Batch Evaluation
# AUC = 0.653 vs. 0.077
# F1 = 0.665 vs. 0.108
# Accuracy = 0.703 vs. 0.056
# Validation
# AUC = 0.434 vs. 0.071
# F1 = 0.486 vs. 0.098
# Accuracy = 0.657 vs. 0.056
# Minibatch Loss= 0.267983
# Train Batch Evaluation
# AUC = 0.655 vs. 0.076
# F1 = 0.667 vs. 0.107
# Accuracy = 0.721 vs. 0.056
# Validation
# AUC = 0.437 vs. 0.070
# F1 = 0.488 vs. 0.099
# Accuracy = 0.686 vs. 0.056
# Minibatch Loss= 0.267465
# Train Batch Evaluation
# AUC = 0.656 vs. 0.077
# F1 = 0.668 vs. 0.108
# Accuracy = 0.700 vs. 0.056
# Validation
# AUC = 0.435 vs. 0.071
# F1 = 0.488 vs. 0.106
# Accuracy = 0.653 vs. 0.056
# Minibatch Loss= 0.264886
# Train Batch Evaluation
# AUC = 0.659 vs. 0.076
# F1 = 0.669 vs. 0.108
# Accuracy = 0.715 vs. 0.056
# Validation
# AUC = 0.438 vs. 0.070
# F1 = 0.490 vs. 0.096
# Accuracy = 0.671 vs. 0.056
# Minibatch Loss= 0.262373
# Train Batch Evaluation
# AUC = 0.661 vs. 0.077
# F1 = 0.671 vs. 0.110
# Accuracy = 0.724 vs. 0.056
# Validation
# AUC = 0.440 vs. 0.070
# F1 = 0.490 vs. 0.103
# Accuracy = 0.690 vs. 0.056
# Minibatch Loss= 0.261429
# Train Batch Evaluation
# AUC = 0.662 vs. 0.077
# F1 = 0.672 vs. 0.108
# Accuracy = 0.711 vs. 0.056
# Validation
# AUC = 0.438 vs. 0.069
# F1 = 0.491 vs. 0.100
# Accuracy = 0.661 vs. 0.056
# Minibatch Loss= 0.260325
# Train Batch Evaluation
# AUC = 0.664 vs. 0.077
# F1 = 0.674 vs. 0.108
# Accuracy = 0.728 vs. 0.056
# Validation
# AUC = 0.441 vs. 0.071
# F1 = 0.492 vs. 0.105
# Accuracy = 0.691 vs. 0.056
# Minibatch Loss= 0.258235
# Train Batch Evaluation
# AUC = 0.666 vs. 0.076
# F1 = 0.674 vs. 0.108
# Accuracy = 0.724 vs. 0.056
# Validation
# AUC = 0.442 vs. 0.071
# F1 = 0.492 vs. 0.104
# Accuracy = 0.684 vs. 0.056
# Minibatch Loss= 0.256243
# Train Batch Evaluation
# AUC = 0.667 vs. 0.076
# F1 = 0.675 vs. 0.108
# Accuracy = 0.713 vs. 0.056
# Validation
# AUC = 0.442 vs. 0.069
# F1 = 0.493 vs. 0.099
# Accuracy = 0.663 vs. 0.056
# Minibatch Loss= 0.255211
# Train Batch Evaluation
# AUC = 0.670 vs. 0.076
# F1 = 0.677 vs. 0.108
# Accuracy = 0.729 vs. 0.056
# Validation
# AUC = 0.444 vs. 0.068
# F1 = 0.494 vs. 0.098
# Accuracy = 0.689 vs. 0.056
# Minibatch Loss= 0.254077
# Train Batch Evaluation
# AUC = 0.670 vs. 0.077
# F1 = 0.678 vs. 0.109
# Accuracy = 0.717 vs. 0.056
# Validation
# AUC = 0.444 vs. 0.072
# F1 = 0.494 vs. 0.106
# Accuracy = 0.671 vs. 0.056
# Minibatch Loss= 0.252149
# Train Batch Evaluation
# AUC = 0.673 vs. 0.077
# F1 = 0.679 vs. 0.110
# Accuracy = 0.722 vs. 0.056
# Validation
# AUC = 0.444 vs. 0.070
# F1 = 0.495 vs. 0.098
# Accuracy = 0.681 vs. 0.056
# Minibatch Loss= 0.250423
# Train Batch Evaluation
# AUC = 0.674 vs. 0.077
# F1 = 0.680 vs. 0.108
# Accuracy = 0.733 vs. 0.056
# Validation
# AUC = 0.446 vs. 0.070
# F1 = 0.495 vs. 0.102
# Accuracy = 0.692 vs. 0.056
# Minibatch Loss= 0.249155
# Train Batch Evaluation
# AUC = 0.675 vs. 0.077
# F1 = 0.681 vs. 0.108
# Accuracy = 0.724 vs. 0.056
# Validation
# AUC = 0.446 vs. 0.070
# F1 = 0.495 vs. 0.100
# Accuracy = 0.678 vs. 0.056
# Minibatch Loss= 0.247926
# Train Batch Evaluation
# AUC = 0.678 vs. 0.076
# F1 = 0.683 vs. 0.108
# Accuracy = 0.733 vs. 0.056
# Validation
# AUC = 0.446 vs. 0.071
# F1 = 0.497 vs. 0.103
# Accuracy = 0.696 vs. 0.056
# Minibatch Loss= 0.246467
# Train Batch Evaluation
# AUC = 0.678 vs. 0.077
# F1 = 0.684 vs. 0.108
# Accuracy = 0.731 vs. 0.056
# Validation
# AUC = 0.449 vs. 0.072
# F1 = 0.497 vs. 0.104
# Accuracy = 0.690 vs. 0.056
# Minibatch Loss= 0.244771
# Train Batch Evaluation
# AUC = 0.680 vs. 0.078
# F1 = 0.685 vs. 0.109
# Accuracy = 0.731 vs. 0.056
# Validation
# AUC = 0.449 vs. 0.070
# F1 = 0.497 vs. 0.106
# Accuracy = 0.686 vs. 0.056
# Minibatch Loss= 0.243271
# Train Batch Evaluation
# AUC = 0.682 vs. 0.078
# F1 = 0.687 vs. 0.109
# Accuracy = 0.736 vs. 0.056
# Validation
# AUC = 0.450 vs. 0.070
# F1 = 0.499 vs. 0.099
# Accuracy = 0.695 vs. 0.056
# Minibatch Loss= 0.242147
# Train Batch Evaluation
# AUC = 0.683 vs. 0.076
# F1 = 0.688 vs. 0.108
# Accuracy = 0.731 vs. 0.056
# Validation
# AUC = 0.451 vs. 0.069
# F1 = 0.499 vs. 0.099
# Accuracy = 0.690 vs. 0.056
# Minibatch Loss= 0.240936
# Train Batch Evaluation
# AUC = 0.685 vs. 0.076
# F1 = 0.689 vs. 0.107
# Accuracy = 0.737 vs. 0.056
# Validation
# AUC = 0.449 vs. 0.070
# F1 = 0.499 vs. 0.099
# Accuracy = 0.697 vs. 0.056
# Minibatch Loss= 0.239364
# Train Batch Evaluation
# AUC = 0.686 vs. 0.077
# F1 = 0.690 vs. 0.108
# Accuracy = 0.737 vs. 0.056
# Validation
# AUC = 0.449 vs. 0.071
# F1 = 0.503 vs. 0.109
# Accuracy = 0.696 vs. 0.056
# Minibatch Loss= 0.237788
# Train Batch Evaluation
# AUC = 0.687 vs. 0.077
# F1 = 0.691 vs. 0.109
# Accuracy = 0.741 vs. 0.056
# Validation
# AUC = 0.451 vs. 0.073
# F1 = 0.503 vs. 0.109
# Accuracy = 0.702 vs. 0.056
# Minibatch Loss= 0.236483
# Train Batch Evaluation
# AUC = 0.689 vs. 0.077
# F1 = 0.692 vs. 0.108
# Accuracy = 0.744 vs. 0.056
# Validation
# AUC = 0.451 vs. 0.072
# F1 = 0.502 vs. 0.100
# Accuracy = 0.703 vs. 0.056
# Minibatch Loss= 0.235271
# Train Batch Evaluation
# AUC = 0.690 vs. 0.077
# F1 = 0.694 vs. 0.108
# Accuracy = 0.738 vs. 0.056
# Validation
# AUC = 0.453 vs. 0.071
# F1 = 0.504 vs. 0.104
# Accuracy = 0.699 vs. 0.056
# Minibatch Loss= 0.233989
# Train Batch Evaluation
# AUC = 0.692 vs. 0.077
# F1 = 0.695 vs. 0.108
# Accuracy = 0.747 vs. 0.056
# Validation
# AUC = 0.453 vs. 0.071
# F1 = 0.505 vs. 0.104
# Accuracy = 0.713 vs. 0.056
# Minibatch Loss= 0.232667
# Train Batch Evaluation
# AUC = 0.693 vs. 0.076
# F1 = 0.695 vs. 0.107
# Accuracy = 0.741 vs. 0.056
# Validation
# AUC = 0.454 vs. 0.068
# F1 = 0.503 vs. 0.100
# Accuracy = 0.701 vs. 0.056
# Minibatch Loss= 0.231327
# Train Batch Evaluation
# AUC = 0.695 vs. 0.077
# F1 = 0.696 vs. 0.109
# Accuracy = 0.750 vs. 0.056
# Validation
# AUC = 0.454 vs. 0.071
# F1 = 0.503 vs. 0.102
# Accuracy = 0.713 vs. 0.056
# Minibatch Loss= 0.229967
# Train Batch Evaluation
# AUC = 0.696 vs. 0.077
# F1 = 0.697 vs. 0.108
# Accuracy = 0.747 vs. 0.056
# Validation
# AUC = 0.454 vs. 0.068
# F1 = 0.503 vs. 0.096
# Accuracy = 0.709 vs. 0.056
# Minibatch Loss= 0.228562
# Train Batch Evaluation
# AUC = 0.697 vs. 0.077
# F1 = 0.698 vs. 0.109
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.455 vs. 0.070
# F1 = 0.504 vs. 0.104
# Accuracy = 0.715 vs. 0.056
# Minibatch Loss= 0.227237
# Train Batch Evaluation
# AUC = 0.699 vs. 0.077
# F1 = 0.699 vs. 0.109
# Accuracy = 0.754 vs. 0.056
# Validation
# AUC = 0.456 vs. 0.074
# F1 = 0.503 vs. 0.110
# Accuracy = 0.717 vs. 0.056
# Minibatch Loss= 0.226015
# Train Batch Evaluation
# AUC = 0.700 vs. 0.076
# F1 = 0.700 vs. 0.107
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.456 vs. 0.069
# F1 = 0.505 vs. 0.102
# Accuracy = 0.717 vs. 0.056
# Minibatch Loss= 0.224831
# Train Batch Evaluation
# AUC = 0.701 vs. 0.076
# F1 = 0.701 vs. 0.109
# Accuracy = 0.757 vs. 0.056
# Validation
# AUC = 0.458 vs. 0.072
# F1 = 0.507 vs. 0.102
# Accuracy = 0.727 vs. 0.056
# Minibatch Loss= 0.223655
# Train Batch Evaluation
# AUC = 0.702 vs. 0.077
# F1 = 0.702 vs. 0.108
# Accuracy = 0.750 vs. 0.056
# Validation
# AUC = 0.458 vs. 0.071
# F1 = 0.507 vs. 0.102
# Accuracy = 0.715 vs. 0.056
# Minibatch Loss= 0.222498
# Train Batch Evaluation
# AUC = 0.704 vs. 0.077
# F1 = 0.703 vs. 0.108
# Accuracy = 0.759 vs. 0.056
# Validation
# AUC = 0.459 vs. 0.071
# F1 = 0.510 vs. 0.104
# Accuracy = 0.735 vs. 0.056
# Minibatch Loss= 0.221478
# Train Batch Evaluation
# AUC = 0.705 vs. 0.076
# F1 = 0.704 vs. 0.108
# Accuracy = 0.752 vs. 0.056
# Validation
# AUC = 0.458 vs. 0.072
# F1 = 0.508 vs. 0.103
# Accuracy = 0.716 vs. 0.056
# Minibatch Loss= 0.220571
# Train Batch Evaluation
# AUC = 0.707 vs. 0.077
# F1 = 0.706 vs. 0.109
# Accuracy = 0.763 vs. 0.056
# Validation
# AUC = 0.461 vs. 0.070
# F1 = 0.511 vs. 0.105
# Accuracy = 0.745 vs. 0.056
# Minibatch Loss= 0.219974
# Train Batch Evaluation
# AUC = 0.707 vs. 0.077
# F1 = 0.705 vs. 0.108
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.458 vs. 0.070
# F1 = 0.509 vs. 0.098
# Accuracy = 0.715 vs. 0.056
# Minibatch Loss= 0.219261
# Train Batch Evaluation
# AUC = 0.710 vs. 0.077
# F1 = 0.706 vs. 0.108
# Accuracy = 0.768 vs. 0.056
# Validation
# AUC = 0.462 vs. 0.070
# F1 = 0.513 vs. 0.105
# Accuracy = 0.750 vs. 0.056
# Minibatch Loss= 0.218845
# Train Batch Evaluation
# AUC = 0.710 vs. 0.077
# F1 = 0.708 vs. 0.108
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.459 vs. 0.070
# F1 = 0.512 vs. 0.100
# Accuracy = 0.716 vs. 0.056
# Minibatch Loss= 0.217181
# Train Batch Evaluation
# AUC = 0.712 vs. 0.077
# F1 = 0.709 vs. 0.108
# Accuracy = 0.767 vs. 0.056
# Validation
# AUC = 0.463 vs. 0.072
# F1 = 0.513 vs. 0.111
# Accuracy = 0.750 vs. 0.056
# Minibatch Loss= 0.215402
# Train Batch Evaluation
# AUC = 0.713 vs. 0.077
# F1 = 0.709 vs. 0.108
# Accuracy = 0.758 vs. 0.056
# Validation
# AUC = 0.462 vs. 0.070
# F1 = 0.512 vs. 0.099
# Accuracy = 0.731 vs. 0.056
# Minibatch Loss= 0.213227
# Train Batch Evaluation
# AUC = 0.714 vs. 0.077
# F1 = 0.710 vs. 0.109
# Accuracy = 0.761 vs. 0.056
# Validation
# AUC = 0.462 vs. 0.070
# F1 = 0.514 vs. 0.098
# Accuracy = 0.736 vs. 0.056
# Minibatch Loss= 0.211964
# Train Batch Evaluation
# AUC = 0.715 vs. 0.077
# F1 = 0.711 vs. 0.109
# Accuracy = 0.767 vs. 0.056
# Validation
# AUC = 0.463 vs. 0.069
# F1 = 0.514 vs. 0.095
# Accuracy = 0.749 vs. 0.056
# Minibatch Loss= 0.211562
# Train Batch Evaluation
# AUC = 0.715 vs. 0.077
# F1 = 0.712 vs. 0.108
# Accuracy = 0.757 vs. 0.056
# Validation
# AUC = 0.461 vs. 0.071
# F1 = 0.515 vs. 0.106
# Accuracy = 0.727 vs. 0.056
# Minibatch Loss= 0.211051
# Train Batch Evaluation
# AUC = 0.718 vs. 0.077
# F1 = 0.712 vs. 0.108
# Accuracy = 0.773 vs. 0.056
# Validation
# AUC = 0.463 vs. 0.072
# F1 = 0.516 vs. 0.105
# Accuracy = 0.757 vs. 0.056
# Minibatch Loss= 0.210193
# Train Batch Evaluation
# AUC = 0.718 vs. 0.077
# F1 = 0.713 vs. 0.109
# Accuracy = 0.760 vs. 0.056
# Validation
# AUC = 0.462 vs. 0.072
# F1 = 0.516 vs. 0.110
# Accuracy = 0.735 vs. 0.056
# Minibatch Loss= 0.208316
# Train Batch Evaluation
# AUC = 0.720 vs. 0.077
# F1 = 0.714 vs. 0.109
# Accuracy = 0.767 vs. 0.056
# Validation
# AUC = 0.463 vs. 0.070
# F1 = 0.518 vs. 0.103
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.206719
# Train Batch Evaluation
# AUC = 0.720 vs. 0.076
# F1 = 0.715 vs. 0.107
# Accuracy = 0.769 vs. 0.056
# Validation
# AUC = 0.463 vs. 0.070
# F1 = 0.519 vs. 0.097
# Accuracy = 0.749 vs. 0.056
# Minibatch Loss= 0.205771
# Train Batch Evaluation
# AUC = 0.721 vs. 0.077
# F1 = 0.716 vs. 0.108
# Accuracy = 0.761 vs. 0.056
# Validation
# AUC = 0.464 vs. 0.072
# F1 = 0.519 vs. 0.106
# Accuracy = 0.737 vs. 0.056
# Minibatch Loss= 0.205235
# Train Batch Evaluation
# AUC = 0.723 vs. 0.077
# F1 = 0.717 vs. 0.108
# Accuracy = 0.774 vs. 0.056
# Validation
# AUC = 0.465 vs. 0.071
# F1 = 0.522 vs. 0.108
# Accuracy = 0.754 vs. 0.056
# Minibatch Loss= 0.204684
# Train Batch Evaluation
# AUC = 0.723 vs. 0.078
# F1 = 0.718 vs. 0.109
# Accuracy = 0.764 vs. 0.056
# Validation
# AUC = 0.464 vs. 0.070
# F1 = 0.522 vs. 0.101
# Accuracy = 0.740 vs. 0.056
# Minibatch Loss= 0.203475
# Train Batch Evaluation
# AUC = 0.725 vs. 0.077
# F1 = 0.719 vs. 0.110
# Accuracy = 0.773 vs. 0.056
# Validation
# AUC = 0.465 vs. 0.069
# F1 = 0.521 vs. 0.098
# Accuracy = 0.754 vs. 0.056
# Minibatch Loss= 0.202157
# Train Batch Evaluation
# AUC = 0.726 vs. 0.076
# F1 = 0.719 vs. 0.108
# Accuracy = 0.772 vs. 0.056
# Validation
# AUC = 0.465 vs. 0.070
# F1 = 0.522 vs. 0.102
# Accuracy = 0.750 vs. 0.056
# Minibatch Loss= 0.200890
# Train Batch Evaluation
# AUC = 0.727 vs. 0.077
# F1 = 0.720 vs. 0.108
# Accuracy = 0.769 vs. 0.056
# Validation
# AUC = 0.465 vs. 0.075
# F1 = 0.522 vs. 0.107
# Accuracy = 0.751 vs. 0.056
# Minibatch Loss= 0.199909
# Train Batch Evaluation
# AUC = 0.728 vs. 0.076
# F1 = 0.720 vs. 0.108
# Accuracy = 0.777 vs. 0.056
# Validation
# AUC = 0.467 vs. 0.072
# F1 = 0.522 vs. 0.105
# Accuracy = 0.760 vs. 0.056
# Minibatch Loss= 0.199141
# Train Batch Evaluation
# AUC = 0.728 vs. 0.077
# F1 = 0.721 vs. 0.108
# Accuracy = 0.768 vs. 0.056
# Validation
# AUC = 0.467 vs. 0.072
# F1 = 0.521 vs. 0.102
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.198387
# Train Batch Evaluation
# AUC = 0.730 vs. 0.077
# F1 = 0.722 vs. 0.108
# Accuracy = 0.777 vs. 0.056
# Validation
# AUC = 0.467 vs. 0.071
# F1 = 0.522 vs. 0.105
# Accuracy = 0.760 vs. 0.056
# Minibatch Loss= 0.197657
# Train Batch Evaluation
# AUC = 0.730 vs. 0.077
# F1 = 0.723 vs. 0.108
# Accuracy = 0.770 vs. 0.056
# Validation
# AUC = 0.466 vs. 0.071
# F1 = 0.523 vs. 0.105
# Accuracy = 0.750 vs. 0.056
# Minibatch Loss= 0.196748
# Train Batch Evaluation
# AUC = 0.732 vs. 0.077
# F1 = 0.723 vs. 0.108
# Accuracy = 0.778 vs. 0.056
# Validation
# AUC = 0.467 vs. 0.071
# F1 = 0.521 vs. 0.105
# Accuracy = 0.758 vs. 0.056
# Minibatch Loss= 0.195828
# Train Batch Evaluation
# AUC = 0.732 vs. 0.077
# F1 = 0.724 vs. 0.109
# Accuracy = 0.775 vs. 0.056
# Validation
# AUC = 0.467 vs. 0.073
# F1 = 0.522 vs. 0.108
# Accuracy = 0.756 vs. 0.056
# Minibatch Loss= 0.194740
# Train Batch Evaluation
# AUC = 0.733 vs. 0.077
# F1 = 0.725 vs. 0.110
# Accuracy = 0.778 vs. 0.056
# Validation
# AUC = 0.468 vs. 0.071
# F1 = 0.522 vs. 0.109
# Accuracy = 0.760 vs. 0.056
# Minibatch Loss= 0.193639
# Train Batch Evaluation
# AUC = 0.734 vs. 0.078
# F1 = 0.726 vs. 0.109
# Accuracy = 0.780 vs. 0.056
# Validation
# AUC = 0.468 vs. 0.068
# F1 = 0.522 vs. 0.098
# Accuracy = 0.759 vs. 0.056
# Minibatch Loss= 0.192574
# Train Batch Evaluation
# AUC = 0.735 vs. 0.078
# F1 = 0.726 vs. 0.110
# Accuracy = 0.778 vs. 0.056
# Validation
# AUC = 0.469 vs. 0.069
# F1 = 0.523 vs. 0.095
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.191618
# Train Batch Evaluation
# AUC = 0.736 vs. 0.077
# F1 = 0.727 vs. 0.109
# Accuracy = 0.782 vs. 0.056
# Validation
# AUC = 0.469 vs. 0.069
# F1 = 0.524 vs. 0.096
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.190808
# Train Batch Evaluation
# AUC = 0.736 vs. 0.076
# F1 = 0.728 vs. 0.108
# Accuracy = 0.780 vs. 0.056
# Validation
# AUC = 0.469 vs. 0.069
# F1 = 0.524 vs. 0.099
# Accuracy = 0.760 vs. 0.056
# Minibatch Loss= 0.190093
# Train Batch Evaluation
# AUC = 0.738 vs. 0.077
# F1 = 0.728 vs. 0.109
# Accuracy = 0.785 vs. 0.056
# Validation
# AUC = 0.470 vs. 0.072
# F1 = 0.527 vs. 0.106
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.189457
# Train Batch Evaluation
# AUC = 0.738 vs. 0.077
# F1 = 0.730 vs. 0.108
# Accuracy = 0.782 vs. 0.056
# Validation
# AUC = 0.470 vs. 0.071
# F1 = 0.523 vs. 0.110
# Accuracy = 0.760 vs. 0.056
# Minibatch Loss= 0.188824
# Train Batch Evaluation
# AUC = 0.739 vs. 0.077
# F1 = 0.729 vs. 0.108
# Accuracy = 0.789 vs. 0.056
# Validation
# AUC = 0.471 vs. 0.070
# F1 = 0.528 vs. 0.098
# Accuracy = 0.767 vs. 0.056
# Minibatch Loss= 0.188343
# Train Batch Evaluation
# AUC = 0.739 vs. 0.077
# F1 = 0.731 vs. 0.108
# Accuracy = 0.779 vs. 0.056
# Validation
# AUC = 0.471 vs. 0.070
# F1 = 0.523 vs. 0.104
# Accuracy = 0.756 vs. 0.056
# Minibatch Loss= 0.187710
# Train Batch Evaluation
# AUC = 0.741 vs. 0.077
# F1 = 0.731 vs. 0.108
# Accuracy = 0.795 vs. 0.056
# Validation
# AUC = 0.473 vs. 0.070
# F1 = 0.528 vs. 0.101
# Accuracy = 0.775 vs. 0.056
# Minibatch Loss= 0.187465
# Train Batch Evaluation
# AUC = 0.740 vs. 0.076
# F1 = 0.733 vs. 0.109
# Accuracy = 0.775 vs. 0.056
# Validation
# AUC = 0.471 vs. 0.070
# F1 = 0.525 vs. 0.104
# Accuracy = 0.750 vs. 0.056
# Minibatch Loss= 0.186689
# Train Batch Evaluation
# AUC = 0.742 vs. 0.076
# F1 = 0.732 vs. 0.109
# Accuracy = 0.797 vs. 0.056
# Validation
# AUC = 0.474 vs. 0.072
# F1 = 0.530 vs. 0.105
# Accuracy = 0.780 vs. 0.056
# Minibatch Loss= 0.186442
# Train Batch Evaluation
# AUC = 0.742 vs. 0.077
# F1 = 0.734 vs. 0.108
# Accuracy = 0.775 vs. 0.056
# Validation
# AUC = 0.471 vs. 0.074
# F1 = 0.525 vs. 0.106
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.184884
# Train Batch Evaluation
# AUC = 0.743 vs. 0.076
# F1 = 0.734 vs. 0.108
# Accuracy = 0.797 vs. 0.056
# Validation
# AUC = 0.475 vs. 0.069
# F1 = 0.530 vs. 0.097
# Accuracy = 0.777 vs. 0.056
# Minibatch Loss= 0.183525
# Train Batch Evaluation
# AUC = 0.744 vs. 0.077
# F1 = 0.735 vs. 0.109
# Accuracy = 0.784 vs. 0.056
# Validation
# AUC = 0.473 vs. 0.070
# F1 = 0.529 vs. 0.101
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.181920
# Train Batch Evaluation
# AUC = 0.745 vs. 0.076
# F1 = 0.735 vs. 0.108
# Accuracy = 0.789 vs. 0.056
# Validation
# AUC = 0.474 vs. 0.073
# F1 = 0.528 vs. 0.108
# Accuracy = 0.768 vs. 0.056
# Minibatch Loss= 0.181062
# Train Batch Evaluation
# AUC = 0.746 vs. 0.077
# F1 = 0.735 vs. 0.107
# Accuracy = 0.800 vs. 0.056
# Validation
# AUC = 0.475 vs. 0.070
# F1 = 0.532 vs. 0.105
# Accuracy = 0.779 vs. 0.056
# Minibatch Loss= 0.180874
# Train Batch Evaluation
# AUC = 0.746 vs. 0.077
# F1 = 0.737 vs. 0.109
# Accuracy = 0.785 vs. 0.056
# Validation
# AUC = 0.473 vs. 0.070
# F1 = 0.529 vs. 0.107
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.180608
# Train Batch Evaluation
# AUC = 0.747 vs. 0.077
# F1 = 0.737 vs. 0.108
# Accuracy = 0.804 vs. 0.056
# Validation
# AUC = 0.476 vs. 0.069
# F1 = 0.534 vs. 0.104
# Accuracy = 0.785 vs. 0.056
# Minibatch Loss= 0.180302
# Train Batch Evaluation
# AUC = 0.747 vs. 0.077
# F1 = 0.738 vs. 0.107
# Accuracy = 0.786 vs. 0.056
# Validation
# AUC = 0.474 vs. 0.071
# F1 = 0.532 vs. 0.109
# Accuracy = 0.762 vs. 0.056
# Minibatch Loss= 0.178897
# Train Batch Evaluation
# AUC = 0.749 vs. 0.077
# F1 = 0.738 vs. 0.108
# Accuracy = 0.797 vs. 0.056
# Validation
# AUC = 0.475 vs. 0.072
# F1 = 0.534 vs. 0.107
# Accuracy = 0.777 vs. 0.056
# Minibatch Loss= 0.177631
# Train Batch Evaluation
# AUC = 0.749 vs. 0.076
# F1 = 0.739 vs. 0.109
# Accuracy = 0.796 vs. 0.056
# Validation
# AUC = 0.475 vs. 0.068
# F1 = 0.535 vs. 0.099
# Accuracy = 0.775 vs. 0.056
# Minibatch Loss= 0.176644
# Train Batch Evaluation
# AUC = 0.750 vs. 0.077
# F1 = 0.739 vs. 0.108
# Accuracy = 0.792 vs. 0.056
# Validation
# AUC = 0.476 vs. 0.070
# F1 = 0.537 vs. 0.107
# Accuracy = 0.771 vs. 0.056
# Minibatch Loss= 0.176076
# Train Batch Evaluation
# AUC = 0.751 vs. 0.077
# F1 = 0.740 vs. 0.108
# Accuracy = 0.805 vs. 0.056
# Validation
# AUC = 0.477 vs. 0.069
# F1 = 0.539 vs. 0.100
# Accuracy = 0.783 vs. 0.056
# Minibatch Loss= 0.175645
# Train Batch Evaluation
# AUC = 0.751 vs. 0.077
# F1 = 0.741 vs. 0.108
# Accuracy = 0.793 vs. 0.056
# Validation
# AUC = 0.477 vs. 0.071
# F1 = 0.538 vs. 0.106
# Accuracy = 0.772 vs. 0.056
# Minibatch Loss= 0.174912
# Train Batch Evaluation
# AUC = 0.752 vs. 0.077
# F1 = 0.741 vs. 0.109
# Accuracy = 0.804 vs. 0.056
# Validation
# AUC = 0.477 vs. 0.076
# F1 = 0.539 vs. 0.111
# Accuracy = 0.784 vs. 0.056
# Minibatch Loss= 0.174196
# Train Batch Evaluation
# AUC = 0.752 vs. 0.077
# F1 = 0.742 vs. 0.108
# Accuracy = 0.799 vs. 0.056
# Validation
# AUC = 0.480 vs. 0.068
# F1 = 0.538 vs. 0.099
# Accuracy = 0.779 vs. 0.056
# Minibatch Loss= 0.173438
# Train Batch Evaluation
# AUC = 0.754 vs. 0.077
# F1 = 0.742 vs. 0.109
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.479 vs. 0.072
# F1 = 0.540 vs. 0.101
# Accuracy = 0.783 vs. 0.056
# Minibatch Loss= 0.172960
# Train Batch Evaluation
# AUC = 0.754 vs. 0.077
# F1 = 0.742 vs. 0.108
# Accuracy = 0.804 vs. 0.056
# Validation
# AUC = 0.481 vs. 0.069
# F1 = 0.540 vs. 0.096
# Accuracy = 0.781 vs. 0.056
# Minibatch Loss= 0.172671
# Train Batch Evaluation
# AUC = 0.755 vs. 0.077
# F1 = 0.743 vs. 0.108
# Accuracy = 0.799 vs. 0.056
# Validation
# AUC = 0.479 vs. 0.069
# F1 = 0.539 vs. 0.099
# Accuracy = 0.778 vs. 0.056
# Minibatch Loss= 0.171855
# Train Batch Evaluation
# AUC = 0.755 vs. 0.076
# F1 = 0.744 vs. 0.108
# Accuracy = 0.806 vs. 0.056
# Validation
# AUC = 0.481 vs. 0.070
# F1 = 0.540 vs. 0.103
# Accuracy = 0.784 vs. 0.056
# Minibatch Loss= 0.170769
# Train Batch Evaluation
# AUC = 0.756 vs. 0.077
# F1 = 0.744 vs. 0.108
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.480 vs. 0.069
# F1 = 0.538 vs. 0.097
# Accuracy = 0.781 vs. 0.056
# Minibatch Loss= 0.169619
# Train Batch Evaluation
# ...
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.080765
# Train Batch Evaluation
# AUC = 0.879 vs. 0.078
# F1 = 0.861 vs. 0.109
# Accuracy = 0.891 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.072
# F1 = 0.553 vs. 0.105
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.080595
# Train Batch Evaluation
# AUC = 0.879 vs. 0.077
# F1 = 0.860 vs. 0.108
# Accuracy = 0.902 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.074
# F1 = 0.553 vs. 0.111
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.080820
# Train Batch Evaluation
# AUC = 0.879 vs. 0.077
# F1 = 0.861 vs. 0.108
# Accuracy = 0.891 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.075
# F1 = 0.553 vs. 0.111
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.080624
# Train Batch Evaluation
# AUC = 0.880 vs. 0.077
# F1 = 0.861 vs. 0.110
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.072
# F1 = 0.553 vs. 0.101
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.081295
# Train Batch Evaluation
# AUC = 0.880 vs. 0.077
# F1 = 0.861 vs. 0.108
# Accuracy = 0.891 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.068
# F1 = 0.553 vs. 0.098
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.080665
# Train Batch Evaluation
# AUC = 0.881 vs. 0.076
# F1 = 0.862 vs. 0.108
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.070
# F1 = 0.552 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.080860
# Train Batch Evaluation
# AUC = 0.880 vs. 0.077
# F1 = 0.862 vs. 0.108
# Accuracy = 0.893 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.073
# F1 = 0.552 vs. 0.101
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.080052
# Train Batch Evaluation
# AUC = 0.881 vs. 0.077
# F1 = 0.862 vs. 0.108
# Accuracy = 0.900 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.069
# F1 = 0.552 vs. 0.096
# Accuracy = 0.859 vs. 0.056
# Minibatch Loss= 0.080096
# Train Batch Evaluation
# AUC = 0.881 vs. 0.077
# F1 = 0.863 vs. 0.109
# Accuracy = 0.900 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.071
# F1 = 0.553 vs. 0.104
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.079452
# Train Batch Evaluation
# AUC = 0.881 vs. 0.076
# F1 = 0.862 vs. 0.107
# Accuracy = 0.897 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.071
# F1 = 0.553 vs. 0.100
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.079236
# Train Batch Evaluation
# AUC = 0.881 vs. 0.077
# F1 = 0.863 vs. 0.110
# Accuracy = 0.896 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.069
# F1 = 0.553 vs. 0.098
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.078605
# Train Batch Evaluation
# AUC = 0.882 vs. 0.077
# F1 = 0.863 vs. 0.108
# Accuracy = 0.902 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.069
# F1 = 0.554 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.078331
# Train Batch Evaluation
# AUC = 0.882 vs. 0.077
# F1 = 0.863 vs. 0.108
# Accuracy = 0.895 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.069
# F1 = 0.554 vs. 0.097
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.078313
# Train Batch Evaluation
# AUC = 0.882 vs. 0.077
# F1 = 0.863 vs. 0.108
# Accuracy = 0.903 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.070
# F1 = 0.552 vs. 0.102
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.078414
# Train Batch Evaluation
# AUC = 0.883 vs. 0.076
# F1 = 0.863 vs. 0.107
# Accuracy = 0.902 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.071
# F1 = 0.552 vs. 0.102
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.078543
# Train Batch Evaluation
# AUC = 0.883 vs. 0.077
# F1 = 0.864 vs. 0.108
# Accuracy = 0.894 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.070
# F1 = 0.552 vs. 0.098
# Accuracy = 0.856 vs. 0.056
# Minibatch Loss= 0.078488
# Train Batch Evaluation
# AUC = 0.883 vs. 0.078
# F1 = 0.864 vs. 0.109
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.071
# F1 = 0.554 vs. 0.102
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.078935
# Train Batch Evaluation
# AUC = 0.883 vs. 0.077
# F1 = 0.865 vs. 0.108
# Accuracy = 0.890 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.072
# F1 = 0.552 vs. 0.111
# Accuracy = 0.857 vs. 0.056
# Minibatch Loss= 0.078559
# Train Batch Evaluation
# AUC = 0.884 vs. 0.077
# F1 = 0.864 vs. 0.109
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.077
# F1 = 0.555 vs. 0.113
# Accuracy = 0.865 vs. 0.056
# Minibatch Loss= 0.079109
# Train Batch Evaluation
# AUC = 0.883 vs. 0.077
# F1 = 0.865 vs. 0.108
# Accuracy = 0.894 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.071
# F1 = 0.552 vs. 0.111
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.078283
# Train Batch Evaluation
# AUC = 0.884 vs. 0.076
# F1 = 0.865 vs. 0.107
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.072
# F1 = 0.555 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.078216
# Train Batch Evaluation
# AUC = 0.884 vs. 0.076
# F1 = 0.865 vs. 0.107
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.070
# F1 = 0.552 vs. 0.100
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.077503
# Train Batch Evaluation
# AUC = 0.885 vs. 0.076
# F1 = 0.866 vs. 0.108
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.069
# F1 = 0.552 vs. 0.095
# Accuracy = 0.859 vs. 0.056
# Minibatch Loss= 0.077299
# Train Batch Evaluation
# AUC = 0.884 vs. 0.077
# F1 = 0.866 vs. 0.109
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.070
# F1 = 0.554 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.076863
# Train Batch Evaluation
# AUC = 0.885 vs. 0.076
# F1 = 0.866 vs. 0.107
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.069
# F1 = 0.553 vs. 0.094
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.076741
# Train Batch Evaluation
# AUC = 0.885 vs. 0.076
# F1 = 0.867 vs. 0.109
# Accuracy = 0.902 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.069
# F1 = 0.554 vs. 0.097
# Accuracy = 0.859 vs. 0.056
# Minibatch Loss= 0.076573
# Train Batch Evaluation
# AUC = 0.885 vs. 0.077
# F1 = 0.866 vs. 0.108
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.070
# F1 = 0.554 vs. 0.102
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.076444
# Train Batch Evaluation
# AUC = 0.886 vs. 0.077
# F1 = 0.867 vs. 0.108
# Accuracy = 0.897 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.071
# F1 = 0.554 vs. 0.102
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.076342
# Train Batch Evaluation
# AUC = 0.886 vs. 0.076
# F1 = 0.867 vs. 0.108
# Accuracy = 0.905 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.071
# F1 = 0.553 vs. 0.104
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.076224
# Train Batch Evaluation
# AUC = 0.886 vs. 0.076
# F1 = 0.867 vs. 0.107
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.070
# F1 = 0.554 vs. 0.106
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.076334
# Train Batch Evaluation
# AUC = 0.886 vs. 0.076
# F1 = 0.869 vs. 0.108
# Accuracy = 0.897 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.073
# F1 = 0.553 vs. 0.110
# Accuracy = 0.856 vs. 0.056
# Minibatch Loss= 0.076375
# Train Batch Evaluation
# AUC = 0.887 vs. 0.078
# F1 = 0.868 vs. 0.110
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.071
# F1 = 0.555 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.076895
# Train Batch Evaluation
# AUC = 0.886 vs. 0.077
# F1 = 0.870 vs. 0.109
# Accuracy = 0.896 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.069
# F1 = 0.553 vs. 0.099
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.076444
# Train Batch Evaluation
# AUC = 0.887 vs. 0.077
# F1 = 0.869 vs. 0.108
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.069
# F1 = 0.554 vs. 0.096
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.076744
# Train Batch Evaluation
# AUC = 0.887 vs. 0.077
# F1 = 0.870 vs. 0.108
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.068
# F1 = 0.554 vs. 0.099
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.076099
# Train Batch Evaluation
# AUC = 0.888 vs. 0.077
# F1 = 0.870 vs. 0.109
# Accuracy = 0.903 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.070
# F1 = 0.554 vs. 0.104
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.076396
# Train Batch Evaluation
# AUC = 0.887 vs. 0.077
# F1 = 0.870 vs. 0.109
# Accuracy = 0.898 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.073
# F1 = 0.553 vs. 0.106
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.075864
# Train Batch Evaluation
# AUC = 0.888 vs. 0.077
# F1 = 0.871 vs. 0.108
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.554 vs. 0.101
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.075772
# Train Batch Evaluation
# AUC = 0.888 vs. 0.077
# F1 = 0.871 vs. 0.108
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.072
# F1 = 0.555 vs. 0.108
# Accuracy = 0.859 vs. 0.056
# Minibatch Loss= 0.074977
# Train Batch Evaluation
# AUC = 0.888 vs. 0.077
# F1 = 0.871 vs. 0.109
# Accuracy = 0.905 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.069
# F1 = 0.554 vs. 0.100
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.074889
# Train Batch Evaluation
# AUC = 0.888 vs. 0.077
# F1 = 0.873 vs. 0.109
# Accuracy = 0.902 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.072
# F1 = 0.556 vs. 0.108
# Accuracy = 0.859 vs. 0.056
# Minibatch Loss= 0.074747
# Train Batch Evaluation
# AUC = 0.888 vs. 0.076
# F1 = 0.871 vs. 0.108
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.069
# F1 = 0.555 vs. 0.099
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.074719
# Train Batch Evaluation
# AUC = 0.889 vs. 0.077
# F1 = 0.873 vs. 0.109
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.071
# F1 = 0.554 vs. 0.102
# Accuracy = 0.857 vs. 0.056
# Minibatch Loss= 0.074313
# Train Batch Evaluation
# AUC = 0.889 vs. 0.077
# F1 = 0.873 vs. 0.110
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.069
# F1 = 0.555 vs. 0.101
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.073971
# Train Batch Evaluation
# AUC = 0.889 vs. 0.076
# F1 = 0.872 vs. 0.108
# Accuracy = 0.909 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.068
# F1 = 0.555 vs. 0.102
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.073875
# Train Batch Evaluation
# AUC = 0.889 vs. 0.077
# F1 = 0.873 vs. 0.110
# Accuracy = 0.902 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.075
# F1 = 0.554 vs. 0.109
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.073918
# Train Batch Evaluation
# AUC = 0.890 vs. 0.077
# F1 = 0.873 vs. 0.108
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.071
# F1 = 0.555 vs. 0.102
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.073861
# Train Batch Evaluation
# AUC = 0.890 vs. 0.077
# F1 = 0.874 vs. 0.108
# Accuracy = 0.905 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.070
# F1 = 0.555 vs. 0.103
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.073756
# Train Batch Evaluation
# AUC = 0.890 vs. 0.077
# F1 = 0.874 vs. 0.108
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.070
# F1 = 0.554 vs. 0.101
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.073724
# Train Batch Evaluation
# AUC = 0.890 vs. 0.076
# F1 = 0.875 vs. 0.107
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.069
# F1 = 0.553 vs. 0.101
# Accuracy = 0.859 vs. 0.056
# Minibatch Loss= 0.073596
# Train Batch Evaluation
# AUC = 0.891 vs. 0.077
# F1 = 0.874 vs. 0.108
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.072
# F1 = 0.556 vs. 0.109
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.073924
# Train Batch Evaluation
# AUC = 0.891 vs. 0.076
# F1 = 0.875 vs. 0.108
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.067
# F1 = 0.553 vs. 0.097
# Accuracy = 0.856 vs. 0.056
# Minibatch Loss= 0.073927
# Train Batch Evaluation
# AUC = 0.891 vs. 0.078
# F1 = 0.874 vs. 0.109
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.513 vs. 0.070
# F1 = 0.556 vs. 0.106
# Accuracy = 0.865 vs. 0.056
# Minibatch Loss= 0.074765
# Train Batch Evaluation
# AUC = 0.891 vs. 0.078
# F1 = 0.876 vs. 0.109
# Accuracy = 0.900 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.070
# F1 = 0.554 vs. 0.101
# Accuracy = 0.855 vs. 0.056
# Minibatch Loss= 0.074407
# Train Batch Evaluation
# AUC = 0.892 vs. 0.078
# F1 = 0.874 vs. 0.109
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.069
# F1 = 0.555 vs. 0.100
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.075914
# Train Batch Evaluation
# AUC = 0.891 vs. 0.076
# F1 = 0.876 vs. 0.108
# Accuracy = 0.897 vs. 0.056
# Validation
# AUC = 0.509 vs. 0.072
# F1 = 0.554 vs. 0.101
# Accuracy = 0.854 vs. 0.056
# Minibatch Loss= 0.074301
# Train Batch Evaluation
# AUC = 0.892 vs. 0.077
# F1 = 0.875 vs. 0.108
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.513 vs. 0.069
# F1 = 0.559 vs. 0.101
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.074415
# Train Batch Evaluation
# AUC = 0.892 vs. 0.077
# F1 = 0.877 vs. 0.108
# Accuracy = 0.903 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.068
# F1 = 0.555 vs. 0.094
# Accuracy = 0.857 vs. 0.056
# Minibatch Loss= 0.072862
# Train Batch Evaluation
# AUC = 0.892 vs. 0.077
# F1 = 0.877 vs. 0.108
# Accuracy = 0.903 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.071
# F1 = 0.555 vs. 0.106
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.072391
# Train Batch Evaluation
# AUC = 0.893 vs. 0.077
# F1 = 0.877 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.069
# F1 = 0.556 vs. 0.100
# Accuracy = 0.866 vs. 0.056
# Minibatch Loss= 0.072193
# Train Batch Evaluation
# AUC = 0.893 vs. 0.077
# F1 = 0.877 vs. 0.108
# Accuracy = 0.905 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.072
# F1 = 0.554 vs. 0.106
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.072404
# Train Batch Evaluation
# AUC = 0.893 vs. 0.078
# F1 = 0.877 vs. 0.109
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.070
# F1 = 0.555 vs. 0.099
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.073329
# Train Batch Evaluation
# AUC = 0.893 vs. 0.077
# F1 = 0.877 vs. 0.108
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.068
# F1 = 0.553 vs. 0.098
# Accuracy = 0.857 vs. 0.056
# Minibatch Loss= 0.073525
# Train Batch Evaluation
# AUC = 0.894 vs. 0.077
# F1 = 0.877 vs. 0.109
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.067
# F1 = 0.556 vs. 0.095
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.075468
# Train Batch Evaluation
# AUC = 0.893 vs. 0.077
# F1 = 0.879 vs. 0.108
# Accuracy = 0.900 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.071
# F1 = 0.555 vs. 0.105
# Accuracy = 0.856 vs. 0.056
# Minibatch Loss= 0.073046
# Train Batch Evaluation
# AUC = 0.894 vs. 0.076
# F1 = 0.878 vs. 0.108
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.070
# F1 = 0.555 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.072139
# Train Batch Evaluation
# AUC = 0.894 vs. 0.077
# F1 = 0.879 vs. 0.107
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.072
# F1 = 0.556 vs. 0.104
# Accuracy = 0.859 vs. 0.056
# Minibatch Loss= 0.071495
# Train Batch Evaluation
# AUC = 0.894 vs. 0.076
# F1 = 0.879 vs. 0.108
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.074
# F1 = 0.551 vs. 0.109
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.071853
# Train Batch Evaluation
# AUC = 0.895 vs. 0.077
# F1 = 0.878 vs. 0.107
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.513 vs. 0.069
# F1 = 0.555 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.072644
# Train Batch Evaluation
# AUC = 0.894 vs. 0.076
# F1 = 0.879 vs. 0.108
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.068
# F1 = 0.554 vs. 0.094
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.073153
# Train Batch Evaluation
# AUC = 0.895 vs. 0.078
# F1 = 0.878 vs. 0.110
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.554 vs. 0.107
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.076373
# Train Batch Evaluation
# AUC = 0.895 vs. 0.077
# F1 = 0.880 vs. 0.108
# Accuracy = 0.878 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.069
# F1 = 0.556 vs. 0.103
# Accuracy = 0.837 vs. 0.056
# Minibatch Loss= 0.073356
# Train Batch Evaluation
# AUC = 0.895 vs. 0.077
# F1 = 0.879 vs. 0.109
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.513 vs. 0.070
# F1 = 0.555 vs. 0.097
# Accuracy = 0.857 vs. 0.056
# Minibatch Loss= 0.071539
# Train Batch Evaluation
# AUC = 0.895 vs. 0.076
# F1 = 0.880 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.069
# F1 = 0.554 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.071250
# Train Batch Evaluation
# AUC = 0.895 vs. 0.077
# F1 = 0.882 vs. 0.109
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.073
# F1 = 0.554 vs. 0.106
# Accuracy = 0.854 vs. 0.056
# Minibatch Loss= 0.072161
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-340a4186f466> in <module>()
#       2                 train_eval_step = 1,
#       3                 validation_eval_step = 1,
# ----> 4                 display_step = 1)
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#      81         for _ in range (max_iter):
#      82             if self.global_step % self.num_batch == 0:
# ---> 83                 self.data_train ,self.ground_truth_train = self.shuffle(self.data_train, self.ground_truth_train)
#      84
#      85             batch_idx = self.global_step % self.num_batch
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.pyc in shuffle(self, data, gt)
#     154         np.random.shuffle(idx)
#     155
# --> 156         data = data[idx]
#     157         gt = gt[idx]
#     158
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# [autoreload of models.wavelet_conv_model_light failed: Traceback (most recent call last):
#   File "/data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "../src/models/wavelet_conv_model_light.py", line 109
#     trainable=trainable_last
#             ^
# SyntaxError: invalid syntax
# ]
# '../model/DWN9005_opp/checkpoint-607'

# %%
trainer.train(max_iter = 4000,
                train_eval_step = 1, 
                validation_eval_step = 1,
                display_step = 1)
# Out:
# Train Batch Evaluation
# AUC = 0.896 vs. 0.077
# F1 = 0.879 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.069
# F1 = 0.556 vs. 0.102
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.074121
# Train Batch Evaluation
# AUC = 0.896 vs. 0.077
# F1 = 0.881 vs. 0.109
# Accuracy = 0.900 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.072
# F1 = 0.554 vs. 0.103
# Accuracy = 0.855 vs. 0.056
# Minibatch Loss= 0.072992
# Train Batch Evaluation
# AUC = 0.897 vs. 0.077
# F1 = 0.880 vs. 0.110
# Accuracy = 0.897 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.070
# F1 = 0.555 vs. 0.102
# Accuracy = 0.849 vs. 0.056
# Minibatch Loss= 0.075119
# Train Batch Evaluation
# AUC = 0.896 vs. 0.077
# F1 = 0.880 vs. 0.109
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.556 vs. 0.102
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.070315
# Train Batch Evaluation
# AUC = 0.896 vs. 0.077
# F1 = 0.881 vs. 0.108
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.072
# F1 = 0.555 vs. 0.105
# Accuracy = 0.869 vs. 0.056
# Minibatch Loss= 0.073153
# Train Batch Evaluation
# AUC = 0.897 vs. 0.077
# F1 = 0.880 vs. 0.110
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.069
# F1 = 0.556 vs. 0.096
# Accuracy = 0.850 vs. 0.056
# Minibatch Loss= 0.083220
# Train Batch Evaluation
# AUC = 0.897 vs. 0.077
# F1 = 0.882 vs. 0.108
# Accuracy = 0.884 vs. 0.056
# Validation
# AUC = 0.513 vs. 0.070
# F1 = 0.554 vs. 0.101
# Accuracy = 0.846 vs. 0.056
# Minibatch Loss= 0.072026
# Train Batch Evaluation
# AUC = 0.895 vs. 0.077
# F1 = 0.879 vs. 0.109
# Accuracy = 0.927 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.080
# F1 = 0.553 vs. 0.117
# Accuracy = 0.876 vs. 0.056
# Minibatch Loss= 0.092209
# Train Batch Evaluation
# AUC = 0.894 vs. 0.076
# F1 = 0.869 vs. 0.107
# Accuracy = 0.880 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.070
# F1 = 0.574 vs. 0.098
# Accuracy = 0.824 vs. 0.056
# Minibatch Loss= 0.147237
# Train Batch Evaluation
# AUC = 0.893 vs. 0.077
# F1 = 0.872 vs. 0.108
# Accuracy = 0.798 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.072
# F1 = 0.562 vs. 0.107
# Accuracy = 0.727 vs. 0.056
# Minibatch Loss= 0.136872
# Train Batch Evaluation
# AUC = 0.893 vs. 0.077
# F1 = 0.869 vs. 0.108
# Accuracy = 0.862 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.557 vs. 0.102
# Accuracy = 0.835 vs. 0.056
# Minibatch Loss= 0.132931
# Train Batch Evaluation
# AUC = 0.889 vs. 0.078
# F1 = 0.865 vs. 0.110
# Accuracy = 0.897 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.073
# F1 = 0.558 vs. 0.107
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.278152
# Train Batch Evaluation
# AUC = 0.875 vs. 0.077
# F1 = 0.848 vs. 0.108
# Accuracy = 0.755 vs. 0.056
# Validation
# AUC = 0.536 vs. 0.077
# F1 = 0.575 vs. 0.112
# Accuracy = 0.708 vs. 0.056
# Minibatch Loss= 0.363981
# Train Batch Evaluation
# AUC = 0.815 vs. 0.076
# F1 = 0.818 vs. 0.108
# Accuracy = 0.462 vs. 0.056
# Validation
# AUC = 0.489 vs. 0.074
# F1 = 0.543 vs. 0.106
# Accuracy = 0.375 vs. 0.056
# Minibatch Loss= 0.623322
# Train Batch Evaluation
# AUC = 0.882 vs. 0.077
# F1 = 0.853 vs. 0.109
# Accuracy = 0.583 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.074
# F1 = 0.563 vs. 0.109
# Accuracy = 0.468 vs. 0.056
# Minibatch Loss= 0.300449
# Train Batch Evaluation
# AUC = 0.884 vs. 0.077
# F1 = 0.852 vs. 0.109
# Accuracy = 0.755 vs. 0.056
# Validation
# AUC = 0.498 vs. 0.073
# F1 = 0.548 vs. 0.104
# Accuracy = 0.711 vs. 0.056
# Minibatch Loss= 0.208340
# Train Batch Evaluation
# AUC = 0.872 vs. 0.077
# F1 = 0.839 vs. 0.108
# Accuracy = 0.867 vs. 0.056
# Validation
# AUC = 0.482 vs. 0.070
# F1 = 0.551 vs. 0.104
# Accuracy = 0.836 vs. 0.056
# Minibatch Loss= 0.373215
# Train Batch Evaluation
# AUC = 0.869 vs. 0.077
# F1 = 0.835 vs. 0.109
# Accuracy = 0.879 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.069
# F1 = 0.568 vs. 0.105
# Accuracy = 0.854 vs. 0.056
# Minibatch Loss= 0.289529
# Train Batch Evaluation
# AUC = 0.875 vs. 0.076
# F1 = 0.842 vs. 0.108
# Accuracy = 0.885 vs. 0.056
# Validation
# AUC = 0.546 vs. 0.069
# F1 = 0.591 vs. 0.105
# Accuracy = 0.845 vs. 0.056
# Minibatch Loss= 0.220654
# Train Batch Evaluation
# AUC = 0.877 vs. 0.078
# F1 = 0.846 vs. 0.109
# Accuracy = 0.720 vs. 0.056
# Validation
# AUC = 0.555 vs. 0.070
# F1 = 0.590 vs. 0.100
# Accuracy = 0.633 vs. 0.056
# Minibatch Loss= 0.205819
# Train Batch Evaluation
# AUC = 0.873 vs. 0.076
# F1 = 0.844 vs. 0.108
# Accuracy = 0.547 vs. 0.056
# Validation
# AUC = 0.541 vs. 0.069
# F1 = 0.586 vs. 0.096
# Accuracy = 0.462 vs. 0.056
# Minibatch Loss= 0.272484
# Train Batch Evaluation
# AUC = 0.875 vs. 0.076
# F1 = 0.842 vs. 0.109
# Accuracy = 0.560 vs. 0.056
# Validation
# AUC = 0.546 vs. 0.070
# F1 = 0.589 vs. 0.095
# Accuracy = 0.482 vs. 0.056
# Minibatch Loss= 0.244484
# Train Batch Evaluation
# AUC = 0.872 vs. 0.077
# F1 = 0.838 vs. 0.109
# Accuracy = 0.639 vs. 0.056
# Validation
# AUC = 0.545 vs. 0.070
# F1 = 0.590 vs. 0.105
# Accuracy = 0.581 vs. 0.056
# Minibatch Loss= 0.209479
# Train Batch Evaluation
# AUC = 0.868 vs. 0.078
# F1 = 0.833 vs. 0.108
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.536 vs. 0.071
# F1 = 0.575 vs. 0.102
# Accuracy = 0.744 vs. 0.056
# Minibatch Loss= 0.172050
# Train Batch Evaluation
# AUC = 0.867 vs. 0.077
# F1 = 0.831 vs. 0.108
# Accuracy = 0.851 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.072
# F1 = 0.567 vs. 0.112
# Accuracy = 0.825 vs. 0.056
# Minibatch Loss= 0.166911
# Train Batch Evaluation
# AUC = 0.868 vs. 0.077
# F1 = 0.833 vs. 0.108
# Accuracy = 0.903 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.070
# F1 = 0.572 vs. 0.102
# Accuracy = 0.866 vs. 0.056
# Minibatch Loss= 0.177470
# Train Batch Evaluation
# AUC = 0.870 vs. 0.077
# F1 = 0.834 vs. 0.109
# Accuracy = 0.921 vs. 0.056
# Validation
# AUC = 0.535 vs. 0.070
# F1 = 0.580 vs. 0.100
# Accuracy = 0.877 vs. 0.056
# Minibatch Loss= 0.143871
# Train Batch Evaluation
# AUC = 0.872 vs. 0.077
# F1 = 0.835 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.542 vs. 0.072
# F1 = 0.582 vs. 0.105
# Accuracy = 0.869 vs. 0.056
# Minibatch Loss= 0.142753
# Train Batch Evaluation
# AUC = 0.874 vs. 0.077
# F1 = 0.836 vs. 0.107
# Accuracy = 0.893 vs. 0.056
# Validation
# AUC = 0.545 vs. 0.071
# F1 = 0.571 vs. 0.107
# Accuracy = 0.857 vs. 0.056
# Minibatch Loss= 0.146630
# Train Batch Evaluation
# AUC = 0.877 vs. 0.076
# F1 = 0.838 vs. 0.109
# Accuracy = 0.834 vs. 0.056
# Validation
# AUC = 0.544 vs. 0.070
# F1 = 0.571 vs. 0.103
# Accuracy = 0.775 vs. 0.056
# Minibatch Loss= 0.132212
# Train Batch Evaluation
# AUC = 0.879 vs. 0.077
# F1 = 0.840 vs. 0.109
# Accuracy = 0.778 vs. 0.056
# Validation
# AUC = 0.542 vs. 0.070
# F1 = 0.573 vs. 0.100
# Accuracy = 0.688 vs. 0.056
# Minibatch Loss= 0.122226
# Train Batch Evaluation
# AUC = 0.881 vs. 0.077
# F1 = 0.842 vs. 0.108
# Accuracy = 0.739 vs. 0.056
# Validation
# AUC = 0.537 vs. 0.074
# F1 = 0.571 vs. 0.102
# Accuracy = 0.636 vs. 0.056
# Minibatch Loss= 0.126155
# Train Batch Evaluation
# AUC = 0.881 vs. 0.077
# F1 = 0.842 vs. 0.108
# Accuracy = 0.738 vs. 0.056
# Validation
# AUC = 0.533 vs. 0.069
# F1 = 0.568 vs. 0.094
# Accuracy = 0.646 vs. 0.056
# Minibatch Loss= 0.130360
# Train Batch Evaluation
# AUC = 0.882 vs. 0.077
# F1 = 0.843 vs. 0.110
# Accuracy = 0.779 vs. 0.056
# Validation
# AUC = 0.533 vs. 0.069
# F1 = 0.563 vs. 0.104
# Accuracy = 0.717 vs. 0.056
# Minibatch Loss= 0.122766
# Train Batch Evaluation
# AUC = 0.883 vs. 0.076
# F1 = 0.845 vs. 0.108
# Accuracy = 0.839 vs. 0.056
# Validation
# AUC = 0.535 vs. 0.070
# F1 = 0.562 vs. 0.103
# Accuracy = 0.818 vs. 0.056
# Minibatch Loss= 0.116295
# Train Batch Evaluation
# AUC = 0.884 vs. 0.077
# F1 = 0.846 vs. 0.107
# Accuracy = 0.884 vs. 0.056
# Validation
# AUC = 0.532 vs. 0.070
# F1 = 0.561 vs. 0.099
# Accuracy = 0.852 vs. 0.056
# Minibatch Loss= 0.112494
# Train Batch Evaluation
# AUC = 0.884 vs. 0.076
# F1 = 0.846 vs. 0.108
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.527 vs. 0.070
# F1 = 0.567 vs. 0.101
# Accuracy = 0.866 vs. 0.056
# Minibatch Loss= 0.109053
# Train Batch Evaluation
# AUC = 0.885 vs. 0.077
# F1 = 0.849 vs. 0.108
# Accuracy = 0.922 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.069
# F1 = 0.566 vs. 0.101
# Accuracy = 0.876 vs. 0.056
# Minibatch Loss= 0.107844
# Train Batch Evaluation
# AUC = 0.885 vs. 0.076
# F1 = 0.851 vs. 0.108
# Accuracy = 0.926 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.069
# F1 = 0.563 vs. 0.098
# Accuracy = 0.882 vs. 0.056
# Minibatch Loss= 0.102783
# Train Batch Evaluation
# AUC = 0.886 vs. 0.077
# F1 = 0.854 vs. 0.108
# Accuracy = 0.922 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.068
# F1 = 0.569 vs. 0.096
# Accuracy = 0.877 vs. 0.056
# Minibatch Loss= 0.093657
# Train Batch Evaluation
# AUC = 0.886 vs. 0.076
# F1 = 0.855 vs. 0.108
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.532 vs. 0.074
# F1 = 0.569 vs. 0.105
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.090215
# Train Batch Evaluation
# AUC = 0.886 vs. 0.077
# F1 = 0.855 vs. 0.107
# Accuracy = 0.893 vs. 0.056
# Validation
# AUC = 0.529 vs. 0.069
# F1 = 0.575 vs. 0.098
# Accuracy = 0.856 vs. 0.056
# Minibatch Loss= 0.093225
# Train Batch Evaluation
# AUC = 0.886 vs. 0.077
# F1 = 0.855 vs. 0.109
# Accuracy = 0.879 vs. 0.056
# Validation
# AUC = 0.528 vs. 0.071
# F1 = 0.573 vs. 0.103
# Accuracy = 0.845 vs. 0.056
# Minibatch Loss= 0.095780
# Train Batch Evaluation
# AUC = 0.886 vs. 0.077
# F1 = 0.853 vs. 0.109
# Accuracy = 0.866 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.071
# F1 = 0.569 vs. 0.101
# Accuracy = 0.830 vs. 0.056
# Minibatch Loss= 0.095224
# Train Batch Evaluation
# AUC = 0.887 vs. 0.077
# F1 = 0.854 vs. 0.107
# Accuracy = 0.862 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.074
# F1 = 0.567 vs. 0.110
# Accuracy = 0.825 vs. 0.056
# Minibatch Loss= 0.093526
# Train Batch Evaluation
# AUC = 0.888 vs. 0.077
# F1 = 0.855 vs. 0.108
# Accuracy = 0.862 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.069
# F1 = 0.567 vs. 0.100
# Accuracy = 0.825 vs. 0.056
# Minibatch Loss= 0.090671
# Train Batch Evaluation
# AUC = 0.889 vs. 0.076
# F1 = 0.857 vs. 0.107
# Accuracy = 0.866 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.071
# F1 = 0.565 vs. 0.105
# Accuracy = 0.831 vs. 0.056
# Minibatch Loss= 0.087815
# Train Batch Evaluation
# AUC = 0.890 vs. 0.077
# F1 = 0.858 vs. 0.108
# Accuracy = 0.874 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.072
# F1 = 0.562 vs. 0.103
# Accuracy = 0.842 vs. 0.056
# Minibatch Loss= 0.086611
# Train Batch Evaluation
# AUC = 0.890 vs. 0.076
# F1 = 0.859 vs. 0.107
# Accuracy = 0.883 vs. 0.056
# Validation
# AUC = 0.525 vs. 0.070
# F1 = 0.562 vs. 0.104
# Accuracy = 0.854 vs. 0.056
# Minibatch Loss= 0.086112
# Train Batch Evaluation
# AUC = 0.891 vs. 0.077
# F1 = 0.860 vs. 0.108
# Accuracy = 0.893 vs. 0.056
# Validation
# AUC = 0.530 vs. 0.070
# F1 = 0.563 vs. 0.102
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.085728
# Train Batch Evaluation
# AUC = 0.891 vs. 0.077
# F1 = 0.861 vs. 0.109
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.531 vs. 0.069
# F1 = 0.565 vs. 0.098
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.084035
# Train Batch Evaluation
# AUC = 0.891 vs. 0.077
# F1 = 0.863 vs. 0.109
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.530 vs. 0.070
# F1 = 0.566 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.081769
# Train Batch Evaluation
# AUC = 0.891 vs. 0.077
# F1 = 0.863 vs. 0.108
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.528 vs. 0.071
# F1 = 0.568 vs. 0.105
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.081790
# Train Batch Evaluation
# AUC = 0.890 vs. 0.077
# F1 = 0.864 vs. 0.109
# Accuracy = 0.905 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.072
# F1 = 0.570 vs. 0.105
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.082348
# Train Batch Evaluation
# AUC = 0.891 vs. 0.077
# F1 = 0.864 vs. 0.108
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.071
# F1 = 0.568 vs. 0.099
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.082175
# Train Batch Evaluation
# AUC = 0.891 vs. 0.077
# F1 = 0.865 vs. 0.108
# Accuracy = 0.899 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.070
# F1 = 0.570 vs. 0.104
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.081480
# Train Batch Evaluation
# AUC = 0.892 vs. 0.077
# F1 = 0.866 vs. 0.108
# Accuracy = 0.895 vs. 0.056
# Validation
# AUC = 0.527 vs. 0.068
# F1 = 0.571 vs. 0.101
# Accuracy = 0.855 vs. 0.056
# Minibatch Loss= 0.080015
# Train Batch Evaluation
# AUC = 0.893 vs. 0.076
# F1 = 0.868 vs. 0.108
# Accuracy = 0.891 vs. 0.056
# Validation
# AUC = 0.528 vs. 0.072
# F1 = 0.569 vs. 0.109
# Accuracy = 0.853 vs. 0.056
# Minibatch Loss= 0.078937
# Train Batch Evaluation
# AUC = 0.893 vs. 0.077
# F1 = 0.869 vs. 0.110
# Accuracy = 0.891 vs. 0.056
# Validation
# AUC = 0.527 vs. 0.072
# F1 = 0.568 vs. 0.098
# Accuracy = 0.854 vs. 0.056
# Minibatch Loss= 0.078498
# Train Batch Evaluation
# AUC = 0.894 vs. 0.077
# F1 = 0.870 vs. 0.108
# Accuracy = 0.895 vs. 0.056
# Validation
# AUC = 0.527 vs. 0.071
# F1 = 0.566 vs. 0.108
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.077584
# Train Batch Evaluation
# AUC = 0.895 vs. 0.077
# F1 = 0.870 vs. 0.109
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.525 vs. 0.070
# F1 = 0.566 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.077333
# Train Batch Evaluation
# AUC = 0.895 vs. 0.077
# F1 = 0.870 vs. 0.109
# Accuracy = 0.903 vs. 0.056
# Validation
# AUC = 0.525 vs. 0.073
# F1 = 0.566 vs. 0.109
# Accuracy = 0.865 vs. 0.056
# Minibatch Loss= 0.077290
# Train Batch Evaluation
# AUC = 0.896 vs. 0.077
# F1 = 0.872 vs. 0.108
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.072
# F1 = 0.567 vs. 0.104
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.076462
# Train Batch Evaluation
# AUC = 0.896 vs. 0.076
# F1 = 0.872 vs. 0.108
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.069
# F1 = 0.566 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.076188
# Train Batch Evaluation
# AUC = 0.896 vs. 0.077
# F1 = 0.872 vs. 0.109
# Accuracy = 0.904 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.073
# F1 = 0.565 vs. 0.115
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.076058
# Train Batch Evaluation
# AUC = 0.897 vs. 0.076
# F1 = 0.873 vs. 0.107
# Accuracy = 0.905 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.075
# F1 = 0.564 vs. 0.114
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.075593
# Train Batch Evaluation
# AUC = 0.897 vs. 0.077
# F1 = 0.873 vs. 0.108
# Accuracy = 0.909 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.070
# F1 = 0.568 vs. 0.102
# Accuracy = 0.865 vs. 0.056
# Minibatch Loss= 0.075362
# Train Batch Evaluation
# AUC = 0.897 vs. 0.077
# F1 = 0.873 vs. 0.108
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.071
# F1 = 0.570 vs. 0.110
# Accuracy = 0.867 vs. 0.056
# Minibatch Loss= 0.074934
# Train Batch Evaluation
# AUC = 0.897 vs. 0.077
# F1 = 0.874 vs. 0.108
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.525 vs. 0.071
# F1 = 0.568 vs. 0.105
# Accuracy = 0.867 vs. 0.056
# Minibatch Loss= 0.074563
# Train Batch Evaluation
# AUC = 0.897 vs. 0.076
# F1 = 0.874 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.525 vs. 0.070
# F1 = 0.567 vs. 0.106
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.074491
# Train Batch Evaluation
# AUC = 0.897 vs. 0.077
# F1 = 0.875 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.075
# F1 = 0.567 vs. 0.111
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.074060
# Train Batch Evaluation
# AUC = 0.898 vs. 0.078
# F1 = 0.875 vs. 0.110
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.527 vs. 0.071
# F1 = 0.565 vs. 0.106
# Accuracy = 0.866 vs. 0.056
# Minibatch Loss= 0.073741
# Train Batch Evaluation
# AUC = 0.898 vs. 0.077
# F1 = 0.876 vs. 0.108
# Accuracy = 0.906 vs. 0.056
# Validation
# AUC = 0.526 vs. 0.069
# F1 = 0.567 vs. 0.096
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.073569
# Train Batch Evaluation
# AUC = 0.899 vs. 0.077
# F1 = 0.876 vs. 0.109
# Accuracy = 0.900 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.074
# F1 = 0.566 vs. 0.108
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.073310
# Train Batch Evaluation
# AUC = 0.899 vs. 0.077
# F1 = 0.877 vs. 0.108
# Accuracy = 0.895 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.070
# F1 = 0.565 vs. 0.097
# Accuracy = 0.854 vs. 0.056
# Minibatch Loss= 0.073209
# Train Batch Evaluation
# AUC = 0.900 vs. 0.077
# F1 = 0.877 vs. 0.108
# Accuracy = 0.894 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.072
# F1 = 0.565 vs. 0.106
# Accuracy = 0.856 vs. 0.056
# Minibatch Loss= 0.073040
# Train Batch Evaluation
# AUC = 0.900 vs. 0.077
# F1 = 0.877 vs. 0.109
# Accuracy = 0.898 vs. 0.056
# Validation
# AUC = 0.519 vs. 0.070
# F1 = 0.565 vs. 0.098
# Accuracy = 0.856 vs. 0.056
# Minibatch Loss= 0.072745
# Train Batch Evaluation
# AUC = 0.900 vs. 0.076
# F1 = 0.878 vs. 0.108
# Accuracy = 0.903 vs. 0.056
# Validation
# AUC = 0.519 vs. 0.071
# F1 = 0.565 vs. 0.098
# Accuracy = 0.857 vs. 0.056
# Minibatch Loss= 0.072574
# Train Batch Evaluation
# AUC = 0.901 vs. 0.077
# F1 = 0.878 vs. 0.108
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.519 vs. 0.070
# F1 = 0.566 vs. 0.100
# Accuracy = 0.858 vs. 0.056
# Minibatch Loss= 0.072364
# Train Batch Evaluation
# AUC = 0.901 vs. 0.077
# F1 = 0.878 vs. 0.109
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.070
# F1 = 0.565 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.072194
# Train Batch Evaluation
# AUC = 0.901 vs. 0.077
# F1 = 0.878 vs. 0.108
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.069
# F1 = 0.565 vs. 0.100
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.072083
# Train Batch Evaluation
# AUC = 0.901 vs. 0.077
# F1 = 0.878 vs. 0.109
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.070
# F1 = 0.565 vs. 0.103
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.071874
# Train Batch Evaluation
# AUC = 0.901 vs. 0.076
# F1 = 0.879 vs. 0.107
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.070
# F1 = 0.566 vs. 0.103
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.071733
# Train Batch Evaluation
# AUC = 0.901 vs. 0.077
# F1 = 0.879 vs. 0.109
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.565 vs. 0.105
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.071589
# Train Batch Evaluation
# AUC = 0.901 vs. 0.076
# F1 = 0.879 vs. 0.108
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.068
# F1 = 0.566 vs. 0.097
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.071415
# Train Batch Evaluation
# AUC = 0.901 vs. 0.076
# F1 = 0.880 vs. 0.109
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.068
# F1 = 0.566 vs. 0.095
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.071324
# Train Batch Evaluation
# AUC = 0.902 vs. 0.077
# F1 = 0.881 vs. 0.110
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.073
# F1 = 0.566 vs. 0.115
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.071173
# Train Batch Evaluation
# AUC = 0.902 vs. 0.077
# F1 = 0.880 vs. 0.108
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.069
# F1 = 0.565 vs. 0.097
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.071006
# Train Batch Evaluation
# AUC = 0.902 vs. 0.076
# F1 = 0.881 vs. 0.107
# Accuracy = 0.907 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.070
# F1 = 0.564 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.070877
# Train Batch Evaluation
# AUC = 0.902 vs. 0.077
# F1 = 0.882 vs. 0.108
# Accuracy = 0.909 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.070
# F1 = 0.564 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.070738
# Train Batch Evaluation
# AUC = 0.902 vs. 0.076
# F1 = 0.882 vs. 0.107
# Accuracy = 0.909 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.069
# F1 = 0.563 vs. 0.100
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.070634
# Train Batch Evaluation
# AUC = 0.902 vs. 0.077
# F1 = 0.882 vs. 0.108
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.071
# F1 = 0.563 vs. 0.106
# Accuracy = 0.860 vs. 0.056
# Minibatch Loss= 0.070524
# Train Batch Evaluation
# AUC = 0.902 vs. 0.077
# F1 = 0.882 vs. 0.109
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.069
# F1 = 0.562 vs. 0.105
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.070413
# Train Batch Evaluation
# AUC = 0.903 vs. 0.078
# F1 = 0.882 vs. 0.110
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.562 vs. 0.108
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.070322
# Train Batch Evaluation
# AUC = 0.903 vs. 0.077
# F1 = 0.882 vs. 0.109
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.077
# F1 = 0.562 vs. 0.118
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.070190
# Train Batch Evaluation
# AUC = 0.903 vs. 0.076
# F1 = 0.883 vs. 0.108
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.069
# F1 = 0.562 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.070068
# Train Batch Evaluation
# AUC = 0.903 vs. 0.076
# F1 = 0.883 vs. 0.108
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.070
# F1 = 0.562 vs. 0.102
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.069976
# Train Batch Evaluation
# AUC = 0.903 vs. 0.077
# F1 = 0.883 vs. 0.110
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.070
# F1 = 0.562 vs. 0.098
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069873
# Train Batch Evaluation
# AUC = 0.903 vs. 0.077
# F1 = 0.884 vs. 0.108
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.070
# F1 = 0.562 vs. 0.099
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069778
# Train Batch Evaluation
# AUC = 0.903 vs. 0.077
# F1 = 0.884 vs. 0.108
# Accuracy = 0.911 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.069
# F1 = 0.562 vs. 0.098
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069677
# Train Batch Evaluation
# AUC = 0.903 vs. 0.076
# F1 = 0.884 vs. 0.107
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.562 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069579
# Train Batch Evaluation
# AUC = 0.903 vs. 0.076
# F1 = 0.884 vs. 0.107
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.071
# F1 = 0.561 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069495
# Train Batch Evaluation
# AUC = 0.903 vs. 0.077
# F1 = 0.885 vs. 0.109
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.071
# F1 = 0.561 vs. 0.103
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069402
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.885 vs. 0.110
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.069
# F1 = 0.560 vs. 0.099
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069317
# Train Batch Evaluation
# AUC = 0.904 vs. 0.076
# F1 = 0.885 vs. 0.107
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.561 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.069231
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.885 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.561 vs. 0.100
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.069142
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.885 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.072
# F1 = 0.562 vs. 0.106
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.069060
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.885 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.069
# F1 = 0.562 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.068972
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.886 vs. 0.109
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.068
# F1 = 0.562 vs. 0.096
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.068889
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.886 vs. 0.108
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.074
# F1 = 0.562 vs. 0.116
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.068812
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.886 vs. 0.108
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.562 vs. 0.097
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068733
# Train Batch Evaluation
# AUC = 0.904 vs. 0.077
# F1 = 0.886 vs. 0.108
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.072
# F1 = 0.562 vs. 0.110
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068656
# Train Batch Evaluation
# AUC = 0.904 vs. 0.076
# F1 = 0.886 vs. 0.108
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.072
# F1 = 0.562 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068579
# Train Batch Evaluation
# AUC = 0.904 vs. 0.076
# F1 = 0.887 vs. 0.108
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.076
# F1 = 0.562 vs. 0.119
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068503
# Train Batch Evaluation
# AUC = 0.905 vs. 0.077
# F1 = 0.887 vs. 0.109
# Accuracy = 0.912 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.071
# F1 = 0.562 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068428
# Train Batch Evaluation
# AUC = 0.905 vs. 0.077
# F1 = 0.887 vs. 0.107
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.072
# F1 = 0.562 vs. 0.107
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068354
# Train Batch Evaluation
# AUC = 0.905 vs. 0.077
# F1 = 0.887 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.069
# F1 = 0.562 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068284
# Train Batch Evaluation
# AUC = 0.905 vs. 0.076
# F1 = 0.887 vs. 0.107
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.562 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.068212
# Train Batch Evaluation
# AUC = 0.905 vs. 0.076
# F1 = 0.887 vs. 0.107
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.562 vs. 0.101
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.068140
# Train Batch Evaluation
# AUC = 0.905 vs. 0.077
# F1 = 0.887 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.071
# F1 = 0.562 vs. 0.097
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.068071
# Train Batch Evaluation
# AUC = 0.905 vs. 0.077
# F1 = 0.887 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.562 vs. 0.101
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.068004
# Train Batch Evaluation
# AUC = 0.905 vs. 0.078
# F1 = 0.887 vs. 0.109
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.562 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067937
# Train Batch Evaluation
# AUC = 0.905 vs. 0.076
# F1 = 0.887 vs. 0.109
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.562 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067869
# Train Batch Evaluation
# AUC = 0.905 vs. 0.076
# F1 = 0.887 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.070
# F1 = 0.562 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067803
# Train Batch Evaluation
# AUC = 0.905 vs. 0.076
# F1 = 0.887 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.068
# F1 = 0.562 vs. 0.095
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067739
# Train Batch Evaluation
# AUC = 0.905 vs. 0.076
# F1 = 0.887 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.562 vs. 0.098
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067674
# Train Batch Evaluation
# AUC = 0.905 vs. 0.077
# F1 = 0.888 vs. 0.108
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.071
# F1 = 0.562 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067610
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.888 vs. 0.109
# Accuracy = 0.913 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.068
# F1 = 0.561 vs. 0.095
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067546
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.888 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067484
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.888 vs. 0.109
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.071
# F1 = 0.561 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067422
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.888 vs. 0.109
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.073
# F1 = 0.561 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067360
# Train Batch Evaluation
# AUC = 0.906 vs. 0.076
# F1 = 0.888 vs. 0.107
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.073
# F1 = 0.561 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067298
# Train Batch Evaluation
# AUC = 0.906 vs. 0.076
# F1 = 0.889 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.071
# F1 = 0.561 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067238
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.889 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.561 vs. 0.098
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067178
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.889 vs. 0.109
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.072
# F1 = 0.561 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.067119
# Train Batch Evaluation
# AUC = 0.906 vs. 0.076
# F1 = 0.889 vs. 0.107
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.099
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.067060
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.889 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.102
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.067002
# Train Batch Evaluation
# AUC = 0.906 vs. 0.076
# F1 = 0.889 vs. 0.107
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.561 vs. 0.102
# Accuracy = 0.861 vs. 0.056
# Minibatch Loss= 0.066944
# Train Batch Evaluation
# AUC = 0.906 vs. 0.076
# F1 = 0.889 vs. 0.109
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.561 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066886
# Train Batch Evaluation
# AUC = 0.906 vs. 0.077
# F1 = 0.889 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.098
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066829
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.889 vs. 0.109
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.561 vs. 0.097
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066772
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.889 vs. 0.107
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.074
# F1 = 0.561 vs. 0.110
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066716
# Train Batch Evaluation
# AUC = 0.907 vs. 0.076
# F1 = 0.889 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.098
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066660
# Train Batch Evaluation
# AUC = 0.907 vs. 0.076
# F1 = 0.890 vs. 0.109
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066605
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.108
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066549
# Train Batch Evaluation
# AUC = 0.907 vs. 0.076
# F1 = 0.890 vs. 0.107
# Accuracy = 0.914 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.098
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066494
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.109
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.075
# F1 = 0.561 vs. 0.109
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066440
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.108
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.561 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066385
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.108
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.075
# F1 = 0.562 vs. 0.109
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066331
# Train Batch Evaluation
# AUC = 0.907 vs. 0.078
# F1 = 0.890 vs. 0.110
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.562 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066277
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.108
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.068
# F1 = 0.562 vs. 0.096
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066224
# Train Batch Evaluation
# AUC = 0.907 vs. 0.076
# F1 = 0.890 vs. 0.108
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.562 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066171
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.107
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.078
# F1 = 0.562 vs. 0.109
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066118
# Train Batch Evaluation
# AUC = 0.907 vs. 0.076
# F1 = 0.890 vs. 0.108
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.071
# F1 = 0.562 vs. 0.108
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066065
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.108
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.562 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.066013
# Train Batch Evaluation
# AUC = 0.907 vs. 0.077
# F1 = 0.890 vs. 0.109
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.562 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065961
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.890 vs. 0.107
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.071
# F1 = 0.562 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065909
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.890 vs. 0.109
# Accuracy = 0.915 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.561 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065858
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.890 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.071
# F1 = 0.561 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065806
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.890 vs. 0.109
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.561 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065755
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.890 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.074
# F1 = 0.561 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065704
# Train Batch Evaluation
# AUC = 0.908 vs. 0.076
# F1 = 0.891 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.073
# F1 = 0.561 vs. 0.110
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065654
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.891 vs. 0.107
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.074
# F1 = 0.561 vs. 0.109
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065603
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.891 vs. 0.109
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.070
# F1 = 0.561 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065553
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.891 vs. 0.110
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.560 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065503
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.891 vs. 0.109
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.069
# F1 = 0.560 vs. 0.099
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065453
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.891 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.515 vs. 0.068
# F1 = 0.560 vs. 0.092
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065404
# Train Batch Evaluation
# AUC = 0.908 vs. 0.076
# F1 = 0.891 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.068
# F1 = 0.559 vs. 0.095
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065354
# Train Batch Evaluation
# AUC = 0.908 vs. 0.076
# F1 = 0.891 vs. 0.107
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.075
# F1 = 0.559 vs. 0.110
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065305
# Train Batch Evaluation
# AUC = 0.908 vs. 0.077
# F1 = 0.892 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.068
# F1 = 0.559 vs. 0.095
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065256
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.559 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065207
# Train Batch Evaluation
# AUC = 0.909 vs. 0.076
# F1 = 0.892 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.069
# F1 = 0.559 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065158
# Train Batch Evaluation
# AUC = 0.909 vs. 0.076
# F1 = 0.892 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.559 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.065110
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.559 vs. 0.103
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.065062
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.559 vs. 0.102
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.065013
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.559 vs. 0.110
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064966
# Train Batch Evaluation
# AUC = 0.909 vs. 0.076
# F1 = 0.892 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.072
# F1 = 0.559 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064918
# Train Batch Evaluation
# AUC = 0.909 vs. 0.076
# F1 = 0.892 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.069
# F1 = 0.559 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064870
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.072
# F1 = 0.559 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064823
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.069
# F1 = 0.559 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064776
# Train Batch Evaluation
# AUC = 0.909 vs. 0.076
# F1 = 0.892 vs. 0.107
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.559 vs. 0.105
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064729
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.075
# F1 = 0.559 vs. 0.109
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064682
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.559 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064635
# Train Batch Evaluation
# AUC = 0.909 vs. 0.077
# F1 = 0.892 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.559 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064588
# Train Batch Evaluation
# AUC = 0.909 vs. 0.076
# F1 = 0.893 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.074
# F1 = 0.559 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064542
# Train Batch Evaluation
# AUC = 0.909 vs. 0.076
# F1 = 0.893 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.072
# F1 = 0.559 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064495
# Train Batch Evaluation
# AUC = 0.910 vs. 0.076
# F1 = 0.893 vs. 0.108
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.559 vs. 0.096
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064449
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.893 vs. 0.109
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.074
# F1 = 0.560 vs. 0.107
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064403
# Train Batch Evaluation
# AUC = 0.910 vs. 0.076
# F1 = 0.893 vs. 0.108
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.069
# F1 = 0.560 vs. 0.102
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064357
# Train Batch Evaluation
# AUC = 0.910 vs. 0.076
# F1 = 0.893 vs. 0.107
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.560 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064311
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.893 vs. 0.109
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.560 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064265
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.893 vs. 0.109
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.068
# F1 = 0.560 vs. 0.091
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064219
# Train Batch Evaluation
# AUC = 0.910 vs. 0.076
# F1 = 0.893 vs. 0.109
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.561 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064174
# Train Batch Evaluation
# AUC = 0.910 vs. 0.078
# F1 = 0.893 vs. 0.110
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.072
# F1 = 0.561 vs. 0.106
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064128
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.893 vs. 0.108
# Accuracy = 0.918 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.561 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064083
# Train Batch Evaluation
# AUC = 0.910 vs. 0.078
# F1 = 0.893 vs. 0.110
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.068
# F1 = 0.561 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.064038
# Train Batch Evaluation
# AUC = 0.910 vs. 0.076
# F1 = 0.893 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.069
# F1 = 0.561 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.063993
# Train Batch Evaluation
# AUC = 0.910 vs. 0.076
# F1 = 0.893 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.561 vs. 0.099
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063948
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.893 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.561 vs. 0.100
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063903
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.894 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.561 vs. 0.100
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063858
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.894 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.077
# F1 = 0.561 vs. 0.111
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063814
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.894 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.068
# F1 = 0.561 vs. 0.094
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063769
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.894 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.070
# F1 = 0.560 vs. 0.105
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063725
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.894 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.072
# F1 = 0.560 vs. 0.101
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063681
# Train Batch Evaluation
# AUC = 0.910 vs. 0.077
# F1 = 0.894 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.067
# F1 = 0.560 vs. 0.092
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063636
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.894 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.560 vs. 0.097
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063592
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.894 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.560 vs. 0.100
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063548
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.894 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.071
# F1 = 0.560 vs. 0.102
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063504
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.894 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.514 vs. 0.069
# F1 = 0.560 vs. 0.108
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063460
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.075
# F1 = 0.560 vs. 0.112
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063416
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.895 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.069
# F1 = 0.560 vs. 0.099
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063372
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.895 vs. 0.106
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.560 vs. 0.099
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063328
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.073
# F1 = 0.560 vs. 0.110
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063284
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.895 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.073
# F1 = 0.560 vs. 0.108
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.063241
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.895 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.560 vs. 0.105
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.063197
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.895 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.073
# F1 = 0.560 vs. 0.112
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.063154
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.069
# F1 = 0.560 vs. 0.103
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.063110
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.069
# F1 = 0.560 vs. 0.099
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.063067
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.560 vs. 0.100
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.063023
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.073
# F1 = 0.560 vs. 0.109
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062980
# Train Batch Evaluation
# AUC = 0.911 vs. 0.076
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.072
# F1 = 0.560 vs. 0.102
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062937
# Train Batch Evaluation
# AUC = 0.911 vs. 0.077
# F1 = 0.895 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.071
# F1 = 0.559 vs. 0.099
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062894
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.895 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.559 vs. 0.099
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062851
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.896 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.069
# F1 = 0.560 vs. 0.099
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062808
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.896 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.071
# F1 = 0.560 vs. 0.104
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062765
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.896 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.560 vs. 0.103
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062723
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.896 vs. 0.110
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.072
# F1 = 0.560 vs. 0.113
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062680
# Train Batch Evaluation
# AUC = 0.912 vs. 0.076
# F1 = 0.896 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.560 vs. 0.094
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062637
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.896 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.071
# F1 = 0.560 vs. 0.106
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062595
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.896 vs. 0.108
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.560 vs. 0.101
# Accuracy = 0.864 vs. 0.056
# Minibatch Loss= 0.062552
# Train Batch Evaluation
# AUC = 0.912 vs. 0.076
# F1 = 0.896 vs. 0.107
# Accuracy = 0.919 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.560 vs. 0.103
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.062510
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.896 vs. 0.109
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.068
# F1 = 0.559 vs. 0.096
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.062468
# Train Batch Evaluation
# AUC = 0.912 vs. 0.076
# F1 = 0.896 vs. 0.109
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.072
# F1 = 0.559 vs. 0.108
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.062425
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.897 vs. 0.109
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.512 vs. 0.070
# F1 = 0.559 vs. 0.097
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.062383
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.897 vs. 0.109
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.075
# F1 = 0.558 vs. 0.105
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.062341
# Train Batch Evaluation
# AUC = 0.912 vs. 0.076
# F1 = 0.897 vs. 0.108
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.070
# F1 = 0.559 vs. 0.104
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.062298
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.897 vs. 0.107
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.071
# F1 = 0.559 vs. 0.107
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.062256
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.897 vs. 0.109
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.074
# F1 = 0.559 vs. 0.111
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.062214
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.897 vs. 0.107
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.069
# F1 = 0.558 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.062172
# Train Batch Evaluation
# AUC = 0.912 vs. 0.077
# F1 = 0.897 vs. 0.108
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.511 vs. 0.072
# F1 = 0.557 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# Minibatch Loss= 0.062130
# Train Batch Evaluation
# AUC = 0.913 vs. 0.077
# F1 = 0.897 vs. 0.107
# Accuracy = 0.920 vs. 0.056
# Validation
# AUC = 0.510 vs. 0.072
# F1 = 0.557 vs. 0.106
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.062088
# Train Batch Evaluation
# ...
# AUC = 0.508 vs. 0.069
# F1 = 0.555 vs. 0.100
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.037099
# Train Batch Evaluation
# AUC = 0.952 vs. 0.077
# F1 = 0.948 vs. 0.108
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.071
# F1 = 0.555 vs. 0.110
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.037070
# Train Batch Evaluation
# AUC = 0.952 vs. 0.077
# F1 = 0.948 vs. 0.108
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.069
# F1 = 0.555 vs. 0.102
# Accuracy = 0.869 vs. 0.056
# Minibatch Loss= 0.037024
# Train Batch Evaluation
# AUC = 0.952 vs. 0.078
# F1 = 0.949 vs. 0.109
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.102
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.036989
# Train Batch Evaluation
# AUC = 0.952 vs. 0.078
# F1 = 0.948 vs. 0.109
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.069
# F1 = 0.555 vs. 0.097
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036946
# Train Batch Evaluation
# AUC = 0.952 vs. 0.076
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.075
# F1 = 0.555 vs. 0.104
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.036908
# Train Batch Evaluation
# AUC = 0.952 vs. 0.076
# F1 = 0.948 vs. 0.109
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.098
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036871
# Train Batch Evaluation
# AUC = 0.952 vs. 0.077
# F1 = 0.949 vs. 0.109
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.069
# F1 = 0.555 vs. 0.098
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.036836
# Train Batch Evaluation
# AUC = 0.952 vs. 0.077
# F1 = 0.949 vs. 0.109
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.093
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036803
# Train Batch Evaluation
# AUC = 0.952 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.100
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036772
# Train Batch Evaluation
# AUC = 0.952 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.104
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036742
# Train Batch Evaluation
# AUC = 0.952 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.105
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036714
# Train Batch Evaluation
# AUC = 0.952 vs. 0.076
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.069
# F1 = 0.555 vs. 0.099
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036686
# Train Batch Evaluation
# AUC = 0.952 vs. 0.076
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.100
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036659
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.073
# F1 = 0.555 vs. 0.112
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036634
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.100
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036610
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.071
# F1 = 0.555 vs. 0.100
# Accuracy = 0.869 vs. 0.056
# Minibatch Loss= 0.036591
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.069
# F1 = 0.555 vs. 0.099
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036573
# Train Batch Evaluation
# AUC = 0.953 vs. 0.076
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.071
# F1 = 0.554 vs. 0.102
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036570
# Train Batch Evaluation
# AUC = 0.953 vs. 0.076
# F1 = 0.949 vs. 0.107
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.071
# F1 = 0.555 vs. 0.101
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036557
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.107
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.071
# F1 = 0.555 vs. 0.108
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036580
# Train Batch Evaluation
# AUC = 0.953 vs. 0.076
# F1 = 0.949 vs. 0.107
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.070
# F1 = 0.555 vs. 0.102
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036558
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.109
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.069
# F1 = 0.555 vs. 0.102
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036598
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.107
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.555 vs. 0.100
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036544
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.071
# F1 = 0.555 vs. 0.104
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036577
# Train Batch Evaluation
# AUC = 0.953 vs. 0.076
# F1 = 0.949 vs. 0.108
# Accuracy = 0.959 vs. 0.056
# Validation
# AUC = 0.503 vs. 0.071
# F1 = 0.555 vs. 0.106
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036486
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.109
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.074
# F1 = 0.555 vs. 0.109
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036484
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.950 vs. 0.109
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.068
# F1 = 0.555 vs. 0.094
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036385
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.949 vs. 0.109
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.070
# F1 = 0.555 vs. 0.097
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036348
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.950 vs. 0.109
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.555 vs. 0.098
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036267
# Train Batch Evaluation
# AUC = 0.953 vs. 0.078
# F1 = 0.950 vs. 0.109
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.070
# F1 = 0.555 vs. 0.106
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.036220
# Train Batch Evaluation
# AUC = 0.953 vs. 0.076
# F1 = 0.950 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.554 vs. 0.102
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036164
# Train Batch Evaluation
# AUC = 0.953 vs. 0.076
# F1 = 0.950 vs. 0.107
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.555 vs. 0.100
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036125
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.950 vs. 0.109
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.071
# F1 = 0.554 vs. 0.105
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036085
# Train Batch Evaluation
# AUC = 0.954 vs. 0.076
# F1 = 0.950 vs. 0.107
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.068
# F1 = 0.555 vs. 0.094
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036051
# Train Batch Evaluation
# AUC = 0.953 vs. 0.077
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.555 vs. 0.096
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036018
# Train Batch Evaluation
# AUC = 0.954 vs. 0.076
# F1 = 0.950 vs. 0.109
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.068
# F1 = 0.555 vs. 0.095
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.035987
# Train Batch Evaluation
# AUC = 0.954 vs. 0.076
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.069
# F1 = 0.555 vs. 0.096
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035958
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.069
# F1 = 0.555 vs. 0.105
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035930
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.109
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.071
# F1 = 0.555 vs. 0.105
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035903
# Train Batch Evaluation
# AUC = 0.954 vs. 0.076
# F1 = 0.950 vs. 0.107
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.072
# F1 = 0.555 vs. 0.109
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.035880
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.503 vs. 0.070
# F1 = 0.555 vs. 0.106
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035860
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.107
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.555 vs. 0.099
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035851
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.072
# F1 = 0.555 vs. 0.109
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.035844
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.507 vs. 0.070
# F1 = 0.555 vs. 0.105
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035875
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.069
# F1 = 0.555 vs. 0.098
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.035885
# Train Batch Evaluation
# AUC = 0.954 vs. 0.076
# F1 = 0.950 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.555 vs. 0.101
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036012
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.109
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.503 vs. 0.073
# F1 = 0.555 vs. 0.106
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.036007
# Train Batch Evaluation
# AUC = 0.954 vs. 0.076
# F1 = 0.951 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.073
# F1 = 0.555 vs. 0.104
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036278
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.950 vs. 0.108
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.071
# F1 = 0.555 vs. 0.105
# Accuracy = 0.869 vs. 0.056
# Minibatch Loss= 0.036113
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.951 vs. 0.109
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.103
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.036349
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.951 vs. 0.109
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.503 vs. 0.070
# F1 = 0.555 vs. 0.098
# Accuracy = 0.869 vs. 0.056
# Minibatch Loss= 0.035967
# Train Batch Evaluation
# AUC = 0.954 vs. 0.076
# F1 = 0.951 vs. 0.108
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.072
# F1 = 0.555 vs. 0.109
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035900
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.072
# F1 = 0.555 vs. 0.104
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035647
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.951 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.503 vs. 0.070
# F1 = 0.555 vs. 0.103
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035534
# Train Batch Evaluation
# AUC = 0.954 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.503 vs. 0.071
# F1 = 0.555 vs. 0.106
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.035452
# Train Batch Evaluation
# AUC = 0.955 vs. 0.078
# F1 = 0.951 vs. 0.111
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.070
# F1 = 0.555 vs. 0.099
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035405
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.071
# F1 = 0.555 vs. 0.105
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035380
# Train Batch Evaluation
# AUC = 0.955 vs. 0.076
# F1 = 0.951 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.071
# F1 = 0.555 vs. 0.104
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035372
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.069
# F1 = 0.555 vs. 0.096
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035387
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.555 vs. 0.102
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035406
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.504 vs. 0.071
# F1 = 0.554 vs. 0.104
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035506
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.109
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.554 vs. 0.102
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035532
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.072
# F1 = 0.554 vs. 0.102
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.035803
# Train Batch Evaluation
# AUC = 0.955 vs. 0.078
# F1 = 0.951 vs. 0.110
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.554 vs. 0.099
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035697
# Train Batch Evaluation
# AUC = 0.955 vs. 0.078
# F1 = 0.951 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.074
# F1 = 0.555 vs. 0.108
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.036053
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.069
# F1 = 0.554 vs. 0.100
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.035651
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.070
# F1 = 0.555 vs. 0.099
# Accuracy = 0.871 vs. 0.056
# Minibatch Loss= 0.035671
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.072
# F1 = 0.554 vs. 0.106
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035299
# Train Batch Evaluation
# AUC = 0.955 vs. 0.078
# F1 = 0.952 vs. 0.110
# Accuracy = 0.963 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.072
# F1 = 0.554 vs. 0.102
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035142
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.963 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.070
# F1 = 0.554 vs. 0.099
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035027
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.951 vs. 0.108
# Accuracy = 0.963 vs. 0.056
# Validation
# AUC = 0.505 vs. 0.068
# F1 = 0.554 vs. 0.100
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.034978
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.952 vs. 0.109
# Accuracy = 0.963 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.074
# F1 = 0.554 vs. 0.116
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.034968
# Train Batch Evaluation
# AUC = 0.955 vs. 0.076
# F1 = 0.951 vs. 0.108
# Accuracy = 0.963 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.072
# F1 = 0.554 vs. 0.109
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.034993
# Train Batch Evaluation
# AUC = 0.956 vs. 0.077
# F1 = 0.952 vs. 0.109
# Accuracy = 0.963 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.071
# F1 = 0.554 vs. 0.099
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.035093
# Train Batch Evaluation
# AUC = 0.955 vs. 0.078
# F1 = 0.952 vs. 0.110
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.070
# F1 = 0.554 vs. 0.099
# Accuracy = 0.870 vs. 0.056
# Minibatch Loss= 0.035163
# Train Batch Evaluation
# AUC = 0.956 vs. 0.077
# F1 = 0.952 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.070
# F1 = 0.554 vs. 0.101
# Accuracy = 0.873 vs. 0.056
# Minibatch Loss= 0.035505
# Train Batch Evaluation
# AUC = 0.955 vs. 0.077
# F1 = 0.952 vs. 0.110
# Accuracy = 0.961 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.073
# F1 = 0.554 vs. 0.103
# Accuracy = 0.868 vs. 0.056
# Minibatch Loss= 0.035393
# Train Batch Evaluation
# AUC = 0.956 vs. 0.077
# F1 = 0.952 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.508 vs. 0.072
# F1 = 0.555 vs. 0.105
# Accuracy = 0.873 vs. 0.056
# Minibatch Loss= 0.035799
# Train Batch Evaluation
# AUC = 0.956 vs. 0.077
# F1 = 0.952 vs. 0.109
# Accuracy = 0.962 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.070
# F1 = 0.554 vs. 0.099
# Accuracy = 0.869 vs. 0.056
# Minibatch Loss= 0.035297
# Train Batch Evaluation
# AUC = 0.956 vs. 0.077
# F1 = 0.952 vs. 0.108
# Accuracy = 0.963 vs. 0.056
# Validation
# AUC = 0.506 vs. 0.071
# F1 = 0.554 vs. 0.108
# Accuracy = 0.872 vs. 0.056

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.537 vs. 0.069
# F1 = 0.586 vs. 0.103
# Accuracy = 0.919 vs. 0.056

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
# Out:
# 1
