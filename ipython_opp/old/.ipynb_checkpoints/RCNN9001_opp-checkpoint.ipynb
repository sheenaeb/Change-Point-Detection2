# %%
# useing this variable for saving models and summaries
exp_name = "RCNN9001_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training
import evaluation.nn_eval_activity as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp6.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((1358, 1024, 77), (1358, 1024, 18))

# %%
test_data.shape, test_gt.shape
# Out:
# ((233, 1024, 77), (233, 1024, 18))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 10

pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 18

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

print s[0]*s[1], (s[0]*s[1]/resolution), (s[0]*s[1]/resolution)*resolution

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)
# Out:
# 1390592 21728 1390592

# %%
pos_weight.shape
# Out:
# (18,)

# %%
pos_weight
# Out:
# array([  0.1575919 ,  33.59872611,  33.82051282,  36.46206897,
#         35.45637584,  26.22807018,  26.78516624,  39.3866171 ,
#         41.27237354,  45.82758621,  50.98086124,  47.71748879,
#         50.24528302,  42.63052209,  43.89256198,  33.16352201,
#         10.44783983,  35.95238095])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables = n_variables,
                        n_classes = n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride = pooling_stride,
                         weights_shape = weights_shape,
                         bias_shape = bias_shape,
                         activation = activation,
                         lstm_n_hidden = lstm_n_hidden,
                         n_classes = n_classes,
                         learning_rate = learning_rate,
                         pos_weight = pos_weight,
                         trainable_conv = True,
                         trainable_last = True)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'activity')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# AUC = 0.126 vs. 0.109
# F1 = 0.195 vs. 0.171
# Accuracy = 0.000 vs. 0.067
# Validation
# AUC = 0.068 vs. 0.069
# F1 = 0.100 vs. 0.101
# Accuracy = 0.002 vs. 0.056
# Minibatch Loss= 1.889159
# Train Batch Evaluation
# AUC = 0.684 vs. 0.124
# F1 = 0.722 vs. 0.190
# Accuracy = 0.406 vs. 0.056
# Validation
# AUC = 0.215 vs. 0.068
# F1 = 0.287 vs. 0.094
# Accuracy = 0.437 vs. 0.056
# Minibatch Loss= 0.640944
# Train Batch Evaluation
# AUC = 0.583 vs. 0.171
# F1 = 0.623 vs. 0.239
# Accuracy = 0.679 vs. 0.111
# Validation
# AUC = 0.418 vs. 0.069
# F1 = 0.471 vs. 0.096
# Accuracy = 0.670 vs. 0.056
# Minibatch Loss= 0.277882
# Train Batch Evaluation
# AUC = 0.658 vs. 0.104
# F1 = 0.669 vs. 0.169
# Accuracy = 0.656 vs. 0.056
# Validation
# AUC = 0.489 vs. 0.067
# F1 = 0.523 vs. 0.092
# Accuracy = 0.520 vs. 0.056
# Minibatch Loss= 0.448409
# Train Batch Evaluation
# AUC = 0.821 vs. 0.124
# F1 = 0.819 vs. 0.177
# Accuracy = 0.764 vs. 0.083
# Validation
# AUC = 0.547 vs. 0.068
# F1 = 0.567 vs. 0.094
# Accuracy = 0.741 vs. 0.056
# Minibatch Loss= 0.195352
# Train Batch Evaluation
# AUC = 0.908 vs. 0.118
# F1 = 0.907 vs. 0.173
# Accuracy = 0.767 vs. 0.062
# Validation
# AUC = 0.561 vs. 0.068
# F1 = 0.581 vs. 0.094
# Accuracy = 0.710 vs. 0.056
# Minibatch Loss= 0.167525
# Train Batch Evaluation
# AUC = 0.927 vs. 0.099
# F1 = 0.907 vs. 0.163
# Accuracy = 0.779 vs. 0.056
# Validation
# AUC = 0.584 vs. 0.068
# F1 = 0.595 vs. 0.093
# Accuracy = 0.799 vs. 0.056
# Minibatch Loss= 0.163727
# Train Batch Evaluation
# AUC = 0.850 vs. 0.160
# F1 = 0.848 vs. 0.235
# Accuracy = 0.765 vs. 0.111
# Validation
# AUC = 0.576 vs. 0.069
# F1 = 0.602 vs. 0.098
# Accuracy = 0.811 vs. 0.056
# Minibatch Loss= 0.162275
# Train Batch Evaluation
# AUC = 0.956 vs. 0.106
# F1 = 0.943 vs. 0.176
# Accuracy = 0.908 vs. 0.056
# Validation
# AUC = 0.622 vs. 0.068
# F1 = 0.634 vs. 0.096
# Accuracy = 0.880 vs. 0.056
# Minibatch Loss= 0.107206
# Train Batch Evaluation
# AUC = 0.900 vs. 0.099
# F1 = 0.902 vs. 0.157
# Accuracy = 0.875 vs. 0.059
# Validation
# AUC = 0.654 vs. 0.069
# F1 = 0.657 vs. 0.094
# Accuracy = 0.851 vs. 0.056
# Minibatch Loss= 0.171607
# Train Batch Evaluation
# AUC = 0.935 vs. 0.116
# F1 = 0.941 vs. 0.181
# Accuracy = 0.630 vs. 0.056
# Validation
# AUC = 0.648 vs. 0.068
# F1 = 0.651 vs. 0.094
# Accuracy = 0.808 vs. 0.056
# Minibatch Loss= 0.190109
# Train Batch Evaluation
# AUC = 0.987 vs. 0.084
# F1 = 0.973 vs. 0.131
# Accuracy = 0.901 vs. 0.056
# Validation
# AUC = 0.676 vs. 0.069
# F1 = 0.660 vs. 0.103
# Accuracy = 0.847 vs. 0.056
# Minibatch Loss= 0.068987
# Train Batch Evaluation
# AUC = 0.990 vs. 0.115
# F1 = 0.979 vs. 0.165
# Accuracy = 0.886 vs. 0.077
# Validation
# AUC = 0.661 vs. 0.068
# F1 = 0.655 vs. 0.092
# Accuracy = 0.835 vs. 0.056
# Minibatch Loss= 0.072485
# Train Batch Evaluation
# AUC = 0.976 vs. 0.099
# F1 = 0.956 vs. 0.155
# Accuracy = 0.877 vs. 0.056
# Validation
# AUC = 0.665 vs. 0.068
# F1 = 0.661 vs. 0.100
# Accuracy = 0.865 vs. 0.056
# Minibatch Loss= 0.086182
# Train Batch Evaluation
# AUC = 0.951 vs. 0.090
# F1 = 0.958 vs. 0.156
# Accuracy = 0.982 vs. 0.056
# Validation
# AUC = 0.677 vs. 0.069
# F1 = 0.675 vs. 0.092
# Accuracy = 0.884 vs. 0.056
# Minibatch Loss= 0.060898
# Train Batch Evaluation
# AUC = 0.989 vs. 0.120
# F1 = 0.980 vs. 0.187
# Accuracy = 0.962 vs. 0.077
# Validation
# AUC = 0.653 vs. 0.068
# F1 = 0.659 vs. 0.091
# Accuracy = 0.908 vs. 0.056
# Minibatch Loss= 0.045265
# Train Batch Evaluation
# AUC = 0.993 vs. 0.099
# F1 = 0.982 vs. 0.171
# Accuracy = 0.943 vs. 0.056
# Validation
# AUC = 0.703 vs. 0.068
# F1 = 0.681 vs. 0.096
# Accuracy = 0.895 vs. 0.056
# Minibatch Loss= 0.044465
# Train Batch Evaluation
# AUC = 0.942 vs. 0.117
# F1 = 0.948 vs. 0.182
# Accuracy = 0.949 vs. 0.077
# Validation
# AUC = 0.702 vs. 0.068
# F1 = 0.680 vs. 0.093
# Accuracy = 0.872 vs. 0.056
# Minibatch Loss= 0.061497
# Train Batch Evaluation
# AUC = 0.973 vs. 0.154
# F1 = 0.960 vs. 0.245
# Accuracy = 0.910 vs. 0.056
# Validation
# AUC = 0.698 vs. 0.069
# F1 = 0.680 vs. 0.096
# Accuracy = 0.863 vs. 0.056
# Minibatch Loss= 0.086216
# Train Batch Evaluation
# AUC = 0.928 vs. 0.123
# F1 = 0.916 vs. 0.204
# Accuracy = 0.806 vs. 0.059
# Validation
# AUC = 0.674 vs. 0.068
# F1 = 0.675 vs. 0.096
# Accuracy = 0.865 vs. 0.056
# Minibatch Loss= 0.133317
# Train Batch Evaluation
# AUC = 0.968 vs. 0.098
# F1 = 0.951 vs. 0.149
# Accuracy = 0.930 vs. 0.059
# Validation
# AUC = 0.684 vs. 0.068
# F1 = 0.686 vs. 0.096
# Accuracy = 0.826 vs. 0.056
# Minibatch Loss= 0.072280
# Train Batch Evaluation
# AUC = 0.941 vs. 0.097
# F1 = 0.947 vs. 0.139
# Accuracy = 0.877 vs. 0.071
# Validation
# AUC = 0.677 vs. 0.068
# F1 = 0.678 vs. 0.092
# Accuracy = 0.887 vs. 0.056
# Minibatch Loss= 0.053865
# Train Batch Evaluation
# AUC = 0.983 vs. 0.094
# F1 = 0.968 vs. 0.154
# Accuracy = 0.946 vs. 0.056
# Validation
# AUC = 0.715 vs. 0.067
# F1 = 0.706 vs. 0.092
# Accuracy = 0.928 vs. 0.056
# Minibatch Loss= 0.065950
# Train Batch Evaluation
# AUC = 0.990 vs. 0.124
# F1 = 0.992 vs. 0.189
# Accuracy = 0.916 vs. 0.091
# Validation
# AUC = 0.710 vs. 0.068
# F1 = 0.701 vs. 0.095
# Accuracy = 0.847 vs. 0.056
# Minibatch Loss= 0.030056
# Train Batch Evaluation
# AUC = 0.977 vs. 0.124
# F1 = 0.985 vs. 0.219
# Accuracy = 0.943 vs. 0.056
# Validation
# AUC = 0.720 vs. 0.068
# F1 = 0.704 vs. 0.093
# Accuracy = 0.903 vs. 0.056
# Minibatch Loss= 0.039157
# Train Batch Evaluation
# AUC = 0.985 vs. 0.099
# F1 = 0.982 vs. 0.159
# Accuracy = 0.981 vs. 0.056
# Validation
# AUC = 0.710 vs. 0.069
# F1 = 0.700 vs. 0.098
# Accuracy = 0.915 vs. 0.056
# Minibatch Loss= 0.037047
# Train Batch Evaluation
# AUC = 0.977 vs. 0.106
# F1 = 0.964 vs. 0.169
# Accuracy = 0.956 vs. 0.056
# Validation
# AUC = 0.718 vs. 0.069
# F1 = 0.700 vs. 0.094
# Accuracy = 0.874 vs. 0.056
# Minibatch Loss= 0.074755
# Train Batch Evaluation
# AUC = 0.968 vs. 0.112
# F1 = 0.970 vs. 0.173
# Accuracy = 0.960 vs. 0.056
# Validation
# AUC = 0.704 vs. 0.069
# F1 = 0.695 vs. 0.099
# Accuracy = 0.931 vs. 0.056
# Minibatch Loss= 0.042064
# Train Batch Evaluation
# AUC = 0.998 vs. 0.141
# F1 = 0.992 vs. 0.225
# Accuracy = 0.989 vs. 0.062
# Validation
# AUC = 0.722 vs. 0.069
# F1 = 0.709 vs. 0.097
# Accuracy = 0.940 vs. 0.056
# Minibatch Loss= 0.036762
# Train Batch Evaluation
# AUC = 0.985 vs. 0.101
# F1 = 0.975 vs. 0.166
# Accuracy = 0.956 vs. 0.056
# Validation
# AUC = 0.723 vs. 0.067
# F1 = 0.715 vs. 0.092
# Accuracy = 0.897 vs. 0.056
# Minibatch Loss= 0.048008
# Train Batch Evaluation
# AUC = 0.920 vs. 0.101
# F1 = 0.937 vs. 0.146
# Accuracy = 0.910 vs. 0.071
# Validation
# AUC = 0.682 vs. 0.067
# F1 = 0.692 vs. 0.095
# Accuracy = 0.886 vs. 0.056
# Minibatch Loss= 0.066595
# Train Batch Evaluation
# AUC = 0.993 vs. 0.115
# F1 = 0.984 vs. 0.201
# Accuracy = 0.926 vs. 0.056
# Validation
# AUC = 0.701 vs. 0.066
# F1 = 0.698 vs. 0.090
# Accuracy = 0.915 vs. 0.056
# Minibatch Loss= 0.061615
# Train Batch Evaluation
# AUC = 0.998 vs. 0.088
# F1 = 0.991 vs. 0.145
# Accuracy = 0.982 vs. 0.056
# Validation
# AUC = 0.738 vs. 0.067
# F1 = 0.719 vs. 0.091
# Accuracy = 0.925 vs. 0.056
# Minibatch Loss= 0.032850
# Train Batch Evaluation
# AUC = 0.987 vs. 0.104
# F1 = 0.985 vs. 0.179
# Accuracy = 0.972 vs. 0.056
# Validation
# AUC = 0.726 vs. 0.068
# F1 = 0.705 vs. 0.092
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.026592
# Train Batch Evaluation
# AUC = 0.996 vs. 0.127
# F1 = 0.991 vs. 0.194
# Accuracy = 0.944 vs. 0.056
# Validation
# AUC = 0.722 vs. 0.067
# F1 = 0.715 vs. 0.095
# Accuracy = 0.906 vs. 0.056
# Minibatch Loss= 0.029081
# Train Batch Evaluation
# AUC = 0.993 vs. 0.131
# F1 = 0.988 vs. 0.209
# Accuracy = 0.949 vs. 0.056
# Validation
# AUC = 0.738 vs. 0.068
# F1 = 0.718 vs. 0.093
# Accuracy = 0.933 vs. 0.056
# Minibatch Loss= 0.035226
# Train Batch Evaluation
# AUC = 0.997 vs. 0.111
# F1 = 0.992 vs. 0.201
# Accuracy = 0.976 vs. 0.056
# Validation
# AUC = 0.732 vs. 0.068
# F1 = 0.717 vs. 0.099
# Accuracy = 0.897 vs. 0.056
# Minibatch Loss= 0.020253
# Train Batch Evaluation
# AUC = 1.000 vs. 0.119
# F1 = 0.998 vs. 0.183
# Accuracy = 0.989 vs. 0.059
# Validation
# AUC = 0.733 vs. 0.069
# F1 = 0.714 vs. 0.098
# Accuracy = 0.938 vs. 0.056
# Minibatch Loss= 0.012506
# Train Batch Evaluation
# AUC = 0.999 vs. 0.132
# F1 = 0.997 vs. 0.230
# Accuracy = 0.989 vs. 0.062
# Validation
# AUC = 0.729 vs. 0.068
# F1 = 0.719 vs. 0.091
# Accuracy = 0.935 vs. 0.056
# Minibatch Loss= 0.013027
# Train Batch Evaluation
# AUC = 0.955 vs. 0.109
# F1 = 0.966 vs. 0.152
# Accuracy = 0.992 vs. 0.067
# Validation
# AUC = 0.730 vs. 0.071
# F1 = 0.707 vs. 0.097
# Accuracy = 0.930 vs. 0.056
# Minibatch Loss= 0.013612
# Train Batch Evaluation
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.149
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.729 vs. 0.068
# F1 = 0.717 vs. 0.095
# Accuracy = 0.940 vs. 0.056
# Minibatch Loss= 0.004454
# Train Batch Evaluation
# AUC = 1.000 vs. 0.110
# F1 = 0.999 vs. 0.181
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.726 vs. 0.068
# F1 = 0.712 vs. 0.095
# Accuracy = 0.943 vs. 0.056
# Minibatch Loss= 0.010502
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 0.999 vs. 0.183
# Accuracy = 0.981 vs. 0.062
# Validation
# AUC = 0.725 vs. 0.067
# F1 = 0.713 vs. 0.092
# Accuracy = 0.939 vs. 0.056
# Minibatch Loss= 0.014729
# Train Batch Evaluation
# AUC = 0.998 vs. 0.137
# F1 = 0.992 vs. 0.196
# Accuracy = 0.977 vs. 0.100
# Validation
# AUC = 0.730 vs. 0.070
# F1 = 0.720 vs. 0.100
# Accuracy = 0.951 vs. 0.056
# Minibatch Loss= 0.021011
# Train Batch Evaluation
# AUC = 1.000 vs. 0.100
# F1 = 0.998 vs. 0.176
# Accuracy = 0.982 vs. 0.056
# Validation
# AUC = 0.716 vs. 0.068
# F1 = 0.707 vs. 0.092
# Accuracy = 0.923 vs. 0.056
# Minibatch Loss= 0.008575
# Train Batch Evaluation
# AUC = 1.000 vs. 0.133
# F1 = 0.998 vs. 0.209
# Accuracy = 0.992 vs. 0.071
# Validation
# AUC = 0.725 vs. 0.067
# F1 = 0.709 vs. 0.094
# Accuracy = 0.944 vs. 0.056
# Minibatch Loss= 0.005911
# Train Batch Evaluation
# AUC = 0.995 vs. 0.124
# F1 = 0.990 vs. 0.189
# Accuracy = 0.978 vs. 0.056
# Validation
# AUC = 0.714 vs. 0.071
# F1 = 0.699 vs. 0.103
# Accuracy = 0.944 vs. 0.056
# Minibatch Loss= 0.030501
# Train Batch Evaluation
# AUC = 0.906 vs. 0.121
# F1 = 0.880 vs. 0.180
# Accuracy = 0.760 vs. 0.071
# Validation
# AUC = 0.632 vs. 0.068
# F1 = 0.641 vs. 0.093
# Accuracy = 0.768 vs. 0.056
# Minibatch Loss= 0.161538
# Train Batch Evaluation
# AUC = 0.979 vs. 0.142
# F1 = 0.966 vs. 0.229
# Accuracy = 0.961 vs. 0.067
# Validation
# AUC = 0.683 vs. 0.069
# F1 = 0.679 vs. 0.096
# Accuracy = 0.910 vs. 0.056
# Minibatch Loss= 0.108761
# Train Batch Evaluation
# AUC = 0.940 vs. 0.107
# F1 = 0.956 vs. 0.181
# Accuracy = 0.857 vs. 0.059
# Validation
# AUC = 0.644 vs. 0.069
# F1 = 0.647 vs. 0.094
# Accuracy = 0.838 vs. 0.056
# Minibatch Loss= 0.099782
# Train Batch Evaluation
# AUC = 0.968 vs. 0.105
# F1 = 0.964 vs. 0.172
# Accuracy = 0.944 vs. 0.056
# Validation
# AUC = 0.720 vs. 0.068
# F1 = 0.707 vs. 0.092
# Accuracy = 0.920 vs. 0.056
# Minibatch Loss= 0.068286
# Train Batch Evaluation
# AUC = 0.987 vs. 0.120
# F1 = 0.977 vs. 0.173
# Accuracy = 0.962 vs. 0.077
# Validation
# AUC = 0.731 vs. 0.070
# F1 = 0.714 vs. 0.093
# Accuracy = 0.937 vs. 0.056
# Minibatch Loss= 0.027331
# Train Batch Evaluation
# AUC = 1.000 vs. 0.113
# F1 = 0.997 vs. 0.171
# Accuracy = 0.991 vs. 0.062
# Validation
# AUC = 0.748 vs. 0.069
# F1 = 0.720 vs. 0.094
# Accuracy = 0.947 vs. 0.056
# Minibatch Loss= 0.023205
# Train Batch Evaluation
# AUC = 0.991 vs. 0.104
# F1 = 0.989 vs. 0.166
# Accuracy = 0.981 vs. 0.067
# Validation
# AUC = 0.749 vs. 0.069
# F1 = 0.719 vs. 0.098
# Accuracy = 0.921 vs. 0.056
# Minibatch Loss= 0.023718
# Train Batch Evaluation
# AUC = 1.000 vs. 0.087
# F1 = 0.999 vs. 0.145
# Accuracy = 0.980 vs. 0.056
# Validation
# AUC = 0.744 vs. 0.068
# F1 = 0.712 vs. 0.095
# Accuracy = 0.934 vs. 0.056
# Minibatch Loss= 0.017603
# Train Batch Evaluation
# AUC = 0.988 vs. 0.102
# F1 = 0.991 vs. 0.172
# Accuracy = 0.979 vs. 0.056
# Validation
# AUC = 0.747 vs. 0.069
# F1 = 0.718 vs. 0.094
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.017769
# Train Batch Evaluation
# AUC = 1.000 vs. 0.084
# F1 = 1.000 vs. 0.134
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.745 vs. 0.068
# F1 = 0.714 vs. 0.095
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.007209
# Train Batch Evaluation
# AUC = 0.995 vs. 0.102
# F1 = 0.991 vs. 0.166
# Accuracy = 0.979 vs. 0.062
# Validation
# AUC = 0.748 vs. 0.068
# F1 = 0.720 vs. 0.093
# Accuracy = 0.950 vs. 0.056
# Minibatch Loss= 0.017473
# Train Batch Evaluation
# AUC = 1.000 vs. 0.088
# F1 = 0.997 vs. 0.139
# Accuracy = 0.982 vs. 0.062
# Validation
# AUC = 0.747 vs. 0.068
# F1 = 0.719 vs. 0.093
# Accuracy = 0.946 vs. 0.056
# Minibatch Loss= 0.012932
# Train Batch Evaluation
# AUC = 1.000 vs. 0.115
# F1 = 1.000 vs. 0.188
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.744 vs. 0.068
# F1 = 0.723 vs. 0.092
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.004768
# Train Batch Evaluation
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.155
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.746 vs. 0.070
# F1 = 0.721 vs. 0.095
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.005587
# Train Batch Evaluation
# AUC = 1.000 vs. 0.105
# F1 = 0.999 vs. 0.157
# Accuracy = 0.991 vs. 0.059
# Validation
# AUC = 0.746 vs. 0.071
# F1 = 0.719 vs. 0.096
# Accuracy = 0.938 vs. 0.056
# Minibatch Loss= 0.010638
# Train Batch Evaluation
# AUC = 1.000 vs. 0.095
# F1 = 0.999 vs. 0.144
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.748 vs. 0.068
# F1 = 0.727 vs. 0.093
# Accuracy = 0.947 vs. 0.056
# Minibatch Loss= 0.002745
# Train Batch Evaluation
# AUC = 1.000 vs. 0.104
# F1 = 0.999 vs. 0.167
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.744 vs. 0.068
# F1 = 0.722 vs. 0.094
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.007190
# Train Batch Evaluation
# AUC = 0.998 vs. 0.093
# F1 = 0.996 vs. 0.161
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.741 vs. 0.068
# F1 = 0.720 vs. 0.095
# Accuracy = 0.951 vs. 0.056
# Minibatch Loss= 0.011140
# Train Batch Evaluation
# AUC = 1.000 vs. 0.091
# F1 = 0.999 vs. 0.139
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.737 vs. 0.069
# F1 = 0.719 vs. 0.096
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.005372
# Train Batch Evaluation
# AUC = 1.000 vs. 0.086
# F1 = 0.999 vs. 0.142
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.736 vs. 0.068
# F1 = 0.716 vs. 0.097
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.002432
# Train Batch Evaluation
# AUC = 1.000 vs. 0.104
# F1 = 0.999 vs. 0.172
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.738 vs. 0.067
# F1 = 0.720 vs. 0.092
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.004606
# Train Batch Evaluation
# AUC = 1.000 vs. 0.090
# F1 = 0.997 vs. 0.149
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.741 vs. 0.069
# F1 = 0.717 vs. 0.097
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.004840
# Train Batch Evaluation
# AUC = 1.000 vs. 0.099
# F1 = 0.999 vs. 0.169
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.736 vs. 0.069
# F1 = 0.719 vs. 0.096
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.005011
# Train Batch Evaluation
# AUC = 1.000 vs. 0.109
# F1 = 0.998 vs. 0.187
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.742 vs. 0.069
# F1 = 0.724 vs. 0.100
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.004081
# Train Batch Evaluation
# AUC = 1.000 vs. 0.094
# F1 = 0.999 vs. 0.162
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.736 vs. 0.068
# F1 = 0.721 vs. 0.093
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.004445
# Train Batch Evaluation
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.125
# Accuracy = 1.000 vs. 0.077
# Validation
# AUC = 0.742 vs. 0.068
# F1 = 0.726 vs. 0.093
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.001559
# Train Batch Evaluation
# AUC = 1.000 vs. 0.134
# F1 = 1.000 vs. 0.188
# Accuracy = 1.000 vs. 0.111
# Validation
# AUC = 0.738 vs. 0.070
# F1 = 0.726 vs. 0.096
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.000794
# Train Batch Evaluation
# AUC = 1.000 vs. 0.120
# F1 = 0.999 vs. 0.172
# Accuracy = 1.000 vs. 0.083
# Validation
# AUC = 0.739 vs. 0.068
# F1 = 0.724 vs. 0.095
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.002741
# Train Batch Evaluation
# AUC = 1.000 vs. 0.108
# F1 = 1.000 vs. 0.179
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.737 vs. 0.068
# F1 = 0.726 vs. 0.094
# Accuracy = 0.961 vs. 0.056
# Minibatch Loss= 0.003517
# Train Batch Evaluation
# AUC = 1.000 vs. 0.111
# F1 = 0.998 vs. 0.175
# Accuracy = 0.990 vs. 0.056
# Validation
# AUC = 0.741 vs. 0.067
# F1 = 0.729 vs. 0.091
# Accuracy = 0.960 vs. 0.056
# Minibatch Loss= 0.003156
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 0.999 vs. 0.187
# Accuracy = 1.000 vs. 0.071
# Validation
# AUC = 0.740 vs. 0.067
# F1 = 0.721 vs. 0.090
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.003890
# Train Batch Evaluation
# AUC = 1.000 vs. 0.148
# F1 = 1.000 vs. 0.222
# Accuracy = 1.000 vs. 0.077
# Validation
# AUC = 0.745 vs. 0.068
# F1 = 0.730 vs. 0.093
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.003215
# Train Batch Evaluation
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.148
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.739 vs. 0.070
# F1 = 0.720 vs. 0.096
# Accuracy = 0.960 vs. 0.056
# Minibatch Loss= 0.002099
# Train Batch Evaluation
# AUC = 1.000 vs. 0.096
# F1 = 1.000 vs. 0.142
# Accuracy = 1.000 vs. 0.071
# Validation
# AUC = 0.740 vs. 0.069
# F1 = 0.724 vs. 0.099
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.002100
# Train Batch Evaluation
# AUC = 1.000 vs. 0.125
# F1 = 0.999 vs. 0.214
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.740 vs. 0.068
# F1 = 0.724 vs. 0.093
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.004887
# Train Batch Evaluation
# AUC = 1.000 vs. 0.110
# F1 = 1.000 vs. 0.174
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.738 vs. 0.069
# F1 = 0.721 vs. 0.097
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.001506
# Train Batch Evaluation
# AUC = 1.000 vs. 0.118
# F1 = 1.000 vs. 0.192
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.742 vs. 0.068
# F1 = 0.726 vs. 0.095
# Accuracy = 0.961 vs. 0.056
# Minibatch Loss= 0.001393
# Train Batch Evaluation
# AUC = 1.000 vs. 0.104
# F1 = 0.999 vs. 0.170
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.739 vs. 0.068
# F1 = 0.723 vs. 0.093
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.001629
# Train Batch Evaluation
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.159
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.742 vs. 0.069
# F1 = 0.724 vs. 0.096
# Accuracy = 0.961 vs. 0.056
# Minibatch Loss= 0.001049
# Train Batch Evaluation
# AUC = 1.000 vs. 0.108
# F1 = 1.000 vs. 0.171
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.740 vs. 0.069
# F1 = 0.723 vs. 0.098
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.002074
# Train Batch Evaluation
# AUC = 1.000 vs. 0.128
# F1 = 1.000 vs. 0.194
# Accuracy = 1.000 vs. 0.071
# Validation
# AUC = 0.745 vs. 0.068
# F1 = 0.724 vs. 0.096
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.001461
# Train Batch Evaluation
# AUC = 1.000 vs. 0.124
# F1 = 0.999 vs. 0.189
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.742 vs. 0.069
# F1 = 0.728 vs. 0.093
# Accuracy = 0.960 vs. 0.056
# Minibatch Loss= 0.002106
# Train Batch Evaluation
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.153
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.740 vs. 0.068
# F1 = 0.724 vs. 0.095
# Accuracy = 0.963 vs. 0.056
# Minibatch Loss= 0.001035
# Train Batch Evaluation
# AUC = 1.000 vs. 0.101
# F1 = 1.000 vs. 0.167
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.744 vs. 0.069
# F1 = 0.724 vs. 0.095
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.001443
# Train Batch Evaluation
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.143
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.743 vs. 0.069
# F1 = 0.723 vs. 0.096
# Accuracy = 0.961 vs. 0.056
# Minibatch Loss= 0.000859
# Train Batch Evaluation
# AUC = 0.890 vs. 0.098
# F1 = 0.888 vs. 0.151
# Accuracy = 0.926 vs. 0.062
# Validation
# AUC = 0.507 vs. 0.068
# F1 = 0.534 vs. 0.094
# Accuracy = 0.804 vs. 0.056
# Minibatch Loss= 0.326269
# Train Batch Evaluation
# AUC = 0.897 vs. 0.094
# F1 = 0.895 vs. 0.142
# Accuracy = 0.929 vs. 0.056
# Validation
# AUC = 0.699 vs. 0.068
# F1 = 0.677 vs. 0.096
# Accuracy = 0.873 vs. 0.056
# Minibatch Loss= 0.150151
# Train Batch Evaluation
# AUC = 0.994 vs. 0.099
# F1 = 0.981 vs. 0.163
# Accuracy = 0.972 vs. 0.056
# Validation
# AUC = 0.725 vs. 0.072
# F1 = 0.704 vs. 0.101
# Accuracy = 0.914 vs. 0.056
# Minibatch Loss= 0.057921
# Train Batch Evaluation
# AUC = 0.990 vs. 0.104
# F1 = 0.976 vs. 0.185
# Accuracy = 0.959 vs. 0.059
# Validation
# AUC = 0.731 vs. 0.068
# F1 = 0.706 vs. 0.097
# Accuracy = 0.903 vs. 0.056
# Minibatch Loss= 0.037804
# Train Batch Evaluation
# AUC = 0.999 vs. 0.120
# F1 = 0.994 vs. 0.203
# Accuracy = 0.967 vs. 0.056
# Validation
# AUC = 0.738 vs. 0.068
# F1 = 0.724 vs. 0.092
# Accuracy = 0.938 vs. 0.056
# Minibatch Loss= 0.025897
# Train Batch Evaluation
# AUC = 1.000 vs. 0.156
# F1 = 1.000 vs. 0.189
# Accuracy = 0.993 vs. 0.111
# Validation
# AUC = 0.739 vs. 0.068
# F1 = 0.725 vs. 0.097
# Accuracy = 0.953 vs. 0.056
# Minibatch Loss= 0.007788
# Train Batch Evaluation
# AUC = 1.000 vs. 0.142
# F1 = 1.000 vs. 0.196
# Accuracy = 0.963 vs. 0.100
# Validation
# AUC = 0.735 vs. 0.069
# F1 = 0.725 vs. 0.095
# Accuracy = 0.934 vs. 0.056
# Minibatch Loss= 0.007343
# Train Batch Evaluation
# AUC = 1.000 vs. 0.095
# F1 = 0.996 vs. 0.160
# Accuracy = 0.967 vs. 0.059
# Validation
# AUC = 0.743 vs. 0.070
# F1 = 0.732 vs. 0.101
# Accuracy = 0.940 vs. 0.056
# Minibatch Loss= 0.013301
# Train Batch Evaluation
# AUC = 1.000 vs. 0.134
# F1 = 0.998 vs. 0.230
# Accuracy = 0.988 vs. 0.059
# Validation
# AUC = 0.739 vs. 0.069
# F1 = 0.731 vs. 0.096
# Accuracy = 0.948 vs. 0.056
# Minibatch Loss= 0.012866
# Train Batch Evaluation
# AUC = 1.000 vs. 0.093
# F1 = 0.999 vs. 0.134
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.743 vs. 0.069
# F1 = 0.730 vs. 0.095
# Accuracy = 0.944 vs. 0.056
# Minibatch Loss= 0.006298
# Train Batch Evaluation
# AUC = 1.000 vs. 0.111
# F1 = 0.999 vs. 0.186
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.743 vs. 0.067
# F1 = 0.734 vs. 0.091
# Accuracy = 0.953 vs. 0.056
# Minibatch Loss= 0.008194
# Train Batch Evaluation
# AUC = 1.000 vs. 0.173
# F1 = 0.999 vs. 0.226
# Accuracy = 0.993 vs. 0.143
# Validation
# AUC = 0.742 vs. 0.068
# F1 = 0.727 vs. 0.095
# Accuracy = 0.948 vs. 0.056
# Minibatch Loss= 0.002911
# Train Batch Evaluation
# AUC = 0.997 vs. 0.098
# F1 = 0.993 vs. 0.164
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.742 vs. 0.069
# F1 = 0.728 vs. 0.096
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.008140
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 0.998 vs. 0.180
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.740 vs. 0.067
# F1 = 0.732 vs. 0.093
# Accuracy = 0.950 vs. 0.056
# Minibatch Loss= 0.004435
# Train Batch Evaluation
# AUC = 1.000 vs. 0.094
# F1 = 0.999 vs. 0.155
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.742 vs. 0.068
# F1 = 0.729 vs. 0.095
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.003593
# Train Batch Evaluation
# AUC = 1.000 vs. 0.125
# F1 = 0.999 vs. 0.188
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.743 vs. 0.068
# F1 = 0.733 vs. 0.091
# Accuracy = 0.940 vs. 0.056
# Minibatch Loss= 0.010318
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 0.999 vs. 0.180
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.730 vs. 0.069
# F1 = 0.726 vs. 0.093
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.004087
# Train Batch Evaluation
# AUC = 1.000 vs. 0.129
# F1 = 0.999 vs. 0.199
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.741 vs. 0.069
# F1 = 0.723 vs. 0.099
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.004856
# Train Batch Evaluation
# AUC = 1.000 vs. 0.086
# F1 = 0.999 vs. 0.145
# Accuracy = 0.991 vs. 0.056
# Validation
# AUC = 0.742 vs. 0.070
# F1 = 0.724 vs. 0.097
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.006068
# Train Batch Evaluation
# AUC = 1.000 vs. 0.111
# F1 = 0.999 vs. 0.184
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.741 vs. 0.069
# F1 = 0.728 vs. 0.093
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.003271
# Train Batch Evaluation
# AUC = 1.000 vs. 0.121
# F1 = 0.999 vs. 0.198
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.740 vs. 0.068
# F1 = 0.727 vs. 0.094
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.002564
# Train Batch Evaluation
# AUC = 1.000 vs. 0.112
# F1 = 1.000 vs. 0.170
# Accuracy = 1.000 vs. 0.077
# Validation
# AUC = 0.736 vs. 0.068
# F1 = 0.728 vs. 0.091
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.000973
# Train Batch Evaluation
# AUC = 1.000 vs. 0.135
# F1 = 1.000 vs. 0.201
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.737 vs. 0.070
# F1 = 0.725 vs. 0.098
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.001751
# Train Batch Evaluation
# AUC = 1.000 vs. 0.140
# F1 = 0.999 vs. 0.216
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.736 vs. 0.067
# F1 = 0.725 vs. 0.097
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.002393
# Train Batch Evaluation
# AUC = 1.000 vs. 0.128
# F1 = 1.000 vs. 0.204
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.740 vs. 0.070
# F1 = 0.730 vs. 0.095
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.001925
# Train Batch Evaluation
# AUC = 1.000 vs. 0.120
# F1 = 1.000 vs. 0.193
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.739 vs. 0.068
# F1 = 0.724 vs. 0.093
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.001980
# Train Batch Evaluation
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.147
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.739 vs. 0.071
# F1 = 0.723 vs. 0.101
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.001380
# Train Batch Evaluation
# AUC = 1.000 vs. 0.115
# F1 = 1.000 vs. 0.174
# Accuracy = 1.000 vs. 0.077
# Validation
# AUC = 0.739 vs. 0.069
# F1 = 0.730 vs. 0.094
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.001127
# Train Batch Evaluation
# AUC = 1.000 vs. 0.114
# F1 = 1.000 vs. 0.187
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.737 vs. 0.068
# F1 = 0.724 vs. 0.096
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.002020
# Train Batch Evaluation
# AUC = 1.000 vs. 0.110
# F1 = 1.000 vs. 0.165
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.738 vs. 0.068
# F1 = 0.726 vs. 0.095
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.001376
# Train Batch Evaluation
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.160
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.737 vs. 0.068
# F1 = 0.725 vs. 0.094
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.001228
# Train Batch Evaluation
# AUC = 1.000 vs. 0.139
# F1 = 1.000 vs. 0.210
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.736 vs. 0.069
# F1 = 0.724 vs. 0.095
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.001188
# Train Batch Evaluation
# AUC = 1.000 vs. 0.115
# F1 = 1.000 vs. 0.178
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.737 vs. 0.068
# F1 = 0.723 vs. 0.097
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.001498
# Train Batch Evaluation
# AUC = 1.000 vs. 0.099
# F1 = 1.000 vs. 0.159
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.737 vs. 0.068
# F1 = 0.721 vs. 0.094
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.002314
# Train Batch Evaluation
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.146
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.730 vs. 0.070
# F1 = 0.721 vs. 0.098
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.001700
# Train Batch Evaluation
# AUC = 1.000 vs. 0.090
# F1 = 0.999 vs. 0.122
# Accuracy = 1.000 vs. 0.071
# Validation
# AUC = 0.729 vs. 0.069
# F1 = 0.711 vs. 0.097
# Accuracy = 0.946 vs. 0.056
# Minibatch Loss= 0.010691
# Train Batch Evaluation
# AUC = 0.921 vs. 0.099
# F1 = 0.907 vs. 0.150
# Accuracy = 0.904 vs. 0.059
# Validation
# AUC = 0.600 vs. 0.069
# F1 = 0.621 vs. 0.096
# Accuracy = 0.818 vs. 0.056
# Minibatch Loss= 0.128992
# Train Batch Evaluation
# AUC = 1.000 vs. 0.114
# F1 = 0.998 vs. 0.172
# Accuracy = 0.976 vs. 0.083
# Validation
# AUC = 0.658 vs. 0.067
# F1 = 0.655 vs. 0.091
# Accuracy = 0.915 vs. 0.056
# Minibatch Loss= 0.027731
# Train Batch Evaluation
# AUC = 0.986 vs. 0.130
# F1 = 0.966 vs. 0.202
# Accuracy = 0.898 vs. 0.067
# Validation
# AUC = 0.695 vs. 0.069
# F1 = 0.694 vs. 0.100
# Accuracy = 0.928 vs. 0.056
# Minibatch Loss= 0.073938
# Train Batch Evaluation
# AUC = 0.994 vs. 0.108
# F1 = 0.993 vs. 0.166
# Accuracy = 0.972 vs. 0.056
# Validation
# AUC = 0.694 vs. 0.067
# F1 = 0.691 vs. 0.090
# Accuracy = 0.894 vs. 0.056
# Minibatch Loss= 0.020754
# Train Batch Evaluation
# AUC = 0.995 vs. 0.125
# F1 = 0.992 vs. 0.208
# Accuracy = 0.981 vs. 0.067
# Validation
# AUC = 0.728 vs. 0.068
# F1 = 0.712 vs. 0.091
# Accuracy = 0.942 vs. 0.056
# Minibatch Loss= 0.024720
# Train Batch Evaluation
# AUC = 1.000 vs. 0.104
# F1 = 0.999 vs. 0.172
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.727 vs. 0.068
# F1 = 0.712 vs. 0.095
# Accuracy = 0.944 vs. 0.056
# Minibatch Loss= 0.009948
# Train Batch Evaluation
# AUC = 0.998 vs. 0.101
# F1 = 0.993 vs. 0.163
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.728 vs. 0.068
# F1 = 0.710 vs. 0.096
# Accuracy = 0.944 vs. 0.056
# Minibatch Loss= 0.014590
# Train Batch Evaluation
# AUC = 1.000 vs. 0.107
# F1 = 0.998 vs. 0.184
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.726 vs. 0.069
# F1 = 0.713 vs. 0.099
# Accuracy = 0.946 vs. 0.056
# Minibatch Loss= 0.007685
# Train Batch Evaluation
# AUC = 1.000 vs. 0.118
# F1 = 0.999 vs. 0.190
# Accuracy = 1.000 vs. 0.077
# Validation
# AUC = 0.723 vs. 0.070
# F1 = 0.710 vs. 0.099
# Accuracy = 0.947 vs. 0.056
# Minibatch Loss= 0.006522
# Train Batch Evaluation
# AUC = 1.000 vs. 0.121
# F1 = 0.998 vs. 0.212
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.723 vs. 0.069
# F1 = 0.710 vs. 0.096
# Accuracy = 0.950 vs. 0.056
# Minibatch Loss= 0.012811
# Train Batch Evaluation
# AUC = 1.000 vs. 0.125
# F1 = 0.998 vs. 0.198
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.722 vs. 0.068
# F1 = 0.707 vs. 0.095
# Accuracy = 0.951 vs. 0.056
# Minibatch Loss= 0.007187
# Train Batch Evaluation
# AUC = 1.000 vs. 0.092
# F1 = 0.999 vs. 0.148
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.722 vs. 0.068
# F1 = 0.709 vs. 0.093
# Accuracy = 0.951 vs. 0.056
# Minibatch Loss= 0.003292
# Train Batch Evaluation
# AUC = 1.000 vs. 0.100
# F1 = 0.999 vs. 0.163
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.718 vs. 0.071
# F1 = 0.706 vs. 0.101
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.004313
# Train Batch Evaluation
# AUC = 1.000 vs. 0.095
# F1 = 0.999 vs. 0.154
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.720 vs. 0.067
# F1 = 0.709 vs. 0.094
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.005293
# Train Batch Evaluation
# AUC = 1.000 vs. 0.090
# F1 = 1.000 vs. 0.144
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.721 vs. 0.068
# F1 = 0.710 vs. 0.094
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.002235
# Train Batch Evaluation
# AUC = 1.000 vs. 0.113
# F1 = 1.000 vs. 0.161
# Accuracy = 1.000 vs. 0.077
# Validation
# AUC = 0.719 vs. 0.069
# F1 = 0.708 vs. 0.099
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.003326
# Train Batch Evaluation
# AUC = 1.000 vs. 0.096
# F1 = 0.999 vs. 0.158
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.720 vs. 0.070
# F1 = 0.709 vs. 0.099
# Accuracy = 0.952 vs. 0.056
# Minibatch Loss= 0.003012
# Train Batch Evaluation
# AUC = 1.000 vs. 0.112
# F1 = 0.999 vs. 0.184
# Accuracy = 0.991 vs. 0.059
# Validation
# AUC = 0.719 vs. 0.070
# F1 = 0.705 vs. 0.097
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.003001
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 0.999 vs. 0.189
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.718 vs. 0.069
# F1 = 0.705 vs. 0.097
# Accuracy = 0.953 vs. 0.056
# Minibatch Loss= 0.004967
# Train Batch Evaluation
# AUC = 1.000 vs. 0.152
# F1 = 1.000 vs. 0.215
# Accuracy = 1.000 vs. 0.071
# Validation
# AUC = 0.716 vs. 0.069
# F1 = 0.706 vs. 0.097
# Accuracy = 0.950 vs. 0.056
# Minibatch Loss= 0.001207
# Train Batch Evaluation
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.154
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.718 vs. 0.067
# F1 = 0.705 vs. 0.093
# Accuracy = 0.953 vs. 0.056
# Minibatch Loss= 0.002061
# Train Batch Evaluation
# AUC = 1.000 vs. 0.122
# F1 = 1.000 vs. 0.163
# Accuracy = 1.000 vs. 0.091
# Validation
# AUC = 0.719 vs. 0.069
# F1 = 0.708 vs. 0.099
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.001113
# Train Batch Evaluation
# AUC = 1.000 vs. 0.098
# F1 = 0.999 vs. 0.172
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.718 vs. 0.069
# F1 = 0.707 vs. 0.095
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.002466
# Train Batch Evaluation
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.160
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.717 vs. 0.067
# F1 = 0.707 vs. 0.092
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.001743
# Train Batch Evaluation
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.142
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.720 vs. 0.069
# F1 = 0.705 vs. 0.098
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.001377
# Train Batch Evaluation
# AUC = 1.000 vs. 0.091
# F1 = 1.000 vs. 0.146
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.720 vs. 0.070
# F1 = 0.707 vs. 0.095
# Accuracy = 0.953 vs. 0.056
# Minibatch Loss= 0.001402
# Train Batch Evaluation
# AUC = 1.000 vs. 0.134
# F1 = 1.000 vs. 0.181
# Accuracy = 1.000 vs. 0.071
# Validation
# AUC = 0.718 vs. 0.068
# F1 = 0.704 vs. 0.094
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.001383
# Train Batch Evaluation
# AUC = 1.000 vs. 0.120
# F1 = 1.000 vs. 0.170
# Accuracy = 1.000 vs. 0.083
# Validation
# AUC = 0.717 vs. 0.069
# F1 = 0.706 vs. 0.096
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.000583
# Train Batch Evaluation
# AUC = 1.000 vs. 0.123
# F1 = 1.000 vs. 0.172
# Accuracy = 1.000 vs. 0.083
# Validation
# AUC = 0.718 vs. 0.068
# F1 = 0.705 vs. 0.095
# Accuracy = 0.954 vs. 0.056
# Minibatch Loss= 0.000803
# Train Batch Evaluation
# AUC = 1.000 vs. 0.094
# F1 = 1.000 vs. 0.162
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.718 vs. 0.068
# F1 = 0.708 vs. 0.097
# Accuracy = 0.953 vs. 0.056
# Minibatch Loss= 0.001077
# Train Batch Evaluation
# AUC = 1.000 vs. 0.163
# F1 = 1.000 vs. 0.230
# Accuracy = 1.000 vs. 0.125
# Validation
# AUC = 0.719 vs. 0.071
# F1 = 0.704 vs. 0.105
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.000308
# Train Batch Evaluation
# AUC = 1.000 vs. 0.116
# F1 = 1.000 vs. 0.195
# Accuracy = 1.000 vs. 0.077
# Validation
# AUC = 0.722 vs. 0.068
# F1 = 0.707 vs. 0.097
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.001430
# Train Batch Evaluation
# AUC = 1.000 vs. 0.092
# F1 = 1.000 vs. 0.146
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.719 vs. 0.067
# F1 = 0.709 vs. 0.093
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.000793
# Train Batch Evaluation
# AUC = 1.000 vs. 0.116
# F1 = 1.000 vs. 0.194
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.718 vs. 0.068
# F1 = 0.705 vs. 0.092
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.000743
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 1.000 vs. 0.170
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.720 vs. 0.069
# F1 = 0.706 vs. 0.096
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.000375
# Train Batch Evaluation
# AUC = 1.000 vs. 0.115
# F1 = 1.000 vs. 0.198
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.720 vs. 0.069
# F1 = 0.708 vs. 0.096
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.000931
# Train Batch Evaluation
# AUC = 1.000 vs. 0.107
# F1 = 1.000 vs. 0.170
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.719 vs. 0.069
# F1 = 0.707 vs. 0.096
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.000490
# Train Batch Evaluation
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.174
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.720 vs. 0.069
# F1 = 0.709 vs. 0.095
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.000461
# Train Batch Evaluation
# AUC = 1.000 vs. 0.100
# F1 = 1.000 vs. 0.172
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.721 vs. 0.068
# F1 = 0.708 vs. 0.093
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.000516
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 1.000 vs. 0.171
# Accuracy = 1.000 vs. 0.083
# Validation
# AUC = 0.721 vs. 0.069
# F1 = 0.709 vs. 0.101
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.000391
# Train Batch Evaluation
# AUC = 1.000 vs. 0.117
# F1 = 1.000 vs. 0.189
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.721 vs. 0.069
# F1 = 0.709 vs. 0.096
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.000609
# Train Batch Evaluation
# AUC = 1.000 vs. 0.110
# F1 = 1.000 vs. 0.185
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.721 vs. 0.068
# F1 = 0.713 vs. 0.094
# Accuracy = 0.961 vs. 0.056
# Minibatch Loss= 0.000367
# Train Batch Evaluation
# AUC = 1.000 vs. 0.107
# F1 = 1.000 vs. 0.171
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.722 vs. 0.068
# F1 = 0.711 vs. 0.096
# Accuracy = 0.957 vs. 0.056
# Minibatch Loss= 0.000364
# Train Batch Evaluation
# AUC = 1.000 vs. 0.101
# F1 = 1.000 vs. 0.149
# Accuracy = 1.000 vs. 0.067
# Validation
# AUC = 0.722 vs. 0.068
# F1 = 0.711 vs. 0.093
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.000407
# Train Batch Evaluation
# AUC = 1.000 vs. 0.095
# F1 = 1.000 vs. 0.148
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.723 vs. 0.068
# F1 = 0.713 vs. 0.093
# Accuracy = 0.956 vs. 0.056
# Minibatch Loss= 0.000421
# Train Batch Evaluation
# AUC = 1.000 vs. 0.097
# F1 = 1.000 vs. 0.155
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.725 vs. 0.067
# F1 = 0.714 vs. 0.091
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.000385
# Train Batch Evaluation
# AUC = 1.000 vs. 0.093
# F1 = 1.000 vs. 0.156
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.723 vs. 0.070
# F1 = 0.712 vs. 0.097
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.000528
# Train Batch Evaluation
# AUC = 1.000 vs. 0.115
# F1 = 1.000 vs. 0.196
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.722 vs. 0.070
# F1 = 0.713 vs. 0.098
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.000754
# Train Batch Evaluation
# AUC = 1.000 vs. 0.113
# F1 = 1.000 vs. 0.170
# Accuracy = 1.000 vs. 0.062
# Validation
# AUC = 0.723 vs. 0.068
# F1 = 0.714 vs. 0.093
# Accuracy = 0.961 vs. 0.056
# Minibatch Loss= 0.000247
# Train Batch Evaluation
# AUC = 1.000 vs. 0.106
# F1 = 1.000 vs. 0.147
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.721 vs. 0.069
# F1 = 0.711 vs. 0.095
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.000170
# Train Batch Evaluation
# AUC = 1.000 vs. 0.108
# F1 = 1.000 vs. 0.166
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.725 vs. 0.069
# F1 = 0.715 vs. 0.096
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.000327
# Train Batch Evaluation
# AUC = 1.000 vs. 0.105
# F1 = 1.000 vs. 0.169
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.726 vs. 0.071
# F1 = 0.714 vs. 0.099
# Accuracy = 0.959 vs. 0.056
# Minibatch Loss= 0.000211
# Train Batch Evaluation
# AUC = 0.999 vs. 0.110
# F1 = 0.997 vs. 0.183
# Accuracy = 0.975 vs. 0.056
# Validation
# AUC = 0.691 vs. 0.068
# F1 = 0.684 vs. 0.092
# Accuracy = 0.855 vs. 0.056
# Minibatch Loss= 0.019027
# Train Batch Evaluation
# AUC = 0.935 vs. 0.103
# F1 = 0.914 vs. 0.164
# Accuracy = 0.934 vs. 0.056
# Validation
# AUC = 0.657 vs. 0.068
# F1 = 0.669 vs. 0.094
# Accuracy = 0.905 vs. 0.056
# Minibatch Loss= 0.199725
# Train Batch Evaluation
# AUC = 0.966 vs. 0.117
# F1 = 0.971 vs. 0.187
# Accuracy = 0.911 vs. 0.062
# Validation
# AUC = 0.720 vs. 0.070
# F1 = 0.704 vs. 0.096
# Accuracy = 0.928 vs. 0.056
# Minibatch Loss= 0.055019
# Train Batch Evaluation
# AUC = 0.988 vs. 0.122
# F1 = 0.986 vs. 0.181
# Accuracy = 0.975 vs. 0.062
# Validation
# AUC = 0.715 vs. 0.067
# F1 = 0.700 vs. 0.090
# Accuracy = 0.920 vs. 0.056
# Minibatch Loss= 0.038854
# Train Batch Evaluation
# AUC = 0.999 vs. 0.143
# F1 = 0.994 vs. 0.212
# Accuracy = 0.970 vs. 0.059
# Validation
# AUC = 0.713 vs. 0.069
# F1 = 0.705 vs. 0.095
# Accuracy = 0.933 vs. 0.056
# Minibatch Loss= 0.018148
# Train Batch Evaluation
# AUC = 0.996 vs. 0.095
# F1 = 0.993 vs. 0.155
# Accuracy = 0.980 vs. 0.056
# Validation
# AUC = 0.717 vs. 0.068
# F1 = 0.713 vs. 0.093
# Accuracy = 0.940 vs. 0.056
# Minibatch Loss= 0.022709
# Train Batch Evaluation
# AUC = 0.999 vs. 0.110
# F1 = 0.996 vs. 0.177
# Accuracy = 0.991 vs. 0.059
# Validation
# AUC = 0.730 vs. 0.069
# F1 = 0.723 vs. 0.092
# Accuracy = 0.951 vs. 0.056
# Minibatch Loss= 0.016110
# Train Batch Evaluation
# AUC = 1.000 vs. 0.103
# F1 = 0.997 vs. 0.166
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.734 vs. 0.068
# F1 = 0.720 vs. 0.097
# Accuracy = 0.950 vs. 0.056
# Minibatch Loss= 0.018657
# Train Batch Evaluation
# AUC = 1.000 vs. 0.096
# F1 = 0.999 vs. 0.169
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.734 vs. 0.068
# F1 = 0.721 vs. 0.100
# Accuracy = 0.955 vs. 0.056
# Minibatch Loss= 0.009284
# Train Batch Evaluation
# AUC = 1.000 vs. 0.114
# F1 = 1.000 vs. 0.193
# Accuracy = 1.000 vs. 0.071
# Validation
# AUC = 0.734 vs. 0.068
# F1 = 0.728 vs. 0.094
# Accuracy = 0.958 vs. 0.056
# Minibatch Loss= 0.007445
# Train Batch Evaluation
# AUC = 1.000 vs. 0.107
# F1 = 0.999 vs. 0.176
# Accuracy = 0.988 vs. 0.056
# Validation
# AUC = 0.732 vs. 0.070
# F1 = 0.719 vs. 0.096
# Accuracy = 0.960 vs. 0.056
# Minibatch Loss= 0.008524
# Train Batch Evaluation
# AUC = 1.000 vs. 0.135
# F1 = 1.000 vs. 0.211
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.732 vs. 0.068
# F1 = 0.719 vs. 0.095
# Accuracy = 0.960 vs. 0.056
# Minibatch Loss= 0.003045
# Train Batch Evaluation
# AUC = 1.000 vs. 0.099
# F1 = 0.999 vs. 0.178
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.733 vs. 0.068
# F1 = 0.718 vs. 0.092
# Accuracy = 0.963 vs. 0.056
# Minibatch Loss= 0.002964
# Train Batch Evaluation
# AUC = 1.000 vs. 0.120
# F1 = 0.999 vs. 0.199
# Accuracy = 1.000 vs. 0.056
# Validation
# AUC = 0.731 vs. 0.069
# F1 = 0.717 vs. 0.095
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.005077
# Train Batch Evaluation
# AUC = 1.000 vs. 0.126
# F1 = 1.000 vs. 0.206
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.733 vs. 0.068
# F1 = 0.721 vs. 0.097
# Accuracy = 0.961 vs. 0.056
# Minibatch Loss= 0.002727
# Train Batch Evaluation
# AUC = 1.000 vs. 0.101
# F1 = 0.999 vs. 0.175
# Accuracy = 0.990 vs. 0.059
# Validation
# AUC = 0.734 vs. 0.070
# F1 = 0.721 vs. 0.095
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.004852
# Train Batch Evaluation
# AUC = 1.000 vs. 0.169
# F1 = 0.998 vs. 0.219
# Accuracy = 1.000 vs. 0.111
# Validation
# AUC = 0.734 vs. 0.068
# F1 = 0.720 vs. 0.093
# Accuracy = 0.963 vs. 0.056
# Minibatch Loss= 0.001588
# Train Batch Evaluation
# AUC = 1.000 vs. 0.104
# F1 = 1.000 vs. 0.168
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.733 vs. 0.068
# F1 = 0.718 vs. 0.095
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.001758
# Train Batch Evaluation
# AUC = 1.000 vs. 0.111
# F1 = 1.000 vs. 0.178
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.733 vs. 0.069
# F1 = 0.721 vs. 0.095
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.004742
# Train Batch Evaluation
# AUC = 1.000 vs. 0.114
# F1 = 1.000 vs. 0.185
# Accuracy = 1.000 vs. 0.059
# Validation
# AUC = 0.735 vs. 0.068
# F1 = 0.721 vs. 0.094
# Accuracy = 0.962 vs. 0.056
# Minibatch Loss= 0.002013
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/RCNN9001_opp/RCNN9001_opp-20000'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
