# %%
# useing this variable for saving models and summaries
exp_name = "DWN9001_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval_activity as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp1.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((1, 700165, 77), (1, 700165, 18))

# %%
test_data.shape, test_gt.shape
# Out:
# ((1, 120516, 77), (1, 120516, 18))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 1

wavelet_levels = 5    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 18

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[0,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

# %%
train_data = train_data[:,:-(train_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_data = validation_data[:,:-(validation_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_data = test_data[:,:-(test_data.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

train_gt = train_gt[:,:-(train_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
validation_gt = validation_gt[:,:-(validation_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]
test_gt = test_gt[:,:-(test_gt.shape[1]%((2**(wavelet_levels-1))*resolution)),:]

# %%
pos_weight.shape
# Out:
# (18,)

# %%
pos_weight
# Out:
# array([  0.15400844,  34.75163399,  34.29032258,  35.46666667,
#         35.7114094 ,  26.21393035,  26.69620253,  39.51851852,
#         40.59695817,  45.55319149,  50.12149533,  48.50226244,
#         52.10679612,  43.11290323,  43.11290323,  33.08099688,
#         10.4795383 ,  35.83501684])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'activity')

# %%
trainer.run_debug_ops()
# Out:
# {'wavelet_out_shape': [array([     1, 699392,     77], dtype=int32), array([     1, 349696,     77], dtype=int32), array([     1, 174848,     77], dtype=int32), array([    1, 87424,    77], dtype=int32), array([    1, 43712,    77], dtype=int32), array([    1, 21856,    77], dtype=int32)], 'cnn_out_shape': [array([    1, 10928,    18], dtype=int32), array([   1, 5464,   18], dtype=int32), array([   1, 2732,   18], dtype=int32), array([   1, 1366,   18], dtype=int32), array([  1, 683,  18], dtype=int32), array([  1, 342,  18], dtype=int32)], 'input_shape': array([     1, 699392,     77], dtype=int32), 'label_shape': array([     1, 699392,     18], dtype=int32)}

# %%
trainer.train(max_iter = 4000,
                train_eval_step = 1, 
                validation_eval_step = 1,
                display_step = 1)
# Out:
# Train Batch Evaluation
# AUC = 0.077 vs. 0.077
# F1 = 0.121 vs. 0.109
# Accuracy = 0.005 vs. 0.056
# Validation
# AUC = 0.070 vs. 0.073
# F1 = 0.099 vs. 0.108
# Accuracy = 0.003 vs. 0.056
# Minibatch Loss= 1.527065
# Train Batch Evaluation
# AUC = 0.081 vs. 0.077
# F1 = 0.123 vs. 0.108
# Accuracy = 0.008 vs. 0.056
# Validation
# AUC = 0.075 vs. 0.070
# F1 = 0.111 vs. 0.107
# Accuracy = 0.003 vs. 0.056
# Minibatch Loss= 1.358774
# Train Batch Evaluation
# AUC = 0.088 vs. 0.077
# F1 = 0.134 vs. 0.108
# Accuracy = 0.005 vs. 0.056
# Validation
# AUC = 0.076 vs. 0.072
# F1 = 0.117 vs. 0.104
# Accuracy = 0.001 vs. 0.056
# Minibatch Loss= 1.297104
# Train Batch Evaluation
# AUC = 0.099 vs. 0.076
# F1 = 0.155 vs. 0.109
# Accuracy = 0.015 vs. 0.056
# Validation
# AUC = 0.078 vs. 0.072
# F1 = 0.118 vs. 0.104
# Accuracy = 0.004 vs. 0.056
# Minibatch Loss= 1.270680
# Train Batch Evaluation
# AUC = 0.119 vs. 0.076
# F1 = 0.185 vs. 0.108
# Accuracy = 0.020 vs. 0.056
# Validation
# AUC = 0.085 vs. 0.072
# F1 = 0.125 vs. 0.106
# Accuracy = 0.005 vs. 0.056
# Minibatch Loss= 1.253762
# Train Batch Evaluation
# AUC = 0.141 vs. 0.076
# F1 = 0.213 vs. 0.107
# Accuracy = 0.023 vs. 0.056
# Validation
# AUC = 0.089 vs. 0.071
# F1 = 0.137 vs. 0.106
# Accuracy = 0.007 vs. 0.056
# Minibatch Loss= 1.239397
# Train Batch Evaluation
# AUC = 0.163 vs. 0.077
# F1 = 0.236 vs. 0.109
# Accuracy = 0.026 vs. 0.056
# Validation
# AUC = 0.089 vs. 0.069
# F1 = 0.145 vs. 0.099
# Accuracy = 0.010 vs. 0.056
# Minibatch Loss= 1.224962
# Train Batch Evaluation
# AUC = 0.180 vs. 0.077
# F1 = 0.259 vs. 0.109
# Accuracy = 0.030 vs. 0.056
# Validation
# AUC = 0.093 vs. 0.070
# F1 = 0.156 vs. 0.096
# Accuracy = 0.011 vs. 0.056
# Minibatch Loss= 1.209529
# Train Batch Evaluation
# AUC = 0.194 vs. 0.077
# F1 = 0.274 vs. 0.109
# Accuracy = 0.033 vs. 0.056
# Validation
# AUC = 0.096 vs. 0.071
# F1 = 0.165 vs. 0.109
# Accuracy = 0.014 vs. 0.056
# Minibatch Loss= 1.192093
# Train Batch Evaluation
# AUC = 0.203 vs. 0.077
# F1 = 0.286 vs. 0.108
# Accuracy = 0.049 vs. 0.056
# Validation
# AUC = 0.099 vs. 0.070
# F1 = 0.162 vs. 0.103
# Accuracy = 0.036 vs. 0.056
# Minibatch Loss= 1.172027
# Train Batch Evaluation
# AUC = 0.208 vs. 0.077
# F1 = 0.295 vs. 0.110
# Accuracy = 0.066 vs. 0.056
# Validation
# AUC = 0.102 vs. 0.071
# F1 = 0.168 vs. 0.104
# Accuracy = 0.052 vs. 0.056
# Minibatch Loss= 1.149713
# Train Batch Evaluation
# AUC = 0.210 vs. 0.077
# F1 = 0.301 vs. 0.109
# Accuracy = 0.078 vs. 0.056
# Validation
# AUC = 0.106 vs. 0.068
# F1 = 0.171 vs. 0.096
# Accuracy = 0.067 vs. 0.056
# Minibatch Loss= 1.125107
# Train Batch Evaluation
# AUC = 0.213 vs. 0.076
# F1 = 0.298 vs. 0.108
# Accuracy = 0.077 vs. 0.056
# Validation
# AUC = 0.107 vs. 0.069
# F1 = 0.171 vs. 0.101
# Accuracy = 0.065 vs. 0.056
# Minibatch Loss= 1.097426
# Train Batch Evaluation
# AUC = 0.213 vs. 0.077
# F1 = 0.297 vs. 0.109
# Accuracy = 0.055 vs. 0.056
# Validation
# AUC = 0.107 vs. 0.068
# F1 = 0.176 vs. 0.096
# Accuracy = 0.039 vs. 0.056
# Minibatch Loss= 1.069196
# Train Batch Evaluation
# AUC = 0.213 vs. 0.076
# F1 = 0.299 vs. 0.108
# Accuracy = 0.042 vs. 0.056
# Validation
# AUC = 0.106 vs. 0.070
# F1 = 0.178 vs. 0.101
# Accuracy = 0.024 vs. 0.056
# Minibatch Loss= 1.044549
# Train Batch Evaluation
# AUC = 0.215 vs. 0.077
# F1 = 0.301 vs. 0.109
# Accuracy = 0.040 vs. 0.056
# Validation
# AUC = 0.107 vs. 0.074
# F1 = 0.178 vs. 0.104
# Accuracy = 0.021 vs. 0.056
# Minibatch Loss= 1.021749
# Train Batch Evaluation
# AUC = 0.221 vs. 0.076
# F1 = 0.307 vs. 0.108
# Accuracy = 0.033 vs. 0.056
# Validation
# AUC = 0.112 vs. 0.070
# F1 = 0.184 vs. 0.102
# Accuracy = 0.015 vs. 0.056
# Minibatch Loss= 0.997489
# Train Batch Evaluation
# AUC = 0.228 vs. 0.076
# F1 = 0.312 vs. 0.108
# Accuracy = 0.034 vs. 0.056
# Validation
# AUC = 0.116 vs. 0.070
# F1 = 0.193 vs. 0.104
# Accuracy = 0.015 vs. 0.056
# Minibatch Loss= 0.971583
# Train Batch Evaluation
# AUC = 0.237 vs. 0.076
# F1 = 0.322 vs. 0.108
# Accuracy = 0.036 vs. 0.056
# Validation
# AUC = 0.119 vs. 0.070
# F1 = 0.195 vs. 0.103
# Accuracy = 0.018 vs. 0.056
# Minibatch Loss= 0.944864
# Train Batch Evaluation
# AUC = 0.245 vs. 0.076
# F1 = 0.330 vs. 0.108
# Accuracy = 0.037 vs. 0.056
# Validation
# AUC = 0.118 vs. 0.070
# F1 = 0.194 vs. 0.103
# Accuracy = 0.016 vs. 0.056
# Minibatch Loss= 0.918921
# Train Batch Evaluation
# AUC = 0.249 vs. 0.077
# F1 = 0.334 vs. 0.109
# Accuracy = 0.038 vs. 0.056
# Validation
# AUC = 0.120 vs. 0.070
# F1 = 0.200 vs. 0.101
# Accuracy = 0.018 vs. 0.056
# Minibatch Loss= 0.893638
# Train Batch Evaluation
# AUC = 0.250 vs. 0.077
# F1 = 0.335 vs. 0.108
# Accuracy = 0.042 vs. 0.056
# Validation
# AUC = 0.120 vs. 0.070
# F1 = 0.199 vs. 0.100
# Accuracy = 0.020 vs. 0.056
# Minibatch Loss= 0.870896
# Train Batch Evaluation
# AUC = 0.249 vs. 0.076
# F1 = 0.335 vs. 0.109
# Accuracy = 0.045 vs. 0.056
# Validation
# AUC = 0.120 vs. 0.073
# F1 = 0.195 vs. 0.112
# Accuracy = 0.020 vs. 0.056
# Minibatch Loss= 0.850321
# Train Batch Evaluation
# AUC = 0.256 vs. 0.076
# F1 = 0.343 vs. 0.107
# Accuracy = 0.045 vs. 0.056
# Validation
# AUC = 0.122 vs. 0.072
# F1 = 0.197 vs. 0.107
# Accuracy = 0.018 vs. 0.056
# Minibatch Loss= 0.831577
# Train Batch Evaluation
# AUC = 0.254 vs. 0.077
# F1 = 0.345 vs. 0.108
# Accuracy = 0.048 vs. 0.056
# Validation
# AUC = 0.123 vs. 0.070
# F1 = 0.203 vs. 0.101
# Accuracy = 0.024 vs. 0.056
# Minibatch Loss= 0.805173
# Train Batch Evaluation
# AUC = 0.267 vs. 0.076
# F1 = 0.356 vs. 0.107
# Accuracy = 0.048 vs. 0.056
# Validation
# AUC = 0.129 vs. 0.072
# F1 = 0.204 vs. 0.101
# Accuracy = 0.021 vs. 0.056
# Minibatch Loss= 0.776264
# Train Batch Evaluation
# AUC = 0.275 vs. 0.076
# F1 = 0.363 vs. 0.108
# Accuracy = 0.047 vs. 0.056
# Validation
# AUC = 0.133 vs. 0.068
# F1 = 0.207 vs. 0.098
# Accuracy = 0.016 vs. 0.056
# Minibatch Loss= 0.763088
# Train Batch Evaluation
# AUC = 0.277 vs. 0.077
# F1 = 0.362 vs. 0.109
# Accuracy = 0.053 vs. 0.056
# Validation
# AUC = 0.136 vs. 0.070
# F1 = 0.212 vs. 0.100
# Accuracy = 0.018 vs. 0.056
# Minibatch Loss= 0.744766
# Train Batch Evaluation
# AUC = 0.286 vs. 0.077
# F1 = 0.369 vs. 0.108
# Accuracy = 0.058 vs. 0.056
# Validation
# AUC = 0.142 vs. 0.073
# F1 = 0.220 vs. 0.113
# Accuracy = 0.022 vs. 0.056
# Minibatch Loss= 0.717228
# Train Batch Evaluation
# AUC = 0.296 vs. 0.077
# F1 = 0.375 vs. 0.108
# Accuracy = 0.063 vs. 0.056
# Validation
# AUC = 0.148 vs. 0.071
# F1 = 0.233 vs. 0.103
# Accuracy = 0.037 vs. 0.056
# Minibatch Loss= 0.702176
# Train Batch Evaluation
# AUC = 0.309 vs. 0.077
# F1 = 0.385 vs. 0.108
# Accuracy = 0.089 vs. 0.056
# Validation
# AUC = 0.149 vs. 0.071
# F1 = 0.230 vs. 0.100
# Accuracy = 0.040 vs. 0.056
# Minibatch Loss= 0.686922
# Train Batch Evaluation
# AUC = 0.324 vs. 0.077
# F1 = 0.395 vs. 0.109
# Accuracy = 0.103 vs. 0.056
# Validation
# AUC = 0.160 vs. 0.072
# F1 = 0.242 vs. 0.105
# Accuracy = 0.046 vs. 0.056
# Minibatch Loss= 0.665893
# Train Batch Evaluation
# AUC = 0.331 vs. 0.076
# F1 = 0.401 vs. 0.108
# Accuracy = 0.122 vs. 0.056
# Validation
# AUC = 0.162 vs. 0.069
# F1 = 0.243 vs. 0.100
# Accuracy = 0.074 vs. 0.056
# Minibatch Loss= 0.646386
# Train Batch Evaluation
# AUC = 0.344 vs. 0.077
# F1 = 0.412 vs. 0.109
# Accuracy = 0.204 vs. 0.056
# Validation
# AUC = 0.166 vs. 0.073
# F1 = 0.246 vs. 0.105
# Accuracy = 0.133 vs. 0.056
# Minibatch Loss= 0.637627
# Train Batch Evaluation
# AUC = 0.347 vs. 0.077
# F1 = 0.415 vs. 0.109
# Accuracy = 0.201 vs. 0.056
# Validation
# AUC = 0.167 vs. 0.068
# F1 = 0.246 vs. 0.096
# Accuracy = 0.107 vs. 0.056
# Minibatch Loss= 0.623099
# Train Batch Evaluation
# AUC = 0.359 vs. 0.077
# F1 = 0.423 vs. 0.109
# Accuracy = 0.290 vs. 0.056
# Validation
# AUC = 0.173 vs. 0.071
# F1 = 0.253 vs. 0.103
# Accuracy = 0.185 vs. 0.056
# Minibatch Loss= 0.603585
# Train Batch Evaluation
# AUC = 0.367 vs. 0.077
# F1 = 0.431 vs. 0.108
# Accuracy = 0.316 vs. 0.056
# Validation
# AUC = 0.177 vs. 0.070
# F1 = 0.256 vs. 0.104
# Accuracy = 0.212 vs. 0.056
# Minibatch Loss= 0.595349
# Train Batch Evaluation
# AUC = 0.372 vs. 0.077
# F1 = 0.434 vs. 0.108
# Accuracy = 0.301 vs. 0.056
# Validation
# AUC = 0.180 vs. 0.071
# F1 = 0.259 vs. 0.105
# Accuracy = 0.184 vs. 0.056
# Minibatch Loss= 0.582706
# Train Batch Evaluation
# AUC = 0.382 vs. 0.077
# F1 = 0.443 vs. 0.109
# Accuracy = 0.331 vs. 0.056
# Validation
# AUC = 0.184 vs. 0.069
# F1 = 0.266 vs. 0.103
# Accuracy = 0.204 vs. 0.056
# Minibatch Loss= 0.565317
# Train Batch Evaluation
# AUC = 0.391 vs. 0.077
# F1 = 0.452 vs. 0.110
# Accuracy = 0.412 vs. 0.056
# Validation
# AUC = 0.189 vs. 0.072
# F1 = 0.270 vs. 0.109
# Accuracy = 0.277 vs. 0.056
# Minibatch Loss= 0.558667
# Train Batch Evaluation
# AUC = 0.397 vs. 0.077
# F1 = 0.457 vs. 0.107
# Accuracy = 0.386 vs. 0.056
# Validation
# AUC = 0.193 vs. 0.070
# F1 = 0.276 vs. 0.102
# Accuracy = 0.250 vs. 0.056
# Minibatch Loss= 0.547067
# Train Batch Evaluation
# AUC = 0.406 vs. 0.076
# F1 = 0.465 vs. 0.107
# Accuracy = 0.361 vs. 0.056
# Validation
# AUC = 0.200 vs. 0.069
# F1 = 0.287 vs. 0.098
# Accuracy = 0.237 vs. 0.056
# Minibatch Loss= 0.534531
# Train Batch Evaluation
# AUC = 0.414 vs. 0.077
# F1 = 0.470 vs. 0.108
# Accuracy = 0.445 vs. 0.056
# Validation
# AUC = 0.210 vs. 0.068
# F1 = 0.293 vs. 0.098
# Accuracy = 0.314 vs. 0.056
# Minibatch Loss= 0.531501
# Train Batch Evaluation
# AUC = 0.418 vs. 0.076
# F1 = 0.473 vs. 0.107
# Accuracy = 0.351 vs. 0.056
# Validation
# AUC = 0.211 vs. 0.071
# F1 = 0.291 vs. 0.103
# Accuracy = 0.235 vs. 0.056
# Minibatch Loss= 0.521260
# Train Batch Evaluation
# AUC = 0.423 vs. 0.077
# F1 = 0.478 vs. 0.108
# Accuracy = 0.439 vs. 0.056
# Validation
# AUC = 0.216 vs. 0.071
# F1 = 0.294 vs. 0.102
# Accuracy = 0.304 vs. 0.056
# Minibatch Loss= 0.515640
# Train Batch Evaluation
# AUC = 0.428 vs. 0.077
# F1 = 0.481 vs. 0.108
# Accuracy = 0.397 vs. 0.056
# Validation
# AUC = 0.215 vs. 0.070
# F1 = 0.295 vs. 0.100
# Accuracy = 0.293 vs. 0.056
# Minibatch Loss= 0.520418
# Train Batch Evaluation
# AUC = 0.428 vs. 0.077
# F1 = 0.484 vs. 0.109
# Accuracy = 0.474 vs. 0.056
# Validation
# AUC = 0.221 vs. 0.069
# F1 = 0.300 vs. 0.099
# Accuracy = 0.342 vs. 0.056
# Minibatch Loss= 0.513459
# Train Batch Evaluation
# AUC = 0.433 vs. 0.077
# F1 = 0.489 vs. 0.109
# Accuracy = 0.384 vs. 0.056
# Validation
# AUC = 0.222 vs. 0.073
# F1 = 0.304 vs. 0.111
# Accuracy = 0.262 vs. 0.056
# Minibatch Loss= 0.491675
# Train Batch Evaluation
# AUC = 0.441 vs. 0.077
# F1 = 0.494 vs. 0.109
# Accuracy = 0.429 vs. 0.056
# Validation
# AUC = 0.223 vs. 0.071
# F1 = 0.305 vs. 0.104
# Accuracy = 0.305 vs. 0.056
# Minibatch Loss= 0.495236
# Train Batch Evaluation
# AUC = 0.447 vs. 0.077
# F1 = 0.497 vs. 0.109
# Accuracy = 0.482 vs. 0.056
# Validation
# AUC = 0.234 vs. 0.070
# F1 = 0.320 vs. 0.103
# Accuracy = 0.353 vs. 0.056
# Minibatch Loss= 0.486035
# Train Batch Evaluation
# AUC = 0.449 vs. 0.077
# F1 = 0.500 vs. 0.109
# Accuracy = 0.364 vs. 0.056
# Validation
# AUC = 0.232 vs. 0.072
# F1 = 0.321 vs. 0.112
# Accuracy = 0.243 vs. 0.056
# Minibatch Loss= 0.476958
# Train Batch Evaluation
# AUC = 0.456 vs. 0.077
# F1 = 0.506 vs. 0.108
# Accuracy = 0.419 vs. 0.056
# Validation
# AUC = 0.231 vs. 0.071
# F1 = 0.320 vs. 0.109
# Accuracy = 0.290 vs. 0.056
# Minibatch Loss= 0.472108
# Train Batch Evaluation
# AUC = 0.461 vs. 0.077
# F1 = 0.509 vs. 0.110
# Accuracy = 0.487 vs. 0.056
# Validation
# AUC = 0.243 vs. 0.071
# F1 = 0.328 vs. 0.099
# Accuracy = 0.356 vs. 0.056
# Minibatch Loss= 0.463739
# Train Batch Evaluation
# AUC = 0.464 vs. 0.077
# F1 = 0.511 vs. 0.109
# Accuracy = 0.425 vs. 0.056
# Validation
# AUC = 0.246 vs. 0.071
# F1 = 0.335 vs. 0.108
# Accuracy = 0.302 vs. 0.056
# Minibatch Loss= 0.459042
# Train Batch Evaluation
# AUC = 0.468 vs. 0.077
# F1 = 0.514 vs. 0.108
# Accuracy = 0.450 vs. 0.056
# Validation
# AUC = 0.243 vs. 0.071
# F1 = 0.335 vs. 0.103
# Accuracy = 0.322 vs. 0.056
# Minibatch Loss= 0.449760
# Train Batch Evaluation
# AUC = 0.473 vs. 0.077
# F1 = 0.518 vs. 0.109
# Accuracy = 0.506 vs. 0.056
# Validation
# AUC = 0.254 vs. 0.073
# F1 = 0.345 vs. 0.105
# Accuracy = 0.393 vs. 0.056
# Minibatch Loss= 0.448178
# Train Batch Evaluation
# AUC = 0.474 vs. 0.077
# F1 = 0.519 vs. 0.109
# Accuracy = 0.446 vs. 0.056
# Validation
# AUC = 0.256 vs. 0.070
# F1 = 0.346 vs. 0.103
# Accuracy = 0.331 vs. 0.056
# Minibatch Loss= 0.438718
# Train Batch Evaluation
# AUC = 0.475 vs. 0.077
# F1 = 0.521 vs. 0.109
# Accuracy = 0.445 vs. 0.056
# Validation
# AUC = 0.252 vs. 0.072
# F1 = 0.345 vs. 0.099
# Accuracy = 0.325 vs. 0.056
# Minibatch Loss= 0.436031
# Train Batch Evaluation
# AUC = 0.480 vs. 0.077
# F1 = 0.525 vs. 0.109
# Accuracy = 0.529 vs. 0.056
# Validation
# AUC = 0.253 vs. 0.071
# F1 = 0.345 vs. 0.106
# Accuracy = 0.414 vs. 0.056
# Minibatch Loss= 0.427800
# Train Batch Evaluation
# AUC = 0.484 vs. 0.077
# F1 = 0.527 vs. 0.109
# Accuracy = 0.543 vs. 0.056
# Validation
# AUC = 0.257 vs. 0.072
# F1 = 0.346 vs. 0.102
# Accuracy = 0.435 vs. 0.056
# Minibatch Loss= 0.425448
# Train Batch Evaluation
# AUC = 0.486 vs. 0.076
# F1 = 0.529 vs. 0.108
# Accuracy = 0.530 vs. 0.056
# Validation
# AUC = 0.253 vs. 0.069
# F1 = 0.347 vs. 0.101
# Accuracy = 0.421 vs. 0.056
# Minibatch Loss= 0.417760
# Train Batch Evaluation
# AUC = 0.490 vs. 0.077
# F1 = 0.532 vs. 0.108
# Accuracy = 0.556 vs. 0.056
# Validation
# AUC = 0.255 vs. 0.069
# F1 = 0.345 vs. 0.095
# Accuracy = 0.449 vs. 0.056
# Minibatch Loss= 0.414257
# Train Batch Evaluation
# AUC = 0.495 vs. 0.077
# F1 = 0.537 vs. 0.108
# Accuracy = 0.548 vs. 0.056
# Validation
# AUC = 0.261 vs. 0.070
# F1 = 0.351 vs. 0.101
# Accuracy = 0.448 vs. 0.056
# Minibatch Loss= 0.409724
# Train Batch Evaluation
# AUC = 0.498 vs. 0.076
# F1 = 0.538 vs. 0.108
# Accuracy = 0.515 vs. 0.056
# Validation
# AUC = 0.265 vs. 0.071
# F1 = 0.352 vs. 0.106
# Accuracy = 0.406 vs. 0.056
# Minibatch Loss= 0.402292
# Train Batch Evaluation
# AUC = 0.500 vs. 0.077
# F1 = 0.540 vs. 0.109
# Accuracy = 0.525 vs. 0.056
# Validation
# AUC = 0.261 vs. 0.071
# F1 = 0.348 vs. 0.101
# Accuracy = 0.426 vs. 0.056
# Minibatch Loss= 0.401755
# Train Batch Evaluation
# AUC = 0.504 vs. 0.076
# F1 = 0.544 vs. 0.108
# Accuracy = 0.535 vs. 0.056
# Validation
# AUC = 0.268 vs. 0.070
# F1 = 0.352 vs. 0.101
# Accuracy = 0.437 vs. 0.056
# Minibatch Loss= 0.392946
# Train Batch Evaluation
# AUC = 0.506 vs. 0.077
# F1 = 0.546 vs. 0.108
# Accuracy = 0.522 vs. 0.056
# Validation
# AUC = 0.268 vs. 0.072
# F1 = 0.350 vs. 0.112
# Accuracy = 0.422 vs. 0.056
# Minibatch Loss= 0.390819
# Train Batch Evaluation
# AUC = 0.507 vs. 0.077
# F1 = 0.547 vs. 0.109
# Accuracy = 0.533 vs. 0.056
# Validation
# AUC = 0.262 vs. 0.070
# F1 = 0.348 vs. 0.102
# Accuracy = 0.427 vs. 0.056
# Minibatch Loss= 0.386698
# Train Batch Evaluation
# AUC = 0.511 vs. 0.078
# F1 = 0.551 vs. 0.108
# Accuracy = 0.530 vs. 0.056
# Validation
# AUC = 0.265 vs. 0.072
# F1 = 0.346 vs. 0.102
# Accuracy = 0.424 vs. 0.056
# Minibatch Loss= 0.379847
# Train Batch Evaluation
# AUC = 0.516 vs. 0.077
# F1 = 0.555 vs. 0.108
# Accuracy = 0.533 vs. 0.056
# Validation
# AUC = 0.270 vs. 0.069
# F1 = 0.351 vs. 0.100
# Accuracy = 0.424 vs. 0.056
# Minibatch Loss= 0.378636
# Train Batch Evaluation
# AUC = 0.519 vs. 0.076
# F1 = 0.555 vs. 0.108
# Accuracy = 0.568 vs. 0.056
# Validation
# AUC = 0.269 vs. 0.070
# F1 = 0.353 vs. 0.098
# Accuracy = 0.471 vs. 0.056
# Minibatch Loss= 0.373094
# Train Batch Evaluation
# AUC = 0.521 vs. 0.077
# F1 = 0.559 vs. 0.107
# Accuracy = 0.533 vs. 0.056
# Validation
# AUC = 0.270 vs. 0.069
# F1 = 0.352 vs. 0.096
# Accuracy = 0.435 vs. 0.056
# Minibatch Loss= 0.368320
# Train Batch Evaluation
# AUC = 0.525 vs. 0.076
# F1 = 0.562 vs. 0.108
# Accuracy = 0.578 vs. 0.056
# Validation
# AUC = 0.274 vs. 0.073
# F1 = 0.354 vs. 0.106
# Accuracy = 0.483 vs. 0.056
# Minibatch Loss= 0.365759
# Train Batch Evaluation
# AUC = 0.528 vs. 0.077
# F1 = 0.563 vs. 0.109
# Accuracy = 0.598 vs. 0.056
# Validation
# AUC = 0.275 vs. 0.069
# F1 = 0.353 vs. 0.096
# Accuracy = 0.503 vs. 0.056
# Minibatch Loss= 0.360295
# Train Batch Evaluation
# AUC = 0.532 vs. 0.077
# F1 = 0.566 vs. 0.108
# Accuracy = 0.576 vs. 0.056
# Validation
# AUC = 0.278 vs. 0.071
# F1 = 0.356 vs. 0.101
# Accuracy = 0.484 vs. 0.056
# Minibatch Loss= 0.356711
# Train Batch Evaluation
# AUC = 0.536 vs. 0.077
# F1 = 0.571 vs. 0.107
# Accuracy = 0.614 vs. 0.056
# Validation
# AUC = 0.282 vs. 0.069
# F1 = 0.362 vs. 0.097
# Accuracy = 0.511 vs. 0.056
# Minibatch Loss= 0.353640
# Train Batch Evaluation
# AUC = 0.539 vs. 0.077
# F1 = 0.572 vs. 0.108
# Accuracy = 0.609 vs. 0.056
# Validation
# AUC = 0.283 vs. 0.071
# F1 = 0.363 vs. 0.098
# Accuracy = 0.512 vs. 0.056
# Minibatch Loss= 0.349038
# Train Batch Evaluation
# AUC = 0.543 vs. 0.076
# F1 = 0.575 vs. 0.107
# Accuracy = 0.592 vs. 0.056
# Validation
# AUC = 0.285 vs. 0.070
# F1 = 0.367 vs. 0.104
# Accuracy = 0.493 vs. 0.056
# Minibatch Loss= 0.345292
# Train Batch Evaluation
# AUC = 0.547 vs. 0.077
# F1 = 0.578 vs. 0.108
# Accuracy = 0.620 vs. 0.056
# Validation
# AUC = 0.289 vs. 0.070
# F1 = 0.371 vs. 0.107
# Accuracy = 0.528 vs. 0.056
# Minibatch Loss= 0.342676
# Train Batch Evaluation
# AUC = 0.550 vs. 0.077
# F1 = 0.579 vs. 0.108
# Accuracy = 0.614 vs. 0.056
# Validation
# AUC = 0.289 vs. 0.069
# F1 = 0.370 vs. 0.101
# Accuracy = 0.528 vs. 0.056
# Minibatch Loss= 0.339522
# Train Batch Evaluation
# AUC = 0.553 vs. 0.077
# F1 = 0.582 vs. 0.109
# Accuracy = 0.618 vs. 0.056
# Validation
# AUC = 0.289 vs. 0.070
# F1 = 0.369 vs. 0.102
# Accuracy = 0.525 vs. 0.056
# Minibatch Loss= 0.336293
# Train Batch Evaluation
# AUC = 0.557 vs. 0.076
# F1 = 0.585 vs. 0.108
# Accuracy = 0.661 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.070
# F1 = 0.374 vs. 0.100
# Accuracy = 0.597 vs. 0.056
# Minibatch Loss= 0.337084
# Train Batch Evaluation
# AUC = 0.559 vs. 0.077
# F1 = 0.588 vs. 0.109
# Accuracy = 0.564 vs. 0.056
# Validation
# AUC = 0.292 vs. 0.072
# F1 = 0.375 vs. 0.097
# Accuracy = 0.467 vs. 0.056
# Minibatch Loss= 0.345456
# Train Batch Evaluation
# AUC = 0.559 vs. 0.077
# F1 = 0.588 vs. 0.109
# Accuracy = 0.676 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.070
# F1 = 0.380 vs. 0.104
# Accuracy = 0.636 vs. 0.056
# Minibatch Loss= 0.380586
# Train Batch Evaluation
# AUC = 0.565 vs. 0.078
# F1 = 0.592 vs. 0.109
# Accuracy = 0.515 vs. 0.056
# Validation
# AUC = 0.297 vs. 0.072
# F1 = 0.375 vs. 0.103
# Accuracy = 0.415 vs. 0.056
# Minibatch Loss= 0.342249
# Train Batch Evaluation
# AUC = 0.570 vs. 0.076
# F1 = 0.597 vs. 0.109
# Accuracy = 0.664 vs. 0.056
# Validation
# AUC = 0.303 vs. 0.072
# F1 = 0.377 vs. 0.102
# Accuracy = 0.572 vs. 0.056
# Minibatch Loss= 0.329304
# Train Batch Evaluation
# AUC = 0.573 vs. 0.077
# F1 = 0.597 vs. 0.109
# Accuracy = 0.686 vs. 0.056
# Validation
# AUC = 0.310 vs. 0.073
# F1 = 0.385 vs. 0.111
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.349063
# Train Batch Evaluation
# AUC = 0.574 vs. 0.077
# F1 = 0.600 vs. 0.108
# Accuracy = 0.597 vs. 0.056
# Validation
# AUC = 0.306 vs. 0.072
# F1 = 0.384 vs. 0.110
# Accuracy = 0.503 vs. 0.056
# Minibatch Loss= 0.318400
# Train Batch Evaluation
# AUC = 0.574 vs. 0.078
# F1 = 0.600 vs. 0.109
# Accuracy = 0.577 vs. 0.056
# Validation
# AUC = 0.298 vs. 0.069
# F1 = 0.375 vs. 0.102
# Accuracy = 0.478 vs. 0.056
# Minibatch Loss= 0.339741
# Train Batch Evaluation
# AUC = 0.578 vs. 0.077
# F1 = 0.603 vs. 0.109
# Accuracy = 0.647 vs. 0.056
# Validation
# AUC = 0.317 vs. 0.073
# F1 = 0.384 vs. 0.107
# Accuracy = 0.571 vs. 0.056
# Minibatch Loss= 0.343805
# Train Batch Evaluation
# AUC = 0.583 vs. 0.077
# F1 = 0.607 vs. 0.109
# Accuracy = 0.693 vs. 0.056
# Validation
# AUC = 0.317 vs. 0.069
# F1 = 0.384 vs. 0.096
# Accuracy = 0.630 vs. 0.056
# Minibatch Loss= 0.323859
# Train Batch Evaluation
# AUC = 0.583 vs. 0.076
# F1 = 0.606 vs. 0.108
# Accuracy = 0.600 vs. 0.056
# Validation
# AUC = 0.306 vs. 0.070
# F1 = 0.384 vs. 0.100
# Accuracy = 0.505 vs. 0.056
# Minibatch Loss= 0.344570
# Train Batch Evaluation
# AUC = 0.586 vs. 0.077
# F1 = 0.607 vs. 0.109
# Accuracy = 0.543 vs. 0.056
# Validation
# AUC = 0.314 vs. 0.070
# F1 = 0.384 vs. 0.106
# Accuracy = 0.455 vs. 0.056
# Minibatch Loss= 0.335464
# Train Batch Evaluation
# AUC = 0.587 vs. 0.078
# F1 = 0.608 vs. 0.110
# Accuracy = 0.665 vs. 0.056
# Validation
# AUC = 0.314 vs. 0.072
# F1 = 0.390 vs. 0.114
# Accuracy = 0.598 vs. 0.056
# Minibatch Loss= 0.331418
# Train Batch Evaluation
# AUC = 0.591 vs. 0.077
# F1 = 0.613 vs. 0.108
# Accuracy = 0.688 vs. 0.056
# Validation
# AUC = 0.306 vs. 0.069
# F1 = 0.382 vs. 0.102
# Accuracy = 0.615 vs. 0.056
# Minibatch Loss= 0.320537
# Train Batch Evaluation
# AUC = 0.593 vs. 0.076
# F1 = 0.614 vs. 0.108
# Accuracy = 0.620 vs. 0.056
# Validation
# AUC = 0.304 vs. 0.069
# F1 = 0.389 vs. 0.099
# Accuracy = 0.542 vs. 0.056
# Minibatch Loss= 0.324228
# Train Batch Evaluation
# AUC = 0.598 vs. 0.077
# F1 = 0.616 vs. 0.108
# Accuracy = 0.668 vs. 0.056
# Validation
# AUC = 0.314 vs. 0.070
# F1 = 0.390 vs. 0.106
# Accuracy = 0.611 vs. 0.056
# Minibatch Loss= 0.310656
# Train Batch Evaluation
# AUC = 0.599 vs. 0.076
# F1 = 0.618 vs. 0.108
# Accuracy = 0.709 vs. 0.056
# Validation
# AUC = 0.322 vs. 0.069
# F1 = 0.396 vs. 0.097
# Accuracy = 0.649 vs. 0.056
# Minibatch Loss= 0.315055
# Train Batch Evaluation
# AUC = 0.598 vs. 0.076
# F1 = 0.618 vs. 0.108
# Accuracy = 0.612 vs. 0.056
# Validation
# AUC = 0.320 vs. 0.070
# F1 = 0.394 vs. 0.108
# Accuracy = 0.519 vs. 0.056
# Minibatch Loss= 0.304530
# Train Batch Evaluation
# AUC = 0.600 vs. 0.077
# F1 = 0.620 vs. 0.110
# Accuracy = 0.576 vs. 0.056
# Validation
# AUC = 0.317 vs. 0.072
# F1 = 0.393 vs. 0.100
# Accuracy = 0.480 vs. 0.056
# Minibatch Loss= 0.303464
# Train Batch Evaluation
# AUC = 0.603 vs. 0.077
# F1 = 0.621 vs. 0.109
# Accuracy = 0.711 vs. 0.056
# Validation
# AUC = 0.320 vs. 0.071
# F1 = 0.389 vs. 0.101
# Accuracy = 0.655 vs. 0.056
# Minibatch Loss= 0.299605
# Train Batch Evaluation
# AUC = 0.607 vs. 0.077
# F1 = 0.625 vs. 0.108
# Accuracy = 0.738 vs. 0.056
# Validation
# AUC = 0.321 vs. 0.072
# F1 = 0.393 vs. 0.099
# Accuracy = 0.688 vs. 0.056
# Minibatch Loss= 0.297482
# Train Batch Evaluation
# AUC = 0.608 vs. 0.077
# F1 = 0.627 vs. 0.108
# Accuracy = 0.646 vs. 0.056
# Validation
# AUC = 0.316 vs. 0.070
# F1 = 0.395 vs. 0.099
# Accuracy = 0.570 vs. 0.056
# Minibatch Loss= 0.294161
# Train Batch Evaluation
# AUC = 0.609 vs. 0.077
# F1 = 0.624 vs. 0.109
# Accuracy = 0.615 vs. 0.056
# Validation
# AUC = 0.311 vs. 0.071
# F1 = 0.386 vs. 0.105
# Accuracy = 0.525 vs. 0.056
# Minibatch Loss= 0.288974
# Train Batch Evaluation
# AUC = 0.613 vs. 0.076
# F1 = 0.625 vs. 0.109
# Accuracy = 0.693 vs. 0.056
# Validation
# AUC = 0.314 vs. 0.071
# F1 = 0.387 vs. 0.102
# Accuracy = 0.625 vs. 0.056
# Minibatch Loss= 0.291221
# Train Batch Evaluation
# AUC = 0.616 vs. 0.076
# F1 = 0.632 vs. 0.107
# Accuracy = 0.713 vs. 0.056
# Validation
# AUC = 0.315 vs. 0.072
# F1 = 0.392 vs. 0.107
# Accuracy = 0.659 vs. 0.056
# Minibatch Loss= 0.282646
# Train Batch Evaluation
# AUC = 0.616 vs. 0.077
# F1 = 0.633 vs. 0.108
# Accuracy = 0.705 vs. 0.056
# Validation
# AUC = 0.320 vs. 0.071
# F1 = 0.396 vs. 0.107
# Accuracy = 0.650 vs. 0.056
# Minibatch Loss= 0.285849
# Train Batch Evaluation
# AUC = 0.617 vs. 0.077
# F1 = 0.632 vs. 0.109
# Accuracy = 0.691 vs. 0.056
# Validation
# AUC = 0.319 vs. 0.070
# F1 = 0.393 vs. 0.102
# Accuracy = 0.618 vs. 0.056
# Minibatch Loss= 0.276201
# Train Batch Evaluation
# AUC = 0.618 vs. 0.077
# F1 = 0.632 vs. 0.108
# Accuracy = 0.693 vs. 0.056
# Validation
# AUC = 0.316 vs. 0.070
# F1 = 0.395 vs. 0.100
# Accuracy = 0.610 vs. 0.056
# Minibatch Loss= 0.282358
# Train Batch Evaluation
# AUC = 0.619 vs. 0.077
# F1 = 0.635 vs. 0.109
# Accuracy = 0.702 vs. 0.056
# Validation
# AUC = 0.318 vs. 0.073
# F1 = 0.393 vs. 0.109
# Accuracy = 0.635 vs. 0.056
# Minibatch Loss= 0.272415
# Train Batch Evaluation
# AUC = 0.621 vs. 0.076
# F1 = 0.638 vs. 0.109
# Accuracy = 0.710 vs. 0.056
# Validation
# AUC = 0.321 vs. 0.070
# F1 = 0.397 vs. 0.101
# Accuracy = 0.650 vs. 0.056
# Minibatch Loss= 0.275857
# Train Batch Evaluation
# AUC = 0.625 vs. 0.077
# F1 = 0.639 vs. 0.108
# Accuracy = 0.701 vs. 0.056
# Validation
# AUC = 0.320 vs. 0.070
# F1 = 0.397 vs. 0.098
# Accuracy = 0.633 vs. 0.056
# Minibatch Loss= 0.268547
# Train Batch Evaluation
# AUC = 0.625 vs. 0.076
# F1 = 0.640 vs. 0.108
# Accuracy = 0.688 vs. 0.056
# Validation
# AUC = 0.319 vs. 0.070
# F1 = 0.393 vs. 0.105
# Accuracy = 0.605 vs. 0.056
# Minibatch Loss= 0.270511
# Train Batch Evaluation
# AUC = 0.626 vs. 0.077
# F1 = 0.641 vs. 0.109
# Accuracy = 0.685 vs. 0.056
# Validation
# AUC = 0.318 vs. 0.071
# F1 = 0.394 vs. 0.103
# Accuracy = 0.608 vs. 0.056
# Minibatch Loss= 0.265509
# Train Batch Evaluation
# AUC = 0.629 vs. 0.077
# F1 = 0.642 vs. 0.109
# Accuracy = 0.717 vs. 0.056
# Validation
# AUC = 0.320 vs. 0.069
# F1 = 0.392 vs. 0.096
# Accuracy = 0.650 vs. 0.056
# Minibatch Loss= 0.265393
# Train Batch Evaluation
# AUC = 0.631 vs. 0.077
# F1 = 0.643 vs. 0.109
# Accuracy = 0.716 vs. 0.056
# Validation
# AUC = 0.320 vs. 0.068
# F1 = 0.396 vs. 0.093
# Accuracy = 0.655 vs. 0.056
# Minibatch Loss= 0.261242
# Train Batch Evaluation
# AUC = 0.631 vs. 0.077
# F1 = 0.644 vs. 0.108
# Accuracy = 0.688 vs. 0.056
# Validation
# AUC = 0.320 vs. 0.071
# F1 = 0.395 vs. 0.111
# Accuracy = 0.612 vs. 0.056
# Minibatch Loss= 0.261227
# Train Batch Evaluation
# AUC = 0.632 vs. 0.077
# F1 = 0.645 vs. 0.110
# Accuracy = 0.688 vs. 0.056
# Validation
# AUC = 0.322 vs. 0.074
# F1 = 0.395 vs. 0.110
# Accuracy = 0.605 vs. 0.056
# Minibatch Loss= 0.257647
# Train Batch Evaluation
# AUC = 0.633 vs. 0.076
# F1 = 0.647 vs. 0.108
# Accuracy = 0.727 vs. 0.056
# Validation
# AUC = 0.321 vs. 0.073
# F1 = 0.393 vs. 0.107
# Accuracy = 0.654 vs. 0.056
# Minibatch Loss= 0.257582
# Train Batch Evaluation
# AUC = 0.636 vs. 0.077
# F1 = 0.649 vs. 0.108
# Accuracy = 0.705 vs. 0.056
# Validation
# AUC = 0.321 vs. 0.073
# F1 = 0.396 vs. 0.112
# Accuracy = 0.642 vs. 0.056
# Minibatch Loss= 0.253391
# Train Batch Evaluation
# AUC = 0.638 vs. 0.077
# F1 = 0.650 vs. 0.108
# Accuracy = 0.702 vs. 0.056
# Validation
# AUC = 0.321 vs. 0.070
# F1 = 0.395 vs. 0.102
# Accuracy = 0.628 vs. 0.056
# Minibatch Loss= 0.253397
# Train Batch Evaluation
# AUC = 0.640 vs. 0.077
# F1 = 0.652 vs. 0.109
# Accuracy = 0.727 vs. 0.056
# Validation
# AUC = 0.325 vs. 0.069
# F1 = 0.396 vs. 0.097
# Accuracy = 0.648 vs. 0.056
# Minibatch Loss= 0.250109
# Train Batch Evaluation
# AUC = 0.641 vs. 0.077
# F1 = 0.653 vs. 0.108
# Accuracy = 0.716 vs. 0.056
# Validation
# AUC = 0.326 vs. 0.068
# F1 = 0.399 vs. 0.094
# Accuracy = 0.627 vs. 0.056
# Minibatch Loss= 0.249285
# Train Batch Evaluation
# AUC = 0.644 vs. 0.076
# F1 = 0.654 vs. 0.108
# Accuracy = 0.704 vs. 0.056
# Validation
# AUC = 0.329 vs. 0.071
# F1 = 0.398 vs. 0.106
# Accuracy = 0.621 vs. 0.056
# Minibatch Loss= 0.246583
# Train Batch Evaluation
# AUC = 0.645 vs. 0.077
# F1 = 0.655 vs. 0.108
# Accuracy = 0.728 vs. 0.056
# Validation
# AUC = 0.328 vs. 0.069
# F1 = 0.399 vs. 0.100
# Accuracy = 0.655 vs. 0.056
# Minibatch Loss= 0.245482
# Train Batch Evaluation
# AUC = 0.646 vs. 0.077
# F1 = 0.658 vs. 0.109
# Accuracy = 0.734 vs. 0.056
# Validation
# AUC = 0.326 vs. 0.070
# F1 = 0.401 vs. 0.100
# Accuracy = 0.665 vs. 0.056
# Minibatch Loss= 0.243498
# Train Batch Evaluation
# AUC = 0.647 vs. 0.077
# F1 = 0.659 vs. 0.108
# Accuracy = 0.721 vs. 0.056
# Validation
# AUC = 0.326 vs. 0.073
# F1 = 0.406 vs. 0.103
# Accuracy = 0.634 vs. 0.056
# Minibatch Loss= 0.241773
# Train Batch Evaluation
# AUC = 0.649 vs. 0.077
# F1 = 0.660 vs. 0.108
# Accuracy = 0.719 vs. 0.056
# Validation
# AUC = 0.330 vs. 0.071
# F1 = 0.402 vs. 0.103
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.240239
# Train Batch Evaluation
# AUC = 0.652 vs. 0.076
# F1 = 0.662 vs. 0.108
# Accuracy = 0.727 vs. 0.056
# Validation
# AUC = 0.332 vs. 0.069
# F1 = 0.402 vs. 0.098
# Accuracy = 0.653 vs. 0.056
# Minibatch Loss= 0.238058
# Train Batch Evaluation
# AUC = 0.653 vs. 0.077
# F1 = 0.663 vs. 0.108
# Accuracy = 0.733 vs. 0.056
# Validation
# AUC = 0.331 vs. 0.069
# F1 = 0.405 vs. 0.097
# Accuracy = 0.661 vs. 0.056
# Minibatch Loss= 0.236967
# Train Batch Evaluation
# AUC = 0.654 vs. 0.077
# F1 = 0.665 vs. 0.108
# Accuracy = 0.720 vs. 0.056
# Validation
# AUC = 0.331 vs. 0.072
# F1 = 0.402 vs. 0.105
# Accuracy = 0.632 vs. 0.056
# Minibatch Loss= 0.234815
# Train Batch Evaluation
# AUC = 0.656 vs. 0.078
# F1 = 0.666 vs. 0.109
# Accuracy = 0.727 vs. 0.056
# Validation
# AUC = 0.333 vs. 0.069
# F1 = 0.402 vs. 0.104
# Accuracy = 0.645 vs. 0.056
# Minibatch Loss= 0.233615
# Train Batch Evaluation
# AUC = 0.658 vs. 0.078
# F1 = 0.668 vs. 0.109
# Accuracy = 0.742 vs. 0.056
# Validation
# AUC = 0.335 vs. 0.069
# F1 = 0.404 vs. 0.097
# Accuracy = 0.677 vs. 0.056
# Minibatch Loss= 0.231807
# Train Batch Evaluation
# AUC = 0.659 vs. 0.076
# F1 = 0.669 vs. 0.107
# Accuracy = 0.750 vs. 0.056
# Validation
# AUC = 0.338 vs. 0.070
# F1 = 0.406 vs. 0.102
# Accuracy = 0.685 vs. 0.056
# Minibatch Loss= 0.230338
# Train Batch Evaluation
# AUC = 0.660 vs. 0.077
# F1 = 0.670 vs. 0.109
# Accuracy = 0.722 vs. 0.056
# Validation
# AUC = 0.336 vs. 0.076
# F1 = 0.406 vs. 0.112
# Accuracy = 0.629 vs. 0.056
# Minibatch Loss= 0.229244
# Train Batch Evaluation
# AUC = 0.662 vs. 0.077
# F1 = 0.672 vs. 0.108
# Accuracy = 0.743 vs. 0.056
# Validation
# AUC = 0.337 vs. 0.071
# F1 = 0.404 vs. 0.105
# Accuracy = 0.665 vs. 0.056
# Minibatch Loss= 0.227458
# Train Batch Evaluation
# AUC = 0.664 vs. 0.076
# F1 = 0.672 vs. 0.108
# Accuracy = 0.742 vs. 0.056
# Validation
# AUC = 0.335 vs. 0.073
# F1 = 0.401 vs. 0.105
# Accuracy = 0.667 vs. 0.056
# Minibatch Loss= 0.227630
# Train Batch Evaluation
# AUC = 0.665 vs. 0.078
# F1 = 0.673 vs. 0.109
# Accuracy = 0.749 vs. 0.056
# Validation
# AUC = 0.340 vs. 0.070
# F1 = 0.403 vs. 0.103
# Accuracy = 0.683 vs. 0.056
# Minibatch Loss= 0.227897
# Train Batch Evaluation
# AUC = 0.667 vs. 0.077
# F1 = 0.674 vs. 0.108
# Accuracy = 0.680 vs. 0.056
# Validation
# AUC = 0.337 vs. 0.070
# F1 = 0.403 vs. 0.104
# Accuracy = 0.576 vs. 0.056
# Minibatch Loss= 0.231785
# Train Batch Evaluation
# AUC = 0.667 vs. 0.077
# F1 = 0.675 vs. 0.108
# Accuracy = 0.764 vs. 0.056
# Validation
# AUC = 0.342 vs. 0.072
# F1 = 0.410 vs. 0.104
# Accuracy = 0.708 vs. 0.056
# Minibatch Loss= 0.239875
# Train Batch Evaluation
# AUC = 0.669 vs. 0.077
# F1 = 0.675 vs. 0.108
# Accuracy = 0.687 vs. 0.056
# Validation
# AUC = 0.336 vs. 0.070
# F1 = 0.404 vs. 0.101
# Accuracy = 0.581 vs. 0.056
# Minibatch Loss= 0.238585
# Train Batch Evaluation
# AUC = 0.671 vs. 0.077
# F1 = 0.677 vs. 0.109
# Accuracy = 0.751 vs. 0.056
# Validation
# AUC = 0.342 vs. 0.071
# F1 = 0.409 vs. 0.105
# Accuracy = 0.684 vs. 0.056
# Minibatch Loss= 0.225118
# Train Batch Evaluation
# AUC = 0.673 vs. 0.077
# F1 = 0.680 vs. 0.108
# Accuracy = 0.769 vs. 0.056
# Validation
# AUC = 0.341 vs. 0.072
# F1 = 0.410 vs. 0.105
# Accuracy = 0.706 vs. 0.056
# Minibatch Loss= 0.222539
# Train Batch Evaluation
# AUC = 0.674 vs. 0.077
# F1 = 0.678 vs. 0.109
# Accuracy = 0.668 vs. 0.056
# Validation
# AUC = 0.338 vs. 0.070
# F1 = 0.407 vs. 0.102
# Accuracy = 0.557 vs. 0.056
# Minibatch Loss= 0.236619
# Train Batch Evaluation
# AUC = 0.676 vs. 0.076
# F1 = 0.682 vs. 0.108
# Accuracy = 0.756 vs. 0.056
# Validation
# AUC = 0.344 vs. 0.069
# F1 = 0.407 vs. 0.096
# Accuracy = 0.690 vs. 0.056
# Minibatch Loss= 0.222554
# Train Batch Evaluation
# AUC = 0.679 vs. 0.076
# F1 = 0.682 vs. 0.108
# Accuracy = 0.798 vs. 0.056
# Validation
# AUC = 0.340 vs. 0.070
# F1 = 0.407 vs. 0.098
# Accuracy = 0.743 vs. 0.056
# Minibatch Loss= 0.225110
# Train Batch Evaluation
# AUC = 0.675 vs. 0.076
# F1 = 0.679 vs. 0.107
# Accuracy = 0.633 vs. 0.056
# Validation
# AUC = 0.338 vs. 0.074
# F1 = 0.409 vs. 0.112
# Accuracy = 0.520 vs. 0.056
# Minibatch Loss= 0.243629
# Train Batch Evaluation
# AUC = 0.679 vs. 0.076
# F1 = 0.684 vs. 0.107
# Accuracy = 0.739 vs. 0.056
# Validation
# AUC = 0.342 vs. 0.071
# F1 = 0.407 vs. 0.104
# Accuracy = 0.667 vs. 0.056
# Minibatch Loss= 0.218953
# Train Batch Evaluation
# AUC = 0.680 vs. 0.077
# F1 = 0.686 vs. 0.108
# Accuracy = 0.825 vs. 0.056
# Validation
# AUC = 0.342 vs. 0.070
# F1 = 0.409 vs. 0.095
# Accuracy = 0.777 vs. 0.056
# Minibatch Loss= 0.253745
# Train Batch Evaluation
# AUC = 0.675 vs. 0.077
# F1 = 0.677 vs. 0.109
# Accuracy = 0.550 vs. 0.056
# Validation
# AUC = 0.337 vs. 0.072
# F1 = 0.408 vs. 0.101
# Accuracy = 0.413 vs. 0.056
# Minibatch Loss= 0.280161
# Train Batch Evaluation
# AUC = 0.669 vs. 0.077
# F1 = 0.673 vs. 0.107
# Accuracy = 0.585 vs. 0.056
# Validation
# AUC = 0.326 vs. 0.069
# F1 = 0.401 vs. 0.098
# Accuracy = 0.463 vs. 0.056
# Minibatch Loss= 0.271028
# Train Batch Evaluation
# AUC = 0.680 vs. 0.077
# F1 = 0.683 vs. 0.108
# Accuracy = 0.799 vs. 0.056
# Validation
# AUC = 0.342 vs. 0.069
# F1 = 0.405 vs. 0.096
# Accuracy = 0.748 vs. 0.056
# Minibatch Loss= 0.239170
# Train Batch Evaluation
# AUC = 0.682 vs. 0.077
# F1 = 0.686 vs. 0.108
# Accuracy = 0.850 vs. 0.056
# Validation
# AUC = 0.340 vs. 0.070
# F1 = 0.410 vs. 0.099
# Accuracy = 0.810 vs. 0.056
# Minibatch Loss= 0.281798
# Train Batch Evaluation
# AUC = 0.678 vs. 0.076
# F1 = 0.680 vs. 0.108
# Accuracy = 0.650 vs. 0.056
# Validation
# AUC = 0.340 vs. 0.074
# F1 = 0.416 vs. 0.115
# Accuracy = 0.532 vs. 0.056
# Minibatch Loss= 0.255101
# Train Batch Evaluation
# AUC = 0.674 vs. 0.076
# F1 = 0.678 vs. 0.108
# Accuracy = 0.501 vs. 0.056
# Validation
# AUC = 0.341 vs. 0.071
# F1 = 0.409 vs. 0.101
# Accuracy = 0.378 vs. 0.056
# Minibatch Loss= 0.297841
# Train Batch Evaluation
# AUC = 0.683 vs. 0.076
# F1 = 0.683 vs. 0.108
# Accuracy = 0.678 vs. 0.056
# Validation
# AUC = 0.340 vs. 0.068
# F1 = 0.411 vs. 0.098
# Accuracy = 0.592 vs. 0.056
# Minibatch Loss= 0.241488
# Train Batch Evaluation
# AUC = 0.683 vs. 0.077
# F1 = 0.684 vs. 0.108
# Accuracy = 0.794 vs. 0.056
# Validation
# AUC = 0.342 vs. 0.068
# F1 = 0.417 vs. 0.095
# Accuracy = 0.745 vs. 0.056
# Minibatch Loss= 0.257203
# Train Batch Evaluation
# AUC = 0.688 vs. 0.077
# F1 = 0.686 vs. 0.107
# Accuracy = 0.815 vs. 0.056
# Validation
# AUC = 0.344 vs. 0.069
# F1 = 0.412 vs. 0.101
# Accuracy = 0.767 vs. 0.056
# Minibatch Loss= 0.245343
# Train Batch Evaluation
# AUC = 0.688 vs. 0.076
# F1 = 0.684 vs. 0.108
# Accuracy = 0.778 vs. 0.056
# Validation
# AUC = 0.347 vs. 0.069
# F1 = 0.415 vs. 0.102
# Accuracy = 0.719 vs. 0.056
# Minibatch Loss= 0.230617
# Train Batch Evaluation
# AUC = 0.686 vs. 0.078
# F1 = 0.684 vs. 0.109
# Accuracy = 0.687 vs. 0.056
# Validation
# AUC = 0.352 vs. 0.070
# F1 = 0.422 vs. 0.106
# Accuracy = 0.584 vs. 0.056
# Minibatch Loss= 0.244795
# Train Batch Evaluation
# AUC = 0.694 vs. 0.077
# F1 = 0.692 vs. 0.107
# Accuracy = 0.644 vs. 0.056
# Validation
# AUC = 0.367 vs. 0.069
# F1 = 0.430 vs. 0.099
# Accuracy = 0.543 vs. 0.056
# Minibatch Loss= 0.229465
# Train Batch Evaluation
# AUC = 0.696 vs. 0.076
# F1 = 0.697 vs. 0.108
# Accuracy = 0.692 vs. 0.056
# Validation
# AUC = 0.367 vs. 0.069
# F1 = 0.435 vs. 0.103
# Accuracy = 0.617 vs. 0.056
# Minibatch Loss= 0.228051
# Train Batch Evaluation
# AUC = 0.696 vs. 0.077
# F1 = 0.698 vs. 0.108
# Accuracy = 0.773 vs. 0.056
# Validation
# AUC = 0.358 vs. 0.070
# F1 = 0.421 vs. 0.098
# Accuracy = 0.707 vs. 0.056
# Minibatch Loss= 0.229362
# Train Batch Evaluation
# AUC = 0.700 vs. 0.077
# F1 = 0.699 vs. 0.108
# Accuracy = 0.756 vs. 0.056
# Validation
# AUC = 0.351 vs. 0.070
# F1 = 0.417 vs. 0.102
# Accuracy = 0.686 vs. 0.056
# Minibatch Loss= 0.216765
# Train Batch Evaluation
# AUC = 0.697 vs. 0.076
# F1 = 0.696 vs. 0.108
# Accuracy = 0.714 vs. 0.056
# Validation
# AUC = 0.343 vs. 0.076
# F1 = 0.414 vs. 0.106
# Accuracy = 0.637 vs. 0.056
# Minibatch Loss= 0.226770
# Train Batch Evaluation
# AUC = 0.699 vs. 0.076
# F1 = 0.700 vs. 0.108
# Accuracy = 0.737 vs. 0.056
# Validation
# AUC = 0.340 vs. 0.070
# F1 = 0.410 vs. 0.098
# Accuracy = 0.668 vs. 0.056
# Minibatch Loss= 0.217845
# Train Batch Evaluation
# AUC = 0.703 vs. 0.076
# F1 = 0.704 vs. 0.108
# Accuracy = 0.776 vs. 0.056
# Validation
# AUC = 0.345 vs. 0.069
# F1 = 0.415 vs. 0.103
# Accuracy = 0.731 vs. 0.056
# Minibatch Loss= 0.209644
# Train Batch Evaluation
# AUC = 0.702 vs. 0.076
# F1 = 0.705 vs. 0.107
# Accuracy = 0.771 vs. 0.056
# Validation
# AUC = 0.346 vs. 0.072
# F1 = 0.417 vs. 0.108
# Accuracy = 0.726 vs. 0.056
# Minibatch Loss= 0.215704
# Train Batch Evaluation
# AUC = 0.702 vs. 0.077
# F1 = 0.704 vs. 0.109
# Accuracy = 0.725 vs. 0.056
# Validation
# AUC = 0.343 vs. 0.072
# F1 = 0.418 vs. 0.110
# Accuracy = 0.648 vs. 0.056
# Minibatch Loss= 0.208223
# Train Batch Evaluation
# AUC = 0.700 vs. 0.077
# F1 = 0.701 vs. 0.110
# Accuracy = 0.712 vs. 0.056
# Validation
# AUC = 0.345 vs. 0.070
# F1 = 0.416 vs. 0.101
# Accuracy = 0.616 vs. 0.056
# Minibatch Loss= 0.207102
# Train Batch Evaluation
# AUC = 0.702 vs. 0.077
# F1 = 0.702 vs. 0.108
# Accuracy = 0.768 vs. 0.056
# Validation
# AUC = 0.344 vs. 0.069
# F1 = 0.414 vs. 0.102
# Accuracy = 0.703 vs. 0.056
# Minibatch Loss= 0.207951
# Train Batch Evaluation
# AUC = 0.707 vs. 0.077
# F1 = 0.707 vs. 0.109
# Accuracy = 0.805 vs. 0.056
# Validation
# AUC = 0.343 vs. 0.071
# F1 = 0.419 vs. 0.106
# Accuracy = 0.769 vs. 0.056
# Minibatch Loss= 0.201726
# Train Batch Evaluation
# AUC = 0.707 vs. 0.077
# F1 = 0.709 vs. 0.108
# Accuracy = 0.803 vs. 0.056
# Validation
# AUC = 0.346 vs. 0.068
# F1 = 0.426 vs. 0.099
# Accuracy = 0.764 vs. 0.056
# Minibatch Loss= 0.203564
# Train Batch Evaluation
# AUC = 0.708 vs. 0.077
# F1 = 0.708 vs. 0.108
# Accuracy = 0.772 vs. 0.056
# Validation
# AUC = 0.349 vs. 0.074
# F1 = 0.420 vs. 0.115
# Accuracy = 0.723 vs. 0.056
# Minibatch Loss= 0.199850
# Train Batch Evaluation
# AUC = 0.709 vs. 0.077
# F1 = 0.710 vs. 0.108
# Accuracy = 0.721 vs. 0.056
# Validation
# AUC = 0.352 vs. 0.070
# F1 = 0.419 vs. 0.099
# Accuracy = 0.638 vs. 0.056
# Minibatch Loss= 0.197399
# Train Batch Evaluation
# AUC = 0.710 vs. 0.077
# F1 = 0.711 vs. 0.107
# Accuracy = 0.711 vs. 0.056
# Validation
# AUC = 0.348 vs. 0.070
# F1 = 0.421 vs. 0.099
# Accuracy = 0.616 vs. 0.056
# Minibatch Loss= 0.198484
# Train Batch Evaluation
# AUC = 0.711 vs. 0.076
# F1 = 0.713 vs. 0.107
# Accuracy = 0.753 vs. 0.056
# Validation
# AUC = 0.350 vs. 0.069
# F1 = 0.423 vs. 0.097
# Accuracy = 0.686 vs. 0.056
# Minibatch Loss= 0.193797
# Train Batch Evaluation
# AUC = 0.713 vs. 0.077
# F1 = 0.714 vs. 0.109
# Accuracy = 0.797 vs. 0.056
# Validation
# AUC = 0.352 vs. 0.069
# F1 = 0.426 vs. 0.098
# Accuracy = 0.758 vs. 0.056
# Minibatch Loss= 0.194505
# Train Batch Evaluation
# AUC = 0.714 vs. 0.077
# F1 = 0.715 vs. 0.109
# Accuracy = 0.792 vs. 0.056
# Validation
# AUC = 0.351 vs. 0.069
# F1 = 0.426 vs. 0.096
# Accuracy = 0.757 vs. 0.056
# Minibatch Loss= 0.192153
# Train Batch Evaluation
# AUC = 0.714 vs. 0.076
# F1 = 0.714 vs. 0.108
# Accuracy = 0.767 vs. 0.056
# Validation
# AUC = 0.351 vs. 0.070
# F1 = 0.422 vs. 0.102
# Accuracy = 0.707 vs. 0.056
# Minibatch Loss= 0.190913
# Train Batch Evaluation
# AUC = 0.716 vs. 0.076
# F1 = 0.715 vs. 0.108
# Accuracy = 0.755 vs. 0.056
# Validation
# AUC = 0.352 vs. 0.069
# F1 = 0.420 vs. 0.099
# Accuracy = 0.684 vs. 0.056
# Minibatch Loss= 0.190222
# Train Batch Evaluation
# AUC = 0.717 vs. 0.076
# F1 = 0.717 vs. 0.108
# Accuracy = 0.783 vs. 0.056
# Validation
# AUC = 0.354 vs. 0.072
# F1 = 0.428 vs. 0.103
# Accuracy = 0.725 vs. 0.056
# Minibatch Loss= 0.187386
# Train Batch Evaluation
# AUC = 0.717 vs. 0.077
# F1 = 0.720 vs. 0.108
# Accuracy = 0.803 vs. 0.056
# Validation
# AUC = 0.350 vs. 0.069
# F1 = 0.426 vs. 0.095
# Accuracy = 0.760 vs. 0.056
# Minibatch Loss= 0.187868
# Train Batch Evaluation
# AUC = 0.717 vs. 0.077
# F1 = 0.720 vs. 0.108
# Accuracy = 0.791 vs. 0.056
# Validation
# AUC = 0.349 vs. 0.070
# F1 = 0.427 vs. 0.105
# Accuracy = 0.740 vs. 0.056
# Minibatch Loss= 0.185431
# Train Batch Evaluation
# AUC = 0.718 vs. 0.077
# F1 = 0.719 vs. 0.108
# Accuracy = 0.771 vs. 0.056
# Validation
# AUC = 0.347 vs. 0.070
# F1 = 0.428 vs. 0.102
# Accuracy = 0.711 vs. 0.056
# Minibatch Loss= 0.184692
# Train Batch Evaluation
# AUC = 0.717 vs. 0.077
# F1 = 0.720 vs. 0.109
# Accuracy = 0.774 vs. 0.056
# Validation
# AUC = 0.350 vs. 0.068
# F1 = 0.429 vs. 0.099
# Accuracy = 0.708 vs. 0.056
# Minibatch Loss= 0.183977
# Train Batch Evaluation
# AUC = 0.719 vs. 0.077
# F1 = 0.720 vs. 0.108
# Accuracy = 0.792 vs. 0.056
# Validation
# AUC = 0.352 vs. 0.071
# F1 = 0.429 vs. 0.104
# Accuracy = 0.738 vs. 0.056
# Minibatch Loss= 0.182348
# Train Batch Evaluation
# AUC = 0.721 vs. 0.077
# F1 = 0.722 vs. 0.108
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.355 vs. 0.074
# F1 = 0.430 vs. 0.109
# Accuracy = 0.745 vs. 0.056
# Minibatch Loss= 0.181614
# Train Batch Evaluation
# AUC = 0.722 vs. 0.077
# F1 = 0.722 vs. 0.108
# Accuracy = 0.780 vs. 0.056
# Validation
# AUC = 0.356 vs. 0.069
# F1 = 0.431 vs. 0.098
# Accuracy = 0.718 vs. 0.056
# Minibatch Loss= 0.180282
# Train Batch Evaluation
# AUC = 0.723 vs. 0.077
# F1 = 0.723 vs. 0.108
# Accuracy = 0.754 vs. 0.056
# Validation
# AUC = 0.356 vs. 0.071
# F1 = 0.428 vs. 0.104
# Accuracy = 0.682 vs. 0.056
# Minibatch Loss= 0.179428
# Train Batch Evaluation
# AUC = 0.724 vs. 0.076
# F1 = 0.724 vs. 0.108
# Accuracy = 0.763 vs. 0.056
# Validation
# AUC = 0.356 vs. 0.069
# F1 = 0.429 vs. 0.100
# Accuracy = 0.692 vs. 0.056
# Minibatch Loss= 0.178619
# Train Batch Evaluation
# AUC = 0.725 vs. 0.077
# F1 = 0.725 vs. 0.108
# Accuracy = 0.790 vs. 0.056
# Validation
# AUC = 0.354 vs. 0.069
# F1 = 0.429 vs. 0.095
# Accuracy = 0.730 vs. 0.056
# Minibatch Loss= 0.177524
# Train Batch Evaluation
# AUC = 0.726 vs. 0.076
# F1 = 0.726 vs. 0.109
# Accuracy = 0.798 vs. 0.056
# Validation
# AUC = 0.354 vs. 0.071
# F1 = 0.430 vs. 0.106
# Accuracy = 0.742 vs. 0.056
# Minibatch Loss= 0.176141
# Train Batch Evaluation
# AUC = 0.727 vs. 0.077
# F1 = 0.725 vs. 0.108
# Accuracy = 0.795 vs. 0.056
# Validation
# AUC = 0.356 vs. 0.071
# F1 = 0.429 vs. 0.105
# Accuracy = 0.736 vs. 0.056
# Minibatch Loss= 0.175917
# Train Batch Evaluation
# AUC = 0.727 vs. 0.077
# F1 = 0.726 vs. 0.108
# Accuracy = 0.793 vs. 0.056
# Validation
# AUC = 0.356 vs. 0.071
# F1 = 0.429 vs. 0.107
# Accuracy = 0.732 vs. 0.056
# Minibatch Loss= 0.174438
# Train Batch Evaluation
# AUC = 0.728 vs. 0.077
# F1 = 0.727 vs. 0.108
# Accuracy = 0.789 vs. 0.056
# Validation
# AUC = 0.353 vs. 0.070
# F1 = 0.430 vs. 0.102
# Accuracy = 0.723 vs. 0.056
# Minibatch Loss= 0.174180
# Train Batch Evaluation
# AUC = 0.728 vs. 0.077
# F1 = 0.728 vs. 0.107
# Accuracy = 0.780 vs. 0.056
# Validation
# AUC = 0.361 vs. 0.071
# F1 = 0.433 vs. 0.101
# Accuracy = 0.714 vs. 0.056
# Minibatch Loss= 0.172930
# Train Batch Evaluation
# AUC = 0.730 vs. 0.077
# F1 = 0.729 vs. 0.109
# Accuracy = 0.783 vs. 0.056
# Validation
# AUC = 0.358 vs. 0.070
# F1 = 0.433 vs. 0.100
# Accuracy = 0.708 vs. 0.056
# Minibatch Loss= 0.172172
# Train Batch Evaluation
# AUC = 0.731 vs. 0.076
# F1 = 0.730 vs. 0.107
# Accuracy = 0.792 vs. 0.056
# Validation
# AUC = 0.359 vs. 0.069
# F1 = 0.432 vs. 0.098
# Accuracy = 0.733 vs. 0.056
# Minibatch Loss= 0.171167
# Train Batch Evaluation
# AUC = 0.731 vs. 0.077
# F1 = 0.729 vs. 0.109
# Accuracy = 0.796 vs. 0.056
# Validation
# AUC = 0.358 vs. 0.072
# F1 = 0.432 vs. 0.100
# Accuracy = 0.740 vs. 0.056
# Minibatch Loss= 0.170188
# Train Batch Evaluation
# AUC = 0.732 vs. 0.077
# F1 = 0.731 vs. 0.108
# Accuracy = 0.794 vs. 0.056
# Validation
# AUC = 0.358 vs. 0.073
# F1 = 0.432 vs. 0.106
# Accuracy = 0.737 vs. 0.056
# Minibatch Loss= 0.169569
# Train Batch Evaluation
# AUC = 0.733 vs. 0.077
# F1 = 0.732 vs. 0.109
# Accuracy = 0.786 vs. 0.056
# Validation
# AUC = 0.361 vs. 0.069
# F1 = 0.433 vs. 0.100
# Accuracy = 0.721 vs. 0.056
# Minibatch Loss= 0.168686
# Train Batch Evaluation
# AUC = 0.734 vs. 0.077
# F1 = 0.733 vs. 0.108
# Accuracy = 0.785 vs. 0.056
# Validation
# AUC = 0.362 vs. 0.069
# F1 = 0.434 vs. 0.097
# Accuracy = 0.717 vs. 0.056
# Minibatch Loss= 0.168027
# Train Batch Evaluation
# AUC = 0.734 vs. 0.077
# F1 = 0.733 vs. 0.109
# Accuracy = 0.797 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.071
# F1 = 0.432 vs. 0.103
# Accuracy = 0.733 vs. 0.056
# Minibatch Loss= 0.167387
# Train Batch Evaluation
# AUC = 0.735 vs. 0.077
# F1 = 0.734 vs. 0.109
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.357 vs. 0.071
# F1 = 0.429 vs. 0.107
# Accuracy = 0.741 vs. 0.056
# Minibatch Loss= 0.166628
# Train Batch Evaluation
# AUC = 0.736 vs. 0.077
# F1 = 0.734 vs. 0.108
# Accuracy = 0.793 vs. 0.056
# Validation
# AUC = 0.359 vs. 0.070
# F1 = 0.432 vs. 0.102
# Accuracy = 0.731 vs. 0.056
# Minibatch Loss= 0.166073
# Train Batch Evaluation
# AUC = 0.737 vs. 0.078
# F1 = 0.736 vs. 0.109
# Accuracy = 0.797 vs. 0.056
# Validation
# AUC = 0.358 vs. 0.071
# F1 = 0.430 vs. 0.107
# Accuracy = 0.735 vs. 0.056
# Minibatch Loss= 0.165442
# Train Batch Evaluation
# AUC = 0.737 vs. 0.076
# F1 = 0.737 vs. 0.108
# Accuracy = 0.803 vs. 0.056
# Validation
# AUC = 0.360 vs. 0.070
# F1 = 0.432 vs. 0.098
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.165265
# Train Batch Evaluation
# AUC = 0.738 vs. 0.077
# F1 = 0.737 vs. 0.108
# Accuracy = 0.800 vs. 0.056
# Validation
# AUC = 0.356 vs. 0.069
# F1 = 0.431 vs. 0.096
# Accuracy = 0.737 vs. 0.056
# Minibatch Loss= 0.164727
# Train Batch Evaluation
# AUC = 0.739 vs. 0.077
# F1 = 0.737 vs. 0.108
# Accuracy = 0.798 vs. 0.056
# Validation
# AUC = 0.361 vs. 0.068
# F1 = 0.433 vs. 0.094
# Accuracy = 0.735 vs. 0.056
# Minibatch Loss= 0.165111
# Train Batch Evaluation
# AUC = 0.740 vs. 0.077
# F1 = 0.738 vs. 0.108
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.357 vs. 0.072
# F1 = 0.428 vs. 0.107
# Accuracy = 0.736 vs. 0.056
# Minibatch Loss= 0.164323
# Train Batch Evaluation
# AUC = 0.740 vs. 0.078
# F1 = 0.739 vs. 0.109
# Accuracy = 0.802 vs. 0.056
# Validation
# AUC = 0.362 vs. 0.071
# F1 = 0.436 vs. 0.107
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.165938
# Train Batch Evaluation
# AUC = 0.741 vs. 0.077
# F1 = 0.739 vs. 0.109
# Accuracy = 0.802 vs. 0.056
# Validation
# AUC = 0.357 vs. 0.068
# F1 = 0.430 vs. 0.096
# Accuracy = 0.732 vs. 0.056
# Minibatch Loss= 0.164174
# Train Batch Evaluation
# AUC = 0.742 vs. 0.076
# F1 = 0.740 vs. 0.107
# Accuracy = 0.798 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.073
# F1 = 0.436 vs. 0.103
# Accuracy = 0.738 vs. 0.056
# Minibatch Loss= 0.165549
# Train Batch Evaluation
# AUC = 0.743 vs. 0.077
# F1 = 0.740 vs. 0.108
# Accuracy = 0.802 vs. 0.056
# Validation
# AUC = 0.358 vs. 0.068
# F1 = 0.431 vs. 0.093
# Accuracy = 0.735 vs. 0.056
# Minibatch Loss= 0.161851
# Train Batch Evaluation
# AUC = 0.744 vs. 0.077
# F1 = 0.742 vs. 0.109
# Accuracy = 0.807 vs. 0.056
# Validation
# AUC = 0.364 vs. 0.070
# F1 = 0.438 vs. 0.101
# Accuracy = 0.750 vs. 0.056
# Minibatch Loss= 0.160650
# Train Batch Evaluation
# AUC = 0.745 vs. 0.077
# F1 = 0.742 vs. 0.109
# Accuracy = 0.806 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.073
# F1 = 0.434 vs. 0.103
# Accuracy = 0.744 vs. 0.056
# Minibatch Loss= 0.158640
# Train Batch Evaluation
# AUC = 0.746 vs. 0.076
# F1 = 0.743 vs. 0.108
# Accuracy = 0.803 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.069
# F1 = 0.435 vs. 0.101
# Accuracy = 0.742 vs. 0.056
# Minibatch Loss= 0.157554
# Train Batch Evaluation
# AUC = 0.746 vs. 0.076
# F1 = 0.743 vs. 0.108
# Accuracy = 0.805 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.070
# F1 = 0.433 vs. 0.099
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.156734
# Train Batch Evaluation
# AUC = 0.747 vs. 0.078
# F1 = 0.745 vs. 0.110
# Accuracy = 0.807 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.070
# F1 = 0.433 vs. 0.101
# Accuracy = 0.752 vs. 0.056
# Minibatch Loss= 0.156229
# Train Batch Evaluation
# AUC = 0.747 vs. 0.077
# F1 = 0.745 vs. 0.109
# Accuracy = 0.805 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.073
# F1 = 0.436 vs. 0.104
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.155878
# Train Batch Evaluation
# AUC = 0.748 vs. 0.077
# F1 = 0.745 vs. 0.108
# Accuracy = 0.807 vs. 0.056
# Validation
# AUC = 0.363 vs. 0.070
# F1 = 0.432 vs. 0.100
# Accuracy = 0.745 vs. 0.056
# Minibatch Loss= 0.155782
# Train Batch Evaluation
# AUC = 0.748 vs. 0.076
# F1 = 0.747 vs. 0.108
# Accuracy = 0.811 vs. 0.056
# Validation
# AUC = 0.364 vs. 0.068
# F1 = 0.436 vs. 0.098
# Accuracy = 0.750 vs. 0.056
# Minibatch Loss= 0.156802
# Train Batch Evaluation
# AUC = 0.749 vs. 0.077
# F1 = 0.747 vs. 0.107
# Accuracy = 0.810 vs. 0.056
# Validation
# AUC = 0.359 vs. 0.070
# F1 = 0.433 vs. 0.098
# Accuracy = 0.748 vs. 0.056
# Minibatch Loss= 0.157144
# Train Batch Evaluation
# AUC = 0.749 vs. 0.077
# F1 = 0.747 vs. 0.109
# Accuracy = 0.806 vs. 0.056
# Validation
# AUC = 0.366 vs. 0.071
# F1 = 0.438 vs. 0.111
# Accuracy = 0.746 vs. 0.056
# Minibatch Loss= 0.162951
# Train Batch Evaluation
# AUC = 0.751 vs. 0.078
# F1 = 0.748 vs. 0.109
# Accuracy = 0.801 vs. 0.056
# Validation
# AUC = 0.359 vs. 0.070
# F1 = 0.432 vs. 0.099
# Accuracy = 0.734 vs. 0.056
# Minibatch Loss= 0.158706
# Train Batch Evaluation
# AUC = 0.751 vs. 0.077
# F1 = 0.749 vs. 0.108
# Accuracy = 0.813 vs. 0.056
# Validation
# AUC = 0.368 vs. 0.075
# F1 = 0.441 vs. 0.112
# Accuracy = 0.753 vs. 0.056
# Minibatch Loss= 0.161664
# Train Batch Evaluation
# AUC = 0.753 vs. 0.077
# F1 = 0.749 vs. 0.109
# Accuracy = 0.800 vs. 0.056
# Validation
# AUC = 0.364 vs. 0.069
# F1 = 0.433 vs. 0.099
# Accuracy = 0.731 vs. 0.056
# Minibatch Loss= 0.154169
# Train Batch Evaluation
# AUC = 0.754 vs. 0.076
# F1 = 0.751 vs. 0.108
# Accuracy = 0.817 vs. 0.056
# Validation
# AUC = 0.367 vs. 0.070
# F1 = 0.436 vs. 0.098
# Accuracy = 0.756 vs. 0.056
# Minibatch Loss= 0.151222
# Train Batch Evaluation
# AUC = 0.754 vs. 0.077
# F1 = 0.752 vs. 0.108
# Accuracy = 0.813 vs. 0.056
# Validation
# AUC = 0.368 vs. 0.071
# F1 = 0.436 vs. 0.107
# Accuracy = 0.755 vs. 0.056
# Minibatch Loss= 0.150837
# Train Batch Evaluation
# AUC = 0.755 vs. 0.078
# F1 = 0.752 vs. 0.109
# Accuracy = 0.810 vs. 0.056
# Validation
# AUC = 0.366 vs. 0.071
# F1 = 0.433 vs. 0.098
# Accuracy = 0.744 vs. 0.056
# Minibatch Loss= 0.152415
# Train Batch Evaluation
# AUC = 0.755 vs. 0.078
# F1 = 0.753 vs. 0.110
# Accuracy = 0.814 vs. 0.056
# Validation
# AUC = 0.370 vs. 0.070
# F1 = 0.439 vs. 0.103
# Accuracy = 0.752 vs. 0.056
# Minibatch Loss= 0.157989
# Train Batch Evaluation
# AUC = 0.756 vs. 0.077
# F1 = 0.753 vs. 0.108
# Accuracy = 0.799 vs. 0.056
# Validation
# AUC = 0.362 vs. 0.071
# F1 = 0.432 vs. 0.106
# Accuracy = 0.735 vs. 0.056
# Minibatch Loss= 0.154473
# Train Batch Evaluation
# AUC = 0.757 vs. 0.077
# F1 = 0.754 vs. 0.108
# Accuracy = 0.819 vs. 0.056
# Validation
# AUC = 0.372 vs. 0.072
# F1 = 0.445 vs. 0.110
# Accuracy = 0.758 vs. 0.056
# Minibatch Loss= 0.156564
# Train Batch Evaluation
# AUC = 0.758 vs. 0.077
# F1 = 0.756 vs. 0.108
# Accuracy = 0.812 vs. 0.056
# Validation
# AUC = 0.367 vs. 0.072
# F1 = 0.433 vs. 0.104
# Accuracy = 0.747 vs. 0.056
# Minibatch Loss= 0.149241
# Train Batch Evaluation
# AUC = 0.759 vs. 0.077
# F1 = 0.757 vs. 0.108
# Accuracy = 0.821 vs. 0.056
# Validation
# AUC = 0.368 vs. 0.075
# F1 = 0.436 vs. 0.113
# Accuracy = 0.756 vs. 0.056
# Minibatch Loss= 0.147864
# Train Batch Evaluation
# AUC = 0.759 vs. 0.077
# F1 = 0.757 vs. 0.108
# Accuracy = 0.816 vs. 0.056
# Validation
# AUC = 0.371 vs. 0.069
# F1 = 0.442 vs. 0.098
# Accuracy = 0.753 vs. 0.056
# Minibatch Loss= 0.150994
# Train Batch Evaluation
# AUC = 0.760 vs. 0.077
# F1 = 0.758 vs. 0.108
# Accuracy = 0.810 vs. 0.056
# Validation
# AUC = 0.364 vs. 0.071
# F1 = 0.432 vs. 0.105
# Accuracy = 0.742 vs. 0.056
# Minibatch Loss= 0.151744
# Train Batch Evaluation
# AUC = 0.760 vs. 0.077
# F1 = 0.758 vs. 0.109
# Accuracy = 0.816 vs. 0.056
# Validation
# AUC = 0.374 vs. 0.071
# F1 = 0.446 vs. 0.098
# Accuracy = 0.754 vs. 0.056
# Minibatch Loss= 0.158668
# Train Batch Evaluation
# AUC = 0.761 vs. 0.077
# F1 = 0.759 vs. 0.108
# Accuracy = 0.796 vs. 0.056
# Validation
# AUC = 0.369 vs. 0.071
# F1 = 0.436 vs. 0.102
# Accuracy = 0.727 vs. 0.056
# Minibatch Loss= 0.148739
# Train Batch Evaluation
# AUC = 0.762 vs. 0.076
# F1 = 0.761 vs. 0.108
# Accuracy = 0.829 vs. 0.056
# Validation
# AUC = 0.373 vs. 0.070
# F1 = 0.440 vs. 0.098
# Accuracy = 0.763 vs. 0.056
# Minibatch Loss= 0.145036
# Train Batch Evaluation
# ...
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019887
# Train Batch Evaluation
# AUC = 0.985 vs. 0.076
# F1 = 0.980 vs. 0.107
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.068
# F1 = 0.576 vs. 0.099
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019871
# Train Batch Evaluation
# AUC = 0.985 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.072
# F1 = 0.576 vs. 0.108
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019857
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.070
# F1 = 0.576 vs. 0.103
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019842
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.072
# F1 = 0.576 vs. 0.106
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019825
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.068
# F1 = 0.576 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019808
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.069
# F1 = 0.576 vs. 0.097
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019791
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.107
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.069
# F1 = 0.576 vs. 0.097
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019774
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.070
# F1 = 0.577 vs. 0.105
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019759
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.107
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.068
# F1 = 0.577 vs. 0.092
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019744
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.070
# F1 = 0.576 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019729
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.069
# F1 = 0.576 vs. 0.097
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019712
# Train Batch Evaluation
# AUC = 0.985 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.069
# F1 = 0.576 vs. 0.100
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019697
# Train Batch Evaluation
# AUC = 0.985 vs. 0.075
# F1 = 0.980 vs. 0.107
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.070
# F1 = 0.576 vs. 0.104
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019682
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.069
# F1 = 0.576 vs. 0.097
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019666
# Train Batch Evaluation
# AUC = 0.985 vs. 0.076
# F1 = 0.980 vs. 0.107
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.517 vs. 0.076
# F1 = 0.576 vs. 0.115
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019648
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.069
# F1 = 0.576 vs. 0.101
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019631
# Train Batch Evaluation
# AUC = 0.985 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.069
# F1 = 0.576 vs. 0.100
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019615
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.107
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.072
# F1 = 0.576 vs. 0.116
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019599
# Train Batch Evaluation
# AUC = 0.985 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.070
# F1 = 0.576 vs. 0.097
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019583
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.069
# F1 = 0.576 vs. 0.097
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019568
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.110
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.067
# F1 = 0.576 vs. 0.095
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019555
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.069
# F1 = 0.576 vs. 0.096
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019539
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.070
# F1 = 0.576 vs. 0.102
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019523
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.071
# F1 = 0.576 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019505
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.076
# F1 = 0.576 vs. 0.114
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019488
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.072
# F1 = 0.576 vs. 0.103
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019473
# Train Batch Evaluation
# AUC = 0.986 vs. 0.078
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.072
# F1 = 0.576 vs. 0.109
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019457
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.071
# F1 = 0.576 vs. 0.100
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019441
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.068
# F1 = 0.576 vs. 0.096
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019425
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.073
# F1 = 0.576 vs. 0.106
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019410
# Train Batch Evaluation
# AUC = 0.986 vs. 0.078
# F1 = 0.980 vs. 0.110
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.073
# F1 = 0.575 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019395
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.070
# F1 = 0.576 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019382
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.070
# F1 = 0.575 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019368
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.110
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.074
# F1 = 0.575 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019352
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.071
# F1 = 0.575 vs. 0.102
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019333
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.069
# F1 = 0.575 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019316
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.069
# F1 = 0.575 vs. 0.095
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019300
# Train Batch Evaluation
# AUC = 0.986 vs. 0.078
# F1 = 0.980 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.075
# F1 = 0.575 vs. 0.110
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019284
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.070
# F1 = 0.575 vs. 0.098
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019269
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.980 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.072
# F1 = 0.575 vs. 0.106
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019254
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.110
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.074
# F1 = 0.575 vs. 0.106
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019239
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.069
# F1 = 0.575 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019223
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.069
# F1 = 0.575 vs. 0.102
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019207
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.107
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.072
# F1 = 0.575 vs. 0.109
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019193
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.070
# F1 = 0.575 vs. 0.104
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019180
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.071
# F1 = 0.575 vs. 0.104
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019165
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.069
# F1 = 0.575 vs. 0.096
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019149
# Train Batch Evaluation
# AUC = 0.986 vs. 0.078
# F1 = 0.981 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.070
# F1 = 0.575 vs. 0.102
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019132
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.072
# F1 = 0.575 vs. 0.099
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019114
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.072
# F1 = 0.575 vs. 0.105
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019099
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.111
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.070
# F1 = 0.575 vs. 0.096
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019084
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.070
# F1 = 0.575 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019069
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.072
# F1 = 0.576 vs. 0.097
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019054
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.072
# F1 = 0.575 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.019038
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.071
# F1 = 0.575 vs. 0.102
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019024
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.524 vs. 0.072
# F1 = 0.575 vs. 0.107
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.019011
# Train Batch Evaluation
# AUC = 0.986 vs. 0.076
# F1 = 0.981 vs. 0.107
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.071
# F1 = 0.575 vs. 0.104
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018996
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.069
# F1 = 0.576 vs. 0.098
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.018980
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.519 vs. 0.070
# F1 = 0.576 vs. 0.096
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.018963
# Train Batch Evaluation
# AUC = 0.986 vs. 0.078
# F1 = 0.981 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.521 vs. 0.070
# F1 = 0.576 vs. 0.105
# Accuracy = 0.917 vs. 0.056
# Minibatch Loss= 0.018947
# Train Batch Evaluation
# AUC = 0.986 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.519 vs. 0.068
# F1 = 0.576 vs. 0.099
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018932
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.519 vs. 0.071
# F1 = 0.576 vs. 0.099
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018916
# Train Batch Evaluation
# AUC = 0.987 vs. 0.076
# F1 = 0.981 vs. 0.107
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.071
# F1 = 0.576 vs. 0.097
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018900
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.520 vs. 0.069
# F1 = 0.576 vs. 0.100
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018886
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.518 vs. 0.071
# F1 = 0.576 vs. 0.105
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018871
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.109
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.071
# F1 = 0.576 vs. 0.101
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018857
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.109
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.516 vs. 0.069
# F1 = 0.576 vs. 0.099
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018844
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.073
# F1 = 0.575 vs. 0.107
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018829
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.073
# F1 = 0.576 vs. 0.114
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018811
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# AUC = 0.522 vs. 0.068
# F1 = 0.575 vs. 0.096
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018795
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.523 vs. 0.069
# F1 = 0.575 vs. 0.101
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018780
# Train Batch Evaluation
# AUC = 0.987 vs. 0.076
# F1 = 0.981 vs. 0.108
# Accuracy = 0.986 vs. 0.056
# Validation
# AUC = 0.519 vs. 0.072
# F1 = 0.575 vs. 0.104
# Accuracy = 0.916 vs. 0.056
# Minibatch Loss= 0.018766
# Train Batch Evaluation
# AUC = 0.987 vs. 0.077
# F1 = 0.981 vs. 0.108
# Accuracy = 0.985 vs. 0.056
# Validation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-340a4186f466> in <module>()
#       2                 train_eval_step = 1,
#       3                 validation_eval_step = 1,
# ----> 4                 display_step = 1)
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     108
#     109                 print("Validation")
# --> 110                 eval_result = self.evaluate_model(self.model, self.sess, self.data_validation, self.ground_truth_validation)
#     111
#     112                 #summary np.array
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/evaluation/nn_eval_activity.pyc in evaluate_model(model, sess, data, ground_truth)
#     102         if np.max(pooled_y[:,:,i]) > 0:
#     103             result.append(auc(probability_of_pos[:,:,i],
# --> 104                          (pooled_y[:,:,i]>0.5).astype('int32')))
#     105
#     106     auc_result = float(sum([i[0] for i in result]))/ float(len(result))
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/evaluation/nn_eval_activity.pyc in auc(prob_of_pos, gt)
#      28     #the precision recall curve
#      29     for i in range(idx_true_gt.shape[0]):
# ---> 30         output_prec.append(float(i + 1) / float(idx_true_gt[i] + 1))
#      31         output_rec.append(float(i + 1) / float(idx_true_gt.shape[0]))
#      32
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/DWN9001_opp/checkpoint-3474'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.520 vs. 0.071
# F1 = 0.575 vs. 0.109
# Accuracy = 0.916 vs. 0.056

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
# Out:
# 1
