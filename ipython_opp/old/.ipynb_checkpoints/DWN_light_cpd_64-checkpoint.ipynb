# %%
# useing this variable for saving models and summaries
exp_name = "DWN_light_cpd_64"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model_light as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp7.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((1358, 1024, 77), (1358, 1024, 1))

# %%
test_data.shape, test_gt.shape
# Out:
# ((233, 1024, 77), (233, 1024, 1))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 5    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_kernel_size = 5    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

# %%
train_data.shape
# Out:
# (1358, 1024, 77)

# %%
pos_weight.shape
# Out:
# (1,)

# %%
pos_weight
# Out:
# array([ 2.15172601], dtype=float32)

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_kernel_size = wavelet_kernel_size,    
                                 activation = activation,
                                 trainable_wavelet=False,
                                 trainable_conv=False,
                                 trainable_last=True)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'change')

# %%
#load the model
saver = tf.train.Saver(var_list = [
    model.weights['wc0'],model.weights['wc1'],model.weights['wc2'],
    model.bias['bc0'],model.bias['bc1'],model.bias['bc2'],
    model.weights['high_pass'],model.weights['low_pass']
])
saver.restore(sess, '../model/DWN9009_opp/checkpoint-4000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/DWN9009_opp/checkpoint-4000

# %%
trainer.run_debug_ops()
# Out:
# {'input_shape': array([ 100, 1024,   77], dtype=int32)}

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# AUC = 0.300 vs. 0.280
# F1 = 0.431 vs. 0.431
# Precision = 0.275 vs. 0.275
# Recall = 0.998 vs. 1.000
# Validation
# AUC = 0.268 vs. 0.188
# F1 = 0.325 vs. 0.317
# Precision = 0.246 vs. 0.189
# Recall = 0.477 vs. 0.999
# Minibatch Loss= 5.230678
# Train Batch Evaluation
# AUC = 0.525 vs. 0.287
# F1 = 0.526 vs. 0.464
# Precision = 0.467 vs. 0.302
# Recall = 0.602 vs. 1.000
# Validation
# AUC = 0.463 vs. 0.194
# F1 = 0.497 vs. 0.317
# Precision = 0.505 vs. 0.189
# Recall = 0.489 vs. 0.997
# Minibatch Loss= 2.799953
# Train Batch Evaluation
# AUC = 0.602 vs. 0.291
# F1 = 0.567 vs. 0.422
# Precision = 0.454 vs. 0.271
# Recall = 0.756 vs. 0.955
# Validation
# AUC = 0.474 vs. 0.184
# F1 = 0.513 vs. 0.317
# Precision = 0.495 vs. 0.188
# Recall = 0.531 vs. 1.000
# Minibatch Loss= 1.637616
# Train Batch Evaluation
# AUC = 0.640 vs. 0.360
# F1 = 0.645 vs. 0.511
# Precision = 0.528 vs. 0.343
# Recall = 0.830 vs. 1.000
# Validation
# AUC = 0.494 vs. 0.205
# F1 = 0.521 vs. 0.318
# Precision = 0.455 vs. 0.189
# Recall = 0.610 vs. 0.993
# Minibatch Loss= 1.630648
# Train Batch Evaluation
# AUC = 0.685 vs. 0.347
# F1 = 0.690 vs. 0.512
# Precision = 0.585 vs. 0.344
# Recall = 0.840 vs. 1.000
# Validation
# AUC = 0.503 vs. 0.189
# F1 = 0.528 vs. 0.318
# Precision = 0.408 vs. 0.189
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 1.335008
# Train Batch Evaluation
# AUC = 0.666 vs. 0.290
# F1 = 0.663 vs. 0.457
# Precision = 0.554 vs. 0.297
# Recall = 0.826 vs. 0.989
# Validation
# AUC = 0.513 vs. 0.204
# F1 = 0.541 vs. 0.319
# Precision = 0.427 vs. 0.198
# Recall = 0.739 vs. 0.823
# Minibatch Loss= 1.089797
# Train Batch Evaluation
# AUC = 0.635 vs. 0.250
# F1 = 0.626 vs. 0.422
# Precision = 0.500 vs. 0.268
# Recall = 0.836 vs. 1.000
# Validation
# AUC = 0.521 vs. 0.197
# F1 = 0.554 vs. 0.318
# Precision = 0.439 vs. 0.190
# Recall = 0.748 vs. 0.986
# Minibatch Loss= 0.980587
# Train Batch Evaluation
# AUC = 0.669 vs. 0.324
# F1 = 0.667 vs. 0.486
# Precision = 0.529 vs. 0.321
# Recall = 0.900 vs. 0.998
# Validation
# AUC = 0.531 vs. 0.186
# F1 = 0.565 vs. 0.317
# Precision = 0.450 vs. 0.189
# Recall = 0.758 vs. 0.987
# Minibatch Loss= 0.931085
# Train Batch Evaluation
# AUC = 0.658 vs. 0.319
# F1 = 0.683 vs. 0.463
# Precision = 0.606 vs. 0.301
# Recall = 0.782 vs. 0.998
# Validation
# AUC = 0.542 vs. 0.187
# F1 = 0.576 vs. 0.319
# Precision = 0.455 vs. 0.190
# Recall = 0.785 vs. 0.993
# Minibatch Loss= 0.796999
# Train Batch Evaluation
# AUC = 0.629 vs. 0.331
# F1 = 0.661 vs. 0.487
# Precision = 0.576 vs. 0.322
# Recall = 0.774 vs. 0.998
# Validation
# AUC = 0.552 vs. 0.191
# F1 = 0.584 vs. 0.318
# Precision = 0.507 vs. 0.190
# Recall = 0.689 vs. 0.991
# Minibatch Loss= 0.892882
# Train Batch Evaluation
# AUC = 0.614 vs. 0.291
# F1 = 0.639 vs. 0.446
# Precision = 0.487 vs. 0.288
# Recall = 0.928 vs. 0.989
# Validation
# AUC = 0.570 vs. 0.199
# F1 = 0.601 vs. 0.319
# Precision = 0.517 vs. 0.193
# Recall = 0.717 vs. 0.933
# Minibatch Loss= 0.757391
# Train Batch Evaluation
# AUC = 0.721 vs. 0.316
# F1 = 0.716 vs. 0.482
# Precision = 0.604 vs. 0.318
# Recall = 0.880 vs. 1.000
# Validation
# AUC = 0.581 vs. 0.191
# F1 = 0.613 vs. 0.318
# Precision = 0.522 vs. 0.189
# Recall = 0.742 vs. 0.994
# Minibatch Loss= 0.629365
# Train Batch Evaluation
# AUC = 0.675 vs. 0.340
# F1 = 0.680 vs. 0.496
# Precision = 0.556 vs. 0.334
# Recall = 0.874 vs. 0.966
# Validation
# AUC = 0.594 vs. 0.200
# F1 = 0.619 vs. 0.321
# Precision = 0.539 vs. 0.197
# Recall = 0.726 vs. 0.863
# Minibatch Loss= 0.720520
# Train Batch Evaluation
# AUC = 0.707 vs. 0.310
# F1 = 0.698 vs. 0.488
# Precision = 0.601 vs. 0.323
# Recall = 0.833 vs. 1.000
# Validation
# AUC = 0.608 vs. 0.188
# F1 = 0.627 vs. 0.317
# Precision = 0.547 vs. 0.188
# Recall = 0.734 vs. 1.000
# Minibatch Loss= 0.670577
# Train Batch Evaluation
# AUC = 0.677 vs. 0.313
# F1 = 0.703 vs. 0.469
# Precision = 0.603 vs. 0.307
# Recall = 0.845 vs. 1.000
# Validation
# AUC = 0.619 vs. 0.187
# F1 = 0.628 vs. 0.321
# Precision = 0.537 vs. 0.194
# Recall = 0.756 vs. 0.937
# Minibatch Loss= 0.622966
# Train Batch Evaluation
# AUC = 0.723 vs. 0.294
# F1 = 0.713 vs. 0.447
# Precision = 0.594 vs. 0.288
# Recall = 0.894 vs. 1.000
# Validation
# AUC = 0.626 vs. 0.187
# F1 = 0.627 vs. 0.319
# Precision = 0.534 vs. 0.190
# Recall = 0.759 vs. 0.999
# Minibatch Loss= 0.556535
# Train Batch Evaluation
# AUC = 0.700 vs. 0.299
# F1 = 0.696 vs. 0.468
# Precision = 0.599 vs. 0.306
# Recall = 0.829 vs. 0.994
# Validation
# AUC = 0.634 vs. 0.196
# F1 = 0.625 vs. 0.321
# Precision = 0.533 vs. 0.192
# Recall = 0.756 vs. 0.989
# Minibatch Loss= 0.619132
# Train Batch Evaluation
# AUC = 0.742 vs. 0.299
# F1 = 0.732 vs. 0.460
# Precision = 0.676 vs. 0.299
# Recall = 0.799 vs. 0.996
# Validation
# AUC = 0.642 vs. 0.187
# F1 = 0.629 vs. 0.319
# Precision = 0.529 vs. 0.191
# Recall = 0.776 vs. 0.966
# Minibatch Loss= 0.538576
# Train Batch Evaluation
# AUC = 0.742 vs. 0.356
# F1 = 0.727 vs. 0.508
# Precision = 0.642 vs. 0.343
# Recall = 0.839 vs. 0.976
# Validation
# AUC = 0.639 vs. 0.183
# F1 = 0.624 vs. 0.318
# Precision = 0.562 vs. 0.190
# Recall = 0.701 vs. 0.966
# Minibatch Loss= 0.600507
# Train Batch Evaluation
# AUC = 0.763 vs. 0.310
# F1 = 0.747 vs. 0.490
# Precision = 0.644 vs. 0.326
# Recall = 0.889 vs. 0.984
# Validation
# AUC = 0.647 vs. 0.192
# F1 = 0.633 vs. 0.319
# Precision = 0.555 vs. 0.193
# Recall = 0.738 vs. 0.923
# Minibatch Loss= 0.560097
# Train Batch Evaluation
# AUC = 0.716 vs. 0.293
# F1 = 0.712 vs. 0.468
# Precision = 0.596 vs. 0.306
# Recall = 0.885 vs. 0.996
# Validation
# AUC = 0.649 vs. 0.180
# F1 = 0.632 vs. 0.318
# Precision = 0.555 vs. 0.189
# Recall = 0.735 vs. 1.000
# Minibatch Loss= 0.575412
# Train Batch Evaluation
# AUC = 0.771 vs. 0.312
# F1 = 0.761 vs. 0.486
# Precision = 0.700 vs. 0.321
# Recall = 0.834 vs. 1.000
# Validation
# AUC = 0.649 vs. 0.192
# F1 = 0.629 vs. 0.317
# Precision = 0.555 vs. 0.188
# Recall = 0.725 vs. 1.000
# Minibatch Loss= 0.536231
# Train Batch Evaluation
# AUC = 0.740 vs. 0.341
# F1 = 0.723 vs. 0.469
# Precision = 0.614 vs. 0.307
# Recall = 0.879 vs. 0.990
# Validation
# AUC = 0.648 vs. 0.186
# F1 = 0.628 vs. 0.319
# Precision = 0.552 vs. 0.191
# Recall = 0.728 vs. 0.967
# Minibatch Loss= 0.565730
# Train Batch Evaluation
# AUC = 0.771 vs. 0.316
# F1 = 0.731 vs. 0.471
# Precision = 0.626 vs. 0.308
# Recall = 0.876 vs. 1.000
# Validation
# AUC = 0.651 vs. 0.185
# F1 = 0.629 vs. 0.317
# Precision = 0.564 vs. 0.188
# Recall = 0.711 vs. 1.000
# Minibatch Loss= 0.540690
# Train Batch Evaluation
# AUC = 0.735 vs. 0.312
# F1 = 0.720 vs. 0.468
# Precision = 0.620 vs. 0.306
# Recall = 0.859 vs. 1.000
# Validation
# AUC = 0.651 vs. 0.189
# F1 = 0.632 vs. 0.318
# Precision = 0.588 vs. 0.189
# Recall = 0.684 vs. 0.989
# Minibatch Loss= 0.567934
# Train Batch Evaluation
# AUC = 0.749 vs. 0.315
# F1 = 0.726 vs. 0.465
# Precision = 0.644 vs. 0.303
# Recall = 0.832 vs. 1.000
# Validation
# AUC = 0.654 vs. 0.194
# F1 = 0.631 vs. 0.318
# Precision = 0.583 vs. 0.191
# Recall = 0.688 vs. 0.952
# Minibatch Loss= 0.568931
# Train Batch Evaluation
# AUC = 0.765 vs. 0.274
# F1 = 0.730 vs. 0.417
# Precision = 0.617 vs. 0.264
# Recall = 0.893 vs. 0.988
# Validation
# AUC = 0.647 vs. 0.200
# F1 = 0.627 vs. 0.317
# Precision = 0.588 vs. 0.188
# Recall = 0.672 vs. 1.000
# Minibatch Loss= 0.470846
# Train Batch Evaluation
# AUC = 0.746 vs. 0.326
# F1 = 0.716 vs. 0.482
# Precision = 0.638 vs. 0.317
# Recall = 0.815 vs. 1.000
# Validation
# AUC = 0.647 vs. 0.195
# F1 = 0.627 vs. 0.317
# Precision = 0.586 vs. 0.189
# Recall = 0.675 vs. 0.997
# Minibatch Loss= 0.595500
# Train Batch Evaluation
# AUC = 0.744 vs. 0.353
# F1 = 0.737 vs. 0.521
# Precision = 0.626 vs. 0.352
# Recall = 0.895 vs. 1.000
# Validation
# AUC = 0.652 vs. 0.188
# F1 = 0.633 vs. 0.317
# Precision = 0.565 vs. 0.188
# Recall = 0.721 vs. 1.000
# Minibatch Loss= 0.623413
# Train Batch Evaluation
# AUC = 0.741 vs. 0.329
# F1 = 0.708 vs. 0.489
# Precision = 0.577 vs. 0.324
# Recall = 0.917 vs. 1.000
# Validation
# AUC = 0.652 vs. 0.199
# F1 = 0.634 vs. 0.317
# Precision = 0.571 vs. 0.188
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.612678
# Train Batch Evaluation
# AUC = 0.758 vs. 0.286
# F1 = 0.738 vs. 0.448
# Precision = 0.668 vs. 0.289
# Recall = 0.825 vs. 1.000
# Validation
# AUC = 0.655 vs. 0.192
# F1 = 0.633 vs. 0.319
# Precision = 0.587 vs. 0.189
# Recall = 0.687 vs. 1.000
# Minibatch Loss= 0.520811
# Train Batch Evaluation
# AUC = 0.771 vs. 0.308
# F1 = 0.741 vs. 0.477
# Precision = 0.666 vs. 0.314
# Recall = 0.835 vs. 0.992
# Validation
# AUC = 0.649 vs. 0.181
# F1 = 0.629 vs. 0.318
# Precision = 0.557 vs. 0.189
# Recall = 0.724 vs. 1.000
# Minibatch Loss= 0.554493
# Train Batch Evaluation
# AUC = 0.758 vs. 0.303
# F1 = 0.753 vs. 0.482
# Precision = 0.659 vs. 0.318
# Recall = 0.880 vs. 0.996
# Validation
# AUC = 0.652 vs. 0.188
# F1 = 0.633 vs. 0.317
# Precision = 0.561 vs. 0.189
# Recall = 0.726 vs. 0.997
# Minibatch Loss= 0.545564
# Train Batch Evaluation
# AUC = 0.798 vs. 0.326
# F1 = 0.746 vs. 0.485
# Precision = 0.657 vs. 0.324
# Recall = 0.861 vs. 0.971
# Validation
# AUC = 0.651 vs. 0.186
# F1 = 0.631 vs. 0.317
# Precision = 0.557 vs. 0.188
# Recall = 0.728 vs. 1.000
# Minibatch Loss= 0.533998
# Train Batch Evaluation
# AUC = 0.744 vs. 0.340
# F1 = 0.726 vs. 0.508
# Precision = 0.693 vs. 0.341
# Recall = 0.763 vs. 1.000
# Validation
# AUC = 0.650 vs. 0.192
# F1 = 0.631 vs. 0.317
# Precision = 0.557 vs. 0.188
# Recall = 0.728 vs. 1.000
# Minibatch Loss= 0.614021
# Train Batch Evaluation
# AUC = 0.719 vs. 0.294
# F1 = 0.703 vs. 0.474
# Precision = 0.662 vs. 0.310
# Recall = 0.751 vs. 1.000
# Validation
# AUC = 0.651 vs. 0.193
# F1 = 0.633 vs. 0.318
# Precision = 0.562 vs. 0.189
# Recall = 0.724 vs. 0.994
# Minibatch Loss= 0.586945
# Train Batch Evaluation
# AUC = 0.765 vs. 0.348
# F1 = 0.724 vs. 0.514
# Precision = 0.667 vs. 0.346
# Recall = 0.792 vs. 0.998
# Validation
# AUC = 0.651 vs. 0.188
# F1 = 0.631 vs. 0.318
# Precision = 0.568 vs. 0.189
# Recall = 0.709 vs. 0.993
# Minibatch Loss= 0.607126
# Train Batch Evaluation
# AUC = 0.773 vs. 0.360
# F1 = 0.753 vs. 0.524
# Precision = 0.674 vs. 0.355
# Recall = 0.854 vs. 1.000
# Validation
# AUC = 0.651 vs. 0.192
# F1 = 0.633 vs. 0.319
# Precision = 0.562 vs. 0.190
# Recall = 0.725 vs. 0.993
# Minibatch Loss= 0.588945
# Train Batch Evaluation
# AUC = 0.719 vs. 0.269
# F1 = 0.677 vs. 0.411
# Precision = 0.555 vs. 0.259
# Recall = 0.869 vs. 1.000
# Validation
# AUC = 0.654 vs. 0.193
# F1 = 0.633 vs. 0.319
# Precision = 0.568 vs. 0.191
# Recall = 0.715 vs. 0.974
# Minibatch Loss= 0.539779
# Train Batch Evaluation
# AUC = 0.772 vs. 0.331
# F1 = 0.748 vs. 0.496
# Precision = 0.686 vs. 0.330
# Recall = 0.823 vs. 1.000
# Validation
# AUC = 0.649 vs. 0.204
# F1 = 0.632 vs. 0.318
# Precision = 0.559 vs. 0.189
# Recall = 0.725 vs. 0.994
# Minibatch Loss= 0.559213
# Train Batch Evaluation
# AUC = 0.725 vs. 0.318
# F1 = 0.745 vs. 0.505
# Precision = 0.653 vs. 0.338
# Recall = 0.868 vs. 1.000
# Validation
# AUC = 0.650 vs. 0.189
# F1 = 0.633 vs. 0.317
# Precision = 0.563 vs. 0.188
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.587223
# Train Batch Evaluation
# AUC = 0.704 vs. 0.304
# F1 = 0.694 vs. 0.440
# Precision = 0.585 vs. 0.284
# Recall = 0.853 vs. 0.984
# Validation
# AUC = 0.653 vs. 0.188
# F1 = 0.635 vs. 0.318
# Precision = 0.560 vs. 0.191
# Recall = 0.732 vs. 0.950
# Minibatch Loss= 0.618044
# Train Batch Evaluation
# AUC = 0.705 vs. 0.294
# F1 = 0.697 vs. 0.448
# Precision = 0.598 vs. 0.289
# Recall = 0.835 vs. 1.000
# Validation
# AUC = 0.651 vs. 0.183
# F1 = 0.633 vs. 0.317
# Precision = 0.562 vs. 0.190
# Recall = 0.725 vs. 0.973
# Minibatch Loss= 0.581601
# Train Batch Evaluation
# AUC = 0.749 vs. 0.310
# F1 = 0.714 vs. 0.456
# Precision = 0.632 vs. 0.296
# Recall = 0.819 vs. 0.994
# Validation
# AUC = 0.650 vs. 0.194
# F1 = 0.633 vs. 0.317
# Precision = 0.562 vs. 0.188
# Recall = 0.724 vs. 0.997
# Minibatch Loss= 0.568134
# Train Batch Evaluation
# AUC = 0.718 vs. 0.325
# F1 = 0.718 vs. 0.480
# Precision = 0.619 vs. 0.316
# Recall = 0.855 vs. 1.000
# Validation
# AUC = 0.648 vs. 0.184
# F1 = 0.630 vs. 0.318
# Precision = 0.558 vs. 0.189
# Recall = 0.724 vs. 1.000
# Minibatch Loss= 0.593541
# Train Batch Evaluation
# AUC = 0.730 vs. 0.297
# F1 = 0.710 vs. 0.461
# Precision = 0.652 vs. 0.300
# Recall = 0.779 vs. 1.000
# Validation
# AUC = 0.652 vs. 0.191
# F1 = 0.634 vs. 0.318
# Precision = 0.558 vs. 0.189
# Recall = 0.735 vs. 1.000
# Minibatch Loss= 0.579912
# Train Batch Evaluation
# AUC = 0.724 vs. 0.300
# F1 = 0.697 vs. 0.475
# Precision = 0.565 vs. 0.312
# Recall = 0.909 vs. 0.996
# Validation
# AUC = 0.651 vs. 0.196
# F1 = 0.631 vs. 0.320
# Precision = 0.543 vs. 0.191
# Recall = 0.754 vs. 0.966
# Minibatch Loss= 0.594309
# Train Batch Evaluation
# AUC = 0.791 vs. 0.294
# F1 = 0.753 vs. 0.466
# Precision = 0.626 vs. 0.305
# Recall = 0.946 vs. 0.979
# Validation
# AUC = 0.649 vs. 0.189
# F1 = 0.631 vs. 0.317
# Precision = 0.566 vs. 0.188
# Recall = 0.714 vs. 1.000
# Minibatch Loss= 0.510099
# Train Batch Evaluation
# AUC = 0.729 vs. 0.332
# F1 = 0.726 vs. 0.473
# Precision = 0.604 vs. 0.319
# Recall = 0.909 vs. 0.917
# Validation
# AUC = 0.653 vs. 0.189
# F1 = 0.633 vs. 0.317
# Precision = 0.560 vs. 0.188
# Recall = 0.729 vs. 1.000
# Minibatch Loss= 0.574003
# Train Batch Evaluation
# AUC = 0.783 vs. 0.364
# F1 = 0.764 vs. 0.545
# Precision = 0.683 vs. 0.375
# Recall = 0.866 vs. 1.000
# Validation
# AUC = 0.652 vs. 0.181
# F1 = 0.632 vs. 0.317
# Precision = 0.576 vs. 0.189
# Recall = 0.701 vs. 1.000
# Minibatch Loss= 0.588743
# Train Batch Evaluation
# AUC = 0.777 vs. 0.339
# F1 = 0.755 vs. 0.513
# Precision = 0.676 vs. 0.348
# Recall = 0.855 vs. 0.972
# Validation
# AUC = 0.653 vs. 0.190
# F1 = 0.634 vs. 0.317
# Precision = 0.560 vs. 0.189
# Recall = 0.729 vs. 1.000
# Minibatch Loss= 0.562725
# Train Batch Evaluation
# AUC = 0.760 vs. 0.307
# F1 = 0.741 vs. 0.478
# Precision = 0.662 vs. 0.314
# Recall = 0.843 vs. 1.000
# Validation
# AUC = 0.648 vs. 0.186
# F1 = 0.632 vs. 0.317
# Precision = 0.557 vs. 0.188
# Recall = 0.729 vs. 1.000
# Minibatch Loss= 0.559459
# Train Batch Evaluation
# AUC = 0.760 vs. 0.293
# F1 = 0.732 vs. 0.449
# Precision = 0.605 vs. 0.293
# Recall = 0.928 vs. 0.956
# Validation
# AUC = 0.651 vs. 0.197
# F1 = 0.634 vs. 0.318
# Precision = 0.558 vs. 0.189
# Recall = 0.734 vs. 0.996
# Minibatch Loss= 0.532457
# Train Batch Evaluation
# AUC = 0.720 vs. 0.317
# F1 = 0.698 vs. 0.478
# Precision = 0.634 vs. 0.314
# Recall = 0.776 vs. 0.998
# Validation
# AUC = 0.651 vs. 0.193
# F1 = 0.633 vs. 0.320
# Precision = 0.563 vs. 0.198
# Recall = 0.724 vs. 0.838
# Minibatch Loss= 0.621423
# Train Batch Evaluation
# AUC = 0.746 vs. 0.317
# F1 = 0.742 vs. 0.487
# Precision = 0.638 vs. 0.324
# Recall = 0.887 vs. 0.986
# Validation
# AUC = 0.653 vs. 0.191
# F1 = 0.633 vs. 0.319
# Precision = 0.554 vs. 0.191
# Recall = 0.738 vs. 0.966
# Minibatch Loss= 0.561759
# Train Batch Evaluation
# AUC = 0.730 vs. 0.295
# F1 = 0.706 vs. 0.450
# Precision = 0.639 vs. 0.291
# Recall = 0.789 vs. 0.998
# Validation
# AUC = 0.651 vs. 0.187
# F1 = 0.633 vs. 0.317
# Precision = 0.563 vs. 0.189
# Recall = 0.724 vs. 1.000
# Minibatch Loss= 0.569816
# Train Batch Evaluation
# AUC = 0.766 vs. 0.298
# F1 = 0.740 vs. 0.447
# Precision = 0.645 vs. 0.292
# Recall = 0.866 vs. 0.952
# Validation
# AUC = 0.653 vs. 0.185
# F1 = 0.634 vs. 0.322
# Precision = 0.554 vs. 0.196
# Recall = 0.741 vs. 0.900
# Minibatch Loss= 0.514902
# Train Batch Evaluation
# AUC = 0.745 vs. 0.255
# F1 = 0.721 vs. 0.418
# Precision = 0.654 vs. 0.265
# Recall = 0.801 vs. 1.000
# Validation
# AUC = 0.652 vs. 0.191
# F1 = 0.634 vs. 0.317
# Precision = 0.558 vs. 0.189
# Recall = 0.734 vs. 0.999
# Minibatch Loss= 0.525309
# Train Batch Evaluation
# AUC = 0.777 vs. 0.329
# F1 = 0.755 vs. 0.508
# Precision = 0.710 vs. 0.341
# Recall = 0.806 vs. 1.000
# Validation
# AUC = 0.652 vs. 0.195
# F1 = 0.633 vs. 0.318
# Precision = 0.561 vs. 0.192
# Recall = 0.726 vs. 0.932
# Minibatch Loss= 0.556601
# Train Batch Evaluation
# AUC = 0.750 vs. 0.327
# F1 = 0.716 vs. 0.505
# Precision = 0.664 vs. 0.340
# Recall = 0.776 vs. 0.981
# Validation
# AUC = 0.654 vs. 0.188
# F1 = 0.634 vs. 0.317
# Precision = 0.580 vs. 0.188
# Recall = 0.699 vs. 1.000
# Minibatch Loss= 0.638318
# Train Batch Evaluation
# AUC = 0.721 vs. 0.295
# F1 = 0.708 vs. 0.465
# Precision = 0.609 vs. 0.306
# Recall = 0.845 vs. 0.975
# Validation
# AUC = 0.653 vs. 0.189
# F1 = 0.634 vs. 0.318
# Precision = 0.564 vs. 0.189
# Recall = 0.725 vs. 0.991
# Minibatch Loss= 0.574598
# Train Batch Evaluation
# AUC = 0.736 vs. 0.296
# F1 = 0.719 vs. 0.456
# Precision = 0.656 vs. 0.296
# Recall = 0.796 vs. 0.989
# Validation
# AUC = 0.653 vs. 0.183
# F1 = 0.634 vs. 0.317
# Precision = 0.563 vs. 0.188
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.575159

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
result = nn_eval.evaluate_model (model, sess, test_data, test_gt)

# %%
probability_of_pos = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
