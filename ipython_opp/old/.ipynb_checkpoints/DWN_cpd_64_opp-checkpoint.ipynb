# %%
# useing this variable for saving models and summaries
exp_name = "DWN_cpd_64"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp7.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((1358, 1024, 77), (1358, 1024, 1))

# %%
test_data.shape, test_gt.shape
# Out:
# ((233, 1024, 77), (233, 1024, 1))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 5    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

# %%
train_data.shape
# Out:
# (1358, 1024, 77)

# %%
pos_weight.shape
# Out:
# (1,)

# %%
pos_weight
# Out:
# array([ 2.15172601], dtype=float32)

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet=False,
                                 trainable_conv=False,
                                 trainable_last=True)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'change')

# %%
#load the model
saver = tf.train.Saver(var_list = [
    model.weights['wc0'],model.weights['wc1'],model.weights['wc2'],
    model.bias['bc0'],model.bias['bc1'],model.bias['bc2'],
    model.weights['high_pass'],model.weights['low_pass']
])
saver.restore(sess, '../model/DWN9008_opp/checkpoint-4000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/DWN9008_opp/checkpoint-4000

# %%
trainer.run_debug_ops()
# Out:
# {'wavelet_out_shape': [array([ 100, 1024,   77], dtype=int32), array([100, 512,  77], dtype=int32), array([100, 256,  77], dtype=int32), array([100, 128,  77], dtype=int32), array([100,  64,  77], dtype=int32), array([100,  32,  77], dtype=int32)], 'cnn_out_shape': [array([100,  16,   1], dtype=int32), array([100,   8,   1], dtype=int32), array([100,   4,   1], dtype=int32), array([100,   2,   1], dtype=int32), array([100,   1,   1], dtype=int32), array([100,   1,   1], dtype=int32)], 'input_shape': array([ 100, 1024,   77], dtype=int32), 'label_shape': array([ 100, 1024,    1], dtype=int32)}

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# AUC = 0.333 vs. 0.363
# F1 = 0.519 vs. 0.521
# Precision = 0.351 vs. 0.352
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.150 vs. 0.189
# F1 = 0.317 vs. 0.318
# Precision = 0.188 vs. 0.190
# Recall = 1.000 vs. 0.984
# Minibatch Loss= 21.529043
# Train Batch Evaluation
# AUC = 0.278 vs. 0.323
# F1 = 0.495 vs. 0.495
# Precision = 0.329 vs. 0.329
# Recall = 1.000 vs. 1.000
# Validation
# AUC = 0.142 vs. 0.186
# F1 = 0.317 vs. 0.317
# Precision = 0.188 vs. 0.188
# Recall = 1.000 vs. 0.997
# Minibatch Loss= 7.606409
# Train Batch Evaluation
# AUC = 0.392 vs. 0.325
# F1 = 0.511 vs. 0.476
# Precision = 0.421 vs. 0.316
# Recall = 0.649 vs. 0.968
# Validation
# AUC = 0.253 vs. 0.182
# F1 = 0.348 vs. 0.320
# Precision = 0.276 vs. 0.190
# Recall = 0.470 vs. 0.993
# Minibatch Loss= 3.491687
# Train Batch Evaluation
# AUC = 0.547 vs. 0.317
# F1 = 0.562 vs. 0.472
# Precision = 0.457 vs. 0.309
# Recall = 0.730 vs. 1.000
# Validation
# AUC = 0.348 vs. 0.190
# F1 = 0.413 vs. 0.317
# Precision = 0.327 vs. 0.192
# Recall = 0.558 vs. 0.915
# Minibatch Loss= 2.384804
# Train Batch Evaluation
# AUC = 0.596 vs. 0.336
# F1 = 0.629 vs. 0.494
# Precision = 0.557 vs. 0.328
# Recall = 0.722 vs. 1.000
# Validation
# AUC = 0.401 vs. 0.192
# F1 = 0.456 vs. 0.320
# Precision = 0.376 vs. 0.195
# Recall = 0.580 vs. 0.892
# Minibatch Loss= 2.011042
# Train Batch Evaluation
# AUC = 0.607 vs. 0.346
# F1 = 0.637 vs. 0.514
# Precision = 0.522 vs. 0.346
# Recall = 0.816 vs. 1.000
# Validation
# AUC = 0.439 vs. 0.188
# F1 = 0.481 vs. 0.318
# Precision = 0.411 vs. 0.189
# Recall = 0.581 vs. 0.999
# Minibatch Loss= 1.814049
# Train Batch Evaluation
# AUC = 0.593 vs. 0.330
# F1 = 0.639 vs. 0.499
# Precision = 0.528 vs. 0.333
# Recall = 0.809 vs. 0.994
# Validation
# AUC = 0.462 vs. 0.194
# F1 = 0.499 vs. 0.317
# Precision = 0.395 vs. 0.189
# Recall = 0.678 vs. 1.000
# Minibatch Loss= 1.584326
# Train Batch Evaluation
# AUC = 0.630 vs. 0.352
# F1 = 0.655 vs. 0.514
# Precision = 0.552 vs. 0.346
# Recall = 0.805 vs. 1.000
# Validation
# AUC = 0.479 vs. 0.190
# F1 = 0.510 vs. 0.318
# Precision = 0.421 vs. 0.189
# Recall = 0.645 vs. 0.991
# Minibatch Loss= 1.524574
# Train Batch Evaluation
# AUC = 0.622 vs. 0.298
# F1 = 0.643 vs. 0.462
# Precision = 0.516 vs. 0.300
# Recall = 0.854 vs. 0.998
# Validation
# AUC = 0.493 vs. 0.186
# F1 = 0.523 vs. 0.317
# Precision = 0.436 vs. 0.188
# Recall = 0.654 vs. 1.000
# Minibatch Loss= 1.227920
# Train Batch Evaluation
# AUC = 0.647 vs. 0.318
# F1 = 0.666 vs. 0.474
# Precision = 0.514 vs. 0.311
# Recall = 0.945 vs. 0.990
# Validation
# AUC = 0.503 vs. 0.188
# F1 = 0.532 vs. 0.318
# Precision = 0.449 vs. 0.190
# Recall = 0.652 vs. 0.969
# Minibatch Loss= 1.046762
# Train Batch Evaluation
# AUC = 0.677 vs. 0.369
# F1 = 0.693 vs. 0.530
# Precision = 0.583 vs. 0.360
# Recall = 0.852 vs. 0.998
# Validation
# AUC = 0.510 vs. 0.180
# F1 = 0.540 vs. 0.317
# Precision = 0.434 vs. 0.188
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 1.031910
# Train Batch Evaluation
# AUC = 0.743 vs. 0.353
# F1 = 0.715 vs. 0.515
# Precision = 0.633 vs. 0.349
# Recall = 0.821 vs. 0.984
# Validation
# AUC = 0.519 vs. 0.179
# F1 = 0.549 vs. 0.317
# Precision = 0.435 vs. 0.189
# Recall = 0.744 vs. 0.996
# Minibatch Loss= 0.883320
# Train Batch Evaluation
# AUC = 0.657 vs. 0.272
# F1 = 0.672 vs. 0.437
# Precision = 0.547 vs. 0.280
# Recall = 0.870 vs. 0.996
# Validation
# AUC = 0.527 vs. 0.193
# F1 = 0.553 vs. 0.318
# Precision = 0.464 vs. 0.192
# Recall = 0.684 vs. 0.933
# Minibatch Loss= 0.818170
# Train Batch Evaluation
# AUC = 0.698 vs. 0.328
# F1 = 0.734 vs. 0.480
# Precision = 0.666 vs. 0.316
# Recall = 0.817 vs. 0.994
# Validation
# AUC = 0.535 vs. 0.189
# F1 = 0.561 vs. 0.321
# Precision = 0.472 vs. 0.192
# Recall = 0.689 vs. 0.964
# Minibatch Loss= 0.751213
# Train Batch Evaluation
# AUC = 0.666 vs. 0.288
# F1 = 0.674 vs. 0.456
# Precision = 0.544 vs. 0.296
# Recall = 0.885 vs. 1.000
# Validation
# AUC = 0.540 vs. 0.194
# F1 = 0.561 vs. 0.320
# Precision = 0.445 vs. 0.192
# Recall = 0.756 vs. 0.964
# Minibatch Loss= 0.772476
# Train Batch Evaluation
# AUC = 0.673 vs. 0.295
# F1 = 0.700 vs. 0.468
# Precision = 0.631 vs. 0.311
# Recall = 0.787 vs. 0.946
# Validation
# AUC = 0.549 vs. 0.182
# F1 = 0.568 vs. 0.317
# Precision = 0.470 vs. 0.188
# Recall = 0.718 vs. 1.000
# Minibatch Loss= 0.730706
# Train Batch Evaluation
# AUC = 0.634 vs. 0.278
# F1 = 0.666 vs. 0.418
# Precision = 0.575 vs. 0.264
# Recall = 0.791 vs. 0.998
# Validation
# AUC = 0.558 vs. 0.177
# F1 = 0.575 vs. 0.319
# Precision = 0.479 vs. 0.190
# Recall = 0.719 vs. 0.980
# Minibatch Loss= 0.682516
# Train Batch Evaluation
# AUC = 0.726 vs. 0.301
# F1 = 0.718 vs. 0.490
# Precision = 0.664 vs. 0.324
# Recall = 0.782 vs. 1.000
# Validation
# AUC = 0.564 vs. 0.190
# F1 = 0.581 vs. 0.318
# Precision = 0.489 vs. 0.191
# Recall = 0.717 vs. 0.940
# Minibatch Loss= 0.659810
# Train Batch Evaluation
# AUC = 0.714 vs. 0.282
# F1 = 0.714 vs. 0.459
# Precision = 0.619 vs. 0.298
# Recall = 0.844 vs. 0.998
# Validation
# AUC = 0.572 vs. 0.180
# F1 = 0.582 vs. 0.318
# Precision = 0.487 vs. 0.189
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.620551
# Train Batch Evaluation
# AUC = 0.673 vs. 0.303
# F1 = 0.707 vs. 0.477
# Precision = 0.598 vs. 0.313
# Recall = 0.863 vs. 1.000
# Validation
# AUC = 0.580 vs. 0.190
# F1 = 0.587 vs. 0.319
# Precision = 0.496 vs. 0.190
# Recall = 0.719 vs. 0.997
# Minibatch Loss= 0.669438
# Train Batch Evaluation
# AUC = 0.691 vs. 0.306
# F1 = 0.690 vs. 0.460
# Precision = 0.598 vs. 0.300
# Recall = 0.816 vs. 0.987
# Validation
# AUC = 0.588 vs. 0.188
# F1 = 0.597 vs. 0.317
# Precision = 0.530 vs. 0.190
# Recall = 0.682 vs. 0.973
# Minibatch Loss= 0.632734
# Train Batch Evaluation
# AUC = 0.719 vs. 0.332
# F1 = 0.709 vs. 0.501
# Precision = 0.596 vs. 0.335
# Recall = 0.876 vs. 0.998
# Validation
# AUC = 0.594 vs. 0.191
# F1 = 0.603 vs. 0.317
# Precision = 0.533 vs. 0.189
# Recall = 0.692 vs. 1.000
# Minibatch Loss= 0.631528
# Train Batch Evaluation
# AUC = 0.686 vs. 0.340
# F1 = 0.701 vs. 0.507
# Precision = 0.592 vs. 0.341
# Recall = 0.861 vs. 0.991
# Validation
# AUC = 0.601 vs. 0.190
# F1 = 0.607 vs. 0.317
# Precision = 0.536 vs. 0.188
# Recall = 0.699 vs. 1.000
# Minibatch Loss= 0.690290
# Train Batch Evaluation
# AUC = 0.682 vs. 0.287
# F1 = 0.690 vs. 0.438
# Precision = 0.609 vs. 0.282
# Recall = 0.796 vs. 0.980
# Validation
# AUC = 0.606 vs. 0.202
# F1 = 0.610 vs. 0.318
# Precision = 0.528 vs. 0.192
# Recall = 0.722 vs. 0.917
# Minibatch Loss= 0.604191
# Train Batch Evaluation
# AUC = 0.733 vs. 0.321
# F1 = 0.705 vs. 0.473
# Precision = 0.612 vs. 0.310
# Recall = 0.832 vs. 1.000
# Validation
# AUC = 0.611 vs. 0.190
# F1 = 0.615 vs. 0.318
# Precision = 0.537 vs. 0.190
# Recall = 0.719 vs. 0.981
# Minibatch Loss= 0.602114
# Train Batch Evaluation
# AUC = 0.669 vs. 0.256
# F1 = 0.671 vs. 0.419
# Precision = 0.577 vs. 0.266
# Recall = 0.802 vs. 0.993
# Validation
# AUC = 0.615 vs. 0.184
# F1 = 0.619 vs. 0.318
# Precision = 0.537 vs. 0.189
# Recall = 0.729 vs. 0.993
# Minibatch Loss= 0.593485
# Train Batch Evaluation
# AUC = 0.740 vs. 0.347
# F1 = 0.724 vs. 0.530
# Precision = 0.634 vs. 0.360
# Recall = 0.844 vs. 1.000
# Validation
# AUC = 0.617 vs. 0.191
# F1 = 0.618 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.722 vs. 1.000
# Minibatch Loss= 0.663931
# Train Batch Evaluation
# AUC = 0.713 vs. 0.303
# F1 = 0.710 vs. 0.472
# Precision = 0.649 vs. 0.310
# Recall = 0.783 vs. 0.994
# Validation
# AUC = 0.620 vs. 0.198
# F1 = 0.621 vs. 0.318
# Precision = 0.543 vs. 0.189
# Recall = 0.725 vs. 0.993
# Minibatch Loss= 0.594128
# Train Batch Evaluation
# AUC = 0.735 vs. 0.323
# F1 = 0.721 vs. 0.486
# Precision = 0.640 vs. 0.321
# Recall = 0.827 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.193
# F1 = 0.620 vs. 0.319
# Precision = 0.540 vs. 0.192
# Recall = 0.728 vs. 0.929
# Minibatch Loss= 0.584812
# Train Batch Evaluation
# AUC = 0.727 vs. 0.344
# F1 = 0.717 vs. 0.503
# Precision = 0.639 vs. 0.337
# Recall = 0.816 vs. 0.993
# Validation
# AUC = 0.625 vs. 0.186
# F1 = 0.623 vs. 0.317
# Precision = 0.536 vs. 0.188
# Recall = 0.744 vs. 1.000
# Minibatch Loss= 0.605628
# Train Batch Evaluation
# AUC = 0.695 vs. 0.325
# F1 = 0.711 vs. 0.502
# Precision = 0.622 vs. 0.335
# Recall = 0.830 vs. 1.000
# Validation
# AUC = 0.629 vs. 0.188
# F1 = 0.628 vs. 0.318
# Precision = 0.535 vs. 0.190
# Recall = 0.761 vs. 0.963
# Minibatch Loss= 0.634510
# Train Batch Evaluation
# AUC = 0.693 vs. 0.321
# F1 = 0.695 vs. 0.471
# Precision = 0.605 vs. 0.308
# Recall = 0.817 vs. 0.998
# Validation
# AUC = 0.628 vs. 0.185
# F1 = 0.625 vs. 0.317
# Precision = 0.541 vs. 0.189
# Recall = 0.739 vs. 0.974
# Minibatch Loss= 0.603363
# Train Batch Evaluation
# AUC = 0.762 vs. 0.373
# F1 = 0.752 vs. 0.525
# Precision = 0.644 vs. 0.356
# Recall = 0.903 vs. 1.000
# Validation
# AUC = 0.629 vs. 0.181
# F1 = 0.626 vs. 0.317
# Precision = 0.537 vs. 0.189
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.583207
# Train Batch Evaluation
# AUC = 0.692 vs. 0.294
# F1 = 0.704 vs. 0.454
# Precision = 0.601 vs. 0.294
# Recall = 0.851 vs. 0.996
# Validation
# AUC = 0.628 vs. 0.178
# F1 = 0.626 vs. 0.318
# Precision = 0.542 vs. 0.190
# Recall = 0.741 vs. 0.993
# Minibatch Loss= 0.580702
# Train Batch Evaluation
# AUC = 0.736 vs. 0.322
# F1 = 0.724 vs. 0.474
# Precision = 0.626 vs. 0.311
# Recall = 0.861 vs. 0.998
# Validation
# AUC = 0.627 vs. 0.186
# F1 = 0.626 vs. 0.319
# Precision = 0.540 vs. 0.191
# Recall = 0.744 vs. 0.963
# Minibatch Loss= 0.556790
# Train Batch Evaluation
# AUC = 0.678 vs. 0.328
# F1 = 0.694 vs. 0.513
# Precision = 0.569 vs. 0.345
# Recall = 0.891 vs. 1.000
# Validation
# AUC = 0.628 vs. 0.194
# F1 = 0.627 vs. 0.320
# Precision = 0.533 vs. 0.195
# Recall = 0.762 vs. 0.880
# Minibatch Loss= 0.677253
# Train Batch Evaluation
# AUC = 0.732 vs. 0.291
# F1 = 0.724 vs. 0.448
# Precision = 0.635 vs. 0.288
# Recall = 0.842 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.203
# F1 = 0.626 vs. 0.320
# Precision = 0.537 vs. 0.194
# Recall = 0.752 vs. 0.913
# Minibatch Loss= 0.530287
# Train Batch Evaluation
# AUC = 0.679 vs. 0.301
# F1 = 0.697 vs. 0.464
# Precision = 0.595 vs. 0.302
# Recall = 0.841 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.185
# F1 = 0.629 vs. 0.319
# Precision = 0.539 vs. 0.191
# Recall = 0.755 vs. 0.976
# Minibatch Loss= 0.597766
# Train Batch Evaluation
# AUC = 0.686 vs. 0.330
# F1 = 0.689 vs. 0.488
# Precision = 0.596 vs. 0.323
# Recall = 0.818 vs. 1.000
# Validation
# AUC = 0.626 vs. 0.196
# F1 = 0.630 vs. 0.318
# Precision = 0.541 vs. 0.190
# Recall = 0.755 vs. 0.993
# Minibatch Loss= 0.643238
# Train Batch Evaluation
# AUC = 0.738 vs. 0.333
# F1 = 0.719 vs. 0.478
# Precision = 0.603 vs. 0.316
# Recall = 0.890 vs. 0.988
# Validation
# AUC = 0.625 vs. 0.184
# F1 = 0.630 vs. 0.317
# Precision = 0.542 vs. 0.188
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.569340
# Train Batch Evaluation
# AUC = 0.724 vs. 0.341
# F1 = 0.733 vs. 0.505
# Precision = 0.662 vs. 0.339
# Recall = 0.820 vs. 0.993
# Validation
# AUC = 0.624 vs. 0.189
# F1 = 0.628 vs. 0.318
# Precision = 0.543 vs. 0.189
# Recall = 0.745 vs. 0.993
# Minibatch Loss= 0.599422
# Train Batch Evaluation
# AUC = 0.675 vs. 0.277
# F1 = 0.670 vs. 0.425
# Precision = 0.554 vs. 0.270
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.185
# F1 = 0.630 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.577276
# Train Batch Evaluation
# AUC = 0.774 vs. 0.269
# F1 = 0.747 vs. 0.444
# Precision = 0.625 vs. 0.285
# Recall = 0.927 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.188
# F1 = 0.629 vs. 0.319
# Precision = 0.546 vs. 0.191
# Recall = 0.741 vs. 0.966
# Minibatch Loss= 0.482227
# Train Batch Evaluation
# AUC = 0.726 vs. 0.355
# F1 = 0.730 vs. 0.531
# Precision = 0.610 vs. 0.362
# Recall = 0.908 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.196
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.748 vs. 0.997
# Minibatch Loss= 0.632298
# Train Batch Evaluation
# AUC = 0.747 vs. 0.327
# F1 = 0.707 vs. 0.496
# Precision = 0.580 vs. 0.332
# Recall = 0.905 vs. 0.979
# Validation
# AUC = 0.622 vs. 0.187
# F1 = 0.629 vs. 0.317
# Precision = 0.534 vs. 0.189
# Recall = 0.764 vs. 0.994
# Minibatch Loss= 0.607794
# Train Batch Evaluation
# AUC = 0.752 vs. 0.326
# F1 = 0.726 vs. 0.491
# Precision = 0.608 vs. 0.326
# Recall = 0.902 vs. 0.992
# Validation
# AUC = 0.625 vs. 0.183
# F1 = 0.627 vs. 0.318
# Precision = 0.545 vs. 0.189
# Recall = 0.739 vs. 0.999
# Minibatch Loss= 0.575766
# Train Batch Evaluation
# AUC = 0.768 vs. 0.319
# F1 = 0.748 vs. 0.484
# Precision = 0.675 vs. 0.319
# Recall = 0.840 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.190
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.748 vs. 0.993
# Minibatch Loss= 0.538661
# Train Batch Evaluation
# AUC = 0.736 vs. 0.260
# F1 = 0.718 vs. 0.430
# Precision = 0.621 vs. 0.274
# Recall = 0.851 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.194
# F1 = 0.629 vs. 0.318
# Precision = 0.542 vs. 0.189
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.511605
# Train Batch Evaluation
# AUC = 0.737 vs. 0.335
# F1 = 0.719 vs. 0.484
# Precision = 0.603 vs. 0.319
# Recall = 0.890 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.193
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.190
# Recall = 0.748 vs. 0.984
# Minibatch Loss= 0.585852
# Train Batch Evaluation
# AUC = 0.761 vs. 0.358
# F1 = 0.718 vs. 0.510
# Precision = 0.605 vs. 0.342
# Recall = 0.883 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.193
# F1 = 0.630 vs. 0.317
# Precision = 0.545 vs. 0.189
# Recall = 0.746 vs. 0.984
# Minibatch Loss= 0.602875
# Train Batch Evaluation
# AUC = 0.693 vs. 0.335
# F1 = 0.700 vs. 0.500
# Precision = 0.587 vs. 0.335
# Recall = 0.867 vs. 0.989
# Validation
# AUC = 0.621 vs. 0.188
# F1 = 0.624 vs. 0.317
# Precision = 0.528 vs. 0.189
# Recall = 0.765 vs. 0.997
# Minibatch Loss= 0.657900
# Train Batch Evaluation
# AUC = 0.702 vs. 0.328
# F1 = 0.709 vs. 0.496
# Precision = 0.626 vs. 0.330
# Recall = 0.819 vs. 0.996
# Validation
# AUC = 0.624 vs. 0.196
# F1 = 0.628 vs. 0.319
# Precision = 0.544 vs. 0.191
# Recall = 0.742 vs. 0.962
# Minibatch Loss= 0.630482
# Train Batch Evaluation
# AUC = 0.752 vs. 0.313
# F1 = 0.729 vs. 0.472
# Precision = 0.624 vs. 0.309
# Recall = 0.879 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.185
# F1 = 0.630 vs. 0.318
# Precision = 0.544 vs. 0.189
# Recall = 0.748 vs. 0.999
# Minibatch Loss= 0.541274
# Train Batch Evaluation
# AUC = 0.719 vs. 0.284
# F1 = 0.698 vs. 0.439
# Precision = 0.676 vs. 0.281
# Recall = 0.721 vs. 1.000
# Validation
# AUC = 0.617 vs. 0.184
# F1 = 0.625 vs. 0.318
# Precision = 0.536 vs. 0.189
# Recall = 0.749 vs. 0.991
# Minibatch Loss= 0.545011
# Train Batch Evaluation
# AUC = 0.720 vs. 0.329
# F1 = 0.716 vs. 0.505
# Precision = 0.602 vs. 0.339
# Recall = 0.885 vs. 0.996
# Validation
# AUC = 0.624 vs. 0.196
# F1 = 0.630 vs. 0.317
# Precision = 0.549 vs. 0.188
# Recall = 0.739 vs. 1.000
# Minibatch Loss= 0.615319
# Train Batch Evaluation
# AUC = 0.702 vs. 0.302
# F1 = 0.723 vs. 0.456
# Precision = 0.594 vs. 0.295
# Recall = 0.924 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.192
# F1 = 0.629 vs. 0.317
# Precision = 0.544 vs. 0.189
# Recall = 0.745 vs. 0.996
# Minibatch Loss= 0.556203
# Train Batch Evaluation
# AUC = 0.697 vs. 0.286
# F1 = 0.697 vs. 0.465
# Precision = 0.568 vs. 0.303
# Recall = 0.901 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.193
# F1 = 0.628 vs. 0.318
# Precision = 0.542 vs. 0.190
# Recall = 0.746 vs. 0.964
# Minibatch Loss= 0.589791
# Train Batch Evaluation
# AUC = 0.716 vs. 0.311
# F1 = 0.717 vs. 0.484
# Precision = 0.626 vs. 0.322
# Recall = 0.839 vs. 0.972
# Validation
# AUC = 0.621 vs. 0.197
# F1 = 0.626 vs. 0.317
# Precision = 0.540 vs. 0.189
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.587831
# Train Batch Evaluation
# AUC = 0.749 vs. 0.293
# F1 = 0.710 vs. 0.452
# Precision = 0.631 vs. 0.292
# Recall = 0.811 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.198
# F1 = 0.626 vs. 0.319
# Precision = 0.539 vs. 0.191
# Recall = 0.748 vs. 0.983
# Minibatch Loss= 0.534813
# Train Batch Evaluation
# AUC = 0.736 vs. 0.317
# F1 = 0.709 vs. 0.467
# Precision = 0.598 vs. 0.305
# Recall = 0.870 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.194
# F1 = 0.629 vs. 0.317
# Precision = 0.542 vs. 0.188
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.553450
# Train Batch Evaluation
# AUC = 0.754 vs. 0.311
# F1 = 0.733 vs. 0.476
# Precision = 0.616 vs. 0.312
# Recall = 0.905 vs. 0.998
# Validation
# AUC = 0.622 vs. 0.190
# F1 = 0.629 vs. 0.318
# Precision = 0.543 vs. 0.189
# Recall = 0.746 vs. 0.997
# Minibatch Loss= 0.538605
# Train Batch Evaluation
# AUC = 0.709 vs. 0.355
# F1 = 0.727 vs. 0.520
# Precision = 0.603 vs. 0.352
# Recall = 0.915 vs. 0.998
# Validation
# AUC = 0.622 vs. 0.185
# F1 = 0.627 vs. 0.319
# Precision = 0.539 vs. 0.190
# Recall = 0.749 vs. 0.996
# Minibatch Loss= 0.647537
# Train Batch Evaluation
# AUC = 0.718 vs. 0.338
# F1 = 0.721 vs. 0.480
# Precision = 0.594 vs. 0.320
# Recall = 0.917 vs. 0.958
# Validation
# AUC = 0.624 vs. 0.194
# F1 = 0.629 vs. 0.320
# Precision = 0.544 vs. 0.191
# Recall = 0.746 vs. 0.991
# Minibatch Loss= 0.566159
# Train Batch Evaluation
# AUC = 0.716 vs. 0.373
# F1 = 0.718 vs. 0.525
# Precision = 0.613 vs. 0.359
# Recall = 0.866 vs. 0.979
# Validation
# AUC = 0.622 vs. 0.203
# F1 = 0.628 vs. 0.319
# Precision = 0.543 vs. 0.190
# Recall = 0.744 vs. 0.986
# Minibatch Loss= 0.633020
# Train Batch Evaluation
# AUC = 0.691 vs. 0.271
# F1 = 0.693 vs. 0.453
# Precision = 0.576 vs. 0.292
# Recall = 0.870 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.199
# F1 = 0.628 vs. 0.317
# Precision = 0.541 vs. 0.189
# Recall = 0.748 vs. 0.999
# Minibatch Loss= 0.588155
# Train Batch Evaluation
# AUC = 0.722 vs. 0.320
# F1 = 0.716 vs. 0.492
# Precision = 0.597 vs. 0.326
# Recall = 0.894 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.195
# F1 = 0.628 vs. 0.317
# Precision = 0.541 vs. 0.188
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.605691
# Train Batch Evaluation
# AUC = 0.702 vs. 0.276
# F1 = 0.710 vs. 0.423
# Precision = 0.619 vs. 0.268
# Recall = 0.832 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.182
# F1 = 0.629 vs. 0.317
# Precision = 0.543 vs. 0.189
# Recall = 0.748 vs. 0.984
# Minibatch Loss= 0.528128
# Train Batch Evaluation
# AUC = 0.723 vs. 0.273
# F1 = 0.737 vs. 0.448
# Precision = 0.631 vs. 0.290
# Recall = 0.885 vs. 0.993
# Validation
# AUC = 0.625 vs. 0.205
# F1 = 0.628 vs. 0.318
# Precision = 0.542 vs. 0.189
# Recall = 0.746 vs. 0.999
# Minibatch Loss= 0.514432
# Train Batch Evaluation
# AUC = 0.674 vs. 0.305
# F1 = 0.694 vs. 0.454
# Precision = 0.601 vs. 0.295
# Recall = 0.823 vs. 0.989
# Validation
# AUC = 0.624 vs. 0.189
# F1 = 0.629 vs. 0.320
# Precision = 0.539 vs. 0.190
# Recall = 0.756 vs. 0.997
# Minibatch Loss= 0.582867
# Train Batch Evaluation
# AUC = 0.742 vs. 0.307
# F1 = 0.736 vs. 0.483
# Precision = 0.620 vs. 0.318
# Recall = 0.905 vs. 1.000
# Validation
# AUC = 0.620 vs. 0.198
# F1 = 0.627 vs. 0.318
# Precision = 0.538 vs. 0.191
# Recall = 0.751 vs. 0.940
# Minibatch Loss= 0.557397
# Train Batch Evaluation
# AUC = 0.724 vs. 0.327
# F1 = 0.720 vs. 0.481
# Precision = 0.636 vs. 0.316
# Recall = 0.830 vs. 1.000
# Validation
# AUC = 0.626 vs. 0.189
# F1 = 0.631 vs. 0.320
# Precision = 0.546 vs. 0.194
# Recall = 0.746 vs. 0.925
# Minibatch Loss= 0.582879
# Train Batch Evaluation
# AUC = 0.744 vs. 0.339
# F1 = 0.733 vs. 0.510
# Precision = 0.626 vs. 0.342
# Recall = 0.884 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.192
# F1 = 0.625 vs. 0.317
# Precision = 0.538 vs. 0.188
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.601270
# Train Batch Evaluation
# AUC = 0.702 vs. 0.335
# F1 = 0.707 vs. 0.504
# Precision = 0.584 vs. 0.337
# Recall = 0.893 vs. 0.998
# Validation
# AUC = 0.622 vs. 0.184
# F1 = 0.627 vs. 0.317
# Precision = 0.539 vs. 0.188
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.633237
# Train Batch Evaluation
# AUC = 0.720 vs. 0.315
# F1 = 0.729 vs. 0.473
# Precision = 0.655 vs. 0.310
# Recall = 0.823 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.184
# F1 = 0.627 vs. 0.317
# Precision = 0.538 vs. 0.188
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.557013
# Train Batch Evaluation
# AUC = 0.733 vs. 0.335
# F1 = 0.743 vs. 0.517
# Precision = 0.662 vs. 0.348
# Recall = 0.846 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.182
# F1 = 0.629 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.592894
# Train Batch Evaluation
# AUC = 0.745 vs. 0.331
# F1 = 0.752 vs. 0.484
# Precision = 0.617 vs. 0.321
# Recall = 0.963 vs. 0.978
# Validation
# AUC = 0.623 vs. 0.185
# F1 = 0.632 vs. 0.317
# Precision = 0.545 vs. 0.188
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.530009
# Train Batch Evaluation
# AUC = 0.750 vs. 0.335
# F1 = 0.734 vs. 0.519
# Precision = 0.608 vs. 0.351
# Recall = 0.928 vs. 0.991
# Validation
# AUC = 0.623 vs. 0.190
# F1 = 0.629 vs. 0.317
# Precision = 0.543 vs. 0.189
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.588643
# Train Batch Evaluation
# AUC = 0.769 vs. 0.328
# F1 = 0.753 vs. 0.486
# Precision = 0.648 vs. 0.321
# Recall = 0.900 vs. 0.998
# Validation
# AUC = 0.625 vs. 0.189
# F1 = 0.631 vs. 0.317
# Precision = 0.544 vs. 0.189
# Recall = 0.752 vs. 0.989
# Minibatch Loss= 0.528862
# Train Batch Evaluation
# AUC = 0.690 vs. 0.356
# F1 = 0.708 vs. 0.526
# Precision = 0.583 vs. 0.357
# Recall = 0.902 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.197
# F1 = 0.626 vs. 0.318
# Precision = 0.538 vs. 0.194
# Recall = 0.748 vs. 0.880
# Minibatch Loss= 0.686193
# Train Batch Evaluation
# AUC = 0.750 vs. 0.339
# F1 = 0.727 vs. 0.493
# Precision = 0.602 vs. 0.327
# Recall = 0.918 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.185
# F1 = 0.629 vs. 0.317
# Precision = 0.544 vs. 0.189
# Recall = 0.744 vs. 0.999
# Minibatch Loss= 0.567552
# Train Batch Evaluation
# AUC = 0.687 vs. 0.304
# F1 = 0.681 vs. 0.445
# Precision = 0.567 vs. 0.286
# Recall = 0.851 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.185
# F1 = 0.630 vs. 0.317
# Precision = 0.546 vs. 0.189
# Recall = 0.745 vs. 0.996
# Minibatch Loss= 0.593459
# Train Batch Evaluation
# AUC = 0.731 vs. 0.292
# F1 = 0.712 vs. 0.459
# Precision = 0.602 vs. 0.299
# Recall = 0.869 vs. 0.996
# Validation
# AUC = 0.620 vs. 0.206
# F1 = 0.626 vs. 0.318
# Precision = 0.538 vs. 0.192
# Recall = 0.749 vs. 0.930
# Minibatch Loss= 0.545202
# Train Batch Evaluation
# AUC = 0.721 vs. 0.319
# F1 = 0.700 vs. 0.469
# Precision = 0.595 vs. 0.309
# Recall = 0.850 vs. 0.973
# Validation
# AUC = 0.624 vs. 0.180
# F1 = 0.627 vs. 0.317
# Precision = 0.541 vs. 0.188
# Recall = 0.745 vs. 0.999
# Minibatch Loss= 0.583650
# Train Batch Evaluation
# AUC = 0.651 vs. 0.258
# F1 = 0.654 vs. 0.389
# Precision = 0.544 vs. 0.241
# Recall = 0.819 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.196
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.748 vs. 0.993
# Minibatch Loss= 0.561606
# Train Batch Evaluation
# AUC = 0.724 vs. 0.274
# F1 = 0.698 vs. 0.429
# Precision = 0.568 vs. 0.273
# Recall = 0.904 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.192
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.528811
# Train Batch Evaluation
# AUC = 0.701 vs. 0.278
# F1 = 0.695 vs. 0.423
# Precision = 0.592 vs. 0.271
# Recall = 0.842 vs. 0.965
# Validation
# AUC = 0.621 vs. 0.186
# F1 = 0.627 vs. 0.317
# Precision = 0.535 vs. 0.188
# Recall = 0.759 vs. 1.000
# Minibatch Loss= 0.535455
# Train Batch Evaluation
# AUC = 0.702 vs. 0.357
# F1 = 0.708 vs. 0.509
# Precision = 0.587 vs. 0.341
# Recall = 0.892 vs. 1.000
# Validation
# AUC = 0.620 vs. 0.191
# F1 = 0.625 vs. 0.317
# Precision = 0.538 vs. 0.189
# Recall = 0.745 vs. 0.994
# Minibatch Loss= 0.659646
# Train Batch Evaluation
# AUC = 0.687 vs. 0.306
# F1 = 0.701 vs. 0.473
# Precision = 0.602 vs. 0.309
# Recall = 0.838 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.192
# F1 = 0.628 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.745 vs. 1.000
# Minibatch Loss= 0.602093
# Train Batch Evaluation
# AUC = 0.734 vs. 0.352
# F1 = 0.739 vs. 0.520
# Precision = 0.629 vs. 0.353
# Recall = 0.896 vs. 0.989
# Validation
# AUC = 0.621 vs. 0.197
# F1 = 0.624 vs. 0.318
# Precision = 0.547 vs. 0.190
# Recall = 0.725 vs. 0.984
# Minibatch Loss= 0.616571
# Train Batch Evaluation
# AUC = 0.726 vs. 0.361
# F1 = 0.727 vs. 0.514
# Precision = 0.615 vs. 0.346
# Recall = 0.890 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.199
# F1 = 0.628 vs. 0.319
# Precision = 0.543 vs. 0.191
# Recall = 0.744 vs. 0.966
# Minibatch Loss= 0.623680
# Train Batch Evaluation
# AUC = 0.744 vs. 0.319
# F1 = 0.722 vs. 0.481
# Precision = 0.604 vs. 0.317
# Recall = 0.897 vs. 0.992
# Validation
# AUC = 0.624 vs. 0.191
# F1 = 0.630 vs. 0.317
# Precision = 0.542 vs. 0.189
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.562574
# Train Batch Evaluation
# AUC = 0.741 vs. 0.356
# F1 = 0.750 vs. 0.501
# Precision = 0.645 vs. 0.335
# Recall = 0.895 vs. 0.998
# Validation
# AUC = 0.624 vs. 0.197
# F1 = 0.629 vs. 0.318
# Precision = 0.546 vs. 0.189
# Recall = 0.742 vs. 1.000
# Minibatch Loss= 0.570723
# Train Batch Evaluation
# AUC = 0.759 vs. 0.323
# F1 = 0.730 vs. 0.484
# Precision = 0.598 vs. 0.320
# Recall = 0.937 vs. 0.998
# Validation
# AUC = 0.620 vs. 0.204
# F1 = 0.626 vs. 0.318
# Precision = 0.539 vs. 0.189
# Recall = 0.748 vs. 0.996
# Minibatch Loss= 0.547349
# Train Batch Evaluation
# AUC = 0.748 vs. 0.322
# F1 = 0.728 vs. 0.499
# Precision = 0.614 vs. 0.333
# Recall = 0.893 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.196
# F1 = 0.629 vs. 0.318
# Precision = 0.542 vs. 0.189
# Recall = 0.749 vs. 0.994
# Minibatch Loss= 0.577047
# Train Batch Evaluation
# AUC = 0.732 vs. 0.304
# F1 = 0.730 vs. 0.479
# Precision = 0.626 vs. 0.315
# Recall = 0.877 vs. 1.000
# Validation
# AUC = 0.620 vs. 0.185
# F1 = 0.629 vs. 0.317
# Precision = 0.541 vs. 0.188
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.552212
# Train Batch Evaluation
# AUC = 0.748 vs. 0.325
# F1 = 0.730 vs. 0.492
# Precision = 0.619 vs. 0.326
# Recall = 0.888 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.187
# F1 = 0.628 vs. 0.318
# Precision = 0.537 vs. 0.193
# Recall = 0.756 vs. 0.889
# Minibatch Loss= 0.575521
# Train Batch Evaluation
# AUC = 0.731 vs. 0.291
# F1 = 0.724 vs. 0.458
# Precision = 0.613 vs. 0.297
# Recall = 0.884 vs. 0.998
# Validation
# AUC = 0.621 vs. 0.188
# F1 = 0.628 vs. 0.317
# Precision = 0.536 vs. 0.188
# Recall = 0.758 vs. 1.000
# Minibatch Loss= 0.556527
# Train Batch Evaluation
# AUC = 0.718 vs. 0.290
# F1 = 0.704 vs. 0.449
# Precision = 0.602 vs. 0.290
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.188
# F1 = 0.627 vs. 0.317
# Precision = 0.540 vs. 0.188
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.544581
# Train Batch Evaluation
# AUC = 0.749 vs. 0.345
# F1 = 0.752 vs. 0.516
# Precision = 0.637 vs. 0.348
# Recall = 0.917 vs. 1.000
# Validation
# AUC = 0.626 vs. 0.196
# F1 = 0.631 vs. 0.317
# Precision = 0.547 vs. 0.188
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.578474
# Train Batch Evaluation
# AUC = 0.732 vs. 0.307
# F1 = 0.707 vs. 0.480
# Precision = 0.580 vs. 0.316
# Recall = 0.905 vs. 0.990
# Validation
# AUC = 0.623 vs. 0.190
# F1 = 0.630 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.751 vs. 0.999
# Minibatch Loss= 0.597162
# Train Batch Evaluation
# AUC = 0.716 vs. 0.258
# F1 = 0.680 vs. 0.409
# Precision = 0.552 vs. 0.257
# Recall = 0.888 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.188
# F1 = 0.630 vs. 0.318
# Precision = 0.543 vs. 0.190
# Recall = 0.751 vs. 0.972
# Minibatch Loss= 0.541915
# Train Batch Evaluation
# AUC = 0.713 vs. 0.334
# F1 = 0.729 vs. 0.495
# Precision = 0.607 vs. 0.329
# Recall = 0.913 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.200
# F1 = 0.628 vs. 0.318
# Precision = 0.540 vs. 0.189
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.593317
# Train Batch Evaluation
# AUC = 0.723 vs. 0.351
# F1 = 0.719 vs. 0.520
# Precision = 0.598 vs. 0.352
# Recall = 0.902 vs. 0.996
# Validation
# AUC = 0.619 vs. 0.198
# F1 = 0.624 vs. 0.319
# Precision = 0.527 vs. 0.190
# Recall = 0.764 vs. 0.984
# Minibatch Loss= 0.642480
# Train Batch Evaluation
# AUC = 0.710 vs. 0.317
# F1 = 0.722 vs. 0.483
# Precision = 0.628 vs. 0.319
# Recall = 0.849 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.198
# F1 = 0.628 vs. 0.318
# Precision = 0.542 vs. 0.190
# Recall = 0.746 vs. 0.964
# Minibatch Loss= 0.590485
# Train Batch Evaluation
# AUC = 0.724 vs. 0.289
# F1 = 0.701 vs. 0.438
# Precision = 0.633 vs. 0.281
# Recall = 0.787 vs. 0.996
# Validation
# AUC = 0.621 vs. 0.196
# F1 = 0.626 vs. 0.318
# Precision = 0.539 vs. 0.192
# Recall = 0.746 vs. 0.940
# Minibatch Loss= 0.542614
# Train Batch Evaluation
# AUC = 0.709 vs. 0.312
# F1 = 0.695 vs. 0.461
# Precision = 0.641 vs. 0.300
# Recall = 0.758 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.186
# F1 = 0.628 vs. 0.317
# Precision = 0.541 vs. 0.189
# Recall = 0.749 vs. 0.993
# Minibatch Loss= 0.593199
# Train Batch Evaluation
# AUC = 0.700 vs. 0.329
# F1 = 0.711 vs. 0.482
# Precision = 0.587 vs. 0.320
# Recall = 0.903 vs. 0.972
# Validation
# AUC = 0.623 vs. 0.195
# F1 = 0.630 vs. 0.319
# Precision = 0.542 vs. 0.191
# Recall = 0.751 vs. 0.966
# Minibatch Loss= 0.597258
# Train Batch Evaluation
# AUC = 0.689 vs. 0.326
# F1 = 0.701 vs. 0.501
# Precision = 0.577 vs. 0.334
# Recall = 0.895 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.189
# F1 = 0.630 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.751 vs. 0.999
# Minibatch Loss= 0.651523
# Train Batch Evaluation
# AUC = 0.735 vs. 0.309
# F1 = 0.727 vs. 0.457
# Precision = 0.617 vs. 0.297
# Recall = 0.883 vs. 0.992
# Validation
# AUC = 0.618 vs. 0.183
# F1 = 0.625 vs. 0.318
# Precision = 0.530 vs. 0.190
# Recall = 0.764 vs. 0.959
# Minibatch Loss= 0.544266
# Train Batch Evaluation
# AUC = 0.699 vs. 0.289
# F1 = 0.702 vs. 0.428
# Precision = 0.595 vs. 0.272
# Recall = 0.857 vs. 0.995
# Validation
# AUC = 0.620 vs. 0.188
# F1 = 0.628 vs. 0.317
# Precision = 0.534 vs. 0.188
# Recall = 0.764 vs. 1.000
# Minibatch Loss= 0.549529
# Train Batch Evaluation
# AUC = 0.706 vs. 0.364
# F1 = 0.714 vs. 0.513
# Precision = 0.607 vs. 0.345
# Recall = 0.866 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.191
# F1 = 0.626 vs. 0.320
# Precision = 0.538 vs. 0.192
# Recall = 0.748 vs. 0.960
# Minibatch Loss= 0.648368
# Train Batch Evaluation
# AUC = 0.729 vs. 0.249
# F1 = 0.704 vs. 0.417
# Precision = 0.591 vs. 0.264
# Recall = 0.872 vs. 1.000
# Validation
# AUC = 0.619 vs. 0.186
# F1 = 0.624 vs. 0.318
# Precision = 0.526 vs. 0.189
# Recall = 0.768 vs. 1.000
# Minibatch Loss= 0.506906
# Train Batch Evaluation
# AUC = 0.766 vs. 0.290
# F1 = 0.743 vs. 0.475
# Precision = 0.637 vs. 0.312
# Recall = 0.890 vs. 0.998
# Validation
# AUC = 0.624 vs. 0.191
# F1 = 0.629 vs. 0.317
# Precision = 0.542 vs. 0.188
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.526011
# Train Batch Evaluation
# AUC = 0.681 vs. 0.285
# F1 = 0.690 vs. 0.463
# Precision = 0.578 vs. 0.302
# Recall = 0.856 vs. 0.992
# Validation
# AUC = 0.623 vs. 0.186
# F1 = 0.629 vs. 0.317
# Precision = 0.543 vs. 0.189
# Recall = 0.746 vs. 0.984
# Minibatch Loss= 0.602981
# Train Batch Evaluation
# AUC = 0.683 vs. 0.317
# F1 = 0.711 vs. 0.478
# Precision = 0.589 vs. 0.314
# Recall = 0.898 vs. 1.000
# Validation
# AUC = 0.619 vs. 0.187
# F1 = 0.624 vs. 0.317
# Precision = 0.525 vs. 0.189
# Recall = 0.768 vs. 1.000
# Minibatch Loss= 0.607287
# Train Batch Evaluation
# AUC = 0.693 vs. 0.316
# F1 = 0.689 vs. 0.501
# Precision = 0.552 vs. 0.334
# Recall = 0.918 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.181
# F1 = 0.629 vs. 0.317
# Precision = 0.544 vs. 0.188
# Recall = 0.745 vs. 1.000
# Minibatch Loss= 0.661751
# Train Batch Evaluation
# AUC = 0.743 vs. 0.321
# F1 = 0.708 vs. 0.477
# Precision = 0.650 vs. 0.316
# Recall = 0.779 vs. 0.972
# Validation
# AUC = 0.620 vs. 0.195
# F1 = 0.625 vs. 0.322
# Precision = 0.536 vs. 0.193
# Recall = 0.751 vs. 0.980
# Minibatch Loss= 0.579571
# Train Batch Evaluation
# AUC = 0.722 vs. 0.375
# F1 = 0.719 vs. 0.534
# Precision = 0.599 vs. 0.365
# Recall = 0.899 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.176
# F1 = 0.629 vs. 0.317
# Precision = 0.544 vs. 0.189
# Recall = 0.745 vs. 0.997
# Minibatch Loss= 0.653319
# Train Batch Evaluation
# AUC = 0.769 vs. 0.314
# F1 = 0.735 vs. 0.488
# Precision = 0.639 vs. 0.323
# Recall = 0.865 vs. 1.000
# Validation
# AUC = 0.620 vs. 0.200
# F1 = 0.628 vs. 0.317
# Precision = 0.537 vs. 0.189
# Recall = 0.758 vs. 0.984
# Minibatch Loss= 0.556649
# Train Batch Evaluation
# AUC = 0.696 vs. 0.322
# F1 = 0.715 vs. 0.478
# Precision = 0.606 vs. 0.315
# Recall = 0.874 vs. 0.996
# Validation
# AUC = 0.622 vs. 0.191
# F1 = 0.627 vs. 0.320
# Precision = 0.535 vs. 0.194
# Recall = 0.756 vs. 0.915
# Minibatch Loss= 0.584391
# Train Batch Evaluation
# AUC = 0.737 vs. 0.368
# F1 = 0.731 vs. 0.522
# Precision = 0.642 vs. 0.355
# Recall = 0.850 vs. 0.988
# Validation
# AUC = 0.625 vs. 0.200
# F1 = 0.630 vs. 0.318
# Precision = 0.543 vs. 0.190
# Recall = 0.749 vs. 0.974
# Minibatch Loss= 0.628711
# Train Batch Evaluation
# AUC = 0.717 vs. 0.321
# F1 = 0.700 vs. 0.484
# Precision = 0.601 vs. 0.322
# Recall = 0.838 vs. 0.980
# Validation
# AUC = 0.625 vs. 0.198
# F1 = 0.629 vs. 0.319
# Precision = 0.543 vs. 0.191
# Recall = 0.748 vs. 0.989
# Minibatch Loss= 0.621087
# Train Batch Evaluation
# AUC = 0.778 vs. 0.391
# F1 = 0.753 vs. 0.543
# Precision = 0.639 vs. 0.373
# Recall = 0.916 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.188
# F1 = 0.625 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.741 vs. 0.997
# Minibatch Loss= 0.608605
# Train Batch Evaluation
# AUC = 0.783 vs. 0.349
# F1 = 0.757 vs. 0.489
# Precision = 0.652 vs. 0.323
# Recall = 0.901 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.181
# F1 = 0.626 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.742 vs. 1.000
# Minibatch Loss= 0.527712
# Train Batch Evaluation
# AUC = 0.692 vs. 0.329
# F1 = 0.682 vs. 0.508
# Precision = 0.559 vs. 0.341
# Recall = 0.875 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.207
# F1 = 0.630 vs. 0.317
# Precision = 0.544 vs. 0.189
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.694641
# Train Batch Evaluation
# AUC = 0.706 vs. 0.310
# F1 = 0.696 vs. 0.452
# Precision = 0.618 vs. 0.292
# Recall = 0.797 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.180
# F1 = 0.630 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.584718
# Train Batch Evaluation
# AUC = 0.726 vs. 0.334
# F1 = 0.719 vs. 0.491
# Precision = 0.582 vs. 0.325
# Recall = 0.940 vs. 0.998
# Validation
# AUC = 0.621 vs. 0.178
# F1 = 0.628 vs. 0.317
# Precision = 0.540 vs. 0.188
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.581026
# Train Batch Evaluation
# AUC = 0.739 vs. 0.332
# F1 = 0.744 vs. 0.499
# Precision = 0.635 vs. 0.338
# Recall = 0.898 vs. 0.957
# Validation
# AUC = 0.625 vs. 0.181
# F1 = 0.630 vs. 0.317
# Precision = 0.545 vs. 0.189
# Recall = 0.748 vs. 0.997
# Minibatch Loss= 0.573863
# Train Batch Evaluation
# AUC = 0.678 vs. 0.324
# F1 = 0.689 vs. 0.502
# Precision = 0.584 vs. 0.335
# Recall = 0.840 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.192
# F1 = 0.629 vs. 0.318
# Precision = 0.544 vs. 0.190
# Recall = 0.744 vs. 0.986
# Minibatch Loss= 0.677823
# Train Batch Evaluation
# AUC = 0.679 vs. 0.308
# F1 = 0.685 vs. 0.431
# Precision = 0.625 vs. 0.275
# Recall = 0.758 vs. 0.995
# Validation
# AUC = 0.621 vs. 0.203
# F1 = 0.627 vs. 0.317
# Precision = 0.541 vs. 0.189
# Recall = 0.745 vs. 0.984
# Minibatch Loss= 0.562854
# Train Batch Evaluation
# AUC = 0.688 vs. 0.293
# F1 = 0.693 vs. 0.464
# Precision = 0.587 vs. 0.302
# Recall = 0.846 vs. 0.994
# Validation
# AUC = 0.619 vs. 0.181
# F1 = 0.624 vs. 0.318
# Precision = 0.529 vs. 0.189
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.628660
# Train Batch Evaluation
# AUC = 0.717 vs. 0.330
# F1 = 0.710 vs. 0.506
# Precision = 0.607 vs. 0.339
# Recall = 0.854 vs. 1.000
# Validation
# AUC = 0.624 vs. 0.191
# F1 = 0.628 vs. 0.319
# Precision = 0.538 vs. 0.191
# Recall = 0.754 vs. 0.969
# Minibatch Loss= 0.634111
# Train Batch Evaluation
# AUC = 0.692 vs. 0.272
# F1 = 0.708 vs. 0.423
# Precision = 0.612 vs. 0.268
# Recall = 0.839 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.184
# F1 = 0.629 vs. 0.317
# Precision = 0.540 vs. 0.189
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.537556
# Train Batch Evaluation
# AUC = 0.754 vs. 0.349
# F1 = 0.708 vs. 0.508
# Precision = 0.611 vs. 0.340
# Recall = 0.843 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.188
# F1 = 0.627 vs. 0.317
# Precision = 0.540 vs. 0.188
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.608376
# Train Batch Evaluation
# AUC = 0.766 vs. 0.352
# F1 = 0.754 vs. 0.512
# Precision = 0.660 vs. 0.344
# Recall = 0.880 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.196
# F1 = 0.626 vs. 0.317
# Precision = 0.539 vs. 0.188
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.568022
# Train Batch Evaluation
# AUC = 0.688 vs. 0.324
# F1 = 0.713 vs. 0.493
# Precision = 0.583 vs. 0.327
# Recall = 0.918 vs. 1.000
# Validation
# AUC = 0.620 vs. 0.183
# F1 = 0.626 vs. 0.317
# Precision = 0.533 vs. 0.188
# Recall = 0.759 vs. 1.000
# Minibatch Loss= 0.616500
# Train Batch Evaluation
# AUC = 0.753 vs. 0.344
# F1 = 0.738 vs. 0.522
# Precision = 0.631 vs. 0.354
# Recall = 0.890 vs. 0.998
# Validation
# AUC = 0.623 vs. 0.182
# F1 = 0.626 vs. 0.317
# Precision = 0.538 vs. 0.189
# Recall = 0.749 vs. 0.999
# Minibatch Loss= 0.605923
# Train Batch Evaluation
# AUC = 0.723 vs. 0.306
# F1 = 0.732 vs. 0.487
# Precision = 0.606 vs. 0.322
# Recall = 0.926 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.177
# F1 = 0.628 vs. 0.317
# Precision = 0.541 vs. 0.189
# Recall = 0.748 vs. 0.997
# Minibatch Loss= 0.572048
# Train Batch Evaluation
# AUC = 0.719 vs. 0.344
# F1 = 0.724 vs. 0.494
# Precision = 0.606 vs. 0.328
# Recall = 0.899 vs. 1.000
# Validation
# AUC = 0.619 vs. 0.181
# F1 = 0.625 vs. 0.318
# Precision = 0.537 vs. 0.189
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.597618
# Train Batch Evaluation
# AUC = 0.712 vs. 0.311
# F1 = 0.703 vs. 0.465
# Precision = 0.606 vs. 0.303
# Recall = 0.837 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.187
# F1 = 0.629 vs. 0.318
# Precision = 0.544 vs. 0.189
# Recall = 0.746 vs. 0.999
# Minibatch Loss= 0.588983
# Train Batch Evaluation
# AUC = 0.745 vs. 0.291
# F1 = 0.717 vs. 0.430
# Precision = 0.600 vs. 0.274
# Recall = 0.893 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.196
# F1 = 0.629 vs. 0.318
# Precision = 0.545 vs. 0.189
# Recall = 0.744 vs. 0.997
# Minibatch Loss= 0.504872
# Train Batch Evaluation
# AUC = 0.738 vs. 0.339
# F1 = 0.745 vs. 0.496
# Precision = 0.657 vs. 0.330
# Recall = 0.860 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.182
# F1 = 0.624 vs. 0.319
# Precision = 0.538 vs. 0.190
# Recall = 0.744 vs. 0.981
# Minibatch Loss= 0.567715
# Train Batch Evaluation
# AUC = 0.687 vs. 0.334
# F1 = 0.695 vs. 0.473
# Precision = 0.566 vs. 0.310
# Recall = 0.899 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.184
# F1 = 0.628 vs. 0.319
# Precision = 0.541 vs. 0.190
# Recall = 0.749 vs. 0.990
# Minibatch Loss= 0.611998
# Train Batch Evaluation
# AUC = 0.739 vs. 0.326
# F1 = 0.724 vs. 0.520
# Precision = 0.626 vs. 0.351
# Recall = 0.858 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.179
# F1 = 0.628 vs. 0.317
# Precision = 0.541 vs. 0.189
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.621035
# Train Batch Evaluation
# AUC = 0.720 vs. 0.305
# F1 = 0.715 vs. 0.489
# Precision = 0.634 vs. 0.324
# Recall = 0.818 vs. 1.000
# Validation
# AUC = 0.618 vs. 0.204
# F1 = 0.625 vs. 0.318
# Precision = 0.537 vs. 0.189
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.611317
# Train Batch Evaluation
# AUC = 0.751 vs. 0.340
# F1 = 0.738 vs. 0.529
# Precision = 0.644 vs. 0.359
# Recall = 0.863 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.193
# F1 = 0.627 vs. 0.318
# Precision = 0.539 vs. 0.189
# Recall = 0.749 vs. 0.990
# Minibatch Loss= 0.609162
# Train Batch Evaluation
# AUC = 0.723 vs. 0.318
# F1 = 0.713 vs. 0.467
# Precision = 0.608 vs. 0.304
# Recall = 0.860 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.183
# F1 = 0.626 vs. 0.318
# Precision = 0.539 vs. 0.189
# Recall = 0.745 vs. 0.993
# Minibatch Loss= 0.565987
# Train Batch Evaluation
# AUC = 0.761 vs. 0.350
# F1 = 0.735 vs. 0.498
# Precision = 0.639 vs. 0.331
# Recall = 0.864 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.182
# F1 = 0.629 vs. 0.317
# Precision = 0.544 vs. 0.190
# Recall = 0.746 vs. 0.964
# Minibatch Loss= 0.569375
# Train Batch Evaluation
# AUC = 0.735 vs. 0.365
# F1 = 0.729 vs. 0.514
# Precision = 0.642 vs. 0.346
# Recall = 0.843 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.191
# F1 = 0.628 vs. 0.319
# Precision = 0.540 vs. 0.190
# Recall = 0.749 vs. 0.999
# Minibatch Loss= 0.626467
# Train Batch Evaluation
# AUC = 0.730 vs. 0.325
# F1 = 0.722 vs. 0.499
# Precision = 0.661 vs. 0.332
# Recall = 0.797 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.192
# F1 = 0.630 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.600625
# Train Batch Evaluation
# AUC = 0.738 vs. 0.307
# F1 = 0.714 vs. 0.457
# Precision = 0.622 vs. 0.297
# Recall = 0.837 vs. 0.989
# Validation
# AUC = 0.623 vs. 0.189
# F1 = 0.627 vs. 0.319
# Precision = 0.540 vs. 0.191
# Recall = 0.746 vs. 0.974
# Minibatch Loss= 0.540049
# Train Batch Evaluation
# AUC = 0.798 vs. 0.335
# F1 = 0.769 vs. 0.512
# Precision = 0.658 vs. 0.344
# Recall = 0.924 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.185
# F1 = 0.629 vs. 0.318
# Precision = 0.534 vs. 0.189
# Recall = 0.765 vs. 0.997
# Minibatch Loss= 0.525047
# Train Batch Evaluation
# AUC = 0.708 vs. 0.325
# F1 = 0.707 vs. 0.508
# Precision = 0.589 vs. 0.341
# Recall = 0.884 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.190
# F1 = 0.625 vs. 0.319
# Precision = 0.537 vs. 0.191
# Recall = 0.748 vs. 0.959
# Minibatch Loss= 0.643959
# Train Batch Evaluation
# AUC = 0.737 vs. 0.406
# F1 = 0.726 vs. 0.576
# Precision = 0.603 vs. 0.404
# Recall = 0.910 vs. 1.000
# Validation
# AUC = 0.626 vs. 0.198
# F1 = 0.629 vs. 0.317
# Precision = 0.541 vs. 0.189
# Recall = 0.751 vs. 0.987
# Minibatch Loss= 0.703217
# Train Batch Evaluation
# AUC = 0.695 vs. 0.288
# F1 = 0.704 vs. 0.475
# Precision = 0.572 vs. 0.312
# Recall = 0.914 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.194
# F1 = 0.627 vs. 0.319
# Precision = 0.541 vs. 0.190
# Recall = 0.745 vs. 0.990
# Minibatch Loss= 0.593887
# Train Batch Evaluation
# AUC = 0.735 vs. 0.302
# F1 = 0.714 vs. 0.452
# Precision = 0.656 vs. 0.292
# Recall = 0.782 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.197
# F1 = 0.625 vs. 0.317
# Precision = 0.540 vs. 0.188
# Recall = 0.742 vs. 1.000
# Minibatch Loss= 0.540962
# Train Batch Evaluation
# AUC = 0.699 vs. 0.333
# F1 = 0.723 vs. 0.509
# Precision = 0.650 vs. 0.342
# Recall = 0.815 vs. 0.996
# Validation
# AUC = 0.623 vs. 0.191
# F1 = 0.628 vs. 0.317
# Precision = 0.543 vs. 0.189
# Recall = 0.745 vs. 0.997
# Minibatch Loss= 0.628610
# Train Batch Evaluation
# AUC = 0.735 vs. 0.314
# F1 = 0.720 vs. 0.475
# Precision = 0.609 vs. 0.311
# Recall = 0.882 vs. 1.000
# Validation
# AUC = 0.620 vs. 0.183
# F1 = 0.625 vs. 0.318
# Precision = 0.526 vs. 0.189
# Recall = 0.769 vs. 1.000
# Minibatch Loss= 0.573173
# Train Batch Evaluation
# AUC = 0.712 vs. 0.378
# F1 = 0.709 vs. 0.555
# Precision = 0.580 vs. 0.385
# Recall = 0.912 vs. 0.995
# Validation
# AUC = 0.625 vs. 0.195
# F1 = 0.631 vs. 0.321
# Precision = 0.541 vs. 0.192
# Recall = 0.758 vs. 0.970
# Minibatch Loss= 0.701236
# Train Batch Evaluation
# AUC = 0.729 vs. 0.307
# F1 = 0.737 vs. 0.460
# Precision = 0.623 vs. 0.301
# Recall = 0.903 vs. 0.979
# Validation
# AUC = 0.621 vs. 0.188
# F1 = 0.626 vs. 0.317
# Precision = 0.537 vs. 0.188
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.537159
# Train Batch Evaluation
# AUC = 0.695 vs. 0.311
# F1 = 0.670 vs. 0.471
# Precision = 0.576 vs. 0.308
# Recall = 0.800 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.188
# F1 = 0.631 vs. 0.318
# Precision = 0.546 vs. 0.189
# Recall = 0.748 vs. 0.993
# Minibatch Loss= 0.636435
# Train Batch Evaluation
# AUC = 0.685 vs. 0.308
# F1 = 0.698 vs. 0.461
# Precision = 0.616 vs. 0.301
# Recall = 0.805 vs. 0.985
# Validation
# AUC = 0.623 vs. 0.186
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.190
# Recall = 0.748 vs. 0.973
# Minibatch Loss= 0.593017
# Train Batch Evaluation
# AUC = 0.708 vs. 0.288
# F1 = 0.701 vs. 0.447
# Precision = 0.573 vs. 0.289
# Recall = 0.905 vs. 0.991
# Validation
# AUC = 0.623 vs. 0.197
# F1 = 0.629 vs. 0.318
# Precision = 0.544 vs. 0.189
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.565055
# Train Batch Evaluation
# AUC = 0.679 vs. 0.332
# F1 = 0.704 vs. 0.489
# Precision = 0.583 vs. 0.325
# Recall = 0.888 vs. 0.984
# Validation
# AUC = 0.622 vs. 0.194
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.190
# Recall = 0.749 vs. 0.976
# Minibatch Loss= 0.628334
# Train Batch Evaluation
# AUC = 0.725 vs. 0.364
# F1 = 0.735 vs. 0.551
# Precision = 0.622 vs. 0.381
# Recall = 0.899 vs. 0.998
# Validation
# AUC = 0.623 vs. 0.186
# F1 = 0.629 vs. 0.318
# Precision = 0.542 vs. 0.189
# Recall = 0.748 vs. 0.993
# Minibatch Loss= 0.667972
# Train Batch Evaluation
# AUC = 0.737 vs. 0.323
# F1 = 0.729 vs. 0.470
# Precision = 0.646 vs. 0.310
# Recall = 0.835 vs. 0.973
# Validation
# AUC = 0.621 vs. 0.200
# F1 = 0.628 vs. 0.320
# Precision = 0.541 vs. 0.192
# Recall = 0.748 vs. 0.973
# Minibatch Loss= 0.551223
# Train Batch Evaluation
# AUC = 0.647 vs. 0.301
# F1 = 0.668 vs. 0.454
# Precision = 0.545 vs. 0.294
# Recall = 0.863 vs. 0.994
# Validation
# AUC = 0.621 vs. 0.190
# F1 = 0.629 vs. 0.320
# Precision = 0.541 vs. 0.191
# Recall = 0.751 vs. 0.984
# Minibatch Loss= 0.639102
# Train Batch Evaluation
# AUC = 0.742 vs. 0.388
# F1 = 0.737 vs. 0.539
# Precision = 0.627 vs. 0.369
# Recall = 0.895 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.186
# F1 = 0.630 vs. 0.317
# Precision = 0.545 vs. 0.189
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.637544
# Train Batch Evaluation
# AUC = 0.687 vs. 0.292
# F1 = 0.685 vs. 0.461
# Precision = 0.586 vs. 0.299
# Recall = 0.824 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.199
# F1 = 0.629 vs. 0.318
# Precision = 0.542 vs. 0.189
# Recall = 0.748 vs. 0.999
# Minibatch Loss= 0.601635
# Train Batch Evaluation
# AUC = 0.739 vs. 0.330
# F1 = 0.722 vs. 0.487
# Precision = 0.596 vs. 0.324
# Recall = 0.917 vs. 0.979
# Validation
# AUC = 0.620 vs. 0.191
# F1 = 0.624 vs. 0.317
# Precision = 0.530 vs. 0.189
# Recall = 0.758 vs. 0.996
# Minibatch Loss= 0.589017
# Train Batch Evaluation
# AUC = 0.661 vs. 0.286
# F1 = 0.677 vs. 0.452
# Precision = 0.539 vs. 0.292
# Recall = 0.910 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.184
# F1 = 0.627 vs. 0.319
# Precision = 0.538 vs. 0.190
# Recall = 0.751 vs. 0.986
# Minibatch Loss= 0.613189
# Train Batch Evaluation
# AUC = 0.699 vs. 0.314
# F1 = 0.693 vs. 0.470
# Precision = 0.657 vs. 0.308
# Recall = 0.732 vs. 0.992
# Validation
# AUC = 0.622 vs. 0.193
# F1 = 0.628 vs. 0.318
# Precision = 0.543 vs. 0.189
# Recall = 0.745 vs. 1.000
# Minibatch Loss= 0.615735
# Train Batch Evaluation
# AUC = 0.742 vs. 0.337
# F1 = 0.741 vs. 0.516
# Precision = 0.620 vs. 0.349
# Recall = 0.919 vs. 0.989
# Validation
# AUC = 0.624 vs. 0.181
# F1 = 0.630 vs. 0.317
# Precision = 0.543 vs. 0.188
# Recall = 0.749 vs. 0.997
# Minibatch Loss= 0.590685
# Train Batch Evaluation
# AUC = 0.718 vs. 0.360
# F1 = 0.717 vs. 0.501
# Precision = 0.608 vs. 0.334
# Recall = 0.873 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.180
# F1 = 0.627 vs. 0.318
# Precision = 0.542 vs. 0.190
# Recall = 0.745 vs. 0.976
# Minibatch Loss= 0.613268
# Train Batch Evaluation
# AUC = 0.722 vs. 0.336
# F1 = 0.703 vs. 0.507
# Precision = 0.605 vs. 0.340
# Recall = 0.838 vs. 0.994
# Validation
# AUC = 0.625 vs. 0.199
# F1 = 0.627 vs. 0.317
# Precision = 0.543 vs. 0.190
# Recall = 0.744 vs. 0.973
# Minibatch Loss= 0.629142
# Train Batch Evaluation
# AUC = 0.698 vs. 0.316
# F1 = 0.710 vs. 0.504
# Precision = 0.588 vs. 0.337
# Recall = 0.895 vs. 0.994
# Validation
# AUC = 0.624 vs. 0.186
# F1 = 0.631 vs. 0.318
# Precision = 0.544 vs. 0.191
# Recall = 0.751 vs. 0.942
# Minibatch Loss= 0.640388
# Train Batch Evaluation
# AUC = 0.702 vs. 0.288
# F1 = 0.700 vs. 0.434
# Precision = 0.585 vs. 0.278
# Recall = 0.872 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.183
# F1 = 0.627 vs. 0.317
# Precision = 0.538 vs. 0.188
# Recall = 0.752 vs. 0.999
# Minibatch Loss= 0.554556
# Train Batch Evaluation
# AUC = 0.699 vs. 0.294
# F1 = 0.692 vs. 0.467
# Precision = 0.573 vs. 0.305
# Recall = 0.873 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.185
# F1 = 0.630 vs. 0.317
# Precision = 0.544 vs. 0.190
# Recall = 0.748 vs. 0.972
# Minibatch Loss= 0.601111
# Train Batch Evaluation
# AUC = 0.723 vs. 0.313
# F1 = 0.719 vs. 0.466
# Precision = 0.589 vs. 0.304
# Recall = 0.923 vs. 0.996
# Validation
# AUC = 0.622 vs. 0.195
# F1 = 0.628 vs. 0.319
# Precision = 0.539 vs. 0.190
# Recall = 0.751 vs. 0.993
# Minibatch Loss= 0.547351
# Train Batch Evaluation
# AUC = 0.735 vs. 0.280
# F1 = 0.721 vs. 0.451
# Precision = 0.607 vs. 0.292
# Recall = 0.886 vs. 0.991
# Validation
# AUC = 0.619 vs. 0.201
# F1 = 0.623 vs. 0.317
# Precision = 0.529 vs. 0.188
# Recall = 0.759 vs. 1.000
# Minibatch Loss= 0.528776
# Train Batch Evaluation
# AUC = 0.727 vs. 0.375
# F1 = 0.720 vs. 0.526
# Precision = 0.611 vs. 0.357
# Recall = 0.877 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.197
# F1 = 0.630 vs. 0.319
# Precision = 0.540 vs. 0.191
# Recall = 0.756 vs. 0.969
# Minibatch Loss= 0.645556
# Train Batch Evaluation
# AUC = 0.735 vs. 0.317
# F1 = 0.726 vs. 0.487
# Precision = 0.602 vs. 0.323
# Recall = 0.912 vs. 0.990
# Validation
# AUC = 0.620 vs. 0.190
# F1 = 0.624 vs. 0.319
# Precision = 0.526 vs. 0.190
# Recall = 0.768 vs. 0.999
# Minibatch Loss= 0.586619
# Train Batch Evaluation
# AUC = 0.715 vs. 0.342
# F1 = 0.721 vs. 0.523
# Precision = 0.636 vs. 0.354
# Recall = 0.832 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.178
# F1 = 0.624 vs. 0.317
# Precision = 0.524 vs. 0.188
# Recall = 0.772 vs. 1.000
# Minibatch Loss= 0.656525
# Train Batch Evaluation
# AUC = 0.739 vs. 0.330
# F1 = 0.723 vs. 0.496
# Precision = 0.613 vs. 0.330
# Recall = 0.882 vs. 0.996
# Validation
# AUC = 0.619 vs. 0.195
# F1 = 0.625 vs. 0.319
# Precision = 0.548 vs. 0.191
# Recall = 0.726 vs. 0.983
# Minibatch Loss= 0.594199
# Train Batch Evaluation
# AUC = 0.729 vs. 0.351
# F1 = 0.727 vs. 0.500
# Precision = 0.628 vs. 0.334
# Recall = 0.864 vs. 0.998
# Validation
# AUC = 0.622 vs. 0.181
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.746 vs. 0.997
# Minibatch Loss= 0.602788
# Train Batch Evaluation
# AUC = 0.751 vs. 0.277
# F1 = 0.737 vs. 0.450
# Precision = 0.624 vs. 0.292
# Recall = 0.898 vs. 0.989
# Validation
# AUC = 0.623 vs. 0.184
# F1 = 0.628 vs. 0.320
# Precision = 0.544 vs. 0.193
# Recall = 0.742 vs. 0.942
# Minibatch Loss= 0.506668
# Train Batch Evaluation
# AUC = 0.706 vs. 0.306
# F1 = 0.708 vs. 0.465
# Precision = 0.612 vs. 0.304
# Recall = 0.838 vs. 0.983
# Validation
# AUC = 0.626 vs. 0.186
# F1 = 0.632 vs. 0.319
# Precision = 0.542 vs. 0.190
# Recall = 0.756 vs. 0.987
# Minibatch Loss= 0.598890
# Train Batch Evaluation
# AUC = 0.723 vs. 0.343
# F1 = 0.718 vs. 0.510
# Precision = 0.611 vs. 0.342
# Recall = 0.868 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.193
# F1 = 0.626 vs. 0.318
# Precision = 0.539 vs. 0.190
# Recall = 0.746 vs. 0.983
# Minibatch Loss= 0.616787
# Train Batch Evaluation
# AUC = 0.700 vs. 0.299
# F1 = 0.692 vs. 0.438
# Precision = 0.564 vs. 0.281
# Recall = 0.898 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.181
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.557589
# Train Batch Evaluation
# AUC = 0.729 vs. 0.303
# F1 = 0.713 vs. 0.474
# Precision = 0.580 vs. 0.311
# Recall = 0.925 vs. 1.000
# Validation
# AUC = 0.621 vs. 0.184
# F1 = 0.627 vs. 0.317
# Precision = 0.539 vs. 0.188
# Recall = 0.749 vs. 0.999
# Minibatch Loss= 0.562783
# Train Batch Evaluation
# AUC = 0.718 vs. 0.288
# F1 = 0.720 vs. 0.447
# Precision = 0.599 vs. 0.290
# Recall = 0.902 vs. 0.970
# Validation
# AUC = 0.625 vs. 0.199
# F1 = 0.631 vs. 0.321
# Precision = 0.545 vs. 0.195
# Recall = 0.749 vs. 0.910
# Minibatch Loss= 0.540195
# Train Batch Evaluation
# AUC = 0.647 vs. 0.261
# F1 = 0.668 vs. 0.415
# Precision = 0.560 vs. 0.262
# Recall = 0.828 vs. 0.995
# Validation
# AUC = 0.621 vs. 0.193
# F1 = 0.624 vs. 0.318
# Precision = 0.524 vs. 0.190
# Recall = 0.772 vs. 0.960
# Minibatch Loss= 0.564221
# Train Batch Evaluation
# AUC = 0.645 vs. 0.306
# F1 = 0.669 vs. 0.463
# Precision = 0.521 vs. 0.303
# Recall = 0.933 vs. 0.979
# Validation
# AUC = 0.621 vs. 0.198
# F1 = 0.627 vs. 0.318
# Precision = 0.535 vs. 0.189
# Recall = 0.759 vs. 0.986
# Minibatch Loss= 0.640227
# Train Batch Evaluation
# AUC = 0.688 vs. 0.275
# F1 = 0.703 vs. 0.431
# Precision = 0.579 vs. 0.275
# Recall = 0.893 vs. 1.000
# Validation
# AUC = 0.622 vs. 0.184
# F1 = 0.628 vs. 0.318
# Precision = 0.541 vs. 0.189
# Recall = 0.748 vs. 0.990
# Minibatch Loss= 0.542493
# Train Batch Evaluation
# AUC = 0.701 vs. 0.318
# F1 = 0.704 vs. 0.473
# Precision = 0.649 vs. 0.310
# Recall = 0.770 vs. 1.000
# Validation
# AUC = 0.623 vs. 0.181
# F1 = 0.629 vs. 0.317
# Precision = 0.545 vs. 0.188
# Recall = 0.745 vs. 1.000
# Minibatch Loss= 0.591795
# Train Batch Evaluation
# AUC = 0.745 vs. 0.357
# F1 = 0.741 vs. 0.522
# Precision = 0.645 vs. 0.353
# Recall = 0.871 vs. 1.000
# Validation
# AUC = 0.625 vs. 0.191
# F1 = 0.631 vs. 0.317
# Precision = 0.546 vs. 0.188
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.615148
# Train Batch Evaluation
# AUC = 0.677 vs. 0.290
# F1 = 0.692 vs. 0.450
# Precision = 0.561 vs. 0.290
# Recall = 0.903 vs. 0.998
# Validation
# AUC = 0.622 vs. 0.200
# F1 = 0.628 vs. 0.318
# Precision = 0.542 vs. 0.189
# Recall = 0.746 vs. 0.999
# Minibatch Loss= 0.589161
# Train Batch Evaluation
# AUC = 0.690 vs. 0.282
# F1 = 0.685 vs. 0.436
# Precision = 0.581 vs. 0.280
# Recall = 0.834 vs. 0.987
# Validation
# AUC = 0.619 vs. 0.179
# F1 = 0.623 vs. 0.317
# Precision = 0.523 vs. 0.188
# Recall = 0.771 vs. 1.000
# Minibatch Loss= 0.563612
# Train Batch Evaluation
# AUC = 0.741 vs. 0.301
# F1 = 0.746 vs. 0.478
# Precision = 0.625 vs. 0.314
# Recall = 0.924 vs. 1.000
# Validation
# AUC = 0.619 vs. 0.183
# F1 = 0.624 vs. 0.317
# Precision = 0.524 vs. 0.189
# Recall = 0.771 vs. 1.000
# Minibatch Loss= 0.551600
# Train Batch Evaluation
# AUC = 0.761 vs. 0.348
# F1 = 0.746 vs. 0.507
# Precision = 0.639 vs. 0.340
# Recall = 0.896 vs. 0.993
# Validation
# AUC = 0.625 vs. 0.182
# F1 = 0.630 vs. 0.318
# Precision = 0.543 vs. 0.190
# Recall = 0.749 vs. 0.986
# Minibatch Loss= 0.569947
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/DWN_cpd_64/checkpoint-20000'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN7002_Gleam/CNN7002_Gleam-10000')

# %%
#This is the model evaluation on test dataset
result = nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.624 vs. 0.184
# F1 = 0.630 vs. 0.318
# Precision = 0.545 vs. 0.189
# Recall = 0.746 vs. 0.994

# %%
probability_of_pos = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
# Out:
# 1
