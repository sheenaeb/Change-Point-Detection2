# %%
# useing this variable for saving models and summaries
exp_name = "DWN_activity_Wmultitask_64_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 5    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
train_data.shape
# Out:
# (691, 1024, 77)

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.16329966,  34.21019108,  34.43589744,  37.12413793,
#         36.10067114,  26.70927318,  27.27621483,  39.94814815,
#         42.01945525,  46.65517241,  51.89952153,  48.57847534,
#         51.1509434 ,  43.40160643,  44.68595041,  33.7672956 ,
#         10.65015806,  36.60544218,   2.20649652])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet = True,
                                 trainable_conv = True,
                                 trainable_last = True,
                                 variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.078 vs. 0.080
# F1 = 0.126 vs. 0.123
# Accuracy = 0.004 vs. 0.056
# CHANGE DETECTION
# AUC = 0.404 vs. 0.358
# F1 = 0.513 vs. 0.498
# Precision = 0.421 vs. 0.332
# Recall = 0.658 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.068
# F1 = 0.103 vs. 0.101
# Accuracy = 0.001 vs. 0.056
# CHANGE DETECTION
# AUC = 0.208 vs. 0.170
# F1 = 0.312 vs. 0.315
# Precision = 0.214 vs. 0.187
# Recall = 0.575 vs. 0.997
# Minibatch Loss= 1.407298
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.564 vs. 0.082
# F1 = 0.605 vs. 0.127
# Accuracy = 0.459 vs. 0.056
# CHANGE DETECTION
# AUC = 0.780 vs. 0.355
# F1 = 0.746 vs. 0.545
# Precision = 0.671 vs. 0.375
# Recall = 0.839 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.329 vs. 0.068
# F1 = 0.397 vs. 0.098
# Accuracy = 0.528 vs. 0.056
# CHANGE DETECTION
# AUC = 0.460 vs. 0.193
# F1 = 0.518 vs. 0.313
# Precision = 0.468 vs. 0.185
# Recall = 0.581 vs. 1.000
# Minibatch Loss= 0.449908
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.718 vs. 0.077
# F1 = 0.710 vs. 0.116
# Accuracy = 0.763 vs. 0.056
# CHANGE DETECTION
# AUC = 0.709 vs. 0.318
# F1 = 0.690 vs. 0.476
# Precision = 0.568 vs. 0.312
# Recall = 0.879 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.402 vs. 0.070
# F1 = 0.471 vs. 0.101
# Accuracy = 0.661 vs. 0.056
# CHANGE DETECTION
# AUC = 0.488 vs. 0.209
# F1 = 0.539 vs. 0.317
# Precision = 0.442 vs. 0.191
# Recall = 0.689 vs. 0.920
# Minibatch Loss= 0.235371
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.773 vs. 0.083
# F1 = 0.763 vs. 0.130
# Accuracy = 0.768 vs. 0.056
# CHANGE DETECTION
# AUC = 0.772 vs. 0.361
# F1 = 0.726 vs. 0.514
# Precision = 0.638 vs. 0.346
# Recall = 0.843 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.403 vs. 0.069
# F1 = 0.468 vs. 0.098
# Accuracy = 0.731 vs. 0.056
# CHANGE DETECTION
# AUC = 0.488 vs. 0.192
# F1 = 0.525 vs. 0.312
# Precision = 0.431 vs. 0.185
# Recall = 0.670 vs. 0.994
# Minibatch Loss= 0.224370
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.800 vs. 0.081
# F1 = 0.801 vs. 0.126
# Accuracy = 0.798 vs. 0.056
# CHANGE DETECTION
# AUC = 0.796 vs. 0.367
# F1 = 0.744 vs. 0.537
# Precision = 0.671 vs. 0.367
# Recall = 0.835 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.418 vs. 0.068
# F1 = 0.477 vs. 0.099
# Accuracy = 0.780 vs. 0.056
# CHANGE DETECTION
# AUC = 0.501 vs. 0.200
# F1 = 0.561 vs. 0.312
# Precision = 0.475 vs. 0.186
# Recall = 0.684 vs. 0.969
# Minibatch Loss= 0.174932
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.860 vs. 0.074
# F1 = 0.869 vs. 0.113
# Accuracy = 0.839 vs. 0.056
# CHANGE DETECTION
# AUC = 0.803 vs. 0.268
# F1 = 0.768 vs. 0.433
# Precision = 0.692 vs. 0.281
# Recall = 0.862 vs. 0.943
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.427 vs. 0.071
# F1 = 0.479 vs. 0.104
# Accuracy = 0.734 vs. 0.056
# CHANGE DETECTION
# AUC = 0.503 vs. 0.181
# F1 = 0.548 vs. 0.316
# Precision = 0.500 vs. 0.188
# Recall = 0.607 vs. 0.994
# Minibatch Loss= 0.112109
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.855 vs. 0.075
# F1 = 0.862 vs. 0.110
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.794 vs. 0.274
# F1 = 0.738 vs. 0.428
# Precision = 0.669 vs. 0.273
# Recall = 0.823 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.434 vs. 0.068
# F1 = 0.494 vs. 0.099
# Accuracy = 0.797 vs. 0.056
# CHANGE DETECTION
# AUC = 0.497 vs. 0.170
# F1 = 0.535 vs. 0.314
# Precision = 0.444 vs. 0.187
# Recall = 0.672 vs. 0.974
# Minibatch Loss= 0.112990
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.902 vs. 0.081
# F1 = 0.893 vs. 0.121
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.817 vs. 0.288
# F1 = 0.779 vs. 0.458
# Precision = 0.684 vs. 0.297
# Recall = 0.905 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.447 vs. 0.067
# F1 = 0.496 vs. 0.102
# Accuracy = 0.825 vs. 0.056
# CHANGE DETECTION
# AUC = 0.488 vs. 0.175
# F1 = 0.536 vs. 0.312
# Precision = 0.440 vs. 0.185
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.091417
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.903 vs. 0.082
# F1 = 0.917 vs. 0.122
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.816 vs. 0.343
# F1 = 0.793 vs. 0.516
# Precision = 0.702 vs. 0.348
# Recall = 0.912 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.439 vs. 0.067
# F1 = 0.482 vs. 0.097
# Accuracy = 0.830 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.185
# F1 = 0.538 vs. 0.313
# Precision = 0.434 vs. 0.186
# Recall = 0.709 vs. 0.991
# Minibatch Loss= 0.094916
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.907 vs. 0.078
# F1 = 0.906 vs. 0.115
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.856 vs. 0.311
# F1 = 0.808 vs. 0.478
# Precision = 0.746 vs. 0.315
# Recall = 0.882 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.430 vs. 0.070
# F1 = 0.480 vs. 0.098
# Accuracy = 0.825 vs. 0.056
# CHANGE DETECTION
# AUC = 0.488 vs. 0.175
# F1 = 0.527 vs. 0.311
# Precision = 0.437 vs. 0.184
# Recall = 0.664 vs. 1.000
# Minibatch Loss= 0.085755
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.916 vs. 0.087
# F1 = 0.903 vs. 0.133
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.833 vs. 0.355
# F1 = 0.798 vs. 0.537
# Precision = 0.726 vs. 0.367
# Recall = 0.885 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.420 vs. 0.067
# F1 = 0.466 vs. 0.094
# Accuracy = 0.770 vs. 0.056
# CHANGE DETECTION
# AUC = 0.483 vs. 0.188
# F1 = 0.521 vs. 0.312
# Precision = 0.452 vs. 0.185
# Recall = 0.615 vs. 0.994
# Minibatch Loss= 0.110441
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.937 vs. 0.077
# F1 = 0.935 vs. 0.117
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.834 vs. 0.284
# F1 = 0.785 vs. 0.450
# Precision = 0.765 vs. 0.296
# Recall = 0.807 vs. 0.937
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.440 vs. 0.070
# F1 = 0.495 vs. 0.101
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.493 vs. 0.180
# F1 = 0.546 vs. 0.312
# Precision = 0.464 vs. 0.185
# Recall = 0.664 vs. 0.994
# Minibatch Loss= 0.068344
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.959 vs. 0.082
# F1 = 0.956 vs. 0.121
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.885 vs. 0.323
# F1 = 0.826 vs. 0.481
# Precision = 0.752 vs. 0.316
# Recall = 0.917 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.441 vs. 0.067
# F1 = 0.493 vs. 0.096
# Accuracy = 0.835 vs. 0.056
# CHANGE DETECTION
# AUC = 0.490 vs. 0.194
# F1 = 0.545 vs. 0.313
# Precision = 0.458 vs. 0.189
# Recall = 0.675 vs. 0.909
# Minibatch Loss= 0.061597
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.963 vs. 0.081
# F1 = 0.957 vs. 0.123
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.892 vs. 0.318
# F1 = 0.841 vs. 0.488
# Precision = 0.766 vs. 0.323
# Recall = 0.932 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.439 vs. 0.068
# F1 = 0.489 vs. 0.101
# Accuracy = 0.830 vs. 0.056
# CHANGE DETECTION
# AUC = 0.482 vs. 0.183
# F1 = 0.524 vs. 0.311
# Precision = 0.453 vs. 0.184
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 0.058606
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.817 vs. 0.084
# F1 = 0.782 vs. 0.127
# Accuracy = 0.703 vs. 0.056
# CHANGE DETECTION
# AUC = 0.757 vs. 0.351
# F1 = 0.729 vs. 0.516
# Precision = 0.629 vs. 0.348
# Recall = 0.867 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.469 vs. 0.070
# F1 = 0.525 vs. 0.101
# Accuracy = 0.662 vs. 0.056
# CHANGE DETECTION
# AUC = 0.499 vs. 0.187
# F1 = 0.555 vs. 0.317
# Precision = 0.460 vs. 0.198
# Recall = 0.701 vs. 0.792
# Minibatch Loss= 0.236364
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.912 vs. 0.077
# F1 = 0.895 vs. 0.111
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.827 vs. 0.301
# F1 = 0.786 vs. 0.460
# Precision = 0.729 vs. 0.298
# Recall = 0.853 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.497 vs. 0.069
# F1 = 0.537 vs. 0.095
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.525 vs. 0.184
# F1 = 0.569 vs. 0.313
# Precision = 0.513 vs. 0.185
# Recall = 0.638 vs. 0.997
# Minibatch Loss= 0.093923
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.939 vs. 0.080
# F1 = 0.933 vs. 0.123
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.831 vs. 0.344
# F1 = 0.780 vs. 0.513
# Precision = 0.683 vs. 0.346
# Recall = 0.911 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.502 vs. 0.070
# F1 = 0.544 vs. 0.105
# Accuracy = 0.828 vs. 0.056
# CHANGE DETECTION
# AUC = 0.530 vs. 0.192
# F1 = 0.584 vs. 0.313
# Precision = 0.481 vs. 0.186
# Recall = 0.744 vs. 0.994
# Minibatch Loss= 0.077721
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.945 vs. 0.076
# F1 = 0.943 vs. 0.108
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.828 vs. 0.282
# F1 = 0.764 vs. 0.448
# Precision = 0.706 vs. 0.290
# Recall = 0.831 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.070
# F1 = 0.539 vs. 0.102
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.528 vs. 0.189
# F1 = 0.577 vs. 0.313
# Precision = 0.491 vs. 0.186
# Recall = 0.701 vs. 0.977
# Minibatch Loss= 0.064191
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.945 vs. 0.080
# F1 = 0.953 vs. 0.127
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.862 vs. 0.321
# F1 = 0.817 vs. 0.479
# Precision = 0.744 vs. 0.315
# Recall = 0.904 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.067
# F1 = 0.542 vs. 0.098
# Accuracy = 0.840 vs. 0.056
# CHANGE DETECTION
# AUC = 0.534 vs. 0.175
# F1 = 0.584 vs. 0.312
# Precision = 0.516 vs. 0.185
# Recall = 0.672 vs. 1.000
# Minibatch Loss= 0.061745
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.964 vs. 0.085
# F1 = 0.967 vs. 0.135
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.886 vs. 0.358
# F1 = 0.836 vs. 0.515
# Precision = 0.764 vs. 0.346
# Recall = 0.924 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.071
# F1 = 0.545 vs. 0.101
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.535 vs. 0.189
# F1 = 0.587 vs. 0.319
# Precision = 0.498 vs. 0.192
# Recall = 0.715 vs. 0.937
# Minibatch Loss= 0.055841
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.968 vs. 0.078
# F1 = 0.972 vs. 0.118
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.887 vs. 0.298
# F1 = 0.838 vs. 0.452
# Precision = 0.759 vs. 0.292
# Recall = 0.936 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.068
# F1 = 0.537 vs. 0.099
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.530 vs. 0.192
# F1 = 0.578 vs. 0.314
# Precision = 0.486 vs. 0.187
# Recall = 0.712 vs. 0.989
# Minibatch Loss= 0.044297
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.959 vs. 0.075
# F1 = 0.971 vs. 0.114
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.917 vs. 0.302
# F1 = 0.873 vs. 0.454
# Precision = 0.824 vs. 0.298
# Recall = 0.928 vs. 0.952
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.502 vs. 0.069
# F1 = 0.540 vs. 0.097
# Accuracy = 0.850 vs. 0.056
# CHANGE DETECTION
# AUC = 0.529 vs. 0.206
# F1 = 0.576 vs. 0.312
# Precision = 0.476 vs. 0.185
# Recall = 0.729 vs. 1.000
# Minibatch Loss= 0.040611
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.084
# F1 = 0.966 vs. 0.129
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.894 vs. 0.381
# F1 = 0.840 vs. 0.530
# Precision = 0.761 vs. 0.361
# Recall = 0.938 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.506 vs. 0.071
# F1 = 0.541 vs. 0.108
# Accuracy = 0.852 vs. 0.056
# CHANGE DETECTION
# AUC = 0.519 vs. 0.194
# F1 = 0.568 vs. 0.313
# Precision = 0.468 vs. 0.186
# Recall = 0.724 vs. 0.983
# Minibatch Loss= 0.052777
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.081
# F1 = 0.969 vs. 0.122
# Accuracy = 0.950 vs. 0.056
# CHANGE DETECTION
# AUC = 0.934 vs. 0.353
# F1 = 0.886 vs. 0.508
# Precision = 0.860 vs. 0.342
# Recall = 0.914 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.508 vs. 0.067
# F1 = 0.540 vs. 0.093
# Accuracy = 0.854 vs. 0.056
# CHANGE DETECTION
# AUC = 0.526 vs. 0.186
# F1 = 0.575 vs. 0.316
# Precision = 0.492 vs. 0.195
# Recall = 0.692 vs. 0.829
# Minibatch Loss= 0.045894
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.880 vs. 0.080
# F1 = 0.833 vs. 0.120
# Accuracy = 0.852 vs. 0.056
# CHANGE DETECTION
# AUC = 0.806 vs. 0.298
# F1 = 0.765 vs. 0.478
# Precision = 0.695 vs. 0.314
# Recall = 0.851 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.488 vs. 0.070
# F1 = 0.535 vs. 0.104
# Accuracy = 0.809 vs. 0.056
# CHANGE DETECTION
# AUC = 0.537 vs. 0.189
# F1 = 0.577 vs. 0.318
# Precision = 0.537 vs. 0.190
# Recall = 0.624 vs. 0.974
# Minibatch Loss= 0.148662
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.941 vs. 0.074
# F1 = 0.909 vs. 0.113
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.809 vs. 0.274
# F1 = 0.762 vs. 0.436
# Precision = 0.675 vs. 0.279
# Recall = 0.874 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.507 vs. 0.068
# F1 = 0.549 vs. 0.096
# Accuracy = 0.798 vs. 0.056
# CHANGE DETECTION
# AUC = 0.548 vs. 0.167
# F1 = 0.587 vs. 0.312
# Precision = 0.528 vs. 0.185
# Recall = 0.661 vs. 1.000
# Minibatch Loss= 0.084708
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.937 vs. 0.081
# F1 = 0.930 vs. 0.120
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.867 vs. 0.323
# F1 = 0.814 vs. 0.490
# Precision = 0.726 vs. 0.324
# Recall = 0.925 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.070
# F1 = 0.546 vs. 0.105
# Accuracy = 0.841 vs. 0.056
# CHANGE DETECTION
# AUC = 0.558 vs. 0.174
# F1 = 0.597 vs. 0.313
# Precision = 0.538 vs. 0.186
# Recall = 0.672 vs. 0.980
# Minibatch Loss= 0.076308
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.949 vs. 0.077
# F1 = 0.946 vs. 0.117
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.304
# F1 = 0.843 vs. 0.489
# Precision = 0.780 vs. 0.325
# Recall = 0.917 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.067
# F1 = 0.550 vs. 0.094
# Accuracy = 0.846 vs. 0.056
# CHANGE DETECTION
# AUC = 0.568 vs. 0.178
# F1 = 0.610 vs. 0.315
# Precision = 0.527 vs. 0.192
# Recall = 0.724 vs. 0.889
# Minibatch Loss= 0.060939
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.963 vs. 0.079
# F1 = 0.958 vs. 0.116
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.858 vs. 0.285
# F1 = 0.814 vs. 0.450
# Precision = 0.727 vs. 0.290
# Recall = 0.925 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.072
# F1 = 0.557 vs. 0.103
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.581 vs. 0.184
# F1 = 0.619 vs. 0.314
# Precision = 0.542 vs. 0.186
# Recall = 0.721 vs. 1.000
# Minibatch Loss= 0.055760
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.961 vs. 0.082
# F1 = 0.962 vs. 0.122
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.895 vs. 0.341
# F1 = 0.841 vs. 0.505
# Precision = 0.794 vs. 0.338
# Recall = 0.894 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.072
# F1 = 0.556 vs. 0.103
# Accuracy = 0.855 vs. 0.056
# CHANGE DETECTION
# AUC = 0.575 vs. 0.181
# F1 = 0.619 vs. 0.314
# Precision = 0.539 vs. 0.186
# Recall = 0.726 vs. 0.989
# Minibatch Loss= 0.052071
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.083
# F1 = 0.975 vs. 0.134
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.899 vs. 0.338
# F1 = 0.838 vs. 0.501
# Precision = 0.801 vs. 0.334
# Recall = 0.879 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.506 vs. 0.070
# F1 = 0.548 vs. 0.098
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.569 vs. 0.206
# F1 = 0.611 vs. 0.313
# Precision = 0.535 vs. 0.193
# Recall = 0.712 vs. 0.823
# Minibatch Loss= 0.049777
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.078
# F1 = 0.982 vs. 0.119
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.913 vs. 0.350
# F1 = 0.847 vs. 0.494
# Precision = 0.809 vs. 0.329
# Recall = 0.889 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.507 vs. 0.069
# F1 = 0.554 vs. 0.100
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.562 vs. 0.195
# F1 = 0.609 vs. 0.314
# Precision = 0.527 vs. 0.187
# Recall = 0.721 vs. 0.986
# Minibatch Loss= 0.045697
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.962 vs. 0.079
# F1 = 0.970 vs. 0.120
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.901 vs. 0.292
# F1 = 0.869 vs. 0.446
# Precision = 0.801 vs. 0.287
# Recall = 0.949 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.070
# F1 = 0.550 vs. 0.102
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.564 vs. 0.173
# F1 = 0.612 vs. 0.312
# Precision = 0.532 vs. 0.185
# Recall = 0.721 vs. 1.000
# Minibatch Loss= 0.038188
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.076
# F1 = 0.984 vs. 0.118
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.929 vs. 0.254
# F1 = 0.873 vs. 0.415
# Precision = 0.825 vs. 0.262
# Recall = 0.928 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.068
# F1 = 0.551 vs. 0.097
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.559 vs. 0.182
# F1 = 0.605 vs. 0.312
# Precision = 0.525 vs. 0.185
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.029753
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.079
# F1 = 0.980 vs. 0.121
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.935 vs. 0.300
# F1 = 0.898 vs. 0.473
# Precision = 0.861 vs. 0.310
# Recall = 0.938 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.074
# F1 = 0.547 vs. 0.109
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.558 vs. 0.183
# F1 = 0.606 vs. 0.312
# Precision = 0.511 vs. 0.185
# Recall = 0.746 vs. 0.997
# Minibatch Loss= 0.032928
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.078
# F1 = 0.985 vs. 0.118
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.939 vs. 0.297
# F1 = 0.885 vs. 0.469
# Precision = 0.872 vs. 0.309
# Recall = 0.899 vs. 0.971
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.496 vs. 0.067
# F1 = 0.547 vs. 0.096
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.549 vs. 0.184
# F1 = 0.598 vs. 0.311
# Precision = 0.508 vs. 0.184
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.030883
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.078
# F1 = 0.988 vs. 0.126
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.311
# F1 = 0.883 vs. 0.481
# Precision = 0.820 vs. 0.321
# Recall = 0.956 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.494 vs. 0.070
# F1 = 0.549 vs. 0.103
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.542 vs. 0.190
# F1 = 0.598 vs. 0.312
# Precision = 0.525 vs. 0.185
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 0.032414
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.078
# F1 = 0.981 vs. 0.118
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.946 vs. 0.283
# F1 = 0.903 vs. 0.427
# Precision = 0.849 vs. 0.273
# Recall = 0.963 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.490 vs. 0.068
# F1 = 0.545 vs. 0.098
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.543 vs. 0.173
# F1 = 0.597 vs. 0.312
# Precision = 0.507 vs. 0.185
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.025225
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.077
# F1 = 0.986 vs. 0.119
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.954 vs. 0.321
# F1 = 0.899 vs. 0.464
# Precision = 0.833 vs. 0.303
# Recall = 0.977 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.488 vs. 0.071
# F1 = 0.540 vs. 0.112
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.538 vs. 0.191
# F1 = 0.597 vs. 0.314
# Precision = 0.513 vs. 0.187
# Recall = 0.712 vs. 0.986
# Minibatch Loss= 0.026707
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.080
# F1 = 0.994 vs. 0.119
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.964 vs. 0.314
# F1 = 0.917 vs. 0.480
# Precision = 0.883 vs. 0.318
# Recall = 0.954 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.484 vs. 0.068
# F1 = 0.540 vs. 0.100
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.530 vs. 0.197
# F1 = 0.595 vs. 0.317
# Precision = 0.508 vs. 0.189
# Recall = 0.718 vs. 0.983
# Minibatch Loss= 0.023116
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.075
# F1 = 0.991 vs. 0.112
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.956 vs. 0.298
# F1 = 0.924 vs. 0.437
# Precision = 0.897 vs. 0.280
# Recall = 0.953 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.483 vs. 0.069
# F1 = 0.538 vs. 0.102
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.528 vs. 0.186
# F1 = 0.584 vs. 0.312
# Precision = 0.491 vs. 0.185
# Recall = 0.721 vs. 0.986
# Minibatch Loss= 0.020966
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.080
# F1 = 0.990 vs. 0.119
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.965 vs. 0.309
# F1 = 0.907 vs. 0.483
# Precision = 0.873 vs. 0.318
# Recall = 0.945 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.487 vs. 0.067
# F1 = 0.542 vs. 0.094
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.527 vs. 0.186
# F1 = 0.575 vs. 0.313
# Precision = 0.492 vs. 0.186
# Recall = 0.692 vs. 0.983
# Minibatch Loss= 0.026600
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.768 vs. 0.080
# F1 = 0.747 vs. 0.125
# Accuracy = 0.697 vs. 0.056
# CHANGE DETECTION
# AUC = 0.736 vs. 0.315
# F1 = 0.717 vs. 0.477
# Precision = 0.633 vs. 0.319
# Recall = 0.827 vs. 0.952
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.452 vs. 0.070
# F1 = 0.505 vs. 0.101
# Accuracy = 0.679 vs. 0.056
# CHANGE DETECTION
# AUC = 0.495 vs. 0.199
# F1 = 0.520 vs. 0.314
# Precision = 0.420 vs. 0.187
# Recall = 0.681 vs. 0.994
# Minibatch Loss= 0.235546
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.860 vs. 0.081
# F1 = 0.831 vs. 0.116
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.839 vs. 0.295
# F1 = 0.783 vs. 0.446
# Precision = 0.693 vs. 0.287
# Recall = 0.899 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.475 vs. 0.068
# F1 = 0.539 vs. 0.100
# Accuracy = 0.793 vs. 0.056
# CHANGE DETECTION
# AUC = 0.542 vs. 0.192
# F1 = 0.589 vs. 0.312
# Precision = 0.504 vs. 0.186
# Recall = 0.709 vs. 0.989
# Minibatch Loss= 0.119142
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.915 vs. 0.079
# F1 = 0.884 vs. 0.118
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.858 vs. 0.338
# F1 = 0.797 vs. 0.497
# Precision = 0.736 vs. 0.330
# Recall = 0.867 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.497 vs. 0.072
# F1 = 0.545 vs. 0.108
# Accuracy = 0.817 vs. 0.056
# CHANGE DETECTION
# AUC = 0.570 vs. 0.199
# F1 = 0.592 vs. 0.317
# Precision = 0.540 vs. 0.190
# Recall = 0.655 vs. 0.972
# Minibatch Loss= 0.107218
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.933 vs. 0.079
# F1 = 0.904 vs. 0.117
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.853 vs. 0.286
# F1 = 0.811 vs. 0.459
# Precision = 0.792 vs. 0.300
# Recall = 0.831 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.506 vs. 0.068
# F1 = 0.547 vs. 0.103
# Accuracy = 0.841 vs. 0.056
# CHANGE DETECTION
# AUC = 0.581 vs. 0.192
# F1 = 0.597 vs. 0.316
# Precision = 0.534 vs. 0.188
# Recall = 0.678 vs. 0.991
# Minibatch Loss= 0.087940
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.955 vs. 0.079
# F1 = 0.939 vs. 0.116
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.861 vs. 0.270
# F1 = 0.818 vs. 0.430
# Precision = 0.748 vs. 0.276
# Recall = 0.904 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.068
# F1 = 0.547 vs. 0.095
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.589 vs. 0.175
# F1 = 0.606 vs. 0.314
# Precision = 0.547 vs. 0.187
# Recall = 0.678 vs. 0.991
# Minibatch Loss= 0.063188
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.951 vs. 0.081
# F1 = 0.939 vs. 0.126
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.878 vs. 0.365
# F1 = 0.839 vs. 0.527
# Precision = 0.796 vs. 0.358
# Recall = 0.886 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.069
# F1 = 0.554 vs. 0.102
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.593 vs. 0.186
# F1 = 0.607 vs. 0.312
# Precision = 0.535 vs. 0.185
# Recall = 0.701 vs. 0.997
# Minibatch Loss= 0.075235
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.956 vs. 0.079
# F1 = 0.945 vs. 0.115
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.880 vs. 0.316
# F1 = 0.833 vs. 0.479
# Precision = 0.744 vs. 0.315
# Recall = 0.946 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.070
# F1 = 0.555 vs. 0.101
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.594 vs. 0.188
# F1 = 0.604 vs. 0.313
# Precision = 0.530 vs. 0.186
# Recall = 0.701 vs. 0.994
# Minibatch Loss= 0.063412
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.956 vs. 0.080
# F1 = 0.949 vs. 0.123
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.303
# F1 = 0.827 vs. 0.473
# Precision = 0.780 vs. 0.310
# Recall = 0.881 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.515 vs. 0.070
# F1 = 0.555 vs. 0.103
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.592 vs. 0.193
# F1 = 0.599 vs. 0.311
# Precision = 0.537 vs. 0.184
# Recall = 0.678 vs. 1.000
# Minibatch Loss= 0.059541
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.955 vs. 0.083
# F1 = 0.952 vs. 0.123
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.851 vs. 0.290
# F1 = 0.829 vs. 0.468
# Precision = 0.776 vs. 0.305
# Recall = 0.889 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.070
# F1 = 0.552 vs. 0.101
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.594 vs. 0.192
# F1 = 0.600 vs. 0.311
# Precision = 0.521 vs. 0.184
# Recall = 0.707 vs. 1.000
# Minibatch Loss= 0.060092
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.080
# F1 = 0.971 vs. 0.124
# Accuracy = 0.937 vs. 0.056
# CHANGE DETECTION
# AUC = 0.918 vs. 0.369
# F1 = 0.861 vs. 0.524
# Precision = 0.804 vs. 0.356
# Recall = 0.928 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.514 vs. 0.069
# F1 = 0.554 vs. 0.097
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.595 vs. 0.190
# F1 = 0.601 vs. 0.312
# Precision = 0.548 vs. 0.189
# Recall = 0.664 vs. 0.900
# Minibatch Loss= 0.054959
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.973 vs. 0.080
# F1 = 0.968 vs. 0.122
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.919 vs. 0.334
# F1 = 0.872 vs. 0.491
# Precision = 0.804 vs. 0.325
# Recall = 0.953 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.070
# F1 = 0.555 vs. 0.098
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.594 vs. 0.195
# F1 = 0.598 vs. 0.313
# Precision = 0.537 vs. 0.188
# Recall = 0.675 vs. 0.920
# Minibatch Loss= 0.049696
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.077
# F1 = 0.978 vs. 0.122
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.310
# F1 = 0.872 vs. 0.465
# Precision = 0.800 vs. 0.307
# Recall = 0.958 vs. 0.962
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.069
# F1 = 0.550 vs. 0.102
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.599 vs. 0.187
# F1 = 0.602 vs. 0.312
# Precision = 0.545 vs. 0.188
# Recall = 0.672 vs. 0.934
# Minibatch Loss= 0.044514
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.079
# F1 = 0.978 vs. 0.123
# Accuracy = 0.949 vs. 0.056
# CHANGE DETECTION
# AUC = 0.901 vs. 0.320
# F1 = 0.860 vs. 0.482
# Precision = 0.795 vs. 0.318
# Recall = 0.937 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.070
# F1 = 0.548 vs. 0.107
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.604 vs. 0.184
# F1 = 0.602 vs. 0.312
# Precision = 0.549 vs. 0.185
# Recall = 0.667 vs. 1.000
# Minibatch Loss= 0.042597
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.968 vs. 0.078
# F1 = 0.970 vs. 0.118
# Accuracy = 0.948 vs. 0.056
# CHANGE DETECTION
# AUC = 0.902 vs. 0.338
# F1 = 0.850 vs. 0.482
# Precision = 0.790 vs. 0.318
# Recall = 0.921 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.512 vs. 0.070
# F1 = 0.548 vs. 0.104
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.604 vs. 0.196
# F1 = 0.596 vs. 0.313
# Precision = 0.532 vs. 0.185
# Recall = 0.678 vs. 0.997
# Minibatch Loss= 0.045426
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.076
# F1 = 0.985 vs. 0.118
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.911 vs. 0.300
# F1 = 0.872 vs. 0.442
# Precision = 0.825 vs. 0.285
# Recall = 0.924 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.511 vs. 0.071
# F1 = 0.549 vs. 0.106
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.182
# F1 = 0.592 vs. 0.312
# Precision = 0.529 vs. 0.185
# Recall = 0.672 vs. 0.991
# Minibatch Loss= 0.034354
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.083
# F1 = 0.986 vs. 0.128
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.941 vs. 0.359
# F1 = 0.891 vs. 0.519
# Precision = 0.860 vs. 0.352
# Recall = 0.925 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.512 vs. 0.070
# F1 = 0.552 vs. 0.104
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.190
# F1 = 0.591 vs. 0.313
# Precision = 0.525 vs. 0.185
# Recall = 0.675 vs. 1.000
# Minibatch Loss= 0.035911
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.079
# F1 = 0.982 vs. 0.118
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.916 vs. 0.304
# F1 = 0.870 vs. 0.477
# Precision = 0.817 vs. 0.313
# Recall = 0.930 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.068
# F1 = 0.552 vs. 0.098
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.604 vs. 0.172
# F1 = 0.589 vs. 0.311
# Precision = 0.523 vs. 0.184
# Recall = 0.672 vs. 1.000
# Minibatch Loss= 0.035690
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.079
# F1 = 0.987 vs. 0.115
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.946 vs. 0.279
# F1 = 0.881 vs. 0.450
# Precision = 0.842 vs. 0.291
# Recall = 0.924 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.508 vs. 0.069
# F1 = 0.551 vs. 0.100
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.200
# F1 = 0.590 vs. 0.311
# Precision = 0.551 vs. 0.184
# Recall = 0.635 vs. 1.000
# Minibatch Loss= 0.030239
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.077
# F1 = 0.991 vs. 0.119
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.299
# F1 = 0.906 vs. 0.461
# Precision = 0.855 vs. 0.300
# Recall = 0.962 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.070
# F1 = 0.550 vs. 0.103
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.193
# F1 = 0.596 vs. 0.311
# Precision = 0.559 vs. 0.184
# Recall = 0.638 vs. 1.000
# Minibatch Loss= 0.026121
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.080
# F1 = 0.989 vs. 0.120
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.949 vs. 0.344
# F1 = 0.904 vs. 0.501
# Precision = 0.852 vs. 0.335
# Recall = 0.962 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.067
# F1 = 0.549 vs. 0.099
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.604 vs. 0.182
# F1 = 0.595 vs. 0.313
# Precision = 0.656 vs. 0.185
# Recall = 0.544 vs. 1.000
# Minibatch Loss= 0.028538
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.078
# F1 = 0.985 vs. 0.116
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.311
# F1 = 0.925 vs. 0.431
# Precision = 0.902 vs. 0.275
# Recall = 0.950 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.071
# F1 = 0.551 vs. 0.100
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.193
# F1 = 0.596 vs. 0.313
# Precision = 0.647 vs. 0.188
# Recall = 0.553 vs. 0.932
# Minibatch Loss= 0.023792
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.080
# F1 = 0.993 vs. 0.119
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.974 vs. 0.347
# F1 = 0.939 vs. 0.513
# Precision = 0.904 vs. 0.345
# Recall = 0.976 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.070
# F1 = 0.550 vs. 0.108
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.603 vs. 0.180
# F1 = 0.595 vs. 0.313
# Precision = 0.633 vs. 0.185
# Recall = 0.561 vs. 1.000
# Minibatch Loss= 0.022914
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.081
# F1 = 0.990 vs. 0.123
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.966 vs. 0.340
# F1 = 0.938 vs. 0.522
# Precision = 0.907 vs. 0.353
# Recall = 0.972 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.069
# F1 = 0.550 vs. 0.101
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.176
# F1 = 0.594 vs. 0.316
# Precision = 0.559 vs. 0.191
# Recall = 0.632 vs. 0.917
# Minibatch Loss= 0.024066
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.079
# F1 = 0.994 vs. 0.117
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.959 vs. 0.369
# F1 = 0.924 vs. 0.518
# Precision = 0.889 vs. 0.353
# Recall = 0.962 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.511 vs. 0.067
# F1 = 0.551 vs. 0.097
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.599 vs. 0.186
# F1 = 0.595 vs. 0.311
# Precision = 0.607 vs. 0.185
# Recall = 0.584 vs. 0.977
# Minibatch Loss= 0.024388
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.082
# F1 = 0.996 vs. 0.122
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.359
# F1 = 0.935 vs. 0.514
# Precision = 0.914 vs. 0.345
# Recall = 0.956 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.508 vs. 0.069
# F1 = 0.548 vs. 0.104
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.600 vs. 0.194
# F1 = 0.597 vs. 0.313
# Precision = 0.550 vs. 0.192
# Recall = 0.652 vs. 0.843
# Minibatch Loss= 0.019479
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.082
# F1 = 0.994 vs. 0.127
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.979 vs. 0.346
# F1 = 0.949 vs. 0.539
# Precision = 0.945 vs. 0.369
# Recall = 0.954 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.070
# F1 = 0.549 vs. 0.099
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.192
# F1 = 0.602 vs. 0.313
# Precision = 0.552 vs. 0.186
# Recall = 0.661 vs. 0.997
# Minibatch Loss= 0.020035
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.082
# F1 = 0.991 vs. 0.121
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.332
# F1 = 0.946 vs. 0.490
# Precision = 0.931 vs. 0.325
# Recall = 0.961 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.071
# F1 = 0.549 vs. 0.105
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.597 vs. 0.177
# F1 = 0.598 vs. 0.312
# Precision = 0.553 vs. 0.185
# Recall = 0.650 vs. 1.000
# Minibatch Loss= 0.019376
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.075
# F1 = 0.990 vs. 0.112
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.981 vs. 0.274
# F1 = 0.955 vs. 0.432
# Precision = 0.922 vs. 0.276
# Recall = 0.991 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.504 vs. 0.069
# F1 = 0.547 vs. 0.100
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.596 vs. 0.195
# F1 = 0.595 vs. 0.315
# Precision = 0.542 vs. 0.189
# Recall = 0.658 vs. 0.954
# Minibatch Loss= 0.016297
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.081
# F1 = 0.995 vs. 0.123
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.358
# F1 = 0.944 vs. 0.508
# Precision = 0.923 vs. 0.341
# Recall = 0.967 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.496 vs. 0.067
# F1 = 0.547 vs. 0.097
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.593 vs. 0.218
# F1 = 0.595 vs. 0.312
# Precision = 0.551 vs. 0.185
# Recall = 0.647 vs. 0.989
# Minibatch Loss= 0.017581
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.079
# F1 = 0.994 vs. 0.119
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.330
# F1 = 0.965 vs. 0.485
# Precision = 0.956 vs. 0.328
# Recall = 0.974 vs. 0.931
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.499 vs. 0.073
# F1 = 0.549 vs. 0.102
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.588 vs. 0.183
# F1 = 0.596 vs. 0.312
# Precision = 0.537 vs. 0.185
# Recall = 0.670 vs. 0.997
# Minibatch Loss= 0.014871
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.116
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.324
# F1 = 0.964 vs. 0.481
# Precision = 0.953 vs. 0.317
# Recall = 0.974 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.071
# F1 = 0.549 vs. 0.101
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.587 vs. 0.189
# F1 = 0.594 vs. 0.315
# Precision = 0.542 vs. 0.188
# Recall = 0.655 vs. 0.980
# Minibatch Loss= 0.013234
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.119
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.270
# F1 = 0.962 vs. 0.409
# Precision = 0.945 vs. 0.259
# Recall = 0.978 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.504 vs. 0.067
# F1 = 0.550 vs. 0.094
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.582 vs. 0.183
# F1 = 0.595 vs. 0.319
# Precision = 0.547 vs. 0.195
# Recall = 0.652 vs. 0.877
# Minibatch Loss= 0.011362
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.997 vs. 0.121
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.305
# F1 = 0.970 vs. 0.463
# Precision = 0.956 vs. 0.303
# Recall = 0.985 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.502 vs. 0.067
# F1 = 0.550 vs. 0.100
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.582 vs. 0.196
# F1 = 0.596 vs. 0.313
# Precision = 0.537 vs. 0.186
# Recall = 0.670 vs. 0.989
# Minibatch Loss= 0.011399
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.077
# F1 = 0.997 vs. 0.114
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.305
# F1 = 0.980 vs. 0.481
# Precision = 0.973 vs. 0.319
# Recall = 0.988 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.508 vs. 0.072
# F1 = 0.548 vs. 0.104
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.578 vs. 0.189
# F1 = 0.599 vs. 0.312
# Precision = 0.548 vs. 0.185
# Recall = 0.661 vs. 1.000
# Minibatch Loss= 0.010801
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.787 vs. 0.078
# F1 = 0.741 vs. 0.114
# Accuracy = 0.731 vs. 0.056
# CHANGE DETECTION
# AUC = 0.758 vs. 0.315
# F1 = 0.714 vs. 0.493
# Precision = 0.605 vs. 0.328
# Recall = 0.870 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.470 vs. 0.068
# F1 = 0.526 vs. 0.100
# Accuracy = 0.684 vs. 0.056
# CHANGE DETECTION
# AUC = 0.464 vs. 0.183
# F1 = 0.487 vs. 0.311
# Precision = 0.382 vs. 0.184
# Recall = 0.672 vs. 1.000
# Minibatch Loss= 0.345063
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.945 vs. 0.081
# F1 = 0.922 vs. 0.120
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.328
# F1 = 0.827 vs. 0.516
# Precision = 0.775 vs. 0.348
# Recall = 0.886 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.069
# F1 = 0.547 vs. 0.098
# Accuracy = 0.847 vs. 0.056
# CHANGE DETECTION
# AUC = 0.585 vs. 0.183
# F1 = 0.585 vs. 0.313
# Precision = 0.510 vs. 0.187
# Recall = 0.687 vs. 0.960
# Minibatch Loss= 0.085158
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.967 vs. 0.083
# F1 = 0.949 vs. 0.125
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.897 vs. 0.319
# F1 = 0.855 vs. 0.506
# Precision = 0.796 vs. 0.339
# Recall = 0.924 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.502 vs. 0.068
# F1 = 0.542 vs. 0.099
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.587 vs. 0.197
# F1 = 0.586 vs. 0.312
# Precision = 0.558 vs. 0.185
# Recall = 0.618 vs. 0.997
# Minibatch Loss= 0.062002
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.084
# F1 = 0.967 vs. 0.117
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.923 vs. 0.336
# F1 = 0.872 vs. 0.503
# Precision = 0.819 vs. 0.336
# Recall = 0.933 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.504 vs. 0.069
# F1 = 0.542 vs. 0.103
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.593 vs. 0.198
# F1 = 0.591 vs. 0.316
# Precision = 0.547 vs. 0.188
# Recall = 0.641 vs. 0.994
# Minibatch Loss= 0.050627
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.081
# F1 = 0.970 vs. 0.126
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.937 vs. 0.321
# F1 = 0.875 vs. 0.502
# Precision = 0.823 vs. 0.337
# Recall = 0.934 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.072
# F1 = 0.545 vs. 0.106
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.201
# F1 = 0.599 vs. 0.317
# Precision = 0.561 vs. 0.190
# Recall = 0.644 vs. 0.943
# Minibatch Loss= 0.045440
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.077
# F1 = 0.976 vs. 0.118
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.936 vs. 0.294
# F1 = 0.896 vs. 0.447
# Precision = 0.842 vs. 0.288
# Recall = 0.959 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.070
# F1 = 0.545 vs. 0.099
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.184
# F1 = 0.601 vs. 0.313
# Precision = 0.548 vs. 0.185
# Recall = 0.664 vs. 1.000
# Minibatch Loss= 0.033963
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.084
# F1 = 0.983 vs. 0.124
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.949 vs. 0.374
# F1 = 0.910 vs. 0.532
# Precision = 0.865 vs. 0.362
# Recall = 0.960 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.506 vs. 0.069
# F1 = 0.548 vs. 0.098
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.179
# F1 = 0.606 vs. 0.311
# Precision = 0.548 vs. 0.184
# Recall = 0.678 vs. 1.000
# Minibatch Loss= 0.036987
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.077
# F1 = 0.987 vs. 0.116
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.950 vs. 0.294
# F1 = 0.899 vs. 0.458
# Precision = 0.861 vs. 0.298
# Recall = 0.941 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.069
# F1 = 0.549 vs. 0.099
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.185
# F1 = 0.609 vs. 0.314
# Precision = 0.548 vs. 0.187
# Recall = 0.687 vs. 0.972
# Minibatch Loss= 0.029672
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.081
# F1 = 0.990 vs. 0.120
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.320
# F1 = 0.921 vs. 0.500
# Precision = 0.877 vs. 0.333
# Recall = 0.970 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.070
# F1 = 0.549 vs. 0.100
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.188
# F1 = 0.603 vs. 0.312
# Precision = 0.528 vs. 0.186
# Recall = 0.704 vs. 0.986
# Minibatch Loss= 0.027852
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.078
# F1 = 0.995 vs. 0.121
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.967 vs. 0.309
# F1 = 0.929 vs. 0.458
# Precision = 0.904 vs. 0.297
# Recall = 0.956 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.507 vs. 0.068
# F1 = 0.553 vs. 0.099
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.186
# F1 = 0.599 vs. 0.311
# Precision = 0.530 vs. 0.184
# Recall = 0.689 vs. 1.000
# Minibatch Loss= 0.022070
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.077
# F1 = 0.991 vs. 0.115
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.309
# F1 = 0.932 vs. 0.475
# Precision = 0.893 vs. 0.314
# Recall = 0.974 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.506 vs. 0.069
# F1 = 0.551 vs. 0.099
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.186
# F1 = 0.601 vs. 0.312
# Precision = 0.545 vs. 0.185
# Recall = 0.670 vs. 1.000
# Minibatch Loss= 0.023404
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.079
# F1 = 0.997 vs. 0.120
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.315
# F1 = 0.935 vs. 0.470
# Precision = 0.920 vs. 0.307
# Recall = 0.951 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.512 vs. 0.069
# F1 = 0.556 vs. 0.104
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.189
# F1 = 0.597 vs. 0.313
# Precision = 0.539 vs. 0.187
# Recall = 0.670 vs. 0.952
# Minibatch Loss= 0.020744
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.076
# F1 = 0.996 vs. 0.117
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.273
# F1 = 0.930 vs. 0.424
# Precision = 0.901 vs. 0.269
# Recall = 0.960 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.511 vs. 0.069
# F1 = 0.558 vs. 0.101
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.194
# F1 = 0.604 vs. 0.319
# Precision = 0.555 vs. 0.193
# Recall = 0.664 vs. 0.909
# Minibatch Loss= 0.019229
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.078
# F1 = 0.995 vs. 0.110
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.278
# F1 = 0.949 vs. 0.426
# Precision = 0.911 vs. 0.271
# Recall = 0.991 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.514 vs. 0.070
# F1 = 0.557 vs. 0.093
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.602 vs. 0.181
# F1 = 0.604 vs. 0.312
# Precision = 0.584 vs. 0.185
# Recall = 0.627 vs. 0.997
# Minibatch Loss= 0.015313
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.078
# F1 = 0.997 vs. 0.120
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.320
# F1 = 0.964 vs. 0.482
# Precision = 0.938 vs. 0.318
# Recall = 0.990 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.071
# F1 = 0.559 vs. 0.099
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.598 vs. 0.195
# F1 = 0.604 vs. 0.315
# Precision = 0.573 vs. 0.187
# Recall = 0.638 vs. 0.989
# Minibatch Loss= 0.015951
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.074
# F1 = 0.997 vs. 0.115
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.272
# F1 = 0.950 vs. 0.424
# Precision = 0.923 vs. 0.269
# Recall = 0.979 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.069
# F1 = 0.559 vs. 0.099
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.598 vs. 0.198
# F1 = 0.604 vs. 0.313
# Precision = 0.575 vs. 0.186
# Recall = 0.635 vs. 0.991
# Minibatch Loss= 0.013790
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.082
# F1 = 0.995 vs. 0.125
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.348
# F1 = 0.967 vs. 0.503
# Precision = 0.954 vs. 0.336
# Recall = 0.979 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.516 vs. 0.069
# F1 = 0.562 vs. 0.099
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.597 vs. 0.185
# F1 = 0.600 vs. 0.315
# Precision = 0.583 vs. 0.187
# Recall = 0.618 vs. 0.994
# Minibatch Loss= 0.017284
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.080
# F1 = 0.995 vs. 0.120
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.292
# F1 = 0.973 vs. 0.473
# Precision = 0.957 vs. 0.312
# Recall = 0.990 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.514 vs. 0.069
# F1 = 0.561 vs. 0.099
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.591 vs. 0.185
# F1 = 0.595 vs. 0.314
# Precision = 0.559 vs. 0.187
# Recall = 0.635 vs. 0.994
# Minibatch Loss= 0.014384
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.079
# F1 = 0.996 vs. 0.118
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.318
# F1 = 0.978 vs. 0.473
# Precision = 0.967 vs. 0.309
# Recall = 0.989 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.070
# F1 = 0.565 vs. 0.111
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.591 vs. 0.184
# F1 = 0.593 vs. 0.311
# Precision = 0.563 vs. 0.184
# Recall = 0.627 vs. 1.000
# Minibatch Loss= 0.011627
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.078
# F1 = 0.996 vs. 0.119
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.307
# F1 = 0.983 vs. 0.473
# Precision = 0.980 vs. 0.309
# Recall = 0.986 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.514 vs. 0.070
# F1 = 0.566 vs. 0.108
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.592 vs. 0.178
# F1 = 0.588 vs. 0.312
# Precision = 0.548 vs. 0.185
# Recall = 0.635 vs. 0.997
# Minibatch Loss= 0.011512
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.117
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.298
# F1 = 0.986 vs. 0.458
# Precision = 0.979 vs. 0.297
# Recall = 0.994 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.070
# F1 = 0.566 vs. 0.103
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.592 vs. 0.180
# F1 = 0.589 vs. 0.313
# Precision = 0.582 vs. 0.186
# Recall = 0.595 vs. 0.983
# Minibatch Loss= 0.008575
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.078
# F1 = 0.997 vs. 0.117
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.308
# F1 = 0.988 vs. 0.487
# Precision = 0.983 vs. 0.327
# Recall = 0.994 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.512 vs. 0.067
# F1 = 0.568 vs. 0.099
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.588 vs. 0.197
# F1 = 0.589 vs. 0.315
# Precision = 0.592 vs. 0.188
# Recall = 0.587 vs. 0.972
# Minibatch Loss= 0.010038
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.074
# F1 = 0.998 vs. 0.113
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.275
# F1 = 0.990 vs. 0.429
# Precision = 0.982 vs. 0.273
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.070
# F1 = 0.567 vs. 0.100
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.589 vs. 0.201
# F1 = 0.590 vs. 0.315
# Precision = 0.515 vs. 0.187
# Recall = 0.689 vs. 0.980
# Minibatch Loss= 0.008177
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.079
# F1 = 0.997 vs. 0.121
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.294
# F1 = 0.988 vs. 0.457
# Precision = 0.985 vs. 0.296
# Recall = 0.992 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.512 vs. 0.070
# F1 = 0.564 vs. 0.101
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.584 vs. 0.174
# F1 = 0.588 vs. 0.315
# Precision = 0.592 vs. 0.190
# Recall = 0.584 vs. 0.923
# Minibatch Loss= 0.008372
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.123
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.274
# F1 = 0.996 vs. 0.446
# Precision = 0.991 vs. 0.287
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.071
# F1 = 0.565 vs. 0.107
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.583 vs. 0.184
# F1 = 0.591 vs. 0.312
# Precision = 0.598 vs. 0.185
# Recall = 0.584 vs. 1.000
# Minibatch Loss= 0.007371
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.122
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.318
# F1 = 0.991 vs. 0.493
# Precision = 0.983 vs. 0.327
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.512 vs. 0.067
# F1 = 0.565 vs. 0.094
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.583 vs. 0.195
# F1 = 0.588 vs. 0.316
# Precision = 0.521 vs. 0.188
# Recall = 0.675 vs. 0.977
# Minibatch Loss= 0.008482
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.125
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.344
# F1 = 0.992 vs. 0.516
# Precision = 0.984 vs. 0.348
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.071
# F1 = 0.565 vs. 0.102
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.538 vs. 0.187
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.006042
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.998 vs. 0.114
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.275
# F1 = 0.999 vs. 0.435
# Precision = 0.998 vs. 0.278
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.496 vs. 0.070
# F1 = 0.558 vs. 0.098
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.593 vs. 0.187
# F1 = 0.601 vs. 0.312
# Precision = 0.527 vs. 0.186
# Recall = 0.701 vs. 0.986
# Minibatch Loss= 0.005327
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.120
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.302
# F1 = 1.000 vs. 0.476
# Precision = 1.000 vs. 0.313
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.497 vs. 0.069
# F1 = 0.558 vs. 0.100
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.589 vs. 0.209
# F1 = 0.604 vs. 0.311
# Precision = 0.529 vs. 0.184
# Recall = 0.704 vs. 1.000
# Minibatch Loss= 0.005380
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.125
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.335
# F1 = 0.999 vs. 0.518
# Precision = 0.998 vs. 0.350
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.499 vs. 0.068
# F1 = 0.559 vs. 0.100
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.588 vs. 0.180
# F1 = 0.604 vs. 0.312
# Precision = 0.630 vs. 0.185
# Recall = 0.581 vs. 1.000
# Minibatch Loss= 0.005299
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.119
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.318
# F1 = 1.000 vs. 0.493
# Precision = 1.000 vs. 0.328
# Recall = 1.000 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.495 vs. 0.070
# F1 = 0.561 vs. 0.099
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.584 vs. 0.185
# F1 = 0.604 vs. 0.314
# Precision = 0.524 vs. 0.187
# Recall = 0.712 vs. 0.994
# Minibatch Loss= 0.003679
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 0.998 vs. 0.125
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.355
# F1 = 0.998 vs. 0.512
# Precision = 0.996 vs. 0.345
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.504 vs. 0.069
# F1 = 0.559 vs. 0.104
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.577 vs. 0.183
# F1 = 0.601 vs. 0.312
# Precision = 0.519 vs. 0.185
# Recall = 0.715 vs. 0.997
# Minibatch Loss= 0.004675
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.116
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.287
# F1 = 1.000 vs. 0.461
# Precision = 1.000 vs. 0.299
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.498 vs. 0.067
# F1 = 0.558 vs. 0.092
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.592 vs. 0.176
# F1 = 0.600 vs. 0.314
# Precision = 0.522 vs. 0.187
# Recall = 0.704 vs. 0.972
# Minibatch Loss= 0.003911
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.123
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.287
# F1 = 1.000 vs. 0.456
# Precision = 1.000 vs. 0.296
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.495 vs. 0.069
# F1 = 0.558 vs. 0.100
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.584 vs. 0.198
# F1 = 0.602 vs. 0.315
# Precision = 0.540 vs. 0.189
# Recall = 0.681 vs. 0.940
# Minibatch Loss= 0.003224
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.344
# F1 = 1.000 vs. 0.514
# Precision = 1.000 vs. 0.346
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.067
# F1 = 0.559 vs. 0.095
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.585 vs. 0.190
# F1 = 0.603 vs. 0.312
# Precision = 0.529 vs. 0.185
# Recall = 0.701 vs. 0.989
# Minibatch Loss= 0.004228
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.085
# F1 = 0.999 vs. 0.128
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.331
# F1 = 1.000 vs. 0.503
# Precision = 1.000 vs. 0.336
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.496 vs. 0.068
# F1 = 0.561 vs. 0.098
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.184
# F1 = 0.604 vs. 0.312
# Precision = 0.531 vs. 0.185
# Recall = 0.701 vs. 1.000
# Minibatch Loss= 0.003897
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.123
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.320
# F1 = 1.000 vs. 0.484
# Precision = 1.000 vs. 0.320
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.507 vs. 0.070
# F1 = 0.561 vs. 0.098
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.590 vs. 0.179
# F1 = 0.605 vs. 0.312
# Precision = 0.547 vs. 0.186
# Recall = 0.675 vs. 0.980
# Minibatch Loss= 0.003153
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.072
# F1 = 0.999 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.307
# F1 = 1.000 vs. 0.426
# Precision = 1.000 vs. 0.271
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.073
# F1 = 0.558 vs. 0.116
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.600 vs. 0.193
# F1 = 0.607 vs. 0.314
# Precision = 0.550 vs. 0.186
# Recall = 0.678 vs. 0.997
# Minibatch Loss= 0.002777
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.999 vs. 0.114
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.264
# F1 = 0.999 vs. 0.430
# Precision = 0.998 vs. 0.274
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.505 vs. 0.071
# F1 = 0.556 vs. 0.100
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.586 vs. 0.190
# F1 = 0.607 vs. 0.312
# Precision = 0.521 vs. 0.185
# Recall = 0.726 vs. 0.997
# Minibatch Loss= 0.002779
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.999 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.363
# F1 = 1.000 vs. 0.523
# Precision = 1.000 vs. 0.354
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.493 vs. 0.070
# F1 = 0.555 vs. 0.103
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.595 vs. 0.187
# F1 = 0.609 vs. 0.312
# Precision = 0.504 vs. 0.185
# Recall = 0.769 vs. 1.000
# Minibatch Loss= 0.003117
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.999 vs. 0.115
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.302
# F1 = 1.000 vs. 0.445
# Precision = 1.000 vs. 0.290
# Recall = 1.000 vs. 0.961
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.489 vs. 0.069
# F1 = 0.557 vs. 0.100
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.579 vs. 0.190
# F1 = 0.608 vs. 0.316
# Precision = 0.528 vs. 0.188
# Recall = 0.715 vs. 0.986
# Minibatch Loss= 0.002483
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.116
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 1.000 vs. 0.448
# Precision = 1.000 vs. 0.289
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.494 vs. 0.071
# F1 = 0.557 vs. 0.102
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.582 vs. 0.198
# F1 = 0.609 vs. 0.313
# Precision = 0.510 vs. 0.187
# Recall = 0.758 vs. 0.957
# Minibatch Loss= 0.002209
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.073
# F1 = 0.999 vs. 0.107
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.286
# F1 = 1.000 vs. 0.439
# Precision = 1.000 vs. 0.282
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.498 vs. 0.070
# F1 = 0.559 vs. 0.104
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.578 vs. 0.169
# F1 = 0.613 vs. 0.312
# Precision = 0.510 vs. 0.185
# Recall = 0.766 vs. 0.980
# Minibatch Loss= 0.002295
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.999 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.324
# F1 = 1.000 vs. 0.504
# Precision = 1.000 vs. 0.337
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.489 vs. 0.067
# F1 = 0.557 vs. 0.094
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.587 vs. 0.185
# F1 = 0.615 vs. 0.312
# Precision = 0.519 vs. 0.185
# Recall = 0.755 vs. 1.000
# Minibatch Loss= 0.002207
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.126
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.330
# F1 = 1.000 vs. 0.503
# Precision = 1.000 vs. 0.336
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.493 vs. 0.067
# F1 = 0.558 vs. 0.093
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.579 vs. 0.188
# F1 = 0.612 vs. 0.316
# Precision = 0.518 vs. 0.190
# Recall = 0.749 vs. 0.949
# Minibatch Loss= 0.002150
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.338
# F1 = 1.000 vs. 0.484
# Precision = 1.000 vs. 0.319
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.496 vs. 0.072
# F1 = 0.558 vs. 0.104
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.570 vs. 0.185
# F1 = 0.615 vs. 0.315
# Precision = 0.551 vs. 0.187
# Recall = 0.695 vs. 0.989
# Minibatch Loss= 0.001629
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.285
# F1 = 1.000 vs. 0.431
# Precision = 1.000 vs. 0.278
# Recall = 1.000 vs. 0.962
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.493 vs. 0.071
# F1 = 0.561 vs. 0.108
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.599 vs. 0.198
# F1 = 0.610 vs. 0.313
# Precision = 0.514 vs. 0.186
# Recall = 0.749 vs. 0.994
# Minibatch Loss= 0.001462
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.125
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.316
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.331
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.069
# F1 = 0.562 vs. 0.097
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.596 vs. 0.177
# F1 = 0.611 vs. 0.317
# Precision = 0.545 vs. 0.189
# Recall = 0.695 vs. 0.989
# Minibatch Loss= 0.001744
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.999 vs. 0.127
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.343
# F1 = 1.000 vs. 0.493
# Precision = 1.000 vs. 0.328
# Recall = 1.000 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.492 vs. 0.069
# F1 = 0.564 vs. 0.102
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.578 vs. 0.207
# F1 = 0.613 vs. 0.316
# Precision = 0.529 vs. 0.190
# Recall = 0.729 vs. 0.954
# Minibatch Loss= 0.001693
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 1.000 vs. 0.127
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.336
# F1 = 1.000 vs. 0.507
# Precision = 1.000 vs. 0.339
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.497 vs. 0.070
# F1 = 0.564 vs. 0.101
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.587 vs. 0.173
# F1 = 0.612 vs. 0.313
# Precision = 0.538 vs. 0.185
# Recall = 0.709 vs. 0.997
# Minibatch Loss= 0.001469
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.115
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.284
# F1 = 1.000 vs. 0.443
# Precision = 1.000 vs. 0.284
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.495 vs. 0.070
# F1 = 0.565 vs. 0.106
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.594 vs. 0.173
# F1 = 0.610 vs. 0.314
# Precision = 0.539 vs. 0.186
# Recall = 0.701 vs. 0.997
# Minibatch Loss= 0.001181
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.304
# F1 = 1.000 vs. 0.467
# Precision = 1.000 vs. 0.305
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.069
# F1 = 0.568 vs. 0.099
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.569 vs. 0.188
# F1 = 0.610 vs. 0.312
# Precision = 0.520 vs. 0.185
# Recall = 0.738 vs. 0.991
# Minibatch Loss= 0.001241
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.115
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.278
# F1 = 1.000 vs. 0.425
# Precision = 1.000 vs. 0.270
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.496 vs. 0.068
# F1 = 0.568 vs. 0.097
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.580 vs. 0.185
# F1 = 0.614 vs. 0.313
# Precision = 0.532 vs. 0.186
# Recall = 0.726 vs. 0.983
# Minibatch Loss= 0.001002
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.287
# F1 = 1.000 vs. 0.444
# Precision = 1.000 vs. 0.286
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.069
# F1 = 0.563 vs. 0.101
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.181
# F1 = 0.612 vs. 0.312
# Precision = 0.543 vs. 0.185
# Recall = 0.701 vs. 0.980
# Minibatch Loss= 0.001023
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.118
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.317
# F1 = 1.000 vs. 0.452
# Precision = 1.000 vs. 0.295
# Recall = 1.000 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.506 vs. 0.068
# F1 = 0.561 vs. 0.100
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.591 vs. 0.180
# F1 = 0.611 vs. 0.312
# Precision = 0.520 vs. 0.185
# Recall = 0.741 vs. 0.994
# Minibatch Loss= 0.000889
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.306
# F1 = 1.000 vs. 0.464
# Precision = 1.000 vs. 0.302
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.500 vs. 0.068
# F1 = 0.563 vs. 0.102
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.599 vs. 0.187
# F1 = 0.612 vs. 0.319
# Precision = 0.528 vs. 0.193
# Recall = 0.726 vs. 0.909
# Minibatch Loss= 0.000676
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.290
# F1 = 1.000 vs. 0.458
# Precision = 1.000 vs. 0.297
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.497 vs. 0.069
# F1 = 0.563 vs. 0.105
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.574 vs. 0.174
# F1 = 0.609 vs. 0.311
# Precision = 0.520 vs. 0.184
# Recall = 0.735 vs. 1.000
# Minibatch Loss= 0.000476
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.308
# F1 = 1.000 vs. 0.476
# Precision = 1.000 vs. 0.312
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.492 vs. 0.069
# F1 = 0.564 vs. 0.099
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.598 vs. 0.188
# F1 = 0.611 vs. 0.313
# Precision = 0.607 vs. 0.185
# Recall = 0.615 vs. 1.000
# Minibatch Loss= 0.000819
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.117
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.338
# F1 = 1.000 vs. 0.504
# Precision = 1.000 vs. 0.338
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.494 vs. 0.071
# F1 = 0.563 vs. 0.108
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.573 vs. 0.200
# F1 = 0.614 vs. 0.312
# Precision = 0.607 vs. 0.185
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 0.000622
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.112
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.287
# F1 = 1.000 vs. 0.452
# Precision = 1.000 vs. 0.292
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.498 vs. 0.070
# F1 = 0.563 vs. 0.098
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.588 vs. 0.181
# F1 = 0.614 vs. 0.315
# Precision = 0.605 vs. 0.187
# Recall = 0.624 vs. 0.994
# Minibatch Loss= 0.000636
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.297
# F1 = 1.000 vs. 0.465
# Precision = 1.000 vs. 0.303
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.499 vs. 0.069
# F1 = 0.565 vs. 0.099
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.558 vs. 0.191
# F1 = 0.615 vs. 0.311
# Precision = 0.594 vs. 0.184
# Recall = 0.638 vs. 1.000
# Minibatch Loss= 0.000428
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/DWN_activity_Wmultitask_64_opp/checkpoint-20000'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/DWN_activity_multitask_64_opp/checkpoint-20000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/DWN_activity_multitask_64_opp/checkpoint-20000

# %%
#This is the model evaluation on test dataset
result = nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.488 vs. 0.071
# F1 = 0.563 vs. 0.102
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.565 vs. 0.204
# F1 = 0.617 vs. 0.320
# Precision = 0.610 vs. 0.192
# Recall = 0.624 vs. 0.963

# %%
probability_of_pos = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
# Out:
# 1
