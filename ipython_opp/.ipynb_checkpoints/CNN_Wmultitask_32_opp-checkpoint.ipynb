# %%
# useing this variable for saving models and summaries
exp_name = "CNN_Wmultitask_32_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)


variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.28595522,  42.44204322,  42.96023857,  45.06666667,
#         44.49794239,  34.32268371,  35.42833608,  50.54312354,
#         54.97974684,  62.17714286,  69.87179487,  66.41463415,
#         71.02605863,  57.96533333,  57.4973545 ,  39.35036496,
#         12.09177028,  47.81236203,   4.77487595])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,
                     variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.068 vs. 0.068
# F1 = 0.102 vs. 0.103
# Accuracy = 0.024 vs. 0.056
# CHANGE DETECTION
# AUC = 0.165 vs. 0.171
# F1 = 0.291 vs. 0.293
# Precision = 0.170 vs. 0.172
# Recall = 1.000 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.064 vs. 0.061
# F1 = 0.088 vs. 0.089
# Accuracy = 0.021 vs. 0.056
# CHANGE DETECTION
# AUC = 0.092 vs. 0.104
# F1 = 0.181 vs. 0.184
# Precision = 0.100 vs. 0.103
# Recall = 1.000 vs. 0.844
# Minibatch Loss= 1.449339
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.478 vs. 0.066
# F1 = 0.538 vs. 0.097
# Accuracy = 0.525 vs. 0.056
# CHANGE DETECTION
# AUC = 0.357 vs. 0.144
# F1 = 0.447 vs. 0.274
# Precision = 0.351 vs. 0.159
# Recall = 0.616 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.359 vs. 0.065
# F1 = 0.441 vs. 0.089
# Accuracy = 0.561 vs. 0.056
# CHANGE DETECTION
# AUC = 0.255 vs. 0.104
# F1 = 0.340 vs. 0.181
# Precision = 0.293 vs. 0.100
# Recall = 0.406 vs. 1.000
# Minibatch Loss= 0.423075
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.068
# F1 = 0.638 vs. 0.102
# Accuracy = 0.759 vs. 0.056
# CHANGE DETECTION
# AUC = 0.472 vs. 0.170
# F1 = 0.521 vs. 0.297
# Precision = 0.420 vs. 0.176
# Recall = 0.685 vs. 0.938
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.439 vs. 0.062
# F1 = 0.510 vs. 0.085
# Accuracy = 0.719 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.100
# F1 = 0.374 vs. 0.183
# Precision = 0.300 vs. 0.101
# Recall = 0.499 vs. 0.939
# Minibatch Loss= 0.292817
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.690 vs. 0.069
# F1 = 0.694 vs. 0.106
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.475 vs. 0.179
# F1 = 0.546 vs. 0.301
# Precision = 0.448 vs. 0.177
# Recall = 0.701 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.481 vs. 0.062
# F1 = 0.537 vs. 0.089
# Accuracy = 0.794 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.102
# F1 = 0.412 vs. 0.187
# Precision = 0.346 vs. 0.106
# Recall = 0.509 vs. 0.792
# Minibatch Loss= 0.262302
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.744 vs. 0.069
# F1 = 0.730 vs. 0.107
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.526 vs. 0.184
# F1 = 0.582 vs. 0.302
# Precision = 0.489 vs. 0.184
# Recall = 0.718 vs. 0.842
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.062
# F1 = 0.555 vs. 0.090
# Accuracy = 0.810 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.106
# F1 = 0.432 vs. 0.181
# Precision = 0.352 vs. 0.100
# Recall = 0.559 vs. 1.000
# Minibatch Loss= 0.206896
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.771 vs. 0.069
# F1 = 0.751 vs. 0.104
# Accuracy = 0.818 vs. 0.056
# CHANGE DETECTION
# AUC = 0.588 vs. 0.196
# F1 = 0.605 vs. 0.320
# Precision = 0.541 vs. 0.191
# Recall = 0.685 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.526 vs. 0.063
# F1 = 0.561 vs. 0.089
# Accuracy = 0.806 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.111
# F1 = 0.429 vs. 0.186
# Precision = 0.324 vs. 0.105
# Recall = 0.633 vs. 0.826
# Minibatch Loss= 0.193534
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.755 vs. 0.066
# F1 = 0.733 vs. 0.097
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.528 vs. 0.160
# F1 = 0.566 vs. 0.279
# Precision = 0.462 vs. 0.162
# Recall = 0.731 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.062
# F1 = 0.591 vs. 0.089
# Accuracy = 0.836 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.100
# F1 = 0.436 vs. 0.181
# Precision = 0.327 vs. 0.100
# Recall = 0.657 vs. 1.000
# Minibatch Loss= 0.178958
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.799 vs. 0.067
# F1 = 0.780 vs. 0.101
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.562 vs. 0.157
# F1 = 0.603 vs. 0.280
# Precision = 0.510 vs. 0.163
# Recall = 0.739 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.064
# F1 = 0.597 vs. 0.097
# Accuracy = 0.829 vs. 0.056
# CHANGE DETECTION
# AUC = 0.363 vs. 0.105
# F1 = 0.444 vs. 0.186
# Precision = 0.323 vs. 0.103
# Recall = 0.712 vs. 0.921
# Minibatch Loss= 0.150392
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.787 vs. 0.067
# F1 = 0.786 vs. 0.099
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.605 vs. 0.150
# F1 = 0.628 vs. 0.275
# Precision = 0.541 vs. 0.160
# Recall = 0.748 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.061
# F1 = 0.617 vs. 0.085
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.363 vs. 0.098
# F1 = 0.436 vs. 0.184
# Precision = 0.314 vs. 0.102
# Recall = 0.712 vs. 0.979
# Minibatch Loss= 0.137385
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.867 vs. 0.068
# F1 = 0.838 vs. 0.104
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.664 vs. 0.186
# F1 = 0.675 vs. 0.308
# Precision = 0.606 vs. 0.182
# Recall = 0.763 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.063
# F1 = 0.616 vs. 0.089
# Accuracy = 0.863 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.097
# F1 = 0.445 vs. 0.181
# Precision = 0.323 vs. 0.100
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.129641
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.861 vs. 0.067
# F1 = 0.829 vs. 0.101
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.645 vs. 0.177
# F1 = 0.649 vs. 0.302
# Precision = 0.581 vs. 0.178
# Recall = 0.734 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.063
# F1 = 0.620 vs. 0.093
# Accuracy = 0.844 vs. 0.056
# CHANGE DETECTION
# AUC = 0.367 vs. 0.108
# F1 = 0.440 vs. 0.182
# Precision = 0.325 vs. 0.104
# Recall = 0.683 vs. 0.726
# Minibatch Loss= 0.142204
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.865 vs. 0.065
# F1 = 0.842 vs. 0.094
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.685 vs. 0.147
# F1 = 0.686 vs. 0.262
# Precision = 0.669 vs. 0.151
# Recall = 0.705 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.062
# F1 = 0.628 vs. 0.088
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.379 vs. 0.096
# F1 = 0.443 vs. 0.182
# Precision = 0.327 vs. 0.100
# Recall = 0.686 vs. 0.960
# Minibatch Loss= 0.103632
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.865 vs. 0.068
# F1 = 0.844 vs. 0.104
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.700 vs. 0.191
# F1 = 0.703 vs. 0.312
# Precision = 0.642 vs. 0.185
# Recall = 0.778 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.613 vs. 0.061
# F1 = 0.630 vs. 0.084
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.097
# F1 = 0.448 vs. 0.182
# Precision = 0.346 vs. 0.100
# Recall = 0.633 vs. 0.992
# Minibatch Loss= 0.115690
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.888 vs. 0.068
# F1 = 0.862 vs. 0.106
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.712 vs. 0.185
# F1 = 0.690 vs. 0.305
# Precision = 0.564 vs. 0.181
# Recall = 0.887 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.613 vs. 0.062
# F1 = 0.634 vs. 0.093
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.105
# F1 = 0.454 vs. 0.184
# Precision = 0.348 vs. 0.106
# Recall = 0.652 vs. 0.699
# Minibatch Loss= 0.101966
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.913 vs. 0.069
# F1 = 0.882 vs. 0.105
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.723 vs. 0.202
# F1 = 0.689 vs. 0.335
# Precision = 0.660 vs. 0.201
# Recall = 0.722 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.062
# F1 = 0.636 vs. 0.084
# Accuracy = 0.848 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.107
# F1 = 0.449 vs. 0.184
# Precision = 0.334 vs. 0.102
# Recall = 0.683 vs. 0.982
# Minibatch Loss= 0.104465
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.905 vs. 0.067
# F1 = 0.874 vs. 0.100
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.715 vs. 0.178
# F1 = 0.705 vs. 0.294
# Precision = 0.642 vs. 0.173
# Recall = 0.783 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.063
# F1 = 0.639 vs. 0.089
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.093
# F1 = 0.455 vs. 0.183
# Precision = 0.349 vs. 0.101
# Recall = 0.654 vs. 0.992
# Minibatch Loss= 0.092656
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.925 vs. 0.068
# F1 = 0.892 vs. 0.104
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.767 vs. 0.184
# F1 = 0.724 vs. 0.315
# Precision = 0.655 vs. 0.187
# Recall = 0.810 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.063
# F1 = 0.638 vs. 0.089
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.382 vs. 0.098
# F1 = 0.463 vs. 0.183
# Precision = 0.352 vs. 0.101
# Recall = 0.675 vs. 0.968
# Minibatch Loss= 0.096214
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.920 vs. 0.068
# F1 = 0.904 vs. 0.098
# Accuracy = 0.936 vs. 0.056
# CHANGE DETECTION
# AUC = 0.767 vs. 0.182
# F1 = 0.728 vs. 0.301
# Precision = 0.669 vs. 0.177
# Recall = 0.798 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.061
# F1 = 0.637 vs. 0.084
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.093
# F1 = 0.464 vs. 0.184
# Precision = 0.352 vs. 0.102
# Recall = 0.681 vs. 0.921
# Minibatch Loss= 0.081320
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.937 vs. 0.066
# F1 = 0.920 vs. 0.102
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.784 vs. 0.166
# F1 = 0.761 vs. 0.285
# Precision = 0.708 vs. 0.167
# Recall = 0.823 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.062
# F1 = 0.638 vs. 0.091
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.098
# F1 = 0.462 vs. 0.181
# Precision = 0.349 vs. 0.100
# Recall = 0.683 vs. 1.000
# Minibatch Loss= 0.070722
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.924 vs. 0.066
# F1 = 0.899 vs. 0.099
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.754 vs. 0.163
# F1 = 0.706 vs. 0.274
# Precision = 0.592 vs. 0.160
# Recall = 0.874 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.063
# F1 = 0.640 vs. 0.091
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.103
# F1 = 0.467 vs. 0.181
# Precision = 0.358 vs. 0.100
# Recall = 0.673 vs. 1.000
# Minibatch Loss= 0.072636
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.903 vs. 0.070
# F1 = 0.904 vs. 0.110
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.773 vs. 0.178
# F1 = 0.733 vs. 0.307
# Precision = 0.657 vs. 0.184
# Recall = 0.830 vs. 0.925
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.063
# F1 = 0.637 vs. 0.086
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.389 vs. 0.097
# F1 = 0.469 vs. 0.182
# Precision = 0.365 vs. 0.101
# Recall = 0.657 vs. 0.939
# Minibatch Loss= 0.073473
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.935 vs. 0.067
# F1 = 0.930 vs. 0.099
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.767 vs. 0.170
# F1 = 0.748 vs. 0.298
# Precision = 0.658 vs. 0.175
# Recall = 0.866 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.062
# F1 = 0.638 vs. 0.087
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.103
# F1 = 0.457 vs. 0.183
# Precision = 0.358 vs. 0.110
# Recall = 0.631 vs. 0.549
# Minibatch Loss= 0.062523
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.948 vs. 0.065
# F1 = 0.928 vs. 0.099
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.736 vs. 0.137
# F1 = 0.721 vs. 0.258
# Precision = 0.650 vs. 0.148
# Recall = 0.810 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.063
# F1 = 0.637 vs. 0.089
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.107
# F1 = 0.462 vs. 0.184
# Precision = 0.347 vs. 0.106
# Recall = 0.694 vs. 0.675
# Minibatch Loss= 0.057952
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.932 vs. 0.069
# F1 = 0.926 vs. 0.108
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.796 vs. 0.206
# F1 = 0.755 vs. 0.332
# Precision = 0.667 vs. 0.199
# Recall = 0.869 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.061
# F1 = 0.636 vs. 0.085
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.096
# F1 = 0.469 vs. 0.181
# Precision = 0.360 vs. 0.100
# Recall = 0.670 vs. 0.997
# Minibatch Loss= 0.068299
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.938 vs. 0.067
# F1 = 0.930 vs. 0.095
# Accuracy = 0.947 vs. 0.056
# CHANGE DETECTION
# AUC = 0.788 vs. 0.153
# F1 = 0.748 vs. 0.254
# Precision = 0.650 vs. 0.148
# Recall = 0.882 vs. 0.894
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.062
# F1 = 0.635 vs. 0.086
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.392 vs. 0.106
# F1 = 0.475 vs. 0.187
# Precision = 0.377 vs. 0.106
# Recall = 0.641 vs. 0.770
# Minibatch Loss= 0.055229
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.947 vs. 0.067
# F1 = 0.939 vs. 0.101
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.818 vs. 0.186
# F1 = 0.779 vs. 0.311
# Precision = 0.708 vs. 0.185
# Recall = 0.865 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.062
# F1 = 0.636 vs. 0.088
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.393 vs. 0.101
# F1 = 0.472 vs. 0.182
# Precision = 0.340 vs. 0.101
# Recall = 0.770 vs. 0.976
# Minibatch Loss= 0.059592
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.948 vs. 0.065
# F1 = 0.940 vs. 0.096
# Accuracy = 0.933 vs. 0.056
# CHANGE DETECTION
# AUC = 0.740 vs. 0.157
# F1 = 0.724 vs. 0.267
# Precision = 0.642 vs. 0.154
# Recall = 0.832 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.062
# F1 = 0.636 vs. 0.089
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.103
# F1 = 0.471 vs. 0.182
# Precision = 0.367 vs. 0.100
# Recall = 0.657 vs. 0.997
# Minibatch Loss= 0.055226
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.954 vs. 0.066
# F1 = 0.935 vs. 0.099
# Accuracy = 0.947 vs. 0.056
# CHANGE DETECTION
# AUC = 0.818 vs. 0.168
# F1 = 0.762 vs. 0.274
# Precision = 0.700 vs. 0.160
# Recall = 0.835 vs. 0.938
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.065
# F1 = 0.638 vs. 0.091
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.102
# F1 = 0.470 vs. 0.187
# Precision = 0.362 vs. 0.104
# Recall = 0.670 vs. 0.897
# Minibatch Loss= 0.055820
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.952 vs. 0.068
# F1 = 0.946 vs. 0.101
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.809 vs. 0.162
# F1 = 0.779 vs. 0.294
# Precision = 0.707 vs. 0.172
# Recall = 0.867 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.062
# F1 = 0.637 vs. 0.086
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.389 vs. 0.096
# F1 = 0.466 vs. 0.181
# Precision = 0.348 vs. 0.100
# Recall = 0.707 vs. 1.000
# Minibatch Loss= 0.054627
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.968 vs. 0.068
# F1 = 0.957 vs. 0.099
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.825 vs. 0.174
# F1 = 0.773 vs. 0.311
# Precision = 0.696 vs. 0.186
# Recall = 0.869 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.063
# F1 = 0.638 vs. 0.095
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.096
# F1 = 0.468 vs. 0.183
# Precision = 0.376 vs. 0.102
# Recall = 0.620 vs. 0.889
# Minibatch Loss= 0.054427
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.069
# F1 = 0.959 vs. 0.101
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.842 vs. 0.173
# F1 = 0.789 vs. 0.303
# Precision = 0.719 vs. 0.178
# Recall = 0.874 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.615 vs. 0.063
# F1 = 0.637 vs. 0.093
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.106
# F1 = 0.458 vs. 0.181
# Precision = 0.347 vs. 0.100
# Recall = 0.673 vs. 0.968
# Minibatch Loss= 0.050493
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.934 vs. 0.064
# F1 = 0.940 vs. 0.095
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.825 vs. 0.155
# F1 = 0.771 vs. 0.263
# Precision = 0.706 vs. 0.153
# Recall = 0.849 vs. 0.940
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.063
# F1 = 0.638 vs. 0.095
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.105
# F1 = 0.464 vs. 0.185
# Precision = 0.398 vs. 0.106
# Recall = 0.557 vs. 0.739
# Minibatch Loss= 0.048549
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.968 vs. 0.067
# F1 = 0.964 vs. 0.097
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.804 vs. 0.151
# F1 = 0.755 vs. 0.266
# Precision = 0.659 vs. 0.154
# Recall = 0.883 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.061
# F1 = 0.637 vs. 0.083
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.102
# F1 = 0.467 vs. 0.181
# Precision = 0.395 vs. 0.100
# Recall = 0.570 vs. 1.000
# Minibatch Loss= 0.048253
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.068
# F1 = 0.974 vs. 0.104
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.874 vs. 0.193
# F1 = 0.813 vs. 0.313
# Precision = 0.781 vs. 0.185
# Recall = 0.848 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.613 vs. 0.062
# F1 = 0.636 vs. 0.088
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.386 vs. 0.102
# F1 = 0.459 vs. 0.183
# Precision = 0.384 vs. 0.101
# Recall = 0.570 vs. 0.945
# Minibatch Loss= 0.039663
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.967 vs. 0.068
# F1 = 0.965 vs. 0.103
# Accuracy = 0.962 vs. 0.056
# CHANGE DETECTION
# AUC = 0.883 vs. 0.155
# F1 = 0.820 vs. 0.288
# Precision = 0.725 vs. 0.169
# Recall = 0.944 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.062
# F1 = 0.633 vs. 0.083
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.386 vs. 0.106
# F1 = 0.459 vs. 0.186
# Precision = 0.353 vs. 0.109
# Recall = 0.657 vs. 0.623
# Minibatch Loss= 0.040545
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.062
# F1 = 0.966 vs. 0.096
# Accuracy = 0.949 vs. 0.056
# CHANGE DETECTION
# AUC = 0.852 vs. 0.135
# F1 = 0.805 vs. 0.233
# Precision = 0.777 vs. 0.132
# Recall = 0.836 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.062
# F1 = 0.630 vs. 0.086
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.388 vs. 0.102
# F1 = 0.461 vs. 0.184
# Precision = 0.403 vs. 0.102
# Recall = 0.538 vs. 0.966
# Minibatch Loss= 0.033921
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.067
# F1 = 0.973 vs. 0.103
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.881 vs. 0.192
# F1 = 0.827 vs. 0.307
# Precision = 0.766 vs. 0.181
# Recall = 0.899 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.064
# F1 = 0.634 vs. 0.094
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.106
# F1 = 0.461 vs. 0.182
# Precision = 0.394 vs. 0.100
# Recall = 0.554 vs. 0.989
# Minibatch Loss= 0.038809
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.064
# F1 = 0.976 vs. 0.096
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.866 vs. 0.146
# F1 = 0.824 vs. 0.255
# Precision = 0.777 vs. 0.146
# Recall = 0.877 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.063
# F1 = 0.628 vs. 0.089
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.110
# F1 = 0.461 vs. 0.187
# Precision = 0.419 vs. 0.107
# Recall = 0.512 vs. 0.757
# Minibatch Loss= 0.033919
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.069
# F1 = 0.977 vs. 0.104
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.898 vs. 0.187
# F1 = 0.849 vs. 0.304
# Precision = 0.817 vs. 0.179
# Recall = 0.883 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.062
# F1 = 0.629 vs. 0.087
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.096
# F1 = 0.456 vs. 0.181
# Precision = 0.382 vs. 0.100
# Recall = 0.567 vs. 0.997
# Minibatch Loss= 0.037867
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.981 vs. 0.067
# F1 = 0.974 vs. 0.105
# Accuracy = 0.949 vs. 0.056
# CHANGE DETECTION
# AUC = 0.897 vs. 0.195
# F1 = 0.818 vs. 0.330
# Precision = 0.784 vs. 0.199
# Recall = 0.854 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.062
# F1 = 0.633 vs. 0.090
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.386 vs. 0.101
# F1 = 0.461 vs. 0.184
# Precision = 0.401 vs. 0.103
# Recall = 0.544 vs. 0.887
# Minibatch Loss= 0.040367
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.066
# F1 = 0.975 vs. 0.101
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.878 vs. 0.173
# F1 = 0.841 vs. 0.285
# Precision = 0.767 vs. 0.166
# Recall = 0.932 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.063
# F1 = 0.628 vs. 0.093
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.384 vs. 0.100
# F1 = 0.465 vs. 0.184
# Precision = 0.410 vs. 0.107
# Recall = 0.536 vs. 0.633
# Minibatch Loss= 0.033632
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.069
# F1 = 0.978 vs. 0.106
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.884 vs. 0.166
# F1 = 0.834 vs. 0.305
# Precision = 0.779 vs. 0.180
# Recall = 0.897 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.062
# F1 = 0.627 vs. 0.087
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.103
# F1 = 0.457 vs. 0.190
# Precision = 0.384 vs. 0.108
# Recall = 0.565 vs. 0.776
# Minibatch Loss= 0.037762
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.069
# F1 = 0.982 vs. 0.105
# Accuracy = 0.951 vs. 0.056
# CHANGE DETECTION
# AUC = 0.926 vs. 0.181
# F1 = 0.867 vs. 0.312
# Precision = 0.839 vs. 0.185
# Recall = 0.898 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.608 vs. 0.062
# F1 = 0.623 vs. 0.089
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.098
# F1 = 0.455 vs. 0.184
# Precision = 0.401 vs. 0.102
# Recall = 0.525 vs. 0.942
# Minibatch Loss= 0.035332
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.065
# F1 = 0.984 vs. 0.098
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.163
# F1 = 0.839 vs. 0.281
# Precision = 0.775 vs. 0.164
# Recall = 0.914 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.063
# F1 = 0.624 vs. 0.087
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.103
# F1 = 0.455 vs. 0.181
# Precision = 0.367 vs. 0.100
# Recall = 0.596 vs. 1.000
# Minibatch Loss= 0.031242
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.067
# F1 = 0.980 vs. 0.104
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.915 vs. 0.180
# F1 = 0.853 vs. 0.302
# Precision = 0.791 vs. 0.179
# Recall = 0.926 vs. 0.963
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.063
# F1 = 0.625 vs. 0.090
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.099
# F1 = 0.456 vs. 0.182
# Precision = 0.393 vs. 0.100
# Recall = 0.544 vs. 1.000
# Minibatch Loss= 0.030774
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.067
# F1 = 0.989 vs. 0.103
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.934 vs. 0.174
# F1 = 0.884 vs. 0.301
# Precision = 0.839 vs. 0.178
# Recall = 0.934 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.062
# F1 = 0.617 vs. 0.089
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.377 vs. 0.100
# F1 = 0.455 vs. 0.182
# Precision = 0.398 vs. 0.100
# Recall = 0.533 vs. 0.995
# Minibatch Loss= 0.028224
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.069
# F1 = 0.986 vs. 0.102
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.927 vs. 0.184
# F1 = 0.873 vs. 0.306
# Precision = 0.830 vs. 0.181
# Recall = 0.922 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.062
# F1 = 0.620 vs. 0.089
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.107
# F1 = 0.454 vs. 0.190
# Precision = 0.398 vs. 0.107
# Recall = 0.528 vs. 0.807
# Minibatch Loss= 0.029338
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.066
# F1 = 0.981 vs. 0.095
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.916 vs. 0.125
# F1 = 0.867 vs. 0.232
# Precision = 0.818 vs. 0.133
# Recall = 0.923 vs. 0.906
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.063
# F1 = 0.620 vs. 0.092
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.102
# F1 = 0.461 vs. 0.181
# Precision = 0.388 vs. 0.100
# Recall = 0.567 vs. 1.000
# Minibatch Loss= 0.023563
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.067
# F1 = 0.984 vs. 0.100
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.942 vs. 0.186
# F1 = 0.898 vs. 0.326
# Precision = 0.857 vs. 0.195
# Recall = 0.943 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.064
# F1 = 0.619 vs. 0.094
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.101
# F1 = 0.453 vs. 0.182
# Precision = 0.371 vs. 0.100
# Recall = 0.580 vs. 0.995
# Minibatch Loss= 0.026033
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.069
# F1 = 0.968 vs. 0.107
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.893 vs. 0.191
# F1 = 0.836 vs. 0.305
# Precision = 0.760 vs. 0.184
# Recall = 0.928 vs. 0.883
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.064
# F1 = 0.611 vs. 0.088
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.360 vs. 0.103
# F1 = 0.438 vs. 0.182
# Precision = 0.347 vs. 0.100
# Recall = 0.594 vs. 0.966
# Minibatch Loss= 0.076914
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.066
# F1 = 0.983 vs. 0.102
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.912 vs. 0.196
# F1 = 0.873 vs. 0.315
# Precision = 0.823 vs. 0.189
# Recall = 0.931 vs. 0.946
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.064
# F1 = 0.619 vs. 0.093
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.100
# F1 = 0.456 vs. 0.182
# Precision = 0.402 vs. 0.100
# Recall = 0.528 vs. 0.995
# Minibatch Loss= 0.029960
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.068
# F1 = 0.982 vs. 0.106
# Accuracy = 0.956 vs. 0.056
# CHANGE DETECTION
# AUC = 0.905 vs. 0.185
# F1 = 0.854 vs. 0.324
# Precision = 0.793 vs. 0.193
# Recall = 0.924 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.063
# F1 = 0.619 vs. 0.092
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.375 vs. 0.101
# F1 = 0.457 vs. 0.183
# Precision = 0.366 vs. 0.102
# Recall = 0.609 vs. 0.916
# Minibatch Loss= 0.032690
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.069
# F1 = 0.984 vs. 0.103
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.930 vs. 0.187
# F1 = 0.885 vs. 0.327
# Precision = 0.849 vs. 0.197
# Recall = 0.926 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.062
# F1 = 0.618 vs. 0.088
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.374 vs. 0.096
# F1 = 0.453 vs. 0.182
# Precision = 0.371 vs. 0.100
# Recall = 0.580 vs. 1.000
# Minibatch Loss= 0.028519
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.065
# F1 = 0.990 vs. 0.096
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.163
# F1 = 0.880 vs. 0.259
# Precision = 0.810 vs. 0.159
# Recall = 0.964 vs. 0.698
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.062
# F1 = 0.619 vs. 0.084
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.095
# F1 = 0.455 vs. 0.181
# Precision = 0.374 vs. 0.100
# Recall = 0.580 vs. 1.000
# Minibatch Loss= 0.020901
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.065
# F1 = 0.989 vs. 0.096
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.938 vs. 0.158
# F1 = 0.899 vs. 0.278
# Precision = 0.850 vs. 0.161
# Recall = 0.953 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.063
# F1 = 0.618 vs. 0.091
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.091
# F1 = 0.454 vs. 0.182
# Precision = 0.371 vs. 0.100
# Recall = 0.586 vs. 1.000
# Minibatch Loss= 0.021220
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.068
# F1 = 0.985 vs. 0.099
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.946 vs. 0.166
# F1 = 0.898 vs. 0.278
# Precision = 0.855 vs. 0.162
# Recall = 0.946 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.062
# F1 = 0.617 vs. 0.087
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.372 vs. 0.103
# F1 = 0.454 vs. 0.184
# Precision = 0.370 vs. 0.102
# Recall = 0.586 vs. 0.910
# Minibatch Loss= 0.020206
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.066
# F1 = 0.989 vs. 0.099
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.165
# F1 = 0.916 vs. 0.296
# Precision = 0.874 vs. 0.174
# Recall = 0.962 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.065
# F1 = 0.616 vs. 0.091
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.369 vs. 0.109
# F1 = 0.447 vs. 0.182
# Precision = 0.392 vs. 0.101
# Recall = 0.520 vs. 0.976
# Minibatch Loss= 0.021156
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.067
# F1 = 0.992 vs. 0.102
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.935 vs. 0.169
# F1 = 0.893 vs. 0.292
# Precision = 0.850 vs. 0.172
# Recall = 0.941 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.591 vs. 0.064
# F1 = 0.617 vs. 0.092
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.369 vs. 0.107
# F1 = 0.448 vs. 0.181
# Precision = 0.400 vs. 0.100
# Recall = 0.509 vs. 1.000
# Minibatch Loss= 0.021725
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.071
# F1 = 0.988 vs. 0.104
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.194
# F1 = 0.905 vs. 0.327
# Precision = 0.885 vs. 0.196
# Recall = 0.925 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.062
# F1 = 0.616 vs. 0.085
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.368 vs. 0.096
# F1 = 0.447 vs. 0.184
# Precision = 0.358 vs. 0.106
# Recall = 0.596 vs. 0.702
# Minibatch Loss= 0.024580
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.066
# F1 = 0.986 vs. 0.102
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.947 vs. 0.168
# F1 = 0.908 vs. 0.286
# Precision = 0.857 vs. 0.170
# Recall = 0.965 vs. 0.904
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.064
# F1 = 0.618 vs. 0.092
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.367 vs. 0.099
# F1 = 0.445 vs. 0.185
# Precision = 0.357 vs. 0.103
# Recall = 0.588 vs. 0.897
# Minibatch Loss= 0.022480
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.066
# F1 = 0.994 vs. 0.098
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.954 vs. 0.174
# F1 = 0.901 vs. 0.293
# Precision = 0.868 vs. 0.172
# Recall = 0.935 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.061
# F1 = 0.616 vs. 0.087
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.369 vs. 0.105
# F1 = 0.444 vs. 0.183
# Precision = 0.355 vs. 0.101
# Recall = 0.594 vs. 0.997
# Minibatch Loss= 0.019209
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.064
# F1 = 0.993 vs. 0.098
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.942 vs. 0.142
# F1 = 0.916 vs. 0.241
# Precision = 0.884 vs. 0.141
# Recall = 0.951 vs. 0.847
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.063
# F1 = 0.616 vs. 0.091
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.364 vs. 0.099
# F1 = 0.443 vs. 0.185
# Precision = 0.341 vs. 0.102
# Recall = 0.633 vs. 0.984
# Minibatch Loss= 0.016691
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.067
# F1 = 0.987 vs. 0.103
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.945 vs. 0.166
# F1 = 0.907 vs. 0.293
# Precision = 0.873 vs. 0.173
# Recall = 0.945 vs. 0.960
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.062
# F1 = 0.616 vs. 0.089
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.364 vs. 0.109
# F1 = 0.447 vs. 0.185
# Precision = 0.350 vs. 0.103
# Recall = 0.617 vs. 0.923
# Minibatch Loss= 0.023721
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.070
# F1 = 0.994 vs. 0.104
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.962 vs. 0.172
# F1 = 0.927 vs. 0.306
# Precision = 0.892 vs. 0.182
# Recall = 0.965 vs. 0.957
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.063
# F1 = 0.615 vs. 0.093
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.365 vs. 0.099
# F1 = 0.443 vs. 0.184
# Precision = 0.339 vs. 0.102
# Recall = 0.636 vs. 0.934
# Minibatch Loss= 0.017912
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.069
# F1 = 0.995 vs. 0.104
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.187
# F1 = 0.914 vs. 0.322
# Precision = 0.894 vs. 0.193
# Recall = 0.934 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.064
# F1 = 0.618 vs. 0.092
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.365 vs. 0.103
# F1 = 0.444 vs. 0.181
# Precision = 0.375 vs. 0.100
# Recall = 0.544 vs. 1.000
# Minibatch Loss= 0.021004
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.068
# F1 = 0.994 vs. 0.103
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.961 vs. 0.177
# F1 = 0.934 vs. 0.317
# Precision = 0.915 vs. 0.189
# Recall = 0.953 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.062
# F1 = 0.614 vs. 0.092
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.360 vs. 0.099
# F1 = 0.440 vs. 0.183
# Precision = 0.337 vs. 0.102
# Recall = 0.636 vs. 0.931
# Minibatch Loss= 0.017567
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.071
# F1 = 0.992 vs. 0.111
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.956 vs. 0.215
# F1 = 0.915 vs. 0.346
# Precision = 0.884 vs. 0.210
# Recall = 0.949 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.062
# F1 = 0.617 vs. 0.091
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.359 vs. 0.109
# F1 = 0.442 vs. 0.186
# Precision = 0.359 vs. 0.103
# Recall = 0.573 vs. 0.934
# Minibatch Loss= 0.022224
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.068
# F1 = 0.993 vs. 0.100
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.962 vs. 0.159
# F1 = 0.921 vs. 0.279
# Precision = 0.890 vs. 0.162
# Recall = 0.954 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.062
# F1 = 0.614 vs. 0.087
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.356 vs. 0.106
# F1 = 0.438 vs. 0.181
# Precision = 0.359 vs. 0.100
# Recall = 0.562 vs. 1.000
# Minibatch Loss= 0.016460
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.067
# F1 = 0.993 vs. 0.100
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.163
# F1 = 0.931 vs. 0.280
# Precision = 0.895 vs. 0.163
# Recall = 0.971 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.062
# F1 = 0.615 vs. 0.089
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.358 vs. 0.096
# F1 = 0.441 vs. 0.181
# Precision = 0.352 vs. 0.100
# Recall = 0.588 vs. 0.997
# Minibatch Loss= 0.016210
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.068
# F1 = 0.991 vs. 0.101
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.966 vs. 0.178
# F1 = 0.935 vs. 0.309
# Precision = 0.911 vs. 0.185
# Recall = 0.960 vs. 0.929
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.063
# F1 = 0.613 vs. 0.091
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.349 vs. 0.107
# F1 = 0.436 vs. 0.182
# Precision = 0.411 vs. 0.100
# Recall = 0.464 vs. 0.971
# Minibatch Loss= 0.018223
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.066
# F1 = 0.993 vs. 0.100
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.958 vs. 0.164
# F1 = 0.931 vs. 0.279
# Precision = 0.885 vs. 0.162
# Recall = 0.983 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.062
# F1 = 0.612 vs. 0.085
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.361 vs. 0.104
# F1 = 0.444 vs. 0.181
# Precision = 0.370 vs. 0.100
# Recall = 0.557 vs. 1.000
# Minibatch Loss= 0.016605
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.964 vs. 0.068
# F1 = 0.916 vs. 0.099
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.852 vs. 0.170
# F1 = 0.773 vs. 0.294
# Precision = 0.697 vs. 0.174
# Recall = 0.867 vs. 0.954
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.064
# F1 = 0.590 vs. 0.092
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.370 vs. 0.099
# F1 = 0.444 vs. 0.182
# Precision = 0.328 vs. 0.100
# Recall = 0.691 vs. 1.000
# Minibatch Loss= 0.145891
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.068
# F1 = 0.993 vs. 0.104
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.959 vs. 0.179
# F1 = 0.926 vs. 0.321
# Precision = 0.896 vs. 0.191
# Recall = 0.957 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.062
# F1 = 0.619 vs. 0.088
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.355 vs. 0.095
# F1 = 0.440 vs. 0.181
# Precision = 0.344 vs. 0.100
# Recall = 0.609 vs. 1.000
# Minibatch Loss= 0.018504
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.066
# F1 = 0.992 vs. 0.100
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.182
# F1 = 0.930 vs. 0.301
# Precision = 0.912 vs. 0.178
# Recall = 0.949 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.063
# F1 = 0.622 vs. 0.090
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.354 vs. 0.099
# F1 = 0.435 vs. 0.184
# Precision = 0.328 vs. 0.102
# Recall = 0.646 vs. 0.929
# Minibatch Loss= 0.017693
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.069
# F1 = 0.990 vs. 0.106
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.967 vs. 0.203
# F1 = 0.933 vs. 0.335
# Precision = 0.891 vs. 0.201
# Recall = 0.978 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.062
# F1 = 0.620 vs. 0.090
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.356 vs. 0.098
# F1 = 0.437 vs. 0.183
# Precision = 0.360 vs. 0.101
# Recall = 0.554 vs. 0.974
# Minibatch Loss= 0.018648
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.067
# F1 = 0.991 vs. 0.101
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.966 vs. 0.167
# F1 = 0.926 vs. 0.277
# Precision = 0.893 vs. 0.161
# Recall = 0.963 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.063
# F1 = 0.617 vs. 0.090
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.104
# F1 = 0.435 vs. 0.186
# Precision = 0.346 vs. 0.103
# Recall = 0.583 vs. 0.955
# Minibatch Loss= 0.017299
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.068
# F1 = 0.995 vs. 0.103
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.969 vs. 0.183
# F1 = 0.943 vs. 0.310
# Precision = 0.901 vs. 0.187
# Recall = 0.990 vs. 0.900
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.062
# F1 = 0.617 vs. 0.090
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.113
# F1 = 0.438 vs. 0.187
# Precision = 0.345 vs. 0.110
# Recall = 0.602 vs. 0.625
# Minibatch Loss= 0.015719
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.068
# F1 = 0.992 vs. 0.103
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.171
# F1 = 0.941 vs. 0.292
# Precision = 0.903 vs. 0.172
# Recall = 0.984 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.064
# F1 = 0.617 vs. 0.093
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.353 vs. 0.101
# F1 = 0.438 vs. 0.181
# Precision = 0.350 vs. 0.100
# Recall = 0.586 vs. 0.995
# Minibatch Loss= 0.015856
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.066
# F1 = 0.995 vs. 0.100
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.179
# F1 = 0.944 vs. 0.309
# Precision = 0.908 vs. 0.183
# Recall = 0.983 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.062
# F1 = 0.615 vs. 0.089
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.351 vs. 0.116
# F1 = 0.439 vs. 0.185
# Precision = 0.348 vs. 0.103
# Recall = 0.594 vs. 0.913
# Minibatch Loss= 0.015326
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.997 vs. 0.094
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.975 vs. 0.149
# F1 = 0.938 vs. 0.261
# Precision = 0.903 vs. 0.150
# Recall = 0.975 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.062
# F1 = 0.615 vs. 0.087
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.347 vs. 0.112
# F1 = 0.434 vs. 0.183
# Precision = 0.343 vs. 0.102
# Recall = 0.591 vs. 0.873
# Minibatch Loss= 0.012611
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.069
# F1 = 0.995 vs. 0.106
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.206
# F1 = 0.959 vs. 0.335
# Precision = 0.944 vs. 0.202
# Recall = 0.974 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.582 vs. 0.061
# F1 = 0.612 vs. 0.085
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.351 vs. 0.103
# F1 = 0.436 vs. 0.181
# Precision = 0.342 vs. 0.101
# Recall = 0.602 vs. 0.897
# Minibatch Loss= 0.013016
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.994 vs. 0.104
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.164
# F1 = 0.942 vs. 0.278
# Precision = 0.919 vs. 0.169
# Recall = 0.967 vs. 0.784
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.064
# F1 = 0.615 vs. 0.093
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.348 vs. 0.102
# F1 = 0.434 vs. 0.186
# Precision = 0.338 vs. 0.103
# Recall = 0.607 vs. 0.979
# Minibatch Loss= 0.014090
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.995 vs. 0.104
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.978 vs. 0.163
# F1 = 0.949 vs. 0.295
# Precision = 0.932 vs. 0.173
# Recall = 0.966 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.063
# F1 = 0.613 vs. 0.091
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.354 vs. 0.102
# F1 = 0.440 vs. 0.181
# Precision = 0.357 vs. 0.100
# Recall = 0.573 vs. 1.000
# Minibatch Loss= 0.014566
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.069
# F1 = 0.994 vs. 0.107
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.182
# F1 = 0.961 vs. 0.316
# Precision = 0.958 vs. 0.188
# Recall = 0.963 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.062
# F1 = 0.611 vs. 0.086
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.347 vs. 0.094
# F1 = 0.429 vs. 0.182
# Precision = 0.332 vs. 0.100
# Recall = 0.604 vs. 1.000
# Minibatch Loss= 0.014607
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.066
# F1 = 0.995 vs. 0.096
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.976 vs. 0.140
# F1 = 0.947 vs. 0.259
# Precision = 0.914 vs. 0.149
# Recall = 0.983 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.064
# F1 = 0.611 vs. 0.089
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.348 vs. 0.094
# F1 = 0.436 vs. 0.181
# Precision = 0.352 vs. 0.100
# Recall = 0.575 vs. 1.000
# Minibatch Loss= 0.012317
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.068
# F1 = 0.996 vs. 0.103
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.179
# F1 = 0.951 vs. 0.304
# Precision = 0.920 vs. 0.181
# Recall = 0.984 vs. 0.953
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.062
# F1 = 0.611 vs. 0.085
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.348 vs. 0.109
# F1 = 0.431 vs. 0.181
# Precision = 0.345 vs. 0.100
# Recall = 0.575 vs. 1.000
# Minibatch Loss= 0.014345
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.067
# F1 = 0.995 vs. 0.102
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.156
# F1 = 0.966 vs. 0.296
# Precision = 0.948 vs. 0.174
# Recall = 0.986 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.578 vs. 0.063
# F1 = 0.607 vs. 0.086
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.104
# F1 = 0.430 vs. 0.184
# Precision = 0.346 vs. 0.102
# Recall = 0.570 vs. 0.939
# Minibatch Loss= 0.012228
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.066
# F1 = 0.997 vs. 0.100
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.165
# F1 = 0.951 vs. 0.289
# Precision = 0.951 vs. 0.169
# Recall = 0.951 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.063
# F1 = 0.608 vs. 0.088
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.097
# F1 = 0.428 vs. 0.190
# Precision = 0.345 vs. 0.106
# Recall = 0.565 vs. 0.918
# Minibatch Loss= 0.012273
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.067
# F1 = 0.995 vs. 0.102
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.981 vs. 0.192
# F1 = 0.950 vs. 0.314
# Precision = 0.930 vs. 0.187
# Recall = 0.971 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.063
# F1 = 0.612 vs. 0.088
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.348 vs. 0.101
# F1 = 0.434 vs. 0.183
# Precision = 0.344 vs. 0.101
# Recall = 0.588 vs. 0.950
# Minibatch Loss= 0.014281
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.995 vs. 0.106
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.192
# F1 = 0.957 vs. 0.314
# Precision = 0.944 vs. 0.187
# Recall = 0.970 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.577 vs. 0.063
# F1 = 0.611 vs. 0.086
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.115
# F1 = 0.428 vs. 0.188
# Precision = 0.336 vs. 0.110
# Recall = 0.591 vs. 0.631
# Minibatch Loss= 0.013019
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.067
# F1 = 0.996 vs. 0.097
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.978 vs. 0.163
# F1 = 0.949 vs. 0.291
# Precision = 0.915 vs. 0.170
# Recall = 0.985 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.061
# F1 = 0.609 vs. 0.083
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.349 vs. 0.107
# F1 = 0.433 vs. 0.181
# Precision = 0.347 vs. 0.100
# Recall = 0.578 vs. 0.997
# Minibatch Loss= 0.013072
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.996 vs. 0.102
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.177
# F1 = 0.966 vs. 0.303
# Precision = 0.941 vs. 0.180
# Recall = 0.993 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.577 vs. 0.062
# F1 = 0.607 vs. 0.088
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.340 vs. 0.096
# F1 = 0.426 vs. 0.185
# Precision = 0.334 vs. 0.103
# Recall = 0.588 vs. 0.873
# Minibatch Loss= 0.011618
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.996 vs. 0.106
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.171
# F1 = 0.964 vs. 0.310
# Precision = 0.940 vs. 0.183
# Recall = 0.990 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.063
# F1 = 0.609 vs. 0.089
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.338 vs. 0.101
# F1 = 0.418 vs. 0.186
# Precision = 0.356 vs. 0.104
# Recall = 0.507 vs. 0.887
# Minibatch Loss= 0.010779
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.997 vs. 0.097
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.987 vs. 0.185
# F1 = 0.971 vs. 0.303
# Precision = 0.964 vs. 0.180
# Recall = 0.979 vs. 0.968
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.062
# F1 = 0.609 vs. 0.087
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.345 vs. 0.108
# F1 = 0.428 vs. 0.184
# Precision = 0.340 vs. 0.110
# Recall = 0.578 vs. 0.578
# Minibatch Loss= 0.009940
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.064
# F1 = 0.997 vs. 0.094
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.158
# F1 = 0.960 vs. 0.268
# Precision = 0.931 vs. 0.155
# Recall = 0.991 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.061
# F1 = 0.608 vs. 0.086
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.106
# F1 = 0.426 vs. 0.184
# Precision = 0.340 vs. 0.103
# Recall = 0.573 vs. 0.871
# Minibatch Loss= 0.010456
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.997 vs. 0.101
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.146
# F1 = 0.962 vs. 0.268
# Precision = 0.938 vs. 0.155
# Recall = 0.988 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.062
# F1 = 0.608 vs. 0.086
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.343 vs. 0.102
# F1 = 0.423 vs. 0.181
# Precision = 0.334 vs. 0.100
# Recall = 0.578 vs. 1.000
# Minibatch Loss= 0.010136
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.996 vs. 0.103
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.178
# F1 = 0.961 vs. 0.305
# Precision = 0.949 vs. 0.180
# Recall = 0.974 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.062
# F1 = 0.603 vs. 0.087
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.351 vs. 0.102
# F1 = 0.428 vs. 0.182
# Precision = 0.338 vs. 0.100
# Recall = 0.583 vs. 0.992
# Minibatch Loss= 0.024801
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.067
# F1 = 0.984 vs. 0.100
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.184
# F1 = 0.908 vs. 0.289
# Precision = 0.867 vs. 0.170
# Recall = 0.953 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.582 vs. 0.061
# F1 = 0.608 vs. 0.084
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.339 vs. 0.103
# F1 = 0.426 vs. 0.181
# Precision = 0.350 vs. 0.103
# Recall = 0.546 vs. 0.778
# Minibatch Loss= 0.022346
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.069
# F1 = 0.994 vs. 0.103
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.188
# F1 = 0.949 vs. 0.336
# Precision = 0.934 vs. 0.202
# Recall = 0.964 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.062
# F1 = 0.615 vs. 0.092
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.103
# F1 = 0.432 vs. 0.181
# Precision = 0.343 vs. 0.100
# Recall = 0.586 vs. 1.000
# Minibatch Loss= 0.016752
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.067
# F1 = 0.995 vs. 0.101
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.157
# F1 = 0.967 vs. 0.280
# Precision = 0.958 vs. 0.163
# Recall = 0.975 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.063
# F1 = 0.613 vs. 0.095
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.347 vs. 0.102
# F1 = 0.430 vs. 0.181
# Precision = 0.339 vs. 0.100
# Recall = 0.588 vs. 1.000
# Minibatch Loss= 0.011975
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.068
# F1 = 0.996 vs. 0.103
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.165
# F1 = 0.959 vs. 0.287
# Precision = 0.954 vs. 0.168
# Recall = 0.964 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.061
# F1 = 0.613 vs. 0.084
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.348 vs. 0.103
# F1 = 0.429 vs. 0.183
# Precision = 0.331 vs. 0.101
# Recall = 0.607 vs. 0.942
# Minibatch Loss= 0.013586
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.067
# F1 = 0.996 vs. 0.099
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.176
# F1 = 0.964 vs. 0.301
# Precision = 0.939 vs. 0.177
# Recall = 0.990 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.063
# F1 = 0.613 vs. 0.092
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.094
# F1 = 0.427 vs. 0.181
# Precision = 0.367 vs. 0.100
# Recall = 0.509 vs. 1.000
# Minibatch Loss= 0.012622
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.069
# F1 = 0.996 vs. 0.103
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.992 vs. 0.188
# F1 = 0.973 vs. 0.296
# Precision = 0.959 vs. 0.176
# Recall = 0.987 vs. 0.938
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.062
# F1 = 0.611 vs. 0.086
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.358 vs. 0.111
# Recall = 0.491 vs. 0.570
# Minibatch Loss= 0.004754
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.068
# F1 = 0.998 vs. 0.099
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.168
# F1 = 0.991 vs. 0.292
# Precision = 0.982 vs. 0.171
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.062
# F1 = 0.589 vs. 0.089
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.314 vs. 0.099
# F1 = 0.420 vs. 0.182
# Precision = 0.369 vs. 0.100
# Recall = 0.488 vs. 0.997
# Minibatch Loss= 0.005695
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.070
# F1 = 0.997 vs. 0.107
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.181
# F1 = 0.998 vs. 0.306
# Precision = 0.997 vs. 0.181
# Recall = 1.000 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.064
# F1 = 0.588 vs. 0.092
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.098
# F1 = 0.415 vs. 0.182
# Precision = 0.362 vs. 0.100
# Recall = 0.485 vs. 0.992
# Minibatch Loss= 0.005331
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.103
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.191
# F1 = 0.993 vs. 0.318
# Precision = 0.987 vs. 0.190
# Recall = 0.998 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.061
# F1 = 0.587 vs. 0.088
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.102
# F1 = 0.417 vs. 0.183
# Precision = 0.362 vs. 0.106
# Recall = 0.491 vs. 0.678
# Minibatch Loss= 0.006099
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.931 vs. 0.070
# F1 = 0.911 vs. 0.103
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.854 vs. 0.159
# F1 = 0.812 vs. 0.276
# Precision = 0.761 vs. 0.160
# Recall = 0.870 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.508 vs. 0.062
# F1 = 0.572 vs. 0.086
# Accuracy = 0.799 vs. 0.056
# CHANGE DETECTION
# AUC = 0.291 vs. 0.099
# F1 = 0.383 vs. 0.182
# Precision = 0.316 vs. 0.100
# Recall = 0.488 vs. 0.997
# Minibatch Loss= 0.116880
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.104
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.181
# F1 = 0.980 vs. 0.301
# Precision = 0.967 vs. 0.181
# Recall = 0.995 vs. 0.892
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.064
# F1 = 0.592 vs. 0.094
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.103
# F1 = 0.402 vs. 0.181
# Precision = 0.343 vs. 0.100
# Recall = 0.485 vs. 1.000
# Minibatch Loss= 0.008227
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.997 vs. 0.101
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.167
# F1 = 0.989 vs. 0.285
# Precision = 0.978 vs. 0.166
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.063
# F1 = 0.594 vs. 0.087
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.102
# F1 = 0.406 vs. 0.182
# Precision = 0.354 vs. 0.100
# Recall = 0.478 vs. 0.989
# Minibatch Loss= 0.007482
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.998 vs. 0.097
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.151
# F1 = 0.990 vs. 0.262
# Precision = 0.980 vs. 0.151
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.064
# F1 = 0.595 vs. 0.091
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.101
# F1 = 0.413 vs. 0.181
# Precision = 0.363 vs. 0.100
# Recall = 0.480 vs. 1.000
# Minibatch Loss= 0.005890
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.104
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.169
# F1 = 0.998 vs. 0.285
# Precision = 0.996 vs. 0.166
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.062
# F1 = 0.594 vs. 0.091
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.092
# F1 = 0.410 vs. 0.181
# Precision = 0.349 vs. 0.100
# Recall = 0.496 vs. 1.000
# Minibatch Loss= 0.004879
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 0.998 vs. 0.105
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.179
# F1 = 0.996 vs. 0.298
# Precision = 0.993 vs. 0.176
# Recall = 0.998 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.061
# F1 = 0.592 vs. 0.087
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.315 vs. 0.096
# F1 = 0.413 vs. 0.182
# Precision = 0.348 vs. 0.100
# Recall = 0.507 vs. 0.997
# Minibatch Loss= 0.005405
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 0.998 vs. 0.103
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.181
# F1 = 0.996 vs. 0.297
# Precision = 0.993 vs. 0.174
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.063
# F1 = 0.591 vs. 0.088
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.104
# F1 = 0.414 vs. 0.181
# Precision = 0.353 vs. 0.100
# Recall = 0.501 vs. 1.000
# Minibatch Loss= 0.005653
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 0.998 vs. 0.097
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.167
# F1 = 0.997 vs. 0.284
# Precision = 0.994 vs. 0.165
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.064
# F1 = 0.590 vs. 0.092
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.108
# F1 = 0.413 vs. 0.183
# Precision = 0.355 vs. 0.101
# Recall = 0.493 vs. 0.997
# Minibatch Loss= 0.005474
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.101
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.166
# F1 = 0.998 vs. 0.288
# Precision = 0.996 vs. 0.169
# Recall = 1.000 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.062
# F1 = 0.590 vs. 0.084
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.315 vs. 0.099
# F1 = 0.411 vs. 0.181
# Precision = 0.357 vs. 0.105
# Recall = 0.483 vs. 0.670
# Minibatch Loss= 0.004679
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 0.998 vs. 0.105
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.184
# F1 = 0.995 vs. 0.318
# Precision = 0.991 vs. 0.189
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.554 vs. 0.062
# F1 = 0.590 vs. 0.087
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.114
# F1 = 0.411 vs. 0.186
# Precision = 0.362 vs. 0.111
# Recall = 0.475 vs. 0.583
# Minibatch Loss= 0.004937
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.103
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.181
# F1 = 0.997 vs. 0.303
# Precision = 0.995 vs. 0.179
# Recall = 1.000 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.062
# F1 = 0.590 vs. 0.084
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.096
# F1 = 0.411 vs. 0.182
# Precision = 0.362 vs. 0.101
# Recall = 0.475 vs. 0.900
# Minibatch Loss= 0.005226
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 0.998 vs. 0.105
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.191
# F1 = 0.992 vs. 0.303
# Precision = 0.990 vs. 0.179
# Recall = 0.995 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.061
# F1 = 0.588 vs. 0.083
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.098
# F1 = 0.412 vs. 0.181
# Precision = 0.363 vs. 0.100
# Recall = 0.478 vs. 1.000
# Minibatch Loss= 0.005792
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.067
# F1 = 0.997 vs. 0.104
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.188
# F1 = 0.998 vs. 0.313
# Precision = 0.998 vs. 0.186
# Recall = 0.998 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.062
# F1 = 0.588 vs. 0.088
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.106
# F1 = 0.410 vs. 0.182
# Precision = 0.358 vs. 0.100
# Recall = 0.480 vs. 0.963
# Minibatch Loss= 0.005510
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.069
# F1 = 0.998 vs. 0.104
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.193
# F1 = 0.999 vs. 0.316
# Precision = 0.998 vs. 0.187
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.064
# F1 = 0.588 vs. 0.095
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.101
# F1 = 0.412 vs. 0.187
# Precision = 0.349 vs. 0.106
# Recall = 0.501 vs. 0.823
# Minibatch Loss= 0.004964
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.099
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.159
# F1 = 0.996 vs. 0.283
# Precision = 0.992 vs. 0.165
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.062
# F1 = 0.588 vs. 0.089
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.111
# F1 = 0.412 vs. 0.189
# Precision = 0.367 vs. 0.109
# Recall = 0.470 vs. 0.728
# Minibatch Loss= 0.004689
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 0.998 vs. 0.108
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.206
# F1 = 0.997 vs. 0.330
# Precision = 0.994 vs. 0.198
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.064
# F1 = 0.589 vs. 0.093
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.107
# F1 = 0.410 vs. 0.183
# Precision = 0.347 vs. 0.102
# Recall = 0.499 vs. 0.900
# Minibatch Loss= 0.004517
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.065
# F1 = 0.997 vs. 0.098
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.159
# F1 = 0.997 vs. 0.285
# Precision = 0.994 vs. 0.166
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.063
# F1 = 0.587 vs. 0.087
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.110
# F1 = 0.412 vs. 0.184
# Precision = 0.351 vs. 0.102
# Recall = 0.499 vs. 0.929
# Minibatch Loss= 0.005254
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.070
# F1 = 0.998 vs. 0.104
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.193
# F1 = 0.998 vs. 0.328
# Precision = 0.997 vs. 0.197
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.061
# F1 = 0.588 vs. 0.089
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.096
# F1 = 0.414 vs. 0.181
# Precision = 0.346 vs. 0.100
# Recall = 0.515 vs. 1.000
# Minibatch Loss= 0.006008
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.069
# F1 = 0.998 vs. 0.106
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.195
# F1 = 0.996 vs. 0.323
# Precision = 0.992 vs. 0.192
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.061
# F1 = 0.588 vs. 0.083
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.097
# F1 = 0.412 vs. 0.182
# Precision = 0.354 vs. 0.100
# Recall = 0.491 vs. 1.000
# Minibatch Loss= 0.005206
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.103
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.177
# F1 = 0.998 vs. 0.293
# Precision = 0.996 vs. 0.172
# Recall = 1.000 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.062
# F1 = 0.589 vs. 0.089
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.303 vs. 0.102
# F1 = 0.411 vs. 0.184
# Precision = 0.345 vs. 0.103
# Recall = 0.507 vs. 0.847
# Minibatch Loss= 0.004952
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.100
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.164
# F1 = 0.999 vs. 0.285
# Precision = 0.998 vs. 0.167
# Recall = 1.000 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.063
# F1 = 0.589 vs. 0.091
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.101
# F1 = 0.411 vs. 0.181
# Precision = 0.351 vs. 0.100
# Recall = 0.496 vs. 1.000
# Minibatch Loss= 0.004273
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.106
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.189
# F1 = 1.000 vs. 0.312
# Precision = 1.000 vs. 0.185
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.062
# F1 = 0.588 vs. 0.089
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.099
# F1 = 0.412 vs. 0.182
# Precision = 0.354 vs. 0.100
# Recall = 0.491 vs. 1.000
# Minibatch Loss= 0.004047
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.997 vs. 0.105
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.186
# F1 = 0.997 vs. 0.292
# Precision = 0.994 vs. 0.171
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.544 vs. 0.061
# F1 = 0.589 vs. 0.083
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.096
# F1 = 0.412 vs. 0.184
# Precision = 0.351 vs. 0.103
# Recall = 0.499 vs. 0.844
# Minibatch Loss= 0.005040
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.106
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.161
# F1 = 0.999 vs. 0.291
# Precision = 0.998 vs. 0.170
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.063
# F1 = 0.589 vs. 0.093
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.103
# F1 = 0.410 vs. 0.185
# Precision = 0.347 vs. 0.103
# Recall = 0.501 vs. 0.905
# Minibatch Loss= 0.004331
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.999 vs. 0.100
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.154
# F1 = 0.996 vs. 0.272
# Precision = 0.992 vs. 0.158
# Recall = 1.000 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.061
# F1 = 0.589 vs. 0.088
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.094
# F1 = 0.413 vs. 0.183
# Precision = 0.358 vs. 0.101
# Recall = 0.488 vs. 0.992
# Minibatch Loss= 0.003920
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.064
# F1 = 0.997 vs. 0.096
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.149
# F1 = 0.999 vs. 0.243
# Precision = 0.998 vs. 0.138
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.062
# F1 = 0.586 vs. 0.087
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.103
# F1 = 0.410 vs. 0.186
# Precision = 0.339 vs. 0.105
# Recall = 0.520 vs. 0.792
# Minibatch Loss= 0.004154
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.102
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.187
# F1 = 0.997 vs. 0.306
# Precision = 0.993 vs. 0.187
# Recall = 1.000 vs. 0.847
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.063
# F1 = 0.588 vs. 0.090
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.305 vs. 0.100
# F1 = 0.415 vs. 0.183
# Precision = 0.359 vs. 0.101
# Recall = 0.491 vs. 0.937
# Minibatch Loss= 0.004643
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.998 vs. 0.100
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.158
# F1 = 0.998 vs. 0.282
# Precision = 0.996 vs. 0.164
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.062
# F1 = 0.589 vs. 0.090
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.098
# F1 = 0.413 vs. 0.183
# Precision = 0.357 vs. 0.101
# Recall = 0.491 vs. 0.987
# Minibatch Loss= 0.003783
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.068
# F1 = 0.998 vs. 0.101
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.176
# F1 = 0.996 vs. 0.308
# Precision = 0.991 vs. 0.182
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.064
# F1 = 0.587 vs. 0.087
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.096
# F1 = 0.414 vs. 0.182
# Precision = 0.355 vs. 0.100
# Recall = 0.496 vs. 0.997
# Minibatch Loss= 0.005174
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.065
# F1 = 0.999 vs. 0.099
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.167
# F1 = 0.997 vs. 0.261
# Precision = 0.994 vs. 0.151
# Recall = 1.000 vs. 0.946
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.062
# F1 = 0.590 vs. 0.088
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.304 vs. 0.105
# F1 = 0.413 vs. 0.181
# Precision = 0.357 vs. 0.100
# Recall = 0.491 vs. 0.992
# Minibatch Loss= 0.003502
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.103
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.162
# F1 = 1.000 vs. 0.278
# Precision = 1.000 vs. 0.163
# Recall = 1.000 vs. 0.944
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.541 vs. 0.063
# F1 = 0.589 vs. 0.092
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.108
# F1 = 0.413 vs. 0.184
# Precision = 0.358 vs. 0.103
# Recall = 0.488 vs. 0.834
# Minibatch Loss= 0.003992
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/CNN_Wmultitask_32_opp/CNN_Wmultitask_32_opp-20000'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN_activity_multitask_64_opp/CNN_activity_multitask_64_opp-20000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/CNN_activity_multitask_64_opp/CNN_activity_multitask_64_opp-20000

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.539 vs. 0.062
# F1 = 0.588 vs. 0.087
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.106
# F1 = 0.413 vs. 0.181
# Precision = 0.359 vs. 0.100
# Recall = 0.488 vs. 1.000

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
