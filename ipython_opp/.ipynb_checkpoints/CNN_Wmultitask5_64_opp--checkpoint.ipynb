# %%
# useing this variable for saving models and summaries
exp_name = "CNN_activity_Wmultitask5_64_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)


variables_weights = np.ones((n_classes,))
variables_weights[-1] = 5

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.16329966,  34.21019108,  34.43589744,  37.12413793,
#         36.10067114,  26.70927318,  27.27621483,  39.94814815,
#         42.01945525,  46.65517241,  51.89952153,  48.57847534,
#         51.1509434 ,  43.40160643,  44.68595041,  33.7672956 ,
#         10.65015806,  36.60544218,   2.20649652])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,
                     variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.081 vs. 0.079
# F1 = 0.131 vs. 0.117
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.315
# F1 = 0.569 vs. 0.477
# Precision = 0.407 vs. 0.313
# Recall = 0.946 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.070
# F1 = 0.101 vs. 0.102
# Accuracy = 0.003 vs. 0.056
# CHANGE DETECTION
# AUC = 0.237 vs. 0.196
# F1 = 0.432 vs. 0.312
# Precision = 0.283 vs. 0.185
# Recall = 0.912 vs. 1.000
# Minibatch Loss= 1.320136
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.083
# F1 = 0.582 vs. 0.128
# Accuracy = 0.698 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.295
# F1 = 0.694 vs. 0.445
# Precision = 0.633 vs. 0.287
# Recall = 0.767 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.380 vs. 0.068
# F1 = 0.451 vs. 0.095
# Accuracy = 0.693 vs. 0.056
# CHANGE DETECTION
# AUC = 0.653 vs. 0.170
# F1 = 0.624 vs. 0.312
# Precision = 0.629 vs. 0.185
# Recall = 0.618 vs. 0.994
# Minibatch Loss= 0.411946
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.711 vs. 0.084
# F1 = 0.698 vs. 0.126
# Accuracy = 0.687 vs. 0.056
# CHANGE DETECTION
# AUC = 0.853 vs. 0.374
# F1 = 0.812 vs. 0.525
# Precision = 0.747 vs. 0.356
# Recall = 0.889 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.471 vs. 0.073
# F1 = 0.536 vs. 0.112
# Accuracy = 0.693 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.200
# F1 = 0.645 vs. 0.314
# Precision = 0.561 vs. 0.187
# Recall = 0.758 vs. 0.991
# Minibatch Loss= 0.341534
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.781 vs. 0.078
# F1 = 0.764 vs. 0.121
# Accuracy = 0.826 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.324
# F1 = 0.850 vs. 0.461
# Precision = 0.765 vs. 0.300
# Recall = 0.956 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.492 vs. 0.071
# F1 = 0.554 vs. 0.102
# Accuracy = 0.801 vs. 0.056
# CHANGE DETECTION
# AUC = 0.686 vs. 0.194
# F1 = 0.673 vs. 0.311
# Precision = 0.608 vs. 0.184
# Recall = 0.755 vs. 1.000
# Minibatch Loss= 0.209977
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.820 vs. 0.084
# F1 = 0.800 vs. 0.132
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.930 vs. 0.353
# F1 = 0.880 vs. 0.529
# Precision = 0.838 vs. 0.360
# Recall = 0.925 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.071
# F1 = 0.568 vs. 0.114
# Accuracy = 0.838 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.197
# F1 = 0.688 vs. 0.317
# Precision = 0.637 vs. 0.188
# Recall = 0.749 vs. 0.991
# Minibatch Loss= 0.204099
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.859 vs. 0.077
# F1 = 0.830 vs. 0.114
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.945 vs. 0.296
# F1 = 0.887 vs. 0.463
# Precision = 0.852 vs. 0.301
# Recall = 0.925 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.544 vs. 0.070
# F1 = 0.592 vs. 0.103
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.708 vs. 0.194
# F1 = 0.680 vs. 0.313
# Precision = 0.595 vs. 0.187
# Recall = 0.795 vs. 0.960
# Minibatch Loss= 0.155320
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.871 vs. 0.085
# F1 = 0.848 vs. 0.123
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.952 vs. 0.337
# F1 = 0.903 vs. 0.496
# Precision = 0.902 vs. 0.331
# Recall = 0.905 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.554 vs. 0.068
# F1 = 0.596 vs. 0.097
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.180
# F1 = 0.678 vs. 0.315
# Precision = 0.636 vs. 0.188
# Recall = 0.726 vs. 0.963
# Minibatch Loss= 0.154731
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.886 vs. 0.079
# F1 = 0.872 vs. 0.118
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.314
# F1 = 0.905 vs. 0.501
# Precision = 0.893 vs. 0.334
# Recall = 0.918 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.068
# F1 = 0.603 vs. 0.099
# Accuracy = 0.840 vs. 0.056
# CHANGE DETECTION
# AUC = 0.722 vs. 0.168
# F1 = 0.691 vs. 0.313
# Precision = 0.612 vs. 0.185
# Recall = 0.792 vs. 1.000
# Minibatch Loss= 0.134715
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.893 vs. 0.081
# F1 = 0.873 vs. 0.122
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.308
# F1 = 0.935 vs. 0.475
# Precision = 0.925 vs. 0.311
# Recall = 0.946 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.564 vs. 0.069
# F1 = 0.604 vs. 0.096
# Accuracy = 0.860 vs. 0.056
# CHANGE DETECTION
# AUC = 0.721 vs. 0.170
# F1 = 0.692 vs. 0.312
# Precision = 0.614 vs. 0.185
# Recall = 0.792 vs. 0.997
# Minibatch Loss= 0.109146
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.940 vs. 0.083
# F1 = 0.914 vs. 0.127
# Accuracy = 0.932 vs. 0.056
# CHANGE DETECTION
# AUC = 0.975 vs. 0.349
# F1 = 0.944 vs. 0.500
# Precision = 0.918 vs. 0.334
# Recall = 0.972 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.067
# F1 = 0.608 vs. 0.096
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.706 vs. 0.182
# F1 = 0.685 vs. 0.318
# Precision = 0.635 vs. 0.190
# Recall = 0.744 vs. 0.972
# Minibatch Loss= 0.095581
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.912 vs. 0.080
# F1 = 0.896 vs. 0.117
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.979 vs. 0.289
# F1 = 0.948 vs. 0.457
# Precision = 0.932 vs. 0.297
# Recall = 0.965 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.071
# F1 = 0.605 vs. 0.102
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.723 vs. 0.179
# F1 = 0.703 vs. 0.316
# Precision = 0.618 vs. 0.188
# Recall = 0.815 vs. 0.986
# Minibatch Loss= 0.088820
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.921 vs. 0.077
# F1 = 0.906 vs. 0.120
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.294
# F1 = 0.952 vs. 0.454
# Precision = 0.953 vs. 0.294
# Recall = 0.951 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.070
# F1 = 0.608 vs. 0.105
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.721 vs. 0.196
# F1 = 0.692 vs. 0.312
# Precision = 0.636 vs. 0.185
# Recall = 0.758 vs. 0.997
# Minibatch Loss= 0.081714
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.946 vs. 0.078
# F1 = 0.933 vs. 0.113
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.335
# F1 = 0.966 vs. 0.484
# Precision = 0.963 vs. 0.319
# Recall = 0.969 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.075
# F1 = 0.608 vs. 0.107
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.720 vs. 0.198
# F1 = 0.697 vs. 0.315
# Precision = 0.618 vs. 0.189
# Recall = 0.798 vs. 0.946
# Minibatch Loss= 0.081615
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.936 vs. 0.082
# F1 = 0.924 vs. 0.127
# Accuracy = 0.946 vs. 0.056
# CHANGE DETECTION
# AUC = 0.994 vs. 0.290
# F1 = 0.972 vs. 0.462
# Precision = 0.959 vs. 0.301
# Recall = 0.985 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.074
# F1 = 0.605 vs. 0.108
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.709 vs. 0.204
# F1 = 0.678 vs. 0.316
# Precision = 0.609 vs. 0.191
# Recall = 0.766 vs. 0.912
# Minibatch Loss= 0.067297
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.928 vs. 0.077
# F1 = 0.926 vs. 0.117
# Accuracy = 0.952 vs. 0.056
# CHANGE DETECTION
# AUC = 0.994 vs. 0.282
# F1 = 0.977 vs. 0.438
# Precision = 0.978 vs. 0.280
# Recall = 0.975 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.068
# F1 = 0.611 vs. 0.102
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.705 vs. 0.191
# F1 = 0.674 vs. 0.312
# Precision = 0.595 vs. 0.186
# Recall = 0.778 vs. 0.983
# Minibatch Loss= 0.056227
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.948 vs. 0.079
# F1 = 0.944 vs. 0.121
# Accuracy = 0.939 vs. 0.056
# CHANGE DETECTION
# AUC = 0.996 vs. 0.328
# F1 = 0.980 vs. 0.494
# Precision = 0.986 vs. 0.328
# Recall = 0.973 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.582 vs. 0.071
# F1 = 0.614 vs. 0.110
# Accuracy = 0.870 vs. 0.056
# CHANGE DETECTION
# AUC = 0.711 vs. 0.198
# F1 = 0.678 vs. 0.317
# Precision = 0.607 vs. 0.194
# Recall = 0.766 vs. 0.872
# Minibatch Loss= 0.051798
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.956 vs. 0.078
# F1 = 0.953 vs. 0.117
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.310
# F1 = 0.981 vs. 0.492
# Precision = 0.970 vs. 0.327
# Recall = 0.992 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.072
# F1 = 0.613 vs. 0.103
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.700 vs. 0.197
# F1 = 0.672 vs. 0.314
# Precision = 0.607 vs. 0.191
# Recall = 0.752 vs. 0.880
# Minibatch Loss= 0.053643
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.966 vs. 0.084
# F1 = 0.959 vs. 0.129
# Accuracy = 0.949 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.343
# F1 = 0.983 vs. 0.500
# Precision = 0.978 vs. 0.334
# Recall = 0.988 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.069
# F1 = 0.621 vs. 0.103
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.704 vs. 0.200
# F1 = 0.671 vs. 0.316
# Precision = 0.628 vs. 0.195
# Recall = 0.721 vs. 0.835
# Minibatch Loss= 0.051414
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.077
# F1 = 0.967 vs. 0.118
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.344
# F1 = 0.989 vs. 0.506
# Precision = 0.987 vs. 0.339
# Recall = 0.991 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.068
# F1 = 0.618 vs. 0.099
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.706 vs. 0.179
# F1 = 0.673 vs. 0.313
# Precision = 0.605 vs. 0.186
# Recall = 0.758 vs. 0.994
# Minibatch Loss= 0.042732
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.078
# F1 = 0.972 vs. 0.117
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.290
# F1 = 0.988 vs. 0.460
# Precision = 0.985 vs. 0.300
# Recall = 0.992 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.069
# F1 = 0.616 vs. 0.096
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.706 vs. 0.194
# F1 = 0.665 vs. 0.317
# Precision = 0.623 vs. 0.191
# Recall = 0.712 vs. 0.934
# Minibatch Loss= 0.033677
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.074
# F1 = 0.972 vs. 0.110
# Accuracy = 0.965 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.286
# F1 = 0.989 vs. 0.435
# Precision = 0.993 vs. 0.279
# Recall = 0.984 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.069
# F1 = 0.616 vs. 0.101
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.701 vs. 0.178
# F1 = 0.666 vs. 0.312
# Precision = 0.621 vs. 0.185
# Recall = 0.718 vs. 0.997
# Minibatch Loss= 0.035219
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.971 vs. 0.083
# F1 = 0.968 vs. 0.123
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.376
# F1 = 0.996 vs. 0.541
# Precision = 0.997 vs. 0.378
# Recall = 0.995 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.071
# F1 = 0.618 vs. 0.105
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.701 vs. 0.189
# F1 = 0.667 vs. 0.316
# Precision = 0.608 vs. 0.189
# Recall = 0.738 vs. 0.972
# Minibatch Loss= 0.037155
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.082
# F1 = 0.979 vs. 0.129
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.330
# F1 = 0.996 vs. 0.496
# Precision = 0.994 vs. 0.329
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.069
# F1 = 0.622 vs. 0.103
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.697 vs. 0.196
# F1 = 0.654 vs. 0.314
# Precision = 0.618 vs. 0.192
# Recall = 0.695 vs. 0.852
# Minibatch Loss= 0.026861
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.076
# F1 = 0.979 vs. 0.119
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.301
# F1 = 0.995 vs. 0.453
# Precision = 0.991 vs. 0.293
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.073
# F1 = 0.618 vs. 0.110
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.697 vs. 0.177
# F1 = 0.655 vs. 0.314
# Precision = 0.605 vs. 0.187
# Recall = 0.715 vs. 0.969
# Minibatch Loss= 0.025458
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.079
# F1 = 0.974 vs. 0.120
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.311
# F1 = 0.994 vs. 0.470
# Precision = 0.998 vs. 0.307
# Recall = 0.991 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.069
# F1 = 0.616 vs. 0.094
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.700 vs. 0.189
# F1 = 0.652 vs. 0.314
# Precision = 0.585 vs. 0.194
# Recall = 0.738 vs. 0.821
# Minibatch Loss= 0.027622
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.082
# F1 = 0.982 vs. 0.125
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.345
# F1 = 0.998 vs. 0.503
# Precision = 1.000 vs. 0.336
# Recall = 0.996 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.069
# F1 = 0.616 vs. 0.104
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.690 vs. 0.188
# F1 = 0.643 vs. 0.316
# Precision = 0.568 vs. 0.189
# Recall = 0.741 vs. 0.980
# Minibatch Loss= 0.024853
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.078
# F1 = 0.983 vs. 0.114
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.299
# F1 = 0.998 vs. 0.469
# Precision = 0.998 vs. 0.307
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.069
# F1 = 0.615 vs. 0.098
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.189
# F1 = 0.630 vs. 0.314
# Precision = 0.588 vs. 0.188
# Recall = 0.678 vs. 0.963
# Minibatch Loss= 0.020327
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.082
# F1 = 0.989 vs. 0.127
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.341
# F1 = 1.000 vs. 0.493
# Precision = 1.000 vs. 0.327
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.067
# F1 = 0.617 vs. 0.095
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.689 vs. 0.204
# F1 = 0.634 vs. 0.319
# Precision = 0.562 vs. 0.194
# Recall = 0.726 vs. 0.883
# Minibatch Loss= 0.016781
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.080
# F1 = 0.987 vs. 0.120
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.317
# F1 = 1.000 vs. 0.483
# Precision = 1.000 vs. 0.318
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.069
# F1 = 0.616 vs. 0.104
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.688 vs. 0.182
# F1 = 0.639 vs. 0.316
# Precision = 0.574 vs. 0.191
# Recall = 0.721 vs. 0.917
# Minibatch Loss= 0.016257
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.076
# F1 = 0.990 vs. 0.118
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 1.000 vs. 0.473
# Precision = 1.000 vs. 0.310
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.577 vs. 0.069
# F1 = 0.613 vs. 0.100
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.679 vs. 0.184
# F1 = 0.622 vs. 0.312
# Precision = 0.564 vs. 0.185
# Recall = 0.695 vs. 0.989
# Minibatch Loss= 0.016455
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.079
# F1 = 0.989 vs. 0.121
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.355
# F1 = 1.000 vs. 0.503
# Precision = 1.000 vs. 0.337
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.070
# F1 = 0.615 vs. 0.102
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.222
# F1 = 0.629 vs. 0.313
# Precision = 0.659 vs. 0.187
# Recall = 0.601 vs. 0.957
# Minibatch Loss= 0.015086
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.080
# F1 = 0.961 vs. 0.124
# Accuracy = 0.970 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.326
# F1 = 0.979 vs. 0.474
# Precision = 0.970 vs. 0.311
# Recall = 0.989 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.073
# F1 = 0.601 vs. 0.112
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.700 vs. 0.179
# F1 = 0.675 vs. 0.312
# Precision = 0.585 vs. 0.185
# Recall = 0.798 vs. 1.000
# Minibatch Loss= 0.043523
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.077
# F1 = 0.988 vs. 0.123
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.323
# F1 = 0.998 vs. 0.477
# Precision = 1.000 vs. 0.313
# Recall = 0.996 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.577 vs. 0.072
# F1 = 0.606 vs. 0.116
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.689 vs. 0.175
# F1 = 0.659 vs. 0.314
# Precision = 0.585 vs. 0.187
# Recall = 0.755 vs. 0.977
# Minibatch Loss= 0.020886
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.082
# F1 = 0.990 vs. 0.120
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.282
# F1 = 1.000 vs. 0.446
# Precision = 1.000 vs. 0.287
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.069
# F1 = 0.605 vs. 0.106
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.688 vs. 0.212
# F1 = 0.655 vs. 0.312
# Precision = 0.624 vs. 0.185
# Recall = 0.689 vs. 1.000
# Minibatch Loss= 0.015754
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.081
# F1 = 0.985 vs. 0.125
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.360
# F1 = 0.999 vs. 0.517
# Precision = 1.000 vs. 0.349
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.070
# F1 = 0.605 vs. 0.104
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.682 vs. 0.199
# F1 = 0.649 vs. 0.317
# Precision = 0.621 vs. 0.189
# Recall = 0.681 vs. 0.966
# Minibatch Loss= 0.017948
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.079
# F1 = 0.990 vs. 0.118
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.317
# F1 = 1.000 vs. 0.489
# Precision = 1.000 vs. 0.324
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.071
# F1 = 0.607 vs. 0.109
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.687 vs. 0.183
# F1 = 0.642 vs. 0.316
# Precision = 0.607 vs. 0.190
# Recall = 0.681 vs. 0.937
# Minibatch Loss= 0.014265
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.077
# F1 = 0.989 vs. 0.116
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.339
# F1 = 1.000 vs. 0.491
# Precision = 1.000 vs. 0.329
# Recall = 1.000 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.069
# F1 = 0.604 vs. 0.102
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.689 vs. 0.168
# F1 = 0.640 vs. 0.312
# Precision = 0.589 vs. 0.186
# Recall = 0.701 vs. 0.974
# Minibatch Loss= 0.014335
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.079
# F1 = 0.993 vs. 0.117
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 1.000 vs. 0.488
# Precision = 1.000 vs. 0.323
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.069
# F1 = 0.602 vs. 0.101
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.679 vs. 0.184
# F1 = 0.631 vs. 0.312
# Precision = 0.608 vs. 0.185
# Recall = 0.655 vs. 1.000
# Minibatch Loss= 0.013954
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.080
# F1 = 0.990 vs. 0.118
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.337
# F1 = 1.000 vs. 0.505
# Precision = 1.000 vs. 0.342
# Recall = 1.000 vs. 0.961
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.073
# F1 = 0.604 vs. 0.107
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.687 vs. 0.197
# F1 = 0.635 vs. 0.316
# Precision = 0.577 vs. 0.189
# Recall = 0.707 vs. 0.954
# Minibatch Loss= 0.012547
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.076
# F1 = 0.992 vs. 0.111
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.280
# F1 = 1.000 vs. 0.455
# Precision = 1.000 vs. 0.295
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.069
# F1 = 0.607 vs. 0.101
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.686 vs. 0.191
# F1 = 0.638 vs. 0.313
# Precision = 0.568 vs. 0.186
# Recall = 0.726 vs. 0.991
# Minibatch Loss= 0.011115
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.077
# F1 = 0.991 vs. 0.118
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.306
# F1 = 1.000 vs. 0.464
# Precision = 1.000 vs. 0.303
# Recall = 1.000 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.069
# F1 = 0.609 vs. 0.099
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.683 vs. 0.186
# F1 = 0.635 vs. 0.316
# Precision = 0.563 vs. 0.190
# Recall = 0.729 vs. 0.934
# Minibatch Loss= 0.011459
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.077
# F1 = 0.995 vs. 0.116
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.292
# F1 = 1.000 vs. 0.446
# Precision = 1.000 vs. 0.289
# Recall = 1.000 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.071
# F1 = 0.609 vs. 0.103
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.681 vs. 0.194
# F1 = 0.636 vs. 0.313
# Precision = 0.564 vs. 0.187
# Recall = 0.729 vs. 0.963
# Minibatch Loss= 0.009633
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.077
# F1 = 0.993 vs. 0.116
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.283
# F1 = 1.000 vs. 0.440
# Precision = 1.000 vs. 0.283
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.071
# F1 = 0.605 vs. 0.110
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.682 vs. 0.198
# F1 = 0.631 vs. 0.312
# Precision = 0.558 vs. 0.185
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.011510
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.112
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.256
# F1 = 1.000 vs. 0.393
# Precision = 1.000 vs. 0.246
# Recall = 1.000 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.068
# F1 = 0.606 vs. 0.098
# Accuracy = 0.901 vs. 0.056
# CHANGE DETECTION
# AUC = 0.686 vs. 0.191
# F1 = 0.638 vs. 0.313
# Precision = 0.568 vs. 0.186
# Recall = 0.729 vs. 0.983
# Minibatch Loss= 0.008550
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.080
# F1 = 0.994 vs. 0.124
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.333
# F1 = 1.000 vs. 0.498
# Precision = 1.000 vs. 0.333
# Recall = 1.000 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.069
# F1 = 0.604 vs. 0.098
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.688 vs. 0.195
# F1 = 0.640 vs. 0.311
# Precision = 0.569 vs. 0.184
# Recall = 0.732 vs. 1.000
# Minibatch Loss= 0.011110
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.081
# F1 = 0.989 vs. 0.127
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.311
# F1 = 1.000 vs. 0.456
# Precision = 1.000 vs. 0.296
# Recall = 1.000 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.575 vs. 0.067
# F1 = 0.605 vs. 0.101
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.680 vs. 0.181
# F1 = 0.631 vs. 0.311
# Precision = 0.559 vs. 0.185
# Recall = 0.724 vs. 0.991
# Minibatch Loss= 0.010733
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.076
# F1 = 0.993 vs. 0.113
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.257
# F1 = 1.000 vs. 0.411
# Precision = 1.000 vs. 0.258
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.072
# F1 = 0.607 vs. 0.102
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.680 vs. 0.186
# F1 = 0.642 vs. 0.312
# Precision = 0.573 vs. 0.185
# Recall = 0.729 vs. 1.000
# Minibatch Loss= 0.007810
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.081
# F1 = 0.995 vs. 0.123
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 1.000 vs. 0.486
# Precision = 1.000 vs. 0.321
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.068
# F1 = 0.607 vs. 0.103
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.675 vs. 0.195
# F1 = 0.633 vs. 0.321
# Precision = 0.522 vs. 0.195
# Recall = 0.803 vs. 0.909
# Minibatch Loss= 0.007493
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.075
# F1 = 0.996 vs. 0.115
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.282
# F1 = 1.000 vs. 0.440
# Precision = 1.000 vs. 0.282
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.068
# F1 = 0.609 vs. 0.098
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.686 vs. 0.182
# F1 = 0.637 vs. 0.315
# Precision = 0.534 vs. 0.189
# Recall = 0.789 vs. 0.946
# Minibatch Loss= 0.008249
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.077
# F1 = 0.996 vs. 0.111
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.297
# F1 = 1.000 vs. 0.459
# Precision = 1.000 vs. 0.298
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.070
# F1 = 0.609 vs. 0.101
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.193
# F1 = 0.636 vs. 0.312
# Precision = 0.537 vs. 0.185
# Recall = 0.781 vs. 1.000
# Minibatch Loss= 0.008210
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.077
# F1 = 0.996 vs. 0.119
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.285
# F1 = 1.000 vs. 0.441
# Precision = 1.000 vs. 0.283
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.071
# F1 = 0.607 vs. 0.099
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.678 vs. 0.180
# F1 = 0.630 vs. 0.311
# Precision = 0.525 vs. 0.184
# Recall = 0.789 vs. 1.000
# Minibatch Loss= 0.007082
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.081
# F1 = 0.995 vs. 0.129
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.340
# F1 = 1.000 vs. 0.496
# Precision = 1.000 vs. 0.330
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.607 vs. 0.099
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.678 vs. 0.185
# F1 = 0.636 vs. 0.315
# Precision = 0.548 vs. 0.188
# Recall = 0.758 vs. 0.972
# Minibatch Loss= 0.008396
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.081
# F1 = 0.995 vs. 0.126
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.325
# F1 = 1.000 vs. 0.481
# Precision = 1.000 vs. 0.317
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.069
# F1 = 0.606 vs. 0.104
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.680 vs. 0.190
# F1 = 0.633 vs. 0.312
# Precision = 0.539 vs. 0.185
# Recall = 0.766 vs. 0.994
# Minibatch Loss= 0.008201
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.079
# F1 = 0.997 vs. 0.121
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.305
# F1 = 1.000 vs. 0.468
# Precision = 1.000 vs. 0.308
# Recall = 1.000 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.068
# F1 = 0.607 vs. 0.097
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.671 vs. 0.179
# F1 = 0.628 vs. 0.314
# Precision = 0.526 vs. 0.187
# Recall = 0.781 vs. 0.974
# Minibatch Loss= 0.005795
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.118
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.290
# F1 = 1.000 vs. 0.442
# Precision = 1.000 vs. 0.287
# Recall = 1.000 vs. 0.965
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.070
# F1 = 0.608 vs. 0.101
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.677 vs. 0.184
# F1 = 0.632 vs. 0.313
# Precision = 0.536 vs. 0.188
# Recall = 0.769 vs. 0.940
# Minibatch Loss= 0.005978
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.998 vs. 0.109
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.260
# F1 = 1.000 vs. 0.400
# Precision = 1.000 vs. 0.259
# Recall = 1.000 vs. 0.879
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.069
# F1 = 0.608 vs. 0.101
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.190
# F1 = 0.631 vs. 0.313
# Precision = 0.557 vs. 0.186
# Recall = 0.729 vs. 0.997
# Minibatch Loss= 0.005537
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 0.998 vs. 0.127
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.347
# F1 = 1.000 vs. 0.496
# Precision = 1.000 vs. 0.330
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.072
# F1 = 0.606 vs. 0.106
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.675 vs. 0.185
# F1 = 0.629 vs. 0.312
# Precision = 0.552 vs. 0.185
# Recall = 0.732 vs. 1.000
# Minibatch Loss= 0.005989
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.997 vs. 0.123
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.331
# F1 = 1.000 vs. 0.481
# Precision = 1.000 vs. 0.317
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.573 vs. 0.071
# F1 = 0.607 vs. 0.100
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.679 vs. 0.174
# F1 = 0.633 vs. 0.312
# Precision = 0.552 vs. 0.185
# Recall = 0.741 vs. 1.000
# Minibatch Loss= 0.005113
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.085
# F1 = 0.996 vs. 0.128
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.348
# F1 = 1.000 vs. 0.533
# Precision = 1.000 vs. 0.363
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.572 vs. 0.070
# F1 = 0.607 vs. 0.098
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.678 vs. 0.191
# F1 = 0.634 vs. 0.312
# Precision = 0.550 vs. 0.186
# Recall = 0.749 vs. 0.989
# Minibatch Loss= 0.005744
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.080
# F1 = 0.997 vs. 0.125
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 1.000 vs. 0.476
# Precision = 1.000 vs. 0.312
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.067
# F1 = 0.606 vs. 0.094
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.184
# F1 = 0.631 vs. 0.312
# Precision = 0.532 vs. 0.185
# Recall = 0.775 vs. 0.997
# Minibatch Loss= 0.005439
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.120
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.322
# F1 = 1.000 vs. 0.502
# Precision = 1.000 vs. 0.335
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.068
# F1 = 0.605 vs. 0.097
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.671 vs. 0.211
# F1 = 0.633 vs. 0.316
# Precision = 0.552 vs. 0.194
# Recall = 0.741 vs. 0.849
# Minibatch Loss= 0.004837
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.998 vs. 0.116
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.312
# F1 = 1.000 vs. 0.473
# Precision = 1.000 vs. 0.310
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.069
# F1 = 0.608 vs. 0.100
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.675 vs. 0.204
# F1 = 0.638 vs. 0.312
# Precision = 0.551 vs. 0.186
# Recall = 0.758 vs. 0.983
# Minibatch Loss= 0.004815
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.076
# F1 = 0.997 vs. 0.116
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.290
# F1 = 1.000 vs. 0.445
# Precision = 1.000 vs. 0.292
# Recall = 1.000 vs. 0.939
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.072
# F1 = 0.606 vs. 0.107
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.177
# F1 = 0.629 vs. 0.313
# Precision = 0.535 vs. 0.185
# Recall = 0.764 vs. 0.997
# Minibatch Loss= 0.004855
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.113
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.298
# F1 = 1.000 vs. 0.450
# Precision = 1.000 vs. 0.291
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.069
# F1 = 0.606 vs. 0.098
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.664 vs. 0.178
# F1 = 0.626 vs. 0.312
# Precision = 0.528 vs. 0.185
# Recall = 0.769 vs. 0.991
# Minibatch Loss= 0.004909
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.117
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.327
# F1 = 1.000 vs. 0.504
# Precision = 1.000 vs. 0.337
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.069
# F1 = 0.607 vs. 0.104
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.173
# F1 = 0.633 vs. 0.312
# Precision = 0.532 vs. 0.185
# Recall = 0.781 vs. 0.991
# Minibatch Loss= 0.004631
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.121
# Accuracy = 0.992 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.325
# F1 = 1.000 vs. 0.496
# Precision = 1.000 vs. 0.330
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.069
# F1 = 0.607 vs. 0.102
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.175
# F1 = 0.629 vs. 0.315
# Precision = 0.526 vs. 0.188
# Recall = 0.783 vs. 0.969
# Minibatch Loss= 0.004555
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.996 vs. 0.118
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.310
# F1 = 1.000 vs. 0.473
# Precision = 1.000 vs. 0.310
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.071
# F1 = 0.606 vs. 0.102
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.658 vs. 0.187
# F1 = 0.626 vs. 0.313
# Precision = 0.518 vs. 0.185
# Recall = 0.792 vs. 1.000
# Minibatch Loss= 0.004395
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.121
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.307
# F1 = 1.000 vs. 0.464
# Precision = 1.000 vs. 0.302
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.070
# F1 = 0.604 vs. 0.100
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.191
# F1 = 0.627 vs. 0.312
# Precision = 0.538 vs. 0.185
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.004131
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.123
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.353
# F1 = 1.000 vs. 0.516
# Precision = 1.000 vs. 0.347
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.070
# F1 = 0.604 vs. 0.101
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.671 vs. 0.195
# F1 = 0.623 vs. 0.316
# Precision = 0.533 vs. 0.189
# Recall = 0.749 vs. 0.966
# Minibatch Loss= 0.003784
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.112
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.262
# F1 = 1.000 vs. 0.443
# Precision = 1.000 vs. 0.286
# Recall = 1.000 vs. 0.978
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.070
# F1 = 0.609 vs. 0.106
# Accuracy = 0.909 vs. 0.056
# CHANGE DETECTION
# AUC = 0.664 vs. 0.186
# F1 = 0.627 vs. 0.312
# Precision = 0.532 vs. 0.185
# Recall = 0.764 vs. 1.000
# Minibatch Loss= 0.003466
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.119
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.327
# F1 = 1.000 vs. 0.487
# Precision = 1.000 vs. 0.329
# Recall = 1.000 vs. 0.936
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.067
# F1 = 0.606 vs. 0.091
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.663 vs. 0.185
# F1 = 0.622 vs. 0.311
# Precision = 0.532 vs. 0.184
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.003860
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.999 vs. 0.113
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.278
# F1 = 1.000 vs. 0.430
# Precision = 1.000 vs. 0.275
# Recall = 1.000 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.069
# F1 = 0.606 vs. 0.101
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.668 vs. 0.165
# F1 = 0.626 vs. 0.311
# Precision = 0.525 vs. 0.184
# Recall = 0.775 vs. 1.000
# Minibatch Loss= 0.002889
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.113
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.294
# F1 = 1.000 vs. 0.443
# Precision = 1.000 vs. 0.284
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.072
# F1 = 0.608 vs. 0.105
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.185
# F1 = 0.631 vs. 0.313
# Precision = 0.558 vs. 0.188
# Recall = 0.726 vs. 0.929
# Minibatch Loss= 0.003010
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.123
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.348
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.330
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.068
# F1 = 0.608 vs. 0.108
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.658 vs. 0.185
# F1 = 0.631 vs. 0.314
# Precision = 0.554 vs. 0.190
# Recall = 0.732 vs. 0.895
# Minibatch Loss= 0.003162
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.119
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.272
# F1 = 1.000 vs. 0.438
# Precision = 1.000 vs. 0.281
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.068
# F1 = 0.607 vs. 0.096
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.661 vs. 0.185
# F1 = 0.626 vs. 0.312
# Precision = 0.545 vs. 0.185
# Recall = 0.735 vs. 1.000
# Minibatch Loss= 0.002988
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.119
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.295
# F1 = 1.000 vs. 0.441
# Precision = 1.000 vs. 0.284
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.069
# F1 = 0.609 vs. 0.098
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.672 vs. 0.216
# F1 = 0.629 vs. 0.312
# Precision = 0.557 vs. 0.185
# Recall = 0.724 vs. 0.997
# Minibatch Loss= 0.002871
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.999 vs. 0.120
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.304
# F1 = 1.000 vs. 0.446
# Precision = 1.000 vs. 0.287
# Recall = 1.000 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.068
# F1 = 0.609 vs. 0.101
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.643 vs. 0.207
# F1 = 0.631 vs. 0.318
# Precision = 0.557 vs. 0.190
# Recall = 0.729 vs. 0.969
# Minibatch Loss= 0.002398
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.131
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.341
# F1 = 1.000 vs. 0.511
# Precision = 1.000 vs. 0.344
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.067
# F1 = 0.607 vs. 0.098
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.650 vs. 0.189
# F1 = 0.629 vs. 0.313
# Precision = 0.557 vs. 0.186
# Recall = 0.721 vs. 0.994
# Minibatch Loss= 0.002912
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.115
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.323
# F1 = 1.000 vs. 0.487
# Precision = 1.000 vs. 0.321
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.560 vs. 0.068
# F1 = 0.610 vs. 0.099
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.650 vs. 0.200
# F1 = 0.627 vs. 0.320
# Precision = 0.551 vs. 0.191
# Recall = 0.729 vs. 0.977
# Minibatch Loss= 0.002415
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.121
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.335
# F1 = 1.000 vs. 0.502
# Precision = 1.000 vs. 0.335
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.566 vs. 0.068
# F1 = 0.609 vs. 0.100
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.649 vs. 0.190
# F1 = 0.627 vs. 0.314
# Precision = 0.551 vs. 0.188
# Recall = 0.729 vs. 0.957
# Minibatch Loss= 0.002353
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.117
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.331
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.071
# F1 = 0.609 vs. 0.103
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.652 vs. 0.183
# F1 = 0.625 vs. 0.312
# Precision = 0.547 vs. 0.185
# Recall = 0.729 vs. 1.000
# Minibatch Loss= 0.002638
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.384
# F1 = 1.000 vs. 0.543
# Precision = 1.000 vs. 0.373
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.070
# F1 = 0.609 vs. 0.100
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.649 vs. 0.197
# F1 = 0.627 vs. 0.311
# Precision = 0.556 vs. 0.184
# Recall = 0.718 vs. 1.000
# Minibatch Loss= 0.001969
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.116
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.296
# F1 = 1.000 vs. 0.455
# Precision = 1.000 vs. 0.295
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.071
# F1 = 0.609 vs. 0.100
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.659 vs. 0.172
# F1 = 0.626 vs. 0.312
# Precision = 0.557 vs. 0.185
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.002063
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.120
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.324
# F1 = 1.000 vs. 0.507
# Precision = 1.000 vs. 0.345
# Recall = 1.000 vs. 0.955
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.552 vs. 0.070
# F1 = 0.611 vs. 0.107
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.651 vs. 0.213
# F1 = 0.628 vs. 0.313
# Precision = 0.549 vs. 0.186
# Recall = 0.732 vs. 1.000
# Minibatch Loss= 0.001880
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.124
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.336
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.331
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.069
# F1 = 0.611 vs. 0.100
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.653 vs. 0.169
# F1 = 0.625 vs. 0.314
# Precision = 0.552 vs. 0.188
# Recall = 0.721 vs. 0.957
# Minibatch Loss= 0.002032
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.999 vs. 0.120
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.359
# F1 = 1.000 vs. 0.519
# Precision = 1.000 vs. 0.350
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.068
# F1 = 0.608 vs. 0.101
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.650 vs. 0.197
# F1 = 0.626 vs. 0.314
# Precision = 0.538 vs. 0.187
# Recall = 0.749 vs. 0.972
# Minibatch Loss= 0.002096
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.086
# F1 = 0.999 vs. 0.130
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.360
# F1 = 1.000 vs. 0.524
# Precision = 1.000 vs. 0.355
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.069
# F1 = 0.609 vs. 0.104
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.657 vs. 0.184
# F1 = 0.627 vs. 0.313
# Precision = 0.553 vs. 0.186
# Recall = 0.724 vs. 0.974
# Minibatch Loss= 0.001933
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.999 vs. 0.113
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.332
# F1 = 1.000 vs. 0.489
# Precision = 1.000 vs. 0.326
# Recall = 1.000 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.552 vs. 0.070
# F1 = 0.610 vs. 0.101
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.636 vs. 0.205
# F1 = 0.627 vs. 0.314
# Precision = 0.543 vs. 0.187
# Recall = 0.744 vs. 1.000
# Minibatch Loss= 0.001742
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.122
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.322
# F1 = 1.000 vs. 0.491
# Precision = 1.000 vs. 0.328
# Recall = 1.000 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.075
# F1 = 0.605 vs. 0.111
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.646 vs. 0.187
# F1 = 0.626 vs. 0.314
# Precision = 0.528 vs. 0.188
# Recall = 0.769 vs. 0.937
# Minibatch Loss= 0.001382
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.856 vs. 0.084
# F1 = 0.843 vs. 0.120
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.322
# F1 = 0.861 vs. 0.467
# Precision = 0.848 vs. 0.304
# Recall = 0.874 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.486 vs. 0.070
# F1 = 0.542 vs. 0.104
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.622 vs. 0.189
# F1 = 0.639 vs. 0.312
# Precision = 0.587 vs. 0.187
# Recall = 0.701 vs. 0.954
# Minibatch Loss= 0.603652
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.080
# F1 = 0.986 vs. 0.118
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.280
# F1 = 0.992 vs. 0.434
# Precision = 0.993 vs. 0.277
# Recall = 0.991 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.554 vs. 0.070
# F1 = 0.586 vs. 0.102
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.647 vs. 0.189
# F1 = 0.628 vs. 0.313
# Precision = 0.573 vs. 0.185
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 0.016966
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.079
# F1 = 0.994 vs. 0.117
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.356
# F1 = 1.000 vs. 0.497
# Precision = 1.000 vs. 0.332
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.068
# F1 = 0.593 vs. 0.100
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.184
# F1 = 0.626 vs. 0.313
# Precision = 0.632 vs. 0.186
# Recall = 0.621 vs. 0.983
# Minibatch Loss= 0.008037
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.080
# F1 = 0.998 vs. 0.120
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.324
# F1 = 1.000 vs. 0.481
# Precision = 1.000 vs. 0.321
# Recall = 1.000 vs. 0.956
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.066
# F1 = 0.599 vs. 0.091
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.662 vs. 0.190
# F1 = 0.626 vs. 0.314
# Precision = 0.547 vs. 0.186
# Recall = 0.732 vs. 0.991
# Minibatch Loss= 0.005418
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.999 vs. 0.121
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.331
# F1 = 1.000 vs. 0.485
# Precision = 1.000 vs. 0.320
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.070
# F1 = 0.600 vs. 0.106
# Accuracy = 0.910 vs. 0.056
# CHANGE DETECTION
# AUC = 0.655 vs. 0.183
# F1 = 0.627 vs. 0.317
# Precision = 0.568 vs. 0.190
# Recall = 0.698 vs. 0.957
# Minibatch Loss= 0.004576
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.999 vs. 0.120
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.304
# F1 = 1.000 vs. 0.492
# Precision = 1.000 vs. 0.328
# Recall = 1.000 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.069
# F1 = 0.605 vs. 0.101
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.650 vs. 0.182
# F1 = 0.628 vs. 0.313
# Precision = 0.612 vs. 0.185
# Recall = 0.644 vs. 0.997
# Minibatch Loss= 0.003434
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.122
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.305
# F1 = 1.000 vs. 0.468
# Precision = 1.000 vs. 0.306
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.552 vs. 0.072
# F1 = 0.604 vs. 0.104
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.659 vs. 0.194
# F1 = 0.629 vs. 0.314
# Precision = 0.618 vs. 0.186
# Recall = 0.641 vs. 1.000
# Minibatch Loss= 0.002981
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.116
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.334
# F1 = 1.000 vs. 0.474
# Precision = 1.000 vs. 0.311
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.071
# F1 = 0.604 vs. 0.102
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.654 vs. 0.181
# F1 = 0.629 vs. 0.316
# Precision = 0.620 vs. 0.189
# Recall = 0.638 vs. 0.969
# Minibatch Loss= 0.003111
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.123
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.350
# F1 = 1.000 vs. 0.505
# Precision = 1.000 vs. 0.338
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.070
# F1 = 0.603 vs. 0.098
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.661 vs. 0.179
# F1 = 0.628 vs. 0.313
# Precision = 0.624 vs. 0.186
# Recall = 0.632 vs. 0.991
# Minibatch Loss= 0.002848
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.999 vs. 0.115
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.290
# F1 = 1.000 vs. 0.439
# Precision = 1.000 vs. 0.282
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.547 vs. 0.069
# F1 = 0.602 vs. 0.098
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.664 vs. 0.184
# F1 = 0.626 vs. 0.313
# Precision = 0.620 vs. 0.186
# Recall = 0.632 vs. 0.986
# Minibatch Loss= 0.002194
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e877f88d5a2e> in <module>()
#       2                 train_eval_step = 100,
#       3                 validation_eval_step = 100,
# ----> 4                 display_step = 100)
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#      91                                        self.data_train.shape[0])).astype('int32')
#      92
# ---> 93             batch_x = self.data_train[data_idx]
#      94             batch_y = self.ground_truth_train[data_idx]
#      95
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/CNN_activity_Wmultitask5_64_opp/CNN_activity_Wmultitask5_64_opp-9900'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN_activity_multitask_64_opp/CNN_activity_multitask_64_opp-20000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/CNN_activity_multitask_64_opp/CNN_activity_multitask_64_opp-20000

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.543 vs. 0.068
# F1 = 0.601 vs. 0.096
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.657 vs. 0.179
# F1 = 0.628 vs. 0.311
# Precision = 0.533 vs. 0.184
# Recall = 0.764 vs. 1.000

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
