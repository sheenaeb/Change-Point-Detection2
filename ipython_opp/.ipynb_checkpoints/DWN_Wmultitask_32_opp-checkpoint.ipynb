# %%
# useing this variable for saving models and summaries
exp_name = "DWN_Wmultitask_32_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
train_data.shape
# Out:
# (691, 1024, 77)

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.28595522,  42.44204322,  42.96023857,  45.06666667,
#         44.49794239,  34.32268371,  35.42833608,  50.54312354,
#         54.97974684,  62.17714286,  69.87179487,  66.41463415,
#         71.02605863,  57.96533333,  57.4973545 ,  39.35036496,
#         12.09177028,  47.81236203,   4.77487595])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/checkpoint'

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet = True,
                                 trainable_conv = True,
                                 trainable_last = True,
                                 variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.069 vs. 0.068
# F1 = 0.109 vs. 0.103
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.219 vs. 0.170
# F1 = 0.358 vs. 0.305
# Precision = 0.225 vs. 0.180
# Recall = 0.878 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.063 vs. 0.062
# F1 = 0.091 vs. 0.085
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.124 vs. 0.100
# F1 = 0.239 vs. 0.183
# Precision = 0.144 vs. 0.105
# Recall = 0.702 vs. 0.739
# Minibatch Loss= 1.449261
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.524 vs. 0.068
# F1 = 0.566 vs. 0.100
# Accuracy = 0.521 vs. 0.056
# CHANGE DETECTION
# AUC = 0.398 vs. 0.168
# F1 = 0.490 vs. 0.284
# Precision = 0.400 vs. 0.165
# Recall = 0.631 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.289 vs. 0.062
# F1 = 0.371 vs. 0.084
# Accuracy = 0.460 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.092
# F1 = 0.360 vs. 0.187
# Precision = 0.280 vs. 0.104
# Recall = 0.504 vs. 0.923
# Minibatch Loss= 0.393301
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.654 vs. 0.066
# F1 = 0.669 vs. 0.098
# Accuracy = 0.765 vs. 0.056
# CHANGE DETECTION
# AUC = 0.431 vs. 0.170
# F1 = 0.512 vs. 0.283
# Precision = 0.418 vs. 0.165
# Recall = 0.663 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.392 vs. 0.062
# F1 = 0.454 vs. 0.085
# Accuracy = 0.702 vs. 0.056
# CHANGE DETECTION
# AUC = 0.288 vs. 0.098
# F1 = 0.376 vs. 0.182
# Precision = 0.265 vs. 0.100
# Recall = 0.649 vs. 1.000
# Minibatch Loss= 0.238949
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.751 vs. 0.065
# F1 = 0.745 vs. 0.099
# Accuracy = 0.835 vs. 0.056
# CHANGE DETECTION
# AUC = 0.432 vs. 0.142
# F1 = 0.512 vs. 0.242
# Precision = 0.409 vs. 0.139
# Recall = 0.686 vs. 0.960
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.419 vs. 0.063
# F1 = 0.479 vs. 0.089
# Accuracy = 0.769 vs. 0.056
# CHANGE DETECTION
# AUC = 0.279 vs. 0.099
# F1 = 0.397 vs. 0.182
# Precision = 0.284 vs. 0.102
# Recall = 0.660 vs. 0.876
# Minibatch Loss= 0.159725
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.767 vs. 0.069
# F1 = 0.768 vs. 0.105
# Accuracy = 0.829 vs. 0.056
# CHANGE DETECTION
# AUC = 0.503 vs. 0.205
# F1 = 0.567 vs. 0.341
# Precision = 0.464 vs. 0.206
# Recall = 0.729 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.417 vs. 0.062
# F1 = 0.471 vs. 0.083
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.095
# F1 = 0.363 vs. 0.182
# Precision = 0.251 vs. 0.100
# Recall = 0.660 vs. 0.989
# Minibatch Loss= 0.195843
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.792 vs. 0.067
# F1 = 0.799 vs. 0.101
# Accuracy = 0.795 vs. 0.056
# CHANGE DETECTION
# AUC = 0.504 vs. 0.179
# F1 = 0.551 vs. 0.303
# Precision = 0.440 vs. 0.179
# Recall = 0.736 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.420 vs. 0.061
# F1 = 0.479 vs. 0.088
# Accuracy = 0.752 vs. 0.056
# CHANGE DETECTION
# AUC = 0.276 vs. 0.102
# F1 = 0.376 vs. 0.182
# Precision = 0.254 vs. 0.100
# Recall = 0.728 vs. 0.987
# Minibatch Loss= 0.147611
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.835 vs. 0.066
# F1 = 0.831 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.560 vs. 0.182
# F1 = 0.595 vs. 0.310
# Precision = 0.471 vs. 0.183
# Recall = 0.805 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.421 vs. 0.063
# F1 = 0.489 vs. 0.091
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.097
# F1 = 0.377 vs. 0.181
# Precision = 0.270 vs. 0.100
# Recall = 0.625 vs. 0.958
# Minibatch Loss= 0.140608
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.843 vs. 0.069
# F1 = 0.834 vs. 0.106
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.530 vs. 0.185
# F1 = 0.567 vs. 0.322
# Precision = 0.449 vs. 0.193
# Recall = 0.769 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.427 vs. 0.062
# F1 = 0.486 vs. 0.085
# Accuracy = 0.829 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.095
# F1 = 0.355 vs. 0.182
# Precision = 0.296 vs. 0.100
# Recall = 0.443 vs. 0.989
# Minibatch Loss= 0.136274
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.828 vs. 0.068
# F1 = 0.832 vs. 0.097
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.564 vs. 0.157
# F1 = 0.614 vs. 0.282
# Precision = 0.493 vs. 0.165
# Recall = 0.813 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.427 vs. 0.063
# F1 = 0.494 vs. 0.086
# Accuracy = 0.823 vs. 0.056
# CHANGE DETECTION
# AUC = 0.266 vs. 0.095
# F1 = 0.354 vs. 0.183
# Precision = 0.249 vs. 0.102
# Recall = 0.612 vs. 0.908
# Minibatch Loss= 0.116215
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.923 vs. 0.067
# F1 = 0.904 vs. 0.101
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.606 vs. 0.187
# F1 = 0.633 vs. 0.300
# Precision = 0.504 vs. 0.177
# Recall = 0.851 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.418 vs. 0.063
# F1 = 0.480 vs. 0.090
# Accuracy = 0.839 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.102
# F1 = 0.360 vs. 0.183
# Precision = 0.258 vs. 0.102
# Recall = 0.599 vs. 0.889
# Minibatch Loss= 0.090781
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.877 vs. 0.068
# F1 = 0.879 vs. 0.105
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.582 vs. 0.195
# F1 = 0.618 vs. 0.310
# Precision = 0.488 vs. 0.184
# Recall = 0.842 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.434 vs. 0.065
# F1 = 0.492 vs. 0.091
# Accuracy = 0.813 vs. 0.056
# CHANGE DETECTION
# AUC = 0.281 vs. 0.092
# F1 = 0.383 vs. 0.181
# Precision = 0.268 vs. 0.100
# Recall = 0.675 vs. 1.000
# Minibatch Loss= 0.109345
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.923 vs. 0.066
# F1 = 0.911 vs. 0.098
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.574 vs. 0.133
# F1 = 0.605 vs. 0.243
# Precision = 0.488 vs. 0.138
# Recall = 0.796 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.420 vs. 0.064
# F1 = 0.480 vs. 0.098
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.265 vs. 0.105
# F1 = 0.365 vs. 0.182
# Precision = 0.257 vs. 0.101
# Recall = 0.625 vs. 0.968
# Minibatch Loss= 0.070341
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.897 vs. 0.066
# F1 = 0.894 vs. 0.100
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.638 vs. 0.167
# F1 = 0.648 vs. 0.289
# Precision = 0.535 vs. 0.169
# Recall = 0.822 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.424 vs. 0.063
# F1 = 0.485 vs. 0.093
# Accuracy = 0.828 vs. 0.056
# CHANGE DETECTION
# AUC = 0.270 vs. 0.098
# F1 = 0.365 vs. 0.182
# Precision = 0.260 vs. 0.100
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 0.097088
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.895 vs. 0.066
# F1 = 0.901 vs. 0.098
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.621 vs. 0.172
# F1 = 0.631 vs. 0.294
# Precision = 0.518 vs. 0.173
# Recall = 0.805 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.426 vs. 0.061
# F1 = 0.483 vs. 0.084
# Accuracy = 0.807 vs. 0.056
# CHANGE DETECTION
# AUC = 0.271 vs. 0.108
# F1 = 0.380 vs. 0.181
# Precision = 0.290 vs. 0.100
# Recall = 0.554 vs. 1.000
# Minibatch Loss= 0.088488
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.920 vs. 0.067
# F1 = 0.920 vs. 0.103
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.690 vs. 0.153
# F1 = 0.669 vs. 0.265
# Precision = 0.548 vs. 0.152
# Recall = 0.859 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.426 vs. 0.062
# F1 = 0.493 vs. 0.088
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.268 vs. 0.103
# F1 = 0.371 vs. 0.182
# Precision = 0.293 vs. 0.101
# Recall = 0.507 vs. 0.958
# Minibatch Loss= 0.065174
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.938 vs. 0.067
# F1 = 0.937 vs. 0.101
# Accuracy = 0.942 vs. 0.056
# CHANGE DETECTION
# AUC = 0.677 vs. 0.170
# F1 = 0.673 vs. 0.288
# Precision = 0.546 vs. 0.168
# Recall = 0.879 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.424 vs. 0.061
# F1 = 0.488 vs. 0.083
# Accuracy = 0.846 vs. 0.056
# CHANGE DETECTION
# AUC = 0.273 vs. 0.096
# F1 = 0.385 vs. 0.181
# Precision = 0.303 vs. 0.100
# Recall = 0.530 vs. 1.000
# Minibatch Loss= 0.061792
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.703 vs. 0.067
# F1 = 0.688 vs. 0.102
# Accuracy = 0.516 vs. 0.056
# CHANGE DETECTION
# AUC = 0.385 vs. 0.179
# F1 = 0.493 vs. 0.281
# Precision = 0.383 vs. 0.163
# Recall = 0.693 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.385 vs. 0.064
# F1 = 0.462 vs. 0.091
# Accuracy = 0.437 vs. 0.056
# CHANGE DETECTION
# AUC = 0.270 vs. 0.104
# F1 = 0.363 vs. 0.186
# Precision = 0.282 vs. 0.105
# Recall = 0.507 vs. 0.839
# Minibatch Loss= 0.378848
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.879 vs. 0.065
# F1 = 0.834 vs. 0.102
# Accuracy = 0.780 vs. 0.056
# CHANGE DETECTION
# AUC = 0.551 vs. 0.148
# F1 = 0.570 vs. 0.254
# Precision = 0.462 vs. 0.148
# Recall = 0.742 vs. 0.896
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.482 vs. 0.063
# F1 = 0.537 vs. 0.091
# Accuracy = 0.754 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.114
# F1 = 0.407 vs. 0.188
# Precision = 0.288 vs. 0.107
# Recall = 0.694 vs. 0.778
# Minibatch Loss= 0.130844
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.910 vs. 0.067
# F1 = 0.880 vs. 0.103
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.575 vs. 0.190
# F1 = 0.624 vs. 0.324
# Precision = 0.495 vs. 0.193
# Recall = 0.843 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.475 vs. 0.062
# F1 = 0.529 vs. 0.083
# Accuracy = 0.816 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.106
# F1 = 0.427 vs. 0.185
# Precision = 0.316 vs. 0.102
# Recall = 0.657 vs. 0.966
# Minibatch Loss= 0.115204
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.905 vs. 0.065
# F1 = 0.897 vs. 0.102
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.622 vs. 0.145
# F1 = 0.621 vs. 0.255
# Precision = 0.530 vs. 0.148
# Recall = 0.749 vs. 0.910
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.479 vs. 0.063
# F1 = 0.533 vs. 0.092
# Accuracy = 0.794 vs. 0.056
# CHANGE DETECTION
# AUC = 0.314 vs. 0.102
# F1 = 0.414 vs. 0.186
# Precision = 0.307 vs. 0.108
# Recall = 0.639 vs. 0.675
# Minibatch Loss= 0.076305
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.917 vs. 0.067
# F1 = 0.908 vs. 0.099
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.593 vs. 0.157
# F1 = 0.623 vs. 0.272
# Precision = 0.499 vs. 0.157
# Recall = 0.826 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.475 vs. 0.062
# F1 = 0.527 vs. 0.088
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.110
# F1 = 0.420 vs. 0.188
# Precision = 0.306 vs. 0.105
# Recall = 0.670 vs. 0.926
# Minibatch Loss= 0.077915
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.950 vs. 0.067
# F1 = 0.930 vs. 0.101
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.624 vs. 0.166
# F1 = 0.661 vs. 0.288
# Precision = 0.551 vs. 0.169
# Recall = 0.827 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.468 vs. 0.063
# F1 = 0.516 vs. 0.088
# Accuracy = 0.810 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.098
# F1 = 0.413 vs. 0.184
# Precision = 0.313 vs. 0.102
# Recall = 0.609 vs. 0.937
# Minibatch Loss= 0.073110
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.945 vs. 0.066
# F1 = 0.932 vs. 0.100
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.636 vs. 0.171
# F1 = 0.679 vs. 0.303
# Precision = 0.574 vs. 0.179
# Recall = 0.831 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.473 vs. 0.063
# F1 = 0.520 vs. 0.086
# Accuracy = 0.816 vs. 0.056
# CHANGE DETECTION
# AUC = 0.311 vs. 0.103
# F1 = 0.421 vs. 0.185
# Precision = 0.296 vs. 0.107
# Recall = 0.731 vs. 0.702
# Minibatch Loss= 0.072380
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.943 vs. 0.067
# F1 = 0.940 vs. 0.099
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.712 vs. 0.175
# F1 = 0.697 vs. 0.305
# Precision = 0.624 vs. 0.180
# Recall = 0.790 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.472 vs. 0.062
# F1 = 0.518 vs. 0.085
# Accuracy = 0.809 vs. 0.056
# CHANGE DETECTION
# AUC = 0.306 vs. 0.101
# F1 = 0.416 vs. 0.181
# Precision = 0.303 vs. 0.100
# Recall = 0.662 vs. 0.984
# Minibatch Loss= 0.063892
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.951 vs. 0.065
# F1 = 0.935 vs. 0.096
# Accuracy = 0.949 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.158
# F1 = 0.686 vs. 0.261
# Precision = 0.566 vs. 0.150
# Recall = 0.872 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.472 vs. 0.064
# F1 = 0.524 vs. 0.088
# Accuracy = 0.819 vs. 0.056
# CHANGE DETECTION
# AUC = 0.307 vs. 0.098
# F1 = 0.414 vs. 0.184
# Precision = 0.301 vs. 0.101
# Recall = 0.665 vs. 0.989
# Minibatch Loss= 0.059113
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.949 vs. 0.067
# F1 = 0.949 vs. 0.100
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.748 vs. 0.182
# F1 = 0.729 vs. 0.315
# Precision = 0.613 vs. 0.187
# Recall = 0.898 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.472 vs. 0.063
# F1 = 0.519 vs. 0.093
# Accuracy = 0.831 vs. 0.056
# CHANGE DETECTION
# AUC = 0.302 vs. 0.105
# F1 = 0.406 vs. 0.185
# Precision = 0.292 vs. 0.106
# Recall = 0.670 vs. 0.707
# Minibatch Loss= 0.059128
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.066
# F1 = 0.959 vs. 0.098
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.744 vs. 0.150
# F1 = 0.728 vs. 0.268
# Precision = 0.636 vs. 0.155
# Recall = 0.851 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.468 vs. 0.063
# F1 = 0.524 vs. 0.088
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.298 vs. 0.098
# F1 = 0.402 vs. 0.182
# Precision = 0.292 vs. 0.100
# Recall = 0.646 vs. 0.987
# Minibatch Loss= 0.046900
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.956 vs. 0.069
# F1 = 0.946 vs. 0.104
# Accuracy = 0.945 vs. 0.056
# CHANGE DETECTION
# AUC = 0.743 vs. 0.197
# F1 = 0.732 vs. 0.315
# Precision = 0.655 vs. 0.188
# Recall = 0.831 vs. 0.956
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.475 vs. 0.063
# F1 = 0.525 vs. 0.090
# Accuracy = 0.816 vs. 0.056
# CHANGE DETECTION
# AUC = 0.296 vs. 0.106
# F1 = 0.408 vs. 0.182
# Precision = 0.299 vs. 0.104
# Recall = 0.641 vs. 0.720
# Minibatch Loss= 0.059656
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.923 vs. 0.070
# F1 = 0.890 vs. 0.105
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.674 vs. 0.183
# F1 = 0.672 vs. 0.309
# Precision = 0.585 vs. 0.183
# Recall = 0.791 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.510 vs. 0.063
# F1 = 0.549 vs. 0.092
# Accuracy = 0.738 vs. 0.056
# CHANGE DETECTION
# AUC = 0.287 vs. 0.108
# F1 = 0.381 vs. 0.191
# Precision = 0.295 vs. 0.108
# Recall = 0.538 vs. 0.852
# Minibatch Loss= 0.113783
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.974 vs. 0.066
# F1 = 0.963 vs. 0.102
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.754 vs. 0.164
# F1 = 0.731 vs. 0.271
# Precision = 0.635 vs. 0.157
# Recall = 0.860 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.503 vs. 0.062
# F1 = 0.545 vs. 0.081
# Accuracy = 0.845 vs. 0.056
# CHANGE DETECTION
# AUC = 0.315 vs. 0.106
# F1 = 0.409 vs. 0.186
# Precision = 0.284 vs. 0.104
# Recall = 0.731 vs. 0.897
# Minibatch Loss= 0.049807
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.066
# F1 = 0.957 vs. 0.099
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.761 vs. 0.164
# F1 = 0.743 vs. 0.277
# Precision = 0.640 vs. 0.161
# Recall = 0.887 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.498 vs. 0.062
# F1 = 0.537 vs. 0.089
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.109
# F1 = 0.416 vs. 0.183
# Precision = 0.327 vs. 0.102
# Recall = 0.570 vs. 0.902
# Minibatch Loss= 0.046641
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.065
# F1 = 0.975 vs. 0.098
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.773 vs. 0.159
# F1 = 0.760 vs. 0.271
# Precision = 0.659 vs. 0.157
# Recall = 0.899 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.494 vs. 0.062
# F1 = 0.530 vs. 0.088
# Accuracy = 0.850 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.108
# F1 = 0.411 vs. 0.182
# Precision = 0.323 vs. 0.103
# Recall = 0.565 vs. 0.760
# Minibatch Loss= 0.037540
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.975 vs. 0.069
# F1 = 0.962 vs. 0.106
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.782 vs. 0.187
# F1 = 0.758 vs. 0.319
# Precision = 0.657 vs. 0.190
# Recall = 0.898 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.488 vs. 0.062
# F1 = 0.533 vs. 0.090
# Accuracy = 0.857 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.109
# F1 = 0.400 vs. 0.185
# Precision = 0.329 vs. 0.102
# Recall = 0.512 vs. 0.953
# Minibatch Loss= 0.049231
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.067
# F1 = 0.972 vs. 0.102
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.778 vs. 0.152
# F1 = 0.774 vs. 0.263
# Precision = 0.672 vs. 0.155
# Recall = 0.911 vs. 0.855
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.491 vs. 0.063
# F1 = 0.536 vs. 0.087
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.312 vs. 0.097
# F1 = 0.402 vs. 0.181
# Precision = 0.338 vs. 0.100
# Recall = 0.496 vs. 1.000
# Minibatch Loss= 0.036421
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.982 vs. 0.068
# F1 = 0.974 vs. 0.102
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.776 vs. 0.168
# F1 = 0.770 vs. 0.294
# Precision = 0.685 vs. 0.173
# Recall = 0.880 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.489 vs. 0.063
# F1 = 0.528 vs. 0.092
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.104
# F1 = 0.402 vs. 0.182
# Precision = 0.330 vs. 0.100
# Recall = 0.515 vs. 0.982
# Minibatch Loss= 0.042876
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.979 vs. 0.069
# F1 = 0.974 vs. 0.101
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.839 vs. 0.178
# F1 = 0.806 vs. 0.299
# Precision = 0.725 vs. 0.176
# Recall = 0.907 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.485 vs. 0.062
# F1 = 0.529 vs. 0.085
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.309 vs. 0.103
# F1 = 0.398 vs. 0.183
# Precision = 0.344 vs. 0.101
# Recall = 0.472 vs. 0.997
# Minibatch Loss= 0.038616
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.067
# F1 = 0.966 vs. 0.098
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.784 vs. 0.161
# F1 = 0.788 vs. 0.283
# Precision = 0.702 vs. 0.165
# Recall = 0.898 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.484 vs. 0.063
# F1 = 0.523 vs. 0.088
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.101
# F1 = 0.398 vs. 0.182
# Precision = 0.318 vs. 0.100
# Recall = 0.533 vs. 0.997
# Minibatch Loss= 0.040314
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.888 vs. 0.067
# F1 = 0.840 vs. 0.100
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.674 vs. 0.187
# F1 = 0.662 vs. 0.310
# Precision = 0.565 vs. 0.183
# Recall = 0.799 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.063
# F1 = 0.575 vs. 0.091
# Accuracy = 0.826 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.105
# F1 = 0.392 vs. 0.186
# Precision = 0.309 vs. 0.105
# Recall = 0.538 vs. 0.839
# Minibatch Loss= 0.154875
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.969 vs. 0.069
# F1 = 0.951 vs. 0.106
# Accuracy = 0.947 vs. 0.056
# CHANGE DETECTION
# AUC = 0.755 vs. 0.187
# F1 = 0.745 vs. 0.309
# Precision = 0.656 vs. 0.183
# Recall = 0.862 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.534 vs. 0.061
# F1 = 0.568 vs. 0.087
# Accuracy = 0.858 vs. 0.056
# CHANGE DETECTION
# AUC = 0.340 vs. 0.093
# F1 = 0.425 vs. 0.181
# Precision = 0.330 vs. 0.100
# Recall = 0.599 vs. 0.992
# Minibatch Loss= 0.056648
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.068
# F1 = 0.971 vs. 0.099
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.806 vs. 0.177
# F1 = 0.777 vs. 0.302
# Precision = 0.676 vs. 0.178
# Recall = 0.913 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.531 vs. 0.062
# F1 = 0.560 vs. 0.084
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.333 vs. 0.102
# F1 = 0.420 vs. 0.188
# Precision = 0.342 vs. 0.119
# Recall = 0.544 vs. 0.446
# Minibatch Loss= 0.042053
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.067
# F1 = 0.976 vs. 0.105
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.799 vs. 0.172
# F1 = 0.775 vs. 0.299
# Precision = 0.701 vs. 0.176
# Recall = 0.866 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.526 vs. 0.062
# F1 = 0.561 vs. 0.087
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.331 vs. 0.103
# F1 = 0.415 vs. 0.183
# Precision = 0.326 vs. 0.102
# Recall = 0.570 vs. 0.894
# Minibatch Loss= 0.040883
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.065
# F1 = 0.981 vs. 0.096
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.776 vs. 0.170
# F1 = 0.776 vs. 0.283
# Precision = 0.663 vs. 0.165
# Recall = 0.934 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.529 vs. 0.064
# F1 = 0.563 vs. 0.090
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.100
# F1 = 0.417 vs. 0.182
# Precision = 0.321 vs. 0.100
# Recall = 0.594 vs. 0.997
# Minibatch Loss= 0.035730
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.063
# F1 = 0.980 vs. 0.094
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.821 vs. 0.152
# F1 = 0.799 vs. 0.262
# Precision = 0.693 vs. 0.151
# Recall = 0.944 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.062
# F1 = 0.560 vs. 0.085
# Accuracy = 0.864 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.113
# F1 = 0.417 vs. 0.189
# Precision = 0.320 vs. 0.108
# Recall = 0.599 vs. 0.757
# Minibatch Loss= 0.031992
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.066
# F1 = 0.984 vs. 0.098
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.877 vs. 0.160
# F1 = 0.843 vs. 0.276
# Precision = 0.759 vs. 0.160
# Recall = 0.949 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.520 vs. 0.063
# F1 = 0.556 vs. 0.091
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.105
# F1 = 0.409 vs. 0.184
# Precision = 0.312 vs. 0.104
# Recall = 0.591 vs. 0.797
# Minibatch Loss= 0.028079
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.066
# F1 = 0.982 vs. 0.098
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.828 vs. 0.172
# F1 = 0.820 vs. 0.283
# Precision = 0.725 vs. 0.165
# Recall = 0.943 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.513 vs. 0.062
# F1 = 0.554 vs. 0.086
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.101
# F1 = 0.403 vs. 0.181
# Precision = 0.293 vs. 0.100
# Recall = 0.646 vs. 1.000
# Minibatch Loss= 0.031133
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.067
# F1 = 0.984 vs. 0.101
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.845 vs. 0.175
# F1 = 0.849 vs. 0.308
# Precision = 0.762 vs. 0.182
# Recall = 0.957 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.063
# F1 = 0.553 vs. 0.088
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.093
# F1 = 0.404 vs. 0.181
# Precision = 0.309 vs. 0.100
# Recall = 0.583 vs. 0.995
# Minibatch Loss= 0.030851
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.067
# F1 = 0.982 vs. 0.100
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.880 vs. 0.163
# F1 = 0.857 vs. 0.284
# Precision = 0.799 vs. 0.166
# Recall = 0.924 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.507 vs. 0.062
# F1 = 0.547 vs. 0.086
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.316 vs. 0.094
# F1 = 0.406 vs. 0.183
# Precision = 0.313 vs. 0.101
# Recall = 0.578 vs. 0.979
# Minibatch Loss= 0.028564
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.940 vs. 0.070
# F1 = 0.889 vs. 0.108
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.745 vs. 0.202
# F1 = 0.706 vs. 0.323
# Precision = 0.623 vs. 0.193
# Recall = 0.815 vs. 0.984
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.544 vs. 0.065
# F1 = 0.581 vs. 0.092
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.329 vs. 0.094
# F1 = 0.415 vs. 0.181
# Precision = 0.308 vs. 0.100
# Recall = 0.636 vs. 1.000
# Minibatch Loss= 0.108320
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.067
# F1 = 0.958 vs. 0.102
# Accuracy = 0.955 vs. 0.056
# CHANGE DETECTION
# AUC = 0.772 vs. 0.165
# F1 = 0.745 vs. 0.277
# Precision = 0.676 vs. 0.163
# Recall = 0.829 vs. 0.924
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.534 vs. 0.062
# F1 = 0.583 vs. 0.085
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.099
# F1 = 0.427 vs. 0.183
# Precision = 0.303 vs. 0.101
# Recall = 0.723 vs. 0.968
# Minibatch Loss= 0.049104
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.980 vs. 0.070
# F1 = 0.972 vs. 0.105
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.831 vs. 0.185
# F1 = 0.805 vs. 0.308
# Precision = 0.718 vs. 0.182
# Recall = 0.916 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.530 vs. 0.062
# F1 = 0.579 vs. 0.086
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.335 vs. 0.102
# F1 = 0.425 vs. 0.181
# Precision = 0.307 vs. 0.100
# Recall = 0.691 vs. 0.997
# Minibatch Loss= 0.044049
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.065
# F1 = 0.977 vs. 0.098
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.812 vs. 0.156
# F1 = 0.792 vs. 0.272
# Precision = 0.697 vs. 0.158
# Recall = 0.917 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.537 vs. 0.062
# F1 = 0.580 vs. 0.088
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.334 vs. 0.096
# F1 = 0.428 vs. 0.181
# Precision = 0.308 vs. 0.100
# Recall = 0.699 vs. 1.000
# Minibatch Loss= 0.037808
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.067
# F1 = 0.986 vs. 0.103
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.865 vs. 0.163
# F1 = 0.819 vs. 0.285
# Precision = 0.726 vs. 0.167
# Recall = 0.938 vs. 0.973
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.532 vs. 0.063
# F1 = 0.582 vs. 0.087
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.099
# F1 = 0.412 vs. 0.185
# Precision = 0.293 vs. 0.102
# Recall = 0.691 vs. 0.960
# Minibatch Loss= 0.031348
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.068
# F1 = 0.985 vs. 0.104
# Accuracy = 0.969 vs. 0.056
# CHANGE DETECTION
# AUC = 0.894 vs. 0.185
# F1 = 0.841 vs. 0.321
# Precision = 0.755 vs. 0.192
# Recall = 0.948 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.527 vs. 0.065
# F1 = 0.580 vs. 0.097
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.328 vs. 0.106
# F1 = 0.417 vs. 0.182
# Precision = 0.328 vs. 0.100
# Recall = 0.573 vs. 0.989
# Minibatch Loss= 0.032454
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.070
# F1 = 0.985 vs. 0.105
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.903 vs. 0.198
# F1 = 0.868 vs. 0.333
# Precision = 0.797 vs. 0.200
# Recall = 0.952 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.525 vs. 0.062
# F1 = 0.585 vs. 0.087
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.327 vs. 0.100
# F1 = 0.423 vs. 0.185
# Precision = 0.320 vs. 0.102
# Recall = 0.625 vs. 0.950
# Minibatch Loss= 0.031227
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.067
# F1 = 0.989 vs. 0.100
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.892 vs. 0.155
# F1 = 0.850 vs. 0.284
# Precision = 0.793 vs. 0.166
# Recall = 0.915 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.525 vs. 0.063
# F1 = 0.585 vs. 0.089
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.099
# F1 = 0.424 vs. 0.182
# Precision = 0.320 vs. 0.101
# Recall = 0.631 vs. 0.913
# Minibatch Loss= 0.025352
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.067
# F1 = 0.987 vs. 0.104
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.887 vs. 0.169
# F1 = 0.865 vs. 0.291
# Precision = 0.793 vs. 0.171
# Recall = 0.952 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.523 vs. 0.062
# F1 = 0.584 vs. 0.093
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.103
# F1 = 0.425 vs. 0.181
# Precision = 0.314 vs. 0.100
# Recall = 0.657 vs. 0.997
# Minibatch Loss= 0.025781
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.068
# F1 = 0.989 vs. 0.105
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.882 vs. 0.179
# F1 = 0.868 vs. 0.293
# Precision = 0.786 vs. 0.177
# Recall = 0.971 vs. 0.851
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.062
# F1 = 0.580 vs. 0.090
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.096
# F1 = 0.416 vs. 0.181
# Precision = 0.320 vs. 0.100
# Recall = 0.594 vs. 1.000
# Minibatch Loss= 0.025267
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.067
# F1 = 0.985 vs. 0.101
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.887 vs. 0.187
# F1 = 0.877 vs. 0.307
# Precision = 0.808 vs. 0.187
# Recall = 0.960 vs. 0.855
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.523 vs. 0.062
# F1 = 0.577 vs. 0.085
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.106
# F1 = 0.410 vs. 0.185
# Precision = 0.331 vs. 0.107
# Recall = 0.541 vs. 0.697
# Minibatch Loss= 0.026785
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.069
# F1 = 0.991 vs. 0.105
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.195
# F1 = 0.890 vs. 0.331
# Precision = 0.837 vs. 0.198
# Recall = 0.951 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.062
# F1 = 0.583 vs. 0.090
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.094
# F1 = 0.410 vs. 0.181
# Precision = 0.324 vs. 0.100
# Recall = 0.559 vs. 1.000
# Minibatch Loss= 0.024764
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.069
# F1 = 0.992 vs. 0.107
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.925 vs. 0.157
# F1 = 0.892 vs. 0.274
# Precision = 0.826 vs. 0.159
# Recall = 0.970 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.517 vs. 0.062
# F1 = 0.578 vs. 0.084
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.097
# F1 = 0.408 vs. 0.182
# Precision = 0.300 vs. 0.100
# Recall = 0.639 vs. 0.979
# Minibatch Loss= 0.020028
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.068
# F1 = 0.985 vs. 0.103
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.903 vs. 0.178
# F1 = 0.887 vs. 0.307
# Precision = 0.828 vs. 0.182
# Recall = 0.955 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.509 vs. 0.064
# F1 = 0.575 vs. 0.088
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.318 vs. 0.099
# F1 = 0.410 vs. 0.184
# Precision = 0.313 vs. 0.101
# Recall = 0.594 vs. 0.963
# Minibatch Loss= 0.025710
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.932 vs. 0.066
# F1 = 0.880 vs. 0.098
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.765 vs. 0.184
# F1 = 0.727 vs. 0.316
# Precision = 0.687 vs. 0.193
# Recall = 0.771 vs. 0.861
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.543 vs. 0.063
# F1 = 0.598 vs. 0.086
# Accuracy = 0.859 vs. 0.056
# CHANGE DETECTION
# AUC = 0.325 vs. 0.092
# F1 = 0.429 vs. 0.182
# Precision = 0.367 vs. 0.100
# Recall = 0.517 vs. 0.989
# Minibatch Loss= 0.104638
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.067
# F1 = 0.971 vs. 0.102
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.835 vs. 0.171
# F1 = 0.777 vs. 0.276
# Precision = 0.718 vs. 0.165
# Recall = 0.847 vs. 0.839
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.062
# F1 = 0.592 vs. 0.085
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.339 vs. 0.098
# F1 = 0.444 vs. 0.182
# Precision = 0.377 vs. 0.100
# Recall = 0.541 vs. 0.989
# Minibatch Loss= 0.040108
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.067
# F1 = 0.981 vs. 0.100
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.857 vs. 0.172
# F1 = 0.826 vs. 0.284
# Precision = 0.772 vs. 0.166
# Recall = 0.889 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.061
# F1 = 0.597 vs. 0.087
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.341 vs. 0.093
# F1 = 0.443 vs. 0.181
# Precision = 0.347 vs. 0.100
# Recall = 0.612 vs. 1.000
# Minibatch Loss= 0.033397
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.067
# F1 = 0.981 vs. 0.101
# Accuracy = 0.972 vs. 0.056
# CHANGE DETECTION
# AUC = 0.879 vs. 0.154
# F1 = 0.828 vs. 0.285
# Precision = 0.769 vs. 0.166
# Recall = 0.896 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.063
# F1 = 0.597 vs. 0.088
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.345 vs. 0.107
# F1 = 0.435 vs. 0.182
# Precision = 0.356 vs. 0.101
# Recall = 0.559 vs. 0.934
# Minibatch Loss= 0.031519
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.069
# F1 = 0.987 vs. 0.110
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.890 vs. 0.186
# F1 = 0.873 vs. 0.307
# Precision = 0.808 vs. 0.181
# Recall = 0.948 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.065
# F1 = 0.596 vs. 0.092
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.340 vs. 0.095
# F1 = 0.428 vs. 0.183
# Precision = 0.370 vs. 0.101
# Recall = 0.507 vs. 0.960
# Minibatch Loss= 0.027245
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.069
# F1 = 0.987 vs. 0.102
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.912 vs. 0.187
# F1 = 0.871 vs. 0.311
# Precision = 0.818 vs. 0.184
# Recall = 0.931 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.062
# F1 = 0.599 vs. 0.087
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.344 vs. 0.104
# F1 = 0.430 vs. 0.182
# Precision = 0.333 vs. 0.100
# Recall = 0.607 vs. 0.984
# Minibatch Loss= 0.029758
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.064
# F1 = 0.990 vs. 0.097
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.879 vs. 0.141
# F1 = 0.865 vs. 0.240
# Precision = 0.808 vs. 0.136
# Recall = 0.931 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.065
# F1 = 0.598 vs. 0.098
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.342 vs. 0.104
# F1 = 0.418 vs. 0.187
# Precision = 0.330 vs. 0.104
# Recall = 0.570 vs. 0.894
# Minibatch Loss= 0.021887
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.067
# F1 = 0.988 vs. 0.103
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.937 vs. 0.184
# F1 = 0.910 vs. 0.323
# Precision = 0.865 vs. 0.193
# Recall = 0.959 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.062
# F1 = 0.596 vs. 0.088
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.345 vs. 0.109
# F1 = 0.424 vs. 0.187
# Precision = 0.334 vs. 0.105
# Recall = 0.580 vs. 0.855
# Minibatch Loss= 0.022616
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.067
# F1 = 0.991 vs. 0.104
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.932 vs. 0.166
# F1 = 0.912 vs. 0.285
# Precision = 0.856 vs. 0.166
# Recall = 0.976 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.063
# F1 = 0.597 vs. 0.084
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.340 vs. 0.099
# F1 = 0.415 vs. 0.182
# Precision = 0.384 vs. 0.101
# Recall = 0.451 vs. 0.971
# Minibatch Loss= 0.019640
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.067
# F1 = 0.991 vs. 0.099
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.924 vs. 0.184
# F1 = 0.910 vs. 0.290
# Precision = 0.864 vs. 0.171
# Recall = 0.961 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.062
# F1 = 0.600 vs. 0.089
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.337 vs. 0.105
# F1 = 0.410 vs. 0.183
# Precision = 0.343 vs. 0.101
# Recall = 0.509 vs. 0.939
# Minibatch Loss= 0.019996
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.067
# F1 = 0.994 vs. 0.101
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.928 vs. 0.166
# F1 = 0.919 vs. 0.295
# Precision = 0.860 vs. 0.174
# Recall = 0.987 vs. 0.967
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.062
# F1 = 0.599 vs. 0.089
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.335 vs. 0.106
# F1 = 0.410 vs. 0.183
# Precision = 0.378 vs. 0.102
# Recall = 0.449 vs. 0.897
# Minibatch Loss= 0.018006
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.068
# F1 = 0.991 vs. 0.103
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.198
# F1 = 0.926 vs. 0.303
# Precision = 0.875 vs. 0.178
# Recall = 0.982 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.567 vs. 0.061
# F1 = 0.597 vs. 0.092
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.338 vs. 0.104
# F1 = 0.410 vs. 0.182
# Precision = 0.361 vs. 0.101
# Recall = 0.475 vs. 0.902
# Minibatch Loss= 0.018023
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.966 vs. 0.067
# F1 = 0.935 vs. 0.102
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.845 vs. 0.183
# F1 = 0.771 vs. 0.315
# Precision = 0.746 vs. 0.187
# Recall = 0.798 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.570 vs. 0.062
# F1 = 0.598 vs. 0.088
# Accuracy = 0.828 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.092
# F1 = 0.428 vs. 0.181
# Precision = 0.326 vs. 0.100
# Recall = 0.620 vs. 1.000
# Minibatch Loss= 0.144437
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.067
# F1 = 0.954 vs. 0.097
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.851 vs. 0.181
# F1 = 0.789 vs. 0.281
# Precision = 0.732 vs. 0.164
# Recall = 0.856 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.568 vs. 0.062
# F1 = 0.594 vs. 0.087
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.102
# F1 = 0.415 vs. 0.182
# Precision = 0.320 vs. 0.100
# Recall = 0.591 vs. 0.995
# Minibatch Loss= 0.054008
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.067
# F1 = 0.990 vs. 0.105
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.911 vs. 0.179
# F1 = 0.881 vs. 0.302
# Precision = 0.828 vs. 0.178
# Recall = 0.942 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.063
# F1 = 0.589 vs. 0.092
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.334 vs. 0.101
# F1 = 0.416 vs. 0.183
# Precision = 0.395 vs. 0.101
# Recall = 0.441 vs. 0.992
# Minibatch Loss= 0.024948
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.069
# F1 = 0.990 vs. 0.104
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.946 vs. 0.186
# F1 = 0.909 vs. 0.303
# Precision = 0.850 vs. 0.179
# Recall = 0.977 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.062
# F1 = 0.586 vs. 0.085
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.330 vs. 0.103
# F1 = 0.411 vs. 0.182
# Precision = 0.354 vs. 0.100
# Recall = 0.488 vs. 0.987
# Minibatch Loss= 0.021699
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.069
# F1 = 0.993 vs. 0.105
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.944 vs. 0.153
# F1 = 0.915 vs. 0.280
# Precision = 0.869 vs. 0.163
# Recall = 0.967 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.062
# F1 = 0.582 vs. 0.088
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.323 vs. 0.098
# F1 = 0.397 vs. 0.182
# Precision = 0.342 vs. 0.100
# Recall = 0.472 vs. 1.000
# Minibatch Loss= 0.018279
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.068
# F1 = 0.990 vs. 0.104
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.919 vs. 0.159
# F1 = 0.912 vs. 0.268
# Precision = 0.858 vs. 0.155
# Recall = 0.972 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.558 vs. 0.062
# F1 = 0.581 vs. 0.087
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.324 vs. 0.103
# F1 = 0.398 vs. 0.185
# Precision = 0.288 vs. 0.105
# Recall = 0.644 vs. 0.813
# Minibatch Loss= 0.018230
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.067
# F1 = 0.994 vs. 0.100
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.185
# F1 = 0.936 vs. 0.317
# Precision = 0.894 vs. 0.188
# Recall = 0.982 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.557 vs. 0.063
# F1 = 0.579 vs. 0.090
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.096
# F1 = 0.398 vs. 0.184
# Precision = 0.288 vs. 0.102
# Recall = 0.646 vs. 0.955
# Minibatch Loss= 0.018227
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.068
# F1 = 0.993 vs. 0.104
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.950 vs. 0.169
# F1 = 0.940 vs. 0.274
# Precision = 0.897 vs. 0.160
# Recall = 0.987 vs. 0.963
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.555 vs. 0.061
# F1 = 0.575 vs. 0.082
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.096
# F1 = 0.402 vs. 0.181
# Precision = 0.294 vs. 0.100
# Recall = 0.639 vs. 1.000
# Minibatch Loss= 0.014887
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.068
# F1 = 0.993 vs. 0.104
# Accuracy = 0.988 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.170
# F1 = 0.941 vs. 0.291
# Precision = 0.905 vs. 0.172
# Recall = 0.980 vs. 0.926
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.061
# F1 = 0.580 vs. 0.082
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.321 vs. 0.104
# F1 = 0.404 vs. 0.183
# Precision = 0.288 vs. 0.101
# Recall = 0.673 vs. 0.984
# Minibatch Loss= 0.014464
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.069
# F1 = 0.996 vs. 0.102
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.174
# F1 = 0.954 vs. 0.295
# Precision = 0.927 vs. 0.173
# Recall = 0.984 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.553 vs. 0.062
# F1 = 0.578 vs. 0.083
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.322 vs. 0.104
# F1 = 0.401 vs. 0.181
# Precision = 0.289 vs. 0.100
# Recall = 0.657 vs. 1.000
# Minibatch Loss= 0.012687
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.069
# F1 = 0.996 vs. 0.110
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.182
# F1 = 0.968 vs. 0.318
# Precision = 0.945 vs. 0.189
# Recall = 0.992 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.063
# F1 = 0.578 vs. 0.088
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.110
# F1 = 0.394 vs. 0.184
# Precision = 0.289 vs. 0.104
# Recall = 0.617 vs. 0.799
# Minibatch Loss= 0.012623
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.066
# F1 = 0.993 vs. 0.099
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.971 vs. 0.187
# F1 = 0.954 vs. 0.312
# Precision = 0.921 vs. 0.186
# Recall = 0.990 vs. 0.947
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.546 vs. 0.063
# F1 = 0.576 vs. 0.090
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.320 vs. 0.099
# F1 = 0.399 vs. 0.182
# Precision = 0.299 vs. 0.101
# Recall = 0.599 vs. 0.968
# Minibatch Loss= 0.013362
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.066
# F1 = 0.997 vs. 0.102
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.153
# F1 = 0.956 vs. 0.275
# Precision = 0.928 vs. 0.160
# Recall = 0.986 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.545 vs. 0.062
# F1 = 0.572 vs. 0.083
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.313 vs. 0.108
# F1 = 0.388 vs. 0.182
# Precision = 0.312 vs. 0.101
# Recall = 0.512 vs. 0.876
# Minibatch Loss= 0.011629
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.998 vs. 0.101
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.183
# F1 = 0.974 vs. 0.299
# Precision = 0.952 vs. 0.176
# Recall = 0.996 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.549 vs. 0.062
# F1 = 0.577 vs. 0.089
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.317 vs. 0.103
# F1 = 0.396 vs. 0.184
# Precision = 0.292 vs. 0.102
# Recall = 0.615 vs. 0.968
# Minibatch Loss= 0.009063
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.069
# F1 = 0.995 vs. 0.107
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.199
# F1 = 0.966 vs. 0.335
# Precision = 0.936 vs. 0.201
# Recall = 0.998 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.062
# F1 = 0.577 vs. 0.086
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.319 vs. 0.099
# F1 = 0.398 vs. 0.184
# Precision = 0.297 vs. 0.102
# Recall = 0.604 vs. 0.923
# Minibatch Loss= 0.012303
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.063
# F1 = 0.998 vs. 0.098
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.984 vs. 0.154
# F1 = 0.979 vs. 0.257
# Precision = 0.968 vs. 0.152
# Recall = 0.991 vs. 0.833
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.542 vs. 0.063
# F1 = 0.572 vs. 0.092
# Accuracy = 0.889 vs. 0.056
# CHANGE DETECTION
# AUC = 0.315 vs. 0.102
# F1 = 0.398 vs. 0.182
# Precision = 0.293 vs. 0.100
# Recall = 0.620 vs. 0.989
# Minibatch Loss= 0.007218
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.067
# F1 = 0.996 vs. 0.105
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.977 vs. 0.170
# F1 = 0.943 vs. 0.293
# Precision = 0.913 vs. 0.172
# Recall = 0.975 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.544 vs. 0.062
# F1 = 0.581 vs. 0.089
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.310 vs. 0.095
# F1 = 0.403 vs. 0.181
# Precision = 0.292 vs. 0.100
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 0.020321
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.911 vs. 0.067
# F1 = 0.854 vs. 0.105
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.731 vs. 0.177
# F1 = 0.699 vs. 0.299
# Precision = 0.608 vs. 0.177
# Recall = 0.823 vs. 0.966
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.562 vs. 0.062
# F1 = 0.588 vs. 0.089
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.362 vs. 0.098
# F1 = 0.430 vs. 0.182
# Precision = 0.397 vs. 0.101
# Recall = 0.470 vs. 0.923
# Minibatch Loss= 0.116604
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.964 vs. 0.069
# F1 = 0.930 vs. 0.103
# Accuracy = 0.935 vs. 0.056
# CHANGE DETECTION
# AUC = 0.870 vs. 0.209
# F1 = 0.794 vs. 0.320
# Precision = 0.744 vs. 0.191
# Recall = 0.852 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.569 vs. 0.063
# F1 = 0.587 vs. 0.091
# Accuracy = 0.847 vs. 0.056
# CHANGE DETECTION
# AUC = 0.371 vs. 0.094
# F1 = 0.451 vs. 0.182
# Precision = 0.357 vs. 0.101
# Recall = 0.612 vs. 0.955
# Minibatch Loss= 0.066441
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.972 vs. 0.067
# F1 = 0.948 vs. 0.101
# Accuracy = 0.951 vs. 0.056
# CHANGE DETECTION
# AUC = 0.863 vs. 0.169
# F1 = 0.810 vs. 0.291
# Precision = 0.719 vs. 0.171
# Recall = 0.926 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.061
# F1 = 0.591 vs. 0.089
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.378 vs. 0.102
# F1 = 0.460 vs. 0.182
# Precision = 0.356 vs. 0.100
# Recall = 0.649 vs. 0.989
# Minibatch Loss= 0.048338
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.965 vs. 0.067
# F1 = 0.948 vs. 0.103
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.872 vs. 0.170
# F1 = 0.822 vs. 0.288
# Precision = 0.787 vs. 0.168
# Recall = 0.860 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.063
# F1 = 0.592 vs. 0.087
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.098
# F1 = 0.449 vs. 0.183
# Precision = 0.360 vs. 0.102
# Recall = 0.596 vs. 0.947
# Minibatch Loss= 0.047500
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.978 vs. 0.069
# F1 = 0.963 vs. 0.108
# Accuracy = 0.931 vs. 0.056
# CHANGE DETECTION
# AUC = 0.889 vs. 0.206
# F1 = 0.855 vs. 0.334
# Precision = 0.791 vs. 0.200
# Recall = 0.930 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.062
# F1 = 0.590 vs. 0.088
# Accuracy = 0.871 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.101
# F1 = 0.456 vs. 0.183
# Precision = 0.410 vs. 0.101
# Recall = 0.515 vs. 0.976
# Minibatch Loss= 0.049464
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.067
# F1 = 0.963 vs. 0.100
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.928 vs. 0.201
# F1 = 0.872 vs. 0.319
# Precision = 0.820 vs. 0.190
# Recall = 0.930 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.571 vs. 0.062
# F1 = 0.586 vs. 0.091
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.380 vs. 0.096
# F1 = 0.456 vs. 0.184
# Precision = 0.412 vs. 0.102
# Recall = 0.512 vs. 0.934
# Minibatch Loss= 0.036709
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.066
# F1 = 0.974 vs. 0.099
# Accuracy = 0.959 vs. 0.056
# CHANGE DETECTION
# AUC = 0.898 vs. 0.150
# F1 = 0.850 vs. 0.274
# Precision = 0.796 vs. 0.159
# Recall = 0.912 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.062
# F1 = 0.590 vs. 0.087
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.376 vs. 0.100
# F1 = 0.456 vs. 0.186
# Precision = 0.402 vs. 0.105
# Recall = 0.528 vs. 0.860
# Minibatch Loss= 0.034465
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.988 vs. 0.068
# F1 = 0.976 vs. 0.101
# Accuracy = 0.967 vs. 0.056
# CHANGE DETECTION
# AUC = 0.929 vs. 0.186
# F1 = 0.879 vs. 0.307
# Precision = 0.857 vs. 0.182
# Recall = 0.903 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.584 vs. 0.062
# F1 = 0.591 vs. 0.084
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.373 vs. 0.105
# F1 = 0.461 vs. 0.182
# Precision = 0.411 vs. 0.101
# Recall = 0.525 vs. 0.918
# Minibatch Loss= 0.033998
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.069
# F1 = 0.986 vs. 0.105
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.930 vs. 0.193
# F1 = 0.898 vs. 0.325
# Precision = 0.867 vs. 0.194
# Recall = 0.932 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.582 vs. 0.062
# F1 = 0.588 vs. 0.090
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.371 vs. 0.110
# F1 = 0.453 vs. 0.187
# Precision = 0.371 vs. 0.105
# Recall = 0.580 vs. 0.834
# Minibatch Loss= 0.029433
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.068
# F1 = 0.991 vs. 0.101
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.947 vs. 0.186
# F1 = 0.902 vs. 0.310
# Precision = 0.869 vs. 0.186
# Recall = 0.938 vs. 0.943
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.061
# F1 = 0.592 vs. 0.084
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.369 vs. 0.092
# F1 = 0.453 vs. 0.182
# Precision = 0.380 vs. 0.100
# Recall = 0.562 vs. 0.976
# Minibatch Loss= 0.025061
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.993 vs. 0.067
# F1 = 0.984 vs. 0.103
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.947 vs. 0.168
# F1 = 0.923 vs. 0.284
# Precision = 0.877 vs. 0.166
# Recall = 0.973 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.062
# F1 = 0.594 vs. 0.090
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.367 vs. 0.104
# F1 = 0.456 vs. 0.182
# Precision = 0.415 vs. 0.100
# Recall = 0.507 vs. 0.987
# Minibatch Loss= 0.022994
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.068
# F1 = 0.989 vs. 0.098
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.945 vs. 0.166
# F1 = 0.915 vs. 0.299
# Precision = 0.868 vs. 0.177
# Recall = 0.967 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.062
# F1 = 0.597 vs. 0.086
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.366 vs. 0.101
# F1 = 0.457 vs. 0.182
# Precision = 0.418 vs. 0.101
# Recall = 0.504 vs. 0.963
# Minibatch Loss= 0.021918
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.067
# F1 = 0.987 vs. 0.103
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.187
# F1 = 0.919 vs. 0.316
# Precision = 0.874 vs. 0.188
# Recall = 0.968 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.063
# F1 = 0.601 vs. 0.089
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# ...
# Precision = 0.408 vs. 0.101
# Recall = 0.546 vs. 0.979
# Minibatch Loss= 0.043364
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.976 vs. 0.066
# F1 = 0.965 vs. 0.099
# Accuracy = 0.955 vs. 0.056
# CHANGE DETECTION
# AUC = 0.898 vs. 0.190
# F1 = 0.840 vs. 0.302
# Precision = 0.766 vs. 0.178
# Recall = 0.929 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.062
# F1 = 0.599 vs. 0.086
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.092
# F1 = 0.465 vs. 0.184
# Precision = 0.392 vs. 0.102
# Recall = 0.573 vs. 0.950
# Minibatch Loss= 0.036533
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.068
# F1 = 0.979 vs. 0.102
# Accuracy = 0.962 vs. 0.056
# CHANGE DETECTION
# AUC = 0.920 vs. 0.188
# F1 = 0.862 vs. 0.319
# Precision = 0.831 vs. 0.189
# Recall = 0.894 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.586 vs. 0.061
# F1 = 0.601 vs. 0.084
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.398 vs. 0.096
# F1 = 0.465 vs. 0.182
# Precision = 0.408 vs. 0.101
# Recall = 0.541 vs. 0.968
# Minibatch Loss= 0.034286
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.068
# F1 = 0.978 vs. 0.104
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.894 vs. 0.190
# F1 = 0.826 vs. 0.309
# Precision = 0.779 vs. 0.183
# Recall = 0.880 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.063
# F1 = 0.602 vs. 0.093
# Accuracy = 0.873 vs. 0.056
# CHANGE DETECTION
# AUC = 0.399 vs. 0.104
# F1 = 0.466 vs. 0.182
# Precision = 0.396 vs. 0.100
# Recall = 0.565 vs. 0.997
# Minibatch Loss= 0.037600
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.067
# F1 = 0.973 vs. 0.100
# Accuracy = 0.971 vs. 0.056
# CHANGE DETECTION
# AUC = 0.891 vs. 0.174
# F1 = 0.842 vs. 0.290
# Precision = 0.773 vs. 0.170
# Recall = 0.924 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.063
# F1 = 0.598 vs. 0.092
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.094
# F1 = 0.465 vs. 0.181
# Precision = 0.405 vs. 0.100
# Recall = 0.546 vs. 1.000
# Minibatch Loss= 0.035835
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.068
# F1 = 0.980 vs. 0.101
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.906 vs. 0.170
# F1 = 0.861 vs. 0.299
# Precision = 0.816 vs. 0.176
# Recall = 0.911 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.062
# F1 = 0.600 vs. 0.089
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.101
# F1 = 0.465 vs. 0.183
# Precision = 0.386 vs. 0.103
# Recall = 0.586 vs. 0.834
# Minibatch Loss= 0.032913
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.069
# F1 = 0.978 vs. 0.102
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.925 vs. 0.168
# F1 = 0.882 vs. 0.289
# Precision = 0.839 vs. 0.169
# Recall = 0.931 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.062
# F1 = 0.605 vs. 0.089
# Accuracy = 0.878 vs. 0.056
# CHANGE DETECTION
# AUC = 0.395 vs. 0.107
# F1 = 0.466 vs. 0.182
# Precision = 0.392 vs. 0.100
# Recall = 0.573 vs. 0.968
# Minibatch Loss= 0.029711
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.066
# F1 = 0.981 vs. 0.100
# Accuracy = 0.961 vs. 0.056
# CHANGE DETECTION
# AUC = 0.925 vs. 0.173
# F1 = 0.869 vs. 0.297
# Precision = 0.808 vs. 0.175
# Recall = 0.939 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.063
# F1 = 0.603 vs. 0.092
# Accuracy = 0.876 vs. 0.056
# CHANGE DETECTION
# AUC = 0.399 vs. 0.111
# F1 = 0.466 vs. 0.186
# Precision = 0.381 vs. 0.107
# Recall = 0.599 vs. 0.699
# Minibatch Loss= 0.030496
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.069
# F1 = 0.976 vs. 0.108
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.890 vs. 0.195
# F1 = 0.836 vs. 0.316
# Precision = 0.760 vs. 0.187
# Recall = 0.930 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.063
# F1 = 0.604 vs. 0.089
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.105
# F1 = 0.465 vs. 0.181
# Precision = 0.406 vs. 0.100
# Recall = 0.544 vs. 0.995
# Minibatch Loss= 0.036562
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.068
# F1 = 0.979 vs. 0.100
# Accuracy = 0.960 vs. 0.056
# CHANGE DETECTION
# AUC = 0.908 vs. 0.178
# F1 = 0.864 vs. 0.309
# Precision = 0.817 vs. 0.182
# Recall = 0.916 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.063
# F1 = 0.604 vs. 0.092
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.096
# F1 = 0.464 vs. 0.183
# Precision = 0.388 vs. 0.102
# Recall = 0.578 vs. 0.910
# Minibatch Loss= 0.032916
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.068
# F1 = 0.978 vs. 0.105
# Accuracy = 0.965 vs. 0.056
# CHANGE DETECTION
# AUC = 0.905 vs. 0.189
# F1 = 0.853 vs. 0.331
# Precision = 0.789 vs. 0.199
# Recall = 0.927 vs. 0.976
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.591 vs. 0.063
# F1 = 0.605 vs. 0.091
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.104
# F1 = 0.465 vs. 0.185
# Precision = 0.367 vs. 0.102
# Recall = 0.636 vs. 0.974
# Minibatch Loss= 0.036016
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.066
# F1 = 0.978 vs. 0.101
# Accuracy = 0.962 vs. 0.056
# CHANGE DETECTION
# AUC = 0.914 vs. 0.167
# F1 = 0.850 vs. 0.283
# Precision = 0.783 vs. 0.165
# Recall = 0.930 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.063
# F1 = 0.605 vs. 0.088
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.100
# F1 = 0.466 vs. 0.183
# Precision = 0.369 vs. 0.102
# Recall = 0.633 vs. 0.929
# Minibatch Loss= 0.030900
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.066
# F1 = 0.981 vs. 0.101
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.916 vs. 0.191
# F1 = 0.871 vs. 0.310
# Precision = 0.814 vs. 0.183
# Recall = 0.937 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.063
# F1 = 0.605 vs. 0.085
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.400 vs. 0.098
# F1 = 0.470 vs. 0.182
# Precision = 0.402 vs. 0.100
# Recall = 0.567 vs. 1.000
# Minibatch Loss= 0.031720
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.066
# F1 = 0.985 vs. 0.098
# Accuracy = 0.962 vs. 0.056
# CHANGE DETECTION
# AUC = 0.907 vs. 0.155
# F1 = 0.864 vs. 0.265
# Precision = 0.797 vs. 0.155
# Recall = 0.943 vs. 0.941
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.064
# F1 = 0.608 vs. 0.092
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.399 vs. 0.104
# F1 = 0.468 vs. 0.182
# Precision = 0.399 vs. 0.100
# Recall = 0.567 vs. 1.000
# Minibatch Loss= 0.026710
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.068
# F1 = 0.982 vs. 0.103
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.156
# F1 = 0.870 vs. 0.279
# Precision = 0.804 vs. 0.162
# Recall = 0.949 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.062
# F1 = 0.607 vs. 0.087
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.098
# F1 = 0.469 vs. 0.183
# Precision = 0.373 vs. 0.101
# Recall = 0.631 vs. 0.945
# Minibatch Loss= 0.025597
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.068
# F1 = 0.985 vs. 0.103
# Accuracy = 0.977 vs. 0.056
# CHANGE DETECTION
# AUC = 0.929 vs. 0.187
# F1 = 0.879 vs. 0.315
# Precision = 0.828 vs. 0.187
# Recall = 0.938 vs. 0.997
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.064
# F1 = 0.591 vs. 0.091
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.393 vs. 0.093
# F1 = 0.465 vs. 0.183
# Precision = 0.366 vs. 0.100
# Recall = 0.636 vs. 1.000
# Minibatch Loss= 0.028221
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.072
# F1 = 0.979 vs. 0.111
# Accuracy = 0.940 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.230
# F1 = 0.881 vs. 0.380
# Precision = 0.822 vs. 0.235
# Recall = 0.948 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.063
# F1 = 0.614 vs. 0.089
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.396 vs. 0.092
# F1 = 0.474 vs. 0.182
# Precision = 0.390 vs. 0.100
# Recall = 0.602 vs. 1.000
# Minibatch Loss= 0.038127
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.987 vs. 0.065
# F1 = 0.984 vs. 0.097
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.926 vs. 0.154
# F1 = 0.879 vs. 0.262
# Precision = 0.827 vs. 0.151
# Recall = 0.937 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.063
# F1 = 0.610 vs. 0.089
# Accuracy = 0.883 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.102
# F1 = 0.465 vs. 0.182
# Precision = 0.374 vs. 0.100
# Recall = 0.615 vs. 0.995
# Minibatch Loss= 0.024167
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.990 vs. 0.066
# F1 = 0.987 vs. 0.099
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.926 vs. 0.158
# F1 = 0.874 vs. 0.268
# Precision = 0.816 vs. 0.156
# Recall = 0.941 vs. 0.969
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.063
# F1 = 0.612 vs. 0.088
# Accuracy = 0.891 vs. 0.056
# CHANGE DETECTION
# AUC = 0.397 vs. 0.103
# F1 = 0.476 vs. 0.183
# Precision = 0.387 vs. 0.102
# Recall = 0.617 vs. 0.910
# Minibatch Loss= 0.023902
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.067
# F1 = 0.985 vs. 0.100
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.928 vs. 0.157
# F1 = 0.884 vs. 0.281
# Precision = 0.835 vs. 0.164
# Recall = 0.940 vs. 0.979
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.591 vs. 0.061
# F1 = 0.606 vs. 0.085
# Accuracy = 0.881 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.105
# F1 = 0.464 vs. 0.186
# Precision = 0.388 vs. 0.104
# Recall = 0.578 vs. 0.887
# Minibatch Loss= 0.024979
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.066
# F1 = 0.988 vs. 0.097
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.921 vs. 0.157
# F1 = 0.880 vs. 0.275
# Precision = 0.843 vs. 0.162
# Recall = 0.919 vs. 0.912
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.062
# F1 = 0.605 vs. 0.090
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.395 vs. 0.097
# F1 = 0.475 vs. 0.182
# Precision = 0.384 vs. 0.100
# Recall = 0.623 vs. 0.987
# Minibatch Loss= 0.024000
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.068
# F1 = 0.986 vs. 0.103
# Accuracy = 0.947 vs. 0.056
# CHANGE DETECTION
# AUC = 0.934 vs. 0.184
# F1 = 0.880 vs. 0.296
# Precision = 0.859 vs. 0.173
# Recall = 0.901 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.589 vs. 0.062
# F1 = 0.607 vs. 0.087
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.381 vs. 0.109
# F1 = 0.456 vs. 0.183
# Precision = 0.366 vs. 0.102
# Recall = 0.604 vs. 0.934
# Minibatch Loss= 0.028517
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.066
# F1 = 0.986 vs. 0.100
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.925 vs. 0.169
# F1 = 0.890 vs. 0.281
# Precision = 0.845 vs. 0.164
# Recall = 0.940 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.063
# F1 = 0.606 vs. 0.087
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.388 vs. 0.099
# F1 = 0.464 vs. 0.184
# Precision = 0.381 vs. 0.102
# Recall = 0.594 vs. 0.934
# Minibatch Loss= 0.024674
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.068
# F1 = 0.988 vs. 0.102
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.931 vs. 0.169
# F1 = 0.889 vs. 0.304
# Precision = 0.850 vs. 0.180
# Recall = 0.932 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.062
# F1 = 0.605 vs. 0.087
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.390 vs. 0.103
# F1 = 0.467 vs. 0.181
# Precision = 0.386 vs. 0.100
# Recall = 0.588 vs. 1.000
# Minibatch Loss= 0.024636
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.072
# F1 = 0.988 vs. 0.111
# Accuracy = 0.968 vs. 0.056
# CHANGE DETECTION
# AUC = 0.949 vs. 0.192
# F1 = 0.908 vs. 0.318
# Precision = 0.869 vs. 0.189
# Recall = 0.952 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.063
# F1 = 0.610 vs. 0.092
# Accuracy = 0.886 vs. 0.056
# CHANGE DETECTION
# AUC = 0.388 vs. 0.096
# F1 = 0.462 vs. 0.183
# Precision = 0.373 vs. 0.101
# Recall = 0.607 vs. 0.966
# Minibatch Loss= 0.023635
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.071
# F1 = 0.987 vs. 0.108
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.948 vs. 0.193
# F1 = 0.908 vs. 0.322
# Precision = 0.870 vs. 0.192
# Recall = 0.949 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.063
# F1 = 0.606 vs. 0.090
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.096
# F1 = 0.463 vs. 0.183
# Precision = 0.379 vs. 0.104
# Recall = 0.596 vs. 0.770
# Minibatch Loss= 0.024824
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.065
# F1 = 0.992 vs. 0.098
# Accuracy = 0.978 vs. 0.056
# CHANGE DETECTION
# AUC = 0.941 vs. 0.159
# F1 = 0.900 vs. 0.291
# Precision = 0.862 vs. 0.171
# Recall = 0.941 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.062
# F1 = 0.606 vs. 0.088
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.389 vs. 0.094
# F1 = 0.461 vs. 0.184
# Precision = 0.381 vs. 0.102
# Recall = 0.583 vs. 0.934
# Minibatch Loss= 0.021492
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.067
# F1 = 0.992 vs. 0.104
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.965 vs. 0.207
# F1 = 0.927 vs. 0.321
# Precision = 0.900 vs. 0.193
# Recall = 0.957 vs. 0.949
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.062
# F1 = 0.605 vs. 0.088
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.387 vs. 0.106
# F1 = 0.457 vs. 0.184
# Precision = 0.376 vs. 0.104
# Recall = 0.583 vs. 0.834
# Minibatch Loss= 0.020734
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.995 vs. 0.067
# F1 = 0.990 vs. 0.099
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.955 vs. 0.207
# F1 = 0.922 vs. 0.320
# Precision = 0.872 vs. 0.192
# Recall = 0.978 vs. 0.972
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.062
# F1 = 0.604 vs. 0.085
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.102
# F1 = 0.459 vs. 0.183
# Precision = 0.374 vs. 0.101
# Recall = 0.594 vs. 0.992
# Minibatch Loss= 0.021814
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.069
# F1 = 0.989 vs. 0.105
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.966 vs. 0.211
# F1 = 0.917 vs. 0.338
# Precision = 0.902 vs. 0.206
# Recall = 0.932 vs. 0.950
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.062
# F1 = 0.603 vs. 0.091
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.394 vs. 0.104
# F1 = 0.459 vs. 0.181
# Precision = 0.379 vs. 0.105
# Recall = 0.580 vs. 0.670
# Minibatch Loss= 0.022851
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.067
# F1 = 0.992 vs. 0.098
# Accuracy = 0.984 vs. 0.056
# CHANGE DETECTION
# AUC = 0.968 vs. 0.164
# F1 = 0.926 vs. 0.267
# Precision = 0.894 vs. 0.154
# Recall = 0.959 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.062
# F1 = 0.605 vs. 0.088
# Accuracy = 0.887 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.111
# F1 = 0.450 vs. 0.186
# Precision = 0.358 vs. 0.109
# Recall = 0.607 vs. 0.639
# Minibatch Loss= 0.017261
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.069
# F1 = 0.993 vs. 0.104
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.946 vs. 0.165
# F1 = 0.914 vs. 0.278
# Precision = 0.858 vs. 0.162
# Recall = 0.977 vs. 0.986
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.063
# F1 = 0.603 vs. 0.086
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.100
# F1 = 0.456 vs. 0.184
# Precision = 0.376 vs. 0.102
# Recall = 0.580 vs. 0.955
# Minibatch Loss= 0.017967
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.067
# F1 = 0.991 vs. 0.099
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.957 vs. 0.167
# F1 = 0.926 vs. 0.294
# Precision = 0.888 vs. 0.172
# Recall = 0.967 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.061
# F1 = 0.598 vs. 0.085
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.394 vs. 0.106
# F1 = 0.457 vs. 0.182
# Precision = 0.377 vs. 0.104
# Recall = 0.580 vs. 0.734
# Minibatch Loss= 0.019182
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.994 vs. 0.068
# F1 = 0.991 vs. 0.104
# Accuracy = 0.982 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.186
# F1 = 0.927 vs. 0.302
# Precision = 0.897 vs. 0.178
# Recall = 0.960 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.575 vs. 0.066
# F1 = 0.600 vs. 0.099
# Accuracy = 0.895 vs. 0.056
# CHANGE DETECTION
# AUC = 0.391 vs. 0.099
# F1 = 0.451 vs. 0.182
# Precision = 0.376 vs. 0.102
# Recall = 0.565 vs. 0.850
# Minibatch Loss= 0.019379
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.066
# F1 = 0.994 vs. 0.101
# Accuracy = 0.980 vs. 0.056
# CHANGE DETECTION
# AUC = 0.956 vs. 0.167
# F1 = 0.923 vs. 0.274
# Precision = 0.881 vs. 0.159
# Recall = 0.969 vs. 0.974
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.575 vs. 0.061
# F1 = 0.599 vs. 0.085
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.383 vs. 0.101
# F1 = 0.450 vs. 0.182
# Precision = 0.376 vs. 0.102
# Recall = 0.559 vs. 0.844
# Minibatch Loss= 0.017389
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/DWN_Wmultitask_32_opp/checkpoint-20000'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/DWN_activity_multitask_64_opp/checkpoint-20000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/DWN_activity_multitask_64_opp/checkpoint-20000

# %%
#This is the model evaluation on test dataset
result = nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.576 vs. 0.063
# F1 = 0.599 vs. 0.089
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.386 vs. 0.102
# F1 = 0.453 vs. 0.183
# Precision = 0.389 vs. 0.101
# Recall = 0.541 vs. 0.989

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(out, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
out.shape
# Out:
# (119, 32, 19)
