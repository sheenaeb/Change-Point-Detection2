# %%
# useing this variable for saving models and summaries
exp_name = "CNN_Wmultitask_16_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 2, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)


variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.36565482,  48.46756152,  47.65126513,  50.0669746 ,
#         49.94930876,  40.02411874,  41.52307692,  58.84303112,
#         63.4664723 ,  75.37996546,  86.74603175,  80.14495413,
#         87.27145709,  69.42038217,  68.86413902,  43.71587462,
#         13.05721551,  58.2021419 ,  10.05323669])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,
                     variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.059 vs. 0.060
# F1 = 0.093 vs. 0.091
# Accuracy = 0.055 vs. 0.056
# CHANGE DETECTION
# AUC = 0.092 vs. 0.085
# F1 = 0.161 vs. 0.158
# Precision = 0.088 vs. 0.086
# Recall = 0.936 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.058 vs. 0.059
# F1 = 0.079 vs. 0.080
# Accuracy = 0.056 vs. 0.056
# CHANGE DETECTION
# AUC = 0.053 vs. 0.052
# F1 = 0.106 vs. 0.097
# Precision = 0.058 vs. 0.051
# Recall = 0.608 vs. 1.000
# Minibatch Loss= 1.340462
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.425 vs. 0.062
# F1 = 0.488 vs. 0.091
# Accuracy = 0.552 vs. 0.056
# CHANGE DETECTION
# AUC = 0.241 vs. 0.092
# F1 = 0.347 vs. 0.168
# Precision = 0.240 vs. 0.093
# Recall = 0.627 vs. 0.868
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.317 vs. 0.059
# F1 = 0.405 vs. 0.085
# Accuracy = 0.587 vs. 0.056
# CHANGE DETECTION
# AUC = 0.187 vs. 0.053
# F1 = 0.277 vs. 0.098
# Precision = 0.180 vs. 0.051
# Recall = 0.603 vs. 0.956
# Minibatch Loss= 0.447942
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.580 vs. 0.062
# F1 = 0.595 vs. 0.093
# Accuracy = 0.780 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.092
# F1 = 0.414 vs. 0.178
# Precision = 0.300 vs. 0.098
# Recall = 0.670 vs. 0.957
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.420 vs. 0.059
# F1 = 0.485 vs. 0.084
# Accuracy = 0.737 vs. 0.056
# CHANGE DETECTION
# AUC = 0.191 vs. 0.051
# F1 = 0.263 vs. 0.097
# Precision = 0.244 vs. 0.051
# Recall = 0.286 vs. 0.956
# Minibatch Loss= 0.340049
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.642 vs. 0.060
# F1 = 0.659 vs. 0.091
# Accuracy = 0.730 vs. 0.056
# CHANGE DETECTION
# AUC = 0.398 vs. 0.096
# F1 = 0.451 vs. 0.172
# Precision = 0.365 vs. 0.094
# Recall = 0.590 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.463 vs. 0.058
# F1 = 0.518 vs. 0.079
# Accuracy = 0.732 vs. 0.056
# CHANGE DETECTION
# AUC = 0.202 vs. 0.052
# F1 = 0.280 vs. 0.099
# Precision = 0.244 vs. 0.057
# Recall = 0.330 vs. 0.387
# Minibatch Loss= 0.253739
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.695 vs. 0.061
# F1 = 0.690 vs. 0.091
# Accuracy = 0.789 vs. 0.056
# CHANGE DETECTION
# AUC = 0.426 vs. 0.085
# F1 = 0.443 vs. 0.163
# Precision = 0.381 vs. 0.088
# Recall = 0.530 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.501 vs. 0.058
# F1 = 0.544 vs. 0.078
# Accuracy = 0.778 vs. 0.056
# CHANGE DETECTION
# AUC = 0.206 vs. 0.051
# F1 = 0.285 vs. 0.099
# Precision = 0.229 vs. 0.052
# Recall = 0.377 vs. 0.914
# Minibatch Loss= 0.224246
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.693 vs. 0.060
# F1 = 0.691 vs. 0.086
# Accuracy = 0.808 vs. 0.056
# CHANGE DETECTION
# AUC = 0.425 vs. 0.069
# F1 = 0.456 vs. 0.137
# Precision = 0.377 vs. 0.075
# Recall = 0.577 vs. 0.870
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.521 vs. 0.059
# F1 = 0.553 vs. 0.080
# Accuracy = 0.767 vs. 0.056
# CHANGE DETECTION
# AUC = 0.212 vs. 0.051
# F1 = 0.292 vs. 0.103
# Precision = 0.219 vs. 0.055
# Recall = 0.439 vs. 0.777
# Minibatch Loss= 0.165450
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.710 vs. 0.060
# F1 = 0.707 vs. 0.089
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.400 vs. 0.077
# F1 = 0.466 vs. 0.144
# Precision = 0.357 vs. 0.078
# Recall = 0.670 vs. 0.957
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.537 vs. 0.059
# F1 = 0.560 vs. 0.080
# Accuracy = 0.788 vs. 0.056
# CHANGE DETECTION
# AUC = 0.226 vs. 0.051
# F1 = 0.314 vs. 0.099
# Precision = 0.258 vs. 0.052
# Recall = 0.403 vs. 0.925
# Minibatch Loss= 0.168211
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.782 vs. 0.065
# F1 = 0.753 vs. 0.097
# Accuracy = 0.832 vs. 0.056
# CHANGE DETECTION
# AUC = 0.474 vs. 0.115
# F1 = 0.512 vs. 0.187
# Precision = 0.452 vs. 0.106
# Recall = 0.591 vs. 0.804
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.548 vs. 0.060
# F1 = 0.574 vs. 0.083
# Accuracy = 0.823 vs. 0.056
# CHANGE DETECTION
# AUC = 0.233 vs. 0.052
# F1 = 0.330 vs. 0.097
# Precision = 0.274 vs. 0.051
# Recall = 0.413 vs. 1.000
# Minibatch Loss= 0.178497
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.787 vs. 0.062
# F1 = 0.766 vs. 0.092
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.479 vs. 0.091
# F1 = 0.506 vs. 0.165
# Precision = 0.413 vs. 0.090
# Recall = 0.653 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.550 vs. 0.058
# F1 = 0.581 vs. 0.079
# Accuracy = 0.833 vs. 0.056
# CHANGE DETECTION
# AUC = 0.238 vs. 0.053
# F1 = 0.309 vs. 0.101
# Precision = 0.231 vs. 0.056
# Recall = 0.470 vs. 0.556
# Minibatch Loss= 0.145785
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.832 vs. 0.063
# F1 = 0.802 vs. 0.097
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.546 vs. 0.100
# F1 = 0.576 vs. 0.183
# Precision = 0.496 vs. 0.101
# Recall = 0.688 vs. 0.938
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.556 vs. 0.059
# F1 = 0.587 vs. 0.079
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.238 vs. 0.052
# F1 = 0.321 vs. 0.098
# Precision = 0.252 vs. 0.055
# Recall = 0.442 vs. 0.436
# Minibatch Loss= 0.145583
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.823 vs. 0.063
# F1 = 0.795 vs. 0.094
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.526 vs. 0.099
# F1 = 0.550 vs. 0.180
# Precision = 0.464 vs. 0.101
# Recall = 0.676 vs. 0.855
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.563 vs. 0.059
# F1 = 0.593 vs. 0.080
# Accuracy = 0.818 vs. 0.056
# CHANGE DETECTION
# AUC = 0.245 vs. 0.048
# F1 = 0.319 vs. 0.096
# Precision = 0.265 vs. 0.051
# Recall = 0.403 vs. 1.000
# Minibatch Loss= 0.136753
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.839 vs. 0.062
# F1 = 0.801 vs. 0.092
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.545 vs. 0.100
# F1 = 0.579 vs. 0.171
# Precision = 0.509 vs. 0.094
# Recall = 0.672 vs. 0.918
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.565 vs. 0.059
# F1 = 0.596 vs. 0.080
# Accuracy = 0.829 vs. 0.056
# CHANGE DETECTION
# AUC = 0.249 vs. 0.052
# F1 = 0.329 vs. 0.099
# Precision = 0.243 vs. 0.052
# Recall = 0.509 vs. 0.948
# Minibatch Loss= 0.134136
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.875 vs. 0.062
# F1 = 0.829 vs. 0.094
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.565 vs. 0.089
# F1 = 0.588 vs. 0.168
# Precision = 0.493 vs. 0.092
# Recall = 0.728 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.574 vs. 0.059
# F1 = 0.599 vs. 0.080
# Accuracy = 0.802 vs. 0.056
# CHANGE DETECTION
# AUC = 0.252 vs. 0.053
# F1 = 0.325 vs. 0.096
# Precision = 0.303 vs. 0.051
# Recall = 0.351 vs. 1.000
# Minibatch Loss= 0.118466
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.820 vs. 0.062
# F1 = 0.798 vs. 0.089
# Accuracy = 0.880 vs. 0.056
# CHANGE DETECTION
# AUC = 0.504 vs. 0.084
# F1 = 0.540 vs. 0.149
# Precision = 0.463 vs. 0.080
# Recall = 0.647 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.578 vs. 0.059
# F1 = 0.604 vs. 0.084
# Accuracy = 0.827 vs. 0.056
# CHANGE DETECTION
# AUC = 0.258 vs. 0.053
# F1 = 0.329 vs. 0.098
# Precision = 0.281 vs. 0.052
# Recall = 0.395 vs. 0.745
# Minibatch Loss= 0.113652
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.857 vs. 0.060
# F1 = 0.826 vs. 0.089
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.548 vs. 0.104
# F1 = 0.569 vs. 0.172
# Precision = 0.464 vs. 0.094
# Recall = 0.735 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.582 vs. 0.059
# F1 = 0.606 vs. 0.083
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.052
# F1 = 0.343 vs. 0.101
# Precision = 0.278 vs. 0.057
# Recall = 0.447 vs. 0.470
# Minibatch Loss= 0.110975
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.873 vs. 0.064
# F1 = 0.845 vs. 0.095
# Accuracy = 0.869 vs. 0.056
# CHANGE DETECTION
# AUC = 0.595 vs. 0.109
# F1 = 0.607 vs. 0.195
# Precision = 0.525 vs. 0.111
# Recall = 0.720 vs. 0.804
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.059
# F1 = 0.613 vs. 0.082
# Accuracy = 0.819 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.051
# F1 = 0.339 vs. 0.100
# Precision = 0.278 vs. 0.054
# Recall = 0.434 vs. 0.608
# Minibatch Loss= 0.121756
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.841 vs. 0.061
# F1 = 0.821 vs. 0.088
# Accuracy = 0.885 vs. 0.056
# CHANGE DETECTION
# AUC = 0.553 vs. 0.086
# F1 = 0.560 vs. 0.159
# Precision = 0.488 vs. 0.086
# Recall = 0.658 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.058
# F1 = 0.608 vs. 0.078
# Accuracy = 0.836 vs. 0.056
# CHANGE DETECTION
# AUC = 0.265 vs. 0.051
# F1 = 0.341 vs. 0.099
# Precision = 0.275 vs. 0.053
# Recall = 0.449 vs. 0.805
# Minibatch Loss= 0.107295
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.861 vs. 0.062
# F1 = 0.832 vs. 0.092
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.562 vs. 0.093
# F1 = 0.583 vs. 0.176
# Precision = 0.480 vs. 0.096
# Recall = 0.740 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.060
# F1 = 0.611 vs. 0.082
# Accuracy = 0.842 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.057
# F1 = 0.348 vs. 0.106
# Precision = 0.313 vs. 0.063
# Recall = 0.392 vs. 0.338
# Minibatch Loss= 0.112301
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.849 vs. 0.060
# F1 = 0.839 vs. 0.087
# Accuracy = 0.882 vs. 0.056
# CHANGE DETECTION
# AUC = 0.547 vs. 0.087
# F1 = 0.570 vs. 0.157
# Precision = 0.524 vs. 0.088
# Recall = 0.627 vs. 0.720
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.059
# F1 = 0.612 vs. 0.082
# Accuracy = 0.813 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.051
# F1 = 0.336 vs. 0.097
# Precision = 0.282 vs. 0.051
# Recall = 0.416 vs. 1.000
# Minibatch Loss= 0.098769
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.914 vs. 0.061
# F1 = 0.878 vs. 0.089
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.617 vs. 0.082
# F1 = 0.626 vs. 0.149
# Precision = 0.542 vs. 0.081
# Recall = 0.740 vs. 0.975
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.059
# F1 = 0.613 vs. 0.078
# Accuracy = 0.829 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.050
# F1 = 0.332 vs. 0.097
# Precision = 0.256 vs. 0.051
# Recall = 0.470 vs. 0.974
# Minibatch Loss= 0.084749
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.911 vs. 0.061
# F1 = 0.876 vs. 0.091
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.608 vs. 0.096
# F1 = 0.628 vs. 0.167
# Precision = 0.541 vs. 0.091
# Recall = 0.748 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.059
# F1 = 0.616 vs. 0.082
# Accuracy = 0.856 vs. 0.056
# CHANGE DETECTION
# AUC = 0.269 vs. 0.048
# F1 = 0.339 vs. 0.097
# Precision = 0.276 vs. 0.051
# Recall = 0.439 vs. 0.979
# Minibatch Loss= 0.085004
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.903 vs. 0.062
# F1 = 0.873 vs. 0.094
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.570 vs. 0.088
# F1 = 0.592 vs. 0.159
# Precision = 0.517 vs. 0.086
# Recall = 0.693 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.594 vs. 0.059
# F1 = 0.610 vs. 0.082
# Accuracy = 0.831 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.053
# F1 = 0.339 vs. 0.098
# Precision = 0.262 vs. 0.052
# Recall = 0.481 vs. 0.956
# Minibatch Loss= 0.091724
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.891 vs. 0.062
# F1 = 0.868 vs. 0.092
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.601 vs. 0.108
# F1 = 0.627 vs. 0.187
# Precision = 0.559 vs. 0.105
# Recall = 0.715 vs. 0.816
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.058
# F1 = 0.614 vs. 0.080
# Accuracy = 0.849 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.046
# F1 = 0.337 vs. 0.096
# Precision = 0.273 vs. 0.051
# Recall = 0.442 vs. 0.953
# Minibatch Loss= 0.095981
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.921 vs. 0.063
# F1 = 0.885 vs. 0.095
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.623 vs. 0.101
# F1 = 0.628 vs. 0.189
# Precision = 0.527 vs. 0.105
# Recall = 0.776 vs. 0.956
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.058
# F1 = 0.619 vs. 0.081
# Accuracy = 0.851 vs. 0.056
# CHANGE DETECTION
# AUC = 0.267 vs. 0.051
# F1 = 0.343 vs. 0.097
# Precision = 0.291 vs. 0.051
# Recall = 0.418 vs. 0.990
# Minibatch Loss= 0.096118
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.888 vs. 0.060
# F1 = 0.870 vs. 0.088
# Accuracy = 0.907 vs. 0.056
# CHANGE DETECTION
# AUC = 0.625 vs. 0.092
# F1 = 0.636 vs. 0.160
# Precision = 0.610 vs. 0.098
# Recall = 0.665 vs. 0.443
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.059
# F1 = 0.617 vs. 0.082
# Accuracy = 0.841 vs. 0.056
# CHANGE DETECTION
# AUC = 0.264 vs. 0.049
# F1 = 0.337 vs. 0.098
# Precision = 0.254 vs. 0.052
# Recall = 0.504 vs. 0.935
# Minibatch Loss= 0.075347
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.929 vs. 0.062
# F1 = 0.902 vs. 0.091
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.662 vs. 0.085
# F1 = 0.659 vs. 0.166
# Precision = 0.597 vs. 0.090
# Recall = 0.735 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.059
# F1 = 0.619 vs. 0.082
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.051
# F1 = 0.333 vs. 0.097
# Precision = 0.282 vs. 0.052
# Recall = 0.405 vs. 0.803
# Minibatch Loss= 0.073177
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.929 vs. 0.062
# F1 = 0.904 vs. 0.092
# Accuracy = 0.941 vs. 0.056
# CHANGE DETECTION
# AUC = 0.659 vs. 0.102
# F1 = 0.673 vs. 0.174
# Precision = 0.626 vs. 0.095
# Recall = 0.728 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.059
# F1 = 0.618 vs. 0.084
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.262 vs. 0.054
# F1 = 0.337 vs. 0.099
# Precision = 0.265 vs. 0.052
# Recall = 0.465 vs. 0.881
# Minibatch Loss= 0.068766
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.922 vs. 0.063
# F1 = 0.904 vs. 0.094
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.649 vs. 0.100
# F1 = 0.658 vs. 0.185
# Precision = 0.560 vs. 0.108
# Recall = 0.796 vs. 0.641
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.059
# F1 = 0.622 vs. 0.078
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.261 vs. 0.056
# F1 = 0.341 vs. 0.102
# Precision = 0.256 vs. 0.056
# Recall = 0.512 vs. 0.584
# Minibatch Loss= 0.080496
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.941 vs. 0.062
# F1 = 0.911 vs. 0.091
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.639 vs. 0.090
# F1 = 0.662 vs. 0.166
# Precision = 0.590 vs. 0.091
# Recall = 0.753 vs. 0.928
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.058
# F1 = 0.620 vs. 0.077
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.258 vs. 0.046
# F1 = 0.336 vs. 0.099
# Precision = 0.334 vs. 0.052
# Recall = 0.338 vs. 0.935
# Minibatch Loss= 0.067483
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.933 vs. 0.061
# F1 = 0.913 vs. 0.094
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.658 vs. 0.101
# F1 = 0.672 vs. 0.185
# Precision = 0.619 vs. 0.102
# Recall = 0.736 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.059
# F1 = 0.620 vs. 0.079
# Accuracy = 0.865 vs. 0.056
# CHANGE DETECTION
# AUC = 0.264 vs. 0.052
# F1 = 0.338 vs. 0.098
# Precision = 0.259 vs. 0.052
# Recall = 0.488 vs. 0.896
# Minibatch Loss= 0.073115
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.930 vs. 0.061
# F1 = 0.912 vs. 0.093
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.714 vs. 0.104
# F1 = 0.702 vs. 0.192
# Precision = 0.645 vs. 0.107
# Recall = 0.770 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.059
# F1 = 0.617 vs. 0.081
# Accuracy = 0.868 vs. 0.056
# CHANGE DETECTION
# AUC = 0.256 vs. 0.054
# F1 = 0.335 vs. 0.098
# Precision = 0.324 vs. 0.053
# Recall = 0.348 vs. 0.673
# Minibatch Loss= 0.068111
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.944 vs. 0.064
# F1 = 0.919 vs. 0.094
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.682 vs. 0.101
# F1 = 0.668 vs. 0.180
# Precision = 0.583 vs. 0.099
# Recall = 0.780 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.058
# F1 = 0.621 vs. 0.078
# Accuracy = 0.862 vs. 0.056
# CHANGE DETECTION
# AUC = 0.260 vs. 0.046
# F1 = 0.342 vs. 0.096
# Precision = 0.303 vs. 0.051
# Recall = 0.392 vs. 1.000
# Minibatch Loss= 0.068750
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.940 vs. 0.061
# F1 = 0.913 vs. 0.091
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.685 vs. 0.091
# F1 = 0.667 vs. 0.166
# Precision = 0.549 vs. 0.091
# Recall = 0.848 vs. 0.925
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.059
# F1 = 0.624 vs. 0.084
# Accuracy = 0.866 vs. 0.056
# CHANGE DETECTION
# AUC = 0.263 vs. 0.051
# F1 = 0.341 vs. 0.097
# Precision = 0.351 vs. 0.051
# Recall = 0.332 vs. 0.891
# Minibatch Loss= 0.068013
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.948 vs. 0.063
# F1 = 0.926 vs. 0.093
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.711 vs. 0.108
# F1 = 0.704 vs. 0.180
# Precision = 0.607 vs. 0.099
# Recall = 0.840 vs. 0.981
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.059
# F1 = 0.622 vs. 0.080
# Accuracy = 0.867 vs. 0.056
# CHANGE DETECTION
# AUC = 0.261 vs. 0.054
# F1 = 0.342 vs. 0.103
# Precision = 0.331 vs. 0.059
# Recall = 0.353 vs. 0.384
# Minibatch Loss= 0.063989
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.936 vs. 0.061
# F1 = 0.915 vs. 0.090
# Accuracy = 0.906 vs. 0.056
# CHANGE DETECTION
# AUC = 0.699 vs. 0.087
# F1 = 0.679 vs. 0.163
# Precision = 0.600 vs. 0.089
# Recall = 0.783 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.058
# F1 = 0.624 vs. 0.078
# Accuracy = 0.861 vs. 0.056
# CHANGE DETECTION
# AUC = 0.261 vs. 0.054
# F1 = 0.345 vs. 0.101
# Precision = 0.273 vs. 0.056
# Recall = 0.470 vs. 0.577
# Minibatch Loss= 0.062821

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN_activity_multitask_64_opp/CNN_activity_multitask_64_opp-20000')

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})

# %%
1
