# %%
# useing this variable for saving models and summaries
exp_name = "CNN_activity_Wmultitask_64_opp"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import hickle 

import sys
sys.path.append('../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval_multitask as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../data/opp8.hkl'
with open(data_path, 'r') as fin:
    data = hickle.load(fin)

# %%
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = data['train_gt']
validation_gt = data['validation_gt']
test_gt = data['test_gt']

# %%
train_data.shape, train_gt.shape
# Out:
# ((691, 1024, 77), (691, 1024, 19))

# %%
test_data.shape, test_gt.shape
# Out:
# ((119, 1024, 77), (119, 1024, 19))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 77
learning_rate = 0.001
batch_size = 100

convolution_levels = 3    #number of convolution to have in the network
pooling_stride = [4, 4, 4]
weights_shape = [[9, n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32]]
bias_shape = [32, 32, 32]
activation = tf.nn.relu
n_classes = 19

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)
pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)


variables_weights = np.ones((n_classes,))

# %%
pos_weight.shape
# Out:
# (19,)

# %%
pos_weight
# Out:
# array([  0.16329966,  34.21019108,  34.43589744,  37.12413793,
#         36.10067114,  26.70927318,  27.27621483,  39.94814815,
#         42.01945525,  46.65517241,  51.89952153,  48.57847534,
#         51.1509434 ,  43.40160643,  44.68595041,  33.7672956 ,
#         10.65015806,  36.60544218,   2.20649652])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values = pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,
                     variables_weights = variables_weights)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'multitask')

# %%
trainer.train(max_iter = 20000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.083 vs. 0.081
# F1 = 0.128 vs. 0.124
# Accuracy = 0.010 vs. 0.056
# CHANGE DETECTION
# AUC = 0.326 vs. 0.334
# F1 = 0.477 vs. 0.478
# Precision = 0.313 vs. 0.315
# Recall = 1.000 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.078 vs. 0.068
# F1 = 0.126 vs. 0.097
# Accuracy = 0.009 vs. 0.056
# CHANGE DETECTION
# AUC = 0.218 vs. 0.179
# F1 = 0.311 vs. 0.312
# Precision = 0.184 vs. 0.185
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 1.388341
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.529 vs. 0.078
# F1 = 0.585 vs. 0.116
# Accuracy = 0.489 vs. 0.056
# CHANGE DETECTION
# AUC = 0.713 vs. 0.315
# F1 = 0.704 vs. 0.475
# Precision = 0.645 vs. 0.312
# Recall = 0.775 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.354 vs. 0.070
# F1 = 0.438 vs. 0.097
# Accuracy = 0.396 vs. 0.056
# CHANGE DETECTION
# AUC = 0.544 vs. 0.181
# F1 = 0.577 vs. 0.315
# Precision = 0.501 vs. 0.188
# Recall = 0.681 vs. 0.974
# Minibatch Loss= 0.421611
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.758 vs. 0.080
# F1 = 0.742 vs. 0.118
# Accuracy = 0.843 vs. 0.056
# CHANGE DETECTION
# AUC = 0.765 vs. 0.351
# F1 = 0.753 vs. 0.519
# Precision = 0.651 vs. 0.350
# Recall = 0.895 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.491 vs. 0.068
# F1 = 0.544 vs. 0.092
# Accuracy = 0.748 vs. 0.056
# CHANGE DETECTION
# AUC = 0.581 vs. 0.191
# F1 = 0.602 vs. 0.311
# Precision = 0.575 vs. 0.184
# Recall = 0.632 vs. 1.000
# Minibatch Loss= 0.270542
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.838 vs. 0.080
# F1 = 0.805 vs. 0.115
# Accuracy = 0.837 vs. 0.056
# CHANGE DETECTION
# AUC = 0.788 vs. 0.287
# F1 = 0.754 vs. 0.462
# Precision = 0.711 vs. 0.300
# Recall = 0.802 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.530 vs. 0.070
# F1 = 0.561 vs. 0.106
# Accuracy = 0.810 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.184
# F1 = 0.645 vs. 0.313
# Precision = 0.601 vs. 0.186
# Recall = 0.695 vs. 0.983
# Minibatch Loss= 0.192873
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.842 vs. 0.078
# F1 = 0.809 vs. 0.116
# Accuracy = 0.835 vs. 0.056
# CHANGE DETECTION
# AUC = 0.787 vs. 0.321
# F1 = 0.756 vs. 0.487
# Precision = 0.634 vs. 0.322
# Recall = 0.938 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.551 vs. 0.068
# F1 = 0.587 vs. 0.100
# Accuracy = 0.815 vs. 0.056
# CHANGE DETECTION
# AUC = 0.640 vs. 0.184
# F1 = 0.645 vs. 0.311
# Precision = 0.638 vs. 0.184
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 0.169459
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.861 vs. 0.079
# F1 = 0.837 vs. 0.119
# Accuracy = 0.875 vs. 0.056
# CHANGE DETECTION
# AUC = 0.832 vs. 0.310
# F1 = 0.790 vs. 0.497
# Precision = 0.757 vs. 0.331
# Recall = 0.826 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.579 vs. 0.069
# F1 = 0.611 vs. 0.100
# Accuracy = 0.853 vs. 0.056
# CHANGE DETECTION
# AUC = 0.657 vs. 0.190
# F1 = 0.654 vs. 0.313
# Precision = 0.656 vs. 0.186
# Recall = 0.652 vs. 0.994
# Minibatch Loss= 0.146570
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.888 vs. 0.076
# F1 = 0.854 vs. 0.117
# Accuracy = 0.877 vs. 0.056
# CHANGE DETECTION
# AUC = 0.800 vs. 0.256
# F1 = 0.788 vs. 0.430
# Precision = 0.736 vs. 0.274
# Recall = 0.847 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.581 vs. 0.067
# F1 = 0.606 vs. 0.092
# Accuracy = 0.834 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.188
# F1 = 0.653 vs. 0.314
# Precision = 0.627 vs. 0.188
# Recall = 0.681 vs. 0.966
# Minibatch Loss= 0.120468
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.914 vs. 0.076
# F1 = 0.898 vs. 0.113
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.887 vs. 0.291
# F1 = 0.840 vs. 0.451
# Precision = 0.789 vs. 0.291
# Recall = 0.898 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.068
# F1 = 0.616 vs. 0.097
# Accuracy = 0.872 vs. 0.056
# CHANGE DETECTION
# AUC = 0.680 vs. 0.205
# F1 = 0.665 vs. 0.312
# Precision = 0.678 vs. 0.185
# Recall = 0.652 vs. 0.994
# Minibatch Loss= 0.090829
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.926 vs. 0.080
# F1 = 0.913 vs. 0.128
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.830 vs. 0.306
# F1 = 0.790 vs. 0.467
# Precision = 0.737 vs. 0.305
# Recall = 0.852 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.071
# F1 = 0.625 vs. 0.102
# Accuracy = 0.888 vs. 0.056
# CHANGE DETECTION
# AUC = 0.680 vs. 0.197
# F1 = 0.659 vs. 0.315
# Precision = 0.613 vs. 0.192
# Recall = 0.712 vs. 0.877
# Minibatch Loss= 0.088524
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.921 vs. 0.075
# F1 = 0.904 vs. 0.115
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.855 vs. 0.269
# F1 = 0.807 vs. 0.443
# Precision = 0.760 vs. 0.286
# Recall = 0.861 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.069
# F1 = 0.629 vs. 0.100
# Accuracy = 0.879 vs. 0.056
# CHANGE DETECTION
# AUC = 0.688 vs. 0.204
# F1 = 0.664 vs. 0.312
# Precision = 0.635 vs. 0.185
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 0.078365
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.943 vs. 0.077
# F1 = 0.936 vs. 0.117
# Accuracy = 0.934 vs. 0.056
# CHANGE DETECTION
# AUC = 0.855 vs. 0.309
# F1 = 0.830 vs. 0.475
# Precision = 0.794 vs. 0.312
# Recall = 0.869 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.069
# F1 = 0.633 vs. 0.100
# Accuracy = 0.905 vs. 0.056
# CHANGE DETECTION
# AUC = 0.689 vs. 0.188
# F1 = 0.658 vs. 0.312
# Precision = 0.587 vs. 0.186
# Recall = 0.749 vs. 0.983
# Minibatch Loss= 0.082809
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.951 vs. 0.073
# F1 = 0.924 vs. 0.109
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.864 vs. 0.264
# F1 = 0.816 vs. 0.410
# Precision = 0.745 vs. 0.258
# Recall = 0.903 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.070
# F1 = 0.639 vs. 0.103
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.695 vs. 0.177
# F1 = 0.677 vs. 0.313
# Precision = 0.610 vs. 0.186
# Recall = 0.761 vs. 0.977
# Minibatch Loss= 0.068855
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.959 vs. 0.080
# F1 = 0.947 vs. 0.121
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.913 vs. 0.361
# F1 = 0.875 vs. 0.497
# Precision = 0.824 vs. 0.336
# Recall = 0.934 vs. 0.951
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.071
# F1 = 0.640 vs. 0.110
# Accuracy = 0.902 vs. 0.056
# CHANGE DETECTION
# AUC = 0.696 vs. 0.193
# F1 = 0.672 vs. 0.316
# Precision = 0.594 vs. 0.190
# Recall = 0.775 vs. 0.949
# Minibatch Loss= 0.061496
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.957 vs. 0.084
# F1 = 0.945 vs. 0.124
# Accuracy = 0.938 vs. 0.056
# CHANGE DETECTION
# AUC = 0.915 vs. 0.328
# F1 = 0.867 vs. 0.503
# Precision = 0.810 vs. 0.337
# Recall = 0.931 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.072
# F1 = 0.644 vs. 0.106
# Accuracy = 0.884 vs. 0.056
# CHANGE DETECTION
# AUC = 0.694 vs. 0.179
# F1 = 0.678 vs. 0.312
# Precision = 0.611 vs. 0.185
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.062436
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.080
# F1 = 0.959 vs. 0.122
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.918 vs. 0.324
# F1 = 0.884 vs. 0.499
# Precision = 0.851 vs. 0.333
# Recall = 0.919 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.067
# F1 = 0.640 vs. 0.097
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.692 vs. 0.201
# F1 = 0.666 vs. 0.313
# Precision = 0.594 vs. 0.186
# Recall = 0.758 vs. 0.991
# Minibatch Loss= 0.053189
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.970 vs. 0.078
# F1 = 0.969 vs. 0.120
# Accuracy = 0.962 vs. 0.056
# CHANGE DETECTION
# AUC = 0.912 vs. 0.322
# F1 = 0.879 vs. 0.476
# Precision = 0.836 vs. 0.315
# Recall = 0.928 vs. 0.980
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.070
# F1 = 0.642 vs. 0.099
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.693 vs. 0.174
# F1 = 0.667 vs. 0.313
# Precision = 0.592 vs. 0.186
# Recall = 0.764 vs. 0.994
# Minibatch Loss= 0.048557
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.977 vs. 0.080
# F1 = 0.965 vs. 0.121
# Accuracy = 0.943 vs. 0.056
# CHANGE DETECTION
# AUC = 0.928 vs. 0.315
# F1 = 0.879 vs. 0.473
# Precision = 0.837 vs. 0.311
# Recall = 0.924 vs. 0.992
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.068
# F1 = 0.641 vs. 0.099
# Accuracy = 0.897 vs. 0.056
# CHANGE DETECTION
# AUC = 0.696 vs. 0.201
# F1 = 0.668 vs. 0.313
# Precision = 0.611 vs. 0.187
# Recall = 0.735 vs. 0.946
# Minibatch Loss= 0.046653
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.984 vs. 0.081
# F1 = 0.979 vs. 0.124
# Accuracy = 0.957 vs. 0.056
# CHANGE DETECTION
# AUC = 0.909 vs. 0.294
# F1 = 0.862 vs. 0.469
# Precision = 0.834 vs. 0.306
# Recall = 0.892 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.628 vs. 0.072
# F1 = 0.646 vs. 0.107
# Accuracy = 0.898 vs. 0.056
# CHANGE DETECTION
# AUC = 0.697 vs. 0.184
# F1 = 0.667 vs. 0.312
# Precision = 0.585 vs. 0.185
# Recall = 0.778 vs. 1.000
# Minibatch Loss= 0.044016
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.983 vs. 0.081
# F1 = 0.973 vs. 0.122
# Accuracy = 0.927 vs. 0.056
# CHANGE DETECTION
# AUC = 0.929 vs. 0.331
# F1 = 0.890 vs. 0.492
# Precision = 0.864 vs. 0.328
# Recall = 0.917 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.624 vs. 0.067
# F1 = 0.637 vs. 0.099
# Accuracy = 0.892 vs. 0.056
# CHANGE DETECTION
# AUC = 0.693 vs. 0.184
# F1 = 0.659 vs. 0.313
# Precision = 0.582 vs. 0.187
# Recall = 0.761 vs. 0.963
# Minibatch Loss= 0.044983
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.986 vs. 0.076
# F1 = 0.984 vs. 0.117
# Accuracy = 0.953 vs. 0.056
# CHANGE DETECTION
# AUC = 0.937 vs. 0.301
# F1 = 0.888 vs. 0.454
# Precision = 0.840 vs. 0.294
# Recall = 0.942 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.625 vs. 0.069
# F1 = 0.643 vs. 0.096
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.694 vs. 0.185
# F1 = 0.666 vs. 0.312
# Precision = 0.627 vs. 0.185
# Recall = 0.709 vs. 1.000
# Minibatch Loss= 0.032019
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.985 vs. 0.081
# F1 = 0.980 vs. 0.124
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.937 vs. 0.336
# F1 = 0.883 vs. 0.483
# Precision = 0.835 vs. 0.319
# Recall = 0.935 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.623 vs. 0.069
# F1 = 0.639 vs. 0.105
# Accuracy = 0.900 vs. 0.056
# CHANGE DETECTION
# AUC = 0.692 vs. 0.180
# F1 = 0.665 vs. 0.312
# Precision = 0.621 vs. 0.185
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.038943
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.082
# F1 = 0.981 vs. 0.127
# Accuracy = 0.963 vs. 0.056
# CHANGE DETECTION
# AUC = 0.956 vs. 0.339
# F1 = 0.906 vs. 0.506
# Precision = 0.884 vs. 0.339
# Recall = 0.930 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.067
# F1 = 0.638 vs. 0.094
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.692 vs. 0.181
# F1 = 0.660 vs. 0.312
# Precision = 0.612 vs. 0.185
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.035665
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.087
# F1 = 0.988 vs. 0.132
# Accuracy = 0.964 vs. 0.056
# CHANGE DETECTION
# AUC = 0.945 vs. 0.342
# F1 = 0.912 vs. 0.518
# Precision = 0.880 vs. 0.350
# Recall = 0.946 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.070
# F1 = 0.637 vs. 0.096
# Accuracy = 0.899 vs. 0.056
# CHANGE DETECTION
# AUC = 0.692 vs. 0.194
# F1 = 0.665 vs. 0.316
# Precision = 0.594 vs. 0.192
# Recall = 0.755 vs. 0.877
# Minibatch Loss= 0.031030
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.989 vs. 0.081
# F1 = 0.985 vs. 0.121
# Accuracy = 0.974 vs. 0.056
# CHANGE DETECTION
# AUC = 0.960 vs. 0.351
# F1 = 0.929 vs. 0.529
# Precision = 0.903 vs. 0.359
# Recall = 0.956 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.072
# F1 = 0.634 vs. 0.105
# Accuracy = 0.903 vs. 0.056
# CHANGE DETECTION
# AUC = 0.692 vs. 0.186
# F1 = 0.661 vs. 0.313
# Precision = 0.591 vs. 0.185
# Recall = 0.749 vs. 1.000
# Minibatch Loss= 0.031689
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.992 vs. 0.079
# F1 = 0.988 vs. 0.122
# Accuracy = 0.966 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.315
# F1 = 0.929 vs. 0.488
# Precision = 0.910 vs. 0.323
# Recall = 0.949 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.625 vs. 0.068
# F1 = 0.638 vs. 0.100
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.696 vs. 0.193
# F1 = 0.664 vs. 0.316
# Precision = 0.589 vs. 0.188
# Recall = 0.761 vs. 0.997
# Minibatch Loss= 0.026309
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.080
# F1 = 0.992 vs. 0.124
# Accuracy = 0.958 vs. 0.056
# CHANGE DETECTION
# AUC = 0.973 vs. 0.336
# F1 = 0.930 vs. 0.491
# Precision = 0.929 vs. 0.328
# Recall = 0.931 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.619 vs. 0.071
# F1 = 0.633 vs. 0.101
# Accuracy = 0.874 vs. 0.056
# CHANGE DETECTION
# AUC = 0.692 vs. 0.190
# F1 = 0.656 vs. 0.312
# Precision = 0.585 vs. 0.185
# Recall = 0.746 vs. 0.994
# Minibatch Loss= 0.026935
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.082
# F1 = 0.988 vs. 0.125
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.982 vs. 0.341
# F1 = 0.949 vs. 0.526
# Precision = 0.928 vs. 0.358
# Recall = 0.970 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.068
# F1 = 0.631 vs. 0.100
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.694 vs. 0.179
# F1 = 0.659 vs. 0.315
# Precision = 0.660 vs. 0.187
# Recall = 0.658 vs. 1.000
# Minibatch Loss= 0.022418
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.079
# F1 = 0.991 vs. 0.118
# Accuracy = 0.975 vs. 0.056
# CHANGE DETECTION
# AUC = 0.966 vs. 0.325
# F1 = 0.942 vs. 0.497
# Precision = 0.924 vs. 0.331
# Recall = 0.962 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.069
# F1 = 0.626 vs. 0.098
# Accuracy = 0.890 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.189
# F1 = 0.645 vs. 0.312
# Precision = 0.607 vs. 0.185
# Recall = 0.689 vs. 0.997
# Minibatch Loss= 0.025058
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.996 vs. 0.081
# F1 = 0.991 vs. 0.123
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.972 vs. 0.359
# F1 = 0.942 vs. 0.527
# Precision = 0.919 vs. 0.365
# Recall = 0.966 vs. 0.945
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.069
# F1 = 0.628 vs. 0.098
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.689 vs. 0.202
# F1 = 0.659 vs. 0.315
# Precision = 0.652 vs. 0.190
# Recall = 0.667 vs. 0.909
# Minibatch Loss= 0.023533
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.079
# F1 = 0.992 vs. 0.120
# Accuracy = 0.983 vs. 0.056
# CHANGE DETECTION
# AUC = 0.976 vs. 0.311
# F1 = 0.937 vs. 0.480
# Precision = 0.926 vs. 0.316
# Recall = 0.948 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.070
# F1 = 0.628 vs. 0.105
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.693 vs. 0.184
# F1 = 0.657 vs. 0.318
# Precision = 0.589 vs. 0.191
# Recall = 0.744 vs. 0.943
# Minibatch Loss= 0.021806
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.078
# F1 = 0.994 vs. 0.120
# Accuracy = 0.981 vs. 0.056
# CHANGE DETECTION
# AUC = 0.986 vs. 0.317
# F1 = 0.952 vs. 0.480
# Precision = 0.942 vs. 0.315
# Recall = 0.962 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.069
# F1 = 0.623 vs. 0.103
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.690 vs. 0.195
# F1 = 0.658 vs. 0.314
# Precision = 0.645 vs. 0.200
# Recall = 0.672 vs. 0.735
# Minibatch Loss= 0.017469
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.080
# F1 = 0.997 vs. 0.122
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.983 vs. 0.345
# F1 = 0.957 vs. 0.475
# Precision = 0.936 vs. 0.321
# Recall = 0.978 vs. 0.913
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.072
# F1 = 0.624 vs. 0.100
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.690 vs. 0.201
# F1 = 0.657 vs. 0.313
# Precision = 0.602 vs. 0.186
# Recall = 0.724 vs. 0.989
# Minibatch Loss= 0.017605
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.083
# F1 = 0.996 vs. 0.127
# Accuracy = 0.976 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.416
# F1 = 0.963 vs. 0.570
# Precision = 0.950 vs. 0.399
# Recall = 0.976 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.068
# F1 = 0.624 vs. 0.102
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.680 vs. 0.186
# F1 = 0.647 vs. 0.313
# Precision = 0.596 vs. 0.188
# Recall = 0.707 vs. 0.923
# Minibatch Loss= 0.018643
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.076
# F1 = 0.995 vs. 0.111
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.990 vs. 0.304
# F1 = 0.966 vs. 0.463
# Precision = 0.959 vs. 0.301
# Recall = 0.973 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.073
# F1 = 0.625 vs. 0.108
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.182
# F1 = 0.655 vs. 0.313
# Precision = 0.619 vs. 0.185
# Recall = 0.695 vs. 0.994
# Minibatch Loss= 0.013240
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.997 vs. 0.115
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.279
# F1 = 0.963 vs. 0.448
# Precision = 0.955 vs. 0.288
# Recall = 0.972 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.073
# F1 = 0.624 vs. 0.106
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.683 vs. 0.191
# F1 = 0.650 vs. 0.312
# Precision = 0.608 vs. 0.185
# Recall = 0.698 vs. 1.000
# Minibatch Loss= 0.013518
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.083
# F1 = 0.997 vs. 0.127
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.350
# F1 = 0.976 vs. 0.508
# Precision = 0.963 vs. 0.340
# Recall = 0.991 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.070
# F1 = 0.623 vs. 0.104
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.684 vs. 0.198
# F1 = 0.656 vs. 0.319
# Precision = 0.612 vs. 0.197
# Recall = 0.707 vs. 0.829
# Minibatch Loss= 0.013822
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.082
# F1 = 0.996 vs. 0.119
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.993 vs. 0.380
# F1 = 0.967 vs. 0.523
# Precision = 0.966 vs. 0.354
# Recall = 0.968 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.069
# F1 = 0.628 vs. 0.103
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.680 vs. 0.185
# F1 = 0.653 vs. 0.313
# Precision = 0.610 vs. 0.187
# Recall = 0.704 vs. 0.963
# Minibatch Loss= 0.014123
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.084
# F1 = 0.997 vs. 0.128
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.989 vs. 0.329
# F1 = 0.967 vs. 0.490
# Precision = 0.956 vs. 0.329
# Recall = 0.979 vs. 0.959
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.070
# F1 = 0.619 vs. 0.101
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.681 vs. 0.180
# F1 = 0.652 vs. 0.311
# Precision = 0.601 vs. 0.184
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.012509
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.119
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.312
# F1 = 0.986 vs. 0.479
# Precision = 0.985 vs. 0.316
# Recall = 0.987 vs. 0.991
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.071
# F1 = 0.617 vs. 0.107
# Accuracy = 0.916 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.206
# F1 = 0.645 vs. 0.313
# Precision = 0.626 vs. 0.187
# Recall = 0.664 vs. 0.957
# Minibatch Loss= 0.009822
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.081
# F1 = 0.998 vs. 0.123
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.324
# F1 = 0.981 vs. 0.498
# Precision = 0.983 vs. 0.331
# Recall = 0.979 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.071
# F1 = 0.623 vs. 0.106
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.182
# F1 = 0.656 vs. 0.312
# Precision = 0.619 vs. 0.185
# Recall = 0.698 vs. 0.989
# Minibatch Loss= 0.010864
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.997 vs. 0.119
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.292
# F1 = 0.980 vs. 0.458
# Precision = 0.971 vs. 0.297
# Recall = 0.989 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.071
# F1 = 0.623 vs. 0.104
# Accuracy = 0.894 vs. 0.056
# CHANGE DETECTION
# AUC = 0.675 vs. 0.184
# F1 = 0.647 vs. 0.314
# Precision = 0.585 vs. 0.186
# Recall = 0.724 vs. 0.991
# Minibatch Loss= 0.012080
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.121
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.997 vs. 0.316
# F1 = 0.983 vs. 0.502
# Precision = 0.979 vs. 0.335
# Recall = 0.987 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.070
# F1 = 0.617 vs. 0.101
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.200
# F1 = 0.647 vs. 0.313
# Precision = 0.603 vs. 0.189
# Recall = 0.698 vs. 0.929
# Minibatch Loss= 0.010613
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.122
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.319
# F1 = 0.991 vs. 0.464
# Precision = 0.990 vs. 0.302
# Recall = 0.992 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.600 vs. 0.069
# F1 = 0.623 vs. 0.101
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.670 vs. 0.206
# F1 = 0.643 vs. 0.314
# Precision = 0.584 vs. 0.187
# Recall = 0.715 vs. 0.997
# Minibatch Loss= 0.007367
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.116
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.275
# F1 = 0.992 vs. 0.419
# Precision = 0.993 vs. 0.265
# Recall = 0.991 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.071
# F1 = 0.621 vs. 0.107
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.672 vs. 0.195
# F1 = 0.644 vs. 0.314
# Precision = 0.613 vs. 0.187
# Recall = 0.678 vs. 0.991
# Minibatch Loss= 0.005802
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.123
# Accuracy = 0.993 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.311
# F1 = 0.990 vs. 0.478
# Precision = 0.986 vs. 0.314
# Recall = 0.994 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.066
# F1 = 0.620 vs. 0.095
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.186
# F1 = 0.653 vs. 0.321
# Precision = 0.630 vs. 0.193
# Recall = 0.678 vs. 0.963
# Minibatch Loss= 0.007506
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.120
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.262
# F1 = 0.988 vs. 0.414
# Precision = 0.984 vs. 0.268
# Recall = 0.992 vs. 0.906
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.072
# F1 = 0.623 vs. 0.109
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.678 vs. 0.188
# F1 = 0.654 vs. 0.313
# Precision = 0.627 vs. 0.186
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.007055
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.117
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.250
# F1 = 0.986 vs. 0.416
# Precision = 0.981 vs. 0.263
# Recall = 0.990 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.068
# F1 = 0.615 vs. 0.095
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.661 vs. 0.186
# F1 = 0.635 vs. 0.315
# Precision = 0.619 vs. 0.188
# Recall = 0.652 vs. 0.989
# Minibatch Loss= 0.006418
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.117
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.299
# F1 = 0.995 vs. 0.464
# Precision = 0.992 vs. 0.303
# Recall = 0.998 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.069
# F1 = 0.620 vs. 0.098
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.677 vs. 0.183
# F1 = 0.650 vs. 0.312
# Precision = 0.610 vs. 0.185
# Recall = 0.695 vs. 0.997
# Minibatch Loss= 0.005114
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.998 vs. 0.111
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.318
# F1 = 0.999 vs. 0.467
# Precision = 0.998 vs. 0.306
# Recall = 1.000 vs. 0.983
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.070
# F1 = 0.616 vs. 0.110
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.199
# F1 = 0.648 vs. 0.312
# Precision = 0.607 vs. 0.185
# Recall = 0.695 vs. 0.991
# Minibatch Loss= 0.005127
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.118
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.295
# F1 = 0.996 vs. 0.472
# Precision = 0.996 vs. 0.311
# Recall = 0.996 vs. 0.982
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.597 vs. 0.068
# F1 = 0.620 vs. 0.099
# Accuracy = 0.915 vs. 0.056
# CHANGE DETECTION
# AUC = 0.676 vs. 0.185
# F1 = 0.651 vs. 0.312
# Precision = 0.615 vs. 0.187
# Recall = 0.692 vs. 0.943
# Minibatch Loss= 0.005498
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.122
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.315
# F1 = 0.998 vs. 0.465
# Precision = 0.998 vs. 0.303
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.069
# F1 = 0.616 vs. 0.101
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.670 vs. 0.185
# F1 = 0.648 vs. 0.315
# Precision = 0.605 vs. 0.188
# Recall = 0.698 vs. 0.957
# Minibatch Loss= 0.004528
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.125
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.329
# F1 = 0.996 vs. 0.509
# Precision = 0.993 vs. 0.341
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.067
# F1 = 0.617 vs. 0.094
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.189
# F1 = 0.651 vs. 0.313
# Precision = 0.598 vs. 0.186
# Recall = 0.715 vs. 0.983
# Minibatch Loss= 0.005369
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.998 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.263
# F1 = 0.999 vs. 0.432
# Precision = 1.000 vs. 0.277
# Recall = 0.997 vs. 0.987
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.587 vs. 0.069
# F1 = 0.617 vs. 0.102
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.671 vs. 0.193
# F1 = 0.653 vs. 0.315
# Precision = 0.608 vs. 0.190
# Recall = 0.707 vs. 0.915
# Minibatch Loss= 0.004055
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.998 vs. 0.124
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.356
# F1 = 0.995 vs. 0.519
# Precision = 0.991 vs. 0.351
# Recall = 0.998 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.591 vs. 0.074
# F1 = 0.619 vs. 0.113
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.656 vs. 0.184
# F1 = 0.641 vs. 0.312
# Precision = 0.586 vs. 0.185
# Recall = 0.707 vs. 1.000
# Minibatch Loss= 0.004895
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.998 vs. 0.121
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.365
# F1 = 0.998 vs. 0.510
# Precision = 0.996 vs. 0.343
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.072
# F1 = 0.617 vs. 0.117
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.180
# F1 = 0.655 vs. 0.316
# Precision = 0.603 vs. 0.189
# Recall = 0.718 vs. 0.963
# Minibatch Loss= 0.003989
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.115
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.311
# F1 = 0.999 vs. 0.471
# Precision = 0.998 vs. 0.314
# Recall = 1.000 vs. 0.945
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.585 vs. 0.067
# F1 = 0.616 vs. 0.096
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.203
# F1 = 0.657 vs. 0.311
# Precision = 0.616 vs. 0.184
# Recall = 0.704 vs. 1.000
# Minibatch Loss= 0.003975
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.120
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.292
# F1 = 0.999 vs. 0.449
# Precision = 0.998 vs. 0.290
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.592 vs. 0.075
# F1 = 0.617 vs. 0.105
# Accuracy = 0.918 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.189
# F1 = 0.662 vs. 0.312
# Precision = 0.628 vs. 0.185
# Recall = 0.701 vs. 1.000
# Minibatch Loss= 0.003374
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.114
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.269
# F1 = 0.999 vs. 0.416
# Precision = 0.998 vs. 0.263
# Recall = 1.000 vs. 0.995
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.069
# F1 = 0.614 vs. 0.103
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.176
# F1 = 0.660 vs. 0.313
# Precision = 0.616 vs. 0.187
# Recall = 0.709 vs. 0.969
# Minibatch Loss= 0.002887
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.120
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 0.999 vs. 0.498
# Precision = 0.998 vs. 0.336
# Recall = 1.000 vs. 0.958
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.072
# F1 = 0.612 vs. 0.109
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.183
# F1 = 0.649 vs. 0.319
# Precision = 0.597 vs. 0.190
# Recall = 0.712 vs. 0.986
# Minibatch Loss= 0.003512
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.999 vs. 0.122
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.305
# F1 = 0.998 vs. 0.449
# Precision = 1.000 vs. 0.290
# Recall = 0.995 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.583 vs. 0.071
# F1 = 0.615 vs. 0.105
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.658 vs. 0.182
# F1 = 0.653 vs. 0.313
# Precision = 0.616 vs. 0.186
# Recall = 0.695 vs. 0.980
# Minibatch Loss= 0.003117
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.903 vs. 0.077
# F1 = 0.872 vs. 0.113
# Accuracy = 0.893 vs. 0.056
# CHANGE DETECTION
# AUC = 0.897 vs. 0.306
# F1 = 0.829 vs. 0.463
# Precision = 0.820 vs. 0.301
# Recall = 0.837 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.561 vs. 0.068
# F1 = 0.609 vs. 0.097
# Accuracy = 0.855 vs. 0.056
# CHANGE DETECTION
# AUC = 0.620 vs. 0.189
# F1 = 0.642 vs. 0.312
# Precision = 0.646 vs. 0.185
# Recall = 0.638 vs. 0.989
# Minibatch Loss= 0.134097
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.971 vs. 0.076
# F1 = 0.944 vs. 0.117
# Accuracy = 0.954 vs. 0.056
# CHANGE DETECTION
# AUC = 0.933 vs. 0.311
# F1 = 0.869 vs. 0.472
# Precision = 0.854 vs. 0.309
# Recall = 0.885 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.588 vs. 0.069
# F1 = 0.623 vs. 0.097
# Accuracy = 0.896 vs. 0.056
# CHANGE DETECTION
# AUC = 0.641 vs. 0.187
# F1 = 0.658 vs. 0.312
# Precision = 0.631 vs. 0.185
# Recall = 0.687 vs. 1.000
# Minibatch Loss= 0.050827
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.991 vs. 0.082
# F1 = 0.977 vs. 0.124
# Accuracy = 0.973 vs. 0.056
# CHANGE DETECTION
# AUC = 0.970 vs. 0.349
# F1 = 0.921 vs. 0.529
# Precision = 0.894 vs. 0.360
# Recall = 0.950 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.068
# F1 = 0.630 vs. 0.105
# Accuracy = 0.904 vs. 0.056
# CHANGE DETECTION
# AUC = 0.647 vs. 0.197
# F1 = 0.661 vs. 0.312
# Precision = 0.626 vs. 0.185
# Recall = 0.701 vs. 0.989
# Minibatch Loss= 0.031010
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.079
# F1 = 0.992 vs. 0.117
# Accuracy = 0.979 vs. 0.056
# CHANGE DETECTION
# AUC = 0.985 vs. 0.328
# F1 = 0.948 vs. 0.514
# Precision = 0.946 vs. 0.346
# Recall = 0.949 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.593 vs. 0.071
# F1 = 0.627 vs. 0.105
# Accuracy = 0.908 vs. 0.056
# CHANGE DETECTION
# AUC = 0.659 vs. 0.197
# F1 = 0.648 vs. 0.312
# Precision = 0.628 vs. 0.185
# Recall = 0.670 vs. 0.994
# Minibatch Loss= 0.020332
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.997 vs. 0.079
# F1 = 0.993 vs. 0.117
# Accuracy = 0.985 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.315
# F1 = 0.966 vs. 0.473
# Precision = 0.953 vs. 0.311
# Recall = 0.980 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.595 vs. 0.075
# F1 = 0.626 vs. 0.112
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.661 vs. 0.194
# F1 = 0.646 vs. 0.313
# Precision = 0.610 vs. 0.187
# Recall = 0.687 vs. 0.957
# Minibatch Loss= 0.014403
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.999 vs. 0.077
# F1 = 0.996 vs. 0.117
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.991 vs. 0.319
# F1 = 0.965 vs. 0.473
# Precision = 0.954 vs. 0.310
# Recall = 0.976 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.590 vs. 0.070
# F1 = 0.627 vs. 0.103
# Accuracy = 0.912 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.186
# F1 = 0.648 vs. 0.313
# Precision = 0.607 vs. 0.185
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 0.012906
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 0.998 vs. 0.077
# F1 = 0.995 vs. 0.119
# Accuracy = 0.987 vs. 0.056
# CHANGE DETECTION
# AUC = 0.988 vs. 0.299
# F1 = 0.958 vs. 0.447
# Precision = 0.932 vs. 0.288
# Recall = 0.986 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.069
# F1 = 0.627 vs. 0.099
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.655 vs. 0.191
# F1 = 0.644 vs. 0.317
# Precision = 0.603 vs. 0.193
# Recall = 0.689 vs. 0.883
# Minibatch Loss= 0.013131
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.997 vs. 0.126
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 0.995 vs. 0.313
# F1 = 0.972 vs. 0.474
# Precision = 0.952 vs. 0.313
# Recall = 0.994 vs. 0.970
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.599 vs. 0.071
# F1 = 0.629 vs. 0.105
# Accuracy = 0.911 vs. 0.056
# CHANGE DETECTION
# AUC = 0.655 vs. 0.176
# F1 = 0.644 vs. 0.313
# Precision = 0.618 vs. 0.185
# Recall = 0.672 vs. 0.997
# Minibatch Loss= 0.010858
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.998 vs. 0.120
# Accuracy = 0.989 vs. 0.056
# CHANGE DETECTION
# AUC = 0.994 vs. 0.319
# F1 = 0.980 vs. 0.490
# Precision = 0.966 vs. 0.325
# Recall = 0.994 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.069
# F1 = 0.626 vs. 0.096
# Accuracy = 0.914 vs. 0.056
# CHANGE DETECTION
# AUC = 0.661 vs. 0.178
# F1 = 0.646 vs. 0.314
# Precision = 0.604 vs. 0.193
# Recall = 0.695 vs. 0.840
# Minibatch Loss= 0.009956
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.117
# Accuracy = 0.990 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.291
# F1 = 0.991 vs. 0.463
# Precision = 0.982 vs. 0.302
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.601 vs. 0.069
# F1 = 0.629 vs. 0.098
# Accuracy = 0.913 vs. 0.056
# CHANGE DETECTION
# AUC = 0.668 vs. 0.181
# F1 = 0.651 vs. 0.312
# Precision = 0.612 vs. 0.186
# Recall = 0.695 vs. 0.986
# Minibatch Loss= 0.007578
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.113
# Accuracy = 0.986 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.299
# F1 = 0.987 vs. 0.464
# Precision = 0.990 vs. 0.302
# Recall = 0.983 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.071
# F1 = 0.628 vs. 0.101
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.180
# F1 = 0.650 vs. 0.313
# Precision = 0.612 vs. 0.185
# Recall = 0.692 vs. 1.000
# Minibatch Loss= 0.008330
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.999 vs. 0.114
# Accuracy = 0.991 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.284
# F1 = 0.988 vs. 0.417
# Precision = 0.988 vs. 0.263
# Recall = 0.988 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.598 vs. 0.073
# F1 = 0.631 vs. 0.112
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.187
# F1 = 0.650 vs. 0.311
# Precision = 0.606 vs. 0.184
# Recall = 0.701 vs. 1.000
# Minibatch Loss= 0.006014
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.130
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.416
# F1 = 0.990 vs. 0.570
# Precision = 0.984 vs. 0.398
# Recall = 0.995 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.070
# F1 = 0.632 vs. 0.101
# Accuracy = 0.919 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.189
# F1 = 0.647 vs. 0.311
# Precision = 0.605 vs. 0.184
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 0.007901
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.998 vs. 0.117
# Accuracy = 0.995 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.259
# F1 = 0.990 vs. 0.421
# Precision = 0.985 vs. 0.267
# Recall = 0.995 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.596 vs. 0.069
# F1 = 0.633 vs. 0.098
# Accuracy = 0.917 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.181
# F1 = 0.653 vs. 0.312
# Precision = 0.597 vs. 0.185
# Recall = 0.721 vs. 0.994
# Minibatch Loss= 0.006401
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.087
# F1 = 0.998 vs. 0.129
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.379
# F1 = 0.991 vs. 0.555
# Precision = 0.992 vs. 0.385
# Recall = 0.990 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.070
# F1 = 0.633 vs. 0.097
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.186
# F1 = 0.653 vs. 0.313
# Precision = 0.600 vs. 0.186
# Recall = 0.715 vs. 0.997
# Minibatch Loss= 0.007189
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.998 vs. 0.123
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 0.998 vs. 0.327
# F1 = 0.992 vs. 0.496
# Precision = 0.989 vs. 0.334
# Recall = 0.996 vs. 0.962
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.604 vs. 0.069
# F1 = 0.630 vs. 0.098
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.187
# F1 = 0.653 vs. 0.311
# Precision = 0.602 vs. 0.185
# Recall = 0.712 vs. 0.994
# Minibatch Loss= 0.006336
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.126
# Accuracy = 0.994 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.348
# F1 = 0.997 vs. 0.541
# Precision = 0.993 vs. 0.371
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.071
# F1 = 0.632 vs. 0.106
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.664 vs. 0.171
# F1 = 0.653 vs. 0.311
# Precision = 0.600 vs. 0.184
# Recall = 0.715 vs. 1.000
# Minibatch Loss= 0.005993
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.076
# F1 = 0.999 vs. 0.115
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.293
# F1 = 0.999 vs. 0.475
# Precision = 0.998 vs. 0.312
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.069
# F1 = 0.630 vs. 0.101
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.185
# F1 = 0.648 vs. 0.318
# Precision = 0.599 vs. 0.190
# Recall = 0.707 vs. 0.966
# Minibatch Loss= 0.004525
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.083
# F1 = 0.998 vs. 0.123
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 0.999 vs. 0.334
# F1 = 0.996 vs. 0.507
# Precision = 0.994 vs. 0.339
# Recall = 0.998 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.609 vs. 0.070
# F1 = 0.626 vs. 0.105
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.673 vs. 0.192
# F1 = 0.648 vs. 0.315
# Precision = 0.607 vs. 0.190
# Recall = 0.695 vs. 0.917
# Minibatch Loss= 0.004962
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.115
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.346
# F1 = 0.998 vs. 0.495
# Precision = 0.998 vs. 0.331
# Recall = 0.998 vs. 0.977
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.067
# F1 = 0.627 vs. 0.095
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.663 vs. 0.187
# F1 = 0.651 vs. 0.312
# Precision = 0.616 vs. 0.185
# Recall = 0.689 vs. 1.000
# Minibatch Loss= 0.004748
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.119
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.346
# F1 = 0.997 vs. 0.534
# Precision = 0.994 vs. 0.365
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.607 vs. 0.072
# F1 = 0.629 vs. 0.111
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.193
# F1 = 0.649 vs. 0.313
# Precision = 0.615 vs. 0.185
# Recall = 0.687 vs. 0.994
# Minibatch Loss= 0.005390
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.078
# F1 = 0.998 vs. 0.120
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.329
# F1 = 0.994 vs. 0.505
# Precision = 0.989 vs. 0.338
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.603 vs. 0.069
# F1 = 0.628 vs. 0.098
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.672 vs. 0.187
# F1 = 0.650 vs. 0.311
# Precision = 0.620 vs. 0.184
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.005091
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.121
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.329
# F1 = 0.998 vs. 0.505
# Precision = 1.000 vs. 0.339
# Recall = 0.996 vs. 0.985
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.605 vs. 0.067
# F1 = 0.628 vs. 0.093
# Accuracy = 0.921 vs. 0.056
# CHANGE DETECTION
# AUC = 0.670 vs. 0.197
# F1 = 0.650 vs. 0.312
# Precision = 0.620 vs. 0.185
# Recall = 0.684 vs. 0.989
# Minibatch Loss= 0.004062
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.123
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.318
# F1 = 1.000 vs. 0.482
# Precision = 1.000 vs. 0.318
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.610 vs. 0.073
# F1 = 0.628 vs. 0.111
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.194
# F1 = 0.650 vs. 0.313
# Precision = 0.622 vs. 0.186
# Recall = 0.681 vs. 0.994
# Minibatch Loss= 0.004312
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.998 vs. 0.120
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.309
# F1 = 0.999 vs. 0.477
# Precision = 1.000 vs. 0.314
# Recall = 0.998 vs. 0.990
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.602 vs. 0.067
# F1 = 0.627 vs. 0.095
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.670 vs. 0.187
# F1 = 0.651 vs. 0.312
# Precision = 0.624 vs. 0.185
# Recall = 0.681 vs. 0.994
# Minibatch Loss= 0.004204
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.999 vs. 0.107
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.278
# F1 = 1.000 vs. 0.431
# Precision = 1.000 vs. 0.274
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.606 vs. 0.068
# F1 = 0.627 vs. 0.096
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.670 vs. 0.170
# F1 = 0.651 vs. 0.315
# Precision = 0.624 vs. 0.188
# Recall = 0.681 vs. 0.977
# Minibatch Loss= 0.003489
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.998 vs. 0.119
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.299
# F1 = 1.000 vs. 0.489
# Precision = 1.000 vs. 0.325
# Recall = 1.000 vs. 0.988
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.611 vs. 0.071
# F1 = 0.627 vs. 0.105
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.675 vs. 0.185
# F1 = 0.651 vs. 0.311
# Precision = 0.624 vs. 0.184
# Recall = 0.681 vs. 1.000
# Minibatch Loss= 0.003538
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.082
# F1 = 0.999 vs. 0.125
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.326
# F1 = 0.998 vs. 0.496
# Precision = 0.998 vs. 0.330
# Recall = 0.998 vs. 0.994
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.614 vs. 0.069
# F1 = 0.628 vs. 0.102
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.668 vs. 0.178
# F1 = 0.651 vs. 0.312
# Precision = 0.624 vs. 0.185
# Recall = 0.681 vs. 1.000
# Minibatch Loss= 0.003660
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.118
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.303
# F1 = 1.000 vs. 0.462
# Precision = 1.000 vs. 0.301
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.612 vs. 0.069
# F1 = 0.629 vs. 0.096
# Accuracy = 0.923 vs. 0.056
# CHANGE DETECTION
# AUC = 0.668 vs. 0.191
# F1 = 0.652 vs. 0.313
# Precision = 0.626 vs. 0.186
# Recall = 0.681 vs. 0.980
# Minibatch Loss= 0.003092
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.998 vs. 0.126
# Accuracy = 0.999 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.297
# F1 = 0.998 vs. 0.460
# Precision = 0.996 vs. 0.299
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.071
# F1 = 0.629 vs. 0.103
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.664 vs. 0.172
# F1 = 0.653 vs. 0.313
# Precision = 0.627 vs. 0.186
# Recall = 0.681 vs. 1.000
# Minibatch Loss= 0.003412
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.115
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.273
# F1 = 0.999 vs. 0.429
# Precision = 0.998 vs. 0.274
# Recall = 1.000 vs. 0.993
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.072
# F1 = 0.630 vs. 0.099
# Accuracy = 0.922 vs. 0.056
# CHANGE DETECTION
# AUC = 0.661 vs. 0.204
# F1 = 0.654 vs. 0.316
# Precision = 0.627 vs. 0.191
# Recall = 0.684 vs. 0.906
# Minibatch Loss= 0.003006
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.118
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.252
# F1 = 1.000 vs. 0.431
# Precision = 1.000 vs. 0.274
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.622 vs. 0.067
# F1 = 0.631 vs. 0.094
# Accuracy = 0.920 vs. 0.056
# CHANGE DETECTION
# AUC = 0.664 vs. 0.195
# F1 = 0.654 vs. 0.314
# Precision = 0.627 vs. 0.189
# Recall = 0.684 vs. 0.929
# Minibatch Loss= 0.002794
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.074
# F1 = 0.999 vs. 0.112
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.253
# F1 = 1.000 vs. 0.385
# Precision = 1.000 vs. 0.239
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.070
# F1 = 0.631 vs. 0.098
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.665 vs. 0.205
# F1 = 0.654 vs. 0.313
# Precision = 0.629 vs. 0.185
# Recall = 0.681 vs. 0.997
# Minibatch Loss= 0.003070
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.075
# F1 = 0.999 vs. 0.114
# Accuracy = 0.996 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.280
# F1 = 0.999 vs. 0.452
# Precision = 0.998 vs. 0.292
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.619 vs. 0.068
# F1 = 0.630 vs. 0.091
# Accuracy = 0.926 vs. 0.056
# CHANGE DETECTION
# AUC = 0.669 vs. 0.209
# F1 = 0.654 vs. 0.314
# Precision = 0.629 vs. 0.194
# Recall = 0.681 vs. 0.826
# Minibatch Loss= 0.003184
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.079
# F1 = 0.999 vs. 0.122
# Accuracy = 1.000 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.276
# F1 = 0.999 vs. 0.444
# Precision = 0.998 vs. 0.286
# Recall = 1.000 vs. 0.998
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.620 vs. 0.068
# F1 = 0.631 vs. 0.103
# Accuracy = 0.924 vs. 0.056
# CHANGE DETECTION
# AUC = 0.653 vs. 0.189
# F1 = 0.648 vs. 0.313
# Precision = 0.628 vs. 0.186
# Recall = 0.670 vs. 1.000
# Minibatch Loss= 0.002756
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.113
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.299
# F1 = 1.000 vs. 0.456
# Precision = 1.000 vs. 0.295
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.069
# F1 = 0.633 vs. 0.101
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.670 vs. 0.188
# F1 = 0.651 vs. 0.312
# Precision = 0.629 vs. 0.186
# Recall = 0.675 vs. 0.983
# Minibatch Loss= 0.002429
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.085
# F1 = 0.999 vs. 0.127
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.377
# F1 = 1.000 vs. 0.546
# Precision = 1.000 vs. 0.375
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.618 vs. 0.070
# F1 = 0.634 vs. 0.101
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.672 vs. 0.183
# F1 = 0.648 vs. 0.313
# Precision = 0.624 vs. 0.186
# Recall = 0.675 vs. 0.997
# Minibatch Loss= 0.002935
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.119
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.287
# F1 = 1.000 vs. 0.443
# Precision = 1.000 vs. 0.285
# Recall = 1.000 vs. 0.989
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.616 vs. 0.068
# F1 = 0.636 vs. 0.095
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.666 vs. 0.194
# F1 = 0.649 vs. 0.313
# Precision = 0.630 vs. 0.186
# Recall = 0.670 vs. 0.997
# Minibatch Loss= 0.002543
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.080
# F1 = 0.999 vs. 0.119
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.300
# F1 = 1.000 vs. 0.473
# Precision = 1.000 vs. 0.317
# Recall = 1.000 vs. 0.933
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.621 vs. 0.067
# F1 = 0.635 vs. 0.097
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.667 vs. 0.185
# F1 = 0.648 vs. 0.312
# Precision = 0.633 vs. 0.185
# Recall = 0.664 vs. 1.000
# Minibatch Loss= 0.002114
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.077
# F1 = 0.999 vs. 0.116
# Accuracy = 0.997 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.312
# F1 = 1.000 vs. 0.484
# Precision = 1.000 vs. 0.320
# Recall = 1.000 vs. 1.000
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.069
# F1 = 0.634 vs. 0.105
# Accuracy = 0.925 vs. 0.056
# CHANGE DETECTION
# AUC = 0.651 vs. 0.186
# F1 = 0.647 vs. 0.313
# Precision = 0.639 vs. 0.186
# Recall = 0.655 vs. 0.991
# Minibatch Loss= 0.002418
# Train Batch Evaluation
# ACTIVITY RECOGNITION
# AUC = 1.000 vs. 0.081
# F1 = 0.999 vs. 0.126
# Accuracy = 0.998 vs. 0.056
# CHANGE DETECTION
# AUC = 1.000 vs. 0.313
# F1 = 1.000 vs. 0.482
# Precision = 1.000 vs. 0.318
# Recall = 1.000 vs. 0.996
# Validation
# ACTIVITY RECOGNITION
# AUC = 0.626 vs. 0.072
# F1 = 0.635 vs. 0.105
# Accuracy = 0.930 vs. 0.056
# CHANGE DETECTION
# AUC = 0.659 vs. 0.178
# F1 = 0.650 vs. 0.312
# Precision = 0.644 vs. 0.185
# Recall = 0.655 vs. 1.000
# Minibatch Loss= 0.002534
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e877f88d5a2e> in <module>()
#       2                 train_eval_step = 100,
#       3                 validation_eval_step = 100,
# ----> 4                 display_step = 100)
#
# /data2/data/zebrahim/git_lab/deepmodels2/src/training.py in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1087             feed_handles[subfeed_t] = subfeed_val
#    1088           else:
# -> 1089             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1090
#    1091           if (not is_tensor_handle_feed and
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/CNN_activity_Wmultitask_64_opp/CNN_activity_Wmultitask_64_opp-10093'

# %%
#load the model
saver = tf.train.Saver()
#saver.restore(sess, "../model" + "/CNN7002_Gleam" + "/CNN7002_Gleam")
saver.restore(sess, '../model/CNN_activity_multitask_64_opp/CNN_activity_multitask_64_opp-20000')
# Out:
# INFO:tensorflow:Restoring parameters from ../model/CNN_activity_multitask_64_opp/CNN_activity_multitask_64_opp-20000

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# ACTIVITY RECOGNITION
# AUC = 0.617 vs. 0.067
# F1 = 0.634 vs. 0.094
# Accuracy = 0.928 vs. 0.056
# CHANGE DETECTION
# AUC = 0.662 vs. 0.185
# F1 = 0.652 vs. 0.311
# Precision = 0.648 vs. 0.185
# Recall = 0.655 vs. 0.994

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})

# %%
1
