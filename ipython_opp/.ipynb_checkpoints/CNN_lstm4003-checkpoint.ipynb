# %%
# useing this variable for saving models and summaries
exp_name = "CNN-LSTM4003"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,32,32, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../src')
sys.path.append('../src/models')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training  
import nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 100

pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 32],
                 [5, 32, 32],
                 [5, 32, 64],
                 [5, 64, 64]]

bias_shape = [32,32,32, 64, 64]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 1


#positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
pos_weight
# Out:
# 3.186018221237171

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables, n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride,
                         weights_shape,
                         bias_shape,
                         activation,
                         lstm_n_hidden,
                         n_classes,
                         learning_rate,
                         pos_weight)

# %%
train_obj = training.Trainer(model,
                 train_data, train_gt,
                 validation_data, validation_gt,
                 sess,
                 summary_path,
                 batch_size,
                 global_step = 0)

# %%
train_obj.train(max_iter = 1000,
                train_eval_step=10,
                validation_eval_step=10,
                display_step=10)
# Out:
# Tarin Iter 0, auc= 0.246377, fmeasure_max= 0.382516, precision= 0.236488, recall= 1.000000
# Train Random guess:  , auc= 0.240510fmeasure_max= 0.380871, precision= 0.235407, recall= 0.996840
# Validation Iter 0, auc= 0.220089, fmeasure_max= 0.387792, precision= 0.245232, recall= 0.926244
# Validation Random guess:  auc= 0.227747, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 1.188781
# Tarin Iter 10, auc= 0.251009, fmeasure_max= 0.417447, precision= 0.274718, recall= 0.868861
# Train Random guess:  , auc= 0.237081fmeasure_max= 0.385450, precision= 0.238876, recall= 0.997544
# Validation Iter 10, auc= 0.224336, fmeasure_max= 0.413243, precision= 0.269231, recall= 0.888508
# Validation Random guess:  auc= 0.236931, fmeasure_max= 0.371173, precision= 0.227967, recall= 0.998285
# Minibatch Loss= 1.063640
# Tarin Iter 20, auc= 0.371784, fmeasure_max= 0.385680, precision= 0.244500, recall= 0.912690
# Train Random guess:  , auc= 0.224763fmeasure_max= 0.368619, precision= 0.225955, recall= 1.000000
# Validation Iter 20, auc= 0.300035, fmeasure_max= 0.372246, precision= 0.230269, recall= 0.970840
# Validation Random guess:  auc= 0.220863, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 1.031071
# Tarin Iter 30, auc= 0.411431, fmeasure_max= 0.480741, precision= 0.526253, recall= 0.442475
# Train Random guess:  , auc= 0.233536fmeasure_max= 0.378822, precision= 0.233689, recall= 0.999666
# Validation Iter 30, auc= 0.346306, fmeasure_max= 0.397233, precision= 0.468531, recall= 0.344768
# Validation Random guess:  auc= 0.236574, fmeasure_max= 0.371766, precision= 0.228414, recall= 0.998285
# Minibatch Loss= 1.016654
# Tarin Iter 40, auc= 0.436152, fmeasure_max= 0.495860, precision= 0.538892, recall= 0.459192
# Train Random guess:  , auc= 0.230342fmeasure_max= 0.373002, precision= 0.229258, recall= 1.000000
# Validation Iter 40, auc= 0.391232, fmeasure_max= 0.468604, precision= 0.516529, recall= 0.428816
# Validation Random guess:  auc= 0.226789, fmeasure_max= 0.372361, precision= 0.228864, recall= 0.998285
# Minibatch Loss= 0.995826
# Tarin Iter 50, auc= 0.472507, fmeasure_max= 0.533287, precision= 0.557466, recall= 0.511118
# Train Random guess:  , auc= 0.229606fmeasure_max= 0.381161, precision= 0.235536, recall= 0.998506
# Validation Iter 50, auc= 0.435406, fmeasure_max= 0.522907, precision= 0.484627, recall= 0.567753
# Validation Random guess:  auc= 0.213056, fmeasure_max= 0.372004, precision= 0.228594, recall= 0.998285
# Minibatch Loss= 0.965112
# Tarin Iter 60, auc= 0.539712, fmeasure_max= 0.560741, precision= 0.593021, recall= 0.531794
# Train Random guess:  , auc= 0.232648fmeasure_max= 0.378527, precision= 0.233447, recall= 1.000000
# Validation Iter 60, auc= 0.495320, fmeasure_max= 0.543498, precision= 0.569549, recall= 0.519726
# Validation Random guess:  auc= 0.236686, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.947170
# Tarin Iter 70, auc= 0.548395, fmeasure_max= 0.612721, precision= 0.599162, recall= 0.626908
# Train Random guess:  , auc= 0.223751fmeasure_max= 0.364281, precision= 0.222704, recall= 1.000000
# Validation Iter 70, auc= 0.556790, fmeasure_max= 0.620529, precision= 0.567568, recall= 0.684391
# Validation Random guess:  auc= 0.248493, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.903315
# Tarin Iter 80, auc= 0.629446, fmeasure_max= 0.640218, precision= 0.676780, recall= 0.607403
# Train Random guess:  , auc= 0.244091fmeasure_max= 0.392614, precision= 0.244545, recall= 0.995195
# Validation Iter 80, auc= 0.591201, fmeasure_max= 0.636771, precision= 0.667293, recall= 0.608919
# Validation Random guess:  auc= 0.219868, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.926700
# Tarin Iter 90, auc= 0.673489, fmeasure_max= 0.675947, precision= 0.720917, recall= 0.636258
# Train Random guess:  , auc= 0.236041fmeasure_max= 0.381275, precision= 0.235596, recall= 0.999005
# Validation Iter 90, auc= 0.621333, fmeasure_max= 0.651825, precision= 0.677778, recall= 0.627787
# Validation Random guess:  auc= 0.226364, fmeasure_max= 0.372167, precision= 0.228627, recall= 1.000000
# Minibatch Loss= 0.854402
# Tarin Iter 100, auc= 0.674415, fmeasure_max= 0.690227, precision= 0.694609, recall= 0.685901
# Train Random guess:  , auc= 0.225732fmeasure_max= 0.370620, precision= 0.227461, recall= 1.000000
# Validation Iter 100, auc= 0.646621, fmeasure_max= 0.659016, precision= 0.631083, recall= 0.689537
# Validation Random guess:  auc= 0.228445, fmeasure_max= 0.371693, precision= 0.228269, recall= 1.000000
# Minibatch Loss= 0.815681
# Tarin Iter 110, auc= 0.708710, fmeasure_max= 0.712378, precision= 0.716829, recall= 0.707981
# Train Random guess:  , auc= 0.232841fmeasure_max= 0.375406, precision= 0.231304, recall= 0.995773
# Validation Iter 110, auc= 0.696768, fmeasure_max= 0.703060, precision= 0.678914, recall= 0.728988
# Validation Random guess:  auc= 0.230521, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.814148
# Tarin Iter 120, auc= 0.732271, fmeasure_max= 0.727114, precision= 0.743000, recall= 0.711893
# Train Random guess:  , auc= 0.231199fmeasure_max= 0.372133, precision= 0.228628, recall= 0.999487
# Validation Iter 120, auc= 0.693870, fmeasure_max= 0.686907, precision= 0.768577, recall= 0.620926
# Validation Random guess:  auc= 0.223216, fmeasure_max= 0.372047, precision= 0.230020, recall= 0.972556
# Minibatch Loss= 0.788991
# Tarin Iter 130, auc= 0.753277, fmeasure_max= 0.727946, precision= 0.734375, recall= 0.721629
# Train Random guess:  , auc= 0.234822fmeasure_max= 0.379373, precision= 0.234090, recall= 1.000000
# Validation Iter 130, auc= 0.697817, fmeasure_max= 0.704933, precision= 0.738722, recall= 0.674099
# Validation Random guess:  auc= 0.225358, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.765942
# Tarin Iter 140, auc= 0.742663, fmeasure_max= 0.727181, precision= 0.723008, recall= 0.731404
# Train Random guess:  , auc= 0.232960fmeasure_max= 0.376767, precision= 0.232109, recall= 1.000000
# Validation Iter 140, auc= 0.730490, fmeasure_max= 0.719122, precision= 0.770588, recall= 0.674099
# Validation Random guess:  auc= 0.219961, fmeasure_max= 0.374414, precision= 0.232626, recall= 0.958834
# Minibatch Loss= 0.759738
# Tarin Iter 150, auc= 0.762742, fmeasure_max= 0.732911, precision= 0.740565, recall= 0.725413
# Train Random guess:  , auc= 0.227691fmeasure_max= 0.370293, precision= 0.227214, recall= 1.000000
# Validation Iter 150, auc= 0.733285, fmeasure_max= 0.689594, precision= 0.709619, recall= 0.670669
# Validation Random guess:  auc= 0.235451, fmeasure_max= 0.373506, precision= 0.230096, recall= 0.991424
# Minibatch Loss= 0.735890
# Tarin Iter 160, auc= 0.779320, fmeasure_max= 0.739030, precision= 0.776683, recall= 0.704860
# Train Random guess:  , auc= 0.230664fmeasure_max= 0.376020, precision= 0.231560, recall= 0.999663
# Validation Iter 160, auc= 0.768679, fmeasure_max= 0.713672, precision= 0.715517, recall= 0.711835
# Validation Random guess:  auc= 0.223915, fmeasure_max= 0.372736, precision= 0.230644, recall= 0.970840
# Minibatch Loss= 0.733649
# Tarin Iter 170, auc= 0.778088, fmeasure_max= 0.731429, precision= 0.755805, recall= 0.708576
# Train Random guess:  , auc= 0.231742fmeasure_max= 0.375803, precision= 0.231428, recall= 0.999062
# Validation Iter 170, auc= 0.765604, fmeasure_max= 0.715909, precision= 0.799154, recall= 0.648370
# Validation Random guess:  auc= 0.238067, fmeasure_max= 0.372762, precision= 0.229077, recall= 1.000000
# Minibatch Loss= 0.736414
# Tarin Iter 180, auc= 0.779206, fmeasure_max= 0.730669, precision= 0.749373, recall= 0.712875
# Train Random guess:  , auc= 0.225680fmeasure_max= 0.373157, precision= 0.229375, recall= 1.000000
# Validation Iter 180, auc= 0.773651, fmeasure_max= 0.721485, precision= 0.744526, recall= 0.699828
# Validation Random guess:  auc= 0.232524, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.764132
# Tarin Iter 190, auc= 0.774958, fmeasure_max= 0.730024, precision= 0.736409, recall= 0.723749
# Train Random guess:  , auc= 0.234923fmeasure_max= 0.376316, precision= 0.231767, recall= 1.000000
# Validation Iter 190, auc= 0.778586, fmeasure_max= 0.717866, precision= 0.678899, recall= 0.761578
# Validation Random guess:  auc= 0.218482, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.739843
# Tarin Iter 200, auc= 0.789536, fmeasure_max= 0.738026, precision= 0.769231, recall= 0.709255
# Train Random guess:  , auc= 0.240927fmeasure_max= 0.385174, precision= 0.238523, recall= 1.000000
# Validation Iter 200, auc= 0.758413, fmeasure_max= 0.704780, precision= 0.776860, recall= 0.644940
# Validation Random guess:  auc= 0.235916, fmeasure_max= 0.371344, precision= 0.229675, recall= 0.969125
# Minibatch Loss= 0.714977
# Tarin Iter 210, auc= 0.810923, fmeasure_max= 0.758150, precision= 0.772801, recall= 0.744045
# Train Random guess:  , auc= 0.225797fmeasure_max= 0.367055, precision= 0.224799, recall= 0.999652
# Validation Iter 210, auc= 0.781545, fmeasure_max= 0.726761, precision= 0.802905, recall= 0.663808
# Validation Random guess:  auc= 0.229696, fmeasure_max= 0.372619, precision= 0.229515, recall= 0.989708
# Minibatch Loss= 0.677018
# Tarin Iter 220, auc= 0.811723, fmeasure_max= 0.745031, precision= 0.757096, recall= 0.733345
# Train Random guess:  , auc= 0.228097fmeasure_max= 0.376171, precision= 0.231884, recall= 0.995783
# Validation Iter 220, auc= 0.782042, fmeasure_max= 0.720072, precision= 0.757576, recall= 0.686106
# Validation Random guess:  auc= 0.235406, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.677374
# Tarin Iter 230, auc= 0.813190, fmeasure_max= 0.751392, precision= 0.756757, recall= 0.746104
# Train Random guess:  , auc= 0.234924fmeasure_max= 0.378162, precision= 0.233196, recall= 0.999497
# Validation Iter 230, auc= 0.799563, fmeasure_max= 0.738326, precision= 0.759058, recall= 0.718696
# Validation Random guess:  auc= 0.224529, fmeasure_max= 0.374426, precision= 0.231455, recall= 0.979417
# Minibatch Loss= 0.679367
# Tarin Iter 240, auc= 0.831274, fmeasure_max= 0.769193, precision= 0.768051, recall= 0.770337
# Train Random guess:  , auc= 0.237128fmeasure_max= 0.382304, precision= 0.236475, recall= 0.997354
# Validation Iter 240, auc= 0.805028, fmeasure_max= 0.752879, precision= 0.778388, recall= 0.728988
# Validation Random guess:  auc= 0.242312, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.671594
# Tarin Iter 250, auc= 0.812937, fmeasure_max= 0.752787, precision= 0.781374, recall= 0.726218
# Train Random guess:  , auc= 0.233061fmeasure_max= 0.377232, precision= 0.232480, recall= 0.999664
# Validation Iter 250, auc= 0.776477, fmeasure_max= 0.707471, precision= 0.744318, recall= 0.674099
# Validation Random guess:  auc= 0.238613, fmeasure_max= 0.372077, precision= 0.231024, recall= 0.955403
# Minibatch Loss= 0.688612
# Tarin Iter 260, auc= 0.829268, fmeasure_max= 0.768598, precision= 0.779027, recall= 0.758445
# Train Random guess:  , auc= 0.231736fmeasure_max= 0.374142, precision= 0.230240, recall= 0.997735
# Validation Iter 260, auc= 0.792741, fmeasure_max= 0.735552, precision= 0.751342, recall= 0.720412
# Validation Random guess:  auc= 0.225498, fmeasure_max= 0.371811, precision= 0.228359, recall= 1.000000
# Minibatch Loss= 0.648143
# Tarin Iter 270, auc= 0.835930, fmeasure_max= 0.774765, precision= 0.774204, recall= 0.775326
# Train Random guess:  , auc= 0.246702fmeasure_max= 0.390500, precision= 0.242641, recall= 0.999678
# Validation Iter 270, auc= 0.802632, fmeasure_max= 0.728070, precision= 0.745063, recall= 0.711835
# Validation Random guess:  auc= 0.220021, fmeasure_max= 0.373533, precision= 0.230584, recall= 0.982847
# Minibatch Loss= 0.649600
# Tarin Iter 280, auc= 0.816950, fmeasure_max= 0.750859, precision= 0.803275, recall= 0.704864
# Train Random guess:  , auc= 0.211703fmeasure_max= 0.350298, precision= 0.212549, recall= 0.995394
# Validation Iter 280, auc= 0.794553, fmeasure_max= 0.729373, precision= 0.702703, recall= 0.758148
# Validation Random guess:  auc= 0.227834, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.641854
# Tarin Iter 290, auc= 0.842163, fmeasure_max= 0.769908, precision= 0.809709, recall= 0.733837
# Train Random guess:  , auc= 0.230660fmeasure_max= 0.377555, precision= 0.232771, recall= 0.998825
# Validation Iter 290, auc= 0.812016, fmeasure_max= 0.730077, precision= 0.729452, recall= 0.730703
# Validation Random guess:  auc= 0.227219, fmeasure_max= 0.371757, precision= 0.229894, recall= 0.970840
# Minibatch Loss= 0.633632
# Tarin Iter 300, auc= 0.846721, fmeasure_max= 0.774326, precision= 0.790657, recall= 0.758655
# Train Random guess:  , auc= 0.234318fmeasure_max= 0.378929, precision= 0.233963, recall= 0.996153
# Validation Iter 300, auc= 0.791526, fmeasure_max= 0.702756, precision= 0.824480, recall= 0.612350
# Validation Random guess:  auc= 0.236798, fmeasure_max= 0.372108, precision= 0.228944, recall= 0.993139
# Minibatch Loss= 0.631108
# Tarin Iter 310, auc= 0.845465, fmeasure_max= 0.784501, precision= 0.782298, recall= 0.786717
# Train Random guess:  , auc= 0.233490fmeasure_max= 0.371777, precision= 0.228485, recall= 0.997090
# Validation Iter 310, auc= 0.808343, fmeasure_max= 0.757498, precision= 0.756849, recall= 0.758148
# Validation Random guess:  auc= 0.244126, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.641330
# Tarin Iter 320, auc= 0.834221, fmeasure_max= 0.769994, precision= 0.779010, recall= 0.761184
# Train Random guess:  , auc= 0.225329fmeasure_max= 0.370132, precision= 0.227093, recall= 1.000000
# Validation Iter 320, auc= 0.798104, fmeasure_max= 0.742475, precision= 0.724307, recall= 0.761578
# Validation Random guess:  auc= 0.217664, fmeasure_max= 0.372062, precision= 0.230517, recall= 0.963979
# Minibatch Loss= 0.656109
# Tarin Iter 330, auc= 0.840730, fmeasure_max= 0.776459, precision= 0.765074, recall= 0.788187
# Train Random guess:  , auc= 0.222601fmeasure_max= 0.374305, precision= 0.230252, recall= 0.999830
# Validation Iter 330, auc= 0.799924, fmeasure_max= 0.736387, precision= 0.742160, recall= 0.730703
# Validation Random guess:  auc= 0.241093, fmeasure_max= 0.372372, precision= 0.231152, recall= 0.957118
# Minibatch Loss= 0.647521
# Tarin Iter 340, auc= 0.851473, fmeasure_max= 0.771102, precision= 0.757192, recall= 0.785534
# Train Random guess:  , auc= 0.232433fmeasure_max= 0.376214, precision= 0.231716, recall= 0.999494
# Validation Iter 340, auc= 0.788416, fmeasure_max= 0.715493, precision= 0.790456, recall= 0.653516
# Validation Random guess:  auc= 0.237410, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.607285
# Tarin Iter 350, auc= 0.834504, fmeasure_max= 0.769841, precision= 0.773054, recall= 0.766654
# Train Random guess:  , auc= 0.224076fmeasure_max= 0.367953, precision= 0.225474, recall= 0.999615
# Validation Iter 350, auc= 0.811664, fmeasure_max= 0.747646, precision= 0.828810, recall= 0.680961
# Validation Random guess:  auc= 0.242819, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.643792
# Tarin Iter 360, auc= 0.862530, fmeasure_max= 0.790648, precision= 0.763466, recall= 0.819837
# Train Random guess:  , auc= 0.227288fmeasure_max= 0.373605, precision= 0.229749, recall= 0.999319
# Validation Iter 360, auc= 0.796919, fmeasure_max= 0.733040, precision= 0.753623, recall= 0.713551
# Validation Random guess:  auc= 0.239636, fmeasure_max= 0.371419, precision= 0.228605, recall= 0.989708
# Minibatch Loss= 0.606686
# Tarin Iter 370, auc= 0.852419, fmeasure_max= 0.779697, precision= 0.791689, recall= 0.768063
# Train Random guess:  , auc= 0.222948fmeasure_max= 0.365987, precision= 0.224200, recall= 0.995637
# Validation Iter 370, auc= 0.802326, fmeasure_max= 0.731915, precision= 0.726351, recall= 0.737564
# Validation Random guess:  auc= 0.225214, fmeasure_max= 0.371687, precision= 0.228992, recall= 0.986278
# Minibatch Loss= 0.604277
# Tarin Iter 380, auc= 0.876325, fmeasure_max= 0.811022, precision= 0.829346, recall= 0.793489
# Train Random guess:  , auc= 0.230300fmeasure_max= 0.374571, precision= 0.230445, recall= 1.000000
# Validation Iter 380, auc= 0.803486, fmeasure_max= 0.723297, precision= 0.709571, recall= 0.737564
# Validation Random guess:  auc= 0.238441, fmeasure_max= 0.371869, precision= 0.228763, recall= 0.993139
# Minibatch Loss= 0.573809
# Tarin Iter 390, auc= 0.890328, fmeasure_max= 0.819835, precision= 0.814078, recall= 0.825674
# Train Random guess:  , auc= 0.230286fmeasure_max= 0.374547, precision= 0.230498, recall= 0.998643
# Validation Iter 390, auc= 0.822699, fmeasure_max= 0.751092, precision= 0.765125, recall= 0.737564
# Validation Random guess:  auc= 0.242661, fmeasure_max= 0.372289, precision= 0.229449, recall= 0.986278
# Minibatch Loss= 0.550975
# Tarin Iter 400, auc= 0.874232, fmeasure_max= 0.806851, precision= 0.810558, recall= 0.803178
# Train Random guess:  , auc= 0.235485fmeasure_max= 0.382054, precision= 0.236246, recall= 0.998014
# Validation Iter 400, auc= 0.837887, fmeasure_max= 0.773842, precision= 0.822394, recall= 0.730703
# Validation Random guess:  auc= 0.237883, fmeasure_max= 0.371669, precision= 0.231318, recall= 0.945111
# Minibatch Loss= 0.591255
# Tarin Iter 410, auc= 0.850047, fmeasure_max= 0.783444, precision= 0.779997, recall= 0.786922
# Train Random guess:  , auc= 0.227110fmeasure_max= 0.372536, precision= 0.228977, recall= 0.998634
# Validation Iter 410, auc= 0.813319, fmeasure_max= 0.748052, precision= 0.755245, recall= 0.740995
# Validation Random guess:  auc= 0.223058, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.608476
# Tarin Iter 420, auc= 0.859364, fmeasure_max= 0.784327, precision= 0.789393, recall= 0.779325
# Train Random guess:  , auc= 0.231832fmeasure_max= 0.377815, precision= 0.233235, recall= 0.993959
# Validation Iter 420, auc= 0.807564, fmeasure_max= 0.750665, precision= 0.777574, recall= 0.725557
# Validation Random guess:  auc= 0.234220, fmeasure_max= 0.372306, precision= 0.229931, recall= 0.977702
# Minibatch Loss= 0.601186
# Tarin Iter 430, auc= 0.881811, fmeasure_max= 0.810696, precision= 0.802664, recall= 0.818890
# Train Random guess:  , auc= 0.236067fmeasure_max= 0.381570, precision= 0.235784, recall= 0.999669
# Validation Iter 430, auc= 0.802463, fmeasure_max= 0.724907, precision= 0.791075, recall= 0.668954
# Validation Random guess:  auc= 0.226837, fmeasure_max= 0.371914, precision= 0.228707, recall= 0.994854
# Minibatch Loss= 0.588906
# Tarin Iter 440, auc= 0.852592, fmeasure_max= 0.785858, precision= 0.825958, recall= 0.749472
# Train Random guess:  , auc= 0.227345fmeasure_max= 0.368594, precision= 0.225947, recall= 0.999808
# Validation Iter 440, auc= 0.795978, fmeasure_max= 0.720227, precision= 0.802105, recall= 0.653516
# Validation Random guess:  auc= 0.221369, fmeasure_max= 0.372093, precision= 0.229960, recall= 0.974271
# Minibatch Loss= 0.617590
# Tarin Iter 450, auc= 0.880889, fmeasure_max= 0.808963, precision= 0.821994, recall= 0.796338
# Train Random guess:  , auc= 0.228588fmeasure_max= 0.366056, precision= 0.224032, recall= 1.000000
# Validation Iter 450, auc= 0.829553, fmeasure_max= 0.757630, precision= 0.794727, recall= 0.723842
# Validation Random guess:  auc= 0.223197, fmeasure_max= 0.373994, precision= 0.230190, recall= 0.996569
# Minibatch Loss= 0.582633
# Tarin Iter 460, auc= 0.872105, fmeasure_max= 0.798583, precision= 0.796811, recall= 0.800363
# Train Random guess:  , auc= 0.236435fmeasure_max= 0.382637, precision= 0.236581, recall= 1.000000
# Validation Iter 460, auc= 0.800941, fmeasure_max= 0.723792, precision= 0.772374, recall= 0.680961
# Validation Random guess:  auc= 0.223800, fmeasure_max= 0.371009, precision= 0.227933, recall= 0.996569
# Minibatch Loss= 0.596206
# Tarin Iter 470, auc= 0.887390, fmeasure_max= 0.816095, precision= 0.817528, recall= 0.814667
# Train Random guess:  , auc= 0.239824fmeasure_max= 0.379894, precision= 0.234792, recall= 0.994500
# Validation Iter 470, auc= 0.791780, fmeasure_max= 0.731490, precision= 0.762082, recall= 0.703259
# Validation Random guess:  auc= 0.245040, fmeasure_max= 0.371207, precision= 0.228628, recall= 0.986278
# Minibatch Loss= 0.552566
# Tarin Iter 480, auc= 0.893881, fmeasure_max= 0.827574, precision= 0.825997, recall= 0.829158
# Train Random guess:  , auc= 0.227669fmeasure_max= 0.366792, precision= 0.224584, recall= 1.000000
# Validation Iter 480, auc= 0.826359, fmeasure_max= 0.758371, precision= 0.802682, recall= 0.718696
# Validation Random guess:  auc= 0.219487, fmeasure_max= 0.372108, precision= 0.228944, recall= 0.993139
# Minibatch Loss= 0.542696
# Tarin Iter 490, auc= 0.884062, fmeasure_max= 0.821636, precision= 0.818469, recall= 0.824828
# Train Random guess:  , auc= 0.223216fmeasure_max= 0.362386, precision= 0.221289, recall= 1.000000
# Validation Iter 490, auc= 0.814250, fmeasure_max= 0.748624, precision= 0.804734, recall= 0.699828
# Validation Random guess:  auc= 0.225022, fmeasure_max= 0.371716, precision= 0.229200, recall= 0.982847
# Minibatch Loss= 0.535484
# Tarin Iter 500, auc= 0.876755, fmeasure_max= 0.805636, precision= 0.839504, recall= 0.774394
# Train Random guess:  , auc= 0.234168fmeasure_max= 0.377226, precision= 0.232677, recall= 0.995962
# Validation Iter 500, auc= 0.810838, fmeasure_max= 0.728333, precision= 0.708266, recall= 0.749571
# Validation Random guess:  auc= 0.238119, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.572540
# Tarin Iter 510, auc= 0.889695, fmeasure_max= 0.819580, precision= 0.816066, recall= 0.823124
# Train Random guess:  , auc= 0.224538fmeasure_max= 0.362990, precision= 0.222152, recall= 0.991703
# Validation Iter 510, auc= 0.807894, fmeasure_max= 0.725490, precision= 0.755102, recall= 0.698113
# Validation Random guess:  auc= 0.224541, fmeasure_max= 0.371410, precision= 0.228146, recall= 0.998285
# Minibatch Loss= 0.534498
# Tarin Iter 520, auc= 0.883133, fmeasure_max= 0.808013, precision= 0.802944, recall= 0.813146
# Train Random guess:  , auc= 0.229430fmeasure_max= 0.374841, precision= 0.230703, recall= 0.998984
# Validation Iter 520, auc= 0.807133, fmeasure_max= 0.728723, precision= 0.754128, recall= 0.704974
# Validation Random guess:  auc= 0.217415, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.586546
# Tarin Iter 530, auc= 0.884099, fmeasure_max= 0.810821, precision= 0.807831, recall= 0.813834
# Train Random guess:  , auc= 0.231440fmeasure_max= 0.371101, precision= 0.227833, recall= 0.999809
# Validation Iter 530, auc= 0.805785, fmeasure_max= 0.727599, precision= 0.761726, recall= 0.696398
# Validation Random guess:  auc= 0.236823, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.566149
# Tarin Iter 540, auc= 0.898729, fmeasure_max= 0.826530, precision= 0.816399, recall= 0.836915
# Train Random guess:  , auc= 0.228273fmeasure_max= 0.368143, precision= 0.226398, recall= 0.984575
# Validation Iter 540, auc= 0.799841, fmeasure_max= 0.723048, precision= 0.789047, recall= 0.667238
# Validation Random guess:  auc= 0.228541, fmeasure_max= 0.371200, precision= 0.228167, recall= 0.994854
# Minibatch Loss= 0.509853
# Tarin Iter 550, auc= 0.891970, fmeasure_max= 0.821742, precision= 0.803081, recall= 0.841291
# Train Random guess:  , auc= 0.235882fmeasure_max= 0.380819, precision= 0.235554, recall= 0.993512
# Validation Iter 550, auc= 0.808341, fmeasure_max= 0.733610, precision= 0.710611, recall= 0.758148
# Validation Random guess:  auc= 0.226116, fmeasure_max= 0.371180, precision= 0.228424, recall= 0.989708
# Minibatch Loss= 0.557491
# Tarin Iter 560, auc= 0.898666, fmeasure_max= 0.824499, precision= 0.819791, recall= 0.829260
# Train Random guess:  , auc= 0.229258fmeasure_max= 0.378421, precision= 0.233375, recall= 0.999833
# Validation Iter 560, auc= 0.812601, fmeasure_max= 0.726786, precision= 0.757914, recall= 0.698113
# Validation Random guess:  auc= 0.213417, fmeasure_max= 0.375167, precision= 0.232905, recall= 0.963979
# Minibatch Loss= 0.538750
# Tarin Iter 570, auc= 0.897108, fmeasure_max= 0.831422, precision= 0.821995, recall= 0.841068
# Train Random guess:  , auc= 0.223046fmeasure_max= 0.365943, precision= 0.224009, recall= 0.998779
# Validation Iter 570, auc= 0.806036, fmeasure_max= 0.732026, precision= 0.803279, recall= 0.672384
# Validation Random guess:  auc= 0.231856, fmeasure_max= 0.371560, precision= 0.229648, recall= 0.972556
# Minibatch Loss= 0.523661
# Tarin Iter 580, auc= 0.906119, fmeasure_max= 0.830988, precision= 0.830713, recall= 0.831263
# Train Random guess:  , auc= 0.236253fmeasure_max= 0.381800, precision= 0.236033, recall= 0.998344
# Validation Iter 580, auc= 0.813236, fmeasure_max= 0.742601, precision= 0.778195, recall= 0.710120
# Validation Random guess:  auc= 0.217610, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.528973
# Tarin Iter 590, auc= 0.893783, fmeasure_max= 0.815000, precision= 0.812543, recall= 0.817473
# Train Random guess:  , auc= 0.225543fmeasure_max= 0.367872, precision= 0.225438, recall= 0.999133
# Validation Iter 590, auc= 0.809383, fmeasure_max= 0.741365, precision= 0.728477, recall= 0.754717
# Validation Random guess:  auc= 0.229467, fmeasure_max= 0.371227, precision= 0.228368, recall= 0.991424
# Minibatch Loss= 0.526413
# Tarin Iter 600, auc= 0.898386, fmeasure_max= 0.825049, precision= 0.812552, recall= 0.837936
# Train Random guess:  , auc= 0.226818fmeasure_max= 0.369441, precision= 0.226644, recall= 0.998619
# Validation Iter 600, auc= 0.790321, fmeasure_max= 0.713781, precision= 0.735883, recall= 0.692967
# Validation Random guess:  auc= 0.222916, fmeasure_max= 0.371659, precision= 0.228787, recall= 0.989708
# Minibatch Loss= 0.534872
# Tarin Iter 610, auc= 0.892521, fmeasure_max= 0.814209, precision= 0.809292, recall= 0.819185
# Train Random guess:  , auc= 0.227860fmeasure_max= 0.374166, precision= 0.230174, recall= 0.999321
# Validation Iter 610, auc= 0.799803, fmeasure_max= 0.716253, precision= 0.770751, recall= 0.668954
# Validation Random guess:  auc= 0.229250, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.554977
# Tarin Iter 620, auc= 0.892021, fmeasure_max= 0.818487, precision= 0.773380, recall= 0.869182
# Train Random guess:  , auc= 0.230135fmeasure_max= 0.376009, precision= 0.232166, recall= 0.988363
# Validation Iter 620, auc= 0.801068, fmeasure_max= 0.723735, precision= 0.835955, recall= 0.638079
# Validation Random guess:  auc= 0.222759, fmeasure_max= 0.372719, precision= 0.229134, recall= 0.998285
# Minibatch Loss= 0.531970
# Tarin Iter 630, auc= 0.912860, fmeasure_max= 0.842496, precision= 0.858714, recall= 0.826879
# Train Random guess:  , auc= 0.238334fmeasure_max= 0.382343, precision= 0.236402, recall= 0.999172
# Validation Iter 630, auc= 0.825591, fmeasure_max= 0.737673, precision= 0.867749, recall= 0.641509
# Validation Random guess:  auc= 0.210186, fmeasure_max= 0.372643, precision= 0.228987, recall= 1.000000
# Minibatch Loss= 0.531382
# Tarin Iter 640, auc= 0.903246, fmeasure_max= 0.827276, precision= 0.818325, recall= 0.836425
# Train Random guess:  , auc= 0.217087fmeasure_max= 0.359290, precision= 0.218984, recall= 1.000000
# Validation Iter 640, auc= 0.791315, fmeasure_max= 0.712438, precision= 0.848341, recall= 0.614065
# Validation Random guess:  auc= 0.239491, fmeasure_max= 0.371081, precision= 0.228077, recall= 0.994854
# Minibatch Loss= 0.508917
# Tarin Iter 650, auc= 0.904146, fmeasure_max= 0.833389, precision= 0.823676, recall= 0.843334
# Train Random guess:  , auc= 0.227641fmeasure_max= 0.372847, precision= 0.229141, recall= 1.000000
# Validation Iter 650, auc= 0.814636, fmeasure_max= 0.717412, precision= 0.805556, recall= 0.646655
# Validation Random guess:  auc= 0.223657, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.533315
# Tarin Iter 660, auc= 0.900113, fmeasure_max= 0.830226, precision= 0.815691, recall= 0.845288
# Train Random guess:  , auc= 0.231584fmeasure_max= 0.377426, precision= 0.232709, recall= 0.998152
# Validation Iter 660, auc= 0.785413, fmeasure_max= 0.708098, precision= 0.784969, recall= 0.644940
# Validation Random guess:  auc= 0.236533, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.527994
# Tarin Iter 670, auc= 0.911720, fmeasure_max= 0.829328, precision= 0.840007, recall= 0.818917
# Train Random guess:  , auc= 0.232419fmeasure_max= 0.370425, precision= 0.227322, recall= 0.999828
# Validation Iter 670, auc= 0.811246, fmeasure_max= 0.729537, precision= 0.757856, recall= 0.703259
# Validation Random guess:  auc= 0.232663, fmeasure_max= 0.371493, precision= 0.228753, recall= 0.987993
# Minibatch Loss= 0.508054
# Tarin Iter 680, auc= 0.911746, fmeasure_max= 0.831701, precision= 0.807060, recall= 0.857895
# Train Random guess:  , auc= 0.235888fmeasure_max= 0.374158, precision= 0.230159, recall= 0.999491
# Validation Iter 680, auc= 0.792397, fmeasure_max= 0.711069, precision= 0.784679, recall= 0.650086
# Validation Random guess:  auc= 0.253095, fmeasure_max= 0.372581, precision= 0.230333, recall= 0.974271
# Minibatch Loss= 0.511221
# Tarin Iter 690, auc= 0.912491, fmeasure_max= 0.837412, precision= 0.856620, recall= 0.819046
# Train Random guess:  , auc= 0.235934fmeasure_max= 0.379635, precision= 0.234299, recall= 0.999833
# Validation Iter 690, auc= 0.796958, fmeasure_max= 0.712406, precision= 0.787942, recall= 0.650086
# Validation Random guess:  auc= 0.230647, fmeasure_max= 0.372317, precision= 0.228920, recall= 0.996569
# Minibatch Loss= 0.523373
# Tarin Iter 700, auc= 0.919309, fmeasure_max= 0.842096, precision= 0.849851, recall= 0.834482
# Train Random guess:  , auc= 0.222739fmeasure_max= 0.369750, precision= 0.226806, recall= 1.000000
# Validation Iter 700, auc= 0.805853, fmeasure_max= 0.719221, precision= 0.743590, recall= 0.696398
# Validation Random guess:  auc= 0.226729, fmeasure_max= 0.371648, precision= 0.228325, recall= 0.998285
# Minibatch Loss= 0.499052
# Tarin Iter 710, auc= 0.921769, fmeasure_max= 0.850556, precision= 0.852020, recall= 0.849097
# Train Random guess:  , auc= 0.246412fmeasure_max= 0.387757, precision= 0.240549, recall= 0.999278
# Validation Iter 710, auc= 0.812093, fmeasure_max= 0.725664, precision= 0.749543, recall= 0.703259
# Validation Random guess:  auc= 0.223962, fmeasure_max= 0.371438, precision= 0.228346, recall= 0.994854
# Minibatch Loss= 0.516303
# Tarin Iter 720, auc= 0.932015, fmeasure_max= 0.856690, precision= 0.857899, recall= 0.855483
# Train Random guess:  , auc= 0.223776fmeasure_max= 0.363317, precision= 0.221983, recall= 1.000000
# Validation Iter 720, auc= 0.810206, fmeasure_max= 0.720346, precision= 0.727273, recall= 0.713551
# Validation Random guess:  auc= 0.224869, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.461625
# Tarin Iter 730, auc= 0.933233, fmeasure_max= 0.867125, precision= 0.868831, recall= 0.865425
# Train Random guess:  , auc= 0.243060fmeasure_max= 0.386124, precision= 0.239262, recall= 0.999837
# Validation Iter 730, auc= 0.793437, fmeasure_max= 0.704126, precision= 0.721223, recall= 0.687822
# Validation Random guess:  auc= 0.229539, fmeasure_max= 0.372405, precision= 0.228807, recall= 1.000000
# Minibatch Loss= 0.514998
# Tarin Iter 740, auc= 0.913047, fmeasure_max= 0.834425, precision= 0.847138, recall= 0.822088
# Train Random guess:  , auc= 0.236440fmeasure_max= 0.385964, precision= 0.239130, recall= 1.000000
# Validation Iter 740, auc= 0.788155, fmeasure_max= 0.697318, precision= 0.789588, recall= 0.624357
# Validation Random guess:  auc= 0.220236, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.553324
# Tarin Iter 750, auc= 0.912458, fmeasure_max= 0.842150, precision= 0.857118, recall= 0.827695
# Train Random guess:  , auc= 0.230900fmeasure_max= 0.379846, precision= 0.234451, recall= 1.000000
# Validation Iter 750, auc= 0.778004, fmeasure_max= 0.706103, precision= 0.780083, recall= 0.644940
# Validation Random guess:  auc= 0.217515, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.515471
# Tarin Iter 760, auc= 0.909380, fmeasure_max= 0.830272, precision= 0.840966, recall= 0.819847
# Train Random guess:  , auc= 0.224722fmeasure_max= 0.366029, precision= 0.224047, recall= 0.999302
# Validation Iter 760, auc= 0.808551, fmeasure_max= 0.723600, precision= 0.778656, recall= 0.675815
# Validation Random guess:  auc= 0.237805, fmeasure_max= 0.371401, precision= 0.228868, recall= 0.984563
# Minibatch Loss= 0.514292
# Tarin Iter 770, auc= 0.913698, fmeasure_max= 0.839765, precision= 0.847346, recall= 0.832318
# Train Random guess:  , auc= 0.216574fmeasure_max= 0.358397, precision= 0.218570, recall= 0.994805
# Validation Iter 770, auc= 0.796534, fmeasure_max= 0.713450, precision= 0.826185, recall= 0.627787
# Validation Random guess:  auc= 0.218536, fmeasure_max= 0.371795, precision= 0.228616, recall= 0.994854
# Minibatch Loss= 0.494538
# Tarin Iter 780, auc= 0.927534, fmeasure_max= 0.853001, precision= 0.854126, recall= 0.851878
# Train Random guess:  , auc= 0.220613fmeasure_max= 0.364528, precision= 0.222967, recall= 0.998420
# Validation Iter 780, auc= 0.789020, fmeasure_max= 0.714829, precision= 0.801706, recall= 0.644940
# Validation Random guess:  auc= 0.229965, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.466972
# Tarin Iter 790, auc= 0.928975, fmeasure_max= 0.859801, precision= 0.858945, recall= 0.860658
# Train Random guess:  , auc= 0.235273fmeasure_max= 0.380578, precision= 0.235064, recall= 0.999002
# Validation Iter 790, auc= 0.784875, fmeasure_max= 0.729805, precision= 0.795547, recall= 0.674099
# Validation Random guess:  auc= 0.224015, fmeasure_max= 0.375126, precision= 0.233278, recall= 0.957118
# Minibatch Loss= 0.485176
# Tarin Iter 800, auc= 0.923700, fmeasure_max= 0.861022, precision= 0.851230, recall= 0.871042
# Train Random guess:  , auc= 0.228384fmeasure_max= 0.370708, precision= 0.227527, recall= 1.000000
# Validation Iter 800, auc= 0.793553, fmeasure_max= 0.707930, precision= 0.811530, recall= 0.627787
# Validation Random guess:  auc= 0.231021, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.490168
# Tarin Iter 810, auc= 0.933378, fmeasure_max= 0.862132, precision= 0.861269, recall= 0.862998
# Train Random guess:  , auc= 0.233896fmeasure_max= 0.378873, precision= 0.233801, recall= 0.998327
# Validation Iter 810, auc= 0.793505, fmeasure_max= 0.701209, precision= 0.706087, recall= 0.696398
# Validation Random guess:  auc= 0.227339, fmeasure_max= 0.372138, precision= 0.229150, recall= 0.989708
# Minibatch Loss= 0.478067
# Tarin Iter 820, auc= 0.920388, fmeasure_max= 0.851149, precision= 0.842884, recall= 0.859578
# Train Random guess:  , auc= 0.246996fmeasure_max= 0.387909, precision= 0.240625, recall= 1.000000
# Validation Iter 820, auc= 0.795717, fmeasure_max= 0.710158, precision= 0.777551, recall= 0.653516
# Validation Random guess:  auc= 0.243549, fmeasure_max= 0.371338, precision= 0.228002, recall= 1.000000
# Minibatch Loss= 0.492599
# Tarin Iter 830, auc= 0.930819, fmeasure_max= 0.857987, precision= 0.869266, recall= 0.846996
# Train Random guess:  , auc= 0.222324fmeasure_max= 0.362395, precision= 0.221356, recall= 0.998763
# Validation Iter 830, auc= 0.784866, fmeasure_max= 0.707581, precision= 0.746667, recall= 0.672384
# Validation Random guess:  auc= 0.232909, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.465994
# Tarin Iter 840, auc= 0.920888, fmeasure_max= 0.853104, precision= 0.849895, recall= 0.856337
# Train Random guess:  , auc= 0.228361fmeasure_max= 0.362979, precision= 0.221766, recall= 0.999295
# Validation Iter 840, auc= 0.783190, fmeasure_max= 0.712821, precision= 0.710392, recall= 0.715266
# Validation Random guess:  auc= 0.226183, fmeasure_max= 0.373951, precision= 0.232471, recall= 0.955403
# Minibatch Loss= 0.483173
# Tarin Iter 850, auc= 0.923846, fmeasure_max= 0.848988, precision= 0.858642, recall= 0.839548
# Train Random guess:  , auc= 0.228874fmeasure_max= 0.371895, precision= 0.228422, recall= 1.000000
# Validation Iter 850, auc= 0.773090, fmeasure_max= 0.706107, precision= 0.795699, recall= 0.634648
# Validation Random guess:  auc= 0.240914, fmeasure_max= 0.372472, precision= 0.229964, recall= 0.979417
# Minibatch Loss= 0.492308
# Tarin Iter 860, auc= 0.933114, fmeasure_max= 0.864050, precision= 0.865440, recall= 0.862665
# Train Random guess:  , auc= 0.222685fmeasure_max= 0.359710, precision= 0.219297, recall= 1.000000
# Validation Iter 860, auc= 0.796479, fmeasure_max= 0.727097, precision= 0.830396, recall= 0.646655
# Validation Random guess:  auc= 0.223205, fmeasure_max= 0.372197, precision= 0.228830, recall= 0.996569
# Minibatch Loss= 0.458355
# Tarin Iter 870, auc= 0.936046, fmeasure_max= 0.857461, precision= 0.856874, recall= 0.858048
# Train Random guess:  , auc= 0.232284fmeasure_max= 0.371655, precision= 0.228358, recall= 0.997774
# Validation Iter 870, auc= 0.804932, fmeasure_max= 0.715789, precision= 0.809524, recall= 0.641509
# Validation Random guess:  auc= 0.240799, fmeasure_max= 0.371438, precision= 0.229555, recall= 0.972556
# Minibatch Loss= 0.465782
# Tarin Iter 880, auc= 0.936137, fmeasure_max= 0.866851, precision= 0.857855, recall= 0.876039
# Train Random guess:  , auc= 0.229176fmeasure_max= 0.374511, precision= 0.230444, recall= 0.999152
# Validation Iter 880, auc= 0.796259, fmeasure_max= 0.705996, precision= 0.809313, recall= 0.626072
# Validation Random guess:  auc= 0.236245, fmeasure_max= 0.371101, precision= 0.227823, recall= 1.000000
# Minibatch Loss= 0.461200
# Tarin Iter 890, auc= 0.930077, fmeasure_max= 0.850404, precision= 0.831789, recall= 0.869871
# Train Random guess:  , auc= 0.228275fmeasure_max= 0.372027, precision= 0.228522, recall= 1.000000
# Validation Iter 890, auc= 0.787289, fmeasure_max= 0.702751, precision= 0.727941, recall= 0.679245
# Validation Random guess:  auc= 0.231958, fmeasure_max= 0.371108, precision= 0.228278, recall= 0.991424
# Minibatch Loss= 0.464699
# Tarin Iter 900, auc= 0.940644, fmeasure_max= 0.868684, precision= 0.864648, recall= 0.872757
# Train Random guess:  , auc= 0.239396fmeasure_max= 0.389306, precision= 0.241872, recall= 0.997090
# Validation Iter 900, auc= 0.794496, fmeasure_max= 0.707224, precision= 0.793177, recall= 0.638079
# Validation Random guess:  auc= 0.225003, fmeasure_max= 0.374830, precision= 0.233772, recall= 0.945111
# Minibatch Loss= 0.472863
# Tarin Iter 910, auc= 0.951862, fmeasure_max= 0.884946, precision= 0.883614, recall= 0.886283
# Train Random guess:  , auc= 0.223464fmeasure_max= 0.360762, precision= 0.220105, recall= 0.999467
# Validation Iter 910, auc= 0.791628, fmeasure_max= 0.723104, precision= 0.744102, recall= 0.703259
# Validation Random guess:  auc= 0.244423, fmeasure_max= 0.374839, precision= 0.230830, recall= 0.996569
# Minibatch Loss= 0.419456
# Tarin Iter 920, auc= 0.937716, fmeasure_max= 0.869483, precision= 0.864879, recall= 0.874137
# Train Random guess:  , auc= 0.222178fmeasure_max= 0.369244, precision= 0.226558, recall= 0.997410
# Validation Iter 920, auc= 0.788937, fmeasure_max= 0.709677, precision= 0.825000, recall= 0.622642
# Validation Random guess:  auc= 0.227011, fmeasure_max= 0.371574, precision= 0.228180, recall= 1.000000
# Minibatch Loss= 0.457296
# Tarin Iter 930, auc= 0.936851, fmeasure_max= 0.864420, precision= 0.860579, recall= 0.868296
# Train Random guess:  , auc= 0.219523fmeasure_max= 0.363700, precision= 0.222410, recall= 0.997187
# Validation Iter 930, auc= 0.778937, fmeasure_max= 0.709804, precision= 0.828375, recall= 0.620926
# Validation Random guess:  auc= 0.223997, fmeasure_max= 0.370983, precision= 0.227734, recall= 1.000000
# Minibatch Loss= 0.448245
# Tarin Iter 940, auc= 0.948359, fmeasure_max= 0.876753, precision= 0.876601, recall= 0.876904
# Train Random guess:  , auc= 0.224248fmeasure_max= 0.368567, precision= 0.225978, recall= 0.998788
# Validation Iter 940, auc= 0.800064, fmeasure_max= 0.711155, precision= 0.847981, recall= 0.612350
# Validation Random guess:  auc= 0.222787, fmeasure_max= 0.371456, precision= 0.228091, recall= 1.000000
# Minibatch Loss= 0.449129
# Tarin Iter 950, auc= 0.941032, fmeasure_max= 0.873503, precision= 0.881457, recall= 0.865692
# Train Random guess:  , auc= 0.224916fmeasure_max= 0.370260, precision= 0.227198, recall= 0.999828
# Validation Iter 950, auc= 0.786095, fmeasure_max= 0.715378, precision= 0.708754, recall= 0.722127
# Validation Random guess:  auc= 0.243753, fmeasure_max= 0.371219, precision= 0.227912, recall= 1.000000
# Minibatch Loss= 0.450375
# Tarin Iter 960, auc= 0.940194, fmeasure_max= 0.862662, precision= 0.860547, recall= 0.864789
# Train Random guess:  , auc= 0.221742fmeasure_max= 0.363252, precision= 0.222057, recall= 0.997535
# Validation Iter 960, auc= 0.789902, fmeasure_max= 0.706522, precision= 0.748560, recall= 0.668954
# Validation Random guess:  auc= 0.224199, fmeasure_max= 0.371365, precision= 0.228201, recall= 0.996569
# Minibatch Loss= 0.449359
# Tarin Iter 970, auc= 0.946285, fmeasure_max= 0.871666, precision= 0.874210, recall= 0.869138
# Train Random guess:  , auc= 0.243328fmeasure_max= 0.390391, precision= 0.242978, recall= 0.992587
# Validation Iter 970, auc= 0.787419, fmeasure_max= 0.714414, precision= 0.747191, recall= 0.684391
# Validation Random guess:  auc= 0.229646, fmeasure_max= 0.371930, precision= 0.228448, recall= 1.000000
# Minibatch Loss= 0.466063
# Tarin Iter 980, auc= 0.943742, fmeasure_max= 0.869378, precision= 0.861025, recall= 0.877894
# Train Random guess:  , auc= 0.221425fmeasure_max= 0.359917, precision= 0.219479, recall= 0.999406
# Validation Iter 980, auc= 0.778308, fmeasure_max= 0.706781, precision= 0.797414, recall= 0.634648
# Validation Random guess:  auc= 0.234876, fmeasure_max= 0.371539, precision= 0.228696, recall= 0.989708
# Minibatch Loss= 0.435211
# Tarin Iter 990, auc= 0.942565, fmeasure_max= 0.870112, precision= 0.875620, recall= 0.864673
# Train Random guess:  , auc= 0.234922fmeasure_max= 0.375803, precision= 0.231505, recall= 0.997635
# Validation Iter 990, auc= 0.792034, fmeasure_max= 0.701107, precision= 0.758483, recall= 0.651801
# Validation Random guess:  auc= 0.235371, fmeasure_max= 0.371959, precision= 0.228650, recall= 0.996569
# Minibatch Loss= 0.453419
#  Optimization Finished!

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=train_obj.global_step)
# Out:
# '../model/CNN-LSTM4003/CNN-LSTM4003-1000'

# %%
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-1000')

# %%
probability_of_pos = nn_eval.evaluate_model(model,
                                   sess,
                                   test_data,
                                   test_gt)
# Out:
# Testing auc = 0.761804 F1_max = 0.690783 prec = 0.747737 rec = 0.641892
# Test Random guess: auc= 0.230601 fmeasure_max= 0.375679 , precision= 0.231347 , recall= 0.998818

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':probability_change})
