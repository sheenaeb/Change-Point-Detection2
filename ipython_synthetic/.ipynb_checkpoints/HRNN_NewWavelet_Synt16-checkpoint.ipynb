# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_NewWavelet_Synt16"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,64,64, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import hickle

sys.path.append('../src')

# %%
from models.HRNN_model_new_Wavelet import Model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data2.h'

with open(data_path, 'r') as fin:
    data = hickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape
# Out:
# (890, 8192, 12)

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

wavelet_levels= 6
convolution_levels = 5
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]

bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
wavelet_kernel_size = 3

lstm_n_hidden = 128
n_classes = 1

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight
# Out:
# array([ 3.18601822])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary_synthetic/' + exp_name 
checkpoint_path = '../model_synthetic/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_kernel_size = wavelet_kernel_size,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights,
                 optimizer = tf.train.AdamOptimizer
)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'change')

# %%
trainer.train(max_iter = 20000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 0
# AUC = 0.215 vs. 0.228
# F1 = 0.426 vs. 0.383
# Precision = 0.286 vs. 0.238
# Recall = 0.830 vs. 0.982
# Validation: 0
# AUC = 0.223 vs. 0.230
# F1 = 0.380 vs. 0.376
# Precision = 0.242 vs. 0.231
# Recall = 0.877 vs. 1.000
# Minibatch Loss= 1.057324
# Training: 100
# AUC = 0.549 vs. 0.242
# F1 = 0.512 vs. 0.404
# Precision = 0.456 vs. 0.254
# Recall = 0.585 vs. 0.997
# Validation: 100
# AUC = 0.428 vs. 0.228
# F1 = 0.443 vs. 0.376
# Precision = 0.386 vs. 0.231
# Recall = 0.521 vs. 0.999
# Minibatch Loss= 0.969408
# Training: 200
# AUC = 0.619 vs. 0.252
# F1 = 0.572 vs. 0.385
# Precision = 0.742 vs. 0.238
# Recall = 0.465 vs. 1.000
# Validation: 200
# AUC = 0.624 vs. 0.233
# F1 = 0.592 vs. 0.376
# Precision = 0.622 vs. 0.231
# Recall = 0.565 vs. 1.000
# Minibatch Loss= 0.893877
# Training: 300
# AUC = 0.726 vs. 0.252
# F1 = 0.667 vs. 0.396
# Precision = 0.846 vs. 0.247
# Recall = 0.551 vs. 1.000
# Validation: 300
# AUC = 0.750 vs. 0.234
# F1 = 0.688 vs. 0.376
# Precision = 0.773 vs. 0.231
# Recall = 0.621 vs. 1.000
# Minibatch Loss= 0.859471
# Training: 400
# AUC = 0.742 vs. 0.235
# F1 = 0.668 vs. 0.373
# Precision = 0.713 vs. 0.230
# Recall = 0.629 vs. 0.995
# Validation: 400
# AUC = 0.825 vs. 0.229
# F1 = 0.750 vs. 0.376
# Precision = 0.757 vs. 0.231
# Recall = 0.743 vs. 0.998
# Minibatch Loss= 0.781157
# Training: 500
# AUC = 0.843 vs. 0.232
# F1 = 0.771 vs. 0.387
# Precision = 0.777 vs. 0.240
# Recall = 0.766 vs. 1.000
# Validation: 500
# AUC = 0.839 vs. 0.229
# F1 = 0.763 vs. 0.376
# Precision = 0.814 vs. 0.232
# Recall = 0.718 vs. 0.999
# Minibatch Loss= 0.662866
# Training: 600
# AUC = 0.805 vs. 0.228
# F1 = 0.726 vs. 0.362
# Precision = 0.760 vs. 0.221
# Recall = 0.694 vs. 1.000
# Validation: 600
# AUC = 0.850 vs. 0.230
# F1 = 0.769 vs. 0.376
# Precision = 0.785 vs. 0.231
# Recall = 0.755 vs. 1.000
# Minibatch Loss= 0.670552
# Training: 700
# AUC = 0.856 vs. 0.229
# F1 = 0.825 vs. 0.367
# Precision = 0.884 vs. 0.225
# Recall = 0.772 vs. 1.000
# Validation: 700
# AUC = 0.872 vs. 0.233
# F1 = 0.794 vs. 0.376
# Precision = 0.840 vs. 0.231
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.629627
# Training: 800
# AUC = 0.876 vs. 0.240
# F1 = 0.801 vs. 0.369
# Precision = 0.847 vs. 0.226
# Recall = 0.760 vs. 1.000
# Validation: 800
# AUC = 0.874 vs. 0.233
# F1 = 0.799 vs. 0.376
# Precision = 0.829 vs. 0.231
# Recall = 0.771 vs. 0.999
# Minibatch Loss= 0.600639
# Training: 900
# AUC = 0.903 vs. 0.258
# F1 = 0.805 vs. 0.427
# Precision = 0.787 vs. 0.272
# Recall = 0.824 vs. 0.997
# Validation: 900
# AUC = 0.876 vs. 0.232
# F1 = 0.797 vs. 0.376
# Precision = 0.861 vs. 0.231
# Recall = 0.742 vs. 0.999
# Minibatch Loss= 0.630164
# Training: 1000
# AUC = 0.960 vs. 0.212
# F1 = 0.876 vs. 0.347
# Precision = 0.890 vs. 0.210
# Recall = 0.862 vs. 0.996
# Validation: 1000
# AUC = 0.875 vs. 0.233
# F1 = 0.798 vs. 0.376
# Precision = 0.845 vs. 0.231
# Recall = 0.757 vs. 1.000
# Minibatch Loss= 0.393468
# Training: 1100
# AUC = 0.940 vs. 0.231
# F1 = 0.867 vs. 0.376
# Precision = 0.857 vs. 0.232
# Recall = 0.876 vs. 0.986
# Validation: 1100
# AUC = 0.870 vs. 0.230
# F1 = 0.793 vs. 0.376
# Precision = 0.830 vs. 0.232
# Recall = 0.760 vs. 0.995
# Minibatch Loss= 0.421585
# Training: 1200
# AUC = 0.884 vs. 0.240
# F1 = 0.815 vs. 0.385
# Precision = 0.875 vs. 0.240
# Recall = 0.763 vs. 0.980
# Validation: 1200
# AUC = 0.870 vs. 0.235
# F1 = 0.791 vs. 0.376
# Precision = 0.827 vs. 0.231
# Recall = 0.757 vs. 0.999
# Minibatch Loss= 0.632048
# Training: 1300
# AUC = 0.814 vs. 0.225
# F1 = 0.755 vs. 0.352
# Precision = 0.783 vs. 0.214
# Recall = 0.728 vs. 1.000
# Validation: 1300
# AUC = 0.871 vs. 0.236
# F1 = 0.800 vs. 0.376
# Precision = 0.851 vs. 0.231
# Recall = 0.756 vs. 0.998
# Minibatch Loss= 0.653352
# Training: 1400
# AUC = 0.942 vs. 0.236
# F1 = 0.861 vs. 0.374
# Precision = 0.896 vs. 0.232
# Recall = 0.828 vs. 0.966
# Validation: 1400
# AUC = 0.877 vs. 0.233
# F1 = 0.804 vs. 0.376
# Precision = 0.825 vs. 0.231
# Recall = 0.785 vs. 0.999
# Minibatch Loss= 0.430143
# Training: 1500
# AUC = 0.902 vs. 0.238
# F1 = 0.818 vs. 0.392
# Precision = 0.777 vs. 0.244
# Recall = 0.862 vs. 1.000
# Validation: 1500
# AUC = 0.867 vs. 0.234
# F1 = 0.792 vs. 0.376
# Precision = 0.835 vs. 0.231
# Recall = 0.753 vs. 0.999
# Minibatch Loss= 0.529063
# Training: 1600
# AUC = 0.906 vs. 0.224
# F1 = 0.842 vs. 0.374
# Precision = 0.868 vs. 0.230
# Recall = 0.818 vs. 0.998
# Validation: 1600
# AUC = 0.882 vs. 0.231
# F1 = 0.811 vs. 0.376
# Precision = 0.856 vs. 0.231
# Recall = 0.771 vs. 0.999
# Minibatch Loss= 0.551798
# Training: 1700
# AUC = 0.938 vs. 0.223
# F1 = 0.858 vs. 0.363
# Precision = 0.885 vs. 0.223
# Recall = 0.832 vs. 0.984
# Validation: 1700
# AUC = 0.885 vs. 0.238
# F1 = 0.806 vs. 0.376
# Precision = 0.867 vs. 0.231
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.432579
# Training: 1800
# AUC = 0.924 vs. 0.259
# F1 = 0.843 vs. 0.399
# Precision = 0.830 vs. 0.250
# Recall = 0.856 vs. 0.987
# Validation: 1800
# AUC = 0.882 vs. 0.230
# F1 = 0.804 vs. 0.376
# Precision = 0.858 vs. 0.231
# Recall = 0.756 vs. 0.999
# Minibatch Loss= 0.506304
# Training: 1900
# AUC = 0.944 vs. 0.239
# F1 = 0.881 vs. 0.394
# Precision = 0.878 vs. 0.246
# Recall = 0.883 vs. 0.997
# Validation: 1900
# AUC = 0.874 vs. 0.230
# F1 = 0.793 vs. 0.376
# Precision = 0.803 vs. 0.231
# Recall = 0.784 vs. 1.000
# Minibatch Loss= 0.457381
# Training: 2000
# AUC = 0.934 vs. 0.243
# F1 = 0.863 vs. 0.384
# Precision = 0.874 vs. 0.237
# Recall = 0.853 vs. 1.000
# Validation: 2000
# AUC = 0.882 vs. 0.230
# F1 = 0.802 vs. 0.376
# Precision = 0.828 vs. 0.232
# Recall = 0.777 vs. 0.999
# Minibatch Loss= 0.464671
# Training: 2100
# AUC = 0.919 vs. 0.288
# F1 = 0.834 vs. 0.414
# Precision = 0.861 vs. 0.261
# Recall = 0.809 vs. 1.000
# Validation: 2100
# AUC = 0.880 vs. 0.232
# F1 = 0.800 vs. 0.376
# Precision = 0.840 vs. 0.232
# Recall = 0.765 vs. 0.985
# Minibatch Loss= 0.562941
# Training: 2200
# AUC = 0.939 vs. 0.242
# F1 = 0.857 vs. 0.379
# Precision = 0.865 vs. 0.234
# Recall = 0.849 vs. 0.988
# Validation: 2200
# AUC = 0.882 vs. 0.234
# F1 = 0.809 vs. 0.376
# Precision = 0.863 vs. 0.231
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.445039
# Training: 2300
# AUC = 0.938 vs. 0.212
# F1 = 0.856 vs. 0.356
# Precision = 0.856 vs. 0.217
# Recall = 0.856 vs. 0.982
# Validation: 2300
# AUC = 0.871 vs. 0.231
# F1 = 0.793 vs. 0.376
# Precision = 0.825 vs. 0.231
# Recall = 0.763 vs. 0.999
# Minibatch Loss= 0.446827
# Training: 2400
# AUC = 0.838 vs. 0.227
# F1 = 0.752 vs. 0.384
# Precision = 0.788 vs. 0.238
# Recall = 0.719 vs. 0.995
# Validation: 2400
# AUC = 0.872 vs. 0.234
# F1 = 0.797 vs. 0.376
# Precision = 0.842 vs. 0.232
# Recall = 0.756 vs. 0.997
# Minibatch Loss= 0.733473
# Training: 2500
# AUC = 0.943 vs. 0.297
# F1 = 0.879 vs. 0.452
# Precision = 0.902 vs. 0.292
# Recall = 0.857 vs. 0.999
# Validation: 2500
# AUC = 0.879 vs. 0.233
# F1 = 0.803 vs. 0.376
# Precision = 0.852 vs. 0.231
# Recall = 0.758 vs. 0.997
# Minibatch Loss= 0.534377
# Training: 2600
# AUC = 0.917 vs. 0.244
# F1 = 0.841 vs. 0.387
# Precision = 0.821 vs. 0.240
# Recall = 0.861 vs. 0.993
# Validation: 2600
# AUC = 0.874 vs. 0.233
# F1 = 0.797 vs. 0.376
# Precision = 0.820 vs. 0.231
# Recall = 0.775 vs. 1.000
# Minibatch Loss= 0.484663
# Training: 2700
# AUC = 0.921 vs. 0.199
# F1 = 0.836 vs. 0.340
# Precision = 0.827 vs. 0.205
# Recall = 0.846 vs. 1.000
# Validation: 2700
# AUC = 0.875 vs. 0.233
# F1 = 0.796 vs. 0.376
# Precision = 0.814 vs. 0.232
# Recall = 0.778 vs. 0.997
# Minibatch Loss= 0.396795
# Training: 2800
# AUC = 0.947 vs. 0.240
# F1 = 0.870 vs. 0.401
# Precision = 0.905 vs. 0.253
# Recall = 0.838 vs. 0.978
# Validation: 2800
# AUC = 0.876 vs. 0.232
# F1 = 0.800 vs. 0.376
# Precision = 0.828 vs. 0.232
# Recall = 0.774 vs. 0.996
# Minibatch Loss= 0.465235
# Training: 2900
# AUC = 0.912 vs. 0.237
# F1 = 0.840 vs. 0.398
# Precision = 0.867 vs. 0.249
# Recall = 0.815 vs. 0.984
# Validation: 2900
# AUC = 0.881 vs. 0.231
# F1 = 0.804 vs. 0.376
# Precision = 0.841 vs. 0.231
# Recall = 0.769 vs. 1.000
# Minibatch Loss= 0.553913
# Training: 3000
# AUC = 0.927 vs. 0.251
# F1 = 0.848 vs. 0.369
# Precision = 0.890 vs. 0.226
# Recall = 0.810 vs. 1.000
# Validation: 3000
# AUC = 0.881 vs. 0.231
# F1 = 0.807 vs. 0.376
# Precision = 0.842 vs. 0.231
# Recall = 0.774 vs. 0.999
# Minibatch Loss= 0.463726
# Training: 3100
# AUC = 0.930 vs. 0.275
# F1 = 0.845 vs. 0.414
# Precision = 0.842 vs. 0.262
# Recall = 0.848 vs. 0.977
# Validation: 3100
# AUC = 0.883 vs. 0.231
# F1 = 0.809 vs. 0.376
# Precision = 0.854 vs. 0.231
# Recall = 0.768 vs. 0.998
# Minibatch Loss= 0.508832
# Training: 3200
# AUC = 0.915 vs. 0.214
# F1 = 0.836 vs. 0.343
# Precision = 0.847 vs. 0.207
# Recall = 0.825 vs. 1.000
# Validation: 3200
# AUC = 0.861 vs. 0.233
# F1 = 0.781 vs. 0.376
# Precision = 0.821 vs. 0.231
# Recall = 0.744 vs. 0.998
# Minibatch Loss= 0.464961
# Training: 3300
# AUC = 0.963 vs. 0.209
# F1 = 0.899 vs. 0.348
# Precision = 0.873 vs. 0.211
# Recall = 0.928 vs. 1.000
# Validation: 3300
# AUC = 0.875 vs. 0.230
# F1 = 0.798 vs. 0.376
# Precision = 0.818 vs. 0.231
# Recall = 0.779 vs. 1.000
# Minibatch Loss= 0.364683
# Training: 3400
# AUC = 0.942 vs. 0.218
# F1 = 0.864 vs. 0.367
# Precision = 0.852 vs. 0.226
# Recall = 0.876 vs. 0.984
# Validation: 3400
# AUC = 0.874 vs. 0.234
# F1 = 0.797 vs. 0.376
# Precision = 0.831 vs. 0.232
# Recall = 0.765 vs. 0.996
# Minibatch Loss= 0.431169
# Training: 3500
# AUC = 0.957 vs. 0.228
# F1 = 0.896 vs. 0.378
# Precision = 0.917 vs. 0.233
# Recall = 0.876 vs. 1.000
# Validation: 3500
# AUC = 0.879 vs. 0.230
# F1 = 0.806 vs. 0.376
# Precision = 0.833 vs. 0.231
# Recall = 0.780 vs. 1.000
# Minibatch Loss= 0.455281
# Training: 3600
# AUC = 0.934 vs. 0.229
# F1 = 0.853 vs. 0.375
# Precision = 0.866 vs. 0.231
# Recall = 0.841 vs. 0.998
# Validation: 3600
# AUC = 0.879 vs. 0.235
# F1 = 0.806 vs. 0.376
# Precision = 0.824 vs. 0.231
# Recall = 0.788 vs. 1.000
# Minibatch Loss= 0.452673
# Training: 3700
# AUC = 0.937 vs. 0.231
# F1 = 0.864 vs. 0.368
# Precision = 0.821 vs. 0.228
# Recall = 0.913 vs. 0.949
# Validation: 3700
# AUC = 0.877 vs. 0.229
# F1 = 0.803 vs. 0.376
# Precision = 0.830 vs. 0.231
# Recall = 0.778 vs. 1.000
# Minibatch Loss= 0.395250
# Training: 3800
# AUC = 0.943 vs. 0.189
# F1 = 0.866 vs. 0.332
# Precision = 0.888 vs. 0.199
# Recall = 0.845 vs. 0.998
# Validation: 3800
# AUC = 0.869 vs. 0.234
# F1 = 0.787 vs. 0.376
# Precision = 0.801 vs. 0.231
# Recall = 0.773 vs. 0.999
# Minibatch Loss= 0.387267
# Training: 3900
# AUC = 0.927 vs. 0.231
# F1 = 0.838 vs. 0.386
# Precision = 0.831 vs. 0.239
# Recall = 0.845 vs. 0.997
# Validation: 3900
# AUC = 0.871 vs. 0.227
# F1 = 0.797 vs. 0.376
# Precision = 0.818 vs. 0.231
# Recall = 0.777 vs. 1.000
# Minibatch Loss= 0.454363
# Training: 4000
# AUC = 0.964 vs. 0.248
# F1 = 0.891 vs. 0.395
# Precision = 0.912 vs. 0.247
# Recall = 0.871 vs. 0.989
# Validation: 4000
# AUC = 0.879 vs. 0.229
# F1 = 0.811 vs. 0.376
# Precision = 0.844 vs. 0.231
# Recall = 0.780 vs. 1.000
# Minibatch Loss= 0.410907
# Training: 4100
# AUC = 0.969 vs. 0.216
# F1 = 0.897 vs. 0.362
# Precision = 0.889 vs. 0.221
# Recall = 0.906 vs. 0.996
# Validation: 4100
# AUC = 0.877 vs. 0.231
# F1 = 0.805 vs. 0.376
# Precision = 0.833 vs. 0.231
# Recall = 0.778 vs. 1.000
# Minibatch Loss= 0.376956
# Training: 4200
# AUC = 0.976 vs. 0.264
# F1 = 0.914 vs. 0.422
# Precision = 0.910 vs. 0.269
# Recall = 0.919 vs. 0.972
# Validation: 4200
# AUC = 0.859 vs. 0.231
# F1 = 0.783 vs. 0.376
# Precision = 0.776 vs. 0.232
# Recall = 0.790 vs. 0.985
# Minibatch Loss= 0.391644
# Training: 4300
# AUC = 0.951 vs. 0.233
# F1 = 0.878 vs. 0.369
# Precision = 0.878 vs. 0.227
# Recall = 0.877 vs. 1.000
# Validation: 4300
# AUC = 0.868 vs. 0.233
# F1 = 0.785 vs. 0.376
# Precision = 0.803 vs. 0.231
# Recall = 0.767 vs. 0.999
# Minibatch Loss= 0.402396
# Training: 4400
# AUC = 0.938 vs. 0.204
# F1 = 0.868 vs. 0.356
# Precision = 0.872 vs. 0.217
# Recall = 0.864 vs. 1.000
# Validation: 4400
# AUC = 0.879 vs. 0.230
# F1 = 0.806 vs. 0.376
# Precision = 0.823 vs. 0.231
# Recall = 0.790 vs. 1.000
# Minibatch Loss= 0.396584
# Training: 4500
# AUC = 0.937 vs. 0.249
# F1 = 0.860 vs. 0.382
# Precision = 0.856 vs. 0.236
# Recall = 0.864 vs. 1.000
# Validation: 4500
# AUC = 0.862 vs. 0.233
# F1 = 0.787 vs. 0.376
# Precision = 0.810 vs. 0.231
# Recall = 0.765 vs. 1.000
# Minibatch Loss= 0.498499
# Training: 4600
# AUC = 0.955 vs. 0.252
# F1 = 0.884 vs. 0.397
# Precision = 0.875 vs. 0.248
# Recall = 0.894 vs. 0.995
# Validation: 4600
# AUC = 0.872 vs. 0.229
# F1 = 0.800 vs. 0.376
# Precision = 0.837 vs. 0.231
# Recall = 0.766 vs. 1.000
# Minibatch Loss= 0.398694
# Training: 4700
# AUC = 0.950 vs. 0.257
# F1 = 0.884 vs. 0.418
# Precision = 0.880 vs. 0.264
# Recall = 0.889 vs. 1.000
# Validation: 4700
# AUC = 0.865 vs. 0.232
# F1 = 0.795 vs. 0.376
# Precision = 0.815 vs. 0.231
# Recall = 0.776 vs. 0.999
# Minibatch Loss= 0.418109
# Training: 4800
# AUC = 0.964 vs. 0.227
# F1 = 0.898 vs. 0.364
# Precision = 0.898 vs. 0.223
# Recall = 0.898 vs. 0.998
# Validation: 4800
# AUC = 0.875 vs. 0.236
# F1 = 0.798 vs. 0.376
# Precision = 0.809 vs. 0.231
# Recall = 0.786 vs. 0.997
# Minibatch Loss= 0.367701
# Training: 4900
# AUC = 0.982 vs. 0.274
# F1 = 0.930 vs. 0.415
# Precision = 0.912 vs. 0.262
# Recall = 0.948 vs. 0.997
# Validation: 4900
# AUC = 0.871 vs. 0.232
# F1 = 0.797 vs. 0.376
# Precision = 0.808 vs. 0.231
# Recall = 0.787 vs. 1.000
# Minibatch Loss= 0.363102
# Training: 5000
# AUC = 0.960 vs. 0.244
# F1 = 0.887 vs. 0.392
# Precision = 0.895 vs. 0.244
# Recall = 0.878 vs. 0.987
# Validation: 5000
# AUC = 0.876 vs. 0.231
# F1 = 0.802 vs. 0.376
# Precision = 0.802 vs. 0.232
# Recall = 0.802 vs. 0.992
# Minibatch Loss= 0.399662
# Training: 5100
# AUC = 0.971 vs. 0.195
# F1 = 0.908 vs. 0.325
# Precision = 0.914 vs. 0.194
# Recall = 0.901 vs. 1.000
# Validation: 5100
# AUC = 0.876 vs. 0.230
# F1 = 0.799 vs. 0.376
# Precision = 0.819 vs. 0.231
# Recall = 0.780 vs. 1.000
# Minibatch Loss= 0.304430
# Training: 5200
# AUC = 0.967 vs. 0.239
# F1 = 0.912 vs. 0.373
# Precision = 0.908 vs. 0.230
# Recall = 0.917 vs. 0.988
# Validation: 5200
# AUC = 0.866 vs. 0.232
# F1 = 0.794 vs. 0.376
# Precision = 0.804 vs. 0.231
# Recall = 0.785 vs. 0.999
# Minibatch Loss= 0.363831
# Training: 5300
# AUC = 0.987 vs. 0.246
# F1 = 0.944 vs. 0.394
# Precision = 0.937 vs. 0.246
# Recall = 0.951 vs. 1.000
# Validation: 5300
# AUC = 0.869 vs. 0.234
# F1 = 0.790 vs. 0.376
# Precision = 0.831 vs. 0.231
# Recall = 0.754 vs. 1.000
# Minibatch Loss= 0.314181
# Training: 5400
# AUC = 0.956 vs. 0.228
# F1 = 0.877 vs. 0.369
# Precision = 0.863 vs. 0.227
# Recall = 0.891 vs. 1.000
# Validation: 5400
# AUC = 0.864 vs. 0.233
# F1 = 0.790 vs. 0.376
# Precision = 0.791 vs. 0.231
# Recall = 0.788 vs. 1.000
# Minibatch Loss= 0.387168
# Training: 5500
# AUC = 0.973 vs. 0.260
# F1 = 0.906 vs. 0.395
# Precision = 0.897 vs. 0.246
# Recall = 0.916 vs. 0.997
# Validation: 5500
# AUC = 0.873 vs. 0.232
# F1 = 0.798 vs. 0.376
# Precision = 0.810 vs. 0.232
# Recall = 0.786 vs. 0.993
# Minibatch Loss= 0.389410
# Training: 5600
# AUC = 0.931 vs. 0.224
# F1 = 0.865 vs. 0.358
# Precision = 0.865 vs. 0.218
# Recall = 0.865 vs. 1.000
# Validation: 5600
# AUC = 0.856 vs. 0.232
# F1 = 0.777 vs. 0.376
# Precision = 0.815 vs. 0.231
# Recall = 0.742 vs. 1.000
# Minibatch Loss= 0.439931
# Training: 5700
# AUC = 0.956 vs. 0.214
# F1 = 0.885 vs. 0.353
# Precision = 0.909 vs. 0.215
# Recall = 0.861 vs. 0.996
# Validation: 5700
# AUC = 0.855 vs. 0.234
# F1 = 0.782 vs. 0.376
# Precision = 0.787 vs. 0.231
# Recall = 0.777 vs. 1.000
# Minibatch Loss= 0.399023
# Training: 5800
# AUC = 0.967 vs. 0.261
# F1 = 0.893 vs. 0.418
# Precision = 0.864 vs. 0.264
# Recall = 0.923 vs. 1.000
# Validation: 5800
# AUC = 0.858 vs. 0.229
# F1 = 0.781 vs. 0.376
# Precision = 0.832 vs. 0.231
# Recall = 0.736 vs. 1.000
# Minibatch Loss= 0.406348
# Training: 5900
# AUC = 0.971 vs. 0.229
# F1 = 0.922 vs. 0.383
# Precision = 0.896 vs. 0.238
# Recall = 0.948 vs. 0.978
# Validation: 5900
# AUC = 0.874 vs. 0.233
# F1 = 0.802 vs. 0.376
# Precision = 0.830 vs. 0.231
# Recall = 0.776 vs. 1.000
# Minibatch Loss= 0.361132
# Training: 6000
# AUC = 0.964 vs. 0.253
# F1 = 0.901 vs. 0.404
# Precision = 0.901 vs. 0.253
# Recall = 0.901 vs. 0.997
# Validation: 6000
# AUC = 0.865 vs. 0.235
# F1 = 0.790 vs. 0.376
# Precision = 0.807 vs. 0.231
# Recall = 0.774 vs. 1.000
# Minibatch Loss= 0.394103
# Training: 6100
# AUC = 0.956 vs. 0.245
# F1 = 0.895 vs. 0.394
# Precision = 0.840 vs. 0.245
# Recall = 0.957 vs. 1.000
# Validation: 6100
# AUC = 0.874 vs. 0.232
# F1 = 0.803 vs. 0.376
# Precision = 0.827 vs. 0.231
# Recall = 0.780 vs. 0.999
# Minibatch Loss= 0.357844
# Training: 6200
# AUC = 0.974 vs. 0.200
# F1 = 0.914 vs. 0.338
# Precision = 0.909 vs. 0.204
# Recall = 0.920 vs. 0.986
# Validation: 6200
# AUC = 0.871 vs. 0.233
# F1 = 0.801 vs. 0.376
# Precision = 0.815 vs. 0.231
# Recall = 0.787 vs. 1.000
# Minibatch Loss= 0.326146
# Training: 6300
# AUC = 0.988 vs. 0.262
# F1 = 0.937 vs. 0.415
# Precision = 0.948 vs. 0.265
# Recall = 0.926 vs. 0.959
# Validation: 6300
# AUC = 0.877 vs. 0.237
# F1 = 0.806 vs. 0.376
# Precision = 0.828 vs. 0.232
# Recall = 0.785 vs. 0.997
# Minibatch Loss= 0.367373
# Training: 6400
# AUC = 0.986 vs. 0.222
# F1 = 0.933 vs. 0.376
# Precision = 0.937 vs. 0.232
# Recall = 0.929 vs. 1.000
# Validation: 6400
# AUC = 0.877 vs. 0.232
# F1 = 0.805 vs. 0.376
# Precision = 0.837 vs. 0.232
# Recall = 0.776 vs. 0.990
# Minibatch Loss= 0.341634
# Training: 6500
# AUC = 0.985 vs. 0.251
# F1 = 0.925 vs. 0.402
# Precision = 0.911 vs. 0.251
# Recall = 0.939 vs. 1.000
# Validation: 6500
# AUC = 0.873 vs. 0.230
# F1 = 0.800 vs. 0.376
# Precision = 0.801 vs. 0.232
# Recall = 0.799 vs. 0.994
# Minibatch Loss= 0.345555
# Training: 6600
# AUC = 0.965 vs. 0.191
# F1 = 0.919 vs. 0.321
# Precision = 0.893 vs. 0.192
# Recall = 0.947 vs. 0.973
# Validation: 6600
# AUC = 0.873 vs. 0.228
# F1 = 0.801 vs. 0.376
# Precision = 0.795 vs. 0.231
# Recall = 0.807 vs. 1.000
# Minibatch Loss= 0.296439
# Training: 6700
# AUC = 0.984 vs. 0.262
# F1 = 0.934 vs. 0.423
# Precision = 0.904 vs. 0.268
# Recall = 0.966 vs. 0.999
# Validation: 6700
# AUC = 0.874 vs. 0.229
# F1 = 0.803 vs. 0.376
# Precision = 0.810 vs. 0.231
# Recall = 0.796 vs. 1.000
# Minibatch Loss= 0.402773
# Training: 6800
# AUC = 0.991 vs. 0.247
# F1 = 0.959 vs. 0.401
# Precision = 0.947 vs. 0.251
# Recall = 0.972 vs. 1.000
# Validation: 6800
# AUC = 0.871 vs. 0.229
# F1 = 0.803 vs. 0.376
# Precision = 0.835 vs. 0.231
# Recall = 0.774 vs. 0.999
# Minibatch Loss= 0.312763
# Training: 6900
# AUC = 0.971 vs. 0.247
# F1 = 0.913 vs. 0.394
# Precision = 0.874 vs. 0.245
# Recall = 0.955 vs. 0.997
# Validation: 6900
# AUC = 0.865 vs. 0.232
# F1 = 0.793 vs. 0.376
# Precision = 0.814 vs. 0.231
# Recall = 0.772 vs. 1.000
# Minibatch Loss= 0.368773
# Training: 7000
# AUC = 0.988 vs. 0.194
# F1 = 0.946 vs. 0.328
# Precision = 0.948 vs. 0.196
# Recall = 0.944 vs. 0.998
# Validation: 7000
# AUC = 0.867 vs. 0.231
# F1 = 0.798 vs. 0.376
# Precision = 0.810 vs. 0.231
# Recall = 0.787 vs. 0.998
# Minibatch Loss= 0.284250
# Training: 7100
# AUC = 0.991 vs. 0.225
# F1 = 0.956 vs. 0.366
# Precision = 0.947 vs. 0.224
# Recall = 0.965 vs. 0.998
# Validation: 7100
# AUC = 0.870 vs. 0.237
# F1 = 0.796 vs. 0.376
# Precision = 0.828 vs. 0.231
# Recall = 0.766 vs. 1.000
# Minibatch Loss= 0.282627
# Training: 7200
# AUC = 0.988 vs. 0.247
# F1 = 0.940 vs. 0.393
# Precision = 0.957 vs. 0.245
# Recall = 0.923 vs. 0.997
# Validation: 7200
# AUC = 0.869 vs. 0.230
# F1 = 0.794 vs. 0.376
# Precision = 0.806 vs. 0.231
# Recall = 0.782 vs. 1.000
# Minibatch Loss= 0.361709
# Training: 7300
# AUC = 0.967 vs. 0.222
# F1 = 0.898 vs. 0.371
# Precision = 0.858 vs. 0.228
# Recall = 0.941 vs. 0.988
# Validation: 7300
# AUC = 0.861 vs. 0.232
# F1 = 0.794 vs. 0.376
# Precision = 0.808 vs. 0.231
# Recall = 0.781 vs. 0.998
# Minibatch Loss= 0.361111
# Training: 7400
# AUC = 0.961 vs. 0.194
# F1 = 0.886 vs. 0.319
# Precision = 0.896 vs. 0.190
# Recall = 0.876 vs. 0.988
# Validation: 7400
# AUC = 0.858 vs. 0.231
# F1 = 0.782 vs. 0.376
# Precision = 0.800 vs. 0.232
# Recall = 0.765 vs. 0.998
# Minibatch Loss= 0.356565
# Training: 7500
# AUC = 0.919 vs. 0.205
# F1 = 0.841 vs. 0.345
# Precision = 0.844 vs. 0.209
# Recall = 0.838 vs. 0.991
# Validation: 7500
# AUC = 0.875 vs. 0.227
# F1 = 0.800 vs. 0.376
# Precision = 0.817 vs. 0.231
# Recall = 0.784 vs. 0.999
# Minibatch Loss= 0.538449
# Training: 7600
# AUC = 0.979 vs. 0.240
# F1 = 0.924 vs. 0.380
# Precision = 0.916 vs. 0.238
# Recall = 0.933 vs. 0.936
# Validation: 7600
# AUC = 0.866 vs. 0.228
# F1 = 0.791 vs. 0.376
# Precision = 0.802 vs. 0.231
# Recall = 0.780 vs. 0.998
# Minibatch Loss= 0.386657
# Training: 7700
# AUC = 0.983 vs. 0.224
# F1 = 0.926 vs. 0.368
# Precision = 0.915 vs. 0.225
# Recall = 0.938 vs. 1.000
# Validation: 7700
# AUC = 0.869 vs. 0.233
# F1 = 0.796 vs. 0.376
# Precision = 0.823 vs. 0.231
# Recall = 0.771 vs. 0.999
# Minibatch Loss= 0.324942
# Training: 7800
# AUC = 0.979 vs. 0.228
# F1 = 0.929 vs. 0.367
# Precision = 0.929 vs. 0.225
# Recall = 0.929 vs. 0.995
# Validation: 7800
# AUC = 0.861 vs. 0.233
# F1 = 0.795 vs. 0.376
# Precision = 0.802 vs. 0.232
# Recall = 0.787 vs. 0.985
# Minibatch Loss= 0.341107
# Training: 7900
# AUC = 0.982 vs. 0.202
# F1 = 0.934 vs. 0.333
# Precision = 0.929 vs. 0.200
# Recall = 0.939 vs. 1.000
# Validation: 7900
# AUC = 0.868 vs. 0.235
# F1 = 0.799 vs. 0.376
# Precision = 0.802 vs. 0.231
# Recall = 0.795 vs. 1.000
# Minibatch Loss= 0.293394
# Training: 8000
# AUC = 0.987 vs. 0.266
# F1 = 0.955 vs. 0.410
# Precision = 0.947 vs. 0.260
# Recall = 0.962 vs. 0.970
# Validation: 8000
# AUC = 0.868 vs. 0.229
# F1 = 0.798 vs. 0.376
# Precision = 0.818 vs. 0.231
# Recall = 0.780 vs. 1.000
# Minibatch Loss= 0.383130
# Training: 8100
# AUC = 0.991 vs. 0.246
# F1 = 0.963 vs. 0.392
# Precision = 0.946 vs. 0.243
# Recall = 0.981 vs. 1.000
# Validation: 8100
# AUC = 0.866 vs. 0.235
# F1 = 0.797 vs. 0.376
# Precision = 0.801 vs. 0.232
# Recall = 0.794 vs. 0.997
# Minibatch Loss= 0.319244
# Training: 8200
# AUC = 0.993 vs. 0.209
# F1 = 0.955 vs. 0.344
# Precision = 0.978 vs. 0.208
# Recall = 0.932 vs. 1.000
# Validation: 8200
# AUC = 0.870 vs. 0.229
# F1 = 0.799 vs. 0.376
# Precision = 0.833 vs. 0.231
# Recall = 0.768 vs. 0.999
# Minibatch Loss= 0.275257
# Training: 8300
# AUC = 0.992 vs. 0.229
# F1 = 0.964 vs. 0.384
# Precision = 0.946 vs. 0.237
# Recall = 0.982 vs. 1.000
# Validation: 8300
# AUC = 0.866 vs. 0.231
# F1 = 0.796 vs. 0.376
# Precision = 0.811 vs. 0.231
# Recall = 0.782 vs. 1.000
# Minibatch Loss= 0.328553
# Training: 8400
# AUC = 0.996 vs. 0.277
# F1 = 0.967 vs. 0.437
# Precision = 0.963 vs. 0.281
# Recall = 0.972 vs. 0.992
# Validation: 8400
# AUC = 0.866 vs. 0.229
# F1 = 0.797 vs. 0.376
# Precision = 0.816 vs. 0.231
# Recall = 0.779 vs. 1.000
# Minibatch Loss= 0.378073
# Training: 8500
# AUC = 0.992 vs. 0.251
# F1 = 0.960 vs. 0.399
# Precision = 0.954 vs. 0.250
# Recall = 0.966 vs. 0.992
# Validation: 8500
# AUC = 0.863 vs. 0.230
# F1 = 0.794 vs. 0.376
# Precision = 0.836 vs. 0.231
# Recall = 0.757 vs. 1.000
# Minibatch Loss= 0.364712
# Training: 8600
# AUC = 0.996 vs. 0.236
# F1 = 0.969 vs. 0.392
# Precision = 0.963 vs. 0.244
# Recall = 0.974 vs. 1.000
# Validation: 8600
# AUC = 0.864 vs. 0.231
# F1 = 0.796 vs. 0.376
# Precision = 0.829 vs. 0.231
# Recall = 0.765 vs. 1.000
# Minibatch Loss= 0.240309
# Training: 8700
# AUC = 0.995 vs. 0.263
# F1 = 0.965 vs. 0.417
# Precision = 0.958 vs. 0.264
# Recall = 0.972 vs. 0.993
# Validation: 8700
# AUC = 0.862 vs. 0.231
# F1 = 0.792 vs. 0.376
# Precision = 0.802 vs. 0.232
# Recall = 0.783 vs. 0.999
# Minibatch Loss= 0.335288
# Training: 8800
# AUC = 0.990 vs. 0.245
# F1 = 0.952 vs. 0.401
# Precision = 0.934 vs. 0.251
# Recall = 0.970 vs. 0.998
# Validation: 8800
# AUC = 0.866 vs. 0.232
# F1 = 0.798 vs. 0.376
# Precision = 0.815 vs. 0.232
# Recall = 0.782 vs. 0.999
# Minibatch Loss= 0.337630
# Training: 8900
# AUC = 0.995 vs. 0.226
# F1 = 0.970 vs. 0.365
# Precision = 0.962 vs. 0.224
# Recall = 0.977 vs. 0.998
# Validation: 8900
# AUC = 0.866 vs. 0.229
# F1 = 0.798 vs. 0.376
# Precision = 0.817 vs. 0.231
# Recall = 0.781 vs. 0.998
# Minibatch Loss= 0.300048
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-76902324ec9b> in <module>()
#       2                 train_eval_step=100,
#       3                 validation_eval_step=100,
# ----> 4                 display_step=100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model_synthetic/HRNN_NewWavelet_Synt16/HRNN_NewWavelet_Synt16-8988'

# %%
#saver = tf.train.Saver()
#saver.restore(sess, checkpoint_path+'-1000')

# %%
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.863 vs. 0.231
# F1 = 0.791 vs. 0.376
# Precision = 0.794 vs. 0.231
# Recall = 0.789 vs. 0.998

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc_synthetic/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})
