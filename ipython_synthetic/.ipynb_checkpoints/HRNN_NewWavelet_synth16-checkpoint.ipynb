# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_NewWavelet_Synt16"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,64,64, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import hickle

sys.path.append('../src')

# %%
from models.HRNN_model_new_Wavelet import Model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data2.h'

with open(data_path, 'r') as fin:
    data = hickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

wavelet_levels= 6
convolution_levels = 5
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]

bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
wavelet_kernel_size = 3

lstm_n_hidden = 128
n_classes = 1

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight
# Out:
# array([ 3.18601822])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary_synthetic/' + exp_name 
checkpoint_path = '../model_synthetic/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_kernel_size = wavelet_kernel_size,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights,
                 optimizer = tf.train.AdamOptimizer
)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'change')

# %%
trainer.train(max_iter = 20000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 0
# AUC = 0.255 vs. 0.246
# F1 = 0.390 vs. 0.384
# Precision = 0.243 vs. 0.237
# Recall = 0.980 vs. 1.000
# Validation: 0
# AUC = 0.213 vs. 0.233
# F1 = 0.376 vs. 0.376
# Precision = 0.231 vs. 0.231
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 1.065036
# Training: 100
# AUC = 0.511 vs. 0.237
# F1 = 0.484 vs. 0.379
# Precision = 0.525 vs. 0.234
# Recall = 0.449 vs. 0.997
# Validation: 100
# AUC = 0.402 vs. 0.229
# F1 = 0.424 vs. 0.376
# Precision = 0.391 vs. 0.231
# Recall = 0.463 vs. 1.000
# Minibatch Loss= 1.006828
# Training: 200
# AUC = 0.556 vs. 0.234
# F1 = 0.573 vs. 0.374
# Precision = 0.663 vs. 0.231
# Recall = 0.504 vs. 0.983
# Validation: 200
# AUC = 0.561 vs. 0.231
# F1 = 0.524 vs. 0.376
# Precision = 0.522 vs. 0.231
# Recall = 0.527 vs. 1.000
# Minibatch Loss= 0.917549
# Training: 300
# AUC = 0.856 vs. 0.263
# F1 = 0.799 vs. 0.418
# Precision = 0.860 vs. 0.265
# Recall = 0.746 vs. 1.000
# Validation: 300
# AUC = 0.748 vs. 0.231
# F1 = 0.699 vs. 0.376
# Precision = 0.749 vs. 0.231
# Recall = 0.655 vs. 1.000
# Minibatch Loss= 0.704426
# Training: 400
# AUC = 0.838 vs. 0.214
# F1 = 0.780 vs. 0.370
# Precision = 0.821 vs. 0.227
# Recall = 0.743 vs. 1.000
# Validation: 400
# AUC = 0.812 vs. 0.229
# F1 = 0.748 vs. 0.376
# Precision = 0.770 vs. 0.232
# Recall = 0.727 vs. 0.992
# Minibatch Loss= 0.605312
# Training: 500
# AUC = 0.843 vs. 0.235
# F1 = 0.781 vs. 0.363
# Precision = 0.829 vs. 0.221
# Recall = 0.739 vs. 1.000
# Validation: 500
# AUC = 0.828 vs. 0.238
# F1 = 0.751 vs. 0.376
# Precision = 0.792 vs. 0.232
# Recall = 0.713 vs. 0.995
# Minibatch Loss= 0.628513
# Training: 600
# AUC = 0.854 vs. 0.252
# F1 = 0.789 vs. 0.410
# Precision = 0.848 vs. 0.258
# Recall = 0.737 vs. 0.998
# Validation: 600
# AUC = 0.843 vs. 0.239
# F1 = 0.766 vs. 0.376
# Precision = 0.779 vs. 0.231
# Recall = 0.753 vs. 1.000
# Minibatch Loss= 0.672531
# Training: 700
# AUC = 0.926 vs. 0.234
# F1 = 0.849 vs. 0.364
# Precision = 0.920 vs. 0.223
# Recall = 0.788 vs. 1.000
# Validation: 700
# AUC = 0.854 vs. 0.230
# F1 = 0.776 vs. 0.376
# Precision = 0.800 vs. 0.231
# Recall = 0.754 vs. 1.000
# Minibatch Loss= 0.493376
# Training: 800
# AUC = 0.891 vs. 0.208
# F1 = 0.818 vs. 0.347
# Precision = 0.871 vs. 0.210
# Recall = 0.771 vs. 0.998
# Validation: 800
# AUC = 0.854 vs. 0.232
# F1 = 0.778 vs. 0.376
# Precision = 0.817 vs. 0.231
# Recall = 0.743 vs. 1.000
# Minibatch Loss= 0.514352
# Training: 900
# AUC = 0.916 vs. 0.254
# F1 = 0.832 vs. 0.402
# Precision = 0.839 vs. 0.254
# Recall = 0.826 vs. 0.974
# Validation: 900
# AUC = 0.857 vs. 0.234
# F1 = 0.778 vs. 0.376
# Precision = 0.812 vs. 0.232
# Recall = 0.746 vs. 0.995
# Minibatch Loss= 0.542464
# Training: 1000
# AUC = 0.931 vs. 0.237
# F1 = 0.847 vs. 0.392
# Precision = 0.815 vs. 0.246
# Recall = 0.881 vs. 0.968
# Validation: 1000
# AUC = 0.866 vs. 0.233
# F1 = 0.793 vs. 0.376
# Precision = 0.828 vs. 0.231
# Recall = 0.761 vs. 0.999
# Minibatch Loss= 0.503260
# Training: 1100
# AUC = 0.896 vs. 0.258
# F1 = 0.828 vs. 0.383
# Precision = 0.869 vs. 0.237
# Recall = 0.791 vs. 0.997
# Validation: 1100
# AUC = 0.859 vs. 0.231
# F1 = 0.782 vs. 0.376
# Precision = 0.827 vs. 0.231
# Recall = 0.742 vs. 1.000
# Minibatch Loss= 0.579236
# Training: 1200
# AUC = 0.853 vs. 0.265
# F1 = 0.767 vs. 0.398
# Precision = 0.848 vs. 0.248
# Recall = 0.701 vs. 1.000
# Validation: 1200
# AUC = 0.856 vs. 0.229
# F1 = 0.778 vs. 0.376
# Precision = 0.804 vs. 0.231
# Recall = 0.753 vs. 1.000
# Minibatch Loss= 0.660700
# Training: 1300
# AUC = 0.841 vs. 0.239
# F1 = 0.762 vs. 0.383
# Precision = 0.843 vs. 0.237
# Recall = 0.694 vs. 1.000
# Validation: 1300
# AUC = 0.859 vs. 0.231
# F1 = 0.784 vs. 0.376
# Precision = 0.825 vs. 0.231
# Recall = 0.747 vs. 0.999
# Minibatch Loss= 0.645256
# Training: 1400
# AUC = 0.882 vs. 0.231
# F1 = 0.789 vs. 0.387
# Precision = 0.796 vs. 0.240
# Recall = 0.782 vs. 0.997
# Validation: 1400
# AUC = 0.855 vs. 0.232
# F1 = 0.782 vs. 0.376
# Precision = 0.798 vs. 0.231
# Recall = 0.766 vs. 0.999
# Minibatch Loss= 0.541980
# Training: 1500
# AUC = 0.921 vs. 0.231
# F1 = 0.820 vs. 0.366
# Precision = 0.831 vs. 0.226
# Recall = 0.809 vs. 0.958
# Validation: 1500
# AUC = 0.868 vs. 0.233
# F1 = 0.794 vs. 0.376
# Precision = 0.840 vs. 0.231
# Recall = 0.753 vs. 1.000
# Minibatch Loss= 0.449924
# Training: 1600
# AUC = 0.931 vs. 0.229
# F1 = 0.875 vs. 0.385
# Precision = 0.895 vs. 0.238
# Recall = 0.856 vs. 1.000
# Validation: 1600
# AUC = 0.858 vs. 0.226
# F1 = 0.782 vs. 0.376
# Precision = 0.842 vs. 0.231
# Recall = 0.730 vs. 1.000
# Minibatch Loss= 0.526286
# Training: 1700
# AUC = 0.920 vs. 0.210
# F1 = 0.835 vs. 0.357
# Precision = 0.846 vs. 0.217
# Recall = 0.823 vs. 1.000
# Validation: 1700
# AUC = 0.856 vs. 0.236
# F1 = 0.782 vs. 0.376
# Precision = 0.846 vs. 0.231
# Recall = 0.727 vs. 0.999
# Minibatch Loss= 0.518691
# Training: 1800
# AUC = 0.896 vs. 0.207
# F1 = 0.829 vs. 0.343
# Precision = 0.826 vs. 0.207
# Recall = 0.832 vs. 1.000
# Validation: 1800
# AUC = 0.865 vs. 0.228
# F1 = 0.791 vs. 0.376
# Precision = 0.827 vs. 0.231
# Recall = 0.757 vs. 1.000
# Minibatch Loss= 0.516678
# Training: 1900
# AUC = 0.909 vs. 0.235
# F1 = 0.820 vs. 0.372
# Precision = 0.926 vs. 0.228
# Recall = 0.735 vs. 0.997
# Validation: 1900
# AUC = 0.862 vs. 0.232
# F1 = 0.782 vs. 0.376
# Precision = 0.820 vs. 0.231
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.522074
# Training: 2000
# AUC = 0.915 vs. 0.256
# F1 = 0.816 vs. 0.396
# Precision = 0.780 vs. 0.247
# Recall = 0.854 vs. 1.000
# Validation: 2000
# AUC = 0.858 vs. 0.232
# F1 = 0.783 vs. 0.376
# Precision = 0.816 vs. 0.231
# Recall = 0.753 vs. 1.000
# Minibatch Loss= 0.504934
# Training: 2100
# AUC = 0.814 vs. 0.227
# F1 = 0.741 vs. 0.365
# Precision = 0.845 vs. 0.223
# Recall = 0.660 vs. 1.000
# Validation: 2100
# AUC = 0.860 vs. 0.230
# F1 = 0.786 vs. 0.376
# Precision = 0.824 vs. 0.231
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.728123
# Training: 2200
# AUC = 0.869 vs. 0.230
# F1 = 0.780 vs. 0.398
# Precision = 0.838 vs. 0.249
# Recall = 0.731 vs. 0.998
# Validation: 2200
# AUC = 0.871 vs. 0.230
# F1 = 0.796 vs. 0.376
# Precision = 0.844 vs. 0.231
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.626266
# Training: 2300
# AUC = 0.868 vs. 0.228
# F1 = 0.807 vs. 0.362
# Precision = 0.872 vs. 0.223
# Recall = 0.751 vs. 0.959
# Validation: 2300
# AUC = 0.862 vs. 0.232
# F1 = 0.789 vs. 0.376
# Precision = 0.816 vs. 0.231
# Recall = 0.764 vs. 1.000
# Minibatch Loss= 0.596508
# Training: 2400
# AUC = 0.937 vs. 0.236
# F1 = 0.862 vs. 0.383
# Precision = 0.877 vs. 0.238
# Recall = 0.848 vs. 0.980
# Validation: 2400
# AUC = 0.861 vs. 0.233
# F1 = 0.787 vs. 0.376
# Precision = 0.833 vs. 0.231
# Recall = 0.746 vs. 0.999
# Minibatch Loss= 0.476098
# Training: 2500
# AUC = 0.878 vs. 0.209
# F1 = 0.785 vs. 0.327
# Precision = 0.822 vs. 0.196
# Recall = 0.751 vs. 0.996
# Validation: 2500
# AUC = 0.856 vs. 0.230
# F1 = 0.775 vs. 0.376
# Precision = 0.817 vs. 0.231
# Recall = 0.738 vs. 1.000
# Minibatch Loss= 0.508057
# Training: 2600
# AUC = 0.949 vs. 0.232
# F1 = 0.869 vs. 0.361
# Precision = 0.891 vs. 0.221
# Recall = 0.848 vs. 0.991
# Validation: 2600
# AUC = 0.864 vs. 0.228
# F1 = 0.792 vs. 0.376
# Precision = 0.828 vs. 0.231
# Recall = 0.759 vs. 1.000
# Minibatch Loss= 0.408601
# Training: 2700
# AUC = 0.915 vs. 0.272
# F1 = 0.840 vs. 0.414
# Precision = 0.876 vs. 0.261
# Recall = 0.806 vs. 1.000
# Validation: 2700
# AUC = 0.862 vs. 0.236
# F1 = 0.789 vs. 0.376
# Precision = 0.838 vs. 0.231
# Recall = 0.745 vs. 1.000
# Minibatch Loss= 0.566311
# Training: 2800
# AUC = 0.905 vs. 0.239
# F1 = 0.818 vs. 0.396
# Precision = 0.842 vs. 0.248
# Recall = 0.795 vs. 0.990
# Validation: 2800
# AUC = 0.863 vs. 0.232
# F1 = 0.791 vs. 0.376
# Precision = 0.817 vs. 0.232
# Recall = 0.767 vs. 0.995
# Minibatch Loss= 0.545958
# Training: 2900
# AUC = 0.909 vs. 0.251
# F1 = 0.832 vs. 0.388
# Precision = 0.838 vs. 0.240
# Recall = 0.826 vs. 1.000
# Validation: 2900
# AUC = 0.857 vs. 0.235
# F1 = 0.780 vs. 0.376
# Precision = 0.843 vs. 0.231
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.515748
# Training: 3000
# AUC = 0.887 vs. 0.232
# F1 = 0.794 vs. 0.376
# Precision = 0.876 vs. 0.232
# Recall = 0.725 vs. 0.986
# Validation: 3000
# AUC = 0.861 vs. 0.231
# F1 = 0.789 vs. 0.376
# Precision = 0.816 vs. 0.231
# Recall = 0.763 vs. 0.998
# Minibatch Loss= 0.543201
# Training: 3100
# AUC = 0.881 vs. 0.258
# F1 = 0.790 vs. 0.390
# Precision = 0.793 vs. 0.243
# Recall = 0.786 vs. 0.977
# Validation: 3100
# AUC = 0.863 vs. 0.233
# F1 = 0.787 vs. 0.376
# Precision = 0.816 vs. 0.231
# Recall = 0.760 vs. 0.998
# Minibatch Loss= 0.566299
# Training: 3200
# AUC = 0.943 vs. 0.230
# F1 = 0.862 vs. 0.366
# Precision = 0.869 vs. 0.224
# Recall = 0.855 vs. 1.000
# Validation: 3200
# AUC = 0.863 vs. 0.240
# F1 = 0.781 vs. 0.376
# Precision = 0.821 vs. 0.232
# Recall = 0.745 vs. 0.997
# Minibatch Loss= 0.443785
# Training: 3300
# AUC = 0.937 vs. 0.219
# F1 = 0.860 vs. 0.351
# Precision = 0.882 vs. 0.212
# Recall = 0.838 vs. 1.000
# Validation: 3300
# AUC = 0.869 vs. 0.229
# F1 = 0.795 vs. 0.376
# Precision = 0.836 vs. 0.231
# Recall = 0.758 vs. 0.999
# Minibatch Loss= 0.391355
# Training: 3400
# AUC = 0.956 vs. 0.251
# F1 = 0.877 vs. 0.402
# Precision = 0.877 vs. 0.252
# Recall = 0.877 vs. 1.000
# Validation: 3400
# AUC = 0.861 vs. 0.229
# F1 = 0.781 vs. 0.376
# Precision = 0.844 vs. 0.231
# Recall = 0.728 vs. 1.000
# Minibatch Loss= 0.424432
# Training: 3500
# AUC = 0.957 vs. 0.263
# F1 = 0.895 vs. 0.422
# Precision = 0.883 vs. 0.267
# Recall = 0.908 vs. 1.000
# Validation: 3500
# AUC = 0.857 vs. 0.234
# F1 = 0.780 vs. 0.376
# Precision = 0.821 vs. 0.231
# Recall = 0.742 vs. 0.998
# Minibatch Loss= 0.464991
# Training: 3600
# AUC = 0.926 vs. 0.232
# F1 = 0.849 vs. 0.374
# Precision = 0.856 vs. 0.230
# Recall = 0.842 vs. 1.000
# Validation: 3600
# AUC = 0.855 vs. 0.232
# F1 = 0.782 vs. 0.376
# Precision = 0.812 vs. 0.231
# Recall = 0.754 vs. 1.000
# Minibatch Loss= 0.414152
# Training: 3700
# AUC = 0.848 vs. 0.207
# F1 = 0.775 vs. 0.344
# Precision = 0.794 vs. 0.208
# Recall = 0.757 vs. 0.998
# Validation: 3700
# AUC = 0.860 vs. 0.230
# F1 = 0.782 vs. 0.376
# Precision = 0.803 vs. 0.231
# Recall = 0.762 vs. 1.000
# Minibatch Loss= 0.590903
# Training: 3800
# AUC = 0.942 vs. 0.261
# F1 = 0.869 vs. 0.420
# Precision = 0.858 vs. 0.272
# Recall = 0.880 vs. 0.927
# Validation: 3800
# AUC = 0.844 vs. 0.231
# F1 = 0.760 vs. 0.376
# Precision = 0.784 vs. 0.231
# Recall = 0.737 vs. 0.999
# Minibatch Loss= 0.497510
# Training: 3900
# AUC = 0.943 vs. 0.222
# F1 = 0.864 vs. 0.358
# Precision = 0.857 vs. 0.218
# Recall = 0.871 vs. 0.987
# Validation: 3900
# AUC = 0.853 vs. 0.229
# F1 = 0.777 vs. 0.376
# Precision = 0.786 vs. 0.231
# Recall = 0.768 vs. 0.999
# Minibatch Loss= 0.399788
# Training: 4000
# AUC = 0.984 vs. 0.219
# F1 = 0.929 vs. 0.344
# Precision = 0.947 vs. 0.208
# Recall = 0.911 vs. 1.000
# Validation: 4000
# AUC = 0.861 vs. 0.230
# F1 = 0.788 vs. 0.376
# Precision = 0.814 vs. 0.231
# Recall = 0.763 vs. 1.000
# Minibatch Loss= 0.306978
# Training: 4100
# AUC = 0.966 vs. 0.227
# F1 = 0.899 vs. 0.346
# Precision = 0.867 vs. 0.209
# Recall = 0.935 vs. 1.000
# Validation: 4100
# AUC = 0.856 vs. 0.227
# F1 = 0.780 vs. 0.376
# Precision = 0.801 vs. 0.231
# Recall = 0.760 vs. 1.000
# Minibatch Loss= 0.363890
# Training: 4200
# AUC = 0.955 vs. 0.236
# F1 = 0.876 vs. 0.387
# Precision = 0.854 vs. 0.240
# Recall = 0.899 vs. 1.000
# Validation: 4200
# AUC = 0.855 vs. 0.231
# F1 = 0.769 vs. 0.376
# Precision = 0.808 vs. 0.231
# Recall = 0.734 vs. 1.000
# Minibatch Loss= 0.436618
# Training: 4300
# AUC = 0.955 vs. 0.251
# F1 = 0.894 vs. 0.406
# Precision = 0.888 vs. 0.254
# Recall = 0.900 vs. 1.000
# Validation: 4300
# AUC = 0.855 vs. 0.230
# F1 = 0.781 vs. 0.376
# Precision = 0.817 vs. 0.231
# Recall = 0.748 vs. 0.998
# Minibatch Loss= 0.426752
# Training: 4400
# AUC = 0.977 vs. 0.274
# F1 = 0.918 vs. 0.413
# Precision = 0.909 vs. 0.261
# Recall = 0.927 vs. 1.000
# Validation: 4400
# AUC = 0.855 vs. 0.232
# F1 = 0.780 vs. 0.376
# Precision = 0.793 vs. 0.231
# Recall = 0.768 vs. 1.000
# Minibatch Loss= 0.396775
# Training: 4500
# AUC = 0.970 vs. 0.236
# F1 = 0.914 vs. 0.379
# Precision = 0.919 vs. 0.234
# Recall = 0.908 vs. 1.000
# Validation: 4500
# AUC = 0.854 vs. 0.235
# F1 = 0.781 vs. 0.376
# Precision = 0.821 vs. 0.232
# Recall = 0.745 vs. 0.993
# Minibatch Loss= 0.379167
# Training: 4600
# AUC = 0.976 vs. 0.259
# F1 = 0.914 vs. 0.405
# Precision = 0.927 vs. 0.255
# Recall = 0.901 vs. 0.991
# Validation: 4600
# AUC = 0.861 vs. 0.234
# F1 = 0.783 vs. 0.376
# Precision = 0.809 vs. 0.231
# Recall = 0.759 vs. 1.000
# Minibatch Loss= 0.391902
# Training: 4700
# AUC = 0.973 vs. 0.210
# F1 = 0.907 vs. 0.357
# Precision = 0.888 vs. 0.217
# Recall = 0.926 vs. 1.000
# Validation: 4700
# AUC = 0.860 vs. 0.232
# F1 = 0.786 vs. 0.376
# Precision = 0.825 vs. 0.231
# Recall = 0.750 vs. 1.000
# Minibatch Loss= 0.349595
# Training: 4800
# AUC = 0.966 vs. 0.217
# F1 = 0.898 vs. 0.348
# Precision = 0.871 vs. 0.213
# Recall = 0.925 vs. 0.957
# Validation: 4800
# AUC = 0.856 vs. 0.230
# F1 = 0.774 vs. 0.376
# Precision = 0.799 vs. 0.231
# Recall = 0.750 vs. 0.999
# Minibatch Loss= 0.362273
# Training: 4900
# AUC = 0.982 vs. 0.210
# F1 = 0.924 vs. 0.363
# Precision = 0.929 vs. 0.222
# Recall = 0.919 vs. 1.000
# Validation: 4900
# AUC = 0.853 vs. 0.236
# F1 = 0.783 vs. 0.376
# Precision = 0.811 vs. 0.231
# Recall = 0.756 vs. 1.000
# Minibatch Loss= 0.355720
# Training: 5000
# AUC = 0.963 vs. 0.211
# F1 = 0.888 vs. 0.345
# Precision = 0.913 vs. 0.209
# Recall = 0.865 vs. 0.989
# Validation: 5000
# AUC = 0.861 vs. 0.231
# F1 = 0.787 vs. 0.376
# Precision = 0.801 vs. 0.232
# Recall = 0.774 vs. 0.995
# Minibatch Loss= 0.357479
# Training: 5100
# AUC = 0.970 vs. 0.249
# F1 = 0.903 vs. 0.386
# Precision = 0.932 vs. 0.240
# Recall = 0.876 vs. 0.982
# Validation: 5100
# AUC = 0.851 vs. 0.226
# F1 = 0.779 vs. 0.376
# Precision = 0.814 vs. 0.232
# Recall = 0.747 vs. 0.995
# Minibatch Loss= 0.359724
# Training: 5200
# AUC = 0.959 vs. 0.244
# F1 = 0.893 vs. 0.401
# Precision = 0.850 vs. 0.250
# Recall = 0.941 vs. 1.000
# Validation: 5200
# AUC = 0.856 vs. 0.236
# F1 = 0.784 vs. 0.376
# Precision = 0.825 vs. 0.231
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.385926
# Training: 5300
# AUC = 0.953 vs. 0.235
# F1 = 0.897 vs. 0.369
# Precision = 0.896 vs. 0.226
# Recall = 0.898 vs. 0.993
# Validation: 5300
# AUC = 0.844 vs. 0.232
# F1 = 0.771 vs. 0.376
# Precision = 0.798 vs. 0.231
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.384348
# Training: 5400
# AUC = 0.977 vs. 0.225
# F1 = 0.911 vs. 0.381
# Precision = 0.932 vs. 0.235
# Recall = 0.890 vs. 1.000
# Validation: 5400
# AUC = 0.843 vs. 0.235
# F1 = 0.769 vs. 0.376
# Precision = 0.779 vs. 0.231
# Recall = 0.759 vs. 1.000
# Minibatch Loss= 0.331008
# Training: 5500
# AUC = 0.954 vs. 0.203
# F1 = 0.893 vs. 0.343
# Precision = 0.890 vs. 0.207
# Recall = 0.897 vs. 0.985
# Validation: 5500
# AUC = 0.850 vs. 0.232
# F1 = 0.778 vs. 0.376
# Precision = 0.809 vs. 0.231
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.326471
# Training: 5600
# AUC = 0.980 vs. 0.231
# F1 = 0.923 vs. 0.371
# Precision = 0.909 vs. 0.228
# Recall = 0.938 vs. 1.000
# Validation: 5600
# AUC = 0.844 vs. 0.227
# F1 = 0.774 vs. 0.376
# Precision = 0.798 vs. 0.231
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.350961
# Training: 5700
# AUC = 0.978 vs. 0.248
# F1 = 0.923 vs. 0.387
# Precision = 0.943 vs. 0.241
# Recall = 0.903 vs. 0.985
# Validation: 5700
# AUC = 0.842 vs. 0.227
# F1 = 0.774 vs. 0.376
# Precision = 0.797 vs. 0.231
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.361789
# Training: 5800
# AUC = 0.985 vs. 0.211
# F1 = 0.932 vs. 0.334
# Precision = 0.909 vs. 0.200
# Recall = 0.955 vs. 1.000
# Validation: 5800
# AUC = 0.842 vs. 0.230
# F1 = 0.770 vs. 0.376
# Precision = 0.789 vs. 0.231
# Recall = 0.753 vs. 0.998
# Minibatch Loss= 0.254173
# Training: 5900
# AUC = 0.972 vs. 0.216
# F1 = 0.906 vs. 0.353
# Precision = 0.875 vs. 0.215
# Recall = 0.940 vs. 0.984
# Validation: 5900
# AUC = 0.847 vs. 0.229
# F1 = 0.771 vs. 0.376
# Precision = 0.835 vs. 0.231
# Recall = 0.716 vs. 0.999
# Minibatch Loss= 0.335239
# Training: 6000
# AUC = 0.971 vs. 0.237
# F1 = 0.909 vs. 0.397
# Precision = 0.916 vs. 0.248
# Recall = 0.902 vs. 0.995
# Validation: 6000
# AUC = 0.833 vs. 0.233
# F1 = 0.755 vs. 0.376
# Precision = 0.770 vs. 0.231
# Recall = 0.742 vs. 0.999
# Minibatch Loss= 0.404837
# Training: 6100
# AUC = 0.946 vs. 0.228
# F1 = 0.860 vs. 0.380
# Precision = 0.871 vs. 0.236
# Recall = 0.848 vs. 0.975
# Validation: 6100
# AUC = 0.853 vs. 0.234
# F1 = 0.775 vs. 0.376
# Precision = 0.820 vs. 0.231
# Recall = 0.735 vs. 1.000
# Minibatch Loss= 0.421862
# Training: 6200
# AUC = 0.960 vs. 0.215
# F1 = 0.879 vs. 0.361
# Precision = 0.829 vs. 0.221
# Recall = 0.936 vs. 0.988
# Validation: 6200
# AUC = 0.850 vs. 0.229
# F1 = 0.776 vs. 0.376
# Precision = 0.805 vs. 0.232
# Recall = 0.748 vs. 0.992
# Minibatch Loss= 0.368865
# Training: 6300
# AUC = 0.974 vs. 0.204
# F1 = 0.916 vs. 0.344
# Precision = 0.882 vs. 0.208
# Recall = 0.953 vs. 0.994
# Validation: 6300
# AUC = 0.844 vs. 0.233
# F1 = 0.765 vs. 0.376
# Precision = 0.780 vs. 0.232
# Recall = 0.750 vs. 0.991
# Minibatch Loss= 0.326732
# Training: 6400
# AUC = 0.976 vs. 0.226
# F1 = 0.921 vs. 0.371
# Precision = 0.925 vs. 0.228
# Recall = 0.916 vs. 1.000
# Validation: 6400
# AUC = 0.845 vs. 0.237
# F1 = 0.773 vs. 0.376
# Precision = 0.791 vs. 0.232
# Recall = 0.756 vs. 0.991
# Minibatch Loss= 0.342215
# Training: 6500
# AUC = 0.989 vs. 0.257
# F1 = 0.945 vs. 0.403
# Precision = 0.940 vs. 0.265
# Recall = 0.950 vs. 0.841
# Validation: 6500
# AUC = 0.844 vs. 0.231
# F1 = 0.769 vs. 0.376
# Precision = 0.774 vs. 0.232
# Recall = 0.764 vs. 0.994
# Minibatch Loss= 0.330875
# Training: 6600
# AUC = 0.985 vs. 0.239
# F1 = 0.942 vs. 0.386
# Precision = 0.919 vs. 0.240
# Recall = 0.966 vs. 0.993
# Validation: 6600
# AUC = 0.846 vs. 0.231
# F1 = 0.774 vs. 0.376
# Precision = 0.798 vs. 0.231
# Recall = 0.752 vs. 1.000
# Minibatch Loss= 0.367797
# Training: 6700
# AUC = 0.991 vs. 0.233
# F1 = 0.952 vs. 0.384
# Precision = 0.949 vs. 0.238
# Recall = 0.954 vs. 0.992
# Validation: 6700
# AUC = 0.839 vs. 0.232
# F1 = 0.769 vs. 0.376
# Precision = 0.785 vs. 0.231
# Recall = 0.754 vs. 0.999
# Minibatch Loss= 0.300380
# Training: 6800
# AUC = 0.994 vs. 0.233
# F1 = 0.968 vs. 0.393
# Precision = 0.975 vs. 0.246
# Recall = 0.961 vs. 0.987
# Validation: 6800
# AUC = 0.847 vs. 0.235
# F1 = 0.773 vs. 0.376
# Precision = 0.782 vs. 0.231
# Recall = 0.764 vs. 1.000
# Minibatch Loss= 0.292072
# Training: 6900
# AUC = 0.988 vs. 0.248
# F1 = 0.938 vs. 0.407
# Precision = 0.926 vs. 0.255
# Recall = 0.951 vs. 0.995
# Validation: 6900
# AUC = 0.838 vs. 0.233
# F1 = 0.769 vs. 0.376
# Precision = 0.790 vs. 0.231
# Recall = 0.750 vs. 0.999
# Minibatch Loss= 0.377406
# Training: 7000
# AUC = 0.986 vs. 0.283
# F1 = 0.940 vs. 0.425
# Precision = 0.931 vs. 0.270
# Recall = 0.949 vs. 0.996
# Validation: 7000
# AUC = 0.837 vs. 0.233
# F1 = 0.768 vs. 0.376
# Precision = 0.791 vs. 0.231
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.407463
# Training: 7100
# AUC = 0.992 vs. 0.202
# F1 = 0.960 vs. 0.329
# Precision = 0.985 vs. 0.197
# Recall = 0.937 vs. 0.998
# Validation: 7100
# AUC = 0.836 vs. 0.232
# F1 = 0.763 vs. 0.376
# Precision = 0.763 vs. 0.231
# Recall = 0.762 vs. 0.999
# Minibatch Loss= 0.255484
# Training: 7200
# AUC = 0.991 vs. 0.240
# F1 = 0.949 vs. 0.364
# Precision = 0.932 vs. 0.226
# Recall = 0.966 vs. 0.928
# Validation: 7200
# AUC = 0.836 vs. 0.226
# F1 = 0.766 vs. 0.376
# Precision = 0.786 vs. 0.231
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.320526
# Training: 7300
# AUC = 0.989 vs. 0.240
# F1 = 0.948 vs. 0.395
# Precision = 0.943 vs. 0.246
# Recall = 0.952 vs. 0.998
# Validation: 7300
# AUC = 0.836 vs. 0.234
# F1 = 0.768 vs. 0.376
# Precision = 0.778 vs. 0.231
# Recall = 0.758 vs. 1.000
# Minibatch Loss= 0.339127
# Training: 7400
# AUC = 0.986 vs. 0.192
# F1 = 0.938 vs. 0.334
# Precision = 0.923 vs. 0.202
# Recall = 0.952 vs. 0.974
# Validation: 7400
# AUC = 0.836 vs. 0.234
# F1 = 0.765 vs. 0.376
# Precision = 0.784 vs. 0.231
# Recall = 0.747 vs. 0.999
# Minibatch Loss= 0.276511
# Training: 7500
# AUC = 0.991 vs. 0.269
# F1 = 0.950 vs. 0.399
# Precision = 0.937 vs. 0.250
# Recall = 0.964 vs. 0.991
# Validation: 7500
# AUC = 0.836 vs. 0.231
# F1 = 0.762 vs. 0.376
# Precision = 0.772 vs. 0.231
# Recall = 0.753 vs. 0.999
# Minibatch Loss= 0.316276
# Training: 7600
# AUC = 0.989 vs. 0.235
# F1 = 0.942 vs. 0.378
# Precision = 0.912 vs. 0.233
# Recall = 0.975 vs. 1.000
# Validation: 7600
# AUC = 0.827 vs. 0.234
# F1 = 0.766 vs. 0.376
# Precision = 0.768 vs. 0.232
# Recall = 0.764 vs. 0.997
# Minibatch Loss= 0.325257
# Training: 7700
# AUC = 0.986 vs. 0.238
# F1 = 0.941 vs. 0.380
# Precision = 0.940 vs. 0.239
# Recall = 0.941 vs. 0.921
# Validation: 7700
# AUC = 0.835 vs. 0.231
# F1 = 0.762 vs. 0.376
# Precision = 0.782 vs. 0.231
# Recall = 0.743 vs. 0.998
# Minibatch Loss= 0.338209
# Training: 7800
# AUC = 0.990 vs. 0.237
# F1 = 0.948 vs. 0.399
# Precision = 0.934 vs. 0.250
# Recall = 0.962 vs. 0.997
# Validation: 7800
# AUC = 0.838 vs. 0.231
# F1 = 0.764 vs. 0.376
# Precision = 0.804 vs. 0.231
# Recall = 0.727 vs. 0.998
# Minibatch Loss= 0.365808
# Training: 7900
# AUC = 0.991 vs. 0.232
# F1 = 0.947 vs. 0.387
# Precision = 0.929 vs. 0.241
# Recall = 0.966 vs. 0.972
# Validation: 7900
# AUC = 0.837 vs. 0.237
# F1 = 0.766 vs. 0.376
# Precision = 0.777 vs. 0.232
# Recall = 0.756 vs. 0.995
# Minibatch Loss= 0.340101
# Training: 8000
# AUC = 0.993 vs. 0.203
# F1 = 0.959 vs. 0.350
# Precision = 0.957 vs. 0.212
# Recall = 0.961 vs. 0.994
# Validation: 8000
# AUC = 0.833 vs. 0.232
# F1 = 0.757 vs. 0.376
# Precision = 0.760 vs. 0.231
# Recall = 0.754 vs. 1.000
# Minibatch Loss= 0.304992
# Training: 8100
# AUC = 0.995 vs. 0.228
# F1 = 0.965 vs. 0.369
# Precision = 0.962 vs. 0.227
# Recall = 0.967 vs. 0.995
# Validation: 8100
# AUC = 0.832 vs. 0.231
# F1 = 0.760 vs. 0.376
# Precision = 0.777 vs. 0.231
# Recall = 0.743 vs. 1.000
# Minibatch Loss= 0.313189
# Training: 8200
# AUC = 0.986 vs. 0.204
# F1 = 0.940 vs. 0.338
# Precision = 0.932 vs. 0.203
# Recall = 0.948 vs. 1.000
# Validation: 8200
# AUC = 0.836 vs. 0.228
# F1 = 0.767 vs. 0.376
# Precision = 0.789 vs. 0.231
# Recall = 0.747 vs. 1.000
# Minibatch Loss= 0.298313
# Training: 8300
# AUC = 0.991 vs. 0.235
# F1 = 0.954 vs. 0.352
# Precision = 0.941 vs. 0.214
# Recall = 0.967 vs. 0.989
# Validation: 8300
# AUC = 0.838 vs. 0.231
# F1 = 0.769 vs. 0.376
# Precision = 0.759 vs. 0.231
# Recall = 0.779 vs. 1.000
# Minibatch Loss= 0.307013
# Training: 8400
# AUC = 0.986 vs. 0.240
# F1 = 0.942 vs. 0.394
# Precision = 0.936 vs. 0.248
# Recall = 0.948 vs. 0.955
# Validation: 8400
# AUC = 0.828 vs. 0.231
# F1 = 0.762 vs. 0.376
# Precision = 0.785 vs. 0.231
# Recall = 0.740 vs. 0.999
# Minibatch Loss= 0.324925
# Training: 8500
# AUC = 0.985 vs. 0.220
# F1 = 0.937 vs. 0.376
# Precision = 0.925 vs. 0.231
# Recall = 0.949 vs. 1.000
# Validation: 8500
# AUC = 0.839 vs. 0.235
# F1 = 0.765 vs. 0.376
# Precision = 0.822 vs. 0.232
# Recall = 0.715 vs. 0.997
# Minibatch Loss= 0.369745
# Training: 8600
# AUC = 0.936 vs. 0.226
# F1 = 0.853 vs. 0.380
# Precision = 0.834 vs. 0.236
# Recall = 0.873 vs. 0.978
# Validation: 8600
# AUC = 0.839 vs. 0.232
# F1 = 0.762 vs. 0.376
# Precision = 0.816 vs. 0.232
# Recall = 0.715 vs. 0.999
# Minibatch Loss= 0.467011
# Training: 8700
# AUC = 0.947 vs. 0.249
# F1 = 0.880 vs. 0.402
# Precision = 0.917 vs. 0.251
# Recall = 0.846 vs. 1.000
# Validation: 8700
# AUC = 0.829 vs. 0.234
# F1 = 0.753 vs. 0.376
# Precision = 0.783 vs. 0.231
# Recall = 0.726 vs. 0.999
# Minibatch Loss= 0.451570
# Training: 8800
# AUC = 0.919 vs. 0.233
# F1 = 0.855 vs. 0.367
# Precision = 0.855 vs. 0.225
# Recall = 0.855 vs. 0.998
# Validation: 8800
# AUC = 0.850 vs. 0.227
# F1 = 0.774 vs. 0.376
# Precision = 0.775 vs. 0.231
# Recall = 0.773 vs. 0.999
# Minibatch Loss= 0.491446
# Training: 8900
# AUC = 0.982 vs. 0.230
# F1 = 0.924 vs. 0.390
# Precision = 0.924 vs. 0.243
# Recall = 0.925 vs. 0.976
# Validation: 8900
# AUC = 0.850 vs. 0.233
# F1 = 0.770 vs. 0.376
# Precision = 0.784 vs. 0.231
# Recall = 0.758 vs. 1.000
# Minibatch Loss= 0.383762
# Training: 9000
# AUC = 0.982 vs. 0.245
# F1 = 0.930 vs. 0.391
# Precision = 0.909 vs. 0.243
# Recall = 0.951 vs. 0.995
# Validation: 9000
# AUC = 0.845 vs. 0.227
# F1 = 0.776 vs. 0.376
# Precision = 0.781 vs. 0.231
# Recall = 0.771 vs. 0.999
# Minibatch Loss= 0.337640
# Training: 9100
# AUC = 0.988 vs. 0.295
# F1 = 0.950 vs. 0.430
# Precision = 0.942 vs. 0.275
# Recall = 0.957 vs. 0.990
# Validation: 9100
# AUC = 0.842 vs. 0.233
# F1 = 0.772 vs. 0.376
# Precision = 0.777 vs. 0.231
# Recall = 0.767 vs. 1.000
# Minibatch Loss= 0.390674
# Training: 9200
# AUC = 0.991 vs. 0.221
# F1 = 0.947 vs. 0.376
# Precision = 0.934 vs. 0.231
# Recall = 0.959 vs. 1.000
# Validation: 9200
# AUC = 0.838 vs. 0.230
# F1 = 0.769 vs. 0.376
# Precision = 0.793 vs. 0.231
# Recall = 0.746 vs. 1.000
# Minibatch Loss= 0.318378
# Training: 9300
# AUC = 0.991 vs. 0.251
# F1 = 0.951 vs. 0.370
# Precision = 0.936 vs. 0.227
# Recall = 0.967 vs. 0.993
# Validation: 9300
# AUC = 0.833 vs. 0.236
# F1 = 0.768 vs. 0.376
# Precision = 0.796 vs. 0.231
# Recall = 0.742 vs. 1.000
# Minibatch Loss= 0.306485
# Training: 9400
# AUC = 0.992 vs. 0.249
# F1 = 0.959 vs. 0.393
# Precision = 0.955 vs. 0.244
# Recall = 0.962 vs. 1.000
# Validation: 9400
# AUC = 0.837 vs. 0.234
# F1 = 0.769 vs. 0.376
# Precision = 0.790 vs. 0.231
# Recall = 0.750 vs. 1.000
# Minibatch Loss= 0.307765
# Training: 9500
# AUC = 0.995 vs. 0.236
# F1 = 0.961 vs. 0.388
# Precision = 0.944 vs. 0.241
# Recall = 0.979 vs. 1.000
# Validation: 9500
# AUC = 0.836 vs. 0.231
# F1 = 0.765 vs. 0.376
# Precision = 0.796 vs. 0.231
# Recall = 0.737 vs. 1.000
# Minibatch Loss= 0.321861

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-76115a49481e> in <module>()
# ----> 1 saver = tf.train.Saver()
#       2 saver.save(sess, checkpoint_path, global_step=trainer.global_step)
#
# NameError: name 'tf' is not defined

# %%
#saver = tf.train.Saver()
#saver.restore(sess, checkpoint_path+'-1000')

# %%
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.962 vs. 0.232
# F1 = 0.891 vs. 0.376
# Precision = 0.879 vs. 0.231
# Recall = 0.904 vs. 0.998

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})
