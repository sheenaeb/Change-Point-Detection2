# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_synthetic_1"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,64,64, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import hickle

sys.path.append('../src')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from models.HRNN_model import Model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data2.h'

with open(data_path, 'r') as fin:
    data = hickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape
# Out:
# (890, 8192, 12)

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

wavelet_levels= 6
convolution_levels = 5
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]

bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions

lstm_n_hidden = 128
n_classes = 1

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight
# Out:
# array([ 3.18601822])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary_synthetic/' + exp_name 
checkpoint_path = '../model_synthetic/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights,
                 optimizer = tf.train.AdamOptimizer
)
# Out:
# 6
# Tensor("Squeeze_29:0", shape=(?, ?, 64), dtype=float32)
# Tensor("Squeeze_29:0", shape=(?, ?, 64), dtype=float32) Tensor("zeros:0", shape=(?, ?, 128), dtype=float32) 5
# Tensor("Squeeze_24:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape:0", shape=(?, ?, ?), dtype=float32) 4
# Tensor("Squeeze_19:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_1:0", shape=(?, ?, ?), dtype=float32) 3
# Tensor("Squeeze_14:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_2:0", shape=(?, ?, ?), dtype=float32) 2
# Tensor("Squeeze_9:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_3:0", shape=(?, ?, ?), dtype=float32) 1
# Tensor("Squeeze_4:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_4:0", shape=(?, ?, ?), dtype=float32) 0
# Tensor("Squeeze_30:0", shape=(?, ?, 1), dtype=float32) Tensor("Reshape_7:0", shape=(?, ?, 1), dtype=float32)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = test_data,
                    ground_truth_validation = test_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'change')

# %%
trainer.train(max_iter = 20000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 0
# AUC = 0.241 vs. 0.242
# F1 = 0.392 vs. 0.384
# Precision = 0.307 vs. 0.238
# Recall = 0.540 vs. 1.000
# Validation: 0
# AUC = 0.204 vs. 0.232
# F1 = 0.376 vs. 0.376
# Precision = 0.231 vs. 0.231
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 1.069105
# Training: 100
# AUC = 0.589 vs. 0.241
# F1 = 0.581 vs. 0.378
# Precision = 0.442 vs. 0.238
# Recall = 0.847 vs. 0.916
# Validation: 100
# AUC = 0.503 vs. 0.232
# F1 = 0.483 vs. 0.376
# Precision = 0.405 vs. 0.232
# Recall = 0.597 vs. 0.997
# Minibatch Loss= 0.822554
# Training: 200
# AUC = 0.721 vs. 0.202
# F1 = 0.693 vs. 0.346
# Precision = 0.673 vs. 0.209
# Recall = 0.714 vs. 0.998
# Validation: 200
# AUC = 0.725 vs. 0.229
# F1 = 0.674 vs. 0.376
# Precision = 0.660 vs. 0.231
# Recall = 0.688 vs. 1.000
# Minibatch Loss= 0.692992
# Training: 300
# AUC = 0.903 vs. 0.207
# F1 = 0.837 vs. 0.361
# Precision = 0.847 vs. 0.220
# Recall = 0.828 vs. 1.000
# Validation: 300
# AUC = 0.870 vs. 0.226
# F1 = 0.785 vs. 0.376
# Precision = 0.785 vs. 0.232
# Recall = 0.786 vs. 0.997
# Minibatch Loss= 0.489919
# Training: 400
# AUC = 0.881 vs. 0.245
# F1 = 0.787 vs. 0.371
# Precision = 0.779 vs. 0.228
# Recall = 0.796 vs. 1.000
# Validation: 400
# AUC = 0.893 vs. 0.230
# F1 = 0.809 vs. 0.376
# Precision = 0.807 vs. 0.232
# Recall = 0.812 vs. 0.998
# Minibatch Loss= 0.522534
# Training: 500
# AUC = 0.941 vs. 0.233
# F1 = 0.872 vs. 0.374
# Precision = 0.859 vs. 0.231
# Recall = 0.886 vs. 0.990
# Validation: 500
# AUC = 0.936 vs. 0.230
# F1 = 0.859 vs. 0.376
# Precision = 0.863 vs. 0.231
# Recall = 0.856 vs. 1.000
# Minibatch Loss= 0.424231
# Training: 600
# AUC = 0.935 vs. 0.208
# F1 = 0.851 vs. 0.339
# Precision = 0.852 vs. 0.205
# Recall = 0.849 vs. 0.973
# Validation: 600
# AUC = 0.931 vs. 0.231
# F1 = 0.852 vs. 0.376
# Precision = 0.837 vs. 0.231
# Recall = 0.868 vs. 1.000
# Minibatch Loss= 0.386967
# Training: 700
# AUC = 0.951 vs. 0.269
# F1 = 0.872 vs. 0.412
# Precision = 0.846 vs. 0.259
# Recall = 0.899 vs. 1.000
# Validation: 700
# AUC = 0.942 vs. 0.232
# F1 = 0.861 vs. 0.376
# Precision = 0.868 vs. 0.231
# Recall = 0.855 vs. 1.000
# Minibatch Loss= 0.460476
# Training: 800
# AUC = 0.962 vs. 0.235
# F1 = 0.900 vs. 0.381
# Precision = 0.896 vs. 0.236
# Recall = 0.904 vs. 1.000
# Validation: 800
# AUC = 0.943 vs. 0.229
# F1 = 0.865 vs. 0.376
# Precision = 0.861 vs. 0.231
# Recall = 0.868 vs. 0.999
# Minibatch Loss= 0.481529
# Training: 900
# AUC = 0.949 vs. 0.178
# F1 = 0.883 vs. 0.298
# Precision = 0.880 vs. 0.175
# Recall = 0.886 vs. 0.998
# Validation: 900
# AUC = 0.946 vs. 0.233
# F1 = 0.866 vs. 0.376
# Precision = 0.858 vs. 0.231
# Recall = 0.874 vs. 1.000
# Minibatch Loss= 0.345775
# Training: 1000
# AUC = 0.931 vs. 0.227
# F1 = 0.855 vs. 0.362
# Precision = 0.896 vs. 0.221
# Recall = 0.818 vs. 1.000
# Validation: 1000
# AUC = 0.940 vs. 0.229
# F1 = 0.859 vs. 0.376
# Precision = 0.863 vs. 0.231
# Recall = 0.855 vs. 1.000
# Minibatch Loss= 0.459459
# Training: 1100
# AUC = 0.958 vs. 0.208
# F1 = 0.878 vs. 0.352
# Precision = 0.907 vs. 0.214
# Recall = 0.852 vs. 0.996
# Validation: 1100
# AUC = 0.951 vs. 0.237
# F1 = 0.877 vs. 0.376
# Precision = 0.872 vs. 0.231
# Recall = 0.882 vs. 1.000
# Minibatch Loss= 0.353402
# Training: 1200
# AUC = 0.973 vs. 0.215
# F1 = 0.921 vs. 0.341
# Precision = 0.905 vs. 0.206
# Recall = 0.939 vs. 0.989
# Validation: 1200
# AUC = 0.954 vs. 0.232
# F1 = 0.877 vs. 0.376
# Precision = 0.891 vs. 0.232
# Recall = 0.863 vs. 0.997
# Minibatch Loss= 0.328549
# Training: 1300
# AUC = 0.926 vs. 0.233
# F1 = 0.844 vs. 0.383
# Precision = 0.857 vs. 0.238
# Recall = 0.831 vs. 0.970
# Validation: 1300
# AUC = 0.947 vs. 0.233
# F1 = 0.869 vs. 0.376
# Precision = 0.869 vs. 0.231
# Recall = 0.870 vs. 1.000
# Minibatch Loss= 0.494669
# Training: 1400
# AUC = 0.967 vs. 0.240
# F1 = 0.898 vs. 0.383
# Precision = 0.877 vs. 0.237
# Recall = 0.921 vs. 0.998
# Validation: 1400
# AUC = 0.952 vs. 0.232
# F1 = 0.876 vs. 0.376
# Precision = 0.894 vs. 0.231
# Recall = 0.859 vs. 1.000
# Minibatch Loss= 0.367076
# Training: 1500
# AUC = 0.955 vs. 0.240
# F1 = 0.882 vs. 0.384
# Precision = 0.869 vs. 0.238
# Recall = 0.896 vs. 0.995
# Validation: 1500
# AUC = 0.946 vs. 0.232
# F1 = 0.868 vs. 0.376
# Precision = 0.882 vs. 0.232
# Recall = 0.855 vs. 0.992
# Minibatch Loss= 0.459782
# Training: 1600
# AUC = 0.968 vs. 0.230
# F1 = 0.896 vs. 0.372
# Precision = 0.908 vs. 0.232
# Recall = 0.884 vs. 0.943
# Validation: 1600
# AUC = 0.954 vs. 0.235
# F1 = 0.876 vs. 0.376
# Precision = 0.895 vs. 0.231
# Recall = 0.857 vs. 0.999
# Minibatch Loss= 0.321446
# Training: 1700
# AUC = 0.975 vs. 0.220
# F1 = 0.914 vs. 0.354
# Precision = 0.890 vs. 0.215
# Recall = 0.940 vs. 1.000
# Validation: 1700
# AUC = 0.954 vs. 0.234
# F1 = 0.883 vs. 0.376
# Precision = 0.886 vs. 0.232
# Recall = 0.881 vs. 0.997
# Minibatch Loss= 0.300107
# Training: 1800
# AUC = 0.968 vs. 0.216
# F1 = 0.891 vs. 0.355
# Precision = 0.916 vs. 0.216
# Recall = 0.868 vs. 1.000
# Validation: 1800
# AUC = 0.950 vs. 0.231
# F1 = 0.874 vs. 0.376
# Precision = 0.875 vs. 0.231
# Recall = 0.873 vs. 1.000
# Minibatch Loss= 0.339354
# Training: 1900
# AUC = 0.961 vs. 0.258
# F1 = 0.887 vs. 0.403
# Precision = 0.914 vs. 0.252
# Recall = 0.862 vs. 1.000
# Validation: 1900
# AUC = 0.957 vs. 0.231
# F1 = 0.885 vs. 0.376
# Precision = 0.901 vs. 0.231
# Recall = 0.871 vs. 1.000
# Minibatch Loss= 0.400508
# Training: 2000
# AUC = 0.967 vs. 0.246
# F1 = 0.896 vs. 0.382
# Precision = 0.883 vs. 0.236
# Recall = 0.910 vs. 1.000
# Validation: 2000
# AUC = 0.962 vs. 0.232
# F1 = 0.891 vs. 0.376
# Precision = 0.904 vs. 0.231
# Recall = 0.879 vs. 1.000
# Minibatch Loss= 0.395105
# Training: 2100
# AUC = 0.976 vs. 0.216
# F1 = 0.923 vs. 0.354
# Precision = 0.896 vs. 0.215
# Recall = 0.953 vs. 1.000
# Validation: 2100
# AUC = 0.962 vs. 0.233
# F1 = 0.893 vs. 0.376
# Precision = 0.887 vs. 0.231
# Recall = 0.899 vs. 1.000
# Minibatch Loss= 0.324906
# Training: 2200
# AUC = 0.982 vs. 0.248
# F1 = 0.929 vs. 0.374
# Precision = 0.918 vs. 0.233
# Recall = 0.940 vs. 0.950
# Validation: 2200
# AUC = 0.958 vs. 0.233
# F1 = 0.890 vs. 0.376
# Precision = 0.891 vs. 0.231
# Recall = 0.889 vs. 1.000
# Minibatch Loss= 0.321053
# Training: 2300
# AUC = 0.964 vs. 0.245
# F1 = 0.896 vs. 0.371
# Precision = 0.895 vs. 0.228
# Recall = 0.897 vs. 1.000
# Validation: 2300
# AUC = 0.962 vs. 0.232
# F1 = 0.891 vs. 0.376
# Precision = 0.906 vs. 0.231
# Recall = 0.876 vs. 1.000
# Minibatch Loss= 0.353611
# Training: 2400
# AUC = 0.958 vs. 0.246
# F1 = 0.887 vs. 0.381
# Precision = 0.851 vs. 0.235
# Recall = 0.926 vs. 0.998
# Validation: 2400
# AUC = 0.963 vs. 0.231
# F1 = 0.896 vs. 0.376
# Precision = 0.900 vs. 0.232
# Recall = 0.893 vs. 0.992
# Minibatch Loss= 0.379190
# Training: 2500
# AUC = 0.958 vs. 0.277
# F1 = 0.878 vs. 0.438
# Precision = 0.873 vs. 0.280
# Recall = 0.883 vs. 0.999
# Validation: 2500
# AUC = 0.956 vs. 0.232
# F1 = 0.884 vs. 0.376
# Precision = 0.888 vs. 0.231
# Recall = 0.880 vs. 0.999
# Minibatch Loss= 0.460016
# Training: 2600
# AUC = 0.967 vs. 0.210
# F1 = 0.907 vs. 0.351
# Precision = 0.916 vs. 0.213
# Recall = 0.899 vs. 0.996
# Validation: 2600
# AUC = 0.965 vs. 0.230
# F1 = 0.898 vs. 0.376
# Precision = 0.896 vs. 0.231
# Recall = 0.901 vs. 1.000
# Minibatch Loss= 0.374656
# Training: 2700
# AUC = 0.982 vs. 0.231
# F1 = 0.928 vs. 0.362
# Precision = 0.930 vs. 0.221
# Recall = 0.925 vs. 0.998
# Validation: 2700
# AUC = 0.960 vs. 0.234
# F1 = 0.890 vs. 0.376
# Precision = 0.886 vs. 0.231
# Recall = 0.894 vs. 1.000
# Minibatch Loss= 0.330064
# Training: 2800
# AUC = 0.979 vs. 0.219
# F1 = 0.926 vs. 0.364
# Precision = 0.903 vs. 0.223
# Recall = 0.951 vs. 1.000
# Validation: 2800
# AUC = 0.965 vs. 0.232
# F1 = 0.900 vs. 0.376
# Precision = 0.926 vs. 0.231
# Recall = 0.875 vs. 1.000
# Minibatch Loss= 0.330573
# Training: 2900
# AUC = 0.981 vs. 0.201
# F1 = 0.928 vs. 0.331
# Precision = 0.932 vs. 0.198
# Recall = 0.925 vs. 0.992
# Validation: 2900
# AUC = 0.964 vs. 0.229
# F1 = 0.899 vs. 0.376
# Precision = 0.924 vs. 0.231
# Recall = 0.875 vs. 0.999
# Minibatch Loss= 0.312307
# Training: 3000
# AUC = 0.986 vs. 0.247
# F1 = 0.939 vs. 0.382
# Precision = 0.911 vs. 0.236
# Recall = 0.968 vs. 0.993
# Validation: 3000
# AUC = 0.963 vs. 0.229
# F1 = 0.898 vs. 0.376
# Precision = 0.926 vs. 0.231
# Recall = 0.871 vs. 0.997
# Minibatch Loss= 0.321064
# Training: 3100
# AUC = 0.988 vs. 0.232
# F1 = 0.936 vs. 0.371
# Precision = 0.939 vs. 0.229
# Recall = 0.933 vs. 0.976
# Validation: 3100
# AUC = 0.962 vs. 0.231
# F1 = 0.894 vs. 0.376
# Precision = 0.913 vs. 0.231
# Recall = 0.876 vs. 0.999
# Minibatch Loss= 0.316742
# Training: 3200
# AUC = 0.989 vs. 0.241
# F1 = 0.939 vs. 0.373
# Precision = 0.922 vs. 0.229
# Recall = 0.956 vs. 0.998
# Validation: 3200
# AUC = 0.958 vs. 0.235
# F1 = 0.892 vs. 0.376
# Precision = 0.904 vs. 0.231
# Recall = 0.880 vs. 0.999
# Minibatch Loss= 0.330284
# Training: 3300
# AUC = 0.977 vs. 0.268
# F1 = 0.919 vs. 0.403
# Precision = 0.925 vs. 0.252
# Recall = 0.913 vs. 0.997
# Validation: 3300
# AUC = 0.950 vs. 0.229
# F1 = 0.872 vs. 0.376
# Precision = 0.877 vs. 0.231
# Recall = 0.867 vs. 1.000
# Minibatch Loss= 0.411926
# Training: 3400
# AUC = 0.973 vs. 0.254
# F1 = 0.914 vs. 0.399
# Precision = 0.905 vs. 0.250
# Recall = 0.923 vs. 1.000
# Validation: 3400
# AUC = 0.963 vs. 0.232
# F1 = 0.894 vs. 0.376
# Precision = 0.894 vs. 0.231
# Recall = 0.895 vs. 1.000
# Minibatch Loss= 0.407024
# Training: 3500
# AUC = 0.983 vs. 0.220
# F1 = 0.927 vs. 0.366
# Precision = 0.918 vs. 0.225
# Recall = 0.935 vs. 0.988
# Validation: 3500
# AUC = 0.960 vs. 0.238
# F1 = 0.887 vs. 0.376
# Precision = 0.894 vs. 0.232
# Recall = 0.879 vs. 0.985
# Minibatch Loss= 0.337141
# Training: 3600
# AUC = 0.986 vs. 0.273
# F1 = 0.936 vs. 0.422
# Precision = 0.933 vs. 0.269
# Recall = 0.940 vs. 0.984
# Validation: 3600
# AUC = 0.961 vs. 0.236
# F1 = 0.893 vs. 0.376
# Precision = 0.902 vs. 0.232
# Recall = 0.883 vs. 0.993
# Minibatch Loss= 0.379460
# Training: 3700
# AUC = 0.975 vs. 0.260
# F1 = 0.909 vs. 0.392
# Precision = 0.912 vs. 0.244
# Recall = 0.905 vs. 0.997
# Validation: 3700
# AUC = 0.966 vs. 0.230
# F1 = 0.897 vs. 0.376
# Precision = 0.897 vs. 0.231
# Recall = 0.897 vs. 1.000
# Minibatch Loss= 0.382377
# Training: 3800
# AUC = 0.981 vs. 0.236
# F1 = 0.928 vs. 0.383
# Precision = 0.916 vs. 0.237
# Recall = 0.941 vs. 1.000
# Validation: 3800
# AUC = 0.969 vs. 0.232
# F1 = 0.902 vs. 0.376
# Precision = 0.920 vs. 0.232
# Recall = 0.884 vs. 0.995
# Minibatch Loss= 0.360966
# Training: 3900
# AUC = 0.987 vs. 0.231
# F1 = 0.939 vs. 0.359
# Precision = 0.944 vs. 0.220
# Recall = 0.935 vs. 0.982
# Validation: 3900
# AUC = 0.969 vs. 0.235
# F1 = 0.903 vs. 0.376
# Precision = 0.901 vs. 0.231
# Recall = 0.906 vs. 1.000
# Minibatch Loss= 0.336984
# Training: 4000
# AUC = 0.986 vs. 0.219
# F1 = 0.938 vs. 0.352
# Precision = 0.948 vs. 0.214
# Recall = 0.929 vs. 1.000
# Validation: 4000
# AUC = 0.968 vs. 0.232
# F1 = 0.903 vs. 0.376
# Precision = 0.899 vs. 0.231
# Recall = 0.908 vs. 1.000
# Minibatch Loss= 0.315732
# Training: 4100
# AUC = 0.989 vs. 0.222
# F1 = 0.947 vs. 0.370
# Precision = 0.927 vs. 0.228
# Recall = 0.967 vs. 0.985
# Validation: 4100
# AUC = 0.966 vs. 0.229
# F1 = 0.902 vs. 0.376
# Precision = 0.901 vs. 0.231
# Recall = 0.904 vs. 1.000
# Minibatch Loss= 0.336854
# Training: 4200
# AUC = 0.992 vs. 0.216
# F1 = 0.950 vs. 0.361
# Precision = 0.947 vs. 0.220
# Recall = 0.952 vs. 1.000
# Validation: 4200
# AUC = 0.964 vs. 0.236
# F1 = 0.900 vs. 0.376
# Precision = 0.888 vs. 0.231
# Recall = 0.913 vs. 1.000
# Minibatch Loss= 0.288160
# Training: 4300
# AUC = 0.991 vs. 0.213
# F1 = 0.951 vs. 0.337
# Precision = 0.955 vs. 0.202
# Recall = 0.946 vs. 0.998
# Validation: 4300
# AUC = 0.961 vs. 0.229
# F1 = 0.896 vs. 0.376
# Precision = 0.900 vs. 0.231
# Recall = 0.892 vs. 1.000
# Minibatch Loss= 0.298711
# Training: 4400
# AUC = 0.989 vs. 0.213
# F1 = 0.943 vs. 0.336
# Precision = 0.924 vs. 0.202
# Recall = 0.963 vs. 1.000
# Validation: 4400
# AUC = 0.965 vs. 0.234
# F1 = 0.900 vs. 0.376
# Precision = 0.916 vs. 0.231
# Recall = 0.884 vs. 0.999
# Minibatch Loss= 0.320624
# Training: 4500
# AUC = 0.992 vs. 0.208
# F1 = 0.955 vs. 0.362
# Precision = 0.967 vs. 0.221
# Recall = 0.943 vs. 1.000
# Validation: 4500
# AUC = 0.964 vs. 0.231
# F1 = 0.897 vs. 0.376
# Precision = 0.903 vs. 0.231
# Recall = 0.891 vs. 1.000
# Minibatch Loss= 0.305508
# Training: 4600
# AUC = 0.993 vs. 0.243
# F1 = 0.959 vs. 0.395
# Precision = 0.951 vs. 0.246
# Recall = 0.966 vs. 0.997
# Validation: 4600
# AUC = 0.965 vs. 0.231
# F1 = 0.900 vs. 0.376
# Precision = 0.912 vs. 0.231
# Recall = 0.889 vs. 1.000
# Minibatch Loss= 0.330916
# Training: 4700
# AUC = 0.995 vs. 0.246
# F1 = 0.968 vs. 0.395
# Precision = 0.961 vs. 0.246
# Recall = 0.975 vs. 1.000
# Validation: 4700
# AUC = 0.964 vs. 0.235
# F1 = 0.898 vs. 0.376
# Precision = 0.897 vs. 0.232
# Recall = 0.900 vs. 0.997
# Minibatch Loss= 0.310482
# Training: 4800
# AUC = 0.995 vs. 0.240
# F1 = 0.964 vs. 0.394
# Precision = 0.965 vs. 0.246
# Recall = 0.963 vs. 0.995
# Validation: 4800
# AUC = 0.964 vs. 0.233
# F1 = 0.899 vs. 0.376
# Precision = 0.907 vs. 0.231
# Recall = 0.890 vs. 0.998
# Minibatch Loss= 0.327377
# Training: 4900
# AUC = 0.991 vs. 0.196
# F1 = 0.951 vs. 0.322
# Precision = 0.942 vs. 0.192
# Recall = 0.959 vs. 1.000
# Validation: 4900
# AUC = 0.963 vs. 0.231
# F1 = 0.898 vs. 0.376
# Precision = 0.912 vs. 0.231
# Recall = 0.885 vs. 1.000
# Minibatch Loss= 0.272684
# Training: 5000
# AUC = 0.995 vs. 0.232
# F1 = 0.956 vs. 0.378
# Precision = 0.955 vs. 0.233
# Recall = 0.956 vs. 1.000
# Validation: 5000
# AUC = 0.962 vs. 0.231
# F1 = 0.896 vs. 0.376
# Precision = 0.906 vs. 0.231
# Recall = 0.886 vs. 1.000
# Minibatch Loss= 0.300497
# Training: 5100
# AUC = 0.994 vs. 0.240
# F1 = 0.962 vs. 0.386
# Precision = 0.953 vs. 0.240
# Recall = 0.970 vs. 0.982
# Validation: 5100
# AUC = 0.961 vs. 0.235
# F1 = 0.894 vs. 0.376
# Precision = 0.888 vs. 0.232
# Recall = 0.901 vs. 0.992
# Minibatch Loss= 0.307342
# Training: 5200
# AUC = 0.995 vs. 0.239
# F1 = 0.964 vs. 0.395
# Precision = 0.980 vs. 0.247
# Recall = 0.947 vs. 0.982
# Validation: 5200
# AUC = 0.962 vs. 0.234
# F1 = 0.895 vs. 0.376
# Precision = 0.911 vs. 0.231
# Recall = 0.879 vs. 0.999
# Minibatch Loss= 0.319539
# Training: 5300
# AUC = 0.995 vs. 0.220
# F1 = 0.965 vs. 0.369
# Precision = 0.944 vs. 0.226
# Recall = 0.986 vs. 1.000
# Validation: 5300
# AUC = 0.962 vs. 0.233
# F1 = 0.900 vs. 0.376
# Precision = 0.902 vs. 0.233
# Recall = 0.898 vs. 0.982
# Minibatch Loss= 0.316024
# Training: 5400
# AUC = 0.996 vs. 0.252
# F1 = 0.966 vs. 0.413
# Precision = 0.953 vs. 0.261
# Recall = 0.979 vs. 0.995
# Validation: 5400
# AUC = 0.964 vs. 0.231
# F1 = 0.897 vs. 0.376
# Precision = 0.917 vs. 0.232
# Recall = 0.878 vs. 0.997
# Minibatch Loss= 0.330123
# Training: 5500
# AUC = 0.995 vs. 0.224
# F1 = 0.962 vs. 0.373
# Precision = 0.962 vs. 0.232
# Recall = 0.962 vs. 0.957
# Validation: 5500
# AUC = 0.963 vs. 0.232
# F1 = 0.899 vs. 0.376
# Precision = 0.891 vs. 0.231
# Recall = 0.907 vs. 1.000
# Minibatch Loss= 0.305105
# Training: 5600
# AUC = 0.995 vs. 0.226
# F1 = 0.961 vs. 0.378
# Precision = 0.951 vs. 0.234
# Recall = 0.971 vs. 0.982
# Validation: 5600
# AUC = 0.961 vs. 0.229
# F1 = 0.894 vs. 0.376
# Precision = 0.890 vs. 0.231
# Recall = 0.898 vs. 1.000
# Minibatch Loss= 0.303783
# Training: 5700
# AUC = 0.997 vs. 0.253
# F1 = 0.970 vs. 0.395
# Precision = 0.967 vs. 0.246
# Recall = 0.973 vs. 1.000
# Validation: 5700
# AUC = 0.962 vs. 0.228
# F1 = 0.898 vs. 0.376
# Precision = 0.903 vs. 0.231
# Recall = 0.892 vs. 0.999
# Minibatch Loss= 0.308899
# Training: 5800
# AUC = 0.993 vs. 0.203
# F1 = 0.962 vs. 0.323
# Precision = 0.938 vs. 0.193
# Recall = 0.988 vs. 1.000
# Validation: 5800
# AUC = 0.963 vs. 0.235
# F1 = 0.899 vs. 0.376
# Precision = 0.894 vs. 0.231
# Recall = 0.904 vs. 1.000
# Minibatch Loss= 0.243668
# Training: 5900
# AUC = 0.880 vs. 0.236
# F1 = 0.794 vs. 0.396
# Precision = 0.879 vs. 0.248
# Recall = 0.723 vs. 0.984
# Validation: 5900
# AUC = 0.860 vs. 0.234
# F1 = 0.770 vs. 0.376
# Precision = 0.789 vs. 0.231
# Recall = 0.753 vs. 1.000
# Minibatch Loss= 0.707105
# Training: 6000
# AUC = 0.952 vs. 0.228
# F1 = 0.888 vs. 0.375
# Precision = 0.926 vs. 0.230
# Recall = 0.854 vs. 1.000
# Validation: 6000
# AUC = 0.950 vs. 0.232
# F1 = 0.873 vs. 0.376
# Precision = 0.879 vs. 0.231
# Recall = 0.868 vs. 1.000
# Minibatch Loss= 0.409570
# Training: 6100
# AUC = 0.943 vs. 0.248
# F1 = 0.865 vs. 0.411
# Precision = 0.894 vs. 0.258
# Recall = 0.838 vs. 1.000
# Validation: 6100
# AUC = 0.958 vs. 0.230
# F1 = 0.890 vs. 0.376
# Precision = 0.890 vs. 0.231
# Recall = 0.890 vs. 1.000
# Minibatch Loss= 0.519627
# Training: 6200
# AUC = 0.959 vs. 0.241
# F1 = 0.897 vs. 0.387
# Precision = 0.877 vs. 0.240
# Recall = 0.918 vs. 1.000
# Validation: 6200
# AUC = 0.957 vs. 0.229
# F1 = 0.888 vs. 0.376
# Precision = 0.886 vs. 0.231
# Recall = 0.890 vs. 1.000
# Minibatch Loss= 0.399585
# Training: 6300
# AUC = 0.973 vs. 0.238
# F1 = 0.911 vs. 0.387
# Precision = 0.917 vs. 0.240
# Recall = 0.905 vs. 1.000
# Validation: 6300
# AUC = 0.963 vs. 0.228
# F1 = 0.895 vs. 0.376
# Precision = 0.892 vs. 0.231
# Recall = 0.897 vs. 1.000
# Minibatch Loss= 0.394467
# Training: 6400
# AUC = 0.973 vs. 0.203
# F1 = 0.910 vs. 0.338
# Precision = 0.894 vs. 0.204
# Recall = 0.927 vs. 1.000
# Validation: 6400
# AUC = 0.966 vs. 0.232
# F1 = 0.899 vs. 0.376
# Precision = 0.892 vs. 0.231
# Recall = 0.906 vs. 1.000
# Minibatch Loss= 0.302569
# Training: 6500
# AUC = 0.977 vs. 0.237
# F1 = 0.920 vs. 0.389
# Precision = 0.910 vs. 0.243
# Recall = 0.930 vs. 0.985
# Validation: 6500
# AUC = 0.964 vs. 0.226
# F1 = 0.903 vs. 0.376
# Precision = 0.915 vs. 0.231
# Recall = 0.891 vs. 1.000
# Minibatch Loss= 0.394090
# Training: 6600
# AUC = 0.973 vs. 0.206
# F1 = 0.914 vs. 0.335
# Precision = 0.924 vs. 0.202
# Recall = 0.904 vs. 0.986
# Validation: 6600
# AUC = 0.956 vs. 0.234
# F1 = 0.888 vs. 0.376
# Precision = 0.907 vs. 0.232
# Recall = 0.869 vs. 0.999
# Minibatch Loss= 0.345593
# Training: 6700
# AUC = 0.967 vs. 0.224
# F1 = 0.903 vs. 0.377
# Precision = 0.881 vs. 0.233
# Recall = 0.926 vs. 0.985
# Validation: 6700
# AUC = 0.947 vs. 0.229
# F1 = 0.872 vs. 0.376
# Precision = 0.879 vs. 0.231
# Recall = 0.864 vs. 0.999
# Minibatch Loss= 0.350634
# Training: 6800
# AUC = 0.961 vs. 0.284
# F1 = 0.897 vs. 0.416
# Precision = 0.920 vs. 0.263
# Recall = 0.875 vs. 0.999
# Validation: 6800
# AUC = 0.964 vs. 0.233
# F1 = 0.901 vs. 0.376
# Precision = 0.898 vs. 0.231
# Recall = 0.905 vs. 1.000
# Minibatch Loss= 0.438379
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-76902324ec9b> in <module>()
#       2                 train_eval_step=100,
#       3                 validation_eval_step=100,
# ----> 4                 display_step=100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model_synthetic/HRNN_synthetic_1/HRNN_synthetic_1-6883'

# %%
#saver = tf.train.Saver()
#saver.restore(sess, checkpoint_path+'-1000')

# %%
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.960 vs. 0.232
# F1 = 0.893 vs. 0.376
# Precision = 0.902 vs. 0.231
# Recall = 0.884 vs. 1.000

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
probability_change = np.squeeze(probability_of_pos, axis = 2)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':out[:,:,-1]})
