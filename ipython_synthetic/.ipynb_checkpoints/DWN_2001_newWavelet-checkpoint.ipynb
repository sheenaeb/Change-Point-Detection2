# %%
# useing this variable for saving models and summaries
exp_name = "DWN2001_newWavelet"

# %% [markdown]
# # Neural wavelet network
# 6levels wavelet then 5 layers CNN [2, 2, 2, 2, 2]

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../src')

# %%
import models.New_wavelet as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
#index of changes for test dataset
gt_test_idx_changes = index_of_changes[900:1000]

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10


wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]    #stride of pooling in convolution
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
#wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
wavelet_kernel_size = 3
activation = tf.nn.relu
granularity = np.prod(pooling_stride)
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 3.18601822124

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../summary/' + exp_name 
checkpoint_path = '../model/' + exp_name + '/' + exp_name

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_kernel_size = wavelet_kernel_size,    
                                 activation = activation,
                                 trainable_wavelet = True,
                                 trainable_conv = True,
                                 trainable_last = True,
                                 variables_weights = None,)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.234 vs. 0.224
# F1 = 0.401 vs. 0.363
# Precision = 0.295 vs. 0.222
# Recall = 0.627 vs. 1.000
# Validation: 0
# AUC = 0.308 vs. 0.234
# F1 = 0.432 vs. 0.371
# Precision = 0.292 vs. 0.228
# Recall = 0.834 vs. 1.000
# Minibatch Loss= 1.028049
# Training: 100
# AUC = 0.627 vs. 0.244
# F1 = 0.627 vs. 0.387
# Precision = 0.683 vs. 0.242
# Recall = 0.579 vs. 0.962
# Validation: 100
# AUC = 0.691 vs. 0.218
# F1 = 0.656 vs. 0.372
# Precision = 0.601 vs. 0.228
# Recall = 0.722 vs. 0.998
# Minibatch Loss= 0.907921
# Training: 200
# AUC = 0.662 vs. 0.230
# F1 = 0.655 vs. 0.368
# Precision = 0.689 vs. 0.225
# Recall = 0.623 vs. 1.000
# Validation: 200
# AUC = 0.707 vs. 0.227
# F1 = 0.659 vs. 0.372
# Precision = 0.701 vs. 0.229
# Recall = 0.623 vs. 0.986
# Minibatch Loss= 0.833184
# Training: 300
# AUC = 0.743 vs. 0.237
# F1 = 0.726 vs. 0.387
# Precision = 0.716 vs. 0.240
# Recall = 0.737 vs. 0.998
# Validation: 300
# AUC = 0.737 vs. 0.222
# F1 = 0.706 vs. 0.371
# Precision = 0.783 vs. 0.228
# Recall = 0.643 vs. 0.997
# Minibatch Loss= 0.791215
# Training: 400
# AUC = 0.766 vs. 0.226
# F1 = 0.727 vs. 0.370
# Precision = 0.703 vs. 0.227
# Recall = 0.753 vs. 0.995
# Validation: 400
# AUC = 0.758 vs. 0.226
# F1 = 0.713 vs. 0.373
# Precision = 0.745 vs. 0.229
# Recall = 0.683 vs. 0.991
# Minibatch Loss= 0.735638
# Training: 500
# AUC = 0.727 vs. 0.210
# F1 = 0.673 vs. 0.343
# Precision = 0.767 vs. 0.207
# Recall = 0.600 vs. 1.000
# Validation: 500
# AUC = 0.763 vs. 0.221
# F1 = 0.716 vs. 0.374
# Precision = 0.723 vs. 0.232
# Recall = 0.710 vs. 0.954
# Minibatch Loss= 0.667888
# Training: 600
# AUC = 0.810 vs. 0.245
# F1 = 0.744 vs. 0.410
# Precision = 0.772 vs. 0.259
# Recall = 0.719 vs. 0.985
# Validation: 600
# AUC = 0.777 vs. 0.230
# F1 = 0.741 vs. 0.372
# Precision = 0.808 vs. 0.228
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.749511
# Training: 700
# AUC = 0.832 vs. 0.226
# F1 = 0.753 vs. 0.380
# Precision = 0.814 vs. 0.235
# Recall = 0.701 vs. 0.995
# Validation: 700
# AUC = 0.779 vs. 0.241
# F1 = 0.724 vs. 0.372
# Precision = 0.809 vs. 0.229
# Recall = 0.655 vs. 0.998
# Minibatch Loss= 0.629914
# Training: 800
# AUC = 0.818 vs. 0.232
# F1 = 0.729 vs. 0.353
# Precision = 0.729 vs. 0.214
# Recall = 0.728 vs. 1.000
# Validation: 800
# AUC = 0.800 vs. 0.235
# F1 = 0.767 vs. 0.371
# Precision = 0.750 vs. 0.228
# Recall = 0.784 vs. 1.000
# Minibatch Loss= 0.663385
# Training: 900
# AUC = 0.769 vs. 0.233
# F1 = 0.724 vs. 0.382
# Precision = 0.755 vs. 0.236
# Recall = 0.694 vs. 1.000
# Validation: 900
# AUC = 0.820 vs. 0.232
# F1 = 0.778 vs. 0.371
# Precision = 0.854 vs. 0.228
# Recall = 0.714 vs. 1.000
# Minibatch Loss= 0.783976
# Training: 1000
# AUC = 0.856 vs. 0.258
# F1 = 0.766 vs. 0.416
# Precision = 0.847 vs. 0.263
# Recall = 0.699 vs. 1.000
# Validation: 1000
# AUC = 0.826 vs. 0.240
# F1 = 0.751 vs. 0.372
# Precision = 0.802 vs. 0.230
# Recall = 0.707 vs. 0.962
# Minibatch Loss= 0.667907
# Training: 1100
# AUC = 0.816 vs. 0.218
# F1 = 0.741 vs. 0.359
# Precision = 0.765 vs. 0.219
# Recall = 0.719 vs. 1.000
# Validation: 1100
# AUC = 0.821 vs. 0.229
# F1 = 0.767 vs. 0.373
# Precision = 0.812 vs. 0.230
# Recall = 0.727 vs. 0.985
# Minibatch Loss= 0.635734
# Training: 1200
# AUC = 0.864 vs. 0.251
# F1 = 0.782 vs. 0.406
# Precision = 0.814 vs. 0.255
# Recall = 0.752 vs. 0.995
# Validation: 1200
# AUC = 0.820 vs. 0.229
# F1 = 0.772 vs. 0.372
# Precision = 0.879 vs. 0.229
# Recall = 0.688 vs. 0.995
# Minibatch Loss= 0.631165
# Training: 1300
# AUC = 0.877 vs. 0.240
# F1 = 0.782 vs. 0.382
# Precision = 0.709 vs. 0.238
# Recall = 0.874 vs. 0.970
# Validation: 1300
# AUC = 0.839 vs. 0.227
# F1 = 0.793 vs. 0.373
# Precision = 0.793 vs. 0.229
# Recall = 0.794 vs. 1.000
# Minibatch Loss= 0.560978
# Training: 1400
# AUC = 0.814 vs. 0.240
# F1 = 0.745 vs. 0.386
# Precision = 0.745 vs. 0.241
# Recall = 0.745 vs. 0.975
# Validation: 1400
# AUC = 0.849 vs. 0.234
# F1 = 0.769 vs. 0.371
# Precision = 0.802 vs. 0.228
# Recall = 0.738 vs. 1.000
# Minibatch Loss= 0.643191
# Training: 1500
# AUC = 0.862 vs. 0.294
# F1 = 0.796 vs. 0.438
# Precision = 0.801 vs. 0.281
# Recall = 0.790 vs. 0.993
# Validation: 1500
# AUC = 0.866 vs. 0.231
# F1 = 0.791 vs. 0.372
# Precision = 0.829 vs. 0.229
# Recall = 0.756 vs. 0.979
# Minibatch Loss= 0.623414
# Training: 1600
# AUC = 0.895 vs. 0.236
# F1 = 0.833 vs. 0.391
# Precision = 0.880 vs. 0.243
# Recall = 0.790 vs. 1.000
# Validation: 1600
# AUC = 0.815 vs. 0.226
# F1 = 0.806 vs. 0.373
# Precision = 0.824 vs. 0.229
# Recall = 0.789 vs. 0.998
# Minibatch Loss= 0.589725
# Training: 1700
# AUC = 0.882 vs. 0.251
# F1 = 0.826 vs. 0.376
# Precision = 0.797 vs. 0.232
# Recall = 0.856 vs. 0.998
# Validation: 1700
# AUC = 0.861 vs. 0.242
# F1 = 0.817 vs. 0.376
# Precision = 0.853 vs. 0.233
# Recall = 0.784 vs. 0.973
# Minibatch Loss= 0.529264
# Training: 1800
# AUC = 0.872 vs. 0.260
# F1 = 0.788 vs. 0.420
# Precision = 0.850 vs. 0.266
# Recall = 0.734 vs. 1.000
# Validation: 1800
# AUC = 0.837 vs. 0.232
# F1 = 0.804 vs. 0.373
# Precision = 0.861 vs. 0.229
# Recall = 0.755 vs. 0.991
# Minibatch Loss= 0.706555
# Training: 1900
# AUC = 0.921 vs. 0.276
# F1 = 0.823 vs. 0.420
# Precision = 0.891 vs. 0.270
# Recall = 0.765 vs. 0.952
# Validation: 1900
# AUC = 0.854 vs. 0.219
# F1 = 0.769 vs. 0.371
# Precision = 0.802 vs. 0.228
# Recall = 0.738 vs. 1.000
# Minibatch Loss= 0.554372
# Training: 2000
# AUC = 0.768 vs. 0.239
# F1 = 0.720 vs. 0.373
# Precision = 0.739 vs. 0.229
# Recall = 0.701 vs. 1.000
# Validation: 2000
# AUC = 0.870 vs. 0.230
# F1 = 0.795 vs. 0.372
# Precision = 0.813 vs. 0.229
# Recall = 0.777 vs. 1.000
# Minibatch Loss= 0.669833
# Training: 2100
# AUC = 0.906 vs. 0.215
# F1 = 0.834 vs. 0.373
# Precision = 0.776 vs. 0.229
# Recall = 0.901 vs. 0.997
# Validation: 2100
# AUC = 0.852 vs. 0.237
# F1 = 0.763 vs. 0.371
# Precision = 0.769 vs. 0.228
# Recall = 0.758 vs. 1.000
# Minibatch Loss= 0.519409
# Training: 2200
# AUC = 0.933 vs. 0.237
# F1 = 0.852 vs. 0.385
# Precision = 0.886 vs. 0.242
# Recall = 0.819 vs. 0.946
# Validation: 2200
# AUC = 0.860 vs. 0.225
# F1 = 0.767 vs. 0.373
# Precision = 0.713 vs. 0.232
# Recall = 0.830 vs. 0.943
# Minibatch Loss= 0.495514
# Training: 2300
# AUC = 0.866 vs. 0.215
# F1 = 0.802 vs. 0.340
# Precision = 0.777 vs. 0.205
# Recall = 0.829 vs. 0.992
# Validation: 2300
# AUC = 0.861 vs. 0.257
# F1 = 0.794 vs. 0.371
# Precision = 0.830 vs. 0.228
# Recall = 0.762 vs. 1.000
# Minibatch Loss= 0.552291
# Training: 2400
# AUC = 0.875 vs. 0.207
# F1 = 0.791 vs. 0.352
# Precision = 0.770 vs. 0.215
# Recall = 0.813 vs. 0.972
# Validation: 2400
# AUC = 0.878 vs. 0.230
# F1 = 0.795 vs. 0.373
# Precision = 0.786 vs. 0.232
# Recall = 0.804 vs. 0.947
# Minibatch Loss= 0.543221
# Training: 2500
# AUC = 0.921 vs. 0.215
# F1 = 0.858 vs. 0.366
# Precision = 0.842 vs. 0.225
# Recall = 0.875 vs. 0.984
# Validation: 2500
# AUC = 0.871 vs. 0.232
# F1 = 0.784 vs. 0.372
# Precision = 0.778 vs. 0.229
# Recall = 0.789 vs. 0.990
# Minibatch Loss= 0.500749
# Training: 2600
# AUC = 0.881 vs. 0.273
# F1 = 0.809 vs. 0.437
# Precision = 0.863 vs. 0.280
# Recall = 0.762 vs. 0.996
# Validation: 2600
# AUC = 0.858 vs. 0.225
# F1 = 0.776 vs. 0.373
# Precision = 0.787 vs. 0.231
# Recall = 0.765 vs. 0.969
# Minibatch Loss= 0.707649
# Training: 2700
# AUC = 0.894 vs. 0.250
# F1 = 0.844 vs. 0.372
# Precision = 0.837 vs. 0.235
# Recall = 0.851 vs. 0.895
# Validation: 2700
# AUC = 0.845 vs. 0.228
# F1 = 0.754 vs. 0.371
# Precision = 0.773 vs. 0.230
# Recall = 0.736 vs. 0.966
# Minibatch Loss= 0.592703
# Training: 2800
# AUC = 0.911 vs. 0.220
# F1 = 0.818 vs. 0.376
# Precision = 0.826 vs. 0.232
# Recall = 0.811 vs. 0.978
# Validation: 2800
# AUC = 0.855 vs. 0.240
# F1 = 0.770 vs. 0.372
# Precision = 0.732 vs. 0.228
# Recall = 0.811 vs. 0.998
# Minibatch Loss= 0.512873
# Training: 2900
# AUC = 0.884 vs. 0.217
# F1 = 0.803 vs. 0.375
# Precision = 0.803 vs. 0.231
# Recall = 0.803 vs. 0.998
# Validation: 2900
# AUC = 0.854 vs. 0.226
# F1 = 0.764 vs. 0.372
# Precision = 0.781 vs. 0.229
# Recall = 0.748 vs. 0.997
# Minibatch Loss= 0.547493
# Training: 3000
# AUC = 0.825 vs. 0.220
# F1 = 0.749 vs. 0.373
# Precision = 0.760 vs. 0.230
# Recall = 0.739 vs. 0.998
# Validation: 3000
# AUC = 0.831 vs. 0.219
# F1 = 0.755 vs. 0.371
# Precision = 0.727 vs. 0.228
# Recall = 0.786 vs. 1.000
# Minibatch Loss= 0.627577
# Training: 3100
# AUC = 0.757 vs. 0.232
# F1 = 0.746 vs. 0.365
# Precision = 0.811 vs. 0.223
# Recall = 0.690 vs. 1.000
# Validation: 3100
# AUC = 0.869 vs. 0.237
# F1 = 0.791 vs. 0.371
# Precision = 0.882 vs. 0.228
# Recall = 0.717 vs. 1.000
# Minibatch Loss= 0.738347
# Training: 3200
# AUC = 0.809 vs. 0.223
# F1 = 0.715 vs. 0.355
# Precision = 0.693 vs. 0.216
# Recall = 0.738 vs. 0.987
# Validation: 3200
# AUC = 0.834 vs. 0.228
# F1 = 0.760 vs. 0.372
# Precision = 0.834 vs. 0.229
# Recall = 0.698 vs. 0.991
# Minibatch Loss= 0.594547
# Training: 3300
# AUC = 0.869 vs. 0.185
# F1 = 0.837 vs. 0.316
# Precision = 0.834 vs. 0.187
# Recall = 0.839 vs. 1.000
# Validation: 3300
# AUC = 0.864 vs. 0.223
# F1 = 0.767 vs. 0.372
# Precision = 0.785 vs. 0.229
# Recall = 0.750 vs. 0.995
# Minibatch Loss= 0.493313
# Training: 3400
# AUC = 0.940 vs. 0.221
# F1 = 0.872 vs. 0.363
# Precision = 0.911 vs. 0.222
# Recall = 0.837 vs. 0.993
# Validation: 3400
# AUC = 0.856 vs. 0.231
# F1 = 0.777 vs. 0.374
# Precision = 0.897 vs. 0.231
# Recall = 0.686 vs. 0.981
# Minibatch Loss= 0.413662
# Training: 3500
# AUC = 0.892 vs. 0.219
# F1 = 0.837 vs. 0.358
# Precision = 0.834 vs. 0.218
# Recall = 0.840 vs. 0.995
# Validation: 3500
# AUC = 0.848 vs. 0.234
# F1 = 0.753 vs. 0.371
# Precision = 0.728 vs. 0.228
# Recall = 0.780 vs. 1.000
# Minibatch Loss= 0.523270
# Training: 3600
# AUC = 0.906 vs. 0.280
# F1 = 0.831 vs. 0.431
# Precision = 0.827 vs. 0.275
# Recall = 0.835 vs. 0.990
# Validation: 3600
# AUC = 0.829 vs. 0.229
# F1 = 0.751 vs. 0.371
# Precision = 0.831 vs. 0.228
# Recall = 0.684 vs. 1.000
# Minibatch Loss= 0.586374
# Training: 3700
# AUC = 0.948 vs. 0.238
# F1 = 0.887 vs. 0.368
# Precision = 0.853 vs. 0.228
# Recall = 0.925 vs. 0.958
# Validation: 3700
# AUC = 0.838 vs. 0.225
# F1 = 0.736 vs. 0.373
# Precision = 0.690 vs. 0.233
# Recall = 0.787 vs. 0.930
# Minibatch Loss= 0.404020
# Training: 3800
# AUC = 0.877 vs. 0.197
# F1 = 0.825 vs. 0.319
# Precision = 0.807 vs. 0.190
# Recall = 0.844 vs. 1.000
# Validation: 3800
# AUC = 0.838 vs. 0.234
# F1 = 0.742 vs. 0.371
# Precision = 0.739 vs. 0.228
# Recall = 0.744 vs. 1.000
# Minibatch Loss= 0.482208
# Training: 3900
# AUC = 0.877 vs. 0.269
# F1 = 0.782 vs. 0.407
# Precision = 0.703 vs. 0.255
# Recall = 0.881 vs. 0.998
# Validation: 3900
# AUC = 0.855 vs. 0.234
# F1 = 0.784 vs. 0.373
# Precision = 0.859 vs. 0.231
# Recall = 0.720 vs. 0.971
# Minibatch Loss= 0.613490
# Training: 4000
# AUC = 0.863 vs. 0.227
# F1 = 0.773 vs. 0.364
# Precision = 0.809 vs. 0.222
# Recall = 0.739 vs. 0.996
# Validation: 4000
# AUC = 0.861 vs. 0.230
# F1 = 0.790 vs. 0.375
# Precision = 0.806 vs. 0.231
# Recall = 0.775 vs. 0.995
# Minibatch Loss= 0.577135
# Training: 4100
# AUC = 0.886 vs. 0.235
# F1 = 0.824 vs. 0.380
# Precision = 0.893 vs. 0.234
# Recall = 0.765 vs. 1.000
# Validation: 4100
# AUC = 0.832 vs. 0.239
# F1 = 0.732 vs. 0.373
# Precision = 0.852 vs. 0.229
# Recall = 0.642 vs. 0.997
# Minibatch Loss= 0.609333
# Training: 4200
# AUC = 0.896 vs. 0.258
# F1 = 0.799 vs. 0.401
# Precision = 0.834 vs. 0.251
# Recall = 0.767 vs. 1.000
# Validation: 4200
# AUC = 0.869 vs. 0.224
# F1 = 0.771 vs. 0.372
# Precision = 0.698 vs. 0.229
# Recall = 0.863 vs. 0.988
# Minibatch Loss= 0.574136
# Training: 4300
# AUC = 0.859 vs. 0.255
# F1 = 0.777 vs. 0.391
# Precision = 0.817 vs. 0.244
# Recall = 0.741 vs. 0.997
# Validation: 4300
# AUC = 0.849 vs. 0.231
# F1 = 0.742 vs. 0.373
# Precision = 0.787 vs. 0.230
# Recall = 0.702 vs. 0.976
# Minibatch Loss= 0.606287
# Training: 4400
# AUC = 0.880 vs. 0.248
# F1 = 0.809 vs. 0.397
# Precision = 0.802 vs. 0.248
# Recall = 0.815 vs. 0.998
# Validation: 4400
# AUC = 0.863 vs. 0.230
# F1 = 0.787 vs. 0.372
# Precision = 0.886 vs. 0.229
# Recall = 0.708 vs. 0.995
# Minibatch Loss= 0.598842
# Training: 4500
# AUC = 0.851 vs. 0.253
# F1 = 0.773 vs. 0.392
# Precision = 0.802 vs. 0.245
# Recall = 0.746 vs. 0.984
# Validation: 4500
# AUC = 0.868 vs. 0.232
# F1 = 0.778 vs. 0.372
# Precision = 0.757 vs. 0.229
# Recall = 0.801 vs. 0.983
# Minibatch Loss= 0.658089
# Training: 4600
# AUC = 0.907 vs. 0.232
# F1 = 0.815 vs. 0.387
# Precision = 0.824 vs. 0.240
# Recall = 0.806 vs. 1.000
# Validation: 4600
# AUC = 0.828 vs. 0.244
# F1 = 0.760 vs. 0.371
# Precision = 0.842 vs. 0.228
# Recall = 0.693 vs. 1.000
# Minibatch Loss= 0.484094
# Training: 4700
# AUC = 0.912 vs. 0.267
# F1 = 0.860 vs. 0.398
# Precision = 0.832 vs. 0.249
# Recall = 0.890 vs. 1.000
# Validation: 4700
# AUC = 0.850 vs. 0.212
# F1 = 0.768 vs. 0.372
# Precision = 0.828 vs. 0.228
# Recall = 0.717 vs. 1.000
# Minibatch Loss= 0.549380
# Training: 4800
# AUC = 0.884 vs. 0.243
# F1 = 0.809 vs. 0.382
# Precision = 0.788 vs. 0.238
# Recall = 0.831 vs. 0.966
# Validation: 4800
# AUC = 0.860 vs. 0.228
# F1 = 0.801 vs. 0.372
# Precision = 0.869 vs. 0.229
# Recall = 0.743 vs. 0.986
# Minibatch Loss= 0.530982
# Training: 4900
# AUC = 0.907 vs. 0.263
# F1 = 0.815 vs. 0.393
# Precision = 0.854 vs. 0.245
# Recall = 0.778 vs. 0.984
# Validation: 4900
# AUC = 0.858 vs. 0.223
# F1 = 0.776 vs. 0.372
# Precision = 0.840 vs. 0.229
# Recall = 0.720 vs. 0.998
# Minibatch Loss= 0.520105
# Training: 5000
# AUC = 0.910 vs. 0.229
# F1 = 0.808 vs. 0.394
# Precision = 0.805 vs. 0.247
# Recall = 0.810 vs. 0.966
# Validation: 5000
# AUC = 0.852 vs. 0.214
# F1 = 0.759 vs. 0.371
# Precision = 0.837 vs. 0.228
# Recall = 0.695 vs. 1.000
# Minibatch Loss= 0.506982
# Training: 5100
# AUC = 0.927 vs. 0.206
# F1 = 0.833 vs. 0.347
# Precision = 0.778 vs. 0.210
# Recall = 0.897 vs. 0.996
# Validation: 5100
# AUC = 0.853 vs. 0.240
# F1 = 0.774 vs. 0.372
# Precision = 0.812 vs. 0.232
# Recall = 0.739 vs. 0.947
# Minibatch Loss= 0.469511
# Training: 5200
# AUC = 0.893 vs. 0.231
# F1 = 0.823 vs. 0.366
# Precision = 0.830 vs. 0.224
# Recall = 0.817 vs. 0.997
# Validation: 5200
# AUC = 0.860 vs. 0.235
# F1 = 0.788 vs. 0.373
# Precision = 0.780 vs. 0.234
# Recall = 0.796 vs. 0.911
# Minibatch Loss= 0.544000
# Training: 5300
# AUC = 0.922 vs. 0.222
# F1 = 0.850 vs. 0.367
# Precision = 0.888 vs. 0.225
# Recall = 0.815 vs. 0.991
# Validation: 5300
# AUC = 0.853 vs. 0.240
# F1 = 0.767 vs. 0.373
# Precision = 0.823 vs. 0.230
# Recall = 0.719 vs. 0.988
# Minibatch Loss= 0.479068
# Training: 5400
# AUC = 0.921 vs. 0.216
# F1 = 0.856 vs. 0.352
# Precision = 0.815 vs. 0.218
# Recall = 0.902 vs. 0.924
# Validation: 5400
# AUC = 0.850 vs. 0.244
# F1 = 0.757 vs. 0.373
# Precision = 0.829 vs. 0.229
# Recall = 0.696 vs. 0.997
# Minibatch Loss= 0.434309
# Training: 5500
# AUC = 0.906 vs. 0.203
# F1 = 0.826 vs. 0.358
# Precision = 0.857 vs. 0.218
# Recall = 0.797 vs. 1.000
# Validation: 5500
# AUC = 0.867 vs. 0.233
# F1 = 0.765 vs. 0.372
# Precision = 0.754 vs. 0.229
# Recall = 0.777 vs. 0.995
# Minibatch Loss= 0.519404
# Training: 5600
# AUC = 0.897 vs. 0.248
# F1 = 0.832 vs. 0.387
# Precision = 0.837 vs. 0.241
# Recall = 0.827 vs. 0.987
# Validation: 5600
# AUC = 0.848 vs. 0.248
# F1 = 0.779 vs. 0.373
# Precision = 0.840 vs. 0.232
# Recall = 0.727 vs. 0.964
# Minibatch Loss= 0.536912
# Training: 5700
# AUC = 0.912 vs. 0.228
# F1 = 0.844 vs. 0.360
# Precision = 0.862 vs. 0.220
# Recall = 0.827 vs. 0.991
# Validation: 5700
# AUC = 0.848 vs. 0.230
# F1 = 0.760 vs. 0.371
# Precision = 0.828 vs. 0.228
# Recall = 0.702 vs. 1.000
# Minibatch Loss= 0.481491
# Training: 5800
# AUC = 0.926 vs. 0.230
# F1 = 0.856 vs. 0.369
# Precision = 0.858 vs. 0.227
# Recall = 0.855 vs. 0.993
# Validation: 5800
# AUC = 0.860 vs. 0.227
# F1 = 0.778 vs. 0.372
# Precision = 0.857 vs. 0.232
# Recall = 0.712 vs. 0.945
# Minibatch Loss= 0.445739
# Training: 5900
# AUC = 0.945 vs. 0.267
# F1 = 0.872 vs. 0.420
# Precision = 0.880 vs. 0.266
# Recall = 0.864 vs. 0.994
# Validation: 5900
# AUC = 0.830 vs. 0.247
# F1 = 0.767 vs. 0.376
# Precision = 0.802 vs. 0.231
# Recall = 0.736 vs. 0.995
# Minibatch Loss= 0.497940
# Training: 6000
# AUC = 0.879 vs. 0.224
# F1 = 0.784 vs. 0.364
# Precision = 0.725 vs. 0.222
# Recall = 0.854 vs. 0.996
# Validation: 6000
# AUC = 0.867 vs. 0.227
# F1 = 0.798 vs. 0.371
# Precision = 0.897 vs. 0.228
# Recall = 0.719 vs. 1.000
# Minibatch Loss= 0.504747
# Training: 6100
# AUC = 0.934 vs. 0.241
# F1 = 0.873 vs. 0.394
# Precision = 0.885 vs. 0.245
# Recall = 0.861 vs. 0.998
# Validation: 6100
# AUC = 0.843 vs. 0.221
# F1 = 0.778 vs. 0.371
# Precision = 0.822 vs. 0.228
# Recall = 0.738 vs. 1.000
# Minibatch Loss= 0.463531
# Training: 6200
# AUC = 0.949 vs. 0.206
# F1 = 0.884 vs. 0.340
# Precision = 0.846 vs. 0.205
# Recall = 0.925 vs. 0.989
# Validation: 6200
# AUC = 0.852 vs. 0.216
# F1 = 0.773 vs. 0.371
# Precision = 0.828 vs. 0.228
# Recall = 0.726 vs. 1.000
# Minibatch Loss= 0.364863
# Training: 6300
# AUC = 0.901 vs. 0.224
# F1 = 0.848 vs. 0.352
# Precision = 0.826 vs. 0.214
# Recall = 0.872 vs. 0.987
# Validation: 6300
# AUC = 0.841 vs. 0.221
# F1 = 0.770 vs. 0.372
# Precision = 0.831 vs. 0.228
# Recall = 0.717 vs. 1.000
# Minibatch Loss= 0.482098
# Training: 6400
# AUC = 0.942 vs. 0.169
# F1 = 0.876 vs. 0.303
# Precision = 0.880 vs. 0.181
# Recall = 0.873 vs. 0.941
# Validation: 6400
# AUC = 0.829 vs. 0.222
# F1 = 0.779 vs. 0.372
# Precision = 0.871 vs. 0.229
# Recall = 0.705 vs. 0.983
# Minibatch Loss= 0.345012
# Training: 6500
# AUC = 0.899 vs. 0.207
# F1 = 0.832 vs. 0.354
# Precision = 0.768 vs. 0.215
# Recall = 0.907 vs. 1.000
# Validation: 6500
# AUC = 0.841 vs. 0.223
# F1 = 0.781 vs. 0.373
# Precision = 0.878 vs. 0.230
# Recall = 0.703 vs. 0.993
# Minibatch Loss= 0.454837
# Training: 6600
# AUC = 0.938 vs. 0.225
# F1 = 0.862 vs. 0.374
# Precision = 0.856 vs. 0.230
# Recall = 0.869 vs. 0.998
# Validation: 6600
# AUC = 0.839 vs. 0.243
# F1 = 0.790 vs. 0.373
# Precision = 0.856 vs. 0.230
# Recall = 0.734 vs. 0.976
# Minibatch Loss= 0.461917
# Training: 6700
# AUC = 0.928 vs. 0.211
# F1 = 0.841 vs. 0.353
# Precision = 0.782 vs. 0.214
# Recall = 0.909 vs. 1.000
# Validation: 6700
# AUC = 0.827 vs. 0.237
# F1 = 0.776 vs. 0.376
# Precision = 0.783 vs. 0.234
# Recall = 0.768 vs. 0.949
# Minibatch Loss= 0.410651
# Training: 6800
# AUC = 0.935 vs. 0.234
# F1 = 0.846 vs. 0.375
# Precision = 0.894 vs. 0.231
# Recall = 0.802 vs. 1.000
# Validation: 6800
# AUC = 0.839 vs. 0.232
# F1 = 0.782 vs. 0.371
# Precision = 0.810 vs. 0.228
# Recall = 0.755 vs. 1.000
# Minibatch Loss= 0.474912
# Training: 6900
# AUC = 0.879 vs. 0.194
# F1 = 0.797 vs. 0.327
# Precision = 0.779 vs. 0.198
# Recall = 0.815 vs. 0.940
# Validation: 6900
# AUC = 0.843 vs. 0.232
# F1 = 0.786 vs. 0.373
# Precision = 0.800 vs. 0.229
# Recall = 0.774 vs. 0.998
# Minibatch Loss= 0.508463
# Training: 7000
# AUC = 0.957 vs. 0.279
# F1 = 0.894 vs. 0.443
# Precision = 0.896 vs. 0.286
# Recall = 0.891 vs. 0.989
# Validation: 7000
# AUC = 0.828 vs. 0.228
# F1 = 0.757 vs. 0.372
# Precision = 0.796 vs. 0.229
# Recall = 0.722 vs. 0.997
# Minibatch Loss= 0.473967
# Training: 7100
# AUC = 0.948 vs. 0.252
# F1 = 0.876 vs. 0.398
# Precision = 0.839 vs. 0.248
# Recall = 0.917 vs. 1.000
# Validation: 7100
# AUC = 0.832 vs. 0.223
# F1 = 0.785 vs. 0.371
# Precision = 0.858 vs. 0.228
# Recall = 0.724 vs. 1.000
# Minibatch Loss= 0.435454
# Training: 7200
# AUC = 0.900 vs. 0.222
# F1 = 0.822 vs. 0.363
# Precision = 0.864 vs. 0.222
# Recall = 0.784 vs. 0.995
# Validation: 7200
# AUC = 0.832 vs. 0.208
# F1 = 0.794 vs. 0.371
# Precision = 0.869 vs. 0.229
# Recall = 0.731 vs. 0.986
# Minibatch Loss= 0.466862
# Training: 7300
# AUC = 0.932 vs. 0.246
# F1 = 0.877 vs. 0.380
# Precision = 0.877 vs. 0.235
# Recall = 0.877 vs. 1.000
# Validation: 7300
# AUC = 0.832 vs. 0.230
# F1 = 0.781 vs. 0.373
# Precision = 0.805 vs. 0.232
# Recall = 0.758 vs. 0.950
# Minibatch Loss= 0.435042
# Training: 7400
# AUC = 0.957 vs. 0.247
# F1 = 0.893 vs. 0.392
# Precision = 0.932 vs. 0.246
# Recall = 0.858 vs. 0.952
# Validation: 7400
# AUC = 0.842 vs. 0.239
# F1 = 0.789 vs. 0.377
# Precision = 0.899 vs. 0.241
# Recall = 0.703 vs. 0.873
# Minibatch Loss= 0.390444
# Training: 7500
# AUC = 0.869 vs. 0.224
# F1 = 0.802 vs. 0.368
# Precision = 0.761 vs. 0.226
# Recall = 0.846 vs. 0.981
# Validation: 7500
# AUC = 0.840 vs. 0.226
# F1 = 0.794 vs. 0.371
# Precision = 0.861 vs. 0.228
# Recall = 0.736 vs. 0.998
# Minibatch Loss= 0.498492
# Training: 7600
# AUC = 0.937 vs. 0.202
# F1 = 0.883 vs. 0.355
# Precision = 0.879 vs. 0.216
# Recall = 0.886 vs. 1.000
# Validation: 7600
# AUC = 0.827 vs. 0.228
# F1 = 0.785 vs. 0.372
# Precision = 0.804 vs. 0.229
# Recall = 0.767 vs. 0.995
# Minibatch Loss= 0.412487
# Training: 7700
# AUC = 0.955 vs. 0.233
# F1 = 0.900 vs. 0.385
# Precision = 0.895 vs. 0.238
# Recall = 0.906 vs. 1.000
# Validation: 7700
# AUC = 0.830 vs. 0.235
# F1 = 0.770 vs. 0.371
# Precision = 0.838 vs. 0.228
# Recall = 0.712 vs. 1.000
# Minibatch Loss= 0.403778
# Training: 7800
# AUC = 0.958 vs. 0.227
# F1 = 0.888 vs. 0.355
# Precision = 0.903 vs. 0.216
# Recall = 0.873 vs. 1.000
# Validation: 7800
# AUC = 0.839 vs. 0.237
# F1 = 0.792 vs. 0.373
# Precision = 0.843 vs. 0.230
# Recall = 0.746 vs. 0.985
# Minibatch Loss= 0.397934
# Training: 7900
# AUC = 0.904 vs. 0.176
# F1 = 0.824 vs. 0.303
# Precision = 0.857 vs. 0.178
# Recall = 0.793 vs. 0.998
# Validation: 7900
# AUC = 0.830 vs. 0.242
# F1 = 0.786 vs. 0.372
# Precision = 0.818 vs. 0.228
# Recall = 0.756 vs. 0.998
# Minibatch Loss= 0.402688
# Training: 8000
# AUC = 0.936 vs. 0.232
# F1 = 0.855 vs. 0.387
# Precision = 0.840 vs. 0.240
# Recall = 0.871 vs. 1.000
# Validation: 8000
# AUC = 0.823 vs. 0.219
# F1 = 0.797 vs. 0.374
# Precision = 0.840 vs. 0.230
# Recall = 0.758 vs. 0.991
# Minibatch Loss= 0.443879
# Training: 8100
# AUC = 0.901 vs. 0.232
# F1 = 0.824 vs. 0.371
# Precision = 0.769 vs. 0.229
# Recall = 0.887 vs. 0.981
# Validation: 8100
# AUC = 0.832 vs. 0.226
# F1 = 0.791 vs. 0.371
# Precision = 0.813 vs. 0.228
# Recall = 0.770 vs. 1.000
# Minibatch Loss= 0.461317
# Training: 8200
# AUC = 0.941 vs. 0.229
# F1 = 0.874 vs. 0.365
# Precision = 0.852 vs. 0.224
# Recall = 0.898 vs. 0.982
# Validation: 8200
# AUC = 0.830 vs. 0.242
# F1 = 0.800 vs. 0.374
# Precision = 0.872 vs. 0.232
# Recall = 0.739 vs. 0.966
# Minibatch Loss= 0.436118
# Training: 8300
# AUC = 0.940 vs. 0.253
# F1 = 0.860 vs. 0.383
# Precision = 0.862 vs. 0.237
# Recall = 0.859 vs. 0.995
# Validation: 8300
# AUC = 0.829 vs. 0.229
# F1 = 0.793 vs. 0.372
# Precision = 0.846 vs. 0.228
# Recall = 0.746 vs. 0.997
# Minibatch Loss= 0.433066
# Training: 8400
# AUC = 0.928 vs. 0.223
# F1 = 0.841 vs. 0.362
# Precision = 0.857 vs. 0.221
# Recall = 0.827 vs. 1.000
# Validation: 8400
# AUC = 0.824 vs. 0.236
# F1 = 0.796 vs. 0.376
# Precision = 0.850 vs. 0.233
# Recall = 0.748 vs. 0.971
# Minibatch Loss= 0.418087
# Training: 8500
# AUC = 0.934 vs. 0.208
# F1 = 0.861 vs. 0.354
# Precision = 0.868 vs. 0.215
# Recall = 0.854 vs. 0.998
# Validation: 8500
# AUC = 0.842 vs. 0.233
# F1 = 0.793 vs. 0.371
# Precision = 0.855 vs. 0.228
# Recall = 0.739 vs. 1.000
# Minibatch Loss= 0.445705
# Training: 8600
# AUC = 0.961 vs. 0.247
# F1 = 0.899 vs. 0.385
# Precision = 0.889 vs. 0.240
# Recall = 0.908 vs. 0.977
# Validation: 8600
# AUC = 0.833 vs. 0.221
# F1 = 0.782 vs. 0.371
# Precision = 0.825 vs. 0.228
# Recall = 0.743 vs. 1.000
# Minibatch Loss= 0.431913
# Training: 8700
# AUC = 0.957 vs. 0.213
# F1 = 0.901 vs. 0.356
# Precision = 0.903 vs. 0.217
# Recall = 0.899 vs. 0.996
# Validation: 8700
# AUC = 0.840 vs. 0.232
# F1 = 0.799 vs. 0.371
# Precision = 0.854 vs. 0.228
# Recall = 0.751 vs. 1.000
# Minibatch Loss= 0.359131
# Training: 8800
# AUC = 0.892 vs. 0.233
# F1 = 0.816 vs. 0.395
# Precision = 0.855 vs. 0.246
# Recall = 0.780 vs. 0.998
# Validation: 8800
# AUC = 0.846 vs. 0.241
# F1 = 0.782 vs. 0.378
# Precision = 0.801 vs. 0.239
# Recall = 0.765 vs. 0.906
# Minibatch Loss= 0.530238
# Training: 8900
# AUC = 0.948 vs. 0.227
# F1 = 0.882 vs. 0.375
# Precision = 0.892 vs. 0.230
# Recall = 0.871 vs. 1.000
# Validation: 8900
# AUC = 0.828 vs. 0.217
# F1 = 0.784 vs. 0.373
# Precision = 0.838 vs. 0.229
# Recall = 0.736 vs. 1.000
# Minibatch Loss= 0.409061
# Training: 9000
# AUC = 0.931 vs. 0.207
# F1 = 0.863 vs. 0.344
# Precision = 0.861 vs. 0.208
# Recall = 0.864 vs. 0.994
# Validation: 9000
# AUC = 0.825 vs. 0.242
# F1 = 0.780 vs. 0.372
# Precision = 0.816 vs. 0.230
# Recall = 0.746 vs. 0.974
# Minibatch Loss= 0.396834
# Training: 9100
# AUC = 0.922 vs. 0.216
# F1 = 0.853 vs. 0.353
# Precision = 0.855 vs. 0.215
# Recall = 0.851 vs. 1.000
# Validation: 9100
# AUC = 0.819 vs. 0.242
# F1 = 0.781 vs. 0.373
# Precision = 0.852 vs. 0.230
# Recall = 0.720 vs. 0.995
# Minibatch Loss= 0.430572
# Training: 9200
# AUC = 0.955 vs. 0.210
# F1 = 0.885 vs. 0.343
# Precision = 0.859 vs. 0.207
# Recall = 0.913 vs. 0.996
# Validation: 9200
# AUC = 0.822 vs. 0.220
# F1 = 0.762 vs. 0.371
# Precision = 0.769 vs. 0.228
# Recall = 0.755 vs. 1.000
# Minibatch Loss= 0.349143
# Training: 9300
# AUC = 0.955 vs. 0.245
# F1 = 0.878 vs. 0.412
# Precision = 0.887 vs. 0.259
# Recall = 0.869 vs. 0.998
# Validation: 9300
# AUC = 0.819 vs. 0.216
# F1 = 0.758 vs. 0.372
# Precision = 0.811 vs. 0.229
# Recall = 0.712 vs. 0.998
# Minibatch Loss= 0.435154
# Training: 9400
# AUC = 0.942 vs. 0.217
# F1 = 0.873 vs. 0.358
# Precision = 0.850 vs. 0.218
# Recall = 0.897 vs. 0.995
# Validation: 9400
# AUC = 0.830 vs. 0.219
# F1 = 0.782 vs. 0.371
# Precision = 0.788 vs. 0.228
# Recall = 0.777 vs. 1.000
# Minibatch Loss= 0.407288
# Training: 9500
# AUC = 0.951 vs. 0.234
# F1 = 0.865 vs. 0.362
# Precision = 0.839 vs. 0.223
# Recall = 0.892 vs. 0.953
# Validation: 9500
# AUC = 0.819 vs. 0.227
# F1 = 0.767 vs. 0.373
# Precision = 0.807 vs. 0.229
# Recall = 0.731 vs. 0.991
# Minibatch Loss= 0.376582
# Training: 9600
# AUC = 0.938 vs. 0.265
# F1 = 0.848 vs. 0.408
# Precision = 0.798 vs. 0.256
# Recall = 0.905 vs. 1.000
# Validation: 9600
# AUC = 0.822 vs. 0.231
# F1 = 0.766 vs. 0.372
# Precision = 0.768 vs. 0.232
# Recall = 0.765 vs. 0.928
# Minibatch Loss= 0.466856
# Training: 9700
# AUC = 0.944 vs. 0.234
# F1 = 0.883 vs. 0.380
# Precision = 0.873 vs. 0.235
# Recall = 0.893 vs. 0.997
# Validation: 9700
# AUC = 0.842 vs. 0.239
# F1 = 0.773 vs. 0.375
# Precision = 0.822 vs. 0.242
# Recall = 0.729 vs. 0.832
# Minibatch Loss= 0.442100
# Training: 9800
# AUC = 0.949 vs. 0.243
# F1 = 0.890 vs. 0.401
# Precision = 0.867 vs. 0.252
# Recall = 0.913 vs. 0.984
# Validation: 9800
# AUC = 0.831 vs. 0.239
# F1 = 0.784 vs. 0.372
# Precision = 0.861 vs. 0.228
# Recall = 0.720 vs. 1.000
# Minibatch Loss= 0.435380
# Training: 9900
# AUC = 0.958 vs. 0.235
# F1 = 0.893 vs. 0.358
# Precision = 0.865 vs. 0.219
# Recall = 0.923 vs. 0.989
# Validation: 9900
# AUC = 0.826 vs. 0.228
# F1 = 0.777 vs. 0.372
# Precision = 0.823 vs. 0.231
# Recall = 0.736 vs. 0.966
# Minibatch Loss= 0.359766
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../model/DWN2001_newWavelet/DWN2001_newWavelet-10000'

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.839 vs. 0.232
# F1 = 0.767 vs. 0.376
# Precision = 0.774 vs. 0.231
# Recall = 0.760 vs. 0.999

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (100, 256)

# %%
savemat('../poc/poc'+exp_name+'.mat', {'poc':out})
