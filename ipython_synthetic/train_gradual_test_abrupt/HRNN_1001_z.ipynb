# %%
# useing this variable for saving models and summaries
exp_name = "HRNN_1001_z"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,64,64, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../src')

# %%
from models.HRNN_model import Model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed4.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape
# Out:
# (900, 8192, 12)

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

wavelet_levels= 6
convolution_levels = 5
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]

bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions

lstm_n_hidden = 128
n_classes = 1

##positive weight for weighted cross entropy
s = train_gt.shape
resolution = np.prod(pooling_stride)

pooled_gt = np.reshape(train_gt[:,:(s[0]*s[1]/resolution)*resolution,:], (s[0]*(s[1]/resolution), resolution, s[2])).max(axis=1)
pos_weight = (1.0 - pooled_gt.mean(axis = 0)) / pooled_gt.mean(axis=0)

variables_weights = np.ones((n_classes,))

# %%
pos_weight
# Out:
# array([ 2.46045165])

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_gradual_test_abrupt/' + exp_name 
checkpoint_path = '../../model_synthetic/train_gradual_test_abrupt/' + exp_name + '/' + exp_name

# %%
model = Model(n_variables = n_variables,
                            learning_rate = learning_rate,
                            n_classes = n_classes)

# %%
model.build_model(pos_weight = pos_weight, 
                 learning_rate = learning_rate,
                 wavelet_levels = wavelet_levels,    
                 convolution_levels = convolution_levels,    
                 pooling_stride = pooling_stride,     
                 weights_shape = weights_shape,
                 bias_shape = bias_shape,
                 wavelet_weights_shape = wavelet_weights_shape,    
                 activation = activation,
                 lstm_n_hidden = lstm_n_hidden,
                 trainable_wavelet = True,
                 trainable_conv = True,
                 trainable_last = True,
                 variables_weights = variables_weights,
                 optimizer = tf.train.AdamOptimizer
)
# Out:
# 6
# Tensor("Squeeze_29:0", shape=(?, ?, 64), dtype=float32)
# Tensor("Squeeze_29:0", shape=(?, ?, 64), dtype=float32) Tensor("zeros:0", shape=(?, ?, 128), dtype=float32) 5
# Tensor("Squeeze_24:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape:0", shape=(?, ?, ?), dtype=float32) 4
# Tensor("Squeeze_19:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_1:0", shape=(?, ?, ?), dtype=float32) 3
# Tensor("Squeeze_14:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_2:0", shape=(?, ?, ?), dtype=float32) 2
# Tensor("Squeeze_9:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_3:0", shape=(?, ?, ?), dtype=float32) 1
# Tensor("Squeeze_4:0", shape=(?, ?, 64), dtype=float32) Tensor("Reshape_4:0", shape=(?, ?, ?), dtype=float32) 0
# Tensor("Squeeze_30:0", shape=(?, ?, 1), dtype=float32) Tensor("Reshape_7:0", shape=(?, ?, 1), dtype=float32)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    eval_type = 'change')

# %%
trainer.train(max_iter = 10000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 0
# AUC = 0.247 vs. 0.266
# F1 = 0.443 vs. 0.432
# Precision = 0.285 vs. 0.275
# Recall = 1.000 vs. 1.000
# Validation: 0
# AUC = 0.079 vs. 0.073
# F1 = 0.141 vs. 0.137
# Precision = 0.078 vs. 0.073
# Recall = 0.786 vs. 0.981
# Minibatch Loss= 0.979648
# Training: 100
# AUC = 0.773 vs. 0.274
# F1 = 0.691 vs. 0.433
# Precision = 0.685 vs. 0.277
# Recall = 0.697 vs. 0.996
# Validation: 100
# AUC = 0.366 vs. 0.073
# F1 = 0.417 vs. 0.137
# Precision = 0.394 vs. 0.073
# Recall = 0.441 vs. 0.998
# Minibatch Loss= 0.687678
# Training: 200
# AUC = 0.883 vs. 0.294
# F1 = 0.797 vs. 0.457
# Precision = 0.840 vs. 0.296
# Recall = 0.758 vs. 0.997
# Validation: 200
# AUC = 0.609 vs. 0.073
# F1 = 0.594 vs. 0.137
# Precision = 0.598 vs. 0.073
# Recall = 0.590 vs. 0.995
# Minibatch Loss= 0.684738
# Training: 300
# AUC = 0.919 vs. 0.275
# F1 = 0.843 vs. 0.440
# Precision = 0.835 vs. 0.282
# Recall = 0.852 vs. 0.999
# Validation: 300
# AUC = 0.728 vs. 0.074
# F1 = 0.684 vs. 0.137
# Precision = 0.669 vs. 0.073
# Recall = 0.699 vs. 0.972
# Minibatch Loss= 0.506343
# Training: 400
# AUC = 0.921 vs. 0.312
# F1 = 0.845 vs. 0.458
# Precision = 0.846 vs. 0.298
# Recall = 0.844 vs. 0.985
# Validation: 400
# AUC = 0.809 vs. 0.072
# F1 = 0.741 vs. 0.137
# Precision = 0.710 vs. 0.073
# Recall = 0.774 vs. 1.000
# Minibatch Loss= 0.518218
# Training: 500
# AUC = 0.949 vs. 0.273
# F1 = 0.882 vs. 0.406
# Precision = 0.898 vs. 0.255
# Recall = 0.866 vs. 0.998
# Validation: 500
# AUC = 0.825 vs. 0.073
# F1 = 0.746 vs. 0.137
# Precision = 0.704 vs. 0.073
# Recall = 0.793 vs. 0.999
# Minibatch Loss= 0.423462
# Training: 600
# AUC = 0.960 vs. 0.268
# F1 = 0.888 vs. 0.419
# Precision = 0.903 vs. 0.265
# Recall = 0.874 vs. 0.997
# Validation: 600
# AUC = 0.831 vs. 0.073
# F1 = 0.743 vs. 0.137
# Precision = 0.729 vs. 0.073
# Recall = 0.759 vs. 1.000
# Minibatch Loss= 0.392806
# Training: 700
# AUC = 0.957 vs. 0.287
# F1 = 0.883 vs. 0.436
# Precision = 0.868 vs. 0.279
# Recall = 0.899 vs. 1.000
# Validation: 700
# AUC = 0.849 vs. 0.073
# F1 = 0.767 vs. 0.137
# Precision = 0.731 vs. 0.073
# Recall = 0.805 vs. 0.999
# Minibatch Loss= 0.398612
# Training: 800
# AUC = 0.950 vs. 0.287
# F1 = 0.875 vs. 0.437
# Precision = 0.843 vs. 0.282
# Recall = 0.909 vs. 0.971
# Validation: 800
# AUC = 0.870 vs. 0.073
# F1 = 0.794 vs. 0.137
# Precision = 0.765 vs. 0.073
# Recall = 0.825 vs. 0.986
# Minibatch Loss= 0.428683
# Training: 900
# AUC = 0.975 vs. 0.238
# F1 = 0.908 vs. 0.401
# Precision = 0.905 vs. 0.251
# Recall = 0.910 vs. 0.998
# Validation: 900
# AUC = 0.882 vs. 0.074
# F1 = 0.803 vs. 0.137
# Precision = 0.793 vs. 0.073
# Recall = 0.814 vs. 0.999
# Minibatch Loss= 0.318948
# Training: 1000
# AUC = 0.965 vs. 0.312
# F1 = 0.890 vs. 0.445
# Precision = 0.890 vs. 0.286
# Recall = 0.889 vs. 1.000
# Validation: 1000
# AUC = 0.877 vs. 0.073
# F1 = 0.789 vs. 0.137
# Precision = 0.760 vs. 0.073
# Recall = 0.820 vs. 1.000
# Minibatch Loss= 0.385637
# Training: 1100
# AUC = 0.951 vs. 0.277
# F1 = 0.871 vs. 0.442
# Precision = 0.879 vs. 0.284
# Recall = 0.862 vs. 1.000
# Validation: 1100
# AUC = 0.875 vs. 0.073
# F1 = 0.788 vs. 0.137
# Precision = 0.750 vs. 0.073
# Recall = 0.830 vs. 0.999
# Minibatch Loss= 0.430808
# Training: 1200
# AUC = 0.984 vs. 0.261
# F1 = 0.932 vs. 0.415
# Precision = 0.925 vs. 0.262
# Recall = 0.939 vs. 1.000
# Validation: 1200
# AUC = 0.859 vs. 0.074
# F1 = 0.765 vs. 0.137
# Precision = 0.708 vs. 0.073
# Recall = 0.833 vs. 1.000
# Minibatch Loss= 0.293909
# Training: 1300
# AUC = 0.972 vs. 0.285
# F1 = 0.917 vs. 0.437
# Precision = 0.920 vs. 0.279
# Recall = 0.915 vs. 1.000
# Validation: 1300
# AUC = 0.873 vs. 0.073
# F1 = 0.784 vs. 0.137
# Precision = 0.748 vs. 0.073
# Recall = 0.824 vs. 1.000
# Minibatch Loss= 0.366059
# Training: 1400
# AUC = 0.979 vs. 0.291
# F1 = 0.922 vs. 0.436
# Precision = 0.923 vs. 0.280
# Recall = 0.921 vs. 0.989
# Validation: 1400
# AUC = 0.854 vs. 0.074
# F1 = 0.773 vs. 0.137
# Precision = 0.716 vs. 0.073
# Recall = 0.839 vs. 1.000
# Minibatch Loss= 0.360993
# Training: 1500
# AUC = 0.961 vs. 0.299
# F1 = 0.902 vs. 0.444
# Precision = 0.903 vs. 0.286
# Recall = 0.901 vs. 0.996
# Validation: 1500
# AUC = 0.862 vs. 0.074
# F1 = 0.778 vs. 0.137
# Precision = 0.732 vs. 0.073
# Recall = 0.831 vs. 0.981
# Minibatch Loss= 0.400465
# Training: 1600
# AUC = 0.982 vs. 0.297
# F1 = 0.920 vs. 0.456
# Precision = 0.903 vs. 0.297
# Recall = 0.939 vs. 0.981
# Validation: 1600
# AUC = 0.891 vs. 0.073
# F1 = 0.815 vs. 0.137
# Precision = 0.794 vs. 0.073
# Recall = 0.836 vs. 1.000
# Minibatch Loss= 0.363875
# Training: 1700
# AUC = 0.987 vs. 0.281
# F1 = 0.935 vs. 0.448
# Precision = 0.939 vs. 0.289
# Recall = 0.932 vs. 0.997
# Validation: 1700
# AUC = 0.867 vs. 0.073
# F1 = 0.793 vs. 0.137
# Precision = 0.754 vs. 0.073
# Recall = 0.836 vs. 1.000
# Minibatch Loss= 0.372355
# Training: 1800
# AUC = 0.974 vs. 0.313
# F1 = 0.914 vs. 0.445
# Precision = 0.920 vs. 0.287
# Recall = 0.908 vs. 0.988
# Validation: 1800
# AUC = 0.875 vs. 0.074
# F1 = 0.807 vs. 0.137
# Precision = 0.790 vs. 0.073
# Recall = 0.826 vs. 1.000
# Minibatch Loss= 0.385183
# Training: 1900
# AUC = 0.978 vs. 0.267
# F1 = 0.914 vs. 0.421
# Precision = 0.898 vs. 0.267
# Recall = 0.931 vs. 1.000
# Validation: 1900
# AUC = 0.879 vs. 0.074
# F1 = 0.811 vs. 0.137
# Precision = 0.780 vs. 0.073
# Recall = 0.845 vs. 1.000
# Minibatch Loss= 0.343171
# Training: 2000
# AUC = 0.974 vs. 0.269
# F1 = 0.906 vs. 0.421
# Precision = 0.843 vs. 0.266
# Recall = 0.979 vs. 1.000
# Validation: 2000
# AUC = 0.850 vs. 0.073
# F1 = 0.783 vs. 0.137
# Precision = 0.747 vs. 0.073
# Recall = 0.823 vs. 0.998
# Minibatch Loss= 0.357086
# Training: 2100
# AUC = 0.972 vs. 0.296
# F1 = 0.913 vs. 0.430
# Precision = 0.911 vs. 0.274
# Recall = 0.916 vs. 1.000
# Validation: 2100
# AUC = 0.871 vs. 0.073
# F1 = 0.799 vs. 0.137
# Precision = 0.758 vs. 0.073
# Recall = 0.845 vs. 0.997
# Minibatch Loss= 0.390616
# Training: 2200
# AUC = 0.985 vs. 0.288
# F1 = 0.933 vs. 0.413
# Precision = 0.954 vs. 0.271
# Recall = 0.913 vs. 0.869
# Validation: 2200
# AUC = 0.870 vs. 0.073
# F1 = 0.797 vs. 0.137
# Precision = 0.756 vs. 0.073
# Recall = 0.841 vs. 0.999
# Minibatch Loss= 0.300716
# Training: 2300
# AUC = 0.984 vs. 0.275
# F1 = 0.931 vs. 0.446
# Precision = 0.939 vs. 0.287
# Recall = 0.922 vs. 1.000
# Validation: 2300
# AUC = 0.882 vs. 0.074
# F1 = 0.811 vs. 0.137
# Precision = 0.770 vs. 0.073
# Recall = 0.857 vs. 1.000
# Minibatch Loss= 0.402252
# Training: 2400
# AUC = 0.970 vs. 0.304
# F1 = 0.915 vs. 0.447
# Precision = 0.907 vs. 0.288
# Recall = 0.922 vs. 0.997
# Validation: 2400
# AUC = 0.870 vs. 0.073
# F1 = 0.807 vs. 0.137
# Precision = 0.782 vs. 0.073
# Recall = 0.833 vs. 0.989
# Minibatch Loss= 0.435205
# Training: 2500
# AUC = 0.974 vs. 0.270
# F1 = 0.913 vs. 0.420
# Precision = 0.933 vs. 0.266
# Recall = 0.894 vs. 1.000
# Validation: 2500
# AUC = 0.837 vs. 0.074
# F1 = 0.772 vs. 0.137
# Precision = 0.720 vs. 0.073
# Recall = 0.832 vs. 0.996
# Minibatch Loss= 0.362804
# Training: 2600
# AUC = 0.986 vs. 0.277
# F1 = 0.939 vs. 0.435
# Precision = 0.938 vs. 0.278
# Recall = 0.941 vs. 0.992
# Validation: 2600
# AUC = 0.860 vs. 0.074
# F1 = 0.799 vs. 0.137
# Precision = 0.763 vs. 0.073
# Recall = 0.838 vs. 0.981
# Minibatch Loss= 0.333929
# Training: 2700
# AUC = 0.979 vs. 0.276
# F1 = 0.920 vs. 0.422
# Precision = 0.918 vs. 0.268
# Recall = 0.921 vs. 1.000
# Validation: 2700
# AUC = 0.881 vs. 0.074
# F1 = 0.828 vs. 0.137
# Precision = 0.788 vs. 0.073
# Recall = 0.871 vs. 0.990
# Minibatch Loss= 0.327789
# Training: 2800
# AUC = 0.980 vs. 0.267
# F1 = 0.929 vs. 0.427
# Precision = 0.914 vs. 0.271
# Recall = 0.945 vs. 0.999
# Validation: 2800
# AUC = 0.853 vs. 0.074
# F1 = 0.794 vs. 0.137
# Precision = 0.750 vs. 0.073
# Recall = 0.842 vs. 0.997
# Minibatch Loss= 0.322810
# Training: 2900
# AUC = 0.986 vs. 0.297
# F1 = 0.942 vs. 0.456
# Precision = 0.944 vs. 0.295
# Recall = 0.939 vs. 0.999
# Validation: 2900
# AUC = 0.869 vs. 0.074
# F1 = 0.814 vs. 0.137
# Precision = 0.764 vs. 0.073
# Recall = 0.870 vs. 0.997
# Minibatch Loss= 0.350689
# Training: 3000
# AUC = 0.985 vs. 0.285
# F1 = 0.932 vs. 0.438
# Precision = 0.899 vs. 0.282
# Recall = 0.968 vs. 0.986
# Validation: 3000
# AUC = 0.865 vs. 0.074
# F1 = 0.809 vs. 0.137
# Precision = 0.770 vs. 0.073
# Recall = 0.853 vs. 0.992
# Minibatch Loss= 0.328665
# Training: 3100
# AUC = 0.983 vs. 0.291
# F1 = 0.937 vs. 0.449
# Precision = 0.944 vs. 0.290
# Recall = 0.930 vs. 0.993
# Validation: 3100
# AUC = 0.856 vs. 0.074
# F1 = 0.800 vs. 0.137
# Precision = 0.758 vs. 0.073
# Recall = 0.848 vs. 1.000
# Minibatch Loss= 0.342714
# Training: 3200
# AUC = 0.989 vs. 0.285
# F1 = 0.943 vs. 0.441
# Precision = 0.942 vs. 0.285
# Recall = 0.943 vs. 0.974
# Validation: 3200
# AUC = 0.857 vs. 0.073
# F1 = 0.813 vs. 0.137
# Precision = 0.769 vs. 0.073
# Recall = 0.861 vs. 0.991
# Minibatch Loss= 0.350436
# Training: 3300
# AUC = 0.966 vs. 0.269
# F1 = 0.895 vs. 0.434
# Precision = 0.915 vs. 0.277
# Recall = 0.877 vs. 0.994
# Validation: 3300
# AUC = 0.844 vs. 0.074
# F1 = 0.804 vs. 0.137
# Precision = 0.762 vs. 0.073
# Recall = 0.851 vs. 1.000
# Minibatch Loss= 0.386526
# Training: 3400
# AUC = 0.963 vs. 0.297
# F1 = 0.908 vs. 0.451
# Precision = 0.936 vs. 0.291
# Recall = 0.882 vs. 1.000
# Validation: 3400
# AUC = 0.864 vs. 0.073
# F1 = 0.809 vs. 0.137
# Precision = 0.765 vs. 0.073
# Recall = 0.858 vs. 0.990
# Minibatch Loss= 0.418114
# Training: 3500
# AUC = 0.984 vs. 0.256
# F1 = 0.936 vs. 0.412
# Precision = 0.938 vs. 0.260
# Recall = 0.933 vs. 0.991
# Validation: 3500
# AUC = 0.865 vs. 0.074
# F1 = 0.817 vs. 0.137
# Precision = 0.776 vs. 0.073
# Recall = 0.864 vs. 0.999
# Minibatch Loss= 0.331341
# Training: 3600
# AUC = 0.987 vs. 0.269
# F1 = 0.939 vs. 0.421
# Precision = 0.949 vs. 0.267
# Recall = 0.930 vs. 0.999
# Validation: 3600
# AUC = 0.858 vs. 0.074
# F1 = 0.808 vs. 0.137
# Precision = 0.762 vs. 0.073
# Recall = 0.860 vs. 0.992
# Minibatch Loss= 0.333625
# Training: 3700
# AUC = 0.990 vs. 0.284
# F1 = 0.947 vs. 0.428
# Precision = 0.940 vs. 0.273
# Recall = 0.954 vs. 0.984
# Validation: 3700
# AUC = 0.863 vs. 0.074
# F1 = 0.816 vs. 0.137
# Precision = 0.774 vs. 0.073
# Recall = 0.863 vs. 0.999
# Minibatch Loss= 0.319780
# Training: 3800
# AUC = 0.992 vs. 0.273
# F1 = 0.956 vs. 0.432
# Precision = 0.965 vs. 0.277
# Recall = 0.948 vs. 0.989
# Validation: 3800
# AUC = 0.843 vs. 0.073
# F1 = 0.800 vs. 0.137
# Precision = 0.752 vs. 0.073
# Recall = 0.854 vs. 0.999
# Minibatch Loss= 0.321047
# Training: 3900
# AUC = 0.984 vs. 0.253
# F1 = 0.932 vs. 0.413
# Precision = 0.921 vs. 0.260
# Recall = 0.943 vs. 1.000
# Validation: 3900
# AUC = 0.851 vs. 0.073
# F1 = 0.801 vs. 0.137
# Precision = 0.740 vs. 0.073
# Recall = 0.874 vs. 0.987
# Minibatch Loss= 0.313692
# Training: 4000
# AUC = 0.994 vs. 0.289
# F1 = 0.959 vs. 0.448
# Precision = 0.948 vs. 0.289
# Recall = 0.970 vs. 1.000
# Validation: 4000
# AUC = 0.856 vs. 0.074
# F1 = 0.807 vs. 0.137
# Precision = 0.774 vs. 0.073
# Recall = 0.844 vs. 1.000
# Minibatch Loss= 0.295557
# Training: 4100
# AUC = 0.964 vs. 0.303
# F1 = 0.905 vs. 0.450
# Precision = 0.935 vs. 0.291
# Recall = 0.876 vs. 0.995
# Validation: 4100
# AUC = 0.873 vs. 0.073
# F1 = 0.818 vs. 0.137
# Precision = 0.772 vs. 0.073
# Recall = 0.870 vs. 0.996
# Minibatch Loss= 0.444219
# Training: 4200
# AUC = 0.989 vs. 0.269
# F1 = 0.943 vs. 0.415
# Precision = 0.939 vs. 0.262
# Recall = 0.948 vs. 0.999
# Validation: 4200
# AUC = 0.865 vs. 0.073
# F1 = 0.817 vs. 0.137
# Precision = 0.774 vs. 0.073
# Recall = 0.865 vs. 0.992
# Minibatch Loss= 0.277288
# Training: 4300
# AUC = 0.974 vs. 0.299
# F1 = 0.913 vs. 0.445
# Precision = 0.921 vs. 0.286
# Recall = 0.905 vs. 1.000
# Validation: 4300
# AUC = 0.842 vs. 0.073
# F1 = 0.794 vs. 0.137
# Precision = 0.751 vs. 0.073
# Recall = 0.841 vs. 0.988
# Minibatch Loss= 0.358447
# Training: 4400
# AUC = 0.985 vs. 0.306
# F1 = 0.929 vs. 0.456
# Precision = 0.926 vs. 0.295
# Recall = 0.931 vs. 1.000
# Validation: 4400
# AUC = 0.847 vs. 0.074
# F1 = 0.806 vs. 0.137
# Precision = 0.766 vs. 0.073
# Recall = 0.851 vs. 0.999
# Minibatch Loss= 0.376278
# Training: 4500
# AUC = 0.991 vs. 0.276
# F1 = 0.952 vs. 0.440
# Precision = 0.933 vs. 0.282
# Recall = 0.971 vs. 0.999
# Validation: 4500
# AUC = 0.843 vs. 0.073
# F1 = 0.806 vs. 0.137
# Precision = 0.757 vs. 0.073
# Recall = 0.861 vs. 0.996
# Minibatch Loss= 0.335035
# Training: 4600
# AUC = 0.992 vs. 0.294
# F1 = 0.950 vs. 0.453
# Precision = 0.932 vs. 0.294
# Recall = 0.969 vs. 0.996
# Validation: 4600
# AUC = 0.851 vs. 0.073
# F1 = 0.805 vs. 0.137
# Precision = 0.759 vs. 0.073
# Recall = 0.857 vs. 0.985
# Minibatch Loss= 0.321765
# Training: 4700
# AUC = 0.992 vs. 0.313
# F1 = 0.953 vs. 0.467
# Precision = 0.958 vs. 0.305
# Recall = 0.949 vs. 0.997
# Validation: 4700
# AUC = 0.846 vs. 0.073
# F1 = 0.801 vs. 0.137
# Precision = 0.745 vs. 0.073
# Recall = 0.865 vs. 1.000
# Minibatch Loss= 0.330855
# Training: 4800
# AUC = 0.993 vs. 0.278
# F1 = 0.957 vs. 0.430
# Precision = 0.956 vs. 0.274
# Recall = 0.958 vs. 0.997
# Validation: 4800
# AUC = 0.833 vs. 0.073
# F1 = 0.795 vs. 0.137
# Precision = 0.736 vs. 0.073
# Recall = 0.865 vs. 1.000
# Minibatch Loss= 0.312161
# Training: 4900
# AUC = 0.995 vs. 0.285
# F1 = 0.961 vs. 0.449
# Precision = 0.953 vs. 0.290
# Recall = 0.969 vs. 0.996
# Validation: 4900
# AUC = 0.841 vs. 0.074
# F1 = 0.801 vs. 0.137
# Precision = 0.756 vs. 0.073
# Recall = 0.852 vs. 0.998
# Minibatch Loss= 0.319879
# Training: 5000
# AUC = 0.992 vs. 0.311
# F1 = 0.952 vs. 0.452
# Precision = 0.984 vs. 0.293
# Recall = 0.921 vs. 0.988
# Validation: 5000
# AUC = 0.836 vs. 0.074
# F1 = 0.795 vs. 0.137
# Precision = 0.754 vs. 0.073
# Recall = 0.840 vs. 0.996
# Minibatch Loss= 0.349055
# Training: 5100
# AUC = 0.996 vs. 0.301
# F1 = 0.968 vs. 0.457
# Precision = 0.963 vs. 0.301
# Recall = 0.972 vs. 0.952
# Validation: 5100
# AUC = 0.836 vs. 0.074
# F1 = 0.798 vs. 0.137
# Precision = 0.750 vs. 0.073
# Recall = 0.852 vs. 0.995
# Minibatch Loss= 0.295071
# Training: 5200
# AUC = 0.991 vs. 0.292
# F1 = 0.952 vs. 0.449
# Precision = 0.932 vs. 0.289
# Recall = 0.972 vs. 1.000
# Validation: 5200
# AUC = 0.831 vs. 0.074
# F1 = 0.799 vs. 0.137
# Precision = 0.756 vs. 0.073
# Recall = 0.847 vs. 0.997
# Minibatch Loss= 0.348165
# Training: 5300
# AUC = 0.995 vs. 0.283
# F1 = 0.961 vs. 0.448
# Precision = 0.961 vs. 0.288
# Recall = 0.962 vs. 1.000
# Validation: 5300
# AUC = 0.820 vs. 0.072
# F1 = 0.780 vs. 0.137
# Precision = 0.732 vs. 0.073
# Recall = 0.835 vs. 1.000
# Minibatch Loss= 0.341123
# Training: 5400
# AUC = 0.994 vs. 0.288
# F1 = 0.955 vs. 0.450
# Precision = 0.962 vs. 0.290
# Recall = 0.949 vs. 1.000
# Validation: 5400
# AUC = 0.810 vs. 0.073
# F1 = 0.770 vs. 0.137
# Precision = 0.724 vs. 0.073
# Recall = 0.821 vs. 0.999
# Minibatch Loss= 0.324233
# Training: 5500
# AUC = 0.995 vs. 0.289
# F1 = 0.965 vs. 0.450
# Precision = 0.974 vs. 0.290
# Recall = 0.955 vs. 0.999
# Validation: 5500
# AUC = 0.835 vs. 0.074
# F1 = 0.798 vs. 0.137
# Precision = 0.750 vs. 0.073
# Recall = 0.851 vs. 0.999
# Minibatch Loss= 0.338695
# Training: 5600
# AUC = 0.994 vs. 0.252
# F1 = 0.956 vs. 0.416
# Precision = 0.958 vs. 0.263
# Recall = 0.954 vs. 0.999
# Validation: 5600
# AUC = 0.819 vs. 0.072
# F1 = 0.786 vs. 0.137
# Precision = 0.728 vs. 0.073
# Recall = 0.854 vs. 0.995
# Minibatch Loss= 0.296445
# Training: 5700
# AUC = 0.994 vs. 0.293
# F1 = 0.956 vs. 0.456
# Precision = 0.931 vs. 0.295
# Recall = 0.983 vs. 1.000
# Validation: 5700
# AUC = 0.823 vs. 0.073
# F1 = 0.788 vs. 0.137
# Precision = 0.725 vs. 0.073
# Recall = 0.864 vs. 0.997
# Minibatch Loss= 0.330831
# Training: 5800
# AUC = 0.996 vs. 0.295
# F1 = 0.966 vs. 0.445
# Precision = 0.970 vs. 0.286
# Recall = 0.963 vs. 0.996
# Validation: 5800
# AUC = 0.805 vs. 0.073
# F1 = 0.777 vs. 0.137
# Precision = 0.720 vs. 0.073
# Recall = 0.843 vs. 0.997
# Minibatch Loss= 0.332329
# Training: 5900
# AUC = 0.996 vs. 0.291
# F1 = 0.968 vs. 0.456
# Precision = 0.962 vs. 0.295
# Recall = 0.973 vs. 0.999
# Validation: 5900
# AUC = 0.809 vs. 0.073
# F1 = 0.784 vs. 0.137
# Precision = 0.731 vs. 0.073
# Recall = 0.846 vs. 1.000
# Minibatch Loss= 0.343493
# Training: 6000
# AUC = 0.996 vs. 0.283
# F1 = 0.964 vs. 0.432
# Precision = 0.953 vs. 0.275
# Recall = 0.976 vs. 1.000
# Validation: 6000
# AUC = 0.814 vs. 0.074
# F1 = 0.786 vs. 0.137
# Precision = 0.744 vs. 0.073
# Recall = 0.834 vs. 1.000
# Minibatch Loss= 0.292405
# Training: 6100
# AUC = 0.996 vs. 0.296
# F1 = 0.966 vs. 0.444
# Precision = 0.963 vs. 0.286
# Recall = 0.970 vs. 0.999
# Validation: 6100
# AUC = 0.805 vs. 0.074
# F1 = 0.780 vs. 0.137
# Precision = 0.728 vs. 0.073
# Recall = 0.840 vs. 0.994
# Minibatch Loss= 0.300465
# Training: 6200
# AUC = 0.996 vs. 0.287
# F1 = 0.966 vs. 0.424
# Precision = 0.952 vs. 0.269
# Recall = 0.981 vs. 0.997
# Validation: 6200
# AUC = 0.801 vs. 0.073
# F1 = 0.775 vs. 0.137
# Precision = 0.716 vs. 0.073
# Recall = 0.844 vs. 0.996
# Minibatch Loss= 0.269186
# Training: 6300
# AUC = 0.996 vs. 0.303
# F1 = 0.966 vs. 0.457
# Precision = 0.955 vs. 0.296
# Recall = 0.978 vs. 1.000
# Validation: 6300
# AUC = 0.801 vs. 0.074
# F1 = 0.776 vs. 0.137
# Precision = 0.715 vs. 0.073
# Recall = 0.847 vs. 1.000
# Minibatch Loss= 0.349627
# Training: 6400
# AUC = 0.995 vs. 0.304
# F1 = 0.961 vs. 0.443
# Precision = 0.960 vs. 0.290
# Recall = 0.962 vs. 0.940
# Validation: 6400
# AUC = 0.819 vs. 0.073
# F1 = 0.789 vs. 0.137
# Precision = 0.731 vs. 0.073
# Recall = 0.857 vs. 1.000
# Minibatch Loss= 0.334364
# Training: 6500
# AUC = 0.995 vs. 0.277
# F1 = 0.961 vs. 0.439
# Precision = 0.955 vs. 0.281
# Recall = 0.967 vs. 1.000
# Validation: 6500
# AUC = 0.791 vs. 0.073
# F1 = 0.770 vs. 0.137
# Precision = 0.716 vs. 0.073
# Recall = 0.835 vs. 0.999
# Minibatch Loss= 0.303199
# Training: 6600
# AUC = 0.996 vs. 0.299
# F1 = 0.963 vs. 0.434
# Precision = 0.955 vs. 0.279
# Recall = 0.972 vs. 0.979
# Validation: 6600
# AUC = 0.805 vs. 0.073
# F1 = 0.785 vs. 0.137
# Precision = 0.732 vs. 0.073
# Recall = 0.847 vs. 1.000
# Minibatch Loss= 0.318740
# Training: 6700
# AUC = 0.994 vs. 0.251
# F1 = 0.958 vs. 0.404
# Precision = 0.960 vs. 0.254
# Recall = 0.957 vs. 0.991
# Validation: 6700
# AUC = 0.810 vs. 0.073
# F1 = 0.790 vs. 0.137
# Precision = 0.748 vs. 0.073
# Recall = 0.836 vs. 0.999
# Minibatch Loss= 0.282675
# Training: 6800
# AUC = 0.948 vs. 0.287
# F1 = 0.879 vs. 0.426
# Precision = 0.841 vs. 0.270
# Recall = 0.921 vs. 1.000
# Validation: 6800
# AUC = 0.830 vs. 0.073
# F1 = 0.776 vs. 0.137
# Precision = 0.739 vs. 0.073
# Recall = 0.818 vs. 0.996
# Minibatch Loss= 0.401260
# Training: 6900
# AUC = 0.967 vs. 0.283
# F1 = 0.898 vs. 0.437
# Precision = 0.911 vs. 0.280
# Recall = 0.885 vs. 1.000
# Validation: 6900
# AUC = 0.840 vs. 0.074
# F1 = 0.799 vs. 0.137
# Precision = 0.761 vs. 0.073
# Recall = 0.841 vs. 0.998
# Minibatch Loss= 0.366642
# Training: 7000
# AUC = 0.985 vs. 0.257
# F1 = 0.935 vs. 0.411
# Precision = 0.930 vs. 0.259
# Recall = 0.941 vs. 0.997
# Validation: 7000
# AUC = 0.839 vs. 0.073
# F1 = 0.800 vs. 0.137
# Precision = 0.758 vs. 0.073
# Recall = 0.846 vs. 1.000
# Minibatch Loss= 0.308677
# Training: 7100
# AUC = 0.982 vs. 0.287
# F1 = 0.922 vs. 0.447
# Precision = 0.896 vs. 0.291
# Recall = 0.950 vs. 0.970
# Validation: 7100
# AUC = 0.840 vs. 0.074
# F1 = 0.803 vs. 0.137
# Precision = 0.753 vs. 0.073
# Recall = 0.860 vs. 0.995
# Minibatch Loss= 0.373907
# Training: 7200
# AUC = 0.988 vs. 0.288
# F1 = 0.948 vs. 0.432
# Precision = 0.946 vs. 0.278
# Recall = 0.949 vs. 0.967
# Validation: 7200
# AUC = 0.832 vs. 0.074
# F1 = 0.794 vs. 0.137
# Precision = 0.744 vs. 0.073
# Recall = 0.851 vs. 0.999
# Minibatch Loss= 0.302951
# Training: 7300
# AUC = 0.992 vs. 0.294
# F1 = 0.951 vs. 0.478
# Precision = 0.951 vs. 0.314
# Recall = 0.950 vs. 1.000
# Validation: 7300
# AUC = 0.827 vs. 0.074
# F1 = 0.789 vs. 0.137
# Precision = 0.738 vs. 0.073
# Recall = 0.847 vs. 0.988
# Minibatch Loss= 0.355878
# Training: 7400
# AUC = 0.988 vs. 0.285
# F1 = 0.944 vs. 0.442
# Precision = 0.939 vs. 0.284
# Recall = 0.949 vs. 1.000
# Validation: 7400
# AUC = 0.815 vs. 0.072
# F1 = 0.776 vs. 0.137
# Precision = 0.715 vs. 0.073
# Recall = 0.848 vs. 0.999
# Minibatch Loss= 0.347557
# Training: 7500
# AUC = 0.995 vs. 0.286
# F1 = 0.958 vs. 0.434
# Precision = 0.941 vs. 0.277
# Recall = 0.976 vs. 0.994
# Validation: 7500
# AUC = 0.810 vs. 0.072
# F1 = 0.781 vs. 0.137
# Precision = 0.726 vs. 0.073
# Recall = 0.845 vs. 0.998
# Minibatch Loss= 0.317458
# Training: 7600
# AUC = 0.995 vs. 0.278
# F1 = 0.961 vs. 0.432
# Precision = 0.960 vs. 0.275
# Recall = 0.962 vs. 1.000
# Validation: 7600
# AUC = 0.815 vs. 0.073
# F1 = 0.785 vs. 0.137
# Precision = 0.732 vs. 0.073
# Recall = 0.846 vs. 1.000
# Minibatch Loss= 0.307344
# Training: 7700
# AUC = 0.992 vs. 0.289
# F1 = 0.954 vs. 0.451
# Precision = 0.960 vs. 0.291
# Recall = 0.947 vs. 0.996
# Validation: 7700
# AUC = 0.810 vs. 0.074
# F1 = 0.780 vs. 0.137
# Precision = 0.720 vs. 0.073
# Recall = 0.851 vs. 0.999
# Minibatch Loss= 0.329402
# Training: 7800
# AUC = 0.992 vs. 0.299
# F1 = 0.953 vs. 0.456
# Precision = 0.961 vs. 0.298
# Recall = 0.946 vs. 0.972
# Validation: 7800
# AUC = 0.808 vs. 0.074
# F1 = 0.780 vs. 0.137
# Precision = 0.721 vs. 0.073
# Recall = 0.849 vs. 0.994
# Minibatch Loss= 0.356152
# Training: 7900
# AUC = 0.995 vs. 0.293
# F1 = 0.961 vs. 0.445
# Precision = 0.958 vs. 0.286
# Recall = 0.963 vs. 1.000
# Validation: 7900
# AUC = 0.796 vs. 0.074
# F1 = 0.774 vs. 0.137
# Precision = 0.718 vs. 0.073
# Recall = 0.840 vs. 1.000
# Minibatch Loss= 0.290701
# Training: 8000
# AUC = 0.997 vs. 0.285
# F1 = 0.970 vs. 0.444
# Precision = 0.961 vs. 0.286
# Recall = 0.979 vs. 0.988
# Validation: 8000
# AUC = 0.790 vs. 0.074
# F1 = 0.765 vs. 0.137
# Precision = 0.716 vs. 0.073
# Recall = 0.822 vs. 0.999
# Minibatch Loss= 0.287242
# Training: 8100
# AUC = 0.997 vs. 0.258
# F1 = 0.970 vs. 0.396
# Precision = 0.973 vs. 0.249
# Recall = 0.967 vs. 0.973
# Validation: 8100
# AUC = 0.796 vs. 0.073
# F1 = 0.771 vs. 0.137
# Precision = 0.715 vs. 0.073
# Recall = 0.836 vs. 1.000
# Minibatch Loss= 0.260321
# Training: 8200
# AUC = 0.997 vs. 0.283
# F1 = 0.976 vs. 0.437
# Precision = 0.971 vs. 0.280
# Recall = 0.982 vs. 1.000
# Validation: 8200
# AUC = 0.794 vs. 0.074
# F1 = 0.772 vs. 0.137
# Precision = 0.716 vs. 0.073
# Recall = 0.837 vs. 0.985
# Minibatch Loss= 0.296809
# Training: 8300
# AUC = 0.998 vs. 0.274
# F1 = 0.976 vs. 0.431
# Precision = 0.974 vs. 0.276
# Recall = 0.977 vs. 0.987
# Validation: 8300
# AUC = 0.782 vs. 0.073
# F1 = 0.768 vs. 0.137
# Precision = 0.698 vs. 0.073
# Recall = 0.853 vs. 1.000
# Minibatch Loss= 0.286988
# Training: 8400
# AUC = 0.997 vs. 0.292
# F1 = 0.968 vs. 0.441
# Precision = 0.973 vs. 0.283
# Recall = 0.963 vs. 1.000
# Validation: 8400
# AUC = 0.792 vs. 0.075
# F1 = 0.774 vs. 0.137
# Precision = 0.718 vs. 0.073
# Recall = 0.840 vs. 1.000
# Minibatch Loss= 0.313093
# Training: 8500
# AUC = 0.998 vs. 0.271
# F1 = 0.976 vs. 0.432
# Precision = 0.984 vs. 0.275
# Recall = 0.969 vs. 1.000
# Validation: 8500
# AUC = 0.770 vs. 0.074
# F1 = 0.757 vs. 0.137
# Precision = 0.686 vs. 0.073
# Recall = 0.844 vs. 0.999
# Minibatch Loss= 0.303539
# Training: 8600
# AUC = 0.998 vs. 0.273
# F1 = 0.976 vs. 0.434
# Precision = 0.972 vs. 0.285
# Recall = 0.980 vs. 0.907
# Validation: 8600
# AUC = 0.781 vs. 0.074
# F1 = 0.768 vs. 0.137
# Precision = 0.700 vs. 0.073
# Recall = 0.851 vs. 1.000
# Minibatch Loss= 0.268748
# Training: 8700
# AUC = 0.998 vs. 0.278
# F1 = 0.975 vs. 0.427
# Precision = 0.970 vs. 0.271
# Recall = 0.980 vs. 0.999
# Validation: 8700
# AUC = 0.764 vs. 0.072
# F1 = 0.750 vs. 0.137
# Precision = 0.687 vs. 0.073
# Recall = 0.825 vs. 1.000
# Minibatch Loss= 0.299440
# Training: 8800
# AUC = 0.998 vs. 0.287
# F1 = 0.977 vs. 0.438
# Precision = 0.970 vs. 0.283
# Recall = 0.985 vs. 0.964
# Validation: 8800
# AUC = 0.770 vs. 0.073
# F1 = 0.761 vs. 0.137
# Precision = 0.708 vs. 0.073
# Recall = 0.822 vs. 0.988
# Minibatch Loss= 0.308602
# Training: 8900
# AUC = 0.997 vs. 0.295
# F1 = 0.971 vs. 0.451
# Precision = 0.971 vs. 0.291
# Recall = 0.972 vs. 1.000
# Validation: 8900
# AUC = 0.767 vs. 0.073
# F1 = 0.750 vs. 0.137
# Precision = 0.686 vs. 0.073
# Recall = 0.828 vs. 0.998
# Minibatch Loss= 0.348690
# Training: 9000
# AUC = 0.998 vs. 0.286
# F1 = 0.974 vs. 0.451
# Precision = 0.962 vs. 0.291
# Recall = 0.987 vs. 1.000
# Validation: 9000
# AUC = 0.766 vs. 0.074
# F1 = 0.757 vs. 0.137
# Precision = 0.694 vs. 0.073
# Recall = 0.832 vs. 1.000
# Minibatch Loss= 0.316599
# Training: 9100
# AUC = 0.997 vs. 0.279
# F1 = 0.972 vs. 0.439
# Precision = 0.972 vs. 0.281
# Recall = 0.972 vs. 1.000
# Validation: 9100
# AUC = 0.777 vs. 0.074
# F1 = 0.758 vs. 0.137
# Precision = 0.697 vs. 0.073
# Recall = 0.830 vs. 1.000
# Minibatch Loss= 0.302136
# Training: 9200
# AUC = 0.996 vs. 0.287
# F1 = 0.967 vs. 0.456
# Precision = 0.953 vs. 0.296
# Recall = 0.982 vs. 1.000
# Validation: 9200
# AUC = 0.785 vs. 0.074
# F1 = 0.769 vs. 0.137
# Precision = 0.711 vs. 0.073
# Recall = 0.836 vs. 0.989
# Minibatch Loss= 0.344893
# Training: 9300
# AUC = 0.991 vs. 0.278
# F1 = 0.950 vs. 0.443
# Precision = 0.943 vs. 0.284
# Recall = 0.956 vs. 1.000
# Validation: 9300
# AUC = 0.804 vs. 0.073
# F1 = 0.778 vs. 0.137
# Precision = 0.719 vs. 0.073
# Recall = 0.849 vs. 0.994
# Minibatch Loss= 0.318804
# Training: 9400
# AUC = 0.991 vs. 0.287
# F1 = 0.950 vs. 0.442
# Precision = 0.948 vs. 0.284
# Recall = 0.952 vs. 1.000
# Validation: 9400
# AUC = 0.806 vs. 0.073
# F1 = 0.781 vs. 0.137
# Precision = 0.731 vs. 0.073
# Recall = 0.838 vs. 0.999
# Minibatch Loss= 0.357314
# Training: 9500
# AUC = 0.959 vs. 0.280
# F1 = 0.898 vs. 0.449
# Precision = 0.906 vs. 0.290
# Recall = 0.891 vs. 1.000
# Validation: 9500
# AUC = 0.812 vs. 0.073
# F1 = 0.781 vs. 0.137
# Precision = 0.729 vs. 0.073
# Recall = 0.841 vs. 1.000
# Minibatch Loss= 0.437571
# Training: 9600
# AUC = 0.982 vs. 0.300
# F1 = 0.933 vs. 0.451
# Precision = 0.918 vs. 0.291
# Recall = 0.949 vs. 1.000
# Validation: 9600
# AUC = 0.830 vs. 0.073
# F1 = 0.787 vs. 0.137
# Precision = 0.747 vs. 0.073
# Recall = 0.831 vs. 0.999
# Minibatch Loss= 0.375178
# Training: 9700
# AUC = 0.988 vs. 0.286
# F1 = 0.941 vs. 0.439
# Precision = 0.923 vs. 0.281
# Recall = 0.961 vs. 1.000
# Validation: 9700
# AUC = 0.850 vs. 0.073
# F1 = 0.808 vs. 0.137
# Precision = 0.765 vs. 0.073
# Recall = 0.857 vs. 1.000
# Minibatch Loss= 0.342797
# Training: 9800
# AUC = 0.966 vs. 0.283
# F1 = 0.896 vs. 0.445
# Precision = 0.894 vs. 0.288
# Recall = 0.898 vs. 0.977
# Validation: 9800
# AUC = 0.818 vs. 0.073
# F1 = 0.788 vs. 0.137
# Precision = 0.740 vs. 0.073
# Recall = 0.841 vs. 1.000
# Minibatch Loss= 0.413937
# Training: 9900
# AUC = 0.989 vs. 0.303
# F1 = 0.944 vs. 0.464
# Precision = 0.932 vs. 0.302
# Recall = 0.957 vs. 0.996
# Validation: 9900
# AUC = 0.842 vs. 0.073
# F1 = 0.802 vs. 0.137
# Precision = 0.765 vs. 0.073
# Recall = 0.844 vs. 1.000
# Minibatch Loss= 0.365829
#  Optimization Finished!

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model_synthetic/train_gradual_test_abrupt/HRNN_1001_z/HRNN_1001_z-10000'

# %%
#saver = tf.train.Saver()
#saver.restore(sess, checkpoint_path+'-1000')

# %%
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.804 vs. 0.073
# F1 = 0.775 vs. 0.137
# Precision = 0.714 vs. 0.073
# Recall = 0.849 vs. 0.989

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (1000, 256)

# %%
savemat('../../poc_synthetic/train_gradual_test_abrupt/poc'+exp_name+'.mat', {'poc':out})
