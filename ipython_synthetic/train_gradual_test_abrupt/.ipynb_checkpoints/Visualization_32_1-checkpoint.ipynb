# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt

from hdf5storage import savemat
from hdf5storage import loadmat
import matplotlib.patches as mpatches
import matplotlib
import pickle
import hickle

import sys
sys.path.append('../../src')

# %%
import evaluation.eval_rank as eval_rank
import evaluation.eval_utils as eval_utils

# %%
data_path_old = '/data2/data/zebrahim/synthetic_dataset/data_8192_1000_3_4_4_.03_.03_.2' + 'processed_data2.h'
with open(data_path_old, 'r') as fin:
    data_old = hickle.load(fin)
index_of_changes_old = data_old['index_of_changes']

#data which I trained on gradual and test on abrupt changes
data_path_new = '../../data/synthetic2/' + 'processed4.p'
with open(data_path_new, 'r') as fin:
    data_new = pickle.load(fin)
index_of_changes_new = data_new['index_of_changes']


#mixed new data
data_path_new = '../../data/synthetic2/' + 'processed3.p'
with open(data_path_new, 'r') as fin:
    data_new_3 = pickle.load(fin)
index_of_changes3 = data_new_3['index_of_changes']


data_num_step = 8192

# %%
index_of_changes_old.shape, index_of_changes_new.shape
# Out:
# ((100, 4), (1000, 4))

# %%
data_old['test_data'].shape, data_new['test_data'].shape
# Out:
# ((100, 8192, 12), (1000, 8192, 12))

# %%
#old CNN, DWN, RCNN
CNN1001_1 = loadmat("../../poc_synthetic/pocCNN1001"+'.mat')['poc']
DWN_2001_1 = loadmat("../../poc_synthetic/pocDWN2001"+'.mat')['poc']

#new CNN, DWN
CNN1001_z = loadmat("../../poc_synthetic/train_gradual_test_abrupt/pocCNN1001_z"+'.mat')['poc']
DWN_1001_z = loadmat("../../poc_synthetic/train_gradual_test_abrupt/pocDWN1001_z"+'.mat')['poc']

#merged training and test part of the third version of synthetic dataset
CNN1001_y = loadmat("../../poc_synthetic/train_abrupt_test_gradual/pocCNN1001_y"+'.mat')['poc']
DWN_1001_y = loadmat("../../poc_synthetic/train_abrupt_test_gradual/pocDWN1001_y"+'.mat')['poc']

# %%
cpd_val_CNN32_1, cpd_CNN32_1 = eval_rank.non_max_supression(CNN1001_1, window=15, data_num_step=data_num_step)
cpd_val_DWN32_1, cpd_DWN32_1 = eval_rank.non_max_supression(DWN_2001_1, window=15, data_num_step=data_num_step)

cpd_val_CNN32_z, cpd_CNN32_z = eval_rank.non_max_supression(CNN1001_z, window=15, data_num_step=data_num_step)
cpd_val_DWN32_z, cpd_DWN32_z = eval_rank.non_max_supression(DWN_1001_z, window=15, data_num_step=data_num_step)

cpd_val_CNN32_y, cpd_CNN32_y = eval_rank.non_max_supression(CNN1001_y, window=15, data_num_step=data_num_step)
cpd_val_DWN32_y, cpd_DWN32_y = eval_rank.non_max_supression(DWN_1001_y, window=15, data_num_step=data_num_step)

# %%
RCNN_2001_1 = loadmat("../../poc_synthetic/pocCNN-LSTM4001"+'.mat')['poc']
RCNN_1001_z = loadmat("../../poc_synthetic/train_gradual_test_abrupt/pocRCNN1001_z"+'.mat')['poc']
RCNN_1001_y = loadmat("../../poc_synthetic/train_abrupt_test_gradual/pocRCNN1001_y"+'.mat')['poc']

PRN_1001_1 = loadmat("../../poc_synthetic/pocHRNN_synthetic_1"+'.mat')['poc']
PRN_1001_z = loadmat("../../poc_synthetic/train_gradual_test_abrupt/pocHRNN_1001_z"+'.mat')['poc']
PRN_1001_y = loadmat("../../poc_synthetic/train_abrupt_test_gradual/pocHRNN_1001_y"+'.mat')['poc']

# %%
cpd_val_RCNN32_1, cpd_RCNN32_1 = eval_rank.non_max_supression(RCNN_2001_1, window=15, data_num_step=data_num_step)
cpd_val_RCNN32_z, cpd_RCNN32_z = eval_rank.non_max_supression(RCNN_1001_z, window=15, data_num_step=data_num_step)
cpd_val_RCNN32_y, cpd_RCNN32_y = eval_rank.non_max_supression(RCNN_1001_y, window=15, data_num_step=data_num_step)

cpd_val_PRN32_1, cpd_PRN32_1 = eval_rank.non_max_supression(PRN_1001_1, window=15, data_num_step=data_num_step)
cpd_val_PRN32_z, cpd_PRN32_z = eval_rank.non_max_supression(PRN_1001_z, window=15, data_num_step=data_num_step)
cpd_val_PRN32_y, cpd_PRN32_y = eval_rank.non_max_supression(PRN_1001_y, window=15, data_num_step=data_num_step)

# %%
def tolerance_auc(cpd_val, cpd, gt_mean_test, tolerance):
    out_put = []
    for t in tolerance:
        print t
        out = eval_rank.parallel_ranking(cpd_val, cpd, gt_mean_test, t)
        out_put.append(eval_utils.calc_auc(zip(out[0], out[1]), gt_mean_test))
        
    return out_put

# %%
tolerance = [8, 16, 32, 64, 128, 256, 512]
tol_auc_CNN32_1 = tolerance_auc(cpd_val_CNN32_1, cpd_CNN32_1, index_of_changes_old, tolerance)
tol_auc_DWN32_1 = tolerance_auc(cpd_val_DWN32_1, cpd_DWN32_1, index_of_changes_old, tolerance)

tol_auc_CNN32_z = tolerance_auc(cpd_val_CNN32_z, cpd_CNN32_z, index_of_changes_new, tolerance)
tol_auc_DWN32_z = tolerance_auc(cpd_val_DWN32_z, cpd_DWN32_z, index_of_changes_new, tolerance)

tol_auc_CNN32_y = tolerance_auc(cpd_val_CNN32_y, cpd_CNN32_y, index_of_changes3, tolerance)
tol_auc_DWN32_y = tolerance_auc(cpd_val_DWN32_y, cpd_DWN32_y, index_of_changes3, tolerance)
# Out:
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %%
tol_auc_DWN32_z = tolerance_auc(cpd_val_DWN32_z, cpd_DWN32_z, index_of_changes_new, tolerance)

tol_auc_CNN32_y = tolerance_auc(cpd_val_CNN32_y, cpd_CNN32_y, index_of_changes3, tolerance)
tol_auc_DWN32_y = tolerance_auc(cpd_val_DWN32_y, cpd_DWN32_y, index_of_changes3, tolerance)
# Out:
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %%
tol_auc_RCNN32_1 = tolerance_auc(cpd_val_RCNN32_1, cpd_RCNN32_1, index_of_changes_old, tolerance)
tol_auc_RCNN32_z = tolerance_auc(cpd_val_RCNN32_z, cpd_RCNN32_z, index_of_changes_new, tolerance)
tol_auc_RCNN32_y = tolerance_auc(cpd_val_RCNN32_y, cpd_RCNN32_y, index_of_changes3, tolerance)

tol_auc_PRN32_1 = tolerance_auc(cpd_val_PRN32_1, cpd_PRN32_1, index_of_changes_old, tolerance)
tol_auc_PRN32_z = tolerance_auc(cpd_val_PRN32_z, cpd_PRN32_z, index_of_changes_new, tolerance)
tol_auc_PRN32_y = tolerance_auc(cpd_val_PRN32_y, cpd_PRN32_y, index_of_changes3, tolerance)
# Out:
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %%
tol_auc_RCNN32_1 = tolerance_auc(cpd_val_RCNN32_1, cpd_RCNN32_1, index_of_changes_old, tolerance)
tol_auc_RCNN32_z = tolerance_auc(cpd_val_RCNN32_z, cpd_RCNN32_z, index_of_changes_new, tolerance)
tol_auc_RCNN32_y = tolerance_auc(cpd_val_RCNN32_y, cpd_RCNN32_y, index_of_changes3, tolerance)

tol_auc_PRN32_1 = tolerance_auc(cpd_val_PRN32_1, cpd_PRN32_1, index_of_changes_old, tolerance)
tol_auc_PRN32_z = tolerance_auc(cpd_val_PRN32_z, cpd_PRN32_z, index_of_changes_new, tolerance)
tol_auc_PRN32_y = tolerance_auc(cpd_val_PRN32_y, cpd_PRN32_y, index_of_changes3, tolerance)
# Out:
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %%
plt.figure(figsize=(8,5.5))
plt.plot(np.log2(tolerance[:]),tol_auc_PRN32_y[:],'d-g',label ='PRN')
plt.plot(np.log2(tolerance[:]),tol_auc_DWN32_y[:],':sb',label ='DWN')
plt.plot(np.log2(tolerance[:]),tol_auc_RCNN32_y[:],'--*r',label ='RCNN')
plt.plot(np.log2(tolerance[:]),tol_auc_CNN32_y[:],'-.ok',label ='CNN')


font = {'family' : 'normal',
        'size'   : 15
         }

matplotlib.rc('font', **font)

plt.legend(loc='upper left', fontsize = 13)
plt.ylim([0,1], )
plt.grid()
plt.xlabel('$log_2(tolerance)$', fontsize = 16)
plt.ylabel('$AUC$', fontsize = 16)
plt.title('Results on the synthetic dataset/ train on mix, test on mix')
# show the results
plt.show()

#save the results
plt.savefig('../../plot/plt4.png', bbox_inches = 'tight')
# Out:
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family [u'normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(8,5.5))


plt.plot(np.log2(tolerance[:]),tol_auc_PRN32_z[:],'-g',label ='PRN')
plt.plot(np.log2(tolerance[:]),tol_auc_DWN32_z[:],'-k',label ='DWN')
plt.plot(np.log2(tolerance[:]),tol_auc_RCNN32_z[:],'-r',label ='RCNN')
plt.plot(np.log2(tolerance[:]),tol_auc_CNN32_z[:],'-b',label ='CNN')

font = {'family' : 'normal',
        'size'   : 15
         }

matplotlib.rc('font', **font)

plt.legend(loc='upper left', fontsize = 13)
plt.ylim([0,1], )
plt.grid()
plt.xlabel('$log_2(tolerance)$', fontsize = 16)
plt.ylabel('$AUC$', fontsize = 16)
plt.title('Results on the synthetic dataset/ train on gradual, test on abrupt')
# show the results
plt.show()

#save the results
#plt.savefig('../../plot/plt4.png', bbox_inches = 'tight')

# %%
matplotlib.rcParams['mathtext.fontset'] = 'cm'

plt.figure(figsize=(8,5.5), dpi=600)

plt.plot(np.log2(tolerance[:]),tol_auc_PRN32_z[:],'d-g',label ='PRNN')
plt.plot(np.log2(tolerance[:]),tol_auc_DWN32_z[:],':sb',label ='DWNN')
plt.plot(np.log2(tolerance[:]),tol_auc_RCNN32_z[:],'--*r',label ='RCNN')
plt.plot(np.log2(tolerance[:]),tol_auc_CNN32_z[:],'-.ok',label ='CNN')

#plt.plot(np.log2(tolerance[:]),tol_auc_HRNN_NewWavelet16[:],'>:c',label ='HRRN_NewWavelet D=16')

font = {'family' : 'serif',
        'size'   : 21
         }

matplotlib.rc('font', **font)

plt.legend(loc='lower right', fontsize = 18)
plt.ylim([0,1], )
#plt.grid()
plt.xlabel('$\log_2(\eta)$', fontsize = 30)
plt.ylabel('AUC', fontsize = 20, fontname='serif')
#plt.title('Results on the synthetic dataset/train on gradual, test on abrupt')
# show the results
#plt.show()

#save the results
plt.savefig('../../plot/plt_z_2.png', bbox_inches = 'tight')

# %%
#np.asarray([tol_auc_PRN32_y[3], tol_auc_DWN32_y[3], tol_auc_RCNN32_y[3], tol_auc_CNN32_y[3]]) - np.asarray([tol_auc_PRN32_x[3], tol_auc_DWN32_x[3], tol_auc_RCNN32_x[3], tol_auc_CNN32_x[3]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a1086a353115> in <module>()
# ----> 1 np.asarray([tol_auc_PRN32_y[3], tol_auc_DWN32_y[3], tol_auc_RCNN32_y[3], tol_auc_CNN32_y[3]]) - np.asarray([tol_auc_PRN32_x[3], tol_auc_DWN32_x[3], tol_auc_RCNN32_x[3], tol_auc_CNN32_x[3]])
#
# NameError: name 'tol_auc_PRN32_x' is not defined
