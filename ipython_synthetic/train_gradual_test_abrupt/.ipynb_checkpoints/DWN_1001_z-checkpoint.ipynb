# %%
# useing this variable for saving models and summaries
exp_name = "DWN1001_z"

# %% [markdown]
# # Neural wavelet network
# 6levels wavelet then 5 layers CNN [2, 2, 2, 2, 2]

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed4.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape, validation_data.shape, test_data.shape, train_gt.shape, validation_gt.shape, test_gt.shape, index_of_changes.shape
# Out:
# ((900, 8192, 12),
#  (100, 8192, 12),
#  (1000, 8192, 12),
#  (900, 8192, 1),
#  (100, 8192, 1),
#  (1000, 8192, 1),
#  (1000, 4))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10


wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]    #stride of pooling in convolution
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
granularity = np.prod(pooling_stride)
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 2.46045164873

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_gradual_test_abrupt/' + exp_name 
checkpoint_path = '../../model_synthetic/train_gradual_test_abrupt/' + exp_name + '/' + exp_name

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet=True,
                                 trainable_conv=True,
                                 trainable_last = True)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.261 vs. 0.267
# F1 = 0.449 vs. 0.424
# Precision = 0.311 vs. 0.269
# Recall = 0.810 vs. 1.000
# Validation: 0
# AUC = 0.268 vs. 0.284
# F1 = 0.455 vs. 0.445
# Precision = 0.312 vs. 0.286
# Recall = 0.840 vs. 1.000
# Minibatch Loss= 0.971041
# Training: 100
# AUC = 0.728 vs. 0.276
# F1 = 0.688 vs. 0.433
# Precision = 0.640 vs. 0.277
# Recall = 0.744 vs. 0.989
# Validation: 100
# AUC = 0.725 vs. 0.286
# F1 = 0.663 vs. 0.445
# Precision = 0.625 vs. 0.286
# Recall = 0.705 vs. 0.999
# Minibatch Loss= 0.725686
# Training: 200
# AUC = 0.774 vs. 0.292
# F1 = 0.718 vs. 0.452
# Precision = 0.685 vs. 0.292
# Recall = 0.755 vs. 1.000
# Validation: 200
# AUC = 0.769 vs. 0.289
# F1 = 0.713 vs. 0.445
# Precision = 0.617 vs. 0.286
# Recall = 0.845 vs. 1.000
# Minibatch Loss= 0.745848
# Training: 300
# AUC = 0.836 vs. 0.280
# F1 = 0.767 vs. 0.431
# Precision = 0.729 vs. 0.275
# Recall = 0.809 vs. 0.999
# Validation: 300
# AUC = 0.835 vs. 0.283
# F1 = 0.782 vs. 0.445
# Precision = 0.750 vs. 0.286
# Recall = 0.818 vs. 0.999
# Minibatch Loss= 0.552317
# Training: 400
# AUC = 0.871 vs. 0.280
# F1 = 0.808 vs. 0.435
# Precision = 0.716 vs. 0.278
# Recall = 0.927 vs. 1.000
# Validation: 400
# AUC = 0.874 vs. 0.284
# F1 = 0.814 vs. 0.445
# Precision = 0.780 vs. 0.286
# Recall = 0.852 vs. 1.000
# Minibatch Loss= 0.542908
# Training: 500
# AUC = 0.881 vs. 0.281
# F1 = 0.789 vs. 0.437
# Precision = 0.748 vs. 0.281
# Recall = 0.835 vs. 0.989
# Validation: 500
# AUC = 0.891 vs. 0.281
# F1 = 0.827 vs. 0.445
# Precision = 0.794 vs. 0.286
# Recall = 0.863 vs. 0.996
# Minibatch Loss= 0.558160
# Training: 600
# AUC = 0.940 vs. 0.278
# F1 = 0.858 vs. 0.433
# Precision = 0.813 vs. 0.277
# Recall = 0.909 vs. 0.999
# Validation: 600
# AUC = 0.890 vs. 0.283
# F1 = 0.821 vs. 0.445
# Precision = 0.803 vs. 0.286
# Recall = 0.840 vs. 0.998
# Minibatch Loss= 0.404008
# Training: 700
# AUC = 0.894 vs. 0.296
# F1 = 0.821 vs. 0.440
# Precision = 0.815 vs. 0.283
# Recall = 0.826 vs. 0.989
# Validation: 700
# AUC = 0.892 vs. 0.292
# F1 = 0.826 vs. 0.445
# Precision = 0.780 vs. 0.286
# Recall = 0.879 vs. 0.998
# Minibatch Loss= 0.545968
# Training: 800
# AUC = 0.935 vs. 0.274
# F1 = 0.872 vs. 0.430
# Precision = 0.863 vs. 0.274
# Recall = 0.882 vs. 1.000
# Validation: 800
# AUC = 0.895 vs. 0.286
# F1 = 0.836 vs. 0.445
# Precision = 0.802 vs. 0.286
# Recall = 0.872 vs. 0.999
# Minibatch Loss= 0.440048
# Training: 900
# AUC = 0.921 vs. 0.288
# F1 = 0.838 vs. 0.443
# Precision = 0.825 vs. 0.289
# Recall = 0.851 vs. 0.950
# Validation: 900
# AUC = 0.898 vs. 0.286
# F1 = 0.832 vs. 0.445
# Precision = 0.794 vs. 0.286
# Recall = 0.874 vs. 1.000
# Minibatch Loss= 0.511782
# Training: 1000
# AUC = 0.965 vs. 0.309
# F1 = 0.901 vs. 0.467
# Precision = 0.894 vs. 0.305
# Recall = 0.909 vs. 0.996
# Validation: 1000
# AUC = 0.915 vs. 0.283
# F1 = 0.847 vs. 0.445
# Precision = 0.820 vs. 0.286
# Recall = 0.876 vs. 1.000
# Minibatch Loss= 0.446634
# Training: 1100
# AUC = 0.928 vs. 0.296
# F1 = 0.834 vs. 0.441
# Precision = 0.764 vs. 0.283
# Recall = 0.917 vs. 1.000
# Validation: 1100
# AUC = 0.917 vs. 0.285
# F1 = 0.839 vs. 0.445
# Precision = 0.819 vs. 0.286
# Recall = 0.860 vs. 0.997
# Minibatch Loss= 0.461170
# Training: 1200
# AUC = 0.911 vs. 0.263
# F1 = 0.842 vs. 0.416
# Precision = 0.770 vs. 0.263
# Recall = 0.929 vs. 0.999
# Validation: 1200
# AUC = 0.886 vs. 0.290
# F1 = 0.815 vs. 0.445
# Precision = 0.800 vs. 0.286
# Recall = 0.831 vs. 0.999
# Minibatch Loss= 0.479003
# Training: 1300
# AUC = 0.944 vs. 0.275
# F1 = 0.884 vs. 0.432
# Precision = 0.837 vs. 0.276
# Recall = 0.936 vs. 0.999
# Validation: 1300
# AUC = 0.919 vs. 0.281
# F1 = 0.851 vs. 0.445
# Precision = 0.825 vs. 0.286
# Recall = 0.878 vs. 0.999
# Minibatch Loss= 0.428423
# Training: 1400
# AUC = 0.903 vs. 0.272
# F1 = 0.843 vs. 0.439
# Precision = 0.773 vs. 0.282
# Recall = 0.926 vs. 0.997
# Validation: 1400
# AUC = 0.913 vs. 0.292
# F1 = 0.831 vs. 0.445
# Precision = 0.816 vs. 0.286
# Recall = 0.847 vs. 1.000
# Minibatch Loss= 0.530818
# Training: 1500
# AUC = 0.942 vs. 0.284
# F1 = 0.866 vs. 0.442
# Precision = 0.890 vs. 0.284
# Recall = 0.843 vs. 0.993
# Validation: 1500
# AUC = 0.920 vs. 0.283
# F1 = 0.848 vs. 0.445
# Precision = 0.815 vs. 0.286
# Recall = 0.883 vs. 1.000
# Minibatch Loss= 0.460219
# Training: 1600
# AUC = 0.940 vs. 0.296
# F1 = 0.876 vs. 0.438
# Precision = 0.865 vs. 0.281
# Recall = 0.887 vs. 0.997
# Validation: 1600
# AUC = 0.928 vs. 0.290
# F1 = 0.846 vs. 0.445
# Precision = 0.845 vs. 0.286
# Recall = 0.847 vs. 1.000
# Minibatch Loss= 0.437515
# Training: 1700
# AUC = 0.951 vs. 0.283
# F1 = 0.883 vs. 0.440
# Precision = 0.813 vs. 0.284
# Recall = 0.965 vs. 0.975
# Validation: 1700
# AUC = 0.927 vs. 0.287
# F1 = 0.856 vs. 0.445
# Precision = 0.846 vs. 0.286
# Recall = 0.866 vs. 1.000
# Minibatch Loss= 0.418988
# Training: 1800
# AUC = 0.931 vs. 0.299
# F1 = 0.852 vs. 0.460
# Precision = 0.842 vs. 0.298
# Recall = 0.861 vs. 1.000
# Validation: 1800
# AUC = 0.929 vs. 0.283
# F1 = 0.860 vs. 0.445
# Precision = 0.835 vs. 0.286
# Recall = 0.887 vs. 1.000
# Minibatch Loss= 0.520208
# Training: 1900
# AUC = 0.947 vs. 0.280
# F1 = 0.868 vs. 0.434
# Precision = 0.889 vs. 0.277
# Recall = 0.848 vs. 1.000
# Validation: 1900
# AUC = 0.926 vs. 0.285
# F1 = 0.852 vs. 0.445
# Precision = 0.807 vs. 0.286
# Recall = 0.902 vs. 0.999
# Minibatch Loss= 0.411586
# Training: 2000
# AUC = 0.936 vs. 0.291
# F1 = 0.865 vs. 0.443
# Precision = 0.829 vs. 0.285
# Recall = 0.905 vs. 0.996
# Validation: 2000
# AUC = 0.928 vs. 0.285
# F1 = 0.859 vs. 0.445
# Precision = 0.835 vs. 0.286
# Recall = 0.884 vs. 1.000
# Minibatch Loss= 0.471424
# Training: 2100
# AUC = 0.931 vs. 0.251
# F1 = 0.851 vs. 0.413
# Precision = 0.846 vs. 0.261
# Recall = 0.856 vs. 0.989
# Validation: 2100
# AUC = 0.933 vs. 0.284
# F1 = 0.860 vs. 0.445
# Precision = 0.837 vs. 0.286
# Recall = 0.884 vs. 0.998
# Minibatch Loss= 0.408584
# Training: 2200
# AUC = 0.953 vs. 0.285
# F1 = 0.891 vs. 0.425
# Precision = 0.881 vs. 0.270
# Recall = 0.901 vs. 0.997
# Validation: 2200
# AUC = 0.931 vs. 0.292
# F1 = 0.859 vs. 0.445
# Precision = 0.832 vs. 0.286
# Recall = 0.888 vs. 0.998
# Minibatch Loss= 0.402945
# Training: 2300
# AUC = 0.940 vs. 0.288
# F1 = 0.875 vs. 0.432
# Precision = 0.876 vs. 0.275
# Recall = 0.874 vs. 0.999
# Validation: 2300
# AUC = 0.935 vs. 0.289
# F1 = 0.857 vs. 0.445
# Precision = 0.820 vs. 0.286
# Recall = 0.899 vs. 1.000
# Minibatch Loss= 0.462588
# Training: 2400
# AUC = 0.943 vs. 0.285
# F1 = 0.867 vs. 0.438
# Precision = 0.877 vs. 0.281
# Recall = 0.858 vs. 1.000
# Validation: 2400
# AUC = 0.926 vs. 0.287
# F1 = 0.855 vs. 0.445
# Precision = 0.828 vs. 0.286
# Recall = 0.884 vs. 1.000
# Minibatch Loss= 0.460536
# Training: 2500
# AUC = 0.956 vs. 0.303
# F1 = 0.898 vs. 0.453
# Precision = 0.878 vs. 0.293
# Recall = 0.920 vs. 1.000
# Validation: 2500
# AUC = 0.925 vs. 0.291
# F1 = 0.851 vs. 0.445
# Precision = 0.823 vs. 0.286
# Recall = 0.881 vs. 1.000
# Minibatch Loss= 0.419162
# Training: 2600
# AUC = 0.935 vs. 0.266
# F1 = 0.874 vs. 0.420
# Precision = 0.842 vs. 0.266
# Recall = 0.908 vs. 0.997
# Validation: 2600
# AUC = 0.930 vs. 0.285
# F1 = 0.857 vs. 0.445
# Precision = 0.840 vs. 0.286
# Recall = 0.875 vs. 1.000
# Minibatch Loss= 0.377188
# Training: 2700
# AUC = 0.945 vs. 0.307
# F1 = 0.889 vs. 0.448
# Precision = 0.858 vs. 0.289
# Recall = 0.923 vs. 1.000
# Validation: 2700
# AUC = 0.934 vs. 0.288
# F1 = 0.859 vs. 0.445
# Precision = 0.860 vs. 0.286
# Recall = 0.857 vs. 1.000
# Minibatch Loss= 0.443088
# Training: 2800
# AUC = 0.953 vs. 0.269
# F1 = 0.896 vs. 0.426
# Precision = 0.850 vs. 0.272
# Recall = 0.946 vs. 0.984
# Validation: 2800
# AUC = 0.937 vs. 0.287
# F1 = 0.863 vs. 0.445
# Precision = 0.857 vs. 0.286
# Recall = 0.869 vs. 0.999
# Minibatch Loss= 0.384580
# Training: 2900
# AUC = 0.943 vs. 0.314
# F1 = 0.849 vs. 0.457
# Precision = 0.816 vs. 0.297
# Recall = 0.885 vs. 0.996
# Validation: 2900
# AUC = 0.935 vs. 0.284
# F1 = 0.857 vs. 0.445
# Precision = 0.834 vs. 0.286
# Recall = 0.881 vs. 1.000
# Minibatch Loss= 0.475121
# Training: 3000
# AUC = 0.929 vs. 0.277
# F1 = 0.857 vs. 0.429
# Precision = 0.854 vs. 0.273
# Recall = 0.859 vs. 0.999
# Validation: 3000
# AUC = 0.927 vs. 0.291
# F1 = 0.852 vs. 0.445
# Precision = 0.817 vs. 0.286
# Recall = 0.889 vs. 0.998
# Minibatch Loss= 0.432767
# Training: 3100
# AUC = 0.953 vs. 0.302
# F1 = 0.884 vs. 0.461
# Precision = 0.878 vs. 0.300
# Recall = 0.890 vs. 0.992
# Validation: 3100
# AUC = 0.932 vs. 0.289
# F1 = 0.859 vs. 0.445
# Precision = 0.830 vs. 0.286
# Recall = 0.890 vs. 0.999
# Minibatch Loss= 0.448007
# Training: 3200
# AUC = 0.962 vs. 0.276
# F1 = 0.889 vs. 0.431
# Precision = 0.839 vs. 0.275
# Recall = 0.945 vs. 1.000
# Validation: 3200
# AUC = 0.925 vs. 0.289
# F1 = 0.851 vs. 0.445
# Precision = 0.818 vs. 0.286
# Recall = 0.886 vs. 0.998
# Minibatch Loss= 0.403252
# Training: 3300
# AUC = 0.921 vs. 0.282
# F1 = 0.846 vs. 0.437
# Precision = 0.825 vs. 0.282
# Recall = 0.868 vs. 0.969
# Validation: 3300
# AUC = 0.931 vs. 0.284
# F1 = 0.856 vs. 0.445
# Precision = 0.849 vs. 0.286
# Recall = 0.864 vs. 1.000
# Minibatch Loss= 0.470957
# Training: 3400
# AUC = 0.948 vs. 0.258
# F1 = 0.887 vs. 0.427
# Precision = 0.857 vs. 0.273
# Recall = 0.918 vs. 0.981
# Validation: 3400
# AUC = 0.931 vs. 0.290
# F1 = 0.858 vs. 0.445
# Precision = 0.852 vs. 0.286
# Recall = 0.865 vs. 1.000
# Minibatch Loss= 0.392308
# Training: 3500
# AUC = 0.940 vs. 0.281
# F1 = 0.874 vs. 0.437
# Precision = 0.892 vs. 0.281
# Recall = 0.857 vs. 0.983
# Validation: 3500
# AUC = 0.933 vs. 0.282
# F1 = 0.857 vs. 0.445
# Precision = 0.841 vs. 0.286
# Recall = 0.874 vs. 1.000
# Minibatch Loss= 0.439429
# Training: 3600
# AUC = 0.977 vs. 0.298
# F1 = 0.916 vs. 0.462
# Precision = 0.893 vs. 0.301
# Recall = 0.941 vs. 1.000
# Validation: 3600
# AUC = 0.940 vs. 0.289
# F1 = 0.862 vs. 0.445
# Precision = 0.861 vs. 0.286
# Recall = 0.863 vs. 1.000
# Minibatch Loss= 0.399719
# Training: 3700
# AUC = 0.954 vs. 0.279
# F1 = 0.880 vs. 0.444
# Precision = 0.855 vs. 0.286
# Recall = 0.907 vs. 1.000
# Validation: 3700
# AUC = 0.937 vs. 0.288
# F1 = 0.868 vs. 0.445
# Precision = 0.843 vs. 0.286
# Recall = 0.896 vs. 1.000
# Minibatch Loss= 0.436202
# Training: 3800
# AUC = 0.950 vs. 0.279
# F1 = 0.886 vs. 0.431
# Precision = 0.854 vs. 0.276
# Recall = 0.920 vs. 0.983
# Validation: 3800
# AUC = 0.933 vs. 0.282
# F1 = 0.857 vs. 0.445
# Precision = 0.828 vs. 0.286
# Recall = 0.888 vs. 1.000
# Minibatch Loss= 0.428299
# Training: 3900
# AUC = 0.953 vs. 0.285
# F1 = 0.882 vs. 0.439
# Precision = 0.880 vs. 0.282
# Recall = 0.885 vs. 0.986
# Validation: 3900
# AUC = 0.929 vs. 0.291
# F1 = 0.856 vs. 0.445
# Precision = 0.853 vs. 0.286
# Recall = 0.858 vs. 1.000
# Minibatch Loss= 0.407785
# Training: 4000
# AUC = 0.945 vs. 0.272
# F1 = 0.886 vs. 0.432
# Precision = 0.855 vs. 0.275
# Recall = 0.919 vs. 0.999
# Validation: 4000
# AUC = 0.943 vs. 0.288
# F1 = 0.868 vs. 0.445
# Precision = 0.849 vs. 0.286
# Recall = 0.888 vs. 0.998
# Minibatch Loss= 0.446508
# Training: 4100
# AUC = 0.961 vs. 0.292
# F1 = 0.894 vs. 0.444
# Precision = 0.908 vs. 0.285
# Recall = 0.879 vs. 0.997
# Validation: 4100
# AUC = 0.942 vs. 0.293
# F1 = 0.870 vs. 0.445
# Precision = 0.852 vs. 0.286
# Recall = 0.888 vs. 0.999
# Minibatch Loss= 0.408093
# Training: 4200
# AUC = 0.949 vs. 0.289
# F1 = 0.902 vs. 0.452
# Precision = 0.883 vs. 0.292
# Recall = 0.922 vs. 1.000
# Validation: 4200
# AUC = 0.935 vs. 0.287
# F1 = 0.859 vs. 0.445
# Precision = 0.829 vs. 0.286
# Recall = 0.892 vs. 1.000
# Minibatch Loss= 0.399846
# Training: 4300
# AUC = 0.971 vs. 0.316
# F1 = 0.917 vs. 0.469
# Precision = 0.911 vs. 0.306
# Recall = 0.923 vs. 1.000
# Validation: 4300
# AUC = 0.941 vs. 0.286
# F1 = 0.868 vs. 0.445
# Precision = 0.849 vs. 0.286
# Recall = 0.887 vs. 0.998
# Minibatch Loss= 0.412493
# Training: 4400
# AUC = 0.924 vs. 0.293
# F1 = 0.862 vs. 0.439
# Precision = 0.839 vs. 0.282
# Recall = 0.887 vs. 0.997
# Validation: 4400
# AUC = 0.942 vs. 0.289
# F1 = 0.873 vs. 0.445
# Precision = 0.861 vs. 0.286
# Recall = 0.885 vs. 0.999
# Minibatch Loss= 0.466111
# Training: 4500
# AUC = 0.964 vs. 0.274
# F1 = 0.911 vs. 0.426
# Precision = 0.888 vs. 0.271
# Recall = 0.935 vs. 0.993
# Validation: 4500
# AUC = 0.936 vs. 0.286
# F1 = 0.862 vs. 0.445
# Precision = 0.839 vs. 0.287
# Recall = 0.886 vs. 0.995
# Minibatch Loss= 0.368918
# Training: 4600
# AUC = 0.970 vs. 0.268
# F1 = 0.917 vs. 0.447
# Precision = 0.926 vs. 0.287
# Recall = 0.908 vs. 1.000
# Validation: 4600
# AUC = 0.942 vs. 0.287
# F1 = 0.874 vs. 0.445
# Precision = 0.842 vs. 0.286
# Recall = 0.908 vs. 0.999
# Minibatch Loss= 0.380540
# Training: 4700
# AUC = 0.958 vs. 0.267
# F1 = 0.906 vs. 0.435
# Precision = 0.897 vs. 0.278
# Recall = 0.915 vs. 0.999
# Validation: 4700
# AUC = 0.946 vs. 0.283
# F1 = 0.868 vs. 0.445
# Precision = 0.837 vs. 0.286
# Recall = 0.902 vs. 1.000
# Minibatch Loss= 0.386060
# Training: 4800
# AUC = 0.958 vs. 0.259
# F1 = 0.899 vs. 0.414
# Precision = 0.892 vs. 0.261
# Recall = 0.905 vs. 1.000
# Validation: 4800
# AUC = 0.942 vs. 0.283
# F1 = 0.866 vs. 0.445
# Precision = 0.851 vs. 0.286
# Recall = 0.882 vs. 1.000
# Minibatch Loss= 0.374374
# Training: 4900
# AUC = 0.965 vs. 0.255
# F1 = 0.885 vs. 0.418
# Precision = 0.822 vs. 0.265
# Recall = 0.959 vs. 1.000
# Validation: 4900
# AUC = 0.938 vs. 0.287
# F1 = 0.860 vs. 0.445
# Precision = 0.822 vs. 0.286
# Recall = 0.902 vs. 1.000
# Minibatch Loss= 0.326041
# Training: 5000
# AUC = 0.970 vs. 0.261
# F1 = 0.905 vs. 0.409
# Precision = 0.867 vs. 0.257
# Recall = 0.945 vs. 0.998
# Validation: 5000
# AUC = 0.939 vs. 0.288
# F1 = 0.861 vs. 0.445
# Precision = 0.822 vs. 0.286
# Recall = 0.904 vs. 1.000
# Minibatch Loss= 0.326897
# Training: 5100
# AUC = 0.958 vs. 0.284
# F1 = 0.904 vs. 0.448
# Precision = 0.875 vs. 0.288
# Recall = 0.935 vs. 1.000
# Validation: 5100
# AUC = 0.939 vs. 0.284
# F1 = 0.866 vs. 0.445
# Precision = 0.828 vs. 0.286
# Recall = 0.908 vs. 0.999
# Minibatch Loss= 0.428052
# Training: 5200
# AUC = 0.938 vs. 0.275
# F1 = 0.876 vs. 0.423
# Precision = 0.884 vs. 0.268
# Recall = 0.869 vs. 1.000
# Validation: 5200
# AUC = 0.940 vs. 0.288
# F1 = 0.865 vs. 0.445
# Precision = 0.840 vs. 0.286
# Recall = 0.892 vs. 1.000
# Minibatch Loss= 0.407008
# Training: 5300
# AUC = 0.965 vs. 0.297
# F1 = 0.901 vs. 0.465
# Precision = 0.863 vs. 0.303
# Recall = 0.942 vs. 0.997
# Validation: 5300
# AUC = 0.940 vs. 0.284
# F1 = 0.869 vs. 0.445
# Precision = 0.850 vs. 0.286
# Recall = 0.888 vs. 1.000
# Minibatch Loss= 0.410982
# Training: 5400
# AUC = 0.956 vs. 0.299
# F1 = 0.876 vs. 0.457
# Precision = 0.811 vs. 0.297
# Recall = 0.952 vs. 0.999
# Validation: 5400
# AUC = 0.939 vs. 0.284
# F1 = 0.866 vs. 0.445
# Precision = 0.827 vs. 0.286
# Recall = 0.909 vs. 0.998
# Minibatch Loss= 0.437201
# Training: 5500
# AUC = 0.957 vs. 0.287
# F1 = 0.891 vs. 0.450
# Precision = 0.852 vs. 0.290
# Recall = 0.933 vs. 1.000
# Validation: 5500
# AUC = 0.935 vs. 0.283
# F1 = 0.862 vs. 0.445
# Precision = 0.833 vs. 0.286
# Recall = 0.893 vs. 0.997
# Minibatch Loss= 0.437232
# Training: 5600
# AUC = 0.957 vs. 0.284
# F1 = 0.889 vs. 0.441
# Precision = 0.886 vs. 0.283
# Recall = 0.892 vs. 1.000
# Validation: 5600
# AUC = 0.940 vs. 0.288
# F1 = 0.868 vs. 0.445
# Precision = 0.859 vs. 0.286
# Recall = 0.878 vs. 1.000
# Minibatch Loss= 0.398074
# Training: 5700
# AUC = 0.976 vs. 0.251
# F1 = 0.909 vs. 0.418
# Precision = 0.880 vs. 0.264
# Recall = 0.939 vs. 1.000
# Validation: 5700
# AUC = 0.938 vs. 0.291
# F1 = 0.864 vs. 0.445
# Precision = 0.831 vs. 0.286
# Recall = 0.900 vs. 1.000
# Minibatch Loss= 0.340752
# Training: 5800
# AUC = 0.977 vs. 0.295
# F1 = 0.926 vs. 0.456
# Precision = 0.944 vs. 0.297
# Recall = 0.908 vs. 0.981
# Validation: 5800
# AUC = 0.943 vs. 0.287
# F1 = 0.866 vs. 0.445
# Precision = 0.855 vs. 0.286
# Recall = 0.879 vs. 0.999
# Minibatch Loss= 0.348480
# Training: 5900
# AUC = 0.961 vs. 0.314
# F1 = 0.906 vs. 0.476
# Precision = 0.908 vs. 0.314
# Recall = 0.905 vs. 0.985
# Validation: 5900
# AUC = 0.939 vs. 0.286
# F1 = 0.866 vs. 0.445
# Precision = 0.842 vs. 0.286
# Recall = 0.892 vs. 1.000
# Minibatch Loss= 0.460361
# Training: 6000
# AUC = 0.972 vs. 0.287
# F1 = 0.909 vs. 0.456
# Precision = 0.934 vs. 0.297
# Recall = 0.885 vs. 0.988
# Validation: 6000
# AUC = 0.943 vs. 0.288
# F1 = 0.869 vs. 0.445
# Precision = 0.854 vs. 0.286
# Recall = 0.885 vs. 1.000
# Minibatch Loss= 0.378583
# Training: 6100
# AUC = 0.967 vs. 0.284
# F1 = 0.906 vs. 0.452
# Precision = 0.863 vs. 0.292
# Recall = 0.953 vs. 0.997
# Validation: 6100
# AUC = 0.935 vs. 0.285
# F1 = 0.867 vs. 0.445
# Precision = 0.833 vs. 0.286
# Recall = 0.904 vs. 1.000
# Minibatch Loss= 0.404486
# Training: 6200
# AUC = 0.962 vs. 0.297
# F1 = 0.903 vs. 0.466
# Precision = 0.888 vs. 0.303
# Recall = 0.919 vs. 1.000
# Validation: 6200
# AUC = 0.938 vs. 0.286
# F1 = 0.855 vs. 0.445
# Precision = 0.845 vs. 0.286
# Recall = 0.864 vs. 1.000
# Minibatch Loss= 0.422456
# Training: 6300
# AUC = 0.972 vs. 0.269
# F1 = 0.918 vs. 0.428
# Precision = 0.893 vs. 0.272
# Recall = 0.945 vs. 1.000
# Validation: 6300
# AUC = 0.944 vs. 0.288
# F1 = 0.871 vs. 0.445
# Precision = 0.851 vs. 0.286
# Recall = 0.892 vs. 1.000
# Minibatch Loss= 0.360459
# Training: 6400
# AUC = 0.973 vs. 0.292
# F1 = 0.912 vs. 0.463
# Precision = 0.891 vs. 0.302
# Recall = 0.935 vs. 0.999
# Validation: 6400
# AUC = 0.945 vs. 0.288
# F1 = 0.870 vs. 0.445
# Precision = 0.850 vs. 0.286
# Recall = 0.891 vs. 0.998
# Minibatch Loss= 0.391586
# Training: 6500
# AUC = 0.965 vs. 0.260
# F1 = 0.901 vs. 0.417
# Precision = 0.907 vs. 0.263
# Recall = 0.895 vs. 1.000
# Validation: 6500
# AUC = 0.941 vs. 0.289
# F1 = 0.865 vs. 0.445
# Precision = 0.854 vs. 0.286
# Recall = 0.876 vs. 0.999
# Minibatch Loss= 0.401611
# Training: 6600
# AUC = 0.947 vs. 0.278
# F1 = 0.887 vs. 0.452
# Precision = 0.858 vs. 0.292
# Recall = 0.917 vs. 1.000
# Validation: 6600
# AUC = 0.942 vs. 0.285
# F1 = 0.863 vs. 0.445
# Precision = 0.843 vs. 0.286
# Recall = 0.885 vs. 1.000
# Minibatch Loss= 0.458901
# Training: 6700
# AUC = 0.965 vs. 0.289
# F1 = 0.918 vs. 0.451
# Precision = 0.884 vs. 0.292
# Recall = 0.954 vs. 0.987
# Validation: 6700
# AUC = 0.942 vs. 0.290
# F1 = 0.869 vs. 0.445
# Precision = 0.847 vs. 0.286
# Recall = 0.892 vs. 0.998
# Minibatch Loss= 0.390780
# Training: 6800
# AUC = 0.969 vs. 0.283
# F1 = 0.901 vs. 0.434
# Precision = 0.870 vs. 0.277
# Recall = 0.935 vs. 1.000
# Validation: 6800
# AUC = 0.946 vs. 0.282
# F1 = 0.868 vs. 0.445
# Precision = 0.850 vs. 0.286
# Recall = 0.887 vs. 0.998
# Minibatch Loss= 0.377055
# Training: 6900
# AUC = 0.967 vs. 0.276
# F1 = 0.908 vs. 0.432
# Precision = 0.880 vs. 0.276
# Recall = 0.938 vs. 0.999
# Validation: 6900
# AUC = 0.939 vs. 0.286
# F1 = 0.862 vs. 0.445
# Precision = 0.862 vs. 0.286
# Recall = 0.861 vs. 0.999
# Minibatch Loss= 0.400590
# Training: 7000
# AUC = 0.965 vs. 0.278
# F1 = 0.896 vs. 0.427
# Precision = 0.856 vs. 0.271
# Recall = 0.939 vs. 1.000
# Validation: 7000
# AUC = 0.943 vs. 0.282
# F1 = 0.867 vs. 0.445
# Precision = 0.846 vs. 0.286
# Recall = 0.888 vs. 0.999
# Minibatch Loss= 0.384007
# Training: 7100
# AUC = 0.960 vs. 0.298
# F1 = 0.883 vs. 0.440
# Precision = 0.873 vs. 0.282
# Recall = 0.893 vs. 1.000
# Validation: 7100
# AUC = 0.941 vs. 0.284
# F1 = 0.869 vs. 0.445
# Precision = 0.869 vs. 0.286
# Recall = 0.869 vs. 1.000
# Minibatch Loss= 0.422788
# Training: 7200
# AUC = 0.969 vs. 0.299
# F1 = 0.907 vs. 0.453
# Precision = 0.908 vs. 0.293
# Recall = 0.906 vs. 0.993
# Validation: 7200
# AUC = 0.943 vs. 0.290
# F1 = 0.869 vs. 0.445
# Precision = 0.847 vs. 0.286
# Recall = 0.893 vs. 0.999
# Minibatch Loss= 0.388488
# Training: 7300
# AUC = 0.973 vs. 0.276
# F1 = 0.914 vs. 0.441
# Precision = 0.921 vs. 0.283
# Recall = 0.907 vs. 0.994
# Validation: 7300
# AUC = 0.937 vs. 0.291
# F1 = 0.860 vs. 0.445
# Precision = 0.833 vs. 0.286
# Recall = 0.889 vs. 1.000
# Minibatch Loss= 0.362782
# Training: 7400
# AUC = 0.968 vs. 0.303
# F1 = 0.916 vs. 0.460
# Precision = 0.906 vs. 0.298
# Recall = 0.927 vs. 0.999
# Validation: 7400
# AUC = 0.943 vs. 0.286
# F1 = 0.869 vs. 0.445
# Precision = 0.855 vs. 0.286
# Recall = 0.883 vs. 0.999
# Minibatch Loss= 0.400723
# Training: 7500
# AUC = 0.971 vs. 0.280
# F1 = 0.909 vs. 0.443
# Precision = 0.903 vs. 0.285
# Recall = 0.916 vs. 0.999
# Validation: 7500
# AUC = 0.936 vs. 0.283
# F1 = 0.862 vs. 0.445
# Precision = 0.837 vs. 0.286
# Recall = 0.889 vs. 1.000
# Minibatch Loss= 0.385840
# Training: 7600
# AUC = 0.975 vs. 0.282
# F1 = 0.928 vs. 0.441
# Precision = 0.920 vs. 0.283
# Recall = 0.936 vs. 0.996
# Validation: 7600
# AUC = 0.941 vs. 0.287
# F1 = 0.869 vs. 0.445
# Precision = 0.846 vs. 0.286
# Recall = 0.893 vs. 1.000
# Minibatch Loss= 0.381099
# Training: 7700
# AUC = 0.958 vs. 0.289
# F1 = 0.891 vs. 0.447
# Precision = 0.870 vs. 0.288
# Recall = 0.912 vs. 1.000
# Validation: 7700
# AUC = 0.933 vs. 0.287
# F1 = 0.862 vs. 0.445
# Precision = 0.848 vs. 0.286
# Recall = 0.875 vs. 0.999
# Minibatch Loss= 0.421241
# Training: 7800
# AUC = 0.964 vs. 0.294
# F1 = 0.903 vs. 0.445
# Precision = 0.901 vs. 0.287
# Recall = 0.906 vs. 0.999
# Validation: 7800
# AUC = 0.943 vs. 0.288
# F1 = 0.870 vs. 0.445
# Precision = 0.868 vs. 0.286
# Recall = 0.871 vs. 1.000
# Minibatch Loss= 0.397972
# Training: 7900
# AUC = 0.966 vs. 0.297
# F1 = 0.903 vs. 0.460
# Precision = 0.899 vs. 0.299
# Recall = 0.907 vs. 0.999
# Validation: 7900
# AUC = 0.939 vs. 0.289
# F1 = 0.862 vs. 0.445
# Precision = 0.841 vs. 0.286
# Recall = 0.883 vs. 1.000
# Minibatch Loss= 0.420940
# Training: 8000
# AUC = 0.973 vs. 0.268
# F1 = 0.920 vs. 0.431
# Precision = 0.924 vs. 0.276
# Recall = 0.917 vs. 0.983
# Validation: 8000
# AUC = 0.947 vs. 0.285
# F1 = 0.876 vs. 0.445
# Precision = 0.867 vs. 0.286
# Recall = 0.885 vs. 1.000
# Minibatch Loss= 0.376557
# Training: 8100
# AUC = 0.976 vs. 0.309
# F1 = 0.928 vs. 0.450
# Precision = 0.929 vs. 0.297
# Recall = 0.927 vs. 0.930
# Validation: 8100
# AUC = 0.942 vs. 0.282
# F1 = 0.871 vs. 0.445
# Precision = 0.840 vs. 0.286
# Recall = 0.904 vs. 1.000
# Minibatch Loss= 0.375581
# Training: 8200
# AUC = 0.979 vs. 0.282
# F1 = 0.918 vs. 0.444
# Precision = 0.925 vs. 0.285
# Recall = 0.912 vs. 0.996
# Validation: 8200
# AUC = 0.938 vs. 0.283
# F1 = 0.869 vs. 0.445
# Precision = 0.836 vs. 0.286
# Recall = 0.905 vs. 1.000
# Minibatch Loss= 0.345485
# Training: 8300
# AUC = 0.984 vs. 0.293
# F1 = 0.934 vs. 0.452
# Precision = 0.935 vs. 0.292
# Recall = 0.932 vs. 1.000
# Validation: 8300
# AUC = 0.936 vs. 0.289
# F1 = 0.864 vs. 0.445
# Precision = 0.857 vs. 0.286
# Recall = 0.871 vs. 1.000
# Minibatch Loss= 0.340872
# Training: 8400
# AUC = 0.967 vs. 0.267
# F1 = 0.902 vs. 0.433
# Precision = 0.928 vs. 0.277
# Recall = 0.877 vs. 1.000
# Validation: 8400
# AUC = 0.938 vs. 0.286
# F1 = 0.860 vs. 0.445
# Precision = 0.850 vs. 0.286
# Recall = 0.871 vs. 1.000
# Minibatch Loss= 0.379406
# Training: 8500
# AUC = 0.972 vs. 0.261
# F1 = 0.906 vs. 0.428
# Precision = 0.930 vs. 0.272
# Recall = 0.883 vs. 0.997
# Validation: 8500
# AUC = 0.939 vs. 0.289
# F1 = 0.863 vs. 0.445
# Precision = 0.838 vs. 0.286
# Recall = 0.888 vs. 0.999
# Minibatch Loss= 0.371416
# Training: 8600
# AUC = 0.979 vs. 0.292
# F1 = 0.921 vs. 0.448
# Precision = 0.912 vs. 0.289
# Recall = 0.930 vs. 1.000
# Validation: 8600
# AUC = 0.944 vs. 0.285
# F1 = 0.868 vs. 0.445
# Precision = 0.844 vs. 0.286
# Recall = 0.894 vs. 0.998
# Minibatch Loss= 0.382520
# Training: 8700
# AUC = 0.970 vs. 0.283
# F1 = 0.895 vs. 0.447
# Precision = 0.842 vs. 0.287
# Recall = 0.955 vs. 1.000
# Validation: 8700
# AUC = 0.941 vs. 0.289
# F1 = 0.864 vs. 0.445
# Precision = 0.847 vs. 0.286
# Recall = 0.882 vs. 0.998
# Minibatch Loss= 0.408824
# Training: 8800
# AUC = 0.980 vs. 0.284
# F1 = 0.931 vs. 0.440
# Precision = 0.926 vs. 0.282
# Recall = 0.936 vs. 0.999
# Validation: 8800
# AUC = 0.933 vs. 0.286
# F1 = 0.859 vs. 0.445
# Precision = 0.839 vs. 0.286
# Recall = 0.881 vs. 1.000
# Minibatch Loss= 0.349182
# Training: 8900
# AUC = 0.979 vs. 0.294
# F1 = 0.924 vs. 0.454
# Precision = 0.898 vs. 0.294
# Recall = 0.950 vs. 0.991
# Validation: 8900
# AUC = 0.942 vs. 0.283
# F1 = 0.868 vs. 0.445
# Precision = 0.861 vs. 0.286
# Recall = 0.874 vs. 1.000
# Minibatch Loss= 0.407542
# Training: 9000
# AUC = 0.978 vs. 0.276
# F1 = 0.917 vs. 0.429
# Precision = 0.872 vs. 0.274
# Recall = 0.967 vs. 0.997
# Validation: 9000
# AUC = 0.940 vs. 0.289
# F1 = 0.863 vs. 0.445
# Precision = 0.851 vs. 0.286
# Recall = 0.876 vs. 0.999
# Minibatch Loss= 0.352300
# Training: 9100
# AUC = 0.980 vs. 0.266
# F1 = 0.927 vs. 0.428
# Precision = 0.947 vs. 0.276
# Recall = 0.907 vs. 0.958
# Validation: 9100
# AUC = 0.938 vs. 0.289
# F1 = 0.859 vs. 0.445
# Precision = 0.850 vs. 0.286
# Recall = 0.868 vs. 0.999
# Minibatch Loss= 0.341837
# Training: 9200
# AUC = 0.980 vs. 0.321
# F1 = 0.931 vs. 0.462
# Precision = 0.918 vs. 0.302
# Recall = 0.944 vs. 0.990
# Validation: 9200
# AUC = 0.938 vs. 0.284
# F1 = 0.864 vs. 0.445
# Precision = 0.834 vs. 0.286
# Recall = 0.897 vs. 1.000
# Minibatch Loss= 0.366031
# Training: 9300
# AUC = 0.977 vs. 0.274
# F1 = 0.933 vs. 0.430
# Precision = 0.927 vs. 0.274
# Recall = 0.939 vs. 1.000
# Validation: 9300
# AUC = 0.940 vs. 0.281
# F1 = 0.864 vs. 0.445
# Precision = 0.857 vs. 0.286
# Recall = 0.872 vs. 0.999
# Minibatch Loss= 0.330217
# Training: 9400
# AUC = 0.978 vs. 0.264
# F1 = 0.927 vs. 0.427
# Precision = 0.947 vs. 0.272
# Recall = 0.908 vs. 0.997
# Validation: 9400
# AUC = 0.940 vs. 0.286
# F1 = 0.863 vs. 0.445
# Precision = 0.850 vs. 0.286
# Recall = 0.875 vs. 0.997
# Minibatch Loss= 0.363466
# Training: 9500
# AUC = 0.972 vs. 0.288
# F1 = 0.916 vs. 0.439
# Precision = 0.896 vs. 0.282
# Recall = 0.936 vs. 0.997
# Validation: 9500
# AUC = 0.940 vs. 0.286
# F1 = 0.868 vs. 0.445
# Precision = 0.839 vs. 0.286
# Recall = 0.899 vs. 1.000
# Minibatch Loss= 0.379699
# Training: 9600
# AUC = 0.973 vs. 0.310
# F1 = 0.923 vs. 0.451
# Precision = 0.935 vs. 0.291
# Recall = 0.911 vs. 1.000
# Validation: 9600
# AUC = 0.942 vs. 0.282
# F1 = 0.866 vs. 0.445
# Precision = 0.838 vs. 0.286
# Recall = 0.896 vs. 1.000
# Minibatch Loss= 0.388485
# Training: 9700
# AUC = 0.974 vs. 0.273
# F1 = 0.923 vs. 0.431
# Precision = 0.934 vs. 0.275
# Recall = 0.912 vs. 0.994
# Validation: 9700
# AUC = 0.939 vs. 0.279
# F1 = 0.867 vs. 0.445
# Precision = 0.855 vs. 0.286
# Recall = 0.879 vs. 1.000
# Minibatch Loss= 0.352023
# Training: 9800
# AUC = 0.973 vs. 0.299
# F1 = 0.913 vs. 0.451
# Precision = 0.927 vs. 0.291
# Recall = 0.899 vs. 1.000
# Validation: 9800
# AUC = 0.939 vs. 0.284
# F1 = 0.861 vs. 0.445
# Precision = 0.856 vs. 0.286
# Recall = 0.865 vs. 1.000
# Minibatch Loss= 0.378716
# Training: 9900
# AUC = 0.974 vs. 0.306
# F1 = 0.918 vs. 0.430
# Precision = 0.894 vs. 0.275
# Recall = 0.944 vs. 0.990
# Validation: 9900
# AUC = 0.942 vs. 0.285
# F1 = 0.864 vs. 0.445
# Precision = 0.836 vs. 0.286
# Recall = 0.892 vs. 0.996
# Minibatch Loss= 0.370150
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model_synthetic/train_gradual_test_abrupt/DWN1001_z/DWN1001_z-10000'

# %%
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-10000')
# Out:
# INFO:tensorflow:Restoring parameters from ../../model_synthetic/train_gradual_test_abrupt/DWN1001_z/DWN1001_z-10000

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data[:], test_gt[:])
# Out:
# AUC = 0.811 vs. 0.074
# F1 = 0.765 vs. 0.137
# Precision = 0.708 vs. 0.073
# Recall = 0.833 vs. 1.000

# %%
out = nn_eval.deploy(model, sess, test_data[:], test_gt[:])

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (1000, 256)

# %%
savemat('../../poc_synthetic/train_gradual_test_abrupt/poc'+exp_name+'.mat', {'poc':out})
