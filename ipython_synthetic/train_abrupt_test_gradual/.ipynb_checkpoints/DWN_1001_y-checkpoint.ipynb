# %%
# useing this variable for saving models and summaries
exp_name = "DWN1001_y"

# %% [markdown]
# # Neural wavelet network
# 6levels wavelet then 5 layers CNN [2, 2, 2, 2, 2]

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed3.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape, validation_data.shape, test_data.shape, train_gt.shape, validation_gt.shape, test_gt.shape, index_of_changes.shape
# Out:
# ((900, 8192, 12),
#  (100, 8192, 12),
#  (1000, 8192, 12),
#  (900, 8192, 1),
#  (100, 8192, 1),
#  (1000, 8192, 1),
#  (1000, 4))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10


wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]    #stride of pooling in convolution
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
granularity = np.prod(pooling_stride)
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 4.442850052

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet=True,
                                 trainable_conv=True,
                                 trainable_last = True)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size)

# %%
trainer.train(max_iter = 1200,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.102 vs. 0.144
# F1 = 0.246 vs. 0.242
# Precision = 0.142 vs. 0.138
# Recall = 0.923 vs. 0.994
# Validation: 0
# AUC = 0.157 vs. 0.179
# F1 = 0.307 vs. 0.300
# Precision = 0.184 vs. 0.177
# Recall = 0.921 vs. 1.000
# Minibatch Loss= 1.022623
# Training: 100
# AUC = 0.526 vs. 0.157
# F1 = 0.603 vs. 0.268
# Precision = 0.618 vs. 0.157
# Recall = 0.588 vs. 0.923
# Validation: 100
# AUC = 0.564 vs. 0.177
# F1 = 0.562 vs. 0.300
# Precision = 0.540 vs. 0.177
# Recall = 0.586 vs. 1.000
# Minibatch Loss= 0.804934
# Training: 200
# AUC = 0.787 vs. 0.222
# F1 = 0.745 vs. 0.365
# Precision = 0.740 vs. 0.224
# Recall = 0.750 vs. 0.989
# Validation: 200
# AUC = 0.725 vs. 0.179
# F1 = 0.675 vs. 0.300
# Precision = 0.653 vs. 0.177
# Recall = 0.698 vs. 0.996
# Minibatch Loss= 0.773006
# Training: 300
# AUC = 0.793 vs. 0.149
# F1 = 0.759 vs. 0.239
# Precision = 0.676 vs. 0.135
# Recall = 0.864 vs. 0.997
# Validation: 300
# AUC = 0.806 vs. 0.178
# F1 = 0.733 vs. 0.300
# Precision = 0.708 vs. 0.177
# Recall = 0.760 vs. 0.998
# Minibatch Loss= 0.533609
# Training: 400
# AUC = 0.822 vs. 0.191
# F1 = 0.746 vs. 0.322
# Precision = 0.656 vs. 0.192
# Recall = 0.865 vs. 0.996
# Validation: 400
# AUC = 0.834 vs. 0.176
# F1 = 0.757 vs. 0.300
# Precision = 0.716 vs. 0.177
# Recall = 0.804 vs. 1.000
# Minibatch Loss= 0.686378
# Training: 500
# AUC = 0.875 vs. 0.194
# F1 = 0.796 vs. 0.321
# Precision = 0.793 vs. 0.191
# Recall = 0.799 vs. 1.000
# Validation: 500
# AUC = 0.865 vs. 0.178
# F1 = 0.790 vs. 0.300
# Precision = 0.743 vs. 0.177
# Recall = 0.844 vs. 1.000
# Minibatch Loss= 0.553771
# Training: 600
# AUC = 0.908 vs. 0.188
# F1 = 0.845 vs. 0.316
# Precision = 0.797 vs. 0.187
# Recall = 0.900 vs. 1.000
# Validation: 600
# AUC = 0.860 vs. 0.178
# F1 = 0.794 vs. 0.300
# Precision = 0.789 vs. 0.177
# Recall = 0.798 vs. 1.000
# Minibatch Loss= 0.430014
# Training: 700
# AUC = 0.918 vs. 0.195
# F1 = 0.849 vs. 0.335
# Precision = 0.769 vs. 0.202
# Recall = 0.947 vs. 0.980
# Validation: 700
# AUC = 0.892 vs. 0.177
# F1 = 0.829 vs. 0.300
# Precision = 0.819 vs. 0.177
# Recall = 0.838 vs. 1.000
# Minibatch Loss= 0.478515
# Training: 800
# AUC = 0.889 vs. 0.227
# F1 = 0.790 vs. 0.362
# Precision = 0.772 vs. 0.221
# Recall = 0.808 vs. 0.989
# Validation: 800
# AUC = 0.881 vs. 0.175
# F1 = 0.813 vs. 0.300
# Precision = 0.775 vs. 0.177
# Recall = 0.855 vs. 0.999
# Minibatch Loss= 0.619127
# Training: 900
# AUC = 0.877 vs. 0.137
# F1 = 0.825 vs. 0.244
# Precision = 0.774 vs. 0.140
# Recall = 0.884 vs. 0.938
# Validation: 900
# AUC = 0.866 vs. 0.177
# F1 = 0.794 vs. 0.300
# Precision = 0.802 vs. 0.177
# Recall = 0.787 vs. 0.998
# Minibatch Loss= 0.394453
# Training: 1000
# AUC = 0.930 vs. 0.237
# F1 = 0.844 vs. 0.380
# Precision = 0.824 vs. 0.235
# Recall = 0.866 vs. 0.985
# Validation: 1000
# AUC = 0.905 vs. 0.180
# F1 = 0.829 vs. 0.300
# Precision = 0.800 vs. 0.177
# Recall = 0.860 vs. 1.000
# Minibatch Loss= 0.492096
# Training: 1100
# AUC = 0.867 vs. 0.187
# F1 = 0.778 vs. 0.317
# Precision = 0.844 vs. 0.189
# Recall = 0.722 vs. 0.979
# Validation: 1100
# AUC = 0.893 vs. 0.172
# F1 = 0.825 vs. 0.300
# Precision = 0.799 vs. 0.177
# Recall = 0.853 vs. 1.000
# Minibatch Loss= 0.541979
#  Optimization Finished!

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 1200
# AUC = 0.909 vs. 0.132
# F1 = 0.845 vs. 0.237
# Precision = 0.831 vs. 0.135
# Recall = 0.860 vs. 0.991
# Validation: 1200
# AUC = 0.912 vs. 0.175
# F1 = 0.836 vs. 0.301
# Precision = 0.810 vs. 0.177
# Recall = 0.863 vs. 0.998
# Minibatch Loss= 0.322581
# Training: 1300
# AUC = 0.894 vs. 0.188
# F1 = 0.831 vs. 0.299
# Precision = 0.822 vs. 0.176
# Recall = 0.840 vs. 1.000
# Validation: 1300
# AUC = 0.904 vs. 0.179
# F1 = 0.832 vs. 0.300
# Precision = 0.803 vs. 0.177
# Recall = 0.863 vs. 1.000
# Minibatch Loss= 0.449739
# Training: 1400
# AUC = 0.957 vs. 0.158
# F1 = 0.888 vs. 0.272
# Precision = 0.890 vs. 0.158
# Recall = 0.886 vs. 1.000
# Validation: 1400
# AUC = 0.911 vs. 0.175
# F1 = 0.838 vs. 0.300
# Precision = 0.816 vs. 0.177
# Recall = 0.862 vs. 1.000
# Minibatch Loss= 0.361634
# Training: 1500
# AUC = 0.906 vs. 0.143
# F1 = 0.840 vs. 0.232
# Precision = 0.811 vs. 0.133
# Recall = 0.870 vs. 0.894
# Validation: 1500
# AUC = 0.911 vs. 0.177
# F1 = 0.844 vs. 0.300
# Precision = 0.819 vs. 0.177
# Recall = 0.870 vs. 1.000
# Minibatch Loss= 0.311333
# Training: 1600
# AUC = 0.941 vs. 0.156
# F1 = 0.866 vs. 0.246
# Precision = 0.859 vs. 0.140
# Recall = 0.874 vs. 0.997
# Validation: 1600
# AUC = 0.915 vs. 0.174
# F1 = 0.836 vs. 0.300
# Precision = 0.820 vs. 0.177
# Recall = 0.853 vs. 1.000
# Minibatch Loss= 0.281825
# Training: 1700
# AUC = 0.938 vs. 0.188
# F1 = 0.862 vs. 0.295
# Precision = 0.874 vs. 0.173
# Recall = 0.850 vs. 0.998
# Validation: 1700
# AUC = 0.902 vs. 0.179
# F1 = 0.826 vs. 0.301
# Precision = 0.812 vs. 0.177
# Recall = 0.840 vs. 0.999
# Minibatch Loss= 0.341775
# Training: 1800
# AUC = 0.895 vs. 0.157
# F1 = 0.855 vs. 0.270
# Precision = 0.809 vs. 0.159
# Recall = 0.907 vs. 0.892
# Validation: 1800
# AUC = 0.909 vs. 0.175
# F1 = 0.831 vs. 0.300
# Precision = 0.788 vs. 0.177
# Recall = 0.878 vs. 0.999
# Minibatch Loss= 0.446766
# Training: 1900
# AUC = 0.947 vs. 0.176
# F1 = 0.878 vs. 0.291
# Precision = 0.882 vs. 0.170
# Recall = 0.874 vs. 1.000
# Validation: 1900
# AUC = 0.931 vs. 0.180
# F1 = 0.853 vs. 0.300
# Precision = 0.814 vs. 0.177
# Recall = 0.895 vs. 0.998
# Minibatch Loss= 0.351265
# Training: 2000
# AUC = 0.935 vs. 0.175
# F1 = 0.851 vs. 0.283
# Precision = 0.805 vs. 0.165
# Recall = 0.903 vs. 1.000
# Validation: 2000
# AUC = 0.923 vs. 0.175
# F1 = 0.843 vs. 0.300
# Precision = 0.800 vs. 0.177
# Recall = 0.891 vs. 1.000
# Minibatch Loss= 0.395166
# Training: 2100
# AUC = 0.818 vs. 0.143
# F1 = 0.736 vs. 0.243
# Precision = 0.655 vs. 0.143
# Recall = 0.841 vs. 0.797
# Validation: 2100
# AUC = 0.913 vs. 0.172
# F1 = 0.836 vs. 0.300
# Precision = 0.814 vs. 0.177
# Recall = 0.858 vs. 0.996
# Minibatch Loss= 0.427733
# Training: 2200
# AUC = 0.953 vs. 0.235
# F1 = 0.898 vs. 0.379
# Precision = 0.881 vs. 0.234
# Recall = 0.916 vs. 1.000
# Validation: 2200
# AUC = 0.923 vs. 0.175
# F1 = 0.839 vs. 0.300
# Precision = 0.798 vs. 0.177
# Recall = 0.884 vs. 1.000
# Minibatch Loss= 0.461261
# Training: 2300
# AUC = 0.935 vs. 0.239
# F1 = 0.859 vs. 0.370
# Precision = 0.792 vs. 0.227
# Recall = 0.938 vs. 1.000
# Validation: 2300
# AUC = 0.921 vs. 0.180
# F1 = 0.839 vs. 0.300
# Precision = 0.821 vs. 0.177
# Recall = 0.857 vs. 1.000
# Minibatch Loss= 0.485744
# Training: 2400
# AUC = 0.900 vs. 0.150
# F1 = 0.828 vs. 0.266
# Precision = 0.774 vs. 0.154
# Recall = 0.891 vs. 1.000
# Validation: 2400
# AUC = 0.918 vs. 0.180
# F1 = 0.849 vs. 0.300
# Precision = 0.824 vs. 0.177
# Recall = 0.876 vs. 0.993
# Minibatch Loss= 0.358922
# Training: 2500
# AUC = 0.928 vs. 0.168
# F1 = 0.852 vs. 0.278
# Precision = 0.841 vs. 0.168
# Recall = 0.863 vs. 0.817
# Validation: 2500
# AUC = 0.931 vs. 0.184
# F1 = 0.853 vs. 0.300
# Precision = 0.849 vs. 0.177
# Recall = 0.858 vs. 0.999
# Minibatch Loss= 0.338278
# Training: 2600
# AUC = 0.880 vs. 0.171
# F1 = 0.806 vs. 0.309
# Precision = 0.762 vs. 0.183
# Recall = 0.856 vs. 0.998
# Validation: 2600
# AUC = 0.917 vs. 0.176
# F1 = 0.846 vs. 0.300
# Precision = 0.820 vs. 0.177
# Recall = 0.873 vs. 0.992
# Minibatch Loss= 0.507302
# Training: 2700
# AUC = 0.922 vs. 0.157
# F1 = 0.871 vs. 0.256
# Precision = 0.865 vs. 0.151
# Recall = 0.877 vs. 0.832
# Validation: 2700
# AUC = 0.925 vs. 0.176
# F1 = 0.847 vs. 0.300
# Precision = 0.857 vs. 0.177
# Recall = 0.837 vs. 1.000
# Minibatch Loss= 0.315756
# Training: 2800
# AUC = 0.899 vs. 0.172
# F1 = 0.839 vs. 0.293
# Precision = 0.863 vs. 0.172
# Recall = 0.817 vs. 0.998
# Validation: 2800
# AUC = 0.927 vs. 0.175
# F1 = 0.848 vs. 0.300
# Precision = 0.823 vs. 0.177
# Recall = 0.873 vs. 1.000
# Minibatch Loss= 0.418984
# Training: 2900
# AUC = 0.962 vs. 0.256
# F1 = 0.903 vs. 0.408
# Precision = 0.867 vs. 0.257
# Recall = 0.942 vs. 0.982
# Validation: 2900
# AUC = 0.931 vs. 0.179
# F1 = 0.853 vs. 0.301
# Precision = 0.852 vs. 0.177
# Recall = 0.854 vs. 0.998
# Minibatch Loss= 0.448736
# Training: 3000
# AUC = 0.928 vs. 0.163
# F1 = 0.849 vs. 0.281
# Precision = 0.851 vs. 0.164
# Recall = 0.847 vs. 0.968
# Validation: 3000
# AUC = 0.919 vs. 0.179
# F1 = 0.844 vs. 0.300
# Precision = 0.815 vs. 0.177
# Recall = 0.875 vs. 0.990
# Minibatch Loss= 0.355213
# Training: 3100
# AUC = 0.956 vs. 0.199
# F1 = 0.887 vs. 0.336
# Precision = 0.845 vs. 0.203
# Recall = 0.933 vs. 0.986
# Validation: 3100
# AUC = 0.921 vs. 0.174
# F1 = 0.845 vs. 0.300
# Precision = 0.837 vs. 0.177
# Recall = 0.853 vs. 1.000
# Minibatch Loss= 0.444877
# Training: 3200
# AUC = 0.899 vs. 0.121
# F1 = 0.845 vs. 0.218
# Precision = 0.810 vs. 0.126
# Recall = 0.884 vs. 0.792
# Validation: 3200
# AUC = 0.938 vs. 0.174
# F1 = 0.856 vs. 0.300
# Precision = 0.817 vs. 0.177
# Recall = 0.899 vs. 0.996
# Minibatch Loss= 0.304975
# Training: 3300
# AUC = 0.959 vs. 0.172
# F1 = 0.894 vs. 0.294
# Precision = 0.864 vs. 0.176
# Recall = 0.927 vs. 0.913
# Validation: 3300
# AUC = 0.929 vs. 0.178
# F1 = 0.849 vs. 0.301
# Precision = 0.836 vs. 0.177
# Recall = 0.863 vs. 0.992
# Minibatch Loss= 0.327096
# Training: 3400
# AUC = 0.898 vs. 0.157
# F1 = 0.817 vs. 0.275
# Precision = 0.873 vs. 0.160
# Recall = 0.769 vs. 0.973
# Validation: 3400
# AUC = 0.928 vs. 0.173
# F1 = 0.847 vs. 0.300
# Precision = 0.831 vs. 0.177
# Recall = 0.864 vs. 1.000
# Minibatch Loss= 0.410852
# Training: 3500
# AUC = 0.917 vs. 0.117
# F1 = 0.863 vs. 0.225
# Precision = 0.831 vs. 0.127
# Recall = 0.898 vs. 0.994
# Validation: 3500
# AUC = 0.939 vs. 0.179
# F1 = 0.869 vs. 0.300
# Precision = 0.857 vs. 0.177
# Recall = 0.881 vs. 0.996
# Minibatch Loss= 0.315640
# Training: 3600
# AUC = 0.925 vs. 0.204
# F1 = 0.851 vs. 0.325
# Precision = 0.851 vs. 0.195
# Recall = 0.851 vs. 0.982
# Validation: 3600
# AUC = 0.936 vs. 0.175
# F1 = 0.860 vs. 0.300
# Precision = 0.834 vs. 0.177
# Recall = 0.889 vs. 0.990
# Minibatch Loss= 0.423467
# Training: 3700
# AUC = 0.922 vs. 0.180
# F1 = 0.870 vs. 0.307
# Precision = 0.835 vs. 0.182
# Recall = 0.909 vs. 0.972
# Validation: 3700
# AUC = 0.936 vs. 0.180
# F1 = 0.855 vs. 0.300
# Precision = 0.814 vs. 0.177
# Recall = 0.900 vs. 0.993
# Minibatch Loss= 0.428880
# Training: 3800
# AUC = 0.927 vs. 0.115
# F1 = 0.849 vs. 0.206
# Precision = 0.839 vs. 0.115
# Recall = 0.860 vs. 0.986
# Validation: 3800
# AUC = 0.930 vs. 0.176
# F1 = 0.848 vs. 0.300
# Precision = 0.818 vs. 0.177
# Recall = 0.880 vs. 1.000
# Minibatch Loss= 0.254812
# Training: 3900
# AUC = 0.943 vs. 0.184
# F1 = 0.880 vs. 0.298
# Precision = 0.820 vs. 0.175
# Recall = 0.949 vs. 1.000
# Validation: 3900
# AUC = 0.934 vs. 0.176
# F1 = 0.853 vs. 0.301
# Precision = 0.844 vs. 0.178
# Recall = 0.863 vs. 0.980
# Minibatch Loss= 0.346752
# Training: 4000
# AUC = 0.943 vs. 0.224
# F1 = 0.873 vs. 0.364
# Precision = 0.915 vs. 0.222
# Recall = 0.835 vs. 1.000
# Validation: 4000
# AUC = 0.945 vs. 0.177
# F1 = 0.865 vs. 0.300
# Precision = 0.859 vs. 0.178
# Recall = 0.870 vs. 0.975
# Minibatch Loss= 0.424008
# Training: 4100
# AUC = 0.899 vs. 0.185
# F1 = 0.802 vs. 0.288
# Precision = 0.844 vs. 0.168
# Recall = 0.765 vs. 1.000
# Validation: 4100
# AUC = 0.933 vs. 0.175
# F1 = 0.859 vs. 0.300
# Precision = 0.830 vs. 0.177
# Recall = 0.889 vs. 1.000
# Minibatch Loss= 0.432186
# Training: 4200
# AUC = 0.922 vs. 0.273
# F1 = 0.859 vs. 0.436
# Precision = 0.831 vs. 0.280
# Recall = 0.889 vs. 0.986
# Validation: 4200
# AUC = 0.937 vs. 0.171
# F1 = 0.863 vs. 0.300
# Precision = 0.847 vs. 0.177
# Recall = 0.881 vs. 1.000
# Minibatch Loss= 0.599087
# Training: 4300
# AUC = 0.913 vs. 0.186
# F1 = 0.833 vs. 0.309
# Precision = 0.788 vs. 0.183
# Recall = 0.884 vs. 1.000
# Validation: 4300
# AUC = 0.932 vs. 0.177
# F1 = 0.855 vs. 0.300
# Precision = 0.817 vs. 0.177
# Recall = 0.895 vs. 0.998
# Minibatch Loss= 0.428158
# Training: 4400
# AUC = 0.934 vs. 0.184
# F1 = 0.856 vs. 0.308
# Precision = 0.838 vs. 0.182
# Recall = 0.874 vs. 0.987
# Validation: 4400
# AUC = 0.923 vs. 0.181
# F1 = 0.844 vs. 0.301
# Precision = 0.855 vs. 0.177
# Recall = 0.833 vs. 0.998
# Minibatch Loss= 0.392296
# Training: 4500
# AUC = 0.927 vs. 0.199
# F1 = 0.853 vs. 0.335
# Precision = 0.884 vs. 0.201
# Recall = 0.825 vs. 0.998
# Validation: 4500
# AUC = 0.941 vs. 0.179
# F1 = 0.864 vs. 0.300
# Precision = 0.835 vs. 0.177
# Recall = 0.894 vs. 1.000
# Minibatch Loss= 0.451373
# Training: 4600
# AUC = 0.946 vs. 0.181
# F1 = 0.873 vs. 0.308
# Precision = 0.816 vs. 0.184
# Recall = 0.939 vs. 0.943
# Validation: 4600
# AUC = 0.925 vs. 0.179
# F1 = 0.853 vs. 0.301
# Precision = 0.846 vs. 0.178
# Recall = 0.860 vs. 0.982
# Minibatch Loss= 0.414971
# Training: 4700
# AUC = 0.973 vs. 0.195
# F1 = 0.911 vs. 0.337
# Precision = 0.879 vs. 0.204
# Recall = 0.946 vs. 0.967
# Validation: 4700
# AUC = 0.936 vs. 0.173
# F1 = 0.852 vs. 0.300
# Precision = 0.836 vs. 0.177
# Recall = 0.869 vs. 0.999
# Minibatch Loss= 0.354874
# Training: 4800
# AUC = 0.957 vs. 0.189
# F1 = 0.898 vs. 0.315
# Precision = 0.886 vs. 0.187
# Recall = 0.910 vs. 1.000
# Validation: 4800
# AUC = 0.933 vs. 0.174
# F1 = 0.861 vs. 0.300
# Precision = 0.855 vs. 0.177
# Recall = 0.868 vs. 1.000
# Minibatch Loss= 0.373020
# Training: 4900
# AUC = 0.958 vs. 0.174
# F1 = 0.890 vs. 0.305
# Precision = 0.884 vs. 0.181
# Recall = 0.895 vs. 0.976
# Validation: 4900
# AUC = 0.935 vs. 0.181
# F1 = 0.859 vs. 0.300
# Precision = 0.856 vs. 0.177
# Recall = 0.862 vs. 0.997
# Minibatch Loss= 0.317236
# Training: 5000
# AUC = 0.923 vs. 0.189
# F1 = 0.853 vs. 0.321
# Precision = 0.815 vs. 0.191
# Recall = 0.895 vs. 0.996
# Validation: 5000
# AUC = 0.943 vs. 0.177
# F1 = 0.862 vs. 0.300
# Precision = 0.868 vs. 0.177
# Recall = 0.856 vs. 1.000
# Minibatch Loss= 0.463623
# Training: 5100
# AUC = 0.921 vs. 0.161
# F1 = 0.832 vs. 0.267
# Precision = 0.882 vs. 0.156
# Recall = 0.787 vs. 0.921
# Validation: 5100
# AUC = 0.941 vs. 0.176
# F1 = 0.866 vs. 0.300
# Precision = 0.835 vs. 0.177
# Recall = 0.898 vs. 0.998
# Minibatch Loss= 0.392611
# Training: 5200
# AUC = 0.944 vs. 0.173
# F1 = 0.880 vs. 0.307
# Precision = 0.823 vs. 0.181
# Recall = 0.946 vs. 0.996
# Validation: 5200
# AUC = 0.938 vs. 0.179
# F1 = 0.868 vs. 0.300
# Precision = 0.853 vs. 0.177
# Recall = 0.883 vs. 1.000
# Minibatch Loss= 0.366479
# Training: 5300
# AUC = 0.942 vs. 0.128
# F1 = 0.874 vs. 0.228
# Precision = 0.884 vs. 0.131
# Recall = 0.865 vs. 0.883
# Validation: 5300
# AUC = 0.942 vs. 0.176
# F1 = 0.862 vs. 0.300
# Precision = 0.843 vs. 0.177
# Recall = 0.883 vs. 0.998
# Minibatch Loss= 0.287137
# Training: 5400
# AUC = 0.956 vs. 0.156
# F1 = 0.891 vs. 0.271
# Precision = 0.892 vs. 0.157
# Recall = 0.890 vs. 1.000
# Validation: 5400
# AUC = 0.941 vs. 0.176
# F1 = 0.856 vs. 0.300
# Precision = 0.838 vs. 0.177
# Recall = 0.875 vs. 0.999
# Minibatch Loss= 0.320485
# Training: 5500
# AUC = 0.956 vs. 0.156
# F1 = 0.883 vs. 0.270
# Precision = 0.877 vs. 0.156
# Recall = 0.890 vs. 1.000
# Validation: 5500
# AUC = 0.943 vs. 0.176
# F1 = 0.864 vs. 0.300
# Precision = 0.851 vs. 0.177
# Recall = 0.878 vs. 1.000
# Minibatch Loss= 0.307431
# Training: 5600
# AUC = 0.917 vs. 0.167
# F1 = 0.844 vs. 0.283
# Precision = 0.774 vs. 0.165
# Recall = 0.929 vs. 1.000
# Validation: 5600
# AUC = 0.941 vs. 0.177
# F1 = 0.864 vs. 0.300
# Precision = 0.868 vs. 0.177
# Recall = 0.859 vs. 0.998
# Minibatch Loss= 0.403814
# Training: 5700
# AUC = 0.935 vs. 0.150
# F1 = 0.876 vs. 0.263
# Precision = 0.831 vs. 0.152
# Recall = 0.927 vs. 0.963
# Validation: 5700
# AUC = 0.939 vs. 0.178
# F1 = 0.857 vs. 0.300
# Precision = 0.842 vs. 0.177
# Recall = 0.872 vs. 0.997
# Minibatch Loss= 0.288961
# Training: 5800
# AUC = 0.929 vs. 0.150
# F1 = 0.872 vs. 0.270
# Precision = 0.843 vs. 0.156
# Recall = 0.902 vs. 1.000
# Validation: 5800
# AUC = 0.946 vs. 0.175
# F1 = 0.875 vs. 0.300
# Precision = 0.851 vs. 0.177
# Recall = 0.899 vs. 0.999
# Minibatch Loss= 0.355063
# Training: 5900
# AUC = 0.958 vs. 0.150
# F1 = 0.888 vs. 0.271
# Precision = 0.874 vs. 0.157
# Recall = 0.902 vs. 1.000
# Validation: 5900
# AUC = 0.943 vs. 0.173
# F1 = 0.865 vs. 0.300
# Precision = 0.870 vs. 0.177
# Recall = 0.861 vs. 0.999
# Minibatch Loss= 0.349196
# Training: 6000
# AUC = 0.945 vs. 0.211
# F1 = 0.889 vs. 0.331
# Precision = 0.870 vs. 0.199
# Recall = 0.909 vs. 0.974
# Validation: 6000
# AUC = 0.942 vs. 0.178
# F1 = 0.868 vs. 0.300
# Precision = 0.849 vs. 0.177
# Recall = 0.888 vs. 0.992
# Minibatch Loss= 0.417239
# Training: 6100
# AUC = 0.939 vs. 0.158
# F1 = 0.876 vs. 0.271
# Precision = 0.864 vs. 0.157
# Recall = 0.888 vs. 0.995
# Validation: 6100
# AUC = 0.931 vs. 0.178
# F1 = 0.861 vs. 0.301
# Precision = 0.833 vs. 0.178
# Recall = 0.891 vs. 0.956
# Minibatch Loss= 0.344207
# Training: 6200
# AUC = 0.947 vs. 0.255
# F1 = 0.881 vs. 0.421
# Precision = 0.854 vs. 0.267
# Recall = 0.911 vs. 1.000
# Validation: 6200
# AUC = 0.943 vs. 0.176
# F1 = 0.864 vs. 0.300
# Precision = 0.868 vs. 0.177
# Recall = 0.860 vs. 0.992
# Minibatch Loss= 0.518188
# Training: 6300
# AUC = 0.963 vs. 0.152
# F1 = 0.888 vs. 0.268
# Precision = 0.872 vs. 0.158
# Recall = 0.904 vs. 0.870
# Validation: 6300
# AUC = 0.945 vs. 0.175
# F1 = 0.871 vs. 0.301
# Precision = 0.847 vs. 0.177
# Recall = 0.896 vs. 0.997
# Minibatch Loss= 0.300876
# Training: 6400
# AUC = 0.954 vs. 0.201
# F1 = 0.878 vs. 0.292
# Precision = 0.815 vs. 0.172
# Recall = 0.952 vs. 0.977
# Validation: 6400
# AUC = 0.930 vs. 0.176
# F1 = 0.855 vs. 0.300
# Precision = 0.848 vs. 0.177
# Recall = 0.862 vs. 0.998
# Minibatch Loss= 0.359821
# Training: 6500
# AUC = 0.972 vs. 0.133
# F1 = 0.914 vs. 0.234
# Precision = 0.887 vs. 0.136
# Recall = 0.943 vs. 0.838
# Validation: 6500
# AUC = 0.941 vs. 0.174
# F1 = 0.866 vs. 0.300
# Precision = 0.844 vs. 0.177
# Recall = 0.890 vs. 1.000
# Minibatch Loss= 0.239259
# Training: 6600
# AUC = 0.960 vs. 0.168
# F1 = 0.911 vs. 0.292
# Precision = 0.868 vs. 0.173
# Recall = 0.959 vs. 0.922
# Validation: 6600
# AUC = 0.940 vs. 0.175
# F1 = 0.867 vs. 0.300
# Precision = 0.868 vs. 0.177
# Recall = 0.865 vs. 0.998
# Minibatch Loss= 0.289901
# Training: 6700
# AUC = 0.950 vs. 0.147
# F1 = 0.867 vs. 0.245
# Precision = 0.897 vs. 0.141
# Recall = 0.839 vs. 0.929
# Validation: 6700
# AUC = 0.949 vs. 0.180
# F1 = 0.871 vs. 0.300
# Precision = 0.867 vs. 0.177
# Recall = 0.876 vs. 1.000
# Minibatch Loss= 0.291998
# Training: 6800
# AUC = 0.955 vs. 0.225
# F1 = 0.883 vs. 0.352
# Precision = 0.870 vs. 0.213
# Recall = 0.896 vs. 1.000
# Validation: 6800
# AUC = 0.946 vs. 0.178
# F1 = 0.872 vs. 0.300
# Precision = 0.867 vs. 0.177
# Recall = 0.877 vs. 1.000
# Minibatch Loss= 0.438458
# Training: 6900
# AUC = 0.970 vs. 0.158
# F1 = 0.906 vs. 0.285
# Precision = 0.883 vs. 0.166
# Recall = 0.929 vs. 0.998
# Validation: 6900
# AUC = 0.940 vs. 0.177
# F1 = 0.862 vs. 0.300
# Precision = 0.838 vs. 0.177
# Recall = 0.887 vs. 1.000
# Minibatch Loss= 0.301109
# Training: 7000
# AUC = 0.942 vs. 0.167
# F1 = 0.886 vs. 0.281
# Precision = 0.826 vs. 0.163
# Recall = 0.957 vs. 0.998
# Validation: 7000
# AUC = 0.941 vs. 0.173
# F1 = 0.867 vs. 0.301
# Precision = 0.864 vs. 0.177
# Recall = 0.870 vs. 0.998
# Minibatch Loss= 0.334125
# Training: 7100
# AUC = 0.947 vs. 0.170
# F1 = 0.892 vs. 0.299
# Precision = 0.861 vs. 0.176
# Recall = 0.926 vs. 1.000
# Validation: 7100
# AUC = 0.943 vs. 0.176
# F1 = 0.865 vs. 0.300
# Precision = 0.855 vs. 0.177
# Recall = 0.876 vs. 0.991
# Minibatch Loss= 0.347306
# Training: 7200
# AUC = 0.943 vs. 0.216
# F1 = 0.867 vs. 0.346
# Precision = 0.818 vs. 0.209
# Recall = 0.922 vs. 1.000
# Validation: 7200
# AUC = 0.934 vs. 0.173
# F1 = 0.864 vs. 0.301
# Precision = 0.869 vs. 0.177
# Recall = 0.858 vs. 0.994
# Minibatch Loss= 0.474360
# Training: 7300
# AUC = 0.918 vs. 0.105
# F1 = 0.842 vs. 0.181
# Precision = 0.803 vs. 0.099
# Recall = 0.885 vs. 1.000
# Validation: 7300
# AUC = 0.940 vs. 0.176
# F1 = 0.864 vs. 0.301
# Precision = 0.860 vs. 0.177
# Recall = 0.867 vs. 1.000
# Minibatch Loss= 0.234631
# Training: 7400
# AUC = 0.969 vs. 0.184
# F1 = 0.908 vs. 0.331
# Precision = 0.880 vs. 0.201
# Recall = 0.939 vs. 0.933
# Validation: 7400
# AUC = 0.933 vs. 0.175
# F1 = 0.861 vs. 0.301
# Precision = 0.860 vs. 0.178
# Recall = 0.861 vs. 0.977
# Minibatch Loss= 0.376727
# Training: 7500
# AUC = 0.960 vs. 0.155
# F1 = 0.890 vs. 0.233
# Precision = 0.874 vs. 0.132
# Recall = 0.907 vs. 1.000
# Validation: 7500
# AUC = 0.939 vs. 0.177
# F1 = 0.870 vs. 0.300
# Precision = 0.857 vs. 0.177
# Recall = 0.883 vs. 1.000
# Minibatch Loss= 0.284381
# Training: 7600
# AUC = 0.964 vs. 0.153
# F1 = 0.897 vs. 0.249
# Precision = 0.917 vs. 0.145
# Recall = 0.878 vs. 0.875
# Validation: 7600
# AUC = 0.933 vs. 0.176
# F1 = 0.858 vs. 0.300
# Precision = 0.844 vs. 0.177
# Recall = 0.872 vs. 0.999
# Minibatch Loss= 0.260435
# Training: 7700
# AUC = 0.945 vs. 0.174
# F1 = 0.884 vs. 0.284
# Precision = 0.828 vs. 0.169
# Recall = 0.948 vs. 0.879
# Validation: 7700
# AUC = 0.940 vs. 0.176
# F1 = 0.862 vs. 0.300
# Precision = 0.841 vs. 0.177
# Recall = 0.885 vs. 1.000
# Minibatch Loss= 0.322386
# Training: 7800
# AUC = 0.967 vs. 0.213
# F1 = 0.899 vs. 0.352
# Precision = 0.884 vs. 0.214
# Recall = 0.914 vs. 0.978
# Validation: 7800
# AUC = 0.934 vs. 0.177
# F1 = 0.855 vs. 0.300
# Precision = 0.835 vs. 0.177
# Recall = 0.875 vs. 1.000
# Minibatch Loss= 0.394248
# Training: 7900
# AUC = 0.964 vs. 0.169
# F1 = 0.911 vs. 0.291
# Precision = 0.890 vs. 0.173
# Recall = 0.932 vs. 0.904
# Validation: 7900
# AUC = 0.936 vs. 0.177
# F1 = 0.861 vs. 0.300
# Precision = 0.842 vs. 0.177
# Recall = 0.881 vs. 0.993
# Minibatch Loss= 0.322988
# Training: 8000
# AUC = 0.966 vs. 0.161
# F1 = 0.908 vs. 0.264
# Precision = 0.920 vs. 0.153
# Recall = 0.897 vs. 0.987
# Validation: 8000
# AUC = 0.929 vs. 0.175
# F1 = 0.854 vs. 0.301
# Precision = 0.851 vs. 0.177
# Recall = 0.857 vs. 1.000
# Minibatch Loss= 0.324253
# Training: 8100
# AUC = 0.956 vs. 0.186
# F1 = 0.882 vs. 0.278
# Precision = 0.861 vs. 0.161
# Recall = 0.903 vs. 1.000
# Validation: 8100
# AUC = 0.936 vs. 0.180
# F1 = 0.855 vs. 0.300
# Precision = 0.863 vs. 0.177
# Recall = 0.848 vs. 1.000
# Minibatch Loss= 0.313515
# Training: 8200
# AUC = 0.965 vs. 0.159
# F1 = 0.922 vs. 0.262
# Precision = 0.907 vs. 0.151
# Recall = 0.938 vs. 1.000
# Validation: 8200
# AUC = 0.944 vs. 0.177
# F1 = 0.872 vs. 0.301
# Precision = 0.842 vs. 0.177
# Recall = 0.905 vs. 0.992
# Minibatch Loss= 0.285359
# Training: 8300
# AUC = 0.976 vs. 0.181
# F1 = 0.925 vs. 0.287
# Precision = 0.939 vs. 0.167
# Recall = 0.911 vs. 1.000
# Validation: 8300
# AUC = 0.937 vs. 0.175
# F1 = 0.858 vs. 0.300
# Precision = 0.855 vs. 0.177
# Recall = 0.862 vs. 1.000
# Minibatch Loss= 0.292194
# Training: 8400
# AUC = 0.951 vs. 0.197
# F1 = 0.881 vs. 0.328
# Precision = 0.919 vs. 0.196
# Recall = 0.846 vs. 0.992
# Validation: 8400
# AUC = 0.938 vs. 0.178
# F1 = 0.860 vs. 0.300
# Precision = 0.848 vs. 0.177
# Recall = 0.872 vs. 0.998
# Minibatch Loss= 0.388579
# Training: 8500
# AUC = 0.959 vs. 0.176
# F1 = 0.890 vs. 0.307
# Precision = 0.897 vs. 0.182
# Recall = 0.884 vs. 0.998
# Validation: 8500
# AUC = 0.938 vs. 0.178
# F1 = 0.858 vs. 0.300
# Precision = 0.852 vs. 0.177
# Recall = 0.863 vs. 0.998
# Minibatch Loss= 0.328393
# Training: 8600
# AUC = 0.945 vs. 0.173
# F1 = 0.864 vs. 0.291
# Precision = 0.832 vs. 0.171
# Recall = 0.899 vs. 0.998
# Validation: 8600
# AUC = 0.938 vs. 0.175
# F1 = 0.857 vs. 0.300
# Precision = 0.829 vs. 0.177
# Recall = 0.888 vs. 0.999
# Minibatch Loss= 0.314492
# Training: 8700
# AUC = 0.971 vs. 0.171
# F1 = 0.899 vs. 0.284
# Precision = 0.889 vs. 0.166
# Recall = 0.910 vs. 0.981
# Validation: 8700
# AUC = 0.939 vs. 0.177
# F1 = 0.864 vs. 0.300
# Precision = 0.856 vs. 0.177
# Recall = 0.873 vs. 1.000
# Minibatch Loss= 0.285850
# Training: 8800
# AUC = 0.954 vs. 0.170
# F1 = 0.883 vs. 0.294
# Precision = 0.844 vs. 0.173
# Recall = 0.925 vs. 0.975
# Validation: 8800
# AUC = 0.940 vs. 0.178
# F1 = 0.864 vs. 0.300
# Precision = 0.850 vs. 0.177
# Recall = 0.879 vs. 0.998
# Minibatch Loss= 0.327848
# Training: 8900
# AUC = 0.961 vs. 0.168
# F1 = 0.893 vs. 0.262
# Precision = 0.868 vs. 0.153
# Recall = 0.921 vs. 0.892
# Validation: 8900
# AUC = 0.937 vs. 0.180
# F1 = 0.863 vs. 0.300
# Precision = 0.870 vs. 0.177
# Recall = 0.856 vs. 0.998
# Minibatch Loss= 0.273858
# Training: 9000
# AUC = 0.968 vs. 0.193
# F1 = 0.917 vs. 0.326
# Precision = 0.930 vs. 0.195
# Recall = 0.905 vs. 0.996
# Validation: 9000
# AUC = 0.942 vs. 0.178
# F1 = 0.865 vs. 0.300
# Precision = 0.858 vs. 0.177
# Recall = 0.871 vs. 0.999
# Minibatch Loss= 0.331075
# Training: 9100
# AUC = 0.974 vs. 0.140
# F1 = 0.914 vs. 0.255
# Precision = 0.906 vs. 0.146
# Recall = 0.922 vs. 1.000
# Validation: 9100
# AUC = 0.941 vs. 0.175
# F1 = 0.864 vs. 0.300
# Precision = 0.836 vs. 0.177
# Recall = 0.893 vs. 0.979
# Minibatch Loss= 0.267870
# Training: 9200
# AUC = 0.975 vs. 0.227
# F1 = 0.913 vs. 0.360
# Precision = 0.899 vs. 0.219
# Recall = 0.928 vs. 0.998
# Validation: 9200
# AUC = 0.940 vs. 0.176
# F1 = 0.860 vs. 0.301
# Precision = 0.869 vs. 0.177
# Recall = 0.850 vs. 0.991
# Minibatch Loss= 0.435728
# Training: 9300
# AUC = 0.953 vs. 0.188
# F1 = 0.881 vs. 0.324
# Precision = 0.882 vs. 0.194
# Recall = 0.880 vs. 0.994
# Validation: 9300
# AUC = 0.936 vs. 0.177
# F1 = 0.857 vs. 0.300
# Precision = 0.852 vs. 0.177
# Recall = 0.861 vs. 1.000
# Minibatch Loss= 0.372821
# Training: 9400
# AUC = 0.975 vs. 0.244
# F1 = 0.911 vs. 0.382
# Precision = 0.922 vs. 0.237
# Recall = 0.902 vs. 0.978
# Validation: 9400
# AUC = 0.936 vs. 0.173
# F1 = 0.857 vs. 0.300
# Precision = 0.859 vs. 0.177
# Recall = 0.856 vs. 0.996
# Minibatch Loss= 0.397442
# Training: 9500
# AUC = 0.973 vs. 0.142
# F1 = 0.917 vs. 0.244
# Precision = 0.885 vs. 0.139
# Recall = 0.952 vs. 1.000
# Validation: 9500
# AUC = 0.939 vs. 0.176
# F1 = 0.866 vs. 0.300
# Precision = 0.838 vs. 0.177
# Recall = 0.896 vs. 1.000
# Minibatch Loss= 0.263481
# Training: 9600
# AUC = 0.973 vs. 0.180
# F1 = 0.918 vs. 0.287
# Precision = 0.906 vs. 0.169
# Recall = 0.930 vs. 0.960
# Validation: 9600
# AUC = 0.938 vs. 0.181
# F1 = 0.864 vs. 0.300
# Precision = 0.874 vs. 0.177
# Recall = 0.854 vs. 0.992
# Minibatch Loss= 0.272040
# Training: 9700
# AUC = 0.961 vs. 0.130
# F1 = 0.903 vs. 0.225
# Precision = 0.880 vs. 0.127
# Recall = 0.927 vs. 0.981
# Validation: 9700
# AUC = 0.941 vs. 0.178
# F1 = 0.867 vs. 0.300
# Precision = 0.855 vs. 0.177
# Recall = 0.880 vs. 0.991
# Minibatch Loss= 0.217824
# Training: 9800
# AUC = 0.969 vs. 0.186
# F1 = 0.906 vs. 0.333
# Precision = 0.904 vs. 0.200
# Recall = 0.908 vs. 1.000
# Validation: 9800
# AUC = 0.930 vs. 0.174
# F1 = 0.863 vs. 0.300
# Precision = 0.851 vs. 0.177
# Recall = 0.875 vs. 1.000
# Minibatch Loss= 0.348432
# Training: 9900
# AUC = 0.964 vs. 0.228
# F1 = 0.894 vs. 0.351
# Precision = 0.859 vs. 0.213
# Recall = 0.932 vs. 1.000
# Validation: 9900
# AUC = 0.937 vs. 0.177
# F1 = 0.859 vs. 0.300
# Precision = 0.834 vs. 0.177
# Recall = 0.886 vs. 1.000
# Minibatch Loss= 0.384400
# Training: 10000
# AUC = 0.971 vs. 0.185
# F1 = 0.920 vs. 0.322
# Precision = 0.910 vs. 0.193
# Recall = 0.931 vs. 0.988
# Validation: 10000
# AUC = 0.940 vs. 0.177
# F1 = 0.861 vs. 0.300
# Precision = 0.867 vs. 0.177
# Recall = 0.854 vs. 1.000
# Minibatch Loss= 0.367250
# Training: 10100
# AUC = 0.966 vs. 0.225
# F1 = 0.904 vs. 0.364
# Precision = 0.850 vs. 0.224
# Recall = 0.967 vs. 0.979
# Validation: 10100
# AUC = 0.940 vs. 0.179
# F1 = 0.861 vs. 0.300
# Precision = 0.870 vs. 0.177
# Recall = 0.853 vs. 1.000
# Minibatch Loss= 0.426633
# Training: 10200
# AUC = 0.967 vs. 0.122
# F1 = 0.912 vs. 0.201
# Precision = 0.882 vs. 0.112
# Recall = 0.944 vs. 0.993
# Validation: 10200
# AUC = 0.937 vs. 0.177
# F1 = 0.862 vs. 0.300
# Precision = 0.864 vs. 0.177
# Recall = 0.859 vs. 1.000
# Minibatch Loss= 0.218074
# Training: 10300
# AUC = 0.964 vs. 0.146
# F1 = 0.913 vs. 0.254
# Precision = 0.899 vs. 0.146
# Recall = 0.928 vs. 1.000
# Validation: 10300
# AUC = 0.942 vs. 0.177
# F1 = 0.871 vs. 0.300
# Precision = 0.848 vs. 0.177
# Recall = 0.896 vs. 1.000
# Minibatch Loss= 0.266854
# Training: 10400
# AUC = 0.963 vs. 0.150
# F1 = 0.895 vs. 0.260
# Precision = 0.922 vs. 0.149
# Recall = 0.869 vs. 1.000
# Validation: 10400
# AUC = 0.940 vs. 0.184
# F1 = 0.860 vs. 0.300
# Precision = 0.841 vs. 0.177
# Recall = 0.879 vs. 0.999
# Minibatch Loss= 0.272869
# Training: 10500
# AUC = 0.952 vs. 0.136
# F1 = 0.889 vs. 0.241
# Precision = 0.871 vs. 0.138
# Recall = 0.907 vs. 0.948
# Validation: 10500
# AUC = 0.939 vs. 0.175
# F1 = 0.866 vs. 0.300
# Precision = 0.854 vs. 0.177
# Recall = 0.879 vs. 0.997
# Minibatch Loss= 0.291031
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-fdb06298bfba> in <module>()
#       2                 train_eval_step = 100,
#       3                 validation_eval_step = 100,
# ----> 4                 display_step = 100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model_synthetic/train_abrupt_test_gradual/DWN1001_y/DWN1001_y-10578'

# %%
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-10578')
# Out:
# INFO:tensorflow:Restoring parameters from ../../model_synthetic/train_abrupt_test_gradual/DWN1001_y/DWN1001_y-10578

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.938 vs. 0.176
# F1 = 0.862 vs. 0.300
# Precision = 0.855 vs. 0.177
# Recall = 0.870 vs. 1.000

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (1000, 256)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
