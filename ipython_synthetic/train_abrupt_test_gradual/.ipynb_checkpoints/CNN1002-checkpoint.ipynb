# %%
# useing this variable for saving models and summaries
exp_name = "CNN1002"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed2.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape, validation_data.shape, test_data.shape, train_gt.shape, validation_gt.shape, test_gt.shape, index_of_changes.shape
# Out:
# ((8, 8192, 12),
#  (2, 8192, 12),
#  (10, 8192, 12),
#  (8, 8192, 1),
#  (2, 8192, 1),
#  (10, 8192, 1),
#  (10, 4))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5, n_variables, 32],
                 [9, 32, 64],
                 [9, 64, 64],
                 [9, 64, 64],
                 [9, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

#variables_weights = np.ones((n_classes,))

# %%
print pos_weight
# Out:
# 14.8812031901

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values= pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.058 vs. 0.065
# F1 = 0.138 vs. 0.120
# Precision = 0.080 vs. 0.065
# Recall = 0.516 vs. 0.750
# Validation: 0
# AUC = 0.280 vs. 0.095
# F1 = 0.316 vs. 0.177
# Precision = 0.300 vs. 0.097
# Recall = 0.333 vs. 0.956
# Minibatch Loss= 1.298494
# Training: 100
# AUC = 0.981 vs. 0.060
# F1 = 0.948 vs. 0.117
# Precision = 0.944 vs. 0.062
# Recall = 0.952 vs. 0.992
# Validation: 100
# AUC = 0.498 vs. 0.084
# F1 = 0.507 vs. 0.162
# Precision = 0.773 vs. 0.088
# Recall = 0.378 vs. 1.000
# Minibatch Loss= 0.191954
# Training: 200
# AUC = 0.997 vs. 0.062
# F1 = 0.972 vs. 0.119
# Precision = 0.953 vs. 0.065
# Recall = 0.992 vs. 0.661
# Validation: 200
# AUC = 0.475 vs. 0.116
# F1 = 0.520 vs. 0.210
# Precision = 0.402 vs. 0.165
# Recall = 0.733 vs. 0.289
# Minibatch Loss= 0.166373
# Training: 300
# AUC = 0.999 vs. 0.065
# F1 = 0.992 vs. 0.120
# Precision = 0.984 vs. 0.064
# Recall = 1.000 vs. 0.863
# Validation: 300
# AUC = 0.524 vs. 0.108
# F1 = 0.528 vs. 0.204
# Precision = 0.412 vs. 0.120
# Recall = 0.733 vs. 0.689
# Minibatch Loss= 0.151618
# Training: 400
# AUC = 0.998 vs. 0.059
# F1 = 0.980 vs. 0.124
# Precision = 0.969 vs. 0.067
# Recall = 0.992 vs. 0.895
# Validation: 400
# AUC = 0.536 vs. 0.093
# F1 = 0.517 vs. 0.163
# Precision = 0.413 vs. 0.089
# Recall = 0.689 vs. 1.000
# Minibatch Loss= 0.148700
# Training: 500
# AUC = 1.000 vs. 0.062
# F1 = 0.992 vs. 0.115
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 0.960
# Validation: 500
# AUC = 0.493 vs. 0.085
# F1 = 0.517 vs. 0.164
# Precision = 0.423 vs. 0.089
# Recall = 0.667 vs. 1.000
# Minibatch Loss= 0.144770
# Training: 600
# AUC = 0.998 vs. 0.059
# F1 = 0.980 vs. 0.120
# Precision = 0.976 vs. 0.065
# Recall = 0.984 vs. 0.806
# Validation: 600
# AUC = 0.489 vs. 0.101
# F1 = 0.513 vs. 0.168
# Precision = 0.426 vs. 0.128
# Recall = 0.644 vs. 0.244
# Minibatch Loss= 0.145163
# Training: 700
# AUC = 1.000 vs. 0.057
# F1 = 0.996 vs. 0.119
# Precision = 0.992 vs. 0.063
# Recall = 1.000 vs. 0.935
# Validation: 700
# AUC = 0.486 vs. 0.106
# F1 = 0.513 vs. 0.162
# Precision = 0.426 vs. 0.088
# Recall = 0.644 vs. 1.000
# Minibatch Loss= 0.142756
# Training: 800
# AUC = 0.999 vs. 0.062
# F1 = 0.992 vs. 0.117
# Precision = 0.984 vs. 0.065
# Recall = 1.000 vs. 0.637
# Validation: 800
# AUC = 0.475 vs. 0.095
# F1 = 0.518 vs. 0.187
# Precision = 0.433 vs. 0.107
# Recall = 0.644 vs. 0.756
# Minibatch Loss= 0.142670
# Training: 900
# AUC = 1.000 vs. 0.066
# F1 = 0.992 vs. 0.114
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 900
# AUC = 0.485 vs. 0.109
# F1 = 0.518 vs. 0.177
# Precision = 0.433 vs. 0.098
# Recall = 0.644 vs. 0.911
# Minibatch Loss= 0.142405
# Training: 1000
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.083
# Recall = 1.000 vs. 0.218
# Validation: 1000
# AUC = 0.465 vs. 0.110
# F1 = 0.523 vs. 0.176
# Precision = 0.439 vs. 0.120
# Recall = 0.644 vs. 0.333
# Minibatch Loss= 0.142103
# Training: 1100
# AUC = 0.999 vs. 0.062
# F1 = 0.996 vs. 0.118
# Precision = 1.000 vs. 0.063
# Recall = 0.992 vs. 0.976
# Validation: 1100
# AUC = 0.460 vs. 0.103
# F1 = 0.523 vs. 0.195
# Precision = 0.439 vs. 0.162
# Recall = 0.644 vs. 0.244
# Minibatch Loss= 0.142408
# Training: 1200
# AUC = 1.000 vs. 0.066
# F1 = 0.992 vs. 0.115
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 0.976
# Validation: 1200
# AUC = 0.445 vs. 0.081
# F1 = 0.514 vs. 0.164
# Precision = 0.438 vs. 0.089
# Recall = 0.622 vs. 1.000
# Minibatch Loss= 0.141775
# Training: 1300
# AUC = 0.999 vs. 0.059
# F1 = 0.988 vs. 0.118
# Precision = 0.992 vs. 0.062
# Recall = 0.984 vs. 0.992
# Validation: 1300
# AUC = 0.440 vs. 0.115
# F1 = 0.505 vs. 0.194
# Precision = 0.424 vs. 0.110
# Recall = 0.622 vs. 0.800
# Minibatch Loss= 0.142079
# Training: 1400
# AUC = 0.996 vs. 0.063
# F1 = 0.984 vs. 0.116
# Precision = 0.976 vs. 0.062
# Recall = 0.992 vs. 1.000
# Validation: 1400
# AUC = 0.444 vs. 0.094
# F1 = 0.500 vs. 0.169
# Precision = 0.429 vs. 0.093
# Recall = 0.600 vs. 0.911
# Minibatch Loss= 0.144283
# Training: 1500
# AUC = 0.998 vs. 0.064
# F1 = 0.988 vs. 0.116
# Precision = 0.976 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 1500
# AUC = 0.458 vs. 0.109
# F1 = 0.495 vs. 0.179
# Precision = 0.422 vs. 0.104
# Recall = 0.600 vs. 0.644
# Minibatch Loss= 0.141733
# Training: 1600
# AUC = 1.000 vs. 0.058
# F1 = 0.992 vs. 0.122
# Precision = 0.984 vs. 0.069
# Recall = 1.000 vs. 0.524
# Validation: 1600
# AUC = 0.451 vs. 0.117
# F1 = 0.496 vs. 0.222
# Precision = 0.412 vs. 0.135
# Recall = 0.622 vs. 0.622
# Minibatch Loss= 0.141392
# Training: 1700
# AUC = 1.000 vs. 0.068
# F1 = 0.992 vs. 0.124
# Precision = 0.984 vs. 0.073
# Recall = 1.000 vs. 0.403
# Validation: 1700
# AUC = 0.455 vs. 0.101
# F1 = 0.509 vs. 0.181
# Precision = 0.431 vs. 0.105
# Recall = 0.622 vs. 0.644
# Minibatch Loss= 0.141154
# Training: 1800
# AUC = 0.999 vs. 0.073
# F1 = 0.988 vs. 0.144
# Precision = 0.976 vs. 0.125
# Recall = 1.000 vs. 0.169
# Validation: 1800
# AUC = 0.454 vs. 0.096
# F1 = 0.448 vs. 0.165
# Precision = 0.366 vs. 0.095
# Recall = 0.578 vs. 0.644
# Minibatch Loss= 0.141939
# Training: 1900
# AUC = 1.000 vs. 0.072
# F1 = 0.992 vs. 0.121
# Precision = 0.984 vs. 0.070
# Recall = 1.000 vs. 0.452
# Validation: 1900
# AUC = 0.460 vs. 0.169
# F1 = 0.463 vs. 0.219
# Precision = 0.397 vs. 0.141
# Recall = 0.556 vs. 0.489
# Minibatch Loss= 0.141103
# Training: 2000
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.984
# Validation: 2000
# AUC = 0.458 vs. 0.081
# F1 = 0.444 vs. 0.165
# Precision = 0.381 vs. 0.090
# Recall = 0.533 vs. 1.000
# Minibatch Loss= 0.141214
# Training: 2100
# AUC = 1.000 vs. 0.056
# F1 = 0.988 vs. 0.118
# Precision = 0.976 vs. 0.064
# Recall = 1.000 vs. 0.831
# Validation: 2100
# AUC = 0.454 vs. 0.149
# F1 = 0.441 vs. 0.198
# Precision = 0.929 vs. 0.196
# Recall = 0.289 vs. 0.200
# Minibatch Loss= 0.141703
# Training: 2200
# AUC = 1.000 vs. 0.074
# F1 = 0.996 vs. 0.125
# Precision = 0.992 vs. 0.073
# Recall = 1.000 vs. 0.460
# Validation: 2200
# AUC = 0.455 vs. 0.083
# F1 = 0.456 vs. 0.166
# Precision = 0.377 vs. 0.093
# Recall = 0.578 vs. 0.778
# Minibatch Loss= 0.141882
# Training: 2300
# AUC = 1.000 vs. 0.060
# F1 = 0.992 vs. 0.115
# Precision = 0.984 vs. 0.065
# Recall = 1.000 vs. 0.508
# Validation: 2300
# AUC = 0.447 vs. 0.086
# F1 = 0.441 vs. 0.166
# Precision = 0.652 vs. 0.094
# Recall = 0.333 vs. 0.711
# Minibatch Loss= 0.141070
# Training: 2400
# AUC = 1.000 vs. 0.057
# F1 = 0.996 vs. 0.124
# Precision = 0.992 vs. 0.068
# Recall = 1.000 vs. 0.637
# Validation: 2400
# AUC = 0.445 vs. 0.088
# F1 = 0.459 vs. 0.170
# Precision = 0.875 vs. 0.104
# Recall = 0.311 vs. 0.467
# Minibatch Loss= 0.140964
# Training: 2500
# AUC = 1.000 vs. 0.063
# F1 = 0.992 vs. 0.121
# Precision = 0.992 vs. 0.065
# Recall = 0.992 vs. 0.831
# Validation: 2500
# AUC = 0.439 vs. 0.104
# F1 = 0.459 vs. 0.211
# Precision = 0.875 vs. 0.155
# Recall = 0.311 vs. 0.333
# Minibatch Loss= 0.141118
# Training: 2600
# AUC = 1.000 vs. 0.063
# F1 = 0.992 vs. 0.119
# Precision = 0.984 vs. 0.063
# Recall = 1.000 vs. 0.968
# Validation: 2600
# AUC = 0.441 vs. 0.095
# F1 = 0.435 vs. 0.176
# Precision = 0.625 vs. 0.126
# Recall = 0.333 vs. 0.289
# Minibatch Loss= 0.141688
# Training: 2700
# AUC = 1.000 vs. 0.063
# F1 = 0.996 vs. 0.116
# Precision = 0.992 vs. 0.074
# Recall = 1.000 vs. 0.274
# Validation: 2700
# AUC = 0.437 vs. 0.073
# F1 = 0.459 vs. 0.163
# Precision = 0.875 vs. 0.089
# Recall = 0.311 vs. 1.000
# Minibatch Loss= 0.140891
# Training: 2800
# AUC = 0.999 vs. 0.057
# F1 = 0.992 vs. 0.117
# Precision = 0.992 vs. 0.064
# Recall = 0.992 vs. 0.734
# Validation: 2800
# AUC = 0.432 vs. 0.114
# F1 = 0.433 vs. 0.179
# Precision = 0.867 vs. 0.109
# Recall = 0.289 vs. 0.489
# Minibatch Loss= 0.142612
# Training: 2900
# AUC = 1.000 vs. 0.059
# F1 = 0.996 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 0.992 vs. 1.000
# Validation: 2900
# AUC = 0.438 vs. 0.085
# F1 = 0.436 vs. 0.167
# Precision = 0.369 vs. 0.091
# Recall = 0.533 vs. 1.000
# Minibatch Loss= 0.141845
# Training: 3000
# AUC = 1.000 vs. 0.076
# F1 = 1.000 vs. 0.132
# Precision = 1.000 vs. 0.077
# Recall = 1.000 vs. 0.452
# Validation: 3000
# AUC = 0.433 vs. 0.089
# F1 = 0.438 vs. 0.165
# Precision = 0.737 vs. 0.091
# Recall = 0.311 vs. 0.933
# Minibatch Loss= 0.140922
# Training: 3100
# AUC = 1.000 vs. 0.055
# F1 = 0.996 vs. 0.117
# Precision = 0.992 vs. 0.063
# Recall = 1.000 vs. 0.887
# Validation: 3100
# AUC = 0.442 vs. 0.095
# F1 = 0.452 vs. 0.168
# Precision = 0.824 vs. 0.093
# Recall = 0.311 vs. 0.933
# Minibatch Loss= 0.141049
# Training: 3200
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.126
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.597
# Validation: 3200
# AUC = 0.431 vs. 0.085
# F1 = 0.452 vs. 0.175
# Precision = 0.824 vs. 0.096
# Recall = 0.311 vs. 1.000
# Minibatch Loss= 0.141010
# Training: 3300
# AUC = 1.000 vs. 0.068
# F1 = 0.996 vs. 0.126
# Precision = 0.992 vs. 0.069
# Recall = 1.000 vs. 0.782
# Validation: 3300
# AUC = 0.418 vs. 0.095
# F1 = 0.419 vs. 0.168
# Precision = 0.765 vs. 0.098
# Recall = 0.289 vs. 0.578
# Minibatch Loss= 0.140901
# Training: 3400
# AUC = 0.998 vs. 0.057
# F1 = 0.984 vs. 0.121
# Precision = 0.976 vs. 0.065
# Recall = 0.992 vs. 0.919
# Validation: 3400
# AUC = 0.487 vs. 0.080
# F1 = 0.484 vs. 0.165
# Precision = 0.882 vs. 0.091
# Recall = 0.333 vs. 0.911
# Minibatch Loss= 0.141368
# Training: 3500
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.831
# Validation: 3500
# AUC = 0.448 vs. 0.094
# F1 = 0.459 vs. 0.180
# Precision = 0.875 vs. 0.105
# Recall = 0.311 vs. 0.644
# Minibatch Loss= 0.140835
# Training: 3600
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.992
# Validation: 3600
# AUC = 0.449 vs. 0.091
# F1 = 0.467 vs. 0.164
# Precision = 0.933 vs. 0.089
# Recall = 0.311 vs. 1.000
# Minibatch Loss= 0.140795
# Training: 3700
# AUC = 0.999 vs. 0.062
# F1 = 0.988 vs. 0.114
# Precision = 0.976 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 3700
# AUC = 0.447 vs. 0.097
# F1 = 0.459 vs. 0.166
# Precision = 0.875 vs. 0.092
# Recall = 0.311 vs. 0.889
# Minibatch Loss= 0.141249
# Training: 3800
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.637
# Validation: 3800
# AUC = 0.443 vs. 0.102
# F1 = 0.448 vs. 0.173
# Precision = 1.000 vs. 0.100
# Recall = 0.289 vs. 0.644
# Minibatch Loss= 0.140869
# Training: 3900
# AUC = 1.000 vs. 0.065
# F1 = 0.996 vs. 0.121
# Precision = 1.000 vs. 0.067
# Recall = 0.992 vs. 0.645
# Validation: 3900
# AUC = 0.495 vs. 0.096
# F1 = 0.492 vs. 0.171
# Precision = 0.938 vs. 0.104
# Recall = 0.333 vs. 0.467
# Minibatch Loss= 0.140823
# Training: 4000
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.903
# Validation: 4000
# AUC = 0.472 vs. 0.098
# F1 = 0.475 vs. 0.172
# Precision = 1.000 vs. 0.096
# Recall = 0.311 vs. 0.822
# Minibatch Loss= 0.141079
# Training: 4100
# AUC = 0.999 vs. 0.056
# F1 = 0.996 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 0.992 vs. 0.960
# Validation: 4100
# AUC = 0.462 vs. 0.104
# F1 = 0.459 vs. 0.162
# Precision = 0.875 vs. 0.088
# Recall = 0.311 vs. 1.000
# Minibatch Loss= 0.141941
# Training: 4200
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.131
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.331
# Validation: 4200
# AUC = 0.459 vs. 0.093
# F1 = 0.459 vs. 0.170
# Precision = 0.875 vs. 0.094
# Recall = 0.311 vs. 0.867
# Minibatch Loss= 0.140745
# Training: 4300
# AUC = 0.999 vs. 0.062
# F1 = 0.992 vs. 0.117
# Precision = 0.992 vs. 0.063
# Recall = 0.992 vs. 0.919
# Validation: 4300
# AUC = 0.464 vs. 0.085
# F1 = 0.459 vs. 0.167
# Precision = 0.875 vs. 0.096
# Recall = 0.311 vs. 0.667
# Minibatch Loss= 0.141049
# Training: 4400
# AUC = 0.998 vs. 0.061
# F1 = 0.988 vs. 0.118
# Precision = 0.976 vs. 0.066
# Recall = 1.000 vs. 0.548
# Validation: 4400
# AUC = 0.484 vs. 0.097
# F1 = 0.484 vs. 0.195
# Precision = 0.882 vs. 0.116
# Recall = 0.333 vs. 0.600
# Minibatch Loss= 0.141497
# Training: 4500
# AUC = 0.999 vs. 0.063
# F1 = 0.988 vs. 0.122
# Precision = 0.976 vs. 0.065
# Recall = 1.000 vs. 0.871
# Validation: 4500
# AUC = 0.462 vs. 0.106
# F1 = 0.452 vs. 0.183
# Precision = 0.824 vs. 0.121
# Recall = 0.311 vs. 0.378
# Minibatch Loss= 0.141772
# Training: 4600
# AUC = 1.000 vs. 0.058
# F1 = 0.996 vs. 0.117
# Precision = 0.992 vs. 0.062
# Recall = 1.000 vs. 0.919
# Validation: 4600
# AUC = 0.453 vs. 0.116
# F1 = 0.448 vs. 0.188
# Precision = 1.000 vs. 0.130
# Recall = 0.289 vs. 0.333
# Minibatch Loss= 0.142206
# Training: 4700
# AUC = 1.000 vs. 0.073
# F1 = 1.000 vs. 0.129
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.298
# Validation: 4700
# AUC = 0.448 vs. 0.157
# F1 = 0.448 vs. 0.209
# Precision = 1.000 vs. 0.144
# Recall = 0.289 vs. 0.378
# Minibatch Loss= 0.140700
# Training: 4800
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.790
# Validation: 4800
# AUC = 0.442 vs. 0.089
# F1 = 0.448 vs. 0.184
# Precision = 1.000 vs. 0.106
# Recall = 0.289 vs. 0.689
# Minibatch Loss= 0.140701
# Training: 4900
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.079
# Recall = 1.000 vs. 0.274
# Validation: 4900
# AUC = 0.443 vs. 0.076
# F1 = 0.448 vs. 0.165
# Precision = 1.000 vs. 0.090
# Recall = 0.289 vs. 1.000
# Minibatch Loss= 0.140699
# Training: 5000
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.806
# Validation: 5000
# AUC = 0.481 vs. 0.092
# F1 = 0.484 vs. 0.172
# Precision = 0.882 vs. 0.095
# Recall = 0.333 vs. 0.889
# Minibatch Loss= 0.140780
# Training: 5100
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 5100
# AUC = 0.474 vs. 0.096
# F1 = 0.484 vs. 0.190
# Precision = 0.882 vs. 0.109
# Recall = 0.333 vs. 0.733
# Minibatch Loss= 0.140702
# Training: 5200
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 5200
# AUC = 0.469 vs. 0.090
# F1 = 0.484 vs. 0.168
# Precision = 0.882 vs. 0.096
# Recall = 0.333 vs. 0.667
# Minibatch Loss= 0.140914
# Training: 5300
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.960
# Validation: 5300
# AUC = 0.524 vs. 0.077
# F1 = 0.531 vs. 0.166
# Precision = 0.895 vs. 0.092
# Recall = 0.378 vs. 0.889
# Minibatch Loss= 0.140686
# Training: 5400
# AUC = 1.000 vs. 0.088
# F1 = 1.000 vs. 0.125
# Precision = 1.000 vs. 0.081
# Recall = 1.000 vs. 0.274
# Validation: 5400
# AUC = 0.522 vs. 0.123
# F1 = 0.540 vs. 0.215
# Precision = 0.944 vs. 0.165
# Recall = 0.378 vs. 0.311
# Minibatch Loss= 0.140680
# Training: 5500
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.758
# Validation: 5500
# AUC = 0.501 vs. 0.071
# F1 = 0.508 vs. 0.162
# Precision = 0.889 vs. 0.088
# Recall = 0.356 vs. 1.000
# Minibatch Loss= 0.140690
# Training: 5600
# AUC = 0.998 vs. 0.063
# F1 = 0.984 vs. 0.124
# Precision = 0.976 vs. 0.067
# Recall = 0.992 vs. 0.798
# Validation: 5600
# AUC = 0.538 vs. 0.105
# F1 = 0.540 vs. 0.186
# Precision = 0.944 vs. 0.107
# Recall = 0.378 vs. 0.711
# Minibatch Loss= 0.143108
# Training: 5700
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.952
# Validation: 5700
# AUC = 0.497 vs. 0.073
# F1 = 0.492 vs. 0.173
# Precision = 0.938 vs. 0.096
# Recall = 0.333 vs. 0.844
# Minibatch Loss= 0.140675
# Training: 5800
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 5800
# AUC = 0.481 vs. 0.097
# F1 = 0.467 vs. 0.166
# Precision = 0.403 vs. 0.091
# Recall = 0.556 vs. 0.956
# Minibatch Loss= 0.140662
# Training: 5900
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 5900
# AUC = 0.467 vs. 0.152
# F1 = 0.467 vs. 0.201
# Precision = 0.933 vs. 0.132
# Recall = 0.311 vs. 0.422
# Minibatch Loss= 0.140658
# Training: 6000
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.984
# Validation: 6000
# AUC = 0.462 vs. 0.084
# F1 = 0.459 vs. 0.173
# Precision = 0.875 vs. 0.095
# Recall = 0.311 vs. 1.000
# Minibatch Loss= 0.140655
# Training: 6100
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.992
# Validation: 6100
# AUC = 0.453 vs. 0.092
# F1 = 0.452 vs. 0.188
# Precision = 0.824 vs. 0.106
# Recall = 0.311 vs. 0.844
# Minibatch Loss= 0.140655
# Training: 6200
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.766
# Validation: 6200
# AUC = 0.451 vs. 0.106
# F1 = 0.444 vs. 0.167
# Precision = 0.778 vs. 0.092
# Recall = 0.311 vs. 0.933
# Minibatch Loss= 0.140698
# Training: 6300
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.130
# Precision = 1.000 vs. 0.075
# Recall = 1.000 vs. 0.476
# Validation: 6300
# AUC = 0.447 vs. 0.094
# F1 = 0.441 vs. 0.179
# Precision = 0.929 vs. 0.103
# Recall = 0.289 vs. 0.689
# Minibatch Loss= 0.140703
# Training: 6400
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 6400
# AUC = 0.441 vs. 0.108
# F1 = 0.438 vs. 0.168
# Precision = 0.383 vs. 0.128
# Recall = 0.511 vs. 0.244
# Minibatch Loss= 0.140676
# Training: 6500
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.927
# Validation: 6500
# AUC = 0.438 vs. 0.089
# F1 = 0.438 vs. 0.172
# Precision = 0.383 vs. 0.096
# Recall = 0.511 vs. 0.822
# Minibatch Loss= 0.140635
# Training: 6600
# AUC = 0.995 vs. 0.077
# F1 = 0.972 vs. 0.118
# Precision = 0.976 vs. 0.064
# Recall = 0.968 vs. 0.815
# Validation: 6600
# AUC = 0.515 vs. 0.092
# F1 = 0.514 vs. 0.169
# Precision = 0.720 vs. 0.092
# Recall = 0.400 vs. 0.978
# Minibatch Loss= 0.167172
# Training: 6700
# AUC = 0.999 vs. 0.062
# F1 = 0.984 vs. 0.121
# Precision = 0.976 vs. 0.072
# Recall = 0.992 vs. 0.379
# Validation: 6700
# AUC = 0.582 vs. 0.086
# F1 = 0.649 vs. 0.171
# Precision = 0.828 vs. 0.094
# Recall = 0.533 vs. 1.000
# Minibatch Loss= 0.151430
# Training: 6800
# AUC = 0.999 vs. 0.064
# F1 = 0.988 vs. 0.119
# Precision = 0.976 vs. 0.064
# Recall = 1.000 vs. 0.871
# Validation: 6800
# AUC = 0.622 vs. 0.093
# F1 = 0.725 vs. 0.173
# Precision = 0.829 vs. 0.096
# Recall = 0.644 vs. 0.911
# Minibatch Loss= 0.147874
# Training: 6900
# AUC = 1.000 vs. 0.063
# F1 = 0.992 vs. 0.123
# Precision = 1.000 vs. 0.078
# Recall = 0.984 vs. 0.282
# Validation: 6900
# AUC = 0.622 vs. 0.116
# F1 = 0.729 vs. 0.202
# Precision = 0.775 vs. 0.115
# Recall = 0.689 vs. 0.822
# Minibatch Loss= 0.145906
# Training: 7000
# AUC = 1.000 vs. 0.051
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.976
# Validation: 7000
# AUC = 0.613 vs. 0.089
# F1 = 0.716 vs. 0.167
# Precision = 0.806 vs. 0.101
# Recall = 0.644 vs. 0.467
# Minibatch Loss= 0.144666
# Training: 7100
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.839
# Validation: 7100
# AUC = 0.609 vs. 0.077
# F1 = 0.716 vs. 0.163
# Precision = 0.806 vs. 0.089
# Recall = 0.644 vs. 1.000
# Minibatch Loss= 0.143899
# Training: 7200
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.074
# Recall = 1.000 vs. 0.306
# Validation: 7200
# AUC = 0.618 vs. 0.088
# F1 = 0.689 vs. 0.172
# Precision = 0.689 vs. 0.097
# Recall = 0.689 vs. 0.756
# Minibatch Loss= 0.143411
# Training: 7300
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.139
# Precision = 1.000 vs. 0.082
# Recall = 1.000 vs. 0.452
# Validation: 7300
# AUC = 0.594 vs. 0.110
# F1 = 0.698 vs. 0.188
# Precision = 0.732 vs. 0.122
# Recall = 0.667 vs. 0.400
# Minibatch Loss= 0.143592
# Training: 7400
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.984
# Validation: 7400
# AUC = 0.585 vs. 0.099
# F1 = 0.674 vs. 0.174
# Precision = 0.707 vs. 0.097
# Recall = 0.644 vs. 0.822
# Minibatch Loss= 0.142406
# Training: 7500
# AUC = 1.000 vs. 0.063
# F1 = 0.992 vs. 0.125
# Precision = 1.000 vs. 0.084
# Recall = 0.984 vs. 0.250
# Validation: 7500
# AUC = 0.602 vs. 0.086
# F1 = 0.646 vs. 0.172
# Precision = 0.608 vs. 0.094
# Recall = 0.689 vs. 0.978
# Minibatch Loss= 0.142894
# Training: 7600
# AUC = 0.999 vs. 0.067
# F1 = 0.988 vs. 0.117
# Precision = 0.976 vs. 0.063
# Recall = 1.000 vs. 0.823
# Validation: 7600
# AUC = 0.559 vs. 0.084
# F1 = 0.626 vs. 0.177
# Precision = 0.574 vs. 0.098
# Recall = 0.689 vs. 0.867
# Minibatch Loss= 0.142304
# Training: 7700
# AUC = 1.000 vs. 0.055
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.927
# Validation: 7700
# AUC = 0.556 vs. 0.131
# F1 = 0.615 vs. 0.238
# Precision = 0.727 vs. 0.214
# Recall = 0.533 vs. 0.267
# Minibatch Loss= 0.141872
# Training: 7800
# AUC = 0.999 vs. 0.061
# F1 = 0.992 vs. 0.116
# Precision = 1.000 vs. 0.063
# Recall = 0.984 vs. 0.750
# Validation: 7800
# AUC = 0.558 vs. 0.087
# F1 = 0.610 vs. 0.171
# Precision = 0.676 vs. 0.097
# Recall = 0.556 vs. 0.711
# Minibatch Loss= 0.141997
# Training: 7900
# AUC = 1.000 vs. 0.083
# F1 = 0.996 vs. 0.133
# Precision = 1.000 vs. 0.077
# Recall = 0.992 vs. 0.484
# Validation: 7900
# AUC = 0.540 vs. 0.130
# F1 = 0.584 vs. 0.177
# Precision = 0.591 vs. 0.206
# Recall = 0.578 vs. 0.156
# Minibatch Loss= 0.143446
# Training: 8000
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.123
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.935
# Validation: 8000
# AUC = 0.538 vs. 0.078
# F1 = 0.575 vs. 0.163
# Precision = 0.657 vs. 0.089
# Recall = 0.511 vs. 1.000
# Minibatch Loss= 0.142601
# Training: 8100
# AUC = 0.999 vs. 0.074
# F1 = 0.988 vs. 0.129
# Precision = 0.992 vs. 0.072
# Recall = 0.984 vs. 0.621
# Validation: 8100
# AUC = 0.559 vs. 0.091
# F1 = 0.584 vs. 0.173
# Precision = 0.591 vs. 0.103
# Recall = 0.578 vs. 0.533
# Minibatch Loss= 0.142013
# Training: 8200
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.124
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.427
# Validation: 8200
# AUC = 0.560 vs. 0.086
# F1 = 0.562 vs. 0.169
# Precision = 0.529 vs. 0.093
# Recall = 0.600 vs. 1.000
# Minibatch Loss= 0.141420
# Training: 8300
# AUC = 0.999 vs. 0.063
# F1 = 0.992 vs. 0.117
# Precision = 0.984 vs. 0.089
# Recall = 1.000 vs. 0.169
# Validation: 8300
# AUC = 0.549 vs. 0.079
# F1 = 0.581 vs. 0.170
# Precision = 0.610 vs. 0.093
# Recall = 0.556 vs. 0.978
# Minibatch Loss= 0.141429
# Training: 8400
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.629
# Validation: 8400
# AUC = 0.551 vs. 0.087
# F1 = 0.575 vs. 0.171
# Precision = 0.595 vs. 0.094
# Recall = 0.556 vs. 0.956
# Minibatch Loss= 0.141305
# Training: 8500
# AUC = 0.998 vs. 0.065
# F1 = 0.992 vs. 0.116
# Precision = 0.992 vs. 0.082
# Recall = 0.992 vs. 0.202
# Validation: 8500
# AUC = 0.538 vs. 0.116
# F1 = 0.575 vs. 0.190
# Precision = 0.595 vs. 0.121
# Recall = 0.556 vs. 0.444
# Minibatch Loss= 0.142024
# Training: 8600
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.976
# Validation: 8600
# AUC = 0.538 vs. 0.075
# F1 = 0.584 vs. 0.166
# Precision = 0.591 vs. 0.093
# Recall = 0.578 vs. 0.778
# Minibatch Loss= 0.141164
# Training: 8700
# AUC = 0.999 vs. 0.054
# F1 = 0.988 vs. 0.115
# Precision = 0.976 vs. 0.061
# Recall = 1.000 vs. 0.976
# Validation: 8700
# AUC = 0.542 vs. 0.097
# F1 = 0.574 vs. 0.186
# Precision = 0.551 vs. 0.118
# Recall = 0.600 vs. 0.444
# Minibatch Loss= 0.141572
# Training: 8800
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.911
# Validation: 8800
# AUC = 0.522 vs. 0.109
# F1 = 0.587 vs. 0.202
# Precision = 0.574 vs. 0.124
# Recall = 0.600 vs. 0.556
# Minibatch Loss= 0.141122
# Training: 8900
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.124
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.750
# Validation: 8900
# AUC = 0.533 vs. 0.084
# F1 = 0.574 vs. 0.165
# Precision = 0.551 vs. 0.090
# Recall = 0.600 vs. 1.000
# Minibatch Loss= 0.141103
# Training: 9000
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.125
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.532
# Validation: 9000
# AUC = 0.531 vs. 0.118
# F1 = 0.575 vs. 0.182
# Precision = 0.595 vs. 0.103
# Recall = 0.556 vs. 0.756
# Minibatch Loss= 0.141058
# Training: 9100
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 9100
# AUC = 0.530 vs. 0.101
# F1 = 0.578 vs. 0.201
# Precision = 0.578 vs. 0.117
# Recall = 0.578 vs. 0.711
# Minibatch Loss= 0.141282
# Training: 9200
# AUC = 0.999 vs. 0.067
# F1 = 0.984 vs. 0.119
# Precision = 0.992 vs. 0.079
# Recall = 0.976 vs. 0.242
# Validation: 9200
# AUC = 0.519 vs. 0.099
# F1 = 0.564 vs. 0.180
# Precision = 0.667 vs. 0.104
# Recall = 0.489 vs. 0.644
# Minibatch Loss= 0.143292
# Training: 9300
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.540
# Validation: 9300
# AUC = 0.534 vs. 0.092
# F1 = 0.565 vs. 0.168
# Precision = 0.600 vs. 0.097
# Recall = 0.533 vs. 0.644
# Minibatch Loss= 0.140999
# Training: 9400
# AUC = 1.000 vs. 0.059
# F1 = 0.988 vs. 0.115
# Precision = 0.984 vs. 0.061
# Recall = 0.992 vs. 1.000
# Validation: 9400
# AUC = 0.535 vs. 0.100
# F1 = 0.571 vs. 0.163
# Precision = 0.688 vs. 0.090
# Recall = 0.489 vs. 0.911
# Minibatch Loss= 0.141960
# Training: 9500
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.124
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.565
# Validation: 9500
# AUC = 0.535 vs. 0.080
# F1 = 0.578 vs. 0.162
# Precision = 0.632 vs. 0.088
# Recall = 0.533 vs. 1.000
# Minibatch Loss= 0.141379
# Training: 9600
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.150
# Precision = 1.000 vs. 0.087
# Recall = 1.000 vs. 0.565
# Validation: 9600
# AUC = 0.530 vs. 0.160
# F1 = 0.578 vs. 0.187
# Precision = 0.632 vs. 0.122
# Recall = 0.533 vs. 0.400
# Minibatch Loss= 0.140954
# Training: 9700
# AUC = 1.000 vs. 0.065
# F1 = 0.996 vs. 0.129
# Precision = 1.000 vs. 0.073
# Recall = 0.992 vs. 0.548
# Validation: 9700
# AUC = 0.532 vs. 0.087
# F1 = 0.578 vs. 0.164
# Precision = 0.632 vs. 0.090
# Recall = 0.533 vs. 0.867
# Minibatch Loss= 0.140944
# Training: 9800
# AUC = 1.000 vs. 0.063
# F1 = 0.992 vs. 0.120
# Precision = 0.984 vs. 0.072
# Recall = 1.000 vs. 0.347
# Validation: 9800
# AUC = 0.531 vs. 0.103
# F1 = 0.582 vs. 0.190
# Precision = 0.676 vs. 0.116
# Recall = 0.511 vs. 0.533
# Minibatch Loss= 0.141452
# Training: 9900
# AUC = 0.999 vs. 0.059
# F1 = 0.988 vs. 0.119
# Precision = 0.984 vs. 0.063
# Recall = 0.992 vs. 0.968
# Validation: 9900
# AUC = 0.563 vs. 0.158
# F1 = 0.593 vs. 0.308
# Precision = 0.667 vs. 0.304
# Recall = 0.533 vs. 0.311
# Minibatch Loss= 0.146462
#  Optimization Finished!

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 1000, 
                validation_eval_step = 1000,
                display_step = 1000)
# Out:
# Training: 10000
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.903
# Validation: 10000
# AUC = 0.574 vs. 0.113
# F1 = 0.513 vs. 0.164
# Precision = 0.417 vs. 0.090
# Recall = 0.667 vs. 0.956
# Minibatch Loss= 0.141110
# Training: 11000
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.597
# Validation: 11000
# AUC = 0.613 vs. 0.118
# F1 = 0.575 vs. 0.165
# Precision = 0.750 vs. 0.090
# Recall = 0.467 vs. 1.000
# Minibatch Loss= 0.141006
# Training: 12000
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 1.000
# Validation: 12000
# AUC = 0.593 vs. 0.125
# F1 = 0.597 vs. 0.214
# Precision = 0.909 vs. 0.231
# Recall = 0.444 vs. 0.200
# Minibatch Loss= 0.140994
# Training: 13000
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.952
# Validation: 13000
# AUC = 0.550 vs. 0.097
# F1 = 0.541 vs. 0.164
# Precision = 0.690 vs. 0.089
# Recall = 0.444 vs. 1.000
# Minibatch Loss= 0.140687
# Training: 14000
# AUC = 1.000 vs. 0.060
# F1 = 0.992 vs. 0.117
# Precision = 0.984 vs. 0.063
# Recall = 1.000 vs. 0.871
# Validation: 14000
# AUC = 0.641 vs. 0.084
# F1 = 0.684 vs. 0.173
# Precision = 0.839 vs. 0.096
# Recall = 0.578 vs. 0.867
# Minibatch Loss= 0.142228
# Training: 15000
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.798
# Validation: 15000
# AUC = 0.616 vs. 0.104
# F1 = 0.676 vs. 0.192
# Precision = 0.923 vs. 0.117
# Recall = 0.533 vs. 0.533
# Minibatch Loss= 0.141479
# Training: 16000
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.123
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.815
# Validation: 16000
# AUC = 0.582 vs. 0.134
# F1 = 0.639 vs. 0.220
# Precision = 0.852 vs. 0.188
# Recall = 0.511 vs. 0.267
# Minibatch Loss= 0.140834
# Training: 17000
# AUC = 1.000 vs. 0.053
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 17000
# AUC = 0.565 vs. 0.082
# F1 = 0.608 vs. 0.169
# Precision = 0.706 vs. 0.092
# Recall = 0.533 vs. 1.000
# Minibatch Loss= 0.140808
# Training: 18000
# AUC = 1.000 vs. 0.051
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.952
# Validation: 18000
# AUC = 0.555 vs. 0.092
# F1 = 0.587 vs. 0.169
# Precision = 0.733 vs. 0.094
# Recall = 0.489 vs. 0.867
# Minibatch Loss= 0.141173
# Training: 19000
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.589
# Validation: 19000
# AUC = 0.539 vs. 0.119
# F1 = 0.590 vs. 0.194
# Precision = 0.697 vs. 0.146
# Recall = 0.511 vs. 0.289
# Minibatch Loss= 0.140772
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model_synthetic/train_abrupt_test_gradual/CNN1002/CNN1002-10000'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
probability_of_pos= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.494 vs. 0.289
# F1 = 0.464 vs. 0.435
# Precision = 0.431 vs. 0.279
# Recall = 0.502 vs. 0.984

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
#squeezed_probability_of_pos = np.squeeze(probability_of_pos, axis = 2)

# %%
out = nn_eval.deploy (model, sess, test_data, test_gt)

# %%
out = np.squeeze(out, axis = 2)
out.shape
# Out:
# (10, 256)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
