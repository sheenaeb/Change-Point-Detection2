# %%
# useing this variable for saving models and summaries
exp_name = "CNN1001_y"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed3.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape, validation_data.shape, test_data.shape, train_gt.shape, validation_gt.shape, test_gt.shape, index_of_changes.shape
# Out:
# ((8, 8192, 12),
#  (2, 8192, 12),
#  (10, 8192, 12),
#  (8, 8192, 1),
#  (2, 8192, 1),
#  (10, 8192, 1),
#  (10, 4))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

#variables_weights = np.ones((n_classes,))

# %%
print pos_weight
# Out:
# 14.8542629897

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values= pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.064 vs. 0.055
# F1 = 0.125 vs. 0.116
# Precision = 0.071 vs. 0.063
# Recall = 0.521 vs. 0.719
# Validation: 0
# AUC = 0.195 vs. 0.090
# F1 = 0.241 vs. 0.171
# Precision = 0.149 vs. 0.094
# Recall = 0.630 vs. 0.935
# Minibatch Loss= 1.297529
# Training: 100
# AUC = 0.949 vs. 0.069
# F1 = 0.900 vs. 0.121
# Precision = 0.908 vs. 0.078
# Recall = 0.893 vs. 0.273
# Validation: 100
# AUC = 0.410 vs. 0.150
# F1 = 0.484 vs. 0.228
# Precision = 0.938 vs. 0.150
# Recall = 0.326 vs. 0.478
# Minibatch Loss= 0.273284
# Training: 200
# AUC = 0.986 vs. 0.061
# F1 = 0.939 vs. 0.114
# Precision = 0.927 vs. 0.061
# Recall = 0.950 vs. 1.000
# Validation: 200
# AUC = 0.366 vs. 0.094
# F1 = 0.433 vs. 0.189
# Precision = 0.929 vs. 0.120
# Recall = 0.283 vs. 0.435
# Minibatch Loss= 0.207615
# Training: 300
# AUC = 0.996 vs. 0.063
# F1 = 0.967 vs. 0.112
# Precision = 0.952 vs. 0.059
# Recall = 0.983 vs. 1.000
# Validation: 300
# AUC = 0.351 vs. 0.109
# F1 = 0.414 vs. 0.184
# Precision = 1.000 vs. 0.125
# Recall = 0.261 vs. 0.348
# Minibatch Loss= 0.184753
# Training: 400
# AUC = 0.999 vs. 0.073
# F1 = 0.983 vs. 0.122
# Precision = 0.983 vs. 0.069
# Recall = 0.983 vs. 0.554
# Validation: 400
# AUC = 0.341 vs. 0.087
# F1 = 0.400 vs. 0.166
# Precision = 0.857 vs. 0.091
# Recall = 0.261 vs. 0.978
# Minibatch Loss= 0.172258
# Training: 500
# AUC = 0.999 vs. 0.064
# F1 = 0.984 vs. 0.123
# Precision = 0.976 vs. 0.067
# Recall = 0.992 vs. 0.793
# Validation: 500
# AUC = 0.334 vs. 0.113
# F1 = 0.386 vs. 0.196
# Precision = 1.000 vs. 0.112
# Recall = 0.239 vs. 0.761
# Minibatch Loss= 0.169678
# Training: 600
# AUC = 1.000 vs. 0.057
# F1 = 0.992 vs. 0.113
# Precision = 0.992 vs. 0.060
# Recall = 0.992 vs. 0.884
# Validation: 600
# AUC = 0.334 vs. 0.096
# F1 = 0.400 vs. 0.188
# Precision = 0.857 vs. 0.107
# Recall = 0.261 vs. 0.761
# Minibatch Loss= 0.161721
# Training: 700
# AUC = 1.000 vs. 0.065
# F1 = 0.996 vs. 0.122
# Precision = 1.000 vs. 0.081
# Recall = 0.992 vs. 0.248
# Validation: 700
# AUC = 0.333 vs. 0.092
# F1 = 0.407 vs. 0.188
# Precision = 0.923 vs. 0.104
# Recall = 0.261 vs. 0.957
# Minibatch Loss= 0.158624
# Training: 800
# AUC = 0.997 vs. 0.058
# F1 = 0.988 vs. 0.117
# Precision = 0.992 vs. 0.064
# Recall = 0.983 vs. 0.694
# Validation: 800
# AUC = 0.333 vs. 0.091
# F1 = 0.414 vs. 0.175
# Precision = 1.000 vs. 0.098
# Recall = 0.261 vs. 0.848
# Minibatch Loss= 0.159284
# Training: 900
# AUC = 0.998 vs. 0.064
# F1 = 0.984 vs. 0.122
# Precision = 0.976 vs. 0.081
# Recall = 0.992 vs. 0.240
# Validation: 900
# AUC = 0.334 vs. 0.092
# F1 = 0.414 vs. 0.173
# Precision = 1.000 vs. 0.095
# Recall = 0.261 vs. 0.935
# Minibatch Loss= 0.157482
# Training: 1000
# AUC = 0.991 vs. 0.057
# F1 = 0.954 vs. 0.116
# Precision = 0.974 vs. 0.062
# Recall = 0.934 vs. 0.901
# Validation: 1000
# AUC = 0.223 vs. 0.102
# F1 = 0.376 vs. 0.184
# Precision = 0.410 vs. 0.103
# Recall = 0.348 vs. 0.848
# Minibatch Loss= 0.190818
# Training: 1100
# AUC = 0.997 vs. 0.068
# F1 = 0.980 vs. 0.120
# Precision = 0.968 vs. 0.075
# Recall = 0.992 vs. 0.298
# Validation: 1100
# AUC = 0.261 vs. 0.150
# F1 = 0.410 vs. 0.242
# Precision = 0.500 vs. 0.400
# Recall = 0.348 vs. 0.174
# Minibatch Loss= 0.164889
# Training: 1200
# AUC = 0.997 vs. 0.061
# F1 = 0.975 vs. 0.116
# Precision = 0.975 vs. 0.062
# Recall = 0.975 vs. 0.851
# Validation: 1200
# AUC = 0.259 vs. 0.114
# F1 = 0.421 vs. 0.167
# Precision = 0.533 vs. 0.094
# Recall = 0.348 vs. 0.761
# Minibatch Loss= 0.157896
# Training: 1300
# AUC = 0.999 vs. 0.064
# F1 = 0.983 vs. 0.117
# Precision = 0.992 vs. 0.063
# Recall = 0.975 vs. 0.802
# Validation: 1300
# AUC = 0.253 vs. 0.090
# F1 = 0.421 vs. 0.176
# Precision = 0.533 vs. 0.102
# Recall = 0.348 vs. 0.630
# Minibatch Loss= 0.154665
# Training: 1400
# AUC = 0.999 vs. 0.059
# F1 = 0.984 vs. 0.114
# Precision = 0.968 vs. 0.061
# Recall = 1.000 vs. 0.860
# Validation: 1400
# AUC = 0.252 vs. 0.112
# F1 = 0.421 vs. 0.183
# Precision = 0.533 vs. 0.107
# Recall = 0.348 vs. 0.652
# Minibatch Loss= 0.152946
# Training: 1500
# AUC = 0.999 vs. 0.056
# F1 = 0.988 vs. 0.112
# Precision = 0.976 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 1500
# AUC = 0.251 vs. 0.096
# F1 = 0.421 vs. 0.175
# Precision = 0.533 vs. 0.096
# Recall = 0.348 vs. 0.957
# Minibatch Loss= 0.152101
# Training: 1600
# AUC = 1.000 vs. 0.093
# F1 = 0.992 vs. 0.138
# Precision = 0.984 vs. 0.091
# Recall = 1.000 vs. 0.289
# Validation: 1600
# AUC = 0.238 vs. 0.106
# F1 = 0.395 vs. 0.176
# Precision = 0.500 vs. 0.097
# Recall = 0.326 vs. 0.913
# Minibatch Loss= 0.152202
# Training: 1700
# AUC = 1.000 vs. 0.063
# F1 = 0.992 vs. 0.120
# Precision = 0.984 vs. 0.067
# Recall = 1.000 vs. 0.587
# Validation: 1700
# AUC = 0.235 vs. 0.103
# F1 = 0.385 vs. 0.169
# Precision = 0.469 vs. 0.093
# Recall = 0.326 vs. 0.957
# Minibatch Loss= 0.150961
# Training: 1800
# AUC = 1.000 vs. 0.055
# F1 = 0.996 vs. 0.115
# Precision = 0.992 vs. 0.061
# Recall = 1.000 vs. 0.860
# Validation: 1800
# AUC = 0.233 vs. 0.109
# F1 = 0.385 vs. 0.174
# Precision = 0.469 vs. 0.109
# Recall = 0.326 vs. 0.435
# Minibatch Loss= 0.150410
# Training: 1900
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.124
# Precision = 1.000 vs. 0.081
# Recall = 1.000 vs. 0.264
# Validation: 1900
# AUC = 0.233 vs. 0.111
# F1 = 0.385 vs. 0.168
# Precision = 0.469 vs. 0.099
# Recall = 0.326 vs. 0.565
# Minibatch Loss= 0.150027
# Training: 2000
# AUC = 1.000 vs. 0.058
# F1 = 0.996 vs. 0.114
# Precision = 0.992 vs. 0.061
# Recall = 1.000 vs. 0.950
# Validation: 2000
# AUC = 0.233 vs. 0.100
# F1 = 0.385 vs. 0.186
# Precision = 0.469 vs. 0.124
# Recall = 0.326 vs. 0.370
# Minibatch Loss= 0.149803
# Training: 2100
# AUC = 0.999 vs. 0.066
# F1 = 0.988 vs. 0.136
# Precision = 0.976 vs. 0.089
# Recall = 1.000 vs. 0.289
# Validation: 2100
# AUC = 0.233 vs. 0.102
# F1 = 0.380 vs. 0.199
# Precision = 0.455 vs. 0.122
# Recall = 0.326 vs. 0.543
# Minibatch Loss= 0.150210
# Training: 2200
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.661
# Validation: 2200
# AUC = 0.239 vs. 0.119
# F1 = 0.385 vs. 0.193
# Precision = 0.469 vs. 0.109
# Recall = 0.326 vs. 0.848
# Minibatch Loss= 0.149306
# Training: 2300
# AUC = 0.999 vs. 0.059
# F1 = 0.988 vs. 0.116
# Precision = 0.976 vs. 0.062
# Recall = 1.000 vs. 0.860
# Validation: 2300
# AUC = 0.246 vs. 0.111
# F1 = 0.385 vs. 0.178
# Precision = 0.469 vs. 0.099
# Recall = 0.326 vs. 0.848
# Minibatch Loss= 0.149360
# Training: 2400
# AUC = 0.992 vs. 0.067
# F1 = 0.954 vs. 0.114
# Precision = 0.958 vs. 0.087
# Recall = 0.950 vs. 0.165
# Validation: 2400
# AUC = 0.340 vs. 0.080
# F1 = 0.394 vs. 0.174
# Precision = 0.650 vs. 0.096
# Recall = 0.283 vs. 0.913
# Minibatch Loss= 0.183079
# Training: 2500
# AUC = 1.000 vs. 0.066
# F1 = 0.996 vs. 0.128
# Precision = 0.992 vs. 0.072
# Recall = 1.000 vs. 0.579
# Validation: 2500
# AUC = 0.311 vs. 0.114
# F1 = 0.368 vs. 0.190
# Precision = 0.467 vs. 0.106
# Recall = 0.304 vs. 0.913
# Minibatch Loss= 0.157622
# Training: 2600
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.736
# Validation: 2600
# AUC = 0.308 vs. 0.118
# F1 = 0.351 vs. 0.206
# Precision = 0.464 vs. 0.180
# Recall = 0.283 vs. 0.239
# Minibatch Loss= 0.153483
# Training: 2700
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.126
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.240
# Validation: 2700
# AUC = 0.302 vs. 0.106
# F1 = 0.333 vs. 0.195
# Precision = 0.550 vs. 0.110
# Recall = 0.239 vs. 0.870
# Minibatch Loss= 0.151782
# Training: 2800
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 2800
# AUC = 0.296 vs. 0.083
# F1 = 0.333 vs. 0.169
# Precision = 0.550 vs. 0.092
# Recall = 0.239 vs. 1.000
# Minibatch Loss= 0.150746
# Training: 2900
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.595
# Validation: 2900
# AUC = 0.291 vs. 0.090
# F1 = 0.328 vs. 0.170
# Precision = 0.524 vs. 0.095
# Recall = 0.239 vs. 0.826
# Minibatch Loss= 0.150072
# Training: 3000
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.909
# Validation: 3000
# AUC = 0.289 vs. 0.111
# F1 = 0.323 vs. 0.205
# Precision = 0.625 vs. 0.138
# Recall = 0.217 vs. 0.391
# Minibatch Loss= 0.149543
# Training: 3100
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.793
# Validation: 3100
# AUC = 0.290 vs. 0.119
# F1 = 0.323 vs. 0.193
# Precision = 0.625 vs. 0.112
# Recall = 0.217 vs. 0.674
# Minibatch Loss= 0.149334
# Training: 3200
# AUC = 1.000 vs. 0.055
# F1 = 0.992 vs. 0.114
# Precision = 0.984 vs. 0.060
# Recall = 1.000 vs. 1.000
# Validation: 3200
# AUC = 0.284 vs. 0.109
# F1 = 0.323 vs. 0.176
# Precision = 0.625 vs. 0.100
# Recall = 0.217 vs. 0.739
# Minibatch Loss= 0.149896
# Training: 3300
# AUC = 1.000 vs. 0.071
# F1 = 0.996 vs. 0.127
# Precision = 0.992 vs. 0.069
# Recall = 1.000 vs. 0.793
# Validation: 3300
# AUC = 0.284 vs. 0.093
# F1 = 0.323 vs. 0.176
# Precision = 0.625 vs. 0.096
# Recall = 0.217 vs. 1.000
# Minibatch Loss= 0.149228
# Training: 3400
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.364
# Validation: 3400
# AUC = 0.287 vs. 0.095
# F1 = 0.323 vs. 0.188
# Precision = 0.625 vs. 0.141
# Recall = 0.217 vs. 0.283
# Minibatch Loss= 0.149033
# Training: 3500
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.126
# Precision = 1.000 vs. 0.076
# Recall = 1.000 vs. 0.355
# Validation: 3500
# AUC = 0.287 vs. 0.079
# F1 = 0.323 vs. 0.173
# Precision = 0.625 vs. 0.094
# Recall = 0.217 vs. 1.000
# Minibatch Loss= 0.148961
# Training: 3600
# AUC = 1.000 vs. 0.061
# F1 = 0.996 vs. 0.120
# Precision = 1.000 vs. 0.067
# Recall = 0.992 vs. 0.570
# Validation: 3600
# AUC = 0.287 vs. 0.087
# F1 = 0.323 vs. 0.179
# Precision = 0.625 vs. 0.100
# Recall = 0.217 vs. 0.913
# Minibatch Loss= 0.148919
# Training: 3700
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.711
# Validation: 3700
# AUC = 0.285 vs. 0.098
# F1 = 0.323 vs. 0.184
# Precision = 0.625 vs. 0.112
# Recall = 0.217 vs. 0.522
# Minibatch Loss= 0.148595
# Training: 3800
# AUC = 1.000 vs. 0.056
# F1 = 0.996 vs. 0.116
# Precision = 0.992 vs. 0.062
# Recall = 1.000 vs. 0.860
# Validation: 3800
# AUC = 0.284 vs. 0.093
# F1 = 0.323 vs. 0.176
# Precision = 0.625 vs. 0.100
# Recall = 0.217 vs. 0.739
# Minibatch Loss= 0.149476
# Training: 3900
# AUC = 1.000 vs. 0.056
# F1 = 0.992 vs. 0.114
# Precision = 0.992 vs. 0.060
# Recall = 0.992 vs. 0.983
# Validation: 3900
# AUC = 0.286 vs. 0.094
# F1 = 0.323 vs. 0.171
# Precision = 0.625 vs. 0.141
# Recall = 0.217 vs. 0.217
# Minibatch Loss= 0.150987
# Training: 4000
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.099
# Recall = 1.000 vs. 0.157
# Validation: 4000
# AUC = 0.286 vs. 0.110
# F1 = 0.323 vs. 0.200
# Precision = 0.625 vs. 0.113
# Recall = 0.217 vs. 0.870
# Minibatch Loss= 0.148424
# Training: 4100
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 4100
# AUC = 0.287 vs. 0.139
# F1 = 0.323 vs. 0.198
# Precision = 0.625 vs. 0.115
# Recall = 0.217 vs. 0.717
# Minibatch Loss= 0.148445
# Training: 4200
# AUC = 1.000 vs. 0.067
# F1 = 0.992 vs. 0.113
# Precision = 0.984 vs. 0.060
# Recall = 1.000 vs. 0.843
# Validation: 4200
# AUC = 0.287 vs. 0.105
# F1 = 0.323 vs. 0.186
# Precision = 0.625 vs. 0.106
# Recall = 0.217 vs. 0.761
# Minibatch Loss= 0.149593
# Training: 4300
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.934
# Validation: 4300
# AUC = 0.288 vs. 0.148
# F1 = 0.323 vs. 0.189
# Precision = 0.625 vs. 0.109
# Recall = 0.217 vs. 0.717
# Minibatch Loss= 0.148370
# Training: 4400
# AUC = 0.996 vs. 0.063
# F1 = 0.979 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 0.959 vs. 0.835
# Validation: 4400
# AUC = 0.292 vs. 0.114
# F1 = 0.328 vs. 0.221
# Precision = 0.667 vs. 0.139
# Recall = 0.217 vs. 0.543
# Minibatch Loss= 0.170567
# Training: 4500
# AUC = 0.999 vs. 0.071
# F1 = 0.992 vs. 0.120
# Precision = 1.000 vs. 0.065
# Recall = 0.983 vs. 0.777
# Validation: 4500
# AUC = 0.417 vs. 0.084
# F1 = 0.469 vs. 0.168
# Precision = 0.833 vs. 0.093
# Recall = 0.326 vs. 0.891
# Minibatch Loss= 0.158719
# Training: 4600
# AUC = 1.000 vs. 0.058
# F1 = 0.992 vs. 0.113
# Precision = 0.984 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 4600
# AUC = 0.417 vs. 0.082
# F1 = 0.479 vs. 0.169
# Precision = 0.680 vs. 0.092
# Recall = 0.370 vs. 0.978
# Minibatch Loss= 0.152848
# Training: 4700
# AUC = 1.000 vs. 0.056
# F1 = 0.992 vs. 0.114
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 0.843
# Validation: 4700
# AUC = 0.407 vs. 0.100
# F1 = 0.472 vs. 0.185
# Precision = 0.654 vs. 0.111
# Recall = 0.370 vs. 0.543
# Minibatch Loss= 0.151153
# Training: 4800
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.068
# Recall = 1.000 vs. 0.479
# Validation: 4800
# AUC = 0.394 vs. 0.081
# F1 = 0.448 vs. 0.168
# Precision = 0.714 vs. 0.092
# Recall = 0.326 vs. 0.957
# Minibatch Loss= 0.150271
# Training: 4900
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.909
# Validation: 4900
# AUC = 0.390 vs. 0.070
# F1 = 0.441 vs. 0.166
# Precision = 0.682 vs. 0.091
# Recall = 0.326 vs. 1.000
# Minibatch Loss= 0.149790
# Training: 5000
# AUC = 1.000 vs. 0.065
# F1 = 0.992 vs. 0.121
# Precision = 0.984 vs. 0.070
# Recall = 1.000 vs. 0.438
# Validation: 5000
# AUC = 0.384 vs. 0.101
# F1 = 0.441 vs. 0.178
# Precision = 0.682 vs. 0.101
# Recall = 0.326 vs. 0.761
# Minibatch Loss= 0.149527
# Training: 5100
# AUC = 1.000 vs. 0.063
# F1 = 0.992 vs. 0.115
# Precision = 0.992 vs. 0.078
# Recall = 0.992 vs. 0.215
# Validation: 5100
# AUC = 0.380 vs. 0.124
# F1 = 0.441 vs. 0.188
# Precision = 0.682 vs. 0.119
# Recall = 0.326 vs. 0.457
# Minibatch Loss= 0.151673
# Training: 5200
# AUC = 1.000 vs. 0.053
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.736
# Validation: 5200
# AUC = 0.377 vs. 0.094
# F1 = 0.441 vs. 0.170
# Precision = 0.682 vs. 0.093
# Recall = 0.326 vs. 0.957
# Minibatch Loss= 0.149024
# Training: 5300
# AUC = 1.000 vs. 0.061
# F1 = 0.996 vs. 0.117
# Precision = 0.992 vs. 0.064
# Recall = 1.000 vs. 0.669
# Validation: 5300
# AUC = 0.373 vs. 0.105
# F1 = 0.441 vs. 0.205
# Precision = 0.682 vs. 0.130
# Recall = 0.326 vs. 0.478
# Minibatch Loss= 0.150057
# Training: 5400
# AUC = 0.990 vs. 0.067
# F1 = 0.971 vs. 0.128
# Precision = 0.975 vs. 0.073
# Recall = 0.967 vs. 0.537
# Validation: 5400
# AUC = 0.368 vs. 0.097
# F1 = 0.438 vs. 0.177
# Precision = 0.778 vs. 0.100
# Recall = 0.304 vs. 0.761
# Minibatch Loss= 0.154138
# Training: 5500
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.967
# Validation: 5500
# AUC = 0.376 vs. 0.098
# F1 = 0.441 vs. 0.165
# Precision = 0.682 vs. 0.090
# Recall = 0.326 vs. 1.000
# Minibatch Loss= 0.148702
# Training: 5600
# AUC = 1.000 vs. 0.064
# F1 = 0.996 vs. 0.118
# Precision = 0.992 vs. 0.063
# Recall = 1.000 vs. 0.835
# Validation: 5600
# AUC = 0.372 vs. 0.149
# F1 = 0.441 vs. 0.202
# Precision = 0.682 vs. 0.189
# Recall = 0.326 vs. 0.217
# Minibatch Loss= 0.148933
# Training: 5700
# AUC = 1.000 vs. 0.052
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.975
# Validation: 5700
# AUC = 0.371 vs. 0.120
# F1 = 0.441 vs. 0.179
# Precision = 0.682 vs. 0.099
# Recall = 0.326 vs. 0.978
# Minibatch Loss= 0.148573
# Training: 5800
# AUC = 1.000 vs. 0.054
# F1 = 0.996 vs. 0.112
# Precision = 0.992 vs. 0.060
# Recall = 1.000 vs. 0.959
# Validation: 5800
# AUC = 0.372 vs. 0.097
# F1 = 0.438 vs. 0.183
# Precision = 0.778 vs. 0.113
# Recall = 0.304 vs. 0.478
# Minibatch Loss= 0.148692
# Training: 5900
# AUC = 0.995 vs. 0.066
# F1 = 0.968 vs. 0.123
# Precision = 0.938 vs. 0.071
# Recall = 1.000 vs. 0.463
# Validation: 5900
# AUC = 0.379 vs. 0.083
# F1 = 0.435 vs. 0.167
# Precision = 0.652 vs. 0.091
# Recall = 0.326 vs. 1.000
# Minibatch Loss= 0.153800
# Training: 6000
# AUC = 1.000 vs. 0.055
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 6000
# AUC = 0.371 vs. 0.087
# F1 = 0.431 vs. 0.172
# Precision = 0.737 vs. 0.095
# Recall = 0.304 vs. 0.870
# Minibatch Loss= 0.148410
# Training: 6100
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.826
# Validation: 6100
# AUC = 0.375 vs. 0.089
# F1 = 0.431 vs. 0.193
# Precision = 0.737 vs. 0.112
# Recall = 0.304 vs. 0.696
# Minibatch Loss= 0.148348
# Training: 6200
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.868
# Validation: 6200
# AUC = 0.374 vs. 0.071
# F1 = 0.431 vs. 0.168
# Precision = 0.737 vs. 0.092
# Recall = 0.304 vs. 0.978
# Minibatch Loss= 0.148336
# Training: 6300
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.068
# Recall = 1.000 vs. 0.463
# Validation: 6300
# AUC = 0.375 vs. 0.123
# F1 = 0.438 vs. 0.189
# Precision = 0.778 vs. 0.114
# Recall = 0.304 vs. 0.543
# Minibatch Loss= 0.148265
# Training: 6400
# AUC = 1.000 vs. 0.056
# F1 = 0.996 vs. 0.114
# Precision = 0.992 vs. 0.061
# Recall = 1.000 vs. 0.769
# Validation: 6400
# AUC = 0.390 vs. 0.130
# F1 = 0.455 vs. 0.190
# Precision = 0.750 vs. 0.106
# Recall = 0.326 vs. 0.935
# Minibatch Loss= 0.148513
# Training: 6500
# AUC = 1.000 vs. 0.073
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.108
# Recall = 1.000 vs. 0.132
# Validation: 6500
# AUC = 0.382 vs. 0.092
# F1 = 0.431 vs. 0.171
# Precision = 0.737 vs. 0.106
# Recall = 0.304 vs. 0.457
# Minibatch Loss= 0.148289
# Training: 6600
# AUC = 1.000 vs. 0.065
# F1 = 0.992 vs. 0.115
# Precision = 1.000 vs. 0.072
# Recall = 0.983 vs. 0.298
# Validation: 6600
# AUC = 0.383 vs. 0.132
# F1 = 0.435 vs. 0.215
# Precision = 0.652 vs. 0.167
# Recall = 0.326 vs. 0.304
# Minibatch Loss= 0.148859
# Training: 6700
# AUC = 1.000 vs. 0.053
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.942
# Validation: 6700
# AUC = 0.379 vs. 0.078
# F1 = 0.433 vs. 0.166
# Precision = 0.929 vs. 0.091
# Recall = 0.283 vs. 1.000
# Minibatch Loss= 0.148227
# Training: 6800
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.075
# Recall = 1.000 vs. 0.405
# Validation: 6800
# AUC = 0.380 vs. 0.105
# F1 = 0.433 vs. 0.183
# Precision = 0.929 vs. 0.101
# Recall = 0.283 vs. 0.957
# Minibatch Loss= 0.148301
# Training: 6900
# AUC = 1.000 vs. 0.060
# F1 = 0.992 vs. 0.114
# Precision = 0.984 vs. 0.060
# Recall = 1.000 vs. 0.967
# Validation: 6900
# AUC = 0.382 vs. 0.096
# F1 = 0.441 vs. 0.184
# Precision = 0.682 vs. 0.137
# Recall = 0.326 vs. 0.283
# Minibatch Loss= 0.148632
# Training: 7000
# AUC = 0.995 vs. 0.071
# F1 = 0.964 vs. 0.121
# Precision = 0.944 vs. 0.068
# Recall = 0.983 vs. 0.521
# Validation: 7000
# AUC = 0.394 vs. 0.112
# F1 = 0.441 vs. 0.199
# Precision = 0.682 vs. 0.139
# Recall = 0.326 vs. 0.348
# Minibatch Loss= 0.158575
# Training: 7100
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.744
# Validation: 7100
# AUC = 0.369 vs. 0.106
# F1 = 0.431 vs. 0.178
# Precision = 0.737 vs. 0.122
# Recall = 0.304 vs. 0.326
# Minibatch Loss= 0.148365
# Training: 7200
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 7200
# AUC = 0.375 vs. 0.104
# F1 = 0.431 vs. 0.175
# Precision = 0.737 vs. 0.111
# Recall = 0.304 vs. 0.413
# Minibatch Loss= 0.148244
# Training: 7300
# AUC = 1.000 vs. 0.071
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.950
# Validation: 7300
# AUC = 0.382 vs. 0.092
# F1 = 0.431 vs. 0.168
# Precision = 0.737 vs. 0.093
# Recall = 0.304 vs. 0.891
# Minibatch Loss= 0.148179
# Training: 7400
# AUC = 1.000 vs. 0.052
# F1 = 0.996 vs. 0.112
# Precision = 0.992 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 7400
# AUC = 0.381 vs. 0.108
# F1 = 0.431 vs. 0.172
# Precision = 0.737 vs. 0.099
# Recall = 0.304 vs. 0.652
# Minibatch Loss= 0.148206
# Training: 7500
# AUC = 1.000 vs. 0.079
# F1 = 1.000 vs. 0.143
# Precision = 1.000 vs. 0.086
# Recall = 1.000 vs. 0.413
# Validation: 7500
# AUC = 0.379 vs. 0.105
# F1 = 0.431 vs. 0.171
# Precision = 0.737 vs. 0.093
# Recall = 0.304 vs. 1.000
# Minibatch Loss= 0.148167
# Training: 7600
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 7600
# AUC = 0.378 vs. 0.088
# F1 = 0.431 vs. 0.165
# Precision = 0.737 vs. 0.090
# Recall = 0.304 vs. 1.000
# Minibatch Loss= 0.148109
# Training: 7700
# AUC = 1.000 vs. 0.058
# F1 = 0.992 vs. 0.115
# Precision = 0.984 vs. 0.062
# Recall = 1.000 vs. 0.727
# Validation: 7700
# AUC = 0.378 vs. 0.108
# F1 = 0.431 vs. 0.170
# Precision = 0.737 vs. 0.093
# Recall = 0.304 vs. 0.957
# Minibatch Loss= 0.148654
# Training: 7800
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.545
# Validation: 7800
# AUC = 0.372 vs. 0.100
# F1 = 0.431 vs. 0.170
# Precision = 0.737 vs. 0.093
# Recall = 0.304 vs. 0.978
# Minibatch Loss= 0.148137
# Training: 7900
# AUC = 1.000 vs. 0.067
# F1 = 0.992 vs. 0.118
# Precision = 0.992 vs. 0.063
# Recall = 0.992 vs. 0.917
# Validation: 7900
# AUC = 0.372 vs. 0.085
# F1 = 0.431 vs. 0.172
# Precision = 0.737 vs. 0.100
# Recall = 0.304 vs. 0.609
# Minibatch Loss= 0.151574
# Training: 8000
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.132
# Precision = 1.000 vs. 0.080
# Recall = 1.000 vs. 0.372
# Validation: 8000
# AUC = 0.368 vs. 0.081
# F1 = 0.438 vs. 0.167
# Precision = 0.778 vs. 0.091
# Recall = 0.304 vs. 1.000
# Minibatch Loss= 0.148117
# Training: 8100
# AUC = 1.000 vs. 0.068
# F1 = 0.996 vs. 0.119
# Precision = 0.992 vs. 0.065
# Recall = 1.000 vs. 0.793
# Validation: 8100
# AUC = 0.373 vs. 0.089
# F1 = 0.438 vs. 0.165
# Precision = 0.778 vs. 0.090
# Recall = 0.304 vs. 1.000
# Minibatch Loss= 0.148777
# Training: 8200
# AUC = 0.998 vs. 0.059
# F1 = 0.980 vs. 0.115
# Precision = 0.960 vs. 0.062
# Recall = 1.000 vs. 0.901
# Validation: 8200
# AUC = 0.366 vs. 0.118
# F1 = 0.438 vs. 0.233
# Precision = 0.778 vs. 0.170
# Recall = 0.304 vs. 0.370
# Minibatch Loss= 0.149912
# Training: 8300
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.876
# Validation: 8300
# AUC = 0.367 vs. 0.085
# F1 = 0.438 vs. 0.179
# Precision = 0.778 vs. 0.100
# Recall = 0.304 vs. 0.826
# Minibatch Loss= 0.148050
# Training: 8400
# AUC = 1.000 vs. 0.062
# F1 = 0.996 vs. 0.116
# Precision = 0.992 vs. 0.062
# Recall = 1.000 vs. 0.810
# Validation: 8400
# AUC = 0.372 vs. 0.104
# F1 = 0.438 vs. 0.170
# Precision = 0.778 vs. 0.093
# Recall = 0.304 vs. 0.957
# Minibatch Loss= 0.148135
# Training: 8500
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.975
# Validation: 8500
# AUC = 0.367 vs. 0.121
# F1 = 0.438 vs. 0.204
# Precision = 0.778 vs. 0.140
# Recall = 0.304 vs. 0.370
# Minibatch Loss= 0.148127
# Training: 8600
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.068
# Recall = 1.000 vs. 0.438
# Validation: 8600
# AUC = 0.371 vs. 0.097
# F1 = 0.438 vs. 0.175
# Precision = 0.778 vs. 0.096
# Recall = 0.304 vs. 1.000
# Minibatch Loss= 0.148003
# Training: 8700
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.777
# Validation: 8700
# AUC = 0.371 vs. 0.087
# F1 = 0.438 vs. 0.167
# Precision = 0.778 vs. 0.091
# Recall = 0.304 vs. 1.000
# Minibatch Loss= 0.148007
# Training: 8800
# AUC = 1.000 vs. 0.060
# F1 = 0.996 vs. 0.113
# Precision = 0.992 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 8800
# AUC = 0.371 vs. 0.092
# F1 = 0.438 vs. 0.178
# Precision = 0.778 vs. 0.099
# Recall = 0.304 vs. 0.848
# Minibatch Loss= 0.148102
# Training: 8900
# AUC = 0.999 vs. 0.064
# F1 = 0.992 vs. 0.114
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 0.975
# Validation: 8900
# AUC = 0.370 vs. 0.117
# F1 = 0.438 vs. 0.180
# Precision = 0.778 vs. 0.102
# Recall = 0.304 vs. 0.739
# Minibatch Loss= 0.148634
# Training: 9000
# AUC = 0.932 vs. 0.076
# F1 = 0.916 vs. 0.141
# Precision = 0.885 vs. 0.094
# Recall = 0.950 vs. 0.281
# Validation: 9000
# AUC = 0.373 vs. 0.094
# F1 = 0.379 vs. 0.183
# Precision = 0.917 vs. 0.109
# Recall = 0.239 vs. 0.565
# Minibatch Loss= 0.232662
# Training: 9100
# AUC = 1.000 vs. 0.060
# F1 = 0.996 vs. 0.120
# Precision = 0.992 vs. 0.075
# Recall = 1.000 vs. 0.298
# Validation: 9100
# AUC = 0.343 vs. 0.170
# F1 = 0.357 vs. 0.265
# Precision = 1.000 vs. 0.250
# Recall = 0.217 vs. 0.283
# Minibatch Loss= 0.158344
# Training: 9200
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.128
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.645
# Validation: 9200
# AUC = 0.343 vs. 0.104
# F1 = 0.386 vs. 0.169
# Precision = 1.000 vs. 0.100
# Recall = 0.239 vs. 0.565
# Minibatch Loss= 0.153661
# Training: 9300
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.120
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.413
# Validation: 9300
# AUC = 0.335 vs. 0.095
# F1 = 0.373 vs. 0.171
# Precision = 0.846 vs. 0.098
# Recall = 0.239 vs. 0.696
# Minibatch Loss= 0.151665
# Training: 9400
# AUC = 0.998 vs. 0.055
# F1 = 0.988 vs. 0.112
# Precision = 0.984 vs. 0.059
# Recall = 0.992 vs. 1.000
# Validation: 9400
# AUC = 0.320 vs. 0.097
# F1 = 0.349 vs. 0.168
# Precision = 0.647 vs. 0.092
# Recall = 0.239 vs. 0.935
# Minibatch Loss= 0.152463
# Training: 9500
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.421
# Validation: 9500
# AUC = 0.313 vs. 0.105
# F1 = 0.314 vs. 0.174
# Precision = 0.458 vs. 0.145
# Recall = 0.239 vs. 0.217
# Minibatch Loss= 0.150079
# Training: 9600
# AUC = 1.000 vs. 0.055
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.826
# Validation: 9600
# AUC = 0.302 vs. 0.080
# F1 = 0.299 vs. 0.174
# Precision = 0.317 vs. 0.097
# Recall = 0.283 vs. 0.891
# Minibatch Loss= 0.149598
# Training: 9700
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 9700
# AUC = 0.302 vs. 0.116
# F1 = 0.295 vs. 0.170
# Precision = 0.310 vs. 0.106
# Recall = 0.283 vs. 0.435
# Minibatch Loss= 0.150096
# Training: 9800
# AUC = 1.000 vs. 0.055
# F1 = 0.992 vs. 0.114
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 0.917
# Validation: 9800
# AUC = 0.295 vs. 0.098
# F1 = 0.288 vs. 0.175
# Precision = 0.236 vs. 0.097
# Recall = 0.370 vs. 0.891
# Minibatch Loss= 0.149686
# Training: 9900
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 9900
# AUC = 0.295 vs. 0.100
# F1 = 0.296 vs. 0.176
# Precision = 0.225 vs. 0.105
# Recall = 0.435 vs. 0.543
# Minibatch Loss= 0.149884
#  Optimization Finished!

# %%
trainer.train(max_iter = 5000,
                train_eval_step = 1000, 
                validation_eval_step = 1000,
                display_step = 1000)
# Out:
# Training: 10000
# AUC = 0.999 vs. 0.067
# F1 = 0.984 vs. 0.118
# Precision = 0.968 vs. 0.065
# Recall = 1.000 vs. 0.636
# Validation: 10000
# AUC = 0.292 vs. 0.088
# F1 = 0.303 vs. 0.165
# Precision = 0.233 vs. 0.090
# Recall = 0.435 vs. 1.000
# Minibatch Loss= 0.149059
# Training: 11000
# AUC = 1.000 vs. 0.060
# F1 = 0.996 vs. 0.121
# Precision = 0.992 vs. 0.072
# Recall = 1.000 vs. 0.380
# Validation: 11000
# AUC = 0.241 vs. 0.111
# F1 = 0.292 vs. 0.194
# Precision = 0.220 vs. 0.138
# Recall = 0.435 vs. 0.326
# Minibatch Loss= 0.150318
# Training: 12000
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 12000
# AUC = 0.289 vs. 0.094
# F1 = 0.291 vs. 0.176
# Precision = 0.250 vs. 0.101
# Recall = 0.348 vs. 0.696
# Minibatch Loss= 0.148211
# Training: 13000
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 1.000
# Validation: 13000
# AUC = 0.279 vs. 0.092
# F1 = 0.290 vs. 0.169
# Precision = 0.231 vs. 0.094
# Recall = 0.391 vs. 0.804
# Minibatch Loss= 0.148003
# Training: 14000
# AUC = 1.000 vs. 0.058
# F1 = 0.996 vs. 0.113
# Precision = 0.992 vs. 0.060
# Recall = 1.000 vs. 0.983
# Validation: 14000
# AUC = 0.293 vs. 0.103
# F1 = 0.315 vs. 0.196
# Precision = 0.274 vs. 0.113
# Recall = 0.370 vs. 0.739
# Minibatch Loss= 0.148981
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model_synthetic/train_abrupt_test_gradual/CNN1001_y/CNN1001_y-15000'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.110 vs. 0.065
# F1 = 0.232 vs. 0.126
# Precision = 0.242 vs. 0.067
# Recall = 0.224 vs. 0.994

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (10, 256)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
