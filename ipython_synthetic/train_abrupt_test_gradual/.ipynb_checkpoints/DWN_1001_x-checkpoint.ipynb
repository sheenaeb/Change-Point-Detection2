# %%
# useing this variable for saving models and summaries
exp_name = "DWN1001_x"

# %% [markdown]
# # Neural wavelet network
# 6levels wavelet then 5 layers CNN [2, 2, 2, 2, 2]

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../src')

# %%
import models.wavelet_conv_model as wavelet_conv_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed2.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape, validation_data.shape, test_data.shape, train_gt.shape, validation_gt.shape, test_gt.shape, index_of_changes.shape
# Out:
# ((900, 8192, 12),
#  (100, 8192, 12),
#  (1000, 8192, 12),
#  (900, 8192, 1),
#  (100, 8192, 1),
#  (1000, 8192, 1),
#  (1000, 4))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10


wavelet_levels = 6    #number of wavelet layer to have in the network
convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]    #stride of pooling in convolution
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
wavelet_weights_shape = [[5, n_variables, n_variables]]    #high_pass and low_pass dimensions
activation = tf.nn.relu
granularity = np.prod(pooling_stride)
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
print pos_weight
# Out:
# 12.0408324012

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = wavelet_conv_model.Model(n_variables = n_variables,
                                 learning_rate = learning_rate,
                                 n_classes = n_classes)

# %%
model.build_neural_wavelet_layer(pos_weight = pos_weight, 
                                 learning_rate = learning_rate,
                                 wavelet_levels = wavelet_levels,    
                                 convolution_levels = convolution_levels,    
                                 pooling_stride = pooling_stride,     
                                 weights_shape = weights_shape,
                                 bias_shape = bias_shape,
                                 wavelet_weights_shape = wavelet_weights_shape,    
                                 activation = activation,
                                 trainable_wavelet=True,
                                 trainable_conv=True,
                                 trainable_last = True)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100,
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.075 vs. 0.084
# F1 = 0.170 vs. 0.159
# Precision = 0.094 vs. 0.086
# Recall = 0.887 vs. 1.000
# Validation: 0
# AUC = 0.069 vs. 0.070
# F1 = 0.137 vs. 0.136
# Precision = 0.074 vs. 0.073
# Recall = 0.935 vs. 0.990
# Minibatch Loss= 1.389715
# Training: 100
# AUC = 0.655 vs. 0.089
# F1 = 0.646 vs. 0.150
# Precision = 0.643 vs. 0.089
# Recall = 0.650 vs. 0.457
# Validation: 100
# AUC = 0.534 vs. 0.072
# F1 = 0.559 vs. 0.135
# Precision = 0.515 vs. 0.073
# Recall = 0.610 vs. 0.998
# Minibatch Loss= 0.650709
# Training: 200
# AUC = 0.666 vs. 0.065
# F1 = 0.708 vs. 0.131
# Precision = 0.727 vs. 0.070
# Recall = 0.690 vs. 0.983
# Validation: 200
# AUC = 0.670 vs. 0.073
# F1 = 0.667 vs. 0.136
# Precision = 0.595 vs. 0.073
# Recall = 0.760 vs. 0.994
# Minibatch Loss= 0.643023
# Training: 300
# AUC = 0.622 vs. 0.062
# F1 = 0.652 vs. 0.126
# Precision = 0.551 vs. 0.068
# Recall = 0.798 vs. 0.964
# Validation: 300
# AUC = 0.746 vs. 0.073
# F1 = 0.712 vs. 0.136
# Precision = 0.694 vs. 0.073
# Recall = 0.730 vs. 0.969
# Minibatch Loss= 0.498682
# Training: 400
# AUC = 0.829 vs. 0.082
# F1 = 0.800 vs. 0.144
# Precision = 0.731 vs. 0.085
# Recall = 0.883 vs. 0.463
# Validation: 400
# AUC = 0.784 vs. 0.074
# F1 = 0.742 vs. 0.136
# Precision = 0.726 vs. 0.073
# Recall = 0.758 vs. 0.978
# Minibatch Loss= 0.389265
# Training: 500
# AUC = 0.814 vs. 0.084
# F1 = 0.765 vs. 0.152
# Precision = 0.699 vs. 0.086
# Recall = 0.845 vs. 0.699
# Validation: 500
# AUC = 0.784 vs. 0.075
# F1 = 0.758 vs. 0.135
# Precision = 0.699 vs. 0.072
# Recall = 0.829 vs. 1.000
# Minibatch Loss= 0.455886
# Training: 600
# AUC = 0.836 vs. 0.054
# F1 = 0.784 vs. 0.114
# Precision = 0.795 vs. 0.060
# Recall = 0.773 vs. 0.980
# Validation: 600
# AUC = 0.842 vs. 0.071
# F1 = 0.789 vs. 0.135
# Precision = 0.764 vs. 0.073
# Recall = 0.815 vs. 0.999
# Minibatch Loss= 0.298036
# Training: 700
# AUC = 0.880 vs. 0.078
# F1 = 0.826 vs. 0.145
# Precision = 0.748 vs. 0.081
# Recall = 0.923 vs. 0.704
# Validation: 700
# AUC = 0.855 vs. 0.074
# F1 = 0.809 vs. 0.135
# Precision = 0.805 vs. 0.072
# Recall = 0.813 vs. 1.000
# Minibatch Loss= 0.340712
# Training: 800
# AUC = 0.890 vs. 0.070
# F1 = 0.854 vs. 0.133
# Precision = 0.840 vs. 0.071
# Recall = 0.868 vs. 1.000
# Validation: 800
# AUC = 0.858 vs. 0.070
# F1 = 0.799 vs. 0.135
# Precision = 0.787 vs. 0.073
# Recall = 0.812 vs. 1.000
# Minibatch Loss= 0.316052
# Training: 900
# AUC = 0.877 vs. 0.093
# F1 = 0.801 vs. 0.161
# Precision = 0.783 vs. 0.088
# Recall = 0.819 vs. 0.907
# Validation: 900
# AUC = 0.891 vs. 0.072
# F1 = 0.817 vs. 0.135
# Precision = 0.787 vs. 0.073
# Recall = 0.851 vs. 0.990
# Minibatch Loss= 0.391302
# Training: 1000
# AUC = 0.896 vs. 0.073
# F1 = 0.856 vs. 0.142
# Precision = 0.794 vs. 0.076
# Recall = 0.928 vs. 1.000
# Validation: 1000
# AUC = 0.887 vs. 0.073
# F1 = 0.809 vs. 0.136
# Precision = 0.802 vs. 0.073
# Recall = 0.817 vs. 0.935
# Minibatch Loss= 0.369376
# Training: 1100
# AUC = 0.847 vs. 0.085
# F1 = 0.823 vs. 0.155
# Precision = 0.827 vs. 0.090
# Recall = 0.818 vs. 0.567
# Validation: 1100
# AUC = 0.861 vs. 0.073
# F1 = 0.805 vs. 0.135
# Precision = 0.774 vs. 0.073
# Recall = 0.839 vs. 0.906
# Minibatch Loss= 0.598421
# Training: 1200
# AUC = 0.918 vs. 0.078
# F1 = 0.818 vs. 0.137
# Precision = 0.825 vs. 0.077
# Recall = 0.812 vs. 0.634
# Validation: 1200
# AUC = 0.884 vs. 0.071
# F1 = 0.820 vs. 0.135
# Precision = 0.811 vs. 0.072
# Recall = 0.829 vs. 1.000
# Minibatch Loss= 0.302529
# Training: 1300
# AUC = 0.908 vs. 0.074
# F1 = 0.832 vs. 0.144
# Precision = 0.782 vs. 0.078
# Recall = 0.889 vs. 0.980
# Validation: 1300
# AUC = 0.889 vs. 0.073
# F1 = 0.826 vs. 0.135
# Precision = 0.785 vs. 0.073
# Recall = 0.871 vs. 0.902
# Minibatch Loss= 0.304741
# Training: 1400
# AUC = 0.875 vs. 0.078
# F1 = 0.836 vs. 0.147
# Precision = 0.745 vs. 0.081
# Recall = 0.953 vs. 0.798
# Validation: 1400
# AUC = 0.870 vs. 0.075
# F1 = 0.814 vs. 0.135
# Precision = 0.803 vs. 0.073
# Recall = 0.826 vs. 0.996
# Minibatch Loss= 0.310984
# Training: 1500
# AUC = 0.900 vs. 0.066
# F1 = 0.827 vs. 0.133
# Precision = 0.814 vs. 0.071
# Recall = 0.841 vs. 1.000
# Validation: 1500
# AUC = 0.889 vs. 0.073
# F1 = 0.829 vs. 0.135
# Precision = 0.771 vs. 0.073
# Recall = 0.895 vs. 0.995
# Minibatch Loss= 0.273806
# Training: 1600
# AUC = 0.868 vs. 0.063
# F1 = 0.808 vs. 0.119
# Precision = 0.750 vs. 0.063
# Recall = 0.877 vs. 0.929
# Validation: 1600
# AUC = 0.885 vs. 0.074
# F1 = 0.817 vs. 0.136
# Precision = 0.796 vs. 0.075
# Recall = 0.838 vs. 0.725
# Minibatch Loss= 0.278575
# Training: 1700
# AUC = 0.907 vs. 0.073
# F1 = 0.821 vs. 0.136
# Precision = 0.860 vs. 0.073
# Recall = 0.786 vs. 1.000
# Validation: 1700
# AUC = 0.886 vs. 0.071
# F1 = 0.820 vs. 0.135
# Precision = 0.796 vs. 0.072
# Recall = 0.845 vs. 1.000
# Minibatch Loss= 0.327993
# Training: 1800
# AUC = 0.878 vs. 0.068
# F1 = 0.830 vs. 0.119
# Precision = 0.768 vs. 0.064
# Recall = 0.903 vs. 0.857
# Validation: 1800
# AUC = 0.885 vs. 0.074
# F1 = 0.815 vs. 0.135
# Precision = 0.794 vs. 0.073
# Recall = 0.837 vs. 0.991
# Minibatch Loss= 0.235123
# Training: 1900
# AUC = 0.897 vs. 0.091
# F1 = 0.847 vs. 0.155
# Precision = 0.810 vs. 0.085
# Recall = 0.887 vs. 0.953
# Validation: 1900
# AUC = 0.899 vs. 0.073
# F1 = 0.826 vs. 0.136
# Precision = 0.798 vs. 0.073
# Recall = 0.856 vs. 0.978
# Minibatch Loss= 0.369177
# Training: 2000
# AUC = 0.903 vs. 0.073
# F1 = 0.857 vs. 0.146
# Precision = 0.787 vs. 0.079
# Recall = 0.940 vs. 1.000
# Validation: 2000
# AUC = 0.912 vs. 0.073
# F1 = 0.841 vs. 0.135
# Precision = 0.801 vs. 0.073
# Recall = 0.884 vs. 0.987
# Minibatch Loss= 0.298843
# Training: 2100
# AUC = 0.944 vs. 0.090
# F1 = 0.867 vs. 0.163
# Precision = 0.795 vs. 0.099
# Recall = 0.953 vs. 0.458
# Validation: 2100
# AUC = 0.903 vs. 0.070
# F1 = 0.834 vs. 0.136
# Precision = 0.809 vs. 0.073
# Recall = 0.861 vs. 0.989
# Minibatch Loss= 0.291390
# Training: 2200
# AUC = 0.920 vs. 0.080
# F1 = 0.837 vs. 0.152
# Precision = 0.801 vs. 0.083
# Recall = 0.876 vs. 0.861
# Validation: 2200
# AUC = 0.906 vs. 0.072
# F1 = 0.836 vs. 0.135
# Precision = 0.814 vs. 0.073
# Recall = 0.859 vs. 1.000
# Minibatch Loss= 0.304621
# Training: 2300
# AUC = 0.878 vs. 0.074
# F1 = 0.857 vs. 0.132
# Precision = 0.809 vs. 0.071
# Recall = 0.912 vs. 1.000
# Validation: 2300
# AUC = 0.885 vs. 0.072
# F1 = 0.819 vs. 0.135
# Precision = 0.780 vs. 0.073
# Recall = 0.862 vs. 0.991
# Minibatch Loss= 0.287511
# Training: 2400
# AUC = 0.897 vs. 0.091
# F1 = 0.860 vs. 0.151
# Precision = 0.844 vs. 0.082
# Recall = 0.877 vs. 0.966
# Validation: 2400
# AUC = 0.899 vs. 0.072
# F1 = 0.829 vs. 0.135
# Precision = 0.768 vs. 0.073
# Recall = 0.900 vs. 0.980
# Minibatch Loss= 0.312759
# Training: 2500
# AUC = 0.919 vs. 0.083
# F1 = 0.861 vs. 0.153
# Precision = 0.829 vs. 0.083
# Recall = 0.896 vs. 1.000
# Validation: 2500
# AUC = 0.918 vs. 0.073
# F1 = 0.846 vs. 0.136
# Precision = 0.827 vs. 0.073
# Recall = 0.866 vs. 0.962
# Minibatch Loss= 0.382433
# Training: 2600
# AUC = 0.911 vs. 0.077
# F1 = 0.827 vs. 0.144
# Precision = 0.827 vs. 0.078
# Recall = 0.827 vs. 0.944
# Validation: 2600
# AUC = 0.910 vs. 0.077
# F1 = 0.840 vs. 0.137
# Precision = 0.807 vs. 0.075
# Recall = 0.875 vs. 0.825
# Minibatch Loss= 0.357991
# Training: 2700
# AUC = 0.842 vs. 0.070
# F1 = 0.817 vs. 0.131
# Precision = 0.748 vs. 0.075
# Recall = 0.901 vs. 0.509
# Validation: 2700
# AUC = 0.900 vs. 0.072
# F1 = 0.829 vs. 0.135
# Precision = 0.801 vs. 0.073
# Recall = 0.859 vs. 0.911
# Minibatch Loss= 0.312575
# Training: 2800
# AUC = 0.930 vs. 0.075
# F1 = 0.869 vs. 0.146
# Precision = 0.848 vs. 0.079
# Recall = 0.891 vs. 1.000
# Validation: 2800
# AUC = 0.904 vs. 0.074
# F1 = 0.833 vs. 0.136
# Precision = 0.789 vs. 0.073
# Recall = 0.881 vs. 0.998
# Minibatch Loss= 0.307816
# Training: 2900
# AUC = 0.909 vs. 0.064
# F1 = 0.835 vs. 0.127
# Precision = 0.788 vs. 0.068
# Recall = 0.889 vs. 0.883
# Validation: 2900
# AUC = 0.913 vs. 0.076
# F1 = 0.833 vs. 0.137
# Precision = 0.829 vs. 0.074
# Recall = 0.837 vs. 0.873
# Minibatch Loss= 0.251656
# Training: 3000
# AUC = 0.941 vs. 0.070
# F1 = 0.873 vs. 0.131
# Precision = 0.871 vs. 0.070
# Recall = 0.876 vs. 0.972
# Validation: 3000
# AUC = 0.911 vs. 0.073
# F1 = 0.836 vs. 0.135
# Precision = 0.811 vs. 0.073
# Recall = 0.864 vs. 0.994
# Minibatch Loss= 0.257366
# Training: 3100
# AUC = 0.930 vs. 0.082
# F1 = 0.884 vs. 0.148
# Precision = 0.819 vs. 0.080
# Recall = 0.960 vs. 0.970
# Validation: 3100
# AUC = 0.896 vs. 0.075
# F1 = 0.831 vs. 0.136
# Precision = 0.796 vs. 0.074
# Recall = 0.870 vs. 0.889
# Minibatch Loss= 0.270047
# Training: 3200
# AUC = 0.922 vs. 0.081
# F1 = 0.854 vs. 0.146
# Precision = 0.830 vs. 0.079
# Recall = 0.880 vs. 0.985
# Validation: 3200
# AUC = 0.910 vs. 0.075
# F1 = 0.841 vs. 0.136
# Precision = 0.791 vs. 0.073
# Recall = 0.899 vs. 0.968
# Minibatch Loss= 0.305609
# Training: 3300
# AUC = 0.877 vs. 0.081
# F1 = 0.805 vs. 0.138
# Precision = 0.738 vs. 0.076
# Recall = 0.886 vs. 0.696
# Validation: 3300
# AUC = 0.903 vs. 0.071
# F1 = 0.833 vs. 0.135
# Precision = 0.794 vs. 0.073
# Recall = 0.875 vs. 0.951
# Minibatch Loss= 0.307561
# Training: 3400
# AUC = 0.891 vs. 0.065
# F1 = 0.810 vs. 0.133
# Precision = 0.813 vs. 0.074
# Recall = 0.808 vs. 0.703
# Validation: 3400
# AUC = 0.901 vs. 0.071
# F1 = 0.827 vs. 0.136
# Precision = 0.823 vs. 0.073
# Recall = 0.831 vs. 0.990
# Minibatch Loss= 0.273465
# Training: 3500
# AUC = 0.914 vs. 0.064
# F1 = 0.838 vs. 0.129
# Precision = 0.840 vs. 0.069
# Recall = 0.835 vs. 1.000
# Validation: 3500
# AUC = 0.905 vs. 0.072
# F1 = 0.833 vs. 0.136
# Precision = 0.791 vs. 0.074
# Recall = 0.879 vs. 0.873
# Minibatch Loss= 0.264678
# Training: 3600
# AUC = 0.906 vs. 0.091
# F1 = 0.848 vs. 0.158
# Precision = 0.784 vs. 0.091
# Recall = 0.924 vs. 0.619
# Validation: 3600
# AUC = 0.912 vs. 0.072
# F1 = 0.847 vs. 0.135
# Precision = 0.813 vs. 0.073
# Recall = 0.884 vs. 0.997
# Minibatch Loss= 0.284521
# Training: 3700
# AUC = 0.907 vs. 0.081
# F1 = 0.856 vs. 0.148
# Precision = 0.875 vs. 0.088
# Recall = 0.837 vs. 0.467
# Validation: 3700
# AUC = 0.912 vs. 0.075
# F1 = 0.843 vs. 0.136
# Precision = 0.805 vs. 0.073
# Recall = 0.886 vs. 0.930
# Minibatch Loss= 0.293276
# Training: 3800
# AUC = 0.926 vs. 0.085
# F1 = 0.859 vs. 0.146
# Precision = 0.834 vs. 0.081
# Recall = 0.884 vs. 0.784
# Validation: 3800
# AUC = 0.908 vs. 0.074
# F1 = 0.834 vs. 0.135
# Precision = 0.833 vs. 0.073
# Recall = 0.835 vs. 0.988
# Minibatch Loss= 0.309245
# Training: 3900
# AUC = 0.930 vs. 0.087
# F1 = 0.890 vs. 0.151
# Precision = 0.845 vs. 0.090
# Recall = 0.939 vs. 0.475
# Validation: 3900
# AUC = 0.915 vs. 0.072
# F1 = 0.851 vs. 0.135
# Precision = 0.826 vs. 0.072
# Recall = 0.878 vs. 0.999
# Minibatch Loss= 0.276165
# Training: 4000
# AUC = 0.929 vs. 0.087
# F1 = 0.859 vs. 0.154
# Precision = 0.817 vs. 0.083
# Recall = 0.906 vs. 1.000
# Validation: 4000
# AUC = 0.905 vs. 0.074
# F1 = 0.839 vs. 0.136
# Precision = 0.803 vs. 0.075
# Recall = 0.879 vs. 0.736
# Minibatch Loss= 0.288197
# Training: 4100
# AUC = 0.887 vs. 0.071
# F1 = 0.824 vs. 0.131
# Precision = 0.811 vs. 0.070
# Recall = 0.838 vs. 1.000
# Validation: 4100
# AUC = 0.894 vs. 0.074
# F1 = 0.836 vs. 0.136
# Precision = 0.795 vs. 0.074
# Recall = 0.881 vs. 0.853
# Minibatch Loss= 0.285644
# Training: 4200
# AUC = 0.873 vs. 0.077
# F1 = 0.802 vs. 0.150
# Precision = 0.751 vs. 0.081
# Recall = 0.860 vs. 1.000
# Validation: 4200
# AUC = 0.908 vs. 0.073
# F1 = 0.835 vs. 0.135
# Precision = 0.817 vs. 0.073
# Recall = 0.854 vs. 0.998
# Minibatch Loss= 0.371023
# Training: 4300
# AUC = 0.941 vs. 0.080
# F1 = 0.893 vs. 0.147
# Precision = 0.897 vs. 0.081
# Recall = 0.888 vs. 0.802
# Validation: 4300
# AUC = 0.918 vs. 0.074
# F1 = 0.842 vs. 0.135
# Precision = 0.810 vs. 0.073
# Recall = 0.877 vs. 1.000
# Minibatch Loss= 0.254591
# Training: 4400
# AUC = 0.920 vs. 0.066
# F1 = 0.835 vs. 0.125
# Precision = 0.793 vs. 0.068
# Recall = 0.882 vs. 0.888
# Validation: 4400
# AUC = 0.907 vs. 0.073
# F1 = 0.835 vs. 0.135
# Precision = 0.806 vs. 0.072
# Recall = 0.867 vs. 0.997
# Minibatch Loss= 0.241185
# Training: 4500
# AUC = 0.916 vs. 0.097
# F1 = 0.864 vs. 0.162
# Precision = 0.841 vs. 0.089
# Recall = 0.888 vs. 0.907
# Validation: 4500
# AUC = 0.909 vs. 0.071
# F1 = 0.834 vs. 0.136
# Precision = 0.808 vs. 0.073
# Recall = 0.861 vs. 0.978
# Minibatch Loss= 0.309109
# Training: 4600
# AUC = 0.948 vs. 0.080
# F1 = 0.881 vs. 0.141
# Precision = 0.850 vs. 0.078
# Recall = 0.914 vs. 0.747
# Validation: 4600
# AUC = 0.914 vs. 0.073
# F1 = 0.845 vs. 0.135
# Precision = 0.836 vs. 0.072
# Recall = 0.854 vs. 1.000
# Minibatch Loss= 0.244441
# Training: 4700
# AUC = 0.943 vs. 0.076
# F1 = 0.878 vs. 0.158
# Precision = 0.797 vs. 0.086
# Recall = 0.977 vs. 0.995
# Validation: 4700
# AUC = 0.922 vs. 0.076
# F1 = 0.853 vs. 0.136
# Precision = 0.815 vs. 0.075
# Recall = 0.894 vs. 0.702
# Minibatch Loss= 0.280913
# Training: 4800
# AUC = 0.946 vs. 0.081
# F1 = 0.893 vs. 0.145
# Precision = 0.880 vs. 0.081
# Recall = 0.907 vs. 0.696
# Validation: 4800
# AUC = 0.912 vs. 0.074
# F1 = 0.851 vs. 0.137
# Precision = 0.809 vs. 0.075
# Recall = 0.896 vs. 0.765
# Minibatch Loss= 0.257485
# Training: 4900
# AUC = 0.933 vs. 0.070
# F1 = 0.850 vs. 0.126
# Precision = 0.840 vs. 0.074
# Recall = 0.861 vs. 0.418
# Validation: 4900
# AUC = 0.917 vs. 0.070
# F1 = 0.839 vs. 0.136
# Precision = 0.807 vs. 0.073
# Recall = 0.873 vs. 0.975
# Minibatch Loss= 0.241733
# Training: 5000
# AUC = 0.907 vs. 0.068
# F1 = 0.837 vs. 0.126
# Precision = 0.773 vs. 0.067
# Recall = 0.913 vs. 1.000
# Validation: 5000
# AUC = 0.909 vs. 0.076
# F1 = 0.835 vs. 0.135
# Precision = 0.801 vs. 0.073
# Recall = 0.872 vs. 0.999
# Minibatch Loss= 0.271877
# Training: 5100
# AUC = 0.941 vs. 0.071
# F1 = 0.879 vs. 0.141
# Precision = 0.845 vs. 0.076
# Recall = 0.916 vs. 0.916
# Validation: 5100
# AUC = 0.920 vs. 0.070
# F1 = 0.847 vs. 0.135
# Precision = 0.812 vs. 0.073
# Recall = 0.885 vs. 0.994
# Minibatch Loss= 0.279378
# Training: 5200
# AUC = 0.941 vs. 0.078
# F1 = 0.898 vs. 0.145
# Precision = 0.910 vs. 0.079
# Recall = 0.887 vs. 0.876
# Validation: 5200
# AUC = 0.915 vs. 0.073
# F1 = 0.840 vs. 0.135
# Precision = 0.805 vs. 0.072
# Recall = 0.878 vs. 0.999
# Minibatch Loss= 0.280063
# Training: 5300
# AUC = 0.930 vs. 0.073
# F1 = 0.876 vs. 0.135
# Precision = 0.867 vs. 0.073
# Recall = 0.886 vs. 0.989
# Validation: 5300
# AUC = 0.905 vs. 0.068
# F1 = 0.845 vs. 0.135
# Precision = 0.826 vs. 0.073
# Recall = 0.865 vs. 0.995
# Minibatch Loss= 0.274678
# Training: 5400
# AUC = 0.923 vs. 0.081
# F1 = 0.856 vs. 0.150
# Precision = 0.848 vs. 0.087
# Recall = 0.865 vs. 0.545
# Validation: 5400
# AUC = 0.911 vs. 0.073
# F1 = 0.836 vs. 0.136
# Precision = 0.809 vs. 0.073
# Recall = 0.865 vs. 0.974
# Minibatch Loss= 0.302450
# Training: 5500
# AUC = 0.944 vs. 0.087
# F1 = 0.884 vs. 0.150
# Precision = 0.838 vs. 0.083
# Recall = 0.936 vs. 0.789
# Validation: 5500
# AUC = 0.916 vs. 0.071
# F1 = 0.838 vs. 0.135
# Precision = 0.821 vs. 0.073
# Recall = 0.856 vs. 0.997
# Minibatch Loss= 0.264997
# Training: 5600
# AUC = 0.913 vs. 0.061
# F1 = 0.857 vs. 0.129
# Precision = 0.821 vs. 0.069
# Recall = 0.897 vs. 1.000
# Validation: 5600
# AUC = 0.919 vs. 0.075
# F1 = 0.845 vs. 0.135
# Precision = 0.845 vs. 0.073
# Recall = 0.844 vs. 0.991
# Minibatch Loss= 0.250891
# Training: 5700
# AUC = 0.945 vs. 0.082
# F1 = 0.889 vs. 0.147
# Precision = 0.899 vs. 0.079
# Recall = 0.880 vs. 0.964
# Validation: 5700
# AUC = 0.923 vs. 0.072
# F1 = 0.853 vs. 0.136
# Precision = 0.825 vs. 0.074
# Recall = 0.882 vs. 0.866
# Minibatch Loss= 0.265878
# Training: 5800
# AUC = 0.948 vs. 0.082
# F1 = 0.878 vs. 0.146
# Precision = 0.836 vs. 0.079
# Recall = 0.925 vs. 1.000
# Validation: 5800
# AUC = 0.911 vs. 0.073
# F1 = 0.846 vs. 0.136
# Precision = 0.814 vs. 0.074
# Recall = 0.880 vs. 0.896
# Minibatch Loss= 0.253213
# Training: 5900
# AUC = 0.955 vs. 0.086
# F1 = 0.898 vs. 0.153
# Precision = 0.877 vs. 0.083
# Recall = 0.919 vs. 0.962
# Validation: 5900
# AUC = 0.915 vs. 0.072
# F1 = 0.841 vs. 0.135
# Precision = 0.824 vs. 0.073
# Recall = 0.858 vs. 1.000
# Minibatch Loss= 0.274466
# Training: 6000
# AUC = 0.926 vs. 0.078
# F1 = 0.864 vs. 0.120
# Precision = 0.834 vs. 0.064
# Recall = 0.896 vs. 1.000
# Validation: 6000
# AUC = 0.909 vs. 0.073
# F1 = 0.843 vs. 0.137
# Precision = 0.816 vs. 0.074
# Recall = 0.871 vs. 0.933
# Minibatch Loss= 0.228125
# Training: 6100
# AUC = 0.919 vs. 0.065
# F1 = 0.833 vs. 0.126
# Precision = 0.843 vs. 0.067
# Recall = 0.824 vs. 0.965
# Validation: 6100
# AUC = 0.915 vs. 0.073
# F1 = 0.842 vs. 0.135
# Precision = 0.807 vs. 0.072
# Recall = 0.879 vs. 1.000
# Minibatch Loss= 0.236510
# Training: 6200
# AUC = 0.931 vs. 0.075
# F1 = 0.874 vs. 0.140
# Precision = 0.845 vs. 0.075
# Recall = 0.906 vs. 1.000
# Validation: 6200
# AUC = 0.920 vs. 0.074
# F1 = 0.850 vs. 0.135
# Precision = 0.826 vs. 0.073
# Recall = 0.875 vs. 0.998
# Minibatch Loss= 0.287999
# Training: 6300
# AUC = 0.934 vs. 0.083
# F1 = 0.855 vs. 0.150
# Precision = 0.772 vs. 0.092
# Recall = 0.959 vs. 0.402
# Validation: 6300
# AUC = 0.913 vs. 0.073
# F1 = 0.839 vs. 0.135
# Precision = 0.788 vs. 0.073
# Recall = 0.897 vs. 1.000
# Minibatch Loss= 0.252904
# Training: 6400
# AUC = 0.922 vs. 0.076
# F1 = 0.840 vs. 0.142
# Precision = 0.882 vs. 0.077
# Recall = 0.801 vs. 1.000
# Validation: 6400
# AUC = 0.921 vs. 0.070
# F1 = 0.842 vs. 0.136
# Precision = 0.814 vs. 0.073
# Recall = 0.871 vs. 0.984
# Minibatch Loss= 0.293481
# Training: 6500
# AUC = 0.933 vs. 0.069
# F1 = 0.892 vs. 0.144
# Precision = 0.870 vs. 0.078
# Recall = 0.914 vs. 1.000
# Validation: 6500
# AUC = 0.919 vs. 0.072
# F1 = 0.840 vs. 0.135
# Precision = 0.798 vs. 0.072
# Recall = 0.888 vs. 0.996
# Minibatch Loss= 0.253349
# Training: 6600
# AUC = 0.948 vs. 0.072
# F1 = 0.875 vs. 0.135
# Precision = 0.904 vs. 0.074
# Recall = 0.847 vs. 0.746
# Validation: 6600
# AUC = 0.924 vs. 0.072
# F1 = 0.844 vs. 0.136
# Precision = 0.807 vs. 0.073
# Recall = 0.884 vs. 0.946
# Minibatch Loss= 0.213010
# Training: 6700
# AUC = 0.951 vs. 0.069
# F1 = 0.896 vs. 0.134
# Precision = 0.873 vs. 0.073
# Recall = 0.921 vs. 0.860
# Validation: 6700
# AUC = 0.912 vs. 0.073
# F1 = 0.828 vs. 0.135
# Precision = 0.812 vs. 0.073
# Recall = 0.844 vs. 0.999
# Minibatch Loss= 0.215532
# Training: 6800
# AUC = 0.937 vs. 0.072
# F1 = 0.884 vs. 0.140
# Precision = 0.884 vs. 0.075
# Recall = 0.884 vs. 0.942
# Validation: 6800
# AUC = 0.918 vs. 0.071
# F1 = 0.842 vs. 0.135
# Precision = 0.831 vs. 0.073
# Recall = 0.853 vs. 0.936
# Minibatch Loss= 0.261492
# Training: 6900
# AUC = 0.937 vs. 0.069
# F1 = 0.876 vs. 0.126
# Precision = 0.829 vs. 0.070
# Recall = 0.928 vs. 0.659
# Validation: 6900
# AUC = 0.912 vs. 0.073
# F1 = 0.839 vs. 0.135
# Precision = 0.833 vs. 0.072
# Recall = 0.845 vs. 1.000
# Minibatch Loss= 0.210615
# Training: 7000
# AUC = 0.939 vs. 0.078
# F1 = 0.874 vs. 0.134
# Precision = 0.874 vs. 0.072
# Recall = 0.874 vs. 1.000
# Validation: 7000
# AUC = 0.920 vs. 0.073
# F1 = 0.840 vs. 0.135
# Precision = 0.799 vs. 0.073
# Recall = 0.885 vs. 0.992
# Minibatch Loss= 0.239615
# Training: 7100
# AUC = 0.945 vs. 0.070
# F1 = 0.875 vs. 0.133
# Precision = 0.833 vs. 0.072
# Recall = 0.920 vs. 0.859
# Validation: 7100
# AUC = 0.921 vs. 0.072
# F1 = 0.847 vs. 0.137
# Precision = 0.833 vs. 0.074
# Recall = 0.861 vs. 0.938
# Minibatch Loss= 0.206466
# Training: 7200
# AUC = 0.948 vs. 0.074
# F1 = 0.884 vs. 0.126
# Precision = 0.838 vs. 0.070
# Recall = 0.936 vs. 0.655
# Validation: 7200
# AUC = 0.919 vs. 0.072
# F1 = 0.840 vs. 0.135
# Precision = 0.837 vs. 0.073
# Recall = 0.843 vs. 0.978
# Minibatch Loss= 0.191949
# Training: 7300
# AUC = 0.956 vs. 0.079
# F1 = 0.882 vs. 0.148
# Precision = 0.921 vs. 0.084
# Recall = 0.845 vs. 0.644
# Validation: 7300
# AUC = 0.911 vs. 0.073
# F1 = 0.837 vs. 0.135
# Precision = 0.805 vs. 0.072
# Recall = 0.872 vs. 1.000
# Minibatch Loss= 0.246132
# Training: 7400
# AUC = 0.949 vs. 0.081
# F1 = 0.890 vs. 0.162
# Precision = 0.890 vs. 0.092
# Recall = 0.890 vs. 0.636
# Validation: 7400
# AUC = 0.920 vs. 0.072
# F1 = 0.849 vs. 0.136
# Precision = 0.838 vs. 0.073
# Recall = 0.861 vs. 0.977
# Minibatch Loss= 0.243690
# Training: 7500
# AUC = 0.962 vs. 0.082
# F1 = 0.898 vs. 0.153
# Precision = 0.864 vs. 0.086
# Recall = 0.934 vs. 0.672
# Validation: 7500
# AUC = 0.922 vs. 0.072
# F1 = 0.842 vs. 0.136
# Precision = 0.815 vs. 0.073
# Recall = 0.871 vs. 0.954
# Minibatch Loss= 0.243147
# Training: 7600
# AUC = 0.922 vs. 0.070
# F1 = 0.875 vs. 0.134
# Precision = 0.868 vs. 0.072
# Recall = 0.883 vs. 0.978
# Validation: 7600
# AUC = 0.905 vs. 0.071
# F1 = 0.838 vs. 0.135
# Precision = 0.814 vs. 0.072
# Recall = 0.863 vs. 1.000
# Minibatch Loss= 0.241936
# Training: 7700
# AUC = 0.945 vs. 0.065
# F1 = 0.885 vs. 0.129
# Precision = 0.844 vs. 0.069
# Recall = 0.931 vs. 1.000
# Validation: 7700
# AUC = 0.916 vs. 0.071
# F1 = 0.841 vs. 0.136
# Precision = 0.816 vs. 0.073
# Recall = 0.867 vs. 0.930
# Minibatch Loss= 0.231198
# Training: 7800
# AUC = 0.959 vs. 0.061
# F1 = 0.912 vs. 0.126
# Precision = 0.864 vs. 0.067
# Recall = 0.965 vs. 1.000
# Validation: 7800
# AUC = 0.919 vs. 0.072
# F1 = 0.841 vs. 0.136
# Precision = 0.771 vs. 0.073
# Recall = 0.925 vs. 0.981
# Minibatch Loss= 0.216484
# Training: 7900
# AUC = 0.918 vs. 0.079
# F1 = 0.848 vs. 0.141
# Precision = 0.869 vs. 0.077
# Recall = 0.828 vs. 0.828
# Validation: 7900
# AUC = 0.918 vs. 0.074
# F1 = 0.841 vs. 0.136
# Precision = 0.793 vs. 0.073
# Recall = 0.895 vs. 0.987
# Minibatch Loss= 0.283103
# Training: 8000
# AUC = 0.961 vs. 0.081
# F1 = 0.893 vs. 0.141
# Precision = 0.905 vs. 0.076
# Recall = 0.881 vs. 1.000
# Validation: 8000
# AUC = 0.918 vs. 0.075
# F1 = 0.845 vs. 0.136
# Precision = 0.819 vs. 0.074
# Recall = 0.873 vs. 0.851
# Minibatch Loss= 0.241254
# Training: 8100
# AUC = 0.956 vs. 0.076
# F1 = 0.904 vs. 0.150
# Precision = 0.876 vs. 0.082
# Recall = 0.934 vs. 0.883
# Validation: 8100
# AUC = 0.917 vs. 0.073
# F1 = 0.840 vs. 0.135
# Precision = 0.806 vs. 0.073
# Recall = 0.878 vs. 0.990
# Minibatch Loss= 0.265444
# Training: 8200
# AUC = 0.970 vs. 0.076
# F1 = 0.926 vs. 0.146
# Precision = 0.921 vs. 0.079
# Recall = 0.930 vs. 1.000
# Validation: 8200
# AUC = 0.922 vs. 0.072
# F1 = 0.842 vs. 0.135
# Precision = 0.803 vs. 0.072
# Recall = 0.885 vs. 1.000
# Minibatch Loss= 0.212131
# Training: 8300
# AUC = 0.941 vs. 0.082
# F1 = 0.860 vs. 0.141
# Precision = 0.835 vs. 0.076
# Recall = 0.887 vs. 1.000
# Validation: 8300
# AUC = 0.909 vs. 0.072
# F1 = 0.841 vs. 0.135
# Precision = 0.828 vs. 0.073
# Recall = 0.854 vs. 0.995
# Minibatch Loss= 0.266201
# Training: 8400
# AUC = 0.938 vs. 0.086
# F1 = 0.871 vs. 0.151
# Precision = 0.834 vs. 0.085
# Recall = 0.912 vs. 0.699
# Validation: 8400
# AUC = 0.916 vs. 0.074
# F1 = 0.842 vs. 0.135
# Precision = 0.819 vs. 0.073
# Recall = 0.866 vs. 1.000
# Minibatch Loss= 0.246893
# Training: 8500
# AUC = 0.946 vs. 0.076
# F1 = 0.893 vs. 0.141
# Precision = 0.859 vs. 0.081
# Recall = 0.929 vs. 0.560
# Validation: 8500
# AUC = 0.917 vs. 0.073
# F1 = 0.843 vs. 0.136
# Precision = 0.814 vs. 0.073
# Recall = 0.874 vs. 0.975
# Minibatch Loss= 0.228323
# Training: 8600
# AUC = 0.948 vs. 0.077
# F1 = 0.874 vs. 0.151
# Precision = 0.847 vs. 0.081
# Recall = 0.904 vs. 1.000
# Validation: 8600
# AUC = 0.919 vs. 0.071
# F1 = 0.842 vs. 0.135
# Precision = 0.800 vs. 0.073
# Recall = 0.889 vs. 0.998
# Minibatch Loss= 0.266383
# Training: 8700
# AUC = 0.935 vs. 0.072
# F1 = 0.864 vs. 0.141
# Precision = 0.839 vs. 0.078
# Recall = 0.891 vs. 0.788
# Validation: 8700
# AUC = 0.921 vs. 0.070
# F1 = 0.840 vs. 0.135
# Precision = 0.802 vs. 0.072
# Recall = 0.882 vs. 1.000
# Minibatch Loss= 0.270286
# Training: 8800
# AUC = 0.950 vs. 0.066
# F1 = 0.885 vs. 0.120
# Precision = 0.883 vs. 0.069
# Recall = 0.888 vs. 0.491
# Validation: 8800
# AUC = 0.919 vs. 0.071
# F1 = 0.847 vs. 0.135
# Precision = 0.808 vs. 0.073
# Recall = 0.891 vs. 0.998
# Minibatch Loss= 0.199788
# Training: 8900
# AUC = 0.931 vs. 0.075
# F1 = 0.881 vs. 0.148
# Precision = 0.836 vs. 0.080
# Recall = 0.931 vs. 0.946
# Validation: 8900
# AUC = 0.914 vs. 0.073
# F1 = 0.840 vs. 0.135
# Precision = 0.815 vs. 0.073
# Recall = 0.867 vs. 0.982
# Minibatch Loss= 0.281514
# Training: 9000
# AUC = 0.972 vs. 0.076
# F1 = 0.915 vs. 0.149
# Precision = 0.909 vs. 0.080
# Recall = 0.922 vs. 1.000
# Validation: 9000
# AUC = 0.920 vs. 0.072
# F1 = 0.844 vs. 0.135
# Precision = 0.803 vs. 0.073
# Recall = 0.890 vs. 0.997
# Minibatch Loss= 0.230247
# Training: 9100
# AUC = 0.955 vs. 0.081
# F1 = 0.887 vs. 0.154
# Precision = 0.880 vs. 0.084
# Recall = 0.893 vs. 0.883
# Validation: 9100
# AUC = 0.922 vs. 0.072
# F1 = 0.840 vs. 0.135
# Precision = 0.804 vs. 0.072
# Recall = 0.880 vs. 1.000
# Minibatch Loss= 0.246833
# Training: 9200
# AUC = 0.947 vs. 0.090
# F1 = 0.881 vs. 0.157
# Precision = 0.881 vs. 0.086
# Recall = 0.881 vs. 0.924
# Validation: 9200
# AUC = 0.917 vs. 0.072
# F1 = 0.836 vs. 0.135
# Precision = 0.831 vs. 0.073
# Recall = 0.841 vs. 0.996
# Minibatch Loss= 0.257879
# Training: 9300
# AUC = 0.971 vs. 0.078
# F1 = 0.904 vs. 0.142
# Precision = 0.902 vs. 0.090
# Recall = 0.907 vs. 0.335
# Validation: 9300
# AUC = 0.918 vs. 0.073
# F1 = 0.844 vs. 0.137
# Precision = 0.801 vs. 0.074
# Recall = 0.892 vs. 0.853
# Minibatch Loss= 0.214209
# Training: 9400
# AUC = 0.960 vs. 0.090
# F1 = 0.900 vs. 0.154
# Precision = 0.883 vs. 0.089
# Recall = 0.919 vs. 0.604
# Validation: 9400
# AUC = 0.924 vs. 0.073
# F1 = 0.851 vs. 0.136
# Precision = 0.839 vs. 0.073
# Recall = 0.864 vs. 0.983
# Minibatch Loss= 0.222763
# Training: 9500
# AUC = 0.947 vs. 0.076
# F1 = 0.905 vs. 0.148
# Precision = 0.873 vs. 0.080
# Recall = 0.939 vs. 0.919
# Validation: 9500
# AUC = 0.922 vs. 0.075
# F1 = 0.848 vs. 0.136
# Precision = 0.825 vs. 0.074
# Recall = 0.872 vs. 0.838
# Minibatch Loss= 0.238298
# Training: 9600
# AUC = 0.966 vs. 0.084
# F1 = 0.903 vs. 0.149
# Precision = 0.915 vs. 0.081
# Recall = 0.892 vs. 0.912
# Validation: 9600
# AUC = 0.914 vs. 0.073
# F1 = 0.844 vs. 0.136
# Precision = 0.840 vs. 0.073
# Recall = 0.848 vs. 0.954
# Minibatch Loss= 0.230345
# Training: 9700
# AUC = 0.920 vs. 0.066
# F1 = 0.858 vs. 0.133
# Precision = 0.901 vs. 0.072
# Recall = 0.819 vs. 0.881
# Validation: 9700
# AUC = 0.907 vs. 0.074
# F1 = 0.834 vs. 0.136
# Precision = 0.849 vs. 0.073
# Recall = 0.819 vs. 0.915
# Minibatch Loss= 0.248599
# Training: 9800
# AUC = 0.957 vs. 0.084
# F1 = 0.884 vs. 0.160
# Precision = 0.920 vs. 0.094
# Recall = 0.851 vs. 0.549
# Validation: 9800
# AUC = 0.914 vs. 0.072
# F1 = 0.842 vs. 0.135
# Precision = 0.821 vs. 0.073
# Recall = 0.864 vs. 0.999
# Minibatch Loss= 0.273565
# Training: 9900
# AUC = 0.971 vs. 0.074
# F1 = 0.920 vs. 0.153
# Precision = 0.899 vs. 0.083
# Recall = 0.942 vs. 1.000
# Validation: 9900
# AUC = 0.920 vs. 0.072
# F1 = 0.840 vs. 0.135
# Precision = 0.803 vs. 0.073
# Recall = 0.881 vs. 0.999
# Minibatch Loss= 0.232840
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model_synthetic/train_abrupt_test_gradual/DWN1001_x/DWN1001_x-10000'

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.935 vs. 0.281
# F1 = 0.853 vs. 0.439
# Precision = 0.830 vs. 0.281
# Recall = 0.877 vs. 1.000

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
