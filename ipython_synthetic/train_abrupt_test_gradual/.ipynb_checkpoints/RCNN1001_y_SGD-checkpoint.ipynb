# %%
# useing this variable for saving models and summaries
exp_name = "RCNN1001_y"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,64,64, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../src')
sys.path.append('../../src/models')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed3.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]

bias_shape = [32,64,64, 64, 64]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 1


#positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
pos_weight
# Out:
# 14.854262989736288

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables, n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride,
                         weights_shape,
                         bias_shape,
                         activation,
                         lstm_n_hidden,
                         n_classes,
                         learning_rate,
                         pos_weight,
                         trainable_conv=True,
                         trainable_last=True)

# %%
train_obj = training.Trainer(model,
                 train_data, train_gt,
                 validation_data, validation_gt,
                 sess,
                 summary_path,
                 batch_size,
                 global_step = 0)

# %%
train_obj.train(max_iter = 10000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 0
# AUC = 0.104 vs. 0.056
# F1 = 0.126 vs. 0.114
# Precision = 0.068 vs. 0.061
# Recall = 0.950 vs. 0.975
# Validation: 0
# AUC = 0.134 vs. 0.075
# F1 = 0.247 vs. 0.165
# Precision = 0.147 vs. 0.090
# Recall = 0.783 vs. 1.000
# Minibatch Loss= 1.545129
# Training: 100
# AUC = 0.985 vs. 0.059
# F1 = 0.938 vs. 0.116
# Precision = 0.942 vs. 0.062
# Recall = 0.934 vs. 0.959
# Validation: 100
# AUC = 0.119 vs. 0.134
# F1 = 0.193 vs. 0.212
# Precision = 0.109 vs. 0.163
# Recall = 0.826 vs. 0.304
# Minibatch Loss= 0.183488
# Training: 200
# AUC = 0.925 vs. 0.055
# F1 = 0.850 vs. 0.113
# Precision = 0.833 vs. 0.060
# Recall = 0.868 vs. 0.992
# Validation: 200
# AUC = 0.261 vs. 0.116
# F1 = 0.284 vs. 0.174
# Precision = 0.202 vs. 0.116
# Recall = 0.478 vs. 0.348
# Minibatch Loss= 0.247138
# Training: 300
# AUC = 0.997 vs. 0.067
# F1 = 0.983 vs. 0.123
# Precision = 1.000 vs. 0.074
# Recall = 0.967 vs. 0.364
# Validation: 300
# AUC = 0.177 vs. 0.158
# F1 = 0.276 vs. 0.202
# Precision = 0.165 vs. 0.209
# Recall = 0.848 vs. 0.196
# Minibatch Loss= 0.156044
# Training: 400
# AUC = 0.999 vs. 0.059
# F1 = 0.992 vs. 0.116
# Precision = 1.000 vs. 0.063
# Recall = 0.983 vs. 0.810
# Validation: 400
# AUC = 0.177 vs. 0.104
# F1 = 0.279 vs. 0.182
# Precision = 0.169 vs. 0.101
# Recall = 0.804 vs. 0.935
# Minibatch Loss= 0.151582
# Training: 500
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.080
# Recall = 1.000 vs. 0.248
# Validation: 500
# AUC = 0.215 vs. 0.077
# F1 = 0.281 vs. 0.168
# Precision = 0.170 vs. 0.091
# Recall = 0.826 vs. 1.000
# Minibatch Loss= 0.150374
# Training: 600
# AUC = 0.999 vs. 0.057
# F1 = 0.988 vs. 0.115
# Precision = 0.984 vs. 0.063
# Recall = 0.992 vs. 0.686
# Validation: 600
# AUC = 0.229 vs. 0.095
# F1 = 0.272 vs. 0.176
# Precision = 0.168 vs. 0.097
# Recall = 0.717 vs. 0.913
# Minibatch Loss= 0.151571
# Training: 700
# AUC = 1.000 vs. 0.050
# F1 = 0.992 vs. 0.112
# Precision = 0.992 vs. 0.059
# Recall = 0.992 vs. 1.000
# Validation: 700
# AUC = 0.230 vs. 0.098
# F1 = 0.278 vs. 0.175
# Precision = 0.170 vs. 0.105
# Recall = 0.761 vs. 0.522
# Minibatch Loss= 0.149223
# Training: 800
# AUC = 1.000 vs. 0.055
# F1 = 0.996 vs. 0.113
# Precision = 0.992 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 800
# AUC = 0.246 vs. 0.105
# F1 = 0.284 vs. 0.170
# Precision = 0.172 vs. 0.093
# Recall = 0.804 vs. 0.957
# Minibatch Loss= 0.149053
# Training: 900
# AUC = 1.000 vs. 0.070
# F1 = 0.996 vs. 0.123
# Precision = 0.992 vs. 0.067
# Recall = 1.000 vs. 0.818
# Validation: 900
# AUC = 0.247 vs. 0.075
# F1 = 0.275 vs. 0.171
# Precision = 0.167 vs. 0.094
# Recall = 0.783 vs. 0.935
# Minibatch Loss= 0.148763
# Training: 1000
# AUC = 1.000 vs. 0.077
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.074
# Recall = 1.000 vs. 0.446
# Validation: 1000
# AUC = 0.245 vs. 0.090
# F1 = 0.273 vs. 0.166
# Precision = 0.167 vs. 0.091
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.148623
# Training: 1100
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.125
# Precision = 1.000 vs. 0.068
# Recall = 1.000 vs. 0.818
# Validation: 1100
# AUC = 0.243 vs. 0.141
# F1 = 0.275 vs. 0.229
# Precision = 0.167 vs. 0.155
# Recall = 0.761 vs. 0.435
# Minibatch Loss= 0.148523
# Training: 1200
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.068
# Recall = 1.000 vs. 0.380
# Validation: 1200
# AUC = 0.242 vs. 0.073
# F1 = 0.270 vs. 0.166
# Precision = 0.163 vs. 0.090
# Recall = 0.783 vs. 1.000
# Minibatch Loss= 0.148909
# Training: 1300
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.653
# Validation: 1300
# AUC = 0.245 vs. 0.088
# F1 = 0.266 vs. 0.169
# Precision = 0.160 vs. 0.104
# Recall = 0.783 vs. 0.457
# Minibatch Loss= 0.148712
# Training: 1400
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.975
# Validation: 1400
# AUC = 0.241 vs. 0.132
# F1 = 0.264 vs. 0.196
# Precision = 0.162 vs. 0.123
# Recall = 0.717 vs. 0.478
# Minibatch Loss= 0.148300
# Training: 1500
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.835
# Validation: 1500
# AUC = 0.247 vs. 0.097
# F1 = 0.262 vs. 0.187
# Precision = 0.157 vs. 0.105
# Recall = 0.804 vs. 0.870
# Minibatch Loss= 0.148239
# Training: 1600
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.909
# Validation: 1600
# AUC = 0.253 vs. 0.107
# F1 = 0.262 vs. 0.181
# Precision = 0.157 vs. 0.106
# Recall = 0.804 vs. 0.630
# Minibatch Loss= 0.148305
# Training: 1700
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.752
# Validation: 1700
# AUC = 0.250 vs. 0.131
# F1 = 0.259 vs. 0.200
# Precision = 0.154 vs. 0.235
# Recall = 0.804 vs. 0.174
# Minibatch Loss= 0.148119
# Training: 1800
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 1800
# AUC = 0.249 vs. 0.090
# F1 = 0.258 vs. 0.171
# Precision = 0.158 vs. 0.094
# Recall = 0.696 vs. 0.978
# Minibatch Loss= 0.148081
# Training: 1900
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.992
# Validation: 1900
# AUC = 0.250 vs. 0.113
# F1 = 0.259 vs. 0.206
# Precision = 0.159 vs. 0.122
# Recall = 0.696 vs. 0.674
# Minibatch Loss= 0.148149
# Training: 2000
# AUC = 1.000 vs. 0.067
# F1 = 0.996 vs. 0.125
# Precision = 1.000 vs. 0.097
# Recall = 0.992 vs. 0.174
# Validation: 2000
# AUC = 0.250 vs. 0.087
# F1 = 0.258 vs. 0.174
# Precision = 0.154 vs. 0.095
# Recall = 0.804 vs. 1.000
# Minibatch Loss= 0.148657
# Training: 2100
# AUC = 1.000 vs. 0.063
# F1 = 0.996 vs. 0.113
# Precision = 0.992 vs. 0.060
# Recall = 1.000 vs. 1.000
# Validation: 2100
# AUC = 0.246 vs. 0.088
# F1 = 0.256 vs. 0.178
# Precision = 0.152 vs. 0.102
# Recall = 0.804 vs. 0.696
# Minibatch Loss= 0.148379
# Training: 2200
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.135
# Precision = 1.000 vs. 0.088
# Recall = 1.000 vs. 0.289
# Validation: 2200
# AUC = 0.248 vs. 0.097
# F1 = 0.253 vs. 0.173
# Precision = 0.153 vs. 0.096
# Recall = 0.717 vs. 0.891
# Minibatch Loss= 0.148004
# Training: 2300
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.130
# Precision = 1.000 vs. 0.074
# Recall = 1.000 vs. 0.545
# Validation: 2300
# AUC = 0.245 vs. 0.120
# F1 = 0.254 vs. 0.201
# Precision = 0.154 vs. 0.135
# Recall = 0.717 vs. 0.391
# Minibatch Loss= 0.147975
# Training: 2400
# AUC = 1.000 vs. 0.058
# F1 = 0.996 vs. 0.113
# Precision = 0.992 vs. 0.061
# Recall = 1.000 vs. 0.868
# Validation: 2400
# AUC = 0.245 vs. 0.079
# F1 = 0.255 vs. 0.166
# Precision = 0.155 vs. 0.091
# Recall = 0.717 vs. 1.000
# Minibatch Loss= 0.147971
# Training: 2500
# AUC = 0.999 vs. 0.070
# F1 = 0.988 vs. 0.123
# Precision = 0.992 vs. 0.070
# Recall = 0.983 vs. 0.529
# Validation: 2500
# AUC = 0.244 vs. 0.098
# F1 = 0.253 vs. 0.195
# Precision = 0.153 vs. 0.115
# Recall = 0.717 vs. 0.652
# Minibatch Loss= 0.150434
# Training: 2600
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.069
# Recall = 1.000 vs. 0.512
# Validation: 2600
# AUC = 0.248 vs. 0.114
# F1 = 0.257 vs. 0.191
# Precision = 0.156 vs. 0.159
# Recall = 0.717 vs. 0.239
# Minibatch Loss= 0.147958
# Training: 2700
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.702
# Validation: 2700
# AUC = 0.244 vs. 0.087
# F1 = 0.256 vs. 0.181
# Precision = 0.156 vs. 0.103
# Recall = 0.717 vs. 0.717
# Minibatch Loss= 0.148015
# Training: 2800
# AUC = 1.000 vs. 0.070
# F1 = 0.996 vs. 0.135
# Precision = 1.000 vs. 0.083
# Recall = 0.992 vs. 0.355
# Validation: 2800
# AUC = 0.244 vs. 0.086
# F1 = 0.257 vs. 0.168
# Precision = 0.156 vs. 0.092
# Recall = 0.717 vs. 0.935
# Minibatch Loss= 0.148183
# Training: 2900
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.123
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.711
# Validation: 2900
# AUC = 0.242 vs. 0.078
# F1 = 0.254 vs. 0.176
# Precision = 0.154 vs. 0.098
# Recall = 0.717 vs. 0.870
# Minibatch Loss= 0.148183
# Training: 3000
# AUC = 1.000 vs. 0.056
# F1 = 0.996 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 0.992 vs. 0.785
# Validation: 3000
# AUC = 0.242 vs. 0.083
# F1 = 0.257 vs. 0.165
# Precision = 0.155 vs. 0.090
# Recall = 0.739 vs. 1.000
# Minibatch Loss= 0.148176
# Training: 3100
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.893
# Validation: 3100
# AUC = 0.244 vs. 0.090
# F1 = 0.258 vs. 0.180
# Precision = 0.157 vs. 0.101
# Recall = 0.717 vs. 0.783
# Minibatch Loss= 0.147962
# Training: 3200
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.322
# Validation: 3200
# AUC = 0.243 vs. 0.090
# F1 = 0.256 vs. 0.172
# Precision = 0.156 vs. 0.114
# Recall = 0.717 vs. 0.348
# Minibatch Loss= 0.147984
# Training: 3300
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.083
# Recall = 1.000 vs. 0.273
# Validation: 3300
# AUC = 0.241 vs. 0.077
# F1 = 0.256 vs. 0.170
# Precision = 0.156 vs. 0.093
# Recall = 0.717 vs. 1.000
# Minibatch Loss= 0.147913
# Training: 3400
# AUC = 1.000 vs. 0.065
# F1 = 0.996 vs. 0.120
# Precision = 0.992 vs. 0.071
# Recall = 1.000 vs. 0.388
# Validation: 3400
# AUC = 0.239 vs. 0.097
# F1 = 0.254 vs. 0.185
# Precision = 0.153 vs. 0.118
# Recall = 0.739 vs. 0.435
# Minibatch Loss= 0.148107
# Training: 3500
# AUC = 1.000 vs. 0.056
# F1 = 0.988 vs. 0.112
# Precision = 0.976 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 3500
# AUC = 0.242 vs. 0.093
# F1 = 0.252 vs. 0.166
# Precision = 0.153 vs. 0.091
# Recall = 0.717 vs. 1.000
# Minibatch Loss= 0.148881
# Training: 3600
# AUC = 0.998 vs. 0.059
# F1 = 0.979 vs. 0.116
# Precision = 0.983 vs. 0.062
# Recall = 0.975 vs. 0.959
# Validation: 3600
# AUC = 0.188 vs. 0.103
# F1 = 0.338 vs. 0.184
# Precision = 0.245 vs. 0.115
# Recall = 0.543 vs. 0.457
# Minibatch Loss= 0.159445
# Training: 3700
# AUC = 1.000 vs. 0.056
# F1 = 0.992 vs. 0.116
# Precision = 0.992 vs. 0.064
# Recall = 0.992 vs. 0.678
# Validation: 3700
# AUC = 0.157 vs. 0.089
# F1 = 0.301 vs. 0.165
# Precision = 0.191 vs. 0.090
# Recall = 0.717 vs. 1.000
# Minibatch Loss= 0.150970
# Training: 3800
# AUC = 1.000 vs. 0.060
# F1 = 0.992 vs. 0.112
# Precision = 0.984 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 3800
# AUC = 0.152 vs. 0.086
# F1 = 0.298 vs. 0.174
# Precision = 0.185 vs. 0.095
# Recall = 0.761 vs. 1.000
# Minibatch Loss= 0.149686
# Training: 3900
# AUC = 1.000 vs. 0.071
# F1 = 0.996 vs. 0.120
# Precision = 1.000 vs. 0.068
# Recall = 0.992 vs. 0.479
# Validation: 3900
# AUC = 0.148 vs. 0.092
# F1 = 0.274 vs. 0.174
# Precision = 0.169 vs. 0.096
# Recall = 0.717 vs. 0.935
# Minibatch Loss= 0.149107
# Training: 4000
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.876
# Validation: 4000
# AUC = 0.147 vs. 0.091
# F1 = 0.267 vs. 0.175
# Precision = 0.170 vs. 0.115
# Recall = 0.630 vs. 0.370
# Minibatch Loss= 0.148795
# Training: 4100
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.661
# Validation: 4100
# AUC = 0.161 vs. 0.099
# F1 = 0.269 vs. 0.185
# Precision = 0.169 vs. 0.104
# Recall = 0.652 vs. 0.848
# Minibatch Loss= 0.148549
# Training: 4200
# AUC = 1.000 vs. 0.075
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.793
# Validation: 4200
# AUC = 0.157 vs. 0.089
# F1 = 0.263 vs. 0.169
# Precision = 0.165 vs. 0.092
# Recall = 0.652 vs. 1.000
# Minibatch Loss= 0.148436
# Training: 4300
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.068
# Recall = 1.000 vs. 0.430
# Validation: 4300
# AUC = 0.154 vs. 0.103
# F1 = 0.262 vs. 0.205
# Precision = 0.164 vs. 0.145
# Recall = 0.652 vs. 0.348
# Minibatch Loss= 0.148425
# Training: 4400
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.752
# Validation: 4400
# AUC = 0.152 vs. 0.081
# F1 = 0.247 vs. 0.168
# Precision = 0.152 vs. 0.092
# Recall = 0.652 vs. 0.913
# Minibatch Loss= 0.148279
# Training: 4500
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.075
# Recall = 1.000 vs. 0.273
# Validation: 4500
# AUC = 0.147 vs. 0.155
# F1 = 0.241 vs. 0.209
# Precision = 0.157 vs. 0.150
# Recall = 0.522 vs. 0.348
# Minibatch Loss= 0.148310
# Training: 4600
# AUC = 0.999 vs. 0.059
# F1 = 0.980 vs. 0.113
# Precision = 0.960 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 4600
# AUC = 0.147 vs. 0.122
# F1 = 0.241 vs. 0.196
# Precision = 0.157 vs. 0.196
# Recall = 0.522 vs. 0.196
# Minibatch Loss= 0.148613
# Training: 4700
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.727
# Validation: 4700
# AUC = 0.145 vs. 0.082
# F1 = 0.242 vs. 0.169
# Precision = 0.158 vs. 0.092
# Recall = 0.522 vs. 1.000
# Minibatch Loss= 0.148149
# Training: 4800
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.136
# Precision = 1.000 vs. 0.074
# Recall = 1.000 vs. 0.802
# Validation: 4800
# AUC = 0.143 vs. 0.090
# F1 = 0.243 vs. 0.174
# Precision = 0.161 vs. 0.095
# Recall = 0.500 vs. 0.957
# Minibatch Loss= 0.148118
# Training: 4900
# AUC = 0.979 vs. 0.055
# F1 = 0.922 vs. 0.115
# Precision = 0.911 vs. 0.061
# Recall = 0.934 vs. 0.975
# Validation: 4900
# AUC = 0.274 vs. 0.106
# F1 = 0.405 vs. 0.185
# Precision = 0.290 vs. 0.119
# Recall = 0.674 vs. 0.413
# Minibatch Loss= 0.182959
# Training: 5000
# AUC = 1.000 vs. 0.068
# F1 = 0.996 vs. 0.131
# Precision = 0.992 vs. 0.079
# Recall = 1.000 vs. 0.380
# Validation: 5000
# AUC = 0.209 vs. 0.108
# F1 = 0.444 vs. 0.194
# Precision = 0.337 vs. 0.119
# Recall = 0.652 vs. 0.522
# Minibatch Loss= 0.149421
# Training: 5100
# AUC = 1.000 vs. 0.056
# F1 = 0.996 vs. 0.119
# Precision = 0.992 vs. 0.065
# Recall = 1.000 vs. 0.669
# Validation: 5100
# AUC = 0.200 vs. 0.104
# F1 = 0.429 vs. 0.180
# Precision = 0.319 vs. 0.100
# Recall = 0.652 vs. 0.913
# Minibatch Loss= 0.148800
# Training: 5200
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.129
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.645
# Validation: 5200
# AUC = 0.190 vs. 0.077
# F1 = 0.387 vs. 0.170
# Precision = 0.275 vs. 0.093
# Recall = 0.652 vs. 0.957
# Minibatch Loss= 0.148540
# Training: 5300
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.129
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.694
# Validation: 5300
# AUC = 0.175 vs. 0.079
# F1 = 0.331 vs. 0.168
# Precision = 0.253 vs. 0.091
# Recall = 0.478 vs. 1.000
# Minibatch Loss= 0.148396
# Training: 5400
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.777
# Validation: 5400
# AUC = 0.165 vs. 0.142
# F1 = 0.308 vs. 0.210
# Precision = 0.227 vs. 0.155
# Recall = 0.478 vs. 0.326
# Minibatch Loss= 0.148300
# Training: 5500
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.893
# Validation: 5500
# AUC = 0.159 vs. 0.088
# F1 = 0.287 vs. 0.178
# Precision = 0.178 vs. 0.101
# Recall = 0.739 vs. 0.761
# Minibatch Loss= 0.148226
# Training: 5600
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 5600
# AUC = 0.157 vs. 0.095
# F1 = 0.277 vs. 0.167
# Precision = 0.173 vs. 0.091
# Recall = 0.696 vs. 0.957
# Minibatch Loss= 0.148163
# Training: 5700
# AUC = 1.000 vs. 0.073
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.653
# Validation: 5700
# AUC = 0.155 vs. 0.092
# F1 = 0.276 vs. 0.170
# Precision = 0.173 vs. 0.094
# Recall = 0.674 vs. 0.913
# Minibatch Loss= 0.148114
# Training: 5800
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.950
# Validation: 5800
# AUC = 0.153 vs. 0.084
# F1 = 0.274 vs. 0.172
# Precision = 0.169 vs. 0.094
# Recall = 0.717 vs. 0.957
# Minibatch Loss= 0.148089
# Training: 5900
# AUC = 0.962 vs. 0.065
# F1 = 0.924 vs. 0.115
# Precision = 0.898 vs. 0.061
# Recall = 0.950 vs. 0.975
# Validation: 5900
# AUC = 0.329 vs. 0.094
# F1 = 0.384 vs. 0.181
# Precision = 0.304 vs. 0.104
# Recall = 0.522 vs. 0.696
# Minibatch Loss= 0.195009
# Training: 6000
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.123
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.438
# Validation: 6000
# AUC = 0.227 vs. 0.089
# F1 = 0.338 vs. 0.177
# Precision = 0.241 vs. 0.100
# Recall = 0.565 vs. 0.739
# Minibatch Loss= 0.148895
# Training: 6100
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.917
# Validation: 6100
# AUC = 0.224 vs. 0.087
# F1 = 0.312 vs. 0.176
# Precision = 0.219 vs. 0.097
# Recall = 0.543 vs. 0.957
# Minibatch Loss= 0.148388
# Training: 6200
# AUC = 1.000 vs. 0.086
# F1 = 1.000 vs. 0.139
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.405
# Validation: 6200
# AUC = 0.221 vs. 0.118
# F1 = 0.307 vs. 0.173
# Precision = 0.221 vs. 0.100
# Recall = 0.500 vs. 0.652
# Minibatch Loss= 0.148213
# Training: 6300
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.702
# Validation: 6300
# AUC = 0.218 vs. 0.102
# F1 = 0.304 vs. 0.181
# Precision = 0.241 vs. 0.112
# Recall = 0.413 vs. 0.478
# Minibatch Loss= 0.148127
# Training: 6400
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.826
# Validation: 6400
# AUC = 0.216 vs. 0.134
# F1 = 0.304 vs. 0.204
# Precision = 0.241 vs. 0.140
# Recall = 0.413 vs. 0.370
# Minibatch Loss= 0.148082
# Training: 6500
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.120
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.843
# Validation: 6500
# AUC = 0.208 vs. 0.091
# F1 = 0.304 vs. 0.166
# Precision = 0.258 vs. 0.090
# Recall = 0.370 vs. 1.000
# Minibatch Loss= 0.148066
# Training: 6600
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.512
# Validation: 6600
# AUC = 0.208 vs. 0.085
# F1 = 0.301 vs. 0.188
# Precision = 0.254 vs. 0.108
# Recall = 0.370 vs. 0.717
# Minibatch Loss= 0.148006
# Training: 6700
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.069
# Recall = 1.000 vs. 0.421
# Validation: 6700
# AUC = 0.200 vs. 0.094
# F1 = 0.295 vs. 0.181
# Precision = 0.229 vs. 0.103
# Recall = 0.413 vs. 0.739
# Minibatch Loss= 0.147979
# Training: 6800
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.587
# Validation: 6800
# AUC = 0.197 vs. 0.116
# F1 = 0.296 vs. 0.184
# Precision = 0.246 vs. 0.105
# Recall = 0.370 vs. 0.739
# Minibatch Loss= 0.147964
# Training: 6900
# AUC = 1.000 vs. 0.056
# F1 = 0.996 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 0.992 vs. 0.868
# Validation: 6900
# AUC = 0.125 vs. 0.085
# F1 = 0.186 vs. 0.165
# Precision = 0.104 vs. 0.090
# Recall = 0.870 vs. 1.000
# Minibatch Loss= 0.148750
# Training: 7000
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.793
# Validation: 7000
# AUC = 0.129 vs. 0.075
# F1 = 0.176 vs. 0.168
# Precision = 0.098 vs. 0.091
# Recall = 0.870 vs. 1.000
# Minibatch Loss= 0.148195
# Training: 7100
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.289
# Validation: 7100
# AUC = 0.131 vs. 0.113
# F1 = 0.173 vs. 0.172
# Precision = 0.097 vs. 0.096
# Recall = 0.783 vs. 0.848
# Minibatch Loss= 0.148064
# Training: 7200
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.736
# Validation: 7200
# AUC = 0.136 vs. 0.112
# F1 = 0.171 vs. 0.174
# Precision = 0.096 vs. 0.110
# Recall = 0.783 vs. 0.413
# Minibatch Loss= 0.148012
# Training: 7300
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 7300
# AUC = 0.136 vs. 0.110
# F1 = 0.171 vs. 0.181
# Precision = 0.094 vs. 0.101
# Recall = 0.935 vs. 0.913
# Minibatch Loss= 0.147976
# Training: 7400
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.934
# Validation: 7400
# AUC = 0.135 vs. 0.081
# F1 = 0.171 vs. 0.171
# Precision = 0.093 vs. 0.095
# Recall = 1.000 vs. 0.804
# Minibatch Loss= 0.147990
# Training: 7500
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.893
# Validation: 7500
# AUC = 0.135 vs. 0.085
# F1 = 0.171 vs. 0.169
# Precision = 0.094 vs. 0.092
# Recall = 1.000 vs. 0.978
# Minibatch Loss= 0.147949
# Training: 7600
# AUC = 1.000 vs. 0.053
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.942
# Validation: 7600
# AUC = 0.129 vs. 0.106
# F1 = 0.171 vs. 0.167
# Precision = 0.094 vs. 0.091
# Recall = 0.978 vs. 1.000
# Minibatch Loss= 0.147930
# Training: 7700
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.123
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.901
# Validation: 7700
# AUC = 0.129 vs. 0.093
# F1 = 0.173 vs. 0.173
# Precision = 0.095 vs. 0.121
# Recall = 0.957 vs. 0.304
# Minibatch Loss= 0.147910
# Training: 7800
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.909
# Validation: 7800
# AUC = 0.127 vs. 0.128
# F1 = 0.174 vs. 0.194
# Precision = 0.096 vs. 0.115
# Recall = 0.957 vs. 0.609
# Minibatch Loss= 0.147896
# Training: 7900
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.884
# Validation: 7900
# AUC = 0.126 vs. 0.082
# F1 = 0.173 vs. 0.169
# Precision = 0.095 vs. 0.093
# Recall = 0.957 vs. 0.957
# Minibatch Loss= 0.147888
# Training: 8000
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.537
# Validation: 8000
# AUC = 0.127 vs. 0.085
# F1 = 0.174 vs. 0.168
# Precision = 0.096 vs. 0.093
# Recall = 0.891 vs. 0.913
# Minibatch Loss= 0.147896
# Training: 8100
# AUC = 1.000 vs. 0.050
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 8100
# AUC = 0.127 vs. 0.115
# F1 = 0.174 vs. 0.179
# Precision = 0.096 vs. 0.113
# Recall = 0.891 vs. 0.435
# Minibatch Loss= 0.147879
# Training: 8200
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.521
# Validation: 8200
# AUC = 0.127 vs. 0.083
# F1 = 0.173 vs. 0.178
# Precision = 0.096 vs. 0.099
# Recall = 0.891 vs. 0.935
# Minibatch Loss= 0.148099
# Training: 8300
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.124
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.793
# Validation: 8300
# AUC = 0.129 vs. 0.118
# F1 = 0.173 vs. 0.206
# Precision = 0.095 vs. 0.131
# Recall = 0.957 vs. 0.478
# Minibatch Loss= 0.147871
# Training: 8400
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.719
# Validation: 8400
# AUC = 0.128 vs. 0.123
# F1 = 0.173 vs. 0.178
# Precision = 0.095 vs. 0.099
# Recall = 0.957 vs. 0.935
# Minibatch Loss= 0.148162
# Training: 8500
# AUC = 1.000 vs. 0.078
# F1 = 1.000 vs. 0.147
# Precision = 1.000 vs. 0.117
# Recall = 1.000 vs. 0.198
# Validation: 8500
# AUC = 0.131 vs. 0.169
# F1 = 0.173 vs. 0.250
# Precision = 0.095 vs. 0.294
# Recall = 0.957 vs. 0.217
# Minibatch Loss= 0.148162
# Training: 8600
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.135
# Precision = 1.000 vs. 0.105
# Recall = 1.000 vs. 0.190
# Validation: 8600
# AUC = 0.149 vs. 0.094
# F1 = 0.171 vs. 0.177
# Precision = 0.094 vs. 0.100
# Recall = 1.000 vs. 0.739
# Minibatch Loss= 0.147883
# Training: 8700
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.645
# Validation: 8700
# AUC = 0.147 vs. 0.091
# F1 = 0.171 vs. 0.171
# Precision = 0.093 vs. 0.094
# Recall = 1.000 vs. 0.935
# Minibatch Loss= 0.147952
# Training: 8800
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.562
# Validation: 8800
# AUC = 0.142 vs. 0.107
# F1 = 0.170 vs. 0.168
# Precision = 0.093 vs. 0.092
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.147879
# Training: 8900
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.339
# Validation: 8900
# AUC = 0.137 vs. 0.121
# F1 = 0.170 vs. 0.194
# Precision = 0.093 vs. 0.127
# Recall = 1.000 vs. 0.413
# Minibatch Loss= 0.147853
# Training: 9000
# AUC = 1.000 vs. 0.052
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.917
# Validation: 9000
# AUC = 0.137 vs. 0.088
# F1 = 0.170 vs. 0.167
# Precision = 0.093 vs. 0.091
# Recall = 1.000 vs. 0.978
# Minibatch Loss= 0.147859
# Training: 9100
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.620
# Validation: 9100
# AUC = 0.138 vs. 0.105
# F1 = 0.170 vs. 0.197
# Precision = 0.093 vs. 0.134
# Recall = 1.000 vs. 0.370
# Minibatch Loss= 0.147845
# Training: 9200
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.752
# Validation: 9200
# AUC = 0.139 vs. 0.093
# F1 = 0.170 vs. 0.176
# Precision = 0.093 vs. 0.106
# Recall = 1.000 vs. 0.522
# Minibatch Loss= 0.147844
# Training: 9300
# AUC = 1.000 vs. 0.050
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 9300
# AUC = 0.141 vs. 0.130
# F1 = 0.172 vs. 0.245
# Precision = 0.108 vs. 0.174
# Recall = 0.435 vs. 0.413
# Minibatch Loss= 0.147956
# Training: 9400
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.504
# Validation: 9400
# AUC = 0.143 vs. 0.099
# F1 = 0.174 vs. 0.166
# Precision = 0.109 vs. 0.091
# Recall = 0.435 vs. 1.000
# Minibatch Loss= 0.147838
# Training: 9500
# AUC = 0.998 vs. 0.058
# F1 = 0.976 vs. 0.114
# Precision = 0.960 vs. 0.060
# Recall = 0.992 vs. 0.942
# Validation: 9500
# AUC = 0.221 vs. 0.079
# F1 = 0.260 vs. 0.168
# Precision = 0.323 vs. 0.092
# Recall = 0.217 vs. 0.978
# Minibatch Loss= 0.152921
# Training: 9600
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.769
# Validation: 9600
# AUC = 0.258 vs. 0.110
# F1 = 0.271 vs. 0.188
# Precision = 0.615 vs. 0.117
# Recall = 0.174 vs. 0.478
# Minibatch Loss= 0.148125
# Training: 9700
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.868
# Validation: 9700
# AUC = 0.256 vs. 0.088
# F1 = 0.281 vs. 0.173
# Precision = 0.235 vs. 0.094
# Recall = 0.348 vs. 1.000
# Minibatch Loss= 0.148001
# Training: 9800
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.818
# Validation: 9800
# AUC = 0.261 vs. 0.138
# F1 = 0.299 vs. 0.193
# Precision = 0.262 vs. 0.146
# Recall = 0.348 vs. 0.283
# Minibatch Loss= 0.147951
# Training: 9900
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.124
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.512
# Validation: 9900
# AUC = 0.264 vs. 0.088
# F1 = 0.294 vs. 0.167
# Precision = 0.254 vs. 0.096
# Recall = 0.348 vs. 0.652
# Minibatch Loss= 0.147924
#  Optimization Finished!

# %%
train_obj.train(max_iter = 5000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 10000
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.587
# Validation: 10000
# AUC = 0.266 vs. 0.076
# F1 = 0.288 vs. 0.172
# Precision = 0.259 vs. 0.094
# Recall = 0.326 vs. 0.957
# Minibatch Loss= 0.147919
# Training: 10100
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.135
# Precision = 1.000 vs. 0.114
# Recall = 1.000 vs. 0.165
# Validation: 10100
# AUC = 0.266 vs. 0.111
# F1 = 0.288 vs. 0.202
# Precision = 0.259 vs. 0.157
# Recall = 0.326 vs. 0.283
# Minibatch Loss= 0.147891
# Training: 10200
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 1.000
# Validation: 10200
# AUC = 0.267 vs. 0.119
# F1 = 0.288 vs. 0.171
# Precision = 0.259 vs. 0.095
# Recall = 0.326 vs. 0.848
# Minibatch Loss= 0.147880
# Training: 10300
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.893
# Validation: 10300
# AUC = 0.268 vs. 0.080
# F1 = 0.288 vs. 0.165
# Precision = 0.259 vs. 0.090
# Recall = 0.326 vs. 1.000
# Minibatch Loss= 0.147881
# Training: 10400
# AUC = 1.000 vs. 0.089
# F1 = 1.000 vs. 0.133
# Precision = 1.000 vs. 0.084
# Recall = 1.000 vs. 0.314
# Validation: 10400
# AUC = 0.267 vs. 0.102
# F1 = 0.281 vs. 0.188
# Precision = 0.727 vs. 0.108
# Recall = 0.174 vs. 0.696
# Minibatch Loss= 0.147870
# Training: 10500
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.810
# Validation: 10500
# AUC = 0.266 vs. 0.069
# F1 = 0.281 vs. 0.165
# Precision = 0.727 vs. 0.090
# Recall = 0.174 vs. 1.000
# Minibatch Loss= 0.148009
# Training: 10600
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.950
# Validation: 10600
# AUC = 0.266 vs. 0.086
# F1 = 0.281 vs. 0.174
# Precision = 0.727 vs. 0.095
# Recall = 0.174 vs. 0.957
# Minibatch Loss= 0.147867
# Training: 10700
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.942
# Validation: 10700
# AUC = 0.264 vs. 0.095
# F1 = 0.281 vs. 0.172
# Precision = 0.727 vs. 0.095
# Recall = 0.174 vs. 0.913
# Minibatch Loss= 0.147900
# Training: 10800
# AUC = 1.000 vs. 0.067
# F1 = 0.996 vs. 0.118
# Precision = 0.992 vs. 0.063
# Recall = 1.000 vs. 0.975
# Validation: 10800
# AUC = 0.264 vs. 0.099
# F1 = 0.286 vs. 0.182
# Precision = 0.529 vs. 0.105
# Recall = 0.196 vs. 0.674
# Minibatch Loss= 0.147928
# Training: 10900
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.983
# Validation: 10900
# AUC = 0.269 vs. 0.102
# F1 = 0.286 vs. 0.193
# Precision = 0.529 vs. 0.121
# Recall = 0.196 vs. 0.478
# Minibatch Loss= 0.147854
# Training: 11000
# AUC = 1.000 vs. 0.060
# F1 = 0.996 vs. 0.112
# Precision = 0.992 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 11000
# AUC = 0.270 vs. 0.099
# F1 = 0.286 vs. 0.175
# Precision = 0.529 vs. 0.109
# Recall = 0.196 vs. 0.435
# Minibatch Loss= 0.147956
# Training: 11100
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.120
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.562
# Validation: 11100
# AUC = 0.243 vs. 0.119
# F1 = 0.303 vs. 0.189
# Precision = 0.233 vs. 0.106
# Recall = 0.435 vs. 0.913
# Minibatch Loss= 0.149322
# Training: 11200
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 1.000
# Validation: 11200
# AUC = 0.222 vs. 0.092
# F1 = 0.302 vs. 0.182
# Precision = 0.267 vs. 0.101
# Recall = 0.348 vs. 0.891
# Minibatch Loss= 0.148002
# Training: 11300
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.934
# Validation: 11300
# AUC = 0.219 vs. 0.097
# F1 = 0.305 vs. 0.167
# Precision = 0.271 vs. 0.098
# Recall = 0.348 vs. 0.565
# Minibatch Loss= 0.147889
# Training: 11400
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.975
# Validation: 11400
# AUC = 0.213 vs. 0.092
# F1 = 0.302 vs. 0.182
# Precision = 0.267 vs. 0.118
# Recall = 0.348 vs. 0.391
# Minibatch Loss= 0.147865
# Training: 11500
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.075
# Recall = 1.000 vs. 0.322
# Validation: 11500
# AUC = 0.213 vs. 0.105
# F1 = 0.308 vs. 0.175
# Precision = 0.276 vs. 0.098
# Recall = 0.348 vs. 0.804
# Minibatch Loss= 0.147858
# Training: 11600
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.120
# Precision = 1.000 vs. 0.068
# Recall = 1.000 vs. 0.529
# Validation: 11600
# AUC = 0.212 vs. 0.076
# F1 = 0.299 vs. 0.172
# Precision = 0.262 vs. 0.094
# Recall = 0.348 vs. 0.978
# Minibatch Loss= 0.147844
# Training: 11700
# AUC = 1.000 vs. 0.053
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 11700
# AUC = 0.212 vs. 0.097
# F1 = 0.305 vs. 0.169
# Precision = 0.271 vs. 0.112
# Recall = 0.348 vs. 0.348
# Minibatch Loss= 0.147837
# Training: 11800
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 11800
# AUC = 0.213 vs. 0.076
# F1 = 0.308 vs. 0.171
# Precision = 0.276 vs. 0.096
# Recall = 0.348 vs. 0.783
# Minibatch Loss= 0.147834
# Training: 11900
# AUC = 1.000 vs. 0.080
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.069
# Recall = 1.000 vs. 0.413
# Validation: 11900
# AUC = 0.213 vs. 0.076
# F1 = 0.308 vs. 0.172
# Precision = 0.276 vs. 0.095
# Recall = 0.348 vs. 0.935
# Minibatch Loss= 0.147836
# Training: 12000
# AUC = 1.000 vs. 0.056
# F1 = 0.996 vs. 0.114
# Precision = 0.992 vs. 0.061
# Recall = 1.000 vs. 0.826
# Validation: 12000
# AUC = 0.215 vs. 0.092
# F1 = 0.308 vs. 0.170
# Precision = 0.276 vs. 0.093
# Recall = 0.348 vs. 0.957
# Minibatch Loss= 0.147936
# Training: 12100
# AUC = 1.000 vs. 0.070
# F1 = 0.996 vs. 0.118
# Precision = 0.992 vs. 0.063
# Recall = 1.000 vs. 0.835
# Validation: 12100
# AUC = 0.216 vs. 0.109
# F1 = 0.305 vs. 0.188
# Precision = 0.271 vs. 0.107
# Recall = 0.348 vs. 0.783
# Minibatch Loss= 0.148046
# Training: 12200
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.934
# Validation: 12200
# AUC = 0.213 vs. 0.092
# F1 = 0.305 vs. 0.189
# Precision = 0.271 vs. 0.107
# Recall = 0.348 vs. 0.804
# Minibatch Loss= 0.147821
# Training: 12300
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.777
# Validation: 12300
# AUC = 0.214 vs. 0.089
# F1 = 0.305 vs. 0.171
# Precision = 0.271 vs. 0.113
# Recall = 0.348 vs. 0.348
# Minibatch Loss= 0.147819
# Training: 12400
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.934
# Validation: 12400
# AUC = 0.216 vs. 0.102
# F1 = 0.305 vs. 0.190
# Precision = 0.271 vs. 0.107
# Recall = 0.348 vs. 0.826
# Minibatch Loss= 0.147817
# Training: 12500
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.934
# Validation: 12500
# AUC = 0.219 vs. 0.074
# F1 = 0.318 vs. 0.166
# Precision = 0.279 vs. 0.092
# Recall = 0.370 vs. 0.870
# Minibatch Loss= 0.147816
# Training: 12600
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.802
# Validation: 12600
# AUC = 0.219 vs. 0.112
# F1 = 0.321 vs. 0.199
# Precision = 0.273 vs. 0.139
# Recall = 0.391 vs. 0.348
# Minibatch Loss= 0.147815
# Training: 12700
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.123
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.711
# Validation: 12700
# AUC = 0.235 vs. 0.109
# F1 = 0.327 vs. 0.185
# Precision = 0.293 vs. 0.113
# Recall = 0.370 vs. 0.522
# Minibatch Loss= 0.147958
# Training: 12800
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.967
# Validation: 12800
# AUC = 0.236 vs. 0.088
# F1 = 0.324 vs. 0.165
# Precision = 0.277 vs. 0.090
# Recall = 0.391 vs. 1.000
# Minibatch Loss= 0.147824
# Training: 12900
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.884
# Validation: 12900
# AUC = 0.236 vs. 0.121
# F1 = 0.327 vs. 0.195
# Precision = 0.281 vs. 0.108
# Recall = 0.391 vs. 0.978
# Minibatch Loss= 0.147859
# Training: 13000
# AUC = 1.000 vs. 0.064
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.669
# Validation: 13000
# AUC = 0.236 vs. 0.092
# F1 = 0.327 vs. 0.177
# Precision = 0.281 vs. 0.112
# Recall = 0.391 vs. 0.413
# Minibatch Loss= 0.148110
# Training: 13100
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.488
# Validation: 13100
# AUC = 0.237 vs. 0.095
# F1 = 0.327 vs. 0.172
# Precision = 0.281 vs. 0.095
# Recall = 0.391 vs. 0.935
# Minibatch Loss= 0.148051
# Training: 13200
# AUC = 1.000 vs. 0.067
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.876
# Validation: 13200
# AUC = 0.231 vs. 0.107
# F1 = 0.330 vs. 0.188
# Precision = 0.286 vs. 0.106
# Recall = 0.391 vs. 0.826
# Minibatch Loss= 0.147809
# Training: 13300
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 13300
# AUC = 0.230 vs. 0.091
# F1 = 0.330 vs. 0.175
# Precision = 0.286 vs. 0.102
# Recall = 0.391 vs. 0.609
# Minibatch Loss= 0.147818
# Training: 13400
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 1.000
# Validation: 13400
# AUC = 0.233 vs. 0.122
# F1 = 0.330 vs. 0.185
# Precision = 0.286 vs. 0.107
# Recall = 0.391 vs. 0.696
# Minibatch Loss= 0.147806
# Training: 13500
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.868
# Validation: 13500
# AUC = 0.229 vs. 0.094
# F1 = 0.330 vs. 0.166
# Precision = 0.286 vs. 0.091
# Recall = 0.391 vs. 0.957
# Minibatch Loss= 0.147893
# Training: 13600
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.298
# Validation: 13600
# AUC = 0.235 vs. 0.075
# F1 = 0.330 vs. 0.171
# Precision = 0.286 vs. 0.094
# Recall = 0.391 vs. 1.000
# Minibatch Loss= 0.147814
# Training: 13700
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.950
# Validation: 13700
# AUC = 0.235 vs. 0.102
# F1 = 0.330 vs. 0.174
# Precision = 0.286 vs. 0.102
# Recall = 0.391 vs. 0.587
# Minibatch Loss= 0.147804
# Training: 13800
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.645
# Validation: 13800
# AUC = 0.232 vs. 0.117
# F1 = 0.330 vs. 0.206
# Precision = 0.286 vs. 0.122
# Recall = 0.391 vs. 0.652
# Minibatch Loss= 0.147806
# Training: 13900
# AUC = 1.000 vs. 0.055
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.934
# Validation: 13900
# AUC = 0.237 vs. 0.099
# F1 = 0.328 vs. 0.198
# Precision = 0.271 vs. 0.127
# Recall = 0.413 vs. 0.457
# Minibatch Loss= 0.147802
# Training: 14000
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.388
# Validation: 14000
# AUC = 0.239 vs. 0.112
# F1 = 0.328 vs. 0.203
# Precision = 0.271 vs. 0.135
# Recall = 0.413 vs. 0.413
# Minibatch Loss= 0.147802
# Training: 14100
# AUC = 0.998 vs. 0.073
# F1 = 0.983 vs. 0.136
# Precision = 1.000 vs. 0.091
# Recall = 0.967 vs. 0.264
# Validation: 14100
# AUC = 0.238 vs. 0.084
# F1 = 0.336 vs. 0.171
# Precision = 0.266 vs. 0.095
# Recall = 0.457 vs. 0.826
# Minibatch Loss= 0.148445
# Training: 14200
# AUC = 0.998 vs. 0.054
# F1 = 0.984 vs. 0.112
# Precision = 0.968 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 14200
# AUC = 0.350 vs. 0.103
# F1 = 0.417 vs. 0.176
# Precision = 0.338 vs. 0.097
# Recall = 0.543 vs. 0.978
# Minibatch Loss= 0.150863
# Training: 14300
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.868
# Validation: 14300
# AUC = 0.313 vs. 0.088
# F1 = 0.378 vs. 0.195
# Precision = 0.296 vs. 0.111
# Recall = 0.522 vs. 0.826
# Minibatch Loss= 0.148533
# Training: 14400
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.065
# Recall = 1.000 vs. 0.570
# Validation: 14400
# AUC = 0.321 vs. 0.118
# F1 = 0.382 vs. 0.200
# Precision = 0.294 vs. 0.116
# Recall = 0.543 vs. 0.717
# Minibatch Loss= 0.148260
# Training: 14500
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.661
# Validation: 14500
# AUC = 0.327 vs. 0.095
# F1 = 0.387 vs. 0.183
# Precision = 0.308 vs. 0.114
# Recall = 0.522 vs. 0.457
# Minibatch Loss= 0.148127
# Training: 14600
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.802
# Validation: 14600
# AUC = 0.330 vs. 0.098
# F1 = 0.391 vs. 0.172
# Precision = 0.299 vs. 0.098
# Recall = 0.565 vs. 0.717
# Minibatch Loss= 0.148061
# Training: 14700
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.702
# Validation: 14700
# AUC = 0.332 vs. 0.105
# F1 = 0.394 vs. 0.175
# Precision = 0.302 vs. 0.100
# Recall = 0.565 vs. 0.696
# Minibatch Loss= 0.148011
# Training: 14800
# AUC = 1.000 vs. 0.074
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.612
# Validation: 14800
# AUC = 0.335 vs. 0.093
# F1 = 0.391 vs. 0.171
# Precision = 0.305 vs. 0.094
# Recall = 0.543 vs. 1.000
# Minibatch Loss= 0.147987
# Training: 14900
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.071
# Recall = 1.000 vs. 0.380
# Validation: 14900
# AUC = 0.338 vs. 0.103
# F1 = 0.400 vs. 0.173
# Precision = 0.310 vs. 0.098
# Recall = 0.565 vs. 0.783
# Minibatch Loss= 0.147950
#  Optimization Finished!

# %%
train_obj.train(max_iter = 5000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 15000
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.122
# Precision = 1.000 vs. 0.067
# Recall = 1.000 vs. 0.711
# Validation: 15000
# AUC = 0.337 vs. 0.096
# F1 = 0.400 vs. 0.197
# Precision = 0.310 vs. 0.120
# Recall = 0.565 vs. 0.543
# Minibatch Loss= 0.147938
# Training: 15100
# AUC = 1.000 vs. 0.062
# F1 = 0.992 vs. 0.114
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 0.967
# Validation: 15100
# AUC = 0.337 vs. 0.089
# F1 = 0.397 vs. 0.183
# Precision = 0.306 vs. 0.107
# Recall = 0.565 vs. 0.630
# Minibatch Loss= 0.148150
# Training: 15200
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.702
# Validation: 15200
# AUC = 0.336 vs. 0.087
# F1 = 0.400 vs. 0.169
# Precision = 0.310 vs. 0.092
# Recall = 0.565 vs. 0.978
# Minibatch Loss= 0.147904
# Training: 15300
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.893
# Validation: 15300
# AUC = 0.335 vs. 0.081
# F1 = 0.397 vs. 0.165
# Precision = 0.306 vs. 0.090
# Recall = 0.565 vs. 1.000
# Minibatch Loss= 0.147908
# Training: 15400
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.983
# Validation: 15400
# AUC = 0.334 vs. 0.130
# F1 = 0.394 vs. 0.182
# Precision = 0.302 vs. 0.190
# Recall = 0.565 vs. 0.174
# Minibatch Loss= 0.147884
# Training: 15500
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 15500
# AUC = 0.339 vs. 0.100
# F1 = 0.394 vs. 0.170
# Precision = 0.302 vs. 0.094
# Recall = 0.565 vs. 0.913
# Minibatch Loss= 0.147877
# Training: 15600
# AUC = 1.000 vs. 0.083
# F1 = 1.000 vs. 0.127
# Precision = 1.000 vs. 0.085
# Recall = 1.000 vs. 0.256
# Validation: 15600
# AUC = 0.338 vs. 0.085
# F1 = 0.391 vs. 0.169
# Precision = 0.299 vs. 0.094
# Recall = 0.565 vs. 0.826
# Minibatch Loss= 0.147871
# Training: 15700
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.975
# Validation: 15700
# AUC = 0.337 vs. 0.083
# F1 = 0.388 vs. 0.174
# Precision = 0.301 vs. 0.095
# Recall = 0.543 vs. 1.000
# Minibatch Loss= 0.147864
# Training: 15800
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 15800
# AUC = 0.337 vs. 0.119
# F1 = 0.385 vs. 0.197
# Precision = 0.292 vs. 0.124
# Recall = 0.565 vs. 0.478
# Minibatch Loss= 0.147861
# Training: 15900
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.686
# Validation: 15900
# AUC = 0.337 vs. 0.075
# F1 = 0.388 vs. 0.168
# Precision = 0.295 vs. 0.092
# Recall = 0.565 vs. 1.000
# Minibatch Loss= 0.147873
# Training: 16000
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.123
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.521
# Validation: 16000
# AUC = 0.338 vs. 0.096
# F1 = 0.388 vs. 0.188
# Precision = 0.295 vs. 0.129
# Recall = 0.565 vs. 0.348
# Minibatch Loss= 0.147960
# Training: 16100
# AUC = 1.000 vs. 0.072
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.694
# Validation: 16100
# AUC = 0.338 vs. 0.106
# F1 = 0.391 vs. 0.180
# Precision = 0.299 vs. 0.101
# Recall = 0.565 vs. 0.848
# Minibatch Loss= 0.147846
# Training: 16200
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.983
# Validation: 16200
# AUC = 0.340 vs. 0.091
# F1 = 0.388 vs. 0.165
# Precision = 0.295 vs. 0.090
# Recall = 0.565 vs. 1.000
# Minibatch Loss= 0.147844
# Training: 16300
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 16300
# AUC = 0.341 vs. 0.113
# F1 = 0.388 vs. 0.165
# Precision = 0.295 vs. 0.090
# Recall = 0.565 vs. 1.000
# Minibatch Loss= 0.147840
# Training: 16400
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 16400
# AUC = 0.342 vs. 0.098
# F1 = 0.388 vs. 0.178
# Precision = 0.295 vs. 0.130
# Recall = 0.565 vs. 0.283
# Minibatch Loss= 0.147871
# Training: 16500
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.529
# Validation: 16500
# AUC = 0.341 vs. 0.092
# F1 = 0.382 vs. 0.170
# Precision = 0.289 vs. 0.097
# Recall = 0.565 vs. 0.674
# Minibatch Loss= 0.147872
# Training: 16600
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.669
# Validation: 16600
# AUC = 0.341 vs. 0.113
# F1 = 0.378 vs. 0.176
# Precision = 0.278 vs. 0.102
# Recall = 0.587 vs. 0.630
# Minibatch Loss= 0.147832
# Training: 16700
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.959
# Validation: 16700
# AUC = 0.365 vs. 0.100
# F1 = 0.344 vs. 0.183
# Precision = 0.248 vs. 0.101
# Recall = 0.565 vs. 0.935
# Minibatch Loss= 0.148791
# Training: 16800
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.835
# Validation: 16800
# AUC = 0.345 vs. 0.098
# F1 = 0.336 vs. 0.169
# Precision = 0.274 vs. 0.093
# Recall = 0.435 vs. 1.000
# Minibatch Loss= 0.148119
# Training: 16900
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.645
# Validation: 16900
# AUC = 0.339 vs. 0.100
# F1 = 0.323 vs. 0.182
# Precision = 0.250 vs. 0.101
# Recall = 0.457 vs. 0.935
# Minibatch Loss= 0.147995
# Training: 17000
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.967
# Validation: 17000
# AUC = 0.333 vs. 0.100
# F1 = 0.312 vs. 0.182
# Precision = 0.556 vs. 0.117
# Recall = 0.217 vs. 0.413
# Minibatch Loss= 0.147940
# Training: 17100
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.934
# Validation: 17100
# AUC = 0.331 vs. 0.122
# F1 = 0.312 vs. 0.193
# Precision = 0.556 vs. 0.120
# Recall = 0.217 vs. 0.500
# Minibatch Loss= 0.147909
# Training: 17200
# AUC = 1.000 vs. 0.073
# F1 = 1.000 vs. 0.140
# Precision = 1.000 vs. 0.091
# Recall = 1.000 vs. 0.306
# Validation: 17200
# AUC = 0.329 vs. 0.109
# F1 = 0.304 vs. 0.186
# Precision = 0.241 vs. 0.104
# Recall = 0.413 vs. 0.870
# Minibatch Loss= 0.147888
# Training: 17300
# AUC = 1.000 vs. 0.059
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.868
# Validation: 17300
# AUC = 0.327 vs. 0.087
# F1 = 0.304 vs. 0.181
# Precision = 0.241 vs. 0.102
# Recall = 0.413 vs. 0.804
# Minibatch Loss= 0.147871
# Training: 17400
# AUC = 1.000 vs. 0.055
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.669
# Validation: 17400
# AUC = 0.372 vs. 0.088
# F1 = 0.389 vs. 0.167
# Precision = 0.328 vs. 0.091
# Recall = 0.478 vs. 0.978
# Minibatch Loss= 0.147958
# Training: 17500
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.388
# Validation: 17500
# AUC = 0.361 vs. 0.117
# F1 = 0.386 vs. 0.200
# Precision = 0.324 vs. 0.115
# Recall = 0.478 vs. 0.783
# Minibatch Loss= 0.147892
# Training: 17600
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 17600
# AUC = 0.356 vs. 0.078
# F1 = 0.372 vs. 0.165
# Precision = 0.313 vs. 0.090
# Recall = 0.457 vs. 1.000
# Minibatch Loss= 0.147870
# Training: 17700
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.118
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.537
# Validation: 17700
# AUC = 0.355 vs. 0.092
# F1 = 0.373 vs. 0.168
# Precision = 0.261 vs. 0.092
# Recall = 0.652 vs. 0.978
# Minibatch Loss= 0.147858
# Training: 17800
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 17800
# AUC = 0.353 vs. 0.094
# F1 = 0.372 vs. 0.182
# Precision = 0.313 vs. 0.101
# Recall = 0.457 vs. 0.891
# Minibatch Loss= 0.147850
# Training: 17900
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.785
# Validation: 17900
# AUC = 0.351 vs. 0.122
# F1 = 0.372 vs. 0.205
# Precision = 0.313 vs. 0.138
# Recall = 0.457 vs. 0.391
# Minibatch Loss= 0.147847
# Training: 18000
# AUC = 1.000 vs. 0.052
# F1 = 1.000 vs. 0.112
# Precision = 1.000 vs. 0.059
# Recall = 1.000 vs. 1.000
# Validation: 18000
# AUC = 0.345 vs. 0.084
# F1 = 0.372 vs. 0.166
# Precision = 0.313 vs. 0.091
# Recall = 0.457 vs. 0.957
# Minibatch Loss= 0.147861
# Training: 18100
# AUC = 1.000 vs. 0.066
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.760
# Validation: 18100
# AUC = 0.341 vs. 0.091
# F1 = 0.372 vs. 0.171
# Precision = 0.313 vs. 0.094
# Recall = 0.457 vs. 0.935
# Minibatch Loss= 0.147838
# Training: 18200
# AUC = 1.000 vs. 0.057
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.992
# Validation: 18200
# AUC = 0.340 vs. 0.094
# F1 = 0.368 vs. 0.168
# Precision = 0.309 vs. 0.093
# Recall = 0.457 vs. 0.913
# Minibatch Loss= 0.147879
# Training: 18300
# AUC = 1.000 vs. 0.060
# F1 = 0.996 vs. 0.116
# Precision = 0.992 vs. 0.063
# Recall = 1.000 vs. 0.760
# Validation: 18300
# AUC = 0.336 vs. 0.099
# F1 = 0.365 vs. 0.176
# Precision = 0.304 vs. 0.106
# Recall = 0.457 vs. 0.522
# Minibatch Loss= 0.147942
# Training: 18400
# AUC = 1.000 vs. 0.056
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.063
# Recall = 1.000 vs. 0.934
# Validation: 18400
# AUC = 0.333 vs. 0.127
# F1 = 0.365 vs. 0.188
# Precision = 0.265 vs. 0.108
# Recall = 0.587 vs. 0.739
# Minibatch Loss= 0.147824
# Training: 18500
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.967
# Validation: 18500
# AUC = 0.331 vs. 0.104
# F1 = 0.365 vs. 0.171
# Precision = 0.265 vs. 0.094
# Recall = 0.587 vs. 0.957
# Minibatch Loss= 0.147875
# Training: 18600
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.126
# Precision = 1.000 vs. 0.070
# Recall = 1.000 vs. 0.587
# Validation: 18600
# AUC = 0.329 vs. 0.096
# F1 = 0.362 vs. 0.166
# Precision = 0.262 vs. 0.091
# Recall = 0.587 vs. 0.935
# Minibatch Loss= 0.147822
# Training: 18700
# AUC = 0.961 vs. 0.066
# F1 = 0.899 vs. 0.123
# Precision = 0.881 vs. 0.069
# Recall = 0.917 vs. 0.595
# Validation: 18700
# AUC = 0.245 vs. 0.089
# F1 = 0.318 vs. 0.176
# Precision = 0.279 vs. 0.098
# Recall = 0.370 vs. 0.913
# Minibatch Loss= 0.214709
# Training: 18800
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.579
# Validation: 18800
# AUC = 0.172 vs. 0.109
# F1 = 0.278 vs. 0.175
# Precision = 0.184 vs. 0.101
# Recall = 0.565 vs. 0.652
# Minibatch Loss= 0.148217
# Training: 18900
# AUC = 1.000 vs. 0.060
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.064
# Recall = 1.000 vs. 0.711
# Validation: 18900
# AUC = 0.168 vs. 0.092
# F1 = 0.277 vs. 0.190
# Precision = 0.183 vs. 0.111
# Recall = 0.565 vs. 0.652
# Minibatch Loss= 0.148021
# Training: 19000
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.126
# Precision = 1.000 vs. 0.072
# Recall = 1.000 vs. 0.512
# Validation: 19000
# AUC = 0.157 vs. 0.112
# F1 = 0.282 vs. 0.181
# Precision = 0.208 vs. 0.111
# Recall = 0.435 vs. 0.500
# Minibatch Loss= 0.147939
# Training: 19100
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.678
# Validation: 19100
# AUC = 0.155 vs. 0.100
# F1 = 0.283 vs. 0.179
# Precision = 0.188 vs. 0.100
# Recall = 0.565 vs. 0.848
# Minibatch Loss= 0.147904
# Training: 19200
# AUC = 1.000 vs. 0.058
# F1 = 1.000 vs. 0.114
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 0.975
# Validation: 19200
# AUC = 0.151 vs. 0.111
# F1 = 0.288 vs. 0.226
# Precision = 0.206 vs. 0.148
# Recall = 0.478 vs. 0.478
# Minibatch Loss= 0.147884
# Training: 19300
# AUC = 1.000 vs. 0.068
# F1 = 1.000 vs. 0.136
# Precision = 1.000 vs. 0.090
# Recall = 1.000 vs. 0.281
# Validation: 19300
# AUC = 0.153 vs. 0.090
# F1 = 0.286 vs. 0.183
# Precision = 0.213 vs. 0.101
# Recall = 0.435 vs. 0.935
# Minibatch Loss= 0.147869
# Training: 19400
# AUC = 1.000 vs. 0.062
# F1 = 1.000 vs. 0.113
# Precision = 1.000 vs. 0.060
# Recall = 1.000 vs. 0.934
# Validation: 19400
# AUC = 0.150 vs. 0.089
# F1 = 0.284 vs. 0.170
# Precision = 0.198 vs. 0.096
# Recall = 0.500 vs. 0.761
# Minibatch Loss= 0.147856
# Training: 19500
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.512
# Validation: 19500
# AUC = 0.150 vs. 0.078
# F1 = 0.282 vs. 0.167
# Precision = 0.200 vs. 0.093
# Recall = 0.478 vs. 0.783
# Minibatch Loss= 0.147852
# Training: 19600
# AUC = 1.000 vs. 0.063
# F1 = 1.000 vs. 0.119
# Precision = 1.000 vs. 0.069
# Recall = 1.000 vs. 0.421
# Validation: 19600
# AUC = 0.149 vs. 0.082
# F1 = 0.279 vs. 0.168
# Precision = 0.193 vs. 0.092
# Recall = 0.500 vs. 0.978
# Minibatch Loss= 0.147848
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-ed29ea3997e1> in <module>()
#       2                 train_eval_step=100,
#       3                 validation_eval_step=100,
# ----> 4                 display_step=100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=train_obj.global_step)

# %%
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-1000')

# %%
_ = nn_eval.evaluate_model(model,
                                   sess,
                                   test_data,
                                   test_gt)
# Out:
# AUC = 0.247 vs. 0.068
# F1 = 0.254 vs. 0.128
# Precision = 0.419 vs. 0.069
# Recall = 0.182 vs. 0.829

# %%
out = nn_eval.deploy(model,
                     sess,
                     test_data,
                     test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
