# %%
# useing this variable for saving models and summaries
exp_name = "RCNN1001_y"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,64,64, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../src')
sys.path.append('../../src/models')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed3.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]

bias_shape = [32,64,64, 64, 64]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 1


#positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
pos_weight
# Out:
# 4.4428500520033891

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables, n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride,
                         weights_shape,
                         bias_shape,
                         activation,
                         lstm_n_hidden,
                         n_classes,
                         learning_rate,
                         pos_weight,
                         trainable_conv=True,
                         trainable_last=True)

# %%
train_obj = training.Trainer(model,
                 train_data, train_gt,
                 validation_data, validation_gt,
                 sess,
                 summary_path,
                 batch_size,
                 global_step = 0)

# %%
train_obj.train(max_iter = 10000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 0
# AUC = 0.205 vs. 0.170
# F1 = 0.339 vs. 0.293
# Precision = 0.214 vs. 0.173
# Recall = 0.812 vs. 0.959
# Validation: 0
# AUC = 0.179 vs. 0.183
# F1 = 0.311 vs. 0.300
# Precision = 0.189 vs. 0.178
# Recall = 0.871 vs. 0.961
# Minibatch Loss= 1.280222
# Training: 100
# AUC = 0.441 vs. 0.170
# F1 = 0.520 vs. 0.295
# Precision = 0.495 vs. 0.174
# Recall = 0.548 vs. 0.980
# Validation: 100
# AUC = 0.360 vs. 0.179
# F1 = 0.429 vs. 0.300
# Precision = 0.428 vs. 0.177
# Recall = 0.430 vs. 1.000
# Minibatch Loss= 1.085934
# Training: 200
# AUC = 0.498 vs. 0.158
# F1 = 0.549 vs. 0.276
# Precision = 0.584 vs. 0.160
# Recall = 0.517 vs. 1.000
# Validation: 200
# AUC = 0.527 vs. 0.177
# F1 = 0.522 vs. 0.300
# Precision = 0.658 vs. 0.177
# Recall = 0.433 vs. 0.999
# Minibatch Loss= 0.872877
# Training: 300
# AUC = 0.721 vs. 0.189
# F1 = 0.703 vs. 0.309
# Precision = 0.740 vs. 0.184
# Recall = 0.669 vs. 0.961
# Validation: 300
# AUC = 0.661 vs. 0.173
# F1 = 0.650 vs. 0.300
# Precision = 0.662 vs. 0.177
# Recall = 0.638 vs. 1.000
# Minibatch Loss= 0.856429
# Training: 400
# AUC = 0.699 vs. 0.148
# F1 = 0.666 vs. 0.259
# Precision = 0.761 vs. 0.149
# Recall = 0.592 vs. 0.995
# Validation: 400
# AUC = 0.708 vs. 0.172
# F1 = 0.678 vs. 0.300
# Precision = 0.730 vs. 0.177
# Recall = 0.634 vs. 0.999
# Minibatch Loss= 0.744800
# Training: 500
# AUC = 0.645 vs. 0.171
# F1 = 0.597 vs. 0.313
# Precision = 0.548 vs. 0.186
# Recall = 0.657 vs. 0.987
# Validation: 500
# AUC = 0.670 vs. 0.181
# F1 = 0.626 vs. 0.300
# Precision = 0.578 vs. 0.177
# Recall = 0.682 vs. 1.000
# Minibatch Loss= 0.922459
# Training: 600
# AUC = 0.727 vs. 0.214
# F1 = 0.678 vs. 0.341
# Precision = 0.648 vs. 0.206
# Recall = 0.710 vs. 0.983
# Validation: 600
# AUC = 0.765 vs. 0.177
# F1 = 0.721 vs. 0.300
# Precision = 0.826 vs. 0.177
# Recall = 0.640 vs. 1.000
# Minibatch Loss= 0.961550
# Training: 700
# AUC = 0.776 vs. 0.152
# F1 = 0.731 vs. 0.281
# Precision = 0.793 vs. 0.164
# Recall = 0.679 vs. 0.995
# Validation: 700
# AUC = 0.778 vs. 0.178
# F1 = 0.734 vs. 0.300
# Precision = 0.766 vs. 0.177
# Recall = 0.706 vs. 1.000
# Minibatch Loss= 0.752185
# Training: 800
# AUC = 0.811 vs. 0.157
# F1 = 0.785 vs. 0.284
# Precision = 0.785 vs. 0.166
# Recall = 0.785 vs. 0.998
# Validation: 800
# AUC = 0.770 vs. 0.172
# F1 = 0.734 vs. 0.300
# Precision = 0.772 vs. 0.177
# Recall = 0.700 vs. 1.000
# Minibatch Loss= 0.644922
# Training: 900
# AUC = 0.866 vs. 0.239
# F1 = 0.818 vs. 0.371
# Precision = 0.830 vs. 0.228
# Recall = 0.806 vs. 0.998
# Validation: 900
# AUC = 0.808 vs. 0.176
# F1 = 0.765 vs. 0.300
# Precision = 0.819 vs. 0.177
# Recall = 0.717 vs. 0.998
# Minibatch Loss= 0.730131
# Training: 1000
# AUC = 0.845 vs. 0.152
# F1 = 0.777 vs. 0.280
# Precision = 0.799 vs. 0.163
# Recall = 0.755 vs. 0.990
# Validation: 1000
# AUC = 0.842 vs. 0.176
# F1 = 0.792 vs. 0.300
# Precision = 0.881 vs. 0.177
# Recall = 0.720 vs. 0.999
# Minibatch Loss= 0.558648
# Training: 1100
# AUC = 0.856 vs. 0.117
# F1 = 0.814 vs. 0.209
# Precision = 0.855 vs. 0.117
# Recall = 0.777 vs. 0.986
# Validation: 1100
# AUC = 0.832 vs. 0.179
# F1 = 0.778 vs. 0.300
# Precision = 0.825 vs. 0.177
# Recall = 0.736 vs. 0.981
# Minibatch Loss= 0.457006
# Training: 1200
# AUC = 0.856 vs. 0.151
# F1 = 0.797 vs. 0.242
# Precision = 0.894 vs. 0.138
# Recall = 0.719 vs. 0.989
# Validation: 1200
# AUC = 0.850 vs. 0.177
# F1 = 0.787 vs. 0.300
# Precision = 0.838 vs. 0.177
# Recall = 0.741 vs. 0.997
# Minibatch Loss= 0.515080
# Training: 1300
# AUC = 0.916 vs. 0.159
# F1 = 0.840 vs. 0.275
# Precision = 0.862 vs. 0.160
# Recall = 0.819 vs. 0.985
# Validation: 1300
# AUC = 0.872 vs. 0.178
# F1 = 0.801 vs. 0.300
# Precision = 0.876 vs. 0.177
# Recall = 0.738 vs. 0.998
# Minibatch Loss= 0.477960
# Training: 1400
# AUC = 0.913 vs. 0.230
# F1 = 0.833 vs. 0.376
# Precision = 0.915 vs. 0.232
# Recall = 0.765 vs. 0.993
# Validation: 1400
# AUC = 0.888 vs. 0.177
# F1 = 0.813 vs. 0.300
# Precision = 0.869 vs. 0.177
# Recall = 0.764 vs. 0.999
# Minibatch Loss= 0.613987
# Training: 1500
# AUC = 0.911 vs. 0.213
# F1 = 0.816 vs. 0.339
# Precision = 0.824 vs. 0.204
# Recall = 0.808 vs. 1.000
# Validation: 1500
# AUC = 0.883 vs. 0.174
# F1 = 0.809 vs. 0.300
# Precision = 0.848 vs. 0.177
# Recall = 0.773 vs. 1.000
# Minibatch Loss= 0.552804
# Training: 1600
# AUC = 0.847 vs. 0.181
# F1 = 0.757 vs. 0.293
# Precision = 0.839 vs. 0.172
# Recall = 0.689 vs. 0.993
# Validation: 1600
# AUC = 0.888 vs. 0.176
# F1 = 0.817 vs. 0.300
# Precision = 0.851 vs. 0.177
# Recall = 0.786 vs. 1.000
# Minibatch Loss= 0.591086
# Training: 1700
# AUC = 0.927 vs. 0.148
# F1 = 0.850 vs. 0.245
# Precision = 0.941 vs. 0.143
# Recall = 0.776 vs. 0.871
# Validation: 1700
# AUC = 0.897 vs. 0.176
# F1 = 0.822 vs. 0.300
# Precision = 0.875 vs. 0.177
# Recall = 0.775 vs. 1.000
# Minibatch Loss= 0.352980
# Training: 1800
# AUC = 0.934 vs. 0.155
# F1 = 0.861 vs. 0.269
# Precision = 0.905 vs. 0.158
# Recall = 0.821 vs. 0.912
# Validation: 1800
# AUC = 0.895 vs. 0.176
# F1 = 0.827 vs. 0.300
# Precision = 0.876 vs. 0.177
# Recall = 0.784 vs. 1.000
# Minibatch Loss= 0.409932
# Training: 1900
# AUC = 0.947 vs. 0.144
# F1 = 0.882 vs. 0.250
# Precision = 0.885 vs. 0.146
# Recall = 0.880 vs. 0.860
# Validation: 1900
# AUC = 0.899 vs. 0.178
# F1 = 0.827 vs. 0.300
# Precision = 0.868 vs. 0.177
# Recall = 0.790 vs. 0.995
# Minibatch Loss= 0.331099
# Training: 2000
# AUC = 0.915 vs. 0.183
# F1 = 0.837 vs. 0.309
# Precision = 0.874 vs. 0.183
# Recall = 0.803 vs. 0.987
# Validation: 2000
# AUC = 0.881 vs. 0.176
# F1 = 0.810 vs. 0.300
# Precision = 0.846 vs. 0.177
# Recall = 0.776 vs. 1.000
# Minibatch Loss= 0.500658
# Training: 2100
# AUC = 0.929 vs. 0.177
# F1 = 0.851 vs. 0.290
# Precision = 0.839 vs. 0.170
# Recall = 0.864 vs. 0.991
# Validation: 2100
# AUC = 0.878 vs. 0.178
# F1 = 0.799 vs. 0.300
# Precision = 0.857 vs. 0.177
# Recall = 0.748 vs. 1.000
# Minibatch Loss= 0.460369
# Training: 2200
# AUC = 0.963 vs. 0.154
# F1 = 0.915 vs. 0.278
# Precision = 0.957 vs. 0.164
# Recall = 0.876 vs. 0.911
# Validation: 2200
# AUC = 0.899 vs. 0.175
# F1 = 0.823 vs. 0.300
# Precision = 0.894 vs. 0.177
# Recall = 0.762 vs. 0.995
# Minibatch Loss= 0.370476
# Training: 2300
# AUC = 0.933 vs. 0.225
# F1 = 0.856 vs. 0.356
# Precision = 0.862 vs. 0.220
# Recall = 0.851 vs. 0.942
# Validation: 2300
# AUC = 0.908 vs. 0.177
# F1 = 0.834 vs. 0.300
# Precision = 0.858 vs. 0.177
# Recall = 0.811 vs. 1.000
# Minibatch Loss= 0.520299
# Training: 2400
# AUC = 0.928 vs. 0.123
# F1 = 0.842 vs. 0.211
# Precision = 0.903 vs. 0.118
# Recall = 0.788 vs. 1.000
# Validation: 2400
# AUC = 0.907 vs. 0.176
# F1 = 0.830 vs. 0.300
# Precision = 0.857 vs. 0.177
# Recall = 0.804 vs. 1.000
# Minibatch Loss= 0.347495
# Training: 2500
# AUC = 0.955 vs. 0.176
# F1 = 0.908 vs. 0.318
# Precision = 0.919 vs. 0.189
# Recall = 0.896 vs. 0.996
# Validation: 2500
# AUC = 0.897 vs. 0.177
# F1 = 0.831 vs. 0.300
# Precision = 0.878 vs. 0.177
# Recall = 0.788 vs. 0.998
# Minibatch Loss= 0.412666
# Training: 2600
# AUC = 0.951 vs. 0.190
# F1 = 0.896 vs. 0.315
# Precision = 0.921 vs. 0.187
# Recall = 0.872 vs. 0.994
# Validation: 2600
# AUC = 0.903 vs. 0.177
# F1 = 0.832 vs. 0.300
# Precision = 0.863 vs. 0.177
# Recall = 0.804 vs. 0.978
# Minibatch Loss= 0.481249
# Training: 2700
# AUC = 0.954 vs. 0.158
# F1 = 0.910 vs. 0.262
# Precision = 0.920 vs. 0.159
# Recall = 0.900 vs. 0.738
# Validation: 2700
# AUC = 0.910 vs. 0.178
# F1 = 0.839 vs. 0.300
# Precision = 0.876 vs. 0.177
# Recall = 0.805 vs. 1.000
# Minibatch Loss= 0.361390
# Training: 2800
# AUC = 0.938 vs. 0.205
# F1 = 0.874 vs. 0.318
# Precision = 0.873 vs. 0.196
# Recall = 0.875 vs. 0.833
# Validation: 2800
# AUC = 0.906 vs. 0.178
# F1 = 0.837 vs. 0.300
# Precision = 0.864 vs. 0.177
# Recall = 0.812 vs. 1.000
# Minibatch Loss= 0.487134
# Training: 2900
# AUC = 0.959 vs. 0.178
# F1 = 0.898 vs. 0.298
# Precision = 0.909 vs. 0.176
# Recall = 0.886 vs. 0.982
# Validation: 2900
# AUC = 0.905 vs. 0.176
# F1 = 0.839 vs. 0.300
# Precision = 0.893 vs. 0.177
# Recall = 0.792 vs. 1.000
# Minibatch Loss= 0.414828
# Training: 3000
# AUC = 0.951 vs. 0.231
# F1 = 0.884 vs. 0.380
# Precision = 0.877 vs. 0.235
# Recall = 0.892 vs. 1.000
# Validation: 3000
# AUC = 0.904 vs. 0.179
# F1 = 0.832 vs. 0.301
# Precision = 0.875 vs. 0.178
# Recall = 0.793 vs. 0.984
# Minibatch Loss= 0.507872
# Training: 3100
# AUC = 0.961 vs. 0.205
# F1 = 0.894 vs. 0.362
# Precision = 0.876 vs. 0.221
# Recall = 0.913 vs. 0.989
# Validation: 3100
# AUC = 0.911 vs. 0.178
# F1 = 0.837 vs. 0.300
# Precision = 0.888 vs. 0.177
# Recall = 0.791 vs. 1.000
# Minibatch Loss= 0.500319
# Training: 3200
# AUC = 0.917 vs. 0.203
# F1 = 0.844 vs. 0.352
# Precision = 0.831 vs. 0.214
# Recall = 0.857 vs. 0.993
# Validation: 3200
# AUC = 0.893 vs. 0.181
# F1 = 0.820 vs. 0.300
# Precision = 0.866 vs. 0.177
# Recall = 0.779 vs. 0.994
# Minibatch Loss= 0.626021
# Training: 3300
# AUC = 0.949 vs. 0.187
# F1 = 0.893 vs. 0.322
# Precision = 0.913 vs. 0.192
# Recall = 0.873 vs. 1.000
# Validation: 3300
# AUC = 0.915 vs. 0.176
# F1 = 0.843 vs. 0.300
# Precision = 0.858 vs. 0.177
# Recall = 0.828 vs. 0.993
# Minibatch Loss= 0.483583
# Training: 3400
# AUC = 0.936 vs. 0.199
# F1 = 0.855 vs. 0.345
# Precision = 0.845 vs. 0.209
# Recall = 0.865 vs. 0.993
# Validation: 3400
# AUC = 0.914 vs. 0.181
# F1 = 0.841 vs. 0.300
# Precision = 0.879 vs. 0.177
# Recall = 0.806 vs. 1.000
# Minibatch Loss= 0.509414
# Training: 3500
# AUC = 0.971 vs. 0.130
# F1 = 0.905 vs. 0.244
# Precision = 0.887 vs. 0.140
# Recall = 0.924 vs. 0.956
# Validation: 3500
# AUC = 0.908 vs. 0.179
# F1 = 0.840 vs. 0.300
# Precision = 0.892 vs. 0.177
# Recall = 0.793 vs. 1.000
# Minibatch Loss= 0.283938
# Training: 3600
# AUC = 0.966 vs. 0.123
# F1 = 0.898 vs. 0.220
# Precision = 0.898 vs. 0.126
# Recall = 0.898 vs. 0.856
# Validation: 3600
# AUC = 0.912 vs. 0.178
# F1 = 0.840 vs. 0.300
# Precision = 0.883 vs. 0.177
# Recall = 0.800 vs. 1.000
# Minibatch Loss= 0.286839
# Training: 3700
# AUC = 0.961 vs. 0.230
# F1 = 0.902 vs. 0.372
# Precision = 0.921 vs. 0.229
# Recall = 0.884 vs. 1.000
# Validation: 3700
# AUC = 0.914 vs. 0.178
# F1 = 0.844 vs. 0.300
# Precision = 0.888 vs. 0.177
# Recall = 0.805 vs. 0.999
# Minibatch Loss= 0.516760
# Training: 3800
# AUC = 0.975 vs. 0.172
# F1 = 0.920 vs. 0.289
# Precision = 0.915 vs. 0.169
# Recall = 0.926 vs. 0.993
# Validation: 3800
# AUC = 0.905 vs. 0.180
# F1 = 0.832 vs. 0.300
# Precision = 0.876 vs. 0.177
# Recall = 0.792 vs. 1.000
# Minibatch Loss= 0.359694
# Training: 3900
# AUC = 0.970 vs. 0.188
# F1 = 0.907 vs. 0.321
# Precision = 0.906 vs. 0.193
# Recall = 0.908 vs. 0.967
# Validation: 3900
# AUC = 0.907 vs. 0.175
# F1 = 0.838 vs. 0.300
# Precision = 0.888 vs. 0.177
# Recall = 0.793 vs. 0.999
# Minibatch Loss= 0.396371
# Training: 4000
# AUC = 0.965 vs. 0.190
# F1 = 0.894 vs. 0.314
# Precision = 0.895 vs. 0.186
# Recall = 0.893 vs. 1.000
# Validation: 4000
# AUC = 0.905 vs. 0.177
# F1 = 0.836 vs. 0.300
# Precision = 0.887 vs. 0.177
# Recall = 0.790 vs. 1.000
# Minibatch Loss= 0.383572
# Training: 4100
# AUC = 0.975 vs. 0.145
# F1 = 0.927 vs. 0.254
# Precision = 0.929 vs. 0.146
# Recall = 0.924 vs. 0.967
# Validation: 4100
# AUC = 0.902 vs. 0.174
# F1 = 0.830 vs. 0.300
# Precision = 0.863 vs. 0.177
# Recall = 0.798 vs. 0.994
# Minibatch Loss= 0.293904
# Training: 4200
# AUC = 0.970 vs. 0.202
# F1 = 0.912 vs. 0.344
# Precision = 0.938 vs. 0.208
# Recall = 0.887 vs. 0.994
# Validation: 4200
# AUC = 0.900 vs. 0.178
# F1 = 0.825 vs. 0.301
# Precision = 0.877 vs. 0.177
# Recall = 0.779 vs. 0.999
# Minibatch Loss= 0.416720
# Training: 4300
# AUC = 0.954 vs. 0.168
# F1 = 0.896 vs. 0.282
# Precision = 0.889 vs. 0.164
# Recall = 0.902 vs. 1.000
# Validation: 4300
# AUC = 0.900 vs. 0.177
# F1 = 0.824 vs. 0.300
# Precision = 0.852 vs. 0.177
# Recall = 0.797 vs. 1.000
# Minibatch Loss= 0.385508
# Training: 4400
# AUC = 0.941 vs. 0.196
# F1 = 0.882 vs. 0.332
# Precision = 0.893 vs. 0.199
# Recall = 0.871 vs. 1.000
# Validation: 4400
# AUC = 0.906 vs. 0.178
# F1 = 0.830 vs. 0.300
# Precision = 0.852 vs. 0.177
# Recall = 0.809 vs. 0.995
# Minibatch Loss= 0.484687
# Training: 4500
# AUC = 0.966 vs. 0.153
# F1 = 0.918 vs. 0.272
# Precision = 0.933 vs. 0.158
# Recall = 0.903 vs. 1.000
# Validation: 4500
# AUC = 0.906 vs. 0.176
# F1 = 0.833 vs. 0.300
# Precision = 0.891 vs. 0.177
# Recall = 0.783 vs. 0.997
# Minibatch Loss= 0.354192
# Training: 4600
# AUC = 0.960 vs. 0.161
# F1 = 0.895 vs. 0.289
# Precision = 0.882 vs. 0.170
# Recall = 0.907 vs. 0.964
# Validation: 4600
# AUC = 0.911 vs. 0.181
# F1 = 0.835 vs. 0.300
# Precision = 0.876 vs. 0.177
# Recall = 0.797 vs. 0.999
# Minibatch Loss= 0.375642
# Training: 4700
# AUC = 0.978 vs. 0.179
# F1 = 0.925 vs. 0.306
# Precision = 0.912 vs. 0.181
# Recall = 0.939 vs. 0.991
# Validation: 4700
# AUC = 0.908 vs. 0.174
# F1 = 0.831 vs. 0.300
# Precision = 0.869 vs. 0.177
# Recall = 0.796 vs. 1.000
# Minibatch Loss= 0.340537
# Training: 4800
# AUC = 0.959 vs. 0.160
# F1 = 0.886 vs. 0.285
# Precision = 0.912 vs. 0.166
# Recall = 0.861 vs. 1.000
# Validation: 4800
# AUC = 0.904 vs. 0.180
# F1 = 0.828 vs. 0.300
# Precision = 0.877 vs. 0.177
# Recall = 0.785 vs. 0.999
# Minibatch Loss= 0.378640
# Training: 4900
# AUC = 0.960 vs. 0.179
# F1 = 0.890 vs. 0.296
# Precision = 0.895 vs. 0.174
# Recall = 0.885 vs. 0.989
# Validation: 4900
# AUC = 0.904 vs. 0.177
# F1 = 0.830 vs. 0.300
# Precision = 0.880 vs. 0.177
# Recall = 0.785 vs. 1.000
# Minibatch Loss= 0.367768
# Training: 5000
# AUC = 0.952 vs. 0.209
# F1 = 0.885 vs. 0.345
# Precision = 0.912 vs. 0.210
# Recall = 0.859 vs. 0.979
# Validation: 5000
# AUC = 0.910 vs. 0.178
# F1 = 0.836 vs. 0.300
# Precision = 0.892 vs. 0.177
# Recall = 0.787 vs. 0.998
# Minibatch Loss= 0.471389
# Training: 5100
# AUC = 0.941 vs. 0.214
# F1 = 0.873 vs. 0.346
# Precision = 0.857 vs. 0.209
# Recall = 0.890 vs. 1.000
# Validation: 5100
# AUC = 0.905 vs. 0.173
# F1 = 0.830 vs. 0.300
# Precision = 0.877 vs. 0.177
# Recall = 0.788 vs. 1.000
# Minibatch Loss= 0.490521
# Training: 5200
# AUC = 0.969 vs. 0.205
# F1 = 0.909 vs. 0.338
# Precision = 0.933 vs. 0.204
# Recall = 0.887 vs. 0.992
# Validation: 5200
# AUC = 0.911 vs. 0.177
# F1 = 0.837 vs. 0.300
# Precision = 0.865 vs. 0.177
# Recall = 0.812 vs. 0.994
# Minibatch Loss= 0.418994
# Training: 5300
# AUC = 0.965 vs. 0.142
# F1 = 0.906 vs. 0.249
# Precision = 0.938 vs. 0.142
# Recall = 0.876 vs. 1.000
# Validation: 5300
# AUC = 0.910 vs. 0.176
# F1 = 0.832 vs. 0.300
# Precision = 0.842 vs. 0.177
# Recall = 0.822 vs. 0.999
# Minibatch Loss= 0.295531
# Training: 5400
# AUC = 0.968 vs. 0.185
# F1 = 0.905 vs. 0.316
# Precision = 0.909 vs. 0.188
# Recall = 0.901 vs. 0.987
# Validation: 5400
# AUC = 0.904 vs. 0.176
# F1 = 0.834 vs. 0.300
# Precision = 0.853 vs. 0.177
# Recall = 0.816 vs. 0.999
# Minibatch Loss= 0.385363
# Training: 5500
# AUC = 0.967 vs. 0.226
# F1 = 0.909 vs. 0.348
# Precision = 0.903 vs. 0.217
# Recall = 0.916 vs. 0.881
# Validation: 5500
# AUC = 0.894 vs. 0.179
# F1 = 0.824 vs. 0.300
# Precision = 0.875 vs. 0.177
# Recall = 0.778 vs. 0.996
# Minibatch Loss= 0.457762
# Training: 5600
# AUC = 0.963 vs. 0.186
# F1 = 0.904 vs. 0.301
# Precision = 0.910 vs. 0.177
# Recall = 0.898 vs. 1.000
# Validation: 5600
# AUC = 0.899 vs. 0.178
# F1 = 0.823 vs. 0.300
# Precision = 0.866 vs. 0.177
# Recall = 0.784 vs. 0.999
# Minibatch Loss= 0.400731
# Training: 5700
# AUC = 0.982 vs. 0.213
# F1 = 0.929 vs. 0.351
# Precision = 0.964 vs. 0.214
# Recall = 0.895 vs. 0.978
# Validation: 5700
# AUC = 0.908 vs. 0.176
# F1 = 0.831 vs. 0.300
# Precision = 0.847 vs. 0.177
# Recall = 0.815 vs. 1.000
# Minibatch Loss= 0.416868
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-51d04776f999> in <module>()
#       2                 train_eval_step=100,
#       3                 validation_eval_step=100,
# ----> 4                 display_step=100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=train_obj.global_step)
# Out:
# '../../model_synthetic/train_abrupt_test_gradual/RCNN1001_y/RCNN1001_y-5787'

# %%
#saver = tf.train.Saver()
#saver.restore(sess, checkpoint_path+'-1000')

# %%
_ = nn_eval.evaluate_model(model,
                                   sess,
                                   test_data,
                                   test_gt)
# Out:
# AUC = 0.900 vs. 0.177
# F1 = 0.826 vs. 0.300
# Precision = 0.858 vs. 0.177
# Recall = 0.796 vs. 0.999

# %%
out = nn_eval.deploy(model,
                     sess,
                     test_data,
                     test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
