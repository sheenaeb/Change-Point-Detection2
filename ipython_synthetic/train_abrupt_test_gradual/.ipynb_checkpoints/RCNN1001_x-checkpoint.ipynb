# %%
# useing this variable for saving models and summaries
exp_name = "RCNN1001_x"

# %% [markdown]
# ## Running CNN then RNN
# 5 layers CNN [2, 2, 2, 2, 2], then RNN, bias_shape = [32,64,64, 64, 64]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import sys
from hdf5storage import savemat
import pickle

sys.path.append('../../src')
sys.path.append('../../src/models')

# %%
import models.CNN_lstm_model as CNN_lstm_model
import training  
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed2.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %% [markdown]
# ## Model

# %%
## Model Parameter
n_variables= 12
learning_rate = 0.001
batch_size = 10

pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5,n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]

bias_shape = [32,64,64, 64, 64]
activation = tf.nn.relu

lstm_n_hidden = 128
n_classes = 1


#positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

# %%
pos_weight
# Out:
# 12.040832401194599

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = CNN_lstm_model.Model(n_variables, n_classes)

# %%
model.build_cnn_lstm_net(pooling_stride,
                         weights_shape,
                         bias_shape,
                         activation,
                         lstm_n_hidden,
                         n_classes,
                         learning_rate,
                         pos_weight,
                         trainable_conv=True,
                         trainable_last=True)

# %%
train_obj = training.Trainer(model,
                 train_data, train_gt,
                 validation_data, validation_gt,
                 sess,
                 summary_path,
                 batch_size,
                 global_step = 0)

# %%
train_obj.train(max_iter = 10000,
                train_eval_step=100,
                validation_eval_step=100,
                display_step=100)
# Out:
# Training: 0
# AUC = 0.068 vs. 0.075
# F1 = 0.155 vs. 0.150
# Precision = 0.085 vs. 0.081
# Recall = 0.884 vs. 0.985
# Validation: 0
# AUC = 0.070 vs. 0.076
# F1 = 0.144 vs. 0.135
# Precision = 0.078 vs. 0.073
# Recall = 0.891 vs. 0.960
# Minibatch Loss= 2.159580
# Training: 100
# AUC = 0.617 vs. 0.080
# F1 = 0.645 vs. 0.141
# Precision = 0.630 vs. 0.080
# Recall = 0.661 vs. 0.617
# Validation: 100
# AUC = 0.538 vs. 0.073
# F1 = 0.593 vs. 0.136
# Precision = 0.574 vs. 0.073
# Recall = 0.613 vs. 0.981
# Minibatch Loss= 0.911889
# Training: 200
# AUC = 0.693 vs. 0.085
# F1 = 0.718 vs. 0.157
# Precision = 0.732 vs. 0.086
# Recall = 0.704 vs. 0.840
# Validation: 200
# AUC = 0.688 vs. 0.073
# F1 = 0.700 vs. 0.135
# Precision = 0.723 vs. 0.073
# Recall = 0.679 vs. 0.996
# Minibatch Loss= 0.967240
# Training: 300
# AUC = 0.761 vs. 0.070
# F1 = 0.761 vs. 0.143
# Precision = 0.830 vs. 0.077
# Recall = 0.703 vs. 1.000
# Validation: 300
# AUC = 0.752 vs. 0.070
# F1 = 0.754 vs. 0.135
# Precision = 0.734 vs. 0.073
# Recall = 0.775 vs. 0.995
# Minibatch Loss= 0.760259
# Training: 400
# AUC = 0.813 vs. 0.088
# F1 = 0.798 vs. 0.159
# Precision = 0.792 vs. 0.101
# Recall = 0.804 vs. 0.366
# Validation: 400
# AUC = 0.783 vs. 0.074
# F1 = 0.769 vs. 0.136
# Precision = 0.775 vs. 0.073
# Recall = 0.763 vs. 0.984
# Minibatch Loss= 0.678293
# Training: 500
# AUC = 0.861 vs. 0.067
# F1 = 0.847 vs. 0.124
# Precision = 0.820 vs. 0.070
# Recall = 0.876 vs. 0.516
# Validation: 500
# AUC = 0.794 vs. 0.073
# F1 = 0.794 vs. 0.135
# Precision = 0.812 vs. 0.073
# Recall = 0.776 vs. 0.996
# Minibatch Loss= 0.505418
# Training: 600
# AUC = 0.825 vs. 0.070
# F1 = 0.844 vs. 0.148
# Precision = 0.899 vs. 0.080
# Recall = 0.796 vs. 0.990
# Validation: 600
# AUC = 0.808 vs. 0.073
# F1 = 0.798 vs. 0.136
# Precision = 0.849 vs. 0.073
# Recall = 0.753 vs. 0.918
# Minibatch Loss= 0.574439
# Training: 700
# AUC = 0.872 vs. 0.070
# F1 = 0.813 vs. 0.138
# Precision = 0.831 vs. 0.075
# Recall = 0.796 vs. 0.909
# Validation: 700
# AUC = 0.870 vs. 0.074
# F1 = 0.833 vs. 0.136
# Precision = 0.863 vs. 0.074
# Recall = 0.805 vs. 0.820
# Minibatch Loss= 0.457678
# Training: 800
# AUC = 0.859 vs. 0.067
# F1 = 0.812 vs. 0.130
# Precision = 0.927 vs. 0.070
# Recall = 0.722 vs. 0.977
# Validation: 800
# AUC = 0.878 vs. 0.072
# F1 = 0.839 vs. 0.135
# Precision = 0.881 vs. 0.073
# Recall = 0.802 vs. 0.999
# Minibatch Loss= 0.510190
# Training: 900
# AUC = 0.913 vs. 0.081
# F1 = 0.871 vs. 0.143
# Precision = 0.850 vs. 0.077
# Recall = 0.893 vs. 0.985
# Validation: 900
# AUC = 0.877 vs. 0.071
# F1 = 0.840 vs. 0.135
# Precision = 0.874 vs. 0.073
# Recall = 0.809 vs. 0.929
# Minibatch Loss= 0.440360
# Training: 1000
# AUC = 0.932 vs. 0.090
# F1 = 0.887 vs. 0.158
# Precision = 0.881 vs. 0.086
# Recall = 0.894 vs. 0.949
# Validation: 1000
# AUC = 0.899 vs. 0.074
# F1 = 0.861 vs. 0.136
# Precision = 0.914 vs. 0.075
# Recall = 0.815 vs. 0.696
# Minibatch Loss= 0.477114
# Training: 1100
# AUC = 0.929 vs. 0.074
# F1 = 0.891 vs. 0.138
# Precision = 0.879 vs. 0.075
# Recall = 0.903 vs. 0.870
# Validation: 1100
# AUC = 0.901 vs. 0.070
# F1 = 0.856 vs. 0.135
# Precision = 0.864 vs. 0.072
# Recall = 0.849 vs. 1.000
# Minibatch Loss= 0.341179
# Training: 1200
# AUC = 0.885 vs. 0.058
# F1 = 0.878 vs. 0.123
# Precision = 0.871 vs. 0.065
# Recall = 0.886 vs. 1.000
# Validation: 1200
# AUC = 0.819 vs. 0.074
# F1 = 0.827 vs. 0.136
# Precision = 0.826 vs. 0.073
# Recall = 0.827 vs. 0.918
# Minibatch Loss= 0.322241
# Training: 1300
# AUC = 0.951 vs. 0.065
# F1 = 0.896 vs. 0.126
# Precision = 0.920 vs. 0.067
# Recall = 0.872 vs. 1.000
# Validation: 1300
# AUC = 0.889 vs. 0.074
# F1 = 0.858 vs. 0.136
# Precision = 0.879 vs. 0.074
# Recall = 0.838 vs. 0.819
# Minibatch Loss= 0.360239
# Training: 1400
# AUC = 0.958 vs. 0.074
# F1 = 0.895 vs. 0.146
# Precision = 0.938 vs. 0.081
# Recall = 0.856 vs. 0.728
# Validation: 1400
# AUC = 0.914 vs. 0.074
# F1 = 0.854 vs. 0.136
# Precision = 0.873 vs. 0.073
# Recall = 0.837 vs. 0.919
# Minibatch Loss= 0.359633
# Training: 1500
# AUC = 0.951 vs. 0.078
# F1 = 0.894 vs. 0.151
# Precision = 0.939 vs. 0.083
# Recall = 0.854 vs. 0.904
# Validation: 1500
# AUC = 0.919 vs. 0.071
# F1 = 0.862 vs. 0.136
# Precision = 0.881 vs. 0.073
# Recall = 0.845 vs. 0.973
# Minibatch Loss= 0.396581
# Training: 1600
# AUC = 0.956 vs. 0.082
# F1 = 0.898 vs. 0.145
# Precision = 0.872 vs. 0.078
# Recall = 0.927 vs. 0.932
# Validation: 1600
# AUC = 0.918 vs. 0.071
# F1 = 0.859 vs. 0.135
# Precision = 0.902 vs. 0.073
# Recall = 0.819 vs. 1.000
# Minibatch Loss= 0.334233
# Training: 1700
# AUC = 0.932 vs. 0.069
# F1 = 0.865 vs. 0.137
# Precision = 0.938 vs. 0.079
# Recall = 0.802 vs. 0.545
# Validation: 1700
# AUC = 0.931 vs. 0.074
# F1 = 0.878 vs. 0.136
# Precision = 0.909 vs. 0.073
# Recall = 0.849 vs. 0.918
# Minibatch Loss= 0.378386
# Training: 1800
# AUC = 0.950 vs. 0.066
# F1 = 0.894 vs. 0.130
# Precision = 0.905 vs. 0.070
# Recall = 0.884 vs. 0.849
# Validation: 1800
# AUC = 0.926 vs. 0.074
# F1 = 0.864 vs. 0.135
# Precision = 0.892 vs. 0.073
# Recall = 0.838 vs. 0.999
# Minibatch Loss= 0.303401
# Training: 1900
# AUC = 0.942 vs. 0.063
# F1 = 0.881 vs. 0.129
# Precision = 0.889 vs. 0.069
# Recall = 0.874 vs. 0.989
# Validation: 1900
# AUC = 0.927 vs. 0.073
# F1 = 0.869 vs. 0.136
# Precision = 0.928 vs. 0.073
# Recall = 0.817 vs. 0.985
# Minibatch Loss= 0.323449
# Training: 2000
# AUC = 0.968 vs. 0.070
# F1 = 0.909 vs. 0.133
# Precision = 0.931 vs. 0.080
# Recall = 0.887 vs. 0.399
# Validation: 2000
# AUC = 0.930 vs. 0.069
# F1 = 0.881 vs. 0.135
# Precision = 0.922 vs. 0.073
# Recall = 0.843 vs. 0.995
# Minibatch Loss= 0.263553
# Training: 2100
# AUC = 0.945 vs. 0.074
# F1 = 0.903 vs. 0.151
# Precision = 0.884 vs. 0.082
# Recall = 0.922 vs. 0.966
# Validation: 2100
# AUC = 0.924 vs. 0.072
# F1 = 0.866 vs. 0.135
# Precision = 0.903 vs. 0.073
# Recall = 0.832 vs. 0.990
# Minibatch Loss= 0.338112
# Training: 2200
# AUC = 0.925 vs. 0.072
# F1 = 0.872 vs. 0.138
# Precision = 0.892 vs. 0.074
# Recall = 0.853 vs. 0.962
# Validation: 2200
# AUC = 0.925 vs. 0.072
# F1 = 0.869 vs. 0.135
# Precision = 0.903 vs. 0.073
# Recall = 0.837 vs. 1.000
# Minibatch Loss= 0.354760
# Training: 2300
# AUC = 0.913 vs. 0.081
# F1 = 0.886 vs. 0.147
# Precision = 0.877 vs. 0.080
# Recall = 0.894 vs. 0.930
# Validation: 2300
# AUC = 0.931 vs. 0.071
# F1 = 0.875 vs. 0.135
# Precision = 0.910 vs. 0.073
# Recall = 0.843 vs. 0.995
# Minibatch Loss= 0.379191
# Training: 2400
# AUC = 0.949 vs. 0.066
# F1 = 0.888 vs. 0.135
# Precision = 0.933 vs. 0.073
# Recall = 0.846 vs. 0.901
# Validation: 2400
# AUC = 0.930 vs. 0.073
# F1 = 0.874 vs. 0.136
# Precision = 0.915 vs. 0.074
# Recall = 0.836 vs. 0.895
# Minibatch Loss= 0.305386
# Training: 2500
# AUC = 0.969 vs. 0.086
# F1 = 0.920 vs. 0.149
# Precision = 0.935 vs. 0.086
# Recall = 0.906 vs. 0.539
# Validation: 2500
# AUC = 0.912 vs. 0.073
# F1 = 0.857 vs. 0.136
# Precision = 0.876 vs. 0.075
# Recall = 0.839 vs. 0.735
# Minibatch Loss= 0.318754
# Training: 2600
# AUC = 0.974 vs. 0.076
# F1 = 0.918 vs. 0.139
# Precision = 0.904 vs. 0.075
# Recall = 0.932 vs. 1.000
# Validation: 2600
# AUC = 0.929 vs. 0.070
# F1 = 0.874 vs. 0.136
# Precision = 0.904 vs. 0.073
# Recall = 0.847 vs. 0.965
# Minibatch Loss= 0.267431
# Training: 2700
# AUC = 0.954 vs. 0.082
# F1 = 0.905 vs. 0.155
# Precision = 0.877 vs. 0.084
# Recall = 0.935 vs. 1.000
# Validation: 2700
# AUC = 0.915 vs. 0.074
# F1 = 0.862 vs. 0.135
# Precision = 0.901 vs. 0.072
# Recall = 0.826 vs. 1.000
# Minibatch Loss= 0.327189
# Training: 2800
# AUC = 0.976 vs. 0.069
# F1 = 0.934 vs. 0.133
# Precision = 0.959 vs. 0.071
# Recall = 0.911 vs. 0.989
# Validation: 2800
# AUC = 0.927 vs. 0.072
# F1 = 0.872 vs. 0.135
# Precision = 0.940 vs. 0.072
# Recall = 0.813 vs. 1.000
# Minibatch Loss= 0.270239
# Training: 2900
# AUC = 0.958 vs. 0.096
# F1 = 0.898 vs. 0.157
# Precision = 0.892 vs. 0.089
# Recall = 0.905 vs. 0.675
# Validation: 2900
# AUC = 0.925 vs. 0.071
# F1 = 0.875 vs. 0.135
# Precision = 0.911 vs. 0.073
# Recall = 0.842 vs. 0.987
# Minibatch Loss= 0.337367
# Training: 3000
# AUC = 0.973 vs. 0.074
# F1 = 0.907 vs. 0.146
# Precision = 0.872 vs. 0.079
# Recall = 0.945 vs. 0.990
# Validation: 3000
# AUC = 0.915 vs. 0.072
# F1 = 0.862 vs. 0.135
# Precision = 0.918 vs. 0.073
# Recall = 0.812 vs. 0.991
# Minibatch Loss= 0.310357
# Training: 3100
# AUC = 0.958 vs. 0.072
# F1 = 0.901 vs. 0.146
# Precision = 0.928 vs. 0.079
# Recall = 0.875 vs. 0.953
# Validation: 3100
# AUC = 0.919 vs. 0.073
# F1 = 0.871 vs. 0.135
# Precision = 0.909 vs. 0.073
# Recall = 0.836 vs. 0.951
# Minibatch Loss= 0.318950
# Training: 3200
# AUC = 0.971 vs. 0.078
# F1 = 0.934 vs. 0.144
# Precision = 0.942 vs. 0.086
# Recall = 0.926 vs. 0.440
# Validation: 3200
# AUC = 0.928 vs. 0.073
# F1 = 0.875 vs. 0.136
# Precision = 0.928 vs. 0.073
# Recall = 0.827 vs. 0.995
# Minibatch Loss= 0.254958
# Training: 3300
# AUC = 0.968 vs. 0.082
# F1 = 0.922 vs. 0.152
# Precision = 0.945 vs. 0.082
# Recall = 0.900 vs. 0.981
# Validation: 3300
# AUC = 0.930 vs. 0.076
# F1 = 0.874 vs. 0.135
# Precision = 0.941 vs. 0.073
# Recall = 0.816 vs. 0.996
# Minibatch Loss= 0.277292
# Training: 3400
# AUC = 0.971 vs. 0.077
# F1 = 0.914 vs. 0.135
# Precision = 0.911 vs. 0.077
# Recall = 0.916 vs. 0.536
# Validation: 3400
# AUC = 0.923 vs. 0.075
# F1 = 0.871 vs. 0.135
# Precision = 0.930 vs. 0.073
# Recall = 0.819 vs. 0.997
# Minibatch Loss= 0.273367
# Training: 3500
# AUC = 0.980 vs. 0.086
# F1 = 0.932 vs. 0.154
# Precision = 0.917 vs. 0.083
# Recall = 0.947 vs. 0.981
# Validation: 3500
# AUC = 0.926 vs. 0.072
# F1 = 0.870 vs. 0.136
# Precision = 0.904 vs. 0.073
# Recall = 0.838 vs. 0.961
# Minibatch Loss= 0.311485
# Training: 3600
# AUC = 0.960 vs. 0.069
# F1 = 0.903 vs. 0.139
# Precision = 0.894 vs. 0.076
# Recall = 0.913 vs. 0.853
# Validation: 3600
# AUC = 0.930 vs. 0.072
# F1 = 0.878 vs. 0.136
# Precision = 0.879 vs. 0.073
# Recall = 0.877 vs. 0.957
# Minibatch Loss= 0.299214
# Training: 3700
# AUC = 0.985 vs. 0.062
# F1 = 0.937 vs. 0.137
# Precision = 0.927 vs. 0.074
# Recall = 0.947 vs. 1.000
# Validation: 3700
# AUC = 0.930 vs. 0.072
# F1 = 0.884 vs. 0.135
# Precision = 0.914 vs. 0.072
# Recall = 0.857 vs. 1.000
# Minibatch Loss= 0.263022
# Training: 3800
# AUC = 0.965 vs. 0.082
# F1 = 0.904 vs. 0.153
# Precision = 0.867 vs. 0.085
# Recall = 0.943 vs. 0.814
# Validation: 3800
# AUC = 0.925 vs. 0.071
# F1 = 0.869 vs. 0.136
# Precision = 0.877 vs. 0.073
# Recall = 0.860 vs. 0.978
# Minibatch Loss= 0.284147
# Training: 3900
# AUC = 0.971 vs. 0.069
# F1 = 0.915 vs. 0.143
# Precision = 0.875 vs. 0.077
# Recall = 0.958 vs. 0.947
# Validation: 3900
# AUC = 0.927 vs. 0.074
# F1 = 0.872 vs. 0.137
# Precision = 0.923 vs. 0.075
# Recall = 0.825 vs. 0.764
# Minibatch Loss= 0.261055
# Training: 4000
# AUC = 0.966 vs. 0.072
# F1 = 0.912 vs. 0.144
# Precision = 0.915 vs. 0.078
# Recall = 0.910 vs. 0.984
# Validation: 4000
# AUC = 0.922 vs. 0.074
# F1 = 0.871 vs. 0.136
# Precision = 0.929 vs. 0.073
# Recall = 0.819 vs. 0.965
# Minibatch Loss= 0.250960
# Training: 4100
# AUC = 0.971 vs. 0.074
# F1 = 0.914 vs. 0.150
# Precision = 0.916 vs. 0.081
# Recall = 0.911 vs. 0.961
# Validation: 4100
# AUC = 0.925 vs. 0.074
# F1 = 0.869 vs. 0.135
# Precision = 0.913 vs. 0.072
# Recall = 0.829 vs. 0.998
# Minibatch Loss= 0.306998
# Training: 4200
# AUC = 0.976 vs. 0.081
# F1 = 0.934 vs. 0.141
# Precision = 0.915 vs. 0.076
# Recall = 0.953 vs. 1.000
# Validation: 4200
# AUC = 0.933 vs. 0.075
# F1 = 0.878 vs. 0.136
# Precision = 0.915 vs. 0.075
# Recall = 0.844 vs. 0.776
# Minibatch Loss= 0.288478
# Training: 4300
# AUC = 0.979 vs. 0.078
# F1 = 0.931 vs. 0.153
# Precision = 0.921 vs. 0.083
# Recall = 0.943 vs. 0.976
# Validation: 4300
# AUC = 0.924 vs. 0.072
# F1 = 0.873 vs. 0.135
# Precision = 0.916 vs. 0.073
# Recall = 0.834 vs. 0.947
# Minibatch Loss= 0.281076
# Training: 4400
# AUC = 0.946 vs. 0.068
# F1 = 0.869 vs. 0.139
# Precision = 0.912 vs. 0.075
# Recall = 0.830 vs. 0.936
# Validation: 4400
# AUC = 0.911 vs. 0.068
# F1 = 0.858 vs. 0.136
# Precision = 0.908 vs. 0.073
# Recall = 0.812 vs. 0.985
# Minibatch Loss= 0.327993
# Training: 4500
# AUC = 0.986 vs. 0.070
# F1 = 0.944 vs. 0.135
# Precision = 0.927 vs. 0.073
# Recall = 0.962 vs. 0.940
# Validation: 4500
# AUC = 0.922 vs. 0.074
# F1 = 0.868 vs. 0.135
# Precision = 0.899 vs. 0.073
# Recall = 0.839 vs. 0.991
# Minibatch Loss= 0.256175
# Training: 4600
# AUC = 0.981 vs. 0.069
# F1 = 0.942 vs. 0.136
# Precision = 0.940 vs. 0.074
# Recall = 0.945 vs. 0.852
# Validation: 4600
# AUC = 0.932 vs. 0.072
# F1 = 0.874 vs. 0.136
# Precision = 0.916 vs. 0.073
# Recall = 0.836 vs. 0.969
# Minibatch Loss= 0.269496
# Training: 4700
# AUC = 0.963 vs. 0.072
# F1 = 0.911 vs. 0.138
# Precision = 0.911 vs. 0.095
# Recall = 0.911 vs. 0.250
# Validation: 4700
# AUC = 0.928 vs. 0.073
# F1 = 0.875 vs. 0.136
# Precision = 0.919 vs. 0.073
# Recall = 0.835 vs. 0.967
# Minibatch Loss= 0.262169
# Training: 4800
# AUC = 0.981 vs. 0.071
# F1 = 0.928 vs. 0.141
# Precision = 0.909 vs. 0.077
# Recall = 0.947 vs. 0.858
# Validation: 4800
# AUC = 0.929 vs. 0.074
# F1 = 0.876 vs. 0.135
# Precision = 0.913 vs. 0.073
# Recall = 0.843 vs. 0.985
# Minibatch Loss= 0.232191
# Training: 4900
# AUC = 0.973 vs. 0.063
# F1 = 0.914 vs. 0.127
# Precision = 0.877 vs. 0.068
# Recall = 0.953 vs. 1.000
# Validation: 4900
# AUC = 0.921 vs. 0.072
# F1 = 0.868 vs. 0.136
# Precision = 0.894 vs. 0.073
# Recall = 0.844 vs. 0.987
# Minibatch Loss= 0.260221
# Training: 5000
# AUC = 0.980 vs. 0.080
# F1 = 0.927 vs. 0.145
# Precision = 0.970 vs. 0.080
# Recall = 0.886 vs. 0.757
# Validation: 5000
# AUC = 0.913 vs. 0.074
# F1 = 0.864 vs. 0.135
# Precision = 0.897 vs. 0.073
# Recall = 0.833 vs. 0.994
# Minibatch Loss= 0.257564
# Training: 5100
# AUC = 0.977 vs. 0.076
# F1 = 0.931 vs. 0.157
# Precision = 0.927 vs. 0.085
# Recall = 0.935 vs. 1.000
# Validation: 5100
# AUC = 0.928 vs. 0.074
# F1 = 0.875 vs. 0.135
# Precision = 0.904 vs. 0.073
# Recall = 0.849 vs. 0.996
# Minibatch Loss= 0.261527
# Training: 5200
# AUC = 0.981 vs. 0.073
# F1 = 0.940 vs. 0.138
# Precision = 0.970 vs. 0.076
# Recall = 0.911 vs. 0.722
# Validation: 5200
# AUC = 0.923 vs. 0.072
# F1 = 0.874 vs. 0.135
# Precision = 0.918 vs. 0.073
# Recall = 0.835 vs. 0.996
# Minibatch Loss= 0.248855
# Training: 5300
# AUC = 0.977 vs. 0.075
# F1 = 0.926 vs. 0.127
# Precision = 0.918 vs. 0.069
# Recall = 0.934 vs. 0.880
# Validation: 5300
# AUC = 0.931 vs. 0.073
# F1 = 0.875 vs. 0.135
# Precision = 0.901 vs. 0.073
# Recall = 0.851 vs. 0.963
# Minibatch Loss= 0.244268
# Training: 5400
# AUC = 0.985 vs. 0.073
# F1 = 0.951 vs. 0.138
# Precision = 0.945 vs. 0.074
# Recall = 0.956 vs. 0.956
# Validation: 5400
# AUC = 0.928 vs. 0.070
# F1 = 0.874 vs. 0.136
# Precision = 0.890 vs. 0.073
# Recall = 0.859 vs. 0.963
# Minibatch Loss= 0.228833
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-51d04776f999> in <module>()
#       2                 train_eval_step=100,
#       3                 validation_eval_step=100,
# ----> 4                 display_step=100)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=train_obj.global_step)
# Out:
# '../../model_synthetic/train_abrupt_test_gradual/RCNN1001_x/RCNN1001_x-5462'

# %%
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path+'-1000')

# %%
_ = nn_eval.evaluate_model(model,
                           sess,
                           test_data[:100],
                           test_gt[:100])
# Out:
# AUC = 0.852 vs. 0.283
# F1 = 0.766 vs. 0.435
# Precision = 0.832 vs. 0.278
# Recall = 0.709 vs. 0.998

# %%
out = nn_eval.deploy(model,
                     sess,
                     test_data[:],
                     test_gt[:])

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (1000, 256)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
