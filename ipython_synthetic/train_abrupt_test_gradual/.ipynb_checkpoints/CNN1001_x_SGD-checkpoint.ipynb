# %%
# useing this variable for saving models and summaries
exp_name = "CNN1001_x_SGD"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed2.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape, validation_data.shape, test_data.shape, train_gt.shape, validation_gt.shape, test_gt.shape, index_of_changes.shape
# Out:
# ((8, 8192, 12),
#  (2, 8192, 12),
#  (1000, 8192, 12),
#  (8, 8192, 1),
#  (2, 8192, 1),
#  (1000, 8192, 1),
#  (1000, 4))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

#variables_weights = np.ones((n_classes,))

# %%
print pos_weight
# Out:
# 12.3987655821

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values= pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,)

# %%
model.optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(model.cost)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.069 vs. 0.085
# F1 = 0.155 vs. 0.145
# Precision = 0.087 vs. 0.088
# Recall = 0.733 vs. 0.418
# Validation: 0
# AUC = 0.052 vs. 0.047
# F1 = 0.135 vs. 0.101
# Precision = 0.074 vs. 0.053
# Recall = 0.778 vs. 1.000
# Minibatch Loss= 1.283118
# Training: 100
# AUC = 0.086 vs. 0.070
# F1 = 0.171 vs. 0.134
# Precision = 0.104 vs. 0.072
# Recall = 0.493 vs. 0.952
# Validation: 100
# AUC = 0.052 vs. 0.062
# F1 = 0.130 vs. 0.158
# Precision = 0.071 vs. 0.122
# Recall = 0.852 vs. 0.222
# Minibatch Loss= 1.279808
# Training: 200
# AUC = 0.106 vs. 0.076
# F1 = 0.213 vs. 0.142
# Precision = 0.137 vs. 0.079
# Recall = 0.473 vs. 0.678
# Validation: 200
# AUC = 0.053 vs. 0.062
# F1 = 0.131 vs. 0.119
# Precision = 0.071 vs. 0.073
# Recall = 0.815 vs. 0.333
# Minibatch Loss= 1.276662
# Training: 300
# AUC = 0.122 vs. 0.079
# F1 = 0.231 vs. 0.144
# Precision = 0.164 vs. 0.080
# Recall = 0.390 vs. 0.685
# Validation: 300
# AUC = 0.053 vs. 0.060
# F1 = 0.131 vs. 0.126
# Precision = 0.072 vs. 0.074
# Recall = 0.704 vs. 0.444
# Minibatch Loss= 1.273878
# Training: 400
# AUC = 0.136 vs. 0.075
# F1 = 0.247 vs. 0.138
# Precision = 0.167 vs. 0.074
# Recall = 0.473 vs. 0.959
# Validation: 400
# AUC = 0.053 vs. 0.080
# F1 = 0.147 vs. 0.141
# Precision = 0.082 vs. 0.097
# Recall = 0.741 vs. 0.259
# Minibatch Loss= 1.271257
# Training: 500
# AUC = 0.146 vs. 0.084
# F1 = 0.265 vs. 0.142
# Precision = 0.183 vs. 0.079
# Recall = 0.479 vs. 0.692
# Validation: 500
# AUC = 0.053 vs. 0.065
# F1 = 0.141 vs. 0.118
# Precision = 0.078 vs. 0.064
# Recall = 0.704 vs. 0.852
# Minibatch Loss= 1.268669
# Training: 600
# AUC = 0.154 vs. 0.074
# F1 = 0.278 vs. 0.134
# Precision = 0.241 vs. 0.072
# Recall = 0.329 vs. 0.979
# Validation: 600
# AUC = 0.050 vs. 0.055
# F1 = 0.126 vs. 0.120
# Precision = 0.069 vs. 0.068
# Recall = 0.667 vs. 0.481
# Minibatch Loss= 1.266039
# Training: 700
# AUC = 0.159 vs. 0.079
# F1 = 0.286 vs. 0.139
# Precision = 0.257 vs. 0.076
# Recall = 0.322 vs. 0.781
# Validation: 700
# AUC = 0.047 vs. 0.079
# F1 = 0.121 vs. 0.183
# Precision = 0.067 vs. 0.113
# Recall = 0.593 vs. 0.481
# Minibatch Loss= 1.263304
# Training: 800
# AUC = 0.163 vs. 0.076
# F1 = 0.306 vs. 0.139
# Precision = 0.257 vs. 0.076
# Recall = 0.377 vs. 0.863
# Validation: 800
# AUC = 0.045 vs. 0.063
# F1 = 0.111 vs. 0.127
# Precision = 0.061 vs. 0.070
# Recall = 0.630 vs. 0.667
# Minibatch Loss= 1.260413
# Training: 900
# AUC = 0.167 vs. 0.068
# F1 = 0.328 vs. 0.133
# Precision = 0.276 vs. 0.072
# Recall = 0.404 vs. 0.918
# Validation: 900
# AUC = 0.044 vs. 0.110
# F1 = 0.103 vs. 0.165
# Precision = 0.055 vs. 0.110
# Recall = 0.926 vs. 0.333
# Minibatch Loss= 1.257263
# Training: 1000
# AUC = 0.171 vs. 0.078
# F1 = 0.332 vs. 0.138
# Precision = 0.282 vs. 0.075
# Recall = 0.404 vs. 0.918
# Validation: 1000
# AUC = 0.042 vs. 0.072
# F1 = 0.104 vs. 0.152
# Precision = 0.055 vs. 0.108
# Recall = 1.000 vs. 0.259
# Minibatch Loss= 1.253734
# Training: 1100
# AUC = 0.173 vs. 0.079
# F1 = 0.334 vs. 0.140
# Precision = 0.285 vs. 0.077
# Recall = 0.404 vs. 0.760
# Validation: 1100
# AUC = 0.040 vs. 0.037
# F1 = 0.106 vs. 0.104
# Precision = 0.056 vs. 0.055
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 1.249937
# Training: 1200
# AUC = 0.175 vs. 0.076
# F1 = 0.337 vs. 0.140
# Precision = 0.286 vs. 0.077
# Recall = 0.411 vs. 0.801
# Validation: 1200
# AUC = 0.040 vs. 0.055
# F1 = 0.107 vs. 0.109
# Precision = 0.056 vs. 0.058
# Recall = 1.000 vs. 0.926
# Minibatch Loss= 1.245839
# Training: 1300
# AUC = 0.177 vs. 0.067
# F1 = 0.344 vs. 0.144
# Precision = 0.280 vs. 0.081
# Recall = 0.445 vs. 0.671
# Validation: 1300
# AUC = 0.041 vs. 0.071
# F1 = 0.107 vs. 0.139
# Precision = 0.057 vs. 0.091
# Recall = 1.000 vs. 0.296
# Minibatch Loss= 1.241430
# Training: 1400
# AUC = 0.182 vs. 0.078
# F1 = 0.343 vs. 0.144
# Precision = 0.290 vs. 0.086
# Recall = 0.418 vs. 0.445
# Validation: 1400
# AUC = 0.044 vs. 0.061
# F1 = 0.108 vs. 0.130
# Precision = 0.057 vs. 0.076
# Recall = 1.000 vs. 0.444
# Minibatch Loss= 1.236636
# Training: 1500
# AUC = 0.186 vs. 0.078
# F1 = 0.347 vs. 0.143
# Precision = 0.294 vs. 0.082
# Recall = 0.425 vs. 0.568
# Validation: 1500
# AUC = 0.043 vs. 0.076
# F1 = 0.108 vs. 0.132
# Precision = 0.057 vs. 0.094
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 1.231346
# Training: 1600
# AUC = 0.191 vs. 0.068
# F1 = 0.341 vs. 0.136
# Precision = 0.284 vs. 0.073
# Recall = 0.425 vs. 0.959
# Validation: 1600
# AUC = 0.044 vs. 0.043
# F1 = 0.108 vs. 0.107
# Precision = 0.057 vs. 0.057
# Recall = 1.000 vs. 0.963
# Minibatch Loss= 1.225659
# Training: 1700
# AUC = 0.197 vs. 0.070
# F1 = 0.348 vs. 0.137
# Precision = 0.275 vs. 0.074
# Recall = 0.473 vs. 0.897
# Validation: 1700
# AUC = 0.044 vs. 0.050
# F1 = 0.108 vs. 0.110
# Precision = 0.057 vs. 0.058
# Recall = 1.000 vs. 0.963
# Minibatch Loss= 1.219392
# Training: 1800
# AUC = 0.201 vs. 0.074
# F1 = 0.349 vs. 0.138
# Precision = 0.284 vs. 0.075
# Recall = 0.452 vs. 0.877
# Validation: 1800
# AUC = 0.044 vs. 0.042
# F1 = 0.108 vs. 0.111
# Precision = 0.057 vs. 0.059
# Recall = 1.000 vs. 0.815
# Minibatch Loss= 1.212545
# Training: 1900
# AUC = 0.202 vs. 0.068
# F1 = 0.346 vs. 0.134
# Precision = 0.281 vs. 0.072
# Recall = 0.452 vs. 1.000
# Validation: 1900
# AUC = 0.045 vs. 0.044
# F1 = 0.109 vs. 0.103
# Precision = 0.058 vs. 0.055
# Recall = 0.852 vs. 0.963
# Minibatch Loss= 1.205188
# Training: 2000
# AUC = 0.203 vs. 0.076
# F1 = 0.351 vs. 0.136
# Precision = 0.274 vs. 0.074
# Recall = 0.486 vs. 0.918
# Validation: 2000
# AUC = 0.045 vs. 0.058
# F1 = 0.117 vs. 0.135
# Precision = 0.063 vs. 0.079
# Recall = 0.926 vs. 0.444
# Minibatch Loss= 1.197289
# Training: 2100
# AUC = 0.203 vs. 0.068
# F1 = 0.353 vs. 0.136
# Precision = 0.277 vs. 0.073
# Recall = 0.486 vs. 0.973
# Validation: 2100
# AUC = 0.043 vs. 0.058
# F1 = 0.122 vs. 0.111
# Precision = 0.065 vs. 0.089
# Recall = 0.963 vs. 0.148
# Minibatch Loss= 1.188851
# Training: 2200
# AUC = 0.203 vs. 0.075
# F1 = 0.360 vs. 0.139
# Precision = 0.277 vs. 0.080
# Recall = 0.514 vs. 0.521
# Validation: 2200
# AUC = 0.042 vs. 0.056
# F1 = 0.123 vs. 0.116
# Precision = 0.066 vs. 0.068
# Recall = 1.000 vs. 0.407
# Minibatch Loss= 1.179771
# Training: 2300
# AUC = 0.204 vs. 0.079
# F1 = 0.364 vs. 0.141
# Precision = 0.282 vs. 0.076
# Recall = 0.514 vs. 0.932
# Validation: 2300
# AUC = 0.041 vs. 0.048
# F1 = 0.120 vs. 0.102
# Precision = 0.064 vs. 0.054
# Recall = 0.963 vs. 1.000
# Minibatch Loss= 1.169923
# Training: 2400
# AUC = 0.207 vs. 0.076
# F1 = 0.367 vs. 0.144
# Precision = 0.275 vs. 0.081
# Recall = 0.555 vs. 0.685
# Validation: 2400
# AUC = 0.041 vs. 0.050
# F1 = 0.116 vs. 0.102
# Precision = 0.062 vs. 0.053
# Recall = 0.926 vs. 1.000
# Minibatch Loss= 1.159214
# Training: 2500
# AUC = 0.214 vs. 0.067
# F1 = 0.374 vs. 0.138
# Precision = 0.282 vs. 0.075
# Recall = 0.555 vs. 0.938
# Validation: 2500
# AUC = 0.038 vs. 0.056
# F1 = 0.114 vs. 0.110
# Precision = 0.061 vs. 0.058
# Recall = 0.926 vs. 0.926
# Minibatch Loss= 1.147928
# Training: 2600
# AUC = 0.217 vs. 0.072
# F1 = 0.379 vs. 0.143
# Precision = 0.281 vs. 0.084
# Recall = 0.582 vs. 0.500
# Validation: 2600
# AUC = 0.037 vs. 0.066
# F1 = 0.114 vs. 0.142
# Precision = 0.060 vs. 0.083
# Recall = 1.000 vs. 0.481
# Minibatch Loss= 1.135840
# Training: 2700
# AUC = 0.221 vs. 0.083
# F1 = 0.390 vs. 0.135
# Precision = 0.286 vs. 0.072
# Recall = 0.616 vs. 0.973
# Validation: 2700
# AUC = 0.037 vs. 0.055
# F1 = 0.114 vs. 0.122
# Precision = 0.060 vs. 0.067
# Recall = 1.000 vs. 0.741
# Minibatch Loss= 1.122992
# Training: 2800
# AUC = 0.224 vs. 0.077
# F1 = 0.399 vs. 0.136
# Precision = 0.295 vs. 0.074
# Recall = 0.616 vs. 0.870
# Validation: 2800
# AUC = 0.037 vs. 0.061
# F1 = 0.114 vs. 0.133
# Precision = 0.060 vs. 0.095
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 1.109350
# Training: 2900
# AUC = 0.228 vs. 0.078
# F1 = 0.411 vs. 0.143
# Precision = 0.301 vs. 0.078
# Recall = 0.651 vs. 0.829
# Validation: 2900
# AUC = 0.036 vs. 0.054
# F1 = 0.114 vs. 0.110
# Precision = 0.060 vs. 0.078
# Recall = 1.000 vs. 0.185
# Minibatch Loss= 1.095147
# Training: 3000
# AUC = 0.230 vs. 0.069
# F1 = 0.424 vs. 0.134
# Precision = 0.310 vs. 0.072
# Recall = 0.671 vs. 0.993
# Validation: 3000
# AUC = 0.036 vs. 0.059
# F1 = 0.114 vs. 0.120
# Precision = 0.060 vs. 0.071
# Recall = 1.000 vs. 0.407
# Minibatch Loss= 1.080283
# Training: 3100
# AUC = 0.232 vs. 0.080
# F1 = 0.431 vs. 0.144
# Precision = 0.314 vs. 0.081
# Recall = 0.685 vs. 0.651
# Validation: 3100
# AUC = 0.036 vs. 0.048
# F1 = 0.114 vs. 0.102
# Precision = 0.060 vs. 0.054
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 1.064769
# Training: 3200
# AUC = 0.235 vs. 0.057
# F1 = 0.435 vs. 0.133
# Precision = 0.316 vs. 0.071
# Recall = 0.699 vs. 1.000
# Validation: 3200
# AUC = 0.036 vs. 0.076
# F1 = 0.114 vs. 0.161
# Precision = 0.060 vs. 0.143
# Recall = 1.000 vs. 0.185
# Minibatch Loss= 1.048594
# Training: 3300
# AUC = 0.239 vs. 0.067
# F1 = 0.436 vs. 0.133
# Precision = 0.317 vs. 0.071
# Recall = 0.699 vs. 1.000
# Validation: 3300
# AUC = 0.036 vs. 0.068
# F1 = 0.114 vs. 0.138
# Precision = 0.060 vs. 0.100
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 1.032055
# Training: 3400
# AUC = 0.241 vs. 0.069
# F1 = 0.436 vs. 0.136
# Precision = 0.317 vs. 0.073
# Recall = 0.699 vs. 0.993
# Validation: 3400
# AUC = 0.035 vs. 0.067
# F1 = 0.114 vs. 0.154
# Precision = 0.060 vs. 0.118
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 1.015357
# Training: 3500
# AUC = 0.237 vs. 0.069
# F1 = 0.438 vs. 0.134
# Precision = 0.318 vs. 0.072
# Recall = 0.705 vs. 0.979
# Validation: 3500
# AUC = 0.035 vs. 0.067
# F1 = 0.114 vs. 0.137
# Precision = 0.060 vs. 0.078
# Recall = 1.000 vs. 0.556
# Minibatch Loss= 0.998829
# Training: 3600
# AUC = 0.240 vs. 0.072
# F1 = 0.444 vs. 0.133
# Precision = 0.306 vs. 0.073
# Recall = 0.808 vs. 0.753
# Validation: 3600
# AUC = 0.035 vs. 0.064
# F1 = 0.114 vs. 0.127
# Precision = 0.060 vs. 0.071
# Recall = 1.000 vs. 0.630
# Minibatch Loss= 0.982601
# Training: 3700
# AUC = 0.250 vs. 0.092
# F1 = 0.443 vs. 0.144
# Precision = 0.306 vs. 0.094
# Recall = 0.801 vs. 0.308
# Validation: 3700
# AUC = 0.035 vs. 0.058
# F1 = 0.114 vs. 0.114
# Precision = 0.060 vs. 0.071
# Recall = 1.000 vs. 0.296
# Minibatch Loss= 0.966860
# Training: 3800
# AUC = 0.260 vs. 0.075
# F1 = 0.442 vs. 0.136
# Precision = 0.302 vs. 0.073
# Recall = 0.822 vs. 0.904
# Validation: 3800
# AUC = 0.035 vs. 0.049
# F1 = 0.114 vs. 0.107
# Precision = 0.060 vs. 0.057
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.951780
# Training: 3900
# AUC = 0.277 vs. 0.075
# F1 = 0.445 vs. 0.137
# Precision = 0.322 vs. 0.077
# Recall = 0.719 vs. 0.630
# Validation: 3900
# AUC = 0.035 vs. 0.054
# F1 = 0.114 vs. 0.104
# Precision = 0.060 vs. 0.055
# Recall = 1.000 vs. 0.963
# Minibatch Loss= 0.937204
# Training: 4000
# AUC = 0.303 vs. 0.083
# F1 = 0.447 vs. 0.156
# Precision = 0.321 vs. 0.094
# Recall = 0.733 vs. 0.459
# Validation: 4000
# AUC = 0.035 vs. 0.083
# F1 = 0.114 vs. 0.109
# Precision = 0.060 vs. 0.058
# Recall = 1.000 vs. 0.778
# Minibatch Loss= 0.922921
# Training: 4100
# AUC = 0.315 vs. 0.083
# F1 = 0.448 vs. 0.144
# Precision = 0.310 vs. 0.089
# Recall = 0.808 vs. 0.384
# Validation: 4100
# AUC = 0.035 vs. 0.068
# F1 = 0.114 vs. 0.156
# Precision = 0.060 vs. 0.120
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 0.909687
# Training: 4200
# AUC = 0.328 vs. 0.073
# F1 = 0.449 vs. 0.138
# Precision = 0.312 vs. 0.075
# Recall = 0.801 vs. 0.856
# Validation: 4200
# AUC = 0.035 vs. 0.057
# F1 = 0.114 vs. 0.112
# Precision = 0.060 vs. 0.060
# Recall = 1.000 vs. 0.778
# Minibatch Loss= 0.897165
# Training: 4300
# AUC = 0.344 vs. 0.079
# F1 = 0.451 vs. 0.148
# Precision = 0.312 vs. 0.083
# Recall = 0.815 vs. 0.664
# Validation: 4300
# AUC = 0.035 vs. 0.053
# F1 = 0.114 vs. 0.112
# Precision = 0.060 vs. 0.061
# Recall = 1.000 vs. 0.630
# Minibatch Loss= 0.885105
# Training: 4400
# AUC = 0.360 vs. 0.082
# F1 = 0.452 vs. 0.135
# Precision = 0.309 vs. 0.073
# Recall = 0.842 vs. 0.966
# Validation: 4400
# AUC = 0.035 vs. 0.099
# F1 = 0.114 vs. 0.188
# Precision = 0.060 vs. 0.162
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 0.873448
# Training: 4500
# AUC = 0.371 vs. 0.083
# F1 = 0.455 vs. 0.150
# Precision = 0.313 vs. 0.096
# Recall = 0.836 vs. 0.336
# Validation: 4500
# AUC = 0.035 vs. 0.067
# F1 = 0.114 vs. 0.149
# Precision = 0.060 vs. 0.090
# Recall = 1.000 vs. 0.444
# Minibatch Loss= 0.862295
# Training: 4600
# AUC = 0.383 vs. 0.068
# F1 = 0.460 vs. 0.138
# Precision = 0.315 vs. 0.075
# Recall = 0.856 vs. 0.795
# Validation: 4600
# AUC = 0.035 vs. 0.056
# F1 = 0.114 vs. 0.122
# Precision = 0.060 vs. 0.065
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.851460
# Training: 4700
# AUC = 0.395 vs. 0.063
# F1 = 0.459 vs. 0.134
# Precision = 0.315 vs. 0.072
# Recall = 0.842 vs. 1.000
# Validation: 4700
# AUC = 0.035 vs. 0.056
# F1 = 0.114 vs. 0.133
# Precision = 0.060 vs. 0.086
# Recall = 1.000 vs. 0.296
# Minibatch Loss= 0.840629
# Training: 4800
# AUC = 0.406 vs. 0.078
# F1 = 0.461 vs. 0.146
# Precision = 0.316 vs. 0.113
# Recall = 0.849 vs. 0.205
# Validation: 4800
# AUC = 0.035 vs. 0.094
# F1 = 0.114 vs. 0.171
# Precision = 0.060 vs. 0.375
# Recall = 1.000 vs. 0.111
# Minibatch Loss= 0.829744
# Training: 4900
# AUC = 0.415 vs. 0.074
# F1 = 0.463 vs. 0.135
# Precision = 0.314 vs. 0.073
# Recall = 0.877 vs. 0.938
# Validation: 4900
# AUC = 0.035 vs. 0.043
# F1 = 0.114 vs. 0.103
# Precision = 0.060 vs. 0.055
# Recall = 1.000 vs. 0.704
# Minibatch Loss= 0.815563
# Training: 5000
# AUC = 0.426 vs. 0.074
# F1 = 0.468 vs. 0.134
# Precision = 0.372 vs. 0.072
# Recall = 0.630 vs. 0.993
# Validation: 5000
# AUC = 0.035 vs. 0.066
# F1 = 0.114 vs. 0.139
# Precision = 0.060 vs. 0.076
# Recall = 1.000 vs. 0.815
# Minibatch Loss= 0.802510
# Training: 5100
# AUC = 0.437 vs. 0.063
# F1 = 0.470 vs. 0.136
# Precision = 0.348 vs. 0.073
# Recall = 0.726 vs. 0.966
# Validation: 5100
# AUC = 0.035 vs. 0.093
# F1 = 0.114 vs. 0.140
# Precision = 0.060 vs. 0.133
# Recall = 1.000 vs. 0.148
# Minibatch Loss= 0.790684
# Training: 5200
# AUC = 0.448 vs. 0.068
# F1 = 0.476 vs. 0.134
# Precision = 0.393 vs. 0.073
# Recall = 0.603 vs. 0.904
# Validation: 5200
# AUC = 0.035 vs. 0.057
# F1 = 0.114 vs. 0.114
# Precision = 0.060 vs. 0.063
# Recall = 1.000 vs. 0.556
# Minibatch Loss= 0.779305
# Training: 5300
# AUC = 0.464 vs. 0.065
# F1 = 0.486 vs. 0.133
# Precision = 0.405 vs. 0.071
# Recall = 0.610 vs. 1.000
# Validation: 5300
# AUC = 0.035 vs. 0.061
# F1 = 0.114 vs. 0.127
# Precision = 0.060 vs. 0.073
# Recall = 1.000 vs. 0.481
# Minibatch Loss= 0.768048
# Training: 5400
# AUC = 0.472 vs. 0.065
# F1 = 0.501 vs. 0.134
# Precision = 0.416 vs. 0.072
# Recall = 0.630 vs. 1.000
# Validation: 5400
# AUC = 0.035 vs. 0.052
# F1 = 0.114 vs. 0.120
# Precision = 0.060 vs. 0.067
# Recall = 1.000 vs. 0.556
# Minibatch Loss= 0.756950
# Training: 5500
# AUC = 0.479 vs. 0.064
# F1 = 0.506 vs. 0.134
# Precision = 0.436 vs. 0.072
# Recall = 0.603 vs. 0.973
# Validation: 5500
# AUC = 0.035 vs. 0.061
# F1 = 0.114 vs. 0.106
# Precision = 0.060 vs. 0.057
# Recall = 1.000 vs. 0.704
# Minibatch Loss= 0.745906
# Training: 5600
# AUC = 0.487 vs. 0.074
# F1 = 0.513 vs. 0.134
# Precision = 0.439 vs. 0.072
# Recall = 0.616 vs. 1.000
# Validation: 5600
# AUC = 0.035 vs. 0.084
# F1 = 0.114 vs. 0.200
# Precision = 0.060 vs. 0.217
# Recall = 1.000 vs. 0.185
# Minibatch Loss= 0.734957
# Training: 5700
# AUC = 0.496 vs. 0.071
# F1 = 0.514 vs. 0.135
# Precision = 0.441 vs. 0.080
# Recall = 0.616 vs. 0.452
# Validation: 5700
# AUC = 0.035 vs. 0.062
# F1 = 0.114 vs. 0.132
# Precision = 0.060 vs. 0.085
# Recall = 1.000 vs. 0.296
# Minibatch Loss= 0.724129
# Training: 5800
# AUC = 0.503 vs. 0.069
# F1 = 0.519 vs. 0.136
# Precision = 0.456 vs. 0.073
# Recall = 0.603 vs. 0.986
# Validation: 5800
# AUC = 0.035 vs. 0.049
# F1 = 0.114 vs. 0.104
# Precision = 0.060 vs. 0.055
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.713263
# Training: 5900
# AUC = 0.511 vs. 0.088
# F1 = 0.524 vs. 0.139
# Precision = 0.430 vs. 0.077
# Recall = 0.671 vs. 0.740
# Validation: 5900
# AUC = 0.035 vs. 0.045
# F1 = 0.114 vs. 0.102
# Precision = 0.060 vs. 0.054
# Recall = 1.000 vs. 0.926
# Minibatch Loss= 0.702528
# Training: 6000
# AUC = 0.519 vs. 0.091
# F1 = 0.532 vs. 0.138
# Precision = 0.438 vs. 0.075
# Recall = 0.678 vs. 0.925
# Validation: 6000
# AUC = 0.035 vs. 0.079
# F1 = 0.114 vs. 0.132
# Precision = 0.060 vs. 0.079
# Recall = 1.000 vs. 0.407
# Minibatch Loss= 0.692176
# Training: 6100
# AUC = 0.524 vs. 0.075
# F1 = 0.542 vs. 0.146
# Precision = 0.445 vs. 0.087
# Recall = 0.692 vs. 0.445
# Validation: 6100
# AUC = 0.035 vs. 0.061
# F1 = 0.114 vs. 0.117
# Precision = 0.060 vs. 0.063
# Recall = 1.000 vs. 0.741
# Minibatch Loss= 0.681929
# Training: 6200
# AUC = 0.527 vs. 0.077
# F1 = 0.548 vs. 0.138
# Precision = 0.451 vs. 0.074
# Recall = 0.699 vs. 0.973
# Validation: 6200
# AUC = 0.035 vs. 0.068
# F1 = 0.114 vs. 0.111
# Precision = 0.060 vs. 0.079
# Recall = 1.000 vs. 0.185
# Minibatch Loss= 0.671851
# Training: 6300
# AUC = 0.537 vs. 0.076
# F1 = 0.556 vs. 0.136
# Precision = 0.465 vs. 0.074
# Recall = 0.692 vs. 0.890
# Validation: 6300
# AUC = 0.035 vs. 0.112
# F1 = 0.114 vs. 0.191
# Precision = 0.060 vs. 0.134
# Recall = 1.000 vs. 0.333
# Minibatch Loss= 0.661702
# Training: 6400
# AUC = 0.547 vs. 0.074
# F1 = 0.567 vs. 0.137
# Precision = 0.475 vs. 0.077
# Recall = 0.705 vs. 0.623
# Validation: 6400
# AUC = 0.035 vs. 0.073
# F1 = 0.114 vs. 0.130
# Precision = 0.060 vs. 0.092
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 0.651081
# Training: 6500
# AUC = 0.556 vs. 0.063
# F1 = 0.573 vs. 0.136
# Precision = 0.479 vs. 0.073
# Recall = 0.712 vs. 0.938
# Validation: 6500
# AUC = 0.035 vs. 0.052
# F1 = 0.114 vs. 0.106
# Precision = 0.060 vs. 0.067
# Recall = 1.000 vs. 0.259
# Minibatch Loss= 0.639781
# Training: 6600
# AUC = 0.567 vs. 0.066
# F1 = 0.604 vs. 0.138
# Precision = 0.544 vs. 0.076
# Recall = 0.678 vs. 0.774
# Validation: 6600
# AUC = 0.035 vs. 0.053
# F1 = 0.114 vs. 0.124
# Precision = 0.060 vs. 0.078
# Recall = 1.000 vs. 0.296
# Minibatch Loss= 0.628488
# Training: 6700
# AUC = 0.576 vs. 0.077
# F1 = 0.625 vs. 0.134
# Precision = 0.549 vs. 0.072
# Recall = 0.726 vs. 0.993
# Validation: 6700
# AUC = 0.035 vs. 0.105
# F1 = 0.114 vs. 0.143
# Precision = 0.060 vs. 0.082
# Recall = 1.000 vs. 0.556
# Minibatch Loss= 0.617486
# Training: 6800
# AUC = 0.584 vs. 0.084
# F1 = 0.633 vs. 0.139
# Precision = 0.557 vs. 0.075
# Recall = 0.733 vs. 0.986
# Validation: 6800
# AUC = 0.035 vs. 0.101
# F1 = 0.114 vs. 0.169
# Precision = 0.060 vs. 0.156
# Recall = 1.000 vs. 0.185
# Minibatch Loss= 0.606628
# Training: 6900
# AUC = 0.591 vs. 0.086
# F1 = 0.637 vs. 0.150
# Precision = 0.556 vs. 0.084
# Recall = 0.747 vs. 0.733
# Validation: 6900
# AUC = 0.035 vs. 0.063
# F1 = 0.114 vs. 0.124
# Precision = 0.060 vs. 0.086
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 0.595809
# Training: 7000
# AUC = 0.601 vs. 0.078
# F1 = 0.641 vs. 0.144
# Precision = 0.562 vs. 0.079
# Recall = 0.747 vs. 0.747
# Validation: 7000
# AUC = 0.035 vs. 0.071
# F1 = 0.114 vs. 0.127
# Precision = 0.060 vs. 0.096
# Recall = 1.000 vs. 0.185
# Minibatch Loss= 0.584835
# Training: 7100
# AUC = 0.611 vs. 0.085
# F1 = 0.649 vs. 0.140
# Precision = 0.566 vs. 0.089
# Recall = 0.760 vs. 0.322
# Validation: 7100
# AUC = 0.035 vs. 0.044
# F1 = 0.114 vs. 0.101
# Precision = 0.060 vs. 0.053
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.573795
# Training: 7200
# AUC = 0.618 vs. 0.069
# F1 = 0.667 vs. 0.135
# Precision = 0.543 vs. 0.072
# Recall = 0.863 vs. 0.979
# Validation: 7200
# AUC = 0.035 vs. 0.045
# F1 = 0.114 vs. 0.101
# Precision = 0.060 vs. 0.053
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.563033
# Training: 7300
# AUC = 0.627 vs. 0.069
# F1 = 0.679 vs. 0.134
# Precision = 0.560 vs. 0.072
# Recall = 0.863 vs. 0.973
# Validation: 7300
# AUC = 0.036 vs. 0.062
# F1 = 0.114 vs. 0.137
# Precision = 0.060 vs. 0.082
# Recall = 1.000 vs. 0.407
# Minibatch Loss= 0.552599
# Training: 7400
# AUC = 0.638 vs. 0.072
# F1 = 0.687 vs. 0.137
# Precision = 0.577 vs. 0.074
# Recall = 0.849 vs. 0.938
# Validation: 7400
# AUC = 0.036 vs. 0.055
# F1 = 0.114 vs. 0.109
# Precision = 0.060 vs. 0.058
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.542248
# Training: 7500
# AUC = 0.652 vs. 0.062
# F1 = 0.693 vs. 0.134
# Precision = 0.596 vs. 0.072
# Recall = 0.829 vs. 0.993
# Validation: 7500
# AUC = 0.036 vs. 0.053
# F1 = 0.114 vs. 0.109
# Precision = 0.060 vs. 0.060
# Recall = 1.000 vs. 0.556
# Minibatch Loss= 0.531516
# Training: 7600
# AUC = 0.678 vs. 0.073
# F1 = 0.708 vs. 0.141
# Precision = 0.600 vs. 0.088
# Recall = 0.863 vs. 0.356
# Validation: 7600
# AUC = 0.036 vs. 0.100
# F1 = 0.114 vs. 0.188
# Precision = 0.060 vs. 0.138
# Recall = 1.000 vs. 0.296
# Minibatch Loss= 0.518807
# Training: 7700
# AUC = 0.697 vs. 0.069
# F1 = 0.737 vs. 0.135
# Precision = 0.648 vs. 0.074
# Recall = 0.856 vs. 0.849
# Validation: 7700
# AUC = 0.036 vs. 0.090
# F1 = 0.114 vs. 0.164
# Precision = 0.060 vs. 0.108
# Recall = 1.000 vs. 0.333
# Minibatch Loss= 0.507686
# Training: 7800
# AUC = 0.705 vs. 0.067
# F1 = 0.749 vs. 0.133
# Precision = 0.632 vs. 0.071
# Recall = 0.918 vs. 1.000
# Validation: 7800
# AUC = 0.036 vs. 0.050
# F1 = 0.114 vs. 0.103
# Precision = 0.060 vs. 0.055
# Recall = 1.000 vs. 0.889
# Minibatch Loss= 0.497834
# Training: 7900
# AUC = 0.710 vs. 0.074
# F1 = 0.760 vs. 0.134
# Precision = 0.652 vs. 0.072
# Recall = 0.911 vs. 1.000
# Validation: 7900
# AUC = 0.036 vs. 0.087
# F1 = 0.114 vs. 0.179
# Precision = 0.060 vs. 0.172
# Recall = 1.000 vs. 0.185
# Minibatch Loss= 0.488497
# Training: 8000
# AUC = 0.716 vs. 0.073
# F1 = 0.765 vs. 0.137
# Precision = 0.663 vs. 0.076
# Recall = 0.904 vs. 0.733
# Validation: 8000
# AUC = 0.036 vs. 0.132
# F1 = 0.114 vs. 0.140
# Precision = 0.060 vs. 0.188
# Recall = 1.000 vs. 0.111
# Minibatch Loss= 0.478969
# Training: 8100
# AUC = 0.724 vs. 0.080
# F1 = 0.768 vs. 0.137
# Precision = 0.679 vs. 0.074
# Recall = 0.884 vs. 0.966
# Validation: 8100
# AUC = 0.036 vs. 0.047
# F1 = 0.114 vs. 0.101
# Precision = 0.060 vs. 0.053
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.470624
# Training: 8200
# AUC = 0.732 vs. 0.086
# F1 = 0.776 vs. 0.153
# Precision = 0.747 vs. 0.090
# Recall = 0.808 vs. 0.507
# Validation: 8200
# AUC = 0.036 vs. 0.085
# F1 = 0.114 vs. 0.170
# Precision = 0.060 vs. 0.200
# Recall = 1.000 vs. 0.148
# Minibatch Loss= 0.462794
# Training: 8300
# AUC = 0.738 vs. 0.073
# F1 = 0.792 vs. 0.138
# Precision = 0.753 vs. 0.077
# Recall = 0.836 vs. 0.644
# Validation: 8300
# AUC = 0.036 vs. 0.059
# F1 = 0.114 vs. 0.119
# Precision = 0.060 vs. 0.065
# Recall = 1.000 vs. 0.704
# Minibatch Loss= 0.455395
# Training: 8400
# AUC = 0.743 vs. 0.086
# F1 = 0.792 vs. 0.144
# Precision = 0.753 vs. 0.105
# Recall = 0.836 vs. 0.226
# Validation: 8400
# AUC = 0.036 vs. 0.043
# F1 = 0.114 vs. 0.105
# Precision = 0.060 vs. 0.056
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.448397
# Training: 8500
# AUC = 0.746 vs. 0.067
# F1 = 0.795 vs. 0.135
# Precision = 0.758 vs. 0.072
# Recall = 0.836 vs. 1.000
# Validation: 8500
# AUC = 0.037 vs. 0.085
# F1 = 0.114 vs. 0.174
# Precision = 0.060 vs. 0.211
# Recall = 1.000 vs. 0.148
# Minibatch Loss= 0.441717
# Training: 8600
# AUC = 0.750 vs. 0.083
# F1 = 0.799 vs. 0.141
# Precision = 0.738 vs. 0.076
# Recall = 0.870 vs. 0.925
# Validation: 8600
# AUC = 0.037 vs. 0.061
# F1 = 0.114 vs. 0.128
# Precision = 0.060 vs. 0.150
# Recall = 1.000 vs. 0.111
# Minibatch Loss= 0.435007
# Training: 8700
# AUC = 0.757 vs. 0.062
# F1 = 0.802 vs. 0.134
# Precision = 0.730 vs. 0.072
# Recall = 0.890 vs. 0.973
# Validation: 8700
# AUC = 0.037 vs. 0.090
# F1 = 0.114 vs. 0.171
# Precision = 0.060 vs. 0.140
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 0.428699
# Training: 8800
# AUC = 0.764 vs. 0.065
# F1 = 0.809 vs. 0.135
# Precision = 0.736 vs. 0.073
# Recall = 0.897 vs. 0.856
# Validation: 8800
# AUC = 0.037 vs. 0.046
# F1 = 0.114 vs. 0.101
# Precision = 0.060 vs. 0.053
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.422627
# Training: 8900
# AUC = 0.770 vs. 0.073
# F1 = 0.813 vs. 0.139
# Precision = 0.735 vs. 0.077
# Recall = 0.911 vs. 0.719
# Validation: 8900
# AUC = 0.037 vs. 0.059
# F1 = 0.114 vs. 0.120
# Precision = 0.060 vs. 0.065
# Recall = 1.000 vs. 0.852
# Minibatch Loss= 0.416887
# Training: 9000
# AUC = 0.776 vs. 0.077
# F1 = 0.818 vs. 0.139
# Precision = 0.743 vs. 0.077
# Recall = 0.911 vs. 0.747
# Validation: 9000
# AUC = 0.037 vs. 0.053
# F1 = 0.114 vs. 0.114
# Precision = 0.060 vs. 0.061
# Recall = 1.000 vs. 0.815
# Minibatch Loss= 0.411385
# Training: 9100
# AUC = 0.782 vs. 0.076
# F1 = 0.816 vs. 0.135
# Precision = 0.739 vs. 0.074
# Recall = 0.911 vs. 0.822
# Validation: 9100
# AUC = 0.037 vs. 0.045
# F1 = 0.114 vs. 0.101
# Precision = 0.060 vs. 0.053
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.406042
# Training: 9200
# AUC = 0.788 vs. 0.075
# F1 = 0.820 vs. 0.137
# Precision = 0.740 vs. 0.075
# Recall = 0.918 vs. 0.836
# Validation: 9200
# AUC = 0.037 vs. 0.054
# F1 = 0.114 vs. 0.123
# Precision = 0.060 vs. 0.066
# Recall = 1.000 vs. 0.815
# Minibatch Loss= 0.400685
# Training: 9300
# AUC = 0.793 vs. 0.063
# F1 = 0.820 vs. 0.133
# Precision = 0.740 vs. 0.071
# Recall = 0.918 vs. 1.000
# Validation: 9300
# AUC = 0.037 vs. 0.060
# F1 = 0.114 vs. 0.111
# Precision = 0.060 vs. 0.111
# Recall = 1.000 vs. 0.111
# Minibatch Loss= 0.395660
# Training: 9400
# AUC = 0.799 vs. 0.072
# F1 = 0.821 vs. 0.134
# Precision = 0.738 vs. 0.072
# Recall = 0.925 vs. 1.000
# Validation: 9400
# AUC = 0.037 vs. 0.068
# F1 = 0.114 vs. 0.128
# Precision = 0.060 vs. 0.090
# Recall = 1.000 vs. 0.222
# Minibatch Loss= 0.390931
# Training: 9500
# AUC = 0.806 vs. 0.077
# F1 = 0.825 vs. 0.136
# Precision = 0.737 vs. 0.073
# Recall = 0.938 vs. 0.925
# Validation: 9500
# AUC = 0.037 vs. 0.058
# F1 = 0.114 vs. 0.109
# Precision = 0.060 vs. 0.059
# Recall = 1.000 vs. 0.704
# Minibatch Loss= 0.386452
# Training: 9600
# AUC = 0.812 vs. 0.060
# F1 = 0.825 vs. 0.133
# Precision = 0.737 vs. 0.071
# Recall = 0.938 vs. 0.993
# Validation: 9600
# AUC = 0.037 vs. 0.052
# F1 = 0.114 vs. 0.107
# Precision = 0.060 vs. 0.057
# Recall = 1.000 vs. 1.000
# Minibatch Loss= 0.381924
# Training: 9700
# AUC = 0.819 vs. 0.074
# F1 = 0.825 vs. 0.136
# Precision = 0.737 vs. 0.073
# Recall = 0.938 vs. 0.973
# Validation: 9700
# AUC = 0.037 vs. 0.047
# F1 = 0.114 vs. 0.104
# Precision = 0.060 vs. 0.055
# Recall = 1.000 vs. 0.963
# Minibatch Loss= 0.377310
# Training: 9800
# AUC = 0.824 vs. 0.067
# F1 = 0.829 vs. 0.135
# Precision = 0.738 vs. 0.072
# Recall = 0.945 vs. 0.993
# Validation: 9800
# AUC = 0.037 vs. 0.129
# F1 = 0.114 vs. 0.138
# Precision = 0.060 vs. 1.000
# Recall = 1.000 vs. 0.074
# Minibatch Loss= 0.372966
# Training: 9900
# AUC = 0.829 vs. 0.086
# F1 = 0.831 vs. 0.159
# Precision = 0.742 vs. 0.092
# Recall = 0.945 vs. 0.610
# Validation: 9900
# AUC = 0.037 vs. 0.050
# F1 = 0.114 vs. 0.117
# Precision = 0.060 vs. 0.062
# Recall = 1.000 vs. 0.926
# Minibatch Loss= 0.369708
#  Optimization Finished!

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 1000, 
                validation_eval_step = 1000,
                display_step = 1000)
# Out:
# Training: 10000
# AUC = 0.833 vs. 0.071
# F1 = 0.840 vs. 0.133
# Precision = 0.852 vs. 0.072
# Recall = 0.829 vs. 0.993
# Validation: 10000
# AUC = 0.037 vs. 0.052
# F1 = 0.114 vs. 0.107
# Precision = 0.060 vs. 0.060
# Recall = 1.000 vs. 0.519
# Minibatch Loss= 0.371944
# Training: 11000
# AUC = 0.898 vs. 0.072
# F1 = 0.871 vs. 0.139
# Precision = 0.887 vs. 0.078
# Recall = 0.856 vs. 0.678
# Validation: 11000
# AUC = 0.037 vs. 0.105
# F1 = 0.114 vs. 0.133
# Precision = 0.060 vs. 0.076
# Recall = 1.000 vs. 0.519
# Minibatch Loss= 0.360987
# Training: 12000
# AUC = 0.923 vs. 0.073
# F1 = 0.891 vs. 0.135
# Precision = 0.885 vs. 0.073
# Recall = 0.897 vs. 0.973
# Validation: 12000
# AUC = 0.037 vs. 0.063
# F1 = 0.114 vs. 0.133
# Precision = 0.060 vs. 0.078
# Recall = 1.000 vs. 0.444
# Minibatch Loss= 0.343658
# Training: 13000
# AUC = 0.948 vs. 0.075
# F1 = 0.900 vs. 0.139
# Precision = 0.903 vs. 0.075
# Recall = 0.897 vs. 0.904
# Validation: 13000
# AUC = 0.037 vs. 0.057
# F1 = 0.114 vs. 0.120
# Precision = 0.060 vs. 0.070
# Recall = 1.000 vs. 0.407
# Minibatch Loss= 0.321096
# Training: 14000
# AUC = 0.961 vs. 0.074
# F1 = 0.912 vs. 0.137
# Precision = 0.905 vs. 0.074
# Recall = 0.918 vs. 0.925
# Validation: 14000
# AUC = 0.038 vs. 0.068
# F1 = 0.114 vs. 0.155
# Precision = 0.060 vs. 0.086
# Recall = 1.000 vs. 0.815
# Minibatch Loss= 0.301558
# Training: 15000
# AUC = 0.971 vs. 0.074
# F1 = 0.924 vs. 0.135
# Precision = 0.892 vs. 0.073
# Recall = 0.959 vs. 0.918
# Validation: 15000
# AUC = 0.038 vs. 0.057
# F1 = 0.114 vs. 0.122
# Precision = 0.060 vs. 0.073
# Recall = 1.000 vs. 0.370
# Minibatch Loss= 0.273561
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8356d399ae2c> in <module>()
#       2                 train_eval_step = 1000,
#       3                 validation_eval_step = 1000,
# ----> 4                 display_step = 1000)
#
# /data2/data/zebrahim/git/bitbucket/cpd_deep/src/training.pyc in train(self, max_iter, train_eval_step, validation_eval_step, display_step, checkpoint_step)
#     125             _, summary_str, loss, debug_info = self.sess.run((self.model.optimizer, self.summary, self.model.cost, self.model.debug_info),
#     126                                            feed_dict={self.model.x: batch_x,
# --> 127                                                       self.model.y: batch_y})
#     128
#     129             #print debug_info
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1087             feed_handles[subfeed_t] = subfeed_val
#    1088           else:
# -> 1089             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1090
#    1091           if (not is_tensor_handle_feed and
#
# /data2/data/zebrahim/anaconda2/envs/tensorflow/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# KeyboardInterrupt:

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.314 vs. 0.279
# F1 = 0.439 vs. 0.439
# Precision = 0.282 vs. 0.281
# Recall = 0.994 vs. 1.000

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (1000, 256)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
