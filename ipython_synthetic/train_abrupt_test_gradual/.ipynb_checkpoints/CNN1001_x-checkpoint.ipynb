# %%
# useing this variable for saving models and summaries
exp_name = "CNN1001_x"

# %% [markdown]
# ## Importing Libraries

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import numpy as np
from hdf5storage import savemat
import pickle 

import sys
sys.path.append('../../src')

# %%
import models.CNN_model as CNN_model
import training
import evaluation.nn_eval as nn_eval

# %% [markdown]
# ## Loading synthetic data

# %%
#loading data
data_path= '../../data/synthetic2/' + 'processed2.p'

with open(data_path, 'r') as fin:
    data = pickle.load(fin)
    
train_data = data['train_data']
validation_data = data['validation_data']
test_data = data['test_data']

train_gt = np.expand_dims(data['train_gt'], axis=-1)
validation_gt = np.expand_dims(data['validation_gt'], axis=-1)
test_gt = np.expand_dims(data['test_gt'], axis=-1)

index_of_changes = data['index_of_changes']

# %%
train_data.shape, validation_data.shape, test_data.shape, train_gt.shape, validation_gt.shape, test_gt.shape, index_of_changes.shape
# Out:
# ((900, 8192, 12),
#  (100, 8192, 12),
#  (1000, 8192, 12),
#  (900, 8192, 1),
#  (100, 8192, 1),
#  (1000, 8192, 1),
#  (1000, 4))

# %% [markdown]
# ## Model

# %%
# Model parameters
n_variables = 12
learning_rate = 0.001
batch_size = 10

convolution_levels = 5    #number of convolution to have in the network
pooling_stride = [2, 2, 2, 2, 2]
weights_shape = [[5, n_variables, 32],
                 [5, 32, 64],
                 [5, 64, 64],
                 [5, 64, 64],
                 [5, 64, 64]]
bias_shape = [32, 64, 64, 64, 64]
activation = tf.nn.relu
n_classes = 1

##positive weight for weighted cross entropy
s = train_data.shape
resolution = np.prod(pooling_stride)
gt_effective = np.reshape(train_gt, (s[0]*(s[1]/resolution), resolution))
pos_weight = (1.0 - gt_effective.max(axis=1).mean()) / gt_effective.max(axis=1).mean()

#variables_weights = np.ones((n_classes,))

# %%
print pos_weight
# Out:
# 12.0408324012

# %%
# Launch the graph
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
summary_path = '../../summary_synthetic/train_abrupt_test_gradual/' + exp_name 
checkpoint_path = '../../model_synthetic/train_abrupt_test_gradual/' + exp_name + '/' + exp_name

# %%
model = CNN_model.Model(n_variables = n_variables,
                        learning_rate = learning_rate,
                        n_classes = n_classes)

# %%
model.build_conv_net(pos_weight_values= pos_weight,
                     learning_rate = learning_rate,
                     convolution_levels = convolution_levels, 
                     pooling_stride = pooling_stride,
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                     n_classes = n_classes,
                     activation = activation,
                     trainable_conv = True,
                     trainable_last = True,)

# %%
trainer = training.Trainer(model = model,
                    data_train = train_data,
                    ground_truth_train = train_gt,
                    data_validation = validation_data,
                    ground_truth_validation = validation_gt,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0)

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 100, 
                validation_eval_step = 100,
                display_step = 100)
# Out:
# Training: 0
# AUC = 0.075 vs. 0.082
# F1 = 0.136 vs. 0.140
# Precision = 0.074 vs. 0.076
# Recall = 0.918 vs. 0.835
# Validation: 0
# AUC = 0.070 vs. 0.076
# F1 = 0.136 vs. 0.136
# Precision = 0.073 vs. 0.073
# Recall = 0.978 vs. 0.992
# Minibatch Loss= 1.257368
# Training: 100
# AUC = 0.763 vs. 0.060
# F1 = 0.765 vs. 0.117
# Precision = 0.818 vs. 0.062
# Recall = 0.718 vs. 0.936
# Validation: 100
# AUC = 0.724 vs. 0.076
# F1 = 0.740 vs. 0.135
# Precision = 0.806 vs. 0.073
# Recall = 0.684 vs. 0.994
# Minibatch Loss= 0.784244
# Training: 200
# AUC = 0.812 vs. 0.086
# F1 = 0.808 vs. 0.140
# Precision = 0.840 vs. 0.076
# Recall = 0.778 vs. 0.937
# Validation: 200
# AUC = 0.746 vs. 0.072
# F1 = 0.758 vs. 0.135
# Precision = 0.800 vs. 0.072
# Recall = 0.720 vs. 1.000
# Minibatch Loss= 0.709179
# Training: 300
# AUC = 0.764 vs. 0.069
# F1 = 0.766 vs. 0.134
# Precision = 0.824 vs. 0.072
# Recall = 0.716 vs. 1.000
# Validation: 300
# AUC = 0.757 vs. 0.075
# F1 = 0.754 vs. 0.135
# Precision = 0.767 vs. 0.075
# Recall = 0.742 vs. 0.688
# Minibatch Loss= 0.808008
# Training: 400
# AUC = 0.800 vs. 0.093
# F1 = 0.790 vs. 0.144
# Precision = 0.863 vs. 0.079
# Recall = 0.728 vs. 0.812
# Validation: 400
# AUC = 0.758 vs. 0.076
# F1 = 0.762 vs. 0.136
# Precision = 0.806 vs. 0.073
# Recall = 0.723 vs. 0.889
# Minibatch Loss= 0.760546
# Training: 500
# AUC = 0.766 vs. 0.072
# F1 = 0.803 vs. 0.142
# Precision = 0.825 vs. 0.077
# Recall = 0.782 vs. 0.917
# Validation: 500
# AUC = 0.796 vs. 0.073
# F1 = 0.780 vs. 0.136
# Precision = 0.811 vs. 0.073
# Recall = 0.751 vs. 0.957
# Minibatch Loss= 0.812880
# Training: 600
# AUC = 0.872 vs. 0.090
# F1 = 0.866 vs. 0.160
# Precision = 0.845 vs. 0.087
# Recall = 0.887 vs. 0.995
# Validation: 600
# AUC = 0.805 vs. 0.071
# F1 = 0.783 vs. 0.135
# Precision = 0.792 vs. 0.073
# Recall = 0.774 vs. 0.995
# Minibatch Loss= 0.683892
# Training: 700
# AUC = 0.767 vs. 0.067
# F1 = 0.761 vs. 0.131
# Precision = 0.783 vs. 0.071
# Recall = 0.741 vs. 0.859
# Validation: 700
# AUC = 0.803 vs. 0.075
# F1 = 0.782 vs. 0.136
# Precision = 0.791 vs. 0.073
# Recall = 0.774 vs. 0.967
# Minibatch Loss= 0.736390
# Training: 800
# AUC = 0.871 vs. 0.087
# F1 = 0.837 vs. 0.158
# Precision = 0.886 vs. 0.095
# Recall = 0.792 vs. 0.483
# Validation: 800
# AUC = 0.818 vs. 0.075
# F1 = 0.794 vs. 0.135
# Precision = 0.782 vs. 0.073
# Recall = 0.807 vs. 0.964
# Minibatch Loss= 0.604658
# Training: 900
# AUC = 0.903 vs. 0.077
# F1 = 0.851 vs. 0.132
# Precision = 0.812 vs. 0.074
# Recall = 0.894 vs. 0.615
# Validation: 900
# AUC = 0.824 vs. 0.076
# F1 = 0.795 vs. 0.136
# Precision = 0.807 vs. 0.073
# Recall = 0.783 vs. 0.907
# Minibatch Loss= 0.501915
# Training: 1000
# AUC = 0.839 vs. 0.070
# F1 = 0.841 vs. 0.128
# Precision = 0.819 vs. 0.070
# Recall = 0.863 vs. 0.720
# Validation: 1000
# AUC = 0.798 vs. 0.072
# F1 = 0.788 vs. 0.135
# Precision = 0.800 vs. 0.073
# Recall = 0.776 vs. 0.997
# Minibatch Loss= 0.557120
# Training: 1100
# AUC = 0.874 vs. 0.064
# F1 = 0.809 vs. 0.138
# Precision = 0.850 vs. 0.075
# Recall = 0.772 vs. 0.918
# Validation: 1100
# AUC = 0.831 vs. 0.072
# F1 = 0.792 vs. 0.137
# Precision = 0.795 vs. 0.074
# Recall = 0.790 vs. 0.935
# Minibatch Loss= 0.545937
# Training: 1200
# AUC = 0.876 vs. 0.076
# F1 = 0.829 vs. 0.139
# Precision = 0.810 vs. 0.075
# Recall = 0.848 vs. 1.000
# Validation: 1200
# AUC = 0.827 vs. 0.072
# F1 = 0.803 vs. 0.135
# Precision = 0.825 vs. 0.073
# Recall = 0.782 vs. 0.997
# Minibatch Loss= 0.524313
# Training: 1300
# AUC = 0.847 vs. 0.073
# F1 = 0.799 vs. 0.128
# Precision = 0.768 vs. 0.071
# Recall = 0.832 vs. 0.689
# Validation: 1300
# AUC = 0.847 vs. 0.075
# F1 = 0.809 vs. 0.136
# Precision = 0.825 vs. 0.073
# Recall = 0.795 vs. 0.948
# Minibatch Loss= 0.583055
# Training: 1400
# AUC = 0.908 vs. 0.076
# F1 = 0.862 vs. 0.150
# Precision = 0.864 vs. 0.081
# Recall = 0.860 vs. 1.000
# Validation: 1400
# AUC = 0.862 vs. 0.073
# F1 = 0.810 vs. 0.135
# Precision = 0.869 vs. 0.072
# Recall = 0.758 vs. 1.000
# Minibatch Loss= 0.503624
# Training: 1500
# AUC = 0.918 vs. 0.080
# F1 = 0.885 vs. 0.142
# Precision = 0.963 vs. 0.076
# Recall = 0.819 vs. 0.959
# Validation: 1500
# AUC = 0.853 vs. 0.073
# F1 = 0.831 vs. 0.135
# Precision = 0.872 vs. 0.073
# Recall = 0.793 vs. 0.988
# Minibatch Loss= 0.646179
# Training: 1600
# AUC = 0.897 vs. 0.067
# F1 = 0.844 vs. 0.131
# Precision = 0.892 vs. 0.070
# Recall = 0.801 vs. 0.994
# Validation: 1600
# AUC = 0.872 vs. 0.072
# F1 = 0.827 vs. 0.136
# Precision = 0.864 vs. 0.073
# Recall = 0.794 vs. 0.981
# Minibatch Loss= 0.427819
# Training: 1700
# AUC = 0.927 vs. 0.086
# F1 = 0.857 vs. 0.152
# Precision = 0.880 vs. 0.087
# Recall = 0.836 vs. 0.597
# Validation: 1700
# AUC = 0.876 vs. 0.074
# F1 = 0.815 vs. 0.137
# Precision = 0.820 vs. 0.074
# Recall = 0.809 vs. 0.949
# Minibatch Loss= 0.532317
# Training: 1800
# AUC = 0.910 vs. 0.069
# F1 = 0.859 vs. 0.120
# Precision = 0.838 vs. 0.065
# Recall = 0.881 vs. 0.730
# Validation: 1800
# AUC = 0.880 vs. 0.076
# F1 = 0.829 vs. 0.136
# Precision = 0.907 vs. 0.073
# Recall = 0.763 vs. 0.904
# Minibatch Loss= 0.416475
# Training: 1900
# AUC = 0.921 vs. 0.072
# F1 = 0.859 vs. 0.126
# Precision = 0.869 vs. 0.067
# Recall = 0.849 vs. 1.000
# Validation: 1900
# AUC = 0.882 vs. 0.074
# F1 = 0.829 vs. 0.135
# Precision = 0.872 vs. 0.073
# Recall = 0.790 vs. 0.973
# Minibatch Loss= 0.431906
# Training: 2000
# AUC = 0.914 vs. 0.071
# F1 = 0.872 vs. 0.139
# Precision = 0.817 vs. 0.080
# Recall = 0.935 vs. 0.554
# Validation: 2000
# AUC = 0.872 vs. 0.075
# F1 = 0.813 vs. 0.136
# Precision = 0.863 vs. 0.073
# Recall = 0.769 vs. 0.988
# Minibatch Loss= 0.460382
# Training: 2100
# AUC = 0.927 vs. 0.082
# F1 = 0.882 vs. 0.142
# Precision = 0.946 vs. 0.082
# Recall = 0.826 vs. 0.547
# Validation: 2100
# AUC = 0.889 vs. 0.072
# F1 = 0.832 vs. 0.136
# Precision = 0.861 vs. 0.073
# Recall = 0.805 vs. 0.996
# Minibatch Loss= 0.452267
# Training: 2200
# AUC = 0.921 vs. 0.082
# F1 = 0.888 vs. 0.148
# Precision = 0.902 vs. 0.088
# Recall = 0.875 vs. 0.465
# Validation: 2200
# AUC = 0.873 vs. 0.070
# F1 = 0.824 vs. 0.135
# Precision = 0.848 vs. 0.072
# Recall = 0.802 vs. 1.000
# Minibatch Loss= 0.561858
# Training: 2300
# AUC = 0.929 vs. 0.092
# F1 = 0.868 vs. 0.142
# Precision = 0.864 vs. 0.078
# Recall = 0.873 vs. 0.772
# Validation: 2300
# AUC = 0.882 vs. 0.074
# F1 = 0.820 vs. 0.135
# Precision = 0.841 vs. 0.073
# Recall = 0.800 vs. 0.985
# Minibatch Loss= 0.431114
# Training: 2400
# AUC = 0.917 vs. 0.084
# F1 = 0.889 vs. 0.150
# Precision = 0.851 vs. 0.088
# Recall = 0.931 vs. 0.510
# Validation: 2400
# AUC = 0.859 vs. 0.071
# F1 = 0.818 vs. 0.135
# Precision = 0.843 vs. 0.073
# Recall = 0.795 vs. 0.996
# Minibatch Loss= 0.434660
# Training: 2500
# AUC = 0.906 vs. 0.072
# F1 = 0.865 vs. 0.143
# Precision = 0.901 vs. 0.077
# Recall = 0.832 vs. 1.000
# Validation: 2500
# AUC = 0.879 vs. 0.072
# F1 = 0.828 vs. 0.135
# Precision = 0.860 vs. 0.073
# Recall = 0.798 vs. 0.958
# Minibatch Loss= 0.408684
# Training: 2600
# AUC = 0.943 vs. 0.077
# F1 = 0.885 vs. 0.150
# Precision = 0.885 vs. 0.082
# Recall = 0.885 vs. 0.843
# Validation: 2600
# AUC = 0.872 vs. 0.075
# F1 = 0.829 vs. 0.138
# Precision = 0.870 vs. 0.075
# Recall = 0.792 vs. 0.903
# Minibatch Loss= 0.366770
# Training: 2700
# AUC = 0.952 vs. 0.085
# F1 = 0.885 vs. 0.156
# Precision = 0.840 vs. 0.085
# Recall = 0.935 vs. 0.944
# Validation: 2700
# AUC = 0.891 vs. 0.073
# F1 = 0.842 vs. 0.135
# Precision = 0.863 vs. 0.073
# Recall = 0.822 vs. 0.999
# Minibatch Loss= 0.400381
# Training: 2800
# AUC = 0.916 vs. 0.076
# F1 = 0.856 vs. 0.146
# Precision = 0.820 vs. 0.079
# Recall = 0.896 vs. 0.959
# Validation: 2800
# AUC = 0.876 vs. 0.073
# F1 = 0.833 vs. 0.136
# Precision = 0.872 vs. 0.073
# Recall = 0.797 vs. 0.957
# Minibatch Loss= 0.407418
# Training: 2900
# AUC = 0.933 vs. 0.069
# F1 = 0.862 vs. 0.131
# Precision = 0.896 vs. 0.075
# Recall = 0.831 vs. 0.525
# Validation: 2900
# AUC = 0.893 vs. 0.073
# F1 = 0.834 vs. 0.135
# Precision = 0.860 vs. 0.073
# Recall = 0.809 vs. 0.976
# Minibatch Loss= 0.406269
# Training: 3000
# AUC = 0.959 vs. 0.078
# F1 = 0.888 vs. 0.135
# Precision = 0.852 vs. 0.072
# Recall = 0.928 vs. 0.972
# Validation: 3000
# AUC = 0.889 vs. 0.075
# F1 = 0.827 vs. 0.135
# Precision = 0.831 vs. 0.072
# Recall = 0.823 vs. 0.998
# Minibatch Loss= 0.303376
# Training: 3100
# AUC = 0.933 vs. 0.065
# F1 = 0.889 vs. 0.131
# Precision = 0.856 vs. 0.070
# Recall = 0.925 vs. 0.960
# Validation: 3100
# AUC = 0.891 vs. 0.073
# F1 = 0.839 vs. 0.135
# Precision = 0.859 vs. 0.073
# Recall = 0.821 vs. 0.988
# Minibatch Loss= 0.336742
# Training: 3200
# AUC = 0.926 vs. 0.081
# F1 = 0.894 vs. 0.155
# Precision = 0.908 vs. 0.091
# Recall = 0.881 vs. 0.512
# Validation: 3200
# AUC = 0.900 vs. 0.076
# F1 = 0.840 vs. 0.136
# Precision = 0.864 vs. 0.073
# Recall = 0.817 vs. 0.972
# Minibatch Loss= 0.428338
# Training: 3300
# AUC = 0.936 vs. 0.079
# F1 = 0.873 vs. 0.146
# Precision = 0.878 vs. 0.080
# Recall = 0.868 vs. 0.800
# Validation: 3300
# AUC = 0.870 vs. 0.074
# F1 = 0.820 vs. 0.136
# Precision = 0.825 vs. 0.074
# Recall = 0.815 vs. 0.868
# Minibatch Loss= 0.394286
# Training: 3400
# AUC = 0.940 vs. 0.080
# F1 = 0.897 vs. 0.126
# Precision = 0.882 vs. 0.067
# Recall = 0.913 vs. 1.000
# Validation: 3400
# AUC = 0.881 vs. 0.074
# F1 = 0.825 vs. 0.136
# Precision = 0.874 vs. 0.073
# Recall = 0.781 vs. 0.937
# Minibatch Loss= 0.353619
# Training: 3500
# AUC = 0.930 vs. 0.079
# F1 = 0.874 vs. 0.146
# Precision = 0.870 vs. 0.081
# Recall = 0.879 vs. 0.779
# Validation: 3500
# AUC = 0.874 vs. 0.072
# F1 = 0.815 vs. 0.135
# Precision = 0.822 vs. 0.073
# Recall = 0.808 vs. 0.972
# Minibatch Loss= 0.425572
# Training: 3600
# AUC = 0.950 vs. 0.082
# F1 = 0.894 vs. 0.159
# Precision = 0.841 vs. 0.087
# Recall = 0.954 vs. 0.944
# Validation: 3600
# AUC = 0.849 vs. 0.070
# F1 = 0.806 vs. 0.136
# Precision = 0.831 vs. 0.073
# Recall = 0.782 vs. 0.998
# Minibatch Loss= 0.415514
# Training: 3700
# AUC = 0.933 vs. 0.069
# F1 = 0.878 vs. 0.137
# Precision = 0.893 vs. 0.074
# Recall = 0.864 vs. 0.951
# Validation: 3700
# AUC = 0.866 vs. 0.073
# F1 = 0.819 vs. 0.136
# Precision = 0.854 vs. 0.073
# Recall = 0.787 vs. 0.989
# Minibatch Loss= 0.381039
# Training: 3800
# AUC = 0.951 vs. 0.084
# F1 = 0.903 vs. 0.140
# Precision = 0.918 vs. 0.076
# Recall = 0.888 vs. 0.904
# Validation: 3800
# AUC = 0.888 vs. 0.075
# F1 = 0.824 vs. 0.138
# Precision = 0.849 vs. 0.074
# Recall = 0.800 vs. 0.948
# Minibatch Loss= 0.352210
# Training: 3900
# AUC = 0.976 vs. 0.073
# F1 = 0.924 vs. 0.140
# Precision = 0.892 vs. 0.075
# Recall = 0.958 vs. 0.979
# Validation: 3900
# AUC = 0.892 vs. 0.071
# F1 = 0.835 vs. 0.135
# Precision = 0.856 vs. 0.072
# Recall = 0.815 vs. 1.000
# Minibatch Loss= 0.351182
# Training: 4000
# AUC = 0.901 vs. 0.072
# F1 = 0.844 vs. 0.138
# Precision = 0.797 vs. 0.075
# Recall = 0.897 vs. 0.918
# Validation: 4000
# AUC = 0.872 vs. 0.071
# F1 = 0.818 vs. 0.135
# Precision = 0.840 vs. 0.073
# Recall = 0.798 vs. 0.996
# Minibatch Loss= 0.402930
# Training: 4100
# AUC = 0.936 vs. 0.072
# F1 = 0.878 vs. 0.133
# Precision = 0.915 vs. 0.072
# Recall = 0.844 vs. 0.849
# Validation: 4100
# AUC = 0.861 vs. 0.074
# F1 = 0.809 vs. 0.137
# Precision = 0.828 vs. 0.074
# Recall = 0.791 vs. 0.876
# Minibatch Loss= 0.373212
# Training: 4200
# AUC = 0.894 vs. 0.075
# F1 = 0.850 vs. 0.133
# Precision = 0.899 vs. 0.073
# Recall = 0.807 vs. 0.722
# Validation: 4200
# AUC = 0.861 vs. 0.071
# F1 = 0.822 vs. 0.136
# Precision = 0.853 vs. 0.073
# Recall = 0.794 vs. 0.914
# Minibatch Loss= 0.443456
# Training: 4300
# AUC = 0.958 vs. 0.070
# F1 = 0.913 vs. 0.143
# Precision = 0.895 vs. 0.077
# Recall = 0.932 vs. 0.958
# Validation: 4300
# AUC = 0.891 vs. 0.072
# F1 = 0.828 vs. 0.137
# Precision = 0.868 vs. 0.075
# Recall = 0.791 vs. 0.753
# Minibatch Loss= 0.375772
# Training: 4400
# AUC = 0.945 vs. 0.083
# F1 = 0.893 vs. 0.135
# Precision = 0.906 vs. 0.075
# Recall = 0.880 vs. 0.703
# Validation: 4400
# AUC = 0.896 vs. 0.074
# F1 = 0.846 vs. 0.135
# Precision = 0.876 vs. 0.073
# Recall = 0.817 vs. 0.984
# Minibatch Loss= 0.360888
# Training: 4500
# AUC = 0.968 vs. 0.068
# F1 = 0.914 vs. 0.140
# Precision = 0.909 vs. 0.076
# Recall = 0.920 vs. 0.879
# Validation: 4500
# AUC = 0.896 vs. 0.074
# F1 = 0.835 vs. 0.136
# Precision = 0.844 vs. 0.073
# Recall = 0.826 vs. 0.956
# Minibatch Loss= 0.302328
# Training: 4600
# AUC = 0.949 vs. 0.081
# F1 = 0.889 vs. 0.142
# Precision = 0.891 vs. 0.077
# Recall = 0.887 vs. 0.928
# Validation: 4600
# AUC = 0.900 vs. 0.073
# F1 = 0.840 vs. 0.136
# Precision = 0.884 vs. 0.073
# Recall = 0.801 vs. 0.983
# Minibatch Loss= 0.314807
# Training: 4700
# AUC = 0.968 vs. 0.076
# F1 = 0.911 vs. 0.152
# Precision = 0.873 vs. 0.082
# Recall = 0.952 vs. 1.000
# Validation: 4700
# AUC = 0.892 vs. 0.076
# F1 = 0.834 vs. 0.135
# Precision = 0.853 vs. 0.073
# Recall = 0.816 vs. 1.000
# Minibatch Loss= 0.357234
# Training: 4800
# AUC = 0.947 vs. 0.083
# F1 = 0.904 vs. 0.152
# Precision = 0.879 vs. 0.084
# Recall = 0.931 vs. 0.872
# Validation: 4800
# AUC = 0.877 vs. 0.072
# F1 = 0.832 vs. 0.135
# Precision = 0.845 vs. 0.072
# Recall = 0.819 vs. 0.999
# Minibatch Loss= 0.353037
# Training: 4900
# AUC = 0.936 vs. 0.075
# F1 = 0.871 vs. 0.143
# Precision = 0.838 vs. 0.078
# Recall = 0.907 vs. 0.892
# Validation: 4900
# AUC = 0.875 vs. 0.075
# F1 = 0.826 vs. 0.135
# Precision = 0.844 vs. 0.072
# Recall = 0.808 vs. 1.000
# Minibatch Loss= 0.358127
# Training: 5000
# AUC = 0.930 vs. 0.082
# F1 = 0.877 vs. 0.154
# Precision = 0.858 vs. 0.085
# Recall = 0.896 vs. 0.817
# Validation: 5000
# AUC = 0.893 vs. 0.075
# F1 = 0.842 vs. 0.135
# Precision = 0.867 vs. 0.073
# Recall = 0.818 vs. 0.955
# Minibatch Loss= 0.377604
# Training: 5100
# AUC = 0.954 vs. 0.065
# F1 = 0.887 vs. 0.127
# Precision = 0.858 vs. 0.072
# Recall = 0.918 vs. 0.556
# Validation: 5100
# AUC = 0.903 vs. 0.073
# F1 = 0.844 vs. 0.135
# Precision = 0.892 vs. 0.073
# Recall = 0.802 vs. 0.998
# Minibatch Loss= 0.341783
# Training: 5200
# AUC = 0.959 vs. 0.070
# F1 = 0.908 vs. 0.136
# Precision = 0.908 vs. 0.073
# Recall = 0.908 vs. 0.995
# Validation: 5200
# AUC = 0.898 vs. 0.072
# F1 = 0.848 vs. 0.135
# Precision = 0.902 vs. 0.072
# Recall = 0.801 vs. 1.000
# Minibatch Loss= 0.344266
# Training: 5300
# AUC = 0.950 vs. 0.071
# F1 = 0.873 vs. 0.141
# Precision = 0.834 vs. 0.077
# Recall = 0.917 vs. 0.839
# Validation: 5300
# AUC = 0.890 vs. 0.073
# F1 = 0.838 vs. 0.135
# Precision = 0.887 vs. 0.073
# Recall = 0.795 vs. 0.998
# Minibatch Loss= 0.382045
# Training: 5400
# AUC = 0.950 vs. 0.080
# F1 = 0.903 vs. 0.156
# Precision = 0.870 vs. 0.089
# Recall = 0.939 vs. 0.626
# Validation: 5400
# AUC = 0.896 vs. 0.069
# F1 = 0.843 vs. 0.136
# Precision = 0.838 vs. 0.073
# Recall = 0.849 vs. 0.992
# Minibatch Loss= 0.380979
# Training: 5500
# AUC = 0.964 vs. 0.078
# F1 = 0.901 vs. 0.146
# Precision = 0.883 vs. 0.079
# Recall = 0.919 vs. 0.975
# Validation: 5500
# AUC = 0.898 vs. 0.072
# F1 = 0.843 vs. 0.135
# Precision = 0.878 vs. 0.073
# Recall = 0.810 vs. 0.970
# Minibatch Loss= 0.351106
# Training: 5600
# AUC = 0.954 vs. 0.080
# F1 = 0.880 vs. 0.149
# Precision = 0.923 vs. 0.084
# Recall = 0.840 vs. 0.655
# Validation: 5600
# AUC = 0.897 vs. 0.072
# F1 = 0.842 vs. 0.135
# Precision = 0.858 vs. 0.073
# Recall = 0.827 vs. 0.995
# Minibatch Loss= 0.374969
# Training: 5700
# AUC = 0.931 vs. 0.071
# F1 = 0.900 vs. 0.143
# Precision = 0.874 vs. 0.078
# Recall = 0.928 vs. 0.907
# Validation: 5700
# AUC = 0.888 vs. 0.072
# F1 = 0.837 vs. 0.136
# Precision = 0.890 vs. 0.073
# Recall = 0.791 vs. 0.976
# Minibatch Loss= 0.328523
# Training: 5800
# AUC = 0.969 vs. 0.062
# F1 = 0.918 vs. 0.120
# Precision = 0.936 vs. 0.064
# Recall = 0.901 vs. 0.994
# Validation: 5800
# AUC = 0.889 vs. 0.074
# F1 = 0.830 vs. 0.135
# Precision = 0.828 vs. 0.073
# Recall = 0.832 vs. 0.999
# Minibatch Loss= 0.328229
# Training: 5900
# AUC = 0.969 vs. 0.079
# F1 = 0.898 vs. 0.136
# Precision = 0.895 vs. 0.077
# Recall = 0.900 vs. 0.583
# Validation: 5900
# AUC = 0.894 vs. 0.075
# F1 = 0.837 vs. 0.136
# Precision = 0.862 vs. 0.075
# Recall = 0.813 vs. 0.701
# Minibatch Loss= 0.310644
# Training: 6000
# AUC = 0.942 vs. 0.068
# F1 = 0.890 vs. 0.138
# Precision = 0.853 vs. 0.074
# Recall = 0.930 vs. 0.968
# Validation: 6000
# AUC = 0.895 vs. 0.074
# F1 = 0.838 vs. 0.136
# Precision = 0.884 vs. 0.073
# Recall = 0.797 vs. 0.951
# Minibatch Loss= 0.355973
# Training: 6100
# AUC = 0.960 vs. 0.090
# F1 = 0.898 vs. 0.146
# Precision = 0.917 vs. 0.078
# Recall = 0.880 vs. 1.000
# Validation: 6100
# AUC = 0.899 vs. 0.070
# F1 = 0.842 vs. 0.135
# Precision = 0.888 vs. 0.073
# Recall = 0.801 vs. 0.998
# Minibatch Loss= 0.369375
# Training: 6200
# AUC = 0.968 vs. 0.073
# F1 = 0.900 vs. 0.149
# Precision = 0.863 vs. 0.081
# Recall = 0.940 vs. 0.985
# Validation: 6200
# AUC = 0.904 vs. 0.073
# F1 = 0.844 vs. 0.137
# Precision = 0.856 vs. 0.073
# Recall = 0.833 vs. 0.975
# Minibatch Loss= 0.342670
# Training: 6300
# AUC = 0.954 vs. 0.084
# F1 = 0.906 vs. 0.151
# Precision = 0.889 vs. 0.082
# Recall = 0.923 vs. 1.000
# Validation: 6300
# AUC = 0.902 vs. 0.074
# F1 = 0.841 vs. 0.137
# Precision = 0.848 vs. 0.074
# Recall = 0.833 vs. 0.847
# Minibatch Loss= 0.352959
# Training: 6400
# AUC = 0.936 vs. 0.068
# F1 = 0.873 vs. 0.146
# Precision = 0.835 vs. 0.079
# Recall = 0.915 vs. 0.990
# Validation: 6400
# AUC = 0.890 vs. 0.071
# F1 = 0.829 vs. 0.135
# Precision = 0.828 vs. 0.072
# Recall = 0.830 vs. 1.000
# Minibatch Loss= 0.351631
# Training: 6500
# AUC = 0.950 vs. 0.068
# F1 = 0.887 vs. 0.137
# Precision = 0.880 vs. 0.074
# Recall = 0.894 vs. 1.000
# Validation: 6500
# AUC = 0.899 vs. 0.071
# F1 = 0.843 vs. 0.135
# Precision = 0.895 vs. 0.073
# Recall = 0.797 vs. 0.998
# Minibatch Loss= 0.347880
# Training: 6600
# AUC = 0.954 vs. 0.071
# F1 = 0.899 vs. 0.140
# Precision = 0.909 vs. 0.076
# Recall = 0.889 vs. 0.884
# Validation: 6600
# AUC = 0.896 vs. 0.072
# F1 = 0.845 vs. 0.136
# Precision = 0.877 vs. 0.073
# Recall = 0.815 vs. 0.959
# Minibatch Loss= 0.343872
# Training: 6700
# AUC = 0.961 vs. 0.068
# F1 = 0.897 vs. 0.139
# Precision = 0.922 vs. 0.075
# Recall = 0.874 vs. 0.974
# Validation: 6700
# AUC = 0.900 vs. 0.072
# F1 = 0.843 vs. 0.135
# Precision = 0.890 vs. 0.072
# Recall = 0.801 vs. 1.000
# Minibatch Loss= 0.312646
# Training: 6800
# AUC = 0.967 vs. 0.081
# F1 = 0.903 vs. 0.148
# Precision = 0.872 vs. 0.080
# Recall = 0.936 vs. 1.000
# Validation: 6800
# AUC = 0.894 vs. 0.071
# F1 = 0.837 vs. 0.135
# Precision = 0.882 vs. 0.073
# Recall = 0.797 vs. 0.992
# Minibatch Loss= 0.308795
# Training: 6900
# AUC = 0.958 vs. 0.088
# F1 = 0.895 vs. 0.151
# Precision = 0.831 vs. 0.082
# Recall = 0.970 vs. 0.889
# Validation: 6900
# AUC = 0.899 vs. 0.074
# F1 = 0.844 vs. 0.136
# Precision = 0.865 vs. 0.073
# Recall = 0.824 vs. 0.931
# Minibatch Loss= 0.304166
# Training: 7000
# AUC = 0.938 vs. 0.079
# F1 = 0.888 vs. 0.135
# Precision = 0.833 vs. 0.100
# Recall = 0.951 vs. 0.207
# Validation: 7000
# AUC = 0.892 vs. 0.074
# F1 = 0.832 vs. 0.135
# Precision = 0.873 vs. 0.073
# Recall = 0.795 vs. 0.985
# Minibatch Loss= 0.312324
# Training: 7100
# AUC = 0.976 vs. 0.076
# F1 = 0.915 vs. 0.134
# Precision = 0.926 vs. 0.072
# Recall = 0.905 vs. 0.972
# Validation: 7100
# AUC = 0.888 vs. 0.073
# F1 = 0.835 vs. 0.136
# Precision = 0.860 vs. 0.073
# Recall = 0.812 vs. 0.990
# Minibatch Loss= 0.287652
# Training: 7200
# AUC = 0.959 vs. 0.078
# F1 = 0.905 vs. 0.144
# Precision = 0.889 vs. 0.084
# Recall = 0.922 vs. 0.531
# Validation: 7200
# AUC = 0.900 vs. 0.072
# F1 = 0.841 vs. 0.136
# Precision = 0.890 vs. 0.073
# Recall = 0.798 vs. 0.996
# Minibatch Loss= 0.297650
# Training: 7300
# AUC = 0.956 vs. 0.065
# F1 = 0.897 vs. 0.132
# Precision = 0.878 vs. 0.071
# Recall = 0.917 vs. 1.000
# Validation: 7300
# AUC = 0.884 vs. 0.072
# F1 = 0.824 vs. 0.135
# Precision = 0.882 vs. 0.073
# Recall = 0.773 vs. 0.978
# Minibatch Loss= 0.333775
# Training: 7400
# AUC = 0.962 vs. 0.071
# F1 = 0.913 vs. 0.133
# Precision = 0.884 vs. 0.072
# Recall = 0.944 vs. 0.944
# Validation: 7400
# AUC = 0.890 vs. 0.072
# F1 = 0.837 vs. 0.136
# Precision = 0.888 vs. 0.074
# Recall = 0.792 vs. 0.790
# Minibatch Loss= 0.299886
# Training: 7500
# AUC = 0.973 vs. 0.079
# F1 = 0.919 vs. 0.147
# Precision = 0.916 vs. 0.079
# Recall = 0.921 vs. 1.000
# Validation: 7500
# AUC = 0.899 vs. 0.070
# F1 = 0.845 vs. 0.136
# Precision = 0.851 vs. 0.073
# Recall = 0.838 vs. 0.996
# Minibatch Loss= 0.315766
# Training: 7600
# AUC = 0.960 vs. 0.075
# F1 = 0.915 vs. 0.144
# Precision = 0.884 vs. 0.078
# Recall = 0.948 vs. 0.974
# Validation: 7600
# AUC = 0.902 vs. 0.073
# F1 = 0.847 vs. 0.135
# Precision = 0.872 vs. 0.072
# Recall = 0.824 vs. 0.999
# Minibatch Loss= 0.329030
# Training: 7700
# AUC = 0.960 vs. 0.071
# F1 = 0.905 vs. 0.140
# Precision = 0.903 vs. 0.078
# Recall = 0.908 vs. 0.690
# Validation: 7700
# AUC = 0.901 vs. 0.077
# F1 = 0.844 vs. 0.136
# Precision = 0.865 vs. 0.074
# Recall = 0.824 vs. 0.924
# Minibatch Loss= 0.299423
# Training: 7800
# AUC = 0.963 vs. 0.077
# F1 = 0.908 vs. 0.135
# Precision = 0.894 vs. 0.075
# Recall = 0.923 vs. 0.703
# Validation: 7800
# AUC = 0.900 vs. 0.072
# F1 = 0.845 vs. 0.136
# Precision = 0.881 vs. 0.073
# Recall = 0.812 vs. 0.998
# Minibatch Loss= 0.299360
# Training: 7900
# AUC = 0.966 vs. 0.068
# F1 = 0.905 vs. 0.132
# Precision = 0.884 vs. 0.071
# Recall = 0.928 vs. 0.994
# Validation: 7900
# AUC = 0.900 vs. 0.075
# F1 = 0.842 vs. 0.135
# Precision = 0.890 vs. 0.073
# Recall = 0.799 vs. 0.997
# Minibatch Loss= 0.304406
# Training: 8000
# AUC = 0.976 vs. 0.075
# F1 = 0.916 vs. 0.147
# Precision = 0.933 vs. 0.080
# Recall = 0.900 vs. 0.965
# Validation: 8000
# AUC = 0.901 vs. 0.074
# F1 = 0.850 vs. 0.136
# Precision = 0.887 vs. 0.073
# Recall = 0.816 vs. 0.971
# Minibatch Loss= 0.306584
# Training: 8100
# AUC = 0.971 vs. 0.079
# F1 = 0.909 vs. 0.150
# Precision = 0.937 vs. 0.081
# Recall = 0.882 vs. 0.995
# Validation: 8100
# AUC = 0.895 vs. 0.071
# F1 = 0.842 vs. 0.136
# Precision = 0.861 vs. 0.073
# Recall = 0.825 vs. 0.989
# Minibatch Loss= 0.303040
# Training: 8200
# AUC = 0.958 vs. 0.074
# F1 = 0.904 vs. 0.142
# Precision = 0.897 vs. 0.077
# Recall = 0.911 vs. 0.885
# Validation: 8200
# AUC = 0.889 vs. 0.072
# F1 = 0.837 vs. 0.135
# Precision = 0.873 vs. 0.073
# Recall = 0.804 vs. 0.999
# Minibatch Loss= 0.348290
# Training: 8300
# AUC = 0.974 vs. 0.069
# F1 = 0.907 vs. 0.134
# Precision = 0.885 vs. 0.072
# Recall = 0.929 vs. 1.000
# Validation: 8300
# AUC = 0.894 vs. 0.074
# F1 = 0.842 vs. 0.136
# Precision = 0.867 vs. 0.073
# Recall = 0.818 vs. 0.989
# Minibatch Loss= 0.278287
# Training: 8400
# AUC = 0.981 vs. 0.076
# F1 = 0.933 vs. 0.134
# Precision = 0.947 vs. 0.073
# Recall = 0.920 vs. 0.829
# Validation: 8400
# AUC = 0.896 vs. 0.076
# F1 = 0.843 vs. 0.136
# Precision = 0.895 vs. 0.075
# Recall = 0.797 vs. 0.771
# Minibatch Loss= 0.278774
# Training: 8500
# AUC = 0.947 vs. 0.077
# F1 = 0.871 vs. 0.144
# Precision = 0.883 vs. 0.078
# Recall = 0.860 vs. 0.917
# Validation: 8500
# AUC = 0.888 vs. 0.073
# F1 = 0.832 vs. 0.136
# Precision = 0.858 vs. 0.073
# Recall = 0.808 vs. 0.996
# Minibatch Loss= 0.338518
# Training: 8600
# AUC = 0.953 vs. 0.069
# F1 = 0.896 vs. 0.144
# Precision = 0.911 vs. 0.078
# Recall = 0.883 vs. 0.954
# Validation: 8600
# AUC = 0.897 vs. 0.075
# F1 = 0.845 vs. 0.135
# Precision = 0.877 vs. 0.073
# Recall = 0.816 vs. 1.000
# Minibatch Loss= 0.344032
# Training: 8700
# AUC = 0.961 vs. 0.088
# F1 = 0.899 vs. 0.151
# Precision = 0.890 vs. 0.089
# Recall = 0.907 vs. 0.512
# Validation: 8700
# AUC = 0.897 vs. 0.072
# F1 = 0.845 vs. 0.135
# Precision = 0.876 vs. 0.073
# Recall = 0.816 vs. 0.988
# Minibatch Loss= 0.384047
# Training: 8800
# AUC = 0.979 vs. 0.078
# F1 = 0.923 vs. 0.135
# Precision = 0.888 vs. 0.074
# Recall = 0.961 vs. 0.702
# Validation: 8800
# AUC = 0.899 vs. 0.073
# F1 = 0.841 vs. 0.137
# Precision = 0.852 vs. 0.075
# Recall = 0.830 vs. 0.855
# Minibatch Loss= 0.280940
# Training: 8900
# AUC = 0.951 vs. 0.079
# F1 = 0.885 vs. 0.150
# Precision = 0.903 vs. 0.082
# Recall = 0.868 vs. 0.828
# Validation: 8900
# AUC = 0.893 vs. 0.073
# F1 = 0.835 vs. 0.135
# Precision = 0.878 vs. 0.073
# Recall = 0.796 vs. 0.999
# Minibatch Loss= 0.418590
# Training: 9000
# AUC = 0.971 vs. 0.073
# F1 = 0.903 vs. 0.134
# Precision = 0.908 vs. 0.074
# Recall = 0.898 vs. 0.773
# Validation: 9000
# AUC = 0.901 vs. 0.075
# F1 = 0.848 vs. 0.136
# Precision = 0.876 vs. 0.074
# Recall = 0.823 vs. 0.922
# Minibatch Loss= 0.296193
# Training: 9100
# AUC = 0.953 vs. 0.058
# F1 = 0.891 vs. 0.120
# Precision = 0.880 vs. 0.064
# Recall = 0.902 vs. 1.000
# Validation: 9100
# AUC = 0.901 vs. 0.074
# F1 = 0.846 vs. 0.136
# Precision = 0.871 vs. 0.073
# Recall = 0.823 vs. 0.960
# Minibatch Loss= 0.261441
# Training: 9200
# AUC = 0.962 vs. 0.092
# F1 = 0.905 vs. 0.167
# Precision = 0.910 vs. 0.094
# Recall = 0.901 vs. 0.755
# Validation: 9200
# AUC = 0.890 vs. 0.070
# F1 = 0.834 vs. 0.135
# Precision = 0.864 vs. 0.073
# Recall = 0.807 vs. 0.955
# Minibatch Loss= 0.389419
# Training: 9300
# AUC = 0.961 vs. 0.087
# F1 = 0.913 vs. 0.152
# Precision = 0.922 vs. 0.082
# Recall = 0.904 vs. 0.986
# Validation: 9300
# AUC = 0.897 vs. 0.073
# F1 = 0.842 vs. 0.135
# Precision = 0.871 vs. 0.072
# Recall = 0.815 vs. 1.000
# Minibatch Loss= 0.359544
# Training: 9400
# AUC = 0.969 vs. 0.068
# F1 = 0.925 vs. 0.142
# Precision = 0.937 vs. 0.077
# Recall = 0.913 vs. 1.000
# Validation: 9400
# AUC = 0.902 vs. 0.074
# F1 = 0.844 vs. 0.137
# Precision = 0.856 vs. 0.074
# Recall = 0.833 vs. 0.892
# Minibatch Loss= 0.306088
# Training: 9500
# AUC = 0.974 vs. 0.069
# F1 = 0.917 vs. 0.131
# Precision = 0.920 vs. 0.070
# Recall = 0.914 vs. 0.960
# Validation: 9500
# AUC = 0.896 vs. 0.072
# F1 = 0.850 vs. 0.136
# Precision = 0.897 vs. 0.073
# Recall = 0.806 vs. 0.975
# Minibatch Loss= 0.295536
# Training: 9600
# AUC = 0.982 vs. 0.074
# F1 = 0.944 vs. 0.132
# Precision = 0.944 vs. 0.071
# Recall = 0.944 vs. 0.950
# Validation: 9600
# AUC = 0.896 vs. 0.073
# F1 = 0.837 vs. 0.136
# Precision = 0.880 vs. 0.073
# Recall = 0.797 vs. 0.951
# Minibatch Loss= 0.254962
# Training: 9700
# AUC = 0.960 vs. 0.082
# F1 = 0.898 vs. 0.139
# Precision = 0.913 vs. 0.075
# Recall = 0.884 vs. 0.984
# Validation: 9700
# AUC = 0.883 vs. 0.073
# F1 = 0.826 vs. 0.136
# Precision = 0.848 vs. 0.073
# Recall = 0.806 vs. 0.995
# Minibatch Loss= 0.335369
# Training: 9800
# AUC = 0.970 vs. 0.077
# F1 = 0.908 vs. 0.149
# Precision = 0.926 vs. 0.084
# Recall = 0.890 vs. 0.681
# Validation: 9800
# AUC = 0.898 vs. 0.075
# F1 = 0.844 vs. 0.135
# Precision = 0.913 vs. 0.073
# Recall = 0.784 vs. 0.997
# Minibatch Loss= 0.288879
# Training: 9900
# AUC = 0.989 vs. 0.087
# F1 = 0.948 vs. 0.144
# Precision = 0.958 vs. 0.085
# Recall = 0.938 vs. 0.490
# Validation: 9900
# AUC = 0.903 vs. 0.072
# F1 = 0.852 vs. 0.136
# Precision = 0.868 vs. 0.073
# Recall = 0.837 vs. 0.988
# Minibatch Loss= 0.274966
#  Optimization Finished!

# %%
trainer.train(max_iter = 10000,
                train_eval_step = 1000, 
                validation_eval_step = 1000,
                display_step = 1000)
# Out:
# Training: 10000
# AUC = 0.999 vs. 0.071
# F1 = 0.992 vs. 0.127
# Precision = 0.992 vs. 0.079
# Recall = 0.992 vs. 0.331
# Validation: 10000
# AUC = 0.590 vs. 0.100
# F1 = 0.586 vs. 0.179
# Precision = 0.537 vs. 0.112
# Recall = 0.644 vs. 0.444
# Minibatch Loss= 0.146792
# Training: 11000
# AUC = 0.999 vs. 0.055
# F1 = 0.988 vs. 0.117
# Precision = 1.000 vs. 0.063
# Recall = 0.976 vs. 0.863
# Validation: 11000
# AUC = 0.582 vs. 0.120
# F1 = 0.567 vs. 0.197
# Precision = 0.864 vs. 0.149
# Recall = 0.422 vs. 0.289
# Minibatch Loss= 0.142615
# Training: 12000
# AUC = 0.999 vs. 0.055
# F1 = 0.996 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 0.992 vs. 0.887
# Validation: 12000
# AUC = 0.556 vs. 0.079
# F1 = 0.545 vs. 0.169
# Precision = 0.656 vs. 0.093
# Recall = 0.467 vs. 0.889
# Minibatch Loss= 0.141143
# Training: 13000
# AUC = 0.990 vs. 0.058
# F1 = 0.949 vs. 0.115
# Precision = 0.924 vs. 0.061
# Recall = 0.976 vs. 1.000
# Validation: 13000
# AUC = 0.321 vs. 0.101
# F1 = 0.356 vs. 0.164
# Precision = 0.356 vs. 0.089
# Recall = 0.356 vs. 1.000
# Minibatch Loss= 0.158430
# Training: 14000
# AUC = 1.000 vs. 0.053
# F1 = 0.992 vs. 0.115
# Precision = 0.984 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 14000
# AUC = 0.411 vs. 0.081
# F1 = 0.379 vs. 0.164
# Precision = 0.846 vs. 0.091
# Recall = 0.244 vs. 0.822
# Minibatch Loss= 0.141501
# Training: 15000
# AUC = 1.000 vs. 0.065
# F1 = 1.000 vs. 0.116
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 1.000
# Validation: 15000
# AUC = 0.413 vs. 0.093
# F1 = 0.387 vs. 0.163
# Precision = 0.375 vs. 0.089
# Recall = 0.400 vs. 1.000
# Minibatch Loss= 0.140783
# Training: 16000
# AUC = 1.000 vs. 0.061
# F1 = 1.000 vs. 0.115
# Precision = 1.000 vs. 0.061
# Recall = 1.000 vs. 1.000
# Validation: 16000
# AUC = 0.409 vs. 0.086
# F1 = 0.379 vs. 0.170
# Precision = 0.846 vs. 0.098
# Recall = 0.244 vs. 0.644
# Minibatch Loss= 0.140765
# Training: 17000
# AUC = 1.000 vs. 0.054
# F1 = 1.000 vs. 0.117
# Precision = 1.000 vs. 0.062
# Recall = 1.000 vs. 0.984
# Validation: 17000
# AUC = 0.548 vs. 0.106
# F1 = 0.543 vs. 0.194
# Precision = 0.532 vs. 0.133
# Recall = 0.556 vs. 0.356
# Minibatch Loss= 0.140880
# Training: 18000
# AUC = 1.000 vs. 0.069
# F1 = 1.000 vs. 0.130
# Precision = 1.000 vs. 0.073
# Recall = 1.000 vs. 0.613
# Validation: 18000
# AUC = 0.547 vs. 0.086
# F1 = 0.512 vs. 0.164
# Precision = 0.568 vs. 0.089
# Recall = 0.467 vs. 1.000
# Minibatch Loss= 0.140702
# Training: 19000
# AUC = 1.000 vs. 0.070
# F1 = 1.000 vs. 0.121
# Precision = 1.000 vs. 0.066
# Recall = 1.000 vs. 0.702
# Validation: 19000
# AUC = 0.548 vs. 0.112
# F1 = 0.533 vs. 0.192
# Precision = 0.667 vs. 0.117
# Recall = 0.444 vs. 0.533
# Minibatch Loss= 0.140679
#  Optimization Finished!

# %%
#Save the model
saver = tf.train.Saver()
saver.save(sess, checkpoint_path, global_step=trainer.global_step)
# Out:
# '../../model_synthetic/train_abrupt_test_gradual/CNN1001_x/CNN1001_x-10000'

# %%
#load the model
saver = tf.train.Saver()
saver.restore(sess, "../models/model" + exp_name + "/model")

# %%
#This is the model evaluation on test dataset
_= nn_eval.evaluate_model (model, sess, test_data, test_gt)
# Out:
# AUC = 0.851 vs. 0.282
# F1 = 0.766 vs. 0.439
# Precision = 0.804 vs. 0.281
# Recall = 0.732 vs. 1.000

# %%
out = nn_eval.deploy(model, sess, test_data, test_gt)

# %%
#shape of probability_change is (batch size, T, num_classes)
#since num_classes = 1 we squeeze that axis
out = np.squeeze(out, axis = 2)

# %%
out.shape
# Out:
# (1000, 256)

# %%
savemat('../../poc_synthetic/train_abrupt_test_gradual/poc'+exp_name+'.mat', {'poc':out})
